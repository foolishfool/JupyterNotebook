# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CarPrice_Assignment.csv",encoding='latin-1')
csv = csv.drop(columns=['car_ID'])

dataread.changeCategoryTextToInt(csv,"CarName")
dataread.changeCategoryTextToInt(csv,"carbody")
dataread.changeCategoryTextToInt(csv,"drivewheel")
dataread.changeCategoryTextToInt(csv,"fueltype")
dataread.changeCategoryTextToInt(csv,"aspiration")
dataread.changeCategoryTextToInt(csv,"doornumber")
dataread.changeCategoryTextToInt(csv,"cylindernumber")
dataread.changeCategoryTextToInt(csv,"enginelocation")
dataread.changeCategoryTextToInt(csv,"enginetype")
dataread.changeCategoryTextToInt(csv,"fuelsystem")

dataread.stringToIntCarPriceDataSet(csv,"symboling")
                                 
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv_training,csv_training,csv_test,"symboling")
# Out:
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 3
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# self.continuous_feature_num 15
# self.data_discrete_indexes ['fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5
features_choosen =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)
# Out:
# neuron unit number: 5
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.5277777777777778
# precision_score_sog 0.4152777777777778
# f1_score_sog 0.4025926869064125
# neuron unit number: 10
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.49074074074074076
# precision_score_sog 0.46195652173913043
# f1_score_sog 0.44274819579697633
# neuron unit number: 15
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.49074074074074076
# precision_score_sog 0.5
# f1_score_sog 0.45288291954958626
# neuron unit number: 20
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.47222222222222227
# precision_score_sog 0.46792328042328046
# f1_score_sog 0.4251839826839827
# Not good recall_score result !!!!!
# neuron unit number: 25
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4444444444444445
# precision_score_sog 0.46663824950269966
# f1_score_sog 0.39683374050489273
# Not good recall_score result !!!!!
# neuron unit number: 30
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.46296296296296297
# precision_score_sog 0.4616545893719806
# f1_score_sog 0.4204443253223742
# Not good recall_score result !!!!!
# neuron unit number: 35
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4537037037037037
# precision_score_sog 0.4563635840809754
# f1_score_sog 0.4076704325484813
# Not good recall_score result !!!!!
# neuron unit number: 40
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.46296296296296297
# precision_score_sog 0.4777493606138108
# f1_score_sog 0.42268844135959366
# Not good recall_score result !!!!!
# neuron unit number: 45
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4444444444444444
# precision_score_sog 0.436537999037999
# f1_score_sog 0.396017316017316
# Not good recall_score result !!!!!
# neuron unit number: 50
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.4259259259259259
# precision_score_sog 0.43187864517787794
# f1_score_sog 0.3779749434753639
# Not good recall_score result !!!!!
# neuron unit number: 55
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4351851851851852
# precision_score_sog 0.4266304347826087
# f1_score_sog 0.39009202179933894
# Not good recall_score result !!!!!
# neuron unit number: 60
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4444444444444444
# precision_score_sog 0.4491172072693812
# f1_score_sog 0.3995403512476683
# Not good recall_score result !!!!!
# neuron unit number: 65
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.48148148148148145
# precision_score_sog 0.48943236714975846
# f1_score_sog 0.4426665475445964
# neuron unit number: 70
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.47222222222222227
# precision_score_sog 0.45436507936507936
# f1_score_sog 0.4256338432809022
# Not good recall_score result !!!!!
# neuron unit number: 75
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4537037037037037
# precision_score_sog 0.44182900432900435
# f1_score_sog 0.40879120879120884
# Not good recall_score result !!!!!
# neuron unit number: 80
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4351851851851852
# precision_score_sog 0.4371696504688832
# f1_score_sog 0.3907488362492568
# Not good recall_score result !!!!!
# neuron unit number: 85
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.49074074074074076
# precision_score_sog 0.49173280423280424
# f1_score_sog 0.446017316017316
# neuron unit number: 90
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4444444444444444
# precision_score_sog 0.4491172072693812
# f1_score_sog 0.3995403512476683
# Not good recall_score result !!!!!
# neuron unit number: 95
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.4444444444444444
# precision_score_sog 0.436537999037999
# f1_score_sog 0.396017316017316
# Not good recall_score result !!!!!
# neuron unit number: 100
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.47540983606557374
# recall_score_original 0.48148148148148145
# precision_score_original 0.39098679098679096
# f1_score_original 0.3634471808384852
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.4259259259259259
# precision_score_sog 0.42133942949160336
# f1_score_sog 0.3773181290254461
# Not good recall_score result !!!!!
# all_accuracy_score_original mean 0.47540983606557363
# all_recall_score_original mean 0.4814814814814814
# all_precision_score_original mean 0.3909867909867909
# all_f1_score_original mean 0.36344718083848526
# all_accuracy_score_sog mean 0.5254098360655738
# all_recall_score_sog mean 0.4601851851851852
# all_precision_score_sog mean 0.45366255955610174
# all_f1_score_sog mean 0.4110701452692848
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N     Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.47541  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.52541  2.406691e-02  5.381524e-03
# 2                     combined  40.0  0.50041  3.038434e-02  4.804185e-03
#
#    95% Conf.  Interval
# 0   0.475410  0.475410
# 1   0.514146  0.536673
# 2   0.490692  0.510127
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -5.000000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -9.291000e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.938100e+00
# 7                                       Hedge's g =  -2.879700e+00
# 8                                  Glass's delta1 =  -4.389566e+14
# 9                                Point-Biserial r =  -8.333000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.481481  5.695324e-17  1.273513e-17
# 1       all_recall_score_sog  20.0  0.460185  2.620636e-02  5.859921e-03
# 2                   combined  40.0  0.470833  2.123375e-02  3.357351e-03
#
#    95% Conf.  Interval
# 0   0.481481  0.481481
# 1   0.447920  0.472450
# 2   0.464042  0.477624
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re...  2.130000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   3.634200e+00
# 3                           Two side test p value =   8.000000e-04
# 4                          Difference < 0 p value =   9.996000e-01
# 5                          Difference > 0 p value =   4.000000e-04
# 6                                       Cohen's d =   1.149200e+00
# 7                                       Hedge's g =   1.126400e+00
# 8                                  Glass's delta1 =   3.739260e+14
# 9                                Point-Biserial r =   5.079000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.390987  5.695324e-17  1.273513e-17
# 1       all_precision_score_sog  20.0  0.453663  2.376604e-02  5.314247e-03
# 2                      combined  40.0  0.422325  3.581082e-02  5.662188e-03
#
#    95% Conf.  Interval
# 0   0.390987  0.390987
# 1   0.442540  0.464785
# 2   0.410872  0.433778
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -6.270000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.179390e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.729600e+00
# 7                                       Hedge's g =  -3.655500e+00
# 8                                  Glass's delta1 =  -1.100478e+15
# 9                                Point-Biserial r =  -8.862000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.363447  5.695324e-17  1.273513e-17
# 1       all_f1_score_sog  20.0  0.411070  2.259888e-02  5.053263e-03
# 2               combined  40.0  0.387259  2.881548e-02  4.556127e-03
#
#    95% Conf.  Interval
# 0   0.363447  0.363447
# 1   0.400494  0.421647
# 2   0.378043  0.396474
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -4.760000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -9.424200e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.980200e+00
# 7                                       Hedge's g =  -2.921000e+00
# 8                                  Glass's delta1 =  -8.361766e+14
# 9                                Point-Biserial r =  -8.369000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.450599128540305
# precision_score_sog 0.4304372041214147
# f1_score_sog 0.4386337067470496
# neuron unit number: 7
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.43763616557734203
# precision_score_sog 0.40277777777777773
# f1_score_sog 0.4126962732719928
# neuron unit number: 12
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6557377049180327
# recall_score_sog 0.5001361655773421
# precision_score_sog 0.5271762551174316
# f1_score_sog 0.5083688547882922
# neuron unit number: 17
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.639344262295082
# recall_score_sog 0.4691176470588235
# precision_score_sog 0.5108024691358025
# f1_score_sog 0.48014184397163123
# neuron unit number: 22
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6229508196721312
# recall_score_sog 0.459313725490196
# precision_score_sog 0.4880952380952381
# f1_score_sog 0.46565656565656566
# neuron unit number: 27
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4128540305010893
# precision_score_sog 0.4373973727422003
# f1_score_sog 0.41731859410430844
# neuron unit number: 32
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4128540305010893
# precision_score_sog 0.4373973727422003
# f1_score_sog 0.41731859410430844
# neuron unit number: 37
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6229508196721312
# recall_score_sog 0.459313725490196
# precision_score_sog 0.5045518207282913
# f1_score_sog 0.4716153127917834
# neuron unit number: 42
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5901639344262295
# recall_score_sog 0.43099128540305015
# precision_score_sog 0.46050561029009307
# f1_score_sog 0.4347694633408919
# neuron unit number: 47
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.44079520697167757
# precision_score_sog 0.46685340802987857
# f1_score_sog 0.44357298474945533
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.44063180827886717
# precision_score_sog 0.46547619047619043
# f1_score_sog 0.4467171717171717
# neuron unit number: 57
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5901639344262295
# recall_score_sog 0.43246187363834426
# precision_score_sog 0.45031901649548706
# f1_score_sog 0.43514114865804476
# neuron unit number: 62
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.4211873638344226
# precision_score_sog 0.45396825396825397
# f1_score_sog 0.42564814814814816
# neuron unit number: 67
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.639344262295082
# recall_score_sog 0.4778322440087146
# precision_score_sog 0.5219680464778504
# f1_score_sog 0.48944778857169347
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.44079520697167757
# precision_score_sog 0.46685340802987857
# f1_score_sog 0.44357298474945533
# neuron unit number: 77
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5901639344262295
# recall_score_sog 0.43246187363834426
# precision_score_sog 0.45031901649548706
# f1_score_sog 0.43514114865804476
# neuron unit number: 82
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.42265795206971674
# precision_score_sog 0.4439484126984126
# f1_score_sog 0.42638888888888893
# neuron unit number: 87
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.42265795206971674
# precision_score_sog 0.4439484126984126
# f1_score_sog 0.42638888888888893
# neuron unit number: 92
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4128540305010893
# precision_score_sog 0.4373973727422003
# f1_score_sog 0.41731859410430844
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.4509803921568627
# precision_score_sog 0.4900015561780268
# f1_score_sog 0.4627205137374099
# all_accuracy_score_original mean 0.5245901639344264
# all_recall_score_original mean 0.3799019607843137
# all_precision_score_original mean 0.3297619047619048
# all_f1_score_original mean 0.34908900836320195
# all_accuracy_score_sog mean 0.5959016393442622
# all_recall_score_sog mean 0.44140659041394337
# all_precision_score_sog mean 0.46450971075202646
# all_f1_score_sog mean 0.4449288734824167
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.524590  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.595902  2.926513e-02  6.543882e-03
# 2                     combined  40.0  0.560246  4.148703e-02  6.559675e-03
#
#    95% Conf.  Interval
# 0   0.524590  0.524590
# 1   0.582205  0.609598
# 2   0.546978  0.573514
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -7.130000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.089740e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.446100e+00
# 7                                       Hedge's g =  -3.377600e+00
# 8                                  Glass's delta1 =  -6.260528e+14
# 9                                Point-Biserial r =  -8.704000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.379902  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.441407  0.023173  0.005182   0.430561
# 2                   combined  40.0  0.410654  0.035094  0.005549   0.399431
#
#    Interval
# 0       NaN
# 1  0.452252
# 2  0.421878
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0615
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -11.8696
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.7535
# 7                                       Hedge's g =   -3.6789
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8875
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.329762  5.695324e-17  1.273513e-17
# 1       all_precision_score_sog  20.0  0.464510  3.304337e-02  7.388722e-03
# 2                      combined  40.0  0.397136  7.202477e-02  1.138812e-02
#
#    95% Conf.  Interval
# 0   0.329762  0.329762
# 1   0.449045  0.479974
# 2   0.374101  0.420170
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -1.347000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.823700e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.767000e+00
# 7                                       Hedge's g =  -5.652500e+00
# 8                                  Glass's delta1 =  -2.365938e+15
# 9                                Point-Biserial r =  -9.473000e-01
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.349089  0.000000  0.000000        NaN
# 1       all_f1_score_sog  20.0  0.444929  0.026588  0.005945   0.432485
# 2               combined  40.0  0.397009  0.051958  0.008215   0.380392
#
#    Interval
# 0       NaN
# 1  0.457372
# 2  0.413626
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0958
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -16.1205
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -5.0978
# 7                                       Hedge's g =   -4.9965
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9340
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#Decision Tree
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5

features_choosen =[]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6721311475409836
# recall_score_original 0.564175833912676
# precision_score_original 0.5754176379176379
# f1_score_original 0.5653259356045733
# SOG Classficiation
# accuracy_score_sog 0.6229508196721312
# recall_score_sog 0.5153704726073147
# precision_score_sog 0.5819444444444445
# f1_score_sog 0.536487128392828
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.5204712441554546
# precision_score_original 0.5478595478595478
# f1_score_original 0.5257378067722895
# SOG Classficiation
# accuracy_score_sog 0.47540983606557374
# recall_score_sog 0.4011581741844899
# precision_score_sog 0.4961640211640212
# f1_score_sog 0.4089782766253354
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.6721311475409836
# recall_score_original 0.5521987758829865
# precision_score_original 0.6041666666666666
# f1_score_original 0.5690248751269426
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4425641366430841
# precision_score_sog 0.4792811355311355
# f1_score_sog 0.44753694581280784
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.5901639344262295
# recall_score_original 0.5206867937131094
# precision_score_original 0.4983974358974359
# f1_score_original 0.4983800410116199
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4738869804659278
# precision_score_sog 0.5131578947368421
# f1_score_sog 0.46685434196777204
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.6557377049180327
# recall_score_original 0.5702512643302117
# precision_score_original 0.5646825396825396
# f1_score_original 0.5584910485933504
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.41297506100137676
# precision_score_sog 0.4322142998613587
# f1_score_sog 0.4190545808966862
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 27
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.639344262295082
# recall_score_original 0.5369015730857837
# precision_score_original 0.5366161616161617
# f1_score_original 0.5354059302269022
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4476487206750364
# precision_score_sog 0.5009259259259259
# f1_score_sog 0.4564373865844454
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.5737704918032787
# recall_score_original 0.4883731035046824
# precision_score_original 0.4999699374699375
# f1_score_original 0.48622395214687303
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.37373822571190995
# precision_score_sog 0.37918192918192917
# f1_score_sog 0.3640348422957118
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 37
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6065573770491803
# recall_score_original 0.5153091304407094
# precision_score_original 0.5383449883449883
# f1_score_original 0.5180647697675561
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.5202548426232637
# precision_score_sog 0.4875420875420875
# f1_score_sog 0.4924059434929
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.5171042407884513
# precision_score_original 0.5774170274170274
# f1_score_original 0.5324810885155713
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.5243417644733435
# precision_score_sog 0.5098215624531414
# f1_score_sog 0.5075633528265108
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 47
# accuracy_score_orignial 0.6885245901639344
# recall_score_original 0.587811311495522
# precision_score_original 0.5857843137254902
# f1_score_original 0.5816588857765328
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.4089102904892378
# precision_score_sog 0.43293650793650795
# f1_score_sog 0.41195463940561977
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5573770491803278
# recall_score_original 0.4651925803241593
# precision_score_original 0.48059384572542463
# f1_score_original 0.46736968632986575
# SOG Classficiation
# accuracy_score_sog 0.6557377049180327
# recall_score_sog 0.5610857222699328
# precision_score_sog 0.569023569023569
# f1_score_sog 0.5541003798717048
# neuron unit number: 57
# accuracy_score_orignial 0.6557377049180327
# recall_score_original 0.5316355184776237
# precision_score_original 0.5788888888888889
# f1_score_original 0.5413337167610959
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.45901639344262296
# recall_score_sog 0.3825714977030767
# precision_score_sog 0.434508969291578
# f1_score_sog 0.38048325943062783
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 62
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.5130394702763125
# precision_score_original 0.5418470418470419
# f1_score_original 0.5192007797270954
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.5025499597868018
# precision_score_sog 0.5217592592592593
# f1_score_sog 0.5071710195549205
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 67
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.5184674000463474
# precision_score_original 0.5432521726639373
# f1_score_original 0.5248677248677249
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.46263836066467645
# precision_score_sog 0.4668664668664668
# f1_score_sog 0.4520872144711154
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6065573770491803
# recall_score_original 0.5421855191592033
# precision_score_original 0.5487179487179487
# f1_score_original 0.5173307148025574
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.46911166319061054
# precision_score_sog 0.4596412846412847
# f1_score_sog 0.45354090354090354
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 77
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6065573770491803
# recall_score_original 0.5217730612467454
# precision_score_original 0.5218017276840806
# f1_score_original 0.5163177830940989
# SOG Classficiation
# accuracy_score_sog 0.47540983606557374
# recall_score_sog 0.4138491868755027
# precision_score_sog 0.4299989226459815
# f1_score_sog 0.412053872053872
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 82
# accuracy_score_orignial 0.5901639344262295
# recall_score_original 0.5209296064559222
# precision_score_original 0.5096866096866096
# f1_score_original 0.5011070853462158
# SOG Classficiation
# accuracy_score_sog 0.7049180327868853
# recall_score_sog 0.571408245750351
# precision_score_sog 0.6185185185185186
# f1_score_sog 0.5872503809713112
# neuron unit number: 87
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.435603504682452
# precision_score_original 0.4594387094387095
# f1_score_original 0.43864653423476957
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.5116831268147057
# precision_score_sog 0.5333964646464647
# f1_score_sog 0.5094179511815895
# neuron unit number: 92
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6721311475409836
# recall_score_original 0.5722891874207664
# precision_score_original 0.5811348781937018
# f1_score_original 0.5717855244171034
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.5064980097874835
# precision_score_sog 0.5349777034559643
# f1_score_sog 0.5129361612199141
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6065573770491803
# recall_score_original 0.5099817336659441
# precision_score_original 0.5180976430976431
# f1_score_original 0.5098323387325946
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.39788488801646693
# precision_score_sog 0.4474358974358974
# f1_score_sog 0.4060225466107819
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.6204918032786886
# all_recall_score_original mean 0.5252190426532531
# all_precision_score_original mean 0.5406057861270709
# all_f1_score_original mean 0.5239293110927666
# all_accuracy_score_sog mean 0.5483606557377049
# all_recall_score_sog mean 0.4650064664867296
# all_precision_score_sog mean 0.4914648432281189
# all_f1_score_sog mean 0.4643185563603679
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.620492  0.041973  0.009385   0.600848
# 1       all_accuracy_score_sog  20.0  0.548361  0.072825  0.016284   0.514278
# 2                     combined  40.0  0.584426  0.069109  0.010927   0.562324
#
#    Interval
# 0  0.640136
# 1  0.582444
# 2  0.606528
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...   0.0721
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    3.8378
# 3                           Two side test p value =    0.0005
# 4                          Difference < 0 p value =    0.9998
# 5                          Difference > 0 p value =    0.0002
# 6                                       Cohen's d =    1.2136
# 7                                       Hedge's g =    1.1895
# 8                                  Glass's delta1 =    1.7185
# 9                                Point-Biserial r =    0.5285
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.525219  0.035929  0.008034   0.508404
# 1       all_recall_score_sog  20.0  0.465006  0.059849  0.013383   0.436996
# 2                   combined  40.0  0.495113  0.057477  0.009088   0.476731
#
#    Interval
# 0  0.542035
# 1  0.493017
# 2  0.513495
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...   0.0602
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    3.8575
# 3                           Two side test p value =    0.0004
# 4                          Difference < 0 p value =    0.9998
# 5                          Difference > 0 p value =    0.0002
# 6                                       Cohen's d =    1.2199
# 7                                       Hedge's g =    1.1956
# 8                                  Glass's delta1 =    1.6759
# 9                                Point-Biserial r =    0.5305
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.540606  0.038335  0.008572
# 1       all_precision_score_sog  20.0  0.491465  0.058991  0.013191
# 2                      combined  40.0  0.516035  0.055050  0.008704
#
#    95% Conf.  Interval
# 0   0.522664  0.558547
# 1   0.463856  0.519074
# 2   0.498429  0.533641
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...   0.0491
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    3.1237
# 3                           Two side test p value =    0.0034
# 4                          Difference < 0 p value =    0.9983
# 5                          Difference > 0 p value =    0.0017
# 6                                       Cohen's d =    0.9878
# 7                                       Hedge's g =    0.9682
# 8                                  Glass's delta1 =    1.2819
# 9                                Point-Biserial r =    0.4520
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.523929  0.035910  0.008030   0.507123
# 1       all_f1_score_sog  20.0  0.464319  0.060245  0.013471   0.436123
# 2               combined  40.0  0.494124  0.057511  0.009093   0.475731
#
#    Interval
# 0  0.540736
# 1  0.492514
# 2  0.512517
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...   0.0596
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    3.8011
# 3                           Two side test p value =    0.0005
# 4                          Difference < 0 p value =    0.9997
# 5                          Difference > 0 p value =    0.0003
# 6                                       Cohen's d =    1.2020
# 7                                       Hedge's g =    1.1781
# 8                                  Glass's delta1 =    1.6600
# 9                                Point-Biserial r =    0.5249

# %%
#LinearDiscriminantAnalysis
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 5
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.429708328792997
# precision_score_sog 0.4324016563146998
# f1_score_sog 0.42680471982797563
# Not good recall_score result !!!!!
# neuron unit number: 10
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5901639344262295
# recall_score_sog 0.44572663542915264
# precision_score_sog 0.42284909132735216
# f1_score_sog 0.42556494995519384
# Not good recall_score result !!!!!
# neuron unit number: 15
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.44566307072027894
# precision_score_sog 0.4123677248677249
# f1_score_sog 0.4235588770472491
# Not good recall_score result !!!!!
# neuron unit number: 20
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4266572227670626
# precision_score_sog 0.40119047619047615
# f1_score_sog 0.4090141125024846
# Not good recall_score result !!!!!
# neuron unit number: 25
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4296447640841234
# precision_score_sog 0.40915032679738556
# f1_score_sog 0.41598263923845313
# Not good recall_score result !!!!!
# neuron unit number: 30
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.4384166939086847
# precision_score_sog 0.42571707045391255
# f1_score_sog 0.42917874167874165
# Not good recall_score result !!!!!
# neuron unit number: 35
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.410638916130907
# precision_score_sog 0.3956975772765246
# f1_score_sog 0.4013220561568174
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 40
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.45596055355780757
# precision_score_sog 0.45462962962962966
# f1_score_sog 0.45191637630662024
# neuron unit number: 45
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.410638916130907
# precision_score_sog 0.3982699805068226
# f1_score_sog 0.4012636012636012
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 50
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.44718862373324614
# precision_score_sog 0.4407685881370092
# f1_score_sog 0.4401837928153718
# Not good recall_score result !!!!!
# neuron unit number: 55
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.43542915259162407
# precision_score_sog 0.4387218045112782
# f1_score_sog 0.43492063492063493
# Not good recall_score result !!!!!
# neuron unit number: 60
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.44718862373324614
# precision_score_sog 0.4447368421052631
# f1_score_sog 0.44335839598997495
# Not good recall_score result !!!!!
# neuron unit number: 65
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4266572227670626
# precision_score_sog 0.43756613756613755
# f1_score_sog 0.431466693966694
# Not good recall_score result !!!!!
# neuron unit number: 70
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5901639344262295
# recall_score_sog 0.4782445243543642
# precision_score_sog 0.4751519321178765
# f1_score_sog 0.47182539682539687
# neuron unit number: 75
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.44718862373324614
# precision_score_sog 0.44244987468671676
# f1_score_sog 0.44224664224664223
# Not good recall_score result !!!!!
# neuron unit number: 80
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.42110166721150705
# precision_score_sog 0.44226190476190474
# f1_score_sog 0.42909958258795466
# Not good recall_score result !!!!!
# neuron unit number: 85
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.4384166939086847
# precision_score_sog 0.41513505987190197
# f1_score_sog 0.42189852189852184
# Not good recall_score result !!!!!
# neuron unit number: 90
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.42834804402310117
# precision_score_sog 0.4469298245614035
# f1_score_sog 0.43405607040857946
# Not good recall_score result !!!!!
# neuron unit number: 95
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.44718862373324614
# precision_score_sog 0.4407685881370092
# f1_score_sog 0.4401837928153718
# Not good recall_score result !!!!!
# neuron unit number: 100
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.4544350005448403
# precision_score_sog 0.4527777777777778
# f1_score_sog 0.45137130485967697
# all_accuracy_score_original mean 0.4918032786885244
# all_recall_score_original mean 0.4476698993861466
# all_precision_score_original mean 0.3925925925925925
# all_f1_score_original mean 0.40743816601061933
# all_accuracy_score_sog mean 0.5573770491803278
# all_recall_score_sog mean 0.4382220950928045
# all_precision_score_sog mean 0.43147709337994034
# all_f1_score_sog mean 0.43126084516559776
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.491803  1.708597e-16  3.820539e-17
# 1       all_accuracy_score_sog  20.0  0.557377  1.917697e-02  4.288101e-03
# 2                     combined  40.0  0.524590  3.580093e-02  5.660624e-03
#
#    95% Conf.  Interval
# 0   0.491803  0.491803
# 1   0.548402  0.566352
# 2   0.513140  0.536040
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -6.560000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.529200e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.835800e+00
# 7                                       Hedge's g =  -4.739700e+00
# 8                                  Glass's delta1 =  -3.837872e+14
# 9                                Point-Biserial r =  -9.275000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.447670  5.695324e-17  1.273513e-17
# 1       all_recall_score_sog  20.0  0.438222  1.613476e-02  3.607842e-03
# 2                   combined  40.0  0.442946  1.223581e-02  1.934652e-03
#
#    95% Conf.  Interval
# 0   0.447670  0.447670
# 1   0.430671  0.445773
# 2   0.439033  0.446859
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re...  9.400000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   2.618700e+00
# 3                           Two side test p value =   1.260000e-02
# 4                          Difference < 0 p value =   9.937000e-01
# 5                          Difference > 0 p value =   6.300000e-03
# 6                                       Cohen's d =   8.281000e-01
# 7                                       Hedge's g =   8.116000e-01
# 8                                  Glass's delta1 =   1.658870e+14
# 9                                Point-Biserial r =   3.910000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.392593  5.695324e-17  1.273513e-17
# 1       all_precision_score_sog  20.0  0.431477  2.096382e-02  4.687653e-03
# 2                      combined  40.0  0.412035  2.453161e-02  3.878788e-03
#
#    95% Conf.  Interval
# 0   0.392593  0.392593
# 1   0.421666  0.441288
# 2   0.404189  0.419880
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -3.890000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -8.295100e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.623100e+00
# 7                                       Hedge's g =  -2.571000e+00
# 8                                  Glass's delta1 =  -6.827443e+14
# 9                                Point-Biserial r =  -8.026000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.407438  5.695324e-17  1.273513e-17
# 1       all_f1_score_sog  20.0  0.431261  1.725486e-02  3.858305e-03
# 2               combined  40.0  0.419350  1.704600e-02  2.695209e-03
#
#    95% Conf.  Interval
# 0   0.407438  0.407438
# 1   0.423185  0.439336
# 2   0.413898  0.424801
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -2.380000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -6.174400e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.952500e+00
# 7                                       Hedge's g =  -1.913700e+00
# 8                                  Glass's delta1 =  -4.182849e+14
# 9                                Point-Biserial r =  -7.077000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#KNN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 50
class_num = 2
interval = 2

features = []
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 4
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 6
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 8
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 10
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 14
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 16
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 18
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 20
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 24
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 26
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 28
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 30
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 34
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 36
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 38
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 40
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 44
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 46
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 48
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 50
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.44471677559912853
# precision_score_original 0.40297619047619043
# f1_score_original 0.39843050824818005
# SOG Classficiation
# accuracy_score_sog 0.4262295081967213
# recall_score_sog 0.3110021786492375
# precision_score_sog 0.3277777777777778
# f1_score_sog 0.2862914862914863
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.5409836065573771
# all_recall_score_original mean 0.4447167755991285
# all_precision_score_original mean 0.40297619047619043
# all_f1_score_original mean 0.39843050824818005
# all_accuracy_score_sog mean 0.4262295081967213
# all_recall_score_sog mean 0.3110021786492375
# all_precision_score_sog mean 0.3277777777777778
# all_f1_score_sog mean 0.2862914862914863
# Accuracy Score T-Test
#                       Variable     N      Mean       SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  25.0  0.540984  0.00000  0.000000        NaN
# 1       all_accuracy_score_sog  25.0  0.426230  0.00000  0.000000        NaN
# 2                     combined  50.0  0.483607  0.05796  0.008197   0.467135
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.500078
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...   0.1148
# 1                              Degrees of freedom =   48.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  25.0  0.444717  5.665583e-17  1.133117e-17
# 1       all_recall_score_sog  25.0  0.311002  0.000000e+00  0.000000e+00
# 2                   combined  50.0  0.377859  6.753607e-02  9.551043e-03
#
#    95% Conf.  Interval
# 0   0.444717  0.444717
# 1        NaN       NaN
# 2   0.358666  0.397053
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re...  1.337000e-01
# 1                              Degrees of freedom =   4.800000e+01
# 2                                               t =   1.180060e+16
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   3.337715e+15
# 7                                       Hedge's g =   3.285290e+15
# 8                                  Glass's delta1 =   2.360121e+15
# 9                                Point-Biserial r =   1.000000e+00
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  25.0  0.402976  0.000000  0.000000
# 1       all_precision_score_sog  25.0  0.327778  0.000000  0.000000
# 2                      combined  50.0  0.365377  0.037981  0.005371
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1        NaN       NaN
# 2   0.354583  0.376171
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...   0.0752
# 1                              Degrees of freedom =   48.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# F1 Score T-Test
#                 Variable     N      Mean        SD       SE  95% Conf.  \
# 0  all_f1_score_original  25.0  0.398431  0.000000  0.00000        NaN
# 1       all_f1_score_sog  25.0  0.286291  0.000000  0.00000        NaN
# 2               combined  50.0  0.342361  0.056639  0.00801   0.326264
#
#    Interval
# 0       NaN
# 1       NaN
# 2  0.358458
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...   0.1121
# 1                              Degrees of freedom =   48.0000
# 2                                               t =       inf
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =       inf
# 7                                       Hedge's g =       inf
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: divide by zero encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: divide by zero encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:76: RuntimeWarning: invalid value encountered in double_scalars
#   r = t_val / numpy.sqrt(t_val**2 + dof)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#SVM
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5
features =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.5901639344262295
# recall_score_original 0.5704795204795206
# precision_score_original 0.6232919254658386
# f1_score_original 0.570569834972112
# SOG Classficiation
# accuracy_score_sog 0.47540983606557374
# recall_score_sog 0.35127372627372627
# precision_score_sog 0.3403735632183908
# f1_score_sog 0.335632183908046
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.639344262295082
# recall_score_original 0.6163669663669664
# precision_score_original 0.6569747899159664
# f1_score_original 0.6169522618303106
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.3985458985458985
# precision_score_sog 0.5227045119122918
# f1_score_sog 0.38702177452177455
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.6232767232767233
# precision_score_original 0.616726268900182
# f1_score_original 0.6137320574162679
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.4553640803640803
# precision_score_sog 0.5021825396825397
# f1_score_sog 0.459377725449154
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.6065573770491803
# recall_score_original 0.5161227661227662
# precision_score_original 0.5102707749766573
# f1_score_original 0.5053827751196173
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.4674630924630924
# precision_score_sog 0.5765856950067476
# f1_score_sog 0.4881796690307329
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.5901639344262295
# recall_score_original 0.6293206793206794
# precision_score_original 0.5967320261437908
# f1_score_original 0.6084819892869429
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.42579642579642574
# precision_score_sog 0.48067496229260936
# f1_score_sog 0.42616986510916427
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 27
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.4410242535242535
# precision_score_original 0.47894119769119764
# f1_score_original 0.45133300312907837
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.38324869574869574
# precision_score_sog 0.47484984984984985
# f1_score_sog 0.3904569089913918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.4426229508196721
# recall_score_original 0.39398101898101895
# precision_score_original 0.3884922947422947
# f1_score_original 0.3858665518882238
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5409836065573771
# recall_score_sog 0.4338092463092463
# precision_score_sog 0.4907407407407407
# f1_score_sog 0.43834234030312474
# neuron unit number: 37
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.41500860250860255
# precision_score_original 0.46069902319902317
# f1_score_original 0.4311339074636947
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.35841242091242087
# precision_score_sog 0.42406898656898656
# f1_score_sog 0.3716887122902161
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.6415501165501165
# precision_score_original 0.6383838383838384
# f1_score_original 0.6290897009966778
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.38157675657675655
# precision_score_sog 0.5370370370370371
# f1_score_sog 0.3949428903800721
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 47
# accuracy_score_orignial 0.5409836065573771
# recall_score_original 0.43614024864024864
# precision_score_original 0.4671717171717171
# f1_score_original 0.4434290925672595
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.3977480852480853
# precision_score_sog 0.4314814814814815
# f1_score_sog 0.38551587301587303
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 52
# accuracy_score_orignial 0.5737704918032787
# recall_score_original 0.4437784437784438
# precision_score_original 0.536553724053724
# f1_score_original 0.4757169485360975
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.5414585414585414
# precision_score_sog 0.6575
# f1_score_sog 0.5762656609947251
# neuron unit number: 57
# accuracy_score_orignial 0.6721311475409836
# recall_score_original 0.5527528027528027
# precision_score_original 0.5611111111111111
# f1_score_original 0.5546031746031745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.47540983606557374
# recall_score_sog 0.38996420246420244
# precision_score_sog 0.405119825708061
# f1_score_sog 0.3857591754650578
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 62
# accuracy_score_orignial 0.5573770491803278
# recall_score_original 0.5570263070263071
# precision_score_original 0.6465413533834586
# f1_score_original 0.5467349921984068
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.3622627372627372
# precision_score_sog 0.35212418300653586
# f1_score_sog 0.3457703634813609
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 67
# accuracy_score_orignial 0.5081967213114754
# recall_score_original 0.4065725940725941
# precision_score_original 0.41380471380471384
# f1_score_original 0.4044829949052715
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.4918032786885246
# recall_score_sog 0.36482961482961485
# precision_score_sog 0.44276819923371646
# f1_score_sog 0.3799763515371501
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5737704918032787
# recall_score_original 0.4899059274059274
# precision_score_original 0.502020202020202
# f1_score_original 0.48179240207103985
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.4288489288489288
# precision_score_sog 0.4736721611721612
# f1_score_sog 0.440107594994813
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 77
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6557377049180327
# recall_score_original 0.6877955377955378
# precision_score_original 0.6577777777777778
# f1_score_original 0.6678804855275444
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4732767232767233
# precision_score_sog 0.5281118881118881
# f1_score_sog 0.4887059355144462
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 82
# accuracy_score_orignial 0.6229508196721312
# recall_score_original 0.5062784437784438
# precision_score_original 0.5389291465378422
# f1_score_original 0.5078319426145513
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.5415501165501165
# precision_score_sog 0.5895970695970696
# f1_score_sog 0.5526330990661404
# Not good accuracy result !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.5737704918032787
# recall_score_original 0.4896839271839272
# precision_score_original 0.508876357560568
# f1_score_original 0.4913590569387671
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.4274059274059274
# precision_score_sog 0.4817587641117053
# f1_score_sog 0.4461368089275066
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 92
# accuracy_score_orignial 0.6065573770491803
# recall_score_original 0.5339035964035964
# precision_score_original 0.5185897435897436
# f1_score_original 0.5191387039213126
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.45689726939726943
# precision_score_sog 0.5035612535612536
# f1_score_sog 0.4608391329731602
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.5901639344262295
# recall_score_original 0.4720487845487846
# precision_score_original 0.5166666666666667
# f1_score_original 0.4871652218199533
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.5245901639344263
# recall_score_sog 0.38951326451326457
# precision_score_sog 0.5274698960043788
# f1_score_sog 0.4116110198868819
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.5836065573770491
# all_recall_score_original mean 0.521150863025863
# all_precision_score_original mean 0.5419277326548159
# all_f1_score_original mean 0.5196338548903151
# all_accuracy_score_sog mean 0.5278688524590165
# all_recall_score_sog mean 0.42146228771228766
# all_precision_score_sog mean 0.4871191304148722
# all_f1_score_sog mean 0.4282566542920396
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.583607  0.053294  0.011917   0.558664
# 1       all_accuracy_score_sog  20.0  0.527869  0.033045  0.007389   0.512403
# 2                     combined  40.0  0.555738  0.052079  0.008234   0.539082
#
#    Interval
# 0  0.608549
# 1  0.543334
# 2  0.572393
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...   0.0557
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    3.9751
# 3                           Two side test p value =    0.0003
# 4                          Difference < 0 p value =    0.9998
# 5                          Difference > 0 p value =    0.0002
# 6                                       Cohen's d =    1.2570
# 7                                       Hedge's g =    1.2321
# 8                                  Glass's delta1 =    1.0459
# 9                                Point-Biserial r =    0.5419
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.521151  0.086805  0.019410   0.480525
# 1       all_recall_score_sog  20.0  0.421462  0.055275  0.012360   0.395593
# 2                   combined  40.0  0.471307  0.087793  0.013881   0.443229
#
#    Interval
# 0  0.561777
# 1  0.447332
# 2  0.499384
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...   0.0997
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    4.3321
# 3                           Two side test p value =    0.0001
# 4                          Difference < 0 p value =    0.9999
# 5                          Difference > 0 p value =    0.0001
# 6                                       Cohen's d =    1.3699
# 7                                       Hedge's g =    1.3427
# 8                                  Glass's delta1 =    1.1484
# 9                                Point-Biserial r =    0.5750
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.541928  0.080626  0.018029
# 1       all_precision_score_sog  20.0  0.487119  0.076445  0.017094
# 2                      combined  40.0  0.514523  0.082366  0.013023
#
#    95% Conf.  Interval
# 0   0.504194  0.579662
# 1   0.451342  0.522897
# 2   0.488181  0.540865
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...   0.0548
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    2.2061
# 3                           Two side test p value =    0.0335
# 4                          Difference < 0 p value =    0.9833
# 5                          Difference > 0 p value =    0.0167
# 6                                       Cohen's d =    0.6976
# 7                                       Hedge's g =    0.6838
# 8                                  Glass's delta1 =    0.6798
# 9                                Point-Biserial r =    0.3370
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.519634  0.079387  0.017751   0.482480
# 1       all_f1_score_sog  20.0  0.428257  0.063362  0.014168   0.398602
# 2               combined  40.0  0.473945  0.084659  0.013386   0.446870
#
#    Interval
# 0  0.556788
# 1  0.457911
# 2  0.501021
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...   0.0914
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    4.0232
# 3                           Two side test p value =    0.0003
# 4                          Difference < 0 p value =    0.9999
# 5                          Difference > 0 p value =    0.0001
# 6                                       Cohen's d =    1.2723
# 7                                       Hedge's g =    1.2470
# 8                                  Glass's delta1 =    1.1510
# 9                                Point-Biserial r =    0.5465

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[1,2]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02234382538594245
# test_discrete_score_W_discrete_a 0.04032700754385205
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.01739318005978277
# test_discrete_score_W0_a 0.029175201704974632
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.03443300398952806
# test_discrete_score_W_discrete_a 0.02422357085425989
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.02334380379895585
# test_discrete_score_W0_a 0.037353108504030286
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.053434189827062516
# test_discrete_score_W_discrete_a 0.05456195729343344
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.476
# test_discrete_score_W0_n 0.033922299757219505
# test_discrete_score_W0_a 0.052561119522969935
# test_discrete_score_W_discrete_p 0.46
# test_discrete_score_W_discrete_n 0.031134181280268396
# test_discrete_score_W_discrete_a 0.044253704350719236
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.030552889554805434
# test_discrete_score_W0_a 0.042998231189427
# test_discrete_score_W_discrete_p 0.4746666666666667
# test_discrete_score_W_discrete_n 0.03376967607150299
# test_discrete_score_W_discrete_a 0.04632683501465729
# Not good purity result for discrete features !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03342601353355848
# test_discrete_score_W0_a 0.04798282495417882
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.05507820220623584
# test_discrete_score_W_discrete_a 0.06572394767970656
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.027459821320045832
# test_discrete_score_W0_a 0.04253570431171219
# test_discrete_score_W_discrete_p 0.49333333333333335
# test_discrete_score_W_discrete_n 0.04397362826092439
# test_discrete_score_W_discrete_a 0.06267067104557747
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.024786498576812546
# test_discrete_score_W0_a 0.03788888448751348
# test_discrete_score_W_discrete_p 0.49066666666666664
# test_discrete_score_W_discrete_n 0.03958278449072278
# test_discrete_score_W_discrete_a 0.05649455222149977
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.016522062383778145
# test_discrete_score_W0_a 0.028494233453073153
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.05119010651141663
# test_discrete_score_W_discrete_a 0.07210828379153088
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.017426370665438014
# test_discrete_score_W0_a 0.023699636325396987
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032538084155730576
# test_discrete_score_W_discrete_a 0.04820567242261783
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.036857456552891944
# test_discrete_score_W0_a 0.05578198334814375
# test_discrete_score_W_discrete_p 0.5213333333333333
# test_discrete_score_W_discrete_n 0.06132297519620123
# test_discrete_score_W_discrete_a 0.08512012645846712
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4866666666666667
# test_discrete_score_W0_n 0.03759457527631816
# test_discrete_score_W0_a 0.055163595305752385
# test_discrete_score_W_discrete_p 0.556
# test_discrete_score_W_discrete_n 0.09577315053890768
# test_discrete_score_W_discrete_a 0.11281183908452129
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03093370149562325
# test_discrete_score_W0_a 0.044458312234050626
# test_discrete_score_W_discrete_p 0.516
# test_discrete_score_W_discrete_n 0.05804740739737212
# test_discrete_score_W_discrete_a 0.08513700710052961
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.02054779399772174
# test_discrete_score_W0_a 0.03101276852118271
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.04653708967400014
# test_discrete_score_W_discrete_a 0.06827491998098022
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5146666666666667
# test_discrete_score_W0_n 0.05443083282314605
# test_discrete_score_W0_a 0.07036287681764777
# test_discrete_score_W_discrete_p 0.544
# test_discrete_score_W_discrete_n 0.08269977748474737
# test_discrete_score_W_discrete_a 0.09852532914984698
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.02892604535266786
# test_discrete_score_W0_a 0.047155247862443884
# test_discrete_score_W_discrete_p 0.524
# test_discrete_score_W_discrete_n 0.06372742679275416
# test_discrete_score_W_discrete_a 0.07877786447256512
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.524
# test_discrete_score_W0_n 0.05945259033535872
# test_discrete_score_W0_a 0.07960516206945854
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.0541905060530825
# test_discrete_score_W_discrete_a 0.07125467232825451
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.022448343490384687
# test_discrete_score_W0_a 0.03397696731084315
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.03841331757870813
# test_discrete_score_W_discrete_a 0.0518461718393148
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.5226666666666666
# test_discrete_score_W0_n 0.058074070778292367
# test_discrete_score_W0_a 0.0763494609595373
# test_discrete_score_W_discrete_p 0.5146666666666667
# test_discrete_score_W_discrete_n 0.05986941507524195
# test_discrete_score_W_discrete_a 0.08647900509679979
# Not good purity result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.46993333333333326
# test_discrete_score_W_discrete_p mean 0.49493333333333334
# test_discrete_score_W0_n mean 0.029605726327701958
# test_discrete_score_W_discrete_n mean 0.04883370954923206
# test_discrete_score_W0_a mean 0.04282968855928333
# test_discrete_score_W_discrete_a mean 0.06369091609333
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.029606  0.014779  0.003305   0.022689  0.036523
# 1  test_dis_W_dis  20.0  0.048834  0.019029  0.004255   0.039928  0.057740
# 2        combined  40.0  0.039220  0.019433  0.003073   0.033005  0.045435
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0192
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.5689
# 3                      Two side test p value =    0.0010
# 4                     Difference < 0 p value =    0.0005
# 5                     Difference > 0 p value =    0.9995
# 6                                  Cohen's d =   -1.1286
# 7                                  Hedge's g =   -1.1062
# 8                             Glass's delta1 =   -1.3010
# 9                           Point-Biserial r =   -0.5010
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.042830  0.019305  0.004317   0.033795  0.051865
# 1  test_dis_W_dis  20.0  0.063691  0.023612  0.005280   0.052640  0.074742
# 2        combined  40.0  0.053260  0.023765  0.003758   0.045660  0.060861
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0209
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.0589
# 3                      Two side test p value =    0.0041
# 4                     Difference < 0 p value =    0.0020
# 5                     Difference > 0 p value =    0.9980
# 6                                  Cohen's d =   -0.9673
# 7                                  Hedge's g =   -0.9481
# 8                             Glass's delta1 =   -1.0806
# 9                           Point-Biserial r =   -0.4445
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.469933  0.028203  0.006306   0.456734  0.483133
# 1  test_dis_W_dis  20.0  0.494933  0.030892  0.006908   0.480475  0.509391
# 2        combined  40.0  0.482433  0.031823  0.005032   0.472256  0.492611
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0250
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.6728
# 3                      Two side test p value =    0.0110
# 4                     Difference < 0 p value =    0.0055
# 5                     Difference > 0 p value =    0.9945
# 6                                  Cohen's d =   -0.8452
# 7                                  Hedge's g =   -0.8284
# 8                             Glass's delta1 =   -0.8864
# 9                           Point-Biserial r =   -0.3978

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.428
# test_discrete_score_W_discrete_n 0.02345171762930623
# test_discrete_score_W_discrete_a 0.01923792963102035
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.018856935362735645
# test_discrete_score_W_discrete_a 0.029045041233303804
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.026855580654044465
# test_discrete_score_W0_a 0.03604144266742046
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01810404796207701
# test_discrete_score_W_discrete_a 0.03346196864130828
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024682167696410937
# test_discrete_score_W0_a 0.032188349757317845
# test_discrete_score_W_discrete_p 0.44666666666666666
# test_discrete_score_W_discrete_n 0.01797489888334447
# test_discrete_score_W_discrete_a 0.0285471281012557
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024203462603534617
# test_discrete_score_W0_a 0.03846988685325159
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01838925770914136
# test_discrete_score_W_discrete_a 0.032019100024307974
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.03349335568258328
# test_discrete_score_W0_a 0.04667109658886825
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.01605391401844283
# test_discrete_score_W_discrete_a 0.026793244224623227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48533333333333334
# test_discrete_score_W0_n 0.035485179839995426
# test_discrete_score_W0_a 0.04981859509745033
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02068810713236546
# test_discrete_score_W_discrete_a 0.03309157601901982
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02390083884461625
# test_discrete_score_W0_a 0.03873861993122384
# test_discrete_score_W_discrete_p 0.4573333333333333
# test_discrete_score_W_discrete_n 0.023235517855302763
# test_discrete_score_W_discrete_a 0.03744560308797647
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.026985376253148303
# test_discrete_score_W0_a 0.03978610299904206
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.026305260920569878
# test_discrete_score_W_discrete_a 0.041094189990076725
# Not good nmi result for discrete features !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.018162904680171798
# test_discrete_score_W0_a 0.03022682699783115
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03400184259136679
# test_discrete_score_W_discrete_a 0.05029641376853773
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.033072619927399426
# test_discrete_score_W0_a 0.047156111573114626
# test_discrete_score_W_discrete_p 0.4786666666666667
# test_discrete_score_W_discrete_n 0.03499390650337792
# test_discrete_score_W_discrete_a 0.051949215378023175
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.023824261795553792
# test_discrete_score_W0_a 0.037597994770207366
# test_discrete_score_W_discrete_p 0.468
# test_discrete_score_W_discrete_n 0.028031643322058132
# test_discrete_score_W_discrete_a 0.044080209705631444
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.028791201469484017
# test_discrete_score_W0_a 0.04599112596540657
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032429275622864545
# test_discrete_score_W_discrete_a 0.04740265300888458
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.4706666666666667
# test_discrete_score_W0_n 0.028197704700882276
# test_discrete_score_W0_a 0.042188175616839595
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03430876326213519
# test_discrete_score_W_discrete_a 0.05324336208092509
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.021944285346807382
# test_discrete_score_W0_a 0.031945508345160974
# test_discrete_score_W_discrete_p 0.48533333333333334
# test_discrete_score_W_discrete_n 0.03869110510763206
# test_discrete_score_W_discrete_a 0.05802214839446757
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5106666666666667
# test_discrete_score_W0_n 0.05054444015796348
# test_discrete_score_W0_a 0.06925893080150226
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.028500768616768247
# test_discrete_score_W_discrete_a 0.03993660270160838
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.03193530568800679
# test_discrete_score_W0_a 0.04764998062763653
# test_discrete_score_W_discrete_p 0.504
# test_discrete_score_W_discrete_n 0.047939169427930486
# test_discrete_score_W_discrete_a 0.06706429938523999
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.025557559612347378
# test_discrete_score_W0_a 0.038599165108127206
# test_discrete_score_W_discrete_p 0.4693333333333333
# test_discrete_score_W_discrete_n 0.02610302923188745
# test_discrete_score_W_discrete_a 0.041979976747958815
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02431624127598852
# test_discrete_score_W0_a 0.039038707645552506
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.02710259286982934
# test_discrete_score_W_discrete_a 0.03850236196126793
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.49333333333333335
# test_discrete_score_W0_n 0.043797733013326734
# test_discrete_score_W0_a 0.06109381550919402
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03414668262562054
# test_discrete_score_W_discrete_a 0.047714667147608227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.46453333333333335
# test_discrete_score_W_discrete_p mean 0.46593333333333337
# test_discrete_score_W0_n mean 0.02718831980217513
# test_discrete_score_W_discrete_n mean 0.027465421832737813
# test_discrete_score_W0_a mean 0.03962494445792386
# test_discrete_score_W_discrete_a mean 0.04104638456165226
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.027188  0.010186  0.002278   0.022421  0.031956
# 1  test_dis_W_dis  20.0  0.027465  0.008303  0.001857   0.023580  0.031351
# 2        combined  40.0  0.027327  0.009173  0.001450   0.024393  0.030261
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0003
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.0943
# 3                      Two side test p value =    0.9254
# 4                     Difference < 0 p value =    0.4627
# 5                     Difference > 0 p value =    0.5373
# 6                                  Cohen's d =   -0.0298
# 7                                  Hedge's g =   -0.0292
# 8                             Glass's delta1 =   -0.0272
# 9                           Point-Biserial r =   -0.0153
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.039625  0.014212  0.003178   0.032973  0.046276
# 1  test_dis_W_dis  20.0  0.041046  0.011732  0.002623   0.035556  0.046537
# 2        combined  40.0  0.040336  0.012883  0.002037   0.036215  0.044456
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.3449
# 3                      Two side test p value =    0.7320
# 4                     Difference < 0 p value =    0.3660
# 5                     Difference > 0 p value =    0.6340
# 6                                  Cohen's d =   -0.1091
# 7                                  Hedge's g =   -0.1069
# 8                             Glass's delta1 =   -0.1000
# 9                           Point-Biserial r =   -0.0559
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.464533  0.020521  0.004589   0.454929  0.474138
# 1  test_dis_W_dis  20.0  0.465933  0.017670  0.003951   0.457664  0.474203
# 2        combined  40.0  0.465233  0.018915  0.002991   0.459184  0.471283
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.2312
# 3                      Two side test p value =    0.8184
# 4                     Difference < 0 p value =    0.4092
# 5                     Difference > 0 p value =    0.5908
# 6                                  Cohen's d =   -0.0731
# 7                                  Hedge's g =   -0.0717
# 8                             Glass's delta1 =   -0.0682
# 9                           Point-Biserial r =   -0.0375

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
