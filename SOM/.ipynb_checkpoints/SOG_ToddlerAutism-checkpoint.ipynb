# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.sample(int(csv.shape[0]*0.1))
csv_original_encode = csv


# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode,"Class/ASD Traits ")

dataread.baseN_encoding(csv_original_encode,["Sex","Ethnicity","Jaundice","Family_mem_with_ASD","Who completed the test"])


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Class/ASD Traits ")
# Out:
# self.data_continuous_indexes ['Case_No', 'Age_Mons']
# self.continuous_feature_num 2
#  column number self.data_train_discrete 16

# %%
# compare fuzzy with probability
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 47
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 47
# train_discrete_score_W0_p 0.9459459459459459
# train_discrete_score_W0_n 0.6484271619961154
# train_discrete_score_W0_a  0.7785160446130795
# test_discrete_score_W0_p 0.9354838709677419
# test_discrete_score_W0_n 0.6269821441016398
# test_discrete_score_W0_a 0.7481792717086835
# train_discrete_score_W_discrete_p 0.8378378378378378
# train_discrete_score_W_discrete_n 0.2589903923992244
# train_discrete_score_W_discrete_a 0.41148548997189716
# test_discrete_score_W_discrete_p 0.8709677419354839
# test_discrete_score_W_discrete_n 0.5444848391073066
# test_discrete_score_W_discrete_a 0.5365448504983389
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 52
# train_discrete_score_W0_p 0.918918918918919
# train_discrete_score_W0_n 0.5568762676224931
# train_discrete_score_W0_a  0.6820966926756994
# test_discrete_score_W0_p 0.9354838709677419
# test_discrete_score_W0_n 0.7010919626146087
# test_discrete_score_W0_a 0.7500695023630803
# train_discrete_score_W_discrete_p 0.8648648648648649
# train_discrete_score_W_discrete_n 0.30535619251189877
# train_discrete_score_W_discrete_a 0.47498028867822983
# test_discrete_score_W_discrete_p 0.8064516129032258
# test_discrete_score_W_discrete_n 0.23483326155226558
# test_discrete_score_W_discrete_a 0.3415463041631266
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 57
# train_discrete_score_W0_p 0.9324324324324325
# train_discrete_score_W0_n 0.5719013670359432
# train_discrete_score_W0_a  0.7248250561884353
# test_discrete_score_W0_p 0.967741935483871
# test_discrete_score_W0_n 0.8141131499687284
# test_discrete_score_W0_a 0.8702928870292888
# train_discrete_score_W_discrete_p 0.9324324324324325
# train_discrete_score_W_discrete_n 0.5994115814534928
# train_discrete_score_W_discrete_a 0.7292178644812192
# test_discrete_score_W_discrete_p 0.967741935483871
# test_discrete_score_W_discrete_n 0.8082501000608955
# test_discrete_score_W_discrete_a 0.8690878378378378
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 62
# train_discrete_score_W0_p 0.9594594594594594
# train_discrete_score_W0_n 0.7064019448261033
# train_discrete_score_W0_a  0.8301093825163383
# test_discrete_score_W0_p 0.967741935483871
# test_discrete_score_W0_n 0.8141131499687284
# test_discrete_score_W0_a 0.8702928870292888
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 12
#       8 interval = 5
#      11 experiment = experiment.Experiment()
# ---> 12 experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
#
# File C:\JupyterDoc\SOM\experiment.py:309, in Experiment.UTtest_Discrete_Continuous(self, dataread, noralimized, class_num, best_num, neuron_scope_num, unstable_repeat_num, type, interval, test_type, compareType)
#     307 while y <= neuron_scope_num:
#     308     print("neuron unit number: {}".format(y))
# --> 309     self.InitializedExperimentDataList(
#     310                         dataread,
#     311                         noralimized,
#     312                         y,
#     313                         all_train_score_W0_p,
#     314                         all_train_score_W_combine_p,
#     315                         test_score_W0_p,
#     316                         test_score_W_combine_p,
#     317                         all_train_score_W0_n,
#     318                         all_train_score_W_combine_n,
#     319                         test_score_W0_n,
#     320                         test_score_W_combine_n,
#     321                         all_train_score_W0_a,
#     322                         all_train_score_W_combine_a,
#     323                         test_score_W0_a,
#     324                         test_score_W_combine_a,
#     325                         train_discrete_score_W0_p,
#     326                         train_discrete_score_W_discrete_p,
#     327                         test_discrete_score_W0_p,
#     328                         test_discrete_score_W_discrete_p,
#     329                         train_discrete_score_W0_n,
#     330                         train_discrete_score_W_discrete_n,
#     331                         test_discrete_score_W0_n,
#     332                         test_discrete_score_W_discrete_n,
#     333                         train_discrete_score_W0_a,
#     334                         train_discrete_score_W_discrete_a,
#     335                         test_discrete_score_W0_a,
#     336                         test_discrete_score_W_discrete_a,
#     337                         test_type,
#     338                         compareType
#     339                         )
#     340     y =y + interval
#     341     if(y<= neuron_scope_num):
#
# File C:\JupyterDoc\SOM\experiment.py:200, in Experiment.InitializedExperimentDataList(self, dataread, continuous_features_noralimized, y, all_train_score_W0_p, all_train_score_W_combine_p, test_score_W0_p, test_score_W_combine_p, all_train_score_W0_n, all_train_score_W_combine_n, test_score_W0_n, test_score_W_combine_n, all_train_score_W0_a, all_train_score_W_combine_a, test_score_W0_a, test_score_W_combine_a, train_discrete_score_W0_p, train_discrete_score_W_discrete_p, test_discrete_score_W0_p, test_discrete_score_W_discrete_p, train_discrete_score_W0_n, train_discrete_score_W_discrete_n, test_discrete_score_W0_n, test_discrete_score_W_discrete_n, train_discrete_score_W0_a, train_discrete_score_W_discrete_a, test_discrete_score_W0_a, test_discrete_score_W_discrete_a, iscontinous_data_test, compareType)
#     198     optimize_W.do_COSOM(optimize_W.som_discrete_original,optimize_W.data_train_discrete_normalized, optimize_W.data_train_discrete_unnormalized, optimize_W.data_test_discrete_normalized,optimize_W.data_test_discrete_unnormalized,iscontinous_data_test,1)
#     199 if compareType == 3: #discrete unnormalization
# --> 200      optimize_W.do_DOSOM(True)
#     201 if compareType == 4: # hybrid embedding continous + discrete_embedding
#     202      optimize_W.do_CDOSOM()
#
# File C:\JupyterDoc\SOM\CDSOM.py:1241, in CDSOM.do_DOSOM(self, fuzzy_set_no_probability)
#    1239 else:
#    1240     self.som_sog = newSom.SOM(self.som_sog_fuzzy.weights0.shape[0] , self.som_sog_fuzzy.weights0.shape[1],dim)
# -> 1241 self.som_sog.fit(self.discrete_data_embedding_sog)
#    1243 weight_sog = self.som_sog.weights0
#    1245 self.train_W_baseline_predicted_label = self.som_sog.predict(self.discrete_data_embedding_sog,weight_sog)
#
# File C:\JupyterDoc\SOM\newSom.py:364, in SOM.fit(self, X, weightIndex, epochs, shuffle, showlog)
#     359 input = X[idx]
#     361 #if (type(input) is np.float64):
#     362 #    input = [input]
#     363 # Do one step of training
# --> 364 self.step(input,showlog)
#     365 # Update learning rate
#     366 global_iter_counter += 1
#
# File C:\JupyterDoc\SOM\newSom.py:177, in SOM.step(self, x, showlog)
#     168 x_stack = np.stack([x]*(self.m*self.n), axis=0)
#     169 #print("x_stack {}".format(x_stack))
#     170 #print("self.weights{}".format(self.weights));
#     171 #print("x_stack{}".format(x_stack));
#    (...)
#     175 #if showlog == True:
#     176 #    print("x {} {}".format(x, self.weights.shape) )
# --> 177 bmu_index = self._find_bmu(x,self.weights,showlog)
#     179 #print("bmu_index{}".format(bmu_index));
#     180 # Find location of best matching unit, _locations is all the indices for a given matrix for array
#     181 # bmu_location is the bmu_indexth element in _locations, such as if bmu_index = 4 in [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1]] it return [2,0]
#     182 bmu_location = self._locations[bmu_index,:]
#
# File C:\JupyterDoc\SOM\newSom.py:127, in SOM._find_bmu(self, x, newWeights, showlog)
#     121  x_stack = np.stack([x]*(newWeights.shape[0]), axis=0)
#     122  # Calculate distance between x and each weight  ， it use the norm to represent the distance of the concept of vector x_stack - newWeights
#     123 # if showlog:
#     124  #    print("x {} x_stack{}  newWeights {} m {} n{} dim{}".format(x, x_stack, newWeights, self.m,self.n,self.dim))
#     125 # if x_stack.shape != newWeights.shape:
#     126  #    print("x {} x_stack{}  newWeights {} m {} n{} dim{}".format(x, x_stack, newWeights, self.m,self.n,self.dim))
# --> 127  distance = np.linalg.norm((x_stack - newWeights).astype(float), axis=1)
#     128  # Find index of best matching unit
#     129  return np.argmin(distance)
#
# MemoryError: Unable to allocate 8.18 GiB for an array with shape (1107072, 992) and data type float64

# %%
train_discrete_score_W0_n = [0.8387096774193549,
                            0.8387096774193549,
                             0.8709677419354839,
                             0.8709677419354839,
                             0.9032258064516129,
                             0.9032258064516129,
                             0.9354838709677419,
                             1,
                             0.967741935483871,
                             0.9354838709677419,
                             0.9354838709677419,
                            ]

train_discrete_score_W_discrete_n = [0.8387096774193549,
                            0.8387096774193549,
                            0.9032258064516129,
                            0.967741935483871,
                             0.8387096774193549,
                             0.8387096774193549,
                             0.8387096774193549,
                            0.8709677419354839,
                            0.8387096774193549,
                             0.8064516129032258,
                             0.967741935483871,
                            ]
                df1_n = pd.DataFrame(train_discrete_score_W0_n, columns = ['train_dis_W0'])
                df2_n = pd.DataFrame(train_discrete_score_W_discrete_n, columns = ['train_dis_W_dis'])

                df3_n = pd.DataFrame(test_discrete_score_W0_n, columns = ['test_dis_W0'])
                df4_n = pd.DataFrame(test_discrete_score_W_discrete_n, columns = ['test_dis_W_dis'])

                print("NMI T-Test")

                summary, results = rp.ttest(group1= df1_n['train_dis_W0'], group1_name= "train_dis_W0",
                                            group2= df2_n['train_dis_W_dis'], group2_name= "train_dis_W_dis")
               
                print(summary)
                print(results)

                
                summary1, results1 = rp.ttest(group1= df3_n['test_dis_W0'], group1_name= "test_dis_W0",
                                            group2= df4_n['test_dis_W_dis'], group2_name= "test_dis_W_dis")
        
                print(summary1)
                print(results1)


                df1_a = pd.DataFrame(train_discrete_score_W0_a, columns = ['train_dis_W0'])
                df2_a = pd.DataFrame(train_discrete_score_W_discrete_a, columns = ['train_dis_W_dis'])

                df3_a = pd.DataFrame(test_discrete_score_W0_a, columns = ['test_dis_W0'])
                df4_a = pd.DataFrame(test_discrete_score_W_discrete_a, columns = ['test_dis_W_dis'])



                print("ARI T-Test")

                summary, results = rp.ttest(group1= df1_a['train_dis_W0'], group1_name= "train_dis_W0",
                                            group2= df2_a['train_dis_W_dis'], group2_name= "train_dis_W_dis")
               
                print(summary)
                print(results)

                
                summary1, results1 = rp.ttest(group1= df3_a['test_dis_W0'], group1_name= "test_dis_W0",
                                            group2= df4_a['test_dis_W_dis'], group2_name= "test_dis_W_dis")
        
                print(summary1)
                print(results1)
                
                df1_p = pd.DataFrame(train_discrete_score_W0_p, columns = ['train_dis_W0'])
                df2_p = pd.DataFrame(train_discrete_score_W_discrete_p, columns = ['train_dis_W_dis'])

                df3_p = pd.DataFrame(test_discrete_score_W0_p, columns = ['test_dis_W0'])
                df4_p = pd.DataFrame(test_discrete_score_W_discrete_p, columns = ['test_dis_W_dis'])
                

                print("Purity T-Test")

                summary, results = rp.ttest(group1= df1_p['train_dis_W0'], group1_name= "train_dis_W0",
                                            group2= df2_p['train_dis_W_dis'], group2_name= "train_dis_W_dis")
               
                print(summary)
                print(results)

                
                summary1, results1 = rp.ttest(group1= df3_p['test_dis_W0'], group1_name= "test_dis_W0",
                                            group2= df4_p['test_dis_W_dis'], group2_name= "test_dis_W_dis")
        
                print(summary1)
                print(results1)

# %%
#new binary encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 2
# all_train_score_W0_p 0.6951219512195121
# all_train_score_W0_n 0.009882250026559278
# all_train_score_W0_a 0.013640338398397166
# test_score_W0_p0.6930379746835443
# test_score_W0_n 0.010090334231688732
# test_score_W0_a  0.023532092406543265
# all_train_score_W_combine_p 0.7574525745257452
# all_train_score_W_combine_n 0.12377050534738604
# all_train_score_W_combine_a 0.21180755322020944
# test_score_W_combine_p0.7626582278481012
# test_score_W_combine_n 0.14740908946559855
# test_score_W_combine_a 0.2537941872763043
# neuron unit number: 7
# all_train_score_W0_p 0.7086720867208672
# all_train_score_W0_n 0.04224962667525039
# all_train_score_W0_a 0.09905950740171235
# test_score_W0_p0.7215189873417721
# test_score_W0_n 0.07690996637088114
# test_score_W0_a  0.16042545133321023
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10863451927545542
# all_train_score_W_combine_a 0.1903769955245221
# test_score_W_combine_p0.7689873417721519
# test_score_W_combine_n 0.1631271659168738
# test_score_W_combine_a 0.27103796282269793
# neuron unit number: 12
# all_train_score_W0_p 0.7032520325203252
# all_train_score_W0_n 0.027700545770414364
# all_train_score_W0_a 0.05907600475671342
# test_score_W0_p0.7215189873417721
# test_score_W0_n 0.07447822883265752
# test_score_W0_a  0.15699152872899733
# all_train_score_W_combine_p 0.7533875338753387
# all_train_score_W_combine_n 0.11655155943737376
# all_train_score_W_combine_a 0.19871018520376196
# test_score_W_combine_p0.7689873417721519
# test_score_W_combine_n 0.1631271659168738
# test_score_W_combine_a 0.27103796282269793
# neuron unit number: 17
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.04687699647507626
# all_train_score_W0_a 0.10361681110363066
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.10663472965138326
# test_score_W0_a  0.19786890006704502
# all_train_score_W_combine_p 0.7615176151761518
# all_train_score_W_combine_n 0.13519673453416547
# all_train_score_W_combine_a 0.21296566012099485
# test_score_W_combine_p0.7753164556962026
# test_score_W_combine_n 0.17076009904437406
# test_score_W_combine_a 0.28300639510889214
# neuron unit number: 22
# all_train_score_W0_p 0.7249322493224932
# all_train_score_W0_n 0.0662028216641249
# all_train_score_W0_a 0.1331466714242788
# test_score_W0_p0.7563291139240507
# test_score_W0_n 0.14598876591395293
# test_score_W0_a  0.24589143706569708
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.11098654863845425
# all_train_score_W_combine_a 0.19565303234210257
# test_score_W_combine_p0.7563291139240507
# test_score_W_combine_n 0.12464200659339392
# test_score_W_combine_a 0.224303727426833
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 27
# all_train_score_W0_p 0.7195121951219512
# all_train_score_W0_n 0.05596867494842085
# all_train_score_W0_a 0.10862582614466147
# test_score_W0_p0.740506329113924
# test_score_W0_n 0.10656846283397182
# test_score_W0_a  0.20167577850062834
# all_train_score_W_combine_p 0.7533875338753387
# all_train_score_W_combine_n 0.11731615766523633
# all_train_score_W_combine_a 0.19581010643953337
# test_score_W_combine_p0.7753164556962026
# test_score_W_combine_n 0.16515415976156617
# test_score_W_combine_a 0.2782245038685445
# neuron unit number: 32
# all_train_score_W0_p 0.7086720867208672
# all_train_score_W0_n 0.039056152059549085
# all_train_score_W0_a 0.08685063768985993
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.1302952699089386
# test_score_W0_a  0.22581102380950843
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10874784570551282
# all_train_score_W_combine_a 0.18941434233848964
# test_score_W_combine_p0.7974683544303798
# test_score_W_combine_n 0.20562408426609047
# test_score_W_combine_a 0.3264506470227929
# neuron unit number: 37
# all_train_score_W0_p 0.7100271002710027
# all_train_score_W0_n 0.04383633829792945
# all_train_score_W0_a 0.10095411090038646
# test_score_W0_p0.7310126582278481
# test_score_W0_n 0.08653817990071343
# test_score_W0_a  0.1741473832343238
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.10147231283576806
# all_train_score_W_combine_a 0.18779952220771515
# test_score_W_combine_p0.7531645569620253
# test_score_W_combine_n 0.12840716719333267
# test_score_W_combine_a 0.23039209443885542
# neuron unit number: 42
# all_train_score_W0_p 0.7140921409214093
# all_train_score_W0_n 0.053214146261781
# all_train_score_W0_a 0.12104312891331216
# test_score_W0_p0.7246835443037974
# test_score_W0_n 0.08558665588587148
# test_score_W0_a  0.1718514620959998
# all_train_score_W_combine_p 0.7588075880758808
# all_train_score_W_combine_n 0.1263541067136262
# all_train_score_W_combine_a 0.21525554422846266
# test_score_W_combine_p0.7689873417721519
# test_score_W_combine_n 0.1539262284324789
# test_score_W_combine_a 0.2639508177133723
# neuron unit number: 47
# all_train_score_W0_p 0.7276422764227642
# all_train_score_W0_n 0.07633503297363874
# all_train_score_W0_a 0.1589797087105237
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.1501040073844464
# test_score_W0_a  0.2520547179176607
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.10430099979811244
# all_train_score_W_combine_a 0.19375243362590613
# test_score_W_combine_p0.7689873417721519
# test_score_W_combine_n 0.15810140093710337
# test_score_W_combine_a 0.26766556503979877
# neuron unit number: 52
# all_train_score_W0_p 0.7235772357723578
# all_train_score_W0_n 0.06349966060100458
# all_train_score_W0_a 0.12660998274456464
# test_score_W0_p0.7310126582278481
# test_score_W0_n 0.10491926214216277
# test_score_W0_a  0.19312421218916928
# all_train_score_W_combine_p 0.7520325203252033
# all_train_score_W_combine_n 0.11350065863226562
# all_train_score_W_combine_a 0.2035373179450938
# test_score_W_combine_p0.7626582278481012
# test_score_W_combine_n 0.1506944032673372
# test_score_W_combine_a 0.2561232141374297
# neuron unit number: 57
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.05129377931976669
# all_train_score_W0_a 0.11803516488193147
# test_score_W0_p0.7531645569620253
# test_score_W0_n 0.14197952599057911
# test_score_W0_a  0.23980974457753385
# all_train_score_W_combine_p 0.7411924119241192
# all_train_score_W_combine_n 0.09769860112134231
# all_train_score_W_combine_a 0.18924808832253318
# test_score_W_combine_p0.7531645569620253
# test_score_W_combine_n 0.13134451378889667
# test_score_W_combine_a 0.2329836079017576
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 62
# all_train_score_W0_p 0.7086720867208672
# all_train_score_W0_n 0.04296956377768188
# all_train_score_W0_a 0.10136235309202662
# test_score_W0_p0.7373417721518988
# test_score_W0_n 0.11193139073175014
# test_score_W0_a  0.20410328288817448
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10846344018330102
# all_train_score_W_combine_a 0.19413129723062458
# test_score_W_combine_p0.7531645569620253
# test_score_W_combine_n 0.146165275745967
# test_score_W_combine_a 0.24177787369373172
# neuron unit number: 67
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.06479370220098454
# all_train_score_W0_a 0.14372965354427905
# test_score_W0_p0.7310126582278481
# test_score_W0_n 0.11658796479177051
# test_score_W0_a  0.19949152504858247
# all_train_score_W_combine_p 0.7520325203252033
# all_train_score_W_combine_n 0.11344935267185173
# all_train_score_W_combine_a 0.2026569625455491
# test_score_W_combine_p0.7753164556962026
# test_score_W_combine_n 0.16298269111054
# test_score_W_combine_a 0.2756047385180887
# neuron unit number: 72
# all_train_score_W0_p 0.7195121951219512
# all_train_score_W0_n 0.057781256078383504
# all_train_score_W0_a 0.12156561665539856
# test_score_W0_p0.7278481012658228
# test_score_W0_n 0.08392873112220915
# test_score_W0_a  0.17063985913477603
# all_train_score_W_combine_p 0.7520325203252033
# all_train_score_W_combine_n 0.1142636562079559
# all_train_score_W_combine_a 0.20862886790613355
# test_score_W_combine_p0.759493670886076
# test_score_W_combine_n 0.1463873717110186
# test_score_W_combine_a 0.24989609653346942
# neuron unit number: 77
# all_train_score_W0_p 0.7222222222222222
# all_train_score_W0_n 0.06062476039649444
# all_train_score_W0_a 0.1126749515512699
# test_score_W0_p0.7120253164556962
# test_score_W0_n 0.068683319338846
# test_score_W0_a  0.1473415936279314
# all_train_score_W_combine_p 0.7574525745257452
# all_train_score_W_combine_n 0.12432701851092759
# all_train_score_W_combine_a 0.2090676593990389
# test_score_W_combine_p0.7753164556962026
# test_score_W_combine_n 0.17241978164488586
# test_score_W_combine_a 0.28410862018924427
# neuron unit number: 82
# all_train_score_W0_p 0.7262872628726287
# all_train_score_W0_n 0.06877848755761802
# all_train_score_W0_a 0.13848893918453126
# test_score_W0_p0.7563291139240507
# test_score_W0_n 0.1387334638143777
# test_score_W0_a  0.24145827474498088
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10893188031766016
# all_train_score_W_combine_a 0.19948021314768796
# test_score_W_combine_p0.7974683544303798
# test_score_W_combine_n 0.21208702517767639
# test_score_W_combine_a 0.334706273053482
# neuron unit number: 87
# all_train_score_W0_p 0.7100271002710027
# all_train_score_W0_n 0.04560262180523519
# all_train_score_W0_a 0.10663961855150823
# test_score_W0_p0.7341772151898734
# test_score_W0_n 0.11387060465773424
# test_score_W0_a  0.20197222055198125
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.10358699144290279
# all_train_score_W_combine_a 0.18458408179326705
# test_score_W_combine_p0.7563291139240507
# test_score_W_combine_n 0.1280289196102361
# test_score_W_combine_a 0.23069035907434723
# neuron unit number: 92
# all_train_score_W0_p 0.7303523035230353
# all_train_score_W0_n 0.07600075665300343
# all_train_score_W0_a 0.1511561205899591
# test_score_W0_p0.7658227848101266
# test_score_W0_n 0.14912222445911683
# test_score_W0_a  0.25758789200662696
# all_train_score_W_combine_p 0.7425474254742548
# all_train_score_W_combine_n 0.09632748349110304
# all_train_score_W_combine_a 0.1774645421291099
# test_score_W_combine_p0.7721518987341772
# test_score_W_combine_n 0.15333229330673867
# test_score_W_combine_a 0.26029790832372124
# neuron unit number: 97
# all_train_score_W0_p 0.7032520325203252
# all_train_score_W0_n 0.03479151724702808
# all_train_score_W0_a 0.08694287140689748
# test_score_W0_p0.7436708860759493
# test_score_W0_n 0.10932451467062228
# test_score_W0_a  0.20581132519856735
# all_train_score_W_combine_p 0.7520325203252033
# all_train_score_W_combine_n 0.11344935267185173
# all_train_score_W_combine_a 0.2026569625455491
# test_score_W_combine_p0.7753164556962026
# test_score_W_combine_n 0.1677498150160613
# test_score_W_combine_a 0.28069073956468843
# test_score_W0_p mean 0.7367088607594937
# test_score_W_combine_p mean 0.7688291139240507
# test_score_W0_n mean 0.1056137801316837
# test_score_W_combine_n mean 0.15757353289535217
# test_score_W0_a mean 0.19357948525639687
# test_score_W_combine_a mean 0.2658371647265375
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.051373  0.016549  0.003700   0.043628  0.059118
# 1  train_W_combine  20.0  0.112366  0.009810  0.002194   0.107775  0.116958
# 2         combined  40.0  0.081870  0.033678  0.005325   0.071099  0.092640
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0610
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -14.1788
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.4837
# 7                                Hedge's g =   -4.3946
# 8                           Glass's delta1 =   -3.6856
# 9                         Point-Biserial r =   -0.9171
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.105614  0.034254  0.007659   0.089583  0.121645
# 1  test_W_combine  20.0  0.157574  0.022781  0.005094   0.146912  0.168235
# 2        combined  40.0  0.131594  0.038945  0.006158   0.119138  0.144049
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0520
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -5.6487
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.7863
# 7                              Hedge's g =   -1.7508
# 8                         Glass's delta1 =   -1.5169
# 9                       Point-Biserial r =   -0.6756
# ARI T-Test
#           Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.10961  0.032811  0.007337   0.094254  0.124966
# 1  train_W_combine  20.0  0.19815  0.010212  0.002284   0.193370  0.202930
# 2         combined  40.0  0.15388  0.050847  0.008040   0.137618  0.170141
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0885
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -11.5229
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.6439
# 7                                Hedge's g =   -3.5715
# 8                           Glass's delta1 =   -2.6985
# 9                         Point-Biserial r =   -0.8818
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.193579  0.051829  0.011589   0.169323  0.217836
# 1  test_W_combine  20.0  0.265837  0.028996  0.006484   0.252266  0.279408
# 2        combined  40.0  0.229708  0.055291  0.008742   0.212025  0.247391
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0723
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -5.4412
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.7206
# 7                              Hedge's g =   -1.6865
# 8                         Glass's delta1 =   -1.3941
# 9                       Point-Biserial r =   -0.6618
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.714905  0.009299  0.002079   0.710553  0.719257
# 1  train_W_combine  20.0  0.751016  0.005236  0.001171   0.748566  0.753467
# 2         combined  40.0  0.732961  0.019745  0.003122   0.726646  0.739275
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0361
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -15.1327
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.7854
# 7                                Hedge's g =   -4.6903
# 8                           Glass's delta1 =   -3.8834
# 9                         Point-Biserial r =   -0.9261
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.736709  0.017742  0.003967   0.728405  0.745012
# 1  test_W_combine  20.0  0.768829  0.012719  0.002844   0.762876  0.774782
# 2        combined  40.0  0.752769  0.022287  0.003524   0.745641  0.759897
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0321
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.5802
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.0808
# 7                              Hedge's g =   -2.0395
# 8                         Glass's delta1 =   -1.8104
# 9                       Point-Biserial r =   -0.7298

# %%
#one hot encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 2
# all_train_score_W0_p 0.6856368563685636
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.7278481012658228
# test_score_W0_n 0.06881138106515927
# test_score_W0_a  0.15279828117424177
# all_train_score_W_combine_p 0.7479674796747967
# all_train_score_W_combine_n 0.11159079827840743
# all_train_score_W_combine_a 0.19744383056905776
# test_score_W_combine_p 0.8006329113924051
# test_score_W_combine_n 0.2046554731499591
# test_score_W_combine_a 0.3328258553077697
# neuron unit number: 7
# all_train_score_W0_p 0.7005420054200542
# all_train_score_W0_n 0.03482855707073228
# all_train_score_W0_a 0.08232766203149533
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.1149993348107722
# test_score_W0_a  0.2025486263564244
# all_train_score_W_combine_p 0.7317073170731707
# all_train_score_W_combine_n 0.08481440765994973
# all_train_score_W_combine_a 0.16510190551729897
# test_score_W_combine_p 0.810126582278481
# test_score_W_combine_n 0.22464885574158494
# test_score_W_combine_a 0.3563701448761242
# neuron unit number: 12
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.06311299291603306
# all_train_score_W0_a 0.13532801444880954
# test_score_W0_p0.7816455696202531
# test_score_W0_n 0.16572548284248895
# test_score_W0_a  0.2850688476764562
# all_train_score_W_combine_p 0.7425474254742548
# all_train_score_W_combine_n 0.10203504519985823
# all_train_score_W_combine_a 0.1844174598591103
# test_score_W_combine_p 0.7974683544303798
# test_score_W_combine_n 0.19650774684369313
# test_score_W_combine_a 0.3227043152655012
# neuron unit number: 17
# all_train_score_W0_p 0.6991869918699187
# all_train_score_W0_n 0.04431139333867009
# all_train_score_W0_a 0.10911188251974903
# test_score_W0_p0.7658227848101266
# test_score_W0_n 0.1301495311146803
# test_score_W0_a  0.23702963539179128
# all_train_score_W_combine_p 0.7439024390243902
# all_train_score_W_combine_n 0.10440251900758937
# all_train_score_W_combine_a 0.18765829562866568
# test_score_W_combine_p 0.7943037974683544
# test_score_W_combine_n 0.1916353016735643
# test_score_W_combine_a 0.3170872595110272
# neuron unit number: 22
# all_train_score_W0_p 0.7100271002710027
# all_train_score_W0_n 0.04891520128755349
# all_train_score_W0_a 0.10550851698215984
# test_score_W0_p0.7784810126582279
# test_score_W0_n 0.1539108702909301
# test_score_W0_a  0.2663418763372038
# all_train_score_W_combine_p 0.7344173441734417
# all_train_score_W_combine_n 0.09042635070519298
# all_train_score_W_combine_a 0.17543746713537284
# test_score_W_combine_p 0.810126582278481
# test_score_W_combine_n 0.22560807064355376
# test_score_W_combine_a 0.3577429380869217
# neuron unit number: 27
# all_train_score_W0_p 0.7100271002710027
# all_train_score_W0_n 0.04783062035512801
# all_train_score_W0_a 0.09993485726145311
# test_score_W0_p0.7784810126582279
# test_score_W0_n 0.16048062588831602
# test_score_W0_a  0.2784305921072173
# all_train_score_W_combine_p 0.7384823848238482
# all_train_score_W_combine_n 0.09542858418607068
# all_train_score_W_combine_a 0.17822626356679136
# test_score_W_combine_p 0.7943037974683544
# test_score_W_combine_n 0.19583666649343834
# test_score_W_combine_a 0.32126974430808364
# neuron unit number: 32
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.06082159650757232
# all_train_score_W0_a 0.1314656929425485
# test_score_W0_p0.7721518987341772
# test_score_W0_n 0.1442699170515451
# test_score_W0_a  0.25709465101639684
# all_train_score_W_combine_p 0.7276422764227642
# all_train_score_W_combine_n 0.07859317209901054
# all_train_score_W_combine_a 0.15672584694213773
# test_score_W_combine_p 0.7784810126582279
# test_score_W_combine_n 0.16186419106677363
# test_score_W_combine_a 0.2799696219958849
# neuron unit number: 37
# all_train_score_W0_p 0.7018970189701897
# all_train_score_W0_n 0.03425145188968238
# all_train_score_W0_a 0.07440118139057796
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.11610838459671866
# test_score_W0_a  0.2144131832505261
# all_train_score_W_combine_p 0.7262872628726287
# all_train_score_W_combine_n 0.07824635294118318
# all_train_score_W_combine_a 0.15878216810609483
# test_score_W_combine_p 0.7943037974683544
# test_score_W_combine_n 0.21543309994802384
# test_score_W_combine_a 0.33161130038174674
# neuron unit number: 42
# all_train_score_W0_p 0.7113821138211383
# all_train_score_W0_n 0.056879605912645466
# all_train_score_W0_a 0.12724862379687038
# test_score_W0_p0.7689873417721519
# test_score_W0_n 0.13553101300339546
# test_score_W0_a  0.24324622932898565
# all_train_score_W_combine_p 0.7411924119241192
# all_train_score_W_combine_n 0.10155735028273405
# all_train_score_W_combine_a 0.19100349075707196
# test_score_W_combine_p 0.7848101265822784
# test_score_W_combine_n 0.16911541710827
# test_score_W_combine_a 0.28855502868088906
# neuron unit number: 47
# all_train_score_W0_p 0.7140921409214093
# all_train_score_W0_n 0.06386730175029337
# all_train_score_W0_a 0.13978058854507683
# test_score_W0_p0.7689873417721519
# test_score_W0_n 0.14150051044255402
# test_score_W0_a  0.25421615951770704
# all_train_score_W_combine_p 0.7479674796747967
# all_train_score_W_combine_n 0.11190970425666912
# all_train_score_W_combine_a 0.19316844793843943
# test_score_W_combine_p 0.7974683544303798
# test_score_W_combine_n 0.19998069339529173
# test_score_W_combine_a 0.3270291208546435
# neuron unit number: 52
# all_train_score_W0_p 0.7140921409214093
# all_train_score_W0_n 0.05462303626821459
# all_train_score_W0_a 0.11245787191090913
# test_score_W0_p0.7689873417721519
# test_score_W0_n 0.13806731574969971
# test_score_W0_a  0.24895607092171715
# all_train_score_W_combine_p 0.7344173441734417
# all_train_score_W_combine_n 0.09015587914453331
# all_train_score_W_combine_a 0.1746319203695015
# test_score_W_combine_p 0.8006329113924051
# test_score_W_combine_n 0.2181149295159044
# test_score_W_combine_a 0.34291312067228075
# neuron unit number: 57
# all_train_score_W0_p 0.7181571815718157
# all_train_score_W0_n 0.06250874142083014
# all_train_score_W0_a 0.12985358840233877
# test_score_W0_p0.7753164556962026
# test_score_W0_n 0.14962539085511198
# test_score_W0_a  0.26352053969689776
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.10983409320513884
# all_train_score_W_combine_a 0.20410624281151163
# test_score_W_combine_p 0.8037974683544303
# test_score_W_combine_n 0.2091878920921469
# test_score_W_combine_a 0.33717065317889583
# neuron unit number: 62
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.06082159650757232
# all_train_score_W0_a 0.1314656929425485
# test_score_W0_p0.7753164556962026
# test_score_W0_n 0.14807762849555958
# test_score_W0_a  0.25983790523978595
# all_train_score_W_combine_p 0.7330623306233063
# all_train_score_W_combine_n 0.08914915848607899
# all_train_score_W_combine_a 0.17474256567872792
# test_score_W_combine_p 0.7816455696202531
# test_score_W_combine_n 0.16252050687669228
# test_score_W_combine_a 0.2801554534066605
# neuron unit number: 67
# all_train_score_W0_p 0.7113821138211383
# all_train_score_W0_n 0.05726476308509011
# all_train_score_W0_a 0.128137711173099
# test_score_W0_p0.7721518987341772
# test_score_W0_n 0.1433233329093907
# test_score_W0_a  0.2552849138778737
# all_train_score_W_combine_p 0.7398373983739838
# all_train_score_W_combine_n 0.09785832799148741
# all_train_score_W_combine_a 0.1822441437752924
# test_score_W_combine_p 0.8069620253164557
# test_score_W_combine_n 0.22051352710362862
# test_score_W_combine_a 0.3515980938232809
# neuron unit number: 72
# all_train_score_W0_p 0.7249322493224932
# all_train_score_W0_n 0.07553691720706297
# all_train_score_W0_a 0.1540975037222373
# test_score_W0_p0.7816455696202531
# test_score_W0_n 0.17156702710063776
# test_score_W0_a  0.29098377273936066
# all_train_score_W_combine_p 0.7276422764227642
# all_train_score_W_combine_n 0.08448517479664047
# all_train_score_W_combine_a 0.1702811077683315
# test_score_W_combine_p 0.7848101265822784
# test_score_W_combine_n 0.16911541710827
# test_score_W_combine_a 0.28855502868088906
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 77
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.05870956083929937
# all_train_score_W0_a 0.12480194014923189
# test_score_W0_p0.7784810126582279
# test_score_W0_n 0.16048062588831602
# test_score_W0_a  0.2784305921072173
# all_train_score_W_combine_p 0.7411924119241192
# all_train_score_W_combine_n 0.10047466294354838
# all_train_score_W_combine_a 0.18706313646548828
# test_score_W_combine_p 0.7848101265822784
# test_score_W_combine_n 0.1723554639384632
# test_score_W_combine_a 0.2933480548952447
# neuron unit number: 82
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.054182059395791606
# all_train_score_W0_a 0.11679496752741624
# test_score_W0_p0.7848101265822784
# test_score_W0_n 0.1783112253180036
# test_score_W0_a  0.29911294148251666
# all_train_score_W_combine_p 0.7330623306233063
# all_train_score_W_combine_n 0.08561726390383283
# all_train_score_W_combine_a 0.15829147992614373
# test_score_W_combine_p 0.7943037974683544
# test_score_W_combine_n 0.19583666649343834
# test_score_W_combine_a 0.32126974430808364
# neuron unit number: 87
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.05474018288878843
# all_train_score_W0_a 0.11881718952537941
# test_score_W0_p0.7784810126582279
# test_score_W0_n 0.15602417139047373
# test_score_W0_a  0.2718106722735857
# all_train_score_W_combine_p 0.7384823848238482
# all_train_score_W_combine_n 0.09497385078032039
# all_train_score_W_combine_a 0.17022009733476814
# test_score_W_combine_p 0.7974683544303798
# test_score_W_combine_n 0.19868199412430376
# test_score_W_combine_a 0.3256300849912678
# neuron unit number: 92
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.061845337240206924
# all_train_score_W0_a 0.1316449829374743
# test_score_W0_p0.7721518987341772
# test_score_W0_n 0.14647169900700246
# test_score_W0_a  0.26056731236009917
# all_train_score_W_combine_p 0.7303523035230353
# all_train_score_W_combine_n 0.08554274275444972
# all_train_score_W_combine_a 0.17022946399573266
# test_score_W_combine_p 0.819620253164557
# test_score_W_combine_n 0.2466999279935002
# test_score_W_combine_a 0.3820508251401345
# neuron unit number: 97
# all_train_score_W0_p 0.7059620596205962
# all_train_score_W0_n 0.04359574414608158
# all_train_score_W0_a 0.0987091590300813
# test_score_W0_p0.7689873417721519
# test_score_W0_n 0.1340202433785664
# test_score_W0_a  0.23706773072862164
# all_train_score_W_combine_p 0.7303523035230353
# all_train_score_W_combine_n 0.08128059479368138
# all_train_score_W_combine_a 0.15478712677478237
# test_score_W_combine_p 0.7974683544303798
# test_score_W_combine_n 0.19650774684369313
# test_score_W_combine_a 0.3227043152655012
# test_score_W0_p mean 0.7708860759493671
# test_score_W_combine_p mean 0.7966772151898734
# test_score_W0_n mean 0.14287278555996613
# test_score_W_combine_n mean 0.19874097940770968
# test_score_W0_a mean 0.2528380266792313
# test_score_W_combine_a mean 0.32402803518154155
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.051932  0.015840  0.003542   0.044519  0.059346
# 1  train_W_combine  20.0  0.093919  0.010725  0.002398   0.088899  0.098938
# 2         combined  40.0  0.072926  0.025106  0.003970   0.064896  0.080955
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0420
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -9.8155
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.1039
# 7                                Hedge's g =   -3.0423
# 8                           Glass's delta1 =   -2.6506
# 9                         Point-Biserial r =   -0.8468
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.142873  0.023954  0.005356   0.131662  0.154083
# 1  test_W_combine  20.0  0.198741  0.023133  0.005173   0.187914  0.209568
# 2        combined  40.0  0.170807  0.036614  0.005789   0.159097  0.182516
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0559
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -7.5030
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.3726
# 7                              Hedge's g =   -2.3255
# 8                         Glass's delta1 =   -2.3324
# 9                       Point-Biserial r =   -0.7727
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.112594  0.032832  0.007341   0.097229  0.127960
# 1  train_W_combine  20.0  0.176728  0.014115  0.003156   0.170122  0.183334
# 2         combined  40.0  0.144661  0.040950  0.006475   0.131565  0.157758
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0641
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -8.0255
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.5379
# 7                                Hedge's g =   -2.4875
# 8                           Glass's delta1 =   -1.9534
# 9                         Point-Biserial r =   -0.7931
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.252838  0.033526  0.007497   0.237147  0.268529
# 1  test_W_combine  20.0  0.324028  0.027507  0.006151   0.311154  0.336902
# 2        combined  40.0  0.288433  0.047071  0.007443   0.273379  0.303487
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0712
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -7.3415
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.3216
# 7                              Hedge's g =   -2.2755
# 8                         Glass's delta1 =   -2.1234
# 9                       Point-Biserial r =   -0.7658
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.710637  0.008575  0.001917   0.706624  0.714650
# 1  train_W_combine  20.0  0.736789  0.006823  0.001526   0.733595  0.739982
# 2         combined  40.0  0.723713  0.015293  0.002418   0.718822  0.728604
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0262
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -10.6725
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.3749
# 7                                Hedge's g =   -3.3079
# 8                           Glass's delta1 =   -3.0497
# 9                         Point-Biserial r =   -0.8659
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.770886  0.012252  0.002740   0.765152  0.776620
# 1  test_W_combine  20.0  0.796677  0.010464  0.002340   0.791780  0.801575
# 2        combined  40.0  0.783782  0.017235  0.002725   0.778270  0.789294
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0258
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -7.1585
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.2637
# 7                              Hedge's g =   -2.2188
# 8                         Glass's delta1 =   -2.1051
# 9                       Point-Biserial r =   -0.7578

# %%
#new hash encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 2
# all_train_score_W0_p 0.6924119241192412
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.6993670886075949
# test_score_W0_n 0.028126866164033017
# test_score_W0_a  0.061350141827041973
# all_train_score_W_combine_p 0.7425474254742548
# all_train_score_W_combine_n 0.0947652980706082
# all_train_score_W_combine_a 0.17411555782142185
# test_score_W_combine_p 0.7848101265822784
# test_score_W_combine_n 0.18151456275924302
# test_score_W_combine_a 0.2888410603626961
# neuron unit number: 7
# all_train_score_W0_p 0.7005420054200542
# all_train_score_W0_n 0.025371409246990988
# all_train_score_W0_a 0.06465767318899822
# test_score_W0_p0.7278481012658228
# test_score_W0_n 0.07564861764194852
# test_score_W0_a  0.143271411279176
# all_train_score_W_combine_p 0.7520325203252033
# all_train_score_W_combine_n 0.1119980194965581
# all_train_score_W_combine_a 0.19867706621009848
# test_score_W_combine_p 0.7943037974683544
# test_score_W_combine_n 0.20721246915719965
# test_score_W_combine_a 0.32759521063172564
# neuron unit number: 12
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.05403797902539586
# all_train_score_W0_a 0.12033401766015832
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.1331016195240088
# test_score_W0_a  0.23402955122666583
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10706905388610717
# all_train_score_W_combine_a 0.19377328146422992
# test_score_W_combine_p 0.7879746835443038
# test_score_W_combine_n 0.18951362847805708
# test_score_W_combine_a 0.3067255600951258
# neuron unit number: 17
# all_train_score_W0_p 0.7059620596205962
# all_train_score_W0_n 0.03595525517124855
# all_train_score_W0_a 0.08752035198861477
# test_score_W0_p0.7310126582278481
# test_score_W0_n 0.08385179863795764
# test_score_W0_a  0.16548766005357743
# all_train_score_W_combine_p 0.7344173441734417
# all_train_score_W_combine_n 0.080284690375624
# all_train_score_W_combine_a 0.14774406332756765
# test_score_W_combine_p 0.7753164556962026
# test_score_W_combine_n 0.16265265069185045
# test_score_W_combine_a 0.2717095430081456
# neuron unit number: 22
# all_train_score_W0_p 0.7249322493224932
# all_train_score_W0_n 0.06403401765153444
# all_train_score_W0_a 0.1269806462115153
# test_score_W0_p0.7626582278481012
# test_score_W0_n 0.14669578059347765
# test_score_W0_a  0.2527008589681392
# all_train_score_W_combine_p 0.7479674796747967
# all_train_score_W_combine_n 0.10470305531268373
# all_train_score_W_combine_a 0.18460901936540705
# test_score_W_combine_p 0.7974683544303798
# test_score_W_combine_n 0.20985536995126672
# test_score_W_combine_a 0.33153209135148864
# neuron unit number: 27
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.05018861853256488
# all_train_score_W0_a 0.10396764180881701
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.1084957449341915
# test_score_W0_a  0.19276860257806172
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.09985493884335526
# all_train_score_W_combine_a 0.18467290331212213
# test_score_W_combine_p 0.7911392405063291
# test_score_W_combine_n 0.19443871024944243
# test_score_W_combine_a 0.3070991006162273
# neuron unit number: 32
# all_train_score_W0_p 0.7195121951219512
# all_train_score_W0_n 0.05809059699593179
# all_train_score_W0_a 0.1265362445810255
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.1325639241263846
# test_score_W0_a  0.23244320907517013
# all_train_score_W_combine_p 0.7479674796747967
# all_train_score_W_combine_n 0.10657810347846884
# all_train_score_W_combine_a 0.17630448894841502
# test_score_W_combine_p 0.7658227848101266
# test_score_W_combine_n 0.1501608285570491
# test_score_W_combine_a 0.25775525123527154
# neuron unit number: 37
# all_train_score_W0_p 0.7181571815718157
# all_train_score_W0_n 0.058974442671920604
# all_train_score_W0_a 0.1317402447912475
# test_score_W0_p0.7658227848101266
# test_score_W0_n 0.15560355703092563
# test_score_W0_a  0.2625024305539265
# all_train_score_W_combine_p 0.7384823848238482
# all_train_score_W_combine_n 0.08752351500480791
# all_train_score_W_combine_a 0.15887531854528517
# test_score_W_combine_p 0.7753164556962026
# test_score_W_combine_n 0.1637873613489846
# test_score_W_combine_a 0.2745000525301864
# neuron unit number: 42
# all_train_score_W0_p 0.7208672086720868
# all_train_score_W0_n 0.05716394381501294
# all_train_score_W0_a 0.11608689787704564
# test_score_W0_p0.7436708860759493
# test_score_W0_n 0.10757884902264171
# test_score_W0_a  0.20145576547169
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.10297619391391477
# all_train_score_W_combine_a 0.19256721472761887
# test_score_W_combine_p 0.7911392405063291
# test_score_W_combine_n 0.19550819995961477
# test_score_W_combine_a 0.31371815028324723
# neuron unit number: 47
# all_train_score_W0_p 0.7222222222222222
# all_train_score_W0_n 0.06034464024832448
# all_train_score_W0_a 0.12512246098388632
# test_score_W0_p0.75
# test_score_W0_n 0.12502150012892263
# test_score_W0_a  0.22463002995239006
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10883182906879123
# all_train_score_W_combine_a 0.1808507149677984
# test_score_W_combine_p 0.7879746835443038
# test_score_W_combine_n 0.18767145400136723
# test_score_W_combine_a 0.30012537616833224
# neuron unit number: 52
# all_train_score_W0_p 0.7222222222222222
# all_train_score_W0_n 0.06318753166641759
# all_train_score_W0_a 0.13589846135598824
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.13531138699904974
# test_score_W0_a  0.2385409384120522
# all_train_score_W_combine_p 0.7398373983739838
# all_train_score_W_combine_n 0.08991708056869281
# all_train_score_W_combine_a 0.1664316582361523
# test_score_W_combine_p 0.7943037974683544
# test_score_W_combine_n 0.20109571457390835
# test_score_W_combine_a 0.31825348993850194
# neuron unit number: 57
# all_train_score_W0_p 0.7086720867208672
# all_train_score_W0_n 0.04483767963565043
# all_train_score_W0_a 0.10862047248443413
# test_score_W0_p0.7373417721518988
# test_score_W0_n 0.10491911982570683
# test_score_W0_a  0.19775724204014372
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.10127165940461681
# all_train_score_W_combine_a 0.19192310566137286
# test_score_W_combine_p 0.8037974683544303
# test_score_W_combine_n 0.22210362865348088
# test_score_W_combine_a 0.34499596549458045
# neuron unit number: 62
# all_train_score_W0_p 0.7303523035230353
# all_train_score_W0_n 0.07312128597079652
# all_train_score_W0_a 0.13547256754813009
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.1106452859371123
# test_score_W0_a  0.2038258550550108
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.09970951563369018
# all_train_score_W_combine_a 0.17781816107312792
# test_score_W_combine_p 0.7974683544303798
# test_score_W_combine_n 0.20912953050175256
# test_score_W_combine_a 0.33037863916940613
# neuron unit number: 67
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.05275912122745433
# all_train_score_W0_a 0.11942348514917732
# test_score_W0_p0.7373417721518988
# test_score_W0_n 0.10122880224848708
# test_score_W0_a  0.19342089772240725
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.10413760730780072
# all_train_score_W_combine_a 0.1968948652986909
# test_score_W_combine_p 0.7816455696202531
# test_score_W_combine_n 0.18152349318860617
# test_score_W_combine_a 0.2964974965099113
# neuron unit number: 72
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.05275912122745433
# all_train_score_W0_a 0.11942348514917732
# test_score_W0_p0.7563291139240507
# test_score_W0_n 0.13049805248326218
# test_score_W0_a  0.23245900929652313
# all_train_score_W_combine_p 0.7411924119241192
# all_train_score_W_combine_n 0.09243370932859309
# all_train_score_W_combine_a 0.16560359336614305
# test_score_W_combine_p 0.8037974683544303
# test_score_W_combine_n 0.23191949107952106
# test_score_W_combine_a 0.3542489302554255
# neuron unit number: 77
# all_train_score_W0_p 0.7113821138211383
# all_train_score_W0_n 0.041879828363082953
# all_train_score_W0_a 0.09245273725519873
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.11209623154318121
# test_score_W0_a  0.20715339512935585
# all_train_score_W_combine_p 0.7357723577235772
# all_train_score_W_combine_n 0.082685795865784
# all_train_score_W_combine_a 0.15435872472959652
# test_score_W_combine_p 0.7626582278481012
# test_score_W_combine_n 0.13893503282987657
# test_score_W_combine_a 0.2417290759601154
# neuron unit number: 82
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.04922063030094059
# all_train_score_W0_a 0.10690512157182762
# test_score_W0_p0.75
# test_score_W0_n 0.11839321955274244
# test_score_W0_a  0.2161090988066404
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.10317462261914588
# all_train_score_W_combine_a 0.19345131488393785
# test_score_W_combine_p 0.7658227848101266
# test_score_W_combine_n 0.15887433737368695
# test_score_W_combine_a 0.2646552346973834
# neuron unit number: 87
# all_train_score_W0_p 0.7235772357723578
# all_train_score_W0_n 0.06374529570710052
# all_train_score_W0_a 0.13379883166984782
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.11704628004529637
# test_score_W0_a  0.21472719256652775
# all_train_score_W_combine_p 0.7344173441734417
# all_train_score_W_combine_n 0.08037125743959053
# all_train_score_W_combine_a 0.15212571092665075
# test_score_W_combine_p 0.8037974683544303
# test_score_W_combine_n 0.2227773396713064
# test_score_W_combine_a 0.3386785840305665
# neuron unit number: 92
# all_train_score_W0_p 0.6991869918699187
# all_train_score_W0_n 0.017320407805720403
# all_train_score_W0_a 0.037524538362327164
# test_score_W0_p0.7215189873417721
# test_score_W0_n 0.06716658730330745
# test_score_W0_a  0.1378318319082768
# all_train_score_W_combine_p 0.7384823848238482
# all_train_score_W_combine_n 0.08923490041439779
# all_train_score_W_combine_a 0.17390087080846975
# test_score_W_combine_p 0.8069620253164557
# test_score_W_combine_n 0.2288554544900408
# test_score_W_combine_a 0.35124163938528596
# neuron unit number: 97
# all_train_score_W0_p 0.7005420054200542
# all_train_score_W0_n 0.025771860284424634
# all_train_score_W0_a 0.06603273303976948
# test_score_W0_p0.7373417721518988
# test_score_W0_n 0.10122880224848708
# test_score_W0_a  0.19342089772240725
# all_train_score_W_combine_p 0.7208672086720868
# all_train_score_W_combine_n 0.058964435904868134
# all_train_score_W_combine_a 0.12530839023903825
# test_score_W_combine_p 0.7626582278481012
# test_score_W_combine_n 0.1379935823191025
# test_score_W_combine_a 0.23858497342106064
# test_score_W0_p mean 0.7443037974683545
# test_score_W_combine_p mean 0.7867088607594936
# test_score_W0_n mean 0.10976110129955623
# test_score_W_combine_n mean 0.1887761419917679
# test_score_W0_a mean 0.20029430098225923
# test_score_W_combine_a mean 0.30294327125723425
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.047438  0.018283  0.004088   0.038882  0.055995
# 1  train_W_combine  20.0  0.095324  0.012883  0.002881   0.089295  0.101354
# 2         combined  40.0  0.071381  0.028839  0.004560   0.062158  0.080604
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0479
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -9.5750
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.0279
# 7                                Hedge's g =   -2.9677
# 8                           Glass's delta1 =   -2.6192
# 9                         Point-Biserial r =   -0.8408
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.109761  0.029441  0.006583   0.095982  0.123540
# 1  test_W_combine  20.0  0.188776  0.029041  0.006494   0.175184  0.202368
# 2        combined  40.0  0.149269  0.049336  0.007801   0.133490  0.165047
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0790
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -8.5449
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.7021
# 7                              Hedge's g =   -2.6484
# 8                         Glass's delta1 =   -2.6838
# 9                       Point-Biserial r =   -0.8110
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.102925  0.036035  0.008058   0.086060  0.119790
# 1  train_W_combine  20.0  0.174500  0.019382  0.004334   0.165429  0.183571
# 2         combined  40.0  0.138713  0.046144  0.007296   0.123955  0.153470
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0716
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -7.8230
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.4738
# 7                                Hedge's g =   -2.4247
# 8                           Glass's delta1 =   -1.9863
# 9                         Point-Biserial r =   -0.7855
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.200294  0.046012  0.010289   0.178760  0.221828
# 1  test_W_combine  20.0  0.302943  0.035541  0.007947   0.286310  0.319577
# 2        combined  40.0  0.251619  0.065943  0.010427   0.230529  0.272709
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1026
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -7.8958
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.4969
# 7                              Hedge's g =   -2.4473
# 8                         Glass's delta1 =   -2.2309
# 9                       Point-Biserial r =   -0.7882
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.714024  0.009942  0.002223   0.709371  0.718678
# 1  train_W_combine  20.0  0.742412  0.007262  0.001624   0.739013  0.745811
# 2         combined  40.0  0.728218  0.016748  0.002648   0.722862  0.733574
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0284
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -10.3110
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.2606
# 7                                Hedge's g =   -3.1958
# 8                           Glass's delta1 =   -2.8552
# 9                         Point-Biserial r =   -0.8583
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.744304  0.015992  0.003576   0.736819  0.751788
# 1  test_W_combine  20.0  0.786709  0.014498  0.003242   0.779924  0.793494
# 2        combined  40.0  0.765506  0.026231  0.004147   0.757117  0.773895
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0424
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -8.7856
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.7782
# 7                              Hedge's g =   -2.7230
# 8                         Glass's delta1 =   -2.6517
# 9                       Point-Biserial r =   -0.8186

# %%
#baseN encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 2
# all_train_score_W0_p 0.7032520325203252
# all_train_score_W0_n 0.0070288945601686284
# all_train_score_W0_a 0.017758634626636433
# test_score_W0_p0.6867088607594937
# test_score_W0_n 0.03758364266345287
# test_score_W0_a  0.07991477665465842
# all_train_score_W_combine_p 0.7601626016260162
# all_train_score_W_combine_n 0.11696656889835362
# all_train_score_W_combine_a 0.208127437060439
# test_score_W_combine_p 0.7689873417721519
# test_score_W_combine_n 0.17402279229977538
# test_score_W_combine_a 0.2759834983583605
# neuron unit number: 7
# all_train_score_W0_p 0.7140921409214093
# all_train_score_W0_n 0.038281811771113596
# all_train_score_W0_a 0.09556990765484258
# test_score_W0_p0.7215189873417721
# test_score_W0_n 0.09161201834695454
# test_score_W0_a  0.1703623059449161
# all_train_score_W_combine_p 0.7574525745257452
# all_train_score_W_combine_n 0.11171183876347913
# all_train_score_W_combine_a 0.20097408420643756
# test_score_W_combine_p 0.75
# test_score_W_combine_n 0.1360898774893486
# test_score_W_combine_a 0.229505503902957
# neuron unit number: 12
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.0340899500728043
# all_train_score_W0_a 0.08533599492125556
# test_score_W0_p0.6993670886075949
# test_score_W0_n 0.0675553333047708
# test_score_W0_a  0.13600748034196344
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.09913563958493539
# all_train_score_W_combine_a 0.1739573216197078
# test_score_W_combine_p 0.7468354430379747
# test_score_W_combine_n 0.1295767748527974
# test_score_W_combine_a 0.22042190211369195
# neuron unit number: 17
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.027417994828647225
# all_train_score_W0_a 0.05881669051643521
# test_score_W0_p0.7088607594936709
# test_score_W0_n 0.08002721577941359
# test_score_W0_a  0.15355382557035208
# all_train_score_W_combine_p 0.7547425474254743
# all_train_score_W_combine_n 0.11191210426045096
# all_train_score_W_combine_a 0.21427975246836636
# test_score_W_combine_p 0.7468354430379747
# test_score_W_combine_n 0.13612433044291905
# test_score_W_combine_a 0.2281674980853222
# neuron unit number: 22
# all_train_score_W0_p 0.7276422764227642
# all_train_score_W0_n 0.06340141266545525
# all_train_score_W0_a 0.14147783798836278
# test_score_W0_p0.7246835443037974
# test_score_W0_n 0.09258681064919988
# test_score_W0_a  0.16643037022717824
# all_train_score_W_combine_p 0.7642276422764228
# all_train_score_W_combine_n 0.1252260125059432
# all_train_score_W_combine_a 0.2158217698150699
# test_score_W_combine_p 0.7689873417721519
# test_score_W_combine_n 0.1709825087160714
# test_score_W_combine_a 0.2735815754484453
# neuron unit number: 27
# all_train_score_W0_p 0.7276422764227642
# all_train_score_W0_n 0.05843341401216571
# all_train_score_W0_a 0.12596673184737225
# test_score_W0_p0.7341772151898734
# test_score_W0_n 0.10811625065340669
# test_score_W0_a  0.19057853672898573
# all_train_score_W_combine_p 0.7615176151761518
# all_train_score_W_combine_n 0.12202088793927539
# all_train_score_W_combine_a 0.19963019649834146
# test_score_W_combine_p 0.740506329113924
# test_score_W_combine_n 0.12171034719246909
# test_score_W_combine_a 0.21088008995595905
# neuron unit number: 32
# all_train_score_W0_p 0.7276422764227642
# all_train_score_W0_n 0.064293907895323
# all_train_score_W0_a 0.14368345407180147
# test_score_W0_p0.7183544303797469
# test_score_W0_n 0.08858419873541207
# test_score_W0_a  0.16637095110377553
# all_train_score_W_combine_p 0.7601626016260162
# all_train_score_W_combine_n 0.11773972071707772
# all_train_score_W_combine_a 0.2161596069973294
# test_score_W_combine_p 0.7531645569620253
# test_score_W_combine_n 0.14494361650808169
# test_score_W_combine_a 0.2402340255784155
# neuron unit number: 37
# all_train_score_W0_p 0.7262872628726287
# all_train_score_W0_n 0.054201539665779716
# all_train_score_W0_a 0.11329658562889708
# test_score_W0_p0.7341772151898734
# test_score_W0_n 0.10745869906922059
# test_score_W0_a  0.18668737519414244
# all_train_score_W_combine_p 0.7479674796747967
# all_train_score_W_combine_n 0.09675983678683624
# all_train_score_W_combine_a 0.1900135955036747
# test_score_W_combine_p 0.759493670886076
# test_score_W_combine_n 0.15152747437213607
# test_score_W_combine_a 0.24888972289985614
# neuron unit number: 42
# all_train_score_W0_p 0.7371273712737128
# all_train_score_W0_n 0.07676083603890091
# all_train_score_W0_a 0.15892768735741156
# test_score_W0_p0.7436708860759493
# test_score_W0_n 0.1234993280270821
# test_score_W0_a  0.2111872595227042
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.09683693583127707
# all_train_score_W_combine_a 0.184139273577935
# test_score_W_combine_p 0.7310126582278481
# test_score_W_combine_n 0.10355240078569568
# test_score_W_combine_a 0.18509778924594103
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 47
# all_train_score_W0_p 0.7235772357723578
# all_train_score_W0_n 0.054164369380863206
# all_train_score_W0_a 0.1235344727532241
# test_score_W0_p0.7215189873417721
# test_score_W0_n 0.08872889642330115
# test_score_W0_a  0.16401763675871817
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.10014978219929067
# all_train_score_W_combine_a 0.16902040151080003
# test_score_W_combine_p 0.7563291139240507
# test_score_W_combine_n 0.14547142544170033
# test_score_W_combine_a 0.24064369713224676
# neuron unit number: 52
# all_train_score_W0_p 0.7317073170731707
# all_train_score_W0_n 0.06398570380494996
# all_train_score_W0_a 0.12970509824938087
# test_score_W0_p0.7120253164556962
# test_score_W0_n 0.08437398339313866
# test_score_W0_a  0.1595373499985711
# all_train_score_W_combine_p 0.7533875338753387
# all_train_score_W_combine_n 0.10393967075082507
# all_train_score_W_combine_a 0.19031261469199337
# test_score_W_combine_p 0.759493670886076
# test_score_W_combine_n 0.15738828454029538
# test_score_W_combine_a 0.25514075697581856
# neuron unit number: 57
# all_train_score_W0_p 0.7276422764227642
# all_train_score_W0_n 0.061711531706668314
# all_train_score_W0_a 0.13692508560357727
# test_score_W0_p0.7436708860759493
# test_score_W0_n 0.12483229964648586
# test_score_W0_a  0.21456571074891687
# all_train_score_W_combine_p 0.7533875338753387
# all_train_score_W_combine_n 0.10449587622636146
# all_train_score_W_combine_a 0.19564807241155474
# test_score_W_combine_p 0.7531645569620253
# test_score_W_combine_n 0.14226279250197899
# test_score_W_combine_a 0.2375084053711188
# neuron unit number: 62
# all_train_score_W0_p 0.7398373983739838
# all_train_score_W0_n 0.07943889714349166
# all_train_score_W0_a 0.15773022789845728
# test_score_W0_p0.7310126582278481
# test_score_W0_n 0.1113320578390109
# test_score_W0_a  0.19593969411636641
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.09073303150575696
# all_train_score_W_combine_a 0.1791536317766834
# test_score_W_combine_p 0.7341772151898734
# test_score_W_combine_n 0.10951723360597508
# test_score_W_combine_a 0.1941796560134831
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 67
# all_train_score_W0_p 0.7330623306233063
# all_train_score_W0_n 0.06865435964431069
# all_train_score_W0_a 0.14430339392186173
# test_score_W0_p0.7246835443037974
# test_score_W0_n 0.09628331239115843
# test_score_W0_a  0.17677787957693009
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.09916619319591785
# all_train_score_W_combine_a 0.18654313588530985
# test_score_W_combine_p 0.7531645569620253
# test_score_W_combine_n 0.14091593701642996
# test_score_W_combine_a 0.23554763245136673
# neuron unit number: 72
# all_train_score_W0_p 0.7317073170731707
# all_train_score_W0_n 0.07065956527897325
# all_train_score_W0_a 0.15336028645145985
# test_score_W0_p0.7278481012658228
# test_score_W0_n 0.10260171255487509
# test_score_W0_a  0.1854736139780238
# all_train_score_W_combine_p 0.7425474254742548
# all_train_score_W_combine_n 0.08352409960603317
# all_train_score_W_combine_a 0.1587053024490015
# test_score_W_combine_p 0.7531645569620253
# test_score_W_combine_n 0.14494361650808169
# test_score_W_combine_a 0.2402340255784155
# neuron unit number: 77
# all_train_score_W0_p 0.7249322493224932
# all_train_score_W0_n 0.05030896879095736
# all_train_score_W0_a 0.09680248215678328
# test_score_W0_p0.7373417721518988
# test_score_W0_n 0.11659715066287442
# test_score_W0_a  0.2041556876557862
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.09898503040278248
# all_train_score_W_combine_a 0.17516078645922573
# test_score_W_combine_p 0.7563291139240507
# test_score_W_combine_n 0.14708766130314038
# test_score_W_combine_a 0.24364609697918754
# neuron unit number: 82
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.03937692975126358
# all_train_score_W0_a 0.09242410775260262
# test_score_W0_p0.7246835443037974
# test_score_W0_n 0.09279832294155865
# test_score_W0_a  0.16784068648832987
# all_train_score_W_combine_p 0.7371273712737128
# all_train_score_W_combine_n 0.07387855674842839
# all_train_score_W_combine_a 0.1460305364126594
# test_score_W_combine_p 0.7373417721518988
# test_score_W_combine_n 0.11742603192110097
# test_score_W_combine_a 0.20517697492150777
# neuron unit number: 87
# all_train_score_W0_p 0.7371273712737128
# all_train_score_W0_n 0.07783338563228097
# all_train_score_W0_a 0.1621968828160934
# test_score_W0_p0.7278481012658228
# test_score_W0_n 0.10538690622699479
# test_score_W0_a  0.18856128033898656
# all_train_score_W_combine_p 0.7357723577235772
# all_train_score_W_combine_n 0.07291252961094005
# all_train_score_W_combine_a 0.14985939616818195
# test_score_W_combine_p 0.7341772151898734
# test_score_W_combine_n 0.12415610795724027
# test_score_W_combine_a 0.20734534445889868
# neuron unit number: 92
# all_train_score_W0_p 0.7317073170731707
# all_train_score_W0_n 0.06897678094765575
# all_train_score_W0_a 0.14901352210353236
# test_score_W0_p0.740506329113924
# test_score_W0_n 0.12444026036118426
# test_score_W0_a  0.21378602103690794
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.09018201724281151
# all_train_score_W_combine_a 0.1770295378367494
# test_score_W_combine_p 0.740506329113924
# test_score_W_combine_n 0.1278062636688683
# test_score_W_combine_a 0.21642767789758804
# neuron unit number: 97
# all_train_score_W0_p 0.7208672086720868
# all_train_score_W0_n 0.04878529460419582
# all_train_score_W0_a 0.11321045469352796
# test_score_W0_p0.7246835443037974
# test_score_W0_n 0.09439398248031182
# test_score_W0_a  0.17314506010424666
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.10299908242200528
# all_train_score_W_combine_a 0.20059877098650336
# test_score_W_combine_p 0.7341772151898734
# test_score_W_combine_n 0.11239441915821864
# test_score_W_combine_a 0.19854238029298157
# test_score_W0_p mean 0.7243670886075949
# test_score_W_combine_p mean 0.7488924050632911
# test_score_W0_n mean 0.09693961910749035
# test_score_W_combine_n mean 0.1368949948141162
# test_score_W0_a mean 0.17524467510452302
# test_score_W_combine_a mean 0.22935771268307809
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.055390  0.018631  0.004166   0.046671  0.064110
# 1  train_W_combine  20.0  0.100964  0.014367  0.003213   0.094240  0.107688
# 2         combined  40.0  0.078177  0.028324  0.004478   0.069119  0.087235
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0456
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -8.6627
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.7394
# 7                                Hedge's g =   -2.6850
# 8                           Glass's delta1 =   -2.4461
# 9                         Point-Biserial r =   -0.8148
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.096940  0.020789  0.004649   0.087210  0.106669
# 1  test_W_combine  20.0  0.136895  0.019053  0.004260   0.127978  0.145812
# 2        combined  40.0  0.116917  0.028227  0.004463   0.107890  0.125945
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0400
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.3366
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.0038
# 7                              Hedge's g =   -1.9640
# 8                         Glass's delta1 =   -1.9220
# 9                       Point-Biserial r =   -0.7168
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.120002  0.037064  0.008288   0.102656  0.137348
# 1  train_W_combine  20.0  0.186558  0.020728  0.004635   0.176857  0.196259
# 2         combined  40.0  0.153280  0.044882  0.007096   0.138926  0.167634
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0666
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -7.0091
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.2165
# 7                                Hedge's g =   -2.1724
# 8                           Glass's delta1 =   -1.7957
# 9                         Point-Biserial r =   -0.7509
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.175245  0.030735  0.006873   0.160860  0.189629
# 1  test_W_combine  20.0  0.229358  0.024766  0.005538   0.217767  0.240949
# 2        combined  40.0  0.202301  0.038857  0.006144   0.189874  0.214728
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0541
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.1310
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.9388
# 7                              Hedge's g =   -1.9003
# 8                         Glass's delta1 =   -1.7606
# 9                       Point-Biserial r =   -0.7052
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.725407  0.009513  0.002127   0.720954  0.729859
# 1  train_W_combine  20.0  0.751084  0.007590  0.001697   0.747532  0.754636
# 2         combined  40.0  0.738245  0.015531  0.002456   0.733278  0.743212
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0257
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -9.4355
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.9838
# 7                                Hedge's g =   -2.9245
# 8                           Glass's delta1 =   -2.6991
# 9                         Point-Biserial r =   -0.8372
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.724367  0.014370  0.003213   0.717642  0.731093
# 1  test_W_combine  20.0  0.748892  0.011400  0.002549   0.743557  0.754228
# 2        combined  40.0  0.736630  0.017837  0.002820   0.730925  0.742334
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0245
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -5.9795
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.8909
# 7                              Hedge's g =   -1.8533
# 8                         Glass's delta1 =   -1.7067
# 9                       Point-Biserial r =   -0.6963

# %%
#effect encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 2
# all_train_score_W0_p 0.6991869918699187
# all_train_score_W0_n 0.011858076458447114
# all_train_score_W0_a 0.030722860037081922
# test_score_W0_p0.6930379746835443
# test_score_W0_n 0.033604334993249725
# test_score_W0_a  0.07784195656255295
# all_train_score_W_combine_p 0.7588075880758808
# all_train_score_W_combine_n 0.12277709428534507
# all_train_score_W_combine_a 0.22520877782670196
# test_score_W_combine_p 0.7879746835443038
# test_score_W_combine_n 0.19715504856833063
# test_score_W_combine_a 0.3117592227534185
# neuron unit number: 7
# all_train_score_W0_p 0.7059620596205962
# all_train_score_W0_n 0.02959596105082568
# all_train_score_W0_a 0.07490238286682949
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.12034919661758296
# test_score_W0_a  0.21424709276200765
# all_train_score_W_combine_p 0.7655826558265583
# all_train_score_W_combine_n 0.13610975165329672
# all_train_score_W_combine_a 0.2437276726624065
# test_score_W_combine_p 0.7816455696202531
# test_score_W_combine_n 0.1861818589670002
# test_score_W_combine_a 0.28206310878000657
# neuron unit number: 12
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.04094330039905508
# all_train_score_W0_a 0.09619396581471629
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.14725314638457285
# test_score_W0_a  0.24915912718232258
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.09894002505333808
# all_train_score_W_combine_a 0.1888698712138517
# test_score_W_combine_p 0.7721518987341772
# test_score_W_combine_n 0.16893206745575223
# test_score_W_combine_a 0.27682168565455284
# neuron unit number: 17
# all_train_score_W0_p 0.7140921409214093
# all_train_score_W0_n 0.04095821168961404
# all_train_score_W0_a 0.09148466859947062
# test_score_W0_p0.7341772151898734
# test_score_W0_n 0.11135443228268395
# test_score_W0_a  0.1999865863491992
# all_train_score_W_combine_p 0.7547425474254743
# all_train_score_W_combine_n 0.11504690478438714
# all_train_score_W_combine_a 0.21429786670274786
# test_score_W_combine_p 0.7563291139240507
# test_score_W_combine_n 0.13564503447299736
# test_score_W_combine_a 0.23343667355747122
# neuron unit number: 22
# all_train_score_W0_p 0.7168021680216802
# all_train_score_W0_n 0.04581277565953175
# all_train_score_W0_a 0.1006676329725767
# test_score_W0_p0.7246835443037974
# test_score_W0_n 0.0893999395140028
# test_score_W0_a  0.172932329510066
# all_train_score_W_combine_p 0.7357723577235772
# all_train_score_W_combine_n 0.07818473884328517
# all_train_score_W_combine_a 0.15177812970856835
# test_score_W_combine_p 0.7468354430379747
# test_score_W_combine_n 0.13270146560611232
# test_score_W_combine_a 0.22694199665976486
# neuron unit number: 27
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.04280911867505908
# all_train_score_W0_a 0.09339690224048142
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.11910281552504338
# test_score_W0_a  0.21147347541247077
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.10506386489696495
# all_train_score_W_combine_a 0.20009873543622503
# test_score_W_combine_p 0.7784810126582279
# test_score_W_combine_n 0.18535475925670344
# test_score_W_combine_a 0.2949121389026033
# neuron unit number: 32
# all_train_score_W0_p 0.7249322493224932
# all_train_score_W0_n 0.05904365184152127
# all_train_score_W0_a 0.12038133873108464
# test_score_W0_p0.7689873417721519
# test_score_W0_n 0.16930318262676333
# test_score_W0_a  0.2741103335581423
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.10001317106160465
# all_train_score_W_combine_a 0.19257956685033592
# test_score_W_combine_p 0.7753164556962026
# test_score_W_combine_n 0.17629712415135257
# test_score_W_combine_a 0.2854282916744015
# neuron unit number: 37
# all_train_score_W0_p 0.7262872628726287
# all_train_score_W0_n 0.06776977196029084
# all_train_score_W0_a 0.14715973150132824
# test_score_W0_p0.7531645569620253
# test_score_W0_n 0.1382627168073595
# test_score_W0_a  0.23688689394088064
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.09753346046391903
# all_train_score_W_combine_a 0.1788835184036594
# test_score_W_combine_p 0.7784810126582279
# test_score_W_combine_n 0.17682983274834363
# test_score_W_combine_a 0.2857289871861971
# neuron unit number: 42
# all_train_score_W0_p 0.7344173441734417
# all_train_score_W0_n 0.08056633245986936
# all_train_score_W0_a 0.16612773163684985
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.1461317725304021
# test_score_W0_a  0.24807925769266015
# all_train_score_W_combine_p 0.7398373983739838
# all_train_score_W_combine_n 0.0860555824911012
# all_train_score_W_combine_a 0.16721842462927516
# test_score_W_combine_p 0.7531645569620253
# test_score_W_combine_n 0.12957571006849955
# test_score_W_combine_a 0.22467127105705018
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 47
# all_train_score_W0_p 0.7181571815718157
# all_train_score_W0_n 0.04980225901408463
# all_train_score_W0_a 0.11150113700001209
# test_score_W0_p0.740506329113924
# test_score_W0_n 0.11773528593283239
# test_score_W0_a  0.21013516076614067
# all_train_score_W_combine_p 0.7439024390243902
# all_train_score_W_combine_n 0.09260239999887236
# all_train_score_W_combine_a 0.1720500211734139
# test_score_W_combine_p 0.7531645569620253
# test_score_W_combine_n 0.12957571006849955
# test_score_W_combine_a 0.22467127105705018
# neuron unit number: 52
# all_train_score_W0_p 0.7154471544715447
# all_train_score_W0_n 0.04797944386010938
# all_train_score_W0_a 0.1123516836905039
# test_score_W0_p0.759493670886076
# test_score_W0_n 0.1461317725304021
# test_score_W0_a  0.24807925769266015
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.09944467993670422
# all_train_score_W_combine_a 0.19074455689216413
# test_score_W_combine_p 0.7626582278481012
# test_score_W_combine_n 0.14832433083891577
# test_score_W_combine_a 0.2508712451789916
# neuron unit number: 57
# all_train_score_W0_p 0.7330623306233063
# all_train_score_W0_n 0.07533839313484614
# all_train_score_W0_a 0.15388468827481236
# test_score_W0_p0.7563291139240507
# test_score_W0_n 0.13938746171078747
# test_score_W0_a  0.23966174059301906
# all_train_score_W_combine_p 0.7479674796747967
# all_train_score_W_combine_n 0.10182427069757849
# all_train_score_W_combine_a 0.19407209186138497
# test_score_W_combine_p 0.7689873417721519
# test_score_W_combine_n 0.16093636500022596
# test_score_W_combine_a 0.2670955613964878
# neuron unit number: 62
# all_train_score_W0_p 0.7100271002710027
# all_train_score_W0_n 0.037391627621839466
# all_train_score_W0_a 0.09113643868461713
# test_score_W0_p0.7468354430379747
# test_score_W0_n 0.12380459120690211
# test_score_W0_a  0.21935572861467884
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.09611165694577854
# all_train_score_W_combine_a 0.183603894739362
# test_score_W_combine_p 0.7658227848101266
# test_score_W_combine_n 0.15197786267432675
# test_score_W_combine_a 0.25206922657237957
# neuron unit number: 67
# all_train_score_W0_p 0.7235772357723578
# all_train_score_W0_n 0.058274443695375086
# all_train_score_W0_a 0.12440776662244551
# test_score_W0_p0.7563291139240507
# test_score_W0_n 0.15332505381406789
# test_score_W0_a  0.24956464634066
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.10508494759836297
# all_train_score_W_combine_a 0.19123247851782046
# test_score_W_combine_p 0.7626582278481012
# test_score_W_combine_n 0.147661268853314
# test_score_W_combine_a 0.24964874044543708
# Not good nmi result for discrete features !!!!!
# neuron unit number: 72
# all_train_score_W0_p 0.7208672086720868
# all_train_score_W0_n 0.05566844643213887
# all_train_score_W0_a 0.12381520105155888
# test_score_W0_p0.75
# test_score_W0_n 0.13145148008704058
# test_score_W0_a  0.2287267322102979
# all_train_score_W_combine_p 0.7493224932249323
# all_train_score_W_combine_n 0.1037413491521421
# all_train_score_W_combine_a 0.19556797594605713
# test_score_W_combine_p 0.7879746835443038
# test_score_W_combine_n 0.1965126460776041
# test_score_W_combine_a 0.31072525231284776
# neuron unit number: 77
# all_train_score_W0_p 0.7127371273712737
# all_train_score_W0_n 0.042471919764611045
# all_train_score_W0_a 0.10124922704231991
# test_score_W0_p0.7658227848101266
# test_score_W0_n 0.15251423127442174
# test_score_W0_a  0.2547000496388789
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.0963292261032865
# all_train_score_W_combine_a 0.18457486036772305
# test_score_W_combine_p 0.7626582278481012
# test_score_W_combine_n 0.14658217288627332
# test_score_W_combine_a 0.23859007752148206
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 82
# all_train_score_W0_p 0.7222222222222222
# all_train_score_W0_n 0.060382647547240056
# all_train_score_W0_a 0.13468412582077094
# test_score_W0_p0.7531645569620253
# test_score_W0_n 0.1409869105937056
# test_score_W0_a  0.23891617201381252
# all_train_score_W_combine_p 0.7425474254742548
# all_train_score_W_combine_n 0.0918605865815081
# all_train_score_W_combine_a 0.17889685165848476
# test_score_W_combine_p 0.7689873417721519
# test_score_W_combine_n 0.16015070305823742
# test_score_W_combine_a 0.26596298487091624
# neuron unit number: 87
# all_train_score_W0_p 0.7140921409214093
# all_train_score_W0_n 0.048127224565539466
# all_train_score_W0_a 0.11498383542849043
# test_score_W0_p0.7436708860759493
# test_score_W0_n 0.11749372422653742
# test_score_W0_a  0.21108349388559364
# all_train_score_W_combine_p 0.7506775067750677
# all_train_score_W_combine_n 0.10746069792760428
# all_train_score_W_combine_a 0.20342202076193266
# test_score_W_combine_p 0.7658227848101266
# test_score_W_combine_n 0.1590577070027722
# test_score_W_combine_a 0.2638531834029999
# neuron unit number: 92
# all_train_score_W0_p 0.7195121951219512
# all_train_score_W0_n 0.0547468369173509
# all_train_score_W0_a 0.12405582162111697
# test_score_W0_p0.7436708860759493
# test_score_W0_n 0.13373926730423988
# test_score_W0_a  0.2237930252184135
# all_train_score_W_combine_p 0.7452574525745257
# all_train_score_W_combine_n 0.09766153855640189
# all_train_score_W_combine_a 0.18927835700905005
# test_score_W_combine_p 0.7689873417721519
# test_score_W_combine_n 0.16093636500022596
# test_score_W_combine_a 0.2670955613964878
# neuron unit number: 97
# all_train_score_W0_p 0.7262872628726287
# all_train_score_W0_n 0.0626358981443139
# all_train_score_W0_a 0.13091818293869883
# test_score_W0_p0.7531645569620253
# test_score_W0_n 0.1382627168073595
# test_score_W0_a  0.23688689394088064
# all_train_score_W_combine_p 0.7466124661246613
# all_train_score_W_combine_n 0.09981060296345881
# all_train_score_W_combine_a 0.1642870083413616
# test_score_W_combine_p 0.7689873417721519
# test_score_W_combine_n 0.158461832484801
# test_score_W_combine_a 0.26236333425797964
# test_score_W0_p mean 0.7477848101265823
# test_score_W_combine_p mean 0.7683544303797467
# test_score_W0_n mean 0.12847970163849787
# test_score_W_combine_n mean 0.16044249326201437
# test_score_W0_a mean 0.22228099769426687
# test_score_W_combine_a mean 0.26373549073192637
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.050609  0.015702  0.003511   0.043260  0.057958
# 1  train_W_combine  20.0  0.101583  0.012474  0.002789   0.095745  0.107421
# 2         combined  40.0  0.076096  0.029363  0.004643   0.066705  0.085486
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0510
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -11.3676
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.5947
# 7                                Hedge's g =   -3.5233
# 8                           Glass's delta1 =   -3.2463
# 9                         Point-Biserial r =   -0.8791
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.128480  0.028630  0.006402   0.115080  0.141879
# 1  test_W_combine  20.0  0.160442  0.021019  0.004700   0.150605  0.170280
# 2        combined  40.0  0.144461  0.029606  0.004681   0.134993  0.153930
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0320
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.0245
# 3                  Two side test p value =    0.0003
# 4                 Difference < 0 p value =    0.0001
# 5                 Difference > 0 p value =    0.9999
# 6                              Cohen's d =   -1.2727
# 7                              Hedge's g =   -1.2474
# 8                         Glass's delta1 =   -1.1164
# 9                       Point-Biserial r =   -0.5467
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.112201  0.029902  0.006686   0.098207  0.126196
# 1  train_W_combine  20.0  0.190520  0.020941  0.004683   0.180719  0.200320
# 2         combined  40.0  0.151360  0.047138  0.007453   0.136285  0.166436
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0783
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -9.5944
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.0340
# 7                                Hedge's g =   -2.9737
# 8                           Glass's delta1 =   -2.6191
# 9                         Point-Biserial r =   -0.8413
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.222281  0.040938  0.009154   0.203121  0.241441
# 1  test_W_combine  20.0  0.263735  0.026590  0.005946   0.251291  0.276180
# 2        combined  40.0  0.243008  0.040019  0.006328   0.230209  0.255807
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0415
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -3.7978
# 3                  Two side test p value =    0.0005
# 4                 Difference < 0 p value =    0.0003
# 5                 Difference > 0 p value =    0.9997
# 6                              Cohen's d =   -1.2010
# 7                              Hedge's g =   -1.1771
# 8                         Glass's delta1 =   -1.0126
# 9                       Point-Biserial r =   -0.5245
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.718293  0.008591  0.001921   0.714272  0.722314
# 1  train_W_combine  20.0  0.747900  0.006423  0.001436   0.744894  0.750906
# 2         combined  40.0  0.733096  0.016758  0.002650   0.727737  0.738456
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0296
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -12.3433
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.9033
# 7                                Hedge's g =   -3.8258
# 8                           Glass's delta1 =   -3.4462
# 9                         Point-Biserial r =   -0.8946
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.747785  0.016590  0.003710   0.740020  0.755549
# 1  test_W_combine  20.0  0.768354  0.011228  0.002511   0.763099  0.773609
# 2        combined  40.0  0.758070  0.017436  0.002757   0.752493  0.763646
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0206
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.5920
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.4521
# 7                              Hedge's g =   -1.4233
# 8                         Glass's delta1 =   -1.2399
# 9                       Point-Biserial r =   -0.5974

# %%
#new hash encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6930379746835443
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8577235772357723
# train_discrete_score_W_discrete_n 0.35709253551124215
# train_discrete_score_W_discrete_a 0.49931142485258484
# test_discrete_score_W_discrete_p 0.8386075949367089
# test_discrete_score_W_discrete_n 0.3062268225175252
# test_discrete_score_W_discrete_a 0.4437607573361104
# neuron unit number: 7
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6930379746835443
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.94579945799458
# train_discrete_score_W_discrete_n 0.6751573370316002
# train_discrete_score_W_discrete_a 0.7912304498418788
# test_discrete_score_W_discrete_p 0.9208860759493671
# test_discrete_score_W_discrete_n 0.5761141441614017
# test_discrete_score_W_discrete_a 0.7030711962656898
# neuron unit number: 12
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.019231739581299086
# test_discrete_score_W0_a 0.04689653546432775
# train_discrete_score_W_discrete_p 0.964769647696477
# train_discrete_score_W_discrete_n 0.7663690039425585
# train_discrete_score_W_discrete_a 0.8615028942727777
# test_discrete_score_W_discrete_p 0.9651898734177216
# test_discrete_score_W_discrete_n 0.8009833212797174
# test_discrete_score_W_discrete_a 0.8632324844527635
# neuron unit number: 17
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6930379746835443
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.9823848238482384
# train_discrete_score_W_discrete_n 0.8641404645233325
# train_discrete_score_W_discrete_a 0.9293886407655055
# test_discrete_score_W_discrete_p 0.9683544303797469
# test_discrete_score_W_discrete_n 0.7974277368631543
# test_discrete_score_W_discrete_a 0.8750278517187419
# neuron unit number: 22
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.03667460057723447
# test_discrete_score_W0_a 0.09707224173324153
# train_discrete_score_W_discrete_p 0.989159891598916
# train_discrete_score_W_discrete_n 0.9073163981626279
# train_discrete_score_W_discrete_a 0.9562093754475537
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.8887380879999434
# test_discrete_score_W_discrete_a 0.936368542120915
# neuron unit number: 27
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.009830838670727227
# train_discrete_score_W0_a  0.030028258852959733
# test_discrete_score_W0_p 0.7025316455696202
# test_discrete_score_W0_n 0.022619188550497916
# test_discrete_score_W0_a 0.04728793763750441
# train_discrete_score_W_discrete_p 0.962059620596206
# train_discrete_score_W_discrete_n 0.7477196215046872
# train_discrete_score_W_discrete_a 0.850192823731623
# test_discrete_score_W_discrete_p 0.9493670886075949
# test_discrete_score_W_discrete_n 0.6959720660504217
# test_discrete_score_W_discrete_a 0.8039652575980264
# neuron unit number: 32
# train_discrete_score_W0_p 0.6924119241192412
# train_discrete_score_W0_n 0.014176767851115995
# train_discrete_score_W0_a  0.03924226700313787
# test_discrete_score_W0_p 0.7151898734177216
# test_discrete_score_W0_n 0.05527996193136523
# test_discrete_score_W0_a 0.12640189735726223
# train_discrete_score_W_discrete_p 0.986449864498645
# train_discrete_score_W_discrete_n 0.8895317022565105
# train_discrete_score_W_discrete_a 0.9452463711482222
# test_discrete_score_W_discrete_p 0.9778481012658228
# test_discrete_score_W_discrete_n 0.8312425799916339
# test_discrete_score_W_discrete_a 0.9112422039925573
# neuron unit number: 37
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6930379746835443
# test_discrete_score_W0_n 0.006987085811208905
# test_discrete_score_W0_a 0.020646542506962257
# train_discrete_score_W_discrete_p 0.9539295392953929
# train_discrete_score_W_discrete_n 0.7068314647744244
# train_discrete_score_W_discrete_a 0.8206221352951475
# test_discrete_score_W_discrete_p 0.9367088607594937
# test_discrete_score_W_discrete_n 0.6340652401929215
# test_discrete_score_W_discrete_a 0.7579112655932214
# neuron unit number: 42
# train_discrete_score_W0_p 0.6978319783197832
# train_discrete_score_W0_n 0.027037132778921922
# train_discrete_score_W0_a  0.07065978318761866
# test_discrete_score_W0_p 0.7341772151898734
# test_discrete_score_W0_n 0.09675461128268308
# test_discrete_score_W0_a 0.18897436736831769
# train_discrete_score_W_discrete_p 0.9688346883468835
# train_discrete_score_W_discrete_n 0.7808737209623497
# train_discrete_score_W_discrete_a 0.8766528472733124
# test_discrete_score_W_discrete_p 0.9683544303797469
# test_discrete_score_W_discrete_n 0.7767794078584399
# test_discrete_score_W_discrete_a 0.8741553084040761
# neuron unit number: 47
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.005833617209298312
# train_discrete_score_W0_a  0.017286724830400557
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.039788134292166884
# test_discrete_score_W0_a 0.0705028132237252
# train_discrete_score_W_discrete_p 0.989159891598916
# train_discrete_score_W_discrete_n 0.9098332476200366
# train_discrete_score_W_discrete_a 0.9560767592727497
# test_discrete_score_W_discrete_p 0.9968354430379747
# test_discrete_score_W_discrete_n 0.9692442982690357
# test_discrete_score_W_discrete_a 0.9870551385923925
# neuron unit number: 52
# train_discrete_score_W0_p 0.6924119241192412
# train_discrete_score_W0_n 0.014620087188098587
# train_discrete_score_W0_a  0.04072162776942105
# test_discrete_score_W0_p 0.7215189873417721
# test_discrete_score_W0_n 0.06642144452392444
# test_discrete_score_W0_a 0.14483554901521806
# train_discrete_score_W_discrete_p 0.983739837398374
# train_discrete_score_W_discrete_n 0.8689545354220948
# train_discrete_score_W_discrete_a 0.934516938983012
# test_discrete_score_W_discrete_p 0.9778481012658228
# test_discrete_score_W_discrete_n 0.8329949519408018
# test_discrete_score_W_discrete_a 0.910977026867777
# neuron unit number: 57
# train_discrete_score_W0_p 0.6978319783197832
# train_discrete_score_W0_n 0.01850110628134646
# train_discrete_score_W0_a  0.03497902352080581
# test_discrete_score_W0_p 0.7056962025316456
# test_discrete_score_W0_n 0.0336762053471972
# test_discrete_score_W0_a 0.08124987312644849
# train_discrete_score_W_discrete_p 0.981029810298103
# train_discrete_score_W_discrete_n 0.8580460713372906
# train_discrete_score_W_discrete_a 0.9236690462054509
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.8938446075160607
# test_discrete_score_W_discrete_a 0.9486751061726428
# neuron unit number: 62
# train_discrete_score_W0_p 0.6964769647696477
# train_discrete_score_W0_n 0.019371439813932287
# train_discrete_score_W0_a  0.04710947464987395
# test_discrete_score_W0_p 0.7025316455696202
# test_discrete_score_W0_n 0.024045614031461156
# test_discrete_score_W0_a 0.05441471085036128
# train_discrete_score_W_discrete_p 0.989159891598916
# train_discrete_score_W_discrete_n 0.916280762466273
# train_discrete_score_W_discrete_a 0.9560490061232084
# test_discrete_score_W_discrete_p 0.9968354430379747
# test_discrete_score_W_discrete_n 0.9692442982690357
# test_discrete_score_W_discrete_a 0.9870551385923925
# neuron unit number: 67
# train_discrete_score_W0_p 0.6910569105691057
# train_discrete_score_W0_n 0.004130565956440043
# train_discrete_score_W0_a  0.008624949611198817
# test_discrete_score_W0_p 0.6962025316455697
# test_discrete_score_W0_n 0.016852151735044035
# test_discrete_score_W0_a 0.04648641605465238
# train_discrete_score_W_discrete_p 0.9728997289972899
# train_discrete_score_W_discrete_n 0.8052353077647278
# train_discrete_score_W_discrete_a 0.8923852716760661
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.7975299321960051
# test_discrete_score_W_discrete_a 0.886781921048133
# neuron unit number: 72
# train_discrete_score_W0_p 0.7046070460704607
# train_discrete_score_W0_n 0.033975810555289136
# train_discrete_score_W0_a  0.07692678904499768
# test_discrete_score_W0_p 0.7436708860759493
# test_discrete_score_W0_n 0.10569807633405161
# test_discrete_score_W0_a 0.202351453678205
# train_discrete_score_W_discrete_p 0.9728997289972899
# train_discrete_score_W_discrete_n 0.8093492396363748
# train_discrete_score_W_discrete_a 0.892506735560245
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.8115321626679063
# test_discrete_score_W_discrete_a 0.8870852862376886
# neuron unit number: 77
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.030027360333508692
# train_discrete_score_W0_a  0.0643092637749106
# test_discrete_score_W0_p 0.7658227848101266
# test_discrete_score_W0_n 0.13783854666210732
# test_discrete_score_W0_a 0.23085571179320805
# train_discrete_score_W_discrete_p 1.0
# train_discrete_score_W_discrete_n 1.0
# train_discrete_score_W_discrete_a 1.0
# test_discrete_score_W_discrete_p 1.0
# test_discrete_score_W_discrete_n 1.0
# test_discrete_score_W_discrete_a 1.0
# neuron unit number: 82
# train_discrete_score_W0_p 0.6951219512195121
# train_discrete_score_W0_n 0.017431871065759896
# train_discrete_score_W0_a  0.0439799190396061
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.049863217855883255
# test_discrete_score_W0_a 0.11705720853194311
# train_discrete_score_W_discrete_p 0.9742547425474255
# train_discrete_score_W_discrete_n 0.8139063410550069
# train_discrete_score_W_discrete_a 0.8976528616973549
# test_discrete_score_W_discrete_p 0.9620253164556962
# test_discrete_score_W_discrete_n 0.7483615068893019
# test_discrete_score_W_discrete_a 0.850620736422547
# neuron unit number: 87
# train_discrete_score_W0_p 0.6964769647696477
# train_discrete_score_W0_n 0.02612217767092233
# train_discrete_score_W0_a  0.07019687250898984
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.07400552159349921
# test_discrete_score_W0_a 0.15483133784278896
# train_discrete_score_W_discrete_p 0.9688346883468835
# train_discrete_score_W_discrete_n 0.78334226210847
# train_discrete_score_W_discrete_a 0.8767953525080889
# test_discrete_score_W_discrete_p 0.9683544303797469
# test_discrete_score_W_discrete_n 0.7790460669796498
# test_discrete_score_W_discrete_a 0.8739611034392639
# neuron unit number: 92
# train_discrete_score_W0_p 0.6978319783197832
# train_discrete_score_W0_n 0.02354278288325226
# train_discrete_score_W0_a  0.058757647271282215
# test_discrete_score_W0_p 0.7151898734177216
# test_discrete_score_W0_n 0.05842612364602613
# test_discrete_score_W0_a 0.13307192319425515
# train_discrete_score_W_discrete_p 0.9878048780487805
# train_discrete_score_W_discrete_n 0.8979908340680718
# train_discrete_score_W_discrete_a 0.9506694602284598
# test_discrete_score_W_discrete_p 0.9810126582278481
# test_discrete_score_W_discrete_n 0.8511478462341109
# test_discrete_score_W_discrete_a 0.923506167853458
# neuron unit number: 97
# train_discrete_score_W0_p 0.6937669376693767
# train_discrete_score_W0_n 0.009793035617939524
# train_discrete_score_W0_a  0.013467579716297192
# test_discrete_score_W0_p 0.7056962025316456
# test_discrete_score_W0_n 0.03199264307287009
# test_discrete_score_W0_a 0.07510939453398216
# train_discrete_score_W_discrete_p 0.9566395663956639
# train_discrete_score_W_discrete_n 0.7425991180405843
# train_discrete_score_W_discrete_a 0.8315054895358016
# test_discrete_score_W_discrete_p 0.9746835443037974
# test_discrete_score_W_discrete_n 0.8119458732559599
# test_discrete_score_W_discrete_a 0.8988172689594316
# test_discrete_score_W0_p mean 0.7115506329113923
# test_discrete_score_W_discrete_p mean 0.9648734177215191
# test_discrete_score_W0_n mean 0.043807743341425995
# test_discrete_score_W_discrete_n mean 0.7886220475566513
# test_discrete_score_W0_a mean 0.0919022956956202
# test_discrete_score_W_discrete_a mean 0.8661634880833914
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.012720  0.011396  0.002548   0.007386  0.018053
# 1  train_dis_W_dis  20.0  0.805028  0.132783  0.029691   0.742884  0.867173
# 2         combined  40.0  0.408874  0.411844  0.065118   0.277160  0.540588
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.7923
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -26.5872
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.4076
# 7                                    Hedge's g =   -8.2406
# 8                               Glass's delta1 =  -69.5240
# 9                             Point-Biserial r =   -0.9742
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.043808  0.037608  0.008409   0.026207  0.061409
# 1  test_dis_W_dis  20.0  0.788622  0.154287  0.034500   0.716413  0.860831
# 2        combined  40.0  0.416215  0.393102  0.062155   0.290495  0.541935
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.7448
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -20.9749
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.6328
# 7                                  Hedge's g =   -6.5011
# 8                             Glass's delta1 =  -19.8045
# 9                           Point-Biserial r =   -0.9594
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.030815  0.027594  0.006170   0.017900  0.043729
# 1  train_dis_W_dis  20.0  0.882109  0.104834  0.023442   0.833045  0.931173
# 2         combined  40.0  0.456462  0.437660  0.069200   0.316491  0.596432
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.8513
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -35.1193
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -11.1057
# 7                                    Hedge's g =  -10.8850
# 8                               Glass's delta1 =  -30.8507
# 9                             Point-Biserial r =   -0.9849
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.091902  0.068821  0.015389   0.059693  0.124111
# 1  test_dis_W_dis  20.0  0.866163  0.123374  0.027587   0.808423  0.923904
# 2        combined  40.0  0.479033  0.404272  0.063921   0.349740  0.608325
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.7743
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -24.5104
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.7509
# 7                                  Hedge's g =   -7.5969
# 8                             Glass's delta1 =  -11.2504
# 9                           Point-Biserial r =   -0.9698
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.693835  0.004683  0.001047   0.691643  0.696026
# 1  train_dis_W_dis  20.0  0.969377  0.029737  0.006649   0.955459  0.983294
# 2         combined  40.0  0.831606  0.141099  0.022310   0.786480  0.876731
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2755
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -40.9342
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -12.9445
# 7                                    Hedge's g =  -12.6874
# 8                               Glass's delta1 =  -58.8377
# 9                             Point-Biserial r =   -0.9889
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.711551  0.019216  0.004297   0.702557  0.720544
# 1  test_dis_W_dis  20.0  0.964873  0.035461  0.007929   0.948277  0.981470
# 2        combined  40.0  0.838212  0.131328  0.020765   0.796211  0.880213
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2533
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -28.0886
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.8824
# 7                                  Hedge's g =   -8.7059
# 8                             Glass's delta1 =  -13.1831
# 9                           Point-Biserial r =   -0.9768

# %%
#new baseN
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6613924050632911
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8929539295392954
# train_discrete_score_W_discrete_n 0.4891604463614754
# train_discrete_score_W_discrete_a 0.5946057254486488
# test_discrete_score_W_discrete_p 0.8481012658227848
# test_discrete_score_W_discrete_n 0.34584777293538366
# test_discrete_score_W_discrete_a 0.47527924789419707
# neuron unit number: 7
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6613924050632911
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.9471544715447154
# train_discrete_score_W_discrete_n 0.6679983927589199
# train_discrete_score_W_discrete_a 0.7938908030723577
# test_discrete_score_W_discrete_p 0.9462025316455697
# test_discrete_score_W_discrete_n 0.6830031880464237
# test_discrete_score_W_discrete_a 0.7940317242208007
# neuron unit number: 12
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677215189873418
# test_discrete_score_W0_n 0.012323680694515188
# test_discrete_score_W0_a 0.02541319917669735
# train_discrete_score_W_discrete_p 0.9471544715447154
# train_discrete_score_W_discrete_n 0.6675830939685611
# train_discrete_score_W_discrete_a 0.7935773033090816
# test_discrete_score_W_discrete_p 0.9556962025316456
# test_discrete_score_W_discrete_n 0.7206229686862535
# test_discrete_score_W_discrete_a 0.8283352757921505
# neuron unit number: 17
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6708860759493671
# test_discrete_score_W0_n 0.018297040095412904
# test_discrete_score_W0_a 0.04100936182801846
# train_discrete_score_W_discrete_p 0.994579945799458
# train_discrete_score_W_discrete_n 0.9454139596025041
# train_discrete_score_W_discrete_a 0.9778104001525973
# test_discrete_score_W_discrete_p 0.9936708860759493
# test_discrete_score_W_discrete_n 0.9406345864581427
# test_discrete_score_W_discrete_a 0.9745020229889949
# neuron unit number: 22
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677215189873418
# test_discrete_score_W0_n 0.013337081907063281
# test_discrete_score_W0_a 0.030392913947849088
# train_discrete_score_W_discrete_p 0.9932249322493225
# train_discrete_score_W_discrete_n 0.9416919660346028
# train_discrete_score_W_discrete_a 0.9722482967106043
# test_discrete_score_W_discrete_p 0.9936708860759493
# test_discrete_score_W_discrete_n 0.9472978967508767
# test_discrete_score_W_discrete_a 0.9744801808862665
# neuron unit number: 27
# train_discrete_score_W0_p 0.7046070460704607
# train_discrete_score_W0_n 0.005909903013351033
# train_discrete_score_W0_a  0.01403290534624805
# test_discrete_score_W0_p 0.6740506329113924
# test_discrete_score_W0_n 0.024062770702991353
# test_discrete_score_W0_a 0.0556783613105856
# train_discrete_score_W_discrete_p 0.9796747967479674
# train_discrete_score_W_discrete_n 0.8528273042774548
# train_discrete_score_W_discrete_a 0.9176202704331831
# test_discrete_score_W_discrete_p 0.9683544303797469
# test_discrete_score_W_discrete_n 0.7884925445687763
# test_discrete_score_W_discrete_a 0.8759583464738911
# neuron unit number: 32
# train_discrete_score_W0_p 0.7073170731707317
# train_discrete_score_W0_n 0.0129270627791868
# train_discrete_score_W0_a  0.02910521460379388
# test_discrete_score_W0_p 0.6962025316455697
# test_discrete_score_W0_n 0.05336879640367764
# test_discrete_score_W0_a 0.10149370240533111
# train_discrete_score_W_discrete_p 0.986449864498645
# train_discrete_score_W_discrete_n 0.8984645523251729
# train_discrete_score_W_discrete_a 0.944767095049407
# test_discrete_score_W_discrete_p 0.9810126582278481
# test_discrete_score_W_discrete_n 0.8738271951846784
# test_discrete_score_W_discrete_a 0.9242786089323745
# neuron unit number: 37
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.680379746835443
# test_discrete_score_W0_n 0.031091875214867132
# test_discrete_score_W0_a 0.06106028081933366
# train_discrete_score_W_discrete_p 0.9796747967479674
# train_discrete_score_W_discrete_n 0.8640766826044707
# train_discrete_score_W_discrete_a 0.9184683451615877
# test_discrete_score_W_discrete_p 0.990506329113924
# test_discrete_score_W_discrete_n 0.9179404661661852
# test_discrete_score_W_discrete_a 0.9618906783166725
# neuron unit number: 42
# train_discrete_score_W0_p 0.7073170731707317
# train_discrete_score_W0_n 0.02095322667217496
# train_discrete_score_W0_a  0.057408209226524336
# test_discrete_score_W0_p 0.6867088607594937
# test_discrete_score_W0_n 0.046052452896165864
# test_discrete_score_W0_a 0.10186916252895307
# train_discrete_score_W_discrete_p 0.9959349593495935
# train_discrete_score_W_discrete_n 0.9616507528068
# train_discrete_score_W_discrete_a 0.9833163166786386
# test_discrete_score_W_discrete_p 0.990506329113924
# test_discrete_score_W_discrete_n 0.917702602431167
# test_discrete_score_W_discrete_a 0.9618586747036477
# neuron unit number: 47
# train_discrete_score_W0_p 0.7046070460704607
# train_discrete_score_W0_n 0.0053311285887864615
# train_discrete_score_W0_a  0.0037084196130382032
# test_discrete_score_W0_p 0.6645569620253164
# test_discrete_score_W0_n 0.026853008712389825
# test_discrete_score_W0_a 0.07166283180898048
# train_discrete_score_W_discrete_p 0.991869918699187
# train_discrete_score_W_discrete_n 0.9324211612651997
# train_discrete_score_W_discrete_a 0.9667305308405281
# test_discrete_score_W_discrete_p 0.990506329113924
# test_discrete_score_W_discrete_n 0.9268706220925472
# test_discrete_score_W_discrete_a 0.9618253590417268
# neuron unit number: 52
# train_discrete_score_W0_p 0.7113821138211383
# train_discrete_score_W0_n 0.027818115238667555
# train_discrete_score_W0_a  0.07073556280613238
# test_discrete_score_W0_p 0.7025316455696202
# test_discrete_score_W0_n 0.08244382208735476
# test_discrete_score_W0_a 0.15045484473160758
# train_discrete_score_W_discrete_p 0.989159891598916
# train_discrete_score_W_discrete_n 0.9039581111972557
# train_discrete_score_W_discrete_a 0.9558952525719897
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.8750335275533812
# test_discrete_score_W_discrete_a 0.9368903139322957
# neuron unit number: 57
# train_discrete_score_W0_p 0.7140921409214093
# train_discrete_score_W0_n 0.03028309015344294
# train_discrete_score_W0_a  0.07121186282184516
# test_discrete_score_W0_p 0.7341772151898734
# test_discrete_score_W0_n 0.11522846945458681
# test_discrete_score_W0_a 0.20072578406511946
# train_discrete_score_W_discrete_p 0.9796747967479674
# train_discrete_score_W_discrete_n 0.8528273042774548
# train_discrete_score_W_discrete_a 0.9176202704331831
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.9080720705848483
# test_discrete_score_W_discrete_a 0.9492403008071741
# neuron unit number: 62
# train_discrete_score_W0_p 0.7100271002710027
# train_discrete_score_W0_n 0.0186958070115019
# train_discrete_score_W0_a  0.040025824800210066
# test_discrete_score_W0_p 0.7088607594936709
# test_discrete_score_W0_n 0.07352489725783104
# test_discrete_score_W0_a 0.1419219437888602
# train_discrete_score_W_discrete_p 0.9959349593495935
# train_discrete_score_W_discrete_n 0.9616507528068
# train_discrete_score_W_discrete_a 0.9833163166786386
# test_discrete_score_W_discrete_p 0.9936708860759493
# test_discrete_score_W_discrete_n 0.9472978967508767
# test_discrete_score_W_discrete_a 0.9744801808862665
# neuron unit number: 67
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6867088607594937
# test_discrete_score_W0_n 0.04673638437544773
# test_discrete_score_W0_a 0.10334320530372401
# train_discrete_score_W_discrete_p 1.0
# train_discrete_score_W_discrete_n 1.0
# train_discrete_score_W_discrete_a 1.0
# test_discrete_score_W_discrete_p 1.0
# test_discrete_score_W_discrete_n 1.0
# test_discrete_score_W_discrete_a 1.0
# neuron unit number: 72
# train_discrete_score_W0_p 0.7235772357723578
# train_discrete_score_W0_n 0.049947444620225025
# train_discrete_score_W0_a  0.1126828832930285
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.09058178615797564
# test_discrete_score_W0_a 0.16440275196843546
# train_discrete_score_W_discrete_p 0.986449864498645
# train_discrete_score_W_discrete_n 0.8984645523251729
# train_discrete_score_W_discrete_a 0.944767095049407
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.878519042827958
# test_discrete_score_W_discrete_a 0.9367821440999843
# neuron unit number: 77
# train_discrete_score_W0_p 0.7168021680216802
# train_discrete_score_W0_n 0.03470692905195058
# train_discrete_score_W0_a  0.07811134998297058
# test_discrete_score_W0_p 0.7088607594936709
# test_discrete_score_W0_n 0.07993569374539053
# test_discrete_score_W0_a 0.1527337949426405
# train_discrete_score_W_discrete_p 0.991869918699187
# train_discrete_score_W_discrete_n 0.9324211612651997
# train_discrete_score_W_discrete_a 0.9667305308405281
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.9080720705848483
# test_discrete_score_W_discrete_a 0.9492403008071741
# neuron unit number: 82
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6867088607594937
# test_discrete_score_W0_n 0.046052452896165864
# test_discrete_score_W0_a 0.10186916252895307
# train_discrete_score_W_discrete_p 0.9471544715447154
# train_discrete_score_W_discrete_n 0.6801565228450842
# train_discrete_score_W_discrete_a 0.7951898970608031
# test_discrete_score_W_discrete_p 0.9620253164556962
# test_discrete_score_W_discrete_n 0.7526269675667233
# test_discrete_score_W_discrete_a 0.8520061571960083
# neuron unit number: 87
# train_discrete_score_W0_p 0.7140921409214093
# train_discrete_score_W0_n 0.0306839296774557
# train_discrete_score_W0_a  0.07280820347189677
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.10035280897428973
# test_discrete_score_W0_a 0.177675290289467
# train_discrete_score_W_discrete_p 0.983739837398374
# train_discrete_score_W_discrete_n 0.8828734517270401
# train_discrete_score_W_discrete_a 0.933849557582165
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.8972975840820756
# test_discrete_score_W_discrete_a 0.9492854550096508
# neuron unit number: 92
# train_discrete_score_W0_p 0.7086720867208672
# train_discrete_score_W0_n 0.022405769287955127
# train_discrete_score_W0_a  0.059157612024151734
# test_discrete_score_W0_p 0.7215189873417721
# test_discrete_score_W0_n 0.10200130798786713
# test_discrete_score_W0_a 0.18075236181803755
# train_discrete_score_W_discrete_p 0.997289972899729
# train_discrete_score_W_discrete_n 0.9726454021737693
# train_discrete_score_W_discrete_a 0.9888666283651696
# test_discrete_score_W_discrete_p 0.9968354430379747
# test_discrete_score_W_discrete_n 0.9702557204702864
# test_discrete_score_W_discrete_a 0.987204986721671
# neuron unit number: 97
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6740506329113924
# test_discrete_score_W0_n 0.03147577532440646
# test_discrete_score_W0_a 0.07807109970155907
# train_discrete_score_W_discrete_p 0.991869918699187
# train_discrete_score_W_discrete_n 0.9265273090522079
# train_discrete_score_W_discrete_a 0.9667561537981099
# test_discrete_score_W_discrete_p 0.9778481012658228
# test_discrete_score_W_discrete_n 0.8383840239576338
# test_discrete_score_W_discrete_a 0.9120641657159267
# test_discrete_score_W0_p mean 0.6897151898734177
# test_discrete_score_W_discrete_p mean 0.9759493670886077
# test_discrete_score_W0_n mean 0.04968600524441995
# test_discrete_score_W_discrete_n mean 0.8518899373849532
# test_discrete_score_W0_a mean 0.09702650264820764
# test_discrete_score_W_discrete_a mean 0.9089817062213437
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.012983  0.015358  0.003434   0.005795  0.020171
# 1  train_dis_W_dis  20.0  0.861641  0.132004  0.029517   0.799861  0.923420
# 2         combined  40.0  0.437312  0.439631  0.069512   0.296711  0.577913
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.8487
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -28.5589
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -9.0311
# 7                                    Hedge's g =   -8.8517
# 8                               Glass's delta1 =  -55.2580
# 9                             Point-Biserial r =   -0.9775
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.049686  0.035816  0.008009   0.032924  0.066448
# 1  test_dis_W_dis  20.0  0.851890  0.145518  0.032539   0.783786  0.919994
# 2        combined  40.0  0.450788  0.419463  0.066323   0.316637  0.584939
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.8022
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -23.9394
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.5703
# 7                                  Hedge's g =   -7.4199
# 8                             Glass's delta1 =  -22.3981
# 9                           Point-Biserial r =   -0.9684
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.030449  0.036336  0.008125   0.013443  0.047455
# 1  train_dis_W_dis  20.0  0.915801  0.099340  0.022213   0.869309  0.962294
# 2         combined  40.0  0.473125  0.454354  0.071840   0.327816  0.618435
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.8854
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -37.4318
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -11.8370
# 7                                    Hedge's g =  -11.6018
# 8                               Glass's delta1 =  -24.3654
# 9                             Point-Biserial r =   -0.9867
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.097027  0.061741  0.013806   0.068131  0.125922
# 1  test_dis_W_dis  20.0  0.908982  0.115730  0.025878   0.854818  0.963145
# 2        combined  40.0  0.503004  0.421220  0.066601   0.368291  0.637717
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.8120
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -27.6830
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.7541
# 7                                  Hedge's g =   -8.5802
# 8                             Glass's delta1 =  -13.1509
# 9                           Point-Biserial r =   -0.9761
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.707588  0.005776  0.001291   0.704885  0.710291
# 1  train_dis_W_dis  20.0  0.978591  0.026129  0.005843   0.966362  0.990820
# 2         combined  40.0  0.843089  0.138493  0.021898   0.798797  0.887382
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2710
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -45.2899
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -14.3219
# 7                                    Hedge's g =  -14.0374
# 8                               Glass's delta1 =  -46.9214
# 9                             Point-Biserial r =   -0.9909
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.689715  0.022992  0.005141   0.678955  0.700476
# 1  test_dis_W_dis  20.0  0.975949  0.033276  0.007441   0.960376  0.991523
# 2        combined  40.0  0.832832  0.147664  0.023348   0.785607  0.880058
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2862
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -31.6488
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -10.0082
# 7                                  Hedge's g =   -9.8094
# 8                             Glass's delta1 =  -12.4493
# 9                           Point-Biserial r =   -0.9816

# %%
#new one hot encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8387533875338753
# train_discrete_score_W_discrete_n 0.31944142985540835
# train_discrete_score_W_discrete_a 0.4501002767066935
# test_discrete_score_W_discrete_p 0.879746835443038
# test_discrete_score_W_discrete_n 0.4047314666424305
# test_discrete_score_W_discrete_a 0.5589405956894457
# neuron unit number: 7
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.9701897018970189
# train_discrete_score_W_discrete_n 0.7905152650347306
# train_discrete_score_W_discrete_a 0.8822648864202781
# test_discrete_score_W_discrete_p 0.9620253164556962
# test_discrete_score_W_discrete_n 0.7435067212340277
# test_discrete_score_W_discrete_a 0.8457917004339524
# neuron unit number: 12
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.9715447154471545
# train_discrete_score_W_discrete_n 0.8010884498854234
# train_discrete_score_W_discrete_a 0.8877510861871587
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.8845075203174615
# test_discrete_score_W_discrete_a 0.935295086605227
# neuron unit number: 17
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.9905149051490515
# train_discrete_score_W_discrete_n 0.9258524294828033
# train_discrete_score_W_discrete_a 0.9617254355768687
# test_discrete_score_W_discrete_p 0.990506329113924
# test_discrete_score_W_discrete_n 0.9211948556493627
# test_discrete_score_W_discrete_a 0.9605608891150691
# neuron unit number: 22
# train_discrete_score_W0_p 0.6775067750677507
# train_discrete_score_W0_n 0.004876253427507708
# train_discrete_score_W0_a  0.011788851873970505
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.017011224952043665
# test_discrete_score_W0_a 0.05094978336170556
# train_discrete_score_W_discrete_p 0.978319783197832
# train_discrete_score_W_discrete_n 0.8481820319578406
# train_discrete_score_W_discrete_a 0.9139756200176352
# test_discrete_score_W_discrete_p 0.9810126582278481
# test_discrete_score_W_discrete_n 0.846317131969924
# test_discrete_score_W_discrete_a 0.922342815977127
# neuron unit number: 27
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.009073161757856956
# train_discrete_score_W0_a  0.02797373654043467
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.02671160177127189
# test_discrete_score_W0_a 0.07455991141500536
# train_discrete_score_W_discrete_p 0.907859078590786
# train_discrete_score_W_discrete_n 0.5387019038135391
# train_discrete_score_W_discrete_a 0.661690479230688
# test_discrete_score_W_discrete_p 0.9525316455696202
# test_discrete_score_W_discrete_n 0.704867007454981
# test_discrete_score_W_discrete_a 0.8129216212103308
# neuron unit number: 32
# train_discrete_score_W0_p 0.6829268292682927
# train_discrete_score_W0_n 0.017535992979117412
# train_discrete_score_W0_a  0.04314182718655739
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.017372688585638743
# test_discrete_score_W0_a 0.04483323322353419
# train_discrete_score_W_discrete_p 0.9634146341463414
# train_discrete_score_W_discrete_n 0.7565384301765106
# train_discrete_score_W_discrete_a 0.8568225857903968
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.8145388559171881
# test_discrete_score_W_discrete_a 0.8830456889999176
# neuron unit number: 37
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7310126582278481
# test_discrete_score_W0_n 0.019589537315937034
# test_discrete_score_W0_a 0.03817491680674308
# train_discrete_score_W_discrete_p 0.9769647696476965
# train_discrete_score_W_discrete_n 0.8387431934961252
# train_discrete_score_W_discrete_a 0.9081772229119502
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.881945456915477
# test_discrete_score_W_discrete_a 0.9345236526152262
# neuron unit number: 42
# train_discrete_score_W0_p 0.6829268292682927
# train_discrete_score_W0_n 0.016610048886274924
# train_discrete_score_W0_a  0.039405357549530756
# test_discrete_score_W0_p 0.7373417721518988
# test_discrete_score_W0_n 0.04802366506944684
# test_discrete_score_W0_a 0.1182662213503657
# train_discrete_score_W_discrete_p 0.9742547425474255
# train_discrete_score_W_discrete_n 0.838375404689471
# train_discrete_score_W_discrete_a 0.8974938298751394
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.8708552645985903
# test_discrete_score_W_discrete_a 0.9351508867522261
# neuron unit number: 47
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.013660841940943233
# test_discrete_score_W0_a 0.04059758195896735
# train_discrete_score_W_discrete_p 0.9634146341463414
# train_discrete_score_W_discrete_n 0.763915617633466
# train_discrete_score_W_discrete_a 0.856032722298477
# test_discrete_score_W_discrete_p 0.9588607594936709
# test_discrete_score_W_discrete_n 0.7166691263006588
# test_discrete_score_W_discrete_a 0.8345573399619353
# neuron unit number: 52
# train_discrete_score_W0_p 0.6856368563685636
# train_discrete_score_W0_n 0.02141126463364156
# train_discrete_score_W0_a  0.04998115353398743
# test_discrete_score_W0_p 0.7436708860759493
# test_discrete_score_W0_n 0.06294829696169797
# test_discrete_score_W0_a 0.1467716777759761
# train_discrete_score_W_discrete_p 0.9959349593495935
# train_discrete_score_W_discrete_n 0.9588426994782968
# train_discrete_score_W_discrete_a 0.9835390655861074
# test_discrete_score_W_discrete_p 0.990506329113924
# test_discrete_score_W_discrete_n 0.9211948556493627
# test_discrete_score_W_discrete_a 0.9605608891150691
# neuron unit number: 57
# train_discrete_score_W0_p 0.6829268292682927
# train_discrete_score_W0_n 0.01980271076376123
# train_discrete_score_W0_a  0.05148572823980471
# test_discrete_score_W0_p 0.75
# test_discrete_score_W0_n 0.06833326145135574
# test_discrete_score_W0_a 0.14635185181978888
# train_discrete_score_W_discrete_p 0.975609756097561
# train_discrete_score_W_discrete_n 0.8368054613710872
# train_discrete_score_W_discrete_a 0.9028331476477806
# test_discrete_score_W_discrete_p 0.9746835443037974
# test_discrete_score_W_discrete_n 0.8080808954085333
# test_discrete_score_W_discrete_a 0.8963797811253753
# neuron unit number: 62
# train_discrete_score_W0_p 0.6788617886178862
# train_discrete_score_W0_n 0.008001026961969096
# train_discrete_score_W0_a  0.018915440968093784
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.02824067247867403
# test_discrete_score_W0_a 0.07909608201323107
# train_discrete_score_W_discrete_p 0.9986449864498645
# train_discrete_score_W_discrete_n 0.9852619589786463
# train_discrete_score_W_discrete_a 0.9944954645188617
# test_discrete_score_W_discrete_p 1.0
# test_discrete_score_W_discrete_n 1.0
# test_discrete_score_W_discrete_a 1.0
# neuron unit number: 67
# train_discrete_score_W0_p 0.6775067750677507
# train_discrete_score_W0_n 0.005727947174812086
# train_discrete_score_W0_a  0.014637557380495516
# test_discrete_score_W0_p 0.7310126582278481
# test_discrete_score_W0_n 0.027505972289153344
# test_discrete_score_W0_a 0.06958259747271348
# train_discrete_score_W_discrete_p 0.9905149051490515
# train_discrete_score_W_discrete_n 0.917098187676324
# train_discrete_score_W_discrete_a 0.961763406687566
# test_discrete_score_W_discrete_p 0.9968354430379747
# test_discrete_score_W_discrete_n 0.967930066777395
# test_discrete_score_W_discrete_a 0.9868019029747359
# neuron unit number: 72
# train_discrete_score_W0_p 0.7032520325203252
# train_discrete_score_W0_n 0.047953327273299935
# train_discrete_score_W0_a  0.0949793669941943
# test_discrete_score_W0_p 0.7341772151898734
# test_discrete_score_W0_n 0.04423180286631821
# test_discrete_score_W0_a 0.11343136107534325
# train_discrete_score_W_discrete_p 0.9769647696476965
# train_discrete_score_W_discrete_n 0.8514832397972776
# train_discrete_score_W_discrete_a 0.9080790267860829
# test_discrete_score_W_discrete_p 0.9746835443037974
# test_discrete_score_W_discrete_n 0.8150435813003545
# test_discrete_score_W_discrete_a 0.8961149619044024
# neuron unit number: 77
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.025974477127108476
# train_discrete_score_W0_a  0.04872174437068825
# test_discrete_score_W0_p 0.7436708860759493
# test_discrete_score_W0_n 0.0688087470726226
# test_discrete_score_W0_a 0.1599855745196067
# train_discrete_score_W_discrete_p 0.9769647696476965
# train_discrete_score_W_discrete_n 0.8387431934961252
# train_discrete_score_W_discrete_a 0.9081772229119502
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.786923531988512
# test_discrete_score_W_discrete_a 0.8839507312299637
# neuron unit number: 82
# train_discrete_score_W0_p 0.6842818428184282
# train_discrete_score_W0_n 0.018742948186834512
# train_discrete_score_W0_a  0.04348884293503817
# test_discrete_score_W0_p 0.7310126582278481
# test_discrete_score_W0_n 0.021962431575202845
# test_discrete_score_W0_a 0.04917101032623372
# train_discrete_score_W_discrete_p 0.994579945799458
# train_discrete_score_W_discrete_n 0.9531490775844107
# train_discrete_score_W_discrete_a 0.9780973251422773
# test_discrete_score_W_discrete_p 0.9968354430379747
# test_discrete_score_W_discrete_n 0.9680774319581378
# test_discrete_score_W_discrete_a 0.9868331436430218
# neuron unit number: 87
# train_discrete_score_W0_p 0.6856368563685636
# train_discrete_score_W0_n 0.02284716272174187
# train_discrete_score_W0_a  0.05586091277919511
# test_discrete_score_W0_p 0.7373417721518988
# test_discrete_score_W0_n 0.04802366506944684
# test_discrete_score_W0_a 0.1182662213503657
# train_discrete_score_W_discrete_p 0.9715447154471545
# train_discrete_score_W_discrete_n 0.8049714878795201
# train_discrete_score_W_discrete_a 0.8872011459072559
# test_discrete_score_W_discrete_p 0.9746835443037974
# test_discrete_score_W_discrete_n 0.8303768974678016
# test_discrete_score_W_discrete_a 0.89584176257381
# neuron unit number: 92
# train_discrete_score_W0_p 0.6829268292682927
# train_discrete_score_W0_n 0.015453561377256005
# train_discrete_score_W0_a  0.03426890165989037
# test_discrete_score_W0_p 0.7341772151898734
# test_discrete_score_W0_n 0.048695960109903985
# test_discrete_score_W0_a 0.12467474193985993
# train_discrete_score_W_discrete_p 0.9932249322493225
# train_discrete_score_W_discrete_n 0.9364325686812452
# train_discrete_score_W_discrete_a 0.9726266994051943
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.8893639313803501
# test_discrete_score_W_discrete_a 0.9476469760489376
# neuron unit number: 97
# train_discrete_score_W0_p 0.6761517615176151
# train_discrete_score_W0_n 0.0030764297740264426
# train_discrete_score_W0_a  0.00890004881079263
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.011054152506630131
# test_discrete_score_W0_a 0.022392195158224156
# train_discrete_score_W_discrete_p 0.991869918699187
# train_discrete_score_W_discrete_n 0.9264999109087496
# train_discrete_score_W_discrete_a 0.9671889294171621
# test_discrete_score_W_discrete_p 0.9968354430379747
# test_discrete_score_W_discrete_n 0.967930066777395
# test_discrete_score_W_discrete_a 0.9868019029747359
# test_discrete_score_W0_p mean 0.7316455696202532
# test_discrete_score_W_discrete_p mean 0.9756329113924049
# test_discrete_score_W0_n mean 0.02860872610081435
# test_discrete_score_W_discrete_n mean 0.8372027332853971
# test_discrete_score_W0_a mean 0.06985524807838323
# test_discrete_score_W_discrete_a mean 0.9032031164475255
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.011854  0.012402  0.002773   0.006050  0.017658
# 1  train_dis_W_dis  20.0  0.821532  0.154106  0.034459   0.749408  0.893656
# 2         combined  40.0  0.416693  0.423960  0.067034   0.281104  0.552282
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.8097
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -23.4211
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -7.4064
# 7                                    Hedge's g =   -7.2592
# 8                               Glass's delta1 =  -65.2882
# 9                             Point-Biserial r =   -0.9671
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.028609  0.022909  0.005123   0.017887  0.039330
# 1  test_dis_W_dis  20.0  0.837203  0.132263  0.029575   0.775302  0.899104
# 2        combined  40.0  0.432906  0.420030  0.066413   0.298574  0.567238
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.8086
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -26.9395
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.5190
# 7                                  Hedge's g =   -8.3498
# 8                             Glass's delta1 =  -35.2963
# 9                           Point-Biserial r =   -0.9748
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.027177  0.026101  0.005836   0.014962  0.039393
# 1  train_dis_W_dis  20.0  0.887002  0.125672  0.028101   0.828185  0.945818
# 2         combined  40.0  0.457090  0.444511  0.070283   0.314928  0.599251
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.8598
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -29.9581
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -9.4736
# 7                                    Hedge's g =   -9.2854
# 8                               Glass's delta1 =  -32.9418
# 9                             Point-Biserial r =   -0.9795
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.069855  0.053623  0.011990   0.044759  0.094952
# 1  test_dis_W_dis  20.0  0.903203  0.096763  0.021637   0.857917  0.948490
# 2        combined  40.0  0.486529  0.428989  0.067829   0.349332  0.623726
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.8333
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -33.6882
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -10.6531
# 7                                  Hedge's g =  -10.4415
# 8                             Glass's delta1 =  -15.5409
# 9                           Point-Biserial r =   -0.9837
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.681165  0.006712  0.001501   0.678024  0.684307
# 1  train_dis_W_dis  20.0  0.970054  0.036563  0.008176   0.952942  0.987166
# 2         combined  40.0  0.825610  0.148568  0.023491   0.778095  0.873124
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2889
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -34.7545
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -10.9903
# 7                                    Hedge's g =  -10.7720
# 8                               Glass's delta1 =  -43.0406
# 9                             Point-Biserial r =   -0.9846
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.731646  0.007446  0.001665   0.728161  0.735131
# 1  test_dis_W_dis  20.0  0.975633  0.026158  0.005849   0.963391  0.987875
# 2        combined  40.0  0.853639  0.124998  0.019764   0.813663  0.893615
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2440
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -40.1195
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -12.6869
# 7                                  Hedge's g =  -12.4348
# 8                             Glass's delta1 =  -32.7660
# 9                           Point-Biserial r =   -0.9884

# %%
# new sum encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8644986449864499
# train_discrete_score_W_discrete_n 0.3876126367124
# train_discrete_score_W_discrete_a 0.52341641943458
# test_discrete_score_W_discrete_p 0.8575949367088608
# test_discrete_score_W_discrete_n 0.3484635545984631
# test_discrete_score_W_discrete_a 0.49371011433801143
# neuron unit number: 7
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8915989159891599
# train_discrete_score_W_discrete_n 0.4642604247464275
# train_discrete_score_W_discrete_a 0.6057272920237019
# test_discrete_score_W_discrete_p 0.9177215189873418
# test_discrete_score_W_discrete_n 0.5478071966611513
# test_discrete_score_W_discrete_a 0.689416929147625
# neuron unit number: 12
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8915989159891599
# train_discrete_score_W_discrete_n 0.4653819196767302
# train_discrete_score_W_discrete_a 0.6003213790016473
# test_discrete_score_W_discrete_p 0.9050632911392406
# test_discrete_score_W_discrete_n 0.4995045614869531
# test_discrete_score_W_discrete_a 0.6453905532696297
# neuron unit number: 17
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7025316455696202
# test_discrete_score_W0_n 0.01576345863180432
# test_discrete_score_W0_a 0.042294080550490575
# train_discrete_score_W_discrete_p 0.9105691056910569
# train_discrete_score_W_discrete_n 0.594032847635542
# train_discrete_score_W_discrete_a 0.6716356953236675
# test_discrete_score_W_discrete_p 0.8987341772151899
# test_discrete_score_W_discrete_n 0.5161592801979191
# test_discrete_score_W_discrete_a 0.6302805907048661
# neuron unit number: 22
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.005126888405237057
# train_discrete_score_W0_a  0.015115985515610525
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.013895936637168352
# test_discrete_score_W0_a 0.0422167709499383
# train_discrete_score_W_discrete_p 0.9349593495934959
# train_discrete_score_W_discrete_n 0.6550935830235933
# train_discrete_score_W_discrete_a 0.7537582084575779
# test_discrete_score_W_discrete_p 0.9208860759493671
# test_discrete_score_W_discrete_n 0.5845315632807687
# test_discrete_score_W_discrete_a 0.7031406075638481
# neuron unit number: 27
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7151898734177216
# test_discrete_score_W0_n 0.040510495469240085
# test_discrete_score_W0_a 0.094182881477407
# train_discrete_score_W_discrete_p 0.9010840108401084
# train_discrete_score_W_discrete_n 0.4919980357063247
# train_discrete_score_W_discrete_a 0.6347882397351964
# test_discrete_score_W_discrete_p 0.9335443037974683
# test_discrete_score_W_discrete_n 0.6097733195973121
# test_discrete_score_W_discrete_a 0.7437385528609572
# neuron unit number: 32
# train_discrete_score_W0_p 0.6937669376693767
# train_discrete_score_W0_n 0.015289860379529927
# train_discrete_score_W0_a  0.02772614313902469
# test_discrete_score_W0_p 0.7088607594936709
# test_discrete_score_W0_n 0.03434757934230652
# test_discrete_score_W0_a 0.0884917466373597
# train_discrete_score_W_discrete_p 0.9390243902439024
# train_discrete_score_W_discrete_n 0.640581872202021
# train_discrete_score_W_discrete_a 0.7649429145143654
# test_discrete_score_W_discrete_p 0.9493670886075949
# test_discrete_score_W_discrete_n 0.6885816400640457
# test_discrete_score_W_discrete_a 0.8031937436805618
# neuron unit number: 37
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0006396372174886936
# train_discrete_score_W0_a  0.0017401944204439258
# test_discrete_score_W0_p 0.7025316455696202
# test_discrete_score_W0_n 0.030666662830265434
# test_discrete_score_W0_a 0.0859407357657035
# train_discrete_score_W_discrete_p 0.978319783197832
# train_discrete_score_W_discrete_n 0.8345326398551958
# train_discrete_score_W_discrete_a 0.913377810682552
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.8907817673411764
# test_discrete_score_W_discrete_a 0.9485931468934
# neuron unit number: 42
# train_discrete_score_W0_p 0.6910569105691057
# train_discrete_score_W0_n 0.013877939820320016
# train_discrete_score_W0_a  0.035257999621764034
# test_discrete_score_W0_p 0.7088607594936709
# test_discrete_score_W0_n 0.03223734491695334
# test_discrete_score_W0_a 0.08224782799834825
# train_discrete_score_W_discrete_p 0.9579945799457995
# train_discrete_score_W_discrete_n 0.7278851189347012
# train_discrete_score_W_discrete_a 0.8359775034666801
# test_discrete_score_W_discrete_p 0.9778481012658228
# test_discrete_score_W_discrete_n 0.8335993025379573
# test_discrete_score_W_discrete_a 0.9111142180272561
# neuron unit number: 47
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0006396372174886936
# train_discrete_score_W0_a  0.0017401944204439258
# test_discrete_score_W0_p 0.6993670886075949
# test_discrete_score_W0_n 0.010168924665650841
# test_discrete_score_W0_a 0.03051900400828532
# train_discrete_score_W_discrete_p 0.9607046070460704
# train_discrete_score_W_discrete_n 0.7520590280718037
# train_discrete_score_W_discrete_a 0.8448176016068811
# test_discrete_score_W_discrete_p 0.9620253164556962
# test_discrete_score_W_discrete_n 0.7429703877945649
# test_discrete_score_W_discrete_a 0.8492289904810734
# neuron unit number: 52
# train_discrete_score_W0_p 0.6964769647696477
# train_discrete_score_W0_n 0.024439056206068874
# train_discrete_score_W0_a  0.05878616609723393
# test_discrete_score_W0_p 0.7183544303797469
# test_discrete_score_W0_n 0.04621195001421769
# test_discrete_score_W0_a 0.1049013367281986
# train_discrete_score_W_discrete_p 0.948509485094851
# train_discrete_score_W_discrete_n 0.7049622757778811
# train_discrete_score_W_discrete_a 0.8018803157789741
# test_discrete_score_W_discrete_p 0.9493670886075949
# test_discrete_score_W_discrete_n 0.7407468538578157
# test_discrete_score_W_discrete_a 0.8044969002746869
# neuron unit number: 57
# train_discrete_score_W0_p 0.6937669376693767
# train_discrete_score_W0_n 0.016491451893615117
# train_discrete_score_W0_a  0.03548210925221574
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.0667905171841675
# test_discrete_score_W0_a 0.14844639436760876
# train_discrete_score_W_discrete_p 0.9661246612466124
# train_discrete_score_W_discrete_n 0.7801340981200826
# train_discrete_score_W_discrete_a 0.8655562739850385
# test_discrete_score_W_discrete_p 0.9778481012658228
# test_discrete_score_W_discrete_n 0.8335993025379573
# test_discrete_score_W_discrete_a 0.9111142180272561
# neuron unit number: 62
# train_discrete_score_W0_p 0.6897018970189702
# train_discrete_score_W0_n 0.009396257523777434
# train_discrete_score_W0_a  0.022973270163800553
# test_discrete_score_W0_p 0.7215189873417721
# test_discrete_score_W0_n 0.05557507786404568
# test_discrete_score_W0_a 0.12656387147445444
# train_discrete_score_W_discrete_p 0.943089430894309
# train_discrete_score_W_discrete_n 0.6702146616947521
# train_discrete_score_W_discrete_a 0.7819660697262375
# test_discrete_score_W_discrete_p 0.930379746835443
# test_discrete_score_W_discrete_n 0.6094471013059842
# test_discrete_score_W_discrete_a 0.7351837609762178
# neuron unit number: 67
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.0018479862841886067
# train_discrete_score_W0_a  0.005174348591540966
# test_discrete_score_W0_p 0.7151898734177216
# test_discrete_score_W0_n 0.03737680364075894
# test_discrete_score_W0_a 0.08097791902494066
# train_discrete_score_W_discrete_p 0.9024390243902439
# train_discrete_score_W_discrete_n 0.5721841524782176
# train_discrete_score_W_discrete_a 0.630813470702725
# test_discrete_score_W_discrete_p 0.939873417721519
# test_discrete_score_W_discrete_n 0.6599996449165042
# test_discrete_score_W_discrete_a 0.7643477673891225
# neuron unit number: 72
# train_discrete_score_W0_p 0.7086720867208672
# train_discrete_score_W0_n 0.050478728273342606
# train_discrete_score_W0_a  0.11644336629585032
# test_discrete_score_W0_p 0.7310126582278481
# test_discrete_score_W0_n 0.07644099239842843
# test_discrete_score_W0_a 0.16292618367843456
# train_discrete_score_W_discrete_p 0.940379403794038
# train_discrete_score_W_discrete_n 0.6488319759247806
# train_discrete_score_W_discrete_a 0.7716587702815428
# test_discrete_score_W_discrete_p 0.9462025316455697
# test_discrete_score_W_discrete_n 0.6648216682493262
# test_discrete_score_W_discrete_a 0.7901011257078907
# neuron unit number: 77
# train_discrete_score_W0_p 0.6937669376693767
# train_discrete_score_W0_n 0.0181463022782713
# train_discrete_score_W0_a  0.042895762098727024
# test_discrete_score_W0_p 0.7373417721518988
# test_discrete_score_W0_n 0.08236324650033644
# test_discrete_score_W0_a 0.16896586632708166
# train_discrete_score_W_discrete_p 0.9634146341463414
# train_discrete_score_W_discrete_n 0.7781945808142006
# train_discrete_score_W_discrete_a 0.8549166624689909
# test_discrete_score_W_discrete_p 0.9683544303797469
# test_discrete_score_W_discrete_n 0.7751434157225335
# test_discrete_score_W_discrete_a 0.873746235888023
# neuron unit number: 82
# train_discrete_score_W0_p 0.6910569105691057
# train_discrete_score_W0_n 0.009548269860253696
# train_discrete_score_W0_a  0.01646131468376849
# test_discrete_score_W0_p 0.7183544303797469
# test_discrete_score_W0_n 0.05758058071432189
# test_discrete_score_W0_a 0.1341877627732566
# train_discrete_score_W_discrete_p 0.948509485094851
# train_discrete_score_W_discrete_n 0.6823041967815453
# train_discrete_score_W_discrete_a 0.7996952349548452
# test_discrete_score_W_discrete_p 0.9556962025316456
# test_discrete_score_W_discrete_n 0.7099153622157313
# test_discrete_score_W_discrete_a 0.8258428085459096
# neuron unit number: 87
# train_discrete_score_W0_p 0.6951219512195121
# train_discrete_score_W0_n 0.02149703610085748
# train_discrete_score_W0_a  0.0516441033033888
# test_discrete_score_W0_p 0.7468354430379747
# test_discrete_score_W0_n 0.09842925989015174
# test_discrete_score_W0_a 0.19196297697436013
# train_discrete_score_W_discrete_p 0.9539295392953929
# train_discrete_score_W_discrete_n 0.7055957433868403
# train_discrete_score_W_discrete_a 0.820091797788149
# test_discrete_score_W_discrete_p 0.9651898734177216
# test_discrete_score_W_discrete_n 0.7586720336784556
# test_discrete_score_W_discrete_a 0.8619140328211706
# neuron unit number: 92
# train_discrete_score_W0_p 0.6910569105691057
# train_discrete_score_W0_n 0.013470230810655329
# train_discrete_score_W0_a  0.03376809436758479
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.0704078002047065
# test_discrete_score_W0_a 0.15344426295301078
# train_discrete_score_W_discrete_p 0.9661246612466124
# train_discrete_score_W_discrete_n 0.7901596301617969
# train_discrete_score_W_discrete_a 0.8653771378297689
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.869564995963569
# test_discrete_score_W_discrete_a 0.9358949684826775
# neuron unit number: 97
# train_discrete_score_W0_p 0.6883468834688347
# train_discrete_score_W0_n 0.0040241256496373265
# train_discrete_score_W0_a  0.008374258352588131
# test_discrete_score_W0_p 0.7025316455696202
# test_discrete_score_W0_n 0.016918665678633753
# test_discrete_score_W0_a 0.046126228205045756
# train_discrete_score_W_discrete_p 0.9512195121951219
# train_discrete_score_W_discrete_n 0.6975339502521993
# train_discrete_score_W_discrete_a 0.8110217593186779
# test_discrete_score_W_discrete_p 0.9462025316455697
# test_discrete_score_W_discrete_n 0.6762736952998883
# test_discrete_score_W_discrete_a 0.7917412060966081
# test_discrete_score_W0_p mean 0.7139240506329114
# test_discrete_score_W_discrete_p mean 0.9436708860759493
# test_discrete_score_W0_n mean 0.03928426482915788
# test_discrete_score_W_discrete_n mean 0.6780178323654039
# test_discrete_score_W0_a mean 0.08921979249469623
# test_discrete_score_W_discrete_a mean 0.7856095235588396
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.010246  0.012446  0.002783   0.004421  0.016071
# 1  train_dis_W_dis  20.0  0.652178  0.122469  0.027385   0.594860  0.709495
# 2         combined  40.0  0.331212  0.336219  0.053161   0.223684  0.438740
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.6419
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -23.3210
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -7.3747
# 7                                    Hedge's g =   -7.2282
# 8                               Glass's delta1 =  -51.5764
# 9                             Point-Biserial r =   -0.9668
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.039284  0.029413  0.006577   0.025519  0.053050
# 1  test_dis_W_dis  20.0  0.678018  0.137232  0.030686   0.613791  0.742244
# 2        combined  40.0  0.358651  0.337945  0.053434   0.250571  0.466731
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.6387
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -20.3530
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.4362
# 7                                  Hedge's g =   -6.3083
# 8                             Glass's delta1 =  -21.7164
# 9                           Point-Biserial r =   -0.9571
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.023679  0.028882  0.006458   0.010162  0.037196
# 1  train_dis_W_dis  20.0  0.757587  0.108410  0.024241   0.706850  0.808324
# 2         combined  40.0  0.390633  0.379789  0.060050   0.269171  0.512096
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.7339
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -29.2549
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -9.2512
# 7                                    Hedge's g =   -9.0674
# 8                               Glass's delta1 =  -25.4105
# 9                             Point-Biserial r =   -0.9785
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.089220  0.059556  0.013317   0.061347  0.117093
# 1  test_dis_W_dis  20.0  0.785610  0.114806  0.025671   0.731879  0.839340
# 2        combined  40.0  0.437415  0.364002  0.057554   0.321001  0.553828
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.6964
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -24.0799
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.6147
# 7                                  Hedge's g =   -7.4634
# 8                             Glass's delta1 =  -11.6931
# 9                           Point-Biserial r =   -0.9688
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.690786  0.005305  0.001186   0.688303  0.693269
# 1  train_dis_W_dis  20.0  0.935705  0.031156  0.006967   0.921123  0.950286
# 2         combined  40.0  0.813245  0.125966  0.019917   0.772959  0.853531
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2449
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -34.6570
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -10.9595
# 7                                    Hedge's g =  -10.7418
# 8                               Glass's delta1 =  -46.1700
# 9                             Point-Biserial r =   -0.9845
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.713924  0.014204  0.003176   0.707276  0.720572
# 1  test_dis_W_dis  20.0  0.943671  0.032380  0.007240   0.928517  0.958825
# 2        combined  40.0  0.828797  0.118926  0.018804   0.790763  0.866832
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2297
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -29.0584
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -9.1891
# 7                                  Hedge's g =   -9.0065
# 8                             Glass's delta1 =  -16.1744
# 9                           Point-Biserial r =   -0.9782

# %%
#new binary encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8983739837398373
# train_discrete_score_W_discrete_n 0.5003567383527496
# train_discrete_score_W_discrete_a 0.6224915389367592
# test_discrete_score_W_discrete_p 0.939873417721519
# test_discrete_score_W_discrete_n 0.6332234690498513
# test_discrete_score_W_discrete_a 0.7641731165065646
# neuron unit number: 7
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.9390243902439024
# train_discrete_score_W_discrete_n 0.6399451503773059
# train_discrete_score_W_discrete_a 0.7661031853911061
# test_discrete_score_W_discrete_p 0.9493670886075949
# test_discrete_score_W_discrete_n 0.6851758196847736
# test_discrete_score_W_discrete_a 0.7987277171360101
# neuron unit number: 12
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7151898734177216
# test_discrete_score_W0_n 0.020702687438231553
# test_discrete_score_W0_a 0.05714813804272248
# train_discrete_score_W_discrete_p 0.9769647696476965
# train_discrete_score_W_discrete_n 0.8296116603995226
# train_discrete_score_W_discrete_a 0.908410724211485
# test_discrete_score_W_discrete_p 0.9936708860759493
# test_discrete_score_W_discrete_n 0.9446617471660185
# test_discrete_score_W_discrete_a 0.9739961454416991
# neuron unit number: 17
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7151898734177216
# test_discrete_score_W0_n 0.018019122869630765
# test_discrete_score_W0_a 0.048455989771935236
# train_discrete_score_W_discrete_p 0.986449864498645
# train_discrete_score_W_discrete_n 0.8883224687650728
# train_discrete_score_W_discrete_a 0.94547292336498
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.802175737750359
# test_discrete_score_W_discrete_a 0.8845313345574407
# neuron unit number: 22
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7183544303797469
# test_discrete_score_W0_n 0.01963804918246675
# test_discrete_score_W0_a 0.04348563493761525
# train_discrete_score_W_discrete_p 0.9336043360433605
# train_discrete_score_W_discrete_n 0.6184321577548492
# train_discrete_score_W_discrete_a 0.7463467905128083
# test_discrete_score_W_discrete_p 0.9462025316455697
# test_discrete_score_W_discrete_n 0.6671128711989333
# test_discrete_score_W_discrete_a 0.7901129256927512
# neuron unit number: 27
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.012197215729494339
# train_discrete_score_W0_a  0.023201331556011243
# test_discrete_score_W0_p 0.7183544303797469
# test_discrete_score_W0_n 0.02557392985222291
# test_discrete_score_W0_a 0.06559423257850788
# train_discrete_score_W_discrete_p 0.964769647696477
# train_discrete_score_W_discrete_n 0.7660700407256719
# train_discrete_score_W_discrete_a 0.861841509417335
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.8241561512727761
# test_discrete_score_W_discrete_a 0.8863096214695887
# neuron unit number: 32
# train_discrete_score_W0_p 0.6869918699186992
# train_discrete_score_W0_n 0.013937938107449862
# train_discrete_score_W0_a  0.03193865798990531
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.03605670921123463
# test_discrete_score_W0_a 0.08260488669806025
# train_discrete_score_W_discrete_p 0.9607046070460704
# train_discrete_score_W_discrete_n 0.7534495718136498
# train_discrete_score_W_discrete_a 0.8468015313054635
# test_discrete_score_W_discrete_p 0.9620253164556962
# test_discrete_score_W_discrete_n 0.7429703877945649
# test_discrete_score_W_discrete_a 0.8492289904810734
# neuron unit number: 37
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.006196490346777928
# train_discrete_score_W0_a  0.018594408247399555
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.013280521409118973
# test_discrete_score_W0_a 0.039887815518853224
# train_discrete_score_W_discrete_p 0.9661246612466124
# train_discrete_score_W_discrete_n 0.7858313423498104
# train_discrete_score_W_discrete_a 0.8658368818709592
# test_discrete_score_W_discrete_p 0.9651898734177216
# test_discrete_score_W_discrete_n 0.7882881083081922
# test_discrete_score_W_discrete_a 0.8591568381030319
# neuron unit number: 42
# train_discrete_score_W0_p 0.6842818428184282
# train_discrete_score_W0_n 0.010099596023810883
# train_discrete_score_W0_a  0.02597798302283204
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.04503035635665174
# test_discrete_score_W0_a 0.11182759292020417
# train_discrete_score_W_discrete_p 0.964769647696477
# train_discrete_score_W_discrete_n 0.7628382172571331
# train_discrete_score_W_discrete_a 0.8617055373223065
# test_discrete_score_W_discrete_p 0.9683544303797469
# test_discrete_score_W_discrete_n 0.7932758959118219
# test_discrete_score_W_discrete_a 0.8739813177068916
# neuron unit number: 47
# train_discrete_score_W0_p 0.6856368563685636
# train_discrete_score_W0_n 0.012349825747553417
# train_discrete_score_W0_a  0.03037471939453923
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.03810647001552737
# test_discrete_score_W0_a 0.09044273041069197
# train_discrete_score_W_discrete_p 0.975609756097561
# train_discrete_score_W_discrete_n 0.8200485062467198
# train_discrete_score_W_discrete_a 0.9030835124947522
# test_discrete_score_W_discrete_p 0.9841772151898734
# test_discrete_score_W_discrete_n 0.8729738184453824
# test_discrete_score_W_discrete_a 0.9356723676307565
# neuron unit number: 52
# train_discrete_score_W0_p 0.6924119241192412
# train_discrete_score_W0_n 0.025633717309889923
# train_discrete_score_W0_a  0.060917949564638335
# test_discrete_score_W0_p 0.7436708860759493
# test_discrete_score_W0_n 0.07250202342253609
# test_discrete_score_W0_a 0.14492976126506488
# train_discrete_score_W_discrete_p 0.975609756097561
# train_discrete_score_W_discrete_n 0.8394263292948302
# train_discrete_score_W_discrete_a 0.9034139090614498
# test_discrete_score_W_discrete_p 0.9873417721518988
# test_discrete_score_W_discrete_n 0.8912965837707967
# test_discrete_score_W_discrete_a 0.9481194948133702
# neuron unit number: 57
# train_discrete_score_W0_p 0.7018970189701897
# train_discrete_score_W0_n 0.0389073510679972
# train_discrete_score_W0_a  0.07801088570639333
# test_discrete_score_W0_p 0.7246835443037974
# test_discrete_score_W0_n 0.03918894847480581
# test_discrete_score_W0_a 0.09422407914159682
# train_discrete_score_W_discrete_p 0.959349593495935
# train_discrete_score_W_discrete_n 0.7332206149388419
# train_discrete_score_W_discrete_a 0.8408261260723986
# test_discrete_score_W_discrete_p 0.9367088607594937
# test_discrete_score_W_discrete_n 0.6231780658099519
# test_discrete_score_W_discrete_a 0.7517641844677457
# neuron unit number: 62
# train_discrete_score_W0_p 0.6842818428184282
# train_discrete_score_W0_n 0.018451239727930308
# train_discrete_score_W0_a  0.053503160922739525
# test_discrete_score_W0_p 0.7215189873417721
# test_discrete_score_W0_n 0.026602349998414904
# test_discrete_score_W0_a 0.05692688020419638
# train_discrete_score_W_discrete_p 0.975609756097561
# train_discrete_score_W_discrete_n 0.8243876478615225
# train_discrete_score_W_discrete_a 0.903229920541217
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.8076005144554059
# test_discrete_score_W_discrete_a 0.8861136343596361
# neuron unit number: 67
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0033019562701343745
# train_discrete_score_W0_a  0.00954067043315521
# test_discrete_score_W0_p 0.7278481012658228
# test_discrete_score_W0_n 0.04542346562173369
# test_discrete_score_W0_a 0.10619120262247672
# train_discrete_score_W_discrete_p 0.9715447154471545
# train_discrete_score_W_discrete_n 0.8000428964240257
# train_discrete_score_W_discrete_a 0.8875442190123038
# test_discrete_score_W_discrete_p 0.9651898734177216
# test_discrete_score_W_discrete_n 0.7577989182899408
# test_discrete_score_W_discrete_a 0.8612095134412783
# neuron unit number: 72
# train_discrete_score_W0_p 0.7100271002710027
# train_discrete_score_W0_n 0.05213284782444291
# train_discrete_score_W0_a  0.1018845748437244
# test_discrete_score_W0_p 0.7436708860759493
# test_discrete_score_W0_n 0.07722290923482379
# test_discrete_score_W0_a 0.16346938537099867
# train_discrete_score_W_discrete_p 0.9607046070460704
# train_discrete_score_W_discrete_n 0.7427576061031335
# train_discrete_score_W_discrete_a 0.8464366531920023
# test_discrete_score_W_discrete_p 0.9715189873417721
# test_discrete_score_W_discrete_n 0.7899706777116633
# test_discrete_score_W_discrete_a 0.8854812367231066
# neuron unit number: 77
# train_discrete_score_W0_p 0.7005420054200542
# train_discrete_score_W0_n 0.04265391049649457
# train_discrete_score_W0_a  0.10005899673127537
# test_discrete_score_W0_p 0.75
# test_discrete_score_W0_n 0.09394458150690531
# test_discrete_score_W0_a 0.19287064851724223
# train_discrete_score_W_discrete_p 0.9308943089430894
# train_discrete_score_W_discrete_n 0.6070366731871129
# train_discrete_score_W_discrete_a 0.7379210898725227
# test_discrete_score_W_discrete_p 0.9430379746835443
# test_discrete_score_W_discrete_n 0.6547668973375124
# test_discrete_score_W_discrete_a 0.7787090578387583
# neuron unit number: 82
# train_discrete_score_W0_p 0.6910569105691057
# train_discrete_score_W0_n 0.025122181967661802
# train_discrete_score_W0_a  0.06286774527840179
# test_discrete_score_W0_p 0.7215189873417721
# test_discrete_score_W0_n 0.03534822300785198
# test_discrete_score_W0_a 0.08968392760227772
# train_discrete_score_W_discrete_p 0.9850948509485095
# train_discrete_score_W_discrete_n 0.8799457764769597
# train_discrete_score_W_discrete_a 0.9400863595116355
# test_discrete_score_W_discrete_p 0.9746835443037974
# test_discrete_score_W_discrete_n 0.8081380355929699
# test_discrete_score_W_discrete_a 0.8975692589905002
# neuron unit number: 87
# train_discrete_score_W0_p 0.6856368563685636
# train_discrete_score_W0_n 0.009573940026771503
# train_discrete_score_W0_a  0.018645266522176074
# test_discrete_score_W0_p 0.7373417721518988
# test_discrete_score_W0_n 0.07117181130380117
# test_discrete_score_W0_a 0.1585241658804239
# train_discrete_score_W_discrete_p 0.9390243902439024
# train_discrete_score_W_discrete_n 0.6526544125180122
# train_discrete_score_W_discrete_a 0.7677478459377567
# test_discrete_score_W_discrete_p 0.9556962025316456
# test_discrete_score_W_discrete_n 0.7085749419223901
# test_discrete_score_W_discrete_a 0.8234996023599475
# neuron unit number: 92
# train_discrete_score_W0_p 0.7005420054200542
# train_discrete_score_W0_n 0.044754828582664476
# train_discrete_score_W0_a  0.10573707066847877
# test_discrete_score_W0_p 0.7468354430379747
# test_discrete_score_W0_n 0.08716626842434899
# test_discrete_score_W0_a 0.18237349160484528
# train_discrete_score_W_discrete_p 0.9742547425474255
# train_discrete_score_W_discrete_n 0.8117222817703236
# train_discrete_score_W_discrete_a 0.8977613087233307
# test_discrete_score_W_discrete_p 0.9936708860759493
# test_discrete_score_W_discrete_n 0.9371692934110647
# test_discrete_score_W_discrete_a 0.9739456720101881
# neuron unit number: 97
# train_discrete_score_W0_p 0.6815718157181572
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.7120253164556962
# test_discrete_score_W0_n 0.013280521409118973
# test_discrete_score_W0_a 0.039887815518853224
# train_discrete_score_W_discrete_p 0.962059620596206
# train_discrete_score_W_discrete_n 0.7752823783536109
# train_discrete_score_W_discrete_a 0.8521044604194471
# test_discrete_score_W_discrete_p 0.9651898734177216
# test_discrete_score_W_discrete_n 0.7694760597053103
# test_discrete_score_W_discrete_a 0.8617123573205135
# test_discrete_score_W0_p mean 0.7253164556962026
# test_discrete_score_W_discrete_p mean 0.9658227848101266
# test_discrete_score_W0_n mean 0.03891294743697127
# test_discrete_score_W_discrete_n mean 0.7750991997294838
# test_discrete_score_W0_a mean 0.08842641893032832
# test_discrete_score_W_discrete_a mean 0.8642007193525425
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.015766  0.016936  0.003787   0.007839  0.023692
# 1  train_dis_W_dis  20.0  0.751569  0.100370  0.022443   0.704594  0.798544
# 2         combined  40.0  0.383667  0.379302  0.059973   0.262361  0.504974
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.7358
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -32.3277
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -10.2229
# 7                                    Hedge's g =  -10.0198
# 8                               Glass's delta1 =  -43.4449
# 9                             Point-Biserial r =   -0.9823
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.038913  0.028010  0.006263   0.025804  0.052022
# 1  test_dis_W_dis  20.0  0.775099  0.093847  0.020985   0.731178  0.819021
# 2        combined  40.0  0.407006  0.378998  0.059925   0.285797  0.528216
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.7362
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -33.6166
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -10.6305
# 7                                  Hedge's g =  -10.4193
# 8                             Glass's delta1 =  -26.2832
# 9                           Point-Biserial r =   -0.9836
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.036063  0.037073  0.008290   0.018712  0.053414
# 1  train_dis_W_dis  20.0  0.845258  0.080098  0.017910   0.807771  0.882745
# 2         combined  40.0  0.440660  0.414357  0.065516   0.308143  0.573178
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.8092
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -41.0013
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -12.9658
# 7                                    Hedge's g =  -12.7082
# 8                               Glass's delta1 =  -21.8269
# 9                             Point-Biserial r =   -0.9889
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.088426  0.056600  0.012656   0.061937  0.114916
# 1  test_dis_W_dis  20.0  0.864201  0.065272  0.014595   0.833653  0.894749
# 2        combined  40.0  0.476314  0.397430  0.062839   0.349209  0.603418
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.7758
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -40.1574
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -12.6989
# 7                                  Hedge's g =  -12.4466
# 8                             Glass's delta1 =  -13.7062
# 9                           Point-Biserial r =   -0.9884
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.688144  0.008562  0.001914   0.684137  0.692151
# 1  train_dis_W_dis  20.0  0.960027  0.021758  0.004865   0.949844  0.970210
# 2         combined  40.0  0.824085  0.138637  0.021921   0.779747  0.868424
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2719
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -52.0016
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -16.4444
# 7                                    Hedge's g =  -16.1176
# 8                               Glass's delta1 =  -31.7559
# 9                             Point-Biserial r =   -0.9930
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.725316  0.012431  0.002780   0.719498  0.731135
# 1  test_dis_W_dis  20.0  0.965823  0.016827  0.003763   0.957948  0.973698
# 2        combined  40.0  0.845570  0.122657  0.019394   0.806342  0.884797
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2405
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -51.4117
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -16.2578
# 7                                  Hedge's g =  -15.9348
# 8                             Glass's delta1 =  -19.3468
# 9                           Point-Biserial r =   -0.9929
