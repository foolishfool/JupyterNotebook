# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Class/ASD Traits ")
# Out:
# self.continuous_feature_num 2
# self.data_discrete_indexes ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'Qchat-10-Score', 'Sex', 'Ethnicity', 'Jaundice', 'Family_mem_with_ASD', 'Who completed the test']

# %%
dataread.PCA_Comparision()  #123 2, 0, 9, 15, 3, 14, 13, 4,|5, 3, 6, 14, 0, 4, 1, 7, 11, 8, 10|5, 3, 13, 11, 2, 6, 7, 10, 9, 14, 8
# Out:
# Sorted feature index for component 0 [2, 0, 9, 15, 3, 14, 13, 4, 8, 6, 5, 11, 7, 10, 1, 12]
# Sorted imporance porporation for component 0  [0.11556670879247012, 0.11290770033710659, 0.10653806419539703, 0.08603075771805034, 0.08168575557148039, 0.0803029779532608, 0.07989203091501162, 0.07395867004611667, 0.05202245665489511, 0.05183152730591575, 0.05148172472690301, 0.04385807665666631, 0.029560847133366912, 0.02651482255688573, 0.006223073661089403, 0.001624805775384323]
# Sorted feature index for component 1 [5, 3, 6, 14, 0, 4, 1, 7, 11, 8, 10, 13, 9, 15, 2, 12]
# Sorted imporance porporation for component 1  [0.16403851924780266, 0.10631067831526478, 0.09672534472770454, 0.0905170798908018, 0.08625016397258012, 0.08429711766442045, 0.07518163336814337, 0.06649428685735807, 0.061801266693644254, 0.05582206835881756, 0.031762358953595124, 0.03156764484317849, 0.023870839656901125, 0.010927398199656584, 0.009854330154837327, 0.004579269095294013]
# Sorted feature index for component 2 [5, 3, 13, 11, 2, 6, 7, 10, 9, 14, 8, 1, 15, 4, 0, 12]
# Sorted imporance porporation for component 2  [0.1638246478918691, 0.16220603354495267, 0.11814521000652196, 0.09542409899037392, 0.07507044452179616, 0.07270288984778744, 0.060227829406058725, 0.05197840130567495, 0.04979124699150475, 0.04454659986637731, 0.028731805450503082, 0.021456864460118675, 0.020995275965792082, 0.019179591266905924, 0.010848820247960505, 0.0048702402358025846]
# Sorted feature index for component 3 [7, 2, 12, 0, 8, 9, 6, 4, 15, 10, 3, 13, 14, 5, 1, 11]
# Sorted imporance porporation for component 3  [0.16145184068212032, 0.14732751534338234, 0.11425613154472315, 0.10031595981749494, 0.0958874280411213, 0.09068372517702986, 0.06984960245106224, 0.06062802192385465, 0.03404352108845973, 0.029894788572455748, 0.027774645430071333, 0.02743816288198969, 0.022337791982399442, 0.013802212944532178, 0.002449133228644473, 0.0018595188906586012]
# Sorted feature index for component 4 [2, 0, 10, 6, 5, 3, 11, 12, 15, 7, 8, 4, 13, 9, 1, 14]
# Sorted imporance porporation for component 4  [0.18520914660852125, 0.08976460836941724, 0.089503962706625, 0.08422804704998865, 0.07760293386375426, 0.07496617533069687, 0.0618155312009745, 0.05641870741356963, 0.05465410006462007, 0.048896317976459526, 0.04771343307863664, 0.04685896377228821, 0.03952187962394609, 0.03234045285807957, 0.007420909811425359, 0.0030848302709969543]
# Sorted feature index for component 5 [5, 1, 8, 7, 11, 9, 2, 14, 6, 4, 12, 13, 0, 15, 3, 10]
# Sorted imporance porporation for component 5  [0.12667127267435951, 0.11729586202178131, 0.11165076905111355, 0.09965873144340014, 0.09232529358620083, 0.09112546276278084, 0.09023035564329626, 0.08126082235541165, 0.05983790471447274, 0.04740409063830878, 0.031073334673588405, 0.02269278307401188, 0.012083468338210087, 0.008196754996628804, 0.006539298338559983, 0.001953795687875269]
# Sorted feature index for component 6 [5, 1, 10, 2, 4, 6, 13, 8, 3, 9, 15, 14, 7, 11, 0, 12]
# Sorted imporance porporation for component 6  [0.20515412340945163, 0.144627832866219, 0.11798362588696688, 0.10077304712512027, 0.09378768241246031, 0.08079528093511626, 0.04887816080216936, 0.04509233252407947, 0.038349232729478544, 0.03436126305575843, 0.03388157546253285, 0.024697012472908352, 0.02032337514103103, 0.0062813333599911, 0.004207205757536317, 0.000806916059180239]
# Sorted feature index for component 7 [5, 0, 14, 6, 9, 8, 7, 15, 3, 11, 4, 12, 2, 10, 1, 13]
# Sorted imporance porporation for component 7  [0.21537542255072548, 0.14463803949251258, 0.10093632474277109, 0.0953796759609595, 0.08549525413084014, 0.08012943907949117, 0.07355505182265794, 0.04709164406454873, 0.037887798412167384, 0.02974138501561004, 0.028299965391747214, 0.022763491563818513, 0.014938852665576175, 0.012785426782117621, 0.009566883404218381, 0.0014153449202380234]
# Sorted feature index for component 8 [5, 1, 2, 9, 3, 11, 14, 6, 4, 15, 8, 12, 10, 7, 0, 13]
# Sorted imporance porporation for component 8  [0.18429542327641515, 0.16929307704993712, 0.09801299779871867, 0.08785282776263946, 0.07739627832726433, 0.0736954272555995, 0.06963746369036686, 0.06257384995277657, 0.041432984436485, 0.036372377347811624, 0.03566193746393575, 0.028679799734748483, 0.013276239366445723, 0.01261647174828463, 0.008109934185234946, 0.0010929106033363955]
# Sorted feature index for component 9 [2, 0, 14, 15, 9, 11, 8, 1, 3, 4, 12, 10, 7, 6, 5, 13]
# Sorted imporance porporation for component 9  [0.22787628397941398, 0.16537718737072954, 0.10529329122294563, 0.09317738457351347, 0.07830038056372235, 0.06742472757579836, 0.06602134013936824, 0.06395136592345153, 0.04773468074666866, 0.03067161370559187, 0.013231685150141276, 0.012475334574171784, 0.010488643119945518, 0.008579330486246718, 0.006124684811639683, 0.003272066056651397]
# Sorted feature index for component 10 [15, 13, 11, 12, 4, 3, 5, 10, 7, 2, 0, 6, 8, 9, 1, 14]
# Sorted imporance porporation for component 10  [0.555809040108829, 0.18054956216121637, 0.12046578886885177, 0.03501668936155427, 0.023175955501408375, 0.012814170306172941, 0.012436593436374606, 0.01081204105482493, 0.010603072095346167, 0.007629708992473565, 0.007439320634732265, 0.0062526400103250675, 0.005973987058045102, 0.005575352582616697, 0.002765230185010269, 0.002680847642218753]
# Sorted feature index for component 11 [4, 2, 6, 12, 15, 14, 5, 8, 11, 13, 1, 7, 10, 9, 3, 0]
# Sorted imporance porporation for component 11  [0.21568948704095456, 0.13315517987185788, 0.10836181322732814, 0.10386005463369495, 0.09048677689927398, 0.07422272276532597, 0.07371025294802722, 0.05934866808439922, 0.04592917196999842, 0.029571374285802178, 0.023423282877008938, 0.013719671655208418, 0.011862706433754245, 0.009276962326992563, 0.007381874980373295, 1.7533550601472852e-17]
# Sorted feature index for component 12 [14, 15, 8, 6, 9, 2, 1, 4, 7, 13, 12, 3, 10, 11, 5, 0]
# Sorted imporance porporation for component 12  [0.6377795066438281, 0.1390774397571146, 0.03922783590570153, 0.03866985265735136, 0.03173699518019604, 0.022008252005477364, 0.01970177871686707, 0.016869181948911068, 0.014924762078174074, 0.011862198901586197, 0.009163429881443468, 0.008036980091479302, 0.00650122896028275, 0.0027782169044004365, 0.001662340367186556, 3.774511462667368e-17]
# Sorted feature index for component 13 [1, 5, 10, 4, 14, 15, 7, 13, 11, 8, 6, 2, 9, 12, 3, 0]
# Sorted imporance porporation for component 13  [0.2179226781514546, 0.19240341160966504, 0.15020592480222372, 0.10320390100972472, 0.08800591220613903, 0.06524256083817204, 0.046925430486416446, 0.046839880215302436, 0.03689680457749325, 0.018849596021218943, 0.014918162025459687, 0.009261875624667569, 0.004724297744292591, 0.0037049824565814466, 0.0008945822311886485, 2.0344443656427882e-17]
# Sorted feature index for component 14 [1, 6, 2, 8, 10, 9, 15, 5, 3, 7, 14, 12, 13, 11, 4, 0]
# Sorted imporance porporation for component 14  [0.20156035207763476, 0.1706388015567071, 0.15577072402130226, 0.13007299286371402, 0.11474387729043015, 0.08694799711151677, 0.04515217214581195, 0.03227839392882874, 0.014993942527849382, 0.011993799950398171, 0.010676966226046237, 0.010033408519654221, 0.007689121398863883, 0.005103225514727347, 0.0023442248665151047, 4.475570644051311e-20]
# Sorted feature index for component 15 [3, 8, 9, 13, 6, 4, 5, 1, 2, 10, 11, 7, 12, 14, 15, 0]
# Sorted imporance porporation for component 15  [0.7987119858858838, 0.057459879544284775, 0.025166766570215056, 0.02513296469956522, 0.022716122468030175, 0.015597763177113458, 0.01346039557939821, 0.008247348363916784, 0.007629286760153334, 0.0070046681079119315, 0.005135630707382879, 0.004566752741659749, 0.003880597551968493, 0.0036730247988161213, 0.0016168130437000936, 1.6604128106254194e-17]
# [6.20894332e-01 2.54863496e-01 2.44937040e-02 1.65702658e-02
#  1.56968227e-02 1.23883448e-02 1.14101694e-02 9.90278250e-03
#  7.62752403e-03 7.01899920e-03 6.06450681e-03 5.54166940e-03
#  4.19968210e-03 2.57708111e-03 7.50620365e-04 2.58217494e-33]

# %%
#RandomFOrest
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5
features = 15
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 2
#  self.multple_feature_groups  [15]  self.left_feature_group []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 11
#       9 features = 15
#      10 experiment = experiment.Experiment()
# ---> 11 experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
#
# File C:\JupyterDoc\SOM\experiment.py:175, in Experiment.UTtest_Discrete(self, dataread, class_num, neuron_scope_num, interval, features_choosen)
#     173 while y <= neuron_scope_num:
#     174     print("neuron unit number: {}".format(y))
# --> 175     self.InitializedExperimentDataList(
#     176                             dataread,
#     177                             y,
#     178                             all_accuracy_score_original,
#     179                             all_recall_score_original,
#     180                             all_precision_score_original,
#     181                             all_f1_score_original,
#     182                             all_accuracy_score_sog ,
#     183                             all_recall_score_sog ,
#     184                             all_precision_score_sog ,
#     185                             all_f1_score_sog,
#     186                             features_choosen
#     187                             )
#     188     y =y + interval
#     189     if(y<= neuron_scope_num):
#
# File C:\JupyterDoc\SOM\experiment.py:137, in Experiment.InitializedExperimentDataList(self, dataread, y, all_accuracy_score_original, all_recall_score_original, all_precision_score_original, all_f1_score_original, all_accuracy_score_sog, all_recall_score_sog, all_precision_score_sog, all_f1_score_sog, features_choosen)
#     117     som_total_discrete = som_continusous
#     121 optimize_W = CDSOM.CDSOM(som,
#     122          som_continusous,
#     123          som_discrete_original,
#    (...)
#     133          dataread.label_train,
#     134          dataread.label_test)
# --> 137 optimize_W.do_DOSOM(features_choosen)
#     142 all_accuracy_score_original.append(optimize_W.accuracy_score_original)
#     143 all_recall_score_original.append(optimize_W.recall_score_original)
#
# File C:\JupyterDoc\SOM\CDSOM.py:1261, in CDSOM.do_DOSOM(self, features_chosoen_number)
#    1228  """
#    1229  get all combinations of features
#    1230  total_combinations = []
#    (...)
#    1240  print(f" self.reminder_combinations  {self.reminder_combinations }")
#    1241  """
#    1242  # first step,  get discrete data classification
#    1243
#    1244
#    (...)
#    1257  #class_result_test = clf.predict(self.data_test_discrete_unnormalized)
#    1258 # self.getScores("Original",self.test_label_all,class_result_test)
# -> 1261  self.getAllFeatureCombinationsGroupGranular(self.data_train_discrete_unnormalized)
#    1265  self.getAllfeatureGroups()  #group each column by feature value get    self.all_feature_groups
#    1266  self.som_discrete.fit(self.data_train_discrete_unnormalized)
#
# File C:\JupyterDoc\SOM\CDSOM.py:787, in CDSOM.getAllFeatureCombinationsGroupGranular(self, X)
#     785 self.all_feature_combinations ={}
#     786 for i in range(0,len(self.multiple_feature_groups)):  # self.multple_feature_groups =[[0,1,2], [3,4,5]]
# --> 787     self.all_feature_combinations[i] = self.clusterMultipleFeatures(X,self.multiple_feature_groups[i])
#     788 # for the left
#     789 if self.left_feature_group != []:
#
# File C:\JupyterDoc\SOM\CDSOM.py:764, in CDSOM.clusterMultipleFeatures(self, X, mutilple_feature_index_group)
#     762 mutiple_feature_group = {} #mutilple_feature_index_group = [0,1,2]
#     763 for i in range(0,X.shape[0]): #choose one column in mutilple_feature_columns, as they are the same
# --> 764      key = tuple(self.getOneRowDataBaseOneMutipleFeatures(X,mutilple_feature_index_group,i))
#     765     # print(f"key {key} mutiple_feature_group.keys() {mutiple_feature_group.keys()}")
#     766      if len(mutiple_feature_group)>=1:
#
# File C:\JupyterDoc\SOM\CDSOM.py:776, in CDSOM.getOneRowDataBaseOneMutipleFeatures(self, X, mutilple_feature_columns, row_num)
#     775 def getOneRowDataBaseOneMutipleFeatures(self,X,mutilple_feature_columns,row_num):   #X is training data from  [[F1column],[F2column],[F3column]] get one row F1_1,F2_1,F3_1
# --> 776     features_num = len(mutilple_feature_columns)
#     777     combination =[]
#     778     for i in range(0,features_num):
#
# TypeError: object of type 'int' has no len()

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 32)
# accuracy_score_sog 0.7096774193548387
# recall_score_sog 0.6820652173913043
# precision_score_sog 0.6522727272727272
# f1_score_sog 0.6585067319461444
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 112)
# accuracy_score_sog 0.7096774193548387
# recall_score_sog 0.6820652173913043
# precision_score_sog 0.6522727272727272
# f1_score_sog 0.6585067319461444
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 192)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 17
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 272)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 22
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 352)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 27
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 432)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 32
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 512)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 37
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 592)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 42
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 672)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 47
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 752)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 52
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 832)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 57
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 912)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 62
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 992)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 67
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1072)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 72
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1152)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 77
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1232)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 82
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1312)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 87
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1392)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 92
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1472)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 97
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.7445652173913043
# precision_score_original 0.6973684210526316
# f1_score_original 0.7047619047619047
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1552)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# all_accuracy_score_original mean 0.7419354838709677
# all_recall_score_original mean 0.7445652173913044
# all_precision_score_original mean 0.6973684210526316
# all_f1_score_original mean 0.7047619047619046
# all_accuracy_score_sog mean 0.8838709677419352
# all_recall_score_sog mean 0.7994565217391305
# all_precision_score_sog mean 0.9133041958041959
# all_f1_score_sog mean 0.8344534989402973
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.741935  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.883871  0.059573  0.013321   0.855990
# 2                     combined  40.0  0.812903  0.083033  0.013129   0.786348
#
#    Interval
# 0       NaN
# 1  0.911752
# 2  0.839459
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.1419
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -10.6551
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.3694
# 7                                       Hedge's g =   -3.3025
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8656
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.744565  1.139065e-16  2.547026e-17
# 1       all_recall_score_sog  20.0  0.799457  4.014698e-02  8.977137e-03
# 2                   combined  40.0  0.772011  3.946903e-02  6.240602e-03
#
#    95% Conf.  Interval
# 0   0.744565  0.744565
# 1   0.780667  0.818246
# 2   0.759388  0.784634
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -5.490000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -6.114600e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.933600e+00
# 7                                       Hedge's g =  -1.895200e+00
# 8                                  Glass's delta1 =  -4.818980e+14
# 9                                Point-Biserial r =  -7.042000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.697368  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.913304  0.089271  0.019962
# 2                      combined  40.0  0.805336  0.125851  0.019899
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.871524  0.955084
# 2   0.765087  0.845585
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.2159
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -10.8176
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.4208
# 7                                       Hedge's g =   -3.3529
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8688
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.704762  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.834453  6.017252e-02  1.345499e-02
# 2               combined  40.0  0.769608  7.795347e-02  1.232553e-02
#
#    95% Conf.  Interval
# 0   0.704762  0.704762
# 1   0.806292  0.862615
# 2   0.744677  0.794538
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.297000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -9.638900e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.048100e+00
# 7                                       Hedge's g =  -2.987500e+00
# 8                                  Glass's delta1 =  -1.138580e+15
# 9                                Point-Biserial r =  -8.424000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 10
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 10
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 160)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 15
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 240)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 20
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 320)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 25
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 400)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 30
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 480)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 35
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 560)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 40
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 640)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 45
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 720)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 50
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 800)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 55
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 880)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 60
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 960)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 65
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1040)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 70
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1120)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 75
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1200)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 80
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1280)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 85
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1360)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 90
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1440)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 95
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1520)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 100
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1600)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# all_accuracy_score_original mean 1.0
# all_recall_score_original mean 1.0
# all_precision_score_original mean 1.0
# all_f1_score_original mean 1.0
# all_accuracy_score_sog mean 1.0
# all_recall_score_sog mean 1.0
# all_precision_score_sog mean 1.0
# all_f1_score_sog mean 1.0
# Accuracy Score T-Test
#                       Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_accuracy_score_original  19.0   1.0  0.0  0.0        NaN       NaN
# 1       all_accuracy_score_sog  19.0   1.0  0.0  0.0        NaN       NaN
# 2                     combined  38.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...      0.0
# 1                              Degrees of freedom =      36.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Recall Score T-Test
#                     Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_recall_score_original  19.0   1.0  0.0  0.0        NaN       NaN
# 1       all_recall_score_sog  19.0   1.0  0.0  0.0        NaN       NaN
# 2                   combined  38.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...      0.0
# 1                              Degrees of freedom =      36.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Precision Score T-Test
#                        Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_precision_score_original  19.0   1.0  0.0  0.0        NaN       NaN
# 1       all_precision_score_sog  19.0   1.0  0.0  0.0        NaN       NaN
# 2                      combined  38.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...      0.0
# 1                              Degrees of freedom =      36.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# F1 Score T-Test
#                 Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_f1_score_original  19.0   1.0  0.0  0.0        NaN       NaN
# 1       all_f1_score_sog  19.0   1.0  0.0  0.0        NaN       NaN
# 2               combined  38.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...      0.0
# 1                              Degrees of freedom =      36.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#Decision Tree
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 32)
# accuracy_score_sog 0.9354838709677419
# recall_score_sog 0.9565217391304348
# precision_score_sog 0.9
# f1_score_sog 0.9217171717171717
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 112)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 12
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 192)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 17
# accuracy_score_orignial 0.967741935483871
# recall_score_original 0.9375
# precision_score_original 0.9791666666666667
# f1_score_original 0.9560283687943263
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 272)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 22
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 352)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 27
# accuracy_score_orignial 0.967741935483871
# recall_score_original 0.9375
# precision_score_original 0.9791666666666667
# f1_score_original 0.9560283687943263
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 432)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 32
# accuracy_score_orignial 0.8387096774193549
# recall_score_original 0.8505434782608696
# precision_score_original 0.7931818181818182
# f1_score_original 0.8102815177478581
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 512)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 37
# accuracy_score_orignial 0.967741935483871
# recall_score_original 0.9375
# precision_score_original 0.9791666666666667
# f1_score_original 0.9560283687943263
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 592)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 42
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 672)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 47
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 752)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 52
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 832)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 57
# accuracy_score_orignial 0.967741935483871
# recall_score_original 0.9375
# precision_score_original 0.9791666666666667
# f1_score_original 0.9560283687943263
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 912)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 62
# accuracy_score_orignial 0.9354838709677419
# recall_score_original 0.9565217391304348
# precision_score_original 0.9
# f1_score_original 0.9217171717171717
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 992)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 67
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8940217391304348
# precision_score_original 0.8661616161616161
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1072)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 72
# accuracy_score_orignial 0.967741935483871
# recall_score_original 0.9782608695652174
# precision_score_original 0.9444444444444444
# f1_score_original 0.9594771241830065
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1152)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 77
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1232)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 82
# accuracy_score_orignial 0.967741935483871
# recall_score_original 0.9375
# precision_score_original 0.9791666666666667
# f1_score_original 0.9560283687943263
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1312)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 87
# accuracy_score_orignial 0.9354838709677419
# recall_score_original 0.9157608695652174
# precision_score_original 0.9157608695652174
# f1_score_original 0.9157608695652174
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1392)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 92
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1472)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 97
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1552)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.9347826086956521
# precision_score_sog 0.8636363636363636
# f1_score_sog 0.8861689106487148
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.9709677419354839
# all_recall_score_original mean 0.9641304347826087
# all_precision_score_original mean 0.9657691040843217
# all_f1_score_original mean 0.9632904949866953
# all_accuracy_score_sog mean 0.9919354838709677
# all_recall_score_sog mean 0.9945652173913043
# all_precision_score_sog mean 0.988181818181818
# all_f1_score_sog mean 0.9903943041182941
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.970968  0.041733  0.009332   0.951436
# 1       all_accuracy_score_sog  20.0  0.991935  0.025368  0.005672   0.980063
# 2                     combined  40.0  0.981452  0.035703  0.005645   0.970033
#
#    Interval
# 0  0.990499
# 1  1.003808
# 2  0.992870
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0210
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.9200
# 3                           Two side test p value =    0.0624
# 4                          Difference < 0 p value =    0.0312
# 5                          Difference > 0 p value =    0.9688
# 6                                       Cohen's d =   -0.6072
# 7                                       Hedge's g =   -0.5951
# 8                                  Glass's delta1 =   -0.5024
# 9                                Point-Biserial r =   -0.2974
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.964130  0.044025  0.009844   0.943526
# 1       all_recall_score_sog  20.0  0.994565  0.017096  0.003823   0.986564
# 2                   combined  40.0  0.979348  0.036389  0.005754   0.967710
#
#    Interval
# 0  0.984735
# 1  1.002566
# 2  0.990986
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0304
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.8819
# 3                           Two side test p value =    0.0065
# 4                          Difference < 0 p value =    0.0032
# 5                          Difference > 0 p value =    0.9968
# 6                                       Cohen's d =   -0.9113
# 7                                       Hedge's g =   -0.8932
# 8                                  Glass's delta1 =   -0.6913
# 9                                Point-Biserial r =   -0.4235
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.965769  0.056009  0.012524
# 1        all_accuracy_score_sog  20.0  0.991935  0.025368  0.005672
# 2                      combined  40.0  0.978852  0.044915  0.007102
#
#    95% Conf.  Interval
# 0   0.939556  0.991982
# 1   0.980063  1.003808
# 2   0.964488  0.993217
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0262
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.9032
# 3                           Two side test p value =    0.0646
# 4                          Difference < 0 p value =    0.0323
# 5                          Difference > 0 p value =    0.9677
# 6                                       Cohen's d =   -0.6018
# 7                                       Hedge's g =   -0.5899
# 8                                  Glass's delta1 =   -0.4672
# 9                                Point-Biserial r =   -0.2950
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.963290  0.050448  0.011280   0.939680
# 1       all_f1_score_sog  20.0  0.990394  0.030123  0.006736   0.976296
# 2               combined  40.0  0.976842  0.043247  0.006838   0.963011
#
#    Interval
# 0  0.986901
# 1  1.004492
# 2  0.990673
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0271
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.0629
# 3                           Two side test p value =    0.0460
# 4                          Difference < 0 p value =    0.0230
# 5                          Difference > 0 p value =    0.9770
# 6                                       Cohen's d =   -0.6524
# 7                                       Hedge's g =   -0.6394
# 8                                  Glass's delta1 =   -0.5373
# 9                                Point-Biserial r =   -0.3174

# %%
#LinearDiscriminantAnalysis()
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 34)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 7
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 119)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 12
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 204)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 289)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 22
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 374)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 27
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 459)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 544)
# accuracy_score_sog 0.9354838709677419
# recall_score_sog 0.8571428571428572
# precision_score_sog 0.9615384615384616
# f1_score_sog 0.8966666666666667
# neuron unit number: 37
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 629)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 42
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 714)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 47
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 799)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 52
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 884)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 57
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 969)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 62
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1054)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 67
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1139)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 72
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1224)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 77
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1309)
# accuracy_score_sog 0.8387096774193549
# recall_score_sog 0.6428571428571428
# precision_score_sog 0.9137931034482758
# f1_score_sog 0.6750524109014675
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 82
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1394)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1479)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 92
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1564)
# accuracy_score_sog 0.8709677419354839
# recall_score_sog 0.7142857142857143
# precision_score_sog 0.9285714285714286
# f1_score_sog 0.7615384615384615
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 97
# accuracy_score_orignial 0.8709677419354839
# recall_score_original 0.7648809523809523
# precision_score_original 0.8423076923076923
# f1_score_original 0.7933333333333332
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1649)
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# all_accuracy_score_original mean 0.8709677419354838
# all_recall_score_original mean 0.7648809523809523
# all_precision_score_original mean 0.8423076923076923
# all_f1_score_original mean 0.7933333333333332
# all_accuracy_score_sog mean 0.9370967741935484
# all_recall_score_sog mean 0.8607142857142858
# all_precision_score_sog mean 0.9651951496779082
# all_f1_score_sog mean 0.8832013384937912
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.870968  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.937097  6.658401e-02  1.488864e-02
# 2                     combined  40.0  0.904032  5.728150e-02  9.057001e-03
#
#    95% Conf.  Interval
# 0   0.870968  0.870968
# 1   0.905934  0.968259
# 2   0.885713  0.922352
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -6.610000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -4.441600e+00
# 3                           Two side test p value =   1.000000e-04
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.404600e+00
# 7                                       Hedge's g =  -1.376600e+00
# 8                                  Glass's delta1 =  -5.805555e+14
# 9                                Point-Biserial r =  -5.846000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.764881  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.860714  0.147436  0.032968   0.791712
# 2                   combined  40.0  0.812798  0.113776  0.017989   0.776410
#
#    Interval
# 0       NaN
# 1  0.929716
# 2  0.849185
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0958
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.9069
# 3                           Two side test p value =    0.0061
# 4                          Difference < 0 p value =    0.0030
# 5                          Difference > 0 p value =    0.9970
# 6                                       Cohen's d =   -0.9192
# 7                                       Hedge's g =   -0.9010
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.4265
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.842308  0.000000  0.000000
# 1        all_accuracy_score_sog  20.0  0.937097  0.066584  0.014889
# 2                      combined  40.0  0.889702  0.066811  0.010564
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.905934  0.968259
# 2   0.868335  0.911069
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0948
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -6.3665
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.0133
# 7                                       Hedge's g =   -1.9733
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7184
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.793333  0.000000  0.000000        NaN
# 1       all_f1_score_sog  20.0  0.883201  0.125308  0.028020   0.824555
# 2               combined  40.0  0.838267  0.098593  0.015589   0.806736
#
#    Interval
# 0       NaN
# 1  0.941847
# 2  0.869799
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0899
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.2073
# 3                           Two side test p value =    0.0027
# 4                          Difference < 0 p value =    0.0014
# 5                          Difference > 0 p value =    0.9986
# 6                                       Cohen's d =   -1.0142
# 7                                       Hedge's g =   -0.9941
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.4616
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#KNN
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 34)
# accuracy_score_sog 0.8064516129032258
# recall_score_sog 0.797979797979798
# precision_score_sog 0.7681818181818182
# f1_score_sog 0.7785714285714287
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 119)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 12
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 204)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 17
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 289)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 22
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 374)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 27
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 459)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 32
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 544)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 37
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 629)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 42
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 714)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 47
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 799)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 52
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 884)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 57
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 969)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 62
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1054)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 67
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1139)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 72
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1224)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 77
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1309)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 82
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1394)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 87
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1479)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 92
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1564)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# neuron unit number: 97
# accuracy_score_orignial 0.9032258064516129
# recall_score_original 0.8661616161616161
# precision_score_original 0.8940217391304348
# f1_score_original 0.8784313725490196
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1649)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9772727272727273
# precision_score_sog 0.95
# f1_score_sog 0.9620563035495717
# all_accuracy_score_original mean 0.9032258064516128
# all_recall_score_original mean 0.8661616161616161
# all_precision_score_original mean 0.8940217391304348
# all_f1_score_original mean 0.8784313725490197
# all_accuracy_score_sog mean 0.959677419354839
# all_recall_score_sog mean 0.9683080808080808
# all_precision_score_sog mean 0.9409090909090908
# all_f1_score_sog mean 0.9528820598006646
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.903226  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.959677  3.606561e-02  8.064516e-03
# 2                     combined  40.0  0.931452  3.808953e-02  6.022484e-03
#
#    95% Conf.  Interval
# 0   0.903226  0.903226
# 1   0.942798  0.976557
# 2   0.919270  0.943633
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -5.650000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -7.000000e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.213600e+00
# 7                                       Hedge's g =  -2.169600e+00
# 8                                  Glass's delta1 =  -4.955962e+14
# 9                                Point-Biserial r =  -7.505000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.866162  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.968308  0.040091  0.008965   0.949545
# 2                   combined  40.0  0.917235  0.058808  0.009298   0.898427
#
#    Interval
# 0       NaN
# 1  0.987071
# 2  0.936043
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.1021
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -11.3944
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.6032
# 7                                       Hedge's g =   -3.5316
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8795
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.894022  0.000000  0.000000
# 1        all_accuracy_score_sog  20.0  0.959677  0.036066  0.008065
# 2                      combined  40.0  0.926850  0.041701  0.006594
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.942798  0.976557
# 2   0.913513  0.940186
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0657
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -8.1413
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.5745
# 7                                       Hedge's g =   -2.5234
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7972
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.878431  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.952882  4.102847e-02  9.174244e-03
# 2               combined  40.0  0.915657  4.734283e-02  7.485559e-03
#
#    95% Conf.  Interval
# 0   0.878431  0.878431
# 1   0.933680  0.972084
# 2   0.900516  0.930798
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -7.450000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -8.115200e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.566200e+00
# 7                                       Hedge's g =  -2.515300e+00
# 8                                  Glass's delta1 =  -6.536124e+14
# 9                                Point-Biserial r =  -7.963000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#SVM
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 34)
# accuracy_score_sog 0.7419354838709677
# recall_score_sog 0.5
# precision_score_sog 0.3709677419354839
# f1_score_sog 0.42592592592592593
# neuron unit number: 7
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 119)
# accuracy_score_sog 0.7419354838709677
# recall_score_sog 0.5
# precision_score_sog 0.3709677419354839
# f1_score_sog 0.42592592592592593
# neuron unit number: 12
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 204)
# accuracy_score_sog 0.7419354838709677
# recall_score_sog 0.5
# precision_score_sog 0.3709677419354839
# f1_score_sog 0.42592592592592593
# neuron unit number: 17
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 289)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 22
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 374)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 27
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 459)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 32
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 544)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 37
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 629)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# neuron unit number: 42
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 714)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 47
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 799)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 884)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 57
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 969)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 62
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1054)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 67
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1139)
# accuracy_score_sog 0.9354838709677419
# recall_score_sog 0.875
# precision_score_sog 0.96
# f1_score_sog 0.9077380952380952
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1224)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 77
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1309)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 82
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1394)
# accuracy_score_sog 0.9354838709677419
# recall_score_sog 0.875
# precision_score_sog 0.96
# f1_score_sog 0.9077380952380952
# neuron unit number: 87
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1479)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 92
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1564)
# accuracy_score_sog 0.967741935483871
# recall_score_sog 0.9375
# precision_score_sog 0.9791666666666667
# f1_score_sog 0.9560283687943263
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.7419354838709677
# recall_score_original 0.5
# precision_score_original 0.3709677419354839
# f1_score_original 0.42592592592592593
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (74, 1649)
# accuracy_score_sog 0.9032258064516129
# recall_score_sog 0.8125
# precision_score_sog 0.9423076923076923
# f1_score_sog 0.8540031397174255
# all_accuracy_score_original mean 0.7419354838709677
# all_recall_score_original mean 0.5
# all_precision_score_original mean 0.3709677419354839
# all_f1_score_original mean 0.4259259259259259
# all_accuracy_score_sog mean 0.9209677419354838
# all_recall_score_sog mean 0.846875
# all_precision_score_sog mean 0.8804913151364765
# all_f1_score_sog mean 0.856380190646908
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.741935  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.920968  0.080713  0.018048   0.883193
# 2                     combined  40.0  0.831452  0.106735  0.016876   0.797316
#
#    Interval
# 0       NaN
# 1  0.958743
# 2  0.865587
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.1790
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -9.9198
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.1369
# 7                                       Hedge's g =   -3.0746
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8494
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.500000  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.846875  0.156382  0.034968   0.773686
# 2                   combined  40.0  0.673438  0.206799  0.032698   0.607300
#
#    Interval
# 0       NaN
# 1  0.920064
# 2  0.739575
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.3469
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -9.9198
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.1369
# 7                                       Hedge's g =   -3.0746
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8494
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.370968  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.880491  0.220023  0.049199
# 2                      combined  40.0  0.625730  0.300254  0.047474
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.777517  0.983465
# 2   0.529704  0.721755
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.5095
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -10.3565
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.2750
# 7                                       Hedge's g =   -3.2099
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8593
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.425926  5.695324e-17  1.273513e-17
# 1       all_f1_score_sog  20.0  0.856380  1.892258e-01  4.231218e-02
# 2               combined  40.0  0.641153  2.548620e-01  4.029722e-02
#
#    95% Conf.  Interval
# 0   0.425926  0.425926
# 1   0.767820  0.944941
# 2   0.559644  0.722662
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -4.305000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.017330e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.217100e+00
# 7                                       Hedge's g =  -3.153200e+00
# 8                                  Glass's delta1 =  -7.558030e+15
# 9                                Point-Biserial r =  -8.552000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
