# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Iris.csv")
csv = csv.drop(columns=['Id'])
dataread.stringToIntIrisDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset_iris(csv_training,csv_test)

# %%
# multiple text by adding neuron number
scoretype = 2
scope_num = 2
class_num = 3
dim_num = 4
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.20952380952380953
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7758567605696368
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5579678522074333
# all_train_score_W': 0.7410020070499739
# test_score_W0 : 0.7195114273122206
# test_score_W': 0.7903044591383788
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5555555555555556
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6471329050359483
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7607688113413305
# all_train_score_W': 0.630521070855502
# test_score_W0 : 0.8343065421951129
# test_score_W': 0.7151173212819957
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.800740534640327
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7404153354632588
# all_train_score_W': 0.8084446788062291
# test_score_W0 : 0.9402623443896734
# test_score_W': 0.7100364488414476
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.584079128583949
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7111389152749473
# all_train_score_W': 0.5635288587188566
# test_score_W0 : 0.7168680715070408
# test_score_W': 0.7244577369776679
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3142857142857143
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.9394164699776947
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5235592015637032
# all_train_score_W': 0.6282204587455158
# test_score_W0 : 0.640578150226801
# test_score_W': 0.7916323505188602
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.12380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6929133858267716
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.7181796201775817
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6774220913907116
# all_train_score_W': 0.6916628576052558
# test_score_W0 : 0.6829187942678306
# test_score_W': 0.7492770707089311
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.2
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6285266442021724
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5675625180233054
# all_train_score_W': 0.5057269877593831
# test_score_W0 : 0.6992425367592455
# test_score_W': 0.5748415428594081
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.18095238095238095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.77545422006635
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5916988771566063
# all_train_score_W': 0.7404153354632588
# test_score_W0 : 0.6883460303469118
# test_score_W': 0.8358904462822095
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.8874617132694398
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5216772049461577
# all_train_score_W': 0.8072859869138496
# test_score_W0 : 0.570199868938401
# test_score_W': 0.8680109232339392
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 0.5833333333333334
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5424688342714986
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7379470455156301
# all_train_score_W': 0.49455012631885714
# test_score_W0 : 0.813986526740296
# test_score_W': 0.6883460303469118
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.23809523809523808
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7798093539216233
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5409100183635993
# all_train_score_W': 0.7398998132614044
# test_score_W0 : 0.7195114273122206
# test_score_W': 0.9401662513482352
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.29523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6271691197525915
# error_data0_score_W0 0.7063085153811859
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6427898968847439
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4032647416544733
# all_train_score_W': 0.38856764200675237
# test_score_W0 : 0.4146898339847529
# test_score_W': 0.17102042569027956
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.786106261780396
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4158283685337313
# all_train_score_W': 0.7638023779582532
# test_score_W0 : 0.48910550458715596
# test_score_W': 0.7903044591383788
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6958360549439006
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7638023779582532
# all_train_score_W': 0.7251193367205786
# test_score_W0 : 0.7168680715070408
# test_score_W': 0.8557933396056107
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.8416604109322434
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5216772049461577
# all_train_score_W': 0.8081620191329126
# test_score_W0 : 0.570199868938401
# test_score_W': 0.813986526740296
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6838756122972117
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7219806500706598
# all_train_score_W': 0.658740474552081
# test_score_W0 : 0.6610436118333997
# test_score_W': 0.7064349459840301
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6433825544094525
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7390855569997706
# all_train_score_W': 0.6491746868111189
# test_score_W0 : 0.7886206032249979
# test_score_W': 0.7146269148410476
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.13333333333333333
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5915884887501006
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6632786172410045
# all_train_score_W': 0.5317949754840015
# test_score_W0 : 0.8614764649913248
# test_score_W': 0.6319459361213463
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.13333333333333333
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 0.6111111111111112
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.790726630665111
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6588930810758721
# all_train_score_W': 0.7096798822516405
# test_score_W0 : 0.813986526740296
# test_score_W': 0.8351022976486809
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.13333333333333333
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2498126405196103
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5643102978877125
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6583982660111894
# all_train_score_W': 0.5168964029663715
# test_score_W0 : 0.7886206032249979
# test_score_W': 0.6247024596667549
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.4380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9221090022426587
# error_data0_score_W0 0.3568832137198248
# combinedweight shape 0: (6, 4)
# right_data0_score_W' -0.01942576203986862
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.23935802731572514
# all_train_score_W': 0.48089263294945517
# test_score_W0 : 0.16360776088096488
# test_score_W': 0.5592435863528167
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.12380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.621005467038938
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6810478239534972
# all_train_score_W': 0.5889387144992526
# test_score_W0 : 0.8358904462822095
# test_score_W': 0.6398388089774445
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6792034181103478
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8330842052815147
# all_train_score_W': 0.6506268740320933
# test_score_W0 : 0.9312926240202837
# test_score_W': 0.7314704989931867
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.7412026275896918
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8096379126730564
# all_train_score_W': 0.7585050124060853
# test_score_W0 : 0.8351022976486809
# test_score_W': 0.9146829576574679
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.17142857142857143
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6438567430170788
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6024374773468648
# all_train_score_W': 0.5693355224228888
# test_score_W0 : 0.7916323505188602
# test_score_W': 0.6535464977068867
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.11428571428571428
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6648199445983379
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5761282678186571
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6960637767812655
# all_train_score_W': 0.5315770899670353
# test_score_W0 : 0.7492770707089311
# test_score_W': 0.7195114273122206
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.29523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7268590305400121
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5225962460559519
# all_train_score_W': 0.48480947783697453
# test_score_W0 : 0.6523544865736606
# test_score_W': 0.5910316588435034
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6888452630701029
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7849480609271411
# all_train_score_W': 0.6692158303929577
# test_score_W0 : 0.9402623443896734
# test_score_W': 0.6766197832603182
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.24761904761904763
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7107358107180954
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5355459659217159
# all_train_score_W': 0.5100929529323941
# test_score_W0 : 0.7195114273122206
# test_score_W': 0.6213624060655986
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.792072632312597
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7638023779582532
# all_train_score_W': 0.7946948965811358
# test_score_W0 : 0.7168680715070408
# test_score_W': 0.8755284170972287
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5050505050505051
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7143426107175643
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7842121615812524
# all_train_score_W': 0.7015979997825851
# test_score_W0 : 1.0
# test_score_W': 0.7916323505188602
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6960604729421711
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7621941149818554
# all_train_score_W': 0.6279611598184585
# test_score_W0 : 0.8854877067004728
# test_score_W': 0.6840303299934234
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.19047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7748890209178755
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5781684305906458
# all_train_score_W': 0.7410020070499739
# test_score_W0 : 0.7195114273122206
# test_score_W': 0.7903044591383788
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24096385542168675
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.8254052353593722
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7607688113413305
# all_train_score_W': 0.761334844796517
# test_score_W0 : 0.9401662513482352
# test_score_W': 0.7336868803320268
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3619047619047619
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 -0.025048169556840076
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.8558907070045391
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4039454984321776
# all_train_score_W': 0.6632928446265418
# test_score_W0 : 0.4976481201069622
# test_score_W': 0.8739355717004459
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5555555555555556
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.71955834752748
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7609734712900027
# all_train_score_W': 0.6813468718940554
# test_score_W0 : 0.9402623443896734
# test_score_W': 0.8126637554585153
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.20952380952380953
# right_data0_score_W0 1.0
# error_data0_score_W1 0.48346475226550545
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6041060592238973
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5166473599641269
# all_train_score_W': 0.4700897486323167
# test_score_W0 : 0.4877246993138355
# test_score_W': 0.5067264573991032
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.20952380952380953
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.674708929971132
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5579678522074333
# all_train_score_W': 0.5235592015637032
# test_score_W0 : 0.7916323505188602
# test_score_W': 0.6346448645886561
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.24761904761904763
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 -0.020560747663551402
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7507504217698999
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4617802652763935
# all_train_score_W': 0.459700577881326
# test_score_W0 : 0.5996063758461838
# test_score_W': 0.5467919774002458
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5837830104470231
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8853683887677208
# all_train_score_W': 0.5841926502975442
# test_score_W0 : 1.0
# test_score_W': 0.6537810342914752
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.29523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8690878378378378
# error_data0_score_W0 0.8690878378378378
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6211494625447812
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4100272582472619
# all_train_score_W': 0.3987182635745945
# test_score_W0 : 0.42575899493860153
# test_score_W': 0.47771352169850834
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.11428571428571428
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6089699508734258
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6998321886552802
# all_train_score_W': 0.478558332960694
# test_score_W0 : 0.7916323505188602
# test_score_W': 0.5989725530231012
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.6288479668256353
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7846420470474297
# all_train_score_W': 0.6060252323440938
# test_score_W0 : 0.8851198930570641
# test_score_W': 0.7195114273122206
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.8484732784950494
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7638023779582532
# all_train_score_W': 0.7827498989134268
# test_score_W0 : 0.6778791072819761
# test_score_W': 0.6793458758394423
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.46153846153846156
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.5701914034998465
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7823660714285714
# all_train_score_W': 0.5426133275356017
# test_score_W0 : 0.813986526740296
# test_score_W': 0.6149728216109372
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5794667265939241
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7219806500706598
# all_train_score_W': 0.6010295065041896
# test_score_W0 : 0.6991324848507174
# test_score_W': 0.7572339382050024
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.5710754882438591
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7416588508918395
# all_train_score_W': 0.5270868154557075
# test_score_W0 : 0.7348447018875461
# test_score_W': 0.5992701548118718
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.125
# error_data0_score_W0 0.7741935483870968
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.8665254666010132
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7826883697738988
# all_train_score_W': 0.7713539883601507
# test_score_W0 : 0.7178164565691115
# test_score_W': 0.7165054924420242
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3536665733811196
# error_data0_score_W0 0.7624143835616438
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.5327892129537112
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.2951171730915827
# all_train_score_W': 0.40933021472139114
# test_score_W0 : 0.38671702513493467
# test_score_W': 0.4402306412290546
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.8296481045535768
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7611777813688051
# all_train_score_W': 0.7667423677686667
# test_score_W0 : 0.8122357040165965
# test_score_W': 0.8388455866863282
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.1523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7491638795986622
# error_data0_score_W0 0.83150800336984
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.8770737162060515
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6078558368778814
# all_train_score_W': 0.6901450095403813
# test_score_W0 : 0.5288534754704667
# test_score_W': 0.6673280634940955
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.7057588968452201
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7638023779582532
# all_train_score_W': 0.6769639594751702
# test_score_W0 : 0.6991324848507174
# test_score_W': 0.6544046192601258
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6017699115044248
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.5233756070368027
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7384155455904334
# all_train_score_W': 0.5024537111850107
# test_score_W0 : 0.8343065421951129
# test_score_W': 0.599302039017458
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.1523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5390123196798989
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6308060236911924
# all_train_score_W': 0.45058372119032664
# test_score_W0 : 0.8358904462822095
# test_score_W': 0.6141085608615251
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7323523563782466
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7410020070499739
# all_train_score_W': 0.7211213024824168
# test_score_W0 : 0.7508647669247241
# test_score_W': 0.7195114273122206
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.19047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5877535766054506
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5781684305906458
# all_train_score_W': 0.5216435069479156
# test_score_W0 : 0.7497623078171741
# test_score_W': 0.6055179844264084
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.5408922410601351
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7853141315808417
# all_train_score_W': 0.5233935967441843
# test_score_W0 : 0.8851198930570641
# test_score_W': 0.640578150226801
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.17142857142857143
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.621883384761997
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6024374773468648
# all_train_score_W': 0.5123294986593057
# test_score_W0 : 0.7528213322680515
# test_score_W': 0.6346448645886561
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3619047619047619
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 0.0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.8222607577201787
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.38715986298427485
# all_train_score_W': 0.5256725379963768
# test_score_W0 : 0.49010876706328926
# test_score_W': 0.5210158918758354
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 0.34
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.5519618292476417
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7167436273173392
# all_train_score_W': 0.4955924415060721
# test_score_W0 : 0.6991324848507174
# test_score_W': 0.6247024596667549
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   60.0  0.724988  0.162196  0.020939   0.683089  0.766888
# 1  test_score_W'   60.0  0.687779  0.128837  0.016633   0.654497  0.721061
# 2       combined  120.0  0.706384  0.147044  0.013423   0.679804  0.732963
#                               Independent t-test   results
# 0  Difference (test_score_W0 - test_score_W') =     0.0372
# 1                          Degrees of freedom =   118.0000
# 2                                           t =     1.3914
# 3                       Two side test p value =     0.1667
# 4                      Difference < 0 p value =     0.9166
# 5                      Difference > 0 p value =     0.0834
# 6                                   Cohen's d =     0.2540
# 7                                   Hedge's g =     0.2524
# 8                               Glass's delta =     0.2294
# 9                                 Pearson's r =     0.1271
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=1.3914364648355344, pvalue=0.9166446090174715)
