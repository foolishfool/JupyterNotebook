# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")


dataread.stringToIntToddlerAutismDataSet(csv,"Sex")
dataread.stringToIntToddlerAutismDataSet(csv,"Ethnicity")
dataread.stringToIntToddlerAutismDataSet(csv,"Jaundice")
dataread.stringToIntToddlerAutismDataSet(csv,"Family_mem_with_ASD")
dataread.stringToIntToddlerAutismDataSet(csv,"Who completed the test")
dataread.stringToIntToddlerAutismDataSet(csv,"Class/ASD Traits ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv,csv_training,csv_test,"Class/ASD Traits ")

#print(dataread.data_test)

#print(dataread.data_test_discrete_after_transfer)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 15
best_num = 48
interval = 1


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_n 0.47037370642438064
# train_discrete_score_W0 0.43650644863041355
# test_discrete_score_W0_n 0.4537672099534426
# test_discrete_score_W0 0.41496550397217297
# train_discrete_score_W_discrete 0.37005955096615695
# train_discrete_score_W_discrete 0.2658278264247965
# test_discrete_score_W_discrete 0.34576492619912863
# test_discrete_score_W_discrete 0.22770572239661488
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 12
# train_discrete_score_W0_n 0.5722392125861556
# train_discrete_score_W0 0.7079815740532265
# test_discrete_score_W0_n 0.5326544488327665
# test_discrete_score_W0 0.6760092556620532
# train_discrete_score_W_discrete 0.55935908919612
# train_discrete_score_W_discrete 0.6875288459511298
# test_discrete_score_W_discrete 0.534272854270715
# test_discrete_score_W_discrete 0.6599788951284907
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# train_discrete_score_W0_n 0.6965080044568165
# train_discrete_score_W0 0.8110184195874536
# test_discrete_score_W0_n 0.7207783225134127
# test_discrete_score_W0 0.815294487445245
# train_discrete_score_W_discrete 0.5212809807758175
# train_discrete_score_W_discrete 0.6619977781675158
# test_discrete_score_W_discrete 0.6649043418916751
# test_discrete_score_W_discrete 0.7904528133745657
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 32
# train_discrete_score_W0_n 0.5435042131821552
# train_discrete_score_W0 0.6790635142297483
# test_discrete_score_W0_n 0.5450168992013832
# test_discrete_score_W0 0.6883601582610979
# train_discrete_score_W_discrete 0.477033277427063
# train_discrete_score_W_discrete 0.6186741912952805
# test_discrete_score_W_discrete 0.492172512700982
# test_discrete_score_W_discrete 0.6363763441409201
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 42
# train_discrete_score_W0_n 0.6042492135398024
# train_discrete_score_W0 0.7368955342762475
# test_discrete_score_W0_n 0.6014414790374804
# test_discrete_score_W0 0.7453527323671973
# train_discrete_score_W_discrete 0.498875865506051
# train_discrete_score_W_discrete 0.640434694118402
# test_discrete_score_W_discrete 0.5816639785863118
# test_discrete_score_W_discrete 0.7203886706862739
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 52
# train_discrete_score_W0_n 0.537724574757675
# train_discrete_score_W0 0.6767300707278623
# test_discrete_score_W0_n 0.49491347924366114
# test_discrete_score_W0 0.6369552143595678
# train_discrete_score_W_discrete 0.502074273620372
# train_discrete_score_W_discrete 0.6439537509326478
# test_discrete_score_W_discrete 0.35827969527431386
# test_discrete_score_W_discrete 0.5131361412226011
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 62
# train_discrete_score_W0_n 0.5772173804550861
# train_discrete_score_W0 0.713118499779797
# test_discrete_score_W0_n 0.5566147177007364
# test_discrete_score_W0 0.7174988756230699
# train_discrete_score_W_discrete 0.5158693777640209
# train_discrete_score_W_discrete 0.6429958111814488
# test_discrete_score_W_discrete 0.4317756321370057
# test_discrete_score_W_discrete 0.5752650852809597
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 72
# train_discrete_score_W0_n 0.5855235745108551
# train_discrete_score_W0 0.7166825331845685
# test_discrete_score_W0_n 0.5449597683481502
# test_discrete_score_W0 0.6814787403337185
# train_discrete_score_W_discrete 0.6507973779673237
# train_discrete_score_W_discrete 0.7760983595665649
# test_discrete_score_W_discrete 0.6305169866429922
# test_discrete_score_W_discrete 0.7569260368376862
# neuron unit number: 82
# train_discrete_score_W0_n 0.583922014869338
# train_discrete_score_W0 0.7170465375380597
# test_discrete_score_W0_n 0.5029245881500175
# test_discrete_score_W0 0.6573076604806403
# train_discrete_score_W_discrete 0.6422846545426557
# train_discrete_score_W_discrete 0.7649530298530868
# test_discrete_score_W_discrete 0.6436625256661475
# test_discrete_score_W_discrete 0.7585603644815511
# neuron unit number: 92
# train_discrete_score_W0_n 0.5940959643240482
# train_discrete_score_W0 0.727846311291214
# test_discrete_score_W0_n 0.6298758032523651
# test_discrete_score_W0 0.7681452027675002
# train_discrete_score_W_discrete 0.5574727335237102
# train_discrete_score_W_discrete 0.6934857011448371
# test_discrete_score_W_discrete 0.3357181973840827
# test_discrete_score_W_discrete 0.48110559922117146
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 102
# train_discrete_score_W0_n 0.5879638379910123
# train_discrete_score_W0 0.7227169886015266
# test_discrete_score_W0_n 0.5871418305688947
# test_discrete_score_W0 0.7171439340364966
# train_discrete_score_W_discrete 0.8237110904929125
# train_discrete_score_W_discrete 0.9025917804451906
# test_discrete_score_W_discrete 0.6919117409222334
# test_discrete_score_W_discrete 0.8155137794148344
# neuron unit number: 112
# train_discrete_score_W0_n 0.6098117768750085
# train_discrete_score_W0 0.7416023353693186
# test_discrete_score_W0_n 0.5318581588198613
# test_discrete_score_W0 0.6644133501705836
# train_discrete_score_W_discrete 0.6079455473821812
# train_discrete_score_W_discrete 0.7379273180196894
# test_discrete_score_W_discrete 0.5030049072904216
# test_discrete_score_W_discrete 0.6511200476332157
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 122
# train_discrete_score_W0_n 0.5989672454500217
# train_discrete_score_W0 0.7323619647820179
# test_discrete_score_W0_n 0.5783918661178701
# test_discrete_score_W0 0.7122529841483962
# train_discrete_score_W_discrete 0.5795456115094659
# train_discrete_score_W_discrete 0.7101050137210126
# test_discrete_score_W_discrete 0.5177794388961438
# test_discrete_score_W_discrete 0.6612564006302704
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 132
# train_discrete_score_W0_n 0.656431709590184
# train_discrete_score_W0 0.7802903492263743
# test_discrete_score_W0_n 0.516698123036013
# test_discrete_score_W0 0.6734477312064842
# train_discrete_score_W_discrete 0.6627751145389993
# train_discrete_score_W_discrete 0.7851482640454901
# test_discrete_score_W_discrete 0.5682706854152692
# test_discrete_score_W_discrete 0.7091188764407917
# neuron unit number: 142
# train_discrete_score_W0_n 0.6622590686636397
# train_discrete_score_W0 0.7852780008280175
# test_discrete_score_W0_n 0.5494425302695745
# test_discrete_score_W0 0.7001639551148328
# train_discrete_score_W_discrete 0.5569908835592016
# train_discrete_score_W_discrete 0.6936800190662519
# test_discrete_score_W_discrete 0.45691368857734943
# test_discrete_score_W_discrete 0.6077399864100297
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 152
# train_discrete_score_W0_n 0.6817876735234748
# train_discrete_score_W0 0.7999509791654712
# test_discrete_score_W0_n 0.5943315915623281
# test_discrete_score_W0 0.725106325948852
# train_discrete_score_W_discrete 0.7569163378089303
# train_discrete_score_W_discrete 0.8555818913646028
# test_discrete_score_W_discrete 0.6715931974819341
# test_discrete_score_W_discrete 0.7854934223893665
# neuron unit number: 162
# train_discrete_score_W0_n 0.6622590686636397
# train_discrete_score_W0 0.7852780008280175
# test_discrete_score_W0_n 0.5137588084540148
# test_discrete_score_W0 0.643357496604753
# train_discrete_score_W_discrete 0.8110896121717805
# train_discrete_score_W_discrete 0.8975344813986452
# test_discrete_score_W_discrete 0.6826409846740247
# test_discrete_score_W_discrete 0.8073607565318462
# neuron unit number: 172
# train_discrete_score_W0_n 0.7399732708394916
# train_discrete_score_W0 0.8455086599371826
# test_discrete_score_W0_n 0.653345498406029
# test_discrete_score_W0 0.7836696465838142
# train_discrete_score_W_discrete 0.6885413614280522
# train_discrete_score_W_discrete 0.805890276309594
# test_discrete_score_W_discrete 0.4922067478833761
# test_discrete_score_W_discrete 0.6237049956039316
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 182
# train_discrete_score_W0_n 0.6029453884402292
# train_discrete_score_W0 0.7308717100543584
# test_discrete_score_W0_n 0.42907271116521345
# test_discrete_score_W0 0.5889849875063041
# train_discrete_score_W_discrete 0.6998326428918975
# train_discrete_score_W_discrete 0.8151228334105529
# test_discrete_score_W_discrete 0.5024351595977767
# test_discrete_score_W_discrete 0.612382909632617
# neuron unit number: 192
# train_discrete_score_W0_n 0.6945757273615193
# train_discrete_score_W0 0.8099383889274356
# test_discrete_score_W0_n 0.5250385047871996
# test_discrete_score_W0 0.6413082449916025
# train_discrete_score_W_discrete 0.6457036356064393
# train_discrete_score_W_discrete 0.770208021642283
# test_discrete_score_W_discrete 0.3520367423757291
# test_discrete_score_W_discrete 0.46516539398372003
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 202
# train_discrete_score_W0_n 0.6927371847299347
# train_discrete_score_W0 0.8104993658191578
# test_discrete_score_W0_n 0.46727969680150155
# test_discrete_score_W0 0.6097936147376475
# train_discrete_score_W_discrete 0.730164540164104
# train_discrete_score_W_discrete 0.8350170027405144
# test_discrete_score_W_discrete 0.4611750424920021
# test_discrete_score_W_discrete 0.6138767961798609
# Not good nmi result for discrete features !!!!!
# neuron unit number: 212
# train_discrete_score_W0_n 0.649977107995166
# train_discrete_score_W0 0.7755836128049107
# test_discrete_score_W0_n 0.5753868015323107
# test_discrete_score_W0 0.7299257563955719
# train_discrete_score_W_discrete 0.7606525278598961
# train_discrete_score_W_discrete 0.8609460009406055
# test_discrete_score_W_discrete 0.5735814804166138
# test_discrete_score_W_discrete 0.6956327441559259
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 222
# train_discrete_score_W0_n 0.6570136768846909
# train_discrete_score_W0 0.7801566549986862
# test_discrete_score_W0_n 0.47980525154918824
# test_discrete_score_W0 0.6029398993453202
# train_discrete_score_W_discrete 0.6635018629197705
# train_discrete_score_W_discrete 0.7850166020485625
# test_discrete_score_W_discrete 0.5442090189023641
# test_discrete_score_W_discrete 0.6889980622484128
# neuron unit number: 232
# train_discrete_score_W0_n 0.7029937282347173
# train_discrete_score_W0 0.8093347683475484
# test_discrete_score_W0_n 0.4893452152212215
# test_discrete_score_W0 0.6125637918275776
# train_discrete_score_W_discrete 0.7320827418777608
# train_discrete_score_W_discrete 0.8405487556285581
# test_discrete_score_W_discrete 0.5327664800988757
# test_discrete_score_W_discrete 0.6426571763256419
# neuron unit number: 242
# train_discrete_score_W0_n 0.7200088631894371
# train_discrete_score_W0 0.8308780555595975
# test_discrete_score_W0_n 0.49660461606800826
# test_discrete_score_W0 0.6116112154087803
# train_discrete_score_W_discrete 0.6912413721280196
# train_discrete_score_W_discrete 0.8046329307633343
# test_discrete_score_W_discrete 0.434735076972876
# test_discrete_score_W_discrete 0.5785316156397504
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 252
# train_discrete_score_W0_n 0.6644478001979433
# train_discrete_score_W0 0.7848830080446996
# test_discrete_score_W0_n 0.4164072557543191
# test_discrete_score_W0 0.533924641916448
# train_discrete_score_W_discrete 0.7137700982179511
# train_discrete_score_W_discrete 0.825085710991998
# test_discrete_score_W_discrete 0.5889380399234233
# test_discrete_score_W_discrete 0.6890466904817708
# neuron unit number: 262
# train_discrete_score_W0_n 0.7137700982179511
# train_discrete_score_W0 0.825085710991998
# test_discrete_score_W0_n 0.40264026325173247
# test_discrete_score_W0 0.5319509950388369
# train_discrete_score_W_discrete 0.7494696001327136
# train_discrete_score_W_discrete 0.8343708275715594
# test_discrete_score_W_discrete 0.5536159738608776
# test_discrete_score_W_discrete 0.6564601507637835
# neuron unit number: 272
# train_discrete_score_W0_n 0.6627751145389993
# train_discrete_score_W0 0.7851482640454901
# test_discrete_score_W0_n 0.44259595425723197
# test_discrete_score_W0 0.5473959932378603
# train_discrete_score_W_discrete 0.6840084804744295
# train_discrete_score_W_discrete 0.7997022740207055
# test_discrete_score_W_discrete 0.4302136792625225
# test_discrete_score_W_discrete 0.5686133864672585
# Not good nmi result for discrete features !!!!!
# neuron unit number: 282
# train_discrete_score_W0_n 0.7056919322344826
# train_discrete_score_W0 0.8092088592549396
# test_discrete_score_W0_n 0.4445174718798625
# test_discrete_score_W0 0.5939521088185405
# train_discrete_score_W_discrete 0.8704665576209265
# train_discrete_score_W_discrete 0.9291396013797371
# test_discrete_score_W_discrete 0.44747512657627053
# test_discrete_score_W_discrete 0.5822951722306289
# Not good ari result for discrete features  !!!!!
# neuron unit number: 292
# train_discrete_score_W0_n 0.6726297735813298
# train_discrete_score_W0 0.7896293209430642
# test_discrete_score_W0_n 0.3900611920017297
# test_discrete_score_W0 0.4628191878752102
# train_discrete_score_W_discrete 0.6990413783426431
# train_discrete_score_W_discrete 0.815341292038512
# test_discrete_score_W_discrete 0.4701880378232208
# test_discrete_score_W_discrete 0.57683896161933
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  30.0  0.636813  0.063680  0.011626   0.613034  0.660591
# 1  train_dis_W_dis  30.0  0.647419  0.115178  0.021028   0.604411  0.690427
# 2         combined  60.0  0.642116  0.092425  0.011932   0.618240  0.665991
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0106
# 1                           Degrees of freedom =   58.0000
# 2                                            t =   -0.4414
# 3                        Two side test p value =    0.6606
# 4                       Difference < 0 p value =    0.3303
# 5                       Difference > 0 p value =    0.6697
# 6                                    Cohen's d =   -0.1140
# 7                                    Hedge's g =   -0.1125
# 8                                Glass's delta =   -0.1666
# 9                                  Pearson's r =    0.0579
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  30.0  0.522222  0.076458  0.013959   0.493672  0.550772
# 1  test_dis_W_dis  30.0  0.516481  0.102062  0.018634   0.478370  0.554592
# 2        combined  60.0  0.519352  0.089453  0.011548   0.496243  0.542460
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0057
# 1                         Degrees of freedom =   58.0000
# 2                                          t =    0.2466
# 3                      Two side test p value =    0.8061
# 4                     Difference < 0 p value =    0.5970
# 5                     Difference > 0 p value =    0.4030
# 6                                  Cohen's d =    0.0637
# 7                                  Hedge's g =    0.0628
# 8                              Glass's delta =    0.0751
# 9                                Pearson's r =    0.0324
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  30.0  0.755236  0.075686  0.013818   0.726975  0.783498
# 1  train_dis_W_dis  30.0  0.756651  0.125181  0.022855   0.709908  0.803395
# 2         combined  60.0  0.755944  0.102560  0.013240   0.729450  0.782438
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0014
# 1                           Degrees of freedom =   58.0000
# 2                                            t =   -0.0530
# 3                        Two side test p value =    0.9579
# 4                       Difference < 0 p value =    0.4790
# 5                       Difference > 0 p value =    0.5210
# 6                                    Cohen's d =   -0.0137
# 7                                    Hedge's g =   -0.0135
# 8                                Glass's delta =   -0.0187
# 9                                  Pearson's r =    0.0070
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  30.0  0.649603  0.091302  0.016669   0.615510  0.683696
# 1  test_dis_W_dis  30.0  0.638390  0.119728  0.021859   0.593683  0.683097
# 2        combined  60.0  0.643997  0.105713  0.013647   0.616688  0.671305
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0112
# 1                         Degrees of freedom =   58.0000
# 2                                          t =    0.4079
# 3                      Two side test p value =    0.6849
# 4                     Difference < 0 p value =    0.6576
# 5                     Difference > 0 p value =    0.3424
# 6                                  Cohen's d =    0.1053
# 7                                  Hedge's g =    0.1040
# 8                              Glass's delta =    0.1228
# 9                                Pearson's r =    0.0535
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
