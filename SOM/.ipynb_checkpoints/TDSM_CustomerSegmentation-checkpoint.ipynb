# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/test.csv")
csv = csv.drop(columns=[Segmentation'])


dataread.stringToIntCustomerSegmentationDataSet(csv,"Gender")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Ever_Married")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Graduated")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Profession")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Spending_Score")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Var_1")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Work_Experience")

dataread.stringToIntCustomerSegmentationDataSet(csv2,"Gender")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Ever_Married")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Graduated")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Profession")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Spending_Score")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Var_1")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Work_Experience")

csv_training = csv.drop(columns=['ID','Segmentation'])
csv_test = csv2.drop(columns=['ID'])

dataread.initializedataset(csv_training,csv_test,"Var_1")
print(csv_training)
print(csv_test)
# Out:
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Ever_Married
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Graduated
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Profession
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value -1 at Var_1
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 13.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 10.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 11.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 11.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 13.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 10.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 13.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 10.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 11.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 13.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 10.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 13.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 10.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# ...
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 11.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 7.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 6.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 12.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 14.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 3.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 2.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 4.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 5.0 at Work_Experience
# Unkonwn value 8.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 0.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value -1 at Work_Experience
# Unkonwn value 1.0 at Work_Experience
# Unkonwn value 9.0 at Work_Experience
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 22>()
#      19 dataread.stringToIntCustomerSegmentationDataSet(csv2,"Var_1")
#      20 dataread.stringToIntCustomerSegmentationDataSet(csv2,"Work_Experience")
# ---> 22 csv_training = csv.drop(columns=['ID'])
#      23 csv_test = csv2.drop(columns=['ID'])
#      25 dataread.initializedataset(csv_training,csv_test,"Var_1")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['ID'] not found in axis"

# %%
# multiple text by adding neuron number 
scoretype = 1
scope_num = 5
class_num = 10
dim_num = 22
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.26662696049235657
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5338808571920098
# error_data0_score_W0 0.2954000295565885
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.881822114883458
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.623565653532038
# all_train_score_W': 0.6826555455295747
# test_score_W0 : 0.6162099577151658
# test_score_W': 0.6937110994696402
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17728806829461982
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5886657382780014
# error_data0_score_W0 0.422946512805882
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8234048042752269
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6792941801492239
# all_train_score_W': 0.6884484662072428
# test_score_W0 : 0.6910361381448742
# test_score_W': 0.6887223891859893
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14095691880087355
# right_data0_score_W0 1.0
# error_data0_score_W1 0.634810065052285
# error_data0_score_W0 0.4783124566509497
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.928657549590476
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7303652539454524
# all_train_score_W': 0.8119602599895449
# test_score_W0 : 0.7103471476571556
# test_score_W': 0.8020040799272057
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14949374627754616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6186964355871856
# error_data0_score_W0 0.4491412953142836
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.901882665937411
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7174332753208706
# all_train_score_W': 0.7948054889897918
# test_score_W0 : 0.7269896082042759
# test_score_W': 0.7909055545073957
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.13103037522334723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6576842449398383
# error_data0_score_W0 0.4281613602837723
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9080645720133513
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7454102219700055
# all_train_score_W': 0.8136109366160393
# test_score_W0 : 0.749708429902984
# test_score_W': 0.8099671549453646
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.20131030375223347
# right_data0_score_W0 1.0
# error_data0_score_W1 0.48804659769605013
# error_data0_score_W0 0.381585109901599
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9453340077278114
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6622496107087312
# all_train_score_W': 0.7433439979547342
# test_score_W0 : 0.6568433362084217
# test_score_W': 0.733781434302494
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.19515584673416717
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5481502767491218
# error_data0_score_W0 0.37197978123954656
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8718771476348967
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6600295018425694
# all_train_score_W': 0.7243276064870756
# test_score_W0 : 0.6544081820443172
# test_score_W': 0.7307454378147619
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.15803057375421878
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5857685421929779
# error_data0_score_W0 0.39970655159502855
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9168643067661643
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7030437163440193
# all_train_score_W': 0.7898708431867304
# test_score_W0 : 0.7101630729808844
# test_score_W': 0.7961883342153657
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.11554496724240619
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5276944225406689
# error_data0_score_W0 0.4382378659505253
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.853813408926324
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7690446214611293
# all_train_score_W': 0.7559855021018467
# test_score_W0 : 0.7753998013931942
# test_score_W': 0.7465306628388374
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.09211832439944412
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6302289451209644
# error_data0_score_W0 0.3884250056032219
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9300805934101242
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7934049796014504
# all_train_score_W': 0.8448805761009371
# test_score_W0 : 0.8005253878825993
# test_score_W': 0.8359118395913009
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.18443517967043876
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5230130714905029
# error_data0_score_W0 0.39563490264518864
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8366016606948985
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7018655310925525
# all_train_score_W': 0.6909079138878931
# test_score_W0 : 0.7040790412893466
# test_score_W': 0.708685422690008
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.22493547746674608
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5572239848503977
# error_data0_score_W0 0.343615144547446
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9243817553255634
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6544081840185305
# all_train_score_W': 0.7589446797876203
# test_score_W0 : 0.6560548445980898
# test_score_W': 0.7662332469545734
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.18046456223942822
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5435967253618538
# error_data0_score_W0 0.29765235316093297
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9073246437841843
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6669492123424867
# all_train_score_W': 0.7453402050343272
# test_score_W0 : 0.6504535683006113
# test_score_W': 0.7398005644918659
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.12944212825094303
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6206269014615118
# error_data0_score_W0 0.5029307278329629
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8993636804083611
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.754646601283021
# all_train_score_W': 0.8082189921906393
# test_score_W0 : 0.7643743813301315
# test_score_W': 0.8107765572960087
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.08715505261068096
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6233328175941857
# error_data0_score_W0 0.4478512926717222
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8882771348978603
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8002410232400863
# all_train_score_W': 0.8017466387256638
# test_score_W0 : 0.8007731157160699
# test_score_W': 0.7915106632275738
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.21083978558665872
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5094008182227208
# error_data0_score_W0 0.36803220254339875
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9225612106751572
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6491983076967652
# all_train_score_W': 0.7008232914688693
# test_score_W0 : 0.6533638126609226
# test_score_W': 0.7059723718659656
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.1856263648997419
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5399072302611111
# error_data0_score_W0 0.3573000011141461
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9312761941872072
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6816675908916388
# all_train_score_W': 0.7636365607939866
# test_score_W0 : 0.6831131228125067
# test_score_W': 0.7790504102182262
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14711137581893985
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5123118541084019
# error_data0_score_W0 0.4464747126062978
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8251038222169219
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7271826416728576
# all_train_score_W': 0.7254243808656587
# test_score_W0 : 0.7225163309675027
# test_score_W': 0.70833337989486
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.11614055985705778
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5825282553998079
# error_data0_score_W0 0.42092489923229576
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9128469593315622
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7635160574712874
# all_train_score_W': 0.8072694741293847
# test_score_W0 : 0.7802208579233595
# test_score_W': 0.7955566171991767
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11395672027000199
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5807359100657298
# error_data0_score_W0 0.4419604729931357
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8869097185585215
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7646399647864809
# all_train_score_W': 0.7911118500875975
# test_score_W0 : 0.7752316754051642
# test_score_W': 0.801091863812821
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2060750446694461
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5057055139100465
# error_data0_score_W0 0.4618036774985925
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8625626832504544
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6897094944420517
# all_train_score_W': 0.6438439742742028
# test_score_W0 : 0.692088745832271
# test_score_W': 0.6483590088758482
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.1816557474687314
# right_data0_score_W0 1.0
# error_data0_score_W1 0.56997345292837
# error_data0_score_W0 0.3118380559603224
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8353449003420577
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6899509948895208
# all_train_score_W': 0.7177781851483058
# test_score_W0 : 0.6913240583332637
# test_score_W': 0.7192712780836366
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.13519952352590828
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5745447751990923
# error_data0_score_W0 0.4153456281989945
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9293940431550332
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7337174037151031
# all_train_score_W': 0.8182254515384658
# test_score_W0 : 0.735721055021274
# test_score_W': 0.8096023261815359
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.12209648600357356
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6402427708060736
# error_data0_score_W0 0.35374495412093887
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8589281327789307
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7588865144769786
# all_train_score_W': 0.7661097588394689
# test_score_W0 : 0.7714052467028555
# test_score_W': 0.744223578620658
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.12229501687512408
# right_data0_score_W0 1.0
# error_data0_score_W1 0.670361156183169
# error_data0_score_W0 0.368653822999619
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9101618342803783
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7470126328608598
# all_train_score_W': 0.8059254460376918
# test_score_W0 : 0.751210171477131
# test_score_W': 0.8155755402833351
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.1947587849910661
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4225328412840633
# error_data0_score_W0 0.3312369064408287
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8460388810200886
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6683398756564025
# all_train_score_W': 0.6695502637152245
# test_score_W0 : 0.6623456924460095
# test_score_W': 0.6821606230273034
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.2023029581099861
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4884522296046582
# error_data0_score_W0 0.3755978622808976
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.909971956652235
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6731609063377603
# all_train_score_W': 0.726543044438012
# test_score_W0 : 0.6605317705473209
# test_score_W': 0.7314977463623042
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14711137581893985
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5917277311917943
# error_data0_score_W0 0.3144047323950251
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9021738639488268
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6981254101410042
# all_train_score_W': 0.7668267973280807
# test_score_W0 : 0.6924660492470106
# test_score_W': 0.7665581160123016
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.1125670041691483
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6023911736339818
# error_data0_score_W0 0.426737861353204
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9154246755875967
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7610729220851286
# all_train_score_W': 0.7999916760882907
# test_score_W0 : 0.7669977372472748
# test_score_W': 0.800310021558909
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11455231288465356
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6980189681472888
# error_data0_score_W0 0.40760872187232783
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8123009433892192
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7688376366791343
# all_train_score_W': 0.7598850642366629
# test_score_W0 : 0.7858742449558495
# test_score_W': 0.760111815485296
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.22533253920984714
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5329495630102751
# error_data0_score_W0 0.3911361060295111
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8557722167552069
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6385039425121221
# all_train_score_W': 0.7106360053956744
# test_score_W0 : 0.6351331357255317
# test_score_W': 0.7079189572419315
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.12606710343458408
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5362346805015421
# error_data0_score_W0 0.3872919143061497
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9337619865921555
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7562924625649979
# all_train_score_W': 0.797974388554851
# test_score_W0 : 0.7525467671368361
# test_score_W': 0.7813476017788934
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.16756005558864404
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6133540199381132
# error_data0_score_W0 0.40404864407323604
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8871944570671951
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6911788183022368
# all_train_score_W': 0.7653758446091989
# test_score_W0 : 0.693368098536976
# test_score_W': 0.767852976787878
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.17153067301965455
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7000490647473799
# error_data0_score_W0 0.5362962779548532
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8796896812755293
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7229904564937258
# all_train_score_W': 0.7910224188530709
# test_score_W0 : 0.7167458492144052
# test_score_W': 0.7989481399808148
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11137581893984515
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6346276991434834
# error_data0_score_W0 0.4156000680973672
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8603314845874137
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679786072931797
# all_train_score_W': 0.7838462405821474
# test_score_W0 : 0.7723503388759323
# test_score_W': 0.7810548381784165
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.25411951558467344
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4654919345439885
# error_data0_score_W0 0.37699253681556366
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9013138404772115
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6077042550306548
# all_train_score_W': 0.6807313759342426
# test_score_W0 : 0.6171861292339672
# test_score_W': 0.687066548285476
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.2237442922374429
# right_data0_score_W0 1.0
# error_data0_score_W1 0.619225361034836
# error_data0_score_W0 0.5211158026030848
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8276049702925456
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6664534301424014
# all_train_score_W': 0.6922838820482885
# test_score_W0 : 0.6611573571926546
# test_score_W': 0.6749204931000764
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.15862616636887036
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5096880001453772
# error_data0_score_W0 0.4330710912874994
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9027510961517268
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7139114873886975
# all_train_score_W': 0.7507885606325067
# test_score_W0 : 0.7160405086222804
# test_score_W': 0.7579569595133566
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.10819932499503673
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5742140889285909
# error_data0_score_W0 0.39171409591031064
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9016108284427509
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7729977684615537
# all_train_score_W': 0.8010828505921245
# test_score_W0 : 0.7784959500969442
# test_score_W': 0.7964238694973408
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10601548540798095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5815000941583759
# error_data0_score_W0 0.40597224340403054
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9040136023531347
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7688492967985515
# all_train_score_W': 0.8220537351590349
# test_score_W0 : 0.7748664277020122
# test_score_W': 0.8093601126148452
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.19733968632122295
# right_data0_score_W0 1.0
# error_data0_score_W1 0.523177240107551
# error_data0_score_W0 0.48551548508716075
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9217988807036245
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7192857663016746
# all_train_score_W': 0.737184735113389
# test_score_W0 : 0.7308385822057325
# test_score_W': 0.7483469362800172
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.19277347627556085
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5664864455291798
# error_data0_score_W0 0.4096574643724838
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8018588844266454
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6659515632042772
# all_train_score_W': 0.7002961425775203
# test_score_W0 : 0.6562458441536699
# test_score_W': 0.7123041345247368
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.12368473297597776
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5965602537854252
# error_data0_score_W0 0.4078414173045078
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.882580641220168
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.74925383558772
# all_train_score_W': 0.7828790746517519
# test_score_W0 : 0.7494291878290441
# test_score_W': 0.774378121752348
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.10224339884852095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6133060186951462
# error_data0_score_W0 0.4593174721095141
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8451507897356794
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7909150587286706
# all_train_score_W': 0.7775719079612664
# test_score_W0 : 0.7772241205905489
# test_score_W': 0.7682404836228527
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.12507444907683143
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6739897638483108
# error_data0_score_W0 0.386388771376921
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8630305265398341
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7618511290042042
# all_train_score_W': 0.7931221497947605
# test_score_W0 : 0.7660145914306474
# test_score_W': 0.8109693587640564
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2960095294818344
# right_data0_score_W0 1.0
# error_data0_score_W1 0.44478949315042127
# error_data0_score_W0 0.4329763532620261
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8013212581236491
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5553851558628777
# all_train_score_W': 0.5589269400010266
# test_score_W0 : 0.5393911297730561
# test_score_W': 0.5669545491450662
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.1741115743498114
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5931701203871267
# error_data0_score_W0 0.3904148192471058
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8942095137031714
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6874789655733226
# all_train_score_W': 0.7298863796095411
# test_score_W0 : 0.7054010972239474
# test_score_W': 0.7439082549141045
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.1308318443517967
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4989848512483506
# error_data0_score_W0 0.4901809793819689
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8690007677852788
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7449867270648382
# all_train_score_W': 0.7675500694479673
# test_score_W0 : 0.7604648662201479
# test_score_W': 0.7808074186790336
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.11852293031566409
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5489573719444021
# error_data0_score_W0 0.4454486919746912
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9119544512490375
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7574293368577962
# all_train_score_W': 0.8018406584808013
# test_score_W0 : 0.7594544626740252
# test_score_W': 0.793634518405441
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11197141155449672
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5778649753276189
# error_data0_score_W0 0.43668058240035784
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9071662856131049
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7642134191405288
# all_train_score_W': 0.814252863691264
# test_score_W0 : 0.7509826522694015
# test_score_W': 0.8191412811341439
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.22473694659519555
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5349776373333691
# error_data0_score_W0 0.4797814727554816
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9411183698152975
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6862182429685316
# all_train_score_W': 0.7496252103868993
# test_score_W0 : 0.6833032512726043
# test_score_W': 0.7590875457366614
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.18244987095493348
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6273969128558308
# error_data0_score_W0 0.416790694761379
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9196675530762874
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6867738533062782
# all_train_score_W': 0.7627923573407721
# test_score_W0 : 0.6738893635125092
# test_score_W': 0.7599608179549846
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.1405598570577725
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5520067190828837
# error_data0_score_W0 0.42913255570794856
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9222464173641133
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7391532355816788
# all_train_score_W': 0.8170974801663434
# test_score_W0 : 0.7450682291470405
# test_score_W': 0.8000178484687107
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.11554496724240619
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5510428602925179
# error_data0_score_W0 0.42902453918280387
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9017380573215299
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7694346177070114
# all_train_score_W': 0.785562672850575
# test_score_W0 : 0.7600241276988314
# test_score_W': 0.7806081528561399
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11078022632519356
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6453709894914893
# error_data0_score_W0 0.35633108672041364
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8648845659279915
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7659458074617692
# all_train_score_W': 0.7955804967616176
# test_score_W0 : 0.7584322329342346
# test_score_W': 0.7967680754439471
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.27714909668453447
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5178679371919135
# error_data0_score_W0 0.3992027549489588
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9495128851367539
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.587106238147819
# all_train_score_W': 0.6979563393950425
# test_score_W0 : 0.5863344476661628
# test_score_W': 0.7060258845461327
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.15902322811197142
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5305050923880901
# error_data0_score_W0 0.4284194577287664
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9139630783884245
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7148445788115003
# all_train_score_W': 0.7446780889533656
# test_score_W0 : 0.7321734519298481
# test_score_W': 0.7660541292931611
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.11534643637085566
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5408582163587038
# error_data0_score_W0 0.410037223617583
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8855177722865293
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7602493568269437
# all_train_score_W': 0.7875156913732123
# test_score_W0 : 0.7508456019844582
# test_score_W': 0.7751339977428403
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.10919197935278936
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6547150083356148
# error_data0_score_W0 0.5207776549197122
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8926610488239497
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7871105698336126
# all_train_score_W': 0.814716681207703
# test_score_W0 : 0.7879304552616756
# test_score_W': 0.8025323804317778
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11494937462775462
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6405984631527236
# error_data0_score_W0 0.4317706035091881
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9339837691847457
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.759794514736465
# all_train_score_W': 0.8341423846423448
# test_score_W0 : 0.7500317827724913
# test_score_W': 0.8377430400658117
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.190192574945404
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5366427745027023
# error_data0_score_W0 0.3626577837611169
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8998889640266675
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6517717116287423
# all_train_score_W': 0.7024827796512936
# test_score_W0 : 0.6534367579748525
# test_score_W': 0.702950965568166
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17768513003772088
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4732943181586823
# error_data0_score_W0 0.3231406113372008
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.7447770302162497
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6794051114399822
# all_train_score_W': 0.6217852495135451
# test_score_W0 : 0.6981210040168498
# test_score_W': 0.6380840118945545
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14889815366289458
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6050598182976824
# error_data0_score_W0 0.4655280425181263
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9136786299895223
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7247505560458714
# all_train_score_W': 0.7902181402623254
# test_score_W0 : 0.726013399330943
# test_score_W': 0.788903734175125
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.12884653563629145
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7278326959136479
# error_data0_score_W0 0.329320014458406
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.908255944056542
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7312503323579752
# all_train_score_W': 0.7936435336719546
# test_score_W0 : 0.7339186297758782
# test_score_W': 0.792130857970588
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.0897359539408378
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6230640060742411
# error_data0_score_W0 0.4074514956847877
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8257180444204139
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7920036664509686
# all_train_score_W': 0.7406837261851544
# test_score_W0 : 0.7709340000268482
# test_score_W': 0.7377686428642823
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.24995036728211237
# right_data0_score_W0 1.0
# error_data0_score_W1 0.41055529312220385
# error_data0_score_W0 0.29882156657026837
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8991979177192628
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6249913764143521
# all_train_score_W': 0.7368221937731756
# test_score_W0 : 0.638784395865155
# test_score_W': 0.7448790114971023
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.21997220567798292
# right_data0_score_W0 1.0
# error_data0_score_W1 0.537045826557581
# error_data0_score_W0 0.3752849472619164
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9088581199618035
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6308129144944545
# all_train_score_W': 0.7366862254656311
# test_score_W0 : 0.6351650278065852
# test_score_W': 0.7220538355403442
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.16021441334127456
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5952205897622047
# error_data0_score_W0 0.4412956674924457
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8884449309020604
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7152008747732351
# all_train_score_W': 0.7608996175051655
# test_score_W0 : 0.7040082936891963
# test_score_W': 0.7452237692230393
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14472900536033353
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6129343788812529
# error_data0_score_W0 0.39630418738981377
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8339484092017568
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.719516285713947
# all_train_score_W': 0.7633413514216267
# test_score_W0 : 0.7224108399526786
# test_score_W': 0.7634801202414011
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10462576930712726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6429510947432171
# error_data0_score_W0 0.4173617332709843
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9044331751036139
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7920872062815782
# all_train_score_W': 0.8169208039971123
# test_score_W0 : 0.7878800209328295
# test_score_W': 0.8229390647520355
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.27258288663887237
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6036990333389923
# error_data0_score_W0 0.4055227441996883
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8039604139389029
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5772932423734958
# all_train_score_W': 0.6853778598576348
# test_score_W0 : 0.5642590853251596
# test_score_W': 0.6918171731366171
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.12884653563629145
# right_data0_score_W0 1.0
# error_data0_score_W1 0.42006448853965334
# error_data0_score_W0 0.34783797840167546
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.903732256084607
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7323095397644854
# all_train_score_W': 0.7201124163897424
# test_score_W0 : 0.7258903105425654
# test_score_W': 0.7101549013743753
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.13718483224141353
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6513168298781159
# error_data0_score_W0 0.3682163135470019
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8808722313506016
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.748590888483215
# all_train_score_W': 0.7831186476358857
# test_score_W0 : 0.7493899138499147
# test_score_W': 0.7902341693654604
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.15187611673615248
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6100358819334476
# error_data0_score_W0 0.46592284702214637
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8379522558887865
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7239043316980969
# all_train_score_W': 0.7548850346107091
# test_score_W0 : 0.7349760023454986
# test_score_W': 0.7630008141100059
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.1421481040301767
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7078868543064816
# error_data0_score_W0 0.4461841207113135
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9068441272652298
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7518857931777908
# all_train_score_W': 0.8357704944093369
# test_score_W0 : 0.7458160030278649
# test_score_W': 0.838706029214617
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.24459003375024815
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4389312633428351
# error_data0_score_W0 0.27384882012119616
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8629899867779715
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.635106745928336
# all_train_score_W': 0.6495448036007895
# test_score_W0 : 0.6327086733714586
# test_score_W': 0.6483787781132123
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17212626563430614
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5313230482871037
# error_data0_score_W0 0.5194996812538152
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8874481645334354
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6922638570558689
# all_train_score_W': 0.7590616470779395
# test_score_W0 : 0.7020657967552002
# test_score_W': 0.7759460355663136
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14036132618622196
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6596970118466685
# error_data0_score_W0 0.31621705185921734
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9006788418849396
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7370820616020202
# all_train_score_W': 0.8058503572123965
# test_score_W0 : 0.7268963149595684
# test_score_W': 0.7994016020896825
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.13658923962676195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6215327751306896
# error_data0_score_W0 0.41330625763194473
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9140441669922751
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7387372428106619
# all_train_score_W': 0.7954709965240361
# test_score_W0 : 0.743329948211667
# test_score_W': 0.8020941634058543
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.1209053007742704
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5953805701795769
# error_data0_score_W0 0.394824619264943
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.880161119744888
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.764125199598993
# all_train_score_W': 0.7832231678965209
# test_score_W0 : 0.7587302944231614
# test_score_W': 0.7912847254773687
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2485606511812587
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5269769406532563
# error_data0_score_W0 0.4292975982831919
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9359571532869906
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6176382629794682
# all_train_score_W': 0.7111585153240245
# test_score_W0 : 0.6126108236628334
# test_score_W': 0.7189828871268814
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.18383958705578718
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5815768373527772
# error_data0_score_W0 0.38058910178054045
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9149463233017938
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6779993805011796
# all_train_score_W': 0.7726421608457729
# test_score_W0 : 0.6783567546342362
# test_score_W': 0.7723757228530872
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.13182449870954935
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5180798146520487
# error_data0_score_W0 0.4511279959790405
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8737494754028889
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.748911257619926
# all_train_score_W': 0.7518421635174259
# test_score_W0 : 0.7574332387647843
# test_score_W': 0.7516205140647731
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.11216994242604725
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5869525364919537
# error_data0_score_W0 0.36842545324224585
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8918925800667624
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7625823319652449
# all_train_score_W': 0.8013600088314684
# test_score_W0 : 0.7659012047899122
# test_score_W': 0.8018404099985931
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11276553504069883
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6568737075713107
# error_data0_score_W0 0.47196766841190607
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9169704353464997
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7760001910022517
# all_train_score_W': 0.8297801719223151
# test_score_W0 : 0.7767884760330891
# test_score_W': 0.8267080497401799
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2576930712725829
# right_data0_score_W0 1.0
# error_data0_score_W1 0.40713572715604146
# error_data0_score_W0 0.2702786799722339
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9472207421430485
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5979019220844162
# all_train_score_W': 0.6484868060283608
# test_score_W0 : 0.6109927550097359
# test_score_W': 0.6494521717415759
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.16636887035934086
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5443717182219553
# error_data0_score_W0 0.40523583070671937
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9025928239740789
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7185583032563545
# all_train_score_W': 0.7801858132214797
# test_score_W0 : 0.6991893943867685
# test_score_W': 0.7754254730345818
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14075838792932302
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5630764781744777
# error_data0_score_W0 0.38872718384751537
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8945209884294493
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7301597341311327
# all_train_score_W': 0.7650803674117075
# test_score_W0 : 0.7257291536999578
# test_score_W': 0.7851156494608352
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14075838792932302
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6074819927663785
# error_data0_score_W0 0.3971639132370587
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9065077727960484
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7102315373159334
# all_train_score_W': 0.7801031920863839
# test_score_W0 : 0.7052706107286888
# test_score_W': 0.7901658301533767
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10700813976573358
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5746569879522742
# error_data0_score_W0 0.39798079895905547
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9024388182417543
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7875532281639995
# all_train_score_W': 0.8166183805547295
# test_score_W0 : 0.7904592565015209
# test_score_W': 0.8113804146043584
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.1891999205876514
# right_data0_score_W0 1.0
# error_data0_score_W1 0.48700930967437756
# error_data0_score_W0 0.35813907034600106
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8403899231202329
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.674535740075327
# all_train_score_W': 0.696711503088821
# test_score_W0 : 0.6781460672480176
# test_score_W': 0.7159090466721683
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17927337701012508
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6188425393068319
# error_data0_score_W0 0.4532207605241571
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8595200955850604
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6996339883667476
# all_train_score_W': 0.7452438971346748
# test_score_W0 : 0.6903577838357229
# test_score_W': 0.7459271677393869
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14353782013103036
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5908248669268088
# error_data0_score_W0 0.3629935510655519
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8219733252712608
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7205650221746821
# all_train_score_W': 0.7302504362646032
# test_score_W0 : 0.7208545738266711
# test_score_W': 0.725347032940922
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.13400833829660513
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6330882270396396
# error_data0_score_W0 0.3978946461473303
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9189005217488957
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7328652666912459
# all_train_score_W': 0.8133312751211843
# test_score_W0 : 0.736295377165536
# test_score_W': 0.8038829575863243
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.1042287075640262
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6758240490393239
# error_data0_score_W0 0.43036487380037924
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9123943060419187
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7749041390973722
# all_train_score_W': 0.8328652985092359
# test_score_W0 : 0.7721006506637801
# test_score_W': 0.8195760412935721
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2640460591621997
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4748402791597923
# error_data0_score_W0 0.28986548569415777
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.7253544666792624
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5656792107144049
# all_train_score_W': 0.5462572846086243
# test_score_W0 : 0.5771724076543626
# test_score_W': 0.5470854363986933
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.16914830256104824
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5520495402397679
# error_data0_score_W0 0.38325024014325554
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9170405863223583
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6904168843999046
# all_train_score_W': 0.7572424987238686
# test_score_W0 : 0.6997074426484726
# test_score_W': 0.7529472922141818
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.15862616636887036
# right_data0_score_W0 1.0
# error_data0_score_W1 0.629571463319966
# error_data0_score_W0 0.4378869502025855
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9048755624695346
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7211505220987647
# all_train_score_W': 0.7932608741893766
# test_score_W0 : 0.7167866542496193
# test_score_W': 0.8092739157226151
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.13222156045265038
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6130547973451054
# error_data0_score_W0 0.41078898025494537
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8882869199857283
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7298583674053883
# all_train_score_W': 0.7864042173783972
# test_score_W0 : 0.7384983022255716
# test_score_W': 0.762674927999395
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10482430017867779
# right_data0_score_W0 1.0
# error_data0_score_W1 0.681952174284321
# error_data0_score_W0 0.47969256675600846
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9250804282836016
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7737693601135133
# all_train_score_W': 0.8453298234497595
# test_score_W0 : 0.7778512634223883
# test_score_W': 0.8505369646660758
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.20587651379789557
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5452085750686954
# error_data0_score_W0 0.4906019850972376
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9063684544267986
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6781535359482882
# all_train_score_W': 0.6845487672255519
# test_score_W0 : 0.6677779455252334
# test_score_W': 0.6932262086556028
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.18383958705578718
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6053172262334573
# error_data0_score_W0 0.35882796618188106
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9001574017435048
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6782886436965827
# all_train_score_W': 0.7543780907885965
# test_score_W0 : 0.6742597810520587
# test_score_W': 0.753708511967043
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.17073654953345246
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6032160692939685
# error_data0_score_W0 0.39158757249957915
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9337163437768272
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.721590083740498
# all_train_score_W': 0.8065529815263144
# ...
# right_data0_score_W' 0.8559129054216306
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7389449184579342
# all_train_score_W': 0.7286573183156992
# test_score_W0 : 0.740567910986175
# test_score_W': 0.7392792715647865
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.12586857256303355
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6194371064462728
# error_data0_score_W0 0.39186305339817284
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.929992454936947
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7555597603043823
# all_train_score_W': 0.8158245133919788
# test_score_W0 : 0.7512412912996417
# test_score_W': 0.8070291079723884
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.18999404407385348
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5268717623225991
# error_data0_score_W0 0.5091547073026629
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.7835996833665821
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6965888485866748
# all_train_score_W': 0.6705753598805698
# test_score_W0 : 0.6913658544966393
# test_score_W': 0.6846924555176704
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.1643835616438356
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5297463539762227
# error_data0_score_W0 0.27606044563753807
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9186544032476387
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7003864615516767
# all_train_score_W': 0.7718898030584785
# test_score_W0 : 0.7085221396248487
# test_score_W': 0.7863328453078967
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.16021441334127456
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5298387352222168
# error_data0_score_W0 0.4567980961380196
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9107390422062795
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7103615279381573
# all_train_score_W': 0.7693158913595606
# test_score_W0 : 0.6806247560324393
# test_score_W': 0.7484725881199451
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14492753623188406
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6739550250991722
# error_data0_score_W0 0.3912647676660941
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8592520289805103
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7322505356824606
# all_train_score_W': 0.7619214442064569
# test_score_W0 : 0.7420050736443665
# test_score_W': 0.774018689633535
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10978757196744093
# right_data0_score_W0 1.0
# error_data0_score_W1 0.575717860705729
# error_data0_score_W0 0.41981249692692646
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9106147795908047
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7653907721622653
# all_train_score_W': 0.81286769067241
# test_score_W0 : 0.7603014208259862
# test_score_W': 0.830174839954823
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.24578121897955132
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4600392590208083
# error_data0_score_W0 0.40484026467187206
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.7563766071400566
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6571160924714946
# all_train_score_W': 0.6230921649901834
# test_score_W0 : 0.6567378480000076
# test_score_W': 0.6259126465429219
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.22850903315465554
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5552942983787729
# error_data0_score_W0 0.29168734919673056
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8113209987589157
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6213205333292994
# all_train_score_W': 0.6656390178551079
# test_score_W0 : 0.6273667807837641
# test_score_W': 0.6760507975959845
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.11911852293031566
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5505164889016668
# error_data0_score_W0 0.4116199029064832
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8917085200792259
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7536288610279364
# all_train_score_W': 0.7858620122375163
# test_score_W0 : 0.7573223314861399
# test_score_W': 0.7992285680323681
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.13619217788366092
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5516496445037388
# error_data0_score_W0 0.4078659384382478
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8773912036030774
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7429519439523283
# all_train_score_W': 0.7681695248648727
# test_score_W0 : 0.7435881080705005
# test_score_W': 0.7635850029331666
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10522136192177883
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6016385499829952
# error_data0_score_W0 0.43741783583178406
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9393071656913666
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7818517071827471
# all_train_score_W': 0.8527664562481218
# test_score_W0 : 0.7841317354668136
# test_score_W': 0.858335526062876
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2074647607702998
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5044499676132953
# error_data0_score_W0 0.36992335545263166
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8359914992479004
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6594621048362747
# all_train_score_W': 0.6680143976173727
# test_score_W0 : 0.661296925080523
# test_score_W': 0.6772919075448288
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17470716696446298
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5015647783404109
# error_data0_score_W0 0.355199080886901
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8998604194996841
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6860346474245883
# all_train_score_W': 0.7529089104506088
# test_score_W0 : 0.7035443438127387
# test_score_W': 0.735036445838292
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.1314274369664483
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5489583983114685
# error_data0_score_W0 0.3774590367589522
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8576681174795288
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7388047940920761
# all_train_score_W': 0.7394053617450133
# test_score_W0 : 0.7456734840893426
# test_score_W': 0.7613267040770378
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.1232876712328767
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6391987357376181
# error_data0_score_W0 0.4727672907992105
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9024194136778063
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7658160001422787
# all_train_score_W': 0.8098965279024812
# test_score_W0 : 0.7743741653081241
# test_score_W': 0.8084121849952635
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.13480246178280722
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6258662977098368
# error_data0_score_W0 0.43189667741172505
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8665774585271504
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7367102448786321
# all_train_score_W': 0.7622026283567276
# test_score_W0 : 0.7554562119197666
# test_score_W': 0.7758631593462096
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.22414135398054397
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5069153021717797
# error_data0_score_W0 0.5851614721913034
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8163510096340357
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6513699483011106
# all_train_score_W': 0.6218676244858069
# test_score_W0 : 0.6438145127067066
# test_score_W': 0.6211452896793521
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.1627953146714314
# right_data0_score_W0 1.0
# error_data0_score_W1 0.480521686824634
# error_data0_score_W0 0.4118988738393422
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9259416504466953
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.730973983037876
# all_train_score_W': 0.7661578202727699
# test_score_W0 : 0.7298002958290428
# test_score_W': 0.7797977397936217
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.16815564820329562
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5747219566838704
# error_data0_score_W0 0.4586100552795867
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8887695828813797
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7130275844422189
# all_train_score_W': 0.7806884798393898
# test_score_W0 : 0.7076462560237788
# test_score_W': 0.7812201174594198
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.12765535040698828
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6533403337519977
# error_data0_score_W0 0.3470788460742693
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.8813909225154839
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7540554228619327
# all_train_score_W': 0.7784257652209104
# test_score_W0 : 0.7418215742901553
# test_score_W': 0.7877690977393065
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.09728012705975779
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5987879439263615
# error_data0_score_W0 0.4179501602905269
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8944970088176784
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7818563850573922
# all_train_score_W': 0.8110628594410871
# test_score_W0 : 0.7756730198528805
# test_score_W': 0.8092876689722225
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.23228111971411555
# right_data0_score_W0 1.0
# error_data0_score_W1 0.506191579013957
# error_data0_score_W0 0.26839757437335904
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8199959614349647
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6380878224251586
# all_train_score_W': 0.668546210881701
# test_score_W0 : 0.640689328035711
# test_score_W': 0.6649777226952892
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.1528687710939051
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5126723884871953
# error_data0_score_W0 0.460889297394471
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.920428310950841
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7417134782605838
# all_train_score_W': 0.7821702925338443
# test_score_W0 : 0.7452946842162426
# test_score_W': 0.7865564364800579
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.13857454834226723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5369817048252782
# error_data0_score_W0 0.5171388224217468
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.8842132802034888
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7527534370153999
# all_train_score_W': 0.7740177784801637
# test_score_W0 : 0.75143193360442
# test_score_W': 0.7875509566910828
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.10919197935278936
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5929146288006718
# error_data0_score_W0 0.4111978772899849
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9141669872292606
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7681548209503751
# all_train_score_W': 0.8115228030638133
# test_score_W0 : 0.7631598687629566
# test_score_W': 0.8079540156081645
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.09728012705975779
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6105887977291955
# error_data0_score_W0 0.40836148663764993
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8800566650317253
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7802940292088404
# all_train_score_W': 0.8031071151762632
# test_score_W0 : 0.7857638648982248
# test_score_W': 0.7970223068545854
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.22612666269604922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.49509004319814215
# error_data0_score_W0 0.3312101065954924
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8620617176599418
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6359209645352186
# all_train_score_W': 0.7048938281199055
# test_score_W0 : 0.6451256733705701
# test_score_W': 0.7055348176926631
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17609688306531665
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5040307466604174
# error_data0_score_W0 0.43963256391050953
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.7399957958850326
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6690947943247675
# all_train_score_W': 0.6184663420278477
# test_score_W0 : 0.6651019607294051
# test_score_W': 0.6197824211535787
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.11812586857256303
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5692979047453379
# error_data0_score_W0 0.3786968008800298
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9435354152708378
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7559379303054353
# all_train_score_W': 0.8322972113033719
# test_score_W0 : 0.743415221230118
# test_score_W': 0.8300238681794927
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14135398054397458
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6141648644863007
# error_data0_score_W0 0.47534683479515727
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9136301966314742
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7542389297071819
# all_train_score_W': 0.8127822261205442
# test_score_W0 : 0.7492214580822848
# test_score_W': 0.8079763591928312
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.11673615247170935
# right_data0_score_W0 1.0
# error_data0_score_W1 0.64361630191961
# error_data0_score_W0 0.37501746229038924
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.917089537928826
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7388683710232167
# all_train_score_W': 0.8091957931339658
# test_score_W0 : 0.7545372860664725
# test_score_W': 0.8017419561162121
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  150.0  0.715245  0.055306  0.004516   0.706322  0.724168
# 1  test_score_W'  150.0  0.757614  0.056574  0.004619   0.748486  0.766742
# 2       combined  300.0  0.736429  0.059746  0.003449   0.729641  0.743218
#                               Independent t-test   results
# 0  Difference (test_score_W0 - test_score_W') =    -0.0424
# 1                          Degrees of freedom =   298.0000
# 2                                           t =    -6.5589
# 3                       Two side test p value =     0.0000
# 4                      Difference < 0 p value =     0.0000
# 5                      Difference > 0 p value =     1.0000
# 6                                   Cohen's d =    -0.7574
# 7                                   Hedge's g =    -0.7554
# 8                               Glass's delta =    -0.7661
# 9                                 Pearson's r =     0.3552
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-6.55885084262867, pvalue=1.196175258635368e-10)
