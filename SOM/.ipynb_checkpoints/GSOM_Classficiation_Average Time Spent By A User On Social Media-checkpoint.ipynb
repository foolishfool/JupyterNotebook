# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# self.continuous_feature_num 2
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num =2
best_num = 48
interval = 5


features_chosen = [0,1,2,3,4,5,6,7,8]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
# Out:
# Neuron number: 2
# test_score_W0_p0.15
# test_score_W0_n 0.005699594014870676
# test_score_W0_a  -0.0023876654800692766
# test_score_W_combine_p 0.16
# test_score_W_combine_n 0.009569363145595141
# test_score_W_combine_a 0.0004703282551752534
# Neuron number: 7
# test_score_W0_p0.18333333333333332
# test_score_W0_n 0.030602108207053204
# test_score_W0_a  -0.004980283013117248
# test_score_W_combine_p 0.20333333333333334
# test_score_W_combine_n 0.04412920526429969
# test_score_W_combine_a 0.0030386906167193437
# Neuron number: 12
# test_score_W0_p0.22
# test_score_W0_n 0.08543396364080473
# test_score_W0_a  0.0056375604913824085
# test_score_W_combine_p 0.21666666666666667
# test_score_W_combine_n 0.0676862423798853
# test_score_W_combine_a -0.003528965614168373
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 17
# test_score_W0_p0.24
# test_score_W0_n 0.09374806590383492
# test_score_W0_a  -0.0014253850481237074
# test_score_W_combine_p 0.23333333333333334
# test_score_W_combine_n 0.0880234784627948
# test_score_W_combine_a -0.00167915213749397
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 22
# test_score_W0_p0.28
# test_score_W0_n 0.14688299163135912
# test_score_W0_a  0.007881238843637464
# test_score_W_combine_p 0.27
# test_score_W_combine_n 0.13913180594277905
# test_score_W_combine_a 0.0059116147220291595
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 27
# test_score_W0_p0.27666666666666667
# test_score_W0_n 0.15133307834389614
# test_score_W0_a  0.0014248766076837098
# test_score_W_combine_p 0.27
# test_score_W_combine_n 0.1503044566290438
# test_score_W_combine_a 0.002459726248239594
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Neuron number: 32
# test_score_W0_p0.29
# test_score_W0_n 0.16340819893900474
# test_score_W0_a  -0.003643976390305187
# test_score_W_combine_p 0.2866666666666667
# test_score_W_combine_n 0.1620639156970829
# test_score_W_combine_a 0.0029840299618844545
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Neuron number: 37
# test_score_W0_p0.3333333333333333
# test_score_W0_n 0.2094902647155037
# test_score_W0_a  0.005577549429111029
# test_score_W_combine_p 0.23
# test_score_W_combine_n 0.08517881311755632
# test_score_W_combine_a -0.0033752291250345647
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 42
# test_score_W0_p0.30666666666666664
# test_score_W0_n 0.19214514380867534
# test_score_W0_a  -0.003679913514604171
# test_score_W_combine_p 0.31
# test_score_W_combine_n 0.18481247873576098
# test_score_W_combine_a -0.00261493173788282
# Not good nmi result !!!!!
# Neuron number: 47
# test_score_W0_p0.3333333333333333
# test_score_W0_n 0.21705156153185723
# test_score_W0_a  0.00021350481363513612
# test_score_W_combine_p 0.25333333333333335
# test_score_W_combine_n 0.10320868063336769
# test_score_W_combine_a 0.0030454733530400685
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Neuron number: 52
# test_score_W0_p0.3433333333333333
# test_score_W0_n 0.2358620473507612
# test_score_W0_a  -0.0006157991229129006
# test_score_W_combine_p 0.30333333333333334
# test_score_W_combine_n 0.17144199172106886
# test_score_W_combine_a 0.0015146364872430616
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Neuron number: 57
# test_score_W0_p0.38
# test_score_W0_n 0.2645037401671267
# test_score_W0_a  0.0043157826049128505
# test_score_W_combine_p 0.30666666666666664
# test_score_W_combine_n 0.19304906580009554
# test_score_W_combine_a -0.00021837804822913317
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 62
# test_score_W0_p0.36666666666666664
# test_score_W0_n 0.2592320752567674
# test_score_W0_a  -0.001613828699399291
# test_score_W_combine_p 0.2633333333333333
# test_score_W_combine_n 0.12280452510995421
# test_score_W_combine_a 0.0024968207249649
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Neuron number: 67
# test_score_W0_p0.38
# test_score_W0_n 0.26141211391734726
# test_score_W0_a  0.006657134690994516
# test_score_W_combine_p 0.24
# test_score_W_combine_n 0.07181404619101725
# test_score_W_combine_a 0.0002507339876483974
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 72
# test_score_W0_p0.4033333333333333
# test_score_W0_n 0.2866024041989892
# test_score_W0_a  0.0008795660164911212
# test_score_W_combine_p 0.4033333333333333
# test_score_W_combine_n 0.28091801090766705
# test_score_W_combine_a 0.010468868193733083
# Not good nmi result !!!!!
# Neuron number: 77
# test_score_W0_p0.3933333333333333
# test_score_W0_n 0.28378581002534453
# test_score_W0_a  -0.002093856738054397
# test_score_W_combine_p 0.3333333333333333
# test_score_W_combine_n 0.21490767119193482
# test_score_W_combine_a -0.003924192604823904
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 82
# test_score_W0_p0.4
# test_score_W0_n 0.3018759395996332
# test_score_W0_a  0.004412907085952153
# test_score_W_combine_p 0.30333333333333334
# test_score_W_combine_n 0.19214945937530992
# test_score_W_combine_a 0.006425561017112818
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Neuron number: 87
# test_score_W0_p0.4166666666666667
# test_score_W0_n 0.31799767592870465
# test_score_W0_a  0.002233816038283745
# test_score_W_combine_p 0.26666666666666666
# test_score_W_combine_n 0.13896136169727258
# test_score_W_combine_a -0.004741306528432771
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 92
# test_score_W0_p0.43666666666666665
# test_score_W0_n 0.32559117759517664
# test_score_W0_a  0.0036562038206482276
# test_score_W_combine_p 0.31666666666666665
# test_score_W_combine_n 0.21730705028678518
# test_score_W_combine_a -0.002887548685413882
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 97
# test_score_W0_p0.3433333333333333
# test_score_W0_n 0.2530549864480063
# test_score_W0_a  -0.00015470719388451564
# test_score_W_combine_p 0.24333333333333335
# test_score_W_combine_n 0.1071719453120723
# test_score_W_combine_a 0.004213204287128915
# Not good purity result !!!!!
# Not good nmi result !!!!!
# all_test_score_W0_p mean 0.3238333333333334
# all_test_score_W0_n mean 0.2042856470612358
# all_test_score_W0_a mean 0.0011147362621130833
# all_test_score_W_combine_p mean 0.27066666666666667
# all_test_score_W_combine_n mean 0.13723167838006717
# all_test_score_W_combine_a mean 0.0010154991686719815
# Purity T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_p  20.0  0.323833  0.079716  0.017825   0.286525
# 1  all_test_score_W_combine_p  20.0  0.270667  0.053153  0.011885   0.245790
# 2                    combined  40.0  0.297250  0.072091  0.011399   0.274194
#
#    Interval
# 0  0.361142
# 1  0.295543
# 2  0.320306
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_p - all_test_sco...   0.0532
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    2.4816
# 3                           Two side test p value =    0.0176
# 4                          Difference < 0 p value =    0.9912
# 5                          Difference > 0 p value =    0.0088
# 6                                       Cohen's d =    0.7848
# 7                                       Hedge's g =    0.7692
# 8                                  Glass's delta1 =    0.6669
# 9                                Point-Biserial r =    0.3734
# NMI T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_n  20.0  0.204286  0.093922  0.021002   0.160329
# 1  all_test_score_W_combine_n  20.0  0.137232  0.066859  0.014950   0.105941
# 2                    combined  40.0  0.170759  0.087340  0.013810   0.142826
#
#    Interval
# 0  0.248242
# 1  0.168523
# 2  0.198691
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_n - all_test_sco...   0.0671
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    2.6011
# 3                           Two side test p value =    0.0132
# 4                          Difference < 0 p value =    0.9934
# 5                          Difference > 0 p value =    0.0066
# 6                                       Cohen's d =    0.8225
# 7                                       Hedge's g =    0.8062
# 8                                  Glass's delta1 =    0.7139
# 9                                Point-Biserial r =    0.3888
# ARI Score T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_a  20.0  0.001115  0.003773  0.000844  -0.000651
# 1  all_test_score_W_combine_a  20.0  0.001015  0.004007  0.000896  -0.000860
# 2                    combined  40.0  0.001065  0.003842  0.000607  -0.000164
#
#    Interval
# 0  0.002881
# 1  0.002891
# 2  0.002294
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_a - all_test_sco...   0.0001
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.0806
# 3                           Two side test p value =    0.9362
# 4                          Difference < 0 p value =    0.5319
# 5                          Difference > 0 p value =    0.4681
# 6                                       Cohen's d =    0.0255
# 7                                       Hedge's g =    0.0250
# 8                                  Glass's delta1 =    0.0263
# 9                                Point-Biserial r =    0.0131
