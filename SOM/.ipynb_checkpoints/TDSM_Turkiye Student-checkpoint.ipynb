# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Obesity/ObesityDataSet_raw_and_data_sinthetic.csv")
dataread.stringToIntObseityDataSet(csv,"CAEC")
dataread.stringToIntObseityDataSet(csv,"Gender")
dataread.stringToIntObseityDataSet(csv,"family_history_with_overweight")
dataread.stringToIntObseityDataSet(csv,"FAVC")
dataread.stringToIntObseityDataSet(csv,"SCC")
dataread.stringToIntObseityDataSet(csv,"SMOKE")
dataread.stringToIntObseityDataSet(csv,"CALC")
dataread.stringToIntObseityDataSet(csv,"MTRANS")
dataread.stringToIntObseityDataSet(csv,"NObeyesdad")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"NObeyesdad")

# %%
# local scope2
scoretype = 0
scope_num = 30
class_num = 7
dim_num = 16
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 7
# *******************
#
# Error Data percentage 0.5284167794316644
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5544174135723432
# error_data0_score_W0 0.6081946222791293
# combinedweight shape 0: (14, 16)
# right_data0_score_W' 0.8837876614060258
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.47158322056833557
# all_train_score_W': 0.5663058186738836
# test_score_W0 : 0.46129541864139023
# test_score_W': 0.5576619273301737
# neuron unit number: 14
# *******************
#
# Error Data percentage 0.44993234100135315
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5669172932330827
# error_data0_score_W0 0.5263157894736842
# combinedweight shape 0: (28, 16)
# right_data0_score_W' 0.7355473554735548
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5500676589986468
# all_train_score_W': 0.560893098782138
# test_score_W0 : 0.5513428120063191
# test_score_W': 0.5497630331753555
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.39918809201623817
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6457627118644068
# error_data0_score_W0 0.6067796610169491
# combinedweight shape 0: (42, 16)
# right_data0_score_W' 0.7263513513513513
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6008119079837618
# all_train_score_W': 0.5257104194857916
# test_score_W0 : 0.6113744075829384
# test_score_W': 0.5418641390205371
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.3531799729364005
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7011494252873564
# error_data0_score_W0 0.632183908045977
# combinedweight shape 0: (56, 16)
# right_data0_score_W' 0.7217573221757322
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6468200270635994
# all_train_score_W': 0.5805142083897158
# test_score_W0 : 0.6287519747235387
# test_score_W': 0.6129541864139021
# neuron unit number: 35
# *******************
#
# Error Data percentage 0.33964817320703655
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6952191235059761
# error_data0_score_W0 0.5079681274900398
# combinedweight shape 0: (70, 16)
# right_data0_score_W' 0.6752049180327869
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6603518267929634
# all_train_score_W': 0.557510148849797
# test_score_W0 : 0.6382306477093207
# test_score_W': 0.5624012638230648
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.33897158322056836
# right_data0_score_W0 1.0
# error_data0_score_W1 0.688622754491018
# error_data0_score_W0 0.5728542914171657
# combinedweight shape 0: (84, 16)
# right_data0_score_W' 0.7543500511770727
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6610284167794317
# all_train_score_W': 0.6414073071718539
# test_score_W0 : 0.6429699842022117
# test_score_W': 0.641390205371248
# neuron unit number: 49
# *******************
#
# Error Data percentage 0.3085250338294993
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6885964912280702
# error_data0_score_W0 0.543859649122807
# combinedweight shape 0: (98, 16)
# right_data0_score_W' 0.735812133072407
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6914749661705006
# all_train_score_W': 0.6231393775372125
# test_score_W0 : 0.6429699842022117
# test_score_W': 0.6398104265402843
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.2956698240866035
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6956521739130435
# error_data0_score_W0 0.5446224256292906
# combinedweight shape 0: (112, 16)
# right_data0_score_W' 0.8146013448607109
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7043301759133965
# all_train_score_W': 0.7050067658998647
# test_score_W0 : 0.6761453396524486
# test_score_W': 0.6540284360189573
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.32205683355886333
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7542016806722689
# error_data0_score_W0 0.5357142857142857
# combinedweight shape 0: (126, 16)
# right_data0_score_W' 0.8153692614770459
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6779431664411367
# all_train_score_W': 0.6948579161028416
# test_score_W0 : 0.6461295418641391
# test_score_W': 0.6761453396524486
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.2943166441136671
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7655172413793103
# error_data0_score_W0 0.5816091954022988
# combinedweight shape 0: (140, 16)
# right_data0_score_W' 0.7689357622243528
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7056833558863329
# all_train_score_W': 0.6786197564276049
# test_score_W0 : 0.6729857819905213
# test_score_W': 0.6682464454976303
# neuron unit number: 77
# *******************
#
# Error Data percentage 0.2922868741542625
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7013888888888888
# error_data0_score_W0 0.5486111111111112
# combinedweight shape 0: (154, 16)
# right_data0_score_W' 0.7351816443594646
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7077131258457375
# all_train_score_W': 0.6542625169147497
# test_score_W0 : 0.684044233807267
# test_score_W': 0.6287519747235387
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2598105548037889
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7786458333333334
# error_data0_score_W0 0.5494791666666666
# combinedweight shape 0: (168, 16)
# right_data0_score_W' 0.7568555758683729
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7401894451962111
# all_train_score_W': 0.7036535859269283
# test_score_W0 : 0.6856240126382307
# test_score_W': 0.6587677725118484
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.2571041948579161
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7657894736842106
# error_data0_score_W0 0.5526315789473685
# combinedweight shape 0: (182, 16)
# right_data0_score_W' 0.7049180327868853
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7428958051420839
# all_train_score_W': 0.6617050067658998
# test_score_W0 : 0.7109004739336493
# test_score_W': 0.6034755134281201
# neuron unit number: 98
# *******************
#
# Error Data percentage 0.2530446549391069
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7540106951871658
# error_data0_score_W0 0.5721925133689839
# combinedweight shape 0: (196, 16)
# right_data0_score_W' 0.7255434782608695
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7469553450608931
# all_train_score_W': 0.6677943166441137
# test_score_W0 : 0.6919431279620853
# test_score_W': 0.631911532385466
# neuron unit number: 105
# *******************
#
# Error Data percentage 0.2787550744248985
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7597087378640777
# error_data0_score_W0 0.5558252427184466
# combinedweight shape 0: (210, 16)
# right_data0_score_W' 0.7851782363977486
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7212449255751014
# all_train_score_W': 0.7043301759133965
# test_score_W0 : 0.688783570300158
# test_score_W': 0.6492890995260664
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.2469553450608931
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7917808219178082
# error_data0_score_W0 0.5589041095890411
# combinedweight shape 0: (224, 16)
# right_data0_score_W' 0.7646001796945193
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7530446549391069
# all_train_score_W': 0.7151556156968877
# test_score_W0 : 0.6951026856240127
# test_score_W': 0.688783570300158
# neuron unit number: 119
# *******************
#
# Error Data percentage 0.2449255751014885
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7596685082872928
# error_data0_score_W0 0.5138121546961326
# combinedweight shape 0: (238, 16)
# right_data0_score_W' 0.7661290322580645
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7550744248985115
# all_train_score_W': 0.70297699594046
# test_score_W0 : 0.7235387045813586
# test_score_W': 0.6682464454976303
# neuron unit number: 126
# *******************
#
# Error Data percentage 0.2469553450608931
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7808219178082192
# error_data0_score_W0 0.5589041095890411
# combinedweight shape 0: (252, 16)
# right_data0_score_W' 0.734052111410602
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7530446549391069
# all_train_score_W': 0.6907983761840325
# test_score_W0 : 0.7519747235387045
# test_score_W': 0.6635071090047393
# neuron unit number: 133
# *******************
#
# Error Data percentage 0.2476319350473613
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8497267759562842
# error_data0_score_W0 0.5601092896174863
# combinedweight shape 0: (266, 16)
# right_data0_score_W' 0.75
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7523680649526387
# all_train_score_W': 0.7212449255751014
# test_score_W0 : 0.7061611374407583
# test_score_W': 0.6729857819905213
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.2692828146143437
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7562814070351759
# error_data0_score_W0 0.5201005025125628
# combinedweight shape 0: (280, 16)
# right_data0_score_W' 0.7111111111111111
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7307171853856563
# all_train_score_W': 0.6684709066305818
# test_score_W0 : 0.688783570300158
# test_score_W': 0.6192733017377567
# neuron unit number: 147
# *******************
#
# Error Data percentage 0.2855209742895805
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7677725118483413
# error_data0_score_W0 0.533175355450237
# combinedweight shape 0: (294, 16)
# right_data0_score_W' 0.7784090909090909
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7144790257104194
# all_train_score_W': 0.7002706359945873
# test_score_W0 : 0.7030015797788309
# test_score_W': 0.6808846761453397
# neuron unit number: 154
# *******************
#
# Error Data percentage 0.2774018944519621
# right_data0_score_W0 1.0
# error_data0_score_W1 0.748780487804878
# error_data0_score_W0 0.4975609756097561
# combinedweight shape 0: (308, 16)
# right_data0_score_W' 0.7771535580524345
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7225981055480379
# all_train_score_W': 0.7165087956698241
# test_score_W0 : 0.6951026856240127
# test_score_W': 0.65086887835703
# neuron unit number: 161
# *******************
#
# Error Data percentage 0.2740189445196211
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7135802469135802
# error_data0_score_W0 0.5654320987654321
# combinedweight shape 0: (322, 16)
# right_data0_score_W' 0.7726001863932899
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.725981055480379
# all_train_score_W': 0.6847090663058186
# test_score_W0 : 0.6872037914691943
# test_score_W': 0.6524486571879937
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.2557510148849797
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7724867724867724
# error_data0_score_W0 0.5317460317460317
# combinedweight shape 0: (336, 16)
# right_data0_score_W' 0.7627272727272727
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7442489851150202
# all_train_score_W': 0.713125845737483
# test_score_W0 : 0.688783570300158
# test_score_W': 0.6571879936808847
# neuron unit number: 175
# *******************
#
# Error Data percentage 0.2780784844384303
# right_data0_score_W0 1.0
# error_data0_score_W1 0.732360097323601
# error_data0_score_W0 0.5085158150851582
# combinedweight shape 0: (350, 16)
# right_data0_score_W' 0.6935332708528584
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7219215155615697
# all_train_score_W': 0.638700947225981
# test_score_W0 : 0.7045813586097947
# test_score_W': 0.6255924170616114
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.2361299052774019
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7593123209169055
# error_data0_score_W0 0.6131805157593123
# combinedweight shape 0: (364, 16)
# right_data0_score_W' 0.7767936226749336
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7638700947225981
# all_train_score_W': 0.7212449255751014
# test_score_W0 : 0.7377567140600316
# test_score_W': 0.660347551342812
# neuron unit number: 189
# *******************
#
# Error Data percentage 0.2828146143437077
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7248803827751196
# error_data0_score_W0 0.5287081339712919
# combinedweight shape 0: (378, 16)
# right_data0_score_W' 0.6726415094339623
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7171853856562923
# all_train_score_W': 0.6407307171853857
# test_score_W0 : 0.7061611374407583
# test_score_W': 0.6145339652448657
# neuron unit number: 196
# *******************
#
# Error Data percentage 0.2489851150202977
# right_data0_score_W0 1.0
# error_data0_score_W1 0.782608695652174
# error_data0_score_W0 0.5733695652173914
# combinedweight shape 0: (392, 16)
# right_data0_score_W' 0.7576576576576577
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7510148849797023
# all_train_score_W': 0.7158322056833559
# test_score_W0 : 0.717219589257504
# test_score_W': 0.6966824644549763
# neuron unit number: 203
# *******************
#
# Error Data percentage 0.22665764546684708
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7761194029850746
# error_data0_score_W0 0.5343283582089552
# combinedweight shape 0: (406, 16)
# right_data0_score_W' 0.7611548556430446
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7733423545331529
# all_train_score_W': 0.7185385656292287
# test_score_W0 : 0.7282780410742496
# test_score_W': 0.6714060031595577
# neuron unit number: 210
# *******************
#
# Error Data percentage 0.2476319350473613
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7704918032786885
# error_data0_score_W0 0.5300546448087432
# combinedweight shape 0: (420, 16)
# right_data0_score_W' 0.7787769784172662
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7523680649526387
# all_train_score_W': 0.7300405953991881
# test_score_W0 : 0.7140600315955766
# test_score_W': 0.6714060031595577
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.676040  0.057722  0.010539   0.654486  0.697594
# 1  test_score_W'  30.0  0.639021  0.041310  0.007542   0.623595  0.654446
# 2       combined  60.0  0.657530  0.053150  0.006862   0.643800  0.671260
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0370
# 1                          Degrees of freedom =   58.0000
# 2                                           t =    2.8566
# 3                       Two side test p value =    0.0059
# 4                      Difference < 0 p value =    0.9970
# 5                      Difference > 0 p value =    0.0030
# 6                                   Cohen's d =    0.7376
# 7                                   Hedge's g =    0.7280
# 8                               Glass's delta =    0.6413
# 9                                 Pearson's r =    0.3512
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=2.856586842246585, pvalue=0.9970325851538312)
