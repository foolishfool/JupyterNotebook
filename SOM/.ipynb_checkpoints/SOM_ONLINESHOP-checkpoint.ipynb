# %%
import pandas as pd
import numpy as np
import random
import newSom
from mayavi import mlab

# %%
def stringToInt(X,name):
    X[name] = X[name].astype(str).str.strip()
    #print(X[name])
    for i in range(0, X.shape[0]):
        if  X.at[i,name]== 'Jan':
            X.at[i,name] =1            
        elif  X.at[i,name]== 'Feb':
                X.at[i,name]=2 
        elif  X.at[i,name]== 'Mar': 
            X.at[i,name]=3 
        elif  X.at[i,name]== 'Apr': 
            X.at[i,name]=4 
        elif  X.at[i,name]== 'May': 
            X.at[i,name]=5 
        elif  X.at[i,name]== 'June': 
            X.at[i,name]=6  
        elif  X.at[i,name]== 'Jul': 
            X.at[i,name]=7 
        elif  X.at[i,name]== 'Aug':
            X.at[i,name]=8 
        elif  X.at[i,name]== 'Sep':
            X.at[i,name]=9 
        elif  X.at[i,name]== 'Oct':
            X.at[i,name]=10
        elif  X.at[i,name]== 'Nov':
            X.at[i,name]=11 
        elif  X.at[i,name]== 'Dec': 
            X.at[i,name]=12
        elif  X.at[i,name]== 'Returning_Visitor':  
            X.at[i,name]=0
        elif  X.at[i,name]== 'New_Visitor': 
            X.at[i,name]=1
        elif  X.at[i,name]== 'Other': 
            X.at[i,name]=3
        elif  X.at[i,name]== 'False': 
            X.at[i,name]=0        
        elif  X.at[i,name]== 'True': 
            #print(X.at[i,name])
            X.at[i,name]=1
            #print(X.at[i,name])
        else: 
            print("Unkonwn value {}".format(X.at[i,name]))

# %%
csv = pd.read_csv("online_shoppers_intention.csv")
del csv["Month"]
del csv["Weekend"]
stringToInt(csv,"VisitorType")
stringToInt(csv,"Revenue")
#sample number of train and test dataset
train_num = 5000
test_num = 5000
#get samples
data_train = csv
#data_train = csv.sample(train_num)
#data_test = csv.drop(data_train.index)
#print(data_train)
#data_train = data_train[:,0]
#print(data_train[:,1].values)
#data_train.to_numpy(dtype=np.float64)
#data_test = csv.sample(test_num).to_numpy(dtype=np.float64)
a = np.asarray(data_train,dtype='object')
#label_train = data_train[:,data_train.shape[1]-1]
#label_test = data_test[:,data_test.shape[1]-1]
## delete the last column
data_train = a[:,:1]
#data_test= data_test[:,:-1]
print(data_train)
# Out:
# [[0]
#  [2]
#  [8]
#  ...
#  [0]
#  [3]
#  [3]]

# %%
def NormalizeLables(X,Y,category = 0):
    """
    transfrer predcited label to match the range of true label
    a = np.amax(X)+1,b = np.amax(Y)+1 the number of classes in X and Y
    b= m*n,  to make it easier , to make b can be divided by a
    category = 0 noramlize label
    category = 1 normalize sub label
    """
    div = int((np.amax(Y)+1)/(np.amax(X)+1))
    #print("div : {}".format(div) )
    if(category == 0):
        global nLabel 
        nLabel = np.arange(Y.size)
    if(category == 1):
        global nsubLabel 
        nsubLabel = np.arange(Y.size)
    index = 0;
    for idx, y in enumerate(Y): 
       # print("idx {}".format(idx))
        for i in range(1,div+1):
            if(y < i*div):
                index+=1
                #print(i-1)
                if(category == 0):
                    nLabel[idx] = i-1
                if(category == 1):
                    nsubLabel[idx] = i-1
                break               
    if(category == 0):
        print("normalized predicted nLabel:\n {} ".format(nLabel))
    if(category == 1):
        print("normalized predicted nsubLabel: \n{} ".format(nsubLabel))
    return

# %%
def purity_score(y_true, y_pred):
    # compute contingency matrix (also called confusion matrix)
    #print(y_true.shape)
    #print(y_pred.shape)
    contingency_matrix = metrics.cluster.contingency_matrix(y_true, y_pred)
    # return purity
   # print (np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix))
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
def groupClusterList(m,Y):
    """
    transfer all label in a list
    m: cluster Number
    """
    clusters = []
    for i in range(0,m):
        newlist = []
        for idx, y in enumerate(Y): 
            if(y == i):
                newlist.append(idx)
        clusters.append(newlist) 
   # print(clusters)
    return clusters

# %%
def getNoisyClusters(list_true,list_pred):
    """
    get the wrong data indices in the training data when predicted with weight1
    """
    noisylist = []
    for i in range(0,len(list_true)):
        newlist = [item for item in list_pred[i] if item not in list_true[i]]
        noisylist.append(newlist)
    print("noisy data:")
    return noisylist

# %%
def reduce_noisy_data(noisy_list, percent):
    newlist = []
    for x in noisy_list:
        for e in x:
            newlist.append(e)
   # print(newlist)
   # print(len(newlist))
   # print(int(percent * len(newlist)))
    newlist = random.sample(newlist, int(percent * len(newlist)))
   # print(newlist)
    return newlist

# %%
def reduce_data_byindice(reduced_indices,X,category = 0):
   
    if(category == 0): 
        global data_train_subset
        data_train_subset= np.delete(X, reduced_indices, axis=0)
        #print("reduced_indices :{}".format(reduced_indices))
    if(category == 1): 
        global data_train_sublabel
        data_train_sublabel=np.delete(X,reduced_indices, axis=0)
    #print(df_subset.to_numpy())   
    return

# %%
som1 = newSom.SOM(m=2, n=1, dim=1)
# Out:
# [[ 2.40905709]
#  [-1.11629845]]

# %%
x_stack = np.stack([[1, 44.5, 0, 0.0, 31 ,739.6666667, 0.01 ,0.052222222, 0.0 ,0.0 ,1, 8 ,3, 1, 0]]*(2), axis=0)
print(x_stack)
# Out:
# [[1.00000000e+00 4.45000000e+01 0.00000000e+00 0.00000000e+00
#   3.10000000e+01 7.39666667e+02 1.00000000e-02 5.22222220e-02
#   0.00000000e+00 0.00000000e+00 1.00000000e+00 8.00000000e+00
#   3.00000000e+00 1.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 4.45000000e+01 0.00000000e+00 0.00000000e+00
#   3.10000000e+01 7.39666667e+02 1.00000000e-02 5.22222220e-02
#   0.00000000e+00 0.00000000e+00 1.00000000e+00 8.00000000e+00
#   3.00000000e+00 1.00000000e+00 0.00000000e+00]]

# %%
som1.fit(data_train)
# Out:
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[ 2.40905709]
#  [-1.11629845]]
# x_stack - newWeights:[[-2.4090570872958583]
#  [1.1162984536982823]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.88624258]
#  [ 1.11629845]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.52281451]
#  [0.        ]]
# x_stack - newWeights:[[1.4771854877286446]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.47718549]
#  [1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[-3.0]
#  [-1.103638323514327]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.89636168]
#  [0.        ]]
# x_stack - newWeights:[[-1.896361676485673]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.69763247]
#  [ 0.        ]]
# [15]
# x_stack[[15]
#  [15]]
# x:[15]
# x_stack:[[15]
#  [15]]
# newWeights:[[1.1987292]
#  [0.       ]]
# x_stack - newWeights:[[13.801270797318816]
#  [15.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[13.8012708 ]
#  [ 5.51819162]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[15.        ]
#  [ 5.51819162]]
# x_stack - newWeights:[[-13.0]
#  [-3.5181916175716346]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-4.78243274]
#  [-3.51819162]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[10.21756726]
#  [ 2.        ]]
# x_stack - newWeights:[[-8.21756726477125]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.02307405]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[7.19449321]
#  [2.        ]]
# x_stack - newWeights:[[-7.194493211618465]
#  [-2.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.64670614]
#  [-2.        ]]
# [15]
# x_stack[[15]
#  [15]]
# x:[15]
# x_stack:[[15]
#  [15]]
# newWeights:[[4.54778707]
#  [0.        ]]
# x_stack - newWeights:[[10.452212930583471]
#  [15.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[10.45221293]
#  [ 5.51819162]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[15.        ]
#  [ 5.51819162]]
# x_stack - newWeights:[[-15.0]
#  [-5.518191617571635]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-5.51819162]
#  [-5.51819162]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[9.48180838]
#  [0.        ]]
# x_stack - newWeights:[[-9.481808382428365]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.48816237]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[5.99364601]
#  [0.        ]]
# x_stack - newWeights:[[-5.993646013405921]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.20493915]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.78870687]
#  [0.        ]]
# x_stack - newWeights:[[-3.7887068674147075]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.39378737]
#  [ 0.        ]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[2.3949195]
#  [0.       ]]
# x_stack - newWeights:[[-0.39491950226777917]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-0.3949195 ]
#  [ 0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[-2.0]
#  [-0.7357588823428847]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.26424112]
#  [0.        ]]
# x_stack - newWeights:[[-1.2642411176571153]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.46508832]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.7991528]
#  [0.       ]]
# x_stack - newWeights:[[-0.7991528017874561]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.29399189]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.50516092]
#  [0.        ]]
# x_stack - newWeights:[[-0.5051609156552943]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.18583832]
#  [ 0.        ]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[0.3193226]
#  [0.       ]]
# x_stack - newWeights:[[1.6806773996976294]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.6806774 ]
#  [0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[-2.0]
#  [-0.7357588823428847]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.73575888]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.26424112]
#  [0.        ]]
# x_stack - newWeights:[[2.7357588823428847]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[2.73575888]
#  [1.47151776]]
# [5]
# x_stack[[5]
#  [5]]
# x:[5]
# x_stack:[[5]
#  [5]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[1.0]
#  [3.5284822353142307]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.        ]
#  [1.29805607]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[5.        ]
#  [2.76957384]]
# x_stack - newWeights:[[-3.0]
#  [-0.7695738375965302]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-0.76957384]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[3.89636168]
#  [2.        ]]
# x_stack - newWeights:[[-1.896361676485673]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.69763247]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.1987292]
#  [2.       ]]
# x_stack - newWeights:[[-3.198729202681184]
#  [-2.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.17674671]
#  [-2.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.02198249]
#  [0.        ]]
# x_stack - newWeights:[[-2.021982491140057]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.74384579]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.2781367]
#  [0.       ]]
# x_stack - newWeights:[[-1.278136702241012]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.47020022]
#  [ 0.        ]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[0.80793649]
#  [0.        ]]
# x_stack - newWeights:[[0.19206351352012174]
#  [1.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.19206351]
#  [0.36787944]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.        ]
#  [0.36787944]]
# x_stack - newWeights:[[2.0]
#  [2.6321205588285577]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[2.        ]
#  [0.96830304]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.        ]
#  [1.33618248]]
# x_stack - newWeights:[[-3.0]
#  [-1.3361824814491565]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-1.33618248]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.89636168]
#  [0.        ]]
# x_stack - newWeights:[[0.103638323514327]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.10363832]
#  [0.73575888]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[1.0]
#  [2.2642411176571153]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.        ]
#  [0.83296776]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.        ]
#  [1.56872664]]
# x_stack - newWeights:[[-3.0]
#  [-1.5687266393839863]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-1.56872664]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.89636168]
#  [0.        ]]
# x_stack - newWeights:[[-0.896361676485673]
#  [1.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-0.89636168]
#  [ 0.36787944]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.        ]
#  [0.36787944]]
# x_stack - newWeights:[[-1.0]
#  [-0.36787944117144233]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.36787944]
#  [-0.36787944]]
# [8]
# x_stack[[8]
#  [8]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[0.63212056]
#  [0.        ]]
# x_stack - newWeights:[[7.367879441171443]
#  [8.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[7.36787944]
#  [2.94303553]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[8.        ]
#  [2.94303553]]
# x_stack - newWeights:[[-7.0]
#  [-1.9430355293715387]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.57515609]
#  [-1.94303553]]
# [8]
# x_stack[[8]
#  [8]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[5.42484391]
#  [1.        ]]
# x_stack - newWeights:[[2.575156088200096]
#  [7.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[2.57515609]
#  [2.57515609]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[8.        ]
#  [3.57515609]]
# x_stack - newWeights:[[-7.0]
#  [-2.5751560882000963]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.57515609]
#  [-2.57515609]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[5.42484391]
#  [1.        ]]
# x_stack - newWeights:[[-5.424843911799904]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.99568855]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.42915537]
#  [0.        ]]
# x_stack - newWeights:[[-3.4291553650846542]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.26151576]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.16763961]
#  [0.        ]]
# x_stack - newWeights:[[-2.167639605687258]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.79743005]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.37020956]
#  [0.        ]]
# x_stack - newWeights:[[-1.3702095588859438]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.50407193]
#  [ 0.        ]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[0.86613763]
#  [0.        ]]
# x_stack - newWeights:[[2.133862367924786]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[2.13386237]
#  [1.10363832]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[-2.0]
#  [-0.103638323514327]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.26424112]
#  [1.        ]]
# x_stack - newWeights:[[-2.2642411176571153]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.83296776]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.43127336]
#  [0.        ]]
# x_stack - newWeights:[[-1.4312733606160137]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.52653604]
#  [ 0.        ]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[0.90473732]
#  [0.        ]]
# x_stack - newWeights:[[1.0952626834509775]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.09526268]
#  [0.73575888]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[4.0]
#  [5.264241117657115]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[4.        ]
#  [1.93660608]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[6.        ]
#  [2.67236496]]
# x_stack - newWeights:[[-6.0]
#  [-2.672364962898313]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.20727665]
#  [-2.67236496]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[3.79272335]
#  [0.        ]]
# x_stack - newWeights:[[-0.792723352971346]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-0.79272335]
#  [ 1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[-3.0]
#  [-1.103638323514327]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.89636168]
#  [0.        ]]
# x_stack - newWeights:[[-1.896361676485673]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.69763247]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.1987292]
#  [0.       ]]
# x_stack - newWeights:[[-1.198729202681184]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.44098783]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.75774137]
#  [0.        ]]
# x_stack - newWeights:[[-0.7577413734829415]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.27875747]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.4789839]
#  [0.       ]]
# x_stack - newWeights:[[-0.47898390045355577]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.17620833]
#  [ 0.        ]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[0.30277557]
#  [0.        ]]
# x_stack - newWeights:[[3.697224429175416]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[3.69722443]
#  [1.47151776]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[-3.0]
#  [-0.47151776468576934]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-0.47151776]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[2.89636168]
#  [1.        ]]
# x_stack - newWeights:[[-1.896361676485673]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.69763247]
#  [ 0.        ]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[2.1987292]
#  [1.       ]]
# x_stack - newWeights:[[1.801270797318816]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.8012708 ]
#  [1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.        ]
#  [2.10363832]]
# x_stack - newWeights:[[-4.0]
#  [-2.103638323514327]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.47151776]
#  [-2.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.52848224]
#  [0.        ]]
# x_stack - newWeights:[[-2.5284822353142307]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.93017663]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.58798377]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.01032183]
#  [0.        ]]
# x_stack - newWeights:[[-1.0103218313105886]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.37167663]
#  [ 0.        ]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[0.6386452]
#  [0.       ]]
# x_stack - newWeights:[[5.361354799395259]
#  [6.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.3613548 ]
#  [2.20727665]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[6.        ]
#  [2.20727665]]
# x_stack - newWeights:[[-5.0]
#  [-1.207276647028654]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.83939721]
#  [-1.20727665]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[4.16060279]
#  [1.        ]]
# x_stack - newWeights:[[-3.160602794142788]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.16272079]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.997882]
#  [1.      ]]
# x_stack - newWeights:[[-2.99788200446864]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10285916]
#  [-1.        ]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.89502285]
#  [0.        ]]
# x_stack - newWeights:[[0.10497715203320679]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.10497715]
#  [0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[-2.0]
#  [-0.7357588823428847]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.73575888]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.26424112]
#  [0.        ]]
# x_stack - newWeights:[[0.7357588823428847]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.73575888]
#  [0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[-2.0]
#  [-0.7357588823428847]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.26424112]
#  [0.        ]]
# x_stack - newWeights:[[-1.2642411176571153]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.46508832]
#  [ 0.        ]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[0.7991528]
#  [0.       ]]
# x_stack - newWeights:[[0.20084719821254393]
#  [1.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.2008472 ]
#  [0.36787944]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.        ]
#  [0.36787944]]
# x_stack - newWeights:[[-1.0]
#  [-0.36787944117144233]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.36787944]
#  [-0.36787944]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[0.63212056]
#  [0.        ]]
# x_stack - newWeights:[[2.3678794411714423]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[2.36787944]
#  [1.10363832]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[-1.0]
#  [0.896361676485673]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.36787944]
#  [ 0.89636168]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[2.63212056]
#  [2.        ]]
# x_stack - newWeights:[[0.36787944117144233]
#  [1.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.36787944]
#  [0.36787944]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[3.        ]
#  [2.36787944]]
# x_stack - newWeights:[[0.0]
#  [0.6321205588285577]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.        ]
#  [0.23254416]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.       ]
#  [2.6004236]]
# x_stack - newWeights:[[-3.0]
#  [-2.600423599106272]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-2.6004236 ]]
# [10]
# x_stack[[10]
#  [10]]
# x:[10]
# x_stack:[[10]
#  [10]]
# newWeights:[[1.89636168]
#  [0.        ]]
# x_stack - newWeights:[[8.103638323514327]
#  [10.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[8.10363832]
#  [3.67879441]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[10.        ]
#  [ 3.67879441]]
# x_stack - newWeights:[[-9.0]
#  [-2.6787944117144233]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.31091497]
#  [-2.67879441]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[6.68908503]
#  [1.        ]]
# x_stack - newWeights:[[-6.6890850294570185]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.46077686]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.22830817]
#  [0.        ]]
# x_stack - newWeights:[[-4.228308166872109]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.55550765]
#  [ 0.        ]]
# [8]
# x_stack[[8]
#  [8]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[2.67280052]
#  [0.        ]]
# x_stack - newWeights:[[5.327199478657448]
#  [8.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.32719948]
#  [2.94303553]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[8.        ]
#  [2.94303553]]
# x_stack - newWeights:[[-8.0]
#  [-2.9430355293715387]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.94303553]
#  [-2.94303553]]
# [7]
# x_stack[[7]
#  [7]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[5.05696447]
#  [0.        ]]
# x_stack - newWeights:[[1.9430355293715387]
#  [7.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.94303553]
#  [2.57515609]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[7.        ]
#  [2.57515609]]
# x_stack - newWeights:[[-7.0]
#  [-2.5751560882000963]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.57515609]
#  [-2.57515609]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.42484391]
#  [0.        ]]
# x_stack - newWeights:[[-4.424843911799904]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.62780911]
#  [ 0.        ]]
# [9]
# x_stack[[9]
#  [9]]
# x:[9]
# x_stack:[[9]
#  [9]]
# newWeights:[[2.79703481]
#  [0.        ]]
# x_stack - newWeights:[[6.202965193743903]
#  [9.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[6.20296519]
#  [3.31091497]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[9.        ]
#  [3.31091497]]
# x_stack - newWeights:[[-5.0]
#  [0.689085029457019]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.83939721]
#  [ 0.68908503]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[7.16060279]
#  [4.        ]]
# x_stack - newWeights:[[-7.160602794142788]
#  [-4.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.63423855]
#  [-4.        ]]
# [10]
# x_stack[[10]
#  [10]]
# x:[10]
# x_stack:[[10]
#  [10]]
# newWeights:[[4.52636424]
#  [0.        ]]
# x_stack - newWeights:[[5.47363576021713]
#  [10.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.47363576]
#  [3.67879441]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[10.        ]
#  [ 3.67879441]]
# x_stack - newWeights:[[-9.0]
#  [-2.6787944117144233]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.31091497]
#  [-2.67879441]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[6.68908503]
#  [1.        ]]
# x_stack - newWeights:[[-2.6890850294570185]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-2.68908503]
#  [ 1.10363832]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[4.        ]
#  [2.10363832]]
# x_stack - newWeights:[[0.0]
#  [1.896361676485673]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.        ]
#  [0.69763247]]
# [12]
# x_stack[[12]
#  [12]]
# x:[12]
# x_stack:[[12]
#  [12]]
# newWeights:[[4.       ]
#  [2.8012708]]
# x_stack - newWeights:[[8.0]
#  [9.198729202681184]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[8.        ]
#  [3.38402336]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[12.        ]
#  [ 6.18529416]]
# x_stack - newWeights:[[-12.0]
#  [-6.185294155888597]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-4.41455329]
#  [-6.18529416]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[7.58544671]
#  [0.        ]]
# x_stack - newWeights:[[-3.585446705942692]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-3.58544671]
#  [ 1.47151776]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[0.0]
#  [2.5284822353142307]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.        ]
#  [0.93017663]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.       ]
#  [2.4016944]]
# x_stack - newWeights:[[-4.0]
#  [-2.401694396425088]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.47151776]
#  [-2.4016944 ]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[2.52848224]
#  [0.        ]]
# x_stack - newWeights:[[-0.5284822353142307]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-0.52848224]
#  [ 0.73575888]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[-2.0]
#  [-0.7357588823428847]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.73575888]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.26424112]
#  [0.        ]]
# x_stack - newWeights:[[0.7357588823428847]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.73575888]
#  [0.73575888]]
# [12]
# x_stack[[12]
#  [12]]
# x:[12]
# x_stack:[[12]
#  [12]]
# newWeights:[[2.        ]
#  [0.73575888]]
# x_stack - newWeights:[[10.0]
#  [11.264241117657114]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[10.        ]
#  [ 4.14388273]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[12.        ]
#  [ 4.87964161]]
# x_stack - newWeights:[[-12.0]
#  [-4.879641609926967]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-4.41455329]
#  [-4.87964161]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[7.58544671]
#  [0.        ]]
# x_stack - newWeights:[[-7.585446705942692]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.7905299]
#  [ 0.       ]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[4.79491681]
#  [0.        ]]
# x_stack - newWeights:[[-1.794916810724736]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-1.79491681]
#  [ 1.10363832]]
# [12]
# x_stack[[12]
#  [12]]
# x:[12]
# x_stack:[[12]
#  [12]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[9.0]
#  [10.896361676485673]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[9.        ]
#  [4.00854744]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[12.        ]
#  [ 5.11218577]]
# x_stack - newWeights:[[-12.0]
#  [-5.1121857678617975]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-4.41455329]
#  [-5.11218577]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[7.58544671]
#  [0.        ]]
# x_stack - newWeights:[[-7.585446705942692]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.7905299]
#  [ 0.       ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.79491681]
#  [0.        ]]
# x_stack - newWeights:[[-4.794916810724736]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.76395132]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.03096549]
#  [0.        ]]
# x_stack - newWeights:[[-3.030965493931766]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.11502989]
#  [ 0.        ]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.9159356]
#  [0.       ]]
# x_stack - newWeights:[[1.084064398185777]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.0840644 ]
#  [1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[-3.0]
#  [-1.103638323514327]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [-1.10363832]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.89636168]
#  [0.        ]]
# x_stack - newWeights:[[-1.896361676485673]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.69763247]
#  [ 0.        ]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.1987292]
#  [0.       ]]
# x_stack - newWeights:[[-0.198729202681184]
#  [1.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-0.1987292 ]
#  [ 0.36787944]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.        ]
#  [0.36787944]]
# x_stack - newWeights:[[0.0]
#  [0.6321205588285577]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.        ]
#  [0.23254416]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[1.       ]
#  [0.6004236]]
# x_stack - newWeights:[[5.0]
#  [5.399576400893728]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.        ]
#  [1.98639315]]
# [15]
# x_stack[[15]
#  [15]]
# x:[15]
# x_stack:[[15]
#  [15]]
# newWeights:[[6.        ]
#  [2.58681675]]
# x_stack - newWeights:[[9.0]
#  [12.413183251970436]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[9.        ]
#  [4.56655492]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[15.        ]
#  [ 7.15337167]]
# x_stack - newWeights:[[-15.0]
#  [-7.153371665923156]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-5.51819162]
#  [-7.15337167]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[9.48180838]
#  [0.        ]]
# x_stack - newWeights:[[-5.481808382428365]
#  [4.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.0166446]
#  [ 4.       ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[7.46516378]
#  [4.        ]]
# x_stack - newWeights:[[-7.46516377809169]
#  [-4.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.74628028]
#  [-4.        ]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[4.7188835]
#  [0.       ]]
# x_stack - newWeights:[[1.2811165008459735]
#  [6.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.2811165 ]
#  [2.20727665]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[6.        ]
#  [2.20727665]]
# x_stack - newWeights:[[-6.0]
#  [-2.207276647028654]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.20727665]
#  [-2.20727665]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[3.79272335]
#  [0.        ]]
# x_stack - newWeights:[[0.207276647028654]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.20727665]
#  [1.47151776]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[-4.0]
#  [-1.4715177646857693]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.47151776]
#  [-1.47151776]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[2.52848224]
#  [0.        ]]
# x_stack - newWeights:[[3.4715177646857693]
#  [6.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[3.47151776]
#  [2.20727665]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[6.        ]
#  [2.20727665]]
# x_stack - newWeights:[[-6.0]
#  [-2.207276647028654]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.20727665]
#  [-2.20727665]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.79272335]
#  [0.        ]]
# x_stack - newWeights:[[-3.792723352971346]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.39526495]
#  [ 0.        ]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[2.39745841]
#  [0.        ]]
# x_stack - newWeights:[[0.602541594637632]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.60254159]
#  [1.10363832]]
# [8]
# x_stack[[8]
#  [8]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[5.0]
#  [6.896361676485673]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.        ]
#  [2.53702968]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[8.      ]
#  [3.640668]]
# x_stack - newWeights:[[-2.0]
#  [2.3593319968239723]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-2.        ]
#  [ 0.86794974]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[6.        ]
#  [4.50861774]]
# x_stack - newWeights:[[-5.0]
#  [-3.5086177397055334]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.83939721]
#  [-3.50861774]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[4.16060279]
#  [1.        ]]
# x_stack - newWeights:[[1.8393972058572121]
#  [5.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.83939721]
#  [1.83939721]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[6.        ]
#  [2.83939721]]
# x_stack - newWeights:[[-6.0]
#  [-2.8393972058572117]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.20727665]
#  [-2.83939721]]
# [16]
# x_stack[[16]
#  [16]]
# x:[16]
# x_stack:[[16]
#  [16]]
# newWeights:[[3.79272335]
#  [0.        ]]
# x_stack - newWeights:[[12.207276647028653]
#  [16.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[12.20727665]
#  [ 5.88607106]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[16.        ]
#  [ 5.88607106]]
# x_stack - newWeights:[[-16.0]
#  [-5.886071058743077]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-5.88607106]
#  [-5.88607106]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[10.11392894]
#  [ 0.        ]]
# x_stack - newWeights:[[-9.113928941256923]
#  [1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.35282709]
#  [ 1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[6.76110186]
#  [1.        ]]
# x_stack - newWeights:[[-6.761101855471091]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.48727037]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.27383148]
#  [0.        ]]
# x_stack - newWeights:[[-4.273831483177185]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.57225474]
#  [ 0.        ]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[2.70157675]
#  [0.        ]]
# x_stack - newWeights:[[1.2984232545149546]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.29842325]
#  [1.47151776]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[-2.0]
#  [0.5284822353142307]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [ 0.52848224]]
# [12]
# x_stack[[12]
#  [12]]
# x:[12]
# x_stack:[[12]
#  [12]]
# newWeights:[[3.26424112]
#  [2.        ]]
# x_stack - newWeights:[[8.735758882342886]
#  [10.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[8.73575888]
#  [3.67879441]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[12.        ]
#  [ 5.67879441]]
# x_stack - newWeights:[[-9.0]
#  [-2.6787944117144233]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.31091497]
#  [-2.67879441]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[8.68908503]
#  [3.        ]]
# x_stack - newWeights:[[-8.689085029457019]
#  [-3.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-3.19653574]
#  [-3.        ]]
# [7]
# x_stack[[7]
#  [7]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[5.49254928]
#  [0.        ]]
# x_stack - newWeights:[[1.5074507154707746]
#  [7.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.50745072]
#  [2.57515609]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[7.        ]
#  [2.57515609]]
# x_stack - newWeights:[[-3.0]
#  [1.4248439117999037]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [ 1.42484391]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[5.89636168]
#  [4.        ]]
# x_stack - newWeights:[[-2.8963616764856734]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.06551191]
#  [-1.        ]]
# [5]
# x_stack[[5]
#  [5]]
# x:[5]
# x_stack:[[5]
#  [5]]
# newWeights:[[4.83084976]
#  [3.        ]]
# x_stack - newWeights:[[0.1691502384902579]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.16915024]
#  [0.73575888]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[5.        ]
#  [3.73575888]]
# x_stack - newWeights:[[-2.0]
#  [-0.7357588823428847]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [-0.73575888]]
# [5]
# x_stack[[5]
#  [5]]
# x:[5]
# x_stack:[[5]
#  [5]]
# newWeights:[[4.26424112]
#  [3.        ]]
# x_stack - newWeights:[[0.7357588823428847]
#  [2.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[0.73575888]
#  [0.73575888]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[5.        ]
#  [3.73575888]]
# x_stack - newWeights:[[-1.0]
#  [0.26424111765711533]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.36787944]
#  [ 0.26424112]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.63212056]
#  [4.        ]]
# x_stack - newWeights:[[-4.632120558828557]
#  [-4.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.70406192]
#  [-4.        ]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[2.92805864]
#  [0.        ]]
# x_stack - newWeights:[[1.0719413637920416]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.07194136]
#  [1.47151776]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[-2.0]
#  [0.5284822353142307]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [ 0.52848224]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[3.26424112]
#  [2.        ]]
# x_stack - newWeights:[[-0.26424111765711533]
#  [1.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[-0.26424112]
#  [ 0.36787944]]
# [8]
# x_stack[[8]
#  [8]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[3.        ]
#  [2.36787944]]
# x_stack - newWeights:[[5.0]
#  [5.632120558828557]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.        ]
#  [2.07194136]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[8.       ]
#  [4.4398208]]
# x_stack - newWeights:[[-8.0]
#  [-4.4398208049634835]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-2.94303553]
#  [-4.4398208 ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[5.05696447]
#  [0.        ]]
# x_stack - newWeights:[[-5.056964470628461]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.86035326]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.19661121]
#  [0.        ]]
# x_stack - newWeights:[[-3.1966112071498243]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.17596754]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.02064366]
#  [0.        ]]
# x_stack - newWeights:[[-2.0206436626211772]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.74335326]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.2772904]
#  [0.       ]]
# x_stack - newWeights:[[-1.2772904012094821]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.46988888]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.80740152]
#  [0.        ]]
# x_stack - newWeights:[[-0.8074015221988904]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.29702642]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.5103751]
#  [0.       ]]
# x_stack - newWeights:[[-0.5103751014113906]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.18775651]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.32261859]
#  [0.        ]]
# x_stack - newWeights:[[-0.32261859431635004]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.11868475]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.20393385]
#  [0.        ]]
# x_stack - newWeights:[[-0.2039338461277349]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.07502307]
#  [ 0.        ]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[0.12891078]
#  [0.        ]]
# x_stack - newWeights:[[3.871089223221679]
#  [4.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[3.87108922]
#  [1.47151776]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[4.        ]
#  [1.47151776]]
# x_stack - newWeights:[[-4.0]
#  [-1.4715177646857693]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.47151776]
#  [-1.47151776]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.52848224]
#  [0.        ]]
# x_stack - newWeights:[[-2.5284822353142307]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.93017663]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.58798377]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.01032183]
#  [0.        ]]
# x_stack - newWeights:[[-1.0103218313105886]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.37167663]
#  [ 0.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[0.6386452]
#  [0.       ]]
# x_stack - newWeights:[[-0.6386452006047411]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.23494444]
#  [ 0.        ]]
# [6]
# x_stack[[6]
#  [6]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[0.40370076]
#  [0.        ]]
# x_stack - newWeights:[[5.596299238900555]
#  [6.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[5.59629924]
#  [2.20727665]]
# [4]
# x_stack[[4]
#  [4]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[6.        ]
#  [2.20727665]]
# x_stack - newWeights:[[-2.0]
#  [1.792723352971346]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73575888]
#  [ 1.79272335]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[5.26424112]
#  [4.        ]]
# x_stack - newWeights:[[-2.2642411176571153]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.83296776]
#  [-1.        ]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[4.43127336]
#  [3.        ]]
# x_stack - newWeights:[[-3.4312733606160135]
#  [-2.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.26229493]
#  [-2.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[3.16897843]
#  [1.        ]]
# x_stack - newWeights:[[-3.168978434206138]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.16580202]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.00317642]
#  [0.        ]]
# x_stack - newWeights:[[-2.0031764187460315]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.73692742]
#  [ 0.        ]]
# [3]
# x_stack[[3]
#  [3]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.266249]
#  [0.      ]]
# x_stack - newWeights:[[1.7337510027500698]
#  [3.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[1.733751  ]
#  [1.10363832]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[3.        ]
#  [1.10363832]]
# x_stack - newWeights:[[-1.0]
#  [0.896361676485673]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.36787944]
#  [ 0.89636168]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.63212056]
#  [2.        ]]
# x_stack - newWeights:[[-2.6321205588285577]
#  [-2.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.96830304]
#  [-2.        ]]
# [5]
# x_stack[[5]
#  [5]]
# x:[5]
# x_stack:[[5]
#  [5]]
# newWeights:[[1.66381752]
#  [0.        ]]
# x_stack - newWeights:[[3.3361824814491565]
#  [5.0]]
# local_step:[1.         0.36787944]
# local_multiplier:[[1.        ]
#  [0.36787944]]
# delta:[[3.33618248]
#  [1.83939721]]
# [2]
# x_stack[[2]
#  [2]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[5.        ]
#  [1.83939721]]
# x_stack - newWeights:[[-3.0]
#  [0.16060279414278833]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.10363832]
#  [ 0.16060279]]
# [1]
# x_stack[[1]
#  [1]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[3.89636168]
#  [2.        ]]
# x_stack - newWeights:[[-2.896361676485673]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.06551191]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[2.83084976]
#  [1.        ]]
# x_stack - newWeights:[[-2.8308497615097417]
#  [-1.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-1.04141143]
#  [-1.        ]]
# [0]
# x_stack[[0]
#  [0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.78943833]
#  [0.        ]]
# x_stack - newWeights:[[-1.789438333205227]
#  [0.0]]
# local_step:[0.36787944 1.        ]
# local_multiplier:[[0.36787944]
#  [1.        ]]
# delta:[[-0.65829757]
#  [ 0.        ]]
# [14]
# x_stack[[14]
#  [14]]
# x:[14]
# x_stack:[[14]
#  [14]]
# ...
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[4.401694396425087]
#  [6.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# x:[15]
# x_stack:[[15]
#  [15]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[13.401694396425087]
#  [15.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[5.401694396425087]
#  [7.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[4.401694396425087]
#  [6.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[6.401694396425087]
#  [8.0]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[4.401694396425087]
#  [6.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[5.401694396425087]
#  [7.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[5.401694396425087]
#  [7.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[5]
# x_stack:[[5]
#  [5]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[3.401694396425088]
#  [5.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[6.401694396425087]
#  [8.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[6]
# x_stack:[[6]
#  [6]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[4.401694396425087]
#  [6.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[5.401694396425087]
#  [7.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[9]
# x_stack:[[9]
#  [9]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[7.401694396425087]
#  [9.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[10]
# x_stack:[[10]
#  [10]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[8.401694396425087]
#  [10.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[8]
# x_stack:[[8]
#  [8]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[6.401694396425087]
#  [8.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[5]
# x_stack:[[5]
#  [5]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[3.401694396425088]
#  [5.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[1]
# x_stack:[[1]
#  [1]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-0.5983056035749121]
#  [1.0]]
# x:[4]
# x_stack:[[4]
#  [4]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[2.401694396425088]
#  [4.0]]
# x:[2]
# x_stack:[[2]
#  [2]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[0.40169439642508786]
#  [2.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[5.401694396425087]
#  [7.0]]
# x:[7]
# x_stack:[[7]
#  [7]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[5.401694396425087]
#  [7.0]]
# x:[0]
# x_stack:[[0]
#  [0]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[-1.5983056035749121]
#  [0.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# x:[3]
# x_stack:[[3]
#  [3]]
# newWeights:[[1.5983056]
#  [0.       ]]
# x_stack - newWeights:[[1.4016943964250879]
#  [3.0]]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-9d6a82af176c> in <module>
# ----> 1 som1.fit(data_train)
#
# D:\cygwin64\home\fooli\SOM\newSom.py in fit(self, X, weightIndex, epochs, shuffle)
#     221         if(weightIndex == 0):
#     222             self.weights1 = copy.deepcopy(self.weights)
# --> 223             mlab.surf(self.weights1)
#     224             mlab.show()
#     225             print("generate weight1:\n {}".format(self.weights1))
#
# D:\ProgramFiles\lib\site-packages\mayavi\tools\helper_functions.py in the_function(*args, **kwargs)
#      36
#      37     def the_function(*args, **kwargs):
# ---> 38         return pipeline(*args, **kwargs)
#      39
#      40     if hasattr(pipeline, 'doc'):
#
# D:\ProgramFiles\lib\site-packages\mayavi\tools\helper_functions.py in __call__(self, *args, **kwargs)
#      81             scene.disable_render = True
#      82         # Then call the real logic
# ---> 83         output = self.__call_internal__(*args, **kwargs)
#      84         # And re-enable the rendering, if needed.
#      85         if scene is not None:
#
# D:\ProgramFiles\lib\site-packages\mayavi\tools\helper_functions.py in __call_internal__(self, *args, **kwargs)
#     710                 xi, xf, yi, yf, _, _ = self.source.image_data.bounds
#     711                 zi, zf = self.source.image_data.scalar_range
# --> 712             aspect_ratios = [(zf - zi) / (xf - xi), (zf - zi) / (yf - yi)]
#     713             if min(aspect_ratios) < 0.01 or max(aspect_ratios) > 100:
#     714                 print('Warning: the range of your scalar values differs by ' \
#
# ZeroDivisionError: float division by zero

# %%
predictions1_w1 = som1.predict(data_train,som1.weights1)
# Out:
# weights used:
#
# [6.09199190e-08 1.67529777e-07 0.00000000e+00 0.00000000e+00
#  4.00000061e+00 1.07000031e+02 4.12018774e-10 5.00000000e-02
#  0.00000000e+00 5.99999991e-01 2.99999997e+00 1.99999998e+00
#  2.99999997e+00 1.29999998e+01 0.00000000e+00]
# predicted label:
#  [15 15  0 ... 15 15 11]

# %%
NormalizeLables(label_train,predictions1_w1)
# Out:
# normalized predicted nLabel:
#  [1 1 0 ... 1 1 1]

# %%
purity_score(label_train,nLabel)
# Out:
# 0.8352

# %%
global noisy_list
noisy_list = getNoisyClusters(groupClusterList(2,label_train),groupClusterList(2,nLabel))
reduced_indices = reduce_noisy_data(noisy_list,0.1)
reduce_data_byindice(reduced_indices,data_train)
reduce_data_byindice(reduced_indices,label_train,1)
# Out:
# noisy data:

# %%
som1.fit(data_train_subset,weightIndex =1)
# Out:
# generate weight2:
#  [1.29320341e+00 7.61249965e+01 7.10222973e-02 3.55427042e+00
#  2.42463730e+01 8.33853972e+02 1.11796334e-02 4.10507765e-02
#  2.62480752e+00 2.36557765e-03 2.88220061e+00 2.04288808e+00
#  2.42665001e+00 1.92505096e+00 2.44439154e-02]

# %%
predictions2_W2 = som1.predict(data_train_subset,som1.weights2)
NormalizeLables(data_train_sublabel,predictions2_W2,1)
purity_score(data_train_sublabel,nsubLabel)
# Out:
# weights used:
#
# [1.29320341e+00 7.61249965e+01 7.10222973e-02 3.55427042e+00
#  2.42463730e+01 8.33853972e+02 1.11796334e-02 4.10507765e-02
#  2.62480752e+00 2.36557765e-03 2.88220061e+00 2.04288808e+00
#  2.42665001e+00 1.92505096e+00 2.44439154e-02]
# predicted label:
#  [ 3  6 12 ...  2  3  1]
# normalized predicted nsubLabel:
# [0 0 1 ... 0 0 0]
# 0.8386161176714315

# %%
predictions_test_W1 = som1.predict(data_test,som1.weights1)
NormalizeLables(label_test,predictions_test_W1,0)
purity_score(label_test,nLabel)
# Out:
# weights used:
#
# [6.09199190e-08 1.67529777e-07 0.00000000e+00 0.00000000e+00
#  4.00000061e+00 1.07000031e+02 4.12018774e-10 5.00000000e-02
#  0.00000000e+00 5.99999991e-01 2.99999997e+00 1.99999998e+00
#  2.99999997e+00 1.29999998e+01 0.00000000e+00]
# predicted label:
#  [ 0  6 15 ...  4  9  0]
# normalized predicted nLabel:
#  [0 0 1 ... 0 1 0]
# 0.8466

# %%
predictions_test_W2 = som1.predict(data_test,som1.weights2)
NormalizeLables(label_test,predictions_test_W2,0)
purity_score(label_test,nLabel)
# Out:
# weights used:
#
# [1.29320341e+00 7.61249965e+01 7.10222973e-02 3.55427042e+00
#  2.42463730e+01 8.33853972e+02 1.11796334e-02 4.10507765e-02
#  2.62480752e+00 2.36557765e-03 2.88220061e+00 2.04288808e+00
#  2.42665001e+00 1.92505096e+00 2.44439154e-02]
# predicted label:
#  [12 10  3 ... 12  4 12]
# normalized predicted nLabel:
#  [1 1 0 ... 1 0 1]
# 0.8466
