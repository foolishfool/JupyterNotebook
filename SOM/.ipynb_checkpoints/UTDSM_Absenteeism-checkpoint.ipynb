# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Absenteeism/Absenteeism_at_work.csv")
csv = csv.drop(columns=['ID', 'Seasons','Disciplinary failure','Education','Absenteeism time in hours'])
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Reason for absence")

# %%
import experiment
unstable_repeat_num= 30
scope_num = 58
class_num = 28
row = 5
column = 4
dim_num = 15
best_num = 43
elbow_num = 1

total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )   

experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# neuron unit number: 28
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 22>()
#      17 #som = newSom.SOM(m= class_num, n=  1, dim=dim_num)
#      18 #optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#      19 #optimize_W.run( )
#      21 experiment = experiment.Experiment()
# ---> 22 experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
#      23 print("*****************************************************************************************")
#      24 print("Best Number SOM Comparision")
#
# File C:\JupyterDoc\SOM\experiment.py:335, in Experiment.UTtest(self, dataread, label_train, class_num, dim_num, best_num, scope_num, unstable_repeat_num, type, elbow_num, row, column)
#     332  som = newSom.SOM(m= y , n= 1, dim=dim_num)
#     333 optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,elbow_num,row,column)
# --> 335 optimize_W.run()
#     336 all_train_score_W0_n.append(optimize_W.all_train_score_W0_n)
#     337 all_train_score_W_combine_n.append(optimize_W.all_train_score_W_Combined_n)
#
# File C:\JupyterDoc\SOM\UTDSM.py:544, in UTDSM_SOM.run(self)
#     537 # true distributon
#     538 """
#     539 self.cluster_data_based_true_label()
#     540 print("True Distribution : ")
#     541 for i in range(0,len(self.all_true_clustered_datas_indexes)) :
#     542     self.drawnormaldistributonplot(self.all_true_clustered_datas_indexes[i],i,"green")
#     543 """
# --> 544 self.som.fit(self.data_train)
#     545 weight0 = self.som.weights0
#     547 # the new cluster data generated by finding community nodes
#
# File C:\JupyterDoc\SOM\newSom.py:224, in SOM.fit(self, X, weightIndex, epochs, shuffle)
#     220 input = X[idx]
#     221 #if (type(input) is np.float64):
#     222 #    input = [input]
#     223 # Do one step of training
# --> 224 self.step(input)
#     225 # Update learning rate
#     226 global_iter_counter += 1
#
# File C:\JupyterDoc\SOM\newSom.py:124, in SOM.step(self, x)
#     118 x_stack = np.stack([x]*(self.m*self.n), axis=0)
#     119 #print("x_stack {}".format(x_stack))
#     120 #print("self.weights{}".format(self.weights));
#     121 #print("x_stack{}".format(x_stack));
#     122 # x_stack , with mxn row , each row has the same array: x
#     123 # Get index of best matching unit
# --> 124 bmu_index = self._find_bmu(x,self.weights)
#     125 #print("bmu_index{}".format(bmu_index));
#     126 # Find location of best matching unit, _locations is all the indices for a given matrix for array
#     127 # bmu_location is the bmu_indexth element in _locations, such as if bmu_index = 4 in [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1]] it return [2,0]
#     128 bmu_location = self._locations[bmu_index,:]
#
# File C:\JupyterDoc\SOM\newSom.py:101, in SOM._find_bmu(self, x, newWeights)
#      98 x_stack = np.stack([x]*(newWeights.shape[0]), axis=0)
#      99 # Calculate distance between x and each weight  ， it use the norm to represent the distance of the concept of vector x_stack - newWeights
# --> 101 distance = np.linalg.norm((x_stack - newWeights).astype(float), axis=1)
#     102 # Find index of best matching unit
#     103 return np.argmin(distance)
#
# ValueError: operands could not be broadcast together with shapes (196,16) (196,15)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 58
class_num = 28
dim_num = 20
best_num = 43

total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     


experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1)
# Out:
# neuron unit number: 28
# all_train_score_W0_n 0.42125759915254685
# all_train_score_W0_a 0.2750671457015894
# test_score_W0_n 0.41884111558921944
# test_score_W0_a  0.24157938047298338
# Split one time!
# self.rest_data_W0_n 0.42025737210666836
# self.rest_data_W0_a 0.27449121011916294
# all_train_score_W_Combined_n 0.42125759915254685
# all_train_score_W_Combined_a 0.2750671457015894
# test_score_W_combined_n 0.3773137235757569
# test_score_W_combined_a 0.1753389767710153
# Combine Neurons Number :131
# neuron unit number: 29
# all_train_score_W0_n 0.2205988984097866
# all_train_score_W0_a 0.11431957250998942
# test_score_W0_n 0.30717493233542464
# test_score_W0_a  0.12473020248383952
# Split one time!
# self.rest_data_W0_n 0.22336619841635869
# self.rest_data_W0_a 0.11398415176410304
# all_train_score_W_Combined_n 0.23209680972845886
# all_train_score_W_Combined_a 0.11542634702274712
# test_score_W_combined_n 0.3227736788193565
# test_score_W_combined_a 0.1327808252913013
# Combine Neurons Number :33
# neuron unit number: 30
# all_train_score_W0_n 0.42777317686220573
# all_train_score_W0_a 0.2863232260070532
# test_score_W0_n 0.3844659653556496
# test_score_W0_a  0.1612241387275877
# Split one time!
# self.rest_data_W0_n 0.42986916054031865
# self.rest_data_W0_a 0.2869676883538735
# all_train_score_W_Combined_n 0.4295619916899044
# all_train_score_W_Combined_a 0.28806076697411737
# test_score_W_combined_n 0.4156138758375818
# test_score_W_combined_a 0.20713621151434897
# Combine Neurons Number :142
# neuron unit number: 31
# all_train_score_W0_n 0.24482986505772866
# all_train_score_W0_a 0.10077316004674429
# test_score_W0_n 0.3146831119060323
# test_score_W0_a  0.11056027461171199
# Split one time!
# self.rest_data_W0_n 0.24771064826989772
# self.rest_data_W0_a 0.09670128148980818
# Split one time!
# self.rest_data_W0_n 0.8804214400982826
# self.rest_data_W0_a 0.7407407407407407
# all_train_score_W_Combined_n 0.2579595098513674
# all_train_score_W_Combined_a 0.104390380591962
# test_score_W_combined_n 0.3240371922243853
# test_score_W_combined_a 0.11125495928835817
# Combine Neurons Number :37
# neuron unit number: 32
# all_train_score_W0_n 0.4529883782006565
# all_train_score_W0_a 0.2922379963920194
# test_score_W0_n 0.3756562594670701
# test_score_W0_a  0.14813751354113383
# Split one time!
# self.rest_data_W0_n 0.4555398715859496
# self.rest_data_W0_a 0.2945415207109662
# all_train_score_W_Combined_n 0.4550805185719194
# all_train_score_W_Combined_a 0.29436440748682613
# test_score_W_combined_n 0.4056047051225245
# test_score_W_combined_a 0.1538623868488235
# Combine Neurons Number :158
# neuron unit number: 33
# all_train_score_W0_n 0.21985827698190022
# all_train_score_W0_a 0.09732507397571491
# test_score_W0_n 0.33532800981484084
# test_score_W0_a  0.10875484993407648
# Split one time!
# self.rest_data_W0_n 0.2216536238939815
# self.rest_data_W0_a 0.09598406870871763
# all_train_score_W_Combined_n 0.22649771348788067
# all_train_score_W_Combined_a 0.09846338353915383
# test_score_W_combined_n 0.3043616350453113
# test_score_W_combined_a 0.10909484545611128
# Combine Neurons Number :34
# neuron unit number: 34
# all_train_score_W0_n 0.44782758048026655
# all_train_score_W0_a 0.3147547930277194
# test_score_W0_n 0.4294266916857882
# test_score_W0_a  0.19218818572525184
# Split one time!
# self.rest_data_W0_n 0.4468434167899464
# self.rest_data_W0_a 0.3142483765388216
# all_train_score_W_Combined_n 0.44782758048026655
# all_train_score_W_Combined_a 0.3147547930277194
# test_score_W_combined_n 0.39970596278318865
# test_score_W_combined_a 0.19213313110890204
# Combine Neurons Number :158
# neuron unit number: 35
# all_train_score_W0_n 0.2363820480650531
# all_train_score_W0_a 0.09266631126054323
# test_score_W0_n 0.328667289619361
# test_score_W0_a  0.1334180419308835
# Split one time!
# self.rest_data_W0_n 0.22886589854731254
# self.rest_data_W0_a 0.09042490351273114
# all_train_score_W_Combined_n 0.23098290404689206
# all_train_score_W_Combined_a 0.0925986855850018
# test_score_W_combined_n 0.32298631554324
# test_score_W_combined_a 0.11882488051103807
# Combine Neurons Number :36
# neuron unit number: 36
# all_train_score_W0_n 0.4871572173072582
# all_train_score_W0_a 0.3281904318260425
# test_score_W0_n 0.38384800377751094
# test_score_W0_a  0.1210892524179253
# Split one time!
# self.rest_data_W0_n 0.48677819918848825
# self.rest_data_W0_a 0.32958934553326147
# all_train_score_W_Combined_n 0.4871572173072582
# all_train_score_W_Combined_a 0.3281904318260425
# test_score_W_combined_n 0.38818085077247644
# test_score_W_combined_a 0.13627213213749415
# Combine Neurons Number :175
# neuron unit number: 37
# all_train_score_W0_n 0.252796512561339
# all_train_score_W0_a 0.13610201434518263
# test_score_W0_n 0.36099297492252824
# test_score_W0_a  0.1837595110708917
# Split one time!
# self.rest_data_W0_n 0.2513218239414384
# self.rest_data_W0_a 0.13460327374362036
# all_train_score_W_Combined_n 0.252796512561339
# all_train_score_W_Combined_a 0.13610201434518263
# test_score_W_combined_n 0.3304311443646703
# test_score_W_combined_a 0.15775354008785158
# Combine Neurons Number :36
# neuron unit number: 38
# all_train_score_W0_n 0.4540203144304261
# all_train_score_W0_a 0.3098495236244906
# test_score_W0_n 0.42105939186223335
# test_score_W0_a  0.19528094673801505
# Split one time!
# self.rest_data_W0_n 0.45715879289312755
# self.rest_data_W0_a 0.31113982048729416
# all_train_score_W_Combined_n 0.4570470474220892
# all_train_score_W_Combined_a 0.31131249512051734
# test_score_W_combined_n 0.42432499171232685
# test_score_W_combined_a 0.20538144821884602
# Combine Neurons Number :176
# neuron unit number: 39
# all_train_score_W0_n 0.23745225696833847
# all_train_score_W0_a 0.11125970823583115
# test_score_W0_n 0.32985913655209337
# test_score_W0_a  0.16172756331183566
# Split one time!
# self.rest_data_W0_n 0.24633232708728264
# self.rest_data_W0_a 0.1122471101019996
# all_train_score_W_Combined_n 0.2519463757706445
# all_train_score_W_Combined_a 0.11544985931820477
# test_score_W_combined_n 0.322835485099427
# test_score_W_combined_a 0.1467311075302307
# Combine Neurons Number :42
# neuron unit number: 40
# all_train_score_W0_n 0.46276751476352673
# all_train_score_W0_a 0.31509478875807134
# test_score_W0_n 0.42229475944873696
# test_score_W0_a  0.19671006104941177
# Split one time!
# self.rest_data_W0_n 0.4637500314494637
# self.rest_data_W0_a 0.3139287706117577
# all_train_score_W_Combined_n 0.46375804499398693
# all_train_score_W_Combined_a 0.3141585195640218
# test_score_W_combined_n 0.4021704382482907
# test_score_W_combined_a 0.18697559787042753
# Combine Neurons Number :167
# neuron unit number: 41
# all_train_score_W0_n 0.2686213907795194
# all_train_score_W0_a 0.1420684732337094
# test_score_W0_n 0.3417765601959173
# test_score_W0_a  0.12431232758978353
# Split one time!
# self.rest_data_W0_n 0.2684242723817954
# self.rest_data_W0_a 0.14313158442999319
# Split one time!
# y_true [18, 28] y_pred [18 18]
# self.rest_data_W0_n 0.0
# self.rest_data_W0_a 0.0
# all_train_score_W_Combined_n 0.2686213907795194
# all_train_score_W_Combined_a 0.1420684732337094
# test_score_W_combined_n 0.33193134171019945
# test_score_W_combined_a 0.12323572640410264
# Combine Neurons Number :42
# neuron unit number: 42
# all_train_score_W0_n 0.5078689244900602
# all_train_score_W0_a 0.3382520172870261
# test_score_W0_n 0.37878177934946805
# test_score_W0_a  0.142096047202389
# Split one time!
# self.rest_data_W0_n 0.5058425607144985
# self.rest_data_W0_a 0.3349099722417572
# all_train_score_W_Combined_n 0.5078689244900602
# all_train_score_W_Combined_a 0.3382520172870261
# test_score_W_combined_n 0.3959490828749251
# test_score_W_combined_a 0.1467802954475562
# Combine Neurons Number :186
# neuron unit number: 43
# all_train_score_W0_n 0.2786858336651799
# all_train_score_W0_a 0.12644145922425307
# test_score_W0_n 0.3707990135392868
# test_score_W0_a  0.16266345128038728
# Split one time!
# self.rest_data_W0_n 0.2831448927634548
# self.rest_data_W0_a 0.13004564131955085
# Split one time!
# self.rest_data_W0_n 0.823529411764706
# self.rest_data_W0_a 0.375
# all_train_score_W_Combined_n 0.2911920813306555
# all_train_score_W_Combined_a 0.13344425128696594
# test_score_W_combined_n 0.36736532599170013
# test_score_W_combined_a 0.15268653906251126
# Combine Neurons Number :51
# neuron unit number: 44
# all_train_score_W0_n 0.50074097008564
# all_train_score_W0_a 0.332530982797799
# test_score_W0_n 0.42005534957614055
# test_score_W0_a  0.17416363855131084
# Split one time!
# self.rest_data_W0_n 0.5015879791580508
# self.rest_data_W0_a 0.3346706688700879
# all_train_score_W_Combined_n 0.5023517695001773
# all_train_score_W_Combined_a 0.33530156539675704
# test_score_W_combined_n 0.422116590504843
# test_score_W_combined_a 0.1687120457546951
# Combine Neurons Number :195
# neuron unit number: 45
# all_train_score_W0_n 0.2535676778557235
# all_train_score_W0_a 0.12456617898689258
# test_score_W0_n 0.3336741690114649
# test_score_W0_a  0.14364732153029372
# Split one time!
# self.rest_data_W0_n 0.25259727374770913
# self.rest_data_W0_a 0.12425755450429656
# all_train_score_W_Combined_n 0.25472049284617915
# all_train_score_W_Combined_a 0.12458438800759919
# test_score_W_combined_n 0.3073203089797735
# test_score_W_combined_a 0.1276237508447016
# Combine Neurons Number :46
# neuron unit number: 46
# all_train_score_W0_n 0.49567321274382753
# all_train_score_W0_a 0.34690392094522243
# test_score_W0_n 0.3890543730789133
# test_score_W0_a  0.1359557245737151
# Split one time!
# self.rest_data_W0_n 0.4954782958607484
# self.rest_data_W0_a 0.34541579213192647
# all_train_score_W_Combined_n 0.49567321274382753
# all_train_score_W_Combined_a 0.34690392094522243
# test_score_W_combined_n 0.3915970992932913
# test_score_W_combined_a 0.1725000723776763
# Combine Neurons Number :189
# neuron unit number: 47
# all_train_score_W0_n 0.2540778418474496
# all_train_score_W0_a 0.10654843509025717
# test_score_W0_n 0.3711738864156422
# test_score_W0_a  0.12789049243638315
# Split one time!
# self.rest_data_W0_n 0.25685466234679827
# self.rest_data_W0_a 0.10523311952250636
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2609040470626896
# all_train_score_W_Combined_a 0.10977212685484879
# test_score_W_combined_n 0.3351447624326223
# test_score_W_combined_a 0.11189116497717906
# Combine Neurons Number :51
# neuron unit number: 48
# all_train_score_W0_n 0.4980655401870813
# all_train_score_W0_a 0.3464095486546484
# test_score_W0_n 0.4117788017411364
# test_score_W0_a  0.1937253188603451
# Split one time!
# self.rest_data_W0_n 0.4990707834635399
# self.rest_data_W0_a 0.34707717257303616
# all_train_score_W_Combined_n 0.49985632600548324
# all_train_score_W_Combined_a 0.3475619719135893
# test_score_W_combined_n 0.4108078844329132
# test_score_W_combined_a 0.19627926593729225
# Combine Neurons Number :180
# neuron unit number: 49
# all_train_score_W0_n 0.2913673278973274
# all_train_score_W0_a 0.16718610189931413
# test_score_W0_n 0.37530205870517536
# test_score_W0_a  0.1996156125623988
# Split one time!
# self.rest_data_W0_n 0.288966408090556
# self.rest_data_W0_a 0.1623360713357582
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.29182523134432725
# all_train_score_W_Combined_a 0.16363616063446337
# test_score_W_combined_n 0.3589980189655938
# test_score_W_combined_a 0.1837584209686884
# Combine Neurons Number :51
# neuron unit number: 50
# all_train_score_W0_n 0.5348061150223944
# all_train_score_W0_a 0.3957187234150009
# test_score_W0_n 0.41605396068377243
# test_score_W0_a  0.15467202303885386
# Split one time!
# self.rest_data_W0_n 0.5341227401710748
# self.rest_data_W0_a 0.3948992479011041
# all_train_score_W_Combined_n 0.5348061150223944
# all_train_score_W_Combined_a 0.3957187234150009
# test_score_W_combined_n 0.42396986780140833
# test_score_W_combined_a 0.1940633406522368
# Combine Neurons Number :200
# neuron unit number: 51
# all_train_score_W0_n 0.3005194379865616
# all_train_score_W0_a 0.16463520639572776
# test_score_W0_n 0.39370919494980716
# test_score_W0_a  0.1870735592587416
# Split one time!
# self.rest_data_W0_n 0.3016467199159625
# self.rest_data_W0_a 0.16426684232627098
# all_train_score_W_Combined_n 0.30505943876271074
# all_train_score_W_Combined_a 0.16480886355516725
# test_score_W_combined_n 0.3774025925280909
# test_score_W_combined_a 0.17889647412952533
# Combine Neurons Number :52
# neuron unit number: 52
# all_train_score_W0_n 0.5108057509028495
# all_train_score_W0_a 0.34163609276964546
# test_score_W0_n 0.3847169229291361
# test_score_W0_a  0.15159151881302294
# Split one time!
# self.rest_data_W0_n 0.5102919561533051
# self.rest_data_W0_a 0.3410711091831855
# all_train_score_W_Combined_n 0.5108057509028495
# all_train_score_W_Combined_a 0.34163609276964546
# test_score_W_combined_n 0.38409943624050014
# test_score_W_combined_a 0.14476861003304248
# Combine Neurons Number :203
# neuron unit number: 53
# all_train_score_W0_n 0.2931059418665815
# all_train_score_W0_a 0.14676891576779866
# test_score_W0_n 0.35819753049219083
# test_score_W0_a  0.15873494267115631
# Split one time!
# self.rest_data_W0_n 0.29287730641292015
# self.rest_data_W0_a 0.1483373741198716
# all_train_score_W_Combined_n 0.29644693121135807
# all_train_score_W_Combined_a 0.14910068999389625
# test_score_W_combined_n 0.34703982357620994
# test_score_W_combined_a 0.13728625555291388
# Combine Neurons Number :56
# neuron unit number: 54
# all_train_score_W0_n 0.5092359637643484
# all_train_score_W0_a 0.3605974077296762
# test_score_W0_n 0.39821530448355225
# test_score_W0_a  0.16577950351141038
# Split one time!
# self.rest_data_W0_n 0.5095771238756158
# self.rest_data_W0_a 0.3624411191952465
# all_train_score_W_Combined_n 0.5092359637643484
# all_train_score_W_Combined_a 0.3605974077296762
# test_score_W_combined_n 0.42722115827088647
# test_score_W_combined_a 0.2259276665805034
# Combine Neurons Number :204
# neuron unit number: 55
# all_train_score_W0_n 0.25552135922764185
# all_train_score_W0_a 0.11919905962654123
# test_score_W0_n 0.3258491522504919
# test_score_W0_a  0.11470592276555792
# Split one time!
# self.rest_data_W0_n 0.25459304575944713
# self.rest_data_W0_a 0.11839520834094526
# Split one time!
# y_true [12, 19] y_pred [12 12]
# self.rest_data_W0_n 0.0
# self.rest_data_W0_a 0.0
# all_train_score_W_Combined_n 0.25867715551775233
# all_train_score_W_Combined_a 0.11935867750108203
# test_score_W_combined_n 0.3149670673303097
# test_score_W_combined_a 0.10186398866952007
# Combine Neurons Number :56
# neuron unit number: 56
# all_train_score_W0_n 0.5443987651650216
# all_train_score_W0_a 0.37985447550127643
# test_score_W0_n 0.39133967361961686
# test_score_W0_a  0.14617590722572865
# Split one time!
# self.rest_data_W0_n 0.5415955291956001
# self.rest_data_W0_a 0.37502780753752485
# all_train_score_W_Combined_n 0.5443987651650216
# all_train_score_W_Combined_a 0.37985447550127643
# test_score_W_combined_n 0.41278086243508916
# test_score_W_combined_a 0.1656296961981078
# Combine Neurons Number :217
# neuron unit number: 57
# all_train_score_W0_n 0.26949505150835096
# all_train_score_W0_a 0.14184614007582405
# test_score_W0_n 0.35563221322305716
# test_score_W0_a  0.14857894657668652
# Split one time!
# self.rest_data_W0_n 0.2702898141590447
# self.rest_data_W0_a 0.1449041152725405
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2757018466839598
# all_train_score_W_Combined_a 0.14567363812496242
# test_score_W_combined_n 0.3214282662372678
# test_score_W_combined_a 0.1120146393461541
# Combine Neurons Number :54
# neuron unit number: 58
# all_train_score_W0_n 0.5402725613362099
# all_train_score_W0_a 0.40792170221167146
# test_score_W0_n 0.3804123132603676
# test_score_W0_a  0.1559969620061812
# Split one time!
# self.rest_data_W0_n 0.5417154007131382
# self.rest_data_W0_a 0.4070092869153603
# all_train_score_W_Combined_n 0.5430153670556267
# all_train_score_W_Combined_a 0.40942271584373463
# test_score_W_combined_n 0.3941914726074751
# test_score_W_combined_a 0.1623518550158879
# Combine Neurons Number :220
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.374478  0.034676  0.006228   0.361759  0.387197
# 1  test_score_W'  31.0  0.369828  0.040933  0.007352   0.354814  0.384842
# 2       combined  62.0  0.372153  0.037694  0.004787   0.362581  0.381726
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0046
# 1                          Degrees of freedom =   60.0000
# 2                                           t =    0.4826
# 3                       Two side test p value =    0.6311
# 4                      Difference < 0 p value =    0.6844
# 5                      Difference > 0 p value =    0.3156
# 6                                   Cohen's d =    0.1226
# 7                                   Hedge's g =    0.1210
# 8                               Glass's delta =    0.1341
# 9                                 Pearson's r =    0.0622
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.374478  0.034676  0.006228   0.361759  0.387197
# 1  test_score_W'  31.0  0.156123  0.033358  0.005991   0.143887  0.168359
# 2       combined  62.0  0.265300  0.115125  0.014621   0.236064  0.294537
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.2184
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   25.2669
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    1.0000
# 5                      Difference > 0 p value =    0.0000
# 6                                   Cohen's d =    6.4178
# 7                                   Hedge's g =    6.3373
# 8                               Glass's delta =    6.2971
# 9                                 Pearson's r =    0.9561
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.27326522591193175
# all_train_score_W0_a 0.13686214943637304
# test_score_W0_n 0.3824841255995264
# test_score_W0_a  0.1815852365505223
# Split one time!
# self.rest_data_W0_n 0.27324117205715526
# self.rest_data_W0_a 0.1367228427122747
# all_train_score_W_Combined_n 0.27608011366602514
# all_train_score_W_Combined_a 0.13710624021944742
# test_score_W_combined_n 0.36073571613691024
# test_score_W_combined_a 0.16563058477463025
# Combine Neurons Number :44
# all_train_score_W0_n 0.23954744591852647
# all_train_score_W0_a 0.1309346328846438
# test_score_W0_n 0.3086964564761199
# test_score_W0_a  0.11702104196919118
# Split one time!
# self.rest_data_W0_n 0.24101338534561767
# self.rest_data_W0_a 0.13184863208294484
# all_train_score_W_Combined_n 0.24276538835009745
# all_train_score_W_Combined_a 0.13118518463734993
# test_score_W_combined_n 0.30393555289727053
# test_score_W_combined_a 0.10834842526560823
# Combine Neurons Number :44
# all_train_score_W0_n 0.28137773183107584
# all_train_score_W0_a 0.13899086218002168
# test_score_W0_n 0.32109505286354045
# test_score_W0_a  0.14349026869737602
# Split one time!
# self.rest_data_W0_n 0.27874450427476716
# self.rest_data_W0_a 0.13644645256461194
# all_train_score_W_Combined_n 0.28137773183107584
# all_train_score_W_Combined_a 0.13899086218002168
# test_score_W_combined_n 0.33966253512187533
# test_score_W_combined_a 0.14988519500062192
# Combine Neurons Number :44
# all_train_score_W0_n 0.26898199846129767
# all_train_score_W0_a 0.1388781260284854
# test_score_W0_n 0.3732503634703504
# test_score_W0_a  0.15532671589374697
# Split one time!
# self.rest_data_W0_n 0.26843962334924293
# self.rest_data_W0_a 0.1387824417298681
# all_train_score_W_Combined_n 0.26898199846129767
# all_train_score_W_Combined_a 0.1388781260284854
# test_score_W_combined_n 0.3311838637618608
# test_score_W_combined_a 0.13349178122478222
# Combine Neurons Number :43
# all_train_score_W0_n 0.28312603126737435
# all_train_score_W0_a 0.16067492707707473
# test_score_W0_n 0.3810282815288957
# test_score_W0_a  0.18985291071067542
# Split one time!
# self.rest_data_W0_n 0.2842974891560287
# self.rest_data_W0_a 0.16139610582918648
# all_train_score_W_Combined_n 0.2849173289082639
# all_train_score_W_Combined_a 0.16169959933510875
# test_score_W_combined_n 0.35828448772676774
# test_score_W_combined_a 0.1769742908106251
# Combine Neurons Number :44
# all_train_score_W0_n 0.27552176595784983
# all_train_score_W0_a 0.1462739801365714
# test_score_W0_n 0.3434350587816608
# test_score_W0_a  0.12893957419742003
# Split one time!
# self.rest_data_W0_n 0.27311530725751987
# self.rest_data_W0_a 0.14397003794053953
# all_train_score_W_Combined_n 0.27552176595784983
# all_train_score_W_Combined_a 0.1462739801365714
# test_score_W_combined_n 0.33476640579163924
# test_score_W_combined_a 0.13144526320294628
# Combine Neurons Number :42
# all_train_score_W0_n 0.2619953602645217
# all_train_score_W0_a 0.11474106226040581
# test_score_W0_n 0.34905431737960235
# test_score_W0_a  0.10832444564767794
# Split one time!
# self.rest_data_W0_n 0.26546719995094503
# self.rest_data_W0_a 0.11509008081310158
# all_train_score_W_Combined_n 0.26766369773120346
# all_train_score_W_Combined_a 0.11565603274560826
# test_score_W_combined_n 0.3338849885303416
# test_score_W_combined_a 0.11450793755911658
# Combine Neurons Number :45
# all_train_score_W0_n 0.27052286984152246
# all_train_score_W0_a 0.16280647684618568
# test_score_W0_n 0.34775561452637843
# test_score_W0_a  0.14655844263783363
# Split one time!
# self.rest_data_W0_n 0.2727721867857637
# self.rest_data_W0_a 0.1628406668216738
# all_train_score_W_Combined_n 0.2752523233197365
# all_train_score_W_Combined_a 0.1634846329708138
# test_score_W_combined_n 0.331829506097271
# test_score_W_combined_a 0.13133677905258553
# Combine Neurons Number :44
# all_train_score_W0_n 0.27726098490096723
# all_train_score_W0_a 0.10347029527131112
# test_score_W0_n 0.3355876228976858
# test_score_W0_a  0.12057757652997098
# Split one time!
# self.rest_data_W0_n 0.2818676542576326
# self.rest_data_W0_a 0.10617656631669824
# Split one time!
# self.rest_data_W0_n 0.5956958402349807
# self.rest_data_W0_a 0.24324324324324326
# all_train_score_W_Combined_n 0.28470690382663283
# all_train_score_W_Combined_a 0.10813333262467646
# test_score_W_combined_n 0.32518314746329297
# test_score_W_combined_a 0.1090442105062213
# Combine Neurons Number :48
# all_train_score_W0_n 0.2370193901325217
# all_train_score_W0_a 0.10598375472701772
# test_score_W0_n 0.3113323694013057
# test_score_W0_a  0.12820287064428565
# Split one time!
# self.rest_data_W0_n 0.2419053019628096
# self.rest_data_W0_a 0.10664875875969602
# Split one time!
# self.rest_data_W0_n 0.6538673467268862
# self.rest_data_W0_a 0.2709867452135493
# all_train_score_W_Combined_n 0.24806310094966874
# all_train_score_W_Combined_a 0.11019751390864524
# test_score_W_combined_n 0.27984642134990406
# test_score_W_combined_a 0.08446357586810481
# Combine Neurons Number :49
# all_train_score_W0_n 0.2458090787541876
# all_train_score_W0_a 0.12980130822806943
# test_score_W0_n 0.3381778203291163
# test_score_W0_a  0.12872996516098492
# Split one time!
# self.rest_data_W0_n 0.24658284808885925
# self.rest_data_W0_a 0.13049100044990355
# all_train_score_W_Combined_n 0.24814169924310525
# all_train_score_W_Combined_a 0.13138483792907518
# test_score_W_combined_n 0.32952354058883343
# test_score_W_combined_a 0.1266678355090444
# Combine Neurons Number :43
# all_train_score_W0_n 0.25712624073241225
# all_train_score_W0_a 0.1198930785228965
# test_score_W0_n 0.34192242642209497
# test_score_W0_a  0.12317106425813301
# Split one time!
# self.rest_data_W0_n 0.2591240087354067
# self.rest_data_W0_a 0.1209541411395011
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2655640855050158
# all_train_score_W_Combined_a 0.12500588004363383
# test_score_W_combined_n 0.33400647842252296
# test_score_W_combined_a 0.13313380189958474
# Combine Neurons Number :47
# all_train_score_W0_n 0.2508831194079718
# all_train_score_W0_a 0.12499956400513525
# test_score_W0_n 0.31813486319636763
# test_score_W0_a  0.10912534989653133
# Split one time!
# self.rest_data_W0_n 0.25440124421347826
# self.rest_data_W0_a 0.12598410731271026
# Split one time!
# self.rest_data_W0_n 0.7336804366512112
# self.rest_data_W0_a 0.0
# all_train_score_W_Combined_n 0.2575868809925526
# all_train_score_W_Combined_a 0.1274025581441427
# test_score_W_combined_n 0.33156372415721297
# test_score_W_combined_a 0.10325315897963264
# Combine Neurons Number :46
# all_train_score_W0_n 0.2591164931798961
# all_train_score_W0_a 0.11164044922205198
# test_score_W0_n 0.34244331985103266
# test_score_W0_a  0.13745168982392428
# Split one time!
# self.rest_data_W0_n 0.2618965450403714
# self.rest_data_W0_a 0.11173621317834617
# all_train_score_W_Combined_n 0.2659716925547367
# all_train_score_W_Combined_a 0.11522314071208133
# test_score_W_combined_n 0.3121106338123263
# test_score_W_combined_a 0.1264085158787906
# Combine Neurons Number :45
# all_train_score_W0_n 0.2691231478331182
# all_train_score_W0_a 0.12600432365883626
# test_score_W0_n 0.32264862746436374
# test_score_W0_a  0.1187746888038075
# Split one time!
# self.rest_data_W0_n 0.2685280345674162
# self.rest_data_W0_a 0.12548582043802461
# all_train_score_W_Combined_n 0.2752950036078628
# all_train_score_W_Combined_a 0.12724574054734675
# test_score_W_combined_n 0.32674507827502036
# test_score_W_combined_a 0.11496182801517305
# Combine Neurons Number :45
# all_train_score_W0_n 0.26369956340249795
# all_train_score_W0_a 0.13535299241954643
# test_score_W0_n 0.31876420367684477
# test_score_W0_a  0.11215355089120269
# Split one time!
# self.rest_data_W0_n 0.27048509913710006
# self.rest_data_W0_a 0.14185329780341288
# Split one time!
# self.rest_data_W0_n 0.6355290853592154
# self.rest_data_W0_a 0.4363048747643415
# all_train_score_W_Combined_n 0.27605223121392075
# all_train_score_W_Combined_a 0.15318456863975272
# test_score_W_combined_n 0.34771426269221073
# test_score_W_combined_a 0.14093106322360643
# Combine Neurons Number :47
# all_train_score_W0_n 0.2652489689322729
# all_train_score_W0_a 0.12007702143665001
# test_score_W0_n 0.3326674353143499
# test_score_W0_a  0.11819288308953668
# Split one time!
# self.rest_data_W0_n 0.26892328480590055
# self.rest_data_W0_a 0.12229510529384702
# Split one time!
# self.rest_data_W0_n 0.7336804366512112
# self.rest_data_W0_a 0.0
# all_train_score_W_Combined_n 0.27028675578515127
# all_train_score_W_Combined_a 0.1239740236053499
# test_score_W_combined_n 0.33541269446227423
# test_score_W_combined_a 0.10788814005934912
# Combine Neurons Number :45
# all_train_score_W0_n 0.2575456568471041
# all_train_score_W0_a 0.13550653425999643
# test_score_W0_n 0.30771729643157403
# test_score_W0_a  0.09705898262466989
# Split one time!
# self.rest_data_W0_n 0.2542364549994343
# self.rest_data_W0_a 0.13289518829394995
# all_train_score_W_Combined_n 0.2575456568471041
# all_train_score_W_Combined_a 0.13550653425999643
# test_score_W_combined_n 0.2989967699133779
# test_score_W_combined_a 0.08837627887550188
# Combine Neurons Number :43
# all_train_score_W0_n 0.2530014911750248
# all_train_score_W0_a 0.1341402895833823
# test_score_W0_n 0.3332222553125593
# test_score_W0_a  0.12070544553018116
# Split one time!
# self.rest_data_W0_n 0.2519512016052604
# self.rest_data_W0_a 0.13283738112130267
# all_train_score_W_Combined_n 0.25598113069313366
# all_train_score_W_Combined_a 0.13683626125868542
# test_score_W_combined_n 0.325170096137431
# test_score_W_combined_a 0.13730547455188996
# Combine Neurons Number :46
# all_train_score_W0_n 0.2348664275711414
# all_train_score_W0_a 0.1292666987619984
# test_score_W0_n 0.33588006020517475
# test_score_W0_a  0.1260281569580117
# Split one time!
# self.rest_data_W0_n 0.23360042860757252
# self.rest_data_W0_a 0.12833899600746554
# all_train_score_W_Combined_n 0.2348664275711414
# all_train_score_W_Combined_a 0.1292666987619984
# test_score_W_combined_n 0.32054400263166416
# test_score_W_combined_a 0.13417192463752314
# Combine Neurons Number :44
# all_train_score_W0_n 0.29133924359334984
# all_train_score_W0_a 0.1436050510278705
# test_score_W0_n 0.3802126130012518
# test_score_W0_a  0.14725158773918648
# Split one time!
# self.rest_data_W0_n 0.2932005676504672
# self.rest_data_W0_a 0.14704014725829168
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2982918218158239
# all_train_score_W_Combined_a 0.14770528917606135
# test_score_W_combined_n 0.3375372689022107
# test_score_W_combined_a 0.12717095080593863
# Combine Neurons Number :46
# all_train_score_W0_n 0.2789668474917648
# all_train_score_W0_a 0.12567155449142867
# test_score_W0_n 0.3679753870454722
# test_score_W0_a  0.15320247995515018
# Split one time!
# self.rest_data_W0_n 0.2789716981762292
# self.rest_data_W0_a 0.12583911046231328
# all_train_score_W_Combined_n 0.27951823621313604
# all_train_score_W_Combined_a 0.12587086433287248
# test_score_W_combined_n 0.3338193377599353
# test_score_W_combined_a 0.13542451312354192
# Combine Neurons Number :45
# all_train_score_W0_n 0.2544328155202323
# all_train_score_W0_a 0.11592135788820145
# test_score_W0_n 0.36949869426023063
# test_score_W0_a  0.14734130574432822
# Split one time!
# self.rest_data_W0_n 0.2537756391531023
# self.rest_data_W0_a 0.11366575633345948
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.256680872987126
# all_train_score_W_Combined_a 0.1181005259143491
# test_score_W_combined_n 0.339334927636098
# test_score_W_combined_a 0.13122137434005746
# Combine Neurons Number :46
# all_train_score_W0_n 0.27326668525834436
# all_train_score_W0_a 0.134617128145455
# test_score_W0_n 0.3495683076849102
# test_score_W0_a  0.12932108545619816
# Split one time!
# self.rest_data_W0_n 0.2765379922001459
# self.rest_data_W0_a 0.13467498978584205
# all_train_score_W_Combined_n 0.2831336862860774
# all_train_score_W_Combined_a 0.1370138701343399
# test_score_W_combined_n 0.33692458958692323
# test_score_W_combined_a 0.13616534778791897
# Combine Neurons Number :48
# all_train_score_W0_n 0.2551627558123427
# all_train_score_W0_a 0.1337532505564781
# test_score_W0_n 0.3295352582456651
# test_score_W0_a  0.12290322717900144
# Split one time!
# self.rest_data_W0_n 0.2579944935631467
# self.rest_data_W0_a 0.13555879393659373
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# all_train_score_W_Combined_n 0.26209661872510115
# all_train_score_W_Combined_a 0.13736674405997112
# test_score_W_combined_n 0.30403027276471983
# test_score_W_combined_a 0.10409075489943648
# Combine Neurons Number :46
# all_train_score_W0_n 0.27557832487701805
# all_train_score_W0_a 0.12485980969997418
# test_score_W0_n 0.3658348745325521
# test_score_W0_a  0.14840735876843422
# Split one time!
# self.rest_data_W0_n 0.2765696829671602
# self.rest_data_W0_a 0.12984444694073394
# Split one time!
# self.rest_data_W0_n 0.5618848037853961
# self.rest_data_W0_a 0.125
# all_train_score_W_Combined_n 0.2799478843988325
# all_train_score_W_Combined_a 0.131602093417591
# test_score_W_combined_n 0.35879604852493063
# test_score_W_combined_a 0.15123214059250978
# Combine Neurons Number :47
# all_train_score_W0_n 0.29215639291700113
# all_train_score_W0_a 0.13199595121771104
# test_score_W0_n 0.35505146763626794
# test_score_W0_a  0.12668634983001922
# Split one time!
# self.rest_data_W0_n 0.2912346840411608
# self.rest_data_W0_a 0.13098219299853767
# all_train_score_W_Combined_n 0.29648498379836874
# all_train_score_W_Combined_a 0.13227558392224745
# test_score_W_combined_n 0.33736462960946617
# test_score_W_combined_a 0.10119020575420001
# Combine Neurons Number :45
# all_train_score_W0_n 0.2630678215137798
# all_train_score_W0_a 0.14457985138260288
# test_score_W0_n 0.3293237249490607
# test_score_W0_a  0.14002890047878677
# Split one time!
# self.rest_data_W0_n 0.2662686493956579
# self.rest_data_W0_a 0.14681440644965607
# all_train_score_W_Combined_n 0.2690722240607336
# all_train_score_W_Combined_a 0.14883138365813706
# test_score_W_combined_n 0.35036960738769973
# test_score_W_combined_a 0.15882290252896986
# Combine Neurons Number :45
# all_train_score_W0_n 0.23004548336272862
# all_train_score_W0_a 0.10563536559343127
# test_score_W0_n 0.3092723846429151
# test_score_W0_a  0.12931495288894507
# Split one time!
# self.rest_data_W0_n 0.23031378567540273
# self.rest_data_W0_a 0.10521366014795891
# all_train_score_W_Combined_n 0.23338988227928792
# all_train_score_W_Combined_a 0.10582324283460465
# test_score_W_combined_n 0.29097801404297047
# test_score_W_combined_a 0.10675542215474008
# Combine Neurons Number :44
# all_train_score_W0_n 0.2067700159300546
# all_train_score_W0_a 0.09959455333416167
# test_score_W0_n 0.2707210719378651
# test_score_W0_a  0.07897697175703829
# Split one time!
# self.rest_data_W0_n 0.21303859928779723
# self.rest_data_W0_a 0.09882936561360627
# Split one time!
# self.rest_data_W0_n 0.5726339917354203
# self.rest_data_W0_a 0.16129032258064516
# all_train_score_W_Combined_n 0.21978458896075098
# all_train_score_W_Combined_a 0.10484005255852204
# test_score_W_combined_n 0.2940964344123781
# test_score_W_combined_a 0.10039043160228367
# Combine Neurons Number :49
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.339076  0.025948  0.004737   0.329387  0.348765
# 1  test_score_W'  30.0  0.328145  0.020131  0.003675   0.320628  0.335662
# 2       combined  60.0  0.333611  0.023675  0.003056   0.327495  0.339727
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0109
# 1                          Degrees of freedom =   58.0000
# 2                                           t =    1.8231
# 3                       Two side test p value =    0.0734
# 4                      Difference < 0 p value =    0.9633
# 5                      Difference > 0 p value =    0.0367
# 6                                   Cohen's d =    0.4707
# 7                                   Hedge's g =    0.4646
# 8                               Glass's delta =    0.4213
# 9                                 Pearson's r =    0.2328
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.339076  0.025948  0.004737   0.329387  0.348765
# 1  test_score_W'  30.0  0.125690  0.022140  0.004042   0.117422  0.133957
# 2       combined  60.0  0.232383  0.110219  0.014229   0.203910  0.260856
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.2134
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   34.2648
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    1.0000
# 5                      Difference > 0 p value =    0.0000
# 6                                   Cohen's d =    8.8471
# 7                                   Hedge's g =    8.7322
# 8                               Glass's delta =    8.2237
# 9                                 Pearson's r =    0.9762
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
