# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("hcvdat0.csv")
csv = csv.drop(columns=['ID'])
dataread.replaceNANinDataset(csv)
dataread.stringToIntHCVDataSet(csv,"Category")
dataread.stringToIntHCVDataSet(csv,"Sex")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Category")

# %%
import experiment
unstable_repeate_num= 1
scope_num = 20
class_num = 5
dim_num = 12

som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
optimize_W.run()
# Out:
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.96
# error_data0_score_W1 nmi 0.9468417458597951
# error_data0_score_W1 api 0.9669330394047947
# error_data0_score_W0 purity 0.72
# error_data0_score_W0 nmi 0.5370004457271152
# error_data0_score_W0 api 0.4007731958762887
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 1.0
# error_data1_score_W0 api 1.0
# Error data can be represented by W0 purity 1
# Error data can be represented by W0 nmi 1
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.625
# right_data1_score_W' nmi 0.34792879736755206
# right_data1_score_W' api 0.19703600556992243
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.9419953596287703
# all_train_score_W' nmi split_num : 0 0.6039152639548744
# all_train_score_W' ari split_num : 0 0.7277727303185703
# test_score_W0 purity: 0.8967391304347826
# test_score_W0 nmi: 0.45923414215470004
# test_score_W0 api: 0.5958525290353868
# test_score_W': purity split_num : 0 0.8967391304347826
# test_score_W': nmi split_num : 0 0.45923414215470004
# test_score_W': ari split_num : 0 0.5958525290353868
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9976798143851509
# all_train_score_W' nmi split_num : 1 0.976025307707652
# all_train_score_W' ari split_num : 1 0.9874085030181969
# test_score_W0 purity: 0.8967391304347826
# test_score_W0 nmi: 0.45923414215470004
# test_score_W0 api: 0.5958525290353868
# test_score_W': purity split_num : 1 0.8967391304347826
# test_score_W': nmi split_num : 1 0.48485451916050115
# test_score_W': ari split_num : 1 0.7023187734446081
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.8967391304347826
# test_score_W0 nmi: 0.45923414215470004
# test_score_W0 api: 0.5958525290353868
# test_score_W': purity split_num : 2 0.8967391304347826
# test_score_W': nmi split_num : 2 0.48485451916050115
# test_score_W': ari split_num : 2 0.7023187734446081
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.8967391304347826
# test_scores_W_Combined_last_n 0.48485451916050115
# test_scores_W_Combined_last_a 0.7023187734446081
