# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from matplotlib.colors import ListedColormap

# %%
import som
import pandas as pd

# %%
iris = datasets.load_iris()
iris_data = iris.data
iris_label = iris.target

# %%
iris_data.shape
# Out:
# (150, 4)

# %% [markdown]
# iris_data = iris.data[:, :2]
# som = som.SOM(m=3, n=1, dim=2, random_state=1234)
# som.fit(iris_data)

# %%
predictions = som.predict(iris_data)
trained_weights = som.get_trained_weight();
print (trained_weights)
# Out:
# [[5.1402166  3.0010116 ]
#  [5.83961493 2.83495778]
#  [6.57033666 2.90017176]]

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(5,7))
x = iris_data[:,0]
y = iris_data[:,1]
colors = ['red', 'green', 'blue']
ax[0].scatter(x, y, c=iris_label, cmap=ListedColormap(colors))
ax[0].title.set_text('Actual Classes')
ax[1].scatter(x, y, c=predictions, cmap=ListedColormap(colors))
ax[1].title.set_text('SOM Predictions')
plt.savefig('iris_example.png')
