# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Obesity/ObesityDataSet_raw_and_data_sinthetic.csv")
dataread.stringToIntObseityDataSet(csv,"CAEC")
dataread.stringToIntObseityDataSet(csv,"Gender")
dataread.stringToIntObseityDataSet(csv,"family_history_with_overweight")
dataread.stringToIntObseityDataSet(csv,"FAVC")
dataread.stringToIntObseityDataSet(csv,"SCC")
dataread.stringToIntObseityDataSet(csv,"SMOKE")
dataread.stringToIntObseityDataSet(csv,"CALC")
dataread.stringToIntObseityDataSet(csv,"MTRANS")
dataread.stringToIntObseityDataSet(csv,"NObeyesdad")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"NObeyesdad")

# %%
# local scope2
scoretype = 0
scope_num = 30
class_num = 7
dim_num = 16
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(30,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 7
# *******************
#
# Error Data percentage 0.5189445196211097
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5501955671447197
# error_data0_score_W0 0.6166883963494133
# combinedweight shape 0: (14, 16)
# right_data0_score_W' 0.829817158931083
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4810554803788904
# all_train_score_W': 0.4810554803788904
# test_score_W0 : 0.49447077409162715
# test_score_W': 0.49447077409162715
# neuron unit number: 14
# *******************
#
# Error Data percentage 0.476319350473613
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6164772727272727
# error_data0_score_W0 0.6363636363636364
# combinedweight shape 0: (28, 16)
# right_data0_score_W' 0.8617571059431525
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.523680649526387
# all_train_score_W': 0.523680649526387
# test_score_W0 : 0.5955766192733017
# test_score_W': 0.5955766192733017
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.38430311231393777
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5933098591549296
# error_data0_score_W0 0.6003521126760564
# combinedweight shape 0: (42, 16)
# right_data0_score_W' 0.8164835164835165
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6156968876860622
# all_train_score_W': 0.6156968876860622
# test_score_W0 : 0.6445497630331753
# test_score_W': 0.6445497630331753
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.35250338294993233
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6238003838771593
# error_data0_score_W0 0.5585412667946257
# combinedweight shape 0: (56, 16)
# right_data0_score_W' 0.7335423197492164
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6474966170500677
# all_train_score_W': 0.6474966170500677
# test_score_W0 : 0.6761453396524486
# test_score_W': 0.6761453396524486
# neuron unit number: 35
# *******************
#
# Error Data percentage 0.3572395128552097
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6666666666666666
# error_data0_score_W0 0.5321969696969697
# combinedweight shape 0: (70, 16)
# right_data0_score_W' 0.74
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6427604871447903
# all_train_score_W': 0.6427604871447903
# test_score_W0 : 0.6619273301737757
# test_score_W': 0.6619273301737757
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.36400541271989173
# right_data0_score_W0 1.0
# error_data0_score_W1 0.671003717472119
# error_data0_score_W0 0.5817843866171004
# combinedweight shape 0: (84, 16)
# right_data0_score_W' 0.6723404255319149
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6359945872801083
# all_train_score_W': 0.6359945872801083
# test_score_W0 : 0.6429699842022117
# test_score_W': 0.6429699842022117
# neuron unit number: 49
# *******************
#
# Error Data percentage 0.33220568335588635
# right_data0_score_W0 1.0
# error_data0_score_W1 0.670061099796334
# error_data0_score_W0 0.5112016293279023
# combinedweight shape 0: (98, 16)
# right_data0_score_W' 0.7689969604863222
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6677943166441137
# all_train_score_W': 0.6677943166441137
# test_score_W0 : 0.6824644549763034
# test_score_W': 0.6824644549763034
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.32138024357239514
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7221052631578947
# error_data0_score_W0 0.5536842105263158
# combinedweight shape 0: (112, 16)
# right_data0_score_W' 0.7457627118644068
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6786197564276049
# all_train_score_W': 0.6786197564276049
# test_score_W0 : 0.6619273301737757
# test_score_W': 0.6619273301737757
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.30987821380243574
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6965065502183406
# error_data0_score_W0 0.5873362445414847
# combinedweight shape 0: (126, 16)
# right_data0_score_W' 0.7901960784313725
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6901217861975643
# all_train_score_W': 0.6901217861975643
# test_score_W0 : 0.7061611374407583
# test_score_W': 0.7061611374407583
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.2895805142083897
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7453271028037384
# error_data0_score_W0 0.5911214953271028
# combinedweight shape 0: (140, 16)
# right_data0_score_W' 0.7352380952380952
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7104194857916103
# all_train_score_W': 0.7104194857916103
# test_score_W0 : 0.7109004739336493
# test_score_W': 0.7109004739336493
# neuron unit number: 77
# *******************
#
# Error Data percentage 0.3051420838971583
# right_data0_score_W0 1.0
# error_data0_score_W1 0.753880266075388
# error_data0_score_W0 0.5742793791574279
# combinedweight shape 0: (154, 16)
# right_data0_score_W' 0.7224926971762414
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6948579161028416
# all_train_score_W': 0.6948579161028416
# test_score_W0 : 0.7093206951026856
# test_score_W': 0.7093206951026856
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2997293640054127
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7539503386004515
# error_data0_score_W0 0.5665914221218962
# combinedweight shape 0: (168, 16)
# right_data0_score_W' 0.7536231884057971
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7002706359945873
# all_train_score_W': 0.7002706359945873
# test_score_W0 : 0.7282780410742496
# test_score_W': 0.7282780410742496
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.2861975642760487
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7565011820330969
# error_data0_score_W0 0.5650118203309693
# combinedweight shape 0: (182, 16)
# right_data0_score_W' 0.771563981042654
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7138024357239513
# all_train_score_W': 0.7138024357239513
# test_score_W0 : 0.7282780410742496
# test_score_W': 0.7282780410742496
# neuron unit number: 98
# *******************
#
# Error Data percentage 0.2882273342354533
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7629107981220657
# error_data0_score_W0 0.5751173708920188
# combinedweight shape 0: (196, 16)
# right_data0_score_W' 0.7652091254752852
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7117726657645467
# all_train_score_W': 0.7117726657645467
# test_score_W0 : 0.7124802527646129
# test_score_W': 0.7124802527646129
# neuron unit number: 105
# *******************
#
# Error Data percentage 0.2692828146143437
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7512562814070352
# error_data0_score_W0 0.5100502512562815
# combinedweight shape 0: (210, 16)
# right_data0_score_W' 0.7694444444444445
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7307171853856563
# all_train_score_W': 0.7307171853856563
# test_score_W0 : 0.7235387045813586
# test_score_W': 0.7235387045813586
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.2929634641407307
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7528868360277137
# error_data0_score_W0 0.5750577367205543
# combinedweight shape 0: (224, 16)
# right_data0_score_W' 0.7904306220095694
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7070365358592693
# all_train_score_W': 0.7070365358592693
# test_score_W0 : 0.707740916271722
# test_score_W': 0.707740916271722
# neuron unit number: 119
# *******************
#
# Error Data percentage 0.30311231393775373
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7455357142857143
# error_data0_score_W0 0.5714285714285714
# combinedweight shape 0: (238, 16)
# right_data0_score_W' 0.7165048543689321
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6968876860622463
# all_train_score_W': 0.6968876860622463
# test_score_W0 : 0.7282780410742496
# test_score_W': 0.7282780410742496
# neuron unit number: 126
# *******************
#
# Error Data percentage 0.2510148849797023
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8032345013477089
# error_data0_score_W0 0.5795148247978437
# combinedweight shape 0: (252, 16)
# right_data0_score_W' 0.7280939476061428
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7489851150202977
# all_train_score_W': 0.7489851150202977
# test_score_W0 : 0.7266982622432859
# test_score_W': 0.7266982622432859
# neuron unit number: 133
# *******************
#
# Error Data percentage 0.2692828146143437
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7386934673366834
# error_data0_score_W0 0.5577889447236181
# combinedweight shape 0: (266, 16)
# right_data0_score_W' 0.787962962962963
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7307171853856563
# all_train_score_W': 0.7307171853856563
# test_score_W0 : 0.7440758293838863
# test_score_W': 0.7440758293838863
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.29905277401894453
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7873303167420814
# error_data0_score_W0 0.5158371040723982
# combinedweight shape 0: (280, 16)
# right_data0_score_W' 0.7567567567567568
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7009472259810555
# all_train_score_W': 0.7009472259810555
# test_score_W0 : 0.7187993680884676
# test_score_W': 0.7187993680884676
# neuron unit number: 147
# *******************
#
# Error Data percentage 0.2780784844384303
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7566909975669099
# error_data0_score_W0 0.5888077858880778
# combinedweight shape 0: (294, 16)
# right_data0_score_W' 0.7628865979381443
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7219215155615697
# all_train_score_W': 0.7219215155615697
# test_score_W0 : 0.7298578199052133
# test_score_W': 0.7298578199052133
# neuron unit number: 154
# *******************
#
# Error Data percentage 0.2543978349120433
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7686170212765957
# error_data0_score_W0 0.5611702127659575
# combinedweight shape 0: (308, 16)
# right_data0_score_W' 0.7840290381125227
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7456021650879567
# all_train_score_W': 0.7456021650879567
# test_score_W0 : 0.7330173775671406
# test_score_W': 0.7330173775671406
# neuron unit number: 161
# *******************
#
# Error Data percentage 0.2794316644113667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7675544794188862
# error_data0_score_W0 0.5326876513317191
# combinedweight shape 0: (322, 16)
# right_data0_score_W' 0.7502347417840376
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7205683355886333
# all_train_score_W': 0.7205683355886333
# test_score_W0 : 0.7124802527646129
# test_score_W': 0.7124802527646129
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.2483085250338295
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8174386920980926
# error_data0_score_W0 0.5912806539509536
# combinedweight shape 0: (336, 16)
# right_data0_score_W' 0.8253825382538253
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7516914749661705
# all_train_score_W': 0.7516914749661705
# test_score_W0 : 0.7535545023696683
# test_score_W': 0.7535545023696683
# neuron unit number: 175
# *******************
#
# Error Data percentage 0.2530446549391069
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8048128342245989
# error_data0_score_W0 0.5935828877005348
# combinedweight shape 0: (350, 16)
# right_data0_score_W' 0.7853260869565217
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7469553450608931
# all_train_score_W': 0.7469553450608931
# test_score_W0 : 0.7883096366508688
# test_score_W': 0.7883096366508688
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.2706359945872801
# right_data0_score_W0 1.0
# error_data0_score_W1 0.795
# error_data0_score_W0 0.4725
# combinedweight shape 0: (364, 16)
# right_data0_score_W' 0.7708719851576994
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7293640054127198
# all_train_score_W': 0.7293640054127198
# test_score_W0 : 0.7472353870458136
# test_score_W': 0.7472353870458136
# neuron unit number: 189
# *******************
#
# Error Data percentage 0.2422192151556157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8072625698324022
# error_data0_score_W0 0.5586592178770949
# combinedweight shape 0: (378, 16)
# right_data0_score_W' 0.7794642857142857
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7577807848443843
# all_train_score_W': 0.7577807848443843
# test_score_W0 : 0.7551342812006319
# test_score_W': 0.7551342812006319
# neuron unit number: 196
# *******************
#
# Error Data percentage 0.2327469553450609
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8168604651162791
# error_data0_score_W0 0.5581395348837209
# combinedweight shape 0: (392, 16)
# right_data0_score_W' 0.8421516754850088
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7672530446549392
# all_train_score_W': 0.7672530446549392
# test_score_W0 : 0.7361769352290679
# test_score_W': 0.7361769352290679
# neuron unit number: 203
# *******************
#
# Error Data percentage 0.2476319350473613
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8114754098360656
# error_data0_score_W0 0.5327868852459017
# combinedweight shape 0: (406, 16)
# right_data0_score_W' 0.7544964028776978
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7523680649526387
# all_train_score_W': 0.7523680649526387
# test_score_W0 : 0.7503949447077409
# test_score_W': 0.7503949447077409
# neuron unit number: 210
# *******************
#
# Error Data percentage 0.2293640054127199
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8436578171091446
# error_data0_score_W0 0.5427728613569321
# combinedweight shape 0: (420, 16)
# right_data0_score_W' 0.8244073748902546
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7706359945872802
# all_train_score_W': 0.7706359945872802
# test_score_W0 : 0.7598736176935229
# test_score_W': 0.7598736176935229
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.705687  0.056996  0.010406   0.684404  0.726970
# 1  test_score_W'  30.0  0.705687  0.056996  0.010406   0.684404  0.726970
# 2       combined  60.0  0.705687  0.056511  0.007296   0.691089  0.720286
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =       0.0
# 1                          Degrees of freedom =      58.0
# 2                                           t =       0.0
# 3                       Two side test p value =       1.0
# 4                      Difference < 0 p value =       0.5
# 5                      Difference > 0 p value =       0.5
# 6                                   Cohen's d =       0.0
# 7                                   Hedge's g =       0.0
# 8                               Glass's delta =       0.0
# 9                                 Pearson's r =       0.0
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=0.0, pvalue=0.5)
