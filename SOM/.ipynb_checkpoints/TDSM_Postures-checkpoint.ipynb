# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("MiceProtein/Data_Cortex_Nuclear.csv")
csv = csv.drop(columns=['MouseID'])
dataread.replaceNANinDataset(csv)

dataread.stringToIntMiceProteinDataSet(csv,"Genotype")
dataread.stringToIntMiceProteinDataSet(csv,"Treatment")
dataread.stringToIntMiceProteinDataSet(csv,"class")
dataread.stringToIntMiceProteinDataSet(csv,"Behavior")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"class")

# %%
# multiple text by adding neuron number
scoretype = 0
scope_num = 30
class_num = 8
dim_num = 80
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.66005291005291
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3967935871743487
# error_data0_score_W0 0.33266533066132264
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.7392996108949417
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.33994708994708994
# all_train_score_W': 0.3941798941798942
# test_score_W0 : 0.37962962962962965
# test_score_W': 0.3888888888888889
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5846560846560847
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4638009049773756
# error_data0_score_W0 0.35294117647058826
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.7834394904458599
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.41534391534391535
# all_train_score_W': 0.4801587301587302
# test_score_W0 : 0.43209876543209874
# test_score_W': 0.4660493827160494
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.5568783068783069
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6080760095011877
# error_data0_score_W0 0.38954869358669836
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.7791044776119403
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.44312169312169314
# all_train_score_W': 0.5912698412698413
# test_score_W0 : 0.4104938271604938
# test_score_W': 0.5185185185185185
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.455026455026455
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6686046511627907
# error_data0_score_W0 0.40988372093023256
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.8519417475728155
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.544973544973545
# all_train_score_W': 0.7023809523809523
# test_score_W0 : 0.5432098765432098
# test_score_W': 0.6882716049382716
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.38227513227513227
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7439446366782007
# error_data0_score_W0 0.43252595155709345
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.8843683083511777
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6177248677248677
# all_train_score_W': 0.7513227513227513
# test_score_W0 : 0.5524691358024691
# test_score_W': 0.7129629629629629
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.33201058201058203
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7888446215139442
# error_data0_score_W0 0.44621513944223107
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.8792079207920792
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.667989417989418
# all_train_score_W': 0.7976190476190477
# test_score_W0 : 0.5740740740740741
# test_score_W': 0.7469135802469136
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.3412698412698413
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8372093023255814
# error_data0_score_W0 0.4186046511627907
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.785140562248996
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6587301587301587
# all_train_score_W': 0.7645502645502645
# test_score_W0 : 0.6604938271604939
# test_score_W': 0.7067901234567902
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.31613756613756616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8661087866108786
# error_data0_score_W0 0.4602510460251046
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.8297872340425532
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6838624338624338
# all_train_score_W': 0.8201058201058201
# test_score_W0 : 0.6080246913580247
# test_score_W': 0.8179012345679012
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.24603174603174602
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8924731182795699
# error_data0_score_W0 0.5483870967741935
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.8666666666666667
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.753968253968254
# all_train_score_W': 0.8505291005291006
# test_score_W0 : 0.7253086419753086
# test_score_W': 0.8024691358024691
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.22354497354497355
# right_data0_score_W0 1.0
# error_data0_score_W1 0.893491124260355
# error_data0_score_W0 0.5384615384615384
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8858603066439523
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7764550264550265
# all_train_score_W': 0.8756613756613757
# test_score_W0 : 0.7037037037037037
# test_score_W': 0.8425925925925926
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2447089947089947
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9351351351351351
# error_data0_score_W0 0.6162162162162163
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.9141856392294221
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7552910052910053
# all_train_score_W': 0.8941798941798942
# test_score_W0 : 0.6944444444444444
# test_score_W': 0.8672839506172839
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.18253968253968253
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9565217391304348
# error_data0_score_W0 0.6159420289855072
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.8381877022653722
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8174603174603174
# all_train_score_W': 0.8452380952380952
# test_score_W0 : 0.7098765432098766
# test_score_W': 0.8240740740740741
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.19444444444444445
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9523809523809523
# error_data0_score_W0 0.5714285714285714
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8834154351395731
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8055555555555556
# all_train_score_W': 0.8783068783068783
# test_score_W0 : 0.7253086419753086
# test_score_W': 0.8611111111111112
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.23148148148148148
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9771428571428571
# error_data0_score_W0 0.5771428571428572
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.9139414802065404
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7685185185185185
# all_train_score_W': 0.9074074074074074
# test_score_W0 : 0.7098765432098766
# test_score_W': 0.8641975308641975
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.1970899470899471
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9932885906040269
# error_data0_score_W0 0.5033557046979866
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.8945634266886326
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8029100529100529
# all_train_score_W': 0.9074074074074074
# test_score_W0 : 0.7530864197530864
# test_score_W': 0.9228395061728395
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.18783068783068782
# right_data0_score_W0 1.0
# error_data0_score_W1 0.971830985915493
# error_data0_score_W0 0.5211267605633803
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.9234527687296417
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8121693121693122
# all_train_score_W': 0.9140211640211641
# test_score_W0 : 0.75
# test_score_W': 0.8765432098765432
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.2261904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9649122807017544
# error_data0_score_W0 0.4678362573099415
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.8905982905982905
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7738095238095238
# all_train_score_W': 0.8928571428571429
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8672839506172839
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.3386243386243386
# right_data0_score_W0 1.0
# error_data0_score_W1 0.890625
# error_data0_score_W0 0.453125
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.872
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6613756613756614
# all_train_score_W': 0.8412698412698413
# test_score_W0 : 0.6203703703703703
# test_score_W': 0.8179012345679012
# neuron unit number: 152
# *******************
# Error Data percentage 0.20105820105820105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9539473684210527
# error_data0_score_W0 0.6907894736842105
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.8973509933774835
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.798941798941799
# all_train_score_W': 0.8981481481481481
# test_score_W0 : 0.7469135802469136
# test_score_W': 0.8641975308641975
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.19047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9305555555555556
# error_data0_score_W0 0.5902777777777778
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.8398692810457516
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8095238095238095
# all_train_score_W': 0.8478835978835979
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8580246913580247
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.1984126984126984
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9466666666666667
# error_data0_score_W0 0.54
# combinedweight shape 0: (336, 80)
# right_data0_score_W' 0.9042904290429042
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8015873015873016
# all_train_score_W': 0.8994708994708994
# test_score_W0 : 0.7530864197530864
# test_score_W': 0.8580246913580247
# neuron unit number: 176
# *******************
#
# Error Data percentage 0.18518518518518517
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9571428571428572
# error_data0_score_W0 0.6214285714285714
# combinedweight shape 0: (352, 80)
# right_data0_score_W' 0.900974025974026
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8148148148148148
# all_train_score_W': 0.8968253968253969
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8302469135802469
# neuron unit number: 184
# *******************
#
# Error Data percentage 0.2566137566137566
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8865979381443299
# error_data0_score_W0 0.5773195876288659
# combinedweight shape 0: (368, 80)
# right_data0_score_W' 0.891459074733096
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7433862433862434
# all_train_score_W': 0.8584656084656085
# test_score_W0 : 0.7037037037037037
# test_score_W': 0.8734567901234568
# neuron unit number: 192
# *******************
#
# Error Data percentage 0.23941798941798942
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9226519337016574
# error_data0_score_W0 0.5524861878453039
# combinedweight shape 0: (384, 80)
# right_data0_score_W' 0.9095652173913044
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7605820105820106
# all_train_score_W': 0.8955026455026455
# test_score_W0 : 0.7253086419753086
# test_score_W': 0.8240740740740741
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.20105820105820105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9473684210526315
# error_data0_score_W0 0.46710526315789475
# combinedweight shape 0: (400, 80)
# right_data0_score_W' 0.9039735099337748
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.798941798941799
# all_train_score_W': 0.9021164021164021
# test_score_W0 : 0.7654320987654321
# test_score_W': 0.8765432098765432
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.21825396825396826
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9575757575757575
# error_data0_score_W0 0.6060606060606061
# combinedweight shape 0: (416, 80)
# right_data0_score_W' 0.9441624365482234
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7817460317460317
# all_train_score_W': 0.9259259259259259
# test_score_W0 : 0.7191358024691358
# test_score_W': 0.9166666666666666
# neuron unit number: 216
# *******************
#
# Error Data percentage 0.1402116402116402
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9811320754716981
# error_data0_score_W0 0.5188679245283019
# combinedweight shape 0: (432, 80)
# right_data0_score_W' 0.8769230769230769
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8597883597883598
# all_train_score_W': 0.8849206349206349
# test_score_W0 : 0.808641975308642
# test_score_W': 0.8425925925925926
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.2751322751322751
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9182692307692307
# error_data0_score_W0 0.5096153846153846
# combinedweight shape 0: (448, 80)
# right_data0_score_W' 0.8412408759124088
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7248677248677249
# all_train_score_W': 0.832010582010582
# test_score_W0 : 0.7037037037037037
# test_score_W': 0.8055555555555556
# neuron unit number: 232
# *******************
#
# Error Data percentage 0.20105820105820105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9736842105263158
# error_data0_score_W0 0.4868421052631579
# combinedweight shape 0: (464, 80)
# right_data0_score_W' 0.8874172185430463
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.798941798941799
# all_train_score_W': 0.8875661375661376
# test_score_W0 : 0.7654320987654321
# test_score_W': 0.8888888888888888
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.1917989417989418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9586206896551724
# error_data0_score_W0 0.503448275862069
# combinedweight shape 0: (480, 80)
# right_data0_score_W' 0.8919803600654664
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8082010582010583
# all_train_score_W': 0.8849206349206349
# test_score_W0 : 0.7561728395061729
# test_score_W': 0.8518518518518519
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6507936507936508
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4268292682926829
# error_data0_score_W0 0.31910569105691056
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.7803030303030303
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3492063492063492
# all_train_score_W': 0.4007936507936508
# test_score_W0 : 0.3333333333333333
# test_score_W': 0.3425925925925926
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5621693121693122
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4823529411764706
# error_data0_score_W0 0.43529411764705883
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.8157099697885196
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.43783068783068785
# all_train_score_W': 0.5423280423280423
# test_score_W0 : 0.41358024691358025
# test_score_W': 0.5339506172839507
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.4669312169312169
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5807365439093485
# error_data0_score_W0 0.37110481586402266
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.8511166253101737
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.533068783068783
# all_train_score_W': 0.6521164021164021
# test_score_W0 : 0.5679012345679012
# test_score_W': 0.5987654320987654
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.4497354497354497
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6941176470588235
# error_data0_score_W0 0.3911764705882353
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.8052884615384616
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5502645502645502
# all_train_score_W': 0.6666666666666666
# test_score_W0 : 0.5030864197530864
# test_score_W': 0.6296296296296297
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.4444444444444444
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7291666666666666
# error_data0_score_W0 0.4017857142857143
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.8523809523809524
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5555555555555556
# all_train_score_W': 0.7275132275132276
# test_score_W0 : 0.5123456790123457
# test_score_W': 0.6574074074074074
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.35978835978835977
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7794117647058824
# error_data0_score_W0 0.4264705882352941
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.8698347107438017
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6402116402116402
# all_train_score_W': 0.7870370370370371
# test_score_W0 : 0.654320987654321
# test_score_W': 0.7777777777777778
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.2976190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8488888888888889
# error_data0_score_W0 0.4444444444444444
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.903954802259887
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7023809523809523
# all_train_score_W': 0.8412698412698413
# test_score_W0 : 0.6141975308641975
# test_score_W': 0.7685185185185185
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.24338624338624337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8641304347826086
# error_data0_score_W0 0.4891304347826087
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.8706293706293706
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7566137566137566
# all_train_score_W': 0.8505291005291006
# test_score_W0 : 0.7006172839506173
# test_score_W': 0.8518518518518519
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2552910052910053
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8911917098445595
# error_data0_score_W0 0.5025906735751295
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.9271758436944938
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7447089947089947
# all_train_score_W': 0.8928571428571429
# test_score_W0 : 0.7222222222222222
# test_score_W': 0.8333333333333334
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.20105820105820105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9210526315789473
# error_data0_score_W0 0.48026315789473684
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8940397350993378
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.798941798941799
# all_train_score_W': 0.873015873015873
# test_score_W0 : 0.7222222222222222
# test_score_W': 0.8271604938271605
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2328042328042328
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9147727272727273
# error_data0_score_W0 0.4431818181818182
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.9206896551724137
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7671957671957672
# all_train_score_W': 0.9113756613756614
# test_score_W0 : 0.7530864197530864
# test_score_W': 0.8827160493827161
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.2261904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9473684210526315
# error_data0_score_W0 0.5263157894736842
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.9264957264957265
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7738095238095238
# all_train_score_W': 0.9153439153439153
# test_score_W0 : 0.7746913580246914
# test_score_W': 0.8981481481481481
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.2526455026455027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9162303664921466
# error_data0_score_W0 0.47643979057591623
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8601769911504424
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7473544973544973
# all_train_score_W': 0.832010582010582
# test_score_W0 : 0.6882716049382716
# test_score_W': 0.7623456790123457
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.18518518518518517
# right_data0_score_W0 1.0
# error_data0_score_W1 0.95
# error_data0_score_W0 0.5285714285714286
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.9025974025974026
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8148148148148148
# all_train_score_W': 0.8994708994708994
# test_score_W0 : 0.7870370370370371
# test_score_W': 0.8827160493827161
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.26455026455026454
# right_data0_score_W0 1.0
# error_data0_score_W1 0.945
# error_data0_score_W0 0.44
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.9046762589928058
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7354497354497355
# all_train_score_W': 0.8796296296296297
# test_score_W0 : 0.7129629629629629
# test_score_W': 0.8302469135802469
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.17195767195767195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9230769230769231
# error_data0_score_W0 0.5692307692307692
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8626198083067093
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.828042328042328
# all_train_score_W': 0.8664021164021164
# test_score_W0 : 0.7932098765432098
# test_score_W': 0.8395061728395061
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9153439153439153
# error_data0_score_W0 0.5132275132275133
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.8201058201058201
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.75
# all_train_score_W': 0.8161375661375662
# test_score_W0 : 0.7222222222222222
# test_score_W': 0.7654320987654321
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.20105820105820105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9671052631578947
# error_data0_score_W0 0.5263157894736842
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.8625827814569537
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.798941798941799
# all_train_score_W': 0.8664021164021164
# test_score_W0 : 0.7376543209876543
# test_score_W': 0.8240740740740741
# neuron unit number: 152
# *******************
#
# Error Data percentage 0.20899470899470898
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9620253164556962
# error_data0_score_W0 0.5443037974683544
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.9264214046822743
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.791005291005291
# all_train_score_W': 0.9140211640211641
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8981481481481481
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.26587301587301587
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8955223880597015
# error_data0_score_W0 0.5024875621890548
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.9027027027027027
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7341269841269841
# all_train_score_W': 0.8650793650793651
# test_score_W0 : 0.6790123456790124
# test_score_W': 0.7932098765432098
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.19047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9791666666666666
# error_data0_score_W0 0.5763888888888888
# combinedweight shape 0: (336, 80)
# right_data0_score_W' 0.9117647058823529
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8095238095238095
# all_train_score_W': 0.9166666666666666
# test_score_W0 : 0.7376543209876543
# test_score_W': 0.8919753086419753
# neuron unit number: 176
# *******************
#
# Error Data percentage 0.2208994708994709
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9700598802395209
# error_data0_score_W0 0.5449101796407185
# combinedweight shape 0: (352, 80)
# right_data0_score_W' 0.9066213921901528
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7791005291005291
# all_train_score_W': 0.9021164021164021
# test_score_W0 : 0.7129629629629629
# test_score_W': 0.8518518518518519
# neuron unit number: 184
# *******************
#
# Error Data percentage 0.2261904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9415204678362573
# error_data0_score_W0 0.6374269005847953
# combinedweight shape 0: (368, 80)
# right_data0_score_W' 0.8495726495726496
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7738095238095238
# all_train_score_W': 0.8518518518518519
# test_score_W0 : 0.7345679012345679
# test_score_W': 0.8518518518518519
# neuron unit number: 192
# *******************
#
# Error Data percentage 0.18386243386243387
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9712230215827338
# error_data0_score_W0 0.5683453237410072
# combinedweight shape 0: (384, 80)
# right_data0_score_W' 0.899513776337115
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8161375661375662
# all_train_score_W': 0.9047619047619048
# test_score_W0 : 0.7067901234567902
# test_score_W': 0.8734567901234568
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.25396825396825395
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8958333333333334
# error_data0_score_W0 0.4583333333333333
# combinedweight shape 0: (400, 80)
# right_data0_score_W' 0.9184397163120568
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.746031746031746
# all_train_score_W': 0.8941798941798942
# test_score_W0 : 0.691358024691358
# test_score_W': 0.8703703703703703
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.23941798941798942
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9281767955801105
# error_data0_score_W0 0.49171270718232046
# combinedweight shape 0: (416, 80)
# right_data0_score_W' 0.9252173913043479
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7605820105820106
# all_train_score_W': 0.8888888888888888
# test_score_W0 : 0.6882716049382716
# test_score_W': 0.8641975308641975
# neuron unit number: 216
# *******************
#
# Error Data percentage 0.17857142857142858
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9851851851851852
# error_data0_score_W0 0.562962962962963
# combinedweight shape 0: (432, 80)
# right_data0_score_W' 0.9130434782608695
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8214285714285714
# all_train_score_W': 0.921957671957672
# test_score_W0 : 0.7716049382716049
# test_score_W': 0.8703703703703703
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.16534391534391535
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.536
# combinedweight shape 0: (448, 80)
# right_data0_score_W' 0.9334389857369255
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8346560846560847
# all_train_score_W': 0.9378306878306878
# test_score_W0 : 0.7839506172839507
# test_score_W': 0.8302469135802469
# neuron unit number: 232
# *******************
#
# Error Data percentage 0.1574074074074074
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9831932773109243
# error_data0_score_W0 0.6302521008403361
# combinedweight shape 0: (464, 80)
# right_data0_score_W' 0.8634222919937206
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8425925925925926
# all_train_score_W': 0.8783068783068783
# test_score_W0 : 0.7901234567901234
# test_score_W': 0.8580246913580247
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.21957671957671956
# right_data0_score_W0 1.0
# error_data0_score_W1 0.963855421686747
# error_data0_score_W0 0.4759036144578313
# combinedweight shape 0: (480, 80)
# right_data0_score_W' 0.8932203389830509
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7804232804232805
# all_train_score_W': 0.8822751322751323
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8611111111111112
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6190476190476191
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4358974358974359
# error_data0_score_W0 0.3888888888888889
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.7881944444444444
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.38095238095238093
# all_train_score_W': 0.45634920634920634
# test_score_W0 : 0.36419753086419754
# test_score_W': 0.4537037037037037
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5608465608465608
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5235849056603774
# error_data0_score_W0 0.4481132075471698
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.6656626506024096
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.43915343915343913
# all_train_score_W': 0.46825396825396826
# test_score_W0 : 0.39197530864197533
# test_score_W': 0.4567901234567901
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.414021164021164
# right_data0_score_W0 1.0
# error_data0_score_W1 0.65814696485623
# error_data0_score_W0 0.5015974440894568
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.8555304740406321
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5859788359788359
# all_train_score_W': 0.6759259259259259
# test_score_W0 : 0.5771604938271605
# test_score_W': 0.6728395061728395
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.44047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5675675675675675
# error_data0_score_W0 0.3933933933933934
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.7706855791962175
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5595238095238095
# all_train_score_W': 0.6124338624338624
# test_score_W0 : 0.5246913580246914
# test_score_W': 0.5987654320987654
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.34656084656084657
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7748091603053435
# error_data0_score_W0 0.5687022900763359
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.8987854251012146
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6534391534391535
# all_train_score_W': 0.7711640211640212
# test_score_W0 : 0.6759259259259259
# test_score_W': 0.7098765432098766
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.40343915343915343
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7344262295081967
# error_data0_score_W0 0.4163934426229508
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.7982261640798226
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5965608465608465
# all_train_score_W': 0.7103174603174603
# test_score_W0 : 0.5895061728395061
# test_score_W': 0.7037037037037037
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.29365079365079366
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7747747747747747
# error_data0_score_W0 0.5405405405405406
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.8632958801498127
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7063492063492064
# all_train_score_W': 0.8002645502645502
# test_score_W0 : 0.6481481481481481
# test_score_W': 0.7469135802469136
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.28174603174603174
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8309859154929577
# error_data0_score_W0 0.49295774647887325
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.9318600368324125
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7182539682539683
# all_train_score_W': 0.8597883597883598
# test_score_W0 : 0.6975308641975309
# test_score_W': 0.8611111111111112
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.26851851851851855
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9359605911330049
# error_data0_score_W0 0.5221674876847291
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.8842676311030742
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7314814814814815
# all_train_score_W': 0.8716931216931217
# test_score_W0 : 0.6759259259259259
# test_score_W': 0.8549382716049383
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.26455026455026454
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.49
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8381294964028777
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7354497354497355
# all_train_score_W': 0.8174603174603174
# test_score_W0 : 0.7067901234567902
# test_score_W': 0.7993827160493827
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2526455026455027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8952879581151832
# error_data0_score_W0 0.5235602094240838
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.9079646017699115
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7473544973544973
# all_train_score_W': 0.8862433862433863
# test_score_W0 : 0.7345679012345679
# test_score_W': 0.8611111111111112
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.20502645502645503
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9548387096774194
# error_data0_score_W0 0.5225806451612903
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.9217970049916805
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.794973544973545
# all_train_score_W': 0.91005291005291
# test_score_W0 : 0.7407407407407407
# test_score_W': 0.8765432098765432
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9365079365079365
# error_data0_score_W0 0.5608465608465608
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8747795414462081
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.75
# all_train_score_W': 0.8650793650793651
# test_score_W0 : 0.6697530864197531
# test_score_W': 0.8055555555555556
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.167989417989418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9291338582677166
# error_data0_score_W0 0.5196850393700787
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.8855325914149443
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.832010582010582
# all_train_score_W': 0.8822751322751323
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.845679012345679
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.1865079365079365
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9716312056737588
# error_data0_score_W0 0.574468085106383
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.9024390243902439
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8134920634920635
# all_train_score_W': 0.9074074074074074
# test_score_W0 : 0.7746913580246914
# test_score_W': 0.8549382716049383
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.18121693121693122
# right_data0_score_W0 1.0
# error_data0_score_W1 0.948905109489051
# error_data0_score_W0 0.5474452554744526
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8998384491114702
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8187830687830688
# all_train_score_W': 0.9047619047619048
# test_score_W0 : 0.7530864197530864
# test_score_W': 0.8395061728395061
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.18121693121693122
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9854014598540146
# error_data0_score_W0 0.5547445255474452
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.8933764135702746
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8187830687830688
# all_train_score_W': 0.9007936507936508
# test_score_W0 : 0.8055555555555556
# test_score_W': 0.8981481481481481
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.2447089947089947
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8378378378378378
# error_data0_score_W0 0.5783783783783784
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.8896672504378283
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7552910052910053
# all_train_score_W': 0.8544973544973545
# test_score_W0 : 0.7530864197530864
# test_score_W': 0.7530864197530864
# neuron unit number: 152
# *******************
# Error Data percentage 0.2804232804232804
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8726415094339622
# error_data0_score_W0 0.5330188679245284
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.8970588235294118
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7195767195767195
# all_train_score_W': 0.8412698412698413
# test_score_W0 : 0.6419753086419753
# test_score_W': 0.7901234567901234
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.22354497354497355
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9585798816568047
# error_data0_score_W0 0.5384615384615384
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.8705281090289608
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7764550264550265
# all_train_score_W': 0.8756613756613757
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.8549382716049383
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.2037037037037037
# right_data0_score_W0 1.0
# error_data0_score_W1 0.961038961038961
# error_data0_score_W0 0.525974025974026
# combinedweight shape 0: (336, 80)
# right_data0_score_W' 0.8770764119601329
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7962962962962963
# all_train_score_W': 0.8875661375661376
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.8641975308641975
# neuron unit number: 176
# *******************
#
# Error Data percentage 0.21693121693121692
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9695121951219512
# error_data0_score_W0 0.5426829268292683
# combinedweight shape 0: (352, 80)
# right_data0_score_W' 0.8868243243243243
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.783068783068783
# all_train_score_W': 0.9034391534391535
# test_score_W0 : 0.7685185185185185
# test_score_W': 0.8888888888888888
# neuron unit number: 184
# *******************
#
# Error Data percentage 0.20767195767195767
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9235668789808917
# error_data0_score_W0 0.5031847133757962
# combinedweight shape 0: (368, 80)
# right_data0_score_W' 0.8764607679465777
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7923280423280423
# all_train_score_W': 0.8650793650793651
# test_score_W0 : 0.7129629629629629
# test_score_W': 0.845679012345679
# neuron unit number: 192
# *******************
#
# Error Data percentage 0.24735449735449735
# right_data0_score_W0 1.0
# error_data0_score_W1 0.93048128342246
# error_data0_score_W0 0.48663101604278075
# combinedweight shape 0: (384, 80)
# right_data0_score_W' 0.8822495606326889
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7526455026455027
# all_train_score_W': 0.8783068783068783
# test_score_W0 : 0.6820987654320988
# test_score_W': 0.8395061728395061
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.2526455026455027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.93717277486911
# error_data0_score_W0 0.5497382198952879
# combinedweight shape 0: (400, 80)
# right_data0_score_W' 0.8831858407079646
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7473544973544973
# all_train_score_W': 0.8650793650793651
# test_score_W0 : 0.7006172839506173
# test_score_W': 0.8580246913580247
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.167989417989418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9921259842519685
# error_data0_score_W0 0.6141732283464567
# combinedweight shape 0: (416, 80)
# right_data0_score_W' 0.8887122416534181
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.832010582010582
# all_train_score_W': 0.9007936507936508
# test_score_W0 : 0.7808641975308642
# test_score_W': 0.8487654320987654
# neuron unit number: 216
# *******************
#
# Error Data percentage 0.30158730158730157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8640350877192983
# error_data0_score_W0 0.41228070175438597
# combinedweight shape 0: (432, 80)
# right_data0_score_W' 0.9090909090909091
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6984126984126984
# all_train_score_W': 0.843915343915344
# test_score_W0 : 0.654320987654321
# test_score_W': 0.8302469135802469
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.19576719576719576
# right_data0_score_W0 1.0
# error_data0_score_W1 0.972972972972973
# error_data0_score_W0 0.6486486486486487
# combinedweight shape 0: (448, 80)
# right_data0_score_W' 0.9210526315789473
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8042328042328042
# all_train_score_W': 0.9113756613756614
# test_score_W0 : 0.7716049382716049
# test_score_W': 0.8796296296296297
# neuron unit number: 232
# *******************
#
# Error Data percentage 0.16666666666666666
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9603174603174603
# error_data0_score_W0 0.5396825396825397
# combinedweight shape 0: (464, 80)
# right_data0_score_W' 0.8873015873015873
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8333333333333334
# all_train_score_W': 0.8955026455026455
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.808641975308642
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.18518518518518517
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9357142857142857
# error_data0_score_W0 0.5714285714285714
# combinedweight shape 0: (480, 80)
# right_data0_score_W' 0.8831168831168831
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8148148148148148
# all_train_score_W': 0.8888888888888888
# test_score_W0 : 0.7654320987654321
# test_score_W': 0.8858024691358025
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.7037037037037037
# right_data0_score_W0 1.0
# error_data0_score_W1 0.40601503759398494
# error_data0_score_W0 0.28383458646616544
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.8169642857142857
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.2962962962962963
# all_train_score_W': 0.3941798941798942
# test_score_W0 : 0.3117283950617284
# test_score_W': 0.39197530864197533
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5965608465608465
# right_data0_score_W0 1.0
# error_data0_score_W1 0.49889135254988914
# error_data0_score_W0 0.352549889135255
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.7475409836065574
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.40343915343915343
# all_train_score_W': 0.4973544973544973
# test_score_W0 : 0.42592592592592593
# test_score_W': 0.48148148148148145
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.5132275132275133
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5360824742268041
# error_data0_score_W0 0.3711340206185567
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.75
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.48677248677248675
# all_train_score_W': 0.5701058201058201
# test_score_W0 : 0.5
# test_score_W': 0.5709876543209876
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.38756613756613756
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6962457337883959
# error_data0_score_W0 0.4709897610921502
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.7948164146868251
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6124338624338624
# all_train_score_W': 0.6917989417989417
# test_score_W0 : 0.5524691358024691
# test_score_W': 0.6481481481481481
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.376984126984127
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7333333333333333
# error_data0_score_W0 0.48771929824561405
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.8683651804670913
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.623015873015873
# all_train_score_W': 0.746031746031746
# test_score_W0 : 0.6265432098765432
# test_score_W': 0.7037037037037037
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3333333333333333
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7817460317460317
# error_data0_score_W0 0.43253968253968256
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.8353174603174603
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6666666666666666
# all_train_score_W': 0.7566137566137566
# test_score_W0 : 0.6265432098765432
# test_score_W': 0.7222222222222222
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.31613756613756616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8284518828451883
# error_data0_score_W0 0.49372384937238495
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.8820116054158608
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6838624338624338
# all_train_score_W': 0.8055555555555556
# test_score_W0 : 0.6327160493827161
# test_score_W': 0.7592592592592593
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.291005291005291
# right_data0_score_W0 1.0
# error_data0_score_W1 0.85
# error_data0_score_W0 0.55
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.8302238805970149
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.708994708994709
# all_train_score_W': 0.7962962962962963
# test_score_W0 : 0.6512345679012346
# test_score_W': 0.7993827160493827
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2751322751322751
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8557692307692307
# error_data0_score_W0 0.4855769230769231
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.8704379562043796
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7248677248677249
# all_train_score_W': 0.8306878306878307
# test_score_W0 : 0.6975308641975309
# test_score_W': 0.7839506172839507
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.21957671957671956
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8975903614457831
# error_data0_score_W0 0.5120481927710844
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8898305084745762
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7804232804232805
# all_train_score_W': 0.876984126984127
# test_score_W0 : 0.7407407407407407
# test_score_W': 0.8641975308641975
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2222222222222222
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9583333333333334
# error_data0_score_W0 0.5773809523809523
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.9336734693877551
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7777777777777778
# all_train_score_W': 0.9166666666666666
# test_score_W0 : 0.7376543209876543
# test_score_W': 0.9228395061728395
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.22486772486772486
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9470588235294117
# error_data0_score_W0 0.5117647058823529
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.9129692832764505
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7751322751322751
# all_train_score_W': 0.9047619047619048
# test_score_W0 : 0.6944444444444444
# test_score_W': 0.8549382716049383
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.23941798941798942
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9779005524861878
# error_data0_score_W0 0.49171270718232046
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.9043478260869565
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7605820105820106
# all_train_score_W': 0.906084656084656
# test_score_W0 : 0.7222222222222222
# test_score_W': 0.9166666666666666
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.2777777777777778
# ...
# all_train_score_W': 0.8637566137566137
# test_score_W0 : 0.7222222222222222
# test_score_W': 0.8549382716049383
# neuron unit number: 192
# *******************
#
# Error Data percentage 0.21164021164021163
# right_data0_score_W0 1.0
# error_data0_score_W1 0.95625
# error_data0_score_W0 0.49375
# combinedweight shape 0: (384, 80)
# right_data0_score_W' 0.8741610738255033
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7883597883597884
# all_train_score_W': 0.8875661375661376
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8672839506172839
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.2671957671957672
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9207920792079208
# error_data0_score_W0 0.41089108910891087
# combinedweight shape 0: (400, 80)
# right_data0_score_W' 0.9187725631768953
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7328042328042328
# all_train_score_W': 0.9007936507936508
# test_score_W0 : 0.7314814814814815
# test_score_W': 0.8703703703703703
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.21428571428571427
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9444444444444444
# error_data0_score_W0 0.5740740740740741
# combinedweight shape 0: (416, 80)
# right_data0_score_W' 0.9191919191919192
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7857142857142857
# all_train_score_W': 0.9153439153439153
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.904320987654321
# neuron unit number: 216
# *******************
#
# Error Data percentage 0.1917989417989418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9724137931034482
# error_data0_score_W0 0.4482758620689655
# combinedweight shape 0: (432, 80)
# right_data0_score_W' 0.8756137479541735
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8082010582010583
# all_train_score_W': 0.8862433862433863
# test_score_W0 : 0.7808641975308642
# test_score_W': 0.8734567901234568
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.29894179894179895
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8893805309734514
# error_data0_score_W0 0.4469026548672566
# combinedweight shape 0: (448, 80)
# right_data0_score_W' 0.8905660377358491
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.701058201058201
# all_train_score_W': 0.8544973544973545
# test_score_W0 : 0.6604938271604939
# test_score_W': 0.8148148148148148
# neuron unit number: 232
# *******************
#
# Error Data percentage 0.2804232804232804
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8726415094339622
# error_data0_score_W0 0.4528301886792453
# combinedweight shape 0: (464, 80)
# right_data0_score_W' 0.9044117647058824
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7195767195767195
# all_train_score_W': 0.8743386243386243
# test_score_W0 : 0.6728395061728395
# test_score_W': 0.8549382716049383
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.15873015873015872
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9416666666666667
# error_data0_score_W0 0.6166666666666667
# combinedweight shape 0: (480, 80)
# right_data0_score_W' 0.8805031446540881
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8412698412698413
# all_train_score_W': 0.8756613756613757
# test_score_W0 : 0.7962962962962963
# test_score_W': 0.8333333333333334
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6825396825396826
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4321705426356589
# error_data0_score_W0 0.34108527131782945
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.9208333333333333
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.31746031746031744
# all_train_score_W': 0.4060846560846561
# test_score_W0 : 0.31790123456790126
# test_score_W': 0.41358024691358025
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.6124338624338624
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4946004319654428
# error_data0_score_W0 0.3369330453563715
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.863481228668942
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.38756613756613756
# all_train_score_W': 0.544973544973545
# test_score_W0 : 0.3888888888888889
# test_score_W': 0.5154320987654321
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.4933862433862434
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6675603217158177
# error_data0_score_W0 0.42359249329758714
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.8302872062663186
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5066137566137566
# all_train_score_W': 0.656084656084656
# test_score_W0 : 0.46296296296296297
# test_score_W': 0.6111111111111112
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.4470899470899471
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6775147928994083
# error_data0_score_W0 0.378698224852071
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.8253588516746412
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5529100529100529
# all_train_score_W': 0.6759259259259259
# test_score_W0 : 0.5401234567901234
# test_score_W': 0.6419753086419753
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.3637566137566138
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7527272727272727
# error_data0_score_W0 0.3927272727272727
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.8336798336798337
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6362433862433863
# all_train_score_W': 0.7513227513227513
# test_score_W0 : 0.5925925925925926
# test_score_W': 0.6820987654320988
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.34523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7739463601532567
# error_data0_score_W0 0.4099616858237548
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.8303030303030303
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6547619047619048
# all_train_score_W': 0.7645502645502645
# test_score_W0 : 0.6419753086419753
# test_score_W': 0.75
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.3187830687830688
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8464730290456431
# error_data0_score_W0 0.4896265560165975
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.9048543689320389
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6812169312169312
# all_train_score_W': 0.8201058201058201
# test_score_W0 : 0.6419753086419753
# test_score_W': 0.8055555555555556
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.291005291005291
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8181818181818182
# error_data0_score_W0 0.42272727272727273
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.9104477611940298
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.708994708994709
# all_train_score_W': 0.8611111111111112
# test_score_W0 : 0.6697530864197531
# test_score_W': 0.8148148148148148
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.28835978835978837
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8899082568807339
# error_data0_score_W0 0.43577981651376146
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.8903345724907064
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7116402116402116
# all_train_score_W': 0.8571428571428571
# test_score_W0 : 0.6944444444444444
# test_score_W': 0.7962962962962963
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.2526455026455027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.900523560209424
# error_data0_score_W0 0.5026178010471204
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8973451327433628
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7473544973544973
# all_train_score_W': 0.8716931216931217
# test_score_W0 : 0.7191358024691358
# test_score_W': 0.8055555555555556
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.26322751322751325
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9296482412060302
# error_data0_score_W0 0.4221105527638191
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.8850987432675045
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7367724867724867
# all_train_score_W': 0.8677248677248677
# test_score_W0 : 0.6697530864197531
# test_score_W': 0.8395061728395061
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.26455026455026454
# right_data0_score_W0 1.0
# error_data0_score_W1 0.93
# error_data0_score_W0 0.515
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.8884892086330936
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7354497354497355
# all_train_score_W': 0.8597883597883598
# test_score_W0 : 0.7129629629629629
# test_score_W': 0.8271604938271605
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.2857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9259259259259259
# error_data0_score_W0 0.49074074074074076
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8981481481481481
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7142857142857143
# all_train_score_W': 0.8875661375661376
# test_score_W0 : 0.7160493827160493
# test_score_W': 0.8333333333333334
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.2698412698412698
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9019607843137255
# error_data0_score_W0 0.47549019607843135
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.8605072463768116
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7301587301587301
# all_train_score_W': 0.8505291005291006
# test_score_W0 : 0.6759259259259259
# test_score_W': 0.7962962962962963
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.24735449735449735
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9358288770053476
# error_data0_score_W0 0.5294117647058824
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.9191564147627417
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7526455026455027
# all_train_score_W': 0.9047619047619048
# test_score_W0 : 0.7253086419753086
# test_score_W': 0.8641975308641975
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.2843915343915344
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8418604651162791
# error_data0_score_W0 0.4604651162790698
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8687615526802218
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7156084656084656
# all_train_score_W': 0.8240740740740741
# test_score_W0 : 0.6851851851851852
# test_score_W': 0.7962962962962963
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.24867724867724866
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9042553191489362
# error_data0_score_W0 0.5478723404255319
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.9119718309859155
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7513227513227513
# all_train_score_W': 0.9007936507936508
# test_score_W0 : 0.7067901234567902
# test_score_W': 0.9074074074074074
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.2751322751322751
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8846153846153846
# error_data0_score_W0 0.4519230769230769
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.8941605839416058
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7248677248677249
# all_train_score_W': 0.8637566137566137
# test_score_W0 : 0.7129629629629629
# test_score_W': 0.8549382716049383
# neuron unit number: 152
# *******************
# Error Data percentage 0.22486772486772486
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9411764705882353
# error_data0_score_W0 0.5941176470588235
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.9027303754266212
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7751322751322751
# all_train_score_W': 0.8902116402116402
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.8611111111111112
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.18518518518518517
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9785714285714285
# error_data0_score_W0 0.5142857142857142
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.8993506493506493
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8148148148148148
# all_train_score_W': 0.9021164021164021
# test_score_W0 : 0.7530864197530864
# test_score_W': 0.8827160493827161
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.14682539682539683
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9369369369369369
# error_data0_score_W0 0.5585585585585585
# combinedweight shape 0: (336, 80)
# right_data0_score_W' 0.9085271317829458
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8531746031746031
# all_train_score_W': 0.8981481481481481
# test_score_W0 : 0.808641975308642
# test_score_W': 0.8580246913580247
# neuron unit number: 176
# *******************
#
# Error Data percentage 0.24603174603174602
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8870967741935484
# error_data0_score_W0 0.521505376344086
# combinedweight shape 0: (352, 80)
# right_data0_score_W' 0.8771929824561403
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.753968253968254
# all_train_score_W': 0.8677248677248677
# test_score_W0 : 0.6975308641975309
# test_score_W': 0.8302469135802469
# neuron unit number: 184
# *******************
#
# Error Data percentage 0.19047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9444444444444444
# error_data0_score_W0 0.6458333333333334
# combinedweight shape 0: (368, 80)
# right_data0_score_W' 0.8921568627450981
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8095238095238095
# all_train_score_W': 0.8955026455026455
# test_score_W0 : 0.7623456790123457
# test_score_W': 0.8827160493827161
# neuron unit number: 192
# *******************
#
# Error Data percentage 0.19576719576719576
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9662162162162162
# error_data0_score_W0 0.5135135135135135
# combinedweight shape 0: (384, 80)
# right_data0_score_W' 0.9029605263157895
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8042328042328042
# all_train_score_W': 0.8955026455026455
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.8549382716049383
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.23015873015873015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9425287356321839
# error_data0_score_W0 0.4942528735632184
# combinedweight shape 0: (400, 80)
# right_data0_score_W' 0.8831615120274914
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7698412698412699
# all_train_score_W': 0.8955026455026455
# test_score_W0 : 0.7592592592592593
# test_score_W': 0.8734567901234568
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.18783068783068782
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9647887323943662
# error_data0_score_W0 0.4647887323943662
# combinedweight shape 0: (416, 80)
# right_data0_score_W' 0.9087947882736156
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8121693121693122
# all_train_score_W': 0.906084656084656
# test_score_W0 : 0.7623456790123457
# test_score_W': 0.8425925925925926
# neuron unit number: 216
# *******************
#
# Error Data percentage 0.18121693121693122
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9927007299270073
# error_data0_score_W0 0.5912408759124088
# combinedweight shape 0: (432, 80)
# right_data0_score_W' 0.8723747980613893
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8187830687830688
# all_train_score_W': 0.873015873015873
# test_score_W0 : 0.7222222222222222
# test_score_W': 0.8333333333333334
# neuron unit number: 224
# *******************
