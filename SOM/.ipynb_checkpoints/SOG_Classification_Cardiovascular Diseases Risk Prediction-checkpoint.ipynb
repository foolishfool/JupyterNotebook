# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv = csv.sample(int(csv.shape[0]*0.01))


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
csv_training = csv
dataread.initializedataset(csv,csv_training,csv_test,"General_Health")
# Out:
# self.continuous_feature_num 7
# self.data_discrete_indexes ['Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex', 'Age_Category', 'Smoking_History']

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5

#features = 2 #[0,1,2,3,5,6,7,8,9,10]

features_chosen =[0,1,2,3,5,6,7,8,9,10]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
# Out:
# Neuron number: 5
# test_score_W0_p0.37261618758377746
# test_score_W0_n 0.012318695772995214
# test_score_W0_a  0.009546699712696359
# weight_JSD (5, 62)
# test_score_W_combine_p 0.3726453275657754
# test_score_W_combine_n 0.01232982773150999
# test_score_W_combine_a 0.009550563280489189
# Neuron number: 10
# test_score_W0_p0.3744131531403187
# test_score_W0_n 0.013502891070874413
# test_score_W0_a  0.011130017665992592
# weight_JSD (10, 117)
# test_score_W_combine_p 0.37879386376734636
# test_score_W_combine_n 0.01763941632789624
# test_score_W_combine_a 0.015088700994841267
# Neuron number: 15
# test_score_W0_p0.37695156934991936
# test_score_W0_n 0.014918016405752865
# test_score_W0_a  0.015144212580546728
# weight_JSD (15, 172)
# test_score_W_combine_p 0.3809372713320857
# test_score_W_combine_n 0.020987519649662553
# test_score_W_combine_a 0.01833992911468148
# Neuron number: 20
# test_score_W0_p0.3764885674137295
# test_score_W0_n 0.015442254375005899
# test_score_W0_a  0.013526967923345866
# weight_JSD (20, 227)
# test_score_W_combine_p 0.3775894111780971
# test_score_W_combine_n 0.0159723877251788
# test_score_W_combine_a 0.016358251294615003
# Neuron number: 25
# test_score_W0_p0.37980404980994253
# test_score_W0_n 0.018501018291227807
# test_score_W0_a  0.016692887662141918
# weight_JSD (25, 282)
# test_score_W_combine_p 0.38045160496545294
# test_score_W_combine_n 0.02075895486791076
# test_score_W_combine_a 0.016930228626119613
# Neuron number: 30
# test_score_W0_p0.38006630964792426
# test_score_W0_n 0.01838523135745773
# test_score_W0_a  0.01793394148031729
# weight_JSD (30, 337)
# test_score_W_combine_p 0.3803868494499019
# test_score_W_combine_n 0.01915729246232358
# test_score_W_combine_a 0.017587878425730823
# Not good ari !!!!!
# Neuron number: 35
# test_score_W0_p0.3832555187888128
# test_score_W0_n 0.022354863950506676
# test_score_W0_a  0.02017746631748143
# weight_JSD (35, 392)
# test_score_W_combine_p 0.3840196338723151
# test_score_W_combine_n 0.023763118443056532
# test_score_W_combine_a 0.021819009795435055
# Neuron number: 40
# test_score_W0_p0.3855381507119869
# test_score_W0_n 0.025189636870018024
# test_score_W0_a  0.022578911362063827
# weight_JSD (40, 447)
# test_score_W_combine_p 0.3827795657495127
# test_score_W_combine_n 0.0218659649710722
# test_score_W_combine_a 0.020500841554777743
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 45
# test_score_W0_p0.38182442189513494
# test_score_W0_n 0.02204324845123045
# test_score_W0_a  0.01894082777765641
# weight_JSD (45, 502)
# test_score_W_combine_p 0.38384155620454974
# test_score_W_combine_n 0.023233034777945635
# test_score_W_combine_a 0.021992417238880534
# Neuron number: 50
# test_score_W0_p0.3824169348624269
# test_score_W0_n 0.021972758231461914
# test_score_W0_a  0.0185909806113741
# weight_JSD (50, 557)
# test_score_W_combine_p 0.38443730694761924
# test_score_W_combine_n 0.024644019103026316
# test_score_W_combine_a 0.02242124533213974
# Neuron number: 55
# test_score_W0_p0.38440492918984376
# test_score_W0_n 0.024373395473276386
# test_score_W0_a  0.02120556051719704
# weight_JSD (55, 612)
# test_score_W_combine_p 0.383045063363272
# test_score_W_combine_n 0.023248086626431495
# test_score_W_combine_a 0.01991788584245673
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 60
# test_score_W0_p0.3838739339623252
# test_score_W0_n 0.02153256292375216
# test_score_W0_a  0.01999503340882247
# weight_JSD (60, 667)
# test_score_W_combine_p 0.38558347957287264
# test_score_W_combine_n 0.025611878848601884
# test_score_W_combine_a 0.02198874892060284
# Neuron number: 65
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      12 feature_combination_number = 2
#      13 experiment = experiment.Experiment()
# ---> 14 experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
#
# File C:\JupyterDoc\SOM\experiment.py:171, in Experiment.UTtest_Discrete(self, dataread, class_num, scope_num, interval, features_choosen, feature_combination_number)
#     169 while y <= scope_num:
#     170     print("Neuron number: {}".format(y))
# --> 171     self.InitializedExperimentDataList(
#     172                             dataread,
#     173                             y,
#     174                             all_test_score_W0_p,
#     175                             all_test_score_W0_n,
#     176                             all_test_score_W0_a,
#     177                             all_test_score_W_combine_p ,
#     178                             all_test_score_W_combine_n ,
#     179                             all_test_score_W_combine_a ,
#     180                             features_choosen,feature_combination_number
#     181                             )
#     182     y =y + interval
#     183     if(y<= scope_num):
#
# File C:\JupyterDoc\SOM\experiment.py:136, in Experiment.InitializedExperimentDataList(self, dataread, y, test_score_W0_p, test_score_W0_n, atest_score_W0_a, test_score_W_combine_p, test_score_W_combine_n, test_score_W_combine_a, features_choosen, feature_combination_number)
#     116     som_total_discrete = som_continusous
#     120 optimize_W = CDSOM.CDSOM(som,
#     121          som_continusous,
#     122          som_discrete_original,
#    (...)
#     132          dataread.label_train,
#     133          dataread.label_test)
# --> 136 optimize_W.do_DOSOM(features_choosen,feature_combination_number)
#     141 test_score_W0_p.append(optimize_W.test_score_W0_p)
#     142 test_score_W0_n.append(optimize_W.test_score_W0_n)
#
# File C:\JupyterDoc\SOM\CDSOM.py:1431, in CDSOM.do_DOSOM(self, all_feature_column, features_chosoen)
#    1428 self.getEachNeuronProbabilityOfEachFeatureValue_fuzzy(predicted_clusters_indexes)
#    1430 #print(f"weight_original {weight_original}")
# -> 1431 self.test_discrete_W0_predicted_label = self.som.predict(self.data_test_all,weight_original)
#    1433 predicted_clusters_indexes = self.get_indices_and_data_in_predicted_clusters(self.som.weights0.shape[0], self.test_discrete_W0_predicted_label)
#    1434 self.getLabelMapping( self.get_mapped_class_in_clusters(predicted_clusters_indexes,self.test_label_all) ,0)
#
# File C:\JupyterDoc\SOM\newSom.py:578, in SOM.predict(self, X, newWeights)
#     575 assert len(X.shape) == 2, f'X should have two dimensions, not {len(X.shape)}'
#     576 assert X.shape[1] == self.dim, f'This SOM has dimesnion {self.dim}. Received input with dimension {X.shape[1]}'
# --> 578 labels = np.array([self._find_bmu(x,newWeights) for x in X])
#     579 #print(f" labels {labels}")
#     580 return labels
#
# File C:\JupyterDoc\SOM\newSom.py:578, in <listcomp>(.0)
#     575 assert len(X.shape) == 2, f'X should have two dimensions, not {len(X.shape)}'
#     576 assert X.shape[1] == self.dim, f'This SOM has dimesnion {self.dim}. Received input with dimension {X.shape[1]}'
# --> 578 labels = np.array([self._find_bmu(x,newWeights) for x in X])
#     579 #print(f" labels {labels}")
#     580 return labels
#
# File C:\JupyterDoc\SOM\newSom.py:129, in SOM._find_bmu(self, x, newWeights, showlog)
#     123  x_stack = np.stack([x]*(newWeights.shape[0]), axis=0)
#     124  # Calculate distance between x and each weight  ， it use the norm to represent the distance of the concept of vector x_stack - newWeights
#     125 # if showlog:
#     126  #    print("x {} x_stack{}  newWeights {} m {} n{} dim{}".format(x, x_stack, newWeights, self.m,self.n,self.dim))
#     127 # if x_stack.shape != newWeights.shape:
#     128  #    print("x {} x_stack{}  newWeights {} m {} n{} dim{}".format(x, x_stack, newWeights, self.m,self.n,self.dim))
# --> 129  distance = np.linalg.norm((x_stack - newWeights).astype(float), axis=1)
#     130  # Find index of best matching unit
#     131  return np.argmin(distance)
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\numpy\linalg\linalg.py:2546, in norm(x, ord, axis, keepdims)
#    2543     return add.reduce(abs(x), axis=axis, keepdims=keepdims)
#    2544 elif ord is None or ord == 2:
#    2545     # special case for speedup
# -> 2546     s = (x.conj() * x).real
#    2547     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2548 # None of the str-type keywords for ord ('fro', 'nuc')
#    2549 # are valid for vectors
#
# KeyboardInterrupt:
