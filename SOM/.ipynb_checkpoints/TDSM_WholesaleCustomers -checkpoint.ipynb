# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Data_User_Modeling_Dataset_Hamdi Tolga KAHRAMAN.csv")
dataread.stringToIntDataUserModelDataSet(csv," UNS")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test," UNS")

# %%
# local scope2
scoretype = 0
scope_num = 30
class_num = 4
dim_num = 5
unstable_repeat_num = 30


unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.43646408839779005
# right_data0_score_W0 1.0
# error_data0_score_W1 0.569620253164557
# error_data0_score_W0 0.569620253164557
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.8137254901960784
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.56353591160221
# all_train_score_W': 0.5469613259668509
# test_score_W0 : 0.5324675324675324
# test_score_W': 0.5064935064935064
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.43646408839779005
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7341772151898734
# error_data0_score_W0 0.6075949367088608
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.56353591160221
# all_train_score_W': 0.6574585635359116
# test_score_W0 : 0.4805194805194805
# test_score_W': 0.6493506493506493
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.39779005524861877
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7222222222222222
# error_data0_score_W0 0.6944444444444444
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.8899082568807339
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6022099447513812
# all_train_score_W': 0.6850828729281768
# test_score_W0 : 0.5194805194805194
# test_score_W': 0.5974025974025974
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.39779005524861877
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7361111111111112
# error_data0_score_W0 0.6527777777777778
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.8348623853211009
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6022099447513812
# all_train_score_W': 0.6961325966850829
# test_score_W0 : 0.5324675324675324
# test_score_W': 0.5974025974025974
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9285714285714286
# error_data0_score_W0 0.625
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.856
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6906077348066298
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.4805194805194805
# test_score_W': 0.6103896103896104
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.2541436464088398
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8043478260869565
# error_data0_score_W0 0.6956521739130435
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.7703703703703704
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7458563535911602
# all_train_score_W': 0.712707182320442
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6623376623376623
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.6964285714285714
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.816
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6906077348066298
# all_train_score_W': 0.7458563535911602
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5194805194805194
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.3314917127071823
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8
# error_data0_score_W0 0.7833333333333333
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.8264462809917356
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6685082872928176
# all_train_score_W': 0.712707182320442
# test_score_W0 : 0.5714285714285714
# test_score_W': 0.5714285714285714
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.32044198895027626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8275862068965517
# error_data0_score_W0 0.7758620689655172
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.8292682926829268
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6795580110497238
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.6753246753246753
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8653846153846154
# error_data0_score_W0 0.8461538461538461
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.8294573643410853
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5454545454545454
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.292817679558011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8679245283018868
# error_data0_score_W0 0.660377358490566
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.7734375
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7071823204419889
# all_train_score_W': 0.7016574585635359
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5584415584415584
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9302325581395349
# error_data0_score_W0 0.6744186046511628
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.8188405797101449
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 0.7734806629834254
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5974025974025974
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.24861878453038674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9111111111111111
# error_data0_score_W0 0.6888888888888889
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.8382352941176471
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7513812154696132
# all_train_score_W': 0.8121546961325967
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5194805194805194
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9772727272727273
# error_data0_score_W0 0.6818181818181818
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.8394160583941606
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.7955801104972375
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6623376623376623
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9318181818181818
# error_data0_score_W0 0.6818181818181818
# combinedweight shape 0: (120, 5)
# right_data0_score_W' 0.8540145985401459
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.8232044198895028
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6623376623376623
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.281767955801105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8627450980392157
# error_data0_score_W0 0.7843137254901961
# combinedweight shape 0: (128, 5)
# right_data0_score_W' 0.7846153846153846
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7182320441988951
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.6363636363636364
# neuron unit number: 68
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9545454545454546
# error_data0_score_W0 0.75
# combinedweight shape 0: (136, 5)
# right_data0_score_W' 0.7737226277372263
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.7292817679558011
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.6103896103896104
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.875
# combinedweight shape 0: (144, 5)
# right_data0_score_W' 0.8297872340425532
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 0.8011049723756906
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5584415584415584
# neuron unit number: 76
# *******************
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.926829268292683
# error_data0_score_W0 0.6341463414634146
# combinedweight shape 0: (152, 5)
# right_data0_score_W' 0.8571428571428571
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 0.8121546961325967
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6493506493506493
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8181818181818182
# error_data0_score_W0 0.7272727272727273
# combinedweight shape 0: (160, 5)
# right_data0_score_W' 0.8248175182481752
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.7845303867403315
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6233766233766234
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.19889502762430938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9166666666666666
# error_data0_score_W0 0.75
# combinedweight shape 0: (168, 5)
# right_data0_score_W' 0.8137931034482758
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8011049723756906
# all_train_score_W': 0.7955801104972375
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6363636363636364
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.1878453038674033
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8823529411764706
# error_data0_score_W0 0.6176470588235294
# combinedweight shape 0: (176, 5)
# right_data0_score_W' 0.8163265306122449
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8121546961325967
# all_train_score_W': 0.7734806629834254
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6623376623376623
# neuron unit number: 92
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8918918918918919
# error_data0_score_W0 0.7567567567567568
# combinedweight shape 0: (184, 5)
# right_data0_score_W' 0.7569444444444444
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5844155844155844
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9166666666666666
# error_data0_score_W0 0.7291666666666666
# combinedweight shape 0: (192, 5)
# right_data0_score_W' 0.7819548872180451
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7348066298342542
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.5714285714285714
# test_score_W': 0.5584415584415584
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.12154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.6818181818181818
# combinedweight shape 0: (200, 5)
# right_data0_score_W' 0.8050314465408805
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8784530386740331
# all_train_score_W': 0.8232044198895028
# test_score_W0 : 0.5324675324675324
# test_score_W': 0.5064935064935064
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.18232044198895028
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9090909090909091
# error_data0_score_W0 0.7878787878787878
# combinedweight shape 0: (208, 5)
# right_data0_score_W' 0.8445945945945946
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8176795580110497
# all_train_score_W': 0.8287292817679558
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6233766233766234
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 0.6904761904761905
# combinedweight shape 0: (216, 5)
# right_data0_score_W' 0.7913669064748201
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.7734806629834254
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6493506493506493
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.17679558011049723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96875
# error_data0_score_W0 0.78125
# combinedweight shape 0: (224, 5)
# right_data0_score_W' 0.7718120805369127
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8232044198895028
# all_train_score_W': 0.7845303867403315
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5584415584415584
# neuron unit number: 116
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.6829268292682927
# combinedweight shape 0: (232, 5)
# right_data0_score_W' 0.8
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 0.7955801104972375
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6883116883116883
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.17679558011049723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96875
# error_data0_score_W0 0.75
# combinedweight shape 0: (240, 5)
# right_data0_score_W' 0.8389261744966443
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8232044198895028
# all_train_score_W': 0.8397790055248618
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5194805194805194
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.56353591160221
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6372549019607843
# error_data0_score_W0 0.46078431372549017
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.759493670886076
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.43646408839779005
# all_train_score_W': 0.46408839779005523
# test_score_W0 : 0.38961038961038963
# test_score_W': 0.4025974025974026
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.43646408839779005
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5569620253164557
# error_data0_score_W0 0.6455696202531646
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.8137254901960784
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.56353591160221
# all_train_score_W': 0.6353591160220995
# test_score_W0 : 0.4935064935064935
# test_score_W': 0.4805194805194805
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.39226519337016574
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6901408450704225
# error_data0_score_W0 0.6619718309859155
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.7363636363636363
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6077348066298343
# all_train_score_W': 0.6022099447513812
# test_score_W0 : 0.5064935064935064
# test_score_W': 0.5064935064935064
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.32044198895027626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6896551724137931
# error_data0_score_W0 0.6206896551724138
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.8373983739837398
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6795580110497238
# all_train_score_W': 0.6961325966850829
# test_score_W0 : 0.5064935064935064
# test_score_W': 0.5454545454545454
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.35911602209944754
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8307692307692308
# error_data0_score_W0 0.7230769230769231
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.7413793103448276
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6408839779005525
# all_train_score_W': 0.6629834254143646
# test_score_W0 : 0.5064935064935064
# test_score_W': 0.5584415584415584
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.2983425414364641
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8518518518518519
# error_data0_score_W0 0.7407407407407407
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.7795275590551181
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7016574585635359
# all_train_score_W': 0.7513812154696132
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5714285714285714
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.3149171270718232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8070175438596491
# error_data0_score_W0 0.7543859649122807
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.782258064516129
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6850828729281768
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5714285714285714
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.32044198895027626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.896551724137931
# error_data0_score_W0 0.7413793103448276
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.7642276422764228
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6795580110497238
# all_train_score_W': 0.6961325966850829
# test_score_W0 : 0.4935064935064935
# test_score_W': 0.5324675324675324
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8653846153846154
# error_data0_score_W0 0.6730769230769231
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.7906976744186046
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.7402597402597403
# test_score_W': 0.6493506493506493
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.6785714285714286
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.88
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6906077348066298
# all_train_score_W': 0.7845303867403315
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6623376623376623
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.24861878453038674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9111111111111111
# error_data0_score_W0 0.6888888888888889
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.8088235294117647
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7513812154696132
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5454545454545454
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.2541436464088398
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9347826086956522
# error_data0_score_W0 0.717391304347826
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.7037037037037037
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7458563535911602
# all_train_score_W': 0.6850828729281768
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5974025974025974
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.19889502762430938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8611111111111112
# error_data0_score_W0 0.5833333333333334
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.7793103448275862
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8011049723756906
# all_train_score_W': 0.7513812154696132
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6363636363636364
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9767441860465116
# error_data0_score_W0 0.7209302325581395
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.8115942028985508
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 0.8066298342541437
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5584415584415584
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8076923076923077
# error_data0_score_W0 0.5961538461538461
# combinedweight shape 0: (120, 5)
# right_data0_score_W' 0.8914728682170543
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5974025974025974
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9302325581395349
# error_data0_score_W0 0.6744186046511628
# combinedweight shape 0: (128, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 0.8066298342541437
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5454545454545454
# neuron unit number: 68
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9387755102040817
# error_data0_score_W0 0.7551020408163265
# combinedweight shape 0: (136, 5)
# right_data0_score_W' 0.8181818181818182
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.6493506493506493
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9523809523809523
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (144, 5)
# right_data0_score_W' 0.8201438848920863
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.8066298342541437
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6233766233766234
# neuron unit number: 76
# *******************
# Error Data percentage 0.20994475138121546
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9473684210526315
# error_data0_score_W0 0.7631578947368421
# combinedweight shape 0: (152, 5)
# right_data0_score_W' 0.7902097902097902
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7900552486187845
# all_train_score_W': 0.8011049723756906
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5454545454545454
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.20994475138121546
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9736842105263158
# error_data0_score_W0 0.7631578947368421
# combinedweight shape 0: (160, 5)
# right_data0_score_W' 0.8181818181818182
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7900552486187845
# all_train_score_W': 0.8453038674033149
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5454545454545454
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9772727272727273
# error_data0_score_W0 0.7727272727272727
# combinedweight shape 0: (168, 5)
# right_data0_score_W' 0.7372262773722628
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.7458563535911602
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.5194805194805194
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2541436464088398
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8478260869565217
# error_data0_score_W0 0.6521739130434783
# combinedweight shape 0: (176, 5)
# right_data0_score_W' 0.8222222222222222
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7458563535911602
# all_train_score_W': 0.7900552486187845
# test_score_W0 : 0.5454545454545454
# test_score_W': 0.5454545454545454
# neuron unit number: 92
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9285714285714286
# error_data0_score_W0 0.6904761904761905
# combinedweight shape 0: (184, 5)
# right_data0_score_W' 0.8057553956834532
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.8066298342541437
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6363636363636364
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9285714285714286
# error_data0_score_W0 0.8571428571428571
# combinedweight shape 0: (192, 5)
# right_data0_score_W' 0.7338129496402878
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.7182320441988951
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5064935064935064
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9523809523809523
# error_data0_score_W0 0.7142857142857143
# combinedweight shape 0: (200, 5)
# right_data0_score_W' 0.7913669064748201
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.7845303867403315
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6363636363636364
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.1878453038674033
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.8529411764705882
# combinedweight shape 0: (208, 5)
# right_data0_score_W' 0.7891156462585034
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8121546961325967
# all_train_score_W': 0.8121546961325967
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.6493506493506493
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.972972972972973
# error_data0_score_W0 0.8378378378378378
# combinedweight shape 0: (216, 5)
# right_data0_score_W' 0.8541666666666666
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 0.8453038674033149
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.6363636363636364
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9583333333333334
# error_data0_score_W0 0.625
# combinedweight shape 0: (224, 5)
# right_data0_score_W' 0.8571428571428571
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7348066298342542
# all_train_score_W': 0.8287292817679558
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.6233766233766234
# neuron unit number: 116
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.918918918918919
# error_data0_score_W0 0.7837837837837838
# combinedweight shape 0: (232, 5)
# right_data0_score_W' 0.7569444444444444
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5714285714285714
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9459459459459459
# error_data0_score_W0 0.7027027027027027
# combinedweight shape 0: (240, 5)
# right_data0_score_W' 0.8611111111111112
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 0.8453038674033149
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.6233766233766234
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.48066298342541436
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4942528735632184
# error_data0_score_W0 0.5862068965517241
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.776595744680851
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5193370165745856
# all_train_score_W': 0.5248618784530387
# test_score_W0 : 0.4935064935064935
# test_score_W': 0.5324675324675324
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.5082872928176796
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6413043478260869
# error_data0_score_W0 0.5543478260869565
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.7415730337078652
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.49171270718232046
# all_train_score_W': 0.56353591160221
# test_score_W0 : 0.4935064935064935
# test_score_W': 0.5194805194805194
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.4198895027624309
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6447368421052632
# error_data0_score_W0 0.6578947368421053
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.819047619047619
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.580110497237569
# all_train_score_W': 0.6243093922651933
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5584415584415584
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.3425414364640884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7580645161290323
# error_data0_score_W0 0.532258064516129
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.7647058823529411
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6574585635359116
# all_train_score_W': 0.6629834254143646
# test_score_W0 : 0.4675324675324675
# test_score_W': 0.5844155844155844
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.32044198895027626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7758620689655172
# error_data0_score_W0 0.6896551724137931
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.8373983739837398
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6795580110497238
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.6103896103896104
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.34806629834254144
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7936507936507936
# error_data0_score_W0 0.6031746031746031
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.8389830508474576
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6519337016574586
# all_train_score_W': 0.6906077348066298
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5584415584415584
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.8345323741007195
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.5974025974025974
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8461538461538461
# error_data0_score_W0 0.6538461538461539
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.8837209302325582
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.6623376623376623
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8392857142857143
# error_data0_score_W0 0.75
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.808
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6906077348066298
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6493506493506493
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.2983425414364641
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8518518518518519
# error_data0_score_W0 0.6296296296296297
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.7795275590551181
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7016574585635359
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.5324675324675324
# test_score_W': 0.5194805194805194
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.281767955801105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9019607843137255
# error_data0_score_W0 0.6470588235294118
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.8076923076923077
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7182320441988951
# all_train_score_W': 0.7182320441988951
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.5064935064935064
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3259668508287293
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9152542372881356
# error_data0_score_W0 0.7457627118644068
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.8770491803278688
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6740331491712708
# all_train_score_W': 0.8287292817679558
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.6103896103896104
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.20994475138121546
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8421052631578947
# error_data0_score_W0 0.7368421052631579
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.8461538461538461
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7900552486187845
# all_train_score_W': 0.8232044198895028
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5584415584415584
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9272727272727272
# error_data0_score_W0 0.7272727272727273
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.8015873015873016
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.6103896103896104
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9767441860465116
# error_data0_score_W0 0.813953488372093
# combinedweight shape 0: (120, 5)
# right_data0_score_W' 0.8260869565217391
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 0.8397790055248618
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.6233766233766234
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.16574585635359115
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9333333333333333
# error_data0_score_W0 0.7
# combinedweight shape 0: (128, 5)
# right_data0_score_W' 0.7748344370860927
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8342541436464088
# all_train_score_W': 0.7845303867403315
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.6103896103896104
# neuron unit number: 68
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8979591836734694
# error_data0_score_W0 0.673469387755102
# combinedweight shape 0: (136, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.5324675324675324
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8727272727272727
# error_data0_score_W0 0.6909090909090909
# combinedweight shape 0: (144, 5)
# right_data0_score_W' 0.7936507936507936
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 0.7071823204419889
# test_score_W0 : 0.5064935064935064
# test_score_W': 0.6493506493506493
# neuron unit number: 76
# *******************
# Error Data percentage 0.3149171270718232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7543859649122807
# error_data0_score_W0 0.6842105263157895
# combinedweight shape 0: (152, 5)
# right_data0_score_W' 0.8225806451612904
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6850828729281768
# all_train_score_W': 0.7071823204419889
# test_score_W0 : 0.5714285714285714
# test_score_W': 0.6103896103896104
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9047619047619048
# error_data0_score_W0 0.7142857142857143
# combinedweight shape 0: (160, 5)
# right_data0_score_W' 0.8489208633093526
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 0.7955801104972375
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.7142857142857143
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2983425414364641
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8888888888888888
# error_data0_score_W0 0.7222222222222222
# combinedweight shape 0: (168, 5)
# right_data0_score_W' 0.8031496062992126
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7016574585635359
# all_train_score_W': 0.7403314917127072
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.5584415584415584
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8837209302325582
# error_data0_score_W0 0.6976744186046512
# combinedweight shape 0: (176, 5)
# right_data0_score_W' 0.7898550724637681
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 0.7900552486187845
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5844155844155844
# neuron unit number: 92
# *******************
#
# Error Data percentage 0.19889502762430938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9444444444444444
# error_data0_score_W0 0.7222222222222222
# combinedweight shape 0: (184, 5)
# right_data0_score_W' 0.8482758620689655
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8011049723756906
# all_train_score_W': 0.8397790055248618
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.7012987012987013
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9772727272727273
# error_data0_score_W0 0.75
# combinedweight shape 0: (192, 5)
# right_data0_score_W' 0.7591240875912408
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.7900552486187845
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6233766233766234
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9545454545454546
# error_data0_score_W0 0.75
# combinedweight shape 0: (200, 5)
# right_data0_score_W' 0.8394160583941606
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.8066298342541437
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.5844155844155844
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9743589743589743
# error_data0_score_W0 0.7435897435897436
# combinedweight shape 0: (208, 5)
# right_data0_score_W' 0.7464788732394366
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 0.7513812154696132
# test_score_W0 : 0.7272727272727273
# test_score_W': 0.6363636363636364
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.27624309392265195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.86
# error_data0_score_W0 0.66
# combinedweight shape 0: (216, 5)
# right_data0_score_W' 0.7862595419847328
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7237569060773481
# all_train_score_W': 0.6906077348066298
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5844155844155844
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.19337016574585636
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.7142857142857143
# combinedweight shape 0: (224, 5)
# right_data0_score_W' 0.7465753424657534
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8066298342541437
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.5324675324675324
# test_score_W': 0.5064935064935064
# neuron unit number: 116
# *******************
#
# Error Data percentage 0.34806629834254144
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8888888888888888
# error_data0_score_W0 0.8095238095238095
# combinedweight shape 0: (232, 5)
# right_data0_score_W' 0.7372881355932204
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6519337016574586
# all_train_score_W': 0.6850828729281768
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5974025974025974
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2596685082872928
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9148936170212766
# error_data0_score_W0 0.6808510638297872
# combinedweight shape 0: (240, 5)
# right_data0_score_W' 0.8208955223880597
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7403314917127072
# all_train_score_W': 0.8176795580110497
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.6103896103896104
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.4585635359116022
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6265060240963856
# error_data0_score_W0 0.5662650602409639
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.8163265306122449
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5414364640883977
# all_train_score_W': 0.56353591160221
# test_score_W0 : 0.4935064935064935
# test_score_W': 0.45454545454545453
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7291666666666666
# error_data0_score_W0 0.6875
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.7744360902255639
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7348066298342542
# all_train_score_W': 0.6519337016574586
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.5974025974025974
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.39226519337016574
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6197183098591549
# error_data0_score_W0 0.5774647887323944
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.8909090909090909
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6077348066298343
# all_train_score_W': 0.6795580110497238
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5974025974025974
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.39779005524861877
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7777777777777778
# error_data0_score_W0 0.7222222222222222
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.7522935779816514
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6022099447513812
# all_train_score_W': 0.6629834254143646
# test_score_W0 : 0.5064935064935064
# test_score_W': 0.5714285714285714
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.3867403314917127
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8
# error_data0_score_W0 0.7
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.7927927927927928
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6132596685082873
# all_train_score_W': 0.7016574585635359
# test_score_W0 : 0.5064935064935064
# test_score_W': 0.5844155844155844
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8653846153846154
# error_data0_score_W0 0.75
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.7209302325581395
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.7016574585635359
# test_score_W0 : 0.5454545454545454
# test_score_W': 0.5064935064935064
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.3370165745856354
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8688524590163934
# error_data0_score_W0 0.8360655737704918
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.7666666666666667
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6629834254143646
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.5844155844155844
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8909090909090909
# error_data0_score_W0 0.7272727272727273
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.8095238095238095
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.6493506493506493
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8717948717948718
# error_data0_score_W0 0.7435897435897436
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.8309859154929577
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 0.7845303867403315
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5844155844155844
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.7
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.7872340425531915
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 0.7403314917127072
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.5844155844155844
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.27624309392265195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.94
# error_data0_score_W0 0.68
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.8473282442748091
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7237569060773481
# all_train_score_W': 0.8121546961325967
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5844155844155844
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 0.6530612244897959
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 0.8011049723756906
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7272727272727273
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8909090909090909
# error_data0_score_W0 0.6545454545454545
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.6904761904761905
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 0.6850828729281768
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.5714285714285714
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.3149171270718232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8947368421052632
# error_data0_score_W0 0.7543859649122807
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.8387096774193549
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6850828729281768
# all_train_score_W': 0.7955801104972375
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6753246753246753
# ...
#
# Error Data percentage 0.17679558011049723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96875
# error_data0_score_W0 0.78125
# combinedweight shape 0: (232, 5)
# right_data0_score_W' 0.7651006711409396
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8232044198895028
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.5584415584415584
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9487179487179487
# error_data0_score_W0 0.6410256410256411
# combinedweight shape 0: (240, 5)
# right_data0_score_W' 0.795774647887324
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 0.8121546961325967
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.5714285714285714
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.5359116022099447
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7010309278350515
# error_data0_score_W0 0.4639175257731959
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.9880952380952381
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.46408839779005523
# all_train_score_W': 0.5524861878453039
# test_score_W0 : 0.35064935064935066
# test_score_W': 0.45454545454545453
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.44751381215469616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.691358024691358
# error_data0_score_W0 0.6419753086419753
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.78
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5524861878453039
# all_train_score_W': 0.6187845303867403
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.5064935064935064
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.35911602209944754
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6615384615384615
# error_data0_score_W0 0.6
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.8793103448275862
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6408839779005525
# all_train_score_W': 0.7348066298342542
# test_score_W0 : 0.4805194805194805
# test_score_W': 0.6493506493506493
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.3756906077348066
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7205882352941176
# error_data0_score_W0 0.6323529411764706
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.8053097345132744
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6243093922651933
# all_train_score_W': 0.6685082872928176
# test_score_W0 : 0.4805194805194805
# test_score_W': 0.5324675324675324
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 0.6964285714285714
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.784
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6906077348066298
# all_train_score_W': 0.6629834254143646
# test_score_W0 : 0.7532467532467533
# test_score_W': 0.6103896103896104
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.3149171270718232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8596491228070176
# error_data0_score_W0 0.543859649122807
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.782258064516129
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6850828729281768
# all_train_score_W': 0.7458563535911602
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5844155844155844
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8653846153846154
# error_data0_score_W0 0.6538461538461539
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.751937984496124
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.7016574585635359
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.5974025974025974
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.27624309392265195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.88
# error_data0_score_W0 0.68
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.8015267175572519
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7237569060773481
# all_train_score_W': 0.7900552486187845
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6493506493506493
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8363636363636363
# error_data0_score_W0 0.6545454545454545
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.8492063492063492
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.6883116883116883
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.2983425414364641
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.7037037037037037
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.7952755905511811
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7016574585635359
# all_train_score_W': 0.7292817679558011
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.5714285714285714
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8958333333333334
# error_data0_score_W0 0.7291666666666666
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.8120300751879699
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7348066298342542
# all_train_score_W': 0.7955801104972375
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.6103896103896104
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.32044198895027626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.896551724137931
# error_data0_score_W0 0.7068965517241379
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.7886178861788617
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6795580110497238
# all_train_score_W': 0.7292817679558011
# test_score_W0 : 0.5194805194805194
# test_score_W': 0.6233766233766234
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8717948717948718
# error_data0_score_W0 0.717948717948718
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.8098591549295775
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 0.7734806629834254
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.5714285714285714
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8367346938775511
# error_data0_score_W0 0.7755102040816326
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 0.7900552486187845
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6363636363636364
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.292817679558011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9056603773584906
# error_data0_score_W0 0.6415094339622641
# combinedweight shape 0: (120, 5)
# right_data0_score_W' 0.828125
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7071823204419889
# all_train_score_W': 0.7569060773480663
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.6493506493506493
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.292817679558011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8867924528301887
# error_data0_score_W0 0.6415094339622641
# combinedweight shape 0: (128, 5)
# right_data0_score_W' 0.78125
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7071823204419889
# all_train_score_W': 0.7292817679558011
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.6623376623376623
# neuron unit number: 68
# *******************
#
# Error Data percentage 0.2596685082872928
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9148936170212766
# error_data0_score_W0 0.8085106382978723
# combinedweight shape 0: (136, 5)
# right_data0_score_W' 0.835820895522388
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7403314917127072
# all_train_score_W': 0.8121546961325967
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.5324675324675324
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.7435897435897436
# combinedweight shape 0: (144, 5)
# right_data0_score_W' 0.7746478873239436
# Finish one training *********
# 1
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 0.7734806629834254
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.5454545454545454
# neuron unit number: 76
# *******************
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9487179487179487
# error_data0_score_W0 0.7948717948717948
# combinedweight shape 0: (152, 5)
# right_data0_score_W' 0.7676056338028169
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 0.7790055248618785
# test_score_W0 : 0.7532467532467533
# test_score_W': 0.5454545454545454
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9423076923076923
# error_data0_score_W0 0.7692307692307693
# combinedweight shape 0: (160, 5)
# right_data0_score_W' 0.8527131782945736
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 0.8232044198895028
# test_score_W0 : 0.5454545454545454
# test_score_W': 0.6233766233766234
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9387755102040817
# error_data0_score_W0 0.7142857142857143
# combinedweight shape 0: (168, 5)
# right_data0_score_W' 0.7954545454545454
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6363636363636364
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.24861878453038674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9333333333333333
# error_data0_score_W0 0.8444444444444444
# combinedweight shape 0: (176, 5)
# right_data0_score_W' 0.7426470588235294
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7513812154696132
# all_train_score_W': 0.7403314917127072
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5324675324675324
# neuron unit number: 92
# *******************
#
# Error Data percentage 0.2541436464088398
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9347826086956522
# error_data0_score_W0 0.6739130434782609
# combinedweight shape 0: (184, 5)
# right_data0_score_W' 0.8
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7458563535911602
# all_train_score_W': 0.7624309392265194
# test_score_W0 : 0.5324675324675324
# test_score_W': 0.5974025974025974
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8648648648648649
# error_data0_score_W0 0.7837837837837838
# combinedweight shape 0: (192, 5)
# right_data0_score_W' 0.7708333333333334
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 0.7734806629834254
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5974025974025974
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.925
# error_data0_score_W0 0.8
# combinedweight shape 0: (200, 5)
# right_data0_score_W' 0.7659574468085106
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.5974025974025974
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.20994475138121546
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9736842105263158
# error_data0_score_W0 0.8421052631578947
# combinedweight shape 0: (208, 5)
# right_data0_score_W' 0.8461538461538461
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7900552486187845
# all_train_score_W': 0.850828729281768
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6493506493506493
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.1878453038674033
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9705882352941176
# error_data0_score_W0 0.7058823529411765
# combinedweight shape 0: (216, 5)
# right_data0_score_W' 0.891156462585034
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8121546961325967
# all_train_score_W': 0.861878453038674
# test_score_W0 : 0.5974025974025974
# test_score_W': 0.5454545454545454
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9459459459459459
# error_data0_score_W0 0.8108108108108109
# combinedweight shape 0: (224, 5)
# right_data0_score_W' 0.8402777777777778
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 0.8066298342541437
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.7012987012987013
# neuron unit number: 116
# *******************
#
# Error Data percentage 0.20994475138121546
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9736842105263158
# error_data0_score_W0 0.7894736842105263
# combinedweight shape 0: (232, 5)
# right_data0_score_W' 0.8881118881118881
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7900552486187845
# all_train_score_W': 0.8784530386740331
# test_score_W0 : 0.5584415584415584
# test_score_W': 0.5324675324675324
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2430939226519337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9090909090909091
# error_data0_score_W0 0.7045454545454546
# combinedweight shape 0: (240, 5)
# right_data0_score_W' 0.7956204379562044
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7569060773480663
# all_train_score_W': 0.7679558011049724
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.5844155844155844
#         Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   900.0  0.602828  0.066163  0.002205   0.598500  0.607157
# 1  test_score_W'   900.0  0.596248  0.051094  0.001703   0.592906  0.599591
# 2       combined  1800.0  0.599538  0.059186  0.001395   0.596802  0.602274
#                               Independent t-test    results
# 0  Difference (test_score_W0 - test_score_W') =      0.0066
# 1                          Degrees of freedom =   1798.0000
# 2                                           t =      2.3614
# 3                       Two side test p value =      0.0183
# 4                      Difference < 0 p value =      0.9908
# 5                      Difference > 0 p value =      0.0092
# 6                                   Cohen's d =      0.1113
# 7                                   Hedge's g =      0.1113
# 8                               Glass's delta =      0.0995
# 9                                 Pearson's r =      0.0556
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=2.36141922448655, pvalue=0.990844373171156)
