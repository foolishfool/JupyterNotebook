# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Food Waste data and research.csv",encoding='latin-1')
csv = csv.drop(columns=['Source'])
#csv_original_encode = csv

#dataread.hash_encoding(csv_original_encode,["Country","Region"])

dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Confidence in estimate")
dataread.label_encoding(csv,"Region")



                                 
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv,csv_training,csv_test,"Confidence in estimate")
# Out:
# self.continuous_feature_num 7
# self.data_discrete_indexes ['Retail estimate (kg/capita/year)', 'Food service estimate (kg/capita/year)', 'Region']

# %%
#SVM
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

features =[1]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 7
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 12
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 17
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 22
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 27
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 32
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 37
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 42
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 47
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 57
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 62
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 67
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 72
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 77
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 82
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 87
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 92
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# neuron unit number: 97
# accuracy_score_orignial 0.625
# recall_score_original 0.625
# precision_score_original 0.390625
# f1_score_original 0.4807692307692308
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.625
# precision_score_sog 0.390625
# f1_score_sog 0.4807692307692308
# all_accuracy_score_original mean 0.625
# all_recall_score_original mean 0.625
# all_precision_score_original mean 0.390625
# all_f1_score_original mean 0.48076923076923067
# all_accuracy_score_sog mean 0.625
# all_recall_score_sog mean 0.625
# all_precision_score_sog mean 0.390625
# all_f1_score_sog mean 0.48076923076923067
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N   Mean   SD   SE  95% Conf.  Interval
# 0  all_accuracy_score_original  20.0  0.625  0.0  0.0        NaN       NaN
# 1       all_accuracy_score_sog  20.0  0.625  0.0  0.0        NaN       NaN
# 2                     combined  40.0  0.625  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...      0.0
# 1                              Degrees of freedom =      38.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Recall Score T-Test
#                     Variable     N   Mean   SD   SE  95% Conf.  Interval
# 0  all_recall_score_original  20.0  0.625  0.0  0.0        NaN       NaN
# 1       all_recall_score_sog  20.0  0.625  0.0  0.0        NaN       NaN
# 2                   combined  40.0  0.625  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...      0.0
# 1                              Degrees of freedom =      38.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Precision Score T-Test
#                        Variable     N      Mean   SD   SE  95% Conf.  Interval
# 0  all_precision_score_original  20.0  0.390625  0.0  0.0        NaN       NaN
# 1       all_precision_score_sog  20.0  0.390625  0.0  0.0        NaN       NaN
# 2                      combined  40.0  0.390625  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...      0.0
# 1                              Degrees of freedom =      38.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.480769  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.480769  1.139065e-16  2.547026e-17
# 2               combined  40.0  0.480769  5.621833e-17  8.888898e-18
#
#    95% Conf.  Interval
# 0   0.480769  0.480769
# 1   0.480769  0.480769
# 2   0.480769  0.480769
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...      0.0
# 1                              Degrees of freedom =      38.0
# 2                                               t =       0.0
# 3                           Two side test p value =       1.0
# 4                          Difference < 0 p value =       0.5
# 5                          Difference > 0 p value =       0.5
# 6                                       Cohen's d =       0.0
# 7                                       Hedge's g =       0.0
# 8                                  Glass's delta1 =       0.0
# 9                                Point-Biserial r =       0.0
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#Linear Discriminant Analysis 

import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 4
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.45999999999999996
# f1_score_sog 0.4782608695652174
# neuron unit number: 6
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 8
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 10
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 12
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 14
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 16
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 18
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 20
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 22
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 24
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 26
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 28
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 30
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 32
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 34
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 36
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 38
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 40
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 42
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 44
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 46
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 48
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.46875
# f1_score_sog 0.48333333333333334
# neuron unit number: 50
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 54
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 56
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 58
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 60
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 62
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 64
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 66
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 68
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 70
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 72
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 74
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 76
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 78
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 80
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 82
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 84
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 86
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 88
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 90
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 92
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 94
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 96
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# neuron unit number: 98
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.953125
# recall_score_sog 0.75
# precision_score_sog 0.6032608695652174
# f1_score_sog 0.6553030303030303
# neuron unit number: 100
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.65625
# recall_score_original 0.2967032967032967
# precision_score_original 0.34375
# f1_score_original 0.28402255639097745
# SOG Classficiation
# accuracy_score_sog 0.9375
# recall_score_sog 0.5
# precision_score_sog 0.4782608695652174
# f1_score_sog 0.48863636363636365
# all_accuracy_score_original mean 0.65625
# all_recall_score_original mean 0.29670329670329676
# all_precision_score_original mean 0.34375
# all_f1_score_original mean 0.2840225563909775
# all_accuracy_score_sog mean 0.9378125
# all_recall_score_sog mean 0.505
# all_precision_score_sog mean 0.4769717391304348
# all_f1_score_sog mean 0.48985309617918316
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable      N      Mean        SD        SE  \
# 0  all_accuracy_score_original   50.0  0.656250  0.000000  0.000000
# 1       all_accuracy_score_sog   50.0  0.937813  0.002210  0.000313
# 2                     combined  100.0  0.797031  0.141499  0.014150
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.937185  0.938440
# 2   0.768955  0.825108
#                                   Independent t-test   results
# 0  Difference (all_accuracy_score_original - all_...   -0.2816
# 1                              Degrees of freedom =    98.0000
# 2                                               t =  -901.0000
# 3                           Two side test p value =     0.0000
# 4                          Difference < 0 p value =     0.0000
# 5                          Difference > 0 p value =     1.0000
# 6                                       Cohen's d =  -180.2000
# 7                                       Hedge's g =  -178.8174
# 8                                  Glass's delta1 =       -inf
# 9                                Point-Biserial r =    -0.9999
# Recall Score T-Test
#                     Variable      N      Mean            SD            SE  \
# 0  all_recall_score_original   50.0  0.296703  5.607473e-17  7.930164e-18
# 1       all_recall_score_sog   50.0  0.505000  3.535534e-02  5.000000e-03
# 2                   combined  100.0  0.400852  1.075878e-01  1.075878e-02
#
#    95% Conf.  Interval
# 0   0.296703  0.296703
# 1   0.494952  0.515048
# 2   0.379504  0.422199
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -2.083000e-01
# 1                              Degrees of freedom =   9.800000e+01
# 2                                               t =  -4.165930e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -8.331900e+00
# 7                                       Hedge's g =  -8.267900e+00
# 8                                  Glass's delta1 =  -3.714627e+15
# 9                                Point-Biserial r =  -9.729000e-01
# Precision Score T-Test
#                        Variable      N      Mean        SD        SE  \
# 0  all_precision_score_original   50.0  0.343750  0.000000  0.000000
# 1       all_precision_score_sog   50.0  0.476972  0.018900  0.002673
# 2                      combined  100.0  0.410361  0.068254  0.006825
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.471600  0.482343
# 2   0.396818  0.423904
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.1332
# 1                              Degrees of freedom =   98.0000
# 2                                               t =  -49.8419
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -9.9684
# 7                                       Hedge's g =   -9.8919
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9808
# F1 Score T-Test
#                 Variable      N      Mean            SD            SE  \
# 0  all_f1_score_original   50.0  0.284023  5.607473e-17  7.930164e-18
# 1       all_f1_score_sog   50.0  0.489853  2.403977e-02  3.399736e-03
# 2               combined  100.0  0.386938  1.048073e-01  1.048073e-02
#
#    95% Conf.  Interval
# 0   0.284023  0.284023
# 1   0.483021  0.496685
# 2   0.366142  0.407734
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -2.058000e-01
# 1                              Degrees of freedom =   9.800000e+01
# 2                                               t =  -6.054310e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.210860e+01
# 7                                       Hedge's g =  -1.201570e+01
# 8                                  Glass's delta1 =  -3.670647e+15
# 9                                Point-Biserial r =  -9.869000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#KNN
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 50
best_num = 48
interval = 5

features = []
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 50
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.609375
# recall_score_sog 0.31607142857142856
# precision_score_sog 0.3100343053173242
# f1_score_sog 0.2947214076246334
# neuron unit number: 55
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 60
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 65
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 70
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 75
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.609375
# recall_score_sog 0.31607142857142856
# precision_score_sog 0.3100343053173242
# f1_score_sog 0.2947214076246334
# neuron unit number: 80
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 85
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 90
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 95
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# neuron unit number: 100
# accuracy_score_orignial 0.609375
# recall_score_original 0.31607142857142856
# precision_score_original 0.3100343053173242
# f1_score_original 0.2947214076246334
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.625
# recall_score_sog 0.32857142857142857
# precision_score_sog 0.3205128205128205
# f1_score_sog 0.3089080459770115
# all_accuracy_score_original mean 0.609375
# all_recall_score_original mean 0.31607142857142856
# all_precision_score_original mean 0.3100343053173242
# all_f1_score_original mean 0.29472140762463345
# all_accuracy_score_sog mean 0.6221590909090909
# all_recall_score_sog mean 0.32629870129870137
# all_precision_score_sog mean 0.3186076359318211
# all_f1_score_sog mean 0.30632865718567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  11.0  0.609375  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  11.0  0.622159  0.006321  0.001906   0.617913
# 2                     combined  22.0  0.615767  0.007863  0.001676   0.612281
#
#    Interval
# 0       NaN
# 1  0.626405
# 2  0.619253
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0128
# 1                              Degrees of freedom =   20.0000
# 2                                               t =   -6.7082
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.8604
# 7                                       Hedge's g =   -2.7518
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8321
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  11.0  0.316071  0.000000  0.000000        NaN
# 1       all_recall_score_sog  11.0  0.326299  0.005056  0.001525   0.322902
# 2                   combined  22.0  0.321185  0.006290  0.001341   0.318396
#
#    Interval
# 0       NaN
# 1  0.329696
# 2  0.323974
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0102
# 1                              Degrees of freedom =   20.0000
# 2                                               t =   -6.7082
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.8604
# 7                                       Hedge's g =   -2.7518
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8321
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  11.0  0.310034  0.000000  0.000000
# 1       all_precision_score_sog  11.0  0.318608  0.004239  0.001278
# 2                      combined  22.0  0.314321  0.005273  0.001124
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.315760  0.321455
# 2   0.311983  0.316659
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0086
# 1                              Degrees of freedom =   20.0000
# 2                                               t =   -6.7082
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.8604
# 7                                       Hedge's g =   -2.7518
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8321
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  11.0  0.294721  5.822059e-17  1.755417e-17
# 1       all_f1_score_sog  11.0  0.306329  5.738778e-03  1.730307e-03
# 2               combined  22.0  0.300525  7.139231e-03  1.522089e-03
#
#    95% Conf.  Interval
# 0   0.294721  0.294721
# 1   0.302473  0.310184
# 2   0.297360  0.303690
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.160000e-02
# 1                              Degrees of freedom =   2.000000e+01
# 2                                               t =  -6.708200e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.860400e+00
# 7                                       Hedge's g =  -2.751800e+00
# 8                                  Glass's delta1 =  -1.993668e+14
# 9                                Point-Biserial r =  -8.321000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,5]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 55
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37041036717062636
# test_discrete_score_W_discrete_n 0.06688134436929218
# test_discrete_score_W_discrete_a 0.045731723082621384
# neuron unit number: 6
# self.train_new_embedding_sog_fuzzy.shape[1] 66
# test_discrete_score_W0_p 0.36609071274298055
# test_discrete_score_W0_n 0.04921947140534073
# test_discrete_score_W0_a 0.03576620026477917
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.06899313781936849
# test_discrete_score_W_discrete_a 0.04940020987577622
# neuron unit number: 7
# self.train_new_embedding_sog_fuzzy.shape[1] 77
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.06361249329667956
# test_discrete_score_W_discrete_a 0.04592263937186642
# neuron unit number: 8
# self.train_new_embedding_sog_fuzzy.shape[1] 88
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.06845878613869527
# test_discrete_score_W0_a 0.04384251864120721
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.056163739832801124
# test_discrete_score_W_discrete_a 0.04254069367186344
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 9
# self.train_new_embedding_sog_fuzzy.shape[1] 99
# test_discrete_score_W0_p 0.36609071274298055
# test_discrete_score_W0_n 0.04628372058645353
# test_discrete_score_W0_a 0.031378579868955946
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.07053702318085123
# test_discrete_score_W_discrete_a 0.049466370293081846
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 110
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.07974845340370473
# test_discrete_score_W0_a 0.05529097087019835
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.043518312429769904
# test_discrete_score_W_discrete_a 0.029962131083361106
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# self.train_new_embedding_sog_fuzzy.shape[1] 121
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.07206815433388729
# test_discrete_score_W_discrete_a 0.056822063343853514
# neuron unit number: 12
# self.train_new_embedding_sog_fuzzy.shape[1] 132
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.05295714994803752
# test_discrete_score_W0_a 0.035046434011644215
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.05536497219811078
# test_discrete_score_W_discrete_a 0.038843005440694134
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 143
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.06288064142027676
# test_discrete_score_W_discrete_a 0.04284275387360021
# neuron unit number: 14
# self.train_new_embedding_sog_fuzzy.shape[1] 154
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.06493850242559132
# test_discrete_score_W0_a 0.04827678517603408
# test_discrete_score_W_discrete_p 0.38876889848812096
# test_discrete_score_W_discrete_n 0.0694080543704773
# test_discrete_score_W_discrete_a 0.050405333191090626
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 165
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.05842215955664494
# test_discrete_score_W0_a 0.04415354682976919
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.07658039457341215
# test_discrete_score_W_discrete_a 0.054557159830197384
# neuron unit number: 16
# self.train_new_embedding_sog_fuzzy.shape[1] 176
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.08245384213033664
# test_discrete_score_W0_a 0.05206593579493763
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.07008399398214839
# test_discrete_score_W_discrete_a 0.051380495068812766
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 187
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3952483801295896
# test_discrete_score_W_discrete_n 0.0819246075276175
# test_discrete_score_W_discrete_a 0.05826965472836842
# neuron unit number: 18
# self.train_new_embedding_sog_fuzzy.shape[1] 198
# test_discrete_score_W0_p 0.37365010799136067
# test_discrete_score_W0_n 0.05339994379536044
# test_discrete_score_W0_a 0.03679267534727926
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.06600799717791624
# test_discrete_score_W_discrete_a 0.049269959531402924
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 209
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.07004119993269062
# test_discrete_score_W_discrete_a 0.056679716815764516
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.06998302019704493
# test_discrete_score_W0_a 0.04847449555293756
# test_discrete_score_W_discrete_p 0.38876889848812096
# test_discrete_score_W_discrete_n 0.07365667302433472
# test_discrete_score_W_discrete_a 0.05031432821895438
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.07928925533759572
# test_discrete_score_W0_a 0.05829233656520472
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.058866071833629276
# test_discrete_score_W_discrete_a 0.042380010485982465
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# self.train_new_embedding_sog_fuzzy.shape[1] 242
# test_discrete_score_W0_p 0.3617710583153348
# test_discrete_score_W0_n 0.06374878256683557
# test_discrete_score_W0_a 0.04612596775946912
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.06318099430439864
# test_discrete_score_W_discrete_a 0.04761918446043883
# Not good nmi result for discrete features !!!!!
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 253
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.06382477858817902
# test_discrete_score_W_discrete_a 0.04930411727470398
# neuron unit number: 24
# self.train_new_embedding_sog_fuzzy.shape[1] 264
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.07562973413931486
# test_discrete_score_W0_a 0.05597678613431251
# test_discrete_score_W_discrete_p 0.3952483801295896
# test_discrete_score_W_discrete_n 0.06773265221994408
# test_discrete_score_W_discrete_a 0.05457436990750251
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 275
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.07917992062312781
# test_discrete_score_W0_a 0.0588933669437547
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.060668505907510786
# test_discrete_score_W_discrete_a 0.04256345880980146
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 26
# self.train_new_embedding_sog_fuzzy.shape[1] 286
# test_discrete_score_W0_p 0.367170626349892
# test_discrete_score_W0_n 0.067835467380613
# test_discrete_score_W0_a 0.04340428673730868
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.07611933850067813
# test_discrete_score_W_discrete_a 0.057827020639201615
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 297
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.0538190616095796
# test_discrete_score_W0_a 0.03955952384264781
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.0718260450940763
# test_discrete_score_W_discrete_a 0.052125905242736685
# neuron unit number: 28
# self.train_new_embedding_sog_fuzzy.shape[1] 308
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.07390481052360706
# test_discrete_score_W0_a 0.05161200374119362
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.06446153020651951
# test_discrete_score_W_discrete_a 0.04904646743121974
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 319
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.06833507707546392
# test_discrete_score_W_discrete_a 0.04923138486329743
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 330
# test_discrete_score_W0_p 0.40280777537796975
# test_discrete_score_W0_n 0.07477284902089136
# test_discrete_score_W0_a 0.05429123964873095
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.07942275647085054
# test_discrete_score_W_discrete_a 0.06330467043305148
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 341
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.07633523293749273
# test_discrete_score_W_discrete_a 0.055362469270374665
# neuron unit number: 32
# self.train_new_embedding_sog_fuzzy.shape[1] 352
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.06539736696050891
# test_discrete_score_W0_a 0.04970266938257489
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.08023038470336852
# test_discrete_score_W_discrete_a 0.06234031798099663
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 363
# test_discrete_score_W0_p 0.37041036717062636
# test_discrete_score_W0_n 0.07240648643201003
# test_discrete_score_W0_a 0.0483077789191683
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.08373128041985527
# test_discrete_score_W_discrete_a 0.054256698654111514
# neuron unit number: 34
# self.train_new_embedding_sog_fuzzy.shape[1] 374
# test_discrete_score_W0_p 0.3444924406047516
# test_discrete_score_W0_n 0.03694888710625025
# test_discrete_score_W0_a 0.030593657339380177
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.06516598249387263
# test_discrete_score_W_discrete_a 0.05432737222728296
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 385
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.0655418889653397
# test_discrete_score_W0_a 0.049936049381231785
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.068305293672118
# test_discrete_score_W_discrete_a 0.053675523974725546
# Not good purity result for discrete features !!!!!
# neuron unit number: 36
# self.train_new_embedding_sog_fuzzy.shape[1] 396
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.0720259145323451
# test_discrete_score_W0_a 0.0453506585780649
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.0741275535915403
# test_discrete_score_W_discrete_a 0.05086921375474377
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 407
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.06589169790831735
# test_discrete_score_W_discrete_a 0.04941160355772911
# neuron unit number: 38
# self.train_new_embedding_sog_fuzzy.shape[1] 418
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.06244280101703902
# test_discrete_score_W0_a 0.047412211940942854
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.07094374187955242
# test_discrete_score_W_discrete_a 0.05514036210963916
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 429
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.0729507219904997
# test_discrete_score_W0_a 0.04390948505970024
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.07610828341701757
# test_discrete_score_W_discrete_a 0.05627011940677326
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 440
# test_discrete_score_W0_p 0.37365010799136067
# test_discrete_score_W0_n 0.044404881574095056
# test_discrete_score_W0_a 0.03472050149936502
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.08337197205550068
# test_discrete_score_W_discrete_a 0.06540337688891792
# neuron unit number: 41
# self.train_new_embedding_sog_fuzzy.shape[1] 451
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3952483801295896
# test_discrete_score_W_discrete_n 0.06592660647887423
# test_discrete_score_W_discrete_a 0.048675817806265974
# neuron unit number: 42
# self.train_new_embedding_sog_fuzzy.shape[1] 462
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.07286039764287484
# test_discrete_score_W0_a 0.05698510787919541
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.07716106654360826
# test_discrete_score_W_discrete_a 0.05655874948220965
# Not good purity result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 43
# self.train_new_embedding_sog_fuzzy.shape[1] 473
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.06582049570411737
# test_discrete_score_W_discrete_a 0.05017128737248685
# neuron unit number: 44
# self.train_new_embedding_sog_fuzzy.shape[1] 484
# test_discrete_score_W0_p 0.37041036717062636
# test_discrete_score_W0_n 0.07612083889396627
# test_discrete_score_W0_a 0.04930026843226323
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.06740173903611323
# test_discrete_score_W_discrete_a 0.051506902226577854
# Not good nmi result for discrete features !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 495
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.07848121553930623
# test_discrete_score_W0_a 0.05519132527244656
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.06866899337896142
# test_discrete_score_W_discrete_a 0.04956787228250607
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 46
# self.train_new_embedding_sog_fuzzy.shape[1] 506
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.07684541530097433
# test_discrete_score_W0_a 0.05283970094345183
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.07749845460201084
# test_discrete_score_W_discrete_a 0.058221595005290824
# neuron unit number: 47
# self.train_new_embedding_sog_fuzzy.shape[1] 517
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.06308796822787371
# test_discrete_score_W_discrete_a 0.0471544879241244
# neuron unit number: 48
# self.train_new_embedding_sog_fuzzy.shape[1] 528
# test_discrete_score_W0_p 0.4265658747300216
# test_discrete_score_W0_n 0.07890460527136992
# test_discrete_score_W0_a 0.054969741892152035
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.0693333261703777
# test_discrete_score_W_discrete_a 0.05332430009487109
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 49
# self.train_new_embedding_sog_fuzzy.shape[1] 539
# test_discrete_score_W0_p 0.4060475161987041
# test_discrete_score_W0_n 0.06878876506310905
# test_discrete_score_W0_a 0.04488091039001491
# test_discrete_score_W_discrete_p 0.41252699784017277
# test_discrete_score_W_discrete_n 0.07863843928736046
# test_discrete_score_W_discrete_a 0.052908836932652366
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 550
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.07098152090710942
# test_discrete_score_W0_a 0.05322035579378599
# test_discrete_score_W_discrete_p 0.41252699784017277
# test_discrete_score_W_discrete_n 0.06939703755362825
# test_discrete_score_W_discrete_a 0.05425726853965832
# Not good nmi result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.36857920931542865
# test_discrete_score_W_discrete_p mean 0.39731430181237665
# test_discrete_score_W0_n mean 0.048024926912729846
# test_discrete_score_W_discrete_n mean 0.0693327399941836
# test_discrete_score_W0_a mean 0.033838349487697886
# test_discrete_score_W_discrete_a mean 0.051299760923069204
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.048025  0.032012  0.004720   0.038518  0.057531
# 1  test_dis_W_dis  46.0  0.069333  0.007826  0.001154   0.067009  0.071657
# 2        combined  92.0  0.058679  0.025530  0.002662   0.053392  0.063966
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0213
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -4.3853
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -0.9144
# 7                                  Hedge's g =   -0.9068
# 8                             Glass's delta1 =   -0.6656
# 9                           Point-Biserial r =   -0.4196
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.033838  0.022479  0.003314   0.027163  0.040514
# 1  test_dis_W_dis  46.0  0.051300  0.006420  0.000947   0.049393  0.053206
# 2        combined  92.0  0.042569  0.018636  0.001943   0.038710  0.046429
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0175
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -5.0660
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.0563
# 7                                  Hedge's g =   -1.0475
# 8                             Glass's delta1 =   -0.7768
# 9                           Point-Biserial r =   -0.4710
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.368579  0.026241  0.003869   0.360787  0.376372
# 1  test_dis_W_dis  46.0  0.397314  0.011748  0.001732   0.393826  0.400803
# 2        combined  92.0  0.382947  0.024849  0.002591   0.377801  0.388093
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0287
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -6.7787
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.4135
# 7                                  Hedge's g =   -1.4016
# 8                             Glass's delta1 =   -1.0951
# 9                           Point-Biserial r =   -0.5814

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,6]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 55
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.05330166040988121
# test_discrete_score_W_discrete_a 0.040649509777573596
# neuron unit number: 6
# self.train_new_embedding_sog_fuzzy.shape[1] 66
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.054023138159351836
# test_discrete_score_W0_a 0.04150564716833643
# test_discrete_score_W_discrete_p 0.367170626349892
# test_discrete_score_W_discrete_n 0.05694371570479038
# test_discrete_score_W_discrete_a 0.04614059976010921
# Not good purity result for discrete features !!!!!
# neuron unit number: 7
# self.train_new_embedding_sog_fuzzy.shape[1] 77
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.05806915497544241
# test_discrete_score_W_discrete_a 0.04443847491672415
# neuron unit number: 8
# self.train_new_embedding_sog_fuzzy.shape[1] 88
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.05832947143255992
# test_discrete_score_W0_a 0.04147793061258686
# test_discrete_score_W_discrete_p 0.37041036717062636
# test_discrete_score_W_discrete_n 0.04144274635312482
# test_discrete_score_W_discrete_a 0.0286481513114975
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 9
# self.train_new_embedding_sog_fuzzy.shape[1] 99
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.05342722006885237
# test_discrete_score_W0_a 0.03965034371563893
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.058074482702383357
# test_discrete_score_W_discrete_a 0.04241106152301649
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 110
# test_discrete_score_W0_p 0.37041036717062636
# test_discrete_score_W0_n 0.06163772677667659
# test_discrete_score_W0_a 0.045314578716712337
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.05589194337318521
# test_discrete_score_W_discrete_a 0.042930715360422436
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# self.train_new_embedding_sog_fuzzy.shape[1] 121
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.05617035640351349
# test_discrete_score_W_discrete_a 0.04131636884443107
# neuron unit number: 12
# self.train_new_embedding_sog_fuzzy.shape[1] 132
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.05930042015580454
# test_discrete_score_W0_a 0.040100160425163546
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.0554340883583182
# test_discrete_score_W_discrete_a 0.03691871502906037
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 143
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.053701827390975655
# test_discrete_score_W_discrete_a 0.041422555916340975
# neuron unit number: 14
# self.train_new_embedding_sog_fuzzy.shape[1] 154
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.06702198655893009
# test_discrete_score_W0_a 0.04865184937641577
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.047763239390481826
# test_discrete_score_W_discrete_a 0.03343324586051417
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 165
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.0727124543570144
# test_discrete_score_W0_a 0.05068475830467518
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.06816849816844682
# test_discrete_score_W_discrete_a 0.047574391472402104
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 16
# self.train_new_embedding_sog_fuzzy.shape[1] 176
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.07486423599050786
# test_discrete_score_W0_a 0.05162010205772869
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.059161394640535485
# test_discrete_score_W_discrete_a 0.0442524146669965
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 187
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.06537652533584742
# test_discrete_score_W_discrete_a 0.053057717792025075
# neuron unit number: 18
# self.train_new_embedding_sog_fuzzy.shape[1] 198
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.0606287403502058
# test_discrete_score_W0_a 0.045349349982688913
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.05495505435107882
# test_discrete_score_W_discrete_a 0.041935271706250096
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 209
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.05329957226381839
# test_discrete_score_W_discrete_a 0.03944794240984126
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.05105312492613719
# test_discrete_score_W0_a 0.03626533264662699
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.06139799445644199
# test_discrete_score_W_discrete_a 0.04351234837917437
# Not good purity result for discrete features !!!!!
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.06298288109540605
# test_discrete_score_W0_a 0.04532847283951182
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.045869318040893337
# test_discrete_score_W_discrete_a 0.03628964306743618
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# self.train_new_embedding_sog_fuzzy.shape[1] 242
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.0758421619179929
# test_discrete_score_W0_a 0.05765480716977496
# test_discrete_score_W_discrete_p 0.38444924406047515
# test_discrete_score_W_discrete_n 0.06269067462580807
# test_discrete_score_W_discrete_a 0.04809599500425403
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 253
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.06060502839710173
# test_discrete_score_W_discrete_a 0.04871929983361455
# neuron unit number: 24
# self.train_new_embedding_sog_fuzzy.shape[1] 264
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.06464797548221861
# test_discrete_score_W0_a 0.04810498192969988
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.043555224996949415
# test_discrete_score_W_discrete_a 0.03450445277193149
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 275
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.07117804112058759
# test_discrete_score_W0_a 0.048987230819385
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.07057562778910904
# test_discrete_score_W_discrete_a 0.05295034634094129
# Not good nmi result for discrete features !!!!!
# neuron unit number: 26
# self.train_new_embedding_sog_fuzzy.shape[1] 286
# test_discrete_score_W0_p 0.35529157667386607
# test_discrete_score_W0_n 0.028328996864166574
# test_discrete_score_W0_a 0.013967608692842113
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.054154862623821125
# test_discrete_score_W_discrete_a 0.03649058095802191
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 297
# test_discrete_score_W0_p 0.37365010799136067
# test_discrete_score_W0_n 0.07638157527504377
# test_discrete_score_W0_a 0.049258849107116275
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.06864051106512052
# test_discrete_score_W_discrete_a 0.04991238646915955
# Not good nmi result for discrete features !!!!!
# neuron unit number: 28
# self.train_new_embedding_sog_fuzzy.shape[1] 308
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.07112499722985482
# test_discrete_score_W0_a 0.057850583207809385
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.06852010938462766
# test_discrete_score_W_discrete_a 0.04992048988417089
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 319
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.058773340394822446
# test_discrete_score_W_discrete_a 0.043628613221103694
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 330
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.05553375692725529
# test_discrete_score_W0_a 0.03730478864473779
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.05870332400662803
# test_discrete_score_W_discrete_a 0.04468625526799153
# Not good purity result for discrete features !!!!!
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 341
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.05450849095727081
# test_discrete_score_W_discrete_a 0.04004831617307133
# neuron unit number: 32
# self.train_new_embedding_sog_fuzzy.shape[1] 352
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.058745044141843075
# test_discrete_score_W0_a 0.04376747652838799
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.07137105783669696
# test_discrete_score_W_discrete_a 0.05654244003739829
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 363
# test_discrete_score_W0_p 0.3617710583153348
# test_discrete_score_W0_n 0.05774150332295804
# test_discrete_score_W0_a 0.04329007455282658
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.07020858385552625
# test_discrete_score_W_discrete_a 0.05014966897227226
# neuron unit number: 34
# self.train_new_embedding_sog_fuzzy.shape[1] 374
# test_discrete_score_W0_p 0.36069114470842334
# test_discrete_score_W0_n 0.05728356391886932
# test_discrete_score_W0_a 0.0449911174207877
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.06062636871134806
# test_discrete_score_W_discrete_a 0.04553814014019552
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 385
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.07143391844314266
# test_discrete_score_W0_a 0.04434342589501311
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.06034805274812305
# test_discrete_score_W_discrete_a 0.0476169179073836
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 36
# self.train_new_embedding_sog_fuzzy.shape[1] 396
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.06372172820011525
# test_discrete_score_W0_a 0.04886141039195411
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.07532059739011926
# test_discrete_score_W_discrete_a 0.05422571047970978
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 407
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.054154612061609125
# test_discrete_score_W_discrete_a 0.040135707384576384
# neuron unit number: 38
# self.train_new_embedding_sog_fuzzy.shape[1] 418
# test_discrete_score_W0_p 0.3563714902807775
# test_discrete_score_W0_n 0.059623018149441466
# test_discrete_score_W0_a 0.041585375482620035
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.0634886707061916
# test_discrete_score_W_discrete_a 0.046339993749405124
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 429
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.08670492945187734
# test_discrete_score_W0_a 0.05876515207399108
# test_discrete_score_W_discrete_p 0.3930885529157667
# test_discrete_score_W_discrete_n 0.05788815777607669
# test_discrete_score_W_discrete_a 0.04403874905135363
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 440
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.06643089193849365
# test_discrete_score_W0_a 0.05315378832320505
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.06530407412055501
# test_discrete_score_W_discrete_a 0.04870601276433249
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 41
# self.train_new_embedding_sog_fuzzy.shape[1] 451
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38444924406047515
# test_discrete_score_W_discrete_n 0.06810405433047811
# test_discrete_score_W_discrete_a 0.04745353816472529
# neuron unit number: 42
# self.train_new_embedding_sog_fuzzy.shape[1] 462
# test_discrete_score_W0_p 0.40280777537796975
# test_discrete_score_W0_n 0.06629827712071126
# test_discrete_score_W0_a 0.046554581956892806
# test_discrete_score_W_discrete_p 0.4114470842332613
# test_discrete_score_W_discrete_n 0.07039477448838939
# test_discrete_score_W_discrete_a 0.050068563798968166
# neuron unit number: 43
# self.train_new_embedding_sog_fuzzy.shape[1] 473
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.04849187272839395
# test_discrete_score_W_discrete_a 0.034636525393333825
# neuron unit number: 44
# self.train_new_embedding_sog_fuzzy.shape[1] 484
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.06618216092999271
# test_discrete_score_W0_a 0.04793833888165134
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.07577323653540077
# test_discrete_score_W_discrete_a 0.05403029376656841
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 495
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.06258527305117577
# test_discrete_score_W0_a 0.04590906234834747
# test_discrete_score_W_discrete_p 0.408207343412527
# test_discrete_score_W_discrete_n 0.06435014827271207
# test_discrete_score_W_discrete_a 0.045752731528039374
# Not good ari result for discrete features  !!!!!
# neuron unit number: 46
# self.train_new_embedding_sog_fuzzy.shape[1] 506
# test_discrete_score_W0_p 0.36393088552915764
# test_discrete_score_W0_n 0.02681193251360067
# test_discrete_score_W0_a 0.0135322575675834
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.054510438548671096
# test_discrete_score_W_discrete_a 0.04201985538192199
# neuron unit number: 47
# self.train_new_embedding_sog_fuzzy.shape[1] 517
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3930885529157667
# test_discrete_score_W_discrete_n 0.06349344299522433
# test_discrete_score_W_discrete_a 0.04639758065294639
# neuron unit number: 48
# self.train_new_embedding_sog_fuzzy.shape[1] 528
# test_discrete_score_W0_p 0.4330453563714903
# test_discrete_score_W0_n 0.08439408129828524
# test_discrete_score_W0_a 0.06347601258778499
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.0778224535775569
# test_discrete_score_W_discrete_a 0.06336654988528916
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 49
# self.train_new_embedding_sog_fuzzy.shape[1] 539
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.08396414974553754
# test_discrete_score_W0_a 0.05566175150569565
# test_discrete_score_W_discrete_p 0.4103671706263499
# test_discrete_score_W_discrete_n 0.07269523382705985
# test_discrete_score_W_discrete_a 0.055105083409947714
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 550
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.06752628927172467
# test_discrete_score_W0_a 0.04246592638322089
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.06973562379173824
# test_discrete_score_W_discrete_a 0.05975085227239709
# test_discrete_score_W0_p mean 0.36867311484646437
# test_discrete_score_W_discrete_p mean 0.39128087144332807
# test_discrete_score_W0_n mean 0.04561881883013772
# test_discrete_score_W_discrete_n mean 0.06064848306222367
# test_discrete_score_W0_a mean 0.03246463320255246
# test_discrete_score_W_discrete_a mean 0.045330669096931314
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.045619  0.030923  0.004559   0.036436  0.054802
# 1  test_dis_W_dis  46.0  0.060648  0.008614  0.001270   0.058090  0.063206
# 2        combined  92.0  0.053134  0.023804  0.002482   0.048204  0.058063
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0150
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -3.1756
# 3                      Two side test p value =    0.0020
# 4                     Difference < 0 p value =    0.0010
# 5                     Difference > 0 p value =    0.9990
# 6                                  Cohen's d =   -0.6621
# 7                                  Hedge's g =   -0.6566
# 8                             Glass's delta1 =   -0.4860
# 9                           Point-Biserial r =   -0.3174
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.032465  0.022352  0.003296   0.025827  0.039102
# 1  test_dis_W_dis  46.0  0.045331  0.007047  0.001039   0.043238  0.047424
# 2        combined  92.0  0.038898  0.017705  0.001846   0.035231  0.042564
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0129
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -3.7233
# 3                      Two side test p value =    0.0003
# 4                     Difference < 0 p value =    0.0002
# 5                     Difference > 0 p value =    0.9998
# 6                                  Cohen's d =   -0.7764
# 7                                  Hedge's g =   -0.7699
# 8                             Glass's delta1 =   -0.5756
# 9                           Point-Biserial r =   -0.3653
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.368673  0.026285  0.003875   0.360867  0.376479
# 1  test_dis_W_dis  46.0  0.391281  0.012753  0.001880   0.387494  0.395068
# 2        combined  92.0  0.379977  0.023479  0.002448   0.375115  0.384839
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0226
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -5.2484
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.0944
# 7                                  Hedge's g =   -1.0852
# 8                             Glass's delta1 =   -0.8601
# 9                           Point-Biserial r =   -0.4841

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,7]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 55
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.05617934599897371
# test_discrete_score_W_discrete_a 0.040444408328386625
# neuron unit number: 6
# self.train_new_embedding_sog_fuzzy.shape[1] 66
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.06386741190222821
# test_discrete_score_W0_a 0.04237559530591922
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.05438974697049294
# test_discrete_score_W_discrete_a 0.0413439719062535
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 7
# self.train_new_embedding_sog_fuzzy.shape[1] 77
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.07349392392635633
# test_discrete_score_W_discrete_a 0.048253421036643276
# neuron unit number: 8
# self.train_new_embedding_sog_fuzzy.shape[1] 88
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.06515564824596425
# test_discrete_score_W0_a 0.0418895711407197
# test_discrete_score_W_discrete_p 0.36825053995680346
# test_discrete_score_W_discrete_n 0.0629449343502365
# test_discrete_score_W_discrete_a 0.04386542599766968
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 9
# self.train_new_embedding_sog_fuzzy.shape[1] 99
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.05340608777472299
# test_discrete_score_W0_a 0.04026028050740463
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.05593159512481074
# test_discrete_score_W_discrete_a 0.042789613650983084
# Not good purity result for discrete features !!!!!
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 110
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.059526251549013934
# test_discrete_score_W0_a 0.04287437957245872
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.05935708341002226
# test_discrete_score_W_discrete_a 0.038764503275904166
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# self.train_new_embedding_sog_fuzzy.shape[1] 121
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.06327193903482344
# test_discrete_score_W_discrete_a 0.04513414543009658
# neuron unit number: 12
# self.train_new_embedding_sog_fuzzy.shape[1] 132
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.06358010032237117
# test_discrete_score_W0_a 0.043771508217429145
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.06081223601904526
# test_discrete_score_W_discrete_a 0.043463270346423485
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 143
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.06507230341109595
# test_discrete_score_W_discrete_a 0.040908837738196493
# neuron unit number: 14
# self.train_new_embedding_sog_fuzzy.shape[1] 154
# test_discrete_score_W0_p 0.357451403887689
# test_discrete_score_W0_n 0.04902626186919939
# test_discrete_score_W0_a 0.03742000938220866
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.059448155775209004
# test_discrete_score_W_discrete_a 0.0488578373384956
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 165
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.06514048235090285
# test_discrete_score_W0_a 0.04579668921292639
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.06821396449278558
# test_discrete_score_W_discrete_a 0.04207726587651111
# Not good purity result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 16
# self.train_new_embedding_sog_fuzzy.shape[1] 176
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.04937876094027804
# test_discrete_score_W0_a 0.03433864263798634
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.063267800295784
# test_discrete_score_W_discrete_a 0.04588894522850127
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 187
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.06376551892016664
# test_discrete_score_W_discrete_a 0.046406831673096005
# neuron unit number: 18
# self.train_new_embedding_sog_fuzzy.shape[1] 198
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.07440577184716334
# test_discrete_score_W0_a 0.053364913031010514
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.05888607365460576
# test_discrete_score_W_discrete_a 0.044398904777413956
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 209
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.06478893641010525
# test_discrete_score_W_discrete_a 0.04867821570337107
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.05219993661934898
# test_discrete_score_W0_a 0.03602234575190152
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.06666609812633882
# test_discrete_score_W_discrete_a 0.04537993247598191
# Not good purity result for discrete features !!!!!
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.04973204885877978
# test_discrete_score_W0_a 0.033951924529889786
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.062424406375305434
# test_discrete_score_W_discrete_a 0.04633892139263325
# neuron unit number: 22
# self.train_new_embedding_sog_fuzzy.shape[1] 242
# test_discrete_score_W0_p 0.36393088552915764
# test_discrete_score_W0_n 0.05453498917503108
# test_discrete_score_W0_a 0.04258092007158864
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.05839613064362408
# test_discrete_score_W_discrete_a 0.04377631625929836
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 253
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.06125733424969428
# test_discrete_score_W_discrete_a 0.050876273354685676
# neuron unit number: 24
# self.train_new_embedding_sog_fuzzy.shape[1] 264
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.06678869267503741
# test_discrete_score_W0_a 0.04559760113041087
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.04556611261024455
# test_discrete_score_W_discrete_a 0.0323198882143334
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 275
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.0646971760169591
# test_discrete_score_W0_a 0.0493762810305135
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.06485370399873577
# test_discrete_score_W_discrete_a 0.0441468607625837
# Not good ari result for discrete features  !!!!!
# neuron unit number: 26
# self.train_new_embedding_sog_fuzzy.shape[1] 286
# test_discrete_score_W0_p 0.35529157667386607
# test_discrete_score_W0_n 0.027333328102960793
# test_discrete_score_W0_a 0.012094952965462855
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.0634967744879198
# test_discrete_score_W_discrete_a 0.0452427478878363
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 297
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.056665798447327324
# test_discrete_score_W0_a 0.039686570574735354
# test_discrete_score_W_discrete_p 0.38444924406047515
# test_discrete_score_W_discrete_n 0.06621980216306854
# test_discrete_score_W_discrete_a 0.05810471980149538
# neuron unit number: 28
# self.train_new_embedding_sog_fuzzy.shape[1] 308
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.07143478331170015
# test_discrete_score_W0_a 0.051457745582354934
# test_discrete_score_W_discrete_p 0.3930885529157667
# test_discrete_score_W_discrete_n 0.0646231123920284
# test_discrete_score_W_discrete_a 0.05149634424221842
# Not good nmi result for discrete features !!!!!
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 319
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.05509765709064955
# test_discrete_score_W_discrete_a 0.04209197307398576
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 330
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.07287277951717927
# test_discrete_score_W0_a 0.054062222539920886
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.05349406147585485
# test_discrete_score_W_discrete_a 0.041780009749154357
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 341
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.07058283233235459
# test_discrete_score_W_discrete_a 0.04894415492246391
# neuron unit number: 32
# self.train_new_embedding_sog_fuzzy.shape[1] 352
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.07543980747791829
# test_discrete_score_W0_a 0.055856653985830854
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.0738692140674349
# test_discrete_score_W_discrete_a 0.05419979171855841
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 363
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.07335251727894256
# test_discrete_score_W0_a 0.052640664366514926
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.07319272804211695
# test_discrete_score_W_discrete_a 0.04598148150925037
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 34
# self.train_new_embedding_sog_fuzzy.shape[1] 374
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.04845276301921933
# test_discrete_score_W0_a 0.036397968128379234
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.05432923762442551
# test_discrete_score_W_discrete_a 0.041180053024443365
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 385
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.05149158113507375
# test_discrete_score_W0_a 0.040040321073385045
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.06417244114550436
# test_discrete_score_W_discrete_a 0.04821078339856696
# Not good purity result for discrete features !!!!!
# neuron unit number: 36
# self.train_new_embedding_sog_fuzzy.shape[1] 396
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.06122534735379429
# test_discrete_score_W0_a 0.03952325003547781
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.05781446413194847
# test_discrete_score_W_discrete_a 0.0475633834960456
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 407
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.05347196484810991
# test_discrete_score_W_discrete_a 0.03958879399561379
# neuron unit number: 38
# self.train_new_embedding_sog_fuzzy.shape[1] 418
# test_discrete_score_W0_p 0.36069114470842334
# test_discrete_score_W0_n 0.04661642261314702
# test_discrete_score_W0_a 0.03707526962967408
# test_discrete_score_W_discrete_p 0.4103671706263499
# test_discrete_score_W_discrete_n 0.07886816856761902
# test_discrete_score_W_discrete_a 0.049594680537102226
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 429
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.045245799217163735
# test_discrete_score_W0_a 0.036853638740115234
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.06343947046221929
# test_discrete_score_W_discrete_a 0.04885471204201927
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 440
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.0572597219366084
# test_discrete_score_W0_a 0.04024106270283848
# test_discrete_score_W_discrete_p 0.4136069114470842
# test_discrete_score_W_discrete_n 0.07328261917265651
# test_discrete_score_W_discrete_a 0.05486279529670103
# neuron unit number: 41
# self.train_new_embedding_sog_fuzzy.shape[1] 451
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.06647585292420599
# test_discrete_score_W_discrete_a 0.0495469436354513
# neuron unit number: 42
# self.train_new_embedding_sog_fuzzy.shape[1] 462
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.07692098028869412
# test_discrete_score_W0_a 0.04997671471480615
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.06226368880717968
# test_discrete_score_W_discrete_a 0.0448115893872157
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 43
# self.train_new_embedding_sog_fuzzy.shape[1] 473
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.06250399825404486
# test_discrete_score_W_discrete_a 0.05334012418202448
# neuron unit number: 44
# self.train_new_embedding_sog_fuzzy.shape[1] 484
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.0672478930477218
# test_discrete_score_W0_a 0.05361384789553219
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.0686657855704782
# test_discrete_score_W_discrete_a 0.051284664307692435
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 495
# test_discrete_score_W0_p 0.38876889848812096
# test_discrete_score_W0_n 0.06985817271710909
# test_discrete_score_W0_a 0.04759868238853784
# test_discrete_score_W_discrete_p 0.4114470842332613
# test_discrete_score_W_discrete_n 0.06668483251789493
# test_discrete_score_W_discrete_a 0.052473987562021075
# Not good nmi result for discrete features !!!!!
# neuron unit number: 46
# self.train_new_embedding_sog_fuzzy.shape[1] 506
# test_discrete_score_W0_p 0.3650107991360691
# test_discrete_score_W0_n 0.03155149890563736
# test_discrete_score_W0_a 0.024054109450634863
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.05885490321335686
# test_discrete_score_W_discrete_a 0.0486939371166547
# neuron unit number: 47
# self.train_new_embedding_sog_fuzzy.shape[1] 517
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3930885529157667
# test_discrete_score_W_discrete_n 0.06056159031406466
# test_discrete_score_W_discrete_a 0.044820257252448654
# neuron unit number: 48
# self.train_new_embedding_sog_fuzzy.shape[1] 528
# test_discrete_score_W0_p 0.4190064794816415
# test_discrete_score_W0_n 0.08629046982529281
# test_discrete_score_W0_a 0.057209774685084355
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.06896256753530781
# test_discrete_score_W_discrete_a 0.04594879570016074
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 49
# self.train_new_embedding_sog_fuzzy.shape[1] 539
# test_discrete_score_W0_p 0.4287257019438445
# test_discrete_score_W0_n 0.09099590161593052
# test_discrete_score_W0_a 0.06007570557748995
# test_discrete_score_W_discrete_p 0.4265658747300216
# test_discrete_score_W_discrete_n 0.08257796234340839
# test_discrete_score_W_discrete_a 0.05954578011128227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 550
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.07259486302586778
# test_discrete_score_W0_a 0.05169135238200261
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.07616871743257067
# test_discrete_score_W_discrete_a 0.051831315762108886
# test_discrete_score_W0_p mean 0.3690956897361254
# test_discrete_score_W_discrete_p mean 0.39224340313644473
# test_discrete_score_W0_n mean 0.04378891410835411
# test_discrete_score_W_discrete_n mean 0.06366656066771474
# test_discrete_score_W0_a mean 0.031081981933503162
# test_discrete_score_W_discrete_a mean 0.04661103501043429
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.043789  0.030184  0.004450   0.034825  0.052753
# 1  test_dis_W_dis  46.0  0.063667  0.007242  0.001068   0.061516  0.065817
# 2        combined  92.0  0.053728  0.024007  0.002503   0.048756  0.058699
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0199
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -4.3432
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -0.9056
# 7                                  Hedge's g =   -0.8980
# 8                             Glass's delta1 =   -0.6585
# 9                           Point-Biserial r =   -0.4163
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.031082  0.021389  0.003154   0.024730  0.037434
# 1  test_dis_W_dis  46.0  0.046611  0.005197  0.000766   0.045068  0.048154
# 2        combined  92.0  0.038847  0.017336  0.001807   0.035256  0.042437
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0155
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -4.7850
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -0.9978
# 7                                  Hedge's g =   -0.9894
# 8                             Glass's delta1 =   -0.7260
# 9                           Point-Biserial r =   -0.4503
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.369096  0.026593  0.003921   0.361199  0.376993
# 1  test_dis_W_dis  46.0  0.392243  0.013997  0.002064   0.388087  0.396400
# 2        combined  92.0  0.380670  0.024125  0.002515   0.375673  0.385666
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0231
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -5.2242
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.0893
# 7                                  Hedge's g =   -1.0802
# 8                             Glass's delta1 =   -0.8704
# 9                           Point-Biserial r =   -0.4824

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,8]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 55
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37041036717062636
# test_discrete_score_W_discrete_n 0.06804686725077735
# test_discrete_score_W_discrete_a 0.04693393703241673
# neuron unit number: 6
# self.train_new_embedding_sog_fuzzy.shape[1] 66
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.05049737640466404
# test_discrete_score_W0_a 0.038487917113547855
# test_discrete_score_W_discrete_p 0.37041036717062636
# test_discrete_score_W_discrete_n 0.05895395158705962
# test_discrete_score_W_discrete_a 0.04449261520728005
# Not good purity result for discrete features !!!!!
# neuron unit number: 7
# self.train_new_embedding_sog_fuzzy.shape[1] 77
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.0770651014687869
# test_discrete_score_W_discrete_a 0.05467515042360894
# neuron unit number: 8
# self.train_new_embedding_sog_fuzzy.shape[1] 88
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.06173778029015344
# test_discrete_score_W0_a 0.04021176397949343
# test_discrete_score_W_discrete_p 0.3747300215982721
# test_discrete_score_W_discrete_n 0.05415107364247625
# test_discrete_score_W_discrete_a 0.0408143458302253
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 9
# self.train_new_embedding_sog_fuzzy.shape[1] 99
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.06989585468687544
# test_discrete_score_W0_a 0.050418083795614604
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.07400581240746008
# test_discrete_score_W_discrete_a 0.05152453703168655
# Not good purity result for discrete features !!!!!
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 110
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.07201800183344358
# test_discrete_score_W0_a 0.04956707212692965
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.046980809285727315
# test_discrete_score_W_discrete_a 0.0360604584126873
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# self.train_new_embedding_sog_fuzzy.shape[1] 121
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3650107991360691
# test_discrete_score_W_discrete_n 0.055173393273266966
# test_discrete_score_W_discrete_a 0.04013342563980339
# neuron unit number: 12
# self.train_new_embedding_sog_fuzzy.shape[1] 132
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.05612424702051092
# test_discrete_score_W0_a 0.0385409335368488
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.052799994728127506
# test_discrete_score_W_discrete_a 0.03918726181943943
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 143
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.06690812297537237
# test_discrete_score_W_discrete_a 0.04496242407314443
# neuron unit number: 14
# self.train_new_embedding_sog_fuzzy.shape[1] 154
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.06008765058844915
# test_discrete_score_W0_a 0.04533116239155569
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.05173700214700725
# test_discrete_score_W_discrete_a 0.043874566298091396
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 165
# test_discrete_score_W0_p 0.3898488120950324
# test_discrete_score_W0_n 0.06629966424596218
# test_discrete_score_W0_a 0.049434500452097886
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.046956792357678794
# test_discrete_score_W_discrete_a 0.03511730932810544
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 16
# self.train_new_embedding_sog_fuzzy.shape[1] 176
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.07539939145232094
# test_discrete_score_W0_a 0.05283137488989364
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.07015386084145926
# test_discrete_score_W_discrete_a 0.04325148753867641
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 187
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.05590512815824466
# test_discrete_score_W_discrete_a 0.04104486323197833
# neuron unit number: 18
# self.train_new_embedding_sog_fuzzy.shape[1] 198
# test_discrete_score_W0_p 0.3650107991360691
# test_discrete_score_W0_n 0.06481539008687069
# test_discrete_score_W0_a 0.04700097889326084
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.06674121128737258
# test_discrete_score_W_discrete_a 0.04200903770346019
# Not good ari result for discrete features  !!!!!
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 209
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3855291576673866
# test_discrete_score_W_discrete_n 0.0541327050221683
# test_discrete_score_W_discrete_a 0.043883726124404436
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.3898488120950324
# test_discrete_score_W0_n 0.07362174641060032
# test_discrete_score_W0_a 0.05413325682516345
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.059727102540193894
# test_discrete_score_W_discrete_a 0.0474433587182798
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.06515291926059581
# test_discrete_score_W0_a 0.04592494336333032
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.05348366670612116
# test_discrete_score_W_discrete_a 0.04048705809657126
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# self.train_new_embedding_sog_fuzzy.shape[1] 242
# test_discrete_score_W0_p 0.367170626349892
# test_discrete_score_W0_n 0.06856249007438449
# test_discrete_score_W0_a 0.049172319726537975
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.04797088243838363
# test_discrete_score_W_discrete_a 0.04007468861479377
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 253
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.04511449420364655
# test_discrete_score_W_discrete_a 0.03591946140632151
# neuron unit number: 24
# self.train_new_embedding_sog_fuzzy.shape[1] 264
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.07826523788869458
# test_discrete_score_W0_a 0.05139891532619081
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.05953085568500086
# test_discrete_score_W_discrete_a 0.0406905388693255
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 275
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.07798261986092553
# test_discrete_score_W0_a 0.05651894619628315
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.06442664959171304
# test_discrete_score_W_discrete_a 0.05012073416953969
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 26
# self.train_new_embedding_sog_fuzzy.shape[1] 286
# test_discrete_score_W0_p 0.3563714902807775
# test_discrete_score_W0_n 0.05229102946117296
# test_discrete_score_W0_a 0.039753958344292704
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.04969466043255435
# test_discrete_score_W_discrete_a 0.03697786382404855
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 297
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.0612892794392386
# test_discrete_score_W0_a 0.041551730129941004
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.06082180833934469
# test_discrete_score_W_discrete_a 0.035067924098622964
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 28
# self.train_new_embedding_sog_fuzzy.shape[1] 308
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.057535676206243905
# test_discrete_score_W0_a 0.04404489514384289
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.0562943675034327
# test_discrete_score_W_discrete_a 0.040763669442880526
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 319
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.06704193240884433
# test_discrete_score_W_discrete_a 0.047862754216934894
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 330
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.07438188910963775
# test_discrete_score_W0_a 0.05593285755673904
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.05924517081319318
# test_discrete_score_W_discrete_a 0.04079411855373443
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 341
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.06607505951858378
# test_discrete_score_W_discrete_a 0.046450905314918384
# neuron unit number: 32
# self.train_new_embedding_sog_fuzzy.shape[1] 352
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.05667156972770682
# test_discrete_score_W0_a 0.04051000556253914
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.06747122526029369
# test_discrete_score_W_discrete_a 0.054989390350508566
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 363
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.06416488699288965
# test_discrete_score_W0_a 0.04594959430011517
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.06585238225385849
# test_discrete_score_W_discrete_a 0.05832539988156009
# neuron unit number: 34
# self.train_new_embedding_sog_fuzzy.shape[1] 374
# test_discrete_score_W0_p 0.36285097192224625
# test_discrete_score_W0_n 0.05669084967793293
# test_discrete_score_W0_a 0.0413394512553621
# test_discrete_score_W_discrete_p 0.4017278617710583
# test_discrete_score_W_discrete_n 0.046976701340969436
# test_discrete_score_W_discrete_a 0.03565108047894777
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 385
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.0591016636062654
# test_discrete_score_W0_a 0.0429693913654185
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.04721499338465317
# test_discrete_score_W_discrete_a 0.04009499418056048
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 36
# self.train_new_embedding_sog_fuzzy.shape[1] 396
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.06877803384883763
# test_discrete_score_W0_a 0.050171345713614916
# test_discrete_score_W_discrete_p 0.38876889848812096
# test_discrete_score_W_discrete_n 0.04344930587273998
# test_discrete_score_W_discrete_a 0.04004279315824286
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 407
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.06626543095590268
# test_discrete_score_W_discrete_a 0.05063781138746014
# neuron unit number: 38
# self.train_new_embedding_sog_fuzzy.shape[1] 418
# test_discrete_score_W0_p 0.3617710583153348
# test_discrete_score_W0_n 0.043939896759871436
# test_discrete_score_W0_a 0.03419512660547072
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.06872555180480967
# test_discrete_score_W_discrete_a 0.04713525936868915
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 429
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.05758396984642822
# test_discrete_score_W0_a 0.03991782843556803
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.058605363794072586
# test_discrete_score_W_discrete_a 0.04400305646248202
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 440
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.0617664488541663
# test_discrete_score_W0_a 0.0447988234518977
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.06033279713003467
# test_discrete_score_W_discrete_a 0.04853688747327664
# Not good nmi result for discrete features !!!!!
# neuron unit number: 41
# self.train_new_embedding_sog_fuzzy.shape[1] 451
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.05805759414572692
# test_discrete_score_W_discrete_a 0.037435894059832824
# neuron unit number: 42
# self.train_new_embedding_sog_fuzzy.shape[1] 462
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.07556446178739923
# test_discrete_score_W0_a 0.05348186206937387
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.05490181804775638
# test_discrete_score_W_discrete_a 0.04155718644364356
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 43
# self.train_new_embedding_sog_fuzzy.shape[1] 473
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.05486050357562203
# test_discrete_score_W_discrete_a 0.035224431204553194
# neuron unit number: 44
# self.train_new_embedding_sog_fuzzy.shape[1] 484
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.06280443187123594
# test_discrete_score_W0_a 0.04296268766029501
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.07867957727488017
# test_discrete_score_W_discrete_a 0.05150785958168225
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 495
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.061242979362101005
# test_discrete_score_W0_a 0.04733594321075812
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.06190898738807409
# test_discrete_score_W_discrete_a 0.03833875451877427
# Not good ari result for discrete features  !!!!!
# neuron unit number: 46
# self.train_new_embedding_sog_fuzzy.shape[1] 506
# test_discrete_score_W0_p 0.3617710583153348
# test_discrete_score_W0_n 0.05048475278950005
# test_discrete_score_W0_a 0.03916354072742924
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.05873564814223565
# test_discrete_score_W_discrete_a 0.032492666312454836
# Not good ari result for discrete features  !!!!!
# neuron unit number: 47
# self.train_new_embedding_sog_fuzzy.shape[1] 517
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.059247053967355405
# test_discrete_score_W_discrete_a 0.04338712319529058
# neuron unit number: 48
# self.train_new_embedding_sog_fuzzy.shape[1] 528
# test_discrete_score_W0_p 0.4200863930885529
# test_discrete_score_W0_n 0.08312979278456407
# test_discrete_score_W0_a 0.05508860937182349
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.06364662003683126
# test_discrete_score_W_discrete_a 0.044181137863975636
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 49
# self.train_new_embedding_sog_fuzzy.shape[1] 539
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.07608814423051924
# test_discrete_score_W0_a 0.050299719300130774
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.06394039768579529
# test_discrete_score_W_discrete_a 0.045397114357101864
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 550
# test_discrete_score_W0_p 0.3898488120950324
# test_discrete_score_W0_n 0.07149863916404137
# test_discrete_score_W0_a 0.05188157633001584
# test_discrete_score_W_discrete_p 0.4200863930885529
# test_discrete_score_W_discrete_n 0.0736066166021632
# test_discrete_score_W_discrete_a 0.051878362011668115
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.3697530284533759
# test_discrete_score_W_discrete_p mean 0.38848718189501363
# test_discrete_score_W0_n mean 0.04642323403530877
# test_discrete_score_W_discrete_n mean 0.0596003705495168
# test_discrete_score_W0_a mean 0.03326785032937775
# test_discrete_score_W_discrete_a mean 0.04329207441981922
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.046423  0.030492  0.004496   0.037368  0.055478
# 1  test_dis_W_dis  46.0  0.059600  0.008675  0.001279   0.057024  0.062176
# 2        combined  92.0  0.053012  0.023257  0.002425   0.048195  0.057828
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0132
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -2.8191
# 3                      Two side test p value =    0.0059
# 4                     Difference < 0 p value =    0.0030
# 5                     Difference > 0 p value =    0.9970
# 6                                  Cohen's d =   -0.5878
# 7                                  Hedge's g =   -0.5829
# 8                             Glass's delta1 =   -0.4321
# 9                           Point-Biserial r =   -0.2848
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.033268  0.021691  0.003198   0.026827  0.039709
# 1  test_dis_W_dis  46.0  0.043292  0.005958  0.000878   0.041523  0.045061
# 2        combined  92.0  0.038280  0.016601  0.001731   0.034842  0.041718
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0100
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -3.0225
# 3                      Two side test p value =    0.0033
# 4                     Difference < 0 p value =    0.0016
# 5                     Difference > 0 p value =    0.9984
# 6                                  Cohen's d =   -0.6302
# 7                                  Hedge's g =   -0.6250
# 8                             Glass's delta1 =   -0.4621
# 9                           Point-Biserial r =   -0.3036
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.369753  0.026624  0.003925   0.361847  0.377659
# 1  test_dis_W_dis  46.0  0.388487  0.012675  0.001869   0.384723  0.392251
# 2        combined  92.0  0.379120  0.022774  0.002374   0.374404  0.383837
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0187
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -4.3091
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -0.8985
# 7                                  Hedge's g =   -0.8910
# 8                             Glass's delta1 =   -0.7037
# 9                           Point-Biserial r =   -0.4136

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,9]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 55
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.36393088552915764
# test_discrete_score_W_discrete_n 0.04138376934533394
# test_discrete_score_W_discrete_a 0.03286972521617786
# neuron unit number: 6
# self.train_new_embedding_sog_fuzzy.shape[1] 66
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.05871267730103649
# test_discrete_score_W0_a 0.04272328372908189
# test_discrete_score_W_discrete_p 0.36393088552915764
# test_discrete_score_W_discrete_n 0.04138376934533394
# test_discrete_score_W_discrete_a 0.03286972521617786
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 7
# self.train_new_embedding_sog_fuzzy.shape[1] 77
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.37041036717062636
# test_discrete_score_W_discrete_n 0.05422695724760065
# test_discrete_score_W_discrete_a 0.03871759570680439
# neuron unit number: 8
# self.train_new_embedding_sog_fuzzy.shape[1] 88
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.05558152126715689
# test_discrete_score_W0_a 0.0343344094193038
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.045869520148323704
# test_discrete_score_W_discrete_a 0.034511148327709774
# Not good nmi result for discrete features !!!!!
# neuron unit number: 9
# self.train_new_embedding_sog_fuzzy.shape[1] 99
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.06380789428182528
# test_discrete_score_W0_a 0.046188634222236714
# test_discrete_score_W_discrete_p 0.367170626349892
# test_discrete_score_W_discrete_n 0.061752651600100045
# test_discrete_score_W_discrete_a 0.04373605151855665
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 110
# test_discrete_score_W0_p 0.36609071274298055
# test_discrete_score_W0_n 0.07016486192139972
# test_discrete_score_W0_a 0.04463059701091345
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.0579449026925268
# test_discrete_score_W_discrete_a 0.042789613650983084
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# self.train_new_embedding_sog_fuzzy.shape[1] 121
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.06858918999287088
# test_discrete_score_W_discrete_a 0.047853464077745135
# neuron unit number: 12
# self.train_new_embedding_sog_fuzzy.shape[1] 132
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.06599289682754785
# test_discrete_score_W0_a 0.047143058001459036
# test_discrete_score_W_discrete_p 0.3747300215982721
# test_discrete_score_W_discrete_n 0.05911895767906204
# test_discrete_score_W_discrete_a 0.04643487960411277
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 143
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.05949875561864994
# test_discrete_score_W_discrete_a 0.044438883826143194
# neuron unit number: 14
# self.train_new_embedding_sog_fuzzy.shape[1] 154
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.08251393217710701
# test_discrete_score_W0_a 0.058385360050810846
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.07084528962555818
# test_discrete_score_W_discrete_a 0.049826568947909516
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 165
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.06509390976628712
# test_discrete_score_W0_a 0.042925780287921156
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.05883185924953381
# test_discrete_score_W_discrete_a 0.04283020352693556
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 16
# self.train_new_embedding_sog_fuzzy.shape[1] 176
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.06435569985911507
# test_discrete_score_W0_a 0.04607469601679943
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.06058545247187909
# test_discrete_score_W_discrete_a 0.045721164364082675
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 187
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.06848224523934886
# test_discrete_score_W_discrete_a 0.050113029745423664
# neuron unit number: 18
# self.train_new_embedding_sog_fuzzy.shape[1] 198
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.06210808962886083
# test_discrete_score_W0_a 0.045380239540657064
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.07447803805734989
# test_discrete_score_W_discrete_a 0.0499740558702699
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 209
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.07405751244471573
# test_discrete_score_W_discrete_a 0.04819145723960876
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.07830403641225515
# test_discrete_score_W0_a 0.053143687339196014
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.0670834127359419
# test_discrete_score_W_discrete_a 0.04720356891690838
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.047864280486745306
# test_discrete_score_W0_a 0.032778578486809845
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.059453012901764996
# test_discrete_score_W_discrete_a 0.042837336482932
# neuron unit number: 22
# self.train_new_embedding_sog_fuzzy.shape[1] 242
# test_discrete_score_W0_p 0.36285097192224625
# test_discrete_score_W0_n 0.044157203489195475
# test_discrete_score_W0_a 0.03448016771267308
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.06067087556631627
# test_discrete_score_W_discrete_a 0.043599156588439644
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 253
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.06080435850777436
# test_discrete_score_W_discrete_a 0.044657205988685104
# neuron unit number: 24
# self.train_new_embedding_sog_fuzzy.shape[1] 264
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.06795228952017647
# test_discrete_score_W0_a 0.05206184121052665
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.06692776347106204
# test_discrete_score_W_discrete_a 0.0540243581470465
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 275
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.054613077038548
# test_discrete_score_W0_a 0.037367225116060554
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.0629566142241553
# test_discrete_score_W_discrete_a 0.04964985881938828
# Not good purity result for discrete features !!!!!
# neuron unit number: 26
# self.train_new_embedding_sog_fuzzy.shape[1] 286
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.07730586171875455
# test_discrete_score_W0_a 0.05277316230407564
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.06698693220605725
# test_discrete_score_W_discrete_a 0.04289618976316386
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 297
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.0650612335671398
# test_discrete_score_W0_a 0.04908207294094001
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.06879509297810417
# test_discrete_score_W_discrete_a 0.05137970029539873
# neuron unit number: 28
# self.train_new_embedding_sog_fuzzy.shape[1] 308
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.06437024554119126
# test_discrete_score_W0_a 0.038278376969300754
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.07343423937275616
# test_discrete_score_W_discrete_a 0.057915605443513166
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 319
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39092872570194387
# test_discrete_score_W_discrete_n 0.06790132195347635
# test_discrete_score_W_discrete_a 0.04909402072476627
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 330
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.07759978106965632
# test_discrete_score_W0_a 0.054560269068374696
# test_discrete_score_W_discrete_p 0.38876889848812096
# test_discrete_score_W_discrete_n 0.04738034264204166
# test_discrete_score_W_discrete_a 0.03668416404470912
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 341
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.05280855543674203
# test_discrete_score_W_discrete_a 0.04228297056286527
# neuron unit number: 32
# self.train_new_embedding_sog_fuzzy.shape[1] 352
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.06198895689520893
# test_discrete_score_W0_a 0.042714285373257596
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.05797265221633045
# test_discrete_score_W_discrete_a 0.040165343616613114
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 363
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.07170362477953658
# test_discrete_score_W0_a 0.051251378270156016
# test_discrete_score_W_discrete_p 0.3963282937365011
# test_discrete_score_W_discrete_n 0.06264185664403787
# test_discrete_score_W_discrete_a 0.03945068958186361
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 34
# self.train_new_embedding_sog_fuzzy.shape[1] 374
# test_discrete_score_W0_p 0.34233261339092874
# test_discrete_score_W0_n 0.029382840616985633
# test_discrete_score_W0_a 0.022117971978775387
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.051411508590443765
# test_discrete_score_W_discrete_a 0.03958299359620004
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 385
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.07905599646336152
# test_discrete_score_W0_a 0.05411912717056676
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.05228348551523467
# test_discrete_score_W_discrete_a 0.04296589903156769
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 36
# self.train_new_embedding_sog_fuzzy.shape[1] 396
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.06233754006993835
# test_discrete_score_W0_a 0.04640062900109557
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.06170311409186773
# test_discrete_score_W_discrete_a 0.043459460203113504
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 407
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.05175486566047765
# test_discrete_score_W_discrete_a 0.03834746678321323
# neuron unit number: 38
# self.train_new_embedding_sog_fuzzy.shape[1] 418
# test_discrete_score_W0_p 0.36609071274298055
# test_discrete_score_W0_n 0.07478380085703719
# test_discrete_score_W0_a 0.05361025293713295
# test_discrete_score_W_discrete_p 0.408207343412527
# test_discrete_score_W_discrete_n 0.0626344426011236
# test_discrete_score_W_discrete_a 0.04635947074090715
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 429
# test_discrete_score_W0_p 0.37365010799136067
# test_discrete_score_W0_n 0.061976754340960616
# test_discrete_score_W0_a 0.04521224721615941
# test_discrete_score_W_discrete_p 0.4103671706263499
# test_discrete_score_W_discrete_n 0.06595618545837661
# test_discrete_score_W_discrete_a 0.04451451744675228
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 440
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.06257489709670677
# test_discrete_score_W0_a 0.049330889351946475
# test_discrete_score_W_discrete_p 0.4114470842332613
# test_discrete_score_W_discrete_n 0.06976925619448227
# test_discrete_score_W_discrete_a 0.04873249950420889
# Not good ari result for discrete features  !!!!!
# neuron unit number: 41
# self.train_new_embedding_sog_fuzzy.shape[1] 451
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.062046272123552695
# test_discrete_score_W_discrete_a 0.04490657575414068
# neuron unit number: 42
# self.train_new_embedding_sog_fuzzy.shape[1] 462
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.07415292470442016
# test_discrete_score_W0_a 0.051030652064262445
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.0725130416647132
# test_discrete_score_W_discrete_a 0.05432738435095217
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 43
# self.train_new_embedding_sog_fuzzy.shape[1] 473
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.06497187270113881
# test_discrete_score_W_discrete_a 0.043603918760768086
# neuron unit number: 44
# self.train_new_embedding_sog_fuzzy.shape[1] 484
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.06561534266692866
# test_discrete_score_W0_a 0.046194155411760855
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.07556100874928612
# test_discrete_score_W_discrete_a 0.06286791248731627
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 495
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.048277586497624786
# test_discrete_score_W0_a 0.029037895592580645
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.05645339316864251
# test_discrete_score_W_discrete_a 0.040238568662309133
# neuron unit number: 46
# self.train_new_embedding_sog_fuzzy.shape[1] 506
# test_discrete_score_W0_p 0.3369330453563715
# test_discrete_score_W0_n 0.02908806802530949
# test_discrete_score_W0_a 0.021478864948976103
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.07428023460906409
# test_discrete_score_W_discrete_a 0.05232426052674574
# neuron unit number: 47
# self.train_new_embedding_sog_fuzzy.shape[1] 517
# test_discrete_score_W0_p 0.33369330453563717
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.06694243644883985
# test_discrete_score_W_discrete_a 0.04644052128732113
# neuron unit number: 48
# self.train_new_embedding_sog_fuzzy.shape[1] 528
# test_discrete_score_W0_p 0.42764578833693306
# test_discrete_score_W0_n 0.07910771787253906
# test_discrete_score_W0_a 0.05365383614789209
# test_discrete_score_W_discrete_p 0.4168466522678186
# test_discrete_score_W_discrete_n 0.075517363276071
# test_discrete_score_W_discrete_a 0.046102351583121225
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 49
# self.train_new_embedding_sog_fuzzy.shape[1] 539
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.0721725487221278
# test_discrete_score_W0_a 0.04966250719718463
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.07906816803721947
# test_discrete_score_W_discrete_a 0.05412604555304496
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 550
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.06459143524565199
# test_discrete_score_W0_a 0.03810901468620016
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.06421228636685665
# test_discrete_score_W_discrete_a 0.04289902297015222
# Not good nmi result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.3690487369706076
# test_discrete_score_W_discrete_p mean 0.39071743825711325
# test_discrete_score_W0_n mean 0.04570368536365948
# test_discrete_score_W_discrete_n mean 0.06260749645374215
# test_discrete_score_W0_a mean 0.03187467710380625
# test_discrete_score_W_discrete_a mean 0.04531557837079932
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.045704  0.030964  0.004565   0.036509  0.054899
# 1  test_dis_W_dis  46.0  0.062607  0.009006  0.001328   0.059933  0.065282
# 2        combined  92.0  0.054156  0.024217  0.002525   0.049140  0.059171
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0169
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -3.5553
# 3                      Two side test p value =    0.0006
# 4                     Difference < 0 p value =    0.0003
# 5                     Difference > 0 p value =    0.9997
# 6                                  Cohen's d =   -0.7413
# 7                                  Hedge's g =   -0.7351
# 8                             Glass's delta1 =   -0.5459
# 9                           Point-Biserial r =   -0.3509
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.031875  0.021651  0.003192   0.025445  0.038304
# 1  test_dis_W_dis  46.0  0.045316  0.006131  0.000904   0.043495  0.047136
# 2        combined  92.0  0.038595  0.017206  0.001794   0.035032  0.042158
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0134
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -4.0512
# 3                      Two side test p value =    0.0001
# 4                     Difference < 0 p value =    0.0001
# 5                     Difference > 0 p value =    0.9999
# 6                                  Cohen's d =   -0.8447
# 7                                  Hedge's g =   -0.8377
# 8                             Glass's delta1 =   -0.6208
# 9                           Point-Biserial r =   -0.3927
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.369049  0.027323  0.004029   0.360935  0.377163
# 1  test_dis_W_dis  46.0  0.390717  0.013370  0.001971   0.386747  0.394688
# 2        combined  92.0  0.379883  0.024005  0.002503   0.374912  0.384854
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0217
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -4.8314
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.0074
# 7                                  Hedge's g =   -0.9990
# 8                             Glass's delta1 =   -0.7931
# 9                           Point-Biserial r =   -0.4538
