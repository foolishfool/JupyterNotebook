# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Absenteeism/Absenteeism_at_work.csv")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Reason for absence")

# %%
def initialize_listoflist(scores_list):
    for i in range(0,scores_list.size):
        scores_list[i] = []

def getaveragescore(scores_list):
    for i in range(0,scores_list.size):
        average = np.average(scores_list[i])
        scores_list[i] = average

# %%
scoretype = 1
scope_num = 30
class_num = 28
dim_num = 20
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.7162162162162162
# right_data0_score_W0 1.0
# error_data0_score_W1 0.184306616538063
# error_data0_score_W0 0.126306439786961
# combinedweight shape 0: (56, 20)
# right_data0_score_W' 0.4832502879381779
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2098145327299688
# error_data1_score_W0 0.123494359137192
# combinedweight shape1 : (84, 20)
# right_data1_score_W' 0.5094911348176758
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28125652948162794
# error_data2_score_W0 0.1499965289181909
# combinedweight shape1 : (112, 20)
# right_data2_score_W' 0.5928579622342827
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.28837272643026773
# error_data3_score_W0 0.11808852545887247
# combinedweight shape1 : (140, 20)
# right_data3_score_W' 0.7258726882562615
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.31879685417630876
# error_data4_score_W0 0.1486651207154377
# combinedweight shape1 : (168, 20)
# right_data4_score_W' 0.6849297574128884
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4389030728304961
# error_data5_score_W0 0.19748742057318858
# combinedweight shape1 : (196, 20)
# right_data5_score_W' 0.6803093454892144
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.428809394430557
# error_data6_score_W0 0.20266927098740767
# combinedweight shape1 : (224, 20)
# right_data6_score_W' 0.7517785405312161
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4853893848739299
# error_data7_score_W0 0.2981438119103544
# combinedweight shape1 : (252, 20)
# right_data7_score_W' 0.7741655945855884
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5261276857731476
# error_data8_score_W0 0.38910304400843015
# combinedweight shape1 : (280, 20)
# right_data8_score_W' 0.8318956723464143
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6316659567292161
# error_data9_score_W0 0.4550722752569379
# combinedweight shape1 : (308, 20)
# right_data9_score_W' 0.8283419256373167
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.8048377108888054
# error_data10_score_W0 0.5734831299946331
# combinedweight shape1 : (336, 20)
# right_data10_score_W' 0.9445272649374314
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 0.7918756684685216
# combinedweight shape1 : (364, 20)
# right_data11_score_W' 0.9246117268712489
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1253892141020595
# all_train_score_W': 0.9732428980568271
# test_score_W0 : 0.10431087014258272
# test_score_W': 0.3466406735133025
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.7200772200772201
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21327062931881852
# error_data0_score_W0 0.14367570424533985
# combinedweight shape 0: (112, 20)
# right_data0_score_W' 0.4197827526275814
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2355006424867528
# error_data1_score_W0 0.1539254817887951
# combinedweight shape1 : (168, 20)
# right_data1_score_W' 0.6179336272732121
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28789498660096763
# error_data2_score_W0 0.1648109678185007
# combinedweight shape1 : (224, 20)
# right_data2_score_W' 0.5572934913736786
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3297148282586338
# error_data3_score_W0 0.18338880435444438
# combinedweight shape1 : (280, 20)
# right_data3_score_W' 0.6959696677866313
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3858992849115208
# error_data4_score_W0 0.20849746407518463
# combinedweight shape1 : (336, 20)
# right_data4_score_W' 0.7096975206654725
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.41302479866970254
# error_data5_score_W0 0.240499331193863
# combinedweight shape1 : (392, 20)
# right_data5_score_W' 0.7443644417516008
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.4970937621325249
# error_data6_score_W0 0.2504102605951131
# combinedweight shape1 : (448, 20)
# right_data6_score_W' 0.8048384689590349
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4985864566219442
# error_data7_score_W0 0.26404279234669265
# combinedweight shape1 : (504, 20)
# right_data7_score_W' 0.8040038768531333
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5542451339955946
# error_data8_score_W0 0.42304719037545563
# combinedweight shape1 : (560, 20)
# right_data8_score_W' 0.8650908689125241
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.733406342478337
# error_data9_score_W0 0.5294509633736092
# combinedweight shape1 : (616, 20)
# right_data9_score_W' 0.9090909090909091
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.884025111448191
# error_data10_score_W0 0.6764971842744295
# combinedweight shape1 : (672, 20)
# right_data10_score_W' 0.9315520459418734
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (728, 20)
# right_data11_score_W' 0.8189625508803525
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.13613452230134523
# all_train_score_W': 0.9732428980568271
# test_score_W0 : 0.15571199666042743
# test_score_W': 0.3466406735133025
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.6795366795366795
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21432979309845354
# error_data0_score_W0 0.15729326831968374
# combinedweight shape 0: (168, 20)
# right_data0_score_W' 0.5555763083936456
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20483635951785456
# error_data1_score_W0 0.13147641788876507
# combinedweight shape1 : (252, 20)
# right_data1_score_W' 0.530804864748317
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31999230825168895
# error_data2_score_W0 0.16765269778188216
# combinedweight shape1 : (336, 20)
# right_data2_score_W' 0.6227480495817942
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.35841332867438447
# error_data3_score_W0 0.158462717375075
# combinedweight shape1 : (420, 20)
# right_data3_score_W' 0.7487070690999924
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.41515450055004555
# error_data4_score_W0 0.1600500844388659
# combinedweight shape1 : (504, 20)
# right_data4_score_W' 0.7192213687869864
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4430754002889435
# error_data5_score_W0 0.2923475196825353
# combinedweight shape1 : (588, 20)
# right_data5_score_W' 0.7187783832347214
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5512066047913309
# error_data6_score_W0 0.2947597165737448
# combinedweight shape1 : (672, 20)
# right_data6_score_W' 0.7711570177143927
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6159506506217486
# error_data7_score_W0 0.3022192479899451
# combinedweight shape1 : (756, 20)
# right_data7_score_W' 0.8313872537712711
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6817360906096187
# error_data8_score_W0 0.35830355628691885
# combinedweight shape1 : (840, 20)
# right_data8_score_W' 0.7418334361139165
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6294832607672233
# error_data9_score_W0 0.33355209088790394
# combinedweight shape1 : (924, 20)
# right_data9_score_W' 0.8825386262063205
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.2740175421212811
# combinedweight shape1 : (1008, 20)
# right_data10_score_W' 0.822328362394686
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1706943327184604
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.18486128614653852
# test_score_W': 0.34830942675001675
# neuron unit number: 112
# *******************
# Error Data percentage 0.693050193050193
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23385562762143391
# error_data0_score_W0 0.15590509662457866
# combinedweight shape 0: (224, 20)
# right_data0_score_W' 0.5850227519553155
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2168340759259123
# error_data1_score_W0 0.12034432865316297
# combinedweight shape1 : (336, 20)
# right_data1_score_W' 0.6174540280684746
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29206843749159284
# error_data2_score_W0 0.16196459423816026
# combinedweight shape1 : (448, 20)
# right_data2_score_W' 0.5305358820716959
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.38305984904098356
# error_data3_score_W0 0.1829939365526006
# combinedweight shape1 : (560, 20)
# right_data3_score_W' 0.64813954612401
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38860124002909063
# error_data4_score_W0 0.2018418120686042
# combinedweight shape1 : (672, 20)
# right_data4_score_W' 0.7383892177244044
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.470305916124112
# error_data5_score_W0 0.17713781923246172
# combinedweight shape1 : (784, 20)
# right_data5_score_W' 0.7496747284824546
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5781184635909168
# error_data6_score_W0 0.2576341190558843
# combinedweight shape1 : (896, 20)
# right_data6_score_W' 0.8130805403551431
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6144195411615189
# error_data7_score_W0 0.20978611869447322
# combinedweight shape1 : (1008, 20)
# right_data7_score_W' 0.8107568499178791
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6338241949716024
# error_data8_score_W0 0.18138441778818273
# combinedweight shape1 : (1120, 20)
# right_data8_score_W' 0.7901285219616305
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.7968156220676632
# error_data9_score_W0 0.1462239577578469
# combinedweight shape1 : (1232, 20)
# right_data9_score_W' 0.822816179864442
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.0
# combinedweight shape1 : (1344, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.15711636520037042
# all_train_score_W': 0.9732428980568271
# test_score_W0 : 0.188415172170706
# test_score_W': 0.3466406735133025
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.6911196911196911
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20601172116357888
# error_data0_score_W0 0.15450144613625394
# combinedweight shape 0: (280, 20)
# right_data0_score_W' 0.5884662864242085
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23669387708141815
# error_data1_score_W0 0.12489654761718286
# combinedweight shape1 : (420, 20)
# right_data1_score_W' 0.589462477997318
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3121865896395857
# error_data2_score_W0 0.19164336838998117
# combinedweight shape1 : (560, 20)
# right_data2_score_W' 0.6269477181247657
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.35480071335010727
# error_data3_score_W0 0.15590636468559774
# combinedweight shape1 : (700, 20)
# right_data3_score_W' 0.7147311312870113
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.42275162128621435
# error_data4_score_W0 0.19229501862244738
# combinedweight shape1 : (840, 20)
# right_data4_score_W' 0.6670172031826681
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.49370130045476046
# error_data5_score_W0 0.25038707930384035
# combinedweight shape1 : (980, 20)
# right_data5_score_W' 0.7316542860746827
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5453594542932481
# error_data6_score_W0 0.1764365096845136
# combinedweight shape1 : (1120, 20)
# right_data6_score_W' 0.7478677122711238
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6635425533613362
# error_data7_score_W0 0.16530070780281364
# combinedweight shape1 : (1260, 20)
# right_data7_score_W' 0.8177734667035214
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.722712979457676
# error_data8_score_W0 0.16812060584911132
# combinedweight shape1 : (1400, 20)
# right_data8_score_W' 0.8778873720311172
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.24661202918433175
# combinedweight shape1 : (1540, 20)
# right_data9_score_W' 0.9505261186143643
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16016753369346134
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.18122864508960432
# test_score_W': 0.3476824755948417
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21668588749783607
# error_data0_score_W0 0.15017498078184088
# combinedweight shape 0: (336, 20)
# right_data0_score_W' 0.5711503868906448
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23963489457240017
# error_data1_score_W0 0.13537884376157686
# combinedweight shape1 : (504, 20)
# right_data1_score_W' 0.5994855872545883
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3009690695578647
# error_data2_score_W0 0.1278977791254104
# combinedweight shape1 : (672, 20)
# right_data2_score_W' 0.6313625479137727
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.33593094834354315
# error_data3_score_W0 0.10782280469244976
# combinedweight shape1 : (840, 20)
# right_data3_score_W' 0.7884859681849904
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4259291798834799
# error_data4_score_W0 0.12088667393098931
# combinedweight shape1 : (1008, 20)
# right_data4_score_W' 0.6607764120179064
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4854588110337453
# error_data5_score_W0 0.20125856181723556
# combinedweight shape1 : (1176, 20)
# right_data5_score_W' 0.7590712136914644
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.48101854746129546
# error_data6_score_W0 0.19358746134699586
# combinedweight shape1 : (1344, 20)
# right_data6_score_W' 0.8103246822476121
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6074899569911142
# error_data7_score_W0 0.26880442936008014
# combinedweight shape1 : (1512, 20)
# right_data7_score_W' 0.7941666965794867
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6395808117799536
# error_data8_score_W0 0.4832096709545601
# combinedweight shape1 : (1680, 20)
# right_data8_score_W' 0.864937779230575
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8186369418925545
# error_data9_score_W0 0.4135761819989919
# combinedweight shape1 : (1848, 20)
# right_data9_score_W' 0.8228161798644421
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.0
# combinedweight shape1 : (2016, 20)
# right_data10_score_W' 0.8519590445170675
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16707840357576992
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.19893345519468647
# test_score_W': 0.3476824755948417
# neuron unit number: 196
# *******************
#
# Error Data percentage 0.6698841698841699
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20553746071107745
# error_data0_score_W0 0.15133235908593892
# combinedweight shape 0: (392, 20)
# right_data0_score_W' 0.5826014671514441
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23803186065839532
# error_data1_score_W0 0.09674368569796275
# combinedweight shape1 : (588, 20)
# right_data1_score_W' 0.5804622523727297
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31966116939797334
# error_data2_score_W0 0.11153922502975311
# combinedweight shape1 : (784, 20)
# right_data2_score_W' 0.6070595998392502
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40731680770062906
# error_data3_score_W0 0.23527879551743783
# combinedweight shape1 : (980, 20)
# right_data3_score_W' 0.6859805020740453
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.41872946010538087
# error_data4_score_W0 0.16590733480194822
# combinedweight shape1 : (1176, 20)
# right_data4_score_W' 0.7127747540697013
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.491154453199906
# error_data5_score_W0 0.15309659419753907
# combinedweight shape1 : (1372, 20)
# right_data5_score_W' 0.7815999526782591
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.578852101343662
# error_data6_score_W0 0.2054007987436975
# combinedweight shape1 : (1568, 20)
# right_data6_score_W' 0.7691609461788518
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6422211660198839
# error_data7_score_W0 0.26553872132616974
# combinedweight shape1 : (1764, 20)
# right_data7_score_W' 0.7454277247829574
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6957670341262344
# error_data8_score_W0 0.3760814469519632
# combinedweight shape1 : (1960, 20)
# right_data8_score_W' 0.8034732983841154
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6712694853274374
# error_data9_score_W0 0.4743509876140318
# combinedweight shape1 : (2156, 20)
# right_data9_score_W' 0.9565217391304347
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (2352, 20)
# right_data10_score_W' 0.8571428571428571
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1750682487922725
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.20899325236017272
# test_score_W': 0.34830942675001675
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2405339612788036
# error_data0_score_W0 0.18128864426451347
# combinedweight shape 0: (448, 20)
# right_data0_score_W' 0.6101927091740285
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2609293281652467
# error_data1_score_W0 0.10827617255301834
# combinedweight shape1 : (672, 20)
# right_data1_score_W' 0.559027272295105
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3317639481242757
# error_data2_score_W0 0.13109989512620845
# combinedweight shape1 : (896, 20)
# right_data2_score_W' 0.6040779739775449
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40860126241246747
# error_data3_score_W0 0.16217570749334267
# combinedweight shape1 : (1120, 20)
# right_data3_score_W' 0.5764869723850709
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.43872075885257616
# error_data4_score_W0 0.15756744682228765
# combinedweight shape1 : (1344, 20)
# right_data4_score_W' 0.6938717178445118
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4661561186129116
# error_data5_score_W0 0.14986944027960603
# combinedweight shape1 : (1568, 20)
# right_data5_score_W' 0.755163593826854
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5976142899094938
# error_data6_score_W0 0.19759811206664207
# combinedweight shape1 : (1792, 20)
# right_data6_score_W' 0.7157420483952172
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6341370402457854
# error_data7_score_W0 0.08992148987684373
# combinedweight shape1 : (2016, 20)
# right_data7_score_W' 0.7492224457978357
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5047870942353422
# error_data8_score_W0 0.20543860534278371
# combinedweight shape1 : (2240, 20)
# right_data8_score_W' 0.8575015337075814
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6666666666666666
# error_data9_score_W0 0.2693558349079911
# combinedweight shape1 : (2464, 20)
# right_data9_score_W' 0.8189625508803525
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (2688, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20895110940244704
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.25359455662453856
# test_score_W': 0.3476824755948417
# neuron unit number: 252
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.1994500166186641
# error_data0_score_W0 0.130116219642821
# combinedweight shape 0: (504, 20)
# right_data0_score_W' 0.496183845965096
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.21375336773773734
# error_data1_score_W0 0.11876398234530985
# combinedweight shape1 : (756, 20)
# right_data1_score_W' 0.5600563452774743
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31758050445366054
# error_data2_score_W0 0.14073717933356159
# combinedweight shape1 : (1008, 20)
# right_data2_score_W' 0.5774126994455723
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3628715630348147
# error_data3_score_W0 0.1610347723845436
# combinedweight shape1 : (1260, 20)
# right_data3_score_W' 0.692174439361981
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3998268180747371
# error_data4_score_W0 0.1681895732453392
# combinedweight shape1 : (1512, 20)
# right_data4_score_W' 0.8045928368270082
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4847525532091432
# error_data5_score_W0 0.17773538236531175
# combinedweight shape1 : (1764, 20)
# right_data5_score_W' 0.7920054687684284
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.506159154438204
# error_data6_score_W0 0.23437055960692818
# combinedweight shape1 : (2016, 20)
# right_data6_score_W' 0.6851459985701119
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6588942043198054
# error_data7_score_W0 0.22171135876919243
# combinedweight shape1 : (2268, 20)
# right_data7_score_W' 0.8034990266176913
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7015633108414281
# error_data8_score_W0 0.3308751812876516
# combinedweight shape1 : (2520, 20)
# right_data8_score_W' 0.8625215077069525
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6775148272677979
# error_data9_score_W0 0.11481634102168048
# combinedweight shape1 : (2772, 20)
# right_data9_score_W' 0.8487312231733642
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (3024, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16238889373361368
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.16521371197612955
# test_score_W': 0.3476824755948417
# neuron unit number: 280
# *******************
#
# Error Data percentage 0.6602316602316602
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21180877139254836
# error_data0_score_W0 0.17268401968579197
# combinedweight shape 0: (560, 20)
# right_data0_score_W' 0.5683208549338498
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.24539267490581768
# error_data1_score_W0 0.13171641946311266
# combinedweight shape1 : (840, 20)
# right_data1_score_W' 0.5706703224228903
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2851970777636764
# error_data2_score_W0 0.1732189106618772
# combinedweight shape1 : (1120, 20)
# right_data2_score_W' 0.5833732282349238
# Finish one training *********
# 3
# right_data3_score_W0 1.0000000000000002
# error_data3_score_W1 0.38883824573360715
# error_data3_score_W0 0.21014451490399638
# combinedweight shape1 : (1400, 20)
# right_data3_score_W' 0.6643989947051071
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.4660510994763859
# error_data4_score_W0 0.2608920103765349
# combinedweight shape1 : (1680, 20)
# right_data4_score_W' 0.7849878681397308
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5029084422715487
# error_data5_score_W0 0.2750655363658361
# combinedweight shape1 : (1960, 20)
# right_data5_score_W' 0.7205081978302358
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5711618038147401
# error_data6_score_W0 0.40883374733332956
# combinedweight shape1 : (2240, 20)
# right_data6_score_W' 0.7889370620357968
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6294378613274175
# error_data7_score_W0 0.4934736523059826
# combinedweight shape1 : (2520, 20)
# right_data7_score_W' 0.7750050303241238
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6157229319010113
# error_data8_score_W0 0.49021033377267353
# combinedweight shape1 : (2800, 20)
# right_data8_score_W' 0.8078134272252565
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.737175493807016
# error_data9_score_W0 0.6515533942552646
# combinedweight shape1 : (3080, 20)
# right_data9_score_W' 0.7330209011585911
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (3360, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.19541260233082142
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.23944980997415635
# test_score_W': 0.3476824755948417
# neuron unit number: 308
# *******************
#
# Error Data percentage 0.6525096525096525
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22324707171949068
# error_data0_score_W0 0.17476896690223642
# combinedweight shape 0: (616, 20)
# right_data0_score_W' 0.507031665537477
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23111305861478362
# error_data1_score_W0 0.1433366311451009
# combinedweight shape1 : (924, 20)
# right_data1_score_W' 0.5512622396513408
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29941206767755296
# error_data2_score_W0 0.12648640509209502
# combinedweight shape1 : (1232, 20)
# right_data2_score_W' 0.5893189637697436
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3722120845397349
# error_data3_score_W0 0.160437486681451
# combinedweight shape1 : (1540, 20)
# right_data3_score_W' 0.6793790169598306
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4412870828332489
# error_data4_score_W0 0.15706408545078082
# combinedweight shape1 : (1848, 20)
# right_data4_score_W' 0.6995288173789621
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.42691189130768425
# error_data5_score_W0 0.1965382650853385
# combinedweight shape1 : (2156, 20)
# right_data5_score_W' 0.74941733221528
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5846170923108625
# error_data6_score_W0 0.23147768077727895
# combinedweight shape1 : (2464, 20)
# right_data6_score_W' 0.6918255697984477
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6411199326901065
# error_data7_score_W0 0.3222792697934536
# combinedweight shape1 : (2772, 20)
# right_data7_score_W' 0.7524530449656456
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6623843373872026
# error_data8_score_W0 0.37103454246065626
# combinedweight shape1 : (3080, 20)
# right_data8_score_W' 0.8731580672754992
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.0
# combinedweight shape1 : (3388, 20)
# right_data9_score_W' 0.9
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.2022824910336837
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.22420781005881643
# test_score_W': 0.3476824755948417
# neuron unit number: 336
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23269858090485923
# error_data0_score_W0 0.17239922164413965
# combinedweight shape 0: (672, 20)
# right_data0_score_W' 0.5063947991337647
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2755072181279609
# error_data1_score_W0 0.08164180466977976
# combinedweight shape1 : (1008, 20)
# right_data1_score_W' 0.5309295862487722
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.34089814212120706
# error_data2_score_W0 0.0919534687386611
# combinedweight shape1 : (1344, 20)
# right_data2_score_W' 0.7032248672247926
# Finish one training *********
# 3
# right_data3_score_W0 1.0000000000000002
# error_data3_score_W1 0.40762228036203196
# error_data3_score_W0 0.15834665214059426
# combinedweight shape1 : (1680, 20)
# right_data3_score_W' 0.6485920319346292
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4408703795556209
# error_data4_score_W0 0.22168138625630654
# combinedweight shape1 : (2016, 20)
# right_data4_score_W' 0.6808245785089457
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5199902938180112
# error_data5_score_W0 0.11584317072792204
# combinedweight shape1 : (2352, 20)
# right_data5_score_W' 0.7173068408931876
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.581942391403756
# error_data6_score_W0 0.2469617655314895
# combinedweight shape1 : (2688, 20)
# right_data6_score_W' 0.7575403343089289
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6606526019111773
# error_data7_score_W0 0.3202272477945745
# combinedweight shape1 : (3024, 20)
# right_data7_score_W' 0.7808587024500466
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.33876262915585054
# combinedweight shape1 : (3360, 20)
# right_data8_score_W' 0.7779531588078218
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.2740175421212811
# error_data9_score_W0 0.2740175421212811
# combinedweight shape1 : (3696, 20)
# right_data9_score_W' 0.9200625111439561
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (4032, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.19914444858309788
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.24583476036053736
# test_score_W': 0.3476824755948417
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.6756756756756757
# right_data0_score_W0 1.0
# error_data0_score_W1 0.228868233509625
# error_data0_score_W0 0.16061580477220566
# combinedweight shape 0: (728, 20)
# right_data0_score_W' 0.5500373911888403
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26138453858973926
# error_data1_score_W0 0.1358508172584139
# combinedweight shape1 : (1092, 20)
# right_data1_score_W' 0.5351905902741653
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.37455931566571615
# error_data2_score_W0 0.11159826794325468
# combinedweight shape1 : (1456, 20)
# right_data2_score_W' 0.5833277277129646
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.38029460491135086
# error_data3_score_W0 0.16457089441834896
# combinedweight shape1 : (1820, 20)
# right_data3_score_W' 0.6710263337555348
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4493091033280302
# error_data4_score_W0 0.13108587700319183
# combinedweight shape1 : (2184, 20)
# right_data4_score_W' 0.6876293437734414
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4975024712467954
# error_data5_score_W0 0.163591837428772
# combinedweight shape1 : (2548, 20)
# right_data5_score_W' 0.7340626841230324
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6396788166021438
# error_data6_score_W0 0.18139902058495289
# combinedweight shape1 : (2912, 20)
# right_data6_score_W' 0.7446716211616766
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5520511321187771
# error_data7_score_W0 0.2455725561710027
# combinedweight shape1 : (3276, 20)
# right_data7_score_W' 0.8296854426151284
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.45235407972988223
# error_data8_score_W0 0.2611272151678901
# combinedweight shape1 : (3640, 20)
# right_data8_score_W' 0.8571428571428571
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.5678815282792384
# combinedweight shape1 : (4004, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16905830331587451
# all_train_score_W': 0.9669440944348227
# test_score_W0 : 0.2124373037522906
# test_score_W': 0.34750124961538664
# neuron unit number: 392
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22837188386289042
# error_data0_score_W0 0.1674362591801234
# combinedweight shape 0: (784, 20)
# right_data0_score_W' 0.47058581130832183
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2579739500290419
# error_data1_score_W0 0.08279184796504932
# combinedweight shape1 : (1176, 20)
# right_data1_score_W' 0.5753990891561361
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.32920655480755895
# error_data2_score_W0 0.0960197136617073
# combinedweight shape1 : (1568, 20)
# right_data2_score_W' 0.5899994582592447
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4375660179474442
# error_data3_score_W0 0.19320553807248528
# combinedweight shape1 : (1960, 20)
# right_data3_score_W' 0.6670659365046654
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4784388767488715
# error_data4_score_W0 0.10711123778842603
# combinedweight shape1 : (2352, 20)
# right_data4_score_W' 0.7147098562985474
# Finish one training *********
# 5
# right_data5_score_W0 1.0000000000000002
# error_data5_score_W1 0.5945207858255785
# error_data5_score_W0 0.19605971856689988
# combinedweight shape1 : (2744, 20)
# right_data5_score_W' 0.7207490970266182
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6971514582919115
# error_data6_score_W0 0.1952922115047877
# combinedweight shape1 : (3136, 20)
# right_data6_score_W' 0.7068414053211678
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7602878262552523
# error_data7_score_W0 0.16939741126053048
# combinedweight shape1 : (3528, 20)
# right_data7_score_W' 0.8570398853450114
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.0
# combinedweight shape1 : (3920, 20)
# right_data8_score_W' 0.8936897079186652
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1836933815030215
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.22522840702106586
# test_score_W': 0.3476824755948417
# neuron unit number: 420
# *******************
#
# Error Data percentage 0.666023166023166
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20824434194153865
# error_data0_score_W0 0.16094802500953326
# combinedweight shape 0: (840, 20)
# right_data0_score_W' 0.6306618266462113
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.25970137589657666
# error_data1_score_W0 0.10427783046734937
# combinedweight shape1 : (1260, 20)
# right_data1_score_W' 0.570567212507688
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31477280703359956
# error_data2_score_W0 0.1475646325217684
# combinedweight shape1 : (1680, 20)
# right_data2_score_W' 0.5974955374795713
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3669938649469051
# error_data3_score_W0 0.1773049045630813
# combinedweight shape1 : (2100, 20)
# right_data3_score_W' 0.7675273029343964
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.43075224230288955
# error_data4_score_W0 0.20529555806826413
# combinedweight shape1 : (2520, 20)
# right_data4_score_W' 0.6876596139218998
# Finish one training *********
# 5
# right_data5_score_W0 1.0000000000000002
# error_data5_score_W1 0.48617399025181945
# error_data5_score_W0 0.12004614546140858
# combinedweight shape1 : (2940, 20)
# right_data5_score_W' 0.7540237019618379
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6300556678142433
# error_data6_score_W0 0.22127907767553864
# combinedweight shape1 : (3360, 20)
# right_data6_score_W' 0.7213941182995391
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6417095019680872
# error_data7_score_W0 0.2543698230667295
# combinedweight shape1 : (3780, 20)
# right_data7_score_W' 0.8296854426151284
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.34028398819332006
# combinedweight shape1 : (4200, 20)
# right_data8_score_W' 0.8283419256373168
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.3437110184854508
# error_data9_score_W0 0.2693558349079911
# combinedweight shape1 : (4620, 20)
# right_data9_score_W' 0.8571428571428571
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5040, 20)
# right_data10_score_W' 0.7336804366512112
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1829451683192957
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.19321652276322943
# test_score_W': 0.3476824755948417
# neuron unit number: 448
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2334959331381532
# error_data0_score_W0 0.17531276582147934
# combinedweight shape 0: (896, 20)
# right_data0_score_W' 0.5437556497758925
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2512081345441459
# error_data1_score_W0 0.13319807885691207
# combinedweight shape1 : (1344, 20)
# right_data1_score_W' 0.5481000852374786
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3401346208222107
# error_data2_score_W0 0.1274909885055521
# combinedweight shape1 : (1792, 20)
# right_data2_score_W' 0.5569537505072609
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40599110759565193
# error_data3_score_W0 0.1766543630505541
# combinedweight shape1 : (2240, 20)
# right_data3_score_W' 0.7136180442653101
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4811874818532224
# error_data4_score_W0 0.14186033119763572
# combinedweight shape1 : (2688, 20)
# right_data4_score_W' 0.7449834004269332
# Finish one training *********
# 5
# right_data5_score_W0 1.0000000000000002
# error_data5_score_W1 0.5908019047195922
# error_data5_score_W0 0.23576926701597664
# combinedweight shape1 : (3136, 20)
# right_data5_score_W' 0.7507962543786647
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6126492971120643
# error_data6_score_W0 0.25550125212517955
# combinedweight shape1 : (3584, 20)
# right_data6_score_W' 0.8188200034147459
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7232630682175437
# error_data7_score_W0 0.29280451529123375
# combinedweight shape1 : (4032, 20)
# right_data7_score_W' 0.8415264788807096
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.2693558349079911
# error_data8_score_W0 0.0
# combinedweight shape1 : (4480, 20)
# right_data8_score_W' 0.8700141279140435
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.0
# error_data9_score_W0 0.0
# combinedweight shape1 : (4928, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5376, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20022701177066715
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.23648002659160083
# test_score_W': 0.34581891737107207
# neuron unit number: 476
# *******************
#
# Error Data percentage 0.6621621621621622
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22419254285381732
# error_data0_score_W0 0.15011675898074114
# combinedweight shape 0: (952, 20)
# right_data0_score_W' 0.4649338534271013
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23546232600897057
# error_data1_score_W0 0.09105257058258835
# combinedweight shape1 : (1428, 20)
# right_data1_score_W' 0.5800478693583445
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31435299500153896
# error_data2_score_W0 0.10105909664416762
# combinedweight shape1 : (1904, 20)
# right_data2_score_W' 0.560861521177986
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3923774502534638
# error_data3_score_W0 0.17160708957810786
# combinedweight shape1 : (2380, 20)
# right_data3_score_W' 0.6059024906547256
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.39658283934726163
# error_data4_score_W0 0.146155482150518
# combinedweight shape1 : (2856, 20)
# right_data4_score_W' 0.7648912533628723
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5039052476237217
# error_data5_score_W0 0.20215187673007617
# combinedweight shape1 : (3332, 20)
# right_data5_score_W' 0.7475644567192059
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5752085303437353
# error_data6_score_W0 0.21392290245434842
# combinedweight shape1 : (3808, 20)
# right_data6_score_W' 0.8028324478798183
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6856335524148305
# error_data7_score_W0 0.2523839004463063
# combinedweight shape1 : (4284, 20)
# right_data7_score_W' 0.8692344773394185
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7367088530163903
# error_data8_score_W0 0.2757769402592413
# combinedweight shape1 : (4760, 20)
# right_data8_score_W' 0.8483686100754009
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.39999999999999997
# error_data9_score_W0 0.0
# combinedweight shape1 : (5236, 20)
# right_data9_score_W' 0.9090909090909091
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5712, 20)
# right_data10_score_W' 0.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17938653816081793
# all_train_score_W': 0.9722691624242832
# test_score_W0 : 0.18492420554534228
# test_score_W': 0.3460150890340086
# neuron unit number: 504
# *******************
#
# Error Data percentage 0.6718146718146718
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2123707105434942
# error_data0_score_W0 0.16108847901591147
# combinedweight shape 0: (1008, 20)
# right_data0_score_W' 0.6508672460957162
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2613554477962118
# error_data1_score_W0 0.11283078270163936
# combinedweight shape1 : (1512, 20)
# right_data1_score_W' 0.5872619770944136
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3293195816761051
# error_data2_score_W0 0.07968842916118293
# combinedweight shape1 : (2016, 20)
# right_data2_score_W' 0.6436706250002492
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.43139962071307186
# error_data3_score_W0 0.14265288687259076
# combinedweight shape1 : (2520, 20)
# right_data3_score_W' 0.7085276565616592
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.43772433024378127
# error_data4_score_W0 0.19035858713519932
# combinedweight shape1 : (3024, 20)
# right_data4_score_W' 0.6993700275612782
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.48543005218299384
# error_data5_score_W0 0.21817016308316334
# combinedweight shape1 : (3528, 20)
# right_data5_score_W' 0.6532378813357967
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5676963962158362
# error_data6_score_W0 0.27058860980433325
# combinedweight shape1 : (4032, 20)
# right_data6_score_W' 0.6810924210679582
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6316563297480654
# error_data7_score_W0 0.1576301319724114
# combinedweight shape1 : (4536, 20)
# right_data7_score_W' 0.7335564933339042
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5438353977530026
# error_data8_score_W0 0.2444439821583827
# combinedweight shape1 : (5040, 20)
# right_data8_score_W' 0.8283419256373168
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6666666666666666
# error_data9_score_W0 0.2693558349079911
# combinedweight shape1 : (5544, 20)
# right_data9_score_W' 0.7134063057636204
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (6048, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17791134084415142
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.19481657752630513
# test_score_W': 0.3486942897836553
# neuron unit number: 532
# *******************
#
# Error Data percentage 0.6563706563706564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22113162055766727
# error_data0_score_W0 0.17326779962847222
# combinedweight shape 0: (1064, 20)
# right_data0_score_W' 0.5719389243754868
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26879824360809335
# error_data1_score_W0 0.10631225907649017
# combinedweight shape1 : (1596, 20)
# right_data1_score_W' 0.539247777519748
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3485797072076592
# error_data2_score_W0 0.15060156503931071
# combinedweight shape1 : (2128, 20)
# right_data2_score_W' 0.5344777419542591
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.38864352094309723
# error_data3_score_W0 0.10442434791736982
# combinedweight shape1 : (2660, 20)
# right_data3_score_W' 0.5830312597212772
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.47162978604720435
# error_data4_score_W0 0.15534657519071127
# combinedweight shape1 : (3192, 20)
# right_data4_score_W' 0.625696117050935
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5276030939494857
# error_data5_score_W0 0.12441681246827069
# combinedweight shape1 : (3724, 20)
# ...
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (7392, 20)
# right_data9_score_W' 0.8571428571428571
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17800566261116466
# all_train_score_W': 0.9670022629337099
# test_score_W0 : 0.2339069872506183
# test_score_W': 0.34742880763691186
# neuron unit number: 700
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22465845854288857
# error_data0_score_W0 0.17970485638918562
# combinedweight shape 0: (1400, 20)
# right_data0_score_W' 0.5058798870706191
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27134301162422025
# error_data1_score_W0 0.1284147281033921
# combinedweight shape1 : (2100, 20)
# right_data1_score_W' 0.47846561821668654
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3382042374729929
# error_data2_score_W0 0.13573455824843766
# combinedweight shape1 : (2800, 20)
# right_data2_score_W' 0.682860486132256
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.42102187556639653
# error_data3_score_W0 0.058191890155406135
# combinedweight shape1 : (3500, 20)
# right_data3_score_W' 0.662033515817262
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.49131494348463023
# error_data4_score_W0 0.15820184651668584
# combinedweight shape1 : (4200, 20)
# right_data4_score_W' 0.7399697415398369
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5677041115465908
# error_data5_score_W0 0.2518606407208319
# combinedweight shape1 : (4900, 20)
# right_data5_score_W' 0.7539062652612172
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5946235776674458
# error_data6_score_W0 0.39513617470256795
# combinedweight shape1 : (5600, 20)
# right_data6_score_W' 0.7514163550784647
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.705533730359353
# error_data7_score_W0 0.4595810836113788
# combinedweight shape1 : (6300, 20)
# right_data7_score_W' 0.797227580886918
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.9035000824425833
# error_data8_score_W0 0.6313068075421489
# combinedweight shape1 : (7000, 20)
# right_data8_score_W' 0.8228161798644421
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (7700, 20)
# right_data9_score_W' 0.9200625111439561
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20711462927954735
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.24561702685766296
# test_score_W': 0.3476824755948417
# neuron unit number: 728
# *******************
#
# Error Data percentage 0.6525096525096525
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22233745991735282
# error_data0_score_W0 0.16874212530088864
# combinedweight shape 0: (1456, 20)
# right_data0_score_W' 0.5262626796575272
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2617831405021455
# error_data1_score_W0 0.11403626366279553
# combinedweight shape1 : (2184, 20)
# right_data1_score_W' 0.5337070973842124
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.33253499902998956
# error_data2_score_W0 0.11229258876332754
# combinedweight shape1 : (2912, 20)
# right_data2_score_W' 0.605785782251046
# Finish one training *********
# 3
# right_data3_score_W0 1.0000000000000002
# error_data3_score_W1 0.41141259777186157
# error_data3_score_W0 0.22437128820485844
# combinedweight shape1 : (3640, 20)
# right_data3_score_W' 0.7044528730788382
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.5130004130984248
# error_data4_score_W0 0.13089168533480786
# combinedweight shape1 : (4368, 20)
# right_data4_score_W' 0.6958659124835341
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.6291560791485906
# error_data5_score_W0 0.17695047162782004
# combinedweight shape1 : (5096, 20)
# right_data5_score_W' 0.7478420724997267
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.636488313385487
# error_data6_score_W0 0.2064230043952187
# combinedweight shape1 : (5824, 20)
# right_data6_score_W' 0.7769340613994581
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.8026461161994636
# error_data7_score_W0 0.1966612759831868
# combinedweight shape1 : (6552, 20)
# right_data7_score_W' 0.8003031166338541
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7918756684685216
# error_data8_score_W0 0.0
# combinedweight shape1 : (7280, 20)
# right_data8_score_W' 0.8631040918837465
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (8008, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.19631732122063827
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.23700606816148678
# test_score_W': 0.35275916399109625
# neuron unit number: 756
# *******************
#
# Error Data percentage 0.6621621621621622
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22686686426227612
# error_data0_score_W0 0.15739557455818787
# combinedweight shape 0: (1512, 20)
# right_data0_score_W' 0.5566290140142129
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.24356731359126146
# error_data1_score_W0 0.12134948740349775
# combinedweight shape1 : (2268, 20)
# right_data1_score_W' 0.5183219249405041
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.339975880693827
# error_data2_score_W0 0.10968632008255057
# combinedweight shape1 : (3024, 20)
# right_data2_score_W' 0.601989086024272
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4181882906748074
# error_data3_score_W0 0.11380501816490406
# combinedweight shape1 : (3780, 20)
# right_data3_score_W' 0.7185147530457652
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.3839645211635648
# error_data4_score_W0 0.2202495887282127
# combinedweight shape1 : (4536, 20)
# right_data4_score_W' 0.6981978703133773
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.47798620237188344
# error_data5_score_W0 0.16654517148128675
# combinedweight shape1 : (5292, 20)
# right_data5_score_W' 0.7079513960776961
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6305559458703283
# error_data6_score_W0 0.28114734585886475
# combinedweight shape1 : (6048, 20)
# right_data6_score_W' 0.7202130192349587
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6831980880025522
# error_data7_score_W0 0.3432866562024238
# combinedweight shape1 : (6804, 20)
# right_data7_score_W' 0.8121298818685054
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6624365752025368
# error_data8_score_W0 0.3746773416988541
# combinedweight shape1 : (7560, 20)
# right_data8_score_W' 0.960277088673016
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.7336804366512112
# combinedweight shape1 : (8316, 20)
# right_data9_score_W' 0.6666666666666666
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.18020045668226656
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.22255811541066953
# test_score_W': 0.34830942675001675
# neuron unit number: 784
# *******************
#
# Error Data percentage 0.6563706563706564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20590328974077557
# error_data0_score_W0 0.17074740943189046
# combinedweight shape 0: (1568, 20)
# right_data0_score_W' 0.642652498269407
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2526035415046838
# error_data1_score_W0 0.1421269824969135
# combinedweight shape1 : (2352, 20)
# right_data1_score_W' 0.5236038605992038
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3475459449883051
# error_data2_score_W0 0.10902912914353431
# combinedweight shape1 : (3136, 20)
# right_data2_score_W' 0.5985534925692443
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.37547517609808034
# error_data3_score_W0 0.10784415642980995
# combinedweight shape1 : (3920, 20)
# right_data3_score_W' 0.7441085194765455
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.45360866998147975
# error_data4_score_W0 0.2190069213020371
# combinedweight shape1 : (4704, 20)
# right_data4_score_W' 0.6710484037594634
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5520463532761726
# error_data5_score_W0 0.2840159871135285
# combinedweight shape1 : (5488, 20)
# right_data5_score_W' 0.7077013456009749
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5650965630810137
# error_data6_score_W0 0.4118771925770709
# combinedweight shape1 : (6272, 20)
# right_data6_score_W' 0.756021617463376
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7502974927532079
# error_data7_score_W0 0.5104276739534364
# combinedweight shape1 : (7056, 20)
# right_data7_score_W' 0.8950249354869217
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8722165935233486
# error_data8_score_W0 0.5100038178850457
# combinedweight shape1 : (7840, 20)
# right_data8_score_W' 0.8259531341825135
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (8624, 20)
# right_data9_score_W' 0.9310809437291901
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1956323801393554
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.23856708603735755
# test_score_W': 0.3518076208183476
# neuron unit number: 812
# *******************
#
# Error Data percentage 0.6544401544401545
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24484911495796938
# error_data0_score_W0 0.16303344962299612
# combinedweight shape 0: (1624, 20)
# right_data0_score_W' 0.5503603242001607
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2701052703490789
# error_data1_score_W0 0.12014187071219971
# combinedweight shape1 : (2436, 20)
# right_data1_score_W' 0.6230801290782241
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3574740188407378
# error_data2_score_W0 0.14192341436427441
# combinedweight shape1 : (3248, 20)
# right_data2_score_W' 0.5532799477778573
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.37374734020738914
# error_data3_score_W0 0.17381546488448188
# combinedweight shape1 : (4060, 20)
# right_data3_score_W' 0.6280607661473161
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4988851204496525
# error_data4_score_W0 0.17933839478992683
# combinedweight shape1 : (4872, 20)
# right_data4_score_W' 0.7651258654857493
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5600360813192528
# error_data5_score_W0 0.2050514790791368
# combinedweight shape1 : (5684, 20)
# right_data5_score_W' 0.7344622441552677
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6510242268072044
# error_data6_score_W0 0.24010073373519544
# combinedweight shape1 : (6496, 20)
# right_data6_score_W' 0.8151254345623598
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5663301547291709
# error_data7_score_W0 0.24016454558675787
# combinedweight shape1 : (7308, 20)
# right_data7_score_W' 0.8357157544811789
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.38033214891787165
# combinedweight shape1 : (8120, 20)
# right_data8_score_W' 0.7595437291421123
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1936941539503382
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.21833548928456728
# test_score_W': 0.3476824755948417
# neuron unit number: 840
# *******************
#
# Error Data percentage 0.6486486486486487
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21244179821062004
# error_data0_score_W0 0.17663541530678983
# combinedweight shape 0: (1680, 20)
# right_data0_score_W' 0.6007996467883735
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26422174883193594
# error_data1_score_W0 0.09198472846787575
# combinedweight shape1 : (2520, 20)
# right_data1_score_W' 0.5237680481062849
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3320851911810641
# error_data2_score_W0 0.11787054126427159
# combinedweight shape1 : (3360, 20)
# right_data2_score_W' 0.678126807330686
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.39799891170273277
# error_data3_score_W0 0.05957990328159777
# combinedweight shape1 : (4200, 20)
# right_data3_score_W' 0.6883000497355993
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.42575002118785904
# error_data4_score_W0 0.10481445764567884
# combinedweight shape1 : (5040, 20)
# right_data4_score_W' 0.7378020906061014
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5408461792274893
# error_data5_score_W0 0.18573140334959592
# combinedweight shape1 : (5880, 20)
# right_data5_score_W' 0.6626913022691931
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6125607847379009
# error_data6_score_W0 0.17325779368024535
# combinedweight shape1 : (6720, 20)
# right_data6_score_W' 0.8217830213593683
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5625489183416778
# error_data7_score_W0 0.32722822194327633
# combinedweight shape1 : (7560, 20)
# right_data7_score_W' 0.8273798071496014
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5858779295433236
# error_data8_score_W0 0.5858779295433235
# combinedweight shape1 : (8400, 20)
# right_data8_score_W' 0.7427338007991635
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (9240, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20398450733302786
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.23484098410936913
# test_score_W': 0.3508231242944346
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.208411  0.032273  0.005892   0.196361  0.220462
# 1  test_score_W'  30.0  0.348343  0.001854  0.000338   0.347651  0.349035
# 2       combined  60.0  0.278377  0.074107  0.009567   0.259233  0.297521
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1399
# 1                          Degrees of freedom =   58.0000
# 2                                           t =  -23.7096
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -6.1218
# 7                                   Hedge's g =   -6.0423
# 8                               Glass's delta =   -4.3359
# 9                                 Pearson's r =    0.9521
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-23.709637127891067, pvalue=7.851851136812843e-32)
