# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Absenteeism/Absenteeism_at_work.csv")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Reason for absence")

# %%
import experiment

unstable_repeate_num= 30
scope_num = 3
class_num = 28
dim_num = 20
smoothWeight = 0.9

experiment = experiment.Experiment()
experiment.findBestClusterNo(dataread.data_train,class_num, dim_num, scope_num,unstable_repeate_num,smoothWeight)
# Out:
# inertias_average 19042624853.887375  cluster_num 28
# inertias_average 17934325255.558243  cluster_num 29
# inertias_average 18000982677.166397  cluster_num 30
# inertias_average 14906098127.425013  cluster_num 31
# inertias_average 17507339038.994724  cluster_num 32
# inertias_average 18915071944.728653  cluster_num 33
# inertias_average 16487222085.124151  cluster_num 34
# inertias_average 14746619704.286446  cluster_num 35
# inertias_average 16459807104.81964  cluster_num 36
# inertias_average 16766081267.296997  cluster_num 37
# inertias_average 18403123627.393806  cluster_num 38
# inertias_average 20035580181.23309  cluster_num 39
# inertias_average 14031819784.186186  cluster_num 40
# inertias_average 18529044422.270428  cluster_num 41
# inertias_average 19837778543.4287  cluster_num 42
# inertias_average 17586723705.30183  cluster_num 43
# inertias_average 18700483718.48214  cluster_num 44
# inertias_average 14718375190.517324  cluster_num 45
# inertias_average 19747218420.630447  cluster_num 46
# inertias_average 17462412041.508797  cluster_num 47
# inertias_average 19087347980.725918  cluster_num 48
# inertias_average 18850533838.250473  cluster_num 49
# inertias_average 21213287490.14266  cluster_num 50
# inertias_average 17347771541.403336  cluster_num 51
# inertias_average 18333889891.449627  cluster_num 52
# inertias_average 17508655888.69648  cluster_num 53
# inertias_average 13295733223.393475  cluster_num 54
# inertias_average 17433152713.802784  cluster_num 55
# inertias_average 13549850784.184694  cluster_num 56
# inertias_average 16280514461.229546  cluster_num 57
# inertias_average 17252033677.578835  cluster_num 58
# inertias_average 17985962380.457626  cluster_num 59
# inertias_average 18835527054.598293  cluster_num 60
# inertias_average 15739128073.572598  cluster_num 61
# inertias_average 19100295866.166374  cluster_num 62
# inertias_average 13878114964.2656  cluster_num 63
# inertias_average 17065729623.509958  cluster_num 64
# inertias_average 17307569980.556896  cluster_num 65
# inertias_average 24024764229.436157  cluster_num 66
# inertias_average 21097307578.065563  cluster_num 67
# inertias_average 15092687583.163136  cluster_num 68
# inertias_average 18066839149.13403  cluster_num 69
# inertias_average 14663873186.313597  cluster_num 70
# inertias_average 18272830312.290386  cluster_num 71
# inertias_average 17051273595.232826  cluster_num 72
# inertias_average 16180288269.81823  cluster_num 73
# inertias_average 17248358849.79859  cluster_num 74
# inertias_average 14962603315.297628  cluster_num 75
# inertias_average 20099709382.11697  cluster_num 76
# inertias_average 20499119994.83312  cluster_num 77
# inertias_average 14831811325.411308  cluster_num 78
# inertias_average 12489464553.467987  cluster_num 79
# inertias_average 16017177888.856503  cluster_num 80
# inertias_average 21115543564.02955  cluster_num 81
# inertias_average 15978728284.754417  cluster_num 82
# inertias_average 18140006232.30555  cluster_num 83
# inertias_average 23355683259.860176  cluster_num 84
# silhouette_score_average 0.6875063202646714  cluster_num 28
# silhouette_score_average 0.6572322006786918  cluster_num 29
# silhouette_score_average 0.673546915325146  cluster_num 30
# silhouette_score_average 0.6774074977846937  cluster_num 31
# silhouette_score_average 0.6966293823835418  cluster_num 32
# silhouette_score_average 0.6687519002487643  cluster_num 33
# silhouette_score_average 0.6679322749641625  cluster_num 34
# silhouette_score_average 0.6767857953892517  cluster_num 35
# silhouette_score_average 0.6959017458869691  cluster_num 36
# silhouette_score_average 0.6799715050396059  cluster_num 37
# silhouette_score_average 0.6660885955416679  cluster_num 38
# silhouette_score_average 0.6729034409014217  cluster_num 39
# silhouette_score_average 0.6909109786964893  cluster_num 40
# silhouette_score_average 0.68126923689915  cluster_num 41
# silhouette_score_average 0.6924096078170368  cluster_num 42
# silhouette_score_average 0.6808796401578174  cluster_num 43
# silhouette_score_average 0.6895976733135316  cluster_num 44
# silhouette_score_average 0.7033660960841475  cluster_num 45
# silhouette_score_average 0.690797476993984  cluster_num 46
# silhouette_score_average 0.6936060928572192  cluster_num 47
# silhouette_score_average 0.6758045930820609  cluster_num 48
# silhouette_score_average 0.6788599640496492  cluster_num 49
# silhouette_score_average 0.6747938550150943  cluster_num 50
# silhouette_score_average 0.6734193805250227  cluster_num 51
# silhouette_score_average 0.692837962124466  cluster_num 52
# silhouette_score_average 0.6729793673588668  cluster_num 53
# silhouette_score_average 0.7035587030896266  cluster_num 54
# silhouette_score_average 0.6870302356013034  cluster_num 55
# silhouette_score_average 0.6998845996496698  cluster_num 56
# silhouette_score_average 0.6848644000452103  cluster_num 57
# silhouette_score_average 0.6840124502733592  cluster_num 58
# silhouette_score_average 0.6925813528514547  cluster_num 59
# silhouette_score_average 0.6815151965005202  cluster_num 60
# silhouette_score_average 0.6950930824549026  cluster_num 61
# silhouette_score_average 0.6930154603072701  cluster_num 62
# silhouette_score_average 0.7113666344006337  cluster_num 63
# silhouette_score_average 0.7055357661407413  cluster_num 64
# silhouette_score_average 0.6943164894326732  cluster_num 65
# silhouette_score_average 0.6783718602694493  cluster_num 66
# silhouette_score_average 0.6759182837949892  cluster_num 67
# silhouette_score_average 0.7092290865569754  cluster_num 68
# silhouette_score_average 0.6892759593654925  cluster_num 69
# silhouette_score_average 0.6810872377367662  cluster_num 70
# silhouette_score_average 0.7041261795524357  cluster_num 71
# silhouette_score_average 0.7039402566518037  cluster_num 72
# silhouette_score_average 0.6773910366522221  cluster_num 73
# silhouette_score_average 0.6835475098517002  cluster_num 74
# silhouette_score_average 0.7058193101265542  cluster_num 75
# silhouette_score_average 0.6928924044534723  cluster_num 76
# silhouette_score_average 0.6932722866489827  cluster_num 77
# silhouette_score_average 0.6931956976010434  cluster_num 78
# silhouette_score_average 0.7004842285801193  cluster_num 79
# silhouette_score_average 0.6957691165310792  cluster_num 80
# silhouette_score_average 0.6733220446866561  cluster_num 81
# silhouette_score_average 0.6986600162730432  cluster_num 82
# silhouette_score_average 0.6967642794981653  cluster_num 83
# silhouette_score_average 0.6829671827102781  cluster_num 84

# %%
unstable_repeate_num= 10
scope_num = 20
class_num = 28
dim_num = 20

experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num, scope_num,unstable_repeate_num)
# Out:
# neuron unit number: 28
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.22693266832917705
# error_data0_score_W1 nmi 0.15291618429161863
# error_data0_score_W1 api 0.04751530423231606
# error_data0_score_W0 purity 0.18204488778054864
# error_data0_score_W0 nmi 0.1196112792803597
# error_data0_score_W0 api 0.030599037199491173
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.2032258064516129
# error_data1_score_W1 nmi 0.17416174607355786
# error_data1_score_W1 api 0.028503413807767237
# error_data1_score_W0 purity 0.14193548387096774
# error_data1_score_W0 nmi 0.10518248043431128
# error_data1_score_W0 api 0.007999253774672416
# right_data1_score_W' purity 0.6043956043956044
# right_data1_score_W' nmi 0.4369173960694047
# right_data1_score_W' api 0.2692952528106362
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 0.21052631578947367
# error_data2_score_W1 nmi 0.26422341515362896
# error_data2_score_W1 api 0.029261445773586376
# error_data2_score_W0 purity 0.12955465587044535
# error_data2_score_W0 nmi 0.11857533942972039
# error_data2_score_W0 api 0.008477933901993402
# right_data2_score_W' purity 0.31746031746031744
# right_data2_score_W' nmi 0.36211632643163294
# right_data2_score_W' api 0.10859826530528828
# Finish one round splitting 2 *********
#
# right_data3_score_W0 purity 1.0
# right_data3_score_W0 nmi 1.0
# right_data3_score_W0 api 1.0
# error_data3_score_W1 purity 0.20512820512820512
# error_data3_score_W1 nmi 0.2875459325552552
# error_data3_score_W1 api 0.027957311179079763
# error_data3_score_W0 purity 0.13333333333333333
# error_data3_score_W0 nmi 0.12112865640923508
# error_data3_score_W0 api 0.0056192161733256045
# right_data3_score_W' purity 0.4423076923076923
# right_data3_score_W' nmi 0.6234680953327467
# right_data3_score_W' api 0.32398960729251003
# Finish one round splitting 3 *********
#
# right_data4_score_W0 purity 1.0
# right_data4_score_W0 nmi 1.0
# right_data4_score_W0 api 1.0
# error_data4_score_W1 purity 0.21935483870967742
# error_data4_score_W1 nmi 0.34742187934184965
# error_data4_score_W1 api 0.022680835225934844
# error_data4_score_W0 purity 0.11612903225806452
# error_data4_score_W0 nmi 0.10890148416680835
# error_data4_score_W0 api -0.005258278972884473
# right_data4_score_W' purity 0.325
# right_data4_score_W' nmi 0.41315455505716175
# right_data4_score_W' api 0.10751338473755667
# Finish one round splitting 4 *********
#
# right_data5_score_W0 purity 1.0
# right_data5_score_W0 nmi 1.0
# right_data5_score_W0 api 1.0
# error_data5_score_W1 purity 0.2231404958677686
# error_data5_score_W1 nmi 0.34772270769213387
# error_data5_score_W1 api 0.01899225988072603
# error_data5_score_W0 purity 0.1322314049586777
# error_data5_score_W0 nmi 0.13568459546638023
# error_data5_score_W0 api -0.01014152944239506
# right_data5_score_W' purity 0.38235294117647056
# right_data5_score_W' nmi 0.558474124560272
# right_data5_score_W' api 0.1577126444284875
# Finish one round splitting 5 *********
#
# right_data6_score_W0 purity 1.0
# right_data6_score_W0 nmi 1.0
# right_data6_score_W0 api 1.0
# error_data6_score_W1 purity 0.2553191489361702
# error_data6_score_W1 nmi 0.3793694832277862
# error_data6_score_W1 api 0.012743707659899422
# error_data6_score_W0 purity 0.14893617021276595
# error_data6_score_W0 nmi 0.15690751502733696
# error_data6_score_W0 api -0.014581016977843779
# right_data6_score_W' purity 0.37037037037037035
# right_data6_score_W' nmi 0.5048580169619171
# right_data6_score_W' api 0.1052808772604848
# Finish one round splitting 6 *********
#
# right_data7_score_W0 purity 1.0
# right_data7_score_W0 nmi 1.0
# right_data7_score_W0 api 1.0
# error_data7_score_W1 purity 0.3
# error_data7_score_W1 nmi 0.48102554851491874
# error_data7_score_W1 api 0.036623256920286625
# error_data7_score_W0 purity 0.17142857142857143
# error_data7_score_W0 nmi 0.21055526262445337
# error_data7_score_W0 api -0.009959948011989073
# right_data7_score_W' purity 0.3333333333333333
# right_data7_score_W' nmi 0.42893984574716143
# right_data7_score_W' api 0.029657477025898077
# Finish one round splitting 7 *********
#
# right_data8_score_W0 purity 1.0
# right_data8_score_W0 nmi 1.0
# right_data8_score_W0 api 1.0
# error_data8_score_W1 purity 0.3673469387755102
# error_data8_score_W1 nmi 0.52645794853657
# error_data8_score_W1 api 0.06960589079794378
# error_data8_score_W0 purity 0.1836734693877551
# error_data8_score_W0 nmi 0.2818239052562884
# error_data8_score_W0 api -0.008662835577665323
# right_data8_score_W' purity 0.2857142857142857
# right_data8_score_W' nmi 0.4325300705034657
# right_data8_score_W' api -0.007677543186180422
# Finish one round splitting 8 *********
#
# right_data9_score_W0 purity 1.0
# right_data9_score_W0 nmi 1.0
# right_data9_score_W0 api 1.0
# error_data9_score_W1 purity 0.3548387096774194
# error_data9_score_W1 nmi 0.5875865899036358
# error_data9_score_W1 api 0.1034274367607701
# error_data9_score_W0 purity 0.25806451612903225
# error_data9_score_W0 nmi 0.32025073583814484
# error_data9_score_W0 api -0.019999264732914232
# right_data9_score_W' purity 0.3888888888888889
# right_data9_score_W' nmi 0.4675583601056835
# right_data9_score_W' api 0.014242115971515769
# Finish one round splitting 9 *********
#
# right_data10_score_W0 purity 1.0
# right_data10_score_W0 nmi 1.0
# right_data10_score_W0 api 1.0
# error_data10_score_W1 purity 0.5
# error_data10_score_W1 nmi 0.7466811843616382
# error_data10_score_W1 api 0.1732283464566929
# error_data10_score_W0 purity 0.25
# error_data10_score_W0 nmi 0.40841306844545805
# error_data10_score_W0 api -0.030199039121482498
# right_data10_score_W' purity 0.45454545454545453
# right_data10_score_W' nmi 0.5503981961547773
# right_data10_score_W' api -0.06223175965665236
# Finish one round splitting 10 *********
#
# right_data11_score_W0 purity 1.0
# right_data11_score_W0 nmi 1.0
# right_data11_score_W0 api 1.0
# error_data11_score_W1 purity 0.6
# error_data11_score_W1 nmi 0.8068574385777885
# error_data11_score_W1 api -0.038461538461538464
# error_data11_score_W0 purity 0.4
# error_data11_score_W0 nmi 0.6393604453849322
# error_data11_score_W0 api -0.0427807486631016
# right_data11_score_W' purity 0.4
# right_data11_score_W' nmi 0.5580042326779334
# right_data11_score_W' api -0.11940298507462686
# Finish one round splitting 11 *********
#
# right_data12_score_W0 purity 1.0
# right_data12_score_W0 nmi 1.0
# right_data12_score_W0 api 1.0
# error_data12_score_W1 purity 0.75
# error_data12_score_W1 nmi 0.8571428571428571
# error_data12_score_W1 api 0.0
# error_data12_score_W0 purity 0.75
# error_data12_score_W0 nmi 0.8571428571428571
# error_data12_score_W0 api 0.0
# right_data12_score_W' purity 0.6666666666666666
# right_data12_score_W' nmi 0.8189625508803525
# right_data12_score_W' api 0.0
# Finish one round splitting 12 *********
#
# right_data13_score_W0 purity 1.0
# right_data13_score_W0 nmi 1.0
# right_data13_score_W0 api 1.0
# error_data13_score_W1 purity 1.0
# error_data13_score_W1 nmi 1.0
# error_data13_score_W1 api 1.0
# error_data13_score_W0 purity 1.0
# error_data13_score_W0 nmi 1.0
# error_data13_score_W0 api 1.0
# Error data can be represented by W0 purity 13
# Error data can be represented by W0 nmi 13
# Error data can be represented by W0 api 13
# right_data13_score_W' purity 1.0
# right_data13_score_W' nmi 1.0
# right_data13_score_W' api 1.0
# Finish one round splitting 13 *********
#
#  NO Error Data, Finish Training!
# total split_number 14
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.22586872586872586
# all_train_score_W' nmi split_num : 0 0.06152054478910354
# all_train_score_W' ari split_num : 0 0.008015732726670161
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 0 0.23423423423423423
# test_score_W': nmi split_num : 0 0.10599260846827993
# test_score_W': ari split_num : 0 0.013650464858495484
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.3996138996138996
# all_train_score_W' nmi split_num : 1 0.2294187389706851
# all_train_score_W' ari split_num : 1 0.15674209127975489
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 1 0.3108108108108108
# test_score_W': nmi split_num : 1 0.20180460819075086
# test_score_W': ari split_num : 1 0.04799115575105296
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.5173745173745173
# all_train_score_W' nmi split_num : 2 0.3608917912931011
# all_train_score_W' ari split_num : 2 0.2968955527827695
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 2 0.32432432432432434
# test_score_W': nmi split_num : 2 0.22600361077184583
# test_score_W': ari split_num : 2 0.05824766735171343
# stop_split_num 3
# all_train_score_W' purity split_num : 3 0.6138996138996139
# all_train_score_W' nmi split_num : 3 0.4800529562265065
# all_train_score_W' ari split_num : 3 0.44035959882969433
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 3 0.34234234234234234
# test_score_W': nmi split_num : 3 0.2674907925336077
# test_score_W': ari split_num : 3 0.0740761323170335
# stop_split_num 4
# all_train_score_W' purity split_num : 4 0.6891891891891891
# all_train_score_W' nmi split_num : 4 0.5767187477314765
# all_train_score_W' ari split_num : 4 0.5349363481954077
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 4 0.35135135135135137
# test_score_W': nmi split_num : 4 0.2881963889209166
# test_score_W': ari split_num : 4 0.07860503359530972
# stop_split_num 5
# all_train_score_W' purity split_num : 5 0.752895752895753
# all_train_score_W' nmi split_num : 5 0.6529183118936942
# all_train_score_W' ari split_num : 5 0.619422060371505
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 5 0.36036036036036034
# test_score_W': nmi split_num : 5 0.3095644483529259
# test_score_W': ari split_num : 5 0.08122602806330496
# stop_split_num 6
# all_train_score_W' purity split_num : 6 0.805019305019305
# all_train_score_W' nmi split_num : 6 0.7218464709498478
# all_train_score_W' ari split_num : 6 0.7022629786618257
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 6 0.3738738738738739
# test_score_W': nmi split_num : 6 0.3231651025730169
# test_score_W': ari split_num : 6 0.08868887965559294
# stop_split_num 7
# all_train_score_W' purity split_num : 7 0.8494208494208494
# all_train_score_W' nmi split_num : 7 0.7809656375962946
# all_train_score_W' ari split_num : 7 0.7704714042445575
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 7 0.38288288288288286
# test_score_W': nmi split_num : 7 0.3427255503216729
# test_score_W': ari split_num : 7 0.0979626667433605
# stop_split_num 8
# all_train_score_W' purity split_num : 8 0.8841698841698842
# all_train_score_W' nmi split_num : 8 0.8292294401866621
# all_train_score_W' ari split_num : 8 0.8219240532519239
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 8 0.38738738738738737
# test_score_W': nmi split_num : 8 0.3540638203111681
# test_score_W': ari split_num : 8 0.10739310355566448
# stop_split_num 9
# all_train_score_W' purity split_num : 9 0.918918918918919
# all_train_score_W' nmi split_num : 9 0.879644788985533
# all_train_score_W' ari split_num : 9 0.8686734471074724
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 9 0.3783783783783784
# test_score_W': nmi split_num : 9 0.34646453998334775
# test_score_W': ari split_num : 9 0.10585609616549693
# stop_split_num 10
# all_train_score_W' purity split_num : 10 0.9401544401544402
# all_train_score_W' nmi split_num : 10 0.9091060604912719
# all_train_score_W' ari split_num : 10 0.9032745450747434
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 10 0.38738738738738737
# test_score_W': nmi split_num : 10 0.35417133580453647
# test_score_W': ari split_num : 10 0.10829831400941725
# stop_split_num 11
# all_train_score_W' purity split_num : 11 0.9594594594594594
# all_train_score_W' nmi split_num : 11 0.9361150723833084
# all_train_score_W' ari split_num : 11 0.9245871009983362
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 11 0.3918918918918919
# test_score_W': nmi split_num : 11 0.3562165364392924
# test_score_W': ari split_num : 11 0.10910403971047426
# stop_split_num 12
# all_train_score_W' purity split_num : 12 0.971042471042471
# all_train_score_W' nmi split_num : 12 0.9537920116209085
# all_train_score_W' ari split_num : 12 0.9432834702954903
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 12 0.3918918918918919
# test_score_W': nmi split_num : 12 0.3549924417907189
# test_score_W': ari split_num : 12 0.11419764413990485
# stop_split_num 13
# all_train_score_W' purity split_num : 13 0.9768339768339769
# all_train_score_W' nmi split_num : 13 0.9633605506745604
# all_train_score_W' ari split_num : 13 0.9530936354398682
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 13 0.38288288288288286
# test_score_W': nmi split_num : 13 0.3488409249518252
# test_score_W': ari split_num : 13 0.11147484705627747
# stop_split_num 14
# all_train_score_W' purity split_num : 14 0.9787644787644788
# all_train_score_W' nmi split_num : 14 0.9655095632920485
# all_train_score_W' ari split_num : 14 0.9540516763713778
# test_score_W0 purity: 0.23423423423423423
# test_score_W0 nmi: 0.10599260846827993
# test_score_W0 api: 0.013650464858495484
# test_score_W': purity split_num : 14 0.38288288288288286
# test_score_W': nmi split_num : 14 0.3488409249518252
# test_score_W': ari split_num : 14 0.11147484705627747
# all_train_scores_W_Combined_last_p 0.9787644787644788
# all_train_scores_W_Combined_last_n 0.9655095632920485
# all_train_scores_W_Combined_last_a 0.9540516763713778
# test_scores_W_Combined_last_p 0.38288288288288286
# test_scores_W_Combined_last_n 0.3488409249518252
# test_scores_W_Combined_last_a 0.11147484705627747
# neuron unit number: 56
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.2761394101876676
# error_data0_score_W1 nmi 0.23993660585754073
# error_data0_score_W1 api 0.07387460213036885
# error_data0_score_W0 purity 0.18498659517426275
# error_data0_score_W0 nmi 0.14322394095663146
# error_data0_score_W0 api 0.03317051690395234
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.2518518518518518
# error_data1_score_W1 nmi 0.2303584030038952
# error_data1_score_W1 api 0.05367759175333467
# error_data1_score_W0 purity 0.14444444444444443
# error_data1_score_W0 nmi 0.10565999728916532
# error_data1_score_W0 api 0.003145500390008793
# right_data1_score_W' purity 0.36893203883495146
# right_data1_score_W' nmi 0.41620674762306203
# right_data1_score_W' api 0.13860224651070538
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 0.2722772277227723
# error_data2_score_W1 nmi 0.3217761485590418
# error_data2_score_W1 api 0.04871178339599361
# error_data2_score_W0 purity 0.13861386138613863
# error_data2_score_W0 nmi 0.13911372961465715
# error_data2_score_W0 api -0.0016009254298916065
# right_data2_score_W' purity 0.35294117647058826
# right_data2_score_W' nmi 0.3425489967477974
# right_data2_score_W' api 0.05262079706192323
# Finish one round splitting 2 *********
#
# right_data3_score_W0 purity 1.0
# right_data3_score_W0 nmi 1.0
# right_data3_score_W0 api 1.0
# error_data3_score_W1 purity 0.23809523809523808
# error_data3_score_W1 nmi 0.36341682031922273
# error_data3_score_W1 api 0.012876434697777474
# error_data3_score_W0 purity 0.1360544217687075
# error_data3_score_W0 nmi 0.1587199878754457
# error_data3_score_W0 api -0.0017037645242845253
# right_data3_score_W' purity 0.32727272727272727
# right_data3_score_W' nmi 0.44935565136666666
# right_data3_score_W' api 0.10948236371965185
# Finish one round splitting 3 *********
# right_data4_score_W0 purity 1.0
# right_data4_score_W0 nmi 1.0000000000000002
# right_data4_score_W0 api 1.0
# error_data4_score_W1 purity 0.25
# error_data4_score_W1 nmi 0.3709148366938433
# error_data4_score_W1 api 0.02069030298017191
# error_data4_score_W0 purity 0.14285714285714285
# error_data4_score_W0 nmi 0.23698842950775828
# error_data4_score_W0 api -0.006000906710464117
# right_data4_score_W' purity 0.4
# right_data4_score_W' nmi 0.547824802211057
# right_data4_score_W' api 0.07875994231466818
# Finish one round splitting 4 *********
#
# right_data5_score_W0 purity 1.0
# right_data5_score_W0 nmi 1.0
# right_data5_score_W0 api 1.0
# error_data5_score_W1 purity 0.2857142857142857
# error_data5_score_W1 nmi 0.3856315351385431
# error_data5_score_W1 api 0.034092915049624424
# error_data5_score_W0 purity 0.16666666666666666
# error_data5_score_W0 nmi 0.20990204790680378
# error_data5_score_W0 api -0.007214002277963083
# right_data5_score_W' purity 0.2857142857142857
# right_data5_score_W' nmi 0.36452941994714977
# right_data5_score_W' api -0.001509206157561123
# Finish one round splitting 5 *********
#
# right_data6_score_W0 purity 1.0
# right_data6_score_W0 nmi 1.0
# right_data6_score_W0 api 1.0
# error_data6_score_W1 purity 0.38333333333333336
# error_data6_score_W1 nmi 0.5491651421905619
# error_data6_score_W1 api 0.1046733592430339
# error_data6_score_W0 purity 0.21666666666666667
# error_data6_score_W0 nmi 0.23720082845233378
# error_data6_score_W0 api -0.027713020928831496
# right_data6_score_W' purity 0.4583333333333333
# right_data6_score_W' nmi 0.4890693304985395
# right_data6_score_W' api 0.06592827004219409
# Finish one round splitting 6 *********
#
# right_data7_score_W0 purity 1.0
# right_data7_score_W0 nmi 1.0
# right_data7_score_W0 api 1.0
# error_data7_score_W1 purity 0.43243243243243246
# error_data7_score_W1 nmi 0.6672331087208895
# error_data7_score_W1 api 0.06142245323767342
# error_data7_score_W0 purity 0.1891891891891892
# error_data7_score_W0 nmi 0.3096257733007595
# error_data7_score_W0 api -0.02427312836643516
# right_data7_score_W' purity 0.391304347826087
# right_data7_score_W' nmi 0.4231346797255354
# right_data7_score_W' api 0.011214953271028037
# Finish one round splitting 7 *********
#
# right_data8_score_W0 purity 1.0
# right_data8_score_W0 nmi 1.0
# right_data8_score_W0 api 1.0
# error_data8_score_W1 purity 0.7142857142857143
# error_data8_score_W1 nmi 0.8322217263382717
# error_data8_score_W1 api 0.44305772230889234
# error_data8_score_W0 purity 0.2857142857142857
# error_data8_score_W0 nmi 0.4102198456370026
# error_data8_score_W0 api 0.002932551319648094
# right_data8_score_W' purity 0.25
# right_data8_score_W' nmi 0.49844763823558147
# right_data8_score_W' api -0.04849279161205767
# Finish one round splitting 8 *********
#
# right_data9_score_W0 purity 1.0
# right_data9_score_W0 nmi 1.0
# right_data9_score_W0 api 1.0
# error_data9_score_W1 purity 0.8333333333333334
# error_data9_score_W1 nmi 0.9310809437291901
# error_data9_score_W1 api 0.0
# error_data9_score_W0 purity 0.5
# error_data9_score_W0 nmi 0.7216162598446756
# error_data9_score_W0 api 0.0
# right_data9_score_W' purity 0.3333333333333333
# right_data9_score_W' nmi 0.43176119489223286
# right_data9_score_W' api -0.06199021207177814
# Finish one round splitting 9 *********
#
# right_data10_score_W0 purity 1.0
# right_data10_score_W0 nmi 1.0
# right_data10_score_W0 api 1.0
# error_data10_score_W1 purity 1.0
# error_data10_score_W1 nmi 1.0
# error_data10_score_W1 api 1.0
# error_data10_score_W0 purity 1.0
# error_data10_score_W0 nmi 1.0
# error_data10_score_W0 api 1.0
# Error data can be represented by W0 purity 10
# Error data can be represented by W0 nmi 10
# Error data can be represented by W0 api 10
# right_data10_score_W' purity 0.6
# right_data10_score_W' nmi 0.7918756684685216
# right_data10_score_W' api 0.0
# Finish one round splitting 10 *********
#
#  NO Error Data, Finish Training!
# total split_number 11
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.2799227799227799
# all_train_score_W' nmi split_num : 0 0.12239011647771186
# all_train_score_W' ari split_num : 0 0.05263608421899175
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 0 0.3063063063063063
# test_score_W': nmi split_num : 0 0.19143891601082055
# test_score_W': ari split_num : 0 0.0643475562003544
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.47297297297297297
# all_train_score_W' nmi split_num : 1 0.3142015070583729
# all_train_score_W' ari split_num : 1 0.24815859817408895
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 1 0.32432432432432434
# test_score_W': nmi split_num : 1 0.2513837749098143
# test_score_W': ari split_num : 1 0.06339717325471357
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.6042471042471043
# all_train_score_W' nmi split_num : 2 0.45635651656640147
# all_train_score_W' ari split_num : 2 0.4139734244162693
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 2 0.3333333333333333
# test_score_W': nmi split_num : 2 0.27374053335380966
# test_score_W': ari split_num : 2 0.06696468434605586
# stop_split_num 3
# all_train_score_W' purity split_num : 3 0.7027027027027027
# all_train_score_W' nmi split_num : 3 0.5771406787053364
# all_train_score_W' ari split_num : 3 0.5463948132842507
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 3 0.34234234234234234
# test_score_W': nmi split_num : 3 0.29439569966797263
# test_score_W': ari split_num : 3 0.07692641919973009
# stop_split_num 4
# all_train_score_W' purity split_num : 4 0.7702702702702703
# all_train_score_W' nmi split_num : 4 0.6708817278787411
# all_train_score_W' ari split_num : 4 0.6419820606797754
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 4 0.35585585585585583
# test_score_W': nmi split_num : 4 0.30741208171557177
# test_score_W': ari split_num : 4 0.07761446368370796
# stop_split_num 5
# all_train_score_W' purity split_num : 5 0.8243243243243243
# all_train_score_W' nmi split_num : 5 0.7496701486615048
# all_train_score_W' ari split_num : 5 0.727554461972832
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 5 0.3783783783783784
# test_score_W': nmi split_num : 5 0.33214262578329007
# test_score_W': ari split_num : 5 0.08916661915221163
# stop_split_num 6
# all_train_score_W' purity split_num : 6 0.8667953667953668
# all_train_score_W' nmi split_num : 6 0.8040000482460441
# all_train_score_W' ari split_num : 6 0.7951148293111717
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 6 0.3738738738738739
# test_score_W': nmi split_num : 6 0.3371274328325811
# test_score_W': ari split_num : 6 0.09605277517854321
# stop_split_num 7
# all_train_score_W' purity split_num : 7 0.9092664092664092
# all_train_score_W' nmi split_num : 7 0.8624269620668207
# all_train_score_W' ari split_num : 7 0.8576859244429045
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 7 0.38288288288288286
# test_score_W': nmi split_num : 7 0.3438311709257318
# test_score_W': ari split_num : 7 0.0968776379535452
# stop_split_num 8
# all_train_score_W' purity split_num : 8 0.9401544401544402
# all_train_score_W' nmi split_num : 8 0.9073453143755704
# all_train_score_W' ari split_num : 8 0.8949579258149196
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 8 0.38288288288288286
# test_score_W': nmi split_num : 8 0.3516443590271955
# test_score_W': ari split_num : 8 0.10326582355376723
# stop_split_num 9
# all_train_score_W' purity split_num : 9 0.9671814671814671
# all_train_score_W' nmi split_num : 9 0.9468882378288543
# all_train_score_W' ari split_num : 9 0.933390039203037
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 9 0.38738738738738737
# test_score_W': nmi split_num : 9 0.35251602461994896
# test_score_W': ari split_num : 9 0.10968805159096724
# stop_split_num 10
# all_train_score_W' purity split_num : 10 0.9768339768339769
# all_train_score_W' nmi split_num : 10 0.9633816873041746
# all_train_score_W' ari split_num : 10 0.9529101210885268
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 10 0.38288288288288286
# test_score_W': nmi split_num : 10 0.34921744421621903
# test_score_W': ari split_num : 10 0.10890485229802854
# stop_split_num 11
# all_train_score_W' purity split_num : 11 0.9787644787644788
# all_train_score_W' nmi split_num : 11 0.9655285752849927
# all_train_score_W' ari split_num : 11 0.9538717907070627
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.19143891601082055
# test_score_W0 api: 0.0643475562003544
# test_score_W': purity split_num : 11 0.38288288288288286
# test_score_W': nmi split_num : 11 0.34921744421621903
# test_score_W': ari split_num : 11 0.10890485229802854
# all_train_scores_W_Combined_last_p 0.9787644787644788
# all_train_scores_W_Combined_last_n 0.9655285752849927
# all_train_scores_W_Combined_last_a 0.9538717907070627
# test_scores_W_Combined_last_p 0.38288288288288286
# test_scores_W_Combined_last_n 0.34921744421621903
# test_scores_W_Combined_last_a 0.10890485229802854
# neuron unit number: 84
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.23076923076923078
# error_data0_score_W1 nmi 0.21520276446900738
# error_data0_score_W1 api 0.035085580942737046
# error_data0_score_W0 purity 0.1813186813186813
# error_data0_score_W0 nmi 0.13401529205905832
# error_data0_score_W0 api 0.028274195027243352
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.225
# error_data1_score_W1 nmi 0.22116678664861428
# error_data1_score_W1 api 0.0303408021410431
# error_data1_score_W0 purity 0.1392857142857143
# error_data1_score_W0 nmi 0.09825723629694338
# error_data1_score_W0 api 0.002583531421195974
# right_data1_score_W' purity 0.30952380952380953
# right_data1_score_W' nmi 0.39951997496046626
# right_data1_score_W' api 0.09902782979693531
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 0.2304147465437788
# error_data2_score_W1 nmi 0.26464842178200554
# error_data2_score_W1 api 0.039959787552385426
# error_data2_score_W0 purity 0.15668202764976957
# error_data2_score_W0 nmi 0.1409431241320053
# error_data2_score_W0 api 0.011872214598193258
# right_data2_score_W' purity 0.4603174603174603
# right_data2_score_W' nmi 0.5081207903623448
# right_data2_score_W' api 0.20610455133792957
# Finish one round splitting 2 *********
#
# right_data3_score_W0 purity 1.0
# right_data3_score_W0 nmi 1.0
# right_data3_score_W0 api 1.0
# error_data3_score_W1 purity 0.24550898203592814
# error_data3_score_W1 nmi 0.32604152656273716
# error_data3_score_W1 api 0.037654270054408516
# error_data3_score_W0 purity 0.1377245508982036
# error_data3_score_W0 nmi 0.15722306021019464
# error_data3_score_W0 api 0.006345333819046323
# right_data3_score_W' purity 0.4
# right_data3_score_W' nmi 0.3388290189810668
# right_data3_score_W' api 0.07648636589756345
# Finish one round splitting 3 *********
#
# right_data4_score_W0 purity 1.0
# right_data4_score_W0 nmi 1.0
# right_data4_score_W0 api 1.0
# error_data4_score_W1 purity 0.25396825396825395
# error_data4_score_W1 nmi 0.36263076032618297
# error_data4_score_W1 api 0.03849719624708939
# error_data4_score_W0 purity 0.15873015873015872
# error_data4_score_W0 nmi 0.2071203739597681
# error_data4_score_W0 api 0.005915339790952498
# right_data4_score_W' purity 0.34146341463414637
# right_data4_score_W' nmi 0.44558894563490475
# right_data4_score_W' api 0.08589335251207234
# Finish one round splitting 4 *********
#
# right_data5_score_W0 purity 1.0
# right_data5_score_W0 nmi 1.0
# right_data5_score_W0 api 1.0
# error_data5_score_W1 purity 0.2765957446808511
# error_data5_score_W1 nmi 0.42617334555094233
# error_data5_score_W1 api 0.015326184328596044
# error_data5_score_W0 purity 0.14893617021276595
# error_data5_score_W0 nmi 0.19330976914244835
# error_data5_score_W0 api 0.0008765253476057822
# right_data5_score_W' purity 0.375
# right_data5_score_W' nmi 0.32996526444667856
# right_data5_score_W' api -0.0008268042048899563
# Finish one round splitting 5 *********
#
# right_data6_score_W0 purity 1.0
# right_data6_score_W0 nmi 1.0
# right_data6_score_W0 api 1.0
# error_data6_score_W1 purity 0.3088235294117647
# error_data6_score_W1 nmi 0.5044056785242845
# error_data6_score_W1 api 0.015758953951108583
# error_data6_score_W0 purity 0.16176470588235295
# error_data6_score_W0 nmi 0.240684127891126
# error_data6_score_W0 api 0.008504157919262864
# right_data6_score_W' purity 0.38461538461538464
# right_data6_score_W' nmi 0.5127536690214762
# right_data6_score_W' api 0.08950506429135838
# Finish one round splitting 6 *********
#
# right_data7_score_W0 purity 1.0
# right_data7_score_W0 nmi 1.0
# right_data7_score_W0 api 1.0
# error_data7_score_W1 purity 0.40425531914893614
# error_data7_score_W1 nmi 0.5599671290532281
# error_data7_score_W1 api 0.06879852086856951
# error_data7_score_W0 purity 0.23404255319148937
# error_data7_score_W0 nmi 0.37190295092160885
# error_data7_score_W0 api 0.007228937009617912
# right_data7_score_W' purity 0.42857142857142855
# right_data7_score_W' nmi 0.6181452998467878
# right_data7_score_W' api 0.09802930773117736
# Finish one round splitting 7 *********
#
# right_data8_score_W0 purity 1.0
# right_data8_score_W0 nmi 1.0
# right_data8_score_W0 api 1.0
# error_data8_score_W1 purity 0.5
# error_data8_score_W1 nmi 0.6687869717329512
# error_data8_score_W1 api 0.21069648390138757
# error_data8_score_W0 purity 0.21428571428571427
# error_data8_score_W0 nmi 0.4140854508425703
# error_data8_score_W0 api -0.027121743105287217
# right_data8_score_W' purity 0.42105263157894735
# right_data8_score_W' nmi 0.573063024328166
# right_data8_score_W' api 0.07737860244769049
# Finish one round splitting 8 *********
#
# right_data9_score_W0 purity 1.0
# right_data9_score_W0 nmi 1.0
# right_data9_score_W0 api 1.0
# error_data9_score_W1 purity 0.7142857142857143
# error_data9_score_W1 nmi 0.8589253022050937
# error_data9_score_W1 api 0.4964426877470356
# error_data9_score_W0 purity 0.42857142857142855
# error_data9_score_W0 nmi 0.6599975789869146
# error_data9_score_W0 api 0.07903614457831325
# right_data9_score_W' purity 0.5
# right_data9_score_W' nmi 0.5653485756317013
# right_data9_score_W' api 0.011336797354747285
# Finish one round splitting 9 *********
#
# right_data10_score_W0 purity 1.0
# right_data10_score_W0 nmi 1.0
# right_data10_score_W0 api 1.0
# error_data10_score_W1 purity 0.75
# error_data10_score_W1 nmi 0.7999999999999999
# error_data10_score_W1 api 0.5714285714285714
# error_data10_score_W0 purity 0.75
# error_data10_score_W0 nmi 0.7999999999999999
# error_data10_score_W0 api 0.5714285714285714
# right_data10_score_W' purity 0.6
# right_data10_score_W' nmi 0.6905673128342226
# right_data10_score_W' api 0.0546218487394958
# Finish one round splitting 10 *********
#
# right_data11_score_W0 purity 1.0
# right_data11_score_W0 nmi 1.0
# right_data11_score_W0 api 1.0
# error_data11_score_W1 purity 1.0
# error_data11_score_W1 nmi 1.0
# error_data11_score_W1 api 1.0
# error_data11_score_W0 purity 1.0
# error_data11_score_W0 nmi 1.0
# error_data11_score_W0 api 1.0
# Error data can be represented by W0 purity 11
# Error data can be represented by W0 nmi 11
# Error data can be represented by W0 api 11
# right_data11_score_W' purity 1.0
# right_data11_score_W' nmi 1.0
# right_data11_score_W' api 1.0
# Finish one round splitting 11 *********
#
#  NO Error Data, Finish Training!
# total split_number 12
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.2972972972972973
# all_train_score_W' nmi split_num : 0 0.13001367498799532
# all_train_score_W' ari split_num : 0 0.05538511153584662
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 0 0.3063063063063063
# test_score_W': nmi split_num : 0 0.17267405244593736
# test_score_W': ari split_num : 0 0.06299119787279037
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.4555984555984556
# all_train_score_W' nmi split_num : 1 0.30576759659938973
# all_train_score_W' ari split_num : 1 0.21318944671610945
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 1 0.32432432432432434
# test_score_W': nmi split_num : 1 0.26658365004731016
# test_score_W': ari split_num : 1 0.06762974506739294
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.5752895752895753
# all_train_score_W' nmi split_num : 2 0.42570154591620646
# all_train_score_W' ari split_num : 2 0.35604972634093335
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 2 0.33783783783783783
# test_score_W': nmi split_num : 2 0.28673955245431915
# test_score_W': ari split_num : 2 0.07984413218861548
# stop_split_num 3
# all_train_score_W' purity split_num : 3 0.666023166023166
# all_train_score_W' nmi split_num : 3 0.5356383027154088
# all_train_score_W' ari split_num : 3 0.4924720993235849
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 3 0.35135135135135137
# test_score_W': nmi split_num : 3 0.30010521435744175
# test_score_W': ari split_num : 3 0.08959607541293514
# stop_split_num 4
# all_train_score_W' purity split_num : 4 0.7432432432432432
# all_train_score_W' nmi split_num : 4 0.6400950778492468
# all_train_score_W' ari split_num : 4 0.6011694732176562
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 4 0.36936936936936937
# test_score_W': nmi split_num : 4 0.3070641331352084
# test_score_W': ari split_num : 4 0.08077473284303602
# stop_split_num 5
# all_train_score_W' purity split_num : 5 0.805019305019305
# all_train_score_W' nmi split_num : 5 0.7190624275745738
# all_train_score_W' ari split_num : 5 0.6895161407278043
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 5 0.38288288288288286
# test_score_W': nmi split_num : 5 0.3269706183267787
# test_score_W': ari split_num : 5 0.09325929456544187
# stop_split_num 6
# all_train_score_W' purity split_num : 6 0.8552123552123552
# all_train_score_W' nmi split_num : 6 0.7890533025929499
# all_train_score_W' ari split_num : 6 0.7763938485670974
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 6 0.38738738738738737
# test_score_W': nmi split_num : 6 0.35131038503746026
# test_score_W': ari split_num : 6 0.10289116372205201
# stop_split_num 7
# all_train_score_W' purity split_num : 7 0.8918918918918919
# all_train_score_W' nmi split_num : 7 0.8372265236370778
# all_train_score_W' ari split_num : 7 0.8260218502420916
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 7 0.38738738738738737
# test_score_W': nmi split_num : 7 0.35611777183333165
# test_score_W': ari split_num : 7 0.11365362881121112
# stop_split_num 8
# all_train_score_W' purity split_num : 8 0.9266409266409267
# all_train_score_W' nmi split_num : 8 0.8867639911482958
# all_train_score_W' ari split_num : 8 0.8693760431377259
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 8 0.38738738738738737
# test_score_W': nmi split_num : 8 0.3535426803371433
# test_score_W': ari split_num : 8 0.1056732886140944
# stop_split_num 9
# all_train_score_W' purity split_num : 9 0.9536679536679536
# all_train_score_W' nmi split_num : 9 0.9275784846122728
# all_train_score_W' ari split_num : 9 0.911252970972086
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 9 0.38738738738738737
# test_score_W': nmi split_num : 9 0.35343904663193665
# test_score_W': ari split_num : 9 0.11141203881489813
# stop_split_num 10
# all_train_score_W' purity split_num : 10 0.972972972972973
# all_train_score_W' nmi split_num : 10 0.9567846126428236
# all_train_score_W' ari split_num : 10 0.9491137089155096
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 10 0.38288288288288286
# test_score_W': nmi split_num : 10 0.34975038897414185
# test_score_W': ari split_num : 10 0.11238227717372827
# stop_split_num 11
# all_train_score_W' purity split_num : 11 0.9787644787644788
# all_train_score_W' nmi split_num : 11 0.9665610053447541
# all_train_score_W' ari split_num : 11 0.9590348544373772
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 11 0.38738738738738737
# test_score_W': nmi split_num : 11 0.35271229713199864
# test_score_W': ari split_num : 11 0.11547436027380989
# stop_split_num 12
# all_train_score_W' purity split_num : 12 0.9806949806949807
# all_train_score_W' nmi split_num : 12 0.9692570041827628
# all_train_score_W' ari split_num : 12 0.9604379953635528
# test_score_W0 purity: 0.3063063063063063
# test_score_W0 nmi: 0.17267405244593736
# test_score_W0 api: 0.06299119787279037
# test_score_W': purity split_num : 12 0.38288288288288286
# test_score_W': nmi split_num : 12 0.34941473270231727
# test_score_W': ari split_num : 12 0.11468200694919918
# all_train_scores_W_Combined_last_p 0.9806949806949807
# all_train_scores_W_Combined_last_n 0.9692570041827628
# all_train_scores_W_Combined_last_a 0.9604379953635528
# test_scores_W_Combined_last_p 0.38288288288288286
# test_scores_W_Combined_last_n 0.34941473270231727
# test_scores_W_Combined_last_a 0.11468200694919918
# neuron unit number: 112
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.2528409090909091
# error_data0_score_W1 nmi 0.2262093590654684
# error_data0_score_W1 api 0.04518090449644196
# error_data0_score_W0 purity 0.19886363636363635
# error_data0_score_W0 nmi 0.17374428179832696
# error_data0_score_W0 api 0.03654823148532876
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.2509505703422053
# error_data1_score_W1 nmi 0.2510439316620468
# error_data1_score_W1 api 0.04514710023589996
# error_data1_score_W0 purity 0.12927756653992395
# error_data1_score_W0 nmi 0.10922682896123843
# error_data1_score_W0 api -0.0017776135885106165
# right_data1_score_W' purity 0.3707865168539326
# right_data1_score_W' nmi 0.4682453329900661
# right_data1_score_W' api 0.11193819868951536
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 0.26903553299492383
# error_data2_score_W1 nmi 0.3211824090109583
# error_data2_score_W1 api 0.0613903544826236
# error_data2_score_W0 purity 0.16243654822335024
# error_data2_score_W0 nmi 0.18700958708193263
# error_data2_score_W0 api 0.0012269155115200907
# right_data2_score_W' purity 0.5
# right_data2_score_W' nmi 0.4301662455959453
# right_data2_score_W' api 0.055046566214886045
# Finish one round splitting 2 *********
#
# right_data3_score_W0 purity 1.0
# right_data3_score_W0 nmi 1.0
# right_data3_score_W0 api 1.0
# error_data3_score_W1 purity 0.2708333333333333
# error_data3_score_W1 nmi 0.3963346687868228
# error_data3_score_W1 api 0.035983953841971596
# error_data3_score_W0 purity 0.13194444444444445
# error_data3_score_W0 nmi 0.13325127237004153
# error_data3_score_W0 api -0.0008480038267217648
# right_data3_score_W' purity 0.32075471698113206
# right_data3_score_W' nmi 0.30551775881954746
# right_data3_score_W' api 0.030963335059779086
# Finish one round splitting 3 *********
#
# right_data4_score_W0 purity 1.0
# right_data4_score_W0 nmi 1.0
# right_data4_score_W0 api 1.0
# error_data4_score_W1 purity 0.2761904761904762
# error_data4_score_W1 nmi 0.37410662759950886
# error_data4_score_W1 api 0.009713383415474425
# error_data4_score_W0 purity 0.13333333333333333
# error_data4_score_W0 nmi 0.17384949254361015
# error_data4_score_W0 api -0.01164658285873038
# right_data4_score_W' purity 0.38461538461538464
# right_data4_score_W' nmi 0.3959987362777785
# right_data4_score_W' api 0.002049590670828671
# Finish one round splitting 4 *********
#
# right_data5_score_W0 purity 1.0
# right_data5_score_W0 nmi 1.0
# right_data5_score_W0 api 1.0
# error_data5_score_W1 purity 0.3026315789473684
# error_data5_score_W1 nmi 0.5051806770083613
# error_data5_score_W1 api 0.021025103516983012
# error_data5_score_W0 purity 0.18421052631578946
# error_data5_score_W0 nmi 0.281741255206739
# error_data5_score_W0 api -0.016960171046358764
# right_data5_score_W' purity 0.41379310344827586
# right_data5_score_W' nmi 0.4852324646980105
# right_data5_score_W' api 0.014318624844940635
# Finish one round splitting 5 *********
#
# right_data6_score_W0 purity 1.0
# right_data6_score_W0 nmi 1.0
# right_data6_score_W0 api 1.0
# error_data6_score_W1 purity 0.3584905660377358
# error_data6_score_W1 nmi 0.5728713324032072
# error_data6_score_W1 api 0.001829477809455707
# error_data6_score_W0 purity 0.20754716981132076
# error_data6_score_W0 nmi 0.3049411029985857
# error_data6_score_W0 api -0.020500064758020863
# right_data6_score_W' purity 0.391304347826087
# right_data6_score_W' nmi 0.6020972829705961
# right_data6_score_W' api 0.0547945205479452
# Finish one round splitting 6 *********
#
# right_data7_score_W0 purity 1.0
# right_data7_score_W0 nmi 1.0
# right_data7_score_W0 api 1.0
# error_data7_score_W1 purity 0.5
# error_data7_score_W1 nmi 0.6790426659997845
# error_data7_score_W1 api 0.23150684931506849
# error_data7_score_W0 purity 0.20588235294117646
# error_data7_score_W0 nmi 0.2726143603652652
# error_data7_score_W0 api -0.02974372593281105
# right_data7_score_W' purity 0.3157894736842105
# right_data7_score_W' nmi 0.5516784034665869
# right_data7_score_W' api -0.018530774321641297
# Finish one round splitting 7 *********
#
# right_data8_score_W0 purity 1.0
# right_data8_score_W0 nmi 1.0
# right_data8_score_W0 api 1.0
# error_data8_score_W1 purity 0.6470588235294118
# error_data8_score_W1 nmi 0.7692457332240027
# error_data8_score_W1 api 0.36633663366336633
# error_data8_score_W0 purity 0.35294117647058826
# error_data8_score_W0 nmi 0.36446145157279797
# error_data8_score_W0 api -0.07149110008754012
# right_data8_score_W' purity 0.29411764705882354
# right_data8_score_W' nmi 0.4026409986063979
# right_data8_score_W' api -0.02569832402234637
# Finish one round splitting 8 *********
#
# right_data9_score_W0 purity 1.0
# right_data9_score_W0 nmi 1.0
# right_data9_score_W0 api 1.0
# error_data9_score_W1 purity 0.8333333333333334
# error_data9_score_W1 nmi 0.9200625111439561
# error_data9_score_W1 api 0.6341463414634146
# error_data9_score_W0 purity 0.3333333333333333
# error_data9_score_W0 nmi 0.3690702464285425
# error_data9_score_W0 api -0.1320754716981132
# right_data9_score_W' purity 0.45454545454545453
# right_data9_score_W' nmi 0.4437138715162729
# right_data9_score_W' api -0.09601449275362318
# Finish one round splitting 9 *********
#
# right_data10_score_W0 purity 1.0
# right_data10_score_W0 nmi 1.0
# right_data10_score_W0 api 1.0
# error_data10_score_W1 purity 1.0
# error_data10_score_W1 nmi 1.0
# error_data10_score_W1 api 1.0
# error_data10_score_W0 purity 1.0
# error_data10_score_W0 nmi 1.0
# error_data10_score_W0 api 1.0
# Error data can be represented by W0 purity 10
# Error data can be represented by W0 nmi 10
# Error data can be represented by W0 api 10
# right_data10_score_W' purity 0.4
# right_data10_score_W' nmi 0.39472833517573314
# right_data10_score_W' api -0.19047619047619047
# Finish one round splitting 10 *********
#
#  NO Error Data, Finish Training!
# total split_number 11
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.3204633204633205
# all_train_score_W' nmi split_num : 0 0.17987751403582605
# all_train_score_W' ari split_num : 0 0.09329638691418345
# test_score_W0 purity: 0.3333333333333333
# test_score_W0 nmi: 0.23622104223632032
# test_score_W0 api: 0.10876779498195835
# test_score_W': purity split_num : 0 0.3333333333333333
# test_score_W': nmi split_num : 0 0.23622104223632032
# test_score_W': ari split_num : 0 0.10876779498195835
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.48841698841698844
# all_train_score_W' nmi split_num : 1 0.338027047050795
# all_train_score_W' ari split_num : 1 0.2739713064998077
# test_score_W0 purity: 0.3333333333333333
# test_score_W0 nmi: 0.23622104223632032
# test_score_W0 api: 0.10876779498195835
# test_score_W': purity split_num : 1 0.3333333333333333
# test_score_W': nmi split_num : 1 0.2851372494182624
# test_score_W': ari split_num : 1 0.07339709975623103
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.6138996138996139
# all_train_score_W' nmi split_num : 2 0.47271713188699077
# all_train_score_W' ari split_num : 2 0.41787595840041025
# test_score_W0 purity: 0.3333333333333333
# test_score_W0 nmi: 0.23622104223632032
# test_score_W0 api: 0.10876779498195835
# test_score_W': purity split_num : 2 0.35135135135135137
# test_score_W': nmi split_num : 2 0.314836023753074
# test_score_W': ari split_num : 2 0.08331567710964924
# stop_split_num 3
# all_train_score_W' purity split_num : 3 0.7123552123552124
# all_train_score_W' nmi split_num : 3 0.5920452084475258
# all_train_score_W' ari split_num : 3 0.5509525249990769
# test_score_W0 purity: 0.3333333333333333
# test_score_W0 nmi: 0.23622104223632032
# test_score_W0 api: 0.10876779498195835
# test_score_W': purity split_num : 3 0.34684684684684686
# test_score_W': nmi split_num : 3 0.30695763134536785
# ...
# stop_split_num 9
# all_train_score_W' purity split_num : 9 0.972972972972973
# all_train_score_W' nmi split_num : 9 0.9572518646014198
# all_train_score_W' ari split_num : 9 0.9482836564898434
# test_score_W0 purity: 0.32432432432432434
# test_score_W0 nmi: 0.21444840487024233
# test_score_W0 api: 0.09325044997806939
# test_score_W': purity split_num : 9 0.3963963963963964
# test_score_W': nmi split_num : 9 0.36381159179215333
# test_score_W': ari split_num : 9 0.12457979926413557
# stop_split_num 10
# all_train_score_W' purity split_num : 10 0.9806949806949807
# all_train_score_W' nmi split_num : 10 0.9692496771860097
# all_train_score_W' ari split_num : 10 0.9602298553896133
# test_score_W0 purity: 0.32432432432432434
# test_score_W0 nmi: 0.21444840487024233
# test_score_W0 api: 0.09325044997806939
# test_score_W': purity split_num : 10 0.3918918918918919
# test_score_W': nmi split_num : 10 0.3609276830884406
# test_score_W': ari split_num : 10 0.12252609785299333
# all_train_scores_W_Combined_last_p 0.9806949806949807
# all_train_scores_W_Combined_last_n 0.9692496771860097
# all_train_scores_W_Combined_last_a 0.9602298553896133
# test_scores_W_Combined_last_p 0.3918918918918919
# test_scores_W_Combined_last_n 0.3609276830884406
# test_scores_W_Combined_last_a 0.12252609785299333
# neuron unit number: 560
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.245014245014245
# error_data0_score_W1 nmi 0.2029915337839528
# error_data0_score_W1 api 0.04309221821656298
# error_data0_score_W0 purity 0.17663817663817663
# error_data0_score_W0 nmi 0.1564897822809673
# error_data0_score_W0 api 0.024494924548693883
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.2830188679245283
# error_data1_score_W1 nmi 0.28683257370925175
# error_data1_score_W1 api 0.050813226345017094
# error_data1_score_W0 purity 0.16226415094339622
# error_data1_score_W0 nmi 0.12893492743120136
# error_data1_score_W0 api 0.0013029275690407377
# right_data1_score_W' purity 0.4069767441860465
# right_data1_score_W' nmi 0.3952361725469221
# right_data1_score_W' api 0.0843091216364573
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 0.26842105263157895
# error_data2_score_W1 nmi 0.2884022896333567
# error_data2_score_W1 api 0.04461150722702109
# error_data2_score_W0 purity 0.14210526315789473
# error_data2_score_W0 nmi 0.1300418489182281
# error_data2_score_W0 api -0.0026190607901143428
# right_data2_score_W' purity 0.28
# right_data2_score_W' nmi 0.38187441582411374
# right_data2_score_W' api 0.05396745717223351
# Finish one round splitting 2 *********
#
# right_data3_score_W0 purity 1.0
# right_data3_score_W0 nmi 1.0
# right_data3_score_W0 api 1.0
# error_data3_score_W1 purity 0.2949640287769784
# error_data3_score_W1 nmi 0.4020886670972551
# error_data3_score_W1 api 0.05360101694052532
# error_data3_score_W0 purity 0.14388489208633093
# error_data3_score_W0 nmi 0.17453162773708025
# error_data3_score_W0 api -0.004947860794234676
# right_data3_score_W' purity 0.43137254901960786
# right_data3_score_W' nmi 0.37791007692563716
# right_data3_score_W' api 0.05418081837295811
# Finish one round splitting 3 *********
#
# right_data4_score_W0 purity 1.0
# right_data4_score_W0 nmi 1.0
# right_data4_score_W0 api 1.0
# error_data4_score_W1 purity 0.35714285714285715
# error_data4_score_W1 nmi 0.493643414412949
# error_data4_score_W1 api 0.07164876242441032
# error_data4_score_W0 purity 0.1326530612244898
# error_data4_score_W0 nmi 0.15102641079055795
# error_data4_score_W0 api -0.008109112280286216
# right_data4_score_W' purity 0.2682926829268293
# right_data4_score_W' nmi 0.33747325128344574
# right_data4_score_W' api 0.03446849817060212
# Finish one round splitting 4 *********
#
# right_data5_score_W0 purity 1.0
# right_data5_score_W0 nmi 1.0000000000000002
# right_data5_score_W0 api 1.0
# error_data5_score_W1 purity 0.38095238095238093
# error_data5_score_W1 nmi 0.5416764708856653
# error_data5_score_W1 api 0.06003888278410394
# error_data5_score_W0 purity 0.15873015873015872
# error_data5_score_W0 nmi 0.19808889900987206
# error_data5_score_W0 api -0.0036796622508688936
# right_data5_score_W' purity 0.2571428571428571
# right_data5_score_W' nmi 0.2997925187265013
# right_data5_score_W' api 0.028967768257853937
# Finish one round splitting 5 *********
#
# right_data6_score_W0 purity 1.0
# right_data6_score_W0 nmi 1.0
# right_data6_score_W0 api 1.0
# error_data6_score_W1 purity 0.46153846153846156
# error_data6_score_W1 nmi 0.6543035993332209
# error_data6_score_W1 api 0.09855438818232087
# error_data6_score_W0 purity 0.1794871794871795
# error_data6_score_W0 nmi 0.2190135887978981
# error_data6_score_W0 api -0.043510452961672476
# right_data6_score_W' purity 0.4583333333333333
# right_data6_score_W' nmi 0.47197079557966587
# right_data6_score_W' api -0.018540387340576288
# Finish one round splitting 6 *********
#
# right_data7_score_W0 purity 1.0
# right_data7_score_W0 nmi 1.0
# right_data7_score_W0 api 1.0
# error_data7_score_W1 purity 0.5238095238095238
# error_data7_score_W1 nmi 0.6557928610644633
# error_data7_score_W1 api 0.1111111111111111
# error_data7_score_W0 purity 0.23809523809523808
# error_data7_score_W0 nmi 0.19229137808432847
# error_data7_score_W0 api -0.05405405405405406
# right_data7_score_W' purity 0.2777777777777778
# right_data7_score_W' nmi 0.32437162285566223
# right_data7_score_W' api -0.048776968035211775
# Finish one round splitting 7 *********
#
# right_data8_score_W0 purity 1.0
# right_data8_score_W0 nmi 1.0
# right_data8_score_W0 api 1.0
# error_data8_score_W1 purity 0.9
# error_data8_score_W1 nmi 0.9114276815866645
# error_data8_score_W1 api 0.5360824742268041
# error_data8_score_W0 purity 0.4
# error_data8_score_W0 nmi 0.3623165806887975
# error_data8_score_W0 api -0.03618421052631579
# right_data8_score_W' purity 0.2727272727272727
# right_data8_score_W' nmi 0.11510588797002895
# right_data8_score_W' api -0.059957173447537475
# Finish one round splitting 8 *********
#
# right_data9_score_W0 purity 1.0
# right_data9_score_W0 nmi 1.0
# right_data9_score_W0 api 1.0
# error_data9_score_W1 purity 1.0
# error_data9_score_W1 nmi 1.0
# error_data9_score_W1 api 1.0
# error_data9_score_W0 purity 1.0
# error_data9_score_W0 nmi 1.0
# error_data9_score_W0 api 1.0
# Error data can be represented by W0 purity 9
# Error data can be represented by W0 nmi 9
# Error data can be represented by W0 api 9
# right_data9_score_W' purity 0.4444444444444444
# right_data9_score_W' nmi 0.41175840218142407
# right_data9_score_W' api -0.016129032258064516
# Finish one round splitting 9 *********
#
#  NO Error Data, Finish Training!
# total split_number 10
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.3223938223938224
# all_train_score_W' nmi split_num : 0 0.16853407444171595
# all_train_score_W' ari split_num : 0 0.10024080879868953
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 0 0.33783783783783783
# test_score_W': nmi split_num : 0 0.248567914245439
# test_score_W': ari split_num : 0 0.1044682532187573
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.48455598455598453
# all_train_score_W' nmi split_num : 1 0.3312657895176614
# all_train_score_W' ari split_num : 1 0.2721724273003949
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 1 0.3333333333333333
# test_score_W': nmi split_num : 1 0.28281755662179653
# test_score_W': ari split_num : 1 0.09112455897945584
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.6274131274131274
# all_train_score_W' nmi split_num : 2 0.4910585709889571
# all_train_score_W' ari split_num : 2 0.4352984305217576
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 2 0.36936936936936937
# test_score_W': nmi split_num : 2 0.3254342984023802
# test_score_W': ari split_num : 2 0.09758599743821925
# stop_split_num 3
# all_train_score_W' purity split_num : 3 0.722007722007722
# all_train_score_W' nmi split_num : 3 0.6051651806573274
# all_train_score_W' ari split_num : 3 0.5621226275570652
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 3 0.3738738738738739
# test_score_W': nmi split_num : 3 0.3136732849018291
# test_score_W': ari split_num : 3 0.08605462607628728
# stop_split_num 4
# all_train_score_W' purity split_num : 4 0.7992277992277992
# all_train_score_W' nmi split_num : 4 0.7091211483114354
# all_train_score_W' ari split_num : 4 0.670075521370073
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 4 0.3963963963963964
# test_score_W': nmi split_num : 4 0.33818982780441564
# test_score_W': ari split_num : 4 0.09236221564903797
# stop_split_num 5
# all_train_score_W' purity split_num : 5 0.862934362934363
# all_train_score_W' nmi split_num : 5 0.8013376250601195
# all_train_score_W' ari split_num : 5 0.7909392751661669
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 5 0.38738738738738737
# test_score_W': nmi split_num : 5 0.3456676966489179
# test_score_W': ari split_num : 5 0.11027636607945107
# stop_split_num 6
# all_train_score_W' purity split_num : 6 0.9092664092664092
# all_train_score_W' nmi split_num : 6 0.8645846776456996
# all_train_score_W' ari split_num : 6 0.8547498967938041
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 6 0.38738738738738737
# test_score_W': nmi split_num : 6 0.35088766832049095
# test_score_W': ari split_num : 6 0.11280655779124558
# stop_split_num 7
# all_train_score_W' purity split_num : 7 0.9420849420849421
# all_train_score_W' nmi split_num : 7 0.9119065020172
# all_train_score_W' ari split_num : 7 0.8980368421885394
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 7 0.38738738738738737
# test_score_W': nmi split_num : 7 0.3569619909079383
# test_score_W': ari split_num : 7 0.11403098881168855
# stop_split_num 8
# all_train_score_W' purity split_num : 8 0.9633204633204633
# all_train_score_W' nmi split_num : 8 0.9439120966231505
# all_train_score_W' ari split_num : 8 0.9290380891447715
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 8 0.3918918918918919
# test_score_W': nmi split_num : 8 0.36250803140907295
# test_score_W': ari split_num : 8 0.12111645478752656
# stop_split_num 9
# all_train_score_W' purity split_num : 9 0.9787644787644788
# all_train_score_W' nmi split_num : 9 0.9653887839146993
# all_train_score_W' ari split_num : 9 0.9526219497490319
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 9 0.3918918918918919
# test_score_W': nmi split_num : 9 0.3609276830884406
# test_score_W': ari split_num : 9 0.12252609785299333
# stop_split_num 10
# all_train_score_W' purity split_num : 10 0.9806949806949807
# all_train_score_W' nmi split_num : 10 0.9692723277362644
# all_train_score_W' ari split_num : 10 0.9602822316623458
# test_score_W0 purity: 0.33783783783783783
# test_score_W0 nmi: 0.248567914245439
# test_score_W0 api: 0.1044682532187573
# test_score_W': purity split_num : 10 0.3918918918918919
# test_score_W': nmi split_num : 10 0.3609276830884406
# test_score_W': ari split_num : 10 0.12252609785299333
# all_train_scores_W_Combined_last_p 0.9806949806949807
# all_train_scores_W_Combined_last_n 0.9692723277362644
# all_train_scores_W_Combined_last_a 0.9602822316623458
# test_scores_W_Combined_last_p 0.3918918918918919
# test_scores_W_Combined_last_n 0.3609276830884406
# test_scores_W_Combined_last_a 0.12252609785299333
# s 364  value 0.38288288288288286
# s 392  value 0.38288288288288286
# s 420  value 0.38738738738738737
# Purity T-Test
#         Variable    N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  3.0  0.322823  0.013761  0.007945   0.288637  0.357008
# 1  test_score_W'  3.0  0.384384  0.002601  0.001502   0.377924  0.390845
# 2       combined  6.0  0.353604  0.034863  0.014233   0.317017  0.390190
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0616
# 1                          Degrees of freedom =    4.0000
# 2                                           t =   -7.6135
# 3                       Two side test p value =    0.0016
# 4                      Difference < 0 p value =    0.0008
# 5                      Difference > 0 p value =    0.9992
# 6                                   Cohen's d =   -6.2164
# 7                                   Hedge's g =   -4.9731
# 8                               Glass's delta =   -4.4735
# 9                                 Pearson's r =    0.9672
# NMI T-Test
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  200.0  0.216782  0.031177  0.002205   0.212434  0.221129
# 1  test_score_W'  200.0  0.357857  0.005372  0.000380   0.357108  0.358606
# 2       combined  400.0  0.287319  0.074075  0.003704   0.280038  0.294601
#                               Independent t-test   results
# 0  Difference (test_score_W0 - test_score_W') =    -0.1411
# 1                          Degrees of freedom =   398.0000
# 2                                           t =   -63.0634
# 3                       Two side test p value =     0.0000
# 4                      Difference < 0 p value =     0.0000
# 5                      Difference > 0 p value =     1.0000
# 6                                   Cohen's d =    -6.3063
# 7                                   Hedge's g =    -6.2945
# 8                               Glass's delta =    -4.5250
# 9                                 Pearson's r =     0.9534
# ARI T-Test
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  200.0  0.086519  0.023417  0.001656   0.083254  0.089784
# 1  test_score_W'  200.0  0.119141  0.004656  0.000329   0.118491  0.119790
# 2       combined  400.0  0.102830  0.023473  0.001174   0.100522  0.105137
#                               Independent t-test   results
# 0  Difference (test_score_W0 - test_score_W') =    -0.0326
# 1                          Degrees of freedom =   398.0000
# 2                                           t =   -19.3233
# 3                       Two side test p value =     0.0000
# 4                      Difference < 0 p value =     0.0000
# 5                      Difference > 0 p value =     1.0000
# 6                                   Cohen's d =    -1.9323
# 7                                   Hedge's g =    -1.9287
# 8                               Glass's delta =    -1.3931
# 9                                 Pearson's r =     0.6957
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment

unstable_repeate_num= 30
scope_num = 3
class_num = 28
dim_num = 20
smoothWeight = 0.9

experiment = experiment.Experiment()
experiment.findBestClusterNo(dataread.data_train,class_num, dim_num, scope_num,unstable_repeate_num,smoothWeight)
# Out:
# inertias_average 23817454530.187794  cluster_num 28
# inertias_average 17619359524.22431  cluster_num 29
# inertias_average 16591407381.247345  cluster_num 30
# inertias_average 17631889781.061577  cluster_num 31
# inertias_average 14287908263.72201  cluster_num 32
# inertias_average 19419810334.311356  cluster_num 33
# inertias_average 12546810590.337946  cluster_num 34
# inertias_average 20360916695.42195  cluster_num 35
# inertias_average 18524995649.584152  cluster_num 36
# inertias_average 19625604467.18363  cluster_num 37
# inertias_average 16846111959.929546  cluster_num 38
# inertias_average 14537897554.24155  cluster_num 39
# inertias_average 17572510924.589615  cluster_num 40
# inertias_average 19288788481.06432  cluster_num 41
# inertias_average 18293696244.963913  cluster_num 42
# inertias_average 13834517786.978455  cluster_num 43
# inertias_average 18982944627.13152  cluster_num 44
# inertias_average 18793451504.734627  cluster_num 45
# inertias_average 20992297921.157364  cluster_num 46
# inertias_average 19169722214.85896  cluster_num 47
# inertias_average 19575570925.45505  cluster_num 48
# inertias_average 15660614890.35431  cluster_num 49
# inertias_average 21072344678.778633  cluster_num 50
# inertias_average 20822498997.049004  cluster_num 51
# inertias_average 20262162877.240013  cluster_num 52
# inertias_average 14779438482.63776  cluster_num 53
# inertias_average 20617825471.670567  cluster_num 54
# inertias_average 16106278870.1225  cluster_num 55
# inertias_average 16174416643.740362  cluster_num 56
# inertias_average 17683043339.409607  cluster_num 57
# inertias_average 19269433926.914707  cluster_num 58
# inertias_average 16927044464.25697  cluster_num 59
# inertias_average 20195781685.30274  cluster_num 60
# inertias_average 17403606826.290176  cluster_num 61
# inertias_average 15771960642.00722  cluster_num 62
# inertias_average 15033470984.575956  cluster_num 63
# inertias_average 21622675505.401722  cluster_num 64
# inertias_average 15780809493.571545  cluster_num 65
# inertias_average 23297163919.6807  cluster_num 66
# inertias_average 17294105536.57957  cluster_num 67
# inertias_average 19537804936.411213  cluster_num 68
# inertias_average 21054205068.56672  cluster_num 69
# inertias_average 18894287770.41573  cluster_num 70
# inertias_average 19221471888.52845  cluster_num 71
# inertias_average 14715288624.160099  cluster_num 72
# inertias_average 16635837846.39042  cluster_num 73
# inertias_average 19893574693.36497  cluster_num 74
# inertias_average 18590774649.740013  cluster_num 75
# inertias_average 15111078465.00986  cluster_num 76
# inertias_average 16671534127.088514  cluster_num 77
# inertias_average 18478750490.16256  cluster_num 78
# inertias_average 18369535332.110714  cluster_num 79
# inertias_average 15243285135.718477  cluster_num 80
# inertias_average 17909466466.34872  cluster_num 81
# inertias_average 19321059629.61233  cluster_num 82
# inertias_average 17772588534.240696  cluster_num 83
# inertias_average 17283928230.85363  cluster_num 84
# silhouette_score_average 0.6628213129140363  cluster_num 28
# silhouette_score_average 0.6725509425252096  cluster_num 29
# silhouette_score_average 0.6779003485538281  cluster_num 30
# silhouette_score_average 0.665412207932342  cluster_num 31
# silhouette_score_average 0.6841680436284985  cluster_num 32
# silhouette_score_average 0.6777469187291207  cluster_num 33
# silhouette_score_average 0.6900696973252961  cluster_num 34
# silhouette_score_average 0.6556502861782251  cluster_num 35
# silhouette_score_average 0.6862818239989684  cluster_num 36
# silhouette_score_average 0.6660653532231361  cluster_num 37
# silhouette_score_average 0.6882102818193125  cluster_num 38
# silhouette_score_average 0.6996405458950097  cluster_num 39
# silhouette_score_average 0.6681240951975282  cluster_num 40
# silhouette_score_average 0.6865861678939644  cluster_num 41
# silhouette_score_average 0.6817501790699436  cluster_num 42
# silhouette_score_average 0.6899926060946514  cluster_num 43
# silhouette_score_average 0.6685412801650741  cluster_num 44
# silhouette_score_average 0.691981315405936  cluster_num 45
# silhouette_score_average 0.6815802843056978  cluster_num 46
# silhouette_score_average 0.6931057927240579  cluster_num 47
# silhouette_score_average 0.6932215040405141  cluster_num 48
# silhouette_score_average 0.6631126080363509  cluster_num 49
# silhouette_score_average 0.6804605612625478  cluster_num 50
# silhouette_score_average 0.6942551220829645  cluster_num 51
# silhouette_score_average 0.66437173244648  cluster_num 52
# silhouette_score_average 0.7111771702428096  cluster_num 53
# silhouette_score_average 0.7078373945725921  cluster_num 54
# silhouette_score_average 0.6913961689405212  cluster_num 55
# silhouette_score_average 0.6659103489342603  cluster_num 56
# silhouette_score_average 0.6683989323492215  cluster_num 57
# silhouette_score_average 0.6870612868642626  cluster_num 58
# silhouette_score_average 0.6904841543038728  cluster_num 59
# silhouette_score_average 0.6818407760788567  cluster_num 60
# silhouette_score_average 0.6724835461748894  cluster_num 61
# silhouette_score_average 0.6925426808952435  cluster_num 62
# silhouette_score_average 0.6634985405286625  cluster_num 63
# silhouette_score_average 0.661496733241311  cluster_num 64
# silhouette_score_average 0.6971824179147673  cluster_num 65
# silhouette_score_average 0.6771627227160046  cluster_num 66
# silhouette_score_average 0.7061373257613792  cluster_num 67
# silhouette_score_average 0.7051311260923351  cluster_num 68
# silhouette_score_average 0.6764943409781234  cluster_num 69
# silhouette_score_average 0.6964693529971482  cluster_num 70
# silhouette_score_average 0.668597448133937  cluster_num 71
# silhouette_score_average 0.6800857391444685  cluster_num 72
# silhouette_score_average 0.6759465517227501  cluster_num 73
# silhouette_score_average 0.6970270360798685  cluster_num 74
# silhouette_score_average 0.6798574804638086  cluster_num 75
# silhouette_score_average 0.6993873074919434  cluster_num 76
# silhouette_score_average 0.6687484166453714  cluster_num 77
# silhouette_score_average 0.6785258847678375  cluster_num 78
# silhouette_score_average 0.6765588718026749  cluster_num 79
# silhouette_score_average 0.698483838039084  cluster_num 80
# silhouette_score_average 0.6670105994920574  cluster_num 81
# silhouette_score_average 0.680196605723513  cluster_num 82
# silhouette_score_average 0.6917308493142634  cluster_num 83
# silhouette_score_average 0.6961489045511275  cluster_num 84

# %%
# compare between best cluster no with TDSM NMI

scoretype = 1
class_num = 28
dim_num = 20
best_cluster_no = 43

som = newSom.SOM(m= best_cluster_no, n=  1, dim=dim_num)  
optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
optimize_W.run(scoretype)
# Out:
# error_data0_score_W1 0.15221926869662522
# error_data0_score_W0 0.14504487106451844
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 0.21595841132339427
# error_data1_score_W0 0.12342673202492582
# right_data1_score_W' 0.44752279766083386
# Finish one round splitting 1 *********
#
# error_data2_score_W1 0.22919049016769535
# error_data2_score_W0 0.15487093779974392
# right_data2_score_W' 0.4991984528942222
# Finish one round splitting 2 *********
#
# error_data3_score_W1 0.36830789419762155
# error_data3_score_W0 0.19361412414164703
# right_data3_score_W' 0.48815112049979037
# Finish one round splitting 3 *********
#
# error_data4_score_W1 0.3933501727479762
# error_data4_score_W0 0.2347605341302709
# right_data4_score_W' 0.5854489626442114
# Finish one round splitting 4 *********
#
# error_data5_score_W1 0.4131668681532026
# error_data5_score_W0 0.2845594820477537
# right_data5_score_W' 0.5453910545204992
# Finish one round splitting 5 *********
#
# error_data6_score_W1 0.5338531638749949
# error_data6_score_W0 0.3359433662559453
# right_data6_score_W' 0.4632158764791169
# Finish one round splitting 6 *********
#
# error_data7_score_W1 0.5674506206379
# error_data7_score_W0 0.3416546907793818
# right_data7_score_W' 0.611157367633729
# Finish one round splitting 7 *********
#
# error_data8_score_W1 0.6852405924819852
# error_data8_score_W0 0.4418107811663347
# right_data8_score_W' 0.5045615786370433
# Finish one round splitting 8 *********
#
# error_data9_score_W1 0.8618069916354766
# error_data9_score_W0 0.6060316297877858
# right_data9_score_W' 0.4965487334836355
# Finish one round splitting 9 *********
#
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# right_data10_score_W' 0.7336804366512109
# Finish one round splitting 10 *********
#
#  NO Error Data, Finish Training!
# total split_number 10
# stop_split_num 0
# all_train_score_W' split_num : 0 0.1207766756299161
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 0 0.1800944992458331
# stop_split_num 1
# all_train_score_W' split_num : 1 0.2793081652886675
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 1 0.21958979103604154
# stop_split_num 2
# all_train_score_W' split_num : 2 0.43882219086136887
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 2 0.28326471874089204
# stop_split_num 3
# all_train_score_W' split_num : 3 0.5600868316958943
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 3 0.2893038658175717
# stop_split_num 4
# all_train_score_W' split_num : 4 0.6673665953582776
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 4 0.30950008324853473
# stop_split_num 5
# all_train_score_W' split_num : 5 0.7372573258976924
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 5 0.31363699020583563
# stop_split_num 6
# all_train_score_W' split_num : 6 0.8032161601080106
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 6 0.31619614850055094
# stop_split_num 7
# all_train_score_W' split_num : 7 0.8623418380311266
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 7 0.3399636049944148
# stop_split_num 8
# all_train_score_W' split_num : 8 0.9022938039553076
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 8 0.3461254965173656
# stop_split_num 9
# all_train_score_W' split_num : 9 0.9384713327403542
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 9 0.3578287745026572
# stop_split_num 10
# all_train_score_W' split_num : 10 0.9659884896376534
# test_score_W0 : 0.1800944992458331
# test_score_W': split_num : 10 0.35920064127331

# %%
# compare between best cluster no with TDSM ARI

scoretype = 2
class_num = 28
dim_num = 20
best_cluster_no = 43

som = newSom.SOM(m= best_cluster_no, n=  1, dim=dim_num)  
optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
optimize_W.run(scoretype)
# Out:
# error_data0_score_W1 0.0420680443442775
# error_data0_score_W0 0.031957107644369
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 0.03051401647703295
# error_data1_score_W0 0.00837748111631904
# right_data1_score_W' 0.23622175109687807
# Finish one round splitting 1 *********
#
# error_data2_score_W1 0.031366093781323295
# error_data2_score_W0 -0.0035673327842915517
# right_data2_score_W' 0.13364847443059732
# Finish one round splitting 2 *********
#
# error_data3_score_W1 0.04007988752251011
# error_data3_score_W0 0.008495972469003183
# right_data3_score_W' 0.13674857850279917
# Finish one round splitting 3 *********
#
# error_data4_score_W1 0.024626827418313593
# error_data4_score_W0 -0.004515676602639676
# right_data4_score_W' 0.11159704418639722
# Finish one round splitting 4 *********
#
# error_data5_score_W1 0.024430765131596994
# error_data5_score_W0 -0.007313785391976513
# right_data5_score_W' 0.17266851338873498
# Finish one round splitting 5 *********
#
# error_data6_score_W1 0.020793950850661626
# error_data6_score_W0 -0.011660018410555384
# right_data6_score_W' 0.03718378543127095
# Finish one round splitting 6 *********
#
# error_data7_score_W1 0.053027082619129244
# error_data7_score_W0 -0.026899831219491698
# right_data7_score_W' 0.055666003976143144
# Finish one round splitting 7 *********
#
# error_data8_score_W1 0.027726916034527857
# error_data8_score_W0 -0.017440359868736405
# right_data8_score_W' 0.027777777777777776
# Finish one round splitting 8 *********
#
# error_data9_score_W1 0.11627906976744186
# error_data9_score_W0 -0.046750285062713795
# right_data9_score_W' -0.06960081883316274
# Finish one round splitting 9 *********
#
# error_data10_score_W1 -0.05660377358490566
# error_data10_score_W0 0.08196721311475409
# right_data10_score_W' 0.08163265306122448
# Finish one round splitting 10 *********
#
# error_data11_score_W1 0.0
# error_data11_score_W0 0.0
# right_data11_score_W' 0.0
# Finish one round splitting 11 *********
#
# error_data12_score_W1 1.0
# error_data12_score_W0 1.0
# Error data can be represented by W0 12
# right_data12_score_W' 1.0
# Finish one round splitting 12 *********
#
#  NO Error Data, Finish Training!
# total split_number 12
# stop_split_num 0
# all_train_score_W' split_num : 0 0.040907860220529564
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 0 0.00973145313528895
# stop_split_num 1
# all_train_score_W' split_num : 1 0.22641957912246688
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 1 0.03600693079419062
# stop_split_num 2
# all_train_score_W' split_num : 2 0.3543250495909824
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 2 0.07272065748921779
# stop_split_num 3
# all_train_score_W' split_num : 3 0.501612444731354
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 3 0.08794802251860809
# stop_split_num 4
# all_train_score_W' split_num : 4 0.6229500377198678
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 4 0.07902550491466784
# stop_split_num 5
# all_train_score_W' split_num : 5 0.705542470513698
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 5 0.08365570019879004
# stop_split_num 6
# all_train_score_W' split_num : 6 0.7945119784092409
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 6 0.08724842492558146
# stop_split_num 7
# all_train_score_W' split_num : 7 0.8469829444520419
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 7 0.09081691731194888
# stop_split_num 8
# all_train_score_W' split_num : 8 0.8888909650649414
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 8 0.09528041087989253
# stop_split_num 9
# all_train_score_W' split_num : 9 0.9183648520257597
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 9 0.099342070897849
# stop_split_num 10
# all_train_score_W' split_num : 10 0.9381223087453014
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 10 0.09971943705177316
# stop_split_num 11
# all_train_score_W' split_num : 11 0.9523993135741281
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 11 0.10062583580631454
# stop_split_num 12
# all_train_score_W' split_num : 12 0.9577170093846665
# test_score_W0 : 0.00973145313528895
# test_score_W': split_num : 12 0.10062583580631454

# %%
def initialize_listoflist(scores_list):
    for i in range(0,scores_list.size):
        scores_list[i] = []

def getaveragescore(scores_list):
    for i in range(0,scores_list.size):
        average = np.average(scores_list[i])
        scores_list[i] = average

# %%
scoretype = 1
scope_num = 1
class_num = 28
dim_num = 20
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 28
# *******************
#
# error_data0_score_W1 0.14873004331447254
# error_data0_score_W0 0.14264378077817463
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 0.18095091895529727
# error_data1_score_W0 0.13998971246286707
# right_data1_score_W' 0.32338295329804584
# Finish one round splitting 1 *********
#
# error_data2_score_W1 0.27889822671414854
# error_data2_score_W0 0.18022372570106235
# right_data2_score_W' 0.5087352452720757
# Finish one round splitting 2 *********
#
# error_data3_score_W1 0.31952498338605256
# error_data3_score_W0 0.21753940879829564
# right_data3_score_W' 0.5243237208660433
# Finish one round splitting 3 *********
#
# error_data4_score_W1 0.4321965689296619
# error_data4_score_W0 0.228582605262018
# right_data4_score_W' 0.5275366624195289
# Finish one round splitting 4 *********
#
# error_data5_score_W1 0.4695773171081962
# error_data5_score_W0 0.2828103270474173
# right_data5_score_W' 0.618603834887524
# Finish one round splitting 5 *********
#
# error_data6_score_W1 0.5226531855582756
# error_data6_score_W0 0.3390761533755988
# right_data6_score_W' 0.5773971053498699
# Finish one round splitting 6 *********
#
# error_data7_score_W1 0.5272698842382901
# error_data7_score_W0 0.40783984404966994
# right_data7_score_W' 0.7764920076932598
# Finish one round splitting 7 *********
#
# error_data8_score_W1 0.5701817362401674
# error_data8_score_W0 0.4226168032902239
# right_data8_score_W' 0.7011631882783442
# Finish one round splitting 8 *********
#
# error_data9_score_W1 0.5908277881881059
# error_data9_score_W0 0.4223688198975175
# right_data9_score_W' 0.6820841256628642
# Finish one round splitting 9 *********
#
# error_data10_score_W1 0.7148331105132685
# error_data10_score_W0 0.3617298662367427
# right_data10_score_W' 0.5842847800557028
# Finish one round splitting 10 *********
#
# error_data11_score_W1 0.8519590445170675
# error_data11_score_W0 0.5242524223457239
# right_data11_score_W' 0.39472833517573314
# Finish one round splitting 11 *********
#
# error_data12_score_W1 1.0
# error_data12_score_W0 1.0
# Error data can be represented by W0 12
# right_data12_score_W' 0.5771596324111234
# Finish one round splitting 12 *********
#
#  NO Error Data, Finish Training!
# total split_number 12
# stop_split_num 0
# all_train_score_W' split_num : 0 0.13011056633016632
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 0 0.16085006076559955
# stop_split_num 1
# all_train_score_W' split_num : 1 0.27866111667845805
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 1 0.1927712118878063
# stop_split_num 2
# all_train_score_W' split_num : 2 0.40848319245438014
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 2 0.23144078750661057
# stop_split_num 3
# all_train_score_W' split_num : 3 0.5328268497178505
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 3 0.26851848917620263
# stop_split_num 4
# all_train_score_W' split_num : 4 0.6294409817711184
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 4 0.288915236817468
# stop_split_num 5
# all_train_score_W' split_num : 5 0.72803173484397
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 5 0.3030266438825151
# stop_split_num 6
# all_train_score_W' split_num : 6 0.7886583145966167
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 6 0.31752355391795495
# stop_split_num 7
# all_train_score_W' split_num : 7 0.843574464958079
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 7 0.33349110581904273
# stop_split_num 8
# all_train_score_W' split_num : 8 0.8864231830787249
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 8 0.3368818798408988
# stop_split_num 9
# all_train_score_W' split_num : 9 0.9148227636674502
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 9 0.34609569948355384
# stop_split_num 10
# all_train_score_W' split_num : 10 0.9421666676534876
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 10 0.3485229703083888
# stop_split_num 11
# all_train_score_W' split_num : 11 0.9560900651642084
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 11 0.3485229703083888
# stop_split_num 12
# all_train_score_W' split_num : 12 0.9670036441237582
# test_score_W0 : 0.16085006076559955
# test_score_W': split_num : 12 0.3485229703083888

# %%
scoretype = 1
scope_num = 30
class_num = 28
dim_num = 20
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.7162162162162162
# right_data0_score_W0 1.0
# error_data0_score_W1 0.184306616538063
# error_data0_score_W0 0.126306439786961
# combinedweight shape 0: (56, 20)
# right_data0_score_W' 0.4832502879381779
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2098145327299688
# error_data1_score_W0 0.123494359137192
# combinedweight shape1 : (84, 20)
# right_data1_score_W' 0.5094911348176758
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28125652948162794
# error_data2_score_W0 0.1499965289181909
# combinedweight shape1 : (112, 20)
# right_data2_score_W' 0.5928579622342827
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.28837272643026773
# error_data3_score_W0 0.11808852545887247
# combinedweight shape1 : (140, 20)
# right_data3_score_W' 0.7258726882562615
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.31879685417630876
# error_data4_score_W0 0.1486651207154377
# combinedweight shape1 : (168, 20)
# right_data4_score_W' 0.6849297574128884
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4389030728304961
# error_data5_score_W0 0.19748742057318858
# combinedweight shape1 : (196, 20)
# right_data5_score_W' 0.6803093454892144
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.428809394430557
# error_data6_score_W0 0.20266927098740767
# combinedweight shape1 : (224, 20)
# right_data6_score_W' 0.7517785405312161
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4853893848739299
# error_data7_score_W0 0.2981438119103544
# combinedweight shape1 : (252, 20)
# right_data7_score_W' 0.7741655945855884
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5261276857731476
# error_data8_score_W0 0.38910304400843015
# combinedweight shape1 : (280, 20)
# right_data8_score_W' 0.8318956723464143
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6316659567292161
# error_data9_score_W0 0.4550722752569379
# combinedweight shape1 : (308, 20)
# right_data9_score_W' 0.8283419256373167
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.8048377108888054
# error_data10_score_W0 0.5734831299946331
# combinedweight shape1 : (336, 20)
# right_data10_score_W' 0.9445272649374314
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 0.7918756684685216
# combinedweight shape1 : (364, 20)
# right_data11_score_W' 0.9246117268712489
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1253892141020595
# all_train_score_W': 0.9732428980568271
# test_score_W0 : 0.10431087014258272
# test_score_W': 0.3466406735133025
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.7200772200772201
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21327062931881852
# error_data0_score_W0 0.14367570424533985
# combinedweight shape 0: (112, 20)
# right_data0_score_W' 0.4197827526275814
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2355006424867528
# error_data1_score_W0 0.1539254817887951
# combinedweight shape1 : (168, 20)
# right_data1_score_W' 0.6179336272732121
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28789498660096763
# error_data2_score_W0 0.1648109678185007
# combinedweight shape1 : (224, 20)
# right_data2_score_W' 0.5572934913736786
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3297148282586338
# error_data3_score_W0 0.18338880435444438
# combinedweight shape1 : (280, 20)
# right_data3_score_W' 0.6959696677866313
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3858992849115208
# error_data4_score_W0 0.20849746407518463
# combinedweight shape1 : (336, 20)
# right_data4_score_W' 0.7096975206654725
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.41302479866970254
# error_data5_score_W0 0.240499331193863
# combinedweight shape1 : (392, 20)
# right_data5_score_W' 0.7443644417516008
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.4970937621325249
# error_data6_score_W0 0.2504102605951131
# combinedweight shape1 : (448, 20)
# right_data6_score_W' 0.8048384689590349
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4985864566219442
# error_data7_score_W0 0.26404279234669265
# combinedweight shape1 : (504, 20)
# right_data7_score_W' 0.8040038768531333
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5542451339955946
# error_data8_score_W0 0.42304719037545563
# combinedweight shape1 : (560, 20)
# right_data8_score_W' 0.8650908689125241
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.733406342478337
# error_data9_score_W0 0.5294509633736092
# combinedweight shape1 : (616, 20)
# right_data9_score_W' 0.9090909090909091
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.884025111448191
# error_data10_score_W0 0.6764971842744295
# combinedweight shape1 : (672, 20)
# right_data10_score_W' 0.9315520459418734
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (728, 20)
# right_data11_score_W' 0.8189625508803525
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.13613452230134523
# all_train_score_W': 0.9732428980568271
# test_score_W0 : 0.15571199666042743
# test_score_W': 0.3466406735133025
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.6795366795366795
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21432979309845354
# error_data0_score_W0 0.15729326831968374
# combinedweight shape 0: (168, 20)
# right_data0_score_W' 0.5555763083936456
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20483635951785456
# error_data1_score_W0 0.13147641788876507
# combinedweight shape1 : (252, 20)
# right_data1_score_W' 0.530804864748317
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31999230825168895
# error_data2_score_W0 0.16765269778188216
# combinedweight shape1 : (336, 20)
# right_data2_score_W' 0.6227480495817942
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.35841332867438447
# error_data3_score_W0 0.158462717375075
# combinedweight shape1 : (420, 20)
# right_data3_score_W' 0.7487070690999924
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.41515450055004555
# error_data4_score_W0 0.1600500844388659
# combinedweight shape1 : (504, 20)
# right_data4_score_W' 0.7192213687869864
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4430754002889435
# error_data5_score_W0 0.2923475196825353
# combinedweight shape1 : (588, 20)
# right_data5_score_W' 0.7187783832347214
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5512066047913309
# error_data6_score_W0 0.2947597165737448
# combinedweight shape1 : (672, 20)
# right_data6_score_W' 0.7711570177143927
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6159506506217486
# error_data7_score_W0 0.3022192479899451
# combinedweight shape1 : (756, 20)
# right_data7_score_W' 0.8313872537712711
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6817360906096187
# error_data8_score_W0 0.35830355628691885
# combinedweight shape1 : (840, 20)
# right_data8_score_W' 0.7418334361139165
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6294832607672233
# error_data9_score_W0 0.33355209088790394
# combinedweight shape1 : (924, 20)
# right_data9_score_W' 0.8825386262063205
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.2740175421212811
# combinedweight shape1 : (1008, 20)
# right_data10_score_W' 0.822328362394686
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1706943327184604
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.18486128614653852
# test_score_W': 0.34830942675001675
# neuron unit number: 112
# *******************
# Error Data percentage 0.693050193050193
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23385562762143391
# error_data0_score_W0 0.15590509662457866
# combinedweight shape 0: (224, 20)
# right_data0_score_W' 0.5850227519553155
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2168340759259123
# error_data1_score_W0 0.12034432865316297
# combinedweight shape1 : (336, 20)
# right_data1_score_W' 0.6174540280684746
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29206843749159284
# error_data2_score_W0 0.16196459423816026
# combinedweight shape1 : (448, 20)
# right_data2_score_W' 0.5305358820716959
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.38305984904098356
# error_data3_score_W0 0.1829939365526006
# combinedweight shape1 : (560, 20)
# right_data3_score_W' 0.64813954612401
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38860124002909063
# error_data4_score_W0 0.2018418120686042
# combinedweight shape1 : (672, 20)
# right_data4_score_W' 0.7383892177244044
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.470305916124112
# error_data5_score_W0 0.17713781923246172
# combinedweight shape1 : (784, 20)
# right_data5_score_W' 0.7496747284824546
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5781184635909168
# error_data6_score_W0 0.2576341190558843
# combinedweight shape1 : (896, 20)
# right_data6_score_W' 0.8130805403551431
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6144195411615189
# error_data7_score_W0 0.20978611869447322
# combinedweight shape1 : (1008, 20)
# right_data7_score_W' 0.8107568499178791
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6338241949716024
# error_data8_score_W0 0.18138441778818273
# combinedweight shape1 : (1120, 20)
# right_data8_score_W' 0.7901285219616305
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.7968156220676632
# error_data9_score_W0 0.1462239577578469
# combinedweight shape1 : (1232, 20)
# right_data9_score_W' 0.822816179864442
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.0
# combinedweight shape1 : (1344, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.15711636520037042
# all_train_score_W': 0.9732428980568271
# test_score_W0 : 0.188415172170706
# test_score_W': 0.3466406735133025
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.6911196911196911
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20601172116357888
# error_data0_score_W0 0.15450144613625394
# combinedweight shape 0: (280, 20)
# right_data0_score_W' 0.5884662864242085
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23669387708141815
# error_data1_score_W0 0.12489654761718286
# combinedweight shape1 : (420, 20)
# right_data1_score_W' 0.589462477997318
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3121865896395857
# error_data2_score_W0 0.19164336838998117
# combinedweight shape1 : (560, 20)
# right_data2_score_W' 0.6269477181247657
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.35480071335010727
# error_data3_score_W0 0.15590636468559774
# combinedweight shape1 : (700, 20)
# right_data3_score_W' 0.7147311312870113
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.42275162128621435
# error_data4_score_W0 0.19229501862244738
# combinedweight shape1 : (840, 20)
# right_data4_score_W' 0.6670172031826681
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.49370130045476046
# error_data5_score_W0 0.25038707930384035
# combinedweight shape1 : (980, 20)
# right_data5_score_W' 0.7316542860746827
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5453594542932481
# error_data6_score_W0 0.1764365096845136
# combinedweight shape1 : (1120, 20)
# right_data6_score_W' 0.7478677122711238
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6635425533613362
# error_data7_score_W0 0.16530070780281364
# combinedweight shape1 : (1260, 20)
# right_data7_score_W' 0.8177734667035214
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.722712979457676
# error_data8_score_W0 0.16812060584911132
# combinedweight shape1 : (1400, 20)
# right_data8_score_W' 0.8778873720311172
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.24661202918433175
# combinedweight shape1 : (1540, 20)
# right_data9_score_W' 0.9505261186143643
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16016753369346134
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.18122864508960432
# test_score_W': 0.3476824755948417
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21668588749783607
# error_data0_score_W0 0.15017498078184088
# combinedweight shape 0: (336, 20)
# right_data0_score_W' 0.5711503868906448
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23963489457240017
# error_data1_score_W0 0.13537884376157686
# combinedweight shape1 : (504, 20)
# right_data1_score_W' 0.5994855872545883
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3009690695578647
# error_data2_score_W0 0.1278977791254104
# combinedweight shape1 : (672, 20)
# right_data2_score_W' 0.6313625479137727
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.33593094834354315
# error_data3_score_W0 0.10782280469244976
# combinedweight shape1 : (840, 20)
# right_data3_score_W' 0.7884859681849904
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4259291798834799
# error_data4_score_W0 0.12088667393098931
# combinedweight shape1 : (1008, 20)
# right_data4_score_W' 0.6607764120179064
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4854588110337453
# error_data5_score_W0 0.20125856181723556
# combinedweight shape1 : (1176, 20)
# right_data5_score_W' 0.7590712136914644
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.48101854746129546
# error_data6_score_W0 0.19358746134699586
# combinedweight shape1 : (1344, 20)
# right_data6_score_W' 0.8103246822476121
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6074899569911142
# error_data7_score_W0 0.26880442936008014
# combinedweight shape1 : (1512, 20)
# right_data7_score_W' 0.7941666965794867
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6395808117799536
# error_data8_score_W0 0.4832096709545601
# combinedweight shape1 : (1680, 20)
# right_data8_score_W' 0.864937779230575
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8186369418925545
# error_data9_score_W0 0.4135761819989919
# combinedweight shape1 : (1848, 20)
# right_data9_score_W' 0.8228161798644421
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.0
# combinedweight shape1 : (2016, 20)
# right_data10_score_W' 0.8519590445170675
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16707840357576992
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.19893345519468647
# test_score_W': 0.3476824755948417
# neuron unit number: 196
# *******************
#
# Error Data percentage 0.6698841698841699
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20553746071107745
# error_data0_score_W0 0.15133235908593892
# combinedweight shape 0: (392, 20)
# right_data0_score_W' 0.5826014671514441
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23803186065839532
# error_data1_score_W0 0.09674368569796275
# combinedweight shape1 : (588, 20)
# right_data1_score_W' 0.5804622523727297
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31966116939797334
# error_data2_score_W0 0.11153922502975311
# combinedweight shape1 : (784, 20)
# right_data2_score_W' 0.6070595998392502
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40731680770062906
# error_data3_score_W0 0.23527879551743783
# combinedweight shape1 : (980, 20)
# right_data3_score_W' 0.6859805020740453
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.41872946010538087
# error_data4_score_W0 0.16590733480194822
# combinedweight shape1 : (1176, 20)
# right_data4_score_W' 0.7127747540697013
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.491154453199906
# error_data5_score_W0 0.15309659419753907
# combinedweight shape1 : (1372, 20)
# right_data5_score_W' 0.7815999526782591
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.578852101343662
# error_data6_score_W0 0.2054007987436975
# combinedweight shape1 : (1568, 20)
# right_data6_score_W' 0.7691609461788518
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6422211660198839
# error_data7_score_W0 0.26553872132616974
# combinedweight shape1 : (1764, 20)
# right_data7_score_W' 0.7454277247829574
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6957670341262344
# error_data8_score_W0 0.3760814469519632
# combinedweight shape1 : (1960, 20)
# right_data8_score_W' 0.8034732983841154
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6712694853274374
# error_data9_score_W0 0.4743509876140318
# combinedweight shape1 : (2156, 20)
# right_data9_score_W' 0.9565217391304347
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (2352, 20)
# right_data10_score_W' 0.8571428571428571
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1750682487922725
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.20899325236017272
# test_score_W': 0.34830942675001675
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2405339612788036
# error_data0_score_W0 0.18128864426451347
# combinedweight shape 0: (448, 20)
# right_data0_score_W' 0.6101927091740285
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2609293281652467
# error_data1_score_W0 0.10827617255301834
# combinedweight shape1 : (672, 20)
# right_data1_score_W' 0.559027272295105
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3317639481242757
# error_data2_score_W0 0.13109989512620845
# combinedweight shape1 : (896, 20)
# right_data2_score_W' 0.6040779739775449
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40860126241246747
# error_data3_score_W0 0.16217570749334267
# combinedweight shape1 : (1120, 20)
# right_data3_score_W' 0.5764869723850709
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.43872075885257616
# error_data4_score_W0 0.15756744682228765
# combinedweight shape1 : (1344, 20)
# right_data4_score_W' 0.6938717178445118
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4661561186129116
# error_data5_score_W0 0.14986944027960603
# combinedweight shape1 : (1568, 20)
# right_data5_score_W' 0.755163593826854
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5976142899094938
# error_data6_score_W0 0.19759811206664207
# combinedweight shape1 : (1792, 20)
# right_data6_score_W' 0.7157420483952172
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6341370402457854
# error_data7_score_W0 0.08992148987684373
# combinedweight shape1 : (2016, 20)
# right_data7_score_W' 0.7492224457978357
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5047870942353422
# error_data8_score_W0 0.20543860534278371
# combinedweight shape1 : (2240, 20)
# right_data8_score_W' 0.8575015337075814
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6666666666666666
# error_data9_score_W0 0.2693558349079911
# combinedweight shape1 : (2464, 20)
# right_data9_score_W' 0.8189625508803525
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (2688, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20895110940244704
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.25359455662453856
# test_score_W': 0.3476824755948417
# neuron unit number: 252
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.1994500166186641
# error_data0_score_W0 0.130116219642821
# combinedweight shape 0: (504, 20)
# right_data0_score_W' 0.496183845965096
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.21375336773773734
# error_data1_score_W0 0.11876398234530985
# combinedweight shape1 : (756, 20)
# right_data1_score_W' 0.5600563452774743
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31758050445366054
# error_data2_score_W0 0.14073717933356159
# combinedweight shape1 : (1008, 20)
# right_data2_score_W' 0.5774126994455723
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3628715630348147
# error_data3_score_W0 0.1610347723845436
# combinedweight shape1 : (1260, 20)
# right_data3_score_W' 0.692174439361981
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3998268180747371
# error_data4_score_W0 0.1681895732453392
# combinedweight shape1 : (1512, 20)
# right_data4_score_W' 0.8045928368270082
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4847525532091432
# error_data5_score_W0 0.17773538236531175
# combinedweight shape1 : (1764, 20)
# right_data5_score_W' 0.7920054687684284
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.506159154438204
# error_data6_score_W0 0.23437055960692818
# combinedweight shape1 : (2016, 20)
# right_data6_score_W' 0.6851459985701119
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6588942043198054
# error_data7_score_W0 0.22171135876919243
# combinedweight shape1 : (2268, 20)
# right_data7_score_W' 0.8034990266176913
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7015633108414281
# error_data8_score_W0 0.3308751812876516
# combinedweight shape1 : (2520, 20)
# right_data8_score_W' 0.8625215077069525
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6775148272677979
# error_data9_score_W0 0.11481634102168048
# combinedweight shape1 : (2772, 20)
# right_data9_score_W' 0.8487312231733642
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (3024, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16238889373361368
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.16521371197612955
# test_score_W': 0.3476824755948417
# neuron unit number: 280
# *******************
#
# Error Data percentage 0.6602316602316602
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21180877139254836
# error_data0_score_W0 0.17268401968579197
# combinedweight shape 0: (560, 20)
# right_data0_score_W' 0.5683208549338498
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.24539267490581768
# error_data1_score_W0 0.13171641946311266
# combinedweight shape1 : (840, 20)
# right_data1_score_W' 0.5706703224228903
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2851970777636764
# error_data2_score_W0 0.1732189106618772
# combinedweight shape1 : (1120, 20)
# right_data2_score_W' 0.5833732282349238
# Finish one training *********
# 3
# right_data3_score_W0 1.0000000000000002
# error_data3_score_W1 0.38883824573360715
# error_data3_score_W0 0.21014451490399638
# combinedweight shape1 : (1400, 20)
# right_data3_score_W' 0.6643989947051071
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.4660510994763859
# error_data4_score_W0 0.2608920103765349
# combinedweight shape1 : (1680, 20)
# right_data4_score_W' 0.7849878681397308
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5029084422715487
# error_data5_score_W0 0.2750655363658361
# combinedweight shape1 : (1960, 20)
# right_data5_score_W' 0.7205081978302358
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5711618038147401
# error_data6_score_W0 0.40883374733332956
# combinedweight shape1 : (2240, 20)
# right_data6_score_W' 0.7889370620357968
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6294378613274175
# error_data7_score_W0 0.4934736523059826
# combinedweight shape1 : (2520, 20)
# right_data7_score_W' 0.7750050303241238
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6157229319010113
# error_data8_score_W0 0.49021033377267353
# combinedweight shape1 : (2800, 20)
# right_data8_score_W' 0.8078134272252565
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.737175493807016
# error_data9_score_W0 0.6515533942552646
# combinedweight shape1 : (3080, 20)
# right_data9_score_W' 0.7330209011585911
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (3360, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.19541260233082142
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.23944980997415635
# test_score_W': 0.3476824755948417
# neuron unit number: 308
# *******************
#
# Error Data percentage 0.6525096525096525
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22324707171949068
# error_data0_score_W0 0.17476896690223642
# combinedweight shape 0: (616, 20)
# right_data0_score_W' 0.507031665537477
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23111305861478362
# error_data1_score_W0 0.1433366311451009
# combinedweight shape1 : (924, 20)
# right_data1_score_W' 0.5512622396513408
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29941206767755296
# error_data2_score_W0 0.12648640509209502
# combinedweight shape1 : (1232, 20)
# right_data2_score_W' 0.5893189637697436
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3722120845397349
# error_data3_score_W0 0.160437486681451
# combinedweight shape1 : (1540, 20)
# right_data3_score_W' 0.6793790169598306
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4412870828332489
# error_data4_score_W0 0.15706408545078082
# combinedweight shape1 : (1848, 20)
# right_data4_score_W' 0.6995288173789621
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.42691189130768425
# error_data5_score_W0 0.1965382650853385
# combinedweight shape1 : (2156, 20)
# right_data5_score_W' 0.74941733221528
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5846170923108625
# error_data6_score_W0 0.23147768077727895
# combinedweight shape1 : (2464, 20)
# right_data6_score_W' 0.6918255697984477
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6411199326901065
# error_data7_score_W0 0.3222792697934536
# combinedweight shape1 : (2772, 20)
# right_data7_score_W' 0.7524530449656456
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6623843373872026
# error_data8_score_W0 0.37103454246065626
# combinedweight shape1 : (3080, 20)
# right_data8_score_W' 0.8731580672754992
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.0
# combinedweight shape1 : (3388, 20)
# right_data9_score_W' 0.9
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.2022824910336837
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.22420781005881643
# test_score_W': 0.3476824755948417
# neuron unit number: 336
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23269858090485923
# error_data0_score_W0 0.17239922164413965
# combinedweight shape 0: (672, 20)
# right_data0_score_W' 0.5063947991337647
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2755072181279609
# error_data1_score_W0 0.08164180466977976
# combinedweight shape1 : (1008, 20)
# right_data1_score_W' 0.5309295862487722
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.34089814212120706
# error_data2_score_W0 0.0919534687386611
# combinedweight shape1 : (1344, 20)
# right_data2_score_W' 0.7032248672247926
# Finish one training *********
# 3
# right_data3_score_W0 1.0000000000000002
# error_data3_score_W1 0.40762228036203196
# error_data3_score_W0 0.15834665214059426
# combinedweight shape1 : (1680, 20)
# right_data3_score_W' 0.6485920319346292
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4408703795556209
# error_data4_score_W0 0.22168138625630654
# combinedweight shape1 : (2016, 20)
# right_data4_score_W' 0.6808245785089457
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5199902938180112
# error_data5_score_W0 0.11584317072792204
# combinedweight shape1 : (2352, 20)
# right_data5_score_W' 0.7173068408931876
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.581942391403756
# error_data6_score_W0 0.2469617655314895
# combinedweight shape1 : (2688, 20)
# right_data6_score_W' 0.7575403343089289
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6606526019111773
# error_data7_score_W0 0.3202272477945745
# combinedweight shape1 : (3024, 20)
# right_data7_score_W' 0.7808587024500466
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.33876262915585054
# combinedweight shape1 : (3360, 20)
# right_data8_score_W' 0.7779531588078218
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.2740175421212811
# error_data9_score_W0 0.2740175421212811
# combinedweight shape1 : (3696, 20)
# right_data9_score_W' 0.9200625111439561
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (4032, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.19914444858309788
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.24583476036053736
# test_score_W': 0.3476824755948417
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.6756756756756757
# right_data0_score_W0 1.0
# error_data0_score_W1 0.228868233509625
# error_data0_score_W0 0.16061580477220566
# combinedweight shape 0: (728, 20)
# right_data0_score_W' 0.5500373911888403
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26138453858973926
# error_data1_score_W0 0.1358508172584139
# combinedweight shape1 : (1092, 20)
# right_data1_score_W' 0.5351905902741653
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.37455931566571615
# error_data2_score_W0 0.11159826794325468
# combinedweight shape1 : (1456, 20)
# right_data2_score_W' 0.5833277277129646
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.38029460491135086
# error_data3_score_W0 0.16457089441834896
# combinedweight shape1 : (1820, 20)
# right_data3_score_W' 0.6710263337555348
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4493091033280302
# error_data4_score_W0 0.13108587700319183
# combinedweight shape1 : (2184, 20)
# right_data4_score_W' 0.6876293437734414
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4975024712467954
# error_data5_score_W0 0.163591837428772
# combinedweight shape1 : (2548, 20)
# right_data5_score_W' 0.7340626841230324
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6396788166021438
# error_data6_score_W0 0.18139902058495289
# combinedweight shape1 : (2912, 20)
# right_data6_score_W' 0.7446716211616766
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5520511321187771
# error_data7_score_W0 0.2455725561710027
# combinedweight shape1 : (3276, 20)
# right_data7_score_W' 0.8296854426151284
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.45235407972988223
# error_data8_score_W0 0.2611272151678901
# combinedweight shape1 : (3640, 20)
# right_data8_score_W' 0.8571428571428571
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.5678815282792384
# combinedweight shape1 : (4004, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.16905830331587451
# all_train_score_W': 0.9669440944348227
# test_score_W0 : 0.2124373037522906
# test_score_W': 0.34750124961538664
# neuron unit number: 392
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22837188386289042
# error_data0_score_W0 0.1674362591801234
# combinedweight shape 0: (784, 20)
# right_data0_score_W' 0.47058581130832183
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2579739500290419
# error_data1_score_W0 0.08279184796504932
# combinedweight shape1 : (1176, 20)
# right_data1_score_W' 0.5753990891561361
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.32920655480755895
# error_data2_score_W0 0.0960197136617073
# combinedweight shape1 : (1568, 20)
# right_data2_score_W' 0.5899994582592447
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4375660179474442
# error_data3_score_W0 0.19320553807248528
# combinedweight shape1 : (1960, 20)
# right_data3_score_W' 0.6670659365046654
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4784388767488715
# error_data4_score_W0 0.10711123778842603
# combinedweight shape1 : (2352, 20)
# right_data4_score_W' 0.7147098562985474
# Finish one training *********
# 5
# right_data5_score_W0 1.0000000000000002
# error_data5_score_W1 0.5945207858255785
# error_data5_score_W0 0.19605971856689988
# combinedweight shape1 : (2744, 20)
# right_data5_score_W' 0.7207490970266182
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6971514582919115
# error_data6_score_W0 0.1952922115047877
# combinedweight shape1 : (3136, 20)
# right_data6_score_W' 0.7068414053211678
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7602878262552523
# error_data7_score_W0 0.16939741126053048
# combinedweight shape1 : (3528, 20)
# right_data7_score_W' 0.8570398853450114
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.0
# combinedweight shape1 : (3920, 20)
# right_data8_score_W' 0.8936897079186652
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1836933815030215
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.22522840702106586
# test_score_W': 0.3476824755948417
# neuron unit number: 420
# *******************
#
# Error Data percentage 0.666023166023166
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20824434194153865
# error_data0_score_W0 0.16094802500953326
# combinedweight shape 0: (840, 20)
# right_data0_score_W' 0.6306618266462113
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.25970137589657666
# error_data1_score_W0 0.10427783046734937
# combinedweight shape1 : (1260, 20)
# right_data1_score_W' 0.570567212507688
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31477280703359956
# error_data2_score_W0 0.1475646325217684
# combinedweight shape1 : (1680, 20)
# right_data2_score_W' 0.5974955374795713
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3669938649469051
# error_data3_score_W0 0.1773049045630813
# combinedweight shape1 : (2100, 20)
# right_data3_score_W' 0.7675273029343964
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.43075224230288955
# error_data4_score_W0 0.20529555806826413
# combinedweight shape1 : (2520, 20)
# right_data4_score_W' 0.6876596139218998
# Finish one training *********
# 5
# right_data5_score_W0 1.0000000000000002
# error_data5_score_W1 0.48617399025181945
# error_data5_score_W0 0.12004614546140858
# combinedweight shape1 : (2940, 20)
# right_data5_score_W' 0.7540237019618379
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6300556678142433
# error_data6_score_W0 0.22127907767553864
# combinedweight shape1 : (3360, 20)
# right_data6_score_W' 0.7213941182995391
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6417095019680872
# error_data7_score_W0 0.2543698230667295
# combinedweight shape1 : (3780, 20)
# right_data7_score_W' 0.8296854426151284
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.34028398819332006
# combinedweight shape1 : (4200, 20)
# right_data8_score_W' 0.8283419256373168
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.3437110184854508
# error_data9_score_W0 0.2693558349079911
# combinedweight shape1 : (4620, 20)
# right_data9_score_W' 0.8571428571428571
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5040, 20)
# right_data10_score_W' 0.7336804366512112
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1829451683192957
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.19321652276322943
# test_score_W': 0.3476824755948417
# neuron unit number: 448
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2334959331381532
# error_data0_score_W0 0.17531276582147934
# combinedweight shape 0: (896, 20)
# right_data0_score_W' 0.5437556497758925
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2512081345441459
# error_data1_score_W0 0.13319807885691207
# combinedweight shape1 : (1344, 20)
# right_data1_score_W' 0.5481000852374786
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3401346208222107
# error_data2_score_W0 0.1274909885055521
# combinedweight shape1 : (1792, 20)
# right_data2_score_W' 0.5569537505072609
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40599110759565193
# error_data3_score_W0 0.1766543630505541
# combinedweight shape1 : (2240, 20)
# right_data3_score_W' 0.7136180442653101
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4811874818532224
# error_data4_score_W0 0.14186033119763572
# combinedweight shape1 : (2688, 20)
# right_data4_score_W' 0.7449834004269332
# Finish one training *********
# 5
# right_data5_score_W0 1.0000000000000002
# error_data5_score_W1 0.5908019047195922
# error_data5_score_W0 0.23576926701597664
# combinedweight shape1 : (3136, 20)
# right_data5_score_W' 0.7507962543786647
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6126492971120643
# error_data6_score_W0 0.25550125212517955
# combinedweight shape1 : (3584, 20)
# right_data6_score_W' 0.8188200034147459
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7232630682175437
# error_data7_score_W0 0.29280451529123375
# combinedweight shape1 : (4032, 20)
# right_data7_score_W' 0.8415264788807096
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.2693558349079911
# error_data8_score_W0 0.0
# combinedweight shape1 : (4480, 20)
# right_data8_score_W' 0.8700141279140435
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.0
# error_data9_score_W0 0.0
# combinedweight shape1 : (4928, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5376, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20022701177066715
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.23648002659160083
# test_score_W': 0.34581891737107207
# neuron unit number: 476
# *******************
#
# Error Data percentage 0.6621621621621622
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22419254285381732
# error_data0_score_W0 0.15011675898074114
# combinedweight shape 0: (952, 20)
# right_data0_score_W' 0.4649338534271013
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23546232600897057
# error_data1_score_W0 0.09105257058258835
# combinedweight shape1 : (1428, 20)
# right_data1_score_W' 0.5800478693583445
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31435299500153896
# error_data2_score_W0 0.10105909664416762
# combinedweight shape1 : (1904, 20)
# right_data2_score_W' 0.560861521177986
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3923774502534638
# error_data3_score_W0 0.17160708957810786
# combinedweight shape1 : (2380, 20)
# right_data3_score_W' 0.6059024906547256
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.39658283934726163
# error_data4_score_W0 0.146155482150518
# combinedweight shape1 : (2856, 20)
# right_data4_score_W' 0.7648912533628723
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5039052476237217
# error_data5_score_W0 0.20215187673007617
# combinedweight shape1 : (3332, 20)
# right_data5_score_W' 0.7475644567192059
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5752085303437353
# error_data6_score_W0 0.21392290245434842
# combinedweight shape1 : (3808, 20)
# right_data6_score_W' 0.8028324478798183
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6856335524148305
# error_data7_score_W0 0.2523839004463063
# combinedweight shape1 : (4284, 20)
# right_data7_score_W' 0.8692344773394185
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7367088530163903
# error_data8_score_W0 0.2757769402592413
# combinedweight shape1 : (4760, 20)
# right_data8_score_W' 0.8483686100754009
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.39999999999999997
# error_data9_score_W0 0.0
# combinedweight shape1 : (5236, 20)
# right_data9_score_W' 0.9090909090909091
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5712, 20)
# right_data10_score_W' 0.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17938653816081793
# all_train_score_W': 0.9722691624242832
# test_score_W0 : 0.18492420554534228
# test_score_W': 0.3460150890340086
# neuron unit number: 504
# *******************
#
# Error Data percentage 0.6718146718146718
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2123707105434942
# error_data0_score_W0 0.16108847901591147
# combinedweight shape 0: (1008, 20)
# right_data0_score_W' 0.6508672460957162
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2613554477962118
# error_data1_score_W0 0.11283078270163936
# combinedweight shape1 : (1512, 20)
# right_data1_score_W' 0.5872619770944136
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3293195816761051
# error_data2_score_W0 0.07968842916118293
# combinedweight shape1 : (2016, 20)
# right_data2_score_W' 0.6436706250002492
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.43139962071307186
# error_data3_score_W0 0.14265288687259076
# combinedweight shape1 : (2520, 20)
# right_data3_score_W' 0.7085276565616592
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.43772433024378127
# error_data4_score_W0 0.19035858713519932
# combinedweight shape1 : (3024, 20)
# right_data4_score_W' 0.6993700275612782
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.48543005218299384
# error_data5_score_W0 0.21817016308316334
# combinedweight shape1 : (3528, 20)
# right_data5_score_W' 0.6532378813357967
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5676963962158362
# error_data6_score_W0 0.27058860980433325
# combinedweight shape1 : (4032, 20)
# right_data6_score_W' 0.6810924210679582
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6316563297480654
# error_data7_score_W0 0.1576301319724114
# combinedweight shape1 : (4536, 20)
# right_data7_score_W' 0.7335564933339042
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5438353977530026
# error_data8_score_W0 0.2444439821583827
# combinedweight shape1 : (5040, 20)
# right_data8_score_W' 0.8283419256373168
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6666666666666666
# error_data9_score_W0 0.2693558349079911
# combinedweight shape1 : (5544, 20)
# right_data9_score_W' 0.7134063057636204
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (6048, 20)
# right_data10_score_W' 1.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17791134084415142
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.19481657752630513
# test_score_W': 0.3486942897836553
# neuron unit number: 532
# *******************
#
# Error Data percentage 0.6563706563706564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22113162055766727
# error_data0_score_W0 0.17326779962847222
# combinedweight shape 0: (1064, 20)
# right_data0_score_W' 0.5719389243754868
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26879824360809335
# error_data1_score_W0 0.10631225907649017
# combinedweight shape1 : (1596, 20)
# right_data1_score_W' 0.539247777519748
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3485797072076592
# error_data2_score_W0 0.15060156503931071
# combinedweight shape1 : (2128, 20)
# right_data2_score_W' 0.5344777419542591
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.38864352094309723
# error_data3_score_W0 0.10442434791736982
# combinedweight shape1 : (2660, 20)
# right_data3_score_W' 0.5830312597212772
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.47162978604720435
# error_data4_score_W0 0.15534657519071127
# combinedweight shape1 : (3192, 20)
# right_data4_score_W' 0.625696117050935
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5276030939494857
# error_data5_score_W0 0.12441681246827069
# combinedweight shape1 : (3724, 20)
# ...
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (7392, 20)
# right_data9_score_W' 0.8571428571428571
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17800566261116466
# all_train_score_W': 0.9670022629337099
# test_score_W0 : 0.2339069872506183
# test_score_W': 0.34742880763691186
# neuron unit number: 700
# *******************
#
# Error Data percentage 0.6505791505791506
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22465845854288857
# error_data0_score_W0 0.17970485638918562
# combinedweight shape 0: (1400, 20)
# right_data0_score_W' 0.5058798870706191
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27134301162422025
# error_data1_score_W0 0.1284147281033921
# combinedweight shape1 : (2100, 20)
# right_data1_score_W' 0.47846561821668654
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3382042374729929
# error_data2_score_W0 0.13573455824843766
# combinedweight shape1 : (2800, 20)
# right_data2_score_W' 0.682860486132256
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.42102187556639653
# error_data3_score_W0 0.058191890155406135
# combinedweight shape1 : (3500, 20)
# right_data3_score_W' 0.662033515817262
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.49131494348463023
# error_data4_score_W0 0.15820184651668584
# combinedweight shape1 : (4200, 20)
# right_data4_score_W' 0.7399697415398369
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5677041115465908
# error_data5_score_W0 0.2518606407208319
# combinedweight shape1 : (4900, 20)
# right_data5_score_W' 0.7539062652612172
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5946235776674458
# error_data6_score_W0 0.39513617470256795
# combinedweight shape1 : (5600, 20)
# right_data6_score_W' 0.7514163550784647
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.705533730359353
# error_data7_score_W0 0.4595810836113788
# combinedweight shape1 : (6300, 20)
# right_data7_score_W' 0.797227580886918
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.9035000824425833
# error_data8_score_W0 0.6313068075421489
# combinedweight shape1 : (7000, 20)
# right_data8_score_W' 0.8228161798644421
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (7700, 20)
# right_data9_score_W' 0.9200625111439561
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20711462927954735
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.24561702685766296
# test_score_W': 0.3476824755948417
# neuron unit number: 728
# *******************
#
# Error Data percentage 0.6525096525096525
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22233745991735282
# error_data0_score_W0 0.16874212530088864
# combinedweight shape 0: (1456, 20)
# right_data0_score_W' 0.5262626796575272
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2617831405021455
# error_data1_score_W0 0.11403626366279553
# combinedweight shape1 : (2184, 20)
# right_data1_score_W' 0.5337070973842124
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.33253499902998956
# error_data2_score_W0 0.11229258876332754
# combinedweight shape1 : (2912, 20)
# right_data2_score_W' 0.605785782251046
# Finish one training *********
# 3
# right_data3_score_W0 1.0000000000000002
# error_data3_score_W1 0.41141259777186157
# error_data3_score_W0 0.22437128820485844
# combinedweight shape1 : (3640, 20)
# right_data3_score_W' 0.7044528730788382
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.5130004130984248
# error_data4_score_W0 0.13089168533480786
# combinedweight shape1 : (4368, 20)
# right_data4_score_W' 0.6958659124835341
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.6291560791485906
# error_data5_score_W0 0.17695047162782004
# combinedweight shape1 : (5096, 20)
# right_data5_score_W' 0.7478420724997267
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.636488313385487
# error_data6_score_W0 0.2064230043952187
# combinedweight shape1 : (5824, 20)
# right_data6_score_W' 0.7769340613994581
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.8026461161994636
# error_data7_score_W0 0.1966612759831868
# combinedweight shape1 : (6552, 20)
# right_data7_score_W' 0.8003031166338541
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7918756684685216
# error_data8_score_W0 0.0
# combinedweight shape1 : (7280, 20)
# right_data8_score_W' 0.8631040918837465
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (8008, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.19631732122063827
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.23700606816148678
# test_score_W': 0.35275916399109625
# neuron unit number: 756
# *******************
#
# Error Data percentage 0.6621621621621622
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22686686426227612
# error_data0_score_W0 0.15739557455818787
# combinedweight shape 0: (1512, 20)
# right_data0_score_W' 0.5566290140142129
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.24356731359126146
# error_data1_score_W0 0.12134948740349775
# combinedweight shape1 : (2268, 20)
# right_data1_score_W' 0.5183219249405041
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.339975880693827
# error_data2_score_W0 0.10968632008255057
# combinedweight shape1 : (3024, 20)
# right_data2_score_W' 0.601989086024272
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4181882906748074
# error_data3_score_W0 0.11380501816490406
# combinedweight shape1 : (3780, 20)
# right_data3_score_W' 0.7185147530457652
# Finish one training *********
# 4
# right_data4_score_W0 1.0000000000000002
# error_data4_score_W1 0.3839645211635648
# error_data4_score_W0 0.2202495887282127
# combinedweight shape1 : (4536, 20)
# right_data4_score_W' 0.6981978703133773
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.47798620237188344
# error_data5_score_W0 0.16654517148128675
# combinedweight shape1 : (5292, 20)
# right_data5_score_W' 0.7079513960776961
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6305559458703283
# error_data6_score_W0 0.28114734585886475
# combinedweight shape1 : (6048, 20)
# right_data6_score_W' 0.7202130192349587
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6831980880025522
# error_data7_score_W0 0.3432866562024238
# combinedweight shape1 : (6804, 20)
# right_data7_score_W' 0.8121298818685054
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6624365752025368
# error_data8_score_W0 0.3746773416988541
# combinedweight shape1 : (7560, 20)
# right_data8_score_W' 0.960277088673016
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.7336804366512112
# combinedweight shape1 : (8316, 20)
# right_data9_score_W' 0.6666666666666666
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.18020045668226656
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.22255811541066953
# test_score_W': 0.34830942675001675
# neuron unit number: 784
# *******************
#
# Error Data percentage 0.6563706563706564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20590328974077557
# error_data0_score_W0 0.17074740943189046
# combinedweight shape 0: (1568, 20)
# right_data0_score_W' 0.642652498269407
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2526035415046838
# error_data1_score_W0 0.1421269824969135
# combinedweight shape1 : (2352, 20)
# right_data1_score_W' 0.5236038605992038
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3475459449883051
# error_data2_score_W0 0.10902912914353431
# combinedweight shape1 : (3136, 20)
# right_data2_score_W' 0.5985534925692443
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.37547517609808034
# error_data3_score_W0 0.10784415642980995
# combinedweight shape1 : (3920, 20)
# right_data3_score_W' 0.7441085194765455
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.45360866998147975
# error_data4_score_W0 0.2190069213020371
# combinedweight shape1 : (4704, 20)
# right_data4_score_W' 0.6710484037594634
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5520463532761726
# error_data5_score_W0 0.2840159871135285
# combinedweight shape1 : (5488, 20)
# right_data5_score_W' 0.7077013456009749
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5650965630810137
# error_data6_score_W0 0.4118771925770709
# combinedweight shape1 : (6272, 20)
# right_data6_score_W' 0.756021617463376
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7502974927532079
# error_data7_score_W0 0.5104276739534364
# combinedweight shape1 : (7056, 20)
# right_data7_score_W' 0.8950249354869217
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8722165935233486
# error_data8_score_W0 0.5100038178850457
# combinedweight shape1 : (7840, 20)
# right_data8_score_W' 0.8259531341825135
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (8624, 20)
# right_data9_score_W' 0.9310809437291901
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1956323801393554
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.23856708603735755
# test_score_W': 0.3518076208183476
# neuron unit number: 812
# *******************
#
# Error Data percentage 0.6544401544401545
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24484911495796938
# error_data0_score_W0 0.16303344962299612
# combinedweight shape 0: (1624, 20)
# right_data0_score_W' 0.5503603242001607
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2701052703490789
# error_data1_score_W0 0.12014187071219971
# combinedweight shape1 : (2436, 20)
# right_data1_score_W' 0.6230801290782241
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3574740188407378
# error_data2_score_W0 0.14192341436427441
# combinedweight shape1 : (3248, 20)
# right_data2_score_W' 0.5532799477778573
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.37374734020738914
# error_data3_score_W0 0.17381546488448188
# combinedweight shape1 : (4060, 20)
# right_data3_score_W' 0.6280607661473161
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4988851204496525
# error_data4_score_W0 0.17933839478992683
# combinedweight shape1 : (4872, 20)
# right_data4_score_W' 0.7651258654857493
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5600360813192528
# error_data5_score_W0 0.2050514790791368
# combinedweight shape1 : (5684, 20)
# right_data5_score_W' 0.7344622441552677
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6510242268072044
# error_data6_score_W0 0.24010073373519544
# combinedweight shape1 : (6496, 20)
# right_data6_score_W' 0.8151254345623598
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5663301547291709
# error_data7_score_W0 0.24016454558675787
# combinedweight shape1 : (7308, 20)
# right_data7_score_W' 0.8357157544811789
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.38033214891787165
# combinedweight shape1 : (8120, 20)
# right_data8_score_W' 0.7595437291421123
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1936941539503382
# all_train_score_W': 0.9722034397499966
# test_score_W0 : 0.21833548928456728
# test_score_W': 0.3476824755948417
# neuron unit number: 840
# *******************
#
# Error Data percentage 0.6486486486486487
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21244179821062004
# error_data0_score_W0 0.17663541530678983
# combinedweight shape 0: (1680, 20)
# right_data0_score_W' 0.6007996467883735
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26422174883193594
# error_data1_score_W0 0.09198472846787575
# combinedweight shape1 : (2520, 20)
# right_data1_score_W' 0.5237680481062849
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3320851911810641
# error_data2_score_W0 0.11787054126427159
# combinedweight shape1 : (3360, 20)
# right_data2_score_W' 0.678126807330686
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.39799891170273277
# error_data3_score_W0 0.05957990328159777
# combinedweight shape1 : (4200, 20)
# right_data3_score_W' 0.6883000497355993
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.42575002118785904
# error_data4_score_W0 0.10481445764567884
# combinedweight shape1 : (5040, 20)
# right_data4_score_W' 0.7378020906061014
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5408461792274893
# error_data5_score_W0 0.18573140334959592
# combinedweight shape1 : (5880, 20)
# right_data5_score_W' 0.6626913022691931
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6125607847379009
# error_data6_score_W0 0.17325779368024535
# combinedweight shape1 : (6720, 20)
# right_data6_score_W' 0.8217830213593683
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5625489183416778
# error_data7_score_W0 0.32722822194327633
# combinedweight shape1 : (7560, 20)
# right_data7_score_W' 0.8273798071496014
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5858779295433236
# error_data8_score_W0 0.5858779295433235
# combinedweight shape1 : (8400, 20)
# right_data8_score_W' 0.7427338007991635
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (9240, 20)
# right_data9_score_W' 1.0
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.20398450733302786
# all_train_score_W': 0.973175756096313
# test_score_W0 : 0.23484098410936913
# test_score_W': 0.3508231242944346
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.208411  0.032273  0.005892   0.196361  0.220462
# 1  test_score_W'  30.0  0.348343  0.001854  0.000338   0.347651  0.349035
# 2       combined  60.0  0.278377  0.074107  0.009567   0.259233  0.297521
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1399
# 1                          Degrees of freedom =   58.0000
# 2                                           t =  -23.7096
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -6.1218
# 7                                   Hedge's g =   -6.0423
# 8                               Glass's delta =   -4.3359
# 9                                 Pearson's r =    0.9521
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-23.709637127891067, pvalue=7.851851136812843e-32)

# %%
scoretype = 0
scope_num = 120
class_num = 28
dim_num = 20
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:       
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.7239382239382239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.25333333333333335
# error_data0_score_W0 0.19466666666666665
# combinedweight shape 0: (56, 20)
# right_data0_score_W' 0.6293706293706294
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.22142857142857142
# error_data1_score_W0 0.14642857142857144
# combinedweight shape1 : (84, 20)
# right_data1_score_W' 0.5473684210526316
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.22018348623853212
# error_data2_score_W0 0.16055045871559634
# combinedweight shape1 : (112, 20)
# right_data2_score_W' 0.5645161290322581
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.24705882352941178
# error_data3_score_W0 0.15294117647058825
# combinedweight shape1 : (140, 20)
# right_data3_score_W' 0.6458333333333334
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.265625
# error_data4_score_W0 0.15625
# combinedweight shape1 : (168, 20)
# right_data4_score_W' 0.6428571428571429
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2978723404255319
# error_data5_score_W0 0.20212765957446807
# combinedweight shape1 : (196, 20)
# right_data5_score_W' 0.5588235294117647
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3181818181818182
# error_data6_score_W0 0.19696969696969696
# combinedweight shape1 : (224, 20)
# right_data6_score_W' 0.75
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.3333333333333333
# error_data7_score_W0 0.2222222222222222
# combinedweight shape1 : (252, 20)
# right_data7_score_W' 0.6190476190476191
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.4666666666666667
# error_data8_score_W0 0.3
# combinedweight shape1 : (280, 20)
# right_data8_score_W' 0.8666666666666667
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.5625
# error_data9_score_W0 0.3125
# combinedweight shape1 : (308, 20)
# right_data9_score_W' 0.7857142857142857
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.7142857142857143
# error_data10_score_W0 0.2857142857142857
# combinedweight shape1 : (336, 20)
# right_data10_score_W' 0.7777777777777778
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (364, 20)
# right_data11_score_W' 0.8
# Finish one splitting *********
# 12
#  NO Error Data, Finish Training!
# split_num 12
# all_train_score_W0: 0.27606177606177607
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.24774774774774774
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)364
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.7277992277992278
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2572944297082228
# error_data0_score_W0 0.1909814323607427
# combinedweight shape 0: (112, 20)
# right_data0_score_W' 0.7163120567375887
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.24285714285714285
# error_data1_score_W0 0.1357142857142857
# combinedweight shape1 : (168, 20)
# right_data1_score_W' 0.4845360824742268
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.24056603773584906
# error_data2_score_W0 0.13679245283018868
# combinedweight shape1 : (224, 20)
# right_data2_score_W' 0.6176470588235294
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.21739130434782608
# error_data3_score_W0 0.14285714285714285
# combinedweight shape1 : (280, 20)
# right_data3_score_W' 0.6470588235294118
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.2698412698412698
# error_data4_score_W0 0.15079365079365079
# combinedweight shape1 : (336, 20)
# right_data4_score_W' 0.6857142857142857
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2826086956521739
# error_data5_score_W0 0.18478260869565216
# combinedweight shape1 : (392, 20)
# right_data5_score_W' 0.7352941176470589
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3333333333333333
# error_data6_score_W0 0.22727272727272727
# combinedweight shape1 : (448, 20)
# right_data6_score_W' 0.7307692307692307
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.3409090909090909
# error_data7_score_W0 0.25
# combinedweight shape1 : (504, 20)
# right_data7_score_W' 0.5909090909090909
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.41379310344827586
# error_data8_score_W0 0.20689655172413793
# combinedweight shape1 : (560, 20)
# right_data8_score_W' 0.5333333333333333
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.5882352941176471
# error_data9_score_W0 0.23529411764705882
# combinedweight shape1 : (616, 20)
# right_data9_score_W' 0.8333333333333334
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.7142857142857143
# error_data10_score_W0 0.42857142857142855
# combinedweight shape1 : (672, 20)
# right_data10_score_W' 0.9
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (728, 20)
# right_data11_score_W' 0.8
# Finish one splitting *********
# 12
#  NO Error Data, Finish Training!
# split_num 12
# all_train_score_W0: 0.2722007722007722
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.24774774774774774
# test_score_W': 0.4144144144144144
# class_num*x*(optimize_W.split_num +1)728
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.7007722007722008
# right_data0_score_W0 1.0
# error_data0_score_W1 0.25895316804407714
# error_data0_score_W0 0.19834710743801653
# combinedweight shape 0: (168, 20)
# right_data0_score_W' 0.7677419354838709
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.24535315985130113
# error_data1_score_W0 0.1524163568773234
# combinedweight shape1 : (252, 20)
# right_data1_score_W' 0.6808510638297872
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2660098522167488
# error_data2_score_W0 0.13793103448275862
# combinedweight shape1 : (336, 20)
# right_data2_score_W' 0.5606060606060606
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.26174496644295303
# error_data3_score_W0 0.11409395973154363
# combinedweight shape1 : (420, 20)
# right_data3_score_W' 0.5925925925925926
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.2818181818181818
# error_data4_score_W0 0.12727272727272726
# combinedweight shape1 : (504, 20)
# right_data4_score_W' 0.6153846153846154
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3291139240506329
# error_data5_score_W0 0.17721518987341772
# combinedweight shape1 : (588, 20)
# right_data5_score_W' 0.7419354838709677
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.41509433962264153
# error_data6_score_W0 0.18867924528301888
# combinedweight shape1 : (672, 20)
# right_data6_score_W' 0.7692307692307693
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4838709677419355
# error_data7_score_W0 0.22580645161290322
# combinedweight shape1 : (756, 20)
# right_data7_score_W' 0.7727272727272727
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5625
# error_data8_score_W0 0.3125
# combinedweight shape1 : (840, 20)
# right_data8_score_W' 0.6
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.5714285714285714
# error_data9_score_W0 0.42857142857142855
# combinedweight shape1 : (924, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.6666666666666666
# error_data10_score_W0 0.6666666666666666
# combinedweight shape1 : (1008, 20)
# right_data10_score_W' 1.0
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (1092, 20)
# right_data11_score_W' 1.0
# Finish one splitting *********
# 12
#  NO Error Data, Finish Training!
# split_num 12
# all_train_score_W0: 0.29922779922779924
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2882882882882883
# test_score_W': 0.4144144144144144
# class_num*x*(optimize_W.split_num +1)1092
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.6833976833976834
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2598870056497175
# error_data0_score_W0 0.20056497175141244
# combinedweight shape 0: (224, 20)
# right_data0_score_W' 0.6463414634146342
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23282442748091603
# error_data1_score_W0 0.14122137404580154
# combinedweight shape1 : (336, 20)
# right_data1_score_W' 0.4673913043478261
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2736318407960199
# error_data2_score_W0 0.13930348258706468
# combinedweight shape1 : (448, 20)
# right_data2_score_W' 0.5737704918032787
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2671232876712329
# error_data3_score_W0 0.136986301369863
# combinedweight shape1 : (560, 20)
# right_data3_score_W' 0.5818181818181818
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.29906542056074764
# error_data4_score_W0 0.14018691588785046
# combinedweight shape1 : (672, 20)
# right_data4_score_W' 0.5384615384615384
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.32
# error_data5_score_W0 0.14666666666666667
# combinedweight shape1 : (784, 20)
# right_data5_score_W' 0.625
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3137254901960784
# error_data6_score_W0 0.17647058823529413
# combinedweight shape1 : (896, 20)
# right_data6_score_W' 0.75
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.42857142857142855
# error_data7_score_W0 0.2
# combinedweight shape1 : (1008, 20)
# right_data7_score_W' 0.6875
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6
# error_data8_score_W0 0.3
# combinedweight shape1 : (1120, 20)
# right_data8_score_W' 0.8666666666666667
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.75
# error_data9_score_W0 0.375
# combinedweight shape1 : (1232, 20)
# right_data9_score_W' 0.8333333333333334
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (1344, 20)
# right_data10_score_W' 1.0
# Finish one splitting *********
# 11
#  NO Error Data, Finish Training!
# split_num 11
# all_train_score_W0: 0.3166023166023166
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.32882882882882886
# test_score_W': 0.4144144144144144
# class_num*x*(optimize_W.split_num +1)1344
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2636103151862464
# error_data0_score_W0 0.2034383954154728
# combinedweight shape 0: (280, 20)
# right_data0_score_W' 0.7041420118343196
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2607003891050584
# error_data1_score_W0 0.1517509727626459
# combinedweight shape1 : (420, 20)
# right_data1_score_W' 0.532608695652174
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29473684210526313
# error_data2_score_W0 0.13157894736842105
# combinedweight shape1 : (560, 20)
# right_data2_score_W' 0.5522388059701493
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2835820895522388
# error_data3_score_W0 0.12686567164179105
# combinedweight shape1 : (700, 20)
# right_data3_score_W' 0.625
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.2916666666666667
# error_data4_score_W0 0.16666666666666666
# combinedweight shape1 : (840, 20)
# right_data4_score_W' 0.5263157894736842
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3382352941176471
# error_data5_score_W0 0.20588235294117646
# combinedweight shape1 : (980, 20)
# right_data5_score_W' 0.75
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.4888888888888889
# error_data6_score_W0 0.2222222222222222
# combinedweight shape1 : (1120, 20)
# right_data6_score_W' 0.7391304347826086
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5652173913043478
# error_data7_score_W0 0.30434782608695654
# combinedweight shape1 : (1260, 20)
# right_data7_score_W' 0.8181818181818182
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8
# error_data8_score_W0 0.4
# combinedweight shape1 : (1400, 20)
# right_data8_score_W' 0.9230769230769231
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (1540, 20)
# right_data9_score_W' 0.875
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.32625482625482627
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.3063063063063063
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)1540
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.6718146718146718
# right_data0_score_W0 1.0
# error_data0_score_W1 0.27586206896551724
# error_data0_score_W0 0.20402298850574713
# combinedweight shape 0: (336, 20)
# right_data0_score_W' 0.7941176470588235
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2777777777777778
# error_data1_score_W0 0.15079365079365079
# combinedweight shape1 : (504, 20)
# right_data1_score_W' 0.5208333333333334
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2802197802197802
# error_data2_score_W0 0.14285714285714285
# combinedweight shape1 : (672, 20)
# right_data2_score_W' 0.7142857142857143
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.26717557251908397
# error_data3_score_W0 0.16030534351145037
# combinedweight shape1 : (840, 20)
# right_data3_score_W' 0.5294117647058824
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3541666666666667
# error_data4_score_W0 0.17708333333333334
# combinedweight shape1 : (1008, 20)
# right_data4_score_W' 0.5714285714285714
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3548387096774194
# error_data5_score_W0 0.1774193548387097
# combinedweight shape1 : (1176, 20)
# right_data5_score_W' 0.5882352941176471
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.425
# error_data6_score_W0 0.225
# combinedweight shape1 : (1344, 20)
# right_data6_score_W' 0.8181818181818182
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5217391304347826
# error_data7_score_W0 0.30434782608695654
# combinedweight shape1 : (1512, 20)
# right_data7_score_W' 0.7058823529411765
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5454545454545454
# error_data8_score_W0 0.2727272727272727
# combinedweight shape1 : (1680, 20)
# right_data8_score_W' 0.8333333333333334
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8
# error_data9_score_W0 0.4
# combinedweight shape1 : (1848, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (2016, 20)
# right_data10_score_W' 1.0
# Finish one splitting *********
# 11
#  NO Error Data, Finish Training!
# split_num 11
# all_train_score_W0: 0.3281853281853282
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2882882882882883
# test_score_W': 0.4144144144144144
# class_num*x*(optimize_W.split_num +1)2016
# neuron unit number: 196
# *******************
#
# Error Data percentage 0.6756756756756757
# right_data0_score_W0 1.0
# error_data0_score_W1 0.26571428571428574
# error_data0_score_W0 0.20285714285714285
# combinedweight shape 0: (392, 20)
# right_data0_score_W' 0.7083333333333334
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.25680933852140075
# error_data1_score_W0 0.17509727626459143
# combinedweight shape1 : (588, 20)
# right_data1_score_W' 0.5806451612903226
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2513089005235602
# error_data2_score_W0 0.13089005235602094
# combinedweight shape1 : (784, 20)
# right_data2_score_W' 0.7121212121212122
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2727272727272727
# error_data3_score_W0 0.16783216783216784
# combinedweight shape1 : (980, 20)
# right_data3_score_W' 0.7291666666666666
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.33653846153846156
# error_data4_score_W0 0.22115384615384615
# combinedweight shape1 : (1176, 20)
# right_data4_score_W' 0.6410256410256411
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3333333333333333
# error_data5_score_W0 0.21739130434782608
# combinedweight shape1 : (1372, 20)
# right_data5_score_W' 0.6
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.32608695652173914
# error_data6_score_W0 0.1956521739130435
# combinedweight shape1 : (1568, 20)
# right_data6_score_W' 0.6956521739130435
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5161290322580645
# error_data7_score_W0 0.25806451612903225
# combinedweight shape1 : (1764, 20)
# right_data7_score_W' 0.6666666666666666
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6
# error_data8_score_W0 0.4666666666666667
# combinedweight shape1 : (1960, 20)
# right_data8_score_W' 0.625
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8333333333333334
# error_data9_score_W0 0.5
# combinedweight shape1 : (2156, 20)
# right_data9_score_W' 0.6666666666666666
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (2352, 20)
# right_data10_score_W' 1.0
# Finish one splitting *********
# 11
#  NO Error Data, Finish Training!
# split_num 11
# all_train_score_W0: 0.32432432432432434
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2702702702702703
# test_score_W': 0.4189189189189189
# class_num*x*(optimize_W.split_num +1)2352
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.7027027027027027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.29120879120879123
# error_data0_score_W0 0.2087912087912088
# combinedweight shape 0: (448, 20)
# right_data0_score_W' 0.6038961038961039
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2558139534883721
# error_data1_score_W0 0.13565891472868216
# combinedweight shape1 : (672, 20)
# right_data1_score_W' 0.6320754716981132
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2916666666666667
# error_data2_score_W0 0.15104166666666666
# combinedweight shape1 : (896, 20)
# right_data2_score_W' 0.48484848484848486
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2867647058823529
# error_data3_score_W0 0.13970588235294118
# combinedweight shape1 : (1120, 20)
# right_data3_score_W' 0.5892857142857143
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.36082474226804123
# error_data4_score_W0 0.13402061855670103
# combinedweight shape1 : (1344, 20)
# right_data4_score_W' 0.5641025641025641
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.41935483870967744
# error_data5_score_W0 0.14516129032258066
# combinedweight shape1 : (1568, 20)
# right_data5_score_W' 0.6857142857142857
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5277777777777778
# error_data6_score_W0 0.2222222222222222
# combinedweight shape1 : (1792, 20)
# right_data6_score_W' 0.6538461538461539
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5882352941176471
# error_data7_score_W0 0.29411764705882354
# combinedweight shape1 : (2016, 20)
# right_data7_score_W' 0.7368421052631579
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8571428571428571
# error_data8_score_W0 0.2857142857142857
# combinedweight shape1 : (2240, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (2464, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.2972972972972973
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2972972972972973
# test_score_W': 0.4144144144144144
# class_num*x*(optimize_W.split_num +1)2464
# neuron unit number: 252
# *******************
#
# Error Data percentage 0.6776061776061776
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2849002849002849
# error_data0_score_W0 0.2022792022792023
# combinedweight shape 0: (504, 20)
# right_data0_score_W' 0.718562874251497
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2788844621513944
# error_data1_score_W0 0.15139442231075698
# combinedweight shape1 : (756, 20)
# right_data1_score_W' 0.55
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.281767955801105
# error_data2_score_W0 0.1270718232044199
# combinedweight shape1 : (1008, 20)
# right_data2_score_W' 0.5857142857142857
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3
# error_data3_score_W0 0.14615384615384616
# combinedweight shape1 : (1260, 20)
# right_data3_score_W' 0.5490196078431373
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3626373626373626
# error_data4_score_W0 0.17582417582417584
# combinedweight shape1 : (1512, 20)
# right_data4_score_W' 0.5384615384615384
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.41379310344827586
# error_data5_score_W0 0.1896551724137931
# combinedweight shape1 : (1764, 20)
# right_data5_score_W' 0.696969696969697
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5294117647058824
# error_data6_score_W0 0.23529411764705882
# combinedweight shape1 : (2016, 20)
# right_data6_score_W' 0.7916666666666666
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4375
# error_data7_score_W0 0.3125
# combinedweight shape1 : (2268, 20)
# right_data7_score_W' 0.7222222222222222
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.5555555555555556
# combinedweight shape1 : (2520, 20)
# right_data8_score_W' 0.8571428571428571
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6666666666666666
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (2772, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (3024, 20)
# right_data10_score_W' 1.0
# Finish one splitting *********
# 11
#  NO Error Data, Finish Training!
# split_num 11
# all_train_score_W0: 0.3223938223938224
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2747747747747748
# test_score_W': 0.40540540540540543
# class_num*x*(optimize_W.split_num +1)3024
# neuron unit number: 280
# *******************
#
# Error Data percentage 0.6853281853281853
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2647887323943662
# error_data0_score_W0 0.19718309859154928
# combinedweight shape 0: (560, 20)
# right_data0_score_W' 0.7116564417177914
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2796934865900383
# error_data1_score_W0 0.1417624521072797
# combinedweight shape1 : (840, 20)
# right_data1_score_W' 0.5425531914893617
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.30319148936170215
# error_data2_score_W0 0.1276595744680851
# combinedweight shape1 : (1120, 20)
# right_data2_score_W' 0.4383561643835616
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.29770992366412213
# error_data3_score_W0 0.1297709923664122
# combinedweight shape1 : (1400, 20)
# right_data3_score_W' 0.543859649122807
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.34782608695652173
# error_data4_score_W0 0.18478260869565216
# combinedweight shape1 : (1680, 20)
# right_data4_score_W' 0.6153846153846154
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.38333333333333336
# error_data5_score_W0 0.16666666666666666
# combinedweight shape1 : (1960, 20)
# right_data5_score_W' 0.59375
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5135135135135135
# error_data6_score_W0 0.1891891891891892
# combinedweight shape1 : (2240, 20)
# right_data6_score_W' 0.6956521739130435
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5555555555555556
# error_data7_score_W0 0.2222222222222222
# combinedweight shape1 : (2520, 20)
# right_data7_score_W' 0.7894736842105263
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.75
# error_data8_score_W0 0.375
# combinedweight shape1 : (2800, 20)
# right_data8_score_W' 0.9
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (3080, 20)
# right_data9_score_W' 0.8333333333333334
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.31467181467181465
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2702702702702703
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)3080
# neuron unit number: 308
# *******************
#
# Error Data percentage 0.696911196911197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.26869806094182824
# error_data0_score_W0 0.2077562326869806
# combinedweight shape 0: (616, 20)
# right_data0_score_W' 0.7006369426751592
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2727272727272727
# error_data1_score_W0 0.16287878787878787
# combinedweight shape1 : (924, 20)
# right_data1_score_W' 0.5876288659793815
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.265625
# error_data2_score_W0 0.140625
# combinedweight shape1 : (1232, 20)
# right_data2_score_W' 0.5416666666666666
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2695035460992908
# error_data3_score_W0 0.1347517730496454
# combinedweight shape1 : (1540, 20)
# right_data3_score_W' 0.6078431372549019
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.34951456310679613
# error_data4_score_W0 0.1650485436893204
# combinedweight shape1 : (1848, 20)
# right_data4_score_W' 0.631578947368421
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.40298507462686567
# error_data5_score_W0 0.208955223880597
# combinedweight shape1 : (2156, 20)
# right_data5_score_W' 0.5277777777777778
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.475
# error_data6_score_W0 0.225
# combinedweight shape1 : (2464, 20)
# right_data6_score_W' 0.6296296296296297
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.47619047619047616
# error_data7_score_W0 0.3333333333333333
# combinedweight shape1 : (2772, 20)
# right_data7_score_W' 0.7894736842105263
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6363636363636364
# error_data8_score_W0 0.5454545454545454
# combinedweight shape1 : (3080, 20)
# right_data8_score_W' 0.9
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.75
# combinedweight shape1 : (3388, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3030888030888031
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2702702702702703
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)3388
# neuron unit number: 336
# *******************
#
# Error Data percentage 0.6891891891891891
# right_data0_score_W0 1.0
# error_data0_score_W1 0.26330532212885155
# error_data0_score_W0 0.20448179271708683
# combinedweight shape 0: (672, 20)
# right_data0_score_W' 0.7018633540372671
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.25475285171102663
# error_data1_score_W0 0.1520912547528517
# combinedweight shape1 : (1008, 20)
# right_data1_score_W' 0.723404255319149
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29081632653061223
# error_data2_score_W0 0.14795918367346939
# combinedweight shape1 : (1344, 20)
# right_data2_score_W' 0.5074626865671642
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2805755395683453
# error_data3_score_W0 0.1366906474820144
# combinedweight shape1 : (1680, 20)
# right_data3_score_W' 0.6491228070175439
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3
# error_data4_score_W0 0.17
# combinedweight shape1 : (2016, 20)
# right_data4_score_W' 0.6410256410256411
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.37142857142857144
# error_data5_score_W0 0.18571428571428572
# combinedweight shape1 : (2352, 20)
# right_data5_score_W' 0.6333333333333333
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.36363636363636365
# error_data6_score_W0 0.22727272727272727
# combinedweight shape1 : (2688, 20)
# right_data6_score_W' 0.6538461538461539
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4642857142857143
# error_data7_score_W0 0.2857142857142857
# combinedweight shape1 : (3024, 20)
# right_data7_score_W' 0.6875
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.26666666666666666
# combinedweight shape1 : (3360, 20)
# right_data8_score_W' 0.8461538461538461
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.8
# combinedweight shape1 : (3696, 20)
# right_data9_score_W' 0.9
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3108108108108108
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2747747747747748
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)3696
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.667953667953668
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2630057803468208
# error_data0_score_W0 0.1936416184971098
# combinedweight shape 0: (728, 20)
# right_data0_score_W' 0.7383720930232558
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2901960784313726
# error_data1_score_W0 0.12549019607843137
# combinedweight shape1 : (1092, 20)
# right_data1_score_W' 0.6043956043956044
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.30386740331491713
# error_data2_score_W0 0.16574585635359115
# combinedweight shape1 : (1456, 20)
# right_data2_score_W' 0.6351351351351351
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.30952380952380953
# error_data3_score_W0 0.12698412698412698
# combinedweight shape1 : (1820, 20)
# right_data3_score_W' 0.6
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3563218390804598
# error_data4_score_W0 0.1839080459770115
# combinedweight shape1 : (2184, 20)
# right_data4_score_W' 0.6666666666666666
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.44642857142857145
# error_data5_score_W0 0.19642857142857142
# combinedweight shape1 : (2548, 20)
# right_data5_score_W' 0.6129032258064516
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5483870967741935
# error_data6_score_W0 0.25806451612903225
# combinedweight shape1 : (2912, 20)
# right_data6_score_W' 0.64
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6428571428571429
# error_data7_score_W0 0.35714285714285715
# combinedweight shape1 : (3276, 20)
# right_data7_score_W' 0.5882352941176471
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8
# error_data8_score_W0 0.6
# combinedweight shape1 : (3640, 20)
# right_data8_score_W' 0.8888888888888888
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (4004, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.33204633204633205
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.30180180180180183
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)4004
# neuron unit number: 392
# *******************
#
# Error Data percentage 0.6853281853281853
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2619718309859155
# error_data0_score_W0 0.2056338028169014
# combinedweight shape 0: (784, 20)
# right_data0_score_W' 0.7300613496932515
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2786259541984733
# error_data1_score_W0 0.16793893129770993
# combinedweight shape1 : (1176, 20)
# right_data1_score_W' 0.46236559139784944
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.26455026455026454
# error_data2_score_W0 0.1693121693121693
# combinedweight shape1 : (1568, 20)
# right_data2_score_W' 0.5068493150684932
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.26618705035971224
# error_data3_score_W0 0.14388489208633093
# combinedweight shape1 : (1960, 20)
# right_data3_score_W' 0.52
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3431372549019608
# error_data4_score_W0 0.19607843137254902
# combinedweight shape1 : (2352, 20)
# right_data4_score_W' 0.5135135135135135
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.373134328358209
# error_data5_score_W0 0.1791044776119403
# combinedweight shape1 : (2744, 20)
# right_data5_score_W' 0.4857142857142857
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.42857142857142855
# error_data6_score_W0 0.16666666666666666
# combinedweight shape1 : (3136, 20)
# right_data6_score_W' 0.64
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.625
# error_data7_score_W0 0.25
# combinedweight shape1 : (3528, 20)
# right_data7_score_W' 0.7222222222222222
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.3333333333333333
# combinedweight shape1 : (3920, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (4312, 20)
# right_data9_score_W' 0.8333333333333334
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.31467181467181465
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.28378378378378377
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)4312
# neuron unit number: 420
# *******************
#
# Error Data percentage 0.6795366795366795
# right_data0_score_W0 1.0
# error_data0_score_W1 0.26704545454545453
# error_data0_score_W0 0.20170454545454544
# combinedweight shape 0: (840, 20)
# right_data0_score_W' 0.6204819277108434
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2713178294573643
# error_data1_score_W0 0.12403100775193798
# combinedweight shape1 : (1260, 20)
# right_data1_score_W' 0.5212765957446809
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28191489361702127
# error_data2_score_W0 0.13297872340425532
# combinedweight shape1 : (1680, 20)
# right_data2_score_W' 0.5428571428571428
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.28888888888888886
# error_data3_score_W0 0.1259259259259259
# combinedweight shape1 : (2100, 20)
# right_data3_score_W' 0.6037735849056604
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3541666666666667
# error_data4_score_W0 0.14583333333333334
# combinedweight shape1 : (2520, 20)
# right_data4_score_W' 0.5897435897435898
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3870967741935484
# error_data5_score_W0 0.1935483870967742
# combinedweight shape1 : (2940, 20)
# right_data5_score_W' 0.5588235294117647
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.4473684210526316
# error_data6_score_W0 0.21052631578947367
# combinedweight shape1 : (3360, 20)
# right_data6_score_W' 0.5
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5238095238095238
# error_data7_score_W0 0.2857142857142857
# combinedweight shape1 : (3780, 20)
# right_data7_score_W' 0.7647058823529411
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6
# error_data8_score_W0 0.5
# combinedweight shape1 : (4200, 20)
# right_data8_score_W' 0.7272727272727273
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.75
# error_data9_score_W0 0.75
# combinedweight shape1 : (4620, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (5040, 20)
# right_data10_score_W' 1.0
# Finish one splitting *********
# 11
#  NO Error Data, Finish Training!
# split_num 11
# all_train_score_W0: 0.3204633204633205
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.28378378378378377
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)5040
# neuron unit number: 448
# *******************
#
# Error Data percentage 0.694980694980695
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2916666666666667
# error_data0_score_W0 0.21666666666666667
# combinedweight shape 0: (896, 20)
# right_data0_score_W' 0.7341772151898734
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2980392156862745
# error_data1_score_W0 0.12549019607843137
# combinedweight shape1 : (1344, 20)
# right_data1_score_W' 0.5904761904761905
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3128491620111732
# error_data2_score_W0 0.12290502793296089
# combinedweight shape1 : (1792, 20)
# right_data2_score_W' 0.5921052631578947
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3170731707317073
# error_data3_score_W0 0.12195121951219512
# combinedweight shape1 : (2240, 20)
# right_data3_score_W' 0.5714285714285714
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38095238095238093
# error_data4_score_W0 0.16666666666666666
# combinedweight shape1 : (2688, 20)
# right_data4_score_W' 0.6153846153846154
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4230769230769231
# error_data5_score_W0 0.23076923076923078
# combinedweight shape1 : (3136, 20)
# right_data5_score_W' 0.71875
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5333333333333333
# error_data6_score_W0 0.26666666666666666
# combinedweight shape1 : (3584, 20)
# right_data6_score_W' 0.6818181818181818
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5714285714285714
# error_data7_score_W0 0.42857142857142855
# combinedweight shape1 : (4032, 20)
# right_data7_score_W' 0.875
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.5
# combinedweight shape1 : (4480, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (4928, 20)
# right_data9_score_W' 0.75
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.305019305019305
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2747747747747748
# test_score_W': 0.40540540540540543
# class_num*x*(optimize_W.split_num +1)4928
# neuron unit number: 476
# *******************
#
# Error Data percentage 0.666023166023166
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2782608695652174
# error_data0_score_W0 0.2028985507246377
# combinedweight shape 0: (952, 20)
# right_data0_score_W' 0.7687861271676301
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26907630522088355
# error_data1_score_W0 0.13253012048192772
# combinedweight shape1 : (1428, 20)
# right_data1_score_W' 0.5520833333333334
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31868131868131866
# error_data2_score_W0 0.13186813186813187
# combinedweight shape1 : (1904, 20)
# right_data2_score_W' 0.6268656716417911
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3225806451612903
# error_data3_score_W0 0.12903225806451613
# combinedweight shape1 : (2380, 20)
# right_data3_score_W' 0.603448275862069
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.39285714285714285
# error_data4_score_W0 0.19047619047619047
# combinedweight shape1 : (2856, 20)
# right_data4_score_W' 0.575
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.47058823529411764
# error_data5_score_W0 0.17647058823529413
# combinedweight shape1 : (3332, 20)
# right_data5_score_W' 0.5151515151515151
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5555555555555556
# error_data6_score_W0 0.2962962962962963
# combinedweight shape1 : (3808, 20)
# right_data6_score_W' 0.6666666666666666
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5833333333333334
# error_data7_score_W0 0.3333333333333333
# combinedweight shape1 : (4284, 20)
# right_data7_score_W' 0.7333333333333333
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6
# error_data8_score_W0 0.4
# combinedweight shape1 : (4760, 20)
# right_data8_score_W' 0.8571428571428571
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.5
# combinedweight shape1 : (5236, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.333976833976834
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2882882882882883
# test_score_W': 0.40540540540540543
# class_num*x*(optimize_W.split_num +1)5236
# neuron unit number: 504
# *******************
#
# Error Data percentage 0.6833976833976834
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2740112994350282
# error_data0_score_W0 0.1977401129943503
# combinedweight shape 0: (1008, 20)
# right_data0_score_W' 0.7439024390243902
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26459143968871596
# error_data1_score_W0 0.14396887159533073
# combinedweight shape1 : (1512, 20)
# right_data1_score_W' 0.5979381443298969
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2751322751322751
# error_data2_score_W0 0.164021164021164
# combinedweight shape1 : (2016, 20)
# right_data2_score_W' 0.5588235294117647
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2846715328467153
# error_data3_score_W0 0.1386861313868613
# combinedweight shape1 : (2520, 20)
# right_data3_score_W' 0.5576923076923077
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.32653061224489793
# error_data4_score_W0 0.19387755102040816
# combinedweight shape1 : (3024, 20)
# right_data4_score_W' 0.5897435897435898
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4090909090909091
# error_data5_score_W0 0.18181818181818182
# combinedweight shape1 : (3528, 20)
# right_data5_score_W' 0.75
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5384615384615384
# error_data6_score_W0 0.20512820512820512
# combinedweight shape1 : (4032, 20)
# right_data6_score_W' 0.6666666666666666
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5
# error_data7_score_W0 0.16666666666666666
# combinedweight shape1 : (4536, 20)
# right_data7_score_W' 0.7142857142857143
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6666666666666666
# error_data8_score_W0 0.2222222222222222
# combinedweight shape1 : (5040, 20)
# right_data8_score_W' 0.8888888888888888
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (5544, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3166023166023166
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.3063063063063063
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)5544
# neuron unit number: 532
# *******************
#
# Error Data percentage 0.6698841698841699
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2564841498559078
# error_data0_score_W0 0.2017291066282421
# combinedweight shape 0: (1064, 20)
# right_data0_score_W' 0.8128654970760234
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.28294573643410853
# error_data1_score_W0 0.11627906976744186
# combinedweight shape1 : (1596, 20)
# right_data1_score_W' 0.5280898876404494
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2972972972972973
# error_data2_score_W0 0.15675675675675677
# combinedweight shape1 : (2128, 20)
# right_data2_score_W' 0.4931506849315068
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3
# error_data3_score_W0 0.13846153846153847
# combinedweight shape1 : (2660, 20)
# right_data3_score_W' 0.6545454545454545
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3956043956043956
# error_data4_score_W0 0.14285714285714285
# combinedweight shape1 : (3192, 20)
# right_data4_score_W' 0.5897435897435898
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.43636363636363634
# error_data5_score_W0 0.14545454545454545
# combinedweight shape1 : (3724, 20)
# right_data5_score_W' 0.5555555555555556
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5161290322580645
# error_data6_score_W0 0.22580645161290322
# combinedweight shape1 : (4256, 20)
# right_data6_score_W' 0.625
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4666666666666667
# error_data7_score_W0 0.26666666666666666
# combinedweight shape1 : (4788, 20)
# right_data7_score_W' 0.8125
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.625
# error_data8_score_W0 0.375
# combinedweight shape1 : (5320, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (5852, 20)
# right_data9_score_W' 1.0
# ...
# error_data0_score_W1 0.25360230547550433
# error_data0_score_W0 0.207492795389049
# combinedweight shape 0: (6440, 20)
# right_data0_score_W' 0.6900584795321637
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2857142857142857
# error_data1_score_W0 0.16216216216216217
# combinedweight shape1 : (9660, 20)
# right_data1_score_W' 0.5795454545454546
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2972972972972973
# error_data2_score_W0 0.14054054054054055
# combinedweight shape1 : (12880, 20)
# right_data2_score_W' 0.527027027027027
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2923076923076923
# error_data3_score_W0 0.13846153846153847
# combinedweight shape1 : (16100, 20)
# right_data3_score_W' 0.6181818181818182
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3695652173913043
# error_data4_score_W0 0.20652173913043478
# combinedweight shape1 : (19320, 20)
# right_data4_score_W' 0.5263157894736842
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.39655172413793105
# error_data5_score_W0 0.22413793103448276
# combinedweight shape1 : (22540, 20)
# right_data5_score_W' 0.5294117647058824
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.4857142857142857
# error_data6_score_W0 0.2857142857142857
# combinedweight shape1 : (25760, 20)
# right_data6_score_W' 0.8260869565217391
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6111111111111112
# error_data7_score_W0 0.3333333333333333
# combinedweight shape1 : (28980, 20)
# right_data7_score_W' 0.8823529411764706
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7142857142857143
# error_data8_score_W0 0.2857142857142857
# combinedweight shape1 : (32200, 20)
# right_data8_score_W' 0.8181818181818182
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (35420, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3301158301158301
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2882882882882883
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)35420
# neuron unit number: 3248
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2722063037249284
# error_data0_score_W0 0.20057306590257878
# combinedweight shape 0: (6496, 20)
# right_data0_score_W' 0.6568047337278107
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2637795275590551
# error_data1_score_W0 0.12598425196850394
# combinedweight shape1 : (9744, 20)
# right_data1_score_W' 0.6105263157894737
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.27807486631016043
# error_data2_score_W0 0.13903743315508021
# combinedweight shape1 : (12992, 20)
# right_data2_score_W' 0.47761194029850745
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.32592592592592595
# error_data3_score_W0 0.13333333333333333
# combinedweight shape1 : (16240, 20)
# right_data3_score_W' 0.5384615384615384
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38461538461538464
# error_data4_score_W0 0.16483516483516483
# combinedweight shape1 : (19488, 20)
# right_data4_score_W' 0.5909090909090909
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4107142857142857
# error_data5_score_W0 0.19642857142857142
# combinedweight shape1 : (22736, 20)
# right_data5_score_W' 0.7142857142857143
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.48484848484848486
# error_data6_score_W0 0.21212121212121213
# combinedweight shape1 : (25984, 20)
# right_data6_score_W' 0.6521739130434783
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5294117647058824
# error_data7_score_W0 0.23529411764705882
# combinedweight shape1 : (29232, 20)
# right_data7_score_W' 0.8125
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.625
# error_data8_score_W0 0.375
# combinedweight shape1 : (32480, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (35728, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.32625482625482627
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.28378378378378377
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)35728
# neuron unit number: 3276
# *******************
#
# Error Data percentage 0.6795366795366795
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2727272727272727
# error_data0_score_W0 0.19886363636363635
# combinedweight shape 0: (6552, 20)
# right_data0_score_W' 0.6024096385542169
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27734375
# error_data1_score_W0 0.1328125
# combinedweight shape1 : (9828, 20)
# right_data1_score_W' 0.6145833333333334
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2918918918918919
# error_data2_score_W0 0.12972972972972974
# combinedweight shape1 : (13104, 20)
# right_data2_score_W' 0.5352112676056338
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.29770992366412213
# error_data3_score_W0 0.1297709923664122
# combinedweight shape1 : (16380, 20)
# right_data3_score_W' 0.5555555555555556
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.34782608695652173
# error_data4_score_W0 0.16304347826086957
# combinedweight shape1 : (19656, 20)
# right_data4_score_W' 0.6666666666666666
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.43333333333333335
# error_data5_score_W0 0.16666666666666666
# combinedweight shape1 : (22932, 20)
# right_data5_score_W' 0.625
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.47058823529411764
# error_data6_score_W0 0.20588235294117646
# combinedweight shape1 : (26208, 20)
# right_data6_score_W' 0.6923076923076923
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6111111111111112
# error_data7_score_W0 0.2777777777777778
# combinedweight shape1 : (29484, 20)
# right_data7_score_W' 0.75
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8571428571428571
# error_data8_score_W0 0.42857142857142855
# combinedweight shape1 : (32760, 20)
# right_data8_score_W' 0.9090909090909091
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (36036, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3204633204633205
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2882882882882883
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)36036
# neuron unit number: 3304
# *******************
#
# Error Data percentage 0.6737451737451737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2836676217765043
# error_data0_score_W0 0.20630372492836677
# combinedweight shape 0: (6608, 20)
# right_data0_score_W' 0.8047337278106509
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.28
# error_data1_score_W0 0.128
# combinedweight shape1 : (9912, 20)
# right_data1_score_W' 0.6161616161616161
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28888888888888886
# error_data2_score_W0 0.13333333333333333
# combinedweight shape1 : (13216, 20)
# right_data2_score_W' 0.5857142857142857
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.328125
# error_data3_score_W0 0.1328125
# combinedweight shape1 : (16520, 20)
# right_data3_score_W' 0.5961538461538461
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3953488372093023
# error_data4_score_W0 0.13953488372093023
# combinedweight shape1 : (19824, 20)
# right_data4_score_W' 0.6428571428571429
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4230769230769231
# error_data5_score_W0 0.17307692307692307
# combinedweight shape1 : (23128, 20)
# right_data5_score_W' 0.5882352941176471
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5666666666666667
# error_data6_score_W0 0.2
# combinedweight shape1 : (26432, 20)
# right_data6_score_W' 0.7272727272727273
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6153846153846154
# error_data7_score_W0 0.3076923076923077
# combinedweight shape1 : (29736, 20)
# right_data7_score_W' 0.7647058823529411
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8
# error_data8_score_W0 0.6
# combinedweight shape1 : (33040, 20)
# right_data8_score_W' 0.75
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (36344, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.32625482625482627
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.2927927927927928
# test_score_W': 0.4099099099099099
# class_num*x*(optimize_W.split_num +1)36344
# neuron unit number: 3332
# *******************
#
# Error Data percentage 0.6563706563706564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2647058823529412
# error_data0_score_W0 0.2
# combinedweight shape 0: (6664, 20)
# right_data0_score_W' 0.6685393258426966
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.268
# error_data1_score_W0 0.12
# combinedweight shape1 : (9996, 20)
# right_data1_score_W' 0.5555555555555556
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.28415300546448086
# error_data2_score_W0 0.12568306010928962
# combinedweight shape1 : (13328, 20)
# right_data2_score_W' 0.5522388059701493
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3511450381679389
# error_data3_score_W0 0.11450381679389313
# combinedweight shape1 : (16660, 20)
# right_data3_score_W' 0.5384615384615384
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38823529411764707
# error_data4_score_W0 0.15294117647058825
# combinedweight shape1 : (19992, 20)
# right_data4_score_W' 0.5652173913043478
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.46153846153846156
# error_data5_score_W0 0.17307692307692307
# combinedweight shape1 : (23324, 20)
# right_data5_score_W' 0.5454545454545454
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5357142857142857
# error_data6_score_W0 0.2857142857142857
# combinedweight shape1 : (26656, 20)
# right_data6_score_W' 0.7083333333333334
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.46153846153846156
# error_data7_score_W0 0.23076923076923078
# combinedweight shape1 : (29988, 20)
# right_data7_score_W' 0.7333333333333333
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7142857142857143
# error_data8_score_W0 0.42857142857142855
# combinedweight shape1 : (33320, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.5
# combinedweight shape1 : (36652, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3436293436293436
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.3153153153153153
# test_score_W': 0.40540540540540543
# class_num*x*(optimize_W.split_num +1)36652
# neuron unit number: 3360
# *******************
#
# Error Data percentage 0.6563706563706564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2735294117647059
# error_data0_score_W0 0.20294117647058824
# combinedweight shape 0: (6720, 20)
# right_data0_score_W' 0.6292134831460674
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.26720647773279355
# error_data1_score_W0 0.13360323886639677
# combinedweight shape1 : (10080, 20)
# right_data1_score_W' 0.6344086021505376
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.292817679558011
# error_data2_score_W0 0.143646408839779
# combinedweight shape1 : (13440, 20)
# right_data2_score_W' 0.6212121212121212
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3359375
# error_data3_score_W0 0.140625
# combinedweight shape1 : (16800, 20)
# right_data3_score_W' 0.5471698113207547
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38823529411764707
# error_data4_score_W0 0.16470588235294117
# combinedweight shape1 : (20160, 20)
# right_data4_score_W' 0.6046511627906976
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4423076923076923
# error_data5_score_W0 0.19230769230769232
# combinedweight shape1 : (23520, 20)
# right_data5_score_W' 0.5454545454545454
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5517241379310345
# error_data6_score_W0 0.3103448275862069
# combinedweight shape1 : (26880, 20)
# right_data6_score_W' 0.6956521739130435
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6923076923076923
# error_data7_score_W0 0.3076923076923077
# combinedweight shape1 : (30240, 20)
# right_data7_score_W' 0.75
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.75
# error_data8_score_W0 0.25
# combinedweight shape1 : (33600, 20)
# right_data8_score_W' 1.0
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (36960, 20)
# right_data9_score_W' 1.0
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.3436293436293436
# all_train_score_W': 0.9845559845559846
# test_score_W0 : 0.30180180180180183
# test_score_W': 0.4144144144144144
# class_num*x*(optimize_W.split_num +1)36960
# s 364  value 0.4099099099099099
# s 728  value 0.4144144144144144
# s 1092  value 0.4144144144144144
# s 1344  value 0.4144144144144144
# s 1540  value 0.4099099099099099
# s 2016  value 0.4144144144144144
# s 2352  value 0.4189189189189189
# s 2464  value 0.4144144144144144
# s 3024  value 0.40540540540540543
# s 3080  value 0.4099099099099099
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  10.0  0.289640  0.011246  0.003556   0.281595  0.297685
# 1  test_score_W'  10.0  0.412613  0.003799  0.001201   0.409895  0.415330
# 2       combined  20.0  0.351126  0.063611  0.014224   0.321355  0.380897
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1230
# 1                          Degrees of freedom =   18.0000
# 2                                           t =  -32.7600
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =  -14.6507
# 7                                   Hedge's g =  -14.0317
# 8                               Glass's delta =  -10.9346
# 9                                 Pearson's r =    0.9917
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
