# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Iris.csv")
csv = csv.drop(columns=['Id'])
dataread.stringToIntIrisDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Species")

#print("self.data_train len {}".format(len(dataread.data_train)))

# %%
import experiment
unstable_repeat_num= 30
scope_num = 33
class_num = 3
dim_num = 4
best_num = 12
elbow_num = 1
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     


experiment = experiment.Experiment()

experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num)
# Out:
# neuron unit number: 3
# all_train_score_W0_n 0.6641611199379148
# all_train_score_W0_a 0.634378569946722
# test_score_W0_n 0.7600036782271798
# test_score_W0_a  0.6674191727807789
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.8620689655172413
# self.rest_data_W0_n 0.43871922143658476
# self.rest_data_W0_a 0.507305470608223
# Split one time!
# self.rest_data_W0_p 0.9375
# self.rest_data_W0_n 0.6860774131375549
# self.rest_data_W0_a 0.7457627118644068
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8520148001594926
# all_train_score_W_Combined_a 0.8672843050929648
# test_score_W_combined_n 0.8764262914844667
# test_score_W_combined_a 0.8654273420142307
# Combine Neurons Number :17
# neuron unit number: 4
# all_train_score_W0_n 0.6318585480131084
# all_train_score_W0_a 0.5865515674693321
# test_score_W0_n 0.5816407336278712
# test_score_W0_a  0.47816129559954196
# Split one time!
# self.rest_data_W0_p 0.7358490566037735
# self.rest_data_W0_n 0.44497484937073895
# self.rest_data_W0_a 0.266590497170358
# Split one time!
# self.rest_data_W0_p 0.8846153846153846
# self.rest_data_W0_n 0.7449481656949751
# self.rest_data_W0_a 0.798145004347646
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7006626181651138
# all_train_score_W_Combined_a 0.6430777203543844
# test_score_W_combined_n 0.7268253830942792
# test_score_W_combined_a 0.5874551581693662
# Combine Neurons Number :21
# neuron unit number: 5
# all_train_score_W0_n 0.5203994004667931
# all_train_score_W0_a 0.45423925103897483
# test_score_W0_n 0.7132990698600008
# test_score_W0_a  0.660419296416223
# Split one time!
# self.rest_data_W0_p 0.8103448275862069
# self.rest_data_W0_n 0.6364133764109369
# self.rest_data_W0_a 0.5748201150461989
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.8571428571428571
# self.rest_data_W0_n 0.7471790950662619
# self.rest_data_W0_a 0.475
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.75
# self.rest_data_W0_n 0.3437110184854508
# self.rest_data_W0_a 0.0
# all_train_score_W_Combined_n 0.7107347586823417
# all_train_score_W_Combined_a 0.6972051534724876
# test_score_W_combined_n 0.7238646273718151
# test_score_W_combined_a 0.6998656741478704
# Combine Neurons Number :23
# neuron unit number: 6
# all_train_score_W0_n 0.867534632171704
# all_train_score_W0_a 0.891890014768025
# test_score_W0_n 0.875959541647671
# test_score_W0_a  0.8667539194118794
# Split one time!
# self.rest_data_W0_p 0.9545454545454546
# self.rest_data_W0_n 0.8518849716907225
# self.rest_data_W0_a 0.8774034833013447
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943457592855133
# all_train_score_W_Combined_a 0.9177173106922742
# test_score_W_combined_n 0.8496053890527923
# test_score_W_combined_a 0.8656502695417789
# Combine Neurons Number :25
# neuron unit number: 7
# all_train_score_W0_n 0.6492057060900366
# all_train_score_W0_a 0.6049827462677838
# test_score_W0_n 0.7375414745558182
# test_score_W0_a  0.7032948792430908
# Split one time!
# self.rest_data_W0_p 0.7971014492753623
# self.rest_data_W0_n 0.7110462762174722
# self.rest_data_W0_a 0.5747034681957643
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7590172881623533
# all_train_score_W_Combined_a 0.6716750585292326
# test_score_W_combined_n 0.7149235971552675
# test_score_W_combined_a 0.5790165455388897
# Combine Neurons Number :22
# neuron unit number: 8
# all_train_score_W0_n 0.825894338250363
# all_train_score_W0_a 0.842779598918407
# test_score_W0_n 0.8075109595173275
# test_score_W0_a  0.7555018934196805
# Split one time!
# self.rest_data_W0_p 0.948051948051948
# self.rest_data_W0_n 0.8381933209364276
# self.rest_data_W0_a 0.8743158750513356
# Split one time!
# self.rest_data_W0_p 0.9444444444444444
# self.rest_data_W0_n 0.8205217270086157
# self.rest_data_W0_a 0.7938190638756626
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8452518713464839
# all_train_score_W_Combined_a 0.8669033641637308
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :30
# neuron unit number: 9
# all_train_score_W0_n 0.7523875578005559
# all_train_score_W0_a 0.7546734950505184
# test_score_W0_n 0.875959541647671
# test_score_W0_a  0.8667539194118794
# Split one time!
# self.rest_data_W0_p 0.9545454545454546
# self.rest_data_W0_n 0.8785543987421671
# self.rest_data_W0_a 0.8893245962540632
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.8181818181818182
# self.rest_data_W0_n 0.6863255799879583
# self.rest_data_W0_a 0.5181476846057572
# Split one time!
# self.rest_data_W0_p 0.8571428571428571
# self.rest_data_W0_n 0.7699888529362955
# self.rest_data_W0_a 0.625
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8232021423359361
# all_train_score_W_Combined_a 0.8428247137781287
# test_score_W_combined_n 0.8496053890527923
# test_score_W_combined_a 0.8656502695417789
# Combine Neurons Number :27
# neuron unit number: 10
# all_train_score_W0_n 0.84519390705863
# all_train_score_W0_a 0.8670178758663019
# test_score_W0_n 0.6967499986113994
# test_score_W0_a  0.6519672638299069
# Split one time!
# self.rest_data_W0_p 0.975
# self.rest_data_W0_n 0.919958553608803
# self.rest_data_W0_a 0.9343580925010804
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.910416419607222
# all_train_score_W_Combined_a 0.917670088169496
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :36
# neuron unit number: 11
# all_train_score_W0_n 0.7155858075253867
# all_train_score_W0_a 0.6704767558926141
# test_score_W0_n 0.7137510919355251
# test_score_W0_a  0.5609933080706281
# Split one time!
# self.rest_data_W0_p 0.8428571428571429
# self.rest_data_W0_n 0.6812203772310549
# self.rest_data_W0_a 0.6744462852455325
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.6666666666666666
# self.rest_data_W0_n 0.2740175421212811
# self.rest_data_W0_a -0.5
# all_train_score_W_Combined_n 0.7247053526327587
# all_train_score_W_Combined_a 0.7155059408999745
# test_score_W_combined_n 0.6557108483252896
# test_score_W_combined_a 0.5751944926400627
# Combine Neurons Number :33
# neuron unit number: 12
# all_train_score_W0_n 0.8936254767011607
# all_train_score_W0_a 0.9151508946543784
# test_score_W0_n 0.7132990698600008
# test_score_W0_a  0.660419296416223
# Split one time!
# self.rest_data_W0_p 0.9868421052631579
# self.rest_data_W0_n 0.9491591629500657
# self.rest_data_W0_a 0.9612239514639936
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606189664652894
# all_train_score_W_Combined_a 0.9717169648847928
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :50
# neuron unit number: 13
# all_train_score_W0_n 0.8040778527334197
# all_train_score_W0_a 0.8196429941436718
# test_score_W0_n 0.7668800788890244
# test_score_W0_a  0.7518866085600512
# Split one time!
# self.rest_data_W0_p 0.9701492537313433
# self.rest_data_W0_n 0.8904513580399436
# self.rest_data_W0_a 0.9231735685913051
# Split one time!
# self.rest_data_W0_p 0.9523809523809523
# self.rest_data_W0_n 0.8685351720013652
# self.rest_data_W0_a 0.842679794520548
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943913180364574
# all_train_score_W_Combined_a 0.9176464565763084
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :36
# neuron unit number: 14
# all_train_score_W0_n 0.8943457592855133
# all_train_score_W0_a 0.9177173106922742
# test_score_W0_n 0.7745985068154575
# test_score_W0_a  0.7736241354436288
# Split one time!
# self.rest_data_W0_p 0.9767441860465116
# self.rest_data_W0_n 0.909718227074231
# self.rest_data_W0_a 0.9397128622883495
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9214810531258618
# all_train_score_W_Combined_a 0.9442817768419821
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :48
# neuron unit number: 15
# all_train_score_W0_n 0.8015858968357529
# all_train_score_W0_a 0.7893512770627148
# test_score_W0_n 0.7817110818995432
# test_score_W0_a  0.7085281008805305
# Split one time!
# self.rest_data_W0_p 0.918918918918919
# self.rest_data_W0_n 0.827871559657478
# self.rest_data_W0_a 0.8107699512166343
# Split one time!
# self.rest_data_W0_p 0.9375
# self.rest_data_W0_n 0.8450034400998371
# self.rest_data_W0_a 0.8016528925619835
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8420565467214873
# all_train_score_W_Combined_a 0.8202615568897158
# test_score_W_combined_n 0.8075109595173275
# test_score_W_combined_a 0.7555018934196805
# Combine Neurons Number :35
# neuron unit number: 16
# all_train_score_W0_n 0.910416419607222
# all_train_score_W0_a 0.917670088169496
# test_score_W0_n 0.7268327994707248
# test_score_W0_a  0.7008771929824561
# Split one time!
# self.rest_data_W0_p 0.9770114942528736
# self.rest_data_W0_n 0.923731709958674
# self.rest_data_W0_a 0.9344007731079994
# all_train_score_W_Combined_n 0.9332579975464873
# all_train_score_W_Combined_a 0.9442657837435623
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :51
# neuron unit number: 17
# all_train_score_W0_n 0.8086997816083695
# all_train_score_W0_a 0.8195394861897033
# test_score_W0_n 0.7583504035279057
# test_score_W0_a  0.7498315363881402
# Split one time!
# self.rest_data_W0_p 0.9487179487179487
# self.rest_data_W0_n 0.8679779445796765
# self.rest_data_W0_a 0.8645271306638757
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.9
# self.rest_data_W0_n 0.7917656700291278
# self.rest_data_W0_a 0.6762589928057554
# all_train_score_W_Combined_n 0.872734592698713
# all_train_score_W_Combined_a 0.8671321906945081
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :34
# neuron unit number: 18
# all_train_score_W0_n 0.8943457592855133
# all_train_score_W0_a 0.9177173106922742
# test_score_W0_n 0.6817972377096646
# test_score_W0_a  0.6523720582741875
# Split one time!
# self.rest_data_W0_p 0.9885057471264368
# self.rest_data_W0_n 0.9550179143448093
# self.rest_data_W0_a 0.9693079040218677
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606001798344693
# all_train_score_W_Combined_a 0.9717412986215891
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :60
# neuron unit number: 19
# all_train_score_W0_n 0.6588697672471546
# all_train_score_W0_a 0.6295500825858075
# test_score_W0_n 0.6405053106554813
# test_score_W0_a  0.5451254490267606
# Split one time!
# self.rest_data_W0_p 0.8860759493670886
# self.rest_data_W0_n 0.7089252572099335
# self.rest_data_W0_a 0.7306642080171255
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7542004163823286
# all_train_score_W_Combined_a 0.771196399777719
# test_score_W_combined_n 0.8764262914844667
# test_score_W_combined_a 0.8654273420142307
# Combine Neurons Number :27
# neuron unit number: 20
# all_train_score_W0_n 0.9214810531258618
# all_train_score_W0_a 0.9442817768419821
# test_score_W0_n 0.6707913955596023
# test_score_W0_a  0.6419979040899765
# Split one time!
# self.rest_data_W0_p 0.9764705882352941
# self.rest_data_W0_n 0.9229220746935338
# self.rest_data_W0_a 0.9352451664164013
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9332579975464873
# all_train_score_W_Combined_a 0.9442657837435623
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :66
# neuron unit number: 21
# all_train_score_W0_n 0.825894338250363
# all_train_score_W0_a 0.842779598918407
# test_score_W0_n 0.7238646273718151
# test_score_W0_a  0.6998656741478704
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8266846809132101
# self.rest_data_W0_a 0.839876849974168
# Split one time!
# self.rest_data_W0_p 0.9565217391304348
# self.rest_data_W0_n 0.8805039048256257
# self.rest_data_W0_a 0.8693181818181818
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8346915891421971
# all_train_score_W_Combined_a 0.842914865867069
# test_score_W_combined_n 0.8030077906700085
# test_score_W_combined_a 0.8060670509878547
# Combine Neurons Number :40
# neuron unit number: 22
# all_train_score_W0_n 0.9332579975464873
# all_train_score_W0_a 0.9442657837435623
# test_score_W0_n 0.6631174916083891
# test_score_W0_a  0.540210942649967
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.9375
# self.rest_data_W0_n 0.847481617511446
# self.rest_data_W0_a 0.8345588235294118
# all_train_score_W_Combined_n 0.9606189664652894
# all_train_score_W_Combined_a 0.9717169648847928
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :64
# neuron unit number: 23
# all_train_score_W0_n 0.8943913180364574
# all_train_score_W0_a 0.9176464565763084
# test_score_W0_n 0.7668800788890244
# test_score_W0_a  0.7518866085600512
# Split one time!
# self.rest_data_W0_p 0.961038961038961
# self.rest_data_W0_n 0.8676333629952401
# self.rest_data_W0_a 0.8902012362560593
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943913180364574
# all_train_score_W_Combined_a 0.9176464565763084
# test_score_W_combined_n 0.8030077906700085
# test_score_W_combined_a 0.8060670509878547
# Combine Neurons Number :41
# neuron unit number: 24
# all_train_score_W0_n 0.921351067368422
# all_train_score_W0_a 0.9438740219642858
# test_score_W0_n 0.7350307349382155
# test_score_W0_a  0.6759892889021125
# Split one time!
# self.rest_data_W0_p 0.9888888888888889
# self.rest_data_W0_n 0.9558944382414463
# self.rest_data_W0_a 0.9682736108246569
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606189664652894
# all_train_score_W_Combined_a 0.9717169648847928
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :67
# neuron unit number: 25
# all_train_score_W0_n 0.7402525587254732
# all_train_score_W0_a 0.7353980832790985
# test_score_W0_n 0.7675785613905429
# test_score_W0_a  0.749416429957533
# Split one time!
# self.rest_data_W0_p 0.875
# self.rest_data_W0_n 0.7071867850635627
# self.rest_data_W0_a 0.6834405531229737
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7537425292523221
# all_train_score_W_Combined_a 0.7550249765929993
# test_score_W_combined_n 0.714308442349404
# test_score_W_combined_a 0.6536911624783119
# Combine Neurons Number :40
# neuron unit number: 26
# all_train_score_W0_n 0.9332579975464873
# all_train_score_W0_a 0.9442657837435623
# test_score_W0_n 0.7019917451042944
# test_score_W0_a  0.6444747372586958
# Split one time!
# self.rest_data_W0_p 0.9879518072289156
# self.rest_data_W0_n 0.9524765682281451
# self.rest_data_W0_a 0.9631893430527445
# Split one time!
# self.rest_data_W0_p 0.9444444444444444
# self.rest_data_W0_n 0.8616903041593759
# self.rest_data_W0_a 0.8464780252859723
# all_train_score_W_Combined_n 0.9332579975464873
# all_train_score_W_Combined_a 0.9442657837435623
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :73
# neuron unit number: 27
# all_train_score_W0_n 0.8123919540430468
# all_train_score_W0_a 0.8374425376891539
# test_score_W0_n 0.7551758533487013
# test_score_W0_a  0.6784514809337553
# Split one time!
# self.rest_data_W0_p 0.9571428571428572
# self.rest_data_W0_n 0.8532628959120648
# self.rest_data_W0_a 0.8684298479919724
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943913180364574
# all_train_score_W_Combined_a 0.9176464565763084
# test_score_W_combined_n 0.8030077906700085
# test_score_W_combined_a 0.8060670509878547
# Combine Neurons Number :39
# neuron unit number: 28
# all_train_score_W0_n 0.9332579975464873
# all_train_score_W0_a 0.9442657837435623
# test_score_W0_n 0.7271269457533183
# test_score_W0_a  0.701154070681216
# Split one time!
# self.rest_data_W0_p 0.9886363636363636
# self.rest_data_W0_n 0.9548150178870772
# self.rest_data_W0_a 0.966109940003243
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606189664652894
# all_train_score_W_Combined_a 0.9717169648847928
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :75
# neuron unit number: 29
# all_train_score_W0_n 0.7542004163823286
# all_train_score_W0_a 0.771196399777719
# test_score_W0_n 0.8764262914844667
# test_score_W0_a  0.8654273420142307
# Split one time!
# self.rest_data_W0_p 0.9240506329113924
# self.rest_data_W0_n 0.7624774544411306
# self.rest_data_W0_a 0.7892963298637782
# Split one time!
# self.rest_data_W0_p 0.95
# self.rest_data_W0_n 0.8653303528190831
# self.rest_data_W0_a 0.8379052369077307
# all_train_score_W_Combined_n 0.783865571218972
# all_train_score_W_Combined_a 0.8144965638031998
# test_score_W_combined_n 0.8391199597061141
# test_score_W_combined_a 0.8054245283018868
# Combine Neurons Number :42
# neuron unit number: 30
# all_train_score_W0_n 0.9606189664652894
# all_train_score_W0_a 0.9717169648847928
# test_score_W0_n 0.6750746876860781
# test_score_W0_a  0.6109314066326068
# Split one time!
# self.rest_data_W0_p 0.9893617021276596
# self.rest_data_W0_n 0.9570545086992616
# self.rest_data_W0_a 0.968260704309031
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606189664652894
# all_train_score_W_Combined_a 0.9717169648847928
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :69
# neuron unit number: 31
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.8496053890527923
# test_score_W0_a  0.8656502695417789
# Split one time!
# self.rest_data_W0_p 0.9382716049382716
# self.rest_data_W0_n 0.8503922608370098
# self.rest_data_W0_a 0.8364083577410173
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.872734592698713
# all_train_score_W_Combined_a 0.8671321906945081
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :45
# neuron unit number: 32
# all_train_score_W0_n 0.9332009395675025
# all_train_score_W0_a 0.9443616048533252
# test_score_W0_n 0.7027196181236292
# test_score_W0_a  0.6272253516884055
# Split one time!
# self.rest_data_W0_p 0.9885057471264368
# self.rest_data_W0_n 0.954431980342329
# self.rest_data_W0_a 0.9659855860559997
# Split one time!
# self.rest_data_W0_p 0.9285714285714286
# self.rest_data_W0_n 0.8404533827668759
# self.rest_data_W0_a 0.8246628131021194
# all_train_score_W_Combined_n 0.9214810531258618
# all_train_score_W_Combined_a 0.9442817768419821
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :73
# neuron unit number: 33
# all_train_score_W0_n 0.9214810531258618
# all_train_score_W0_a 0.9442817768419821
# test_score_W0_n 0.8902012305350374
# test_score_W0_a  0.8946285389909885
# Split one time!
# self.rest_data_W0_p 0.9753086419753086
# self.rest_data_W0_n 0.9042647878784209
# self.rest_data_W0_a 0.9282826196027506
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9214810531258618
# all_train_score_W_Combined_a 0.9442817768419821
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :38
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.745548  0.073166  0.013141   0.718710  0.772385
# 1  test_score_W'  31.0  0.854004  0.078223  0.014049   0.825311  0.882696
# 2       combined  62.0  0.799776  0.092903  0.011799   0.776183  0.823369
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1085
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -5.6378
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.4320
# 7                                   Hedge's g =   -1.4140
# 8                               Glass's delta =   -1.4823
# 9                                 Pearson's r =    0.5885
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.745548  0.073166  0.013141   0.718710  0.772385
# 1  test_score_W'  31.0  0.838053  0.111524  0.020030   0.797145  0.878960
# 2       combined  62.0  0.791800  0.104518  0.013274   0.765258  0.818343
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0925
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -3.8614
# 3                       Two side test p value =    0.0003
# 4                      Difference < 0 p value =    0.0001
# 5                      Difference > 0 p value =    0.9999
# 6                                   Cohen's d =   -0.9808
# 7                                   Hedge's g =   -0.9685
# 8                               Glass's delta =   -1.2643
# 9                                 Pearson's r =    0.4461
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.8718237565415163
# all_train_score_W0_a 0.8918589833830313
# test_score_W0_n 0.9240047290347859
# test_score_W0_a  0.9307382324956623
# Split one time!
# self.rest_data_W0_p 0.9518072289156626
# self.rest_data_W0_n 0.8500870209658034
# self.rest_data_W0_a 0.8720609555795926
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8718237565415163
# all_train_score_W_Combined_a 0.8918589833830313
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :44
# all_train_score_W0_n 0.7862618174050363
# all_train_score_W0_a 0.8136647098292231
# test_score_W0_n 0.655253185140969
# test_score_W0_a  0.6129249159506911
# Split one time!
# self.rest_data_W0_p 0.9761904761904762
# self.rest_data_W0_n 0.9062757334610215
# self.rest_data_W0_a 0.9305608456861761
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.921351067368422
# all_train_score_W_Combined_a 0.9438740219642858
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :44
# all_train_score_W0_n 0.872734592698713
# all_train_score_W0_a 0.8671321906945081
# test_score_W0_n 0.7668800788890244
# test_score_W0_a  0.7518866085600512
# Split one time!
# self.rest_data_W0_p 0.963855421686747
# self.rest_data_W0_n 0.8956280844881233
# self.rest_data_W0_a 0.9020690092611788
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8904953538650714
# all_train_score_W_Combined_a 0.8919520241413702
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :48
# all_train_score_W0_n 0.8717217415099704
# all_train_score_W0_a 0.8920449049392878
# test_score_W0_n 0.7668800788890244
# test_score_W0_a  0.7518866085600512
# Split one time!
# self.rest_data_W0_p 0.9882352941176471
# self.rest_data_W0_n 0.9537497686439427
# self.rest_data_W0_a 0.9655974353867799
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606001798344693
# all_train_score_W_Combined_a 0.9717412986215891
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :47
# all_train_score_W0_n 0.7718868246552434
# all_train_score_W0_a 0.7760422648443781
# test_score_W0_n 0.6967499986113994
# test_score_W0_a  0.6519672638299069
# Split one time!
# self.rest_data_W0_p 0.9135802469135802
# self.rest_data_W0_n 0.7693270354530878
# self.rest_data_W0_a 0.7794346473029046
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8483968170784378
# self.rest_data_W0_a 0.8118712273641852
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.785317626852337
# all_train_score_W_Combined_a 0.7970858738722931
# test_score_W_combined_n 0.6967499986113994
# test_score_W_combined_a 0.6519672638299069
# Combine Neurons Number :46
# all_train_score_W0_n 0.7646611222711893
# all_train_score_W0_a 0.790758695721737
# test_score_W0_n 0.7645078412672276
# test_score_W0_a  0.6963562753036437
# Split one time!
# self.rest_data_W0_p 0.9302325581395349
# self.rest_data_W0_n 0.7856946164786852
# self.rest_data_W0_a 0.8113390155303348
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8123919540430468
# all_train_score_W_Combined_a 0.8374425376891539
# test_score_W_combined_n 0.8496053890527923
# test_score_W_combined_a 0.8656502695417789
# Combine Neurons Number :44
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.8444819046550165
# test_score_W0_a  0.8321085358959864
# Split one time!
# self.rest_data_W0_p 0.9512195121951219
# self.rest_data_W0_n 0.8726560594244899
# self.rest_data_W0_a 0.8718677427060733
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8904953538650714
# all_train_score_W_Combined_a 0.8919520241413702
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :46
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.8449465663413298
# test_score_W0_a  0.830981106305486
# Split one time!
# self.rest_data_W0_p 0.9425287356321839
# self.rest_data_W0_n 0.8308618396337671
# self.rest_data_W0_a 0.8390059198349793
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8521775606670629
# all_train_score_W_Combined_a 0.8669415566375692
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :47
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.875959541647671
# test_score_W0_a  0.8667539194118794
# Split one time!
# self.rest_data_W0_p 0.9534883720930233
# self.rest_data_W0_n 0.8756985576982409
# self.rest_data_W0_a 0.8733442274307031
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8904953538650714
# all_train_score_W_Combined_a 0.8919520241413702
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :41
# all_train_score_W0_n 0.8718237565415163
# all_train_score_W0_a 0.8918589833830313
# test_score_W0_n 0.7817110818995432
# test_score_W0_a  0.7085281008805305
# Split one time!
# self.rest_data_W0_p 0.9518072289156626
# self.rest_data_W0_n 0.8501159169636794
# self.rest_data_W0_a 0.8720021063420643
# all_train_score_W_Combined_n 0.8718237565415163
# all_train_score_W_Combined_a 0.8918589833830313
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :46
# all_train_score_W0_n 0.8420565467214873
# all_train_score_W0_a 0.8202615568897158
# test_score_W0_n 0.7817110818995432
# test_score_W0_a  0.7085281008805305
# Split one time!
# self.rest_data_W0_p 0.9518072289156626
# self.rest_data_W0_n 0.8739691487021156
# self.rest_data_W0_a 0.8752939470302773
# Split one time!
# self.rest_data_W0_p 0.9230769230769231
# self.rest_data_W0_n 0.8163042517978876
# self.rest_data_W0_a 0.7871759890859482
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.872734592698713
# all_train_score_W_Combined_a 0.8671321906945081
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :50
# all_train_score_W0_n 0.7932196774036901
# all_train_score_W0_a 0.7972022606961102
# test_score_W0_n 0.7001650770455317
# test_score_W0_a  0.6698360888384304
# Split one time!
# self.rest_data_W0_p 0.9036144578313253
# self.rest_data_W0_n 0.7649387940060539
# self.rest_data_W0_a 0.7722268314361186
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7932196774036901
# all_train_score_W_Combined_a 0.7972022606961102
# test_score_W_combined_n 0.8030077906700085
# test_score_W_combined_a 0.8060670509878547
# Combine Neurons Number :49
# all_train_score_W0_n 0.8718237565415163
# all_train_score_W0_a 0.8918589833830313
# test_score_W0_n 0.7597232629576168
# test_score_W0_a  0.7434568541072817
# Split one time!
# self.rest_data_W0_p 0.9746835443037974
# self.rest_data_W0_n 0.9173718801915
# self.rest_data_W0_a 0.9245708080852205
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9332579975464873
# all_train_score_W_Combined_a 0.9442657837435623
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :48
# all_train_score_W0_n 0.7718868246552434
# all_train_score_W0_a 0.7760422648443781
# test_score_W0_n 0.7675785613905429
# test_score_W0_a  0.749416429957533
# Split one time!
# self.rest_data_W0_p 0.9333333333333333
# self.rest_data_W0_n 0.8071029581049886
# self.rest_data_W0_a 0.8281213777188676
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8419884703251996
# self.rest_data_W0_a 0.796
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8232021423359361
# all_train_score_W_Combined_a 0.8428247137781287
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :52
# all_train_score_W0_n 0.7947424235638815
# all_train_score_W0_a 0.8130475037390499
# test_score_W0_n 0.7901245211600953
# test_score_W0_a  0.7744131250545423
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8047921781824533
# self.rest_data_W0_a 0.8372322907689213
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8321912356961896
# all_train_score_W_Combined_a 0.8627440942938474
# test_score_W_combined_n 0.8496053890527923
# test_score_W_combined_a 0.8656502695417789
# Combine Neurons Number :45
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.7631944224424904
# test_score_W0_a  0.7601539119281744
# Split one time!
# self.rest_data_W0_p 0.9759036144578314
# self.rest_data_W0_n 0.9068181603738984
# self.rest_data_W0_a 0.9349927408879041
# Split one time!
# self.rest_data_W0_p 0.9333333333333333
# self.rest_data_W0_n 0.8305006827759324
# self.rest_data_W0_a 0.7860635696821516
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943913180364574
# all_train_score_W_Combined_a 0.9176464565763084
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :42
# all_train_score_W0_n 0.9332579975464873
# all_train_score_W0_a 0.9442657837435623
# test_score_W0_n 0.7750070635909992
# test_score_W0_a  0.7728659618250195
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 1.0
# all_train_score_W_Combined_a 1.0
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :48
# all_train_score_W0_n 0.8904953538650714
# all_train_score_W0_a 0.8919520241413702
# test_score_W0_n 0.8087907676268287
# test_score_W0_a  0.7751253986764643
# Split one time!
# self.rest_data_W0_p 0.975609756097561
# self.rest_data_W0_n 0.9202267526283306
# self.rest_data_W0_a 0.9303192984000728
# Split one time!
# self.rest_data_W0_p 0.9375
# self.rest_data_W0_n 0.8430236582089744
# self.rest_data_W0_a 0.810306670882074
# all_train_score_W_Combined_n 0.910416419607222
# all_train_score_W_Combined_a 0.917670088169496
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :44
# all_train_score_W0_n 0.910416419607222
# all_train_score_W0_a 0.917670088169496
# test_score_W0_n 0.7634606272722496
# test_score_W0_a  0.7399223561691818
# Split one time!
# self.rest_data_W0_p 0.9629629629629629
# self.rest_data_W0_n 0.893423937434018
# self.rest_data_W0_a 0.8999133337337716
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.910416419607222
# all_train_score_W_Combined_a 0.917670088169496
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :47
# all_train_score_W0_n 0.8041405589681776
# all_train_score_W0_a 0.8194876876470599
# test_score_W0_n 0.6367152136420295
# test_score_W0_a  0.5673364685763147
# Split one time!
# self.rest_data_W0_p 0.9397590361445783
# self.rest_data_W0_n 0.8181884165430621
# self.rest_data_W0_a 0.8361017805122052
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8452518713464839
# all_train_score_W_Combined_a 0.8669033641637308
# test_score_W_combined_n 0.803363261817471
# test_score_W_combined_a 0.8051016677447479
# Combine Neurons Number :45
# all_train_score_W0_n 0.872734592698713
# all_train_score_W0_a 0.8671321906945081
# test_score_W0_n 0.7418209865314529
# test_score_W0_a  0.632175366895783
# Split one time!
# self.rest_data_W0_p 0.9878048780487805
# self.rest_data_W0_n 0.952709870561212
# self.rest_data_W0_a 0.9668247798175668
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9606189664652894
# all_train_score_W_Combined_a 0.9717169648847928
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :45
# all_train_score_W0_n 0.8257738883336571
# all_train_score_W0_a 0.8430499002578876
# test_score_W0_n 0.8764262914844667
# test_score_W0_a  0.8654273420142307
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8229251748519796
# self.rest_data_W0_a 0.8476356856856501
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.84519390705863
# all_train_score_W_Combined_a 0.8670178758663019
# test_score_W_combined_n 0.8391199597061141
# test_score_W_combined_a 0.8054245283018868
# Combine Neurons Number :47
# all_train_score_W0_n 0.8452518713464839
# all_train_score_W0_a 0.8669033641637308
# test_score_W0_n 0.8030077906700085
# test_score_W0_a  0.8060670509878547
# Split one time!
# self.rest_data_W0_p 0.95
# self.rest_data_W0_n 0.8654080785999072
# self.rest_data_W0_a 0.8507245066809231
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8904953538650714
# all_train_score_W_Combined_a 0.8919520241413702
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :47
# all_train_score_W0_n 0.8904953538650714
# all_train_score_W0_a 0.8919520241413702
# test_score_W0_n 0.8087907676268287
# test_score_W0_a  0.7751253986764643
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.8823529411764706
# self.rest_data_W0_n 0.701366639662019
# self.rest_data_W0_a 0.6643632773938796
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.921351067368422
# all_train_score_W_Combined_a 0.9438740219642858
# test_score_W_combined_n 0.9240047290347859
# test_score_W_combined_a 0.9307382324956623
# Combine Neurons Number :45
# all_train_score_W0_n 0.783865571218972
# all_train_score_W0_a 0.8144965638031998
# test_score_W0_n 0.6778221015337629
# test_score_W0_a  0.6636234710157773
# Split one time!
# self.rest_data_W0_p 0.9066666666666666
# self.rest_data_W0_n 0.7319955988728614
# self.rest_data_W0_a 0.7513676884003524
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7862618174050363
# all_train_score_W_Combined_a 0.8136647098292231
# test_score_W_combined_n 0.875959541647671
# test_score_W_combined_a 0.8667539194118794
# Combine Neurons Number :49
# all_train_score_W0_n 0.7686667605100415
# all_train_score_W0_a 0.7755926655243843
# test_score_W0_n 0.5931428907661722
# test_score_W0_a  0.5296708991966831
# Split one time!
# self.rest_data_W0_p 0.925
# self.rest_data_W0_n 0.7903573383933596
# self.rest_data_W0_a 0.7967054752550193
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.825894338250363
# all_train_score_W_Combined_a 0.842779598918407
# test_score_W_combined_n 0.6913968819024111
# test_score_W_combined_a 0.6525438005390836
# Combine Neurons Number :44
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.6592840493194867
# test_score_W0_a  0.6170782505206783
# Split one time!
# self.rest_data_W0_p 0.9390243902439024
# self.rest_data_W0_n 0.8264721643004478
# self.rest_data_W0_a 0.8393461574802275
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8521775606670629
# all_train_score_W_Combined_a 0.8669415566375692
# test_score_W_combined_n 0.8030077906700085
# test_score_W_combined_a 0.8060670509878547
# Combine Neurons Number :47
# all_train_score_W0_n 0.8521775606670629
# all_train_score_W0_a 0.8669415566375692
# test_score_W0_n 0.8215606167684458
# test_score_W0_a  0.8278011305986375
# Split one time!
# self.rest_data_W0_p 0.975609756097561
# self.rest_data_W0_n 0.9049387535501614
# self.rest_data_W0_a 0.9287841023247068
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943913180364574
# all_train_score_W_Combined_a 0.9176464565763084
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :43
# all_train_score_W0_n 0.8232021423359361
# all_train_score_W0_a 0.8428247137781287
# test_score_W0_n 0.8902550407934353
# test_score_W0_a  0.8920988766657463
# Split one time!
# self.rest_data_W0_p 0.9615384615384616
# self.rest_data_W0_n 0.8707156136011578
# self.rest_data_W0_a 0.9037049962974646
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8943913180364574
# all_train_score_W_Combined_a 0.9176464565763084
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :47
# all_train_score_W0_n 0.84519390705863
# all_train_score_W0_a 0.8670178758663019
# test_score_W0_n 0.713930327044231
# test_score_W0_a  0.6698360888384304
# Split one time!
# self.rest_data_W0_p 0.975
# self.rest_data_W0_n 0.9045561222880343
# self.rest_data_W0_a 0.9362077527767796
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.9214810531258618
# all_train_score_W_Combined_a 0.9442817768419821
# test_score_W_combined_n 0.9241763062238948
# test_score_W_combined_a 0.9303934527659814
# Combine Neurons Number :50
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.768463  0.078055  0.014251   0.739317  0.797609
# 1  test_score_W'  30.0  0.876380  0.064596  0.011794   0.852260  0.900501
# 2       combined  60.0  0.822422  0.089479  0.011552   0.799307  0.845537
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1079
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -5.8341
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.5063
# 7                                   Hedge's g =   -1.4868
# 8                               Glass's delta =   -1.3826
# 9                                 Pearson's r =    0.6081
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.768463  0.078055  0.014251   0.739317  0.797609
# 1  test_score_W'  30.0  0.874186  0.076512  0.013969   0.845616  0.902757
# 2       combined  60.0  0.821325  0.093348  0.012051   0.797210  0.845439
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1057
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -5.2980
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.3679
# 7                                   Hedge's g =   -1.3502
# 8                               Glass's delta =   -1.3545
# 9                                 Pearson's r =    0.5711
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 33
class_num = 3
dim_num = 4
best_num = 12
elbow_num = 1
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     


experiment = experiment.Experiment()

experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num)
# Out:
# neuron unit number: 3
# all_train_score_W0_n 0.7157059136260981
# all_train_score_W0_a 0.5325240024319678
# test_score_W0_n 0.6850687587108245
# test_score_W0_a  0.6221864951768489
# len  self.all_split_datas 7
# rest_data_true_label len 60
# restdata_W0_predicted_label len 65
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 20>()
#      13 #som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)
#      14 #optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#      15 #optimize_W.run(  total_label_train  )
#      18 experiment = experiment.Experiment()
# ---> 20 experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num)
#      21 print("*****************************************************************************************")
#      22 print("Best Number SOM Comparision")
#
# File C:\JupyterDoc\SOM\experiment.py:335, in Experiment.UTtest(self, dataread, label_train, class_num, dim_num, best_num, scope_num, unstable_repeat_num, type, elbow_num)
#     332  som = newSom.SOM(m= y , n= 1, dim=dim_num)
#     333 optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,elbow_num)
# --> 335 optimize_W.run()
#     336 all_train_score_W0_n.append(optimize_W.all_train_score_W0_n)
#     337 all_train_score_W_combine_n.append(optimize_W.all_train_score_W_Combined_n)
#
# File C:\JupyterDoc\SOM\UTDSM.py:657, in UTDSM_SOM.run(self)
#     655 print("len  self.all_split_datas {}".format(len( self.all_split_datas)))
#     656 #self.test_rest_data(predicted_clusters,current_clustered_datas,weight0)
# --> 657 self.test_rest_data_one_time(predicted_clusters,current_clustered_datas,self.som.weights0)
#     658 self.test_combineW()
#     659 #if self.elbowed_time < self.elbow_num:
#     660
#     661 #for i in range(0,len(predicted_clusters)):
#    (...)
#     700 #plt.show()
#     701 #self.elbowed_time = self.elbowed_time+1
#
# File C:\JupyterDoc\SOM\UTDSM.py:826, in UTDSM_SOM.test_rest_data_one_time(self, predicted_clusters, current_clustered_datas, weight0)
#     824 #restdata_W0_predicted_label = self.som.predict(data_rest,weight0)
#     825 transferred_predicted_label_restdata_W0 =  self.convertPredictedLabelValue(restdata_W0_predicted_label,self.PLabel_to_Tlabel_Mapping_W0)
# --> 826 self.getScore("rest_score_W0",rest_data_true_label,transferred_predicted_label_restdata_W0)
#
# File C:\JupyterDoc\SOM\UTDSM.py:494, in UTDSM_SOM.getScore(self, scorename, y_true, y_pred)
#     491 def getScore(self,scorename, y_true, y_pred):
#     492     #print(scorename)
#     493    # self.purity_score(scorename,y_true,y_pred)
# --> 494     self.nmiScore(scorename,y_true,y_pred)
#     495     self.ariScore(scorename,y_true,y_pred)
#
# File C:\JupyterDoc\SOM\UTDSM.py:123, in UTDSM_SOM.nmiScore(self, scorename, y_true, y_pred)
#     121     print("test_score_W_combined_n {}".format(self.test_score_W_Combined_n ))
#     122 if(scorename == "rest_score_W0" ):
# --> 123     self.rest_data_W0_n  = normalized_mutual_info_score(y_true,y_pred)
#     124   #  if self.rest_data_W0_n == 0.0 :
#     125      #   print("y_true {} y_pred {} ".format((y_true),(y_pred)))
#     126     print("self.rest_data_W0_n {}".format(self.rest_data_W0_n))
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:1020, in normalized_mutual_info_score(labels_true, labels_pred, average_method)
#     943 def normalized_mutual_info_score(
#     944     labels_true, labels_pred, *, average_method="arithmetic"
#     945 ):
#     946     """Normalized Mutual Information between two clusterings.
#     947
#     948     Normalized Mutual Information (NMI) is a normalization of the Mutual
#    (...)
#    1018       0.0
#    1019     """
# -> 1020     labels_true, labels_pred = check_clusterings(labels_true, labels_pred)
#    1021     classes = np.unique(labels_true)
#    1022     clusters = np.unique(labels_pred)
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\cluster\_supervised.py:72, in check_clusterings(labels_true, labels_pred)
#      70 if labels_pred.ndim != 1:
#      71     raise ValueError("labels_pred must be 1D: shape is %r" % (labels_pred.shape,))
# ---> 72 check_consistent_length(labels_true, labels_pred)
#      74 return labels_true, labels_pred
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:332, in check_consistent_length(*arrays)
#     330 uniques = np.unique(lengths)
#     331 if len(uniques) > 1:
# --> 332     raise ValueError(
#     333         "Found input variables with inconsistent numbers of samples: %r"
#     334         % [int(l) for l in lengths]
#     335     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [60, 65]
