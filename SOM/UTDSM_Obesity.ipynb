# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import experiment
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Obesity/ObesityDataSet_raw_and_data_sinthetic.csv")
dataread.stringToIntObseityDataSet(csv,"CAEC")
dataread.stringToIntObseityDataSet(csv,"Gender")
dataread.stringToIntObseityDataSet(csv,"family_history_with_overweight")
dataread.stringToIntObseityDataSet(csv,"FAVC")
dataread.stringToIntObseityDataSet(csv,"SCC")
dataread.stringToIntObseityDataSet(csv,"SMOKE")
dataread.stringToIntObseityDataSet(csv,"CALC")
dataread.stringToIntObseityDataSet(csv,"MTRANS")
dataread.stringToIntObseityDataSet(csv,"NObeyesdad")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"NObeyesdad")

# %%
import experiment
unstable_repeat_num= 30
scope_num = 37
class_num = 7
dim_num = 16
best_num = 15
total_label_train = []
elbow_num = 1
print(len(dataread.data_train))
for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     



experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num)
# Out:
# 1478
# neuron unit number: 7
# all_train_score_W0_n 0.45143486274668376
# all_train_score_W0_a 0.2779297801019076
# test_score_W0_n 0.46477237234635305
# test_score_W0_a  0.30593103065977684
# len  self.all_split_datas 8
# rest_data_true_label len 1475
# len  self.rest_data_predicted_label_dict 1475
# restdata_W0_predicted_label len 1475
# self.rest_data_W0_n 0.0036433500048714098
# self.rest_data_W0_a -0.0018518340768041988
# all_train_score_W_Combined_n 0.4517257671119978
# all_train_score_W_Combined_a 0.27832132226907924
# test_score_W_combined_n 0.4615905497572776
# test_score_W_combined_a 0.3014624167691198
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :8
# neuron unit number: 8
# all_train_score_W0_n 0.47808114996223183
# all_train_score_W0_a 0.30423246657175496
# test_score_W0_n 0.4749185283861781
# test_score_W0_a  0.29648847729407
# len  self.all_split_datas 16
# rest_data_true_label len 1403
# len  self.rest_data_predicted_label_dict 1403
# restdata_W0_predicted_label len 1403
# self.rest_data_W0_n 0.0076335244638456486
# self.rest_data_W0_a -0.000344867653894145
# all_train_score_W_Combined_n 0.48009854301054466
# all_train_score_W_Combined_a 0.3070298762016426
# test_score_W_combined_n 0.4725371837100373
# test_score_W_combined_a 0.29884655238695207
# Not good nmi result !!!!!
# Combine Neurons Number :16
# neuron unit number: 9
# all_train_score_W0_n 0.46332734484143023
# all_train_score_W0_a 0.30381261424168104
# test_score_W0_n 0.4825662926463403
# test_score_W0_a  0.3231689449366126
# len  self.all_split_datas 10
# rest_data_true_label len 1472
# len  self.rest_data_predicted_label_dict 1472
# restdata_W0_predicted_label len 1472
# self.rest_data_W0_n 0.007617822074447837
# self.rest_data_W0_a 0.0006584408391859131
# all_train_score_W_Combined_n 0.46332734484143023
# all_train_score_W_Combined_a 0.30381261424168104
# test_score_W_combined_n 0.47879323668846985
# test_score_W_combined_a 0.3188957594750473
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :10
# neuron unit number: 10
# all_train_score_W0_n 0.47923381887865296
# all_train_score_W0_a 0.35193693392055114
# test_score_W0_n 0.4637365181659883
# test_score_W0_a  0.31528709288348467
# len  self.all_split_datas 26
# rest_data_true_label len 1463
# len  self.rest_data_predicted_label_dict 1463
# restdata_W0_predicted_label len 1463
# self.rest_data_W0_n 0.0071937278180681805
# self.rest_data_W0_a 0.0008184849376813246
# all_train_score_W_Combined_n 0.47923381887865296
# all_train_score_W_Combined_a 0.35193693392055114
# test_score_W_combined_n 0.47766792149975706
# test_score_W_combined_a 0.32677800749588426
# Combine Neurons Number :26
# neuron unit number: 11
# all_train_score_W0_n 0.45120220239779285
# all_train_score_W0_a 0.29120802833451415
# test_score_W0_n 0.46273346047800856
# test_score_W0_a  0.3051393131400119
# len  self.all_split_datas 12
# rest_data_true_label len 1457
# len  self.rest_data_predicted_label_dict 1457
# restdata_W0_predicted_label len 1457
# self.rest_data_W0_n 0.004160878220915535
# self.rest_data_W0_a -0.00010913401917631352
# all_train_score_W_Combined_n 0.45177132033531464
# all_train_score_W_Combined_a 0.2907326528007494
# test_score_W_combined_n 0.4614654235362734
# test_score_W_combined_a 0.3088390864472394
# Not good nmi result !!!!!
# Combine Neurons Number :12
# neuron unit number: 12
# all_train_score_W0_n 0.4988793780373325
# all_train_score_W0_a 0.3919735906498292
# test_score_W0_n 0.49077799511286224
# test_score_W0_a  0.35093331907366987
# len  self.all_split_datas 37
# rest_data_true_label len 1474
# len  self.rest_data_predicted_label_dict 1474
# restdata_W0_predicted_label len 1474
# self.rest_data_W0_n 0.008512312020208423
# self.rest_data_W0_a 0.0008183206036551455
# all_train_score_W_Combined_n 0.4988793780373325
# all_train_score_W_Combined_a 0.3919735906498292
# test_score_W_combined_n 0.504983490699503
# test_score_W_combined_a 0.36749472196579364
# Combine Neurons Number :37
# neuron unit number: 13
# all_train_score_W0_n 0.4922551322142061
# all_train_score_W0_a 0.3608298177669117
# test_score_W0_n 0.5060555746608218
# test_score_W0_a  0.3659964482676652
# len  self.all_split_datas 14
# rest_data_true_label len 1463
# len  self.rest_data_predicted_label_dict 1463
# restdata_W0_predicted_label len 1463
# self.rest_data_W0_n 0.0067169116077960426
# self.rest_data_W0_a 0.00033256016768144325
# all_train_score_W_Combined_n 0.4922551322142061
# all_train_score_W_Combined_a 0.3608298177669117
# test_score_W_combined_n 0.5020558285435082
# test_score_W_combined_a 0.36230976123222924
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :14
# neuron unit number: 14
# all_train_score_W0_n 0.5353294339551948
# all_train_score_W0_a 0.44993373175812584
# test_score_W0_n 0.5374253093942581
# test_score_W0_a  0.42800007310129995
# len  self.all_split_datas 50
# rest_data_true_label len 1471
# len  self.rest_data_predicted_label_dict 1471
# restdata_W0_predicted_label len 1471
# self.rest_data_W0_n 0.008069851615281762
# self.rest_data_W0_a 0.0008177472210480484
# all_train_score_W_Combined_n 0.5418311621326842
# all_train_score_W_Combined_a 0.45538776968809475
# test_score_W_combined_n 0.5404563013931604
# test_score_W_combined_a 0.4324086157744836
# Combine Neurons Number :50
# neuron unit number: 15
# all_train_score_W0_n 0.5087167530026525
# all_train_score_W0_a 0.3577787807899365
# test_score_W0_n 0.4915918868856924
# test_score_W0_a  0.33467011437507066
# len  self.all_split_datas 16
# rest_data_true_label len 1472
# len  self.rest_data_predicted_label_dict 1472
# restdata_W0_predicted_label len 1472
# self.rest_data_W0_n 0.008732695995472948
# self.rest_data_W0_a 0.001220151269980241
# all_train_score_W_Combined_n 0.5081448514129505
# all_train_score_W_Combined_a 0.3567123815740743
# test_score_W_combined_n 0.4895906132134423
# test_score_W_combined_a 0.3278006776613978
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :16
# neuron unit number: 16
# all_train_score_W0_n 0.5453805385171887
# all_train_score_W0_a 0.45531594221423205
# test_score_W0_n 0.5196124456532304
# test_score_W0_a  0.4133077975582514
# len  self.all_split_datas 65
# rest_data_true_label len 1473
# len  self.rest_data_predicted_label_dict 1473
# restdata_W0_predicted_label len 1473
# self.rest_data_W0_n 0.00924449319707779
# self.rest_data_W0_a 0.0016494953925515557
# all_train_score_W_Combined_n 0.5479502127786992
# all_train_score_W_Combined_a 0.4572912233439313
# test_score_W_combined_n 0.5327834638730823
# test_score_W_combined_a 0.4210621654186902
# Combine Neurons Number :65
# neuron unit number: 17
# all_train_score_W0_n 0.5000952227007044
# all_train_score_W0_a 0.38430296342176207
# test_score_W0_n 0.5118355738357347
# test_score_W0_a  0.3787627338413383
# len  self.all_split_datas 18
# rest_data_true_label len 1473
# len  self.rest_data_predicted_label_dict 1473
# restdata_W0_predicted_label len 1473
# self.rest_data_W0_n 0.00940543822421036
# self.rest_data_W0_a 0.0014551673508019065
# all_train_score_W_Combined_n 0.4996873113581341
# all_train_score_W_Combined_a 0.3841030080591392
# test_score_W_combined_n 0.5120862105808147
# test_score_W_combined_a 0.38401808170193114
# Combine Neurons Number :18
# neuron unit number: 18
# all_train_score_W0_n 0.5881729270591779
# all_train_score_W0_a 0.5184133558580288
# test_score_W0_n 0.5517605544082934
# test_score_W0_a  0.44858230560858164
# len  self.all_split_datas 82
# rest_data_true_label len 1475
# len  self.rest_data_predicted_label_dict 1475
# restdata_W0_predicted_label len 1475
# self.rest_data_W0_n 0.00574316852060008
# self.rest_data_W0_a -0.00023311033436882467
# all_train_score_W_Combined_n 0.5881729270591779
# all_train_score_W_Combined_a 0.5184133558580288
# test_score_W_combined_n 0.5697407666456189
# test_score_W_combined_a 0.4671056907592091
# Combine Neurons Number :82
# neuron unit number: 19
# all_train_score_W0_n 0.4912131878450784
# all_train_score_W0_a 0.36226750103774086
# test_score_W0_n 0.5059766646217942
# test_score_W0_a  0.36270270474333743
# len  self.all_split_datas 20
# rest_data_true_label len 1413
# len  self.rest_data_predicted_label_dict 1413
# restdata_W0_predicted_label len 1413
# self.rest_data_W0_n 0.0058057319746630115
# self.rest_data_W0_a -0.00016018983598015512
# all_train_score_W_Combined_n 0.4912131878450784
# all_train_score_W_Combined_a 0.36226750103774086
# test_score_W_combined_n 0.5025240400047816
# test_score_W_combined_a 0.363993028125384
# Not good nmi result !!!!!
# Combine Neurons Number :20
# neuron unit number: 20
# all_train_score_W0_n 0.598684651828126
# all_train_score_W0_a 0.5398004955058403
# test_score_W0_n 0.5729503103067147
# test_score_W0_a  0.49499301118705163
# len  self.all_split_datas 100
# rest_data_true_label len 1476
# len  self.rest_data_predicted_label_dict 1476
# restdata_W0_predicted_label len 1476
# self.rest_data_W0_n 0.005014046047628245
# self.rest_data_W0_a -0.000856990348476505
# all_train_score_W_Combined_n 0.6001280724921026
# all_train_score_W_Combined_a 0.5431390662712398
# test_score_W_combined_n 0.5542348496664464
# test_score_W_combined_a 0.4785025950833471
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :100
# neuron unit number: 21
# all_train_score_W0_n 0.5343722125864424
# all_train_score_W0_a 0.41280867967101514
# test_score_W0_n 0.5221397903223169
# test_score_W0_a  0.3741809668124287
# len  self.all_split_datas 22
# rest_data_true_label len 1465
# len  self.rest_data_predicted_label_dict 1465
# restdata_W0_predicted_label len 1465
# self.rest_data_W0_n 0.006211021141182631
# self.rest_data_W0_a -0.00014722269213955272
# all_train_score_W_Combined_n 0.5343722125864424
# all_train_score_W_Combined_a 0.41280867967101514
# test_score_W_combined_n 0.5267518704788998
# test_score_W_combined_a 0.3848181911195301
# Combine Neurons Number :22
# neuron unit number: 22
# all_train_score_W0_n 0.6145997909101661
# all_train_score_W0_a 0.5499902485618461
# test_score_W0_n 0.5580461756499782
# test_score_W0_a  0.45443605060912695
# len  self.all_split_datas 115
# rest_data_true_label len 1465
# len  self.rest_data_predicted_label_dict 1465
# restdata_W0_predicted_label len 1465
# self.rest_data_W0_n 0.00477253781194187
# self.rest_data_W0_a -0.0010753260847220288
# all_train_score_W_Combined_n 0.6145997909101661
# all_train_score_W_Combined_a 0.5499902485618461
# test_score_W_combined_n 0.5668790145037808
# test_score_W_combined_a 0.46753039784190986
# Combine Neurons Number :115
# neuron unit number: 23
# all_train_score_W0_n 0.47307207448348665
# all_train_score_W0_a 0.3414148395863801
# test_score_W0_n 0.4736340134580854
# test_score_W0_a  0.3329169642910868
# len  self.all_split_datas 24
# rest_data_true_label len 1435
# len  self.rest_data_predicted_label_dict 1435
# restdata_W0_predicted_label len 1435
# self.rest_data_W0_n 0.008356440233403479
# self.rest_data_W0_a -0.0001274141220723847
# all_train_score_W_Combined_n 0.47307207448348665
# all_train_score_W_Combined_a 0.3414148395863801
# test_score_W_combined_n 0.47024330004949594
# test_score_W_combined_a 0.33095726918983576
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :24
# neuron unit number: 24
# all_train_score_W0_n 0.6212018529878413
# all_train_score_W0_a 0.5670222231837417
# test_score_W0_n 0.570555256427877
# test_score_W0_a  0.49067006856537504
# len  self.all_split_datas 118
# rest_data_true_label len 1475
# len  self.rest_data_predicted_label_dict 1475
# restdata_W0_predicted_label len 1475
# self.rest_data_W0_n 0.004584250386093876
# self.rest_data_W0_a -0.0011241987050637197
# all_train_score_W_Combined_n 0.6212018529878413
# all_train_score_W_Combined_a 0.5670222231837417
# test_score_W_combined_n 0.600687351329571
# test_score_W_combined_a 0.5166186593568193
# Combine Neurons Number :118
# neuron unit number: 25
# all_train_score_W0_n 0.48441553565265805
# all_train_score_W0_a 0.34958900911631496
# test_score_W0_n 0.5037087959847809
# test_score_W0_a  0.34689877732019164
# len  self.all_split_datas 25
# rest_data_true_label len 1458
# len  self.rest_data_predicted_label_dict 1458
# restdata_W0_predicted_label len 1458
# self.rest_data_W0_n 0.008734791757884445
# self.rest_data_W0_a 0.0006684630376928985
# all_train_score_W_Combined_n 0.48441553565265805
# all_train_score_W_Combined_a 0.34958900911631496
# test_score_W_combined_n 0.49160941629342625
# test_score_W_combined_a 0.33545913230929064
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :25
# neuron unit number: 26
# all_train_score_W0_n 0.5997920896924428
# all_train_score_W0_a 0.5392329329429406
# test_score_W0_n 0.577006260471015
# test_score_W0_a  0.47494078829349673
# len  self.all_split_datas 121
# rest_data_true_label len 1475
# len  self.rest_data_predicted_label_dict 1475
# restdata_W0_predicted_label len 1475
# self.rest_data_W0_n 0.0072286974772546005
# self.rest_data_W0_a 0.0009357911736497754
# all_train_score_W_Combined_n 0.5997920896924428
# all_train_score_W_Combined_a 0.5392329329429406
# test_score_W_combined_n 0.5829701875713847
# test_score_W_combined_a 0.4955704082486338
# Combine Neurons Number :121
# neuron unit number: 27
# all_train_score_W0_n 0.5125517818377477
# all_train_score_W0_a 0.3996065410982808
# test_score_W0_n 0.5084362941091732
# test_score_W0_a  0.3820476933324551
# len  self.all_split_datas 25
# rest_data_true_label len 1472
# len  self.rest_data_predicted_label_dict 1472
# restdata_W0_predicted_label len 1472
# self.rest_data_W0_n 0.006143120218029622
# self.rest_data_W0_a -0.00019546743012203484
# all_train_score_W_Combined_n 0.5125517818377477
# all_train_score_W_Combined_a 0.3996065410982808
# test_score_W_combined_n 0.5120865606576002
# test_score_W_combined_a 0.39163775855742855
# Combine Neurons Number :25
# neuron unit number: 28
# all_train_score_W0_n 0.6221060540972377
# all_train_score_W0_a 0.5655660840066729
# test_score_W0_n 0.5887886929365324
# test_score_W0_a  0.5114096247217347
# len  self.all_split_datas 160
# rest_data_true_label len 1477
# len  self.rest_data_predicted_label_dict 1477
# restdata_W0_predicted_label len 1477
# self.rest_data_W0_n 0.008709088496289956
# self.rest_data_W0_a 0.0010667145906489226
# all_train_score_W_Combined_n 0.6221060540972377
# all_train_score_W_Combined_a 0.5655660840066729
# test_score_W_combined_n 0.5903749452233795
# test_score_W_combined_a 0.5149549105950332
# Combine Neurons Number :160
# neuron unit number: 29
# all_train_score_W0_n 0.5135982877648669
# all_train_score_W0_a 0.40270737611202556
# test_score_W0_n 0.5120384299610498
# test_score_W0_a  0.37603514021664475
# len  self.all_split_datas 25
# rest_data_true_label len 1476
# len  self.rest_data_predicted_label_dict 1476
# restdata_W0_predicted_label len 1476
# self.rest_data_W0_n 0.004531698484969245
# self.rest_data_W0_a -0.001010022163129968
# all_train_score_W_Combined_n 0.5135982877648669
# all_train_score_W_Combined_a 0.40270737611202556
# test_score_W_combined_n 0.5155083217352471
# test_score_W_combined_a 0.3861072136652921
# Combine Neurons Number :25
# neuron unit number: 30
# all_train_score_W0_n 0.6132462492725774
# all_train_score_W0_a 0.5554356648598664
# test_score_W0_n 0.5758410512808364
# test_score_W0_a  0.4988678657457509
# len  self.all_split_datas 119
# rest_data_true_label len 1463
# len  self.rest_data_predicted_label_dict 1463
# restdata_W0_predicted_label len 1463
# self.rest_data_W0_n 0.006544621899827537
# self.rest_data_W0_a -1.4455408247512803e-05
# all_train_score_W_Combined_n 0.6132462492725774
# all_train_score_W_Combined_a 0.5554356648598664
# test_score_W_combined_n 0.5793047219821239
# test_score_W_combined_a 0.5032003573141274
# Combine Neurons Number :119
# neuron unit number: 31
# all_train_score_W0_n 0.5328410773234484
# all_train_score_W0_a 0.4253421577362598
# test_score_W0_n 0.5194909351102696
# test_score_W0_a  0.38686449114178256
# len  self.all_split_datas 32
# rest_data_true_label len 1470
# len  self.rest_data_predicted_label_dict 1470
# restdata_W0_predicted_label len 1470
# self.rest_data_W0_n 0.008664050392520196
# self.rest_data_W0_a 0.0016748999428253212
# all_train_score_W_Combined_n 0.5333988163915622
# all_train_score_W_Combined_a 0.4256594084852706
# test_score_W_combined_n 0.5127440459432713
# test_score_W_combined_a 0.38091480967495767
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :32
# neuron unit number: 32
# all_train_score_W0_n 0.6418571518470622
# all_train_score_W0_a 0.5984867862827258
# test_score_W0_n 0.5585055665619156
# test_score_W0_a  0.4801193744877416
# len  self.all_split_datas 169
# rest_data_true_label len 1477
# len  self.rest_data_predicted_label_dict 1477
# restdata_W0_predicted_label len 1477
# self.rest_data_W0_n 0.006290741040501937
# self.rest_data_W0_a -0.0001599099808331987
# all_train_score_W_Combined_n 0.6418571518470622
# all_train_score_W_Combined_a 0.5984867862827258
# test_score_W_combined_n 0.5950542232270599
# test_score_W_combined_a 0.5198818276563408
# Combine Neurons Number :169
# neuron unit number: 33
# all_train_score_W0_n 0.5216947127584645
# all_train_score_W0_a 0.39579344078171924
# test_score_W0_n 0.5095819691490363
# test_score_W0_a  0.3700440339331194
# len  self.all_split_datas 29
# rest_data_true_label len 1474
# len  self.rest_data_predicted_label_dict 1474
# restdata_W0_predicted_label len 1474
# self.rest_data_W0_n 0.007058810310597546
# self.rest_data_W0_a 0.00031610242708318063
# all_train_score_W_Combined_n 0.5216947127584645
# all_train_score_W_Combined_a 0.39579344078171924
# test_score_W_combined_n 0.5086674171863335
# test_score_W_combined_a 0.3721440093658891
# Not good nmi result !!!!!
# Combine Neurons Number :29
# neuron unit number: 34
# all_train_score_W0_n 0.6726719122816572
# all_train_score_W0_a 0.6389760399164102
# test_score_W0_n 0.5791727070560115
# test_score_W0_a  0.5158641972467806
# len  self.all_split_datas 196
# rest_data_true_label len 1471
# len  self.rest_data_predicted_label_dict 1471
# restdata_W0_predicted_label len 1471
# self.rest_data_W0_n 0.006358847323351111
# self.rest_data_W0_a 6.878605872028985e-05
# all_train_score_W_Combined_n 0.6726719122816572
# all_train_score_W_Combined_a 0.6389760399164102
# test_score_W_combined_n 0.6094488582243327
# test_score_W_combined_a 0.5496459757440562
# Combine Neurons Number :196
# neuron unit number: 35
# all_train_score_W0_n 0.5418072518396354
# all_train_score_W0_a 0.426659042165067
# test_score_W0_n 0.5281507210857801
# test_score_W0_a  0.39600153638191643
# len  self.all_split_datas 28
# rest_data_true_label len 1473
# len  self.rest_data_predicted_label_dict 1473
# restdata_W0_predicted_label len 1473
# self.rest_data_W0_n 0.006419875237737289
# self.rest_data_W0_a -0.0007905022543431639
# all_train_score_W_Combined_n 0.5418072518396354
# all_train_score_W_Combined_a 0.426659042165067
# test_score_W_combined_n 0.5221657389829982
# test_score_W_combined_a 0.3887035542044222
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :28
# neuron unit number: 36
# all_train_score_W0_n 0.6617630762576273
# all_train_score_W0_a 0.6278759164977804
# test_score_W0_n 0.6077111565911556
# test_score_W0_a  0.5524057675663621
# len  self.all_split_datas 165
# rest_data_true_label len 1476
# len  self.rest_data_predicted_label_dict 1476
# restdata_W0_predicted_label len 1476
# self.rest_data_W0_n 0.006774027454240416
# self.rest_data_W0_a 0.00034942030665260535
# all_train_score_W_Combined_n 0.6617630762576273
# all_train_score_W_Combined_a 0.6278759164977804
# test_score_W_combined_n 0.6281831626380827
# test_score_W_combined_a 0.5700050498202589
# Combine Neurons Number :165
# neuron unit number: 37
# all_train_score_W0_n 0.5022293813697603
# all_train_score_W0_a 0.37177115440492514
# test_score_W0_n 0.49526017506086634
# test_score_W0_a  0.3500221070280531
# len  self.all_split_datas 34
# rest_data_true_label len 1473
# len  self.rest_data_predicted_label_dict 1473
# restdata_W0_predicted_label len 1473
# self.rest_data_W0_n 0.00838013771069403
# self.rest_data_W0_a 0.0013551260867696352
# all_train_score_W_Combined_n 0.5022293813697603
# all_train_score_W_Combined_a 0.37177115440492514
# test_score_W_combined_n 0.49149091018560553
# test_score_W_combined_a 0.34749072203964454
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :34
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.523380  0.040822  0.007332   0.508406  0.538354
# 1  test_score_W'  31.0  0.527893  0.047472  0.008526   0.510480  0.545306
# 2       combined  62.0  0.525636  0.043967  0.005584   0.514471  0.536802
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0045
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -0.4013
# 3                       Two side test p value =    0.6896
# 4                      Difference < 0 p value =    0.3448
# 5                      Difference > 0 p value =    0.6552
# 6                                   Cohen's d =   -0.1019
# 7                                   Hedge's g =   -0.1007
# 8                               Glass's delta =   -0.1105
# 9                                 Pearson's r =    0.0517
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.523380  0.040822  0.007332   0.508406  0.538354
# 1  test_score_W'  31.0  0.406941  0.079661  0.014308   0.377721  0.436160
# 2       combined  62.0  0.465160  0.085940  0.010914   0.443336  0.486985
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.1164
# 1                          Degrees of freedom =   60.0000
# 2                                           t =    7.2427
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    1.0000
# 5                      Difference > 0 p value =    0.0000
# 6                                   Cohen's d =    1.8396
# 7                                   Hedge's g =    1.8166
# 8                               Glass's delta =    2.8523
# 9                                 Pearson's r =    0.6830
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
