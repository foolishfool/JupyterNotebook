# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import experiment
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Obesity/ObesityDataSet_raw_and_data_sinthetic.csv")
#dataread.stringToIntObseityDataSet(csv,"CAEC")
#dataread.stringToIntObseityDataSet(csv,"Gender")
#dataread.stringToIntObseityDataSet(csv,"family_history_with_overweight")
#dataread.stringToIntObseityDataSet(csv,"FAVC")
#dataread.stringToIntObseityDataSet(csv,"SCC")
#dataread.stringToIntObseityDataSet(csv,"SMOKE")
#dataread.stringToIntObseityDataSet(csv,"CALC")
#dataread.stringToIntObseityDataSet(csv,"MTRANS")
dataread.stringToIntObseityDataSet(csv,"NObeyesdad")


csv = csv.drop(columns=['Gender'])
csv = csv.drop(columns=['family_history_with_overweight'])
csv = csv.drop(columns=['FAVC'])
csv = csv.drop(columns=['CAEC'])
csv = csv.drop(columns=['SMOKE'])
csv = csv.drop(columns=['SCC'])
csv = csv.drop(columns=['CALC'])
csv = csv.drop(columns=['MTRANS'])

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"NObeyesdad")

# %%
import experiment
unstable_repeat_num= 30
scope_num = 37
class_num = 7
dim_num = 8
row = 2
column  = 4
best_num = 15
total_label_train = []
elbow_num = 1

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )     



experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# 1478
# neuron unit number: 7
# all_train_score_W0_n 0.18855677957851827
# all_train_score_W0_a 0.10557822631554042
# test_score_W0_n 0.21403842841688653
# test_score_W0_a  0.12697108279198394
# all_train_score_W_Combined_n 0.27114217737156565
# all_train_score_W_Combined_a 0.23025672433849226
# test_score_W_combined_n 0.32790325447812213
# test_score_W_combined_a 0.2761200517905246
# Combine Neurons Number :47
# neuron unit number: 8
# all_train_score_W0_n 0.14613836904239144
# all_train_score_W0_a 0.09771952915399768
# test_score_W0_n 0.16047584560659314
# test_score_W0_a  0.11683175137347103
# all_train_score_W_Combined_n 0.26131153581086236
# all_train_score_W_Combined_a 0.22535294860414362
# test_score_W_combined_n 0.2668799428049968
# test_score_W_combined_a 0.22172835693245288
# Combine Neurons Number :60
# neuron unit number: 9
# all_train_score_W0_n 0.12093852103363065
# all_train_score_W0_a 0.09536629283743252
# test_score_W0_n 0.12692987260928115
# test_score_W0_a  0.09962701169853885
# all_train_score_W_Combined_n 0.25448187606023764
# all_train_score_W_Combined_a 0.20385396946997075
# test_score_W_combined_n 0.2686539125719713
# test_score_W_combined_a 0.22445497576681298
# Combine Neurons Number :35
# neuron unit number: 10
# all_train_score_W0_n 0.27518828475630713
# all_train_score_W0_a 0.24041579512922964
# test_score_W0_n 0.32613588444597214
# test_score_W0_a  0.30280980463443435
# all_train_score_W_Combined_n 0.36660041289795003
# all_train_score_W_Combined_a 0.3323577343767692
# test_score_W_combined_n 0.420745095632568
# test_score_W_combined_a 0.4064075840468467
# Combine Neurons Number :66
# neuron unit number: 11
# all_train_score_W0_n 0.17298644626570914
# all_train_score_W0_a 0.08912841044980066
# test_score_W0_n 0.20670305852514484
# test_score_W0_a  0.12702083478593154
# all_train_score_W_Combined_n 0.295719508460831
# all_train_score_W_Combined_a 0.24377901846836172
# test_score_W_combined_n 0.3273899661589831
# test_score_W_combined_a 0.278757581136435
# Combine Neurons Number :46
# neuron unit number: 12
# all_train_score_W0_n 0.2828322360055295
# all_train_score_W0_a 0.2431179454849545
# test_score_W0_n 0.3070512472143265
# test_score_W0_a  0.28388374080995693
# all_train_score_W_Combined_n 0.41158676916802295
# all_train_score_W_Combined_a 0.36375312540778
# test_score_W_combined_n 0.42675645076116014
# test_score_W_combined_a 0.39852486597515585
# Combine Neurons Number :86
# neuron unit number: 13
# all_train_score_W0_n 0.12069029255860084
# all_train_score_W0_a 0.0572294675917819
# test_score_W0_n 0.1339493720322807
# test_score_W0_a  0.06577400875023207
# all_train_score_W_Combined_n 0.27125880919962747
# all_train_score_W_Combined_a 0.21977448793493204
# test_score_W_combined_n 0.28673282384148047
# test_score_W_combined_a 0.2324953876179812
# Combine Neurons Number :53
# neuron unit number: 14
# all_train_score_W0_n 0.37549032182409053
# all_train_score_W0_a 0.3130118321880598
# test_score_W0_n 0.37989599778906824
# test_score_W0_a  0.32402948004680593
# all_train_score_W_Combined_n 0.41014746404012276
# all_train_score_W_Combined_a 0.3372667641882396
# test_score_W_combined_n 0.4007405179882143
# test_score_W_combined_a 0.34371700121522997
# Combine Neurons Number :104
# neuron unit number: 15
# all_train_score_W0_n 0.2585788218049145
# all_train_score_W0_a 0.1970056463765357
# test_score_W0_n 0.24183470449327024
# test_score_W0_a  0.1955807193178564
# all_train_score_W_Combined_n 0.3445847258485491
# all_train_score_W_Combined_a 0.279639511904041
# test_score_W_combined_n 0.3371103092770024
# test_score_W_combined_a 0.2777689332123782
# Combine Neurons Number :59
# neuron unit number: 16
# all_train_score_W0_n 0.36989033053936765
# all_train_score_W0_a 0.3221930169210794
# test_score_W0_n 0.3685758464595841
# test_score_W0_a  0.3409130827279452
# all_train_score_W_Combined_n 0.4601485418624566
# all_train_score_W_Combined_a 0.4153609670073796
# test_score_W_combined_n 0.47479418452368594
# test_score_W_combined_a 0.4323422647413621
# Combine Neurons Number :128
# neuron unit number: 17
# all_train_score_W0_n 0.21198647387848887
# all_train_score_W0_a 0.15527191952417266
# test_score_W0_n 0.24359838521917912
# test_score_W0_a  0.19024846529184278
# all_train_score_W_Combined_n 0.34733219400849175
# all_train_score_W_Combined_a 0.286397527420967
# test_score_W_combined_n 0.3741753384137461
# test_score_W_combined_a 0.3292233448376786
# Combine Neurons Number :66
# neuron unit number: 18
# all_train_score_W0_n 0.38899039275150094
# all_train_score_W0_a 0.33771120025219475
# test_score_W0_n 0.3967174565505142
# test_score_W0_a  0.35637974780448634
# all_train_score_W_Combined_n 0.4453502069883106
# all_train_score_W_Combined_a 0.39219592574506834
# test_score_W_combined_n 0.44005884472861784
# test_score_W_combined_a 0.38314765050701016
# Combine Neurons Number :148
# neuron unit number: 19
# all_train_score_W0_n 0.2556293585730047
# all_train_score_W0_a 0.19365754710273908
# test_score_W0_n 0.28612279422647013
# test_score_W0_a  0.22619945888089144
# all_train_score_W_Combined_n 0.328906100075598
# all_train_score_W_Combined_a 0.28163698968998624
# test_score_W_combined_n 0.3715614055758502
# test_score_W_combined_a 0.32240746983363455
# Combine Neurons Number :65
# neuron unit number: 20
# all_train_score_W0_n 0.39507121093349284
# all_train_score_W0_a 0.34299969458474666
# test_score_W0_n 0.36920448555323504
# test_score_W0_a  0.3166628271058949
# all_train_score_W_Combined_n 0.49254905693426815
# all_train_score_W_Combined_a 0.44985825128136386
# test_score_W_combined_n 0.5018935858156773
# test_score_W_combined_a 0.45808031906811664
# Combine Neurons Number :167
# neuron unit number: 21
# all_train_score_W0_n 0.2915781022950734
# all_train_score_W0_a 0.21732164686560662
# test_score_W0_n 0.29368669589901814
# test_score_W0_a  0.23884086177083003
# all_train_score_W_Combined_n 0.3836558255875794
# all_train_score_W_Combined_a 0.33332944600202075
# test_score_W_combined_n 0.4135386080684467
# test_score_W_combined_a 0.38103456897142496
# Combine Neurons Number :67
# neuron unit number: 22
# all_train_score_W0_n 0.45688225291009643
# all_train_score_W0_a 0.4082896765665903
# test_score_W0_n 0.39967181361775456
# test_score_W0_a  0.3337101244697925
# all_train_score_W_Combined_n 0.5205438224877972
# all_train_score_W_Combined_a 0.47107328869434106
# test_score_W_combined_n 0.49155134718229937
# test_score_W_combined_a 0.4300283218008607
# Combine Neurons Number :181
# neuron unit number: 23
# all_train_score_W0_n 0.2886605478152104
# all_train_score_W0_a 0.23503376652803273
# test_score_W0_n 0.30471318102477396
# test_score_W0_a  0.25493490550214254
# all_train_score_W_Combined_n 0.37554846950317494
# all_train_score_W_Combined_a 0.33353620923645944
# test_score_W_combined_n 0.3859673804612804
# test_score_W_combined_a 0.35011065855106166
# Combine Neurons Number :72
# neuron unit number: 24
# all_train_score_W0_n 0.486120158341047
# all_train_score_W0_a 0.43903062799331066
# test_score_W0_n 0.486211222860226
# test_score_W0_a  0.43944282486554714
# all_train_score_W_Combined_n 0.5437896196463904
# all_train_score_W_Combined_a 0.5103387987625803
# test_score_W_combined_n 0.5315751730441525
# test_score_W_combined_a 0.49612928013281604
# Combine Neurons Number :209
# neuron unit number: 25
# all_train_score_W0_n 0.2414317504588041
# all_train_score_W0_a 0.1938186462004639
# test_score_W0_n 0.2303293135432531
# test_score_W0_a  0.1877371495906925
# all_train_score_W_Combined_n 0.33075047383290124
# all_train_score_W_Combined_a 0.27047905469293854
# test_score_W_combined_n 0.3314010800309157
# test_score_W_combined_a 0.25391880108097176
# Combine Neurons Number :77
# neuron unit number: 26
# all_train_score_W0_n 0.4886982641789721
# all_train_score_W0_a 0.4474380660811409
# test_score_W0_n 0.4454509661345211
# test_score_W0_a  0.415296651341669
# all_train_score_W_Combined_n 0.5367923923979602
# all_train_score_W_Combined_a 0.49192321981834747
# test_score_W_combined_n 0.5379179500168886
# test_score_W_combined_a 0.4863646941056387
# Combine Neurons Number :232
# neuron unit number: 27
# all_train_score_W0_n 0.3313911600266312
# all_train_score_W0_a 0.26870838318389506
# test_score_W0_n 0.3274774837871648
# test_score_W0_a  0.28854655556813036
# all_train_score_W_Combined_n 0.3787285929412223
# all_train_score_W_Combined_a 0.3337122987726558
# test_score_W_combined_n 0.40128670566027014
# test_score_W_combined_a 0.37835814463767176
# Combine Neurons Number :79
# neuron unit number: 28
# all_train_score_W0_n 0.49303492634257284
# all_train_score_W0_a 0.44437008010473966
# test_score_W0_n 0.4666980421176079
# test_score_W0_a  0.4158521697404968
# all_train_score_W_Combined_n 0.551620508197648
# all_train_score_W_Combined_a 0.5193751625112395
# test_score_W_combined_n 0.5482409315363858
# test_score_W_combined_a 0.5024392574770224
# Combine Neurons Number :254
# neuron unit number: 29
# all_train_score_W0_n 0.366024879290563
# all_train_score_W0_a 0.3103293739991475
# test_score_W0_n 0.35648928587424317
# test_score_W0_a  0.3045866549694958
# all_train_score_W_Combined_n 0.4063936469801895
# all_train_score_W_Combined_a 0.3538440544739596
# test_score_W_combined_n 0.3937054741302078
# test_score_W_combined_a 0.3364201392926273
# Combine Neurons Number :89
# neuron unit number: 30
# all_train_score_W0_n 0.5467272267210922
# all_train_score_W0_a 0.5003789461774732
# test_score_W0_n 0.4982090937757959
# test_score_W0_a  0.4795452140378868
# all_train_score_W_Combined_n 0.5934052634541216
# all_train_score_W_Combined_a 0.5509166663807586
# test_score_W_combined_n 0.5891977273602973
# test_score_W_combined_a 0.5491840547184114
# Combine Neurons Number :272
# neuron unit number: 31
# all_train_score_W0_n 0.32987260697746174
# all_train_score_W0_a 0.2693406820241156
# test_score_W0_n 0.3540580414514018
# test_score_W0_a  0.29513545290666504
# all_train_score_W_Combined_n 0.3643383499789424
# all_train_score_W_Combined_a 0.2982692412208073
# test_score_W_combined_n 0.38099981422437396
# test_score_W_combined_a 0.32073292985413643
# Combine Neurons Number :85
# neuron unit number: 32
# all_train_score_W0_n 0.5698653408365842
# all_train_score_W0_a 0.532643189617956
# test_score_W0_n 0.5285466358125632
# test_score_W0_a  0.48656129111015556
# all_train_score_W_Combined_n 0.6291076428975878
# all_train_score_W_Combined_a 0.5993833352869953
# test_score_W_combined_n 0.5981646352953328
# test_score_W_combined_a 0.5623605847671875
# Combine Neurons Number :305
# neuron unit number: 33
# all_train_score_W0_n 0.2765586168562804
# all_train_score_W0_a 0.22895732220031906
# test_score_W0_n 0.301620784695686
# test_score_W0_a  0.26253003943214565
# all_train_score_W_Combined_n 0.3681596838452744
# all_train_score_W_Combined_a 0.3224448083654848
# test_score_W_combined_n 0.41104740051445765
# test_score_W_combined_a 0.3772862855996647
# Combine Neurons Number :86
# neuron unit number: 34
# all_train_score_W0_n 0.5952491195425913
# all_train_score_W0_a 0.567720652388183
# test_score_W0_n 0.5198526270204282
# test_score_W0_a  0.48446151515788977
# all_train_score_W_Combined_n 0.6467799946540448
# all_train_score_W_Combined_a 0.6223464797296493
# test_score_W_combined_n 0.5943979149761359
# test_score_W_combined_a 0.5554581257686381
# Combine Neurons Number :334
# neuron unit number: 35
# all_train_score_W0_n 0.3323597281067145
# all_train_score_W0_a 0.2790637653294781
# test_score_W0_n 0.3513262685847927
# test_score_W0_a  0.3095561474961606
# all_train_score_W_Combined_n 0.4300348414235321
# all_train_score_W_Combined_a 0.3833819297470669
# test_score_W_combined_n 0.47130081237633004
# test_score_W_combined_a 0.4286073036469902
# Combine Neurons Number :88
# neuron unit number: 36
# all_train_score_W0_n 0.5977780395860275
# all_train_score_W0_a 0.5581337486211082
# test_score_W0_n 0.4963135588501044
# test_score_W0_a  0.46750841953834227
# all_train_score_W_Combined_n 0.6394705757267973
# all_train_score_W_Combined_a 0.6075382591867903
# test_score_W_combined_n 0.6009944638865911
# test_score_W_combined_a 0.5632973652744332
# Combine Neurons Number :355
# neuron unit number: 37
# all_train_score_W0_n 0.33293228851399087
# all_train_score_W0_a 0.28418439085042174
# test_score_W0_n 0.3512163335647039
# test_score_W0_a  0.31101532590043907
# all_train_score_W_Combined_n 0.4177628113748385
# all_train_score_W_Combined_a 0.36239750652272795
# test_score_W_combined_n 0.437670762288215
# test_score_W_combined_a 0.3646176668986493
# Combine Neurons Number :89
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.337842  0.111116  0.019957   0.297084  0.378600
# 1  test_score_W'  31.0  0.430463  0.097591  0.017528   0.394666  0.466260
# 2       combined  62.0  0.384153  0.113737  0.014445   0.355269  0.413036
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0926
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -3.4870
# 3                       Two side test p value =    0.0009
# 4                      Difference < 0 p value =    0.0005
# 5                      Difference > 0 p value =    0.9995
# 6                                   Cohen's d =   -0.8857
# 7                                   Hedge's g =   -0.8746
# 8                               Glass's delta =   -0.8335
# 9                                 Pearson's r =    0.4105
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.337842  0.111116  0.019957   0.297084  0.378600
# 1  test_score_W'  31.0  0.384565  0.102032  0.018325   0.347140  0.421991
# 2       combined  62.0  0.361204  0.108383  0.013765   0.333680  0.388728
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0467
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -1.7245
# 3                       Two side test p value =    0.0898
# 4                      Difference < 0 p value =    0.0449
# 5                      Difference > 0 p value =    0.9551
# 6                                   Cohen's d =   -0.4380
# 7                                   Hedge's g =   -0.4325
# 8                               Glass's delta =   -0.4205
# 9                                 Pearson's r =    0.2173
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 26>()
#      24 print("Best Number SOM Comparision")
#      25 print("*****************************************************************************************")
# ---> 26 experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
#
# File C:\JupyterDoc\SOM\experiment.py:360, in Experiment.UTtest(self, dataread, label_train, class_num, dim_num, best_num, scope_num, unstable_repeat_num, type, elbow_num, row, column)
#     357 else:
#     358     som = newSom.SOM(m= best_num , n= 1, dim=dim_num)
# --> 360 optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,elbow_num)
#     361 optimize_W.run()
#     362 all_train_score_W0_n.append(optimize_W.all_train_score_W0_n)
#
# TypeError: __init__() missing 2 required positional arguments: 'x' and 'y'

# %%
import experiment
unstable_repeat_num= 30
scope_num = 37
class_num = 7
dim_num = 8
row = 2
column  = 4
best_num = 15
total_label_train = []
elbow_num = 1

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# 1478
# all_train_score_W0_n 0.20759410368610243
# all_train_score_W0_a 0.1400682529883114
# test_score_W0_n 0.2086178010444662
# test_score_W0_a  0.13820557747435272
# all_train_score_W_Combined_n 0.330625154038379
# all_train_score_W_Combined_a 0.2737879148798031
# test_score_W_combined_n 0.3037963703150583
# test_score_W_combined_a 0.2320518934151858
# Combine Neurons Number :57
# all_train_score_W0_n 0.2556987021106928
# all_train_score_W0_a 0.19863394648614824
# test_score_W0_n 0.2649431673158834
# test_score_W0_a  0.2027417584873508
# all_train_score_W_Combined_n 0.33672350648077626
# all_train_score_W_Combined_a 0.28868480052421236
# test_score_W_combined_n 0.3229801435967472
# test_score_W_combined_a 0.25536046061855866
# Combine Neurons Number :55
# all_train_score_W0_n 0.2987834293574531
# all_train_score_W0_a 0.2507407363430592
# test_score_W0_n 0.29156324938519756
# test_score_W0_a  0.23262556399587547
# all_train_score_W_Combined_n 0.38325614000523867
# all_train_score_W_Combined_a 0.33356360080133385
# test_score_W_combined_n 0.38077887505693736
# test_score_W_combined_a 0.3167301971833509
# Combine Neurons Number :55
# all_train_score_W0_n 0.2250684343060425
# all_train_score_W0_a 0.1484002238862931
# test_score_W0_n 0.2386261664676359
# test_score_W0_a  0.13593711509057094
# all_train_score_W_Combined_n 0.31343235440225536
# all_train_score_W_Combined_a 0.26210516743968654
# test_score_W_combined_n 0.32681139923817293
# test_score_W_combined_a 0.26968492001914324
# Combine Neurons Number :55
# all_train_score_W0_n 0.2436369294861197
# all_train_score_W0_a 0.18008392388022576
# test_score_W0_n 0.22941569987396224
# test_score_W0_a  0.14243876712107742
# all_train_score_W_Combined_n 0.37066005898286875
# all_train_score_W_Combined_a 0.3395644915008927
# test_score_W_combined_n 0.3543556140718614
# test_score_W_combined_a 0.30545714458153256
# Combine Neurons Number :54
# all_train_score_W0_n 0.23736008672574266
# all_train_score_W0_a 0.17711804623951083
# test_score_W0_n 0.24840769605751514
# test_score_W0_a  0.1665656934154057
# all_train_score_W_Combined_n 0.311957307520324
# all_train_score_W_Combined_a 0.2609315953715755
# test_score_W_combined_n 0.3134673645651239
# test_score_W_combined_a 0.2674094407076918
# Combine Neurons Number :57
# all_train_score_W0_n 0.265773210896564
# all_train_score_W0_a 0.20995601775208156
# test_score_W0_n 0.23361090626082362
# test_score_W0_a  0.19140006831156683
# all_train_score_W_Combined_n 0.3221602475040469
# all_train_score_W_Combined_a 0.28804361667259853
# test_score_W_combined_n 0.27943289870183896
# test_score_W_combined_a 0.22548453439420577
# Combine Neurons Number :55
# all_train_score_W0_n 0.325047267348044
# all_train_score_W0_a 0.26352314121642423
# test_score_W0_n 0.3171489561251013
# test_score_W0_a  0.2475366501688233
# all_train_score_W_Combined_n 0.34564301745006015
# all_train_score_W_Combined_a 0.30244165103185205
# test_score_W_combined_n 0.36665488628791854
# test_score_W_combined_a 0.30389483225720404
# Combine Neurons Number :64
# all_train_score_W0_n 0.3637649784243384
# all_train_score_W0_a 0.2557983509677605
# test_score_W0_n 0.3373053998281708
# test_score_W0_a  0.24345969408278648
# all_train_score_W_Combined_n 0.33872374515838677
# all_train_score_W_Combined_a 0.28974585318250823
# test_score_W_combined_n 0.3336668379973922
# test_score_W_combined_a 0.2745511122187907
# Not good nmi result !!!!!
# Combine Neurons Number :60
# all_train_score_W0_n 0.1796110944450113
# all_train_score_W0_a 0.1461928361937201
# test_score_W0_n 0.18071657615960052
# test_score_W0_a  0.14328815414242663
# all_train_score_W_Combined_n 0.2896243082227986
# all_train_score_W_Combined_a 0.2547916245183552
# test_score_W_combined_n 0.2708400681858659
# test_score_W_combined_a 0.2242385624578545
# Combine Neurons Number :54
# all_train_score_W0_n 0.22074287265105383
# all_train_score_W0_a 0.1831815301927986
# test_score_W0_n 0.22682067227417954
# test_score_W0_a  0.18560398264557984
# all_train_score_W_Combined_n 0.3383829066484658
# all_train_score_W_Combined_a 0.2908415202247886
# test_score_W_combined_n 0.35887120547054013
# test_score_W_combined_a 0.30141848968983276
# Combine Neurons Number :54
# all_train_score_W0_n 0.21689010871156209
# all_train_score_W0_a 0.1705417076853802
# test_score_W0_n 0.2109304849573222
# test_score_W0_a  0.1656341970907507
# all_train_score_W_Combined_n 0.36022815357278726
# all_train_score_W_Combined_a 0.31166361552459815
# test_score_W_combined_n 0.37213272998828556
# test_score_W_combined_a 0.3031931743792731
# Combine Neurons Number :52
# all_train_score_W0_n 0.2847469995187925
# all_train_score_W0_a 0.22213417491456441
# test_score_W0_n 0.27780510223850924
# test_score_W0_a  0.207336939578017
# all_train_score_W_Combined_n 0.3120912329040097
# all_train_score_W_Combined_a 0.24899383012414877
# test_score_W_combined_n 0.3049969156099139
# test_score_W_combined_a 0.2418319050129878
# Combine Neurons Number :60
# all_train_score_W0_n 0.24542018752736025
# all_train_score_W0_a 0.1996026716672334
# test_score_W0_n 0.24140725967974289
# test_score_W0_a  0.1896693597053059
# all_train_score_W_Combined_n 0.29403006209200205
# all_train_score_W_Combined_a 0.2695986944815463
# test_score_W_combined_n 0.28144538541202985
# test_score_W_combined_a 0.24486930805182372
# Combine Neurons Number :65
# all_train_score_W0_n 0.20554740596390056
# all_train_score_W0_a 0.14049024257483608
# test_score_W0_n 0.2126133660314377
# test_score_W0_a  0.13958033384361204
# all_train_score_W_Combined_n 0.2762082935138654
# all_train_score_W_Combined_a 0.2316459838525865
# test_score_W_combined_n 0.25084825255429666
# test_score_W_combined_a 0.20113842210093394
# Combine Neurons Number :61
# all_train_score_W0_n 0.18585122135234178
# all_train_score_W0_a 0.1370197999942962
# test_score_W0_n 0.18368088465689775
# test_score_W0_a  0.12981697480076518
# all_train_score_W_Combined_n 0.3059614961654366
# all_train_score_W_Combined_a 0.28143308811131124
# test_score_W_combined_n 0.2831603344641817
# test_score_W_combined_a 0.24844133886808936
# Combine Neurons Number :57
# all_train_score_W0_n 0.18149298009006828
# all_train_score_W0_a 0.13492190588596437
# test_score_W0_n 0.16188239909106772
# test_score_W0_a  0.11972692167230138
# all_train_score_W_Combined_n 0.31517599308299316
# all_train_score_W_Combined_a 0.26451885144819265
# test_score_W_combined_n 0.29664330173704234
# test_score_W_combined_a 0.23475435546036758
# Combine Neurons Number :59
# all_train_score_W0_n 0.2306230779821914
# all_train_score_W0_a 0.17160886434137643
# test_score_W0_n 0.22346951784285884
# test_score_W0_a  0.17307419636233606
# all_train_score_W_Combined_n 0.35988654584072993
# all_train_score_W_Combined_a 0.3116361005363012
# test_score_W_combined_n 0.3389103033712562
# test_score_W_combined_a 0.28772451589012704
# Combine Neurons Number :62
# all_train_score_W0_n 0.22042241224511655
# all_train_score_W0_a 0.17782639452951957
# test_score_W0_n 0.20944065323036268
# test_score_W0_a  0.147945189212511
# all_train_score_W_Combined_n 0.31895869423846984
# all_train_score_W_Combined_a 0.28833383413039715
# test_score_W_combined_n 0.3050960288594222
# test_score_W_combined_a 0.24222704391971098
# Combine Neurons Number :53
# all_train_score_W0_n 0.19733510337537852
# all_train_score_W0_a 0.13341399763296183
# test_score_W0_n 0.18669670792964507
# test_score_W0_a  0.12577530101323028
# all_train_score_W_Combined_n 0.29878511245975575
# all_train_score_W_Combined_a 0.2359642830592233
# test_score_W_combined_n 0.2860058836810857
# test_score_W_combined_a 0.2125476231426284
# Combine Neurons Number :59
# all_train_score_W0_n 0.2534779573399654
# all_train_score_W0_a 0.20969091805504045
# test_score_W0_n 0.2292550699936861
# test_score_W0_a  0.18636781577486175
# all_train_score_W_Combined_n 0.3516698668812295
# all_train_score_W_Combined_a 0.29421018991679126
# test_score_W_combined_n 0.32933728864587564
# test_score_W_combined_a 0.2543918683444317
# Combine Neurons Number :50
# all_train_score_W0_n 0.25107577316575874
# all_train_score_W0_a 0.19674678748274085
# test_score_W0_n 0.2493208210706691
# test_score_W0_a  0.1825332028845636
# all_train_score_W_Combined_n 0.3390591692764242
# all_train_score_W_Combined_a 0.2875234363592094
# test_score_W_combined_n 0.3184331686342218
# test_score_W_combined_a 0.26970948565878294
# Combine Neurons Number :65
# all_train_score_W0_n 0.3289965086962909
# all_train_score_W0_a 0.276579625864389
# test_score_W0_n 0.3164645197454011
# test_score_W0_a  0.25338715585404825
# all_train_score_W_Combined_n 0.3301999652557547
# all_train_score_W_Combined_a 0.2872388699408082
# test_score_W_combined_n 0.33289665847638034
# test_score_W_combined_a 0.2759667525226155
# Combine Neurons Number :55
# all_train_score_W0_n 0.23832422373979176
# all_train_score_W0_a 0.18722388232445913
# test_score_W0_n 0.2378269595414132
# test_score_W0_a  0.1887404931748896
# all_train_score_W_Combined_n 0.3536990746610636
# all_train_score_W_Combined_a 0.31457336336988806
# test_score_W_combined_n 0.34342900917503155
# test_score_W_combined_a 0.28448275509467214
# Combine Neurons Number :54
# all_train_score_W0_n 0.20237184188963334
# all_train_score_W0_a 0.14372816895005452
# test_score_W0_n 0.21323756634886237
# test_score_W0_a  0.1530449280765002
# all_train_score_W_Combined_n 0.30923185772587863
# all_train_score_W_Combined_a 0.26553679286843274
# test_score_W_combined_n 0.3014748444742843
# test_score_W_combined_a 0.2505408634806115
# Combine Neurons Number :57
# all_train_score_W0_n 0.17058755052355726
# all_train_score_W0_a 0.11708688108203011
# test_score_W0_n 0.15514378636156548
# test_score_W0_a  0.10535052448378458
# all_train_score_W_Combined_n 0.3043761907227475
# all_train_score_W_Combined_a 0.2558925448932915
# test_score_W_combined_n 0.26773591131773794
# test_score_W_combined_a 0.2010005727177444
# Combine Neurons Number :55
# all_train_score_W0_n 0.2495729976224735
# all_train_score_W0_a 0.17096038717858156
# test_score_W0_n 0.23502932713414337
# test_score_W0_a  0.16066614349503044
# all_train_score_W_Combined_n 0.30391075811543633
# all_train_score_W_Combined_a 0.2721052328824223
# test_score_W_combined_n 0.300645027267565
# test_score_W_combined_a 0.26086816936227897
# Combine Neurons Number :57
# all_train_score_W0_n 0.2769680582437812
# all_train_score_W0_a 0.17366016495968445
# test_score_W0_n 0.28710413514348404
# test_score_W0_a  0.1718069887384987
# all_train_score_W_Combined_n 0.3404518525299549
# all_train_score_W_Combined_a 0.2941071390132538
# test_score_W_combined_n 0.303807507417672
# test_score_W_combined_a 0.2374058370688216
# Combine Neurons Number :64
# all_train_score_W0_n 0.23575148767525356
# all_train_score_W0_a 0.16484418623445016
# test_score_W0_n 0.2450094540672466
# test_score_W0_a  0.17520793354017555
# all_train_score_W_Combined_n 0.3155588695120673
# all_train_score_W_Combined_a 0.2733872636239362
# test_score_W_combined_n 0.31769688755932857
# test_score_W_combined_a 0.26505271899103905
# Combine Neurons Number :56
# all_train_score_W0_n 0.23304420088880867
# all_train_score_W0_a 0.18170983813463412
# test_score_W0_n 0.2351984987061013
# test_score_W0_a  0.1683920610103264
# all_train_score_W_Combined_n 0.30167495732941635
# all_train_score_W_Combined_a 0.25854727869016214
# test_score_W_combined_n 0.2892254336179709
# test_score_W_combined_a 0.2391488944219592
# Combine Neurons Number :57
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.236290  0.043864  0.008008   0.219911  0.252669
# 1  test_score_W'  30.0  0.314519  0.032477  0.005930   0.302392  0.326646
# 2       combined  60.0  0.275404  0.054955  0.007095   0.261208  0.289601
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0782
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -7.8507
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -2.0270
# 7                                   Hedge's g =   -2.0007
# 8                               Glass's delta =   -1.7834
# 9                                 Pearson's r =    0.7178
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.236290  0.043864  0.008008   0.219911  0.252669
# 1  test_score_W'  30.0  0.257719  0.031030  0.005665   0.246133  0.269306
# 2       combined  60.0  0.247004  0.039189  0.005059   0.236881  0.257128
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0214
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -2.1845
# 3                       Two side test p value =    0.0330
# 4                      Difference < 0 p value =    0.0165
# 5                      Difference > 0 p value =    0.9835
# 6                                   Cohen's d =   -0.5640
# 7                                   Hedge's g =   -0.5567
# 8                               Glass's delta =   -0.4885
# 9                                 Pearson's r =    0.2757
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
