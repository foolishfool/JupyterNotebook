# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("FrogCall/Frogs_MFCCs.csv")
csv = csv.drop(columns=['Family', 'Genus','RecordID'])
dataread.stringToIntFrogCallDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset_frog(csv_training,csv_test)

# %%
import experiment
unstable_repeate_num= 30
scope_num = 1
class_num = 10
dim_num = 22

experiment = experiment.Experiment()
experiment.UTtest(dataread,class_num, dim_num, scope_num,unstable_repeate_num)
# Out:
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.628257  0.037407  0.006830   0.614289  0.642225
# 1  test_score_W'  30.0  0.648148  0.038026  0.006943   0.633949  0.662348
# 2       combined  60.0  0.638203  0.038719  0.004999   0.628201  0.648205
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0199
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -2.0425
# 3                       Two side test p value =    0.0457
# 4                      Difference < 0 p value =    0.0228
# 5                      Difference > 0 p value =    0.9772
# 6                                   Cohen's d =   -0.5274
# 7                                   Hedge's g =   -0.5205
# 8                               Glass's delta =   -0.5317
# 9                                 Pearson's r =    0.2590
# ARI T-Test
#         Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.78270  0.044162  0.008063   0.766210  0.799190
# 1  test_score_W'  30.0  0.79902  0.043862  0.008008   0.782642  0.815398
# 2       combined  60.0  0.79086  0.044407  0.005733   0.779389  0.802332
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0163
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -1.4361
# 3                       Two side test p value =    0.1563
# 4                      Difference < 0 p value =    0.0782
# 5                      Difference > 0 p value =    0.9218
# 6                                   Cohen's d =   -0.3708
# 7                                   Hedge's g =   -0.3660
# 8                               Glass's delta =   -0.3696
# 9                                 Pearson's r =    0.1853
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeate_num= 30
scope_num = 1
class_num = 10
dim_num = 22

experiment = experiment.Experiment()
experiment.UTtest(dataread,class_num, dim_num, scope_num,unstable_repeate_num)
# Out:
# New Neuron Number : 13
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.637484  0.036300  0.006627   0.623930  0.651039
# 1  test_score_W'  30.0  0.646352  0.038609  0.007049   0.631935  0.660769
# 2       combined  60.0  0.641918  0.037421  0.004831   0.632251  0.651585
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0089
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -0.9165
# 3                       Two side test p value =    0.3632
# 4                      Difference < 0 p value =    0.1816
# 5                      Difference > 0 p value =    0.8184
# 6                                   Cohen's d =   -0.2366
# 7                                   Hedge's g =   -0.2336
# 8                               Glass's delta =   -0.2443
# 9                                 Pearson's r =    0.1195
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.637484  0.036300  0.006627   0.623930  0.651039
# 1  test_score_W'  30.0  0.786455  0.056331  0.010284   0.765421  0.807489
# 2       combined  60.0  0.711970  0.088597  0.011438   0.689083  0.734857
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1490
# 1                          Degrees of freedom =   58.0000
# 2                                           t =  -12.1759
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -3.1438
# 7                                   Hedge's g =   -3.1030
# 8                               Glass's delta =   -4.1039
# 9                                 Pearson's r =    0.8478
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
