# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CarPrice_Assignment.csv",encoding='latin-1')
csv = csv.drop(columns=['car_ID'])

csv_original_encode = csv


# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode,"symboling")

dataread.hash_encoding(csv_original_encode,["CarName","carbody","drivewheel","fueltype","aspiration","doornumber","cylindernumber","enginelocation","enginetype","fuelsystem"])
       
dataread.label_encoding(csv,"CarName")
dataread.label_encoding(csv,"carbody")
dataread.label_encoding(csv,"drivewheel")
dataread.label_encoding(csv,"fueltype")
dataread.label_encoding(csv,"aspiration")
dataread.label_encoding(csv,"doornumber")
dataread.label_encoding(csv,"cylindernumber")
dataread.label_encoding(csv,"enginelocation")
dataread.label_encoding(csv,"enginetype")
dataread.label_encoding(csv,"fuelsystem")    
    
    
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"symboling")
# Out:
# self.data_continuous_indexes ['CarName', 'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'citympg', 'highwaympg', 'price']
# self.continuous_feature_num 14
#  column number self.data_train_discrete 10

# %%
#new binary encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.11734063639751935
# all_train_score_W0_a 0.0738072751490623
# test_score_W0_p0.5081967213114754
# test_score_W0_n 0.23674345275940317
# test_score_W0_a  0.10962962962962963
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.24755033956823888
# all_train_score_W_combine_a 0.21955640130982745
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3706503693646704
# test_score_W_combine_a 0.29162687042343205
# neuron unit number: 10
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.1619755501308435
# all_train_score_W0_a 0.1471976860607409
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.35543993102381277
# test_score_W0_a  0.20251682762657303
# all_train_score_W_combine_p 0.5833333333333334
# all_train_score_W_combine_n 0.2552348108567582
# all_train_score_W_combine_a 0.23262010340861577
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.4148370556143396
# test_score_W_combine_a 0.2728093947606143
# neuron unit number: 15
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.13417010282963157
# all_train_score_W0_a 0.12345432583579033
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.32671001119233606
# test_score_W0_a  0.1854862993074375
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.23416408727110197
# all_train_score_W_combine_a 0.1865039927299445
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.39725445401012277
# test_score_W_combine_a 0.3369890329012961
# neuron unit number: 20
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.16041796042566622
# all_train_score_W0_a 0.1383273733266309
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2885237564428276
# test_score_W0_a  0.17304964539007092
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.25247296112013035
# all_train_score_W_combine_a 0.21395191189583518
# test_score_W_combine_p0.6065573770491803
# test_score_W_combine_n 0.3628092481304593
# test_score_W_combine_a 0.24270639354438237
# neuron unit number: 25
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.14141383006631467
# all_train_score_W0_a 0.11698909007280155
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.36529001107727305
# test_score_W0_a  0.17836713468538742
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.23923465481471085
# all_train_score_W_combine_a 0.18721901318489198
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.4232504634293188
# test_score_W_combine_a 0.32396251673360105
# neuron unit number: 30
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.14150469936467674
# all_train_score_W0_a 0.10558135008292412
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.4061210939015135
# test_score_W0_a  0.2328042328042328
# all_train_score_W_combine_p 0.5833333333333334
# all_train_score_W_combine_n 0.2781039053964531
# all_train_score_W_combine_a 0.21402427947111916
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3683137827172054
# test_score_W_combine_a 0.29155711364300324
# Not good nmi result for discrete features !!!!!
# neuron unit number: 35
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.11559714484912283
# all_train_score_W0_a 0.08737160928266448
# test_score_W0_p0.4426229508196721
# test_score_W0_n 0.24548083378777
# test_score_W0_a  0.0927536231884058
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.22538841800963735
# all_train_score_W_combine_a 0.22512489732522087
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.36773883962439385
# test_score_W_combine_a 0.2957972409367982
# neuron unit number: 40
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.14853311077704728
# all_train_score_W0_a 0.13960088968288256
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3680703990593208
# test_score_W0_a  0.2770034843205575
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.21705878389553385
# all_train_score_W_combine_a 0.1499972526320508
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3602123343321602
# test_score_W_combine_a 0.29333333333333333
# Not good nmi result for discrete features !!!!!
# neuron unit number: 45
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.09982102483450833
# all_train_score_W0_a 0.09526196597172172
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.3202474026947604
# test_score_W0_a  0.17318273964668404
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.2197670177631873
# all_train_score_W_combine_a 0.17029121906599487
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3646567105122451
# test_score_W_combine_a 0.3016028786391887
# neuron unit number: 50
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.1372028579768742
# all_train_score_W0_a 0.10514410809159126
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.34461612278773124
# test_score_W0_a  0.17336907953529937
# all_train_score_W_combine_p 0.5972222222222222
# all_train_score_W_combine_n 0.25694526819100244
# all_train_score_W_combine_a 0.2293692241127658
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.44973771706491944
# test_score_W_combine_a 0.4292682926829268
# neuron unit number: 55
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.1343088482968354
# all_train_score_W0_a 0.1187797001905104
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.3480044205204247
# test_score_W0_a  0.2110009017132552
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.23857806026805697
# all_train_score_W_combine_a 0.20622818074854765
# test_score_W_combine_p0.5901639344262295
# test_score_W_combine_n 0.3458349371721242
# test_score_W_combine_a 0.2599171107164002
# Not good nmi result for discrete features !!!!!
# neuron unit number: 60
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.12040965574553604
# all_train_score_W0_a 0.07945687559865877
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3564772001694466
# test_score_W0_a  0.23739837398373984
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.23838045713472855
# all_train_score_W_combine_a 0.21469758413721332
# test_score_W_combine_p0.6065573770491803
# test_score_W_combine_n 0.3441574636555126
# test_score_W_combine_a 0.2694063926940639
# Not good nmi result for discrete features !!!!!
# neuron unit number: 65
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.120604886442016
# all_train_score_W0_a 0.10356664308445349
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3719610922744229
# test_score_W0_a  0.24343015214384509
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22790130519610857
# all_train_score_W_combine_a 0.1448522052738463
# test_score_W_combine_p0.5737704918032787
# test_score_W_combine_n 0.32758966558749986
# test_score_W_combine_a 0.2328966521106259
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 70
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.17544638051326025
# all_train_score_W0_a 0.14699877536004535
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3535785923271336
# test_score_W0_a  0.22073791348600508
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2575046008557987
# all_train_score_W_combine_a 0.23120684917027798
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.43457330892200524
# test_score_W_combine_a 0.3342601173926475
# neuron unit number: 75
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.1255633847483395
# all_train_score_W0_a 0.10159242998680834
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.34599973929913397
# test_score_W0_a  0.22764227642276422
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2491688749020357
# all_train_score_W_combine_a 0.20111661495092376
# test_score_W_combine_p0.7213114754098361
# test_score_W_combine_n 0.5208745859465186
# test_score_W_combine_a 0.4381669805398619
# neuron unit number: 80
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.13719497080496273
# all_train_score_W0_a 0.1318583902555462
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.3131437340952583
# test_score_W0_a  0.20695504664970313
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.24355108193897498
# all_train_score_W_combine_a 0.22863974224153927
# test_score_W_combine_p0.7049180327868853
# test_score_W_combine_n 0.43119108307389786
# test_score_W_combine_a 0.3961352657004831
# neuron unit number: 85
# all_train_score_W0_p 0.4930555555555556
# all_train_score_W0_n 0.16797639058494332
# all_train_score_W0_a 0.1296690884924983
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2993691553271078
# test_score_W0_a  0.1736930860033727
# all_train_score_W_combine_p 0.6180555555555556
# all_train_score_W_combine_n 0.33719973661416164
# all_train_score_W_combine_a 0.2588020328259523
# test_score_W_combine_p0.5737704918032787
# test_score_W_combine_n 0.37243675259500436
# test_score_W_combine_a 0.24059718633362046
# neuron unit number: 90
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.12484161718393949
# all_train_score_W0_a 0.10062291453479161
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2851737049250627
# test_score_W0_a  0.21542940320232898
# all_train_score_W_combine_p 0.5763888888888888
# all_train_score_W_combine_n 0.253217191798049
# all_train_score_W_combine_a 0.22813511127376382
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.4313127613340965
# test_score_W_combine_a 0.31226765799256506
# neuron unit number: 95
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.12139513482972865
# all_train_score_W0_a 0.09932881556563827
# test_score_W0_p0.5081967213114754
# test_score_W0_n 0.25105147836662783
# test_score_W0_a  0.13536076326774002
# all_train_score_W_combine_p 0.5833333333333334
# all_train_score_W_combine_n 0.26064554940444706
# all_train_score_W_combine_a 0.2038408637291437
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3546977074002648
# test_score_W_combine_a 0.2770475227502528
# neuron unit number: 100
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.168387126639646
# all_train_score_W0_a 0.1172007094809893
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.3244784575629231
# test_score_W0_a  0.1791044776119403
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.259042783969467
# all_train_score_W_combine_a 0.18413937286734083
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.3591300636900594
# test_score_W_combine_a 0.30257844050947497
# test_score_W0_p mean 0.5532786885245903
# test_score_W_combine_p mean 0.6360655737704917
# test_score_W0_n mean 0.3253240294797145
# test_score_W_combine_n mean 0.3900629652088409
# test_score_W0_a mean 0.19244575453094864
# test_score_W_combine_a mean 0.3071463197169285
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.137705  0.020604  0.004607   0.128062  0.147348
# 1  train_W_combine  20.0  0.249555  0.025656  0.005737   0.237548  0.261563
# 2         combined  40.0  0.193630  0.061117  0.009663   0.174084  0.213177
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1119
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -15.2013
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.8071
# 7                                Hedge's g =   -4.7116
# 8                           Glass's delta1 =   -5.4285
# 9                         Point-Biserial r =   -0.9267
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.325324  0.045695  0.010218   0.303938  0.346710
# 1  test_W_combine  20.0  0.390063  0.046975  0.010504   0.368078  0.412048
# 2        combined  40.0  0.357693  0.056275  0.008898   0.339696  0.375691
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0647
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.4179
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.3971
# 7                              Hedge's g =   -1.3693
# 8                         Glass's delta1 =   -1.4168
# 9                       Point-Biserial r =   -0.5825
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.113091  0.021512  0.004810   0.103022  0.123159
# 1  train_W_combine  20.0  0.206516  0.028853  0.006452   0.193012  0.220020
# 2         combined  40.0  0.159803  0.053564  0.008469   0.142673  0.176934
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0934
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -11.6090
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.6711
# 7                                Hedge's g =   -3.5982
# 8                           Glass's delta1 =   -4.3429
# 9                         Point-Biserial r =   -0.8832
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.192446  0.045053  0.010074   0.171360  0.213531
# 1  test_W_combine  20.0  0.307146  0.057410  0.012837   0.280277  0.334015
# 2        combined  40.0  0.249796  0.077253  0.012215   0.225089  0.274503
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1147
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -7.0289
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.2227
# 7                              Hedge's g =   -2.1786
# 8                         Glass's delta1 =   -2.5459
# 9                       Point-Biserial r =   -0.7518
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.475347  0.016165  0.003615   0.467782  0.482913
# 1  train_W_combine  20.0  0.564931  0.020928  0.004680   0.555136  0.574725
# 2         combined  40.0  0.520139  0.048974  0.007743   0.504476  0.535801
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0896
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -15.1503
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.7909
# 7                                Hedge's g =   -4.6958
# 8                           Glass's delta1 =   -5.5418
# 9                         Point-Biserial r =   -0.9263
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.553279  0.040811  0.009126   0.534179  0.572379
# 1  test_W_combine  20.0  0.636066  0.039659  0.008868   0.617504  0.654627
# 2        combined  40.0  0.594672  0.057750  0.009131   0.576203  0.613141
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0828
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.5060
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.0574
# 7                              Hedge's g =   -2.0165
# 8                         Glass's delta1 =   -2.0286
# 9                       Point-Biserial r =   -0.7259

# %%
#hash encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.14683611964559545
# all_train_score_W0_a 0.10848009632681484
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.29611532570846183
# test_score_W0_a  0.21296883550845708
# all_train_score_W_combine_p 0.5069444444444444
# all_train_score_W_combine_n 0.21651041259503842
# all_train_score_W_combine_a 0.16192093057996593
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.3796181729194384
# test_score_W_combine_a 0.3029009271989744
# neuron unit number: 10
# all_train_score_W0_p 0.4236111111111111
# all_train_score_W0_n 0.13275946124281898
# all_train_score_W0_a 0.07903007212779081
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.2799352397517276
# test_score_W0_a  0.2771388158917595
# all_train_score_W_combine_p 0.5138888888888888
# all_train_score_W_combine_n 0.24832466656175997
# all_train_score_W_combine_a 0.14529695899656409
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.34573066181969336
# test_score_W_combine_a 0.26031282718360355
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 15
# all_train_score_W0_p 0.4027777777777778
# all_train_score_W0_n 0.15016417778449548
# all_train_score_W0_a 0.07891573267702318
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.2987936945672216
# test_score_W0_a  0.22863223753068934
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.26297393810875663
# all_train_score_W_combine_a 0.22770316393290654
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.2885760088678689
# test_score_W_combine_a 0.2780089833424394
# Not good nmi result for discrete features !!!!!
# neuron unit number: 20
# all_train_score_W0_p 0.4097222222222222
# all_train_score_W0_n 0.12117483989908133
# all_train_score_W0_a 0.06342219135637588
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.2868279504521559
# test_score_W0_a  0.2958230188324507
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.25476086143226023
# all_train_score_W_combine_a 0.1480337135639463
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.3927030099211423
# test_score_W_combine_a 0.3118779567123411
# neuron unit number: 25
# all_train_score_W0_p 0.4166666666666667
# all_train_score_W0_n 0.1156086875607633
# all_train_score_W0_a 0.0791392191570103
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.371102002294845
# test_score_W0_a  0.3601764015355817
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.23478108489303018
# all_train_score_W_combine_a 0.17171219090269751
# test_score_W_combine_p 0.7213114754098361
# test_score_W_combine_n 0.45811962153919444
# test_score_W_combine_a 0.3755169101733482
# neuron unit number: 30
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.16626559945329142
# all_train_score_W0_a 0.1176889119180146
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.29818115604707274
# test_score_W0_a  0.2984509935845071
# all_train_score_W_combine_p 0.5138888888888888
# all_train_score_W_combine_n 0.22624424943561303
# all_train_score_W_combine_a 0.1652439618251325
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.2985533838485724
# test_score_W_combine_a 0.2562448428474983
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 35
# all_train_score_W0_p 0.3888888888888889
# all_train_score_W0_n 0.1189265030541117
# all_train_score_W0_a 0.049025723657708464
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.20554721152621416
# test_score_W0_a  0.1534674273380862
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.27919087922329694
# all_train_score_W_combine_a 0.18034244453622847
# test_score_W_combine_p 0.7049180327868853
# test_score_W_combine_n 0.41546802261157084
# test_score_W_combine_a 0.30952299693980867
# neuron unit number: 40
# all_train_score_W0_p 0.4097222222222222
# all_train_score_W0_n 0.09951377213356907
# all_train_score_W0_a 0.06720310150669785
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.20882107362933014
# test_score_W0_a  0.18623129919969098
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.28153953279463706
# all_train_score_W_combine_a 0.21112906789968344
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.36263534559436433
# test_score_W_combine_a 0.32469734584907833
# neuron unit number: 45
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.11762015656694326
# all_train_score_W0_a 0.08564529841863629
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.2975006499557543
# test_score_W0_a  0.30339318075760086
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2663864765587688
# all_train_score_W_combine_a 0.21311400212551945
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.32245024711026565
# test_score_W_combine_a 0.27185591713689417
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# all_train_score_W0_p 0.4097222222222222
# all_train_score_W0_n 0.13232317557574064
# all_train_score_W0_a 0.07587188295354125
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.22947622336106555
# test_score_W0_a  0.23458372228015856
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.27812298508941385
# all_train_score_W_combine_a 0.1582283276405459
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.34072493884168037
# test_score_W_combine_a 0.3123654628079407
# neuron unit number: 55
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.16566694931500517
# all_train_score_W0_a 0.1084840420191071
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.27038646857831755
# test_score_W0_a  0.2556394239634391
# all_train_score_W_combine_p 0.5069444444444444
# all_train_score_W_combine_n 0.22829630505450638
# all_train_score_W_combine_a 0.15834202683630919
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.38637091277762375
# test_score_W_combine_a 0.31742371047020246
# neuron unit number: 60
# all_train_score_W0_p 0.4166666666666667
# all_train_score_W0_n 0.129204611625696
# all_train_score_W0_a 0.09062940370510594
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.32638912740693443
# test_score_W0_a  0.2732023910295957
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.27766006568146134
# all_train_score_W_combine_a 0.21838054104143098
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.33265966319829626
# test_score_W_combine_a 0.301154241150886
# neuron unit number: 65
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.1423663794628972
# all_train_score_W0_a 0.11657042279458088
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.2646098246002571
# test_score_W0_a  0.23371814285977033
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.2219394267093543
# all_train_score_W_combine_a 0.16354749326400328
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.250327079305815
# test_score_W_combine_a 0.21871394674205025
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 70
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.14383113116263296
# all_train_score_W0_a 0.09153945396576746
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.2259155884260458
# test_score_W0_a  0.21266060220498056
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.23856212884153194
# all_train_score_W_combine_a 0.16019847793548092
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.2935102573978394
# test_score_W_combine_a 0.2277962433330757
# neuron unit number: 75
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.1506189183758981
# all_train_score_W0_a 0.1083048495894283
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.2777118047622544
# test_score_W0_a  0.25831831925177867
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.232455287598073
# all_train_score_W_combine_a 0.16746892238336658
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.29061450353208207
# test_score_W_combine_a 0.27371856149256685
# neuron unit number: 80
# all_train_score_W0_p 0.3888888888888889
# all_train_score_W0_n 0.12272013244797875
# all_train_score_W0_a 0.04214472234366846
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.24030088326349047
# test_score_W0_a  0.23300802124205364
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.2833508653900817
# all_train_score_W_combine_a 0.18058814157917966
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.2837611261066121
# test_score_W_combine_a 0.23006512541118163
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.11947920537104467
# all_train_score_W0_a 0.08575870198593681
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.285132341667548
# test_score_W0_a  0.3152318267207361
# all_train_score_W_combine_p 0.5
# all_train_score_W_combine_n 0.24507323020650768
# all_train_score_W_combine_a 0.14243233211485573
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.29368403418324057
# test_score_W_combine_a 0.22704875871477972
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 90
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.1401250139695581
# all_train_score_W0_a 0.10140666088480964
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.26042809839768727
# test_score_W0_a  0.2262440733946325
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.2753925090353674
# all_train_score_W_combine_a 0.22360411634984836
# test_score_W_combine_p 0.7049180327868853
# test_score_W_combine_n 0.4007633115357661
# test_score_W_combine_a 0.35132218167581714
# neuron unit number: 95
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.13354441357880098
# all_train_score_W0_a 0.10234483463507286
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.297162162325154
# test_score_W0_a  0.3063088150684343
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.2656970938999768
# all_train_score_W_combine_a 0.15980371775746624
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.33759484407835405
# test_score_W_combine_a 0.2626139998782101
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# all_train_score_W0_p 0.4027777777777778
# all_train_score_W0_n 0.11875099915325041
# all_train_score_W0_a 0.061833901733625345
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.21322517004696787
# test_score_W0_a  0.21373468042360308
# all_train_score_W_combine_p 0.5
# all_train_score_W_combine_n 0.20406055698696746
# all_train_score_W_combine_a 0.13405619837849955
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.2789324349547726
# test_score_W_combine_a 0.1909881085567228
# Not good ari result for discrete features  !!!!!
# test_score_W0_p mean 0.6286885245901639
# test_score_W_combine_p mean 0.6639344262295082
# test_score_W0_n mean 0.27167809983842534
# test_score_W_combine_n mean 0.3376398790072097
# test_score_W0_a mean 0.25394661143090036
# test_score_W_combine_a mean 0.28020745238087097
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.133375  0.017363  0.003883   0.125249  0.141501
# 1  train_W_combine  20.0  0.251066  0.024704  0.005524   0.239504  0.262628
# 2         combined  40.0  0.192221  0.063212  0.009995   0.172004  0.212437
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1177
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -17.4309
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -5.5121
# 7                                Hedge's g =   -5.4026
# 8                           Glass's delta1 =   -6.7782
# 9                         Point-Biserial r =   -0.9428
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.271678  0.042005  0.009393   0.252019  0.291337
# 1  test_W_combine  20.0  0.337640  0.054618  0.012213   0.312078  0.363202
# 2        combined  40.0  0.304659  0.058554  0.009258   0.285933  0.323385
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0660
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.2813
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0001
# 5                 Difference > 0 p value =    0.9999
# 6                              Cohen's d =   -1.3539
# 7                              Hedge's g =   -1.3270
# 8                         Glass's delta1 =   -1.5703
# 9                       Point-Biserial r =   -0.5704
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.085672  0.021749  0.004863   0.075493  0.095851
# 1  train_W_combine  20.0  0.174557  0.028705  0.006419   0.161123  0.187992
# 2         combined  40.0  0.130115  0.051553  0.008151   0.113627  0.146602
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0889
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -11.0375
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.4904
# 7                                Hedge's g =   -3.4210
# 8                           Glass's delta1 =   -4.0868
# 9                         Point-Biserial r =   -0.8731
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.253947  0.049845  0.011146   0.230619  0.277275
# 1  test_W_combine  20.0  0.280207  0.047340  0.010586   0.258052  0.302363
# 2        combined  40.0  0.267077  0.049790  0.007872   0.251153  0.283001
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0263
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -1.7084
# 3                  Two side test p value =    0.0957
# 4                 Difference < 0 p value =    0.0479
# 5                 Difference > 0 p value =    0.9521
# 6                              Cohen's d =   -0.5403
# 7                              Hedge's g =   -0.5295
# 8                         Glass's delta1 =   -0.5269
# 9                       Point-Biserial r =   -0.2671
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.429167  0.025150  0.005624   0.417396  0.440937
# 1  train_W_combine  20.0  0.531944  0.021303  0.004764   0.521974  0.541915
# 2         combined  40.0  0.480556  0.056901  0.008997   0.462358  0.498754
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1028
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -13.9454
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.4099
# 7                                Hedge's g =   -4.3223
# 8                           Glass's delta1 =   -4.0866
# 9                         Point-Biserial r =   -0.9146
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.628689  0.026205  0.005860   0.616424  0.640953
# 1  test_W_combine  20.0  0.663934  0.030784  0.006884   0.649527  0.678342
# 2        combined  40.0  0.646311  0.033388  0.005279   0.635633  0.656990
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0352
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -3.8989
# 3                  Two side test p value =    0.0004
# 4                 Difference < 0 p value =    0.0002
# 5                 Difference > 0 p value =    0.9998
# 6                              Cohen's d =   -1.2329
# 7                              Hedge's g =   -1.2085
# 8                         Glass's delta1 =   -1.3450
# 9                       Point-Biserial r =   -0.5345

# %%
#new baseN encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.1209799329468115
# all_train_score_W0_a 0.09172833605166922
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2920746247460031
# test_score_W0_a  0.15681621640319623
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.24210409710873737
# all_train_score_W_combine_a 0.21023059882829195
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.33679543005899504
# test_score_W_combine_a 0.2547930012724725
# neuron unit number: 10
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.19679146290436592
# all_train_score_W0_a 0.15369078102131034
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.235867944345685
# test_score_W0_a  0.19299564180374956
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.22041481147775424
# all_train_score_W_combine_a 0.16167777278116185
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.4743169054446045
# test_score_W_combine_a 0.33743389332555784
# neuron unit number: 15
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.14184221065658936
# all_train_score_W0_a 0.1316749617719567
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.23230233032628567
# test_score_W0_a  0.14446552213521432
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.24554363808754426
# all_train_score_W_combine_a 0.18083471143105267
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3077314377170929
# test_score_W_combine_a 0.23976988603794097
# neuron unit number: 20
# all_train_score_W0_p 0.5208333333333334
# all_train_score_W0_n 0.203358483068893
# all_train_score_W0_a 0.14026608883738811
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.39033413447374893
# test_score_W0_a  0.2666252535129892
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.25252495606191566
# all_train_score_W_combine_a 0.1916141434975515
# test_score_W_combine_p 0.5901639344262295
# test_score_W_combine_n 0.3395536552224996
# test_score_W_combine_a 0.22144800481887217
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 25
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.1536730636130552
# all_train_score_W0_a 0.12227364556482041
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.3035598589649138
# test_score_W0_a  0.2155181652555996
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.23407419459012838
# all_train_score_W_combine_a 0.1857884022363818
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.395412692750585
# test_score_W_combine_a 0.23706493954218016
# neuron unit number: 30
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.15915456493320487
# all_train_score_W0_a 0.11465378397421232
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3702545792297653
# test_score_W0_a  0.21599289980774247
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2430336932415232
# all_train_score_W_combine_a 0.23272607441400292
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.4688177608990716
# test_score_W_combine_a 0.341790559421363
# neuron unit number: 35
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.12193247899131902
# all_train_score_W0_a 0.09361291108349441
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.29586855571764686
# test_score_W0_a  0.2105825246784576
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.21679816967541407
# all_train_score_W_combine_a 0.15245139283840486
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.4066709491192536
# test_score_W_combine_a 0.27650682064332655
# neuron unit number: 40
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.15465062065021631
# all_train_score_W0_a 0.12213779498794476
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2716469827616749
# test_score_W0_a  0.15664517855704227
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.23295956481996788
# all_train_score_W_combine_a 0.2124727828672029
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.3985864513693066
# test_score_W_combine_a 0.3017088589878263
# neuron unit number: 45
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.17966700568550947
# all_train_score_W0_a 0.15376597597522576
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.3724267048284101
# test_score_W0_a  0.2804902929083984
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.25687501657124523
# all_train_score_W_combine_a 0.202543218248815
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3879103497446215
# test_score_W_combine_a 0.25874226962465047
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 50
# all_train_score_W0_p 0.4930555555555556
# all_train_score_W0_n 0.17624919547680185
# all_train_score_W0_a 0.15109475715431087
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.3111344775063236
# test_score_W0_a  0.2586573615621611
# all_train_score_W_combine_p 0.5
# all_train_score_W_combine_n 0.20770131938659853
# all_train_score_W_combine_a 0.14122495983613545
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3504383806090615
# test_score_W_combine_a 0.27384630971075424
# neuron unit number: 55
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.12066320832643947
# all_train_score_W0_a 0.09069864814691812
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.3116467013670892
# test_score_W0_a  0.15508255856825406
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.24792886408325301
# all_train_score_W_combine_a 0.19168484295341484
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3741869738337142
# test_score_W_combine_a 0.21802088287277915
# neuron unit number: 60
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.14647204455873097
# all_train_score_W0_a 0.1296579659389029
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.24294184581762823
# test_score_W0_a  0.18995236549874478
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.21070922065196473
# all_train_score_W_combine_a 0.17237113346610064
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.40081172341445176
# test_score_W_combine_a 0.31071043316694624
# neuron unit number: 65
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.13837042538886607
# all_train_score_W0_a 0.11236222073734058
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.4043489692541816
# test_score_W0_a  0.3045740013884618
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.24533735085336544
# all_train_score_W_combine_a 0.21156190835489516
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.36882053766315426
# test_score_W_combine_a 0.2487460971342508
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 70
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.16452213174408592
# all_train_score_W0_a 0.12743678642265568
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.36486044652703725
# test_score_W0_a  0.23364288942767983
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.24316852332869443
# all_train_score_W_combine_a 0.182116539230181
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.34107335104264686
# test_score_W_combine_a 0.24290980493859177
# Not good nmi result for discrete features !!!!!
# neuron unit number: 75
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.14719491281736408
# all_train_score_W0_a 0.13200786240439108
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.39165986613816545
# test_score_W0_a  0.26097656894211374
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.26858858690130494
# all_train_score_W_combine_a 0.2168942277092303
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.37227491810128716
# test_score_W_combine_a 0.2661091518146755
# Not good nmi result for discrete features !!!!!
# neuron unit number: 80
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.173344167235323
# all_train_score_W0_a 0.12647637129502154
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.3698213561710899
# test_score_W0_a  0.2624273467594734
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.22689152075818117
# all_train_score_W_combine_a 0.18731657203652463
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3648289946005437
# test_score_W_combine_a 0.28458307237542835
# Not good nmi result for discrete features !!!!!
# neuron unit number: 85
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.16138893236037796
# all_train_score_W0_a 0.11647153128065221
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.3232381392917592
# test_score_W0_a  0.20315757559878278
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.2377453686756551
# all_train_score_W_combine_a 0.17682240290003354
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3963922501364001
# test_score_W_combine_a 0.3003765025055328
# neuron unit number: 90
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.16886608014705715
# all_train_score_W0_a 0.14423740957423783
# test_score_W0_p0.6721311475409836
# test_score_W0_n 0.4223249023749009
# test_score_W0_a  0.331315999165655
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.26051903557950534
# all_train_score_W_combine_a 0.2198836527353703
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.39571519194801025
# test_score_W_combine_a 0.3022341084503858
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 95
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.18084157807720333
# all_train_score_W0_a 0.13101200300000862
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.23365081013660896
# test_score_W0_a  0.13264541503551078
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.25222356249280276
# all_train_score_W_combine_a 0.22088166806985027
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.4317498720908933
# test_score_W_combine_a 0.3860751442905128
# neuron unit number: 100
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.17052545886089687
# all_train_score_W0_a 0.10556715972547849
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2844005252176133
# test_score_W0_a  0.1327506524468241
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.24291774516305872
# all_train_score_W_combine_a 0.1649273576232482
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.31423536881013364
# test_score_W_combine_a 0.22126969210719954
# test_score_W0_p mean 0.5819672131147542
# test_score_W_combine_p mean 0.6352459016393444
# test_score_W0_n mean 0.3212181877598266
# test_score_W_combine_n mean 0.3813161597288164
# test_score_W0_a mean 0.21526572147280257
# test_score_W_combine_a mean 0.27620697165206237
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.159024  0.023421  0.005237   0.148063  0.169986
# 1  train_W_combine  20.0  0.239403  0.016321  0.003650   0.231764  0.247041
# 2         combined  40.0  0.199214  0.045317  0.007165   0.184721  0.213707
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0804
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -12.5920
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.9819
# 7                                Hedge's g =   -3.9028
# 8                           Glass's delta1 =   -3.4319
# 9                         Point-Biserial r =   -0.8981
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.321218  0.061115  0.013666   0.292615  0.349821
# 1  test_W_combine  20.0  0.381316  0.044498  0.009950   0.360490  0.402142
# 2        combined  40.0  0.351267  0.060913  0.009631   0.331786  0.370748
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0601
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -3.5552
# 3                  Two side test p value =    0.0010
# 4                 Difference < 0 p value =    0.0005
# 5                 Difference > 0 p value =    0.9995
# 6                              Cohen's d =   -1.1242
# 7                              Hedge's g =   -1.1019
# 8                         Glass's delta1 =   -0.9834
# 9                       Point-Biserial r =   -0.4996
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.124541  0.019319  0.004320   0.115500  0.133583
# 1  train_W_combine  20.0  0.190801  0.024921  0.005572   0.179138  0.202465
# 2         combined  40.0  0.157671  0.040126  0.006345   0.144838  0.170504
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0663
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -9.3974
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.9717
# 7                                Hedge's g =   -2.9127
# 8                           Glass's delta1 =   -3.4297
# 9                         Point-Biserial r =   -0.8362
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.215266  0.058624  0.013109   0.187829  0.242702
# 1  test_W_combine  20.0  0.276207  0.044891  0.010038   0.255197  0.297217
# 2        combined  40.0  0.245736  0.060070  0.009498   0.226525  0.264948
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0609
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -3.6910
# 3                  Two side test p value =    0.0007
# 4                 Difference < 0 p value =    0.0003
# 5                 Difference > 0 p value =    0.9997
# 6                              Cohen's d =   -1.1672
# 7                              Hedge's g =   -1.1440
# 8                         Glass's delta1 =   -1.0395
# 9                       Point-Biserial r =   -0.5137
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.485069  0.021169  0.004733   0.475162  0.494977
# 1  train_W_combine  20.0  0.535069  0.016321  0.003650   0.527431  0.542708
# 2         combined  40.0  0.510069  0.031450  0.004973   0.500011  0.520128
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0500
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -8.3654
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.6454
# 7                                Hedge's g =   -2.5928
# 8                           Glass's delta1 =   -2.3620
# 9                         Point-Biserial r =   -0.8050
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.581967  0.040681  0.009096   0.562928  0.601006
# 1  test_W_combine  20.0  0.635246  0.024301  0.005434   0.623873  0.646619
# 2        combined  40.0  0.608607  0.042682  0.006749   0.594956  0.622257
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0533
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -5.0283
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.5901
# 7                              Hedge's g =   -1.5585
# 8                         Glass's delta1 =   -1.3097
# 9                       Point-Biserial r =   -0.6321

# %%
#new effect  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.10450488790450507
# all_train_score_W0_a 0.0937946017023323
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.26759067290389627
# test_score_W0_a  0.19869077169782307
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.1934805428736902
# all_train_score_W_combine_a 0.1541484569289863
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.46786976379855544
# test_score_W_combine_a 0.3651943337870633
# neuron unit number: 10
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.14571890653069372
# all_train_score_W0_a 0.08302759301276323
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2196517973720137
# test_score_W0_a  0.16949353485365937
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22793316554154208
# all_train_score_W_combine_a 0.16956916853600776
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.42097392326298655
# test_score_W_combine_a 0.2776682925578075
# neuron unit number: 15
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.16282071338462098
# all_train_score_W0_a 0.0933361880359146
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.2569733403500455
# test_score_W0_a  0.2046528131051671
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.23574013949139908
# all_train_score_W_combine_a 0.22840868561587852
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.43942617712759674
# test_score_W_combine_a 0.32740079648198833
# neuron unit number: 20
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.13532573469570275
# all_train_score_W0_a 0.11950123206832902
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.27840383340088665
# test_score_W0_a  0.19884555369369294
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.23183150033204625
# all_train_score_W_combine_a 0.23258705970550636
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.4367332112529685
# test_score_W_combine_a 0.368453645155516
# neuron unit number: 25
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.11304015957432245
# all_train_score_W0_a 0.08506758160290526
# test_score_W0_p0.5081967213114754
# test_score_W0_n 0.20477731018030326
# test_score_W0_a  0.16080470606302336
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.19251374796017587
# all_train_score_W_combine_a 0.14925535984547314
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3797154201944915
# test_score_W_combine_a 0.31022520959945216
# neuron unit number: 30
# all_train_score_W0_p 0.4236111111111111
# all_train_score_W0_n 0.06848638313061127
# all_train_score_W0_a 0.05155104203236301
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.29278077352299614
# test_score_W0_a  0.2345399871982022
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.2179840335010565
# all_train_score_W_combine_a 0.19435062081118984
# test_score_W_combine_p 0.5573770491803278
# test_score_W_combine_n 0.28322562443772664
# test_score_W_combine_a 0.1724859250463412
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 35
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.11775796888068896
# all_train_score_W0_a 0.0790846681878509
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.32161920571787217
# test_score_W0_a  0.27912181927382873
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.21880731179682658
# all_train_score_W_combine_a 0.16388950031364838
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.4385075568514192
# test_score_W_combine_a 0.32437262541975737
# neuron unit number: 40
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.13927166454094445
# all_train_score_W0_a 0.0984982381882357
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.3486474942156644
# test_score_W0_a  0.23295794763524752
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2473643685073564
# all_train_score_W_combine_a 0.2143693763303125
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3388947682702107
# test_score_W_combine_a 0.2244581980765577
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.11727293090472835
# all_train_score_W0_a 0.08383391375291568
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.22760845967052715
# test_score_W0_a  0.20654960021423927
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.20372577234785913
# all_train_score_W_combine_a 0.1666634987033979
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.42403401771985794
# test_score_W_combine_a 0.3689211448781648
# neuron unit number: 50
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.1264173791153907
# all_train_score_W0_a 0.06188337384423721
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.2698109106333138
# test_score_W0_a  0.2105414784840198
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22807406026144142
# all_train_score_W_combine_a 0.17513531100333657
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.44310370418799705
# test_score_W_combine_a 0.3168502207405293
# neuron unit number: 55
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.11754904227529028
# all_train_score_W0_a 0.06958295047492
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.2682179031539712
# test_score_W0_a  0.23363788512406547
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.20480778664244206
# all_train_score_W_combine_a 0.19364556018537935
# test_score_W_combine_p 0.5901639344262295
# test_score_W_combine_n 0.3949190663105233
# test_score_W_combine_a 0.29734717510772113
# neuron unit number: 60
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.11846260144807154
# all_train_score_W0_a 0.07174868524101767
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2281936665025822
# test_score_W0_a  0.19733705069244498
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22886610433194268
# all_train_score_W_combine_a 0.18142771038690106
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.4328263344246329
# test_score_W_combine_a 0.35003676333138095
# neuron unit number: 65
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.13189460470875414
# all_train_score_W0_a 0.09286703144601197
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.2875557787070352
# test_score_W0_a  0.20405069964633263
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22471416976826075
# all_train_score_W_combine_a 0.1761344953140143
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.38099655242003555
# test_score_W_combine_a 0.26928172632879993
# neuron unit number: 70
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.11653083243177446
# all_train_score_W0_a 0.09798569267331944
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.30519378818616993
# test_score_W0_a  0.18365412174526535
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.24955332098748906
# all_train_score_W_combine_a 0.2207186199898067
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.4353002084460506
# test_score_W_combine_a 0.3303372328381763
# neuron unit number: 75
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.15300955673665426
# all_train_score_W0_a 0.11010046712131173
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.3777782867533043
# test_score_W0_a  0.2910330686252414
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.24825316636185685
# all_train_score_W_combine_a 0.1866981456434455
# test_score_W_combine_p 0.7049180327868853
# test_score_W_combine_n 0.4885419672179907
# test_score_W_combine_a 0.38985816878484914
# neuron unit number: 80
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.16040453471040228
# all_train_score_W0_a 0.13151187802044495
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.28887649854074654
# test_score_W0_a  0.18957757171519982
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2406994141747675
# all_train_score_W_combine_a 0.18801615062569396
# test_score_W_combine_p 0.7049180327868853
# test_score_W_combine_n 0.4580083275493874
# test_score_W_combine_a 0.33940286854797075
# neuron unit number: 85
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.12524569203000974
# all_train_score_W0_a 0.10626670776448861
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.3529912613320473
# test_score_W0_a  0.2939588270617411
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.2732069338187268
# all_train_score_W_combine_a 0.17786548320275364
# test_score_W_combine_p 0.6885245901639344
# test_score_W_combine_n 0.4831426948455648
# test_score_W_combine_a 0.3638232752565778
# neuron unit number: 90
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.13539850471511836
# all_train_score_W0_a 0.08477686214459906
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2795263056626021
# test_score_W0_a  0.18487289150998956
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2527959974749504
# all_train_score_W_combine_a 0.15404142574775395
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3859301290597238
# test_score_W_combine_a 0.28497761831095164
# neuron unit number: 95
# all_train_score_W0_p 0.4166666666666667
# all_train_score_W0_n 0.09288326094316227
# all_train_score_W0_a 0.04202853872347458
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.21286443081878467
# test_score_W0_a  0.1915182982633331
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.19004493998013214
# all_train_score_W_combine_a 0.18380100656724524
# test_score_W_combine_p 0.7049180327868853
# test_score_W_combine_n 0.46315187914689504
# test_score_W_combine_a 0.36194448261037215
# neuron unit number: 100
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.1253234212731145
# all_train_score_W0_a 0.0905779696776847
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.35667395845581157
# test_score_W0_a  0.31285014410555095
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.22076689847197284
# all_train_score_W_combine_a 0.20951418285982676
# test_score_W_combine_p 0.7049180327868853
# test_score_W_combine_n 0.4949744560238702
# test_score_W_combine_a 0.34677061886633
# test_score_W0_p mean 0.5704918032786885
# test_score_W_combine_p mean 0.659016393442623
# test_score_W0_n mean 0.2822867838040287
# test_score_W_combine_n mean 0.42451378912742416
# test_score_W0_a mean 0.21893443853540337
# test_score_W_combine_a mean 0.3194905160863154
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.125366  0.022282  0.004983   0.114937  0.135794
# 1  train_W_combine  20.0  0.226558  0.022207  0.004966   0.216165  0.236951
# 2         combined  40.0  0.175962  0.055747  0.008814   0.158133  0.193791
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1012
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -14.3853
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.5490
# 7                                Hedge's g =   -4.4587
# 8                           Glass's delta1 =   -4.5413
# 9                         Point-Biserial r =   -0.9192
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.282287  0.050371  0.011263   0.258713  0.305861
# 1  test_W_combine  20.0  0.424514  0.052146  0.011660   0.400109  0.448919
# 2        combined  40.0  0.353400  0.088021  0.013917   0.325250  0.381551
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1422
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -8.7730
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.7743
# 7                              Hedge's g =   -2.7192
# 8                         Glass's delta1 =   -2.8236
# 9                       Point-Biserial r =   -0.8182
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.087351  0.021606  0.004831   0.077239  0.097463
# 1  train_W_combine  20.0  0.186012  0.024592  0.005499   0.174502  0.197522
# 2         combined  40.0  0.136682  0.054936  0.008686   0.119112  0.154251
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0987
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -13.4786
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.2623
# 7                                Hedge's g =   -4.1776
# 8                           Glass's delta1 =   -4.5664
# 9                         Point-Biserial r =   -0.9094
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.218934  0.043345  0.009692   0.198648  0.239220
# 1  test_W_combine  20.0  0.319491  0.053613  0.011988   0.294399  0.344582
# 2        combined  40.0  0.269212  0.070059  0.011077   0.246806  0.291619
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1006
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.5228
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.0627
# 7                              Hedge's g =   -2.0217
# 8                         Glass's delta1 =   -2.3199
# 9                       Point-Biserial r =   -0.7268
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.456944  0.018931  0.004233   0.448084  0.465805
# 1  train_W_combine  20.0  0.545139  0.012443  0.002782   0.539315  0.550962
# 2         combined  40.0  0.501042  0.047376  0.007491   0.485890  0.516193
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0882
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -17.4102
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -5.5056
# 7                                Hedge's g =   -5.3962
# 8                           Glass's delta1 =   -4.6587
# 9                         Point-Biserial r =   -0.9427
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.570492  0.034305  0.007671   0.554437  0.586547
# 1  test_W_combine  20.0  0.659016  0.040715  0.009104   0.639961  0.678072
# 2        combined  40.0  0.614754  0.058226  0.009206   0.596132  0.633376
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0885
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -7.4360
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.3515
# 7                              Hedge's g =   -2.3047
# 8                         Glass's delta1 =   -2.5805
# 9                       Point-Biserial r =   -0.7699

# %%
#onehot endoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.0758198142734775
# all_train_score_W0_a 0.07588255039951686
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.2621597728367865
# test_score_W0_a  0.14740907931890943
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.2441396949105848
# all_train_score_W_combine_a 0.22211803766460458
# test_score_W_combine_p 0.5901639344262295
# test_score_W_combine_n 0.311187931369034
# test_score_W_combine_a 0.22963182684356237
# neuron unit number: 10
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.09747192197483055
# all_train_score_W0_a 0.09273726633571658
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.33628089469294004
# test_score_W0_a  0.2521985524055613
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.24671553112448263
# all_train_score_W_combine_a 0.21038726357769247
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.39539270928959575
# test_score_W_combine_a 0.32154241849472187
# neuron unit number: 15
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.08979703411138756
# all_train_score_W0_a 0.10788353615761483
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.3284357637341253
# test_score_W0_a  0.16642771375831109
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.2593805347395053
# all_train_score_W_combine_a 0.1903488542394826
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.4391623466197104
# test_score_W_combine_a 0.3344105030661864
# neuron unit number: 20
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.0740405141156608
# all_train_score_W0_a 0.08060765633844044
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.279992664111942
# test_score_W0_a  0.1506584226176429
# all_train_score_W_combine_p 0.6041666666666666
# all_train_score_W_combine_n 0.27056751259463246
# all_train_score_W_combine_a 0.26607349147267567
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.377900273490426
# test_score_W_combine_a 0.2575469450116107
# neuron unit number: 25
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.052181680351606786
# all_train_score_W0_a 0.05546440566892142
# test_score_W0_p0.47540983606557374
# test_score_W0_n 0.1656340355842895
# test_score_W0_a  0.07347786576658445
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.23076659437710878
# all_train_score_W_combine_a 0.2141100330197089
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3269720009948043
# test_score_W_combine_a 0.23649649815474383
# neuron unit number: 30
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.13137248899098375
# all_train_score_W0_a 0.07711898654992701
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.3229533555593341
# test_score_W0_a  0.1597105144125992
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2834475111711137
# all_train_score_W_combine_a 0.182090719759864
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.36448481146170664
# test_score_W_combine_a 0.2960184650894403
# neuron unit number: 35
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.0932460591197031
# all_train_score_W0_a 0.07003665496388635
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3274718500972134
# test_score_W0_a  0.2219607473996329
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.23855071632110625
# all_train_score_W_combine_a 0.16437425859824858
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.40944293945352905
# test_score_W_combine_a 0.30404940723163737
# neuron unit number: 40
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.09324702963393701
# all_train_score_W0_a 0.0706642087189958
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.2713889320983595
# test_score_W0_a  0.19477597385608478
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.20761923374159127
# all_train_score_W_combine_a 0.11764634137259988
# test_score_W_combine_p 0.6721311475409836
# test_score_W_combine_n 0.42120244203649143
# test_score_W_combine_a 0.36735117195602573
# neuron unit number: 45
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.13593667710569132
# all_train_score_W0_a 0.13367180392484418
# test_score_W0_p0.5081967213114754
# test_score_W0_n 0.17253133315263602
# test_score_W0_a  0.09333959155875829
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.27254754133111614
# all_train_score_W_combine_a 0.1572576477765961
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3456146770306953
# test_score_W_combine_a 0.2620584196415547
# neuron unit number: 50
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.12159380510977233
# all_train_score_W0_a 0.10647909783367321
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3271454386419111
# test_score_W0_a  0.21288391718182711
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2704708646560058
# all_train_score_W_combine_a 0.22772355530860844
# test_score_W_combine_p 0.6229508196721312
# test_score_W_combine_n 0.3609044362916379
# test_score_W_combine_a 0.27071045667985955
# neuron unit number: 55
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.1431972870722263
# all_train_score_W0_a 0.12917637917637917
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.2314004078240758
# test_score_W0_a  0.16844282084172638
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2626444247034606
# all_train_score_W_combine_a 0.18679459863295228
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.375876070930881
# test_score_W_combine_a 0.25899396884276327
# neuron unit number: 60
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.14280294508061006
# all_train_score_W0_a 0.12469592233472969
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.27514552065861303
# test_score_W0_a  0.20237664855931528
# all_train_score_W_combine_p 0.5763888888888888
# all_train_score_W_combine_n 0.2778404421303253
# all_train_score_W_combine_a 0.1992495069095211
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.35865793226050596
# test_score_W_combine_a 0.2560646900269542
# neuron unit number: 65
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.0882859321604088
# all_train_score_W0_a 0.09659901518897424
# test_score_W0_p0.6721311475409836
# test_score_W0_n 0.3654308892710557
# test_score_W0_a  0.3057627774581044
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2876630771687978
# all_train_score_W_combine_a 0.20646504823417353
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.37028623956546713
# test_score_W_combine_a 0.3141610901899163
# Not good purity result for discrete features  !!!!!
# neuron unit number: 70
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.10661409092831024
# all_train_score_W0_a 0.08667285021380597
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.26561987206037174
# test_score_W0_a  0.15482560928469302
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.23305316624213396
# all_train_score_W_combine_a 0.19481213579841997
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3054694287075921
# test_score_W_combine_a 0.2510792578606317
# neuron unit number: 75
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.13172094430805745
# all_train_score_W0_a 0.07473425246224095
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.26435482141608835
# test_score_W0_a  0.10614803926905837
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.23512093473089013
# all_train_score_W_combine_a 0.1778013365832926
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.3911406901572761
# test_score_W_combine_a 0.3021391773419401
# neuron unit number: 80
# all_train_score_W0_p 0.4444444444444444
# all_train_score_W0_n 0.07490046579011554
# all_train_score_W0_a 0.08001174343142631
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.28684310706484206
# test_score_W0_a  0.2165425122013871
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.23921115796074247
# all_train_score_W_combine_a 0.21214426789929805
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.3585485770034319
# test_score_W_combine_a 0.30079106990474874
# neuron unit number: 85
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.13244786810517273
# all_train_score_W0_a 0.1489592793567461
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.2422228873495839
# test_score_W0_a  0.13462724618610963
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.22152981666552962
# all_train_score_W_combine_a 0.19266740585586978
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.3425115164180801
# test_score_W_combine_a 0.2602067403806979
# neuron unit number: 90
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.06766716716960161
# all_train_score_W0_a 0.0667553241942925
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.26560765026494526
# test_score_W0_a  0.19953685835584717
# all_train_score_W_combine_p 0.5972222222222222
# all_train_score_W_combine_n 0.30486351752569835
# all_train_score_W_combine_a 0.2504322722905237
# test_score_W_combine_p 0.639344262295082
# test_score_W_combine_n 0.38837849073243824
# test_score_W_combine_a 0.28855030026304035
# neuron unit number: 95
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.0786851783596794
# all_train_score_W0_a 0.07936059989114878
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.3189298456116691
# test_score_W0_a  0.24618635357557736
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2458503232681257
# all_train_score_W_combine_a 0.1694167853659422
# test_score_W_combine_p 0.6557377049180327
# test_score_W_combine_n 0.3628144117146894
# test_score_W_combine_a 0.3038644541999135
# neuron unit number: 100
# all_train_score_W0_p 0.4305555555555556
# all_train_score_W0_n 0.05424657203257496
# all_train_score_W0_a 0.06872775534211024
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.25680091793662296
# test_score_W0_a  0.1612794287919722
# all_train_score_W_combine_p 0.5902777777777778
# all_train_score_W_combine_n 0.28180088616984567
# all_train_score_W_combine_a 0.22940179911453287
# test_score_W_combine_p 0.6065573770491803
# test_score_W_combine_n 0.34336424035573193
# test_score_W_combine_a 0.22170459452739574
# test_score_W0_p mean 0.569672131147541
# test_score_W_combine_p mean 0.6278688524590164
# test_score_W0_n mean 0.27831749799837024
# test_score_W_combine_n mean 0.3674656082941862
# test_score_W0_a mean 0.17842853363998512
# test_score_W_combine_a mean 0.28186857278536726
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.099264  0.029593  0.006617   0.085414  0.113114
# 1  train_W_combine  20.0  0.255689  0.025215  0.005638   0.243888  0.267490
# 2         combined  40.0  0.177476  0.083728  0.013239   0.150699  0.204254
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1564
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -17.9935
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -5.6900
# 7                                Hedge's g =   -5.5770
# 8                           Glass's delta1 =   -5.2859
# 9                         Point-Biserial r =   -0.9460
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.278317  0.051641  0.011547   0.254149  0.302486
# 1  test_W_combine  20.0  0.367466  0.034273  0.007664   0.351426  0.383506
# 2        combined  40.0  0.322892  0.062524  0.009886   0.302895  0.342888
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0891
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.4325
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.0341
# 7                              Hedge's g =   -1.9937
# 8                         Glass's delta1 =   -1.7263
# 9                       Point-Biserial r =   -0.7220
# ARI T-Test
#           Variable     N      Mean       SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.091312  0.02575  0.005758   0.079260  0.103363
# 1  train_W_combine  20.0  0.198566  0.03361  0.007515   0.182836  0.214295
# 2         combined  40.0  0.144939  0.06183  0.009776   0.125165  0.164713
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1073
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -11.3286
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.5824
# 7                                Hedge's g =   -3.5112
# 8                           Glass's delta1 =   -4.1651
# 9                         Point-Biserial r =   -0.8784
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.178429  0.056496  0.012633   0.151987  0.204870
# 1  test_W_combine  20.0  0.281869  0.037554  0.008397   0.264293  0.299445
# 2        combined  40.0  0.230149  0.070609  0.011164   0.207567  0.252730
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1034
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.8190
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.1564
# 7                              Hedge's g =   -2.1135
# 8                         Glass's delta1 =   -1.8309
# 9                       Point-Biserial r =   -0.7418
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.462847  0.022562  0.005045   0.452288  0.473406
# 1  train_W_combine  20.0  0.564931  0.018617  0.004163   0.556218  0.573644
# 2         combined  40.0  0.513889  0.055578  0.008788   0.496114  0.531664
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1021
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -15.6074
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.9355
# 7                                Hedge's g =   -4.8374
# 8                           Glass's delta1 =   -4.5246
# 9                         Point-Biserial r =   -0.9301
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.569672  0.045092  0.010083   0.548569  0.590776
# 1  test_W_combine  20.0  0.627869  0.022628  0.005060   0.617279  0.638459
# 2        combined  40.0  0.598770  0.045918  0.007260   0.584085  0.613456
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0582
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -5.1587
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.6313
# 7                              Hedge's g =   -1.5989
# 8                         Glass's delta1 =   -1.2906
# 9                       Point-Biserial r =   -0.6418
