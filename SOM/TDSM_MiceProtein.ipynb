# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("MiceProtein/Data_Cortex_Nuclear.csv")
csv = csv.drop(columns=['MouseID'])
dataread.replaceNANinDataset(csv)

dataread.stringToIntMiceProteinDataSet(csv,"Genotype")
dataread.stringToIntMiceProteinDataSet(csv,"Treatment")
dataread.stringToIntMiceProteinDataSet(csv,"class")
dataread.stringToIntMiceProteinDataSet(csv,"Behavior")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"class")

# %%
# multiple text by adding neuron number
scoretype = 2
scope_num = 20
class_num = 8
dim_num = 80
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6693121693121693
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23224364811190926
# error_data0_score_W0 0.10514067322697206
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.6866307224484767
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.1103425749320404
# all_train_score_W': 0.24581375938999095
# test_score_W0 : 0.11583438077844507
# test_score_W': 0.2348033932125976
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5582010582010583
# right_data0_score_W0 1.0
# error_data0_score_W1 0.33277982251030486
# error_data0_score_W0 0.22666671661001422
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.5552322996429614
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.19926274583573778
# all_train_score_W': 0.28149096385511674
# test_score_W0 : 0.18154836149675618
# test_score_W': 0.3020411401471243
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.4801587301587302
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4238818940033545
# error_data0_score_W0 0.18551303767285132
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.4595964997317703
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.24801204190236376
# all_train_score_W': 0.33201960250171814
# test_score_W0 : 0.23174886731107494
# test_score_W': 0.31964300137307167
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.42724867724867727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3922643506396772
# error_data0_score_W0 0.16220134523643043
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.7060537778440816
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.2966886298446955
# all_train_score_W': 0.4895042139040481
# test_score_W0 : 0.34182995298147695
# test_score_W': 0.48964279008900735
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.4246031746031746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5497525061086945
# error_data0_score_W0 0.14611577457482838
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.7381728243798366
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3062625344111625
# all_train_score_W': 0.5233024935615618
# test_score_W0 : 0.30077030714764563
# test_score_W': 0.4820045141218813
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3955026455026455
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5471365648465031
# error_data0_score_W0 0.2689934028338176
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.7428124196763588
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3439068985221682
# all_train_score_W': 0.5519251377538309
# test_score_W0 : 0.3465828529729003
# test_score_W': 0.5343441764812681
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.33201058201058203
# right_data0_score_W0 1.0
# error_data0_score_W1 0.598950333949998
# error_data0_score_W0 0.20420902067685084
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.6512847179111706
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.426037882453284
# all_train_score_W': 0.5446939893554961
# test_score_W0 : 0.3656215318102099
# test_score_W': 0.47505291981888104
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.26322751322751325
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6986786966362457
# error_data0_score_W0 0.2115045900214563
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.7889045298568248
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5242322751597867
# all_train_score_W': 0.686751171829878
# test_score_W0 : 0.4261076548139306
# test_score_W': 0.623912100927424
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2923280423280423
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7680238662514218
# error_data0_score_W0 0.2594629125536489
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.682417019386897
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.47512715088673296
# all_train_score_W': 0.6675788274809012
# test_score_W0 : 0.43664529518585776
# test_score_W': 0.6948815326762865
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.2566137566137566
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7299350748760798
# error_data0_score_W0 0.2965236398893962
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.7646244801482339
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.53184011022384
# all_train_score_W': 0.7035617990721791
# test_score_W0 : 0.47390692369251
# test_score_W': 0.6165285330707854
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2275132275132275
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8724811808684965
# error_data0_score_W0 0.3228804766150485
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.8646961932231744
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5727025250306111
# all_train_score_W': 0.8253099642392758
# test_score_W0 : 0.527269884528435
# test_score_W': 0.7074131559189866
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.2328042328042328
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7046968700136875
# error_data0_score_W0 0.21783965995567445
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.7362874714834025
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5690474415977707
# all_train_score_W': 0.657905781958977
# test_score_W0 : 0.492680773133814
# test_score_W': 0.6380248619030411
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.18253968253968253
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8690684794649598
# error_data0_score_W0 0.2909451997933931
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.7575398571428064
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6576427482986441
# all_train_score_W': 0.7430706984876307
# test_score_W0 : 0.533929669037071
# test_score_W': 0.726734416925523
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.26455026455026454
# right_data0_score_W0 1.0
# error_data0_score_W1 0.794303712976461
# error_data0_score_W0 0.23750520210234213
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.7767152084152439
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5151563010968411
# all_train_score_W': 0.7380467465133141
# test_score_W0 : 0.471136554087772
# test_score_W': 0.6877438182357823
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.18915343915343916
# right_data0_score_W0 1.0
# error_data0_score_W1 0.952053286051908
# error_data0_score_W0 0.3424930216406726
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.8070130482711224
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6281553007682132
# all_train_score_W': 0.813682864345818
# test_score_W0 : 0.528962601209394
# test_score_W': 0.7868110567908729
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.2552910052910053
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7694812395846189
# error_data0_score_W0 0.25861758399886364
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.7875934789465856
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5180139587689924
# all_train_score_W': 0.700077812175978
# test_score_W0 : 0.4587004270598422
# test_score_W': 0.6685700006911548
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.1746031746031746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.93768133537164
# error_data0_score_W0 0.2753623924566454
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.7759622381451716
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6443412326254184
# all_train_score_W': 0.8007881195410558
# test_score_W0 : 0.5911773511755243
# test_score_W': 0.7496146302766182
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.21693121693121692
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9024911486947738
# error_data0_score_W0 0.25054321380041555
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.7544644072875099
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.57545609213246
# all_train_score_W': 0.745387970833664
# test_score_W0 : 0.4891402639971803
# test_score_W': 0.7211429860208686
# neuron unit number: 152
# *******************
# Error Data percentage 0.24074074074074073
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8713657481044113
# error_data0_score_W0 0.23804804233402288
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.8154063626810404
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5420853295630662
# all_train_score_W': 0.7752516628679471
# test_score_W0 : 0.48284641170842246
# test_score_W': 0.7670322069246455
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8899778607056714
# error_data0_score_W0 0.32410870856528323
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.7928827642518161
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.534874742699754
# all_train_score_W': 0.7567359264165935
# test_score_W0 : 0.5123548659822336
# test_score_W': 0.6859911634481274
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6917989417989417
# right_data0_score_W0 1.0
# error_data0_score_W1 0.19769808643985828
# error_data0_score_W0 0.07761242440396914
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.6537890882230839
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08834588843360718
# all_train_score_W': 0.2036597847177983
# test_score_W0 : 0.08197500256689477
# test_score_W': 0.2055253356199255
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.578042328042328
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2603005327378587
# error_data0_score_W0 0.11774476176699893
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.3502115308164298
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.16483627275492532
# all_train_score_W': 0.25921027956765674
# test_score_W0 : 0.1702555581573638
# test_score_W': 0.25926451885392926
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.47883597883597884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.386453108496894
# error_data0_score_W0 0.22392896084224467
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.643598428402722
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.2862220124137166
# all_train_score_W': 0.4026933348387146
# test_score_W0 : 0.2597036816933197
# test_score_W': 0.30051056538271825
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.4444444444444444
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4302663960839688
# error_data0_score_W0 0.2003429703508106
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.646112720413642
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.30295145678288105
# all_train_score_W': 0.42862711702006345
# test_score_W0 : 0.2854372053543236
# test_score_W': 0.4170959995073791
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.3835978835978836
# right_data0_score_W0 1.0
# error_data0_score_W1 0.524028834524958
# error_data0_score_W0 0.18375392334171967
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.615292144813601
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3494266137779118
# all_train_score_W': 0.5094658437832361
# test_score_W0 : 0.2846443908187378
# test_score_W': 0.4340664693913619
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3386243386243386
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6324849452889589
# error_data0_score_W0 0.16926845454145634
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.7943586695467435
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4187592873038655
# all_train_score_W': 0.6472950277727714
# test_score_W0 : 0.3738797690779727
# test_score_W': 0.5877992248587279
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.294973544973545
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6392241546839484
# error_data0_score_W0 0.279236084347843
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.7548463987056461
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4662458623976791
# all_train_score_W': 0.6439322262545396
# test_score_W0 : 0.31714748391571196
# test_score_W': 0.574021756815645
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.28835978835978837
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7399979834867395
# error_data0_score_W0 0.2792586614626905
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.7673817853020419
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.48661511504707383
# all_train_score_W': 0.6846483438523469
# test_score_W0 : 0.46072503282729327
# test_score_W': 0.6203308587128076
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.27645502645502645
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7864509866058401
# error_data0_score_W0 0.238771063127155
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.7315539874991766
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4825076628735863
# all_train_score_W': 0.7134096125829955
# test_score_W0 : 0.44544460834087773
# test_score_W': 0.6168390383972352
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.30687830687830686
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7092574764892033
# error_data0_score_W0 0.17007039130464072
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8278994276424895
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.45902522046957256
# all_train_score_W': 0.709782570484714
# test_score_W0 : 0.44956222573824584
# test_score_W': 0.5935073254826798
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.20767195767195767
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8876151768568172
# error_data0_score_W0 0.3659493277721081
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.7708963130964988
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6045065350125389
# all_train_score_W': 0.7839840176849479
# test_score_W0 : 0.5758079573941919
# test_score_W': 0.6971582594188258
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.2208994708994709
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8736031988783154
# error_data0_score_W0 0.2928321606611378
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.8111458086655369
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5876708493287417
# all_train_score_W': 0.7950862006638786
# test_score_W0 : 0.5616318580387117
# test_score_W': 0.6976522883689527
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.14682539682539683
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8469654235871723
# error_data0_score_W0 0.36169791849644106
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8212514855216636
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7102757702046826
# all_train_score_W': 0.823370124737369
# test_score_W0 : 0.603791943875165
# test_score_W': 0.8073066157670201
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.23148148148148148
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8048355074746418
# error_data0_score_W0 0.20767253497855934
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.7787015925180305
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.572222127338835
# all_train_score_W': 0.7512114519626409
# test_score_W0 : 0.4880685180215736
# test_score_W': 0.6377924128105619
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.28703703703703703
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8329862200131586
# error_data0_score_W0 0.2488962960088616
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.7835843092488295
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.48396445486905576
# all_train_score_W': 0.7340629897983183
# test_score_W0 : 0.4206875145232227
# test_score_W': 0.6753971880751162
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.2526455026455027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7967358923711447
# error_data0_score_W0 0.27225473018752727
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.7634274947554748
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5221692429033439
# all_train_score_W': 0.7058056016888283
# test_score_W0 : 0.48196905118287764
# test_score_W': 0.6216910080640866
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.21693121693121692
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8709689099097317
# error_data0_score_W0 0.2576616528858849
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.8085740239662509
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5855844057256419
# all_train_score_W': 0.7844105276399547
# test_score_W0 : 0.5119069990842299
# test_score_W': 0.7080821048209915
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.28174603174603174
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8453984642411316
# error_data0_score_W0 0.2696871651796616
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.786612693886077
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4963594789105431
# all_train_score_W': 0.7236491946284724
# test_score_W0 : 0.40402847936044484
# test_score_W': 0.6713802761809635
# neuron unit number: 152
# *******************
# Error Data percentage 0.23677248677248677
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8503511805519797
# error_data0_score_W0 0.24293425855568165
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.8386544678642349
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5720936918173185
# all_train_score_W': 0.7948673797253639
# test_score_W0 : 0.5603584444008548
# test_score_W': 0.6976194423538645
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.25396825396825395
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8920985314267903
# error_data0_score_W0 0.40688967409307736
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.7197258105743376
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5353172222411974
# all_train_score_W': 0.7091501907467879
# test_score_W0 : 0.469649901850546
# test_score_W': 0.6456212586360043
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.5753968253968254
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2424121358206215
# error_data0_score_W0 0.18924668079274243
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.7362288049692262
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.23797162631719648
# all_train_score_W': 0.2716633855913023
# test_score_W0 : 0.2437143610868727
# test_score_W': 0.25709246557904875
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.6084656084656085
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24873898398724564
# error_data0_score_W0 0.1908477851979619
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.6195233847774116
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.16643719913065813
# all_train_score_W': 0.27497789486067503
# test_score_W0 : 0.14018734049366255
# test_score_W': 0.24593560936288403
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.4880952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 0.26028429637200473
# error_data0_score_W0 0.16307853510545603
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.5635197263384735
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.263610843988026
# all_train_score_W': 0.2807854899185991
# test_score_W0 : 0.2757397381449697
# test_score_W': 0.2730238913922185
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.455026455026455
# right_data0_score_W0 1.0
# error_data0_score_W1 0.49909835018089904
# error_data0_score_W0 0.1817240722326608
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.7747950033905918
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.2758187626473813
# all_train_score_W': 0.44200111302874906
# test_score_W0 : 0.33663436940108926
# test_score_W': 0.436589230297915
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.39021164021164023
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4117065027541817
# error_data0_score_W0 0.17863854973267124
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.6802170719661251
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.32683466769110414
# all_train_score_W': 0.4950932210667223
# test_score_W0 : 0.3075322854842077
# test_score_W': 0.46280144655669225
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3201058201058201
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5765584674198813
# error_data0_score_W0 0.24630223154235517
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.7057468125373807
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.42525711891993057
# all_train_score_W': 0.6047155085900009
# test_score_W0 : 0.36320296869531915
# test_score_W': 0.552401171124143
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.24206349206349206
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8242914009321638
# error_data0_score_W0 0.3469841041616829
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.6541037017393077
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5507668004080394
# all_train_score_W': 0.6195224025032566
# test_score_W0 : 0.5170642066717098
# test_score_W': 0.610104140220334
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.29894179894179895
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6979780420648147
# error_data0_score_W0 0.20163226979140217
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.8176806703423972
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.44908026547663255
# all_train_score_W': 0.7139757940970254
# test_score_W0 : 0.39869784973871325
# test_score_W': 0.5902837043755464
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2843915343915344
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8059760132040605
# error_data0_score_W0 0.21739664010317866
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.8137789716096272
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.48071583267834567
# all_train_score_W': 0.7572636985823064
# test_score_W0 : 0.4956899412298231
# test_score_W': 0.7616876956895929
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.2275132275132275
# right_data0_score_W0 1.0
# error_data0_score_W1 0.782444518028203
# error_data0_score_W0 0.21611526998067318
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.809446996757183
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5652499519437005
# all_train_score_W': 0.7543787267030139
# test_score_W0 : 0.5711569563877278
# test_score_W': 0.6600047344858557
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2208994708994709
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8148551113139019
# error_data0_score_W0 0.2421847398564934
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.8434832070223132
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5890714009460518
# all_train_score_W': 0.7911623113476419
# test_score_W0 : 0.45526642508745213
# test_score_W': 0.6825731781060607
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.2275132275132275
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8242023565973166
# error_data0_score_W0 0.28486530411271654
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.8454680441073341
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5720764356233298
# all_train_score_W': 0.7936393059125889
# test_score_W0 : 0.5270750649452017
# test_score_W': 0.7235962408368026
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.21825396825396826
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9199312712352437
# error_data0_score_W0 0.25632009676169193
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.838394774858306
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6062053794751187
# all_train_score_W': 0.8329417886809338
# test_score_W0 : 0.6037045639298572
# test_score_W': 0.7840483555845001
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.2037037037037037
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9239147247721847
# error_data0_score_W0 0.2309322824706283
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.7570539336704414
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6129225219897811
# all_train_score_W': 0.7628961992874655
# test_score_W0 : 0.5257303156048044
# test_score_W': 0.7464395688991532
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2447089947089947
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8915029318083498
# error_data0_score_W0 0.27465938564313047
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.8144944181341481
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5471458617150577
# all_train_score_W': 0.7802780671273761
# test_score_W0 : 0.47753371679016604
# test_score_W': 0.7158459253937887
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.2724867724867725
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8567409219285103
# error_data0_score_W0 0.2965350547150755
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8224392949636874
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5050541563996943
# all_train_score_W': 0.7772848192047342
# test_score_W0 : 0.4988760063712472
# test_score_W': 0.6869759982597068
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.26851851851851855
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8751317713044826
# error_data0_score_W0 0.23323102261160966
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.8529803426001138
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5224720891772934
# all_train_score_W': 0.7587263656505459
# test_score_W0 : 0.48611065062721653
# test_score_W': 0.6175498907397713
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.2275132275132275
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7489134820579955
# error_data0_score_W0 0.3166752473570491
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.7731129089303646
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5780845616457602
# all_train_score_W': 0.7196313930907393
# test_score_W0 : 0.5808756051526097
# test_score_W': 0.6756930224028852
# neuron unit number: 152
# *******************
#
# Error Data percentage 0.28174603174603174
# right_data0_score_W0 1.0
# error_data0_score_W1 0.858037077607263
# error_data0_score_W0 0.17586715985511944
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.8060446815754008
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.48924980145148167
# all_train_score_W': 0.7352867703431579
# test_score_W0 : 0.404631427478759
# test_score_W': 0.647323491992395
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.23148148148148148
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8843036541897025
# error_data0_score_W0 0.2569990299153142
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.774576257679008
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5720006191663239
# all_train_score_W': 0.7520192571353711
# test_score_W0 : 0.5075157674834653
# test_score_W': 0.6787854989365537
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6481481481481481
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32771609784797034
# error_data0_score_W0 0.15071613680997362
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.7607465589345737
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.1470100492517803
# all_train_score_W': 0.2493877624917485
# test_score_W0 : 0.16009711743714253
# test_score_W': 0.25182659029731425
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5701058201058201
# right_data0_score_W0 1.0
# error_data0_score_W1 0.25310437508714584
# error_data0_score_W0 0.17438726471087146
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.6988154952540255
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.18973047644498775
# all_train_score_W': 0.29209329898754915
# test_score_W0 : 0.1823972144975187
# test_score_W': 0.2923627846855212
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.5052910052910053
# right_data0_score_W0 1.0
# error_data0_score_W1 0.36127079326771705
# error_data0_score_W0 0.1228926206052774
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.7492278480945479
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.22592755511314458
# all_train_score_W': 0.399252205414708
# test_score_W0 : 0.2090673656027165
# test_score_W': 0.33806108496512777
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.4417989417989418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.41383050040747177
# error_data0_score_W0 0.1516427440959653
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.7963211530013452
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.27536085854312814
# all_train_score_W': 0.45420916620315244
# test_score_W0 : 0.30887207614545736
# test_score_W': 0.46485103808052514
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.4351851851851852
# right_data0_score_W0 1.0
# error_data0_score_W1 0.431673502332476
# error_data0_score_W0 0.2511811824464215
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.5781410353267771
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.30577517556952427
# all_train_score_W': 0.38392162831228
# test_score_W0 : 0.2934559520050521
# test_score_W': 0.35357317420762424
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.39285714285714285
# right_data0_score_W0 1.0
# error_data0_score_W1 0.631566783058821
# error_data0_score_W0 0.1817238849842528
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.6167155621235049
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3325650570805438
# all_train_score_W': 0.5014800589888246
# test_score_W0 : 0.3214656850818495
# test_score_W': 0.44451297096408043
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.34656084656084657
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6320680615126429
# error_data0_score_W0 0.24731301159445992
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.7278285144273399
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.39610568708592747
# all_train_score_W': 0.617315673380872
# test_score_W0 : 0.35474340517954867
# test_score_W': 0.5143172540127101
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.27380952380952384
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7742727222492837
# error_data0_score_W0 0.19871551666735465
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.6811372784345813
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.492304555588005
# all_train_score_W': 0.6651102861361669
# test_score_W0 : 0.44341030259003095
# test_score_W': 0.6217310627232953
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.27380952380952384
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8094744475931795
# error_data0_score_W0 0.2836595090678523
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.7524313636485924
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.501016391646978
# all_train_score_W': 0.6854914236306662
# test_score_W0 : 0.48721069973942127
# test_score_W': 0.6502920454329933
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.2156084656084656
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8314475461674998
# error_data0_score_W0 0.3315682281059063
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8251867747994936
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5828215258004454
# all_train_score_W': 0.782596949204863
# test_score_W0 : 0.509394470542551
# test_score_W': 0.697496557383234
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.291005291005291
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7438238288983188
# error_data0_score_W0 0.26231216696041043
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.6934612879543169
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4876442270089933
# all_train_score_W': 0.6330431478481434
# test_score_W0 : 0.5390492675202604
# test_score_W': 0.6926292588121313
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.22486772486772486
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8792859341565136
# error_data0_score_W0 0.25616521127687397
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.8153542720777766
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5615257374405579
# all_train_score_W': 0.7714565187853138
# test_score_W0 : 0.557308973875254
# test_score_W': 0.7374003597214513
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.2724867724867725
# right_data0_score_W0 1.0
# error_data0_score_W1 0.819203043712459
# error_data0_score_W0 0.31171391366848866
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8178529992982444
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5154115341156559
# all_train_score_W': 0.7499623599287459
# test_score_W0 : 0.4517393649541965
# test_score_W': 0.680022168742646
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.19444444444444445
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8136096508701591
# error_data0_score_W0 0.2596473987526551
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.7897763347542965
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6186059678263928
# all_train_score_W': 0.7565074278620064
# test_score_W0 : 0.5847108987208262
# test_score_W': 0.716085258292134
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.17857142857142858
# right_data0_score_W0 1.0
# error_data0_score_W1 0.93551638181146
# error_data0_score_W0 0.30328170815409383
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.7263851792510911
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6496084724890323
# all_train_score_W': 0.7454902637443541
# test_score_W0 : 0.5651238246968241
# test_score_W': 0.7423315847968601
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.18253968253968253
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9228178261396266
# error_data0_score_W0 0.3937078753059554
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8283238887063947
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6392914201864627
# all_train_score_W': 0.828658435498974
# test_score_W0 : 0.5447861928515498
# test_score_W': 0.7175553723785768
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.26587301587301587
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9033511973373317
# error_data0_score_W0 0.311226670763999
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.8017058359164352
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5176889876566536
# all_train_score_W': 0.7784635099662371
# test_score_W0 : 0.49233958670483546
# test_score_W': 0.7887792595179717
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.18518518518518517
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9578728877230068
# error_data0_score_W0 0.2829550811502458
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.7841906530008723
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6395044413425935
# all_train_score_W': 0.790734196849133
# test_score_W0 : 0.594247544460687
# test_score_W': 0.7358833959522898
# neuron unit number: 152
# *******************
# Error Data percentage 0.19576719576719576
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9074757153672305
# error_data0_score_W0 0.4538054210437715
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.7124641358170984
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6349098565658415
# all_train_score_W': 0.6972861412669332
# test_score_W0 : 0.6229088572714561
# test_score_W': 0.6466973280142353
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.20502645502645503
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9087210290633252
# error_data0_score_W0 0.24627994789953556
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.879055101272273
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6005661405953318
# all_train_score_W': 0.8373063385463967
# test_score_W0 : 0.5257638829616909
# test_score_W': 0.6958495902862272
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6812169312169312
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23315481353738113
# error_data0_score_W0 0.1419075742080028
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.664626006482053
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.14033858424678944
# all_train_score_W': 0.2718965038134667
# test_score_W0 : 0.1688410523040808
# test_score_W': 0.26517523459627723
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5462962962962963
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3336139778269113
# error_data0_score_W0 0.149468450116211
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.5532394898735805
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.23113711655186875
# all_train_score_W': 0.2801128151344237
# test_score_W0 : 0.25451609765022076
# test_score_W': 0.249527914182708
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.49074074074074076
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32234956261466985
# error_data0_score_W0 0.15574167748917522
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.7641258244527874
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.23600244236371365
# all_train_score_W': 0.3901296759633598
# test_score_W0 : 0.26154170210308286
# test_score_W': 0.42381946466844
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.4166666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.48736760704879917
# error_data0_score_W0 0.2197352694265679
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.7792720163721696
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.32986974581608086
# all_train_score_W': 0.5470773387341495
# test_score_W0 : 0.2831677631124918
# test_score_W': 0.4408390568624375
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.38756613756613756
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6013162652755877
# error_data0_score_W0 0.1930788755520797
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.6955865114120972
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.36585075190638233
# all_train_score_W': 0.5475675900245444
# test_score_W0 : 0.3490910805390689
# test_score_W': 0.47791959024755876
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3941798941798942
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5757837222722155
# error_data0_score_W0 0.18006807890542942
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.624363946417473
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3365155359845628
# all_train_score_W': 0.4481505635325005
# test_score_W0 : 0.29184848271814245
# test_score_W': 0.38139189168455273
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.30158730158730157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.722068836347085
# error_data0_score_W0 0.19099817150106138
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.698646132354753
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4370187380641307
# all_train_score_W': 0.6404264443080865
# test_score_W0 : 0.413603305009799
# test_score_W': 0.6024926507700291
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.28703703703703703
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6425525769225479
# error_data0_score_W0 0.22424486045710348
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.8287125954224984
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4754467516888811
# all_train_score_W': 0.6823096174578444
# test_score_W0 : 0.4654895666131621
# test_score_W': 0.5945055169086284
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.22883597883597884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8155798072437809
# error_data0_score_W0 0.17801607978783549
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.6798834618959569
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5616970771460646
# all_train_score_W': 0.6670426807538302
# test_score_W0 : 0.5123994187105383
# test_score_W': 0.6546085331541103
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.21693121693121692
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7830682932961407
# error_data0_score_W0 0.21923438064255887
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.6649888819657847
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5868398379923605
# all_train_score_W': 0.6504219022281083
# test_score_W0 : 0.5059644447865381
# test_score_W': 0.6881814699033347
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.22883597883597884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8697552440321966
# error_data0_score_W0 0.28587980999476276
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.7675875558981528
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5765991931665633
# all_train_score_W': 0.7453598728585403
# test_score_W0 : 0.4637122664688523
# test_score_W': 0.6954750872242086
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.30158730158730157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7990464534843307
# error_data0_score_W0 0.2539775362293626
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.832395006515711
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.48532787233384395
# all_train_score_W': 0.7270355508084085
# test_score_W0 : 0.48878351832525607
# test_score_W': 0.729376332457725
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.1970899470899471
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8913050347395409
# error_data0_score_W0 0.2682233285842563
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.8061906683571631
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6185176026765848
# all_train_score_W': 0.7791938695768521
# test_score_W0 : 0.5448403134233535
# test_score_W': 0.7269979332185715
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.2037037037037037
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8296376361946364
# error_data0_score_W0 0.3069497078549063
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.7128982488370172
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6116478982100977
# all_train_score_W': 0.7234423318272931
# test_score_W0 : 0.5384306567924487
# test_score_W': 0.6661940472905202
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2526455026455027
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9066124971147379
# error_data0_score_W0 0.19503585262542975
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.8061387361816112
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5277510817907729
# all_train_score_W': 0.7694367420899295
# test_score_W0 : 0.45255830595582736
# test_score_W': 0.7614375840769355
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.1931216931216931
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9156665849994332
# error_data0_score_W0 0.21157098912902356
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8062735067151574
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6272032796805365
# all_train_score_W': 0.7765274203319203
# test_score_W0 : 0.5393119172262856
# test_score_W': 0.7473944332721006
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.21825396825396826
# right_data0_score_W0 1.0
# error_data0_score_W1 0.920102137562722
# error_data0_score_W0 0.33143461190717893
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.7730237816498791
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5904495708647544
# all_train_score_W': 0.7687793553399304
# test_score_W0 : 0.5641100521851912
# test_score_W': 0.7055492877489445
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.18783068783068782
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875200039081291
# error_data0_score_W0 0.31572153581603524
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.8585315787178482
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6380421834564886
# all_train_score_W': 0.8372922606855462
# test_score_W0 : 0.5299644623719734
# test_score_W': 0.7151217286539927
# neuron unit number: 152
# *******************
# Error Data percentage 0.23544973544973544
# right_data0_score_W0 1.0
# error_data0_score_W1 0.885209954311332
# error_data0_score_W0 0.27120884257606115
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.8722898987583074
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5499829749528428
# all_train_score_W': 0.8363707978104898
# test_score_W0 : 0.4961249960389854
# test_score_W': 0.7731263115110498
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.21164021164021163
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9374003612924269
# error_data0_score_W0 0.45863466055711327
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.6646553295760973
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5992684747861474
# all_train_score_W': 0.674040024319675
# test_score_W0 : 0.5403522101864024
# test_score_W': 0.669069935111752
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6415343915343915
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24499756828435465
# error_data0_score_W0 0.1335959856165895
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.700869911164175
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.16232854235849997
# all_train_score_W': 0.2179204550017737
# test_score_W0 : 0.16494778221393283
# test_score_W': 0.2609602354423962
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.5740740740740741
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32123456159365366
# error_data0_score_W0 0.15640008157079877
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.6487882976940021
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.21110211985381414
# all_train_score_W': 0.29152010872804585
# test_score_W0 : 0.22078887421437082
# test_score_W': 0.2997481767236708
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.4523809523809524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3685585618084485
# error_data0_score_W0 0.17566894901839034
# combinedweight shape 0: (48, 80)
# ...
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.47960497094963606
# all_train_score_W': 0.6714394734891801
# test_score_W0 : 0.48243559718969553
# test_score_W': 0.6431712874866798
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.25793650793650796
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8258423235193539
# error_data0_score_W0 0.2678735214629187
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8284173039266627
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5289218787040968
# all_train_score_W': 0.7571082027751534
# test_score_W0 : 0.4888624177040484
# test_score_W': 0.6903619323090793
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2328042328042328
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9017309656330955
# error_data0_score_W0 0.23672673254377477
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.8412600660819886
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5586381684657878
# all_train_score_W': 0.7970705170171237
# test_score_W0 : 0.5405912960980436
# test_score_W': 0.7598090711237151
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.23148148148148148
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9005430755303551
# error_data0_score_W0 0.21385640477511642
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.776688795820476
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5571613605126696
# all_train_score_W': 0.7554514072551641
# test_score_W0 : 0.5452852130281062
# test_score_W': 0.6813155103706535
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.19047619047619047
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9184496382341455
# error_data0_score_W0 0.28441482430103604
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.823188732511747
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6422442573882142
# all_train_score_W': 0.7942138738842596
# test_score_W0 : 0.5331556417090704
# test_score_W': 0.6940505000981766
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.26851851851851855
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8375433493893886
# error_data0_score_W0 0.24731129646442052
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.8585822136372964
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5157844379724219
# all_train_score_W': 0.7919998716301588
# test_score_W0 : 0.5078597209328419
# test_score_W': 0.7245812594349544
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2037037037037037
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8869281932944211
# error_data0_score_W0 0.20496605930689532
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.795720675859511
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6001997495702952
# all_train_score_W': 0.7856537422924705
# test_score_W0 : 0.5126277098083629
# test_score_W': 0.6915009089438512
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.2830687830687831
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7663262873619754
# error_data0_score_W0 0.26986394880216646
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.8079230702939949
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5013164124658817
# all_train_score_W': 0.7539234905269592
# test_score_W0 : 0.47309822031645965
# test_score_W': 0.6543110052672273
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.1970899470899471
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8668212860651467
# error_data0_score_W0 0.2973329643990561
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.798378760010768
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.616912936487559
# all_train_score_W': 0.7575862866321134
# test_score_W0 : 0.5147726720237127
# test_score_W': 0.6830205017312387
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.20899470899470898
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9272363987933755
# error_data0_score_W0 0.2889770139312016
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.8606379603843586
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5915979752525059
# all_train_score_W': 0.8468004857782436
# test_score_W0 : 0.5720161443348667
# test_score_W': 0.7816448470086771
# neuron unit number: 152
# *******************
#
# Error Data percentage 0.22486772486772486
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8764813171784023
# error_data0_score_W0 0.19228108110431782
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.7704170813281132
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5701658181452683
# all_train_score_W': 0.769259248013917
# test_score_W0 : 0.5191156697805513
# test_score_W': 0.7134158701587586
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.20767195767195767
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9226322757985764
# error_data0_score_W0 0.29903268401765287
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.776046212839684
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5928917580984108
# all_train_score_W': 0.7848986056779472
# test_score_W0 : 0.5484030454719843
# test_score_W': 0.7407036706629823
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.6349206349206349
# right_data0_score_W0 1.0
# error_data0_score_W1 0.23464965070432817
# error_data0_score_W0 0.08093076641202566
# combinedweight shape 0: (16, 80)
# right_data0_score_W' 0.7877932584228731
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.1384231015278638
# all_train_score_W': 0.27569330039377604
# test_score_W0 : 0.19234936163443564
# test_score_W': 0.3088004884175883
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.578042328042328
# right_data0_score_W0 1.0
# error_data0_score_W1 0.21315825429123897
# error_data0_score_W0 0.1853543183631184
# combinedweight shape 0: (32, 80)
# right_data0_score_W' 0.6155720624592613
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.21543627331900292
# all_train_score_W': 0.25573792446298643
# test_score_W0 : 0.2246234726326048
# test_score_W': 0.2382438165450051
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.4748677248677249
# right_data0_score_W0 1.0
# error_data0_score_W1 0.31211867568664353
# error_data0_score_W0 0.17071910239648272
# combinedweight shape 0: (48, 80)
# right_data0_score_W' 0.7302965225297395
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.25193863678301737
# all_train_score_W': 0.38666229250685713
# test_score_W0 : 0.29309218028903017
# test_score_W': 0.4249920895813464
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.4312169312169312
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5230071926171089
# error_data0_score_W0 0.16377961905170438
# combinedweight shape 0: (64, 80)
# right_data0_score_W' 0.6928100886625778
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.295205780381165
# all_train_score_W': 0.47891300631927736
# test_score_W0 : 0.30925322848720016
# test_score_W': 0.5040099410334599
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.38756613756613756
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5046095254333122
# error_data0_score_W0 0.2824688263630409
# combinedweight shape 0: (80, 80)
# right_data0_score_W' 0.7134724618366217
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.37962523603221665
# all_train_score_W': 0.47869117524156407
# test_score_W0 : 0.4089178667258893
# test_score_W': 0.48166663757636907
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.3478835978835979
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5045163929203451
# error_data0_score_W0 0.18047759194360097
# combinedweight shape 0: (96, 80)
# right_data0_score_W' 0.7162631569451147
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.3977216641874981
# all_train_score_W': 0.553137793500309
# test_score_W0 : 0.392187522071679
# test_score_W': 0.5265546322965664
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.2843915343915344
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7002473672751535
# error_data0_score_W0 0.154778303462799
# combinedweight shape 0: (112, 80)
# right_data0_score_W' 0.810405195309907
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4776651901022598
# all_train_score_W': 0.6951838989029163
# test_score_W0 : 0.4556151583318913
# test_score_W': 0.6669950492835315
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.3055555555555556
# right_data0_score_W0 1.0
# error_data0_score_W1 0.799066778139818
# error_data0_score_W0 0.14482402964517443
# combinedweight shape 0: (128, 80)
# right_data0_score_W' 0.7652721247242322
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.4359924239554664
# all_train_score_W': 0.6965070085434164
# test_score_W0 : 0.41255083852684055
# test_score_W': 0.6940607990093246
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.27380952380952384
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8166706935621381
# error_data0_score_W0 0.2548375576032437
# combinedweight shape 0: (144, 80)
# right_data0_score_W' 0.8139652773577305
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5179614860173505
# all_train_score_W': 0.7600464672820263
# test_score_W0 : 0.4721649417154958
# test_score_W': 0.7529830248736189
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.2328042328042328
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7730698826316357
# error_data0_score_W0 0.2545120930532008
# combinedweight shape 0: (160, 80)
# right_data0_score_W' 0.8221414854684724
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5712844349117597
# all_train_score_W': 0.7499662873319984
# test_score_W0 : 0.515743014468129
# test_score_W': 0.7489160788422129
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.2156084656084656
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8865077869474726
# error_data0_score_W0 0.24611114161782371
# combinedweight shape 0: (176, 80)
# right_data0_score_W' 0.7390870705320836
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5881320102972376
# all_train_score_W': 0.6987078389094217
# test_score_W0 : 0.5423921831224063
# test_score_W': 0.6898631421831072
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.26322751322751325
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7730256310127113
# error_data0_score_W0 0.2771826098979957
# combinedweight shape 0: (192, 80)
# right_data0_score_W' 0.7764163210163362
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.519165030002932
# all_train_score_W': 0.7216184443019651
# test_score_W0 : 0.5199898580179232
# test_score_W': 0.6526299881560034
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7921385740642397
# error_data0_score_W0 0.37010187303046166
# combinedweight shape 0: (208, 80)
# right_data0_score_W' 0.7741288616388206
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5345208014199712
# all_train_score_W': 0.7170547572694899
# test_score_W0 : 0.5136614786779736
# test_score_W': 0.7228776191027435
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.19973544973544974
# right_data0_score_W0 1.0
# error_data0_score_W1 0.83851901200456
# error_data0_score_W0 0.22564321302142523
# combinedweight shape 0: (224, 80)
# right_data0_score_W' 0.7715709162186314
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6058828732412088
# all_train_score_W': 0.7313006400543286
# test_score_W0 : 0.6163801873984702
# test_score_W': 0.6888585507370037
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.1970899470899471
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9622822643996162
# error_data0_score_W0 0.31192451770232155
# combinedweight shape 0: (240, 80)
# right_data0_score_W' 0.6869081836253931
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.6196092523183953
# all_train_score_W': 0.7090327143270705
# test_score_W0 : 0.5261527577272771
# test_score_W': 0.6616470576920418
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.26455026455026454
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8665659246128489
# error_data0_score_W0 0.2362983275178068
# combinedweight shape 0: (256, 80)
# right_data0_score_W' 0.72634589510814
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5089236202576477
# all_train_score_W': 0.6912673083949399
# test_score_W0 : 0.4823388889540367
# test_score_W': 0.6021132065584079
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.22486772486772486
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9042008445634766
# error_data0_score_W0 0.23641926394336898
# combinedweight shape 0: (272, 80)
# right_data0_score_W' 0.7823102978114056
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5812302580209899
# all_train_score_W': 0.7957628282981648
# test_score_W0 : 0.5034185488595564
# test_score_W': 0.7290464497462495
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.23941798941798942
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8912666849769124
# error_data0_score_W0 0.2574170664351123
# combinedweight shape 0: (288, 80)
# right_data0_score_W' 0.8468794859144171
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5386793565739124
# all_train_score_W': 0.8044506049233875
# test_score_W0 : 0.5328893063184055
# test_score_W': 0.74367475943508
# neuron unit number: 152
# *******************
# Error Data percentage 0.2447089947089947
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7177344641105955
# error_data0_score_W0 0.2252618743397602
# combinedweight shape 0: (304, 80)
# right_data0_score_W' 0.7278238777188591
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5390192131458561
# all_train_score_W': 0.6906025572958694
# test_score_W0 : 0.5099049891691426
# test_score_W': 0.626335678687629
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.24735449735449735
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8965410846676198
# error_data0_score_W0 0.30323974111893087
# combinedweight shape 0: (320, 80)
# right_data0_score_W' 0.7454887519913058
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.5481791150472495
# all_train_score_W': 0.7059060462083718
# test_score_W0 : 0.41334007593416605
# test_score_W': 0.6397875236514454
#         Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   600.0  0.424135  0.127590  0.005209   0.413905  0.434365
# 1  test_score_W'   600.0  0.588152  0.169282  0.006911   0.574580  0.601725
# 2       combined  1200.0  0.506144  0.170822  0.004931   0.496469  0.515818
#                               Independent t-test    results
# 0  Difference (test_score_W0 - test_score_W') =     -0.1640
# 1                          Degrees of freedom =   1198.0000
# 2                                           t =    -18.9527
# 3                       Two side test p value =      0.0000
# 4                      Difference < 0 p value =      0.0000
# 5                      Difference > 0 p value =      1.0000
# 6                                   Cohen's d =     -1.0942
# 7                                   Hedge's g =     -1.0935
# 8                               Glass's delta =     -1.2855
# 9                                 Pearson's r =      0.4803
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-18.95267688896728, pvalue=1.4440228585141364e-70)
