# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Iris.csv")
csv = csv.drop(columns=['Id'])
dataread.stringToIntIrisDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Species")

#print("self.data_train len {}".format(len(dataread.data_train)))

# %%
import experiment
unstable_repeat_num= 30
scope_num = 33
class_num = 3
dim_num = 4
best_num = 12
elbow_num = 1
row = 2
column = 2
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )   

experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
#print("*****************************************************************************************")
#print("Best Number SOM Comparision")
#print("*****************************************************************************************")
#experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
#  mxn 0 3
# neuron unit number: 3
#  mxn 3
# all_train_score_W0_n 0.8054365608461928
# all_train_score_W0_a 0.8263472400933418
# test_score_W0_n 0.5896240025129957
# test_score_W0_a  0.529067834183108
# all_train_score_W_Combined_n 0.7322922355085398
# all_train_score_W_Combined_a 0.7605296478028436
# test_score_W_combined_n 0.8015663194875055
# test_score_W_combined_a 0.735601274565782
# Combine Neurons Number :8
#  mxn 0 4
# neuron unit number: 4
#  mxn 4
# all_train_score_W0_n 0.7944865613557465
# all_train_score_W0_a 0.8058277005645427
# test_score_W0_n 0.6097854262150078
# test_score_W0_a  0.5304643324185438
# all_train_score_W_Combined_n 0.8289885656413034
# all_train_score_W_Combined_a 0.8678285527479223
# test_score_W_combined_n 0.8723226909557366
# test_score_W_combined_a 0.8588926591078374
# Combine Neurons Number :9
#  mxn 0 5
# neuron unit number: 5
#  mxn 5
# all_train_score_W0_n 0.7458768188197896
# all_train_score_W0_a 0.7313370343950625
# test_score_W0_n 0.5360424857748601
# test_score_W0_a  0.37236303230851475
# all_train_score_W_Combined_n 0.7737102082659314
# all_train_score_W_Combined_a 0.7848382746477385
# test_score_W_combined_n 0.7514069095569623
# test_score_W_combined_a 0.6323886713915045
# Combine Neurons Number :13
#  mxn 0 6
# neuron unit number: 6
#  mxn 9
# all_train_score_W0_n 0.7564425493977135
# all_train_score_W0_a 0.7484838858467895
# test_score_W0_n 0.5966737077931908
# test_score_W0_a  0.45357317360068045
# all_train_score_W_Combined_n 0.7672855340773564
# all_train_score_W_Combined_a 0.7813740400209508
# test_score_W_combined_n 0.7314722011449214
# test_score_W_combined_a 0.5888253979845187
# Combine Neurons Number :13
#  mxn 0 7
# neuron unit number: 7
#  mxn 7
# all_train_score_W0_n 0.9107628338440832
# all_train_score_W0_a 0.9208600550428463
# test_score_W0_n 0.8015663194875055
# test_score_W0_a  0.735601274565782
# all_train_score_W_Combined_n 0.8556703506362838
# all_train_score_W_Combined_a 0.8943027410991862
# test_score_W_combined_n 0.8723226909557366
# test_score_W_combined_a 0.8588926591078374
# Combine Neurons Number :14
#  mxn 0 8
# neuron unit number: 8
#  mxn 16
# all_train_score_W0_n 0.7103169858263437
# all_train_score_W0_a 0.6926099278468096
# test_score_W0_n 0.6754524183052194
# test_score_W0_a  0.6752639039898705
# all_train_score_W_Combined_n 0.7532571614509047
# all_train_score_W_Combined_a 0.7533016831063477
# test_score_W_combined_n 0.7957470449084165
# test_score_W_combined_a 0.7978601764129369
# Combine Neurons Number :15
#  mxn 0 9
# neuron unit number: 9
#  mxn 9
# all_train_score_W0_n 0.7430143783346113
# all_train_score_W0_a 0.7445929050749721
# test_score_W0_n 0.5350644780258963
# test_score_W0_a  0.4707352634867736
# all_train_score_W_Combined_n 0.8305090105630121
# all_train_score_W_Combined_a 0.8048473745810888
# test_score_W_combined_n 0.92135628827507
# test_score_W_combined_a 0.9281280627245998
# Combine Neurons Number :16
#  mxn 0 10
# neuron unit number: 10
#  mxn 25
# all_train_score_W0_n 0.7702600405108265
# all_train_score_W0_a 0.6970374079518146
# test_score_W0_n 0.705653814545882
# test_score_W0_a  0.5888520724856431
# all_train_score_W_Combined_n 0.788980285648041
# all_train_score_W_Combined_a 0.8043534901347734
# test_score_W_combined_n 0.7129362167657375
# test_score_W_combined_a 0.6855602744201241
# Combine Neurons Number :16
#  mxn 0 11
# neuron unit number: 11
#  mxn 11
# all_train_score_W0_n 0.7808669273079293
# all_train_score_W0_a 0.7679728933411903
# test_score_W0_n 0.6994815654336012
# test_score_W0_a  0.5183827172728174
# all_train_score_W_Combined_n 0.7710733484973284
# all_train_score_W_Combined_a 0.802481521832846
# test_score_W_combined_n 0.6813873986488367
# test_score_W_combined_a 0.6159388162270006
# Not good nmi result !!!!!
# Combine Neurons Number :18
#  mxn 0 12
# neuron unit number: 12
#  mxn 36
# all_train_score_W0_n 0.7436473759928125
# all_train_score_W0_a 0.7407975882823084
# test_score_W0_n 0.58219996066379
# test_score_W0_a  0.5341943140045335
# all_train_score_W_Combined_n 0.8271175766729743
# all_train_score_W_Combined_a 0.8482910537909472
# test_score_W_combined_n 0.8723226909557366
# test_score_W_combined_a 0.8588926591078374
# Combine Neurons Number :18
#  mxn 0 13
# neuron unit number: 13
#  mxn 13
# all_train_score_W0_n 0.7808669273079293
# all_train_score_W0_a 0.7679728933411903
# test_score_W0_n 0.7056765219189969
# test_score_W0_a  0.5578159247048422
# all_train_score_W_Combined_n 0.788980285648041
# all_train_score_W_Combined_a 0.8043534901347734
# test_score_W_combined_n 0.7494323648325599
# test_score_W_combined_a 0.7379326712428801
# Combine Neurons Number :19
#  mxn 0 14
# neuron unit number: 14
#  mxn 49
# all_train_score_W0_n 0.7403821561349438
# all_train_score_W0_a 0.7448082419860307
# test_score_W0_n 0.5293210433399697
# test_score_W0_a  0.4493624738259049
# all_train_score_W_Combined_n 0.7484083986030846
# all_train_score_W_Combined_a 0.7446647244131789
# test_score_W_combined_n 0.7138475162431561
# test_score_W_combined_a 0.6823111974988311
# Combine Neurons Number :21
#  mxn 0 15
# neuron unit number: 15
#  mxn 15
# all_train_score_W0_n 0.8064087271319668
# all_train_score_W0_a 0.8044634581451404
# test_score_W0_n 0.6883562388823031
# test_score_W0_a  0.6458372049804869
# all_train_score_W_Combined_n 0.8682169599696015
# all_train_score_W_Combined_a 0.8956913156758383
# test_score_W_combined_n 0.8723226909557366
# test_score_W_combined_a 0.8588926591078374
# Combine Neurons Number :21
#  mxn 0 16
# neuron unit number: 16
#  mxn 64
# all_train_score_W0_n 0.872579524856133
# all_train_score_W0_a 0.8955446599872096
# test_score_W0_n 0.92135628827507
# test_score_W0_a  0.9281280627245998
# all_train_score_W_Combined_n 0.872579524856133
# all_train_score_W_Combined_a 0.8955446599872096
# test_score_W_combined_n 1.0
# test_score_W_combined_a 1.0
# Combine Neurons Number :20
#  mxn 0 17
# neuron unit number: 17
#  mxn 17
# all_train_score_W0_n 0.7546112346935755
# all_train_score_W0_a 0.764063690219158
# test_score_W0_n 0.6850567536556731
# test_score_W0_a  0.6313001737978978
# all_train_score_W_Combined_n 0.7546112346935755
# all_train_score_W_Combined_a 0.764063690219158
# test_score_W_combined_n 0.661206654756121
# test_score_W_combined_a 0.5851675169911407
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :19
#  mxn 0 18
# neuron unit number: 18
#  mxn 81
# all_train_score_W0_n 0.7869794046731305
# all_train_score_W0_a 0.8046281785674432
# test_score_W0_n 0.6787611282690011
# test_score_W0_a  0.5966371294067249
# all_train_score_W_Combined_n 0.7869794046731305
# all_train_score_W_Combined_a 0.8046281785674432
# test_score_W_combined_n 0.6850567536556731
# test_score_W_combined_a 0.6313001737978978
# Combine Neurons Number :21
#  mxn 0 19
# neuron unit number: 19
#  mxn 19
# all_train_score_W0_n 0.8033846862118097
# all_train_score_W0_a 0.7955218648566036
# test_score_W0_n 0.864024251127627
# test_score_W0_a  0.8475316650643568
# all_train_score_W_Combined_n 0.843666958144711
# all_train_score_W_Combined_a 0.8261521927930638
# test_score_W_combined_n 0.8315521637685857
# test_score_W_combined_a 0.8010574544285369
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :22
#  mxn 0 20
# neuron unit number: 20
#  mxn 100
# all_train_score_W0_n 0.8682169599696015
# all_train_score_W0_a 0.8956913156758383
# test_score_W0_n 0.7123288202506254
# test_score_W0_a  0.6703144223564563
# all_train_score_W_Combined_n 0.894896908739237
# all_train_score_W_Combined_a 0.9204597117878537
# test_score_W_combined_n 0.8723226909557366
# test_score_W_combined_a 0.8588926591078374
# Combine Neurons Number :26
#  mxn 0 21
# neuron unit number: 21
#  mxn 21
# all_train_score_W0_n 0.8268439710109857
# all_train_score_W0_a 0.8488859501652427
# test_score_W0_n 0.7315421486274242
# test_score_W0_a  0.6980540797273197
# all_train_score_W_Combined_n 0.8243487365445887
# all_train_score_W_Combined_a 0.8485040537196699
# test_score_W_combined_n 0.796652762097661
# test_score_W_combined_a 0.7957714841063913
# Combine Neurons Number :24
#  mxn 0 22
# neuron unit number: 22
#  mxn 121
# all_train_score_W0_n 0.8461976046027658
# all_train_score_W0_a 0.8715755763241388
# test_score_W0_n 0.8193171652771937
# test_score_W0_a  0.7808723662770436
# all_train_score_W_Combined_n 0.872579524856133
# all_train_score_W_Combined_a 0.8955446599872096
# test_score_W_combined_n 0.7957470449084165
# test_score_W_combined_a 0.7978601764129369
# Not good nmi result !!!!!
# Combine Neurons Number :25
#  mxn 0 23
# neuron unit number: 23
#  mxn 23
# all_train_score_W0_n 0.8102084372868193
# all_train_score_W0_a 0.8258587989147538
# test_score_W0_n 0.7494323648325599
# test_score_W0_a  0.7379326712428801
# all_train_score_W_Combined_n 0.8289885656413034
# all_train_score_W_Combined_a 0.8678285527479223
# test_score_W_combined_n 0.9217784300507554
# test_score_W_combined_a 0.9273854165711614
# Combine Neurons Number :26
#  mxn 0 24
# neuron unit number: 24
#  mxn 144
# all_train_score_W0_n 0.8555146204949725
# all_train_score_W0_a 0.8921983040900856
# test_score_W0_n 0.661206654756121
# test_score_W0_a  0.5851675169911407
# all_train_score_W_Combined_n 0.8555146204949725
# all_train_score_W_Combined_a 0.8921983040900856
# test_score_W_combined_n 0.9217784300507554
# test_score_W_combined_a 0.9273854165711614
# Combine Neurons Number :26
#  mxn 0 25
# neuron unit number: 25
#  mxn 25
# all_train_score_W0_n 0.8243487365445887
# all_train_score_W0_a 0.8485040537196699
# test_score_W0_n 0.7027907076334549
# test_score_W0_a  0.6447743667169938
# all_train_score_W_Combined_n 0.8682169599696015
# all_train_score_W_Combined_a 0.8956913156758383
# test_score_W_combined_n 0.796652762097661
# test_score_W_combined_a 0.7957714841063913
# Combine Neurons Number :25
#  mxn 0 26
# neuron unit number: 26
#  mxn 169
# all_train_score_W0_n 0.8204866362956889
# all_train_score_W0_a 0.8259077666453493
# test_score_W0_n 0.7815935097317677
# test_score_W0_a  0.7264840771370158
# all_train_score_W_Combined_n 0.8580349804304526
# all_train_score_W_Combined_a 0.8483763255955962
# test_score_W_combined_n 1.0
# test_score_W_combined_a 1.0
# Combine Neurons Number :31
#  mxn 0 27
# neuron unit number: 27
#  mxn 27
# all_train_score_W0_n 0.873823453029809
# all_train_score_W0_a 0.8715033515715673
# test_score_W0_n 0.812212541579008
# test_score_W0_a  0.8189960424911477
# all_train_score_W_Combined_n 0.9110046423661738
# all_train_score_W_Combined_a 0.9203925937896017
# test_score_W_combined_n 0.9217784300507554
# test_score_W_combined_a 0.9273854165711614
# Combine Neurons Number :32
#  mxn 0 28
# neuron unit number: 28
#  mxn 196
# all_train_score_W0_n 0.873823453029809
# all_train_score_W0_a 0.8715033515715673
# test_score_W0_n 0.6428483718769135
# test_score_W0_a  0.5683706190110076
# all_train_score_W_Combined_n 0.873823453029809
# all_train_score_W_Combined_a 0.8715033515715673
# test_score_W_combined_n 0.7957470449084165
# test_score_W_combined_a 0.7978601764129369
# Combine Neurons Number :34
#  mxn 0 29
# neuron unit number: 29
#  mxn 29
# all_train_score_W0_n 0.8947906447607352
# all_train_score_W0_a 0.9206158811855276
# test_score_W0_n 0.8021526785156629
# test_score_W0_a  0.7554940446233853
# all_train_score_W_Combined_n 0.9217612805184228
# all_train_score_W_Combined_a 0.9461899644359483
# test_score_W_combined_n 0.9217784300507554
# test_score_W_combined_a 0.9273854165711614
# Combine Neurons Number :28
#  mxn 0 30
# neuron unit number: 30
#  mxn 225
# all_train_score_W0_n 0.8069883724860829
# all_train_score_W0_a 0.8443648202147428
# test_score_W0_n 0.7963560131788909
# test_score_W0_a  0.790514614603318
# all_train_score_W_Combined_n 0.8068522440201391
# all_train_score_W_Combined_a 0.8432729190232784
# test_score_W_combined_n 0.7494323648325599
# test_score_W_combined_a 0.7379326712428801
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :31
#  mxn 0 31
# neuron unit number: 31
#  mxn 31
# all_train_score_W0_n 0.8713388962672578
# all_train_score_W0_a 0.8913079156211706
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_Combined_n 0.8713388962672578
# all_train_score_W_Combined_a 0.8913079156211706
# test_score_W_combined_n 0.9217784300507554
# test_score_W_combined_a 0.9273854165711614
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :29
#  mxn 0 32
# neuron unit number: 32
#  mxn 256
# all_train_score_W0_n 0.8064087271319668
# all_train_score_W0_a 0.8044634581451404
# test_score_W0_n 0.6382071571797956
# test_score_W0_a  0.6063349693886675
# all_train_score_W_Combined_n 0.8102084372868193
# all_train_score_W_Combined_a 0.8258587989147538
# test_score_W_combined_n 0.7494323648325599
# test_score_W_combined_a 0.7379326712428801
# Combine Neurons Number :31
#  mxn 0 33
# neuron unit number: 33
#  mxn 33
# all_train_score_W0_n 0.8204866362956889
# all_train_score_W0_a 0.8259077666453493
# test_score_W0_n 0.5495593123188057
# test_score_W0_a  0.4778268251273345
# all_train_score_W_Combined_n 0.872579524856133
# all_train_score_W_Combined_a 0.8955446599872096
# test_score_W_combined_n 0.8445569398503836
# test_score_W_combined_a 0.8599295311815394
# Combine Neurons Number :28
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.703343  0.114523  0.020569   0.661336  0.745351
# 1  test_score_W'  31.0  0.823732  0.092539  0.016621   0.789788  0.857676
# 2       combined  62.0  0.763538  0.119769  0.015211   0.733122  0.793953
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1204
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -4.5525
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.1563
# 7                                   Hedge's g =   -1.1418
# 8                               Glass's delta =   -1.0512
# 9                                 Pearson's r =    0.5067
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.703343  0.114523  0.020569   0.661336  0.745351
# 1  test_score_W'  31.0  0.802468  0.118628  0.021306   0.758955  0.845981
# 2       combined  62.0  0.752906  0.125968  0.015998   0.720916  0.784896
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0991
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -3.3471
# 3                       Two side test p value =    0.0014
# 4                      Difference < 0 p value =    0.0007
# 5                      Difference > 0 p value =    0.9993
# 6                                   Cohen's d =   -0.8502
# 7                                   Hedge's g =   -0.8395
# 8                               Glass's delta =   -0.8655
# 9                                 Pearson's r =    0.3967
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 33
class_num = 3
dim_num = 4
best_num = 12
elbow_num = 1
row = 2
column = 2
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )   

experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# neuron unit number: 3
# all_train_score_W0_n 0.6690586714235337
# all_train_score_W0_a 0.5630805849100265
# test_score_W0_n 0.5489257089660707
# test_score_W0_a  0.44123267458455284
# all_train_score_W_Combined_n 0.5875770039072967
# all_train_score_W_Combined_a 0.5834549446087078
# test_score_W_combined_n 0.5091453394319059
# test_score_W_combined_a 0.410908491706031
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :7
# neuron unit number: 4
# all_train_score_W0_n 0.4590191699492501
# all_train_score_W0_a 0.4531269606243883
# test_score_W0_n 0.37101905070984187
# test_score_W0_a  0.22509829619921362
# all_train_score_W_Combined_n 0.7059933236442323
# all_train_score_W_Combined_a 0.7062840658148352
# test_score_W_combined_n 0.6957374367880687
# test_score_W_combined_a 0.6586489393981187
# Combine Neurons Number :9
# neuron unit number: 5
# all_train_score_W0_n 0.4755460442658902
# all_train_score_W0_a 0.44542598038667547
# test_score_W0_n 0.4366788776327436
# test_score_W0_a  0.2893500391542678
# all_train_score_W_Combined_n 0.7520374799236966
# all_train_score_W_Combined_a 0.7559221496671377
# test_score_W_combined_n 0.6770935662486072
# test_score_W_combined_a 0.5800481367748361
# Combine Neurons Number :8
# neuron unit number: 6
# all_train_score_W0_n 0.7174074325440948
# all_train_score_W0_a 0.6866664126209893
# test_score_W0_n 0.808002419080367
# test_score_W0_a  0.7531445669640383
# all_train_score_W_Combined_n 0.7130655332041185
# all_train_score_W_Combined_a 0.7288423814740275
# test_score_W_combined_n 0.6737574856655092
# test_score_W_combined_a 0.6165656900987634
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :12
# neuron unit number: 7
# all_train_score_W0_n 0.7013194232983115
# all_train_score_W0_a 0.6090536261873302
# test_score_W0_n 0.6080847660482139
# test_score_W0_a  0.5319274206497886
# all_train_score_W_Combined_n 0.6964765850140782
# all_train_score_W_Combined_a 0.6772304205553928
# test_score_W_combined_n 0.7217121569674992
# test_score_W_combined_a 0.7092629239068557
# Combine Neurons Number :10
# neuron unit number: 8
# all_train_score_W0_n 0.8252919462669418
# all_train_score_W0_a 0.8441049198634569
# test_score_W0_n 0.7375414745558182
# test_score_W0_a  0.7032948792430908
# all_train_score_W_Combined_n 0.8941630655129792
# all_train_score_W_Combined_a 0.9179972729473832
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :21
# neuron unit number: 9
# all_train_score_W0_n 0.7045581582649187
# all_train_score_W0_a 0.6723423322504761
# test_score_W0_n 0.7136424850253061
# test_score_W0_a  0.553980996068152
# all_train_score_W_Combined_n 0.7670611928570747
# all_train_score_W_Combined_a 0.7419190221923503
# test_score_W_combined_n 0.7136424850253061
# test_score_W_combined_a 0.553980996068152
# Combine Neurons Number :14
# neuron unit number: 10
# all_train_score_W0_n 0.8520148001594926
# all_train_score_W0_a 0.8672843050929648
# test_score_W0_n 0.8009820461493606
# test_score_W0_a  0.804849201655825
# all_train_score_W_Combined_n 0.8716195785203926
# all_train_score_W_Combined_a 0.8922290101649087
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :29
# neuron unit number: 11
# all_train_score_W0_n 0.7718868246552435
# all_train_score_W0_a 0.7760422648443781
# test_score_W0_n 0.6513314162893643
# test_score_W0_a  0.524195320224102
# all_train_score_W_Combined_n 0.7718868246552435
# all_train_score_W_Combined_a 0.7760422648443781
# test_score_W_combined_n 0.693867134833372
# test_score_W_combined_a 0.6160026597218374
# Combine Neurons Number :18
# neuron unit number: 12
# all_train_score_W0_n 0.8256534189890978
# all_train_score_W0_a 0.8433175609320597
# test_score_W0_n 0.6654711512678282
# test_score_W0_a  0.5693872021220462
# all_train_score_W_Combined_n 0.8716195785203926
# all_train_score_W_Combined_a 0.8922290101649087
# test_score_W_combined_n 0.7225991378413997
# test_score_W_combined_a 0.7054542458530155
# Combine Neurons Number :34
# neuron unit number: 13
# all_train_score_W0_n 0.7782364424733458
# all_train_score_W0_a 0.7787750059875711
# test_score_W0_n 0.7426163791002159
# test_score_W0_a  0.617686812125893
# all_train_score_W_Combined_n 0.7327575658785181
# all_train_score_W_Combined_a 0.751930416259874
# test_score_W_combined_n 0.7610095767734243
# test_score_W_combined_a 0.6576479375881816
# Combine Neurons Number :18
# neuron unit number: 14
# all_train_score_W0_n 0.8449617998748724
# all_train_score_W0_a 0.8674703401169829
# test_score_W0_n 0.7022295097353846
# test_score_W0_a  0.5605550883095037
# all_train_score_W_Combined_n 0.8449617998748724
# all_train_score_W_Combined_a 0.8674703401169829
# test_score_W_combined_n 0.7375414745558182
# test_score_W_combined_a 0.7032948792430908
# Combine Neurons Number :42
# neuron unit number: 15
# all_train_score_W0_n 0.7791003838469059
# all_train_score_W0_a 0.7759793722316539
# test_score_W0_n 0.7375414745558182
# test_score_W0_a  0.7032948792430908
# all_train_score_W_Combined_n 0.8228332949566197
# all_train_score_W_Combined_a 0.8436246992782679
# test_score_W_combined_n 0.808002419080367
# test_score_W_combined_a 0.7531445669640383
# Combine Neurons Number :23
# neuron unit number: 16
# all_train_score_W0_n 0.8716195785203926
# all_train_score_W0_a 0.8922290101649087
# test_score_W0_n 0.8222861250693487
# test_score_W0_a  0.7902838582121169
# all_train_score_W_Combined_n 0.9103117576150148
# all_train_score_W_Combined_a 0.917882163776272
# test_score_W_combined_n 0.9233084678434053
# test_score_W_combined_a 0.9320279028891574
# Combine Neurons Number :50
# neuron unit number: 17
# all_train_score_W0_n 0.7302314127668322
# all_train_score_W0_a 0.754059853477063
# test_score_W0_n 0.7610095767734243
# test_score_W0_a  0.6576479375881816
# all_train_score_W_Combined_n 0.7807497564063091
# all_train_score_W_Combined_a 0.7959496190804334
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :25
# neuron unit number: 18
# all_train_score_W0_n 0.9103117576150148
# all_train_score_W0_a 0.917882163776272
# test_score_W0_n 0.6071037470521724
# test_score_W0_a  0.6144303724432392
# all_train_score_W_Combined_n 0.9605247754412919
# all_train_score_W_Combined_a 0.9718374472748589
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :49
# neuron unit number: 19
# all_train_score_W0_n 0.8420996500243991
# all_train_score_W0_a 0.8201053477368092
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_Combined_n 0.7885097638971397
# all_train_score_W_Combined_a 0.7677566045907319
# test_score_W_combined_n 0.9227759370196875
# test_score_W_combined_a 0.9329068285938897
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :24
# neuron unit number: 20
# all_train_score_W0_n 0.9103117576150148
# all_train_score_W0_a 0.917882163776272
# test_score_W0_n 0.5894062028649794
# test_score_W0_a  0.5159481146998763
# all_train_score_W_Combined_n 0.8904172700149433
# all_train_score_W_Combined_a 0.8921382162596853
# test_score_W_combined_n 0.7562042794722178
# test_score_W_combined_a 0.7567169069462647
# Combine Neurons Number :50
# neuron unit number: 21
# all_train_score_W0_n 0.7953645876251556
# all_train_score_W0_a 0.8194764278664879
# test_score_W0_n 0.7269339134478248
# test_score_W0_a  0.5831044710534988
# all_train_score_W_Combined_n 0.8324879497219305
# all_train_score_W_Combined_a 0.8677790170084408
# test_score_W_combined_n 0.7071610726064683
# test_score_W_combined_a 0.6388596442622042
# Not good nmi result !!!!!
# Combine Neurons Number :27
# neuron unit number: 22
# all_train_score_W0_n 0.9331437607583546
# all_train_score_W0_a 0.9444564898542221
# test_score_W0_n 0.7104070473514229
# test_score_W0_a  0.6514270728615761
# all_train_score_W_Combined_n 0.9331437607583546
# all_train_score_W_Combined_a 0.9444564898542221
# test_score_W_combined_n 0.9233084678434053
# test_score_W_combined_a 0.9320279028891574
# Combine Neurons Number :58
# neuron unit number: 23
# all_train_score_W0_n 0.8128452723693629
# all_train_score_W0_a 0.8425870747695545
# test_score_W0_n 0.7610095767734243
# test_score_W0_a  0.6576479375881816
# all_train_score_W_Combined_n 0.8672130643624698
# all_train_score_W_Combined_a 0.8924402693448403
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :29
# neuron unit number: 24
# all_train_score_W0_n 0.9103117576150148
# all_train_score_W0_a 0.917882163776272
# test_score_W0_n 0.5339825309939117
# test_score_W0_a  0.400490289066262
# all_train_score_W_Combined_n 0.9103117576150148
# all_train_score_W_Combined_a 0.917882163776272
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :56
# neuron unit number: 25
# all_train_score_W0_n 0.7903554971516632
# all_train_score_W0_a 0.7800558946273483
# test_score_W0_n 0.724323064193443
# test_score_W0_a  0.6059632707213184
# all_train_score_W_Combined_n 0.8228332949566197
# all_train_score_W_Combined_a 0.8436246992782679
# test_score_W_combined_n 0.7825764822956857
# test_score_W_combined_a 0.7028592009752314
# Combine Neurons Number :27
# neuron unit number: 26
# all_train_score_W0_n 0.9331437607583546
# all_train_score_W0_a 0.9444564898542221
# test_score_W0_n 0.5876494012487115
# test_score_W0_a  0.488819064119694
# all_train_score_W_Combined_n 0.9331437607583546
# all_train_score_W_Combined_a 0.9444564898542221
# test_score_W_combined_n 0.8015852966316769
# test_score_W_combined_a 0.8096781280896408
# Combine Neurons Number :59
# neuron unit number: 27
# all_train_score_W0_n 0.8228332949566197
# all_train_score_W0_a 0.8436246992782679
# test_score_W0_n 0.7269339134478248
# test_score_W0_a  0.5831044710534988
# all_train_score_W_Combined_n 0.807971206095828
# all_train_score_W_Combined_a 0.8213584609344327
# test_score_W_combined_n 0.7610095767734243
# test_score_W_combined_a 0.6576479375881816
# Combine Neurons Number :24
# neuron unit number: 28
# all_train_score_W0_n 0.9605247754412919
# all_train_score_W0_a 0.9718374472748589
# test_score_W0_n 0.8175406128633326
# test_score_W0_a  0.7248873807991576
# all_train_score_W_Combined_n 0.9605247754412919
# all_train_score_W_Combined_a 0.9718374472748589
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :65
# neuron unit number: 29
# all_train_score_W0_n 0.8904172700149433
# all_train_score_W0_a 0.8921382162596853
# test_score_W0_n 0.8015852966316769
# test_score_W0_a  0.8096781280896408
# all_train_score_W_Combined_n 0.8449617998748724
# all_train_score_W_Combined_a 0.8674703401169829
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Not good ari result !!!!!
# Combine Neurons Number :26
# neuron unit number: 30
# all_train_score_W0_n 0.9608261033431887
# all_train_score_W0_a 0.9731363971616775
# test_score_W0_n 0.6679317719154493
# test_score_W0_a  0.5601296119007291
# all_train_score_W_Combined_n 0.9215106810074365
# all_train_score_W_Combined_a 0.9453774557862973
# test_score_W_combined_n 0.7982253440193465
# test_score_W_combined_a 0.7970199178956971
# Combine Neurons Number :63
# neuron unit number: 31
# all_train_score_W0_n 0.8064690389883581
# all_train_score_W0_a 0.8427532818090375
# test_score_W0_n 0.6859979943908266
# test_score_W0_a  0.5963205108712178
# all_train_score_W_Combined_n 0.8064690389883581
# all_train_score_W_Combined_a 0.8427532818090375
# test_score_W_combined_n 0.761830064339905
# test_score_W_combined_a 0.7394303762398182
# Combine Neurons Number :33
# neuron unit number: 32
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_n 0.6833023074995715
# test_score_W0_a  0.5836267605633803
# all_train_score_W_Combined_n 1.0
# all_train_score_W_Combined_a 1.0
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :64
# neuron unit number: 33
# all_train_score_W0_n 0.8941630655129792
# all_train_score_W0_a 0.9179972729473832
# test_score_W0_n 0.7541396085257671
# test_score_W0_a  0.667441144360776
# all_train_score_W_Combined_n 0.8716195785203926
# all_train_score_W_Combined_a 0.8922290101649087
# test_score_W_combined_n 0.9233084678434053
# test_score_W_combined_a 0.9320279028891574
# Combine Neurons Number :35
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.693084  0.121349  0.021795   0.648573  0.737595
# 1  test_score_W'  31.0  0.791723  0.095539  0.017159   0.756679  0.826767
# 2       combined  62.0  0.742404  0.119178  0.015136   0.712138  0.772669
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0986
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -3.5559
# 3                       Two side test p value =    0.0007
# 4                      Difference < 0 p value =    0.0004
# 5                      Difference > 0 p value =    0.9996
# 6                                   Cohen's d =   -0.9032
# 7                                   Hedge's g =   -0.8919
# 8                               Glass's delta =   -0.8129
# 9                                 Pearson's r =    0.4172
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.693084  0.121349  0.021795   0.648573  0.737595
# 1  test_score_W'  31.0  0.755777  0.128500  0.023079   0.708643  0.802911
# 2       combined  62.0  0.724430  0.127912  0.016245   0.691947  0.756914
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0627
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -1.9750
# 3                       Two side test p value =    0.0529
# 4                      Difference < 0 p value =    0.0264
# 5                      Difference > 0 p value =    0.9736
# 6                                   Cohen's d =   -0.5016
# 7                                   Hedge's g =   -0.4953
# 8                               Glass's delta =   -0.5166
# 9                                 Pearson's r =    0.2471
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.8941630655129792
# all_train_score_W0_a 0.9179972729473832
# test_score_W0_n 0.7825764822956857
# test_score_W0_a  0.7028592009752314
# all_train_score_W_Combined_n 0.8823137958762395
# all_train_score_W_Combined_a 0.9185826190900074
# test_score_W_combined_n 0.7982253440193465
# test_score_W_combined_a 0.7970199178956971
# Combine Neurons Number :36
# all_train_score_W0_n 0.8672130643624698
# all_train_score_W0_a 0.8924402693448403
# test_score_W0_n 0.7890202128854529
# test_score_W0_a  0.7061293638956864
# all_train_score_W_Combined_n 0.9331437607583546
# all_train_score_W_Combined_a 0.9444564898542221
# test_score_W_combined_n 0.9233084678434053
# test_score_W_combined_a 0.9320279028891574
# Combine Neurons Number :36
# all_train_score_W0_n 0.8228332949566197
# all_train_score_W0_a 0.8436246992782679
# test_score_W0_n 0.6957374367880687
# test_score_W0_a  0.6586489393981187
# all_train_score_W_Combined_n 0.8345798871296013
# all_train_score_W_Combined_a 0.8431855605621578
# test_score_W_combined_n 0.7562042794722178
# test_score_W_combined_a 0.7567169069462647
# Combine Neurons Number :37
# all_train_score_W0_n 0.8449617998748724
# all_train_score_W0_a 0.8674703401169829
# test_score_W0_n 0.7338405349385463
# test_score_W0_a  0.6243977375881572
# all_train_score_W_Combined_n 0.9331437607583546
# all_train_score_W_Combined_a 0.9444564898542221
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :35
# all_train_score_W0_n 0.8184212025184799
# all_train_score_W0_a 0.8187855666419986
# test_score_W0_n 0.8222861250693487
# test_score_W0_a  0.7902838582121169
# all_train_score_W_Combined_n 0.8904172700149433
# all_train_score_W_Combined_a 0.8921382162596853
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :35
# all_train_score_W0_n 0.844787468905107
# all_train_score_W0_a 0.8678038921584827
# test_score_W0_n 0.7825764822956857
# test_score_W0_a  0.7028592009752314
# all_train_score_W_Combined_n 0.8281649738481874
# all_train_score_W_Combined_a 0.8654561434794793
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :37
# all_train_score_W0_n 0.8287205572749555
# all_train_score_W0_a 0.7978922686783989
# test_score_W0_n 0.800521062862383
# test_score_W0_a  0.8121391200628914
# all_train_score_W_Combined_n 0.8256534189890978
# all_train_score_W_Combined_a 0.8433175609320597
# test_score_W_combined_n 0.8015852966316769
# test_score_W_combined_a 0.8096781280896408
# Not good ari result !!!!!
# Combine Neurons Number :35
# all_train_score_W0_n 0.9212599649828938
# all_train_score_W0_a 0.9445653695854177
# test_score_W0_n 0.7486722410753476
# test_score_W0_a  0.6540979164586929
# all_train_score_W_Combined_n 0.9604679505630548
# all_train_score_W_Combined_a 0.9719083270836776
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :32
# all_train_score_W0_n 0.812581478408359
# all_train_score_W0_a 0.8390370304182995
# test_score_W0_n 0.808002419080367
# test_score_W0_a  0.7531445669640383
# all_train_score_W_Combined_n 0.8323153063447929
# all_train_score_W_Combined_a 0.8644001837344018
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :35
# all_train_score_W0_n 0.844787468905107
# all_train_score_W0_a 0.8678038921584827
# test_score_W0_n 0.7338405349385463
# test_score_W0_a  0.6243977375881572
# all_train_score_W_Combined_n 0.8285283058067744
# all_train_score_W_Combined_a 0.8673351305984384
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :35
# all_train_score_W0_n 0.844787468905107
# all_train_score_W0_a 0.8678038921584827
# test_score_W0_n 0.6405751422328823
# test_score_W0_a  0.547431706100737
# all_train_score_W_Combined_n 0.8672130643624698
# all_train_score_W_Combined_a 0.8924402693448403
# test_score_W_combined_n 0.808002419080367
# test_score_W_combined_a 0.7531445669640383
# Combine Neurons Number :37
# all_train_score_W0_n 0.8449617998748724
# all_train_score_W0_a 0.8674703401169829
# test_score_W0_n 0.763037112661083
# test_score_W0_a  0.6928760787410457
# all_train_score_W_Combined_n 0.8716195785203926
# all_train_score_W_Combined_a 0.8922290101649087
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :37
# all_train_score_W0_n 0.8720685974866498
# all_train_score_W0_a 0.8689037072518939
# test_score_W0_n 0.6623731376980971
# test_score_W0_a  0.5439081437380395
# all_train_score_W_Combined_n 0.8720685974866498
# all_train_score_W_Combined_a 0.8689037072518939
# test_score_W_combined_n 0.7610095767734243
# test_score_W_combined_a 0.6576479375881816
# Combine Neurons Number :36
# all_train_score_W0_n 0.8672130643624698
# all_train_score_W0_a 0.8924402693448403
# test_score_W0_n 0.8222861250693487
# test_score_W0_a  0.7902838582121169
# all_train_score_W_Combined_n 0.8449617998748724
# all_train_score_W_Combined_a 0.8674703401169829
# test_score_W_combined_n 0.7562042794722178
# test_score_W_combined_a 0.7567169069462647
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :36
# all_train_score_W0_n 0.8904172700149433
# all_train_score_W0_a 0.8921382162596853
# test_score_W0_n 0.6448612631019753
# test_score_W0_a  0.581276032328359
# all_train_score_W_Combined_n 0.9103117576150148
# all_train_score_W_Combined_a 0.917882163776272
# test_score_W_combined_n 0.7225991378413997
# test_score_W_combined_a 0.7054542458530155
# Combine Neurons Number :35
# all_train_score_W0_n 0.8345798871296013
# all_train_score_W0_a 0.8431855605621578
# test_score_W0_n 0.7177124821414124
# test_score_W0_a  0.649949083503055
# all_train_score_W_Combined_n 0.812581478408359
# all_train_score_W_Combined_a 0.8390370304182995
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :36
# all_train_score_W0_n 0.7718868246552435
# all_train_score_W0_a 0.7760422648443781
# test_score_W0_n 0.8864868858658332
# test_score_W0_a  0.8910861134794686
# all_train_score_W_Combined_n 0.8716195785203926
# all_train_score_W_Combined_a 0.8922290101649087
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :36
# all_train_score_W0_n 0.8163921330527141
# all_train_score_W0_a 0.7766067132546683
# test_score_W0_n 0.8150966135280114
# test_score_W0_a  0.8286983845738569
# all_train_score_W_Combined_n 0.8940255658920061
# all_train_score_W_Combined_a 0.9182036582730613
# test_score_W_combined_n 0.808002419080367
# test_score_W_combined_a 0.7531445669640383
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :36
# all_train_score_W0_n 0.8252919462669418
# all_train_score_W0_a 0.8441049198634569
# test_score_W0_n 0.7781281736314071
# test_score_W0_a  0.7157284327595143
# all_train_score_W_Combined_n 0.8256534189890978
# all_train_score_W_Combined_a 0.8433175609320597
# test_score_W_combined_n 0.808002419080367
# test_score_W_combined_a 0.7531445669640383
# Combine Neurons Number :38
# all_train_score_W0_n 0.8940255658920061
# all_train_score_W0_a 0.9182036582730613
# test_score_W0_n 0.8383576662582253
# test_score_W0_a  0.8082828450493816
# all_train_score_W_Combined_n 0.8520148001594926
# all_train_score_W_Combined_a 0.8672843050929648
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :37
# all_train_score_W0_n 0.8449617998748724
# all_train_score_W0_a 0.8674703401169829
# test_score_W0_n 0.7610095767734243
# test_score_W0_a  0.6576479375881816
# all_train_score_W_Combined_n 0.8449617998748724
# all_train_score_W_Combined_a 0.8674703401169829
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :39
# all_train_score_W0_n 0.8252919462669418
# all_train_score_W0_a 0.8441049198634569
# test_score_W0_n 0.7609227029510404
# test_score_W0_a  0.6826205023761032
# all_train_score_W_Combined_n 0.8188617082536593
# all_train_score_W_Combined_a 0.8199537917565515
# test_score_W_combined_n 0.8015852966316769
# test_score_W_combined_a 0.8096781280896408
# Combine Neurons Number :34
# all_train_score_W0_n 0.8058781046684586
# all_train_score_W0_a 0.8412314738248203
# test_score_W0_n 0.7177124821414124
# test_score_W0_a  0.649949083503055
# all_train_score_W_Combined_n 0.8449617998748724
# all_train_score_W_Combined_a 0.8674703401169829
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :35
# all_train_score_W0_n 0.8256534189890978
# all_train_score_W0_a 0.8433175609320597
# test_score_W0_n 0.7269339134478248
# test_score_W0_a  0.5831044710534988
# all_train_score_W_Combined_n 0.9212599649828938
# all_train_score_W_Combined_a 0.9445653695854177
# test_score_W_combined_n 0.7661883658271771
# test_score_W_combined_a 0.7542272363666456
# Combine Neurons Number :43
# all_train_score_W0_n 0.8713122200492643
# all_train_score_W0_a 0.8927705798002614
# test_score_W0_n 0.7136424850253061
# test_score_W0_a  0.553980996068152
# all_train_score_W_Combined_n 0.9212599649828938
# all_train_score_W_Combined_a 0.9445653695854177
# test_score_W_combined_n 0.8754902725281971
# test_score_W_combined_a 0.8680109232339392
# Combine Neurons Number :37
# all_train_score_W0_n 0.8520148001594926
# all_train_score_W0_a 0.8672843050929648
# test_score_W0_n 0.6647655733317535
# test_score_W0_a  0.6540977840309532
# all_train_score_W_Combined_n 0.8323153063447929
# all_train_score_W_Combined_a 0.8644001837344018
# test_score_W_combined_n 0.8015852966316769
# test_score_W_combined_a 0.8096781280896408
# Combine Neurons Number :32
# all_train_score_W0_n 0.8713122200492643
# all_train_score_W0_a 0.8927705798002614
# test_score_W0_n 0.618992087524187
# test_score_W0_a  0.48000111066376044
# all_train_score_W_Combined_n 0.8940255658920061
# all_train_score_W_Combined_a 0.9182036582730613
# test_score_W_combined_n 0.808002419080367
# test_score_W_combined_a 0.7531445669640383
# Combine Neurons Number :37
# all_train_score_W0_n 0.8228332949566197
# all_train_score_W0_a 0.8436246992782679
# test_score_W0_n 0.8009820461493606
# test_score_W0_a  0.804849201655825
# all_train_score_W_Combined_n 0.8508373168612583
# all_train_score_W_Combined_a 0.8634941912421805
# test_score_W_combined_n 0.9233084678434053
# test_score_W_combined_a 0.9320279028891574
# Combine Neurons Number :34
# all_train_score_W0_n 0.8345798871296013
# all_train_score_W0_a 0.8431855605621578
# test_score_W0_n 0.7338405349385463
# test_score_W0_a  0.6243977375881572
# all_train_score_W_Combined_n 0.8941630655129792
# all_train_score_W_Combined_a 0.9179972729473832
# test_score_W_combined_n 0.8383576662582253
# test_score_W_combined_a 0.8082828450493816
# Combine Neurons Number :36
# all_train_score_W0_n 0.8449617998748724
# all_train_score_W0_a 0.8674703401169829
# test_score_W0_n 0.8933765288215662
# test_score_W0_a  0.9109231599784056
# all_train_score_W_Combined_n 0.8520148001594926
# all_train_score_W_Combined_a 0.8672843050929648
# test_score_W_combined_n 0.9233084678434053
# test_score_W_combined_a 0.9320279028891574
# Combine Neurons Number :36
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.755272  0.068735  0.012549   0.729606  0.780938
# 1  test_score_W'  30.0  0.835849  0.053399  0.009749   0.815909  0.855788
# 2       combined  60.0  0.795560  0.073311  0.009464   0.776622  0.814498
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0806
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -5.0705
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.3092
# 7                                   Hedge's g =   -1.2922
# 8                               Glass's delta =   -1.1723
# 9                                 Pearson's r =    0.5542
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.755272  0.068735  0.012549   0.729606  0.780938
# 1  test_score_W'  30.0  0.819291  0.067409  0.012307   0.794120  0.844462
# 2       combined  60.0  0.787281  0.074818  0.009659   0.767954  0.806609
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0640
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -3.6422
# 3                       Two side test p value =    0.0006
# 4                      Difference < 0 p value =    0.0003
# 5                      Difference > 0 p value =    0.9997
# 6                                   Cohen's d =   -0.9404
# 7                                   Hedge's g =   -0.9282
# 8                               Glass's delta =   -0.9314
# 9                                 Pearson's r =    0.4314
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
