# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv_training = pd.read_csv("Crowdsourced Mapping/training.csv")
csv_test = pd.read_csv("Crowdsourced Mapping/testing.csv")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_training,"class")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_test,"class")
dataread.initializedataset_CM(csv_training,csv_test)

# %%
som = newSom.SOM(m= 6, n= 2, dim=28)  # dim = i-1, as the first feature is the class label
optimize_W1 = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,6)
optimize_W1.run(20,0)
# Out:
# Error Data percentage 0.26932195353247984
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6088028169014085
# error_data0_score_W0 0.6014084507042253
# combinedweight shape 0: (24, 28)
# right_data0_score_W' 0.9068137573004542
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6291629162916291
# error_data1_score_W0 0.25112511251125114
# combinedweight shape1 : (36, 28)
# right_data1_score_W' 0.788316946211683
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5097087378640777
# error_data2_score_W0 0.33980582524271846
# combinedweight shape1 : (48, 28)
# right_data2_score_W' 0.6967095851216023
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40594059405940597
# error_data3_score_W0 0.2376237623762376
# combinedweight shape1 : (60, 28)
# right_data3_score_W' 0.7
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5833333333333334
# error_data4_score_W0 0.325
# combinedweight shape1 : (72, 28)
# right_data4_score_W' 0.6829268292682927
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.56
# error_data5_score_W0 0.3
# combinedweight shape1 : (84, 28)
# right_data5_score_W' 0.5428571428571428
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6818181818181818
# error_data6_score_W0 0.2727272727272727
# combinedweight shape1 : (96, 28)
# right_data6_score_W' 0.5714285714285714
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.2857142857142857
# combinedweight shape1 : (108, 28)
# right_data7_score_W' 0.7333333333333333
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7306780464675201
# all_train_score_W': 1.0
# test_score_W0 : 0.38333333333333336
# test_score_W': 0.61

# %%
#local scope 1

scoretype = 0
scope_num = 30
class_num = 6
dim_num = 28
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.23850165955429115
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6898608349900597
# error_data0_score_W0 0.5729622266401591
# combinedweight shape 0: (12, 28)
# right_data0_score_W' 0.9933997509339975
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7614983404457089
# all_train_score_W': 0.7614983404457089
# test_score_W0 : 0.37666666666666665
# test_score_W': 0.37666666666666665
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.19535324798482692
# right_data0_score_W0 1.0
# error_data0_score_W1 0.49029126213592233
# error_data0_score_W0 0.5393203883495146
# combinedweight shape 0: (24, 28)
# right_data0_score_W' 0.9285798467884502
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8046467520151731
# all_train_score_W': 0.8046467520151731
# test_score_W0 : 0.45
# test_score_W': 0.45
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.22465623518255098
# right_data0_score_W0 1.0
# error_data0_score_W1 0.718024482904179
# error_data0_score_W0 0.6006753904601098
# combinedweight shape 0: (36, 28)
# right_data0_score_W' 0.9667318982387475
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.775343764817449
# all_train_score_W': 0.775343764817449
# test_score_W0 : 0.41
# test_score_W': 0.41
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.22057847321005217
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6848667239896818
# error_data0_score_W0 0.6423043852106621
# combinedweight shape 0: (48, 28)
# right_data0_score_W' 0.9546173500425843
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7794215267899478
# all_train_score_W': 0.7794215267899478
# test_score_W0 : 0.4266666666666667
# test_score_W': 0.4266666666666667
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.20474158368895212
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5933302454840204
# error_data0_score_W0 0.5924038906901343
# combinedweight shape 0: (60, 28)
# right_data0_score_W' 0.8978058669210589
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7952584163110479
# all_train_score_W': 0.7952584163110479
# test_score_W0 : 0.43
# test_score_W': 0.43
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.1876718824087245
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5325922182920667
# error_data0_score_W0 0.5689742294087923
# combinedweight shape 0: (72, 28)
# right_data0_score_W' 0.901003969180481
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8123281175912754
# all_train_score_W': 0.8123281175912754
# test_score_W0 : 0.48333333333333334
# test_score_W': 0.48333333333333334
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.20094831673779043
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6559697970740915
# error_data0_score_W0 0.6210476639924493
# combinedweight shape 0: (84, 28)
# right_data0_score_W' 0.9162117256112035
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.7990516832622095
# all_train_score_W': 0.7990516832622095
# test_score_W0 : 0.44666666666666666
# test_score_W': 0.44666666666666666
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.1968705547652916
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6541425818882466
# error_data0_score_W0 0.5920038535645472
# combinedweight shape 0: (96, 28)
# right_data0_score_W' 0.9145117487306648
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8031294452347084
# all_train_score_W': 0.8031294452347084
# test_score_W0 : 0.43666666666666665
# test_score_W': 0.43666666666666665
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.18511142721669038
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5952868852459017
# error_data0_score_W0 0.5660860655737705
# combinedweight shape 0: (108, 28)
# right_data0_score_W' 0.89596182939602
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8148885727833096
# all_train_score_W': 0.8148885727833096
# test_score_W0 : 0.48
# test_score_W': 0.48
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.1768610715979137
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6680965147453083
# error_data0_score_W0 0.5495978552278821
# combinedweight shape 0: (120, 28)
# right_data0_score_W' 0.8953917050691245
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8231389284020862
# all_train_score_W': 0.8231389284020862
# test_score_W0 : 0.4666666666666667
# test_score_W': 0.4666666666666667
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.1793266951161688
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6250661025912215
# error_data0_score_W0 0.6118455843469064
# combinedweight shape 0: (132, 28)
# right_data0_score_W' 0.8879131037670441
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8206733048838312
# all_train_score_W': 0.8206733048838312
# test_score_W0 : 0.45
# test_score_W': 0.45
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.17610241820768135
# right_data0_score_W0 1.0
# error_data0_score_W1 0.69520732364028
# error_data0_score_W0 0.5374259558427571
# combinedweight shape 0: (144, 28)
# right_data0_score_W' 0.9012430939226519
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8238975817923186
# all_train_score_W': 0.8238975817923186
# test_score_W0 : 0.47333333333333333
# test_score_W': 0.47333333333333333
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.17316263632053105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6670317634173056
# error_data0_score_W0 0.6002190580503833
# combinedweight shape 0: (156, 28)
# right_data0_score_W' 0.9013648354169056
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8268373636794689
# all_train_score_W': 0.8268373636794689
# test_score_W0 : 0.4633333333333333
# test_score_W': 0.4633333333333333
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.16206733048838312
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6699824458747806
# error_data0_score_W0 0.5904037448800468
# combinedweight shape 0: (168, 28)
# right_data0_score_W' 0.8849026708918063
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8379326695116169
# all_train_score_W': 0.8379326695116169
# test_score_W0 : 0.47
# test_score_W': 0.47
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.16908487434803224
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6892877173303421
# error_data0_score_W0 0.5232753785754347
# combinedweight shape 0: (180, 28)
# right_data0_score_W' 0.8965989500114129
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8309151256519678
# all_train_score_W': 0.8309151256519678
# test_score_W0 : 0.4633333333333333
# test_score_W': 0.4633333333333333
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.17828354670459934
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6877659574468085
# error_data0_score_W0 0.5898936170212766
# combinedweight shape 0: (192, 28)
# right_data0_score_W' 0.8950952106174265
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8217164532954007
# all_train_score_W': 0.8217164532954007
# test_score_W0 : 0.47
# test_score_W': 0.47
# neuron unit number: 102
# *******************
#
# Error Data percentage 0.1745851114272167
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7354698533405758
# error_data0_score_W0 0.5855513307984791
# combinedweight shape 0: (204, 28)
# right_data0_score_W' 0.90234375
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8254148885727833
# all_train_score_W': 0.8254148885727833
# test_score_W0 : 0.4666666666666667
# test_score_W': 0.4666666666666667
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.1435751541014699
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7100396301188904
# error_data0_score_W0 0.5376486129458389
# combinedweight shape 0: (216, 28)
# right_data0_score_W' 0.8810762927693501
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.8564248458985301
# all_train_score_W': 0.8564248458985301
# test_score_W0 : 0.48
# test_score_W': 0.48
# neuron unit number: 114
# *******************
# Error Data percentage 0.15523944997629208
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6866218692730605
# error_data0_score_W0 0.5632254123396457
# combinedweight shape 0: (228, 28)
# right_data0_score_W' 0.8999775482712169
# Finish one training *********
# 1
#  Max Training Time !
