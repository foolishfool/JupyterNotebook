# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv_training = pd.read_csv("Crowdsourced Mapping/training.csv")
csv_test = pd.read_csv("Crowdsourced Mapping/testing.csv")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_training,"class")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_test,"class")
dataread.initializedataset_CM(csv_training,csv_test)

# %%
som = newSom.SOM(m= 6, n= 2, dim=28)  # dim = i-1, as the first feature is the class label
optimize_W1 = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,6)
optimize_W1.run(20,0)
# Out:
# Error Data percentage 0.26932195353247984
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6088028169014085
# error_data0_score_W0 0.6014084507042253
# combinedweight shape 0: (24, 28)
# right_data0_score_W' 0.9068137573004542
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6291629162916291
# error_data1_score_W0 0.25112511251125114
# combinedweight shape1 : (36, 28)
# right_data1_score_W' 0.788316946211683
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5097087378640777
# error_data2_score_W0 0.33980582524271846
# combinedweight shape1 : (48, 28)
# right_data2_score_W' 0.6967095851216023
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.40594059405940597
# error_data3_score_W0 0.2376237623762376
# combinedweight shape1 : (60, 28)
# right_data3_score_W' 0.7
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5833333333333334
# error_data4_score_W0 0.325
# combinedweight shape1 : (72, 28)
# right_data4_score_W' 0.6829268292682927
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.56
# error_data5_score_W0 0.3
# combinedweight shape1 : (84, 28)
# right_data5_score_W' 0.5428571428571428
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6818181818181818
# error_data6_score_W0 0.2727272727272727
# combinedweight shape1 : (96, 28)
# right_data6_score_W' 0.5714285714285714
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.2857142857142857
# combinedweight shape1 : (108, 28)
# right_data7_score_W' 0.7333333333333333
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7306780464675201
# all_train_score_W': 1.0
# test_score_W0 : 0.38333333333333336
# test_score_W': 0.61

# %%
#local scope 1

scoretype = 1
scope_num = 30
class_num = 6
dim_num = 28
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.29530583214793743
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3492436324119102
# error_data0_score_W0 0.0
# combinedweight shape 0: (12, 28)
# right_data0_score_W' 6.4828938545308676e-15
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3331024884246174
# error_data1_score_W0 6.720832602784795e-16
# combinedweight shape1 : (18, 28)
# right_data1_score_W' 0.4720735847722438
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2707307016112808
# error_data2_score_W0 0.0
# combinedweight shape1 : (24, 28)
# right_data2_score_W' 0.46532173397622084
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2924200428499725
# error_data3_score_W0 0.0
# combinedweight shape1 : (30, 28)
# right_data3_score_W' 0.487394794766246
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.16160265204655114
# error_data4_score_W0 0.0
# combinedweight shape1 : (36, 28)
# right_data4_score_W' 0.1431908574367521
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5373735836565796
# error_data5_score_W0 0.0
# combinedweight shape1 : (42, 28)
# right_data5_score_W' 0.10657815904656882
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.0
# combinedweight shape1 : (48, 28)
# right_data6_score_W' 0.4320373272855248
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.0
# all_train_score_W': 1.0
# test_score_W0 : 0.0
# test_score_W': 0.37611234539797417
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.23859649122807017
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24108264163228357
# error_data0_score_W0 0.3135338837737984
# combinedweight shape 0: (24, 28)
# right_data0_score_W' 0.44454856089918576
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.13085369636792515
# error_data1_score_W0 0.03295956316425039
# combinedweight shape1 : (36, 28)
# right_data1_score_W' 0.45298197008572477
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.16327742332449513
# error_data2_score_W0 0.06208152512261394
# combinedweight shape1 : (48, 28)
# right_data2_score_W' 0.12179007147164196
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.12820862526562637
# error_data3_score_W0 0.08760395352981479
# combinedweight shape1 : (60, 28)
# right_data3_score_W' 0.2685453856798691
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.26051215502574526
# error_data4_score_W0 0.09420114056737126
# combinedweight shape1 : (72, 28)
# right_data4_score_W' 0.3362673863718546
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2565672836612491
# error_data5_score_W0 0.10077952847449052
# combinedweight shape1 : (84, 28)
# right_data5_score_W' 0.3242899764534968
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.49135014623107004
# error_data6_score_W0 0.08164715803877146
# combinedweight shape1 : (96, 28)
# right_data6_score_W' 0.46953639192083946
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7335088253543874
# error_data7_score_W0 0.21223783884155178
# combinedweight shape1 : (108, 28)
# right_data7_score_W' 0.2856900976856682
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.0
# combinedweight shape1 : (120, 28)
# right_data8_score_W' 0.853012188864063
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.2732464263498007
# all_train_score_W': 1.0
# test_score_W0 : 0.2764694482280074
# test_score_W': 0.3322740993573433
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.21005215742057848
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2821224834295254
# error_data0_score_W0 0.4271563337099068
# combinedweight shape 0: (36, 28)
# right_data0_score_W' 0.4646833574674662
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.15485053559283035
# error_data1_score_W0 0.013634957114624981
# combinedweight shape1 : (54, 28)
# right_data1_score_W' 0.4379170505944796
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.18709163771050563
# error_data2_score_W0 0.030670648861053584
# combinedweight shape1 : (72, 28)
# right_data2_score_W' 0.38141257120577876
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.14284875324458177
# error_data3_score_W0 0.04533700847475923
# combinedweight shape1 : (90, 28)
# right_data3_score_W' 0.2751120302492118
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.19397487554503132
# error_data4_score_W0 0.11706096390217542
# combinedweight shape1 : (108, 28)
# right_data4_score_W' 0.14138709342211792
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.36456592027836054
# error_data5_score_W0 0.08421588529174821
# combinedweight shape1 : (126, 28)
# right_data5_score_W' 0.2533276010479687
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.8392089708035508
# error_data6_score_W0 0.11620215703568523
# combinedweight shape1 : (144, 28)
# right_data6_score_W' 0.4097416234608655
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.7020168761809934
# combinedweight shape1 : (162, 28)
# right_data7_score_W' 0.4252028972285866
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.34795269525500044
# all_train_score_W': 1.0
# test_score_W0 : 0.3880539065768686
# test_score_W': 0.35090748360140256
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.21697486960644854
# right_data0_score_W0 1.0
# error_data0_score_W1 0.29086035512973524
# error_data0_score_W0 0.3953405138340575
# combinedweight shape 0: (48, 28)
# right_data0_score_W' 0.37390578491593063
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2265698243716182
# error_data1_score_W0 0.05553797628827327
# combinedweight shape1 : (72, 28)
# right_data1_score_W' 0.5030405930525348
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.20058152091146036
# error_data2_score_W0 0.09144112358653353
# combinedweight shape1 : (96, 28)
# right_data2_score_W' 0.3672222853888851
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.22430379757729724
# error_data3_score_W0 0.05177919272498126
# combinedweight shape1 : (120, 28)
# right_data3_score_W' 0.33004562000263943
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.24129854735842443
# error_data4_score_W0 0.03386013380062828
# combinedweight shape1 : (144, 28)
# right_data4_score_W' 0.34236648255195146
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5174697260108755
# error_data5_score_W0 0.07200170832794346
# combinedweight shape1 : (168, 28)
# right_data5_score_W' 0.22813299682980648
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.9194726456904493
# error_data6_score_W0 0.27884924087839646
# combinedweight shape1 : (192, 28)
# right_data6_score_W' 0.45781598195605855
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 1.0
# Error data can be represented by W0 7
# combinedweight shape1 : (216, 28)
# right_data7_score_W' 0.7864950039035419
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.31586984541622803
# all_train_score_W': 1.0
# test_score_W0 : 0.313052670418064
# test_score_W': 0.3222803169819522
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.17951635846372688
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3036913438298132
# error_data0_score_W0 0.30716857007987564
# combinedweight shape 0: (60, 28)
# right_data0_score_W' 0.47587916237001926
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.15295771625291252
# error_data1_score_W0 0.038778992690361266
# combinedweight shape1 : (90, 28)
# right_data1_score_W' 0.627801755100677
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.22177895356818875
# error_data2_score_W0 0.041433720063568436
# combinedweight shape1 : (120, 28)
# right_data2_score_W' 0.20763837328816936
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.24728460633893598
# error_data3_score_W0 0.071479486380469
# combinedweight shape1 : (150, 28)
# right_data3_score_W' 0.32205438944483433
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.33607306014209387
# error_data4_score_W0 0.06394802783463197
# combinedweight shape1 : (180, 28)
# right_data4_score_W' 0.2862998978336968
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.7793964961600468
# error_data5_score_W0 0.10724121576524456
# combinedweight shape1 : (210, 28)
# right_data5_score_W' 0.3412698010511482
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.0
# combinedweight shape1 : (240, 28)
# right_data6_score_W' 0.7145629769702865
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.368804506733466
# all_train_score_W': 1.0
# test_score_W0 : 0.26726093713403964
# test_score_W': 0.3462575630200809
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.2060692271218587
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3479275467640242
# error_data0_score_W0 0.311750248282023
# combinedweight shape 0: (72, 28)
# right_data0_score_W' 0.4490500896578465
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.15038481460238037
# error_data1_score_W0 0.032537954496372444
# combinedweight shape1 : (108, 28)
# right_data1_score_W' 0.5609945424205123
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.21340531531494022
# error_data2_score_W0 0.04443165968706552
# combinedweight shape1 : (144, 28)
# right_data2_score_W' 0.2531436304748414
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3062653977187337
# error_data3_score_W0 0.043558492029323215
# combinedweight shape1 : (180, 28)
# right_data3_score_W' 0.3121725875316909
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5063777609661482
# error_data4_score_W0 0.11697494927051988
# combinedweight shape1 : (216, 28)
# right_data4_score_W' 0.15909579225779916
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.8443409065530258
# error_data5_score_W0 0.20704682607383182
# combinedweight shape1 : (252, 28)
# right_data5_score_W' 0.3143169893651714
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (288, 28)
# right_data6_score_W' 0.5951797347661995
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3282843683189174
# all_train_score_W': 1.0
# test_score_W0 : 0.34998549617883573
# test_score_W': 0.31463873826537375
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.20644855381697486
# right_data0_score_W0 1.0
# error_data0_score_W1 0.38509434729939196
# error_data0_score_W0 0.3391125120052557
# combinedweight shape 0: (84, 28)
# right_data0_score_W' 0.441088239012215
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.16509655216988012
# error_data1_score_W0 0.02133445234002774
# combinedweight shape1 : (126, 28)
# right_data1_score_W' 0.5100196359469924
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.21073777062258914
# error_data2_score_W0 0.0624849478932294
# combinedweight shape1 : (168, 28)
# right_data2_score_W' 0.2838464400337257
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.276020072282813
# error_data3_score_W0 0.0269482821459507
# combinedweight shape1 : (210, 28)
# right_data3_score_W' 0.29291943529009123
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5952486492528036
# error_data4_score_W0 0.061027216597941414
# combinedweight shape1 : (252, 28)
# right_data4_score_W' 0.2143116691777659
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.8484132108434458
# error_data5_score_W0 0.14952561185636512
# combinedweight shape1 : (294, 28)
# right_data5_score_W' 0.44369747804438864
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (336, 28)
# right_data6_score_W' 0.651230428986064
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3614678348407599
# all_train_score_W': 1.0
# test_score_W0 : 0.23437465860179962
# test_score_W': 0.34406253288902794
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.19914651493598862
# right_data0_score_W0 1.0
# error_data0_score_W1 0.39323277081903657
# error_data0_score_W0 0.39432773919454195
# combinedweight shape 0: (96, 28)
# right_data0_score_W' 0.5467225801361074
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.21337301071570827
# error_data1_score_W0 0.05097771312370001
# combinedweight shape1 : (144, 28)
# right_data1_score_W' 0.4952467677110141
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.21135307757876448
# error_data2_score_W0 0.05154896023348011
# combinedweight shape1 : (192, 28)
# right_data2_score_W' 0.3419495223644674
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3742502417354704
# error_data3_score_W0 0.03499647699156109
# combinedweight shape1 : (240, 28)
# right_data3_score_W' 0.327958353865286
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.7574482457639325
# error_data4_score_W0 0.11294553191619937
# combinedweight shape1 : (288, 28)
# right_data4_score_W' 0.39935009381108416
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 0.46553861800309987
# combinedweight shape1 : (336, 28)
# right_data5_score_W' 0.48425343702889256
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.34189980724663993
# all_train_score_W': 1.0
# test_score_W0 : 0.3755637344326665
# test_score_W': 0.3542365676154088
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.17354196301564723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2799508888920918
# error_data0_score_W0 0.36452216968087686
# combinedweight shape 0: (108, 28)
# right_data0_score_W' 0.5011436474234957
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20553996870494123
# error_data1_score_W0 0.03966338230908026
# combinedweight shape1 : (162, 28)
# right_data1_score_W' 0.4259368818139333
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2984624503980402
# error_data2_score_W0 0.06090900487324306
# combinedweight shape1 : (216, 28)
# right_data2_score_W' 0.19550771720382518
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3521287166188544
# error_data3_score_W0 0.05681826790052802
# combinedweight shape1 : (270, 28)
# right_data3_score_W' 0.34369699018592614
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.790464534629062
# error_data4_score_W0 0.08687729264393948
# combinedweight shape1 : (324, 28)
# right_data4_score_W' 0.28891485894305446
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 0.0
# combinedweight shape1 : (378, 28)
# right_data5_score_W' 0.519956155349662
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4089164128584021
# all_train_score_W': 1.0
# test_score_W0 : 0.33696228125121463
# test_score_W': 0.3693575106125764
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.1824561403508772
# right_data0_score_W0 1.0
# error_data0_score_W1 0.39051030320599217
# error_data0_score_W0 0.3669234890737953
# combinedweight shape 0: (120, 28)
# right_data0_score_W' 0.5039388106739616
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.25193998435965975
# error_data1_score_W0 0.03193270135875355
# combinedweight shape1 : (180, 28)
# right_data1_score_W' 0.558797491485943
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2946618569518267
# error_data2_score_W0 0.12991060379932412
# combinedweight shape1 : (240, 28)
# right_data2_score_W' 0.3557417845909601
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4815130404305994
# error_data3_score_W0 0.05557716570605163
# combinedweight shape1 : (300, 28)
# right_data3_score_W' 0.420650252091889
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.9474934609725808
# error_data4_score_W0 0.14842655722914752
# combinedweight shape1 : (360, 28)
# right_data4_score_W' 0.4254356900461713
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (420, 28)
# right_data5_score_W' 0.8533955828236109
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3862466630076974
# all_train_score_W': 1.0
# test_score_W0 : 0.34488024645259646
# test_score_W': 0.3315760763318018
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.17970602181128498
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32408550664929875
# error_data0_score_W0 0.35312732999313023
# combinedweight shape 0: (132, 28)
# right_data0_score_W' 0.5459005131668946
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2666671047410136
# error_data1_score_W0 0.042110958564356676
# combinedweight shape1 : (198, 28)
# right_data1_score_W' 0.4494771773117406
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3051076093768151
# error_data2_score_W0 0.06659235673973395
# combinedweight shape1 : (264, 28)
# right_data2_score_W' 0.40109605344088906
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.5644981630984951
# error_data3_score_W0 0.08818429018071604
# combinedweight shape1 : (330, 28)
# right_data3_score_W' 0.2587123695240737
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.8727870831586907
# error_data4_score_W0 0.37382568562279334
# combinedweight shape1 : (396, 28)
# right_data4_score_W' 0.3729090106016232
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (462, 28)
# right_data5_score_W' 0.7229864073683292
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.37594343562183874
# all_train_score_W': 1.0
# test_score_W0 : 0.37450951022820905
# test_score_W': 0.3374689981699087
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.18055950687529634
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3030229292588952
# error_data0_score_W0 0.3213430554995345
# combinedweight shape 0: (144, 28)
# right_data0_score_W' 0.5628602076831555
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.25396773026605185
# error_data1_score_W0 0.04589402890041401
# combinedweight shape1 : (216, 28)
# right_data1_score_W' 0.48809078787737736
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.25369353295762465
# error_data2_score_W0 0.042876315862686025
# combinedweight shape1 : (288, 28)
# right_data2_score_W' 0.28639195110891974
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.5215065305042643
# error_data3_score_W0 0.07545992852053324
# combinedweight shape1 : (360, 28)
# right_data3_score_W' 0.24039576550762923
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.9309783760732061
# error_data4_score_W0 0.14707410136950938
# combinedweight shape1 : (432, 28)
# right_data4_score_W' 0.41664409422401016
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (504, 28)
# right_data5_score_W' 0.7706640337659508
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3924454813868328
# all_train_score_W': 1.0
# test_score_W0 : 0.321358207449812
# test_score_W': 0.3211348209454796
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.16614509246088194
# right_data0_score_W0 1.0
# error_data0_score_W1 0.34861002097486954
# error_data0_score_W0 0.3668305073373013
# combinedweight shape 0: (156, 28)
# right_data0_score_W' 0.5505021752589498
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.22302971727830198
# error_data1_score_W0 0.06145879016787919
# combinedweight shape1 : (234, 28)
# right_data1_score_W' 0.4561122687448706
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3113995925242366
# error_data2_score_W0 0.05389859429715611
# combinedweight shape1 : (312, 28)
# right_data2_score_W' 0.30492222727739227
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6104770807487233
# error_data3_score_W0 0.11542152193786405
# combinedweight shape1 : (390, 28)
# right_data3_score_W' 0.3424349085015767
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.2960006724288832
# combinedweight shape1 : (468, 28)
# right_data4_score_W' 0.4647777546380326
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4332282088334985
# all_train_score_W': 1.0
# test_score_W0 : 0.3515250977586722
# test_score_W': 0.35998865344339764
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.15495495495495495
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3039802729504801
# error_data0_score_W0 0.31757015850531783
# combinedweight shape 0: (168, 28)
# right_data0_score_W' 0.5480048530205818
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27893115436924276
# error_data1_score_W0 0.027327203857063373
# combinedweight shape1 : (252, 28)
# right_data1_score_W' 0.4415406889810725
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3389374924180335
# error_data2_score_W0 0.06435410162146238
# combinedweight shape1 : (336, 28)
# right_data2_score_W' 0.2994023887750352
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6600100742765587
# error_data3_score_W0 0.12152124724820597
# combinedweight shape1 : (420, 28)
# right_data3_score_W' 0.29004326642270667
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.8720493136359168
# error_data4_score_W0 0.3119093961619932
# combinedweight shape1 : (504, 28)
# right_data4_score_W' 0.4842381480238795
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (588, 28)
# right_data5_score_W' 0.623004213318981
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.44141833391901414
# all_train_score_W': 1.0
# test_score_W0 : 0.32567693931980995
# test_score_W': 0.3617748777574953
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.16661925082977713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35876076556165337
# error_data0_score_W0 0.3331407894148239
# combinedweight shape 0: (180, 28)
# right_data0_score_W' 0.5206602261338974
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.30034701834451716
# error_data1_score_W0 0.03729808903321893
# combinedweight shape1 : (270, 28)
# right_data1_score_W' 0.5565071590757538
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.4373155403027133
# error_data2_score_W0 0.06727453170283676
# combinedweight shape1 : (360, 28)
# right_data2_score_W' 0.4023435933308715
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9103552904737032
# error_data3_score_W0 0.08567911670893982
# combinedweight shape1 : (450, 28)
# right_data3_score_W' 0.34260255783258375
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.2740175421212811
# combinedweight shape1 : (540, 28)
# right_data4_score_W' 0.6596312652365646
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4244088916750921
# all_train_score_W': 1.0
# test_score_W0 : 0.3526841193862879
# test_score_W': 0.31322901160833966
# neuron unit number: 96
# *******************
# Error Data percentage 0.16254148885727834
# right_data0_score_W0 1.0
# error_data0_score_W1 0.37406822038745646
# error_data0_score_W0 0.3261493300405047
# combinedweight shape 0: (192, 28)
# right_data0_score_W' 0.5608572552922767
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27299571565604286
# error_data1_score_W0 0.02980860770347338
# combinedweight shape1 : (288, 28)
# right_data1_score_W' 0.5560917028763217
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.36448231539889214
# error_data2_score_W0 0.03168256854920801
# combinedweight shape1 : (384, 28)
# right_data2_score_W' 0.3748978013965925
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.7869214136323756
# error_data3_score_W0 0.09570832047341764
# combinedweight shape1 : (480, 28)
# right_data3_score_W' 0.3395594016199993
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.5162375532111046
# combinedweight shape1 : (576, 28)
# right_data4_score_W' 0.548939713440151
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4315678783498651
# all_train_score_W': 1.0
# test_score_W0 : 0.3397924756396941
# test_score_W': 0.34108108952752486
# neuron unit number: 102
# *******************
#
# Error Data percentage 0.1512565196775723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3157870077105766
# error_data0_score_W0 0.3244333918730436
# combinedweight shape 0: (204, 28)
# right_data0_score_W' 0.496091560396649
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.30232864471281296
# error_data1_score_W0 0.05046942648954031
# combinedweight shape1 : (306, 28)
# right_data1_score_W' 0.4689440816376435
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.501444232531966
# error_data2_score_W0 0.06683375322285438
# combinedweight shape1 : (408, 28)
# right_data2_score_W' 0.3802641564853189
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9239978417364573
# error_data3_score_W0 0.13346975706125258
# combinedweight shape1 : (510, 28)
# right_data3_score_W' 0.3872439801144092
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.0
# combinedweight shape1 : (612, 28)
# right_data4_score_W' 0.7194548414453688
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4542935665928691
# all_train_score_W': 1.0
# test_score_W0 : 0.3311888995489093
# test_score_W': 0.28983239930564786
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.17363679468942628
# right_data0_score_W0 1.0
# error_data0_score_W1 0.38289265462032185
# error_data0_score_W0 0.37193370964321915
# combinedweight shape 0: (216, 28)
# right_data0_score_W' 0.5950775908301985
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2932911774936767
# error_data1_score_W0 0.04047952304339881
# combinedweight shape1 : (324, 28)
# right_data1_score_W' 0.49319198461756114
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3729797983735432
# error_data2_score_W0 0.056624844559531956
# combinedweight shape1 : (432, 28)
# right_data2_score_W' 0.37386153403760375
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.7670160909600061
# error_data3_score_W0 0.13640710559470495
# combinedweight shape1 : (540, 28)
# right_data3_score_W' 0.33620449184666656
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.5333333333333333
# combinedweight shape1 : (648, 28)
# right_data4_score_W' 0.698024023056484
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3946810412801024
# all_train_score_W': 1.0
# test_score_W0 : 0.3073035348700653
# test_score_W': 0.2777457933023834
# neuron unit number: 114
# *******************
#
# Error Data percentage 0.1478425794215268
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3731704014249173
# error_data0_score_W0 0.33326551690778855
# combinedweight shape 0: (228, 28)
# right_data0_score_W' 0.5757937247314727
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3219545728817064
# error_data1_score_W0 0.03474509428292728
# combinedweight shape1 : (342, 28)
# right_data1_score_W' 0.4586553486160551
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5315995094530734
# error_data2_score_W0 0.05712195190387457
# combinedweight shape1 : (456, 28)
# right_data2_score_W' 0.39245185782358233
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.943972629362639
# error_data3_score_W0 0.2509420324352541
# combinedweight shape1 : (570, 28)
# right_data3_score_W' 0.39630032168556195
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (684, 28)
# right_data4_score_W' 0.5688830905670132
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.47600787497931907
# all_train_score_W': 1.0
# test_score_W0 : 0.3144961206438327
# test_score_W': 0.32439785621939804
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.15751541014698908
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3671606096230421
# error_data0_score_W0 0.38827223351426937
# combinedweight shape 0: (240, 28)
# right_data0_score_W' 0.5460101371202567
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.31545842298257226
# error_data1_score_W0 0.0536937557903046
# combinedweight shape1 : (360, 28)
# right_data1_score_W' 0.45395772712992355
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5281548116211068
# error_data2_score_W0 0.09410284466660791
# combinedweight shape1 : (480, 28)
# right_data2_score_W' 0.30910920477223464
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.7786550070538772
# error_data3_score_W0 0.07379189512095008
# combinedweight shape1 : (600, 28)
# right_data3_score_W' 0.37112428627714467
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.10584021904759336
# combinedweight shape1 : (720, 28)
# right_data4_score_W' 0.6772741298037804
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.44178983001696787
# all_train_score_W': 1.0
# test_score_W0 : 0.3963601754266174
# test_score_W': 0.3258417065905154
# neuron unit number: 126
# *******************
#
# Error Data percentage 0.15353247984826932
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3921866067313004
# error_data0_score_W0 0.28944801119938285
# combinedweight shape 0: (252, 28)
# right_data0_score_W' 0.5431472771061074
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3342516157634342
# error_data1_score_W0 0.023251197182058675
# combinedweight shape1 : (378, 28)
# right_data1_score_W' 0.5481191563730549
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5775293168612695
# error_data2_score_W0 0.08142352312506845
# combinedweight shape1 : (504, 28)
# right_data2_score_W' 0.40704796363810747
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.20104034737404583
# combinedweight shape1 : (630, 28)
# right_data3_score_W' 0.43146280906662055
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.44627195111113005
# all_train_score_W': 1.0
# test_score_W0 : 0.38715224419466593
# test_score_W': 0.3748388293552766
# neuron unit number: 132
# *******************
#
# Error Data percentage 0.14025604551920343
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35187873511381224
# error_data0_score_W0 0.3118350685650511
# combinedweight shape 0: (264, 28)
# right_data0_score_W' 0.5219002882968802
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.37029651262651636
# error_data1_score_W0 0.05484559893226066
# combinedweight shape1 : (396, 28)
# right_data1_score_W' 0.4800914755585901
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6301934234242227
# error_data2_score_W0 0.056937430013128794
# combinedweight shape1 : (528, 28)
# right_data2_score_W' 0.411544117147554
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.1706511924889884
# combinedweight shape1 : (660, 28)
# right_data3_score_W' 0.4066165188523299
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.48311442273082617
# all_train_score_W': 1.0
# test_score_W0 : 0.3363389546528228
# test_score_W': 0.3286488891003254
# neuron unit number: 138
# *******************
#
# Error Data percentage 0.13987671882408725
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3733578838350291
# error_data0_score_W0 0.3587311229272684
# combinedweight shape 0: (276, 28)
# right_data0_score_W' 0.5406908061720725
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.32338627099613904
# error_data1_score_W0 0.035186241891788615
# combinedweight shape1 : (414, 28)
# right_data1_score_W' 0.4418509737754263
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6215265952678743
# error_data2_score_W0 0.0479007236417928
# combinedweight shape1 : (552, 28)
# right_data2_score_W' 0.28018296215468513
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9412871307027125
# error_data3_score_W0 0.2395710546150814
# combinedweight shape1 : (690, 28)
# right_data3_score_W' 0.42916694909101116
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (828, 28)
# right_data4_score_W' 0.6190367522634116
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4979307777698363
# all_train_score_W': 1.0
# test_score_W0 : 0.3726747963684193
# test_score_W': 0.375529327288922
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.13769559032716927
# right_data0_score_W0 1.0
# error_data0_score_W1 0.39999559397901313
# error_data0_score_W0 0.34698881986129604
# combinedweight shape 0: (288, 28)
# right_data0_score_W' 0.5684354193268918
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.31917706251439715
# error_data1_score_W0 0.030002563438636522
# combinedweight shape1 : (432, 28)
# right_data1_score_W' 0.5319456234467594
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6501752829472166
# error_data2_score_W0 0.024205004539178756
# combinedweight shape1 : (576, 28)
# right_data2_score_W' 0.4384644549004351
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.3059697483581321
# combinedweight shape1 : (720, 28)
# right_data3_score_W' 0.5281105906247378
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4988874463037897
# all_train_score_W': 1.0
# test_score_W0 : 0.35736156610599384
# test_score_W': 0.3784595330200885
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.14499762920815554
# right_data0_score_W0 1.0
# error_data0_score_W1 0.44478690564776213
# error_data0_score_W0 0.30594543909202876
# combinedweight shape 0: (300, 28)
# right_data0_score_W' 0.589914166324763
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.414103827931827
# error_data1_score_W0 0.04723967711041298
# combinedweight shape1 : (450, 28)
# right_data1_score_W' 0.5520503808254669
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6017631028512133
# error_data2_score_W0 0.08947024999228242
# combinedweight shape1 : (600, 28)
# right_data2_score_W' 0.3946188833356697
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.8777092842691073
# error_data3_score_W0 0.11355932193259229
# combinedweight shape1 : (750, 28)
# right_data3_score_W' 0.5977422681143244
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (900, 28)
# right_data4_score_W' 0.6240110240302029
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.47253865830921743
# all_train_score_W': 1.0
# test_score_W0 : 0.3294058252429092
# test_score_W': 0.38547259726568894
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.12935040303461356
# right_data0_score_W0 1.0
# error_data0_score_W1 0.33515607339737774
# error_data0_score_W0 0.3271381216850078
# combinedweight shape 0: (312, 28)
# right_data0_score_W' 0.6080407731855473
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4203919497647092
# error_data1_score_W0 0.053691783626143116
# combinedweight shape1 : (468, 28)
# right_data1_score_W' 0.45851506186143387
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.707634983615995
# error_data2_score_W0 0.04698054184283782
# combinedweight shape1 : (624, 28)
# right_data2_score_W' 0.371885716290583
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.3505165297619205
# combinedweight shape1 : (780, 28)
# right_data3_score_W' 0.46542673558313197
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5074308601777922
# all_train_score_W': 1.0
# test_score_W0 : 0.36840725008494535
# test_score_W': 0.3098566692968809
# neuron unit number: 162
# *******************
#
# Error Data percentage 0.13494547178757704
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3742841445007665
# error_data0_score_W0 0.3043044009488664
# combinedweight shape 0: (324, 28)
# right_data0_score_W' 0.5558089855767518
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3897781163955534
# error_data1_score_W0 0.04778608700167613
# combinedweight shape1 : (486, 28)
# right_data1_score_W' 0.5370103695228404
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6124275446257083
# error_data2_score_W0 0.07202132540646204
# combinedweight shape1 : (648, 28)
# right_data2_score_W' 0.44027085315171327
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9225191928591646
# error_data3_score_W0 0.25230840254358344
# combinedweight shape1 : (810, 28)
# right_data3_score_W' 0.5539077260779616
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (972, 28)
# right_data4_score_W' 0.7903165009803398
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.49258981893359277
# all_train_score_W': 1.0
# test_score_W0 : 0.38729815213360036
# test_score_W': 0.3722288932077107
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.1330488383119962
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32686945822247476
# error_data0_score_W0 0.3045849702899314
# combinedweight shape 0: (336, 28)
# right_data0_score_W' 0.5704339557981255
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4125413585702593
# error_data1_score_W0 0.03407960931439276
# combinedweight shape1 : (504, 28)
# right_data1_score_W' 0.4690713790979016
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7587355210031969
# error_data2_score_W0 0.12089981122856042
# combinedweight shape1 : (672, 28)
# right_data2_score_W' 0.36506083019176433
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.4928724125936632
# combinedweight shape1 : (840, 28)
# right_data3_score_W' 0.5813950271962224
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.502073422321679
# all_train_score_W': 1.0
# test_score_W0 : 0.3370927750729027
# test_score_W': 0.27934331897811576
# neuron unit number: 174
# *******************
#
# Error Data percentage 0.12290184921763869
# right_data0_score_W0 1.0
# error_data0_score_W1 0.37175354506556546
# error_data0_score_W0 0.2898965307649447
# combinedweight shape 0: (348, 28)
# right_data0_score_W' 0.5177333069212381
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4903494189788433
# error_data1_score_W0 0.062257785366584745
# combinedweight shape1 : (522, 28)
# right_data1_score_W' 0.5298203792963523
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8350359297101488
# error_data2_score_W0 0.10364520741101399
# combinedweight shape1 : (696, 28)
# right_data2_score_W' 0.3846651117213965
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.39893927929656336
# combinedweight shape1 : (870, 28)
# right_data3_score_W' 0.7298988809394712
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5261199684651283
# all_train_score_W': 1.0
# test_score_W0 : 0.34893920450131327
# test_score_W': 0.28505517957452653
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.1337126600284495
# right_data0_score_W0 1.0
# error_data0_score_W1 0.34132260667951186
# error_data0_score_W0 0.31453600412018984
# combinedweight shape 0: (360, 28)
# right_data0_score_W' 0.5983112058945858
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3809588392721146
# error_data1_score_W0 0.034498115610510464
# combinedweight shape1 : (540, 28)
# right_data1_score_W' 0.4619777040596431
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7402473001198719
# error_data2_score_W0 0.06587221864577464
# combinedweight shape1 : (720, 28)
# right_data2_score_W' 0.3773245714617616
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.3851334387902764
# combinedweight shape1 : (900, 28)
# right_data3_score_W' 0.5777861553658515
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.502248374314477
# all_train_score_W': 1.0
# test_score_W0 : 0.37882881220848047
# test_score_W': 0.3379971202940946
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.23575154101469892
# right_data0_score_W0 1.0
# error_data0_score_W1 0.17686561737826537
# error_data0_score_W0 0.4452951797491498
# combinedweight shape 0: (12, 28)
# right_data0_score_W' 0.35615745438831387
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.1374768565849793
# error_data1_score_W0 0.02202146103714797
# combinedweight shape1 : (18, 28)
# right_data1_score_W' 0.34242529867110916
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.12272833778101139
# error_data2_score_W0 0.0667846282530876
# combinedweight shape1 : (24, 28)
# right_data2_score_W' 0.3219033757464364
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1969658033557562
# error_data3_score_W0 0.06062611604037769
# combinedweight shape1 : (30, 28)
# right_data3_score_W' 0.34752514899595144
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.15709347238848692
# error_data4_score_W0 0.10486420596115509
# combinedweight shape1 : (36, 28)
# right_data4_score_W' 0.4454890929108314
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.08370870836964794
# error_data5_score_W0 0.0779238335448827
# combinedweight shape1 : (42, 28)
# right_data5_score_W' 0.29938477927293444
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.15337902858689845
# error_data6_score_W0 0.05620608484116834
# combinedweight shape1 : (48, 28)
# right_data6_score_W' 0.2372260358170523
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.1959571527025668
# error_data7_score_W0 0.18274811070827132
# combinedweight shape1 : (54, 28)
# right_data7_score_W' 0.0852063181347123
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.4394932873542646
# error_data8_score_W0 0.1447712899830855
# combinedweight shape1 : (60, 28)
# right_data8_score_W' 0.6229408100339454
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.8640546073105768
# combinedweight shape1 : (66, 28)
# right_data9_score_W' 0.591867789620662
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.2711959210593813
# all_train_score_W': 1.0
# test_score_W0 : 0.27686889730052905
# test_score_W': 0.3866270529292141
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.23973447131341868
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2422477964547996
# error_data0_score_W0 0.21994999992595557
# combinedweight shape 0: (24, 28)
# right_data0_score_W' 0.3868996898639671
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.33784848648396
# error_data1_score_W0 0.09310963222283651
# combinedweight shape1 : (36, 28)
# right_data1_score_W' 0.2496780399434959
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2408409261287754
# error_data2_score_W0 0.0428371143911932
# combinedweight shape1 : (48, 28)
# right_data2_score_W' 0.2598835542695756
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.10442283627154869
# error_data3_score_W0 0.06083168760694608
# combinedweight shape1 : (60, 28)
# right_data3_score_W' 0.4016226213916617
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.28042465920391846
# error_data4_score_W0 0.07133769637572816
# combinedweight shape1 : (72, 28)
# right_data4_score_W' 0.2471088020778348
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.46509010780392934
# error_data5_score_W0 0.05550552545883961
# combinedweight shape1 : (84, 28)
# right_data5_score_W' 0.5031583417836888
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.9032931956800037
# error_data6_score_W0 0.09350354822353452
# combinedweight shape1 : (96, 28)
# right_data6_score_W' 0.5391713326953309
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 1.0
# Error data can be represented by W0 7
# combinedweight shape1 : (108, 28)
# right_data7_score_W' 0.8898335579791239
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.28172790367894407
# all_train_score_W': 1.0
# test_score_W0 : 0.2999550515827799
# test_score_W': 0.33841288957446974
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.28724513987671885
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3557953876143034
# error_data0_score_W0 0.037063046379146584
# combinedweight shape 0: (36, 28)
# right_data0_score_W' 0.046944528282590305
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3105199788576444
# error_data1_score_W0 0.027591228246424144
# combinedweight shape1 : (54, 28)
# right_data1_score_W' 0.5443558705927164
# Finish one training *********
# 2
# ...
# test_score_W': 0.3520675382586892
# neuron unit number: 102
# *******************
#
# Error Data percentage 0.1388335704125178
# right_data0_score_W0 1.0
# error_data0_score_W1 0.24935336690339246
# error_data0_score_W0 0.29957752241105284
# combinedweight shape 0: (204, 28)
# right_data0_score_W' 0.5933367990617833
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3074990801897828
# error_data1_score_W0 0.04275615242234539
# combinedweight shape1 : (306, 28)
# right_data1_score_W' 0.4785651732689094
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.44950675943730495
# error_data2_score_W0 0.07970814265034423
# combinedweight shape1 : (408, 28)
# right_data2_score_W' 0.3147648445444956
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.8151358672545997
# error_data3_score_W0 0.1942514798097582
# combinedweight shape1 : (510, 28)
# right_data3_score_W' 0.4186531493978475
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.822328362394686
# combinedweight shape1 : (612, 28)
# right_data4_score_W' 0.618087596934502
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.47743078189818616
# all_train_score_W': 1.0
# test_score_W0 : 0.38758098573208943
# test_score_W': 0.3327517811253615
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.16064485538169748
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3783309568159904
# error_data0_score_W0 0.3320319373109596
# combinedweight shape 0: (216, 28)
# right_data0_score_W' 0.5392340411644917
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2839125480071144
# error_data1_score_W0 0.04322599779857508
# combinedweight shape1 : (324, 28)
# right_data1_score_W' 0.449673268150211
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5242224158966133
# error_data2_score_W0 0.08090523253637244
# combinedweight shape1 : (432, 28)
# right_data2_score_W' 0.28195847395528884
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.8359109196861317
# error_data3_score_W0 0.18118902037125256
# combinedweight shape1 : (540, 28)
# right_data3_score_W' 0.35529039579034377
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.3437110184854508
# combinedweight shape1 : (648, 28)
# right_data4_score_W' 0.5520262070986522
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.43753503149125494
# all_train_score_W': 1.0
# test_score_W0 : 0.359997956897404
# test_score_W': 0.32754863400338413
# neuron unit number: 114
# *******************
#
# Error Data percentage 0.1389284020862968
# right_data0_score_W0 1.0
# error_data0_score_W1 0.37961508748339506
# error_data0_score_W0 0.3058367286776835
# combinedweight shape 0: (228, 28)
# right_data0_score_W' 0.5184901396695837
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3157926152032264
# error_data1_score_W0 0.04648044470849897
# combinedweight shape1 : (342, 28)
# right_data1_score_W' 0.4363792812786133
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.49754345044080067
# error_data2_score_W0 0.07262126929072939
# combinedweight shape1 : (456, 28)
# right_data2_score_W' 0.39075740662301955
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9093208408456908
# error_data3_score_W0 0.19007236895361243
# combinedweight shape1 : (570, 28)
# right_data3_score_W' 0.4493404778982894
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (684, 28)
# right_data4_score_W' 0.5729672311332482
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.49635101035610246
# all_train_score_W': 1.0
# test_score_W0 : 0.36771517906529283
# test_score_W': 0.3528266709264219
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.1647226173541963
# right_data0_score_W0 1.0
# error_data0_score_W1 0.31968838247029135
# error_data0_score_W0 0.2939086809725637
# combinedweight shape 0: (240, 28)
# right_data0_score_W' 0.5678675520381483
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2888382027577931
# error_data1_score_W0 0.04663995651192089
# combinedweight shape1 : (360, 28)
# right_data1_score_W' 0.43658413261243345
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.4316503613740418
# error_data2_score_W0 0.07097649571971931
# combinedweight shape1 : (480, 28)
# right_data2_score_W' 0.3677001051270894
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.7238245827480962
# error_data3_score_W0 0.1862340361095479
# combinedweight shape1 : (600, 28)
# right_data3_score_W' 0.433726408367557
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.2593900461016638
# combinedweight shape1 : (720, 28)
# right_data4_score_W' 0.7040490810653667
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.42165268011413654
# all_train_score_W': 1.0
# test_score_W0 : 0.3659492499728103
# test_score_W': 0.31509994419401466
# neuron unit number: 126
# *******************
#
# Error Data percentage 0.1379800853485064
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3032067001085918
# error_data0_score_W0 0.31842619762806146
# combinedweight shape 0: (252, 28)
# right_data0_score_W' 0.5818055445600627
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3525406681051523
# error_data1_score_W0 0.04384600852616945
# combinedweight shape1 : (378, 28)
# right_data1_score_W' 0.41953806599175325
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5791778525890622
# error_data2_score_W0 0.039813121139607374
# combinedweight shape1 : (504, 28)
# right_data2_score_W' 0.355027810928672
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.949505323791889
# error_data3_score_W0 0.27401156699705026
# combinedweight shape1 : (630, 28)
# right_data3_score_W' 0.38557215391928157
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (756, 28)
# right_data4_score_W' 0.7391976696322922
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4857459858853256
# all_train_score_W': 1.0
# test_score_W0 : 0.3703688413385856
# test_score_W': 0.32953464113957426
# neuron unit number: 132
# *******************
#
# Error Data percentage 0.13987671882408725
# right_data0_score_W0 1.0
# error_data0_score_W1 0.34628883272679084
# error_data0_score_W0 0.2945031966749456
# combinedweight shape 0: (264, 28)
# right_data0_score_W' 0.5349714002606314
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.34828124339285693
# error_data1_score_W0 0.043684807449519775
# combinedweight shape1 : (396, 28)
# right_data1_score_W' 0.5310297295749008
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5446452067682197
# error_data2_score_W0 0.04406356174708244
# combinedweight shape1 : (528, 28)
# right_data2_score_W' 0.4274676739843587
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9434305479604111
# error_data3_score_W0 0.19634777936470393
# combinedweight shape1 : (660, 28)
# right_data3_score_W' 0.49726314917204895
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (792, 28)
# right_data4_score_W' 0.7402420308981363
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.46865543712543317
# all_train_score_W': 1.0
# test_score_W0 : 0.38730212763849464
# test_score_W': 0.3221120415240776
# neuron unit number: 138
# *******************
#
# Error Data percentage 0.14006638217164533
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35447260020835536
# error_data0_score_W0 0.31312816543083233
# combinedweight shape 0: (276, 28)
# right_data0_score_W' 0.49990475778396715
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3747679106295126
# error_data1_score_W0 0.06184474015819325
# combinedweight shape1 : (414, 28)
# right_data1_score_W' 0.4581339929359435
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6717222438857595
# error_data2_score_W0 0.09406741981921164
# combinedweight shape1 : (552, 28)
# right_data2_score_W' 0.3998810002020695
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9234841638723542
# error_data3_score_W0 0.30986908916637884
# combinedweight shape1 : (690, 28)
# right_data3_score_W' 0.5125744721732794
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (828, 28)
# right_data4_score_W' 0.7509431297985985
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4820675203367546
# all_train_score_W': 1.0
# test_score_W0 : 0.31337936077662243
# test_score_W': 0.36683164597752865
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.1366524419155998
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3653595406089375
# error_data0_score_W0 0.32865254679688055
# combinedweight shape 0: (288, 28)
# right_data0_score_W' 0.5457241172641155
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.35474586497646965
# error_data1_score_W0 0.0296839490761129
# combinedweight shape1 : (432, 28)
# right_data1_score_W' 0.5320650596566654
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6336490038010409
# error_data2_score_W0 0.054791393443063025
# combinedweight shape1 : (576, 28)
# right_data2_score_W' 0.42402009694764276
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.3233375108526651
# combinedweight shape1 : (720, 28)
# right_data3_score_W' 0.4139138909483301
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5006259702586542
# all_train_score_W': 1.0
# test_score_W0 : 0.3216804192170397
# test_score_W': 0.3701049594457953
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.14746325272641062
# right_data0_score_W0 1.0
# error_data0_score_W1 0.45128505357573684
# error_data0_score_W0 0.3409802436519203
# combinedweight shape 0: (300, 28)
# right_data0_score_W' 0.6029781068194432
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.39727073964627285
# error_data1_score_W0 0.02499063312374267
# combinedweight shape1 : (450, 28)
# right_data1_score_W' 0.527219387710288
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8029258227391043
# error_data2_score_W0 0.05282326854873152
# combinedweight shape1 : (600, 28)
# right_data2_score_W' 0.3867859447985006
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.1459930036879852
# combinedweight shape1 : (750, 28)
# right_data3_score_W' 0.6330686045084912
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.47282302458628933
# all_train_score_W': 1.0
# test_score_W0 : 0.3489428491710301
# test_score_W': 0.3691908054182735
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.1330488383119962
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3555674307893526
# error_data0_score_W0 0.2835327319218642
# combinedweight shape 0: (312, 28)
# right_data0_score_W' 0.5498551222666856
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4076798775082737
# error_data1_score_W0 0.04955670005161996
# combinedweight shape1 : (468, 28)
# right_data1_score_W' 0.4491401270533962
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.808631818914974
# error_data2_score_W0 0.08290368055035802
# combinedweight shape1 : (624, 28)
# right_data2_score_W' 0.3806774297598224
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.3584511169268158
# combinedweight shape1 : (780, 28)
# right_data3_score_W' 0.4746667665871365
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4941707703808815
# all_train_score_W': 1.0
# test_score_W0 : 0.4002453458928412
# test_score_W': 0.3538260287240368
# neuron unit number: 162
# *******************
#
# Error Data percentage 0.1427216690374585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.39843179573354987
# error_data0_score_W0 0.2887732221427977
# combinedweight shape 0: (324, 28)
# right_data0_score_W' 0.6128618611922506
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.43757033418030594
# error_data1_score_W0 0.051274817382859925
# combinedweight shape1 : (486, 28)
# right_data1_score_W' 0.5372679857149603
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.858575511483225
# error_data2_score_W0 0.11158869406336723
# combinedweight shape1 : (648, 28)
# right_data2_score_W' 0.4181226564419039
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.6232710931088749
# combinedweight shape1 : (810, 28)
# right_data3_score_W' 0.5379750598714962
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4728428558792311
# all_train_score_W': 1.0
# test_score_W0 : 0.4183845215255291
# test_score_W': 0.372480274866277
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.13845424371740161
# right_data0_score_W0 1.0
# error_data0_score_W1 0.42485649816177995
# error_data0_score_W0 0.2954977468861963
# combinedweight shape 0: (336, 28)
# right_data0_score_W' 0.5707367707951235
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4322941652364454
# error_data1_score_W0 0.03862329985521692
# combinedweight shape1 : (504, 28)
# right_data1_score_W' 0.5829330543645003
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7721632994629245
# error_data2_score_W0 0.0701011859278543
# combinedweight shape1 : (672, 28)
# right_data2_score_W' 0.4053587498782109
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.8447914757396762
# error_data3_score_W0 0.2626970598970893
# combinedweight shape1 : (840, 28)
# right_data3_score_W' 0.6085583793549929
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (1008, 28)
# right_data4_score_W' 0.7891305866113808
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.48957484691471426
# all_train_score_W': 1.0
# test_score_W0 : 0.3355543518665726
# test_score_W': 0.34276964214721684
# neuron unit number: 174
# *******************
#
# Error Data percentage 0.1289710763394974
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4209188588892614
# error_data0_score_W0 0.2840251732800412
# combinedweight shape 0: (348, 28)
# right_data0_score_W' 0.5323783252880104
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4922485600190268
# error_data1_score_W0 0.07260088320078374
# combinedweight shape1 : (522, 28)
# right_data1_score_W' 0.5491955929535973
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8377957488649733
# error_data2_score_W0 0.10838594163255003
# combinedweight shape1 : (696, 28)
# right_data2_score_W' 0.455996113106832
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.3139638226595144
# combinedweight shape1 : (870, 28)
# right_data3_score_W' 0.5912885733884772
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
