# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])
csv_original_encode = csv


# class label do not need to onehot encoding
dataread.label_encoding(csv_original_encode,"Subscription Type")
#one hot encoding vs proposed
#dataread.label_encoding(csv_original_encode,["Country","Gender","Device"])

dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


# label encoding
dataread.original_encoding_data = csv
#*** -1 the class labe is not included 
dataread.original_encoded_feature_num = csv.shape[1]-1


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)




dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Subscription Type")
# Out:
# 11111111
# self.continuous_feature_num 3
# self.data_discrete_indexes ['Monthly Revenue', 'Country', 'Gender', 'Device']

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[0,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.4493333333333333
# test_discrete_score_W0_n 0.02975835285728234
# test_discrete_score_W0_a 0.041094568313962125
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.034478683400900184
# test_discrete_score_W_discrete_a 0.052594451749002076
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.49733333333333335
# test_discrete_score_W0_n 0.052563402366378575
# test_discrete_score_W0_a 0.06350177636769327
# test_discrete_score_W_discrete_p 0.49066666666666664
# test_discrete_score_W_discrete_n 0.0656121335544029
# test_discrete_score_W_discrete_a 0.05425146414624794
# Not good purity result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.5066666666666667
# test_discrete_score_W0_n 0.05918067702583017
# test_discrete_score_W0_a 0.06441544144453343
# test_discrete_score_W_discrete_p 0.488
# test_discrete_score_W_discrete_n 0.037403642851017535
# test_discrete_score_W_discrete_a 0.05483018942027142
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.488
# test_discrete_score_W0_n 0.03804923927454012
# test_discrete_score_W0_a 0.0504190766811897
# test_discrete_score_W_discrete_p 0.44
# test_discrete_score_W_discrete_n 0.013721971674661854
# test_discrete_score_W_discrete_a 0.021470140587606188
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.49733333333333335
# test_discrete_score_W0_n 0.04823058056441314
# test_discrete_score_W0_a 0.055424246275121936
# test_discrete_score_W_discrete_p 0.468
# test_discrete_score_W_discrete_n 0.033419026205300774
# test_discrete_score_W_discrete_a 0.037798557862118776
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.484
# test_discrete_score_W0_n 0.0418326320885851
# test_discrete_score_W0_a 0.046048360678791714
# test_discrete_score_W_discrete_p 0.44266666666666665
# test_discrete_score_W_discrete_n 0.014330490491716325
# test_discrete_score_W_discrete_a 0.023358300260662643
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.037271768818057244
# test_discrete_score_W0_a 0.04479290888306534
# test_discrete_score_W_discrete_p 0.456
# test_discrete_score_W_discrete_n 0.02391099418788635
# test_discrete_score_W_discrete_a 0.03265918625655701
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.492
# test_discrete_score_W0_n 0.045223129127557125
# test_discrete_score_W0_a 0.058694163776659675
# test_discrete_score_W_discrete_p 0.45466666666666666
# test_discrete_score_W_discrete_n 0.020637170001117727
# test_discrete_score_W_discrete_a 0.0268764242436013
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.484
# test_discrete_score_W0_n 0.03606397947249804
# test_discrete_score_W0_a 0.04568447775403821
# test_discrete_score_W_discrete_p 0.44533333333333336
# test_discrete_score_W_discrete_n 0.01462040433099771
# test_discrete_score_W_discrete_a 0.023702175602839815
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.02717669742998091
# test_discrete_score_W0_a 0.036106729659192704
# test_discrete_score_W_discrete_p 0.45066666666666666
# test_discrete_score_W_discrete_n 0.017969652101678994
# test_discrete_score_W_discrete_a 0.025829963188204432
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.04202682407958894
# test_discrete_score_W0_a 0.04735870376028075
# test_discrete_score_W_discrete_p 0.456
# test_discrete_score_W_discrete_n 0.020314133145945466
# test_discrete_score_W_discrete_a 0.028353461072124914
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.484
# test_discrete_score_W0_n 0.03721366462000843
# test_discrete_score_W0_a 0.045868504167028167
# test_discrete_score_W_discrete_p 0.46266666666666667
# test_discrete_score_W_discrete_n 0.024437721616131166
# test_discrete_score_W_discrete_a 0.03095001687125651
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03669986438831707
# test_discrete_score_W0_a 0.05046289858981795
# test_discrete_score_W_discrete_p 0.45466666666666666
# test_discrete_score_W_discrete_n 0.019683784184239488
# test_discrete_score_W_discrete_a 0.02729179831770708
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.484
# test_discrete_score_W0_n 0.038401991070227966
# test_discrete_score_W0_a 0.04267851015390857
# test_discrete_score_W_discrete_p 0.4653333333333333
# test_discrete_score_W_discrete_n 0.026132464429946673
# test_discrete_score_W_discrete_a 0.03405543167499107
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.48933333333333334
# test_discrete_score_W0_n 0.041349139505854844
# test_discrete_score_W0_a 0.05124835894613615
# test_discrete_score_W_discrete_p 0.468
# test_discrete_score_W_discrete_n 0.026307781631247088
# test_discrete_score_W_discrete_a 0.03790757820049946
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5066666666666667
# test_discrete_score_W0_n 0.05107460933541957
# test_discrete_score_W0_a 0.06341481360767211
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03603367244202761
# test_discrete_score_W_discrete_a 0.04546237986353658
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.49733333333333335
# test_discrete_score_W0_n 0.04496202152353495
# test_discrete_score_W0_a 0.056825147551324146
# test_discrete_score_W_discrete_p 0.45466666666666666
# test_discrete_score_W_discrete_n 0.01967848732316639
# test_discrete_score_W_discrete_a 0.02866793158739445
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.49066666666666664
# test_discrete_score_W0_n 0.04311047009768307
# test_discrete_score_W0_a 0.04924373144884753
# test_discrete_score_W_discrete_p 0.4653333333333333
# test_discrete_score_W_discrete_n 0.024660387206087542
# test_discrete_score_W_discrete_a 0.033695040941197685
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.49466666666666664
# test_discrete_score_W0_n 0.043683517989707384
# test_discrete_score_W0_a 0.055027012347629856
# test_discrete_score_W_discrete_p 0.488
# test_discrete_score_W_discrete_n 0.037837790329319526
# test_discrete_score_W_discrete_a 0.05385786425475225
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.5013333333333333
# test_discrete_score_W0_n 0.047477209289770214
# test_discrete_score_W0_a 0.057520397955632026
# test_discrete_score_W_discrete_p 0.4746666666666667
# test_discrete_score_W_discrete_n 0.031167188233673992
# test_discrete_score_W_discrete_a 0.03970309571517234
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.48786666666666667
# test_discrete_score_W_discrete_p mean 0.4641333333333333
# test_discrete_score_W0_n mean 0.04206748854626176
# test_discrete_score_W_discrete_n mean 0.027117878967073267
# test_discrete_score_W0_a mean 0.051291491418126264
# test_discrete_score_W_discrete_a mean 0.035665772590787195
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.042067  0.007568  0.001692   0.038525  0.045609
# 1  test_dis_W_dis  20.0  0.027118  0.011919  0.002665   0.021540  0.032696
# 2        combined  40.0  0.034593  0.012427  0.001965   0.030618  0.038567
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0149
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    4.7353
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    1.4974
# 7                                  Hedge's g =    1.4677
# 8                             Glass's delta1 =    1.9753
# 9                           Point-Biserial r =    0.6092
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.051291  0.007894  0.001765   0.047597  0.054986
# 1  test_dis_W_dis  20.0  0.035666  0.011080  0.002478   0.030480  0.040851
# 2        combined  40.0  0.043479  0.012360  0.001954   0.039526  0.047432
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0156
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    5.1366
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    1.6243
# 7                                  Hedge's g =    1.5921
# 8                             Glass's delta1 =    1.9795
# 9                           Point-Biserial r =    0.6402
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.487867  0.013227  0.002958   0.481676  0.494057
# 1  test_dis_W_dis  20.0  0.464133  0.015208  0.003401   0.457016  0.471251
# 2        combined  40.0  0.476000  0.018502  0.002925   0.470083  0.481917
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0237
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    5.2661
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    1.6653
# 7                                  Hedge's g =    1.6322
# 8                             Glass's delta1 =    1.7943
# 9                           Point-Biserial r =    0.6495

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[0,2]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.42533333333333334
# test_discrete_score_W0_n 0.024880807119918823
# test_discrete_score_W0_a 0.033259023184621775
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.015079646998981499
# test_discrete_score_W_discrete_a 0.025757675242713312
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.02235899216138412
# test_discrete_score_W0_a 0.034125098640851184
# test_discrete_score_W_discrete_p 0.444
# test_discrete_score_W_discrete_n 0.018224110008983482
# test_discrete_score_W_discrete_a 0.02799053494753048
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02023972883373783
# test_discrete_score_W0_a 0.03435558330327013
# test_discrete_score_W_discrete_p 0.45466666666666666
# test_discrete_score_W_discrete_n 0.02083645387680597
# test_discrete_score_W_discrete_a 0.030767181531471722
# Not good purity result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.02545932245061713
# test_discrete_score_W0_a 0.03859140084619326
# test_discrete_score_W_discrete_p 0.4706666666666667
# test_discrete_score_W_discrete_n 0.02787297283956957
# test_discrete_score_W_discrete_a 0.0378051765329808
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.472
# test_discrete_score_W0_n 0.029151052142196744
# test_discrete_score_W0_a 0.037645182293131456
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.02449815168760021
# test_discrete_score_W_discrete_a 0.03923168090364789
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48
# test_discrete_score_W0_n 0.03454472306979973
# test_discrete_score_W0_a 0.05423039126819346
# test_discrete_score_W_discrete_p 0.4786666666666667
# test_discrete_score_W_discrete_n 0.030478642526988425
# test_discrete_score_W_discrete_a 0.04094929711566715
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.01749929989929211
# test_discrete_score_W0_a 0.025463331613423287
# test_discrete_score_W_discrete_p 0.476
# test_discrete_score_W_discrete_n 0.04287029680011084
# test_discrete_score_W_discrete_a 0.03461266515385444
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.0206023057222122
# test_discrete_score_W0_a 0.03303562769806343
# test_discrete_score_W_discrete_p 0.48933333333333334
# test_discrete_score_W_discrete_n 0.0397884967274604
# test_discrete_score_W_discrete_a 0.04993039356285617
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.021491386298348087
# test_discrete_score_W0_a 0.03272853388251361
# test_discrete_score_W_discrete_p 0.4866666666666667
# test_discrete_score_W_discrete_n 0.03517397518430822
# test_discrete_score_W_discrete_a 0.05213397745945536
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.02934062426403414
# test_discrete_score_W0_a 0.042389063993036595
# test_discrete_score_W_discrete_p 0.49466666666666664
# test_discrete_score_W_discrete_n 0.044470822139824694
# test_discrete_score_W_discrete_a 0.05166577402069738
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.464
# test_discrete_score_W0_n 0.026949739837027586
# test_discrete_score_W0_a 0.040099355890695756
# test_discrete_score_W_discrete_p 0.4866666666666667
# test_discrete_score_W_discrete_n 0.03821746342926337
# test_discrete_score_W_discrete_a 0.0508295603537361
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.02659115205802398
# test_discrete_score_W0_a 0.039768534262157804
# test_discrete_score_W_discrete_p 0.48133333333333334
# test_discrete_score_W_discrete_n 0.03715369068383125
# test_discrete_score_W_discrete_a 0.043803049192181275
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.472
# test_discrete_score_W0_n 0.02999050519040955
# test_discrete_score_W0_a 0.036585954611056584
# test_discrete_score_W_discrete_p 0.496
# test_discrete_score_W_discrete_n 0.04199331311580401
# test_discrete_score_W_discrete_a 0.05586699308583172
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.017518922470107685
# test_discrete_score_W0_a 0.030046417912209557
# test_discrete_score_W_discrete_p 0.476
# test_discrete_score_W_discrete_n 0.031110089117990694
# test_discrete_score_W_discrete_a 0.04199983845281161
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5053333333333333
# test_discrete_score_W0_n 0.04722701196619385
# test_discrete_score_W0_a 0.0649297757043014
# test_discrete_score_W_discrete_p 0.504
# test_discrete_score_W_discrete_n 0.04756239455290511
# test_discrete_score_W_discrete_a 0.06084387986503986
# Not good purity result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.024086693315859612
# test_discrete_score_W0_a 0.0353955555637585
# test_discrete_score_W_discrete_p 0.5093333333333333
# test_discrete_score_W_discrete_n 0.0505933587334232
# test_discrete_score_W_discrete_a 0.06727073227557086
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.5
# test_discrete_score_W0_n 0.04636627489433889
# test_discrete_score_W0_a 0.06346509169711757
# test_discrete_score_W_discrete_p 0.496
# test_discrete_score_W_discrete_n 0.04286097917726837
# test_discrete_score_W_discrete_a 0.06177817101512117
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.026504564762636535
# test_discrete_score_W0_a 0.03861793192269973
# test_discrete_score_W_discrete_p 0.476
# test_discrete_score_W_discrete_n 0.030374400737682005
# test_discrete_score_W_discrete_a 0.04129430990846777
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.508
# test_discrete_score_W0_n 0.049052649804980614
# test_discrete_score_W0_a 0.06593163583476998
# test_discrete_score_W_discrete_p 0.49333333333333335
# test_discrete_score_W_discrete_n 0.04029962869550498
# test_discrete_score_W_discrete_a 0.053463566389578214
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.4641333333333334
# test_discrete_score_W_discrete_p mean 0.4776000000000001
# test_discrete_score_W0_n mean 0.026992787813055964
# test_discrete_score_W_discrete_n mean 0.03390371650242988
# test_discrete_score_W0_a mean 0.03903317450610325
# test_discrete_score_W_discrete_a mean 0.04443448205733395
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.026993  0.011262  0.002518   0.021722  0.032264
# 1  test_dis_W_dis  20.0  0.033904  0.010439  0.002334   0.029018  0.038790
# 2        combined  40.0  0.030448  0.011275  0.001783   0.026842  0.034054
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0069
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.0126
# 3                      Two side test p value =    0.0513
# 4                     Difference < 0 p value =    0.0256
# 5                     Difference > 0 p value =    0.9744
# 6                                  Cohen's d =   -0.6364
# 7                                  Hedge's g =   -0.6238
# 8                             Glass's delta1 =   -0.6136
# 9                           Point-Biserial r =   -0.3104
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.039033  0.014868  0.003325   0.032075  0.045992
# 1  test_dis_W_dis  20.0  0.044434  0.012674  0.002834   0.038503  0.050366
# 2        combined  40.0  0.041734  0.013908  0.002199   0.037286  0.046182
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0054
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -1.2364
# 3                      Two side test p value =    0.2239
# 4                     Difference < 0 p value =    0.1119
# 5                     Difference > 0 p value =    0.8881
# 6                                  Cohen's d =   -0.3910
# 7                                  Hedge's g =   -0.3832
# 8                             Glass's delta1 =   -0.3633
# 9                           Point-Biserial r =   -0.1967
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.464133  0.022532  0.005038   0.453588  0.474678
# 1  test_dis_W_dis  20.0  0.477600  0.021186  0.004737   0.467684  0.487516
# 2        combined  40.0  0.470867  0.022639  0.003579   0.463626  0.478107
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0135
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -1.9473
# 3                      Two side test p value =    0.0589
# 4                     Difference < 0 p value =    0.0295
# 5                     Difference > 0 p value =    0.9705
# 6                                  Cohen's d =   -0.6158
# 7                                  Hedge's g =   -0.6035
# 8                             Glass's delta1 =   -0.5977
# 9                           Point-Biserial r =   -0.3012

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[0,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.43866666666666665
# test_discrete_score_W_discrete_n 0.012570445973485013
# test_discrete_score_W_discrete_a 0.02323706123119206
# Not good nmi result for discrete features !!!!!
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.02176122247237533
# test_discrete_score_W0_a 0.03550052950626864
# test_discrete_score_W_discrete_p 0.45466666666666666
# test_discrete_score_W_discrete_n 0.017320936482129998
# test_discrete_score_W_discrete_a 0.02974799753159003
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.03148270431382814
# test_discrete_score_W0_a 0.04915214066195132
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.022098312505857726
# test_discrete_score_W_discrete_a 0.03314051693970969
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.464
# test_discrete_score_W0_n 0.026645647729567012
# test_discrete_score_W0_a 0.03541407523022867
# test_discrete_score_W_discrete_p 0.46
# test_discrete_score_W_discrete_n 0.021437607618928257
# test_discrete_score_W_discrete_a 0.033230901090294425
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.023296637454621294
# test_discrete_score_W0_a 0.03913917556107725
# test_discrete_score_W_discrete_p 0.4613333333333333
# test_discrete_score_W_discrete_n 0.025628523194707806
# test_discrete_score_W_discrete_a 0.03587417717010159
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.47733333333333333
# test_discrete_score_W0_n 0.03405428055260019
# test_discrete_score_W0_a 0.05147975939670968
# test_discrete_score_W_discrete_p 0.4653333333333333
# test_discrete_score_W_discrete_n 0.027967948270084433
# test_discrete_score_W_discrete_a 0.037320723407165524
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.464
# test_discrete_score_W0_n 0.03133071307338424
# test_discrete_score_W0_a 0.04034865981972572
# test_discrete_score_W_discrete_p 0.47333333333333333
# test_discrete_score_W_discrete_n 0.03175189603322077
# test_discrete_score_W_discrete_a 0.04529073786353949
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.033447829735047334
# test_discrete_score_W0_a 0.052018330892978526
# test_discrete_score_W_discrete_p 0.476
# test_discrete_score_W_discrete_n 0.027306348781758683
# test_discrete_score_W_discrete_a 0.04353408166255726
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.47333333333333333
# test_discrete_score_W0_n 0.03579251757923196
# test_discrete_score_W0_a 0.04456684736789564
# test_discrete_score_W_discrete_p 0.4866666666666667
# test_discrete_score_W_discrete_n 0.03310074776714173
# test_discrete_score_W_discrete_a 0.04776265561811944
# Not good nmi result for discrete features !!!!!
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.4693333333333333
# test_discrete_score_W0_n 0.02434831796106618
# test_discrete_score_W0_a 0.03503584262019204
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.023090267535546834
# test_discrete_score_W_discrete_a 0.03400696292939796
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.4653333333333333
# test_discrete_score_W0_n 0.023624334260864927
# test_discrete_score_W0_a 0.03994731944944577
# test_discrete_score_W_discrete_p 0.492
# test_discrete_score_W_discrete_n 0.037421078215167276
# test_discrete_score_W_discrete_a 0.049623645285619855
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.021601753048996492
# test_discrete_score_W0_a 0.03487408602728535
# test_discrete_score_W_discrete_p 0.5026666666666667
# test_discrete_score_W_discrete_n 0.047874279016082544
# test_discrete_score_W_discrete_a 0.06281385908035532
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.48533333333333334
# test_discrete_score_W0_n 0.03687474502691452
# test_discrete_score_W0_a 0.053607002234442765
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.044351606148254376
# test_discrete_score_W_discrete_a 0.061170870873229324
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.018300010389533317
# test_discrete_score_W0_a 0.031192576063846136
# test_discrete_score_W_discrete_p 0.476
# test_discrete_score_W_discrete_n 0.029063935456662332
# test_discrete_score_W_discrete_a 0.043549071074027924
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5093333333333333
# test_discrete_score_W0_n 0.05146837905574483
# test_discrete_score_W0_a 0.07179634216563689
# test_discrete_score_W_discrete_p 0.488
# test_discrete_score_W_discrete_n 0.03613904485209987
# test_discrete_score_W_discrete_a 0.05274191006593363
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.024663559848772183
# test_discrete_score_W0_a 0.03132234409748721
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.02318312489428207
# test_discrete_score_W_discrete_a 0.03832735431650912
# Not good nmi result for discrete features !!!!!
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.488
# test_discrete_score_W0_n 0.03722613949898315
# test_discrete_score_W0_a 0.05469203651140671
# test_discrete_score_W_discrete_p 0.492
# test_discrete_score_W_discrete_n 0.03749370474571715
# test_discrete_score_W_discrete_a 0.05604983354616635
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.022186061858669285
# test_discrete_score_W0_a 0.036539429562487166
# test_discrete_score_W_discrete_p 0.492
# test_discrete_score_W_discrete_n 0.037219356586499164
# test_discrete_score_W_discrete_a 0.05465162783200421
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.5133333333333333
# test_discrete_score_W0_n 0.05308862586017605
# test_discrete_score_W0_a 0.07450020942839415
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.028457354983908743
# test_discrete_score_W_discrete_a 0.044490939499197774
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.4673333333333334
# test_discrete_score_W_discrete_p mean 0.4729333333333335
# test_discrete_score_W0_n mean 0.028460482826080706
# test_discrete_score_W_discrete_n mean 0.029104598103791308
# test_discrete_score_W0_a mean 0.041558257945039485
# test_discrete_score_W_discrete_a mean 0.04236300555770883
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.028460  0.011808  0.002640   0.022934  0.033987
# 1  test_dis_W_dis  20.0  0.029105  0.009122  0.002040   0.024835  0.033374
# 2        combined  40.0  0.028783  0.010420  0.001648   0.025450  0.032115
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0006
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.1931
# 3                      Two side test p value =    0.8479
# 4                     Difference < 0 p value =    0.4240
# 5                     Difference > 0 p value =    0.5760
# 6                                  Cohen's d =   -0.0610
# 7                                  Hedge's g =   -0.0598
# 8                             Glass's delta1 =   -0.0545
# 9                           Point-Biserial r =   -0.0313
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.041558  0.016529  0.003696   0.033822  0.049294
# 1  test_dis_W_dis  20.0  0.042363  0.011770  0.002632   0.036854  0.047872
# 2        combined  40.0  0.041961  0.014169  0.002240   0.037429  0.046492
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0008
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.1774
# 3                      Two side test p value =    0.8602
# 4                     Difference < 0 p value =    0.4301
# 5                     Difference > 0 p value =    0.5699
# 6                                  Cohen's d =   -0.0561
# 7                                  Hedge's g =   -0.0550
# 8                             Glass's delta1 =   -0.0487
# 9                           Point-Biserial r =   -0.0288
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.467333  0.022605  0.005055   0.456754  0.477913
# 1  test_dis_W_dis  20.0  0.472933  0.019172  0.004287   0.463961  0.481906
# 2        combined  40.0  0.470133  0.020882  0.003302   0.463455  0.476812
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0056
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.8449
# 3                      Two side test p value =    0.4034
# 4                     Difference < 0 p value =    0.2017
# 5                     Difference > 0 p value =    0.7983
# 6                                  Cohen's d =   -0.2672
# 7                                  Hedge's g =   -0.2619
# 8                             Glass's delta1 =   -0.2477
# 9                           Point-Biserial r =   -0.1358

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[1,2]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02234382538594245
# test_discrete_score_W_discrete_a 0.04032700754385205
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.01739318005978277
# test_discrete_score_W0_a 0.029175201704974632
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.03443300398952806
# test_discrete_score_W_discrete_a 0.02422357085425989
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.02334380379895585
# test_discrete_score_W0_a 0.037353108504030286
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.053434189827062516
# test_discrete_score_W_discrete_a 0.05456195729343344
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.476
# test_discrete_score_W0_n 0.033922299757219505
# test_discrete_score_W0_a 0.052561119522969935
# test_discrete_score_W_discrete_p 0.46
# test_discrete_score_W_discrete_n 0.031134181280268396
# test_discrete_score_W_discrete_a 0.044253704350719236
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.030552889554805434
# test_discrete_score_W0_a 0.042998231189427
# test_discrete_score_W_discrete_p 0.4746666666666667
# test_discrete_score_W_discrete_n 0.03376967607150299
# test_discrete_score_W_discrete_a 0.04632683501465729
# Not good purity result for discrete features !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03342601353355848
# test_discrete_score_W0_a 0.04798282495417882
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.05507820220623584
# test_discrete_score_W_discrete_a 0.06572394767970656
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.027459821320045832
# test_discrete_score_W0_a 0.04253570431171219
# test_discrete_score_W_discrete_p 0.49333333333333335
# test_discrete_score_W_discrete_n 0.04397362826092439
# test_discrete_score_W_discrete_a 0.06267067104557747
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.024786498576812546
# test_discrete_score_W0_a 0.03788888448751348
# test_discrete_score_W_discrete_p 0.49066666666666664
# test_discrete_score_W_discrete_n 0.03958278449072278
# test_discrete_score_W_discrete_a 0.05649455222149977
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.016522062383778145
# test_discrete_score_W0_a 0.028494233453073153
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.05119010651141663
# test_discrete_score_W_discrete_a 0.07210828379153088
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.017426370665438014
# test_discrete_score_W0_a 0.023699636325396987
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032538084155730576
# test_discrete_score_W_discrete_a 0.04820567242261783
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.036857456552891944
# test_discrete_score_W0_a 0.05578198334814375
# test_discrete_score_W_discrete_p 0.5213333333333333
# test_discrete_score_W_discrete_n 0.06132297519620123
# test_discrete_score_W_discrete_a 0.08512012645846712
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4866666666666667
# test_discrete_score_W0_n 0.03759457527631816
# test_discrete_score_W0_a 0.055163595305752385
# test_discrete_score_W_discrete_p 0.556
# test_discrete_score_W_discrete_n 0.09577315053890768
# test_discrete_score_W_discrete_a 0.11281183908452129
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03093370149562325
# test_discrete_score_W0_a 0.044458312234050626
# test_discrete_score_W_discrete_p 0.516
# test_discrete_score_W_discrete_n 0.05804740739737212
# test_discrete_score_W_discrete_a 0.08513700710052961
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.02054779399772174
# test_discrete_score_W0_a 0.03101276852118271
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.04653708967400014
# test_discrete_score_W_discrete_a 0.06827491998098022
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5146666666666667
# test_discrete_score_W0_n 0.05443083282314605
# test_discrete_score_W0_a 0.07036287681764777
# test_discrete_score_W_discrete_p 0.544
# test_discrete_score_W_discrete_n 0.08269977748474737
# test_discrete_score_W_discrete_a 0.09852532914984698
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.02892604535266786
# test_discrete_score_W0_a 0.047155247862443884
# test_discrete_score_W_discrete_p 0.524
# test_discrete_score_W_discrete_n 0.06372742679275416
# test_discrete_score_W_discrete_a 0.07877786447256512
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.524
# test_discrete_score_W0_n 0.05945259033535872
# test_discrete_score_W0_a 0.07960516206945854
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.0541905060530825
# test_discrete_score_W_discrete_a 0.07125467232825451
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.022448343490384687
# test_discrete_score_W0_a 0.03397696731084315
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.03841331757870813
# test_discrete_score_W_discrete_a 0.0518461718393148
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.5226666666666666
# test_discrete_score_W0_n 0.058074070778292367
# test_discrete_score_W0_a 0.0763494609595373
# test_discrete_score_W_discrete_p 0.5146666666666667
# test_discrete_score_W_discrete_n 0.05986941507524195
# test_discrete_score_W_discrete_a 0.08647900509679979
# Not good purity result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.46993333333333326
# test_discrete_score_W_discrete_p mean 0.49493333333333334
# test_discrete_score_W0_n mean 0.029605726327701958
# test_discrete_score_W_discrete_n mean 0.04883370954923206
# test_discrete_score_W0_a mean 0.04282968855928333
# test_discrete_score_W_discrete_a mean 0.06369091609333
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.029606  0.014779  0.003305   0.022689  0.036523
# 1  test_dis_W_dis  20.0  0.048834  0.019029  0.004255   0.039928  0.057740
# 2        combined  40.0  0.039220  0.019433  0.003073   0.033005  0.045435
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0192
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.5689
# 3                      Two side test p value =    0.0010
# 4                     Difference < 0 p value =    0.0005
# 5                     Difference > 0 p value =    0.9995
# 6                                  Cohen's d =   -1.1286
# 7                                  Hedge's g =   -1.1062
# 8                             Glass's delta1 =   -1.3010
# 9                           Point-Biserial r =   -0.5010
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.042830  0.019305  0.004317   0.033795  0.051865
# 1  test_dis_W_dis  20.0  0.063691  0.023612  0.005280   0.052640  0.074742
# 2        combined  40.0  0.053260  0.023765  0.003758   0.045660  0.060861
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0209
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.0589
# 3                      Two side test p value =    0.0041
# 4                     Difference < 0 p value =    0.0020
# 5                     Difference > 0 p value =    0.9980
# 6                                  Cohen's d =   -0.9673
# 7                                  Hedge's g =   -0.9481
# 8                             Glass's delta1 =   -1.0806
# 9                           Point-Biserial r =   -0.4445
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.469933  0.028203  0.006306   0.456734  0.483133
# 1  test_dis_W_dis  20.0  0.494933  0.030892  0.006908   0.480475  0.509391
# 2        combined  40.0  0.482433  0.031823  0.005032   0.472256  0.492611
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0250
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.6728
# 3                      Two side test p value =    0.0110
# 4                     Difference < 0 p value =    0.0055
# 5                     Difference > 0 p value =    0.9945
# 6                                  Cohen's d =   -0.8452
# 7                                  Hedge's g =   -0.8284
# 8                             Glass's delta1 =   -0.8864
# 9                           Point-Biserial r =   -0.3978

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.428
# test_discrete_score_W_discrete_n 0.02345171762930623
# test_discrete_score_W_discrete_a 0.01923792963102035
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.018856935362735645
# test_discrete_score_W_discrete_a 0.029045041233303804
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.026855580654044465
# test_discrete_score_W0_a 0.03604144266742046
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01810404796207701
# test_discrete_score_W_discrete_a 0.03346196864130828
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024682167696410937
# test_discrete_score_W0_a 0.032188349757317845
# test_discrete_score_W_discrete_p 0.44666666666666666
# test_discrete_score_W_discrete_n 0.01797489888334447
# test_discrete_score_W_discrete_a 0.0285471281012557
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024203462603534617
# test_discrete_score_W0_a 0.03846988685325159
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01838925770914136
# test_discrete_score_W_discrete_a 0.032019100024307974
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.03349335568258328
# test_discrete_score_W0_a 0.04667109658886825
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.01605391401844283
# test_discrete_score_W_discrete_a 0.026793244224623227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48533333333333334
# test_discrete_score_W0_n 0.035485179839995426
# test_discrete_score_W0_a 0.04981859509745033
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02068810713236546
# test_discrete_score_W_discrete_a 0.03309157601901982
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02390083884461625
# test_discrete_score_W0_a 0.03873861993122384
# test_discrete_score_W_discrete_p 0.4573333333333333
# test_discrete_score_W_discrete_n 0.023235517855302763
# test_discrete_score_W_discrete_a 0.03744560308797647
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.026985376253148303
# test_discrete_score_W0_a 0.03978610299904206
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.026305260920569878
# test_discrete_score_W_discrete_a 0.041094189990076725
# Not good nmi result for discrete features !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.018162904680171798
# test_discrete_score_W0_a 0.03022682699783115
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03400184259136679
# test_discrete_score_W_discrete_a 0.05029641376853773
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.033072619927399426
# test_discrete_score_W0_a 0.047156111573114626
# test_discrete_score_W_discrete_p 0.4786666666666667
# test_discrete_score_W_discrete_n 0.03499390650337792
# test_discrete_score_W_discrete_a 0.051949215378023175
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.023824261795553792
# test_discrete_score_W0_a 0.037597994770207366
# test_discrete_score_W_discrete_p 0.468
# test_discrete_score_W_discrete_n 0.028031643322058132
# test_discrete_score_W_discrete_a 0.044080209705631444
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.028791201469484017
# test_discrete_score_W0_a 0.04599112596540657
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032429275622864545
# test_discrete_score_W_discrete_a 0.04740265300888458
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.4706666666666667
# test_discrete_score_W0_n 0.028197704700882276
# test_discrete_score_W0_a 0.042188175616839595
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03430876326213519
# test_discrete_score_W_discrete_a 0.05324336208092509
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.021944285346807382
# test_discrete_score_W0_a 0.031945508345160974
# test_discrete_score_W_discrete_p 0.48533333333333334
# test_discrete_score_W_discrete_n 0.03869110510763206
# test_discrete_score_W_discrete_a 0.05802214839446757
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5106666666666667
# test_discrete_score_W0_n 0.05054444015796348
# test_discrete_score_W0_a 0.06925893080150226
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.028500768616768247
# test_discrete_score_W_discrete_a 0.03993660270160838
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.03193530568800679
# test_discrete_score_W0_a 0.04764998062763653
# test_discrete_score_W_discrete_p 0.504
# test_discrete_score_W_discrete_n 0.047939169427930486
# test_discrete_score_W_discrete_a 0.06706429938523999
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.025557559612347378
# test_discrete_score_W0_a 0.038599165108127206
# test_discrete_score_W_discrete_p 0.4693333333333333
# test_discrete_score_W_discrete_n 0.02610302923188745
# test_discrete_score_W_discrete_a 0.041979976747958815
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02431624127598852
# test_discrete_score_W0_a 0.039038707645552506
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.02710259286982934
# test_discrete_score_W_discrete_a 0.03850236196126793
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.49333333333333335
# test_discrete_score_W0_n 0.043797733013326734
# test_discrete_score_W0_a 0.06109381550919402
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03414668262562054
# test_discrete_score_W_discrete_a 0.047714667147608227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.46453333333333335
# test_discrete_score_W_discrete_p mean 0.46593333333333337
# test_discrete_score_W0_n mean 0.02718831980217513
# test_discrete_score_W_discrete_n mean 0.027465421832737813
# test_discrete_score_W0_a mean 0.03962494445792386
# test_discrete_score_W_discrete_a mean 0.04104638456165226
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.027188  0.010186  0.002278   0.022421  0.031956
# 1  test_dis_W_dis  20.0  0.027465  0.008303  0.001857   0.023580  0.031351
# 2        combined  40.0  0.027327  0.009173  0.001450   0.024393  0.030261
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0003
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.0943
# 3                      Two side test p value =    0.9254
# 4                     Difference < 0 p value =    0.4627
# 5                     Difference > 0 p value =    0.5373
# 6                                  Cohen's d =   -0.0298
# 7                                  Hedge's g =   -0.0292
# 8                             Glass's delta1 =   -0.0272
# 9                           Point-Biserial r =   -0.0153
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.039625  0.014212  0.003178   0.032973  0.046276
# 1  test_dis_W_dis  20.0  0.041046  0.011732  0.002623   0.035556  0.046537
# 2        combined  40.0  0.040336  0.012883  0.002037   0.036215  0.044456
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.3449
# 3                      Two side test p value =    0.7320
# 4                     Difference < 0 p value =    0.3660
# 5                     Difference > 0 p value =    0.6340
# 6                                  Cohen's d =   -0.1091
# 7                                  Hedge's g =   -0.1069
# 8                             Glass's delta1 =   -0.1000
# 9                           Point-Biserial r =   -0.0559
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.464533  0.020521  0.004589   0.454929  0.474138
# 1  test_dis_W_dis  20.0  0.465933  0.017670  0.003951   0.457664  0.474203
# 2        combined  40.0  0.465233  0.018915  0.002991   0.459184  0.471283
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.2312
# 3                      Two side test p value =    0.8184
# 4                     Difference < 0 p value =    0.4092
# 5                     Difference > 0 p value =    0.5908
# 6                                  Cohen's d =   -0.0731
# 7                                  Hedge's g =   -0.0717
# 8                             Glass's delta1 =   -0.0682
# 9                           Point-Biserial r =   -0.0375

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
