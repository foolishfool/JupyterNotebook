# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])
csv_original_encode = csv


# class label do not need to onehot encoding
dataread.label_encoding(csv_original_encode,"Subscription Type")
#one hot encoding vs proposed
dataread.binary_encoding(csv_original_encode,["Country","Gender","Device"])

dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Subscription Type")
# Out:
# self.data_continuous_indexes ['Join Date', 'Last Payment Date', 'Age']
#  column number self.data_train_discrete 4

# %%
# binary encoding

unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 5
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.39885714285714285
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.4013333333333333
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.5628571428571428
# train_discrete_score_W_discrete_n 0.10144095403852095
# train_discrete_score_W_discrete_a 0.12136072488485088
# test_discrete_score_W_discrete_p 0.5933333333333334
# test_discrete_score_W_discrete_n 0.12713417872837135
# test_discrete_score_W_discrete_a 0.1630094021079717
# neuron unit number: 10
# train_discrete_score_W0_p 0.4085714285714286
# train_discrete_score_W0_n 0.00537284326484774
# train_discrete_score_W0_a  0.00899872953293695
# test_discrete_score_W0_p 0.42
# test_discrete_score_W0_n 0.008398759671586271
# test_discrete_score_W0_a 0.010377880157364254
# train_discrete_score_W_discrete_p 0.6245714285714286
# train_discrete_score_W_discrete_n 0.16627816544214435
# train_discrete_score_W_discrete_a 0.19358778094533535
# test_discrete_score_W_discrete_p 0.672
# test_discrete_score_W_discrete_n 0.2224184279912008
# test_discrete_score_W_discrete_a 0.26190557921738505
# neuron unit number: 15
# train_discrete_score_W0_p 0.4137142857142857
# train_discrete_score_W0_n 0.006656512783639764
# train_discrete_score_W0_a  0.010843351349165002
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.015572477594533162
# test_discrete_score_W0_a 0.017912316047895307
# train_discrete_score_W_discrete_p 0.6388571428571429
# train_discrete_score_W_discrete_n 0.20565891397372993
# train_discrete_score_W_discrete_a 0.20716140318945195
# test_discrete_score_W_discrete_p 0.672
# test_discrete_score_W_discrete_n 0.21559475785280055
# test_discrete_score_W_discrete_a 0.2623818114243638
# neuron unit number: 20
# train_discrete_score_W0_p 0.40914285714285714
# train_discrete_score_W0_n 0.005195508952712476
# train_discrete_score_W0_a  0.009227278297346621
# test_discrete_score_W0_p 0.436
# test_discrete_score_W0_n 0.01543602070655995
# test_discrete_score_W0_a 0.024601869983848553
# train_discrete_score_W_discrete_p 0.6445714285714286
# train_discrete_score_W_discrete_n 0.19239144785541104
# train_discrete_score_W_discrete_a 0.21751704647213208
# test_discrete_score_W_discrete_p 0.6786666666666666
# test_discrete_score_W_discrete_n 0.22956562988060134
# test_discrete_score_W_discrete_a 0.26898140472442533
# neuron unit number: 25
# train_discrete_score_W0_p 0.4125714285714286
# train_discrete_score_W0_n 0.005609795197649485
# train_discrete_score_W0_a  0.011048645897510445
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.01987547418279656
# test_discrete_score_W0_a 0.02747561353810979
# train_discrete_score_W_discrete_p 0.6491428571428571
# train_discrete_score_W_discrete_n 0.22950345487594093
# train_discrete_score_W_discrete_a 0.21915344333198344
# test_discrete_score_W_discrete_p 0.6786666666666666
# test_discrete_score_W_discrete_n 0.24170625766590784
# test_discrete_score_W_discrete_a 0.2675396590314203
# neuron unit number: 30
# train_discrete_score_W0_p 0.41714285714285715
# train_discrete_score_W0_n 0.008064911974996798
# train_discrete_score_W0_a  0.011168069465922806
# test_discrete_score_W0_p 0.44533333333333336
# test_discrete_score_W0_n 0.01949726919975279
# test_discrete_score_W0_a 0.0279165663812169
# train_discrete_score_W_discrete_p 0.6457142857142857
# train_discrete_score_W_discrete_n 0.20334826620638577
# train_discrete_score_W_discrete_a 0.21754239154257715
# test_discrete_score_W_discrete_p 0.696
# test_discrete_score_W_discrete_n 0.27232701993652264
# test_discrete_score_W_discrete_a 0.29243108006068347
# neuron unit number: 35
# train_discrete_score_W0_p 0.4154285714285714
# train_discrete_score_W0_n 0.006699982414761671
# train_discrete_score_W0_a  0.0086881170907663
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.02433621472993882
# test_discrete_score_W0_a 0.031025488476692575
# train_discrete_score_W_discrete_p 0.6508571428571429
# train_discrete_score_W_discrete_n 0.2162426230007769
# train_discrete_score_W_discrete_a 0.22220891256133557
# test_discrete_score_W_discrete_p 0.6813333333333333
# test_discrete_score_W_discrete_n 0.25256106913155174
# test_discrete_score_W_discrete_a 0.26974491330007805
# neuron unit number: 40
# train_discrete_score_W0_p 0.41942857142857143
# train_discrete_score_W0_n 0.009595765473861395
# train_discrete_score_W0_a  0.011846909229250665
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.023402623203167612
# test_discrete_score_W0_a 0.03283017601436296
# train_discrete_score_W_discrete_p 0.6508571428571429
# train_discrete_score_W_discrete_n 0.2162426230007769
# train_discrete_score_W_discrete_a 0.22220891256133557
# test_discrete_score_W_discrete_p 0.676
# test_discrete_score_W_discrete_n 0.24723579832458403
# test_discrete_score_W_discrete_a 0.2626202876361962
# neuron unit number: 45
# train_discrete_score_W0_p 0.4257142857142857
# train_discrete_score_W0_n 0.010773878868702999
# train_discrete_score_W0_a  0.016769059221554257
# test_discrete_score_W0_p 0.44
# test_discrete_score_W0_n 0.017448478186790052
# test_discrete_score_W0_a 0.024293937616296474
# train_discrete_score_W_discrete_p 0.644
# train_discrete_score_W_discrete_n 0.2101616594480377
# train_discrete_score_W_discrete_a 0.21335591056233486
# test_discrete_score_W_discrete_p 0.6693333333333333
# test_discrete_score_W_discrete_n 0.2298085821676473
# test_discrete_score_W_discrete_a 0.2516595185760797
# neuron unit number: 50
# train_discrete_score_W0_p 0.4297142857142857
# train_discrete_score_W0_n 0.011935862474085103
# train_discrete_score_W0_a  0.01755854938912773
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.027856709653746477
# test_discrete_score_W0_a 0.03789329957387652
# train_discrete_score_W_discrete_p 0.6497142857142857
# train_discrete_score_W_discrete_n 0.2153543029765595
# train_discrete_score_W_discrete_a 0.21968916555761966
# test_discrete_score_W_discrete_p 0.6733333333333333
# test_discrete_score_W_discrete_n 0.28305704129587617
# test_discrete_score_W_discrete_a 0.25684470672937587
# neuron unit number: 55
# train_discrete_score_W0_p 0.4268571428571429
# train_discrete_score_W0_n 0.01102831461142162
# train_discrete_score_W0_a  0.016406300072609827
# test_discrete_score_W0_p 0.472
# test_discrete_score_W0_n 0.03131511793041698
# test_discrete_score_W0_a 0.04274742345125847
# train_discrete_score_W_discrete_p 0.6497142857142857
# train_discrete_score_W_discrete_n 0.22385287238864834
# train_discrete_score_W_discrete_a 0.2197400042778668
# test_discrete_score_W_discrete_p 0.6733333333333333
# test_discrete_score_W_discrete_n 0.2838002762232042
# test_discrete_score_W_discrete_a 0.25613435969067383
# neuron unit number: 60
# train_discrete_score_W0_p 0.4297142857142857
# train_discrete_score_W0_n 0.012250592229496819
# train_discrete_score_W0_a  0.017912280725040836
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.02504153101814681
# test_discrete_score_W0_a 0.030965001889844142
# train_discrete_score_W_discrete_p 0.6462857142857142
# train_discrete_score_W_discrete_n 0.212214421454348
# train_discrete_score_W_discrete_a 0.2163712074148116
# test_discrete_score_W_discrete_p 0.6693333333333333
# test_discrete_score_W_discrete_n 0.2757590076457508
# test_discrete_score_W_discrete_a 0.24623743397085712
# neuron unit number: 65
# train_discrete_score_W0_p 0.42228571428571426
# train_discrete_score_W0_n 0.01048079655190606
# train_discrete_score_W0_a  0.010878683616041262
# test_discrete_score_W0_p 0.4653333333333333
# test_discrete_score_W0_n 0.03029880146247051
# test_discrete_score_W0_a 0.03624900588083301
# train_discrete_score_W_discrete_p 0.6542857142857142
# train_discrete_score_W_discrete_n 0.22023846663961025
# train_discrete_score_W_discrete_a 0.22753083993256779
# test_discrete_score_W_discrete_p 0.688
# test_discrete_score_W_discrete_n 0.26083434762705116
# test_discrete_score_W_discrete_a 0.2818748061044949
# neuron unit number: 70
# train_discrete_score_W0_p 0.43028571428571427
# train_discrete_score_W0_n 0.012241088263604424
# train_discrete_score_W0_a  0.020943478920965285
# test_discrete_score_W0_p 0.4866666666666667
# test_discrete_score_W0_n 0.040626054597869145
# test_discrete_score_W0_a 0.0512910625988731
# train_discrete_score_W_discrete_p 0.652
# train_discrete_score_W_discrete_n 0.21785819705584084
# train_discrete_score_W_discrete_a 0.2244955705368713
# test_discrete_score_W_discrete_p 0.6813333333333333
# test_discrete_score_W_discrete_n 0.2561632824348779
# test_discrete_score_W_discrete_a 0.2695236964811809
# neuron unit number: 75
# train_discrete_score_W0_p 0.43257142857142855
# train_discrete_score_W0_n 0.013791392818519006
# train_discrete_score_W0_a  0.019802382106383857
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.02102515303490674
# test_discrete_score_W0_a 0.03123129851312758
# train_discrete_score_W_discrete_p 0.5925714285714285
# train_discrete_score_W_discrete_n 0.13439043208862284
# train_discrete_score_W_discrete_a 0.15838938397104713
# test_discrete_score_W_discrete_p 0.6186666666666667
# test_discrete_score_W_discrete_n 0.15097434232938095
# test_discrete_score_W_discrete_a 0.18757419296834665
# neuron unit number: 80
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.010549446321994647
# train_discrete_score_W0_a  0.015372589425939158
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.029550250372283454
# test_discrete_score_W0_a 0.03634883178219924
# train_discrete_score_W_discrete_p 0.6428571428571429
# train_discrete_score_W_discrete_n 0.19138125054753494
# train_discrete_score_W_discrete_a 0.21513430913978018
# test_discrete_score_W_discrete_p 0.668
# test_discrete_score_W_discrete_n 0.2744154817796963
# test_discrete_score_W_discrete_a 0.24367287971898888
# neuron unit number: 85
# train_discrete_score_W0_p 0.4297142857142857
# train_discrete_score_W0_n 0.011818896995456622
# train_discrete_score_W0_a  0.020030313052720367
# test_discrete_score_W0_p 0.444
# test_discrete_score_W0_n 0.01779833345872262
# test_discrete_score_W0_a 0.026862721371437186
# train_discrete_score_W_discrete_p 0.6554285714285715
# train_discrete_score_W_discrete_n 0.2213672897910585
# train_discrete_score_W_discrete_a 0.22871896857014204
# test_discrete_score_W_discrete_p 0.6906666666666667
# test_discrete_score_W_discrete_n 0.2590489143414513
# test_discrete_score_W_discrete_a 0.2859140137917309
# neuron unit number: 90
# train_discrete_score_W0_p 0.42628571428571427
# train_discrete_score_W0_n 0.012289872409945057
# train_discrete_score_W0_a  0.01425207822570415
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.02824983562476764
# test_discrete_score_W0_a 0.03131628673865513
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.23139568439214583
# train_discrete_score_W_discrete_a 0.2209902892249932
# test_discrete_score_W_discrete_p 0.6866666666666666
# test_discrete_score_W_discrete_n 0.25470163501609205
# test_discrete_score_W_discrete_a 0.27994593041535787
# neuron unit number: 95
# train_discrete_score_W0_p 0.4188571428571429
# train_discrete_score_W0_n 0.009641869194233856
# train_discrete_score_W0_a  0.009899606449482136
# test_discrete_score_W0_p 0.44133333333333336
# test_discrete_score_W0_n 0.017534244433977022
# test_discrete_score_W0_a 0.023791306165462864
# train_discrete_score_W_discrete_p 0.6491428571428571
# train_discrete_score_W_discrete_n 0.24823508619017418
# train_discrete_score_W_discrete_a 0.21786955505835529
# test_discrete_score_W_discrete_p 0.6746666666666666
# test_discrete_score_W_discrete_n 0.24301714493785212
# test_discrete_score_W_discrete_a 0.2604433184521632
# neuron unit number: 100
# train_discrete_score_W0_p 0.43257142857142855
# train_discrete_score_W0_n 0.01544309259734422
# train_discrete_score_W0_a  0.017136226152565184
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.02890261784559331
# test_discrete_score_W0_a 0.037436714462393696
# train_discrete_score_W_discrete_p 0.652
# train_discrete_score_W_discrete_n 0.2218053030246431
# train_discrete_score_W_discrete_a 0.22448517583749314
# test_discrete_score_W_discrete_p 0.6693333333333333
# test_discrete_score_W_discrete_n 0.2580811359357157
# test_discrete_score_W_discrete_a 0.2537724397838316
# test_discrete_score_W0_p mean 0.44973333333333326
# test_discrete_score_W_discrete_p mean 0.6705333333333334
# test_discrete_score_W0_n mean 0.022108298345401296
# test_discrete_score_W_discrete_n mean 0.24191021656230682
# test_discrete_score_W0_a mean 0.029128340032187387
# test_discrete_score_W_discrete_a mean 0.25611057170928025
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.009472  0.003648  0.000816   0.007765  0.011179
# 1  train_dis_W_dis  20.0  0.203968  0.034370  0.007685   0.187883  0.220054
# 2         combined  40.0  0.106720  0.101398  0.016033   0.074291  0.139149
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1945
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -25.1662
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -7.9582
# 7                                    Hedge's g =   -7.8001
# 8                               Glass's delta1 =  -53.3131
# 9                             Point-Biserial r =   -0.9713
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.022108  0.008946  0.002000   0.017922  0.026295
# 1  test_dis_W_dis  20.0  0.241910  0.040271  0.009005   0.223063  0.260757
# 2        combined  40.0  0.132009  0.114965  0.018178   0.095242  0.168777
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2198
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -23.8286
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.5353
# 7                                  Hedge's g =   -7.3856
# 8                             Glass's delta1 =  -24.5709
# 9                           Point-Biserial r =   -0.9681
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.013439  0.005104  0.001141   0.011050  0.015828
# 1  train_dis_W_dis  20.0  0.210376  0.025973  0.005808   0.198220  0.222532
# 2         combined  40.0  0.111907  0.101420  0.016036   0.079472  0.144343
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1969
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -33.2722
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -10.5216
# 7                                    Hedge's g =  -10.3126
# 8                               Glass's delta1 =  -38.5811
# 9                             Point-Biserial r =   -0.9833
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.029128  0.011151  0.002494   0.023909  0.034347
# 1  test_dis_W_dis  20.0  0.256111  0.030675  0.006859   0.241754  0.270467
# 2        combined  40.0  0.142619  0.117173  0.018527   0.105146  0.180093
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2270
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -31.1003
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -9.8348
# 7                                  Hedge's g =   -9.6394
# 8                             Glass's delta1 =  -20.3544
# 9                           Point-Biserial r =   -0.9809
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.421229  0.009309  0.002082   0.416872  0.425585
# 1  train_dis_W_dis  20.0  0.640343  0.022950  0.005132   0.629602  0.651084
# 2         combined  40.0  0.530786  0.112291  0.017755   0.494873  0.566698
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2191
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -39.5668
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -12.5121
# 7                                    Hedge's g =  -12.2635
# 8                               Glass's delta1 =  -23.5375
# 9                             Point-Biserial r =   -0.9881
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.449733  0.018916  0.004230   0.440880  0.458586
# 1  test_dis_W_dis  20.0  0.670533  0.023745  0.005310   0.659420  0.681646
# 2        combined  40.0  0.560133  0.113797  0.017993   0.523739  0.596527
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2208
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -32.5263
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -10.2857
# 7                                  Hedge's g =  -10.0814
# 8                             Glass's delta1 =  -11.6726
# 9                           Point-Biserial r =   -0.9825
