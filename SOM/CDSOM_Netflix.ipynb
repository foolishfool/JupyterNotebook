# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])
csv_original_encode = csv


# class label do not need to onehot encoding
dataread.label_encoding(csv_original_encode,"Subscription Type")
#one hot encoding vs proposed
dataread.baseN_encoding(csv_original_encode,["Country","Gender","Device"])

dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Subscription Type")
# Out:
#       Subscription Type  Monthly Revenue  Join Date  Last Payment Date  \
# 0                     0             10.0    44576.0            45087.0
# 1                     1             15.0    44444.0            45099.0
# 2                     2             12.0    44985.0            45104.0
# 3                     2             12.0    44752.0            45103.0
# 4                     0             10.0    45047.0            45105.0
# ...                 ...              ...        ...                ...
# 2495                  1             14.0    44767.0            45119.0
# 2496                  0             15.0    44777.0            45121.0
# 2497                  2             12.0    44782.0            45122.0
# 2498                  2             13.0    44785.0            45119.0
# 2499                  0             15.0    44786.0            45119.0
#
#              Country   Age  Gender      Device
# 0      United States  28.0    Male  Smartphone
# 1             Canada  35.0  Female      Tablet
# 2     United Kingdom  42.0    Male    Smart TV
# 3          Australia  51.0  Female      Laptop
# 4            Germany  33.0    Male  Smartphone
# ...              ...   ...     ...         ...
# 2495           Spain  28.0  Female    Smart TV
# 2496           Spain  33.0  Female    Smart TV
# 2497   United States  38.0    Male      Laptop
# 2498          Canada  48.0  Female      Tablet
# 2499   United States  35.0  Female    Smart TV
#
# [2500 rows x 8 columns]
#       Subscription Type  Monthly Revenue  Join Date  Last Payment Date  \
# 0                     0             10.0    44576.0            45087.0
# 1                     1             15.0    44444.0            45099.0
# 2                     2             12.0    44985.0            45104.0
# 3                     2             12.0    44752.0            45103.0
# 4                     0             10.0    45047.0            45105.0
# ...                 ...              ...        ...                ...
# 2495                  1             14.0    44767.0            45119.0
# 2496                  0             15.0    44777.0            45121.0
# 2497                  2             12.0    44782.0            45122.0
# 2498                  2             13.0    44785.0            45119.0
# 2499                  0             15.0    44786.0            45119.0
#
#       Country_0  Country_1   Age  Gender_0  Device_0
# 0             0          1  28.0         1         1
# 1             0          2  35.0         2         2
# 2             0          3  42.0         1         3
# 3             0          4  51.0         2         4
# 4             1          0  33.0         1         1
# ...         ...        ...   ...       ...       ...
# 2495          1          4  28.0         2         3
# 2496          1          4  33.0         2         3
# 2497          0          1  38.0         1         4
# 2498          0          2  48.0         2         2
# 2499          0          1  35.0         2         3
#
# [2500 rows x 9 columns]
# self.data_continuous_indexes ['Join Date', 'Last Payment Date', 'Age']
#  column number self.data_train_discrete 4

# %%
# baseN encoding

unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 5
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.392
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.41733333333333333
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.5651428571428572
# train_discrete_score_W_discrete_n 0.10524547177012786
# train_discrete_score_W_discrete_a 0.12031494634659606
# test_discrete_score_W_discrete_p 0.5973333333333334
# test_discrete_score_W_discrete_n 0.12797118743109054
# test_discrete_score_W_discrete_a 0.1633310955803435
# neuron unit number: 10
# train_discrete_score_W0_p 0.4022857142857143
# train_discrete_score_W0_n 0.004182790158639863
# train_discrete_score_W0_a  0.005540248238967811
# test_discrete_score_W0_p 0.42133333333333334
# test_discrete_score_W0_n 0.0021939450993923235
# test_discrete_score_W0_a 0.0041671401482912115
# train_discrete_score_W_discrete_p 0.5845714285714285
# train_discrete_score_W_discrete_n 0.17168706784714402
# train_discrete_score_W_discrete_a 0.1293337160959452
# test_discrete_score_W_discrete_p 0.6133333333333333
# test_discrete_score_W_discrete_n 0.178726341743666
# test_discrete_score_W_discrete_a 0.16033474773949027
# neuron unit number: 15
# train_discrete_score_W0_p 0.4
# train_discrete_score_W0_n 0.004471800168784907
# train_discrete_score_W0_a  0.003798522652570788
# test_discrete_score_W0_p 0.428
# test_discrete_score_W0_n 0.006543840988505216
# test_discrete_score_W0_a 0.011674652954994383
# train_discrete_score_W_discrete_p 0.6194285714285714
# train_discrete_score_W_discrete_n 0.20850216857884993
# train_discrete_score_W_discrete_a 0.17762206106189915
# test_discrete_score_W_discrete_p 0.664
# test_discrete_score_W_discrete_n 0.23538889275941224
# test_discrete_score_W_discrete_a 0.2409876734015262
# neuron unit number: 20
# train_discrete_score_W0_p 0.41314285714285715
# train_discrete_score_W0_n 0.009832325246340635
# train_discrete_score_W0_a  0.009796190194739807
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.009509012575538354
# test_discrete_score_W0_a 0.01982414809735808
# train_discrete_score_W_discrete_p 0.6388571428571429
# train_discrete_score_W_discrete_n 0.22433320752650812
# train_discrete_score_W_discrete_a 0.20620561337942883
# test_discrete_score_W_discrete_p 0.6733333333333333
# test_discrete_score_W_discrete_n 0.22501884129356842
# test_discrete_score_W_discrete_a 0.2639753660614536
# neuron unit number: 25
# train_discrete_score_W0_p 0.412
# train_discrete_score_W0_n 0.007360138637544879
# train_discrete_score_W0_a  0.009741510954907188
# test_discrete_score_W0_p 0.44
# test_discrete_score_W0_n 0.014209163475374606
# test_discrete_score_W0_a 0.0179254810843813
# train_discrete_score_W_discrete_p 0.6497142857142857
# train_discrete_score_W_discrete_n 0.21410726460146642
# train_discrete_score_W_discrete_a 0.2225262615769574
# test_discrete_score_W_discrete_p 0.68
# test_discrete_score_W_discrete_n 0.26199970742856704
# test_discrete_score_W_discrete_a 0.26646482689794804
# neuron unit number: 30
# train_discrete_score_W0_p 0.4217142857142857
# train_discrete_score_W0_n 0.010694845203830775
# train_discrete_score_W0_a  0.01656265052757184
# test_discrete_score_W0_p 0.436
# test_discrete_score_W0_n 0.0089200453269076
# test_discrete_score_W0_a 0.013626659103533056
# train_discrete_score_W_discrete_p 0.6508571428571429
# train_discrete_score_W_discrete_n 0.22048884433079216
# train_discrete_score_W_discrete_a 0.22389692228234662
# test_discrete_score_W_discrete_p 0.692
# test_discrete_score_W_discrete_n 0.28424496446123515
# test_discrete_score_W_discrete_a 0.28624180269138894
# neuron unit number: 35
# train_discrete_score_W0_p 0.43314285714285716
# train_discrete_score_W0_n 0.015600345993977832
# train_discrete_score_W0_a  0.022871486716183102
# test_discrete_score_W0_p 0.4493333333333333
# test_discrete_score_W0_n 0.018211667601595937
# test_discrete_score_W0_a 0.021046730175906025
# train_discrete_score_W_discrete_p 0.6542857142857142
# train_discrete_score_W_discrete_n 0.22749519842852137
# train_discrete_score_W_discrete_a 0.22760939061597632
# test_discrete_score_W_discrete_p 0.6986666666666667
# test_discrete_score_W_discrete_n 0.253955373705607
# test_discrete_score_W_discrete_a 0.3031503901050088
# neuron unit number: 40
# train_discrete_score_W0_p 0.42857142857142855
# train_discrete_score_W0_n 0.013512065154748181
# train_discrete_score_W0_a  0.01934461676462422
# test_discrete_score_W0_p 0.44
# test_discrete_score_W0_n 0.01349204828670669
# test_discrete_score_W0_a 0.015665119365791
# train_discrete_score_W_discrete_p 0.6474285714285715
# train_discrete_score_W_discrete_n 0.24835357166991293
# train_discrete_score_W_discrete_a 0.21697556259100506
# test_discrete_score_W_discrete_p 0.688
# test_discrete_score_W_discrete_n 0.2376067363219878
# test_discrete_score_W_discrete_a 0.2837740983098594
# neuron unit number: 45
# train_discrete_score_W0_p 0.42228571428571426
# train_discrete_score_W0_n 0.010881089544762364
# train_discrete_score_W0_a  0.018074586888168143
# test_discrete_score_W0_p 0.43866666666666665
# test_discrete_score_W0_n 0.010665373321804877
# test_discrete_score_W0_a 0.014979444271648235
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.21345565805419817
# train_discrete_score_W_discrete_a 0.2258762500957663
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.28511588704750535
# test_discrete_score_W_discrete_a 0.28844741649550004
# neuron unit number: 50
# train_discrete_score_W0_p 0.42628571428571427
# train_discrete_score_W0_n 0.012114177594912137
# train_discrete_score_W0_a  0.017781859244587597
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.019769119080537946
# test_discrete_score_W0_a 0.02628633061860912
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.24549420114369702
# train_discrete_score_W_discrete_a 0.2210214281443896
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.2406682354168098
# test_discrete_score_W_discrete_a 0.27584812119213575
# neuron unit number: 55
# train_discrete_score_W0_p 0.42742857142857144
# train_discrete_score_W0_n 0.012946711496176712
# train_discrete_score_W0_a  0.017454795088734484
# test_discrete_score_W0_p 0.452
# test_discrete_score_W0_n 0.018767369369702955
# test_discrete_score_W0_a 0.025196785583802096
# train_discrete_score_W_discrete_p 0.6474285714285715
# train_discrete_score_W_discrete_n 0.24737762226396623
# train_discrete_score_W_discrete_a 0.2147169563820141
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.24477702744711485
# test_discrete_score_W_discrete_a 0.29330130162490303
# neuron unit number: 60
# train_discrete_score_W0_p 0.42628571428571427
# train_discrete_score_W0_n 0.012449874658167692
# train_discrete_score_W0_a  0.017803387848640686
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.015942118196515302
# test_discrete_score_W0_a 0.02313034035685429
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.22474293863175354
# train_discrete_score_W_discrete_a 0.22333678495103693
# test_discrete_score_W_discrete_p 0.6946666666666667
# test_discrete_score_W_discrete_n 0.25321218097057924
# test_discrete_score_W_discrete_a 0.295017068309032
# neuron unit number: 65
# train_discrete_score_W0_p 0.43142857142857144
# train_discrete_score_W0_n 0.014542623525970006
# train_discrete_score_W0_a  0.021924168575654563
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.01402667665018264
# test_discrete_score_W0_a 0.023097361941914293
# train_discrete_score_W_discrete_p 0.6497142857142857
# train_discrete_score_W_discrete_n 0.21120449064064364
# train_discrete_score_W_discrete_a 0.2215296233695661
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.2455037654639282
# test_discrete_score_W_discrete_a 0.27564934496871557
# neuron unit number: 70
# train_discrete_score_W0_p 0.4377142857142857
# train_discrete_score_W0_n 0.01721975985776957
# train_discrete_score_W0_a  0.024032662059829468
# test_discrete_score_W0_p 0.4693333333333333
# test_discrete_score_W0_n 0.026222005198986837
# test_discrete_score_W0_a 0.03458194307613658
# train_discrete_score_W_discrete_p 0.6462857142857142
# train_discrete_score_W_discrete_n 0.24730951722522224
# train_discrete_score_W_discrete_a 0.21522052630626629
# test_discrete_score_W_discrete_p 0.692
# test_discrete_score_W_discrete_n 0.2492309112641566
# test_discrete_score_W_discrete_a 0.29263845301970315
# neuron unit number: 75
# train_discrete_score_W0_p 0.4377142857142857
# train_discrete_score_W0_n 0.017174012806503377
# train_discrete_score_W0_a  0.02325941736692919
# test_discrete_score_W0_p 0.47733333333333333
# test_discrete_score_W0_n 0.029488935101226823
# test_discrete_score_W0_a 0.04578008261741628
# train_discrete_score_W_discrete_p 0.652
# train_discrete_score_W_discrete_n 0.21733590315147674
# train_discrete_score_W_discrete_a 0.22436431007618857
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.2558563491346409
# test_discrete_score_W_discrete_a 0.2707210485715393
# neuron unit number: 80
# train_discrete_score_W0_p 0.43257142857142855
# train_discrete_score_W0_n 0.015191832691524992
# train_discrete_score_W0_a  0.02141019596044498
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.020195398186288658
# test_discrete_score_W0_a 0.029350078402281224
# train_discrete_score_W_discrete_p 0.6491428571428571
# train_discrete_score_W_discrete_n 0.20863042471702856
# train_discrete_score_W_discrete_a 0.22081772515960346
# test_discrete_score_W_discrete_p 0.6826666666666666
# test_discrete_score_W_discrete_n 0.24662785366350515
# test_discrete_score_W_discrete_a 0.27128303746738913
# neuron unit number: 85
# train_discrete_score_W0_p 0.4308571428571429
# train_discrete_score_W0_n 0.014505612228029307
# train_discrete_score_W0_a  0.01939200137485136
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.01766849037450339
# test_discrete_score_W0_a 0.025087725942866023
# train_discrete_score_W_discrete_p 0.6462857142857142
# train_discrete_score_W_discrete_n 0.24633714702906911
# train_discrete_score_W_discrete_a 0.21307738368017584
# test_discrete_score_W_discrete_p 0.6786666666666666
# test_discrete_score_W_discrete_n 0.28222778215539296
# test_discrete_score_W_discrete_a 0.2659101532753034
# neuron unit number: 90
# train_discrete_score_W0_p 0.43028571428571427
# train_discrete_score_W0_n 0.013829377643644964
# train_discrete_score_W0_a  0.018957317297540806
# test_discrete_score_W0_p 0.48
# test_discrete_score_W0_n 0.03276069560257467
# test_discrete_score_W0_a 0.04838354746569361
# train_discrete_score_W_discrete_p 0.6462857142857142
# train_discrete_score_W_discrete_n 0.22345835843015469
# train_discrete_score_W_discrete_a 0.21653957296014328
# test_discrete_score_W_discrete_p 0.6773333333333333
# test_discrete_score_W_discrete_n 0.23755972850371054
# test_discrete_score_W_discrete_a 0.2710684708291163
# neuron unit number: 95
# train_discrete_score_W0_p 0.4268571428571429
# train_discrete_score_W0_n 0.012743135806420936
# train_discrete_score_W0_a  0.017579069103511768
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.020997517713881378
# test_discrete_score_W0_a 0.027825408730498002
# train_discrete_score_W_discrete_p 0.6502857142857142
# train_discrete_score_W_discrete_n 0.21623296634851305
# train_discrete_score_W_discrete_a 0.22251413625397212
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.23150367716574988
# test_discrete_score_W_discrete_a 0.282589697770247
# neuron unit number: 100
# train_discrete_score_W0_p 0.4297142857142857
# train_discrete_score_W0_n 0.014115281055051733
# train_discrete_score_W0_a  0.01858921327530261
# test_discrete_score_W0_p 0.4746666666666667
# test_discrete_score_W0_n 0.028713644665079543
# test_discrete_score_W0_a 0.038397740030837346
# train_discrete_score_W_discrete_p 0.656
# train_discrete_score_W_discrete_n 0.2268042407376391
# train_discrete_score_W_discrete_a 0.22923095920701014
# test_discrete_score_W_discrete_p 0.6813333333333333
# test_discrete_score_W_discrete_n 0.2581469542511472
# test_discrete_score_W_discrete_a 0.26501299138719964
# test_discrete_score_W0_p mean 0.44893333333333335
# test_discrete_score_W_discrete_p mean 0.6768
# test_discrete_score_W0_n mean 0.016414853340765284
# test_discrete_score_W_discrete_n mean 0.24176711988146876
# test_discrete_score_W0_a mean 0.023301335998440607
# test_discrete_score_W_discrete_a mean 0.26578735528489017
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.011668  0.004533  0.001014   0.009547  0.013790
# 1  train_dis_W_dis  20.0  0.217430  0.032124  0.007183   0.202395  0.232464
# 2         combined  40.0  0.114549  0.106624  0.016859   0.080449  0.148649
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2058
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -28.3640
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.9695
# 7                                    Hedge's g =   -8.7913
# 8                                Glass's delta =  -45.3900
# 9                                  Pearson's r =    0.9772
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.016415  0.008789  0.001965   0.012301  0.020528
# 1  test_dis_W_dis  20.0  0.241767  0.035515  0.007941   0.225146  0.258389
# 2        combined  40.0  0.129091  0.116934  0.018489   0.091694  0.166488
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2254
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -27.5459
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.7108
# 7                                  Hedge's g =   -8.5377
# 8                              Glass's delta =  -25.6392
# 9                                Pearson's r =    0.9759
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.016196  0.006781  0.001516   0.013022  0.019370
# 1  train_dis_W_dis  20.0  0.208637  0.030711  0.006867   0.194263  0.223010
# 2         combined  40.0  0.112416  0.099888  0.015794   0.080470  0.144362
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1924
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -27.3637
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.6532
# 7                                    Hedge's g =   -8.4812
# 8                                Glass's delta =  -28.3775
# 9                                  Pearson's r =    0.9756
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.023301  0.012299  0.002750   0.017545  0.029057
# 1  test_dis_W_dis  20.0  0.265787  0.038240  0.008551   0.247890  0.283684
# 2        combined  40.0  0.144544  0.125948  0.019914   0.104264  0.184824
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2425
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -26.9965
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.5371
# 7                                  Hedge's g =   -8.3674
# 8                              Glass's delta =  -19.7165
# 9                                Pearson's r =    0.9749
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.423114  0.012742  0.002849   0.417151  0.429078
# 1  train_dis_W_dis  20.0  0.640400  0.023861  0.005336   0.629232  0.651568
# 2         combined  40.0  0.531757  0.111635  0.017651   0.496055  0.567460
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2173
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -35.9230
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -11.3599
# 7                                    Hedge's g =  -11.1342
# 8                                Glass's delta =  -17.0530
# 9                                  Pearson's r =    0.9856
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.448933  0.017962  0.004016   0.440527  0.457340
# 1  test_dis_W_dis  20.0  0.676800  0.025881  0.005787   0.664687  0.688913
# 2        combined  40.0  0.562867  0.117461  0.018572   0.525301  0.600433
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2279
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -32.3473
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -10.2291
# 7                                  Hedge's g =  -10.0259
# 8                              Glass's delta =  -12.6859
# 9                                Pearson's r =    0.9823
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
# sum encoding

unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 5
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.3994285714285714
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.4013333333333333
# test_discrete_score_W0_n 0.008712844030487669
# test_discrete_score_W0_a 0.003085581426843623
# train_discrete_score_W_discrete_p 0.616
# train_discrete_score_W_discrete_n 0.2173251381901361
# train_discrete_score_W_discrete_a 0.17086573734584284
# test_discrete_score_W_discrete_p 0.6426666666666667
# test_discrete_score_W_discrete_n 0.2356129242422824
# test_discrete_score_W_discrete_a 0.21223126828995958
# neuron unit number: 10
# train_discrete_score_W0_p 0.4034285714285714
# train_discrete_score_W0_n 0.0022735650640814866
# train_discrete_score_W0_a  0.003986786641262529
# test_discrete_score_W0_p 0.41733333333333333
# test_discrete_score_W0_n 0.009142692754601486
# test_discrete_score_W0_a 0.008426835271647611
# train_discrete_score_W_discrete_p 0.648
# train_discrete_score_W_discrete_n 0.215776404485344
# train_discrete_score_W_discrete_a 0.22035054615981317
# test_discrete_score_W_discrete_p 0.688
# test_discrete_score_W_discrete_n 0.2604777096018559
# test_discrete_score_W_discrete_a 0.28226632390902323
# neuron unit number: 15
# train_discrete_score_W0_p 0.4125714285714286
# train_discrete_score_W0_n 0.005697490895654169
# train_discrete_score_W0_a  0.009784729839141696
# test_discrete_score_W0_p 0.43466666666666665
# test_discrete_score_W0_n 0.020284470616066485
# test_discrete_score_W0_a 0.018623123124302147
# train_discrete_score_W_discrete_p 0.6228571428571429
# train_discrete_score_W_discrete_n 0.22324963665492334
# train_discrete_score_W_discrete_a 0.18071043533919992
# test_discrete_score_W_discrete_p 0.6586666666666666
# test_discrete_score_W_discrete_n 0.2326376826406131
# test_discrete_score_W_discrete_a 0.23287579765892824
# neuron unit number: 20
# train_discrete_score_W0_p 0.41085714285714287
# train_discrete_score_W0_n 0.005183411512259379
# train_discrete_score_W0_a  0.007228950392474775
# test_discrete_score_W0_p 0.432
# test_discrete_score_W0_n 0.01325137781283207
# test_discrete_score_W0_a 0.016168850489300647
# train_discrete_score_W_discrete_p 0.6308571428571429
# train_discrete_score_W_discrete_n 0.23136508470857572
# train_discrete_score_W_discrete_a 0.1934239392577059
# test_discrete_score_W_discrete_p 0.6733333333333333
# test_discrete_score_W_discrete_n 0.2769524902638958
# test_discrete_score_W_discrete_a 0.2523138122976425
# neuron unit number: 25
# train_discrete_score_W0_p 0.4188571428571429
# train_discrete_score_W0_n 0.008279540294772595
# train_discrete_score_W0_a  0.014218295783419611
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.024043229206866558
# test_discrete_score_W0_a 0.021855548659575737
# train_discrete_score_W_discrete_p 0.6222857142857143
# train_discrete_score_W_discrete_n 0.22273833884460745
# train_discrete_score_W_discrete_a 0.1796849050092791
# test_discrete_score_W_discrete_p 0.6613333333333333
# test_discrete_score_W_discrete_n 0.26862114240667245
# test_discrete_score_W_discrete_a 0.23311100409808402
# neuron unit number: 30
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.009967283467804733
# train_discrete_score_W0_a  0.01668261996622524
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.020592930827878365
# test_discrete_score_W0_a 0.030069779165395907
# train_discrete_score_W_discrete_p 0.652
# train_discrete_score_W_discrete_n 0.23479611913024817
# train_discrete_score_W_discrete_a 0.22248992524079927
# test_discrete_score_W_discrete_p 0.6946666666666667
# test_discrete_score_W_discrete_n 0.2899568226110641
# test_discrete_score_W_discrete_a 0.28834499076392295
# neuron unit number: 35
# train_discrete_score_W0_p 0.42914285714285716
# train_discrete_score_W0_n 0.011583377014788374
# train_discrete_score_W0_a  0.019996748675907044
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.026482051804770625
# test_discrete_score_W0_a 0.03463583531364593
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.24912952897328094
# train_discrete_score_W_discrete_a 0.2206643735721737
# test_discrete_score_W_discrete_p 0.6893333333333334
# test_discrete_score_W_discrete_n 0.2709839461439825
# test_discrete_score_W_discrete_a 0.27677328776163435
# neuron unit number: 40
# train_discrete_score_W0_p 0.43142857142857144
# train_discrete_score_W0_n 0.012236054036807028
# train_discrete_score_W0_a  0.02043402944859526
# test_discrete_score_W0_p 0.452
# test_discrete_score_W0_n 0.021554221085698374
# test_discrete_score_W0_a 0.028632658359577026
# train_discrete_score_W_discrete_p 0.644
# train_discrete_score_W_discrete_n 0.24171696616183524
# train_discrete_score_W_discrete_a 0.2108838466750949
# test_discrete_score_W_discrete_p 0.6853333333333333
# test_discrete_score_W_discrete_n 0.29220633008924696
# test_discrete_score_W_discrete_a 0.26886193531780533
# neuron unit number: 45
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.0106504639351422
# train_discrete_score_W0_a  0.017664607984594793
# test_discrete_score_W0_p 0.452
# test_discrete_score_W0_n 0.022601340935201077
# test_discrete_score_W0_a 0.027766712740721247
# train_discrete_score_W_discrete_p 0.6485714285714286
# train_discrete_score_W_discrete_n 0.22097043878809702
# train_discrete_score_W_discrete_a 0.2192123565502066
# test_discrete_score_W_discrete_p 0.6893333333333334
# test_discrete_score_W_discrete_n 0.2940221934346379
# test_discrete_score_W_discrete_a 0.2761231910079283
# neuron unit number: 50
# train_discrete_score_W0_p 0.4257142857142857
# train_discrete_score_W0_n 0.010205452580936527
# train_discrete_score_W0_a  0.017020733845945695
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.020577962043098384
# test_discrete_score_W0_a 0.0293909338212021
# train_discrete_score_W_discrete_p 0.6502857142857142
# train_discrete_score_W_discrete_n 0.21453296698829807
# train_discrete_score_W_discrete_a 0.22158302581910774
# test_discrete_score_W_discrete_p 0.688
# test_discrete_score_W_discrete_n 0.29049324157633766
# test_discrete_score_W_discrete_a 0.2767083024721882
# neuron unit number: 55
# train_discrete_score_W0_p 0.4268571428571429
# train_discrete_score_W0_n 0.010445899233091258
# train_discrete_score_W0_a  0.018106283660708662
# test_discrete_score_W0_p 0.4653333333333333
# test_discrete_score_W0_n 0.02837969882579956
# test_discrete_score_W0_a 0.038857763226037026
# train_discrete_score_W_discrete_p 0.6537142857142857
# train_discrete_score_W_discrete_n 0.2452452378195639
# train_discrete_score_W_discrete_a 0.22630084441401319
# test_discrete_score_W_discrete_p 0.6973333333333334
# test_discrete_score_W_discrete_n 0.2820340744964814
# test_discrete_score_W_discrete_a 0.29244494343943694
# neuron unit number: 60
# train_discrete_score_W0_p 0.4297142857142857
# train_discrete_score_W0_n 0.011561867473071958
# train_discrete_score_W0_a  0.017892458504081003
# test_discrete_score_W0_p 0.4613333333333333
# test_discrete_score_W0_n 0.0261844003196883
# test_discrete_score_W0_a 0.0344096712369435
# train_discrete_score_W_discrete_p 0.6531428571428571
# train_discrete_score_W_discrete_n 0.21851673308504654
# train_discrete_score_W_discrete_a 0.22747289063674708
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.27976930969282804
# test_discrete_score_W_discrete_a 0.28921138061323315
# neuron unit number: 65
# train_discrete_score_W0_p 0.43314285714285716
# train_discrete_score_W0_n 0.012892102087937755
# train_discrete_score_W0_a  0.019597948268851775
# test_discrete_score_W0_p 0.4493333333333333
# test_discrete_score_W0_n 0.021018349669801872
# test_discrete_score_W0_a 0.02764712896301432
# train_discrete_score_W_discrete_p 0.6491428571428571
# train_discrete_score_W_discrete_n 0.2349313804663843
# train_discrete_score_W_discrete_a 0.2201356811214765
# test_discrete_score_W_discrete_p 0.688
# test_discrete_score_W_discrete_n 0.2882253453770137
# test_discrete_score_W_discrete_a 0.27224795311998096
# neuron unit number: 70
# train_discrete_score_W0_p 0.41714285714285715
# train_discrete_score_W0_n 0.007195223055647197
# train_discrete_score_W0_a  0.01160276125038221
# test_discrete_score_W0_p 0.48
# test_discrete_score_W0_n 0.03738206000233537
# test_discrete_score_W0_a 0.0461686739827822
# train_discrete_score_W_discrete_p 0.6594285714285715
# train_discrete_score_W_discrete_n 0.2228162018157527
# train_discrete_score_W_discrete_a 0.23599995040917143
# test_discrete_score_W_discrete_p 0.6973333333333334
# test_discrete_score_W_discrete_n 0.2793880905820735
# test_discrete_score_W_discrete_a 0.2909398886511935
# neuron unit number: 75
# train_discrete_score_W0_p 0.42857142857142855
# train_discrete_score_W0_n 0.011120981977900485
# train_discrete_score_W0_a  0.018341589030596166
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.03218303785834947
# test_discrete_score_W0_a 0.034195127734275764
# train_discrete_score_W_discrete_p 0.648
# train_discrete_score_W_discrete_n 0.24597937147053303
# train_discrete_score_W_discrete_a 0.2160020838489435
# test_discrete_score_W_discrete_p 0.6853333333333333
# test_discrete_score_W_discrete_n 0.2927616643073987
# test_discrete_score_W_discrete_a 0.2702646994821298
# neuron unit number: 80
# train_discrete_score_W0_p 0.42457142857142854
# train_discrete_score_W0_n 0.010463122072366356
# train_discrete_score_W0_a  0.015864891038332402
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.028645674251040348
# test_discrete_score_W0_a 0.028796425009631366
# train_discrete_score_W_discrete_p 0.6508571428571429
# train_discrete_score_W_discrete_n 0.251069779339935
# train_discrete_score_W_discrete_a 0.22148736391177548
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.29324691986859514
# test_discrete_score_W_discrete_a 0.2843900865389653
# neuron unit number: 85
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.009970237199125237
# train_discrete_score_W0_a  0.016802321377122786
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03932406219474416
# test_discrete_score_W0_a 0.04892742051890971
# train_discrete_score_W_discrete_p 0.652
# train_discrete_score_W_discrete_n 0.22390195941279376
# train_discrete_score_W_discrete_a 0.22545451804107594
# test_discrete_score_W_discrete_p 0.6986666666666667
# test_discrete_score_W_discrete_n 0.2760190053031369
# test_discrete_score_W_discrete_a 0.295478348459896
# neuron unit number: 90
# train_discrete_score_W0_p 0.42
# train_discrete_score_W0_n 0.00805824318443362
# train_discrete_score_W0_a  0.013886302739983772
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.02022594832760924
# test_discrete_score_W0_a 0.026568431051392616
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.21314640019745681
# train_discrete_score_W_discrete_a 0.22608298317166373
# test_discrete_score_W_discrete_p 0.6973333333333334
# test_discrete_score_W_discrete_n 0.28488742037867276
# test_discrete_score_W_discrete_a 0.29640057153889393
# neuron unit number: 95
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.009855386692086857
# train_discrete_score_W0_a  0.01630087815189277
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.026381538751374573
# test_discrete_score_W0_a 0.034443694782651565
# train_discrete_score_W_discrete_p 0.6531428571428571
# train_discrete_score_W_discrete_n 0.22243005900035467
# train_discrete_score_W_discrete_a 0.22536268155821598
# test_discrete_score_W_discrete_p 0.6906666666666667
# test_discrete_score_W_discrete_n 0.2727699035492172
# test_discrete_score_W_discrete_a 0.2821107564756133
# neuron unit number: 100
# train_discrete_score_W0_p 0.4177142857142857
# train_discrete_score_W0_n 0.007461394764488917
# train_discrete_score_W0_a  0.012703776334063685
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.037488625656641225
# test_discrete_score_W0_a 0.038385972609538306
# train_discrete_score_W_discrete_p 0.6462857142857142
# train_discrete_score_W_discrete_n 0.22954860792780266
# train_discrete_score_W_discrete_a 0.21449271617729537
# test_discrete_score_W_discrete_p 0.696
# test_discrete_score_W_discrete_n 0.2678220811502732
# test_discrete_score_W_discrete_a 0.2951089542335361
# test_discrete_score_W0_p mean 0.4518000000000001
# test_discrete_score_W_discrete_p mean 0.6854
# test_discrete_score_W0_n mean 0.02422282584874426
# test_discrete_score_W_discrete_n mean 0.27644441488581395
# test_discrete_score_W0_a mean 0.028852808374369415
# test_discrete_score_W_discrete_a mean 0.27341037480649977
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.008755  0.003340  0.000747   0.007192  0.010318
# 1  train_dis_W_dis  20.0  0.228959  0.012154  0.002718   0.223271  0.234648
# 2         combined  40.0  0.118857  0.111851  0.017685   0.083085  0.154629
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2202
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -78.1295
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -24.7067
# 7                                    Hedge's g =  -24.2158
# 8                                Glass's delta =  -65.9348
# 9                                  Pearson's r =    0.9969
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.024223  0.008452  0.001890   0.020267  0.028179
# 1  test_dis_W_dis  20.0  0.276444  0.017423  0.003896   0.268290  0.284598
# 2        combined  40.0  0.150334  0.128431  0.020307   0.109260  0.191408
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2522
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -58.2488
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -18.4199
# 7                                  Hedge's g =  -18.0539
# 8                              Glass's delta =  -29.8409
# 9                                Pearson's r =    0.9944
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.014406  0.005477  0.001225   0.011842  0.016969
# 1  train_dis_W_dis  20.0  0.213933  0.017979  0.004020   0.205518  0.222348
# 2         combined  40.0  0.114169  0.101883  0.016109   0.081586  0.146753
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1995
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -47.4757
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -15.0131
# 7                                    Hedge's g =  -14.7149
# 8                                Glass's delta =  -36.4283
# 9                                  Pearson's r =    0.9917
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.028853  0.011293  0.002525   0.023567  0.034138
# 1  test_dis_W_dis  20.0  0.273410  0.023418  0.005236   0.262450  0.284370
# 2        combined  40.0  0.151132  0.125159  0.019789   0.111104  0.191159
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2446
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -42.0666
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -13.3026
# 7                                  Hedge's g =  -13.0383
# 8                              Glass's delta =  -21.6550
# 9                                Pearson's r =    0.9894
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.421486  0.009085  0.002032   0.417234  0.425738
# 1  train_dis_W_dis  20.0  0.645171  0.012046  0.002694   0.639534  0.650809
# 2         combined  40.0  0.533329  0.113756  0.017986   0.496948  0.569710
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2237
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -66.3025
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -20.9667
# 7                                    Hedge's g =  -20.5501
# 8                                Glass's delta =  -24.6210
# 9                                  Pearson's r =    0.9957
#          Variable     N    Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.4518  0.019333  0.004323   0.442752  0.460848
# 1  test_dis_W_dis  20.0  0.6854  0.014995  0.003353   0.678382  0.692418
# 2        combined  40.0  0.5686  0.119514  0.018897   0.530377  0.606823
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2336
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -42.6993
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -13.5027
# 7                                  Hedge's g =  -13.2344
# 8                              Glass's delta =  -12.0831
# 9                                Pearson's r =    0.9897
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
# one hot encoding

unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 5
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# 1750
# 1750
# train_discrete_score_W0_p 0.39885714285714285
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# 750
# 750
# test_discrete_score_W0_p 0.408
# test_discrete_score_W0_n 0.00741451883500766
# test_discrete_score_W0_a 0.012377248035687422
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.5611428571428572
# train_discrete_score_W_discrete_n 0.10682081177538101
# train_discrete_score_W_discrete_a 0.11281318650848858
# 750
# 750
# test_discrete_score_W_discrete_p 0.5773333333333334
# test_discrete_score_W_discrete_n 0.11990326740182673
# test_discrete_score_W_discrete_a 0.1311064813545173
# neuron unit number: 10
# 1750
# 1750
# train_discrete_score_W0_p 0.4045714285714286
# train_discrete_score_W0_n 0.0039686289406788006
# train_discrete_score_W0_a  0.007478146314844185
# 750
# 750
# test_discrete_score_W0_p 0.41333333333333333
# test_discrete_score_W0_n 0.006355799533767776
# test_discrete_score_W0_a 0.006871055349290884
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.5782857142857143
# train_discrete_score_W_discrete_n 0.11386412308552657
# train_discrete_score_W_discrete_a 0.13461635229167407
# 750
# 750
# test_discrete_score_W_discrete_p 0.6213333333333333
# test_discrete_score_W_discrete_n 0.15498442203753632
# test_discrete_score_W_discrete_a 0.18752666191565998
# neuron unit number: 15
# 1750
# 1750
# train_discrete_score_W0_p 0.4102857142857143
# train_discrete_score_W0_n 0.005609448395045179
# train_discrete_score_W0_a  0.007457974681612422
# 750
# 750
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0086088045408889
# test_discrete_score_W0_a 0.009289007597537632
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6531428571428571
# train_discrete_score_W_discrete_n 0.22029998279248023
# train_discrete_score_W_discrete_a 0.22814074416006594
# 750
# 750
# test_discrete_score_W_discrete_p 0.6893333333333334
# test_discrete_score_W_discrete_n 0.24932703375419896
# test_discrete_score_W_discrete_a 0.28392578002836055
# neuron unit number: 20
# 1750
# 1750
# train_discrete_score_W0_p 0.41485714285714287
# train_discrete_score_W0_n 0.00829058034197539
# train_discrete_score_W0_a  0.011176564196043572
# 750
# 750
# test_discrete_score_W0_p 0.428
# test_discrete_score_W0_n 0.012378767294148585
# test_discrete_score_W0_a 0.015186029547694397
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6537142857142857
# train_discrete_score_W_discrete_n 0.2417834453892567
# train_discrete_score_W_discrete_a 0.22631075804686193
# 750
# 750
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.2601304596811569
# test_discrete_score_W_discrete_a 0.2930420242326312
# neuron unit number: 25
# 1750
# 1750
# train_discrete_score_W0_p 0.4205714285714286
# train_discrete_score_W0_n 0.009280359238907134
# train_discrete_score_W0_a  0.01263701875216139
# 750
# 750
# test_discrete_score_W0_p 0.42533333333333334
# test_discrete_score_W0_n 0.0101084793028181
# test_discrete_score_W0_a 0.015379331066410347
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.656
# train_discrete_score_W_discrete_n 0.20821986172982385
# train_discrete_score_W_discrete_a 0.234200659215421
# 750
# 750
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.265622037901496
# test_discrete_score_W_discrete_a 0.2909993459971101
# neuron unit number: 30
# 1750
# 1750
# train_discrete_score_W0_p 0.4257142857142857
# train_discrete_score_W0_n 0.010734810004309798
# train_discrete_score_W0_a  0.019158256279346298
# 750
# 750
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.02386844201190372
# test_discrete_score_W0_a 0.027000780523155975
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6548571428571428
# train_discrete_score_W_discrete_n 0.22863494887649302
# train_discrete_score_W_discrete_a 0.22856945032522147
# 750
# 750
# test_discrete_score_W_discrete_p 0.6826666666666666
# test_discrete_score_W_discrete_n 0.2634148162735385
# test_discrete_score_W_discrete_a 0.2702377341145636
# neuron unit number: 35
# 1750
# 1750
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.01060755041774167
# train_discrete_score_W0_a  0.019292791399744998
# 750
# 750
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.01926011514919248
# test_discrete_score_W0_a 0.027085540462686426
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6554285714285715
# train_discrete_score_W_discrete_n 0.21728574992813277
# train_discrete_score_W_discrete_a 0.23135267606410181
# 750
# 750
# test_discrete_score_W_discrete_p 0.6893333333333334
# test_discrete_score_W_discrete_n 0.26867990591129065
# test_discrete_score_W_discrete_a 0.28450669064401674
# neuron unit number: 40
# 1750
# 1750
# train_discrete_score_W0_p 0.424
# train_discrete_score_W0_n 0.009959947080414578
# train_discrete_score_W0_a  0.015991721075210373
# 750
# 750
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.024264756986117294
# test_discrete_score_W0_a 0.027850750709654128
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.648
# train_discrete_score_W_discrete_n 0.22655567638908533
# train_discrete_score_W_discrete_a 0.21798175491737445
# 750
# 750
# test_discrete_score_W_discrete_p 0.6946666666666667
# test_discrete_score_W_discrete_n 0.2668826412636532
# test_discrete_score_W_discrete_a 0.28965941767792414
# neuron unit number: 45
# 1750
# 1750
# train_discrete_score_W0_p 0.43028571428571427
# train_discrete_score_W0_n 0.01289682967567508
# train_discrete_score_W0_a  0.018701184156421812
# 750
# 750
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.020996184713665347
# test_discrete_score_W0_a 0.02642798646397127
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6497142857142857
# train_discrete_score_W_discrete_n 0.22743835512540192
# train_discrete_score_W_discrete_a 0.2209840402412188
# 750
# 750
# test_discrete_score_W_discrete_p 0.692
# test_discrete_score_W_discrete_n 0.27466418507083606
# test_discrete_score_W_discrete_a 0.28367772057968393
# neuron unit number: 50
# 1750
# 1750
# train_discrete_score_W0_p 0.4308571428571429
# train_discrete_score_W0_n 0.012487157684391617
# train_discrete_score_W0_a  0.020962956674511493
# 750
# 750
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.018925832510561947
# test_discrete_score_W0_a 0.0284020518909198
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6502857142857142
# train_discrete_score_W_discrete_n 0.2469385492259576
# train_discrete_score_W_discrete_a 0.2218388260363716
# 750
# 750
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.2647920470459466
# test_discrete_score_W_discrete_a 0.272307719260048
# neuron unit number: 55
# 1750
# 1750
# train_discrete_score_W0_p 0.4228571428571429
# train_discrete_score_W0_n 0.010105521983218728
# train_discrete_score_W0_a  0.015705980700930815
# 750
# 750
# test_discrete_score_W0_p 0.44133333333333336
# test_discrete_score_W0_n 0.01764347131578123
# test_discrete_score_W0_a 0.020465800849060942
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.652
# train_discrete_score_W_discrete_n 0.2235529132831176
# train_discrete_score_W_discrete_a 0.22609471850009447
# 750
# 750
# test_discrete_score_W_discrete_p 0.6933333333333334
# test_discrete_score_W_discrete_n 0.26695710016949326
# test_discrete_score_W_discrete_a 0.28833161731301904
# neuron unit number: 60
# 1750
# 1750
# train_discrete_score_W0_p 0.4308571428571429
# train_discrete_score_W0_n 0.012666766416954434
# train_discrete_score_W0_a  0.018393950749303153
# 750
# 750
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.027127541920103315
# test_discrete_score_W0_a 0.03149334254564829
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.648
# train_discrete_score_W_discrete_n 0.2440757918199458
# train_discrete_score_W_discrete_a 0.2172035816835838
# 750
# 750
# test_discrete_score_W_discrete_p 0.6826666666666666
# test_discrete_score_W_discrete_n 0.27696410826780504
# test_discrete_score_W_discrete_a 0.26962561095990834
# neuron unit number: 65
# 1750
# 1750
# train_discrete_score_W0_p 0.42
# train_discrete_score_W0_n 0.008689241779826712
# train_discrete_score_W0_a  0.01538574728076333
# 750
# 750
# test_discrete_score_W0_p 0.428
# test_discrete_score_W0_n 0.011876022985895424
# test_discrete_score_W0_a 0.014190967275305118
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6577142857142857
# train_discrete_score_W_discrete_n 0.2544368139419461
# train_discrete_score_W_discrete_a 0.23208413018836105
# 750
# 750
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.24406420323151978
# test_discrete_score_W_discrete_a 0.2744923924465311
# neuron unit number: 70
# 1750
# 1750
# train_discrete_score_W0_p 0.42742857142857144
# train_discrete_score_W0_n 0.01116322248438821
# train_discrete_score_W0_a  0.01854297251759278
# 750
# 750
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.01802127986013168
# test_discrete_score_W0_a 0.024897093683867798
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6588571428571428
# train_discrete_score_W_discrete_n 0.24595233728387828
# train_discrete_score_W_discrete_a 0.23384402795870737
# 750
# 750
# test_discrete_score_W_discrete_p 0.6986666666666667
# test_discrete_score_W_discrete_n 0.30205318503066586
# test_discrete_score_W_discrete_a 0.2937551689627248
# neuron unit number: 75
# 1750
# 1750
# train_discrete_score_W0_p 0.424
# train_discrete_score_W0_n 0.010031041636614176
# train_discrete_score_W0_a  0.016468309573160297
# 750
# 750
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.019873468999476573
# test_discrete_score_W0_a 0.029155211156403755
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6422857142857142
# train_discrete_score_W_discrete_n 0.2127839343081342
# train_discrete_score_W_discrete_a 0.21064805310347076
# 750
# 750
# test_discrete_score_W_discrete_p 0.68
# test_discrete_score_W_discrete_n 0.2638209801065715
# test_discrete_score_W_discrete_a 0.2626349174575796
# neuron unit number: 80
# 1750
# 1750
# train_discrete_score_W0_p 0.44
# train_discrete_score_W0_n 0.01768122250404908
# train_discrete_score_W0_a  0.019810524004904163
# 750
# 750
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03759348405789076
# test_discrete_score_W0_a 0.04958716895414902
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6514285714285715
# train_discrete_score_W_discrete_n 0.24828419199242088
# train_discrete_score_W_discrete_a 0.22398168271135221
# 750
# 750
# test_discrete_score_W_discrete_p 0.6906666666666667
# test_discrete_score_W_discrete_n 0.25876643337646404
# test_discrete_score_W_discrete_a 0.2852635027973899
# neuron unit number: 85
# 1750
# 1750
# train_discrete_score_W0_p 0.42628571428571427
# train_discrete_score_W0_n 0.013278520438338737
# train_discrete_score_W0_a  0.018754609190650463
# 750
# 750
# test_discrete_score_W0_p 0.43333333333333335
# test_discrete_score_W0_n 0.014594998675054248
# test_discrete_score_W0_a 0.020197538227770408
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6434285714285715
# train_discrete_score_W_discrete_n 0.1880717602490878
# train_discrete_score_W_discrete_a 0.21641677390420205
# 750
# 750
# test_discrete_score_W_discrete_p 0.692
# test_discrete_score_W_discrete_n 0.24662567100043628
# test_discrete_score_W_discrete_a 0.2878547581713403
# neuron unit number: 90
# 1750
# 1750
# train_discrete_score_W0_p 0.43485714285714283
# train_discrete_score_W0_n 0.014554093285217532
# train_discrete_score_W0_a  0.020896976451552394
# 750
# 750
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.024423842103030113
# test_discrete_score_W0_a 0.03238070191752675
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6485714285714286
# train_discrete_score_W_discrete_n 0.2453277026975214
# train_discrete_score_W_discrete_a 0.21960421712633443
# 750
# 750
# test_discrete_score_W_discrete_p 0.684
# test_discrete_score_W_discrete_n 0.26725126033767777
# test_discrete_score_W_discrete_a 0.2714056528372149
# neuron unit number: 95
# 1750
# 1750
# train_discrete_score_W0_p 0.42514285714285716
# train_discrete_score_W0_n 0.010490536509860121
# train_discrete_score_W0_a  0.016826189547901913
# 750
# 750
# test_discrete_score_W0_p 0.44533333333333336
# test_discrete_score_W0_n 0.01850684307237426
# test_discrete_score_W0_a 0.022536690811917143
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6525714285714286
# train_discrete_score_W_discrete_n 0.24389317406607083
# train_discrete_score_W_discrete_a 0.22486924588068422
# 750
# 750
# test_discrete_score_W_discrete_p 0.6826666666666666
# test_discrete_score_W_discrete_n 0.24416717383480277
# test_discrete_score_W_discrete_a 0.27202670814517865
# neuron unit number: 100
# 1750
# 1750
# train_discrete_score_W0_p 0.43257142857142855
# train_discrete_score_W0_n 0.013622797908244152
# train_discrete_score_W0_a  0.021117471553261952
# 750
# 750
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.02271519968915053
# test_discrete_score_W0_a 0.027563605947610807
# 1750
# 1750
# train_discrete_score_W_discrete_p 0.6462857142857142
# train_discrete_score_W_discrete_n 0.23578187043520724
# train_discrete_score_W_discrete_a 0.21496290698724674
# 750
# 750
# test_discrete_score_W_discrete_p 0.6986666666666667
# test_discrete_score_W_discrete_n 0.2616335383614844
# test_discrete_score_W_discrete_a 0.3023301556704901
# test_discrete_score_W0_p mean 0.44226666666666664
# test_discrete_score_W_discrete_p mean 0.6801999999999999
# test_discrete_score_W0_n mean 0.018227892677848
# test_discrete_score_W_discrete_n mean 0.25103522350291996
# test_discrete_score_W0_a mean 0.023416895150813417
# test_discrete_score_W_discrete_a mean 0.2697355030282946
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.010306  0.003885  0.000869   0.008488  0.012124
# 1  train_dis_W_dis  20.0  0.219000  0.040626  0.009084   0.199987  0.238013
# 2         combined  40.0  0.114653  0.109448  0.017305   0.079650  0.149656
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2087
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -22.8691
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -7.2319
# 7                                    Hedge's g =   -7.0882
# 8                                Glass's delta =  -53.7189
# 9                                  Pearson's r =    0.9655
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.018228  0.007600  0.001699   0.014671  0.021785
# 1  test_dis_W_dis  20.0  0.251035  0.041311  0.009237   0.231701  0.270369
# 2        combined  40.0  0.134632  0.121478  0.019207   0.095781  0.173482
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2328
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -24.7866
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.8382
# 7                                  Hedge's g =   -7.6825
# 8                              Glass's delta =  -30.6319
# 9                                Pearson's r =    0.9704
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.015738  0.005493  0.001228   0.013167  0.018309
# 1  train_dis_W_dis  20.0  0.213826  0.031692  0.007087   0.198993  0.228658
# 2         combined  40.0  0.114782  0.102787  0.016252   0.081909  0.147655
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1981
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -27.5418
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.7095
# 7                                    Hedge's g =   -8.5364
# 8                                Glass's delta =  -36.0592
# 9                                  Pearson's r =    0.9759
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.023417  0.009720  0.002174   0.018868  0.027966
# 1  test_dis_W_dis  20.0  0.269736  0.040148  0.008977   0.250946  0.288525
# 2        combined  40.0  0.146576  0.128017  0.020241   0.105634  0.187518
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2463
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -26.6674
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.4330
# 7                                  Hedge's g =   -8.2654
# 8                              Glass's delta =  -25.3406
# 9                                Pearson's r =    0.9743
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.423457  0.010021  0.002241   0.418767  0.428147
# 1  train_dis_W_dis  20.0  0.643086  0.025621  0.005729   0.631095  0.655077
# 2         combined  40.0  0.533271  0.112859  0.017845   0.497177  0.569365
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2196
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -35.7023
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -11.2901
# 7                                    Hedge's g =  -11.0658
# 8                                Glass's delta =  -21.9173
# 9                                  Pearson's r =    0.9854
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.442267  0.018180  0.004065   0.433758  0.450775
# 1  test_dis_W_dis  20.0  0.680200  0.029084  0.006503   0.666588  0.693812
# 2        combined  40.0  0.561233  0.122838  0.019422   0.521948  0.600519
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2379
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -31.0237
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -9.8105
# 7                                  Hedge's g =   -9.6156
# 8                              Glass's delta =  -13.0879
# 9                                Pearson's r =    0.9808
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])

dataread.stringToIntNetflixDataSet(csv,"Subscription Type")
dataread.stringToIntNetflixDataSet(csv,"Monthly Revenue")
dataread.stringToIntNetflixDataSet(csv,"Join Date")
dataread.stringToIntNetflixDataSet(csv,"Last Payment Date")
dataread.stringToIntNetflixDataSet(csv,"Country")
dataread.stringToIntNetflixDataSet(csv,"Gender")
dataread.stringToIntNetflixDataSet(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")

#print(dataread.data_test)

#print(dataread.data_test_discrete_after_transfer)
# Out:
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# ...
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45114.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
#  column number self.data_train_discrete 4

# %%
#compare softmax
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 5
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 3
# train_discrete_score_W0_p 0.4228571428571429
# train_discrete_score_W0_n 0.009976189926258885
# train_discrete_score_W0_a  0.014376612520095889
# test_discrete_score_W0_p 0.39066666666666666
# test_discrete_score_W0_n 0.005360508708732223
# test_discrete_score_W0 0.0022995181033320664
# train_discrete_score_W_discrete_p 0.4165714285714286
# train_discrete_score_W_discrete_n 0.005476357489924799
# train_discrete_score_W_discrete_a 0.007748422014448513
# test_discrete_score_W_discrete_p 0.38666666666666666
# test_discrete_score_W_discrete_n 0.0041180178599945685
# test_discrete_score_W_discrete_a 0.002361703220080092
# Not good nmi result for discrete features !!!!!
# neuron unit number: 8
# train_discrete_score_W0_p 0.436
# train_discrete_score_W0_n 0.018181854379558098
# train_discrete_score_W0_a  0.026740497246922987
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.436
# train_discrete_score_W_discrete_n 0.017219857691447585
# train_discrete_score_W_discrete_a 0.025132382489742398
# test_discrete_score_W_discrete_p 0.41733333333333333
# test_discrete_score_W_discrete_n 0.01615428272581853
# test_discrete_score_W_discrete_a 0.013393099904553842
# Not good ari result for discrete features  !!!!!
# neuron unit number: 13
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.42133333333333334
# test_discrete_score_W_discrete_n 0.017354842057716327
# test_discrete_score_W_discrete_a 0.014760764852063858
# neuron unit number: 18
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.014376582710587367
# test_discrete_score_W_discrete_a 0.013513232896536904
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 23
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 28
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 33
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.42133333333333334
# test_discrete_score_W_discrete_n 0.017354842057716327
# test_discrete_score_W_discrete_a 0.014760764852063858
# neuron unit number: 38
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.42133333333333334
# test_discrete_score_W0_n 0.016017802419096134
# test_discrete_score_W0 0.01414656525197086
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 43
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.42133333333333334
# test_discrete_score_W0_n 0.017354842057716327
# test_discrete_score_W0 0.014760764852063858
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.014376582710587367
# test_discrete_score_W_discrete_a 0.013513232896536904
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 48
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.42133333333333334
# test_discrete_score_W0_n 0.016017802419096134
# test_discrete_score_W0 0.01414656525197086
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 53
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 58
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.436
# train_discrete_score_W_discrete_n 0.018181854379558098
# train_discrete_score_W_discrete_a 0.026740497246922987
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 63
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 68
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.01809693691682253
# train_discrete_score_W0_a  0.02630143061007466
# test_discrete_score_W0_p 0.41733333333333333
# test_discrete_score_W0_n 0.01615428272581853
# test_discrete_score_W0 0.013393099904553842
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# Not good nmi result for discrete features !!!!!
# neuron unit number: 73
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.42133333333333334
# test_discrete_score_W_discrete_n 0.017354842057716327
# test_discrete_score_W_discrete_a 0.014760764852063858
# neuron unit number: 78
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.014376582710587367
# test_discrete_score_W0 0.013513232896536904
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.42133333333333334
# test_discrete_score_W_discrete_n 0.017354842057716327
# test_discrete_score_W_discrete_a 0.014760764852063858
# neuron unit number: 83
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.42133333333333334
# test_discrete_score_W0_n 0.017354842057716327
# test_discrete_score_W0 0.014760764852063858
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 88
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 93
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.4186666666666667
# test_discrete_score_W_discrete_n 0.015550368057740693
# test_discrete_score_W_discrete_a 0.014044062714582618
# neuron unit number: 98
# train_discrete_score_W0_p 0.43657142857142855
# train_discrete_score_W0_n 0.019112811908682442
# train_discrete_score_W0_a  0.0280281819935659
# test_discrete_score_W0_p 0.4186666666666667
# test_discrete_score_W0_n 0.015550368057740693
# test_discrete_score_W0 0.014044062714582618
# train_discrete_score_W_discrete_p 0.43657142857142855
# train_discrete_score_W_discrete_n 0.019112811908682442
# train_discrete_score_W_discrete_a 0.0280281819935659
# test_discrete_score_W_discrete_p 0.42133333333333334
# test_discrete_score_W_discrete_n 0.017354842057716327
# test_discrete_score_W_discrete_a 0.014760764852063858
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.018559  0.002042  0.000457   0.017603  0.019514
# 1  train_dis_W_dis  20.0  0.018290  0.003051  0.000682   0.016862  0.019718
# 2         combined  40.0  0.018424  0.002566  0.000406   0.017604  0.019245
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0003
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.3275
# 3                        Two side test p value =    0.7451
# 4                       Difference < 0 p value =    0.6275
# 5                       Difference > 0 p value =    0.3725
# 6                                    Cohen's d =    0.1036
# 7                                    Hedge's g =    0.1015
# 8                                Glass's delta =    0.1317
# 9                                  Pearson's r =    0.0531
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.015240  0.002413  0.000539   0.014110  0.016369
# 1  test_dis_W_dis  20.0  0.015343  0.002803  0.000627   0.014031  0.016654
# 2        combined  40.0  0.015291  0.002582  0.000408   0.014465  0.016117
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0001
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.1247
# 3                      Two side test p value =    0.9014
# 4                     Difference < 0 p value =    0.4507
# 5                     Difference > 0 p value =    0.5493
# 6                                  Cohen's d =   -0.0394
# 7                                  Hedge's g =   -0.0386
# 8                              Glass's delta =   -0.0427
# 9                                Pearson's r =    0.0202
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.027195  0.003053  0.000683   0.025766  0.028624
# 1  train_dis_W_dis  20.0  0.026805  0.004539  0.001015   0.024681  0.028929
# 2         combined  40.0  0.027000  0.003823  0.000604   0.025777  0.028223
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0004
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.3187
# 3                        Two side test p value =    0.7517
# 4                       Difference < 0 p value =    0.6242
# 5                       Difference > 0 p value =    0.3758
# 6                                    Cohen's d =    0.1008
# 7                                    Hedge's g =    0.0988
# 8                                Glass's delta =    0.1277
# 9                                  Pearson's r =    0.0516
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.013480  0.002649  0.000592   0.012240  0.014719
# 1  test_dis_W_dis  20.0  0.013553  0.002668  0.000597   0.012305  0.014802
# 2        combined  40.0  0.013517  0.002624  0.000415   0.012677  0.014356
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0001
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.0878
# 3                      Two side test p value =    0.9305
# 4                     Difference < 0 p value =    0.4652
# 5                     Difference > 0 p value =    0.5348
# 6                                  Cohen's d =   -0.0278
# 7                                  Hedge's g =   -0.0272
# 8                              Glass's delta =   -0.0279
# 9                                Pearson's r =    0.0142
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.435857  0.003063  0.000685   0.434424  0.437290
# 1  train_dis_W_dis  20.0  0.435514  0.004462  0.000998   0.433426  0.437603
# 2         combined  40.0  0.435686  0.003781  0.000598   0.434476  0.436895
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0003
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.2833
# 3                        Two side test p value =    0.7785
# 4                       Difference < 0 p value =    0.6108
# 5                       Difference > 0 p value =    0.3892
# 6                                    Cohen's d =    0.0896
# 7                                    Hedge's g =    0.0878
# 8                                Glass's delta =    0.1120
# 9                                  Pearson's r =    0.0459
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.417733  0.006476  0.001448   0.414703  0.420764
# 1  test_dis_W_dis  20.0  0.417667  0.007403  0.001655   0.414202  0.421131
# 2        combined  40.0  0.417700  0.006865  0.001086   0.415504  0.419896
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0001
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    0.0303
# 3                      Two side test p value =    0.9760
# 4                     Difference < 0 p value =    0.5120
# 5                     Difference > 0 p value =    0.4880
# 6                                  Cohen's d =    0.0096
# 7                                  Hedge's g =    0.0094
# 8                              Glass's delta =    0.0103
# 9                                Pearson's r =    0.0049
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
#comparision two MF
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 3
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 3
#  all feature number 7
# all_train_score_W0_p 0.3982857142857143
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.4026666666666667
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 4
# all_train_score_W_combine_p 0.40114285714285713
# all_train_score_W_combine_n 0.0016975947061351828
# all_train_score_W_combine_a 0.0021761462921737855
# test_score_W_combine_p0.432
# test_score_W_combine_n 0.014115501120057805
# test_score_W_combine_a 0.017106353259492182
# neuron unit number: 8
#  all feature number 7
# all_train_score_W0_p 0.4017142857142857
# all_train_score_W0_n 0.0021248596452014476
# all_train_score_W0_a 0.0014734029895103649
# test_score_W0_p0.4026666666666667
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 4
# all_train_score_W_combine_p 0.42228571428571426
# all_train_score_W_combine_n 0.00926446161525519
# all_train_score_W_combine_a 0.01291100595513963
# test_score_W_combine_p0.4613333333333333
# test_score_W_combine_n 0.026742360451006444
# test_score_W_combine_a 0.038584160382839745
# neuron unit number: 13
#  all feature number 7
# all_train_score_W0_p 0.3994285714285714
# all_train_score_W0_n 0.0005353406867533676
# all_train_score_W0_a 0.0009279170271127429
# test_score_W0_p0.404
# test_score_W0_n 0.0034864829588099723
# test_score_W0_a  0.0013299776387638103
#  discrete feature number 4
# all_train_score_W_combine_p 0.41942857142857143
# all_train_score_W_combine_n 0.00979442799112609
# all_train_score_W_combine_a 0.011046759681260346
# test_score_W_combine_p0.472
# test_score_W_combine_n 0.03538998629462232
# test_score_W_combine_a 0.05061976116890213
# neuron unit number: 18
#  all feature number 7
# all_train_score_W0_p 0.4
# all_train_score_W0_n 0.001393624838249598
# all_train_score_W0_a 0.0025531091016421
# test_score_W0_p0.4226666666666667
# test_score_W0_n 0.008860951452954756
# test_score_W0_a  0.012442779310242858
#  discrete feature number 4
# all_train_score_W_combine_p 0.412
# all_train_score_W_combine_n 0.006373480468234369
# all_train_score_W_combine_a 0.009235921771426877
# test_score_W_combine_p0.4613333333333333
# test_score_W_combine_n 0.025500615874443775
# test_score_W_combine_a 0.033445314721312014
# neuron unit number: 23
#  all feature number 7
# all_train_score_W0_p 0.39885714285714285
# all_train_score_W0_n 0.0005449478693732313
# all_train_score_W0_a 0.0012704490266009193
# test_score_W0_p0.41333333333333333
# test_score_W0_n 0.007480520284062357
# test_score_W0_a  0.003809532995698025
#  discrete feature number 4
# all_train_score_W_combine_p 0.4217142857142857
# all_train_score_W_combine_n 0.009298735122963489
# all_train_score_W_combine_a 0.014166602540993738
# test_score_W_combine_p0.47733333333333333
# test_score_W_combine_n 0.03390258671444906
# test_score_W_combine_a 0.047962761874143334
# neuron unit number: 28
#  all feature number 7
# all_train_score_W0_p 0.412
# all_train_score_W0_n 0.0068392305154503985
# all_train_score_W0_a 0.006117243936187678
# test_score_W0_p0.436
# test_score_W0_n 0.014610811053414757
# test_score_W0_a  0.02188479500027653
#  discrete feature number 4
# all_train_score_W_combine_p 0.4154285714285714
# all_train_score_W_combine_n 0.007205768509253964
# all_train_score_W_combine_a 0.010773842248593492
# test_score_W_combine_p0.45066666666666666
# test_score_W_combine_n 0.021733919682228483
# test_score_W_combine_a 0.028121323993954412
# neuron unit number: 33
#  all feature number 7
# all_train_score_W0_p 0.4057142857142857
# all_train_score_W0_n 0.003706233204074796
# all_train_score_W0_a 0.0032845171028255673
# test_score_W0_p0.428
# test_score_W0_n 0.010991616442467819
# test_score_W0_a  0.017916400773883227
#  discrete feature number 4
# all_train_score_W_combine_p 0.41942857142857143
# all_train_score_W_combine_n 0.008005138028398244
# all_train_score_W_combine_a 0.012043316107850867
# test_score_W_combine_p0.4666666666666667
# test_score_W_combine_n 0.03039551471291296
# test_score_W_combine_a 0.04033490449566054
# neuron unit number: 38
#  all feature number 7
# all_train_score_W0_p 0.40685714285714286
# all_train_score_W0_n 0.004421107564228686
# all_train_score_W0_a 0.005091477421046184
# test_score_W0_p0.42533333333333334
# test_score_W0_n 0.011587562905493655
# test_score_W0_a  0.014469701332108726
#  discrete feature number 4
# all_train_score_W_combine_p 0.4257142857142857
# all_train_score_W_combine_n 0.010786713928017099
# all_train_score_W_combine_a 0.014004380589881382
# test_score_W_combine_p0.464
# test_score_W_combine_n 0.02827537305972015
# test_score_W_combine_a 0.03835477719809674
# neuron unit number: 43
#  all feature number 7
# all_train_score_W0_p 0.4022857142857143
# all_train_score_W0_n 0.002423213860346884
# all_train_score_W0_a 0.0017797988600309726
# test_score_W0_p0.4053333333333333
# test_score_W0_n 0.0021371100171536377
# test_score_W0_a  0.003027424232945661
#  discrete feature number 4
# all_train_score_W_combine_p 0.41828571428571426
# all_train_score_W_combine_n 0.00770976176182574
# all_train_score_W_combine_a 0.011355039135095836
# test_score_W_combine_p0.46266666666666667
# test_score_W_combine_n 0.026701460581968355
# test_score_W_combine_a 0.033836263385295634
# neuron unit number: 48
#  all feature number 7
# all_train_score_W0_p 0.4188571428571429
# all_train_score_W0_n 0.008093304815255303
# all_train_score_W0_a 0.011336664460264267
# test_score_W0_p0.4493333333333333
# test_score_W0_n 0.02081960792170595
# test_score_W0_a  0.025104973290625415
#  discrete feature number 4
# all_train_score_W_combine_p 0.41714285714285715
# all_train_score_W_combine_n 0.008115935357267737
# all_train_score_W_combine_a 0.009009630456383018
# test_score_W_combine_p0.452
# test_score_W_combine_n 0.0216383628369564
# test_score_W_combine_a 0.033330962364334096
# neuron unit number: 53
#  all feature number 7
# all_train_score_W0_p 0.39885714285714285
# all_train_score_W0_n 0.00034698605282487704
# all_train_score_W0_a 0.0006550815030429689
# test_score_W0_p0.416
# test_score_W0_n 0.009698021365120622
# test_score_W0_a  0.004980426704105676
#  discrete feature number 4
# all_train_score_W_combine_p 0.41714285714285715
# all_train_score_W_combine_n 0.007353835146450414
# all_train_score_W_combine_a 0.01255882242960138
# test_score_W_combine_p0.472
# test_score_W_combine_n 0.031880297277787836
# test_score_W_combine_a 0.03999559201224642
# neuron unit number: 58
#  all feature number 7
# all_train_score_W0_p 0.4045714285714286
# all_train_score_W0_n 0.0026342789593116465
# all_train_score_W0_a 0.005001114157218215
# test_score_W0_p0.42933333333333334
# test_score_W0_n 0.010944449272147275
# test_score_W0_a  0.017026975742102265
#  discrete feature number 4
# all_train_score_W_combine_p 0.42457142857142854
# all_train_score_W_combine_n 0.009983404513729508
# all_train_score_W_combine_a 0.016135383508211334
# test_score_W_combine_p0.45466666666666666
# test_score_W_combine_n 0.022533984872615622
# test_score_W_combine_a 0.03135542847788518
# neuron unit number: 63
#  all feature number 7
# all_train_score_W0_p 0.4177142857142857
# all_train_score_W0_n 0.008913696922351937
# all_train_score_W0_a 0.010087247580811186
# test_score_W0_p0.464
# test_score_W0_n 0.027960002702869486
# test_score_W0_a  0.035901371353559024
#  discrete feature number 4
# all_train_score_W_combine_p 0.4188571428571429
# all_train_score_W_combine_n 0.007772542990429647
# all_train_score_W_combine_a 0.01257920300367101
# test_score_W_combine_p0.468
# test_score_W_combine_n 0.030586976472267
# test_score_W_combine_a 0.04550698081937184
# neuron unit number: 68
#  all feature number 7
# all_train_score_W0_p 0.4114285714285714
# all_train_score_W0_n 0.0051907989199094515
# all_train_score_W0_a 0.008382550210581036
# test_score_W0_p0.452
# test_score_W0_n 0.022305759352645768
# test_score_W0_a  0.03127706953228171
#  discrete feature number 4
# all_train_score_W_combine_p 0.42914285714285716
# all_train_score_W_combine_n 0.014409283244787326
# all_train_score_W_combine_a 0.01442951459150237
# test_score_W_combine_p0.464
# test_score_W_combine_n 0.028137905463452347
# test_score_W_combine_a 0.03797391404499271
# neuron unit number: 73
#  all feature number 7
# all_train_score_W0_p 0.4
# all_train_score_W0_n 0.0038899099852501558
# all_train_score_W0_a 0.0007264525055624263
# test_score_W0_p0.404
# test_score_W0_n 0.0019386670926260364
# test_score_W0_a  0.002377065821695603
#  discrete feature number 4
# all_train_score_W_combine_p 0.41942857142857143
# all_train_score_W_combine_n 0.009064144498184889
# all_train_score_W_combine_a 0.011650446904110613
# test_score_W_combine_p0.4666666666666667
# test_score_W_combine_n 0.02914692101789147
# test_score_W_combine_a 0.04262179128312565
# neuron unit number: 78
#  all feature number 7
# all_train_score_W0_p 0.4177142857142857
# all_train_score_W0_n 0.007952742326858773
# all_train_score_W0_a 0.011001124821538996
# test_score_W0_p0.45866666666666667
# test_score_W0_n 0.02641975493343427
# test_score_W0_a  0.04187116904858797
#  discrete feature number 4
# all_train_score_W_combine_p 0.4177142857142857
# all_train_score_W_combine_n 0.008582095402737073
# all_train_score_W_combine_a 0.009145167296274044
# test_score_W_combine_p0.4693333333333333
# test_score_W_combine_n 0.031950102011791603
# test_score_W_combine_a 0.03921584541315611
# Not good ari result for discrete features  !!!!!
# neuron unit number: 83
#  all feature number 7
# all_train_score_W0_p 0.3982857142857143
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.4053333333333333
# test_score_W0_n 0.0026190624705513185
# test_score_W0_a  0.0017532919788074985
#  discrete feature number 4
# all_train_score_W_combine_p 0.42
# all_train_score_W_combine_n 0.008478264809108028
# all_train_score_W_combine_a 0.012216316669306612
# test_score_W_combine_p0.452
# test_score_W_combine_n 0.023539490883800064
# test_score_W_combine_a 0.024954313990766967
# neuron unit number: 88
#  all feature number 7
# all_train_score_W0_p 0.41828571428571426
# all_train_score_W0_n 0.008772362286530125
# all_train_score_W0_a 0.01273079541883346
# test_score_W0_p0.4613333333333333
# test_score_W0_n 0.02527735418639758
# test_score_W0_a  0.03703328928078742
#  discrete feature number 4
# all_train_score_W_combine_p 0.41485714285714287
# all_train_score_W_combine_n 0.007041300530457361
# all_train_score_W_combine_a 0.007509288518667354
# test_score_W_combine_p0.4653333333333333
# test_score_W_combine_n 0.028493296523150025
# test_score_W_combine_a 0.0359098024245369
# Not good ari result for discrete features  !!!!!
# neuron unit number: 93
#  all feature number 7
# all_train_score_W0_p 0.40114285714285713
# all_train_score_W0_n 0.001811072589994839
# all_train_score_W0_a 0.0022655544128222516
# test_score_W0_p0.43333333333333335
# test_score_W0_n 0.012895039955254506
# test_score_W0_a  0.02252479452495086
#  discrete feature number 4
# all_train_score_W_combine_p 0.4177142857142857
# all_train_score_W_combine_n 0.008968372294735783
# all_train_score_W_combine_a 0.009883291538932488
# test_score_W_combine_p0.46
# test_score_W_combine_n 0.02525993219760718
# test_score_W_combine_a 0.03740241647695068
# neuron unit number: 98
#  all feature number 7
# all_train_score_W0_p 0.41942857142857143
# all_train_score_W0_n 0.00943781949652417
# all_train_score_W0_a 0.009786358736833997
# test_score_W0_p0.45466666666666666
# test_score_W0_n 0.023588475461566057
# test_score_W0_a  0.030718855035537694
#  discrete feature number 4
# all_train_score_W_combine_p 0.4142857142857143
# all_train_score_W_combine_n 0.008556375078092784
# all_train_score_W_combine_a 0.007319698361437547
# test_score_W_combine_p0.46266666666666667
# test_score_W_combine_n 0.027021724249217952
# test_score_W_combine_a 0.03624650401148958
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.003952  0.003303  0.000739   0.002406  0.005498
# 1  train_W_combine  20.0  0.008423  0.002330  0.000521   0.007333  0.009513
# 2         combined  40.0  0.006187  0.003618  0.000572   0.005030  0.007344
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0045
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -4.9471
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.5644
# 7                                Hedge's g =   -1.5333
# 8                            Glass's delta =   -1.3537
# 9                              Pearson's r =    0.6259
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.012181  0.009316  0.002083   0.007821  0.016541
# 1  test_W_combine  20.0  0.027147  0.004920  0.001100   0.024845  0.029450
# 2        combined  40.0  0.019664  0.010560  0.001670   0.016287  0.023041
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0150
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.3529
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.0089
# 7                              Hedge's g =   -1.9690
# 8                          Glass's delta =   -1.6065
# 9                            Pearson's r =    0.7177
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.004724  0.004309  0.000963   0.002707  0.006740
# 1  train_W_combine  20.0  0.011007  0.003114  0.000696   0.009550  0.012465
# 2         combined  40.0  0.007866  0.004888  0.000773   0.006302  0.009429
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0063
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -5.2860
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.6716
# 7                                Hedge's g =   -1.6384
# 8                            Glass's delta =   -1.4584
# 9                              Pearson's r =    0.6509
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.016272  0.013936  0.003116   0.009750  0.022795
# 1  test_W_combine  20.0  0.036644  0.007702  0.001722   0.033039  0.040248
# 2        combined  40.0  0.026458  0.015163  0.002398   0.021609  0.031308
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0204
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -5.7216
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.8093
# 7                              Hedge's g =   -1.7734
# 8                          Glass's delta =   -1.4617
# 9                            Pearson's r =    0.6803
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.406571  0.008029  0.001795   0.402814  0.410329
# 1  train_W_combine  20.0  0.418314  0.005713  0.001277   0.415641  0.420988
# 2         combined  40.0  0.412443  0.009092  0.001438   0.409535  0.415351
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0117
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -5.3294
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.6853
# 7                                Hedge's g =   -1.6518
# 8                            Glass's delta =   -1.4626
# 9                              Pearson's r =    0.6540
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.428400  0.021811  0.004877   0.418192  0.438608
# 1  test_W_combine  20.0  0.461733  0.009932  0.002221   0.457085  0.466382
# 2        combined  40.0  0.445067  0.023764  0.003757   0.437467  0.452667
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0333
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.2202
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.9670
# 7                              Hedge's g =   -1.9279
# 8                          Glass's delta =   -1.5283
# 9                            Pearson's r =    0.7103
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
#subjective
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 3
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 3
#  all feature number 7
# all_train_score_W0_p 0.4
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.39866666666666667
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 4
# all_train_score_W_combine_p 0.4097142857142857
# all_train_score_W_combine_n 0.005109505682723463
# all_train_score_W_combine_a 0.00902285335854087
# test_score_W_combine_p0.42933333333333334
# test_score_W_combine_n 0.011856985150407739
# test_score_W_combine_a 0.019120412100553014
# neuron unit number: 8
#  all feature number 7
# all_train_score_W0_p 0.4
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.4
# test_score_W0_n 0.0019526847318176563
# test_score_W0_a  -0.00028369711921733264
#  discrete feature number 4
# all_train_score_W_combine_p 0.41485714285714287
# all_train_score_W_combine_n 0.006435041891784481
# all_train_score_W_combine_a 0.012451814128841023
# test_score_W_combine_p0.43733333333333335
# test_score_W_combine_n 0.015607579168404096
# test_score_W_combine_a 0.020505289351929225
# neuron unit number: 13
#  all feature number 7
# all_train_score_W0_p 0.404
# all_train_score_W0_n 0.0019391188669144574
# all_train_score_W0_a 0.0021473224406993938
# test_score_W0_p0.4013333333333333
# test_score_W0_n 0.0013601086131352247
# test_score_W0_a  0.001278774740988163
#  discrete feature number 4
# all_train_score_W_combine_p 0.4228571428571429
# all_train_score_W_combine_n 0.00886278814811574
# all_train_score_W_combine_a 0.015351261485151774
# test_score_W_combine_p0.44533333333333336
# test_score_W_combine_n 0.018519906741576993
# test_score_W_combine_a 0.02532568874902187
# neuron unit number: 18
#  all feature number 7
# all_train_score_W0_p 0.40285714285714286
# all_train_score_W0_n 0.001781258733682309
# all_train_score_W0_a 0.0017284737488169604
# test_score_W0_p0.42533333333333334
# test_score_W0_n 0.011918034828801927
# test_score_W0_a  0.012451750179312342
#  discrete feature number 4
# all_train_score_W_combine_p 0.42
# all_train_score_W_combine_n 0.008090611237940856
# all_train_score_W_combine_a 0.01514310707458115
# test_score_W_combine_p0.44533333333333336
# test_score_W_combine_n 0.018085461159372065
# test_score_W_combine_a 0.02394082771061075
# neuron unit number: 23
#  all feature number 7
# all_train_score_W0_p 0.4022857142857143
# all_train_score_W0_n 0.0036303730045289086
# all_train_score_W0_a 0.0006989568612316825
# test_score_W0_p0.4066666666666667
# test_score_W0_n 0.0030101165955965323
# test_score_W0_a  0.004004978605149048
#  discrete feature number 4
# all_train_score_W_combine_p 0.42457142857142854
# all_train_score_W_combine_n 0.009854287608575246
# all_train_score_W_combine_a 0.017778531305001063
# test_score_W_combine_p0.464
# test_score_W_combine_n 0.028666190085149548
# test_score_W_combine_a 0.03981901591782977
# neuron unit number: 28
#  all feature number 7
# all_train_score_W0_p 0.41085714285714287
# all_train_score_W0_n 0.006332480423688201
# all_train_score_W0_a 0.005982031144930004
# test_score_W0_p0.428
# test_score_W0_n 0.011024638246861652
# test_score_W0_a  0.017587643400884798
#  discrete feature number 4
# all_train_score_W_combine_p 0.436
# all_train_score_W_combine_n 0.015822598958256332
# all_train_score_W_combine_a 0.020036297406949777
# test_score_W_combine_p0.484
# test_score_W_combine_n 0.03942549795779869
# test_score_W_combine_a 0.049516855888480434
# neuron unit number: 33
#  all feature number 7
# all_train_score_W0_p 0.408
# all_train_score_W0_n 0.004218823208081874
# all_train_score_W0_a 0.008129986141353993
# test_score_W0_p0.4266666666666667
# test_score_W0_n 0.010311755023792358
# test_score_W0_a  0.014878389518579425
#  discrete feature number 4
# all_train_score_W_combine_p 0.42457142857142854
# all_train_score_W_combine_n 0.01024244972870446
# all_train_score_W_combine_a 0.017600624315312757
# test_score_W_combine_p0.452
# test_score_W_combine_n 0.023034240313835413
# test_score_W_combine_a 0.026805084973931727
# neuron unit number: 38
#  all feature number 7
# all_train_score_W0_p 0.4062857142857143
# all_train_score_W0_n 0.0034727730549738694
# all_train_score_W0_a 0.005268002868570583
# test_score_W0_p0.4186666666666667
# test_score_W0_n 0.008092212991638639
# test_score_W0_a  0.00995208285818649
#  discrete feature number 4
# all_train_score_W_combine_p 0.43257142857142855
# all_train_score_W_combine_n 0.013507891831258088
# all_train_score_W_combine_a 0.01961900790866603
# test_score_W_combine_p0.468
# test_score_W_combine_n 0.029019270561939318
# test_score_W_combine_a 0.03890346673489597
# neuron unit number: 43
#  all feature number 7
# all_train_score_W0_p 0.4022857142857143
# all_train_score_W0_n 0.001222436503432451
# all_train_score_W0_a 0.0016346798078883931
# test_score_W0_p0.404
# test_score_W0_n 0.004697500778184632
# test_score_W0_a  0.006716346765620837
#  discrete feature number 4
# all_train_score_W_combine_p 0.416
# all_train_score_W_combine_n 0.006892259183750646
# all_train_score_W_combine_a 0.010525834968572432
# test_score_W_combine_p0.4666666666666667
# test_score_W_combine_n 0.028739696775144607
# test_score_W_combine_a 0.03666497095908848
# neuron unit number: 48
#  all feature number 7
# all_train_score_W0_p 0.41314285714285715
# all_train_score_W0_n 0.006511122679574959
# all_train_score_W0_a 0.006838442825485957
# test_score_W0_p0.452
# test_score_W0_n 0.0220342452579316
# test_score_W0_a  0.0268803451762589
#  discrete feature number 4
# all_train_score_W_combine_p 0.4228571428571429
# all_train_score_W_combine_n 0.00920797746982163
# all_train_score_W_combine_a 0.015681628892714898
# test_score_W_combine_p0.45066666666666666
# test_score_W_combine_n 0.02011582720262684
# test_score_W_combine_a 0.02816992301188055
# Not good nmi result for discrete features !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 53
#  all feature number 7
# all_train_score_W0_p 0.4022857142857143
# all_train_score_W0_n 0.0012272237939654203
# all_train_score_W0_a 0.0010231883486539293
# test_score_W0_p0.404
# test_score_W0_n 0.004318804703096132
# test_score_W0_a  0.0014015139099645317
#  discrete feature number 4
# all_train_score_W_combine_p 0.4268571428571429
# all_train_score_W_combine_n 0.010419770512929272
# all_train_score_W_combine_a 0.016177162660876824
# test_score_W_combine_p0.4613333333333333
# test_score_W_combine_n 0.027424703803856004
# test_score_W_combine_a 0.034228872576196924
# neuron unit number: 58
#  all feature number 7
# all_train_score_W0_p 0.4154285714285714
# all_train_score_W0_n 0.006329345610710627
# all_train_score_W0_a 0.011139004510516947
# test_score_W0_p0.43466666666666665
# test_score_W0_n 0.013613962321000409
# test_score_W0_a  0.018259445217953644
#  discrete feature number 4
# all_train_score_W_combine_p 0.4297142857142857
# all_train_score_W_combine_n 0.012091557038454777
# all_train_score_W_combine_a 0.019624196714927628
# test_score_W_combine_p0.4613333333333333
# test_score_W_combine_n 0.025010990063581786
# test_score_W_combine_a 0.03643189782941846
# neuron unit number: 63
#  all feature number 7
# all_train_score_W0_p 0.41828571428571426
# all_train_score_W0_n 0.00804449937061839
# all_train_score_W0_a 0.01011407643276228
# test_score_W0_p0.4573333333333333
# test_score_W0_n 0.023472720955514927
# test_score_W0_a  0.03113835039971202
#  discrete feature number 4
# all_train_score_W_combine_p 0.43314285714285716
# all_train_score_W_combine_n 0.013898624849169955
# all_train_score_W_combine_a 0.018637917346274603
# test_score_W_combine_p0.47733333333333333
# test_score_W_combine_n 0.034640845627165275
# test_score_W_combine_a 0.04841082353267842
# neuron unit number: 68
#  all feature number 7
# all_train_score_W0_p 0.4114285714285714
# all_train_score_W0_n 0.00516977763431991
# all_train_score_W0_a 0.006395877515247326
# test_score_W0_p0.43466666666666665
# test_score_W0_n 0.013846910789420745
# test_score_W0_a  0.016463542418224997
#  discrete feature number 4
# all_train_score_W_combine_p 0.4308571428571429
# all_train_score_W_combine_n 0.01258562794310383
# all_train_score_W_combine_a 0.020822636597041037
# test_score_W_combine_p0.476
# test_score_W_combine_n 0.03438835135113848
# test_score_W_combine_a 0.04172379910550592
# neuron unit number: 73
#  all feature number 7
# all_train_score_W0_p 0.4017142857142857
# all_train_score_W0_n 0.0009903267616799053
# all_train_score_W0_a 0.0015885386477477949
# test_score_W0_p0.4026666666666667
# test_score_W0_n 0.002475702834985137
# test_score_W0_a  0.0042408362144212
#  discrete feature number 4
# all_train_score_W_combine_p 0.41828571428571426
# all_train_score_W_combine_n 0.007744240557698525
# all_train_score_W_combine_a 0.011496841662486804
# test_score_W_combine_p0.468
# test_score_W_combine_n 0.030756953044837162
# test_score_W_combine_a 0.03771889389716351
# neuron unit number: 78
#  all feature number 7
# all_train_score_W0_p 0.42914285714285716
# all_train_score_W0_n 0.012865582776065724
# all_train_score_W0_a 0.018228366354815884
# test_score_W0_p0.45466666666666666
# test_score_W0_n 0.023176076216860807
# test_score_W0_a  0.03143825531625623
#  discrete feature number 4
# all_train_score_W_combine_p 0.42228571428571426
# all_train_score_W_combine_n 0.009512148502952062
# all_train_score_W_combine_a 0.015396463862660656
# test_score_W_combine_p0.43866666666666665
# test_score_W_combine_n 0.014878905625069992
# test_score_W_combine_a 0.02120707076570299
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 83
#  all feature number 7
# all_train_score_W0_p 0.4022857142857143
# all_train_score_W0_n 0.0013622914649592732
# all_train_score_W0_a 0.001578735065460207
# test_score_W0_p0.404
# test_score_W0_n 0.004415608140650713
# test_score_W0_a  0.007849831731754381
#  discrete feature number 4
# all_train_score_W_combine_p 0.4377142857142857
# all_train_score_W_combine_n 0.01556557532300469
# all_train_score_W_combine_a 0.02306245412463532
# test_score_W_combine_p0.4653333333333333
# test_score_W_combine_n 0.028273370435995704
# test_score_W_combine_a 0.037158531372159145
# neuron unit number: 88
#  all feature number 7
# all_train_score_W0_p 0.42914285714285716
# all_train_score_W0_n 0.011932143157839626
# all_train_score_W0_a 0.01812759812008908
# test_score_W0_p0.4533333333333333
# test_score_W0_n 0.02241581334184941
# test_score_W0_a  0.03263729588022306
#  discrete feature number 4
# all_train_score_W_combine_p 0.4228571428571429
# all_train_score_W_combine_n 0.009819881862911103
# all_train_score_W_combine_a 0.013856520117537656
# test_score_W_combine_p0.4573333333333333
# test_score_W_combine_n 0.026655362377858028
# test_score_W_combine_a 0.03116428120951608
# Not good ari result for discrete features  !!!!!
# neuron unit number: 93
#  all feature number 7
# all_train_score_W0_p 0.41828571428571426
# all_train_score_W0_n 0.008015071665586869
# all_train_score_W0_a 0.013256955873579026
# test_score_W0_p0.4146666666666667
# test_score_W0_n 0.008363184455999284
# test_score_W0_a  0.015883027438799442
#  discrete feature number 4
# all_train_score_W_combine_p 0.4257142857142857
# all_train_score_W_combine_n 0.01043443658422787
# all_train_score_W_combine_a 0.017312505245232715
# test_score_W_combine_p0.4693333333333333
# test_score_W_combine_n 0.030756100827390883
# test_score_W_combine_a 0.03750277587972916
# neuron unit number: 98
#  all feature number 7
# all_train_score_W0_p 0.4268571428571429
# all_train_score_W0_n 0.012358914059288642
# all_train_score_W0_a 0.014946080998655251
# test_score_W0_p0.452
# test_score_W0_n 0.022891967892325015
# test_score_W0_a  0.028873042079253796
#  discrete feature number 4
# all_train_score_W_combine_p 0.43657142857142855
# all_train_score_W_combine_n 0.01477057789225217
# all_train_score_W_combine_a 0.021996228042796887
# test_score_W_combine_p0.45866666666666667
# test_score_W_combine_n 0.02554060164128756
# test_score_W_combine_a 0.0308675204299515
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.004870  0.004106  0.000918   0.002949  0.006792
# 1  train_W_combine  20.0  0.010543  0.003060  0.000684   0.009111  0.011976
# 2         combined  40.0  0.007707  0.004586  0.000725   0.006240  0.009173
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0057
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -4.9544
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.5667
# 7                                Hedge's g =   -1.5356
# 8                            Glass's delta =   -1.3817
# 9                              Pearson's r =    0.6265
#          Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.01067  0.008230  0.001840   0.006818  0.014521
# 1  test_W_combine  20.0  0.02557  0.007230  0.001617   0.022186  0.028953
# 2        combined  40.0  0.01812  0.010742  0.001698   0.014684  0.021555
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0149
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.0832
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.9237
# 7                              Hedge's g =   -1.8854
# 8                          Glass's delta =   -1.8106
# 9                            Pearson's r =    0.7024
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.006441  0.006029  0.001348   0.003620  0.009263
# 1  train_W_combine  20.0  0.016580  0.003819  0.000854   0.014793  0.018367
# 2         combined  40.0  0.011511  0.007153  0.001131   0.009223  0.013798
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0101
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -6.3529
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.0090
# 7                                Hedge's g =   -1.9691
# 8                            Glass's delta =   -1.6815
# 9                              Pearson's r =    0.7177
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.014083  0.011236  0.002513   0.008824  0.019341
# 1  test_W_combine  20.0  0.033259  0.008740  0.001954   0.029169  0.037350
# 2        combined  40.0  0.023671  0.013893  0.002197   0.019228  0.028114
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0192
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.0245
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.9051
# 7                              Hedge's g =   -1.8673
# 8                          Glass's delta =   -1.7066
# 9                            Pearson's r =    0.6989
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.410229  0.009752  0.002181   0.405664  0.414793
# 1  train_W_combine  20.0  0.425400  0.007632  0.001706   0.421828  0.428972
# 2         combined  40.0  0.417814  0.011564  0.001828   0.414116  0.421513
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0152
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -5.4791
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.7326
# 7                                Hedge's g =   -1.6982
# 8                            Glass's delta =   -1.5557
# 9                              Pearson's r =    0.6643
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.423667  0.021192  0.004739   0.413749  0.433585
# 1  test_W_combine  20.0  0.458800  0.014347  0.003208   0.452086  0.465514
# 2        combined  40.0  0.441233  0.025210  0.003986   0.433171  0.449296
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0351
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -6.1396
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.9415
# 7                              Hedge's g =   -1.9029
# 8                          Glass's delta =   -1.6579
# 9                            Pearson's r =    0.7057
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 3
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,False,3)
# Out:
# neuron unit number: 3
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.40914285714285714
# train_discrete_score_W0_n 0.008759394549298244
# train_discrete_score_W0_a  0.013917828982926112
# test_discrete_score_W0_p 0.432
# test_discrete_score_W0_n 0.014729225322251585
# test_discrete_score_W0 0.022134779452225216
# self.training_new_embedding  (1750, 12)
# train_discrete_score_W_discrete_p 0.4297142857142857
# train_discrete_score_W_discrete_n 0.05290726531180534
# train_discrete_score_W_discrete_a 0.029622747932502625
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.03893039660159159
# test_discrete_score_W_discrete_a 0.033144074713449455
# neuron unit number: 8
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.40685714285714286
# train_discrete_score_W0_n 0.0160874618895058
# train_discrete_score_W0_a  0.004560808312123171
# test_discrete_score_W0_p 0.44266666666666665
# test_discrete_score_W0_n 0.027089854226747867
# test_discrete_score_W0 0.016108179108449014
# self.training_new_embedding  (1750, 32)
# train_discrete_score_W_discrete_p 0.5011428571428571
# train_discrete_score_W_discrete_n 0.0937896120598117
# train_discrete_score_W_discrete_a 0.08072185726711285
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.516
# test_discrete_score_W_discrete_n 0.0935906956083618
# test_discrete_score_W_discrete_a 0.06775183635893123
# neuron unit number: 13
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.44571428571428573
# train_discrete_score_W0_n 0.025252376689971268
# train_discrete_score_W0_a  0.028851994868781643
# test_discrete_score_W0_p 0.432
# test_discrete_score_W0_n 0.013958700305560283
# test_discrete_score_W0 0.013504242150624717
# self.training_new_embedding  (1750, 52)
# train_discrete_score_W_discrete_p 0.4948571428571429
# train_discrete_score_W_discrete_n 0.0744198314713927
# train_discrete_score_W_discrete_a 0.06142510405426421
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.06989216100339771
# test_discrete_score_W_discrete_a 0.06217418468834886
# neuron unit number: 18
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.47314285714285714
# train_discrete_score_W0_n 0.05978725351724161
# train_discrete_score_W0_a  0.061373415075233
# test_discrete_score_W0_p 0.5
# test_discrete_score_W0_n 0.05764595108176093
# test_discrete_score_W0 0.05362506557510212
# self.training_new_embedding  (1750, 72)
# train_discrete_score_W_discrete_p 0.5102857142857142
# train_discrete_score_W_discrete_n 0.06823344904826573
# train_discrete_score_W_discrete_a 0.07454418039593598
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.5333333333333333
# test_discrete_score_W_discrete_n 0.07912909981906259
# test_discrete_score_W_discrete_a 0.08695407107086338
# neuron unit number: 23
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.4777142857142857
# train_discrete_score_W0_n 0.04090884677800516
# train_discrete_score_W0_a  0.050123513782818784
# test_discrete_score_W0_p 0.5066666666666667
# test_discrete_score_W0_n 0.05960528322091408
# test_discrete_score_W0 0.0673982827607144
# self.training_new_embedding  (1750, 92)
# train_discrete_score_W_discrete_p 0.5434285714285715
# train_discrete_score_W_discrete_n 0.15857278675828002
# train_discrete_score_W_discrete_a 0.10631224727156972
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.5573333333333333
# test_discrete_score_W_discrete_n 0.1323325110443489
# test_discrete_score_W_discrete_a 0.1128109022088329
# neuron unit number: 28
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5137142857142857
# train_discrete_score_W0_n 0.07802454225348054
# train_discrete_score_W0_a  0.07865893963143056
# test_discrete_score_W0_p 0.5186666666666667
# test_discrete_score_W0_n 0.07186330899510097
# test_discrete_score_W0 0.07028134200770107
# self.training_new_embedding  (1750, 112)
# train_discrete_score_W_discrete_p 0.6245714285714286
# train_discrete_score_W_discrete_n 0.18820267844573052
# train_discrete_score_W_discrete_a 0.18941368425043237
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.624
# test_discrete_score_W_discrete_n 0.16115718903048684
# test_discrete_score_W_discrete_a 0.18313775207095442
# neuron unit number: 33
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5182857142857142
# train_discrete_score_W0_n 0.07385600720439532
# train_discrete_score_W0_a  0.09141672510018534
# test_discrete_score_W0_p 0.516
# test_discrete_score_W0_n 0.06461634390618629
# test_discrete_score_W0 0.07794442090442895
# self.training_new_embedding  (1750, 132)
# train_discrete_score_W_discrete_p 0.5885714285714285
# train_discrete_score_W_discrete_n 0.12686240772418447
# train_discrete_score_W_discrete_a 0.1475690119128449
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6053333333333333
# test_discrete_score_W_discrete_n 0.1334998222399686
# test_discrete_score_W_discrete_a 0.166697394942252
# neuron unit number: 38
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.508
# train_discrete_score_W0_n 0.06557108391007889
# train_discrete_score_W0_a  0.07852517317149629
# test_discrete_score_W0_p 0.52
# test_discrete_score_W0_n 0.06351039568146383
# test_discrete_score_W0 0.07621345265500491
# self.training_new_embedding  (1750, 152)
# train_discrete_score_W_discrete_p 0.5862857142857143
# train_discrete_score_W_discrete_n 0.12809367477389677
# train_discrete_score_W_discrete_a 0.1537716633274088
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.62
# test_discrete_score_W_discrete_n 0.1592090701719257
# test_discrete_score_W_discrete_a 0.1823125720111582
# neuron unit number: 43
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.48742857142857143
# train_discrete_score_W0_n 0.07926918836536513
# train_discrete_score_W0_a  0.05946432022356197
# test_discrete_score_W0_p 0.49866666666666665
# test_discrete_score_W0_n 0.05234225409616128
# test_discrete_score_W0 0.0581767220201591
# self.training_new_embedding  (1750, 172)
# train_discrete_score_W_discrete_p 0.5988571428571429
# train_discrete_score_W_discrete_n 0.217980639501429
# train_discrete_score_W_discrete_a 0.15974715513480206
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6
# test_discrete_score_W_discrete_n 0.202540871759907
# test_discrete_score_W_discrete_a 0.14609501924159377
# neuron unit number: 48
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5354285714285715
# train_discrete_score_W0_n 0.08992990159249965
# train_discrete_score_W0_a  0.09961260576064192
# test_discrete_score_W0_p 0.5693333333333334
# test_discrete_score_W0_n 0.10352232664001172
# test_discrete_score_W0 0.11994236047987762
# self.training_new_embedding  (1750, 192)
# train_discrete_score_W_discrete_p 0.6605714285714286
# train_discrete_score_W_discrete_n 0.2650556479293309
# train_discrete_score_W_discrete_a 0.23628245739448483
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.676
# test_discrete_score_W_discrete_n 0.22223964132960697
# test_discrete_score_W_discrete_a 0.26889145029205175
# neuron unit number: 53
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.4777142857142857
# train_discrete_score_W0_n 0.0540448247064575
# train_discrete_score_W0_a  0.057758799314467923
# test_discrete_score_W0_p 0.5026666666666667
# test_discrete_score_W0_n 0.05683511162979147
# test_discrete_score_W0 0.07284799977984734
# self.training_new_embedding  (1750, 212)
# train_discrete_score_W_discrete_p 0.6062857142857143
# train_discrete_score_W_discrete_n 0.1979955503309042
# train_discrete_score_W_discrete_a 0.1676813657497758
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6133333333333333
# test_discrete_score_W_discrete_n 0.1652574050533158
# test_discrete_score_W_discrete_a 0.16649563281118623
# neuron unit number: 58
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5034285714285714
# train_discrete_score_W0_n 0.07090088887377251
# train_discrete_score_W0_a  0.06716396655771235
# test_discrete_score_W0_p 0.5253333333333333
# test_discrete_score_W0_n 0.08423791777813519
# test_discrete_score_W0 0.0831824721533384
# self.training_new_embedding  (1750, 232)
# train_discrete_score_W_discrete_p 0.6411428571428571
# train_discrete_score_W_discrete_n 0.21451155268490055
# train_discrete_score_W_discrete_a 0.2109340175517332
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6453333333333333
# test_discrete_score_W_discrete_n 0.194646043646363
# test_discrete_score_W_discrete_a 0.21462335764204293
# neuron unit number: 63
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5571428571428572
# train_discrete_score_W0_n 0.1186367577537338
# train_discrete_score_W0_a  0.11074860543873738
# test_discrete_score_W0_p 0.588
# test_discrete_score_W0_n 0.130557771293723
# test_discrete_score_W0 0.13602886212130288
# self.training_new_embedding  (1750, 252)
# train_discrete_score_W_discrete_p 0.6325714285714286
# train_discrete_score_W_discrete_n 0.24618825218959065
# train_discrete_score_W_discrete_a 0.19577736964214407
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6466666666666666
# test_discrete_score_W_discrete_n 0.1993825351659922
# test_discrete_score_W_discrete_a 0.2126811396677925
# neuron unit number: 68
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5154285714285715
# train_discrete_score_W0_n 0.07030321133043942
# train_discrete_score_W0_a  0.07545150969614578
# test_discrete_score_W0_p 0.5333333333333333
# test_discrete_score_W0_n 0.07527586505469834
# test_discrete_score_W0 0.08774661984861035
# self.training_new_embedding  (1750, 272)
# train_discrete_score_W_discrete_p 0.6017142857142858
# train_discrete_score_W_discrete_n 0.22430007674644162
# train_discrete_score_W_discrete_a 0.17522040010675852
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6026666666666667
# test_discrete_score_W_discrete_n 0.1508529234735541
# test_discrete_score_W_discrete_a 0.16532618033204033
# neuron unit number: 73
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.47485714285714287
# train_discrete_score_W0_n 0.046463756111687335
# train_discrete_score_W0_a  0.04876821794289743
# test_discrete_score_W0_p 0.5106666666666667
# test_discrete_score_W0_n 0.060980688565436855
# test_discrete_score_W0 0.06551808069620337
# self.training_new_embedding  (1750, 292)
# train_discrete_score_W_discrete_p 0.636
# train_discrete_score_W_discrete_n 0.2435295209960858
# train_discrete_score_W_discrete_a 0.20204713953775394
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6466666666666666
# test_discrete_score_W_discrete_n 0.20476406858453047
# test_discrete_score_W_discrete_a 0.21279099638797747
# neuron unit number: 78
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5325714285714286
# train_discrete_score_W0_n 0.0863841942859045
# train_discrete_score_W0_a  0.10438098096023717
# test_discrete_score_W0_p 0.5453333333333333
# test_discrete_score_W0_n 0.09089002721507566
# test_discrete_score_W0 0.09872303761649394
# self.training_new_embedding  (1750, 312)
# train_discrete_score_W_discrete_p 0.5617142857142857
# train_discrete_score_W_discrete_n 0.12170317516527165
# train_discrete_score_W_discrete_a 0.1396225914318972
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.5986666666666667
# test_discrete_score_W_discrete_n 0.13553486936720996
# test_discrete_score_W_discrete_a 0.16298916052848886
# neuron unit number: 83
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.49542857142857144
# train_discrete_score_W0_n 0.053819737131095655
# train_discrete_score_W0_a  0.058560532583937626
# test_discrete_score_W0_p 0.504
# test_discrete_score_W0_n 0.05667343816171645
# test_discrete_score_W0 0.05904747415858319
# self.training_new_embedding  (1750, 332)
# train_discrete_score_W_discrete_p 0.6302857142857143
# train_discrete_score_W_discrete_n 0.22551837183757295
# train_discrete_score_W_discrete_a 0.19623585475354421
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6426666666666667
# test_discrete_score_W_discrete_n 0.21136734221056078
# test_discrete_score_W_discrete_a 0.20512778978731225
# neuron unit number: 88
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5828571428571429
# train_discrete_score_W0_n 0.12931364746315194
# train_discrete_score_W0_a  0.1408812566354411
# test_discrete_score_W0_p 0.6186666666666667
# test_discrete_score_W0_n 0.15302090357552703
# test_discrete_score_W0 0.18092764832467403
# self.training_new_embedding  (1750, 352)
# train_discrete_score_W_discrete_p 0.6582857142857143
# train_discrete_score_W_discrete_n 0.2619354931903068
# train_discrete_score_W_discrete_a 0.2312025116098388
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6773333333333333
# test_discrete_score_W_discrete_n 0.23060940380323275
# test_discrete_score_W_discrete_a 0.2671853042718243
# neuron unit number: 93
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.5548571428571428
# train_discrete_score_W0_n 0.10945404942598147
# train_discrete_score_W0_a  0.10944962484142455
# test_discrete_score_W0_p 0.5813333333333334
# test_discrete_score_W0_n 0.1209546651083222
# test_discrete_score_W0 0.12953237895806144
# self.training_new_embedding  (1750, 372)
# train_discrete_score_W_discrete_p 0.6274285714285714
# train_discrete_score_W_discrete_n 0.23582144784946107
# train_discrete_score_W_discrete_a 0.19159589377931288
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6293333333333333
# test_discrete_score_W_discrete_n 0.19039502420154386
# test_discrete_score_W_discrete_a 0.1873370728100017
# neuron unit number: 98
# X shape (1750, 4)
# newX shape 1750
# train_discrete_score_W0_p 0.56
# train_discrete_score_W0_n 0.10852421240846898
# train_discrete_score_W0_a  0.11730980533968587
# test_discrete_score_W0_p 0.6133333333333333
# test_discrete_score_W0_n 0.1462220566776681
# test_discrete_score_W0 0.17344867395151053
# self.training_new_embedding  (1750, 392)
# train_discrete_score_W_discrete_p 0.6274285714285714
# train_discrete_score_W_discrete_n 0.23781391777178293
# train_discrete_score_W_discrete_a 0.19062863956103607
# X shape (750, 4)
# newX shape 750
# test_discrete_score_W_discrete_p 0.6386666666666667
# test_discrete_score_W_discrete_n 0.1945626884576909
# test_discrete_score_W_discrete_a 0.1996743191767602
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.069265  0.032803  0.007335   0.053912  0.084617
# 1  train_dis_W_dis  20.0  0.179172  0.069762  0.015599   0.146522  0.211821
# 2         combined  40.0  0.124218  0.077411  0.012240   0.099461  0.148976
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1099
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -6.3760
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.0163
# 7                                    Hedge's g =   -1.9762
# 8                                Glass's delta =   -3.3505
# 9                                  Pearson's r =    0.7189
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.075227  0.039287  0.008785   0.056840  0.093614
# 1  test_dis_W_dis  20.0  0.158495  0.054311  0.012144   0.133077  0.183913
# 2        combined  40.0  0.116861  0.062983  0.009958   0.096718  0.137003
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0833
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -5.5554
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.7568
# 7                                  Hedge's g =   -1.7219
# 8                              Glass's delta =   -2.1195
# 9                                Pearson's r =    0.6695
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.072849  0.035133  0.007856   0.056406  0.089292
# 1  train_dis_W_dis  20.0  0.157018  0.058288  0.013034   0.129738  0.184297
# 2         combined  40.0  0.114933  0.063820  0.010091   0.094523  0.135344
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0842
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -5.5308
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -1.7490
# 7                                    Hedge's g =   -1.7143
# 8                                Glass's delta =   -2.3957
# 9                                  Pearson's r =    0.6678
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.083117  0.046072  0.010302   0.061554  0.104679
# 1  test_dis_W_dis  20.0  0.165210  0.064397  0.014400   0.135071  0.195349
# 2        combined  40.0  0.124163  0.069155  0.010934   0.102046  0.146280
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0821
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -4.6367
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.4662
# 7                                  Hedge's g =   -1.4371
# 8                              Glass's delta =   -1.7819
# 9                                Pearson's r =    0.6011
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.501486  0.047157  0.010545   0.479416  0.523556
# 1  train_dis_W_dis  20.0  0.588057  0.062488  0.013973   0.558812  0.617303
# 2         combined  40.0  0.544771  0.070053  0.011076   0.522367  0.567175
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0866
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -4.9455
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -1.5639
# 7                                    Hedge's g =   -1.5328
# 8                                Glass's delta =   -1.8358
# 9                                  Pearson's r =    0.6258
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.522933  0.052867  0.011822   0.498191  0.547676
# 1  test_dis_W_dis  20.0  0.601467  0.059991  0.013414   0.573390  0.629543
# 2        combined  40.0  0.562200  0.068530  0.010836   0.540283  0.584117
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0785
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -4.3922
# 3                      Two side test p value =    0.0001
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.3889
# 7                                  Hedge's g =   -1.3614
# 8                              Glass's delta =   -1.4855
# 9                                Pearson's r =    0.5803
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 3
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,False,3)
# Out:
# neuron unit number: 3
# train_discrete_score_W0_n 0.06478414028704131
# train_discrete_score_W0_a  0.019090082424564607
# test_discrete_score_W0_n 0.05992358027045841
# test_discrete_score_W0 0.017344883868831727
# self.training_new_embedding  (1750, 12)
# train_discrete_score_W_discrete_n 0.032341479130435384
# train_discrete_score_W_discrete_a 0.020246247156608454
# test_discrete_score_W_discrete_n 0.05992358027045841
# test_discrete_score_W_discrete_a 0.017344883868831727
# neuron unit number: 8
# train_discrete_score_W0_n 0.018049348343213527
# train_discrete_score_W0_a  0.01573559117555162
# test_discrete_score_W0_n 0.050031576201745635
# test_discrete_score_W0 0.04555526821547803
# self.training_new_embedding  (1750, 32)
# train_discrete_score_W_discrete_n 0.09172858213596805
# train_discrete_score_W_discrete_a 0.058208130248452304
# test_discrete_score_W_discrete_n 0.1370465162381913
# test_discrete_score_W_discrete_a 0.07908317088722792
# neuron unit number: 13
# train_discrete_score_W0_n 0.031243816049823993
# train_discrete_score_W0_a  0.023254352569414955
# test_discrete_score_W0_n 0.05165957978700422
# test_discrete_score_W0 0.038100022078810594
# self.training_new_embedding  (1750, 52)
# train_discrete_score_W_discrete_n 0.17659301260339913
# train_discrete_score_W_discrete_a 0.16884638303252505
# test_discrete_score_W_discrete_n 0.1996952870231416
# test_discrete_score_W_discrete_a 0.20309202513472607
# neuron unit number: 18
# train_discrete_score_W0_n 0.07204948446679879
# train_discrete_score_W0_a  0.06874759799392224
# test_discrete_score_W0_n 0.08568010995085606
# test_discrete_score_W0 0.1003986552520298
# self.training_new_embedding  (1750, 72)
# train_discrete_score_W_discrete_n 0.21639142726354982
# train_discrete_score_W_discrete_a 0.17695739624514076
# test_discrete_score_W_discrete_n 0.2650862189037139
# test_discrete_score_W_discrete_a 0.21777193991445568
# neuron unit number: 23
# train_discrete_score_W0_n 0.04755135594339516
# train_discrete_score_W0_a  0.052019212573453134
# test_discrete_score_W0_n 0.06580236478802444
# test_discrete_score_W0 0.08886787131021007
# self.training_new_embedding  (1750, 92)
# train_discrete_score_W_discrete_n 0.110410971494885
# train_discrete_score_W_discrete_a 0.13043582460489372
# test_discrete_score_W_discrete_n 0.14114131460291793
# test_discrete_score_W_discrete_a 0.17474815088660503
# neuron unit number: 28
# train_discrete_score_W0_n 0.06380364855667905
# train_discrete_score_W0_a  0.0504750068409284
# test_discrete_score_W0_n 0.0979381297515061
# test_discrete_score_W0 0.09394592177723489
# self.training_new_embedding  (1750, 112)
# train_discrete_score_W_discrete_n 0.12010341089985682
# train_discrete_score_W_discrete_a 0.11945490581713801
# test_discrete_score_W_discrete_n 0.1484887631747772
# test_discrete_score_W_discrete_a 0.15406470662907326
# neuron unit number: 33
# train_discrete_score_W0_n 0.06786138810614703
# train_discrete_score_W0_a  0.06942360861461905
# test_discrete_score_W0_n 0.07863403133745225
# test_discrete_score_W0 0.09336073029026459
# self.training_new_embedding  (1750, 132)
# train_discrete_score_W_discrete_n 0.1398367808491368
# train_discrete_score_W_discrete_a 0.1434721922103722
# test_discrete_score_W_discrete_n 0.1680843086605063
# test_discrete_score_W_discrete_a 0.1845677982464825
# neuron unit number: 38
# train_discrete_score_W0_n 0.07538891162053975
# train_discrete_score_W0_a  0.07769527000052905
# test_discrete_score_W0_n 0.08095606681072293
# test_discrete_score_W0 0.09567094376170905
# self.training_new_embedding  (1750, 152)
# train_discrete_score_W_discrete_n 0.200407826168764
# train_discrete_score_W_discrete_a 0.21698682473821004
# test_discrete_score_W_discrete_n 0.22783749593373676
# test_discrete_score_W_discrete_a 0.2540036411881496
# neuron unit number: 43
# train_discrete_score_W0_n 0.0692845899700297
# train_discrete_score_W0_a  0.07362730319532293
# test_discrete_score_W0_n 0.07130666454291845
# test_discrete_score_W0 0.07057320266932954
# self.training_new_embedding  (1750, 172)
# train_discrete_score_W_discrete_n 0.17248736785422278
# train_discrete_score_W_discrete_a 0.1644851178294208
# test_discrete_score_W_discrete_n 0.22473000543216995
# test_discrete_score_W_discrete_a 0.22387363630737925
# neuron unit number: 48
# train_discrete_score_W0_n 0.0760635937819511
# train_discrete_score_W0_a  0.08534849124712264
# test_discrete_score_W0_n 0.12115007276965045
# test_discrete_score_W0 0.13637840601766885
# self.training_new_embedding  (1750, 192)
# train_discrete_score_W_discrete_n 0.09452386815578094
# train_discrete_score_W_discrete_a 0.11043664119252497
# test_discrete_score_W_discrete_n 0.12504602240620494
# test_discrete_score_W_discrete_a 0.1472167326899598
# neuron unit number: 53
# train_discrete_score_W0_n 0.05123238645472104
# train_discrete_score_W0_a  0.054286828116974516
# test_discrete_score_W0_n 0.05437629763083152
# test_discrete_score_W0 0.07225139842135664
# self.training_new_embedding  (1750, 212)
# train_discrete_score_W_discrete_n 0.10573682456306249
# train_discrete_score_W_discrete_a 0.11818412841178125
# test_discrete_score_W_discrete_n 0.10363282232948828
# test_discrete_score_W_discrete_a 0.133383743564865
# neuron unit number: 58
# train_discrete_score_W0_n 0.06622045726009994
# train_discrete_score_W0_a  0.06127452292467465
# test_discrete_score_W0_n 0.06800790430069756
# test_discrete_score_W0 0.08201075687463592
# self.training_new_embedding  (1750, 232)
# train_discrete_score_W_discrete_n 0.07181392834625636
# train_discrete_score_W_discrete_a 0.07164793794016835
# test_discrete_score_W_discrete_n 0.08631642836635628
# test_discrete_score_W_discrete_a 0.09042054589405717
# neuron unit number: 63
# train_discrete_score_W0_n 0.10139018735659479
# train_discrete_score_W0_a  0.1036440197616628
# test_discrete_score_W0_n 0.12158719673681906
# test_discrete_score_W0 0.13671521759342903
# self.training_new_embedding  (1750, 252)
# train_discrete_score_W_discrete_n 0.20148830763914882
# train_discrete_score_W_discrete_a 0.18399487115144011
# test_discrete_score_W_discrete_n 0.24643980721746322
# test_discrete_score_W_discrete_a 0.2419495898894216
# neuron unit number: 68
# train_discrete_score_W0_n 0.09144837208869064
# train_discrete_score_W0_a  0.09800204799015491
# test_discrete_score_W0_n 0.16059069992531327
# test_discrete_score_W0 0.17662757254191847
# self.training_new_embedding  (1750, 272)
# train_discrete_score_W_discrete_n 0.17565921921754815
# train_discrete_score_W_discrete_a 0.1850596124198664
# test_discrete_score_W_discrete_n 0.2387869375162597
# test_discrete_score_W_discrete_a 0.24000327052960635
# neuron unit number: 73
# train_discrete_score_W0_n 0.051637561089493966
# train_discrete_score_W0_a  0.054487272607670605
# test_discrete_score_W0_n 0.058582765717924666
# test_discrete_score_W0 0.0733434306744671
# self.training_new_embedding  (1750, 292)
# train_discrete_score_W_discrete_n 0.1721923952072128
# train_discrete_score_W_discrete_a 0.16665780635747565
# test_discrete_score_W_discrete_n 0.2649507286600901
# test_discrete_score_W_discrete_a 0.22571284480470002
# neuron unit number: 78
# train_discrete_score_W0_n 0.0747450650401995
# train_discrete_score_W0_a  0.08347655361499481
# test_discrete_score_W0_n 0.10070068109027656
# test_discrete_score_W0 0.11715982211881214
# self.training_new_embedding  (1750, 312)
# train_discrete_score_W_discrete_n 0.18263816367331412
# train_discrete_score_W_discrete_a 0.20170421572454314
# test_discrete_score_W_discrete_n 0.21123952055901096
# test_discrete_score_W_discrete_a 0.24132885417374897
# neuron unit number: 83
# train_discrete_score_W0_n 0.06586327535267097
# train_discrete_score_W0_a  0.07250314498893658
# test_discrete_score_W0_n 0.08318556955003999
# test_discrete_score_W0 0.10139507141040126
# self.training_new_embedding  (1750, 332)
# train_discrete_score_W_discrete_n 0.17076197953773042
# train_discrete_score_W_discrete_a 0.1574260593354487
# test_discrete_score_W_discrete_n 0.2101005215667286
# test_discrete_score_W_discrete_a 0.22212346303522248
# neuron unit number: 88
# train_discrete_score_W0_n 0.10599630652244824
# train_discrete_score_W0_a  0.12115289217049016
# test_discrete_score_W0_n 0.15173741048706296
# test_discrete_score_W0 0.17549848964963588
# self.training_new_embedding  (1750, 352)
# train_discrete_score_W_discrete_n 0.1606320069026819
# train_discrete_score_W_discrete_a 0.17476766351284756
# test_discrete_score_W_discrete_n 0.20389143479005448
# test_discrete_score_W_discrete_a 0.19081873758234932
# neuron unit number: 93
# train_discrete_score_W0_n 0.09868064552434838
# train_discrete_score_W0_a  0.1123628366374224
# test_discrete_score_W0_n 0.11376858621789857
# test_discrete_score_W0 0.14510491475882248
# self.training_new_embedding  (1750, 372)
# train_discrete_score_W_discrete_n 0.21184030355823127
# train_discrete_score_W_discrete_a 0.20774414292074683
# test_discrete_score_W_discrete_n 0.2506919104816692
# test_discrete_score_W_discrete_a 0.2606562155230106
# neuron unit number: 98
# train_discrete_score_W0_n 0.0929566058752488
# train_discrete_score_W0_a  0.10809777571548691
# test_discrete_score_W0_n 0.12014103030894994
# test_discrete_score_W0 0.13702449575004844
# self.training_new_embedding  (1750, 392)
# train_discrete_score_W_discrete_n 0.21639142726354982
# train_discrete_score_W_discrete_a 0.17695739624514076
# test_discrete_score_W_discrete_n 0.27323694388676795
# test_discrete_score_W_discrete_a 0.2219824959725161
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.069313  0.022560  0.005045   0.058754  0.079871
# 1  train_dis_W_dis  20.0  0.151199  0.052681  0.011780   0.126544  0.175854
# 2         combined  40.0  0.110256  0.057614  0.009110   0.091830  0.128681
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0819
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -6.3902
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.0207
# 7                                    Hedge's g =   -1.9806
# 8                                Glass's delta =   -3.6297
# 9                                  Pearson's r =    0.7197
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.089788  0.032715  0.007315   0.074477  0.105099
# 1  test_dis_W_dis  20.0  0.189318  0.064051  0.014322   0.159342  0.219295
# 2        combined  40.0  0.139553  0.071135  0.011247   0.116803  0.162303
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0995
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -6.1888
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.9571
# 7                                  Hedge's g =   -1.9182
# 8                              Glass's delta =   -3.0423
# 9                                Pearson's r =    0.7085
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.070235  0.030145  0.006741   0.056127  0.084343
# 1  train_dis_W_dis  20.0  0.147684  0.051847  0.011593   0.123419  0.171949
# 2         combined  40.0  0.108959  0.057361  0.009070   0.090614  0.127304
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0774
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -5.7753
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -1.8263
# 7                                    Hedge's g =   -1.7900
# 8                                Glass's delta =   -2.5692
# 9                                  Pearson's r =    0.6837
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.099866  0.042591  0.009524   0.079933  0.119800
# 1  test_dis_W_dis  20.0  0.186207  0.065161  0.014570   0.155711  0.216704
# 2        combined  40.0  0.143037  0.069741  0.011027   0.120733  0.165341
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0863
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -4.9602
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.5685
# 7                                  Hedge's g =   -1.5374
# 8                              Glass's delta =   -2.0272
# 9                                Pearson's r =    0.6269
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 250
class_num = 100
dim_num = 15
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
# Out:
# neuron unit number: 100
# train_discrete_score_W0_n 0.6574769616172834
# train_discrete_score_W0 0.7844140398477599
# test_discrete_score_W0_n 0.5991246728785601
# test_discrete_score_W0 0.7280464995559777
# train_discrete_score_W_discrete 0.6886438520386063
# train_discrete_score_W_discrete 0.8091450326022601
# test_discrete_score_W_discrete 0.5785566449588014
# test_discrete_score_W_discrete 0.7048138862779197
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 105
# train_discrete_score_W0_n 0.6957307545793543
# train_discrete_score_W0 0.8139811685253157
# test_discrete_score_W0_n 0.4342141881316568
# test_discrete_score_W0 0.5669597231436386
# train_discrete_score_W_discrete 0.5838121951401084
# train_discrete_score_W_discrete 0.7216422433464762
# test_discrete_score_W_discrete 0.39586715928055705
# test_discrete_score_W_discrete 0.5476066638062106
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 110
# train_discrete_score_W0_n 0.633934958918436
# train_discrete_score_W0 0.7640620483538298
# test_discrete_score_W0_n 0.5395153767218647
# test_discrete_score_W0 0.6731000663104956
# train_discrete_score_W_discrete 0.6308541997381613
# train_discrete_score_W_discrete 0.7605882536250287
# test_discrete_score_W_discrete 0.5282858504096698
# test_discrete_score_W_discrete 0.6770845109996166
# Not good nmi result for discrete features !!!!!
# neuron unit number: 115
# train_discrete_score_W0_n 0.6224497238503213
# train_discrete_score_W0 0.7551622236774259
# test_discrete_score_W0_n 0.48122777431053376
# test_discrete_score_W0 0.62656170024418
# train_discrete_score_W_discrete 0.72193374333394
# train_discrete_score_W_discrete 0.8348849779152779
# test_discrete_score_W_discrete 0.6235138676434478
# test_discrete_score_W_discrete 0.7511536077026868
# neuron unit number: 120
# train_discrete_score_W0_n 0.6597902932987586
# train_discrete_score_W0 0.783469692117894
# test_discrete_score_W0_n 0.578019827547471
# test_discrete_score_W0 0.7011945089442781
# train_discrete_score_W_discrete 0.6552689351484178
# train_discrete_score_W_discrete 0.7782521177032266
# test_discrete_score_W_discrete 0.5286997549338525
# test_discrete_score_W_discrete 0.6622504099333069
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 125
# train_discrete_score_W0_n 0.6165444437184009
# train_discrete_score_W0 0.7493294803493851
# test_discrete_score_W0_n 0.507704099421099
# test_discrete_score_W0 0.6526352410013797
# train_discrete_score_W_discrete 0.6055062674336852
# train_discrete_score_W_discrete 0.739446821349269
# test_discrete_score_W_discrete 0.41926132344562667
# test_discrete_score_W_discrete 0.5377347419817168
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 130
# train_discrete_score_W0_n 0.6609397287763483
# train_discrete_score_W0 0.7833043461025578
# test_discrete_score_W0_n 0.5277934411347841
# test_discrete_score_W0 0.658924233816544
# train_discrete_score_W_discrete 0.5825041002611127
# train_discrete_score_W_discrete 0.7208576277428301
# test_discrete_score_W_discrete 0.42631022309641525
# test_discrete_score_W_discrete 0.5643055552167069
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 135
# train_discrete_score_W0_n 0.6956899287825433
# train_discrete_score_W0 0.8146345248713517
# test_discrete_score_W0_n 0.4284669576111802
# test_discrete_score_W0 0.5678881099176638
# train_discrete_score_W_discrete 0.7123697615026302
# train_discrete_score_W_discrete 0.823719158313427
# test_discrete_score_W_discrete 0.497983196890974
# test_discrete_score_W_discrete 0.6238825260567515
# neuron unit number: 140
# train_discrete_score_W0_n 0.6623353381511325
# train_discrete_score_W0 0.7831367013620862
# test_discrete_score_W0_n 0.5423127294094394
# test_discrete_score_W0 0.6637369323975856
# train_discrete_score_W_discrete 0.675941860968173
# train_discrete_score_W_discrete 0.7991159333341294
# test_discrete_score_W_discrete 0.5523971250087036
# test_discrete_score_W_discrete 0.6918419915619364
# neuron unit number: 145
# train_discrete_score_W0_n 0.678843732180922
# train_discrete_score_W0 0.7999386638108118
# test_discrete_score_W0_n 0.39321066908047986
# test_discrete_score_W0 0.5335669539655193
# train_discrete_score_W_discrete 0.8357537539932116
# train_discrete_score_W_discrete 0.913116219712124
# test_discrete_score_W_discrete 0.7376971450820167
# test_discrete_score_W_discrete 0.8357621543155669
# neuron unit number: 150
# train_discrete_score_W0_n 0.6655885779193651
# train_discrete_score_W0 0.7885277689555694
# test_discrete_score_W0_n 0.5237538219558759
# test_discrete_score_W0 0.6634278941692014
# train_discrete_score_W_discrete 0.7123697615026302
# train_discrete_score_W_discrete 0.823719158313427
# test_discrete_score_W_discrete 0.5056481488285197
# test_discrete_score_W_discrete 0.661703147758879
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 155
# train_discrete_score_W0_n 0.6903527254079393
# train_discrete_score_W0 0.8087274947883352
# test_discrete_score_W0_n 0.509947910859519
# test_discrete_score_W0 0.6434011621000975
# train_discrete_score_W_discrete 0.65512732635131
# train_discrete_score_W_discrete 0.7758707782568516
# test_discrete_score_W_discrete 0.4657836656315575
# test_discrete_score_W_discrete 0.6176601004476913
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 160
# train_discrete_score_W0_n 0.7214584407502612
# train_discrete_score_W0 0.8345409406716608
# test_discrete_score_W0_n 0.5615235144685645
# test_discrete_score_W0 0.670784717674389
# train_discrete_score_W_discrete 0.678843732180922
# train_discrete_score_W_discrete 0.7999386638108118
# test_discrete_score_W_discrete 0.4567714371845568
# test_discrete_score_W_discrete 0.6104130475439452
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 165
# train_discrete_score_W0_n 0.7652180485582912
# train_discrete_score_W0 0.8652393549670292
# test_discrete_score_W0_n 0.5203110701792036
# test_discrete_score_W0 0.6371096302481192
# train_discrete_score_W_discrete 0.7778634148496385
# train_discrete_score_W_discrete 0.8760243485659165
# test_discrete_score_W_discrete 0.701060858177909
# test_discrete_score_W_discrete 0.8157609245887354
# neuron unit number: 170
# train_discrete_score_W0_n 0.6263735723609063
# train_discrete_score_W0 0.7533474846405678
# test_discrete_score_W0_n 0.5116829862318818
# test_discrete_score_W0 0.6398476405581756
# train_discrete_score_W_discrete 0.6870456971611327
# train_discrete_score_W_discrete 0.8051144454448084
# test_discrete_score_W_discrete 0.5001152941215847
# test_discrete_score_W_discrete 0.6489015313531601
# Not good nmi result for discrete features !!!!!
# neuron unit number: 175
# train_discrete_score_W0_n 0.6455292464930019
# train_discrete_score_W0 0.7740632888184946
# test_discrete_score_W0_n 0.5714232448237687
# test_discrete_score_W0 0.6861576571402368
# train_discrete_score_W_discrete 0.8756369191848967
# train_discrete_score_W_discrete 0.9397121748544623
# test_discrete_score_W_discrete 0.742674631284831
# test_discrete_score_W_discrete 0.8555398995593311
# neuron unit number: 180
# train_discrete_score_W0_n 0.7148731078019736
# train_discrete_score_W0 0.8293844799204757
# test_discrete_score_W0_n 0.47565164297257156
# test_discrete_score_W0 0.6129594160249715
# train_discrete_score_W_discrete 0.6453147210892557
# train_discrete_score_W_discrete 0.7742266892969817
# test_discrete_score_W_discrete 0.4368387632394
# test_discrete_score_W_discrete 0.5904113894153554
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 185
# train_discrete_score_W0_n 0.7016156490464048
# train_discrete_score_W0 0.8192345481310422
# test_discrete_score_W0_n 0.5297663508396389
# test_discrete_score_W0 0.6680084599333991
# train_discrete_score_W_discrete 0.722619542663477
# train_discrete_score_W_discrete 0.8349962505172506
# test_discrete_score_W_discrete 0.49519652225786276
# test_discrete_score_W_discrete 0.5854155896773557
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 190
# train_discrete_score_W0_n 0.7234653182724621
# train_discrete_score_W0 0.8341814306163504
# test_discrete_score_W0_n 0.5547583939204842
# test_discrete_score_W0 0.6666427714357691
# train_discrete_score_W_discrete 0.8777036461034585
# train_discrete_score_W_discrete 0.939627864331399
# test_discrete_score_W_discrete 0.6995551409924053
# test_discrete_score_W_discrete 0.8126160449005798
# neuron unit number: 195
# train_discrete_score_W0_n 0.6697364816962559
# train_discrete_score_W0 0.7943419932214643
# test_discrete_score_W0_n 0.5473473834687316
# test_discrete_score_W0 0.653337293803526
# train_discrete_score_W_discrete 0.6275724551325147
# train_discrete_score_W_discrete 0.7596036988681206
# test_discrete_score_W_discrete 0.3887772626035656
# test_discrete_score_W_discrete 0.5221738701308484
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 200
# train_discrete_score_W0_n 0.7453289141290422
# train_discrete_score_W0 0.8495371397749328
# test_discrete_score_W0_n 0.5273603100246596
# test_discrete_score_W0 0.6484111023298761
# train_discrete_score_W_discrete 0.6012369010505024
# train_discrete_score_W_discrete 0.7362213637529273
# test_discrete_score_W_discrete 0.3910614903457959
# test_discrete_score_W_discrete 0.5387275651783135
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 205
# train_discrete_score_W0_n 0.6762031013967059
# train_discrete_score_W0 0.7989715426131493
# test_discrete_score_W0_n 0.4289892450335766
# test_discrete_score_W0 0.5537051685513781
# train_discrete_score_W_discrete 0.9470144051176661
# train_discrete_score_W_discrete 0.9778886830122239
# test_discrete_score_W_discrete 0.6641459154197565
# test_discrete_score_W_discrete 0.756452155314377
# neuron unit number: 210
# train_discrete_score_W0_n 0.7015586729150893
# train_discrete_score_W0 0.8194887716876378
# test_discrete_score_W0_n 0.5261120778246873
# test_discrete_score_W0 0.66016981641734
# train_discrete_score_W_discrete 0.7044807831937523
# train_discrete_score_W_discrete 0.8131328281424137
# test_discrete_score_W_discrete 0.4383786977471618
# test_discrete_score_W_discrete 0.5611001459551151
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 215
# train_discrete_score_W0_n 0.7161081424514275
# train_discrete_score_W0 0.8291374281504905
# test_discrete_score_W0_n 0.5641830689383239
# test_discrete_score_W0 0.6759311972267718
# train_discrete_score_W_discrete 0.8118276841120282
# train_discrete_score_W_discrete 0.8967200464630903
# test_discrete_score_W_discrete 0.5162523976413339
# test_discrete_score_W_discrete 0.6582300554330661
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 220
# train_discrete_score_W0_n 0.6762031013967059
# train_discrete_score_W0 0.7989715426131493
# test_discrete_score_W0_n 0.5332744195852142
# test_discrete_score_W0 0.683039556847382
# train_discrete_score_W_discrete 0.6822403685265623
# train_discrete_score_W_discrete 0.8043302988953127
# test_discrete_score_W_discrete 0.3425579699665409
# test_discrete_score_W_discrete 0.48855799126019966
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 225
# train_discrete_score_W0_n 0.7035957634470298
# train_discrete_score_W0 0.8188390833829372
# test_discrete_score_W0_n 0.39893145860481466
# test_discrete_score_W0 0.5530508537011914
# train_discrete_score_W_discrete 0.716248509594852
# train_discrete_score_W_discrete 0.8234480651289127
# test_discrete_score_W_discrete 0.4407101539776244
# test_discrete_score_W_discrete 0.580383188223596
# neuron unit number: 230
# train_discrete_score_W0_n 0.675941860968173
# train_discrete_score_W0 0.7991159333341294
# test_discrete_score_W0_n 0.4006512257338644
# test_discrete_score_W0 0.5465425243863712
# train_discrete_score_W_discrete 0.6697364816962559
# train_discrete_score_W_discrete 0.7943419932214643
# test_discrete_score_W_discrete 0.3688894180027206
# test_discrete_score_W_discrete 0.5135882337728095
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 235
# train_discrete_score_W0_n 0.6641076644334958
# train_discrete_score_W0 0.7888419349310241
# test_discrete_score_W0_n 0.4125183590314679
# test_discrete_score_W0 0.5243918673267207
# train_discrete_score_W_discrete 0.729001712491866
# train_discrete_score_W_discrete 0.8394795325226801
# test_discrete_score_W_discrete 0.4440782982872488
# test_discrete_score_W_discrete 0.5954358664721416
# neuron unit number: 240
# train_discrete_score_W0_n 0.6417122451645323
# train_discrete_score_W0 0.7685381520356563
# test_discrete_score_W0_n 0.40787521830232504
# test_discrete_score_W0 0.5620323052441702
# train_discrete_score_W_discrete 0.9240691000237302
# train_discrete_score_W_discrete 0.966900929520731
# test_discrete_score_W_discrete 0.6970471373781701
# test_discrete_score_W_discrete 0.7993272406668129
# neuron unit number: 245
# train_discrete_score_W0_n 0.7356046594829126
# train_discrete_score_W0 0.8446670556679017
# test_discrete_score_W0_n 0.3774272873187112
# test_discrete_score_W0 0.49536723982802494
# train_discrete_score_W_discrete 0.6974710755004719
# train_discrete_score_W_discrete 0.813706260188164
# test_discrete_score_W_discrete 0.4352970036407572
# test_discrete_score_W_discrete 0.570016544438423
# neuron unit number: 250
# train_discrete_score_W0_n 0.7035957634470298
# train_discrete_score_W0 0.8188390833829372
# test_discrete_score_W0_n 0.5074620865264263
# test_discrete_score_W0 0.6264594018254874
# train_discrete_score_W_discrete 0.841009540337402
# train_discrete_score_W_discrete 0.9182975583104982
# test_discrete_score_W_discrete 0.6494535735936916
# test_discrete_score_W_discrete 0.7517528102957083
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.682191  0.036716  0.006594   0.668723  0.695658
# 1  train_dis_W_dis  31.0  0.718614  0.097945  0.017591   0.682687  0.754540
# 2         combined  62.0  0.700402  0.075618  0.009603   0.681199  0.719605
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0364
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.9388
# 3                        Two side test p value =    0.0572
# 4                       Difference < 0 p value =    0.0286
# 5                       Difference > 0 p value =    0.9714
# 6                                    Cohen's d =   -0.4924
# 7                                    Hedge's g =   -0.4863
# 8                                Glass's delta =   -0.9920
# 9                                  Pearson's r =    0.2428
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.497501  0.063489  0.011403   0.474213  0.520789
# 1  test_dis_W_dis  31.0  0.518351  0.116917  0.020999   0.475465  0.561236
# 2        combined  62.0  0.507926  0.093892  0.011924   0.484082  0.531770
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0208
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -0.8725
# 3                      Two side test p value =    0.3864
# 4                     Difference < 0 p value =    0.1932
# 5                     Difference > 0 p value =    0.8068
# 6                                  Cohen's d =   -0.2216
# 7                                  Hedge's g =   -0.2188
# 8                              Glass's delta =   -0.3284
# 9                                Pearson's r =    0.1119
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.802193  0.029243  0.005252   0.791466  0.812919
# 1  train_dis_W_dis  31.0  0.826260  0.070782  0.012713   0.800297  0.852223
# 2         combined  62.0  0.814226  0.055061  0.006993   0.800244  0.828209
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0241
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.7497
# 3                        Two side test p value =    0.0853
# 4                       Difference < 0 p value =    0.0426
# 5                       Difference > 0 p value =    0.9574
# 6                                    Cohen's d =   -0.4444
# 7                                    Hedge's g =   -0.4389
# 8                                Glass's delta =   -0.8230
# 9                                  Pearson's r =    0.2203
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.627206  0.059049  0.010605   0.605547  0.648865
# 1  test_dis_W_dis  31.0  0.649374  0.104513  0.018771   0.611039  0.687710
# 2        combined  62.0  0.638290  0.084921  0.010785   0.616724  0.659856
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0222
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -1.0282
# 3                      Two side test p value =    0.3080
# 4                     Difference < 0 p value =    0.1540
# 5                     Difference > 0 p value =    0.8460
# 6                                  Cohen's d =   -0.2612
# 7                                  Hedge's g =   -0.2579
# 8                              Glass's delta =   -0.3754
# 9                                Pearson's r =    0.1316
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 250
class_num = 100
dim_num = 15
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
# Out:
# neuron unit number: 100
# train_discrete_score_W0_n 0.6292588022409977
# train_discrete_score_W0 0.7561355023678271
# test_discrete_score_W0_n 0.4952816635392816
# test_discrete_score_W0 0.6407998175210105
# train_discrete_score_W_discrete 0.6409555791298135
# train_discrete_score_W_discrete 0.7536066262118756
# test_discrete_score_W_discrete 0.5653309099674511
# test_discrete_score_W_discrete 0.6682879292525026
# neuron unit number: 105
# train_discrete_score_W0_n 0.6339927776385098
# train_discrete_score_W0 0.7615788594167644
# test_discrete_score_W0_n 0.5095849829464173
# test_discrete_score_W0 0.658018618909443
# train_discrete_score_W_discrete 0.6398235669114352
# train_discrete_score_W_discrete 0.7664877397652967
# test_discrete_score_W_discrete 0.5207443103459976
# test_discrete_score_W_discrete 0.677014100181446
# neuron unit number: 110
# train_discrete_score_W0_n 0.591937942137196
# train_discrete_score_W0 0.7239293959382551
# test_discrete_score_W0_n 0.6179224770628694
# test_discrete_score_W0 0.7435111554482094
# train_discrete_score_W_discrete 0.5896314788969826
# train_discrete_score_W_discrete 0.723199331102171
# test_discrete_score_W_discrete 0.5516143851559271
# test_discrete_score_W_discrete 0.6966261886726719
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 115
# train_discrete_score_W0_n 0.5589589862906104
# train_discrete_score_W0 0.6954708511450571
# test_discrete_score_W0_n 0.5189374992558675
# test_discrete_score_W0 0.6758591443061982
# train_discrete_score_W_discrete 0.6115978993864303
# train_discrete_score_W_discrete 0.7419171178742995
# test_discrete_score_W_discrete 0.5330454832537075
# test_discrete_score_W_discrete 0.6755558734602435
# Not good ari result for discrete features  !!!!!
# neuron unit number: 120
# train_discrete_score_W0_n 0.6398235669114352
# train_discrete_score_W0 0.7664877397652967
# test_discrete_score_W0_n 0.5911556179492762
# test_discrete_score_W0 0.7190753860136597
# train_discrete_score_W_discrete 0.6574590192772458
# train_discrete_score_W_discrete 0.7811702045396339
# test_discrete_score_W_discrete 0.5383203043398485
# test_discrete_score_W_discrete 0.6767373157108679
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 125
# train_discrete_score_W0_n 0.6284076638593791
# train_discrete_score_W0 0.7564127994852318
# test_discrete_score_W0_n 0.652816392944769
# test_discrete_score_W0 0.7815159263706947
# train_discrete_score_W_discrete 0.6327711440033005
# train_discrete_score_W_discrete 0.7575592405172445
# test_discrete_score_W_discrete 0.5255896484098574
# test_discrete_score_W_discrete 0.6673209997039051
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 130
# train_discrete_score_W0_n 0.6232467456572963
# train_discrete_score_W0 0.7513788091170079
# test_discrete_score_W0_n 0.5276572415528077
# test_discrete_score_W0 0.6828780223604305
# train_discrete_score_W_discrete 0.6312597742830336
# train_discrete_score_W_discrete 0.7503294483455606
# test_discrete_score_W_discrete 0.4280115520382575
# test_discrete_score_W_discrete 0.5773408915741055
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 135
# train_discrete_score_W0_n 0.6178117847543365
# train_discrete_score_W0 0.7464941557237494
# test_discrete_score_W0_n 0.5250861261501393
# test_discrete_score_W0 0.6656730592504156
# train_discrete_score_W_discrete 0.6026339241704108
# train_discrete_score_W_discrete 0.7317512074799638
# test_discrete_score_W_discrete 0.6177662253550124
# test_discrete_score_W_discrete 0.7569096365336876
# neuron unit number: 140
# train_discrete_score_W0_n 0.6685100706402355
# train_discrete_score_W0 0.7850402472708164
# test_discrete_score_W0_n 0.5443005379916206
# test_discrete_score_W0 0.6952953828767248
# train_discrete_score_W_discrete 0.6753717859890631
# train_discrete_score_W_discrete 0.7958705234485091
# test_discrete_score_W_discrete 0.5845326654674305
# test_discrete_score_W_discrete 0.7157343935488534
# neuron unit number: 145
# train_discrete_score_W0_n 0.6254927970583161
# train_discrete_score_W0 0.7509419149959745
# test_discrete_score_W0_n 0.4931634525390216
# test_discrete_score_W0 0.6464702105140713
# train_discrete_score_W_discrete 0.7396647031317778
# train_discrete_score_W_discrete 0.8461218262689703
# test_discrete_score_W_discrete 0.6355013906514514
# test_discrete_score_W_discrete 0.769292999411213
# neuron unit number: 150
# train_discrete_score_W0_n 0.6583659119382524
# train_discrete_score_W0 0.7813994781826077
# test_discrete_score_W0_n 0.6212953338030631
# test_discrete_score_W0 0.7481948523690334
# train_discrete_score_W_discrete 0.7684058955787537
# train_discrete_score_W_discrete 0.8663815725397342
# test_discrete_score_W_discrete 0.6402807814182536
# test_discrete_score_W_discrete 0.7456756521034572
# Not good ari result for discrete features  !!!!!
# neuron unit number: 155
# train_discrete_score_W0_n 0.6340326407210548
# train_discrete_score_W0 0.7613171735562273
# test_discrete_score_W0_n 0.5314823894513107
# test_discrete_score_W0 0.6831821143656721
# train_discrete_score_W_discrete 0.6632309603810987
# train_discrete_score_W_discrete 0.785900699732901
# test_discrete_score_W_discrete 0.7249616008647625
# test_discrete_score_W_discrete 0.8496298820120101
# neuron unit number: 160
# train_discrete_score_W0_n 0.6715798244056174
# train_discrete_score_W0 0.7902925611588183
# test_discrete_score_W0_n 0.49667377546958175
# test_discrete_score_W0 0.6478076481968708
# train_discrete_score_W_discrete 0.6287300385219625
# train_discrete_score_W_discrete 0.756942685265179
# test_discrete_score_W_discrete 0.5137972799528551
# test_discrete_score_W_discrete 0.6380174607128802
# Not good ari result for discrete features  !!!!!
# neuron unit number: 165
# train_discrete_score_W0_n 0.6516997896826351
# train_discrete_score_W0 0.7758535736864905
# test_discrete_score_W0_n 0.5066891557264696
# test_discrete_score_W0 0.6607921490062141
# train_discrete_score_W_discrete 0.7489433667449761
# train_discrete_score_W_discrete 0.8514858514459515
# test_discrete_score_W_discrete 0.6470779633978195
# test_discrete_score_W_discrete 0.7749124367094351
# neuron unit number: 170
# train_discrete_score_W0_n 0.6514318978470556
# train_discrete_score_W0 0.7759783054894787
# test_discrete_score_W0_n 0.5565126038692925
# test_discrete_score_W0 0.6924788102971595
# train_discrete_score_W_discrete 0.6232467456572963
# train_discrete_score_W_discrete 0.7513788091170079
# test_discrete_score_W_discrete 0.5402642404122664
# test_discrete_score_W_discrete 0.6941357290542147
# Not good nmi result for discrete features !!!!!
# neuron unit number: 175
# train_discrete_score_W0_n 0.6756960074675901
# train_discrete_score_W0 0.7899188777018251
# test_discrete_score_W0_n 0.6053917367740663
# test_discrete_score_W0 0.7616898504957307
# train_discrete_score_W_discrete 0.700247803877572
# train_discrete_score_W_discrete 0.8157585645959636
# test_discrete_score_W_discrete 0.6012392413464022
# test_discrete_score_W_discrete 0.7441881302936117
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 180
# train_discrete_score_W0_n 0.5908300760154002
# train_discrete_score_W0 0.7224108742200254
# test_discrete_score_W0_n 0.5079133227411924
# test_discrete_score_W0 0.6437287927352358
# train_discrete_score_W_discrete 0.7464012750699429
# train_discrete_score_W_discrete 0.8511789705202492
# test_discrete_score_W_discrete 0.6519454064234129
# test_discrete_score_W_discrete 0.7814067046708406
# neuron unit number: 185
# train_discrete_score_W0_n 0.6943025517951198
# train_discrete_score_W0 0.810914533710653
# test_discrete_score_W0_n 0.49662985203133314
# test_discrete_score_W0 0.6212138220771253
# train_discrete_score_W_discrete 0.7442454794848902
# train_discrete_score_W_discrete 0.846512163816703
# test_discrete_score_W_discrete 0.5427299725008815
# test_discrete_score_W_discrete 0.6854320903643744
# neuron unit number: 190
# train_discrete_score_W0_n 0.6831550484167087
# train_discrete_score_W0 0.8003223527328626
# test_discrete_score_W0_n 0.5137492889462185
# test_discrete_score_W0 0.6544070323826314
# train_discrete_score_W_discrete 0.6899819696464609
# train_discrete_score_W_discrete 0.8052432960222413
# test_discrete_score_W_discrete 0.4830988711540937
# test_discrete_score_W_discrete 0.6072813590138564
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 195
# train_discrete_score_W0_n 0.6911581237462103
# train_discrete_score_W0 0.8051300822111522
# test_discrete_score_W0_n 0.5867750159300696
# test_discrete_score_W0 0.7403733710150424
# train_discrete_score_W_discrete 0.6823985917892547
# train_discrete_score_W_discrete 0.8004359109144292
# test_discrete_score_W_discrete 0.5391929516226899
# test_discrete_score_W_discrete 0.6731836377786408
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 200
# train_discrete_score_W0_n 0.6506191291573669
# train_discrete_score_W0 0.7702350590796179
# test_discrete_score_W0_n 0.5506799600702078
# test_discrete_score_W0 0.6899162376977519
# train_discrete_score_W_discrete 0.6061584571580644
# train_discrete_score_W_discrete 0.737644089727648
# test_discrete_score_W_discrete 0.5124696835053147
# test_discrete_score_W_discrete 0.6286353261716903
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 205
# train_discrete_score_W0_n 0.6939213220832761
# train_discrete_score_W0 0.8107131482527165
# test_discrete_score_W0_n 0.46945814589332036
# test_discrete_score_W0 0.59530114079272
# train_discrete_score_W_discrete 0.6907835985931209
# train_discrete_score_W_discrete 0.799728972450559
# test_discrete_score_W_discrete 0.6066810860760122
# test_discrete_score_W_discrete 0.7446927899155436
# neuron unit number: 210
# train_discrete_score_W0_n 0.6765041817856248
# train_discrete_score_W0 0.7954188455012254
# test_discrete_score_W0_n 0.48935628359627653
# test_discrete_score_W0 0.6416831382521686
# train_discrete_score_W_discrete 0.6572815379975561
# train_discrete_score_W_discrete 0.781052815357843
# test_discrete_score_W_discrete 0.5170432181638466
# test_discrete_score_W_discrete 0.6701629703004152
# neuron unit number: 215
# train_discrete_score_W0_n 0.6702827304485972
# train_discrete_score_W0 0.7912107769177068
# test_discrete_score_W0_n 0.5029192560520906
# test_discrete_score_W0 0.5999870903425004
# train_discrete_score_W_discrete 0.7550862454943247
# train_discrete_score_W_discrete 0.8560167660719277
# test_discrete_score_W_discrete 0.644646154051302
# test_discrete_score_W_discrete 0.7544321803956693
# neuron unit number: 220
# train_discrete_score_W0_n 0.6685100706402355
# train_discrete_score_W0 0.7850402472708164
# test_discrete_score_W0_n 0.5414976159790623
# test_discrete_score_W0 0.6643720400477254
# train_discrete_score_W_discrete 0.664209027182591
# train_discrete_score_W_discrete 0.7855428761926753
# test_discrete_score_W_discrete 0.5978235267039466
# test_discrete_score_W_discrete 0.7252280454680533
# neuron unit number: 225
# train_discrete_score_W0_n 0.7198776702042531
# train_discrete_score_W0 0.830694154436329
# test_discrete_score_W0_n 0.5960307684349339
# test_discrete_score_W0 0.7130830088695653
# train_discrete_score_W_discrete 0.6831550484167087
# train_discrete_score_W_discrete 0.8003223527328626
# test_discrete_score_W_discrete 0.45852521395717777
# test_discrete_score_W_discrete 0.5999204720696379
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 230
# train_discrete_score_W0_n 0.6255167626265794
# train_discrete_score_W0 0.7525760261514041
# test_discrete_score_W0_n 0.534821356086568
# test_discrete_score_W0 0.6547890653323157
# train_discrete_score_W_discrete 0.7072716068421939
# train_discrete_score_W_discrete 0.8205229915255673
# test_discrete_score_W_discrete 0.4633856113135939
# test_discrete_score_W_discrete 0.6194411777686051
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 235
# train_discrete_score_W0_n 0.6776002222842928
# train_discrete_score_W0 0.7897907109330679
# test_discrete_score_W0_n 0.4772074631904445
# test_discrete_score_W0 0.5982701791600156
# train_discrete_score_W_discrete 0.6876939764669457
# train_discrete_score_W_discrete 0.8056796181884821
# test_discrete_score_W_discrete 0.5512602888977355
# test_discrete_score_W_discrete 0.6454104926663206
# neuron unit number: 240
# train_discrete_score_W0_n 0.6706877551272656
# train_discrete_score_W0 0.7904135371541926
# test_discrete_score_W0_n 0.3523475387375797
# test_discrete_score_W0 0.4918560607035182
# train_discrete_score_W_discrete 0.6879222372872533
# train_discrete_score_W_discrete 0.8055730068422489
# test_discrete_score_W_discrete 0.5275084034018531
# test_discrete_score_W_discrete 0.6478147740028101
# neuron unit number: 245
# train_discrete_score_W0_n 0.7131755140505092
# train_discrete_score_W0 0.8256982811101915
# test_discrete_score_W0_n 0.5046393025842951
# test_discrete_score_W0 0.6189398001745655
# train_discrete_score_W_discrete 0.6706877551272656
# train_discrete_score_W_discrete 0.7904135371541926
# test_discrete_score_W_discrete 0.48520567348389554
# test_discrete_score_W_discrete 0.6168384042134496
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 250
# train_discrete_score_W0_n 0.6287456474529606
# train_discrete_score_W0 0.7562751859925645
# test_discrete_score_W0_n 0.4347840466565048
# test_discrete_score_W0 0.5955571131049799
# train_discrete_score_W_discrete 0.6561431589781156
# train_discrete_score_W_discrete 0.7645392068629427
# test_discrete_score_W_discrete 0.518775387108523
# test_discrete_score_W_discrete 0.625756107913313
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.652101  0.036372  0.006533   0.638760  0.665442
# 1  train_dis_W_dis  31.0  0.673658  0.048536  0.008717   0.655855  0.691461
# 2         combined  62.0  0.662879  0.043901  0.005575   0.651731  0.674028
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0216
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.9789
# 3                        Two side test p value =    0.0524
# 4                       Difference < 0 p value =    0.0262
# 5                       Difference > 0 p value =    0.9738
# 6                                    Cohen's d =   -0.5026
# 7                                    Hedge's g =   -0.4963
# 8                                Glass's delta =   -0.5927
# 9                                  Pearson's r =    0.2475
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.527508  0.059502  0.010687   0.505683  0.549334
# 1  test_dis_W_dis  31.0  0.557044  0.066910  0.012017   0.532501  0.581587
# 2        combined  62.0  0.542276  0.064534  0.008196   0.525888  0.558665
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0295
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -1.8366
# 3                      Two side test p value =    0.0712
# 4                     Difference < 0 p value =    0.0356
# 5                     Difference > 0 p value =    0.9644
# 6                                  Cohen's d =   -0.4665
# 7                                  Hedge's g =   -0.4606
# 8                              Glass's delta =   -0.4964
# 9                                Pearson's r =    0.2307
# ARI T-Test
#           Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.77437  0.030153  0.005416   0.763310  0.785430
# 1  train_dis_W_dis  31.0  0.79117  0.039798  0.007148   0.776572  0.805768
# 2         combined  62.0  0.78277  0.036025  0.004575   0.773621  0.791919
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0168
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.8733
# 3                        Two side test p value =    0.0659
# 4                       Difference < 0 p value =    0.0329
# 5                       Difference > 0 p value =    0.9671
# 6                                    Cohen's d =   -0.4758
# 7                                    Hedge's g =   -0.4699
# 8                                Glass's delta =   -0.5572
# 9                                  Pearson's r =    0.2351
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.665378  0.059123  0.010619   0.643691  0.687065
# 1  test_dis_W_dis  31.0  0.688807  0.063637  0.011430   0.665465  0.712149
# 2        combined  62.0  0.677093  0.062050  0.007880   0.661335  0.692850
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0234
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -1.5017
# 3                      Two side test p value =    0.1384
# 4                     Difference < 0 p value =    0.0692
# 5                     Difference > 0 p value =    0.9308
# 6                                  Cohen's d =   -0.3814
# 7                                  Hedge's g =   -0.3767
# 8                              Glass's delta =   -0.3963
# 9                                Pearson's r =    0.1903
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
