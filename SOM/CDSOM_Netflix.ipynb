# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])

dataread.stringToIntNetflixDataSet(csv,"Subscription Type")
dataread.stringToIntNetflixDataSet(csv,"Monthly Revenue")
dataread.stringToIntNetflixDataSet(csv,"Join Date")
dataread.stringToIntNetflixDataSet(csv,"Last Payment Date")
dataread.stringToIntNetflixDataSet(csv,"Country")
dataread.stringToIntNetflixDataSet(csv,"Gender")
dataread.stringToIntNetflixDataSet(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")

#print(dataread.data_test)

#print(dataread.data_test_discrete_after_transfer)
# Out:
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 10.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# Unkonwn value 15.0 type <class 'str'>
# Unkonwn value 13.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 11.0 type <class 'str'>
# Unkonwn value 12.0 type <class 'str'>
# Unkonwn value 14.0 type <class 'str'>
# ...
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45114.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45115.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45116.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45117.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45120.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45118.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45121.0 type <class 'str'>
# Unkonwn value 45122.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
# Unkonwn value 45119.0 type <class 'str'>
#  column number self.data_train_discrete 4

# %%
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 200
class_num = 100
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,0)
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,1)
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,2)
# Out:
# neuron unit number: 100
# train_continuous_score_W0_n 0.03486747092067834
# train_continuous_score_W0_a 0.04058211317630067
# test_continuous_score_W0_n 0.00883680451752471
# test_continuous_score_W0_a 0.001365916216382491
# train_continuous_score_W_continuous_n 0.12163929055062801
# train_continuous_score_W_continuous_a 0.14964815850773006
# test_continuous_score_W_continuous_n 0.019266033317337294
# test_continuous_score_W_continuous_a 0.020670708521402355
# New Continuous Feateure Neurons Number :0
# neuron unit number: 105
# train_continuous_score_W0_n 0.03078522683839926
# train_continuous_score_W0_a 0.04147461122934115
# test_continuous_score_W0_n 0.0038954674343005392
# test_continuous_score_W0_a 0.0004164439155255229
# train_continuous_score_W_continuous_n 0.1081017244556734
# train_continuous_score_W_continuous_a 0.1304815148398338
# test_continuous_score_W_continuous_n 0.03019970544370377
# test_continuous_score_W_continuous_a 0.031053500797349386
# New Continuous Feateure Neurons Number :0
# neuron unit number: 110
# train_continuous_score_W0_n 0.03756559397933193
# train_continuous_score_W0_a 0.04671484595732289
# test_continuous_score_W0_n 0.003133924978356119
# test_continuous_score_W0_a -0.0003124461586053695
# train_continuous_score_W_continuous_n 0.12056970645820868
# train_continuous_score_W_continuous_a 0.1450316654141983
# test_continuous_score_W_continuous_n 0.02526570450987933
# test_continuous_score_W_continuous_a 0.027109202278868705
# New Continuous Feateure Neurons Number :0
# neuron unit number: 115
# train_continuous_score_W0_n 0.045855784646447344
# train_continuous_score_W0_a 0.055842565808298994
# test_continuous_score_W0_n 0.01304929528371202
# test_continuous_score_W0_a 0.006348936746216553
# train_continuous_score_W_continuous_n 0.14004581504505734
# train_continuous_score_W_continuous_a 0.16204193138558937
# test_continuous_score_W_continuous_n 0.05737414205840952
# test_continuous_score_W_continuous_a 0.05905113328552091
# New Continuous Feateure Neurons Number :0
# neuron unit number: 120
# train_continuous_score_W0_n 0.0465456824084241
# train_continuous_score_W0_a 0.05725700931466672
# test_continuous_score_W0_n 0.003141934513541401
# test_continuous_score_W0_a 0.000980118736223457
# train_continuous_score_W_continuous_n 0.13169071656288076
# train_continuous_score_W_continuous_a 0.1558714951415438
# test_continuous_score_W_continuous_n 0.05174925361398066
# test_continuous_score_W_continuous_a 0.06316257292227147
# New Continuous Feateure Neurons Number :0
# neuron unit number: 125
# train_continuous_score_W0_n 0.03733286846930264
# train_continuous_score_W0_a 0.044666557551941086
# test_continuous_score_W0_n 0.008265924881435982
# test_continuous_score_W0_a 0.005099310823499002
# train_continuous_score_W_continuous_n 0.1420162826354055
# train_continuous_score_W_continuous_a 0.16912583714487833
# test_continuous_score_W_continuous_n 0.038895301468118766
# test_continuous_score_W_continuous_a 0.038687193748514065
# New Continuous Feateure Neurons Number :0
# neuron unit number: 130
# train_continuous_score_W0_n 0.03575867731952213
# train_continuous_score_W0_a 0.04542158725235777
# test_continuous_score_W0_n 0.010246196075245058
# test_continuous_score_W0_a 0.006017521639008018
# train_continuous_score_W_continuous_n 0.12845053634087616
# train_continuous_score_W_continuous_a 0.1540008554525155
# test_continuous_score_W_continuous_n 0.04168387723844029
# test_continuous_score_W_continuous_a 0.0472168246053353
# New Continuous Feateure Neurons Number :0
# neuron unit number: 135
# train_continuous_score_W0_n 0.04337381512663017
# train_continuous_score_W0_a 0.050292197884078176
# test_continuous_score_W0_n 0.007719185208307667
# test_continuous_score_W0_a 0.0063310883700340255
# train_continuous_score_W_continuous_n 0.130868705330197
# train_continuous_score_W_continuous_a 0.1569263035811922
# test_continuous_score_W_continuous_n 0.03588790039703193
# test_continuous_score_W_continuous_a 0.03396980770319287
# New Continuous Feateure Neurons Number :0
# neuron unit number: 140
# train_continuous_score_W0_n 0.04289088431170284
# train_continuous_score_W0_a 0.05438601274010623
# test_continuous_score_W0_n 0.012104959958217379
# test_continuous_score_W0_a 0.007886155766773555
# train_continuous_score_W_continuous_n 0.12776762276821915
# train_continuous_score_W_continuous_a 0.14790708139015085
# test_continuous_score_W_continuous_n 0.054296419959030735
# test_continuous_score_W_continuous_a 0.06912969802819385
# New Continuous Feateure Neurons Number :0
# neuron unit number: 145
# train_continuous_score_W0_n 0.04683461444756758
# train_continuous_score_W0_a 0.058594648741439936
# test_continuous_score_W0_n 0.011675863525182616
# test_continuous_score_W0_a 0.0012494587028893517
# train_continuous_score_W_continuous_n 0.14352781703910672
# train_continuous_score_W_continuous_a 0.16695880319885906
# test_continuous_score_W_continuous_n 0.03190490482730028
# test_continuous_score_W_continuous_a 0.027924424657110668
# New Continuous Feateure Neurons Number :0
# neuron unit number: 150
# train_continuous_score_W0_n 0.05207215578528623
# train_continuous_score_W0_a 0.06204664742253684
# test_continuous_score_W0_n 0.007900716599330983
# test_continuous_score_W0_a 0.0037564671083294273
# train_continuous_score_W_continuous_n 0.14965340018785056
# train_continuous_score_W_continuous_a 0.17788810740336525
# test_continuous_score_W_continuous_n 0.051491061048501145
# test_continuous_score_W_continuous_a 0.04764001938242868
# New Continuous Feateure Neurons Number :0
# neuron unit number: 155
# train_continuous_score_W0_n 0.04756440364204602
# train_continuous_score_W0_a 0.05845933679536289
# test_continuous_score_W0_n 0.004739201015239605
# test_continuous_score_W0_a 0.0034454227321725583
# train_continuous_score_W_continuous_n 0.14298541484233854
# train_continuous_score_W_continuous_a 0.16782040669365147
# test_continuous_score_W_continuous_n 0.04755109058117473
# test_continuous_score_W_continuous_a 0.041905357911996816
# New Continuous Feateure Neurons Number :0
# neuron unit number: 160
# train_continuous_score_W0_n 0.053587975141900314
# train_continuous_score_W0_a 0.06901424052041771
# test_continuous_score_W0_n 0.005532233428178693
# test_continuous_score_W0_a 0.0030706023571907765
# train_continuous_score_W_continuous_n 0.15628915848508987
# train_continuous_score_W_continuous_a 0.1820851128772979
# test_continuous_score_W_continuous_n 0.05094585654415289
# test_continuous_score_W_continuous_a 0.051260230855261206
# New Continuous Feateure Neurons Number :0
# neuron unit number: 165
# train_continuous_score_W0_n 0.056530146411714874
# train_continuous_score_W0_a 0.06806656065013582
# test_continuous_score_W0_n 0.0029510962780689987
# test_continuous_score_W0_a -0.0006381484389308058
# train_continuous_score_W_continuous_n 0.14273825593675962
# train_continuous_score_W_continuous_a 0.17233401600629328
# test_continuous_score_W_continuous_n 0.03574378987212792
# test_continuous_score_W_continuous_a 0.04031250379011426
# New Continuous Feateure Neurons Number :0
# neuron unit number: 170
# train_continuous_score_W0_n 0.04959911335942691
# train_continuous_score_W0_a 0.0625622357633028
# test_continuous_score_W0_n 0.01337256695313028
# test_continuous_score_W0_a 0.015166595394038576
# train_continuous_score_W_continuous_n 0.16509497586556682
# train_continuous_score_W_continuous_a 0.19590244168883722
# test_continuous_score_W_continuous_n 0.06299279140332939
# test_continuous_score_W_continuous_a 0.06933776106513807
# New Continuous Feateure Neurons Number :0
# neuron unit number: 175
# train_continuous_score_W0_n 0.05405350010451758
# train_continuous_score_W0_a 0.060028553914739394
# test_continuous_score_W0_n 0.006454121922520526
# test_continuous_score_W0_a 0.0020200267294924325
# train_continuous_score_W_continuous_n 0.16064243153810384
# train_continuous_score_W_continuous_a 0.18839613253234933
# test_continuous_score_W_continuous_n 0.046174383901981544
# test_continuous_score_W_continuous_a 0.049802032440871315
# New Continuous Feateure Neurons Number :0
# neuron unit number: 180
# train_continuous_score_W0_n 0.0605612230378195
# train_continuous_score_W0_a 0.07525131662151119
# test_continuous_score_W0_n 0.0078868865661756
# test_continuous_score_W0_a 0.005682601317727637
# train_continuous_score_W_continuous_n 0.1545235922065049
# train_continuous_score_W_continuous_a 0.18398108085147125
# test_continuous_score_W_continuous_n 0.06520642607706091
# test_continuous_score_W_continuous_a 0.06832237488670066
# New Continuous Feateure Neurons Number :0
# neuron unit number: 185
# train_continuous_score_W0_n 0.0642091861929969
# train_continuous_score_W0_a 0.0732106592430692
# test_continuous_score_W0_n 0.01884504844381165
# test_continuous_score_W0_a 0.009839865006616846
# train_continuous_score_W_continuous_n 0.1599591885289948
# train_continuous_score_W_continuous_a 0.18332905783476236
# test_continuous_score_W_continuous_n 0.05695126308834322
# test_continuous_score_W_continuous_a 0.06543917958323908
# New Continuous Feateure Neurons Number :0
# neuron unit number: 190
# train_continuous_score_W0_n 0.06199586564630266
# train_continuous_score_W0_a 0.07495055401659668
# test_continuous_score_W0_n 0.019902627072236993
# test_continuous_score_W0_a 0.01896376150973932
# train_continuous_score_W_continuous_n 0.1751438396903504
# train_continuous_score_W_continuous_a 0.20102666478674175
# test_continuous_score_W_continuous_n 0.06714848342185051
# test_continuous_score_W_continuous_a 0.07123054645697939
# New Continuous Feateure Neurons Number :0
# neuron unit number: 195
# train_continuous_score_W0_n 0.0665289723505174
# train_continuous_score_W0_a 0.07582937703498371
# test_continuous_score_W0_n 0.01037994050834089
# test_continuous_score_W0_a 0.0018784321087176197
# train_continuous_score_W_continuous_n 0.17028281072043322
# train_continuous_score_W_continuous_a 0.19649335357259914
# test_continuous_score_W_continuous_n 0.05570928623926158
# test_continuous_score_W_continuous_a 0.06140832399155074
# New Continuous Feateure Neurons Number :0
# neuron unit number: 200
# train_continuous_score_W0_n 0.07143626269694436
# train_continuous_score_W0_a 0.08243383981166004
# test_continuous_score_W0_n 0.012025929768176609
# test_continuous_score_W0_a 0.006666240049987617
# train_continuous_score_W_continuous_n 0.15630556865553816
# train_continuous_score_W_continuous_a 0.17672304819776183
# test_continuous_score_W_continuous_n 0.03899365182248003
# test_continuous_score_W_continuous_a 0.04710824345855266
# New Continuous Feateure Neurons Number :0
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  21.0  0.049521  0.011219  0.002448   0.044415  0.054628
# 1  train_con_W_con  21.0  0.144205  0.017707  0.003864   0.136144  0.152265
# 2         combined  42.0  0.096863  0.050102  0.007731   0.081250  0.112476
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.0947
# 1                           Degrees of freedom =   40.0000
# 2                                            t =  -20.6989
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -6.3878
# 7                                    Hedge's g =   -6.2673
# 8                                Glass's delta =   -8.4397
# 9                                  Pearson's r =    0.9564
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  21.0  0.009146  0.004759  0.001039   0.006979  0.011312
# 1  test_con_W_con  21.0  0.045973  0.013278  0.002897   0.039929  0.052017
# 2        combined  42.0  0.027559  0.021080  0.003253   0.020990  0.034128
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =   -0.0368
# 1                         Degrees of freedom =   40.0000
# 2                                          t =  -11.9649
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.6925
# 7                                  Hedge's g =   -3.6228
# 8                              Glass's delta =   -7.7384
# 9                                Pearson's r =    0.8841
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  21.0  0.059861  0.012330  0.002691   0.054249  0.065474
# 1  train_con_W_con  21.0  0.169713  0.018836  0.004110   0.161139  0.178287
# 2         combined  42.0  0.114787  0.057773  0.008915   0.096784  0.132790
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.1099
# 1                           Degrees of freedom =   40.0000
# 2                                            t =  -22.3606
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -6.9006
# 7                                    Hedge's g =   -6.7704
# 8                                Glass's delta =   -8.9095
# 9                                  Pearson's r =    0.9623
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  21.0  0.005011  0.004943  0.001079   0.002761  0.007261
# 1  test_con_W_con  21.0  0.049131  0.015704  0.003427   0.041982  0.056279
# 2        combined  42.0  0.027071  0.025114  0.003875   0.019245  0.034897
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =   -0.0441
# 1                         Degrees of freedom =   40.0000
# 2                                          t =  -12.2804
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.7898
# 7                                  Hedge's g =   -3.7183
# 8                              Glass's delta =   -8.9250
# 9                                Pearson's r =    0.8890
# neuron unit number: 100
# train_continuous_score_W0_n 0.09916819779102987
# train_continuous_score_W0_a 0.11645512641568223
# test_continuous_score_W0_n 0.06342333969800439
# test_continuous_score_W0_a 0.06645974159914707
# train_continuous_score_W_continuous_n 0.1636274502526128
# train_continuous_score_W_continuous_a 0.18924838957946588
# test_continuous_score_W_continuous_n 0.08015672796408017
# test_continuous_score_W_continuous_a 0.08801215866606527
# New Continuous Feateure Neurons Number :0
# neuron unit number: 105
# train_continuous_score_W0_n 0.12679502623565297
# train_continuous_score_W0_a 0.1373262518173846
# test_continuous_score_W0_n 0.10441125983221355
# test_continuous_score_W0_a 0.11339817207553653
# train_continuous_score_W_continuous_n 0.18739280657851945
# train_continuous_score_W_continuous_a 0.2165458777304804
# test_continuous_score_W_continuous_n 0.1284256818124202
# test_continuous_score_W_continuous_a 0.14990654122006317
# New Continuous Feateure Neurons Number :0
# neuron unit number: 110
# train_continuous_score_W0_n 0.12047885789943931
# train_continuous_score_W0_a 0.1269632946559683
# test_continuous_score_W0_n 0.06983428727310682
# test_continuous_score_W0_a 0.07447945501828955
# train_continuous_score_W_continuous_n 0.1793206714634021
# train_continuous_score_W_continuous_a 0.20532990494749578
# test_continuous_score_W_continuous_n 0.10884190880502977
# test_continuous_score_W_continuous_a 0.12632400235964664
# New Continuous Feateure Neurons Number :0
# neuron unit number: 115
# train_continuous_score_W0_n 0.10231500457608338
# train_continuous_score_W0_a 0.11598150903193205
# test_continuous_score_W0_n 0.07121514799337128
# test_continuous_score_W0_a 0.07583558165420355
# train_continuous_score_W_continuous_n 0.18208715695028363
# train_continuous_score_W_continuous_a 0.19522174906650092
# test_continuous_score_W_continuous_n 0.11327541809455764
# test_continuous_score_W_continuous_a 0.11151369834558948
# New Continuous Feateure Neurons Number :0
# neuron unit number: 120
# train_continuous_score_W0_n 0.13408502941865302
# train_continuous_score_W0_a 0.1490960893260761
# test_continuous_score_W0_n 0.11129423724538871
# test_continuous_score_W0_a 0.11751956643903234
# train_continuous_score_W_continuous_n 0.1996117504289017
# train_continuous_score_W_continuous_a 0.2188430347343945
# test_continuous_score_W_continuous_n 0.1499048145775095
# test_continuous_score_W_continuous_a 0.15766600531437117
# New Continuous Feateure Neurons Number :0
# neuron unit number: 125
# train_continuous_score_W0_n 0.0993793428818176
# train_continuous_score_W0_a 0.10676001194117106
# test_continuous_score_W0_n 0.08295851347977207
# test_continuous_score_W0_a 0.08597453644717062
# train_continuous_score_W_continuous_n 0.15657967387875119
# train_continuous_score_W_continuous_a 0.17222424847070533
# test_continuous_score_W_continuous_n 0.11215878236679434
# test_continuous_score_W_continuous_a 0.10507295105882282
# New Continuous Feateure Neurons Number :0
# neuron unit number: 130
# train_continuous_score_W0_n 0.129601380445039
# train_continuous_score_W0_a 0.15221372310796208
# test_continuous_score_W0_n 0.12070895490193032
# test_continuous_score_W0_a 0.1390999461129544
# train_continuous_score_W_continuous_n 0.1737784554151514
# train_continuous_score_W_continuous_a 0.2017241341577356
# test_continuous_score_W_continuous_n 0.1293755049824801
# test_continuous_score_W_continuous_a 0.14619560876666093
# New Continuous Feateure Neurons Number :0
# neuron unit number: 135
# train_continuous_score_W0_n 0.16109932091852852
# train_continuous_score_W0_a 0.15972118685914985
# test_continuous_score_W0_n 0.11021970473021499
# test_continuous_score_W0_a 0.09798964759921538
# train_continuous_score_W_continuous_n 0.20964637951915774
# train_continuous_score_W_continuous_a 0.22007231225369336
# test_continuous_score_W_continuous_n 0.1505979562800374
# test_continuous_score_W_continuous_a 0.1510303408289699
# New Continuous Feateure Neurons Number :0
# neuron unit number: 140
# train_continuous_score_W0_n 0.14197189468021132
# train_continuous_score_W0_a 0.15375708252944342
# test_continuous_score_W0_n 0.10926545928269113
# test_continuous_score_W0_a 0.1195650963210313
# train_continuous_score_W_continuous_n 0.1943076162063791
# train_continuous_score_W_continuous_a 0.21271952123192894
# test_continuous_score_W_continuous_n 0.12217439456530632
# test_continuous_score_W_continuous_a 0.13259519750898596
# New Continuous Feateure Neurons Number :0
# neuron unit number: 145
# train_continuous_score_W0_n 0.10025708656537106
# train_continuous_score_W0_a 0.10110892648913346
# test_continuous_score_W0_n 0.0594112082626932
# test_continuous_score_W0_a 0.05402996932368972
# train_continuous_score_W_continuous_n 0.1586243664118968
# train_continuous_score_W_continuous_a 0.17541756788307816
# test_continuous_score_W_continuous_n 0.09343468648004337
# test_continuous_score_W_continuous_a 0.1022213775678143
# New Continuous Feateure Neurons Number :0
# neuron unit number: 150
# train_continuous_score_W0_n 0.12625233480551262
# train_continuous_score_W0_a 0.14297903555870142
# test_continuous_score_W0_n 0.10186629282864432
# test_continuous_score_W0_a 0.10546362254785124
# train_continuous_score_W_continuous_n 0.17369776540251383
# train_continuous_score_W_continuous_a 0.19215345701394193
# test_continuous_score_W_continuous_n 0.10040648829703788
# test_continuous_score_W_continuous_a 0.09646102571458187
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 155
# train_continuous_score_W0_n 0.1102756561518907
# train_continuous_score_W0_a 0.11490842066306127
# test_continuous_score_W0_n 0.08789067579683019
# test_continuous_score_W0_a 0.08419173060608018
# train_continuous_score_W_continuous_n 0.1672557817113334
# train_continuous_score_W_continuous_a 0.18954567191050334
# test_continuous_score_W_continuous_n 0.09837914971546341
# test_continuous_score_W_continuous_a 0.1043902680567486
# New Continuous Feateure Neurons Number :0
# neuron unit number: 160
# train_continuous_score_W0_n 0.1506140401474704
# train_continuous_score_W0_a 0.1667425469850731
# test_continuous_score_W0_n 0.10782282417492967
# test_continuous_score_W0_a 0.11326308455913676
# train_continuous_score_W_continuous_n 0.18469030272867215
# train_continuous_score_W_continuous_a 0.21385476364068365
# test_continuous_score_W_continuous_n 0.11007754399805733
# test_continuous_score_W_continuous_a 0.12213436679343095
# New Continuous Feateure Neurons Number :0
# neuron unit number: 165
# train_continuous_score_W0_n 0.14358058007779181
# train_continuous_score_W0_a 0.15442747713319832
# test_continuous_score_W0_n 0.11707668452436633
# test_continuous_score_W0_a 0.11634792007268502
# train_continuous_score_W_continuous_n 0.17792733966471566
# train_continuous_score_W_continuous_a 0.20046101800049915
# test_continuous_score_W_continuous_n 0.11213533679305274
# test_continuous_score_W_continuous_a 0.12396707988360946
# Not good nmi result for continuous features !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 170
# train_continuous_score_W0_n 0.11555433321342544
# train_continuous_score_W0_a 0.11654849139585216
# test_continuous_score_W0_n 0.08493487724961438
# test_continuous_score_W0_a 0.08352966923330879
# train_continuous_score_W_continuous_n 0.1937685013801061
# train_continuous_score_W_continuous_a 0.21897610904296202
# test_continuous_score_W_continuous_n 0.12406968914939162
# test_continuous_score_W_continuous_a 0.13126450436715395
# New Continuous Feateure Neurons Number :0
# neuron unit number: 175
# train_continuous_score_W0_n 0.14741601666424467
# train_continuous_score_W0_a 0.15771599754423535
# test_continuous_score_W0_n 0.08826966234982382
# test_continuous_score_W0_a 0.09361609260383094
# train_continuous_score_W_continuous_n 0.1872613897164484
# train_continuous_score_W_continuous_a 0.20707345159839738
# test_continuous_score_W_continuous_n 0.1051800309850915
# test_continuous_score_W_continuous_a 0.11300304841160043
# New Continuous Feateure Neurons Number :0
# neuron unit number: 180
# train_continuous_score_W0_n 0.13382258840609826
# train_continuous_score_W0_a 0.14561674422220816
# test_continuous_score_W0_n 0.10374811969665704
# test_continuous_score_W0_a 0.11172112833548599
# train_continuous_score_W_continuous_n 0.18681785844032167
# train_continuous_score_W_continuous_a 0.20274253572524886
# test_continuous_score_W_continuous_n 0.12431267024279621
# test_continuous_score_W_continuous_a 0.1318882419733089
# New Continuous Feateure Neurons Number :0
# neuron unit number: 185
# train_continuous_score_W0_n 0.07745542808885361
# train_continuous_score_W0_a 0.08326026536623009
# test_continuous_score_W0_n 0.08542431775327392
# test_continuous_score_W0_a 0.08221914501760029
# train_continuous_score_W_continuous_n 0.176784787829794
# train_continuous_score_W_continuous_a 0.19620148953519
# test_continuous_score_W_continuous_n 0.13468621858402954
# test_continuous_score_W_continuous_a 0.14622318425527622
# New Continuous Feateure Neurons Number :0
# neuron unit number: 190
# train_continuous_score_W0_n 0.1304216553364524
# train_continuous_score_W0_a 0.14238548870591003
# test_continuous_score_W0_n 0.10378658270832095
# test_continuous_score_W0_a 0.09766699811321296
# train_continuous_score_W_continuous_n 0.1870044342730752
# train_continuous_score_W_continuous_a 0.21155565631378898
# test_continuous_score_W_continuous_n 0.11093054060729947
# test_continuous_score_W_continuous_a 0.12145995840408665
# New Continuous Feateure Neurons Number :0
# neuron unit number: 195
# train_continuous_score_W0_n 0.13457645513326075
# train_continuous_score_W0_a 0.14392959659921067
# test_continuous_score_W0_n 0.10260661207210774
# test_continuous_score_W0_a 0.09815333348675707
# train_continuous_score_W_continuous_n 0.18483558699793456
# train_continuous_score_W_continuous_a 0.20574676897752997
# test_continuous_score_W_continuous_n 0.117150213156397
# test_continuous_score_W_continuous_a 0.12488143185949686
# New Continuous Feateure Neurons Number :0
# neuron unit number: 200
# train_continuous_score_W0_n 0.12279677900022204
# train_continuous_score_W0_a 0.1410144501459234
# test_continuous_score_W0_n 0.08138168913076524
# test_continuous_score_W0_a 0.078754587105027
# train_continuous_score_W_continuous_n 0.18450609820666525
# train_continuous_score_W_continuous_a 0.207001457246573
# test_continuous_score_W_continuous_n 0.10921656146352317
# test_continuous_score_W_continuous_a 0.11727748303927588
# New Continuous Feateure Neurons Number :0
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  21.0  0.124187  0.020532  0.004480   0.114841  0.133532
# 1  train_con_W_con  21.0  0.181406  0.013074  0.002853   0.175455  0.187357
# 2         combined  42.0  0.152796  0.033578  0.005181   0.142333  0.163260
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.0572
# 1                           Degrees of freedom =   40.0000
# 2                                            t =  -10.7725
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.3245
# 7                                    Hedge's g =   -3.2617
# 8                                Glass's delta =   -2.7869
# 9                                  Pearson's r =    0.8624
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  21.0  0.093693  0.017898  0.003906   0.085546  0.101840
# 1  test_con_W_con  21.0  0.115947  0.017121  0.003736   0.108154  0.123740
# 2        combined  42.0  0.104820  0.020642  0.003185   0.098388  0.111252
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =   -0.0223
# 1                         Degrees of freedom =   40.0000
# 2                                          t =   -4.1175
# 3                      Two side test p value =    0.0002
# 4                     Difference < 0 p value =    0.0001
# 5                     Difference > 0 p value =    0.9999
# 6                                  Cohen's d =   -1.2707
# 7                                  Hedge's g =   -1.2467
# 8                              Glass's delta =   -1.2434
# 9                                Pearson's r =    0.5456
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  21.0  0.134710  0.022189  0.004842   0.124610   0.14481
# 1  train_con_W_con  21.0  0.202508  0.013449  0.002935   0.196385   0.20863
# 2         combined  42.0  0.168609  0.038802  0.005987   0.156517   0.18070
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.0678
# 1                           Degrees of freedom =   40.0000
# 2                                            t =  -11.9740
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.6953
# 7                                    Hedge's g =   -3.6255
# 8                                Glass's delta =   -3.0555
# 9                                  Pearson's r =    0.8842
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  21.0  0.095680  0.020771  0.004533   0.086225  0.105135
# 1  test_con_W_con  21.0  0.123976  0.019130  0.004175   0.115268  0.132684
# 2        combined  42.0  0.109828  0.024373  0.003761   0.102233  0.117423
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =   -0.0283
# 1                         Degrees of freedom =   40.0000
# 2                                          t =   -4.5918
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.4171
# 7                                  Hedge's g =   -1.3903
# 8                              Glass's delta =   -1.3622
# 9                                Pearson's r =    0.5875
# neuron unit number: 100
# train_continuous_score_W0_n 0.12491166484734476
# train_continuous_score_W0_a 0.13519548663446745
# test_continuous_score_W0_n 0.1058275957844246
# test_continuous_score_W0_a 0.10289828377845046
# train_continuous_score_W_continuous_n 0.12422142040304429
# train_continuous_score_W_continuous_a 0.14284702724586873
# test_continuous_score_W_continuous_n 0.04069525766221554
# test_continuous_score_W_continuous_a 0.04022465743138971
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 105
# train_continuous_score_W0_n 0.12802569599555663
# train_continuous_score_W0_a 0.1285024613502862
# test_continuous_score_W0_n 0.08110025590769081
# test_continuous_score_W0_a 0.07250095376697847
# train_continuous_score_W_continuous_n 0.11350075338356347
# train_continuous_score_W_continuous_a 0.13192061855388593
# test_continuous_score_W_continuous_n 0.021065782755365168
# test_continuous_score_W_continuous_a 0.020938666230699864
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 110
# train_continuous_score_W0_n 0.1066111180278841
# train_continuous_score_W0_a 0.11756476763509914
# test_continuous_score_W0_n 0.14497359671837587
# test_continuous_score_W0_a 0.15233500599743177
# train_continuous_score_W_continuous_n 0.11392860081382895
# train_continuous_score_W_continuous_a 0.13578744623805536
# test_continuous_score_W_continuous_n 0.03399930505903433
# test_continuous_score_W_continuous_a 0.03610741014180446
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 115
# train_continuous_score_W0_n 0.09998634983067858
# train_continuous_score_W0_a 0.10813351406268841
# test_continuous_score_W0_n 0.09606259014064032
# test_continuous_score_W0_a 0.10320972293178249
# train_continuous_score_W_continuous_n 0.11577926755028627
# train_continuous_score_W_continuous_a 0.1401006369875745
# test_continuous_score_W_continuous_n 0.05624039739988827
# test_continuous_score_W_continuous_a 0.05980540245605553
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 120
# train_continuous_score_W0_n 0.13317138249973484
# train_continuous_score_W0_a 0.1475717211437508
# test_continuous_score_W0_n 0.11019912179097441
# test_continuous_score_W0_a 0.1222041558520295
# train_continuous_score_W_continuous_n 0.10240639060613382
# train_continuous_score_W_continuous_a 0.12537019837514
# test_continuous_score_W_continuous_n 0.022994609033467336
# test_continuous_score_W_continuous_a 0.026304047857617953
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 125
# train_continuous_score_W0_n 0.12545898277256248
# train_continuous_score_W0_a 0.12807989046739726
# test_continuous_score_W0_n 0.0782536110516491
# test_continuous_score_W0_a 0.08047605508780993
# train_continuous_score_W_continuous_n 0.10514628070462474
# train_continuous_score_W_continuous_a 0.12358510843196077
# test_continuous_score_W_continuous_n 0.031497441506817624
# test_continuous_score_W_continuous_a 0.03454765346135569
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 130
# train_continuous_score_W0_n 0.10051518415631265
# train_continuous_score_W0_a 0.10748294328539618
# test_continuous_score_W0_n 0.07855656337179406
# test_continuous_score_W0_a 0.08128983172936452
# train_continuous_score_W_continuous_n 0.11360320432606844
# train_continuous_score_W_continuous_a 0.13815859930827812
# test_continuous_score_W_continuous_n 0.03316968119774412
# test_continuous_score_W_continuous_a 0.03783189037304751
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 135
# train_continuous_score_W0_n 0.12736470022994822
# train_continuous_score_W0_a 0.1361034234968878
# test_continuous_score_W0_n 0.12798353581083743
# test_continuous_score_W0_a 0.1423542072455301
# train_continuous_score_W_continuous_n 0.11030933800687127
# train_continuous_score_W_continuous_a 0.13231653019280448
# test_continuous_score_W_continuous_n 0.030287522371048987
# test_continuous_score_W_continuous_a 0.027972968411926768
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 140
# train_continuous_score_W0_n 0.12495346390869437
# train_continuous_score_W0_a 0.12678203287409684
# test_continuous_score_W0_n 0.09230457079445518
# test_continuous_score_W0_a 0.08472684376010953
# train_continuous_score_W_continuous_n 0.11890898638683572
# train_continuous_score_W_continuous_a 0.13799380473597242
# test_continuous_score_W_continuous_n 0.03461621224003632
# test_continuous_score_W_continuous_a 0.029720414297726924
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 145
# train_continuous_score_W0_n 0.08836492014038375
# train_continuous_score_W0_a 0.08187006173761209
# test_continuous_score_W0_n 0.07399557526597234
# test_continuous_score_W0_a 0.0659279344933981
# train_continuous_score_W_continuous_n 0.12628617499778702
# train_continuous_score_W_continuous_a 0.14170924662744772
# test_continuous_score_W_continuous_n 0.0318241189429704
# test_continuous_score_W_continuous_a 0.03499865804472694
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 150
# train_continuous_score_W0_n 0.14292285201151814
# train_continuous_score_W0_a 0.15598306186465416
# test_continuous_score_W0_n 0.0916739673759219
# test_continuous_score_W0_a 0.08813345224479399
# train_continuous_score_W_continuous_n 0.1323872075738224
# train_continuous_score_W_continuous_a 0.1500033728218608
# test_continuous_score_W_continuous_n 0.031157327839102487
# test_continuous_score_W_continuous_a 0.03246079588150919
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 155
# train_continuous_score_W0_n 0.10568598904766237
# train_continuous_score_W0_a 0.12637191484611995
# test_continuous_score_W0_n 0.06382387583846805
# test_continuous_score_W0_a 0.07298606592475665
# train_continuous_score_W_continuous_n 0.12597967315787323
# train_continuous_score_W_continuous_a 0.15161955366220062
# test_continuous_score_W_continuous_n 0.06563675173343744
# test_continuous_score_W_continuous_a 0.06803903617010243
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 160
# train_continuous_score_W0_n 0.18135318466190006
# train_continuous_score_W0_a 0.18756495977816068
# test_continuous_score_W0_n 0.15765900385915466
# test_continuous_score_W0_a 0.1459013426317925
# train_continuous_score_W_continuous_n 0.11872375524333005
# train_continuous_score_W_continuous_a 0.14326843291234934
# test_continuous_score_W_continuous_n 0.02634119513096838
# test_continuous_score_W_continuous_a 0.028611040937003864
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 165
# train_continuous_score_W0_n 0.1318082313481656
# train_continuous_score_W0_a 0.15328561207184896
# test_continuous_score_W0_n 0.09857481754547924
# test_continuous_score_W0_a 0.11668349349276484
# train_continuous_score_W_continuous_n 0.13460649744780415
# train_continuous_score_W_continuous_a 0.16321404889354088
# test_continuous_score_W_continuous_n 0.030547952704571276
# test_continuous_score_W_continuous_a 0.03152994554731814
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 170
# train_continuous_score_W0_n 0.15368166525026014
# train_continuous_score_W0_a 0.1729523348622868
# test_continuous_score_W0_n 0.10387975535482367
# test_continuous_score_W0_a 0.1124218300714668
# train_continuous_score_W_continuous_n 0.14200452144048792
# train_continuous_score_W_continuous_a 0.15982626892860938
# test_continuous_score_W_continuous_n 0.05862691180153033
# test_continuous_score_W_continuous_a 0.06056242455432538
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 175
# train_continuous_score_W0_n 0.11963365360350639
# train_continuous_score_W0_a 0.1240512962593326
# test_continuous_score_W0_n 0.1152373079205454
# test_continuous_score_W0_a 0.1159569762451954
# train_continuous_score_W_continuous_n 0.14603011022516954
# train_continuous_score_W_continuous_a 0.1710064463618497
# test_continuous_score_W_continuous_n 0.055458401743603336
# test_continuous_score_W_continuous_a 0.05626756791266861
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 180
# train_continuous_score_W0_n 0.13337765301876608
# train_continuous_score_W0_a 0.14590415170306134
# test_continuous_score_W0_n 0.09880938957425628
# test_continuous_score_W0_a 0.10959619512756288
# train_continuous_score_W_continuous_n 0.1426659040125201
# train_continuous_score_W_continuous_a 0.17239822398587737
# test_continuous_score_W_continuous_n 0.03480986865221055
# test_continuous_score_W_continuous_a 0.04131358989032295
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 185
# train_continuous_score_W0_n 0.10901601587042374
# train_continuous_score_W0_a 0.10776883406819522
# test_continuous_score_W0_n 0.0636633591436214
# test_continuous_score_W0_a 0.05673252277381553
# train_continuous_score_W_continuous_n 0.1305433504924067
# train_continuous_score_W_continuous_a 0.1595432615870661
# test_continuous_score_W_continuous_n 0.04252084289550685
# test_continuous_score_W_continuous_a 0.0447058418396673
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 190
# train_continuous_score_W0_n 0.1441491118941023
# train_continuous_score_W0_a 0.16086469589862187
# test_continuous_score_W0_n 0.09836153868400617
# test_continuous_score_W0_a 0.1099416670269368
# train_continuous_score_W_continuous_n 0.14072907140756277
# train_continuous_score_W_continuous_a 0.1611722880791938
# test_continuous_score_W_continuous_n 0.03426957796802421
# test_continuous_score_W_continuous_a 0.03467538328518707
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 195
# train_continuous_score_W0_n 0.1310198342514979
# train_continuous_score_W0_a 0.139413811085105
# test_continuous_score_W0_n 0.07519757142468514
# test_continuous_score_W0_a 0.07940640332696133
# train_continuous_score_W_continuous_n 0.1482526535961396
# train_continuous_score_W_continuous_a 0.17046033594816828
# test_continuous_score_W_continuous_n 0.040109103386061336
# test_continuous_score_W_continuous_a 0.04113204376000806
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 200
# train_continuous_score_W0_n 0.16138794655479494
# train_continuous_score_W0_a 0.17314506954730824
# test_continuous_score_W0_n 0.1309092393642722
# test_continuous_score_W0_a 0.14219205554873232
# train_continuous_score_W_continuous_n 0.15243647088744844
# train_continuous_score_W_continuous_a 0.17747390808093336
# test_continuous_score_W_continuous_n 0.058257473671575306
# test_continuous_score_W_continuous_a 0.06145796220011161
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  21.0  0.127305  0.022018  0.004805   0.117282  0.137327
# 1  train_con_W_con  21.0  0.126593  0.014796  0.003229   0.119858  0.133328
# 2         combined  42.0  0.126949  0.018531  0.002859   0.121174  0.132724
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =    0.0007
# 1                           Degrees of freedom =   40.0000
# 2                                            t =    0.1230
# 3                        Two side test p value =    0.9027
# 4                       Difference < 0 p value =    0.5486
# 5                       Difference > 0 p value =    0.4514
# 6                                    Cohen's d =    0.0380
# 7                                    Hedge's g =    0.0372
# 8                                Glass's delta =    0.0323
# 9                                  Pearson's r =    0.0194
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  21.0  0.099383  0.025321  0.005526   0.087857  0.110909
# 1  test_con_W_con  21.0  0.038768  0.012692  0.002770   0.032990  0.044545
# 2        combined  42.0  0.069076  0.036501  0.005632   0.057701  0.080450
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =    0.0606
# 1                         Degrees of freedom =   40.0000
# 2                                          t =    9.8069
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    3.0265
# 7                                  Hedge's g =    2.9694
# 8                              Glass's delta =    2.3938
# 9                                Pearson's r =    0.8404
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  21.0  0.136409  0.025551  0.005576   0.124778  0.148040
# 1  train_con_W_con  21.0  0.149037  0.016248  0.003546   0.141641  0.156433
# 2         combined  42.0  0.142723  0.022093  0.003409   0.135838  0.149608
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.0126
# 1                           Degrees of freedom =   40.0000
# 2                                            t =   -1.9111
# 3                        Two side test p value =    0.0632
# 4                       Difference < 0 p value =    0.0316
# 5                       Difference > 0 p value =    0.9684
# 6                                    Cohen's d =   -0.5898
# 7                                    Hedge's g =   -0.5786
# 8                                Glass's delta =   -0.4942
# 9                                  Pearson's r =    0.2893
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  21.0  0.102756  0.028017  0.006114   0.090003  0.115509
# 1  test_con_W_con  21.0  0.040438  0.013248  0.002891   0.034408  0.046469
# 2        combined  42.0  0.071597  0.038250  0.005902   0.059678  0.083517
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =    0.0623
# 1                         Degrees of freedom =   40.0000
# 2                                          t =    9.2148
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    2.8437
# 7                                  Hedge's g =    2.7901
# 8                              Glass's delta =    2.2243
# 9                                Pearson's r =    0.8245
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 250
class_num = 100
dim_num = 15
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
# Out:
# neuron unit number: 100
# train_discrete_score_W0_n 0.6574769616172834
# train_discrete_score_W0 0.7844140398477599
# test_discrete_score_W0_n 0.5991246728785601
# test_discrete_score_W0 0.7280464995559777
# train_discrete_score_W_discrete 0.6886438520386063
# train_discrete_score_W_discrete 0.8091450326022601
# test_discrete_score_W_discrete 0.5785566449588014
# test_discrete_score_W_discrete 0.7048138862779197
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 105
# train_discrete_score_W0_n 0.6957307545793543
# train_discrete_score_W0 0.8139811685253157
# test_discrete_score_W0_n 0.4342141881316568
# test_discrete_score_W0 0.5669597231436386
# train_discrete_score_W_discrete 0.5838121951401084
# train_discrete_score_W_discrete 0.7216422433464762
# test_discrete_score_W_discrete 0.39586715928055705
# test_discrete_score_W_discrete 0.5476066638062106
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 110
# train_discrete_score_W0_n 0.633934958918436
# train_discrete_score_W0 0.7640620483538298
# test_discrete_score_W0_n 0.5395153767218647
# test_discrete_score_W0 0.6731000663104956
# train_discrete_score_W_discrete 0.6308541997381613
# train_discrete_score_W_discrete 0.7605882536250287
# test_discrete_score_W_discrete 0.5282858504096698
# test_discrete_score_W_discrete 0.6770845109996166
# Not good nmi result for discrete features !!!!!
# neuron unit number: 115
# train_discrete_score_W0_n 0.6224497238503213
# train_discrete_score_W0 0.7551622236774259
# test_discrete_score_W0_n 0.48122777431053376
# test_discrete_score_W0 0.62656170024418
# train_discrete_score_W_discrete 0.72193374333394
# train_discrete_score_W_discrete 0.8348849779152779
# test_discrete_score_W_discrete 0.6235138676434478
# test_discrete_score_W_discrete 0.7511536077026868
# neuron unit number: 120
# train_discrete_score_W0_n 0.6597902932987586
# train_discrete_score_W0 0.783469692117894
# test_discrete_score_W0_n 0.578019827547471
# test_discrete_score_W0 0.7011945089442781
# train_discrete_score_W_discrete 0.6552689351484178
# train_discrete_score_W_discrete 0.7782521177032266
# test_discrete_score_W_discrete 0.5286997549338525
# test_discrete_score_W_discrete 0.6622504099333069
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 125
# train_discrete_score_W0_n 0.6165444437184009
# train_discrete_score_W0 0.7493294803493851
# test_discrete_score_W0_n 0.507704099421099
# test_discrete_score_W0 0.6526352410013797
# train_discrete_score_W_discrete 0.6055062674336852
# train_discrete_score_W_discrete 0.739446821349269
# test_discrete_score_W_discrete 0.41926132344562667
# test_discrete_score_W_discrete 0.5377347419817168
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 130
# train_discrete_score_W0_n 0.6609397287763483
# train_discrete_score_W0 0.7833043461025578
# test_discrete_score_W0_n 0.5277934411347841
# test_discrete_score_W0 0.658924233816544
# train_discrete_score_W_discrete 0.5825041002611127
# train_discrete_score_W_discrete 0.7208576277428301
# test_discrete_score_W_discrete 0.42631022309641525
# test_discrete_score_W_discrete 0.5643055552167069
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 135
# train_discrete_score_W0_n 0.6956899287825433
# train_discrete_score_W0 0.8146345248713517
# test_discrete_score_W0_n 0.4284669576111802
# test_discrete_score_W0 0.5678881099176638
# train_discrete_score_W_discrete 0.7123697615026302
# train_discrete_score_W_discrete 0.823719158313427
# test_discrete_score_W_discrete 0.497983196890974
# test_discrete_score_W_discrete 0.6238825260567515
# neuron unit number: 140
# train_discrete_score_W0_n 0.6623353381511325
# train_discrete_score_W0 0.7831367013620862
# test_discrete_score_W0_n 0.5423127294094394
# test_discrete_score_W0 0.6637369323975856
# train_discrete_score_W_discrete 0.675941860968173
# train_discrete_score_W_discrete 0.7991159333341294
# test_discrete_score_W_discrete 0.5523971250087036
# test_discrete_score_W_discrete 0.6918419915619364
# neuron unit number: 145
# train_discrete_score_W0_n 0.678843732180922
# train_discrete_score_W0 0.7999386638108118
# test_discrete_score_W0_n 0.39321066908047986
# test_discrete_score_W0 0.5335669539655193
# train_discrete_score_W_discrete 0.8357537539932116
# train_discrete_score_W_discrete 0.913116219712124
# test_discrete_score_W_discrete 0.7376971450820167
# test_discrete_score_W_discrete 0.8357621543155669
# neuron unit number: 150
# train_discrete_score_W0_n 0.6655885779193651
# train_discrete_score_W0 0.7885277689555694
# test_discrete_score_W0_n 0.5237538219558759
# test_discrete_score_W0 0.6634278941692014
# train_discrete_score_W_discrete 0.7123697615026302
# train_discrete_score_W_discrete 0.823719158313427
# test_discrete_score_W_discrete 0.5056481488285197
# test_discrete_score_W_discrete 0.661703147758879
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 155
# train_discrete_score_W0_n 0.6903527254079393
# train_discrete_score_W0 0.8087274947883352
# test_discrete_score_W0_n 0.509947910859519
# test_discrete_score_W0 0.6434011621000975
# train_discrete_score_W_discrete 0.65512732635131
# train_discrete_score_W_discrete 0.7758707782568516
# test_discrete_score_W_discrete 0.4657836656315575
# test_discrete_score_W_discrete 0.6176601004476913
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 160
# train_discrete_score_W0_n 0.7214584407502612
# train_discrete_score_W0 0.8345409406716608
# test_discrete_score_W0_n 0.5615235144685645
# test_discrete_score_W0 0.670784717674389
# train_discrete_score_W_discrete 0.678843732180922
# train_discrete_score_W_discrete 0.7999386638108118
# test_discrete_score_W_discrete 0.4567714371845568
# test_discrete_score_W_discrete 0.6104130475439452
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 165
# train_discrete_score_W0_n 0.7652180485582912
# train_discrete_score_W0 0.8652393549670292
# test_discrete_score_W0_n 0.5203110701792036
# test_discrete_score_W0 0.6371096302481192
# train_discrete_score_W_discrete 0.7778634148496385
# train_discrete_score_W_discrete 0.8760243485659165
# test_discrete_score_W_discrete 0.701060858177909
# test_discrete_score_W_discrete 0.8157609245887354
# neuron unit number: 170
# train_discrete_score_W0_n 0.6263735723609063
# train_discrete_score_W0 0.7533474846405678
# test_discrete_score_W0_n 0.5116829862318818
# test_discrete_score_W0 0.6398476405581756
# train_discrete_score_W_discrete 0.6870456971611327
# train_discrete_score_W_discrete 0.8051144454448084
# test_discrete_score_W_discrete 0.5001152941215847
# test_discrete_score_W_discrete 0.6489015313531601
# Not good nmi result for discrete features !!!!!
# neuron unit number: 175
# train_discrete_score_W0_n 0.6455292464930019
# train_discrete_score_W0 0.7740632888184946
# test_discrete_score_W0_n 0.5714232448237687
# test_discrete_score_W0 0.6861576571402368
# train_discrete_score_W_discrete 0.8756369191848967
# train_discrete_score_W_discrete 0.9397121748544623
# test_discrete_score_W_discrete 0.742674631284831
# test_discrete_score_W_discrete 0.8555398995593311
# neuron unit number: 180
# train_discrete_score_W0_n 0.7148731078019736
# train_discrete_score_W0 0.8293844799204757
# test_discrete_score_W0_n 0.47565164297257156
# test_discrete_score_W0 0.6129594160249715
# train_discrete_score_W_discrete 0.6453147210892557
# train_discrete_score_W_discrete 0.7742266892969817
# test_discrete_score_W_discrete 0.4368387632394
# test_discrete_score_W_discrete 0.5904113894153554
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 185
# train_discrete_score_W0_n 0.7016156490464048
# train_discrete_score_W0 0.8192345481310422
# test_discrete_score_W0_n 0.5297663508396389
# test_discrete_score_W0 0.6680084599333991
# train_discrete_score_W_discrete 0.722619542663477
# train_discrete_score_W_discrete 0.8349962505172506
# test_discrete_score_W_discrete 0.49519652225786276
# test_discrete_score_W_discrete 0.5854155896773557
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 190
# train_discrete_score_W0_n 0.7234653182724621
# train_discrete_score_W0 0.8341814306163504
# test_discrete_score_W0_n 0.5547583939204842
# test_discrete_score_W0 0.6666427714357691
# train_discrete_score_W_discrete 0.8777036461034585
# train_discrete_score_W_discrete 0.939627864331399
# test_discrete_score_W_discrete 0.6995551409924053
# test_discrete_score_W_discrete 0.8126160449005798
# neuron unit number: 195
# train_discrete_score_W0_n 0.6697364816962559
# train_discrete_score_W0 0.7943419932214643
# test_discrete_score_W0_n 0.5473473834687316
# test_discrete_score_W0 0.653337293803526
# train_discrete_score_W_discrete 0.6275724551325147
# train_discrete_score_W_discrete 0.7596036988681206
# test_discrete_score_W_discrete 0.3887772626035656
# test_discrete_score_W_discrete 0.5221738701308484
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 200
# train_discrete_score_W0_n 0.7453289141290422
# train_discrete_score_W0 0.8495371397749328
# test_discrete_score_W0_n 0.5273603100246596
# test_discrete_score_W0 0.6484111023298761
# train_discrete_score_W_discrete 0.6012369010505024
# train_discrete_score_W_discrete 0.7362213637529273
# test_discrete_score_W_discrete 0.3910614903457959
# test_discrete_score_W_discrete 0.5387275651783135
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 205
# train_discrete_score_W0_n 0.6762031013967059
# train_discrete_score_W0 0.7989715426131493
# test_discrete_score_W0_n 0.4289892450335766
# test_discrete_score_W0 0.5537051685513781
# train_discrete_score_W_discrete 0.9470144051176661
# train_discrete_score_W_discrete 0.9778886830122239
# test_discrete_score_W_discrete 0.6641459154197565
# test_discrete_score_W_discrete 0.756452155314377
# neuron unit number: 210
# train_discrete_score_W0_n 0.7015586729150893
# train_discrete_score_W0 0.8194887716876378
# test_discrete_score_W0_n 0.5261120778246873
# test_discrete_score_W0 0.66016981641734
# train_discrete_score_W_discrete 0.7044807831937523
# train_discrete_score_W_discrete 0.8131328281424137
# test_discrete_score_W_discrete 0.4383786977471618
# test_discrete_score_W_discrete 0.5611001459551151
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 215
# train_discrete_score_W0_n 0.7161081424514275
# train_discrete_score_W0 0.8291374281504905
# test_discrete_score_W0_n 0.5641830689383239
# test_discrete_score_W0 0.6759311972267718
# train_discrete_score_W_discrete 0.8118276841120282
# train_discrete_score_W_discrete 0.8967200464630903
# test_discrete_score_W_discrete 0.5162523976413339
# test_discrete_score_W_discrete 0.6582300554330661
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 220
# train_discrete_score_W0_n 0.6762031013967059
# train_discrete_score_W0 0.7989715426131493
# test_discrete_score_W0_n 0.5332744195852142
# test_discrete_score_W0 0.683039556847382
# train_discrete_score_W_discrete 0.6822403685265623
# train_discrete_score_W_discrete 0.8043302988953127
# test_discrete_score_W_discrete 0.3425579699665409
# test_discrete_score_W_discrete 0.48855799126019966
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 225
# train_discrete_score_W0_n 0.7035957634470298
# train_discrete_score_W0 0.8188390833829372
# test_discrete_score_W0_n 0.39893145860481466
# test_discrete_score_W0 0.5530508537011914
# train_discrete_score_W_discrete 0.716248509594852
# train_discrete_score_W_discrete 0.8234480651289127
# test_discrete_score_W_discrete 0.4407101539776244
# test_discrete_score_W_discrete 0.580383188223596
# neuron unit number: 230
# train_discrete_score_W0_n 0.675941860968173
# train_discrete_score_W0 0.7991159333341294
# test_discrete_score_W0_n 0.4006512257338644
# test_discrete_score_W0 0.5465425243863712
# train_discrete_score_W_discrete 0.6697364816962559
# train_discrete_score_W_discrete 0.7943419932214643
# test_discrete_score_W_discrete 0.3688894180027206
# test_discrete_score_W_discrete 0.5135882337728095
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 235
# train_discrete_score_W0_n 0.6641076644334958
# train_discrete_score_W0 0.7888419349310241
# test_discrete_score_W0_n 0.4125183590314679
# test_discrete_score_W0 0.5243918673267207
# train_discrete_score_W_discrete 0.729001712491866
# train_discrete_score_W_discrete 0.8394795325226801
# test_discrete_score_W_discrete 0.4440782982872488
# test_discrete_score_W_discrete 0.5954358664721416
# neuron unit number: 240
# train_discrete_score_W0_n 0.6417122451645323
# train_discrete_score_W0 0.7685381520356563
# test_discrete_score_W0_n 0.40787521830232504
# test_discrete_score_W0 0.5620323052441702
# train_discrete_score_W_discrete 0.9240691000237302
# train_discrete_score_W_discrete 0.966900929520731
# test_discrete_score_W_discrete 0.6970471373781701
# test_discrete_score_W_discrete 0.7993272406668129
# neuron unit number: 245
# train_discrete_score_W0_n 0.7356046594829126
# train_discrete_score_W0 0.8446670556679017
# test_discrete_score_W0_n 0.3774272873187112
# test_discrete_score_W0 0.49536723982802494
# train_discrete_score_W_discrete 0.6974710755004719
# train_discrete_score_W_discrete 0.813706260188164
# test_discrete_score_W_discrete 0.4352970036407572
# test_discrete_score_W_discrete 0.570016544438423
# neuron unit number: 250
# train_discrete_score_W0_n 0.7035957634470298
# train_discrete_score_W0 0.8188390833829372
# test_discrete_score_W0_n 0.5074620865264263
# test_discrete_score_W0 0.6264594018254874
# train_discrete_score_W_discrete 0.841009540337402
# train_discrete_score_W_discrete 0.9182975583104982
# test_discrete_score_W_discrete 0.6494535735936916
# test_discrete_score_W_discrete 0.7517528102957083
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.682191  0.036716  0.006594   0.668723  0.695658
# 1  train_dis_W_dis  31.0  0.718614  0.097945  0.017591   0.682687  0.754540
# 2         combined  62.0  0.700402  0.075618  0.009603   0.681199  0.719605
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0364
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.9388
# 3                        Two side test p value =    0.0572
# 4                       Difference < 0 p value =    0.0286
# 5                       Difference > 0 p value =    0.9714
# 6                                    Cohen's d =   -0.4924
# 7                                    Hedge's g =   -0.4863
# 8                                Glass's delta =   -0.9920
# 9                                  Pearson's r =    0.2428
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.497501  0.063489  0.011403   0.474213  0.520789
# 1  test_dis_W_dis  31.0  0.518351  0.116917  0.020999   0.475465  0.561236
# 2        combined  62.0  0.507926  0.093892  0.011924   0.484082  0.531770
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0208
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -0.8725
# 3                      Two side test p value =    0.3864
# 4                     Difference < 0 p value =    0.1932
# 5                     Difference > 0 p value =    0.8068
# 6                                  Cohen's d =   -0.2216
# 7                                  Hedge's g =   -0.2188
# 8                              Glass's delta =   -0.3284
# 9                                Pearson's r =    0.1119
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.802193  0.029243  0.005252   0.791466  0.812919
# 1  train_dis_W_dis  31.0  0.826260  0.070782  0.012713   0.800297  0.852223
# 2         combined  62.0  0.814226  0.055061  0.006993   0.800244  0.828209
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0241
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.7497
# 3                        Two side test p value =    0.0853
# 4                       Difference < 0 p value =    0.0426
# 5                       Difference > 0 p value =    0.9574
# 6                                    Cohen's d =   -0.4444
# 7                                    Hedge's g =   -0.4389
# 8                                Glass's delta =   -0.8230
# 9                                  Pearson's r =    0.2203
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.627206  0.059049  0.010605   0.605547  0.648865
# 1  test_dis_W_dis  31.0  0.649374  0.104513  0.018771   0.611039  0.687710
# 2        combined  62.0  0.638290  0.084921  0.010785   0.616724  0.659856
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0222
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -1.0282
# 3                      Two side test p value =    0.3080
# 4                     Difference < 0 p value =    0.1540
# 5                     Difference > 0 p value =    0.8460
# 6                                  Cohen's d =   -0.2612
# 7                                  Hedge's g =   -0.2579
# 8                              Glass's delta =   -0.3754
# 9                                Pearson's r =    0.1316
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 250
class_num = 100
dim_num = 15
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
# Out:
# neuron unit number: 100
# train_discrete_score_W0_n 0.6292588022409977
# train_discrete_score_W0 0.7561355023678271
# test_discrete_score_W0_n 0.4952816635392816
# test_discrete_score_W0 0.6407998175210105
# train_discrete_score_W_discrete 0.6409555791298135
# train_discrete_score_W_discrete 0.7536066262118756
# test_discrete_score_W_discrete 0.5653309099674511
# test_discrete_score_W_discrete 0.6682879292525026
# neuron unit number: 105
# train_discrete_score_W0_n 0.6339927776385098
# train_discrete_score_W0 0.7615788594167644
# test_discrete_score_W0_n 0.5095849829464173
# test_discrete_score_W0 0.658018618909443
# train_discrete_score_W_discrete 0.6398235669114352
# train_discrete_score_W_discrete 0.7664877397652967
# test_discrete_score_W_discrete 0.5207443103459976
# test_discrete_score_W_discrete 0.677014100181446
# neuron unit number: 110
# train_discrete_score_W0_n 0.591937942137196
# train_discrete_score_W0 0.7239293959382551
# test_discrete_score_W0_n 0.6179224770628694
# test_discrete_score_W0 0.7435111554482094
# train_discrete_score_W_discrete 0.5896314788969826
# train_discrete_score_W_discrete 0.723199331102171
# test_discrete_score_W_discrete 0.5516143851559271
# test_discrete_score_W_discrete 0.6966261886726719
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 115
# train_discrete_score_W0_n 0.5589589862906104
# train_discrete_score_W0 0.6954708511450571
# test_discrete_score_W0_n 0.5189374992558675
# test_discrete_score_W0 0.6758591443061982
# train_discrete_score_W_discrete 0.6115978993864303
# train_discrete_score_W_discrete 0.7419171178742995
# test_discrete_score_W_discrete 0.5330454832537075
# test_discrete_score_W_discrete 0.6755558734602435
# Not good ari result for discrete features  !!!!!
# neuron unit number: 120
# train_discrete_score_W0_n 0.6398235669114352
# train_discrete_score_W0 0.7664877397652967
# test_discrete_score_W0_n 0.5911556179492762
# test_discrete_score_W0 0.7190753860136597
# train_discrete_score_W_discrete 0.6574590192772458
# train_discrete_score_W_discrete 0.7811702045396339
# test_discrete_score_W_discrete 0.5383203043398485
# test_discrete_score_W_discrete 0.6767373157108679
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 125
# train_discrete_score_W0_n 0.6284076638593791
# train_discrete_score_W0 0.7564127994852318
# test_discrete_score_W0_n 0.652816392944769
# test_discrete_score_W0 0.7815159263706947
# train_discrete_score_W_discrete 0.6327711440033005
# train_discrete_score_W_discrete 0.7575592405172445
# test_discrete_score_W_discrete 0.5255896484098574
# test_discrete_score_W_discrete 0.6673209997039051
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 130
# train_discrete_score_W0_n 0.6232467456572963
# train_discrete_score_W0 0.7513788091170079
# test_discrete_score_W0_n 0.5276572415528077
# test_discrete_score_W0 0.6828780223604305
# train_discrete_score_W_discrete 0.6312597742830336
# train_discrete_score_W_discrete 0.7503294483455606
# test_discrete_score_W_discrete 0.4280115520382575
# test_discrete_score_W_discrete 0.5773408915741055
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 135
# train_discrete_score_W0_n 0.6178117847543365
# train_discrete_score_W0 0.7464941557237494
# test_discrete_score_W0_n 0.5250861261501393
# test_discrete_score_W0 0.6656730592504156
# train_discrete_score_W_discrete 0.6026339241704108
# train_discrete_score_W_discrete 0.7317512074799638
# test_discrete_score_W_discrete 0.6177662253550124
# test_discrete_score_W_discrete 0.7569096365336876
# neuron unit number: 140
# train_discrete_score_W0_n 0.6685100706402355
# train_discrete_score_W0 0.7850402472708164
# test_discrete_score_W0_n 0.5443005379916206
# test_discrete_score_W0 0.6952953828767248
# train_discrete_score_W_discrete 0.6753717859890631
# train_discrete_score_W_discrete 0.7958705234485091
# test_discrete_score_W_discrete 0.5845326654674305
# test_discrete_score_W_discrete 0.7157343935488534
# neuron unit number: 145
# train_discrete_score_W0_n 0.6254927970583161
# train_discrete_score_W0 0.7509419149959745
# test_discrete_score_W0_n 0.4931634525390216
# test_discrete_score_W0 0.6464702105140713
# train_discrete_score_W_discrete 0.7396647031317778
# train_discrete_score_W_discrete 0.8461218262689703
# test_discrete_score_W_discrete 0.6355013906514514
# test_discrete_score_W_discrete 0.769292999411213
# neuron unit number: 150
# train_discrete_score_W0_n 0.6583659119382524
# train_discrete_score_W0 0.7813994781826077
# test_discrete_score_W0_n 0.6212953338030631
# test_discrete_score_W0 0.7481948523690334
# train_discrete_score_W_discrete 0.7684058955787537
# train_discrete_score_W_discrete 0.8663815725397342
# test_discrete_score_W_discrete 0.6402807814182536
# test_discrete_score_W_discrete 0.7456756521034572
# Not good ari result for discrete features  !!!!!
# neuron unit number: 155
# train_discrete_score_W0_n 0.6340326407210548
# train_discrete_score_W0 0.7613171735562273
# test_discrete_score_W0_n 0.5314823894513107
# test_discrete_score_W0 0.6831821143656721
# train_discrete_score_W_discrete 0.6632309603810987
# train_discrete_score_W_discrete 0.785900699732901
# test_discrete_score_W_discrete 0.7249616008647625
# test_discrete_score_W_discrete 0.8496298820120101
# neuron unit number: 160
# train_discrete_score_W0_n 0.6715798244056174
# train_discrete_score_W0 0.7902925611588183
# test_discrete_score_W0_n 0.49667377546958175
# test_discrete_score_W0 0.6478076481968708
# train_discrete_score_W_discrete 0.6287300385219625
# train_discrete_score_W_discrete 0.756942685265179
# test_discrete_score_W_discrete 0.5137972799528551
# test_discrete_score_W_discrete 0.6380174607128802
# Not good ari result for discrete features  !!!!!
# neuron unit number: 165
# train_discrete_score_W0_n 0.6516997896826351
# train_discrete_score_W0 0.7758535736864905
# test_discrete_score_W0_n 0.5066891557264696
# test_discrete_score_W0 0.6607921490062141
# train_discrete_score_W_discrete 0.7489433667449761
# train_discrete_score_W_discrete 0.8514858514459515
# test_discrete_score_W_discrete 0.6470779633978195
# test_discrete_score_W_discrete 0.7749124367094351
# neuron unit number: 170
# train_discrete_score_W0_n 0.6514318978470556
# train_discrete_score_W0 0.7759783054894787
# test_discrete_score_W0_n 0.5565126038692925
# test_discrete_score_W0 0.6924788102971595
# train_discrete_score_W_discrete 0.6232467456572963
# train_discrete_score_W_discrete 0.7513788091170079
# test_discrete_score_W_discrete 0.5402642404122664
# test_discrete_score_W_discrete 0.6941357290542147
# Not good nmi result for discrete features !!!!!
# neuron unit number: 175
# train_discrete_score_W0_n 0.6756960074675901
# train_discrete_score_W0 0.7899188777018251
# test_discrete_score_W0_n 0.6053917367740663
# test_discrete_score_W0 0.7616898504957307
# train_discrete_score_W_discrete 0.700247803877572
# train_discrete_score_W_discrete 0.8157585645959636
# test_discrete_score_W_discrete 0.6012392413464022
# test_discrete_score_W_discrete 0.7441881302936117
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 180
# train_discrete_score_W0_n 0.5908300760154002
# train_discrete_score_W0 0.7224108742200254
# test_discrete_score_W0_n 0.5079133227411924
# test_discrete_score_W0 0.6437287927352358
# train_discrete_score_W_discrete 0.7464012750699429
# train_discrete_score_W_discrete 0.8511789705202492
# test_discrete_score_W_discrete 0.6519454064234129
# test_discrete_score_W_discrete 0.7814067046708406
# neuron unit number: 185
# train_discrete_score_W0_n 0.6943025517951198
# train_discrete_score_W0 0.810914533710653
# test_discrete_score_W0_n 0.49662985203133314
# test_discrete_score_W0 0.6212138220771253
# train_discrete_score_W_discrete 0.7442454794848902
# train_discrete_score_W_discrete 0.846512163816703
# test_discrete_score_W_discrete 0.5427299725008815
# test_discrete_score_W_discrete 0.6854320903643744
# neuron unit number: 190
# train_discrete_score_W0_n 0.6831550484167087
# train_discrete_score_W0 0.8003223527328626
# test_discrete_score_W0_n 0.5137492889462185
# test_discrete_score_W0 0.6544070323826314
# train_discrete_score_W_discrete 0.6899819696464609
# train_discrete_score_W_discrete 0.8052432960222413
# test_discrete_score_W_discrete 0.4830988711540937
# test_discrete_score_W_discrete 0.6072813590138564
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 195
# train_discrete_score_W0_n 0.6911581237462103
# train_discrete_score_W0 0.8051300822111522
# test_discrete_score_W0_n 0.5867750159300696
# test_discrete_score_W0 0.7403733710150424
# train_discrete_score_W_discrete 0.6823985917892547
# train_discrete_score_W_discrete 0.8004359109144292
# test_discrete_score_W_discrete 0.5391929516226899
# test_discrete_score_W_discrete 0.6731836377786408
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 200
# train_discrete_score_W0_n 0.6506191291573669
# train_discrete_score_W0 0.7702350590796179
# test_discrete_score_W0_n 0.5506799600702078
# test_discrete_score_W0 0.6899162376977519
# train_discrete_score_W_discrete 0.6061584571580644
# train_discrete_score_W_discrete 0.737644089727648
# test_discrete_score_W_discrete 0.5124696835053147
# test_discrete_score_W_discrete 0.6286353261716903
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 205
# train_discrete_score_W0_n 0.6939213220832761
# train_discrete_score_W0 0.8107131482527165
# test_discrete_score_W0_n 0.46945814589332036
# test_discrete_score_W0 0.59530114079272
# train_discrete_score_W_discrete 0.6907835985931209
# train_discrete_score_W_discrete 0.799728972450559
# test_discrete_score_W_discrete 0.6066810860760122
# test_discrete_score_W_discrete 0.7446927899155436
# neuron unit number: 210
# train_discrete_score_W0_n 0.6765041817856248
# train_discrete_score_W0 0.7954188455012254
# test_discrete_score_W0_n 0.48935628359627653
# test_discrete_score_W0 0.6416831382521686
# train_discrete_score_W_discrete 0.6572815379975561
# train_discrete_score_W_discrete 0.781052815357843
# test_discrete_score_W_discrete 0.5170432181638466
# test_discrete_score_W_discrete 0.6701629703004152
# neuron unit number: 215
# train_discrete_score_W0_n 0.6702827304485972
# train_discrete_score_W0 0.7912107769177068
# test_discrete_score_W0_n 0.5029192560520906
# test_discrete_score_W0 0.5999870903425004
# train_discrete_score_W_discrete 0.7550862454943247
# train_discrete_score_W_discrete 0.8560167660719277
# test_discrete_score_W_discrete 0.644646154051302
# test_discrete_score_W_discrete 0.7544321803956693
# neuron unit number: 220
# train_discrete_score_W0_n 0.6685100706402355
# train_discrete_score_W0 0.7850402472708164
# test_discrete_score_W0_n 0.5414976159790623
# test_discrete_score_W0 0.6643720400477254
# train_discrete_score_W_discrete 0.664209027182591
# train_discrete_score_W_discrete 0.7855428761926753
# test_discrete_score_W_discrete 0.5978235267039466
# test_discrete_score_W_discrete 0.7252280454680533
# neuron unit number: 225
# train_discrete_score_W0_n 0.7198776702042531
# train_discrete_score_W0 0.830694154436329
# test_discrete_score_W0_n 0.5960307684349339
# test_discrete_score_W0 0.7130830088695653
# train_discrete_score_W_discrete 0.6831550484167087
# train_discrete_score_W_discrete 0.8003223527328626
# test_discrete_score_W_discrete 0.45852521395717777
# test_discrete_score_W_discrete 0.5999204720696379
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 230
# train_discrete_score_W0_n 0.6255167626265794
# train_discrete_score_W0 0.7525760261514041
# test_discrete_score_W0_n 0.534821356086568
# test_discrete_score_W0 0.6547890653323157
# train_discrete_score_W_discrete 0.7072716068421939
# train_discrete_score_W_discrete 0.8205229915255673
# test_discrete_score_W_discrete 0.4633856113135939
# test_discrete_score_W_discrete 0.6194411777686051
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 235
# train_discrete_score_W0_n 0.6776002222842928
# train_discrete_score_W0 0.7897907109330679
# test_discrete_score_W0_n 0.4772074631904445
# test_discrete_score_W0 0.5982701791600156
# train_discrete_score_W_discrete 0.6876939764669457
# train_discrete_score_W_discrete 0.8056796181884821
# test_discrete_score_W_discrete 0.5512602888977355
# test_discrete_score_W_discrete 0.6454104926663206
# neuron unit number: 240
# train_discrete_score_W0_n 0.6706877551272656
# train_discrete_score_W0 0.7904135371541926
# test_discrete_score_W0_n 0.3523475387375797
# test_discrete_score_W0 0.4918560607035182
# train_discrete_score_W_discrete 0.6879222372872533
# train_discrete_score_W_discrete 0.8055730068422489
# test_discrete_score_W_discrete 0.5275084034018531
# test_discrete_score_W_discrete 0.6478147740028101
# neuron unit number: 245
# train_discrete_score_W0_n 0.7131755140505092
# train_discrete_score_W0 0.8256982811101915
# test_discrete_score_W0_n 0.5046393025842951
# test_discrete_score_W0 0.6189398001745655
# train_discrete_score_W_discrete 0.6706877551272656
# train_discrete_score_W_discrete 0.7904135371541926
# test_discrete_score_W_discrete 0.48520567348389554
# test_discrete_score_W_discrete 0.6168384042134496
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 250
# train_discrete_score_W0_n 0.6287456474529606
# train_discrete_score_W0 0.7562751859925645
# test_discrete_score_W0_n 0.4347840466565048
# test_discrete_score_W0 0.5955571131049799
# train_discrete_score_W_discrete 0.6561431589781156
# train_discrete_score_W_discrete 0.7645392068629427
# test_discrete_score_W_discrete 0.518775387108523
# test_discrete_score_W_discrete 0.625756107913313
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.652101  0.036372  0.006533   0.638760  0.665442
# 1  train_dis_W_dis  31.0  0.673658  0.048536  0.008717   0.655855  0.691461
# 2         combined  62.0  0.662879  0.043901  0.005575   0.651731  0.674028
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0216
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.9789
# 3                        Two side test p value =    0.0524
# 4                       Difference < 0 p value =    0.0262
# 5                       Difference > 0 p value =    0.9738
# 6                                    Cohen's d =   -0.5026
# 7                                    Hedge's g =   -0.4963
# 8                                Glass's delta =   -0.5927
# 9                                  Pearson's r =    0.2475
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.527508  0.059502  0.010687   0.505683  0.549334
# 1  test_dis_W_dis  31.0  0.557044  0.066910  0.012017   0.532501  0.581587
# 2        combined  62.0  0.542276  0.064534  0.008196   0.525888  0.558665
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0295
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -1.8366
# 3                      Two side test p value =    0.0712
# 4                     Difference < 0 p value =    0.0356
# 5                     Difference > 0 p value =    0.9644
# 6                                  Cohen's d =   -0.4665
# 7                                  Hedge's g =   -0.4606
# 8                              Glass's delta =   -0.4964
# 9                                Pearson's r =    0.2307
# ARI T-Test
#           Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.77437  0.030153  0.005416   0.763310  0.785430
# 1  train_dis_W_dis  31.0  0.79117  0.039798  0.007148   0.776572  0.805768
# 2         combined  62.0  0.78277  0.036025  0.004575   0.773621  0.791919
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0168
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   -1.8733
# 3                        Two side test p value =    0.0659
# 4                       Difference < 0 p value =    0.0329
# 5                       Difference > 0 p value =    0.9671
# 6                                    Cohen's d =   -0.4758
# 7                                    Hedge's g =   -0.4699
# 8                                Glass's delta =   -0.5572
# 9                                  Pearson's r =    0.2351
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.665378  0.059123  0.010619   0.643691  0.687065
# 1  test_dis_W_dis  31.0  0.688807  0.063637  0.011430   0.665465  0.712149
# 2        combined  62.0  0.677093  0.062050  0.007880   0.661335  0.692850
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0234
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   -1.5017
# 3                      Two side test p value =    0.1384
# 4                     Difference < 0 p value =    0.0692
# 5                     Difference > 0 p value =    0.9308
# 6                                  Cohen's d =   -0.3814
# 7                                  Hedge's g =   -0.3767
# 8                              Glass's delta =   -0.3963
# 9                                Pearson's r =    0.1903
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
