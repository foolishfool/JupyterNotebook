# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Postures/Postures.csv")
dataread.replaceNANinDataset(csv)
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Class")

# %%
# multiple text by adding neuron number
scoretype = 1
scope_num = 20
class_num = 5
dim_num = 37
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 5
# *******************
#
# Error Data percentage 0.5542466204474363
# right_data0_score_W0 1.0
# error_data0_score_W1 0.27705426353650353
# error_data0_score_W0 0.4021614669487603
# combinedweight shape 0: (10, 37)
# right_data0_score_W' 0.6605641907343933
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27975433644948783
# error_data1_score_W0 0.2743716438435446
# combinedweight shape1 : (15, 37)
# right_data1_score_W' 0.32123038020209566
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.09002005298410579
# error_data2_score_W0 0.08810275716920116
# combinedweight shape1 : (20, 37)
# right_data2_score_W' 0.357433141433025
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.08390220976287571
# error_data3_score_W0 0.08301494991996952
# combinedweight shape1 : (25, 37)
# right_data3_score_W' 0.3578937937322247
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.1391925310727602
# error_data4_score_W0 0.10670139316309829
# combinedweight shape1 : (30, 37)
# right_data4_score_W' 0.08710068085011173
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.06701717122230082
# error_data5_score_W0 0.06864275448605656
# combinedweight shape1 : (35, 37)
# right_data5_score_W' 0.1854043908336842
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.222188391593949
# error_data6_score_W0 0.20984675524411137
# combinedweight shape1 : (40, 37)
# right_data6_score_W' 0.11915650481212198
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.09661784390223227
# error_data7_score_W0 0.12701857729608348
# combinedweight shape1 : (45, 37)
# right_data7_score_W' 0.07462695516916872
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.4127766734326739
# error_data8_score_W0 0.4049832031526286
# combinedweight shape1 : (50, 37)
# right_data8_score_W' 0.4198751380760265
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.31127303496497993
# error_data9_score_W0 0.26129406249077325
# combinedweight shape1 : (55, 37)
# right_data9_score_W' 0.4881196433853949
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.6229083742741092
# error_data10_score_W0 0.5410080335488939
# combinedweight shape1 : (60, 37)
# right_data10_score_W' 0.17787613998332252
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 0.5771596324111234
# combinedweight shape1 : (65, 37)
# right_data11_score_W' 1.0
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3104433475926495
# all_train_score_W': 1.0
# test_score_W0 : 0.30816699890304056
# test_score_W': 0.7552819345935413
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.4983994000036585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.30933491852634537
# error_data0_score_W0 0.46136325970015063
# combinedweight shape 0: (20, 37)
# right_data0_score_W' 0.6696667810220822
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2301696450675316
# error_data1_score_W0 0.19463065928099169
# combinedweight shape1 : (30, 37)
# right_data1_score_W' 0.45997899549926224
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1650083794778217
# error_data2_score_W0 0.13830512038673418
# combinedweight shape1 : (40, 37)
# right_data2_score_W' 0.4191851566974664
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.07440129760243143
# error_data3_score_W0 0.06854351687164834
# combinedweight shape1 : (50, 37)
# right_data3_score_W' 0.20961838889584225
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.14927033988269597
# error_data4_score_W0 0.11328451576552165
# combinedweight shape1 : (60, 37)
# right_data4_score_W' 0.11131446419872938
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.07861628352890249
# error_data5_score_W0 0.04269265221501109
# combinedweight shape1 : (70, 37)
# right_data5_score_W' 0.19181197788941698
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.10821002221384987
# error_data6_score_W0 0.09290310932429593
# combinedweight shape1 : (80, 37)
# right_data6_score_W' 0.0920680198510833
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.2665048310429687
# error_data7_score_W0 0.0700064514381736
# combinedweight shape1 : (90, 37)
# right_data7_score_W' 0.07515029598007021
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.16013683627917163
# error_data8_score_W0 0.08525982285100756
# combinedweight shape1 : (100, 37)
# right_data8_score_W' 0.20411368507063982
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.29220593978097836
# error_data9_score_W0 0.1815317109592035
# combinedweight shape1 : (110, 37)
# right_data9_score_W' 0.19800395679630606
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.3065527770743748
# error_data10_score_W0 0.24180085932597253
# combinedweight shape1 : (120, 37)
# right_data10_score_W' 0.31716611727242433
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.7612722022729244
# error_data11_score_W0 0.45960950474527223
# combinedweight shape1 : (130, 37)
# right_data11_score_W' 0.5628359673831625
# Finish one training *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 1.0
# error_data12_score_W0 0.0
# combinedweight shape1 : (140, 37)
# right_data12_score_W' 0.7942290322392523
# Finish one training *********
# 13
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.359032537806492
# all_train_score_W': 1.0
# test_score_W0 : 0.3634515749618999
# test_score_W': 0.7713136494271
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.4467594709788355
# right_data0_score_W0 1.0
# error_data0_score_W1 0.29735438413749876
# error_data0_score_W0 0.488467948383853
# combinedweight shape 0: (30, 37)
# right_data0_score_W' 0.5725869686744828
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.21753187498049284
# error_data1_score_W0 0.22086073662834754
# combinedweight shape1 : (45, 37)
# right_data1_score_W' 0.4372890054303531
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1563393219037291
# error_data2_score_W0 0.11406712133240123
# combinedweight shape1 : (60, 37)
# right_data2_score_W' 0.3668301377482865
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1180646493262852
# error_data3_score_W0 0.09314821140109276
# combinedweight shape1 : (75, 37)
# right_data3_score_W' 0.22043042012905356
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.1217651571359033
# error_data4_score_W0 0.05623707605466441
# combinedweight shape1 : (90, 37)
# right_data4_score_W' 0.04969032751417378
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.11663133563225503
# error_data5_score_W0 0.06638813739240748
# combinedweight shape1 : (105, 37)
# right_data5_score_W' 0.166478526715815
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.14606598197769052
# error_data6_score_W0 0.07429331572214169
# combinedweight shape1 : (120, 37)
# right_data6_score_W' 0.11764010607933618
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.2322146598856513
# error_data7_score_W0 0.10440222313080909
# combinedweight shape1 : (135, 37)
# right_data7_score_W' 0.16083591004453923
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.194154424550898
# error_data8_score_W0 0.1438090829352973
# combinedweight shape1 : (150, 37)
# right_data8_score_W' 0.15631810754516726
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.38465584661900626
# error_data9_score_W0 0.1333593529826474
# combinedweight shape1 : (165, 37)
# right_data9_score_W' 0.17702410597719329
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.7182714289540791
# error_data10_score_W0 0.29532915423430545
# combinedweight shape1 : (180, 37)
# right_data10_score_W' 0.28601145578939097
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 0.2740175421212811
# combinedweight shape1 : (195, 37)
# right_data11_score_W' 0.34156965186924737
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
