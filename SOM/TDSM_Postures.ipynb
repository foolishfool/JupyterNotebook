# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Postures/Postures.csv")
dataread.replaceNANinDataset(csv)
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Class")

# %%
# multiple text by adding neuron number
scoretype = 1
scope_num = 30
class_num = 5
dim_num = 37
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 5
# *******************
#
# Error Data percentage 0.5731245541185724
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3493068771951902
# error_data0_score_W0 0.4721913243152386
# combinedweight shape 0: (10, 37)
# right_data0_score_W' 0.6005683688186834
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.19107337428129673
# error_data1_score_W0 0.14048248204123756
# combinedweight shape1 : (15, 37)
# right_data1_score_W' 0.4878765551845911
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.8953192130645254e-15
# error_data2_score_W0 0.06302680453117548
# combinedweight shape1 : (20, 37)
# right_data2_score_W' 0.4161031818288761
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.26485589031531936
# error_data3_score_W0 0.22556234516393925
# combinedweight shape1 : (25, 37)
# right_data3_score_W' 0.0
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.13212928979051045
# error_data4_score_W0 0.09122767110558667
# combinedweight shape1 : (30, 37)
# right_data4_score_W' 0.21336942836278167
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.049290620857361814
# error_data5_score_W0 0.12762736983761136
# combinedweight shape1 : (35, 37)
# right_data5_score_W' 0.07267567625712595
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.21264383087211994
# error_data6_score_W0 0.18708587398237742
# combinedweight shape1 : (40, 37)
# right_data6_score_W' 0.049597914887544024
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.32524419074121635
# error_data7_score_W0 0.15760066128710817
# combinedweight shape1 : (45, 37)
# right_data7_score_W' 0.16761319616271197
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.47365360509241095
# error_data8_score_W0 0.3872940487139076
# combinedweight shape1 : (50, 37)
# right_data8_score_W' 0.1766257034581906
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (55, 37)
# right_data9_score_W' 0.3191283525670672
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3356079680929821
# all_train_score_W': 1.0
# test_score_W0 : 0.33447990358451174
# test_score_W': 0.7882116693331123
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.4819177931841879
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4174084788331599
# error_data0_score_W0 0.5029995311451593
# combinedweight shape 0: (20, 37)
# right_data0_score_W' 0.6691069275377031
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20886485728764934
# error_data1_score_W0 0.15383963046884566
# combinedweight shape1 : (30, 37)
# right_data1_score_W' 0.4767743563490501
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.19282060519741376
# error_data2_score_W0 0.12682661452051963
# combinedweight shape1 : (40, 37)
# right_data2_score_W' 0.24903124873434557
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1408824739582565
# error_data3_score_W0 0.12839030440625848
# combinedweight shape1 : (50, 37)
# right_data3_score_W' 0.30486362189963534
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.21993724085500654
# error_data4_score_W0 0.19577538085439308
# combinedweight shape1 : (60, 37)
# right_data4_score_W' 0.13287582309000134
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.22525849337266463
# error_data5_score_W0 0.16149521742776712
# combinedweight shape1 : (70, 37)
# right_data5_score_W' 0.25825752722248563
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.20319584477506766
# error_data6_score_W0 0.1397217232383512
# combinedweight shape1 : (80, 37)
# right_data6_score_W' 0.22085902773169988
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.19504381857725933
# error_data7_score_W0 0.15480070677473837
# combinedweight shape1 : (90, 37)
# right_data7_score_W' 0.12504677716404336
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.4614174907088315
# error_data8_score_W0 0.3070583977014815
# combinedweight shape1 : (100, 37)
# right_data8_score_W' 0.16940546576704735
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.7020513336223111
# error_data9_score_W0 0.17892478830894473
# combinedweight shape1 : (110, 37)
# right_data9_score_W' 0.3477663836677727
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (120, 37)
# right_data10_score_W' 0.5816794691923082
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3719309380600172
# all_train_score_W': 1.0
# test_score_W0 : 0.3721276483004295
# test_score_W': 0.7785333993038114
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.4980884262900836
# right_data0_score_W0 1.0
# error_data0_score_W1 0.34873400533289
# error_data0_score_W0 0.5162488555913382
# combinedweight shape 0: (30, 37)
# right_data0_score_W' 0.6281041933595083
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20774233967453581
# error_data1_score_W0 0.1356585967437654
# combinedweight shape1 : (45, 37)
# right_data1_score_W' 0.42672080211748886
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.25442735521538684
# error_data2_score_W0 0.16288803172874786
# combinedweight shape1 : (60, 37)
# right_data2_score_W' 0.3778974065083267
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.11219044499363981
# error_data3_score_W0 0.0669282826897581
# combinedweight shape1 : (75, 37)
# right_data3_score_W' 0.3557497022292469
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.18671468878259093
# error_data4_score_W0 0.0819173420537188
# combinedweight shape1 : (90, 37)
# right_data4_score_W' 0.12854923347457736
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2176851013961737
# error_data5_score_W0 0.0907181204823452
# combinedweight shape1 : (105, 37)
# right_data5_score_W' 0.269316963508657
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.13984584045735832
# error_data6_score_W0 0.08649368616863262
# combinedweight shape1 : (120, 37)
# right_data6_score_W' 0.19571239078664257
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.21024755584819016
# error_data7_score_W0 0.12139935754428931
# combinedweight shape1 : (135, 37)
# right_data7_score_W' 0.08256742129062145
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.338724756659582
# error_data8_score_W0 0.1494454241308897
# combinedweight shape1 : (150, 37)
# right_data8_score_W' 0.11567173407406559
# Finish one training *********
# 9
# right_data9_score_W0 1.0000000000000002
# error_data9_score_W1 0.5377736731315107
# error_data9_score_W0 0.26457221391095886
# combinedweight shape1 : (165, 37)
# right_data9_score_W' 0.23042613254791688
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.7069915719890948
# combinedweight shape1 : (180, 37)
# right_data10_score_W' 0.5105400970132948
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.35584948189280025
# all_train_score_W': 1.0
# test_score_W0 : 0.3604957132090916
# test_score_W': 0.7404034849735069
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.42082060475241007
# right_data0_score_W0 1.0
# error_data0_score_W1 0.33985459603890733
# error_data0_score_W0 0.44364387353097845
# combinedweight shape 0: (40, 37)
# right_data0_score_W' 0.6162032585004725
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20807066081226064
# error_data1_score_W0 0.1274793801902944
# combinedweight shape1 : (60, 37)
# right_data1_score_W' 0.458175712596284
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.21427077668834188
# error_data2_score_W0 0.1234364469888998
# combinedweight shape1 : (80, 37)
# right_data2_score_W' 0.2761524101606029
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1833746951037532
# error_data3_score_W0 0.0797436907493904
# combinedweight shape1 : (100, 37)
# right_data3_score_W' 0.23139416984269068
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.25618275709581373
# error_data4_score_W0 0.08623679244981125
# combinedweight shape1 : (120, 37)
# right_data4_score_W' 0.22740929311540486
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2074018868488418
# error_data5_score_W0 0.10218277560999463
# combinedweight shape1 : (140, 37)
# right_data5_score_W' 0.14566348884031344
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.23545350463821751
# error_data6_score_W0 0.09391490108674849
# combinedweight shape1 : (160, 37)
# right_data6_score_W' 0.2674624247148537
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.40976167894123616
# error_data7_score_W0 0.12834727497199264
# combinedweight shape1 : (180, 37)
# right_data7_score_W' 0.17612033559418752
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7246511376734289
# error_data8_score_W0 0.3809574349139601
# combinedweight shape1 : (200, 37)
# right_data8_score_W' 0.27773003882484326
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.39999999999999997
# combinedweight shape1 : (220, 37)
# right_data9_score_W' 0.6358670405443638
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.41239755311151893
# all_train_score_W': 1.0
# test_score_W0 : 0.410715788899093
# test_score_W': 0.7578652592129473
# neuron unit number: 25
# *******************
#
# Error Data percentage 0.4340827190078109
# right_data0_score_W0 1.0
# error_data0_score_W1 0.30403577960165395
# error_data0_score_W0 0.4346025156013013
# combinedweight shape 0: (50, 37)
# right_data0_score_W' 0.6072070330281769
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.19212593581602586
# error_data1_score_W0 0.12022909521124603
# combinedweight shape1 : (75, 37)
# right_data1_score_W' 0.38244546548844355
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.17062918935028545
# error_data2_score_W0 0.04880476293700318
# combinedweight shape1 : (100, 37)
# right_data2_score_W' 0.3019065127091285
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.13484860425022832
# error_data3_score_W0 0.054087425717106515
# combinedweight shape1 : (125, 37)
# right_data3_score_W' 0.18383693466047457
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.10261874175797239
# error_data4_score_W0 0.02690663732520819
# combinedweight shape1 : (150, 37)
# right_data4_score_W' 0.1565876957596559
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.20314442256976506
# error_data5_score_W0 0.06829037233502372
# combinedweight shape1 : (175, 37)
# right_data5_score_W' 0.1002847757901315
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.1414223054358752
# error_data6_score_W0 0.06301400070744417
# combinedweight shape1 : (200, 37)
# right_data6_score_W' 0.20069387410378356
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.2734368043894685
# error_data7_score_W0 0.12269334384365836
# combinedweight shape1 : (225, 37)
# right_data7_score_W' 0.1016726587941892
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.4112976842203129
# error_data8_score_W0 0.206952627891492
# combinedweight shape1 : (250, 37)
# right_data8_score_W' 0.2330457597297481
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6827050227304977
# error_data9_score_W0 0.1171748274709155
# combinedweight shape1 : (275, 37)
# right_data9_score_W' 0.28296711869397173
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 0.7020168761809934
# combinedweight shape1 : (300, 37)
# right_data10_score_W' 0.5074177008474889
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.353511714702859
# all_train_score_W': 1.0
# test_score_W0 : 0.35504215196237116
# test_score_W': 0.7185809390847548
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.39996707337150383
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2851885155886904
# error_data0_score_W0 0.5363112906129469
# combinedweight shape 0: (60, 37)
# right_data0_score_W' 0.5789857580362974
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.22651585887299538
# error_data1_score_W0 0.1466605443842071
# combinedweight shape1 : (90, 37)
# right_data1_score_W' 0.4195218443748138
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.17952615593771434
# error_data2_score_W0 0.06342619664059432
# combinedweight shape1 : (120, 37)
# right_data2_score_W' 0.41820324834642053
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.13924003791089962
# error_data3_score_W0 0.03579304264071357
# combinedweight shape1 : (150, 37)
# right_data3_score_W' 0.21888979889956417
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.10672741174236215
# error_data4_score_W0 0.017700187920386714
# combinedweight shape1 : (180, 37)
# right_data4_score_W' 0.1703900975445391
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.10196461362630967
# error_data5_score_W0 0.045471299902860425
# combinedweight shape1 : (210, 37)
# right_data5_score_W' 0.08882830524446218
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.1633805674135454
# error_data6_score_W0 0.07990334767622645
# combinedweight shape1 : (240, 37)
# right_data6_score_W' 0.09274900075876533
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.2662684579753986
# error_data7_score_W0 0.0781955218561785
# combinedweight shape1 : (270, 37)
# right_data7_score_W' 0.12518676021648673
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.43955392885560024
# error_data8_score_W0 0.22979259268160668
# combinedweight shape1 : (300, 37)
# right_data8_score_W' 0.19988899276266892
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8603336564266822
# error_data9_score_W0 0.3527005894960768
# combinedweight shape1 : (330, 37)
# right_data9_score_W' 0.20192411716870393
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (360, 37)
# right_data10_score_W' 0.6156204390318827
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.423745961143228
# all_train_score_W': 1.0
# test_score_W0 : 0.4266677949910345
# test_score_W': 0.7426160874397202
# neuron unit number: 35
# *******************
#
# Error Data percentage 0.4133938207693856
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32917498996338845
# error_data0_score_W0 0.4860491453202197
# combinedweight shape 0: (70, 37)
# right_data0_score_W' 0.6633942978132664
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2096749626489435
# error_data1_score_W0 0.14442680121326693
# combinedweight shape1 : (105, 37)
# right_data1_score_W' 0.36298206897723656
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.15570746868351762
# error_data2_score_W0 0.07703008551626096
# combinedweight shape1 : (140, 37)
# right_data2_score_W' 0.3185596659405484
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.19110209346462614
# error_data3_score_W0 0.029666602700907384
# combinedweight shape1 : (175, 37)
# right_data3_score_W' 0.14792706704024614
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.1341137340439885
# error_data4_score_W0 0.06470239045851203
# combinedweight shape1 : (210, 37)
# right_data4_score_W' 0.20913314299695238
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.15444014719321575
# error_data5_score_W0 0.04753138210167922
# combinedweight shape1 : (245, 37)
# right_data5_score_W' 0.09677623577067801
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.19756636754487106
# error_data6_score_W0 0.08690481417221092
# combinedweight shape1 : (280, 37)
# right_data6_score_W' 0.17979563624029288
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.24548747584608926
# error_data7_score_W0 0.03307059520646321
# combinedweight shape1 : (315, 37)
# right_data7_score_W' 0.14746202937094013
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6830169780875782
# error_data8_score_W0 0.06280359218348887
# combinedweight shape1 : (350, 37)
# right_data8_score_W' 0.18039224538171458
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.5713283112294099
# combinedweight shape1 : (385, 37)
# right_data9_score_W' 0.397418815909353
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.39455395683230804
# all_train_score_W': 1.0
# test_score_W0 : 0.39493815710542135
# test_score_W': 0.7308985347170837
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.3851866756910019
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2723052135898325
# error_data0_score_W0 0.45515785885793314
# combinedweight shape 0: (80, 37)
# right_data0_score_W' 0.586139915709201
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2204003175055752
# error_data1_score_W0 0.14593921879506228
# combinedweight shape1 : (120, 37)
# right_data1_score_W' 0.36731824313166017
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1618732363002948
# error_data2_score_W0 0.060521208134459055
# combinedweight shape1 : (160, 37)
# right_data2_score_W' 0.29159539773836496
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.14979587119939258
# error_data3_score_W0 0.04423774253679257
# combinedweight shape1 : (200, 37)
# right_data3_score_W' 0.16766652140715957
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.1815591371657994
# error_data4_score_W0 0.07101423788459447
# combinedweight shape1 : (240, 37)
# right_data4_score_W' 0.1181954522164462
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.1486409136787547
# error_data5_score_W0 0.0485016515944749
# combinedweight shape1 : (280, 37)
# right_data5_score_W' 0.09780195386519266
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.205798559139498
# error_data6_score_W0 0.04182965022212996
# combinedweight shape1 : (320, 37)
# right_data6_score_W' 0.0775668593241344
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.33179048377224846
# error_data7_score_W0 0.059208763756775654
# combinedweight shape1 : (360, 37)
# right_data7_score_W' 0.13384324672249187
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7824620014137862
# error_data8_score_W0 0.20271906359570602
# combinedweight shape1 : (400, 37)
# right_data8_score_W' 0.24857629054290756
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (440, 37)
# right_data9_score_W' 0.4473269165339237
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4065798306978879
# all_train_score_W': 1.0
# test_score_W0 : 0.40823894261061144
# test_score_W': 0.7297544080290133
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.4348327144346681
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35409820284132476
# error_data0_score_W0 0.444173759130534
# combinedweight shape 0: (90, 37)
# right_data0_score_W' 0.6442660551767113
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2527277975734336
# error_data1_score_W0 0.14231865913149
# combinedweight shape1 : (135, 37)
# right_data1_score_W' 0.4363930329578724
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1697144029312532
# error_data2_score_W0 0.04726174508570384
# combinedweight shape1 : (180, 37)
# right_data2_score_W' 0.36217511851518036
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.15538811448678838
# error_data3_score_W0 0.04298097141723855
# combinedweight shape1 : (225, 37)
# right_data3_score_W' 0.2708270313060394
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.16382071940826412
# error_data4_score_W0 0.0367826694424727
# combinedweight shape1 : (270, 37)
# right_data4_score_W' 0.16160292688615546
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2185032880310598
# error_data5_score_W0 0.07195529994064424
# combinedweight shape1 : (315, 37)
# right_data5_score_W' 0.15830612849571465
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.25368683554811766
# error_data6_score_W0 0.05908125221590318
# combinedweight shape1 : (360, 37)
# right_data6_score_W' 0.1959841930841255
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5366918834810736
# error_data7_score_W0 0.12346625020007503
# combinedweight shape1 : (405, 37)
# right_data7_score_W' 0.22693476087138847
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.28181212218891777
# combinedweight shape1 : (450, 37)
# right_data8_score_W' 0.3245276090898052
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3632275605082483
# all_train_score_W': 1.0
# test_score_W0 : 0.3621994524455246
# test_score_W': 0.7222581450615992
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.38286351912488337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3121392885872444
# error_data0_score_W0 0.44799113344561753
# combinedweight shape 0: (100, 37)
# right_data0_score_W' 0.5968427305025882
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23517099628212634
# error_data1_score_W0 0.13182364105167876
# combinedweight shape1 : (150, 37)
# right_data1_score_W' 0.37313199499355537
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.14292714914309676
# error_data2_score_W0 0.06584573402605562
# combinedweight shape1 : (200, 37)
# right_data2_score_W' 0.29214969470195473
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1702046721633897
# error_data3_score_W0 0.06504368365301468
# combinedweight shape1 : (250, 37)
# right_data3_score_W' 0.15821188096656383
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.16970942076682702
# error_data4_score_W0 0.021011943876232675
# combinedweight shape1 : (300, 37)
# right_data4_score_W' 0.14069591320422775
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.20427580822580996
# error_data5_score_W0 0.08513940303347765
# combinedweight shape1 : (350, 37)
# right_data5_score_W' 0.1117432753925889
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.19880537762346112
# error_data6_score_W0 0.047876543025059566
# combinedweight shape1 : (400, 37)
# right_data6_score_W' 0.16456199687483072
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5162472819421455
# error_data7_score_W0 0.10588185358401168
# combinedweight shape1 : (450, 37)
# right_data7_score_W' 0.2665580062633584
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.35047301954979054
# combinedweight shape1 : (500, 37)
# right_data8_score_W' 0.22680914499179347
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3990867610270924
# all_train_score_W': 1.0
# test_score_W0 : 0.39977630812724746
# test_score_W': 0.7406425451931664
# neuron unit number: 55
# *******************
#
# Error Data percentage 0.3539246711910293
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32940178918892665
# error_data0_score_W0 0.4752718311124732
# combinedweight shape 0: (110, 37)
# right_data0_score_W' 0.5882988833836634
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2108853585232899
# error_data1_score_W0 0.08236684042025727
# combinedweight shape1 : (165, 37)
# right_data1_score_W' 0.4627684206696632
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1433299473280102
# error_data2_score_W0 0.0425631471052536
# combinedweight shape1 : (220, 37)
# right_data2_score_W' 0.28893068981592823
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1450589503088992
# error_data3_score_W0 0.05743040357947123
# combinedweight shape1 : (275, 37)
# right_data3_score_W' 0.19028546125323817
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.11714219974313816
# error_data4_score_W0 0.02662301088750827
# combinedweight shape1 : (330, 37)
# right_data4_score_W' 0.1341307757027809
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.1913524168878566
# error_data5_score_W0 0.034494425749015144
# combinedweight shape1 : (385, 37)
# right_data5_score_W' 0.11565736873703729
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.29474742770340095
# error_data6_score_W0 0.054917344166959
# combinedweight shape1 : (440, 37)
# right_data6_score_W' 0.14915929313039902
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.45507365474918554
# error_data7_score_W0 0.10305529777492532
# combinedweight shape1 : (495, 37)
# right_data7_score_W' 0.15554915669964767
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.20901255298144822
# combinedweight shape1 : (550, 37)
# right_data8_score_W' 0.4941039994379303
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4276668535622842
# all_train_score_W': 1.0
# test_score_W0 : 0.4261590715389765
# test_score_W': 0.7432007093099694
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.35044908262754493
# right_data0_score_W0 1.0
# error_data0_score_W1 0.29991528425405617
# error_data0_score_W0 0.44404221634558927
# combinedweight shape 0: (120, 37)
# right_data0_score_W' 0.6353007446226964
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.23323297639232735
# error_data1_score_W0 0.14425769571307054
# combinedweight shape1 : (180, 37)
# right_data1_score_W' 0.4164091966116487
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.18210411075581223
# error_data2_score_W0 0.06748487723957891
# combinedweight shape1 : (240, 37)
# right_data2_score_W' 0.3095094896099148
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1901726231135872
# error_data3_score_W0 0.06224441476129837
# combinedweight shape1 : (300, 37)
# right_data3_score_W' 0.15300187626423734
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.15062678970482582
# error_data4_score_W0 0.02443837854806609
# combinedweight shape1 : (360, 37)
# right_data4_score_W' 0.08880245888205954
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.21792877150448267
# error_data5_score_W0 0.05337929159473078
# combinedweight shape1 : (420, 37)
# right_data5_score_W' 0.10917976774806053
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.30932493803111455
# error_data6_score_W0 0.05478193377186813
# combinedweight shape1 : (480, 37)
# right_data6_score_W' 0.19837605723389262
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7421510925940905
# error_data7_score_W0 0.0746285646491647
# combinedweight shape1 : (540, 37)
# right_data7_score_W' 0.08805875798561279
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.45561065219097147
# combinedweight shape1 : (600, 37)
# right_data8_score_W' 0.516650170375699
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.43327666901351325
# all_train_score_W': 1.0
# test_score_W0 : 0.4275875804728421
# test_score_W': 0.7410373227826311
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.37399162200230485
# right_data0_score_W0 1.0
# error_data0_score_W1 0.32510363238021883
# error_data0_score_W0 0.4464347498707089
# combinedweight shape 0: (130, 37)
# right_data0_score_W' 0.6247608961360401
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20825920220354413
# error_data1_score_W0 0.11731606755606841
# combinedweight shape1 : (195, 37)
# right_data1_score_W' 0.39879245170443434
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.16795717499242477
# error_data2_score_W0 0.04517581342384137
# combinedweight shape1 : (260, 37)
# right_data2_score_W' 0.2975988537274722
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.15620497179933068
# error_data3_score_W0 0.03891790761949659
# combinedweight shape1 : (325, 37)
# right_data3_score_W' 0.211141778562015
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.14610168707237375
# error_data4_score_W0 0.015196046386575478
# combinedweight shape1 : (390, 37)
# right_data4_score_W' 0.1698985618612481
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.19763567749328542
# error_data5_score_W0 0.01732906715071624
# combinedweight shape1 : (455, 37)
# right_data5_score_W' 0.1158168595169277
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3047247958369378
# error_data6_score_W0 0.048348269903296354
# combinedweight shape1 : (520, 37)
# right_data6_score_W' 0.06668963151267225
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6425303640599827
# error_data7_score_W0 0.10016621768260821
# combinedweight shape1 : (585, 37)
# right_data7_score_W' 0.18441232665264137
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.5143707824529806
# combinedweight shape1 : (650, 37)
# right_data8_score_W' 0.3867707783728282
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.39832888065474525
# all_train_score_W': 1.0
# test_score_W0 : 0.3989895562176533
# test_score_W': 0.7282670893580963
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.38286351912488337
# right_data0_score_W0 1.0
# error_data0_score_W1 0.309542469295244
# error_data0_score_W0 0.4842022338772205
# combinedweight shape 0: (140, 37)
# right_data0_score_W' 0.6202122943115268
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.30400119345557336
# error_data1_score_W0 0.17105505207731406
# combinedweight shape1 : (210, 37)
# right_data1_score_W' 0.37382993142516735
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.14119921734261237
# error_data2_score_W0 0.03517253035738921
# combinedweight shape1 : (280, 37)
# right_data2_score_W' 0.32025973190333185
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.20360725367702232
# error_data3_score_W0 0.03718621239164801
# combinedweight shape1 : (350, 37)
# right_data3_score_W' 0.2218262655543184
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.19223562112421405
# error_data4_score_W0 0.04678718424212454
# combinedweight shape1 : (420, 37)
# right_data4_score_W' 0.15452325701080102
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.253433292230256
# error_data5_score_W0 0.020077158645949444
# combinedweight shape1 : (490, 37)
# right_data5_score_W' 0.08185505598141535
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.46408612141829375
# error_data6_score_W0 0.06449507433274622
# combinedweight shape1 : (560, 37)
# right_data6_score_W' 0.11951635442154697
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.9512196177514227
# error_data7_score_W0 0.11594583166361341
# combinedweight shape1 : (630, 37)
# right_data7_score_W' 0.22089482375767464
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (700, 37)
# right_data8_score_W' 0.6282225360293106
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.40572440516954644
# all_train_score_W': 1.0
# test_score_W0 : 0.4051110390898809
# test_score_W': 0.7289812166431463
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.36833921744379605
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2985690300495731
# error_data0_score_W0 0.430219366554181
# combinedweight shape 0: (150, 37)
# right_data0_score_W' 0.6599577716435437
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2584284308142068
# error_data1_score_W0 0.12059731082176715
# combinedweight shape1 : (225, 37)
# right_data1_score_W' 0.3668301230261088
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.18087130875434618
# error_data2_score_W0 0.04982792909115953
# combinedweight shape1 : (300, 37)
# right_data2_score_W' 0.25654200664701515
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.19459523868306136
# error_data3_score_W0 0.03143567921337874
# combinedweight shape1 : (375, 37)
# right_data3_score_W' 0.23787780055231036
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.18693579194778828
# error_data4_score_W0 0.06458204998315366
# combinedweight shape1 : (450, 37)
# right_data4_score_W' 0.11303223937456391
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.31859709343374837
# error_data5_score_W0 0.04282695572509334
# combinedweight shape1 : (525, 37)
# right_data5_score_W' 0.06376717457482965
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6753432874603348
# error_data6_score_W0 0.06300529654914022
# combinedweight shape1 : (600, 37)
# right_data6_score_W' 0.16789101203217388
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.3099064821998488
# combinedweight shape1 : (675, 37)
# right_data7_score_W' 0.33062173533491784
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
