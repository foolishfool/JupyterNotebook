# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CarPrice_Assignment.csv",encoding='latin-1')
csv = csv.drop(columns=['car_ID'])

dataread.changeCategoryTextToInt(csv,"CarName")
dataread.changeCategoryTextToInt(csv,"carbody")
dataread.changeCategoryTextToInt(csv,"drivewheel")
dataread.changeCategoryTextToInt(csv,"fueltype")
dataread.changeCategoryTextToInt(csv,"aspiration")
dataread.changeCategoryTextToInt(csv,"doornumber")
dataread.changeCategoryTextToInt(csv,"cylindernumber")
dataread.changeCategoryTextToInt(csv,"enginelocation")
dataread.changeCategoryTextToInt(csv,"enginetype")
dataread.changeCategoryTextToInt(csv,"fuelsystem")

dataread.stringToIntCarPriceDataSet(csv,"symboling")
                                 
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv_training,csv_training,csv_test,"symboling")
# Out:
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 3
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
#  column number self.data_train_discrete 9

# %%
# softmax vs original

import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.4652777777777778
# train_discrete_score_W0_n 0.1302931293973052
# train_discrete_score_W0_a  0.10968471431282743
# test_discrete_score_W0_p 0.47540983606557374
# test_discrete_score_W0_n 0.19922262236717922
# test_discrete_score_W0 0.16429596336165947
# train_discrete_score_W_discrete_p 0.5902777777777778
# train_discrete_score_W_discrete_n 0.3315365518684121
# train_discrete_score_W_discrete_a 0.24420704784016342
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.5647207924331179
# test_discrete_score_W_discrete_a 0.4948732543723538
# neuron unit number: 10
# train_discrete_score_W0_p 0.4791666666666667
# train_discrete_score_W0_n 0.13770632143821435
# train_discrete_score_W0_a  0.10717509334346181
# test_discrete_score_W0_p 0.4918032786885246
# test_discrete_score_W0_n 0.14222432001298507
# test_discrete_score_W0 0.12562815812309994
# train_discrete_score_W_discrete_p 0.5833333333333334
# train_discrete_score_W_discrete_n 0.29127134932446247
# train_discrete_score_W_discrete_a 0.24278965370446842
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.4672862713018013
# test_discrete_score_W_discrete_a 0.416865125951766
# neuron unit number: 15
# train_discrete_score_W0_p 0.5277777777777778
# train_discrete_score_W0_n 0.20353216153361392
# train_discrete_score_W0_a  0.1723460421294091
# test_discrete_score_W0_p 0.6065573770491803
# test_discrete_score_W0_n 0.32048163587103967
# test_discrete_score_W0 0.31716717074873346
# train_discrete_score_W_discrete_p 0.6388888888888888
# train_discrete_score_W_discrete_n 0.4191123938948094
# train_discrete_score_W_discrete_a 0.3176439092855814
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.5451834678255817
# test_discrete_score_W_discrete_a 0.5060124838632333
# neuron unit number: 20
# train_discrete_score_W0_p 0.5486111111111112
# train_discrete_score_W0_n 0.1943641677478947
# train_discrete_score_W0_a  0.18160947002839187
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.3775423244101592
# test_discrete_score_W0 0.3549893789554167
# train_discrete_score_W_discrete_p 0.5972222222222222
# train_discrete_score_W_discrete_n 0.3439414273814452
# train_discrete_score_W_discrete_a 0.2491990740547135
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.4757545857570327
# test_discrete_score_W_discrete_a 0.4316024685140818
# neuron unit number: 25
# train_discrete_score_W0_p 0.5833333333333334
# train_discrete_score_W0_n 0.2809525138824996
# train_discrete_score_W0_a  0.24379939564671704
# test_discrete_score_W0_p 0.6721311475409836
# test_discrete_score_W0_n 0.5114666372064649
# test_discrete_score_W0 0.4907833466908019
# train_discrete_score_W_discrete_p 0.5972222222222222
# train_discrete_score_W_discrete_n 0.32711922363048845
# train_discrete_score_W_discrete_a 0.253076302666961
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.4261703112223263
# test_discrete_score_W_discrete_a 0.3769178067971848
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# train_discrete_score_W0_p 0.5972222222222222
# train_discrete_score_W0_n 0.3047365459519578
# train_discrete_score_W0_a  0.2574237484723533
# test_discrete_score_W0_p 0.6229508196721312
# test_discrete_score_W0_n 0.3726324539017089
# test_discrete_score_W0 0.39600043238568805
# train_discrete_score_W_discrete_p 0.625
# train_discrete_score_W_discrete_n 0.3526102582740034
# train_discrete_score_W_discrete_a 0.29233165387818466
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.4833824563806924
# test_discrete_score_W_discrete_a 0.4369582402317601
# neuron unit number: 35
# train_discrete_score_W0_p 0.5416666666666666
# train_discrete_score_W0_n 0.19426438337975843
# train_discrete_score_W0_a  0.18628430882289287
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.3663703300113837
# test_discrete_score_W0 0.3423141344176073
# train_discrete_score_W_discrete_p 0.6180555555555556
# train_discrete_score_W_discrete_n 0.40790996691954207
# train_discrete_score_W_discrete_a 0.2904021928776182
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.5053212921800507
# test_discrete_score_W_discrete_a 0.47697055548353945
# neuron unit number: 40
# train_discrete_score_W0_p 0.5555555555555556
# train_discrete_score_W0_n 0.2488884171378936
# train_discrete_score_W0_a  0.20195662490802174
# test_discrete_score_W0_p 0.6229508196721312
# test_discrete_score_W0_n 0.34527055354392
# test_discrete_score_W0 0.3031029254458539
# train_discrete_score_W_discrete_p 0.5902777777777778
# train_discrete_score_W_discrete_n 0.3537407803633846
# train_discrete_score_W_discrete_a 0.2708755628404397
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.47506541900114213
# test_discrete_score_W_discrete_a 0.42408368724911844
# neuron unit number: 45
# train_discrete_score_W0_p 0.625
# train_discrete_score_W0_n 0.3216471981712852
# train_discrete_score_W0_a  0.2901299181947363
# test_discrete_score_W0_p 0.6065573770491803
# test_discrete_score_W0_n 0.3330140595811522
# test_discrete_score_W0 0.23245957717402702
# train_discrete_score_W_discrete_p 0.6041666666666666
# train_discrete_score_W_discrete_n 0.3275235144223392
# train_discrete_score_W_discrete_a 0.26121816264259473
# test_discrete_score_W_discrete_p 0.7213114754098361
# test_discrete_score_W_discrete_n 0.5351817077883109
# test_discrete_score_W_discrete_a 0.47194408712542885
# neuron unit number: 50
# train_discrete_score_W0_p 0.5694444444444444
# train_discrete_score_W0_n 0.2333509830403088
# train_discrete_score_W0_a  0.19713154066084762
# test_discrete_score_W0_p 0.6721311475409836
# test_discrete_score_W0_n 0.4153783972331189
# test_discrete_score_W0 0.39531041494566943
# train_discrete_score_W_discrete_p 0.6597222222222222
# train_discrete_score_W_discrete_n 0.38653362267873287
# train_discrete_score_W_discrete_a 0.3203791230247271
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.546369485407448
# test_discrete_score_W_discrete_a 0.5045756862768955
# neuron unit number: 55
# train_discrete_score_W0_p 0.625
# train_discrete_score_W0_n 0.3370134442588112
# train_discrete_score_W0_a  0.2987800414377641
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.4870554218317773
# test_discrete_score_W0 0.44773882031416357
# train_discrete_score_W_discrete_p 0.6388888888888888
# train_discrete_score_W_discrete_n 0.40591615790354674
# train_discrete_score_W_discrete_a 0.32034985972522995
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.4083217935393606
# test_discrete_score_W_discrete_a 0.35897722546919647
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 60
# train_discrete_score_W0_p 0.6597222222222222
# train_discrete_score_W0_n 0.3525046279440532
# train_discrete_score_W0_a  0.3167236624440535
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.5414952730495647
# test_discrete_score_W0 0.5124774110093672
# train_discrete_score_W_discrete_p 0.625
# train_discrete_score_W_discrete_n 0.3978316344307387
# train_discrete_score_W_discrete_a 0.3033957944961269
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.48566400038243607
# test_discrete_score_W_discrete_a 0.3885294879881862
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 65
# train_discrete_score_W0_p 0.5625
# train_discrete_score_W0_n 0.22400307714916412
# train_discrete_score_W0_a  0.22497720146090092
# test_discrete_score_W0_p 0.639344262295082
# test_discrete_score_W0_n 0.39483487888663327
# test_discrete_score_W0 0.38503271501537584
# train_discrete_score_W_discrete_p 0.6111111111111112
# train_discrete_score_W_discrete_n 0.3470514468553515
# train_discrete_score_W_discrete_a 0.2717638856867418
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.42659207857351317
# test_discrete_score_W_discrete_a 0.3857456207559313
# neuron unit number: 70
# train_discrete_score_W0_p 0.6388888888888888
# train_discrete_score_W0_n 0.34041482694429537
# train_discrete_score_W0_a  0.2994354292258048
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.4271547797395325
# test_discrete_score_W0 0.35848901270354283
# train_discrete_score_W_discrete_p 0.6180555555555556
# train_discrete_score_W_discrete_n 0.3709086578866795
# train_discrete_score_W_discrete_a 0.28818592069022525
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.43172714362184816
# test_discrete_score_W_discrete_a 0.4096074756215766
# neuron unit number: 75
# train_discrete_score_W0_p 0.6388888888888888
# train_discrete_score_W0_n 0.3194872994696869
# train_discrete_score_W0_a  0.30507914777388706
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.5076534650476424
# test_discrete_score_W0 0.48631843172295613
# train_discrete_score_W_discrete_p 0.6180555555555556
# train_discrete_score_W_discrete_n 0.3514604210383973
# train_discrete_score_W_discrete_a 0.2734239022076432
# test_discrete_score_W_discrete_p 0.6557377049180327
# test_discrete_score_W_discrete_n 0.41434886642686775
# test_discrete_score_W_discrete_a 0.3571957837071963
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 80
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.3178308737760158
# train_discrete_score_W0_a  0.29123837594915525
# test_discrete_score_W0_p 0.6885245901639344
# test_discrete_score_W0_n 0.43894844164439556
# test_discrete_score_W0 0.39741445818870563
# train_discrete_score_W_discrete_p 0.6041666666666666
# train_discrete_score_W_discrete_n 0.39192351701982947
# train_discrete_score_W_discrete_a 0.27657215431527327
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.4565138668929705
# test_discrete_score_W_discrete_a 0.3912095352405573
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# train_discrete_score_W0_p 0.6527777777777778
# train_discrete_score_W0_n 0.38075174110668736
# train_discrete_score_W0_a  0.3444575271921954
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.5422416447245073
# test_discrete_score_W0 0.5081420368273081
# train_discrete_score_W_discrete_p 0.6527777777777778
# train_discrete_score_W_discrete_n 0.38483058340961446
# train_discrete_score_W_discrete_a 0.31539377208401753
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.4814138447793058
# test_discrete_score_W_discrete_a 0.40168643642003626
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 90
# train_discrete_score_W0_p 0.6527777777777778
# train_discrete_score_W0_n 0.35418608881574654
# train_discrete_score_W0_a  0.29648831347387716
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.41269153253288887
# test_discrete_score_W0 0.3815549406118825
# train_discrete_score_W_discrete_p 0.6527777777777778
# train_discrete_score_W_discrete_n 0.3652816191922718
# train_discrete_score_W_discrete_a 0.3208597019096507
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.4396233279927491
# test_discrete_score_W_discrete_a 0.3645158160743242
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# train_discrete_score_W0_p 0.6736111111111112
# train_discrete_score_W0_n 0.36676844113918
# train_discrete_score_W0_a  0.3452730237068623
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.45290971898384874
# test_discrete_score_W0 0.39869185987791234
# train_discrete_score_W_discrete_p 0.6527777777777778
# train_discrete_score_W_discrete_n 0.39825845852421476
# train_discrete_score_W_discrete_a 0.3326885856189218
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.5572366244008712
# test_discrete_score_W_discrete_a 0.49622497196296766
# neuron unit number: 100
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.3154197768458805
# train_discrete_score_W0_a  0.2909413817224088
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.4919218937585905
# test_discrete_score_W0 0.5348032934437059
# train_discrete_score_W_discrete_p 0.6180555555555556
# train_discrete_score_W_discrete_n 0.3609613617371918
# train_discrete_score_W_discrete_a 0.29192846083253515
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.4803054126778629
# test_discrete_score_W_discrete_a 0.4448742716981479
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.277906  0.076542  0.017115   0.242083  0.313729
# 1  train_dis_W_dis  20.0  0.365786  0.033145  0.007411   0.350274  0.381298
# 2         combined  40.0  0.321846  0.073278  0.011586   0.298410  0.345281
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0879
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -4.7118
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -1.4900
# 7                                    Hedge's g =   -1.4604
# 8                                Glass's delta =   -1.1481
# 9                                  Pearson's r =    0.6073
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.404026  0.104730  0.023418   0.355010  0.453041
# 1  test_dis_W_dis  20.0  0.480309  0.048904  0.010935   0.457421  0.503197
# 2        combined  40.0  0.442167  0.089447  0.014143   0.413561  0.470774
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0763
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.9515
# 3                      Two side test p value =    0.0054
# 4                     Difference < 0 p value =    0.0027
# 5                     Difference > 0 p value =    0.9973
# 6                                  Cohen's d =   -0.9333
# 7                                  Hedge's g =   -0.9148
# 8                              Glass's delta =   -0.7284
# 9                                Pearson's r =    0.4318
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.248047  0.071840  0.016064   0.214425  0.281669
# 1  train_dis_W_dis  20.0  0.286834  0.028428  0.006357   0.273529  0.300139
# 2         combined  40.0  0.267440  0.057391  0.009074   0.249086  0.285795
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0388
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -2.2452
# 3                        Two side test p value =    0.0307
# 4                       Difference < 0 p value =    0.0153
# 5                       Difference > 0 p value =    0.9847
# 6                                    Cohen's d =   -0.7100
# 7                                    Hedge's g =   -0.6959
# 8                                Glass's delta =   -0.5399
# 9                                  Pearson's r =    0.3422
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.376636  0.110600  0.024731   0.324873  0.428398
# 1  test_dis_W_dis  20.0  0.426969  0.050287  0.011244   0.403434  0.450503
# 2        combined  40.0  0.401802  0.088549  0.014001   0.373483  0.430121
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0503
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -1.8527
# 3                      Two side test p value =    0.0717
# 4                     Difference < 0 p value =    0.0359
# 5                     Difference > 0 p value =    0.9641
# 6                                  Cohen's d =   -0.5859
# 7                                  Hedge's g =   -0.5742
# 8                              Glass's delta =   -0.4551
# 9                                Pearson's r =    0.2878
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.591667  0.059252  0.013249   0.563936  0.619397
# 1  train_dis_W_dis  20.0  0.619792  0.023292  0.005208   0.608890  0.630693
# 2         combined  40.0  0.605729  0.046664  0.007378   0.590805  0.620653
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0281
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -1.9756
# 3                        Two side test p value =    0.0555
# 4                       Difference < 0 p value =    0.0277
# 5                       Difference > 0 p value =    0.9723
# 6                                    Cohen's d =   -0.6247
# 7                                    Hedge's g =   -0.6123
# 8                                Glass's delta =   -0.4747
# 9                                  Pearson's r =    0.3052
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.650000  0.067962  0.015197   0.618193  0.681807
# 1  test_dis_W_dis  20.0  0.695902  0.026313  0.005884   0.683587  0.708216
# 2        combined  40.0  0.672951  0.055927  0.008843   0.655065  0.690837
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0459
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.8167
# 3                      Two side test p value =    0.0077
# 4                     Difference < 0 p value =    0.0038
# 5                     Difference > 0 p value =    0.9962
# 6                                  Cohen's d =   -0.8907
# 7                                  Hedge's g =   -0.8730
# 8                              Glass's delta =   -0.6754
# 9                                Pearson's r =    0.4156
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
#compare softmax

import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.5416666666666666
# train_discrete_score_W0_n 0.2369038298135141
# train_discrete_score_W0_a  0.1901954640724131
# test_discrete_score_W0_p 0.6885245901639344
# test_discrete_score_W0_n 0.4089896888772637
# test_discrete_score_W0 0.3880558463901406
# train_discrete_score_W_discrete_p 0.5486111111111112
# train_discrete_score_W_discrete_n 0.25482213856853186
# train_discrete_score_W_discrete_a 0.21462999152549275
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.4327001135442839
# test_discrete_score_W_discrete_a 0.39830590312745734
# neuron unit number: 10
# train_discrete_score_W0_p 0.6041666666666666
# train_discrete_score_W0_n 0.32683628015864985
# train_discrete_score_W0_a  0.2865728600390197
# test_discrete_score_W0_p 0.7540983606557377
# test_discrete_score_W0_n 0.5650958561473336
# test_discrete_score_W0 0.5064865842399322
# train_discrete_score_W_discrete_p 0.6319444444444444
# train_discrete_score_W_discrete_n 0.3478219495943364
# train_discrete_score_W_discrete_a 0.3009469679164139
# test_discrete_score_W_discrete_p 0.7868852459016393
# test_discrete_score_W_discrete_n 0.6325573359557485
# test_discrete_score_W_discrete_a 0.6073790945458867
# neuron unit number: 15
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.3032525560458168
# train_discrete_score_W0_a  0.29921031029167766
# test_discrete_score_W0_p 0.7377049180327869
# test_discrete_score_W0_n 0.5134904907450296
# test_discrete_score_W0 0.45139807643709773
# train_discrete_score_W_discrete_p 0.625
# train_discrete_score_W_discrete_n 0.3214035313369269
# train_discrete_score_W_discrete_a 0.2823972009911261
# test_discrete_score_W_discrete_p 0.7868852459016393
# test_discrete_score_W_discrete_n 0.5968681272176827
# test_discrete_score_W_discrete_a 0.5351839120798819
# neuron unit number: 20
# train_discrete_score_W0_p 0.5902777777777778
# train_discrete_score_W0_n 0.2709173825272228
# train_discrete_score_W0_a  0.26531271473391194
# test_discrete_score_W0_p 0.7377049180327869
# test_discrete_score_W0_n 0.5102759450641378
# test_discrete_score_W0 0.4638238732063802
# train_discrete_score_W_discrete_p 0.5416666666666666
# train_discrete_score_W_discrete_n 0.2549333555206065
# train_discrete_score_W_discrete_a 0.23109391648355537
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.47750278982336475
# test_discrete_score_W_discrete_a 0.40000570201281055
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# train_discrete_score_W0_p 0.5902777777777778
# train_discrete_score_W0_n 0.2708437711788967
# train_discrete_score_W0_a  0.27108523489828995
# test_discrete_score_W0_p 0.7540983606557377
# test_discrete_score_W0_n 0.5430846427869975
# test_discrete_score_W0 0.5072606925583671
# train_discrete_score_W_discrete_p 0.6319444444444444
# train_discrete_score_W_discrete_n 0.36918824774145137
# train_discrete_score_W_discrete_a 0.3131428334949081
# test_discrete_score_W_discrete_p 0.7540983606557377
# test_discrete_score_W_discrete_n 0.5702165151521569
# test_discrete_score_W_discrete_a 0.4928669815033451
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# train_discrete_score_W0_p 0.5625
# train_discrete_score_W0_n 0.2917229324246283
# train_discrete_score_W0_a  0.2536884376935792
# test_discrete_score_W0_p 0.6885245901639344
# test_discrete_score_W0_n 0.5247463573503844
# test_discrete_score_W0 0.45209941370393036
# train_discrete_score_W_discrete_p 0.5625
# train_discrete_score_W_discrete_n 0.29468318069566457
# train_discrete_score_W_discrete_a 0.24914214843068694
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.47263272362385184
# test_discrete_score_W_discrete_a 0.4139193303239293
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# train_discrete_score_W0_p 0.5486111111111112
# train_discrete_score_W0_n 0.2294340194845997
# train_discrete_score_W0_a  0.2040552575364481
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.485915699846469
# test_discrete_score_W0 0.40295175705957603
# train_discrete_score_W_discrete_p 0.625
# train_discrete_score_W_discrete_n 0.36505667026170996
# train_discrete_score_W_discrete_a 0.3101648775095216
# test_discrete_score_W_discrete_p 0.7213114754098361
# test_discrete_score_W_discrete_n 0.4694319638908282
# test_discrete_score_W_discrete_a 0.4306210804584512
# Not good nmi result for discrete features !!!!!
# neuron unit number: 40
# train_discrete_score_W0_p 0.625
# train_discrete_score_W0_n 0.3307499441063137
# train_discrete_score_W0_a  0.29667936802678596
# test_discrete_score_W0_p 0.7868852459016393
# test_discrete_score_W0_n 0.64062225105932
# test_discrete_score_W0 0.6140423722948859
# train_discrete_score_W_discrete_p 0.5833333333333334
# train_discrete_score_W_discrete_n 0.35360641749418276
# train_discrete_score_W_discrete_a 0.28596122364573034
# test_discrete_score_W_discrete_p 0.7213114754098361
# test_discrete_score_W_discrete_n 0.4779629837865191
# test_discrete_score_W_discrete_a 0.4266573342665733
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.3082201467064572
# train_discrete_score_W0_a  0.2820806375686835
# test_discrete_score_W0_p 0.7540983606557377
# test_discrete_score_W0_n 0.6036370112581683
# test_discrete_score_W0 0.5502636242315517
# train_discrete_score_W_discrete_p 0.6180555555555556
# train_discrete_score_W_discrete_n 0.3571961710978002
# train_discrete_score_W_discrete_a 0.29451628188355483
# test_discrete_score_W_discrete_p 0.7540983606557377
# test_discrete_score_W_discrete_n 0.5749521594683358
# test_discrete_score_W_discrete_a 0.49067424865749104
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# train_discrete_score_W0_p 0.5972222222222222
# train_discrete_score_W0_n 0.28958318726567456
# train_discrete_score_W0_a  0.255308695451434
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.48685555676768016
# test_discrete_score_W0 0.42733540043284873
# train_discrete_score_W_discrete_p 0.5833333333333334
# train_discrete_score_W_discrete_n 0.2889361358267832
# train_discrete_score_W_discrete_a 0.2481656239103515
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.5046262462551185
# test_discrete_score_W_discrete_a 0.437072583152005
# neuron unit number: 55
# train_discrete_score_W0_p 0.5416666666666666
# train_discrete_score_W0_n 0.2512805893700286
# train_discrete_score_W0_a  0.2176620353031466
# test_discrete_score_W0_p 0.7540983606557377
# test_discrete_score_W0_n 0.5925827768618637
# test_discrete_score_W0 0.5455337370995769
# train_discrete_score_W_discrete_p 0.6180555555555556
# train_discrete_score_W_discrete_n 0.3457624730170405
# train_discrete_score_W_discrete_a 0.3013721577024593
# test_discrete_score_W_discrete_p 0.7540983606557377
# test_discrete_score_W_discrete_n 0.5545590414624846
# test_discrete_score_W_discrete_a 0.5403286771539043
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 60
# train_discrete_score_W0_p 0.5833333333333334
# train_discrete_score_W0_n 0.26482701881442317
# train_discrete_score_W0_a  0.23209818791138448
# test_discrete_score_W0_p 0.6885245901639344
# test_discrete_score_W0_n 0.44640708244341115
# test_discrete_score_W0 0.38147529901913446
# train_discrete_score_W_discrete_p 0.6388888888888888
# train_discrete_score_W_discrete_n 0.3609254945344375
# train_discrete_score_W_discrete_a 0.3140771665494726
# test_discrete_score_W_discrete_p 0.7704918032786885
# test_discrete_score_W_discrete_n 0.560159963153615
# test_discrete_score_W_discrete_a 0.5139144293245066
# neuron unit number: 65
# train_discrete_score_W0_p 0.5902777777777778
# train_discrete_score_W0_n 0.29940365842996075
# train_discrete_score_W0_a  0.2490476837746533
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.4354368613179905
# test_discrete_score_W0 0.3987030541995806
# train_discrete_score_W_discrete_p 0.6041666666666666
# train_discrete_score_W_discrete_n 0.294266847342435
# train_discrete_score_W_discrete_a 0.2595869790408959
# test_discrete_score_W_discrete_p 0.7213114754098361
# test_discrete_score_W_discrete_n 0.525210721700822
# test_discrete_score_W_discrete_a 0.4650221119217779
# neuron unit number: 70
# train_discrete_score_W0_p 0.5902777777777778
# train_discrete_score_W0_n 0.2817922179717356
# train_discrete_score_W0_a  0.22957818540853236
# test_discrete_score_W0_p 0.7377049180327869
# test_discrete_score_W0_n 0.5385773005751014
# test_discrete_score_W0 0.5085831914592567
# train_discrete_score_W_discrete_p 0.6041666666666666
# train_discrete_score_W_discrete_n 0.3130635332735088
# train_discrete_score_W_discrete_a 0.26743998878364705
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.5042071751306858
# test_discrete_score_W_discrete_a 0.47979322634739696
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 75
# train_discrete_score_W0_p 0.5833333333333334
# train_discrete_score_W0_n 0.256753991536674
# train_discrete_score_W0_a  0.22032234543691076
# test_discrete_score_W0_p 0.7377049180327869
# test_discrete_score_W0_n 0.5077162757713204
# test_discrete_score_W0 0.4906327554999907
# train_discrete_score_W_discrete_p 0.5694444444444444
# train_discrete_score_W_discrete_n 0.2913537333186661
# train_discrete_score_W_discrete_a 0.2439085855476228
# test_discrete_score_W_discrete_p 0.7049180327868853
# test_discrete_score_W_discrete_n 0.45512758949408033
# test_discrete_score_W_discrete_a 0.41385226613757375
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 80
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.33661275112449773
# train_discrete_score_W0_a  0.2970823867736854
# test_discrete_score_W0_p 0.7704918032786885
# test_discrete_score_W0_n 0.5777080500652285
# test_discrete_score_W0 0.548429381088447
# train_discrete_score_W_discrete_p 0.5277777777777778
# train_discrete_score_W_discrete_n 0.24602989294704236
# train_discrete_score_W_discrete_a 0.2039221348627672
# test_discrete_score_W_discrete_p 0.6721311475409836
# test_discrete_score_W_discrete_n 0.4612529343029143
# test_discrete_score_W_discrete_a 0.3641021071858155
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# train_discrete_score_W0_p 0.6388888888888888
# train_discrete_score_W0_n 0.3463161779923834
# train_discrete_score_W0_a  0.3144028790286727
# test_discrete_score_W0_p 0.7704918032786885
# test_discrete_score_W0_n 0.5786717442348471
# test_discrete_score_W0 0.5144328842886284
# train_discrete_score_W_discrete_p 0.5833333333333334
# train_discrete_score_W_discrete_n 0.2963859056101089
# train_discrete_score_W_discrete_a 0.2649977858749417
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.5333591966576665
# test_discrete_score_W_discrete_a 0.4802791684466695
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 90
# train_discrete_score_W0_p 0.5972222222222222
# train_discrete_score_W0_n 0.3314170075444355
# train_discrete_score_W0_a  0.26903847565720884
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.5232278348078637
# test_discrete_score_W0 0.41068692118062494
# train_discrete_score_W_discrete_p 0.5763888888888888
# train_discrete_score_W_discrete_n 0.27322107394399464
# train_discrete_score_W_discrete_a 0.2536751058324848
# test_discrete_score_W_discrete_p 0.7377049180327869
# test_discrete_score_W_discrete_n 0.5383208172086313
# test_discrete_score_W_discrete_a 0.46603890738138476
# neuron unit number: 95
# train_discrete_score_W0_p 0.5972222222222222
# train_discrete_score_W0_n 0.2640762797584692
# train_discrete_score_W0_a  0.2827650647284494
# test_discrete_score_W0_p 0.7377049180327869
# test_discrete_score_W0_n 0.5168648717534625
# test_discrete_score_W0 0.4898584183372989
# train_discrete_score_W_discrete_p 0.5833333333333334
# train_discrete_score_W_discrete_n 0.26914998581856087
# train_discrete_score_W_discrete_a 0.234813032066645
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.4360358846849383
# test_discrete_score_W_discrete_a 0.41309753952344175
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# train_discrete_score_W0_p 0.6111111111111112
# train_discrete_score_W0_n 0.316644652080608
# train_discrete_score_W0_a  0.28066443607518343
# test_discrete_score_W0_p 0.7704918032786885
# test_discrete_score_W0_n 0.5928215177708354
# test_discrete_score_W0 0.5270952378652266
# train_discrete_score_W_discrete_p 0.5763888888888888
# train_discrete_score_W_discrete_n 0.2987677527487384
# train_discrete_score_W_discrete_a 0.26013025805047074
# test_discrete_score_W_discrete_p 0.6885245901639344
# test_discrete_score_W_discrete_n 0.4349858478003049
# test_discrete_score_W_discrete_a 0.3544899778300917
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.290379  0.034473  0.007708   0.274246  0.306513
# 1  train_dis_W_dis  20.0  0.309829  0.040315  0.009015   0.290961  0.328697
# 2         combined  40.0  0.300104  0.038311  0.006058   0.287851  0.312357
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0194
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -1.6398
# 3                        Two side test p value =    0.1093
# 4                       Difference < 0 p value =    0.0547
# 5                       Difference > 0 p value =    0.9453
# 6                                    Cohen's d =   -0.5185
# 7                                    Hedge's g =   -0.5082
# 8                                Glass's delta =   -0.5642
# 9                                  Pearson's r =    0.2571
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.529636  0.059570  0.013320   0.501757  0.557516
# 1  test_dis_W_dis  20.0  0.510634  0.058097  0.012991   0.483443  0.537824
# 2        combined  40.0  0.520135  0.058871  0.009308   0.501307  0.538963
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0190
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    1.0213
# 3                      Two side test p value =    0.3136
# 4                     Difference < 0 p value =    0.8432
# 5                     Difference > 0 p value =    0.1568
# 6                                  Cohen's d =    0.3230
# 7                                  Hedge's g =    0.3165
# 8                              Glass's delta =    0.3190
# 9                                Pearson's r =    0.1635
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.259843  0.034674  0.007753   0.243614  0.276071
# 1  train_dis_W_dis  20.0  0.266704  0.032793  0.007333   0.251357  0.282052
# 2         combined  40.0  0.263273  0.033492  0.005296   0.252562  0.273985
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0069
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -0.6430
# 3                        Two side test p value =    0.5241
# 4                       Difference < 0 p value =    0.2620
# 5                       Difference > 0 p value =    0.7380
# 6                                    Cohen's d =   -0.2033
# 7                                    Hedge's g =   -0.1993
# 8                                Glass's delta =   -0.1979
# 9                                  Pearson's r =    0.1037
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.478957  0.064022  0.014316   0.448994  0.508921
# 1  test_dis_W_dis  20.0  0.456180  0.063252  0.014143   0.426578  0.485783
# 2        combined  40.0  0.467569  0.063867  0.010098   0.447143  0.487994
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0228
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    1.1318
# 3                      Two side test p value =    0.2648
# 4                     Difference < 0 p value =    0.8676
# 5                     Difference > 0 p value =    0.1324
# 6                                  Cohen's d =    0.3579
# 7                                  Hedge's g =    0.3508
# 8                              Glass's delta =    0.3558
# 9                                Pearson's r =    0.1806
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.592361  0.027046  0.006048   0.579703  0.605019
# 1  train_dis_W_dis  20.0  0.591667  0.032385  0.007241   0.576510  0.606823
# 2         combined  40.0  0.592014  0.029452  0.004657   0.582595  0.601433
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0007
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.0736
# 3                        Two side test p value =    0.9417
# 4                       Difference < 0 p value =    0.5291
# 5                       Difference > 0 p value =    0.4709
# 6                                    Cohen's d =    0.0233
# 7                                    Hedge's g =    0.0228
# 8                                Glass's delta =    0.0257
# 9                                  Pearson's r =    0.0119
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.736066  0.029566  0.006611   0.722228  0.749903
# 1  test_dis_W_dis  20.0  0.727049  0.033332  0.007453   0.711449  0.742649
# 2        combined  40.0  0.731557  0.031432  0.004970   0.721505  0.741610
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0090
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    0.9050
# 3                      Two side test p value =    0.3712
# 4                     Difference < 0 p value =    0.8144
# 5                     Difference > 0 p value =    0.1856
# 6                                  Cohen's d =    0.2862
# 7                                  Hedge's g =    0.2805
# 8                              Glass's delta =    0.3050
# 9                                Pearson's r =    0.1453
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
#DOSOM

import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.375
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.39344262295081966
# test_discrete_score_W0_n 0.11506079673235795
# test_discrete_score_W0 0.07209651455134118
# train_discrete_score_W_discrete_p 0.5208333333333334
# train_discrete_score_W_discrete_n 0.22231491579375487
# train_discrete_score_W_discrete_a 0.14521380420381003
# test_discrete_score_W_discrete_p 0.5737704918032787
# test_discrete_score_W_discrete_n 0.33546186760181484
# test_discrete_score_W_discrete_a 0.2398599875386883
# neuron unit number: 10
# train_discrete_score_W0_p 0.4791666666666667
# train_discrete_score_W0_n 0.18104694750782954
# train_discrete_score_W0_a  0.10022899066374219
# test_discrete_score_W0_p 0.5081967213114754
# test_discrete_score_W0_n 0.21006959271257694
# test_discrete_score_W0 0.16625285773986578
# train_discrete_score_W_discrete_p 0.5208333333333334
# train_discrete_score_W_discrete_n 0.18081252057278327
# train_discrete_score_W_discrete_a 0.15169908632602147
# test_discrete_score_W_discrete_p 0.5573770491803278
# test_discrete_score_W_discrete_n 0.32851202797384965
# test_discrete_score_W_discrete_a 0.2429742695574707
# neuron unit number: 15
# train_discrete_score_W0_p 0.5555555555555556
# train_discrete_score_W0_n 0.2434247207011598
# train_discrete_score_W0_a  0.21662219678487207
# test_discrete_score_W0_p 0.5573770491803278
# test_discrete_score_W0_n 0.2927658905312382
# test_discrete_score_W0 0.17809494412025537
# train_discrete_score_W_discrete_p 0.5625
# train_discrete_score_W_discrete_n 0.23940949619895682
# train_discrete_score_W_discrete_a 0.20622184304327595
# test_discrete_score_W_discrete_p 0.5901639344262295
# test_discrete_score_W_discrete_n 0.3252809269374051
# test_discrete_score_W_discrete_a 0.231476758026867
# neuron unit number: 20
# train_discrete_score_W0_p 0.5416666666666666
# train_discrete_score_W0_n 0.2135945765310575
# train_discrete_score_W0_a  0.20028253517351285
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.4174669511878693
# test_discrete_score_W0 0.3482354113222585
# train_discrete_score_W_discrete_p 0.5069444444444444
# train_discrete_score_W_discrete_n 0.14629551687268547
# train_discrete_score_W_discrete_a 0.13967770852076353
# test_discrete_score_W_discrete_p 0.6229508196721312
# test_discrete_score_W_discrete_n 0.3717126154702324
# test_discrete_score_W_discrete_a 0.27968586985295263
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# train_discrete_score_W0_p 0.5694444444444444
# train_discrete_score_W0_n 0.2865361051783739
# train_discrete_score_W0_a  0.2594785068111132
# test_discrete_score_W0_p 0.6721311475409836
# test_discrete_score_W0_n 0.3953393320135813
# test_discrete_score_W0 0.3207434989192158
# train_discrete_score_W_discrete_p 0.5486111111111112
# train_discrete_score_W_discrete_n 0.24569115717338924
# train_discrete_score_W_discrete_a 0.2066825519731454
# test_discrete_score_W_discrete_p 0.639344262295082
# test_discrete_score_W_discrete_n 0.36781022513804046
# test_discrete_score_W_discrete_a 0.33282227311123375
# Not good nmi result for discrete features !!!!!
# neuron unit number: 30
# train_discrete_score_W0_p 0.5347222222222222
# train_discrete_score_W0_n 0.18110290738722143
# train_discrete_score_W0_a  0.14935668598446417
# test_discrete_score_W0_p 0.6229508196721312
# test_discrete_score_W0_n 0.3551312462720785
# test_discrete_score_W0 0.24274226115395928
# train_discrete_score_W_discrete_p 0.5069444444444444
# train_discrete_score_W_discrete_n 0.15620011602277223
# train_discrete_score_W_discrete_a 0.11229406347891475
# test_discrete_score_W_discrete_p 0.5901639344262295
# test_discrete_score_W_discrete_n 0.325679005434494
# test_discrete_score_W_discrete_a 0.24400788137275312
# Not good nmi result for discrete features !!!!!
# neuron unit number: 35
# train_discrete_score_W0_p 0.5694444444444444
# train_discrete_score_W0_n 0.2187528336622788
# train_discrete_score_W0_a  0.19797871975454137
# test_discrete_score_W0_p 0.6721311475409836
# test_discrete_score_W0_n 0.4225465777577997
# test_discrete_score_W0 0.31720598235869335
# train_discrete_score_W_discrete_p 0.5625
# train_discrete_score_W_discrete_n 0.24174832478970482
# train_discrete_score_W_discrete_a 0.22082970217696662
# test_discrete_score_W_discrete_p 0.639344262295082
# test_discrete_score_W_discrete_n 0.3823644816552391
# test_discrete_score_W_discrete_a 0.2767685796156576
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# train_discrete_score_W0_p 0.5694444444444444
# train_discrete_score_W0_n 0.2092200689106295
# train_discrete_score_W0_a  0.19760984769370876
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.3885917458582832
# test_discrete_score_W0 0.29506154713245775
# train_discrete_score_W_discrete_p 0.5069444444444444
# train_discrete_score_W_discrete_n 0.14561434877915577
# train_discrete_score_W_discrete_a 0.15383017566758136
# test_discrete_score_W_discrete_p 0.5573770491803278
# test_discrete_score_W_discrete_n 0.31950551784054676
# test_discrete_score_W_discrete_a 0.17315190370273453
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# train_discrete_score_W0_p 0.5555555555555556
# train_discrete_score_W0_n 0.20722285348666164
# train_discrete_score_W0_a  0.16586785817756777
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.37902884588100644
# test_discrete_score_W0 0.305940609926123
# train_discrete_score_W_discrete_p 0.5902777777777778
# train_discrete_score_W_discrete_n 0.2850553980688556
# train_discrete_score_W_discrete_a 0.23933828066929158
# test_discrete_score_W_discrete_p 0.639344262295082
# test_discrete_score_W_discrete_n 0.4410862952730596
# test_discrete_score_W_discrete_a 0.33188942774962876
# neuron unit number: 50
# train_discrete_score_W0_p 0.5625
# train_discrete_score_W0_n 0.2283110708318703
# train_discrete_score_W0_a  0.20512990788001323
# test_discrete_score_W0_p 0.639344262295082
# test_discrete_score_W0_n 0.3677510835147662
# test_discrete_score_W0 0.2709726641911044
# train_discrete_score_W_discrete_p 0.4791666666666667
# train_discrete_score_W_discrete_n 0.11024424562399632
# train_discrete_score_W_discrete_a 0.08848822799486052
# test_discrete_score_W_discrete_p 0.6065573770491803
# test_discrete_score_W_discrete_n 0.3140702242462741
# test_discrete_score_W_discrete_a 0.25707672057733333
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 55
# train_discrete_score_W0_p 0.5972222222222222
# train_discrete_score_W0_n 0.29808120283386375
# train_discrete_score_W0_a  0.2778316168759579
# test_discrete_score_W0_p 0.6721311475409836
# test_discrete_score_W0_n 0.44045841511585987
# test_discrete_score_W0 0.29516840072658757
# train_discrete_score_W_discrete_p 0.5416666666666666
# train_discrete_score_W_discrete_n 0.21261338395738655
# train_discrete_score_W_discrete_a 0.1841755398704187
# test_discrete_score_W_discrete_p 0.6229508196721312
# test_discrete_score_W_discrete_n 0.3551131513517222
# test_discrete_score_W_discrete_a 0.35340412658939435
# Not good nmi result for discrete features !!!!!
# neuron unit number: 60
# train_discrete_score_W0_p 0.5694444444444444
# train_discrete_score_W0_n 0.23481775292646126
# train_discrete_score_W0_a  0.181745444291441
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.454945896887792
# test_discrete_score_W0 0.34192791213747226
# train_discrete_score_W_discrete_p 0.5208333333333334
# train_discrete_score_W_discrete_n 0.17319849655258115
# train_discrete_score_W_discrete_a 0.13498219543410653
# test_discrete_score_W_discrete_p 0.639344262295082
# test_discrete_score_W_discrete_n 0.3920093512898272
# test_discrete_score_W_discrete_a 0.2957753427631222
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 65
# train_discrete_score_W0_p 0.6111111111111112
# train_discrete_score_W0_n 0.2811305374676164
# train_discrete_score_W0_a  0.2773905605102974
# test_discrete_score_W0_p 0.7377049180327869
# test_discrete_score_W0_n 0.517727496447286
# test_discrete_score_W0 0.42861830093722053
# train_discrete_score_W_discrete_p 0.5625
# train_discrete_score_W_discrete_n 0.19844029324950982
# train_discrete_score_W_discrete_a 0.20466339541018752
# test_discrete_score_W_discrete_p 0.5573770491803278
# test_discrete_score_W_discrete_n 0.33383962713874055
# test_discrete_score_W_discrete_a 0.19104193360222158
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 70
# train_discrete_score_W0_p 0.6388888888888888
# train_discrete_score_W0_n 0.3360472085757695
# train_discrete_score_W0_a  0.2975795913965805
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.47355973838237875
# test_discrete_score_W0 0.4088282058400424
# train_discrete_score_W_discrete_p 0.5694444444444444
# train_discrete_score_W_discrete_n 0.2568445861363548
# train_discrete_score_W_discrete_a 0.24343281665234187
# test_discrete_score_W_discrete_p 0.6557377049180327
# test_discrete_score_W_discrete_n 0.38046534806593596
# test_discrete_score_W_discrete_a 0.3391198226694229
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 75
# train_discrete_score_W0_p 0.6111111111111112
# train_discrete_score_W0_n 0.33158533173907934
# train_discrete_score_W0_a  0.2716961914332014
# test_discrete_score_W0_p 0.6885245901639344
# test_discrete_score_W0_n 0.43453350937989027
# test_discrete_score_W0 0.32328998890639327
# train_discrete_score_W_discrete_p 0.5069444444444444
# train_discrete_score_W_discrete_n 0.16088417732447538
# train_discrete_score_W_discrete_a 0.1270019535049003
# test_discrete_score_W_discrete_p 0.639344262295082
# test_discrete_score_W_discrete_n 0.3712480174206234
# test_discrete_score_W_discrete_a 0.3023732927090108
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 80
# train_discrete_score_W0_p 0.5902777777777778
# train_discrete_score_W0_n 0.2485135047451828
# train_discrete_score_W0_a  0.24166033327092765
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.45701809692374934
# test_discrete_score_W0 0.34952413958572154
# train_discrete_score_W_discrete_p 0.5625
# train_discrete_score_W_discrete_n 0.23658739409610696
# train_discrete_score_W_discrete_a 0.22037302378712345
# test_discrete_score_W_discrete_p 0.5901639344262295
# test_discrete_score_W_discrete_n 0.3643087600425591
# test_discrete_score_W_discrete_a 0.2787707249142067
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# train_discrete_score_W0_p 0.6041666666666666
# train_discrete_score_W0_n 0.31038892045018407
# train_discrete_score_W0_a  0.26753936351070084
# test_discrete_score_W0_p 0.6229508196721312
# test_discrete_score_W0_n 0.3726831867177881
# test_discrete_score_W0 0.2997895542376124
# train_discrete_score_W_discrete_p 0.5277777777777778
# train_discrete_score_W_discrete_n 0.19156045763132198
# train_discrete_score_W_discrete_a 0.17441233092963918
# test_discrete_score_W_discrete_p 0.6229508196721312
# test_discrete_score_W_discrete_n 0.37823140225380275
# test_discrete_score_W_discrete_a 0.3175745528824784
# neuron unit number: 90
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.2937276261884422
# train_discrete_score_W0_a  0.30845893050693657
# test_discrete_score_W0_p 0.7049180327868853
# test_discrete_score_W0_n 0.4700295430446957
# test_discrete_score_W0 0.4168835689385556
# train_discrete_score_W_discrete_p 0.5
# train_discrete_score_W_discrete_n 0.1436128456088123
# train_discrete_score_W_discrete_a 0.1055378648364827
# test_discrete_score_W_discrete_p 0.5737704918032787
# test_discrete_score_W_discrete_n 0.32788475102525316
# test_discrete_score_W_discrete_a 0.20473759896335392
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# train_discrete_score_W0_p 0.625
# train_discrete_score_W0_n 0.31941681573150615
# train_discrete_score_W0_a  0.2768251909985146
# test_discrete_score_W0_p 0.6557377049180327
# test_discrete_score_W0_n 0.40629886110253244
# test_discrete_score_W0 0.305400842628486
# train_discrete_score_W_discrete_p 0.5069444444444444
# train_discrete_score_W_discrete_n 0.16328897711549756
# train_discrete_score_W_discrete_a 0.12584395269441573
# test_discrete_score_W_discrete_p 0.5573770491803278
# test_discrete_score_W_discrete_n 0.29050579238176943
# test_discrete_score_W_discrete_a 0.22238992931219928
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# train_discrete_score_W0_p 0.6180555555555556
# train_discrete_score_W0_n 0.3029980043943399
# train_discrete_score_W0_a  0.28877557469217324
# test_discrete_score_W0_p 0.7213114754098361
# test_discrete_score_W0_n 0.4642107593826486
# test_discrete_score_W0 0.44787447601421904
# train_discrete_score_W_discrete_p 0.5138888888888888
# train_discrete_score_W_discrete_n 0.20524716596451192
# train_discrete_score_W_discrete_a 0.15879631347927228
# test_discrete_score_W_discrete_p 0.6065573770491803
# test_discrete_score_W_discrete_n 0.3349547499979784
# test_discrete_score_W_discrete_a 0.25879107687935754
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.246296  0.076134  0.017024   0.210664  0.281928
# 1  train_dis_W_dis  20.0  0.195783  0.046198  0.010330   0.174162  0.217405
# 2         combined  40.0  0.221040  0.067215  0.010628   0.199543  0.242536
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0505
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    2.5367
# 3                        Two side test p value =    0.0154
# 4                       Difference < 0 p value =    0.9923
# 5                       Difference > 0 p value =    0.0077
# 6                                    Cohen's d =    0.8022
# 7                                    Hedge's g =    0.7862
# 8                                Glass's delta =    0.6635
# 9                                  Pearson's r =    0.3805
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.391761  0.094604  0.021154   0.347485  0.436037
# 1  test_dis_W_dis  20.0  0.352002  0.034670  0.007752   0.335776  0.368228
# 2        combined  40.0  0.371882  0.073151  0.011566   0.348487  0.395276
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0398
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    1.7647
# 3                      Two side test p value =    0.0856
# 4                     Difference < 0 p value =    0.9572
# 5                     Difference > 0 p value =    0.0428
# 6                                  Cohen's d =    0.5581
# 7                                  Hedge's g =    0.5470
# 8                              Glass's delta =    0.4203
# 9                                Pearson's r =    0.2752
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.219103  0.075784  0.016946   0.183635  0.254571
# 1  train_dis_W_dis  20.0  0.167175  0.046255  0.010343   0.145527  0.188823
# 2         combined  40.0  0.193139  0.067318  0.010644   0.171609  0.214668
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0519
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    2.6156
# 3                        Two side test p value =    0.0127
# 4                       Difference < 0 p value =    0.9936
# 5                       Difference > 0 p value =    0.0064
# 6                                    Cohen's d =    0.8271
# 7                                    Hedge's g =    0.8107
# 8                                Glass's delta =    0.6852
# 9                                  Pearson's r =    0.3906
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.306733  0.091691  0.020503   0.263820  0.349645
# 1  test_dis_W_dis  20.0  0.268685  0.051247  0.011459   0.244700  0.292669
# 2        combined  40.0  0.287709  0.075806  0.011986   0.263465  0.311952
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0380
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    1.6199
# 3                      Two side test p value =    0.1135
# 4                     Difference < 0 p value =    0.9432
# 5                     Difference > 0 p value =    0.0568
# 6                                  Cohen's d =    0.5123
# 7                                  Hedge's g =    0.5021
# 8                              Glass's delta =    0.4150
# 9                                Pearson's r =    0.2542
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.569792  0.059332  0.013267   0.542023  0.597560
# 1  train_dis_W_dis  20.0  0.530903  0.029504  0.006597   0.517095  0.544711
# 2         combined  40.0  0.550347  0.050268  0.007948   0.534271  0.566424
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0389
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    2.6246
# 3                        Two side test p value =    0.0124
# 4                       Difference < 0 p value =    0.9938
# 5                       Difference > 0 p value =    0.0062
# 6                                    Cohen's d =    0.8300
# 7                                    Hedge's g =    0.8135
# 8                                Glass's delta =    0.6554
# 9                                  Pearson's r =    0.3917
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.648361  0.081444  0.018211   0.610244  0.686477
# 1  test_dis_W_dis  20.0  0.604098  0.033332  0.007453   0.588498  0.619698
# 2        combined  40.0  0.626230  0.065384  0.010338   0.605319  0.647140
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0443
# 1                         Degrees of freedom =   38.0000
# 2                                          t =    2.2494
# 3                      Two side test p value =    0.0304
# 4                     Difference < 0 p value =    0.9848
# 5                     Difference > 0 p value =    0.0152
# 6                                  Cohen's d =    0.7113
# 7                                  Hedge's g =    0.6972
# 8                              Glass's delta =    0.5435
# 9                                Pearson's r =    0.3428
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
# Two Comparision MF

import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
#  all feature number 24
# all_train_score_W0_p 0.4166666666666667
# all_train_score_W0_n 0.14177052580392652
# all_train_score_W0_a 0.08609565539104383
# test_score_W0_p0.4098360655737705
# test_score_W0_n 0.1109736305677308
# test_score_W0_a  0.026127089193723065
#  discrete feature number 10
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.21886723744239744
# all_train_score_W_combine_a 0.18210504456349053
# test_score_W_combine_p0.5409836065573771
# test_score_W_combine_n 0.3473764390685934
# test_score_W_combine_a 0.14790599609057034
# neuron unit number: 10
#  all feature number 24
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.15057950321545066
# all_train_score_W0_a 0.11699310808117114
# test_score_W0_p0.47540983606557374
# test_score_W0_n 0.1950666515895424
# test_score_W0_a  0.06988266335666404
#  discrete feature number 10
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.1952019454778338
# all_train_score_W_combine_a 0.16923837132692054
# test_score_W_combine_p0.5737704918032787
# test_score_W_combine_n 0.37953820108419933
# test_score_W_combine_a 0.14566022085838964
# neuron unit number: 15
#  all feature number 24
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.19087688524024649
# all_train_score_W0_a 0.15681816171071142
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.21641333315191755
# test_score_W0_a  0.15899115909899061
#  discrete feature number 10
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.1949254049757711
# all_train_score_W_combine_a 0.16366417206631198
# test_score_W_combine_p0.5901639344262295
# test_score_W_combine_n 0.3127983109816215
# test_score_W_combine_a 0.17966154124433598
# neuron unit number: 20
#  all feature number 24
# all_train_score_W0_p 0.5347222222222222
# all_train_score_W0_n 0.22503062804181276
# all_train_score_W0_a 0.1876404717863039
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.24281628670636057
# test_score_W0_a  0.15035297150573226
#  discrete feature number 10
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.250757628802021
# all_train_score_W_combine_a 0.18014808474213567
# test_score_W_combine_p0.5573770491803278
# test_score_W_combine_n 0.39065393414448696
# test_score_W_combine_a 0.16634918193797338
# neuron unit number: 25
#  all feature number 24
# all_train_score_W0_p 0.5208333333333334
# all_train_score_W0_n 0.199639259755601
# all_train_score_W0_a 0.1495806629763296
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.39191041790174297
# test_score_W0_a  0.24187769908682458
#  discrete feature number 10
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.21163048026785403
# all_train_score_W_combine_a 0.18875061312880842
# test_score_W_combine_p0.5901639344262295
# test_score_W_combine_n 0.37873336531993357
# test_score_W_combine_a 0.19204701836977897
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 30
#  all feature number 24
# all_train_score_W0_p 0.5277777777777778
# all_train_score_W0_n 0.2038900087858246
# all_train_score_W0_a 0.1609053234318716
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.23869486882647273
# test_score_W0_a  0.1602580499210143
#  discrete feature number 10
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.22598323998524694
# all_train_score_W_combine_a 0.15976062665217886
# test_score_W_combine_p0.5409836065573771
# test_score_W_combine_n 0.3200558101359788
# test_score_W_combine_a 0.14176790063690414
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
#  all feature number 24
# all_train_score_W0_p 0.4930555555555556
# all_train_score_W0_n 0.25106759802472706
# all_train_score_W0_a 0.1523551880354994
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.24165292814991823
# test_score_W0_a  0.14341952080141143
#  discrete feature number 10
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2214074588715372
# all_train_score_W_combine_a 0.2340496622543478
# test_score_W_combine_p0.5409836065573771
# test_score_W_combine_n 0.27714172968473855
# test_score_W_combine_a 0.16962713235612795
# neuron unit number: 40
#  all feature number 24
# all_train_score_W0_p 0.5763888888888888
# all_train_score_W0_n 0.26655547641647004
# all_train_score_W0_a 0.21623702039227258
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.23411509310998885
# test_score_W0_a  0.16798425677738948
#  discrete feature number 10
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.22733325159736345
# all_train_score_W_combine_a 0.1553324185908029
# test_score_W_combine_p0.5737704918032787
# test_score_W_combine_n 0.36879270392889724
# test_score_W_combine_a 0.1754094374748241
# neuron unit number: 45
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.17521613787554186
# all_train_score_W0_a 0.14662512474746245
# test_score_W0_p0.5409836065573771
# test_score_W0_n 0.27897302380696776
# test_score_W0_a  0.1407022554730621
#  discrete feature number 10
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2668572744894412
# all_train_score_W_combine_a 0.20015725071273577
# test_score_W_combine_p0.6065573770491803
# test_score_W_combine_n 0.3463394549852815
# test_score_W_combine_a 0.2013853424822886
# neuron unit number: 50
#  all feature number 24
# all_train_score_W0_p 0.5486111111111112
# all_train_score_W0_n 0.23532311717456567
# all_train_score_W0_a 0.2174189546333606
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.24420353025793393
# test_score_W0_a  0.11269973735022387
#  discrete feature number 10
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.2545259272742735
# all_train_score_W_combine_a 0.1965107052722305
# test_score_W_combine_p0.5901639344262295
# test_score_W_combine_n 0.347060900279265
# test_score_W_combine_a 0.19525732629180906
# neuron unit number: 55
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.19423546619319454
# all_train_score_W0_a 0.1226005207068889
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3658750078053149
# test_score_W0_a  0.2091688524311925
#  discrete feature number 10
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.22003018879579386
# all_train_score_W_combine_a 0.19237421608292754
# test_score_W_combine_p0.5409836065573771
# test_score_W_combine_n 0.2706320291318925
# test_score_W_combine_a 0.161384493061476
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 60
#  all feature number 24
# all_train_score_W0_p 0.5555555555555556
# all_train_score_W0_n 0.2442024908937655
# all_train_score_W0_a 0.1796085794167466
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3396592617446334
# test_score_W0_a  0.2229795434199411
#  discrete feature number 10
# all_train_score_W_combine_p 0.5763888888888888
# all_train_score_W_combine_n 0.2682219105578469
# all_train_score_W_combine_a 0.2372940327262719
# test_score_W_combine_p0.5573770491803278
# test_score_W_combine_n 0.2952099363688274
# test_score_W_combine_a 0.15067673870229212
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 65
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.17894994734940328
# all_train_score_W0_a 0.150427153082429
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.32449679680001003
# test_score_W0_a  0.16571716365681843
#  discrete feature number 10
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.23694559237610155
# all_train_score_W_combine_a 0.154235807860262
# test_score_W_combine_p0.5409836065573771
# test_score_W_combine_n 0.2665568925377629
# test_score_W_combine_a 0.12648439542924503
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 70
#  all feature number 24
# all_train_score_W0_p 0.5277777777777778
# all_train_score_W0_n 0.20571149888605963
# all_train_score_W0_a 0.15936658566157366
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.32551452612636667
# test_score_W0_a  0.21091015763462503
#  discrete feature number 10
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.24519696749794417
# all_train_score_W_combine_a 0.16012281607477652
# test_score_W_combine_p0.5409836065573771
# test_score_W_combine_n 0.2636541765035392
# test_score_W_combine_a 0.14836294756225024
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 75
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.20539585169240743
# all_train_score_W0_a 0.1697022931359423
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.31160694017203766
# test_score_W0_a  0.15497671088420814
#  discrete feature number 10
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.24751919391471824
# all_train_score_W_combine_a 0.18059101941938974
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3904384729957509
# test_score_W_combine_a 0.24272092102324344
# neuron unit number: 80
#  all feature number 24
# all_train_score_W0_p 0.5486111111111112
# all_train_score_W0_n 0.23650499105225065
# all_train_score_W0_a 0.20094307912761963
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.37397948248781093
# test_score_W0_a  0.3060305912450173
#  discrete feature number 10
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.22580742813860238
# all_train_score_W_combine_a 0.21161226666279737
# test_score_W_combine_p0.5737704918032787
# test_score_W_combine_n 0.29818716391291566
# test_score_W_combine_a 0.16818288324854896
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 85
#  all feature number 24
# all_train_score_W0_p 0.5555555555555556
# all_train_score_W0_n 0.2631685436573876
# all_train_score_W0_a 0.202273807076837
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.23921213768565416
# test_score_W0_a  0.1238963189963154
#  discrete feature number 10
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.1850823987373822
# all_train_score_W_combine_a 0.18253599628425451
# test_score_W_combine_p0.5737704918032787
# test_score_W_combine_n 0.312651290358952
# test_score_W_combine_a 0.1955265354848337
# neuron unit number: 90
#  all feature number 24
# all_train_score_W0_p 0.5208333333333334
# all_train_score_W0_n 0.229336934513575
# all_train_score_W0_a 0.16161480306934337
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.26660954874823467
# test_score_W0_a  0.15287433465452688
#  discrete feature number 10
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.23402946660189097
# all_train_score_W_combine_a 0.19300046452474942
# test_score_W_combine_p0.5245901639344263
# test_score_W_combine_n 0.2567008467822924
# test_score_W_combine_a 0.13767025207745073
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 95
#  all feature number 24
# all_train_score_W0_p 0.5555555555555556
# all_train_score_W0_n 0.23118408260051537
# all_train_score_W0_a 0.18407280158504377
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.30942213059636375
# test_score_W0_a  0.2434314031208684
#  discrete feature number 10
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22315840141701312
# all_train_score_W_combine_a 0.1698872556443402
# test_score_W_combine_p0.6065573770491803
# test_score_W_combine_n 0.3294719945676919
# test_score_W_combine_a 0.18314355819203965
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
#  all feature number 24
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.18603541823195144
# all_train_score_W0_a 0.14467555227597656
# test_score_W0_p0.5245901639344263
# test_score_W0_n 0.29822760176232754
# test_score_W0_a  0.12943550004871815
#  discrete feature number 10
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.22806949393010365
# all_train_score_W_combine_a 0.1724090944483376
# test_score_W_combine_p0.5901639344262295
# test_score_W_combine_n 0.30259055868256723
# test_score_W_combine_a 0.1973784155103498
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.210734  0.034790  0.007779   0.194452  0.227016
# 1  train_W_combine  20.0  0.229078  0.022504  0.005032   0.218546  0.239610
# 2         combined  40.0  0.219906  0.030375  0.004803   0.210191  0.229620
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0183
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -1.9799
# 3                    Two side test p value =    0.0550
# 4                   Difference < 0 p value =    0.0275
# 5                   Difference > 0 p value =    0.9725
# 6                                Cohen's d =   -0.6261
# 7                                Hedge's g =   -0.6137
# 8                            Glass's delta =   -0.5273
# 9                              Pearson's r =    0.3058
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.277471  0.068066  0.015220   0.245615  0.309327
# 1  test_W_combine  20.0  0.322729  0.044281  0.009902   0.302005  0.343454
# 2        combined  40.0  0.300100  0.061136  0.009666   0.280548  0.319652
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0453
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -2.4925
# 3                  Two side test p value =    0.0172
# 4                 Difference < 0 p value =    0.0086
# 5                 Difference > 0 p value =    0.9914
# 6                              Cohen's d =   -0.7882
# 7                              Hedge's g =   -0.7725
# 8                          Glass's delta =   -0.6649
# 9                            Pearson's r =    0.3749
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.163298  0.033185  0.007420   0.147767  0.178829
# 1  train_W_combine  20.0  0.184189  0.023576  0.005272   0.173155  0.195223
# 2         combined  40.0  0.173743  0.030319  0.004794   0.164047  0.183440
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0209
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -2.2951
# 3                    Two side test p value =    0.0273
# 4                   Difference < 0 p value =    0.0137
# 5                   Difference > 0 p value =    0.9863
# 6                                Cohen's d =   -0.7258
# 7                                Hedge's g =   -0.7114
# 8                            Glass's delta =   -0.6295
# 9                              Pearson's r =    0.3489
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.164586  0.062818  0.014047   0.135186  0.193986
# 1  test_W_combine  20.0  0.171330  0.027917  0.006242   0.158265  0.184396
# 2        combined  40.0  0.167958  0.048102  0.007606   0.152574  0.183342
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0067
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -0.4388
# 3                  Two side test p value =    0.6633
# 4                 Difference < 0 p value =    0.3317
# 5                 Difference > 0 p value =    0.6683
# 6                              Cohen's d =   -0.1387
# 7                              Hedge's g =   -0.1360
# 8                          Glass's delta =   -0.1074
# 9                            Pearson's r =    0.0710
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.519792  0.036279  0.008112   0.502813  0.536771
# 1  train_W_combine  20.0  0.543056  0.014706  0.003288   0.536173  0.549938
# 2         combined  40.0  0.531424  0.029755  0.004705   0.521908  0.540940
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0233
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -2.6577
# 3                    Two side test p value =    0.0114
# 4                   Difference < 0 p value =    0.0057
# 5                   Difference > 0 p value =    0.9943
# 6                                Cohen's d =   -0.8404
# 7                                Hedge's g =   -0.8237
# 8                            Glass's delta =   -0.6412
# 9                              Pearson's r =    0.3959
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.552459  0.052140  0.011659   0.528057  0.576861
# 1  test_W_combine  20.0  0.568852  0.027688  0.006191   0.555894  0.581811
# 2        combined  40.0  0.560656  0.042034  0.006646   0.547213  0.574099
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0164
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -1.2419
# 3                  Two side test p value =    0.2219
# 4                 Difference < 0 p value =    0.1109
# 5                 Difference > 0 p value =    0.8891
# 6                              Cohen's d =   -0.3927
# 7                              Hedge's g =   -0.3849
# 8                          Glass's delta =   -0.3144
# 9                            Pearson's r =    0.1975
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
# subjective

import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
#  all feature number 24
# all_train_score_W0_p 0.4236111111111111
# all_train_score_W0_n 0.15860895212705
# all_train_score_W0_a 0.08428541115243296
# test_score_W0_p0.47540983606557374
# test_score_W0_n 0.23502895947245256
# test_score_W0_a  0.1530002884685763
#  discrete feature number 9
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22889748448596592
# all_train_score_W_combine_a 0.14786701499304478
# test_score_W_combine_p0.6065573770491803
# test_score_W_combine_n 0.3772510036961333
# test_score_W_combine_a 0.27408329283303734
# neuron unit number: 10
#  all feature number 24
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.15607668661240506
# all_train_score_W0_a 0.06336108310840839
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.35819483289707343
# test_score_W0_a  0.25469209768986656
#  discrete feature number 9
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.1754370794117889
# all_train_score_W_combine_a 0.15148875689035493
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.47760184868937167
# test_score_W_combine_a 0.40642539995457505
# neuron unit number: 15
#  all feature number 24
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.1394717014975943
# all_train_score_W0_a 0.05491152630740732
# test_score_W0_p0.5737704918032787
# test_score_W0_n 0.32066979434656634
# test_score_W0_a  0.2772065487312874
#  discrete feature number 9
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.23460145669293142
# all_train_score_W_combine_a 0.17740736381039707
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.39672792738430246
# test_score_W_combine_a 0.33211785741154853
# neuron unit number: 20
#  all feature number 24
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.19587431722651494
# all_train_score_W0_a 0.08678106879799405
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.35181247592972764
# test_score_W0_a  0.26804190707843417
#  discrete feature number 9
# all_train_score_W_combine_p 0.5
# all_train_score_W_combine_n 0.19473246764057817
# all_train_score_W_combine_a 0.0873472605937544
# test_score_W_combine_p0.6065573770491803
# test_score_W_combine_n 0.38207593328963896
# test_score_W_combine_a 0.30514870282186257
# neuron unit number: 25
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.172850421998837
# all_train_score_W0_a 0.1256669490501892
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.38707019870909276
# test_score_W0_a  0.3211161042033939
#  discrete feature number 9
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.20497899112860538
# all_train_score_W_combine_a 0.13916820990325204
# test_score_W_combine_p0.6229508196721312
# test_score_W_combine_n 0.3845719320224113
# test_score_W_combine_a 0.3243878748456227
# Not good nmi result for discrete features !!!!!
# neuron unit number: 30
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.20743262379796956
# all_train_score_W0_a 0.13979225342364043
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.4132327990896243
# test_score_W0_a  0.3316121247610049
#  discrete feature number 9
# all_train_score_W_combine_p 0.5138888888888888
# all_train_score_W_combine_n 0.16812101205565202
# all_train_score_W_combine_a 0.10615138419673296
# test_score_W_combine_p0.7049180327868853
# test_score_W_combine_n 0.47910278740582174
# test_score_W_combine_a 0.44210718858606185
# neuron unit number: 35
#  all feature number 24
# all_train_score_W0_p 0.4930555555555556
# all_train_score_W0_n 0.2053772045679042
# all_train_score_W0_a 0.10097669855182095
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.36467603266409165
# test_score_W0_a  0.2808787564511332
#  discrete feature number 9
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.22877354293649585
# all_train_score_W_combine_a 0.10125391762043107
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.3974645539503852
# test_score_W_combine_a 0.3389152223242198
# neuron unit number: 40
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.1904452867926223
# all_train_score_W0_a 0.10608631423126813
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.35249294911058726
# test_score_W0_a  0.28991716736989737
#  discrete feature number 9
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.20978650733320206
# all_train_score_W_combine_a 0.11561443362347526
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.5113438925248056
# test_score_W_combine_a 0.4228513936758561
# neuron unit number: 45
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.17987723338562503
# all_train_score_W0_a 0.12062794913246391
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3660320332611129
# test_score_W0_a  0.30232344497607655
#  discrete feature number 9
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.24247326216924756
# all_train_score_W_combine_a 0.16435753631329278
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.488188125481183
# test_score_W_combine_a 0.3746785124653376
# neuron unit number: 50
#  all feature number 24
# all_train_score_W0_p 0.5208333333333334
# all_train_score_W0_n 0.2080037896945676
# all_train_score_W0_a 0.11961076144195193
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.4537467968294133
# test_score_W0_a  0.3405531461194391
#  discrete feature number 9
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.21781668025272
# all_train_score_W_combine_a 0.13189386075858456
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.43393854664912407
# test_score_W_combine_a 0.3413843593720808
# Not good nmi result for discrete features !!!!!
# neuron unit number: 55
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.20591762957321472
# all_train_score_W0_a 0.13163872645771582
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.39912263636397655
# test_score_W0_a  0.29981228129396076
#  discrete feature number 9
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.23778686580231428
# all_train_score_W_combine_a 0.16802081945881703
# test_score_W_combine_p0.7213114754098361
# test_score_W_combine_n 0.4951665143756528
# test_score_W_combine_a 0.4350191562072516
# neuron unit number: 60
#  all feature number 24
# all_train_score_W0_p 0.5277777777777778
# all_train_score_W0_n 0.1930332363771739
# all_train_score_W0_a 0.13382658270996922
# test_score_W0_p0.6721311475409836
# test_score_W0_n 0.42763804719794246
# test_score_W0_a  0.34478692276928474
#  discrete feature number 9
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.23365447567078257
# all_train_score_W_combine_a 0.18734304995606957
# test_score_W_combine_p0.7377049180327869
# test_score_W_combine_n 0.5236089763535534
# test_score_W_combine_a 0.48804795803671785
# neuron unit number: 65
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.181655470116111
# all_train_score_W0_a 0.11242217201865397
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.4105994245246234
# test_score_W0_a  0.33530802050400565
#  discrete feature number 9
# all_train_score_W_combine_p 0.5902777777777778
# all_train_score_W_combine_n 0.25124906511301237
# all_train_score_W_combine_a 0.23631384335836947
# test_score_W_combine_p0.7213114754098361
# test_score_W_combine_n 0.5313439771067265
# test_score_W_combine_a 0.4441853936593884
# neuron unit number: 70
#  all feature number 24
# all_train_score_W0_p 0.5277777777777778
# all_train_score_W0_n 0.20810138505190862
# all_train_score_W0_a 0.13557423954595557
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.38797426455510214
# test_score_W0_a  0.2995648795871149
#  discrete feature number 9
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.23344332943009763
# all_train_score_W_combine_a 0.13778182320390595
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.4992658969796802
# test_score_W_combine_a 0.41810455412660874
# neuron unit number: 75
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.17204809326709922
# all_train_score_W0_a 0.11581566638221437
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.41711610089652956
# test_score_W0_a  0.35555231855500297
#  discrete feature number 9
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.1992919134696231
# all_train_score_W_combine_a 0.14860728062713527
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.4935423263234265
# test_score_W_combine_a 0.4199942966553958
# neuron unit number: 80
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.19189763229080622
# all_train_score_W0_a 0.12543395051540746
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3251750257887881
# test_score_W0_a  0.2901977533719795
#  discrete feature number 9
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.20271469874540685
# all_train_score_W_combine_a 0.16023930365996233
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.40522560917139655
# test_score_W_combine_a 0.32548210034699016
# neuron unit number: 85
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.1947447052159482
# all_train_score_W0_a 0.11300004063601163
# test_score_W0_p0.6885245901639344
# test_score_W0_n 0.4656084274663162
# test_score_W0_a  0.38587472383938515
#  discrete feature number 9
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.20676670172532108
# all_train_score_W_combine_a 0.15651378012813993
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.45675749335325705
# test_score_W_combine_a 0.3940242604809534
# Not good nmi result for discrete features !!!!!
# neuron unit number: 90
#  all feature number 24
# all_train_score_W0_p 0.5347222222222222
# all_train_score_W0_n 0.20921159606973527
# all_train_score_W0_a 0.160451635478001
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.4629836949853394
# test_score_W0_a  0.36779203398666366
#  discrete feature number 9
# all_train_score_W_combine_p 0.4861111111111111
# all_train_score_W_combine_n 0.186977973426783
# all_train_score_W_combine_a 0.07685205085765971
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.4868833046212483
# test_score_W_combine_a 0.38423587540594234
# neuron unit number: 95
#  all feature number 24
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.18570060437413932
# all_train_score_W0_a 0.11583003487551283
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.34158233425974194
# test_score_W0_a  0.3028900730022658
#  discrete feature number 9
# all_train_score_W_combine_p 0.5555555555555556
# all_train_score_W_combine_n 0.21681254138785502
# all_train_score_W_combine_a 0.18138038621342642
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.49000812508562214
# test_score_W_combine_a 0.3857998782081333
# neuron unit number: 100
#  all feature number 24
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.1677390293377408
# all_train_score_W0_a 0.07721132038260527
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.4077247118553083
# test_score_W0_a  0.34430882770366167
#  discrete feature number 9
# all_train_score_W_combine_p 0.5138888888888888
# all_train_score_W_combine_n 0.17865867575081001
# all_train_score_W_combine_a 0.11713894313112368
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.4291864176852469
# test_score_W_combine_a 0.35747822614820446
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.186203  0.019984  0.004469   0.176850  0.195556
# 1  train_W_combine  20.0  0.212649  0.023860  0.005335   0.201482  0.223815
# 2         combined  40.0  0.199426  0.025519  0.004035   0.191265  0.207588
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0264
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -3.7999
# 3                    Two side test p value =    0.0005
# 4                   Difference < 0 p value =    0.0003
# 5                   Difference > 0 p value =    0.9997
# 6                                Cohen's d =   -1.2016
# 7                                Hedge's g =   -1.1778
# 8                            Glass's delta =   -1.3233
# 9                              Pearson's r =    0.5247
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.382424  0.055225  0.012349   0.356578  0.408270
# 1  test_W_combine  20.0  0.456963  0.051169  0.011442   0.433015  0.480910
# 2        combined  40.0  0.419693  0.064699  0.010230   0.399002  0.440385
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0745
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.4277
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.4002
# 7                              Hedge's g =   -1.3723
# 8                          Glass's delta =   -1.3497
# 9                            Pearson's r =    0.5834
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.111165  0.026606  0.005949   0.098713  0.123617
# 1  train_W_combine  20.0  0.144637  0.037783  0.008449   0.126954  0.162320
# 2         combined  40.0  0.127901  0.036436  0.005761   0.116248  0.139554
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0335
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -3.2393
# 3                    Two side test p value =    0.0025
# 4                   Difference < 0 p value =    0.0012
# 5                   Difference > 0 p value =    0.9988
# 6                                Cohen's d =   -1.0244
# 7                                Hedge's g =   -1.0040
# 8                            Glass's delta =   -1.2581
# 9                              Pearson's r =    0.4652
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.307271  0.050307  0.011249   0.283727  0.330816
# 1  test_W_combine  20.0  0.380724  0.054962  0.012290   0.355001  0.406447
# 2        combined  40.0  0.343998  0.063937  0.010109   0.323549  0.364446
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0735
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.4087
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.3942
# 7                              Hedge's g =   -1.3665
# 8                          Glass's delta =   -1.4601
# 9                            Pearson's r =    0.5817
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.498611  0.027833  0.006224   0.485585  0.511637
# 1  train_W_combine  20.0  0.536458  0.024148  0.005400   0.525157  0.547760
# 2         combined  40.0  0.517535  0.032075  0.005071   0.507277  0.527793
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0378
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -4.5934
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.4526
# 7                                Hedge's g =   -1.4237
# 8                            Glass's delta =   -1.3598
# 9                              Pearson's r =    0.5975
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.613934  0.045900  0.010264   0.592453  0.635416
# 1  test_W_combine  20.0  0.667213  0.036888  0.008248   0.649949  0.684477
# 2        combined  40.0  0.640574  0.049165  0.007774   0.624850  0.656297
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0533
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.0463
# 3                  Two side test p value =    0.0002
# 4                 Difference < 0 p value =    0.0001
# 5                 Difference > 0 p value =    0.9999
# 6                              Cohen's d =   -1.2796
# 7                              Hedge's g =   -1.2541
# 8                          Glass's delta =   -1.1608
# 9                            Pearson's r =    0.5487
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
#  all feature number 24
# all_train_score_W0_p 0.4375
# all_train_score_W0_n 0.15630339100879667
# all_train_score_W0_a 0.08864821754101682
# test_score_W0_p0.4918032786885246
# test_score_W0_n 0.2228584336881962
# test_score_W0_a  0.11288343558282209
#  discrete feature number 9
# all_train_score_W_combine_p 0.4722222222222222
# all_train_score_W_combine_n 0.1691392456850799
# all_train_score_W_combine_a 0.1109230770227057
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.34189284655135466
# test_score_W_combine_a 0.2924180111778973
# neuron unit number: 10
#  all feature number 24
# all_train_score_W0_p 0.4513888888888889
# all_train_score_W0_n 0.13614063310903576
# all_train_score_W0_a 0.07299834816469593
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.3135065685629834
# test_score_W0_a  0.22862761807991083
#  discrete feature number 9
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.22417430410163985
# all_train_score_W_combine_a 0.13086766168118236
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.4210870177186397
# test_score_W_combine_a 0.3516188149053146
# neuron unit number: 15
#  all feature number 24
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.1603779449673335
# all_train_score_W0_a 0.10103831450071378
# test_score_W0_p0.5901639344262295
# test_score_W0_n 0.2805440267868142
# test_score_W0_a  0.20754835775997763
#  discrete feature number 9
# all_train_score_W_combine_p 0.5277777777777778
# all_train_score_W_combine_n 0.19713923779133274
# all_train_score_W_combine_a 0.13781863784605936
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.4722097720994657
# test_score_W_combine_a 0.37526018221758073
# neuron unit number: 20
#  all feature number 24
# all_train_score_W0_p 0.4583333333333333
# all_train_score_W0_n 0.17295087015105864
# all_train_score_W0_a 0.08009323175701526
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3404553152619649
# test_score_W0_a  0.2789269300651965
#  discrete feature number 9
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.2253880622160816
# all_train_score_W_combine_a 0.15446424143307644
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.4397921520049763
# test_score_W_combine_a 0.3218571582462566
# neuron unit number: 25
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.18044002453431335
# all_train_score_W0_a 0.16351476014760147
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.3160952078935599
# test_score_W0_a  0.28139810852601677
#  discrete feature number 9
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.2156395109246137
# all_train_score_W_combine_a 0.1965927834513429
# test_score_W_combine_p0.7213114754098361
# test_score_W_combine_n 0.5017456980464778
# test_score_W_combine_a 0.45275544681346847
# neuron unit number: 30
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.18586908374280367
# all_train_score_W0_a 0.10677076407542353
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3872532825649475
# test_score_W0_a  0.22635484596357094
#  discrete feature number 9
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.1938332255871418
# all_train_score_W_combine_a 0.12074605399401513
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.4636163710312534
# test_score_W_combine_a 0.37141557941865755
# neuron unit number: 35
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.2015442524741818
# all_train_score_W0_a 0.14585564905290233
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.39624259439672166
# test_score_W0_a  0.26158711694354575
#  discrete feature number 9
# all_train_score_W_combine_p 0.5694444444444444
# all_train_score_W_combine_n 0.2410365397958106
# all_train_score_W_combine_a 0.2187818452614251
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.3906974614272656
# test_score_W_combine_a 0.2986962055798273
# Not good nmi result for discrete features !!!!!
# neuron unit number: 40
#  all feature number 24
# all_train_score_W0_p 0.5416666666666666
# all_train_score_W0_n 0.22471143117413592
# all_train_score_W0_a 0.17367718515745179
# test_score_W0_p0.6721311475409836
# test_score_W0_n 0.42647598445943163
# test_score_W0_a  0.3865921787709497
#  discrete feature number 9
# all_train_score_W_combine_p 0.5138888888888888
# all_train_score_W_combine_n 0.2265399416855682
# all_train_score_W_combine_a 0.11780506380277564
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.3926856568294896
# test_score_W_combine_a 0.3102312935304853
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 45
#  all feature number 24
# all_train_score_W0_p 0.5486111111111112
# all_train_score_W0_n 0.2393646673604374
# all_train_score_W0_a 0.17992854070751935
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.35810217411880446
# test_score_W0_a  0.2957570746739825
#  discrete feature number 9
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.22277202300111218
# all_train_score_W_combine_a 0.1967723924399353
# test_score_W_combine_p0.7049180327868853
# test_score_W_combine_n 0.47802306510732856
# test_score_W_combine_a 0.399203216643919
# neuron unit number: 50
#  all feature number 24
# all_train_score_W0_p 0.4791666666666667
# all_train_score_W0_n 0.17265706740673914
# all_train_score_W0_a 0.09323519903294726
# test_score_W0_p0.6065573770491803
# test_score_W0_n 0.3238632942041746
# test_score_W0_a  0.24956512627056482
#  discrete feature number 9
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.21589815664163
# all_train_score_W_combine_a 0.11838338514453653
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.44779802758380644
# test_score_W_combine_a 0.29114176614262616
# neuron unit number: 55
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.16336290758155483
# all_train_score_W0_a 0.11161384307163069
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.41608263411007274
# test_score_W0_a  0.33463457095985805
#  discrete feature number 9
# all_train_score_W_combine_p 0.5
# all_train_score_W_combine_n 0.18182066898926189
# all_train_score_W_combine_a 0.12295170962559591
# test_score_W_combine_p0.6557377049180327
# test_score_W_combine_n 0.39874937346107353
# test_score_W_combine_a 0.2723301480625853
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 60
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.21187385661994335
# all_train_score_W0_a 0.11898875175573925
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.43549775853624695
# test_score_W0_a  0.31315761467238995
#  discrete feature number 9
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.22103095171546838
# all_train_score_W_combine_a 0.1601318092537739
# test_score_W_combine_p0.639344262295082
# test_score_W_combine_n 0.4184614927422066
# test_score_W_combine_a 0.3005953866448002
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 65
#  all feature number 24
# all_train_score_W0_p 0.5069444444444444
# all_train_score_W0_n 0.21504737040221708
# all_train_score_W0_a 0.12278679065431913
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.34667782410834624
# test_score_W0_a  0.26378956574388646
#  discrete feature number 9
# all_train_score_W_combine_p 0.5625
# all_train_score_W_combine_n 0.2489430201541138
# all_train_score_W_combine_a 0.19007240359163335
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.45500707249750605
# test_score_W_combine_a 0.3830633661194194
# neuron unit number: 70
#  all feature number 24
# all_train_score_W0_p 0.4930555555555556
# all_train_score_W0_n 0.1894642035876854
# all_train_score_W0_a 0.1369276821302
# test_score_W0_p0.6229508196721312
# test_score_W0_n 0.3987293069186736
# test_score_W0_a  0.23919559122111572
#  discrete feature number 9
# all_train_score_W_combine_p 0.5902777777777778
# all_train_score_W_combine_n 0.2556206097572198
# all_train_score_W_combine_a 0.25141836040138393
# test_score_W_combine_p0.7049180327868853
# test_score_W_combine_n 0.47620213512293846
# test_score_W_combine_a 0.42357150373566244
# neuron unit number: 75
#  all feature number 24
# all_train_score_W0_p 0.4652777777777778
# all_train_score_W0_n 0.129123448159891
# all_train_score_W0_a 0.10315624917310343
# test_score_W0_p0.6721311475409836
# test_score_W0_n 0.3774142470999183
# test_score_W0_a  0.3533806912289742
#  discrete feature number 9
# all_train_score_W_combine_p 0.5416666666666666
# all_train_score_W_combine_n 0.2066255102281029
# all_train_score_W_combine_a 0.17951256206547142
# test_score_W_combine_p0.6885245901639344
# test_score_W_combine_n 0.45478881421326783
# test_score_W_combine_a 0.4007573298712539
# neuron unit number: 80
#  all feature number 24
# all_train_score_W0_p 0.5486111111111112
# all_train_score_W0_n 0.21822328042994962
# all_train_score_W0_a 0.17434711600074995
# test_score_W0_p0.6885245901639344
# test_score_W0_n 0.4403000580946161
# test_score_W0_a  0.414760147601476
#  discrete feature number 9
# all_train_score_W_combine_p 0.5486111111111112
# all_train_score_W_combine_n 0.22772333830796182
# all_train_score_W_combine_a 0.18966032343749176
# test_score_W_combine_p0.7049180327868853
# test_score_W_combine_n 0.5091521342567585
# test_score_W_combine_a 0.4057950317561727
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
#  all feature number 24
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.20221732348023125
# all_train_score_W0_a 0.10166329168138136
# test_score_W0_p0.6557377049180327
# test_score_W0_n 0.4688488371108991
# test_score_W0_a  0.37216163259270213
#  discrete feature number 9
# all_train_score_W_combine_p 0.5347222222222222
# all_train_score_W_combine_n 0.2040959324284609
# all_train_score_W_combine_a 0.13924310635374598
# test_score_W_combine_p0.7049180327868853
# test_score_W_combine_n 0.4958688104271334
# test_score_W_combine_a 0.38927294398092965
# neuron unit number: 90
#  all feature number 24
# all_train_score_W0_p 0.4930555555555556
# all_train_score_W0_n 0.17899741064895067
# all_train_score_W0_a 0.1287001398369031
# test_score_W0_p0.5573770491803278
# test_score_W0_n 0.2772997770356757
# test_score_W0_a  0.19214094823319805
#  discrete feature number 9
# all_train_score_W_combine_p 0.5138888888888888
# all_train_score_W_combine_n 0.1769316458202563
# all_train_score_W_combine_a 0.15665756017060825
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.4444311210403497
# test_score_W_combine_a 0.33077174742811444
# neuron unit number: 95
#  all feature number 24
# all_train_score_W0_p 0.5
# all_train_score_W0_n 0.18156802543166023
# all_train_score_W0_a 0.1418772687247584
# test_score_W0_p0.639344262295082
# test_score_W0_n 0.3771777990634599
# test_score_W0_a  0.31570987547261437
#  discrete feature number 9
# all_train_score_W_combine_p 0.4791666666666667
# all_train_score_W_combine_n 0.14088093969794213
# all_train_score_W_combine_a 0.10250326175300509
# test_score_W_combine_p0.7377049180327869
# test_score_W_combine_n 0.5155879417088401
# test_score_W_combine_a 0.4244073338783137
# neuron unit number: 100
#  all feature number 24
# all_train_score_W0_p 0.5277777777777778
# all_train_score_W0_n 0.2151851313234933
# all_train_score_W0_a 0.155969814160815
# test_score_W0_p0.7049180327868853
# test_score_W0_n 0.5097707097030603
# test_score_W0_a  0.4054808648569008
#  discrete feature number 9
# all_train_score_W_combine_p 0.5208333333333334
# all_train_score_W_combine_n 0.17306478502977904
# all_train_score_W_combine_a 0.1353938479437934
# test_score_W_combine_p0.6721311475409836
# test_score_W_combine_n 0.4183986648871375
# test_score_W_combine_a 0.31886341759064496
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.186771  0.029446  0.006584   0.172990  0.200552
# 1  train_W_combine  20.0  0.208415  0.029073  0.006501   0.194808  0.222021
# 2         combined  40.0  0.197593  0.030892  0.004884   0.187713  0.207473
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0216
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -2.3392
# 3                    Two side test p value =    0.0247
# 4                   Difference < 0 p value =    0.0123
# 5                   Difference > 0 p value =    0.9877
# 6                                Cohen's d =   -0.7397
# 7                                Hedge's g =   -0.7250
# 8                            Glass's delta =   -0.7350
# 9                              Pearson's r =    0.3548
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.370660  0.070260  0.015711   0.337777  0.403542
# 1  test_W_combine  20.0  0.446810  0.045109  0.010087   0.425698  0.467922
# 2        combined  40.0  0.408735  0.069879  0.011049   0.386386  0.431083
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0761
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.0788
# 3                  Two side test p value =    0.0002
# 4                 Difference < 0 p value =    0.0001
# 5                 Difference > 0 p value =    0.9999
# 6                              Cohen's d =   -1.2898
# 7                              Hedge's g =   -1.2642
# 8                          Glass's delta =   -1.0838
# 9                            Pearson's r =    0.5518
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.125090  0.032719  0.007316   0.109777  0.140402
# 1  train_W_combine  20.0  0.156535  0.040385  0.009030   0.137634  0.175436
# 2         combined  40.0  0.140812  0.039618  0.006264   0.128142  0.153483
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0314
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -2.7057
# 3                    Two side test p value =    0.0101
# 4                   Difference < 0 p value =    0.0051
# 5                   Difference > 0 p value =    0.9949
# 6                                Cohen's d =   -0.8556
# 7                                Hedge's g =   -0.8386
# 8                            Glass's delta =   -0.9611
# 9                              Pearson's r =    0.4019
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.286683  0.077280  0.017280   0.250515  0.322851
# 1  test_W_combine  20.0  0.355701  0.053460  0.011954   0.330681  0.380721
# 2        combined  40.0  0.321192  0.074319  0.011751   0.297424  0.344960
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0690
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -3.2847
# 3                  Two side test p value =    0.0022
# 4                 Difference < 0 p value =    0.0011
# 5                 Difference > 0 p value =    0.9989
# 6                              Cohen's d =   -1.0387
# 7                              Hedge's g =   -1.0181
# 8                          Glass's delta =   -0.8931
# 9                            Pearson's r =    0.4703
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.499653  0.030767  0.006880   0.485253  0.514052
# 1  train_W_combine  20.0  0.531250  0.028985  0.006481   0.517685  0.544815
# 2         combined  40.0  0.515451  0.033563  0.005307   0.504717  0.526185
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0316
# 1                       Degrees of freedom =   38.0000
# 2                                        t =   -3.3430
# 3                    Two side test p value =    0.0019
# 4                   Difference < 0 p value =    0.0009
# 5                   Difference > 0 p value =    0.9991
# 6                                Cohen's d =   -1.0571
# 7                                Hedge's g =   -1.0361
# 8                            Glass's delta =   -1.0270
# 9                              Pearson's r =    0.4767
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.626230  0.048046  0.010743   0.603743  0.648716
# 1  test_W_combine  20.0  0.681148  0.027879  0.006234   0.668100  0.694195
# 2        combined  40.0  0.653689  0.047714  0.007544   0.638429  0.668948
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0549
# 1                     Degrees of freedom =   38.0000
# 2                                      t =   -4.4214
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.3982
# 7                              Hedge's g =   -1.3704
# 8                          Glass's delta =   -1.1430
# 9                            Pearson's r =    0.5828
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
