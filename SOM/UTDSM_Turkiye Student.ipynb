# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("turkiye-student-evaluation_generic.csv")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"class")

# %%
unstable_repeat_num= 30
scope_num = 62
class_num = 13
dim_num = 32
total_label_train = []
best_num = 48

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     



experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1)
# Out:
# neuron unit number: 13
# all_train_score_W0_n 0.04618332863308304
# all_train_score_W0_a 0.02305089247937682
# test_score_W0_n 0.06676700241216565
# test_score_W0_a  0.02523114386969881
# Split one time!
# self.rest_data_W0_n 0.04712893721039482
# self.rest_data_W0_a 0.02397425107869493
# Split one time!
# self.rest_data_W0_n 0.35183738009477594
# self.rest_data_W0_a 0.13550444915638196
# all_train_score_W_Combined_n 0.05121861599132465
# all_train_score_W_Combined_a 0.025314362485031223
# test_score_W_combined_n 0.06418702283144923
# test_score_W_combined_a 0.02414082351297183
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :25
# neuron unit number: 14
# all_train_score_W0_n 0.10963524552072516
# all_train_score_W0_a 0.05544053260572876
# test_score_W0_n 0.11469276156212853
# test_score_W0_a  0.04897680698716764
# Split one time!
# self.rest_data_W0_n 0.10958791070050465
# self.rest_data_W0_a 0.055516666456755424
# all_train_score_W_Combined_n 0.1100967891013146
# all_train_score_W_Combined_a 0.05571257022156536
# test_score_W_combined_n 0.106535878620796
# test_score_W_combined_a 0.04724397641139474
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :53
# neuron unit number: 15
# all_train_score_W0_n 0.11756582840917129
# all_train_score_W0_a 0.05876778398269249
# test_score_W0_n 0.1284734219751678
# test_score_W0_a  0.05884505905232557
# Split one time!
# self.rest_data_W0_n 0.11750188583856076
# self.rest_data_W0_a 0.05871666632858004
# all_train_score_W_Combined_n 0.11812810478557159
# all_train_score_W_Combined_a 0.0587689095429274
# test_score_W_combined_n 0.13497700260009524
# test_score_W_combined_a 0.05930138007459029
# Combine Neurons Number :18
# neuron unit number: 16
# all_train_score_W0_n 0.11299498210302733
# all_train_score_W0_a 0.06033295855790784
# test_score_W0_n 0.12384060357707481
# test_score_W0_a  0.057051670618896856
# Split one time!
# self.rest_data_W0_n 0.11392212591057546
# self.rest_data_W0_a 0.06067402947676168
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.11583006539219076
# all_train_score_W_Combined_a 0.06133213017510811
# test_score_W_combined_n 0.11951107277171877
# test_score_W_combined_a 0.057012525312890416
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :74
# neuron unit number: 17
# all_train_score_W0_n 0.0998509353741395
# all_train_score_W0_a 0.05885267121622538
# test_score_W0_n 0.11514809445379949
# test_score_W0_a  0.055424864587495126
# Split one time!
# self.rest_data_W0_n 0.09769759933975287
# self.rest_data_W0_a 0.05783572952899651
# Split one time!
# self.rest_data_W0_n 0.5647910440665185
# self.rest_data_W0_a 0.2882159672120042
# all_train_score_W_Combined_n 0.10302788192525077
# all_train_score_W_Combined_a 0.05847019114325449
# test_score_W_combined_n 0.12173451211536242
# test_score_W_combined_a 0.0586185733919213
# Combine Neurons Number :31
# neuron unit number: 18
# all_train_score_W0_n 0.13674086920357534
# all_train_score_W0_a 0.07673798173367663
# test_score_W0_n 0.14625521188725019
# test_score_W0_a  0.07144017709246812
# Split one time!
# self.rest_data_W0_n 0.136779970181281
# self.rest_data_W0_a 0.07671190948363259
# Split one time!
# self.rest_data_W0_n 0.9399452942025499
# self.rest_data_W0_a 0.6440677966101694
# all_train_score_W_Combined_n 0.13738117343432968
# all_train_score_W_Combined_a 0.07724768214970311
# test_score_W_combined_n 0.14541426513526984
# test_score_W_combined_a 0.07474727835926116
# Not good nmi result !!!!!
# Combine Neurons Number :89
# neuron unit number: 19
# all_train_score_W0_n 0.05724895576732482
# all_train_score_W0_a 0.024070946958910978
# test_score_W0_n 0.06924107913520663
# test_score_W0_a  0.026983369431494812
# Split one time!
# self.rest_data_W0_n 0.05734216419432546
# self.rest_data_W0_a 0.023557618146501903
# Split one time!
# self.rest_data_W0_n 0.634571858056975
# self.rest_data_W0_a 0.3
# all_train_score_W_Combined_n 0.05887503889113899
# all_train_score_W_Combined_a 0.023702593562565658
# test_score_W_combined_n 0.07154189412094021
# test_score_W_combined_a 0.02588763001970113
# Not good ari result !!!!!
# Combine Neurons Number :26
# neuron unit number: 20
# all_train_score_W0_n 0.1422018695526764
# all_train_score_W0_a 0.07291662625697906
# test_score_W0_n 0.13720053100334934
# test_score_W0_a  0.061919330124615216
# Split one time!
# self.rest_data_W0_n 0.14288090171832565
# self.rest_data_W0_a 0.07310675126584548
# all_train_score_W_Combined_n 0.14385132275230708
# all_train_score_W_Combined_a 0.07347898364443979
# test_score_W_combined_n 0.1346881202552424
# test_score_W_combined_a 0.06122050651993981
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :108
# neuron unit number: 21
# all_train_score_W0_n 0.07687067456195208
# all_train_score_W0_a 0.038906200274244414
# test_score_W0_n 0.08312593654398782
# test_score_W0_a  0.04144362005961535
# Split one time!
# self.rest_data_W0_n 0.07686679245917126
# self.rest_data_W0_a 0.03890191903983146
# all_train_score_W_Combined_n 0.07753134431706922
# all_train_score_W_Combined_a 0.03900547893170828
# test_score_W_combined_n 0.08473809050827405
# test_score_W_combined_a 0.040472145969553425
# Not good ari result !!!!!
# Combine Neurons Number :24
# neuron unit number: 22
# all_train_score_W0_n 0.16707649838838576
# all_train_score_W0_a 0.09323680956719123
# test_score_W0_n 0.1844764457001198
# test_score_W0_a  0.09051406519837449
# Split one time!
# self.rest_data_W0_n 0.166887958297497
# self.rest_data_W0_a 0.09292863949417118
# all_train_score_W_Combined_n 0.1671509428214632
# all_train_score_W_Combined_a 0.09313463819210914
# test_score_W_combined_n 0.17504493184443756
# test_score_W_combined_a 0.08361260578667566
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :124
# neuron unit number: 23
# all_train_score_W0_n 0.09125583729291327
# all_train_score_W0_a 0.03925313735701013
# test_score_W0_n 0.10979715979540484
# test_score_W0_a  0.046754386411832626
# Split one time!
# self.rest_data_W0_n 0.09166507986596802
# self.rest_data_W0_a 0.039511723338668404
# Split one time!
# self.rest_data_W0_n 0.645436253792704
# self.rest_data_W0_a 0.4515669515669516
# all_train_score_W_Combined_n 0.09205634960159119
# all_train_score_W_Combined_a 0.03982032460673078
# test_score_W_combined_n 0.10328158605245186
# test_score_W_combined_a 0.039816242843762444
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :31
# neuron unit number: 24
# all_train_score_W0_n 0.21335498678495715
# all_train_score_W0_a 0.11866443918899856
# test_score_W0_n 0.19962657657653932
# test_score_W0_a  0.10996227929294981
# Split one time!
# self.rest_data_W0_n 0.21372222529156498
# self.rest_data_W0_a 0.11935548663828933
# all_train_score_W_Combined_n 0.21385365141019116
# all_train_score_W_Combined_a 0.11938207253751519
# test_score_W_combined_n 0.20032910348996785
# test_score_W_combined_a 0.10348867430933265
# Not good ari result !!!!!
# Combine Neurons Number :146
# neuron unit number: 25
# all_train_score_W0_n 0.09210445019080887
# all_train_score_W0_a 0.04630210594994151
# test_score_W0_n 0.09518313656276192
# test_score_W0_a  0.04330851517036407
# Split one time!
# self.rest_data_W0_n 0.09200785321962004
# self.rest_data_W0_a 0.04628125489533102
# all_train_score_W_Combined_n 0.09218801492813014
# all_train_score_W_Combined_a 0.046321800772777116
# test_score_W_combined_n 0.10388952159805083
# test_score_W_combined_a 0.04924427275296626
# Combine Neurons Number :27
# neuron unit number: 26
# all_train_score_W0_n 0.21173481379342876
# all_train_score_W0_a 0.12891104294236486
# test_score_W0_n 0.20591376901725103
# test_score_W0_a  0.11390790726023008
# Split one time!
# self.rest_data_W0_n 0.2119440004132016
# self.rest_data_W0_a 0.1289939934015154
# all_train_score_W_Combined_n 0.2120363812921434
# all_train_score_W_Combined_a 0.1290380543749878
# test_score_W_combined_n 0.2223628415083172
# test_score_W_combined_a 0.12292876389064335
# Combine Neurons Number :170
# neuron unit number: 27
# all_train_score_W0_n 0.10187531563145744
# all_train_score_W0_a 0.06034251636033585
# test_score_W0_n 0.1267716408167524
# test_score_W0_a  0.06513155668976896
# Split one time!
# self.rest_data_W0_n 0.10276585789245453
# self.rest_data_W0_a 0.060670655292702796
# Split one time!
# self.rest_data_W0_n 0.5635759405465066
# self.rest_data_W0_a 0.24666379681446404
# all_train_score_W_Combined_n 0.10475833039677922
# all_train_score_W_Combined_a 0.06085675112495441
# test_score_W_combined_n 0.11671166130610197
# test_score_W_combined_a 0.05974893554231957
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :34
# neuron unit number: 28
# all_train_score_W0_n 0.19249882624795944
# all_train_score_W0_a 0.10784464023640734
# test_score_W0_n 0.18985559829949739
# test_score_W0_a  0.0875226629945471
# Split one time!
# self.rest_data_W0_n 0.19245379180368455
# self.rest_data_W0_a 0.10773803070344563
# all_train_score_W_Combined_n 0.19249882624795944
# all_train_score_W_Combined_a 0.10784464023640734
# test_score_W_combined_n 0.1886501068355515
# test_score_W_combined_a 0.09209444394120848
# Not good nmi result !!!!!
# Combine Neurons Number :195
# neuron unit number: 29
# all_train_score_W0_n 0.07868697487801635
# all_train_score_W0_a 0.03228279166205051
# test_score_W0_n 0.09279085756830834
# test_score_W0_a  0.03352212016308435
# Split one time!
# self.rest_data_W0_n 0.07894470960713595
# self.rest_data_W0_a 0.03242305739284631
# all_train_score_W_Combined_n 0.07935310699008193
# all_train_score_W_Combined_a 0.03253141096497475
# test_score_W_combined_n 0.08692590539467904
# test_score_W_combined_a 0.0265952447689267
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :31
# neuron unit number: 30
# all_train_score_W0_n 0.22974579116801563
# all_train_score_W0_a 0.1397561734501087
# test_score_W0_n 0.23304572794150544
# test_score_W0_a  0.12541794568209846
# Split one time!
# self.rest_data_W0_n 0.2294954256177756
# self.rest_data_W0_a 0.1396734647761282
# all_train_score_W_Combined_n 0.2298958349061426
# all_train_score_W_Combined_a 0.13976060542619131
# test_score_W_combined_n 0.23508151511333766
# test_score_W_combined_a 0.12590182986918802
# Combine Neurons Number :225
# neuron unit number: 31
# all_train_score_W0_n 0.08451919472267376
# all_train_score_W0_a 0.03353597866854182
# test_score_W0_n 0.10811560359216162
# test_score_W0_a  0.041190542567301466
# Split one time!
# self.rest_data_W0_n 0.08451281345938974
# self.rest_data_W0_a 0.03366088437402717
# Split one time!
# self.rest_data_W0_n 0.5682519468790386
# self.rest_data_W0_a -0.058823529411764705
# all_train_score_W_Combined_n 0.08545338642966684
# all_train_score_W_Combined_a 0.033917036658539276
# test_score_W_combined_n 0.09925213528010841
# test_score_W_combined_a 0.037967260288395706
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :37
# neuron unit number: 32
# all_train_score_W0_n 0.24318684890027362
# all_train_score_W0_a 0.1462537489363535
# test_score_W0_n 0.21882242123693224
# test_score_W0_a  0.11721148915900342
# Split one time!
# self.rest_data_W0_n 0.24318380869890452
# self.rest_data_W0_a 0.14619839798064097
# all_train_score_W_Combined_n 0.2434234762881582
# all_train_score_W_Combined_a 0.1463854646842691
# test_score_W_combined_n 0.22050735725889078
# test_score_W_combined_a 0.11556704174085174
# Not good ari result !!!!!
# Combine Neurons Number :255
# neuron unit number: 33
# all_train_score_W0_n 0.06327111908371073
# all_train_score_W0_a 0.037102362823679666
# test_score_W0_n 0.08410880168182795
# test_score_W0_a  0.041663850921704944
# Split one time!
# self.rest_data_W0_n 0.06321368807255014
# self.rest_data_W0_a 0.03701432400539198
# all_train_score_W_Combined_n 0.06333707440996614
# all_train_score_W_Combined_a 0.03709408838553936
# test_score_W_combined_n 0.08009755876716977
# test_score_W_combined_a 0.043002810767407654
# Not good nmi result !!!!!
# Combine Neurons Number :36
# neuron unit number: 34
# all_train_score_W0_n 0.24232842945531885
# all_train_score_W0_a 0.14274067346155728
# test_score_W0_n 0.21659557604923366
# test_score_W0_a  0.10940215369653637
# Split one time!
# self.rest_data_W0_n 0.2424034572154458
# self.rest_data_W0_a 0.14282600772583645
# all_train_score_W_Combined_n 0.242588096229832
# all_train_score_W_Combined_a 0.14292055341049736
# test_score_W_combined_n 0.21682759620911485
# test_score_W_combined_a 0.1098379349693678
# Combine Neurons Number :283
# neuron unit number: 35
# all_train_score_W0_n 0.0628664255928972
# all_train_score_W0_a 0.027547691672335225
# test_score_W0_n 0.07801196934250886
# test_score_W0_a  0.029434544221633163
# Split one time!
# self.rest_data_W0_n 0.06293558889511965
# self.rest_data_W0_a 0.02706109309973401
# Split one time!
# self.rest_data_W0_n 0.5174537267731402
# self.rest_data_W0_a 0.31991692484024836
# all_train_score_W_Combined_n 0.06962608127634234
# all_train_score_W_Combined_a 0.02857506942879656
# test_score_W_combined_n 0.0730338707824333
# test_score_W_combined_a 0.02318143150696946
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :48
# neuron unit number: 36
# all_train_score_W0_n 0.2421072031136272
# all_train_score_W0_a 0.14127079344821417
# test_score_W0_n 0.21775350452541442
# test_score_W0_a  0.1127720112899226
# Split one time!
# self.rest_data_W0_n 0.24222837246621867
# self.rest_data_W0_a 0.14135649936413314
# all_train_score_W_Combined_n 0.24227217426446648
# all_train_score_W_Combined_a 0.14139003164534994
# test_score_W_combined_n 0.22308601834754208
# test_score_W_combined_a 0.11092348408850759
# Not good ari result !!!!!
# Combine Neurons Number :280
# neuron unit number: 37
# all_train_score_W0_n 0.11580781987774118
# all_train_score_W0_a 0.05706567240483232
# test_score_W0_n 0.11960484090706586
# test_score_W0_a  0.05274927340559046
# Split one time!
# self.rest_data_W0_n 0.1155819389160918
# self.rest_data_W0_a 0.056968837608122096
# all_train_score_W_Combined_n 0.11656900586688075
# all_train_score_W_Combined_a 0.05718305889031616
# test_score_W_combined_n 0.14043608425535634
# test_score_W_combined_a 0.05889371087065894
# Combine Neurons Number :41
# neuron unit number: 38
# all_train_score_W0_n 0.24444380822620823
# all_train_score_W0_a 0.15065420787171113
# test_score_W0_n 0.2144603285049806
# test_score_W0_a  0.11045267559751726
# Split one time!
# self.rest_data_W0_n 0.24604808496527467
# self.rest_data_W0_a 0.15238987369988444
# all_train_score_W_Combined_n 0.2476506040049293
# all_train_score_W_Combined_a 0.15321502847553134
# test_score_W_combined_n 0.22392519201875746
# test_score_W_combined_a 0.12218543195604768
# Combine Neurons Number :325
# neuron unit number: 39
# all_train_score_W0_n 0.1164366084433906
# all_train_score_W0_a 0.06491554503181017
# test_score_W0_n 0.12067841535759384
# test_score_W0_a  0.06359716661296076
# Split one time!
# self.rest_data_W0_n 0.1152266262017023
# self.rest_data_W0_a 0.06394105887953437
# all_train_score_W_Combined_n 0.11567279258136166
# all_train_score_W_Combined_a 0.064089204116898
# test_score_W_combined_n 0.12421931685223798
# test_score_W_combined_a 0.06291927407866243
# Not good ari result !!!!!
# Combine Neurons Number :42
# neuron unit number: 40
# all_train_score_W0_n 0.26975510091562593
# all_train_score_W0_a 0.15455228222292963
# test_score_W0_n 0.23162531838061615
# test_score_W0_a  0.11410677419090948
# Split one time!
# self.rest_data_W0_n 0.2720244432409765
# self.rest_data_W0_a 0.15594245804889154
# Split one time!
# self.rest_data_W0_n 0.6753966387169619
# self.rest_data_W0_a 0.45680873418299756
# all_train_score_W_Combined_n 0.2734402610398212
# all_train_score_W_Combined_a 0.15693008813247006
# test_score_W_combined_n 0.22664948564774476
# test_score_W_combined_a 0.11495067631113237
# Not good nmi result !!!!!
# Combine Neurons Number :353
# neuron unit number: 41
# all_train_score_W0_n 0.12388582447051717
# all_train_score_W0_a 0.06992573847890049
# test_score_W0_n 0.1325252563806648
# test_score_W0_a  0.06363896712452508
# Split one time!
# self.rest_data_W0_n 0.12381304168408526
# self.rest_data_W0_a 0.06990847801034354
# all_train_score_W_Combined_n 0.12406323927256299
# all_train_score_W_Combined_a 0.06997960001497554
# test_score_W_combined_n 0.12774991100091826
# test_score_W_combined_a 0.06457791445474055
# Not good nmi result !!!!!
# Combine Neurons Number :44
# neuron unit number: 42
# all_train_score_W0_n 0.2471282761878567
# all_train_score_W0_a 0.148300615061892
# test_score_W0_n 0.2150973524784749
# test_score_W0_a  0.11240890545887838
# Split one time!
# self.rest_data_W0_n 0.24738309632250652
# self.rest_data_W0_a 0.14839740544513877
# all_train_score_W_Combined_n 0.24747594994870448
# all_train_score_W_Combined_a 0.1485077845078451
# test_score_W_combined_n 0.22035007152935415
# test_score_W_combined_a 0.11595828179899122
# Combine Neurons Number :350
# neuron unit number: 43
# all_train_score_W0_n 0.12733081939408478
# all_train_score_W0_a 0.061354480166496986
# test_score_W0_n 0.13647392542914513
# test_score_W0_a  0.06547156309840436
# Split one time!
# self.rest_data_W0_n 0.12764802567648076
# self.rest_data_W0_a 0.061425762698680345
# all_train_score_W_Combined_n 0.12822018384540743
# all_train_score_W_Combined_a 0.061744037268862836
# test_score_W_combined_n 0.12162236387562968
# test_score_W_combined_a 0.05736361390774815
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :47
# neuron unit number: 44
# all_train_score_W0_n 0.2854003754095094
# all_train_score_W0_a 0.16907205834655625
# test_score_W0_n 0.2397988920264747
# test_score_W0_a  0.12512861146860604
# Split one time!
# self.rest_data_W0_n 0.2856063209126811
# self.rest_data_W0_a 0.16933514914404527
# all_train_score_W_Combined_n 0.2857648949431059
# all_train_score_W_Combined_a 0.16953387980386805
# test_score_W_combined_n 0.2571645427981546
# test_score_W_combined_a 0.13449991233194067
# Combine Neurons Number :380
# neuron unit number: 45
# all_train_score_W0_n 0.12961702267644612
# all_train_score_W0_a 0.06154694091589428
# test_score_W0_n 0.14209041441351605
# test_score_W0_a  0.06586814788400053
# Split one time!
# self.rest_data_W0_n 0.1296670515561707
# self.rest_data_W0_a 0.06159551027994965
# all_train_score_W_Combined_n 0.12975270880514456
# all_train_score_W_Combined_a 0.0617076273150403
# test_score_W_combined_n 0.1284202453218905
# test_score_W_combined_a 0.062330455902787636
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :47
# neuron unit number: 46
# all_train_score_W0_n 0.2693548749854586
# all_train_score_W0_a 0.15752410801408734
# test_score_W0_n 0.2148077072351249
# test_score_W0_a  0.105232028125669
# Split one time!
# self.rest_data_W0_n 0.26957084884727067
# self.rest_data_W0_a 0.1579764125685363
# Split one time!
# self.rest_data_W0_n 0.7877227528268249
# self.rest_data_W0_a 0.4391038696537678
# all_train_score_W_Combined_n 0.2708696763867925
# all_train_score_W_Combined_a 0.15892217055450986
# test_score_W_combined_n 0.22765340828899405
# test_score_W_combined_a 0.11362168131419588
# Combine Neurons Number :373
# neuron unit number: 47
# all_train_score_W0_n 0.10279149159112481
# all_train_score_W0_a 0.05389902434540192
# test_score_W0_n 0.11151553262358731
# test_score_W0_a  0.052545683306032515
# Split one time!
# self.rest_data_W0_n 0.10311097180999666
# self.rest_data_W0_a 0.05412171337174025
# Split one time!
# self.rest_data_W0_n 0.6047894602392057
# self.rest_data_W0_a 0.08695652173913043
# all_train_score_W_Combined_n 0.10321787590706288
# all_train_score_W_Combined_a 0.05442638702685308
# test_score_W_combined_n 0.10708958492849752
# test_score_W_combined_a 0.050154653256372424
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :52
# neuron unit number: 48
# all_train_score_W0_n 0.2730114859784137
# all_train_score_W0_a 0.16632012432061508
# test_score_W0_n 0.21638130249316628
# test_score_W0_a  0.11210345161383746
# Split one time!
# self.rest_data_W0_n 0.27316760821372105
# self.rest_data_W0_a 0.16637147487150833
# all_train_score_W_Combined_n 0.27331800307141974
# all_train_score_W_Combined_a 0.16657668156203823
# test_score_W_combined_n 0.23549523332784641
# test_score_W_combined_a 0.1164679175822358
# Combine Neurons Number :404
# neuron unit number: 49
# all_train_score_W0_n 0.12287290952264004
# all_train_score_W0_a 0.06627480632876667
# test_score_W0_n 0.13237982535306836
# test_score_W0_a  0.06755371069783411
# Split one time!
# self.rest_data_W0_n 0.12274509216738316
# self.rest_data_W0_a 0.06628503193655849
# Split one time!
# self.rest_data_W0_n 0.47172987604316907
# self.rest_data_W0_a -0.06242905788876277
# all_train_score_W_Combined_n 0.12347939455253223
# all_train_score_W_Combined_a 0.06644746454024356
# test_score_W_combined_n 0.12340261537357898
# test_score_W_combined_a 0.061095882475577484
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :55
# neuron unit number: 50
# all_train_score_W0_n 0.3045659164657405
# all_train_score_W0_a 0.183901160178164
# test_score_W0_n 0.24203946264951826
# test_score_W0_a  0.12335012506516024
# Split one time!
# self.rest_data_W0_n 0.30515219919317793
# self.rest_data_W0_a 0.18363155648646554
# all_train_score_W_Combined_n 0.30626936902045565
# all_train_score_W_Combined_a 0.18453050962808507
# test_score_W_combined_n 0.260837558956569
# test_score_W_combined_a 0.13164634972332873
# Combine Neurons Number :475
# neuron unit number: 51
# all_train_score_W0_n 0.10043318833880646
# all_train_score_W0_a 0.04751200255468814
# test_score_W0_n 0.10897845982284475
# test_score_W0_a  0.04174175256586038
# Split one time!
# self.rest_data_W0_n 0.1022203153003204
# self.rest_data_W0_a 0.04744599472876598
# Split one time!
# self.rest_data_W0_n 0.7220363163219347
# self.rest_data_W0_a 0.30129343139741316
# Split one time!
# self.rest_data_W0_n 0.7020168761809934
# self.rest_data_W0_a 0.3333333333333333
# all_train_score_W_Combined_n 0.10339712817263624
# all_train_score_W_Combined_a 0.04813587910856158
# test_score_W_combined_n 0.11004633054714828
# test_score_W_combined_a 0.04412143751225209
# Combine Neurons Number :65
# neuron unit number: 52
# all_train_score_W0_n 0.2842604370168434
# all_train_score_W0_a 0.16976375450964767
# test_score_W0_n 0.24282017137856945
# test_score_W0_a  0.13022909506744657
# Split one time!
# self.rest_data_W0_n 0.28431852283964315
# self.rest_data_W0_a 0.169895725832662
# all_train_score_W_Combined_n 0.28440952789636936
# all_train_score_W_Combined_a 0.1699443940198329
# test_score_W_combined_n 0.2396428870371988
# test_score_W_combined_a 0.12370372519574087
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :416
# neuron unit number: 53
# all_train_score_W0_n 0.09761228372025763
# all_train_score_W0_a 0.05743681814115237
# test_score_W0_n 0.10646870431443932
# test_score_W0_a  0.04977834700469572
# Split one time!
# self.rest_data_W0_n 0.09774277286981553
# self.rest_data_W0_a 0.05747374230588023
# all_train_score_W_Combined_n 0.09794396690272117
# all_train_score_W_Combined_a 0.05757197834322658
# test_score_W_combined_n 0.1074098283538864
# test_score_W_combined_a 0.05216709752953995
# Combine Neurons Number :56
# neuron unit number: 54
# all_train_score_W0_n 0.3014814263124059
# all_train_score_W0_a 0.18201472784258063
# test_score_W0_n 0.23815427813267262
# test_score_W0_a  0.11579943419743453
# Split one time!
# self.rest_data_W0_n 0.30167331400301733
# self.rest_data_W0_a 0.18220132483584106
# Split one time!
# self.rest_data_W0_n 0.8889132922700328
# self.rest_data_W0_a 0.6835443037974683
# all_train_score_W_Combined_n 0.3025371394033445
# all_train_score_W_Combined_a 0.18280374560355916
# test_score_W_combined_n 0.25562378086890597
# test_score_W_combined_a 0.12842307986793988
# Combine Neurons Number :469
# neuron unit number: 55
# all_train_score_W0_n 0.09314419017917643
# all_train_score_W0_a 0.050395797318582555
# test_score_W0_n 0.10488878793308172
# test_score_W0_a  0.05339634879220742
# Split one time!
# self.rest_data_W0_n 0.09310300538149044
# self.rest_data_W0_a 0.05023619104320428
# Split one time!
# self.rest_data_W0_n 0.7207998771789583
# self.rest_data_W0_a 0.19801980198019803
# all_train_score_W_Combined_n 0.09440135688089493
# all_train_score_W_Combined_a 0.050738457126198594
# test_score_W_combined_n 0.09657407860522879
# test_score_W_combined_a 0.04520770569992273
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :64
# neuron unit number: 56
# all_train_score_W0_n 0.2689105248194755
# all_train_score_W0_a 0.1633424977109929
# test_score_W0_n 0.22153759717249222
# test_score_W0_a  0.11712489258272214
# Split one time!
# self.rest_data_W0_n 0.27011025645732084
# self.rest_data_W0_a 0.1637584823007796
# Split one time!
# self.rest_data_W0_n 0.6692825329805316
# self.rest_data_W0_a 0.3636151409037852
# all_train_score_W_Combined_n 0.27116175407351734
# all_train_score_W_Combined_a 0.16449546661939576
# test_score_W_combined_n 0.23290184644260523
# test_score_W_combined_a 0.12249229151011667
# Combine Neurons Number :416
# neuron unit number: 57
# all_train_score_W0_n 0.09792381743243102
# all_train_score_W0_a 0.04769544260213281
# test_score_W0_n 0.11979808948290237
# test_score_W0_a  0.053879572262282294
# Split one time!
# self.rest_data_W0_n 0.09943257116431585
# self.rest_data_W0_a 0.04944104235450221
# Split one time!
# self.rest_data_W0_n 0.3707340062445727
# self.rest_data_W0_a 0.14518929847062098
# Split one time!
# self.rest_data_W0_n 0.4608364423355549
# self.rest_data_W0_a 0.09439562358144678
# all_train_score_W_Combined_n 0.10346716651071762
# all_train_score_W_Combined_a 0.05060194077003595
# test_score_W_combined_n 0.11565751819133084
# test_score_W_combined_a 0.050033289218542304
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :77
# neuron unit number: 58
# all_train_score_W0_n 0.2840399460985341
# all_train_score_W0_a 0.170183467013871
# test_score_W0_n 0.23234983648588795
# test_score_W0_a  0.11479896563592037
# Split one time!
# self.rest_data_W0_n 0.28428509876878505
# self.rest_data_W0_a 0.17019837948312866
# all_train_score_W_Combined_n 0.28471924213465283
# all_train_score_W_Combined_a 0.1703529739498452
# test_score_W_combined_n 0.24946380980059982
# test_score_W_combined_a 0.12495679893845037
# Combine Neurons Number :470
# neuron unit number: 59
# all_train_score_W0_n 0.1197807145076414
# all_train_score_W0_a 0.05681999736744182
# test_score_W0_n 0.12659496842420648
# test_score_W0_a  0.059792782683642166
# Split one time!
# self.rest_data_W0_n 0.11980881848395934
# self.rest_data_W0_a 0.05691434378559059
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.12014422978422465
# all_train_score_W_Combined_a 0.05711828199069852
# test_score_W_combined_n 0.11672364786795023
# test_score_W_combined_a 0.05311126435707101
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :64
# neuron unit number: 60
# all_train_score_W0_n 0.3127091611911682
# all_train_score_W0_a 0.18525807757461493
# test_score_W0_n 0.2289715249885413
# test_score_W0_a  0.11410165034932832
# Split one time!
# self.rest_data_W0_n 0.3128821832500817
# self.rest_data_W0_a 0.18542900396955878
# all_train_score_W_Combined_n 0.31349466399086146
# all_train_score_W_Combined_a 0.18572498400761314
# test_score_W_combined_n 0.2634126686577399
# test_score_W_combined_a 0.1363740947524054
# Combine Neurons Number :515
# neuron unit number: 61
# all_train_score_W0_n 0.09912293812416642
# all_train_score_W0_a 0.049516782310258134
# test_score_W0_n 0.10880281192451705
# test_score_W0_a  0.04966521766546357
# Split one time!
# self.rest_data_W0_n 0.09939935408978906
# self.rest_data_W0_a 0.0497457300454568
# all_train_score_W_Combined_n 0.09976477975483787
# all_train_score_W_Combined_a 0.0500708679422279
# test_score_W_combined_n 0.1059343905084186
# test_score_W_combined_a 0.04262532273016605
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :63
# neuron unit number: 62
# all_train_score_W0_n 0.28642792229469055
# all_train_score_W0_a 0.17827571160178765
# test_score_W0_n 0.24379156584466255
# test_score_W0_a  0.13338346880347743
# Split one time!
# self.rest_data_W0_n 0.2867486280466637
# self.rest_data_W0_a 0.17842794393496578
# all_train_score_W_Combined_n 0.28695530074877235
# all_train_score_W_Combined_a 0.17847540664266945
# test_score_W_combined_n 0.23581452494894464
# test_score_W_combined_a 0.12203734024315292
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :481
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   50.0  0.157965  0.057797  0.008174   0.141539  0.174391
# 1  test_score_W'   50.0  0.159653  0.063415  0.008968   0.141630  0.177675
# 2       combined  100.0  0.158809  0.060370  0.006037   0.146830  0.170788
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0017
# 1                          Degrees of freedom =   98.0000
# 2                                           t =   -0.1391
# 3                       Two side test p value =    0.8897
# 4                      Difference < 0 p value =    0.4448
# 5                      Difference > 0 p value =    0.5552
# 6                                   Cohen's d =   -0.0278
# 7                                   Hedge's g =   -0.0276
# 8                               Glass's delta =   -0.0292
# 9                                 Pearson's r =    0.0140
# ARI T-Test
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   50.0  0.157965  0.057797  0.008174   0.141539  0.174391
# 1  test_score_W'   50.0  0.078090  0.036425  0.005151   0.067738  0.088441
# 2       combined  100.0  0.118027  0.062620  0.006262   0.105602  0.130452
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0799
# 1                          Degrees of freedom =   98.0000
# 2                                           t =    8.2673
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    1.0000
# 5                      Difference > 0 p value =    0.0000
# 6                                   Cohen's d =    1.6535
# 7                                   Hedge's g =    1.6408
# 8                               Glass's delta =    1.3820
# 9                                 Pearson's r =    0.6410
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.26906173948247464
# all_train_score_W0_a 0.1614301250613603
# test_score_W0_n 0.21234748466643422
# test_score_W0_a  0.10637751341710044
# Split one time!
# self.rest_data_W0_n 0.26859038652150635
# self.rest_data_W0_a 0.16122398079709468
# all_train_score_W_Combined_n 0.26892936040572246
# all_train_score_W_Combined_a 0.16149840680947236
# test_score_W_combined_n 0.23454769053707558
# test_score_W_combined_a 0.11724743664268832
# Combine Neurons Number :417
# all_train_score_W0_n 0.26418220264506126
# all_train_score_W0_a 0.16203915548826958
# test_score_W0_n 0.2037727100476433
# test_score_W0_a  0.11046321215338879
# Split one time!
# self.rest_data_W0_n 0.2659613701542906
# self.rest_data_W0_a 0.16374948963060323
# Split one time!
# self.rest_data_W0_n 0.7974267338801974
# self.rest_data_W0_a 0.6660039761431411
# all_train_score_W_Combined_n 0.26692437684737097
# all_train_score_W_Combined_a 0.16442924841998882
# test_score_W_combined_n 0.23554309147701957
# test_score_W_combined_a 0.12653910167269006
# Combine Neurons Number :374
# all_train_score_W0_n 0.26452861571011427
# all_train_score_W0_a 0.15694231020524307
# test_score_W0_n 0.21369126912757105
# test_score_W0_a  0.10474894518423555
# Split one time!
# self.rest_data_W0_n 0.2646647791320893
# self.rest_data_W0_a 0.1570559753634419
# all_train_score_W_Combined_n 0.2648632033758485
# all_train_score_W_Combined_a 0.15726639814832852
# test_score_W_combined_n 0.21856749251156615
# test_score_W_combined_a 0.11170820240126088
# Combine Neurons Number :373
# all_train_score_W0_n 0.27426222183652793
# all_train_score_W0_a 0.15836815466772844
# test_score_W0_n 0.2285363498314343
# test_score_W0_a  0.11446576438181293
# Split one time!
# self.rest_data_W0_n 0.2743704925912211
# self.rest_data_W0_a 0.15872407315917594
# Split one time!
# self.rest_data_W0_n 0.7666667869495797
# self.rest_data_W0_a 0.764903318415942
# all_train_score_W_Combined_n 0.2784396289529002
# all_train_score_W_Combined_a 0.1620612188007656
# test_score_W_combined_n 0.2354787803544566
# test_score_W_combined_a 0.117180885649147
# Combine Neurons Number :444
# all_train_score_W0_n 0.25861174493308914
# all_train_score_W0_a 0.1585908222983825
# test_score_W0_n 0.20936249622306774
# test_score_W0_a  0.11117691584804938
# Split one time!
# self.rest_data_W0_n 0.25864265323029245
# self.rest_data_W0_a 0.15861637637203405
# all_train_score_W_Combined_n 0.25883409752795367
# all_train_score_W_Combined_a 0.15877947734681896
# test_score_W_combined_n 0.22657107008389227
# test_score_W_combined_a 0.12029844934670009
# Combine Neurons Number :353
# all_train_score_W0_n 0.3004166142695028
# all_train_score_W0_a 0.17947160352683997
# test_score_W0_n 0.2539927712235904
# test_score_W0_a  0.13320404490668444
# Split one time!
# self.rest_data_W0_n 0.300371895257308
# self.rest_data_W0_a 0.1794393332398278
# all_train_score_W_Combined_n 0.3004166142695028
# all_train_score_W_Combined_a 0.17947160352683997
# test_score_W_combined_n 0.251459136522726
# test_score_W_combined_a 0.13796001112959982
# Not good nmi result !!!!!
# Combine Neurons Number :416
# all_train_score_W0_n 0.2685910263315561
# all_train_score_W0_a 0.15964914573642125
# test_score_W0_n 0.22079069307220608
# test_score_W0_a  0.10785749914341498
# Split one time!
# self.rest_data_W0_n 0.26817524345027993
# self.rest_data_W0_a 0.15969322697605506
# Split one time!
# self.rest_data_W0_n 0.6913309094816217
# self.rest_data_W0_a 0.6181818181818182
# all_train_score_W_Combined_n 0.2697724871851286
# all_train_score_W_Combined_a 0.16044788366461016
# test_score_W_combined_n 0.2360362601043808
# test_score_W_combined_a 0.12181763706291064
# Combine Neurons Number :400
# all_train_score_W0_n 0.2773811351902521
# all_train_score_W0_a 0.16320249886588903
# test_score_W0_n 0.2297218947478187
# test_score_W0_a  0.11386914528302183
# Split one time!
# self.rest_data_W0_n 0.2773922389884119
# self.rest_data_W0_a 0.16322468794816902
# all_train_score_W_Combined_n 0.27753762275817306
# all_train_score_W_Combined_a 0.16331460144776555
# test_score_W_combined_n 0.24477875627158902
# test_score_W_combined_a 0.12777660430115095
# Combine Neurons Number :405
# all_train_score_W0_n 0.253661946334051
# all_train_score_W0_a 0.15279033645620316
# test_score_W0_n 0.21547512868872395
# test_score_W0_a  0.10767044172853846
# Split one time!
# self.rest_data_W0_n 0.2536175227207767
# self.rest_data_W0_a 0.1526428490586834
# all_train_score_W_Combined_n 0.253661946334051
# all_train_score_W_Combined_a 0.15279033645620316
# test_score_W_combined_n 0.2214665388601899
# test_score_W_combined_a 0.11487032991110092
# Combine Neurons Number :390
# all_train_score_W0_n 0.2752278598387475
# all_train_score_W0_a 0.15972006771287822
# test_score_W0_n 0.22291824956880202
# test_score_W0_a  0.10465299420043322
# Split one time!
# self.rest_data_W0_n 0.2756785556493232
# self.rest_data_W0_a 0.16020512054218905
# Split one time!
# self.rest_data_W0_n 0.9100768814915506
# self.rest_data_W0_a 0.7994945240101096
# all_train_score_W_Combined_n 0.2768778781469386
# all_train_score_W_Combined_a 0.1611643643697751
# test_score_W_combined_n 0.24039501871672242
# test_score_W_combined_a 0.11563808884448412
# Combine Neurons Number :378
# all_train_score_W0_n 0.26263262979480145
# all_train_score_W0_a 0.1646487390058246
# test_score_W0_n 0.23342726288656132
# test_score_W0_a  0.1320723993377571
# Split one time!
# self.rest_data_W0_n 0.26451041713728773
# self.rest_data_W0_a 0.16584984495862418
# Split one time!
# self.rest_data_W0_n 0.7479487866466171
# self.rest_data_W0_a 0.4883303411131059
# all_train_score_W_Combined_n 0.26548699369865997
# all_train_score_W_Combined_a 0.16639849857763703
# test_score_W_combined_n 0.24626373532014448
# test_score_W_combined_a 0.14077098421092285
# Combine Neurons Number :359
# all_train_score_W0_n 0.25707795758368895
# all_train_score_W0_a 0.16194163493930713
# test_score_W0_n 0.20412211573566044
# test_score_W0_a  0.10975012652735645
# Split one time!
# self.rest_data_W0_n 0.257188369803748
# self.rest_data_W0_a 0.1620702056197013
# all_train_score_W_Combined_n 0.25730160302816957
# all_train_score_W_Combined_a 0.16215564053900064
# test_score_W_combined_n 0.21657110248298836
# test_score_W_combined_a 0.11891050679747829
# Combine Neurons Number :402
# all_train_score_W0_n 0.2668906050708662
# all_train_score_W0_a 0.1680353906035435
# test_score_W0_n 0.23224378172522867
# test_score_W0_a  0.11963949331995952
# Split one time!
# self.rest_data_W0_n 0.2708385111166044
# self.rest_data_W0_a 0.16859125756281113
# Split one time!
# self.rest_data_W0_n 0.7044404688962211
# self.rest_data_W0_a 0.4517543859649123
# all_train_score_W_Combined_n 0.27363391545724514
# all_train_score_W_Combined_a 0.1698791604627451
# test_score_W_combined_n 0.23370067517485027
# test_score_W_combined_a 0.1265380063935635
# Combine Neurons Number :439
# all_train_score_W0_n 0.25318502215675537
# all_train_score_W0_a 0.14681502359791015
# test_score_W0_n 0.2155911892349951
# test_score_W0_a  0.11423929161594057
# Split one time!
# self.rest_data_W0_n 0.2536919047230457
# self.rest_data_W0_a 0.14727121356956663
# all_train_score_W_Combined_n 0.25401210604181174
# all_train_score_W_Combined_a 0.14745628130328198
# test_score_W_combined_n 0.2241500715791282
# test_score_W_combined_a 0.11947110842600599
# Combine Neurons Number :324
# all_train_score_W0_n 0.22882594176193385
# all_train_score_W0_a 0.13614234006669793
# test_score_W0_n 0.191802731125795
# test_score_W0_a  0.10649807943096323
# Split one time!
# self.rest_data_W0_n 0.22837999665861902
# self.rest_data_W0_a 0.13607629849512745
# all_train_score_W_Combined_n 0.22916313214013154
# all_train_score_W_Combined_a 0.13639855065131862
# test_score_W_combined_n 0.20480381065217143
# test_score_W_combined_a 0.11276760947738462
# Combine Neurons Number :312
# all_train_score_W0_n 0.2851548168677657
# all_train_score_W0_a 0.17611451080506732
# test_score_W0_n 0.2370821101262228
# test_score_W0_a  0.1242553297706858
# Split one time!
# self.rest_data_W0_n 0.28677002186782974
# self.rest_data_W0_a 0.1765178421141008
# all_train_score_W_Combined_n 0.28747292225265364
# all_train_score_W_Combined_a 0.17704256511409214
# test_score_W_combined_n 0.2413200168554374
# test_score_W_combined_a 0.12438517623448958
# Combine Neurons Number :431
# all_train_score_W0_n 0.25327786813355946
# all_train_score_W0_a 0.15594847859783423
# test_score_W0_n 0.2079865423476554
# test_score_W0_a  0.10470571869782028
# Split one time!
# self.rest_data_W0_n 0.253370317959541
# self.rest_data_W0_a 0.15573500199715046
# all_train_score_W_Combined_n 0.2536327764329922
# all_train_score_W_Combined_a 0.15615608924138497
# test_score_W_combined_n 0.22068177355703733
# test_score_W_combined_a 0.10845782518389305
# Combine Neurons Number :400
# all_train_score_W0_n 0.23050239321940075
# all_train_score_W0_a 0.13768849729853888
# test_score_W0_n 0.17657109209905766
# test_score_W0_a  0.08672203668237413
# Split one time!
# self.rest_data_W0_n 0.23051016507054561
# self.rest_data_W0_a 0.1378010271902336
# all_train_score_W_Combined_n 0.2306839725057922
# all_train_score_W_Combined_a 0.13784456826182148
# test_score_W_combined_n 0.1912260208959538
# test_score_W_combined_a 0.09534186833687779
# Combine Neurons Number :362
# all_train_score_W0_n 0.2995531539913758
# all_train_score_W0_a 0.17778030623451208
# test_score_W0_n 0.24636509104859272
# test_score_W0_a  0.13202106092676752
# Split one time!
# self.rest_data_W0_n 0.29970866436723814
# self.rest_data_W0_a 0.1781097576042645
# all_train_score_W_Combined_n 0.30013930070936606
# all_train_score_W_Combined_a 0.17843322012795682
# test_score_W_combined_n 0.26615998744503644
# test_score_W_combined_a 0.13363165293705037
# Combine Neurons Number :433
# all_train_score_W0_n 0.2592636385858703
# all_train_score_W0_a 0.15070228126635937
# test_score_W0_n 0.21070617909978187
# test_score_W0_a  0.10555088146659998
# Split one time!
# self.rest_data_W0_n 0.25930449688831547
# self.rest_data_W0_a 0.15077330098560818
# all_train_score_W_Combined_n 0.2595881436654659
# all_train_score_W_Combined_a 0.15082139974428646
# test_score_W_combined_n 0.2281065967784762
# test_score_W_combined_a 0.11507522522735512
# Combine Neurons Number :380
# all_train_score_W0_n 0.25738651946822144
# all_train_score_W0_a 0.15032480482176308
# test_score_W0_n 0.2277038081858109
# test_score_W0_a  0.11180583721690537
# Split one time!
# self.rest_data_W0_n 0.2583762869297994
# self.rest_data_W0_a 0.150919597163559
# all_train_score_W_Combined_n 0.25897377736691074
# all_train_score_W_Combined_a 0.1511091199841819
# test_score_W_combined_n 0.23693410430117567
# test_score_W_combined_a 0.12174129934713208
# Combine Neurons Number :365
# all_train_score_W0_n 0.269875984320107
# all_train_score_W0_a 0.1596887040887986
# test_score_W0_n 0.23394996085930073
# test_score_W0_a  0.1154776793544223
# Split one time!
# self.rest_data_W0_n 0.2700007024165763
# self.rest_data_W0_a 0.15974990439687792
# all_train_score_W_Combined_n 0.2706857337466708
# all_train_score_W_Combined_a 0.1601111048275853
# test_score_W_combined_n 0.2445245284720809
# test_score_W_combined_a 0.12225809301588897
# Combine Neurons Number :401
# all_train_score_W0_n 0.2935678749707963
# all_train_score_W0_a 0.173993389597677
# test_score_W0_n 0.24563286035410367
# test_score_W0_a  0.12587878054448895
# Split one time!
# self.rest_data_W0_n 0.29409460034435914
# self.rest_data_W0_a 0.17408285772648222
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2954820085845663
# all_train_score_W_Combined_a 0.17488546227706583
# test_score_W_combined_n 0.27094100392183673
# test_score_W_combined_a 0.13744634691649754
# Combine Neurons Number :389
# all_train_score_W0_n 0.25898005694655263
# all_train_score_W0_a 0.15451886844644297
# test_score_W0_n 0.21712848924501368
# test_score_W0_a  0.11151699674795373
# Split one time!
# self.rest_data_W0_n 0.25894945096448607
# self.rest_data_W0_a 0.1544810678737575
# all_train_score_W_Combined_n 0.2591334288378827
# all_train_score_W_Combined_a 0.1546771931442206
# test_score_W_combined_n 0.2266675222001612
# test_score_W_combined_a 0.11486868849105038
# Combine Neurons Number :352
# all_train_score_W0_n 0.2784021591428134
# all_train_score_W0_a 0.16078110890503636
# test_score_W0_n 0.22722136227979084
# test_score_W0_a  0.1119459581481078
# Split one time!
# self.rest_data_W0_n 0.2784812944464228
# self.rest_data_W0_a 0.16086296553133364
# all_train_score_W_Combined_n 0.27852994192773967
# all_train_score_W_Combined_a 0.1608749206782454
# test_score_W_combined_n 0.23832214602947052
# test_score_W_combined_a 0.11642202050352411
# Combine Neurons Number :384
# all_train_score_W0_n 0.28299697142435376
# all_train_score_W0_a 0.17159270999796003
# test_score_W0_n 0.22533070095793076
# test_score_W0_a  0.11300199969234972
# Split one time!
# self.rest_data_W0_n 0.2832089333869876
# self.rest_data_W0_a 0.1716811450809416
# all_train_score_W_Combined_n 0.2834108242547071
# all_train_score_W_Combined_a 0.1717469440129225
# test_score_W_combined_n 0.23754243108485715
# test_score_W_combined_a 0.12064113194117805
# Combine Neurons Number :455
# all_train_score_W0_n 0.27609977665235125
# all_train_score_W0_a 0.15711583577556676
# test_score_W0_n 0.2232583119844911
# test_score_W0_a  0.10445437123646166
# Split one time!
# self.rest_data_W0_n 0.2761353542568091
# self.rest_data_W0_a 0.15715655394400005
# all_train_score_W_Combined_n 0.2767741019341882
# all_train_score_W_Combined_a 0.1577178546504199
# test_score_W_combined_n 0.23483698798531233
# test_score_W_combined_a 0.11921547809122549
# Combine Neurons Number :366
# all_train_score_W0_n 0.27769222768689245
# all_train_score_W0_a 0.16506070245171744
# test_score_W0_n 0.23936704299832132
# test_score_W0_a  0.12026050444600349
# Split one time!
# self.rest_data_W0_n 0.27740245618703446
# self.rest_data_W0_a 0.16483720133114838
# all_train_score_W_Combined_n 0.27822543595494115
# all_train_score_W_Combined_a 0.16542749129402703
# test_score_W_combined_n 0.2553336532655143
# test_score_W_combined_a 0.1296979930730198
# Combine Neurons Number :383
# all_train_score_W0_n 0.26964510157912047
# all_train_score_W0_a 0.16586474765971007
# test_score_W0_n 0.23833150669538192
# test_score_W0_a  0.12893010126741822
# Split one time!
# self.rest_data_W0_n 0.26980496545283383
# self.rest_data_W0_a 0.16607097717496272
# all_train_score_W_Combined_n 0.2703031278365278
# all_train_score_W_Combined_a 0.16645679421896822
# test_score_W_combined_n 0.24557628145737967
# test_score_W_combined_a 0.12699608489447306
# Not good ari result !!!!!
# Combine Neurons Number :391
# all_train_score_W0_n 0.26464854105715885
# all_train_score_W0_a 0.15412865699920378
# test_score_W0_n 0.23260550998242216
# test_score_W0_a  0.12152485236459085
# Split one time!
# self.rest_data_W0_n 0.2647108132332916
# self.rest_data_W0_a 0.15421060290665303
# all_train_score_W_Combined_n 0.26476519426382994
# all_train_score_W_Combined_a 0.15421499976240519
# test_score_W_combined_n 0.23684538308132566
# test_score_W_combined_a 0.1217719511256677
# Combine Neurons Number :370
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.222568  0.016620  0.003034   0.216362  0.228774
# 1  test_score_W'  30.0  0.234845  0.016189  0.002956   0.228800  0.240890
# 2       combined  60.0  0.228706  0.017404  0.002247   0.224210  0.233202
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0123
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -2.8983
# 3                       Two side test p value =    0.0053
# 4                      Difference < 0 p value =    0.0026
# 5                      Difference > 0 p value =    0.9974
# 6                                   Cohen's d =   -0.7483
# 7                                   Hedge's g =   -0.7386
# 8                               Glass's delta =   -0.7387
# 9                                 Pearson's r =    0.3557
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.222568  0.016620  0.003034   0.216362  0.228774
# 1  test_score_W'  30.0  0.121248  0.009302  0.001698   0.117775  0.124722
# 2       combined  60.0  0.171908  0.052804  0.006817   0.158267  0.185549
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.1013
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   29.1372
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    1.0000
# 5                      Difference > 0 p value =    0.0000
# 6                                   Cohen's d =    7.5232
# 7                                   Hedge's g =    7.4255
# 8                               Glass's delta =    6.0963
# 9                                 Pearson's r =    0.9675
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
