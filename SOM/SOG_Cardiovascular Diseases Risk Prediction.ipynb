# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv_original_encode = csv

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode,"General_Health")
#one hot encoding vs proposed
dataread.baseN_encoding(csv_original_encode,["Checkup","Exercise","Heart_Disease","Skin_Cancer","Other_Cancer","Depression","Diabetes","Arthritis","Sex","Age_Category","Smoking_History"])


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")

csv = csv.sample(int(csv.shape[0]*0.01))

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.original_encoding_data = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.01))
csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"General_Health")
# Out:
#  column number self.data_train_discrete 11

# %%
#new binary endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.3515263644773358
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.3444924406047516
# test_discrete_score_W0_n 0.0031174256430705296
# test_discrete_score_W0_a 0.0019940496098394623
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.06196290376014969
# train_discrete_score_W_discrete_a 0.045481874909531025
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.054783728008854775
# test_discrete_score_W_discrete_a 0.040108743894055894
# neuron unit number: 6
# train_discrete_score_W0_p 0.3515263644773358
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.33801295896328293
# test_discrete_score_W0_n 0.0022287297010550734
# test_discrete_score_W0_a 0.0019177624238798118
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.0691660906960345
# train_discrete_score_W_discrete_a 0.05231539636148121
# test_discrete_score_W_discrete_p 0.43844492440604754
# test_discrete_score_W_discrete_n 0.0753053638072032
# test_discrete_score_W_discrete_a 0.06314281333827389
# neuron unit number: 7
# train_discrete_score_W0_p 0.35291396854764107
# train_discrete_score_W0_n 0.0018907861585931941
# train_discrete_score_W0_a  -0.002025902802493852
# test_discrete_score_W0_p 0.34557235421166305
# test_discrete_score_W0_n 0.0036982735498197875
# test_discrete_score_W0_a 0.002969739580552371
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.07027453964497646
# train_discrete_score_W_discrete_a 0.05816420065389211
# test_discrete_score_W_discrete_p 0.4352051835853132
# test_discrete_score_W_discrete_n 0.06533804741989145
# test_discrete_score_W_discrete_a 0.06307725412854892
# neuron unit number: 8
# train_discrete_score_W0_p 0.3538390379278446
# train_discrete_score_W0_n 0.0010806999864071724
# train_discrete_score_W0_a  -0.00013058935619974954
# test_discrete_score_W0_p 0.3390928725701944
# test_discrete_score_W0_n 0.003222289057044419
# test_discrete_score_W0_a 0.0025624197498128653
# train_discrete_score_W_discrete_p 0.4301572617946346
# train_discrete_score_W_discrete_n 0.0710507461937909
# train_discrete_score_W_discrete_a 0.05949688688011357
# test_discrete_score_W_discrete_p 0.4319654427645788
# test_discrete_score_W_discrete_n 0.07374092057767519
# test_discrete_score_W_discrete_a 0.05994877315451775
# neuron unit number: 9
# train_discrete_score_W0_p 0.35291396854764107
# train_discrete_score_W0_n 0.0017685740097176696
# train_discrete_score_W0_a  0.00011532492066283776
# test_discrete_score_W0_p 0.34989200863930886
# test_discrete_score_W0_n 0.004871140488251215
# test_discrete_score_W0_a 0.0016240269237910486
# train_discrete_score_W_discrete_p 0.42183163737280294
# train_discrete_score_W_discrete_n 0.05726542815217942
# train_discrete_score_W_discrete_a 0.05768821512502424
# test_discrete_score_W_discrete_p 0.4222462203023758
# test_discrete_score_W_discrete_n 0.05739932692016455
# test_discrete_score_W_discrete_a 0.045768952871741486
# neuron unit number: 10
# train_discrete_score_W0_p 0.3547641073080481
# train_discrete_score_W0_n 0.000615628468178972
# train_discrete_score_W0_a  0.0009878392676750728
# test_discrete_score_W0_p 0.3444924406047516
# test_discrete_score_W0_n 0.0035511402522875432
# test_discrete_score_W0_a 0.0027590458264023093
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.0646943363718151
# train_discrete_score_W_discrete_a 0.059223108190309695
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.07532505321823471
# test_discrete_score_W_discrete_a 0.0679418785128613
# neuron unit number: 11
# train_discrete_score_W0_p 0.3556891766882516
# train_discrete_score_W0_n 0.0008709587744081637
# train_discrete_score_W0_a  0.001039325312556782
# test_discrete_score_W0_p 0.35205183585313177
# test_discrete_score_W0_n 0.0056607807333268825
# test_discrete_score_W0_a 0.0026492533078700466
# train_discrete_score_W_discrete_p 0.4222941720629047
# train_discrete_score_W_discrete_n 0.06678600478995587
# train_discrete_score_W_discrete_a 0.06319576321508018
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.05775245884850798
# test_discrete_score_W_discrete_a 0.05670994473509042
# neuron unit number: 12
# train_discrete_score_W0_p 0.3515263644773358
# train_discrete_score_W0_n 0.000601107599924648
# train_discrete_score_W0_a  0.0037556484285479535
# test_discrete_score_W0_p 0.34989200863930886
# test_discrete_score_W0_n 0.003908373255127055
# test_discrete_score_W0_a 0.0035217740163463493
# train_discrete_score_W_discrete_p 0.4315448658649399
# train_discrete_score_W_discrete_n 0.06987417523517268
# train_discrete_score_W_discrete_a 0.06638685092777953
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.0727177147681275
# test_discrete_score_W_discrete_a 0.07335262192384795
# neuron unit number: 13
# train_discrete_score_W0_p 0.3547641073080481
# train_discrete_score_W0_n 0.0010253772711396568
# train_discrete_score_W0_a  -0.00010529500756615803
# test_discrete_score_W0_p 0.34557235421166305
# test_discrete_score_W0_n 0.010615142610110383
# test_discrete_score_W0_a 0.005351785427845792
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.06114377668014374
# train_discrete_score_W_discrete_a 0.05343464058161023
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.05401563125237722
# test_discrete_score_W_discrete_a 0.05122203904176233
# neuron unit number: 14
# train_discrete_score_W0_p 0.3547641073080481
# train_discrete_score_W0_n 0.0015089380310152952
# train_discrete_score_W0_a  0.006634252361608133
# test_discrete_score_W0_p 0.35529157667386607
# test_discrete_score_W0_n 0.008911689647535794
# test_discrete_score_W0_a 0.005030511553706399
# train_discrete_score_W_discrete_p 0.43061979648473636
# train_discrete_score_W_discrete_n 0.07098578339902809
# train_discrete_score_W_discrete_a 0.060252703410837515
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.06857131051107766
# test_discrete_score_W_discrete_a 0.060130030888001104
# neuron unit number: 15
# train_discrete_score_W0_p 0.36077705827937095
# train_discrete_score_W0_n 0.0028835584983189864
# train_discrete_score_W0_a  0.007063316718833688
# test_discrete_score_W0_p 0.3509719222462203
# test_discrete_score_W0_n 0.005643919777227271
# test_discrete_score_W0_a 0.002973441665614076
# train_discrete_score_W_discrete_p 0.41905642923219244
# train_discrete_score_W_discrete_n 0.0636962201563268
# train_discrete_score_W_discrete_a 0.05688837225549207
# test_discrete_score_W_discrete_p 0.42332613390928725
# test_discrete_score_W_discrete_n 0.0750286861214985
# test_discrete_score_W_discrete_a 0.06410285396715483
# neuron unit number: 16
# train_discrete_score_W0_p 0.35892691951896394
# train_discrete_score_W0_n 0.0014744860432211251
# train_discrete_score_W0_a  0.0038011413806250806
# test_discrete_score_W0_p 0.3509719222462203
# test_discrete_score_W0_n 0.010149074334988408
# test_discrete_score_W0_a 0.005657332527079155
# train_discrete_score_W_discrete_p 0.42506938020351526
# train_discrete_score_W_discrete_n 0.061391714411473085
# train_discrete_score_W_discrete_a 0.050854185534950344
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.06903567070130305
# test_discrete_score_W_discrete_a 0.06383849366371204
# neuron unit number: 17
# train_discrete_score_W0_p 0.3593894542090657
# train_discrete_score_W0_n 0.0031473438508445796
# train_discrete_score_W0_a  0.005568541870003582
# test_discrete_score_W0_p 0.3542116630669546
# test_discrete_score_W0_n 0.006549461769689079
# test_discrete_score_W0_a 0.004589469752076087
# train_discrete_score_W_discrete_p 0.4213691026827012
# train_discrete_score_W_discrete_n 0.06987312819805572
# train_discrete_score_W_discrete_a 0.06007462632031248
# test_discrete_score_W_discrete_p 0.4406047516198704
# test_discrete_score_W_discrete_n 0.06946317016506642
# test_discrete_score_W_discrete_a 0.06787905419240688
# neuron unit number: 18
# train_discrete_score_W0_p 0.35892691951896394
# train_discrete_score_W0_n 0.002449667627534278
# train_discrete_score_W0_a  0.0008778310775146967
# test_discrete_score_W0_p 0.35529157667386607
# test_discrete_score_W0_n 0.010627744998946562
# test_discrete_score_W0_a 0.008268207344823211
# train_discrete_score_W_discrete_p 0.4116558741905643
# train_discrete_score_W_discrete_n 0.0601137966518954
# train_discrete_score_W_discrete_a 0.05308715782948184
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.0638005717449055
# test_discrete_score_W_discrete_a 0.0560907906253555
# neuron unit number: 19
# train_discrete_score_W0_p 0.35846438482886217
# train_discrete_score_W0_n 0.004265527054307284
# train_discrete_score_W0_a  0.008802137804100343
# test_discrete_score_W0_p 0.35529157667386607
# test_discrete_score_W0_n 0.007553860088151876
# test_discrete_score_W0_a 0.004671797149720171
# train_discrete_score_W_discrete_p 0.4144310823311748
# train_discrete_score_W_discrete_n 0.05546332379811108
# train_discrete_score_W_discrete_a 0.04703924541700546
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.06065119045261826
# test_discrete_score_W_discrete_a 0.0519208796312212
# neuron unit number: 20
# train_discrete_score_W0_p 0.35430157261794637
# train_discrete_score_W0_n 0.0030035731311907807
# train_discrete_score_W0_a  0.0011550775184939908
# test_discrete_score_W0_p 0.34989200863930886
# test_discrete_score_W0_n 0.008937361356074487
# test_discrete_score_W0_a 0.0021309167953158384
# train_discrete_score_W_discrete_p 0.4222941720629047
# train_discrete_score_W_discrete_n 0.06792537698458091
# train_discrete_score_W_discrete_a 0.05870881981013392
# test_discrete_score_W_discrete_p 0.43628509719222464
# test_discrete_score_W_discrete_n 0.06642447167712114
# test_discrete_score_W_discrete_a 0.06856959323740816
# neuron unit number: 21
# train_discrete_score_W0_p 0.3640148011100833
# train_discrete_score_W0_n 0.004975077897295963
# train_discrete_score_W0_a  0.00734802994525777
# test_discrete_score_W0_p 0.3563714902807775
# test_discrete_score_W0_n 0.007664233221828925
# test_discrete_score_W0_a 0.008979693730939466
# train_discrete_score_W_discrete_p 0.41304347826086957
# train_discrete_score_W_discrete_n 0.06990615319341292
# train_discrete_score_W_discrete_a 0.05829510161896233
# test_discrete_score_W_discrete_p 0.4265658747300216
# test_discrete_score_W_discrete_n 0.060661460902586
# test_discrete_score_W_discrete_a 0.05394107025676447
# neuron unit number: 22
# train_discrete_score_W0_p 0.3621646623496762
# train_discrete_score_W0_n 0.003305733554561407
# train_discrete_score_W0_a  0.002904680188228141
# test_discrete_score_W0_p 0.3650107991360691
# test_discrete_score_W0_n 0.00995047913626392
# test_discrete_score_W0_a 0.009678236745217493
# train_discrete_score_W_discrete_p 0.4167437557816836
# train_discrete_score_W_discrete_n 0.06400712632696523
# train_discrete_score_W_discrete_a 0.05634239022609135
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.07568775382664666
# test_discrete_score_W_discrete_a 0.05722175607959156
# neuron unit number: 23
# train_discrete_score_W0_p 0.3617021276595745
# train_discrete_score_W0_n 0.004317455321173677
# train_discrete_score_W0_a  0.00369326162402321
# test_discrete_score_W0_p 0.367170626349892
# test_discrete_score_W0_n 0.011471803778243314
# test_discrete_score_W0_a 0.013178653089828627
# train_discrete_score_W_discrete_p 0.4241443108233117
# train_discrete_score_W_discrete_n 0.06419798346750367
# train_discrete_score_W_discrete_a 0.05688461119275434
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.06923428791777646
# test_discrete_score_W_discrete_a 0.06331401674957925
# neuron unit number: 24
# train_discrete_score_W0_p 0.3612395929694727
# train_discrete_score_W0_n 0.0035877923136121465
# train_discrete_score_W0_a  0.003750080807480064
# test_discrete_score_W0_p 0.3596112311015119
# test_discrete_score_W0_n 0.006880866619335623
# test_discrete_score_W0_a 0.006094452087068465
# train_discrete_score_W_discrete_p 0.41720629047178537
# train_discrete_score_W_discrete_n 0.05688472953005968
# train_discrete_score_W_discrete_a 0.051117003260922146
# test_discrete_score_W_discrete_p 0.43412526997840173
# test_discrete_score_W_discrete_n 0.06322909271570615
# test_discrete_score_W_discrete_a 0.0565242192481956
# neuron unit number: 25
# train_discrete_score_W0_p 0.36308973172987974
# train_discrete_score_W0_n 0.0029295744003814414
# train_discrete_score_W0_a  0.007719431347495231
# test_discrete_score_W0_p 0.3531317494600432
# test_discrete_score_W0_n 0.009220286156065861
# test_discrete_score_W0_a 0.0061912023479243445
# train_discrete_score_W_discrete_p 0.42183163737280294
# train_discrete_score_W_discrete_n 0.07142446857611422
# train_discrete_score_W_discrete_a 0.06816917539856926
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.0737072390657179
# test_discrete_score_W_discrete_a 0.06681954103519232
# neuron unit number: 26
# train_discrete_score_W0_p 0.3617021276595745
# train_discrete_score_W0_n 0.004160946684858622
# train_discrete_score_W0_a  0.007541875216630565
# test_discrete_score_W0_p 0.3650107991360691
# test_discrete_score_W0_n 0.00950005173369086
# test_discrete_score_W0_a 0.011751922470348355
# train_discrete_score_W_discrete_p 0.41535615171137835
# train_discrete_score_W_discrete_n 0.06261788512569452
# train_discrete_score_W_discrete_a 0.05503603224381902
# test_discrete_score_W_discrete_p 0.4330453563714903
# test_discrete_score_W_discrete_n 0.06875415248560339
# test_discrete_score_W_discrete_a 0.060458491350637314
# neuron unit number: 27
# train_discrete_score_W0_p 0.3635522664199815
# train_discrete_score_W0_n 0.006546321374594335
# train_discrete_score_W0_a  0.01952387491165376
# test_discrete_score_W0_p 0.35853131749460043
# test_discrete_score_W0_n 0.010863576657316111
# test_discrete_score_W0_a 0.011052163094450439
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.06114885526564541
# train_discrete_score_W_discrete_a 0.053246451026226965
# test_discrete_score_W_discrete_p 0.4298056155507559
# test_discrete_score_W_discrete_n 0.0592627464009634
# test_discrete_score_W_discrete_a 0.05916249853820744
# neuron unit number: 28
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.00463074924870927
# train_discrete_score_W0_a  0.00630703938297014
# test_discrete_score_W0_p 0.36069114470842334
# test_discrete_score_W0_n 0.008429640178036477
# test_discrete_score_W0_a 0.008073360569614836
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.06675499521985379
# train_discrete_score_W_discrete_a 0.0572455153133435
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.06358667530670643
# test_discrete_score_W_discrete_a 0.06274830783674966
# neuron unit number: 29
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.006750399795886469
# train_discrete_score_W0_a  0.012207843655345541
# test_discrete_score_W0_p 0.36393088552915764
# test_discrete_score_W0_n 0.008782335933451828
# test_discrete_score_W0_a 0.009643088848810922
# train_discrete_score_W_discrete_p 0.4241443108233117
# train_discrete_score_W_discrete_n 0.06400915841322964
# train_discrete_score_W_discrete_a 0.05866601601769848
# test_discrete_score_W_discrete_p 0.4298056155507559
# test_discrete_score_W_discrete_n 0.07221233844038191
# test_discrete_score_W_discrete_a 0.0699954133585461
# neuron unit number: 30
# train_discrete_score_W0_p 0.36262719703977797
# train_discrete_score_W0_n 0.00472554489077764
# train_discrete_score_W0_a  0.008017616860039201
# test_discrete_score_W0_p 0.35205183585313177
# test_discrete_score_W0_n 0.01139637440356935
# test_discrete_score_W0_a 0.012330649046620687
# train_discrete_score_W_discrete_p 0.4213691026827012
# train_discrete_score_W_discrete_n 0.062464238068014946
# train_discrete_score_W_discrete_a 0.05583566873740666
# test_discrete_score_W_discrete_p 0.44384449244060475
# test_discrete_score_W_discrete_n 0.07327266581907727
# test_discrete_score_W_discrete_a 0.07116134311536507
# neuron unit number: 31
# train_discrete_score_W0_p 0.3695652173913043
# train_discrete_score_W0_n 0.007295978121406538
# train_discrete_score_W0_a  0.0070192493215337475
# test_discrete_score_W0_p 0.367170626349892
# test_discrete_score_W0_n 0.01236359489324518
# test_discrete_score_W0_a 0.008849915762993064
# train_discrete_score_W_discrete_p 0.4181313598519889
# train_discrete_score_W_discrete_n 0.05710908970531881
# train_discrete_score_W_discrete_a 0.055083893066223535
# test_discrete_score_W_discrete_p 0.4406047516198704
# test_discrete_score_W_discrete_n 0.07801494865334707
# test_discrete_score_W_discrete_a 0.06230235301118385
# neuron unit number: 32
# train_discrete_score_W0_p 0.36864014801110084
# train_discrete_score_W0_n 0.005241463322495221
# train_discrete_score_W0_a  0.00849482657010626
# test_discrete_score_W0_p 0.3617710583153348
# test_discrete_score_W0_n 0.011251246922993457
# test_discrete_score_W0_a 0.007446714310291695
# train_discrete_score_W_discrete_p 0.41535615171137835
# train_discrete_score_W_discrete_n 0.05703081458929888
# train_discrete_score_W_discrete_a 0.04374528222086273
# test_discrete_score_W_discrete_p 0.4222462203023758
# test_discrete_score_W_discrete_n 0.06537533163566253
# test_discrete_score_W_discrete_a 0.06026254252427119
# neuron unit number: 33
# train_discrete_score_W0_p 0.36262719703977797
# train_discrete_score_W0_n 0.005197970594307858
# train_discrete_score_W0_a  0.008582616234709213
# test_discrete_score_W0_p 0.36285097192224625
# test_discrete_score_W0_n 0.013626942598833605
# test_discrete_score_W0_a 0.01574469189779582
# train_discrete_score_W_discrete_p 0.4148936170212766
# train_discrete_score_W_discrete_n 0.051538305540126964
# train_discrete_score_W_discrete_a 0.049455153549852214
# test_discrete_score_W_discrete_p 0.4287257019438445
# test_discrete_score_W_discrete_n 0.06491937278824297
# test_discrete_score_W_discrete_a 0.06654055041294597
# neuron unit number: 34
# train_discrete_score_W0_p 0.3723404255319149
# train_discrete_score_W0_n 0.007378901393850064
# train_discrete_score_W0_a  0.013143652302627101
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.012899744735054194
# test_discrete_score_W0_a 0.01314551065584463
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.0646847599979741
# train_discrete_score_W_discrete_a 0.06273545535083645
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.06923796760345689
# test_discrete_score_W_discrete_a 0.06244740404369377
# neuron unit number: 35
# train_discrete_score_W0_p 0.37049028677150786
# train_discrete_score_W0_n 0.009684130832501907
# train_discrete_score_W0_a  0.020979275002051347
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.01103068996887483
# test_discrete_score_W0_a 0.01107227875703356
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.06438828910877438
# train_discrete_score_W_discrete_a 0.055720965131003365
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.06706072484475538
# test_discrete_score_W_discrete_a 0.05584877273310457
# neuron unit number: 36
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.006390488189480143
# train_discrete_score_W0_a  0.010050101982630875
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.015239683678500607
# test_discrete_score_W0_a 0.014830310114691488
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.06125764191375415
# train_discrete_score_W_discrete_a 0.055583129692355134
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.07725981702836376
# test_discrete_score_W_discrete_a 0.06798007168546877
# neuron unit number: 37
# train_discrete_score_W0_p 0.35707678075855687
# train_discrete_score_W0_n 0.0037386036179804048
# train_discrete_score_W0_a  0.005485248848366595
# test_discrete_score_W0_p 0.34557235421166305
# test_discrete_score_W0_n 0.007524240621166233
# test_discrete_score_W0_a 0.007712722721966848
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.06343428699106532
# train_discrete_score_W_discrete_a 0.05184873741844916
# test_discrete_score_W_discrete_p 0.4200863930885529
# test_discrete_score_W_discrete_n 0.06312667738250857
# test_discrete_score_W_discrete_a 0.05041993695924132
# neuron unit number: 38
# train_discrete_score_W0_p 0.37049028677150786
# train_discrete_score_W0_n 0.007379033931941124
# train_discrete_score_W0_a  0.0075418294573965095
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.01906101343460083
# test_discrete_score_W0_a 0.0108484575791653
# train_discrete_score_W_discrete_p 0.41951896392229415
# train_discrete_score_W_discrete_n 0.05839969318410165
# train_discrete_score_W_discrete_a 0.056026903178216896
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.061097913594670844
# test_discrete_score_W_discrete_a 0.05896446968248313
# neuron unit number: 39
# train_discrete_score_W0_p 0.3709528214616096
# train_discrete_score_W0_n 0.006836246246354869
# train_discrete_score_W0_a  0.012259166981467307
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.01475004266699072
# test_discrete_score_W0_a 0.014208497447746792
# train_discrete_score_W_discrete_p 0.42645698427382056
# train_discrete_score_W_discrete_n 0.05335369236817123
# train_discrete_score_W_discrete_a 0.05697097665830657
# test_discrete_score_W_discrete_p 0.43628509719222464
# test_discrete_score_W_discrete_n 0.0648470036287409
# test_discrete_score_W_discrete_a 0.06989078977976741
# neuron unit number: 40
# train_discrete_score_W0_p 0.37511563367252543
# train_discrete_score_W0_n 0.007247877010962404
# train_discrete_score_W0_a  0.012463982767169403
# test_discrete_score_W0_p 0.3617710583153348
# test_discrete_score_W0_n 0.012626782527646582
# test_discrete_score_W0_a 0.015185457414388592
# train_discrete_score_W_discrete_p 0.41304347826086957
# train_discrete_score_W_discrete_n 0.05033849507382707
# train_discrete_score_W_discrete_a 0.038936155219753334
# test_discrete_score_W_discrete_p 0.42764578833693306
# test_discrete_score_W_discrete_n 0.0592209601137575
# test_discrete_score_W_discrete_a 0.060900872039271345
# neuron unit number: 41
# train_discrete_score_W0_p 0.3667900092506938
# train_discrete_score_W0_n 0.007401775320138545
# train_discrete_score_W0_a  0.014383544495445686
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.011400299116872945
# test_discrete_score_W0_a 0.010784941403232629
# train_discrete_score_W_discrete_p 0.41951896392229415
# train_discrete_score_W_discrete_n 0.06371239424531663
# train_discrete_score_W_discrete_a 0.05110600120912278
# test_discrete_score_W_discrete_p 0.4244060475161987
# test_discrete_score_W_discrete_n 0.061829440988565576
# test_discrete_score_W_discrete_a 0.05729493670982218
# neuron unit number: 42
# train_discrete_score_W0_p 0.3709528214616096
# train_discrete_score_W0_n 0.005644059072175534
# train_discrete_score_W0_a  0.011036282177521386
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.01811146312830497
# test_discrete_score_W0_a 0.015253821840058218
# train_discrete_score_W_discrete_p 0.42183163737280294
# train_discrete_score_W_discrete_n 0.057923292819809444
# train_discrete_score_W_discrete_a 0.05178826466949401
# test_discrete_score_W_discrete_p 0.4319654427645788
# test_discrete_score_W_discrete_n 0.0579651143565728
# test_discrete_score_W_discrete_a 0.06492465080501812
# neuron unit number: 43
# train_discrete_score_W0_p 0.3755781683626272
# train_discrete_score_W0_n 0.007836572270899417
# train_discrete_score_W0_a  0.015355290593326716
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.011723017151236803
# test_discrete_score_W0_a 0.011853578196367101
# train_discrete_score_W_discrete_p 0.4107308048103608
# train_discrete_score_W_discrete_n 0.05861913791409733
# train_discrete_score_W_discrete_a 0.04896179880059291
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.052274316499172475
# test_discrete_score_W_discrete_a 0.046086392629652
# neuron unit number: 44
# train_discrete_score_W0_p 0.3700277520814061
# train_discrete_score_W0_n 0.00801802208856071
# train_discrete_score_W0_a  0.016750301899142186
# test_discrete_score_W0_p 0.36609071274298055
# test_discrete_score_W0_n 0.01020359893360558
# test_discrete_score_W0_a 0.011434427442511415
# train_discrete_score_W_discrete_p 0.4107308048103608
# train_discrete_score_W_discrete_n 0.05993532500437169
# train_discrete_score_W_discrete_a 0.05578907514809646
# test_discrete_score_W_discrete_p 0.4244060475161987
# test_discrete_score_W_discrete_n 0.05177329554000512
# test_discrete_score_W_discrete_a 0.053812529448455486
# neuron unit number: 45
# train_discrete_score_W0_p 0.37280296022201664
# train_discrete_score_W0_n 0.007099442056785132
# train_discrete_score_W0_a  0.011260712837998704
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.016964032043936504
# test_discrete_score_W0_a 0.02266051438170535
# train_discrete_score_W_discrete_p 0.42090656799259946
# train_discrete_score_W_discrete_n 0.0615065252582214
# train_discrete_score_W_discrete_a 0.05930118398708117
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.06551535397411003
# test_discrete_score_W_discrete_a 0.06782633288691244
# neuron unit number: 46
# train_discrete_score_W0_p 0.37696577243293244
# train_discrete_score_W0_n 0.007904128331869403
# train_discrete_score_W0_a  0.013479164971170509
# test_discrete_score_W0_p 0.37365010799136067
# test_discrete_score_W0_n 0.01266440660438051
# test_discrete_score_W0_a 0.013166948330742452
# train_discrete_score_W_discrete_p 0.4162812210915819
# train_discrete_score_W_discrete_n 0.06178609264531666
# train_discrete_score_W_discrete_a 0.05723970765699095
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.07037606496302927
# test_discrete_score_W_discrete_a 0.06959055162472969
# neuron unit number: 47
# train_discrete_score_W0_p 0.3617021276595745
# train_discrete_score_W0_n 0.004140714066963859
# train_discrete_score_W0_a  0.006839678638330081
# test_discrete_score_W0_p 0.35529157667386607
# test_discrete_score_W0_n 0.010592932557146518
# test_discrete_score_W0_a 0.00851315940083937
# train_discrete_score_W_discrete_p 0.42923219241443106
# train_discrete_score_W_discrete_n 0.0659247200720044
# train_discrete_score_W_discrete_a 0.06533785776606049
# test_discrete_score_W_discrete_p 0.44600431965442766
# test_discrete_score_W_discrete_n 0.07662273335899256
# test_discrete_score_W_discrete_a 0.07534822163266762
# neuron unit number: 48
# train_discrete_score_W0_p 0.38390379278445885
# train_discrete_score_W0_n 0.010454403001458891
# train_discrete_score_W0_a  0.019943998791995196
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.020257173166840215
# test_discrete_score_W0_a 0.02474672597840474
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.04989831771053696
# train_discrete_score_W_discrete_a 0.047709516854288245
# test_discrete_score_W_discrete_p 0.4373650107991361
# test_discrete_score_W_discrete_n 0.06975854293022482
# test_discrete_score_W_discrete_a 0.06297829167965853
# neuron unit number: 49
# train_discrete_score_W0_p 0.3852913968547641
# train_discrete_score_W0_n 0.013564507774136068
# train_discrete_score_W0_a  0.018564136178783466
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.02022002064330127
# test_discrete_score_W0_a 0.022506002411152193
# train_discrete_score_W_discrete_p 0.4139685476410731
# train_discrete_score_W_discrete_n 0.060307080846376364
# train_discrete_score_W_discrete_a 0.05215204536941564
# test_discrete_score_W_discrete_p 0.4330453563714903
# test_discrete_score_W_discrete_n 0.06883648675388836
# test_discrete_score_W_discrete_a 0.06389551181614976
# neuron unit number: 50
# train_discrete_score_W0_p 0.38251618871415355
# train_discrete_score_W0_n 0.011750753940261753
# train_discrete_score_W0_a  0.015289343874007471
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.024505588802729024
# test_discrete_score_W0_a 0.02621468112684649
# train_discrete_score_W_discrete_p 0.41535615171137835
# train_discrete_score_W_discrete_n 0.06622069116664
# train_discrete_score_W_discrete_a 0.05624726701896613
# test_discrete_score_W_discrete_p 0.4200863930885529
# test_discrete_score_W_discrete_n 0.06696918095501796
# test_discrete_score_W_discrete_a 0.05179444438985703
# test_discrete_score_W0_p mean 0.3605502864118697
# test_discrete_score_W_discrete_p mean 0.43013428490938127
# test_discrete_score_W0_n mean 0.010443968897321068
# test_discrete_score_W_discrete_n mean 0.06632702123193213
# test_discrete_score_W0_a mean 0.009604876366506006
# test_discrete_score_W_discrete_a mean 0.06096219569280745
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.004842  0.003167  0.000467   0.003901  0.005782
# 1  train_dis_W_dis  46.0  0.062445  0.005508  0.000812   0.060809  0.064080
# 2         combined  92.0  0.033643  0.029302  0.003055   0.027575  0.039711
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0576
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -61.4914
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -12.8218
# 7                                    Hedge's g =  -12.7147
# 8                               Glass's delta1 =  -18.1862
# 9                             Point-Biserial r =   -0.9883
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.010444  0.004932  0.000727   0.008979  0.011909
# 1  test_dis_W_dis  46.0  0.066327  0.006945  0.001024   0.064265  0.068390
# 2        combined  92.0  0.038385  0.028726  0.002995   0.032436  0.044335
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0559
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -44.4938
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -9.2776
# 7                                  Hedge's g =   -9.2001
# 8                             Glass's delta1 =  -11.3302
# 9                           Point-Biserial r =   -0.9780
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.007945  0.006063  0.000894   0.006144  0.009746
# 1  train_dis_W_dis  46.0  0.055323  0.005728  0.000844   0.053622  0.057024
# 2         combined  92.0  0.031634  0.024530  0.002557   0.026554  0.036714
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0474
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -38.5251
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.0330
# 7                                    Hedge's g =   -7.9659
# 8                               Glass's delta1 =   -7.8137
# 9                             Point-Biserial r =   -0.9710
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.009605  0.006157  0.000908   0.007776  0.011433
# 1  test_dis_W_dis  46.0  0.060962  0.007556  0.001114   0.058718  0.063206
# 2        combined  92.0  0.035284  0.026714  0.002785   0.029751  0.040816
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0514
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -35.7376
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.4518
# 7                                  Hedge's g =   -7.3895
# 8                             Glass's delta1 =   -8.3412
# 9                           Point-Biserial r =   -0.9665
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.364357  0.008948  0.001319   0.361699  0.367014
# 1  train_dis_W_dis  46.0  0.420514  0.005217  0.000769   0.418965  0.422064
# 2         combined  92.0  0.392436  0.029157  0.003040   0.386397  0.398474
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0562
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -36.7735
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -7.6678
# 7                                    Hedge's g =   -7.6037
# 8                               Glass's delta1 =   -6.2761
# 9                             Point-Biserial r =   -0.9683
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.360550  0.012398  0.001828   0.356869  0.364232
# 1  test_dis_W_dis  46.0  0.430134  0.009450  0.001393   0.427328  0.432941
# 2        combined  92.0  0.395342  0.036660  0.003822   0.387750  0.402934
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0696
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -30.2743
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.3126
# 7                                  Hedge's g =   -6.2599
# 8                             Glass's delta1 =   -5.6125
# 9                           Point-Biserial r =   -0.9542

# %%
#new one hot
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.37604070305272896
# train_discrete_score_W0_n 0.002037211611217504
# train_discrete_score_W0_a  0.0030756743455668226
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.005352126618342266
# test_discrete_score_W0_a 0.007727231861657866
# train_discrete_score_W_discrete_p 0.4366327474560592
# train_discrete_score_W_discrete_n 0.06651514938480566
# train_discrete_score_W_discrete_a 0.06694602292919528
# test_discrete_score_W_discrete_p 0.4470842332613391
# test_discrete_score_W_discrete_n 0.0815558835794569
# test_discrete_score_W_discrete_a 0.07986108245423158
# neuron unit number: 6
# train_discrete_score_W0_p 0.37465309898242366
# train_discrete_score_W0_n 0.0020616255806101807
# train_discrete_score_W0_a  -0.0008341997275376285
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.004144771517349175
# test_discrete_score_W0_a 0.008519290002359623
# train_discrete_score_W_discrete_p 0.4269195189639223
# train_discrete_score_W_discrete_n 0.05666230276585551
# train_discrete_score_W_discrete_a 0.0573694511616853
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.08855698033531847
# test_discrete_score_W_discrete_a 0.08181921341592795
# neuron unit number: 7
# train_discrete_score_W0_p 0.3788159111933395
# train_discrete_score_W0_n 0.0026824179310729395
# train_discrete_score_W0_a  0.007608446314129824
# test_discrete_score_W0_p 0.37041036717062636
# test_discrete_score_W0_n 0.003068323273143292
# test_discrete_score_W0_a -0.0028290237567498784
# train_discrete_score_W_discrete_p 0.4338575393154487
# train_discrete_score_W_discrete_n 0.06960661833111814
# train_discrete_score_W_discrete_a 0.06850612632822455
# test_discrete_score_W_discrete_p 0.458963282937365
# test_discrete_score_W_discrete_n 0.0914751725686405
# test_discrete_score_W_discrete_a 0.08675285215798836
# neuron unit number: 8
# train_discrete_score_W0_p 0.37511563367252543
# train_discrete_score_W0_n 0.0011596378220994096
# train_discrete_score_W0_a  0.001599782198532757
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.006509202736182408
# test_discrete_score_W0_a 0.002647938563759044
# train_discrete_score_W_discrete_p 0.4333950046253469
# train_discrete_score_W_discrete_n 0.06934861512536686
# train_discrete_score_W_discrete_a 0.06360078098673592
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.08473379231451389
# test_discrete_score_W_discrete_a 0.07700967829927562
# neuron unit number: 9
# train_discrete_score_W0_p 0.37465309898242366
# train_discrete_score_W0_n 0.0021489869681245817
# train_discrete_score_W0_a  0.006740876875193734
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.009033168254050759
# test_discrete_score_W0_a 0.014988681268698022
# train_discrete_score_W_discrete_p 0.4380203515263645
# train_discrete_score_W_discrete_n 0.059415017797881185
# train_discrete_score_W_discrete_a 0.05766973682370782
# test_discrete_score_W_discrete_p 0.4740820734341253
# test_discrete_score_W_discrete_n 0.10063511315826887
# test_discrete_score_W_discrete_a 0.09658123067477671
# neuron unit number: 10
# train_discrete_score_W0_p 0.38390379278445885
# train_discrete_score_W0_n 0.0035213901287332898
# train_discrete_score_W0_a  0.004766120930230734
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.005911557804309487
# test_discrete_score_W0_a 0.01023277197262017
# train_discrete_score_W_discrete_p 0.4338575393154487
# train_discrete_score_W_discrete_n 0.06999861326889809
# train_discrete_score_W_discrete_a 0.06276765290586307
# test_discrete_score_W_discrete_p 0.4427645788336933
# test_discrete_score_W_discrete_n 0.08060894574062284
# test_discrete_score_W_discrete_a 0.07355722179182565
# neuron unit number: 11
# train_discrete_score_W0_p 0.3792784458834413
# train_discrete_score_W0_n 0.0021384906252444012
# train_discrete_score_W0_a  0.002876330575004093
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.010279659152386354
# test_discrete_score_W0_a 0.013847355330913797
# train_discrete_score_W_discrete_p 0.4412580943570768
# train_discrete_score_W_discrete_n 0.06570705650559326
# train_discrete_score_W_discrete_a 0.07189373066302494
# test_discrete_score_W_discrete_p 0.47840172786177104
# test_discrete_score_W_discrete_n 0.10077139846289077
# test_discrete_score_W_discrete_a 0.10103527291633452
# neuron unit number: 12
# train_discrete_score_W0_p 0.38020351526364476
# train_discrete_score_W0_n 0.002464761660722398
# train_discrete_score_W0_a  0.007052421687626022
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.008051893244034108
# test_discrete_score_W0_a 0.015295830374036905
# train_discrete_score_W_discrete_p 0.4315448658649399
# train_discrete_score_W_discrete_n 0.0672120423978917
# train_discrete_score_W_discrete_a 0.06691765470199762
# test_discrete_score_W_discrete_p 0.46652267818574517
# test_discrete_score_W_discrete_n 0.09852040539480432
# test_discrete_score_W_discrete_a 0.09117900703245135
# neuron unit number: 13
# train_discrete_score_W0_p 0.38251618871415355
# train_discrete_score_W0_n 0.0027622319256682512
# train_discrete_score_W0_a  0.004683143590421417
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.006090411646252727
# test_discrete_score_W0_a 0.00925798936541974
# train_discrete_score_W_discrete_p 0.4338575393154487
# train_discrete_score_W_discrete_n 0.0628887788061669
# train_discrete_score_W_discrete_a 0.06147778295831184
# test_discrete_score_W_discrete_p 0.45680345572354214
# test_discrete_score_W_discrete_n 0.08492913072365861
# test_discrete_score_W_discrete_a 0.07809985245548982
# neuron unit number: 14
# train_discrete_score_W0_p 0.38159111933395007
# train_discrete_score_W0_n 0.002844862876953433
# train_discrete_score_W0_a  0.008110134841895404
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.010007695185869105
# test_discrete_score_W0_a 0.015939988736019636
# train_discrete_score_W_discrete_p 0.43617021276595747
# train_discrete_score_W_discrete_n 0.06745954365809177
# train_discrete_score_W_discrete_a 0.06717614120456292
# test_discrete_score_W_discrete_p 0.4611231101511879
# test_discrete_score_W_discrete_n 0.09306595919127823
# test_discrete_score_W_discrete_a 0.0926727271910902
# neuron unit number: 15
# train_discrete_score_W0_p 0.3820536540240518
# train_discrete_score_W0_n 0.0026070279837140634
# train_discrete_score_W0_a  0.004772188346400105
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.012461764419752401
# test_discrete_score_W0_a 0.017690339454866248
# train_discrete_score_W_discrete_p 0.4366327474560592
# train_discrete_score_W_discrete_n 0.061894860489260795
# train_discrete_score_W_discrete_a 0.06478097186829343
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.09007158425699294
# test_discrete_score_W_discrete_a 0.08935005631269576
# neuron unit number: 16
# train_discrete_score_W0_p 0.39037927844588344
# train_discrete_score_W0_n 0.005320530982767218
# train_discrete_score_W0_a  0.006668139041185614
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.010122765162215693
# test_discrete_score_W0_a 0.014802157540296599
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.06361038937889037
# train_discrete_score_W_discrete_a 0.060526426613810524
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.08707883876283277
# test_discrete_score_W_discrete_a 0.08095203037723954
# neuron unit number: 17
# train_discrete_score_W0_p 0.379740980573543
# train_discrete_score_W0_n 0.00229169014197015
# train_discrete_score_W0_a  0.006354153568492706
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.011580654435614804
# test_discrete_score_W0_a 0.01777996197693928
# train_discrete_score_W_discrete_p 0.43478260869565216
# train_discrete_score_W_discrete_n 0.06376600835975695
# train_discrete_score_W_discrete_a 0.0679279620171941
# test_discrete_score_W_discrete_p 0.46976241900647947
# test_discrete_score_W_discrete_n 0.09695883233568561
# test_discrete_score_W_discrete_a 0.09815659966522472
# neuron unit number: 18
# train_discrete_score_W0_p 0.3871415356151711
# train_discrete_score_W0_n 0.004149855478559421
# train_discrete_score_W0_a  0.007621712970442298
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.009744500198182043
# test_discrete_score_W0_a 0.016532701599575615
# train_discrete_score_W_discrete_p 0.4301572617946346
# train_discrete_score_W_discrete_n 0.0635786144783646
# train_discrete_score_W_discrete_a 0.0626950879137472
# test_discrete_score_W_discrete_p 0.4449244060475162
# test_discrete_score_W_discrete_n 0.09054181261527162
# test_discrete_score_W_discrete_a 0.07983233118255173
# neuron unit number: 19
# train_discrete_score_W0_p 0.38251618871415355
# train_discrete_score_W0_n 0.002724402627636069
# train_discrete_score_W0_a  0.003255723391338039
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.007519961455697681
# test_discrete_score_W0_a 0.00563777737668275
# train_discrete_score_W_discrete_p 0.4375578168362627
# train_discrete_score_W_discrete_n 0.0633217336022194
# train_discrete_score_W_discrete_a 0.0629419883085525
# test_discrete_score_W_discrete_p 0.4719222462203024
# test_discrete_score_W_discrete_n 0.0944374769185809
# test_discrete_score_W_discrete_a 0.09499808710243522
# neuron unit number: 20
# train_discrete_score_W0_p 0.38251618871415355
# train_discrete_score_W0_n 0.0031399550405659085
# train_discrete_score_W0_a  0.009410831258688138
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.008046910106051464
# test_discrete_score_W0_a 0.008870325449683478
# train_discrete_score_W_discrete_p 0.43293246993524515
# train_discrete_score_W_discrete_n 0.06700390611037475
# train_discrete_score_W_discrete_a 0.0637884851913376
# test_discrete_score_W_discrete_p 0.4654427645788337
# test_discrete_score_W_discrete_n 0.0959289069366883
# test_discrete_score_W_discrete_a 0.08936242560284148
# neuron unit number: 21
# train_discrete_score_W0_p 0.38251618871415355
# train_discrete_score_W0_n 0.00359185864175615
# train_discrete_score_W0_a  0.001233305243306868
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.015453524378774322
# test_discrete_score_W0_a 0.023398663446067388
# train_discrete_score_W_discrete_p 0.44033302497687327
# train_discrete_score_W_discrete_n 0.07536156847918322
# train_discrete_score_W_discrete_a 0.07145295244959309
# test_discrete_score_W_discrete_p 0.46652267818574517
# test_discrete_score_W_discrete_n 0.10117965469013418
# test_discrete_score_W_discrete_a 0.09874160497643326
# neuron unit number: 22
# train_discrete_score_W0_p 0.38482886216466233
# train_discrete_score_W0_n 0.0030629467690878507
# train_discrete_score_W0_a  0.00637753034137612
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.012056877943634439
# test_discrete_score_W0_a 0.015031229198926726
# train_discrete_score_W_discrete_p 0.4315448658649399
# train_discrete_score_W_discrete_n 0.06775313079053723
# train_discrete_score_W_discrete_a 0.06821400006487735
# test_discrete_score_W_discrete_p 0.45788336933045354
# test_discrete_score_W_discrete_n 0.08134101213350903
# test_discrete_score_W_discrete_a 0.07888499190669535
# neuron unit number: 23
# train_discrete_score_W0_p 0.3889916743755782
# train_discrete_score_W0_n 0.006000438022405087
# train_discrete_score_W0_a  0.009189012071331845
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.010356564538610646
# test_discrete_score_W0_a 0.0058129987259482865
# train_discrete_score_W_discrete_p 0.4454209065679926
# train_discrete_score_W_discrete_n 0.07687361478402899
# train_discrete_score_W_discrete_a 0.07503422343692102
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.08419264346370678
# test_discrete_score_W_discrete_a 0.08811114643157893
# neuron unit number: 24
# train_discrete_score_W0_p 0.37835337650323775
# train_discrete_score_W0_n 0.0014171504674698918
# train_discrete_score_W0_a  0.0024258184421621213
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.013485522566140147
# test_discrete_score_W0_a 0.020518033393724242
# train_discrete_score_W_discrete_p 0.4421831637372803
# train_discrete_score_W_discrete_n 0.07065876920823327
# train_discrete_score_W_discrete_a 0.07161047053843192
# test_discrete_score_W_discrete_p 0.47516198704103674
# test_discrete_score_W_discrete_n 0.0805739667226434
# test_discrete_score_W_discrete_a 0.09199267699845656
# neuron unit number: 25
# train_discrete_score_W0_p 0.3871415356151711
# train_discrete_score_W0_n 0.004235921120900994
# train_discrete_score_W0_a  0.010368099997809762
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.012664168677832044
# test_discrete_score_W0_a 0.018940488380076868
# train_discrete_score_W_discrete_p 0.4315448658649399
# train_discrete_score_W_discrete_n 0.06842827439596985
# train_discrete_score_W_discrete_a 0.06835872293750353
# test_discrete_score_W_discrete_p 0.46220302375809935
# test_discrete_score_W_discrete_n 0.09103161381482495
# test_discrete_score_W_discrete_a 0.09057030263772771
# neuron unit number: 26
# train_discrete_score_W0_p 0.38621646623496764
# train_discrete_score_W0_n 0.004284213177857507
# train_discrete_score_W0_a  0.005464247627708521
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.017331737718305148
# test_discrete_score_W0_a 0.02126792034614777
# train_discrete_score_W_discrete_p 0.4296947271045328
# train_discrete_score_W_discrete_n 0.05875695884923081
# train_discrete_score_W_discrete_a 0.061770906994854456
# test_discrete_score_W_discrete_p 0.45680345572354214
# test_discrete_score_W_discrete_n 0.08758523594537057
# test_discrete_score_W_discrete_a 0.09394226854870195
# neuron unit number: 27
# train_discrete_score_W0_p 0.3871415356151711
# train_discrete_score_W0_n 0.004262413139055197
# train_discrete_score_W0_a  0.009272056105732816
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.01021973256684969
# test_discrete_score_W0_a 0.017790623289903773
# train_discrete_score_W_discrete_p 0.4412580943570768
# train_discrete_score_W_discrete_n 0.06884050892895648
# train_discrete_score_W_discrete_a 0.06936490367056809
# test_discrete_score_W_discrete_p 0.47516198704103674
# test_discrete_score_W_discrete_n 0.10216909943698219
# test_discrete_score_W_discrete_a 0.1008889587731263
# neuron unit number: 28
# train_discrete_score_W0_p 0.3894542090656799
# train_discrete_score_W0_n 0.0058733552523776425
# train_discrete_score_W0_a  0.011145303449420546
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.01526552540956358
# test_discrete_score_W0_a 0.022402453297194445
# train_discrete_score_W_discrete_p 0.43293246993524515
# train_discrete_score_W_discrete_n 0.05398363935234048
# train_discrete_score_W_discrete_a 0.057964292797553864
# test_discrete_score_W_discrete_p 0.468682505399568
# test_discrete_score_W_discrete_n 0.0903450916456789
# test_discrete_score_W_discrete_a 0.09762749703434646
# neuron unit number: 29
# train_discrete_score_W0_p 0.38251618871415355
# train_discrete_score_W0_n 0.0030300788863327284
# train_discrete_score_W0_a  0.006680106552535084
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.009204505945820536
# test_discrete_score_W0_a 0.010306180499617375
# train_discrete_score_W_discrete_p 0.4283071230342276
# train_discrete_score_W_discrete_n 0.059649422754964196
# train_discrete_score_W_discrete_a 0.061948137216141175
# test_discrete_score_W_discrete_p 0.4503239740820734
# test_discrete_score_W_discrete_n 0.08196560115013553
# test_discrete_score_W_discrete_a 0.07580049370920908
# neuron unit number: 30
# train_discrete_score_W0_p 0.395004625346901
# train_discrete_score_W0_n 0.006266505781595134
# train_discrete_score_W0_a  0.010308277935713454
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.011638546732442532
# test_discrete_score_W0_a 0.0147215409792125
# train_discrete_score_W_discrete_p 0.43940795559666973
# train_discrete_score_W_discrete_n 0.0657548773610614
# train_discrete_score_W_discrete_a 0.06364290461752307
# test_discrete_score_W_discrete_p 0.468682505399568
# test_discrete_score_W_discrete_n 0.09667269550030391
# test_discrete_score_W_discrete_a 0.09605956550004506
# neuron unit number: 31
# train_discrete_score_W0_p 0.3876040703052729
# train_discrete_score_W0_n 0.004966500024697644
# train_discrete_score_W0_a  0.011114055475979117
# test_discrete_score_W0_p 0.40280777537796975
# test_discrete_score_W0_n 0.014258355739766991
# test_discrete_score_W0_a 0.019645473121629876
# train_discrete_score_W_discrete_p 0.43293246993524515
# train_discrete_score_W_discrete_n 0.057791470771702415
# train_discrete_score_W_discrete_a 0.06306241045452228
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.07757388086011502
# test_discrete_score_W_discrete_a 0.07581540923608966
# neuron unit number: 32
# train_discrete_score_W0_p 0.38806660499537465
# train_discrete_score_W0_n 0.00451099343911488
# train_discrete_score_W0_a  0.009013748722484033
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.018683678066503197
# test_discrete_score_W0_a 0.0269265364713617
# train_discrete_score_W_discrete_p 0.4357076780758557
# train_discrete_score_W_discrete_n 0.06367405878606999
# train_discrete_score_W_discrete_a 0.06384802412900839
# test_discrete_score_W_discrete_p 0.45788336933045354
# test_discrete_score_W_discrete_n 0.08773377324740196
# test_discrete_score_W_discrete_a 0.09133482260541627
# neuron unit number: 33
# train_discrete_score_W0_p 0.3894542090656799
# train_discrete_score_W0_n 0.005945213122462623
# train_discrete_score_W0_a  0.010245415152524945
# test_discrete_score_W0_p 0.4168466522678186
# test_discrete_score_W0_n 0.02040988402341568
# test_discrete_score_W0_a 0.03439325994414009
# train_discrete_score_W_discrete_p 0.4324699352451434
# train_discrete_score_W_discrete_n 0.06331357533041372
# train_discrete_score_W_discrete_a 0.059633527453396624
# test_discrete_score_W_discrete_p 0.46436285097192226
# test_discrete_score_W_discrete_n 0.0864400887624841
# test_discrete_score_W_discrete_a 0.08874497130615963
# neuron unit number: 34
# train_discrete_score_W0_p 0.3866790009250694
# train_discrete_score_W0_n 0.0037800505312483557
# train_discrete_score_W0_a  0.0045063902685538205
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.013329699485479926
# test_discrete_score_W0_a 0.021703843505349305
# train_discrete_score_W_discrete_p 0.42321924144310824
# train_discrete_score_W_discrete_n 0.05624163845979029
# train_discrete_score_W_discrete_a 0.05827815810778546
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.07002749536757595
# test_discrete_score_W_discrete_a 0.07582190671456493
# neuron unit number: 35
# train_discrete_score_W0_p 0.3866790009250694
# train_discrete_score_W0_n 0.0062837614941550655
# train_discrete_score_W0_a  0.011749214658959634
# test_discrete_score_W0_p 0.4146868250539957
# test_discrete_score_W0_n 0.02044444295034151
# test_discrete_score_W0_a 0.02621773103883585
# train_discrete_score_W_discrete_p 0.42876965772432934
# train_discrete_score_W_discrete_n 0.06095007518858592
# train_discrete_score_W_discrete_a 0.06063128658828274
# test_discrete_score_W_discrete_p 0.46652267818574517
# test_discrete_score_W_discrete_n 0.08999569411635755
# test_discrete_score_W_discrete_a 0.1007591790462475
# neuron unit number: 36
# train_discrete_score_W0_p 0.3871415356151711
# train_discrete_score_W0_n 0.0053554279814173305
# train_discrete_score_W0_a  0.008708036059392394
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.024664028713226552
# test_discrete_score_W0_a 0.03314664454404732
# train_discrete_score_W_discrete_p 0.43293246993524515
# train_discrete_score_W_discrete_n 0.05738484763497469
# train_discrete_score_W_discrete_a 0.06247502950991919
# test_discrete_score_W_discrete_p 0.46760259179265656
# test_discrete_score_W_discrete_n 0.09321456508263486
# test_discrete_score_W_discrete_a 0.09665800183158348
# neuron unit number: 37
# train_discrete_score_W0_p 0.38806660499537465
# train_discrete_score_W0_n 0.005952157082071493
# train_discrete_score_W0_a  0.012362364631817481
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.017255815963804776
# test_discrete_score_W0_a 0.024571067079785246
# train_discrete_score_W_discrete_p 0.4333950046253469
# train_discrete_score_W_discrete_n 0.05463036286720616
# train_discrete_score_W_discrete_a 0.06007547641132841
# test_discrete_score_W_discrete_p 0.46760259179265656
# test_discrete_score_W_discrete_n 0.08613389358026194
# test_discrete_score_W_discrete_a 0.08503341884928063
# neuron unit number: 38
# train_discrete_score_W0_p 0.3894542090656799
# train_discrete_score_W0_n 0.005854245269392021
# train_discrete_score_W0_a  0.003964922857623146
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.013372497901738037
# test_discrete_score_W0_a 0.01969925034386358
# train_discrete_score_W_discrete_p 0.4315448658649399
# train_discrete_score_W_discrete_n 0.06616526115483543
# train_discrete_score_W_discrete_a 0.06462175095535493
# test_discrete_score_W_discrete_p 0.4719222462203024
# test_discrete_score_W_discrete_n 0.08382013963158248
# test_discrete_score_W_discrete_a 0.09136596341797429
# neuron unit number: 39
# train_discrete_score_W0_p 0.39454209065679924
# train_discrete_score_W0_n 0.006085721151678125
# train_discrete_score_W0_a  0.008620252186874728
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.01954555502728829
# test_discrete_score_W0_a 0.026685146599272545
# train_discrete_score_W_discrete_p 0.4241443108233117
# train_discrete_score_W_discrete_n 0.056711251775889066
# train_discrete_score_W_discrete_a 0.05891282096839782
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.0690260810884517
# test_discrete_score_W_discrete_a 0.07238984846592214
# neuron unit number: 40
# train_discrete_score_W0_p 0.3889916743755782
# train_discrete_score_W0_n 0.004436989712160295
# train_discrete_score_W0_a  0.00842767583026156
# test_discrete_score_W0_p 0.4168466522678186
# test_discrete_score_W0_n 0.033100298487182114
# test_discrete_score_W0_a 0.03788706850448488
# train_discrete_score_W_discrete_p 0.425531914893617
# train_discrete_score_W_discrete_n 0.06366668611919182
# train_discrete_score_W_discrete_a 0.06069994384935645
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.08431577913150398
# test_discrete_score_W_discrete_a 0.08378448141755454
# neuron unit number: 41
# train_discrete_score_W0_p 0.3954671600370028
# train_discrete_score_W0_n 0.008183400510033965
# train_discrete_score_W0_a  0.015513121549327791
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.013298372406639265
# test_discrete_score_W0_a 0.02030705466884505
# train_discrete_score_W_discrete_p 0.438945420906568
# train_discrete_score_W_discrete_n 0.0646727014337147
# train_discrete_score_W_discrete_a 0.06555544717416852
# test_discrete_score_W_discrete_p 0.4708423326133909
# test_discrete_score_W_discrete_n 0.08553633731959376
# test_discrete_score_W_discrete_a 0.09898276688125981
# neuron unit number: 42
# train_discrete_score_W0_p 0.3987049028677151
# train_discrete_score_W0_n 0.009367413328331319
# train_discrete_score_W0_a  0.01130882569470537
# test_discrete_score_W0_p 0.4244060475161987
# test_discrete_score_W0_n 0.02670478789548289
# test_discrete_score_W0_a 0.03474596123300855
# train_discrete_score_W_discrete_p 0.4338575393154487
# train_discrete_score_W_discrete_n 0.05802783762608273
# train_discrete_score_W_discrete_a 0.058209541651147334
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.08139811316005316
# test_discrete_score_W_discrete_a 0.08223431499740945
# neuron unit number: 43
# train_discrete_score_W0_p 0.393154486586494
# train_discrete_score_W0_n 0.0060907045909383475
# train_discrete_score_W0_a  0.008335768065120491
# test_discrete_score_W0_p 0.4060475161987041
# test_discrete_score_W0_n 0.014719077895663703
# test_discrete_score_W0_a 0.01613818556365906
# train_discrete_score_W_discrete_p 0.4343200740055504
# train_discrete_score_W_discrete_n 0.06599961574395247
# train_discrete_score_W_discrete_a 0.06200918132971787
# test_discrete_score_W_discrete_p 0.46436285097192226
# test_discrete_score_W_discrete_n 0.0980460043251007
# test_discrete_score_W_discrete_a 0.09671174849833149
# neuron unit number: 44
# train_discrete_score_W0_p 0.38806660499537465
# train_discrete_score_W0_n 0.006519259088724404
# train_discrete_score_W0_a  0.00807066165469357
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.018445281945641157
# test_discrete_score_W0_a 0.023474321404822064
# train_discrete_score_W_discrete_p 0.42738205365402404
# train_discrete_score_W_discrete_n 0.05535242070483853
# train_discrete_score_W_discrete_a 0.0511993739698723
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.09523264839935658
# test_discrete_score_W_discrete_a 0.09044365521736641
# neuron unit number: 45
# train_discrete_score_W0_p 0.3973172987974098
# train_discrete_score_W0_n 0.009027196578331847
# train_discrete_score_W0_a  0.015973047546703964
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.024660387176168856
# test_discrete_score_W0_a 0.025311853269470573
# train_discrete_score_W_discrete_p 0.4357076780758557
# train_discrete_score_W_discrete_n 0.0650792389213241
# train_discrete_score_W_discrete_a 0.06366911294655478
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.08977718087295702
# test_discrete_score_W_discrete_a 0.08489446099375025
# neuron unit number: 46
# train_discrete_score_W0_p 0.3876040703052729
# train_discrete_score_W0_n 0.005190366966070435
# train_discrete_score_W0_a  0.010212220967875035
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.017384042569160752
# test_discrete_score_W0_a 0.025764034420050288
# train_discrete_score_W_discrete_p 0.42923219241443106
# train_discrete_score_W_discrete_n 0.056327071079614426
# train_discrete_score_W_discrete_a 0.058048435053455624
# test_discrete_score_W_discrete_p 0.45680345572354214
# test_discrete_score_W_discrete_n 0.08811905162283612
# test_discrete_score_W_discrete_a 0.09133905659380828
# neuron unit number: 47
# train_discrete_score_W0_p 0.38575393154486587
# train_discrete_score_W0_n 0.004840737999878381
# train_discrete_score_W0_a  0.009312457922646537
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.017422996899521218
# test_discrete_score_W0_a 0.021480693144286866
# train_discrete_score_W_discrete_p 0.44033302497687327
# train_discrete_score_W_discrete_n 0.062106576762748195
# train_discrete_score_W_discrete_a 0.06656741732664305
# test_discrete_score_W_discrete_p 0.4740820734341253
# test_discrete_score_W_discrete_n 0.09682153084283854
# test_discrete_score_W_discrete_a 0.09851698625486402
# neuron unit number: 48
# train_discrete_score_W0_p 0.39454209065679924
# train_discrete_score_W0_n 0.00873702592085354
# train_discrete_score_W0_a  0.016704322675612466
# test_discrete_score_W0_p 0.4190064794816415
# test_discrete_score_W0_n 0.025388179750821895
# test_discrete_score_W0_a 0.03063449225161484
# train_discrete_score_W_discrete_p 0.4301572617946346
# train_discrete_score_W_discrete_n 0.06588506510500876
# train_discrete_score_W_discrete_a 0.06435176328573555
# test_discrete_score_W_discrete_p 0.4654427645788337
# test_discrete_score_W_discrete_n 0.08456682794103082
# test_discrete_score_W_discrete_a 0.08722950872494717
# neuron unit number: 49
# train_discrete_score_W0_p 0.3889916743755782
# train_discrete_score_W0_n 0.005933458524709118
# train_discrete_score_W0_a  0.011162896396068354
# test_discrete_score_W0_p 0.4200863930885529
# test_discrete_score_W0_n 0.027000701113487884
# test_discrete_score_W0_a 0.03704605024442381
# train_discrete_score_W_discrete_p 0.43061979648473636
# train_discrete_score_W_discrete_n 0.05427216341273465
# train_discrete_score_W_discrete_a 0.05795288442519265
# test_discrete_score_W_discrete_p 0.4503239740820734
# test_discrete_score_W_discrete_n 0.07504053376391148
# test_discrete_score_W_discrete_a 0.06990099709908622
# neuron unit number: 50
# train_discrete_score_W0_p 0.3963922294172063
# train_discrete_score_W0_n 0.009575176478726972
# train_discrete_score_W0_a  0.01715070310661637
# test_discrete_score_W0_p 0.4265658747300216
# test_discrete_score_W0_n 0.029759096860992255
# test_discrete_score_W0_a 0.0405329183541858
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.05182754810851414
# train_discrete_score_W_discrete_a 0.053005070122244785
# test_discrete_score_W_discrete_p 0.44384449244060475
# test_discrete_score_W_discrete_n 0.07907928598477428
# test_discrete_score_W_discrete_a 0.07157435444329634
# test_discrete_score_W0_p mean 0.4026199643158982
# test_discrete_score_W_discrete_p mean 0.46055967696497324
# test_discrete_score_W0_n mean 0.014466288099124642
# test_discrete_score_W_discrete_n mean 0.0882353424543395
# test_discrete_score_W0_a mean 0.01942267466045078
# test_discrete_score_W_discrete_a mean 0.08776902234225245
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.004624  0.002149  0.000317   0.003986  0.005263
# 1  train_dis_W_dis  46.0  0.063133  0.005681  0.000838   0.061446  0.064820
# 2         combined  92.0  0.033879  0.029723  0.003099   0.027723  0.040034
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0585
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -65.3293
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -13.6221
# 7                                    Hedge's g =  -13.5083
# 8                               Glass's delta1 =  -27.2216
# 9                             Point-Biserial r =   -0.9896
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.014466  0.007059  0.001041   0.012370  0.016563
# 1  test_dis_W_dis  46.0  0.088235  0.007887  0.001163   0.085893  0.090578
# 2        combined  92.0  0.051351  0.037826  0.003944   0.043517  0.059184
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0738
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -47.2682
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -9.8561
# 7                                  Hedge's g =   -9.7737
# 8                             Glass's delta1 =  -10.4504
# 9                           Point-Biserial r =   -0.9804
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.008015  0.004028  0.000594   0.006819  0.009211
# 1  train_dis_W_dis  46.0  0.063242  0.004889  0.000721   0.061791  0.064694
# 2         combined  92.0  0.035629  0.028120  0.002932   0.029805  0.041452
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0552
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -59.1309
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -12.3296
# 7                                    Hedge's g =  -12.2266
# 8                               Glass's delta1 =  -13.7093
# 9                             Point-Biserial r =   -0.9874
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.019423  0.009595  0.001415   0.016573  0.022272
# 1  test_dis_W_dis  46.0  0.087769  0.008945  0.001319   0.085113  0.090425
# 2        combined  92.0  0.053596  0.035577  0.003709   0.046228  0.060964
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0683
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -35.3376
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.3684
# 7                                  Hedge's g =   -7.3068
# 8                             Glass's delta1 =   -7.1231
# 9                           Point-Biserial r =   -0.9658
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.386216  0.006099  0.000899   0.384405  0.388028
# 1  train_dis_W_dis  46.0  0.433254  0.005191  0.000765   0.431713  0.434796
# 2         combined  92.0  0.409735  0.024309  0.002534   0.404701  0.414770
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0470
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -39.8340
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.3060
# 7                                    Hedge's g =   -8.2365
# 8                               Glass's delta1 =   -7.7125
# 9                             Point-Biserial r =   -0.9728
#          Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.40262  0.012324  0.001817   0.398960  0.406280
# 1  test_dis_W_dis  46.0  0.46056  0.009540  0.001407   0.457727  0.463393
# 2        combined  92.0  0.43159  0.031122  0.003245   0.425145  0.438035
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0579
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -25.2147
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -5.2576
# 7                                  Hedge's g =   -5.2137
# 8                             Glass's delta1 =   -4.7013
# 9                           Point-Biserial r =   -0.9359

# %%
#new hash endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.35291396854764107
# train_discrete_score_W0_n 0.0013678915096967008
# train_discrete_score_W0_a  0.0013671747674577238
# test_discrete_score_W0_p 0.35205183585313177
# test_discrete_score_W0_n 0.0021147437564562953
# test_discrete_score_W0_a 0.00021939969114957846
# train_discrete_score_W_discrete_p 0.41211840888066603
# train_discrete_score_W_discrete_n 0.04616117220722092
# train_discrete_score_W_discrete_a 0.0400605401181918
# test_discrete_score_W_discrete_p 0.43628509719222464
# test_discrete_score_W_discrete_n 0.05044037447652823
# test_discrete_score_W_discrete_a 0.05181938171274757
# neuron unit number: 6
# train_discrete_score_W0_p 0.35661424606845515
# train_discrete_score_W0_n 0.000946521741609853
# train_discrete_score_W0_a  0.0032344543758253824
# test_discrete_score_W0_p 0.34989200863930886
# test_discrete_score_W0_n 0.0011359728587550817
# test_discrete_score_W0_a -0.00032365441096592594
# train_discrete_score_W_discrete_p 0.40564292321924145
# train_discrete_score_W_discrete_n 0.03367257187139095
# train_discrete_score_W_discrete_a 0.03183954047092036
# test_discrete_score_W_discrete_p 0.4190064794816415
# test_discrete_score_W_discrete_n 0.053618851811738866
# test_discrete_score_W_discrete_a 0.04294374924349632
# neuron unit number: 7
# train_discrete_score_W0_p 0.35753931544865863
# train_discrete_score_W0_n 0.002355335289811848
# train_discrete_score_W0_a  0.001907626789547841
# test_discrete_score_W0_p 0.36609071274298055
# test_discrete_score_W0_n 0.003460924580123891
# test_discrete_score_W0_a 0.004666688696169723
# train_discrete_score_W_discrete_p 0.4107308048103608
# train_discrete_score_W_discrete_n 0.04870596059321388
# train_discrete_score_W_discrete_a 0.04117123382460974
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.05261924116814056
# test_discrete_score_W_discrete_a 0.03296981479420384
# neuron unit number: 8
# train_discrete_score_W0_p 0.35430157261794637
# train_discrete_score_W0_n 0.000888611594542426
# train_discrete_score_W0_a  0.002245758789258125
# test_discrete_score_W0_p 0.3563714902807775
# test_discrete_score_W0_n 0.00277351126385841
# test_discrete_score_W0_a 0.004782468300834088
# train_discrete_score_W_discrete_p 0.4148936170212766
# train_discrete_score_W_discrete_n 0.04561843463029875
# train_discrete_score_W_discrete_a 0.04205964047419632
# test_discrete_score_W_discrete_p 0.42332613390928725
# test_discrete_score_W_discrete_n 0.055972896311545055
# test_discrete_score_W_discrete_a 0.04840043853831705
# neuron unit number: 9
# train_discrete_score_W0_p 0.3635522664199815
# train_discrete_score_W0_n 0.0020930825645967105
# train_discrete_score_W0_a  -0.001368031439460856
# test_discrete_score_W0_p 0.35853131749460043
# test_discrete_score_W0_n 0.002962483075424395
# test_discrete_score_W0_a -0.00033479230462688957
# train_discrete_score_W_discrete_p 0.41350601295097134
# train_discrete_score_W_discrete_n 0.04602111262205461
# train_discrete_score_W_discrete_a 0.03950737894383983
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.0625262137613873
# test_discrete_score_W_discrete_a 0.05387646069972193
# neuron unit number: 10
# train_discrete_score_W0_p 0.3580018501387604
# train_discrete_score_W0_n 0.0016091361920558959
# train_discrete_score_W0_a  0.0004826136691378259
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.004680726774300146
# test_discrete_score_W0_a 0.005241537281839929
# train_discrete_score_W_discrete_p 0.41720629047178537
# train_discrete_score_W_discrete_n 0.0554711825943633
# train_discrete_score_W_discrete_a 0.048288567040773486
# test_discrete_score_W_discrete_p 0.4352051835853132
# test_discrete_score_W_discrete_n 0.055849122823458615
# test_discrete_score_W_discrete_a 0.05319789695231088
# neuron unit number: 11
# train_discrete_score_W0_p 0.3603145235892692
# train_discrete_score_W0_n 0.001752972123207905
# train_discrete_score_W0_a  0.0038660856310015353
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.004491120261285837
# test_discrete_score_W0_a 0.002954375458331299
# train_discrete_score_W_discrete_p 0.40795559666975023
# train_discrete_score_W_discrete_n 0.04876294269407978
# train_discrete_score_W_discrete_a 0.04464289983566849
# test_discrete_score_W_discrete_p 0.4200863930885529
# test_discrete_score_W_discrete_n 0.056613431790300574
# test_discrete_score_W_discrete_a 0.05240835228468059
# neuron unit number: 12
# train_discrete_score_W0_p 0.3593894542090657
# train_discrete_score_W0_n 0.0018250106001666479
# train_discrete_score_W0_a  0.004500665400326836
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.004506527852676224
# test_discrete_score_W0_a 0.005817893804525312
# train_discrete_score_W_discrete_p 0.41905642923219244
# train_discrete_score_W_discrete_n 0.05417282835882079
# train_discrete_score_W_discrete_a 0.04348435057874828
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.06889011375696284
# test_discrete_score_W_discrete_a 0.06400293205255231
# neuron unit number: 13
# train_discrete_score_W0_p 0.36308973172987974
# train_discrete_score_W0_n 0.0027750630566371207
# train_discrete_score_W0_a  0.00268092033804576
# test_discrete_score_W0_p 0.36285097192224625
# test_discrete_score_W0_n 0.0026904780008747396
# test_discrete_score_W0_a 0.003682508786246851
# train_discrete_score_W_discrete_p 0.40564292321924145
# train_discrete_score_W_discrete_n 0.05014653675043901
# train_discrete_score_W_discrete_a 0.03823693938848771
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.055424071427240845
# test_discrete_score_W_discrete_a 0.049018297940111026
# neuron unit number: 14
# train_discrete_score_W0_p 0.36632747456059206
# train_discrete_score_W0_n 0.0023588215104376428
# train_discrete_score_W0_a  0.0030837662234954938
# test_discrete_score_W0_p 0.36393088552915764
# test_discrete_score_W0_n 0.00450637038387434
# test_discrete_score_W0_a 0.0017260017078527372
# train_discrete_score_W_discrete_p 0.40980573543015725
# train_discrete_score_W_discrete_n 0.04648530887513825
# train_discrete_score_W_discrete_a 0.03812283603407828
# test_discrete_score_W_discrete_p 0.4330453563714903
# test_discrete_score_W_discrete_n 0.04714327763829051
# test_discrete_score_W_discrete_a 0.04485630509592693
# neuron unit number: 15
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.005073856782122575
# train_discrete_score_W0_a  0.008766173347477101
# test_discrete_score_W0_p 0.3650107991360691
# test_discrete_score_W0_n 0.003793621239805018
# test_discrete_score_W0_a 0.0031514543231039244
# train_discrete_score_W_discrete_p 0.4162812210915819
# train_discrete_score_W_discrete_n 0.04396179575379538
# train_discrete_score_W_discrete_a 0.04526086530497515
# test_discrete_score_W_discrete_p 0.4168466522678186
# test_discrete_score_W_discrete_n 0.04171829039372054
# test_discrete_score_W_discrete_a 0.03681556810677954
# neuron unit number: 16
# train_discrete_score_W0_p 0.36262719703977797
# train_discrete_score_W0_n 0.0028104028025140223
# train_discrete_score_W0_a  0.005375335835243082
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.008781343659669844
# test_discrete_score_W0_a 0.007140760673101411
# train_discrete_score_W_discrete_p 0.41766882516188714
# train_discrete_score_W_discrete_n 0.05230363936786589
# train_discrete_score_W_discrete_a 0.04396201659166757
# test_discrete_score_W_discrete_p 0.4406047516198704
# test_discrete_score_W_discrete_n 0.06670792623602595
# test_discrete_score_W_discrete_a 0.05973785764478578
# neuron unit number: 17
# train_discrete_score_W0_p 0.3654024051803885
# train_discrete_score_W0_n 0.0024075844666123034
# train_discrete_score_W0_a  0.0018268694954452888
# test_discrete_score_W0_p 0.37365010799136067
# test_discrete_score_W0_n 0.006631347803962999
# test_discrete_score_W0_a 0.003388005182365261
# train_discrete_score_W_discrete_p 0.4199814986123959
# train_discrete_score_W_discrete_n 0.05081116133687122
# train_discrete_score_W_discrete_a 0.052792249553338125
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.08527345084366802
# test_discrete_score_W_discrete_a 0.07288649528595875
# neuron unit number: 18
# train_discrete_score_W0_p 0.3658649398704903
# train_discrete_score_W0_n 0.002930473205232644
# train_discrete_score_W0_a  0.006024961573731043
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.009386320906296739
# test_discrete_score_W0_a 0.007391236541955199
# train_discrete_score_W_discrete_p 0.4116558741905643
# train_discrete_score_W_discrete_n 0.04729575464349059
# train_discrete_score_W_discrete_a 0.04470798610804532
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.05719774252627389
# test_discrete_score_W_discrete_a 0.04650218692733011
# neuron unit number: 19
# train_discrete_score_W0_p 0.37280296022201664
# train_discrete_score_W0_n 0.0033119789992974097
# train_discrete_score_W0_a  0.005108705247737923
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.007108895123769033
# test_discrete_score_W0_a 0.007536536434086026
# train_discrete_score_W_discrete_p 0.41951896392229415
# train_discrete_score_W_discrete_n 0.05189580828993418
# train_discrete_score_W_discrete_a 0.04836957666586637
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.07035246724154717
# test_discrete_score_W_discrete_a 0.06216190514685363
# neuron unit number: 20
# train_discrete_score_W0_p 0.36864014801110084
# train_discrete_score_W0_n 0.005469633351092172
# train_discrete_score_W0_a  0.007272627032005058
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.00735046006854596
# test_discrete_score_W0_a 0.005800834270752196
# train_discrete_score_W_discrete_p 0.4139685476410731
# train_discrete_score_W_discrete_n 0.052068357127236876
# train_discrete_score_W_discrete_a 0.047416428609117545
# test_discrete_score_W_discrete_p 0.4373650107991361
# test_discrete_score_W_discrete_n 0.060621572529880825
# test_discrete_score_W_discrete_a 0.06041399135768917
# neuron unit number: 21
# train_discrete_score_W0_p 0.3732654949121184
# train_discrete_score_W0_n 0.0035049053695228928
# train_discrete_score_W0_a  0.004301978392599933
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.006401838239106244
# test_discrete_score_W0_a 0.008145801451717696
# train_discrete_score_W_discrete_p 0.41211840888066603
# train_discrete_score_W_discrete_n 0.054374356399816665
# train_discrete_score_W_discrete_a 0.04597836746364976
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.06446638325810562
# test_discrete_score_W_discrete_a 0.05675691455580837
# neuron unit number: 22
# train_discrete_score_W0_p 0.3654024051803885
# train_discrete_score_W0_n 0.00406356291598714
# train_discrete_score_W0_a  0.006089978998462522
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.009636031440798994
# test_discrete_score_W0_a 0.002431229220648661
# train_discrete_score_W_discrete_p 0.42183163737280294
# train_discrete_score_W_discrete_n 0.04709453432835607
# train_discrete_score_W_discrete_a 0.0492504590486971
# test_discrete_score_W_discrete_p 0.4514038876889849
# test_discrete_score_W_discrete_n 0.07246529663768862
# test_discrete_score_W_discrete_a 0.06789542526040664
# neuron unit number: 23
# train_discrete_score_W0_p 0.3737280296022202
# train_discrete_score_W0_n 0.00618347422109251
# train_discrete_score_W0_a  0.0060327920558595535
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.008561637884218654
# test_discrete_score_W0_a 0.009052234210177146
# train_discrete_score_W_discrete_p 0.4070305272895467
# train_discrete_score_W_discrete_n 0.041349029497766546
# train_discrete_score_W_discrete_a 0.03158768050541143
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.061729097527343214
# test_discrete_score_W_discrete_a 0.04337028532821757
# neuron unit number: 24
# train_discrete_score_W0_p 0.3732654949121184
# train_discrete_score_W0_n 0.005161901497661145
# train_discrete_score_W0_a  0.009013099970289271
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.011310004076079155
# test_discrete_score_W0_a 0.012529962964748401
# train_discrete_score_W_discrete_p 0.41859389454209067
# train_discrete_score_W_discrete_n 0.047134688496559066
# train_discrete_score_W_discrete_a 0.03814600630352892
# test_discrete_score_W_discrete_p 0.4298056155507559
# test_discrete_score_W_discrete_n 0.06190138793793551
# test_discrete_score_W_discrete_a 0.05520131203378538
# neuron unit number: 25
# train_discrete_score_W0_p 0.37511563367252543
# train_discrete_score_W0_n 0.004500828248478245
# train_discrete_score_W0_a  0.005211383305092849
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.007849051969010758
# test_discrete_score_W0_a 0.008104032366830001
# train_discrete_score_W_discrete_p 0.4144310823311748
# train_discrete_score_W_discrete_n 0.04933903074206217
# train_discrete_score_W_discrete_a 0.04425192490218968
# test_discrete_score_W_discrete_p 0.4352051835853132
# test_discrete_score_W_discrete_n 0.05564990700739687
# test_discrete_score_W_discrete_a 0.057993220693060274
# neuron unit number: 26
# train_discrete_score_W0_p 0.3714153561517114
# train_discrete_score_W0_n 0.003745467785021034
# train_discrete_score_W0_a  0.003988749486014524
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.009135021166209402
# test_discrete_score_W0_a 0.01122137367874462
# train_discrete_score_W_discrete_p 0.4148936170212766
# train_discrete_score_W_discrete_n 0.05231773828376609
# train_discrete_score_W_discrete_a 0.04743162898182218
# test_discrete_score_W_discrete_p 0.4427645788336933
# test_discrete_score_W_discrete_n 0.0678558652998911
# test_discrete_score_W_discrete_a 0.06415666656624726
# neuron unit number: 27
# train_discrete_score_W0_p 0.37511563367252543
# train_discrete_score_W0_n 0.0073597334009613295
# train_discrete_score_W0_a  0.0077438733342480755
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.017126734483854364
# test_discrete_score_W0_a 0.0195120516997762
# train_discrete_score_W_discrete_p 0.4070305272895467
# train_discrete_score_W_discrete_n 0.03752818789202772
# train_discrete_score_W_discrete_a 0.037753938111823405
# test_discrete_score_W_discrete_p 0.4352051835853132
# test_discrete_score_W_discrete_n 0.0459286592637134
# test_discrete_score_W_discrete_a 0.04782748994037683
# neuron unit number: 28
# train_discrete_score_W0_p 0.3667900092506938
# train_discrete_score_W0_n 0.0025352372058897107
# train_discrete_score_W0_a  0.004658797386405497
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.01455397282460659
# test_discrete_score_W0_a 0.012459338341270875
# train_discrete_score_W_discrete_p 0.41905642923219244
# train_discrete_score_W_discrete_n 0.05315946592076076
# train_discrete_score_W_discrete_a 0.05306023916866773
# test_discrete_score_W_discrete_p 0.4470842332613391
# test_discrete_score_W_discrete_n 0.06432664738529828
# test_discrete_score_W_discrete_a 0.06212212668388473
# neuron unit number: 29
# train_discrete_score_W0_p 0.3737280296022202
# train_discrete_score_W0_n 0.0037109176314367234
# train_discrete_score_W0_a  0.004248748037117199
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.005759390794096372
# test_discrete_score_W0_a 0.0065490228470238415
# train_discrete_score_W_discrete_p 0.42183163737280294
# train_discrete_score_W_discrete_n 0.052268071509900746
# train_discrete_score_W_discrete_a 0.04497619557412063
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.05899730743874659
# test_discrete_score_W_discrete_a 0.0530345175514806
# neuron unit number: 30
# train_discrete_score_W0_p 0.3681776133209991
# train_discrete_score_W0_n 0.004939178047522434
# train_discrete_score_W0_a  0.005678170362411335
# test_discrete_score_W0_p 0.38876889848812096
# test_discrete_score_W0_n 0.015805488206233884
# test_discrete_score_W0_a 0.025001891354987205
# train_discrete_score_W_discrete_p 0.4158186864014801
# train_discrete_score_W_discrete_n 0.044083696912998294
# train_discrete_score_W_discrete_a 0.04089533918500813
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.062056359235299674
# test_discrete_score_W_discrete_a 0.06393454065862658
# neuron unit number: 31
# train_discrete_score_W0_p 0.379740980573543
# train_discrete_score_W0_n 0.0053232501209707845
# train_discrete_score_W0_a  0.008102001227460614
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.00855817551726975
# test_discrete_score_W0_a 0.008816546356184715
# train_discrete_score_W_discrete_p 0.41905642923219244
# train_discrete_score_W_discrete_n 0.04867227922849504
# train_discrete_score_W_discrete_a 0.046277188143114024
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.06310705007418248
# test_discrete_score_W_discrete_a 0.05973878374393378
# neuron unit number: 32
# train_discrete_score_W0_p 0.3700277520814061
# train_discrete_score_W0_n 0.0033842978771574505
# train_discrete_score_W0_a  0.003574397536506918
# test_discrete_score_W0_p 0.4190064794816415
# test_discrete_score_W0_n 0.027865694693514565
# test_discrete_score_W0_a 0.03284187462924384
# train_discrete_score_W_discrete_p 0.4148936170212766
# train_discrete_score_W_discrete_n 0.041163970598302776
# train_discrete_score_W_discrete_a 0.040972382247466715
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.05440816413020782
# test_discrete_score_W_discrete_a 0.040719177478839165
# neuron unit number: 33
# train_discrete_score_W0_p 0.3755781683626272
# train_discrete_score_W0_n 0.008037675625600383
# train_discrete_score_W0_a  0.008692084142848666
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.02004351002949459
# test_discrete_score_W0_a 0.016973585708340955
# train_discrete_score_W_discrete_p 0.425531914893617
# train_discrete_score_W_discrete_n 0.05567270719914656
# train_discrete_score_W_discrete_a 0.046901300468713984
# test_discrete_score_W_discrete_p 0.43844492440604754
# test_discrete_score_W_discrete_n 0.05838245603690653
# test_discrete_score_W_discrete_a 0.05087049962381541
# neuron unit number: 34
# train_discrete_score_W0_p 0.38020351526364476
# train_discrete_score_W0_n 0.007836343776025698
# train_discrete_score_W0_a  0.01048098120666975
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.02102957686864962
# test_discrete_score_W0_a 0.021518709382831697
# train_discrete_score_W_discrete_p 0.4167437557816836
# train_discrete_score_W_discrete_n 0.048294749344839884
# train_discrete_score_W_discrete_a 0.04453651410340891
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.045071936027579126
# test_discrete_score_W_discrete_a 0.03993808396934086
# neuron unit number: 35
# train_discrete_score_W0_p 0.3700277520814061
# train_discrete_score_W0_n 0.005368872188783222
# train_discrete_score_W0_a  0.008893669090345764
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.013301738604605868
# test_discrete_score_W0_a 0.011932691736130931
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.051644827730853986
# train_discrete_score_W_discrete_a 0.047106715527379564
# test_discrete_score_W_discrete_p 0.4298056155507559
# test_discrete_score_W_discrete_n 0.055960297910094076
# test_discrete_score_W_discrete_a 0.04881441885078604
# neuron unit number: 36
# train_discrete_score_W0_p 0.3755781683626272
# train_discrete_score_W0_n 0.0048337225814567165
# train_discrete_score_W0_a  0.004787992569044161
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.013390104734763165
# test_discrete_score_W0_a 0.011906193220111333
# train_discrete_score_W_discrete_p 0.4158186864014801
# train_discrete_score_W_discrete_n 0.05070666282038979
# train_discrete_score_W_discrete_a 0.04537080477287489
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.06011815044430821
# test_discrete_score_W_discrete_a 0.055750629937949665
# neuron unit number: 37
# train_discrete_score_W0_p 0.37419056429232195
# train_discrete_score_W0_n 0.005049056851939472
# train_discrete_score_W0_a  0.00740359616495573
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.014763546315042038
# test_discrete_score_W0_a 0.013949236562808037
# train_discrete_score_W_discrete_p 0.4199814986123959
# train_discrete_score_W_discrete_n 0.04548266488490179
# train_discrete_score_W_discrete_a 0.038226477233301887
# test_discrete_score_W_discrete_p 0.44384449244060475
# test_discrete_score_W_discrete_n 0.06570783086880792
# test_discrete_score_W_discrete_a 0.06012344143654448
# neuron unit number: 38
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.005511471997101023
# train_discrete_score_W0_a  0.0032706395170273394
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.015636594198752747
# test_discrete_score_W0_a 0.020973475891387493
# train_discrete_score_W_discrete_p 0.41304347826086957
# train_discrete_score_W_discrete_n 0.04846290387787022
# train_discrete_score_W_discrete_a 0.046145906628077514
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.059888308359086824
# test_discrete_score_W_discrete_a 0.06334063584877068
# neuron unit number: 39
# train_discrete_score_W0_p 0.3926919518963922
# train_discrete_score_W0_n 0.010694898342261255
# train_discrete_score_W0_a  0.011502668775673136
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.017469985301260933
# test_discrete_score_W0_a 0.021221916093716875
# train_discrete_score_W_discrete_p 0.40749306197964846
# train_discrete_score_W_discrete_n 0.047065310679576644
# train_discrete_score_W_discrete_a 0.04517539368550656
# test_discrete_score_W_discrete_p 0.42764578833693306
# test_discrete_score_W_discrete_n 0.06468052949292435
# test_discrete_score_W_discrete_a 0.04608211483925083
# neuron unit number: 40
# train_discrete_score_W0_p 0.3852913968547641
# train_discrete_score_W0_n 0.00883857936612886
# train_discrete_score_W0_a  0.008600864915017738
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.018783579178685013
# test_discrete_score_W0_a 0.024758249737869917
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.05316202624673515
# train_discrete_score_W_discrete_a 0.04931535659378959
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.059733011554773535
# test_discrete_score_W_discrete_a 0.06359324888629424
# neuron unit number: 41
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.004166891162878395
# train_discrete_score_W0_a  0.00439423178864667
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.01215335866570166
# test_discrete_score_W0_a 0.011903045921961787
# train_discrete_score_W_discrete_p 0.4296947271045328
# train_discrete_score_W_discrete_n 0.05330946017870033
# train_discrete_score_W_discrete_a 0.04851405065998133
# test_discrete_score_W_discrete_p 0.4470842332613391
# test_discrete_score_W_discrete_n 0.07620383090636339
# test_discrete_score_W_discrete_a 0.06441303729373486
# neuron unit number: 42
# train_discrete_score_W0_p 0.38020351526364476
# train_discrete_score_W0_n 0.008004078968383645
# train_discrete_score_W0_a  0.008524305280884192
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.018539422291736402
# test_discrete_score_W0_a 0.022577532641571117
# train_discrete_score_W_discrete_p 0.41535615171137835
# train_discrete_score_W_discrete_n 0.04804843610867913
# train_discrete_score_W_discrete_a 0.04420833211111898
# test_discrete_score_W_discrete_p 0.4427645788336933
# test_discrete_score_W_discrete_n 0.0663198907196766
# test_discrete_score_W_discrete_a 0.05759867115505013
# neuron unit number: 43
# train_discrete_score_W0_p 0.3792784458834413
# train_discrete_score_W0_n 0.0056118872337400155
# train_discrete_score_W0_a  0.0068375984869778255
# test_discrete_score_W0_p 0.3930885529157667
# test_discrete_score_W0_n 0.01435309596737722
# test_discrete_score_W0_a 0.009617538149561412
# train_discrete_score_W_discrete_p 0.42090656799259946
# train_discrete_score_W_discrete_n 0.059393681121764574
# train_discrete_score_W_discrete_a 0.04966949880060449
# test_discrete_score_W_discrete_p 0.4352051835853132
# test_discrete_score_W_discrete_n 0.0511380500470111
# test_discrete_score_W_discrete_a 0.04725414766317718
# neuron unit number: 44
# train_discrete_score_W0_p 0.3788159111933395
# train_discrete_score_W0_n 0.0077900025565012555
# train_discrete_score_W0_a  0.008850575937048358
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.01671411422942037
# test_discrete_score_W0_a 0.019197365759693875
# train_discrete_score_W_discrete_p 0.4167437557816836
# train_discrete_score_W_discrete_n 0.04510994994631189
# train_discrete_score_W_discrete_a 0.04570377033724926
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.05492131788560035
# test_discrete_score_W_discrete_a 0.048328911206847305
# neuron unit number: 45
# train_discrete_score_W0_p 0.379740980573543
# train_discrete_score_W0_n 0.0075313834057882416
# train_discrete_score_W0_a  0.007570582105849149
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.019429872389380622
# test_discrete_score_W0_a 0.023408246011470894
# train_discrete_score_W_discrete_p 0.41720629047178537
# train_discrete_score_W_discrete_n 0.05485741722545632
# train_discrete_score_W_discrete_a 0.048318614316669756
# test_discrete_score_W_discrete_p 0.4427645788336933
# test_discrete_score_W_discrete_n 0.06810998977329137
# test_discrete_score_W_discrete_a 0.05845170154809976
# neuron unit number: 46
# train_discrete_score_W0_p 0.38159111933395007
# train_discrete_score_W0_n 0.00920273335153774
# train_discrete_score_W0_a  0.010395439490082002
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.014599359897219085
# test_discrete_score_W0_a 0.013631902786064956
# train_discrete_score_W_discrete_p 0.4162812210915819
# train_discrete_score_W_discrete_n 0.042373322187811
# train_discrete_score_W_discrete_a 0.04033405246159761
# test_discrete_score_W_discrete_p 0.42764578833693306
# test_discrete_score_W_discrete_n 0.05241474033116631
# test_discrete_score_W_discrete_a 0.05631314307669841
# neuron unit number: 47
# train_discrete_score_W0_p 0.3723404255319149
# train_discrete_score_W0_n 0.0052508634514181396
# train_discrete_score_W0_a  0.007098465325700147
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.012106126753483541
# test_discrete_score_W0_a 0.013638748463922984
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.04971126169520392
# train_discrete_score_W_discrete_a 0.045819293409236815
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.06661093929487914
# test_discrete_score_W_discrete_a 0.06792283902327524
# neuron unit number: 48
# train_discrete_score_W0_p 0.38621646623496764
# train_discrete_score_W0_n 0.008634654428145877
# train_discrete_score_W0_a  0.011236547736499193
# test_discrete_score_W0_p 0.4114470842332613
# test_discrete_score_W0_n 0.022379178388221347
# test_discrete_score_W0_a 0.03043547488463615
# train_discrete_score_W_discrete_p 0.41720629047178537
# train_discrete_score_W_discrete_n 0.049261921394098934
# train_discrete_score_W_discrete_a 0.04604578652778327
# test_discrete_score_W_discrete_p 0.43412526997840173
# test_discrete_score_W_discrete_n 0.058537762070130714
# test_discrete_score_W_discrete_a 0.04743160943994959
# neuron unit number: 49
# train_discrete_score_W0_p 0.3894542090656799
# train_discrete_score_W0_n 0.0103632187437402
# train_discrete_score_W0_a  0.015205948127810991
# test_discrete_score_W0_p 0.40712742980561556
# test_discrete_score_W0_n 0.022157268652302005
# test_discrete_score_W0_a 0.031880892919637666
# train_discrete_score_W_discrete_p 0.41350601295097134
# train_discrete_score_W_discrete_n 0.0496159367022565
# train_discrete_score_W_discrete_a 0.047110759554393374
# test_discrete_score_W_discrete_p 0.4406047516198704
# test_discrete_score_W_discrete_n 0.05448851280926238
# test_discrete_score_W_discrete_a 0.05198700201185991
# neuron unit number: 50
# train_discrete_score_W0_p 0.3866790009250694
# train_discrete_score_W0_n 0.008236840240773494
# train_discrete_score_W0_a  0.010201093525899322
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.027635673686077174
# test_discrete_score_W0_a 0.03441887307260121
# train_discrete_score_W_discrete_p 0.4158186864014801
# train_discrete_score_W_discrete_n 0.05313163184868921
# train_discrete_score_W_discrete_a 0.05197848846888096
# test_discrete_score_W_discrete_p 0.43412526997840173
# test_discrete_score_W_discrete_n 0.05412612179395829
# test_discrete_score_W_discrete_a 0.05090313862320442
# test_discrete_score_W0_p mean 0.3829937083294206
# test_discrete_score_W_discrete_p mean 0.4363085735749835
# test_discrete_score_W0_n mean 0.011596173805583723
# test_discrete_score_W_discrete_n mean 0.059701627092572596
# test_discrete_score_W0_a mean 0.012466310706573766
# test_discrete_score_W_discrete_a mean 0.053997377580712644
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.004899  0.002608  0.000385   0.004124  0.005674
# 1  train_dis_W_dis  46.0  0.048855  0.004893  0.000721   0.047402  0.050308
# 2         combined  92.0  0.026877  0.022440  0.002340   0.022230  0.031524
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0440
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -53.7647
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -11.2107
# 7                                    Hedge's g =  -11.1170
# 8                               Glass's delta1 =  -16.8527
# 9                             Point-Biserial r =   -0.9848
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.011596  0.006952  0.001025   0.009532  0.013661
# 1  test_dis_W_dis  46.0  0.059702  0.008293  0.001223   0.057239  0.062164
# 2        combined  92.0  0.035649  0.025354  0.002643   0.030398  0.040899
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0481
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -30.1493
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.2866
# 7                                  Hedge's g =   -6.2340
# 8                             Glass's delta1 =   -6.9198
# 9                           Point-Biserial r =   -0.9539
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.006064  0.003293  0.000485   0.005087  0.007042
# 1  train_dis_W_dis  46.0  0.044369  0.004761  0.000702   0.042955  0.045783
# 2         combined  92.0  0.025217  0.019683  0.002052   0.021141  0.029293
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0383
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -44.8811
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -9.3584
# 7                                    Hedge's g =   -9.2802
# 8                               Glass's delta1 =  -11.6335
# 9                             Point-Biserial r =   -0.9784
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.012466  0.009376  0.001382   0.009682  0.015251
# 1  test_dis_W_dis  46.0  0.053997  0.008819  0.001300   0.051378  0.056616
# 2        combined  92.0  0.033232  0.022757  0.002373   0.028519  0.037945
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0415
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -21.8826
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -4.5628
# 7                                  Hedge's g =   -4.5247
# 8                             Glass's delta1 =   -4.4295
# 9                           Point-Biserial r =   -0.9175
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.371576  0.009327  0.001375   0.368807  0.374346
# 1  train_dis_W_dis  46.0  0.416010  0.005425  0.000800   0.414399  0.417621
# 2         combined  92.0  0.393793  0.023592  0.002460   0.388907  0.398679
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0444
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -27.9305
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -5.8239
# 7                                    Hedge's g =   -5.7752
# 8                               Glass's delta1 =   -4.7642
# 9                             Point-Biserial r =   -0.9469
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.382994  0.016432  0.002423   0.378114  0.387873
# 1  test_dis_W_dis  46.0  0.436309  0.009607  0.001416   0.433456  0.439161
# 2        combined  92.0  0.409651  0.029960  0.003124   0.403447  0.415856
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0533
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -18.9977
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.9613
# 7                                  Hedge's g =   -3.9282
# 8                             Glass's delta1 =   -3.2446
# 9                           Point-Biserial r =   -0.8947

# %%
#new sum endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.34551341350601295
# train_discrete_score_W0_n 0.0008029350644905392
# train_discrete_score_W0_a  -0.001614865510512148
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.40333024976873266
# train_discrete_score_W_discrete_n 0.04885388338065116
# train_discrete_score_W_discrete_a 0.045931799801603515
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.0658267960286614
# test_discrete_score_W_discrete_a 0.07471001018388865
# neuron unit number: 6
# train_discrete_score_W0_p 0.3519888991674376
# train_discrete_score_W0_n 0.004963408361217402
# train_discrete_score_W0_a  0.013945278339727227
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.4107308048103608
# train_discrete_score_W_discrete_n 0.06041269659414135
# train_discrete_score_W_discrete_a 0.056538428521880915
# test_discrete_score_W_discrete_p 0.468682505399568
# test_discrete_score_W_discrete_n 0.07750849421733162
# test_discrete_score_W_discrete_a 0.06725113290561929
# neuron unit number: 7
# train_discrete_score_W0_p 0.34551341350601295
# train_discrete_score_W0_n 0.000747354969119168
# train_discrete_score_W0_a  -0.001439096855081462
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.002822831113306644
# test_discrete_score_W0_a -0.006509867502503436
# train_discrete_score_W_discrete_p 0.4107308048103608
# train_discrete_score_W_discrete_n 0.0637086475439488
# train_discrete_score_W_discrete_a 0.06189248795619101
# test_discrete_score_W_discrete_p 0.4719222462203024
# test_discrete_score_W_discrete_n 0.08410206627115613
# test_discrete_score_W_discrete_a 0.07929550939925796
# neuron unit number: 8
# train_discrete_score_W0_p 0.34921369102682703
# train_discrete_score_W0_n 0.0013196213055662906
# train_discrete_score_W0_a  0.004487746291431232
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.006093427588316178
# test_discrete_score_W0_a -0.0032194475674889238
# train_discrete_score_W_discrete_p 0.41304347826086957
# train_discrete_score_W_discrete_n 0.05848486709091478
# train_discrete_score_W_discrete_a 0.05763031706584908
# test_discrete_score_W_discrete_p 0.4838012958963283
# test_discrete_score_W_discrete_n 0.0808155623495274
# test_discrete_score_W_discrete_a 0.08225873828844209
# neuron unit number: 9
# train_discrete_score_W0_p 0.3464384828862165
# train_discrete_score_W0_n 0.0023691828714294365
# train_discrete_score_W0_a  0.001074706810054653
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.005237537251916162
# test_discrete_score_W0_a -0.004958216363432354
# train_discrete_score_W_discrete_p 0.41304347826086957
# train_discrete_score_W_discrete_n 0.06053827350533711
# train_discrete_score_W_discrete_a 0.052920465146711684
# test_discrete_score_W_discrete_p 0.4740820734341253
# test_discrete_score_W_discrete_n 0.08194231706660586
# test_discrete_score_W_discrete_a 0.08630515799759192
# neuron unit number: 10
# train_discrete_score_W0_p 0.35291396854764107
# train_discrete_score_W0_n 0.00174758501535377
# train_discrete_score_W0_a  0.0031291702696911875
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.005820754210918242
# test_discrete_score_W0_a -0.0028106800033717897
# train_discrete_score_W_discrete_p 0.4116558741905643
# train_discrete_score_W_discrete_n 0.05197727195626668
# train_discrete_score_W_discrete_a 0.04751888726171331
# test_discrete_score_W_discrete_p 0.4611231101511879
# test_discrete_score_W_discrete_n 0.06598961203798281
# test_discrete_score_W_discrete_a 0.06895161633669282
# neuron unit number: 11
# train_discrete_score_W0_p 0.3482886216466235
# train_discrete_score_W0_n 0.0031645374115908333
# train_discrete_score_W0_a  0.010496734965696296
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.008696250706799623
# test_discrete_score_W0_a 0.01007830567531933
# train_discrete_score_W_discrete_p 0.40888066604995377
# train_discrete_score_W_discrete_n 0.058941960039963506
# train_discrete_score_W_discrete_a 0.05484809198182246
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.07576662565034668
# test_discrete_score_W_discrete_a 0.06798850479288049
# neuron unit number: 12
# train_discrete_score_W0_p 0.34736355226641996
# train_discrete_score_W0_n 0.000760427551968811
# train_discrete_score_W0_a  0.00016388844111139004
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.005696473264461887
# test_discrete_score_W0_a -0.007102105039361006
# train_discrete_score_W_discrete_p 0.41350601295097134
# train_discrete_score_W_discrete_n 0.05561226507644607
# train_discrete_score_W_discrete_a 0.047067038809753624
# test_discrete_score_W_discrete_p 0.48272138228941686
# test_discrete_score_W_discrete_n 0.08543047160999516
# test_discrete_score_W_discrete_a 0.08334629923513588
# neuron unit number: 13
# train_discrete_score_W0_p 0.34782608695652173
# train_discrete_score_W0_n 0.0016575802444691937
# train_discrete_score_W0_a  0.007280174695845646
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.004667323168438122
# test_discrete_score_W0_a -0.0063015219582435375
# train_discrete_score_W_discrete_p 0.4139685476410731
# train_discrete_score_W_discrete_n 0.05603954192881604
# train_discrete_score_W_discrete_a 0.05570795843766429
# test_discrete_score_W_discrete_p 0.47840172786177104
# test_discrete_score_W_discrete_n 0.08562378345793348
# test_discrete_score_W_discrete_a 0.08545214961635901
# neuron unit number: 14
# train_discrete_score_W0_p 0.35661424606845515
# train_discrete_score_W0_n 0.0023755199933816365
# train_discrete_score_W0_a  0.0015352954283555588
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.009661991679653266
# test_discrete_score_W0_a 0.010673921040518794
# train_discrete_score_W_discrete_p 0.408418131359852
# train_discrete_score_W_discrete_n 0.05497810251104606
# train_discrete_score_W_discrete_a 0.052080767946114284
# test_discrete_score_W_discrete_p 0.46220302375809935
# test_discrete_score_W_discrete_n 0.08144333122056512
# test_discrete_score_W_discrete_a 0.0872533618919023
# neuron unit number: 15
# train_discrete_score_W0_p 0.3580018501387604
# train_discrete_score_W0_n 0.0033984849487856033
# train_discrete_score_W0_a  0.0062227709130173075
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.004542147425231506
# test_discrete_score_W0_a 0.0011727901337078833
# train_discrete_score_W_discrete_p 0.40795559666975023
# train_discrete_score_W_discrete_n 0.05691644428964629
# train_discrete_score_W_discrete_a 0.05453734306902428
# test_discrete_score_W_discrete_p 0.458963282937365
# test_discrete_score_W_discrete_n 0.08030770997148083
# test_discrete_score_W_discrete_a 0.07634230489459644
# neuron unit number: 16
# train_discrete_score_W0_p 0.3524514338575393
# train_discrete_score_W0_n 0.001881609763586364
# train_discrete_score_W0_a  0.005772095646187486
# test_discrete_score_W0_p 0.40280777537796975
# test_discrete_score_W0_n 0.009434088371180252
# test_discrete_score_W0_a 0.004814358256693885
# train_discrete_score_W_discrete_p 0.4222941720629047
# train_discrete_score_W_discrete_n 0.06226814493690094
# train_discrete_score_W_discrete_a 0.061983911972963636
# test_discrete_score_W_discrete_p 0.468682505399568
# test_discrete_score_W_discrete_n 0.07508839654929571
# test_discrete_score_W_discrete_a 0.06752997310801284
# neuron unit number: 17
# train_discrete_score_W0_p 0.35430157261794637
# train_discrete_score_W0_n 0.005362124410106461
# train_discrete_score_W0_a  0.011676013562412414
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.005754651519947427
# test_discrete_score_W0_a 0.003984517644519881
# train_discrete_score_W_discrete_p 0.41720629047178537
# train_discrete_score_W_discrete_n 0.060396914897809316
# train_discrete_score_W_discrete_a 0.05351861800010424
# test_discrete_score_W_discrete_p 0.4762419006479482
# test_discrete_score_W_discrete_n 0.0752243526795458
# test_discrete_score_W_discrete_a 0.07470560268788837
# neuron unit number: 18
# train_discrete_score_W0_p 0.3617021276595745
# train_discrete_score_W0_n 0.004036874409924061
# train_discrete_score_W0_a  0.00033468905946556924
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.006733448677950752
# test_discrete_score_W0_a 0.002240081354826167
# train_discrete_score_W_discrete_p 0.408418131359852
# train_discrete_score_W_discrete_n 0.047778311962771845
# train_discrete_score_W_discrete_a 0.04610010776699058
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.07522850086772324
# test_discrete_score_W_discrete_a 0.07402154624806769
# neuron unit number: 19
# train_discrete_score_W0_p 0.36262719703977797
# train_discrete_score_W0_n 0.006786041589729516
# train_discrete_score_W0_a  0.010233538878501546
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.013607204989373123
# test_discrete_score_W0_a 0.0025258645498632
# train_discrete_score_W_discrete_p 0.4125809435707678
# train_discrete_score_W_discrete_n 0.06244486558952413
# train_discrete_score_W_discrete_a 0.06262627653062731
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.06962319593915761
# test_discrete_score_W_discrete_a 0.07878574781744328
# neuron unit number: 20
# train_discrete_score_W0_p 0.3635522664199815
# train_discrete_score_W0_n 0.0041870663363431804
# train_discrete_score_W0_a  0.0073562481425817955
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.004150551947800943
# test_discrete_score_W0_a 0.003342756290641446
# train_discrete_score_W_discrete_p 0.408418131359852
# train_discrete_score_W_discrete_n 0.04841497001708457
# train_discrete_score_W_discrete_a 0.04487185012151444
# test_discrete_score_W_discrete_p 0.4654427645788337
# test_discrete_score_W_discrete_n 0.07526766973364628
# test_discrete_score_W_discrete_a 0.07511021522948817
# neuron unit number: 21
# train_discrete_score_W0_p 0.3506012950971323
# train_discrete_score_W0_n 0.0023380193578939456
# train_discrete_score_W0_a  0.005637474814978805
# test_discrete_score_W0_p 0.4114470842332613
# test_discrete_score_W0_n 0.013903230794151615
# test_discrete_score_W0_a 0.0077165692716576655
# train_discrete_score_W_discrete_p 0.40795559666975023
# train_discrete_score_W_discrete_n 0.05510219647778813
# train_discrete_score_W_discrete_a 0.05418956195761623
# test_discrete_score_W_discrete_p 0.46976241900647947
# test_discrete_score_W_discrete_n 0.07789020281873188
# test_discrete_score_W_discrete_a 0.07503676671124684
# neuron unit number: 22
# train_discrete_score_W0_p 0.3621646623496762
# train_discrete_score_W0_n 0.004592020166997808
# train_discrete_score_W0_a  0.009037855441728894
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.012933223939574369
# test_discrete_score_W0_a 0.006512425199436048
# train_discrete_score_W_discrete_p 0.4070305272895467
# train_discrete_score_W_discrete_n 0.060065068443395715
# train_discrete_score_W_discrete_a 0.05360056374547726
# test_discrete_score_W_discrete_p 0.45788336933045354
# test_discrete_score_W_discrete_n 0.0701308340397852
# test_discrete_score_W_discrete_a 0.07027766316426518
# neuron unit number: 23
# train_discrete_score_W0_p 0.3593894542090657
# train_discrete_score_W0_n 0.003898755571605331
# train_discrete_score_W0_a  0.011309088204412553
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.009598066130415066
# test_discrete_score_W0_a 0.01405734496744539
# train_discrete_score_W_discrete_p 0.40425531914893614
# train_discrete_score_W_discrete_n 0.05367520308222446
# train_discrete_score_W_discrete_a 0.04751952389498302
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.06513985160998535
# test_discrete_score_W_discrete_a 0.06363736949864582
# neuron unit number: 24
# train_discrete_score_W0_p 0.3714153561517114
# train_discrete_score_W0_n 0.007437295402427034
# train_discrete_score_W0_a  0.01357415964318979
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.006629809299705004
# test_discrete_score_W0_a 0.004608566867559559
# train_discrete_score_W_discrete_p 0.4093432007400555
# train_discrete_score_W_discrete_n 0.05037872436731937
# train_discrete_score_W_discrete_a 0.04951739272000039
# test_discrete_score_W_discrete_p 0.4632829373650108
# test_discrete_score_W_discrete_n 0.08182487826926207
# test_discrete_score_W_discrete_a 0.07635293995302099
# neuron unit number: 25
# train_discrete_score_W0_p 0.3681776133209991
# train_discrete_score_W0_n 0.006919809602470009
# train_discrete_score_W0_a  0.011481449265078192
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.010717621074102917
# test_discrete_score_W0_a 0.014229751609681625
# train_discrete_score_W_discrete_p 0.4051803885291397
# train_discrete_score_W_discrete_n 0.051974405324079466
# train_discrete_score_W_discrete_a 0.04816510675613332
# test_discrete_score_W_discrete_p 0.4470842332613391
# test_discrete_score_W_discrete_n 0.0653312090247907
# test_discrete_score_W_discrete_a 0.06678756526923614
# neuron unit number: 26
# train_discrete_score_W0_p 0.3603145235892692
# train_discrete_score_W0_n 0.00706336353434236
# train_discrete_score_W0_a  0.015600835270627516
# test_discrete_score_W0_p 0.42116630669546434
# test_discrete_score_W0_n 0.013518492011417972
# test_discrete_score_W0_a 0.01941375063046267
# train_discrete_score_W_discrete_p 0.408418131359852
# train_discrete_score_W_discrete_n 0.052327242349565296
# train_discrete_score_W_discrete_a 0.04591123974905137
# test_discrete_score_W_discrete_p 0.4632829373650108
# test_discrete_score_W_discrete_n 0.07348684008358429
# test_discrete_score_W_discrete_a 0.07698412295273645
# neuron unit number: 27
# train_discrete_score_W0_p 0.35892691951896394
# train_discrete_score_W0_n 0.003587664112036211
# train_discrete_score_W0_a  0.003781880346356919
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.012489526892896622
# test_discrete_score_W0_a 0.02107337554365334
# train_discrete_score_W_discrete_p 0.4047178538390379
# train_discrete_score_W_discrete_n 0.051250641971975285
# train_discrete_score_W_discrete_a 0.047059634460618546
# test_discrete_score_W_discrete_p 0.4514038876889849
# test_discrete_score_W_discrete_n 0.07053668315482937
# test_discrete_score_W_discrete_a 0.07072379931493487
# neuron unit number: 28
# train_discrete_score_W0_p 0.36632747456059206
# train_discrete_score_W0_n 0.004828345663928062
# train_discrete_score_W0_a  0.009023147016067969
# test_discrete_score_W0_p 0.4244060475161987
# test_discrete_score_W0_n 0.014005803245923177
# test_discrete_score_W0_a 0.02004127393558119
# train_discrete_score_W_discrete_p 0.40009250693802034
# train_discrete_score_W_discrete_n 0.04565827597761123
# train_discrete_score_W_discrete_a 0.04596535850456926
# test_discrete_score_W_discrete_p 0.4535637149028078
# test_discrete_score_W_discrete_n 0.06084557714436825
# test_discrete_score_W_discrete_a 0.06842283439154118
# neuron unit number: 29
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.004925018084130906
# train_discrete_score_W0_a  0.008130126008835935
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.016708986684584776
# test_discrete_score_W0_a 0.012658301528203717
# train_discrete_score_W_discrete_p 0.40749306197964846
# train_discrete_score_W_discrete_n 0.04526554083297622
# train_discrete_score_W_discrete_a 0.044466090184125714
# test_discrete_score_W_discrete_p 0.46220302375809935
# test_discrete_score_W_discrete_n 0.07050321994195821
# test_discrete_score_W_discrete_a 0.07184290416041546
# neuron unit number: 30
# train_discrete_score_W0_p 0.36864014801110084
# train_discrete_score_W0_n 0.006096844522649872
# train_discrete_score_W0_a  0.009673993652684511
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.011156819770712104
# test_discrete_score_W0_a 0.00013956155274008305
# train_discrete_score_W_discrete_p 0.408418131359852
# train_discrete_score_W_discrete_n 0.05317556901653728
# train_discrete_score_W_discrete_a 0.05760682964492653
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.0708364846428071
# test_discrete_score_W_discrete_a 0.07187939763454387
# neuron unit number: 31
# train_discrete_score_W0_p 0.37419056429232195
# train_discrete_score_W0_n 0.006469259359688172
# train_discrete_score_W0_a  0.010770329273874404
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.0035929129942959457
# test_discrete_score_W0_a 0.006564510085179004
# train_discrete_score_W_discrete_p 0.4199814986123959
# train_discrete_score_W_discrete_n 0.06724835397086158
# train_discrete_score_W_discrete_a 0.06275255359310374
# test_discrete_score_W_discrete_p 0.47300215982721383
# test_discrete_score_W_discrete_n 0.09431585659536088
# test_discrete_score_W_discrete_a 0.08250770224488974
# neuron unit number: 32
# train_discrete_score_W0_p 0.37049028677150786
# train_discrete_score_W0_n 0.007120378935224049
# train_discrete_score_W0_a  0.009476417017873346
# test_discrete_score_W0_p 0.4287257019438445
# test_discrete_score_W0_n 0.016351487773482835
# test_discrete_score_W0_a 0.030924193988219346
# train_discrete_score_W_discrete_p 0.406567992599445
# train_discrete_score_W_discrete_n 0.050422352821941255
# train_discrete_score_W_discrete_a 0.04765615902588363
# test_discrete_score_W_discrete_p 0.4611231101511879
# test_discrete_score_W_discrete_n 0.07333656538400397
# test_discrete_score_W_discrete_a 0.07511997253936797
# neuron unit number: 33
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.00714265833483073
# train_discrete_score_W0_a  0.01006294860802955
# test_discrete_score_W0_p 0.4244060475161987
# test_discrete_score_W0_n 0.02030677350393624
# test_discrete_score_W0_a 0.030075337189330177
# train_discrete_score_W_discrete_p 0.4107308048103608
# train_discrete_score_W_discrete_n 0.056628435709484885
# train_discrete_score_W_discrete_a 0.051628772527812665
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.07322146201012573
# test_discrete_score_W_discrete_a 0.07363756238732319
# neuron unit number: 34
# train_discrete_score_W0_p 0.3635522664199815
# train_discrete_score_W0_n 0.006045797902638893
# train_discrete_score_W0_a  0.008824956679355494
# test_discrete_score_W0_p 0.4373650107991361
# test_discrete_score_W0_n 0.01577613926659311
# test_discrete_score_W0_a 0.025761406674083324
# train_discrete_score_W_discrete_p 0.40749306197964846
# train_discrete_score_W_discrete_n 0.04971615174852759
# train_discrete_score_W_discrete_a 0.05033887714146205
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.06120581029912075
# test_discrete_score_W_discrete_a 0.06679629601357075
# neuron unit number: 35
# train_discrete_score_W0_p 0.37465309898242366
# train_discrete_score_W0_n 0.011726195524395995
# train_discrete_score_W0_a  0.02030038319116391
# test_discrete_score_W0_p 0.4222462203023758
# test_discrete_score_W0_n 0.01759834954542581
# test_discrete_score_W0_a 0.023188273185461374
# train_discrete_score_W_discrete_p 0.40888066604995377
# train_discrete_score_W_discrete_n 0.04694779939643553
# train_discrete_score_W_discrete_a 0.04395904847876127
# test_discrete_score_W_discrete_p 0.4632829373650108
# test_discrete_score_W_discrete_n 0.07309216878931647
# test_discrete_score_W_discrete_a 0.07661623801892009
# neuron unit number: 36
# train_discrete_score_W0_p 0.3737280296022202
# train_discrete_score_W0_n 0.007123898490993274
# train_discrete_score_W0_a  0.010213930595889634
# test_discrete_score_W0_p 0.4244060475161987
# test_discrete_score_W0_n 0.014755543023001439
# test_discrete_score_W0_a 0.0189261424142828
# train_discrete_score_W_discrete_p 0.41119333950046255
# train_discrete_score_W_discrete_n 0.05957735512279983
# train_discrete_score_W_discrete_a 0.05258698119737
# test_discrete_score_W_discrete_p 0.490280777537797
# test_discrete_score_W_discrete_n 0.09244995059930876
# test_discrete_score_W_discrete_a 0.09910465591017455
# neuron unit number: 37
# train_discrete_score_W0_p 0.3561517113783534
# train_discrete_score_W0_n 0.0041002712034006105
# train_discrete_score_W0_a  0.00130077431726498
# test_discrete_score_W0_p 0.43088552915766737
# test_discrete_score_W0_n 0.017594994653409326
# test_discrete_score_W0_a 0.018814619252982508
# train_discrete_score_W_discrete_p 0.4116558741905643
# train_discrete_score_W_discrete_n 0.05116399984209074
# train_discrete_score_W_discrete_a 0.053373901758638036
# test_discrete_score_W_discrete_p 0.4719222462203024
# test_discrete_score_W_discrete_n 0.07919295153260922
# test_discrete_score_W_discrete_a 0.07571258782421644
# neuron unit number: 38
# train_discrete_score_W0_p 0.3732654949121184
# train_discrete_score_W0_n 0.008833374837435065
# train_discrete_score_W0_a  0.010756673829438882
# test_discrete_score_W0_p 0.43088552915766737
# test_discrete_score_W0_n 0.01958920783557072
# test_discrete_score_W0_a 0.02779919424552533
# train_discrete_score_W_discrete_p 0.4061054579093432
# train_discrete_score_W_discrete_n 0.03817901421212865
# train_discrete_score_W_discrete_a 0.039609250764886146
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.06578805055911241
# test_discrete_score_W_discrete_a 0.06044573309643224
# neuron unit number: 39
# train_discrete_score_W0_p 0.3755781683626272
# train_discrete_score_W0_n 0.00973396505150043
# train_discrete_score_W0_a  0.012450806699979977
# test_discrete_score_W0_p 0.43412526997840173
# test_discrete_score_W0_n 0.022885023045270663
# test_discrete_score_W0_a 0.02543811264776646
# train_discrete_score_W_discrete_p 0.39916743755781686
# train_discrete_score_W_discrete_n 0.043003120979511
# train_discrete_score_W_discrete_a 0.04473055444766659
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.07450107287389862
# test_discrete_score_W_discrete_a 0.07268941367172609
# neuron unit number: 40
# train_discrete_score_W0_p 0.3737280296022202
# train_discrete_score_W0_n 0.00952399542209651
# train_discrete_score_W0_a  0.013062152179639332
# test_discrete_score_W0_p 0.43952483801295894
# test_discrete_score_W0_n 0.02163549737172806
# test_discrete_score_W0_a 0.026851388749508216
# train_discrete_score_W_discrete_p 0.40795559666975023
# train_discrete_score_W_discrete_n 0.04780669686958828
# train_discrete_score_W_discrete_a 0.04846510573132654
# test_discrete_score_W_discrete_p 0.46760259179265656
# test_discrete_score_W_discrete_n 0.059751234611617
# test_discrete_score_W_discrete_a 0.06983560329148655
# neuron unit number: 41
# train_discrete_score_W0_p 0.3617021276595745
# train_discrete_score_W0_n 0.0031779565081406823
# train_discrete_score_W0_a  0.005520493204897613
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.012242035621345217
# test_discrete_score_W0_a 0.019799435152185414
# train_discrete_score_W_discrete_p 0.4070305272895467
# train_discrete_score_W_discrete_n 0.057207126706439584
# train_discrete_score_W_discrete_a 0.052705880433931124
# test_discrete_score_W_discrete_p 0.47300215982721383
# test_discrete_score_W_discrete_n 0.08667142694450893
# test_discrete_score_W_discrete_a 0.07952448756848603
# neuron unit number: 42
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.005782839070464972
# train_discrete_score_W0_a  0.008352003167063523
# test_discrete_score_W0_p 0.43412526997840173
# test_discrete_score_W0_n 0.02271928571182867
# test_discrete_score_W0_a 0.029178135135034144
# train_discrete_score_W_discrete_p 0.4024051803885291
# train_discrete_score_W_discrete_n 0.048488045704286026
# train_discrete_score_W_discrete_a 0.04521344870612226
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.07352939080767712
# test_discrete_score_W_discrete_a 0.06987737984509462
# neuron unit number: 43
# train_discrete_score_W0_p 0.36308973172987974
# train_discrete_score_W0_n 0.004252728111602715
# train_discrete_score_W0_a  0.007880725274594757
# test_discrete_score_W0_p 0.4190064794816415
# test_discrete_score_W0_n 0.017624917970903035
# test_discrete_score_W0_a 0.02260130445730433
# train_discrete_score_W_discrete_p 0.40980573543015725
# train_discrete_score_W_discrete_n 0.06343193756320091
# train_discrete_score_W_discrete_a 0.05848020172445896
# test_discrete_score_W_discrete_p 0.4708423326133909
# test_discrete_score_W_discrete_n 0.0722880361711515
# test_discrete_score_W_discrete_a 0.0769604461227129
# neuron unit number: 44
# train_discrete_score_W0_p 0.3788159111933395
# train_discrete_score_W0_n 0.011454055858450815
# train_discrete_score_W0_a  0.01787405011572122
# test_discrete_score_W0_p 0.42332613390928725
# test_discrete_score_W0_n 0.019602964217976797
# test_discrete_score_W0_a 0.024798806613178584
# train_discrete_score_W_discrete_p 0.406567992599445
# train_discrete_score_W_discrete_n 0.05311724429315828
# train_discrete_score_W_discrete_a 0.05106220207806965
# test_discrete_score_W_discrete_p 0.47300215982721383
# test_discrete_score_W_discrete_n 0.07829240010680276
# test_discrete_score_W_discrete_a 0.07912623194685098
# neuron unit number: 45
# train_discrete_score_W0_p 0.3732654949121184
# train_discrete_score_W0_n 0.007795302262544526
# train_discrete_score_W0_a  0.012633516439870394
# test_discrete_score_W0_p 0.43412526997840173
# test_discrete_score_W0_n 0.022810732210817107
# test_discrete_score_W0_a 0.019077098364860066
# train_discrete_score_W_discrete_p 0.39916743755781686
# train_discrete_score_W_discrete_n 0.04607113446787293
# train_discrete_score_W_discrete_a 0.042677584009856155
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.059996415867198664
# test_discrete_score_W_discrete_a 0.06324826478013366
# neuron unit number: 46
# train_discrete_score_W0_p 0.3691026827012026
# train_discrete_score_W0_n 0.007871749266024117
# train_discrete_score_W0_a  0.015207621668304605
# test_discrete_score_W0_p 0.43628509719222464
# test_discrete_score_W0_n 0.020492856006901785
# test_discrete_score_W0_a 0.029435871596565195
# train_discrete_score_W_discrete_p 0.4061054579093432
# train_discrete_score_W_discrete_n 0.0527171927096058
# train_discrete_score_W_discrete_a 0.04976705754146753
# test_discrete_score_W_discrete_p 0.4838012958963283
# test_discrete_score_W_discrete_n 0.08328644477614391
# test_discrete_score_W_discrete_a 0.08530216877734671
# neuron unit number: 47
# train_discrete_score_W0_p 0.36493987049028676
# train_discrete_score_W0_n 0.007066372501133838
# train_discrete_score_W0_a  0.007481718365209296
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.010036012246963983
# test_discrete_score_W0_a 0.01499001325368085
# train_discrete_score_W_discrete_p 0.41304347826086957
# train_discrete_score_W_discrete_n 0.05875008609157539
# train_discrete_score_W_discrete_a 0.05891402457862542
# test_discrete_score_W_discrete_p 0.46436285097192226
# test_discrete_score_W_discrete_n 0.06449185985776083
# test_discrete_score_W_discrete_a 0.07128177077148089
# neuron unit number: 48
# train_discrete_score_W0_p 0.3700277520814061
# train_discrete_score_W0_n 0.010192727053935457
# train_discrete_score_W0_a  0.014985973054435005
# test_discrete_score_W0_p 0.4352051835853132
# test_discrete_score_W0_n 0.026861864560111852
# test_discrete_score_W0_a 0.02937888977953012
# train_discrete_score_W_discrete_p 0.40194264569842736
# train_discrete_score_W_discrete_n 0.04325770213890201
# train_discrete_score_W_discrete_a 0.0416757079490195
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.06759279066724858
# test_discrete_score_W_discrete_a 0.06765374464161136
# neuron unit number: 49
# train_discrete_score_W0_p 0.37419056429232195
# train_discrete_score_W0_n 0.008614568736874967
# train_discrete_score_W0_a  0.010579374500624896
# test_discrete_score_W0_p 0.42764578833693306
# test_discrete_score_W0_n 0.020447550220597598
# test_discrete_score_W0_a 0.027516869910157504
# train_discrete_score_W_discrete_p 0.4051803885291397
# train_discrete_score_W_discrete_n 0.0504219136020251
# train_discrete_score_W_discrete_a 0.050854717087415735
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.0789040815814324
# test_discrete_score_W_discrete_a 0.08125694546104706
# neuron unit number: 50
# train_discrete_score_W0_p 0.3866790009250694
# train_discrete_score_W0_n 0.01299611277365538
# train_discrete_score_W0_a  0.02089649201282564
# test_discrete_score_W0_p 0.4265658747300216
# test_discrete_score_W0_n 0.029064079484958493
# test_discrete_score_W0_a 0.031598141983519845
# train_discrete_score_W_discrete_p 0.406567992599445
# train_discrete_score_W_discrete_n 0.05570100156224184
# train_discrete_score_W_discrete_a 0.05377188257400654
# test_discrete_score_W_discrete_p 0.46652267818574517
# test_discrete_score_W_discrete_n 0.08089821328008336
# test_discrete_score_W_discrete_a 0.07992898987654219
# test_discrete_score_W0_p mean 0.41473377781951354
# test_discrete_score_W_discrete_p mean 0.4642454690581275
# test_discrete_score_W0_n mean 0.012751488891823834
# test_discrete_score_W_discrete_n mean 0.07466349673251173
# test_discrete_score_W0_a mean 0.01328477004992316
# test_discrete_score_W_discrete_a mean 0.07495390061898409
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.005528  0.003081  0.000454   0.004613  0.006442
# 1  train_dis_W_dis  46.0  0.053619  0.006300  0.000929   0.051749  0.055490
# 2         combined  92.0  0.029574  0.024676  0.002573   0.024463  0.034684
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0481
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -46.5099
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -9.6980
# 7                                    Hedge's g =   -9.6169
# 8                               Glass's delta1 =  -15.6115
# 9                             Point-Biserial r =   -0.9798
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.012751  0.007197  0.001061   0.010614  0.014889
# 1  test_dis_W_dis  46.0  0.074663  0.008246  0.001216   0.072215  0.077112
# 2        combined  92.0  0.043707  0.032063  0.003343   0.037067  0.050348
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0619
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -38.3638
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.9994
# 7                                  Hedge's g =   -7.9326
# 8                             Glass's delta1 =   -8.6022
# 9                           Point-Biserial r =   -0.9708
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.008838  0.005318  0.000784   0.007258  0.010417
# 1  train_dis_W_dis  46.0  0.051087  0.005813  0.000857   0.049361  0.052813
# 2         combined  92.0  0.029962  0.021951  0.002289   0.025416  0.034508
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0422
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -36.3709
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -7.5839
# 7                                    Hedge's g =   -7.5205
# 8                               Glass's delta1 =   -7.9442
# 9                             Point-Biserial r =   -0.9676
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.013285  0.012150  0.001791   0.009677  0.016893
# 1  test_dis_W_dis  46.0  0.074954  0.007377  0.001088   0.072763  0.077145
# 2        combined  92.0  0.044119  0.032575  0.003396   0.037373  0.050865
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0617
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -29.4249
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.1355
# 7                                  Hedge's g =   -6.0842
# 8                             Glass's delta1 =   -5.0756
# 9                           Point-Biserial r =   -0.9518
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.362929  0.010210  0.001505   0.359897  0.365961
# 1  train_dis_W_dis  46.0  0.408579  0.004742  0.000699   0.407171  0.409987
# 2         combined  92.0  0.385754  0.024277  0.002531   0.380726  0.390782
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0457
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -27.5019
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -5.7345
# 7                                    Hedge's g =   -5.6866
# 8                               Glass's delta1 =   -4.4710
# 9                             Point-Biserial r =   -0.9453
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.414734  0.013899  0.002049   0.410606  0.418861
# 1  test_dis_W_dis  46.0  0.464245  0.010283  0.001516   0.461192  0.467299
# 2        combined  92.0  0.439490  0.027702  0.002888   0.433753  0.445227
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0495
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -19.4226
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -4.0499
# 7                                  Hedge's g =   -4.0160
# 8                             Glass's delta1 =   -3.5623
# 9                           Point-Biserial r =   -0.8985

# %%
 #new baseN endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.42645698427382056
# train_discrete_score_W_discrete_n 0.057872952133865244
# train_discrete_score_W_discrete_a 0.06295021412240599
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.07535730573423359
# test_discrete_score_W_discrete_a 0.07750880686953963
# neuron unit number: 6
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.36825053995680346
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.42923219241443106
# train_discrete_score_W_discrete_n 0.05798608164328186
# train_discrete_score_W_discrete_a 0.06488953875418606
# test_discrete_score_W_discrete_p 0.44600431965442766
# test_discrete_score_W_discrete_n 0.0746389139318743
# test_discrete_score_W_discrete_a 0.06771915613181394
# neuron unit number: 7
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.002243772975268505
# test_discrete_score_W0_a 0.0038286694523058155
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.06385978803348961
# train_discrete_score_W_discrete_a 0.0652944871019074
# test_discrete_score_W_discrete_p 0.4654427645788337
# test_discrete_score_W_discrete_n 0.08953785457840138
# test_discrete_score_W_discrete_a 0.08426347050627421
# neuron unit number: 8
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.003639595005579567
# test_discrete_score_W0_a 0.0015719842191941659
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.05982581453687158
# train_discrete_score_W_discrete_a 0.06300986438201149
# test_discrete_score_W_discrete_p 0.43844492440604754
# test_discrete_score_W_discrete_n 0.07247899428759157
# test_discrete_score_W_discrete_a 0.07112498817027446
# neuron unit number: 9
# train_discrete_score_W0_p 0.3681776133209991
# train_discrete_score_W0_n 0.000904455244371039
# train_discrete_score_W0_a  -0.0007130926008416701
# test_discrete_score_W0_p 0.3714902807775378
# test_discrete_score_W0_n 0.0016307921678644498
# test_discrete_score_W0_a 0.004531853385160286
# train_discrete_score_W_discrete_p 0.4213691026827012
# train_discrete_score_W_discrete_n 0.0618282243908286
# train_discrete_score_W_discrete_a 0.06280723401575858
# test_discrete_score_W_discrete_p 0.4352051835853132
# test_discrete_score_W_discrete_n 0.06927453424394786
# test_discrete_score_W_discrete_a 0.06362888268640773
# neuron unit number: 10
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0013375339256549434
# test_discrete_score_W0_a 0.0008887501733854037
# train_discrete_score_W_discrete_p 0.42738205365402404
# train_discrete_score_W_discrete_n 0.06296292542556703
# train_discrete_score_W_discrete_a 0.06652986295355393
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.06913318138791691
# test_discrete_score_W_discrete_a 0.07690661593412995
# neuron unit number: 11
# train_discrete_score_W0_p 0.3681776133209991
# train_discrete_score_W0_n 0.0019057076382878694
# train_discrete_score_W0_a  0.007293511101722928
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.004061306522567185
# test_discrete_score_W0_a 0.002959896968830121
# train_discrete_score_W_discrete_p 0.42321924144310824
# train_discrete_score_W_discrete_n 0.0604879820222523
# train_discrete_score_W_discrete_a 0.06672547321622943
# test_discrete_score_W_discrete_p 0.4449244060475162
# test_discrete_score_W_discrete_n 0.06630029667915287
# test_discrete_score_W_discrete_a 0.07170211100235638
# neuron unit number: 12
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.002366067000758954
# test_discrete_score_W0_a 0.0017812807198819187
# train_discrete_score_W_discrete_p 0.42738205365402404
# train_discrete_score_W_discrete_n 0.06170670786472044
# train_discrete_score_W_discrete_a 0.06653298481748231
# test_discrete_score_W_discrete_p 0.45680345572354214
# test_discrete_score_W_discrete_n 0.07219868089402444
# test_discrete_score_W_discrete_a 0.07926960176178648
# neuron unit number: 13
# train_discrete_score_W0_p 0.3691026827012026
# train_discrete_score_W0_n 0.0027005659954660536
# train_discrete_score_W0_a  -0.001457696704601308
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.004645300390048318
# test_discrete_score_W0_a 0.007646943041381797
# train_discrete_score_W_discrete_p 0.4278445883441258
# train_discrete_score_W_discrete_n 0.05671490637729925
# train_discrete_score_W_discrete_a 0.060696026864970026
# test_discrete_score_W_discrete_p 0.4632829373650108
# test_discrete_score_W_discrete_n 0.08488381334413604
# test_discrete_score_W_discrete_a 0.07610938611663375
# neuron unit number: 14
# train_discrete_score_W0_p 0.3700277520814061
# train_discrete_score_W0_n 0.0031815763077369945
# train_discrete_score_W0_a  0.008274903306388888
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0039281360366500324
# test_discrete_score_W0_a 0.006540309112377982
# train_discrete_score_W_discrete_p 0.41859389454209067
# train_discrete_score_W_discrete_n 0.056133205022243636
# train_discrete_score_W_discrete_a 0.06206906283614196
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.07828469976038696
# test_discrete_score_W_discrete_a 0.07383470885748096
# neuron unit number: 15
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.3693304535637149
# test_discrete_score_W0_n 0.0023745996061850026
# test_discrete_score_W0_a 0.0021065078580694997
# train_discrete_score_W_discrete_p 0.4227567067530065
# train_discrete_score_W_discrete_n 0.058746008100737476
# train_discrete_score_W_discrete_a 0.06628523464098714
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.061953486247845836
# test_discrete_score_W_discrete_a 0.0698436600763726
# neuron unit number: 16
# train_discrete_score_W0_p 0.3691026827012026
# train_discrete_score_W0_n 0.0016892784220801512
# train_discrete_score_W0_a  0.0032576688071647548
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.010912790026515384
# test_discrete_score_W0_a 0.01349868902106277
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.053981690435061014
# train_discrete_score_W_discrete_a 0.06021009680044039
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.0755593839318381
# test_discrete_score_W_discrete_a 0.07694108552338974
# neuron unit number: 17
# train_discrete_score_W0_p 0.3681776133209991
# train_discrete_score_W0_n 0.0016017315659303095
# train_discrete_score_W0_a  -0.0015236751884521798
# test_discrete_score_W0_p 0.3758099352051836
# test_discrete_score_W0_n 0.005778083656097912
# test_discrete_score_W0_a 0.006454584229576685
# train_discrete_score_W_discrete_p 0.4283071230342276
# train_discrete_score_W_discrete_n 0.06998790806721084
# train_discrete_score_W_discrete_a 0.07370334978186953
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.0724106756148437
# test_discrete_score_W_discrete_a 0.07144189786604842
# neuron unit number: 18
# train_discrete_score_W0_p 0.36864014801110084
# train_discrete_score_W0_n 0.001579240610538071
# train_discrete_score_W0_a  -0.002285956369078256
# test_discrete_score_W0_p 0.38120950323974084
# test_discrete_score_W0_n 0.012555184027752287
# test_discrete_score_W0_a 0.018640370136898392
# train_discrete_score_W_discrete_p 0.42506938020351526
# train_discrete_score_W_discrete_n 0.06213819778780273
# train_discrete_score_W_discrete_a 0.06607700074101508
# test_discrete_score_W_discrete_p 0.45788336933045354
# test_discrete_score_W_discrete_n 0.07829288009019966
# test_discrete_score_W_discrete_a 0.08122949664604472
# neuron unit number: 19
# train_discrete_score_W0_p 0.3709528214616096
# train_discrete_score_W0_n 0.0033187252202170987
# train_discrete_score_W0_a  -0.0020813983795664403
# test_discrete_score_W0_p 0.3898488120950324
# test_discrete_score_W0_n 0.008927491889204756
# test_discrete_score_W0_a 0.017664160077127046
# train_discrete_score_W_discrete_p 0.42321924144310824
# train_discrete_score_W_discrete_n 0.05814129739395329
# train_discrete_score_W_discrete_a 0.06557551461277475
# test_discrete_score_W_discrete_p 0.4470842332613391
# test_discrete_score_W_discrete_n 0.07163643121214004
# test_discrete_score_W_discrete_a 0.07642307428619594
# neuron unit number: 20
# train_discrete_score_W0_p 0.36864014801110084
# train_discrete_score_W0_n 0.002757576169629532
# train_discrete_score_W0_a  0.0064919031387216004
# test_discrete_score_W0_p 0.37688984881209503
# test_discrete_score_W0_n 0.00882900341126477
# test_discrete_score_W0_a 0.00834267431550176
# train_discrete_score_W_discrete_p 0.41905642923219244
# train_discrete_score_W_discrete_n 0.05880396630375951
# train_discrete_score_W_discrete_a 0.0654444538895723
# test_discrete_score_W_discrete_p 0.43412526997840173
# test_discrete_score_W_discrete_n 0.06197061764848029
# test_discrete_score_W_discrete_a 0.06838862258300199
# neuron unit number: 21
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0006057758956395463
# train_discrete_score_W0_a  0.000881596747603579
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.009184915631548426
# test_discrete_score_W0_a 0.019943542302369513
# train_discrete_score_W_discrete_p 0.42645698427382056
# train_discrete_score_W_discrete_n 0.06338493789573964
# train_discrete_score_W_discrete_a 0.06703312335085883
# test_discrete_score_W_discrete_p 0.4514038876889849
# test_discrete_score_W_discrete_n 0.07518190039776647
# test_discrete_score_W_discrete_a 0.0810264449171276
# neuron unit number: 22
# train_discrete_score_W0_p 0.37465309898242366
# train_discrete_score_W0_n 0.0037465929860718986
# train_discrete_score_W0_a  0.007057384804614265
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.009292294105077011
# test_discrete_score_W0_a 0.016839175759772583
# train_discrete_score_W_discrete_p 0.4320074005550416
# train_discrete_score_W_discrete_n 0.06786531499766775
# train_discrete_score_W_discrete_a 0.0730019991261293
# test_discrete_score_W_discrete_p 0.45680345572354214
# test_discrete_score_W_discrete_n 0.0665757170237005
# test_discrete_score_W_discrete_a 0.07320325953665742
# neuron unit number: 23
# train_discrete_score_W0_p 0.3714153561517114
# train_discrete_score_W0_n 0.0031564353939894066
# train_discrete_score_W0_a  0.0065177106872904966
# test_discrete_score_W0_p 0.3930885529157667
# test_discrete_score_W0_n 0.008755013743806599
# test_discrete_score_W0_a 0.011584992018626696
# train_discrete_score_W_discrete_p 0.4222941720629047
# train_discrete_score_W_discrete_n 0.05795928164011944
# train_discrete_score_W_discrete_a 0.06435356490576169
# test_discrete_score_W_discrete_p 0.4406047516198704
# test_discrete_score_W_discrete_n 0.05857030985870554
# test_discrete_score_W_discrete_a 0.06757121258198784
# neuron unit number: 24
# train_discrete_score_W0_p 0.3723404255319149
# train_discrete_score_W0_n 0.0018952204749980168
# train_discrete_score_W0_a  -0.00021757257188736046
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.009019421953794113
# test_discrete_score_W0_a 0.011072357298278561
# train_discrete_score_W_discrete_p 0.4324699352451434
# train_discrete_score_W_discrete_n 0.06121011533280299
# train_discrete_score_W_discrete_a 0.07049800643772239
# test_discrete_score_W_discrete_p 0.4514038876889849
# test_discrete_score_W_discrete_n 0.07897942698612388
# test_discrete_score_W_discrete_a 0.0860553610126943
# neuron unit number: 25
# train_discrete_score_W0_p 0.37280296022201664
# train_discrete_score_W0_n 0.0022600680475590527
# train_discrete_score_W0_a  -0.00020302662855465023
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.013531330183059414
# test_discrete_score_W0_a 0.01728861909575524
# train_discrete_score_W_discrete_p 0.42090656799259946
# train_discrete_score_W_discrete_n 0.05926809964324359
# train_discrete_score_W_discrete_a 0.06371835279671696
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.06294058691257463
# test_discrete_score_W_discrete_a 0.06679635802284557
# neuron unit number: 26
# train_discrete_score_W0_p 0.37049028677150786
# train_discrete_score_W0_n 0.0034504591413623345
# train_discrete_score_W0_a  0.006877197651465898
# test_discrete_score_W0_p 0.38876889848812096
# test_discrete_score_W0_n 0.011447486994701194
# test_discrete_score_W0_a 0.01646474163723734
# train_discrete_score_W_discrete_p 0.42876965772432934
# train_discrete_score_W_discrete_n 0.05800220789783691
# train_discrete_score_W_discrete_a 0.06522175840342513
# test_discrete_score_W_discrete_p 0.46436285097192226
# test_discrete_score_W_discrete_n 0.07544349494402326
# test_discrete_score_W_discrete_a 0.08191394424458028
# neuron unit number: 27
# train_discrete_score_W0_p 0.3700277520814061
# train_discrete_score_W0_n 0.0018755752593619982
# train_discrete_score_W0_a  -0.0012146029559892617
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.010294614262873735
# test_discrete_score_W0_a 0.015732920423549526
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.057702930715935526
# train_discrete_score_W_discrete_a 0.06363408450610228
# test_discrete_score_W_discrete_p 0.4535637149028078
# test_discrete_score_W_discrete_n 0.07607834470284659
# test_discrete_score_W_discrete_a 0.08323880922414918
# neuron unit number: 28
# train_discrete_score_W0_p 0.37419056429232195
# train_discrete_score_W0_n 0.0037968278801865907
# train_discrete_score_W0_a  0.001993118141888989
# test_discrete_score_W0_p 0.3898488120950324
# test_discrete_score_W0_n 0.01637638277887644
# test_discrete_score_W0_a 0.02213035705458167
# train_discrete_score_W_discrete_p 0.42506938020351526
# train_discrete_score_W_discrete_n 0.058428965060424984
# train_discrete_score_W_discrete_a 0.062090148099785594
# test_discrete_score_W_discrete_p 0.4611231101511879
# test_discrete_score_W_discrete_n 0.087180810453783
# test_discrete_score_W_discrete_a 0.08971497387427724
# neuron unit number: 29
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0010626818194057058
# train_discrete_score_W0_a  0.004603584494129502
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.005878873855342928
# test_discrete_score_W0_a 0.011343704268486023
# train_discrete_score_W_discrete_p 0.4246068455134135
# train_discrete_score_W_discrete_n 0.06251340967741807
# train_discrete_score_W_discrete_a 0.06547351127717911
# test_discrete_score_W_discrete_p 0.44600431965442766
# test_discrete_score_W_discrete_n 0.07565938566253623
# test_discrete_score_W_discrete_a 0.07236435750673205
# neuron unit number: 30
# train_discrete_score_W0_p 0.37465309898242366
# train_discrete_score_W0_n 0.004781709934143697
# train_discrete_score_W0_a  0.009685181212548806
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.009406751706615554
# test_discrete_score_W0_a 0.010490000356692402
# train_discrete_score_W_discrete_p 0.4269195189639223
# train_discrete_score_W_discrete_n 0.057453929828463327
# train_discrete_score_W_discrete_a 0.06369515945560666
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.07536695345439215
# test_discrete_score_W_discrete_a 0.07743276457640554
# neuron unit number: 31
# train_discrete_score_W0_p 0.36864014801110084
# train_discrete_score_W0_n 0.0023778800471905043
# train_discrete_score_W0_a  0.002082325803453775
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.005403112712065125
# test_discrete_score_W0_a 0.012524216803863914
# train_discrete_score_W_discrete_p 0.42738205365402404
# train_discrete_score_W_discrete_n 0.060754084883714234
# train_discrete_score_W_discrete_a 0.06455816239211691
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.07287868688826413
# test_discrete_score_W_discrete_a 0.07817106767410564
# neuron unit number: 32
# train_discrete_score_W0_p 0.3737280296022202
# train_discrete_score_W0_n 0.0037630926162389696
# train_discrete_score_W0_a  0.007901200393679083
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.022131384240726325
# test_discrete_score_W0_a 0.0324230295697469
# train_discrete_score_W_discrete_p 0.43293246993524515
# train_discrete_score_W_discrete_n 0.06426152400680894
# train_discrete_score_W_discrete_a 0.07163794369777142
# test_discrete_score_W_discrete_p 0.4535637149028078
# test_discrete_score_W_discrete_n 0.0728199243988814
# test_discrete_score_W_discrete_a 0.07774116401011232
# neuron unit number: 33
# train_discrete_score_W0_p 0.3755781683626272
# train_discrete_score_W0_n 0.004647046927242755
# train_discrete_score_W0_a  0.007211972814550308
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.012815770329321118
# test_discrete_score_W0_a 0.013075695366377172
# train_discrete_score_W_discrete_p 0.4278445883441258
# train_discrete_score_W_discrete_n 0.06683085697442533
# train_discrete_score_W_discrete_a 0.07017598717567745
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.08037363893981049
# test_discrete_score_W_discrete_a 0.07733643009303816
# neuron unit number: 34
# train_discrete_score_W0_p 0.3723404255319149
# train_discrete_score_W0_n 0.004962597573194658
# train_discrete_score_W0_a  0.001532942275564959
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.023219675031270075
# test_discrete_score_W0_a 0.025570810600471075
# train_discrete_score_W_discrete_p 0.42321924144310824
# train_discrete_score_W_discrete_n 0.05639936290011188
# train_discrete_score_W_discrete_a 0.06267794958692746
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.0754748658646833
# test_discrete_score_W_discrete_a 0.07806299088022488
# neuron unit number: 35
# train_discrete_score_W0_p 0.37280296022201664
# train_discrete_score_W0_n 0.005094007889589531
# train_discrete_score_W0_a  0.006826070641359265
# test_discrete_score_W0_p 0.4060475161987041
# test_discrete_score_W0_n 0.015160565678888722
# test_discrete_score_W0_a 0.019227632656864325
# train_discrete_score_W_discrete_p 0.4241443108233117
# train_discrete_score_W_discrete_n 0.06487938618427197
# train_discrete_score_W_discrete_a 0.06908879144417764
# test_discrete_score_W_discrete_p 0.4427645788336933
# test_discrete_score_W_discrete_n 0.06969794664474845
# test_discrete_score_W_discrete_a 0.07578704928295238
# neuron unit number: 36
# train_discrete_score_W0_p 0.377890841813136
# train_discrete_score_W0_n 0.004649870389320652
# train_discrete_score_W0_a  0.005039196258323298
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.01895557665885043
# test_discrete_score_W0_a 0.027063687941362935
# train_discrete_score_W_discrete_p 0.4296947271045328
# train_discrete_score_W_discrete_n 0.06267705177022907
# train_discrete_score_W_discrete_a 0.06508218615338898
# test_discrete_score_W_discrete_p 0.45680345572354214
# test_discrete_score_W_discrete_n 0.07572191635709905
# test_discrete_score_W_discrete_a 0.0863769049229414
# neuron unit number: 37
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.0023259213380002076
# train_discrete_score_W0_a  -0.0012656242866335027
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.011004348670587588
# test_discrete_score_W0_a 0.008515741287226902
# train_discrete_score_W_discrete_p 0.4301572617946346
# train_discrete_score_W_discrete_n 0.059788917873690194
# train_discrete_score_W_discrete_a 0.061785418470209345
# test_discrete_score_W_discrete_p 0.4514038876889849
# test_discrete_score_W_discrete_n 0.07129300691542995
# test_discrete_score_W_discrete_a 0.07977890572936011
# neuron unit number: 38
# train_discrete_score_W0_p 0.37650323774283073
# train_discrete_score_W0_n 0.004275998409424436
# train_discrete_score_W0_a  0.004686554800172146
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.01932604099132443
# test_discrete_score_W0_a 0.032329204703466646
# train_discrete_score_W_discrete_p 0.4222941720629047
# train_discrete_score_W_discrete_n 0.05778988862102358
# train_discrete_score_W_discrete_a 0.06538583657938395
# test_discrete_score_W_discrete_p 0.4406047516198704
# test_discrete_score_W_discrete_n 0.0697027963668623
# test_discrete_score_W_discrete_a 0.07202280836592308
# neuron unit number: 39
# train_discrete_score_W0_p 0.3737280296022202
# train_discrete_score_W0_n 0.003887328695377264
# train_discrete_score_W0_a  0.009832215353027064
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.02482298816543974
# test_discrete_score_W0_a 0.03241712730405208
# train_discrete_score_W_discrete_p 0.42321924144310824
# train_discrete_score_W_discrete_n 0.055482041535863766
# train_discrete_score_W_discrete_a 0.060668538939642754
# test_discrete_score_W_discrete_p 0.43952483801295894
# test_discrete_score_W_discrete_n 0.07047084984923165
# test_discrete_score_W_discrete_a 0.07151430551586936
# neuron unit number: 40
# train_discrete_score_W0_p 0.37187789084181316
# train_discrete_score_W0_n 0.0029086575440417936
# train_discrete_score_W0_a  0.0031736929220885835
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.023943131520911216
# test_discrete_score_W0_a 0.03591256529206267
# train_discrete_score_W_discrete_p 0.4204440333024977
# train_discrete_score_W_discrete_n 0.057582350035198446
# train_discrete_score_W_discrete_a 0.0607793577063649
# test_discrete_score_W_discrete_p 0.44924406047516197
# test_discrete_score_W_discrete_n 0.06528859728010158
# test_discrete_score_W_discrete_a 0.07421598114740609
# neuron unit number: 41
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.004197417398165593
# train_discrete_score_W0_a  0.0002724721887324471
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.009890977562629433
# test_discrete_score_W0_a 0.019899494377244354
# train_discrete_score_W_discrete_p 0.4357076780758557
# train_discrete_score_W_discrete_n 0.05944183863837978
# train_discrete_score_W_discrete_a 0.06588482924018467
# test_discrete_score_W_discrete_p 0.46004319654427644
# test_discrete_score_W_discrete_n 0.07930815845718031
# test_discrete_score_W_discrete_a 0.08130550914617007
# neuron unit number: 42
# train_discrete_score_W0_p 0.37465309898242366
# train_discrete_score_W0_n 0.0028393116406258
# train_discrete_score_W0_a  0.0019886547898071982
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.01617990053254448
# test_discrete_score_W0_a 0.02142367005680452
# train_discrete_score_W_discrete_p 0.42923219241443106
# train_discrete_score_W_discrete_n 0.063904964242481
# train_discrete_score_W_discrete_a 0.0696534941298739
# test_discrete_score_W_discrete_p 0.4481641468682505
# test_discrete_score_W_discrete_n 0.06966618892469845
# test_discrete_score_W_discrete_a 0.0717756835380789
# neuron unit number: 43
# train_discrete_score_W0_p 0.3732654949121184
# train_discrete_score_W0_n 0.00283536903879051
# train_discrete_score_W0_a  -0.00020168365555312554
# test_discrete_score_W0_p 0.38444924406047515
# test_discrete_score_W0_n 0.011500467617180953
# test_discrete_score_W0_a 0.011579356063543567
# train_discrete_score_W_discrete_p 0.42368177613321
# train_discrete_score_W_discrete_n 0.060082367790872115
# train_discrete_score_W_discrete_a 0.06527003719956753
# test_discrete_score_W_discrete_p 0.44168466522678185
# test_discrete_score_W_discrete_n 0.0789038964821395
# test_discrete_score_W_discrete_a 0.07160896955492442
# neuron unit number: 44
# train_discrete_score_W0_p 0.3866790009250694
# train_discrete_score_W0_n 0.008214718849719166
# train_discrete_score_W0_a  0.012311280415461397
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.019103054125191938
# test_discrete_score_W0_a 0.025320967294397537
# train_discrete_score_W_discrete_p 0.4296947271045328
# train_discrete_score_W_discrete_n 0.059852765478988164
# train_discrete_score_W_discrete_a 0.06980834041041839
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.07424388286220553
# test_discrete_score_W_discrete_a 0.07659887758953673
# neuron unit number: 45
# train_discrete_score_W0_p 0.38066604995374653
# train_discrete_score_W0_n 0.007387766120108931
# train_discrete_score_W0_a  0.005834705536115501
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.02172533437878144
# test_discrete_score_W0_a 0.02816736578819188
# train_discrete_score_W_discrete_p 0.4227567067530065
# train_discrete_score_W_discrete_n 0.05797405508137724
# train_discrete_score_W_discrete_a 0.06321664236817573
# test_discrete_score_W_discrete_p 0.4470842332613391
# test_discrete_score_W_discrete_n 0.0796555190739727
# test_discrete_score_W_discrete_a 0.07839241695644805
# neuron unit number: 46
# train_discrete_score_W0_p 0.3774283071230342
# train_discrete_score_W0_n 0.007015734197902892
# train_discrete_score_W0_a  0.0032565789941052603
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.01953911170576048
# test_discrete_score_W0_a 0.023244519779551696
# train_discrete_score_W_discrete_p 0.42876965772432934
# train_discrete_score_W_discrete_n 0.059456809306905396
# train_discrete_score_W_discrete_a 0.0668047559298997
# test_discrete_score_W_discrete_p 0.45788336933045354
# test_discrete_score_W_discrete_n 0.06690041868245272
# test_discrete_score_W_discrete_a 0.07952016729325145
# neuron unit number: 47
# train_discrete_score_W0_p 0.3677150786308973
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.3833693304535637
# test_discrete_score_W0_n 0.004379647155582787
# test_discrete_score_W0_a 0.005643305104745914
# train_discrete_score_W_discrete_p 0.4320074005550416
# train_discrete_score_W_discrete_n 0.06887846082084907
# train_discrete_score_W_discrete_a 0.07359921175042997
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.07569587826676907
# test_discrete_score_W_discrete_a 0.08384312633388485
# neuron unit number: 48
# train_discrete_score_W0_p 0.37835337650323775
# train_discrete_score_W0_n 0.006756308601781305
# train_discrete_score_W0_a  0.008466633495663296
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.02777218775153227
# test_discrete_score_W0_a 0.04072632845497046
# train_discrete_score_W_discrete_p 0.4148936170212766
# train_discrete_score_W_discrete_n 0.053946997484973856
# train_discrete_score_W_discrete_a 0.056851683051225045
# test_discrete_score_W_discrete_p 0.4524838012958963
# test_discrete_score_W_discrete_n 0.06560483328644758
# test_discrete_score_W_discrete_a 0.07932433184832038
# neuron unit number: 49
# train_discrete_score_W0_p 0.3811285846438483
# train_discrete_score_W0_n 0.013987396868828205
# train_discrete_score_W0_a  0.004511955723456969
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.021296077464308262
# test_discrete_score_W0_a 0.027442315185764777
# train_discrete_score_W_discrete_p 0.4324699352451434
# train_discrete_score_W_discrete_n 0.07205500353532641
# train_discrete_score_W_discrete_a 0.07206691959966079
# test_discrete_score_W_discrete_p 0.4503239740820734
# test_discrete_score_W_discrete_n 0.07311097646476164
# test_discrete_score_W_discrete_a 0.08354620889734472
# neuron unit number: 50
# train_discrete_score_W0_p 0.3820536540240518
# train_discrete_score_W0_n 0.010189866318941365
# train_discrete_score_W0_a  0.019127681213195337
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.019934840389647993
# test_discrete_score_W0_a 0.02073376773655433
# train_discrete_score_W_discrete_p 0.41350601295097134
# train_discrete_score_W_discrete_n 0.054595921695777976
# train_discrete_score_W_discrete_a 0.059417746043069215
# test_discrete_score_W_discrete_p 0.43844492440604754
# test_discrete_score_W_discrete_n 0.058038545131410775
# test_discrete_score_W_discrete_a 0.059713873771484856
# test_discrete_score_W0_p mean 0.3879707014743169
# test_discrete_score_W_discrete_p mean 0.4503474504648324
# test_discrete_score_W0_n mean 0.011402629011731572
# test_discrete_score_W_discrete_n mean 0.07284215667653514
# test_discrete_score_W0_a mean 0.015491040962899279
# test_discrete_score_W_discrete_a mean 0.07613673528405622
# NMI T-Test
#           Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.00323  0.002853  0.000421   0.002383  0.004077
# 1  train_dis_W_dis  46.0  0.06047  0.004099  0.000604   0.059252  0.061687
# 2         combined  92.0  0.03185  0.028990  0.003022   0.025846  0.037854
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0572
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -77.7384
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -16.2096
# 7                                    Hedge's g =  -16.0741
# 8                               Glass's delta1 =  -20.0612
# 9                             Point-Biserial r =   -0.9926
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.011403  0.007545  0.001112   0.009162  0.013643
# 1  test_dis_W_dis  46.0  0.072842  0.006730  0.000992   0.070844  0.074841
# 2        combined  92.0  0.042122  0.031696  0.003305   0.035558  0.048686
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0614
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -41.2135
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.5936
# 7                                  Hedge's g =   -8.5218
# 8                             Glass's delta1 =   -8.1427
# 9                           Point-Biserial r =   -0.9745
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.003388  0.004481  0.000661   0.002057  0.004718
# 1  train_dis_W_dis  46.0  0.065477  0.003847  0.000567   0.064334  0.066619
# 2         combined  92.0  0.034432  0.031490  0.003283   0.027911  0.040954
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0621
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -71.3048
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -14.8681
# 7                                    Hedge's g =  -14.7438
# 8                               Glass's delta1 =  -13.8560
# 9                             Point-Biserial r =   -0.9913
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.015491  0.010525  0.001552   0.012365  0.018617
# 1  test_dis_W_dis  46.0  0.076137  0.006198  0.000914   0.074296  0.077977
# 2        combined  92.0  0.045814  0.031676  0.003302   0.039254  0.052374
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0606
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -33.6739
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -7.0215
# 7                                  Hedge's g =   -6.9628
# 8                             Glass's delta1 =   -5.7619
# 9                           Point-Biserial r =   -0.9625
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.372079  0.004607  0.000679   0.370711  0.373447
# 1  train_dis_W_dis  46.0  0.425542  0.004686  0.000691   0.424150  0.426934
# 2         combined  92.0  0.398810  0.027272  0.002843   0.393163  0.404458
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0535
# 1                           Degrees of freedom =   90.0000
# 2                                            t =  -55.1758
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -11.5050
# 7                                    Hedge's g =  -11.4088
# 8                               Glass's delta1 =  -11.6035
# 9                             Point-Biserial r =   -0.9855
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.387971  0.012817  0.001890   0.384165  0.391777
# 1  test_dis_W_dis  46.0  0.450347  0.007736  0.001141   0.448050  0.452645
# 2        combined  92.0  0.419159  0.033079  0.003449   0.412309  0.426010
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0624
# 1                         Degrees of freedom =   90.0000
# 2                                          t =  -28.2595
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -5.8925
# 7                                  Hedge's g =   -5.8433
# 8                             Glass's delta1 =   -4.8667
# 9                           Point-Biserial r =   -0.9480
