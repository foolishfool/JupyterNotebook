# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")
# Out:
# self.continuous_feature_num 3
# self.data_discrete_indexes ['Monthly Revenue', 'Country', 'Gender', 'Device']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 8)
# accuracy_score_sog 0.448
# recall_score_sog 0.4459302690072493
# precision_score_sog 0.47696210762900765
# f1_score_sog 0.3917765112194867
# neuron unit number: 7
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 28)
# accuracy_score_sog 0.496
# recall_score_sog 0.49229413409497064
# precision_score_sog 0.47180674358356933
# f1_score_sog 0.4740376516667148
# neuron unit number: 12
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 48)
# accuracy_score_sog 0.47333333333333333
# recall_score_sog 0.48323829181164574
# precision_score_sog 0.4942039168052672
# f1_score_sog 0.46868784255875645
# neuron unit number: 17
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 68)
# accuracy_score_sog 0.572
# recall_score_sog 0.57882725231613
# precision_score_sog 0.5838985330818361
# f1_score_sog 0.5712777777777778
# neuron unit number: 22
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 88)
# accuracy_score_sog 0.5133333333333333
# recall_score_sog 0.5317323738992762
# precision_score_sog 0.5935399529829469
# f1_score_sog 0.5085643039474211
# neuron unit number: 27
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 108)
# accuracy_score_sog 0.5453333333333333
# recall_score_sog 0.5557905761777233
# precision_score_sog 0.5653392834575359
# f1_score_sog 0.5447572586474849
# neuron unit number: 32
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 128)
# accuracy_score_sog 0.5066666666666667
# recall_score_sog 0.5206298465661646
# precision_score_sog 0.7501017501017501
# f1_score_sog 0.47882435412997754
# neuron unit number: 37
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 148)
# accuracy_score_sog 0.564
# recall_score_sog 0.5712511872304707
# precision_score_sog 0.590899933488345
# f1_score_sog 0.5658629844347504
# neuron unit number: 42
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 168)
# accuracy_score_sog 0.5746666666666667
# recall_score_sog 0.5958510855042177
# precision_score_sog 0.7626181558765829
# f1_score_sog 0.5710128025171026
# neuron unit number: 47
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 188)
# accuracy_score_sog 0.4826666666666667
# recall_score_sog 0.5011709482664445
# precision_score_sog 0.6171974191599526
# f1_score_sog 0.46389642295291394
# neuron unit number: 52
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 208)
# accuracy_score_sog 0.5746666666666667
# recall_score_sog 0.5958510855042177
# precision_score_sog 0.7626181558765829
# f1_score_sog 0.5710128025171026
# neuron unit number: 57
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 228)
# accuracy_score_sog 0.5746666666666667
# recall_score_sog 0.5958510855042177
# precision_score_sog 0.7626181558765829
# f1_score_sog 0.5710128025171026
# neuron unit number: 62
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 248)
# accuracy_score_sog 0.5693333333333334
# recall_score_sog 0.5771586363530959
# precision_score_sog 0.6414282076158526
# f1_score_sog 0.5627983592030414
# neuron unit number: 67
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 268)
# accuracy_score_sog 0.5506666666666666
# recall_score_sog 0.5650869208674427
# precision_score_sog 0.5798858192850248
# f1_score_sog 0.546684446847597
# neuron unit number: 72
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 288)
# accuracy_score_sog 0.5746666666666667
# recall_score_sog 0.5958510855042177
# precision_score_sog 0.7626181558765829
# f1_score_sog 0.5710128025171026
# neuron unit number: 77
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 308)
# accuracy_score_sog 0.5746666666666667
# recall_score_sog 0.5958510855042177
# precision_score_sog 0.7626181558765829
# f1_score_sog 0.5710128025171026
# neuron unit number: 82
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 328)
# accuracy_score_sog 0.5706666666666667
# recall_score_sog 0.5915592400106556
# precision_score_sog 0.728886045572204
# f1_score_sog 0.5641047856435137
# neuron unit number: 87
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 348)
# accuracy_score_sog 0.5506666666666666
# recall_score_sog 0.5696298842860609
# precision_score_sog 0.6168663541300142
# f1_score_sog 0.5431208958118564
# neuron unit number: 92
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 368)
# accuracy_score_sog 0.5746666666666667
# recall_score_sog 0.5959397076825509
# precision_score_sog 0.7491358489814735
# f1_score_sog 0.570507399577167
# neuron unit number: 97
# accuracy_score_orignial 0.428
# recall_score_original 0.4075611511520644
# precision_score_original 0.28205317124086693
# f1_score_original 0.33307404678075275
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 388)
# accuracy_score_sog 0.5146666666666667
# recall_score_sog 0.5255375226607607
# precision_score_sog 0.6094237034767164
# f1_score_sog 0.5031197553162676
# all_accuracy_score_original mean 0.42800000000000005
# all_recall_score_original mean 0.40756115115206437
# all_precision_score_original mean 0.282053171240867
# all_f1_score_original mean 0.3330740467807527
# all_accuracy_score_sog mean 0.5402666666666666
# all_recall_score_sog mean 0.5542516109375865
# all_precision_score_sog mean 0.6441333199367206
# all_f1_score_sog mean 0.5306542381160121
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.428000  5.695324e-17  1.273513e-17
# 1       all_accuracy_score_sog  20.0  0.540267  4.069249e-02  9.099116e-03
# 2                     combined  40.0  0.484133  6.354884e-02  1.004795e-02
#
#    95% Conf.  Interval
# 0   0.428000  0.428000
# 1   0.521222  0.559311
# 2   0.463809  0.504457
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -1.123000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.233820e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.901700e+00
# 7                                       Hedge's g =  -3.824200e+00
# 8                                  Glass's delta1 =  -1.971208e+15
# 9                                Point-Biserial r =  -8.946000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.407561  5.695324e-17  1.273513e-17
# 1       all_recall_score_sog  20.0  0.554252  4.556719e-02  1.018913e-02
# 2                   combined  40.0  0.480906  8.080237e-02  1.277598e-02
#
#    95% Conf.  Interval
# 0   0.407561  0.407561
# 1   0.532926  0.575578
# 2   0.455065  0.506748
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -1.467000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.439680e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.552700e+00
# 7                                       Hedge's g =  -4.462200e+00
# 8                                  Glass's delta1 =  -2.575630e+15
# 9                                Point-Biserial r =  -9.193000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.282053  5.695324e-17  1.273513e-17
# 1       all_precision_score_sog  20.0  0.644133  1.030564e-01  2.304410e-02
# 2                      combined  40.0  0.463093  1.969519e-01  3.114083e-02
#
#    95% Conf.  Interval
# 0   0.282053  0.282053
# 1   0.595901  0.692365
# 2   0.400105  0.526082
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -3.621000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.571250e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.968700e+00
# 7                                       Hedge's g =  -4.870000e+00
# 8                                  Glass's delta1 =  -6.357499e+15
# 9                                Point-Biserial r =  -9.309000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.333074  5.695324e-17  1.273513e-17
# 1       all_f1_score_sog  20.0  0.530654  5.135382e-02  1.148306e-02
# 2               combined  40.0  0.431864  1.062757e-01  1.680366e-02
#
#    95% Conf.  Interval
# 0   0.333074  0.333074
# 1   0.506620  0.554689
# 2   0.397876  0.465853
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.976000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.720620e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.441100e+00
# 7                                       Hedge's g =  -5.333000e+00
# 8                                  Glass's delta1 =  -3.469165e+15
# 9                                Point-Biserial r =  -9.414000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#Decision Tree
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 8)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5700586144685597
# precision_score_sog 0.5794297753975174
# f1_score_sog 0.5734294921869018
# neuron unit number: 7
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 28)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5811794094979935
# f1_score_sog 0.5753429905916567
# neuron unit number: 12
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 48)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5811794094979935
# f1_score_sog 0.5753429905916567
# neuron unit number: 17
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 68)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 22
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 88)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 27
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 108)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 32
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 128)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5810697854750718
# f1_score_sog 0.575280232856473
# neuron unit number: 37
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 148)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 42
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 168)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5810697854750718
# f1_score_sog 0.575280232856473
# neuron unit number: 47
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 188)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5810697854750718
# f1_score_sog 0.575280232856473
# neuron unit number: 52
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 208)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 57
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 228)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5810697854750718
# f1_score_sog 0.575280232856473
# neuron unit number: 62
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 248)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5810697854750718
# f1_score_sog 0.575280232856473
# neuron unit number: 67
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 268)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 72
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 288)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5721565131783276
# precision_score_sog 0.5810697854750718
# f1_score_sog 0.575280232856473
# neuron unit number: 77
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 308)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 82
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 328)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 87
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 348)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 92
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 368)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# neuron unit number: 97
# accuracy_score_orignial 0.58
# recall_score_original 0.5690266227244936
# precision_score_original 0.5777847559234942
# f1_score_original 0.5721831588240974
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 388)
# accuracy_score_sog 0.5813333333333334
# recall_score_sog 0.5705915679514105
# precision_score_sog 0.5797044832443062
# f1_score_sog 0.5738243877063112
# all_accuracy_score_original mean 0.58
# all_recall_score_original mean 0.5690266227244936
# all_precision_score_original mean 0.5777847559234941
# all_f1_score_original mean 0.5721831588240975
# all_accuracy_score_sog mean 0.5818666666666668
# all_recall_score_sog mean 0.5711908983680348
# all_precision_score_sog mean 0.5802478311465652
# all_f1_score_sog mean 0.5743932567639239
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.580000  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.581867  0.000670  0.000150   0.581553
# 2                     combined  40.0  0.580933  0.001055  0.000167   0.580596
#
#    Interval
# 0       NaN
# 1  0.582180
# 2  0.581271
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0019
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -12.4566
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.9391
# 7                                       Hedge's g =   -3.8609
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8963
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.569027  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.571191  0.000817  0.000183   0.570808
# 2                   combined  40.0  0.570109  0.001236  0.000195   0.569714
#
#    Interval
# 0       NaN
# 1  0.571573
# 2  0.570504
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0022
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -11.8421
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.7448
# 7                                       Hedge's g =   -3.6704
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8870
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.577785  1.139065e-16  2.547026e-17
# 1        all_accuracy_score_sog  20.0  0.581867  6.701663e-04  1.498537e-04
# 2                      combined  40.0  0.579826  2.119224e-03  3.350787e-04
#
#    95% Conf.  Interval
# 0   0.577785  0.577785
# 1   0.581553  0.582180
# 2   0.579148  0.580503
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -4.100000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -2.723930e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -8.613800e+00
# 7                                       Hedge's g =  -8.442700e+00
# 8                                  Glass's delta1 =  -3.583563e+13
# 9                                Point-Biserial r =  -9.753000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.572183  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.574393  7.613327e-04  1.702392e-04
# 2               combined  40.0  0.573288  1.238881e-03  1.958843e-04
#
#    95% Conf.  Interval
# 0   0.572183  0.572183
# 1   0.574037  0.574750
# 2   0.572892  0.573684
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -2.200000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.298230e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.105400e+00
# 7                                       Hedge's g =  -4.023800e+00
# 8                                  Glass's delta1 =  -1.940274e+13
# 9                                Point-Biserial r =  -9.033000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#LinearDiscriminantAnalysis
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 8)
# accuracy_score_sog 0.5586666666666666
# recall_score_sog 0.5383391220912482
# precision_score_sog 0.633617169835111
# f1_score_sog 0.5585861367032606
# neuron unit number: 7
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 28)
# accuracy_score_sog 0.5266666666666666
# recall_score_sog 0.49717444364305347
# precision_score_sog 0.5335846271404258
# f1_score_sog 0.49687935698744184
# neuron unit number: 12
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 48)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 17
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 68)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 22
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 88)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 27
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 108)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 32
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 128)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 37
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 148)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 42
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 168)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 47
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 188)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 52
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 208)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 57
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 228)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 62
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 248)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 67
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 268)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 72
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 288)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 77
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 308)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 82
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_original 0.3602662099172567
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 328)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 87
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 348)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 92
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# f1_score_original 0.3602662099172567
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 368)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# neuron unit number: 97
# accuracy_score_orignial 0.4693333333333333
# recall_score_original 0.4369624628245317
# precision_score_original 0.30650819930621254
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_original 0.3602662099172567
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 388)
# accuracy_score_sog 0.6733333333333333
# recall_score_sog 0.647996075106791
# precision_score_sog 0.7378631426045219
# f1_score_sog 0.661892016277955
# all_accuracy_score_original mean 0.4693333333333333
# all_recall_score_original mean 0.4369624628245317
# all_precision_score_original mean 0.30650819930621254
# all_f1_score_original mean 0.3602662099172568
# all_accuracy_score_sog mean 0.6602666666666668
# all_recall_score_sog mean 0.634972145882827
# all_precision_score_sog mean 0.7224369181928465
# all_f1_score_sog mean 0.6484760893346946
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.469333  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.660267  0.040552  0.009068   0.641288
# 2                     combined  40.0  0.564800  0.100741  0.015929   0.532582
#
#    Interval
# 0       NaN
# 1  0.679246
# 2  0.597018
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.1909
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -21.0564
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -6.6586
# 7                                       Hedge's g =   -6.5263
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9597
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.436962  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.634972  0.040639  0.009087   0.615952
# 2                   combined  40.0  0.535967  0.104201  0.016476   0.502642
#
#    Interval
# 0       NaN
# 1  0.653992
# 2  0.569292
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.1980
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -21.7899
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -6.8906
# 7                                       Hedge's g =   -6.7537
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9622
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.306508  0.000000  0.000000
# 1        all_accuracy_score_sog  20.0  0.660267  0.040552  0.009068
# 2                      combined  40.0  0.483387  0.181355  0.028675
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.641288  0.679246
# 2   0.425387  0.541388
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.3538
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -39.0130
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =  -12.3370
# 7                                       Hedge's g =  -12.0919
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9877
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.360266  5.695324e-17  1.273513e-17
# 1       all_f1_score_sog  20.0  0.648476  4.248934e-02  9.500906e-03
# 2               combined  40.0  0.504371  1.489236e-01  2.354688e-02
#
#    95% Conf.  Interval
# 0   0.360266  0.360266
# 1   0.628590  0.668362
# 2   0.456743  0.551999
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -2.882000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -3.033500e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -9.592800e+00
# 7                                       Hedge's g =  -9.402200e+00
# 8                                  Glass's delta1 =  -5.060465e+15
# 9                                Point-Biserial r =  -9.800000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#KNN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 50
class_num = 2
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 8)
# accuracy_score_sog 0.528
# recall_score_sog 0.5164400823903813
# precision_score_sog 0.5327277445189237
# f1_score_sog 0.5218424367961608
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 4
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 16)
# accuracy_score_sog 0.5693333333333334
# recall_score_sog 0.5555660373942837
# precision_score_sog 0.5707937828081023
# f1_score_sog 0.5609586588973187
# Not good precision_score_original !!!!!
# neuron unit number: 6
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 24)
# accuracy_score_sog 0.54
# recall_score_sog 0.5295178412293314
# precision_score_sog 0.554281898016569
# f1_score_sog 0.5368251980192279
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 8
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5826666666666667
# recall_score_sog 0.5655258850236605
# precision_score_sog 0.5924474713948399
# f1_score_sog 0.5736472284980527
# neuron unit number: 10
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 40)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5856903502136529
# precision_score_sog 0.6055398259835292
# f1_score_sog 0.5920299372488836
# neuron unit number: 12
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 48)
# accuracy_score_sog 0.608
# recall_score_sog 0.5905891235882091
# precision_score_sog 0.6229308253716567
# f1_score_sog 0.5998742864734224
# neuron unit number: 14
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 56)
# accuracy_score_sog 0.56
# recall_score_sog 0.5528638014906918
# precision_score_sog 0.5582023133502209
# f1_score_sog 0.5549146382691008
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# neuron unit number: 16
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 64)
# accuracy_score_sog 0.5933333333333334
# recall_score_sog 0.5762424811804062
# precision_score_sog 0.6117853191948627
# f1_score_sog 0.5860790389674159
# neuron unit number: 18
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 72)
# accuracy_score_sog 0.5946666666666667
# recall_score_sog 0.5800435892515604
# precision_score_sog 0.5970900051693104
# f1_score_sog 0.5856335250634538
# neuron unit number: 20
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 80)
# accuracy_score_sog 0.5893333333333334
# recall_score_sog 0.5738539852598975
# precision_score_sog 0.5970800131937573
# f1_score_sog 0.5810882206434856
# neuron unit number: 22
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 88)
# accuracy_score_sog 0.5386666666666666
# recall_score_sog 0.5293928413913641
# precision_score_sog 0.5386621573892474
# f1_score_sog 0.5327460457513467
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 24
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 96)
# accuracy_score_sog 0.5613333333333334
# recall_score_sog 0.5491021623474562
# precision_score_sog 0.5684585781759227
# f1_score_sog 0.5552993694414206
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# neuron unit number: 26
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 104)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5837470307230515
# precision_score_sog 0.6085044133102593
# f1_score_sog 0.5913894268686319
# neuron unit number: 28
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 112)
# accuracy_score_sog 0.5946666666666667
# recall_score_sog 0.5797507458979245
# precision_score_sog 0.6016848296655315
# f1_score_sog 0.5864687728258017
# neuron unit number: 30
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 120)
# accuracy_score_sog 0.5946666666666667
# recall_score_sog 0.5791070179642624
# precision_score_sog 0.5987558383663655
# f1_score_sog 0.5853048643648858
# neuron unit number: 32
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 128)
# accuracy_score_sog 0.604
# recall_score_sog 0.5870413899427719
# precision_score_sog 0.6132829460601833
# f1_score_sog 0.5947408115054339
# neuron unit number: 34
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 136)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5783502694368937
# precision_score_sog 0.6019826200499558
# f1_score_sog 0.5850391800982563
# neuron unit number: 36
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 144)
# accuracy_score_sog 0.592
# recall_score_sog 0.5746073590374837
# precision_score_sog 0.5994047043465648
# f1_score_sog 0.5818688365112682
# neuron unit number: 38
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 152)
# accuracy_score_sog 0.6053333333333333
# recall_score_sog 0.5875294100503803
# precision_score_sog 0.60772677696835
# f1_score_sog 0.5936136170526441
# neuron unit number: 40
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 160)
# accuracy_score_sog 0.6026666666666667
# recall_score_sog 0.5868462131887994
# precision_score_sog 0.6039340548333235
# f1_score_sog 0.5923791133163082
# neuron unit number: 42
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 168)
# accuracy_score_sog 0.5546666666666666
# recall_score_sog 0.5410426340856254
# precision_score_sog 0.5586747689969724
# f1_score_sog 0.5457745409484089
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 44
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 176)
# accuracy_score_sog 0.5666666666666667
# recall_score_sog 0.5467465423006558
# precision_score_sog 0.5736019930022378
# f1_score_sog 0.5543833741481455
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 46
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 184)
# accuracy_score_sog 0.604
# recall_score_sog 0.5879779612300698
# precision_score_sog 0.6086647345450635
# f1_score_sog 0.5943782656947696
# neuron unit number: 48
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 192)
# accuracy_score_sog 0.5786666666666667
# recall_score_sog 0.5574235130841284
# precision_score_sog 0.5928971662987008
# f1_score_sog 0.5653491602959688
# neuron unit number: 50
# accuracy_score_orignial 0.568
# recall_score_original 0.5498432439900734
# precision_score_original 0.5787665995039267
# f1_score_original 0.5544988136824871
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 200)
# accuracy_score_sog 0.5906666666666667
# recall_score_sog 0.5750559102171734
# precision_score_sog 0.5994859425460541
# f1_score_sog 0.5824277530438667
# all_accuracy_score_original mean 0.568
# all_recall_score_original mean 0.5498432439900734
# all_precision_score_original mean 0.5787665995039267
# all_f1_score_original mean 0.5544988136824871
# all_accuracy_score_sog mean 0.5818133333333333
# all_recall_score_sog mean 0.5668021671168045
# all_precision_score_sog mean 0.5887440289422602
# all_f1_score_sog mean 0.5733622520297472
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  25.0  0.568000  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  25.0  0.581813  0.023078  0.004616   0.572287
# 2                     combined  50.0  0.574907  0.017593  0.002488   0.569907
#
#    Interval
# 0       NaN
# 1  0.591339
# 2  0.579907
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0138
# 1                              Degrees of freedom =   48.0000
# 2                                               t =   -2.9928
# 3                           Two side test p value =    0.0044
# 4                          Difference < 0 p value =    0.0022
# 5                          Difference > 0 p value =    0.9978
# 6                                       Cohen's d =   -0.8465
# 7                                       Hedge's g =   -0.8332
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.3966
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  25.0  0.549843  0.000000  0.000000        NaN
# 1       all_recall_score_sog  25.0  0.566802  0.021321  0.004264   0.558001
# 2                   combined  50.0  0.558323  0.017205  0.002433   0.553433
#
#    Interval
# 0       NaN
# 1  0.575603
# 2  0.563212
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0170
# 1                              Degrees of freedom =   48.0000
# 2                                               t =   -3.9771
# 3                           Two side test p value =    0.0002
# 4                          Difference < 0 p value =    0.0001
# 5                          Difference > 0 p value =    0.9999
# 6                                       Cohen's d =   -1.1249
# 7                                       Hedge's g =   -1.1072
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.4978
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  25.0  0.578767  0.000000  0.000000
# 1       all_precision_score_sog  25.0  0.588744  0.024527  0.004905
# 2                      combined  50.0  0.583755  0.017890  0.002530
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.578620  0.598868
# 2   0.578671  0.588840
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0100
# 1                              Degrees of freedom =   48.0000
# 2                                               t =   -2.0340
# 3                           Two side test p value =    0.0475
# 4                          Difference < 0 p value =    0.0238
# 5                          Difference > 0 p value =    0.9762
# 6                                       Cohen's d =   -0.5753
# 7                                       Hedge's g =   -0.5663
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.2817
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  25.0  0.554499  0.000000  0.000000        NaN
# 1       all_f1_score_sog  25.0  0.573362  0.022050  0.004410   0.564260
# 2               combined  50.0  0.563931  0.018136  0.002565   0.558776
#
#    Interval
# 0       NaN
# 1  0.582464
# 2  0.569085
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0189
# 1                              Degrees of freedom =   48.0000
# 2                                               t =   -4.2774
# 3                           Two side test p value =    0.0001
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.2098
# 7                                       Hedge's g =   -1.1908
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.5253
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#SVM
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 8)
# accuracy_score_sog 0.5026666666666667
# recall_score_sog 0.503633493627336
# precision_score_sog 0.5332770743830458
# f1_score_sog 0.509968443919509
# neuron unit number: 7
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 28)
# accuracy_score_sog 0.6226666666666667
# recall_score_sog 0.6000566893424036
# precision_score_sog 0.6998903168394693
# f1_score_sog 0.6106124097855051
# neuron unit number: 12
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 48)
# accuracy_score_sog 0.584
# recall_score_sog 0.5544217687074829
# precision_score_sog 0.6595783589709204
# f1_score_sog 0.5573047312712117
# neuron unit number: 17
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 68)
# accuracy_score_sog 0.6386666666666667
# recall_score_sog 0.6229205762764876
# precision_score_sog 0.6764276467602809
# f1_score_sog 0.6306630702333796
# neuron unit number: 22
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 88)
# accuracy_score_sog 0.64
# recall_score_sog 0.6254715966846508
# precision_score_sog 0.6774672558324039
# f1_score_sog 0.633167533345741
# neuron unit number: 27
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 108)
# accuracy_score_sog 0.6133333333333333
# recall_score_sog 0.592269235280319
# precision_score_sog 0.6693779720414103
# f1_score_sog 0.6014518909424503
# neuron unit number: 32
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 128)
# accuracy_score_sog 0.636
# recall_score_sog 0.621310305731488
# precision_score_sog 0.6698305683871384
# f1_score_sog 0.6288070439178634
# neuron unit number: 37
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 148)
# accuracy_score_sog 0.6186666666666667
# recall_score_sog 0.5957927711314411
# precision_score_sog 0.6772795059849468
# f1_score_sog 0.6040200209765548
# neuron unit number: 42
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 168)
# accuracy_score_sog 0.64
# recall_score_sog 0.6268888302447415
# precision_score_sog 0.6828096490457479
# f1_score_sog 0.6352647907994999
# neuron unit number: 47
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 188)
# accuracy_score_sog 0.64
# recall_score_sog 0.6228936977089686
# precision_score_sog 0.6927374164906973
# f1_score_sog 0.6313150659496309
# neuron unit number: 52
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 208)
# accuracy_score_sog 0.636
# recall_score_sog 0.6227275392915786
# precision_score_sog 0.6688388481795743
# f1_score_sog 0.6299498791088363
# neuron unit number: 57
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 228)
# accuracy_score_sog 0.6426666666666667
# recall_score_sog 0.6299676479787317
# precision_score_sog 0.6881870335221286
# f1_score_sog 0.6378653014999505
# neuron unit number: 62
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 248)
# accuracy_score_sog 0.632
# recall_score_sog 0.6152284189537883
# precision_score_sog 0.6724877199521032
# f1_score_sog 0.6230405806152739
# neuron unit number: 67
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 268)
# accuracy_score_sog 0.648
# recall_score_sog 0.6318735827664399
# precision_score_sog 0.7161739243095177
# f1_score_sog 0.6416855153970761
# neuron unit number: 72
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 288)
# accuracy_score_sog 0.6373333333333333
# recall_score_sog 0.6239639533974509
# precision_score_sog 0.6786618951765185
# f1_score_sog 0.6319161951853437
# neuron unit number: 77
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 308)
# accuracy_score_sog 0.6133333333333333
# recall_score_sog 0.5938404097271093
# precision_score_sog 0.6771353607930211
# f1_score_sog 0.6043445877822666
# neuron unit number: 82
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 328)
# accuracy_score_sog 0.6093333333333333
# recall_score_sog 0.587348013918211
# precision_score_sog 0.6554376426716852
# f1_score_sog 0.594422810784044
# neuron unit number: 87
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 348)
# accuracy_score_sog 0.644
# recall_score_sog 0.6300898232856361
# precision_score_sog 0.6972595232832303
# f1_score_sog 0.6389863547758285
# neuron unit number: 92
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 368)
# accuracy_score_sog 0.6386666666666667
# recall_score_sog 0.624188755962155
# precision_score_sog 0.6884748474888719
# f1_score_sog 0.6324757206519677
# neuron unit number: 97
# accuracy_score_orignial 0.41733333333333333
# recall_score_original 0.39214363906482136
# precision_score_original 0.2751117991056072
# f1_score_original 0.3232939899606566
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1750, 388)
# accuracy_score_sog 0.644
# recall_score_sog 0.6274092970521542
# precision_score_sog 0.7043643369583581
# f1_score_sog 0.6364161749383667
# all_accuracy_score_original mean 0.4173333333333334
# all_recall_score_original mean 0.39214363906482136
# all_precision_score_original mean 0.27511179910560724
# all_f1_score_original mean 0.3232939899606567
# all_accuracy_score_sog mean 0.6240666666666668
# all_recall_score_sog mean 0.6076148203534287
# all_precision_score_sog mean 0.6742848448535536
# all_f1_score_sog mean 0.615683906094015
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.417333  5.695324e-17  1.273513e-17
# 1       all_accuracy_score_sog  20.0  0.624067  3.264403e-02  7.299427e-03
# 2                     combined  40.0  0.520700  1.071344e-01  1.693944e-02
#
#    95% Conf.  Interval
# 0   0.417333  0.417333
# 1   0.608789  0.639345
# 2   0.486437  0.554963
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -2.067000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -2.832190e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -8.956200e+00
# 7                                       Hedge's g =  -8.778200e+00
# 8                                  Glass's delta1 =  -3.629878e+15
# 9                                Point-Biserial r =  -9.771000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.392144  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.607615  0.031484  0.007040   0.592880
# 2                   combined  40.0  0.499879  0.111299  0.017598   0.464284
#
#    Interval
# 0       NaN
# 1  0.622350
# 2  0.535474
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.2155
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -30.6066
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -9.6787
# 7                                       Hedge's g =   -9.4864
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9803
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.275112  5.695324e-17  1.273513e-17
# 1        all_accuracy_score_sog  20.0  0.624067  3.264403e-02  7.299427e-03
# 2                      combined  40.0  0.449589  1.781631e-01  2.817007e-02
#
#    95% Conf.  Interval
# 0   0.275112  0.275112
# 1   0.608789  0.639345
# 2   0.392610  0.506569
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -3.490000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -4.780580e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.511750e+01
# 7                                       Hedge's g =  -1.481720e+01
# 8                                  Glass's delta1 =  -6.127042e+15
# 9                                Point-Biserial r =  -9.918000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.323294  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.615684  3.228398e-02  7.218917e-03
# 2               combined  40.0  0.469489  1.497623e-01  2.367950e-02
#
#    95% Conf.  Interval
# 0   0.323294  0.323294
# 1   0.600575  0.630793
# 2   0.421593  0.517385
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -2.924000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -4.050330e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.280830e+01
# 7                                       Hedge's g =  -1.255380e+01
# 8                                  Glass's delta1 =  -2.566930e+15
# 9                                Point-Biserial r =  -9.886000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[1,2]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02234382538594245
# test_discrete_score_W_discrete_a 0.04032700754385205
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.01739318005978277
# test_discrete_score_W0_a 0.029175201704974632
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.03443300398952806
# test_discrete_score_W_discrete_a 0.02422357085425989
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.02334380379895585
# test_discrete_score_W0_a 0.037353108504030286
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.053434189827062516
# test_discrete_score_W_discrete_a 0.05456195729343344
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.476
# test_discrete_score_W0_n 0.033922299757219505
# test_discrete_score_W0_a 0.052561119522969935
# test_discrete_score_W_discrete_p 0.46
# test_discrete_score_W_discrete_n 0.031134181280268396
# test_discrete_score_W_discrete_a 0.044253704350719236
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.030552889554805434
# test_discrete_score_W0_a 0.042998231189427
# test_discrete_score_W_discrete_p 0.4746666666666667
# test_discrete_score_W_discrete_n 0.03376967607150299
# test_discrete_score_W_discrete_a 0.04632683501465729
# Not good purity result for discrete features !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03342601353355848
# test_discrete_score_W0_a 0.04798282495417882
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.05507820220623584
# test_discrete_score_W_discrete_a 0.06572394767970656
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.027459821320045832
# test_discrete_score_W0_a 0.04253570431171219
# test_discrete_score_W_discrete_p 0.49333333333333335
# test_discrete_score_W_discrete_n 0.04397362826092439
# test_discrete_score_W_discrete_a 0.06267067104557747
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.024786498576812546
# test_discrete_score_W0_a 0.03788888448751348
# test_discrete_score_W_discrete_p 0.49066666666666664
# test_discrete_score_W_discrete_n 0.03958278449072278
# test_discrete_score_W_discrete_a 0.05649455222149977
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.016522062383778145
# test_discrete_score_W0_a 0.028494233453073153
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.05119010651141663
# test_discrete_score_W_discrete_a 0.07210828379153088
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.017426370665438014
# test_discrete_score_W0_a 0.023699636325396987
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032538084155730576
# test_discrete_score_W_discrete_a 0.04820567242261783
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.036857456552891944
# test_discrete_score_W0_a 0.05578198334814375
# test_discrete_score_W_discrete_p 0.5213333333333333
# test_discrete_score_W_discrete_n 0.06132297519620123
# test_discrete_score_W_discrete_a 0.08512012645846712
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4866666666666667
# test_discrete_score_W0_n 0.03759457527631816
# test_discrete_score_W0_a 0.055163595305752385
# test_discrete_score_W_discrete_p 0.556
# test_discrete_score_W_discrete_n 0.09577315053890768
# test_discrete_score_W_discrete_a 0.11281183908452129
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03093370149562325
# test_discrete_score_W0_a 0.044458312234050626
# test_discrete_score_W_discrete_p 0.516
# test_discrete_score_W_discrete_n 0.05804740739737212
# test_discrete_score_W_discrete_a 0.08513700710052961
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.02054779399772174
# test_discrete_score_W0_a 0.03101276852118271
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.04653708967400014
# test_discrete_score_W_discrete_a 0.06827491998098022
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5146666666666667
# test_discrete_score_W0_n 0.05443083282314605
# test_discrete_score_W0_a 0.07036287681764777
# test_discrete_score_W_discrete_p 0.544
# test_discrete_score_W_discrete_n 0.08269977748474737
# test_discrete_score_W_discrete_a 0.09852532914984698
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.02892604535266786
# test_discrete_score_W0_a 0.047155247862443884
# test_discrete_score_W_discrete_p 0.524
# test_discrete_score_W_discrete_n 0.06372742679275416
# test_discrete_score_W_discrete_a 0.07877786447256512
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.524
# test_discrete_score_W0_n 0.05945259033535872
# test_discrete_score_W0_a 0.07960516206945854
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.0541905060530825
# test_discrete_score_W_discrete_a 0.07125467232825451
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.022448343490384687
# test_discrete_score_W0_a 0.03397696731084315
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.03841331757870813
# test_discrete_score_W_discrete_a 0.0518461718393148
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.5226666666666666
# test_discrete_score_W0_n 0.058074070778292367
# test_discrete_score_W0_a 0.0763494609595373
# test_discrete_score_W_discrete_p 0.5146666666666667
# test_discrete_score_W_discrete_n 0.05986941507524195
# test_discrete_score_W_discrete_a 0.08647900509679979
# Not good purity result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.46993333333333326
# test_discrete_score_W_discrete_p mean 0.49493333333333334
# test_discrete_score_W0_n mean 0.029605726327701958
# test_discrete_score_W_discrete_n mean 0.04883370954923206
# test_discrete_score_W0_a mean 0.04282968855928333
# test_discrete_score_W_discrete_a mean 0.06369091609333
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.029606  0.014779  0.003305   0.022689  0.036523
# 1  test_dis_W_dis  20.0  0.048834  0.019029  0.004255   0.039928  0.057740
# 2        combined  40.0  0.039220  0.019433  0.003073   0.033005  0.045435
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0192
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.5689
# 3                      Two side test p value =    0.0010
# 4                     Difference < 0 p value =    0.0005
# 5                     Difference > 0 p value =    0.9995
# 6                                  Cohen's d =   -1.1286
# 7                                  Hedge's g =   -1.1062
# 8                             Glass's delta1 =   -1.3010
# 9                           Point-Biserial r =   -0.5010
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.042830  0.019305  0.004317   0.033795  0.051865
# 1  test_dis_W_dis  20.0  0.063691  0.023612  0.005280   0.052640  0.074742
# 2        combined  40.0  0.053260  0.023765  0.003758   0.045660  0.060861
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0209
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.0589
# 3                      Two side test p value =    0.0041
# 4                     Difference < 0 p value =    0.0020
# 5                     Difference > 0 p value =    0.9980
# 6                                  Cohen's d =   -0.9673
# 7                                  Hedge's g =   -0.9481
# 8                             Glass's delta1 =   -1.0806
# 9                           Point-Biserial r =   -0.4445
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.469933  0.028203  0.006306   0.456734  0.483133
# 1  test_dis_W_dis  20.0  0.494933  0.030892  0.006908   0.480475  0.509391
# 2        combined  40.0  0.482433  0.031823  0.005032   0.472256  0.492611
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0250
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.6728
# 3                      Two side test p value =    0.0110
# 4                     Difference < 0 p value =    0.0055
# 5                     Difference > 0 p value =    0.9945
# 6                                  Cohen's d =   -0.8452
# 7                                  Hedge's g =   -0.8284
# 8                             Glass's delta1 =   -0.8864
# 9                           Point-Biserial r =   -0.3978

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.428
# test_discrete_score_W_discrete_n 0.02345171762930623
# test_discrete_score_W_discrete_a 0.01923792963102035
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.018856935362735645
# test_discrete_score_W_discrete_a 0.029045041233303804
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.026855580654044465
# test_discrete_score_W0_a 0.03604144266742046
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01810404796207701
# test_discrete_score_W_discrete_a 0.03346196864130828
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024682167696410937
# test_discrete_score_W0_a 0.032188349757317845
# test_discrete_score_W_discrete_p 0.44666666666666666
# test_discrete_score_W_discrete_n 0.01797489888334447
# test_discrete_score_W_discrete_a 0.0285471281012557
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024203462603534617
# test_discrete_score_W0_a 0.03846988685325159
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01838925770914136
# test_discrete_score_W_discrete_a 0.032019100024307974
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.03349335568258328
# test_discrete_score_W0_a 0.04667109658886825
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.01605391401844283
# test_discrete_score_W_discrete_a 0.026793244224623227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48533333333333334
# test_discrete_score_W0_n 0.035485179839995426
# test_discrete_score_W0_a 0.04981859509745033
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02068810713236546
# test_discrete_score_W_discrete_a 0.03309157601901982
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02390083884461625
# test_discrete_score_W0_a 0.03873861993122384
# test_discrete_score_W_discrete_p 0.4573333333333333
# test_discrete_score_W_discrete_n 0.023235517855302763
# test_discrete_score_W_discrete_a 0.03744560308797647
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.026985376253148303
# test_discrete_score_W0_a 0.03978610299904206
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.026305260920569878
# test_discrete_score_W_discrete_a 0.041094189990076725
# Not good nmi result for discrete features !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.018162904680171798
# test_discrete_score_W0_a 0.03022682699783115
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03400184259136679
# test_discrete_score_W_discrete_a 0.05029641376853773
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.033072619927399426
# test_discrete_score_W0_a 0.047156111573114626
# test_discrete_score_W_discrete_p 0.4786666666666667
# test_discrete_score_W_discrete_n 0.03499390650337792
# test_discrete_score_W_discrete_a 0.051949215378023175
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.023824261795553792
# test_discrete_score_W0_a 0.037597994770207366
# test_discrete_score_W_discrete_p 0.468
# test_discrete_score_W_discrete_n 0.028031643322058132
# test_discrete_score_W_discrete_a 0.044080209705631444
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.028791201469484017
# test_discrete_score_W0_a 0.04599112596540657
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032429275622864545
# test_discrete_score_W_discrete_a 0.04740265300888458
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.4706666666666667
# test_discrete_score_W0_n 0.028197704700882276
# test_discrete_score_W0_a 0.042188175616839595
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03430876326213519
# test_discrete_score_W_discrete_a 0.05324336208092509
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.021944285346807382
# test_discrete_score_W0_a 0.031945508345160974
# test_discrete_score_W_discrete_p 0.48533333333333334
# test_discrete_score_W_discrete_n 0.03869110510763206
# test_discrete_score_W_discrete_a 0.05802214839446757
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5106666666666667
# test_discrete_score_W0_n 0.05054444015796348
# test_discrete_score_W0_a 0.06925893080150226
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.028500768616768247
# test_discrete_score_W_discrete_a 0.03993660270160838
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.03193530568800679
# test_discrete_score_W0_a 0.04764998062763653
# test_discrete_score_W_discrete_p 0.504
# test_discrete_score_W_discrete_n 0.047939169427930486
# test_discrete_score_W_discrete_a 0.06706429938523999
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.025557559612347378
# test_discrete_score_W0_a 0.038599165108127206
# test_discrete_score_W_discrete_p 0.4693333333333333
# test_discrete_score_W_discrete_n 0.02610302923188745
# test_discrete_score_W_discrete_a 0.041979976747958815
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02431624127598852
# test_discrete_score_W0_a 0.039038707645552506
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.02710259286982934
# test_discrete_score_W_discrete_a 0.03850236196126793
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.49333333333333335
# test_discrete_score_W0_n 0.043797733013326734
# test_discrete_score_W0_a 0.06109381550919402
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03414668262562054
# test_discrete_score_W_discrete_a 0.047714667147608227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.46453333333333335
# test_discrete_score_W_discrete_p mean 0.46593333333333337
# test_discrete_score_W0_n mean 0.02718831980217513
# test_discrete_score_W_discrete_n mean 0.027465421832737813
# test_discrete_score_W0_a mean 0.03962494445792386
# test_discrete_score_W_discrete_a mean 0.04104638456165226
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.027188  0.010186  0.002278   0.022421  0.031956
# 1  test_dis_W_dis  20.0  0.027465  0.008303  0.001857   0.023580  0.031351
# 2        combined  40.0  0.027327  0.009173  0.001450   0.024393  0.030261
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0003
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.0943
# 3                      Two side test p value =    0.9254
# 4                     Difference < 0 p value =    0.4627
# 5                     Difference > 0 p value =    0.5373
# 6                                  Cohen's d =   -0.0298
# 7                                  Hedge's g =   -0.0292
# 8                             Glass's delta1 =   -0.0272
# 9                           Point-Biserial r =   -0.0153
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.039625  0.014212  0.003178   0.032973  0.046276
# 1  test_dis_W_dis  20.0  0.041046  0.011732  0.002623   0.035556  0.046537
# 2        combined  40.0  0.040336  0.012883  0.002037   0.036215  0.044456
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.3449
# 3                      Two side test p value =    0.7320
# 4                     Difference < 0 p value =    0.3660
# 5                     Difference > 0 p value =    0.6340
# 6                                  Cohen's d =   -0.1091
# 7                                  Hedge's g =   -0.1069
# 8                             Glass's delta1 =   -0.1000
# 9                           Point-Biserial r =   -0.0559
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.464533  0.020521  0.004589   0.454929  0.474138
# 1  test_dis_W_dis  20.0  0.465933  0.017670  0.003951   0.457664  0.474203
# 2        combined  40.0  0.465233  0.018915  0.002991   0.459184  0.471283
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.2312
# 3                      Two side test p value =    0.8184
# 4                     Difference < 0 p value =    0.4092
# 5                     Difference > 0 p value =    0.5908
# 6                                  Cohen's d =   -0.0731
# 7                                  Hedge's g =   -0.0717
# 8                             Glass's delta1 =   -0.0682
# 9                           Point-Biserial r =   -0.0375

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
