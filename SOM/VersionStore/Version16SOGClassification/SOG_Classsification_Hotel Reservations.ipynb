# %%
import pandas as pd
import numpy as np
#numpy-1.21.4
import CDSOM
import newSom
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Hotel Reservations.csv")
csv = csv.drop(columns=['Booking_ID'])
csv = csv.sample(int(csv.shape[0]*0.01))


dataread.label_encoding(csv,"type_of_meal_plan")
dataread.label_encoding(csv,"room_type_reserved")
dataread.label_encoding(csv,"arrival_year")
dataread.label_encoding(csv,"market_segment_type")
dataread.label_encoding(csv,"booking_status")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv,csv_training,csv_test,"booking_status")
# Out:
# self.continuous_feature_num 3
# self.data_discrete_indexes ['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'arrival_year', 'arrival_month', 'market_segment_type', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled', 'no_of_special_requests']

# %%
#Gaussian Naive Bayes

import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 28)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 7
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 98)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 12
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 168)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 17
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 238)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 22
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 308)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 27
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 378)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 32
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 448)
# accuracy_score_sog 0.3425925925925926
# recall_score_sog 0.5506329113924051
# precision_score_sog 0.645
# f1_score_sog 0.3167602245388933
# neuron unit number: 37
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 518)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 42
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 588)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 47
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 658)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 52
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 728)
# accuracy_score_sog 0.37962962962962965
# recall_score_sog 0.5759493670886076
# precision_score_sog 0.6510416666666666
# f1_score_sog 0.3638681318681319
# neuron unit number: 57
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 798)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 62
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 868)
# accuracy_score_sog 0.3148148148148148
# recall_score_sog 0.5316455696202531
# precision_score_sog 0.6407766990291262
# f1_score_sog 0.27922077922077926
# neuron unit number: 67
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 938)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 72
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1008)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 77
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1078)
# accuracy_score_sog 0.3425925925925926
# recall_score_sog 0.5506329113924051
# precision_score_sog 0.645
# f1_score_sog 0.3167602245388933
# neuron unit number: 82
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1148)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 87
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1218)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 92
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1288)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# neuron unit number: 97
# accuracy_score_orignial 0.3148148148148148
# recall_score_original 0.5316455696202531
# precision_score_original 0.6407766990291262
# f1_score_original 0.27922077922077926
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1358)
# accuracy_score_sog 0.35185185185185186
# recall_score_sog 0.5569620253164557
# precision_score_sog 0.6464646464646464
# f1_score_sog 0.3288352272727273
# all_accuracy_score_original mean 0.3148148148148148
# all_recall_score_original mean 0.531645569620253
# all_precision_score_original mean 0.6407766990291263
# all_f1_score_original mean 0.2792207792207792
# all_accuracy_score_sog mean 0.3375
# all_recall_score_sog mean 0.547151898734177
# all_precision_score_sog mean 0.6442718538540748
# all_f1_score_sog mean 0.30953359300833494
# Accuracy Score T-Test
#                       Variable     N      Mean        SD       SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.314815  0.000000  0.00000        NaN
# 1       all_accuracy_score_sog  20.0  0.337500  0.020258  0.00453   0.328019
# 2                     combined  40.0  0.326157  0.018218  0.00288   0.320331
#
#    Interval
# 0       NaN
# 1  0.346981
# 2  0.331984
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0227
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -5.0079
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.5836
# 7                                       Hedge's g =   -1.5522
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.6305
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.531646  1.139065e-16  2.547026e-17
# 1       all_recall_score_sog  20.0  0.547152  1.384738e-02  3.096367e-03
# 2                   combined  40.0  0.539399  1.245269e-02  1.968943e-03
#
#    95% Conf.  Interval
# 0   0.531646  0.531646
# 1   0.540671  0.553633
# 2   0.535416  0.543381
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -1.550000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -5.007900e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.583600e+00
# 7                                       Hedge's g =  -1.552200e+00
# 8                                  Glass's delta1 =  -1.361321e+14
# 9                                Point-Biserial r =  -6.305000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.640777  1.139065e-16  2.547026e-17
# 1        all_accuracy_score_sog  20.0  0.337500  2.025820e-02  4.529871e-03
# 2                      combined  40.0  0.489138  1.542197e-01  2.438428e-02
#
#    95% Conf.  Interval
# 0   0.640777  0.640777
# 1   0.328019  0.346981
# 2   0.439816  0.538460
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all...  3.033000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   6.695040e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   2.117160e+01
# 7                                       Hedge's g =   2.075100e+01
# 8                                  Glass's delta1 =   2.662506e+15
# 9                                Point-Biserial r =   9.958000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.279221  5.695324e-17  1.273513e-17
# 1       all_f1_score_sog  20.0  0.309534  2.691175e-02  6.017650e-03
# 2               combined  40.0  0.294377  2.425784e-02  3.835501e-03
#
#    95% Conf.  Interval
# 0   0.279221  0.279221
# 1   0.296939  0.322129
# 2   0.286619  0.302135
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -3.030000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -5.037300e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.592900e+00
# 7                                       Hedge's g =  -1.561300e+00
# 8                                  Glass's delta1 =  -5.322404e+14
# 9                                Point-Biserial r =  -6.328000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#Decision Tree
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.5694444444444444
# precision_score_original 0.5704500978473581
# f1_score_original 0.5698882952889752
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 28)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.5972222222222222
# precision_score_sog 0.6055718475073314
# f1_score_sog 0.599719523189422
# neuron unit number: 7
# accuracy_score_orignial 0.6574074074074074
# recall_score_original 0.625
# precision_score_original 0.6204013377926422
# f1_score_original 0.6221276595744681
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 98)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.6111111111111112
# precision_score_sog 0.6048416454313797
# f1_score_sog 0.606465476969074
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5972222222222222
# precision_score_original 0.5959269128283213
# f1_score_original 0.5965130759651307
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 168)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6111111111111112
# precision_score_sog 0.6082706766917293
# f1_score_sog 0.6094404263418347
# neuron unit number: 17
# accuracy_score_orignial 0.6111111111111112
# recall_score_original 0.5694444444444444
# precision_score_original 0.5676691729323309
# f1_score_original 0.5683288922725542
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 238)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6111111111111112
# precision_score_sog 0.6082706766917293
# f1_score_sog 0.6094404263418347
# neuron unit number: 22
# accuracy_score_orignial 0.6111111111111112
# recall_score_original 0.5555555555555556
# precision_score_original 0.5572337042925278
# f1_score_original 0.5561643835616438
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 308)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6180555555555556
# precision_score_sog 0.6125
# f1_score_sog 0.6142857142857143
# neuron unit number: 27
# accuracy_score_orignial 0.6481481481481481
# recall_score_original 0.6111111111111112
# precision_score_original 0.6082706766917293
# f1_score_original 0.6094404263418347
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 378)
# accuracy_score_sog 0.6203703703703703
# recall_score_sog 0.6041666666666667
# precision_score_sog 0.5952380952380952
# f1_score_sog 0.5950617283950618
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.5694444444444444
# precision_score_original 0.5704500978473581
# f1_score_original 0.5698882952889752
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 448)
# accuracy_score_sog 0.6759259259259259
# recall_score_sog 0.6388888888888888
# precision_score_sog 0.6370384468976018
# f1_score_sog 0.6378963502251174
# neuron unit number: 37
# accuracy_score_orignial 0.6296296296296297
# recall_score_original 0.5833333333333333
# precision_score_original 0.5833333333333333
# f1_score_original 0.5833333333333333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 518)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5972222222222222
# precision_score_sog 0.5926470588235294
# f1_score_sog 0.5939849624060152
# neuron unit number: 42
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.5694444444444444
# precision_score_original 0.5704500978473581
# f1_score_original 0.5698882952889752
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 588)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.6180555555555556
# precision_score_sog 0.6164826798629616
# f1_score_sog 0.6172047130951241
# neuron unit number: 47
# accuracy_score_orignial 0.6296296296296297
# recall_score_original 0.5833333333333333
# precision_score_original 0.5833333333333333
# f1_score_original 0.5833333333333333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 658)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.6111111111111112
# precision_score_sog 0.6048416454313797
# f1_score_sog 0.606465476969074
# neuron unit number: 52
# accuracy_score_orignial 0.6666666666666666
# recall_score_original 0.6319444444444444
# precision_score_original 0.6285714285714286
# f1_score_original 0.629996193376475
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 728)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.576388888888889
# precision_score_sog 0.5786963434022258
# f1_score_sog 0.5772994129158512
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 57
# accuracy_score_orignial 0.6759259259259259
# recall_score_original 0.6527777777777778
# precision_score_original 0.6441572624681471
# f1_score_original 0.646827992151733
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 798)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6180555555555556
# precision_score_sog 0.6125
# f1_score_sog 0.6142857142857143
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 62
# accuracy_score_orignial 0.6481481481481481
# recall_score_original 0.6111111111111112
# precision_score_original 0.6082706766917293
# f1_score_original 0.6094404263418347
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 868)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6041666666666667
# precision_score_sog 0.6041666666666667
# f1_score_sog 0.6041666666666667
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 67
# accuracy_score_orignial 0.6296296296296297
# recall_score_original 0.576388888888889
# precision_score_original 0.5786963434022258
# f1_score_original 0.5772994129158512
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 938)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6041666666666667
# precision_score_sog 0.6041666666666667
# f1_score_sog 0.6041666666666667
# neuron unit number: 72
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5972222222222222
# precision_score_original 0.5959269128283213
# f1_score_original 0.5965130759651307
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1008)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6111111111111112
# precision_score_sog 0.6082706766917293
# f1_score_sog 0.6094404263418347
# neuron unit number: 77
# accuracy_score_orignial 0.6296296296296297
# recall_score_original 0.5902777777777778
# precision_score_original 0.58796992481203
# f1_score_original 0.5888846593071946
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1078)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6041666666666667
# precision_score_sog 0.6041666666666667
# f1_score_sog 0.6041666666666667
# neuron unit number: 82
# accuracy_score_orignial 0.6574074074074074
# recall_score_original 0.6180555555555556
# precision_score_original 0.6164826798629616
# f1_score_original 0.6172047130951241
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1148)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.6111111111111112
# precision_score_sog 0.6127201565557729
# f1_score_sog 0.6118504128217581
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.6481481481481481
# recall_score_original 0.6111111111111112
# precision_score_original 0.6082706766917293
# f1_score_original 0.6094404263418347
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1218)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.6041666666666667
# precision_score_sog 0.600334448160535
# f1_score_sog 0.6017021276595745
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 92
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5972222222222222
# precision_score_original 0.5959269128283213
# f1_score_original 0.5965130759651307
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1288)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.6180555555555556
# precision_score_sog 0.6164826798629616
# f1_score_sog 0.6172047130951241
# neuron unit number: 97
# accuracy_score_orignial 0.6666666666666666
# recall_score_original 0.6319444444444444
# precision_score_original 0.6285714285714286
# f1_score_original 0.629996193376475
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1358)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.6180555555555556
# precision_score_sog 0.6125
# f1_score_sog 0.6142857142857143
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.6393518518518518
# all_recall_score_original mean 0.5975694444444444
# all_precision_score_original mean 0.5960181505737308
# all_f1_score_original mean 0.5965511079543002
# all_accuracy_score_sog mean 0.6467592592592594
# all_recall_score_sog mean 0.6093749999999999
# all_precision_score_sog mean 0.6069853538624481
# all_f1_score_sog mean 0.6074266659811921
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.639352  0.018875  0.004220   0.630518
# 1       all_accuracy_score_sog  20.0  0.646759  0.012119  0.002710   0.641087
# 2                     combined  40.0  0.643056  0.016099  0.002545   0.637907
#
#    Interval
# 0  0.648185
# 1  0.652431
# 2  0.648204
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0074
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.4769
# 3                           Two side test p value =    0.1479
# 4                          Difference < 0 p value =    0.0740
# 5                          Difference > 0 p value =    0.9260
# 6                                       Cohen's d =   -0.4670
# 7                                       Hedge's g =   -0.4578
# 8                                  Glass's delta1 =   -0.3925
# 9                                Point-Biserial r =   -0.2330
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.597569  0.026127  0.005842   0.585341
# 1       all_recall_score_sog  20.0  0.609375  0.012107  0.002707   0.603709
# 2                   combined  40.0  0.603472  0.020969  0.003316   0.596766
#
#    Interval
# 0  0.609797
# 1  0.615041
# 2  0.610179
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0118
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.8334
# 3                           Two side test p value =    0.0746
# 4                          Difference < 0 p value =    0.0373
# 5                          Difference > 0 p value =    0.9627
# 6                                       Cohen's d =   -0.5798
# 7                                       Hedge's g =   -0.5683
# 8                                  Glass's delta1 =   -0.4518
# 9                                Point-Biserial r =   -0.2851
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.596018  0.023904  0.005345
# 1        all_accuracy_score_sog  20.0  0.646759  0.012119  0.002710
# 2                      combined  40.0  0.621389  0.031782  0.005025
#
#    95% Conf.  Interval
# 0   0.584831  0.607205
# 1   0.641087  0.652431
# 2   0.611224  0.631553
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0507
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -8.4671
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.6775
# 7                                       Hedge's g =   -2.6243
# 8                                  Glass's delta1 =   -2.1227
# 9                                Point-Biserial r =   -0.8084
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.596551  0.024797  0.005545   0.584946
# 1       all_f1_score_sog  20.0  0.607427  0.011831  0.002646   0.601889
# 2               combined  40.0  0.601989  0.019952  0.003155   0.595608
#
#    Interval
# 0  0.608157
# 1  0.612964
# 2  0.608370
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0109
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.7702
# 3                           Two side test p value =    0.0847
# 4                          Difference < 0 p value =    0.0424
# 5                          Difference > 0 p value =    0.9576
# 6                                       Cohen's d =   -0.5598
# 7                                       Hedge's g =   -0.5487
# 8                                  Glass's delta1 =   -0.4386
# 9                                Point-Biserial r =   -0.2760

# %%
#Decision Tree2 
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6851851851851852
# recall_score_original 0.642950676560454
# precision_score_original 0.6246669204415684
# f1_score_original 0.6290909090909091
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 28)
# accuracy_score_sog 0.6851851851851852
# recall_score_sog 0.5993016150152771
# precision_score_sog 0.5993016150152771
# f1_score_sog 0.5993016150152771
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.6666666666666666
# recall_score_original 0.6084679179397643
# precision_score_original 0.5972602739726027
# f1_score_original 0.600328947368421
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 98)
# accuracy_score_sog 0.6666666666666666
# recall_score_sog 0.5866433871671759
# precision_score_sog 0.5831587767071638
# f1_score_sog 0.5846153846153846
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.6944444444444444
# recall_score_original 0.6056307289393278
# precision_score_original 0.6080357142857142
# f1_score_original 0.6067527308838133
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 168)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5722391968572675
# precision_score_sog 0.5629996193376475
# f1_score_sog 0.5636363636363636
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.6018518518518519
# recall_score_original 0.5859886512439982
# precision_score_original 0.5690743338008415
# f1_score_original 0.5608510638297872
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 238)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5785683107813182
# precision_score_sog 0.5694444444444444
# f1_score_sog 0.5708609271523178
# Not good recall_score result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.6666666666666666
# recall_score_original 0.5866433871671759
# precision_score_original 0.5831587767071638
# f1_score_original 0.5846153846153846
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 308)
# accuracy_score_sog 0.6481481481481481
# recall_score_sog 0.5958096900916631
# precision_score_sog 0.5835553863722878
# f1_score_sog 0.5854545454545454
# Not good accuracy result !!!!!
# neuron unit number: 27
# accuracy_score_orignial 0.7129629629629629
# recall_score_original 0.6292012221737233
# precision_score_original 0.6321428571428571
# f1_score_original 0.6305858987090367
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 378)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6182889567874291
# precision_score_sog 0.6271106941838649
# f1_score_sog 0.6219085262563524
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.6759259259259259
# recall_score_original 0.614797031863815
# precision_score_original 0.6045310015898251
# f1_score_original 0.6078431372549019
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 448)
# accuracy_score_sog 0.6759259259259259
# recall_score_sog 0.5929725010912266
# precision_score_sog 0.591025641025641
# f1_score_sog 0.5919248623556083
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 37
# accuracy_score_orignial 0.6296296296296297
# recall_score_original 0.6049759930161501
# precision_score_original 0.586046511627907
# f1_score_original 0.5833333333333333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 518)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6182889567874291
# precision_score_sog 0.6271106941838649
# f1_score_sog 0.6219085262563524
# neuron unit number: 42
# accuracy_score_orignial 0.6944444444444444
# recall_score_original 0.6274552597119162
# precision_score_original 0.6200657894736843
# f1_score_original 0.6230565838180857
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 588)
# accuracy_score_sog 0.6759259259259259
# recall_score_sog 0.5820602357049323
# precision_score_sog 0.5839285714285715
# f1_score_sog 0.5829195630585898
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 47
# accuracy_score_orignial 0.6666666666666666
# recall_score_original 0.6412047140986469
# precision_score_original 0.6177648343647616
# f1_score_original 0.6195694716242661
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 658)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5722391968572675
# precision_score_sog 0.5629996193376475
# f1_score_sog 0.5636363636363636
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 52
# accuracy_score_orignial 0.6851851851851852
# recall_score_original 0.6102138804015713
# precision_score_original 0.6057813154587348
# f1_score_original 0.6076923076923078
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 728)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5831514622435617
# precision_score_sog 0.5707915273132664
# f1_score_sog 0.5707472178060413
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 57
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.5768223483195112
# precision_score_original 0.5647058823529412
# f1_score_original 0.5634427684117125
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 798)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.6527717154081187
# precision_score_sog 0.65625
# f1_score_sog 0.6544190665342602
# neuron unit number: 62
# accuracy_score_orignial 0.6111111111111112
# recall_score_original 0.5595809690091663
# precision_score_original 0.5507246376811594
# f1_score_original 0.5492845786963434
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 868)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5785683107813182
# precision_score_sog 0.5694444444444444
# f1_score_sog 0.5708609271523178
# neuron unit number: 67
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5785683107813182
# precision_score_original 0.5694444444444444
# f1_score_original 0.5708609271523178
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 938)
# accuracy_score_sog 0.6759259259259259
# recall_score_sog 0.6038847664775208
# precision_score_sog 0.5978618421052632
# f1_score_sog 0.600211528291909
# neuron unit number: 72
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.5768223483195112
# precision_score_original 0.5647058823529412
# f1_score_original 0.5634427684117125
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1008)
# accuracy_score_sog 0.6666666666666666
# recall_score_sog 0.5866433871671759
# precision_score_sog 0.5831587767071638
# f1_score_sog 0.5846153846153846
# neuron unit number: 77
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.6003928415539066
# precision_score_original 0.5845588235294117
# f1_score_original 0.5847382431233363
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1078)
# accuracy_score_sog 0.6759259259259259
# recall_score_sog 0.6257092972501092
# precision_score_sog 0.6111111111111112
# f1_score_sog 0.6148751910341315
# neuron unit number: 82
# accuracy_score_orignial 0.7129629629629629
# recall_score_original 0.6401134875600175
# precision_score_original 0.6371794871794871
# f1_score_original 0.6385620209435389
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1148)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5722391968572675
# precision_score_sog 0.5629996193376475
# f1_score_sog 0.5636363636363636
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.6111111111111112
# recall_score_original 0.5923177651680489
# precision_score_original 0.5746031746031746
# f1_score_original 0.5683288922725542
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1218)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5785683107813182
# precision_score_sog 0.5694444444444444
# f1_score_sog 0.5708609271523178
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# neuron unit number: 92
# accuracy_score_orignial 0.6851851851851852
# recall_score_original 0.6211261457878656
# precision_score_original 0.6121212121212122
# f1_score_original 0.6154168412232929
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1288)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.5694020078568311
# precision_score_sog 0.5679487179487179
# f1_score_sog 0.5686062830616432
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 97
# accuracy_score_orignial 0.6666666666666666
# recall_score_original 0.6084679179397643
# precision_score_original 0.5972602739726027
# f1_score_original 0.600328947368421
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1358)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6182889567874291
# precision_score_sog 0.6271106941838649
# f1_score_sog 0.6219085262563524
# all_accuracy_score_original mean 0.6592592592592592
# all_recall_score_original mean 0.6055870798777826
# all_precision_score_original mean 0.5951916073551518
# all_f1_score_original mean 0.5954062877911739
# all_accuracy_score_sog mean 0.6666666666666667
# all_recall_score_sog mean 0.5942819729375819
# all_precision_score_sog mean 0.5903378119816167
# all_f1_score_sog mean 0.5903454046488937
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.659259  0.035111  0.007851   0.642827
# 1       all_accuracy_score_sog  20.0  0.666667  0.032075  0.007172   0.651655
# 2                     combined  40.0  0.662963  0.033404  0.005282   0.652280
#
#    Interval
# 0  0.675692
# 1  0.681678
# 2  0.673646
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0074
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -0.6966
# 3                           Two side test p value =    0.4903
# 4                          Difference < 0 p value =    0.2451
# 5                          Difference > 0 p value =    0.7549
# 6                                       Cohen's d =   -0.2203
# 7                                       Hedge's g =   -0.2159
# 8                                  Glass's delta1 =   -0.2110
# 9                                Point-Biserial r =   -0.1123
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.605587  0.023736  0.005308   0.594478
# 1       all_recall_score_sog  20.0  0.594282  0.022321  0.004991   0.583835
# 2                   combined  40.0  0.599935  0.023452  0.003708   0.592434
#
#    Interval
# 0  0.616696
# 1  0.604729
# 2  0.607435
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...   0.0113
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    1.5517
# 3                           Two side test p value =    0.1290
# 4                          Difference < 0 p value =    0.9355
# 5                          Difference > 0 p value =    0.0645
# 6                                       Cohen's d =    0.4907
# 7                                       Hedge's g =    0.4809
# 8                                  Glass's delta1 =    0.4763
# 9                                Point-Biserial r =    0.2441
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.595192  0.024848  0.005556
# 1        all_accuracy_score_sog  20.0  0.666667  0.032075  0.007172
# 2                      combined  40.0  0.630929  0.045956  0.007266
#
#    95% Conf.  Interval
# 0   0.583562  0.606821
# 1   0.651655  0.681678
# 2   0.616232  0.645627
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0715
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -7.8781
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.4913
# 7                                       Hedge's g =   -2.4418
# 8                                  Glass's delta1 =   -2.8764
# 9                                Point-Biserial r =   -0.7876
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.595406  0.026698  0.005970   0.582911
# 1       all_f1_score_sog  20.0  0.590345  0.025294  0.005656   0.578507
# 2               combined  40.0  0.592876  0.025798  0.004079   0.584625
#
#    Interval
# 0  0.607901
# 1  0.602184
# 2  0.601126
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...   0.0051
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.6154
# 3                           Two side test p value =    0.5420
# 4                          Difference < 0 p value =    0.7290
# 5                          Difference > 0 p value =    0.2710
# 6                                       Cohen's d =    0.1946
# 7                                       Hedge's g =    0.1907
# 8                                  Glass's delta1 =    0.1896
# 9                                Point-Biserial r =    0.0993

# %%
#LinearDiscriminantAnalysis()
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 28)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6767001114827201
# precision_score_sog 0.6992040217846669
# f1_score_sog 0.6829745596868884
# neuron unit number: 7
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 98)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.6950947603121516
# precision_score_sog 0.708664546899841
# f1_score_sog 0.6999712616150973
# neuron unit number: 12
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 168)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6861761426978819
# precision_score_sog 0.6883458646616541
# f1_score_sog 0.6871905073343922
# neuron unit number: 17
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 238)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# neuron unit number: 22
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 308)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 27
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 378)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.7006688963210703
# precision_score_sog 0.7083333333333333
# f1_score_sog 0.7038297872340424
# neuron unit number: 32
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 448)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 37
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 518)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 42
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 588)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# neuron unit number: 47
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 658)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 52
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 728)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 57
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 798)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# neuron unit number: 62
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 868)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# neuron unit number: 67
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 938)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# neuron unit number: 72
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1008)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 77
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1078)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# neuron unit number: 82
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1148)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 87
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1218)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 92
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1288)
# accuracy_score_sog 0.7129629629629629
# recall_score_sog 0.6806020066889632
# precision_score_sog 0.6875
# f1_score_sog 0.6834042553191488
# neuron unit number: 97
# accuracy_score_orignial 0.7037037037037037
# recall_score_original 0.6733556298773691
# precision_score_original 0.6775789874381424
# f1_score_original 0.675187969924812
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1358)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6878483835005574
# precision_score_sog 0.6978473581213307
# f1_score_sog 0.6916634944803959
# all_accuracy_score_original mean 0.7037037037037038
# all_recall_score_original mean 0.6733556298773691
# all_precision_score_original mean 0.6775789874381424
# all_f1_score_original mean 0.675187969924812
# all_accuracy_score_sog mean 0.7185185185185186
# all_recall_score_sog mean 0.6849498327759197
# all_precision_score_sog mean 0.6938489636764406
# all_f1_score_sog mean 0.6883124437552766
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.703704  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.718519  6.301454e-03  1.409048e-03
# 2                     combined  40.0  0.711111  8.696073e-03  1.374970e-03
#
#    95% Conf.  Interval
# 0   0.703704  0.703704
# 1   0.715569  0.721468
# 2   0.708330  0.713892
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -1.480000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.051410e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.324800e+00
# 7                                       Hedge's g =  -3.258800e+00
# 8                                  Glass's delta1 =  -1.300612e+14
# 9                                Point-Biserial r =  -8.627000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.673356  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.684950  0.005842  0.001306   0.682216
# 2                   combined  40.0  0.679153  0.007148  0.001130   0.676867
#
#    Interval
# 0       NaN
# 1  0.687684
# 2  0.681439
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0116
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -8.8751
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.8066
# 7                                       Hedge's g =   -2.7508
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8213
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.677579  0.000000  0.000000
# 1        all_accuracy_score_sog  20.0  0.718519  0.006301  0.001409
# 2                      combined  40.0  0.698049  0.021192  0.003351
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.715569  0.721468
# 2   0.691271  0.704826
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0409
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -29.0547
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -9.1879
# 7                                       Hedge's g =   -9.0054
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9782
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.675188  0.000000  0.000000        NaN
# 1       all_f1_score_sog  20.0  0.688312  0.006078  0.001359   0.685468
# 2               combined  40.0  0.681750  0.007884  0.001247   0.679229
#
#    Interval
# 0       NaN
# 1  0.691157
# 2  0.684272
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0131
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -9.6570
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.0538
# 7                                       Hedge's g =   -2.9931
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8429
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#KNN
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 28)
# accuracy_score_sog 0.6666666666666666
# recall_score_sog 0.6195694716242661
# precision_score_sog 0.6195694716242661
# f1_score_sog 0.6195694716242661
# neuron unit number: 7
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 98)
# accuracy_score_sog 0.7037037037037037
# recall_score_sog 0.6320939334637965
# precision_score_sog 0.654320987654321
# f1_score_sog 0.6380393799748638
# neuron unit number: 12
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 168)
# accuracy_score_sog 0.75
# recall_score_sog 0.6812133072407045
# precision_score_sog 0.7171669793621014
# f1_score_sog 0.6915917503966156
# neuron unit number: 17
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 238)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.6600782778864971
# precision_score_sog 0.6918386491557224
# f1_score_sog 0.6687466948704389
# neuron unit number: 22
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 308)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.6749510763209393
# precision_score_sog 0.691025641025641
# f1_score_sog 0.6808965868568517
# neuron unit number: 27
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 378)
# accuracy_score_sog 0.75
# recall_score_sog 0.6960861056751467
# precision_score_sog 0.714102564102564
# f1_score_sog 0.7029037187977585
# neuron unit number: 32
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 448)
# accuracy_score_sog 0.75
# recall_score_sog 0.6886497064579256
# precision_score_sog 0.7151785714285714
# f1_score_sog 0.6974789915966386
# neuron unit number: 37
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 518)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6606653620352251
# precision_score_sog 0.6791793976429507
# f1_score_sog 0.6669407894736843
# neuron unit number: 42
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 588)
# accuracy_score_sog 0.8148148148148148
# recall_score_sog 0.7589041095890411
# precision_score_sog 0.8024691358024691
# f1_score_sog 0.7737746124842899
# neuron unit number: 47
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 658)
# accuracy_score_sog 0.7222222222222222
# recall_score_sog 0.6755381604696673
# precision_score_sog 0.6812121212121212
# f1_score_sog 0.6780604133545309
# neuron unit number: 52
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 728)
# accuracy_score_sog 0.7407407407407407
# recall_score_sog 0.6669275929549902
# precision_score_sog 0.7055421686746988
# f1_score_sog 0.676923076923077
# neuron unit number: 57
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 798)
# accuracy_score_sog 0.7592592592592593
# recall_score_sog 0.7103718199608611
# precision_score_sog 0.7251780477586929
# f1_score_sog 0.7163636363636363
# neuron unit number: 62
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 868)
# accuracy_score_sog 0.7037037037037037
# recall_score_sog 0.6544031311154599
# precision_score_sog 0.6593939393939394
# f1_score_sog 0.656597774244833
# neuron unit number: 67
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 938)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.6600782778864971
# precision_score_sog 0.6918386491557224
# f1_score_sog 0.6687466948704389
# neuron unit number: 72
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1008)
# accuracy_score_sog 0.7592592592592593
# recall_score_sog 0.6880626223091977
# precision_score_sog 0.731566265060241
# f1_score_sog 0.7
# neuron unit number: 77
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1078)
# accuracy_score_sog 0.7870370370370371
# recall_score_sog 0.7234833659491193
# precision_score_sog 0.7678236397748592
# f1_score_sog 0.7372818614489688
# neuron unit number: 82
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1148)
# accuracy_score_sog 0.7407407407407407
# recall_score_sog 0.6669275929549902
# precision_score_sog 0.7055421686746988
# f1_score_sog 0.676923076923077
# neuron unit number: 87
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1218)
# accuracy_score_sog 0.7777777777777778
# recall_score_sog 0.7166340508806262
# precision_score_sog 0.7530864197530864
# f1_score_sog 0.7285295349811479
# neuron unit number: 92
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1288)
# accuracy_score_sog 0.7592592592592593
# recall_score_sog 0.6954990215264187
# precision_score_sog 0.728395061728395
# f1_score_sog 0.705906996229577
# neuron unit number: 97
# accuracy_score_orignial 0.6203703703703703
# recall_score_original 0.510958904109589
# precision_score_original 0.5159090909090909
# f1_score_original 0.49994353472614333
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1358)
# accuracy_score_sog 0.7314814814814815
# recall_score_sog 0.6600782778864971
# precision_score_sog 0.6918386491557224
# f1_score_sog 0.6687466948704389
# all_accuracy_score_original mean 0.6203703703703703
# all_recall_score_original mean 0.5109589041095891
# all_precision_score_original mean 0.5159090909090909
# all_f1_score_original mean 0.4999435347261432
# all_accuracy_score_sog mean 0.7416666666666667
# all_recall_score_sog mean 0.6795107632093933
# all_precision_score_sog mean 0.7063134264070392
# all_f1_score_sog mean 0.6877010878142567
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.620370  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.741667  0.032061  0.007169   0.726662
# 2                     combined  40.0  0.681019  0.065370  0.010336   0.660112
#
#    Interval
# 0       NaN
# 1  0.756672
# 2  0.701925
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.1213
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -16.9194
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -5.3504
# 7                                       Hedge's g =   -5.2441
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9396
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.510959  1.139065e-16  2.547026e-17
# 1       all_recall_score_sog  20.0  0.679511  3.209388e-02  7.176409e-03
# 2                   combined  40.0  0.595235  8.824029e-02  1.395202e-02
#
#    95% Conf.  Interval
# 0   0.510959  0.510959
# 1   0.664490  0.694531
# 2   0.567014  0.623455
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -1.686000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -2.348690e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.427200e+00
# 7                                       Hedge's g =  -7.279700e+00
# 8                                  Glass's delta1 =  -1.479739e+15
# 9                                Point-Biserial r =  -9.672000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.515909  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.706313  0.040791  0.009121
# 2                      combined  40.0  0.611111  0.100531  0.015895
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.687223  0.725404
# 2   0.578960  0.643263
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.1904
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -20.8750
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -6.6013
# 7                                       Hedge's g =   -6.4701
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9591
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.499944  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.687701  3.489532e-02  7.802830e-03
# 2               combined  40.0  0.593822  9.814497e-02  1.551808e-02
#
#    95% Conf.  Interval
# 0   0.499944  0.499944
# 1   0.671370  0.704033
# 2   0.562434  0.625211
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.878000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -2.406270e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.609300e+00
# 7                                       Hedge's g =  -7.458100e+00
# 8                                  Glass's delta1 =  -1.648348e+15
# 9                                Point-Biserial r =  -9.687000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#SVM
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 10
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 140)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5278706800445931
# precision_score_sog 0.5765306122448979
# f1_score_sog 0.4852743492606623
# neuron unit number: 15
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 210)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5206243032329989
# precision_score_sog 0.5520149953139644
# f1_score_sog 0.4795180722891566
# Not good accuracy result !!!!!
# neuron unit number: 20
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 280)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5278706800445931
# precision_score_sog 0.5765306122448979
# f1_score_sog 0.4852743492606623
# neuron unit number: 25
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 350)
# accuracy_score_sog 0.6296296296296297
# recall_score_sog 0.5206243032329989
# precision_score_sog 0.5520149953139644
# f1_score_sog 0.4795180722891566
# Not good accuracy result !!!!!
# neuron unit number: 30
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 420)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5222965440356745
# precision_score_sog 0.575
# f1_score_sog 0.469721767594108
# neuron unit number: 35
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 490)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5278706800445931
# precision_score_sog 0.5765306122448979
# f1_score_sog 0.4852743492606623
# neuron unit number: 40
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 560)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 45
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 630)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5222965440356745
# precision_score_sog 0.575
# f1_score_sog 0.469721767594108
# neuron unit number: 50
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 700)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 55
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 770)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.5256410256410257
# precision_score_sog 0.8254716981132075
# f1_score_sog 0.44306620209059233
# neuron unit number: 60
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 840)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 65
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 910)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 70
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 980)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 75
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1050)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 80
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1120)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 85
# accuracy_score_orignial 0.6388888888888888
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1190)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 90
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1260)
# accuracy_score_sog 0.6574074074074074
# recall_score_sog 0.5256410256410257
# precision_score_sog 0.8254716981132075
# f1_score_sog 0.44306620209059233
# neuron unit number: 95
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1330)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# neuron unit number: 100
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6388888888888888
# recall_score_original 0.5
# precision_score_original 0.3194444444444444
# f1_score_original 0.38983050847457623
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (254, 1400)
# accuracy_score_sog 0.6388888888888888
# recall_score_sog 0.5
# precision_score_sog 0.3194444444444444
# f1_score_sog 0.38983050847457623
# all_accuracy_score_original mean 0.638888888888889
# all_recall_score_original mean 0.5
# all_precision_score_original mean 0.3194444444444445
# all_f1_score_original mean 0.38983050847457623
# all_accuracy_score_sog mean 0.6398635477582847
# all_recall_score_sog mean 0.5116176729449041
# all_precision_score_sog mean 0.46468471937018324
# all_f1_score_sog mean 0.4283547482355507
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  19.0  0.638889  1.140646e-16  2.616821e-17
# 1       all_accuracy_score_sog  19.0  0.639864  6.828411e-03  1.566545e-03
# 2                     combined  38.0  0.639376  4.788258e-03  7.767580e-04
#
#    95% Conf.  Interval
# 0   0.638889  0.638889
# 1   0.636572  0.643155
# 2   0.637802  0.640950
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -1.000000e-03
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -6.222000e-01
# 3                           Two side test p value =   5.378000e-01
# 4                          Difference < 0 p value =   2.689000e-01
# 5                          Difference > 0 p value =   7.311000e-01
# 6                                       Cohen's d =  -2.019000e-01
# 7                                       Hedge's g =  -1.976000e-01
# 8                                  Glass's delta1 =  -8.544799e+12
# 9                                Point-Biserial r =  -1.031000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  19.0  0.500000  0.000000  0.000000        NaN
# 1       all_recall_score_sog  19.0  0.511618  0.012749  0.002925   0.505473
# 2                   combined  38.0  0.505809  0.010664  0.001730   0.502304
#
#    Interval
# 0       NaN
# 1  0.517763
# 2  0.509314
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0116
# 1                              Degrees of freedom =   36.0000
# 2                                               t =   -3.9720
# 3                           Two side test p value =    0.0003
# 4                          Difference < 0 p value =    0.0002
# 5                          Difference > 0 p value =    0.9998
# 6                                       Cohen's d =   -1.2887
# 7                                       Hedge's g =   -1.2617
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.5520
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  19.0  0.319444  5.703229e-17  1.308410e-17
# 1        all_accuracy_score_sog  19.0  0.639864  6.828411e-03  1.566545e-03
# 2                      combined  38.0  0.479654  1.624300e-01  2.634962e-02
#
#    95% Conf.  Interval
# 0   0.319444  0.319444
# 1   0.636572  0.643155
# 2   0.426265  0.533043
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -3.204000e-01
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -2.045387e+02
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -6.636110e+01
# 7                                       Hedge's g =  -6.496890e+01
# 8                                  Glass's delta1 =  -5.618205e+15
# 9                                Point-Biserial r =  -9.996000e-01
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  19.0  0.389831  0.000000  0.000000        NaN
# 1       all_f1_score_sog  19.0  0.428355  0.043238  0.009919   0.407515
# 2               combined  38.0  0.409093  0.035924  0.005828   0.397285
#
#    Interval
# 0       NaN
# 1  0.449195
# 2  0.420901
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0385
# 1                              Degrees of freedom =   36.0000
# 2                                               t =   -3.8837
# 3                           Two side test p value =    0.0004
# 4                          Difference < 0 p value =    0.0002
# 5                          Difference > 0 p value =    0.9998
# 6                                       Cohen's d =   -1.2600
# 7                                       Hedge's g =   -1.2336
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.5434
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
# new baseN endoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6953097310282361
# train_discrete_score_W_discrete_n 0.04326253811712573
# train_discrete_score_W_discrete_a 0.09731587561397101
# test_discrete_score_W_discrete_p 0.6955522881823194
# test_discrete_score_W_discrete_n 0.04345292462000796
# test_discrete_score_W_discrete_a 0.09656268608757898
# neuron unit number: 7
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.69176544717048
# train_discrete_score_W_discrete_n 0.03444068055922682
# train_discrete_score_W_discrete_a 0.06728539141775902
# test_discrete_score_W_discrete_p 0.6916927035471421
# test_discrete_score_W_discrete_n 0.03472899397007041
# test_discrete_score_W_discrete_a 0.06514567851904932
# neuron unit number: 12
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6836529752293939
# train_discrete_score_W_discrete_n 0.03097589986307165
# train_discrete_score_W_discrete_a 0.07985565865091211
# test_discrete_score_W_discrete_p 0.6804815291306745
# test_discrete_score_W_discrete_n 0.016999758823208123
# test_discrete_score_W_discrete_a 0.03528083672497463
# neuron unit number: 17
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6923167802150199
# train_discrete_score_W_discrete_n 0.03605149919283132
# train_discrete_score_W_discrete_a 0.07650686091922959
# test_discrete_score_W_discrete_p 0.695276603565521
# test_discrete_score_W_discrete_n 0.04065340718687777
# test_discrete_score_W_discrete_a 0.08329466407266593
# neuron unit number: 22
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6967274445713385
# train_discrete_score_W_discrete_n 0.04310752480848175
# train_discrete_score_W_discrete_a 0.09137267988318769
# test_discrete_score_W_discrete_p 0.6988605035839001
# test_discrete_score_W_discrete_n 0.045856649547437046
# test_discrete_score_W_discrete_a 0.09059787743776994
# neuron unit number: 27
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7081085338479108
# train_discrete_score_W_discrete_n 0.0596154773852049
# train_discrete_score_W_discrete_a 0.11638279240630763
# test_discrete_score_W_discrete_p 0.7106230472339643
# test_discrete_score_W_discrete_n 0.06666923099377421
# test_discrete_score_W_discrete_a 0.1367539843612744
# neuron unit number: 32
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6931831607135824
# train_discrete_score_W_discrete_n 0.039668647050982636
# train_discrete_score_W_discrete_a 0.08998452118447262
# test_discrete_score_W_discrete_p 0.6936224958647308
# test_discrete_score_W_discrete_n 0.04348544172909356
# test_discrete_score_W_discrete_a 0.10060807988890706
# neuron unit number: 37
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.00010917793052395891
# test_discrete_score_W0_a 0.0002960282515012402
# train_discrete_score_W_discrete_p 0.6975938250699012
# train_discrete_score_W_discrete_n 0.04587115966441047
# train_discrete_score_W_discrete_a 0.10052000654708493
# test_discrete_score_W_discrete_p 0.6959198676713839
# test_discrete_score_W_discrete_n 0.041265007132878576
# test_discrete_score_W_discrete_a 0.07928224622063422
# neuron unit number: 42
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6895207340605679
# train_discrete_score_W_discrete_n 0.03174917817650994
# train_discrete_score_W_discrete_a 0.06812664567130206
# test_discrete_score_W_discrete_p 0.6919683881639405
# test_discrete_score_W_discrete_n 0.03581007091058591
# test_discrete_score_W_discrete_a 0.07529934296295072
# neuron unit number: 47
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.00010917793052395891
# test_discrete_score_W0_a 0.0002960282515012402
# train_discrete_score_W_discrete_p 0.6888118772890166
# train_discrete_score_W_discrete_n 0.03069934605615748
# train_discrete_score_W_discrete_a 0.06626639015465823
# test_discrete_score_W_discrete_p 0.6899467009740856
# test_discrete_score_W_discrete_n 0.032245915909842965
# test_discrete_score_W_discrete_a 0.06537667480593996
# neuron unit number: 52
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.699917300043319
# train_discrete_score_W_discrete_n 0.05043202810184655
# train_discrete_score_W_discrete_a 0.11043380783317634
# test_discrete_score_W_discrete_p 0.7006984010292225
# test_discrete_score_W_discrete_n 0.04978004092562024
# test_discrete_score_W_discrete_a 0.10447545194454617
# neuron unit number: 57
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6726704649880537
# test_discrete_score_W0_n 0.0015523700903355925
# test_discrete_score_W0_a 0.0032148421527858637
# train_discrete_score_W_discrete_p 0.6907021620131533
# train_discrete_score_W_discrete_n 0.03344400710547887
# train_discrete_score_W_discrete_a 0.07083086973757803
# test_discrete_score_W_discrete_p 0.6940819702260614
# test_discrete_score_W_discrete_n 0.03843314382136326
# test_discrete_score_W_discrete_a 0.07302036656873047
# neuron unit number: 62
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6916473043752215
# train_discrete_score_W_discrete_n 0.03426135859696995
# train_discrete_score_W_discrete_a 0.06703860772204544
# test_discrete_score_W_discrete_p 0.6929792317588679
# test_discrete_score_W_discrete_n 0.039352991117927894
# test_discrete_score_W_discrete_a 0.08849352994606127
# neuron unit number: 67
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6722109906267231
# test_discrete_score_W0_n 0.00028257731912842437
# test_discrete_score_W0_a 0.0005873738087223438
# train_discrete_score_W_discrete_p 0.6918835899657386
# train_discrete_score_W_discrete_n 0.03812737215680614
# train_discrete_score_W_discrete_a 0.08782979119306458
# test_discrete_score_W_discrete_p 0.689487226612755
# test_discrete_score_W_discrete_n 0.03593156146547923
# test_discrete_score_W_discrete_a 0.08511119056652657
# neuron unit number: 72
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6932225416453354
# train_discrete_score_W_discrete_n 0.03700353838668257
# train_discrete_score_W_discrete_a 0.07574958293196125
# test_discrete_score_W_discrete_p 0.6941738650983275
# test_discrete_score_W_discrete_n 0.04103464624056018
# test_discrete_score_W_discrete_a 0.09139064805997857
# neuron unit number: 77
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6849131650454849
# train_discrete_score_W_discrete_n 0.026450509379738217
# train_discrete_score_W_discrete_a 0.06285689346180368
# test_discrete_score_W_discrete_p 0.6859952214666422
# test_discrete_score_W_discrete_n 0.027599592972566686
# test_discrete_score_W_discrete_a 0.0627907109506374
# neuron unit number: 82
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 3.1481829416792665e-05
# train_discrete_score_W0_a  8.504918657592544e-05
# test_discrete_score_W0_p 0.6723028854989892
# test_discrete_score_W0_n 0.0004995724532926685
# test_discrete_score_W0_a 0.0009769975606981425
# train_discrete_score_W_discrete_p 0.6831804040483598
# train_discrete_score_W_discrete_n 0.02220619587189063
# train_discrete_score_W_discrete_a 0.05044488039045294
# test_discrete_score_W_discrete_p 0.685903326594376
# test_discrete_score_W_discrete_n 0.026639134758527295
# test_discrete_score_W_discrete_a 0.05820707408483795
# neuron unit number: 87
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 3.1481829416792665e-05
# train_discrete_score_W0_a  8.504918657592544e-05
# test_discrete_score_W0_p 0.6722109906267231
# test_discrete_score_W0_n 0.0003153735851223236
# test_discrete_score_W0_a 0.0006858407215609151
# train_discrete_score_W_discrete_p 0.6886543535620053
# train_discrete_score_W_discrete_n 0.03235017638838458
# train_discrete_score_W_discrete_a 0.07500825120784334
# test_discrete_score_W_discrete_p 0.6888439625068921
# test_discrete_score_W_discrete_n 0.03183450888381467
# test_discrete_score_W_discrete_a 0.07077668273854286
# neuron unit number: 92
# train_discrete_score_W0_p 0.6724687906115858
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6721190957544569
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6966880636395857
# train_discrete_score_W_discrete_n 0.042276445687724366
# train_discrete_score_W_discrete_a 0.08550231542533407
# test_discrete_score_W_discrete_p 0.6942657599705936
# test_discrete_score_W_discrete_n 0.03966431777028728
# test_discrete_score_W_discrete_a 0.08435234897191012
# neuron unit number: 97
# train_discrete_score_W0_p 0.6725081715433388
# train_discrete_score_W0_n 0.00013891796526072593
# train_discrete_score_W0_a  8.294583280593737e-05
# test_discrete_score_W0_p 0.6723028854989892
# test_discrete_score_W0_n 0.0004995724532926685
# test_discrete_score_W0_a 0.0009769975606981425
# train_discrete_score_W_discrete_p 0.6946796361201906
# train_discrete_score_W_discrete_n 0.03951150655366499
# train_discrete_score_W_discrete_a 0.08235265870869944
# test_discrete_score_W_discrete_p 0.695276603565521
# test_discrete_score_W_discrete_n 0.04033159127405939
# test_discrete_score_W_discrete_a 0.0792268415233149
# test_discrete_score_W0_p mean 0.6721742326778167
# test_discrete_score_W_discrete_p mean 0.693282484837346
# test_discrete_score_W0_n mean 0.00016839108811097977
# test_discrete_score_W_discrete_n mean 0.03858844650269914
# test_discrete_score_W0_a mean 0.00035170541537339443
# test_discrete_score_W_discrete_a mean 0.08130234582184157
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000010  0.000032  0.000007  -0.000005  0.000025
# 1  train_dis_W_dis  20.0  0.037575  0.008479  0.001896   0.033607  0.041544
# 2         combined  40.0  0.018793  0.019921  0.003150   0.012422  0.025164
#                                Independent t-test    results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =     -0.0376
# 1                           Degrees of freedom =     38.0000
# 2                                            t =    -19.8133
# 3                        Two side test p value =      0.0000
# 4                       Difference < 0 p value =      0.0000
# 5                       Difference > 0 p value =      1.0000
# 6                                    Cohen's d =     -6.2655
# 7                                    Hedge's g =     -6.1410
# 8                               Glass's delta1 =  -1180.4026
# 9                             Point-Biserial r =     -0.9549
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000168  0.000366  0.000082  -0.000003  0.000340
# 1  test_dis_W_dis  20.0  0.038588  0.009951  0.002225   0.033931  0.043246
# 2        combined  40.0  0.019378  0.020659  0.003266   0.012771  0.025986
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0384
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -17.2541
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -5.4562
# 7                                  Hedge's g =    -5.3478
# 8                             Glass's delta1 =  -104.9754
# 9                           Point-Biserial r =    -0.9417
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000013  0.000031  0.000007  -0.000002  0.000027
# 1  train_dis_W_dis  20.0  0.081083  0.016606  0.003713   0.073311  0.088855
# 2         combined  40.0  0.040548  0.042657  0.006745   0.026906  0.054190
#                                Independent t-test    results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =     -0.0811
# 1                           Degrees of freedom =     38.0000
# 2                                            t =    -21.8329
# 3                        Two side test p value =      0.0000
# 4                       Difference < 0 p value =      0.0000
# 5                       Difference > 0 p value =      1.0000
# 6                                    Cohen's d =     -6.9042
# 7                                    Hedge's g =     -6.7670
# 8                               Glass's delta1 =  -2623.3697
# 9                             Point-Biserial r =     -0.9624
#          Variable     N      Mean        SD        SE     95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000352  0.000753  0.000168 -5.099048e-07  0.000704
# 1  test_dis_W_dis  20.0  0.081302  0.020797  0.004650  7.156913e-02  0.091036
# 2        combined  40.0  0.040827  0.043488  0.006876  2.691875e-02  0.054735
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0810
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -17.3962
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -5.5012
# 7                                  Hedge's g =    -5.3919
# 8                             Glass's delta1 =  -107.5651
# 9                           Point-Biserial r =    -0.9426
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.672471  0.000009  0.000002   0.672467  0.672475
# 1  train_dis_W_dis  20.0  0.692624  0.005796  0.001296   0.689912  0.695336
# 2         combined  40.0  0.682547  0.010977  0.001736   0.679037  0.686058
#                                Independent t-test    results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =     -0.0202
# 1                           Degrees of freedom =     38.0000
# 2                                            t =    -15.5510
# 3                        Two side test p value =      0.0000
# 4                       Difference < 0 p value =      0.0000
# 5                       Difference > 0 p value =      1.0000
# 6                                    Cohen's d =     -4.9177
# 7                                    Hedge's g =     -4.8200
# 8                               Glass's delta1 =  -2288.6156
# 9                             Point-Biserial r =     -0.9296
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.672174  0.000131  0.000029   0.672113  0.672236
# 1  test_dis_W_dis  20.0  0.693282  0.006200  0.001386   0.690381  0.696184
# 2        combined  40.0  0.682728  0.011532  0.001823   0.679040  0.686416
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0211
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -15.2220
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -4.8136
# 7                                  Hedge's g =    -4.7180
# 8                             Glass's delta1 =  -160.7392
# 9                           Point-Biserial r =    -0.9269
