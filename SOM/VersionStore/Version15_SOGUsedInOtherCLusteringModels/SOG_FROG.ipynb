# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("FrogCall/Frogs_MFCCs.csv")

csv = csv.sample(int(csv.shape[0]*0.1))
csv_original_encode = csv

dataread.label_encoding(csv,"Species")
dataread.label_encoding(csv,"Family")
dataread.label_encoding(csv,"Genus")


dataread.onehot_encoding(csv_original_encode,["Family","Genus"])

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)



csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Species")
# Out:
# self.data_continuous_indexes ['MFCCs_ 1', 'MFCCs_ 2', 'MFCCs_ 3', 'MFCCs_ 4', 'MFCCs_ 5', 'MFCCs_ 6', 'MFCCs_ 7', 'MFCCs_ 8', 'MFCCs_ 9', 'MFCCs_10', 'MFCCs_11', 'MFCCs_12', 'MFCCs_13', 'MFCCs_14', 'MFCCs_15', 'MFCCs_16', 'MFCCs_17', 'MFCCs_18', 'MFCCs_19', 'MFCCs_20', 'MFCCs_21', 'MFCCs_22', 'RecordID']
# self.continuous_feature_num 23
#  column number self.data_train_discrete 2

# %%
#fuzzy vs probability
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 10
# all_train_score_W0_p 0.9623015873015873
# all_train_score_W0_n 0.9638389640307494
# all_train_score_W0_a 0.9788259580858448
# test_score_W0_p0.9627906976744186
# test_score_W0_n 0.9621943169952373
# test_score_W0_a  0.9843632486011451
# all_train_score_W_combine_p 0.8988095238095238
# all_train_score_W_combine_n 0.8861466250577518
# all_train_score_W_combine_a 0.8853791050427721
# test_score_W_combine_p 0.8976744186046511
# test_score_W_combine_n 0.8733849372726216
# test_score_W_combine_a 0.8772241997872887
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 15
# all_train_score_W0_p 0.9940476190476191
# all_train_score_W0_n 0.9956118841431439
# all_train_score_W0_a 0.9992713941069834
# test_score_W0_p0.9813953488372092
# test_score_W0_n 0.9907150965810696
# test_score_W0_a  0.9980252380500205
# all_train_score_W_combine_p 0.9682539682539683
# all_train_score_W_combine_n 0.9483535499986094
# all_train_score_W_combine_a 0.972007902261922
# test_score_W_combine_p 0.9488372093023256
# test_score_W_combine_n 0.9309187741452103
# test_score_W_combine_a 0.9448416538439988
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 20
# all_train_score_W0_p 0.9940476190476191
# all_train_score_W0_n 0.9956118841431439
# all_train_score_W0_a 0.9992713941069834
# test_score_W0_p0.9813953488372092
# test_score_W0_n 0.9907150965810696
# test_score_W0_a  0.9980252380500205
# all_train_score_W_combine_p 0.9761904761904762
# all_train_score_W_combine_n 0.9606942175851072
# all_train_score_W_combine_a 0.9775088854993235
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9682403523007848
# test_score_W_combine_a 0.9840720157675851
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 25
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9623366962776867
# all_train_score_W_combine_a 0.9751213167704736
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9585583297498522
# test_score_W_combine_a 0.9810156583955614
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 30
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 0.9940476190476191
# all_train_score_W_combine_n 0.9856733372415746
# all_train_score_W_combine_a 0.9850284030812129
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9765982417397091
# test_score_W_combine_a 0.9867126437338295
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 35
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9623366962776867
# all_train_score_W_combine_a 0.9751213167704736
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9619020108587282
# test_score_W_combine_a 0.9816058451811916
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 40
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 1.0
# test_score_W_combine_n 1.0
# test_score_W_combine_a 1.0
# neuron unit number: 45
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 1.0
# test_score_W_combine_n 1.0
# test_score_W_combine_a 1.0
# neuron unit number: 50
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 55
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 60
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 65
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 70
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 75
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 80
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 85
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 1.0
# test_score_W_combine_n 1.0
# test_score_W_combine_a 1.0
# neuron unit number: 90
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 95
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9926256310608865
# test_score_W_combine_a 0.9992096083655834
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 100
# all_train_score_W0_p 1.0
# all_train_score_W0_n 1.0
# all_train_score_W0_a 1.0
# test_score_W0_p1.0
# test_score_W0_n 1.0
# test_score_W0_a  1.0
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 1.0
# test_score_W_combine_n 1.0
# test_score_W_combine_a 1.0
# test_score_W0_p mean 0.9960832313341492
# test_score_W_combine_p mean 0.9853121175030599
# test_score_W0_n mean 0.9970328689556515
# test_score_W_combine_n mean 0.979117543453415
# test_score_W0_a mean 0.9989691434053256
# test_score_W_combine_a mean 0.9867557101052475
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.997635  0.008299  0.001904   0.993635  1.001635
# 1  train_W_combine  19.0  0.984502  0.029490  0.006765   0.970289  0.998716
# 2         combined  38.0  0.991069  0.022380  0.003631   0.983712  0.998425
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =    0.0131
# 1                       Degrees of freedom =   36.0000
# 2                                        t =    1.8686
# 3                    Two side test p value =    0.0698
# 4                   Difference < 0 p value =    0.9651
# 5                   Difference > 0 p value =    0.0349
# 6                                Cohen's d =    0.6062
# 7                                Hedge's g =    0.5935
# 8                           Glass's delta1 =    1.5824
# 9                         Point-Biserial r =    0.2973
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.997033  0.008927  0.002048   0.992730  1.001336
# 1  test_W_combine  19.0  0.979118  0.031387  0.007201   0.963989  0.994246
# 2        combined  38.0  0.988075  0.024504  0.003975   0.980021  0.996129
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =    0.0179
# 1                     Degrees of freedom =   36.0000
# 2                                      t =    2.3931
# 3                  Two side test p value =    0.0220
# 4                 Difference < 0 p value =    0.9890
# 5                 Difference > 0 p value =    0.0110
# 6                              Cohen's d =    0.7764
# 7                              Hedge's g =    0.7601
# 8                         Glass's delta1 =    2.0069
# 9                       Point-Biserial r =    0.3705
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.998809  0.004845  0.001111   0.996474  1.001144
# 1  train_W_combine  19.0  0.987904  0.026987  0.006191   0.974896  1.000911
# 2         combined  38.0  0.993356  0.019906  0.003229   0.986813  0.999899
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =    0.0109
# 1                       Degrees of freedom =   36.0000
# 2                                        t =    1.7337
# 3                    Two side test p value =    0.0915
# 4                   Difference < 0 p value =    0.9542
# 5                   Difference > 0 p value =    0.0458
# 6                                Cohen's d =    0.5625
# 7                                Hedge's g =    0.5507
# 8                           Glass's delta1 =    2.2511
# 9                         Point-Biserial r =    0.2776
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.998969  0.003591  0.000824   0.997238  1.000700
# 1  test_W_combine  19.0  0.986756  0.029738  0.006822   0.972423  1.001089
# 2        combined  38.0  0.992862  0.021790  0.003535   0.985700  1.000025
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =    0.0122
# 1                     Degrees of freedom =   36.0000
# 2                                      t =    1.7773
# 3                  Two side test p value =    0.0840
# 4                 Difference < 0 p value =    0.9580
# 5                 Difference > 0 p value =    0.0420
# 6                              Cohen's d =    0.5766
# 7                              Hedge's g =    0.5645
# 8                         Glass's delta1 =    3.4011
# 9                       Point-Biserial r =    0.2840
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.997389  0.008700  0.001996   0.993196  1.001583
# 1  train_W_combine  19.0  0.989557  0.024055  0.005519   0.977963  1.001151
# 2         combined  38.0  0.993473  0.018278  0.002965   0.987466  0.999481
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =    0.0078
# 1                       Degrees of freedom =   36.0000
# 2                                        t =    1.3346
# 3                    Two side test p value =    0.1904
# 4                   Difference < 0 p value =    0.9048
# 5                   Difference > 0 p value =    0.0952
# 6                                Cohen's d =    0.4330
# 7                                Hedge's g =    0.4239
# 8                           Glass's delta1 =    0.9002
# 9                         Point-Biserial r =    0.2171
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.996083  0.009959  0.002285   0.991283  1.000883
# 1  test_W_combine  19.0  0.985312  0.024770  0.005683   0.973373  0.997251
# 2        combined  38.0  0.990698  0.019405  0.003148   0.984320  0.997076
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =    0.0108
# 1                     Degrees of freedom =   36.0000
# 2                                      t =    1.7586
# 3                  Two side test p value =    0.0871
# 4                 Difference < 0 p value =    0.9564
# 5                 Difference > 0 p value =    0.0436
# 6                              Cohen's d =    0.5706
# 7                              Hedge's g =    0.5586
# 8                         Glass's delta1 =    1.0815
# 9                       Point-Biserial r =    0.2813

# %%
#hash encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 10
# all_train_score_W0_p 0.48412698412698413
# all_train_score_W0_n 0.04876832376830455
# all_train_score_W0_a 0.019391741045051664
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.11748504443533336
# test_score_W0_a  0.1321048716190152
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9927905624257547
# all_train_score_W_combine_a 0.9991702697879201
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9914994658719463
# test_score_W_combine_a 0.9991593575214914
# neuron unit number: 15
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.06299918494603764
# all_train_score_W0_a 0.05368921328827794
# test_score_W0_p0.5488372093023256
# test_score_W0_n 0.11154475208859836
# test_score_W0_a  0.1474662852410127
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9927905624257547
# all_train_score_W_combine_a 0.9991702697879201
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9940579064411207
# test_score_W_combine_a 0.9989493805089876
# neuron unit number: 20
# all_train_score_W0_p 0.48412698412698413
# all_train_score_W0_n 0.05295965354265179
# all_train_score_W0_a 0.01980603889692775
# test_score_W0_p0.5348837209302325
# test_score_W0_n 0.09533256392750034
# test_score_W0_a  0.10372682466318152
# all_train_score_W_combine_p 0.9702380952380952
# all_train_score_W_combine_n 0.976118370107034
# all_train_score_W_combine_a 0.9946659152574026
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9872070835789537
# test_score_W_combine_a 0.9974800543094576
# neuron unit number: 25
# all_train_score_W0_p 0.48412698412698413
# all_train_score_W0_n 0.05549664838689504
# all_train_score_W0_a 0.03193179315447217
# test_score_W0_p0.5348837209302325
# test_score_W0_n 0.0873360234704784
# test_score_W0_a  0.12882893174075855
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.983371613686205
# all_train_score_W_combine_a 0.9951683317045202
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9830575349984345
# test_score_W_combine_a 0.9946472185307236
# neuron unit number: 30
# all_train_score_W0_p 0.4801587301587302
# all_train_score_W0_n 0.05591428528175968
# all_train_score_W0_a 0.02654965253610923
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.10489405751452113
# test_score_W0_a  0.13422762998307908
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9927905624257547
# all_train_score_W_combine_a 0.9991702697879201
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9914994658719463
# test_score_W_combine_a 0.9991593575214914
# neuron unit number: 35
# all_train_score_W0_p 0.47619047619047616
# all_train_score_W0_n 0.03967331278917781
# all_train_score_W0_a 0.017666948194010927
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.10205089235971382
# test_score_W0_a  0.10657822508050763
# all_train_score_W_combine_p 0.9742063492063492
# all_train_score_W_combine_n 0.9856178040420707
# all_train_score_W_combine_a 0.9963824706738106
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9872070835789537
# test_score_W_combine_a 0.9974800543094576
# neuron unit number: 40
# all_train_score_W0_p 0.48412698412698413
# all_train_score_W0_n 0.0627010959021673
# all_train_score_W0_a 0.029061466671923532
# test_score_W0_p0.5255813953488372
# test_score_W0_n 0.09559263060550673
# test_score_W0_a  0.09923624197821083
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9927905624257547
# all_train_score_W_combine_a 0.9991702697879201
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9940579064411207
# test_score_W_combine_a 0.9989493805089876
# neuron unit number: 45
# all_train_score_W0_p 0.4781746031746032
# all_train_score_W0_n 0.049685519890048144
# all_train_score_W0_a 0.02589969431051185
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.10833749926838945
# test_score_W0_a  0.12403720441957346
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9722283216637908
# all_train_score_W_combine_a 0.9908285572485114
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9830575349984345
# test_score_W_combine_a 0.9946472185307236
# neuron unit number: 50
# all_train_score_W0_p 0.4801587301587302
# all_train_score_W0_n 0.047577126731984644
# all_train_score_W0_a 0.019485260922627024
# test_score_W0_p0.5488372093023256
# test_score_W0_n 0.12974981452060386
# test_score_W0_a  0.13766968815630173
# all_train_score_W_combine_p 0.9722222222222222
# all_train_score_W_combine_n 0.9800506275614694
# all_train_score_W_combine_a 0.9943587201381809
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9872070835789537
# test_score_W_combine_a 0.9974800543094576
# neuron unit number: 55
# all_train_score_W0_p 0.48412698412698413
# all_train_score_W0_n 0.06364488375071585
# all_train_score_W0_a 0.02664580015133053
# test_score_W0_p0.5534883720930233
# test_score_W0_n 0.11750615178211536
# test_score_W0_a  0.14685232160548664
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.983371613686205
# all_train_score_W_combine_a 0.9951683317045202
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9830575349984345
# test_score_W_combine_a 0.9946472185307236
# neuron unit number: 60
# all_train_score_W0_p 0.4781746031746032
# all_train_score_W0_n 0.04740609293075589
# all_train_score_W0_a 0.02273299208606177
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.11027246495621125
# test_score_W0_a  0.11992296366085643
# all_train_score_W_combine_p 0.9761904761904762
# all_train_score_W_combine_n 0.9745938993426777
# all_train_score_W_combine_a 0.9930892798676962
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9761196013581396
# test_score_W_combine_a 0.9931819929472446
# neuron unit number: 65
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.05366061660448754
# all_train_score_W0_a 0.033581992433543484
# test_score_W0_p0.5488372093023256
# test_score_W0_n 0.12165012517518818
# test_score_W0_a  0.14180589940886187
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9953492625990548
# all_train_score_W_combine_a 0.99927146332385
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9940579064411207
# test_score_W_combine_a 0.9989493805089876
# neuron unit number: 70
# all_train_score_W0_p 0.48412698412698413
# all_train_score_W0_n 0.053524413448049236
# all_train_score_W0_a 0.05139032301527179
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.10306150379632707
# test_score_W0_a  0.12283513429838908
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9953492625990548
# all_train_score_W_combine_a 0.99927146332385
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9940579064411207
# test_score_W_combine_a 0.9989493805089876
# neuron unit number: 75
# all_train_score_W0_p 0.4781746031746032
# all_train_score_W0_n 0.04847679084044051
# all_train_score_W0_a 0.020994819797015837
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.10554272497691754
# test_score_W0_a  0.09331484405312929
# all_train_score_W_combine_p 0.9742063492063492
# all_train_score_W_combine_n 0.9856178040420707
# all_train_score_W_combine_a 0.9963824706738106
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9872070835789537
# test_score_W_combine_a 0.9974800543094576
# neuron unit number: 80
# all_train_score_W0_p 0.4742063492063492
# all_train_score_W0_n 0.02745285529316911
# all_train_score_W0_a 0.011264083627798202
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.084253240492759
# test_score_W0_a  0.09709773010077127
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9816781621746726
# all_train_score_W_combine_a 0.9948230344263794
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9940579064411207
# test_score_W_combine_a 0.9989493805089876
# neuron unit number: 85
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.05949138472889389
# all_train_score_W0_a 0.044331702563128884
# test_score_W0_p0.5395348837209303
# test_score_W0_n 0.10481767797101936
# test_score_W0_a  0.11409766135129824
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.983371613686205
# all_train_score_W_combine_a 0.9951683317045202
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9830575349984345
# test_score_W_combine_a 0.9946472185307236
# neuron unit number: 90
# all_train_score_W0_p 0.47619047619047616
# all_train_score_W0_n 0.04262579711922865
# all_train_score_W0_a 0.014740323782725391
# test_score_W0_p0.5348837209302325
# test_score_W0_n 0.10108883678961264
# test_score_W0_a  0.12411221252069507
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9816781621746726
# all_train_score_W_combine_a 0.9948230344263794
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9940579064411207
# test_score_W_combine_a 0.9989493805089876
# neuron unit number: 95
# all_train_score_W0_p 0.4861111111111111
# all_train_score_W0_n 0.058552275104685185
# all_train_score_W0_a 0.031041614302056087
# test_score_W0_p0.5488372093023256
# test_score_W0_n 0.12370665601518945
# test_score_W0_a  0.13087767749655296
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.9847327170438283
# all_train_score_W_combine_a 0.9889955034163919
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9816427830505143
# test_score_W_combine_a 0.9869249427260771
# neuron unit number: 100
# all_train_score_W0_p 0.4801587301587302
# all_train_score_W0_n 0.05328634518284382
# all_train_score_W0_a 0.044931464323694235
# test_score_W0_p0.5255813953488372
# test_score_W0_n 0.0760081007241698
# test_score_W0_a  0.08429926247620614
# all_train_score_W_combine_p 0.9702380952380952
# all_train_score_W_combine_n 0.9748704921245663
# all_train_score_W_combine_a 0.9861321457406836
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9746808287917549
# test_score_W_combine_a 0.9854693835634101
# test_score_W0_p mean 0.5390452876376988
# test_score_W_combine_p mean 0.9860465116279071
# test_score_W0_n mean 0.10527530320369237
# test_score_W_combine_n mean 0.9874130556789777
# test_score_W0_a mean 0.12047850578178357
# test_score_W_combine_a mean 0.9961105478260192
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.051784  0.008869  0.002035   0.047510  0.056059
# 1  train_W_combine  19.0  0.984693  0.007316  0.001678   0.981167  0.988219
# 2         combined  38.0  0.518238  0.472784  0.076696   0.362838  0.673639
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9329
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -353.7031
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -114.7565
# 7                                Hedge's g =  -112.3490
# 8                           Glass's delta1 =  -105.1924
# 9                         Point-Biserial r =    -0.9999
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.105275  0.013795  0.003165   0.098626  0.111924
# 1  test_W_combine  19.0  0.987413  0.006224  0.001428   0.984413  0.990413
# 2        combined  38.0  0.546344  0.447114  0.072531   0.399381  0.693307
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.8821
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -254.0738
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -82.4324
# 7                              Hedge's g =   -80.7031
# 8                         Glass's delta1 =   -63.9470
# 9                       Point-Biserial r =    -0.9997
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.028691  0.012179  0.002794   0.022821  0.034562
# 1  train_W_combine  19.0  0.995327  0.003684  0.000845   0.993551  0.997102
# 2         combined  38.0  0.512009  0.489886  0.079470   0.350988  0.673031
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9666
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -331.1430
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -107.4370
# 7                                Hedge's g =  -105.1831
# 8                           Glass's delta1 =   -79.3685
# 9                         Point-Biserial r =    -0.9998
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.120479  0.018660  0.004281   0.111485  0.129472
# 1  test_W_combine  19.0  0.996111  0.004008  0.000920   0.994179  0.998042
# 2        combined  38.0  0.558295  0.443893  0.072009   0.412391  0.704198
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.8756
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -199.9845
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -64.8835
# 7                              Hedge's g =   -63.5223
# 8                         Glass's delta1 =   -46.9262
# 9                       Point-Biserial r =    -0.9996
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.481621  0.003904  0.000896   0.479739  0.483502
# 1  train_W_combine  19.0  0.983709  0.008302  0.001905   0.979708  0.987711
# 2         combined  38.0  0.732665  0.254495  0.041284   0.649015  0.816315
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.5021
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -238.5518
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -77.3964
# 7                                Hedge's g =   -75.7727
# 8                           Glass's delta1 =  -128.6115
# 9                         Point-Biserial r =    -0.9997
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.539045  0.008040  0.001845   0.535170  0.542921
# 1  test_W_combine  19.0  0.986047  0.004903  0.001125   0.983683  0.988410
# 2        combined  38.0  0.762546  0.226596  0.036759   0.688066  0.837026
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.4470
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -206.9012
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -67.1276
# 7                              Hedge's g =   -65.7193
# 8                         Glass's delta1 =   -55.5949
# 9                       Point-Biserial r =    -0.9996

# %%
#one hot encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 10
# all_train_score_W0_p 0.5059523809523809
# all_train_score_W0_n 0.03794368926182928
# all_train_score_W0_a 0.04140822676904873
# test_score_W0_p0.5534883720930233
# test_score_W0_n 0.1295993368922757
# test_score_W0_a  0.07190459614580857
# all_train_score_W_combine_p 0.9761904761904762
# all_train_score_W_combine_n 0.9780460749912627
# all_train_score_W_combine_a 0.9952536639249288
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9724569247457575
# test_score_W_combine_a 0.994192747308103
# neuron unit number: 15
# all_train_score_W0_p 0.501984126984127
# all_train_score_W0_n 0.03461884322538273
# all_train_score_W0_a 0.04008736117854216
# test_score_W0_p0.5581395348837209
# test_score_W0_n 0.10781110608886818
# test_score_W0_a  0.0780074216306234
# all_train_score_W_combine_p 0.9642857142857143
# all_train_score_W_combine_n 0.9704795537854315
# all_train_score_W_combine_a 0.9918462946767577
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9715899773154754
# test_score_W_combine_a 0.9921030868503151
# neuron unit number: 20
# all_train_score_W0_p 0.5059523809523809
# all_train_score_W0_n 0.033633417224173685
# all_train_score_W0_a 0.043054600645051726
# test_score_W0_p0.5534883720930233
# test_score_W0_n 0.11526488355743161
# test_score_W0_a  0.06865002163425553
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9843433960962339
# all_train_score_W_combine_a 0.9978560109279913
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 25
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.033892003070847845
# all_train_score_W0_a 0.029818875616740216
# test_score_W0_p0.5534883720930233
# test_score_W0_n 0.10610011929839006
# test_score_W0_a  0.0691532431730826
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9899123094938127
# all_train_score_W_combine_a 0.9983536962091543
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 30
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.043431491292517194
# all_train_score_W0_a 0.04867961170926534
# test_score_W0_p0.5581395348837209
# test_score_W0_n 0.13447322213559865
# test_score_W0_a  0.10122262060701731
# all_train_score_W_combine_p 0.9781746031746031
# all_train_score_W_combine_n 0.9773345242658964
# all_train_score_W_combine_a 0.9958483239332024
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 35
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.05522732575256869
# all_train_score_W0_a 0.05730516580331826
# test_score_W0_p0.5488372093023256
# test_score_W0_n 0.08297086546032653
# test_score_W0_a  0.05136875112417252
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9899123094938127
# all_train_score_W_combine_a 0.9983536962091543
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 40
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.045492559601438574
# all_train_score_W0_a 0.052907984162740444
# test_score_W0_p0.5674418604651162
# test_score_W0_n 0.15744731245077995
# test_score_W0_a  0.0831715364285288
# all_train_score_W_combine_p 0.9662698412698413
# all_train_score_W_combine_n 0.9756148458348585
# all_train_score_W_combine_a 0.9931617338513934
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9715899773154754
# test_score_W_combine_a 0.9921030868503151
# neuron unit number: 45
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.038328524013768524
# all_train_score_W0_a 0.05053412839903429
# test_score_W0_p0.5627906976744186
# test_score_W0_n 0.13955731759932585
# test_score_W0_a  0.07514356641923593
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9899123094938127
# all_train_score_W_combine_a 0.9983536962091543
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 50
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.03145408909762662
# all_train_score_W0_a 0.03744081973134513
# test_score_W0_p0.5627906976744186
# test_score_W0_n 0.1370712559333261
# test_score_W0_a  0.10162076016811539
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9774384185961813
# all_train_score_W_combine_a 0.9957509221885708
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 55
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.03539101872752538
# all_train_score_W0_a 0.0429350778045299
# test_score_W0_p0.5534883720930233
# test_score_W0_n 0.13043878155652455
# test_score_W0_a  0.09361458612893875
# all_train_score_W_combine_p 0.9662698412698413
# all_train_score_W_combine_n 0.9629316847328587
# all_train_score_W_combine_a 0.9838537675482533
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9606619602244812
# test_score_W_combine_a 0.9828198624942931
# neuron unit number: 60
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.04952069408531412
# all_train_score_W0_a 0.05604098870027737
# test_score_W0_p0.5488372093023256
# test_score_W0_n 0.11725128665860508
# test_score_W0_a  0.06438624571956607
# all_train_score_W_combine_p 0.9682539682539683
# all_train_score_W_combine_n 0.9613607474701357
# all_train_score_W_combine_a 0.9878208972255283
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9620155252268023
# test_score_W_combine_a 0.9918919420248345
# neuron unit number: 65
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.046742129776845665
# all_train_score_W0_a 0.05257841330661804
# test_score_W0_p0.5581395348837209
# test_score_W0_n 0.1368176198190188
# test_score_W0_a  0.07564870931893974
# all_train_score_W_combine_p 0.9662698412698413
# all_train_score_W_combine_n 0.9756148458348585
# all_train_score_W_combine_a 0.9931617338513934
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9715899773154754
# test_score_W_combine_a 0.9921030868503151
# neuron unit number: 70
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.03741473551483571
# all_train_score_W0_a 0.043700433841721856
# test_score_W0_p0.5581395348837209
# test_score_W0_n 0.11427108596038811
# test_score_W0_a  0.07900535157176061
# all_train_score_W_combine_p 0.9722222222222222
# all_train_score_W_combine_n 0.9670129139848092
# all_train_score_W_combine_a 0.9931515164146218
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9724569247457575
# test_score_W_combine_a 0.994192747308103
# neuron unit number: 75
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.04314124146265476
# all_train_score_W0_a 0.050595827121077123
# test_score_W0_p0.5674418604651162
# test_score_W0_n 0.1550126831352883
# test_score_W0_a  0.10349587361331285
# all_train_score_W_combine_p 0.9742063492063492
# all_train_score_W_combine_n 0.970806788108921
# all_train_score_W_combine_a 0.9942976578908205
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9724569247457575
# test_score_W_combine_a 0.994192747308103
# neuron unit number: 80
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.0330769206082126
# all_train_score_W0_a 0.042416913455728546
# test_score_W0_p0.5674418604651162
# test_score_W0_n 0.12972770023212318
# test_score_W0_a  0.0859055715976863
# all_train_score_W_combine_p 0.9543650793650794
# all_train_score_W_combine_n 0.9326234530339812
# all_train_score_W_combine_a 0.96929525650474
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9620155252268023
# test_score_W_combine_a 0.9918919420248345
# neuron unit number: 85
# all_train_score_W0_p 0.5059523809523809
# all_train_score_W0_n 0.047280001801328866
# all_train_score_W0_a 0.05160844082092106
# test_score_W0_p0.5627906976744186
# test_score_W0_n 0.15944528572039865
# test_score_W0_a  0.09504486772974144
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9899123094938127
# all_train_score_W_combine_a 0.9983536962091543
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 90
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.0600912724281423
# all_train_score_W0_a 0.05533186104778974
# test_score_W0_p0.5581395348837209
# test_score_W0_n 0.12874003574085496
# test_score_W0_a  0.07611698492975826
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9843433960962339
# all_train_score_W_combine_a 0.9978560109279913
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# neuron unit number: 95
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.05907667465342819
# all_train_score_W0_a 0.04729749460617008
# test_score_W0_p0.5720930232558139
# test_score_W0_n 0.16909270203071095
# test_score_W0_a  0.10647573118012052
# all_train_score_W_combine_p 0.9761904761904762
# all_train_score_W_combine_n 0.9780460749912627
# all_train_score_W_combine_a 0.9952536639249288
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9724569247457575
# test_score_W_combine_a 0.994192747308103
# neuron unit number: 100
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.038301472694370224
# all_train_score_W0_a 0.04316424851664388
# test_score_W0_p0.5581395348837209
# test_score_W0_n 0.11138136462681818
# test_score_W0_a  0.07781813221243447
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9899123094938127
# all_train_score_W_combine_a 0.9983536962091543
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9886040801941632
# test_score_W_combine_a 0.998396946470468
# test_score_W0_p mean 0.5591187270501836
# test_score_W_combine_p mean 0.9750305997552019
# test_score_W0_n mean 0.1296038928893186
# test_score_W_combine_n mean 0.9782488085976323
# test_score_W0_a mean 0.08198708270174206
# test_score_W_combine_a mean 0.9950135007663963
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.042319  0.008831  0.002026   0.038062  0.046575
# 1  train_W_combine  19.0  0.976082  0.013992  0.003210   0.969338  0.982826
# 2         combined  38.0  0.509200  0.473289  0.076778   0.353634  0.664767
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9338
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -245.9885
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -79.8092
# 7                                Hedge's g =   -78.1349
# 8                           Glass's delta1 =  -105.7358
# 9                         Point-Biserial r =    -0.9997
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.129604  0.021383  0.004906   0.119298  0.139910
# 1  test_W_combine  19.0  0.978249  0.010720  0.002459   0.973082  0.983416
# 2        combined  38.0  0.553926  0.430342  0.069811   0.412477  0.695376
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.8486
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -154.6489
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -50.1747
# 7                              Hedge's g =   -49.1221
# 8                         Glass's delta1 =   -39.6880
# 9                       Point-Biserial r =    -0.9992
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.046679  0.007131  0.001636   0.043242  0.050116
# 1  train_W_combine  19.0  0.993483  0.007021  0.001611   0.990099  0.996867
# 2         combined  38.0  0.520081  0.479807  0.077835   0.362372  0.677790
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9468
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -412.3965
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -133.7991
# 7                                Hedge's g =  -130.9921
# 8                           Glass's delta1 =  -132.7739
# 9                         Point-Biserial r =    -0.9999
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.081987  0.014898  0.003418   0.074806  0.089168
# 1  test_W_combine  19.0  0.995014  0.004078  0.000936   0.993048  0.996979
# 2        combined  38.0  0.538500  0.462767  0.075071   0.386393  0.690608
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.9130
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -257.6509
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -83.5930
# 7                              Hedge's g =   -81.8393
# 8                         Glass's delta1 =   -61.2832
# 9                       Point-Biserial r =    -0.9997
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.507310  0.003175  0.000729   0.505779  0.508840
# 1  train_W_combine  19.0  0.974415  0.008043  0.001845   0.970539  0.978292
# 2         combined  38.0  0.740863  0.236765  0.038408   0.663040  0.818685
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.4671
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -235.4573
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -76.3924
# 7                                Hedge's g =   -74.7898
# 8                           Glass's delta1 =  -147.0978
# 9                         Point-Biserial r =    -0.9997
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.559119  0.006500  0.001491   0.555986  0.562252
# 1  test_W_combine  19.0  0.975031  0.006432  0.001476   0.971931  0.978131
# 2        combined  38.0  0.767075  0.210844  0.034203   0.697772  0.836377
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.4159
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -198.2503
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -64.3209
# 7                              Hedge's g =   -62.9715
# 8                         Glass's delta1 =   -63.9830
# 9                       Point-Biserial r =    -0.9995

# %%
#binary encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 10
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.057283748339788026
# all_train_score_W0_a 0.03788220068187965
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.11876728379465576
# test_score_W0_a  0.07466575141368076
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.9843999605972301
# all_train_score_W_combine_a 0.9949501325265908
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 15
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.03398185336776175
# all_train_score_W0_a 0.037158370049897964
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.1147818015974529
# test_score_W0_a  0.07600463368088753
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9946854541164825
# all_train_score_W_combine_a 0.9991701835310531
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 20
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.028672682195053943
# all_train_score_W0_a 0.010910057011317179
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.10869240040191262
# test_score_W0_a  0.07019716532933813
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9946854541164825
# all_train_score_W_combine_a 0.9991701835310531
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 25
# all_train_score_W0_p 0.5059523809523809
# all_train_score_W0_n 0.023012598224149774
# all_train_score_W0_a 0.013305299604997453
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.11296372379175919
# test_score_W0_a  0.08262369034005819
# all_train_score_W_combine_p 0.9523809523809523
# all_train_score_W_combine_n 0.9517837026588709
# all_train_score_W_combine_a 0.9837399094030317
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9701193542590313
# test_score_W_combine_a 0.9913616777169517
# neuron unit number: 30
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.025969974194925277
# all_train_score_W0_a 0.03097976881244253
# test_score_W0_p0.5069767441860465
# test_score_W0_n 0.12383290146730298
# test_score_W0_a  0.08724754383986336
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9946854541164825
# all_train_score_W_combine_a 0.9991701835310531
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 35
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.02778032315336884
# all_train_score_W0_a 0.01607564269927648
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.10789739802080683
# test_score_W0_a  0.08817540625742225
# all_train_score_W_combine_p 0.9722222222222222
# all_train_score_W_combine_n 0.9849201517683516
# all_train_score_W_combine_a 0.9967217045517007
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9858267682452795
# test_score_W_combine_a 0.9945544346550997
# neuron unit number: 40
# all_train_score_W0_p 0.5158730158730159
# all_train_score_W0_n 0.05367918055309877
# all_train_score_W0_a 0.04490519228948222
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.11325023594976581
# test_score_W0_a  0.0938029564693003
# all_train_score_W_combine_p 0.9742063492063492
# all_train_score_W_combine_n 0.9677277921370484
# all_train_score_W_combine_a 0.9874713597965745
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9864495694245536
# test_score_W_combine_a 0.9956794083107863
# neuron unit number: 45
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.03433209928944194
# all_train_score_W0_a 0.03004793549943704
# test_score_W0_p0.5116279069767442
# test_score_W0_n 0.13571637664336822
# test_score_W0_a  0.09382174743424915
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9946854541164825
# all_train_score_W_combine_a 0.9991701835310531
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 50
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.029052996084775944
# all_train_score_W0_a 0.022576937557817436
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.11647513633623174
# test_score_W0_a  0.07751954722355396
# all_train_score_W_combine_p 0.9900793650793651
# all_train_score_W_combine_n 0.9904963485680519
# all_train_score_W_combine_a 0.9987553132815659
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9892843148680593
# test_score_W_combine_a 0.9977270081564295
# neuron unit number: 55
# all_train_score_W0_p 0.5158730158730159
# all_train_score_W0_n 0.052210782488450604
# all_train_score_W0_a 0.033306645572133885
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.08931999423593648
# test_score_W0_a  0.06777568673978225
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9714483405709516
# all_train_score_W_combine_a 0.994608249750109
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.9892843148680593
# test_score_W_combine_a 0.9977270081564295
# neuron unit number: 60
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.01562735197706292
# all_train_score_W0_a 0.010741131349584331
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.09956941871312631
# test_score_W0_a  0.06412120756630611
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9946854541164825
# all_train_score_W_combine_a 0.9991701835310531
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 65
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.0408604660535364
# all_train_score_W0_a 0.030146572400225072
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.10627976294825116
# test_score_W0_a  0.09648596133605467
# all_train_score_W_combine_p 0.9761904761904762
# all_train_score_W_combine_n 0.9724979568559952
# all_train_score_W_combine_a 0.9928056740148616
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9891767894387481
# test_score_W_combine_a 0.998521984431991
# neuron unit number: 70
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.04674728958373844
# all_train_score_W0_a 0.039265171914532125
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.1111507842245661
# test_score_W0_a  0.08338141335316702
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9809691621046889
# all_train_score_W_combine_a 0.995701616055565
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9969563450185037
# test_score_W_combine_a 0.9996588064839711
# neuron unit number: 75
# all_train_score_W0_p 0.503968253968254
# all_train_score_W0_n 0.004301023697955511
# all_train_score_W0_a 0.0014808092183166387
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.11654823335078295
# test_score_W0_a  0.08716943766307536
# all_train_score_W_combine_p 0.9722222222222222
# all_train_score_W_combine_n 0.9770189702210986
# all_train_score_W_combine_a 0.9960430746179831
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9840209717673515
# test_score_W_combine_a 0.9968192154741676
# neuron unit number: 80
# all_train_score_W0_p 0.5059523809523809
# all_train_score_W0_n 0.021325192692456536
# all_train_score_W0_a 0.011962011166375897
# test_score_W0_p0.5069767441860465
# test_score_W0_n 0.13006879554661832
# test_score_W0_a  0.09159805495042223
# all_train_score_W_combine_p 0.9702380952380952
# all_train_score_W_combine_n 0.9797307989993149
# all_train_score_W_combine_a 0.9957982822336616
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9858267682452795
# test_score_W_combine_a 0.9945544346550997
# neuron unit number: 85
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.03652607379292877
# all_train_score_W0_a 0.015813222022472255
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.11558435797366862
# test_score_W0_a  0.06558612148163756
# all_train_score_W_combine_p 0.9900793650793651
# all_train_score_W_combine_n 0.9776383925109531
# all_train_score_W_combine_a 0.9795096920808034
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9732327058503867
# test_score_W_combine_a 0.9643705723474353
# neuron unit number: 90
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.022239566989463787
# all_train_score_W0_a 0.014063428782674157
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.10656055601093478
# test_score_W0_a  0.08985441161292139
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9756860829164946
# all_train_score_W_combine_a 0.9789535414761418
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9700758598428303
# test_score_W_combine_a 0.9640403139527884
# neuron unit number: 95
# all_train_score_W0_p 0.5079365079365079
# all_train_score_W0_n 0.02442259061858563
# all_train_score_W0_a 0.01092208340988367
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.09440788994826584
# test_score_W0_a  0.07128395174600208
# all_train_score_W_combine_p 0.9623015873015873
# all_train_score_W_combine_n 0.9610923009849067
# all_train_score_W_combine_a 0.9918075707845808
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9743007142905254
# test_score_W_combine_a 0.9938683352752633
# neuron unit number: 100
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.04956386744160962
# all_train_score_W0_a 0.0264008008579991
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.11701043141303817
# test_score_W0_a  0.07376121907127793
# all_train_score_W_combine_p 0.9900793650793651
# all_train_score_W_combine_n 0.9791569009636113
# all_train_score_W_combine_a 0.9934263219545697
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9787294307824814
# test_score_W_combine_a 0.9896709954078089
# test_score_W0_p mean 0.4991432068543452
# test_score_W_combine_p mean 0.9880048959608324
# test_score_W0_n mean 0.11257249907202342
# test_score_W_combine_n mean 0.9871064198427428
# test_score_W0_a mean 0.08079346881626318
# test_score_W_combine_a mean 0.9935003702067394
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.033031  0.014120  0.003239   0.026226  0.039836
# 1  train_W_combine  19.0  0.980421  0.012241  0.002808   0.974521  0.986321
# 2         combined  38.0  0.506726  0.480230  0.077904   0.348878  0.664574
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9474
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -220.9868
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -71.6976
# 7                                Hedge's g =   -70.1934
# 8                           Glass's delta1 =   -67.0979
# 9                         Point-Biserial r =    -0.9996
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.112572  0.011122  0.002552   0.107212  0.117933
# 1  test_W_combine  19.0  0.987106  0.009751  0.002237   0.982407  0.991806
# 2        combined  38.0  0.549839  0.443257  0.071906   0.404145  0.695534
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.8745
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -257.7221
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -83.6161
# 7                              Hedge's g =   -81.8619
# 8                         Glass's delta1 =   -78.6304
# 9                       Point-Biserial r =    -0.9997
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.023050  0.012359  0.002835   0.017093  0.029006
# 1  train_W_combine  19.0  0.993481  0.006502  0.001492   0.990347  0.996615
# 2         combined  38.0  0.508265  0.491826  0.079785   0.346606  0.669924
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9704
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -302.9038
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -98.2750
# 7                                Hedge's g =   -96.2132
# 8                           Glass's delta1 =   -78.5209
# 9                         Point-Biserial r =    -0.9998
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.080793  0.010363  0.002377   0.075799  0.085788
# 1  test_W_combine  19.0  0.993500  0.010750  0.002466   0.988319  0.998682
# 2        combined  38.0  0.537147  0.462597  0.075043   0.385095  0.689199
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.9127
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -266.4394
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -86.4444
# 7                              Hedge's g =   -84.6308
# 8                         Glass's delta1 =   -88.0752
# 9                       Point-Biserial r =    -0.9997
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.510129  0.003793  0.000870   0.508301  0.511958
# 1  train_W_combine  19.0  0.981412  0.011630  0.002668   0.975806  0.987017
# 2         combined  38.0  0.745771  0.238957  0.038764   0.667228  0.824314
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.4713
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -167.9306
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -54.4839
# 7                                Hedge's g =   -53.3409
# 8                           Glass's delta1 =  -124.2424
# 9                         Point-Biserial r =    -0.9994
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.499143  0.005382  0.001235   0.496549  0.501737
# 1  test_W_combine  19.0  0.988005  0.007324  0.001680   0.984475  0.991535
# 2        combined  38.0  0.743574  0.247793  0.040197   0.662127  0.825022
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.4889
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -234.4459
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -76.0643
# 7                              Hedge's g =   -74.4686
# 8                         Glass's delta1 =   -90.8249
# 9                       Point-Biserial r =    -0.9997

# %%
#baseN encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 10
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.033843444130622874
# all_train_score_W0_a 0.03912297585903744
# test_score_W0_p0.5069767441860465
# test_score_W0_n 0.1017636427254334
# test_score_W0_a  0.058451551357811195
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9873275577269921
# all_train_score_W_combine_a 0.99766274612844
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9890968809414246
# test_score_W_combine_a 0.997918940505685
# neuron unit number: 15
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.03560478179410826
# all_train_score_W0_a 0.03060950978123817
# test_score_W0_p0.4883720930232558
# test_score_W0_n 0.055087654554390825
# test_score_W0_a  0.04055317905160289
# all_train_score_W_combine_p 0.9702380952380952
# all_train_score_W_combine_n 0.9706323491204049
# all_train_score_W_combine_a 0.9928587473025245
# test_score_W_combine_p 0.9627906976744186
# test_score_W_combine_n 0.9609831868598371
# test_score_W_combine_a 0.9900437359758893
# neuron unit number: 20
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.03379775113821025
# all_train_score_W0_a 0.027586396963976193
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.08725171128186388
# test_score_W0_a  0.03360667666757528
# all_train_score_W_combine_p 0.9940476190476191
# all_train_score_W_combine_n 0.9943492622331506
# all_train_score_W_combine_a 0.9993775284322937
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9968777978878991
# test_score_W_combine_a 0.9996711494486787
# neuron unit number: 25
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.0317336852139758
# all_train_score_W0_a 0.03225686524379459
# test_score_W0_p0.5069767441860465
# test_score_W0_n 0.07794552647089709
# test_score_W0_a  0.05921751341938014
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9948842243390201
# all_train_score_W_combine_a 0.9992455638576306
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9968777978878991
# test_score_W_combine_a 0.9996711494486787
# neuron unit number: 30
# all_train_score_W0_p 0.5178571428571429
# all_train_score_W0_n 0.040644095880409625
# all_train_score_W0_a 0.0401908481916812
# test_score_W0_p0.5116279069767442
# test_score_W0_n 0.09349560023259543
# test_score_W0_a  0.05939152991418647
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9948842243390201
# all_train_score_W_combine_a 0.9992455638576306
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9968777978878991
# test_score_W_combine_a 0.9996711494486787
# neuron unit number: 35
# all_train_score_W0_p 0.5178571428571429
# all_train_score_W0_n 0.05961107530035296
# all_train_score_W0_a 0.037797045570751725
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.07019893145203114
# test_score_W0_a  0.04952929927147518
# all_train_score_W_combine_p 0.9682539682539683
# all_train_score_W_combine_n 0.9578368498578524
# all_train_score_W_combine_a 0.9698935066239849
# test_score_W_combine_p 0.9627906976744186
# test_score_W_combine_n 0.9513389524029753
# test_score_W_combine_a 0.9462399620571169
# neuron unit number: 40
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.03289276159790641
# all_train_score_W0_a 0.029617651440404687
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.07969892093505467
# test_score_W0_a  0.04805646086227776
# all_train_score_W_combine_p 0.9900793650793651
# all_train_score_W_combine_n 0.9891983596130971
# all_train_score_W_combine_a 0.9974172584398524
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9968777978878991
# test_score_W_combine_a 0.9996711494486787
# neuron unit number: 45
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.02665909143134175
# all_train_score_W0_a 0.026694345382850544
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.0908280887790832
# test_score_W0_a  0.06636732317160916
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9873275577269921
# all_train_score_W_combine_a 0.99766274612844
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9890968809414246
# test_score_W_combine_a 0.997918940505685
# neuron unit number: 50
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.029227346681959677
# all_train_score_W0_a 0.030401594789319333
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.06940979061414934
# test_score_W0_a  0.05868248841335796
# all_train_score_W_combine_p 0.9702380952380952
# all_train_score_W_combine_n 0.9562043017310473
# all_train_score_W_combine_a 0.9800847790261153
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9782666686444196
# test_score_W_combine_a 0.9937555767639901
# neuron unit number: 55
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.03169974057478982
# all_train_score_W0_a 0.0300074060582945
# test_score_W0_p0.49767441860465117
# test_score_W0_n 0.08523621807339765
# test_score_W0_a  0.037536183334818805
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9763993040784376
# all_train_score_W_combine_a 0.9932924794154402
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9789855953530969
# test_score_W_combine_a 0.992000363778106
# neuron unit number: 60
# all_train_score_W0_p 0.5178571428571429
# all_train_score_W0_n 0.038057691103317394
# all_train_score_W0_a 0.030878210933365367
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.07404400930327777
# test_score_W0_a  0.05143760616534594
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9873275577269921
# all_train_score_W_combine_a 0.99766274612844
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9890968809414246
# test_score_W_combine_a 0.997918940505685
# neuron unit number: 65
# all_train_score_W0_p 0.5158730158730159
# all_train_score_W0_n 0.03196626462896517
# all_train_score_W0_a 0.031205655126128513
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.06855718370820012
# test_score_W0_a  0.03600130818466944
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9724356771621191
# all_train_score_W_combine_a 0.9924985122638333
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9782666686444196
# test_score_W_combine_a 0.9937555767639901
# neuron unit number: 70
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.031391720344781986
# all_train_score_W0_a 0.03389214040893931
# test_score_W0_p0.4883720930232558
# test_score_W0_n 0.058841624640028595
# test_score_W0_a  0.038182134205022256
# all_train_score_W_combine_p 0.9623015873015873
# all_train_score_W_combine_n 0.9518994319355769
# all_train_score_W_combine_a 0.9869141398317202
# test_score_W_combine_p 0.9627906976744186
# test_score_W_combine_n 0.9561851708401209
# test_score_W_combine_a 0.9860953037008241
# neuron unit number: 75
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.023874225040968446
# all_train_score_W0_a 0.02181619558040167
# test_score_W0_p0.4883720930232558
# test_score_W0_n 0.04735728829842297
# test_score_W0_a  0.0410194037346461
# all_train_score_W_combine_p 0.9722222222222222
# all_train_score_W_combine_n 0.959231652836101
# all_train_score_W_combine_a 0.9830969029417305
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9797953403276733
# test_score_W_combine_a 0.9959494290438318
# neuron unit number: 80
# all_train_score_W0_p 0.5119047619047619
# all_train_score_W0_n 0.029844843677737733
# all_train_score_W0_a 0.026828711867003138
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.06756291187862316
# test_score_W0_a  0.03916446846175375
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9948842243390201
# all_train_score_W_combine_a 0.9992455638576306
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9968777978878991
# test_score_W_combine_a 0.9996711494486787
# neuron unit number: 85
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.03261791449188122
# all_train_score_W0_a 0.030831593513697672
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.05539673923628647
# test_score_W0_a  0.044843399994604856
# all_train_score_W_combine_p 0.9900793650793651
# all_train_score_W_combine_n 0.9891983596130971
# all_train_score_W_combine_a 0.9974172584398524
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9968777978878991
# test_score_W_combine_a 0.9996711494486787
# neuron unit number: 90
# all_train_score_W0_p 0.5099206349206349
# all_train_score_W0_n 0.017901615756205552
# all_train_score_W0_a 0.025518798211069175
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.05376672189161063
# test_score_W0_a  0.03327562181483457
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9866814650762253
# all_train_score_W_combine_a 0.9980391842438711
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.987710358912156
# test_score_W_combine_a 0.9983560752021599
# neuron unit number: 95
# all_train_score_W0_p 0.5158730158730159
# all_train_score_W0_n 0.043708177883880164
# all_train_score_W0_a 0.04866699939777879
# test_score_W0_p0.5162790697674419
# test_score_W0_n 0.09253567131201307
# test_score_W0_a  0.06400691825420088
# all_train_score_W_combine_p 0.9642857142857143
# all_train_score_W_combine_n 0.950735372035816
# all_train_score_W_combine_a 0.9867323226056409
# test_score_W_combine_p 0.9627906976744186
# test_score_W_combine_n 0.9561851708401209
# test_score_W_combine_a 0.9860953037008241
# neuron unit number: 100
# all_train_score_W0_p 0.5138888888888888
# all_train_score_W0_n 0.03229356606380482
# all_train_score_W0_a 0.031136138147690142
# test_score_W0_p0.4930232558139535
# test_score_W0_n 0.06767877747045656
# test_score_W0_a  0.04817744133137175
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9681064590118897
# all_train_score_W_combine_a 0.9912605449345959
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.9733218703565635
# test_score_W_combine_a 0.9914528696440372
# test_score_W0_p mean 0.4986536107711139
# test_score_W_combine_p mean 0.9821297429620564
# test_score_W0_n mean 0.0735082638346219
# test_score_W_combine_n mean 0.9815577059648976
# test_score_W0_a mean 0.04776318461108129
# test_score_W_combine_a mean 0.9929225218336789
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.033546  0.008474  0.001944   0.029461  0.037630
# 1  train_W_combine  19.0  0.977344  0.015891  0.003646   0.969685  0.985004
# 2         combined  38.0  0.505445  0.478399  0.077607   0.348199  0.662691
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9438
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -228.4292
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -74.1122
# 7                                Hedge's g =   -72.5574
# 8                           Glass's delta1 =  -111.3764
# 9                         Point-Biserial r =    -0.9997
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.073508  0.015496  0.003555   0.066039  0.080977
# 1  test_W_combine  19.0  0.981558  0.015527  0.003562   0.974074  0.989042
# 2        combined  38.0  0.527533  0.460374  0.074682   0.376212  0.678854
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.9080
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -180.4310
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -58.5396
# 7                              Hedge's g =   -57.3115
# 8                         Glass's delta1 =   -58.5990
# 9                       Point-Biserial r =    -0.9994
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.031845  0.006104  0.001400   0.028903  0.034787
# 1  train_W_combine  19.0  0.992611  0.008038  0.001844   0.988737  0.996485
# 2         combined  38.0  0.512228  0.486882  0.078983   0.352194  0.672262
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9608
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -414.9351
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -134.6227
# 7                                Hedge's g =  -131.7985
# 8                           Glass's delta1 =  -157.4021
# 9                         Point-Biserial r =    -0.9999
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.047763  0.010676  0.002449   0.042617  0.052909
# 1  test_W_combine  19.0  0.992923  0.012184  0.002795   0.987050  0.998795
# 2        combined  38.0  0.520343  0.479057  0.077713   0.362881  0.677805
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.9452
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -254.3177
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -82.5116
# 7                              Hedge's g =   -80.7806
# 8                         Glass's delta1 =   -88.5289
# 9                       Point-Biserial r =    -0.9997
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.513889  0.002291  0.000526   0.512785  0.514993
# 1  train_W_combine  19.0  0.980472  0.010058  0.002307   0.975624  0.985320
# 2         combined  38.0  0.747180  0.236533  0.038371   0.669434  0.824927
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.4666
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -197.1603
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -63.9672
# 7                                Hedge's g =   -62.6253
# 8                           Glass's delta1 =  -203.6527
# 9                         Point-Biserial r =    -0.9995
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.498654  0.007993  0.001834   0.494801  0.502506
# 1  test_W_combine  19.0  0.982130  0.012036  0.002761   0.976329  0.987931
# 2        combined  38.0  0.740392  0.245190  0.039775   0.659800  0.820984
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.4835
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -145.8634
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -47.3243
# 7                              Hedge's g =   -46.3315
# 8                         Glass's delta1 =   -60.4875
# 9                       Point-Biserial r =    -0.9992

# %%
#effect encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 100
class_num = 10
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 10
# all_train_score_W0_p 0.46825396825396826
# all_train_score_W0_n 0.023745942711700625
# all_train_score_W0_a 0.01469486710764327
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.12677395420775453
# test_score_W0_a  0.07852640602997397
# all_train_score_W_combine_p 0.9940476190476191
# all_train_score_W_combine_n 0.9916632881795453
# all_train_score_W_combine_a 0.9985701283863946
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9860459033608542
# test_score_W_combine_a 0.9967374838079641
# neuron unit number: 15
# all_train_score_W0_p 0.4742063492063492
# all_train_score_W0_n 0.04148765553338862
# all_train_score_W0_a 0.019098633994755417
# test_score_W0_p0.5255813953488372
# test_score_W0_n 0.11308740162692178
# test_score_W0_a  0.09260926849562172
# all_train_score_W_combine_p 0.9940476190476191
# all_train_score_W_combine_n 0.9916632881795453
# all_train_score_W_combine_a 0.9985701283863946
# test_score_W_combine_p 0.986046511627907
# test_score_W_combine_n 0.9860459033608542
# test_score_W_combine_a 0.9967374838079641
# neuron unit number: 20
# all_train_score_W0_p 0.47023809523809523
# all_train_score_W0_n 0.02984884377127094
# all_train_score_W0_a 0.014820574063503917
# test_score_W0_p0.5162790697674419
# test_score_W0_n 0.09530941584496402
# test_score_W0_a  0.06081899966956605
# all_train_score_W_combine_p 0.996031746031746
# all_train_score_W_combine_n 0.9966015954058894
# all_train_score_W_combine_a 0.9995166857700892
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9876885251415177
# test_score_W_combine_a 0.9954391491698578
# neuron unit number: 25
# all_train_score_W0_p 0.4662698412698413
# all_train_score_W0_n 0.022250996034175383
# all_train_score_W0_a 0.008540740229224186
# test_score_W0_p0.5162790697674419
# test_score_W0_n 0.09529872084105785
# test_score_W0_a  0.06698963026689976
# all_train_score_W_combine_p 0.9841269841269841
# all_train_score_W_combine_n 0.9813872595454489
# all_train_score_W_combine_a 0.9957564711032881
# test_score_W_combine_p 0.958139534883721
# test_score_W_combine_n 0.9708488210949198
# test_score_W_combine_a 0.9902429008497388
# neuron unit number: 30
# all_train_score_W0_p 0.4662698412698413
# all_train_score_W0_n 0.021967973652355005
# all_train_score_W0_a 0.005527641268034403
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.05557473244926294
# test_score_W0_a  0.04438517498485652
# all_train_score_W_combine_p 1.0
# all_train_score_W_combine_n 1.0
# all_train_score_W_combine_a 1.0
# test_score_W_combine_p 0.9906976744186047
# test_score_W_combine_n 0.993864807662523
# test_score_W_combine_a 0.9986949935231856
# neuron unit number: 35
# all_train_score_W0_p 0.47023809523809523
# all_train_score_W0_n 0.029646699747346805
# all_train_score_W0_a 0.008543276970140594
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.11287759256978593
# test_score_W0_a  0.0968466391152647
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9867559174804168
# all_train_score_W_combine_a 0.9957323244791123
# test_score_W_combine_p 0.9813953488372092
# test_score_W_combine_n 0.975755515353899
# test_score_W_combine_a 0.9931523889058887
# neuron unit number: 40
# all_train_score_W0_p 0.47023809523809523
# all_train_score_W0_n 0.030900165967090505
# all_train_score_W0_a 0.015393264093280814
# test_score_W0_p0.5069767441860465
# test_score_W0_n 0.07766208564825593
# test_score_W0_a  0.04574578943300598
# all_train_score_W_combine_p 0.996031746031746
# all_train_score_W_combine_n 0.9966015954058894
# all_train_score_W_combine_a 0.9995166857700892
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9811343622834894
# test_score_W_combine_a 0.9956525222929888
# neuron unit number: 45
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.030376581165065655
# all_train_score_W0_a 0.01634689231733974
# test_score_W0_p0.5348837209302325
# test_score_W0_n 0.12770148314528573
# test_score_W0_a  0.08764861708760792
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9854751715282735
# all_train_score_W_combine_a 0.9935280314962108
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9876885251415177
# test_score_W_combine_a 0.9954391491698578
# neuron unit number: 50
# all_train_score_W0_p 0.4642857142857143
# all_train_score_W0_n 0.02452515167340846
# all_train_score_W0_a 0.010411119902781785
# test_score_W0_p0.5255813953488372
# test_score_W0_n 0.09979879151337498
# test_score_W0_a  0.09021430604212029
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9658361245227937
# all_train_score_W_combine_a 0.9859578292684162
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9607622749044306
# test_score_W_combine_a 0.9878436500981497
# neuron unit number: 55
# all_train_score_W0_p 0.4662698412698413
# all_train_score_W0_n 0.021964563078204265
# all_train_score_W0_a 0.0072248841989317235
# test_score_W0_p0.5023255813953489
# test_score_W0_n 0.06038640779024537
# test_score_W0_a  0.03884292764036842
# all_train_score_W_combine_p 0.9801587301587301
# all_train_score_W_combine_n 0.9636007484756033
# all_train_score_W_combine_a 0.9565432518801407
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9550002214046998
# test_score_W_combine_a 0.9677727659008764
# neuron unit number: 60
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.0393886736241618
# all_train_score_W0_a 0.018574881759692637
# test_score_W0_p0.5348837209302325
# test_score_W0_n 0.12135860702884739
# test_score_W0_a  0.09156290140217586
# all_train_score_W_combine_p 0.9940476190476191
# all_train_score_W_combine_n 0.9909915171992958
# all_train_score_W_combine_a 0.997343514834206
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9775930591857708
# test_score_W_combine_a 0.9917550608231556
# neuron unit number: 65
# all_train_score_W0_p 0.47023809523809523
# all_train_score_W0_n 0.028667438932620647
# all_train_score_W0_a 0.011030547277776043
# test_score_W0_p0.5116279069767442
# test_score_W0_n 0.09193390809106702
# test_score_W0_a  0.06718414046032702
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.9761908076252278
# all_train_score_W_combine_a 0.9926165870322444
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9657262853280575
# test_score_W_combine_a 0.9894671192665478
# neuron unit number: 70
# all_train_score_W0_p 0.46825396825396826
# all_train_score_W0_n 0.03500365229267342
# all_train_score_W0_a 0.012751117452243435
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.11979702297518681
# test_score_W0_a  0.10562114581061065
# all_train_score_W_combine_p 0.9880952380952381
# all_train_score_W_combine_n 0.983477048202423
# all_train_score_W_combine_a 0.9959738910180305
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9660744240011025
# test_score_W_combine_a 0.9908765214354911
# neuron unit number: 75
# all_train_score_W0_p 0.4662698412698413
# all_train_score_W0_n 0.026311288803583483
# all_train_score_W0_a 0.015573888845099172
# test_score_W0_p0.5069767441860465
# test_score_W0_n 0.06308269038067521
# test_score_W0_a  0.05636556180633351
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9857023755554017
# all_train_score_W_combine_a 0.9925675772313167
# test_score_W_combine_p 0.9953488372093023
# test_score_W_combine_n 0.9900492610667103
# test_score_W_combine_a 0.9963039234634256
# neuron unit number: 80
# all_train_score_W0_p 0.47619047619047616
# all_train_score_W0_n 0.046951263111512556
# all_train_score_W0_a 0.022629570105854924
# test_score_W0_p0.5209302325581395
# test_score_W0_n 0.11667787068530638
# test_score_W0_a  0.07087059760047973
# all_train_score_W_combine_p 0.9900793650793651
# all_train_score_W_combine_n 0.9827606091231459
# all_train_score_W_combine_a 0.9954927007396082
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9697161797322141
# test_score_W_combine_a 0.99087740997413
# neuron unit number: 85
# all_train_score_W0_p 0.4662698412698413
# all_train_score_W0_n 0.018711521423684367
# all_train_score_W0_a 0.007890281063815514
# test_score_W0_p0.5162790697674419
# test_score_W0_n 0.09012422181928378
# test_score_W0_a  0.04303307779400891
# all_train_score_W_combine_p 0.9940476190476191
# all_train_score_W_combine_n 0.9927345685618497
# all_train_score_W_combine_a 0.9990335164944364
# test_score_W_combine_p 0.9767441860465116
# test_score_W_combine_n 0.9791030624140732
# test_score_W_combine_a 0.9950013750316361
# neuron unit number: 90
# all_train_score_W0_p 0.4742063492063492
# all_train_score_W0_n 0.0326656566421837
# all_train_score_W0_a 0.018950877795350946
# test_score_W0_p0.5348837209302325
# test_score_W0_n 0.12887694019233864
# test_score_W0_a  0.0939746319036119
# all_train_score_W_combine_p 0.9861111111111112
# all_train_score_W_combine_n 0.9815449222100913
# all_train_score_W_combine_a 0.9951894759077329
# test_score_W_combine_p 0.9627906976744186
# test_score_W_combine_n 0.9658029171269378
# test_score_W_combine_a 0.9904448620814553
# neuron unit number: 95
# all_train_score_W0_p 0.47619047619047616
# all_train_score_W0_n 0.03864033598937629
# all_train_score_W0_a 0.029193771160916714
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.12166542663861593
# test_score_W0_a  0.08205496116321809
# all_train_score_W_combine_p 0.9821428571428571
# all_train_score_W_combine_n 0.9719042266195592
# all_train_score_W_combine_a 0.9927942102085722
# test_score_W_combine_p 0.9674418604651163
# test_score_W_combine_n 0.9637504775781737
# test_score_W_combine_a 0.9897953626842122
# neuron unit number: 100
# all_train_score_W0_p 0.4722222222222222
# all_train_score_W0_n 0.036789621160586004
# all_train_score_W0_a 0.03016368863295975
# test_score_W0_p0.5302325581395348
# test_score_W0_n 0.11882563551852118
# test_score_W0_a  0.09119187832227
# all_train_score_W_combine_p 0.9920634920634921
# all_train_score_W_combine_n 0.9867559174804168
# all_train_score_W_combine_a 0.9957323244791123
# test_score_W_combine_p 0.9720930232558139
# test_score_W_combine_n 0.9710455128878901
# test_score_W_combine_a 0.992502427856453
# test_score_W0_p mean 0.5214198286413708
# test_score_W_combine_p mean 0.9747858017135861
# test_score_W0_n mean 0.10193752152456587
# test_score_W_combine_n mean 0.9754576862647176
# test_score_W0_a mean 0.07392035026464848
# test_score_W_combine_a mean 0.9918282394812096
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.030518  0.007664  0.001758   0.026824  0.034212
# 1  train_W_combine  19.0  0.984824  0.009977  0.002289   0.980015  0.989632
# 2         combined  38.0  0.507671  0.483637  0.078456   0.348703  0.666638
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9543
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -330.6392
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -107.2735
# 7                                Hedge's g =  -105.0230
# 8                           Glass's delta1 =  -124.5109
# 9                         Point-Biserial r =    -0.9998
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.101938  0.023741  0.005447   0.090495  0.113380
# 1  test_W_combine  19.0  0.975458  0.011172  0.002563   0.970073  0.980842
# 2        combined  38.0  0.538698  0.443001  0.071864   0.393087  0.684308
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.8735
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -145.1169
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -47.0821
# 7                              Hedge's g =   -46.0944
# 8                         Glass's delta1 =   -36.7938
# 9                       Point-Biserial r =    -0.9991
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.015124  0.006924  0.001588   0.011787  0.018461
# 1  train_W_combine  19.0  0.993707  0.009613  0.002205   0.989074  0.998341
# 2         combined  38.0  0.504416  0.495928  0.080450   0.341408  0.667423
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.9786
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -360.0461
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -116.8144
# 7                                Hedge's g =  -114.3637
# 8                           Glass's delta1 =  -141.3331
# 9                         Point-Biserial r =    -0.9999
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.073920  0.020905  0.004796   0.063845  0.083996
# 1  test_W_combine  19.0  0.991828  0.006578  0.001509   0.988658  0.994999
# 2        combined  38.0  0.532874  0.465366  0.075492   0.379912  0.685836
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.9179
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -182.5713
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -59.2340
# 7                              Hedge's g =   -57.9913
# 8                         Glass's delta1 =   -43.9094
# 9                       Point-Biserial r =    -0.9995
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  19.0  0.470029  0.003616  0.000830   0.468286  0.471772
# 1  train_W_combine  19.0  0.990288  0.005608  0.001287   0.987585  0.992991
# 2         combined  38.0  0.730159  0.263662  0.042772   0.643495  0.816822
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.5203
# 1                       Degrees of freedom =    36.0000
# 2                                        t =  -339.8574
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =  -110.2643
# 7                                Hedge's g =  -107.9511
# 8                           Glass's delta1 =  -143.8712
# 9                         Point-Biserial r =    -0.9998
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  19.0  0.521420  0.011276  0.002587   0.515985  0.526855
# 1  test_W_combine  19.0  0.974786  0.009471  0.002173   0.970221  0.979351
# 2        combined  38.0  0.748103  0.229955  0.037304   0.672518  0.823687
#                          Independent t-test   results
# 0  Difference (test_W0 - test_W_combine) =    -0.4534
# 1                     Degrees of freedom =    36.0000
# 2                                      t =  -134.2013
# 3                  Two side test p value =     0.0000
# 4                 Difference < 0 p value =     0.0000
# 5                 Difference > 0 p value =     1.0000
# 6                              Cohen's d =   -43.5407
# 7                              Hedge's g =   -42.6272
# 8                         Glass's delta1 =   -40.2071
# 9                       Point-Biserial r =    -0.9990
