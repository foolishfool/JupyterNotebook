# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import warnings
warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*")
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Airline Passenger Satisfaction/train.csv")
csv2 = pd.read_csv("Airline Passenger Satisfaction/test.csv")
csv = csv.drop(columns=['id'])
csv2 = csv2.drop(columns=['id'])   

dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"Arrival Delay in Minutes")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"Arrival Delay in Minutes")

csv_original_encode1 = csv
csv_original_encode2 = csv2

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode1,"satisfaction")
#one hot encoding vs proposed
#dataread.hash_encoding(csv_original_encode1,["Gender","Customer Type","Type of Travel","Class"])

#csv_training_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.03))

#print(dataread.original_encoding_data)
dataread.label_encoding(csv_original_encode2, "satisfaction")
#one hot encoding vs proposed
#dataread.hash_encoding(csv_original_encode2,["Gender","Customer Type","Type of Travel","Class"])

#dataread.original_encoding_data is udpated through dataread.label_encoding function
#csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.1))


dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Customer Type")
dataread.label_encoding(csv,"Type of Travel")
dataread.label_encoding(csv,"Class")
dataread.label_encoding(csv,"satisfaction")


dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Customer Type")
dataread.label_encoding(csv2,"Type of Travel")
dataread.label_encoding(csv2,"Class")
dataread.label_encoding(csv2,"satisfaction")

#print(csv)
csv_training = csv.sample(int(csv.shape[0]*0.03))
csv_test = csv2.sample(int(csv2.shape[0]*0.1))



# label encoding
dataread.original_encoding_data = csv_training
csv_training_original_encoded = csv_training
csv_test_original_encoded = csv_test
#*** -1 the class labe is not included 
dataread.original_encoded_feature_num = csv.shape[1]-1


#print(csv_training)
#print(csv_test)


dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"satisfaction")
# Out:
# self.data_continuous_indexes ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
# self.continuous_feature_num 4
#  column number self.data_train_discrete 18

# %%
# #AffinityPropagation
import experiment
unstable_repeat_num= 30
scope_num = 40
class_num = 13
dim_num = 7
best_num = 48
interval = 3


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# 3117
# 1
# test_discrete_score_W0_p 0.5664227955333077
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# 1
# test_discrete_score_W_discrete_p 0.5664227955333077
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 16
# 3117
# 4
# test_discrete_score_W0_p 0.6484405082787832
# test_discrete_score_W0_n 0.05688837763258933
# test_discrete_score_W0_a 0.08430770482863728
# 4
# test_discrete_score_W_discrete_p 0.7681940700808625
# test_discrete_score_W_discrete_n 0.22396594765758002
# test_discrete_score_W_discrete_a 0.28744106311088685
# neuron unit number: 19
# 3117
# 1
# test_discrete_score_W0_p 0.5664227955333077
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# 1
# test_discrete_score_W_discrete_p 0.5664227955333077
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 22
# 3117
# 2
# test_discrete_score_W0_p 0.6484405082787832
# ...

# %%
# compare fuzzy with probability
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.8129611806223933
# train_discrete_score_W0_n 0.3619691432598001
# train_discrete_score_W0_a  0.38942636147785004
# test_discrete_score_W0_p 0.8144012321909896
# test_discrete_score_W0_n 0.3683375081831361
# test_discrete_score_W0_a 0.3936097533775333
# train_discrete_score_W_discrete_p 0.8832210458774462
# train_discrete_score_W_discrete_n 0.47877188795638864
# train_discrete_score_W_discrete_a 0.5869972800798785
# test_discrete_score_W_discrete_p 0.8833269156719291
# test_discrete_score_W_discrete_n 0.4800333306581668
# test_discrete_score_W_discrete_a 0.5874025139224173
# neuron unit number: 7
# train_discrete_score_W0_p 0.8707090150786012
# train_discrete_score_W0_n 0.4450951051502497
# train_discrete_score_W0_a  0.5491524297671977
# test_discrete_score_W0_p 0.875240662302657
# test_discrete_score_W0_n 0.45725981077423045
# test_discrete_score_W0_a 0.5628260685585474
# train_discrete_score_W_discrete_p 0.9018286814244466
# ...

# %%
#new binary
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.5601539942252165
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5787447054293415
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8399101700352903
# train_discrete_score_W_discrete_n 0.3612410843537402
# train_discrete_score_W_discrete_a 0.46189217109645486
# test_discrete_score_W_discrete_p 0.8328840970350404
# test_discrete_score_W_discrete_n 0.3419347907274927
# test_discrete_score_W_discrete_a 0.44218678378192383
# neuron unit number: 7
# train_discrete_score_W0_p 0.5601539942252165
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5787447054293415
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.879050368944498
# train_discrete_score_W_discrete_n 0.4673975248114519
# train_discrete_score_W_discrete_a 0.5743580733468097
# ...

# %%
#new one hot endoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.561758100737889
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5471698113207547
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8793711902470324
# train_discrete_score_W_discrete_n 0.4662774031169129
# train_discrete_score_W_discrete_a 0.575347341834703
# test_discrete_score_W_discrete_p 0.8671544089333847
# test_discrete_score_W_discrete_n 0.43773794664157767
# test_discrete_score_W_discrete_a 0.5389020057121162
# neuron unit number: 7
# train_discrete_score_W0_p 0.561758100737889
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5471698113207547
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8768046198267565
# train_discrete_score_W_discrete_n 0.4578280878142874
# train_discrete_score_W_discrete_a 0.5676041668369236
# ...

# %%
#new sum encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.5697786333012512
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5502502887947632
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8575553416746872
# train_discrete_score_W_discrete_n 0.4067419131125221
# train_discrete_score_W_discrete_a 0.5107415405241694
# test_discrete_score_W_discrete_p 0.8348093954562957
# test_discrete_score_W_discrete_n 0.35564291219394384
# test_discrete_score_W_discrete_a 0.4479372838734729
# neuron unit number: 7
# train_discrete_score_W0_p 0.5697786333012512
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5502502887947632
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8822585819698427
# train_discrete_score_W_discrete_n 0.4747692420574116
# train_discrete_score_W_discrete_a 0.5840057503019439
# ...

# %%
# hash encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.5659287776708374
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5660377358490566
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8761629772216876
# train_discrete_score_W_discrete_n 0.4545837359937302
# train_discrete_score_W_discrete_a 0.5656549612927295
# test_discrete_score_W_discrete_p 0.8848671544089334
# test_discrete_score_W_discrete_n 0.4826055369582946
# test_discrete_score_W_discrete_a 0.5920690878344183
# neuron unit number: 7
# train_discrete_score_W0_p 0.5659287776708374
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5660377358490566
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8848251523901187
# train_discrete_score_W_discrete_n 0.48184316977019104
# train_discrete_score_W_discrete_a 0.5919808225530109
# ...

# %%
# sum encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.5694578119987167
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5702733923758182
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.727943535450754
# train_discrete_score_W_discrete_n 0.14718156260579357
# train_discrete_score_W_discrete_a 0.20704596982273415
# test_discrete_score_W_discrete_p 0.7308432807085098
# test_discrete_score_W_discrete_n 0.1513350461860414
# test_discrete_score_W_discrete_a 0.2123465140892595
# neuron unit number: 7
# train_discrete_score_W0_p 0.5694578119987167
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5706584520600693
# test_discrete_score_W0_n 0.0021367805940718304
# test_discrete_score_W0_a 0.006685052473698166
# train_discrete_score_W_discrete_p 0.7847289059993584
# train_discrete_score_W_discrete_n 0.2452270558845993
# ...

# %%
# new baseN encoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

newexperiment = experiment.Experiment()
newexperiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.5765158806544755
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5506353484790143
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8572345203721528
# train_discrete_score_W_discrete_n 0.41065659639557445
# train_discrete_score_W_discrete_a 0.5094190243177602
# test_discrete_score_W_discrete_p 0.8455910666153253
# test_discrete_score_W_discrete_n 0.3882339316042403
# test_discrete_score_W_discrete_a 0.477230613021588
# neuron unit number: 7
# train_discrete_score_W0_p 0.5765158806544755
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5506353484790143
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.8803336541546358
# train_discrete_score_W_discrete_n 0.46489577281992983
# train_discrete_score_W_discrete_a 0.5781225540648093
# ...
