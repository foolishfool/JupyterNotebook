# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Airline Passenger Satisfaction/train.csv")
csv2 = pd.read_csv("Airline Passenger Satisfaction/test.csv")
csv = csv.drop(columns=['id'])
csv2 = csv2.drop(columns=['id'])   

csv_original_encode1 = csv
csv_original_encode2 = csv2

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode1,"satisfaction")
#one hot encoding vs proposed
dataread.onehot_encoding(csv_original_encode1,["Gender","Customer Type","Type of Travel","Class"])

csv_training_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.03))


dataread.label_encoding(csv_original_encode2, "satisfaction")
#one hot encoding vs proposed
dataread.onehot_encoding(csv_original_encode2,["Gender","Customer Type","Type of Travel","Class"])

#dataread.original_encoding_data is udpated through dataread.label_encoding function
csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.1))


dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Customer Type")
dataread.label_encoding(csv,"Type of Travel")
dataread.label_encoding(csv,"Class")
dataread.label_encoding(csv,"satisfaction")


dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Customer Type")
dataread.label_encoding(csv2,"Type of Travel")
dataread.label_encoding(csv2,"Class")
dataread.label_encoding(csv2,"satisfaction")

csv_training = csv.sample(int(csv.shape[0]*0.03))
csv_test = csv2.sample(int(csv2.shape[0]*0.1))



dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"satisfaction")
# Out:
# self.data_continuous_indexes ['Age', 'Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
#  column number self.data_train_discrete 18

# %%
# softmax vs orignal
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7481552775104267
# train_discrete_score_W_discrete_n 0.1852275893728915
# train_discrete_score_W_discrete_a 0.2460549987544204
# test_discrete_score_W_discrete_p 0.7377743550250289
# test_discrete_score_W_discrete_n 0.16297380308696058
# test_discrete_score_W_discrete_a 0.2255222458799179
# neuron unit number: 7
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7600256657042027
# train_discrete_score_W_discrete_n 0.20544125136708766
# train_discrete_score_W_discrete_a 0.2702017536313742
# test_discrete_score_W_discrete_p 0.7539468617635734
# test_discrete_score_W_discrete_n 0.1887594704258533
# test_discrete_score_W_discrete_a 0.2574362349307389
# neuron unit number: 12
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7856913699069619
# train_discrete_score_W_discrete_n 0.24454510878141533
# train_discrete_score_W_discrete_a 0.32577772586465986
# test_discrete_score_W_discrete_p 0.7889872930304197
# test_discrete_score_W_discrete_n 0.24998194190403403
# test_discrete_score_W_discrete_a 0.33334889721202887
# neuron unit number: 17
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7609881296118062
# train_discrete_score_W_discrete_n 0.19981727572329533
# train_discrete_score_W_discrete_a 0.27173632556573735
# test_discrete_score_W_discrete_p 0.7500962649210627
# test_discrete_score_W_discrete_n 0.18204249671310074
# test_discrete_score_W_discrete_a 0.24960567132578523
# neuron unit number: 22
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7828039781841514
# train_discrete_score_W_discrete_n 0.2386057740535681
# train_discrete_score_W_discrete_a 0.31927531870189846
# test_discrete_score_W_discrete_p 0.7662687716596073
# test_discrete_score_W_discrete_n 0.21092524518263728
# test_discrete_score_W_discrete_a 0.28319210342813256
# neuron unit number: 27
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7760667308309271
# train_discrete_score_W_discrete_n 0.22602632139153966
# train_discrete_score_W_discrete_a 0.3043108401504677
# test_discrete_score_W_discrete_p 0.7624181748170966
# test_discrete_score_W_discrete_n 0.204061921002136
# test_discrete_score_W_discrete_a 0.2742888000829049
# neuron unit number: 32
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7507218479307026
# train_discrete_score_W_discrete_n 0.18344958941464906
# train_discrete_score_W_discrete_a 0.2509431998558995
# test_discrete_score_W_discrete_p 0.7416249518675395
# test_discrete_score_W_discrete_n 0.16861315687007886
# test_discrete_score_W_discrete_a 0.23288668611090294
# neuron unit number: 37
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7815206929740135
# train_discrete_score_W_discrete_n 0.23606271626393682
# train_discrete_score_W_discrete_a 0.31641300329965455
# test_discrete_score_W_discrete_p 0.7735849056603774
# test_discrete_score_W_discrete_n 0.22221878582012353
# test_discrete_score_W_discrete_a 0.2989209862774657
# neuron unit number: 42
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7751042669233237
# train_discrete_score_W_discrete_n 0.22489949657318806
# train_discrete_score_W_discrete_a 0.3022936909346165
# test_discrete_score_W_discrete_p 0.7716596072391221
# test_discrete_score_W_discrete_n 0.21844842726330044
# test_discrete_score_W_discrete_a 0.29468690359373195
# neuron unit number: 47
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7853705486044273
# train_discrete_score_W_discrete_n 0.247082195341539
# train_discrete_score_W_discrete_a 0.32478853516386497
# test_discrete_score_W_discrete_p 0.777435502502888
# test_discrete_score_W_discrete_n 0.22934695799147928
# test_discrete_score_W_discrete_a 0.3069707861451812
# neuron unit number: 52
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7754250882258582
# train_discrete_score_W_discrete_n 0.22515204146033743
# train_discrete_score_W_discrete_a 0.302746694814633
# test_discrete_score_W_discrete_p 0.7762803234501348
# test_discrete_score_W_discrete_n 0.226436006351907
# test_discrete_score_W_discrete_a 0.30479574971600154
# neuron unit number: 57
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7699711260827719
# train_discrete_score_W_discrete_n 0.21555228882439045
# train_discrete_score_W_discrete_a 0.29079773883950677
# test_discrete_score_W_discrete_p 0.7593376973430882
# test_discrete_score_W_discrete_n 0.1968255633970485
# test_discrete_score_W_discrete_a 0.2681347790133242
# neuron unit number: 62
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7690086621751684
# train_discrete_score_W_discrete_n 0.21396632998759726
# train_discrete_score_W_discrete_a 0.2886989342538653
# test_discrete_score_W_discrete_p 0.7612629957643434
# test_discrete_score_W_discrete_n 0.2005868800605242
# test_discrete_score_W_discrete_a 0.27250589151359994
# neuron unit number: 67
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7850497273018928
# train_discrete_score_W_discrete_n 0.24282171918253
# train_discrete_score_W_discrete_a 0.324558167420011
# test_discrete_score_W_discrete_p 0.7755102040816326
# test_discrete_score_W_discrete_n 0.22490364068125018
# test_discrete_score_W_discrete_a 0.3030728873604999
# neuron unit number: 72
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7834456207892204
# train_discrete_score_W_discrete_n 0.2398388010359085
# train_discrete_score_W_discrete_a 0.3209100438254034
# test_discrete_score_W_discrete_p 0.7735849056603774
# test_discrete_score_W_discrete_n 0.2211498403866954
# test_discrete_score_W_discrete_a 0.29874123957659254
# neuron unit number: 77
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7670837343599615
# train_discrete_score_W_discrete_n 0.21228583347143068
# train_discrete_score_W_discrete_a 0.2849786155782987
# test_discrete_score_W_discrete_p 0.7524066230265691
# test_discrete_score_W_discrete_n 0.18757939996253092
# test_discrete_score_W_discrete_a 0.25439965413895693
# neuron unit number: 82
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.779916586461341
# train_discrete_score_W_discrete_n 0.23316671051623028
# train_discrete_score_W_discrete_a 0.31292462999379184
# test_discrete_score_W_discrete_p 0.777435502502888
# test_discrete_score_W_discrete_n 0.22914030583517056
# test_discrete_score_W_discrete_a 0.3069955606321182
# neuron unit number: 87
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7815206929740135
# train_discrete_score_W_discrete_n 0.23633221878692784
# train_discrete_score_W_discrete_a 0.316565190500214
# test_discrete_score_W_discrete_p 0.7728147862918753
# test_discrete_score_W_discrete_n 0.21991302602413323
# test_discrete_score_W_discrete_a 0.2971187834885807
# neuron unit number: 92
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7933910811677896
# train_discrete_score_W_discrete_n 0.26008508799386404
# train_discrete_score_W_discrete_a 0.343585226457992
# test_discrete_score_W_discrete_p 0.7812860993453985
# test_discrete_score_W_discrete_n 0.23590380450660683
# test_discrete_score_W_discrete_a 0.3156674583113499
# neuron unit number: 97
# train_discrete_score_W0_p 0.5627205646454925
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.5644974971120523
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.7693294834777029
# train_discrete_score_W_discrete_n 0.2152659003595861
# train_discrete_score_W_discrete_a 0.2892894259413882
# test_discrete_score_W_discrete_p 0.7566422795533307
# test_discrete_score_W_discrete_n 0.19270729201841807
# test_discrete_score_W_discrete_a 0.2624736584787792
# test_discrete_score_W0_p mean 0.5644974971120523
# test_discrete_score_W_discrete_p mean 0.7655179052753177
# test_discrete_score_W0_n mean 0.0
# test_discrete_score_W_discrete_n mean 0.20862589827419944
# test_discrete_score_W0_a mean 0.0
# test_discrete_score_W_discrete_a mean 0.2820382488608297
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  20.0  0.224281  0.020422  0.004567   0.214723  0.233839
# 2         combined  40.0  0.112141  0.114460  0.018098   0.075534  0.148747
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2243
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -49.1143
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -15.5313
# 7                                    Hedge's g =  -15.2227
# 8                                Glass's delta =      -inf
# 9                                  Pearson's r =    0.9922
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  test_dis_W_dis  20.0  0.208626  0.023130  0.005172   0.197801  0.219451
# 2        combined  40.0  0.104313  0.106868  0.016897   0.070135  0.138491
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2086
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -40.3370
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -12.7557
# 7                                  Hedge's g =  -12.5023
# 8                              Glass's delta =      -inf
# 9                                Pearson's r =    0.9885
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  20.0  0.300343  0.026043  0.005823   0.288154  0.312531
# 2         combined  40.0  0.150171  0.153167  0.024218   0.101186  0.199156
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.3003
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -51.5751
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -16.3095
# 7                                    Hedge's g =  -15.9855
# 8                                Glass's delta =      -inf
# 9                                  Pearson's r =    0.9929
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  test_dis_W_dis  20.0  0.282038  0.028727  0.006423   0.268594  0.295483
# 2        combined  40.0  0.141019  0.144216  0.022803   0.094897  0.187142
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2820
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -43.9073
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -13.8847
# 7                                  Hedge's g =  -13.6089
# 8                              Glass's delta =      -inf
# 9                                Pearson's r =    0.9903
# Purity T-Test
#           Variable     N      Mean        SD            SE  95% Conf.  \
# 0     train_dis_W0  20.0  0.562721  0.000000  2.547026e-17   0.562721
# 1  train_dis_W_dis  20.0  0.774030  0.012078  2.700710e-03   0.768377
# 2         combined  40.0  0.668375  0.107332  1.697068e-02   0.634049
#
#    Interval
# 0  0.562721
# 1  0.779682
# 2  0.702701
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.2113
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -78.2420
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =  -24.7423
# 7                                    Hedge's g =  -24.2507
# 8                                Glass's delta =      -inf
# 9                                  Pearson's r =    0.9969
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.564497  0.000000  0.000000        NaN       NaN
# 1  test_dis_W_dis  20.0  0.765518  0.013669  0.003056   0.759121  0.771915
# 2        combined  40.0  0.665008  0.102237  0.016165   0.632311  0.697705
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.2010
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -65.7708
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =  -20.7986
# 7                                  Hedge's g =  -20.3853
# 8                              Glass's delta =      -inf
# 9                                Pearson's r =    0.9956
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:26: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_val, p_val = scipy.stats.ttest_ind(group1, group2, nan_policy= 'omit')
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:26: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_val, p_val = scipy.stats.ttest_ind(group1, group2, nan_policy= 'omit')
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#compare softmax
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.779274943856272
# train_discrete_score_W0_n 0.2349951753703313
# train_discrete_score_W0_a  0.31166361077392324
# test_discrete_score_W0_p 0.7620331151328456
# test_discrete_score_W0_n 0.20325911856772924
# test_discrete_score_W0 0.2742046643936684
# train_discrete_score_W_discrete_p 0.7856913699069619
# train_discrete_score_W_discrete_n 0.2570807954235131
# train_discrete_score_W_discrete_a 0.32626522338760233
# test_discrete_score_W_discrete_p 0.7662687716596073
# test_discrete_score_W_discrete_n 0.2183311897386222
# test_discrete_score_W_discrete_a 0.28331309676092786
# neuron unit number: 7
# train_discrete_score_W0_p 0.8036573628488932
# train_discrete_score_W0_n 0.2820666930397252
# train_discrete_score_W0_a  0.3685402633327211
# test_discrete_score_W0_p 0.783981517135156
# test_discrete_score_W0_n 0.2526432340770651
# test_discrete_score_W0 0.32232178372595377
# train_discrete_score_W_discrete_p 0.8036573628488932
# train_discrete_score_W_discrete_n 0.2846222904861892
# train_discrete_score_W_discrete_a 0.3685840462882928
# test_discrete_score_W_discrete_p 0.7889872930304197
# test_discrete_score_W_discrete_n 0.2491877981396473
# test_discrete_score_W_discrete_a 0.3334905660997631
# Not good nmi result for discrete features !!!!!
# neuron unit number: 12
# train_discrete_score_W0_p 0.8062239332691691
# train_discrete_score_W0_n 0.285475930414568
# train_discrete_score_W0_a  0.3747470772561703
# test_discrete_score_W0_p 0.7882171736619176
# test_discrete_score_W0_n 0.24808613732781787
# test_discrete_score_W0 0.331752028472171
# train_discrete_score_W_discrete_p 0.8042990054539622
# train_discrete_score_W_discrete_n 0.2809716756439039
# train_discrete_score_W_discrete_a 0.37001660965571337
# test_discrete_score_W_discrete_p 0.7847516365036581
# test_discrete_score_W_discrete_n 0.24146035427358917
# test_discrete_score_W_discrete_a 0.32338468135477666
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# train_discrete_score_W0_p 0.8078280397818415
# train_discrete_score_W0_n 0.2909637794446914
# train_discrete_score_W0_a  0.3787523390732652
# test_discrete_score_W0_p 0.7916827108201772
# test_discrete_score_W0_n 0.2563948617456896
# test_discrete_score_W0 0.3398993376120575
# train_discrete_score_W_discrete_p 0.8123195380173244
# train_discrete_score_W_discrete_n 0.3017141001383432
# train_discrete_score_W_discrete_a 0.38992093212354084
# test_discrete_score_W_discrete_p 0.7901424720831729
# test_discrete_score_W_discrete_n 0.25156717668590567
# test_discrete_score_W_discrete_a 0.3361895651496537
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# train_discrete_score_W0_p 0.8065447545717036
# train_discrete_score_W0_n 0.2868472602692618
# train_discrete_score_W0_a  0.37555988548518493
# test_discrete_score_W0_p 0.7847516365036581
# test_discrete_score_W0_n 0.24459237500123682
# test_discrete_score_W0 0.32395777609793436
# train_discrete_score_W_discrete_p 0.8017324350336862
# train_discrete_score_W_discrete_n 0.28025432174693576
# train_discrete_score_W_discrete_a 0.3639151823158158
# test_discrete_score_W_discrete_p 0.7893723527146708
# test_discrete_score_W_discrete_n 0.24950359653637322
# test_discrete_score_W_discrete_a 0.3342013704668918
# neuron unit number: 27
# train_discrete_score_W0_p 0.809432146294514
# train_discrete_score_W0_n 0.3000631838450717
# train_discrete_score_W0_a  0.38278047385538966
# test_discrete_score_W0_p 0.7920677705044282
# test_discrete_score_W0_n 0.2579815700399832
# test_discrete_score_W0 0.3408303155925553
# train_discrete_score_W_discrete_p 0.8107154315046519
# train_discrete_score_W_discrete_n 0.2952437711183656
# train_discrete_score_W_discrete_a 0.3858524813117862
# test_discrete_score_W_discrete_p 0.7943781286099345
# test_discrete_score_W_discrete_n 0.2598515524230531
# test_discrete_score_W_discrete_a 0.3461094966769327
# neuron unit number: 32
# train_discrete_score_W0_p 0.8065447545717036
# train_discrete_score_W0_n 0.28703267353850004
# train_discrete_score_W0_a  0.3755656415630463
# test_discrete_score_W0_p 0.797458606083943
# test_discrete_score_W0_n 0.26706709690754277
# test_discrete_score_W0 0.35349000390821805
# train_discrete_score_W_discrete_p 0.8017324350336862
# train_discrete_score_W_discrete_n 0.278147237085284
# train_discrete_score_W_discrete_a 0.36387678823158554
# test_discrete_score_W_discrete_p 0.790912591451675
# test_discrete_score_W_discrete_n 0.2533642424752621
# test_discrete_score_W_discrete_a 0.3376000525307356
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# train_discrete_score_W0_p 0.8036573628488932
# train_discrete_score_W0_n 0.28195743344459656
# train_discrete_score_W0_a  0.3685377047433315
# test_discrete_score_W0_p 0.7862918752406624
# test_discrete_score_W0_n 0.24631876444838596
# test_discrete_score_W0 0.3274372572293431
# train_discrete_score_W_discrete_p 0.8123195380173244
# train_discrete_score_W_discrete_n 0.2983463728463248
# train_discrete_score_W_discrete_a 0.38984166173864665
# test_discrete_score_W_discrete_p 0.8001540238737004
# test_discrete_score_W_discrete_n 0.2708324096928398
# test_discrete_score_W_discrete_a 0.359782803130306
# neuron unit number: 42
# train_discrete_score_W0_p 0.8107154315046519
# train_discrete_score_W0_n 0.297084890464824
# train_discrete_score_W0_a  0.3859006588486037
# test_discrete_score_W0_p 0.7897574123989218
# test_discrete_score_W0_n 0.2563618176898602
# test_discrete_score_W0 0.33551834243714584
# train_discrete_score_W_discrete_p 0.8152069297401348
# train_discrete_score_W_discrete_n 0.30934473824469455
# train_discrete_score_W_discrete_a 0.3971891399404496
# test_discrete_score_W_discrete_p 0.8001540238737004
# test_discrete_score_W_discrete_n 0.2715610864563762
# test_discrete_score_W_discrete_a 0.3598806611613909
# neuron unit number: 47
# train_discrete_score_W0_p 0.8091113249919795
# train_discrete_score_W0_n 0.2968421546618321
# train_discrete_score_W0_a  0.381966720018466
# test_discrete_score_W0_p 0.7932229495571813
# test_discrete_score_W0_n 0.25870567006394674
# test_discrete_score_W0 0.34347316479771267
# train_discrete_score_W_discrete_p 0.8119987167147898
# train_discrete_score_W_discrete_n 0.3048178416663097
# train_discrete_score_W_discrete_a 0.38915779541059387
# test_discrete_score_W_discrete_p 0.7924528301886793
# test_discrete_score_W_discrete_n 0.25630643039348844
# test_discrete_score_W_discrete_a 0.34160612517434924
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 52
# train_discrete_score_W0_p 0.8113570741097209
# train_discrete_score_W0_n 0.29583319284450343
# train_discrete_score_W0_a  0.38741844053134544
# test_discrete_score_W0_p 0.7951482479784366
# test_discrete_score_W0_n 0.26074970957704935
# test_discrete_score_W0 0.3478095633762163
# train_discrete_score_W_discrete_p 0.8062239332691691
# train_discrete_score_W_discrete_n 0.2855526506898857
# train_discrete_score_W_discrete_a 0.3747502726143617
# test_discrete_score_W_discrete_p 0.7936080092414324
# test_discrete_score_W_discrete_n 0.2596837906497025
# test_discrete_score_W_discrete_a 0.34438938377944434
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 57
# train_discrete_score_W0_p 0.8078280397818415
# train_discrete_score_W0_n 0.28788341332892764
# train_discrete_score_W0_a  0.37863933969044944
# test_discrete_score_W0_p 0.784366576819407
# test_discrete_score_W0_n 0.24050765388008125
# test_discrete_score_W0 0.3228904865005202
# train_discrete_score_W_discrete_p 0.8059031119666346
# train_discrete_score_W_discrete_n 0.2901067427076679
# train_discrete_score_W_discrete_a 0.3740713602084939
# test_discrete_score_W_discrete_p 0.7951482479784366
# test_discrete_score_W_discrete_n 0.2609685988990459
# test_discrete_score_W_discrete_a 0.34787394612165723
# neuron unit number: 62
# train_discrete_score_W0_p 0.8100737888995829
# train_discrete_score_W0_n 0.2930004642252456
# train_discrete_score_W0_a  0.3842199614962623
# test_discrete_score_W0_p 0.7924528301886793
# test_discrete_score_W0_n 0.25562871066088777
# test_discrete_score_W0 0.34133243981564293
# train_discrete_score_W_discrete_p 0.8119987167147898
# train_discrete_score_W_discrete_n 0.3000484643975853
# train_discrete_score_W_discrete_a 0.3891032180132631
# test_discrete_score_W_discrete_p 0.790912591451675
# test_discrete_score_W_discrete_n 0.2547067388810264
# test_discrete_score_W_discrete_a 0.3380946013970368
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 67
# train_discrete_score_W0_p 0.8148861084376002
# train_discrete_score_W0_n 0.30905329461316144
# train_discrete_score_W0_a  0.3963843568629103
# test_discrete_score_W0_p 0.7924528301886793
# test_discrete_score_W0_n 0.25630643039348844
# test_discrete_score_W0 0.34160612517434924
# train_discrete_score_W_discrete_p 0.8007699711260827
# train_discrete_score_W_discrete_n 0.27506068029870956
# train_discrete_score_W_discrete_a 0.361524274319337
# test_discrete_score_W_discrete_p 0.7866769349249133
# test_discrete_score_W_discrete_n 0.2448955575845469
# test_discrete_score_W_discrete_a 0.3281781800631179
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 72
# train_discrete_score_W0_p 0.8087905036894449
# train_discrete_score_W0_n 0.2959256350333384
# train_discrete_score_W0_a  0.3811710218011588
# test_discrete_score_W0_p 0.790912591451675
# test_discrete_score_W0_n 0.25390087493216845
# test_discrete_score_W0 0.338051518280288
# train_discrete_score_W_discrete_p 0.8110362528071864
# train_discrete_score_W_discrete_n 0.2970279366146511
# train_discrete_score_W_discrete_a 0.3866828046624623
# test_discrete_score_W_discrete_p 0.797073546399692
# test_discrete_score_W_discrete_n 0.26634969501921346
# test_discrete_score_W_discrete_a 0.35257599774431625
# neuron unit number: 77
# train_discrete_score_W0_p 0.8180943214629451
# train_discrete_score_W0_n 0.3143511724440667
# train_discrete_score_W0_a  0.4044909536763652
# test_discrete_score_W0_p 0.7963034270311898
# test_discrete_score_W0_n 0.2630221446764005
# test_discrete_score_W0 0.35053506915283683
# train_discrete_score_W_discrete_p 0.806865575874238
# train_discrete_score_W_discrete_n 0.28867613217235555
# train_discrete_score_W_discrete_a 0.37637862503335795
# test_discrete_score_W_discrete_p 0.7997689641894493
# test_discrete_score_W_discrete_n 0.26996173723952427
# test_discrete_score_W_discrete_a 0.35877545425981794
# neuron unit number: 82
# train_discrete_score_W0_p 0.8119987167147898
# train_discrete_score_W0_n 0.2991204760746837
# train_discrete_score_W0_a  0.3890838239763528
# test_discrete_score_W0_p 0.7947631882941856
# test_discrete_score_W0_n 0.26317663482708115
# test_discrete_score_W0 0.34715905628690374
# train_discrete_score_W_discrete_p 0.8139236445299968
# train_discrete_score_W_discrete_n 0.3040370063870539
# train_discrete_score_W_discrete_a 0.39392248022780435
# test_discrete_score_W_discrete_p 0.8032345013477089
# test_discrete_score_W_discrete_n 0.27711496721387074
# test_discrete_score_W_discrete_a 0.3671045462546654
# neuron unit number: 87
# train_discrete_score_W0_p 0.8020532563362207
# train_discrete_score_W0_n 0.27649724158639677
# train_discrete_score_W0_a  0.36457178858751044
# test_discrete_score_W0_p 0.7920677705044282
# test_discrete_score_W0_n 0.25520279996322853
# test_discrete_score_W0 0.34066819592701864
# train_discrete_score_W_discrete_p 0.8113570741097209
# train_discrete_score_W_discrete_n 0.29820787141112093
# train_discrete_score_W_discrete_a 0.3874931758024309
# test_discrete_score_W_discrete_p 0.7959183673469388
# test_discrete_score_W_discrete_n 0.26411524643619705
# test_discrete_score_W_discrete_a 0.34983643863430713
# neuron unit number: 92
# train_discrete_score_W0_p 0.8087905036894449
# train_discrete_score_W0_n 0.29058253318862415
# train_discrete_score_W0_a  0.3810547813802381
# test_discrete_score_W0_p 0.7951482479784366
# test_discrete_score_W0_n 0.2629888755586849
# test_discrete_score_W0 0.34803262612787844
# train_discrete_score_W_discrete_p 0.8042990054539622
# train_discrete_score_W_discrete_n 0.280169812118302
# train_discrete_score_W_discrete_a 0.3699517267032046
# test_discrete_score_W_discrete_p 0.7963034270311898
# test_discrete_score_W_discrete_n 0.2671147138274834
# test_discrete_score_W_discrete_a 0.350828793310537
# neuron unit number: 97
# train_discrete_score_W0_p 0.8164902149502727
# train_discrete_score_W0_n 0.3136717466065751
# train_discrete_score_W0_a  0.4004467297481795
# test_discrete_score_W0_p 0.7916827108201772
# test_discrete_score_W0_n 0.2556340325994096
# test_discrete_score_W0 0.33986230759982783
# train_discrete_score_W_discrete_p 0.8107154315046519
# train_discrete_score_W_discrete_n 0.29483895170634916
# train_discrete_score_W_discrete_a 0.38583713029566913
# test_discrete_score_W_discrete_p 0.7997689641894493
# test_discrete_score_W_discrete_n 0.2715829385172809
# test_discrete_score_W_discrete_a 0.3590083071346493
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.290962  0.016604  0.003713   0.283192  0.298733
# 1  train_dis_W_dis  20.0  0.290213  0.012642  0.002827   0.284297  0.296130
# 2         combined  40.0  0.290588  0.014571  0.002304   0.285928  0.295248
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0007
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.1605
# 3                        Two side test p value =    0.8733
# 4                       Difference < 0 p value =    0.5633
# 5                       Difference > 0 p value =    0.4367
# 6                                    Cohen's d =    0.0508
# 7                                    Hedge's g =    0.0497
# 8                                Glass's delta =    0.0451
# 9                                  Pearson's r =    0.0260
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.252926  0.013460  0.003010   0.246627  0.259226
# 1  test_dis_W_dis  20.0  0.257923  0.013557  0.003031   0.251578  0.264268
# 2        combined  40.0  0.255425  0.013572  0.002146   0.251084  0.259765
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0050
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -1.1697
# 3                      Two side test p value =    0.2494
# 4                     Difference < 0 p value =    0.1247
# 5                     Difference > 0 p value =    0.8753
# 6                                  Cohen's d =   -0.3699
# 7                                  Hedge's g =   -0.3625
# 8                              Glass's delta =   -0.3712
# 9                                Pearson's r =    0.1864
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.378575  0.018766  0.004196   0.369792  0.387357
# 1  train_dis_W_dis  20.0  0.377217  0.016254  0.003635   0.369610  0.384824
# 2         combined  40.0  0.377896  0.017342  0.002742   0.372350  0.383442
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0014
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.2446
# 3                        Two side test p value =    0.8081
# 4                       Difference < 0 p value =    0.5960
# 5                       Difference > 0 p value =    0.4040
# 6                                    Cohen's d =    0.0774
# 7                                    Hedge's g =    0.0758
# 8                                Glass's delta =    0.0724
# 9                                  Pearson's r =    0.0397
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.335542  0.017062  0.003815   0.327556  0.343527
# 1  test_dis_W_dis  20.0  0.342611  0.018240  0.004079   0.334075  0.351148
# 2        combined  40.0  0.339076  0.017797  0.002814   0.333385  0.344768
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0071
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -1.2659
# 3                      Two side test p value =    0.2133
# 4                     Difference < 0 p value =    0.1066
# 5                     Difference > 0 p value =    0.8934
# 6                                  Cohen's d =   -0.4003
# 7                                  Hedge's g =   -0.3923
# 8                              Glass's delta =   -0.4143
# 9                                Pearson's r =    0.2012
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.807668  0.007842  0.001753   0.803998  0.811338
# 1  train_dis_W_dis  20.0  0.807138  0.006729  0.001505   0.803989  0.810288
# 2         combined  40.0  0.807403  0.007217  0.001141   0.805095  0.809711
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0005
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.2291
# 3                        Two side test p value =    0.8200
# 4                       Difference < 0 p value =    0.5900
# 5                       Difference > 0 p value =    0.4100
# 6                                    Cohen's d =    0.0724
# 7                                    Hedge's g =    0.0710
# 8                                Glass's delta =    0.0675
# 9                                  Pearson's r =    0.0371
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.789738  0.007615  0.001703   0.786174  0.793302
# 1  test_dis_W_dis  20.0  0.792799  0.007980  0.001784   0.789065  0.796534
# 2        combined  40.0  0.791269  0.007853  0.001242   0.788757  0.793780
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0031
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -1.2412
# 3                      Two side test p value =    0.2222
# 4                     Difference < 0 p value =    0.1111
# 5                     Difference > 0 p value =    0.8889
# 6                                  Cohen's d =   -0.3925
# 7                                  Hedge's g =   -0.3847
# 8                              Glass's delta =   -0.4020
# 9                                Pearson's r =    0.1974
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5


#compare two MF

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 2
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 7
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 12
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 17
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 22
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 27
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 32
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 37
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 42
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 47
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 52
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 57
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 62
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 67
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 72
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 77
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 82
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 87
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 92
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 97
#  all feature number 22
# all_train_score_W0_p 0.5649663137632339
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.5471698113207547
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 18
# all_train_score_W_combine_p 0.5649663137632339
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p0.5471698113207547
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# NMI T-Test
#           Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0         train_W0  20.0   0.0  0.0  0.0        NaN       NaN
# 1  train_W_combine  20.0   0.0  0.0  0.0        NaN       NaN
# 2         combined  40.0   0.0  0.0  0.0        NaN       NaN
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =       0.0
# 1                       Degrees of freedom =      38.0
# 2                                        t =       NaN
# 3                    Two side test p value =       NaN
# 4                   Difference < 0 p value =       NaN
# 5                   Difference > 0 p value =       NaN
# 6                                Cohen's d =       NaN
# 7                                Hedge's g =       NaN
# 8                            Glass's delta =       NaN
# 9                              Pearson's r =       NaN
#          Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0         test_W0  20.0   0.0  0.0  0.0        NaN       NaN
# 1  test_W_combine  20.0   0.0  0.0  0.0        NaN       NaN
# 2        combined  40.0   0.0  0.0  0.0        NaN       NaN
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =       0.0
# 1                     Degrees of freedom =      38.0
# 2                                      t =       NaN
# 3                  Two side test p value =       NaN
# 4                 Difference < 0 p value =       NaN
# 5                 Difference > 0 p value =       NaN
# 6                              Cohen's d =       NaN
# 7                              Hedge's g =       NaN
# 8                          Glass's delta =       NaN
# 9                            Pearson's r =       NaN
# ARI T-Test
#           Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0         train_W0  20.0   0.0  0.0  0.0        NaN       NaN
# 1  train_W_combine  20.0   0.0  0.0  0.0        NaN       NaN
# 2         combined  40.0   0.0  0.0  0.0        NaN       NaN
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =       0.0
# 1                       Degrees of freedom =      38.0
# 2                                        t =       NaN
# 3                    Two side test p value =       NaN
# 4                   Difference < 0 p value =       NaN
# 5                   Difference > 0 p value =       NaN
# 6                                Cohen's d =       NaN
# 7                                Hedge's g =       NaN
# 8                            Glass's delta =       NaN
# 9                              Pearson's r =       NaN
#          Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0         test_W0  20.0   0.0  0.0  0.0        NaN       NaN
# 1  test_W_combine  20.0   0.0  0.0  0.0        NaN       NaN
# 2        combined  40.0   0.0  0.0  0.0        NaN       NaN
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =       0.0
# 1                     Degrees of freedom =      38.0
# 2                                      t =       NaN
# 3                  Two side test p value =       NaN
# 4                 Difference < 0 p value =       NaN
# 5                 Difference > 0 p value =       NaN
# 6                              Cohen's d =       NaN
# 7                              Hedge's g =       NaN
# 8                          Glass's delta =       NaN
# 9                            Pearson's r =       NaN
# Purity T-Test
#           Variable     N      Mean            SD   SE  95% Conf.  Interval
# 0         train_W0  20.0  0.564966  1.139065e-16  0.0        NaN       NaN
# 1  train_W_combine  20.0  0.564966  1.139065e-16  0.0        NaN       NaN
# 2         combined  40.0  0.564966  3.373100e-16  0.0        NaN       NaN
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =       0.0
# 1                       Degrees of freedom =      38.0
# 2                                        t =       NaN
# 3                    Two side test p value =       NaN
# 4                   Difference < 0 p value =       NaN
# 5                   Difference > 0 p value =       NaN
# 6                                Cohen's d =       0.0
# 7                                Hedge's g =       0.0
# 8                            Glass's delta =       0.0
# 9                              Pearson's r =       NaN
#          Variable     N     Mean            SD   SE  95% Conf.  Interval
# 0         test_W0  20.0  0.54717  0.000000e+00  0.0        NaN       NaN
# 1  test_W_combine  20.0  0.54717  0.000000e+00  0.0        NaN       NaN
# 2        combined  40.0  0.54717  4.497466e-16  0.0        NaN       NaN
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =       0.0
# 1                     Degrees of freedom =      38.0
# 2                                      t =       NaN
# 3                  Two side test p value =       NaN
# 4                 Difference < 0 p value =       NaN
# 5                 Difference > 0 p value =       NaN
# 6                              Cohen's d =       NaN
# 7                              Hedge's g =       NaN
# 8                          Glass's delta =       NaN
# 9                            Pearson's r =       NaN
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:26: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_val, p_val = scipy.stats.ttest_ind(group1, group2, nan_policy= 'omit')
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:26: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_val, p_val = scipy.stats.ttest_ind(group1, group2, nan_policy= 'omit')
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: invalid value encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,False,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.726018607635547
# train_discrete_score_W0_n 0.1744624718087439
# train_discrete_score_W0_a  0.2039062059336093
# test_discrete_score_W0_p 0.7112052368117058
# test_discrete_score_W0_n 0.15211532570912004
# test_discrete_score_W0 0.17793306794561847
# self.training_new_embedding  (3117, 36)
# train_discrete_score_W_discrete_p 0.8399101700352903
# train_discrete_score_W_discrete_n 0.3595299457300542
# train_discrete_score_W_discrete_a 0.46180843469439975
# test_discrete_score_W_discrete_p 0.8259530227185213
# test_discrete_score_W_discrete_n 0.3282826567732044
# test_discrete_score_W_discrete_a 0.4246156570349528
# neuron unit number: 7
# train_discrete_score_W0_p 0.7109400064164261
# train_discrete_score_W0_n 0.17535222243835785
# train_discrete_score_W0_a  0.1769913341635704
# test_discrete_score_W0_p 0.6961879091259146
# test_discrete_score_W0_n 0.1550063253524835
# test_discrete_score_W0 0.1527601865267137
# self.training_new_embedding  (3117, 126)
# train_discrete_score_W_discrete_p 0.8511389156239975
# train_discrete_score_W_discrete_n 0.3872139100791293
# train_discrete_score_W_discrete_a 0.4927131084851971
# test_discrete_score_W_discrete_p 0.8378898729303041
# test_discrete_score_W_discrete_n 0.35335489839445966
# test_discrete_score_W_discrete_a 0.4560930416146455
# neuron unit number: 12
# train_discrete_score_W0_p 0.7638755213346167
# train_discrete_score_W0_n 0.2034304358665848
# train_discrete_score_W0_a  0.27768771098113615
# test_discrete_score_W0_p 0.7466307277628033
# test_discrete_score_W0_n 0.17490954002879214
# test_discrete_score_W0 0.2425387826288486
# self.training_new_embedding  (3117, 216)
# train_discrete_score_W_discrete_p 0.8498556304138595
# train_discrete_score_W_discrete_n 0.38343227952959835
# train_discrete_score_W_discrete_a 0.4892129323086686
# test_discrete_score_W_discrete_p 0.8382749326145552
# test_discrete_score_W_discrete_n 0.35484531865311514
# test_discrete_score_W_discrete_a 0.45706017447090386
# neuron unit number: 17
# train_discrete_score_W0_p 0.8126403593198588
# train_discrete_score_W0_n 0.3015548723847929
# train_discrete_score_W0_a  0.3900140544746158
# test_discrete_score_W0_p 0.8059299191374663
# test_discrete_score_W0_n 0.2829630312590304
# test_discrete_score_W0 0.37345942846357794
# self.training_new_embedding  (3117, 306)
# train_discrete_score_W_discrete_p 0.8822585819698427
# train_discrete_score_W_discrete_n 0.47314928391844285
# train_discrete_score_W_discrete_a 0.5840902900699737
# test_discrete_score_W_discrete_p 0.856757797458606
# test_discrete_score_W_discrete_n 0.4039260766762735
# test_discrete_score_W_discrete_a 0.5084021107111026
# neuron unit number: 22
# train_discrete_score_W0_p 0.809432146294514
# train_discrete_score_W0_n 0.2900877838074505
# train_discrete_score_W0_a  0.3824691703327519
# test_discrete_score_W0_p 0.7986137851366962
# test_discrete_score_W0_n 0.26730888608904585
# test_discrete_score_W0 0.3560725668466359
# self.training_new_embedding  (3117, 396)
# train_discrete_score_W_discrete_p 0.8729547641963427
# train_discrete_score_W_discrete_n 0.4449313364833926
# train_discrete_score_W_discrete_a 0.5560352059302635
# test_discrete_score_W_discrete_p 0.8640739314593762
# test_discrete_score_W_discrete_n 0.4272097929420558
# test_discrete_score_W_discrete_a 0.5294330820584882
# neuron unit number: 27
# train_discrete_score_W0_p 0.7994866859159449
# train_discrete_score_W0_n 0.27871186561519623
# train_discrete_score_W0_a  0.35744259804724104
# test_discrete_score_W0_p 0.7924528301886793
# test_discrete_score_W0_n 0.25538954090849697
# test_discrete_score_W0 0.3411592403547617
# self.training_new_embedding  (3117, 486)
# train_discrete_score_W_discrete_p 0.8886750080205326
# train_discrete_score_W_discrete_n 0.5041087073772554
# train_discrete_score_W_discrete_a 0.6037070294190366
# test_discrete_score_W_discrete_p 0.875240662302657
# test_discrete_score_W_discrete_n 0.46985137123925436
# test_discrete_score_W_discrete_a 0.5623394898231362
# neuron unit number: 32
# train_discrete_score_W0_p 0.8039781841514276
# train_discrete_score_W0_n 0.2789599854732866
# train_discrete_score_W0_a  0.3689469894357525
# test_discrete_score_W0_p 0.7832113977666538
# test_discrete_score_W0_n 0.23809657608855264
# test_discrete_score_W0 0.320253652014786
# self.training_new_embedding  (3117, 576)
# train_discrete_score_W_discrete_p 0.8581969842797562
# train_discrete_score_W_discrete_n 0.4077202393368919
# train_discrete_score_W_discrete_a 0.5126628555533637
# test_discrete_score_W_discrete_p 0.8471313053523296
# test_discrete_score_W_discrete_n 0.3762882076429861
# test_discrete_score_W_discrete_a 0.4814120957041475
# neuron unit number: 37
# train_discrete_score_W0_p 0.8264356753288419
# train_discrete_score_W0_n 0.3288423083563757
# train_discrete_score_W0_a  0.42556370794291726
# test_discrete_score_W0_p 0.8024643819792068
# test_discrete_score_W0_n 0.2769968609736159
# test_discrete_score_W0 0.3648749769970627
# self.training_new_embedding  (3117, 666)
# train_discrete_score_W_discrete_p 0.8649342316329804
# train_discrete_score_W_discrete_n 0.42737358032513045
# train_discrete_score_W_discrete_a 0.532137118227615
# test_discrete_score_W_discrete_p 0.8590681555641124
# test_discrete_score_W_discrete_n 0.4076751319456235
# test_discrete_score_W_discrete_a 0.5151368596020078
# neuron unit number: 42
# train_discrete_score_W0_p 0.8306063522617901
# train_discrete_score_W0_n 0.3399425755613061
# train_discrete_score_W0_a  0.4364636742891014
# test_discrete_score_W0_p 0.8124759337697343
# test_discrete_score_W0_n 0.2957408255716739
# test_discrete_score_W0 0.3898870253291091
# self.training_new_embedding  (3117, 756)
# train_discrete_score_W_discrete_p 0.8861084376002567
# train_discrete_score_W_discrete_n 0.4880671388619005
# train_discrete_score_W_discrete_a 0.5958586128343477
# test_discrete_score_W_discrete_p 0.8810165575664228
# test_discrete_score_W_discrete_n 0.4730643206180509
# test_discrete_score_W_discrete_a 0.5800974763102656
# neuron unit number: 47
# train_discrete_score_W0_p 0.821944177093359
# train_discrete_score_W0_n 0.32449955834253363
# train_discrete_score_W0_a  0.4135975665823307
# test_discrete_score_W0_p 0.8255679630342703
# test_discrete_score_W0_n 0.32474653235365997
# test_discrete_score_W0 0.4233096357434962
# self.training_new_embedding  (3117, 846)
# train_discrete_score_W_discrete_p 0.8774462624318254
# train_discrete_score_W_discrete_n 0.45797255161395717
# train_discrete_score_W_discrete_a 0.5695009581283933
# test_discrete_score_W_discrete_p 0.8656141701963804
# test_discrete_score_W_discrete_n 0.4251532757230073
# test_discrete_score_W_discrete_a 0.5341492852286415
# neuron unit number: 52
# train_discrete_score_W0_p 0.833814565287135
# train_discrete_score_W0_n 0.35264239229896416
# train_discrete_score_W0_a  0.4448116889360859
# test_discrete_score_W0_p 0.8197920677705044
# test_discrete_score_W0_n 0.3135098760634152
# test_discrete_score_W0 0.40817973923199974
# self.training_new_embedding  (3117, 936)
# train_discrete_score_W_discrete_p 0.8697465511709978
# train_discrete_score_W_discrete_n 0.43684539745444145
# train_discrete_score_W_discrete_a 0.5464277691403753
# test_discrete_score_W_discrete_p 0.8602233346168656
# test_discrete_score_W_discrete_n 0.42289120100760524
# test_discrete_score_W_discrete_a 0.5181009434709473
# neuron unit number: 57
# train_discrete_score_W0_p 0.8273981392364453
# train_discrete_score_W0_n 0.3312999638098979
# train_discrete_score_W0_a  0.4280692081675306
# test_discrete_score_W0_p 0.810550635348479
# test_discrete_score_W0_n 0.2966705911583868
# test_discrete_score_W0 0.38457912112336123
# self.training_new_embedding  (3117, 1026)
# train_discrete_score_W_discrete_p 0.8768046198267565
# train_discrete_score_W_discrete_n 0.4588818002780607
# train_discrete_score_W_discrete_a 0.5674615765303985
# test_discrete_score_W_discrete_p 0.8702348864073931
# test_discrete_score_W_discrete_n 0.4398147332541968
# test_discrete_score_W_discrete_a 0.5476959820819552
# neuron unit number: 62
# train_discrete_score_W0_p 0.8177735001604106
# train_discrete_score_W0_n 0.3080655984812002
# train_discrete_score_W0_a  0.40345086343302283
# test_discrete_score_W0_p 0.8043896804004621
# test_discrete_score_W0_n 0.2787531673202231
# test_discrete_score_W0 0.3699085756993884
# self.training_new_embedding  (3117, 1116)
# train_discrete_score_W_discrete_p 0.8739172281039461
# train_discrete_score_W_discrete_n 0.45227967440818945
# train_discrete_score_W_discrete_a 0.5587360990341292
# test_discrete_score_W_discrete_p 0.8579129765113592
# test_discrete_score_W_discrete_n 0.4092627405381928
# test_discrete_score_W_discrete_a 0.5116339675655718
# neuron unit number: 67
# train_discrete_score_W0_p 0.835097850497273
# train_discrete_score_W0_n 0.3476387496270578
# train_discrete_score_W0_a  0.4486394402180531
# test_discrete_score_W0_p 0.8109356950327301
# test_discrete_score_W0_n 0.29396135892441844
# test_discrete_score_W0 0.38579781592307777
# self.training_new_embedding  (3117, 1206)
# train_discrete_score_W_discrete_p 0.8857876162977222
# train_discrete_score_W_discrete_n 0.483564320801434
# train_discrete_score_W_discrete_a 0.5949477492485782
# test_discrete_score_W_discrete_p 0.8725452445128995
# test_discrete_score_W_discrete_n 0.4496937582973299
# test_discrete_score_W_discrete_a 0.5544814475504886
# neuron unit number: 72
# train_discrete_score_W0_p 0.8341353865896696
# train_discrete_score_W0_n 0.35355335628791473
# train_discrete_score_W0_a  0.44566676828723983
# test_discrete_score_W0_p 0.8278783211397767
# test_discrete_score_W0_n 0.32981884410754725
# test_discrete_score_W0 0.4294158888449554
# self.training_new_embedding  (3117, 1296)
# train_discrete_score_W_discrete_p 0.8675008020532563
# train_discrete_score_W_discrete_n 0.44092126991980535
# train_discrete_score_W_discrete_a 0.5395318701305183
# test_discrete_score_W_discrete_p 0.8652291105121294
# test_discrete_score_W_discrete_n 0.4321686673062908
# test_discrete_score_W_discrete_a 0.532768116881401
# neuron unit number: 77
# train_discrete_score_W0_p 0.8309271735643247
# train_discrete_score_W0_n 0.3377745521696856
# train_discrete_score_W0_a  0.437525093810352
# test_discrete_score_W0_p 0.8344243357720447
# test_discrete_score_W0_n 0.34573155219512486
# test_discrete_score_W0 0.4466723136140016
# self.training_new_embedding  (3117, 1386)
# train_discrete_score_W_discrete_p 0.879050368944498
# train_discrete_score_W_discrete_n 0.46574183381764667
# train_discrete_score_W_discrete_a 0.5742526138324832
# test_discrete_score_W_discrete_p 0.8717751251443974
# test_discrete_score_W_discrete_n 0.4456800939293945
# test_discrete_score_W_discrete_a 0.5522303626632621
# neuron unit number: 82
# train_discrete_score_W0_p 0.8293230670516523
# train_discrete_score_W0_n 0.33476489741871635
# train_discrete_score_W0_a  0.43320499191606315
# test_discrete_score_W0_p 0.8113207547169812
# test_discrete_score_W0_n 0.29379398887195307
# test_discrete_score_W0 0.38687389480802564
# self.training_new_embedding  (3117, 1476)
# train_discrete_score_W_discrete_p 0.8719923002887392
# train_discrete_score_W_discrete_n 0.4492347360036655
# train_discrete_score_W_discrete_a 0.5529295910895365
# test_discrete_score_W_discrete_p 0.8644589911436272
# test_discrete_score_W_discrete_n 0.42683331347475206
# test_discrete_score_W_discrete_a 0.5305962264878176
# neuron unit number: 87
# train_discrete_score_W0_p 0.8440808469682387
# train_discrete_score_W0_n 0.37162815989147613
# train_discrete_score_W0_a  0.47293702012197353
# test_discrete_score_W0_p 0.823257604928764
# test_discrete_score_W0_n 0.31945020478929387
# test_discrete_score_W0 0.4173207108111971
# self.training_new_embedding  (3117, 1566)
# train_discrete_score_W_discrete_p 0.8819377606673083
# train_discrete_score_W_discrete_n 0.4708639043996816
# train_discrete_score_W_discrete_a 0.5831685288372641
# test_discrete_score_W_discrete_p 0.862533692722372
# test_discrete_score_W_discrete_n 0.41743533831557555
# test_discrete_score_W_discrete_a 0.5251307386576045
# neuron unit number: 92
# train_discrete_score_W0_p 0.8376644209175489
# train_discrete_score_W0_n 0.35679083009853707
# train_discrete_score_W0_a  0.4553670560835805
# test_discrete_score_W0_p 0.8182518290335002
# test_discrete_score_W0_n 0.31026119208219965
# test_discrete_score_W0 0.404225320677302
# self.training_new_embedding  (3117, 1656)
# train_discrete_score_W_discrete_p 0.8787295476419634
# train_discrete_score_W_discrete_n 0.462589018978113
# train_discrete_score_W_discrete_a 0.5733433910960056
# test_discrete_score_W_discrete_p 0.8737004235656527
# test_discrete_score_W_discrete_n 0.4532344809672755
# test_discrete_score_W_discrete_a 0.5579316239863508
# neuron unit number: 97
# train_discrete_score_W0_p 0.8277189605389798
# train_discrete_score_W0_n 0.3381442067789276
# train_discrete_score_W0_a  0.42863704739287284
# test_discrete_score_W0_p 0.8136311128224875
# test_discrete_score_W0_n 0.3032132096959057
# test_discrete_score_W0 0.3923059068174501
# self.training_new_embedding  (3117, 1746)
# train_discrete_score_W_discrete_p 0.8658966955405839
# train_discrete_score_W_discrete_n 0.43093986625435554
# train_discrete_score_W_discrete_a 0.534932099660913
# test_discrete_score_W_discrete_p 0.8606083943011167
# test_discrete_score_W_discrete_n 0.4147622689890679
# test_discrete_score_W_discrete_a 0.5194533742359518
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.306407  0.058591  0.013101   0.278986  0.333829
# 1  train_dis_W_dis  20.0  0.444268  0.036903  0.008252   0.426997  0.461539
# 2         combined  40.0  0.375338  0.084906  0.013425   0.348183  0.402492
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1379
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -8.9038
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.8156
# 7                                    Hedge's g =   -2.7597
# 8                                Glass's delta =   -2.3529
# 9                                  Pearson's r =    0.8222
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.275422  0.055722  0.012460   0.249343  0.301501
# 1  test_dis_W_dis  20.0  0.416571  0.038358  0.008577   0.398619  0.434523
# 2        combined  40.0  0.345997  0.085662  0.013544   0.318601  0.373393
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.1411
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -9.3312
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.9508
# 7                                  Hedge's g =   -2.8922
# 8                              Glass's delta =   -2.5331
# 9                                Pearson's r =    0.8344
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.391570  0.081451  0.018213   0.353449  0.429690
# 1  train_dis_W_dis  20.0  0.551173  0.038388  0.008584   0.533207  0.569139
# 2         combined  40.0  0.471371  0.102380  0.016188   0.438629  0.504114
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.1596
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -7.9269
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.5067
# 7                                    Hedge's g =   -2.4569
# 8                                Glass's delta =   -1.9595
# 9                                  Pearson's r =    0.7894
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.358376  0.079447  0.017765   0.321194  0.395559
# 1  test_dis_W_dis  20.0  0.519938  0.039265  0.008780   0.501561  0.538315
# 2        combined  40.0  0.439157  0.102562  0.016216   0.406356  0.471958
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.1616
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -8.1530
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.5782
# 7                                  Hedge's g =   -2.5270
# 8                              Glass's delta =   -2.0336
# 9                                Pearson's r =    0.7977
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.811165  0.036384  0.008136   0.794136  0.828193
# 1  train_dis_W_dis  20.0  0.871142  0.013113  0.002932   0.865005  0.877279
# 2         combined  40.0  0.841153  0.040634  0.006425   0.828158  0.854149
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0600
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -6.9354
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.1932
# 7                                    Hedge's g =   -2.1496
# 8                                Glass's delta =   -1.6485
# 9                                  Pearson's r =    0.7474
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.797459  0.037250  0.008329   0.780025  0.814892
# 1  test_dis_W_dis  20.0  0.860512  0.013881  0.003104   0.854016  0.867008
# 2        combined  40.0  0.828985  0.042300  0.006688   0.815457  0.842514
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0631
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -7.0935
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.2432
# 7                                  Hedge's g =   -2.1986
# 8                              Glass's delta =   -1.6927
# 9                                Pearson's r =    0.7548
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 200
class_num = 2
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,0)
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,1)
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,2)
# Out:
# neuron unit number: 2
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 1] unique [0 1]
# train_continuous_score_W0_n 0.2280801571133417
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 1] unique [0 1]
# train_continuous_score_W0_a 0.28992413414450063
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.22366631783003108
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.28414377000129515
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.37702134369711243
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.4767524216538235
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 1 1] unique [0 1]
# test_continuous_score_W_continuous_n 0.35531578021728943
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 1 1] unique [0 1]
# test_continuous_score_W_continuous_a 0.4562617947225587
# New Continuous Feateure Neurons Number :0
# neuron unit number: 7
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.3399905755690092
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.4256595302554358
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.3226680501950479
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.41124415806106174
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.4454686430835311
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.550351389013609
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4083132632500288
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5130649852507155
# New Continuous Feateure Neurons Number :0
# neuron unit number: 12
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.34644162420938807
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.43929726218628895
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.317742746407736
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.41040920610477394
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.4119840848077226
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.5147331583437178
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.37545795869425425
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.4728796488875106
# New Continuous Feateure Neurons Number :0
# neuron unit number: 17
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_n 0.34049665351566355
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_a 0.4214014852429177
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.3236881211349172
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.40715614715374443
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.4793589748371362
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.5802409660052191
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4180109116669595
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5230453041539402
# New Continuous Feateure Neurons Number :0
# neuron unit number: 22
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_n 0.3781216804246288
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_a 0.4776331353584018
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.3708450691430917
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.4719329152038662
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.4494778485820379
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.5551340120329363
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4064925926327855
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5131423537013844
# New Continuous Feateure Neurons Number :0
# neuron unit number: 27
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.3616900044068464
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.4521013443577903
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.3474809551788083
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.4447380697801831
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.44970421465527727
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.544543621610743
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.40897733277164844
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5040715346267864
# New Continuous Feateure Neurons Number :0
# neuron unit number: 32
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.41611833117819785
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5044708893705288
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.39662217415216255
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.4866139388731249
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.4887919825687005
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.595059150720567
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.3832061443823658
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.48360625062319323
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 37
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.37994748726205374
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.4775964004971152
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.3783266549533103
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.47935378926514166
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W_continuous_n 0.5145062018149087
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W_continuous_a 0.6231464989963182
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.41167517987823093
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.517517854729228
# New Continuous Feateure Neurons Number :0
# neuron unit number: 42
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.39803041027225944
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.4991758876785527
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.38324877175173694
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.4869357483399179
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.49213216587716824
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.5990349447069974
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.41224635450115577
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5163610386848135
# New Continuous Feateure Neurons Number :0
# neuron unit number: 47
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.398166274938033
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.4945781099674605
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.39012235755691616
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.48783475031611667
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5314755194050831
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6322488228088502
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.437558791312402
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5398392593659266
# New Continuous Feateure Neurons Number :0
# neuron unit number: 52
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.40106816736981094
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.4972880630654671
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.39411194481013284
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.49548146439249313
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5344328388979119
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6394468910873632
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 1 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4529919776241922
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 1 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5605149428443122
# New Continuous Feateure Neurons Number :0
# neuron unit number: 57
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.44025714178232256
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5485152729480925
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.42893583238891475
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.5377526638183457
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5220055130123789
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6292320530719296
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W_continuous_n 0.42308844324347605
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W_continuous_a 0.5274953471189563
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 62
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.39876864941864815
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5028742192290128
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.41255490150600216
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.5197945615052543
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5269060476457783
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6322784615601288
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43169590325794355
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.537648489538338
# New Continuous Feateure Neurons Number :0
# neuron unit number: 67
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.440268106625439
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5398600286082706
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.39603925335936324
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.4987748053635473
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5638205087876301
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6653699774586829
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44728404292981583
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5489310846814683
# New Continuous Feateure Neurons Number :0
# neuron unit number: 72
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.42517514925697614
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5229877818671478
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.40795007150427076
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.51194151021327
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5307818813428713
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6405125098320017
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.42892841658857644
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5365665617380185
# New Continuous Feateure Neurons Number :0
# neuron unit number: 77
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4359719362107157
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5408703408329194
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.41868205781824525
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5264893739856364
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5279612606668804
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6363949745238862
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.41695143485764546
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.524233281148896
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 82
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4408088917999158
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5436785624686437
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.4225472023118197
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.5275081950268858
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5438026319154945
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.649767692741139
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W_continuous_n 0.40804535059831465
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W_continuous_a 0.5108093000151538
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 87
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4157885613503888
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5203034072789559
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.3986506200875103
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5043291924446498
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5491135055863184
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.646616860664157
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.45053054633991024
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5546981844524812
# New Continuous Feateure Neurons Number :0
# neuron unit number: 92
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_n 0.44083061440818316
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_a 0.537948535937614
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.4125903264433723
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.5163522375530792
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5570654077537197
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6570033861613214
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44361831424069664
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5478310280696234
# New Continuous Feateure Neurons Number :0
# neuron unit number: 97
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4533135952436334
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5589664874451667
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4561993230071061
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5651716682780812
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5885824281238775
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6896927216006221
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.42484454911828573
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5286008592539139
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 102
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_n 0.42779319386185966
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 1 0] unique [0 1]
# train_continuous_score_W0_a 0.5267224040066606
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4395194542921462
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5455876990228268
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.553250125121843
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6517990453914922
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4695094164907249
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5720365859106438
# New Continuous Feateure Neurons Number :0
# neuron unit number: 107
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4528889962405431
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5619100240849516
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4428616327105202
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5525916138627741
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5844713593319236
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6843623252247897
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44043528463419546
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5444091803000162
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 112
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.44163053152348086
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5484795653389947
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.43781073992178215
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5456302064614315
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5604368758155069
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6580342879937758
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44148859659442496
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5409283440028106
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 117
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4529973205408579
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5589708283741687
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.43315218825480895
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.542284651732623
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5738408778795556
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6716566500450811
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.45118693819792094
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5535214844048606
# New Continuous Feateure Neurons Number :0
# neuron unit number: 122
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.45701596761245955
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5628143434712007
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4186757732358155
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5241717329221698
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5756994532931623
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6801384543548268
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44009805953539327
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.547907088551053
# New Continuous Feateure Neurons Number :0
# neuron unit number: 127
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.44445940328524136
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5474739212196222
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4373490489539694
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5456447097000086
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6028939046050554
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6993121992368034
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4463263923415491
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5501081212866101
# New Continuous Feateure Neurons Number :0
# neuron unit number: 132
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.43314917510857803
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5390003550701642
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.412414501440818
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5198080768852033
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5645528287011563
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6653663692851761
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43146345864794394
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5341984496934501
# New Continuous Feateure Neurons Number :0
# neuron unit number: 137
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4593733776370088
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5618131460263407
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.43679842905684113
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5444898495272962
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6186931727335507
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7133459899874828
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.42007618071777003
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5207255518088154
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 142
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4803603733076251
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5841873839095595
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.4523604558100813
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.5627855612686437
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6126882352456798
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7122775746013004
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4580607000297659
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5639511847439631
# New Continuous Feateure Neurons Number :0
# neuron unit number: 147
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.44989754058585624
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5512625912442588
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4073563595202246
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.511958726743703
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5932518964374236
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6907457219982505
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4698849942543882
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5732144957741834
# New Continuous Feateure Neurons Number :0
# neuron unit number: 152
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.47519335588602635
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5822595351449487
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.4385923197224128
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.5479654608167059
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5898045456989587
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6929064831368202
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44338192880846083
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5478353161832082
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 157
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.46733740823931097
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5774290430339054
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.43919309013405233
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5480393931642475
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5967125990576347
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6950273506983422
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4409229233385524
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5444004115679453
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 162
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.46453243932910443
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5685886797987667
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.44092298208903496
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.5496818309928543
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6012702577972104
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7025578331547103
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4513375815630821
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5570231033036974
# New Continuous Feateure Neurons Number :0
# neuron unit number: 167
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.4953612712646933
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.6060615051327909
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.44882804205786314
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.5590287819499336
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6253853951319089
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7264498055142773
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4440176368657459
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5513200206694377
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 172
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.46519281955304254
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5685817255865259
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4527232376473149
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5593436292169357
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6025797400663105
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.704716918320976
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4515127089691338
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5581927313601545
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 177
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.47023572029894806
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5695126759299054
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.4642559085122759
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.5673879402653446
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5880619892468306
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.686483978365267
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.41907563529975267
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5207448721700472
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 182
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.48228089658407086
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5931601203493575
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.44628138626342706
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.5560857293243394
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.606628664428953
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7057842705941496
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43801147599307527
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5421396808495136
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 187
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.46469736850836024
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5715296226309532
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [-1  0  1]
# test_continuous_score_W0_n 0.44248001106690277
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [-1  0  1]
# test_continuous_score_W0_a 0.5523500900701225
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5780026242742401
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.674815706067033
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44169879833064535
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5443870191052098
# Not good nmi result for continuous features !!!!!
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 192
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.48997731811555784
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5970503795226232
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.43598537096633566
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.5451921794100887
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6053830029189784
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7025422807300112
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43852448988298565
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5409755710655791
# Not good ari result for continuous features  !!!!!
# New Continuous Feateure Neurons Number :0
# neuron unit number: 197
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.480694906200208
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.5901561413249137
#  2597   2597
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.412414501440818
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.5198080768852033
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.617849461953749
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.715527931787921
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43863805745916806
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5375220773567301
# New Continuous Feateure Neurons Number :0
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  40.0  0.428360  0.052308  0.008271   0.411631  0.445089
# 1  train_con_W_con  40.0  0.548396  0.060309  0.009536   0.529109  0.567684
# 2         combined  80.0  0.488378  0.082426  0.009216   0.470035  0.506721
#                                Independent t-test  results
# ...
# neuron unit number: 152
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.3535809817114452
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.44786833803507464
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.34786047548434035
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.4457906047735843
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5705224794889979
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6663928880129628
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43871516543857025
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5444429789330044
# New Continuous Feateure Neurons Number :0
# neuron unit number: 157
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.2894413720580909
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.3721543585606497
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.2727220183036394
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.3577933474871813
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6171906383449937
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7122623743724186
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4403127236555609
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5420993028847804
# New Continuous Feateure Neurons Number :0
# neuron unit number: 162
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.36973673127226264
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.4643345887822183
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.34898418636998924
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.44725021827485884
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5773838506505077
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6822615769248694
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4274251638671391
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5331344766454805
# New Continuous Feateure Neurons Number :0
# neuron unit number: 167
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.28282307100334636
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.369985169126085
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.2849366301912599
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.374808267957325
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6029306662148063
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7047154544565537
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.45111968456066537
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5570271493264551
# New Continuous Feateure Neurons Number :0
# neuron unit number: 172
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_n 0.33890641451091547
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W0_a 0.43604463856024744
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_n 0.31991466506055555
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 1] unique [0 1]
# test_continuous_score_W0_a 0.41561218674922296
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6036302217188527
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7025486308283637
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.44015942523329393
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5467374701013687
# New Continuous Feateure Neurons Number :0
# neuron unit number: 177
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.30970699349712344
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.3960750983710225
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.2906085700851474
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.3787919571572633
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6113079178672535
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7046856113898182
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.43440567718022344
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5364419882917112
# New Continuous Feateure Neurons Number :0
# neuron unit number: 182
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.3688370314342127
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.46973972715243517
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 0 ... 0 1 0] unique [0 1]
# test_continuous_score_W0_n 0.3312658454324991
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 0 ... 0 1 0] unique [0 1]
# test_continuous_score_W0_a 0.4286439768829185
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5815724837105438
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6811758199951687
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4359515729525888
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5410238064043695
# New Continuous Feateure Neurons Number :0
# neuron unit number: 187
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 1 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.35242600601643326
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 1 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.45144510190480014
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [-1  0  1]
# test_continuous_score_W0_n 0.3224718292868682
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 1] unique [-1  0  1]
# test_continuous_score_W0_a 0.41805276722456197
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5914001605736435
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6896811678055176
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4550105126536395
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5557965535337739
# New Continuous Feateure Neurons Number :0
# neuron unit number: 192
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.33223330295726283
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 1 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.4275613757382748
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_n 0.32076761049347485
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 0 1 ... 0 0 0] unique [-1  0  1]
# test_continuous_score_W0_a 0.4169511092090377
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.5895787992121321
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 1 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.6886174297856495
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.438975235888302
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5421220558520427
# New Continuous Feateure Neurons Number :0
# neuron unit number: 197
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_n 0.3004285331285996
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [0 0 0 ... 0 0 1] unique [0 1]
# train_continuous_score_W0_a 0.39147533678456575
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_n 0.2959249323690945
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 0 ... 0 0 0] unique [0 1]
# test_continuous_score_W0_a 0.38637944966525983
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_n 0.6201940570142589
#  nmi y_true[1 0 0 ... 1 0 0] unique[0 1] y_pred [1 0 0 ... 0 0 0] unique [0 1]
# train_continuous_score_W_continuous_a 0.7155203662129951
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_n 0.4453451872555405
#  nmi y_true[1 0 1 ... 0 0 0] unique[0 1] y_pred [1 1 1 ... 0 0 0] unique [0 1]
# test_continuous_score_W_continuous_a 0.5466428927340248
# New Continuous Feateure Neurons Number :0
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  40.0  0.310999  0.042025  0.006645   0.297559  0.324439
# 1  train_con_W_con  40.0  0.542701  0.051598  0.008158   0.526199  0.559203
# 2         combined  80.0  0.426850  0.125609  0.014043   0.398897  0.454803
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.2317
# 1                           Degrees of freedom =   78.0000
# 2                                            t =  -22.0208
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.9240
# 7                                    Hedge's g =   -4.8765
# 8                                Glass's delta =   -5.5135
# 9                                  Pearson's r =    0.9281
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  40.0  0.299116  0.040143  0.006347   0.286278  0.311954
# 1  test_con_W_con  40.0  0.428595  0.018532  0.002930   0.422668  0.434521
# 2        combined  80.0  0.363855  0.072176  0.008069   0.347793  0.379917
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =   -0.1295
# 1                         Degrees of freedom =   78.0000
# 2                                          t =  -18.5213
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -4.1415
# 7                                  Hedge's g =   -4.1015
# 8                              Glass's delta =   -3.2255
# 9                                Pearson's r =    0.9026
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_con_W0  40.0  0.399876  0.050493  0.007984   0.383727  0.416024
# 1  train_con_W_con  40.0  0.643849  0.051472  0.008138   0.627388  0.660311
# 2         combined  80.0  0.521862  0.132800  0.014847   0.492309  0.551416
#                                Independent t-test  results
# 0  Difference (train_con_W0 - train_con_W_con) =   -0.2440
# 1                           Degrees of freedom =   78.0000
# 2                                            t =  -21.4000
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.7852
# 7                                    Hedge's g =   -4.7390
# 8                                Glass's delta =   -4.8318
# 9                                  Pearson's r =    0.9244
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_con_W0  40.0  0.389002  0.049316  0.007798   0.373230  0.404774
# 1  test_con_W_con  40.0  0.532419  0.020082  0.003175   0.525996  0.538841
# 2        combined  80.0  0.460711  0.081283  0.009088   0.442622  0.478799
#                              Independent t-test  results
# 0  Difference (test_con_W0 - test_con_W_con) =   -0.1434
# 1                         Degrees of freedom =   78.0000
# 2                                          t =  -17.0342
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.8090
# 7                                  Hedge's g =   -3.7722
# 8                              Glass's delta =   -2.9081
# 9                                Pearson's r =    0.8878
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
