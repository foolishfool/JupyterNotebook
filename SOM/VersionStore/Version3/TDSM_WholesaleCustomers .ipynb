# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Wholesale customers data.csv")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Region")

# %%
# local scope2
scoretype = 0
scope_num = 30
class_num = 3
dim_num = 7
unstable_repeat_num = 1


unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6451612903225806
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (6, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (9, 7)
# right_data1_score_W' 1.0
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6666666666666666
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (12, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9354838709677419
# error_data1_score_W0 0.7741935483870968
# combinedweight shape1 : (18, 7)
# right_data1_score_W' 0.8548387096774194
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (24, 7)
# right_data2_score_W' 0.7931034482758621
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6666666666666666
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (18, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9032258064516129
# error_data1_score_W0 0.8709677419354839
# combinedweight shape1 : (27, 7)
# right_data1_score_W' 0.9032258064516129
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.6666666666666666
# combinedweight shape1 : (36, 7)
# right_data2_score_W' 0.9285714285714286
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6666666666666666
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (24, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (36, 7)
# right_data1_score_W' 0.967741935483871
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7096774193548387
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (30, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (45, 7)
# right_data1_score_W' 0.9090909090909091
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6989247311827957
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (36, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9285714285714286
# error_data1_score_W0 0.7857142857142857
# combinedweight shape1 : (54, 7)
# right_data1_score_W' 0.8461538461538461
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (72, 7)
# right_data2_score_W' 0.8461538461538461
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7204301075268817
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (42, 7)
# right_data0_score_W' 1.0
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9615384615384616
# combinedweight shape1 : (63, 7)
# right_data1_score_W' 0.8805970149253731
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.29545454545454547
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7252747252747253
# error_data0_score_W0 0.6703296703296703
# combinedweight shape 0: (48, 7)
# right_data0_score_W' 0.9861751152073732
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.96
# error_data1_score_W0 0.92
# combinedweight shape1 : (72, 7)
# right_data1_score_W' 0.8939393939393939
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (96, 7)
# right_data2_score_W' 0.9583333333333334
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7045454545454546
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7204301075268817
# error_data0_score_W0 0.6451612903225806
# combinedweight shape 0: (54, 7)
# right_data0_score_W' 0.9906976744186047
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9230769230769231
# error_data1_score_W0 0.8846153846153846
# combinedweight shape1 : (81, 7)
# right_data1_score_W' 0.835820895522388
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (108, 7)
# right_data2_score_W' 0.9166666666666666
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7803030303030303
# test_score_W': 0.7727272727272727
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.2987012987012987
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6956521739130435
# error_data0_score_W0 0.6521739130434783
# combinedweight shape 0: (60, 7)
# right_data0_score_W' 0.9814814814814815
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7142857142857143
# combinedweight shape1 : (90, 7)
# right_data1_score_W' 0.78125
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7012987012987013
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.288961038961039
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7640449438202247
# error_data0_score_W0 0.651685393258427
# combinedweight shape 0: (66, 7)
# right_data0_score_W' 0.9452054794520548
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (99, 7)
# right_data1_score_W' 0.6764705882352942
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.711038961038961
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.288961038961039
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7303370786516854
# error_data0_score_W0 0.6404494382022472
# combinedweight shape 0: (72, 7)
# right_data0_score_W' 0.9680365296803652
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9583333333333334
# error_data1_score_W0 0.8333333333333334
# combinedweight shape1 : (108, 7)
# right_data1_score_W' 0.8615384615384616
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (144, 7)
# right_data2_score_W' 0.8695652173913043
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.711038961038961
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.2857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6818181818181818
# error_data0_score_W0 0.6704545454545454
# combinedweight shape 0: (78, 7)
# right_data0_score_W' 0.9181818181818182
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9285714285714286
# error_data1_score_W0 0.6785714285714286
# combinedweight shape1 : (117, 7)
# right_data1_score_W' 0.7666666666666667
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (156, 7)
# right_data2_score_W' 0.7692307692307693
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7333333333333333
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (84, 7)
# right_data0_score_W' 0.9357798165137615
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9583333333333334
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (126, 7)
# right_data1_score_W' 0.8181818181818182
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (168, 7)
# right_data2_score_W' 0.8695652173913043
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.288961038961039
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7303370786516854
# error_data0_score_W0 0.651685393258427
# combinedweight shape 0: (90, 7)
# right_data0_score_W' 0.9406392694063926
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9583333333333334
# error_data1_score_W0 0.75
# combinedweight shape1 : (135, 7)
# right_data1_score_W' 0.7076923076923077
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (180, 7)
# right_data2_score_W' 0.8260869565217391
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.711038961038961
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7666666666666667
# error_data0_score_W0 0.6777777777777778
# combinedweight shape 0: (96, 7)
# right_data0_score_W' 0.963302752293578
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7619047619047619
# combinedweight shape1 : (144, 7)
# right_data1_score_W' 0.8260869565217391
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.2857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8068181818181818
# error_data0_score_W0 0.6704545454545454
# combinedweight shape 0: (102, 7)
# right_data0_score_W' 0.9545454545454546
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9411764705882353
# combinedweight shape1 : (153, 7)
# right_data1_score_W' 0.8169014084507042
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.30194805194805197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7419354838709677
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (108, 7)
# right_data0_score_W' 0.9255813953488372
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9583333333333334
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (162, 7)
# right_data1_score_W' 0.7536231884057971
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (216, 7)
# right_data2_score_W' 0.7391304347826086
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.698051948051948
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.2857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7727272727272727
# error_data0_score_W0 0.6704545454545454
# combinedweight shape 0: (114, 7)
# right_data0_score_W' 0.95
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7
# combinedweight shape1 : (171, 7)
# right_data1_score_W' 0.7352941176470589
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7738095238095238
# error_data0_score_W0 0.6190476190476191
# combinedweight shape 0: (120, 7)
# right_data0_score_W' 0.8794642857142857
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5789473684210527
# combinedweight shape1 : (180, 7)
# right_data1_score_W' 0.6923076923076923
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (126, 7)
# right_data0_score_W' 0.926605504587156
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (189, 7)
# right_data1_score_W' 0.7638888888888888
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.2857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7386363636363636
# error_data0_score_W0 0.6477272727272727
# combinedweight shape 0: (132, 7)
# right_data0_score_W' 0.9363636363636364
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9565217391304348
# error_data1_score_W0 0.7391304347826086
# combinedweight shape1 : (198, 7)
# right_data1_score_W' 0.8769230769230769
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (264, 7)
# right_data2_score_W' 0.7727272727272727
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7666666666666667
# error_data0_score_W0 0.7
# combinedweight shape 0: (138, 7)
# right_data0_score_W' 0.9357798165137615
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7142857142857143
# combinedweight shape1 : (207, 7)
# right_data1_score_W' 0.8260869565217391
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2824675324675325
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8045977011494253
# error_data0_score_W0 0.7126436781609196
# combinedweight shape 0: (144, 7)
# right_data0_score_W' 0.9230769230769231
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6470588235294118
# combinedweight shape1 : (216, 7)
# right_data1_score_W' 0.7857142857142857
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7175324675324676
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7777777777777778
# error_data0_score_W0 0.6555555555555556
# combinedweight shape 0: (150, 7)
# right_data0_score_W' 0.9541284403669725
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9
# combinedweight shape1 : (225, 7)
# right_data1_score_W' 0.7571428571428571
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7727272727272727
# test_score_W': 0.7651515151515151
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.6444444444444445
# combinedweight shape 0: (156, 7)
# right_data0_score_W' 0.9495412844036697
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (234, 7)
# right_data1_score_W' 0.8133333333333334
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.2922077922077922
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8222222222222222
# error_data0_score_W0 0.6888888888888889
# combinedweight shape 0: (162, 7)
# right_data0_score_W' 0.9678899082568807
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.875
# combinedweight shape1 : (243, 7)
# right_data1_score_W' 0.7837837837837838
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7077922077922078
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2824675324675325
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8275862068965517
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (168, 7)
# right_data0_score_W' 0.9411764705882353
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (252, 7)
# right_data1_score_W' 0.8055555555555556
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7175324675324676
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7380952380952381
# error_data0_score_W0 0.6428571428571429
# combinedweight shape 0: (174, 7)
# right_data0_score_W' 0.9196428571428571
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7727272727272727
# combinedweight shape1 : (261, 7)
# right_data1_score_W' 0.8225806451612904
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.7803030303030303
# test_score_W': 0.7651515151515151
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.29545454545454547
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7142857142857143
# error_data0_score_W0 0.6703296703296703
# combinedweight shape 0: (180, 7)
# right_data0_score_W' 0.9170506912442397
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9615384615384616
# error_data1_score_W0 0.5384615384615384
# combinedweight shape1 : (270, 7)
# right_data1_score_W' 0.8
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (360, 7)
# right_data2_score_W' 0.72
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7045454545454546
# all_train_score_W': 1.0
# test_score_W0 : 0.7651515151515151
# test_score_W': 0.7651515151515151
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.766414  0.004020  0.000734   0.764913  0.767915
# 1  test_score_W'  30.0  0.765404  0.001383  0.000253   0.764888  0.765921
# 2       combined  60.0  0.765909  0.003024  0.000390   0.765128  0.766690
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0010
# 1                          Degrees of freedom =   58.0000
# 2                                           t =    1.3013
# 3                       Two side test p value =    0.1983
# 4                      Difference < 0 p value =    0.9009
# 5                      Difference > 0 p value =    0.0991
# 6                                   Cohen's d =    0.3360
# 7                                   Hedge's g =    0.3316
# 8                               Glass's delta =    0.2513
# 9                                 Pearson's r =    0.1684
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=1.3013188144856476, pvalue=0.900852491447428)

# %%
scoretype = 0
scope_num = 60
class_num = 3
dim_num = 7
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:       
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6071428571428571
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (6, 7)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (9, 7)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)9
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6071428571428571
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (12, 7)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (18, 7)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)18
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6428571428571429
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (18, 7)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9666666666666667
# error_data1_score_W0 0.8
# combinedweight shape1 : (27, 7)
# right_data1_score_W' 0.8333333333333334
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (36, 7)
# right_data2_score_W' 0.8275862068965517
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)36
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6666666666666666
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (24, 7)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9642857142857143
# error_data1_score_W0 0.8928571428571429
# combinedweight shape1 : (36, 7)
# right_data1_score_W' 0.8571428571428571
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (48, 7)
# right_data2_score_W' 0.8888888888888888
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)48
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6428571428571429
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (30, 7)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8666666666666667
# error_data1_score_W0 0.7666666666666667
# combinedweight shape1 : (45, 7)
# right_data1_score_W' 0.8148148148148148
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.75
# combinedweight shape1 : (60, 7)
# right_data2_score_W' 0.8846153846153846
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)60
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6428571428571429
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (36, 7)
# right_data0_score_W' 0.9866071428571429
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9333333333333333
# error_data1_score_W0 0.8
# combinedweight shape1 : (54, 7)
# right_data1_score_W' 0.8148148148148148
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (72, 7)
# right_data2_score_W' 0.8571428571428571
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)72
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7261904761904762
# error_data0_score_W0 0.6071428571428571
# combinedweight shape 0: (42, 7)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7391304347826086
# combinedweight shape1 : (63, 7)
# right_data1_score_W' 0.7377049180327869
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)63
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.2727272727272727
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6785714285714286
# error_data0_score_W0 0.6190476190476191
# combinedweight shape 0: (48, 7)
# right_data0_score_W' 0.9866071428571429
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9259259259259259
# error_data1_score_W0 0.7407407407407407
# combinedweight shape1 : (72, 7)
# right_data1_score_W' 0.8070175438596491
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (96, 7)
# right_data2_score_W' 0.8
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7272727272727273
# all_train_score_W': 1.0
# test_score_W0 : 0.7045454545454546
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)96
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.2694805194805195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6506024096385542
# error_data0_score_W0 0.6024096385542169
# combinedweight shape 0: (54, 7)
# right_data0_score_W' 0.9822222222222222
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9310344827586207
# error_data1_score_W0 0.8275862068965517
# combinedweight shape1 : (81, 7)
# right_data1_score_W' 0.8703703703703703
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (108, 7)
# right_data2_score_W' 0.8518518518518519
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7305194805194806
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)108
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.2694805194805195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7349397590361446
# error_data0_score_W0 0.6024096385542169
# combinedweight shape 0: (60, 7)
# right_data0_score_W' 0.9866666666666667
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6818181818181818
# combinedweight shape1 : (90, 7)
# right_data1_score_W' 0.7868852459016393
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7305194805194806
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)90
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.262987012987013
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6790123456790124
# error_data0_score_W0 0.6049382716049383
# combinedweight shape 0: (66, 7)
# right_data0_score_W' 0.9647577092511013
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9230769230769231
# error_data1_score_W0 0.7692307692307693
# combinedweight shape1 : (99, 7)
# right_data1_score_W' 0.7818181818181819
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (132, 7)
# right_data2_score_W' 0.7916666666666666
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.737012987012987
# all_train_score_W': 1.0
# test_score_W0 : 0.7045454545454546
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)132
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.2662337662337662
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7560975609756098
# error_data0_score_W0 0.6097560975609756
# combinedweight shape 0: (72, 7)
# right_data0_score_W' 0.9646017699115044
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.65
# combinedweight shape1 : (108, 7)
# right_data1_score_W' 0.6935483870967742
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7337662337662337
# all_train_score_W': 1.0
# test_score_W0 : 0.7121212121212122
# test_score_W': 0.7045454545454546
# class_num*x*(optimize_W.split_num +1)108
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.2597402597402597
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7375
# error_data0_score_W0 0.5875
# combinedweight shape 0: (78, 7)
# right_data0_score_W' 0.9692982456140351
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9523809523809523
# error_data1_score_W0 0.7619047619047619
# combinedweight shape1 : (117, 7)
# right_data1_score_W' 0.6779661016949152
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (156, 7)
# right_data2_score_W' 0.75
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7402597402597403
# all_train_score_W': 1.0
# test_score_W0 : 0.7045454545454546
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)156
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6962025316455697
# error_data0_score_W0 0.6075949367088608
# combinedweight shape 0: (84, 7)
# right_data0_score_W' 0.9301310043668122
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9583333333333334
# error_data1_score_W0 0.7083333333333334
# combinedweight shape1 : (126, 7)
# right_data1_score_W' 0.7090909090909091
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (168, 7)
# right_data2_score_W' 0.782608695652174
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)168
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.717948717948718
# error_data0_score_W0 0.6025641025641025
# combinedweight shape 0: (90, 7)
# right_data0_score_W' 0.9478260869565217
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7727272727272727
# combinedweight shape1 : (135, 7)
# right_data1_score_W' 0.7678571428571429
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)135
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.2662337662337662
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7682926829268293
# error_data0_score_W0 0.6341463414634146
# combinedweight shape 0: (96, 7)
# right_data0_score_W' 0.9690265486725663
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8947368421052632
# combinedweight shape1 : (144, 7)
# right_data1_score_W' 0.746031746031746
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7337662337662337
# all_train_score_W': 1.0
# test_score_W0 : 0.7196969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)144
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.2662337662337662
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7560975609756098
# error_data0_score_W0 0.6097560975609756
# combinedweight shape 0: (102, 7)
# right_data0_score_W' 0.9690265486725663
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.95
# error_data1_score_W0 0.75
# combinedweight shape1 : (153, 7)
# right_data1_score_W' 0.7903225806451613
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (204, 7)
# right_data2_score_W' 0.8947368421052632
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7337662337662337
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)204
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8051948051948052
# error_data0_score_W0 0.6493506493506493
# combinedweight shape 0: (108, 7)
# right_data0_score_W' 0.9004329004329005
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (162, 7)
# right_data1_score_W' 0.5806451612903226
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.75
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)162
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.2662337662337662
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7804878048780488
# error_data0_score_W0 0.6463414634146342
# combinedweight shape 0: (114, 7)
# right_data0_score_W' 0.9557522123893806
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9444444444444444
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (171, 7)
# right_data1_score_W' 0.765625
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (228, 7)
# right_data2_score_W' 0.8235294117647058
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7337662337662337
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)228
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.2694805194805195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7469879518072289
# error_data0_score_W0 0.6265060240963856
# combinedweight shape 0: (120, 7)
# right_data0_score_W' 0.9733333333333334
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8571428571428571
# combinedweight shape1 : (180, 7)
# right_data1_score_W' 0.7419354838709677
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7305194805194806
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)180
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.262987012987013
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7407407407407407
# error_data0_score_W0 0.654320987654321
# combinedweight shape 0: (126, 7)
# right_data0_score_W' 0.960352422907489
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9523809523809523
# combinedweight shape1 : (189, 7)
# right_data1_score_W' 0.8
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.737012987012987
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)189
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7848101265822784
# error_data0_score_W0 0.620253164556962
# combinedweight shape 0: (132, 7)
# right_data0_score_W' 0.9475982532751092
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5294117647058824
# combinedweight shape1 : (198, 7)
# right_data1_score_W' 0.7741935483870968
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)198
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7468354430379747
# error_data0_score_W0 0.6708860759493671
# combinedweight shape 0: (138, 7)
# right_data0_score_W' 0.9301310043668122
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (207, 7)
# right_data1_score_W' 0.7966101694915254
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)207
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7692307692307693
# error_data0_score_W0 0.5897435897435898
# combinedweight shape 0: (144, 7)
# right_data0_score_W' 0.9347826086956522
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6111111111111112
# combinedweight shape1 : (216, 7)
# right_data1_score_W' 0.65
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)216
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.2597402597402597
# right_data0_score_W0 1.0
# error_data0_score_W1 0.75
# error_data0_score_W0 0.625
# combinedweight shape 0: (150, 7)
# right_data0_score_W' 0.9429824561403509
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (225, 7)
# right_data1_score_W' 0.7666666666666667
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7402597402597403
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)225
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.2435064935064935
# right_data0_score_W0 1.0
# error_data0_score_W1 0.76
# error_data0_score_W0 0.6266666666666667
# combinedweight shape 0: (156, 7)
# right_data0_score_W' 0.9227467811158798
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8333333333333334
# combinedweight shape1 : (234, 7)
# right_data1_score_W' 0.8070175438596491
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7564935064935064
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)234
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7721518987341772
# error_data0_score_W0 0.6329113924050633
# combinedweight shape 0: (162, 7)
# right_data0_score_W' 0.925764192139738
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4444444444444444
# combinedweight shape1 : (243, 7)
# right_data1_score_W' 0.7377049180327869
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)243
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.262987012987013
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7407407407407407
# error_data0_score_W0 0.6419753086419753
# combinedweight shape 0: (168, 7)
# right_data0_score_W' 0.9559471365638766
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7619047619047619
# combinedweight shape1 : (252, 7)
# right_data1_score_W' 0.7833333333333333
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.737012987012987
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)252
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.2435064935064935
# right_data0_score_W0 1.0
# error_data0_score_W1 0.76
# error_data0_score_W0 0.6
# combinedweight shape 0: (174, 7)
# right_data0_score_W' 0.9098712446351931
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5555555555555556
# combinedweight shape1 : (261, 7)
# right_data1_score_W' 0.7368421052631579
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7564935064935064
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)261
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.2662337662337662
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7804878048780488
# error_data0_score_W0 0.6341463414634146
# combinedweight shape 0: (180, 7)
# right_data0_score_W' 0.9690265486725663
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7777777777777778
# combinedweight shape1 : (270, 7)
# right_data1_score_W' 0.796875
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7337662337662337
# all_train_score_W': 1.0
# test_score_W0 : 0.7045454545454546
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)270
# neuron unit number: 93
# *******************
#
# Error Data percentage 0.24675324675324675
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7631578947368421
# error_data0_score_W0 0.631578947368421
# combinedweight shape 0: (186, 7)
# right_data0_score_W' 0.9482758620689655
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8333333333333334
# combinedweight shape1 : (279, 7)
# right_data1_score_W' 0.8103448275862069
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7532467532467533
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)279
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.2305194805194805
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8028169014084507
# error_data0_score_W0 0.647887323943662
# combinedweight shape 0: (192, 7)
# right_data0_score_W' 0.9029535864978903
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7142857142857143
# combinedweight shape1 : (288, 7)
# right_data1_score_W' 0.6666666666666666
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7694805194805194
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)288
# neuron unit number: 99
# *******************
#
# Error Data percentage 0.262987012987013
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7777777777777778
# error_data0_score_W0 0.6419753086419753
# combinedweight shape 0: (198, 7)
# right_data0_score_W' 0.9074889867841409
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (297, 7)
# right_data1_score_W' 0.6825396825396826
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.737012987012987
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)297
# neuron unit number: 102
# *******************
#
# Error Data percentage 0.2597402597402597
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7625
# error_data0_score_W0 0.6125
# combinedweight shape 0: (204, 7)
# right_data0_score_W' 0.956140350877193
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5789473684210527
# combinedweight shape1 : (306, 7)
# right_data1_score_W' 0.8032786885245902
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7402597402597403
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)306
# neuron unit number: 105
# *******************
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7948717948717948
# error_data0_score_W0 0.6410256410256411
# combinedweight shape 0: (210, 7)
# right_data0_score_W' 0.9565217391304348
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.875
# combinedweight shape1 : (315, 7)
# right_data1_score_W' 0.7580645161290323
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)315
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8461538461538461
# error_data0_score_W0 0.6025641025641025
# combinedweight shape 0: (216, 7)
# right_data0_score_W' 0.9347826086956522
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (324, 7)
# right_data1_score_W' 0.7121212121212122
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)324
# neuron unit number: 111
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.6410256410256411
# combinedweight shape 0: (222, 7)
# right_data0_score_W' 0.9521739130434783
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7692307692307693
# combinedweight shape1 : (333, 7)
# right_data1_score_W' 0.8153846153846154
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)333
# neuron unit number: 114
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7721518987341772
# error_data0_score_W0 0.620253164556962
# combinedweight shape 0: (228, 7)
# right_data0_score_W' 0.9519650655021834
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7777777777777778
# combinedweight shape1 : (342, 7)
# right_data1_score_W' 0.819672131147541
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.7045454545454546
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)342
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.262987012987013
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8148148148148148
# error_data0_score_W0 0.7037037037037037
# combinedweight shape 0: (234, 7)
# right_data0_score_W' 0.8986784140969163
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8
# combinedweight shape1 : (351, 7)
# right_data1_score_W' 0.6212121212121212
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.737012987012987
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)351
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.717948717948718
# error_data0_score_W0 0.5897435897435898
# combinedweight shape 0: (240, 7)
# right_data0_score_W' 0.9217391304347826
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9545454545454546
# error_data1_score_W0 0.6363636363636364
# combinedweight shape1 : (360, 7)
# right_data1_score_W' 0.7321428571428571
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (480, 7)
# right_data2_score_W' 0.7142857142857143
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)480
# neuron unit number: 123
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7922077922077922
# error_data0_score_W0 0.6363636363636364
# combinedweight shape 0: (246, 7)
# right_data0_score_W' 0.9177489177489178
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9375
# combinedweight shape1 : (369, 7)
# right_data1_score_W' 0.6721311475409836
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.75
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)369
# neuron unit number: 126
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8205128205128205
# error_data0_score_W0 0.5897435897435898
# combinedweight shape 0: (252, 7)
# right_data0_score_W' 0.9434782608695652
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9285714285714286
# error_data1_score_W0 0.7142857142857143
# combinedweight shape1 : (378, 7)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (504, 7)
# right_data2_score_W' 0.8461538461538461
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.7045454545454546
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)504
# neuron unit number: 129
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.782051282051282
# error_data0_score_W0 0.6025641025641025
# combinedweight shape 0: (258, 7)
# right_data0_score_W' 0.9130434782608695
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7058823529411765
# combinedweight shape1 : (387, 7)
# right_data1_score_W' 0.6885245901639344
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)387
# neuron unit number: 132
# *******************
#
# Error Data percentage 0.2597402597402597
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8625
# error_data0_score_W0 0.6375
# combinedweight shape 0: (264, 7)
# right_data0_score_W' 0.9210526315789473
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5454545454545454
# combinedweight shape1 : (396, 7)
# right_data1_score_W' 0.6811594202898551
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7402597402597403
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)396
# neuron unit number: 135
# *******************
#
# Error Data percentage 0.2597402597402597
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8375
# error_data0_score_W0 0.7
# combinedweight shape 0: (270, 7)
# right_data0_score_W' 0.9385964912280702
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6923076923076923
# combinedweight shape1 : (405, 7)
# right_data1_score_W' 0.7611940298507462
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7402597402597403
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)405
# neuron unit number: 138
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7948717948717948
# error_data0_score_W0 0.6025641025641025
# combinedweight shape 0: (276, 7)
# right_data0_score_W' 0.8826086956521739
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.625
# combinedweight shape1 : (414, 7)
# right_data1_score_W' 0.6451612903225806
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)414
# neuron unit number: 141
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.6410256410256411
# combinedweight shape 0: (282, 7)
# right_data0_score_W' 0.9043478260869565
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.46153846153846156
# combinedweight shape1 : (423, 7)
# right_data1_score_W' 0.676923076923077
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)423
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.2532467532467532
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8461538461538461
# error_data0_score_W0 0.6410256410256411
# combinedweight shape 0: (288, 7)
# right_data0_score_W' 0.9347826086956522
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9166666666666666
# combinedweight shape1 : (432, 7)
# right_data1_score_W' 0.7727272727272727
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7467532467532467
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)432
# neuron unit number: 147
# *******************
#
# Error Data percentage 0.237012987012987
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8082191780821918
# error_data0_score_W0 0.6575342465753424
# combinedweight shape 0: (294, 7)
# right_data0_score_W' 0.9234042553191489
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.9285714285714286
# combinedweight shape1 : (441, 7)
# right_data1_score_W' 0.7627118644067796
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.762987012987013
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.7045454545454546
# class_num*x*(optimize_W.split_num +1)441
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8227848101265823
# error_data0_score_W0 0.6708860759493671
# combinedweight shape 0: (300, 7)
# right_data0_score_W' 0.925764192139738
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7142857142857143
# combinedweight shape1 : (450, 7)
# right_data1_score_W' 0.7076923076923077
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)450
# neuron unit number: 153
# *******************
#
# Error Data percentage 0.24675324675324675
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7631578947368421
# error_data0_score_W0 0.5921052631578947
# combinedweight shape 0: (306, 7)
# right_data0_score_W' 0.9310344827586207
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9444444444444444
# error_data1_score_W0 0.6111111111111112
# combinedweight shape1 : (459, 7)
# right_data1_score_W' 0.6896551724137931
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (612, 7)
# right_data2_score_W' 0.6470588235294118
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7532467532467533
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)612
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.2435064935064935
# right_data0_score_W0 1.0
# error_data0_score_W1 0.84
# error_data0_score_W0 0.6133333333333333
# combinedweight shape 0: (312, 7)
# right_data0_score_W' 0.944206008583691
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (468, 7)
# right_data1_score_W' 0.8412698412698413
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7564935064935064
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)468
# neuron unit number: 159
# *******************
#
# Error Data percentage 0.2694805194805195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7590361445783133
# error_data0_score_W0 0.6265060240963856
# combinedweight shape 0: (318, 7)
# right_data0_score_W' 0.9422222222222222
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.85
# combinedweight shape1 : (477, 7)
# right_data1_score_W' 0.6031746031746031
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7305194805194806
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)477
# neuron unit number: 162
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7922077922077922
# error_data0_score_W0 0.6363636363636364
# combinedweight shape 0: (324, 7)
# right_data0_score_W' 0.9264069264069265
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6875
# combinedweight shape1 : (486, 7)
# right_data1_score_W' 0.6885245901639344
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.75
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)486
# neuron unit number: 165
# *******************
#
# Error Data percentage 0.2694805194805195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7590361445783133
# error_data0_score_W0 0.6385542168674698
# combinedweight shape 0: (330, 7)
# right_data0_score_W' 0.9377777777777778
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.95
# error_data1_score_W0 0.55
# combinedweight shape1 : (495, 7)
# right_data1_score_W' 0.6349206349206349
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (660, 7)
# right_data2_score_W' 0.7368421052631579
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7305194805194806
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)660
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7341772151898734
# error_data0_score_W0 0.620253164556962
# combinedweight shape 0: (336, 7)
# right_data0_score_W' 0.9563318777292577
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8571428571428571
# combinedweight shape1 : (504, 7)
# right_data1_score_W' 0.7068965517241379
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)504
# neuron unit number: 171
# *******************
#
# Error Data percentage 0.24675324675324675
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7631578947368421
# error_data0_score_W0 0.5921052631578947
# combinedweight shape 0: (342, 7)
# right_data0_score_W' 0.9310344827586207
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9444444444444444
# error_data1_score_W0 0.8333333333333334
# combinedweight shape1 : (513, 7)
# right_data1_score_W' 0.6551724137931034
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (684, 7)
# right_data2_score_W' 0.8823529411764706
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.7532467532467533
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)684
# neuron unit number: 174
# *******************
#
# Error Data percentage 0.25
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8831168831168831
# error_data0_score_W0 0.6623376623376623
# combinedweight shape 0: (348, 7)
# right_data0_score_W' 0.9134199134199135
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (522, 7)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.75
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.7045454545454546
# class_num*x*(optimize_W.split_num +1)522
# neuron unit number: 177
# *******************
#
# Error Data percentage 0.2435064935064935
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8133333333333334
# error_data0_score_W0 0.6133333333333333
# combinedweight shape 0: (354, 7)
# right_data0_score_W' 0.9184549356223176
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6428571428571429
# combinedweight shape1 : (531, 7)
# right_data1_score_W' 0.6557377049180327
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7564935064935064
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.7196969696969697
# class_num*x*(optimize_W.split_num +1)531
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.2564935064935065
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8227848101265823
# error_data0_score_W0 0.620253164556962
# combinedweight shape 0: (360, 7)
# right_data0_score_W' 0.9344978165938864
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5714285714285714
# combinedweight shape1 : (540, 7)
# right_data1_score_W' 0.7846153846153846
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7435064935064936
# all_train_score_W': 1.0
# test_score_W0 : 0.696969696969697
# test_score_W': 0.696969696969697
# class_num*x*(optimize_W.split_num +1)540
# s 9  value 0.696969696969697
# s 18  value 0.696969696969697
# s 36  value 0.696969696969697
# s 48  value 0.696969696969697
# s 60  value 0.696969696969697
# s 63  value 0.696969696969697
# s 72  value 0.696969696969697
# s 90  value 0.696969696969697
# s 96  value 0.696969696969697
# s 108  value 0.7045454545454546
# s 132  value 0.696969696969697
# s 135  value 0.696969696969697
# s 144  value 0.696969696969697
# s 156  value 0.696969696969697
# s 162  value 0.696969696969697
# s 168  value 0.696969696969697
# s 180  value 0.696969696969697
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  17.0  0.699643  0.006529  0.001583   0.696287  0.703000
# 1  test_score_W'  17.0  0.697415  0.001837  0.000446   0.696471  0.698360
# 2       combined  34.0  0.698529  0.004856  0.000833   0.696835  0.700224
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0022
# 1                          Degrees of freedom =   32.0000
# 2                                           t =    1.3546
# 3                       Two side test p value =    0.1850
# 4                      Difference < 0 p value =    0.9075
# 5                      Difference > 0 p value =    0.0925
# 6                                   Cohen's d =    0.4646
# 7                                   Hedge's g =    0.4536
# 8                               Glass's delta =    0.3413
# 9                                 Pearson's r =    0.2329
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
