# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Iris.csv")
csv = csv.drop(columns=['Id'])
dataread.stringToIntIrisDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset_iris(csv_training,csv_test)

# %%
#local scope 1

scoretype = 0
scope_num = 60
class_num = 3
dim_num = 4
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:
            
        
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.24761904761904763
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.9493670886075949
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7523809523809524
# all_train_score_W': 1.0
# test_score_W0 : 0.7777777777777778
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)6
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.968421052631579
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (18, 4)
# right_data1_score_W' 0.7777777777777778
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9047619047619048
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)18
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.88
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# class_num*x*(optimize_W.split_num +1)18
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.7959183673469388
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (36, 4)
# right_data1_score_W' 0.8333333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)36
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.8421052631578947
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (45, 4)
# right_data1_score_W' 0.8888888888888888
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9047619047619048
# all_train_score_W': 1.0
# test_score_W0 : 0.8666666666666667
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)45
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.8585858585858586
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)36
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.8469387755102041
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)42
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (48, 4)
# right_data0_score_W' 0.7959183673469388
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)48
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (54, 4)
# right_data0_score_W' 0.8969072164948454
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)54
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (60, 4)
# right_data0_score_W' 0.81
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)60
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (66, 4)
# right_data0_score_W' 0.7745098039215687
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# class_num*x*(optimize_W.split_num +1)66
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (72, 4)
# right_data0_score_W' 0.8571428571428571
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)72
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (78, 4)
# right_data0_score_W' 0.7549019607843137
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)78
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (84, 4)
# right_data0_score_W' 0.8061224489795918
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (126, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# class_num*x*(optimize_W.split_num +1)126
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (90, 4)
# right_data0_score_W' 0.7475728155339806
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)90
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (96, 4)
# right_data0_score_W' 0.8282828282828283
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)96
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (102, 4)
# right_data0_score_W' 0.86
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)102
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (108, 4)
# right_data0_score_W' 0.83
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)108
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (114, 4)
# right_data0_score_W' 0.82
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)114
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (120, 4)
# right_data0_score_W' 0.8041237113402062
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.8888888888888888
# class_num*x*(optimize_W.split_num +1)120
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (126, 4)
# right_data0_score_W' 0.81
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)126
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (132, 4)
# right_data0_score_W' 0.8020833333333334
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9333333333333333
# class_num*x*(optimize_W.split_num +1)132
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (138, 4)
# right_data0_score_W' 0.8686868686868687
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)138
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (144, 4)
# right_data0_score_W' 0.85
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)144
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (150, 4)
# right_data0_score_W' 0.7647058823529411
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)150
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (156, 4)
# right_data0_score_W' 0.84
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)156
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (162, 4)
# right_data0_score_W' 0.9
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)162
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (168, 4)
# right_data0_score_W' 0.7777777777777778
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)168
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (174, 4)
# right_data0_score_W' 0.7941176470588235
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)174
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (180, 4)
# right_data0_score_W' 0.83
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)180
# neuron unit number: 93
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (186, 4)
# right_data0_score_W' 0.74
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)186
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (192, 4)
# right_data0_score_W' 0.8
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)192
# neuron unit number: 99
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (198, 4)
# right_data0_score_W' 0.83
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (297, 4)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)297
# neuron unit number: 102
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (204, 4)
# right_data0_score_W' 0.6979166666666666
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)204
# neuron unit number: 105
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (210, 4)
# right_data0_score_W' 0.78
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)210
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (216, 4)
# right_data0_score_W' 0.8877551020408163
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.8888888888888888
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)216
# neuron unit number: 111
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (222, 4)
# right_data0_score_W' 0.79
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)222
# neuron unit number: 114
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (228, 4)
# right_data0_score_W' 0.8080808080808081
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)228
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (234, 4)
# right_data0_score_W' 0.8585858585858586
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)234
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (240, 4)
# right_data0_score_W' 0.7941176470588235
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)240
# neuron unit number: 123
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (246, 4)
# right_data0_score_W' 0.8282828282828283
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)246
# neuron unit number: 126
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (252, 4)
# right_data0_score_W' 0.9270833333333334
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)252
# neuron unit number: 129
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (258, 4)
# right_data0_score_W' 0.8823529411764706
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)258
# neuron unit number: 132
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (264, 4)
# right_data0_score_W' 0.9090909090909091
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)264
# neuron unit number: 135
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (270, 4)
# right_data0_score_W' 0.8627450980392157
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)270
# neuron unit number: 138
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (276, 4)
# right_data0_score_W' 0.8383838383838383
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (414, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.8888888888888888
# test_score_W': 0.9111111111111111
# class_num*x*(optimize_W.split_num +1)414
# neuron unit number: 141
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (282, 4)
# right_data0_score_W' 0.7755102040816326
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.8666666666666667
# test_score_W': 0.8888888888888888
# class_num*x*(optimize_W.split_num +1)282
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (288, 4)
# right_data0_score_W' 0.7142857142857143
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)288
# neuron unit number: 147
# *******************
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (294, 4)
# right_data0_score_W' 0.8842105263157894
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9047619047619048
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)294
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (300, 4)
# right_data0_score_W' 0.7878787878787878
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# class_num*x*(optimize_W.split_num +1)300
# neuron unit number: 153
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (306, 4)
# right_data0_score_W' 0.75
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (459, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)459
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (312, 4)
# right_data0_score_W' 0.8367346938775511
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)312
# neuron unit number: 159
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (318, 4)
# right_data0_score_W' 0.7676767676767676
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (477, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)477
# neuron unit number: 162
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (324, 4)
# right_data0_score_W' 0.84
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# class_num*x*(optimize_W.split_num +1)324
# neuron unit number: 165
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (330, 4)
# right_data0_score_W' 0.8155339805825242
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# class_num*x*(optimize_W.split_num +1)330
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (336, 4)
# right_data0_score_W' 0.8247422680412371
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (504, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)504
# neuron unit number: 171
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (342, 4)
# right_data0_score_W' 0.8041237113402062
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (513, 4)
# right_data1_score_W' 0.8571428571428571
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9777777777777777
# class_num*x*(optimize_W.split_num +1)513
# neuron unit number: 174
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (348, 4)
# right_data0_score_W' 0.8725490196078431
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# class_num*x*(optimize_W.split_num +1)348
# neuron unit number: 177
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (354, 4)
# right_data0_score_W' 0.8627450980392157
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# class_num*x*(optimize_W.split_num +1)354
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 0.75
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (360, 4)
# right_data0_score_W' 0.7722772277227723
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (540, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# class_num*x*(optimize_W.split_num +1)540
# s 6  value 1.0
# s 18  value 0.9111111111111111
# s 36  value 1.0
# s 42  value 0.9777777777777777
# s 45  value 0.9555555555555556
# s 48  value 1.0
# s 54  value 0.9555555555555556
# s 60  value 1.0
# s 66  value 0.9333333333333333
# s 72  value 1.0
# s 78  value 0.9555555555555556
# s 90  value 0.9777777777777777
# s 96  value 1.0
# s 102  value 0.9777777777777777
# s 108  value 0.9555555555555556
# s 114  value 0.9777777777777777
# s 120  value 0.8888888888888888
# s 126  value 0.9777777777777777
# s 132  value 0.9333333333333333
# s 138  value 1.0
# s 144  value 0.9555555555555556
# s 150  value 0.9555555555555556
# s 156  value 1.0
# s 162  value 1.0
# s 168  value 0.9555555555555556
# s 174  value 1.0
# s 180  value 0.9777777777777777
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  27.0  0.944856  0.031044  0.005974   0.932575  0.957137
# 1  test_score_W'  27.0  0.971193  0.030077  0.005788   0.959295  0.983092
# 2       combined  54.0  0.958025  0.033064  0.004499   0.949000  0.967050
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0263
# 1                          Degrees of freedom =   52.0000
# 2                                           t =   -3.1661
# 3                       Two side test p value =    0.0026
# 4                      Difference < 0 p value =    0.0013
# 5                      Difference > 0 p value =    0.9987
# 6                                   Cohen's d =   -0.8617
# 7                                   Hedge's g =   -0.8492
# 8                               Glass's delta =   -0.8484
# 9                                 Pearson's r =    0.4020
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
#local scope 1

scoretype = 2
scope_num = 30
class_num = 3
dim_num = 4
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:
            
        
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        

        
        x=x+1


    figure, axis = plt.subplots(1, 2,figsize=(10, 5))
    if scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
    elif scoretype == 0:
        axis[0].set_title("Purity Score")
    
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()

    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])



summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4948453608247423
# error_data0_score_W0 0.6956521739130435
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.5699523330761826
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (9, 4)
# right_data1_score_W' 0.8
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7879991984685634
# all_train_score_W': 1.0
# test_score_W0 : 0.8698493783570597
# test_score_W': 0.8698493783570597
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.12380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.6336456454103303
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (18, 4)
# right_data1_score_W' 0.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6960385982732351
# all_train_score_W': 1.0
# test_score_W0 : 0.7102158569883056
# test_score_W': 0.812219875328422
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.4771041101260791
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8648431678049951
# all_train_score_W': 1.0
# test_score_W0 : 0.8707186030893217
# test_score_W': 0.812219875328422
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.39701031498003847
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7736419605040509
# all_train_score_W': 1.0
# test_score_W0 : 0.6783045095136657
# test_score_W': 0.8384136100637262
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.43849634059206843
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8648431678049951
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 0.9646931274043148
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.43694276043013347
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9434176541551936
# all_train_score_W': 1.0
# test_score_W0 : 0.8140901103079256
# test_score_W': 0.7833106610119229
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4166666666666667
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.5037476553704959
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (63, 4)
# right_data1_score_W' 0.07692307692307693
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.8166025753907781
# all_train_score_W': 1.0
# test_score_W0 : 0.812219875328422
# test_score_W': 0.8671701295714176
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (48, 4)
# right_data0_score_W' 0.5897016610580097
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8901636815953758
# all_train_score_W': 1.0
# test_score_W0 : 0.8425639784104018
# test_score_W': 0.8671701295714176
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (54, 4)
# right_data0_score_W' 0.6048845096545163
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.864765379937264
# all_train_score_W': 1.0
# test_score_W0 : 0.812219875328422
# test_score_W': 0.8698493783570597
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (60, 4)
# right_data0_score_W' 0.48338656846910605
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8901636815953758
# all_train_score_W': 1.0
# test_score_W0 : 0.812219875328422
# test_score_W': 0.7814694028681696
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6196403872752421
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (66, 4)
# right_data0_score_W' 0.5150503198889566
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (99, 4)
# right_data1_score_W' 0.5018450184501845
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7305671415910524
# all_train_score_W': 1.0
# test_score_W0 : 0.6365091745002258
# test_score_W': 0.6854509595334366
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (72, 4)
# right_data0_score_W' 0.5654942346037986
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8902899479945857
# all_train_score_W': 1.0
# test_score_W0 : 0.9327700788212869
# test_score_W': 0.8698493783570597
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (78, 4)
# right_data0_score_W' 0.9116830209745858
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8166025753907781
# all_train_score_W': 1.0
# test_score_W0 : 0.7582917026631109
# test_score_W': 0.7582917026631109
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (84, 4)
# right_data0_score_W' 0.4358252393174612
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8902899479945857
# all_train_score_W': 1.0
# test_score_W0 : 0.9327700788212869
# test_score_W': 0.812219875328422
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (90, 4)
# right_data0_score_W' 0.4521206512255517
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7959888412187877
# all_train_score_W': 1.0
# test_score_W0 : 0.7861689856021874
# test_score_W': 0.734473575527991
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (96, 4)
# right_data0_score_W' 0.38427221352266183
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8402380823205468
# all_train_score_W': 1.0
# test_score_W0 : 0.8140901103079256
# test_score_W': 0.8698493783570597
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (102, 4)
# right_data0_score_W' 0.4710300959994855
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8402380823205468
# all_train_score_W': 1.0
# test_score_W0 : 0.8707186030893217
# test_score_W': 0.8425639784104018
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (108, 4)
# right_data0_score_W' 0.4095732261449092
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.864765379937264
# all_train_score_W': 1.0
# test_score_W0 : 0.8698493783570597
# test_score_W': 0.8425639784104018
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (114, 4)
# right_data0_score_W' 0.6984915632354005
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7936408563307062
# all_train_score_W': 1.0
# test_score_W0 : 0.7599059771658832
# test_score_W': 0.8086915446386396
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (120, 4)
# right_data0_score_W' 0.6254030201126227
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8650759954038398
# all_train_score_W': 1.0
# test_score_W0 : 0.8115880735884965
# test_score_W': 0.812219875328422
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (126, 4)
# right_data0_score_W' 0.3551868053385707
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9434176541551936
# all_train_score_W': 1.0
# test_score_W0 : 0.9327700788212869
# test_score_W': 0.8698493783570597
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (132, 4)
# right_data0_score_W' 0.5543925242536026
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9434176541551936
# all_train_score_W': 1.0
# test_score_W0 : 0.6653269729181535
# test_score_W': 0.812219875328422
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (138, 4)
# right_data0_score_W' 0.6105854922813619
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7512309360581494
# all_train_score_W': 1.0
# test_score_W0 : 0.7763898068939938
# test_score_W': 0.7224888111821663
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (144, 4)
# right_data0_score_W' 0.37137721986838546
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8413337458203901
# all_train_score_W': 1.0
# test_score_W0 : 0.8353747184978952
# test_score_W': 0.8390071989242875
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (150, 4)
# right_data0_score_W' 0.3841116009533939
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8402380823205468
# all_train_score_W': 1.0
# test_score_W0 : 0.7582917026631109
# test_score_W': 0.8425639784104018
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (156, 4)
# right_data0_score_W' 0.49767637665788694
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8648431678049951
# all_train_score_W': 1.0
# test_score_W0 : 0.7630706921944035
# test_score_W': 0.7599059771658832
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.009523809523809525
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (162, 4)
# right_data0_score_W' 0.6022884402654868
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9712886498943729
# all_train_score_W': 1.0
# test_score_W0 : 0.7306893501062104
# test_score_W': 0.7567312234293812
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (168, 4)
# right_data0_score_W' 0.545771721442459
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8901636815953758
# all_train_score_W': 1.0
# test_score_W0 : 0.8991303935739166
# test_score_W': 0.82744262612569
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (174, 4)
# right_data0_score_W' 0.2219571157969619
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9434176541551936
# all_train_score_W': 1.0
# test_score_W0 : 0.8698493783570597
# test_score_W': 0.8698493783570597
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (180, 4)
# right_data0_score_W' 0.5167086768183
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8902899479945857
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 0.898958971218616
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.820865  0.090606  0.016542   0.787033  0.854698
# 1  test_score_W'  30.0  0.823385  0.058155  0.010618   0.801670  0.845101
# 2       combined  60.0  0.822125  0.075492  0.009746   0.802624  0.841627
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0025
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -0.1282
# 3                       Two side test p value =    0.8984
# 4                      Difference < 0 p value =    0.4492
# 5                      Difference > 0 p value =    0.5508
# 6                                   Cohen's d =   -0.0331
# 7                                   Hedge's g =   -0.0327
# 8                               Glass's delta =   -0.0278
# 9                                 Pearson's r =    0.0168
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-0.1282012682283897, pvalue=0.44921659524212465)

# %%
scoretype = 0
scope_num = 30
class_num = 3
dim_num = 4
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        if optimize_W.W0IsBest == False:
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.3333333333333333
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9714285714285714
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (9, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6666666666666666
# all_train_score_W': 1.0
# test_score_W0 : 0.6888888888888889
# test_score_W': 0.9333333333333333
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.13333333333333333
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.8571428571428571
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8666666666666667
# all_train_score_W': 1.0
# test_score_W0 : 0.8888888888888888
# test_score_W': 0.9555555555555556
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.89
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (27, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.9191919191919192
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.8058252427184466
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.8181818181818182
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.7669902912621359
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 0.9777777777777777
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (48, 4)
# right_data0_score_W' 0.8431372549019608
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (54, 4)
# right_data0_score_W' 0.8125
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9333333333333333
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (60, 4)
# right_data0_score_W' 0.8333333333333334
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (66, 4)
# right_data0_score_W' 0.7722772277227723
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (72, 4)
# right_data0_score_W' 0.803921568627451
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (78, 4)
# right_data0_score_W' 0.8080808080808081
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (84, 4)
# right_data0_score_W' 0.79
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (90, 4)
# right_data0_score_W' 0.8217821782178217
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (96, 4)
# right_data0_score_W' 0.85
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (102, 4)
# right_data0_score_W' 0.7731958762886598
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (108, 4)
# right_data0_score_W' 0.84
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (114, 4)
# right_data0_score_W' 0.7572815533980582
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (120, 4)
# right_data0_score_W' 0.7920792079207921
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (126, 4)
# right_data0_score_W' 0.8673469387755102
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (132, 4)
# right_data0_score_W' 0.85
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (138, 4)
# right_data0_score_W' 0.7843137254901961
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (144, 4)
# right_data0_score_W' 0.7450980392156863
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (150, 4)
# right_data0_score_W' 0.7425742574257426
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (156, 4)
# right_data0_score_W' 0.77
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (162, 4)
# right_data0_score_W' 0.8155339805825242
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.8888888888888888
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (168, 4)
# right_data0_score_W' 0.7
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (174, 4)
# right_data0_score_W' 0.8118811881188119
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (180, 4)
# right_data0_score_W' 0.801980198019802
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.20952380952380953
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9545454545454546
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.8192771084337349
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (9, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7904761904761904
# all_train_score_W': 1.0
# test_score_W0 : 0.7777777777777778
# test_score_W': 0.9333333333333333
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.9
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.8910891089108911
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9777777777777777
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.82
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.9583333333333334
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9333333333333333
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.90625
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.8877551020408163
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9777777777777777
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (48, 4)
# right_data0_score_W' 0.9479166666666666
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.8444444444444444
# test_score_W': 0.9333333333333333
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (54, 4)
# right_data0_score_W' 0.85
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (60, 4)
# right_data0_score_W' 0.8469387755102041
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (66, 4)
# right_data0_score_W' 0.82
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (72, 4)
# right_data0_score_W' 0.8041237113402062
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (78, 4)
# right_data0_score_W' 0.8235294117647058
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (84, 4)
# right_data0_score_W' 0.8349514563106796
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (90, 4)
# right_data0_score_W' 0.8571428571428571
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.009523809523809525
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (96, 4)
# right_data0_score_W' 0.7980769230769231
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9904761904761905
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (102, 4)
# right_data0_score_W' 0.803921568627451
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (108, 4)
# right_data0_score_W' 0.7425742574257426
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (114, 4)
# right_data0_score_W' 0.7766990291262136
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (120, 4)
# right_data0_score_W' 0.8613861386138614
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (126, 4)
# right_data0_score_W' 0.8415841584158416
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9111111111111111
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (132, 4)
# right_data0_score_W' 0.7549019607843137
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (138, 4)
# right_data0_score_W' 0.74
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.8888888888888888
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (144, 4)
# right_data0_score_W' 0.8921568627450981
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (150, 4)
# right_data0_score_W' 0.8367346938775511
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9111111111111111
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (156, 4)
# right_data0_score_W' 0.7450980392156863
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (162, 4)
# right_data0_score_W' 0.8631578947368421
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (243, 4)
# right_data1_score_W' 0.8888888888888888
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9047619047619048
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (168, 4)
# right_data0_score_W' 0.875
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.8666666666666667
# test_score_W': 0.9333333333333333
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (174, 4)
# right_data0_score_W' 0.8316831683168316
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (180, 4)
# right_data0_score_W' 0.7843137254901961
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9555555555555556
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.2761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.9078947368421053
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7238095238095238
# all_train_score_W': 1.0
# test_score_W0 : 0.7333333333333333
# test_score_W': 0.9111111111111111
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.9081632653061225
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (18, 4)
# right_data1_score_W' 0.8333333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.9090909090909091
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.9042553191489362
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8952380952380953
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 0.9777777777777777
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.8571428571428571
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.7669902912621359
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.8514851485148515
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (48, 4)
# right_data0_score_W' 0.8529411764705882
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 1.0
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (54, 4)
# right_data0_score_W' 0.7352941176470589
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.8888888888888888
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (60, 4)
# right_data0_score_W' 0.7959183673469388
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9333333333333333
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (66, 4)
# right_data0_score_W' 0.8541666666666666
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (72, 4)
# right_data0_score_W' 0.8
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (78, 4)
# right_data0_score_W' 0.8181818181818182
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9111111111111111
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (84, 4)
# right_data0_score_W' 0.8910891089108911
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (90, 4)
# right_data0_score_W' 0.9090909090909091
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (96, 4)
# right_data0_score_W' 0.912621359223301
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (102, 4)
# right_data0_score_W' 0.8627450980392157
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (108, 4)
# right_data0_score_W' 0.7961165048543689
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.009523809523809525
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (114, 4)
# right_data0_score_W' 0.7211538461538461
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9904761904761905
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (120, 4)
# right_data0_score_W' 0.9108910891089109
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9333333333333333
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (126, 4)
# right_data0_score_W' 0.8737864077669902
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (132, 4)
# right_data0_score_W' 0.7766990291262136
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (138, 4)
# right_data0_score_W' 0.693069306930693
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (144, 4)
# right_data0_score_W' 0.8155339805825242
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9111111111111111
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (150, 4)
# right_data0_score_W' 0.7722772277227723
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (156, 4)
# right_data0_score_W' 0.7843137254901961
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (162, 4)
# right_data0_score_W' 0.77
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (168, 4)
# right_data0_score_W' 0.84375
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.8888888888888888
# test_score_W': 0.9111111111111111
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (174, 4)
# right_data0_score_W' 0.8217821782178217
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.009523809523809525
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (180, 4)
# right_data0_score_W' 0.8076923076923077
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9904761904761905
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 3
# *******************
#
# Error Data percentage 0.18095238095238095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8947368421052632
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (6, 4)
# right_data0_score_W' 0.7790697674418605
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (9, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.819047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.7555555555555555
# test_score_W': 0.8888888888888888
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.9207920792079208
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9111111111111111
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.8
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.87
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.09523809523809523
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.8947368421052632
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9047619047619048
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.9072164948453608
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.78
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9111111111111111
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.8144329896907216
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.8888888888888888
# test_score_W': 0.9111111111111111
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.02857142857142857
# ...
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9047619047619048
# all_train_score_W': 1.0
# test_score_W0 : 0.8666666666666667
# test_score_W': 0.9111111111111111
# neuron unit number: 6
# *******************
#
# Error Data percentage 0.10476190476190476
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (12, 4)
# right_data0_score_W' 0.9468085106382979
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8952380952380953
# all_train_score_W': 1.0
# test_score_W0 : 0.8444444444444444
# test_score_W': 0.9111111111111111
# neuron unit number: 9
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (18, 4)
# right_data0_score_W' 0.9081632653061225
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9333333333333333
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.08571428571428572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8888888888888888
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (24, 4)
# right_data0_score_W' 0.9270833333333334
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (36, 4)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9142857142857143
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9777777777777777
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (30, 4)
# right_data0_score_W' 0.8163265306122449
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 18
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (36, 4)
# right_data0_score_W' 0.845360824742268
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 21
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (42, 4)
# right_data0_score_W' 0.7920792079207921
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 1.0
# test_score_W': 0.9555555555555556
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (48, 4)
# right_data0_score_W' 0.8446601941747572
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 1.0
# neuron unit number: 27
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (54, 4)
# right_data0_score_W' 0.7959183673469388
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (60, 4)
# right_data0_score_W' 0.8163265306122449
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9777777777777777
# neuron unit number: 33
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (66, 4)
# right_data0_score_W' 0.7676767676767676
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (72, 4)
# right_data0_score_W' 0.7755102040816326
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9555555555555556
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (78, 4)
# right_data0_score_W' 0.7087378640776699
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9777777777777777
# neuron unit number: 42
# *******************
#
# Error Data percentage 0.05714285714285714
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (84, 4)
# right_data0_score_W' 0.8080808080808081
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9428571428571428
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (90, 4)
# right_data0_score_W' 0.7669902912621359
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (96, 4)
# right_data0_score_W' 0.7843137254901961
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9777777777777777
# neuron unit number: 51
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (102, 4)
# right_data0_score_W' 0.7745098039215687
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.8888888888888888
# test_score_W': 0.9111111111111111
# neuron unit number: 54
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (108, 4)
# right_data0_score_W' 0.7352941176470589
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 57
# *******************
#
# Error Data percentage 0.01904761904761905
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (114, 4)
# right_data0_score_W' 0.7766990291262136
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9809523809523809
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9333333333333333
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.009523809523809525
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (120, 4)
# right_data0_score_W' 0.7596153846153846
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9904761904761905
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 63
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (126, 4)
# right_data0_score_W' 0.8673469387755102
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9111111111111111
# test_score_W': 0.9111111111111111
# neuron unit number: 66
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (132, 4)
# right_data0_score_W' 0.8469387755102041
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (198, 4)
# right_data1_score_W' 0.8333333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 69
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (138, 4)
# right_data0_score_W' 0.8217821782178217
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.009523809523809525
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (144, 4)
# right_data0_score_W' 0.7692307692307693
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9904761904761905
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9333333333333333
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.0380952380952381
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (150, 4)
# right_data0_score_W' 0.8415841584158416
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9619047619047619
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9555555555555556
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.0761904761904762
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (156, 4)
# right_data0_score_W' 0.8762886597938144
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9238095238095239
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 81
# *******************
#
# Error Data percentage 0.06666666666666667
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (162, 4)
# right_data0_score_W' 0.8673469387755102
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9333333333333333
# all_train_score_W': 1.0
# test_score_W0 : 0.9777777777777777
# test_score_W': 0.9555555555555556
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (168, 4)
# right_data0_score_W' 0.8235294117647058
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9555555555555556
# test_score_W': 0.9111111111111111
# neuron unit number: 87
# *******************
#
# Error Data percentage 0.047619047619047616
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (174, 4)
# right_data0_score_W' 0.74
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9523809523809523
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9777777777777777
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.02857142857142857
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 1.0
# Error data can be represented by W0 0
# combinedweight shape 0: (180, 4)
# right_data0_score_W' 0.7843137254901961
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.9714285714285714
# all_train_score_W': 1.0
# test_score_W0 : 0.9333333333333333
# test_score_W': 0.9111111111111111
#         Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   900.0  0.939432  0.043326  0.001444   0.936598  0.942266
# 1  test_score_W'   900.0  0.943877  0.021916  0.000731   0.942443  0.945310
# 2       combined  1800.0  0.941654  0.034395  0.000811   0.940064  0.943244
#                               Independent t-test    results
# 0  Difference (test_score_W0 - test_score_W') =     -0.0044
# 1                          Degrees of freedom =   1798.0000
# 2                                           t =     -2.7461
# 3                       Two side test p value =      0.0061
# 4                      Difference < 0 p value =      0.0030
# 5                      Difference > 0 p value =      0.9970
# 6                                   Cohen's d =     -0.1295
# 7                                   Hedge's g =     -0.1294
# 8                               Glass's delta =     -0.1026
# 9                                 Pearson's r =      0.0646
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-2.7461246157699066, pvalue=0.003045235818644214)
