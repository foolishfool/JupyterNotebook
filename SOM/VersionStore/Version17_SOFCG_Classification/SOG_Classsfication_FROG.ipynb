# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("FrogCall/Frogs_MFCCs.csv")

csv = csv.sample(int(csv.shape[0]))
csv_original_encode = csv

dataread.label_encoding(csv,"Species")
dataread.label_encoding(csv,"Family")
dataread.label_encoding(csv,"Genus")


dataread.onehot_encoding(csv_original_encode,["Family","Genus"])

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)



csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Species")
# Out:
# self.continuous_feature_num 23
# self.data_discrete_indexes ['Family', 'Genus']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 5
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9619047619047618
# precision_score_sog 0.9910472972972972
# f1_score_sog 0.9729653061444447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 10
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9619047619047618
# precision_score_sog 0.9910472972972972
# f1_score_sog 0.9729653061444447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 15
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9619047619047618
# precision_score_sog 0.9910472972972972
# f1_score_sog 0.9729653061444447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 20
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9619047619047618
# precision_score_sog 0.9910472972972972
# f1_score_sog 0.9729653061444447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 25
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9619047619047618
# precision_score_sog 0.9910472972972972
# f1_score_sog 0.9729653061444447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 30
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9619047619047618
# precision_score_sog 0.9910472972972972
# f1_score_sog 0.9729653061444447
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 35
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 40
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 45
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 50
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 55
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 60
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 65
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 70
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 75
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 80
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 85
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 90
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 95
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# neuron unit number: 100
# accuracy_score_orignial 0.9953488372093023
# recall_score_original 0.9952380952380953
# precision_score_original 0.9972972972972972
# f1_score_original 0.9961911125960574
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9952380952380953
# precision_score_sog 0.9972972972972972
# f1_score_sog 0.9961911125960574
# all_accuracy_score_original mean 0.9953488372093023
# all_recall_score_original mean 0.9952380952380949
# all_precision_score_original mean 0.9972972972972972
# all_f1_score_original mean 0.9961911125960576
# all_accuracy_score_sog mean 0.9939534883720931
# all_recall_score_sog mean 0.9852380952380951
# all_precision_score_sog mean 0.9954222972972973
# all_f1_score_sog mean 0.9892233706605739
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.995349  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.993953  0.002187  0.000489   0.992930
# 2                     combined  40.0  0.994651  0.001682  0.000266   0.994113
#
#    Interval
# 0       NaN
# 1  0.994977
# 2  0.995189
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...   0.0014
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    2.8536
# 3                           Two side test p value =    0.0070
# 4                          Difference < 0 p value =    0.9965
# 5                          Difference > 0 p value =    0.0035
# 6                                       Cohen's d =    0.9024
# 7                                       Hedge's g =    0.8844
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.4201
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.995238  3.417194e-16  7.641079e-17
# 1       all_recall_score_sog  20.0  0.985238  1.567208e-02  3.504383e-03
# 2                   combined  40.0  0.990238  1.205401e-02  1.905906e-03
#
#    95% Conf.  Interval
# 0   0.995238  0.995238
# 1   0.977903  0.992573
# 2   0.986383  0.994093
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re...  1.000000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   2.853600e+00
# 3                           Two side test p value =   7.000000e-03
# 4                          Difference < 0 p value =   9.965000e-01
# 5                          Difference > 0 p value =   3.500000e-03
# 6                                       Cohen's d =   9.024000e-01
# 7                                       Hedge's g =   8.844000e-01
# 8                                  Glass's delta1 =   2.926377e+13
# 9                                Point-Biserial r =   4.201000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.997297  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.995422  0.002939  0.000657
# 2                      combined  40.0  0.996360  0.002260  0.000357
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.994047  0.996798
# 2   0.995637  0.997083
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...   0.0019
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    2.8536
# 3                           Two side test p value =    0.0070
# 4                          Difference < 0 p value =    0.9965
# 5                          Difference > 0 p value =    0.0035
# 6                                       Cohen's d =    0.9024
# 7                                       Hedge's g =    0.8844
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.4201
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.996191  2.278130e-16  5.094053e-17
# 1       all_f1_score_sog  20.0  0.989223  1.091990e-02  2.441764e-03
# 2               combined  40.0  0.992707  8.398923e-03  1.327986e-03
#
#    95% Conf.  Interval
# 0   0.996191  0.996191
# 1   0.984113  0.994334
# 2   0.990021  0.995393
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco...  7.000000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   2.853600e+00
# 3                           Two side test p value =   7.000000e-03
# 4                          Difference < 0 p value =   9.965000e-01
# 5                          Difference > 0 p value =   3.500000e-03
# 6                                       Cohen's d =   9.024000e-01
# 7                                       Hedge's g =   8.844000e-01
# 8                                  Glass's delta1 =   3.058536e+13
# 9                                Point-Biserial r =   4.201000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9720930232558139
# recall_score_sog 0.9131521739130435
# precision_score_sog 0.9315566037735848
# f1_score_sog 0.9043825987072432
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9767441860465116
# recall_score_sog 0.9175000000000001
# precision_score_sog 0.936556603773585
# f1_score_sog 0.909168923493568
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9767441860465116
# recall_score_sog 0.9175000000000001
# precision_score_sog 0.9556742508324085
# f1_score_sog 0.921589748282814
# neuron unit number: 17
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9813953488372092
# recall_score_sog 0.9375
# precision_score_sog 0.9560263007432818
# f1_score_sog 0.9360577802508459
# neuron unit number: 22
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9775
# precision_score_sog 0.9960263007432818
# f1_score_sog 0.9860577802508459
# neuron unit number: 27
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9813953488372092
# recall_score_sog 0.9375
# precision_score_sog 0.9681742508324085
# f1_score_sog 0.9452802244732901
# neuron unit number: 32
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9675
# precision_score_sog 0.9941176470588236
# f1_score_sog 0.9791919191919192
# neuron unit number: 37
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9813953488372092
# recall_score_sog 0.9375
# precision_score_sog 0.9681742508324085
# f1_score_sog 0.9452802244732901
# neuron unit number: 42
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9875
# precision_score_sog 0.9969696969696968
# f1_score_sog 0.9917948717948718
# neuron unit number: 47
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.986046511627907
# recall_score_sog 0.9475
# precision_score_sog 0.9691176470588235
# f1_score_sog 0.951017316017316
# neuron unit number: 52
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9875
# precision_score_sog 0.9969696969696968
# f1_score_sog 0.9917948717948718
# neuron unit number: 57
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9875
# precision_score_sog 0.9969696969696968
# f1_score_sog 0.9917948717948718
# neuron unit number: 62
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9875
# precision_score_sog 0.9969696969696968
# f1_score_sog 0.9917948717948718
# neuron unit number: 67
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9675
# precision_score_sog 0.9941176470588236
# f1_score_sog 0.9791919191919192
# neuron unit number: 72
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9675
# precision_score_sog 0.9941176470588236
# f1_score_sog 0.9791919191919192
# neuron unit number: 77
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9875
# precision_score_sog 0.9969696969696968
# f1_score_sog 0.9917948717948718
# neuron unit number: 82
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9675
# precision_score_sog 0.9941176470588236
# f1_score_sog 0.9791919191919192
# neuron unit number: 87
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9675
# precision_score_sog 0.9941176470588236
# f1_score_sog 0.9791919191919192
# neuron unit number: 92
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9875
# precision_score_sog 0.9969696969696968
# f1_score_sog 0.9917948717948718
# neuron unit number: 97
# accuracy_score_orignial 0.9767441860465116
# recall_score_original 0.9175000000000001
# precision_score_original 0.9485263007432818
# f1_score_original 0.9183447476693922
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9675
# precision_score_sog 0.9941176470588236
# f1_score_sog 0.9791919191919192
# all_accuracy_score_original mean 0.9767441860465113
# all_recall_score_original mean 0.9175000000000001
# all_precision_score_original mean 0.9485263007432818
# all_f1_score_original mean 0.9183447476693921
# all_accuracy_score_sog mean 0.9881395348837211
# all_recall_score_sog mean 0.9607826086956524
# all_precision_score_sog mean 0.9813915136380451
# all_f1_score_sog mean 0.966237767093498
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.976744  3.417194e-16  7.641079e-17
# 1       all_accuracy_score_sog  20.0  0.988140  7.311434e-03  1.634886e-03
# 2                     combined  40.0  0.982442  7.703186e-03  1.217981e-03
#
#    95% Conf.  Interval
# 0   0.976744  0.976744
# 1   0.984718  0.991561
# 2   0.979978  0.984905
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -1.140000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -6.970100e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.204100e+00
# 7                                       Hedge's g =  -2.160400e+00
# 8                                  Glass's delta1 =  -3.334709e+13
# 9                                Point-Biserial r =  -7.491000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.917500  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.960783  0.025804  0.005770   0.948706
# 2                   combined  40.0  0.939141  0.028368  0.004485   0.930069
#
#    Interval
# 0       NaN
# 1  0.972859
# 2  0.948214
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0433
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -7.5013
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.3721
# 7                                       Hedge's g =   -2.3250
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7726
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.948526  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.981392  0.021692  0.004851
# 2                      combined  40.0  0.964959  0.022499  0.003557
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.971239  0.991544
# 2   0.957763  0.972154
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0329
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -6.7756
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.1426
# 7                                       Hedge's g =   -2.1001
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7397
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.918345  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.966238  2.939386e-02  6.572666e-03
# 2               combined  40.0  0.942291  3.176573e-02  5.022602e-03
#
#    95% Conf.  Interval
# 0   0.918345  0.918345
# 1   0.952481  0.979995
# 2   0.932132  0.952450
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -4.790000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -7.286700e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.304300e+00
# 7                                       Hedge's g =  -2.258500e+00
# 8                                  Glass's delta1 =  -4.204591e+14
# 9                                Point-Biserial r =  -7.635000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#Decision Tree
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.9488372093023256
# recall_score_original 0.77119825708061
# precision_score_original 0.7920343137254902
# f1_score_original 0.7780412360671584
# SOG Classficiation
# accuracy_score_sog 0.9767441860465116
# recall_score_sog 0.8799019607843137
# precision_score_sog 0.8593962585034014
# f1_score_sog 0.8660484443093139
# neuron unit number: 7
# accuracy_score_orignial 0.9627906976744186
# recall_score_original 0.9184026233632056
# precision_score_original 0.9323932676518885
# f1_score_original 0.9206070544589439
# SOG Classficiation
# accuracy_score_sog 0.9627906976744186
# recall_score_sog 0.9299999999999999
# precision_score_sog 0.9512626262626263
# f1_score_sog 0.9302100840336134
# neuron unit number: 12
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9939690721649483
# precision_score_original 0.9904444444444443
# f1_score_original 0.9920198035371982
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9767441860465116
# recall_score_sog 0.9639690721649485
# precision_score_sog 0.961
# f1_score_sog 0.9586729575587732
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.9488372093023256
# recall_score_original 0.8078401051142107
# precision_score_original 0.7967197900665643
# f1_score_original 0.7923359518833657
# SOG Classficiation
# accuracy_score_sog 0.986046511627907
# recall_score_sog 0.9889690721649484
# precision_score_sog 0.989103448275862
# f1_score_sog 0.9886064624922781
# neuron unit number: 22
# accuracy_score_orignial 0.9116279069767442
# recall_score_original 0.8763235294117647
# precision_score_original 0.9036967418546367
# f1_score_original 0.8857886557886558
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.986046511627907
# recall_score_sog 0.985
# precision_score_sog 0.99
# f1_score_sog 0.9866287339971549
# neuron unit number: 27
# accuracy_score_orignial 0.9255813953488372
# recall_score_original 0.7719259708465287
# precision_score_original 0.7377036556615173
# f1_score_original 0.7474526898737425
# SOG Classficiation
# accuracy_score_sog 0.9627906976744186
# recall_score_sog 0.918086719223772
# precision_score_sog 0.9348888888888889
# f1_score_sog 0.9076412115270271
# neuron unit number: 32
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9741176470588236
# precision_score_original 0.9694444444444444
# f1_score_original 0.9687157287157288
# SOG Classficiation
# accuracy_score_sog 0.9720930232558139
# recall_score_sog 0.9566666666666667
# precision_score_sog 0.9438528138528138
# f1_score_sog 0.9475626186806313
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 37
# accuracy_score_orignial 0.9720930232558139
# recall_score_original 0.9690686274509804
# precision_score_original 0.9772148859543817
# f1_score_original 0.9722235480275134
# SOG Classficiation
# accuracy_score_sog 0.958139534883721
# recall_score_sog 0.8731357388316152
# precision_score_sog 0.8623024054982817
# f1_score_sog 0.8656923688098577
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.9720930232558139
# recall_score_original 0.8616666666666667
# precision_score_original 0.8674534821903244
# f1_score_original 0.8638130522994858
# SOG Classficiation
# accuracy_score_sog 0.9767441860465116
# recall_score_sog 0.9325000000000001
# precision_score_sog 0.981556724323123
# f1_score_sog 0.9518582667798793
# neuron unit number: 47
# accuracy_score_orignial 0.958139534883721
# recall_score_original 0.8332843137254902
# precision_score_original 0.8203333333333334
# f1_score_original 0.8234608697125395
# SOG Classficiation
# accuracy_score_sog 0.9813953488372092
# recall_score_sog 0.96
# precision_score_sog 0.9400000000000001
# f1_score_sog 0.9390096863781074
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.9488372093023256
# recall_score_original 0.9029139433551199
# precision_score_original 0.9671388888888888
# f1_score_original 0.9204094043773988
# SOG Classficiation
# accuracy_score_sog 0.9813953488372092
# recall_score_sog 0.9366666666666668
# precision_score_sog 0.9542145593869732
# f1_score_sog 0.9438638262322474
# Not good precision_score_original !!!!!
# neuron unit number: 57
# accuracy_score_orignial 0.9302325581395349
# recall_score_original 0.8820518608359725
# precision_score_original 0.8194772519273427
# f1_score_original 0.8349079304478814
# SOG Classficiation
# accuracy_score_sog 0.9674418604651163
# recall_score_sog 0.9537962962962965
# precision_score_sog 0.959593984962406
# f1_score_sog 0.9532668121500609
# neuron unit number: 62
# accuracy_score_orignial 0.9255813953488372
# recall_score_original 0.727156862745098
# precision_score_original 0.7137161084529505
# f1_score_original 0.7056892230576441
# SOG Classficiation
# accuracy_score_sog 0.9488372093023256
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall_score_sog 0.7533769063180827
# precision_score_sog 0.7358703388115153
# f1_score_sog 0.7424386289460462
# neuron unit number: 67
# accuracy_score_orignial 0.9813953488372092
# recall_score_original 0.9791176470588235
# precision_score_original 0.9844444444444445
# f1_score_original 0.9811802232854865
# SOG Classficiation
# accuracy_score_sog 0.958139534883721
# recall_score_sog 0.81541394335512
# precision_score_sog 0.7952107279693487
# f1_score_sog 0.7928442728442728
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 72
# accuracy_score_orignial 0.9255813953488372
# recall_score_original 0.7466379174808525
# precision_score_original 0.7546825396825396
# f1_score_original 0.7438205345387537
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9958333333333333
# precision_score_sog 0.9989795918367348
# f1_score_sog 0.9973595199127114
# neuron unit number: 77
# accuracy_score_orignial 0.9162790697674419
# recall_score_original 0.7488165667183253
# precision_score_original 0.7758273389100456
# f1_score_original 0.7408508949098194
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9813953488372092
# recall_score_sog 0.955586719223772
# precision_score_sog 0.9722533858904386
# f1_score_sog 0.9598291434661961
# neuron unit number: 82
# accuracy_score_orignial 0.9348837209302325
# recall_score_original 0.8502178649237472
# precision_score_original 0.8346874134269093
# f1_score_original 0.8275047702555443
# SOG Classficiation
# accuracy_score_sog 0.9534883720930233
# recall_score_sog 0.8504139433551199
# precision_score_sog 0.8368055555555556
# f1_score_sog 0.8420430892330982
# neuron unit number: 87
# accuracy_score_orignial 0.9534883720930233
# recall_score_original 0.7881372549019607
# precision_score_original 0.8359062980030721
# f1_score_original 0.8050738312224759
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.9720930232558139
# recall_score_sog 0.9439690721649484
# precision_score_sog 0.9554444444444444
# f1_score_sog 0.9419269258127414
# neuron unit number: 92
# accuracy_score_orignial 0.9302325581395349
# recall_score_original 0.7839705882352941
# precision_score_original 0.8014372294372294
# f1_score_original 0.782554016174107
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.958139534883721
# recall_score_sog 0.8889690721649485
# precision_score_sog 0.9002780242531795
# f1_score_sog 0.8914345664625619
# neuron unit number: 97
# accuracy_score_orignial 0.9162790697674419
# recall_score_original 0.7175217864923747
# precision_score_original 0.790458269329237
# f1_score_original 0.7281445582716002
# SOG Classficiation
# accuracy_score_sog 0.9767441860465116
# recall_score_sog 0.9754139433551199
# precision_score_sog 0.9407407407407409
# f1_score_sog 0.9494063441431863
# all_accuracy_score_original mean 0.9472093023255814
# all_recall_score_original mean 0.8452169552815398
# all_precision_score_original mean 0.853260707091484
# all_f1_score_original mean 0.8407296988452522
# all_accuracy_score_sog mean 0.9716279069767442
# all_recall_score_sog mean 0.9228834563034833
# all_precision_score_sog mean 0.9231377259728166
# all_f1_score_sog mean 0.9178171981884878
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.947209  0.025037  0.005598   0.935492
# 1       all_accuracy_score_sog  20.0  0.971628  0.012435  0.002780   0.965808
# 2                     combined  40.0  0.959419  0.023100  0.003652   0.952031
#
#    Interval
# 0  0.958927
# 1  0.977448
# 2  0.966806
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0244
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.9064
# 3                           Two side test p value =    0.0004
# 4                          Difference < 0 p value =    0.0002
# 5                          Difference > 0 p value =    0.9998
# 6                                       Cohen's d =   -1.2353
# 7                                       Hedge's g =   -1.2108
# 8                                  Glass's delta1 =   -0.9753
# 9                                Point-Biserial r =   -0.5353
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.845217  0.089434  0.019998   0.803361
# 1       all_recall_score_sog  20.0  0.922883  0.062554  0.013987   0.893607
# 2                   combined  40.0  0.884050  0.085730  0.013555   0.856632
#
#    Interval
# 0  0.887073
# 1  0.952159
# 2  0.911468
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0777
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.1825
# 3                           Two side test p value =    0.0029
# 4                          Difference < 0 p value =    0.0015
# 5                          Difference > 0 p value =    0.9985
# 6                                       Cohen's d =   -1.0064
# 7                                       Hedge's g =   -0.9864
# 8                                  Glass's delta1 =   -0.8684
# 9                                Point-Biserial r =   -0.4587
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.853261  0.089400  0.019990
# 1       all_precision_score_sog  20.0  0.923138  0.070449  0.015753
# 2                      combined  40.0  0.888199  0.086969  0.013751
#
#    95% Conf.  Interval
# 0   0.811420  0.895101
# 1   0.890167  0.956109
# 2   0.860385  0.916013
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0699
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.7455
# 3                           Two side test p value =    0.0092
# 4                          Difference < 0 p value =    0.0046
# 5                          Difference > 0 p value =    0.9954
# 6                                       Cohen's d =   -0.8682
# 7                                       Hedge's g =   -0.8510
# 8                                  Glass's delta1 =   -0.7816
# 9                                Point-Biserial r =   -0.4069
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.840730  0.092336  0.020647   0.797515
# 1       all_f1_score_sog  20.0  0.917817  0.066484  0.014866   0.886702
# 2               combined  40.0  0.879273  0.088491  0.013992   0.850972
#
#    Interval
# 0  0.883944
# 1  0.948933
# 2  0.907574
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0771
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.0299
# 3                           Two side test p value =    0.0044
# 4                          Difference < 0 p value =    0.0022
# 5                          Difference > 0 p value =    0.9978
# 6                                       Cohen's d =   -0.9581
# 7                                       Hedge's g =   -0.9391
# 8                                  Glass's delta1 =   -0.8349
# 9                                Point-Biserial r =   -0.4411

# %%
#LinearDiscriminantAnalysis
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 5
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9833333333333334
# f1_score_sog 0.9769590643274852
# neuron unit number: 10
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 15
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 20
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 25
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 30
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 35
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 40
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 45
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 50
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 55
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# neuron unit number: 60
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 65
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 70
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 75
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 80
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 85
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 90
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 95
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9953488372093023
# recall_score_sog 0.9933333333333334
# precision_score_sog 0.9973684210526315
# f1_score_sog 0.9952183908045977
# neuron unit number: 100
# accuracy_score_orignial 0.9906976744186047
# recall_score_original 0.9733333333333334
# precision_score_original 0.9833333333333334
# f1_score_original 0.9769590643274852
# SOG Classficiation
# accuracy_score_sog 0.9906976744186047
# recall_score_sog 0.9733333333333334
# precision_score_sog 0.9907017543859649
# f1_score_sog 0.9808888888888889
# all_accuracy_score_original mean 0.9906976744186048
# all_recall_score_original mean 0.9733333333333333
# all_precision_score_original mean 0.9833333333333336
# all_f1_score_original mean 0.9769590643274851
# all_accuracy_score_sog mean 0.9927906976744187
# all_recall_score_sog mean 0.9823333333333333
# all_precision_score_sog mean 0.9933333333333334
# all_f1_score_sog mean 0.9871406735228879
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.990698  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.992791  2.374036e-03  5.308506e-04
# 2                     combined  40.0  0.991744  1.966986e-03  3.110078e-04
#
#    95% Conf.  Interval
# 0   0.990698  0.990698
# 1   0.991680  0.993902
# 2   0.991115  0.992373
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -2.100000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -3.942800e+00
# 3                           Two side test p value =   3.000000e-04
# 4                          Difference < 0 p value =   2.000000e-04
# 5                          Difference > 0 p value =   9.998000e-01
# 6                                       Cohen's d =  -1.246800e+00
# 7                                       Hedge's g =  -1.222000e+00
# 8                                  Glass's delta1 =  -1.837493e+13
# 9                                Point-Biserial r =  -5.388000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.973333  1.139065e-16  2.547026e-17
# 1       all_recall_score_sog  20.0  0.982333  1.020836e-02  2.282658e-03
# 2                   combined  40.0  0.977833  8.458041e-03  1.337334e-03
#
#    95% Conf.  Interval
# 0   0.973333  0.973333
# 1   0.977556  0.987111
# 2   0.975128  0.980538
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -9.000000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -3.942800e+00
# 3                           Two side test p value =   3.000000e-04
# 4                          Difference < 0 p value =   2.000000e-04
# 5                          Difference > 0 p value =   9.998000e-01
# 6                                       Cohen's d =  -1.246800e+00
# 7                                       Hedge's g =  -1.222000e+00
# 8                                  Glass's delta1 =  -7.901219e+13
# 9                                Point-Biserial r =  -5.388000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.983333  2.278130e-16  5.094053e-17
# 1       all_precision_score_sog  20.0  0.993333  4.076825e-03  9.116057e-04
# 2                      combined  40.0  0.988333  5.808459e-03  9.183979e-04
#
#    95% Conf.  Interval
# 0   0.983333  0.983333
# 1   0.991425  0.995241
# 2   0.986476  0.990191
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -1.000000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.096970e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.468900e+00
# 7                                       Hedge's g =  -3.400000e+00
# 8                                  Glass's delta1 =  -4.389566e+13
# 9                                Point-Biserial r =  -8.718000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.976959  1.139065e-16  2.547026e-17
# 1       all_f1_score_sog  20.0  0.987141  7.545507e-03  1.687227e-03
# 2               combined  40.0  0.982050  7.370090e-03  1.165313e-03
#
#    95% Conf.  Interval
# 0   0.976959  0.976959
# 1   0.983609  0.990672
# 2   0.979693  0.984407
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.020000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -6.034500e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.908300e+00
# 7                                       Hedge's g =  -1.870400e+00
# 8                                  Glass's delta1 =  -8.938569e+13
# 9                                Point-Biserial r =  -6.995000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#KNN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 50
class_num = 2
interval = 2

features =[0,1]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 4
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 6
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 8
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 10
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 12
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 14
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 16
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 18
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 20
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 22
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 24
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 26
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 28
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 30
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 32
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 34
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 36
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 38
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 40
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 42
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 44
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 46
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 48
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# neuron unit number: 50
# accuracy_score_orignial 1.0
# recall_score_original 1.0
# precision_score_original 1.0
# f1_score_original 1.0
# SOG Classficiation
# accuracy_score_sog 1.0
# recall_score_sog 1.0
# precision_score_sog 1.0
# f1_score_sog 1.0
# all_accuracy_score_original mean 1.0
# all_recall_score_original mean 1.0
# all_precision_score_original mean 1.0
# all_f1_score_original mean 1.0
# all_accuracy_score_sog mean 1.0
# all_recall_score_sog mean 1.0
# all_precision_score_sog mean 1.0
# all_f1_score_sog mean 1.0
# Accuracy Score T-Test
#                       Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_accuracy_score_original  25.0   1.0  0.0  0.0        NaN       NaN
# 1       all_accuracy_score_sog  25.0   1.0  0.0  0.0        NaN       NaN
# 2                     combined  50.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...      0.0
# 1                              Degrees of freedom =      48.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Recall Score T-Test
#                     Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_recall_score_original  25.0   1.0  0.0  0.0        NaN       NaN
# 1       all_recall_score_sog  25.0   1.0  0.0  0.0        NaN       NaN
# 2                   combined  50.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...      0.0
# 1                              Degrees of freedom =      48.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Precision Score T-Test
#                        Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_precision_score_original  25.0   1.0  0.0  0.0        NaN       NaN
# 1       all_precision_score_sog  25.0   1.0  0.0  0.0        NaN       NaN
# 2                      combined  50.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...      0.0
# 1                              Degrees of freedom =      48.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# F1 Score T-Test
#                 Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_f1_score_original  25.0   1.0  0.0  0.0        NaN       NaN
# 1       all_f1_score_sog  25.0   1.0  0.0  0.0        NaN       NaN
# 2               combined  50.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...      0.0
# 1                              Degrees of freedom =      48.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#SVM
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# SOG Classficiation
# accuracy_score_sog 0.586046511627907
# recall_score_sog 0.2
# precision_score_sog 0.13632478632478634
# f1_score_sog 0.160790273556231
# neuron unit number: 7
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# SOG Classficiation
# accuracy_score_sog 0.586046511627907
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# recall_score_sog 0.2
# precision_score_sog 0.13632478632478634
# f1_score_sog 0.160790273556231
# neuron unit number: 12
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# SOG Classficiation
# accuracy_score_sog 0.6232558139534884
# recall_score_sog 0.2533333333333333
# precision_score_sog 0.2483695652173913
# f1_score_sog 0.2376841227074415
# neuron unit number: 17
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6325581395348837
# recall_score_sog 0.26666666666666666
# precision_score_sog 0.25706521739130433
# f1_score_sog 0.2526643598615917
# neuron unit number: 22
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# SOG Classficiation
# accuracy_score_sog 0.6325581395348837
# recall_score_sog 0.26666666666666666
# precision_score_sog 0.25706521739130433
# f1_score_sog 0.2526643598615917
# neuron unit number: 27
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 32
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 37
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.2580110497237569
# f1_score_sog 0.2662837162837163
# neuron unit number: 42
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 47
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.2580110497237569
# f1_score_sog 0.2662837162837163
# neuron unit number: 52
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 57
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 62
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 67
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.2580110497237569
# f1_score_sog 0.2662837162837163
# neuron unit number: 72
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25898876404494386
# f1_score_sog 0.2670620898536093
# neuron unit number: 77
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6558139534883721
# recall_score_sog 0.3
# precision_score_sog 0.2596590909090909
# f1_score_sog 0.27473309608540925
# neuron unit number: 82
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.25865921787709495
# f1_score_sog 0.2668008048289739
# neuron unit number: 87
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6558139534883721
# recall_score_sog 0.3
# precision_score_sog 0.2596590909090909
# f1_score_sog 0.27473309608540925
# neuron unit number: 92
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6558139534883721
# recall_score_sog 0.3
# precision_score_sog 0.2593220338983051
# f1_score_sog 0.274468085106383
# neuron unit number: 97
# accuracy_score_orignial 0.586046511627907
# recall_score_original 0.2
# precision_score_original 0.13632478632478634
# f1_score_original 0.160790273556231
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.6465116279069767
# recall_score_sog 0.2866666666666667
# precision_score_sog 0.2580110497237569
# f1_score_sog 0.2662837162837163
# all_accuracy_score_original mean 0.5860465116279071
# all_recall_score_original mean 0.20000000000000004
# all_precision_score_original mean 0.13632478632478634
# all_f1_score_original mean 0.160790273556231
# all_accuracy_score_sog mean 0.6393023255813954
# all_recall_score_sog mean 0.2763333333333334
# all_precision_score_sog mean 0.24577186382228478
# all_f1_score_sog mean 0.25441651278057903
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.586047  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.639302  1.981814e-02  4.431470e-03
# 2                     combined  40.0  0.612674  3.030792e-02  4.792103e-03
#
#    95% Conf.  Interval
# 0   0.586047  0.586047
# 1   0.630027  0.648577
# 2   0.602981  0.622367
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -5.330000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.201760e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.800300e+00
# 7                                       Hedge's g =  -3.724800e+00
# 8                                  Glass's delta1 =  -4.675398e+14
# 9                                Point-Biserial r =  -8.898000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.200000  2.847662e-17  6.367566e-18
# 1       all_recall_score_sog  20.0  0.276333  2.840600e-02  6.351774e-03
# 2                   combined  40.0  0.238167  4.344135e-02  6.868681e-03
#
#    95% Conf.  Interval
# 0   0.200000  0.200000
# 1   0.263039  0.289628
# 2   0.224273  0.252060
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -7.630000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.201760e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.800300e+00
# 7                                       Hedge's g =  -3.724800e+00
# 8                                  Glass's delta1 =  -2.680562e+15
# 9                                Point-Biserial r =  -8.898000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.136325  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.245772  0.037504  0.008386
# 2                      combined  40.0  0.191048  0.061292  0.009691
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.228219  0.263324
# 2   0.171446  0.210650
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.1094
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -13.0508
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -4.1270
# 7                                       Hedge's g =   -4.0450
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9042
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.160790  0.000000  0.000000        NaN
# 1       all_f1_score_sog  20.0  0.254417  0.033120  0.007406   0.238916
# 2               combined  40.0  0.207603  0.052745  0.008340   0.190735
#
#    Interval
# 0       NaN
# 1  0.269917
# 2  0.224472
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0936
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -12.6420
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -3.9978
# 7                                       Hedge's g =   -3.9183
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8988
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[1,2]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02234382538594245
# test_discrete_score_W_discrete_a 0.04032700754385205
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.01739318005978277
# test_discrete_score_W0_a 0.029175201704974632
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.03443300398952806
# test_discrete_score_W_discrete_a 0.02422357085425989
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.02334380379895585
# test_discrete_score_W0_a 0.037353108504030286
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.053434189827062516
# test_discrete_score_W_discrete_a 0.05456195729343344
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.476
# test_discrete_score_W0_n 0.033922299757219505
# test_discrete_score_W0_a 0.052561119522969935
# test_discrete_score_W_discrete_p 0.46
# test_discrete_score_W_discrete_n 0.031134181280268396
# test_discrete_score_W_discrete_a 0.044253704350719236
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.030552889554805434
# test_discrete_score_W0_a 0.042998231189427
# test_discrete_score_W_discrete_p 0.4746666666666667
# test_discrete_score_W_discrete_n 0.03376967607150299
# test_discrete_score_W_discrete_a 0.04632683501465729
# Not good purity result for discrete features !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03342601353355848
# test_discrete_score_W0_a 0.04798282495417882
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.05507820220623584
# test_discrete_score_W_discrete_a 0.06572394767970656
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.46266666666666667
# test_discrete_score_W0_n 0.027459821320045832
# test_discrete_score_W0_a 0.04253570431171219
# test_discrete_score_W_discrete_p 0.49333333333333335
# test_discrete_score_W_discrete_n 0.04397362826092439
# test_discrete_score_W_discrete_a 0.06267067104557747
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.024786498576812546
# test_discrete_score_W0_a 0.03788888448751348
# test_discrete_score_W_discrete_p 0.49066666666666664
# test_discrete_score_W_discrete_n 0.03958278449072278
# test_discrete_score_W_discrete_a 0.05649455222149977
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.448
# test_discrete_score_W0_n 0.016522062383778145
# test_discrete_score_W0_a 0.028494233453073153
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.05119010651141663
# test_discrete_score_W_discrete_a 0.07210828379153088
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.44666666666666666
# test_discrete_score_W0_n 0.017426370665438014
# test_discrete_score_W0_a 0.023699636325396987
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032538084155730576
# test_discrete_score_W_discrete_a 0.04820567242261783
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.036857456552891944
# test_discrete_score_W0_a 0.05578198334814375
# test_discrete_score_W_discrete_p 0.5213333333333333
# test_discrete_score_W_discrete_n 0.06132297519620123
# test_discrete_score_W_discrete_a 0.08512012645846712
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4866666666666667
# test_discrete_score_W0_n 0.03759457527631816
# test_discrete_score_W0_a 0.055163595305752385
# test_discrete_score_W_discrete_p 0.556
# test_discrete_score_W_discrete_n 0.09577315053890768
# test_discrete_score_W_discrete_a 0.11281183908452129
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.48133333333333334
# test_discrete_score_W0_n 0.03093370149562325
# test_discrete_score_W0_a 0.044458312234050626
# test_discrete_score_W_discrete_p 0.516
# test_discrete_score_W_discrete_n 0.05804740739737212
# test_discrete_score_W_discrete_a 0.08513700710052961
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.02054779399772174
# test_discrete_score_W0_a 0.03101276852118271
# test_discrete_score_W_discrete_p 0.5013333333333333
# test_discrete_score_W_discrete_n 0.04653708967400014
# test_discrete_score_W_discrete_a 0.06827491998098022
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5146666666666667
# test_discrete_score_W0_n 0.05443083282314605
# test_discrete_score_W0_a 0.07036287681764777
# test_discrete_score_W_discrete_p 0.544
# test_discrete_score_W_discrete_n 0.08269977748474737
# test_discrete_score_W_discrete_a 0.09852532914984698
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.02892604535266786
# test_discrete_score_W0_a 0.047155247862443884
# test_discrete_score_W_discrete_p 0.524
# test_discrete_score_W_discrete_n 0.06372742679275416
# test_discrete_score_W_discrete_a 0.07877786447256512
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.524
# test_discrete_score_W0_n 0.05945259033535872
# test_discrete_score_W0_a 0.07960516206945854
# test_discrete_score_W_discrete_p 0.508
# test_discrete_score_W_discrete_n 0.0541905060530825
# test_discrete_score_W_discrete_a 0.07125467232825451
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.4573333333333333
# test_discrete_score_W0_n 0.022448343490384687
# test_discrete_score_W0_a 0.03397696731084315
# test_discrete_score_W_discrete_p 0.4826666666666667
# test_discrete_score_W_discrete_n 0.03841331757870813
# test_discrete_score_W_discrete_a 0.0518461718393148
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.5226666666666666
# test_discrete_score_W0_n 0.058074070778292367
# test_discrete_score_W0_a 0.0763494609595373
# test_discrete_score_W_discrete_p 0.5146666666666667
# test_discrete_score_W_discrete_n 0.05986941507524195
# test_discrete_score_W_discrete_a 0.08647900509679979
# Not good purity result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.46993333333333326
# test_discrete_score_W_discrete_p mean 0.49493333333333334
# test_discrete_score_W0_n mean 0.029605726327701958
# test_discrete_score_W_discrete_n mean 0.04883370954923206
# test_discrete_score_W0_a mean 0.04282968855928333
# test_discrete_score_W_discrete_a mean 0.06369091609333
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.029606  0.014779  0.003305   0.022689  0.036523
# 1  test_dis_W_dis  20.0  0.048834  0.019029  0.004255   0.039928  0.057740
# 2        combined  40.0  0.039220  0.019433  0.003073   0.033005  0.045435
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0192
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.5689
# 3                      Two side test p value =    0.0010
# 4                     Difference < 0 p value =    0.0005
# 5                     Difference > 0 p value =    0.9995
# 6                                  Cohen's d =   -1.1286
# 7                                  Hedge's g =   -1.1062
# 8                             Glass's delta1 =   -1.3010
# 9                           Point-Biserial r =   -0.5010
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.042830  0.019305  0.004317   0.033795  0.051865
# 1  test_dis_W_dis  20.0  0.063691  0.023612  0.005280   0.052640  0.074742
# 2        combined  40.0  0.053260  0.023765  0.003758   0.045660  0.060861
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0209
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -3.0589
# 3                      Two side test p value =    0.0041
# 4                     Difference < 0 p value =    0.0020
# 5                     Difference > 0 p value =    0.9980
# 6                                  Cohen's d =   -0.9673
# 7                                  Hedge's g =   -0.9481
# 8                             Glass's delta1 =   -1.0806
# 9                           Point-Biserial r =   -0.4445
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.469933  0.028203  0.006306   0.456734  0.483133
# 1  test_dis_W_dis  20.0  0.494933  0.030892  0.006908   0.480475  0.509391
# 2        combined  40.0  0.482433  0.031823  0.005032   0.472256  0.492611
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0250
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -2.6728
# 3                      Two side test p value =    0.0110
# 4                     Difference < 0 p value =    0.0055
# 5                     Difference > 0 p value =    0.9945
# 6                                  Cohen's d =   -0.8452
# 7                                  Hedge's g =   -0.8284
# 8                             Glass's delta1 =   -0.8864
# 9                           Point-Biserial r =   -0.3978

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.428
# test_discrete_score_W_discrete_n 0.02345171762930623
# test_discrete_score_W_discrete_a 0.01923792963102035
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.018856935362735645
# test_discrete_score_W_discrete_a 0.029045041233303804
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.026855580654044465
# test_discrete_score_W0_a 0.03604144266742046
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01810404796207701
# test_discrete_score_W_discrete_a 0.03346196864130828
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# self.train_new_embedding_sog_fuzzy.shape[1] 80
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024682167696410937
# test_discrete_score_W0_a 0.032188349757317845
# test_discrete_score_W_discrete_p 0.44666666666666666
# test_discrete_score_W_discrete_n 0.01797489888334447
# test_discrete_score_W_discrete_a 0.0285471281012557
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 100
# test_discrete_score_W0_p 0.46
# test_discrete_score_W0_n 0.024203462603534617
# test_discrete_score_W0_a 0.03846988685325159
# test_discrete_score_W_discrete_p 0.452
# test_discrete_score_W_discrete_n 0.01838925770914136
# test_discrete_score_W_discrete_a 0.032019100024307974
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 30
# self.train_new_embedding_sog_fuzzy.shape[1] 120
# test_discrete_score_W0_p 0.4826666666666667
# test_discrete_score_W0_n 0.03349335568258328
# test_discrete_score_W0_a 0.04667109658886825
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.01605391401844283
# test_discrete_score_W_discrete_a 0.026793244224623227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 140
# test_discrete_score_W0_p 0.48533333333333334
# test_discrete_score_W0_n 0.035485179839995426
# test_discrete_score_W0_a 0.04981859509745033
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02068810713236546
# test_discrete_score_W_discrete_a 0.03309157601901982
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# self.train_new_embedding_sog_fuzzy.shape[1] 160
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02390083884461625
# test_discrete_score_W0_a 0.03873861993122384
# test_discrete_score_W_discrete_p 0.4573333333333333
# test_discrete_score_W_discrete_n 0.023235517855302763
# test_discrete_score_W_discrete_a 0.03744560308797647
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 45
# self.train_new_embedding_sog_fuzzy.shape[1] 180
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.026985376253148303
# test_discrete_score_W0_a 0.03978610299904206
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.026305260920569878
# test_discrete_score_W_discrete_a 0.041094189990076725
# Not good nmi result for discrete features !!!!!
# neuron unit number: 50
# self.train_new_embedding_sog_fuzzy.shape[1] 200
# test_discrete_score_W0_p 0.4533333333333333
# test_discrete_score_W0_n 0.018162904680171798
# test_discrete_score_W0_a 0.03022682699783115
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03400184259136679
# test_discrete_score_W_discrete_a 0.05029641376853773
# neuron unit number: 55
# self.train_new_embedding_sog_fuzzy.shape[1] 220
# test_discrete_score_W0_p 0.4786666666666667
# test_discrete_score_W0_n 0.033072619927399426
# test_discrete_score_W0_a 0.047156111573114626
# test_discrete_score_W_discrete_p 0.4786666666666667
# test_discrete_score_W_discrete_n 0.03499390650337792
# test_discrete_score_W_discrete_a 0.051949215378023175
# neuron unit number: 60
# self.train_new_embedding_sog_fuzzy.shape[1] 240
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.023824261795553792
# test_discrete_score_W0_a 0.037597994770207366
# test_discrete_score_W_discrete_p 0.468
# test_discrete_score_W_discrete_n 0.028031643322058132
# test_discrete_score_W_discrete_a 0.044080209705631444
# neuron unit number: 65
# self.train_new_embedding_sog_fuzzy.shape[1] 260
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.028791201469484017
# test_discrete_score_W0_a 0.04599112596540657
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.032429275622864545
# test_discrete_score_W_discrete_a 0.04740265300888458
# neuron unit number: 70
# self.train_new_embedding_sog_fuzzy.shape[1] 280
# test_discrete_score_W0_p 0.4706666666666667
# test_discrete_score_W0_n 0.028197704700882276
# test_discrete_score_W0_a 0.042188175616839595
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03430876326213519
# test_discrete_score_W_discrete_a 0.05324336208092509
# neuron unit number: 75
# self.train_new_embedding_sog_fuzzy.shape[1] 300
# test_discrete_score_W0_p 0.45466666666666666
# test_discrete_score_W0_n 0.021944285346807382
# test_discrete_score_W0_a 0.031945508345160974
# test_discrete_score_W_discrete_p 0.48533333333333334
# test_discrete_score_W_discrete_n 0.03869110510763206
# test_discrete_score_W_discrete_a 0.05802214839446757
# neuron unit number: 80
# self.train_new_embedding_sog_fuzzy.shape[1] 320
# test_discrete_score_W0_p 0.5106666666666667
# test_discrete_score_W0_n 0.05054444015796348
# test_discrete_score_W0_a 0.06925893080150226
# test_discrete_score_W_discrete_p 0.47733333333333333
# test_discrete_score_W_discrete_n 0.028500768616768247
# test_discrete_score_W_discrete_a 0.03993660270160838
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# self.train_new_embedding_sog_fuzzy.shape[1] 340
# test_discrete_score_W0_p 0.468
# test_discrete_score_W0_n 0.03193530568800679
# test_discrete_score_W0_a 0.04764998062763653
# test_discrete_score_W_discrete_p 0.504
# test_discrete_score_W_discrete_n 0.047939169427930486
# test_discrete_score_W_discrete_a 0.06706429938523999
# neuron unit number: 90
# self.train_new_embedding_sog_fuzzy.shape[1] 360
# test_discrete_score_W0_p 0.4666666666666667
# test_discrete_score_W0_n 0.025557559612347378
# test_discrete_score_W0_a 0.038599165108127206
# test_discrete_score_W_discrete_p 0.4693333333333333
# test_discrete_score_W_discrete_n 0.02610302923188745
# test_discrete_score_W_discrete_a 0.041979976747958815
# neuron unit number: 95
# self.train_new_embedding_sog_fuzzy.shape[1] 380
# test_discrete_score_W0_p 0.456
# test_discrete_score_W0_n 0.02431624127598852
# test_discrete_score_W0_a 0.039038707645552506
# test_discrete_score_W_discrete_p 0.4666666666666667
# test_discrete_score_W_discrete_n 0.02710259286982934
# test_discrete_score_W_discrete_a 0.03850236196126793
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# self.train_new_embedding_sog_fuzzy.shape[1] 400
# test_discrete_score_W0_p 0.49333333333333335
# test_discrete_score_W0_n 0.043797733013326734
# test_discrete_score_W0_a 0.06109381550919402
# test_discrete_score_W_discrete_p 0.48
# test_discrete_score_W_discrete_n 0.03414668262562054
# test_discrete_score_W_discrete_a 0.047714667147608227
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.46453333333333335
# test_discrete_score_W_discrete_p mean 0.46593333333333337
# test_discrete_score_W0_n mean 0.02718831980217513
# test_discrete_score_W_discrete_n mean 0.027465421832737813
# test_discrete_score_W0_a mean 0.03962494445792386
# test_discrete_score_W_discrete_a mean 0.04104638456165226
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.027188  0.010186  0.002278   0.022421  0.031956
# 1  test_dis_W_dis  20.0  0.027465  0.008303  0.001857   0.023580  0.031351
# 2        combined  40.0  0.027327  0.009173  0.001450   0.024393  0.030261
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0003
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.0943
# 3                      Two side test p value =    0.9254
# 4                     Difference < 0 p value =    0.4627
# 5                     Difference > 0 p value =    0.5373
# 6                                  Cohen's d =   -0.0298
# 7                                  Hedge's g =   -0.0292
# 8                             Glass's delta1 =   -0.0272
# 9                           Point-Biserial r =   -0.0153
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.039625  0.014212  0.003178   0.032973  0.046276
# 1  test_dis_W_dis  20.0  0.041046  0.011732  0.002623   0.035556  0.046537
# 2        combined  40.0  0.040336  0.012883  0.002037   0.036215  0.044456
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.3449
# 3                      Two side test p value =    0.7320
# 4                     Difference < 0 p value =    0.3660
# 5                     Difference > 0 p value =    0.6340
# 6                                  Cohen's d =   -0.1091
# 7                                  Hedge's g =   -0.1069
# 8                             Glass's delta1 =   -0.1000
# 9                           Point-Biserial r =   -0.0559
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.464533  0.020521  0.004589   0.454929  0.474138
# 1  test_dis_W_dis  20.0  0.465933  0.017670  0.003951   0.457664  0.474203
# 2        combined  40.0  0.465233  0.018915  0.002991   0.459184  0.471283
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.2312
# 3                      Two side test p value =    0.8184
# 4                     Difference < 0 p value =    0.4092
# 5                     Difference > 0 p value =    0.5908
# 6                                  Cohen's d =   -0.0731
# 7                                  Hedge's g =   -0.0717
# 8                             Glass's delta1 =   -0.0682
# 9                           Point-Biserial r =   -0.0375

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
