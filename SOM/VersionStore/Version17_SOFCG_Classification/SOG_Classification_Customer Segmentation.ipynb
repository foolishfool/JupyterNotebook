# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/Test.csv")
csv = csv.drop(columns=['ID','Segmentation'])
csv2 = csv2.drop(columns=['ID'])   

csv = csv.sample(int(csv.shape[0]*0.1))
csv2 = csv2.sample(int(csv.shape[0]*0.1))



csv['Family_Size'] = pd.to_numeric(csv['Family_Size'])
csv2['Family_Size'] = pd.to_numeric(csv2['Family_Size'])
csv['Work_Experience'] = pd.to_numeric(csv['Work_Experience'])
csv2['Work_Experience'] = pd.to_numeric(csv2['Work_Experience'])



dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Ever_Married")
dataread.label_encoding(csv,"Graduated")
dataread.label_encoding(csv,"Profession")
dataread.label_encoding(csv,"Spending_Score")
dataread.label_encoding(csv,"Var_1")
dataread.label_encoding(csv,"Family_Size")
dataread.label_encoding(csv,"Work_Experience")



dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Ever_Married")
dataread.label_encoding(csv2,"Graduated")
dataread.label_encoding(csv2,"Profession")
dataread.label_encoding(csv2,"Spending_Score")
dataread.label_encoding(csv2,"Var_1")
dataread.label_encoding(csv2,"Family_Size")
dataread.label_encoding(csv2,"Work_Experience")



csv_training = csv.sample(int(csv.shape[0]))

csv_test = csv2


dataread.initializedataset(csv,csv_training,csv_test,"Var_1")
# Out:
# self.continuous_feature_num 1
# self.data_discrete_indexes ['Gender', 'Ever_Married', 'Graduated', 'Profession', 'Work_Experience', 'Spending_Score', 'Family_Size']

# %%
#Random Forest #(C = 1000,kernel='rbf',gamma ='auto',probability = True)
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 8
dim_num = 7
best_num = 48
interval = 1

features  =4
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features)
# Out:
# Experiment number: 1
# self.train_new_embedding_sog_fuzzy.shape  (806, 56)
# self.train_discrete_extra_sog_fuzzyc (806, 112)
# accuracy_score_orignial 0.5875
# recall_score_original 0.14285714285714285
# precision_score_original 0.08392857142857144
# f1_score_original 0.10573678290213724
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_sog 0.5625
# recall_score_sog 0.30319148936170215
# precision_score_sog 0.3255152807391613
# f1_score_sog 0.29756208703577125
# Not good accuracy result !!!!!
# Experiment number: 2
# self.train_new_embedding_sog_fuzzy.shape  (806, 56)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 112)
# accuracy_score_orignial 0.5875
# recall_score_original 0.14285714285714285
# precision_score_original 0.08392857142857144
# f1_score_original 0.10573678290213724
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_sog 0.575
# recall_score_sog 0.29141337386018235
# precision_score_sog 0.28775510204081634
# f1_score_sog 0.27507413221698934
# Not good accuracy result !!!!!
# Experiment number: 3
# self.train_new_embedding_sog_fuzzy.shape  (806, 56)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 112)
# accuracy_score_orignial 0.5875
# recall_score_original 0.14285714285714285
# precision_score_original 0.08392857142857144
# f1_score_original 0.10573678290213724
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_sog 0.5875
# recall_score_sog 0.3003419452887538
# precision_score_sog 0.3033126293995859
# f1_score_sog 0.2877295118674429
# Experiment number: 4
# self.train_new_embedding_sog_fuzzy.shape  (806, 56)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 112)
# accuracy_score_orignial 0.5875
# recall_score_original 0.14285714285714285
# precision_score_original 0.08392857142857144
# f1_score_original 0.10573678290213724
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
dataread.PCA_Comparision() #COMPONENT 123   0,1,2|0,2,1| 0,2,1,3
# Out:
# Sorted feature index for component 0 [1, 2, 0, 3, 6, 5, 4]
# Sorted imporance porporation for component 0  [0.6847502067717056, 0.1659707702714632, 0.09906544524163181, 0.04214016479974214, 0.003146281284708454, 0.002473021662587853, 0.002454109968160963]
# Sorted feature index for component 1 [0, 2, 1, 5, 3, 4, 6]
# Sorted imporance porporation for component 1  [0.5685404578697325, 0.2732026745026359, 0.08551572125116266, 0.044812792719661064, 0.017706930457136134, 0.0077810291397293, 0.002440394059942525]
# Sorted feature index for component 2 [0, 2, 1, 3, 5, 6, 4]
# Sorted imporance porporation for component 2  [0.6184069345817963, 0.16825944490926925, 0.10630648311845045, 0.05236634818911757, 0.03707279002416466, 0.017223348286478573, 0.0003646508907230098]
# Sorted feature index for component 3 [0, 6, 5, 4, 2, 3, 1]
# Sorted imporance porporation for component 3  [0.7265023862139709, 0.14697643806681554, 0.06546547687025879, 0.027353826575842642, 0.015438937075073112, 0.013721241430655017, 0.004541693767383884]
# Sorted feature index for component 4 [6, 5, 4, 2, 3, 0, 1]
# Sorted imporance porporation for component 4  [0.979847047368957, 0.007108841923978738, 0.004134060229311074, 0.003718238452537289, 0.002962418029084545, 0.002208078401327101, 2.131559480412397e-05]
# Sorted feature index for component 5 [0, 3, 1, 6, 2, 4, 5]
# Sorted imporance porporation for component 5  [0.5422303296752877, 0.24294884252372803, 0.10172310156119564, 0.04606284668553421, 0.04373379906240583, 0.02213659127068582, 0.0011644892211627616]
# Sorted feature index for component 6 [0, 5, 6, 1, 2, 4, 3]
# Sorted imporance porporation for component 6  [0.7772273192814433, 0.15670203652240539, 0.031752240992162756, 0.014616145707032086, 0.008664815720483771, 0.006602157355627951, 0.00443528442084492]
# [0.72972505 0.15116669 0.08890279 0.01711981 0.0052942  0.00474411
#  0.00304734]

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5

features  = []
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# Experiment number: 1
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 2
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1125
# recall_score_original 0.0510204081632653
# precision_score_original 0.20535714285714285
# f1_score_original 0.08037240537240538
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 3
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 4
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 5
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 6
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 7
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 8
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 9
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 10
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 11
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 12
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 13
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 14
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.125
# recall_score_original 0.05393586005830903
# precision_score_original 0.21008403361344538
# f1_score_original 0.08423520923520923
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good precision_score_original !!!!!
# Experiment number: 15
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 16
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 17
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 18
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 19
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 20
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1125
# recall_score_original 0.0510204081632653
# precision_score_original 0.20535714285714285
# f1_score_original 0.08037240537240538
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 21
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 22
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 23
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1125
# recall_score_original 0.0510204081632653
# precision_score_original 0.20535714285714285
# f1_score_original 0.08037240537240538
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 24
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 25
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 26
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 27
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 28
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 29
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 30
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 31
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1125
# recall_score_original 0.0510204081632653
# precision_score_original 0.20535714285714285
# f1_score_original 0.08037240537240538
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 32
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 87
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 88
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1125
# recall_score_original 0.0510204081632653
# precision_score_original 0.20535714285714285
# f1_score_original 0.08037240537240538
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 89
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 90
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 91
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 92
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 93
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 94
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.1880466472303207
# precision_score_original 0.2003996003996004
# f1_score_original 0.07774669007387901
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Not good recall_score result !!!!!
# Experiment number: 95
# self.train_new_embedding_sog_fuzzy.shape  (806, 14)
# self.train_discrete_extra_sog_fuzzyc (806, 28)
# accuracy_score_orignial 0.1
# recall_score_original 0.048104956268221574
# precision_score_original 0.19999999999999998
# f1_score_original 0.07638888888888888
# accuracy_score_sog 0.1875
# recall_score_sog 0.08940719144800778
# precision_score_sog 0.20548654244306416
# f1_score_sog 0.1099206349206349
# Experiment number: 96
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#Decision Tree
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 2
dim_num = 7
best_num = 48
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)

# %%
#Linear Discriminant Analysis 
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 14)
# accuracy_score_sog 0.6475066615911687
# recall_score_sog 0.13859987273419938
# precision_score_sog 0.1995540796963947
# f1_score_sog 0.12381420105737448
# neuron unit number: 7
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 49)
# accuracy_score_sog 0.651313285116102
# recall_score_sog 0.15278809061222406
# precision_score_sog 0.2503867191367191
# f1_score_sog 0.1463600885563781
# neuron unit number: 12
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 84)
# accuracy_score_sog 0.6497906357061287
# recall_score_sog 0.14932499177560182
# precision_score_sog 0.20499691319070415
# f1_score_sog 0.14021034742909977
# neuron unit number: 17
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 119)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 22
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 154)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 27
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 189)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 32
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 224)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 37
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 259)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 42
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 294)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 47
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 329)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 52
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 364)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 57
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 399)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 62
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 434)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 67
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 469)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 504)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 77
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 539)
# accuracy_score_sog 0.6296155310239817
# recall_score_sog 0.1809746174409138
# precision_score_sog 0.20063787617116136
# f1_score_sog 0.1785437411338398
# Not good accuracy result !!!!!
# neuron unit number: 82
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 574)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 87
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 609)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 92
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 644)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.13023054205816
# precision_score_original 0.12559143501429512
# f1_score_original 0.10914806872423001
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 679)
# accuracy_score_sog 0.6509326227636086
# recall_score_sog 0.1533807633067023
# precision_score_sog 0.24804433852802793
# f1_score_sog 0.14762840169425
# all_accuracy_score_original mean 0.6364674533688619
# all_recall_score_original mean 0.13023054205816004
# all_precision_score_original mean 0.12559143501429515
# all_f1_score_original mean 0.10914806872423002
# all_accuracy_score_sog mean 0.649657403882756
# all_recall_score_sog mean 0.15378898927350876
# all_precision_score_sog mean 0.2412142502321713
# all_f1_score_sog mean 0.1475491402642346
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.636467  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.649657  4.785290e-03  1.070023e-03
# 2                     combined  40.0  0.643062  7.467586e-03  1.180729e-03
#
#    95% Conf.  Interval
# 0   0.636467  0.636467
# 1   0.647418  0.651897
# 2   0.640674  0.645451
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -1.320000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.232680e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.898100e+00
# 7                                       Hedge's g =  -3.820600e+00
# 8                                  Glass's delta1 =  -1.157963e+14
# 9                                Point-Biserial r =  -8.944000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.130231  2.847662e-17  6.367566e-18
# 1       all_recall_score_sog  20.0  0.153789  7.230648e-03  1.616822e-03
# 2                   combined  40.0  0.142010  1.295294e-02  2.048040e-03
#
#    95% Conf.  Interval
# 0   0.130231  0.130231
# 1   0.150405  0.157173
# 2   0.137867  0.146152
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -2.360000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.457080e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.607700e+00
# 7                                       Hedge's g =  -4.516200e+00
# 8                                  Glass's delta1 =  -8.272909e+14
# 9                                Point-Biserial r =  -9.210000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.125591  2.847662e-17  6.367566e-18
# 1        all_accuracy_score_sog  20.0  0.649657  4.785290e-03  1.070023e-03
# 2                      combined  40.0  0.387624  2.653921e-01  4.196218e-02
#
#    95% Conf.  Interval
# 0   0.125591  0.125591
# 1   0.647418  0.651897
# 2   0.302748  0.472501
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -5.241000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -4.897706e+02
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.548791e+02
# 7                                       Hedge's g =  -1.518020e+02
# 8                                  Glass's delta1 =  -1.840338e+16
# 9                                Point-Biserial r =  -9.999000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.109148  1.423831e-17  3.183783e-18
# 1       all_f1_score_sog  20.0  0.147549  9.117320e-03  2.038695e-03
# 2               combined  40.0  0.128349  2.045997e-02  3.235006e-03
#
#    95% Conf.  Interval
# 0   0.109148  0.109148
# 1   0.143282  0.151816
# 2   0.121805  0.134892
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -3.840000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.883610e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.956500e+00
# 7                                       Hedge's g =  -5.838200e+00
# 8                                  Glass's delta1 =  -2.697025e+15
# 9                                Point-Biserial r =  -9.504000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#K-Nearest Neighbors (KNN)
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 14)
# accuracy_score_sog 0.6387514274838219
# recall_score_sog 0.2395020458902835
# precision_score_sog 0.3502202510562751
# f1_score_sog 0.2620645296846814
# neuron unit number: 7
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 49)
# accuracy_score_sog 0.6417967263037686
# recall_score_sog 0.23016360152778995
# precision_score_sog 0.3524713238048981
# f1_score_sog 0.25085908096151377
# neuron unit number: 12
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 84)
# accuracy_score_sog 0.6246669204415684
# recall_score_sog 0.20405094325509332
# precision_score_sog 0.2647177319285806
# f1_score_sog 0.21513876916625574
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 119)
# accuracy_score_sog 0.6315188427864484
# recall_score_sog 0.21141822248788164
# precision_score_sog 0.29341630869598867
# f1_score_sog 0.22622195698681064
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 154)
# accuracy_score_sog 0.650171298058622
# recall_score_sog 0.23525516733756582
# precision_score_sog 0.34101994011188175
# f1_score_sog 0.25416138169995106
# neuron unit number: 27
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 189)
# accuracy_score_sog 0.6391320898363152
# recall_score_sog 0.21596770006664007
# precision_score_sog 0.32408994338475283
# f1_score_sog 0.23261161217871817
# Not good precision_score_original !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 224)
# accuracy_score_sog 0.6429387133612485
# recall_score_sog 0.22373744187551653
# precision_score_sog 0.35687383427185043
# f1_score_sog 0.24096410290686118
# neuron unit number: 37
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 259)
# accuracy_score_sog 0.6318995051389418
# recall_score_sog 0.21575239727421625
# precision_score_sog 0.34883999811585253
# f1_score_sog 0.23503526667735508
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 294)
# accuracy_score_sog 0.6338028169014085
# recall_score_sog 0.2183703959420406
# precision_score_sog 0.34298984205261407
# f1_score_sog 0.23769839007329516
# neuron unit number: 47
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 329)
# accuracy_score_sog 0.6360867910163684
# recall_score_sog 0.22470245812391548
# precision_score_sog 0.350175354074838
# f1_score_sog 0.24637833528386002
# neuron unit number: 52
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 364)
# accuracy_score_sog 0.6494099733536354
# recall_score_sog 0.23560982121136131
# precision_score_sog 0.37962867010249546
# f1_score_sog 0.25930490155106445
# neuron unit number: 57
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 399)
# accuracy_score_sog 0.6437000380662352
# recall_score_sog 0.2165833226427063
# precision_score_sog 0.314531290046055
# f1_score_sog 0.23218221541454143
# Not good precision_score_original !!!!!
# neuron unit number: 62
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 434)
# accuracy_score_sog 0.6383707651313285
# recall_score_sog 0.2347458510757749
# precision_score_sog 0.3941243599985605
# f1_score_sog 0.2609190039492186
# neuron unit number: 67
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 469)
# accuracy_score_sog 0.6258089074990484
# recall_score_sog 0.22019810197395298
# precision_score_sog 0.3459795431660493
# f1_score_sog 0.24083945040577875
# Not good accuracy result !!!!!
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 504)
# accuracy_score_sog 0.6341834792539018
# recall_score_sog 0.22830680405931253
# precision_score_sog 0.37800475544910916
# f1_score_sog 0.25102548455951135
# neuron unit number: 77
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 539)
# accuracy_score_sog 0.6258089074990484
# recall_score_sog 0.22205803512694433
# precision_score_sog 0.36659590245714746
# f1_score_sog 0.2413061245596414
# Not good accuracy result !!!!!
# neuron unit number: 82
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 574)
# accuracy_score_sog 0.6341834792539018
# recall_score_sog 0.22940490029010258
# precision_score_sog 0.3578600365142379
# f1_score_sog 0.2531446089655365
# neuron unit number: 87
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 609)
# accuracy_score_sog 0.6364674533688618
# recall_score_sog 0.23141794790903197
# precision_score_sog 0.348156602045968
# f1_score_sog 0.2547282794867886
# neuron unit number: 92
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 644)
# accuracy_score_sog 0.6357061286638751
# recall_score_sog 0.2300365812749775
# precision_score_sog 0.37096318253318183
# f1_score_sog 0.2550616731687357
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6326608298439285
# recall_score_original 0.20721176627402926
# precision_score_original 0.33323959971331685
# f1_score_original 0.22375126424890368
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 679)
# accuracy_score_sog 0.627712219261515
# recall_score_sog 0.22988900851180954
# precision_score_sog 0.34788032843125305
# f1_score_sog 0.25325613984527623
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.6326608298439285
# all_recall_score_original mean 0.20721176627402924
# all_precision_score_original mean 0.3332395997133169
# all_f1_score_original mean 0.22375126424890368
# all_accuracy_score_sog mean 0.6361058241339931
# all_recall_score_sog mean 0.22485853739284586
# all_precision_score_sog mean 0.34642695991207945
# all_f1_score_sog mean 0.24514506537626973
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.632661  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.636106  0.007247  0.001621   0.632714
# 2                     combined  40.0  0.634383  0.005351  0.000846   0.632672
#
#    Interval
# 0       NaN
# 1  0.639498
# 2  0.636095
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0034
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.1258
# 3                           Two side test p value =    0.0401
# 4                          Difference < 0 p value =    0.0200
# 5                          Difference > 0 p value =    0.9800
# 6                                       Cohen's d =   -0.6722
# 7                                       Hedge's g =   -0.6589
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.3260
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.207212  2.847662e-17  6.367566e-18
# 1       all_recall_score_sog  20.0  0.224859  9.201557e-03  2.057531e-03
# 2                   combined  40.0  0.216035  1.100442e-02  1.739951e-03
#
#    95% Conf.  Interval
# 0   0.207212  0.207212
# 1   0.220552  0.229165
# 2   0.212516  0.219555
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -1.760000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -8.576700e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.712200e+00
# 7                                       Hedge's g =  -2.658300e+00
# 8                                  Glass's delta1 =  -6.196933e+14
# 9                                Point-Biserial r =  -8.120000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.333240  5.695324e-17  1.273513e-17
# 1        all_accuracy_score_sog  20.0  0.636106  7.247306e-03  1.620547e-03
# 2                      combined  40.0  0.484673  1.534457e-01  2.426189e-02
#
#    95% Conf.  Interval
# 0   0.333240  0.333240
# 1   0.632714  0.639498
# 2   0.435598  0.533747
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -3.029000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.868914e+02
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.910020e+01
# 7                                       Hedge's g =  -5.792610e+01
# 8                                  Glass's delta1 =  -5.317805e+15
# 9                                Point-Biserial r =  -9.995000e-01
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.223751  0.000000  0.000000        NaN
# 1       all_f1_score_sog  20.0  0.245145  0.012561  0.002809   0.239267
# 2               combined  40.0  0.234448  0.013936  0.002204   0.229991
#
#    Interval
# 0       NaN
# 1  0.251024
# 2  0.238905
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0214
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -7.6172
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.4088
# 7                                       Hedge's g =   -2.3609
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.7773
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %%
#SVM
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 14)
# accuracy_score_sog 0.6414160639512753
# recall_score_sog 0.12920984455958548
# precision_score_sog 0.20495409334353482
# f1_score_sog 0.105672194953085
# neuron unit number: 7
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 49)
# accuracy_score_sog 0.6459840121811953
# recall_score_sog 0.1335940017849617
# precision_score_sog 0.17696483686067022
# f1_score_sog 0.11394601213050319
# neuron unit number: 12
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 84)
# accuracy_score_sog 0.6459840121811953
# recall_score_sog 0.13434122207898455
# precision_score_sog 0.17429696559721686
# f1_score_sog 0.11545724216158659
# neuron unit number: 17
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 119)
# accuracy_score_sog 0.6475066615911687
# recall_score_sog 0.13563655886654932
# precision_score_sog 0.17514738789913073
# f1_score_sog 0.11768819737831024
# neuron unit number: 22
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 154)
# accuracy_score_sog 0.6475066615911687
# recall_score_sog 0.13538748543520837
# precision_score_sog 0.1766190870473036
# f1_score_sog 0.11721009253903991
# neuron unit number: 27
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 189)
# accuracy_score_sog 0.6471259992386753
# recall_score_sog 0.13506365123831718
# precision_score_sog 0.17818742572576537
# f1_score_sog 0.11666866501738567
# neuron unit number: 32
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 224)
# accuracy_score_sog 0.646745336886182
# recall_score_sog 0.13473981704142599
# precision_score_sog 0.17747028411287205
# f1_score_sog 0.11610279584685068
# neuron unit number: 37
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 259)
# accuracy_score_sog 0.6471259992386753
# recall_score_sog 0.13531272466965813
# precision_score_sog 0.17657071243430053
# f1_score_sog 0.11715135193753615
# neuron unit number: 42
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 294)
# accuracy_score_sog 0.6459840121811953
# recall_score_sog 0.13434122207898455
# precision_score_sog 0.17204152754984625
# f1_score_sog 0.11543899181922884
# neuron unit number: 47
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 329)
# accuracy_score_sog 0.6459840121811953
# recall_score_sog 0.13434122207898455
# precision_score_sog 0.17429696559721686
# f1_score_sog 0.11545724216158659
# neuron unit number: 52
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 364)
# accuracy_score_sog 0.6471259992386753
# recall_score_sog 0.13506365123831718
# precision_score_sog 0.17589573547020354
# f1_score_sog 0.11664789604367957
# neuron unit number: 57
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 399)
# accuracy_score_sog 0.6459840121811953
# recall_score_sog 0.13434122207898455
# precision_score_sog 0.17429696559721686
# f1_score_sog 0.11545724216158659
# neuron unit number: 62
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 434)
# accuracy_score_sog 0.6475066615911687
# recall_score_sog 0.13513841200386742
# precision_score_sog 0.17823576292607474
# f1_score_sog 0.11672737802818885
# neuron unit number: 67
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 469)
# accuracy_score_sog 0.6456033498287019
# recall_score_sog 0.13401738788209336
# precision_score_sog 0.17346456029802243
# f1_score_sog 0.11488746202706435
# neuron unit number: 72
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 504)
# accuracy_score_sog 0.6475066615911687
# recall_score_sog 0.13538748543520837
# precision_score_sog 0.17887192594639403
# f1_score_sog 0.11723200819321228
# neuron unit number: 77
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 539)
# accuracy_score_sog 0.6463646745336886
# recall_score_sog 0.13466505627587574
# precision_score_sog 0.17509030803765113
# f1_score_sog 0.11602447191290566
# neuron unit number: 82
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 574)
# accuracy_score_sog 0.6463646745336886
# recall_score_sog 0.13466505627587574
# precision_score_sog 0.17287118909459337
# f1_score_sog 0.11600505709123402
# neuron unit number: 87
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 609)
# accuracy_score_sog 0.6459840121811953
# recall_score_sog 0.1340921486476436
# precision_score_sog 0.17592776117582487
# f1_score_sog 0.11496340769506672
# neuron unit number: 92
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 644)
# accuracy_score_sog 0.6463646745336886
# recall_score_sog 0.13466505627587574
# precision_score_sog 0.17287118909459337
# f1_score_sog 0.11600505709123402
# neuron unit number: 97
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score_orignial 0.6364674533688618
# recall_score_original 0.125
# precision_score_original 0.07955843167110772
# f1_score_original 0.09723191439869737
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (8068, 679)
# accuracy_score_sog 0.6452226874762086
# recall_score_sog 0.13344448025386121
# precision_score_sog 0.1742208606715554
# f1_score_sog 0.11381369838342267
# all_accuracy_score_original mean 0.6364674533688619
# all_recall_score_original mean 0.125
# all_precision_score_original mean 0.07955843167110774
# all_f1_score_original mean 0.09723191439869736
# all_accuracy_score_sog mean 0.6462695089455652
# all_recall_score_sog mean 0.1343723853100131
# all_precision_score_sog mean 0.17691477722399937
# all_f1_score_sog mean 0.11542782322863536
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.636467  1.139065e-16  2.547026e-17
# 1       all_accuracy_score_sog  20.0  0.646270  1.340877e-03  2.998292e-04
# 2                     combined  40.0  0.641368  5.050930e-03  7.986222e-04
#
#    95% Conf.  Interval
# 0   0.636467  0.636467
# 1   0.645642  0.646897
# 2   0.639753  0.642984
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -9.800000e-03
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -3.269210e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.033820e+01
# 7                                       Hedge's g =  -1.013280e+01
# 8                                  Glass's delta1 =  -8.605354e+13
# 9                                Point-Biserial r =  -9.827000e-01
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.125000  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.134372  0.001353  0.000303   0.133739
# 2                   combined  40.0  0.129686  0.004839  0.000765   0.128139
#
#    Interval
# 0       NaN
# 1  0.135006
# 2  0.131234
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0094
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -30.9686
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -9.7931
# 7                                       Hedge's g =   -9.5986
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9808
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.079558  1.423831e-17  3.183783e-18
# 1        all_accuracy_score_sog  20.0  0.646270  1.340877e-03  2.998292e-04
# 2                      combined  40.0  0.362914  2.869668e-01  4.537344e-02
#
#    95% Conf.  Interval
# 0   0.079558  0.079558
# 1   0.645642  0.646897
# 2   0.271138  0.454690
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -5.667000e-01
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.890113e+03
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.977061e+02
# 7                                       Hedge's g =  -5.858312e+02
# 8                                  Glass's delta1 =  -3.980185e+16
# 9                                Point-Biserial r =  -1.000000e+00
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.097232  1.423831e-17  3.183783e-18
# 1       all_f1_score_sog  20.0  0.115428  2.525557e-03  5.647317e-04
# 2               combined  40.0  0.106330  9.380970e-03  1.483262e-03
#
#    95% Conf.  Interval
# 0   0.097232  0.097232
# 1   0.114246  0.116610
# 2   0.103330  0.109330
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.820000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -3.222040e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.018900e+01
# 7                                       Hedge's g =  -9.986600e+00
# 8                                  Glass's delta1 =  -1.277954e+15
# 9                                Point-Biserial r =  -9.822000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 40
class_num = 13
dim_num = 7
best_num = 48
interval = 2
features =[2,5]

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 91
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 105
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.005564941764608015
# test_discrete_score_W0_a 0.011017535230307017
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0029807133347071334
# test_discrete_score_W_discrete_a 0.004461965829821489
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 119
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 133
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6376094404263418
# test_discrete_score_W_discrete_n 0.00566668879667317
# test_discrete_score_W_discrete_a 0.0072411927005067355
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 147
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6379901027788352
# test_discrete_score_W_discrete_n 0.0070670532090423704
# test_discrete_score_W_discrete_a 0.00685799135805923
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 161
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6376094404263418
# test_discrete_score_W_discrete_n 0.007250359761387226
# test_discrete_score_W_discrete_a 0.009342460883234286
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 175
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.014216255786857458
# test_discrete_score_W_discrete_a 0.02753289819423834
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 189
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6368481157213551
# test_discrete_score_W_discrete_n 0.0039750497296574885
# test_discrete_score_W_discrete_a 0.0034086203760339668
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 203
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6379901027788352
# test_discrete_score_W_discrete_n 0.005519717801209763
# test_discrete_score_W_discrete_a 0.0046463063907382475
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 217
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6383707651313285
# test_discrete_score_W_discrete_n 0.014816712071560765
# test_discrete_score_W_discrete_a 0.024367503058538593
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.0014344529814698625
# test_discrete_score_W0_a 0.0009243621023628817
# test_discrete_score_W_discrete_p 0.6368481157213551
# test_discrete_score_W_discrete_n 0.0014344529814698625
# test_discrete_score_W_discrete_a 0.0009243621023628817
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 245
# test_discrete_score_W0_p 0.6391320898363152
# test_discrete_score_W0_n 0.008268162678980397
# test_discrete_score_W0_a 0.008370802709575704
# test_discrete_score_W_discrete_p 0.6372287780738485
# test_discrete_score_W_discrete_n 0.0038950056182722823
# test_discrete_score_W_discrete_a 0.0030347134616494956
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 259
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6372287780738485
# test_discrete_score_W_discrete_n 0.004706615938206944
# test_discrete_score_W_discrete_a 0.004738651752832074
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 273
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6368481157213551
# test_discrete_score_W_discrete_n 0.0014344529814698625
# test_discrete_score_W_discrete_a 0.0009243621023628817
# test_discrete_score_W0_p mean 0.6366849747131438
# test_discrete_score_W_discrete_p mean 0.6373375387459894
# test_discrete_score_W0_n mean 0.001090539816075591
# test_discrete_score_W_discrete_n mean 0.005211648429322453
# test_discrete_score_W0_a mean 0.0014509071458746858
# test_discrete_score_W_discrete_a mean 0.0069629305864555855
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  14.0  0.001091  0.002553  0.000682  -0.000384  0.002565
# 1  test_dis_W_dis  14.0  0.005212  0.004579  0.001224   0.002568  0.007856
# 2        combined  28.0  0.003151  0.004200  0.000794   0.001523  0.004780
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0041
# 1                         Degrees of freedom =   26.0000
# 2                                          t =   -2.9411
# 3                      Two side test p value =    0.0068
# 4                     Difference < 0 p value =    0.0034
# 5                     Difference > 0 p value =    0.9966
# 6                                  Cohen's d =   -1.1116
# 7                                  Hedge's g =   -1.0793
# 8                             Glass's delta1 =   -1.6142
# 9                           Point-Biserial r =   -0.4996
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  14.0  0.001451  0.003539  0.000946  -0.000593  0.003494
# 1  test_dis_W_dis  14.0  0.006963  0.008532  0.002280   0.002037  0.011889
# 2        combined  28.0  0.004207  0.006997  0.001322   0.001494  0.006920
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0055
# 1                         Degrees of freedom =   26.0000
# 2                                          t =   -2.2328
# 3                      Two side test p value =    0.0344
# 4                     Difference < 0 p value =    0.0172
# 5                     Difference > 0 p value =    0.9828
# 6                                  Cohen's d =   -0.8439
# 7                                  Hedge's g =   -0.8193
# 8                             Glass's delta1 =   -1.5574
# 9                           Point-Biserial r =   -0.4011
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  14.0  0.636685  0.000712  0.000190   0.636274  0.637096
# 1  test_dis_W_dis  14.0  0.637338  0.000738  0.000197   0.636911  0.637764
# 2        combined  28.0  0.637011  0.000785  0.000148   0.636707  0.637316
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0007
# 1                         Degrees of freedom =   26.0000
# 2                                          t =   -2.3817
# 3                      Two side test p value =    0.0248
# 4                     Difference < 0 p value =    0.0124
# 5                     Difference > 0 p value =    0.9876
# 6                                  Cohen's d =   -0.9002
# 7                                  Hedge's g =   -0.8740
# 8                             Glass's delta1 =   -0.9170
# 9                           Point-Biserial r =   -0.4232

# %%
import experiment
unstable_repeat_num= 30
scope_num = 40
class_num = 13
dim_num = 7
best_num = 48
interval = 2
features =[2,6]

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 13
# self.train_new_embedding_sog_fuzzy.shape[1] 91
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0008464406634374921
# test_discrete_score_W_discrete_a 0.00039092553757657383
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 105
# test_discrete_score_W0_p 0.6387514274838219
# test_discrete_score_W0_n 0.006886557656426264
# test_discrete_score_W0_a 0.0074479132149055174
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.008164231766131512
# test_discrete_score_W_discrete_a 0.010094276822223932
# neuron unit number: 17
# self.train_new_embedding_sog_fuzzy.shape[1] 119
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 19
# self.train_new_embedding_sog_fuzzy.shape[1] 133
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 21
# self.train_new_embedding_sog_fuzzy.shape[1] 147
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.006886557656426264
# test_discrete_score_W_discrete_a 0.0074479132149055174
# neuron unit number: 23
# self.train_new_embedding_sog_fuzzy.shape[1] 161
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6368481157213551
# test_discrete_score_W_discrete_n 0.009721893016748695
# test_discrete_score_W_discrete_a 0.02335761703212634
# neuron unit number: 25
# self.train_new_embedding_sog_fuzzy.shape[1] 175
# test_discrete_score_W0_p 0.6383707651313285
# test_discrete_score_W0_n 0.006504536653641483
# test_discrete_score_W0_a 0.008745255487946293
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.008416294146576353
# test_discrete_score_W_discrete_a 0.009828178323828467
# neuron unit number: 27
# self.train_new_embedding_sog_fuzzy.shape[1] 189
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 29
# self.train_new_embedding_sog_fuzzy.shape[1] 203
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.012342147448504714
# test_discrete_score_W_discrete_a 0.024062744137350166
# neuron unit number: 31
# self.train_new_embedding_sog_fuzzy.shape[1] 217
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 33
# self.train_new_embedding_sog_fuzzy.shape[1] 231
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.013444992679619707
# test_discrete_score_W_discrete_a 0.012328147448057767
# neuron unit number: 35
# self.train_new_embedding_sog_fuzzy.shape[1] 245
# test_discrete_score_W0_p 0.6410354015987819
# test_discrete_score_W0_n 0.014875553673649806
# test_discrete_score_W0_a 0.01838932263284543
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.010407904555596351
# test_discrete_score_W_discrete_a 0.009002763382903099
# Not good purity result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# self.train_new_embedding_sog_fuzzy.shape[1] 259
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.007824824846019469
# test_discrete_score_W_discrete_a 0.008257248005055534
# neuron unit number: 39
# self.train_new_embedding_sog_fuzzy.shape[1] 273
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.01131335789901556
# test_discrete_score_W_discrete_a 0.010459588855623168
# test_discrete_score_W0_p mean 0.6370928272336724
# test_discrete_score_W_discrete_p mean 0.6379085322747295
# test_discrete_score_W0_n mean 0.0020190462845512537
# test_discrete_score_W_discrete_n mean 0.00638347461986258
# test_discrete_score_W0_a mean 0.002470177952549803
# test_discrete_score_W_discrete_a mean 0.008230671625689327
# test_score_W0_p mean nan
# test_score_W_combine_p mean nan
# test_score_W0_n mean nan
# test_score_W_combine_n mean nan
# test_score_W0_a mean nan
# test_score_W_combine_a mean nan
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# NMI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  14.0  0.002019  0.004420  0.001181  -0.000533  0.004571
# 1  test_dis_W_dis  14.0  0.006383  0.005116  0.001367   0.003429  0.009338
# 2        combined  28.0  0.004201  0.005191  0.000981   0.002188  0.006214
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0044
# 1                         Degrees of freedom =   26.0000
# 2                                          t =   -2.4153
# 3                      Two side test p value =    0.0230
# 4                     Difference < 0 p value =    0.0115
# 5                     Difference > 0 p value =    0.9885
# 6                                  Cohen's d =   -0.9129
# 7                                  Hedge's g =   -0.8863
# 8                             Glass's delta1 =   -0.9875
# 9                           Point-Biserial r =   -0.4281
# ARI T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  14.0  0.002470  0.005440  0.001454  -0.000671  0.005611
# 1  test_dis_W_dis  14.0  0.008231  0.008043  0.002150   0.003587  0.012874
# 2        combined  28.0  0.005350  0.007348  0.001389   0.002501  0.008200
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0058
# 1                         Degrees of freedom =   26.0000
# 2                                          t =   -2.2198
# 3                      Two side test p value =    0.0354
# 4                     Difference < 0 p value =    0.0177
# 5                     Difference > 0 p value =    0.9823
# 6                                  Cohen's d =   -0.8390
# 7                                  Hedge's g =   -0.8146
# 8                             Glass's delta1 =   -1.0589
# 9                           Point-Biserial r =   -0.3992
# Purity T-Test
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  14.0  0.637093  0.001365  0.000365   0.636305  0.637881
# 1  test_dis_W_dis  14.0  0.637909  0.001479  0.000395   0.637054  0.638763
# 2        combined  28.0  0.637501  0.001457  0.000275   0.636936  0.638066
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0008
# 1                         Degrees of freedom =   26.0000
# 2                                          t =   -1.5161
# 3                      Two side test p value =    0.1416
# 4                     Difference < 0 p value =    0.0708
# 5                     Difference > 0 p value =    0.9292
# 6                                  Cohen's d =   -0.5730
# 7                                  Hedge's g =   -0.5563
# 8                             Glass's delta1 =   -0.5975
# 9                           Point-Biserial r =   -0.2850

# %%
import experiment
unstable_repeat_num= 30
scope_num = 40
class_num = 13
dim_num = 7
best_num = 48
interval = 2
features =[2,7]

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 13
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 11
#       8 features =[2,7]
#      10 experiment = experiment.Experiment()
# ---> 11 experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
#
# File C:\JupyterDoc\SOM\experiment.py:314, in Experiment.UTtest_Discrete_Continuous(self, dataread, noralimized, class_num, best_num, neuron_scope_num, unstable_repeat_num, type, interval, test_type, compareType, features_choosen)
#     312 while y <= neuron_scope_num:
#     313     print("neuron unit number: {}".format(y))
# --> 314     self.InitializedExperimentDataList(
#     315                         dataread,
#     316                         noralimized,
#     317                         y,
#     318                         all_train_score_W0_p,
#     319                         all_train_score_W_combine_p,
#     320                         test_score_W0_p,
#     321                         test_score_W_combine_p,
#     322                         all_train_score_W0_n,
#     323                         all_train_score_W_combine_n,
#     324                         test_score_W0_n,
#     325                         test_score_W_combine_n,
#     326                         all_train_score_W0_a,
#     327                         all_train_score_W_combine_a,
#     328                         test_score_W0_a,
#     329                         test_score_W_combine_a,
#     330                         train_discrete_score_W0_p,
#     331                         train_discrete_score_W_discrete_p,
#     332                         test_discrete_score_W0_p,
#     333                         test_discrete_score_W_discrete_p,
#     334                         train_discrete_score_W0_n,
#     335                         train_discrete_score_W_discrete_n,
#     336                         test_discrete_score_W0_n,
#     337                         test_discrete_score_W_discrete_n,
#     338                         train_discrete_score_W0_a,
#     339                         train_discrete_score_W_discrete_a,
#     340                         test_discrete_score_W0_a,
#     341                         test_discrete_score_W_discrete_a,
#     342                         test_type,
#     343                         compareType,
#     344                         features_choosen
#     345                         )
#     346     y =y + interval
#     347     if(y<= neuron_scope_num):
#
# File C:\JupyterDoc\SOM\experiment.py:201, in Experiment.InitializedExperimentDataList(self, dataread, continuous_features_noralimized, y, all_train_score_W0_p, all_train_score_W_combine_p, test_score_W0_p, test_score_W_combine_p, all_train_score_W0_n, all_train_score_W_combine_n, test_score_W0_n, test_score_W_combine_n, all_train_score_W0_a, all_train_score_W_combine_a, test_score_W0_a, test_score_W_combine_a, train_discrete_score_W0_p, train_discrete_score_W_discrete_p, test_discrete_score_W0_p, test_discrete_score_W_discrete_p, train_discrete_score_W0_n, train_discrete_score_W_discrete_n, test_discrete_score_W0_n, test_discrete_score_W_discrete_n, train_discrete_score_W0_a, train_discrete_score_W_discrete_a, test_discrete_score_W0_a, test_discrete_score_W_discrete_a, iscontinous_data_test, compareType, features_choosen)
#     199     optimize_W.do_COSOM(optimize_W.som_discrete_original,optimize_W.data_train_discrete_normalized, optimize_W.data_train_discrete_unnormalized, optimize_W.data_test_discrete_normalized,optimize_W.data_test_discrete_unnormalized,iscontinous_data_test,1)
#     200 if compareType == 3: #discrete unnormalization
# --> 201      optimize_W.do_DOSOM(features_choosen,False)
#     202      #get self.discrete_data_embedding_sog  and  self.test_new_embedding_sog
#     203      #optimize_W.get_SOG_Embedding()
#     204 if compareType == 4: # hybrid embedding continous + discrete_embedding
#
# File C:\JupyterDoc\SOM\CDSOM.py:1090, in CDSOM.do_DOSOM(self, features_chosoen, fuzzy_set_no_probability)
#    1088 self.getEachNeuronProbabilityOfEachFeatureValue_fuzzy(predicted_clusters_indexes)
#    1089 #self.discrete_data_embedding_sog_fuzzy = self.getEmbeddingWithNeuronProbablity_fuzzy(self.data_train_discrete_unnormalized)
# -> 1090 self.train_new_embedding_sog_fuzzy,self.train_new_embedding_sog_fuzzy_features= self.getEmbeddingWithNeuronProbablity_fuzzy(self.data_train_discrete_unnormalized,features_chosoen)
#    1091 self.test_new_embedding_sog_fuzzy,self.test_new_embedding_sog_fuzzy_features= self.getEmbeddingWithNeuronProbablity_fuzzy(self.data_test_discrete_unnormalized,features_chosoen)
#    1092 self.som_sog = newSom.SOM(self.som.m , self.som.m,self.train_new_embedding_sog_fuzzy.shape[1])
#
# File C:\JupyterDoc\SOM\CDSOM.py:1001, in CDSOM.getEmbeddingWithNeuronProbablity_fuzzy(self, X, features_choosen)
#     999 for f in features_choosen:
#    1000     if f+1 > len(x) :
# -> 1001        raise Exception(f" feature {f} exceed {len(x)}!!!!")
#    1002 extra_embedding_one_feature = []
#    1003 if l in features_choosen:
#
# Exception:  feature 7 exceed 7!!!!

# %%
#new  baseN encoding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.021221683239697055
# train_discrete_score_W_discrete_a 0.03905586340910106
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.016817077966245084
# test_discrete_score_W_discrete_a 0.021818659382341524
# neuron unit number: 16
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6574119980168567
# train_discrete_score_W_discrete_n 0.021216360919021394
# train_discrete_score_W_discrete_a 0.03733547759720087
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.0273460907877813
# test_discrete_score_W_discrete_a 0.044005521998694376
# neuron unit number: 19
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6593951412989588
# train_discrete_score_W_discrete_n 0.02358636395747185
# train_discrete_score_W_discrete_a 0.04163270252893237
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.024656243990377236
# test_discrete_score_W_discrete_a 0.0522238740818072
# neuron unit number: 22
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.658155676747645
# train_discrete_score_W_discrete_n 0.014384424106097533
# train_discrete_score_W_discrete_a 0.023022335885052148
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.0353044048564198
# test_discrete_score_W_discrete_a 0.0780168515519242
# neuron unit number: 25
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6586514625681705
# train_discrete_score_W_discrete_n 0.021263654714685807
# train_discrete_score_W_discrete_a 0.040827366283386284
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.026477762131381893
# test_discrete_score_W_discrete_a 0.045780996314031396
# neuron unit number: 28
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.013121453890830451
# train_discrete_score_W_discrete_a 0.01647888939495764
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.025158370939487914
# test_discrete_score_W_discrete_a 0.04368504065927013
# neuron unit number: 31
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.013306356318926274
# train_discrete_score_W_discrete_a 0.021661912265834856
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.027845932607313308
# test_discrete_score_W_discrete_a 0.051356674876185775
# neuron unit number: 34
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6596430342092217
# train_discrete_score_W_discrete_n 0.02024264858263857
# train_discrete_score_W_discrete_a 0.032478901967917036
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.028731614081560816
# test_discrete_score_W_discrete_a 0.06626131938572091
# neuron unit number: 37
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.013904486433166593
# train_discrete_score_W_discrete_a 0.02684414742094661
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.02194110366609597
# test_discrete_score_W_discrete_a 0.04021825005247288
# neuron unit number: 40
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6596430342092217
# train_discrete_score_W_discrete_n 0.021643531870837833
# train_discrete_score_W_discrete_a 0.04349459130985187
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.023230245737026062
# test_discrete_score_W_discrete_a 0.042288155401517105
# neuron unit number: 43
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.002990753075196906
# train_discrete_score_W_discrete_a 0.0038326442333023445
# test_discrete_score_W_discrete_p 0.6372287780738485
# test_discrete_score_W_discrete_n 0.008494288810362127
# test_discrete_score_W_discrete_a 0.01568632141561008
# neuron unit number: 46
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6391320898363152
# test_discrete_score_W0_n 0.01353327161891215
# test_discrete_score_W0_a 0.020719834572384264
# train_discrete_score_W_discrete_p 0.6584035696579078
# train_discrete_score_W_discrete_n 0.02193480768448553
# train_discrete_score_W_discrete_a 0.029581311520001232
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.029307312364890654
# test_discrete_score_W_discrete_a 0.04813180735169105
# neuron unit number: 49
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.658155676747645
# train_discrete_score_W_discrete_n 0.018299035204639345
# train_discrete_score_W_discrete_a 0.037409014338180724
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.02095875811763834
# test_discrete_score_W_discrete_a 0.03399157318055523
# neuron unit number: 52
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6618740704015865
# train_discrete_score_W_discrete_n 0.026804713486238547
# train_discrete_score_W_discrete_a 0.041361446576825875
# test_discrete_score_W_discrete_p 0.6444613627712219
# test_discrete_score_W_discrete_n 0.0332678040801299
# test_discrete_score_W_discrete_a 0.05803630871161119
# neuron unit number: 55
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.015659694489200477
# train_discrete_score_W_discrete_a 0.022107861505417322
# test_discrete_score_W_discrete_p 0.6379901027788352
# test_discrete_score_W_discrete_n 0.013932262292069812
# test_discrete_score_W_discrete_a 0.018984659442244
# neuron unit number: 58
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.010805551226669782
# train_discrete_score_W_discrete_a 0.02135367545970788
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.01828490650678198
# test_discrete_score_W_discrete_a 0.031613527257143496
# neuron unit number: 61
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.014599546708449028
# train_discrete_score_W_discrete_a 0.02293941263056107
# test_discrete_score_W_discrete_p 0.6379901027788352
# test_discrete_score_W_discrete_n 0.01189289675813938
# test_discrete_score_W_discrete_a 0.017138770730328854
# neuron unit number: 64
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.002302899174090629
# test_discrete_score_W0_a 0.0021232392838047578
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.013392997580977438
# train_discrete_score_W_discrete_a 0.024026150639118768
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.018809017774333636
# test_discrete_score_W_discrete_a 0.03373817187440117
# neuron unit number: 67
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6593951412989588
# train_discrete_score_W_discrete_n 0.01985195593407357
# train_discrete_score_W_discrete_a 0.03157304293756439
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.023127598937977542
# test_discrete_score_W_discrete_a 0.031960576735428424
# neuron unit number: 70
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.004155153649274146
# test_discrete_score_W0_a 0.004950799269075385
# train_discrete_score_W_discrete_p 0.6564204263758057
# train_discrete_score_W_discrete_n 0.01546025602235124
# train_discrete_score_W_discrete_a 0.029907543407741367
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.016139387121948304
# test_discrete_score_W_discrete_a 0.03202011353282983
# neuron unit number: 73
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.013730896119480617
# train_discrete_score_W_discrete_a 0.029224223524455795
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.014975803306513349
# test_discrete_score_W_discrete_a 0.03278907142718398
# neuron unit number: 76
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6398934145413019
# test_discrete_score_W0_n 0.021796749192488075
# test_discrete_score_W0_a 0.028661667131483527
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.013381771102258737
# train_discrete_score_W_discrete_a 0.020170034233465736
# test_discrete_score_W_discrete_p 0.6433193757137419
# test_discrete_score_W_discrete_n 0.02673717997171002
# test_discrete_score_W_discrete_a 0.04139739091756187
# neuron unit number: 79
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.020373017315071972
# train_discrete_score_W_discrete_a 0.03682864642572531
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.030587712605552514
# test_discrete_score_W_discrete_a 0.06665826125896962
# test_discrete_score_W0_p mean 0.6367653630360305
# test_discrete_score_W_discrete_p mean 0.6408533456910677
# test_discrete_score_W0_n mean 0.001816872766728913
# test_discrete_score_W_discrete_n mean 0.022783642409205954
# test_discrete_score_W0_a mean 0.0024545887068151274
# test_discrete_score_W_discrete_a mean 0.041208778153892366
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.017008  0.005211  0.001087   0.014754  0.019261
# 2         combined  46.0  0.008504  0.009338  0.001377   0.005731  0.011277
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0170
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -15.6529
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.6158
# 7                                    Hedge's g =   -4.5367
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9207
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.001817  0.005244  0.001093  -0.000451  0.004084
# 1  test_dis_W_dis  23.0  0.022784  0.006983  0.001456   0.019764  0.025803
# 2        combined  46.0  0.012300  0.012232  0.001804   0.008668  0.015933
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0210
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -11.5152
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.3956
# 7                                  Hedge's g =   -3.3374
# 8                             Glass's delta1 =   -3.9986
# 9                           Point-Biserial r =   -0.8665
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.029267  0.009800  0.002044   0.025029  0.033505
# 2         combined  46.0  0.014634  0.016305  0.002404   0.009792  0.019476
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0293
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -14.3219
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.2233
# 7                                    Hedge's g =   -4.1509
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9074
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.002455  0.007202  0.001502  -0.000660  0.005569
# 1  test_dis_W_dis  23.0  0.041209  0.016186  0.003375   0.034209  0.048208
# 2        combined  46.0  0.021832  0.023179  0.003418   0.014948  0.028715
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0388
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -10.4907
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.0935
# 7                                  Hedge's g =   -3.0405
# 8                             Glass's delta1 =   -5.3807
# 9                           Point-Biserial r =   -0.8452
# Purity T-Test
#           Variable     N      Mean            SD            SE  95% Conf.  \
# 0     train_dis_W0  23.0  0.654933  1.135175e-16  2.367003e-17   0.654933
# 1  train_dis_W_dis  23.0  0.657832  1.565021e-03  3.263295e-04   0.657156
# 2         combined  46.0  0.656383  1.829090e-03  2.696846e-04   0.655840
#
#    Interval
# 0  0.654933
# 1  0.658509
# 2  0.656926
#                                Independent t-test       results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =  -2.900000e-03
# 1                           Degrees of freedom =   4.400000e+01
# 2                                            t =  -8.884500e+00
# 3                        Two side test p value =   0.000000e+00
# 4                       Difference < 0 p value =   0.000000e+00
# 5                       Difference > 0 p value =   1.000000e+00
# 6                                    Cohen's d =  -2.619900e+00
# 7                                    Hedge's g =  -2.575000e+00
# 8                               Glass's delta1 =  -2.554029e+13
# 9                             Point-Biserial r =  -8.013000e-01
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636765  0.000889  0.000185   0.636381  0.637150
# 1  test_dis_W_dis  23.0  0.640853  0.001861  0.000388   0.640049  0.641658
# 2        combined  46.0  0.638809  0.002520  0.000372   0.638061  0.639558
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0041
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -9.5070
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.8035
# 7                                  Hedge's g =   -2.7554
# 8                             Glass's delta1 =   -4.5999
# 9                           Point-Biserial r =   -0.8201
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
