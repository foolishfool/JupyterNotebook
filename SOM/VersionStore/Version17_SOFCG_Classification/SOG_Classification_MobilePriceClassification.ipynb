# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"price_range")
# Out:
# self.continuous_feature_num 8
# self.data_discrete_indexes ['blue', 'dual_sim', 'fc', 'four_g', 'm_dep', 'n_cores', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']

# %%
#RandomForeset 
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5
features_choosen =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.24333333333333335
# recall_score_original 0.2437436705296303
# precision_score_original 0.24879034279082857
# f1_score_original 0.24381725308330815
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 24)
# accuracy_score_sog 0.26
# recall_score_sog 0.260570503301796
# precision_score_sog 0.2621888822869215
# f1_score_sog 0.26045283642339156
# neuron unit number: 7
# accuracy_score_orignial 0.23833333333333334
# recall_score_original 0.23913518654732052
# precision_score_original 0.24189269826415977
# f1_score_original 0.23706276373540228
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 84)
# accuracy_score_sog 0.25666666666666665
# recall_score_sog 0.25712709557449054
# precision_score_sog 0.25734982028085474
# f1_score_sog 0.2562118490846175
# neuron unit number: 12
# accuracy_score_orignial 0.25666666666666665
# recall_score_original 0.2568138511953524
# precision_score_original 0.2620285581175015
# f1_score_original 0.257531709180084
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 144)
# accuracy_score_sog 0.255
# recall_score_sog 0.2562242266252943
# precision_score_sog 0.25812531562870267
# f1_score_sog 0.2552951255431759
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.24166666666666667
# recall_score_original 0.24185615224599322
# precision_score_original 0.24765421808222873
# f1_score_original 0.2424905583423671
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 204)
# accuracy_score_sog 0.23666666666666666
# recall_score_sog 0.23681133155369055
# precision_score_sog 0.24053794272990886
# f1_score_sog 0.23728269683306719
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.25333333333333335
# recall_score_original 0.2533899790664442
# precision_score_original 0.25686515748031497
# f1_score_original 0.25301261380643153
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 264)
# accuracy_score_sog 0.25
# recall_score_sog 0.250739586039499
# precision_score_sog 0.2512903131310213
# f1_score_sog 0.24989900781053392
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 27
# accuracy_score_orignial 0.25166666666666665
# recall_score_original 0.25184778022094156
# precision_score_original 0.25577709088375833
# f1_score_original 0.25237968167041414
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 324)
# accuracy_score_sog 0.25666666666666665
# recall_score_sog 0.25645247934232035
# precision_score_sog 0.2587198867645499
# f1_score_sog 0.25678479161420564
# neuron unit number: 32
# accuracy_score_orignial 0.26
# recall_score_original 0.26003151886107945
# precision_score_original 0.26622222756111724
# f1_score_original 0.2611888732958142
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 384)
# accuracy_score_sog 0.2683333333333333
# recall_score_sog 0.26943673354283715
# precision_score_sog 0.2700110171210552
# f1_score_sog 0.26832034911548175
# neuron unit number: 37
# accuracy_score_orignial 0.23833333333333334
# recall_score_original 0.2388572285040461
# precision_score_original 0.2449470330747214
# f1_score_original 0.23904662121115544
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 444)
# accuracy_score_sog 0.25
# recall_score_sog 0.2504843748714894
# precision_score_sog 0.25520303414087736
# f1_score_sog 0.2511892857562424
# neuron unit number: 42
# accuracy_score_orignial 0.24166666666666667
# recall_score_original 0.24238814054891128
# precision_score_original 0.24674823059766698
# f1_score_original 0.2423524804667348
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 504)
# accuracy_score_sog 0.265
# recall_score_sog 0.2646989152854524
# precision_score_sog 0.2649183439640016
# f1_score_sog 0.26429380658577795
# neuron unit number: 47
# accuracy_score_orignial 0.245
# recall_score_original 0.2446512035706922
# precision_score_original 0.24784292200160318
# f1_score_original 0.24523655283705387
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 564)
# accuracy_score_sog 0.25
# recall_score_sog 0.2506450855841407
# precision_score_sog 0.2558502610642734
# f1_score_sog 0.25068524858422886
# neuron unit number: 52
# accuracy_score_orignial 0.24666666666666667
# recall_score_original 0.24742508587248085
# precision_score_original 0.2513635319276789
# f1_score_original 0.2467397780830365
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 624)
# accuracy_score_sog 0.26
# recall_score_sog 0.26060930259195847
# precision_score_sog 0.26131048730382933
# f1_score_sog 0.2599270860068805
# neuron unit number: 57
# accuracy_score_orignial 0.26
# recall_score_original 0.25908478958586645
# precision_score_original 0.2662766192210085
# f1_score_original 0.26067957499330435
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 684)
# accuracy_score_sog 0.26
# recall_score_sog 0.2611389588489437
# precision_score_sog 0.2609531627862022
# f1_score_sog 0.2595833916543448
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 62
# accuracy_score_orignial 0.25166666666666665
# recall_score_original 0.2520186983482589
# precision_score_original 0.25553693972999636
# f1_score_original 0.2520672412707107
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 744)
# accuracy_score_sog 0.24833333333333332
# recall_score_sog 0.24904018943564377
# precision_score_sog 0.24933403889388978
# f1_score_sog 0.24796884560344262
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 67
# accuracy_score_orignial 0.25166666666666665
# recall_score_original 0.25288464753707846
# precision_score_original 0.25461815352863343
# f1_score_original 0.25104563810896885
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 804)
# accuracy_score_sog 0.2683333333333333
# recall_score_sog 0.269232861125589
# precision_score_sog 0.27088345412277676
# f1_score_sog 0.2686816003380246
# neuron unit number: 72
# accuracy_score_orignial 0.24833333333333332
# recall_score_original 0.24771400552399958
# precision_score_original 0.25291220261838177
# f1_score_original 0.2487573878376349
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 864)
# accuracy_score_sog 0.26
# recall_score_sog 0.26071634250791564
# precision_score_sog 0.263922412667418
# f1_score_sog 0.2603545126518708
# neuron unit number: 77
# accuracy_score_orignial 0.255
# recall_score_original 0.25548370181326235
# precision_score_original 0.2586479099546152
# f1_score_original 0.2548678288728245
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 924)
# accuracy_score_sog 0.25833333333333336
# recall_score_sog 0.2585712810103361
# precision_score_sog 0.26410775729978425
# f1_score_sog 0.25934306097631865
# neuron unit number: 82
# accuracy_score_orignial 0.25
# recall_score_original 0.25070108842676775
# precision_score_original 0.25662954480362554
# f1_score_original 0.2504475175567563
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 984)
# accuracy_score_sog 0.25166666666666665
# recall_score_sog 0.2527694305749568
# precision_score_sog 0.25523925522080093
# f1_score_sog 0.25228064237286374
# Not good precision_score_original !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.23333333333333334
# recall_score_original 0.23348429192607353
# precision_score_original 0.23791774584255493
# f1_score_original 0.2341318077972067
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 1044)
# accuracy_score_sog 0.265
# recall_score_sog 0.26546569992704805
# precision_score_sog 0.2649651704884263
# f1_score_sog 0.26396854918294677
# neuron unit number: 92
# accuracy_score_orignial 0.23333333333333334
# recall_score_original 0.23329326064685546
# precision_score_original 0.23564983622838992
# f1_score_original 0.23312944763879806
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 1104)
# accuracy_score_sog 0.27166666666666667
# recall_score_sog 0.2727512337098554
# precision_score_sog 0.274470724808605
# f1_score_sog 0.2721325884728043
# neuron unit number: 97
# accuracy_score_orignial 0.25
# recall_score_original 0.250164436031984
# precision_score_original 0.2542014117541379
# f1_score_original 0.24991190723118817
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (1400, 1164)
# accuracy_score_sog 0.25333333333333335
# recall_score_sog 0.25378400353197583
# precision_score_sog 0.2565352358498906
# f1_score_sog 0.2538813802165122
# all_accuracy_score_original mean 0.24749999999999997
# all_recall_score_original mean 0.24774843585015197
# all_precision_score_original mean 0.25212611872314616
# all_f1_score_original mean 0.2477948618509597
# all_accuracy_score_sog mean 0.25725
# all_recall_score_sog mean 0.25786348174926166
# all_precision_score_sog mean 0.25979582582768945
# all_f1_score_sog mean 0.2574268327413366
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.247500  0.007993  0.001787   0.243759
# 1       all_accuracy_score_sog  20.0  0.257250  0.008329  0.001863   0.253352
# 2                     combined  40.0  0.252375  0.009450  0.001494   0.249353
#
#    Interval
# 0  0.251241
# 1  0.261148
# 2  0.255397
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0098
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.7771
# 3                           Two side test p value =    0.0005
# 4                          Difference < 0 p value =    0.0003
# 5                          Difference > 0 p value =    0.9997
# 6                                       Cohen's d =   -1.1944
# 7                                       Hedge's g =   -1.1707
# 8                                  Glass's delta1 =   -1.2198
# 9                                Point-Biserial r =   -0.5225
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.247748  0.007894  0.001765   0.244054
# 1       all_recall_score_sog  20.0  0.257863  0.008429  0.001885   0.253919
# 2                   combined  40.0  0.252806  0.009550  0.001510   0.249752
#
#    Interval
# 0  0.251443
# 1  0.261808
# 2  0.255860
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0101
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.9172
# 3                           Two side test p value =    0.0004
# 4                          Difference < 0 p value =    0.0002
# 5                          Difference > 0 p value =    0.9998
# 6                                       Cohen's d =   -1.2387
# 7                                       Hedge's g =   -1.2141
# 8                                  Glass's delta1 =   -1.2813
# 9                                Point-Biserial r =   -0.5363
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.252126  0.008357  0.001869
# 1       all_precision_score_sog  20.0  0.259796  0.007851  0.001756
# 2                      combined  40.0  0.255961  0.008896  0.001407
#
#    95% Conf.  Interval
# 0   0.248215  0.256037
# 1   0.256121  0.263470
# 2   0.253116  0.258806
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0077
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.9913
# 3                           Two side test p value =    0.0049
# 4                          Difference < 0 p value =    0.0024
# 5                          Difference > 0 p value =    0.9976
# 6                                       Cohen's d =   -0.9459
# 7                                       Hedge's g =   -0.9271
# 8                                  Glass's delta1 =   -0.9178
# 9                                Point-Biserial r =   -0.4366
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.247795  0.008126  0.001817   0.243992
# 1       all_f1_score_sog  20.0  0.257427  0.008162  0.001825   0.253607
# 2               combined  40.0  0.252611  0.009402  0.001487   0.249604
#
#    Interval
# 0  0.251598
# 1  0.261247
# 2  0.255618
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0096
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -3.7403
# 3                           Two side test p value =    0.0006
# 4                          Difference < 0 p value =    0.0003
# 5                          Difference > 0 p value =    0.9997
# 6                                       Cohen's d =   -1.1828
# 7                                       Hedge's g =   -1.1593
# 8                                  Glass's delta1 =   -1.1854
# 9                                Point-Biserial r =   -0.5187

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5
features_choosen =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)

# %%
#DecisionTree
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5
features_choosen =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)

# %%
#Linear Discriminant Analysis 

import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)

# %%
#KNN
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 10
best_num = 48
interval = 2

features =[]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)

# %%
#SVM
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,5]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,6]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,7]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,8]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1

features =[0,9]


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
