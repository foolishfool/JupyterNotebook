# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# self.continuous_feature_num 2
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
#scope_num = 40
class_num = 9
best_num = 48
interval = 1

features =5 # [0,1,2,3,4,5,6,7,8]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features)
# Out:
# Experiment number: 1
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12333333333333334
# recall_score_original 0.12618241212247053
# precision_score_original 0.12379832579864204
# f1_score_original 0.11993615228058759
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.1283370823031887
# precision_score_sog 0.12668259328395828
# f1_score_sog 0.12243093938150201
# Experiment number: 2
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11
# recall_score_original 0.11048480974077118
# precision_score_original 0.10766047054806743
# f1_score_original 0.10590950349666649
# accuracy_score_sog 0.13
# recall_score_sog 0.13316800017758482
# precision_score_sog 0.12819316545956513
# f1_score_sog 0.12561574232202333
# Experiment number: 3
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13333333333333333
# recall_score_original 0.1358623612052792
# precision_score_original 0.128803219586211
# f1_score_original 0.1275039958368601
# accuracy_score_sog 0.13
# recall_score_sog 0.13316800017758482
# precision_score_sog 0.1288019487572168
# f1_score_sog 0.12545751777478795
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11629535114845307
# precision_score_original 0.11686968446585524
# f1_score_original 0.11280115619904353
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.1285623075284139
# precision_score_sog 0.12577245302512532
# f1_score_sog 0.12207221698364948
# Experiment number: 5
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12541708324203255
# precision_score_original 0.12782941454567656
# f1_score_original 0.1220576982043574
# accuracy_score_sog 0.12
# recall_score_sog 0.12072838665101478
# precision_score_sog 0.12136245356991715
# f1_score_sog 0.11634685576781575
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11333333333333333
# recall_score_original 0.11488921414517561
# precision_score_original 0.1155513102881524
# f1_score_original 0.1110741489413704
# accuracy_score_sog 0.13333333333333333
# recall_score_sog 0.13617100318058784
# precision_score_sog 0.13008855721002935
# f1_score_sog 0.12824332469883534
# Experiment number: 7
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.10169476032103661
# precision_score_original 0.10241680918907346
# f1_score_original 0.09928173866753508
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.12350616442879254
# precision_score_sog 0.12384037978787774
# f1_score_sog 0.119390139066756
# Experiment number: 8
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10694636801898211
# precision_score_original 0.10679664143035585
# f1_score_original 0.1025710180337952
# accuracy_score_sog 0.12
# recall_score_sog 0.12072838665101478
# precision_score_sog 0.12018331571917219
# f1_score_sog 0.11629176923294571
# Experiment number: 9
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12388796791981378
# precision_score_original 0.12763733975395586
# f1_score_original 0.12204875202350879
# accuracy_score_sog 0.13
# recall_score_sog 0.13216849992770976
# precision_score_sog 0.12870682936895605
# f1_score_sog 0.12558335051394287
# Experiment number: 10
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12529026560313763
# precision_score_original 0.1250230690440032
# f1_score_original 0.11986282288312124
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.1253340793001857
# precision_score_sog 0.12501760338991222
# f1_score_sog 0.1194925347641749
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11
# recall_score_original 0.107636813485312
# precision_score_original 0.10892058495397731
# f1_score_original 0.10519165898184073
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.1391740061835908
# precision_score_sog 0.13361200887975672
# f1_score_sog 0.13128706864385653
# Experiment number: 12
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11427576951451195
# precision_score_original 0.11766856385586719
# f1_score_original 0.11266317689439756
# accuracy_score_sog 0.13
# recall_score_sog 0.13316800017758482
# precision_score_sog 0.1285665835561765
# f1_score_sog 0.12563536447531198
# Experiment number: 13
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12333333333333334
# recall_score_original 0.12279629653828733
# precision_score_original 0.12414900888585098
# f1_score_original 0.11946125263487944
# accuracy_score_sog 0.13
# recall_score_sog 0.13134008530619168
# precision_score_sog 0.1274026970840455
# f1_score_sog 0.12478233014842731
# Experiment number: 14
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12333333333333334
# recall_score_original 0.12340865312438469
# precision_score_original 0.12182246456250824
# f1_score_original 0.11759261027624807
# accuracy_score_sog 0.13
# recall_score_sog 0.13194327470248454
# precision_score_sog 0.13035757521973063
# f1_score_sog 0.12577423540916582
# Experiment number: 15
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12333333333333334
# recall_score_original 0.12060115620388329
# precision_score_original 0.12060565834150741
# f1_score_original 0.11713734709039875
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11694126619722765
# precision_score_sog 0.11421118390187474
# f1_score_sog 0.11192225640727961
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13
# recall_score_original 0.12956229125197488
# precision_score_original 0.12353980351292895
# f1_score_original 0.12169884183361163
# accuracy_score_sog 0.13333333333333333
# recall_score_sog 0.13617100318058784
# precision_score_sog 0.13069019119344627
# f1_score_sog 0.1284814639934024
# Experiment number: 17
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.127200025706362
# precision_score_original 0.12441125341745564
# f1_score_original 0.12089047404836878
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.1300815804244984
# precision_score_sog 0.12552071098582726
# f1_score_sog 0.12269898415380946
# Experiment number: 18
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13
# recall_score_original 0.12894411101943515
# precision_score_original 0.12893503853256175
# f1_score_original 0.1249656238336028
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.12939072214993197
# precision_score_sog 0.12656761809464526
# f1_score_sog 0.12292108000424894
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13333333333333333
# recall_score_original 0.13218326971836397
# precision_score_original 0.13237093103592898
# f1_score_original 0.1278743702304256
# accuracy_score_sog 0.13
# recall_score_sog 0.13216849992770976
# precision_score_sog 0.1287355704136397
# f1_score_sog 0.12554994945322986
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13333333333333333
# recall_score_original 0.1344459689676309
# precision_score_original 0.13006902572705167
# f1_score_original 0.1270134197797863
# accuracy_score_sog 0.13333333333333333
# recall_score_sog 0.1343430883091947
# precision_score_sog 0.1304785465840191
# f1_score_sog 0.12739044473937575
# Not good recall_score result !!!!!
# Experiment number: 21
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12
# recall_score_original 0.11676973857936221
# precision_score_original 0.11528792981303153
# f1_score_original 0.11276076911451442
# accuracy_score_sog 0.13
# recall_score_sog 0.13134008530619168
# precision_score_sog 0.1278369047205278
# f1_score_sog 0.12497427333550203
# Experiment number: 22
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13
# recall_score_original 0.13254914470871534
# precision_score_original 0.12452291177830939
# f1_score_original 0.12379883822335261
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.1285623075284139
# precision_score_sog 0.1251756234360581
# f1_score_sog 0.12229337956922463
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12877769032750486
# precision_score_original 0.12133564587797999
# f1_score_original 0.11997164546646014
# accuracy_score_sog 0.13
# recall_score_sog 0.13368620130554204
# precision_score_sog 0.12494643479605884
# f1_score_sog 0.1243191766896642
# Experiment number: 24
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12756863092498116
# precision_score_original 0.12369107581470912
# f1_score_original 0.12062729487122313
# accuracy_score_sog 0.13
# recall_score_sog 0.1342216400243281
# precision_score_sog 0.12934382837608643
# f1_score_sog 0.12620489879317442
# Experiment number: 25
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12333333333333334
# recall_score_original 0.12189363235649037
# precision_score_original 0.11796022366197806
# f1_score_original 0.11523452778912244
# accuracy_score_sog 0.13
# recall_score_sog 0.13339322540281007
# precision_score_sog 0.1276824170273827
# f1_score_sog 0.12536974709988022
# Experiment number: 26
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13333333333333333
# recall_score_original 0.13572483403959942
# precision_score_original 0.1288017055014071
# f1_score_original 0.12660581005216986
# accuracy_score_sog 0.13333333333333333
# recall_score_sog 0.13639622840581303
# precision_score_sog 0.13003470379236232
# f1_score_sog 0.12787683227630584
# Experiment number: 27
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11
# recall_score_original 0.11110052217313626
# precision_score_original 0.1100975740014241
# f1_score_original 0.10736970422615491
# accuracy_score_sog 0.13333333333333333
# recall_score_sog 0.13617100318058784
# precision_score_sog 0.13017119279991132
# f1_score_sog 0.1283625795649256
# Experiment number: 28
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12416887507888756
# precision_score_original 0.127602545947878
# f1_score_original 0.12060151909197162
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.1253340793001857
# precision_score_sog 0.12437715149710216
# f1_score_sog 0.11965128167564057
# Not good accuracy result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.11
# recall_score_original 0.1108612023935866
# precision_score_original 0.10811233574125384
# f1_score_original 0.10489700363328698
# accuracy_score_sog 0.13
# recall_score_sog 0.13134008530619168
# precision_score_sog 0.12916869803917652
# f1_score_sog 0.12507159707739113
# Experiment number: 30
# self.train_new_embedding_sog_fuzzy.shape  (700, 81)
# self.train_discrete_extra_sog_fuzzyc (700, 162)
# accuracy_score_orignial 0.13666666666666666
# recall_score_original 0.1340505958801486
# precision_score_original 0.1280630503355063
# f1_score_original 0.12719361393733936
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.13016499717458183
# precision_score_sog 0.12544343859295948
# f1_score_sog 0.12266380870928585
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.12266666666666667
# all_recall_score_original mean 0.12238232718199035
# all_precision_score_original mean 0.1206784538649703
# all_f1_score_original mean 0.11721988295253336
# all_accuracy_score_sog mean 0.12833333333333333
# all_recall_score_sog mean 0.13057344299399085
# all_precision_score_sog mean 0.12696574595208393
# all_f1_score_sog mean 0.12380517142418453
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  30.0  0.122667  0.009030  0.001649   0.119295
# 1       all_accuracy_score_sog  30.0  0.128333  0.004527  0.000827   0.126643
# 2                     combined  60.0  0.125500  0.007636  0.000986   0.123527
#
#    Interval
# 0  0.126038
# 1  0.130024
# 2  0.127473
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0057
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.0727
# 3                           Two side test p value =    0.0032
# 4                          Difference < 0 p value =    0.0016
# 5                          Difference > 0 p value =    0.9984
# 6                                       Cohen's d =   -0.7934
# 7                                       Hedge's g =   -0.7831
# 8                                  Glass's delta1 =   -0.6276
# 9                                Point-Biserial r =   -0.3742
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  30.0  0.122382  0.009367  0.001710   0.118885
# 1       all_recall_score_sog  30.0  0.130573  0.005171  0.000944   0.128643
# 2                   combined  60.0  0.126478  0.008563  0.001105   0.124266
#
#    Interval
# 0  0.125880
# 1  0.132504
# 2  0.128690
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0082
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -4.1933
# 3                           Two side test p value =    0.0001
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.0827
# 7                                       Hedge's g =   -1.0686
# 8                                  Glass's delta1 =   -0.8745
# 9                                Point-Biserial r =   -0.4823
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  30.0  0.120678  0.008106  0.001480
# 1       all_precision_score_sog  30.0  0.126966  0.003763  0.000687
# 2                      combined  60.0  0.123822  0.007022  0.000907
#
#    95% Conf.  Interval
# 0   0.117652  0.123705
# 1   0.125561  0.128371
# 2   0.122008  0.125636
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0063
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.8534
# 3                           Two side test p value =    0.0003
# 4                          Difference < 0 p value =    0.0001
# 5                          Difference > 0 p value =    0.9999
# 6                                       Cohen's d =   -0.9949
# 7                                       Hedge's g =   -0.9820
# 8                                  Glass's delta1 =   -0.7756
# 9                                Point-Biserial r =   -0.4515
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  30.0  0.117220  0.008086  0.001476   0.114200
# 1       all_f1_score_sog  30.0  0.123805  0.004147  0.000757   0.122257
# 2               combined  60.0  0.120513  0.007184  0.000928   0.118657
#
#    Interval
# 0  0.120239
# 1  0.125354
# 2  0.122368
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0066
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -3.9691
# 3                           Two side test p value =    0.0002
# 4                          Difference < 0 p value =    0.0001
# 5                          Difference > 0 p value =    0.9999
# 6                                       Cohen's d =   -1.0248
# 7                                       Hedge's g =   -1.0115
# 8                                  Glass's delta1 =   -0.8144
# 9                                Point-Biserial r =   -0.4622

# %%
dataread.PCA_Comparision() # 1-8  8, 4, 5, 3, 6 |[5, 3, 4, 6, 8,|7, 8, 6, 5|5, 6, 7, 8, 4|5, 6, 8, 7, 3|7, 6, 4, 5, 3|5, 0, 1|2, 5, 3
# Out:
# Sorted feature index for component 0 [5, 7, 4, 8, 3, 6, 2, 0, 1]
# Sorted imporance porporation for component 0  [0.2945830495038704, 0.2325217048702421, 0.15956242719084954, 0.12969317763108362, 0.10578050511469865, 0.05581983006829407, 0.015662287356519727, 0.0052583927028099445, 0.0011186255616320404]
# Sorted feature index for component 1 [0, 4, 6, 2, 8, 7, 3, 1, 5]
# Sorted imporance porporation for component 1  [0.39611858850249276, 0.28586844829333224, 0.2428750901421531, 0.0304420955098011, 0.017876372923742154, 0.01403260542606228, 0.005815427671210971, 0.004508563905228775, 0.002462807625976695]
# Sorted feature index for component 2 [8, 4, 7, 5, 6, 3, 1, 0, 2]
# Sorted imporance porporation for component 2  [0.21150190810646624, 0.21116761219139263, 0.17960000735671122, 0.17151449606673677, 0.10198315485365689, 0.07904582525083782, 0.02178031904366127, 0.012177577089855696, 0.01122910004068151]
# Sorted feature index for component 3 [8, 3, 6, 5, 7, 4, 0, 1, 2]
# Sorted imporance porporation for component 3  [0.28461366537037136, 0.19801469542393849, 0.16388181063650478, 0.14199552478566055, 0.13456121097441887, 0.04336498734909367, 0.02836046622829187, 0.0029194489962871494, 0.0022881902354334347]
# Sorted feature index for component 4 [4, 8, 7, 5, 2, 6, 1, 0, 3]
# Sorted imporance porporation for component 4  [0.3606354119639298, 0.23672245716565563, 0.19098013167635083, 0.07700425740152088, 0.05238835773592866, 0.03727260718051331, 0.027495128256675418, 0.013198447436242175, 0.004303201183183243]
# Sorted feature index for component 5 [6, 5, 4, 7, 3, 8, 0, 2, 1]
# Sorted imporance porporation for component 5  [0.22650088422644513, 0.20437529989814082, 0.18270267514333105, 0.12568045690720547, 0.12466953366404379, 0.09549328043663527, 0.0174552810374922, 0.017252135453906248, 0.005870453232799945]
# Sorted feature index for component 6 [5, 0, 3, 2, 4, 1, 7, 8, 6]
# Sorted imporance porporation for component 6  [0.39715427022755206, 0.30729404872684707, 0.21557357976112693, 0.032251095910388265, 0.017001256473462928, 0.016467655236208766, 0.00846694634151992, 0.005349563749491345, 0.0004415835734026543]
# Sorted feature index for component 7 [1, 3, 5, 0, 2, 4, 7, 8, 6]
# Sorted imporance porporation for component 7  [0.3785587529172672, 0.32710257811292925, 0.22863488941441978, 0.022106204253959566, 0.01724828320116279, 0.01253850188154006, 0.006968648880439547, 0.003708222552872906, 0.0031339187854088763]
# Sorted feature index for component 8 [5, 3, 4, 6, 1, 2, 7, 0, 8]
# Sorted imporance porporation for component 8  [0.48154047830629854, 0.34147627780826034, 0.038012532716168786, 0.037560764056739415, 0.03460962354912691, 0.027296678488617866, 0.020604063641237395, 0.017023873077398513, 0.0018757083561523871]
# [0.15441442 0.14948238 0.14384638 0.14043442 0.13272003 0.12384872
#  0.05700573 0.05064909 0.04759882]

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 10
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 10
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 100)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5103658536585366
# precision_score_sog 0.5106014412416852
# f1_score_sog 0.5008682792386032
# neuron unit number: 15
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 150)
# accuracy_score_sog 0.48494983277591974
# recall_score_sog 0.49053748870822045
# precision_score_sog 0.4904962801669388
# f1_score_sog 0.4848979774476463
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# neuron unit number: 20
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 200)
# accuracy_score_sog 0.4916387959866221
# recall_score_sog 0.4966350496838302
# precision_score_sog 0.4966304839439168
# f1_score_sog 0.4916331096196868
# neuron unit number: 25
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 250)
# accuracy_score_sog 0.4882943143812709
# recall_score_sog 0.49358626919602533
# precision_score_sog 0.49356825799438353
# f1_score_sog 0.48827141850397665
# neuron unit number: 30
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 300)
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5101400180668474
# precision_score_sog 0.510153776571687
# f1_score_sog 0.5050111856823266
# neuron unit number: 35
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 350)
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5188572719060524
# precision_score_sog 0.5190743786549707
# f1_score_sog 0.511437908496732
# neuron unit number: 40
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 400)
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5094850948509485
# precision_score_sog 0.5094731143991339
# f1_score_sog 0.5050111856823266
# neuron unit number: 45
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 450)
# accuracy_score_sog 0.49498327759197325
# recall_score_sog 0.4996838301716351
# precision_score_sog 0.4996838301716351
# f1_score_sog 0.49498327759197325
# neuron unit number: 50
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 500)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.5033875338753387
# precision_score_sog 0.5033921302578019
# f1_score_sog 0.4983221476510067
# neuron unit number: 55
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 550)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.5020776874435411
# precision_score_sog 0.5020703933747412
# f1_score_sog 0.49827725076069446
# neuron unit number: 60
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 600)
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5094850948509485
# precision_score_sog 0.5094731143991339
# f1_score_sog 0.5050111856823266
# neuron unit number: 65
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 650)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.50273261065944
# precision_score_sog 0.502729159148322
# f1_score_sog 0.4983221476510067
# neuron unit number: 70
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 700)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5057813911472449
# precision_score_sog 0.5057673245021177
# f1_score_sog 0.5016499435104087
# neuron unit number: 75
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 750)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5057813911472449
# precision_score_sog 0.5057673245021177
# f1_score_sog 0.5016499435104087
# neuron unit number: 80
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 800)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.5020776874435411
# precision_score_sog 0.5020703933747412
# f1_score_sog 0.49827725076069446
# neuron unit number: 85
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 850)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.5020776874435411
# precision_score_sog 0.5020703933747412
# f1_score_sog 0.49827725076069446
# neuron unit number: 90
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 900)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5057813911472449
# precision_score_sog 0.5057673245021177
# f1_score_sog 0.5016499435104087
# neuron unit number: 95
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 950)
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5101400180668474
# precision_score_sog 0.510153776571687
# f1_score_sog 0.5050111856823266
# neuron unit number: 100
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 1000)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.5020776874435411
# precision_score_sog 0.5020703933747412
# f1_score_sog 0.49827725076069446
# all_accuracy_score_original mean 0.4782608695652173
# all_recall_score_original mean 0.4922990063233965
# all_precision_score_original mean 0.4916658519894418
# all_f1_score_original mean 0.4733062330623308
# all_accuracy_score_sog mean 0.4993839112832248
# all_recall_score_sog mean 0.5042468977321353
# all_precision_score_sog mean 0.5042638573961377
# all_f1_score_sog mean 0.49930736013178634
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_original  19.0  0.478261  1.140646e-16  2.616821e-17
# 1       all_accuracy_score_sog  19.0  0.499384  6.311599e-03  1.447980e-03
# 2                     combined  38.0  0.488822  1.157326e-02  1.877430e-03
#
#    95% Conf.  Interval
# 0   0.478261  0.478261
# 1   0.496342  0.502426
# 2   0.485018  0.492626
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_... -2.110000e-02
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -1.458790e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -4.733000e+00
# 7                                       Hedge's g =  -4.633700e+00
# 8                                  Glass's delta1 =  -1.851849e+14
# 9                                Point-Biserial r =  -9.248000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  19.0  0.492299  5.703229e-17  1.308410e-17
# 1       all_recall_score_sog  19.0  0.504247  6.601835e-03  1.514565e-03
# 2                   combined  38.0  0.498273  7.606294e-03  1.233904e-03
#
#    95% Conf.  Interval
# 0   0.492299  0.492299
# 1   0.501065  0.507429
# 2   0.495773  0.500773
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re... -1.190000e-02
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -7.888700e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.559400e+00
# 7                                       Hedge's g =  -2.505700e+00
# 8                                  Glass's delta1 =  -2.094935e+14
# 9                                Point-Biserial r =  -7.959000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  19.0  0.491666  0.000000  0.000000
# 1       all_precision_score_sog  19.0  0.504264  0.006648  0.001525
# 2                      combined  38.0  0.497965  0.007890  0.001280
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.501060  0.507468
# 2   0.495372  0.500558
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0126
# 1                              Degrees of freedom =   36.0000
# 2                                               t =   -8.2603
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.6800
# 7                                       Hedge's g =   -2.6238
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.8091
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  19.0  0.473306  1.140646e-16  2.616821e-17
# 1       all_f1_score_sog  19.0  0.499307  6.277757e-03  1.440216e-03
# 2               combined  38.0  0.486307  1.388363e-02  2.252222e-03
#
#    95% Conf.  Interval
# 0   0.473306  0.473306
# 1   0.496282  0.502333
# 2   0.481743  0.490870
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -2.600000e-02
# 1                              Degrees of freedom =   3.600000e+01
# 2                                               t =  -1.805360e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.857400e+00
# 7                                       Hedge's g =  -5.734500e+00
# 8                                  Glass's delta1 =  -2.279509e+14
# 9                                Point-Biserial r =  -9.490000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#Decision Tree
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.12602100424681073
# precision_score_original 0.13039542550118144
# f1_score_original 0.12679739465848316
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 18)
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.08998926660216983
# precision_score_sog 0.08990060936655364
# f1_score_sog 0.08971850066123004
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.1
# recall_score_original 0.09920750243330888
# precision_score_original 0.09908883515994273
# f1_score_original 0.09855744216536605
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 63)
# accuracy_score_sog 0.12
# recall_score_sog 0.11988824811405456
# precision_score_sog 0.1239709325572703
# f1_score_sog 0.12043073160977524
# neuron unit number: 12
# accuracy_score_orignial 0.1
# recall_score_original 0.097140898753802
# precision_score_original 0.0996917703440603
# f1_score_original 0.09770817800742099
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 108)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.1044055576313641
# precision_score_sog 0.10365048957002981
# f1_score_sog 0.10204547803515757
# neuron unit number: 17
# accuracy_score_orignial 0.12666666666666668
# recall_score_original 0.11901822224402868
# precision_score_original 0.12617504126259982
# f1_score_original 0.12157562327207996
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 153)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10675218578444384
# precision_score_sog 0.10940306921989068
# f1_score_sog 0.10715679120504538
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.1
# recall_score_original 0.09757535080115726
# precision_score_original 0.09772110164135255
# f1_score_original 0.09709769029395583
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 198)
# accuracy_score_sog 0.11
# recall_score_sog 0.11127756369691855
# precision_score_sog 0.10925635611543931
# f1_score_sog 0.10907123132332734
# neuron unit number: 27
# accuracy_score_orignial 0.12
# recall_score_original 0.11957714941585909
# precision_score_original 0.12188195170651309
# f1_score_original 0.11980858897003893
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 243)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10531145934371741
# precision_score_sog 0.1057536518062834
# f1_score_sog 0.10467557547693951
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.08666666666666667
# recall_score_original 0.0880948921271502
# precision_score_original 0.08439228475993182
# f1_score_original 0.08584496304524215
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 288)
# accuracy_score_sog 0.11
# recall_score_sog 0.10883076205656851
# precision_score_sog 0.11412920337869628
# f1_score_sog 0.11021706871528897
# neuron unit number: 37
# accuracy_score_orignial 0.1
# recall_score_original 0.10111798015023823
# precision_score_original 0.10091241942048394
# f1_score_original 0.09978194178951814
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 333)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.1038900337287434
# precision_score_sog 0.0961849832121812
# f1_score_sog 0.0986856612342268
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.11
# recall_score_original 0.11085668827604311
# precision_score_original 0.11071160134044797
# f1_score_original 0.10876248802506262
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 378)
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09060981802917285
# precision_score_sog 0.08894217154021075
# f1_score_sog 0.08934421744879262
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 47
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.1037762836149933
# precision_score_original 0.10535923375603884
# f1_score_original 0.10254861129157988
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 423)
# accuracy_score_sog 0.11
# recall_score_sog 0.10838031160611805
# precision_score_sog 0.11743499665011292
# f1_score_sog 0.1112579429816043
# neuron unit number: 52
# accuracy_score_orignial 0.14
# recall_score_original 0.13792634276505245
# precision_score_original 0.13972178627351042
# f1_score_original 0.13797074197081682
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 468)
# accuracy_score_sog 0.07666666666666666
# recall_score_sog 0.07914043075333399
# precision_score_sog 0.08179279172525453
# f1_score_sog 0.07951615445992558
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 57
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.1132031172353753
# precision_score_original 0.12123355436295741
# f1_score_original 0.11595694485830742
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 513)
# accuracy_score_sog 0.13333333333333333
# recall_score_sog 0.13216558619784427
# precision_score_sog 0.1324155804444762
# f1_score_sog 0.13067743085912248
# neuron unit number: 62
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10799778622359267
# precision_score_original 0.10352595205263748
# f1_score_original 0.10406040715157344
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 558)
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11513434255369738
# precision_score_sog 0.11594876404018915
# f1_score_sog 0.1147332726330535
# neuron unit number: 67
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10289598354114483
# precision_score_original 0.1065839585782197
# f1_score_original 0.10355486442371914
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 603)
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09688037429972912
# precision_score_sog 0.09977183101121981
# f1_score_sog 0.09782627641760375
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 72
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.09914165317391126
# precision_score_original 0.09676133009466342
# f1_score_original 0.09705652311731017
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 648)
# accuracy_score_sog 0.08
# recall_score_sog 0.07910110571400894
# precision_score_sog 0.0757319465439599
# f1_score_sog 0.07556072825972616
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 77
# accuracy_score_orignial 0.1
# recall_score_original 0.10081410484636293
# precision_score_original 0.10224394716249983
# f1_score_original 0.09944724108953407
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 693)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10207765369055692
# precision_score_sog 0.10848702859717571
# f1_score_sog 0.10344232924672668
# neuron unit number: 82
# accuracy_score_orignial 0.1
# recall_score_original 0.10643458707974837
# precision_score_original 0.09859983691195358
# f1_score_original 0.09992486753594328
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 738)
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09253531914822238
# precision_score_sog 0.0938170132614577
# f1_score_sog 0.09291366508708203
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.11
# recall_score_original 0.10700621023201669
# precision_score_original 0.1112234802250282
# f1_score_original 0.10790690161668183
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 783)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11326799149379793
# precision_score_sog 0.11467814466907027
# f1_score_sog 0.1122299619694544
# neuron unit number: 92
# accuracy_score_orignial 0.11
# recall_score_original 0.11114034017259823
# precision_score_original 0.11248185904099883
# f1_score_original 0.1103105216225318
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 828)
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11779986941277265
# precision_score_sog 0.11841699014688618
# f1_score_sog 0.11704901650932602
# neuron unit number: 97
# accuracy_score_orignial 0.09666666666666666
# recall_score_original 0.09442557345783152
# precision_score_original 0.09575211410325762
# f1_score_original 0.09460256348027828
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 873)
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11562411804347288
# precision_score_sog 0.12337727822257796
# f1_score_sog 0.11688964708858601
# all_accuracy_score_original mean 0.10816666666666667
# all_recall_score_original mean 0.10716858353955128
# all_precision_score_original mean 0.10822287418491397
# all_f1_score_original mean 0.10646372491927218
# all_accuracy_score_sog mean 0.10516666666666666
# all_recall_score_sog mean 0.10465309989503538
# all_precision_score_sog mean 0.1061531916039468
# all_f1_score_sog mean 0.10417208406109972
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.108167  0.012494  0.002794   0.102319
# 1       all_accuracy_score_sog  20.0  0.105167  0.013571  0.003035   0.098815
# 2                     combined  40.0  0.106667  0.012965  0.002050   0.102520
#
#    Interval
# 0  0.114014
# 1  0.111518
# 2  0.110813
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...   0.0030
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.7273
# 3                           Two side test p value =    0.4715
# 4                          Difference < 0 p value =    0.7642
# 5                          Difference > 0 p value =    0.2358
# 6                                       Cohen's d =    0.2300
# 7                                       Hedge's g =    0.2254
# 8                                  Glass's delta1 =    0.2401
# 9                                Point-Biserial r =    0.1172
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.107169  0.011734  0.002624   0.101677
# 1       all_recall_score_sog  20.0  0.104653  0.013528  0.003025   0.098322
# 2                   combined  40.0  0.105911  0.012564  0.001987   0.101893
#
#    Interval
# 0  0.112660
# 1  0.110984
# 2  0.109929
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...   0.0025
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.6282
# 3                           Two side test p value =    0.5336
# 4                          Difference < 0 p value =    0.7332
# 5                          Difference > 0 p value =    0.2668
# 6                                       Cohen's d =    0.1987
# 7                                       Hedge's g =    0.1947
# 8                                  Glass's delta1 =    0.2144
# 9                                Point-Biserial r =    0.1014
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.108223  0.013633  0.003048
# 1       all_precision_score_sog  20.0  0.106153  0.014899  0.003331
# 2                      combined  40.0  0.107188  0.014134  0.002235
#
#    95% Conf.  Interval
# 0   0.101842  0.114603
# 1   0.099180  0.113126
# 2   0.102668  0.111708
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...   0.0021
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.4583
# 3                           Two side test p value =    0.6493
# 4                          Difference < 0 p value =    0.6753
# 5                          Difference > 0 p value =    0.3247
# 6                                       Cohen's d =    0.1449
# 7                                       Hedge's g =    0.1421
# 8                                  Glass's delta1 =    0.1518
# 9                                Point-Biserial r =    0.0741
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.106464  0.012507  0.002797   0.100610
# 1       all_f1_score_sog  20.0  0.104172  0.013857  0.003099   0.097687
# 2               combined  40.0  0.105318  0.013081  0.002068   0.101134
#
#    Interval
# 0  0.112317
# 1  0.110657
# 2  0.109501
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...   0.0023
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    0.5490
# 3                           Two side test p value =    0.5862
# 4                          Difference < 0 p value =    0.7069
# 5                          Difference > 0 p value =    0.2931
# 6                                       Cohen's d =    0.1736
# 7                                       Hedge's g =    0.1702
# 8                                  Glass's delta1 =    0.1832
# 9                                Point-Biserial r =    0.0887

# %%
#LinearDiscriminantAnalysis()
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 18)
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.11907730113375276
# precision_score_sog 0.1253222621319227
# f1_score_sog 0.11890733795109215
# neuron unit number: 7
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 63)
# accuracy_score_sog 0.14
# recall_score_sog 0.13414234361815008
# precision_score_sog 0.15630065501919047
# f1_score_sog 0.13613427030232178
# neuron unit number: 12
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 108)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.14497714211336504
# f1_score_sog 0.12910568586389648
# neuron unit number: 17
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 153)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.14497714211336504
# f1_score_sog 0.12910568586389648
# neuron unit number: 22
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 198)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1447764149508139
# f1_score_sog 0.12901524396622432
# neuron unit number: 27
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 243)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1447764149508139
# f1_score_sog 0.12901524396622432
# neuron unit number: 32
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 288)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.14511516833834776
# f1_score_sog 0.12923259746996282
# neuron unit number: 37
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 333)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1447764149508139
# f1_score_sog 0.12901524396622432
# neuron unit number: 42
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 378)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 47
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 423)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 52
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 468)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 57
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 513)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 62
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 558)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 67
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 603)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 72
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 648)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 77
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 693)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 82
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 738)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 87
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 783)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 92
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 828)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# neuron unit number: 97
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11816563066563068
# precision_score_original 0.12362345115968305
# f1_score_original 0.11321069656351826
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 873)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13025279678505486
# precision_score_sog 0.1449185007706491
# f1_score_sog 0.12914466867340094
# all_accuracy_score_original mean 0.11666666666666667
# all_recall_score_original mean 0.11816563066563068
# all_precision_score_original mean 0.12362345115968307
# all_f1_score_original mean 0.11321069656351827
# all_accuracy_score_sog mean 0.13616666666666669
# all_recall_score_sog mean 0.12988849934414454
# all_precision_score_sog mean 0.1445021811908211
# all_f1_score_sog mean 0.12896336667153266
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.116667  0.000000  0.000000        NaN
# 1       all_accuracy_score_sog  20.0  0.136167  0.003111  0.000696   0.134711
# 2                     combined  40.0  0.126417  0.010110  0.001599   0.123183
#
#    Interval
# 0       NaN
# 1  0.137623
# 2  0.129650
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0195
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -28.0317
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -8.8644
# 7                                       Hedge's g =   -8.6883
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9767
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.118166  0.000000  0.000000        NaN
# 1       all_recall_score_sog  20.0  0.129888  0.002689  0.000601   0.128630
# 2                   combined  40.0  0.124027  0.006226  0.000984   0.122036
#
#    Interval
# 0       NaN
# 1  0.131147
# 2  0.126018
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0117
# 1                              Degrees of freedom =   38.0000
# 2                                               t =  -19.4978
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -6.1658
# 7                                       Hedge's g =   -6.0433
# 8                                  Glass's delta1 =      -inf
# 9                                Point-Biserial r =   -0.9535
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_original  20.0  0.123623  1.423831e-17  3.183783e-18
# 1       all_precision_score_sog  20.0  0.144502  5.181981e-03  1.158726e-03
# 2                      combined  40.0  0.134063  1.117394e-02  1.766755e-03
#
#    95% Conf.  Interval
# 0   0.123623  0.123623
# 1   0.142077  0.146927
# 2   0.130489  0.137636
#                                   Independent t-test       results
# 0  Difference (all_precision_score_original - all... -2.090000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -1.801870e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.698000e+00
# 7                                       Hedge's g =  -5.584800e+00
# 8                                  Glass's delta1 =  -1.466377e+15
# 9                                Point-Biserial r =  -9.462000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.113211  1.423831e-17  3.183783e-18
# 1       all_f1_score_sog  20.0  0.128963  2.838282e-03  6.346592e-04
# 2               combined  40.0  0.121087  8.219001e-03  1.299538e-03
#
#    95% Conf.  Interval
# 0   0.113211  0.113211
# 1   0.127635  0.130292
# 2   0.118458  0.123716
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco... -1.580000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =  -2.482070e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.849000e+00
# 7                                       Hedge's g =  -7.693000e+00
# 8                                  Glass's delta1 =  -1.106358e+15
# 9                                Point-Biserial r =  -9.705000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#KNN
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 18)
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09903848159426253
# precision_score_sog 0.09509787483471693
# f1_score_sog 0.09464367860290866
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 63)
# accuracy_score_sog 0.12666666666666668
# recall_score_sog 0.12385850799474868
# precision_score_sog 0.12780988801527957
# f1_score_sog 0.1223060637961147
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 12
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 108)
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.12375081493996302
# precision_score_sog 0.12704976876641044
# f1_score_sog 0.12312382762246846
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 17
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 153)
# accuracy_score_sog 0.11
# recall_score_sog 0.10948313817228625
# precision_score_sog 0.116283374666683
# f1_score_sog 0.10986572522835086
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 22
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 198)
# accuracy_score_sog 0.1
# recall_score_sog 0.09887803509760913
# precision_score_sog 0.10119021950202937
# f1_score_sog 0.09911790339242446
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 27
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 243)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10810676179590986
# precision_score_sog 0.10604038827723038
# f1_score_sog 0.10549600127963517
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 32
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 288)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10537037859975656
# precision_score_sog 0.09983671299460772
# f1_score_sog 0.10171899326107418
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 37
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 333)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11249177138291405
# precision_score_sog 0.1143779185737592
# f1_score_sog 0.11168921173381476
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 42
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 378)
# accuracy_score_sog 0.11
# recall_score_sog 0.10968113028204306
# precision_score_sog 0.11182716170646628
# f1_score_sog 0.10939327620711609
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 47
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 423)
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11850307765199584
# precision_score_sog 0.11829998838487803
# f1_score_sog 0.11686632967225129
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 52
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 468)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10503526184307117
# precision_score_sog 0.10446587947092081
# f1_score_sog 0.1029293213387369
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 57
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 513)
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.12432607826032438
# precision_score_sog 0.12367703919174507
# f1_score_sog 0.12209320100598332
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 62
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 558)
# accuracy_score_sog 0.12
# recall_score_sog 0.12009331231778833
# precision_score_sog 0.11853198493906494
# f1_score_sog 0.11781651841259233
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 67
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 603)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13502009293084344
# precision_score_sog 0.1364348748416579
# f1_score_sog 0.1338541392800069
# neuron unit number: 72
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 648)
# accuracy_score_sog 0.13666666666666666
# recall_score_sog 0.13560477966749096
# precision_score_sog 0.1324784772074935
# f1_score_sog 0.1318273898794814
# Not good precision_score_original !!!!!
# neuron unit number: 77
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 693)
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11470060747021532
# precision_score_sog 0.10883094731560204
# f1_score_sog 0.10869697125180847
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 82
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 738)
# accuracy_score_sog 0.11
# recall_score_sog 0.11003659938751216
# precision_score_sog 0.11063450891882265
# f1_score_sog 0.10865980616118243
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 87
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 783)
# accuracy_score_sog 0.13
# recall_score_sog 0.1276784248597974
# precision_score_sog 0.1299625848210363
# f1_score_sog 0.1268773406696331
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 92
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 828)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11282847171961438
# precision_score_sog 0.1118762387865597
# f1_score_sog 0.11037101305400891
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 97
# accuracy_score_orignial 0.13
# recall_score_original 0.1300600988227763
# precision_score_original 0.13589977562495292
# f1_score_original 0.12883852868515222
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 873)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10700010701278449
# precision_score_sog 0.10447168421024632
# f1_score_sog 0.10454240971512445
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.12999999999999998
# all_recall_score_original mean 0.13006009882277633
# all_precision_score_original mean 0.13589977562495292
# all_f1_score_original mean 0.1288385286851522
# all_accuracy_score_sog mean 0.1155
# all_recall_score_sog mean 0.11507429164904656
# all_precision_score_sog mean 0.11495887577126052
# all_f1_score_sog mean 0.11309445607823584
# Accuracy Score T-Test
#                       Variable     N     Mean            SD            SE  \
# 0  all_accuracy_score_original  20.0  0.13000  2.847662e-17  6.367566e-18
# 1       all_accuracy_score_sog  20.0  0.11550  1.120124e-02  2.504674e-03
# 2                     combined  40.0  0.12275  1.072547e-02  1.695845e-03
#
#    95% Conf.  Interval
# 0   0.130000  0.130000
# 1   0.110258  0.120742
# 2   0.119320  0.126180
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_original - all_...  1.450000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   5.789200e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.830700e+00
# 7                                       Hedge's g =   1.794300e+00
# 8                                  Glass's delta1 =   5.091896e+14
# 9                                Point-Biserial r =   6.846000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_original  20.0  0.130060  2.847662e-17  6.367566e-18
# 1       all_recall_score_sog  20.0  0.115074  1.070887e-02  2.394576e-03
# 2                   combined  40.0  0.122567  1.065143e-02  1.684138e-03
#
#    95% Conf.  Interval
# 0   0.130060  0.130060
# 1   0.110062  0.120086
# 2   0.119161  0.125974
#                                   Independent t-test       results
# 0  Difference (all_recall_score_original - all_re...  1.500000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   6.258200e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   1.979000e+00
# 7                                       Hedge's g =   1.939700e+00
# 8                                  Glass's delta1 =   5.262495e+14
# 9                                Point-Biserial r =   7.124000e-01
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.135900  0.000000  0.000000
# 1       all_precision_score_sog  20.0  0.114959  0.011686  0.002613
# 2                      combined  40.0  0.125429  0.013378  0.002115
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.109490  0.120428
# 2   0.121151  0.129708
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...   0.0209
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    8.0142
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.5343
# 7                                       Hedge's g =    2.4839
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.7926
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_original  20.0  0.128839  2.847662e-17  6.367566e-18
# 1       all_f1_score_sog  20.0  0.113094  1.087416e-02  2.431536e-03
# 2               combined  40.0  0.120966  1.100752e-02  1.740442e-03
#
#    95% Conf.  Interval
# 0   0.128839  0.128839
# 1   0.108005  0.118184
# 2   0.117446  0.124487
#                                   Independent t-test       results
# 0  Difference (all_f1_score_original - all_f1_sco...  1.570000e-02
# 1                              Degrees of freedom =   3.800000e+01
# 2                                               t =   6.475000e+00
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   2.047600e+00
# 7                                       Hedge's g =   2.006900e+00
# 8                                  Glass's delta1 =   5.528772e+14
# 9                                Point-Biserial r =   7.243000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
