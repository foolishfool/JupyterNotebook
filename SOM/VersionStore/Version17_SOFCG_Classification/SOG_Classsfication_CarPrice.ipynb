# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CarPrice_Assignment.csv",encoding='latin-1')
csv = csv.drop(columns=['car_ID'])

dataread.changeCategoryTextToInt(csv,"CarName")
dataread.changeCategoryTextToInt(csv,"carbody")
dataread.changeCategoryTextToInt(csv,"drivewheel")
dataread.changeCategoryTextToInt(csv,"fueltype")
dataread.changeCategoryTextToInt(csv,"aspiration")
dataread.changeCategoryTextToInt(csv,"doornumber")
dataread.changeCategoryTextToInt(csv,"cylindernumber")
dataread.changeCategoryTextToInt(csv,"enginelocation")
dataread.changeCategoryTextToInt(csv,"enginetype")
dataread.changeCategoryTextToInt(csv,"fuelsystem")

dataread.stringToIntCarPriceDataSet(csv,"symboling")
                                 
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv_training,csv_training,csv_test,"symboling")
# Out:
# Unkonwn value 3
# Unkonwn value 3
# Unkonwn value 1
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# Unkonwn value 2
# Unkonwn value 2
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 0
# Unkonwn value 2
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 0
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 1
# Unkonwn value 3
# ...

# %%
#Random Forest
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 30
interval = 5
features_choosen =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.7868852459016393
# recall_score_original 0.6458333333333334
# precision_score_original 0.7316468253968255
# f1_score_original 0.6522692993281228
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SOG Classficiation
# accuracy_score_sog 0.7704918032786885
# recall_score_sog 0.625
# precision_score_sog 0.7224556489262373
# f1_score_sog 0.6309736015618369
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# ...

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 30
interval = 5
features_choosen =[0,3,8]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.4426229508196721
# recall_score_original 0.24411764705882352
# precision_score_original 0.16951219512195123
# f1_score_original 0.19137931034482758
# SOG Classficiation
# accuracy_score_sog 0.36065573770491804
# recall_score_sog 0.22892156862745097
# precision_score_sog 0.16435185185185183
# f1_score_sog 0.18282155629547414
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 4
# accuracy_score_orignial 0.36065573770491804
# recall_score_original 0.2818627450980392
# precision_score_original 0.12175925925925928
# f1_score_original 0.1693548387096774
# SOG Classficiation
# accuracy_score_sog 0.36065573770491804
# recall_score_sog 0.2818627450980392
# precision_score_sog 0.12175925925925928
# f1_score_sog 0.1693548387096774
# neuron unit number: 6
# accuracy_score_orignial 0.5081967213114754
# ...

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.5737704918032787
# recall_score_sog 0.450599128540305
# precision_score_sog 0.4304372041214147
# f1_score_sog 0.4386337067470496
# neuron unit number: 7
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# accuracy_score_sog 0.6065573770491803
# recall_score_sog 0.43763616557734203
# precision_score_sog 0.40277777777777773
# f1_score_sog 0.4126962732719928
# neuron unit number: 12
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.3799019607843137
# precision_score_original 0.32976190476190476
# f1_score_original 0.34908900836320195
# SOG Classficiation
# ...

# %%
#Decision Tree
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 2
interval = 5

features_choosen =[]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_choosen)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.45901639344262296
# recall_score_original 0.2553921568627451
# precision_score_original 0.1528376436781609
# f1_score_original 0.19047619047619047
# SOG Classficiation
# accuracy_score_sog 0.5081967213114754
# recall_score_sog 0.3178921568627451
# precision_score_sog 0.3322981366459627
# f1_score_sog 0.28783813086138665
# neuron unit number: 7
# accuracy_score_orignial 0.36065573770491804
# recall_score_original 0.2818627450980392
# precision_score_original 0.12175925925925928
# f1_score_original 0.1693548387096774
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.353921568627451
# precision_score_sog 0.2612411742846525
# f1_score_sog 0.29922480620155034
# neuron unit number: 12
# accuracy_score_orignial 0.5245901639344263
# recall_score_original 0.2901960784313726
# precision_score_original 0.18611746758199846
# f1_score_original 0.22100070472163494
# SOG Classficiation
# ...

# %%
#LinearDiscriminantAnalysis
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 30
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 5
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5573770491803278
# recall_score_sog 0.429708328792997
# precision_score_sog 0.4324016563146998
# f1_score_sog 0.42680471982797563
# Not good recall_score result !!!!!
# neuron unit number: 10
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# f1_score_original 0.4074381660106194
# SOG Classficiation
# accuracy_score_sog 0.5901639344262295
# recall_score_sog 0.44572663542915264
# precision_score_sog 0.42284909132735216
# f1_score_sog 0.42556494995519384
# Not good recall_score result !!!!!
# neuron unit number: 15
# accuracy_score_orignial 0.4918032786885246
# recall_score_original 0.44766989938614654
# precision_score_original 0.39259259259259255
# ...

# %%
#KNN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 50
class_num = 2
interval = 5

features = []
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.3770491803278688
# recall_score_original 0.36542264752791065
# precision_score_original 0.35238095238095235
# f1_score_original 0.35117548170179747
# SOG Classficiation
# accuracy_score_sog 0.3770491803278688
# recall_score_sog 0.36542264752791065
# precision_score_sog 0.35238095238095235
# f1_score_sog 0.35117548170179747
# neuron unit number: 7
# accuracy_score_orignial 0.3770491803278688
# recall_score_original 0.36542264752791065
# precision_score_original 0.35238095238095235
# f1_score_original 0.35117548170179747
# SOG Classficiation
# accuracy_score_sog 0.3770491803278688
# recall_score_sog 0.36542264752791065
# precision_score_sog 0.35238095238095235
# f1_score_sog 0.35117548170179747
# neuron unit number: 12
# accuracy_score_orignial 0.3770491803278688
# recall_score_original 0.36542264752791065
# precision_score_original 0.35238095238095235
# f1_score_original 0.35117548170179747
# SOG Classficiation
# ...

# %%
#SVM
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 200
class_num = 20
interval = 5
features =[]

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features)
# Out:
# neuron unit number: 20
# accuracy_score_orignial 0.3442622950819672
# recall_score_original 0.16666666666666666
# precision_score_original 0.05737704918032787
# f1_score_original 0.08536585365853659
# SOG Classficiation
# accuracy_score_sog 0.3442622950819672
# recall_score_sog 0.16666666666666666
# precision_score_sog 0.05737704918032787
# f1_score_sog 0.08536585365853659
# neuron unit number: 25
# accuracy_score_orignial 0.3442622950819672
# recall_score_original 0.16666666666666666
# precision_score_original 0.05737704918032787
# f1_score_original 0.08536585365853659
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[1,2]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.4533333333333333
# test_discrete_score_W_discrete_n 0.02234382538594245
# test_discrete_score_W_discrete_a 0.04032700754385205
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.436
# test_discrete_score_W_discrete_n 0.01861544301429128
# test_discrete_score_W_discrete_a 0.020695184137465707
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45066666666666666
# test_discrete_score_W0_n 0.01739318005978277
# test_discrete_score_W0_a 0.029175201704974632
# test_discrete_score_W_discrete_p 0.4533333333333333
# ...

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
# Out:
# neuron unit number: 5
# self.train_new_embedding_sog_fuzzy.shape[1] 20
# test_discrete_score_W0_p 0.416
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# test_discrete_score_W_discrete_p 0.428
# test_discrete_score_W_discrete_n 0.02345171762930623
# test_discrete_score_W_discrete_a 0.01923792963102035
# neuron unit number: 10
# self.train_new_embedding_sog_fuzzy.shape[1] 40
# test_discrete_score_W0_p 0.43066666666666664
# test_discrete_score_W0_n 0.018016176801237693
# test_discrete_score_W0_a 0.020038452303330002
# test_discrete_score_W_discrete_p 0.448
# test_discrete_score_W_discrete_n 0.018856935362735645
# test_discrete_score_W_discrete_a 0.029045041233303804
# neuron unit number: 15
# self.train_new_embedding_sog_fuzzy.shape[1] 60
# test_discrete_score_W0_p 0.45866666666666667
# test_discrete_score_W0_n 0.026855580654044465
# test_discrete_score_W0_a 0.03604144266742046
# test_discrete_score_W_discrete_p 0.452
# ...

# %%
# fuzzy vs baseN encoding DBSCAN
import experiment
unstable_repeat_num= 1
best_num =26
scope_num = 100
class_num = 5
interval = 5

features =[2,3]
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3,features)
