# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Airline Passenger Satisfaction/train.csv")
csv2 = pd.read_csv("Airline Passenger Satisfaction/test.csv")
csv = csv.drop(columns=['id'])
csv2 = csv2.drop(columns=['id'])   


dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"Gender")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"Customer Type")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"Type of Travel")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"Class")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"satisfaction")


dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"Gender")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"Customer Type")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"Type of Travel")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"Class")
dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"satisfaction")

csv_training = csv
csv_test = csv2



dataread.initializedataset(csv_training,csv_training,csv_test,"satisfaction")

# %%
import experiment
unstable_repeat_num= 30
scope_num = 200
class_num = 50
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
#experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# neuron unit number: 50
# train_discrete_score_W0_n 0.41963913968479055
# train_discrete_score_W0 0.5226028372522928
# test_discrete_score_W0_n 0.4126802541149887
# test_discrete_score_W0 0.5140124506971119
# train_discrete_score_W_discrete 0.31577341820516036
# train_discrete_score_W_discrete 0.405307965134006
# test_discrete_score_W_discrete 0.31536476702517235
# test_discrete_score_W_discrete 0.40116390076687625
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 55
# train_discrete_score_W0_n 0.4167328135451354
# train_discrete_score_W0 0.5249199394977374
# test_discrete_score_W0_n 0.415413908951536
# test_discrete_score_W0 0.5224733200390094
# train_discrete_score_W_discrete 0.31372281626014054
# train_discrete_score_W_discrete 0.4090373360887324
# test_discrete_score_W_discrete 0.3104549617962114
# test_discrete_score_W_discrete 0.4045796969338361
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 60
# train_discrete_score_W0_n 0.43381651206784044
# train_discrete_score_W0 0.5367298192058438
# test_discrete_score_W0_n 0.43400595480943516
# test_discrete_score_W0 0.5341773148195641
# train_discrete_score_W_discrete 0.3774051514037264
# train_discrete_score_W_discrete 0.4789793645261491
# test_discrete_score_W_discrete 0.37313821625418
# test_discrete_score_W_discrete 0.47170508396842215
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 65
# train_discrete_score_W0_n 0.4593477762163382
# train_discrete_score_W0 0.5661031699514206
# test_discrete_score_W0_n 0.4624660684304938
# test_discrete_score_W0 0.5678862539752312
# train_discrete_score_W_discrete 0.3196746364082704
# train_discrete_score_W_discrete 0.4166015111127664
# test_discrete_score_W_discrete 0.3174644294023772
# test_discrete_score_W_discrete 0.4124095013960766
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 70
# train_discrete_score_W0_n 0.37826577244796933
# train_discrete_score_W0 0.4832105271268228
# test_discrete_score_W0_n 0.36975917390796414
# test_discrete_score_W0 0.47250430769381996
# train_discrete_score_W_discrete 0.25404756139807255
# train_discrete_score_W_discrete 0.3382489687554985
# test_discrete_score_W_discrete 0.2479173794639472
# test_discrete_score_W_discrete 0.32894367269211516
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 75
# train_discrete_score_W0_n 0.4176185689431179
# train_discrete_score_W0 0.5139137608496286
# test_discrete_score_W0_n 0.41545986836204934
# test_discrete_score_W0 0.5099215175199431
# train_discrete_score_W_discrete 0.3269948540164865
# train_discrete_score_W_discrete 0.42302996828765616
# test_discrete_score_W_discrete 0.33145061967188955
# test_discrete_score_W_discrete 0.42639105952546047
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 80
# train_discrete_score_W0_n 0.42403416099136154
# train_discrete_score_W0 0.5306072053527103
# test_discrete_score_W0_n 0.4269872915043672
# test_discrete_score_W0 0.5322483741480459
# train_discrete_score_W_discrete 0.3918789007086491
# train_discrete_score_W_discrete 0.49449166172706355
# test_discrete_score_W_discrete 0.3911376721403276
# test_discrete_score_W_discrete 0.49028990120322913
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# train_discrete_score_W0_n 0.42084830527526446
# train_discrete_score_W0 0.5295173165332332
# test_discrete_score_W0_n 0.4103160172047368
# test_discrete_score_W0 0.5166865937081287
# train_discrete_score_W_discrete 0.30587394563791886
# train_discrete_score_W_discrete 0.3965897978664918
# test_discrete_score_W_discrete 0.2974169408838246
# test_discrete_score_W_discrete 0.3837531396191327
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 90
# train_discrete_score_W0_n 0.4277462980537488
# train_discrete_score_W0 0.5305646969752508
# test_discrete_score_W0_n 0.4198696871109891
# test_discrete_score_W0 0.520875104926311
# train_discrete_score_W_discrete 0.31838838241359413
# train_discrete_score_W_discrete 0.4137565433584501
# test_discrete_score_W_discrete 0.3117894453154895
# test_discrete_score_W_discrete 0.4046539596410808
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# train_discrete_score_W0_n 0.4523097003609876
# train_discrete_score_W0 0.5626128204440767
# test_discrete_score_W0_n 0.44102451551029415
# test_discrete_score_W0 0.549418157274411
# train_discrete_score_W_discrete 0.3054684206841643
# train_discrete_score_W_discrete 0.40039917511525125
# test_discrete_score_W_discrete 0.30429175727079494
# test_discrete_score_W_discrete 0.39777371410913653
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# train_discrete_score_W0_n 0.3953338590108557
# train_discrete_score_W0 0.5012421999401991
# test_discrete_score_W0_n 0.38582113111469474
# test_discrete_score_W0 0.48956479280242965
# train_discrete_score_W_discrete 0.35531228282453875
# train_discrete_score_W_discrete 0.44754287083520783
# test_discrete_score_W_discrete 0.3451151953311154
# test_discrete_score_W_discrete 0.4338639009081729
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 105
# train_discrete_score_W0_n 0.45954577802519136
# train_discrete_score_W0 0.5625577497861898
# test_discrete_score_W0_n 0.45403627411759323
# test_discrete_score_W0 0.5551190568306572
# train_discrete_score_W_discrete 0.37304384438782523
# train_discrete_score_W_discrete 0.46050580023197313
# test_discrete_score_W_discrete 0.3655180705010757
# test_discrete_score_W_discrete 0.4479559227877927
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 110
# train_discrete_score_W0_n 0.4262510656312532
# train_discrete_score_W0 0.5307163160444726
# test_discrete_score_W0_n 0.41710951369623506
# test_discrete_score_W0 0.518438518462153
# train_discrete_score_W_discrete 0.36947309863243594
# train_discrete_score_W_discrete 0.47214790553998837
# test_discrete_score_W_discrete 0.37405136522725313
# test_discrete_score_W_discrete 0.47675196150634463
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 115
# train_discrete_score_W0_n 0.43937779182114195
# train_discrete_score_W0 0.5481681825294156
# test_discrete_score_W0_n 0.44007329187551764
# test_discrete_score_W0 0.547453382509807
# train_discrete_score_W_discrete 0.3064506562127343
# train_discrete_score_W_discrete 0.40000359415049225
# test_discrete_score_W_discrete 0.3033361286707754
# test_discrete_score_W_discrete 0.3939884661811013
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 120
# train_discrete_score_W0_n 0.4411850768150485
# train_discrete_score_W0 0.5483765715719598
# test_discrete_score_W0_n 0.4357576066209834
# test_discrete_score_W0 0.5412775555951785
# train_discrete_score_W_discrete 0.3340793836609905
# train_discrete_score_W_discrete 0.43035241526000007
# test_discrete_score_W_discrete 0.32989325703577244
# test_discrete_score_W_discrete 0.42312190779978986
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 125
# train_discrete_score_W0_n 0.45671676528618493
# train_discrete_score_W0 0.5642674975875251
# test_discrete_score_W0_n 0.4557900254025965
# test_discrete_score_W0 0.5618763536212958
# train_discrete_score_W_discrete 0.3621352179378927
# train_discrete_score_W_discrete 0.4616122972182874
# test_discrete_score_W_discrete 0.36439538680498385
# test_discrete_score_W_discrete 0.4619018744989764
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 130
# train_discrete_score_W0_n 0.4526728355437482
# train_discrete_score_W0 0.5621814008685208
# test_discrete_score_W0_n 0.44698507312195185
# test_discrete_score_W0 0.5547767165851001
# train_discrete_score_W_discrete 0.34031627886625865
# train_discrete_score_W_discrete 0.43339748063268324
# test_discrete_score_W_discrete 0.3332980420624602
# test_discrete_score_W_discrete 0.4231111618597757
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 135
# train_discrete_score_W0_n 0.4420527375356351
# train_discrete_score_W0 0.5529445170443128
# test_discrete_score_W0_n 0.4363043343624545
# test_discrete_score_W0 0.545842781859752
# train_discrete_score_W_discrete 0.35765688559741265
# train_discrete_score_W_discrete 0.4471026885479911
# test_discrete_score_W_discrete 0.3548951762851533
# test_discrete_score_W_discrete 0.43978465934809463
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 140
# train_discrete_score_W0_n 0.45117589329198016
# train_discrete_score_W0 0.5626403938836726
# test_discrete_score_W0_n 0.4444490750479926
# test_discrete_score_W0 0.5545202259785438
# train_discrete_score_W_discrete 0.39614344552713443
# train_discrete_score_W_discrete 0.5024038163097972
# test_discrete_score_W_discrete 0.39157038494453894
# test_discrete_score_W_discrete 0.4958375471990484
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 145
# train_discrete_score_W0_n 0.45978267586207633
# train_discrete_score_W0 0.5661530893242404
# test_discrete_score_W0_n 0.4544965321164093
# test_discrete_score_W0 0.560020469991844
# train_discrete_score_W_discrete 0.3511825618385579
# train_discrete_score_W_discrete 0.4498885469102091
# test_discrete_score_W_discrete 0.3360093418407725
# test_discrete_score_W_discrete 0.4304932429596223
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 150
# train_discrete_score_W0_n 0.4376423042030635
# train_discrete_score_W0 0.5454039609666471
# test_discrete_score_W0_n 0.4340688285425391
# test_discrete_score_W0 0.5402737596825815
# train_discrete_score_W_discrete 0.37388542738676955
# train_discrete_score_W_discrete 0.474649462923655
# test_discrete_score_W_discrete 0.366759488737904
# test_discrete_score_W_discrete 0.46539086496172904
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 155
# train_discrete_score_W0_n 0.43442309765563797
# train_discrete_score_W0 0.5378999101899827
# test_discrete_score_W0_n 0.43217273689125835
# test_discrete_score_W0 0.5318059930427645
# train_discrete_score_W_discrete 0.36908742562472224
# train_discrete_score_W_discrete 0.4674934971997764
# test_discrete_score_W_discrete 0.36969224690930164
# test_discrete_score_W_discrete 0.4652009605163228
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 160
# train_discrete_score_W0_n 0.44707532439987435
# train_discrete_score_W0 0.5564505062790411
# test_discrete_score_W0_n 0.4436156462734241
# test_discrete_score_W0 0.5514580815602383
# train_discrete_score_W_discrete 0.3481902937305116
# train_discrete_score_W_discrete 0.44658543459531114
# test_discrete_score_W_discrete 0.3459005024968255
# test_discrete_score_W_discrete 0.4414880899526886
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 165
# train_discrete_score_W0_n 0.46605283912584045
# train_discrete_score_W0 0.5688160340107443
# test_discrete_score_W0_n 0.461752946338462
# test_discrete_score_W0 0.563075168436199
# train_discrete_score_W_discrete 0.3949271233733138
# train_discrete_score_W_discrete 0.49994940417408623
# test_discrete_score_W_discrete 0.39067195447454145
# test_discrete_score_W_discrete 0.49318260705505157
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 170
# train_discrete_score_W0_n 0.45737395752102245
# train_discrete_score_W0 0.5657937057398886
# test_discrete_score_W0_n 0.45427916353877384
# test_discrete_score_W0 0.5615524043097433
# train_discrete_score_W_discrete 0.3966567383698202
# train_discrete_score_W_discrete 0.5031529985233649
# test_discrete_score_W_discrete 0.39384252152294263
# test_discrete_score_W_discrete 0.49867719919560427
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 175
# train_discrete_score_W0_n 0.46214723799608093
# train_discrete_score_W0 0.5716585446090332
# test_discrete_score_W0_n 0.4625517725965719
# test_discrete_score_W0 0.5707246014353841
# train_discrete_score_W_discrete 0.4067396097044979
# train_discrete_score_W_discrete 0.5128436904133609
# test_discrete_score_W_discrete 0.4035309246443031
# test_discrete_score_W_discrete 0.5079265852407455
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 180
# train_discrete_score_W0_n 0.47058947000417795
# train_discrete_score_W0 0.5798027809794097
# test_discrete_score_W0_n 0.464480591669105
# test_discrete_score_W0 0.5718230549726302
# train_discrete_score_W_discrete 0.3362415764062787
# train_discrete_score_W_discrete 0.43441618479097055
# test_discrete_score_W_discrete 0.3301409872912277
# test_discrete_score_W_discrete 0.4254041921060959
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 185
# train_discrete_score_W0_n 0.45733860908333634
# train_discrete_score_W0 0.5675248163790467
# test_discrete_score_W0_n 0.4463979934788983
# test_discrete_score_W0 0.5550275445056556
# train_discrete_score_W_discrete 0.3754367307348802
# train_discrete_score_W_discrete 0.47077474944776415
# test_discrete_score_W_discrete 0.369163576258678
# test_discrete_score_W_discrete 0.4604958171302315
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 190
# train_discrete_score_W0_n 0.4496768763639166
# train_discrete_score_W0 0.5566127539002583
# test_discrete_score_W0_n 0.4514752099481869
# test_discrete_score_W0 0.5566766240976713
# train_discrete_score_W_discrete 0.3656376261710349
# train_discrete_score_W_discrete 0.4634861369308298
# test_discrete_score_W_discrete 0.3631320213642372
# test_discrete_score_W_discrete 0.45764796502992844
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 195
# train_discrete_score_W0_n 0.4784823771456651
# train_discrete_score_W0 0.5862131099086827
# test_discrete_score_W0_n 0.48004047305639613
# test_discrete_score_W0 0.586036759447345
# train_discrete_score_W_discrete 0.40491793695618267
# train_discrete_score_W_discrete 0.5088081231755884
# test_discrete_score_W_discrete 0.40245392513054407
# test_discrete_score_W_discrete 0.5046935327517986
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 200
# train_discrete_score_W0_n 0.44965923939399577
# train_discrete_score_W0 0.5598421868645486
# test_discrete_score_W0_n 0.44494645383384795
# test_discrete_score_W0 0.5533016325337036
# train_discrete_score_W_discrete 0.34349890249491477
# train_discrete_score_W_discrete 0.4326851761131688
# test_discrete_score_W_discrete 0.33656224623436554
# test_discrete_score_W_discrete 0.42322583234298666
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.441449  0.022007  0.003953   0.433377  0.449521
# 1  train_dis_W_dis  31.0  0.351298  0.035840  0.006437   0.338152  0.364444
# 2         combined  62.0  0.396373  0.054176  0.006880   0.382615  0.410132
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0902
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   11.9345
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    1.0000
# 5                       Difference > 0 p value =    0.0000
# 6                                    Cohen's d =    3.0314
# 7                                    Hedge's g =    2.9933
# 8                                Glass's delta =    4.0965
# 9                                  Pearson's r =    0.8388
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.437245  0.023495  0.004220   0.428627  0.445863
# 1  test_dis_W_dis  31.0  0.347431  0.036413  0.006540   0.334075  0.360787
# 2        combined  62.0  0.392338  0.054527  0.006925   0.378490  0.406185
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0898
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   11.5396
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    2.9311
# 7                                  Hedge's g =    2.8943
# 8                              Glass's delta =    3.8228
# 9                                Pearson's r =    0.8303
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  31.0  0.548260  0.023409  0.004204   0.539673  0.556846
# 1  train_dis_W_dis  31.0  0.448266  0.040343  0.007246   0.433468  0.463064
# 2         combined  62.0  0.498263  0.060088  0.007631   0.483003  0.513522
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.1000
# 1                           Degrees of freedom =   60.0000
# 2                                            t =   11.9363
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    1.0000
# 5                       Difference > 0 p value =    0.0000
# 6                                    Cohen's d =    3.0318
# 7                                    Hedge's g =    2.9938
# 8                                Glass's delta =    4.2715
# 9                                  Pearson's r =    0.8388
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  31.0  0.542285  0.024993  0.004489   0.533118  0.551453
# 1  test_dis_W_dis  31.0  0.441671  0.041268  0.007412   0.426534  0.456809
# 2        combined  62.0  0.491978  0.060968  0.007743   0.476495  0.507461
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.1006
# 1                         Degrees of freedom =   60.0000
# 2                                          t =   11.6111
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    1.0000
# 5                     Difference > 0 p value =    0.0000
# 6                                  Cohen's d =    2.9492
# 7                                  Hedge's g =    2.9122
# 8                              Glass's delta =    4.0256
# 9                                Pearson's r =    0.8319
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
