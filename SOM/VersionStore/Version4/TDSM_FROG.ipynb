# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import warnings
import collections
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("FrogCall/Frogs_MFCCs.csv")
csv = csv.drop(columns=['Family', 'Genus','RecordID'])
dataread.stringToIntFrogCallDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset_frog(csv_training,csv_test)

# %%
scoretype = 0
scope_num = 1
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 10
# *******************
#
# error_data0_score_W1 0.6558303886925795
# error_data0_score_W0 0.5067137809187279
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 0.5626283367556468
# error_data1_score_W0 0.5420944558521561
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.5754310344827587
# Finish one round splitting 1 *********
#
# error_data2_score_W1 0.7276995305164319
# error_data2_score_W0 0.43661971830985913
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.7335766423357665
# Finish one round splitting 2 *********
#
# error_data3_score_W1 0.603448275862069
# error_data3_score_W0 0.4482758620689655
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.632258064516129
# Finish one round splitting 3 *********
#
# error_data4_score_W1 0.6956521739130435
# error_data4_score_W0 0.5652173913043478
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.6857142857142857
# Finish one round splitting 4 *********
#
# error_data5_score_W1 0.8571428571428571
# error_data5_score_W0 0.5714285714285714
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.625
# Finish one round splitting 5 *********
#
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.6666666666666666
# Finish one round splitting 6 *********
#
#  NO Error Data, Finish Training!
# total split_number 6
# stop_split_num 0
# predicted 2: [2 2 5 ... 4 2 4]
# predicted 2: [1 1 7 ... 5 4 9]
# all_train_score_W' split_num : 0 0.7190788167560056
# test_score_W': split_num : 0 0.7284522706209453
# stop_split_num 1
# predicted 2: [2 2 5 ... 4 2 4]
# predicted 2: [12  1 17 ...  5  4 19]
# all_train_score_W' split_num : 1 0.9033154655548938
# test_score_W': split_num : 1 0.9003707136237257
# stop_split_num 2
# predicted 2: [ 2  2  5 ...  4 29  4]
# predicted 2: [12  1 17 ...  5  4 19]
# all_train_score_W' split_num : 2 0.957712924359738
# test_score_W': split_num : 2 0.9462465245597775
# stop_split_num 3
# predicted 2: [ 2  2  5 ...  4 29  4]
# predicted 2: [12  1 17 ...  5  4 19]
# all_train_score_W' split_num : 3 0.9884852094500695
# test_score_W': split_num : 3 0.9712696941612604
# stop_split_num 4
# predicted 2: [ 2  2  5 ...  4 29  4]
# predicted 2: [12  1 17 ...  5  4 19]
# all_train_score_W' split_num : 4 0.9954337899543378
# test_score_W': split_num : 4 0.9712696941612604
# stop_split_num 5
# predicted 2: [ 2  2  5 ...  4 29  4]
# predicted 2: [12  1 17 ...  5  4 19]
# all_train_score_W' split_num : 5 0.9986102838991463
# test_score_W': split_num : 5 0.9726598702502317
# stop_split_num 6

# %%
scoretype = 0
scope_num = 1
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 10
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6109563602599815
# error_data0_score_W0 0.4828226555246054
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5465393794749404
# error_data1_score_W0 0.5107398568019093
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.7127659574468085
# Finish one round splitting 1 *********
#
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5105263157894737
# error_data2_score_W0 0.4
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.6768558951965066
# Finish one round splitting 2 *********
#
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6344086021505376
# error_data3_score_W0 0.5591397849462365
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.6288659793814433
# Finish one round splitting 3 *********
#
# right_data4_score_W0 1.0
# error_data4_score_W1 0.6176470588235294
# error_data4_score_W0 0.5
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.5423728813559322
# Finish one round splitting 4 *********
#
# right_data5_score_W0 1.0
# error_data5_score_W1 0.7692307692307693
# error_data5_score_W0 0.5384615384615384
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.5238095238095238
# Finish one round splitting 5 *********
#
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.7
# Finish one round splitting 6 *********
#
#  NO Error Data, Finish Training!
# total split_number 7
# stop_split_num 0
# all_train_score_W' split_num : 0 0.7861822513400833
# test_score_W': split_num : 0 0.773401297497683
# stop_split_num 1
# all_train_score_W' split_num : 1 0.9168155648203296
# test_score_W': split_num : 1 0.8994439295644114
# stop_split_num 2
# all_train_score_W' split_num : 2 0.9622791344054
# test_score_W': split_num : 2 0.93790546802595
# stop_split_num 3
# all_train_score_W' split_num : 3 0.9815366289458011
# test_score_W': split_num : 3 0.9541241890639481
# stop_split_num 4
# all_train_score_W' split_num : 4 0.9932499503672821
# test_score_W': split_num : 4 0.9633920296570899
# stop_split_num 5
# all_train_score_W' split_num : 5 0.9974190986698431
# test_score_W': split_num : 5 0.9657089898053753
# stop_split_num 6
# all_train_score_W' split_num : 6 0.9994044073853484
# test_score_W': split_num : 6 0.9661723818350324
# stop_split_num 7
# all_train_score_W' split_num : 7 1.0
# test_score_W': split_num : 7 0.9675625579240037

# %%
scoretype = 0
scope_num = 1
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 10
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6071713147410358
# error_data0_score_W0 0.5211155378486055
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9888947646747752
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5679513184584178
# error_data1_score_W0 0.4300202839756592
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.7729658792650919
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6244131455399061
# error_data2_score_W0 0.5070422535211268
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.7464285714285714
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4875
# error_data3_score_W0 0.4875
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.7368421052631579
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5853658536585366
# error_data4_score_W0 0.4878048780487805
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.8974358974358975
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.7647058823529411
# error_data5_score_W0 0.5882352941176471
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.7916666666666666
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.75
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.6923076923076923
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# Split_Data[i] 0 83204
# ...
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# Split_Data[i] 0 83204
# Split_Data[i] 1 16764
# Split_Data[i] 2 6160
# Split_Data[i] 3 2926
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 26>()
#      32     som = newSom.SOM(m= class_num, n= x, dim=dim_num)
#      33     optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
# ---> 34     optimize_W.run(scoretype)
#      35     x=x+1
#      36 y =y+1
#
# File C:\JupyterDoc\SOM\TDSM_SOM.py:588, in TDSM_SOM.run(self, score_type)
#     585 unit_list.append(stop_split_num)
#     587 #self.all_train_W_combined_winW_indexes_labels,self.all_train_W_combined_predicted_label = self.som.predict_among_nearestW_representedData(self.data_train,stop_split_num,self.weights)
# --> 588 self.all_train_W_combined_winW_indexes_labels, self.all_train_W_combined_predicted_label = self.som.predict_among_multipleW(self.data_train,stop_split_num,self.split_train_data,self.weights)
#     590 normalized_predicted_label = self.NormalizeLables(self.all_train_W_combined_winW_indexes_labels,self.all_train_W_combined_predicted_label,category = 0, Wtype= 2,train_counter = current_train_counter )
#     591 self.getScore("all_train_score_W_Combined",self.label_train,normalized_predicted_label,score_type)
#
# File C:\JupyterDoc\SOM\newSom.py:392, in SOM.predict_among_multipleW(self, X, stop_split_num, Train_Split_Data, weights)
#     390 i = 0
#     391 for x in X:
# --> 392     a,b = self._find_bmu_among_multipleW(x,stop_split_num,Train_Split_Data,weights)
#     393     winWindexlabels.append(a)
#     394     labels.append(b)
#
# File C:\JupyterDoc\SOM\newSom.py:144, in SOM._find_bmu_among_multipleW(self, x, stop_split_num, Split_Data, Weights)
#     141 tree = spatial.KDTree(Split_Data[i])
#     142 #print("i {}".format(i))
#     143 #print("Train_Split_Data[i] {}".format(Train_Split_Data[i]))
# --> 144 currentdistance = tree.query(x)[0]
#     145 nearestDataindex = tree.query(x)[1]
#     146 #print("nearestDataindex {}".format(nearestDataindex))
#
# File ~\anaconda3\lib\site-packages\scipy\spatial\kdtree.py:483, in KDTree.query(self, x, k, eps, p, distance_upper_bound, workers)
#     479         dists[idx], inds[idx] = inds_to_hits(x[idx], inds[idx])
#     481     return dists, inds
# --> 483 d, i = super().query(x, k, eps, p, distance_upper_bound, workers)
#     484 if isinstance(i, int):
#     485     i = np.intp(i)
#
# File ckdtree.pyx:833, in scipy.spatial.ckdtree.cKDTree.query()
#
# File <__array_function__ internals>:2, in reshape(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
scoretype = 0
scope_num = 30
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 10
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.546160483175151
# error_data0_score_W0 0.32786885245901637
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9515214027849407
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6083650190114068
# error_data1_score_W0 0.4524714828897338
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.8909952606635071
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5970873786407767
# error_data2_score_W0 0.4563106796116505
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.753125
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.42168674698795183
# error_data3_score_W0 0.3253012048192771
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.6991869918699187
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.6875
# error_data4_score_W0 0.3958333333333333
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.8857142857142857
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.6666666666666666
# error_data5_score_W0 0.5333333333333333
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.7272727272727273
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.6
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.7
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W' split_num : 0 0.7699027198729402
# test_score_W': split_num : 0 0.7845227062094532
# all_train_score_W' split_num : 1 0.8955727615644232
# test_score_W': split_num : 1 0.892029657089898
# all_train_score_W' split_num : 2 0.9591026404605916
# test_score_W': split_num : 2 0.9453197405004634
# all_train_score_W' split_num : 3 0.9835219376613064
# test_score_W': split_num : 3 0.9615384615384616
# all_train_score_W' split_num : 4 0.9904705181655747
# test_score_W': split_num : 4 0.9647822057460612
# all_train_score_W' split_num : 5 0.9970220369267421
# test_score_W': split_num : 5 0.9670991658943466
# all_train_score_W' split_num : 6 0.9990073456422474
# test_score_W': split_num : 6 0.9670991658943466
# all_train_score_W' split_num : 7 1.0
# test_score_W': split_num : 7 0.9675625579240037
# neuron unit number: 20
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6791383219954649
# error_data0_score_W0 0.42630385487528344
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9768953068592058
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5971731448763251
# error_data1_score_W0 0.5229681978798587
# combinedweight shape1 : (60, 22)
# right_data1_score_W' 0.8731218697829716
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7192982456140351
# error_data2_score_W0 0.4298245614035088
# combinedweight shape1 : (80, 22)
# right_data2_score_W' 0.8224852071005917
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.71875
# error_data3_score_W0 0.375
# combinedweight shape1 : (100, 22)
# right_data3_score_W' 0.7926829268292683
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.7777777777777778
# error_data4_score_W0 0.5555555555555556
# combinedweight shape1 : (120, 22)
# right_data4_score_W' 0.8260869565217391
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 0.5
# combinedweight shape1 : (140, 22)
# right_data5_score_W' 1.0
# Finish one splitting *********
# 6
#  NO Error Data, Finish Training!
# split_num 6
# all_train_score_W' split_num : 0 0.824895771292436
# test_score_W': split_num : 0 0.8345690454124189
# all_train_score_W' split_num : 1 0.9438157633512011
# test_score_W': split_num : 1 0.932808155699722
# all_train_score_W' split_num : 2 0.97736748064324
# test_score_W': split_num : 2 0.9476367006487488
# all_train_score_W' split_num : 3 0.9936470121103832
# test_score_W': split_num : 3 0.9620018535681186
# all_train_score_W' split_num : 4 0.9982132221560452
# test_score_W': split_num : 4 0.9652455977757183
# all_train_score_W' split_num : 5 0.9996029382568989
# test_score_W': split_num : 5 0.9657089898053753
# all_train_score_W' split_num : 6 1.0
# test_score_W': split_num : 6 0.9657089898053753
# neuron unit number: 30
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5990453460620525
# error_data0_score_W0 0.4343675417661098
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9635627530364372
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7529761904761905
# error_data1_score_W0 0.39880952380952384
# combinedweight shape1 : (90, 22)
# right_data1_score_W' 0.7529880478087649
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7228915662650602
# error_data2_score_W0 0.39759036144578314
# combinedweight shape1 : (120, 22)
# right_data2_score_W' 0.6758893280632411
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9565217391304348
# error_data3_score_W0 0.6086956521739131
# combinedweight shape1 : (150, 22)
# right_data3_score_W' 0.6833333333333333
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (180, 22)
# right_data4_score_W' 0.7727272727272727
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W' split_num : 0 0.8336311296406591
# test_score_W': split_num : 0 0.8535681186283596
# all_train_score_W' split_num : 1 0.9332936271590232
# test_score_W': split_num : 1 0.9249304911955515
# all_train_score_W' split_num : 2 0.9835219376613064
# test_score_W': split_num : 2 0.9541241890639481
# all_train_score_W' split_num : 3 0.9954337899543378
# test_score_W': split_num : 3 0.9596848934198332
# all_train_score_W' split_num : 4 0.9998014691284495
# test_score_W': split_num : 4 0.9596848934198332
# all_train_score_W' split_num : 5 1.0
# test_score_W': split_num : 5 0.9596848934198332
# neuron unit number: 40
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7294303797468354
# error_data0_score_W0 0.5126582278481012
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9262202043132803
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7719298245614035
# error_data1_score_W0 0.40350877192982454
# combinedweight shape1 : (120, 22)
# right_data1_score_W' 0.8720173535791758
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8461538461538461
# error_data2_score_W0 0.48717948717948717
# combinedweight shape1 : (160, 22)
# right_data2_score_W' 0.6893939393939394
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.8333333333333334
# combinedweight shape1 : (200, 22)
# right_data3_score_W' 0.7575757575757576
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W' split_num : 0 0.8745284891800675
# test_score_W': split_num : 0 0.8836886005560705
# all_train_score_W' split_num : 1 0.9660512209648601
# test_score_W': split_num : 1 0.9504170528266914
# all_train_score_W' split_num : 2 0.9922572960095295
# test_score_W': split_num : 2 0.964318813716404
# all_train_score_W' split_num : 3 0.9988088147706968
# test_score_W': split_num : 3 0.9670991658943466
# all_train_score_W' split_num : 4 1.0
# test_score_W': split_num : 4 0.9675625579240037
# neuron unit number: 50
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.781786941580756
# error_data0_score_W0 0.47594501718213056
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9506172839506173
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8031496062992126
# error_data1_score_W0 0.3464566929133858
# combinedweight shape1 : (150, 22)
# right_data1_score_W' 0.8923076923076924
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.48
# combinedweight shape1 : (200, 22)
# right_data2_score_W' 0.7647058823529411
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8844550327575939
# test_score_W': split_num : 0 0.8887859128822985
# all_train_score_W' split_num : 1 0.9747865793130832
# test_score_W': split_num : 1 0.9513438368860055
# all_train_score_W' split_num : 2 0.9950367282112369
# test_score_W': split_num : 2 0.9615384615384616
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.964318813716404
# neuron unit number: 60
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7816764132553606
# error_data0_score_W0 0.52046783625731
# combinedweight shape 0: (120, 22)
# right_data0_score_W' 0.9515915119363395
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8125
# error_data1_score_W0 0.39285714285714285
# combinedweight shape1 : (180, 22)
# right_data1_score_W' 0.8104738154613467
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5714285714285714
# combinedweight shape1 : (240, 22)
# right_data2_score_W' 0.8571428571428571
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8981536628945801
# test_score_W': split_num : 0 0.8999073215940686
# all_train_score_W' split_num : 1 0.977764542386341
# test_score_W': split_num : 1 0.9541241890639481
# all_train_score_W' split_num : 2 0.9958308516974389
# test_score_W': split_num : 2 0.9629286376274329
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9633920296570899
# neuron unit number: 70
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8362068965517241
# error_data0_score_W0 0.5301724137931034
# combinedweight shape 0: (140, 22)
# right_data0_score_W' 0.9748523944893943
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9210526315789473
# error_data1_score_W0 0.3815789473684211
# combinedweight shape1 : (210, 22)
# right_data1_score_W' 0.7783505154639175
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.8333333333333334
# combinedweight shape1 : (280, 22)
# right_data2_score_W' 0.7428571428571429
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9078816756005559
# test_score_W': split_num : 0 0.9184430027803522
# all_train_score_W' split_num : 1 0.98491165376216
# test_score_W': split_num : 1 0.9601482854494903
# all_train_score_W' split_num : 2 0.9988088147706968
# test_score_W': split_num : 2 0.9615384615384616
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9624652455977757
# neuron unit number: 80
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8299492385786802
# error_data0_score_W0 0.467005076142132
# combinedweight shape 0: (160, 22)
# right_data0_score_W' 0.9720008615119535
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8955223880597015
# error_data1_score_W0 0.417910447761194
# combinedweight shape1 : (240, 22)
# right_data1_score_W' 0.7828746177370031
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.7142857142857143
# combinedweight shape1 : (320, 22)
# right_data2_score_W' 0.8
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9217788366090928
# test_score_W': split_num : 0 0.9291010194624653
# all_train_score_W' split_num : 1 0.9866984316061147
# test_score_W': split_num : 1 0.9601482854494903
# all_train_score_W' split_num : 2 0.9986102838991463
# test_score_W': split_num : 2 0.9657089898053753
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9666357738646896
# neuron unit number: 90
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8493975903614458
# error_data0_score_W0 0.5602409638554217
# combinedweight shape 0: (180, 22)
# right_data0_score_W' 0.9421891604675877
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9
# error_data1_score_W0 0.46
# combinedweight shape1 : (270, 22)
# right_data1_score_W' 0.8262411347517731
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (360, 22)
# right_data2_score_W' 0.8444444444444444
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9340877506452253
# test_score_W': split_num : 0 0.9212233549582948
# all_train_score_W' split_num : 1 0.9900734564224737
# test_score_W': split_num : 1 0.9596848934198332
# all_train_score_W' split_num : 2 0.9990073456422474
# test_score_W': split_num : 2 0.9647822057460612
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9657089898053753
# neuron unit number: 100
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8619718309859155
# error_data0_score_W0 0.49859154929577465
# combinedweight shape 0: (200, 22)
# right_data0_score_W' 0.9455360956856045
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9591836734693877
# error_data1_score_W0 0.4897959183673469
# combinedweight shape1 : (300, 22)
# right_data1_score_W' 0.8366013071895425
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (400, 22)
# right_data2_score_W' 0.7872340425531915
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9295215405995633
# test_score_W': split_num : 0 0.9286376274328082
# all_train_score_W' split_num : 1 0.9902719872940242
# test_score_W': split_num : 1 0.958758109360519
# all_train_score_W' split_num : 2 0.9996029382568989
# test_score_W': split_num : 2 0.9624652455977757
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9629286376274329
# neuron unit number: 110
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8549618320610687
# error_data0_score_W0 0.5776081424936387
# combinedweight shape 0: (220, 22)
# right_data0_score_W' 0.9683462532299741
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9473684210526315
# error_data1_score_W0 0.42105263157894735
# combinedweight shape1 : (330, 22)
# right_data1_score_W' 0.8035714285714286
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (440, 22)
# right_data2_score_W' 0.7407407407407407
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9219773674806433
# test_score_W': split_num : 0 0.9314179796107507
# all_train_score_W' split_num : 1 0.98868374032162
# test_score_W': split_num : 1 0.9670991658943466
# all_train_score_W' split_num : 2 0.9994044073853484
# test_score_W': split_num : 2 0.968952734012975
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.968952734012975
# neuron unit number: 120
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8795986622073578
# error_data0_score_W0 0.5050167224080268
# combinedweight shape 0: (240, 22)
# right_data0_score_W' 0.9772055719712959
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9166666666666666
# error_data1_score_W0 0.4722222222222222
# combinedweight shape1 : (360, 22)
# right_data1_score_W' 0.752851711026616
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (480, 22)
# right_data2_score_W' 0.7878787878787878
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9406392694063926
# test_score_W': split_num : 0 0.9439295644114921
# all_train_score_W' split_num : 1 0.9928528886241811
# test_score_W': split_num : 1 0.9620018535681186
# all_train_score_W' split_num : 2 0.9994044073853484
# test_score_W': split_num : 2 0.9666357738646896
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9666357738646896
# neuron unit number: 130
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8419354838709677
# error_data0_score_W0 0.5645161290322581
# combinedweight shape 0: (260, 22)
# right_data0_score_W' 0.965728792045695
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9183673469387755
# error_data1_score_W0 0.42857142857142855
# combinedweight shape1 : (390, 22)
# right_data1_score_W' 0.8314176245210728
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.75
# combinedweight shape1 : (520, 22)
# right_data2_score_W' 0.7333333333333333
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9384554298193369
# test_score_W': split_num : 0 0.9443929564411492
# all_train_score_W' split_num : 1 0.9902719872940242
# test_score_W': split_num : 1 0.968952734012975
# all_train_score_W' split_num : 2 0.9992058765137979
# test_score_W': split_num : 2 0.9712696941612604
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9712696941612604
# neuron unit number: 140
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8737864077669902
# error_data0_score_W0 0.511326860841424
# combinedweight shape 0: (280, 22)
# right_data0_score_W' 0.9729272419627749
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9230769230769231
# error_data1_score_W0 0.41025641025641024
# combinedweight shape1 : (420, 22)
# right_data1_score_W' 0.8148148148148148
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (560, 22)
# right_data2_score_W' 0.8333333333333334
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9386539606908875
# test_score_W': split_num : 0 0.9425393883225208
# all_train_score_W' split_num : 1 0.9922572960095295
# test_score_W': split_num : 1 0.9666357738646896
# all_train_score_W' split_num : 2 0.9994044073853484
# test_score_W': split_num : 2 0.9698795180722891
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9698795180722891
# neuron unit number: 150
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9133333333333333
# error_data0_score_W0 0.5533333333333333
# combinedweight shape 0: (300, 22)
# right_data0_score_W' 0.9679121807050876
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (450, 22)
# right_data1_score_W' 0.7554744525547445
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9404407385348421
# test_score_W': split_num : 0 0.9406858202038925
# all_train_score_W' split_num : 1 0.9948381973396864
# test_score_W': split_num : 1 0.969416126042632
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9712696941612604
# neuron unit number: 160
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9133574007220217
# error_data0_score_W0 0.5884476534296029
# combinedweight shape 0: (320, 22)
# right_data0_score_W' 0.9628151260504202
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5416666666666666
# combinedweight shape1 : (480, 22)
# right_data1_score_W' 0.8063241106719368
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9450069485805043
# test_score_W': split_num : 0 0.943466172381835
# all_train_score_W' split_num : 1 0.9952352590827874
# test_score_W': split_num : 1 0.9670991658943466
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9680259499536608
# neuron unit number: 170
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9363295880149812
# error_data0_score_W0 0.5243445692883895
# combinedweight shape 0: (340, 22)
# right_data0_score_W' 0.9570230607966457
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9411764705882353
# error_data1_score_W0 0.47058823529411764
# combinedweight shape1 : (510, 22)
# right_data1_score_W' 0.7
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (680, 22)
# right_data2_score_W' 0.9375
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9469922572960096
# test_score_W': split_num : 0 0.9476367006487488
# all_train_score_W' split_num : 1 0.996624975183641
# test_score_W': split_num : 1 0.968952734012975

# %%
scoretype = 1
scope_num = 30
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 10
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5131098193071707
# error_data0_score_W0 0.41365538829168075
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8048430248374389
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4702199469652991
# error_data1_score_W0 0.429571460267093
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.8083567745575764
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.426600183731176
# error_data2_score_W0 0.37713496506533534
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.6586651584093336
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4473585170666792
# error_data3_score_W0 0.3363708915072397
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.721940745345981
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.6077357943522618
# error_data4_score_W0 0.5356483247704904
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.6487734041917722
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.8608651935223532
# error_data5_score_W0 0.6154542889604809
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.6342191934595565
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.7336804366512112
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.7002218142590879
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W' split_num : 0 0.6445403919140097
# test_score_W': split_num : 0 0.6616029199892376
# all_train_score_W' split_num : 1 0.8105846048165313
# test_score_W': split_num : 1 0.7874912799385794
# all_train_score_W' split_num : 2 0.9019267856389531
# test_score_W': split_num : 2 0.8582447971886493
# all_train_score_W' split_num : 3 0.9401857842716437
# test_score_W': split_num : 3 0.8801780810416406
# all_train_score_W' split_num : 4 0.9651257505368227
# test_score_W': split_num : 4 0.8878545261777273
# all_train_score_W' split_num : 5 0.9868622122186433
# test_score_W': split_num : 5 0.8918560247245491
# all_train_score_W' split_num : 6 0.9979087502151943
# test_score_W': split_num : 6 0.8931457159075971
# all_train_score_W' split_num : 7 1.0
# test_score_W': split_num : 7 0.8931457159075971
# neuron unit number: 20
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5910524576323452
# error_data0_score_W0 0.48297472940134745
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.7988377280036204
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6058838695042631
# error_data1_score_W0 0.3801019867872934
# combinedweight shape1 : (60, 22)
# right_data1_score_W' 0.7666253560651894
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6126494839527091
# error_data2_score_W0 0.372232555487471
# combinedweight shape1 : (80, 22)
# right_data2_score_W' 0.5936323681059098
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.7920262154927366
# error_data3_score_W0 0.5350940286252207
# combinedweight shape1 : (100, 22)
# right_data3_score_W' 0.7034667927718228
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.7918756684685216
# combinedweight shape1 : (120, 22)
# right_data4_score_W' 0.7487047702563885
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W' split_num : 0 0.7238100476565479
# test_score_W': split_num : 0 0.734092763261253
# all_train_score_W' split_num : 1 0.8929452085224174
# test_score_W': split_num : 1 0.8834910483923574
# all_train_score_W' split_num : 2 0.96010326462241
# test_score_W': split_num : 2 0.9176052652825412
# all_train_score_W' split_num : 3 0.9843516292169413
# test_score_W': split_num : 3 0.923233318536674
# all_train_score_W' split_num : 4 0.9963588412783896
# test_score_W': split_num : 4 0.9246238964756822
# all_train_score_W' split_num : 5 1.0
# test_score_W': split_num : 5 0.9263552886450392
# neuron unit number: 30
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6345840497420036
# error_data0_score_W0 0.5006019274884498
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9138039625875094
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5660769920980787
# error_data1_score_W0 0.3066610960191111
# combinedweight shape1 : (90, 22)
# right_data1_score_W' 0.8402028191997262
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5808018026516567
# error_data2_score_W0 0.44298567946800504
# combinedweight shape1 : (120, 22)
# right_data2_score_W' 0.46494510252961274
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.8571988181431639
# error_data3_score_W0 0.46563742080894915
# combinedweight shape1 : (150, 22)
# right_data3_score_W' 0.7918280989798107
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 0.2740175421212811
# combinedweight shape1 : (180, 22)
# right_data4_score_W' 0.6703167318112719
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W' split_num : 0 0.7218228264918094
# test_score_W': split_num : 0 0.7083806690764067
# all_train_score_W' split_num : 1 0.8846968401919426
# test_score_W': split_num : 1 0.8374295998225939
# all_train_score_W' split_num : 2 0.9586509611174251
# test_score_W': split_num : 2 0.8766332527159777
# all_train_score_W' split_num : 3 0.9834720830318628
# test_score_W': split_num : 3 0.8858477899549688
# all_train_score_W' split_num : 4 0.9977204186454184
# test_score_W': split_num : 4 0.8875852251233713
# all_train_score_W' split_num : 5 1.0
# test_score_W': split_num : 5 0.8875852251233713
# neuron unit number: 40
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5095389369340486
# error_data0_score_W0 0.39281412188285764
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9103704181428195
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6056698416160909
# error_data1_score_W0 0.36247683669880526
# combinedweight shape1 : (120, 22)
# right_data1_score_W' 0.6980460306767082
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8047805956386977
# error_data2_score_W0 0.4662809995104178
# combinedweight shape1 : (160, 22)
# right_data2_score_W' 0.6929496910504893
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.8788412824036218
# combinedweight shape1 : (200, 22)
# right_data3_score_W' 0.717149961591427
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W' split_num : 0 0.7664775152869109
# test_score_W': split_num : 0 0.7686756370555713
# all_train_score_W' split_num : 1 0.9045523901568012
# test_score_W': split_num : 1 0.8486329499911962
# all_train_score_W' split_num : 2 0.965632557331029
# test_score_W': split_num : 2 0.8748220715307707
# all_train_score_W' split_num : 3 0.9937462075931306
# test_score_W': split_num : 3 0.8881351516840569
# all_train_score_W' split_num : 4 1.0
# test_score_W': split_num : 4 0.8880082912445495
# neuron unit number: 50
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6200987842883522
# error_data0_score_W0 0.42486920868942635
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.8905702253228096
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6901763003431617
# error_data1_score_W0 0.4360918204279
# combinedweight shape1 : (150, 22)
# right_data1_score_W' 0.6316771718511242
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8423654784320802
# error_data2_score_W0 0.4373388093017636
# combinedweight shape1 : (200, 22)
# right_data2_score_W' 0.7615453309298887
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6666666666666666
# error_data3_score_W0 0.0
# combinedweight shape1 : (250, 22)
# right_data3_score_W' 0.847093901218336
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (300, 22)
# right_data4_score_W' 1.0
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W' split_num : 0 0.772331287356556
# test_score_W': split_num : 0 0.7855038962231864
# all_train_score_W' split_num : 1 0.9269577306106224
# test_score_W': split_num : 1 0.9033097765329373
# all_train_score_W' split_num : 2 0.9808365040141084
# test_score_W': split_num : 2 0.9174222049538113
# all_train_score_W' split_num : 3 0.9969301055800279
# test_score_W': split_num : 3 0.9181756696797159
# all_train_score_W' split_num : 4 0.999216479820387
# test_score_W': split_num : 4 0.9198531252924983
# all_train_score_W' split_num : 5 1.0
# test_score_W': split_num : 5 0.9198531252924983
# neuron unit number: 60
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6770544938857788
# error_data0_score_W0 0.37896769824684684
# combinedweight shape 0: (120, 22)
# right_data0_score_W' 0.874443989195966
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7948290058944393
# error_data1_score_W0 0.2918438862413716
# combinedweight shape1 : (180, 22)
# right_data1_score_W' 0.7261779669511311
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.640416840684365
# combinedweight shape1 : (240, 22)
# right_data2_score_W' 0.6045925950155462
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.7205923413389826
# test_score_W': split_num : 0 0.7259322984655582
# all_train_score_W' split_num : 1 0.917425413854803
# test_score_W': split_num : 1 0.8655334775254617
# all_train_score_W' split_num : 2 0.9864035482720914
# test_score_W': split_num : 2 0.9033421475921543
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9056096118134737
# neuron unit number: 70
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7019490059133839
# error_data0_score_W0 0.407439969403733
# combinedweight shape 0: (140, 22)
# right_data0_score_W' 0.9075560999021817
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.713445609678843
# error_data1_score_W0 0.35746423813149125
# combinedweight shape1 : (210, 22)
# right_data1_score_W' 0.7422027148257891
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5356450997535682
# combinedweight shape1 : (280, 22)
# right_data2_score_W' 0.7270879271984033
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.7833158266589955
# test_score_W': split_num : 0 0.805938910280654
# all_train_score_W' split_num : 1 0.9414835950490772
# test_score_W': split_num : 1 0.8987964336933699
# all_train_score_W' split_num : 2 0.9869106109381997
# test_score_W': split_num : 2 0.91019610561448
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.910872379215383
# neuron unit number: 80
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6768176504381682
# error_data0_score_W0 0.4414165503933262
# combinedweight shape 0: (160, 22)
# right_data0_score_W' 0.9181677831444052
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7875498459295925
# error_data1_score_W0 0.30065008756666706
# combinedweight shape1 : (240, 22)
# right_data1_score_W' 0.6484443003732563
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.4879024192774325
# combinedweight shape1 : (320, 22)
# right_data2_score_W' 0.7167616899951428
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8144394115963911
# test_score_W': split_num : 0 0.8130854718065007
# all_train_score_W' split_num : 1 0.9482434047588205
# test_score_W': split_num : 1 0.9006171606439953
# all_train_score_W' split_num : 2 0.9900019815284088
# test_score_W': split_num : 2 0.9131993198153504
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9187433661769245
# neuron unit number: 90
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.704900660485594
# error_data0_score_W0 0.4042868304881691
# combinedweight shape 0: (180, 22)
# right_data0_score_W' 0.8980794176583662
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.848808822107774
# error_data1_score_W0 0.3814162941211522
# combinedweight shape1 : (270, 22)
# right_data1_score_W' 0.7495247094398039
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.4790985919338351
# combinedweight shape1 : (360, 22)
# right_data2_score_W' 0.6899735068218099
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.7922703479262659
# test_score_W': split_num : 0 0.7998365258327087
# all_train_score_W' split_num : 1 0.9457074349254376
# test_score_W': split_num : 1 0.8762581645262185
# all_train_score_W' split_num : 2 0.9922756257223243
# test_score_W': split_num : 2 0.8983134203518703
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.8982525645623138
# neuron unit number: 100
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7404543641692037
# error_data0_score_W0 0.41831089987146336
# combinedweight shape 0: (200, 22)
# right_data0_score_W' 0.9123350624273424
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8365357805244206
# error_data1_score_W0 0.3129615110757072
# combinedweight shape1 : (300, 22)
# right_data1_score_W' 0.822155823984228
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5570232339629421
# combinedweight shape1 : (400, 22)
# right_data2_score_W' 0.7340951922716211
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8144648423984511
# test_score_W': split_num : 0 0.8030067950495434
# all_train_score_W' split_num : 1 0.9594097393445449
# test_score_W': split_num : 1 0.9125827265588606
# all_train_score_W' split_num : 2 0.9949777115965023
# test_score_W': split_num : 2 0.9204169678355766
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9204169678355766
# neuron unit number: 110
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7571787792911355
# error_data0_score_W0 0.45630338382224434
# combinedweight shape 0: (220, 22)
# right_data0_score_W' 0.9242302920714943
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9268950911053805
# error_data1_score_W0 0.4575758131958051
# combinedweight shape1 : (330, 22)
# right_data1_score_W' 0.6683139656045136
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (440, 22)
# right_data2_score_W' 0.7793017045921343
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8550832996089784
# test_score_W': split_num : 0 0.853345446701435
# all_train_score_W' split_num : 1 0.9703737612293871
# test_score_W': split_num : 1 0.9238854771578138
# all_train_score_W' split_num : 2 0.9984086908760524
# test_score_W': split_num : 2 0.9280984227856173
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9280984227856173
# neuron unit number: 120
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7129433930374988
# error_data0_score_W0 0.4308540787372216
# combinedweight shape 0: (240, 22)
# right_data0_score_W' 0.8598972255684588
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8859164221516193
# error_data1_score_W0 0.3929501683704278
# combinedweight shape1 : (360, 22)
# right_data1_score_W' 0.6477570814152943
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (480, 22)
# right_data2_score_W' 0.7724575804163095
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8499378644991279
# test_score_W': split_num : 0 0.8508405526097487
# all_train_score_W' split_num : 1 0.9653374856625755
# test_score_W': split_num : 1 0.9038250445565704
# all_train_score_W' split_num : 2 0.9962732448015211
# test_score_W': split_num : 2 0.9119097985081935
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9119097985081935
# neuron unit number: 130
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7388989436108945
# error_data0_score_W0 0.4417680433401139
# combinedweight shape 0: (260, 22)
# right_data0_score_W' 0.8987742384986438
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8862058497474002
# error_data1_score_W0 0.4511322944129296
# combinedweight shape1 : (390, 22)
# right_data1_score_W' 0.7351180794264196
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.7424834172925047
# combinedweight shape1 : (520, 22)
# right_data2_score_W' 0.7078048069737555
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8242743523353662
# test_score_W': split_num : 0 0.8249578421305046
# all_train_score_W' split_num : 1 0.9610990372048347
# test_score_W': split_num : 1 0.9017381551982043
# all_train_score_W' split_num : 2 0.996163052137509
# test_score_W': split_num : 2 0.910234519844783
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9097563343980483
# neuron unit number: 140
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7644998453028732
# error_data0_score_W0 0.3261524982353256
# combinedweight shape 0: (280, 22)
# right_data0_score_W' 0.8614208006128574
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9071082369578023
# error_data1_score_W0 0.4735366460327283
# combinedweight shape1 : (420, 22)
# right_data1_score_W' 0.6379513908005191
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (560, 22)
# right_data2_score_W' 0.8748690502301186
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.842254546156841
# test_score_W': split_num : 0 0.8549241598655722
# all_train_score_W' split_num : 1 0.9727809963894234
# test_score_W': split_num : 1 0.9125850438594736
# all_train_score_W' split_num : 2 0.9977476892083808
# test_score_W': split_num : 2 0.9211566934184994
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9211566934184994
# neuron unit number: 150
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7794053656091856
# error_data0_score_W0 0.39451106013760945
# combinedweight shape 0: (300, 22)
# right_data0_score_W' 0.8220935324530068
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9261129631883921
# error_data1_score_W0 0.43300959267405825
# combinedweight shape1 : (450, 22)
# right_data1_score_W' 0.6964585208454704
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0000000000000002
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (600, 22)
# right_data2_score_W' 0.8772510765684897
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8415938478280953
# test_score_W': split_num : 0 0.8597933757846457
# all_train_score_W' split_num : 1 0.9735636354730853
# test_score_W': split_num : 1 0.9033235383518149
# all_train_score_W' split_num : 2 0.9985953976793945
# test_score_W': split_num : 2 0.9100183445664715
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9100183445664715
# neuron unit number: 160
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7934643874381355
# error_data0_score_W0 0.43290138632641556
# combinedweight shape 0: (320, 22)
# right_data0_score_W' 0.8188717414914584
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9744623246330644
# error_data1_score_W0 0.4656278764455702
# combinedweight shape1 : (480, 22)
# right_data1_score_W' 0.7369599390483269
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (640, 22)
# right_data2_score_W' 0.8879193154081091
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8422289648087641
# test_score_W': split_num : 0 0.8470439882886066
# all_train_score_W' split_num : 1 0.9726897622496885
# test_score_W': split_num : 1 0.9083797148326651
# all_train_score_W' split_num : 2 0.9991802063114094
# test_score_W': split_num : 2 0.9142704490020476
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9153895550948861
# neuron unit number: 170
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7535530049128079
# error_data0_score_W0 0.38631896666413484
# combinedweight shape 0: (340, 22)
# right_data0_score_W' 0.8911169418844139
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9422959758598051
# error_data1_score_W0 0.5040212818662303
# combinedweight shape1 : (510, 22)
# right_data1_score_W' 0.6207238065178435
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (680, 22)
# right_data2_score_W' 0.8087958798867192
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8368597489248045
# test_score_W': split_num : 0 0.8435003907829361
# all_train_score_W' split_num : 1 0.9696470247690219
# test_score_W': split_num : 1 0.894366896484897
# all_train_score_W' split_num : 2 0.9986097022937324
# test_score_W': split_num : 2 0.9028347722205834
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9028347722205834
# neuron unit number: 180
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7864242248935119
# error_data0_score_W0 0.39873383719155553
# combinedweight shape 0: (360, 22)
# right_data0_score_W' 0.870994853666678
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9695608350447122
# error_data1_score_W0 0.46596952314872575
# combinedweight shape1 : (540, 22)
# right_data1_score_W' 0.6900885939516548
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (720, 22)
# right_data2_score_W' 0.9003695566011826
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8409005291325835
# test_score_W': split_num : 0 0.8313413644579933
# all_train_score_W' split_num : 1 0.973572322021242
# test_score_W': split_num : 1 0.8852790429829204
# all_train_score_W' split_num : 2 0.9993452624782021
# test_score_W': split_num : 2 0.8944507953611504
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.8944507953611504
# neuron unit number: 190
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8196560143043815
# error_data0_score_W0 0.37332634389052594
# combinedweight shape 0: (380, 22)
# right_data0_score_W' 0.8168913792460218
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5990766468747477
# combinedweight shape1 : (570, 22)
# right_data1_score_W' 0.7055309174814597
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.8644111328407493
# test_score_W': split_num : 0 0.8551816411463642
# all_train_score_W' split_num : 1 0.9815608900290125
# test_score_W': split_num : 1 0.9110595111040162
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9132246427828882
# neuron unit number: 200
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8660870107176487
# error_data0_score_W0 0.3882471861212653
# combinedweight shape 0: (400, 22)
# right_data0_score_W' 0.7986442701489324
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9390924725150868
# error_data1_score_W0 0.5458830401001732
# combinedweight shape1 : (600, 22)
# right_data1_score_W' 0.6269654614620601
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (800, 22)
# right_data2_score_W' 0.8918985290582385
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8436406568711837
# test_score_W': split_num : 0 0.8382188724928383
# all_train_score_W' split_num : 1 0.9844517236398754
# test_score_W': split_num : 1 0.9233278636306465
# all_train_score_W' split_num : 2 0.9993127196030163
# test_score_W': split_num : 2 0.9246555555119084
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9268514670954487
# neuron unit number: 210
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.79830171875637
# error_data0_score_W0 0.40453154698095045
# combinedweight shape 0: (420, 22)
# right_data0_score_W' 0.8369484765193499
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8836653996964472
# error_data1_score_W0 0.4247952002916366
# combinedweight shape1 : (630, 22)
# right_data1_score_W' 0.6698706511285657
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (840, 22)
# right_data2_score_W' 0.7631959604291593
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8629424292746298
# test_score_W': split_num : 0 0.8674106436618946
# all_train_score_W' split_num : 1 0.977340804654074
# test_score_W': split_num : 1 0.918052260436619
# all_train_score_W' split_num : 2 0.9984087540589369
# test_score_W': split_num : 2 0.9186940811103357
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9186940811103357
# neuron unit number: 220
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8011490949671277
# error_data0_score_W0 0.3996063506795109
# combinedweight shape 0: (440, 22)
# right_data0_score_W' 0.8936974406275823
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8458949722751432
# error_data1_score_W0 0.389612556615277
# combinedweight shape1 : (660, 22)
# right_data1_score_W' 0.7172219680332093
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.8571428571428571
# combinedweight shape1 : (880, 22)
# right_data2_score_W' 0.8559323065169919
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8399896542053593
# test_score_W': split_num : 0 0.83601764243745
# all_train_score_W' split_num : 1 0.9749497197077485
# test_score_W': split_num : 1 0.9146937728049597
# all_train_score_W' split_num : 2 0.9969559911801721
# test_score_W': split_num : 2 0.9135709401429816
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9122061622573348
# neuron unit number: 230
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8181552704492845
# error_data0_score_W0 0.4052324583210525
# combinedweight shape 0: (460, 22)
# right_data0_score_W' 0.9191231240088049
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.551726720361192
# combinedweight shape1 : (690, 22)
# right_data1_score_W' 0.5926198875843328
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.8629201337971778
# test_score_W': split_num : 0 0.8680257316571421
# all_train_score_W' split_num : 1 0.9816467736007901
# test_score_W': split_num : 1 0.9233820619512054
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9270449907985526
# neuron unit number: 240
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7563663113515927
# error_data0_score_W0 0.4666149245353809
# combinedweight shape 0: (480, 22)
# right_data0_score_W' 0.8199316947666588
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9727060449505498
# error_data1_score_W0 0.4229141674495916
# combinedweight shape1 : (720, 22)
# right_data1_score_W' 0.673634721278481
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (960, 22)
# right_data2_score_W' 0.7602772199301648
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8588196238656542
# test_score_W': split_num : 0 0.8544829142400565
# all_train_score_W' split_num : 1 0.9723851223619207
# test_score_W': split_num : 1 0.9130930566157588
# all_train_score_W' split_num : 2 0.9993452624782021
# test_score_W': split_num : 2 0.914337097096253
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.914337097096253
# neuron unit number: 250
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8329976062553293
# error_data0_score_W0 0.46579117578125345
# combinedweight shape 0: (500, 22)
# right_data0_score_W' 0.8821991771508777
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9528014148476397
# error_data1_score_W0 0.4828714002722544
# combinedweight shape1 : (750, 22)
# right_data1_score_W' 0.6796808827616765
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1000, 22)
# right_data2_score_W' 0.9045622745975634
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8489671371213946
# test_score_W': split_num : 0 0.8336199934092586
# all_train_score_W' split_num : 1 0.9810130415281706
# test_score_W': split_num : 1 0.8951003584168373
# all_train_score_W' split_num : 2 0.9992819067310766
# test_score_W': split_num : 2 0.9023982212149818
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9023982212149818
# neuron unit number: 260
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7616892715242389
# error_data0_score_W0 0.369935235609738
# combinedweight shape 0: (520, 22)
# right_data0_score_W' 0.8565225307715304
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8974368717875312
# error_data1_score_W0 0.42307539084081586
# combinedweight shape1 : (780, 22)
# right_data1_score_W' 0.588959618976537
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.7336804366512112
# combinedweight shape1 : (1040, 22)
# right_data2_score_W' 0.8158707618134643
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8607424449676225
# test_score_W': split_num : 0 0.8538823545016923
# all_train_score_W' split_num : 1 0.9738982455449172
# test_score_W': split_num : 1 0.9158775546236574
# all_train_score_W' split_num : 2 0.9978611104780509
# test_score_W': split_num : 2 0.9159972823605461
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9132483256867117
# neuron unit number: 270
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8213194196056302
# error_data0_score_W0 0.4220693467467793
# combinedweight shape 0: (540, 22)
# right_data0_score_W' 0.8687528412641383
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0000000000000002
# error_data1_score_W0 0.42369669715985336
# combinedweight shape1 : (810, 22)
# right_data1_score_W' 0.6474566733319325
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.8522835062242796
# test_score_W': split_num : 0 0.8534763668608307
# all_train_score_W' split_num : 1 0.977553309297533
# test_score_W': split_num : 1 0.9048819351561252
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9110689903392885
# neuron unit number: 280
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8823397519308838
# error_data0_score_W0 0.429140375985441
# combinedweight shape 0: (560, 22)
# right_data0_score_W' 0.8275795481405959
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5809304270441231
# combinedweight shape1 : (840, 22)
# right_data1_score_W' 0.6143041683690712
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.8772568261618503
# test_score_W': split_num : 0 0.8708370351164672
# all_train_score_W' split_num : 1 0.9887699088630924
# test_score_W': split_num : 1 0.9135548500672688
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9167312285477378
# neuron unit number: 290
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7955485769908467
# error_data0_score_W0 0.395786005114467
# combinedweight shape 0: (580, 22)
# right_data0_score_W' 0.8578283428392549
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.959385829070611
# error_data1_score_W0 0.5247342366532168
# combinedweight shape1 : (870, 22)
# right_data1_score_W' 0.6554494658966973
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1160, 22)
# right_data2_score_W' 0.942864921407168
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8678605417401758
# test_score_W': split_num : 0 0.8663733078729732
# all_train_score_W' split_num : 1 0.9794467349284671
# test_score_W': split_num : 1 0.9126382906877237
# all_train_score_W' split_num : 2 0.9992282654650406
# test_score_W': split_num : 2 0.9204092686939092
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9204092686939092
# neuron unit number: 300
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8033035595390784
# error_data0_score_W0 0.33773145465414756
# combinedweight shape 0: (600, 22)
# right_data0_score_W' 0.804592081355912
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9629386077557105
# error_data1_score_W0 0.5365403088544081
# combinedweight shape1 : (900, 22)
# right_data1_score_W' 0.6732052241114087
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1200, 22)
# right_data2_score_W' 0.8782196958762922
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.8623962467598789
# test_score_W': split_num : 0 0.8524708723924038
# all_train_score_W' split_num : 1 0.980920975168883
# test_score_W': split_num : 1 0.9019386351289588
# all_train_score_W' split_num : 2 0.9992092183029437
# test_score_W': split_num : 2 0.9073728788863722
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9078521215351979

# %%
# multiple text by adding neuron number 
scoretype = 1
scope_num = 5
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.20488385944014295
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4370996959109211
# error_data0_score_W0 0.4302405753842127
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.8708727269683768
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.46557351399835256
# error_data1_score_W0 0.3947932487913735
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.7135041043136284
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.4125909439609899
# error_data2_score_W0 0.2773084546446962
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.6538660655844154
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.5753410052824169
# error_data3_score_W0 0.48749504735111593
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.5647760805485891
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.7166710978160445
# error_data4_score_W0 0.5881264495456408
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.5452314083834078
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.865090868912524
# error_data5_score_W0 0.8186369418925543
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.7448674281505848
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.9048504844691448
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.690127837330402
# all_train_score_W': 1.0
# test_score_W0 : 0.6852396021733043
# test_score_W': 0.8961911647261428
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.163390907286083
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5943034546842619
# error_data0_score_W0 0.376122973019909
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.8706040641998537
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5046468589698533
# error_data1_score_W0 0.39181647387847707
# combinedweight shape1 : (60, 22)
# right_data1_score_W' 0.7813216006419584
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5061997313460003
# error_data2_score_W0 0.3539328296522448
# combinedweight shape1 : (80, 22)
# right_data2_score_W' 0.7162364274305428
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6164033701329334
# error_data3_score_W0 0.37893255465518244
# combinedweight shape1 : (100, 22)
# right_data3_score_W' 0.5280254650236259
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.9369355362093356
# error_data4_score_W0 0.5949463881973084
# combinedweight shape1 : (120, 22)
# right_data4_score_W' 0.8115547933891656
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (140, 22)
# right_data5_score_W' 0.9487949532646253
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7152289671789193
# all_train_score_W': 1.0
# test_score_W0 : 0.7170269624284193
# test_score_W': 0.9101532537266936
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.1542584871947588
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5721726814050796
# error_data0_score_W0 0.3481550462995963
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9027982320654028
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6007498387598982
# error_data1_score_W0 0.3450913642637379
# combinedweight shape1 : (90, 22)
# right_data1_score_W' 0.8121733973421744
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7145282390424488
# error_data2_score_W0 0.36354407726413074
# combinedweight shape1 : (120, 22)
# right_data2_score_W' 0.5960554983083287
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9719069095353614
# error_data3_score_W0 0.6289187426345039
# combinedweight shape1 : (150, 22)
# right_data3_score_W' 0.6806390739437018
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (180, 22)
# right_data4_score_W' 0.8135345132450071
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7129050180316014
# all_train_score_W': 1.0
# test_score_W0 : 0.7164993895910506
# test_score_W': 0.9025428030439068
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.11852293031566409
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5834040356375547
# error_data0_score_W0 0.34661828141174195
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9147261838866076
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6310138565066725
# error_data1_score_W0 0.34052347066220234
# combinedweight shape1 : (120, 22)
# right_data1_score_W' 0.6939534448337688
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8130540483817686
# error_data2_score_W0 0.46902160004602017
# combinedweight shape1 : (160, 22)
# right_data2_score_W' 0.6324748115309274
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.6702252276515629
# combinedweight shape1 : (200, 22)
# right_data3_score_W' 0.7015281910632065
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7550715684581422
# all_train_score_W': 1.0
# test_score_W0 : 0.7723201044445681
# test_score_W': 0.8853841797920811
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10760373238038515
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6616919719914082
# error_data0_score_W0 0.4149186640432204
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9374834415212973
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7144262311964639
# error_data1_score_W0 0.32147919406073033
# combinedweight shape1 : (150, 22)
# right_data1_score_W' 0.755937588981735
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.9528790924110925
# error_data2_score_W0 0.4968215563752915
# combinedweight shape1 : (200, 22)
# right_data2_score_W' 0.6420201619096385
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (250, 22)
# right_data3_score_W' 0.7373355301651002
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7782816822598354
# all_train_score_W': 1.0
# test_score_W0 : 0.7758863544604198
# test_score_W': 0.904258006391574
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   5.0  0.733394  0.039348  0.017597   0.684538  0.782251
# 1  test_score_W'   5.0  0.899706  0.009426  0.004215   0.888002  0.911410
# 2       combined  10.0  0.816550  0.091710  0.029001   0.750945  0.882156
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1663
# 1                          Degrees of freedom =    8.0000
# 2                                           t =   -9.1912
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -5.8130
# 7                                   Hedge's g =   -5.2504
# 8                               Glass's delta =   -4.2267
# 9                                 Pearson's r =    0.9558
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-9.19115647218233, pvalue=7.937005184246487e-06)

# %%
# multiple text by adding neuron number 
scoretype = 2
scope_num = 30
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.2876712328767123
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3330006688937864
# error_data0_score_W0 0.15740001733848127
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9573449570365383
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3273466050609255
# error_data1_score_W0 0.08464325936889172
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.9008314088251995
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.336868004483736
# error_data2_score_W0 0.16518826027012598
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.5940372909778873
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.35621015636487696
# error_data3_score_W0 0.10557772542896289
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.3583286975994155
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.33828801259071434
# error_data4_score_W0 0.12315102428151328
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.46571000661767264
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.626746506986028
# error_data5_score_W0 0.2654729466718568
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.32689369503955457
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.6153846153846154
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.08771929824561403
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6990264095582184
# all_train_score_W': 1.0
# test_score_W0 : 0.7086538810810108
# test_score_W': 0.962223707848625
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.17550129045066507
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35934814024285394
# error_data0_score_W0 0.3282114846126135
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9318563699218926
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4664266053167904
# error_data1_score_W0 0.17119447705514274
# combinedweight shape1 : (60, 22)
# right_data1_score_W' 0.5199154206078052
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.44862227237563446
# error_data2_score_W0 0.1314734178856771
# combinedweight shape1 : (80, 22)
# right_data2_score_W' 0.4760863814641976
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.5560324425796824
# error_data3_score_W0 0.2569288265643604
# combinedweight shape1 : (100, 22)
# right_data3_score_W' 0.6191026148982487
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.6896551724137931
# error_data4_score_W0 -0.13793103448275862
# combinedweight shape1 : (120, 22)
# right_data4_score_W' 0.36114970278087777
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (140, 22)
# right_data5_score_W' 0.71875
# Finish one training *********
# 6
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8336395055939514
# all_train_score_W': 1.0
# test_score_W0 : 0.829553258119312
# test_score_W': 0.9653400011179025
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.15922175898352195
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5153597283660907
# error_data0_score_W0 0.18632327007792773
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9619861238173194
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6098503991276816
# error_data1_score_W0 0.2573051591212025
# combinedweight shape1 : (90, 22)
# right_data1_score_W' 0.6456590561795289
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.41336795682079125
# error_data2_score_W0 0.08274253906764202
# combinedweight shape1 : (120, 22)
# right_data2_score_W' 0.6802383618390616
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.9447368421052632
# error_data3_score_W0 0.007874015748031496
# combinedweight shape1 : (150, 22)
# right_data3_score_W' 0.2851963746223565
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (180, 22)
# right_data4_score_W' 0.3708609271523179
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8491244915217886
# all_train_score_W': 1.0
# test_score_W0 : 0.8617789728147139
# test_score_W': 0.97240014194842
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14790549930514196
# right_data0_score_W0 1.0
# error_data0_score_W1 0.530335694135997
# error_data0_score_W0 0.2361918034727066
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9634603848766893
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6651265636388111
# error_data1_score_W0 0.15601706746081942
# combinedweight shape1 : (120, 22)
# right_data1_score_W' 0.7459481641611915
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8499290780141844
# error_data2_score_W0 0.10929635336414997
# combinedweight shape1 : (160, 22)
# right_data2_score_W' 0.2772515644075575
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 -0.2222222222222222
# combinedweight shape1 : (200, 22)
# right_data3_score_W' 0.7050889025137952
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8806110166881886
# all_train_score_W': 1.0
# test_score_W0 : 0.8841327494502987
# test_score_W': 0.9751425222038023
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.10819932499503673
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5530530764295486
# error_data0_score_W0 0.1246295861805426
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9848195981960444
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6698200230157529
# error_data1_score_W0 0.12075855812459649
# combinedweight shape1 : (150, 22)
# right_data1_score_W' 0.6280787173197471
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.9732161836604549
# error_data2_score_W0 0.04975897994091121
# combinedweight shape1 : (200, 22)
# right_data2_score_W' 0.5314268118376245
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (250, 22)
# right_data3_score_W' 0.4314018691588785
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9018643690597351
# all_train_score_W': 1.0
# test_score_W0 : 0.899633521002341
# test_score_W': 0.9670716837359367
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.10462576930712726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6745895972459109
# error_data0_score_W0 0.18641538866457888
# combinedweight shape 0: (120, 22)
# right_data0_score_W' 0.9597139654978536
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6728365489772641
# error_data1_score_W0 0.20696333835666839
# combinedweight shape1 : (180, 22)
# right_data1_score_W' 0.5000536308906074
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8993920376544421
# error_data2_score_W0 0.06896551724137931
# combinedweight shape1 : (240, 22)
# right_data2_score_W' 0.4569946002043166
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (300, 22)
# right_data3_score_W' 0.6070878274268104
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.907012907768012
# all_train_score_W': 1.0
# test_score_W0 : 0.9018146568703136
# test_score_W': 0.9741430685129884
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.09628747270200516
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7057214640082006
# error_data0_score_W0 0.24024969415779615
# combinedweight shape 0: (140, 22)
# right_data0_score_W' 0.9640594539605633
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6922480986347962
# error_data1_score_W0 0.08429221006727491
# combinedweight shape1 : (210, 22)
# right_data1_score_W' 0.7149667325796225
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8894736842105263
# error_data2_score_W0 -0.11594202898550725
# combinedweight shape1 : (280, 22)
# right_data2_score_W' 0.44088654765438345
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (350, 22)
# right_data3_score_W' 0.4932378679395386
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9209446175471931
# all_train_score_W': 1.0
# test_score_W0 : 0.9103805492655296
# test_score_W': 0.9621575381124617
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.09033154655548938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6949510019224093
# error_data0_score_W0 0.2139668549013021
# combinedweight shape 0: (160, 22)
# right_data0_score_W' 0.9476648028660999
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7769771986733376
# error_data1_score_W0 0.11899211964881558
# combinedweight shape1 : (240, 22)
# right_data1_score_W' 0.7031801903598391
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.21052631578947367
# combinedweight shape1 : (320, 22)
# right_data2_score_W' 0.3692266523949692
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.928033436303409
# all_train_score_W': 1.0
# test_score_W0 : 0.9263199003533351
# test_score_W': 0.9639729343505608
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.06611078022632519
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6993470907092482
# error_data0_score_W0 0.24198196648183137
# combinedweight shape 0: (180, 22)
# right_data0_score_W' 0.9471298785583379
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7305348955680081
# error_data1_score_W0 0.0371423676546171
# combinedweight shape1 : (270, 22)
# right_data1_score_W' 0.5519320061242073
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 -0.14545454545454545
# combinedweight shape1 : (360, 22)
# right_data2_score_W' 0.4765516423429807
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9379328371969599
# all_train_score_W': 1.0
# test_score_W0 : 0.9303690127859001
# test_score_W': 0.9684441851910903
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.07583879293230097
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7911346874488571
# error_data0_score_W0 0.23014206347756225
# combinedweight shape 0: (200, 22)
# right_data0_score_W' 0.9549206617111039
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8522954091816367
# error_data1_score_W0 0.06761385259419003
# combinedweight shape1 : (300, 22)
# right_data1_score_W' 0.682240040016254
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (400, 22)
# right_data2_score_W' 0.3979418130180754
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9263295819018016
# all_train_score_W': 1.0
# test_score_W0 : 0.924693285281928
# test_score_W': 0.9729193417410781
# neuron unit number: 110
# *******************
#
# Error Data percentage 0.06611078022632519
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7002890909257667
# error_data0_score_W0 0.2508467203093824
# combinedweight shape 0: (220, 22)
# right_data0_score_W' 0.9282735344039429
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8391970910520368
# error_data1_score_W0 0.08028608844565327
# combinedweight shape1 : (330, 22)
# right_data1_score_W' 0.5690218490304991
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (440, 22)
# right_data2_score_W' 0.6519517037054916
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9426329477088748
# all_train_score_W': 1.0
# test_score_W0 : 0.9405279854976512
# test_score_W': 0.9717560987947216
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.07107405201508835
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7088717057301595
# error_data0_score_W0 0.2549016835369413
# combinedweight shape 0: (240, 22)
# right_data0_score_W' 0.9446340577539715
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9478407096180984
# error_data1_score_W0 0.0686779470547935
# combinedweight shape1 : (360, 22)
# right_data1_score_W' 0.5497631727743596
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (480, 22)
# right_data2_score_W' 0.5231437596388997
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9338848169128693
# all_train_score_W': 1.0
# test_score_W0 : 0.9313040534338507
# test_score_W': 0.9671132413109559
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.06472106412547152
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7384129575051804
# error_data0_score_W0 0.2306733122834999
# combinedweight shape 0: (260, 22)
# right_data0_score_W' 0.8851420299812391
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9354838709677419
# error_data1_score_W0 0.08163265306122448
# combinedweight shape1 : (390, 22)
# right_data1_score_W' 0.6892055017030962
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (520, 22)
# right_data2_score_W' 0.4547236151939593
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9502684290872461
# all_train_score_W': 1.0
# test_score_W0 : 0.9394700521366427
# test_score_W': 0.9648977208302357
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.061941631923764146
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8276681363506437
# error_data0_score_W0 0.17876476498015312
# combinedweight shape 0: (280, 22)
# right_data0_score_W' 0.9282388157422901
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.04038869652630403
# combinedweight shape1 : (420, 22)
# right_data1_score_W' 0.6309415458954425
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9420101969498664
# all_train_score_W': 1.0
# test_score_W0 : 0.9357254064648568
# test_score_W': 0.9701303716923156
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.06253722453841572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8022920156463966
# error_data0_score_W0 0.2368000519458663
# combinedweight shape 0: (300, 22)
# right_data0_score_W' 0.8586506431609986
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9640123386267565
# error_data1_score_W0 0.12256267409470752
# combinedweight shape1 : (450, 22)
# right_data1_score_W' 0.5814977281216275
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (600, 22)
# right_data2_score_W' 0.746864001443913
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9486376952550707
# all_train_score_W': 1.0
# test_score_W0 : 0.9453910532180774
# test_score_W': 0.973776748535014
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.0540003970617431
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8037380628403271
# error_data0_score_W0 0.2009298823833828
# combinedweight shape 0: (320, 22)
# right_data0_score_W' 0.8061131105152093
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0916030534351145
# combinedweight shape1 : (480, 22)
# right_data1_score_W' 0.5655783589982113
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9482334453263412
# all_train_score_W': 1.0
# test_score_W0 : 0.9351288276451135
# test_score_W': 0.9648729097981822
# neuron unit number: 170
# *******************
# Error Data percentage 0.06571371848322415
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8468843596496612
# error_data0_score_W0 0.27956859430561576
# combinedweight shape 0: (340, 22)
# right_data0_score_W' 0.9169138920745328
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2141039689467526
# combinedweight shape1 : (510, 22)
# right_data1_score_W' 0.6871827867776851
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9387125240648851
# all_train_score_W': 1.0
# test_score_W0 : 0.929243963321621
# test_score_W': 0.9702961079136198
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.06035338495135994
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8662788103055421
# error_data0_score_W0 0.22422625629173001
# combinedweight shape 0: (360, 22)
# right_data0_score_W' 0.9448685928122543
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.23631123919308358
# combinedweight shape1 : (540, 22)
# right_data1_score_W' 0.6072398883770566
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9421243108353268
# all_train_score_W': 1.0
# test_score_W0 : 0.9334800773372142
# test_score_W': 0.9649209046690969
# neuron unit number: 190
# *******************
#
# Error Data percentage 0.04050029779630732
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7910966376328628
# error_data0_score_W0 0.2700618779743442
# combinedweight shape 0: (380, 22)
# right_data0_score_W' 0.8615799299576816
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9373865698729582
# error_data1_score_W0 -0.002526847757422615
# combinedweight shape1 : (570, 22)
# right_data1_score_W' 0.4891810070265869
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (760, 22)
# right_data2_score_W' 0.6035725477906613
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9628409155498061
# all_train_score_W': 1.0
# test_score_W0 : 0.9532868918027914
# test_score_W': 0.9669347046008384
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.05876513797895573
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8634921502793665
# error_data0_score_W0 0.2603261672361848
# combinedweight shape 0: (400, 22)
# right_data0_score_W' 0.7398133808838935
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7401539828249926
# error_data1_score_W0 0.16394067392892306
# combinedweight shape1 : (600, 22)
# right_data1_score_W' 0.5237120743324494
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (800, 22)
# right_data2_score_W' 0.5921985815602837
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.944255622944567
# all_train_score_W': 1.0
# test_score_W0 : 0.9346417690490744
# test_score_W': 0.9674460357501794
# neuron unit number: 210
# *******************
#
# Error Data percentage 0.05618423664879889
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8551499106922372
# error_data0_score_W0 0.2307902448455176
# combinedweight shape 0: (420, 22)
# right_data0_score_W' 0.7939940609364727
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9145321622048073
# error_data1_score_W0 0.06822488945041061
# combinedweight shape1 : (630, 22)
# right_data1_score_W' 0.4241027647927239
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (840, 22)
# right_data2_score_W' 0.4094488188976378
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.946690385025833
# all_train_score_W': 1.0
# test_score_W0 : 0.9390365768111906
# test_score_W': 0.9730715400548474
# neuron unit number: 220
# *******************
#
# Error Data percentage 0.05578717490569784
# right_data0_score_W0 1.0
# error_data0_score_W1 0.842367047113957
# error_data0_score_W0 0.194431248160518
# combinedweight shape 0: (440, 22)
# right_data0_score_W' 0.8099612880128036
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2674992903775192
# combinedweight shape1 : (660, 22)
# right_data1_score_W' 0.46501676418661175
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9494225994785401
# all_train_score_W': 1.0
# test_score_W0 : 0.9472172390788195
# test_score_W': 0.9783740143710385
# neuron unit number: 230
# *******************
#
# Error Data percentage 0.0593607305936073
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7830912422905619
# error_data0_score_W0 0.17465523381178558
# combinedweight shape 0: (460, 22)
# right_data0_score_W' 0.8998342592888396
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.931321540062435
# error_data1_score_W0 0.05335887262279382
# combinedweight shape1 : (690, 22)
# right_data1_score_W' 0.4807875069036868
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (920, 22)
# right_data2_score_W' 0.8147299992612839
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9520519224387326
# all_train_score_W': 1.0
# test_score_W0 : 0.9443041312294771
# test_score_W': 0.9740895608605242
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.052809211832439945
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8488445434415841
# error_data0_score_W0 0.19548395556675496
# combinedweight shape 0: (480, 22)
# right_data0_score_W' 0.8776632063834092
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7617647058823529
# error_data1_score_W0 0.057663125948406675
# combinedweight shape1 : (720, 22)
# right_data1_score_W' 0.5052710506406971
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (960, 22)
# right_data2_score_W' 0.56875
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.950676491129759
# all_train_score_W': 1.0
# test_score_W0 : 0.9313448857780238
# test_score_W': 0.9649773645077621
# neuron unit number: 250
# *******************
#
# Error Data percentage 0.05102243398848521
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7982963455222882
# error_data0_score_W0 0.19688252279590407
# combinedweight shape 0: (500, 22)
# right_data0_score_W' 0.7816181849583794
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0681912681912682
# combinedweight shape1 : (750, 22)
# right_data1_score_W' 0.5765329549765321
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9543514453244321
# all_train_score_W': 1.0
# test_score_W0 : 0.950563108697027
# test_score_W': 0.966933878437966
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.05002977963073258
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7372341957377121
# error_data0_score_W0 0.19423901084033093
# combinedweight shape 0: (520, 22)
# right_data0_score_W' 0.8553938420390484
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8974532341672301
# error_data1_score_W0 0.05289789532865628
# combinedweight shape1 : (780, 22)
# right_data1_score_W' 0.5931446546894371
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1040, 22)
# right_data2_score_W' 0.7178128051332124
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9518610290624413
# all_train_score_W': 1.0
# test_score_W0 : 0.9473385169133182
# test_score_W': 0.9746790604003869
# neuron unit number: 270
# *******************
#
# Error Data percentage 0.047250347429025216
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8712105605516509
# error_data0_score_W0 0.18849460618703934
# combinedweight shape 0: (540, 22)
# right_data0_score_W' 0.7905086514280742
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.837537409149209
# error_data1_score_W0 -0.02193630035857414
# combinedweight shape1 : (810, 22)
# right_data1_score_W' 0.4245477918695098
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1080, 22)
# right_data2_score_W' 0.718904109589041
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9573992403720369
# all_train_score_W': 1.0
# test_score_W0 : 0.9524196288921281
# test_score_W': 0.9754054053944199
# neuron unit number: 280
# *******************
#
# Error Data percentage 0.04665475481437364
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7562011525943526
# error_data0_score_W0 0.1981282579838525
# combinedweight shape 0: (560, 22)
# right_data0_score_W' 0.7844173953193283
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.04976576661409167
# combinedweight shape1 : (840, 22)
# right_data1_score_W' 0.5304012636200538
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9552185700696977
# all_train_score_W': 1.0
# test_score_W0 : 0.9487984330166935
# test_score_W': 0.964495154772716
# neuron unit number: 290
# *******************
#
# Error Data percentage 0.05717689100655152
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7728763212969113
# error_data0_score_W0 0.2406876325239957
# combinedweight shape 0: (580, 22)
# right_data0_score_W' 0.7816562180707173
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.24680210684725357
# combinedweight shape1 : (870, 22)
# right_data1_score_W' 0.5338443940513776
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9511884145759825
# all_train_score_W': 1.0
# test_score_W0 : 0.9419928737151109
# test_score_W': 0.9638671761570927
# neuron unit number: 300
# *******************
#
# Error Data percentage 0.042684137383363116
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8300468235857804
# error_data0_score_W0 0.18416271275945
# combinedweight shape 0: (600, 22)
# right_data0_score_W' 0.7704792573614347
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.03589277601090413
# combinedweight shape1 : (900, 22)
# right_data1_score_W' 0.4659238218766643
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.9647851446969119
# all_train_score_W': 1.0
# test_score_W0 : 0.9620446004916335
# test_score_W': 0.9748476411034095
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.920686  0.049057  0.008957   0.902368  0.939005
# 1  test_score_W'  30.0  0.969223  0.004639  0.000847   0.967491  0.970956
# 2       combined  60.0  0.944955  0.042337  0.005466   0.934018  0.955892
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0485
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -5.3951
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.3930
# 7                                   Hedge's g =   -1.3749
# 8                               Glass's delta =   -0.9894
# 9                                 Pearson's r =    0.5781
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-5.395071530559524, pvalue=6.604466147948136e-07)

# %%
#local scope 1
import collections
scoretype = 0
scope_num = 60
class_num = 10
dim_num = 22
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:       
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.26325193567599764
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6561085972850679
# error_data0_score_W0 0.44871794871794873
# combinedweight shape 0: (20, 22)
# right_data0_score_W' 0.9552681218000539
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.48026315789473684
# error_data1_score_W0 0.4473684210526316
# combinedweight shape1 : (30, 22)
# right_data1_score_W' 0.7816091954022989
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.510548523206751
# error_data2_score_W0 0.4430379746835443
# combinedweight shape1 : (40, 22)
# right_data2_score_W' 0.7899543378995434
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6637931034482759
# error_data3_score_W0 0.5
# combinedweight shape1 : (50, 22)
# right_data3_score_W' 0.8512396694214877
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5641025641025641
# error_data4_score_W0 0.38461538461538464
# combinedweight shape1 : (60, 22)
# right_data4_score_W' 0.7662337662337663
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.8235294117647058
# error_data5_score_W0 0.5882352941176471
# combinedweight shape1 : (70, 22)
# right_data5_score_W' 0.9090909090909091
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.6666666666666666
# combinedweight shape1 : (80, 22)
# right_data6_score_W' 0.8571428571428571
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.7367480643240024
# all_train_score_W': 1.0
# test_score_W0 : 0.7409638554216867
# test_score_W': 0.9647822057460612
# class_num*x*(optimize_W.split_num +1)80
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.152074647607703
# right_data0_score_W0 1.0
# error_data0_score_W1 0.639686684073107
# error_data0_score_W0 0.5
# combinedweight shape 0: (40, 22)
# right_data0_score_W' 0.9206274877077968
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6485507246376812
# error_data1_score_W0 0.4601449275362319
# combinedweight shape1 : (60, 22)
# right_data1_score_W' 0.7959183673469388
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6391752577319587
# error_data2_score_W0 0.4742268041237113
# combinedweight shape1 : (80, 22)
# right_data2_score_W' 0.7430167597765364
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6571428571428571
# error_data3_score_W0 0.4857142857142857
# combinedweight shape1 : (100, 22)
# right_data3_score_W' 0.7580645161290323
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.8333333333333334
# error_data4_score_W0 0.6666666666666666
# combinedweight shape1 : (120, 22)
# right_data4_score_W' 0.6086956521739131
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 1.0
# Error data can be represented by W0 5
# combinedweight shape1 : (140, 22)
# right_data5_score_W' 0.9
# Finish one splitting *********
# 6
#  NO Error Data, Finish Training!
# split_num 6
# all_train_score_W0: 0.847925352392297
# all_train_score_W': 1.0
# test_score_W0 : 0.8716404077849861
# test_score_W': 0.9666357738646896
# class_num*x*(optimize_W.split_num +1)140
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.14711137581893985
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6639676113360324
# error_data0_score_W0 0.49527665317139
# combinedweight shape 0: (60, 22)
# right_data0_score_W' 0.9611266294227188
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6666666666666666
# error_data1_score_W0 0.4979919678714859
# combinedweight shape1 : (90, 22)
# right_data1_score_W' 0.8211382113821138
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7710843373493976
# error_data2_score_W0 0.4819277108433735
# combinedweight shape1 : (120, 22)
# right_data2_score_W' 0.7048192771084337
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.8947368421052632
# error_data3_score_W0 0.5789473684210527
# combinedweight shape1 : (150, 22)
# right_data3_score_W' 0.765625
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (180, 22)
# right_data4_score_W' 0.7647058823529411
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W0: 0.8528886241810602
# all_train_score_W': 1.0
# test_score_W0 : 0.8716404077849861
# test_score_W': 0.9629286376274329
# class_num*x*(optimize_W.split_num +1)180
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.14949374627754616
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8100929614873837
# error_data0_score_W0 0.601593625498008
# combinedweight shape 0: (80, 22)
# right_data0_score_W' 0.9523809523809523
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7062937062937062
# error_data1_score_W0 0.3776223776223776
# combinedweight shape1 : (120, 22)
# right_data1_score_W' 0.8622950819672132
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.7142857142857143
# error_data2_score_W0 0.35714285714285715
# combinedweight shape1 : (160, 22)
# right_data2_score_W' 0.6831683168316832
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.5833333333333334
# combinedweight shape1 : (200, 22)
# right_data3_score_W' 0.7666666666666667
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W0: 0.8505062537224538
# all_train_score_W': 1.0
# test_score_W0 : 0.8577386468952733
# test_score_W': 0.9721964782205746
# class_num*x*(optimize_W.split_num +1)200
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.12487591820528092
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7901430842607313
# error_data0_score_W0 0.4356120826709062
# combinedweight shape 0: (100, 22)
# right_data0_score_W' 0.9242286751361162
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7272727272727273
# error_data1_score_W0 0.44696969696969696
# combinedweight shape1 : (150, 22)
# right_data1_score_W' 0.8169014084507042
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.9166666666666666
# error_data2_score_W0 0.5
# combinedweight shape1 : (200, 22)
# right_data2_score_W' 0.7395833333333334
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (250, 22)
# right_data3_score_W' 0.6666666666666666
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W0: 0.8751240817947191
# all_train_score_W': 1.0
# test_score_W0 : 0.8818350324374421
# test_score_W': 0.9675625579240037
# class_num*x*(optimize_W.split_num +1)250
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.09608894183045463
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7706611570247934
# error_data0_score_W0 0.5
# combinedweight shape 0: (120, 22)
# right_data0_score_W' 0.9492642213924884
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8558558558558559
# error_data1_score_W0 0.34234234234234234
# combinedweight shape1 : (180, 22)
# right_data1_score_W' 0.8364611260053619
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.6875
# combinedweight shape1 : (240, 22)
# right_data2_score_W' 0.7157894736842105
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9039110581695453
# all_train_score_W': 1.0
# test_score_W0 : 0.9193697868396663
# test_score_W': 0.9712696941612604
# class_num*x*(optimize_W.split_num +1)240
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.10363311494937463
# right_data0_score_W0 1.0
# error_data0_score_W1 0.814176245210728
# error_data0_score_W0 0.5210727969348659
# combinedweight shape 0: (140, 22)
# right_data0_score_W' 0.9638981173864895
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.865979381443299
# error_data1_score_W0 0.44329896907216493
# combinedweight shape1 : (210, 22)
# right_data1_score_W' 0.7858823529411765
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.6923076923076923
# combinedweight shape1 : (280, 22)
# right_data2_score_W' 0.7380952380952381
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.8963668850506253
# all_train_score_W': 1.0
# test_score_W0 : 0.902224281742354
# test_score_W': 0.9606116774791473
# class_num*x*(optimize_W.split_num +1)280
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.0859638673813778
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8244803695150116
# error_data0_score_W0 0.581986143187067
# combinedweight shape 0: (160, 22)
# right_data0_score_W' 0.9702432667245873
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.881578947368421
# error_data1_score_W0 0.4473684210526316
# combinedweight shape1 : (240, 22)
# right_data1_score_W' 0.7226890756302521
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5555555555555556
# combinedweight shape1 : (320, 22)
# right_data2_score_W' 0.7313432835820896
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9140361326186222
# all_train_score_W': 1.0
# test_score_W0 : 0.9221501390176089
# test_score_W': 0.9647822057460612
# class_num*x*(optimize_W.split_num +1)320
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.08874329958308518
# right_data0_score_W0 1.0
# error_data0_score_W1 0.854586129753915
# error_data0_score_W0 0.4899328859060403
# combinedweight shape 0: (180, 22)
# right_data0_score_W' 0.9555555555555556
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8923076923076924
# error_data1_score_W0 0.4461538461538462
# combinedweight shape1 : (270, 22)
# right_data1_score_W' 0.743455497382199
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.7142857142857143
# combinedweight shape1 : (360, 22)
# right_data2_score_W' 0.7758620689655172
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9112567004169149
# all_train_score_W': 1.0
# test_score_W0 : 0.9096385542168675
# test_score_W': 0.9624652455977757
# class_num*x*(optimize_W.split_num +1)360
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.07782410164780623
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8392857142857143
# error_data0_score_W0 0.4923469387755102
# combinedweight shape 0: (200, 22)
# right_data0_score_W' 0.9543595263724435
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9206349206349206
# error_data1_score_W0 0.49206349206349204
# combinedweight shape1 : (300, 22)
# right_data1_score_W' 0.8297872340425532
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.8
# combinedweight shape1 : (400, 22)
# right_data2_score_W' 0.7241379310344828
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9221758983521937
# all_train_score_W': 1.0
# test_score_W0 : 0.927710843373494
# test_score_W': 0.9763670064874884
# class_num*x*(optimize_W.split_num +1)400
# neuron unit number: 110
# *******************
#
# Error Data percentage 0.06670637284097677
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8363095238095238
# error_data0_score_W0 0.4583333333333333
# combinedweight shape 0: (220, 22)
# right_data0_score_W' 0.9753243990640289
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9272727272727272
# error_data1_score_W0 0.41818181818181815
# combinedweight shape1 : (330, 22)
# right_data1_score_W' 0.8291814946619217
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (440, 22)
# right_data2_score_W' 0.8431372549019608
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9332936271590232
# all_train_score_W': 1.0
# test_score_W0 : 0.9341983317886933
# test_score_W': 0.9670991658943466
# class_num*x*(optimize_W.split_num +1)440
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.06650784196942625
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8686567164179104
# error_data0_score_W0 0.5462686567164179
# combinedweight shape 0: (240, 22)
# right_data0_score_W' 0.9729902169289664
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9772727272727273
# error_data1_score_W0 0.4772727272727273
# combinedweight shape1 : (360, 22)
# right_data1_score_W' 0.7731958762886598
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (480, 22)
# right_data2_score_W' 0.7441860465116279
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9334921580305737
# all_train_score_W': 1.0
# test_score_W0 : 0.9365152919369787
# test_score_W': 0.964318813716404
# class_num*x*(optimize_W.split_num +1)480
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.0631328171530673
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8207547169811321
# error_data0_score_W0 0.48742138364779874
# combinedweight shape 0: (260, 22)
# right_data0_score_W' 0.9694850603941513
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9649122807017544
# error_data1_score_W0 0.49122807017543857
# combinedweight shape1 : (390, 22)
# right_data1_score_W' 0.7509578544061303
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (520, 22)
# right_data2_score_W' 0.7636363636363637
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9368671828469327
# all_train_score_W': 1.0
# test_score_W0 : 0.9323447636700649
# test_score_W': 0.9657089898053753
# class_num*x*(optimize_W.split_num +1)520
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.07087552114353782
# right_data0_score_W0 1.0
# error_data0_score_W1 0.907563025210084
# error_data0_score_W0 0.4649859943977591
# combinedweight shape 0: (280, 22)
# right_data0_score_W' 0.9532051282051283
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.48484848484848486
# combinedweight shape1 : (420, 22)
# right_data1_score_W' 0.8364197530864198
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9291244788564622
# all_train_score_W': 1.0
# test_score_W0 : 0.9272474513438369
# test_score_W': 0.9772937905468025
# class_num*x*(optimize_W.split_num +1)420
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.06670637284097677
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8511904761904762
# error_data0_score_W0 0.5476190476190477
# combinedweight shape 0: (300, 22)
# right_data0_score_W' 0.9580940225483939
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.96
# error_data1_score_W0 0.44
# combinedweight shape1 : (450, 22)
# right_data1_score_W' 0.8461538461538461
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (600, 22)
# right_data2_score_W' 0.7291666666666666
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9332936271590232
# all_train_score_W': 1.0
# test_score_W0 : 0.9304911955514366
# test_score_W': 0.9680259499536608
# class_num*x*(optimize_W.split_num +1)600
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.053007742703990474
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8876404494382022
# error_data0_score_W0 0.449438202247191
# combinedweight shape 0: (320, 22)
# right_data0_score_W' 0.9637316561844864
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9666666666666667
# error_data1_score_W0 0.5
# combinedweight shape1 : (480, 22)
# right_data1_score_W' 0.7679324894514767
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (640, 22)
# right_data2_score_W' 0.8275862068965517
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9469922572960096
# all_train_score_W': 1.0
# test_score_W0 : 0.9476367006487488
# test_score_W': 0.9708063021316033
# class_num*x*(optimize_W.split_num +1)640
# neuron unit number: 170
# *******************
#
# Error Data percentage 0.07008139765733572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8101983002832861
# error_data0_score_W0 0.48441926345609065
# combinedweight shape 0: (340, 22)
# right_data0_score_W' 0.9611443210930828
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9253731343283582
# error_data1_score_W0 0.417910447761194
# combinedweight shape1 : (510, 22)
# right_data1_score_W' 0.8041958041958042
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.8
# combinedweight shape1 : (680, 22)
# right_data2_score_W' 0.7903225806451613
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9299186023426643
# all_train_score_W': 1.0
# test_score_W0 : 0.9318813716404077
# test_score_W': 0.963855421686747
# class_num*x*(optimize_W.split_num +1)680
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.05122096486003574
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8798449612403101
# error_data0_score_W0 0.5193798449612403
# combinedweight shape 0: (360, 22)
# right_data0_score_W' 0.9581502406361163
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.967741935483871
# error_data1_score_W0 0.5161290322580645
# combinedweight shape1 : (540, 22)
# right_data1_score_W' 0.788546255506608
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (720, 22)
# right_data2_score_W' 0.8333333333333334
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9487790351399643
# all_train_score_W': 1.0
# test_score_W0 : 0.9499536607970342
# test_score_W': 0.974050046339203
# class_num*x*(optimize_W.split_num +1)720
# neuron unit number: 190
# *******************
#
# Error Data percentage 0.06829461981338097
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8895348837209303
# error_data0_score_W0 0.47093023255813954
# combinedweight shape 0: (380, 22)
# right_data0_score_W' 0.9659066695077776
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9736842105263158
# error_data1_score_W0 0.5
# combinedweight shape1 : (570, 22)
# right_data1_score_W' 0.7091503267973857
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (760, 22)
# right_data2_score_W' 0.918918918918919
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.931705380186619
# all_train_score_W': 1.0
# test_score_W0 : 0.9392956441149212
# test_score_W': 0.9745134383688601
# class_num*x*(optimize_W.split_num +1)760
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.06948580504268413
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8628571428571429
# error_data0_score_W0 0.5485714285714286
# combinedweight shape 0: (400, 22)
# right_data0_score_W' 0.9694900789417538
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9791666666666666
# error_data1_score_W0 0.5833333333333334
# combinedweight shape1 : (600, 22)
# right_data1_score_W' 0.8509933774834437
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (800, 22)
# right_data2_score_W' 0.851063829787234
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9305141949573159
# all_train_score_W': 1.0
# test_score_W0 : 0.9355885078776645
# test_score_W': 0.9745134383688601
# class_num*x*(optimize_W.split_num +1)800
# neuron unit number: 210
# *******************
#
# Error Data percentage 0.0585666071074052
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8305084745762712
# error_data0_score_W0 0.5322033898305085
# combinedweight shape 0: (420, 22)
# right_data0_score_W' 0.9740615773935049
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.88
# error_data1_score_W0 0.44
# combinedweight shape1 : (630, 22)
# right_data1_score_W' 0.8081632653061225
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.6666666666666666
# combinedweight shape1 : (840, 22)
# right_data2_score_W' 0.7727272727272727
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9414333928925948
# all_train_score_W': 1.0
# test_score_W0 : 0.9494902687673772
# test_score_W': 0.9763670064874884
# class_num*x*(optimize_W.split_num +1)840
# neuron unit number: 220
# *******************
#
# Error Data percentage 0.06948580504268413
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8657142857142858
# error_data0_score_W0 0.6285714285714286
# combinedweight shape 0: (440, 22)
# right_data0_score_W' 0.9652229571154256
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6382978723404256
# combinedweight shape1 : (660, 22)
# right_data1_score_W' 0.7755775577557755
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9305141949573159
# all_train_score_W': 1.0
# test_score_W0 : 0.9291010194624653
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)660
# neuron unit number: 230
# *******************
#
# Error Data percentage 0.06988286678578519
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8039772727272727
# error_data0_score_W0 0.4602272727272727
# combinedweight shape 0: (460, 22)
# right_data0_score_W' 0.9562433297758804
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8985507246376812
# error_data1_score_W0 0.4782608695652174
# combinedweight shape1 : (690, 22)
# right_data1_score_W' 0.7809187279151943
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (920, 22)
# right_data2_score_W' 0.7580645161290323
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9301171332142149
# all_train_score_W': 1.0
# test_score_W0 : 0.9300278035217794
# test_score_W': 0.9749768303985171
# class_num*x*(optimize_W.split_num +1)920
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.0631328171530673
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8836477987421384
# error_data0_score_W0 0.48742138364779874
# combinedweight shape 0: (480, 22)
# right_data0_score_W' 0.9724517906336089
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.972972972972973
# error_data1_score_W0 0.5135135135135135
# combinedweight shape1 : (720, 22)
# right_data1_score_W' 0.7615658362989324
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (960, 22)
# right_data2_score_W' 0.8888888888888888
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9368671828469327
# all_train_score_W': 1.0
# test_score_W0 : 0.9365152919369787
# test_score_W': 0.9721964782205746
# class_num*x*(optimize_W.split_num +1)960
# neuron unit number: 250
# *******************
#
# Error Data percentage 0.053404804447091524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8847583643122676
# error_data0_score_W0 0.49814126394052044
# combinedweight shape 0: (500, 22)
# right_data0_score_W' 0.9538590604026845
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9354838709677419
# error_data1_score_W0 0.4838709677419355
# combinedweight shape1 : (750, 22)
# right_data1_score_W' 0.7563025210084033
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1000, 22)
# right_data2_score_W' 0.8275862068965517
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9465951955529085
# all_train_score_W': 1.0
# test_score_W0 : 0.9392956441149212
# test_score_W': 0.9661723818350324
# class_num*x*(optimize_W.split_num +1)1000
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.057375421878102045
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8512110726643599
# error_data0_score_W0 0.47750865051903113
# combinedweight shape 0: (520, 22)
# right_data0_score_W' 0.9561920808761584
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9534883720930233
# error_data1_score_W0 0.4186046511627907
# combinedweight shape1 : (780, 22)
# right_data1_score_W' 0.8048780487804879
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1040, 22)
# right_data2_score_W' 0.8292682926829268
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9426245781218979
# all_train_score_W': 1.0
# test_score_W0 : 0.9402224281742354
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)1040
# neuron unit number: 270
# *******************
#
# Error Data percentage 0.047845940043676795
# right_data0_score_W0 1.0
# error_data0_score_W1 0.91701244813278
# error_data0_score_W0 0.4896265560165975
# combinedweight shape 0: (540, 22)
# right_data0_score_W' 0.9620517097581318
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.65
# combinedweight shape1 : (810, 22)
# right_data1_score_W' 0.8009049773755657
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9521540599563232
# all_train_score_W': 1.0
# test_score_W0 : 0.9527340129749768
# test_score_W': 0.9735866543095458
# class_num*x*(optimize_W.split_num +1)810
# neuron unit number: 280
# *******************
#
# Error Data percentage 0.06253722453841572
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8888888888888888
# error_data0_score_W0 0.46984126984126984
# combinedweight shape 0: (560, 22)
# right_data0_score_W' 0.9610334603981364
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9714285714285714
# error_data1_score_W0 0.4857142857142857
# combinedweight shape1 : (840, 22)
# right_data1_score_W' 0.7642857142857142
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1120, 22)
# right_data2_score_W' 0.8235294117647058
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9374627754615843
# all_train_score_W': 1.0
# test_score_W0 : 0.9369786839666358
# test_score_W': 0.9759036144578314
# class_num*x*(optimize_W.split_num +1)1120
# neuron unit number: 290
# *******************
#
# Error Data percentage 0.0639269406392694
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9037267080745341
# error_data0_score_W0 0.4906832298136646
# combinedweight shape 0: (580, 22)
# right_data0_score_W' 0.9635206786850478
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.967741935483871
# error_data1_score_W0 0.45161290322580644
# combinedweight shape1 : (870, 22)
# right_data1_score_W' 0.7491408934707904
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1160, 22)
# right_data2_score_W' 0.8666666666666667
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9360730593607306
# all_train_score_W': 1.0
# test_score_W0 : 0.9388322520852641
# test_score_W': 0.9745134383688601
# class_num*x*(optimize_W.split_num +1)1160
# neuron unit number: 300
# *******************
#
# Error Data percentage 0.048243001786777845
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8765432098765432
# error_data0_score_W0 0.5267489711934157
# combinedweight shape 0: (600, 22)
# right_data0_score_W' 0.9747601168126825
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (900, 22)
# right_data1_score_W' 0.812206572769953
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9517569982132221
# all_train_score_W': 1.0
# test_score_W0 : 0.9476367006487488
# test_score_W': 0.9698795180722891
# class_num*x*(optimize_W.split_num +1)900
# neuron unit number: 310
# *******************
#
# Error Data percentage 0.053801866190192574
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8302583025830258
# error_data0_score_W0 0.5498154981549815
# combinedweight shape 0: (620, 22)
# right_data0_score_W' 0.9414603441040705
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9565217391304348
# error_data1_score_W0 0.4782608695652174
# combinedweight shape1 : (930, 22)
# right_data1_score_W' 0.68
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1240, 22)
# right_data2_score_W' 0.9545454545454546
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9461981338098074
# all_train_score_W': 1.0
# test_score_W0 : 0.9406858202038925
# test_score_W': 0.9675625579240037
# class_num*x*(optimize_W.split_num +1)1240
# neuron unit number: 320
# *******************
#
# Error Data percentage 0.0760373238038515
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8590078328981723
# error_data0_score_W0 0.43342036553524804
# combinedweight shape 0: (640, 22)
# right_data0_score_W' 0.961108723678556
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9629629629629629
# error_data1_score_W0 0.5740740740740741
# combinedweight shape1 : (960, 22)
# right_data1_score_W' 0.7082066869300911
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1280, 22)
# right_data2_score_W' 0.8846153846153846
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9239626761961485
# all_train_score_W': 1.0
# test_score_W0 : 0.9267840593141798
# test_score_W': 0.9721964782205746
# class_num*x*(optimize_W.split_num +1)1280
# neuron unit number: 330
# *******************
#
# Error Data percentage 0.061544570180663095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8451612903225807
# error_data0_score_W0 0.4806451612903226
# combinedweight shape 0: (660, 22)
# right_data0_score_W' 0.9598053733869262
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9166666666666666
# error_data1_score_W0 0.4375
# combinedweight shape1 : (990, 22)
# right_data1_score_W' 0.7557251908396947
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1320, 22)
# right_data2_score_W' 0.7954545454545454
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9384554298193369
# all_train_score_W': 1.0
# test_score_W0 : 0.9457831325301205
# test_score_W': 0.9731232622798888
# class_num*x*(optimize_W.split_num +1)1320
# neuron unit number: 340
# *******************
#
# Error Data percentage 0.05141949573158626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9111969111969112
# error_data0_score_W0 0.4594594594594595
# combinedweight shape 0: (680, 22)
# right_data0_score_W' 0.9581414817915446
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5217391304347826
# combinedweight shape1 : (1020, 22)
# right_data1_score_W' 0.6949152542372882
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9485805042684138
# all_train_score_W': 1.0
# test_score_W0 : 0.9494902687673772
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)1020
# neuron unit number: 350
# *******************
#
# Error Data percentage 0.0631328171530673
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8364779874213837
# error_data0_score_W0 0.5094339622641509
# combinedweight shape 0: (700, 22)
# right_data0_score_W' 0.9743589743589743
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9807692307692307
# error_data1_score_W0 0.4807692307692308
# combinedweight shape1 : (1050, 22)
# right_data1_score_W' 0.8308270676691729
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1400, 22)
# right_data2_score_W' 0.8235294117647058
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9368671828469327
# all_train_score_W': 1.0
# test_score_W0 : 0.9476367006487488
# test_score_W': 0.9772937905468025
# class_num*x*(optimize_W.split_num +1)1400
# neuron unit number: 360
# *******************
#
# Error Data percentage 0.058368076235854674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 0.5102040816326531
# combinedweight shape 0: (720, 22)
# right_data0_score_W' 0.9563567362428842
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5238095238095238
# combinedweight shape1 : (1080, 22)
# right_data1_score_W' 0.7142857142857143
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9416319237641453
# all_train_score_W': 1.0
# test_score_W0 : 0.9485634847080631
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)1080
# neuron unit number: 370
# *******************
#
# Error Data percentage 0.05598570577724836
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9219858156028369
# error_data0_score_W0 0.4929078014184397
# combinedweight shape 0: (740, 22)
# right_data0_score_W' 0.9533123028391167
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5909090909090909
# combinedweight shape1 : (1110, 22)
# right_data1_score_W' 0.7346153846153847
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9440142942227516
# all_train_score_W': 1.0
# test_score_W0 : 0.9425393883225208
# test_score_W': 0.9726598702502317
# class_num*x*(optimize_W.split_num +1)1110
# neuron unit number: 380
# *******************
#
# Error Data percentage 0.057772483621203095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9003436426116839
# error_data0_score_W0 0.49140893470790376
# combinedweight shape 0: (760, 22)
# right_data0_score_W' 0.950063211125158
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5172413793103449
# combinedweight shape1 : (1140, 22)
# right_data1_score_W' 0.7786259541984732
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9422275163787969
# all_train_score_W': 1.0
# test_score_W0 : 0.9402224281742354
# test_score_W': 0.9735866543095458
# class_num*x*(optimize_W.split_num +1)1140
# neuron unit number: 390
# *******************
#
# Error Data percentage 0.06551518761167362
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8696969696969697
# error_data0_score_W0 0.5272727272727272
# combinedweight shape 0: (780, 22)
# right_data0_score_W' 0.964308476736775
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8604651162790697
# error_data1_score_W0 0.3953488372093023
# combinedweight shape1 : (1170, 22)
# right_data1_score_W' 0.8432055749128919
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.6666666666666666
# combinedweight shape1 : (1560, 22)
# right_data2_score_W' 0.7567567567567568
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9344848123883264
# all_train_score_W': 1.0
# test_score_W0 : 0.9365152919369787
# test_score_W': 0.9754402224281742
# class_num*x*(optimize_W.split_num +1)1560
# neuron unit number: 400
# *******************
#
# Error Data percentage 0.053801866190192574
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8634686346863468
# error_data0_score_W0 0.5202952029520295
# combinedweight shape 0: (800, 22)
# right_data0_score_W' 0.9643306756189677
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5405405405405406
# combinedweight shape1 : (1200, 22)
# right_data1_score_W' 0.7777777777777778
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9461981338098074
# all_train_score_W': 1.0
# test_score_W0 : 0.9494902687673772
# test_score_W': 0.9777571825764597
# class_num*x*(optimize_W.split_num +1)1200
# neuron unit number: 410
# *******************
#
# Error Data percentage 0.057772483621203095
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8969072164948454
# error_data0_score_W0 0.5257731958762887
# combinedweight shape 0: (820, 22)
# right_data0_score_W' 0.9633375474083439
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9666666666666667
# error_data1_score_W0 0.5666666666666667
# combinedweight shape1 : (1230, 22)
# right_data1_score_W' 0.7701149425287356
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1640, 22)
# right_data2_score_W' 0.9655172413793104
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9422275163787969
# all_train_score_W': 1.0
# test_score_W0 : 0.943002780352178
# test_score_W': 0.9708063021316033
# class_num*x*(optimize_W.split_num +1)1640
# neuron unit number: 420
# *******************
#
# Error Data percentage 0.0669049037125273
# right_data0_score_W0 1.0
# error_data0_score_W1 0.884272997032641
# error_data0_score_W0 0.5548961424332344
# combinedweight shape 0: (840, 22)
# right_data0_score_W' 0.953404255319149
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9487179487179487
# error_data1_score_W0 0.5128205128205128
# combinedweight shape1 : (1260, 22)
# right_data1_score_W' 0.761744966442953
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1680, 22)
# right_data2_score_W' 0.8378378378378378
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9330950962874727
# all_train_score_W': 1.0
# test_score_W0 : 0.9416126042632067
# test_score_W': 0.9763670064874884
# class_num*x*(optimize_W.split_num +1)1680
# neuron unit number: 430
# *******************
#
# Error Data percentage 0.06412547151081993
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8823529411764706
# error_data0_score_W0 0.4891640866873065
# combinedweight shape 0: (860, 22)
# right_data0_score_W' 0.9694526941026729
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9473684210526315
# error_data1_score_W0 0.5
# combinedweight shape1 : (1290, 22)
# right_data1_score_W' 0.7719298245614035
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1720, 22)
# right_data2_score_W' 0.8611111111111112
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9358745284891801
# all_train_score_W': 1.0
# test_score_W0 : 0.9406858202038925
# test_score_W': 0.9708063021316033
# class_num*x*(optimize_W.split_num +1)1720
# neuron unit number: 440
# *******************
#
# Error Data percentage 0.0730593607305936
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8858695652173914
# error_data0_score_W0 0.5489130434782609
# combinedweight shape 0: (880, 22)
# right_data0_score_W' 0.9653030627543371
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9523809523809523
# error_data1_score_W0 0.5714285714285714
# combinedweight shape1 : (1320, 22)
# right_data1_score_W' 0.8343558282208589
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1760, 22)
# right_data2_score_W' 0.875
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9269406392694064
# all_train_score_W': 1.0
# test_score_W0 : 0.9202965708989805
# test_score_W': 0.969416126042632
# class_num*x*(optimize_W.split_num +1)1760
# neuron unit number: 450
# *******************
#
# Error Data percentage 0.058368076235854674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8639455782312925
# error_data0_score_W0 0.46258503401360546
# combinedweight shape 0: (900, 22)
# right_data0_score_W' 0.9645793801391525
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4
# combinedweight shape1 : (1350, 22)
# right_data1_score_W' 0.7244094488188977
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9416319237641453
# all_train_score_W': 1.0
# test_score_W0 : 0.9457831325301205
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)1350
# neuron unit number: 460
# *******************
#
# Error Data percentage 0.05717689100655152
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9097222222222222
# error_data0_score_W0 0.5416666666666666
# combinedweight shape 0: (920, 22)
# right_data0_score_W' 0.959991577174142
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (1380, 22)
# right_data1_score_W' 0.7786259541984732
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9428231089934485
# all_train_score_W': 1.0
# test_score_W0 : 0.9388322520852641
# test_score_W': 0.9721964782205746
# class_num*x*(optimize_W.split_num +1)1380
# neuron unit number: 470
# *******************
#
# Error Data percentage 0.052809211832439945
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8759398496240601
# error_data0_score_W0 0.45864661654135336
# combinedweight shape 0: (940, 22)
# right_data0_score_W' 0.9595472647243765
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9393939393939394
# error_data1_score_W0 0.42424242424242425
# combinedweight shape1 : (1410, 22)
# right_data1_score_W' 0.7253218884120172
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1880, 22)
# right_data2_score_W' 0.967741935483871
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9471907881675601
# all_train_score_W': 1.0
# test_score_W0 : 0.9518072289156626
# test_score_W': 0.9721964782205746
# class_num*x*(optimize_W.split_num +1)1880
# neuron unit number: 480
# *******************
#
# Error Data percentage 0.053404804447091524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9256505576208178
# error_data0_score_W0 0.4684014869888476
# combinedweight shape 0: (960, 22)
# right_data0_score_W' 0.9580536912751678
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.45
# combinedweight shape1 : (1440, 22)
# right_data1_score_W' 0.7550200803212851
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9465951955529085
# all_train_score_W': 1.0
# test_score_W0 : 0.9457831325301205
# test_score_W': 0.974050046339203
# class_num*x*(optimize_W.split_num +1)1440
# neuron unit number: 490
# *******************
#
# Error Data percentage 0.05082390311693468
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8984375
# error_data0_score_W0 0.51171875
# combinedweight shape 0: (980, 22)
# right_data0_score_W' 0.9702991006065677
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9615384615384616
# error_data1_score_W0 0.6153846153846154
# combinedweight shape1 : (1470, 22)
# right_data1_score_W' 0.6782608695652174
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (1960, 22)
# right_data2_score_W' 0.96
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9491760968830654
# all_train_score_W': 1.0
# test_score_W0 : 0.9494902687673772
# test_score_W': 0.9698795180722891
# class_num*x*(optimize_W.split_num +1)1960
# neuron unit number: 500
# *******************
#
# Error Data percentage 0.05558864403414731
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8714285714285714
# error_data0_score_W0 0.5142857142857142
# combinedweight shape 0: (1000, 22)
# right_data0_score_W' 0.9489173849064536
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9722222222222222
# error_data1_score_W0 0.5
# combinedweight shape1 : (1500, 22)
# right_data1_score_W' 0.819672131147541
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (2000, 22)
# right_data2_score_W' 0.8285714285714286
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9444113559658527
# all_train_score_W': 1.0
# test_score_W0 : 0.9425393883225208
# test_score_W': 0.9698795180722891
# class_num*x*(optimize_W.split_num +1)2000
# neuron unit number: 510
# *******************
#
# Error Data percentage 0.049632717887631524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.872
# error_data0_score_W0 0.488
# combinedweight shape 0: (1020, 22)
# right_data0_score_W' 0.9680384374347191
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (1530, 22)
# right_data1_score_W' 0.7477064220183486
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9503672821123684
# all_train_score_W': 1.0
# test_score_W0 : 0.9420759962928638
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)1530
# neuron unit number: 520
# *******************
#
# Error Data percentage 0.07027992852888625
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8728813559322034
# error_data0_score_W0 0.5310734463276836
# combinedweight shape 0: (1040, 22)
# right_data0_score_W' 0.947896647448217
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9555555555555556
# error_data1_score_W0 0.4
# combinedweight shape1 : (1560, 22)
# right_data1_score_W' 0.8090614886731392
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (2080, 22)
# right_data2_score_W' 0.813953488372093
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.9297200714711138
# all_train_score_W': 1.0
# test_score_W0 : 0.9240037071362373
# test_score_W': 0.969416126042632
# class_num*x*(optimize_W.split_num +1)2080
# neuron unit number: 530
# *******************
#
# Error Data percentage 0.05519158229104626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8776978417266187
# error_data0_score_W0 0.49280575539568344
# combinedweight shape 0: (1060, 22)
# right_data0_score_W' 0.9642782097079219
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4411764705882353
# combinedweight shape1 : (1590, 22)
# right_data1_score_W' 0.7950819672131147
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9448084177089537
# all_train_score_W': 1.0
# test_score_W0 : 0.9541241890639481
# test_score_W': 0.9786839666357738
# class_num*x*(optimize_W.split_num +1)1590
# neuron unit number: 540
# *******************
#
# Error Data percentage 0.049632717887631524
# right_data0_score_W0 1.0
# error_data0_score_W1 0.884
# error_data0_score_W0 0.5
# combinedweight shape 0: (1080, 22)
# right_data0_score_W' 0.9590557760601629
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6551724137931034
# combinedweight shape1 : (1620, 22)
# right_data1_score_W' 0.7692307692307693
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9503672821123684
# all_train_score_W': 1.0
# test_score_W0 : 0.943002780352178
# test_score_W': 0.968952734012975
# class_num*x*(optimize_W.split_num +1)1620
# neuron unit number: 550
# *******************
# Error Data percentage 0.05102243398848521
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8910505836575876
# error_data0_score_W0 0.48249027237354086
# combinedweight shape 0: (1100, 22)
# right_data0_score_W' 0.947907949790795
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.39285714285714285
# combinedweight shape1 : (1650, 22)
# right_data1_score_W' 0.7467248908296943
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9489775660115148
# all_train_score_W': 1.0
# test_score_W0 : 0.9504170528266914
# test_score_W': 0.9717330861909175
# class_num*x*(optimize_W.split_num +1)1650
# neuron unit number: 560
# *******************
#
# Error Data percentage 0.054198927933293624
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8864468864468864
# error_data0_score_W0 0.5347985347985348
# combinedweight shape 0: (1120, 22)
# right_data0_score_W' 0.959487825356843
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5483870967741935
# combinedweight shape1 : (1680, 22)
# right_data1_score_W' 0.8099173553719008
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9458010720667064
# all_train_score_W': 1.0
# test_score_W0 : 0.9420759962928638
# test_score_W': 0.9763670064874884
# class_num*x*(optimize_W.split_num +1)1680
# neuron unit number: 570
# *******************
#
# Error Data percentage 0.06273575540996625
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9082278481012658
# error_data0_score_W0 0.5
# combinedweight shape 0: (1140, 22)
# right_data0_score_W' 0.969074348654946
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4827586206896552
# combinedweight shape1 : (1710, 22)
# right_data1_score_W' 0.7909407665505227
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9372642445900338
# all_train_score_W': 1.0
# test_score_W0 : 0.9457831325301205
# test_score_W': 0.9759036144578314
# class_num*x*(optimize_W.split_num +1)1710
# neuron unit number: 580
# *******************
#
# Error Data percentage 0.048243001786777845
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9135802469135802
# error_data0_score_W0 0.5761316872427984
# combinedweight shape 0: (1160, 22)
# right_data0_score_W' 0.9453483521068001
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5238095238095238
# combinedweight shape1 : (1740, 22)
# right_data1_score_W' 0.7792792792792793
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9517569982132221
# all_train_score_W': 1.0
# test_score_W0 : 0.9518072289156626
# test_score_W': 0.9777571825764597
# class_num*x*(optimize_W.split_num +1)1740
# neuron unit number: 590
# *******************
#
# Error Data percentage 0.04189001389716101
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8957345971563981
# error_data0_score_W0 0.5781990521327014
# combinedweight shape 0: (1180, 22)
# right_data0_score_W' 0.9730625777041028
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5909090909090909
# combinedweight shape1 : (1770, 22)
# right_data1_score_W' 0.7619047619047619
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.958109986102839
# all_train_score_W': 1.0
# test_score_W0 : 0.9573679332715477
# test_score_W': 0.9768303985171455
# class_num*x*(optimize_W.split_num +1)1770
# neuron unit number: 600
# *******************
#
# Error Data percentage 0.052412150089338895
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8939393939393939
# error_data0_score_W0 0.4734848484848485
# combinedweight shape 0: (1200, 22)
# right_data0_score_W' 0.9683637125497591
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (1800, 22)
# right_data1_score_W' 0.7627118644067796
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9475878499106611
# all_train_score_W': 1.0
# test_score_W0 : 0.9481000926784059
# test_score_W': 0.9754402224281742
# class_num*x*(optimize_W.split_num +1)1800
# s 80  value 0.9647822057460612
# s 140  value 0.9666357738646896
# s 180  value 0.9629286376274329
# s 200  value 0.9721964782205746
# s 240  value 0.9712696941612604
# s 250  value 0.9675625579240037
# s 280  value 0.9606116774791473
# s 320  value 0.9647822057460612
# s 360  value 0.9624652455977757
# s 400  value 0.9763670064874884
# s 420  value 0.9772937905468025
# s 440  value 0.9670991658943466
# s 480  value 0.964318813716404
# s 520  value 0.9657089898053753
# s 600  value 0.9680259499536608
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  15.0  0.936824  0.010536  0.002720   0.930990  0.942659
# 1  test_score_W'  15.0  0.967470  0.004883  0.001261   0.964766  0.970174
# 2       combined  30.0  0.952147  0.017549  0.003204   0.945594  0.958700
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0306
# 1                          Degrees of freedom =   28.0000
# 2                                           t =  -10.2210
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -3.7322
# 7                                   Hedge's g =   -3.6313
# 8                               Glass's delta =   -2.9087
# 9                                 Pearson's r =    0.8880
