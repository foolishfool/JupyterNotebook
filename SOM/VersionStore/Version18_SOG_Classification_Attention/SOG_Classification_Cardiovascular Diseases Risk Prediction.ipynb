# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv = csv.sample(int(csv.shape[0]*0.01))
csv_original_encode = csv


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"General_Health")
# Out:
# self.continuous_feature_num 7
# self.data_discrete_indexes ['Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex', 'Age_Category', 'Smoking_History']

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 1

#features = 2 #[0,1,2,3,5,6,7,8,9,10]

features_chosen =[0,1,2,3,5,6,7,8,9,10]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features_chosen,feature_combination_number)
# Out:
# Experiment number: 1
# accuracy_score_orignial 0.33585313174946
# recall_score_original 0.24601207364386876
# precision_score_original 0.250559585342194
# f1_score_original 0.2449493320111213
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33585313174946
# recall_score_sog 0.24537689260320708
# precision_score_sog 0.25030958258249514
# f1_score_sog 0.24435505891805837
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# accuracy_score_orignial 0.3347732181425486
# recall_score_original 0.24555653448824888
# precision_score_original 0.2515951154467638
# f1_score_original 0.24498109985002997
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3304535637149028
# recall_score_sog 0.2439453962314467
# precision_score_sog 0.2503922185517278
# f1_score_sog 0.24376196354436072
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_orignial 0.326133909287257
# recall_score_original 0.2384865524747306
# precision_score_original 0.2417167232577139
# f1_score_original 0.2373136431892758
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33153347732181426
# recall_score_sog 0.24122903100853693
# precision_score_sog 0.24297021003909425
# f1_score_sog 0.23985796273119533
# Experiment number: 4
# accuracy_score_orignial 0.3326133909287257
# recall_score_original 0.2448574956707546
# precision_score_original 0.24950498411044078
# f1_score_original 0.24409050176079877
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33585313174946
# recall_score_sog 0.24749149552222685
# precision_score_sog 0.2544197094485252
# f1_score_sog 0.24706243868462652
# Experiment number: 5
# accuracy_score_orignial 0.3326133909287257
# recall_score_original 0.24405285378571273
# precision_score_original 0.24806407764079172
# f1_score_original 0.24294415042492434
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.326133909287257
# recall_score_sog 0.23971331477862057
# precision_score_sog 0.24329838725098663
# f1_score_sog 0.23904155015652395
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_orignial 0.3347732181425486
# recall_score_original 0.2453870736438688
# precision_score_original 0.24969602921513484
# f1_score_original 0.24430534729035408
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.32721382289416845
# recall_score_sog 0.24181773665697862
# precision_score_sog 0.2461120911312043
# f1_score_sog 0.24142109086670951
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# accuracy_score_orignial 0.3326133909287257
# recall_score_original 0.24527961608960275
# precision_score_original 0.2501002301685241
# f1_score_original 0.24459578267825188
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.32937365010799136
# recall_score_sog 0.24298351679882257
# precision_score_sog 0.2476381431918556
# f1_score_sog 0.24275369488054013
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# accuracy_score_orignial 0.33369330453563717
# recall_score_original 0.24328265176551075
# precision_score_original 0.24644538204210198
# f1_score_original 0.24179223166003805
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3369330453563715
# recall_score_sog 0.24773499518410125
# precision_score_sog 0.25002298336473355
# f1_score_sog 0.24660411782409203
# Experiment number: 9
# accuracy_score_orignial 0.3369330453563715
# recall_score_original 0.24837017622476293
# precision_score_original 0.2532633348875462
# f1_score_original 0.24760167098631083
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3347732181425486
# recall_score_sog 0.24589341392087297
# precision_score_sog 0.25121914787002203
# f1_score_sog 0.24495160311336744
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# accuracy_score_orignial 0.33585313174946
# recall_score_original 0.24601207364386876
# precision_score_original 0.250036440762817
# f1_score_original 0.2448245104107909
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3347732181425486
# recall_score_sog 0.24475189260320707
# precision_score_sog 0.2497413398118254
# f1_score_sog 0.24373648772898265
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# accuracy_score_orignial 0.33153347732181426
# recall_score_original 0.24228633246804687
# precision_score_original 0.24655337100689012
# f1_score_original 0.24128213520169392
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33585313174946
# recall_score_sog 0.2472794560284813
# precision_score_sog 0.25091021590580215
# f1_score_sog 0.24676583612632513
# Experiment number: 12
# accuracy_score_orignial 0.33585313174946
# recall_score_original 0.24601207364386876
# precision_score_original 0.250036440762817
# f1_score_original 0.2448245104107909
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33369330453563717
# recall_score_sog 0.245269435048941
# precision_score_sog 0.24850818036287597
# f1_score_sog 0.2444478458488045
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_orignial 0.34017278617710583
# recall_score_original 0.250329396082919
# precision_score_original 0.25564019569544427
# f1_score_original 0.24961352479273408
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33153347732181426
# recall_score_sog 0.24351309477193678
# precision_score_sog 0.24859314260318569
# f1_score_sog 0.24294259991197045
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# accuracy_score_orignial 0.3326133909287257
# recall_score_original 0.24527961608960275
# precision_score_original 0.25005378904565495
# f1_score_original 0.24459475344311601
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33369330453563717
# recall_score_sog 0.24607305580591476
# precision_score_sog 0.2532317308509232
# f1_score_sog 0.24582435945153785
# Experiment number: 15
# accuracy_score_orignial 0.33153347732181426
# recall_score_original 0.2433436339275567
# precision_score_original 0.24734128681681655
# f1_score_original 0.24231060368288415
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.326133909287257
# recall_score_sog 0.24102429694066654
# precision_score_sog 0.2454987429171826
# f1_score_sog 0.24077104200505223
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# accuracy_score_orignial 0.3326133909287257
# recall_score_original 0.24405285378571273
# precision_score_original 0.24744044596627926
# f1_score_original 0.24280986428206078
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3326133909287257
# recall_score_sog 0.24405285378571273
# precision_score_sog 0.25144502447975
# f1_score_sog 0.2436387971848696
# Experiment number: 17
# accuracy_score_orignial 0.3347732181425486
# recall_score_original 0.24669805580591478
# precision_score_original 0.2521254327578438
# f1_score_original 0.24600752213745136
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3347732181425486
# recall_score_sog 0.24547129350202482
# precision_score_sog 0.25196235068180844
# f1_score_sog 0.2447471176852707
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_orignial 0.3347732181425486
# recall_score_original 0.2453870736438688
# precision_score_original 0.24969602921513484
# f1_score_original 0.24430534729035408
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3326133909287257
# recall_score_sog 0.24544805580591475
# precision_score_sog 0.2526618931674096
# f1_score_sog 0.24520463419314034
# Not good accuracy result !!!!!
# Experiment number: 19
# accuracy_score_orignial 0.3282937365010799
# recall_score_original 0.24244273665697863
# precision_score_original 0.24670934976185147
# f1_score_original 0.24182220756653985
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3326133909287257
# recall_score_sog 0.24413707364386877
# precision_score_sog 0.25130691958086837
# f1_score_sog 0.24362873318269312
# Experiment number: 20
# accuracy_score_orignial 0.32937365010799136
# recall_score_original 0.2428140559544425
# precision_score_original 0.2466443574357319
# f1_score_original 0.2419448467281488
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.32937365010799136
# recall_score_sog 0.24382775763651893
# precision_score_sog 0.24831864061579623
# f1_score_sog 0.2436339340422525
# Experiment number: 21
# accuracy_score_orignial 0.33585313174946
# recall_score_original 0.24609629350202483
# precision_score_original 0.24933973574125087
# f1_score_original 0.24468717630948
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33153347732181426
# recall_score_sog 0.24351207364386881
# precision_score_sog 0.24839606448302104
# f1_score_sog 0.24247041510439896
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_orignial 0.33369330453563717
# recall_score_original 0.2447620736438688
# precision_score_original 0.2484988628585946
# f1_score_original 0.2435557406237232
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3326133909287257
# recall_score_sog 0.24544805580591475
# precision_score_sog 0.2519603401062163
# f1_score_sog 0.24505271500419026
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_orignial 0.33369330453563717
# recall_score_original 0.24501575434640493
# precision_score_original 0.2494799886404364
# f1_score_original 0.24408610916886925
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33585313174946
# recall_score_sog 0.24736367588663732
# precision_score_sog 0.24992156452000236
# f1_score_sog 0.24645006567357752
# Experiment number: 24
# accuracy_score_orignial 0.3369330453563715
# recall_score_original 0.24663707364386883
# precision_score_original 0.2510026610785495
# f1_score_original 0.24555866390128397
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3347732181425486
# recall_score_sog 0.24432977218435886
# precision_score_sog 0.2498377475096656
# f1_score_sog 0.24336473930925523
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# accuracy_score_orignial 0.33369330453563717
# recall_score_original 0.2447620736438688
# precision_score_original 0.2484988628585946
# f1_score_original 0.2435557406237232
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.32721382289416845
# recall_score_sog 0.24181773665697862
# precision_score_sog 0.24615506826088634
# f1_score_sog 0.24142248453481926
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# accuracy_score_orignial 0.33585313174946
# recall_score_original 0.24766095636660693
# precision_score_original 0.2531219319194779
# f1_score_original 0.24711224765568146
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33585313174946
# recall_score_sog 0.24634997420456095
# precision_score_sog 0.2530635539612785
# f1_score_sog 0.2458492113589447
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# accuracy_score_orignial 0.33369330453563717
# recall_score_original 0.2447620736438688
# precision_score_original 0.2479465000190527
# f1_score_original 0.24343253932496167
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3326133909287257
# recall_score_sog 0.24544805580591475
# precision_score_sog 0.2520016770631821
# f1_score_sog 0.24505063996516116
# Not good accuracy result !!!!!
# Experiment number: 28
# accuracy_score_orignial 0.3369330453563715
# recall_score_original 0.24705919406271698
# precision_score_original 0.25159810730644344
# f1_score_original 0.2460604532612881
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.33801295896328293
# recall_score_sog 0.2486978957447934
# precision_score_sog 0.2520370467387102
# f1_score_sog 0.2479285689126836
# Experiment number: 29
# accuracy_score_orignial 0.3326133909287257
# recall_score_original 0.24396863392755672
# precision_score_original 0.24865929860997968
# f1_score_original 0.2430722599137643
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.3304535637149028
# recall_score_sog 0.24280285378571276
# precision_score_sog 0.2483495285578619
# f1_score_sog 0.24197361125669473
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# accuracy_score_orignial 0.33369330453563717
# recall_score_original 0.24467785378571275
# precision_score_original 0.24914354302728955
# f1_score_original 0.2436842292779317
# self.train_discrete_extra_sog_fuzzy shape (2162, 165)
# accuracy_score_sog 0.326133909287257
# recall_score_sog 0.23962909492046452
# precision_score_sog 0.24371948609629768
# f1_score_sog 0.23913959305417692
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.33380129589632834
# all_recall_score_original mean 0.24504483033521127
# all_precision_score_original mean 0.24935040311327208
# all_f1_score_original mean 0.24405729152861255
# all_accuracy_score_sog mean 0.33236141108711303
# all_recall_score_sog mean 0.24441444156390682
# all_precision_score_sog mean 0.2494667577235065
# all_f1_score_sog mean 0.24379509707514252
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  30.0  0.333801  0.002769  0.000506   0.332767
# 1       all_accuracy_score_sog  30.0  0.332361  0.003411  0.000623   0.331088
# 2                     combined  60.0  0.333081  0.003165  0.000409   0.332264
#
#    Interval
# 0  0.334835
# 1  0.333635
# 2  0.333899
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...   0.0014
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.7949
# 3                           Two side test p value =    0.0779
# 4                          Difference < 0 p value =    0.9611
# 5                          Difference > 0 p value =    0.0389
# 6                                       Cohen's d =    0.4634
# 7                                       Hedge's g =    0.4574
# 8                                  Glass's delta1 =    0.5200
# 9                                Point-Biserial r =    0.2294
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  30.0  0.245045  0.002130  0.000389   0.244249
# 1       all_recall_score_sog  30.0  0.244414  0.002332  0.000426   0.243544
# 2                   combined  60.0  0.244730  0.002237  0.000289   0.244152
#
#    Interval
# 0  0.245840
# 1  0.245285
# 2  0.245308
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...   0.0006
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    1.0932
# 3                           Two side test p value =    0.2788
# 4                          Difference < 0 p value =    0.8606
# 5                          Difference > 0 p value =    0.1394
# 6                                       Cohen's d =    0.2823
# 7                                       Hedge's g =    0.2786
# 8                                  Glass's delta1 =    0.2959
# 9                                Point-Biserial r =    0.1421
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  30.0  0.249350  0.002596  0.000474
# 1       all_precision_score_sog  30.0  0.249467  0.003006  0.000549
# 2                      combined  60.0  0.249409  0.002785  0.000360
#
#    95% Conf.  Interval
# 0   0.248381  0.250320
# 1   0.248344  0.250589
# 2   0.248689  0.250128
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0001
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -0.1604
# 3                           Two side test p value =    0.8731
# 4                          Difference < 0 p value =    0.4365
# 5                          Difference > 0 p value =    0.5635
# 6                                       Cohen's d =   -0.0414
# 7                                       Hedge's g =   -0.0409
# 8                                  Glass's delta1 =   -0.0448
# 9                                Point-Biserial r =   -0.0211
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  30.0  0.244057  0.002216  0.000405   0.243230
# 1       all_f1_score_sog  30.0  0.243795  0.002314  0.000423   0.242931
# 2               combined  60.0  0.243926  0.002250  0.000290   0.243345
#
#    Interval
# 0  0.244885
# 1  0.244659
# 2  0.244507
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...   0.0003
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    0.4482
# 3                           Two side test p value =    0.6557
# 4                          Difference < 0 p value =    0.6722
# 5                          Difference > 0 p value =    0.3278
# 6                                       Cohen's d =    0.1157
# 7                                       Hedge's g =    0.1142
# 8                                  Glass's delta1 =    0.1183
# 9                                Point-Biserial r =    0.0588

# %%
dataread.PCA_Comparision()  #012  7,9,10 |  0,1,6,5,9,7 |2,1,6,7,3,8
# Out:
# Sorted feature index for component 0 [8, 10, 9, 7, 1, 6, 5, 3, 4, 0, 2]
# Sorted imporance porporation for component 0  [0.7061464484080805, 0.1333494563608742, 0.042708191838507374, 0.03806692905596888, 0.02922344501645236, 0.020535050134276072, 0.014105476639684493, 0.008274396641217827, 0.004923424755380287, 0.001681523321224056, 0.0009856578283340333]
# Sorted feature index for component 1 [1, 0, 6, 7, 9, 8, 10, 5, 3, 2, 4]
# Sorted imporance porporation for component 1  [0.5247028748449216, 0.13907251959310224, 0.08735035279684317, 0.0763708150067858, 0.05647283659073557, 0.05122611179839049, 0.020791241401855075, 0.018775567932885453, 0.013763932545863753, 0.0076159062874180845, 0.0038578412011987732]
# Sorted feature index for component 2 [3, 2, 4, 5, 7, 6, 1, 0, 8, 9, 10]
# Sorted imporance porporation for component 2  [0.5706266894288403, 0.14698186312653985, 0.11166627988181188, 0.04919362407736371, 0.035881080176908296, 0.0331193377481478, 0.027483593248370637, 0.010960286514387794, 0.01082429554922504, 0.0025600487846333692, 0.0007029014637711224]
# Sorted feature index for component 3 [4, 2, 1, 3, 0, 6, 7, 5, 10, 9, 8]
# Sorted imporance porporation for component 3  [0.3636456011235986, 0.3573937201270935, 0.1656199892249973, 0.03362254669087518, 0.02800817189645391, 0.01752293278991467, 0.012904782817055867, 0.008091380987593415, 0.006522862588480014, 0.006407861741301164, 0.0002601500126362474]
# Sorted feature index for component 4 [5, 3, 0, 8, 4, 2, 6, 1, 10, 9, 7]
# Sorted imporance porporation for component 4  [0.43492797742901623, 0.4319095214156588, 0.03550254971590324, 0.025828143644006058, 0.012985694205727557, 0.012708154991549519, 0.012350973039070193, 0.010666891433036169, 0.01040400522050118, 0.009884015183102932, 0.002832073722427935]
# Sorted feature index for component 5 [0, 4, 3, 6, 9, 7, 8, 10, 5, 2, 1]
# Sorted imporance porporation for component 5  [0.43610137652348724, 0.15334337975458714, 0.1158531609768668, 0.11278642249305086, 0.08896848093208275, 0.024762290117564475, 0.02136131155870908, 0.01746172133636836, 0.016954565060390225, 0.007061187976869506, 0.0053461032700234295]
# Sorted feature index for component 6 [4, 9, 10, 7, 6, 3, 8, 2, 1, 0, 5]
# Sorted imporance porporation for component 6  [0.6467633110681517, 0.11812790008965056, 0.05128740332952402, 0.04219944025616079, 0.032775096361552944, 0.030520003357834807, 0.027271887764823033, 0.022427169533868505, 0.01997584335237308, 0.005899625039594953, 0.002752319846465535]
# Sorted feature index for component 7 [3, 2, 1, 7, 8, 10, 6, 9, 5, 0, 4]
# Sorted imporance porporation for component 7  [0.33332360667084837, 0.1932248488919683, 0.156227510160224, 0.11470049112953656, 0.09571142635914144, 0.03142548250499232, 0.02279491099900729, 0.022493021251139837, 0.020116677635153617, 0.007405482824744511, 0.0025765415732440246]
# Sorted feature index for component 8 [1, 4, 3, 10, 2, 9, 6, 8, 0, 7, 5]
# Sorted imporance porporation for component 8  [0.544043969709029, 0.22617948308422847, 0.05818057030646034, 0.04450813029031901, 0.03552604786318403, 0.03338764443447842, 0.024050327912244387, 0.01973722459472982, 0.009608873216298362, 0.004520743758507702, 0.000256984830520301]
# Sorted feature index for component 9 [10, 9, 6, 3, 7, 4, 0, 8, 5, 2, 1]
# Sorted imporance porporation for component 9  [0.8002702564975068, 0.0548278946017915, 0.028729558865552552, 0.027376380741253446, 0.025773688563673514, 0.024295307975643072, 0.01998861881956679, 0.008242626793476548, 0.005309577030303298, 0.003787494430975542, 0.0013985956802566692]
# Sorted feature index for component 10 [3, 4, 2, 8, 10, 9, 6, 7, 0, 1, 5]
# Sorted imporance porporation for component 10  [0.4492591177529758, 0.24376293367725507, 0.1042203139524218, 0.08817899971772887, 0.056144455538717414, 0.03024950558834914, 0.014639018463501113, 0.010395325118061715, 0.0011586446973481442, 0.0011275607717414833, 0.0008641247218992979]
# [0.82039924 0.06514906 0.0346144  0.01709759 0.01633924 0.01166479
#  0.01060453 0.00875529 0.00592239 0.00513747 0.00431599]
