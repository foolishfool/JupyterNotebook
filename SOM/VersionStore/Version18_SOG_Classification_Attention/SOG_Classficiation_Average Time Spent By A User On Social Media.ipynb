# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# self.continuous_feature_num 2
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
#scope_num = 40
class_num = 9
best_num = 48
interval = 1


features_chosen = [0,1,2,3,4,5,6,7,8]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features_chosen,feature_combination_number)
# Out:
# Experiment number: 1
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10493628166464543
# precision_score_original 0.10544367027295819
# f1_score_original 0.10394919526422311
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.08666666666666667
# recall_score_sog 0.08572716442898999
# precision_score_sog 0.08683429586711498
# f1_score_sog 0.08563711273307269
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11649479395845184
# precision_score_original 0.11423308158325113
# f1_score_original 0.11354212491877266
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.0955505829407114
# precision_score_sog 0.09313931685224236
# f1_score_sog 0.09281685197325108
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_orignial 0.11333333333333333
# recall_score_original 0.11366252759085754
# precision_score_original 0.11568490758887497
# f1_score_original 0.11297457457475445
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09351261577427908
# precision_score_sog 0.096208048672747
# f1_score_sog 0.09369360676528501
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_orignial 0.12333333333333334
# recall_score_original 0.12437095527866318
# precision_score_original 0.12065704628764123
# f1_score_original 0.12066394921683694
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.1
# recall_score_sog 0.0996349018534617
# precision_score_sog 0.10225921406343755
# f1_score_sog 0.09967510209252047
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_orignial 0.11
# recall_score_original 0.11012935506258698
# precision_score_original 0.1102997255536311
# f1_score_original 0.10945459612450745
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11
# recall_score_sog 0.10866393172850237
# precision_score_sog 0.10938876363032636
# f1_score_sog 0.10744853799816034
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_orignial 0.08333333333333333
# recall_score_original 0.08199238188251035
# precision_score_original 0.08846648770969376
# f1_score_original 0.08307653735986195
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09784590081243226
# precision_score_sog 0.10004192658388816
# f1_score_sog 0.09679638635197461
# Experiment number: 7
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.1052293618596864
# precision_score_original 0.10837186009352437
# f1_score_original 0.10556987032547817
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11
# recall_score_sog 0.11016825951325614
# precision_score_sog 0.10880107704775867
# f1_score_sog 0.10862244770750418
# Experiment number: 8
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10871513356300376
# precision_score_original 0.1035398912510169
# f1_score_original 0.10366853823517203
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.1
# recall_score_sog 0.10087528306341695
# precision_score_sog 0.09639223318085105
# f1_score_sog 0.09658786443851795
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.10279848210037527
# precision_score_original 0.10216761435893805
# f1_score_original 0.10186403364223866
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11375527222383207
# precision_score_sog 0.1115121102925981
# f1_score_sog 0.11158811347072328
# Experiment number: 10
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.09295693053722127
# precision_score_original 0.09520985732812418
# f1_score_original 0.09087677796698664
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.1
# recall_score_sog 0.09981773041272704
# precision_score_sog 0.10043313436808024
# f1_score_sog 0.09850423013179292
# Experiment number: 11
# accuracy_score_orignial 0.1
# recall_score_original 0.10076570219403216
# precision_score_original 0.10326011383418772
# f1_score_original 0.09993286338551181
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09609781652124452
# precision_score_sog 0.09913666155364448
# f1_score_sog 0.09542803747110003
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10678422071255067
# precision_score_original 0.11009240088950233
# f1_score_original 0.1060930427925455
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10305782274595662
# precision_score_sog 0.10652520685059562
# f1_score_sog 0.1039139389469739
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.09426474612833641
# precision_score_original 0.09297812425347923
# f1_score_original 0.09276180261104466
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10966375375182003
# precision_score_sog 0.10499713870607758
# f1_score_sog 0.10586275447854987
# Experiment number: 14
# accuracy_score_orignial 0.11333333333333333
# recall_score_original 0.11379417667450123
# precision_score_original 0.1123069508268749
# f1_score_original 0.1118257465869843
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11192937903130601
# precision_score_sog 0.11926650746271782
# f1_score_sog 0.11410631169068969
# Not good recall_score result !!!!!
# Experiment number: 15
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.1039610767678719
# precision_score_original 0.1020296328801287
# f1_score_original 0.1015286623219789
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10273299294174885
# precision_score_sog 0.10438664040700742
# f1_score_sog 0.10261415310503669
# Not good recall_score result !!!!!
# Experiment number: 16
# accuracy_score_orignial 0.1
# recall_score_original 0.10002781444634049
# precision_score_original 0.10235360357864895
# f1_score_original 0.10004546629554172
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10382488883165016
# precision_score_sog 0.1047951377185657
# f1_score_sog 0.103107964690308
# Experiment number: 17
# accuracy_score_orignial 0.09666666666666666
# recall_score_original 0.0944969207350884
# precision_score_original 0.09910953150674845
# f1_score_original 0.09523312478219371
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.07333333333333333
# recall_score_sog 0.0728562976914904
# precision_score_sog 0.07708496275233548
# f1_score_sog 0.07345070824630648
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.10228167895510695
# precision_score_original 0.10554564235850786
# f1_score_original 0.10268783705174844
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10525847312104918
# precision_score_sog 0.09901534894693313
# f1_score_sog 0.10032862996641861
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# accuracy_score_orignial 0.07666666666666666
# recall_score_original 0.076005657690918
# precision_score_original 0.07572941206561896
# f1_score_original 0.07510408866230399
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10639904429204633
# precision_score_sog 0.1099458633884969
# f1_score_sog 0.10616465673009709
# Experiment number: 20
# accuracy_score_orignial 0.07666666666666666
# recall_score_original 0.07569310291166276
# precision_score_original 0.07797633049912032
# f1_score_original 0.07565193248689209
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10548351524517852
# precision_score_sog 0.10926880971638003
# f1_score_sog 0.1061736005144683
# Experiment number: 21
# accuracy_score_orignial 0.08666666666666667
# recall_score_original 0.08693713756256014
# precision_score_original 0.08799605488780252
# f1_score_original 0.08667871313176863
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.08666666666666667
# recall_score_sog 0.08647873581105496
# precision_score_sog 0.09049539138970034
# f1_score_sog 0.08723814755240661
# Not good recall_score result !!!!!
# Experiment number: 22
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.10396036128372167
# precision_score_original 0.1030663136034408
# f1_score_original 0.10128374547575826
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09182284344133568
# precision_score_sog 0.09770361360918636
# f1_score_sog 0.0921132853541412
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_orignial 0.09666666666666666
# recall_score_original 0.09663474265823828
# precision_score_original 0.09569517925079984
# f1_score_original 0.09431714555049737
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10316416157778564
# precision_score_sog 0.10725935656351725
# f1_score_sog 0.103936384731166
# Experiment number: 24
# accuracy_score_orignial 0.11666666666666667
# recall_score_original 0.11414042628545669
# precision_score_original 0.12029822998644472
# f1_score_original 0.11582427504205027
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.12333333333333334
# recall_score_sog 0.1220036865320841
# precision_score_sog 0.12413825797370867
# f1_score_sog 0.12150295329072754
# Experiment number: 25
# accuracy_score_orignial 0.10666666666666667
# recall_score_original 0.10624409725576055
# precision_score_original 0.10754701366819407
# f1_score_original 0.10622099114033057
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11456513320526167
# precision_score_sog 0.1141724183469914
# f1_score_sog 0.11335921970573908
# Experiment number: 26
# accuracy_score_orignial 0.09
# recall_score_original 0.09049170753869874
# precision_score_original 0.09124562292255461
# f1_score_original 0.08882322841085143
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.08333333333333333
# recall_score_sog 0.08294162811995807
# precision_score_sog 0.0831608546119744
# f1_score_sog 0.08242180734156729
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# accuracy_score_orignial 0.06666666666666667
# recall_score_original 0.06646427408766827
# precision_score_original 0.06917109689467413
# f1_score_original 0.06635134079888443
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.08
# recall_score_sog 0.07977476111772935
# precision_score_sog 0.08149287419064294
# f1_score_sog 0.07887238638335961
# Experiment number: 28
# accuracy_score_orignial 0.11
# recall_score_original 0.11181648904772636
# precision_score_original 0.10846913770870127
# f1_score_original 0.10793112013415637
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11666666666666667
# recall_score_sog 0.11646232886513481
# precision_score_sog 0.11271506271506272
# f1_score_sog 0.1126020768198971
# Experiment number: 29
# accuracy_score_orignial 0.11333333333333333
# recall_score_original 0.11440168979469181
# precision_score_original 0.11104156712852364
# f1_score_original 0.1097329743904054
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11409304781938318
# precision_score_sog 0.11042737180893593
# f1_score_sog 0.11080851777949831
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Experiment number: 30
# accuracy_score_orignial 0.11
# recall_score_original 0.11326306384622814
# precision_score_original 0.10941778412227586
# f1_score_original 0.1092041280749872
# self.train_discrete_extra_sog_fuzzy shape (700, 297)
# accuracy_score_sog 0.11
# recall_score_sog 0.11355940843770458
# precision_score_sog 0.10670626351158326
# f1_score_sog 0.1078823191062506
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.10111111111111111
# all_recall_score_original mean 0.10112384300250542
# all_precision_score_original mean 0.1016467961631294
# all_f1_score_original mean 0.09976241422517555
# all_accuracy_score_sog mean 0.10155555555555555
# all_recall_score_sog mean 0.10159071206175105
# all_precision_score_sog mean 0.1022567954261034
# all_f1_score_sog mean 0.10044193691891683
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  30.0  0.101111  0.013169  0.002404   0.096194
# 1       all_accuracy_score_sog  30.0  0.101556  0.011472  0.002094   0.097272
# 2                     combined  60.0  0.101333  0.012247  0.001581   0.098170
#
#    Interval
# 0  0.106029
# 1  0.105839
# 2  0.104497
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0004
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -0.1394
# 3                           Two side test p value =    0.8896
# 4                          Difference < 0 p value =    0.4448
# 5                          Difference > 0 p value =    0.5552
# 6                                       Cohen's d =   -0.0360
# 7                                       Hedge's g =   -0.0355
# 8                                  Glass's delta1 =   -0.0337
# 9                                Point-Biserial r =   -0.0183
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  30.0  0.101124  0.013505  0.002466   0.096081
# 1       all_recall_score_sog  30.0  0.101591  0.011730  0.002142   0.097211
# 2                   combined  60.0  0.101357  0.012543  0.001619   0.098117
#
#    Interval
# 0  0.106167
# 1  0.105971
# 2  0.104598
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0005
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -0.1430
# 3                           Two side test p value =    0.8868
# 4                          Difference < 0 p value =    0.4434
# 5                          Difference > 0 p value =    0.5566
# 6                                       Cohen's d =   -0.0369
# 7                                       Hedge's g =   -0.0364
# 8                                  Glass's delta1 =   -0.0346
# 9                                Point-Biserial r =   -0.0188
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  30.0  0.101647  0.012528  0.002287
# 1       all_precision_score_sog  30.0  0.102257  0.010930  0.001995
# 2                      combined  60.0  0.101952  0.011660  0.001505
#
#    95% Conf.  Interval
# 0   0.096969  0.106325
# 1   0.098176  0.106338
# 2   0.098940  0.104964
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0006
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -0.2010
# 3                           Two side test p value =    0.8414
# 4                          Difference < 0 p value =    0.4207
# 5                          Difference > 0 p value =    0.5793
# 6                                       Cohen's d =   -0.0519
# 7                                       Hedge's g =   -0.0512
# 8                                  Glass's delta1 =   -0.0487
# 9                                Point-Biserial r =   -0.0264
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  30.0  0.099762  0.012830  0.002342   0.094971
# 1       all_f1_score_sog  30.0  0.100442  0.011176  0.002040   0.096269
# 2               combined  60.0  0.100102  0.011934  0.001541   0.097019
#
#    Interval
# 0  0.104553
# 1  0.104615
# 2  0.103185
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0007
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -0.2187
# 3                           Two side test p value =    0.8276
# 4                          Difference < 0 p value =    0.4138
# 5                          Difference > 0 p value =    0.5862
# 6                                       Cohen's d =   -0.0565
# 7                                       Hedge's g =   -0.0557
# 8                                  Glass's delta1 =   -0.0530
# 9                                Point-Biserial r =   -0.0287

# %%
dataread.PCA_Comparision() # 1-8  8, 4, 5, 3, 6 |[5, 3, 4, 6, 8,|7, 8, 6, 5|5, 6, 7, 8, 4|5, 6, 8, 7, 3|7, 6, 4, 5, 3|5, 0, 1|2, 5, 3
# Out:
# Sorted feature index for component 0 [8, 5, 3, 6, 4, 7, 0, 2, 1]
# Sorted imporance porporation for component 0  [0.2731807154874635, 0.2032096369830546, 0.19223561550165483, 0.16526390960982087, 0.10506909623478139, 0.02623782418626994, 0.018914637567926256, 0.009156689977688788, 0.0067318744513398445]
# Sorted feature index for component 1 [3, 6, 4, 5, 7, 8, 1, 2, 0]
# Sorted imporance porporation for component 1  [0.2421900381676867, 0.23123923852710174, 0.22789829517914578, 0.11144739270623644, 0.082693756528739, 0.04307416015731486, 0.02466260485004831, 0.022508247700002815, 0.01428626618372441]
# Sorted feature index for component 2 [7, 1, 5, 8, 4, 6, 0, 3, 2]
# Sorted imporance porporation for component 2  [0.25367097727867355, 0.23510404029597734, 0.16622341497280638, 0.15353759241429968, 0.14615709246345376, 0.023591557135486847, 0.016878401845500768, 0.0027429284923957973, 0.002093995101405818]
# Sorted feature index for component 3 [5, 7, 6, 3, 8, 4, 2, 1, 0]
# Sorted imporance porporation for component 3  [0.26004279295837096, 0.25238855019896356, 0.17064982912005944, 0.1433814836477005, 0.10539426278842896, 0.021909470264869196, 0.021749054162607532, 0.01685615816400491, 0.007628398694994775]
# Sorted feature index for component 4 [3, 4, 7, 8, 6, 5, 0, 2, 1]
# Sorted imporance porporation for component 4  [0.23968570926241853, 0.20188555156555932, 0.18083298557654423, 0.12970361712096448, 0.12745816588104864, 0.08202800521916191, 0.025751000836417053, 0.008906889759453399, 0.0037480747784324267]
# Sorted feature index for component 5 [7, 5, 8, 4, 1, 6, 2, 0, 3]
# Sorted imporance porporation for component 5  [0.2957028960741762, 0.18070647122517364, 0.17967029972372167, 0.16883211760822678, 0.11562776499088949, 0.03765211694608995, 0.010781939053909347, 0.008538551419462342, 0.0024878429583504755]
# Sorted feature index for component 6 [0, 2, 5, 1, 4, 6, 7, 3, 8]
# Sorted imporance porporation for component 6  [0.4705200614709673, 0.42049507202945025, 0.028646072788742885, 0.017611679366824257, 0.016397702616371385, 0.015646056340721592, 0.014570406210220875, 0.009188790505326297, 0.006924158671375036]
# Sorted feature index for component 7 [4, 1, 0, 3, 5, 2, 7, 8, 6]
# Sorted imporance porporation for component 7  [0.32861890301880015, 0.2915171879742228, 0.24955991938421682, 0.031446294861565305, 0.023066774009754914, 0.022527979663233718, 0.019481452941412514, 0.01780740738754991, 0.015974080759243958]
# Sorted feature index for component 8 [3, 5, 2, 0, 1, 4, 7, 8, 6]
# Sorted imporance porporation for component 8  [0.39678211355200166, 0.24864749175829465, 0.2322882103625577, 0.047454682164073, 0.03266856460792054, 0.019759309568190397, 0.01793715700816367, 0.0023328222550761364, 0.0021296487237222623]
# [0.15742852 0.15201386 0.14486652 0.13729172 0.12909376 0.12399569
#  0.05801095 0.04921095 0.04808802]
