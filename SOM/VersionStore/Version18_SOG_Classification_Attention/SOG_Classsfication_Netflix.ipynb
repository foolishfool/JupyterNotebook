# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
from fcmeans import FCM
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")

dataread.data_train_discrete
# Out:
# self.continuous_feature_num 3
# self.data_discrete_indexes ['Monthly Revenue', 'Country', 'Gender', 'Device']
# array([[12.,  9.,  0.,  1.],
#        [11.,  1.,  0.,  3.],
#        [10.,  6.,  0.,  0.],
#        ...,
#        [11.,  9.,  1.,  1.],
#        [11.,  8.,  0.,  0.],
#        [10.,  9.,  1.,  1.]])

# %%
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 10
class_num = 2
interval = 1

features_chosen = [0,1,2]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features_chosen,feature_combination_number)

#mutiple_feature_group_union (15.0, 0.0)  len value 400
# Out:
# Experiment number: 1
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 2
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5758387725366906
# precision_score_original 0.6024770823887473
# f1_score_original 0.5831399459535449
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 3
# accuracy_score_orignial 0.5893333333333334
# recall_score_original 0.5726540591608944
# precision_score_original 0.5974023205413598
# f1_score_original 0.5796147161682178
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 4
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 5
# accuracy_score_orignial 0.5906666666666667
# recall_score_original 0.5723060770261515
# precision_score_original 0.5985855923694778
# f1_score_original 0.5792551455019613
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 6
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 7
# accuracy_score_orignial 0.5866666666666667
# recall_score_original 0.5695818625403107
# precision_score_original 0.5973581429971356
# f1_score_original 0.5771725176966779
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5906666666666667
# recall_score_sog 0.5727665759161068
# precision_score_sog 0.5991894997883022
# f1_score_sog 0.5798330755996061
# Experiment number: 8
# accuracy_score_orignial 0.5906666666666667
# recall_score_original 0.5723060770261515
# precision_score_original 0.5985855923694778
# f1_score_original 0.5792551455019613
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.596
# recall_score_sog 0.577501415897266
# precision_score_sog 0.6053737109010024
# f1_score_sog 0.5848776881447012
# Experiment number: 9
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 10
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 11
# accuracy_score_orignial 0.596
# recall_score_original 0.5784224136771766
# precision_score_original 0.6078371035005686
# f1_score_original 0.5863919456368669
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5986666666666667
# recall_score_sog 0.5805455559277074
# precision_score_sog 0.6080219330628001
# f1_score_sog 0.5879107242902043
# Experiment number: 12
# accuracy_score_orignial 0.596
# recall_score_original 0.5788829125671319
# precision_score_original 0.6069511128182148
# f1_score_original 0.5866140900977035
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5986666666666667
# recall_score_sog 0.5805455559277074
# precision_score_sog 0.6080219330628001
# f1_score_sog 0.5879107242902043
# Experiment number: 13
# accuracy_score_orignial 0.5906666666666667
# recall_score_original 0.5723060770261515
# precision_score_original 0.5985855923694778
# f1_score_original 0.5792551455019613
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.596
# recall_score_sog 0.577501415897266
# precision_score_sog 0.6053737109010024
# f1_score_sog 0.5848776881447012
# Experiment number: 14
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 15
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 16
# accuracy_score_orignial 0.592
# recall_score_original 0.5743167025214698
# precision_score_original 0.6017336010709505
# f1_score_original 0.5817813237409183
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 17
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753782736467352
# precision_score_original 0.60205197245752
# f1_score_original 0.5825415042318669
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 18
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 19
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5758387725366906
# precision_score_original 0.6024770823887473
# f1_score_original 0.5831399459535449
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 20
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 21
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 22
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 23
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 24
# accuracy_score_orignial 0.592
# recall_score_original 0.5733536198563458
# precision_score_original 0.6015371187547434
# f1_score_original 0.5806516290726816
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.596
# recall_score_sog 0.577501415897266
# precision_score_sog 0.6053737109010024
# f1_score_sog 0.5848776881447012
# Experiment number: 25
# accuracy_score_orignial 0.5933333333333334
# recall_score_original 0.5753923019418065
# precision_score_original 0.6022041978303349
# f1_score_original 0.5825995615505036
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 26
# accuracy_score_orignial 0.5946666666666667
# recall_score_original 0.5773608425519112
# precision_score_original 0.6056330504789494
# f1_score_original 0.5851159042879482
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5973333333333334
# recall_score_sog 0.5790234859124866
# precision_score_sog 0.6067006288618124
# f1_score_sog 0.5863966611119907
# Experiment number: 27
# accuracy_score_orignial 0.5946666666666667
# recall_score_original 0.57786342632708
# precision_score_original 0.6023068878650999
# f1_score_original 0.5847894428853949
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.596
# recall_score_sog 0.577501415897266
# precision_score_sog 0.6053737109010024
# f1_score_sog 0.5848776881447012
# Not good recall_score result !!!!!
# Experiment number: 28
# accuracy_score_orignial 0.5906666666666667
# recall_score_original 0.5737156302861598
# precision_score_original 0.6010875547899176
# f1_score_original 0.5813110320136975
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5933333333333334
# recall_score_sog 0.5758387725366906
# precision_score_sog 0.6013833079508918
# f1_score_sog 0.5828478689383667
# Experiment number: 29
# accuracy_score_orignial 0.588
# recall_score_original 0.5711039325555314
# precision_score_original 0.598671799294812
# f1_score_original 0.5786743167950265
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.592
# recall_score_sog 0.5742886459313276
# precision_score_sog 0.6005066918090117
# f1_score_sog 0.5813439257984764
# Experiment number: 30
# accuracy_score_orignial 0.5906666666666667
# recall_score_original 0.5722920487310804
# precision_score_original 0.6019820966441815
# f1_score_original 0.58001211751503
# self.train_discrete_extra_sog_fuzzy shape (1750, 32)
# accuracy_score_sog 0.5986666666666667
# recall_score_sog 0.5805455559277074
# precision_score_sog 0.6080219330628001
# f1_score_sog 0.5879107242902043
# all_accuracy_score_original mean 0.5914666666666668
# all_recall_score_original mean 0.5739297069833165
# all_precision_score_original mean 0.6010907961226867
# all_f1_score_original mean 0.5812986233392896
# all_accuracy_score_sog mean 0.5956888888888888
# all_recall_score_sog mean 0.5775532334706364
# all_precision_score_sog mean 0.6047829699086689
# all_f1_score_sog mean 0.5848294868714864
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  30.0  0.591467  0.002703  0.000494   0.590457
# 1       all_accuracy_score_sog  30.0  0.595689  0.002566  0.000468   0.594731
# 2                     combined  60.0  0.593578  0.003370  0.000435   0.592707
#
#    Interval
# 0  0.592476
# 1  0.596647
# 2  0.594448
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0042
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -6.2053
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.6022
# 7                                       Hedge's g =   -1.5814
# 8                                  Glass's delta1 =   -1.5619
# 9                                Point-Biserial r =   -0.6317
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  30.0  0.573930  0.002518  0.000460   0.572989
# 1       all_recall_score_sog  30.0  0.577553  0.002331  0.000426   0.576683
# 2                   combined  60.0  0.575741  0.003021  0.000390   0.574961
#
#    Interval
# 0  0.574870
# 1  0.578424
# 2  0.576522
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0036
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -5.7839
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.4934
# 7                                       Hedge's g =   -1.4740
# 8                                  Glass's delta1 =   -1.4390
# 9                                Point-Biserial r =   -0.6048
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  30.0  0.601091  0.002653  0.000484
# 1       all_precision_score_sog  30.0  0.604783  0.002966  0.000542
# 2                      combined  60.0  0.602937  0.003354  0.000433
#
#    95% Conf.  Interval
# 0   0.600100  0.602082
# 1   0.603675  0.605891
# 2   0.602070  0.603803
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0037
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -5.0813
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.3120
# 7                                       Hedge's g =   -1.2949
# 8                                  Glass's delta1 =   -1.3916
# 9                                Point-Biserial r =   -0.5550
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  30.0  0.581299  0.002519  0.000460   0.580358
# 1       all_f1_score_sog  30.0  0.584829  0.002469  0.000451   0.583907
# 2               combined  60.0  0.583064  0.003047  0.000393   0.582277
#
#    Interval
# 0  0.582239
# 1  0.585751
# 2  0.583851
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0035
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -5.4826
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.4156
# 7                                       Hedge's g =   -1.3972
# 8                                  Glass's delta1 =   -1.4016
# 9                                Point-Biserial r =   -0.5842

# %%
dataread.PCA_Comparision()  #component 123 2|3|1
# Out:
# Sorted feature index for component 0 [2, 3, 1, 0]
# Sorted imporance porporation for component 0  [0.9803947808364284, 0.012926381929234789, 0.005118069480894521, 0.0015607677534421925]
# Sorted feature index for component 1 [3, 2, 1, 0]
# Sorted imporance porporation for component 1  [0.9858079412379794, 0.012992748003315248, 0.0008533941778655647, 0.0003459165808398085]
# Sorted feature index for component 2 [0, 1, 2, 3]
# Sorted imporance porporation for component 2  [0.9945408555431067, 0.0035222436744135775, 0.0016060379701348447, 0.00033086281234504807]
# Sorted feature index for component 3 [0, 2, 3, 1]
# Sorted imporance porporation for component 3  [0.9905196364118873, 0.005175717058642303, 0.0035166223994113417, 0.000788024130059277]
# [0.67149672 0.21443826 0.09516369 0.01890133]
