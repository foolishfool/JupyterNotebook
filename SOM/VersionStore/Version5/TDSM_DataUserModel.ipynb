# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import experiment
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Data_User_Modeling_Dataset_Hamdi Tolga KAHRAMAN.csv")
dataread.stringToIntDataUserModelDataSet(csv," UNS")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test," UNS")

# %%
unstable_repeate_num= 10
scope_num = 30
class_num = 4
dim_num = 5

experiment = experiment.Experiment()
experiment.Ttest(dataread,class_num, dim_num, scope_num,unstable_repeate_num)
# Out:
# neuron unit number: 4
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.4578313253012048
# error_data0_score_W1 nmi 0.11948909464290271
# error_data0_score_W1 api 0.0502642752620763
# error_data0_score_W0 purity 0.5180722891566265
# error_data0_score_W0 nmi 0.2941884549928106
# error_data0_score_W0 api 0.1794223854275615
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.6888888888888889
# error_data1_score_W1 nmi 0.4316313991255493
# error_data1_score_W1 api 0.3439378655532888
# error_data1_score_W0 purity 0.6444444444444445
# error_data1_score_W0 nmi 0.4752943409863775
# error_data1_score_W0 api 0.3498361728459456
# right_data1_score_W' purity 0.631578947368421
# right_data1_score_W' nmi 0.3098995469040435
# right_data1_score_W' api 0.20874035989717224
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 0.6428571428571429
# error_data2_score_W1 nmi 0.64674037965386
# error_data2_score_W1 api 0.34177215189873417
# error_data2_score_W0 purity 0.42857142857142855
# error_data2_score_W0 nmi 0.2273733098110217
# error_data2_score_W0 api -0.09969788519637462
# right_data2_score_W' purity 0.4838709677419355
# right_data2_score_W' nmi 0.0766203020759348
# right_data2_score_W' api -0.04362037976923292
# Finish one round splitting 2 *********
#
# right_data3_score_W0 purity 1.0
# right_data3_score_W0 nmi 1.0
# right_data3_score_W0 api 1.0
# error_data3_score_W1 purity 1.0
# error_data3_score_W1 nmi 1.0
# error_data3_score_W1 api 1.0
# error_data3_score_W0 purity 0.8
# error_data3_score_W0 nmi 0.4580652856440157
# error_data3_score_W0 api 0.09090909090909091
# right_data3_score_W' purity 0.4444444444444444
# right_data3_score_W' nmi 0.14378913248740022
# right_data3_score_W' api -0.16129032258064516
# Finish one round splitting 3 *********
#
#  NO Error Data, Finish Training!
# total split_number 4
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.5414364640883977
# all_train_score_W' nmi split_num : 0 0.15752344822013462
# all_train_score_W' ari split_num : 0 0.1376865649103945
# test_score_W0 purity: 0.5324675324675324
# test_score_W0 nmi: 0.12701854772165436
# test_score_W0 api: 0.059651994296394506
# test_score_W': purity split_num : 0 0.5324675324675324
# test_score_W': nmi split_num : 0 0.12701854772165436
# test_score_W': ari split_num : 0 0.059651994296394506
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.7513812154696132
# all_train_score_W' nmi split_num : 1 0.45413562925130424
# all_train_score_W' ari split_num : 1 0.42429349402899974
# test_score_W0 purity: 0.5324675324675324
# test_score_W0 nmi: 0.12701854772165436
# test_score_W0 api: 0.059651994296394506
# test_score_W': purity split_num : 1 0.6103896103896104
# test_score_W': nmi split_num : 1 0.22975047379425892
# test_score_W': ari split_num : 1 0.17899136313287226
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.9226519337016574
# all_train_score_W' nmi split_num : 2 0.7658543979827066
# all_train_score_W' ari split_num : 2 0.8031969275297032
# test_score_W0 purity: 0.5324675324675324
# test_score_W0 nmi: 0.12701854772165436
# test_score_W0 api: 0.059651994296394506
# test_score_W': purity split_num : 2 0.7142857142857143
# test_score_W': nmi split_num : 2 0.37867643035458737
# test_score_W': ari split_num : 2 0.3633013147326932
# stop_split_num 3
# all_train_score_W' purity split_num : 3 0.9723756906077348
# all_train_score_W' nmi split_num : 3 0.903232925991776
# all_train_score_W' ari split_num : 3 0.921985975090982
# test_score_W0 purity: 0.5324675324675324
# test_score_W0 nmi: 0.12701854772165436
# test_score_W0 api: 0.059651994296394506
# test_score_W': purity split_num : 3 0.7142857142857143
# test_score_W': nmi split_num : 3 0.3686567485444423
# test_score_W': ari split_num : 3 0.3651016387881218
# stop_split_num 4
# all_train_score_W' purity split_num : 4 1.0
# all_train_score_W' nmi split_num : 4 1.0
# all_train_score_W' ari split_num : 4 1.0
# test_score_W0 purity: 0.5324675324675324
# test_score_W0 nmi: 0.12701854772165436
# test_score_W0 api: 0.059651994296394506
# test_score_W': purity split_num : 4 0.7272727272727273
# test_score_W': nmi split_num : 4 0.386180857311564
# test_score_W': ari split_num : 4 0.3892728961946654
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7272727272727273
# test_scores_W_Combined_last_n 0.386180857311564
# test_scores_W_Combined_last_a 0.3892728961946654
# neuron unit number: 8
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8048780487804879
# error_data0_score_W1 nmi 0.530667681753444
# error_data0_score_W1 api 0.5016991813842226
# error_data0_score_W0 purity 0.5853658536585366
# error_data0_score_W0 nmi 0.35822917012934635
# error_data0_score_W0 api 0.12126047227358172
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.875
# error_data1_score_W1 nmi 0.7265962155849603
# error_data1_score_W1 api 0.5908625980225025
# error_data1_score_W0 purity 0.625
# error_data1_score_W0 nmi 0.2703913360140295
# error_data1_score_W0 api 0.11741528762805359
# right_data1_score_W' purity 0.6666666666666666
# right_data1_score_W' nmi 0.21969438120384158
# right_data1_score_W' api 0.16696524081401193
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 1.0
# error_data2_score_W1 nmi 1.0
# error_data2_score_W1 api 1.0
# error_data2_score_W0 purity 1.0
# error_data2_score_W0 nmi 0.0
# error_data2_score_W0 api 0.0
# Error data can be represented by W0 purity 2
# right_data2_score_W' purity 0.6428571428571429
# right_data2_score_W' nmi 0.4831453847376089
# right_data2_score_W' api 0.2073170731707317
# Finish one round splitting 2 *********
#
#  NO Error Data, Finish Training!
# total split_number 3
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.5469613259668509
# all_train_score_W' nmi split_num : 0 0.2526490198945821
# all_train_score_W' ari split_num : 0 0.1625767357407062
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.23601678352685407
# test_score_W0 api: 0.15529031747035998
# test_score_W': purity split_num : 0 0.5974025974025974
# test_score_W': nmi split_num : 0 0.23601678352685407
# test_score_W': ari split_num : 0 0.15529031747035998
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9116022099447514
# all_train_score_W' nmi split_num : 1 0.748670165992827
# all_train_score_W' ari split_num : 1 0.7869485333771221
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.23601678352685407
# test_score_W0 api: 0.15529031747035998
# test_score_W': purity split_num : 1 0.7402597402597403
# test_score_W': nmi split_num : 1 0.4385267659701507
# test_score_W': ari split_num : 1 0.40970829887615046
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.988950276243094
# all_train_score_W' nmi split_num : 2 0.9622847879941683
# all_train_score_W' ari split_num : 2 0.9772243525092698
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.23601678352685407
# test_score_W0 api: 0.15529031747035998
# test_score_W': purity split_num : 2 0.7142857142857143
# test_score_W': nmi split_num : 2 0.40084061892530143
# test_score_W': ari split_num : 2 0.36467640466991535
# stop_split_num 3
# all_train_score_W' purity split_num : 3 1.0
# all_train_score_W' nmi split_num : 3 1.0
# all_train_score_W' ari split_num : 3 1.0
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.23601678352685407
# test_score_W0 api: 0.15529031747035998
# test_score_W': purity split_num : 3 0.7272727272727273
# test_score_W': nmi split_num : 3 0.41665612876164193
# test_score_W': ari split_num : 3 0.379981363830751
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7272727272727273
# test_scores_W_Combined_last_n 0.41665612876164193
# test_scores_W_Combined_last_a 0.379981363830751
# neuron unit number: 12
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.6956521739130435
# error_data0_score_W1 nmi 0.4427358644570272
# error_data0_score_W1 api 0.30232653475130483
# error_data0_score_W0 purity 0.7246376811594203
# error_data0_score_W0 nmi 0.46503720359165407
# error_data0_score_W0 api 0.3404984415762561
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.8095238095238095
# error_data1_score_W1 nmi 0.33250464656654105
# error_data1_score_W1 api 0.3900889453621347
# error_data1_score_W0 purity 0.6666666666666666
# error_data1_score_W0 nmi 0.15982936768754266
# error_data1_score_W0 api -0.024575352367184677
# right_data1_score_W' purity 0.7083333333333334
# right_data1_score_W' nmi 0.27841847519944557
# right_data1_score_W' api 0.11846256688809303
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 1.0
# error_data2_score_W1 nmi 1.0
# error_data2_score_W1 api 1.0
# error_data2_score_W0 purity 0.75
# error_data2_score_W0 nmi 0.7020168761809934
# error_data2_score_W0 api 0.3333333333333333
# right_data2_score_W' purity 0.7058823529411765
# right_data2_score_W' nmi 0.17998776215659387
# right_data2_score_W' api -0.03453947368421053
# Finish one round splitting 2 *********
#
#  NO Error Data, Finish Training!
# total split_number 3
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.6187845303867403
# all_train_score_W' nmi split_num : 0 0.3279508283068818
# all_train_score_W' ari split_num : 0 0.2700983229793434
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.23725294432589278
# test_score_W0 api: 0.13900941446898676
# test_score_W': purity split_num : 0 0.5584415584415584
# test_score_W': nmi split_num : 0 0.23725294432589278
# test_score_W': ari split_num : 0 0.13900941446898676
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.8839779005524862
# all_train_score_W' nmi split_num : 1 0.7457417620510797
# all_train_score_W' ari split_num : 1 0.7324578164624169
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.23725294432589278
# test_score_W0 api: 0.13900941446898676
# test_score_W': purity split_num : 1 0.7012987012987013
# test_score_W': nmi split_num : 1 0.3760936611170008
# test_score_W': ari split_num : 1 0.32170014184126466
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.9779005524861878
# all_train_score_W' nmi split_num : 2 0.9201646585667533
# all_train_score_W' ari split_num : 2 0.9428276703554054
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.23725294432589278
# test_score_W0 api: 0.13900941446898676
# test_score_W': purity split_num : 2 0.7402597402597403
# test_score_W': nmi split_num : 2 0.44453828252824124
# test_score_W': ari split_num : 2 0.4070592161989264
# stop_split_num 3
# all_train_score_W' purity split_num : 3 1.0
# all_train_score_W' nmi split_num : 3 1.0
# all_train_score_W' ari split_num : 3 1.0
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.23725294432589278
# test_score_W0 api: 0.13900941446898676
# test_score_W': purity split_num : 3 0.7532467532467533
# test_score_W': nmi split_num : 3 0.4599110936354153
# test_score_W': ari split_num : 3 0.4178786654310171
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7532467532467533
# test_scores_W_Combined_last_n 0.4599110936354153
# test_scores_W_Combined_last_a 0.4178786654310171
# neuron unit number: 16
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.6571428571428571
# error_data0_score_W1 nmi 0.3626365969435745
# error_data0_score_W1 api 0.31898374963189036
# error_data0_score_W0 purity 0.4857142857142857
# error_data0_score_W0 nmi 0.3477458536425483
# error_data0_score_W0 api 0.2047872340425532
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.8333333333333334
# error_data1_score_W1 nmi 0.6981631430148059
# error_data1_score_W1 api 0.5177277926038887
# error_data1_score_W0 purity 0.5
# error_data1_score_W0 nmi 0.17537833087800903
# error_data1_score_W0 api -0.006373330064958941
# right_data1_score_W' purity 0.4782608695652174
# right_data1_score_W' nmi 0.18027999491148025
# right_data1_score_W' api 0.07137142932911386
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 1.0
# error_data2_score_W1 nmi 1.0
# error_data2_score_W1 api 1.0
# error_data2_score_W0 purity 1.0
# error_data2_score_W0 nmi 0.0
# error_data2_score_W0 api 0.0
# Error data can be represented by W0 purity 2
# right_data2_score_W' purity 0.55
# right_data2_score_W' nmi 0.2670791267978572
# right_data2_score_W' api 0.034266133637921185
# Finish one round splitting 2 *********
#
#  NO Error Data, Finish Training!
# total split_number 3
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.6132596685082873
# all_train_score_W' nmi split_num : 0 0.2451810150122566
# all_train_score_W' ari split_num : 0 0.22737052634383859
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.21247276970055526
# test_score_W0 api: 0.13051607363318998
# test_score_W': purity split_num : 0 0.5714285714285714
# test_score_W': nmi split_num : 0 0.21247276970055526
# test_score_W': ari split_num : 0 0.13051607363318998
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.8674033149171271
# all_train_score_W' nmi split_num : 1 0.6367640269528017
# all_train_score_W' ari split_num : 1 0.6622288607460446
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.21247276970055526
# test_score_W0 api: 0.13051607363318998
# test_score_W': purity split_num : 1 0.6753246753246753
# test_score_W': nmi split_num : 1 0.3469327409142931
# test_score_W': ari split_num : 1 0.2711160871728986
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.9779005524861878
# all_train_score_W' nmi split_num : 2 0.9279150264592279
# all_train_score_W' ari split_num : 2 0.9348358393298168
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.21247276970055526
# test_score_W0 api: 0.13051607363318998
# test_score_W': purity split_num : 2 0.7012987012987013
# test_score_W': nmi split_num : 2 0.3818854405290293
# test_score_W': ari split_num : 2 0.3030941380345127
# stop_split_num 3
# all_train_score_W' purity split_num : 3 1.0
# all_train_score_W' nmi split_num : 3 1.0
# all_train_score_W' ari split_num : 3 1.0
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.21247276970055526
# test_score_W0 api: 0.13051607363318998
# test_score_W': purity split_num : 3 0.7012987012987013
# test_score_W': nmi split_num : 3 0.3764734604469482
# test_score_W': ari split_num : 3 0.30883770257246285
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7012987012987013
# test_scores_W_Combined_last_n 0.3764734604469482
# test_scores_W_Combined_last_a 0.30883770257246285
# neuron unit number: 20
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8545454545454545
# error_data0_score_W1 nmi 0.6446148206703345
# error_data0_score_W1 api 0.679318910108592
# error_data0_score_W0 purity 0.6909090909090909
# error_data0_score_W0 nmi 0.5228090126836314
# error_data0_score_W0 api 0.4109561737263384
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.5
# error_data1_score_W0 nmi 0.2857142857142856
# error_data1_score_W0 api -0.3333333333333333
# right_data1_score_W' purity 0.5531914893617021
# right_data1_score_W' nmi 0.20595790431688032
# right_data1_score_W' api 0.12540116120034367
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.6961325966850829
# all_train_score_W' nmi split_num : 0 0.42260332224971553
# all_train_score_W' ari split_num : 0 0.3798793722100871
# test_score_W0 purity: 0.5844155844155844
# test_score_W0 nmi: 0.26108396525188293
# test_score_W0 api: 0.16677089694058242
# test_score_W': purity split_num : 0 0.5844155844155844
# test_score_W': nmi split_num : 0 0.26108396525188293
# test_score_W': ari split_num : 0 0.16677089694058242
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9558011049723757
# all_train_score_W' nmi split_num : 1 0.851853709223722
# all_train_score_W' ari split_num : 1 0.8749173574016433
# test_score_W0 purity: 0.5844155844155844
# test_score_W0 nmi: 0.26108396525188293
# test_score_W0 api: 0.16677089694058242
# test_score_W': purity split_num : 1 0.6623376623376623
# test_score_W': nmi split_num : 1 0.3663073559177662
# test_score_W': ari split_num : 1 0.26385104174885143
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.5844155844155844
# test_score_W0 nmi: 0.26108396525188293
# test_score_W0 api: 0.16677089694058242
# test_score_W': purity split_num : 2 0.7012987012987013
# test_score_W': nmi split_num : 2 0.40978743956500774
# test_score_W': ari split_num : 2 0.32434184988069376
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7012987012987013
# test_scores_W_Combined_last_n 0.40978743956500774
# test_scores_W_Combined_last_a 0.32434184988069376
# neuron unit number: 24
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.864406779661017
# error_data0_score_W1 nmi 0.7132303029576218
# error_data0_score_W1 api 0.6981662875446822
# error_data0_score_W0 purity 0.7457627118644068
# error_data0_score_W0 nmi 0.6169328937470322
# error_data0_score_W0 api 0.49288475564989465
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.75
# error_data1_score_W0 nmi 0.405848277385843
# error_data1_score_W0 api 0.0718232044198895
# right_data1_score_W' purity 0.47058823529411764
# right_data1_score_W' nmi 0.15669629862734355
# right_data1_score_W' api 0.09265482477196352
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.6740331491712708
# all_train_score_W' nmi split_num : 0 0.4109496029603925
# all_train_score_W' ari split_num : 0 0.365555427060555
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.2477996210733223
# test_score_W0 api: 0.15297606620179488
# test_score_W': purity split_num : 0 0.5714285714285714
# test_score_W': nmi split_num : 0 0.2477996210733223
# test_score_W': ari split_num : 0 0.15297606620179488
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9558011049723757
# all_train_score_W' nmi split_num : 1 0.8691741985307821
# all_train_score_W' ari split_num : 1 0.869994280242231
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.2477996210733223
# test_score_W0 api: 0.15297606620179488
# test_score_W': purity split_num : 1 0.6883116883116883
# test_score_W': nmi split_num : 1 0.36728506299254216
# test_score_W': ari split_num : 1 0.3089143175861822
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.5714285714285714
# test_score_W0 nmi: 0.2477996210733223
# test_score_W0 api: 0.15297606620179488
# test_score_W': purity split_num : 2 0.7142857142857143
# test_score_W': nmi split_num : 2 0.40396686818950645
# test_score_W': ari split_num : 2 0.35325114836177357
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7142857142857143
# test_scores_W_Combined_last_n 0.40396686818950645
# test_scores_W_Combined_last_a 0.35325114836177357
# neuron unit number: 28
# *******************
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8688524590163934
# error_data0_score_W1 nmi 0.7088438651768896
# error_data0_score_W1 api 0.642657684735827
# error_data0_score_W0 purity 0.6229508196721312
# error_data0_score_W0 nmi 0.3704307259277506
# error_data0_score_W0 api 0.14332299148170335
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.75
# error_data1_score_W0 nmi 0.3051372183945114
# error_data1_score_W0 api 0.01507537688442211
# right_data1_score_W' purity 0.49056603773584906
# right_data1_score_W' nmi 0.11721242452786305
# right_data1_score_W' api -0.04148200839561406
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.6629834254143646
# all_train_score_W' nmi split_num : 0 0.3434872215044576
# all_train_score_W' ari split_num : 0 0.29434276677725785
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.1538992998690932
# test_score_W0 api: 0.06768997702903344
# test_score_W': purity split_num : 0 0.5584415584415584
# test_score_W': nmi split_num : 0 0.1538992998690932
# test_score_W': ari split_num : 0 0.06768997702903344
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9558011049723757
# all_train_score_W' nmi split_num : 1 0.8694265221740045
# all_train_score_W' ari split_num : 1 0.8807586797939797
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.1538992998690932
# test_score_W0 api: 0.06768997702903344
# test_score_W': purity split_num : 1 0.6363636363636364
# test_score_W': nmi split_num : 1 0.2563801735027655
# test_score_W': ari split_num : 1 0.21754256244248033
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.5584415584415584
# test_score_W0 nmi: 0.1538992998690932
# test_score_W0 api: 0.06768997702903344
# test_score_W': purity split_num : 2 0.6493506493506493
# test_score_W': nmi split_num : 2 0.2698706896968722
# test_score_W': ari split_num : 2 0.23270893086737218
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.6493506493506493
# test_scores_W_Combined_last_n 0.2698706896968722
# test_scores_W_Combined_last_a 0.23270893086737218
# neuron unit number: 32
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8461538461538461
# error_data0_score_W1 nmi 0.666485197087786
# error_data0_score_W1 api 0.6985117066476008
# error_data0_score_W0 purity 0.8076923076923077
# error_data0_score_W0 nmi 0.6209324376055088
# error_data0_score_W0 api 0.5701171056481137
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 0.875
# error_data1_score_W1 nmi 0.5288712462777687
# error_data1_score_W1 api 0.5050505050505051
# error_data1_score_W0 purity 0.75
# error_data1_score_W0 nmi 0.12153234023535239
# error_data1_score_W0 api -0.13333333333333333
# right_data1_score_W' purity 0.5909090909090909
# right_data1_score_W' nmi 0.30826901963274045
# right_data1_score_W' api 0.22217478614233988
# Finish one round splitting 1 *********
#
# right_data2_score_W0 purity 1.0
# right_data2_score_W0 nmi 1.0
# right_data2_score_W0 api 1.0
# error_data2_score_W1 purity 1.0
# error_data2_score_W1 nmi 1.0
# error_data2_score_W1 api 1.0
# error_data2_score_W0 purity 1.0
# error_data2_score_W0 nmi 1.0
# error_data2_score_W0 api 1.0
# Error data can be represented by W0 purity 2
# Error data can be represented by W0 nmi 2
# Error data can be represented by W0 api 2
# right_data2_score_W' purity 0.8571428571428571
# right_data2_score_W' nmi 0.34712007071429435
# right_data2_score_W' api -0.01762114537444934
# Finish one round splitting 2 *********
#
#  NO Error Data, Finish Training!
# total split_number 3
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.712707182320442
# all_train_score_W' nmi split_num : 0 0.45254096231909374
# all_train_score_W' ari split_num : 0 0.4051383014822842
# test_score_W0 purity: 0.6493506493506493
# test_score_W0 nmi: 0.3162621259903967
# test_score_W0 api: 0.2519880252468954
# test_score_W': purity split_num : 0 0.6493506493506493
# test_score_W': nmi split_num : 0 0.3162621259903967
# test_score_W': ari split_num : 0 0.2519880252468954
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9558011049723757
# all_train_score_W' nmi split_num : 1 0.8760830385033184
# all_train_score_W' ari split_num : 1 0.8792369399514826
# test_score_W0 purity: 0.6493506493506493
# test_score_W0 nmi: 0.3162621259903967
# test_score_W0 api: 0.2519880252468954
# test_score_W': purity split_num : 1 0.6753246753246753
# test_score_W': nmi split_num : 1 0.33522943482889445
# test_score_W': ari split_num : 1 0.2767699952531741
# stop_split_num 2
# all_train_score_W' purity split_num : 2 0.994475138121547
# all_train_score_W' nmi split_num : 2 0.9788312756752464
# all_train_score_W' ari split_num : 2 0.9826367269206335
# test_score_W0 purity: 0.6493506493506493
# test_score_W0 nmi: 0.3162621259903967
# test_score_W0 api: 0.2519880252468954
# test_score_W': purity split_num : 2 0.6883116883116883
# test_score_W': nmi split_num : 2 0.34752426857023627
# test_score_W': ari split_num : 2 0.3000662895842149
# stop_split_num 3
# all_train_score_W' purity split_num : 3 1.0
# all_train_score_W' nmi split_num : 3 1.0
# all_train_score_W' ari split_num : 3 1.0
# test_score_W0 purity: 0.6493506493506493
# test_score_W0 nmi: 0.3162621259903967
# test_score_W0 api: 0.2519880252468954
# test_score_W': purity split_num : 3 0.6883116883116883
# test_score_W': nmi split_num : 3 0.34752426857023627
# test_score_W': ari split_num : 3 0.3000662895842149
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.6883116883116883
# test_scores_W_Combined_last_n 0.34752426857023627
# test_scores_W_Combined_last_a 0.3000662895842149
# neuron unit number: 36
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.9056603773584906
# error_data0_score_W1 nmi 0.7720441058735643
# error_data0_score_W1 api 0.7308544357724686
# error_data0_score_W0 purity 0.7924528301886793
# error_data0_score_W0 nmi 0.6001181098018412
# error_data0_score_W0 api 0.4495763869909811
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.6
# error_data1_score_W0 nmi 0.13715115395349545
# error_data1_score_W0 api -0.36363636363636365
# right_data1_score_W' purity 0.6875
# right_data1_score_W' nmi 0.3852405685916345
# right_data1_score_W' api 0.28594720905245286
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7071823204419889
# all_train_score_W' nmi split_num : 0 0.43168999352278836
# all_train_score_W' ari split_num : 0 0.38217357569801874
# test_score_W0 purity: 0.6233766233766234
# test_score_W0 nmi: 0.25728528961340835
# test_score_W0 api: 0.17849818785084715
# test_score_W': purity split_num : 0 0.6233766233766234
# test_score_W': nmi split_num : 0 0.25728528961340835
# test_score_W': ari split_num : 0 0.17849818785084715
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9723756906077348
# all_train_score_W' nmi split_num : 1 0.9012841712263695
# all_train_score_W' ari split_num : 1 0.9188160026668009
# test_score_W0 purity: 0.6233766233766234
# test_score_W0 nmi: 0.25728528961340835
# test_score_W0 api: 0.17849818785084715
# test_score_W': purity split_num : 1 0.7662337662337663
# test_score_W': nmi split_num : 1 0.4612314396758078
# test_score_W': ari split_num : 1 0.41609553802500704
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.6233766233766234
# test_score_W0 nmi: 0.25728528961340835
# test_score_W0 api: 0.17849818785084715
# test_score_W': purity split_num : 2 0.7662337662337663
# test_score_W': nmi split_num : 2 0.4612314396758078
# test_score_W': ari split_num : 2 0.41609553802500704
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7662337662337663
# test_scores_W_Combined_last_n 0.4612314396758078
# test_scores_W_Combined_last_a 0.41609553802500704
# neuron unit number: 40
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8636363636363636
# error_data0_score_W1 nmi 0.699988038158463
# error_data0_score_W1 api 0.6650438169425511
# error_data0_score_W0 purity 0.75
# error_data0_score_W0 nmi 0.4876902836934423
# error_data0_score_W0 api 0.32926011887286805
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.6666666666666666
# error_data1_score_W0 nmi 0.5206652463984818
# error_data1_score_W0 api 0.07407407407407407
# right_data1_score_W' purity 0.631578947368421
# right_data1_score_W' nmi 0.2812990440037603
# right_data1_score_W' api 0.1683016040461003
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7569060773480663
# all_train_score_W' nmi split_num : 0 0.4815281736059941
# all_train_score_W' ari split_num : 0 0.473503231295479
# test_score_W0 purity: 0.6233766233766234
# test_score_W0 nmi: 0.2632688035050178
# test_score_W0 api: 0.181272372713131
# test_score_W': purity split_num : 0 0.6233766233766234
# test_score_W': nmi split_num : 0 0.2632688035050178
# test_score_W': ari split_num : 0 0.181272372713131
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9668508287292817
# all_train_score_W' nmi split_num : 1 0.8881743335190787
# all_train_score_W' ari split_num : 1 0.9064409719985289
# test_score_W0 purity: 0.6233766233766234
# test_score_W0 nmi: 0.2632688035050178
# test_score_W0 api: 0.181272372713131
# test_score_W': purity split_num : 1 0.7142857142857143
# test_score_W': nmi split_num : 1 0.40368147160894635
# test_score_W': ari split_num : 1 0.3644018278270446
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.6233766233766234
# test_score_W0 nmi: 0.2632688035050178
# test_score_W0 api: 0.181272372713131
# test_score_W': purity split_num : 2 0.7142857142857143
# test_score_W': nmi split_num : 2 0.40377979805718883
# test_score_W': ari split_num : 2 0.35768159093656904
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7142857142857143
# test_scores_W_Combined_last_n 0.40377979805718883
# test_scores_W_Combined_last_a 0.35768159093656904
# neuron unit number: 44
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8913043478260869
# error_data0_score_W1 nmi 0.7431655201496821
# error_data0_score_W1 api 0.7128411545258198
# error_data0_score_W0 purity 0.7391304347826086
# error_data0_score_W0 nmi 0.5607158000153276
# error_data0_score_W0 api 0.3549970547810721
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 0.8326760405064336
# error_data1_score_W0 api 0.4117647058823529
# Error data can be represented by W0 purity 1
# right_data1_score_W' purity 0.7073170731707317
# right_data1_score_W' nmi 0.39795347454863034
# right_data1_score_W' api 0.21799686548185823
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7458563535911602
# all_train_score_W' nmi split_num : 0 0.47746784733278347
# all_train_score_W' ari split_num : 0 0.44086277917287325
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.25288935965564274
# test_score_W0 api: 0.19366465302807248
# test_score_W': purity split_num : 0 0.5974025974025974
# test_score_W': nmi split_num : 0 0.25288935965564274
# test_score_W': ari split_num : 0 0.19366465302807248
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9723756906077348
# all_train_score_W' nmi split_num : 1 0.9091772475740135
# all_train_score_W' ari split_num : 1 0.9191896819041453
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.25288935965564274
# test_score_W0 api: 0.19366465302807248
# test_score_W': purity split_num : 1 0.6753246753246753
# test_score_W': nmi split_num : 1 0.3364793270889861
# test_score_W': ari split_num : 1 0.2696881008416093
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.5974025974025974
# test_score_W0 nmi: 0.25288935965564274
# test_score_W0 api: 0.19366465302807248
# test_score_W': purity split_num : 2 0.7012987012987013
# test_score_W': nmi split_num : 2 0.38175933999973355
# test_score_W': ari split_num : 2 0.303034673465274
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7012987012987013
# test_scores_W_Combined_last_n 0.38175933999973355
# test_scores_W_Combined_last_a 0.303034673465274
# neuron unit number: 48
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.875
# error_data0_score_W1 nmi 0.7527873431447843
# error_data0_score_W1 api 0.7499648324104505
# error_data0_score_W0 purity 0.7291666666666666
# error_data0_score_W0 nmi 0.6114887008382663
# error_data0_score_W0 api 0.49178200692041524
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 1.0
# error_data1_score_W0 api 1.0
# Error data can be represented by W0 purity 1
# Error data can be represented by W0 nmi 1
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.47619047619047616
# right_data1_score_W' nmi 0.20054958892668687
# right_data1_score_W' api 0.0661356649498942
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7348066298342542
# all_train_score_W' nmi split_num : 0 0.4603037644423984
# all_train_score_W' ari split_num : 0 0.43228860498020016
# test_score_W0 purity: 0.7402597402597403
# test_score_W0 nmi: 0.3997722013049886
# test_score_W0 api: 0.39403651898252107
# test_score_W': purity split_num : 0 0.7402597402597403
# test_score_W': nmi split_num : 0 0.3997722013049886
# test_score_W': ari split_num : 0 0.39403651898252107
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9668508287292817
# all_train_score_W' nmi split_num : 1 0.8867897066750172
# all_train_score_W' ari split_num : 1 0.9162871808309591
# test_score_W0 purity: 0.7402597402597403
# test_score_W0 nmi: 0.3997722013049886
# test_score_W0 api: 0.39403651898252107
# test_score_W': purity split_num : 1 0.7402597402597403
# test_score_W': nmi split_num : 1 0.41110215899645736
# test_score_W': ari split_num : 1 0.3880223178434193
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.7402597402597403
# test_score_W0 nmi: 0.3997722013049886
# test_score_W0 api: 0.39403651898252107
# test_score_W': purity split_num : 2 0.7532467532467533
# test_score_W': nmi split_num : 2 0.4427536069560568
# test_score_W': ari split_num : 2 0.4310770444875512
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7532467532467533
# test_scores_W_Combined_last_n 0.4427536069560568
# test_scores_W_Combined_last_a 0.4310770444875512
# neuron unit number: 52
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8793103448275862
# error_data0_score_W1 nmi 0.6927840369640114
# error_data0_score_W1 api 0.6794636378781851
# error_data0_score_W0 purity 0.7241379310344828
# error_data0_score_W0 nmi 0.5929990387709752
# error_data0_score_W0 api 0.44878639341353954
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.7142857142857143
# error_data1_score_W0 nmi 0.6702252276515629
# error_data1_score_W0 api 0.14634146341463414
# right_data1_score_W' purity 0.6862745098039216
# right_data1_score_W' nmi 0.41358302056256097
# right_data1_score_W' api 0.31097468710144616
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.6795580110497238
# all_train_score_W' nmi split_num : 0 0.4179857517647071
# all_train_score_W' ari split_num : 0 0.3667756227747543
# test_score_W0 purity: 0.6363636363636364
# test_score_W0 nmi: 0.3317951948795966
# test_score_W0 api: 0.2555765791805263
# test_score_W': purity split_num : 0 0.6363636363636364
# test_score_W': nmi split_num : 0 0.3317951948795966
# test_score_W': ari split_num : 0 0.2555765791805263
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9613259668508287
# all_train_score_W' nmi split_num : 1 0.8614421962108446
# all_train_score_W' ari split_num : 1 0.8922633258016416
# test_score_W0 purity: 0.6363636363636364
# test_score_W0 nmi: 0.3317951948795966
# test_score_W0 api: 0.2555765791805263
# test_score_W': purity split_num : 1 0.7402597402597403
# test_score_W': nmi split_num : 1 0.42497651648313717
# test_score_W': ari split_num : 1 0.3806247474435478
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.6363636363636364
# test_score_W0 nmi: 0.3317951948795966
# test_score_W0 api: 0.2555765791805263
# test_score_W': purity split_num : 2 0.7402597402597403
# test_score_W': nmi split_num : 2 0.42497651648313717
# test_score_W': ari split_num : 2 0.3806247474435478
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7402597402597403
# test_scores_W_Combined_last_n 0.42497651648313717
# test_scores_W_Combined_last_a 0.3806247474435478
# neuron unit number: 56
# *******************
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.9347826086956522
# error_data0_score_W1 nmi 0.8006508590078161
# error_data0_score_W1 api 0.7952006619776583
# error_data0_score_W0 purity 0.8478260869565217
# error_data0_score_W0 nmi 0.6132709948406002
# error_data0_score_W0 api 0.5647399654221765
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 1.0
# error_data1_score_W0 api 1.0
# Error data can be represented by W0 purity 1
# Error data can be represented by W0 nmi 1
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.7441860465116279
# right_data1_score_W' nmi 0.3854686026416305
# right_data1_score_W' api 0.3334350856939881
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7458563535911602
# all_train_score_W' nmi split_num : 0 0.5122151159773854
# all_train_score_W' ari split_num : 0 0.4601889347482926
# test_score_W0 purity: 0.6623376623376623
# test_score_W0 nmi: 0.3283427588002384
# test_score_W0 api: 0.27451025349670394
# test_score_W': purity split_num : 0 0.6623376623376623
# test_score_W': nmi split_num : 0 0.3283427588002384
# test_score_W': ari split_num : 0 0.27451025349670394
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9834254143646409
# all_train_score_W' nmi split_num : 1 0.9377639730038805
# all_train_score_W' ari split_num : 1 0.9528532066952231
# test_score_W0 purity: 0.6623376623376623
# test_score_W0 nmi: 0.3283427588002384
# test_score_W0 api: 0.27451025349670394
# test_score_W': purity split_num : 1 0.7662337662337663
# test_score_W': nmi split_num : 1 0.4596932616074487
# test_score_W': ari split_num : 1 0.4007294736226139
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.6623376623376623
# test_score_W0 nmi: 0.3283427588002384
# test_score_W0 api: 0.27451025349670394
# test_score_W': purity split_num : 2 0.7662337662337663
# test_score_W': nmi split_num : 2 0.4596932616074487
# test_score_W': ari split_num : 2 0.4007294736226139
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7662337662337663
# test_scores_W_Combined_last_n 0.4596932616074487
# test_scores_W_Combined_last_a 0.4007294736226139
# neuron unit number: 60
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.9459459459459459
# error_data0_score_W1 nmi 0.8574629263712616
# error_data0_score_W1 api 0.8473382308543826
# error_data0_score_W0 purity 0.6216216216216216
# error_data0_score_W0 nmi 0.4909988985860688
# error_data0_score_W0 api 0.28824877902920365
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 1.0
# error_data1_score_W0 api 1.0
# Error data can be represented by W0 purity 1
# Error data can be represented by W0 nmi 1
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.7428571428571429
# right_data1_score_W' nmi 0.43501033358532193
# right_data1_score_W' api 0.3081081897397949
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7955801104972375
# all_train_score_W' nmi split_num : 0 0.5305147573150293
# all_train_score_W' ari split_num : 0 0.5409533319688183
# test_score_W0 purity: 0.7402597402597403
# test_score_W0 nmi: 0.4298874020947303
# test_score_W0 api: 0.39765992282724216
# test_score_W': purity split_num : 0 0.7402597402597403
# test_score_W': nmi split_num : 0 0.4298874020947303
# test_score_W': ari split_num : 0 0.39765992282724216
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.988950276243094
# all_train_score_W' nmi split_num : 1 0.9600227636726041
# all_train_score_W' ari split_num : 1 0.9710345810699942
# test_score_W0 purity: 0.7402597402597403
# test_score_W0 nmi: 0.4298874020947303
# test_score_W0 api: 0.39765992282724216
# test_score_W': purity split_num : 1 0.7272727272727273
# test_score_W': nmi split_num : 1 0.3858499223285075
# test_score_W': ari split_num : 1 0.3530996783725275
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.7402597402597403
# test_score_W0 nmi: 0.4298874020947303
# test_score_W0 api: 0.39765992282724216
# test_score_W': purity split_num : 2 0.7272727272727273
# test_score_W': nmi split_num : 2 0.3858499223285075
# test_score_W': ari split_num : 2 0.3530996783725275
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7272727272727273
# test_scores_W_Combined_last_n 0.3858499223285075
# test_scores_W_Combined_last_a 0.3530996783725275
# neuron unit number: 64
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8723404255319149
# error_data0_score_W1 nmi 0.7843122484220614
# error_data0_score_W1 api 0.7237460815047022
# error_data0_score_W0 purity 0.8297872340425532
# error_data0_score_W0 nmi 0.6790630295204217
# error_data0_score_W0 api 0.5307237593760866
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 0.8333333333333334
# error_data1_score_W0 nmi 0.41244039972177104
# error_data1_score_W0 api 0.018691588785046728
# right_data1_score_W' purity 0.6097560975609756
# right_data1_score_W' nmi 0.34839004841789767
# ...
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.5277777777777778
# right_data1_score_W' nmi 0.31121345094653136
# right_data1_score_W' api 0.146882802901193
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7955801104972375
# all_train_score_W' nmi split_num : 0 0.5447769429871128
# all_train_score_W' ari split_num : 0 0.5487030207796617
# test_score_W0 purity: 0.7142857142857143
# test_score_W0 nmi: 0.43704378761893115
# test_score_W0 api: 0.34633572990998385
# test_score_W': purity split_num : 0 0.7142857142857143
# test_score_W': nmi split_num : 0 0.43704378761893115
# test_score_W': ari split_num : 0 0.34633572990998385
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.994475138121547
# all_train_score_W' nmi split_num : 1 0.9792257403712551
# all_train_score_W' ari split_num : 1 0.9841798412064773
# test_score_W0 purity: 0.7142857142857143
# test_score_W0 nmi: 0.43704378761893115
# test_score_W0 api: 0.34633572990998385
# test_score_W': purity split_num : 1 0.7142857142857143
# test_score_W': nmi split_num : 1 0.41001194335209623
# test_score_W': ari split_num : 1 0.3471208085480706
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.7142857142857143
# test_score_W0 nmi: 0.43704378761893115
# test_score_W0 api: 0.34633572990998385
# test_score_W': purity split_num : 2 0.7142857142857143
# test_score_W': nmi split_num : 2 0.41001194335209623
# test_score_W': ari split_num : 2 0.3471208085480706
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7142857142857143
# test_scores_W_Combined_last_n 0.41001194335209623
# test_scores_W_Combined_last_a 0.3471208085480706
# neuron unit number: 108
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.9473684210526315
# error_data0_score_W1 nmi 0.898469772290753
# error_data0_score_W1 api 0.8744128371917067
# error_data0_score_W0 purity 0.6842105263157895
# error_data0_score_W0 nmi 0.6101598840973419
# error_data0_score_W0 api 0.3880685174246899
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 0.0
# error_data1_score_W0 api 0.0
# Error data can be represented by W0 purity 1
# right_data1_score_W' purity 0.5833333333333334
# right_data1_score_W' nmi 0.26619792254295144
# right_data1_score_W' api 0.11043203371970495
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7900552486187845
# all_train_score_W' nmi split_num : 0 0.5416956920676326
# all_train_score_W' ari split_num : 0 0.5345312776862428
# test_score_W0 purity: 0.6103896103896104
# test_score_W0 nmi: 0.27765294091976794
# test_score_W0 api: 0.14037121679868672
# test_score_W': purity split_num : 0 0.6103896103896104
# test_score_W': nmi split_num : 0 0.27765294091976794
# test_score_W': ari split_num : 0 0.14037121679868672
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.988950276243094
# all_train_score_W' nmi split_num : 1 0.9680217466028703
# all_train_score_W' ari split_num : 1 0.9768284491984208
# test_score_W0 purity: 0.6103896103896104
# test_score_W0 nmi: 0.27765294091976794
# test_score_W0 api: 0.14037121679868672
# test_score_W': purity split_num : 1 0.6623376623376623
# test_score_W': nmi split_num : 1 0.287229342019023
# test_score_W': ari split_num : 1 0.1837800180551
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.6103896103896104
# test_score_W0 nmi: 0.27765294091976794
# test_score_W0 api: 0.14037121679868672
# test_score_W': purity split_num : 2 0.6623376623376623
# test_score_W': nmi split_num : 2 0.2887601378669907
# test_score_W': ari split_num : 2 0.1939677305395744
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.6623376623376623
# test_scores_W_Combined_last_n 0.2887601378669907
# test_scores_W_Combined_last_a 0.1939677305395744
# neuron unit number: 112
# *******************
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.9361702127659575
# error_data0_score_W1 nmi 0.8301953779421025
# error_data0_score_W1 api 0.8356004663816556
# error_data0_score_W0 purity 0.6382978723404256
# error_data0_score_W0 nmi 0.4493135170696375
# error_data0_score_W0 api 0.2111136519551795
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 1.0
# error_data1_score_W0 api 1.0
# Error data can be represented by W0 purity 1
# Error data can be represented by W0 nmi 1
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.7272727272727273
# right_data1_score_W' nmi 0.4668919681427692
# right_data1_score_W' api 0.3537390941880055
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7403314917127072
# all_train_score_W' nmi split_num : 0 0.43502139671161505
# all_train_score_W' ari split_num : 0 0.4036425474177861
# test_score_W0 purity: 0.7272727272727273
# test_score_W0 nmi: 0.4097911603059051
# test_score_W0 api: 0.33952231832546276
# test_score_W': purity split_num : 0 0.7272727272727273
# test_score_W': nmi split_num : 0 0.4097911603059051
# test_score_W': ari split_num : 0 0.33952231832546276
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9834254143646409
# all_train_score_W' nmi split_num : 1 0.9396687414382325
# all_train_score_W' ari split_num : 1 0.9565458662091171
# test_score_W0 purity: 0.7272727272727273
# test_score_W0 nmi: 0.4097911603059051
# test_score_W0 api: 0.33952231832546276
# test_score_W': purity split_num : 1 0.7792207792207793
# test_score_W': nmi split_num : 1 0.4881294962670853
# test_score_W': ari split_num : 1 0.43875297576939404
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.7272727272727273
# test_score_W0 nmi: 0.4097911603059051
# test_score_W0 api: 0.33952231832546276
# test_score_W': purity split_num : 2 0.7792207792207793
# test_score_W': nmi split_num : 2 0.4836014938001833
# test_score_W': ari split_num : 2 0.46131514984064037
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7792207792207793
# test_scores_W_Combined_last_n 0.4836014938001833
# test_scores_W_Combined_last_a 0.46131514984064037
# neuron unit number: 116
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.95
# error_data0_score_W1 nmi 0.8774178847184285
# error_data0_score_W1 api 0.8750705994419483
# error_data0_score_W0 purity 0.7
# error_data0_score_W0 nmi 0.5739004627816608
# error_data0_score_W0 api 0.4135673833631616
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 1.0
# error_data1_score_W0 api 1.0
# Error data can be represented by W0 purity 1
# Error data can be represented by W0 nmi 1
# Error data can be represented by W0 api 1
# right_data1_score_W' purity 0.6052631578947368
# right_data1_score_W' nmi 0.3251302615618869
# right_data1_score_W' api 0.15567541599336157
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.7790055248618785
# all_train_score_W' nmi split_num : 0 0.5128236726599467
# all_train_score_W' ari split_num : 0 0.5069715543256001
# test_score_W0 purity: 0.6753246753246753
# test_score_W0 nmi: 0.35181242118740974
# test_score_W0 api: 0.26753198569267067
# test_score_W': purity split_num : 0 0.6753246753246753
# test_score_W': nmi split_num : 0 0.35181242118740974
# test_score_W': ari split_num : 0 0.26753198569267067
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.988950276243094
# all_train_score_W' nmi split_num : 1 0.9580135162027761
# all_train_score_W' ari split_num : 1 0.9666701508913162
# test_score_W0 purity: 0.6753246753246753
# test_score_W0 nmi: 0.35181242118740974
# test_score_W0 api: 0.26753198569267067
# test_score_W': purity split_num : 1 0.6753246753246753
# test_score_W': nmi split_num : 1 0.3326858496767888
# test_score_W': ari split_num : 1 0.23823932725584776
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.6753246753246753
# test_score_W0 nmi: 0.35181242118740974
# test_score_W0 api: 0.26753198569267067
# test_score_W': purity split_num : 2 0.6883116883116883
# test_score_W': nmi split_num : 2 0.33407605157557513
# test_score_W': ari split_num : 2 0.2618029590036427
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.6883116883116883
# test_scores_W_Combined_last_n 0.33407605157557513
# test_scores_W_Combined_last_a 0.2618029590036427
# neuron unit number: 120
# *******************
#
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 1.0
# error_data0_score_W1 nmi 1.0
# error_data0_score_W1 api 1.0
# error_data0_score_W0 purity 0.7692307692307693
# error_data0_score_W0 nmi 0.6026999867469592
# error_data0_score_W0 api 0.2905683690280066
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
#  NO Error Data, Finish Training!
# total split_number 1
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.856353591160221
# all_train_score_W' nmi split_num : 0 0.6556704524941717
# all_train_score_W' ari split_num : 0 0.6535784015400937
# test_score_W0 purity: 0.7272727272727273
# test_score_W0 nmi: 0.4133518407807438
# test_score_W0 api: 0.3381099754141264
# test_score_W': purity split_num : 0 0.7272727272727273
# test_score_W': nmi split_num : 0 0.4133518407807438
# test_score_W': ari split_num : 0 0.3381099754141264
# stop_split_num 1
# all_train_score_W' purity split_num : 1 1.0
# all_train_score_W' nmi split_num : 1 1.0
# all_train_score_W' ari split_num : 1 1.0
# test_score_W0 purity: 0.7272727272727273
# test_score_W0 nmi: 0.4133518407807438
# test_score_W0 api: 0.3381099754141264
# test_score_W': purity split_num : 1 0.7402597402597403
# test_score_W': nmi split_num : 1 0.4368424730294773
# test_score_W': ari split_num : 1 0.40855573241504034
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.7402597402597403
# test_scores_W_Combined_last_n 0.4368424730294773
# test_scores_W_Combined_last_a 0.40855573241504034
# s 16  value 0.6883116883116883
# s 20  value 0.7012987012987013
# s 32  value 0.7012987012987013
# s 36  value 0.7662337662337663
# s 48  value 0.7402597402597403
# s 60  value 0.7272727272727273
# s 64  value 0.7142857142857143
# s 72  value 0.7402597402597403
# s 80  value 0.7792207792207793
# s 84  value 0.7662337662337663
# s 96  value 0.7792207792207793
# s 108  value 0.7142857142857143
# s 112  value 0.6753246753246753
# s 120  value 0.7142857142857143
# Purity T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  14.0  0.650278  0.063921  0.017084   0.613371  0.687185
# 1  test_score_W'  14.0  0.729128  0.033734  0.009016   0.709650  0.748606
# 2       combined  28.0  0.689703  0.064243  0.012141   0.664793  0.714614
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0788
# 1                          Degrees of freedom =   26.0000
# 2                                           t =   -4.0819
# 3                       Two side test p value =    0.0004
# 4                      Difference < 0 p value =    0.0002
# 5                      Difference > 0 p value =    0.9998
# 6                                   Cohen's d =   -1.5428
# 7                                   Hedge's g =   -1.4979
# 8                               Glass's delta =   -1.2335
# 9                                 Pearson's r =    0.6249
# NMI T-Test
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  300.0  0.339007  0.081545  0.004708   0.329742  0.348272
# 1  test_score_W'  300.0  0.420968  0.063430  0.003662   0.413761  0.428175
# 2       combined  600.0  0.379987  0.083724  0.003418   0.373275  0.386700
#                               Independent t-test   results
# 0  Difference (test_score_W0 - test_score_W') =    -0.0820
# 1                          Degrees of freedom =   598.0000
# 2                                           t =   -13.7414
# 3                       Two side test p value =     0.0000
# 4                      Difference < 0 p value =     0.0000
# 5                      Difference > 0 p value =     1.0000
# 6                                   Cohen's d =    -1.1220
# 7                                   Hedge's g =    -1.1206
# 8                               Glass's delta =    -1.0051
# 9                                 Pearson's r =     0.4899
# ARI T-Test
#         Variable      N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  300.0  0.258487  0.085651  0.004945   0.248755  0.268218
# 1  test_score_W'  300.0  0.363637  0.072508  0.004186   0.355399  0.371875
# 2       combined  600.0  0.311062  0.095158  0.003885   0.303432  0.318691
#                               Independent t-test   results
# 0  Difference (test_score_W0 - test_score_W') =    -0.1052
# 1                          Degrees of freedom =   598.0000
# 2                                           t =   -16.2293
# 3                       Two side test p value =     0.0000
# 4                      Difference < 0 p value =     0.0000
# 5                      Difference > 0 p value =     1.0000
# 6                                   Cohen's d =    -1.3251
# 7                                   Hedge's g =    -1.3235
# 8                               Glass's delta =    -1.2277
# 9                                 Pearson's r =     0.5530
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
import experiment

unstable_repeate_num= 30
scope_num = 10
class_num = 4
dim_num = 5
smoothWeight = .6

experiment = experiment.Experiment()
experiment.findBestClusterNo(dataread.data_train,class_num, dim_num, scope_num,unstable_repeate_num,smoothWeight)
# Out:
# inertias_average 47.06273539723058  cluster_num 4
# inertias_average 42.67726167711147  cluster_num 5
# inertias_average 39.34999379622575  cluster_num 6
# inertias_average 35.43804829806254  cluster_num 7
# inertias_average 32.654169499623904  cluster_num 8
# inertias_average 31.625452570395982  cluster_num 9
# inertias_average 29.71905003662992  cluster_num 10
# inertias_average 28.565322381201742  cluster_num 11
# inertias_average 27.936897595472956  cluster_num 12
# inertias_average 27.434741540626625  cluster_num 13
# inertias_average 27.281102602557212  cluster_num 14
# inertias_average 26.998300356991702  cluster_num 15
# inertias_average 27.160342766906563  cluster_num 16
# inertias_average 26.83836251911931  cluster_num 17
# inertias_average 25.790018947547892  cluster_num 18
# inertias_average 25.38483319250727  cluster_num 19
# inertias_average 25.64115685759515  cluster_num 20
# inertias_average 24.698811959369248  cluster_num 21
# inertias_average 25.589077170920813  cluster_num 22
# inertias_average 25.601873954314367  cluster_num 23
# inertias_average 26.211269603476616  cluster_num 24
# inertias_average 25.314734517305734  cluster_num 25
# inertias_average 24.675828870028578  cluster_num 26
# inertias_average 25.42030748839996  cluster_num 27
# inertias_average 23.818678175514165  cluster_num 28
# inertias_average 24.258698563574765  cluster_num 29
# inertias_average 24.567432808558372  cluster_num 30
# inertias_average 24.5116623151068  cluster_num 31
# inertias_average 24.901536539375957  cluster_num 32
# inertias_average 23.734569268447498  cluster_num 33
# inertias_average 23.159710832833582  cluster_num 34
# inertias_average 23.317252520708255  cluster_num 35
# inertias_average 23.946344447468004  cluster_num 36
# inertias_average 23.709735147092264  cluster_num 37
# inertias_average 22.613249715494934  cluster_num 38
# inertias_average 22.537204962887497  cluster_num 39
# inertias_average 23.324510380784204  cluster_num 40
# silhouette_score_average 0.09733338501252703  cluster_num 4
# silhouette_score_average 0.10159833073551937  cluster_num 5
# silhouette_score_average 0.09081220026890034  cluster_num 6
# silhouette_score_average 0.09432290882145766  cluster_num 7
# silhouette_score_average 0.09594338009092754  cluster_num 8
# silhouette_score_average 0.09720420673526299  cluster_num 9
# silhouette_score_average 0.09287949658397514  cluster_num 10
# silhouette_score_average 0.10138356830097238  cluster_num 11
# silhouette_score_average 0.09753760776121198  cluster_num 12
# silhouette_score_average 0.08577131501824621  cluster_num 13
# silhouette_score_average 0.08558154926907857  cluster_num 14
# silhouette_score_average 0.09097655021047092  cluster_num 15
# silhouette_score_average 0.08203449147389992  cluster_num 16
# silhouette_score_average 0.0818274004747625  cluster_num 17
# silhouette_score_average 0.09415960527409925  cluster_num 18
# silhouette_score_average 0.08035009168130812  cluster_num 19
# silhouette_score_average 0.0836284003926386  cluster_num 20
# silhouette_score_average 0.08452550574393962  cluster_num 21
# silhouette_score_average 0.08400454699494508  cluster_num 22
# silhouette_score_average 0.08659685067947283  cluster_num 23
# silhouette_score_average 0.0784441035567387  cluster_num 24
# silhouette_score_average 0.08562992199556438  cluster_num 25
# silhouette_score_average 0.08119098162353418  cluster_num 26
# silhouette_score_average 0.0806354861974671  cluster_num 27
# silhouette_score_average 0.08894517002032169  cluster_num 28
# silhouette_score_average 0.08575203464344956  cluster_num 29
# silhouette_score_average 0.08263778359110588  cluster_num 30
# silhouette_score_average 0.08747264521627657  cluster_num 31
# silhouette_score_average 0.09246872360181975  cluster_num 32
# silhouette_score_average 0.08438384002855247  cluster_num 33
# silhouette_score_average 0.08511572196835329  cluster_num 34
# silhouette_score_average 0.09339868569654813  cluster_num 35
# silhouette_score_average 0.0825390437411905  cluster_num 36
# silhouette_score_average 0.08131896562552081  cluster_num 37
# silhouette_score_average 0.08368994871659916  cluster_num 38
# silhouette_score_average 0.08172382476182936  cluster_num 39
# silhouette_score_average 0.08762867339529681  cluster_num 40

# %%
# compare between best cluster no with TDSM NMI

scoretype = 1
class_num = 4
dim_num = 5
best_cluster_no = 18

som = newSom.SOM(m= best_cluster_no, n=  1, dim=dim_num)  
optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
optimize_W.run(scoretype)
# Out:
# error_data0_score_W1 0.3803185552606198
# error_data0_score_W0 0.5311631563748858
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 0.6813797407556976
# error_data1_score_W0 0.5341740975624967
# right_data1_score_W' 0.3307101776417593
# Finish one round splitting 1 *********
#
# error_data2_score_W1 1.0
# error_data2_score_W0 0.7336804366512112
# right_data2_score_W' 0.788575905972584
# Finish one round splitting 2 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' split_num : 0 0.31891149578094885
# test_score_W0 : 0.18513552556682222
# test_score_W': split_num : 0 0.18513552556682222
# stop_split_num 1
# all_train_score_W' split_num : 1 0.6813672869755775
# test_score_W0 : 0.18513552556682222
# test_score_W': split_num : 1 0.31970205586140027
# stop_split_num 2
# all_train_score_W' split_num : 2 0.9457238822455355
# test_score_W0 : 0.18513552556682222
# test_score_W': split_num : 2 0.3811968954480986

# %%
# compare between best cluster no with TDSM ARI

scoretype = 2
class_num = 4
dim_num = 5
best_cluster_no = 18

som = newSom.SOM(m= best_cluster_no, n=  1, dim=dim_num)  
optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
optimize_W.run(scoretype)
# Out:
# error_data0_score_W1 0.5676649827474153
# error_data0_score_W0 0.36251106053365006
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 1.0
# error_data1_score_W0 0.71875
# right_data1_score_W' 0.17369283792871554
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 1
# stop_split_num 0
# all_train_score_W' split_num : 0 0.39741613487973015
# test_score_W0 : 0.20648646901002776
# test_score_W': split_num : 0 0.20648646901002776
# stop_split_num 1
# all_train_score_W' split_num : 1 0.86813062434558
# test_score_W0 : 0.20648646901002776
# test_score_W': split_num : 1 0.37186869274567946

# %%
# local scope2
scoretype = 2
scope_num = 23
class_num = 4
dim_num = 5
unstable_repeat_num = 1


unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.5359116022099447
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3285019075265658
# error_data0_score_W0 0.11978416707527306
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.406322853546105
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.1086285040201161
# error_data1_score_W0 0.06767907303370786
# combinedweight shape1 : (12, 5)
# right_data1_score_W' 0.03787115846923527
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.24279835390946503
# error_data2_score_W0 0.08333333333333333
# combinedweight shape1 : (16, 5)
# right_data2_score_W' 0.21580782642386673
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 -0.2
# error_data3_score_W0 -0.2857142857142857
# combinedweight shape1 : (20, 5)
# right_data3_score_W' 0.16
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (24, 5)
# right_data4_score_W' 0.0
# Finish one training *********
# 5
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.06591690160325851
# all_train_score_W': 1.0
# test_score_W0 : 0.05011517906002091
# test_score_W': 0.37795250078301346
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.4419889502762431
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3973668316360732
# error_data0_score_W0 0.27424656058048064
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.4490787309535971
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.47876447876447875
# error_data1_score_W0 0.3231441048034934
# combinedweight shape1 : (24, 5)
# right_data1_score_W' 0.3691701829596734
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.782608695652174
# combinedweight shape1 : (32, 5)
# right_data2_score_W' 0.06706840754380092
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.17073166726468225
# all_train_score_W': 1.0
# test_score_W0 : 0.20894107594640962
# test_score_W': 0.5335713301062136
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.3867403314917127
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4185112937208763
# error_data0_score_W0 0.11230652321721393
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.2995886614420726
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7733962788114412
# error_data1_score_W0 0.2406699970614164
# combinedweight shape1 : (36, 5)
# right_data1_score_W' 0.3255991065473011
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (48, 5)
# right_data2_score_W' 0.2397003745318352
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1810677042119832
# all_train_score_W': 1.0
# test_score_W0 : 0.025613284600355175
# test_score_W': 0.2527438723502738
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.3756906077348066
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4703897093013111
# error_data0_score_W0 0.2509373468869079
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.42471472376180824
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6374622356495468
# error_data1_score_W0 0.06832298136645963
# combinedweight shape1 : (48, 5)
# right_data1_score_W' 0.1853863901681236
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (64, 5)
# right_data2_score_W' 0.35384615384615387
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.236778580071273
# all_train_score_W': 1.0
# test_score_W0 : 0.3215677015700626
# test_score_W': 0.3164871528945532
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.3812154696132597
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5450374768609968
# error_data0_score_W0 0.31349430369830616
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.6895504213172187
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.7953216374269005
# error_data1_score_W0 0.11764705882352941
# combinedweight shape1 : (60, 5)
# right_data1_score_W' 0.5459997138431487
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (80, 5)
# right_data2_score_W' 0.2241169305724726
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.2667634458699235
# all_train_score_W': 1.0
# test_score_W0 : 0.15692559009935794
# test_score_W': 0.29505860617173807
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5041998472782808
# error_data0_score_W0 0.33557046979865773
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.42686006877659494
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.1662425784563189
# combinedweight shape1 : (72, 5)
# right_data1_score_W' 0.11235380584137535
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.34801428831977654
# all_train_score_W': 1.0
# test_score_W0 : 0.22784533605184593
# test_score_W': 0.3025605686547839
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.281767955801105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6117024484380654
# error_data0_score_W0 0.5037570552996987
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.45230355748451884
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.03076923076923077
# combinedweight shape1 : (84, 5)
# right_data1_score_W' 0.623560180290468
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4207085139597178
# all_train_score_W': 1.0
# test_score_W0 : 0.3336607355176229
# test_score_W': 0.37165318348070636
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6121300818401174
# error_data0_score_W0 0.23522462278970757
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.5054062618901354
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.0425531914893617
# combinedweight shape1 : (96, 5)
# right_data1_score_W' 0.19864128957923455
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3356288260765059
# all_train_score_W': 1.0
# test_score_W0 : 0.19141784637940393
# test_score_W': 0.312044513358028
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.580672236102436
# error_data0_score_W0 0.4184335197266232
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.428308917770179
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.24299065420560748
# combinedweight shape1 : (108, 5)
# right_data1_score_W' 0.2856070170045997
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.37623471271058356
# all_train_score_W': 1.0
# test_score_W0 : 0.33870175250062456
# test_score_W': 0.3947154497564473
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.740926864806197
# error_data0_score_W0 0.392644580217002
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.4418011726180476
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4117647058823529
# combinedweight shape1 : (120, 5)
# right_data1_score_W' 0.2975579725015391
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.49861620763745895
# all_train_score_W': 1.0
# test_score_W0 : 0.32829979417943717
# test_score_W': 0.33709641655499534
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6896072699910283
# error_data0_score_W0 0.2389955320205196
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.3940328864391843
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.3157894736842105
# combinedweight shape1 : (132, 5)
# right_data1_score_W' 0.48627698125098473
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4969511749622465
# all_train_score_W': 1.0
# test_score_W0 : 0.2981805308856531
# test_score_W': 0.3005472302661279
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5941792782305005
# error_data0_score_W0 0.42816028337392076
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.4387677489091274
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.02
# combinedweight shape1 : (144, 5)
# right_data1_score_W' 0.39185678776590616
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.3630295289893773
# all_train_score_W': 1.0
# test_score_W0 : 0.23566290238315316
# test_score_W': 0.43010013519396895
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8347292850732875
# error_data0_score_W0 0.4140220503136992
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.4703210280957472
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (156, 5)
# right_data1_score_W' 0.5218370103556956
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4978658302615305
# all_train_score_W': 1.0
# test_score_W0 : 0.3935940905989367
# test_score_W': 0.371675912023571
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.2983425414364641
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6751126898463256
# error_data0_score_W0 0.3679930720935267
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.5536370501729521
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.2026431718061674
# combinedweight shape1 : (168, 5)
# right_data1_score_W' 0.25573316056912865
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.38544943794736714
# all_train_score_W': 1.0
# test_score_W0 : 0.27341694101584435
# test_score_W': 0.3496810488552668
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5542325171597288
# error_data0_score_W0 0.2608101719781563
# combinedweight shape 0: (120, 5)
# right_data0_score_W' 0.5999768951626714
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8549222797927462
# combinedweight shape1 : (180, 5)
# right_data1_score_W' 0.4274522355036667
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4334122634876727
# all_train_score_W': 1.0
# test_score_W0 : 0.32657801631655897
# test_score_W': 0.3119904050415129
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5494696197314476
# error_data0_score_W0 0.2582112802591344
# combinedweight shape 0: (128, 5)
# right_data0_score_W' 0.4950611717790232
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5794392523364486
# error_data1_score_W0 -0.20446096654275092
# combinedweight shape1 : (192, 5)
# right_data1_score_W' 0.2549485016742254
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (256, 5)
# right_data2_score_W' 0.33962264150943394
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.46493111920522656
# all_train_score_W': 1.0
# test_score_W0 : 0.17904528641349446
# test_score_W': 0.2543257762666372
# neuron unit number: 68
# *******************
#
# Error Data percentage 0.18232044198895028
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6664498987384107
# error_data0_score_W0 0.40781681800236874
# combinedweight shape 0: (136, 5)
# right_data0_score_W' 0.5233058173258579
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.2
# combinedweight shape1 : (204, 5)
# right_data1_score_W' 0.4316870010023157
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5948046933226971
# all_train_score_W': 1.0
# test_score_W0 : 0.3986587531960183
# test_score_W': 0.346753423206277
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.19889502762430938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8322630115978146
# error_data0_score_W0 0.3517890041694948
# combinedweight shape 0: (144, 5)
# right_data0_score_W' 0.5204344274885745
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (216, 5)
# right_data1_score_W' 0.33874770009199634
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.542845389295462
# all_train_score_W': 1.0
# test_score_W0 : 0.14975821470264097
# test_score_W': 0.2867496482353356
# neuron unit number: 76
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6186126536949741
# error_data0_score_W0 0.3143512297715721
# combinedweight shape 0: (152, 5)
# right_data0_score_W' 0.6145198831278166
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.2962962962962963
# combinedweight shape1 : (228, 5)
# right_data1_score_W' 0.48198527619326215
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4967932014541763
# all_train_score_W': 1.0
# test_score_W0 : 0.14694832169030708
# test_score_W': 0.1676764821156651
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.19889502762430938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9425249905511606
# error_data0_score_W0 0.5624841479763759
# combinedweight shape 0: (160, 5)
# right_data0_score_W' 0.5749037223493797
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (240, 5)
# right_data1_score_W' 0.5109440165606259
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5537047620929599
# all_train_score_W': 1.0
# test_score_W0 : 0.28130366916128424
# test_score_W': 0.39133292799113717
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7672596863792982
# error_data0_score_W0 0.2195057203534973
# combinedweight shape 0: (168, 5)
# right_data0_score_W' 0.5715798193115408
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (252, 5)
# right_data1_score_W' 0.6229015284389877
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4994632004500047
# all_train_score_W': 1.0
# test_score_W0 : 0.40884863717120945
# test_score_W': 0.36408874889641074
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9076225996362852
# error_data0_score_W0 0.33134476035270494
# combinedweight shape 0: (176, 5)
# right_data0_score_W' 0.4143283257019277
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (264, 5)
# right_data1_score_W' 0.5291961012250738
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5446192724359992
# all_train_score_W': 1.0
# test_score_W0 : 0.26689225630925223
# test_score_W': 0.4528926476730145
# neuron unit number: 92
# *******************
#
# Error Data percentage 0.20994475138121546
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8340952197816606
# error_data0_score_W0 0.3361910193244393
# combinedweight shape 0: (184, 5)
# right_data0_score_W' 0.40920636161150403
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (276, 5)
# right_data1_score_W' 0.39090729070810376
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5253196180360534
# all_train_score_W': 1.0
# test_score_W0 : 0.2858079705733757
# test_score_W': 0.36348094851635515
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  23.0  0.253382  0.103479  0.021577   0.208634  0.298129
# 1  test_score_W'  23.0  0.342834  0.074798  0.015596   0.310489  0.375179
# 2       combined  46.0  0.298108  0.100075  0.014755   0.268389  0.327826
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0895
# 1                          Degrees of freedom =   44.0000
# 2                                           t =   -3.3599
# 3                       Two side test p value =    0.0016
# 4                      Difference < 0 p value =    0.0008
# 5                      Difference > 0 p value =    0.9992
# 6                                   Cohen's d =   -0.9908
# 7                                   Hedge's g =   -0.9738
# 8                               Glass's delta =   -0.8644
# 9                                 Pearson's r =    0.4519
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-3.35989710427217, pvalue=0.0008097381056689241)

# %%
scoretype = 0
scope_num = 60
class_num = 4
dim_num = 5
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:       
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 4
# *******************
#
# Error Data percentage 0.580110497237569
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4666666666666667
# error_data0_score_W0 0.5714285714285714
# combinedweight shape 0: (8, 5)
# right_data0_score_W' 0.6973684210526315
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5892857142857143
# error_data1_score_W0 0.4642857142857143
# combinedweight shape1 : (12, 5)
# right_data1_score_W' 0.7959183673469388
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6521739130434783
# error_data2_score_W0 0.6086956521739131
# combinedweight shape1 : (16, 5)
# right_data2_score_W' 0.7575757575757576
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.875
# error_data3_score_W0 0.75
# combinedweight shape1 : (20, 5)
# right_data3_score_W' 0.9333333333333333
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (24, 5)
# right_data4_score_W' 1.0
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W0: 0.4198895027624309
# all_train_score_W': 1.0
# test_score_W0 : 0.37662337662337664
# test_score_W': 0.7272727272727273
# class_num*x*(optimize_W.split_num +1)24
# neuron unit number: 8
# *******************
#
# Error Data percentage 0.4530386740331492
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7317073170731707
# error_data0_score_W0 0.5365853658536586
# combinedweight shape 0: (16, 5)
# right_data0_score_W' 0.8686868686868687
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6363636363636364
# error_data1_score_W0 0.5909090909090909
# combinedweight shape1 : (24, 5)
# right_data1_score_W' 0.6833333333333333
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.625
# combinedweight shape1 : (32, 5)
# right_data2_score_W' 0.8571428571428571
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.5469613259668509
# all_train_score_W': 1.0
# test_score_W0 : 0.5454545454545454
# test_score_W': 0.6753246753246753
# class_num*x*(optimize_W.split_num +1)32
# neuron unit number: 12
# *******************
#
# Error Data percentage 0.35911602209944754
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7230769230769231
# error_data0_score_W0 0.6153846153846154
# combinedweight shape 0: (24, 5)
# right_data0_score_W' 0.7844827586206896
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (36, 5)
# right_data1_score_W' 0.8936170212765957
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6408839779005525
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)36
# neuron unit number: 16
# *******************
#
# Error Data percentage 0.4143646408839779
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6933333333333334
# error_data0_score_W0 0.76
# combinedweight shape 0: (32, 5)
# right_data0_score_W' 0.8301886792452831
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9565217391304348
# error_data1_score_W0 0.5652173913043478
# combinedweight shape1 : (48, 5)
# right_data1_score_W' 0.6538461538461539
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (64, 5)
# right_data2_score_W' 0.8181818181818182
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.585635359116022
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.7532467532467533
# class_num*x*(optimize_W.split_num +1)64
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.292817679558011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7735849056603774
# error_data0_score_W0 0.6792452830188679
# combinedweight shape 0: (40, 5)
# right_data0_score_W' 0.71875
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (60, 5)
# right_data1_score_W' 0.7317073170731707
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7071823204419889
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7532467532467533
# class_num*x*(optimize_W.split_num +1)60
# neuron unit number: 24
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.925
# error_data0_score_W0 0.65
# combinedweight shape 0: (48, 5)
# right_data0_score_W' 0.7872340425531915
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (72, 5)
# right_data1_score_W' 0.5675675675675675
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.7012987012987013
# class_num*x*(optimize_W.split_num +1)72
# neuron unit number: 28
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.926829268292683
# error_data0_score_W0 0.7073170731707317
# combinedweight shape 0: (56, 5)
# right_data0_score_W' 0.8071428571428572
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (84, 5)
# right_data1_score_W' 0.7105263157894737
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 1.0
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.7662337662337663
# class_num*x*(optimize_W.split_num +1)84
# neuron unit number: 32
# *******************
#
# Error Data percentage 0.3314917127071823
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.6333333333333333
# combinedweight shape 0: (64, 5)
# right_data0_score_W' 0.8099173553719008
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8
# combinedweight shape1 : (96, 5)
# right_data1_score_W' 0.68
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6685082872928176
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7272727272727273
# class_num*x*(optimize_W.split_num +1)96
# neuron unit number: 36
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.725
# combinedweight shape 0: (72, 5)
# right_data0_score_W' 0.7801418439716312
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (108, 5)
# right_data1_score_W' 0.8055555555555556
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)108
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.2983425414364641
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9074074074074074
# error_data0_score_W0 0.7592592592592593
# combinedweight shape 0: (80, 5)
# right_data0_score_W' 0.7952755905511811
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (120, 5)
# right_data1_score_W' 0.7551020408163265
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7016574585635359
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.7012987012987013
# class_num*x*(optimize_W.split_num +1)120
# neuron unit number: 44
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9761904761904762
# error_data0_score_W0 0.6190476190476191
# combinedweight shape 0: (88, 5)
# right_data0_score_W' 0.8345323741007195
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (132, 5)
# right_data1_score_W' 0.8292682926829268
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 1.0
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6363636363636364
# class_num*x*(optimize_W.split_num +1)132
# neuron unit number: 48
# *******************
#
# Error Data percentage 0.30939226519337015
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 0.7142857142857143
# combinedweight shape 0: (96, 5)
# right_data0_score_W' 0.688
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (144, 5)
# right_data1_score_W' 0.7291666666666666
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6906077348066298
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)144
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9591836734693877
# error_data0_score_W0 0.673469387755102
# combinedweight shape 0: (104, 5)
# right_data0_score_W' 0.8181818181818182
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (156, 5)
# right_data1_score_W' 0.5957446808510638
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)156
# neuron unit number: 56
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8545454545454545
# error_data0_score_W0 0.7636363636363637
# combinedweight shape 0: (112, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (168, 5)
# right_data1_score_W' 0.8085106382978723
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 1.0
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.7142857142857143
# class_num*x*(optimize_W.split_num +1)168
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9807692307692307
# error_data0_score_W0 0.8461538461538461
# combinedweight shape 0: (120, 5)
# right_data0_score_W' 0.8217054263565892
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (180, 5)
# right_data1_score_W' 0.8431372549019608
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 1.0
# test_score_W0 : 0.7272727272727273
# test_score_W': 0.7532467532467533
# class_num*x*(optimize_W.split_num +1)180
# neuron unit number: 64
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.95
# error_data0_score_W0 0.65
# combinedweight shape 0: (128, 5)
# right_data0_score_W' 0.8439716312056738
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (192, 5)
# right_data1_score_W' 0.7631578947368421
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6493506493506493
# class_num*x*(optimize_W.split_num +1)192
# neuron unit number: 68
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9166666666666666
# error_data0_score_W0 0.7708333333333334
# combinedweight shape 0: (136, 5)
# right_data0_score_W' 0.8721804511278195
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (204, 5)
# right_data1_score_W' 0.7954545454545454
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7348066298342542
# all_train_score_W': 1.0
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)204
# neuron unit number: 72
# *******************
#
# Error Data percentage 0.26519337016574585
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9166666666666666
# error_data0_score_W0 0.7916666666666666
# combinedweight shape 0: (144, 5)
# right_data0_score_W' 0.8045112781954887
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (216, 5)
# right_data1_score_W' 0.7727272727272727
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7348066298342542
# all_train_score_W': 1.0
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6233766233766234
# class_num*x*(optimize_W.split_num +1)216
# neuron unit number: 76
# *******************
#
# Error Data percentage 0.27071823204419887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9183673469387755
# error_data0_score_W0 0.7142857142857143
# combinedweight shape 0: (152, 5)
# right_data0_score_W' 0.8106060606060606
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (228, 5)
# right_data1_score_W' 0.6666666666666666
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7292817679558011
# all_train_score_W': 1.0
# test_score_W0 : 0.5714285714285714
# test_score_W': 0.5974025974025974
# class_num*x*(optimize_W.split_num +1)228
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.24861878453038674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9555555555555556
# error_data0_score_W0 0.7555555555555555
# combinedweight shape 0: (160, 5)
# right_data0_score_W' 0.7720588235294118
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (240, 5)
# right_data1_score_W' 0.813953488372093
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7513812154696132
# all_train_score_W': 1.0
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.7402597402597403
# class_num*x*(optimize_W.split_num +1)240
# neuron unit number: 84
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9512195121951219
# error_data0_score_W0 0.7073170731707317
# combinedweight shape 0: (168, 5)
# right_data0_score_W' 0.8714285714285714
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (252, 5)
# right_data1_score_W' 0.7692307692307693
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 1.0
# test_score_W0 : 0.6233766233766234
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)252
# neuron unit number: 88
# *******************
#
# Error Data percentage 0.287292817679558
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9615384615384616
# error_data0_score_W0 0.8269230769230769
# combinedweight shape 0: (176, 5)
# right_data0_score_W' 0.7751937984496124
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (264, 5)
# right_data1_score_W' 0.78
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.712707182320442
# all_train_score_W': 1.0
# test_score_W0 : 0.5714285714285714
# test_score_W': 0.6363636363636364
# class_num*x*(optimize_W.split_num +1)264
# neuron unit number: 92
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8780487804878049
# error_data0_score_W0 0.6585365853658537
# combinedweight shape 0: (184, 5)
# right_data0_score_W' 0.8142857142857143
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8
# combinedweight shape1 : (276, 5)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)276
# neuron unit number: 96
# *******************
#
# Error Data percentage 0.3259668508287293
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9322033898305084
# error_data0_score_W0 0.6610169491525424
# combinedweight shape 0: (192, 5)
# right_data0_score_W' 0.8278688524590164
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (288, 5)
# right_data1_score_W' 0.7454545454545455
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6740331491712708
# all_train_score_W': 1.0
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6753246753246753
# class_num*x*(optimize_W.split_num +1)288
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9767441860465116
# error_data0_score_W0 0.813953488372093
# combinedweight shape 0: (200, 5)
# right_data0_score_W' 0.7753623188405797
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (300, 5)
# right_data1_score_W' 0.5476190476190477
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 1.0
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.7142857142857143
# class_num*x*(optimize_W.split_num +1)300
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.6923076923076923
# combinedweight shape 0: (208, 5)
# right_data0_score_W' 0.8450704225352113
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 1.0
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.7272727272727273
# class_num*x*(optimize_W.split_num +1)208
# neuron unit number: 108
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.926829268292683
# error_data0_score_W0 0.7317073170731707
# combinedweight shape 0: (216, 5)
# right_data0_score_W' 0.7714285714285715
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (324, 5)
# right_data1_score_W' 0.7631578947368421
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7012987012987013
# class_num*x*(optimize_W.split_num +1)324
# neuron unit number: 112
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9761904761904762
# error_data0_score_W0 0.7380952380952381
# combinedweight shape 0: (224, 5)
# right_data0_score_W' 0.7913669064748201
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (336, 5)
# right_data1_score_W' 0.8780487804878049
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7402597402597403
# class_num*x*(optimize_W.split_num +1)336
# neuron unit number: 116
# *******************
#
# Error Data percentage 0.30386740331491713
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9090909090909091
# error_data0_score_W0 0.7272727272727273
# combinedweight shape 0: (232, 5)
# right_data0_score_W' 0.8095238095238095
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (348, 5)
# right_data1_score_W' 0.64
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.6961325966850829
# all_train_score_W': 1.0
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.7142857142857143
# class_num*x*(optimize_W.split_num +1)348
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.19889502762430938
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.8055555555555556
# combinedweight shape 0: (240, 5)
# right_data0_score_W' 0.8482758620689655
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8011049723756906
# all_train_score_W': 1.0
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6363636363636364
# class_num*x*(optimize_W.split_num +1)240
# neuron unit number: 124
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.75
# combinedweight shape 0: (248, 5)
# right_data0_score_W' 0.8085106382978723
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (372, 5)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 1.0
# test_score_W0 : 0.7272727272727273
# test_score_W': 0.7142857142857143
# class_num*x*(optimize_W.split_num +1)372
# neuron unit number: 128
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9230769230769231
# error_data0_score_W0 0.717948717948718
# combinedweight shape 0: (256, 5)
# right_data0_score_W' 0.7394366197183099
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (384, 5)
# right_data1_score_W' 0.8055555555555556
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6493506493506493
# class_num*x*(optimize_W.split_num +1)384
# neuron unit number: 132
# *******************
#
# Error Data percentage 0.2596685082872928
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9361702127659575
# error_data0_score_W0 0.723404255319149
# combinedweight shape 0: (264, 5)
# right_data0_score_W' 0.8432835820895522
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (396, 5)
# right_data1_score_W' 0.7954545454545454
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7403314917127072
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)396
# neuron unit number: 136
# *******************
#
# Error Data percentage 0.24861878453038674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9333333333333333
# error_data0_score_W0 0.6444444444444445
# combinedweight shape 0: (272, 5)
# right_data0_score_W' 0.7794117647058824
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (408, 5)
# right_data1_score_W' 0.7142857142857143
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7513812154696132
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6753246753246753
# class_num*x*(optimize_W.split_num +1)408
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9761904761904762
# error_data0_score_W0 0.7380952380952381
# combinedweight shape 0: (280, 5)
# right_data0_score_W' 0.8129496402877698
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (420, 5)
# right_data1_score_W' 0.9024390243902439
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 1.0
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.7662337662337663
# class_num*x*(optimize_W.split_num +1)420
# neuron unit number: 144
# *******************
#
# Error Data percentage 0.2541436464088398
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9347826086956522
# error_data0_score_W0 0.6304347826086957
# combinedweight shape 0: (288, 5)
# right_data0_score_W' 0.7925925925925926
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (432, 5)
# right_data1_score_W' 0.7209302325581395
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7458563535911602
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7532467532467533
# class_num*x*(optimize_W.split_num +1)432
# neuron unit number: 148
# *******************
# Error Data percentage 0.292817679558011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9622641509433962
# error_data0_score_W0 0.7547169811320755
# combinedweight shape 0: (296, 5)
# right_data0_score_W' 0.828125
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (444, 5)
# right_data1_score_W' 0.7254901960784313
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7071823204419889
# all_train_score_W': 1.0
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6363636363636364
# class_num*x*(optimize_W.split_num +1)444
# neuron unit number: 152
# *******************
#
# Error Data percentage 0.2265193370165746
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8780487804878049
# error_data0_score_W0 0.8048780487804879
# combinedweight shape 0: (304, 5)
# right_data0_score_W' 0.8285714285714286
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (456, 5)
# right_data1_score_W' 0.8333333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7734806629834254
# all_train_score_W': 1.0
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6753246753246753
# class_num*x*(optimize_W.split_num +1)456
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.7435897435897436
# combinedweight shape 0: (312, 5)
# right_data0_score_W' 0.8169014084507042
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 1.0
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)312
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.23204419889502761
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9761904761904762
# error_data0_score_W0 0.8571428571428571
# combinedweight shape 0: (320, 5)
# right_data0_score_W' 0.8561151079136691
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (480, 5)
# right_data1_score_W' 0.8780487804878049
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7679558011049724
# all_train_score_W': 1.0
# test_score_W0 : 0.6363636363636364
# test_score_W': 0.6363636363636364
# class_num*x*(optimize_W.split_num +1)480
# neuron unit number: 164
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 0.975
# error_data0_score_W0 0.625
# combinedweight shape 0: (328, 5)
# right_data0_score_W' 0.8226950354609929
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (492, 5)
# right_data1_score_W' 0.8717948717948718
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)492
# neuron unit number: 168
# *******************
#
# Error Data percentage 0.1712707182320442
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.7741935483870968
# combinedweight shape 0: (336, 5)
# right_data0_score_W' 0.8333333333333334
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8287292817679558
# all_train_score_W': 1.0
# test_score_W0 : 0.7272727272727273
# test_score_W': 0.7532467532467533
# class_num*x*(optimize_W.split_num +1)336
# neuron unit number: 172
# *******************
#
# Error Data percentage 0.22099447513812154
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.675
# combinedweight shape 0: (344, 5)
# right_data0_score_W' 0.8368794326241135
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7790055248618785
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)344
# neuron unit number: 176
# *******************
#
# Error Data percentage 0.23756906077348067
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9534883720930233
# error_data0_score_W0 0.7441860465116279
# combinedweight shape 0: (352, 5)
# right_data0_score_W' 0.8260869565217391
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (528, 5)
# right_data1_score_W' 0.7804878048780488
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7624309392265194
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.7272727272727273
# class_num*x*(optimize_W.split_num +1)528
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.16574585635359115
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9666666666666667
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (360, 5)
# right_data0_score_W' 0.7549668874172185
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (540, 5)
# right_data1_score_W' 0.9655172413793104
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.8342541436464088
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)540
# neuron unit number: 184
# *******************
#
# Error Data percentage 0.18232044198895028
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.7878787878787878
# combinedweight shape 0: (368, 5)
# right_data0_score_W' 0.7905405405405406
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8176795580110497
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)368
# neuron unit number: 188
# *******************
#
# Error Data percentage 0.1712707182320442
# right_data0_score_W0 1.0
# error_data0_score_W1 0.967741935483871
# error_data0_score_W0 0.6774193548387096
# combinedweight shape 0: (376, 5)
# right_data0_score_W' 0.8733333333333333
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (564, 5)
# right_data1_score_W' 0.9666666666666667
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.8287292817679558
# all_train_score_W': 1.0
# test_score_W0 : 0.6623376623376623
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)564
# neuron unit number: 192
# *******************
#
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.8108108108108109
# combinedweight shape 0: (384, 5)
# right_data0_score_W' 0.8402777777777778
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 1.0
# test_score_W0 : 0.6883116883116883
# test_score_W': 0.7142857142857143
# class_num*x*(optimize_W.split_num +1)384
# neuron unit number: 196
# *******************
#
# Error Data percentage 0.1878453038674033
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.7647058823529411
# combinedweight shape 0: (392, 5)
# right_data0_score_W' 0.8163265306122449
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8121546961325967
# all_train_score_W': 1.0
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)392
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.18232044198895028
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.8181818181818182
# combinedweight shape 0: (400, 5)
# right_data0_score_W' 0.8581081081081081
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8176795580110497
# all_train_score_W': 1.0
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.6883116883116883
# class_num*x*(optimize_W.split_num +1)400
# neuron unit number: 204
# *******************
# Error Data percentage 0.20441988950276244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.972972972972973
# error_data0_score_W0 0.7027027027027027
# combinedweight shape 0: (408, 5)
# right_data0_score_W' 0.8194444444444444
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (612, 5)
# right_data1_score_W' 0.7777777777777778
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7955801104972375
# all_train_score_W': 1.0
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)612
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.281767955801105
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9215686274509803
# error_data0_score_W0 0.7647058823529411
# combinedweight shape 0: (416, 5)
# right_data0_score_W' 0.8
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (624, 5)
# right_data1_score_W' 0.6808510638297872
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7182320441988951
# all_train_score_W': 1.0
# test_score_W0 : 0.5714285714285714
# test_score_W': 0.6103896103896104
# class_num*x*(optimize_W.split_num +1)624
# neuron unit number: 212
# *******************
#
# Error Data percentage 0.17679558011049723
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.84375
# combinedweight shape 0: (424, 5)
# right_data0_score_W' 0.8590604026845637
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8232044198895028
# all_train_score_W': 1.0
# test_score_W0 : 0.6753246753246753
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)424
# neuron unit number: 216
# *******************
#
# Error Data percentage 0.17679558011049723
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96875
# error_data0_score_W0 0.75
# combinedweight shape 0: (432, 5)
# right_data0_score_W' 0.8523489932885906
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (648, 5)
# right_data1_score_W' 0.9032258064516129
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.8232044198895028
# all_train_score_W': 1.0
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.7012987012987013
# class_num*x*(optimize_W.split_num +1)648
# neuron unit number: 220
# *******************
#
# Error Data percentage 0.24861878453038674
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9555555555555556
# error_data0_score_W0 0.8888888888888888
# combinedweight shape 0: (440, 5)
# right_data0_score_W' 0.8235294117647058
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (660, 5)
# right_data1_score_W' 0.813953488372093
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7513812154696132
# all_train_score_W': 1.0
# test_score_W0 : 0.5844155844155844
# test_score_W': 0.6493506493506493
# class_num*x*(optimize_W.split_num +1)660
# neuron unit number: 224
# *******************
#
# Error Data percentage 0.15469613259668508
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.6785714285714286
# combinedweight shape 0: (448, 5)
# right_data0_score_W' 0.8431372549019608
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.8453038674033149
# all_train_score_W': 1.0
# test_score_W0 : 0.7532467532467533
# test_score_W': 0.7662337662337663
# class_num*x*(optimize_W.split_num +1)448
# neuron unit number: 228
# *******************
#
# Error Data percentage 0.14917127071823205
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.8888888888888888
# combinedweight shape 0: (456, 5)
# right_data0_score_W' 0.7922077922077922
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W0: 0.850828729281768
# all_train_score_W': 1.0
# test_score_W0 : 0.6493506493506493
# test_score_W': 0.6753246753246753
# class_num*x*(optimize_W.split_num +1)456
# neuron unit number: 232
# *******************
#
# Error Data percentage 0.2154696132596685
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9487179487179487
# error_data0_score_W0 0.717948717948718
# combinedweight shape 0: (464, 5)
# right_data0_score_W' 0.8661971830985915
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (696, 5)
# right_data1_score_W' 0.9459459459459459
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.7845303867403315
# all_train_score_W': 1.0
# test_score_W0 : 0.6103896103896104
# test_score_W': 0.6363636363636364
# class_num*x*(optimize_W.split_num +1)696
# neuron unit number: 236
# *******************
#
# Error Data percentage 0.19337016574585636
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9714285714285714
# error_data0_score_W0 0.7714285714285715
# combinedweight shape 0: (472, 5)
# right_data0_score_W' 0.821917808219178
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (708, 5)
# right_data1_score_W' 0.8823529411764706
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.8066298342541437
# all_train_score_W': 1.0
# test_score_W0 : 0.7012987012987013
# test_score_W': 0.7532467532467533
# class_num*x*(optimize_W.split_num +1)708
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.16574585635359115
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9666666666666667
# error_data0_score_W0 0.8
# combinedweight shape 0: (480, 5)
# right_data0_score_W' 0.8145695364238411
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (720, 5)
# right_data1_score_W' 0.7586206896551724
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.8342541436464088
# all_train_score_W': 1.0
# test_score_W0 : 0.7142857142857143
# test_score_W': 0.6623376623376623
# class_num*x*(optimize_W.split_num +1)720
# s 24  value 0.7272727272727273
# s 32  value 0.6753246753246753
# s 36  value 0.6883116883116883
# s 60  value 0.7532467532467533
# s 64  value 0.7532467532467533
# s 72  value 0.7012987012987013
# s 84  value 0.7662337662337663
# s 96  value 0.7272727272727273
# s 108  value 0.6623376623376623
# s 120  value 0.7012987012987013
# s 132  value 0.6363636363636364
# s 144  value 0.6883116883116883
# s 156  value 0.6623376623376623
# s 168  value 0.7142857142857143
# s 180  value 0.7532467532467533
# s 192  value 0.6493506493506493
# s 204  value 0.6883116883116883
# s 208  value 0.7272727272727273
# s 216  value 0.6233766233766234
# s 228  value 0.5974025974025974
# s 240  value 0.6363636363636364
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  21.0  0.667285  0.043361  0.009462   0.647547  0.687023
# 1  test_score_W'  21.0  0.692022  0.047388  0.010341   0.670452  0.713593
# 2       combined  42.0  0.679654  0.046576  0.007187   0.665140  0.694168
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0247
# 1                          Degrees of freedom =   40.0000
# 2                                           t =   -1.7648
# 3                       Two side test p value =    0.0852
# 4                      Difference < 0 p value =    0.0426
# 5                      Difference > 0 p value =    0.9574
# 6                                   Cohen's d =   -0.5446
# 7                                   Hedge's g =   -0.5344
# 8                               Glass's delta =   -0.5705
# 9                                 Pearson's r =    0.2688
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
