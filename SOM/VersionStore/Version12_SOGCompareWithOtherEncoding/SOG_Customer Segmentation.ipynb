# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/Test.csv")
csv = csv.drop(columns=['ID','Segmentation'])
csv2 = csv2.drop(columns=['ID'])   

csv['Family_Size'] = pd.to_numeric(csv['Family_Size'])
csv2['Family_Size'] = pd.to_numeric(csv2['Family_Size'])
csv['Work_Experience'] = pd.to_numeric(csv['Work_Experience'])
csv2['Work_Experience'] = pd.to_numeric(csv2['Work_Experience'])

csv_original_encode1 = csv
csv_original_encode2 = csv2

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode1,"Var_1")
#one hot encoding vs proposed
dataread.binary_encoding(csv_original_encode1,["Gender","Ever_Married","Graduated","Profession","Spending_Score","Family_Size","Work_Experience"])


csv_training_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.5))


dataread.label_encoding(csv_original_encode2,"Var_1")
#one hot encoding vs proposed
dataread.binary_encoding(csv_original_encode2,["Gender","Ever_Married","Graduated","Profession","Spending_Score","Family_Size","Work_Experience"])

#dataread.original_encoding_data is udpated through dataread.label_encoding function
csv_test_original_encoded = dataread.original_encoding_data

dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Ever_Married")
dataread.label_encoding(csv,"Graduated")
dataread.label_encoding(csv,"Profession")
dataread.label_encoding(csv,"Spending_Score")
dataread.label_encoding(csv,"Var_1")
dataread.label_encoding(csv,"Family_Size")
dataread.label_encoding(csv,"Work_Experience")



dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Ever_Married")
dataread.label_encoding(csv2,"Graduated")
dataread.label_encoding(csv2,"Profession")
dataread.label_encoding(csv2,"Spending_Score")
dataread.label_encoding(csv2,"Var_1")
dataread.label_encoding(csv2,"Family_Size")
dataread.label_encoding(csv2,"Work_Experience")



csv_training = csv.sample(int(csv.shape[0]*0.5))
csv_test = csv2




dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Var_1")
# Out:
# self.data_continuous_indexes ['Age']
#  column number self.data_train_discrete 7

# %%
#binary encooding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6551809618244918
# train_discrete_score_W_discrete_n 0.015730433866052853
# train_discrete_score_W_discrete_a 0.03182393604015379
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.016860715008741128
# test_discrete_score_W_discrete_a 0.033922218040379565
# neuron unit number: 16
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6536936043629152
# train_discrete_score_W_discrete_n 0.011261239581443509
# train_discrete_score_W_discrete_a 0.020133038376824206
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.023431025365292953
# test_discrete_score_W_discrete_a 0.04966379201910787
# neuron unit number: 19
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6531978185423897
# train_discrete_score_W_discrete_n 0.012816441004508572
# train_discrete_score_W_discrete_a 0.020227122509811846
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.021735577793131608
# test_discrete_score_W_discrete_a 0.04442981926684746
# neuron unit number: 22
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.01667827315112917
# train_discrete_score_W_discrete_a 0.03196256700920594
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.023695251430093926
# test_discrete_score_W_discrete_a 0.0557053427545283
# neuron unit number: 25
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.0023384504511731203
# test_discrete_score_W0_a 0.0023814886996770743
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.02371900971941581
# train_discrete_score_W_discrete_a 0.053723895789238266
# test_discrete_score_W_discrete_p 0.6429387133612485
# test_discrete_score_W_discrete_n 0.0313634768388382
# test_discrete_score_W_discrete_a 0.07461213065663758
# neuron unit number: 28
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.653941497273178
# train_discrete_score_W_discrete_n 0.01494545984992545
# train_discrete_score_W_discrete_a 0.02693194079919977
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.01782838863270517
# test_discrete_score_W_discrete_a 0.030287012294936577
# neuron unit number: 31
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.014572406522769572
# train_discrete_score_W_discrete_a 0.029041737644306117
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.02463426323545964
# test_discrete_score_W_discrete_a 0.05947579904560697
# neuron unit number: 34
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.002658843820184531
# test_discrete_score_W0_a 0.003154643226583373
# train_discrete_score_W_discrete_p 0.6546851760039663
# train_discrete_score_W_discrete_n 0.013418278671220606
# train_discrete_score_W_discrete_a 0.025606789257871132
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.027543755845609846
# test_discrete_score_W_discrete_a 0.06664104502517842
# neuron unit number: 37
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6574119980168567
# train_discrete_score_W_discrete_n 0.02684475682940826
# train_discrete_score_W_discrete_a 0.05199344093530621
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.02647260948826936
# test_discrete_score_W_discrete_a 0.04593422008365467
# neuron unit number: 40
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6387514274838219
# test_discrete_score_W0_n 0.006739995760610574
# test_discrete_score_W0_a 0.010751165075730052
# train_discrete_score_W_discrete_p 0.6556767476450174
# train_discrete_score_W_discrete_n 0.014974914549731105
# train_discrete_score_W_discrete_a 0.028526437831639304
# test_discrete_score_W_discrete_p 0.6448420251237152
# test_discrete_score_W_discrete_n 0.02990931820918331
# test_discrete_score_W_discrete_a 0.056282072668659165
# neuron unit number: 43
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.015314906032150416
# train_discrete_score_W_discrete_a 0.03263496143270448
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.01981809156045294
# test_discrete_score_W_discrete_a 0.031506760704252706
# neuron unit number: 46
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.018073239936488045
# train_discrete_score_W_discrete_a 0.03748188677957635
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.015342832697338694
# test_discrete_score_W_discrete_a 0.024553902192465088
# neuron unit number: 49
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6379901027788352
# test_discrete_score_W0_n 0.00587262392913716
# test_discrete_score_W0_a 0.009923526753534534
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.022197528152612337
# train_discrete_score_W_discrete_a 0.04715347711178169
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.024895164529493183
# test_discrete_score_W_discrete_a 0.05036868711826782
# neuron unit number: 52
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6544372830937035
# train_discrete_score_W_discrete_n 0.013331648069983737
# train_discrete_score_W_discrete_a 0.018569213951852372
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.02554885375330878
# test_discrete_score_W_discrete_a 0.05439880576553373
# neuron unit number: 55
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6376094404263418
# test_discrete_score_W0_n 0.007701545413806097
# test_discrete_score_W0_a 0.006258807478993094
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.018519120770048622
# train_discrete_score_W_discrete_a 0.03330933804713795
# test_discrete_score_W_discrete_p 0.6433193757137419
# test_discrete_score_W_discrete_n 0.025408441001068618
# test_discrete_score_W_discrete_a 0.04282880988024102
# neuron unit number: 58
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6379901027788352
# test_discrete_score_W0_n 0.009495786218705098
# test_discrete_score_W0_a 0.01771045954159254
# train_discrete_score_W_discrete_p 0.6544372830937035
# train_discrete_score_W_discrete_n 0.013938918624563212
# train_discrete_score_W_discrete_a 0.028305000545499344
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.028277186886272548
# test_discrete_score_W_discrete_a 0.07430603347255896
# neuron unit number: 61
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6564204263758057
# train_discrete_score_W_discrete_n 0.01693487433439447
# train_discrete_score_W_discrete_a 0.03102808234440613
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.014840046685604666
# test_discrete_score_W_discrete_a 0.027968438223027556
# neuron unit number: 64
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6406547392462886
# test_discrete_score_W0_n 0.019397037693187846
# test_discrete_score_W0_a 0.031744326455629635
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.01938815358739348
# train_discrete_score_W_discrete_a 0.034504766732179164
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.019198161438950385
# test_discrete_score_W_discrete_a 0.04527415122308829
# Not good nmi result for discrete features !!!!!
# neuron unit number: 67
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.008687045634739913
# test_discrete_score_W0_a 0.021449777738711234
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.025714483217551466
# train_discrete_score_W_discrete_a 0.052993910827701676
# test_discrete_score_W_discrete_p 0.6448420251237152
# test_discrete_score_W_discrete_n 0.03596180881101442
# test_discrete_score_W_discrete_a 0.07381735513161922
# neuron unit number: 70
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6391320898363152
# test_discrete_score_W0_n 0.00917578806347381
# test_discrete_score_W0_a 0.010340047488086887
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.021740470960038474
# train_discrete_score_W_discrete_a 0.041805073892121666
# test_discrete_score_W_discrete_p 0.6440807004187286
# test_discrete_score_W_discrete_n 0.02551498038594759
# test_discrete_score_W_discrete_a 0.049643114807844974
# neuron unit number: 73
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.01829443777475254
# train_discrete_score_W_discrete_a 0.035140402359804514
# test_discrete_score_W_discrete_p 0.6429387133612485
# test_discrete_score_W_discrete_n 0.02665501571301137
# test_discrete_score_W_discrete_a 0.061002871879562846
# neuron unit number: 76
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.012080171728910754
# test_discrete_score_W0_a 0.023831444103184118
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.02560889989762507
# train_discrete_score_W_discrete_a 0.05329248472164687
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.022684103280084588
# test_discrete_score_W_discrete_a 0.04728424213710912
# neuron unit number: 79
# train_discrete_score_W0_p 0.6514625681705504
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6564204263758057
# train_discrete_score_W_discrete_n 0.025353775076830613
# train_discrete_score_W_discrete_a 0.04693509590586499
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.022713026232027735
# test_discrete_score_W_discrete_a 0.0376202321110765
# test_discrete_score_W0_p mean 0.637129474851459
# test_discrete_score_W_discrete_p mean 0.6419787822114827
# test_discrete_score_W0_n mean 0.0036585777701708217
# test_discrete_score_W_discrete_n mean 0.0239274823835609
# test_discrete_score_W0_a mean 0.005980247241814023
# test_discrete_score_W_discrete_a mean 0.04945768941313846
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.018234  0.004729  0.000986   0.016188  0.020279
# 2         combined  46.0  0.009117  0.009793  0.001444   0.006209  0.012025
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0182
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -18.4893
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -5.4522
# 7                                    Hedge's g =   -5.3587
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9413
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.003659  0.005291  0.001103   0.001371  0.005947
# 1  test_dis_W_dis  23.0  0.023927  0.005141  0.001072   0.021704  0.026150
# 2        combined  46.0  0.013793  0.011472  0.001691   0.010386  0.017200
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0203
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -13.1766
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.8856
# 7                                  Hedge's g =   -3.8190
# 8                             Glass's delta1 =   -3.8307
# 9                           Point-Biserial r =   -0.8932
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.035353  0.011008  0.002295   0.030593  0.040114
# 2         combined  46.0  0.017677  0.019459  0.002869   0.011898  0.023455
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0354
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -15.4016
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.5417
# 7                                    Hedge's g =   -4.4638
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9184
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.005980  0.009300  0.001939   0.001959  0.010002
# 1  test_dis_W_dis  23.0  0.049458  0.014679  0.003061   0.043110  0.055805
# 2        combined  46.0  0.027719  0.025114  0.003703   0.020261  0.035177
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0435
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -11.9992
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.5384
# 7                                  Hedge's g =   -3.4777
# 8                             Glass's delta1 =   -4.6752
# 9                           Point-Biserial r =   -0.8752
# Purity T-Test
#           Variable     N      Mean            SD            SE  95% Conf.  \
# 0     train_dis_W0  23.0  0.651463  2.270350e-16  4.734007e-17   0.651463
# 1  train_dis_W_dis  23.0  0.655386  1.082225e-03  2.256595e-04   0.654918
# 2         combined  46.0  0.653424  2.122716e-03  3.129774e-04   0.652794
#
#    Interval
# 0  0.651463
# 1  0.655854
# 2  0.654055
#                                Independent t-test       results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =  -3.900000e-03
# 1                           Degrees of freedom =   4.400000e+01
# 2                                            t =  -1.738540e+01
# 3                        Two side test p value =   0.000000e+00
# 4                       Difference < 0 p value =   0.000000e+00
# 5                       Difference > 0 p value =   1.000000e+00
# 6                                    Cohen's d =  -5.126700e+00
# 7                                    Hedge's g =  -5.038800e+00
# 8                               Glass's delta1 =  -1.728004e+13
# 9                             Point-Biserial r =  -9.343000e-01
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.637129  0.001102  0.000230   0.636653  0.637606
# 1  test_dis_W_dis  23.0  0.641979  0.001474  0.000307   0.641341  0.642616
# 2        combined  46.0  0.639554  0.002769  0.000408   0.638732  0.640376
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0048
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -12.6375
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.7266
# 7                                  Hedge's g =   -3.6627
# 8                             Glass's delta1 =   -4.3998
# 9                           Point-Biserial r =   -0.8854
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#has encooding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6546851760039663
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.014206618359120536
# train_discrete_score_W_discrete_a 0.02689733321555633
# test_discrete_score_W_discrete_p 0.6414160639512753
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 3 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.02324852674391067
# test_discrete_score_W_discrete_a 0.05712592301804616
# neuron unit number: 16
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6546851760039663
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [3 5]
# train_discrete_score_W_discrete_n 0.014265006911432277
# train_discrete_score_W_discrete_a 0.02819950425339372
# test_discrete_score_W_discrete_p 0.6402740768937952
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# test_discrete_score_W_discrete_n 0.026594616670156362
# test_discrete_score_W_discrete_a 0.07134338772351834
# neuron unit number: 19
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6551809618244918
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.01635642988473586
# train_discrete_score_W_discrete_a 0.030716273610026695
# test_discrete_score_W_discrete_p 0.6440807004187286
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.033170703387764136
# test_discrete_score_W_discrete_a 0.07031801791894694
# neuron unit number: 22
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# train_discrete_score_W_discrete_n 0.02284933113706113
# train_discrete_score_W_discrete_a 0.039790671480128145
# test_discrete_score_W_discrete_p 0.642177388656262
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5 6 7]
# test_discrete_score_W_discrete_n 0.027746870635628248
# test_discrete_score_W_discrete_a 0.057591204864890735
# neuron unit number: 25
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6584035696579078
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# train_discrete_score_W_discrete_n 0.025557920801551372
# train_discrete_score_W_discrete_a 0.04511127974178978
# test_discrete_score_W_discrete_p 0.6425580510087552
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 2 3 5]
# test_discrete_score_W_discrete_n 0.02992982054516722
# test_discrete_score_W_discrete_a 0.06285150152760781
# neuron unit number: 28
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6574119980168567
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 3 4 5]
# train_discrete_score_W_discrete_n 0.02541437365170391
# train_discrete_score_W_discrete_a 0.04145496491089602
# test_discrete_score_W_discrete_p 0.6433193757137419
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.029881662162393297
# test_discrete_score_W_discrete_a 0.06868640704233825
# neuron unit number: 31
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6586514625681705
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.025644114347430455
# train_discrete_score_W_discrete_a 0.04648339853367608
# test_discrete_score_W_discrete_p 0.6433193757137419
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 2 3 5 7]
# test_discrete_score_W_discrete_n 0.02972722418311049
# test_discrete_score_W_discrete_a 0.06254990917939769
# neuron unit number: 34
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6566683192860684
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 3 5]
# train_discrete_score_W_discrete_n 0.026042769478049003
# train_discrete_score_W_discrete_a 0.043754314831169025
# test_discrete_score_W_discrete_p 0.6425580510087552
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.029224989864232102
# test_discrete_score_W_discrete_a 0.06508470476165243
# neuron unit number: 37
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6564204263758057
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 4 5]
# train_discrete_score_W_discrete_n 0.023785761884959823
# train_discrete_score_W_discrete_a 0.0400820413542485
# test_discrete_score_W_discrete_p 0.6406547392462886
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 4 5]
# test_discrete_score_W_discrete_n 0.01879769371916742
# test_discrete_score_W_discrete_a 0.03198070933015072
# neuron unit number: 40
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6566683192860684
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 3 5 6]
# train_discrete_score_W_discrete_n 0.020378281624108024
# train_discrete_score_W_discrete_a 0.03493332646245413
# test_discrete_score_W_discrete_p 0.6410354015987819
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5 6]
# test_discrete_score_W_discrete_n 0.02464366699144771
# test_discrete_score_W_discrete_a 0.056300482175032876
# neuron unit number: 43
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6544372830937035
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [3 5]
# train_discrete_score_W_discrete_n 0.01352908602834967
# train_discrete_score_W_discrete_a 0.02646203534381238
# test_discrete_score_W_discrete_p 0.6406547392462886
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.029471542318010698
# test_discrete_score_W_discrete_a 0.07870824332060551
# neuron unit number: 46
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 2 3 5]
# train_discrete_score_W_discrete_n 0.02548916699356099
# train_discrete_score_W_discrete_a 0.04392738997365898
# test_discrete_score_W_discrete_p 0.6425580510087552
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 2 3 5]
# test_discrete_score_W_discrete_n 0.02784763984877346
# test_discrete_score_W_discrete_a 0.05273909573762446
# neuron unit number: 49
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.658155676747645
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.023376276826103586
# train_discrete_score_W_discrete_a 0.044284858955903776
# test_discrete_score_W_discrete_p 0.6417967263037686
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.0237434464389871
# test_discrete_score_W_discrete_a 0.055524584261368026
# neuron unit number: 52
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# train_discrete_score_W_discrete_n 0.022477432594991194
# train_discrete_score_W_discrete_a 0.04052841065604815
# test_discrete_score_W_discrete_p 0.6417967263037686
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.02536023669746731
# test_discrete_score_W_discrete_a 0.06149305148862397
# neuron unit number: 55
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.017540265797883873
# train_discrete_score_W_discrete_a 0.037869775890295505
# test_discrete_score_W_discrete_p 0.6429387133612485
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5 7]
# test_discrete_score_W_discrete_n 0.026398100264155653
# test_discrete_score_W_discrete_a 0.05583870302599946
# neuron unit number: 58
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6564204263758057
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [3 5]
# train_discrete_score_W_discrete_n 0.018446799016303354
# train_discrete_score_W_discrete_a 0.03374602816057834
# test_discrete_score_W_discrete_p 0.6410354015987819
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 3 5]
# test_discrete_score_W_discrete_n 0.0216667539107936
# test_discrete_score_W_discrete_a 0.053748517300559816
# neuron unit number: 61
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6566683192860684
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.021298730805963183
# train_discrete_score_W_discrete_a 0.04160607794547929
# test_discrete_score_W_discrete_p 0.6440807004187286
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 3 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.02891758417414198
# test_discrete_score_W_discrete_a 0.06299558304768982
# neuron unit number: 64
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [3 5]
# test_discrete_score_W0_n 0.004618067517301835
# test_discrete_score_W0_a 0.010619896235914462
# train_discrete_score_W_discrete_p 0.6566683192860684
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 3 5 6]
# train_discrete_score_W_discrete_n 0.02245557747814372
# train_discrete_score_W_discrete_a 0.037478683399620204
# test_discrete_score_W_discrete_p 0.642177388656262
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# test_discrete_score_W_discrete_n 0.02469883348301789
# test_discrete_score_W_discrete_a 0.05932040426445494
# neuron unit number: 67
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6551809618244918
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.017655353235816473
# train_discrete_score_W_discrete_a 0.037838535278800996
# test_discrete_score_W_discrete_p 0.6410354015987819
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# test_discrete_score_W_discrete_n 0.02406363957089097
# test_discrete_score_W_discrete_a 0.05488854211637034
# neuron unit number: 70
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [3 5]
# test_discrete_score_W0_n 0.004547733458260874
# test_discrete_score_W0_a 0.008962010864556122
# train_discrete_score_W_discrete_p 0.6536936043629152
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 3 5]
# train_discrete_score_W_discrete_n 0.01317129481564079
# train_discrete_score_W_discrete_a 0.0262028962621605
# test_discrete_score_W_discrete_p 0.6402740768937952
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 2 3 5]
# test_discrete_score_W_discrete_n 0.01971918454380703
# test_discrete_score_W_discrete_a 0.03405055183363078
# neuron unit number: 73
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# train_discrete_score_W_discrete_n 0.015415460248625711
# train_discrete_score_W_discrete_a 0.029494897133807225
# test_discrete_score_W_discrete_p 0.6410354015987819
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 3 5]
# test_discrete_score_W_discrete_n 0.02004126141427199
# test_discrete_score_W_discrete_a 0.03897459995296032
# neuron unit number: 76
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6569162121963312
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 2 3 5]
# train_discrete_score_W_discrete_n 0.024895732564883175
# train_discrete_score_W_discrete_a 0.04067064507901363
# test_discrete_score_W_discrete_p 0.6429387133612485
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# test_discrete_score_W_discrete_n 0.023315477921532407
# test_discrete_score_W_discrete_a 0.04706200166756197
# neuron unit number: 79
# train_discrete_score_W0_p 0.650718889439762
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6556767476450174
#  nmi y_true[2 5 3 ... 5 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [1 2 3 5]
# train_discrete_score_W_discrete_n 0.01950654723882091
# train_discrete_score_W_discrete_a 0.034957173047500206
# test_discrete_score_W_discrete_p 0.6410354015987819
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [2 3 5]
# test_discrete_score_W_discrete_n 0.029330437641302824
# test_discrete_score_W_discrete_a 0.07111057674375992
# test_discrete_score_W0_p mean 0.6364840039059267
# test_discrete_score_W_discrete_p mean 0.6419456811373528
# test_discrete_score_W0_n mean 0.0003985130858940308
# test_discrete_score_W_discrete_n mean 0.02597999622304916
# test_discrete_score_W0_a mean 0.0008513872652378515
# test_discrete_score_W_discrete_a mean 0.057838552274034394
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.020424  0.004420  0.000922   0.018513  0.022336
# 2         combined  46.0  0.010212  0.010778  0.001589   0.007012  0.013413
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0204
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -22.1600
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -6.5346
# 7                                    Hedge's g =   -6.4226
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9580
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.000399  0.001320  0.000275  -0.000172  0.000969
# 1  test_dis_W_dis  23.0  0.025980  0.003802  0.000793   0.024336  0.027624
# 2        combined  46.0  0.013189  0.013235  0.001951   0.009259  0.017119
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0256
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -30.4826
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -8.9888
# 7                                  Hedge's g =   -8.8347
# 8                             Glass's delta1 =  -19.3741
# 9                           Point-Biserial r =   -0.9771
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.037065  0.006432  0.001341   0.034283  0.039846
# 2         combined  46.0  0.018532  0.019269  0.002841   0.012810  0.024255
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0371
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -27.6348
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -8.1490
# 7                                    Hedge's g =   -8.0093
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9724
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.000851  0.002832  0.000590  -0.000373  0.002076
# 1  test_dis_W_dis  23.0  0.057839  0.011638  0.002427   0.052806  0.062871
# 2        combined  46.0  0.029345  0.030001  0.004423   0.020436  0.038254
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0570
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -22.8180
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.7287
# 7                                  Hedge's g =   -6.6133
# 8                             Glass's delta1 =  -20.1235
# 9                           Point-Biserial r =   -0.9602
# Purity T-Test
#           Variable     N      Mean            SD            SE  95% Conf.  \
# 0     train_dis_W0  23.0  0.650719  1.135175e-16  2.367003e-17   0.650719
# 1  train_dis_W_dis  23.0  0.656334  1.334125e-03  2.781843e-04   0.655757
# 2         combined  46.0  0.653527  2.988023e-03  4.405599e-04   0.652639
#
#    Interval
# 0  0.650719
# 1  0.656911
# 2  0.654414
#                                Independent t-test       results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =  -5.600000e-03
# 1                           Degrees of freedom =   4.400000e+01
# 2                                            t =  -2.018560e+01
# 3                        Two side test p value =   0.000000e+00
# 4                       Difference < 0 p value =   0.000000e+00
# 5                       Difference > 0 p value =   1.000000e+00
# 6                                    Cohen's d =  -5.952400e+00
# 7                                    Hedge's g =  -5.850400e+00
# 8                               Glass's delta1 =  -4.946650e+13
# 9                             Point-Biserial r =  -9.500000e-01
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636484  0.000079  0.000017   0.636450  0.636518
# 1  test_dis_W_dis  23.0  0.641946  0.001158  0.000241   0.641445  0.642446
# 2        combined  46.0  0.639215  0.002878  0.000424   0.638360  0.640069
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0055
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -22.5727
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.6563
# 7                                  Hedge's g =   -6.5422
# 8                             Glass's delta1 =  -68.8098
# 9                           Point-Biserial r =   -0.9594
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
