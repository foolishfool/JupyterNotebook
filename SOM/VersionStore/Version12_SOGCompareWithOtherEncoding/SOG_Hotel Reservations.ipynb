# %%
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Hotel Reservations.csv")
csv = csv.drop(columns=['Booking_ID'])
csv_original_encode = csv

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode,"booking_status")
#one hot encoding vs proposed
dataread.binary_encoding(csv_original_encode,["type_of_meal_plan","room_type_reserved","arrival_year","market_segment_type"])

dataread.label_encoding(csv,"type_of_meal_plan")
dataread.label_encoding(csv,"room_type_reserved")
dataread.label_encoding(csv,"arrival_year")
dataread.label_encoding(csv,"market_segment_type")
dataread.label_encoding(csv,"booking_status")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)


dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"booking_status")
# Out:
# self.data_continuous_indexes ['lead_time', 'arrival_date', 'no_of_previous_bookings_not_canceled', 'avg_price_per_room']
#  column number self.data_train_discrete 13

# %%
# binary endoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6743590753357225
# train_discrete_score_W_discrete_n 0.01025003969637083
# train_discrete_score_W_discrete_a 0.029464419253251127
# test_discrete_score_W_discrete_p 0.6725785701157876
# test_discrete_score_W_discrete_n 0.009187879091384193
# test_discrete_score_W_discrete_a 0.027489643467871867
# neuron unit number: 7
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6890087819477809
# train_discrete_score_W_discrete_n 0.035911296508350316
# train_discrete_score_W_discrete_a 0.08675799878395453
# test_discrete_score_W_discrete_p 0.6849843778717147
# test_discrete_score_W_discrete_n 0.02892927532242911
# test_discrete_score_W_discrete_a 0.07039503976486938
# neuron unit number: 12
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6919623518292443
# train_discrete_score_W_discrete_n 0.03946958199039649
# train_discrete_score_W_discrete_a 0.09239790835173757
# test_discrete_score_W_discrete_p 0.6959198676713839
# test_discrete_score_W_discrete_n 0.04227307086323063
# test_discrete_score_W_discrete_a 0.08764201570880395
# neuron unit number: 17
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6812507383924704
# train_discrete_score_W_discrete_n 0.02524058410467338
# train_discrete_score_W_discrete_a 0.06679408266274442
# test_discrete_score_W_discrete_p 0.6826870060650616
# test_discrete_score_W_discrete_n 0.023798283507348087
# test_discrete_score_W_discrete_a 0.057028114802419365
# neuron unit number: 22
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6806600244161777
# train_discrete_score_W_discrete_n 0.023285439100458855
# train_discrete_score_W_discrete_a 0.061645259913601695
# test_discrete_score_W_discrete_p 0.6866384855725051
# test_discrete_score_W_discrete_n 0.02853947564748781
# test_discrete_score_W_discrete_a 0.06297734192804104
# neuron unit number: 27
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6788878824872997
# train_discrete_score_W_discrete_n 0.013012004021323359
# train_discrete_score_W_discrete_a 0.025559713374156103
# test_discrete_score_W_discrete_p 0.6816761624701342
# test_discrete_score_W_discrete_n 0.020944231972693524
# test_discrete_score_W_discrete_a 0.04816652911130788
# neuron unit number: 32
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6909384476036703
# train_discrete_score_W_discrete_n 0.03431941830198631
# train_discrete_score_W_discrete_a 0.07541896206012824
# test_discrete_score_W_discrete_p 0.6939900753537953
# test_discrete_score_W_discrete_n 0.039718087895334216
# test_discrete_score_W_discrete_a 0.08456508766511886
# neuron unit number: 37
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6752254558342851
# train_discrete_score_W_discrete_n 0.007662278356022146
# train_discrete_score_W_discrete_a 0.01846346847963823
# test_discrete_score_W_discrete_p 0.6796544752802793
# test_discrete_score_W_discrete_n 0.019269942131575044
# test_discrete_score_W_discrete_a 0.047986354277119
# neuron unit number: 42
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.68719725908715
# train_discrete_score_W_discrete_n 0.03145365908026269
# train_discrete_score_W_discrete_a 0.07593985264188612
# test_discrete_score_W_discrete_p 0.6920602830362066
# test_discrete_score_W_discrete_n 0.038636090754376885
# test_discrete_score_W_discrete_a 0.08757053937908515
# neuron unit number: 47
# train_discrete_score_W0_p 0.6726656952703501
# train_discrete_score_W0_n 0.0001390027408870554
# train_discrete_score_W0_a  8.306153524349827e-05
# test_discrete_score_W0_p 0.6719353060099247
# test_discrete_score_W0_n 0.0004307471695037268
# test_discrete_score_W0_a 0.0004828620303650975
# train_discrete_score_W_discrete_p 0.6775883117394558
# train_discrete_score_W_discrete_n 0.015116340193187004
# train_discrete_score_W_discrete_a 0.03978314377955263
# test_discrete_score_W_discrete_p 0.6826870060650616
# test_discrete_score_W_discrete_n 0.021712251913564583
# test_discrete_score_W_discrete_a 0.046982459882280024
# neuron unit number: 52
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6783365494427598
# train_discrete_score_W_discrete_n 0.011624046297440217
# train_discrete_score_W_discrete_a 0.01956348684413259
# test_discrete_score_W_discrete_p 0.681584267597868
# test_discrete_score_W_discrete_n 0.01886305927140819
# test_discrete_score_W_discrete_a 0.03348325102470573
# neuron unit number: 57
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6803843578939077
# train_discrete_score_W_discrete_n 0.022487267282610423
# train_discrete_score_W_discrete_a 0.0595465785561195
# test_discrete_score_W_discrete_p 0.6826870060650616
# test_discrete_score_W_discrete_n 0.026000723734149567
# test_discrete_score_W_discrete_a 0.06528830817902635
# neuron unit number: 62
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6849919269089907
# train_discrete_score_W_discrete_n 0.02848988797534933
# train_discrete_score_W_discrete_a 0.07059582186870943
# test_discrete_score_W_discrete_p 0.6884763830178277
# test_discrete_score_W_discrete_n 0.03016650783994028
# test_discrete_score_W_discrete_a 0.05741848992165851
# neuron unit number: 67
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6718434111376586
# test_discrete_score_W0_n 0.00032302178679967435
# test_discrete_score_W0_a 0.00019232147529846144
# train_discrete_score_W_discrete_p 0.6780608829204899
# train_discrete_score_W_discrete_n 0.02064609292167267
# train_discrete_score_W_discrete_a 0.05738023027528065
# test_discrete_score_W_discrete_p 0.6768057342400294
# test_discrete_score_W_discrete_n 0.014874553848598248
# test_discrete_score_W_discrete_a 0.03880288364618353
# neuron unit number: 72
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6804631197574135
# train_discrete_score_W_discrete_n 0.021137483719379596
# train_discrete_score_W_discrete_a 0.054846674905027114
# test_discrete_score_W_discrete_p 0.688016908656497
# test_discrete_score_W_discrete_n 0.03074732864984884
# test_discrete_score_W_discrete_a 0.0676574684909378
# neuron unit number: 77
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6827078328673256
# train_discrete_score_W_discrete_n 0.019558566795073003
# train_discrete_score_W_discrete_a 0.03755347836402456
# test_discrete_score_W_discrete_p 0.6850762727439809
# test_discrete_score_W_discrete_n 0.024761588197504913
# test_discrete_score_W_discrete_a 0.047636054944385726
# neuron unit number: 82
# train_discrete_score_W0_p 0.6726656952703501
# train_discrete_score_W0_n 9.664807482955634e-05
# train_discrete_score_W0_a  0.00016827161514597724
# test_discrete_score_W0_p 0.6719353060099247
# test_discrete_score_W0_n 0.00041318158300563936
# test_discrete_score_W0_a 0.0005809770727426449
# train_discrete_score_W_discrete_p 0.6849919269089907
# train_discrete_score_W_discrete_n 0.03303633756641667
# train_discrete_score_W_discrete_a 0.08400743935830243
# test_discrete_score_W_discrete_p 0.6862709060834405
# test_discrete_score_W_discrete_n 0.033264194585817655
# test_discrete_score_W_discrete_a 0.08198087791573459
# neuron unit number: 87
# train_discrete_score_W0_p 0.6726263143385972
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0004628833469761599
# test_discrete_score_W0_a 0.0012729866548469632
# train_discrete_score_W_discrete_p 0.683889260819911
# train_discrete_score_W_discrete_n 0.02399166145011237
# train_discrete_score_W_discrete_a 0.056401454610452775
# test_discrete_score_W_discrete_p 0.6841573240213196
# test_discrete_score_W_discrete_n 0.023920685873620326
# test_discrete_score_W_discrete_a 0.05077868530738323
# neuron unit number: 92
# train_discrete_score_W0_p 0.6726656952703501
# train_discrete_score_W0_n 0.00010870820463686032
# train_discrete_score_W0_a  0.0002108611416882796
# test_discrete_score_W0_p 0.6717515162653924
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6817626905052574
# train_discrete_score_W_discrete_n 0.020670717005942453
# train_discrete_score_W_discrete_a 0.049617320263933215
# test_discrete_score_W_discrete_p 0.6875574342951664
# test_discrete_score_W_discrete_n 0.029442757099848307
# test_discrete_score_W_discrete_a 0.0626270052243875
# neuron unit number: 97
# train_discrete_score_W0_p 0.672705076202103
# train_discrete_score_W0_n 0.0001860739873368512
# train_discrete_score_W0_a  0.0002087343454768895
# test_discrete_score_W0_p 0.6718434111376586
# test_discrete_score_W0_n 0.00032302178679967435
# test_discrete_score_W0_a 0.00019232147529846144
# train_discrete_score_W_discrete_p 0.6821564998227858
# train_discrete_score_W_discrete_n 0.020609483409065987
# train_discrete_score_W_discrete_a 0.047891328607780836
# test_discrete_score_W_discrete_p 0.6836978496599889
# test_discrete_score_W_discrete_n 0.022477865262095286
# test_discrete_score_W_discrete_a 0.03859570599615955
# test_discrete_score_W0_p mean 0.6717790847270722
# test_discrete_score_W_discrete_p mean 0.6848603197941554
# test_discrete_score_W0_n mean 9.764278365424374e-05
# test_discrete_score_W_discrete_n mean 0.026376392673112786
# test_discrete_score_W0_a mean 0.00013607343542758143
# test_discrete_score_W_discrete_a mean 0.05825359283187396
# NMI T-Test
#           Variable     N      Mean        SD        SE     95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000027  0.000057  0.000013 -4.500148e-09  0.000053
# 1  train_dis_W_dis  20.0  0.022899  0.008872  0.001984  1.874619e-02  0.027051
# 2         combined  40.0  0.011463  0.013133  0.002077  7.262269e-03  0.015663
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0229
# 1                           Degrees of freedom =    38.0000
# 2                                            t =   -11.5284
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -3.6456
# 7                                    Hedge's g =    -3.5732
# 8                               Glass's delta1 =  -403.5439
# 9                             Point-Biserial r =    -0.8818
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000098  0.000176  0.000039   0.000015  0.000180
# 1  test_dis_W_dis  20.0  0.026376  0.008269  0.001849   0.022506  0.030246
# 2        combined  40.0  0.013237  0.014505  0.002293   0.008598  0.017876
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0263
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -14.2095
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -4.4934
# 7                                  Hedge's g =    -4.4042
# 8                             Glass's delta1 =  -149.3132
# 9                           Point-Biserial r =    -0.9174
# ARI T-Test
#           Variable     N      Mean        SD        SE     95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000034  0.000073  0.000016 -5.322538e-07  0.000068
# 1  train_dis_W_dis  20.0  0.055481  0.022099  0.004942  4.513870e-02  0.065824
# 2         combined  40.0  0.027757  0.032035  0.005065  1.751214e-02  0.038003
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0554
# 1                           Degrees of freedom =    38.0000
# 2                                            t =   -11.2207
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -3.5483
# 7                                    Hedge's g =    -3.4778
# 8                               Glass's delta1 =  -761.4850
# 9                             Point-Biserial r =    -0.8764
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000136  0.000316  0.000071  -0.000012  0.000284
# 1  test_dis_W_dis  20.0  0.058254  0.017969  0.004018   0.049844  0.066663
# 2        combined  40.0  0.029195  0.031991  0.005058   0.018964  0.039426
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0581
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -14.4619
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -4.5733
# 7                                  Hedge's g =    -4.4824
# 8                             Glass's delta1 =  -184.0338
# 9                           Point-Biserial r =    -0.9199
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.672636  0.000022  0.000005   0.672626  0.672646
# 1  train_dis_W_dis  20.0  0.682241  0.004844  0.001083   0.679974  0.684508
# 2         combined  40.0  0.677439  0.005924  0.000937   0.675544  0.679333
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0096
# 1                           Degrees of freedom =    38.0000
# 2                                            t =    -8.8672
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -2.8040
# 7                                    Hedge's g =    -2.7483
# 8                               Glass's delta1 =  -443.3581
# 9                             Point-Biserial r =    -0.8211
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.671779  0.000060  0.000013   0.671751  0.671807
# 1  test_dis_W_dis  20.0  0.684860  0.005490  0.001228   0.682291  0.687430
# 2        combined  40.0  0.678320  0.007653  0.001210   0.675872  0.680767
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0131
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -10.6546
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -3.3693
# 7                                  Hedge's g =    -3.3023
# 8                             Glass's delta1 =  -216.6843
# 9                           Point-Biserial r =    -0.8656

# %%
# hash endoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6760524554010948
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.0040797915689853945
# train_discrete_score_W_discrete_a 0.004325320421802063
# test_discrete_score_W_discrete_p 0.6688108803528763
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.0029595607995418255
# test_discrete_score_W_discrete_a 0.006347551388957894
# neuron unit number: 7
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6812507383924704
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.016533192705970628
# train_discrete_score_W_discrete_a 0.03940240690125031
# test_discrete_score_W_discrete_p 0.6777246829626907
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 0 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.021198265438495963
# test_discrete_score_W_discrete_a 0.05057163087615567
# neuron unit number: 12
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6832197849801126
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.020293203942852424
# train_discrete_score_W_discrete_a 0.04839285798832734
# test_discrete_score_W_discrete_p 0.681584267597868
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.027827034739351626
# test_discrete_score_W_discrete_a 0.06592314918285426
# neuron unit number: 17
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6837711180246525
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.024997876421563772
# train_discrete_score_W_discrete_a 0.06448168877635706
# test_discrete_score_W_discrete_p 0.68011394964161
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02788342627180815
# test_discrete_score_W_discrete_a 0.06953569968496572
# neuron unit number: 22
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6803843578939077
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.020100017539892864
# train_discrete_score_W_discrete_a 0.054575533253028205
# test_discrete_score_W_discrete_p 0.6824113214482632
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.03378651211244165
# test_discrete_score_W_discrete_a 0.083585164486115
# neuron unit number: 27
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6929862560548182
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 0 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.037883033407060646
# train_discrete_score_W_discrete_a 0.08818970962124686
# test_discrete_score_W_discrete_p 0.6948171292041904
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.044848078577195395
# test_discrete_score_W_discrete_a 0.08901904681192149
# neuron unit number: 32
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6837317370928996
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.018466046439805848
# train_discrete_score_W_discrete_a 0.03129013500887055
# test_discrete_score_W_discrete_p 0.6843411137658518
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02941500275152007
# test_discrete_score_W_discrete_a 0.060629402500115365
# neuron unit number: 37
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6684433008638118
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0018553751854509986
# test_discrete_score_W0_a 0.003698306112070839
# train_discrete_score_W_discrete_p 0.6843224510691923
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.019813927656354306
# train_discrete_score_W_discrete_a 0.039548480224491166
# test_discrete_score_W_discrete_p 0.6791950009189487
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02124683840162535
# test_discrete_score_W_discrete_a 0.042713331377736224
# neuron unit number: 42
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6822746426180444
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.01589491001001881
# train_discrete_score_W_discrete_a 0.02576268371373169
# test_discrete_score_W_discrete_p 0.6780922624517552
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02032109185159874
# test_discrete_score_W_discrete_a 0.04481027194268086
# neuron unit number: 47
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.668627090608344
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0020704348013700965
# test_discrete_score_W0_a 0.0023204054123796484
# train_discrete_score_W_discrete_p 0.6844799747962037
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.022297666334149407
# train_discrete_score_W_discrete_a 0.052480746650483405
# test_discrete_score_W_discrete_p 0.684433008638118
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 0 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.031023563361240417
# test_discrete_score_W_discrete_a 0.06991859934653763
# neuron unit number: 52
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6817626905052574
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 0 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.017897942724339033
# train_discrete_score_W_discrete_a 0.04334663439863916
# test_discrete_score_W_discrete_p 0.6780922624517552
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.01972033865061491
# test_discrete_score_W_discrete_a 0.04105997709518733
# neuron unit number: 57
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6677081418856827
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6847950222502265
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 0 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.026040061039011953
# train_discrete_score_W_discrete_a 0.0659314194384504
# test_discrete_score_W_discrete_p 0.6884763830178277
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.037239915049715806
# test_discrete_score_W_discrete_a 0.08268750823041557
# neuron unit number: 62
# train_discrete_score_W0_p 0.6743984562674753
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0003566992159909013
# train_discrete_score_W0_a  0.000910712745746614
# test_discrete_score_W0_p 0.6682595111192795
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0011916877421040426
# test_discrete_score_W0_a 0.0017628023774040069
# train_discrete_score_W_discrete_p 0.6822352616862914
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.016072427222204925
# train_discrete_score_W_discrete_a 0.03139572075944277
# test_discrete_score_W_discrete_p 0.6766219444954972
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.017765323364921096
# test_discrete_score_W_discrete_a 0.038768787203256036
# neuron unit number: 67
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.667891931630215
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0008133946597750041
# test_discrete_score_W0_a 0.0019454567100114233
# train_discrete_score_W_discrete_p 0.6835742133658882
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 0 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.020594536954961117
# train_discrete_score_W_discrete_a 0.04839414560477083
# test_discrete_score_W_discrete_p 0.6792868957912148
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02270760735742721
# test_discrete_score_W_discrete_a 0.051446264851672294
# neuron unit number: 72
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6682595111192795
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0011956218529408382
# test_discrete_score_W0_a 0.0015776326937548804
# train_discrete_score_W_discrete_p 0.6799117867128737
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.012672713978689635
# train_discrete_score_W_discrete_a 0.02765552685036244
# test_discrete_score_W_discrete_p 0.6759786803896343
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.019609967191789642
# test_discrete_score_W_discrete_a 0.04928337531452285
# neuron unit number: 77
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6679838265024811
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0017390168667315241
# test_discrete_score_W0_a 0.004508762746004017
# train_discrete_score_W_discrete_p 0.6793998346000867
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.011376260404998095
# train_discrete_score_W_discrete_a 0.023968113503522494
# test_discrete_score_W_discrete_p 0.6743245726888439
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.013212733819384427
# test_discrete_score_W_discrete_a 0.026485758611322886
# neuron unit number: 82
# train_discrete_score_W0_p 0.6744378371992281
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0001863468286038597
# train_discrete_score_W0_a  0.0002994031520162619
# test_discrete_score_W0_p 0.6689027752251424
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0025804058706757793
# test_discrete_score_W0_a 0.004257757918309166
# train_discrete_score_W_discrete_p 0.6834166896388768
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.018401645007291904
# train_discrete_score_W_discrete_a 0.03756463053309716
# test_discrete_score_W_discrete_p 0.6805734240029406
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.023837705409359783
# test_discrete_score_W_discrete_a 0.05053264900707114
# neuron unit number: 87
# train_discrete_score_W0_p 0.6745559799944867
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0007724322356329088
# train_discrete_score_W0_a  0.0017671118898908665
# test_discrete_score_W0_p 0.6687189854806102
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0022416853194029535
# test_discrete_score_W0_a 0.0038871216048153136
# train_discrete_score_W_discrete_p 0.6826684519355728
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.02451248032462111
# train_discrete_score_W_discrete_a 0.06485474617747083
# test_discrete_score_W_discrete_p 0.6826870060650616
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.03515488736112618
# test_discrete_score_W_discrete_a 0.0868180881889543
# neuron unit number: 92
# train_discrete_score_W0_p 0.6743590753357225
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 3.229235917035324e-05
# train_discrete_score_W0_a  8.718365118819588e-05
# test_discrete_score_W0_p 0.6690865649696747
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.0037697781743714037
# test_discrete_score_W0_a 0.00833864155192972
# train_discrete_score_W_discrete_p 0.6803843578939077
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.013465675796655686
# train_discrete_score_W_discrete_a 0.015863375967318922
# test_discrete_score_W_discrete_p 0.6757029957728359
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.015307423048118255
# test_discrete_score_W_discrete_a 0.023865982674508863
# neuron unit number: 97
# train_discrete_score_W0_p 0.6744378371992281
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.00020761542362340203
# train_discrete_score_W0_a  0.00038649059593958985
# test_discrete_score_W0_p 0.668627090608344
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.002040903136000063
# test_discrete_score_W0_a 0.0035183461261757516
# train_discrete_score_W_discrete_p 0.6826684519355728
#  nmi y_true[1 0 1 ... 1 0 1] unique[0 1] y_pred [0 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.017407055611545603
# train_discrete_score_W_discrete_a 0.036886972367044225
# test_discrete_score_W_discrete_p 0.6834221650431906
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 0 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.028354015100361535
# test_discrete_score_W_discrete_a 0.06043720809946992
# test_discrete_score_W0_p mean 0.6680941003492005
# test_discrete_score_W_discrete_p mean 0.6803344973350487
# test_discrete_score_W0_n mean 0.0009749151804411352
# test_discrete_score_W_discrete_n mean 0.024670964532881902
# test_discrete_score_W0_a mean 0.001790761662642738
# test_discrete_score_W_discrete_a mean 0.05472197234372106
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000078  0.000189  0.000042  -0.000011  0.000166
# 1  train_dis_W_dis  20.0  0.018940  0.006765  0.001513   0.015774  0.022106
# 2         combined  40.0  0.009509  0.010655  0.001685   0.006101  0.012917
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0189
# 1                           Degrees of freedom =   38.0000
# 2                                            t =  -12.4648
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.9417
# 7                                    Hedge's g =   -3.8634
# 8                               Glass's delta1 =  -99.5733
# 9                             Point-Biserial r =   -0.8964
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000975  0.001154  0.000258   0.000435  0.001515
# 1  test_dis_W_dis  20.0  0.024671  0.009432  0.002109   0.020257  0.029085
# 2        combined  40.0  0.012823  0.013710  0.002168   0.008438  0.017208
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0237
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -11.1524
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.5267
# 7                                  Hedge's g =   -3.4566
# 8                             Glass's delta1 =  -20.5286
# 9                           Point-Biserial r =   -0.8752
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000173  0.000435  0.000097  -0.000031  0.000376
# 1  train_dis_W_dis  20.0  0.042216  0.019557  0.004373   0.033062  0.051369
# 2         combined  40.0  0.021194  0.025292  0.003999   0.013105  0.029283
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0420
# 1                           Degrees of freedom =   38.0000
# 2                                            t =   -9.6114
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.0394
# 7                                    Hedge's g =   -2.9790
# 8                               Glass's delta1 =  -96.5434
# 9                             Point-Biserial r =   -0.8418
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.001791  0.002292  0.000512   0.000718  0.002863
# 1  test_dis_W_dis  20.0  0.054722  0.022140  0.004951   0.044360  0.065084
# 2        combined  40.0  0.028256  0.030980  0.004898   0.018349  0.038164
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0529
# 1                         Degrees of freedom =   38.0000
# 2                                          t =  -10.6351
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.3631
# 7                                  Hedge's g =   -3.2963
# 8                             Glass's delta1 =  -23.0970
# 9                           Point-Biserial r =   -0.8652
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.674379  0.000049  0.000011   0.674356  0.674402
# 1  train_dis_W_dis  20.0  0.682665  0.003217  0.000719   0.681159  0.684170
# 2         combined  40.0  0.678522  0.004759  0.000752   0.677000  0.680044
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0083
# 1                           Degrees of freedom =    38.0000
# 2                                            t =   -11.5155
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -3.6415
# 7                                    Hedge's g =    -3.5692
# 8                               Glass's delta1 =  -170.3035
# 9                             Point-Biserial r =    -0.8816
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.668094  0.000477  0.000107   0.667871  0.668317
# 1  test_dis_W_dis  20.0  0.680334  0.005488  0.001227   0.677766  0.682903
# 2        combined  40.0  0.674214  0.007294  0.001153   0.671882  0.676547
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0122
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -9.9366
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.1422
# 7                                  Hedge's g =   -3.0798
# 8                             Glass's delta1 =  -25.6794
# 9                           Point-Biserial r =   -0.8498

# %%
# baseN endoding
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 2
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6708541724097192
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.0009940393665484662
# train_discrete_score_W_discrete_a 0.002513248565030027
# test_discrete_score_W_discrete_p 0.6780003675794891
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.005822598464197384
# test_discrete_score_W_discrete_a 0.01405060988897559
# neuron unit number: 7
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6753042176977907
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.010966812693096765
# train_discrete_score_W_discrete_a 0.024972045851684208
# test_discrete_score_W_discrete_p 0.6840654291490534
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.01871772095692755
# test_discrete_score_W_discrete_a 0.04481326025046068
# neuron unit number: 12
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6749891702437679
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.009891229642415114
# train_discrete_score_W_discrete_a 0.0215331621122589
# test_discrete_score_W_discrete_p 0.6799301598970777
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.008038733011016963
# test_discrete_score_W_discrete_a 0.01118801663623543
# neuron unit number: 17
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6768400740361517
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.01565712368703395
# train_discrete_score_W_discrete_a 0.039105609920289254
# test_discrete_score_W_discrete_p 0.6803896342584084
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 0 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.01443329376271048
# test_discrete_score_W_discrete_a 0.03872275737022855
# neuron unit number: 22
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.676485645650376
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.016734254154656687
# train_discrete_score_W_discrete_a 0.0440282203008342
# test_discrete_score_W_discrete_p 0.6831464804263923
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.01639537628497021
# test_discrete_score_W_discrete_a 0.038256572514769334
# neuron unit number: 27
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6762099791281062
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.01439366651141767
# train_discrete_score_W_discrete_a 0.035970853671900976
# test_discrete_score_W_discrete_p 0.6862709060834405
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.020995506680078505
# test_discrete_score_W_discrete_a 0.045626916445670795
# neuron unit number: 32
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6802662150986493
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.019456004966736325
# train_discrete_score_W_discrete_a 0.042867763653978784
# test_discrete_score_W_discrete_p 0.6883844881455615
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.023803200040861065
# test_discrete_score_W_discrete_a 0.04729230996994954
# neuron unit number: 37
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6787303587602883
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.018743605498391446
# train_discrete_score_W_discrete_a 0.04579540608815013
# test_discrete_score_W_discrete_p 0.6861790112111744
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.020786389137796277
# test_discrete_score_W_discrete_a 0.04500373057245995
# neuron unit number: 42
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6884180679714882
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.03301477466792677
# train_discrete_score_W_discrete_a 0.07316859459112611
# test_discrete_score_W_discrete_p 0.6882925932732954
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.025470214672257335
# test_discrete_score_W_discrete_a 0.05830083169482262
# neuron unit number: 47
# train_discrete_score_W0_p 0.6707360296144607
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0001379699892016921
# train_discrete_score_W0_a  8.165180705515138e-05
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6749891702437679
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.01542940495756925
# train_discrete_score_W_discrete_a 0.042512208340693344
# test_discrete_score_W_discrete_p 0.6809410034920051
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.017834154746037372
# test_discrete_score_W_discrete_a 0.0492599411027487
# neuron unit number: 52
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6795573583270981
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.019939327485724943
# train_discrete_score_W_discrete_a 0.048090210380426886
# test_discrete_score_W_discrete_p 0.6846167983826502
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.018532615556096182
# test_discrete_score_W_discrete_a 0.041701130932220325
# neuron unit number: 57
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6742409325404639
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.010710477019673087
# train_discrete_score_W_discrete_a 0.02735303149741461
# test_discrete_score_W_discrete_p 0.6784598419408197
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.005051126122735282
# test_discrete_score_W_discrete_a 0.006253893736377275
# neuron unit number: 62
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6763281219233647
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.01335863189997237
# train_discrete_score_W_discrete_a 0.03136285767516635
# test_discrete_score_W_discrete_p 0.6823194265759971
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.015623969011837775
# test_discrete_score_W_discrete_a 0.038003135186504416
# neuron unit number: 67
# train_discrete_score_W0_p 0.6707360296144607
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0001066283628862941
# train_discrete_score_W0_a  0.0002062351049045151
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.00022951609166278598
# test_discrete_score_W0_a 0.0006244051254165993
# train_discrete_score_W_discrete_p 0.6725475524750916
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.0061779426696194385
# train_discrete_score_W_discrete_a 0.015347011077849065
# test_discrete_score_W_discrete_p 0.6788274214298842
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.008030163013333548
# test_discrete_score_W_discrete_a 0.01956408173267084
# neuron unit number: 72
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6791241680778167
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.019548245204278447
# train_discrete_score_W_discrete_a 0.04785067753523822
# test_discrete_score_W_discrete_p 0.6840654291490534
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.018130184060662972
# test_discrete_score_W_discrete_a 0.042263882274453095
# neuron unit number: 77
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6857007836805419
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.027260440088807777
# train_discrete_score_W_discrete_a 0.053100797598068676
# test_discrete_score_W_discrete_p 0.6921521779084727
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02992630346744766
# test_discrete_score_W_discrete_a 0.05742683298522654
# neuron unit number: 82
# train_discrete_score_W0_p 0.6707360296144607
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0001379699892016921
# train_discrete_score_W0_a  8.165180705515138e-05
# test_discrete_score_W0_p 0.6763462598786988
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.00032872343067127013
# test_discrete_score_W0_a 0.00020010806618337587
# train_discrete_score_W_discrete_p 0.681093214665459
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.020131343172362266
# train_discrete_score_W_discrete_a 0.03023569132245617
# test_discrete_score_W_discrete_p 0.6888439625068921
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.025456657900738255
# test_discrete_score_W_discrete_a 0.03645174472240437
# neuron unit number: 87
# train_discrete_score_W0_p 0.6707360296144607
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 0.0001379699892016921
# train_discrete_score_W0_a  8.165180705515138e-05
# test_discrete_score_W0_p 0.6762543650064327
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 7.708981242330718e-05
# test_discrete_score_W0_a 0.0002083749314000325
# train_discrete_score_W_discrete_p 0.681605166778246
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 0 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.023183657553511625
# train_discrete_score_W_discrete_a 0.054942567241708214
# test_discrete_score_W_discrete_p 0.6881088035287631
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.02680915337689977
# test_discrete_score_W_discrete_a 0.0646764693398595
# neuron unit number: 92
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W0_n 6.135322709728471e-05
# train_discrete_score_W0_a  0.00016612117952408053
# test_discrete_score_W0_p 0.6763462598786988
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.00023235969660811824
# test_discrete_score_W0_a 0.0004083921511791801
# train_discrete_score_W_discrete_p 0.6756980270153192
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.01064213008309045
# train_discrete_score_W_discrete_a 0.0213568949004345
# test_discrete_score_W_discrete_p 0.6823194265759971
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.012694117119584424
# test_discrete_score_W_discrete_a 0.019474539842287007
# neuron unit number: 97
# train_discrete_score_W0_p 0.6706966486827078
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [1]
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6763462598786988
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W0_n 0.00032872343067127013
# test_discrete_score_W0_a 0.00020010806618337587
# train_discrete_score_W_discrete_p 0.6756586460835663
#  nmi y_true[1 0 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# train_discrete_score_W_discrete_n 0.015081884319347006
# train_discrete_score_W_discrete_a 0.03993618488334786
# test_discrete_score_W_discrete_p 0.6832383752986584
#  nmi y_true[1 1 1 ... 1 1 1] unique[0 1] y_pred [1 1 1 ... 1 1 1] unique [0 1]
# test_discrete_score_W_discrete_n 0.017896838328038366
# test_discrete_score_W_discrete_a 0.0441857168949615
# test_discrete_score_W0_p mean 0.6762681492372725
# test_discrete_score_W_discrete_p mean 0.6839275868406544
# test_discrete_score_W0_n mean 5.9820623101837576e-05
# test_discrete_score_W_discrete_n mean 0.017522415785711364
# test_discrete_score_W0_a mean 8.206941701812819e-05
# test_discrete_score_W_discrete_a mean 0.038125818704664305
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000029  0.000054  0.000012   0.000004  0.000054
# 1  train_dis_W_dis  20.0  0.016066  0.007200  0.001610   0.012696  0.019435
# 2         combined  40.0  0.008047  0.009550  0.001510   0.004993  0.011102
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0160
# 1                           Degrees of freedom =    38.0000
# 2                                            t =    -9.9612
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -3.1500
# 7                                    Hedge's g =    -3.0874
# 8                               Glass's delta1 =  -297.2244
# 9                             Point-Biserial r =    -0.8503
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000060  0.000116  0.000026   0.000005  0.000114
# 1  test_dis_W_dis  20.0  0.017522  0.007040  0.001574   0.014228  0.020817
# 2        combined  40.0  0.008791  0.010116  0.001600   0.005556  0.012026
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0175
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -11.0918
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -3.5075
# 7                                  Hedge's g =    -3.4378
# 8                             Glass's delta1 =  -150.1012
# 9                           Point-Biserial r =    -0.8741
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.000031  0.000061  0.000014   0.000002  0.000059
# 1  train_dis_W_dis  20.0  0.037102  0.015883  0.003551   0.029669  0.044535
# 2         combined  40.0  0.018567  0.021801  0.003447   0.011594  0.025539
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0371
# 1                           Degrees of freedom =    38.0000
# 2                                            t =   -10.4382
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -3.3008
# 7                                    Hedge's g =    -3.2353
# 8                               Glass's delta1 =  -606.1099
# 9                             Point-Biserial r =    -0.8611
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.000082  0.000169  0.000038   0.000003  0.000161
# 1  test_dis_W_dis  20.0  0.038126  0.016099  0.003600   0.030591  0.045660
# 2        combined  40.0  0.019104  0.022302  0.003526   0.011971  0.026236
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0380
# 1                         Degrees of freedom =    38.0000
# 2                                          t =   -10.5679
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -3.3419
# 7                                  Hedge's g =    -3.2755
# 8                             Glass's delta1 =  -224.5312
# 9                           Point-Biserial r =    -0.8638
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.670705  0.000016  0.000004   0.670697  0.670712
# 1  train_dis_W_dis  20.0  0.677732  0.004224  0.000945   0.675755  0.679709
# 2         combined  40.0  0.674218  0.004621  0.000731   0.672740  0.675696
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0070
# 1                           Degrees of freedom =    38.0000
# 2                                            t =    -7.4396
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -2.3526
# 7                                    Hedge's g =    -2.3059
# 8                               Glass's delta1 =  -434.8289
# 9                             Point-Biserial r =    -0.7700
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.676268  0.000034  0.000008   0.676252  0.676284
# 1  test_dis_W_dis  20.0  0.683928  0.003934  0.000880   0.682087  0.685769
# 2        combined  40.0  0.680098  0.004752  0.000751   0.678578  0.681618
#                              Independent t-test   results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    -0.0077
# 1                         Degrees of freedom =    38.0000
# 2                                          t =    -8.7076
# 3                      Two side test p value =     0.0000
# 4                     Difference < 0 p value =     0.0000
# 5                     Difference > 0 p value =     1.0000
# 6                                  Cohen's d =    -2.7536
# 7                                  Hedge's g =    -2.6989
# 8                             Glass's delta1 =  -227.5162
# 9                           Point-Biserial r =    -0.8162
