# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"price_range")
# Out:
# self.data_continuous_indexes ['battery_power', 'clock_speed', 'int_memory', 'mobile_wt', 'pc', 'px_height', 'px_width', 'ram']
# self.continuous_feature_num 8
#  column number self.data_train_discrete 12

# %%
#base N hybrid
import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.3707142857142857
# all_train_score_W0_n 0.026223571012410334
# all_train_score_W0_a 0.024257359488135042
# test_score_W0_p0.43
# test_score_W0_n 0.06002275677216115
# test_score_W0_a  0.05412462465175578
# all_train_score_W_combine_p 0.88
# all_train_score_W_combine_n 0.7051055469769569
# all_train_score_W_combine_a 0.7160086828846893
# test_score_W_combine_p 0.8983333333333333
# test_score_W_combine_n 0.7387368182948499
# test_score_W_combine_a 0.7532095300667258
# neuron unit number: 10
# all_train_score_W0_p 0.4
# all_train_score_W0_n 0.039865375964724364
# all_train_score_W0_a 0.03849605710303799
# test_score_W0_p0.47833333333333333
# test_score_W0_n 0.09922709299891368
# test_score_W0_a  0.0884146148590461
# all_train_score_W_combine_p 0.8871428571428571
# all_train_score_W_combine_n 0.7175357973318064
# all_train_score_W_combine_a 0.7316955591361606
# test_score_W_combine_p 0.905
# test_score_W_combine_n 0.7479102934573814
# test_score_W_combine_a 0.7666214451331506
# neuron unit number: 15
# all_train_score_W0_p 0.42714285714285716
# all_train_score_W0_n 0.05963972153319948
# all_train_score_W0_a 0.05592235153537138
# test_score_W0_p0.5133333333333333
# test_score_W0_n 0.12414764280043979
# test_score_W0_a  0.11857523970300039
# all_train_score_W_combine_p 0.8657142857142858
# all_train_score_W_combine_n 0.6867061991392172
# all_train_score_W_combine_a 0.6929978321664817
# test_score_W_combine_p 0.885
# test_score_W_combine_n 0.713545354837872
# test_score_W_combine_a 0.7247601212427308
# neuron unit number: 20
# all_train_score_W0_p 0.4085714285714286
# all_train_score_W0_n 0.04656435920759941
# all_train_score_W0_a 0.04606571630097125
# test_score_W0_p0.4683333333333333
# test_score_W0_n 0.08699810253628396
# test_score_W0_a  0.08175658316342192
# all_train_score_W_combine_p 0.8892857142857142
# all_train_score_W_combine_n 0.7218581651870918
# all_train_score_W_combine_a 0.7363645567438621
# test_score_W_combine_p 0.8916666666666667
# test_score_W_combine_n 0.7297837368948568
# test_score_W_combine_a 0.7388402817924218
# neuron unit number: 25
# all_train_score_W0_p 0.4085714285714286
# all_train_score_W0_n 0.04688940499647919
# all_train_score_W0_a 0.045178664724543835
# test_score_W0_p0.4766666666666667
# test_score_W0_n 0.09462091174033728
# test_score_W0_a  0.0897008321075345
# all_train_score_W_combine_p 0.8928571428571429
# all_train_score_W_combine_n 0.7257230206414196
# all_train_score_W_combine_a 0.7428956590258223
# test_score_W_combine_p 0.91
# test_score_W_combine_n 0.7597801178745021
# test_score_W_combine_a 0.7752511688077687
# neuron unit number: 30
# all_train_score_W0_p 0.4342857142857143
# all_train_score_W0_n 0.05911840125774217
# all_train_score_W0_a 0.05879034050587672
# test_score_W0_p0.5266666666666666
# test_score_W0_n 0.13425034361552945
# test_score_W0_a  0.13311499743731056
# all_train_score_W_combine_p 0.88
# all_train_score_W_combine_n 0.707440062485578
# all_train_score_W_combine_a 0.7188389704279703
# test_score_W_combine_p 0.87
# test_score_W_combine_n 0.6980256105782272
# test_score_W_combine_a 0.6962263060856038
# neuron unit number: 35
# all_train_score_W0_p 0.405
# all_train_score_W0_n 0.04253748094381902
# all_train_score_W0_a 0.041385156494793046
# test_score_W0_p0.48833333333333334
# test_score_W0_n 0.1002612087997354
# test_score_W0_a  0.09812945346979149
# all_train_score_W_combine_p 0.8821428571428571
# all_train_score_W_combine_n 0.7062079730844287
# all_train_score_W_combine_a 0.7200663353025022
# test_score_W_combine_p 0.91
# test_score_W_combine_n 0.7594981499617136
# test_score_W_combine_a 0.7783173840186053
# neuron unit number: 40
# all_train_score_W0_p 0.4114285714285714
# all_train_score_W0_n 0.046600562919863656
# all_train_score_W0_a 0.045403335789781826
# test_score_W0_p0.5033333333333333
# test_score_W0_n 0.11230697853387472
# test_score_W0_a  0.109793029078905
# all_train_score_W_combine_p 0.885
# all_train_score_W_combine_n 0.7133709636148466
# all_train_score_W_combine_a 0.7263792699664694
# test_score_W_combine_p 0.9066666666666666
# test_score_W_combine_n 0.7544815022766345
# test_score_W_combine_a 0.7713143655982521
# neuron unit number: 45
# all_train_score_W0_p 0.4307142857142857
# all_train_score_W0_n 0.0571761964967009
# all_train_score_W0_a 0.05625246416573784
# test_score_W0_p0.5033333333333333
# test_score_W0_n 0.11389723281729931
# test_score_W0_a  0.1103851340241949
# all_train_score_W_combine_p 0.8907142857142857
# all_train_score_W_combine_n 0.7271664617865453
# all_train_score_W_combine_a 0.7407913996991117
# test_score_W_combine_p 0.9083333333333333
# test_score_W_combine_n 0.7554599248748407
# test_score_W_combine_a 0.7734419735709855
# neuron unit number: 50
# all_train_score_W0_p 0.39
# all_train_score_W0_n 0.03471252134980548
# all_train_score_W0_a 0.03366668595539855
# test_score_W0_p0.45166666666666666
# test_score_W0_n 0.07416580714568881
# test_score_W0_a  0.06942550769078809
# all_train_score_W_combine_p 0.8842857142857142
# all_train_score_W_combine_n 0.7117027354080232
# all_train_score_W_combine_a 0.724775092735558
# test_score_W_combine_p 0.9083333333333333
# test_score_W_combine_n 0.7598748501206033
# test_score_W_combine_a 0.775186914244128
# test_score_W0_p mean 0.484
# test_score_W_combine_p mean 0.8993333333333334
# test_score_W0_n mean 0.09998980777602635
# test_score_W_combine_n mean 0.7417096359171482
# test_score_W0_a mean 0.09534200161857487
# test_score_W_combine_a mean 0.7553169490560372
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.045933  0.010815  0.003420   0.038196  0.053669
# 1  train_W_combine  10.0  0.712282  0.011968  0.003784   0.703721  0.720843
# 2         combined  20.0  0.379107  0.342010  0.076476   0.219042  0.539173
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.6663
# 1                       Degrees of freedom =    18.0000
# 2                                        t =  -130.6371
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -58.4227
# 7                                Hedge's g =   -55.9541
# 8                           Glass's delta1 =   -61.6156
# 9                         Point-Biserial r =    -0.9995
#          Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.09999  0.022522  0.007122   0.083879  0.116101
# 1  test_W_combine  10.0  0.74171  0.021644  0.006844   0.726226  0.757193
# 2        combined  20.0  0.42085  0.329897  0.073767   0.266453  0.575246
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6417
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -64.9666
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -29.0539
# 7                              Hedge's g =  -27.8263
# 8                         Glass's delta1 =  -28.4935
# 9                       Point-Biserial r =   -0.9979
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.044542  0.010798  0.003415   0.036817  0.052266
# 1  train_W_combine  10.0  0.725081  0.014578  0.004610   0.714653  0.735510
# 2         combined  20.0  0.384812  0.349333  0.078113   0.221319  0.548304
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.6805
# 1                       Degrees of freedom =    18.0000
# 2                                        t =  -118.6233
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -53.0500
# 7                                Hedge's g =   -50.8084
# 8                           Glass's delta1 =   -63.0240
# 9                         Point-Biserial r =    -0.9994
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.095342  0.023675  0.007487   0.078406  0.112278
# 1  test_W_combine  10.0  0.755317  0.027355  0.008650   0.735748  0.774886
# 2        combined  20.0  0.425329  0.339474  0.075909   0.266451  0.584208
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6600
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -57.6888
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -25.7992
# 7                              Hedge's g =  -24.7091
# 8                         Glass's delta1 =  -27.8769
# 9                       Point-Biserial r =   -0.9973
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.408643  0.019347  0.006118   0.394803  0.422483
# 1  train_W_combine  10.0  0.883714  0.007684  0.002430   0.878217  0.889211
# 2         combined  20.0  0.646179  0.244127  0.054589   0.531923  0.760434
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.4751
# 1                       Degrees of freedom =   18.0000
# 2                                        t =  -72.1662
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -32.2737
# 7                                Hedge's g =  -30.9100
# 8                           Glass's delta1 =  -24.5551
# 9                         Point-Biserial r =   -0.9983
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.484000  0.029326  0.009274   0.463022  0.504978
# 1  test_W_combine  10.0  0.899333  0.013338  0.004218   0.889792  0.908875
# 2        combined  20.0  0.691667  0.214212  0.047899   0.591412  0.791921
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.4153
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -40.7679
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -18.2320
# 7                              Hedge's g =  -17.4616
# 8                         Glass's delta1 =  -14.1627
# 9                       Point-Biserial r =   -0.9946

# %%
#effect hybrid
import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.37714285714285717
# all_train_score_W0_n 0.029602485756895502
# all_train_score_W0_a 0.02751242557318772
# test_score_W0_p0.44
# test_score_W0_n 0.06635635075364335
# test_score_W0_a  0.0632210138169136
# all_train_score_W_combine_p 0.8871428571428571
# all_train_score_W_combine_n 0.7227061161904708
# all_train_score_W_combine_a 0.7347970997736895
# test_score_W_combine_p 0.8866666666666667
# test_score_W_combine_n 0.7198292123466415
# test_score_W_combine_a 0.7307278705585912
# neuron unit number: 10
# all_train_score_W0_p 0.4042857142857143
# all_train_score_W0_n 0.04365634175162392
# all_train_score_W0_a 0.043081914902023406
# test_score_W0_p0.46
# test_score_W0_n 0.07731187831600424
# test_score_W0_a  0.07587250169985348
# all_train_score_W_combine_p 0.8828571428571429
# all_train_score_W_combine_n 0.71360930522636
# all_train_score_W_combine_a 0.722455152754055
# test_score_W_combine_p 0.8916666666666667
# test_score_W_combine_n 0.7325471705050323
# test_score_W_combine_a 0.7420191254286252
# neuron unit number: 15
# all_train_score_W0_p 0.4185714285714286
# all_train_score_W0_n 0.0500099579075142
# all_train_score_W0_a 0.049931784263589386
# test_score_W0_p0.505
# test_score_W0_n 0.11982871400237173
# test_score_W0_a  0.1133325243005186
# all_train_score_W_combine_p 0.8914285714285715
# all_train_score_W_combine_n 0.7237686187933052
# all_train_score_W_combine_a 0.7390380193883783
# test_score_W_combine_p 0.885
# test_score_W_combine_n 0.715455438064388
# test_score_W_combine_a 0.7260620470412518
# neuron unit number: 20
# all_train_score_W0_p 0.39285714285714285
# all_train_score_W0_n 0.03651088659859871
# all_train_score_W0_a 0.0351852382893198
# test_score_W0_p0.46166666666666667
# test_score_W0_n 0.0823424027545788
# test_score_W0_a  0.07547265550925782
# all_train_score_W_combine_p 0.89
# all_train_score_W_combine_n 0.7208433157272623
# all_train_score_W_combine_a 0.7344680021702782
# test_score_W_combine_p 0.915
# test_score_W_combine_n 0.78061368020725
# test_score_W_combine_a 0.791132689856058
# neuron unit number: 25
# all_train_score_W0_p 0.4164285714285714
# all_train_score_W0_n 0.052330504110898235
# all_train_score_W0_a 0.05162031950988474
# test_score_W0_p0.48333333333333334
# test_score_W0_n 0.09870692766188797
# test_score_W0_a  0.09242305785869913
# all_train_score_W_combine_p 0.9092857142857143
# all_train_score_W_combine_n 0.7555776653145756
# all_train_score_W_combine_a 0.7768494632597522
# test_score_W_combine_p 0.9083333333333333
# test_score_W_combine_n 0.7650261538451584
# test_score_W_combine_a 0.7779098598823572
# neuron unit number: 30
# all_train_score_W0_p 0.3992857142857143
# all_train_score_W0_n 0.04422137843601356
# all_train_score_W0_a 0.04089904198386195
# test_score_W0_p0.5
# test_score_W0_n 0.11014859366573525
# test_score_W0_a  0.107008223602956
# all_train_score_W_combine_p 0.8842857142857142
# all_train_score_W_combine_n 0.7181623255677406
# all_train_score_W_combine_a 0.7265324147440131
# test_score_W_combine_p 0.9
# test_score_W_combine_n 0.748542351456886
# test_score_W_combine_a 0.7599556960216295
# neuron unit number: 35
# all_train_score_W0_p 0.41785714285714287
# all_train_score_W0_n 0.04983504160843726
# all_train_score_W0_a 0.049386746691474206
# test_score_W0_p0.495
# test_score_W0_n 0.11272119993305497
# test_score_W0_a  0.10087235923599548
# all_train_score_W_combine_p 0.8928571428571429
# all_train_score_W_combine_n 0.7280271785596298
# all_train_score_W_combine_a 0.7443775794251325
# test_score_W_combine_p 0.895
# test_score_W_combine_n 0.7353298857828272
# test_score_W_combine_a 0.744302654375613
# neuron unit number: 40
# all_train_score_W0_p 0.4142857142857143
# all_train_score_W0_n 0.05128254485793861
# all_train_score_W0_a 0.04889448266627408
# test_score_W0_p0.5066666666666667
# test_score_W0_n 0.11798355401401976
# test_score_W0_a  0.11393001984816425
# all_train_score_W_combine_p 0.89
# all_train_score_W_combine_n 0.7212249923651306
# all_train_score_W_combine_a 0.7358591648979406
# test_score_W_combine_p 0.8933333333333333
# test_score_W_combine_n 0.7316571919894793
# test_score_W_combine_a 0.7452955532649496
# neuron unit number: 45
# all_train_score_W0_p 0.38142857142857145
# all_train_score_W0_n 0.031000905164392824
# all_train_score_W0_a 0.029131632757549146
# test_score_W0_p0.4533333333333333
# test_score_W0_n 0.07369920819023061
# test_score_W0_a  0.07196893606492394
# all_train_score_W_combine_p 0.89
# all_train_score_W_combine_n 0.7205673938045712
# all_train_score_W_combine_a 0.736451876063251
# test_score_W_combine_p 0.8966666666666666
# test_score_W_combine_n 0.7418703042253275
# test_score_W_combine_a 0.7469149051480529
# neuron unit number: 50
# all_train_score_W0_p 0.41928571428571426
# all_train_score_W0_n 0.05401646675107605
# all_train_score_W0_a 0.05149700735948483
# test_score_W0_p0.5166666666666667
# test_score_W0_n 0.13159029663999255
# test_score_W0_a  0.12412186710014199
# all_train_score_W_combine_p 0.8971428571428571
# all_train_score_W_combine_n 0.7340643561824126
# all_train_score_W_combine_a 0.7506337763344415
# test_score_W_combine_p 0.89
# test_score_W_combine_n 0.7276727341696836
# test_score_W_combine_a 0.7381867397767881
# test_score_W0_p mean 0.48216666666666663
# test_score_W_combine_p mean 0.8961666666666668
# test_score_W0_n mean 0.09906891259315193
# test_score_W_combine_n mean 0.7398544122592674
# test_score_W0_a mean 0.09382231590374242
# test_score_W_combine_a mean 0.7502507141353917
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.044247  0.008974  0.002838   0.037827  0.050666
# 1  train_W_combine  10.0  0.725855  0.011801  0.003732   0.717413  0.734297
# 2         combined  20.0  0.385051  0.349807  0.078219   0.221336  0.548765
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.6816
# 1                       Degrees of freedom =    18.0000
# 2                                        t =  -145.3817
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -65.0167
# 7                                Hedge's g =   -62.2695
# 8                           Glass's delta1 =   -75.9513
# 9                         Point-Biserial r =    -0.9996
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.099069  0.022663  0.007167   0.082857  0.115281
# 1  test_W_combine  10.0  0.739854  0.020167  0.006377   0.725428  0.754281
# 2        combined  20.0  0.419462  0.329378  0.073651   0.265308  0.573616
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6408
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -66.7953
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -29.8718
# 7                              Hedge's g =  -28.6096
# 8                         Glass's delta1 =  -28.2745
# 9                       Point-Biserial r =   -0.9980
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.042714  0.009231  0.002919   0.036110  0.049318
# 1  train_W_combine  10.0  0.740146  0.015156  0.004793   0.729304  0.750988
# 2         combined  20.0  0.391430  0.357984  0.080048   0.223889  0.558972
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.6974
# 1                       Degrees of freedom =    18.0000
# 2                                        t =  -124.2774
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -55.5786
# 7                                Hedge's g =   -53.2302
# 8                           Glass's delta1 =   -75.5502
# 9                         Point-Biserial r =    -0.9994
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.093822  0.021086  0.006668   0.078738  0.108906
# 1  test_W_combine  10.0  0.750251  0.020497  0.006482   0.735588  0.764913
# 2        combined  20.0  0.422037  0.337348  0.075433   0.264153  0.579920
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6564
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -70.5904
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -31.5690
# 7                              Hedge's g =  -30.2351
# 8                         Glass's delta1 =  -31.1314
# 9                       Point-Biserial r =   -0.9982
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.404143  0.015900  0.005028   0.392769  0.415517
# 1  train_W_combine  10.0  0.891500  0.007472  0.002363   0.886155  0.896845
# 2         combined  20.0  0.647821  0.250301  0.055969   0.530677  0.764966
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.4874
# 1                       Degrees of freedom =   18.0000
# 2                                        t =  -87.7238
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -39.2313
# 7                                Hedge's g =  -37.5736
# 8                           Glass's delta1 =  -30.6513
# 9                         Point-Biserial r =   -0.9988
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.482167  0.026493  0.008378   0.463215  0.501119
# 1  test_W_combine  10.0  0.896167  0.009430  0.002982   0.889421  0.902912
# 2        combined  20.0  0.689167  0.213258  0.047686   0.589359  0.788974
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.4140
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -46.5550
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -20.8200
# 7                              Hedge's g =  -19.9403
# 8                         Glass's delta1 =  -15.6267
# 9                       Point-Biserial r =   -0.9959

# %%
#onehot encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.385
# all_train_score_W0_n 0.033837397409415104
# all_train_score_W0_a 0.03106665164238734
# test_score_W0_p0.42833333333333334
# test_score_W0_n 0.05864340059412302
# test_score_W0_a  0.05421551641246293
# all_train_score_W_combine_p 0.8807142857142857
# all_train_score_W_combine_n 0.7071787870581889
# all_train_score_W_combine_a 0.7193748277477785
# test_score_W_combine_p 0.8983333333333333
# test_score_W_combine_n 0.742449344324941
# test_score_W_combine_a 0.7532764560286053
# neuron unit number: 10
# all_train_score_W0_p 0.39
# all_train_score_W0_n 0.035468232006826306
# all_train_score_W0_a 0.03251458168323638
# test_score_W0_p0.43833333333333335
# test_score_W0_n 0.06905713028401346
# test_score_W0_a  0.05960465286909775
# all_train_score_W_combine_p 0.8992857142857142
# all_train_score_W_combine_n 0.7397970890001055
# all_train_score_W_combine_a 0.7572835928524053
# test_score_W_combine_p 0.9016666666666666
# test_score_W_combine_n 0.7450194838611698
# test_score_W_combine_a 0.7586002572705344
# neuron unit number: 15
# all_train_score_W0_p 0.4035714285714286
# all_train_score_W0_n 0.045070380479457196
# all_train_score_W0_a 0.0430784248082003
# test_score_W0_p0.455
# test_score_W0_n 0.07661573058256761
# test_score_W0_a  0.06948358345082438
# all_train_score_W_combine_p 0.8885714285714286
# all_train_score_W_combine_n 0.7213866983418467
# all_train_score_W_combine_a 0.7334384523764875
# test_score_W_combine_p 0.9
# test_score_W_combine_n 0.7527284076823878
# test_score_W_combine_a 0.7579632785411702
# neuron unit number: 20
# all_train_score_W0_p 0.3985714285714286
# all_train_score_W0_n 0.039100135000249794
# all_train_score_W0_a 0.03765119608466142
# test_score_W0_p0.45666666666666667
# test_score_W0_n 0.08753521858022408
# test_score_W0_a  0.07464310235145465
# all_train_score_W_combine_p 0.8707142857142857
# all_train_score_W_combine_n 0.6941836410711616
# all_train_score_W_combine_a 0.7003976610551115
# test_score_W_combine_p 0.87
# test_score_W_combine_n 0.6912767204324095
# test_score_W_combine_a 0.6930041069669812
# neuron unit number: 25
# all_train_score_W0_p 0.435
# all_train_score_W0_n 0.06025513405714338
# all_train_score_W0_a 0.06034515032416355
# test_score_W0_p0.47833333333333333
# test_score_W0_n 0.09727755966838247
# test_score_W0_a  0.0868907528006266
# all_train_score_W_combine_p 0.8878571428571429
# all_train_score_W_combine_n 0.7225851027616885
# all_train_score_W_combine_a 0.7331717223160378
# test_score_W_combine_p 0.8883333333333333
# test_score_W_combine_n 0.7217146294686492
# test_score_W_combine_a 0.732405396660813
# neuron unit number: 30
# all_train_score_W0_p 0.43142857142857144
# all_train_score_W0_n 0.060459053303050216
# all_train_score_W0_a 0.05794460475180781
# test_score_W0_p0.49
# test_score_W0_n 0.10740321242624983
# test_score_W0_a  0.10008491496724368
# all_train_score_W_combine_p 0.8942857142857142
# all_train_score_W_combine_n 0.731995952352606
# all_train_score_W_combine_a 0.7469508185712055
# test_score_W_combine_p 0.895
# test_score_W_combine_n 0.7334915497682656
# test_score_W_combine_a 0.7453385363388918
# neuron unit number: 35
# all_train_score_W0_p 0.41714285714285715
# all_train_score_W0_n 0.050114840162538254
# all_train_score_W0_a 0.04855383308382377
# test_score_W0_p0.4816666666666667
# test_score_W0_n 0.09921036261752297
# test_score_W0_a  0.09059854549639465
# all_train_score_W_combine_p 0.9092857142857143
# all_train_score_W_combine_n 0.7557430075233205
# all_train_score_W_combine_a 0.7772815831587755
# test_score_W_combine_p 0.9166666666666666
# test_score_W_combine_n 0.7734478681773028
# test_score_W_combine_a 0.7907877314649399
# neuron unit number: 40
# all_train_score_W0_p 0.435
# all_train_score_W0_n 0.06090688285123476
# all_train_score_W0_a 0.05970368886273476
# test_score_W0_p0.505
# test_score_W0_n 0.11940161997483588
# test_score_W0_a  0.11153851338950688
# all_train_score_W_combine_p 0.8921428571428571
# all_train_score_W_combine_n 0.7269806281180913
# all_train_score_W_combine_a 0.7428072833238724
# test_score_W_combine_p 0.915
# test_score_W_combine_n 0.7680095192471067
# test_score_W_combine_a 0.7892184987208866
# neuron unit number: 45
# all_train_score_W0_p 0.39714285714285713
# all_train_score_W0_n 0.039522806754390724
# all_train_score_W0_a 0.038256989430512804
# test_score_W0_p0.465
# test_score_W0_n 0.08413184485770366
# test_score_W0_a  0.0795554342100042
# all_train_score_W_combine_p 0.9
# all_train_score_W_combine_n 0.7462845446711364
# all_train_score_W_combine_a 0.7617442236500291
# test_score_W_combine_p 0.9016666666666666
# test_score_W_combine_n 0.742805634545099
# test_score_W_combine_a 0.758588976937143
# neuron unit number: 50
# all_train_score_W0_p 0.4307142857142857
# all_train_score_W0_n 0.05851663228314625
# all_train_score_W0_a 0.05875745209322417
# test_score_W0_p0.49333333333333335
# test_score_W0_n 0.1119281084788669
# test_score_W0_a  0.10337475572303813
# all_train_score_W_combine_p 0.9014285714285715
# all_train_score_W_combine_n 0.7451111234935781
# all_train_score_W_combine_a 0.7612793290522775
# test_score_W_combine_p 0.915
# test_score_W_combine_n 0.7697164785573006
# test_score_W_combine_a 0.7891096194596069
# test_score_W0_p mean 0.4691666666666666
# test_score_W_combine_p mean 0.9001666666666666
# test_score_W0_n mean 0.09112041880644899
# test_score_W_combine_n mean 0.7440659636064632
# test_score_W0_a mean 0.08299897716706539
# test_score_W_combine_a mean 0.7568292858389574
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.048325  0.011072  0.003501   0.040405  0.056246
# 1  train_W_combine  10.0  0.729125  0.018828  0.005954   0.715656  0.742593
# 2         combined  20.0  0.388725  0.349566  0.078165   0.225123  0.552327
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.6808
# 1                       Degrees of freedom =   18.0000
# 2                                        t =  -98.5650
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -44.0796
# 7                                Hedge's g =  -42.2171
# 8                           Glass's delta1 =  -61.4886
# 9                         Point-Biserial r =   -0.9991
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.091120  0.019479  0.006160   0.077186  0.105055
# 1  test_W_combine  10.0  0.744066  0.024884  0.007869   0.726265  0.761867
# 2        combined  20.0  0.417593  0.335659  0.075056   0.260500  0.574687
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6529
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -65.3393
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -29.2206
# 7                              Hedge's g =  -27.9859
# 8                         Glass's delta1 =  -33.5204
# 9                       Point-Biserial r =   -0.9979
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.046787  0.011749  0.003715   0.038382  0.055192
# 1  train_W_combine  10.0  0.743373  0.022706  0.007180   0.727130  0.759616
# 2         combined  20.0  0.395080  0.357774  0.080001   0.227637  0.562523
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.6966
# 1                       Degrees of freedom =   18.0000
# 2                                        t =  -86.1619
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -38.5328
# 7                                Hedge's g =  -36.9046
# 8                           Glass's delta1 =  -59.2883
# 9                         Point-Biserial r =   -0.9988
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.082999  0.018958  0.005995   0.069437  0.096561
# 1  test_W_combine  10.0  0.756829  0.029938  0.009467   0.735413  0.778246
# 2        combined  20.0  0.419914  0.346527  0.077486   0.257735  0.582094
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6738
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -60.1324
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -26.8920
# 7                              Hedge's g =  -25.7557
# 8                         Glass's delta1 =  -35.5434
# 9                       Point-Biserial r =   -0.9975
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.412357  0.019709  0.006233   0.398258  0.426456
# 1  train_W_combine  10.0  0.892429  0.011143  0.003524   0.884457  0.900400
# 2         combined  20.0  0.652393  0.246764  0.055178   0.536904  0.767882
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.4801
# 1                       Degrees of freedom =   18.0000
# 2                                        t =  -67.0519
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -29.9865
# 7                                Hedge's g =  -28.7195
# 8                           Glass's delta1 =  -24.3581
# 9                         Point-Biserial r =   -0.9980
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.469167  0.024799  0.007842   0.451427  0.486906
# 1  test_W_combine  10.0  0.900167  0.014130  0.004468   0.890059  0.910275
# 2        combined  20.0  0.684667  0.221969  0.049634   0.580782  0.788551
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.4310
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -47.7526
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -21.3556
# 7                              Hedge's g =  -20.4533
# 8                         Glass's delta1 =  -17.3800
# 9                       Point-Biserial r =   -0.9961

# %%
#hash encoding hybrid
import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 30
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.385
# all_train_score_W0_n 0.03436199709229365
# all_train_score_W0_a 0.03148356101345616
# test_score_W0_p0.44666666666666666
# test_score_W0_n 0.07046153297842453
# test_score_W0_a  0.06605779890644123
# all_train_score_W_combine_p 0.8707142857142857
# all_train_score_W_combine_n 0.6914023970430664
# all_train_score_W_combine_a 0.6967818891369003
# test_score_W_combine_p 0.8916666666666667
# test_score_W_combine_n 0.724852589396512
# test_score_W_combine_a 0.732598941469461
# neuron unit number: 10
# all_train_score_W0_p 0.37357142857142855
# all_train_score_W0_n 0.029544367991256645
# all_train_score_W0_a 0.026815773362573986
# test_score_W0_p0.435
# test_score_W0_n 0.06702388484401732
# test_score_W0_a  0.061033659000262426
# all_train_score_W_combine_p 0.8871428571428571
# all_train_score_W_combine_n 0.7202058354992728
# all_train_score_W_combine_a 0.7365250847876371
# test_score_W_combine_p 0.9
# test_score_W_combine_n 0.7418737182681758
# test_score_W_combine_a 0.7505207557668294
# neuron unit number: 15
# all_train_score_W0_p 0.42
# all_train_score_W0_n 0.053726454279951104
# all_train_score_W0_a 0.05387712320527642
# test_score_W0_p0.49
# test_score_W0_n 0.10348930807910572
# test_score_W0_a  0.1043206025025048
# all_train_score_W_combine_p 0.8907142857142857
# all_train_score_W_combine_n 0.7261492383101531
# all_train_score_W_combine_a 0.7441992086571554
# test_score_W_combine_p 0.8966666666666666
# test_score_W_combine_n 0.7318083931750844
# test_score_W_combine_a 0.743949661766806
# neuron unit number: 20
# all_train_score_W0_p 0.3892857142857143
# all_train_score_W0_n 0.034849322914174065
# all_train_score_W0_a 0.0330476075688073
# test_score_W0_p0.4583333333333333
# test_score_W0_n 0.07890515582439625
# test_score_W0_a  0.07800618963761712
# all_train_score_W_combine_p 0.8728571428571429
# all_train_score_W_combine_n 0.7034202503842492
# all_train_score_W_combine_a 0.7036426588363788
# test_score_W_combine_p 0.9
# test_score_W_combine_n 0.745195518124849
# test_score_W_combine_a 0.7522366052715536
# neuron unit number: 25
# all_train_score_W0_p 0.39
# all_train_score_W0_n 0.03745309179248949
# all_train_score_W0_a 0.03603059203382526
# test_score_W0_p0.43
# test_score_W0_n 0.06242996791686857
# test_score_W0_a  0.05616941046509581
# all_train_score_W_combine_p 0.8685714285714285
# all_train_score_W_combine_n 0.6914360395803842
# all_train_score_W_combine_a 0.700515039038114
# test_score_W_combine_p 0.8883333333333333
# test_score_W_combine_n 0.7155686543598131
# test_score_W_combine_a 0.7249992710913471
# neuron unit number: 30
# all_train_score_W0_p 0.4135714285714286
# all_train_score_W0_n 0.048773460161006414
# all_train_score_W0_a 0.046915840083940036
# test_score_W0_p0.47
# test_score_W0_n 0.08992562383303282
# test_score_W0_a  0.08798485227702839
# all_train_score_W_combine_p 0.8821428571428571
# all_train_score_W_combine_n 0.7074693964008624
# all_train_score_W_combine_a 0.7234970081760382
# test_score_W_combine_p 0.9083333333333333
# test_score_W_combine_n 0.7539900524535403
# test_score_W_combine_a 0.7689136853547417
# neuron unit number: 35
# all_train_score_W0_p 0.4157142857142857
# all_train_score_W0_n 0.051512712655453215
# all_train_score_W0_a 0.046762900529209464
# test_score_W0_p0.49833333333333335
# test_score_W0_n 0.11823350344597502
# test_score_W0_a  0.10979511928495299
# all_train_score_W_combine_p 0.88
# all_train_score_W_combine_n 0.7069649834063628
# all_train_score_W_combine_a 0.7201927801504131
# test_score_W_combine_p 0.9
# test_score_W_combine_n 0.7391375310958846
# test_score_W_combine_a 0.7500535204949689
# neuron unit number: 40
# all_train_score_W0_p 0.41
# all_train_score_W0_n 0.04688339575438326
# all_train_score_W0_a 0.04360955499554934
# test_score_W0_p0.48833333333333334
# test_score_W0_n 0.10192659956528759
# test_score_W0_a  0.09740725280669149
# all_train_score_W_combine_p 0.8864285714285715
# all_train_score_W_combine_n 0.7171430666269968
# all_train_score_W_combine_a 0.7322192919594042
# test_score_W_combine_p 0.9216666666666666
# test_score_W_combine_n 0.7785616931890134
# test_score_W_combine_a 0.8001661327838075
# neuron unit number: 45
# all_train_score_W0_p 0.39714285714285713
# all_train_score_W0_n 0.040939066044604074
# all_train_score_W0_a 0.03711653673594357
# test_score_W0_p0.45166666666666666
# test_score_W0_n 0.07903339032860042
# test_score_W0_a  0.07014423771482223
# all_train_score_W_combine_p 0.8785714285714286
# all_train_score_W_combine_n 0.7018227448812037
# all_train_score_W_combine_a 0.7174591130172192
# test_score_W_combine_p 0.8966666666666666
# test_score_W_combine_n 0.7328309740941776
# test_score_W_combine_a 0.7414488174970243
# neuron unit number: 50
# all_train_score_W0_p 0.4228571428571429
# all_train_score_W0_n 0.052827299865055466
# all_train_score_W0_a 0.052198940721274255
# test_score_W0_p0.5066666666666667
# test_score_W0_n 0.11810334054352066
# test_score_W0_a  0.11571160032366808
# all_train_score_W_combine_p 0.8792857142857143
# all_train_score_W_combine_n 0.7066439874666168
# all_train_score_W_combine_a 0.7191907932149556
# test_score_W_combine_p 0.8933333333333333
# test_score_W_combine_n 0.7295780258989312
# test_score_W_combine_a 0.7386291927998961
# test_score_W0_p mean 0.46749999999999997
# test_score_W_combine_p mean 0.8996666666666666
# test_score_W0_n mean 0.0889532307359229
# test_score_W_combine_n mean 0.7393397150055981
# test_score_W0_a mean 0.08466307229190846
# test_score_W_combine_a mean 0.7503516584296436
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.043087  0.008753  0.002768   0.036826  0.049349
# 1  train_W_combine  10.0  0.707266  0.011396  0.003604   0.699114  0.715418
# 2         combined  20.0  0.375176  0.340860  0.076219   0.215649  0.534704
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.6642
# 1                       Degrees of freedom =    18.0000
# 2                                        t =  -146.1664
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -65.3676
# 7                                Hedge's g =   -62.6056
# 8                           Glass's delta1 =   -75.8790
# 9                         Point-Biserial r =    -0.9996
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.088953  0.020584  0.006509   0.074228  0.103678
# 1  test_W_combine  10.0  0.739340  0.017522  0.005541   0.726806  0.751874
# 2        combined  20.0  0.414146  0.334160  0.074720   0.257755  0.570538
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6504
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -76.0851
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -34.0263
# 7                              Hedge's g =  -32.5886
# 8                         Glass's delta1 =  -31.5967
# 9                       Point-Biserial r =   -0.9984
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.040786  0.009193  0.002907   0.034210  0.047362
# 1  train_W_combine  10.0  0.719422  0.015671  0.004956   0.708212  0.730633
# 2         combined  20.0  0.380104  0.348358  0.077895   0.217068  0.543140
#                            Independent t-test   results
# 0  Difference (train_W0 - train_W_combine) =    -0.6786
# 1                       Degrees of freedom =    18.0000
# 2                                        t =  -118.1174
# 3                    Two side test p value =     0.0000
# 4                   Difference < 0 p value =     0.0000
# 5                   Difference > 0 p value =     1.0000
# 6                                Cohen's d =   -52.8237
# 7                                Hedge's g =   -50.5917
# 8                           Glass's delta1 =   -73.8226
# 9                         Point-Biserial r =    -0.9994
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.084663  0.021414  0.006772   0.069344  0.099982
# 1  test_W_combine  10.0  0.750352  0.021201  0.006704   0.735186  0.765518
# 2        combined  20.0  0.417507  0.342120  0.076500   0.257390  0.577625
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6657
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -69.8588
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -31.2418
# 7                              Hedge's g =  -29.9217
# 8                         Glass's delta1 =  -31.0867
# 9                       Point-Biserial r =   -0.9982
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  10.0  0.401714  0.016900  0.005344   0.389624  0.413804
# 1  train_W_combine  10.0  0.879643  0.007310  0.002311   0.874414  0.884872
# 2         combined  20.0  0.640679  0.245499  0.054895   0.525781  0.755576
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.4779
# 1                       Degrees of freedom =   18.0000
# 2                                        t =  -82.0784
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -36.7066
# 7                                Hedge's g =  -35.1556
# 8                           Glass's delta1 =  -28.2791
# 9                         Point-Biserial r =   -0.9987
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  10.0  0.467500  0.027208  0.008604   0.448037  0.486963
# 1  test_W_combine  10.0  0.899667  0.009487  0.003000   0.892880  0.906453
# 2        combined  20.0  0.683583  0.222582  0.049771   0.579412  0.787755
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.4322
# 1                     Degrees of freedom =   18.0000
# 2                                      t =  -47.4285
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -21.2107
# 7                              Hedge's g =  -20.3145
# 8                         Glass's delta1 =  -15.8838
# 9                       Point-Biserial r =   -0.9960
