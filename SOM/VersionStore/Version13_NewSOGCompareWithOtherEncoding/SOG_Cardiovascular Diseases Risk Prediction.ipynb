# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv_original_encode = csv

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode,"General_Health")
#one hot encoding vs proposed
#dataread.baseN_encoding(csv_original_encode,["Checkup","Exercise","Heart_Disease","Skin_Cancer","Other_Cancer","Depression","Diabetes","Arthritis","Sex","Age_Category","Smoking_History"])


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")


#*** -1 the class labe is not included 



csv = csv.sample(int(csv.shape[0]*0.01))

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
csv_training = csv
#print(f"csv_training {csv_training}")
#dataread.original_encoding_data = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.01))

dataread.original_encoding_data = csv
dataread.original_encoded_feature_num = csv.shape[1]-1

#csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
#csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)
csv_test_original_encoded = csv_test
csv_training_original_encoded = csv_training
#print(csv_training_original_encoded)
#print(f"csv_training {csv_training_original_encoded}")
dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"General_Health")
# Out:
#  column number self.data_train_discrete 11

# %%
#new binary endocing
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.36625647668393785
# train_discrete_score_W0_n 0.011473286167833448
# train_discrete_score_W0_a  0.008482637637875198
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.36139896373056996
# train_discrete_score_W_discrete_n 0.010286726177422496
# train_discrete_score_W_discrete_a 0.007108033827492081
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 10
# train_discrete_score_W0_p 0.3740284974093264
# train_discrete_score_W0_n 0.013395279744055053
# train_discrete_score_W0_a  0.014246633276188601
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.007460763367036186
# test_discrete_score_W0_a 0.011865507608841112
# train_discrete_score_W_discrete_p 0.37208549222797926
# train_discrete_score_W_discrete_n 0.014216723050355016
# train_discrete_score_W_discrete_a 0.0103860565282966
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.004809651620889968
# test_discrete_score_W_discrete_a 0.009609761186816041
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# train_discrete_score_W0_p 0.3759715025906736
# train_discrete_score_W0_n 0.011331740296949453
# train_discrete_score_W0_a  0.015263518519032692
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.011113578287363562
# test_discrete_score_W0_a 0.011661454806341953
# train_discrete_score_W_discrete_p 0.36917098445595853
# train_discrete_score_W_discrete_n 0.007504892797472538
# train_discrete_score_W_discrete_a 0.008978058590283325
# test_discrete_score_W_discrete_p 0.3876889848812095
# test_discrete_score_W_discrete_n 0.008166738308009285
# test_discrete_score_W_discrete_a 0.013383005964956663
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 20
# train_discrete_score_W0_p 0.3711139896373057
# train_discrete_score_W0_n 0.0085106426882708
# train_discrete_score_W0_a  0.007764469251564439
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.01805556156288208
# test_discrete_score_W0_a 0.01181665692851308
# train_discrete_score_W_discrete_p 0.37791450777202074
# train_discrete_score_W_discrete_n 0.012336806487796293
# train_discrete_score_W_discrete_a 0.018867999330472666
# test_discrete_score_W_discrete_p 0.3930885529157667
# test_discrete_score_W_discrete_n 0.018921778456945187
# test_discrete_score_W_discrete_a 0.025023838017918406
# neuron unit number: 25
# train_discrete_score_W0_p 0.3795336787564767
# train_discrete_score_W0_n 0.01761839263277983
# train_discrete_score_W0_a  0.020899626309301006
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.021700297181913315
# test_discrete_score_W0_a 0.023389785863186255
# train_discrete_score_W_discrete_p 0.3856865284974093
# train_discrete_score_W_discrete_n 0.013865858134926889
# train_discrete_score_W_discrete_a 0.01902460711092223
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.028093477469939582
# test_discrete_score_W_discrete_a 0.034465462819870396
# neuron unit number: 30
# train_discrete_score_W0_p 0.38244818652849744
# train_discrete_score_W0_n 0.01843630333249411
# train_discrete_score_W0_a  0.01931276190657274
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.019180794130444014
# test_discrete_score_W0_a 0.02035611366746651
# train_discrete_score_W_discrete_p 0.37791450777202074
# train_discrete_score_W_discrete_n 0.014526344864822977
# train_discrete_score_W_discrete_a 0.014399038251213758
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.02818284115529493
# test_discrete_score_W_discrete_a 0.02813092486652905
# Not good nmi result for discrete features !!!!!
# neuron unit number: 35
# train_discrete_score_W0_p 0.3805051813471503
# train_discrete_score_W0_n 0.02028371271537939
# train_discrete_score_W0_a  0.0218453778925874
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.024742645277090723
# test_discrete_score_W0_a 0.026769913852744204
# train_discrete_score_W_discrete_p 0.38082901554404147
# train_discrete_score_W_discrete_n 0.01714660720768283
# train_discrete_score_W_discrete_a 0.016174617113956707
# test_discrete_score_W_discrete_p 0.4114470842332613
# test_discrete_score_W_discrete_n 0.024938738878752312
# test_discrete_score_W_discrete_a 0.025591944381401364
# Not good ari result for discrete features  !!!!!
# neuron unit number: 40
# train_discrete_score_W0_p 0.3805051813471503
# train_discrete_score_W0_n 0.02227798944412161
# train_discrete_score_W0_a  0.01771405444813332
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.021559908037432254
# test_discrete_score_W0_a 0.0235029775882544
# train_discrete_score_W_discrete_p 0.3785621761658031
# train_discrete_score_W_discrete_n 0.013836740562513777
# train_discrete_score_W_discrete_a 0.012365249508931806
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.029564014467958557
# test_discrete_score_W_discrete_a 0.04071762254919486
# neuron unit number: 45
# train_discrete_score_W0_p 0.3911917098445596
# train_discrete_score_W0_n 0.02005680196048312
# train_discrete_score_W0_a  0.0244464476263238
# test_discrete_score_W0_p 0.4222462203023758
# test_discrete_score_W0_n 0.032424321288523864
# test_discrete_score_W0_a 0.042199999748997505
# train_discrete_score_W_discrete_p 0.38827720207253885
# train_discrete_score_W_discrete_n 0.020540176937469266
# train_discrete_score_W_discrete_a 0.018209399185235474
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.029692795434489487
# test_discrete_score_W_discrete_a 0.03550859459341729
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 50
# train_discrete_score_W0_p 0.3895725388601036
# train_discrete_score_W0_n 0.021750947893932112
# train_discrete_score_W0_a  0.02169287165667739
# test_discrete_score_W0_p 0.42332613390928725
# test_discrete_score_W0_n 0.03352812020538627
# test_discrete_score_W0_a 0.034225209526714775
# train_discrete_score_W_discrete_p 0.391839378238342
# train_discrete_score_W_discrete_n 0.02042891972119469
# train_discrete_score_W_discrete_a 0.019962327604145937
# test_discrete_score_W_discrete_p 0.4168466522678186
# test_discrete_score_W_discrete_n 0.03312437803145348
# test_discrete_score_W_discrete_a 0.03977693537437221
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 55
# train_discrete_score_W0_p 0.39766839378238344
# train_discrete_score_W0_n 0.02552941465733492
# train_discrete_score_W0_a  0.02477620906196748
# test_discrete_score_W0_p 0.4319654427645788
# test_discrete_score_W0_n 0.03721548387698212
# test_discrete_score_W0_a 0.04527096572967886
# train_discrete_score_W_discrete_p 0.39734455958549225
# train_discrete_score_W_discrete_n 0.02191777260757069
# train_discrete_score_W_discrete_a 0.024948548066172624
# test_discrete_score_W_discrete_p 0.43088552915766737
# test_discrete_score_W_discrete_n 0.03725248458821139
# test_discrete_score_W_discrete_a 0.05635881060433823
# Not good nmi result for discrete features !!!!!
# neuron unit number: 60
# train_discrete_score_W0_p 0.3898963730569948
# train_discrete_score_W0_n 0.021010400600882537
# train_discrete_score_W0_a  0.021899870309404445
# test_discrete_score_W0_p 0.43412526997840173
# test_discrete_score_W0_n 0.04182268192852355
# test_discrete_score_W0_a 0.05079010717693686
# train_discrete_score_W_discrete_p 0.3915155440414508
# train_discrete_score_W_discrete_n 0.02184050466070155
# train_discrete_score_W_discrete_a 0.025017739049791352
# test_discrete_score_W_discrete_p 0.43844492440604754
# test_discrete_score_W_discrete_n 0.03929302024841728
# test_discrete_score_W_discrete_a 0.05062924680470451
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 65
# train_discrete_score_W0_p 0.3944300518134715
# train_discrete_score_W0_n 0.024503032425836863
# train_discrete_score_W0_a  0.02412721673812219
# test_discrete_score_W0_p 0.44600431965442766
# test_discrete_score_W0_n 0.047607600701064116
# test_discrete_score_W0_a 0.061280251182894964
# train_discrete_score_W_discrete_p 0.39669689119170987
# train_discrete_score_W_discrete_n 0.0217497908085967
# train_discrete_score_W_discrete_a 0.024979650353395316
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.05314112692229833
# test_discrete_score_W_discrete_a 0.06862604966531868
# neuron unit number: 70
# train_discrete_score_W0_p 0.39248704663212436
# train_discrete_score_W0_n 0.025675690056596222
# train_discrete_score_W0_a  0.02525142858745969
# test_discrete_score_W0_p 0.4298056155507559
# test_discrete_score_W0_n 0.03820737561233791
# test_discrete_score_W0_a 0.04586723241175229
# train_discrete_score_W_discrete_p 0.40025906735751293
# train_discrete_score_W_discrete_n 0.02959096282275331
# train_discrete_score_W_discrete_a 0.03200880642370185
# test_discrete_score_W_discrete_p 0.44384449244060475
# test_discrete_score_W_discrete_n 0.047204198241926544
# test_discrete_score_W_discrete_a 0.0593517805188595
# neuron unit number: 75
# train_discrete_score_W0_p 0.4015544041450777
# train_discrete_score_W0_n 0.029766132371063726
# train_discrete_score_W0_a  0.03184594718981001
# test_discrete_score_W0_p 0.43952483801295894
# test_discrete_score_W0_n 0.05263481942818684
# test_discrete_score_W0_a 0.05217957411504476
# train_discrete_score_W_discrete_p 0.39248704663212436
# train_discrete_score_W_discrete_n 0.023454678428081906
# train_discrete_score_W_discrete_a 0.024413364968114273
# test_discrete_score_W_discrete_p 0.45464362850971923
# test_discrete_score_W_discrete_n 0.059445008239925066
# test_discrete_score_W_discrete_a 0.06510426446494723
# neuron unit number: 80
# train_discrete_score_W0_p 0.4022020725388601
# train_discrete_score_W0_n 0.028095478025364485
# train_discrete_score_W0_a  0.03001596188966298
# test_discrete_score_W0_p 0.46220302375809935
# test_discrete_score_W0_n 0.05730224647936876
# test_discrete_score_W0_a 0.07756456561686288
# train_discrete_score_W_discrete_p 0.3963730569948187
# train_discrete_score_W_discrete_n 0.022584388935844968
# train_discrete_score_W_discrete_a 0.023537044012144622
# test_discrete_score_W_discrete_p 0.4449244060475162
# test_discrete_score_W_discrete_n 0.050964527998484055
# test_discrete_score_W_discrete_a 0.056173295534816946
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 85
# train_discrete_score_W0_p 0.4028497409326425
# train_discrete_score_W0_n 0.023999680725556923
# train_discrete_score_W0_a  0.02328393599682212
# test_discrete_score_W0_p 0.4514038876889849
# test_discrete_score_W0_n 0.049673565942830275
# test_discrete_score_W0_a 0.059596918805172726
# train_discrete_score_W_discrete_p 0.4051165803108808
# train_discrete_score_W_discrete_n 0.028790168126665634
# train_discrete_score_W_discrete_a 0.03430500102436842
# test_discrete_score_W_discrete_p 0.4557235421166307
# test_discrete_score_W_discrete_n 0.057350592100817874
# test_discrete_score_W_discrete_a 0.07726638061425481
# neuron unit number: 90
# train_discrete_score_W0_p 0.4067357512953368
# train_discrete_score_W0_n 0.029763976606979332
# train_discrete_score_W0_a  0.0334659642188635
# test_discrete_score_W0_p 0.46004319654427644
# test_discrete_score_W0_n 0.057192514129206215
# test_discrete_score_W0_a 0.07983187004831926
# train_discrete_score_W_discrete_p 0.4112694300518135
# train_discrete_score_W_discrete_n 0.030754619490519206
# train_discrete_score_W_discrete_a 0.03154682336743238
# test_discrete_score_W_discrete_p 0.4611231101511879
# test_discrete_score_W_discrete_n 0.059273008744954704
# test_discrete_score_W_discrete_a 0.07412892772025534
# Not good ari result for discrete features  !!!!!
# neuron unit number: 95
# train_discrete_score_W0_p 0.39799222797927464
# train_discrete_score_W0_n 0.02530042932128542
# train_discrete_score_W0_a  0.027867108552179096
# test_discrete_score_W0_p 0.4470842332613391
# test_discrete_score_W0_n 0.054700557251835744
# test_discrete_score_W0_a 0.062133162456265295
# train_discrete_score_W_discrete_p 0.3915155440414508
# train_discrete_score_W_discrete_n 0.023306569029696786
# train_discrete_score_W_discrete_a 0.027539047997515234
# test_discrete_score_W_discrete_p 0.4427645788336933
# test_discrete_score_W_discrete_n 0.0483197221956919
# test_discrete_score_W_discrete_a 0.05174283324791172
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 100
# train_discrete_score_W0_p 0.4099740932642487
# train_discrete_score_W0_n 0.03229327103304952
# train_discrete_score_W0_a  0.03315269072105094
# test_discrete_score_W0_p 0.47300215982721383
# test_discrete_score_W0_n 0.06772157896368762
# test_discrete_score_W0_a 0.08676857860772391
# train_discrete_score_W_discrete_p 0.40317357512953367
# train_discrete_score_W_discrete_n 0.027158793296791803
# train_discrete_score_W_discrete_a 0.030555330778871903
# test_discrete_score_W_discrete_p 0.468682505399568
# test_discrete_score_W_discrete_n 0.06998052235590996
# test_discrete_score_W_discrete_a 0.0855957814337246
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.4244060475161987
# test_discrete_score_W_discrete_p mean 0.424622030237581
# test_discrete_score_W0_n mean 0.03469222068260477
# test_discrete_score_W_discrete_n mean 0.03638593127301849
# test_discrete_score_W0_a mean 0.041353542287085585
# test_discrete_score_W_discrete_a mean 0.04485927301818039
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.021554  0.006598  0.001475   0.018466  0.024642
# 1  train_dis_W_dis  20.0  0.019792  0.006617  0.001480   0.016695  0.022889
# 2         combined  40.0  0.020673  0.006583  0.001041   0.018567  0.022778
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0018
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.8432
# 3                        Two side test p value =    0.4044
# 4                       Difference < 0 p value =    0.7978
# 5                       Difference > 0 p value =    0.2022
# 6                                    Cohen's d =    0.2666
# 7                                    Hedge's g =    0.2613
# 8                               Glass's delta1 =    0.2670
# 9                             Point-Biserial r =    0.1355
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.034692  0.018858  0.004217   0.025867  0.043518
# 1  test_dis_W_dis  20.0  0.036386  0.019435  0.004346   0.027290  0.045482
# 2        combined  40.0  0.035539  0.018921  0.002992   0.029488  0.041590
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0017
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.2797
# 3                      Two side test p value =    0.7812
# 4                     Difference < 0 p value =    0.3906
# 5                     Difference > 0 p value =    0.6094
# 6                                  Cohen's d =   -0.0885
# 7                                  Hedge's g =   -0.0867
# 8                             Glass's delta1 =   -0.0898
# 9                           Point-Biserial r =   -0.0453
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.022368  0.007244  0.001620   0.018978  0.025758
# 1  train_dis_W_dis  20.0  0.021216  0.008004  0.001790   0.017470  0.024962
# 2         combined  40.0  0.021792  0.007557  0.001195   0.019375  0.024209
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0012
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.4770
# 3                        Two side test p value =    0.6361
# 4                       Difference < 0 p value =    0.6820
# 5                       Difference > 0 p value =    0.3180
# 6                                    Cohen's d =    0.1508
# 7                                    Hedge's g =    0.1478
# 8                               Glass's delta1 =    0.1589
# 9                             Point-Biserial r =    0.0771
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.041354  0.025066  0.005605   0.029622  0.053085
# 1  test_dis_W_dis  20.0  0.044859  0.023643  0.005287   0.033794  0.055924
# 2        combined  40.0  0.043106  0.024116  0.003813   0.035394  0.050819
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0035
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.4550
# 3                      Two side test p value =    0.6517
# 4                     Difference < 0 p value =    0.3258
# 5                     Difference > 0 p value =    0.6742
# 6                                  Cohen's d =   -0.1439
# 7                                  Hedge's g =   -0.1410
# 8                             Glass's delta1 =   -0.1399
# 9                           Point-Biserial r =   -0.0736
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  20.0  0.389346  0.012539  0.002804   0.383477  0.395214
# 1  train_dis_W_dis  20.0  0.388472  0.012913  0.002887   0.382428  0.394515
# 2         combined  40.0  0.388909  0.012571  0.001988   0.384888  0.392929
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0009
# 1                           Degrees of freedom =   38.0000
# 2                                            t =    0.2172
# 3                        Two side test p value =    0.8292
# 4                       Difference < 0 p value =    0.5854
# 5                       Difference > 0 p value =    0.4146
# 6                                    Cohen's d =    0.0687
# 7                                    Hedge's g =    0.0673
# 8                               Glass's delta1 =    0.0697
# 9                             Point-Biserial r =    0.0352
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  20.0  0.424406  0.028130  0.006290   0.411241  0.437571
# 1  test_dis_W_dis  20.0  0.424622  0.029162  0.006521   0.410974  0.438270
# 2        combined  40.0  0.424514  0.028281  0.004472   0.415469  0.433559
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0002
# 1                         Degrees of freedom =   38.0000
# 2                                          t =   -0.0238
# 3                      Two side test p value =    0.9811
# 4                     Difference < 0 p value =    0.4906
# 5                     Difference > 0 p value =    0.5094
# 6                                  Cohen's d =   -0.0075
# 7                                  Hedge's g =   -0.0074
# 8                             Glass's delta1 =   -0.0077
# 9                           Point-Biserial r =   -0.0039

# %%
#new one hot
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.36625647668393785
# train_discrete_score_W0_n 0.011473286167833448
# train_discrete_score_W0_a  0.008482637637875198
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.36139896373056996
# train_discrete_score_W_discrete_n 0.010286726177422496
# train_discrete_score_W_discrete_a 0.007108033827492081
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 6
# train_discrete_score_W0_p 0.3626943005181347
# train_discrete_score_W0_n 0.010895735032736546
# train_discrete_score_W0_a  0.010641743086525358
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.3633419689119171
# train_discrete_score_W_discrete_n 0.011464784107825636
# train_discrete_score_W_discrete_a 0.010430194361192894
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 7
# train_discrete_score_W0_p 0.36884715025906734
# train_discrete_score_W0_n 0.014364358752183247
# train_discrete_score_W0_a  0.00902618153922351
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.3694948186528497
# train_discrete_score_W_discrete_n 0.014935062441737467
# train_discrete_score_W_discrete_a 0.009807568104842467
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 8
# train_discrete_score_W0_p 0.3701424870466321
# train_discrete_score_W0_n 0.015704343337498036
# train_discrete_score_W0_a  0.010221878682778626
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.004004049759215919
# test_discrete_score_W0_a 0.007283656673940309
# train_discrete_score_W_discrete_p 0.3701424870466321
# train_discrete_score_W_discrete_n 0.015704343337498036
# train_discrete_score_W_discrete_a 0.010221878682778626
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.004004049759215919
# test_discrete_score_W_discrete_a 0.007283656673940309
# neuron unit number: 9
# train_discrete_score_W0_p 0.36722797927461137
# train_discrete_score_W0_n 0.012887887168566077
# train_discrete_score_W0_a  0.0122539025520301
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.0021406585281149226
# test_discrete_score_W0_a 0.0033310491978113294
# train_discrete_score_W_discrete_p 0.3636658031088083
# train_discrete_score_W_discrete_n 0.011808792786709458
# train_discrete_score_W_discrete_a 0.0093495352484008
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.0025641400650307867
# test_discrete_score_W_discrete_a 0.002633439117899124
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 10
# train_discrete_score_W0_p 0.36819948186528495
# train_discrete_score_W0_n 0.011205879907509196
# train_discrete_score_W0_a  0.008219493704896351
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.00641767465439718
# test_discrete_score_W0_a 0.009068386899096769
# train_discrete_score_W_discrete_p 0.37208549222797926
# train_discrete_score_W_discrete_n 0.014216723050355016
# train_discrete_score_W_discrete_a 0.0103860565282966
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.004809651620889968
# test_discrete_score_W_discrete_a 0.009609761186816041
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 11
# train_discrete_score_W0_p 0.3759715025906736
# train_discrete_score_W0_n 0.009114885259776155
# train_discrete_score_W0_a  0.013555558083464295
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.001719927747284585
# test_discrete_score_W0_a 0.0007987544137205614
# train_discrete_score_W_discrete_p 0.37305699481865284
# train_discrete_score_W_discrete_n 0.01635742766959706
# train_discrete_score_W_discrete_a 0.017863768125681752
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.006070196162346819
# test_discrete_score_W_discrete_a 0.008929037430772474
# neuron unit number: 12
# train_discrete_score_W0_p 0.37370466321243523
# train_discrete_score_W0_n 0.010222623097822226
# train_discrete_score_W0_a  0.012882632286164418
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.00291499859716387
# test_discrete_score_W0_a 0.006465428044849577
# train_discrete_score_W_discrete_p 0.37370466321243523
# train_discrete_score_W_discrete_n 0.010349431871182532
# train_discrete_score_W_discrete_a 0.012308529105622646
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.004438142849652427
# test_discrete_score_W_discrete_a 0.010026631311997781
# neuron unit number: 13
# train_discrete_score_W0_p 0.37661917098445596
# train_discrete_score_W0_n 0.01436362719344374
# train_discrete_score_W0_a  0.013568536285760713
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.012131598846246153
# test_discrete_score_W0_a 0.01657112675245526
# train_discrete_score_W_discrete_p 0.37629533678756477
# train_discrete_score_W_discrete_n 0.012998661144483836
# train_discrete_score_W_discrete_a 0.014187118123396247
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.010667610058378638
# test_discrete_score_W_discrete_a 0.012157063564936184
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 14
# train_discrete_score_W0_p 0.36852331606217614
# train_discrete_score_W0_n 0.014478151334361802
# train_discrete_score_W0_a  0.014720078295945621
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.006824969544112294
# test_discrete_score_W0_a 0.012038131694001662
# train_discrete_score_W_discrete_p 0.37338082901554404
# train_discrete_score_W_discrete_n 0.015834683380398965
# train_discrete_score_W_discrete_a 0.011265674063162246
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.012960607025943613
# test_discrete_score_W_discrete_a 0.015596195122484308
# neuron unit number: 15
# train_discrete_score_W0_p 0.375
# train_discrete_score_W0_n 0.01216943186147666
# train_discrete_score_W0_a  0.014571025916310579
# test_discrete_score_W0_p 0.38876889848812096
# test_discrete_score_W0_n 0.009360339440518351
# test_discrete_score_W0_a 0.01631586119046575
# train_discrete_score_W_discrete_p 0.3740284974093264
# train_discrete_score_W_discrete_n 0.013103855256041061
# train_discrete_score_W_discrete_a 0.01144320986917146
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.01179609537381309
# test_discrete_score_W_discrete_a 0.014729008283789608
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 16
# train_discrete_score_W0_p 0.3756476683937824
# train_discrete_score_W0_n 0.01258418056336054
# train_discrete_score_W0_a  0.016774301162717414
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.01601356089831837
# test_discrete_score_W0_a 0.014503679566037504
# train_discrete_score_W_discrete_p 0.3740284974093264
# train_discrete_score_W_discrete_n 0.01716923430394547
# train_discrete_score_W_discrete_a 0.015383672661892668
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.016477907189952273
# test_discrete_score_W_discrete_a 0.013305837625928922
# Not good ari result for discrete features  !!!!!
# neuron unit number: 17
# train_discrete_score_W0_p 0.37338082901554404
# train_discrete_score_W0_n 0.012828452199107684
# train_discrete_score_W0_a  0.015293861906161632
# test_discrete_score_W0_p 0.38228941684665224
# test_discrete_score_W0_n 0.01578709191330853
# test_discrete_score_W0_a 0.014074157708623358
# train_discrete_score_W_discrete_p 0.3759715025906736
# train_discrete_score_W_discrete_n 0.017810866540630195
# train_discrete_score_W_discrete_a 0.013635444354886395
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.022633244016010336
# test_discrete_score_W_discrete_a 0.022892817552040014
# neuron unit number: 18
# train_discrete_score_W0_p 0.37759067357512954
# train_discrete_score_W0_n 0.01413741943318251
# train_discrete_score_W0_a  0.013113511946828672
# test_discrete_score_W0_p 0.3930885529157667
# test_discrete_score_W0_n 0.021346801877178835
# test_discrete_score_W0_a 0.016665387507163745
# train_discrete_score_W_discrete_p 0.37338082901554404
# train_discrete_score_W_discrete_n 0.012377834424686908
# train_discrete_score_W_discrete_a 0.0155027194504336
# test_discrete_score_W_discrete_p 0.37904967602591794
# test_discrete_score_W_discrete_n 0.013253335753049565
# test_discrete_score_W_discrete_a 0.012299087312584101
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 19
# train_discrete_score_W0_p 0.37370466321243523
# train_discrete_score_W0_n 0.012563586351047765
# train_discrete_score_W0_a  0.011350144827244573
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.013411301488647118
# test_discrete_score_W0_a 0.017387665676842502
# train_discrete_score_W_discrete_p 0.37629533678756477
# train_discrete_score_W_discrete_n 0.013491653935040022
# train_discrete_score_W_discrete_a 0.013652004002818326
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.00959970962380916
# test_discrete_score_W_discrete_a 0.01633463557321624
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# train_discrete_score_W0_p 0.3759715025906736
# train_discrete_score_W0_n 0.014131240147615076
# train_discrete_score_W0_a  0.016961600549875642
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.012774726454364164
# test_discrete_score_W0_a 0.02203008406724765
# train_discrete_score_W_discrete_p 0.37661917098445596
# train_discrete_score_W_discrete_n 0.014066853073063533
# train_discrete_score_W_discrete_a 0.01794780808670905
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.017009835927003423
# test_discrete_score_W_discrete_a 0.01624250925053092
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 21
# train_discrete_score_W0_p 0.37661917098445596
# train_discrete_score_W0_n 0.01706013126182864
# train_discrete_score_W0_a  0.01617607888429484
# test_discrete_score_W0_p 0.40280777537796975
# test_discrete_score_W0_n 0.019927979307236318
# test_discrete_score_W0_a 0.024866658727710794
# train_discrete_score_W_discrete_p 0.3714378238341969
# train_discrete_score_W_discrete_n 0.014109246888425976
# train_discrete_score_W_discrete_a 0.013031390863020005
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.010773250673656308
# test_discrete_score_W_discrete_a 0.017169913188744
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# train_discrete_score_W0_p 0.38147668393782386
# train_discrete_score_W0_n 0.017467896521574936
# train_discrete_score_W0_a  0.017436583988778568
# test_discrete_score_W0_p 0.398488120950324
# test_discrete_score_W0_n 0.02371657448877953
# test_discrete_score_W0_a 0.02456542665745442
# train_discrete_score_W_discrete_p 0.38115284974093266
# train_discrete_score_W_discrete_n 0.015838476149448603
# train_discrete_score_W_discrete_a 0.017622313269463324
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.016627770540271015
# test_discrete_score_W_discrete_a 0.02548750543912135
# Not good nmi result for discrete features !!!!!
# neuron unit number: 23
# train_discrete_score_W0_p 0.37661917098445596
# train_discrete_score_W0_n 0.015464154886687235
# train_discrete_score_W0_a  0.012262562675209818
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.028451043700083212
# test_discrete_score_W0_a 0.02559369867422454
# train_discrete_score_W_discrete_p 0.3801813471502591
# train_discrete_score_W_discrete_n 0.016690074784860294
# train_discrete_score_W_discrete_a 0.014064385650286768
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.023924751340380798
# test_discrete_score_W_discrete_a 0.021562488666443988
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 24
# train_discrete_score_W0_p 0.37791450777202074
# train_discrete_score_W0_n 0.008480345651128549
# train_discrete_score_W0_a  0.011380682529279708
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.01699802727374142
# test_discrete_score_W0_a 0.021552808624195768
# train_discrete_score_W_discrete_p 0.38212435233160624
# train_discrete_score_W_discrete_n 0.020922875019046737
# train_discrete_score_W_discrete_a 0.017617371964264873
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.015168435049681829
# test_discrete_score_W_discrete_a 0.016689323390830773
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# train_discrete_score_W0_p 0.38212435233160624
# train_discrete_score_W0_n 0.019203208243494287
# train_discrete_score_W0_a  0.014885192171500337
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.026373812689014252
# test_discrete_score_W0_a 0.021502995337239376
# train_discrete_score_W_discrete_p 0.3805051813471503
# train_discrete_score_W_discrete_n 0.012246568045747952
# train_discrete_score_W_discrete_a 0.016385393228516138
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.02093505991941184
# test_discrete_score_W_discrete_a 0.03270610623842297
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 26
# train_discrete_score_W0_p 0.3805051813471503
# train_discrete_score_W0_n 0.01602564699973602
# train_discrete_score_W0_a  0.01872030765043625
# test_discrete_score_W0_p 0.4190064794816415
# test_discrete_score_W0_n 0.03740185943593404
# test_discrete_score_W0_a 0.043518138153293785
# train_discrete_score_W_discrete_p 0.37791450777202074
# train_discrete_score_W_discrete_n 0.013703819097834436
# train_discrete_score_W_discrete_a 0.01438361691235123
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.018963616984843664
# test_discrete_score_W_discrete_a 0.020126682811432497
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 27
# train_discrete_score_W0_p 0.37338082901554404
# train_discrete_score_W0_n 0.02093539741877682
# train_discrete_score_W0_a  0.011104643940100476
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.021287696539228778
# test_discrete_score_W0_a 0.019664157363028772
# train_discrete_score_W_discrete_p 0.38115284974093266
# train_discrete_score_W_discrete_n 0.02161205672828636
# train_discrete_score_W_discrete_a 0.021061974311264636
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.017247108166623157
# test_discrete_score_W_discrete_a 0.021770817853448445
# Not good nmi result for discrete features !!!!!
# neuron unit number: 28
# train_discrete_score_W0_p 0.37759067357512954
# train_discrete_score_W0_n 0.015191511939316052
# train_discrete_score_W0_a  0.016786304496778755
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.021685284595628518
# test_discrete_score_W0_a 0.023430392916652956
# train_discrete_score_W_discrete_p 0.375
# train_discrete_score_W_discrete_n 0.008639437949369536
# train_discrete_score_W_discrete_a 0.012575091635637898
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.014405436692411065
# test_discrete_score_W_discrete_a 0.018467356989131944
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 29
# train_discrete_score_W0_p 0.3853626943005181
# train_discrete_score_W0_n 0.016697082254003962
# train_discrete_score_W0_a  0.015904664342333737
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.015575921638761502
# test_discrete_score_W0_a 0.01617709754557875
# train_discrete_score_W_discrete_p 0.3746761658031088
# train_discrete_score_W_discrete_n 0.023078448445202994
# train_discrete_score_W_discrete_a 0.019845506188500138
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.025202564817973037
# test_discrete_score_W_discrete_a 0.027891012998840406
# neuron unit number: 30
# train_discrete_score_W0_p 0.38244818652849744
# train_discrete_score_W0_n 0.01843630333249411
# train_discrete_score_W0_a  0.01931276190657274
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.019180794130444014
# test_discrete_score_W0_a 0.02035611366746651
# train_discrete_score_W_discrete_p 0.38439119170984454
# train_discrete_score_W_discrete_n 0.020385401126683703
# train_discrete_score_W_discrete_a 0.01930349379559112
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.020250368658149772
# test_discrete_score_W_discrete_a 0.023206435843695083
# Not good nmi result for discrete features !!!!!
# neuron unit number: 31
# train_discrete_score_W0_p 0.38762953367875647
# train_discrete_score_W0_n 0.016788377985046034
# train_discrete_score_W0_a  0.0189496425755902
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.026173637440888776
# test_discrete_score_W0_a 0.025750107877891323
# train_discrete_score_W_discrete_p 0.37791450777202074
# train_discrete_score_W_discrete_n 0.014575229671223445
# train_discrete_score_W_discrete_a 0.018412317600877016
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.016275463104016775
# test_discrete_score_W_discrete_a 0.020082574569962753
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 32
# train_discrete_score_W0_p 0.3795336787564767
# train_discrete_score_W0_n 0.01849482923773456
# train_discrete_score_W0_a  0.01823081754007727
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.026754991354693784
# test_discrete_score_W0_a 0.025302428884223144
# train_discrete_score_W_discrete_p 0.38180051813471505
# train_discrete_score_W_discrete_n 0.022553012871881592
# train_discrete_score_W_discrete_a 0.020752394988985828
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.014937006101844941
# test_discrete_score_W_discrete_a 0.019639561121377252
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 33
# train_discrete_score_W0_p 0.3895725388601036
# train_discrete_score_W0_n 0.023618415563400358
# train_discrete_score_W0_a  0.021470637013841224
# test_discrete_score_W0_p 0.4103671706263499
# test_discrete_score_W0_n 0.029542636129193934
# test_discrete_score_W0_a 0.03163122087145126
# train_discrete_score_W_discrete_p 0.38212435233160624
# train_discrete_score_W_discrete_n 0.014717891104538031
# train_discrete_score_W_discrete_a 0.014978760179073573
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.020839121853913338
# test_discrete_score_W_discrete_a 0.027265757306712733
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 34
# train_discrete_score_W0_p 0.3898963730569948
# train_discrete_score_W0_n 0.026055357534984835
# train_discrete_score_W0_a  0.02538070118835262
# test_discrete_score_W0_p 0.4060475161987041
# test_discrete_score_W0_n 0.02389630336179229
# test_discrete_score_W0_a 0.029454870026012547
# train_discrete_score_W_discrete_p 0.38244818652849744
# train_discrete_score_W_discrete_n 0.0176543478585078
# train_discrete_score_W_discrete_a 0.01644506047585662
# test_discrete_score_W_discrete_p 0.41576673866090713
# test_discrete_score_W_discrete_n 0.030901866807494675
# test_discrete_score_W_discrete_a 0.0392489650017842
# neuron unit number: 35
# train_discrete_score_W0_p 0.38277202072538863
# train_discrete_score_W0_n 0.01967039983059747
# train_discrete_score_W0_a  0.0175530069827275
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.022422701253928243
# test_discrete_score_W0_a 0.024554297511504952
# train_discrete_score_W_discrete_p 0.38406735751295334
# train_discrete_score_W_discrete_n 0.014907530722498383
# train_discrete_score_W_discrete_a 0.016498580475774457
# test_discrete_score_W_discrete_p 0.4136069114470842
# test_discrete_score_W_discrete_n 0.026083776635447697
# test_discrete_score_W_discrete_a 0.03560716801898156
# neuron unit number: 36
# train_discrete_score_W0_p 0.38374352331606215
# train_discrete_score_W0_n 0.018668285117431554
# train_discrete_score_W0_a  0.01818974283713102
# test_discrete_score_W0_p 0.41576673866090713
# test_discrete_score_W0_n 0.03089735809870824
# test_discrete_score_W0_a 0.03568310896348573
# train_discrete_score_W_discrete_p 0.38406735751295334
# train_discrete_score_W_discrete_n 0.020544731169887
# train_discrete_score_W_discrete_a 0.01870508579765395
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.01973306822704017
# test_discrete_score_W_discrete_a 0.020327160594459284
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# train_discrete_score_W0_p 0.3853626943005181
# train_discrete_score_W0_n 0.023079585534762168
# train_discrete_score_W0_a  0.024118649868687513
# test_discrete_score_W0_p 0.4114470842332613
# test_discrete_score_W0_n 0.03190549000038854
# test_discrete_score_W0_a 0.03194870700327226
# train_discrete_score_W_discrete_p 0.3759715025906736
# train_discrete_score_W_discrete_n 0.015697644105308977
# train_discrete_score_W_discrete_a 0.013972478163518142
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.02071837631359625
# test_discrete_score_W_discrete_a 0.020458254479936315
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 38
# train_discrete_score_W0_p 0.3850388601036269
# train_discrete_score_W0_n 0.017518757576428144
# train_discrete_score_W0_a  0.01761789286610821
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.023260103112142307
# test_discrete_score_W0_a 0.024289475204188296
# train_discrete_score_W_discrete_p 0.39216321243523317
# train_discrete_score_W_discrete_n 0.021890603716871352
# train_discrete_score_W_discrete_a 0.024214266948229413
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.03222204218503063
# test_discrete_score_W_discrete_a 0.03512042312379023
# neuron unit number: 39
# train_discrete_score_W0_p 0.3856865284974093
# train_discrete_score_W0_n 0.015817145342413894
# train_discrete_score_W0_a  0.01713035282953785
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.024936863473569257
# test_discrete_score_W0_a 0.028121264558075263
# train_discrete_score_W_discrete_p 0.3856865284974093
# train_discrete_score_W_discrete_n 0.01670705055563093
# train_discrete_score_W_discrete_a 0.01731931179655343
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.026678098284694887
# test_discrete_score_W_discrete_a 0.03514839158016698
# neuron unit number: 40
# train_discrete_score_W0_p 0.3954015544041451
# train_discrete_score_W0_n 0.015611681421603135
# train_discrete_score_W0_a  0.02063471270558945
# test_discrete_score_W0_p 0.43088552915766737
# test_discrete_score_W0_n 0.029877046975245947
# test_discrete_score_W0_a 0.03820769568251226
# train_discrete_score_W_discrete_p 0.39248704663212436
# train_discrete_score_W_discrete_n 0.02648122263546906
# train_discrete_score_W_discrete_a 0.028493251605251842
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.025194152292326737
# test_discrete_score_W_discrete_a 0.022482665256466867
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 41
# train_discrete_score_W0_p 0.38147668393782386
# train_discrete_score_W0_n 0.023785230468662082
# train_discrete_score_W0_a  0.020246457152084774
# test_discrete_score_W0_p 0.40712742980561556
# test_discrete_score_W0_n 0.0296453050883752
# test_discrete_score_W0_a 0.0317697357719729
# train_discrete_score_W_discrete_p 0.3785621761658031
# train_discrete_score_W_discrete_n 0.018787235425677087
# train_discrete_score_W_discrete_a 0.01544726535204228
# test_discrete_score_W_discrete_p 0.4168466522678186
# test_discrete_score_W_discrete_n 0.027127930705527565
# test_discrete_score_W_discrete_a 0.028958548695616506
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 42
# train_discrete_score_W0_p 0.3898963730569948
# train_discrete_score_W0_n 0.01922320687897944
# train_discrete_score_W0_a  0.01943275485009996
# test_discrete_score_W0_p 0.4287257019438445
# test_discrete_score_W0_n 0.033875865789016815
# test_discrete_score_W0_a 0.034641055746245486
# train_discrete_score_W_discrete_p 0.3856865284974093
# train_discrete_score_W_discrete_n 0.01784100804347421
# train_discrete_score_W_discrete_a 0.017784622399723563
# test_discrete_score_W_discrete_p 0.4136069114470842
# test_discrete_score_W_discrete_n 0.025558046835038144
# test_discrete_score_W_discrete_a 0.03355960578096556
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 43
# train_discrete_score_W0_p 0.38180051813471505
# train_discrete_score_W0_n 0.022962554264122557
# train_discrete_score_W0_a  0.0241450156807135
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.031071594210976453
# test_discrete_score_W0_a 0.028807960250548683
# train_discrete_score_W_discrete_p 0.37661917098445596
# train_discrete_score_W_discrete_n 0.016401879862208
# train_discrete_score_W_discrete_a 0.015386715666769633
# test_discrete_score_W_discrete_p 0.41252699784017277
# test_discrete_score_W_discrete_n 0.029042916564584586
# test_discrete_score_W_discrete_a 0.028283335227923152
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 44
# train_discrete_score_W0_p 0.38892487046632124
# train_discrete_score_W0_n 0.01852912834414278
# train_discrete_score_W0_a  0.02272839861504912
# test_discrete_score_W0_p 0.4265658747300216
# test_discrete_score_W0_n 0.03438158667637488
# test_discrete_score_W0_a 0.04520643939179904
# train_discrete_score_W_discrete_p 0.39378238341968913
# train_discrete_score_W_discrete_n 0.018657666341810413
# train_discrete_score_W_discrete_a 0.019028162661275855
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.03181734894461054
# test_discrete_score_W_discrete_a 0.046665389160612004
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# neuron unit number: 45
# train_discrete_score_W0_p 0.3792098445595855
# train_discrete_score_W0_n 0.013792367696849382
# train_discrete_score_W0_a  0.017445856807558186
# test_discrete_score_W0_p 0.41576673866090713
# test_discrete_score_W0_n 0.031494765642076185
# test_discrete_score_W0_a 0.04424239003242327
# train_discrete_score_W_discrete_p 0.38827720207253885
# train_discrete_score_W_discrete_n 0.01888809677528935
# train_discrete_score_W_discrete_a 0.019028859430126922
# test_discrete_score_W_discrete_p 0.4244060475161987
# test_discrete_score_W_discrete_n 0.028083858489720212
# test_discrete_score_W_discrete_a 0.04158983130553667
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 46
# train_discrete_score_W0_p 0.38180051813471505
# train_discrete_score_W0_n 0.016073202656229996
# train_discrete_score_W0_a  0.01766573027709198
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.02369254804634171
# test_discrete_score_W0_a 0.034388639570811785
# train_discrete_score_W_discrete_p 0.39313471502590674
# train_discrete_score_W_discrete_n 0.024125008559735026
# train_discrete_score_W_discrete_a 0.024542733747600635
# test_discrete_score_W_discrete_p 0.42332613390928725
# test_discrete_score_W_discrete_n 0.033112680930643144
# test_discrete_score_W_discrete_a 0.03564436565662874
# neuron unit number: 47
# train_discrete_score_W0_p 0.3746761658031088
# train_discrete_score_W0_n 0.015372507194825231
# train_discrete_score_W0_a  0.015440978513103411
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.012422538949964347
# test_discrete_score_W0_a 0.01637438701941076
# train_discrete_score_W_discrete_p 0.3798575129533679
# train_discrete_score_W_discrete_n 0.017379553352125945
# train_discrete_score_W_discrete_a 0.016350684212911235
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.017328648069132906
# test_discrete_score_W_discrete_a 0.014361104683207778
# Not good ari result for discrete features  !!!!!
# neuron unit number: 48
# train_discrete_score_W0_p 0.3869818652849741
# train_discrete_score_W0_n 0.016051407427370303
# train_discrete_score_W0_a  0.019414668294061816
# test_discrete_score_W0_p 0.42764578833693306
# test_discrete_score_W0_n 0.03929600602138546
# test_discrete_score_W0_a 0.04334659089195841
# train_discrete_score_W_discrete_p 0.3866580310880829
# train_discrete_score_W_discrete_n 0.017189450225404863
# train_discrete_score_W_discrete_a 0.020239755019456396
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.029775078345091032
# test_discrete_score_W_discrete_a 0.03452621103289545
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 49
# train_discrete_score_W0_p 0.39734455958549225
# train_discrete_score_W0_n 0.02378010209522813
# train_discrete_score_W0_a  0.024873413049168448
# test_discrete_score_W0_p 0.42332613390928725
# test_discrete_score_W0_n 0.033012319042642624
# test_discrete_score_W0_a 0.03631703648314112
# train_discrete_score_W_discrete_p 0.38827720207253885
# train_discrete_score_W_discrete_n 0.021054643117514035
# train_discrete_score_W_discrete_a 0.021039899875572834
# test_discrete_score_W_discrete_p 0.43412526997840173
# test_discrete_score_W_discrete_n 0.03536385428360152
# test_discrete_score_W_discrete_a 0.0406908103442798
# neuron unit number: 50
# train_discrete_score_W0_p 0.39378238341968913
# train_discrete_score_W0_n 0.022500615056182855
# train_discrete_score_W0_a  0.025949587483360122
# test_discrete_score_W0_p 0.4265658747300216
# test_discrete_score_W0_n 0.041899219220264995
# test_discrete_score_W0_a 0.05292836388012576
# train_discrete_score_W_discrete_p 0.3860103626943005
# train_discrete_score_W_discrete_n 0.021248314857745407
# train_discrete_score_W_discrete_a 0.018249245028849875
# test_discrete_score_W_discrete_p 0.4298056155507559
# test_discrete_score_W_discrete_n 0.03706630507129842
# test_discrete_score_W_discrete_a 0.0418114066029159
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# test_discrete_score_W0_p mean 0.4014696215607098
# test_discrete_score_W_discrete_p mean 0.40015494412620906
# test_discrete_score_W0_n mean 0.020345773335558516
# test_discrete_score_W_discrete_n mean 0.018427011485068538
# test_discrete_score_W0_a mean 0.023059274623481646
# test_discrete_score_W_discrete_a mean 0.021925844629810152
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.016423  0.004189  0.000618   0.015180  0.017667
# 1  train_dis_W_dis  46.0  0.016663  0.003945  0.000582   0.015492  0.017835
# 2         combined  92.0  0.016543  0.004048  0.000422   0.015705  0.017382
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0002
# 1                           Degrees of freedom =   90.0000
# 2                                            t =   -0.2825
# 3                        Two side test p value =    0.7782
# 4                       Difference < 0 p value =    0.3891
# 5                       Difference > 0 p value =    0.6109
# 6                                    Cohen's d =   -0.0589
# 7                                    Hedge's g =   -0.0584
# 8                               Glass's delta1 =   -0.0572
# 9                             Point-Biserial r =   -0.0298
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.020346  0.011499  0.001695   0.016931  0.023761
# 1  test_dis_W_dis  46.0  0.018427  0.009989  0.001473   0.015461  0.021393
# 2        combined  92.0  0.019386  0.010755  0.001121   0.017159  0.021614
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0019
# 1                         Degrees of freedom =   90.0000
# 2                                          t =    0.8544
# 3                      Two side test p value =    0.3952
# 4                     Difference < 0 p value =    0.8024
# 5                     Difference > 0 p value =    0.1976
# 6                                  Cohen's d =    0.1781
# 7                                  Hedge's g =    0.1767
# 8                             Glass's delta1 =    0.1669
# 9                           Point-Biserial r =    0.0897
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.016570  0.004551  0.000671   0.015219  0.017921
# 1  train_dis_W_dis  46.0  0.016158  0.004293  0.000633   0.014883  0.017433
# 2         combined  92.0  0.016364  0.004404  0.000459   0.015452  0.017276
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0004
# 1                           Degrees of freedom =   90.0000
# 2                                            t =    0.4467
# 3                        Two side test p value =    0.6562
# 4                       Difference < 0 p value =    0.6719
# 5                       Difference > 0 p value =    0.3281
# 6                                    Cohen's d =    0.0931
# 7                                    Hedge's g =    0.0924
# 8                               Glass's delta1 =    0.0905
# 9                             Point-Biserial r =    0.0470
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.023059  0.012993  0.001916   0.019201  0.026918
# 1  test_dis_W_dis  46.0  0.021926  0.011921  0.001758   0.018386  0.025466
# 2        combined  92.0  0.022493  0.012413  0.001294   0.019922  0.025063
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0011
# 1                         Degrees of freedom =   90.0000
# 2                                          t =    0.4359
# 3                      Two side test p value =    0.6639
# 4                     Difference < 0 p value =    0.6680
# 5                     Difference > 0 p value =    0.3320
# 6                                  Cohen's d =    0.0909
# 7                                  Hedge's g =    0.0901
# 8                             Glass's delta1 =    0.0872
# 9                           Point-Biserial r =    0.0459
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.379653  0.007919  0.001168   0.377302  0.382005
# 1  train_dis_W_dis  46.0  0.378935  0.007597  0.001120   0.376679  0.381191
# 2         combined  92.0  0.379294  0.007725  0.000805   0.377694  0.380894
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0007
# 1                           Degrees of freedom =   90.0000
# 2                                            t =    0.4438
# 3                        Two side test p value =    0.6583
# 4                       Difference < 0 p value =    0.6709
# 5                       Difference > 0 p value =    0.3291
# 6                                    Cohen's d =    0.0925
# 7                                    Hedge's g =    0.0918
# 8                               Glass's delta1 =    0.0907
# 9                             Point-Biserial r =    0.0467
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.401470  0.016933  0.002497   0.396441  0.406498
# 1  test_dis_W_dis  46.0  0.400155  0.016939  0.002497   0.395125  0.405185
# 2        combined  92.0  0.400812  0.016856  0.001757   0.397322  0.404303
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =    0.0013
# 1                         Degrees of freedom =   90.0000
# 2                                          t =    0.3723
# 3                      Two side test p value =    0.7106
# 4                     Difference < 0 p value =    0.6447
# 5                     Difference > 0 p value =    0.3553
# 6                                  Cohen's d =    0.0776
# 7                                  Hedge's g =    0.0770
# 8                             Glass's delta1 =    0.0776
# 9                           Point-Biserial r =    0.0392

# %%
#new hash endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.36625647668393785
# train_discrete_score_W0_n 0.011473286167833448
# train_discrete_score_W0_a  0.008482637637875198
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.36139896373056996
# train_discrete_score_W_discrete_n 0.010286726177422496
# train_discrete_score_W_discrete_a 0.007108033827492081
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 6
# train_discrete_score_W0_p 0.3626943005181347
# train_discrete_score_W0_n 0.010895735032736546
# train_discrete_score_W0_a  0.010641743086525358
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.3633419689119171
# train_discrete_score_W_discrete_n 0.011464784107825636
# train_discrete_score_W_discrete_a 0.010430194361192894
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 7
# train_discrete_score_W0_p 0.36884715025906734
# train_discrete_score_W0_n 0.014364358752183247
# train_discrete_score_W0_a  0.00902618153922351
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.3694948186528497
# train_discrete_score_W_discrete_n 0.014935062441737467
# train_discrete_score_W_discrete_a 0.009807568104842467
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 8
# train_discrete_score_W0_p 0.3701424870466321
# train_discrete_score_W0_n 0.015704343337498036
# train_discrete_score_W0_a  0.010221878682778626
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.004004049759215919
# test_discrete_score_W0_a 0.007283656673940309
# train_discrete_score_W_discrete_p 0.3701424870466321
# train_discrete_score_W_discrete_n 0.015704343337498036
# train_discrete_score_W_discrete_a 0.010221878682778626
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.004004049759215919
# test_discrete_score_W_discrete_a 0.007283656673940309
# neuron unit number: 9
# train_discrete_score_W0_p 0.36722797927461137
# train_discrete_score_W0_n 0.012887887168566077
# train_discrete_score_W0_a  0.0122539025520301
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.0021406585281149226
# test_discrete_score_W0_a 0.0033310491978113294
# train_discrete_score_W_discrete_p 0.3636658031088083
# train_discrete_score_W_discrete_n 0.011808792786709458
# train_discrete_score_W_discrete_a 0.0093495352484008
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.0025641400650307867
# test_discrete_score_W_discrete_a 0.002633439117899124
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 10
# train_discrete_score_W0_p 0.3740284974093264
# train_discrete_score_W0_n 0.013395279744055053
# train_discrete_score_W0_a  0.014246633276188601
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.007460763367036186
# test_discrete_score_W0_a 0.011865507608841112
# train_discrete_score_W_discrete_p 0.37208549222797926
# train_discrete_score_W_discrete_n 0.014216723050355016
# train_discrete_score_W_discrete_a 0.0103860565282966
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.004809651620889968
# test_discrete_score_W_discrete_a 0.009609761186816041
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# train_discrete_score_W0_p 0.37726683937823835
# train_discrete_score_W0_n 0.013950388735846097
# train_discrete_score_W0_a  0.017856700207765575
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.010276806033179493
# test_discrete_score_W0_a 0.012941011785063971
# train_discrete_score_W_discrete_p 0.37305699481865284
# train_discrete_score_W_discrete_n 0.01635742766959706
# train_discrete_score_W_discrete_a 0.017863768125681752
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.006070196162346819
# test_discrete_score_W_discrete_a 0.008929037430772474
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 12
# train_discrete_score_W0_p 0.37370466321243523
# train_discrete_score_W0_n 0.010222623097822226
# train_discrete_score_W0_a  0.012882632286164418
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.00291499859716387
# test_discrete_score_W0_a 0.006465428044849577
# train_discrete_score_W_discrete_p 0.37370466321243523
# train_discrete_score_W_discrete_n 0.010349431871182532
# train_discrete_score_W_discrete_a 0.012308529105622646
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.004438142849652427
# test_discrete_score_W_discrete_a 0.010026631311997781
# neuron unit number: 13
# train_discrete_score_W0_p 0.37370466321243523
# train_discrete_score_W0_n 0.018965491471945085
# train_discrete_score_W0_a  0.015621701089308873
# test_discrete_score_W0_p 0.3855291576673866
# test_discrete_score_W0_n 0.017974524757297848
# test_discrete_score_W0_a 0.017140217228614765
# train_discrete_score_W_discrete_p 0.36917098445595853
# train_discrete_score_W_discrete_n 0.011108555922721901
# train_discrete_score_W_discrete_a 0.012619151432588056
# test_discrete_score_W_discrete_p 0.3747300215982721
# test_discrete_score_W_discrete_n 0.008161910330896272
# test_discrete_score_W_discrete_a 0.009895825040846712
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 14
# train_discrete_score_W0_p 0.37370466321243523
# train_discrete_score_W0_n 0.013109324543829258
# train_discrete_score_W0_a  0.010495979983428598
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.011276617994938893
# test_discrete_score_W0_a 0.01629990752057
# train_discrete_score_W_discrete_p 0.37338082901554404
# train_discrete_score_W_discrete_n 0.015705893192082227
# train_discrete_score_W_discrete_a 0.01429244221273081
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.012150648464906558
# test_discrete_score_W_discrete_a 0.015041621586743617
# Not good ari result for discrete features  !!!!!
# neuron unit number: 15
# train_discrete_score_W0_p 0.37791450777202074
# train_discrete_score_W0_n 0.010414846809883332
# train_discrete_score_W0_a  0.014200818457638759
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.010634905821500314
# test_discrete_score_W0_a 0.014296885707768303
# train_discrete_score_W_discrete_p 0.3701424870466321
# train_discrete_score_W_discrete_n 0.014942757266850614
# train_discrete_score_W_discrete_a 0.014409930519835896
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.013170111545997964
# test_discrete_score_W_discrete_a 0.01450697495403815
# neuron unit number: 16
# train_discrete_score_W0_p 0.3756476683937824
# train_discrete_score_W0_n 0.01258418056336054
# train_discrete_score_W0_a  0.016774301162717414
# test_discrete_score_W0_p 0.37904967602591794
# test_discrete_score_W0_n 0.01601356089831837
# test_discrete_score_W0_a 0.014503679566037504
# train_discrete_score_W_discrete_p 0.3746761658031088
# train_discrete_score_W_discrete_n 0.01705692876531114
# train_discrete_score_W_discrete_a 0.01545067976557586
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.021843146443687372
# test_discrete_score_W_discrete_a 0.015370867998865067
# neuron unit number: 17
# train_discrete_score_W0_p 0.37694300518134716
# train_discrete_score_W0_n 0.013936712607206091
# train_discrete_score_W0_a  0.01686353374448235
# test_discrete_score_W0_p 0.3898488120950324
# test_discrete_score_W0_n 0.015383492057641326
# test_discrete_score_W0_a 0.01675188335276803
# train_discrete_score_W_discrete_p 0.3759715025906736
# train_discrete_score_W_discrete_n 0.017810866540630195
# train_discrete_score_W_discrete_a 0.013635444354886395
# test_discrete_score_W_discrete_p 0.40280777537796975
# test_discrete_score_W_discrete_n 0.022633244016010336
# test_discrete_score_W_discrete_a 0.022892817552040014
# neuron unit number: 18
# train_discrete_score_W0_p 0.36755181347150256
# train_discrete_score_W0_n 0.009713970711821843
# train_discrete_score_W0_a  0.00902769890489573
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.010589496156445869
# test_discrete_score_W0_a 0.018723292890291017
# train_discrete_score_W_discrete_p 0.38277202072538863
# train_discrete_score_W_discrete_n 0.011413422818349972
# train_discrete_score_W_discrete_a 0.0164962729460868
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.017973608099448972
# test_discrete_score_W_discrete_a 0.01680743431947364
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 19
# train_discrete_score_W0_p 0.3853626943005181
# train_discrete_score_W0_n 0.018409312619543938
# train_discrete_score_W0_a  0.019816335478762107
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.014353728692615288
# test_discrete_score_W0_a 0.021657383986396828
# train_discrete_score_W_discrete_p 0.375
# train_discrete_score_W_discrete_n 0.017440151125987218
# train_discrete_score_W_discrete_a 0.01552907913721115
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.019384499676698523
# test_discrete_score_W_discrete_a 0.017576548631053537
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# train_discrete_score_W0_p 0.37823834196891193
# train_discrete_score_W0_n 0.012702044291908214
# train_discrete_score_W0_a  0.014259709604352397
# test_discrete_score_W0_p 0.38876889848812096
# test_discrete_score_W0_n 0.011733733763620463
# test_discrete_score_W0_a 0.01160969066895063
# train_discrete_score_W_discrete_p 0.3753238341968912
# train_discrete_score_W_discrete_n 0.012943642843828781
# train_discrete_score_W_discrete_a 0.013542212615324515
# test_discrete_score_W_discrete_p 0.4006479481641469
# test_discrete_score_W_discrete_n 0.016821969840689104
# test_discrete_score_W_discrete_a 0.021352393962029613
# neuron unit number: 21
# train_discrete_score_W0_p 0.3759715025906736
# train_discrete_score_W0_n 0.021235220458745145
# train_discrete_score_W0_a  0.016944878373968287
# test_discrete_score_W0_p 0.3941684665226782
# test_discrete_score_W0_n 0.010298618978773152
# test_discrete_score_W0_a 0.008704721064692009
# train_discrete_score_W_discrete_p 0.37629533678756477
# train_discrete_score_W_discrete_n 0.015635087706156525
# train_discrete_score_W_discrete_a 0.016287911933752026
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.016368915672726008
# test_discrete_score_W_discrete_a 0.021069436246551825
# Not good nmi result for discrete features !!!!!
# neuron unit number: 22
# train_discrete_score_W0_p 0.3788860103626943
# train_discrete_score_W0_n 0.01817797769293766
# train_discrete_score_W0_a  0.018731194593459576
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.026152778732780765
# test_discrete_score_W0_a 0.028045880946761942
# train_discrete_score_W_discrete_p 0.38277202072538863
# train_discrete_score_W_discrete_n 0.020779532311677278
# train_discrete_score_W_discrete_a 0.01820105661419576
# test_discrete_score_W_discrete_p 0.4114470842332613
# test_discrete_score_W_discrete_n 0.02527620120604397
# test_discrete_score_W_discrete_a 0.02795689721108366
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 23
# train_discrete_score_W0_p 0.37759067357512954
# train_discrete_score_W0_n 0.01709168639960981
# train_discrete_score_W0_a  0.01740712305830562
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.021180741636992465
# test_discrete_score_W0_a 0.02017184793711793
# train_discrete_score_W_discrete_p 0.3801813471502591
# train_discrete_score_W_discrete_n 0.011122159409870554
# train_discrete_score_W_discrete_a 0.012247558049837876
# test_discrete_score_W_discrete_p 0.4038876889848812
# test_discrete_score_W_discrete_n 0.02425846740118463
# test_discrete_score_W_discrete_a 0.026309313504983944
# neuron unit number: 24
# train_discrete_score_W0_p 0.3753238341968912
# train_discrete_score_W0_n 0.0157511351871883
# train_discrete_score_W0_a  0.016141574450078335
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.012597365007913983
# test_discrete_score_W0_a 0.01491766708470252
# train_discrete_score_W_discrete_p 0.3805051813471503
# train_discrete_score_W_discrete_n 0.012987138123121819
# train_discrete_score_W_discrete_a 0.015135311431640848
# test_discrete_score_W_discrete_p 0.3941684665226782
# test_discrete_score_W_discrete_n 0.018108182155584764
# test_discrete_score_W_discrete_a 0.01907657215766168
# Not good nmi result for discrete features !!!!!
# neuron unit number: 25
# train_discrete_score_W0_p 0.37661917098445596
# train_discrete_score_W0_n 0.015056320725075662
# train_discrete_score_W0_a  0.017886081555471924
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.019330139468636456
# test_discrete_score_W0_a 0.025703120477632513
# train_discrete_score_W_discrete_p 0.37338082901554404
# train_discrete_score_W_discrete_n 0.013796099896386043
# train_discrete_score_W_discrete_a 0.016417217123578586
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.024728679636246694
# test_discrete_score_W_discrete_a 0.02806413948712756
# Not good nmi result for discrete features !!!!!
# neuron unit number: 26
# train_discrete_score_W0_p 0.38115284974093266
# train_discrete_score_W0_n 0.018771705842682295
# train_discrete_score_W0_a  0.014305192864155311
# test_discrete_score_W0_p 0.4060475161987041
# test_discrete_score_W0_n 0.023435813687256748
# test_discrete_score_W0_a 0.023559979196726172
# train_discrete_score_W_discrete_p 0.37240932642487046
# train_discrete_score_W_discrete_n 0.01598451155676905
# train_discrete_score_W_discrete_a 0.010865717540455453
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.019811340701894407
# test_discrete_score_W_discrete_a 0.01949227699602208
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 27
# train_discrete_score_W0_p 0.37694300518134716
# train_discrete_score_W0_n 0.015035006432946082
# train_discrete_score_W0_a  0.013537537508451122
# test_discrete_score_W0_p 0.4006479481641469
# test_discrete_score_W0_n 0.023893856555492175
# test_discrete_score_W0_a 0.030583388266976777
# train_discrete_score_W_discrete_p 0.38277202072538863
# train_discrete_score_W_discrete_n 0.016683818934462833
# train_discrete_score_W_discrete_a 0.021163681247447302
# test_discrete_score_W_discrete_p 0.4017278617710583
# test_discrete_score_W_discrete_n 0.027854273546842043
# test_discrete_score_W_discrete_a 0.029938177322937555
# Not good ari result for discrete features  !!!!!
# neuron unit number: 28
# train_discrete_score_W0_p 0.39313471502590674
# train_discrete_score_W0_n 0.02312759564382806
# train_discrete_score_W0_a  0.026311608779663577
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.019019981029767177
# test_discrete_score_W0_a 0.0198540264109262
# train_discrete_score_W_discrete_p 0.38374352331606215
# train_discrete_score_W_discrete_n 0.015979296036350628
# train_discrete_score_W_discrete_a 0.014851501239564854
# test_discrete_score_W_discrete_p 0.4136069114470842
# test_discrete_score_W_discrete_n 0.028943145317303624
# test_discrete_score_W_discrete_a 0.02944516967358438
# neuron unit number: 29
# train_discrete_score_W0_p 0.37823834196891193
# train_discrete_score_W0_n 0.010085421701065562
# train_discrete_score_W0_a  0.011479531335042946
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.017506235587317637
# test_discrete_score_W0_a 0.02041586892391298
# train_discrete_score_W_discrete_p 0.3788860103626943
# train_discrete_score_W_discrete_n 0.012829566057525213
# train_discrete_score_W_discrete_a 0.015362623589970203
# test_discrete_score_W_discrete_p 0.4017278617710583
# test_discrete_score_W_discrete_n 0.027825529169079734
# test_discrete_score_W_discrete_a 0.025852974184940702
# neuron unit number: 30
# train_discrete_score_W0_p 0.38147668393782386
# train_discrete_score_W0_n 0.01808952257021313
# train_discrete_score_W0_a  0.019035723052883292
# test_discrete_score_W0_p 0.4146868250539957
# test_discrete_score_W0_n 0.03600227299160117
# test_discrete_score_W0_a 0.03979987745960377
# train_discrete_score_W_discrete_p 0.3850388601036269
# train_discrete_score_W_discrete_n 0.02130342705168707
# train_discrete_score_W_discrete_a 0.017048418083123008
# test_discrete_score_W_discrete_p 0.4103671706263499
# test_discrete_score_W_discrete_n 0.020132501208826106
# test_discrete_score_W_discrete_a 0.021289930253133662
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 31
# train_discrete_score_W0_p 0.37823834196891193
# train_discrete_score_W0_n 0.010085421701065562
# train_discrete_score_W0_a  0.011479531335042946
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.017506235587317637
# test_discrete_score_W0_a 0.02041586892391298
# train_discrete_score_W_discrete_p 0.37661917098445596
# train_discrete_score_W_discrete_n 0.01385456987566244
# train_discrete_score_W_discrete_a 0.01582213255156599
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.025332252991726846
# test_discrete_score_W_discrete_a 0.024832637532447337
# neuron unit number: 32
# train_discrete_score_W0_p 0.37629533678756477
# train_discrete_score_W0_n 0.011383456454726706
# train_discrete_score_W0_a  0.014346954774522873
# test_discrete_score_W0_p 0.4114470842332613
# test_discrete_score_W0_n 0.031270793612319076
# test_discrete_score_W0_a 0.02769785316665148
# train_discrete_score_W_discrete_p 0.3856865284974093
# train_discrete_score_W_discrete_n 0.023904004028592503
# train_discrete_score_W_discrete_a 0.022107150317738043
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.034223528921808404
# test_discrete_score_W_discrete_a 0.03307722682744161
# Not good nmi result for discrete features !!!!!
# neuron unit number: 33
# train_discrete_score_W0_p 0.3850388601036269
# train_discrete_score_W0_n 0.021622487904802378
# train_discrete_score_W0_a  0.017086984945455637
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.027738703598126153
# test_discrete_score_W0_a 0.029555917099482937
# train_discrete_score_W_discrete_p 0.38341968911917096
# train_discrete_score_W_discrete_n 0.02065211539317094
# train_discrete_score_W_discrete_a 0.01828972380923513
# test_discrete_score_W_discrete_p 0.4222462203023758
# test_discrete_score_W_discrete_n 0.02655431310427984
# test_discrete_score_W_discrete_a 0.032033512583622484
# Not good nmi result for discrete features !!!!!
# neuron unit number: 34
# train_discrete_score_W0_p 0.3792098445595855
# train_discrete_score_W0_n 0.018174758368061757
# train_discrete_score_W0_a  0.01901465468553611
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.01946389536104453
# test_discrete_score_W0_a 0.025382113073673603
# train_discrete_score_W_discrete_p 0.3805051813471503
# train_discrete_score_W_discrete_n 0.017575062865931176
# train_discrete_score_W_discrete_a 0.01614287039466605
# test_discrete_score_W_discrete_p 0.408207343412527
# test_discrete_score_W_discrete_n 0.028092838486698437
# test_discrete_score_W_discrete_a 0.03255989012389337
# Not good nmi result for discrete features !!!!!
# neuron unit number: 35
# train_discrete_score_W0_p 0.38244818652849744
# train_discrete_score_W0_n 0.01496201839256371
# train_discrete_score_W0_a  0.02026588155953714
# test_discrete_score_W0_p 0.4265658747300216
# test_discrete_score_W0_n 0.027368756066649867
# test_discrete_score_W0_a 0.04008101748050336
# train_discrete_score_W_discrete_p 0.3860103626943005
# train_discrete_score_W_discrete_n 0.022833428971538023
# train_discrete_score_W_discrete_a 0.02338289582719534
# test_discrete_score_W_discrete_p 0.41792656587473004
# test_discrete_score_W_discrete_n 0.031583062907742224
# test_discrete_score_W_discrete_a 0.036980965818459416
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 36
# train_discrete_score_W0_p 0.38471502590673573
# train_discrete_score_W0_n 0.014862773343740181
# train_discrete_score_W0_a  0.015122753897943349
# test_discrete_score_W0_p 0.4244060475161987
# test_discrete_score_W0_n 0.03155557210131339
# test_discrete_score_W0_a 0.041007162036584055
# train_discrete_score_W_discrete_p 0.37629533678756477
# train_discrete_score_W_discrete_n 0.017705942975758747
# train_discrete_score_W_discrete_a 0.017885122951015398
# test_discrete_score_W_discrete_p 0.41252699784017277
# test_discrete_score_W_discrete_n 0.01847302852784987
# test_discrete_score_W_discrete_a 0.028509700933429787
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# train_discrete_score_W0_p 0.3853626943005181
# train_discrete_score_W0_n 0.01632332038836005
# train_discrete_score_W0_a  0.016514404984821263
# test_discrete_score_W0_p 0.408207343412527
# test_discrete_score_W0_n 0.02547108456292439
# test_discrete_score_W0_a 0.028548713665160787
# train_discrete_score_W_discrete_p 0.38082901554404147
# train_discrete_score_W_discrete_n 0.01613503309256636
# train_discrete_score_W_discrete_a 0.015645961351150914
# test_discrete_score_W_discrete_p 0.4060475161987041
# test_discrete_score_W_discrete_n 0.0262164001248557
# test_discrete_score_W_discrete_a 0.027602733381592085
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 38
# train_discrete_score_W0_p 0.38406735751295334
# train_discrete_score_W0_n 0.018764767296246997
# train_discrete_score_W0_a  0.01818821289684297
# test_discrete_score_W0_p 0.40496760259179265
# test_discrete_score_W0_n 0.024758361118059468
# test_discrete_score_W0_a 0.024349801347234933
# train_discrete_score_W_discrete_p 0.390220207253886
# train_discrete_score_W_discrete_n 0.018465750065365494
# train_discrete_score_W_discrete_a 0.020636085219363488
# test_discrete_score_W_discrete_p 0.4168466522678186
# test_discrete_score_W_discrete_n 0.026525485557709973
# test_discrete_score_W_discrete_a 0.030913247991750888
# neuron unit number: 39
# train_discrete_score_W0_p 0.3866580310880829
# train_discrete_score_W0_n 0.024571636043938076
# train_discrete_score_W0_a  0.02158459962389893
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.024381092552280798
# test_discrete_score_W0_a 0.027047013938218085
# train_discrete_score_W_discrete_p 0.38244818652849744
# train_discrete_score_W_discrete_n 0.017894592115127495
# train_discrete_score_W_discrete_a 0.01920954608729512
# test_discrete_score_W_discrete_p 0.4244060475161987
# test_discrete_score_W_discrete_n 0.0347654115191532
# test_discrete_score_W_discrete_a 0.04899912918841699
# neuron unit number: 40
# train_discrete_score_W0_p 0.38180051813471505
# train_discrete_score_W0_n 0.013332798299591967
# train_discrete_score_W0_a  0.01230367593725929
# test_discrete_score_W0_p 0.40712742980561556
# test_discrete_score_W0_n 0.023258615453146385
# test_discrete_score_W0_a 0.030930918770319137
# train_discrete_score_W_discrete_p 0.38924870466321243
# train_discrete_score_W_discrete_n 0.020662235850635438
# train_discrete_score_W_discrete_a 0.021551835359144008
# test_discrete_score_W_discrete_p 0.4222462203023758
# test_discrete_score_W_discrete_n 0.028674520916588148
# test_discrete_score_W_discrete_a 0.03360986247771076
# neuron unit number: 41
# train_discrete_score_W0_p 0.3873056994818653
# train_discrete_score_W0_n 0.02163713663091939
# train_discrete_score_W0_a  0.02128808584058728
# test_discrete_score_W0_p 0.40712742980561556
# test_discrete_score_W0_n 0.02155045542870407
# test_discrete_score_W0_a 0.020970930351953618
# train_discrete_score_W_discrete_p 0.3863341968911917
# train_discrete_score_W_discrete_n 0.019364771237230093
# train_discrete_score_W_discrete_a 0.022102631192941362
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.02749388271138536
# test_discrete_score_W_discrete_a 0.029335095226557986
# neuron unit number: 42
# train_discrete_score_W0_p 0.3895725388601036
# train_discrete_score_W0_n 0.021280284155305453
# train_discrete_score_W0_a  0.019318873766626107
# test_discrete_score_W0_p 0.4136069114470842
# test_discrete_score_W0_n 0.0308737852829706
# test_discrete_score_W0_a 0.026971125420081177
# train_discrete_score_W_discrete_p 0.3866580310880829
# train_discrete_score_W_discrete_n 0.014323023833638062
# train_discrete_score_W_discrete_a 0.016504331416356682
# test_discrete_score_W_discrete_p 0.42116630669546434
# test_discrete_score_W_discrete_n 0.03382457144880645
# test_discrete_score_W_discrete_a 0.040942878833160265
# neuron unit number: 43
# train_discrete_score_W0_p 0.38374352331606215
# train_discrete_score_W0_n 0.014235478675622273
# train_discrete_score_W0_a  0.01572704159845983
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.01728786702954631
# test_discrete_score_W0_a 0.016003247978682158
# train_discrete_score_W_discrete_p 0.3898963730569948
# train_discrete_score_W_discrete_n 0.021821010970297372
# train_discrete_score_W_discrete_a 0.025017595397426883
# test_discrete_score_W_discrete_p 0.4114470842332613
# test_discrete_score_W_discrete_n 0.03169864412527124
# test_discrete_score_W_discrete_a 0.03889593473633357
# neuron unit number: 44
# train_discrete_score_W0_p 0.38341968911917096
# train_discrete_score_W0_n 0.015663866328886757
# train_discrete_score_W0_a  0.017754059164359164
# test_discrete_score_W0_p 0.42332613390928725
# test_discrete_score_W0_n 0.031882598323885625
# test_discrete_score_W0_a 0.03771649941918861
# train_discrete_score_W_discrete_p 0.3863341968911917
# train_discrete_score_W_discrete_n 0.017075147607295213
# train_discrete_score_W_discrete_a 0.017193790391292287
# test_discrete_score_W_discrete_p 0.42548596112311016
# test_discrete_score_W_discrete_n 0.03539489537214172
# test_discrete_score_W_discrete_a 0.0479040034153214
# neuron unit number: 45
# train_discrete_score_W0_p 0.38762953367875647
# train_discrete_score_W0_n 0.021649057092104497
# train_discrete_score_W0_a  0.021211678066660848
# test_discrete_score_W0_p 0.41252699784017277
# test_discrete_score_W0_n 0.025349043972865096
# test_discrete_score_W0_a 0.025465645007272587
# train_discrete_score_W_discrete_p 0.3860103626943005
# train_discrete_score_W_discrete_n 0.020291851166036098
# train_discrete_score_W_discrete_a 0.01837006733733186
# test_discrete_score_W_discrete_p 0.41252699784017277
# test_discrete_score_W_discrete_n 0.02482700927570106
# test_discrete_score_W_discrete_a 0.033481625808934753
# Not good nmi result for discrete features !!!!!
# neuron unit number: 46
# train_discrete_score_W0_p 0.39216321243523317
# train_discrete_score_W0_n 0.02047170569961331
# train_discrete_score_W0_a  0.022147913715334158
# test_discrete_score_W0_p 0.4168466522678186
# test_discrete_score_W0_n 0.0304515204078249
# test_discrete_score_W0_a 0.033314062018272715
# train_discrete_score_W_discrete_p 0.3860103626943005
# train_discrete_score_W_discrete_n 0.018635491062947086
# train_discrete_score_W_discrete_a 0.02181060984418671
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.02759720190758704
# test_discrete_score_W_discrete_a 0.03271166006581338
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 47
# train_discrete_score_W0_p 0.38180051813471505
# train_discrete_score_W0_n 0.022962554264122557
# train_discrete_score_W0_a  0.0241450156807135
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.031071594210976453
# test_discrete_score_W0_a 0.028807960250548683
# train_discrete_score_W_discrete_p 0.3801813471502591
# train_discrete_score_W_discrete_n 0.01520717894000809
# train_discrete_score_W_discrete_a 0.014219859734747953
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.03338638717449186
# test_discrete_score_W_discrete_a 0.030696779194026153
# Not good nmi result for discrete features !!!!!
# neuron unit number: 48
# train_discrete_score_W0_p 0.3869818652849741
# train_discrete_score_W0_n 0.02224651008537501
# train_discrete_score_W0_a  0.022622563560171196
# test_discrete_score_W0_p 0.4200863930885529
# test_discrete_score_W0_n 0.03555825996576836
# test_discrete_score_W0_a 0.038881147534607946
# train_discrete_score_W_discrete_p 0.38860103626943004
# train_discrete_score_W_discrete_n 0.025191174682529776
# train_discrete_score_W_discrete_a 0.0267154424488756
# test_discrete_score_W_discrete_p 0.42764578833693306
# test_discrete_score_W_discrete_n 0.038418250114438585
# test_discrete_score_W_discrete_a 0.04411914504704723
# neuron unit number: 49
# train_discrete_score_W0_p 0.3805051813471503
# train_discrete_score_W0_n 0.01777976221699187
# train_discrete_score_W0_a  0.017384477131345756
# test_discrete_score_W0_p 0.4200863930885529
# test_discrete_score_W0_n 0.023698604819091116
# test_discrete_score_W0_a 0.032469738804814546
# train_discrete_score_W_discrete_p 0.3915155440414508
# train_discrete_score_W_discrete_n 0.018802468971703797
# train_discrete_score_W_discrete_a 0.020071359849724968
# test_discrete_score_W_discrete_p 0.43412526997840173
# test_discrete_score_W_discrete_n 0.048269318648569655
# test_discrete_score_W_discrete_a 0.04553772808926385
# neuron unit number: 50
# train_discrete_score_W0_p 0.39669689119170987
# train_discrete_score_W0_n 0.028249676285392447
# train_discrete_score_W0_a  0.028365954285919714
# test_discrete_score_W0_p 0.4200863930885529
# test_discrete_score_W0_n 0.025129040558902103
# test_discrete_score_W0_a 0.029044854154313383
# train_discrete_score_W_discrete_p 0.38406735751295334
# train_discrete_score_W_discrete_n 0.017977117004295065
# train_discrete_score_W_discrete_a 0.016474377412184285
# test_discrete_score_W_discrete_p 0.4168466522678186
# test_discrete_score_W_discrete_n 0.032672700065756476
# test_discrete_score_W_discrete_a 0.03554814695637303
# Not good nmi result for discrete features !!!!!
# test_discrete_score_W0_p mean 0.3998967039158607
# test_discrete_score_W_discrete_p mean 0.4013052868813972
# test_discrete_score_W0_n mean 0.018908717828637758
# test_discrete_score_W_discrete_n mean 0.021768614321603586
# test_discrete_score_W0_a mean 0.02150625135744419
# test_discrete_score_W_discrete_a mean 0.02453725654426391
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.016422  0.004441  0.000655   0.015103  0.017741
# 1  train_dis_W_dis  46.0  0.016500  0.003654  0.000539   0.015415  0.017585
# 2         combined  92.0  0.016461  0.004044  0.000422   0.015624  0.017299
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0001
# 1                           Degrees of freedom =   90.0000
# 2                                            t =   -0.0925
# 3                        Two side test p value =    0.9265
# 4                       Difference < 0 p value =    0.4633
# 5                       Difference > 0 p value =    0.5367
# 6                                    Cohen's d =   -0.0193
# 7                                    Hedge's g =   -0.0191
# 8                               Glass's delta1 =   -0.0177
# 9                             Point-Biserial r =   -0.0097
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.018909  0.009901  0.001460   0.015968  0.021849
# 1  test_dis_W_dis  46.0  0.021769  0.011426  0.001685   0.018376  0.025162
# 2        combined  92.0  0.020339  0.010729  0.001119   0.018117  0.022561
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0029
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -1.2829
# 3                      Two side test p value =    0.2028
# 4                     Difference < 0 p value =    0.1014
# 5                     Difference > 0 p value =    0.8986
# 6                                  Cohen's d =   -0.2675
# 7                                  Hedge's g =   -0.2653
# 8                             Glass's delta1 =   -0.2888
# 9                           Point-Biserial r =   -0.1340
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.016529  0.004519  0.000666   0.015187  0.017871
# 1  train_dis_W_dis  46.0  0.016308  0.004303  0.000634   0.015031  0.017586
# 2         combined  92.0  0.016419  0.004390  0.000458   0.015510  0.017328
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0002
# 1                           Degrees of freedom =   90.0000
# 2                                            t =    0.2396
# 3                        Two side test p value =    0.8112
# 4                       Difference < 0 p value =    0.5944
# 5                       Difference > 0 p value =    0.4056
# 6                                    Cohen's d =    0.0500
# 7                                    Hedge's g =    0.0495
# 8                               Glass's delta1 =    0.0488
# 9                             Point-Biserial r =    0.0252
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.021506  0.010868  0.001602   0.018279  0.024734
# 1  test_dis_W_dis  46.0  0.024537  0.012737  0.001878   0.020755  0.028320
# 2        combined  92.0  0.023022  0.011873  0.001238   0.020563  0.025481
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0030
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -1.2278
# 3                      Two side test p value =    0.2227
# 4                     Difference < 0 p value =    0.1114
# 5                     Difference > 0 p value =    0.8886
# 6                                  Cohen's d =   -0.2560
# 7                                  Hedge's g =   -0.2539
# 8                             Glass's delta1 =   -0.2789
# 9                           Point-Biserial r =   -0.1283
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  46.0  0.379527  0.007244  0.001068   0.377376  0.381678
# 1  train_dis_W_dis  46.0  0.379048  0.007536  0.001111   0.376810  0.381286
# 2         combined  92.0  0.379287  0.007354  0.000767   0.377764  0.380810
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    0.0005
# 1                           Degrees of freedom =   90.0000
# 2                                            t =    0.3106
# 3                        Two side test p value =    0.7568
# 4                       Difference < 0 p value =    0.6216
# 5                       Difference > 0 p value =    0.3784
# 6                                    Cohen's d =    0.0648
# 7                                    Hedge's g =    0.0642
# 8                               Glass's delta1 =    0.0661
# 9                             Point-Biserial r =    0.0327
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  46.0  0.399897  0.015621  0.002303   0.395258  0.404536
# 1  test_dis_W_dis  46.0  0.401305  0.016903  0.002492   0.396286  0.406325
# 2        combined  92.0  0.400601  0.016201  0.001689   0.397246  0.403956
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0014
# 1                         Degrees of freedom =   90.0000
# 2                                          t =   -0.4151
# 3                      Two side test p value =    0.6791
# 4                     Difference < 0 p value =    0.3395
# 5                     Difference > 0 p value =    0.6605
# 6                                  Cohen's d =   -0.0865
# 7                                  Hedge's g =   -0.0858
# 8                             Glass's delta1 =   -0.0902
# 9                           Point-Biserial r =   -0.0437

# %%
#new sum endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 5
# train_discrete_score_W0_p 0.36625647668393785
# train_discrete_score_W0_n 0.011473286167833448
# train_discrete_score_W0_a  0.008482637637875198
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.36139896373056996
# train_discrete_score_W_discrete_n 0.010286726177422496
# train_discrete_score_W_discrete_a 0.007108033827492081
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 6
# train_discrete_score_W0_p 0.3626943005181347
# train_discrete_score_W0_n 0.010895735032736546
# train_discrete_score_W0_a  0.010641743086525358
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.3633419689119171
# train_discrete_score_W_discrete_n 0.011464784107825636
# train_discrete_score_W_discrete_a 0.010430194361192894
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 7
# train_discrete_score_W0_p 0.36884715025906734
# train_discrete_score_W0_n 0.014364358752183247
# train_discrete_score_W0_a  0.00902618153922351
# test_discrete_score_W0_p 0.37257019438444927
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.3694948186528497
# train_discrete_score_W_discrete_n 0.014935062441737467
# train_discrete_score_W_discrete_a 0.009807568104842467
# test_discrete_score_W_discrete_p 0.37257019438444927
# test_discrete_score_W_discrete_n 0.0
# test_discrete_score_W_discrete_a 0.0
# neuron unit number: 8
# train_discrete_score_W0_p 0.3701424870466321
# train_discrete_score_W0_n 0.015704343337498036
# train_discrete_score_W0_a  0.010221878682778626
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.004004049759215919
# test_discrete_score_W0_a 0.007283656673940309
# train_discrete_score_W_discrete_p 0.3701424870466321
# train_discrete_score_W_discrete_n 0.015704343337498036
# train_discrete_score_W_discrete_a 0.010221878682778626
# test_discrete_score_W_discrete_p 0.3801295896328294
# test_discrete_score_W_discrete_n 0.004004049759215919
# test_discrete_score_W_discrete_a 0.007283656673940309
# neuron unit number: 9
# train_discrete_score_W0_p 0.36722797927461137
# train_discrete_score_W0_n 0.012887887168566077
# train_discrete_score_W0_a  0.0122539025520301
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.0021406585281149226
# test_discrete_score_W0_a 0.0033310491978113294
# train_discrete_score_W_discrete_p 0.3636658031088083
# train_discrete_score_W_discrete_n 0.011808792786709458
# train_discrete_score_W_discrete_a 0.0093495352484008
# test_discrete_score_W_discrete_p 0.37365010799136067
# test_discrete_score_W_discrete_n 0.0025641400650307867
# test_discrete_score_W_discrete_a 0.002633439117899124
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 10
# train_discrete_score_W0_p 0.3740284974093264
# train_discrete_score_W0_n 0.013395279744055053
# train_discrete_score_W0_a  0.014246633276188601
# test_discrete_score_W0_p 0.3876889848812095
# test_discrete_score_W0_n 0.007460763367036186
# test_discrete_score_W0_a 0.011865507608841112
# train_discrete_score_W_discrete_p 0.37208549222797926
# train_discrete_score_W_discrete_n 0.014216723050355016
# train_discrete_score_W_discrete_a 0.0103860565282966
# test_discrete_score_W_discrete_p 0.3779697624190065
# test_discrete_score_W_discrete_n 0.004809651620889968
# test_discrete_score_W_discrete_a 0.009609761186816041
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 11
# train_discrete_score_W0_p 0.3759715025906736
# train_discrete_score_W0_n 0.009114885259776155
# train_discrete_score_W0_a  0.013555558083464295
# test_discrete_score_W0_p 0.3747300215982721
# test_discrete_score_W0_n 0.001719927747284585
# test_discrete_score_W0_a 0.0007987544137205614
# train_discrete_score_W_discrete_p 0.37305699481865284
# train_discrete_score_W_discrete_n 0.01635742766959706
# train_discrete_score_W_discrete_a 0.017863768125681752
# test_discrete_score_W_discrete_p 0.38120950323974084
# test_discrete_score_W_discrete_n 0.006070196162346819
# test_discrete_score_W_discrete_a 0.008929037430772474
# neuron unit number: 12
# train_discrete_score_W0_p 0.37370466321243523
# train_discrete_score_W0_n 0.010222623097822226
# train_discrete_score_W0_a  0.012882632286164418
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.00291499859716387
# test_discrete_score_W0_a 0.006465428044849577
# train_discrete_score_W_discrete_p 0.37370466321243523
# train_discrete_score_W_discrete_n 0.010349431871182532
# train_discrete_score_W_discrete_a 0.012308529105622646
# test_discrete_score_W_discrete_p 0.38228941684665224
# test_discrete_score_W_discrete_n 0.004438142849652427
# test_discrete_score_W_discrete_a 0.010026631311997781
# neuron unit number: 13
# train_discrete_score_W0_p 0.3704663212435233
# train_discrete_score_W0_n 0.012111306199924208
# train_discrete_score_W0_a  0.005246691892831803
# test_discrete_score_W0_p 0.3801295896328294
# test_discrete_score_W0_n 0.004318963931871193
# test_discrete_score_W0_a 0.005684408212864518
# train_discrete_score_W_discrete_p 0.3714378238341969
# train_discrete_score_W_discrete_n 0.020717261374447193
# train_discrete_score_W_discrete_a 0.017749269527120616
# test_discrete_score_W_discrete_p 0.38660907127429806
# test_discrete_score_W_discrete_n 0.018993731464375236
# test_discrete_score_W_discrete_a 0.013819621498674746
# neuron unit number: 14
# train_discrete_score_W0_p 0.36852331606217614
# train_discrete_score_W0_n 0.014478151334361802
# train_discrete_score_W0_a  0.014720078295945621
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.006824969544112294
# test_discrete_score_W0_a 0.012038131694001662
# train_discrete_score_W_discrete_p 0.37338082901554404
# train_discrete_score_W_discrete_n 0.015834683380398965
# train_discrete_score_W_discrete_a 0.011265674063162246
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.012960607025943613
# test_discrete_score_W_discrete_a 0.015596195122484308
# neuron unit number: 15
# train_discrete_score_W0_p 0.375
# train_discrete_score_W0_n 0.01216943186147666
# train_discrete_score_W0_a  0.014571025916310579
# test_discrete_score_W0_p 0.38876889848812096
# test_discrete_score_W0_n 0.009360339440518351
# test_discrete_score_W0_a 0.01631586119046575
# train_discrete_score_W_discrete_p 0.3740284974093264
# train_discrete_score_W_discrete_n 0.013103855256041061
# train_discrete_score_W_discrete_a 0.01144320986917146
# test_discrete_score_W_discrete_p 0.3758099352051836
# test_discrete_score_W_discrete_n 0.01179609537381309
# test_discrete_score_W_discrete_a 0.014729008283789608
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 16
# train_discrete_score_W0_p 0.37273316062176165
# train_discrete_score_W0_n 0.01724576774544024
# train_discrete_score_W0_a  0.01565769231475262
# test_discrete_score_W0_p 0.3779697624190065
# test_discrete_score_W0_n 0.021105007325983895
# test_discrete_score_W0_a 0.015250722529877922
# train_discrete_score_W_discrete_p 0.3746761658031088
# train_discrete_score_W_discrete_n 0.01815934101936171
# train_discrete_score_W_discrete_a 0.0163565274671486
# test_discrete_score_W_discrete_p 0.3833693304535637
# test_discrete_score_W_discrete_n 0.02705559436482345
# test_discrete_score_W_discrete_a 0.01913492846097685
# neuron unit number: 17
# train_discrete_score_W0_p 0.37208549222797926
# train_discrete_score_W0_n 0.007020756864676798
# train_discrete_score_W0_a  0.008136928072639611
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.022267138539956256
# test_discrete_score_W0_a 0.013039913204633663
# train_discrete_score_W_discrete_p 0.3788860103626943
# train_discrete_score_W_discrete_n 0.01623223689204453
# train_discrete_score_W_discrete_a 0.017842636819606888
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.015217677520980015
# test_discrete_score_W_discrete_a 0.016808356986029654
# Not good nmi result for discrete features !!!!!
# neuron unit number: 18
# train_discrete_score_W0_p 0.375
# train_discrete_score_W0_n 0.010155861340761534
# train_discrete_score_W0_a  0.005689867814938
# test_discrete_score_W0_p 0.38660907127429806
# test_discrete_score_W0_n 0.009738868196302944
# test_discrete_score_W0_a -0.0029178276739581736
# train_discrete_score_W_discrete_p 0.38115284974093266
# train_discrete_score_W_discrete_n 0.017252185510110762
# train_discrete_score_W_discrete_a 0.01737856222961847
# test_discrete_score_W_discrete_p 0.38444924406047515
# test_discrete_score_W_discrete_n 0.011366932965861647
# test_discrete_score_W_discrete_a 0.007440503821798686
# Not good nmi result for discrete features !!!!!
# neuron unit number: 19
# train_discrete_score_W0_p 0.3853626943005181
# train_discrete_score_W0_n 0.018409312619543938
# train_discrete_score_W0_a  0.019816335478762107
# test_discrete_score_W0_p 0.3963282937365011
# test_discrete_score_W0_n 0.014353728692615288
# test_discrete_score_W0_a 0.021657383986396828
# train_discrete_score_W_discrete_p 0.375
# train_discrete_score_W_discrete_n 0.017440151125987218
# train_discrete_score_W_discrete_a 0.01552907913721115
# test_discrete_score_W_discrete_p 0.39200863930885527
# test_discrete_score_W_discrete_n 0.019384499676698523
# test_discrete_score_W_discrete_a 0.017576548631053537
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 20
# train_discrete_score_W0_p 0.37823834196891193
# train_discrete_score_W0_n 0.01056952520958127
# train_discrete_score_W0_a  0.018378514336418884
# test_discrete_score_W0_p 0.3930885529157667
# test_discrete_score_W0_n 0.024580021058188063
# test_discrete_score_W0_a 0.02478191280916783
# train_discrete_score_W_discrete_p 0.37629533678756477
# train_discrete_score_W_discrete_n 0.011995309310286867
# train_discrete_score_W_discrete_a 0.016505260772217985
# test_discrete_score_W_discrete_p 0.3898488120950324
# test_discrete_score_W_discrete_n 0.017651186561391825
# test_discrete_score_W_discrete_a 0.01594749515003186
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 21
# train_discrete_score_W0_p 0.3743523316062176
# train_discrete_score_W0_n 0.011805422208846594
# train_discrete_score_W0_a  0.018344144152263576
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.021196536141604612
# test_discrete_score_W0_a 0.02094522781269747
# train_discrete_score_W_discrete_p 0.38244818652849744
# train_discrete_score_W_discrete_n 0.014372925871568758
# train_discrete_score_W_discrete_a 0.015172875772375714
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.014188461203596594
# test_discrete_score_W_discrete_a 0.01817346032922399
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 22
# train_discrete_score_W0_p 0.3785621761658031
# train_discrete_score_W0_n 0.01107349142400656
# train_discrete_score_W0_a  0.015246043672094945
# test_discrete_score_W0_p 0.39092872570194387
# test_discrete_score_W0_n 0.015150511660032362
# test_discrete_score_W0_a 0.01418345737566477
# train_discrete_score_W_discrete_p 0.37759067357512954
# train_discrete_score_W_discrete_n 0.015519511277558068
# train_discrete_score_W_discrete_a 0.015380022498711598
# test_discrete_score_W_discrete_p 0.4017278617710583
# test_discrete_score_W_discrete_n 0.01823963954548749
# test_discrete_score_W_discrete_a 0.023730704815924205
# neuron unit number: 23
# train_discrete_score_W0_p 0.37726683937823835
# train_discrete_score_W0_n 0.017620399097246445
# train_discrete_score_W0_a  0.016307158292540775
# test_discrete_score_W0_p 0.4038876889848812
# test_discrete_score_W0_n 0.023122289860746412
# test_discrete_score_W0_a 0.025693865998861795
# train_discrete_score_W_discrete_p 0.37694300518134716
# train_discrete_score_W_discrete_n 0.014293071023802163
# train_discrete_score_W_discrete_a 0.015437387412788611
# test_discrete_score_W_discrete_p 0.398488120950324
# test_discrete_score_W_discrete_n 0.028099769858014663
# test_discrete_score_W_discrete_a 0.029610887138683702
# Not good nmi result for discrete features !!!!!
# neuron unit number: 24
# train_discrete_score_W0_p 0.37759067357512954
# train_discrete_score_W0_n 0.015198076725521032
# train_discrete_score_W0_a  0.014456042821697945
# test_discrete_score_W0_p 0.39956803455723544
# test_discrete_score_W0_n 0.024761751616676674
# test_discrete_score_W0_a 0.025626617997393828
# train_discrete_score_W_discrete_p 0.3753238341968912
# train_discrete_score_W_discrete_n 0.02171296500453306
# train_discrete_score_W_discrete_a 0.01980473199659312
# test_discrete_score_W_discrete_p 0.4017278617710583
# test_discrete_score_W_discrete_n 0.017527504508040914
# test_discrete_score_W_discrete_a 0.017413017957835376
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 25
# train_discrete_score_W0_p 0.37823834196891193
# train_discrete_score_W0_n 0.013036950644990055
# train_discrete_score_W0_a  0.013984004540764974
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.026676962042231953
# test_discrete_score_W0_a 0.028570562005527902
# train_discrete_score_W_discrete_p 0.38762953367875647
# train_discrete_score_W_discrete_n 0.022032026923886488
# train_discrete_score_W_discrete_a 0.019914520909633852
# test_discrete_score_W_discrete_p 0.39740820734341253
# test_discrete_score_W_discrete_n 0.022862035200413397
# test_discrete_score_W_discrete_a 0.021395013266112574
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 26
# train_discrete_score_W0_p 0.3788860103626943
# train_discrete_score_W0_n 0.01621620804810763
# train_discrete_score_W0_a  0.017478618078661693
# test_discrete_score_W0_p 0.40280777537796975
# test_discrete_score_W0_n 0.024970827832209764
# test_discrete_score_W0_a 0.028981371736092377
# train_discrete_score_W_discrete_p 0.3746761658031088
# train_discrete_score_W_discrete_n 0.019127680005611332
# train_discrete_score_W_discrete_a 0.014783930974984339
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.029808442356278456
# test_discrete_score_W_discrete_a 0.02753724227294623
# Not good ari result for discrete features  !!!!!
# neuron unit number: 27
# train_discrete_score_W0_p 0.37823834196891193
# train_discrete_score_W0_n 0.018503762011748148
# train_discrete_score_W0_a  0.01128158460980982
# test_discrete_score_W0_p 0.40928725701943847
# test_discrete_score_W0_n 0.027488286767780985
# test_discrete_score_W0_a 0.028445798602679408
# train_discrete_score_W_discrete_p 0.38439119170984454
# train_discrete_score_W_discrete_n 0.015308074981559835
# train_discrete_score_W_discrete_a 0.017513437380996307
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.01847362849626686
# test_discrete_score_W_discrete_a 0.01929131449833291
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 28
# train_discrete_score_W0_p 0.3805051813471503
# train_discrete_score_W0_n 0.02040775352834281
# train_discrete_score_W0_a  0.020303875229065224
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.01261584753595525
# test_discrete_score_W0_a 0.01776080800072506
# train_discrete_score_W_discrete_p 0.38827720207253885
# train_discrete_score_W_discrete_n 0.02092027590429703
# train_discrete_score_W_discrete_a 0.022006413191658344
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.01975535989610901
# test_discrete_score_W_discrete_a 0.017441437195894697
# Not good ari result for discrete features  !!!!!
# neuron unit number: 29
# train_discrete_score_W0_p 0.3759715025906736
# train_discrete_score_W0_n 0.017678125690274663
# train_discrete_score_W0_a  0.01570987737717368
# test_discrete_score_W0_p 0.4017278617710583
# test_discrete_score_W0_n 0.025674145658815047
# test_discrete_score_W0_a 0.023763517345874473
# train_discrete_score_W_discrete_p 0.3792098445595855
# train_discrete_score_W_discrete_n 0.01872909710229054
# train_discrete_score_W_discrete_a 0.017992120973446973
# test_discrete_score_W_discrete_p 0.40928725701943847
# test_discrete_score_W_discrete_n 0.024503991825926982
# test_discrete_score_W_discrete_a 0.02666752087611094
# Not good nmi result for discrete features !!!!!
# neuron unit number: 30
# train_discrete_score_W0_p 0.3740284974093264
# train_discrete_score_W0_n 0.01236620381309295
# train_discrete_score_W0_a  0.014054775183101723
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.029389182039996378
# test_discrete_score_W0_a 0.03550552032102231
# train_discrete_score_W_discrete_p 0.3873056994818653
# train_discrete_score_W_discrete_n 0.017554117217891768
# train_discrete_score_W_discrete_a 0.019555896434910663
# test_discrete_score_W_discrete_p 0.40712742980561556
# test_discrete_score_W_discrete_n 0.024033272767740265
# test_discrete_score_W_discrete_a 0.02612072396372641
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 31
# train_discrete_score_W0_p 0.37759067357512954
# train_discrete_score_W0_n 0.01709168639960981
# train_discrete_score_W0_a  0.01740712305830562
# test_discrete_score_W0_p 0.39200863930885527
# test_discrete_score_W0_n 0.021180741636992465
# test_discrete_score_W0_a 0.02017184793711793
# train_discrete_score_W_discrete_p 0.3853626943005181
# train_discrete_score_W_discrete_n 0.018475724452288896
# train_discrete_score_W_discrete_a 0.019318021672497084
# test_discrete_score_W_discrete_p 0.3952483801295896
# test_discrete_score_W_discrete_n 0.020233615195224562
# test_discrete_score_W_discrete_a 0.021835200421627985
# Not good nmi result for discrete features !!!!!
# neuron unit number: 32
# train_discrete_score_W0_p 0.38827720207253885
# train_discrete_score_W0_n 0.02007275057244485
# train_discrete_score_W0_a  0.022623295684710058
# test_discrete_score_W0_p 0.3952483801295896
# test_discrete_score_W0_n 0.022244846993169747
# test_discrete_score_W0_a 0.02803162526236264
# train_discrete_score_W_discrete_p 0.3856865284974093
# train_discrete_score_W_discrete_n 0.01945660233254591
# train_discrete_score_W_discrete_a 0.016984805342391666
# test_discrete_score_W_discrete_p 0.39956803455723544
# test_discrete_score_W_discrete_n 0.018678807804580852
# test_discrete_score_W_discrete_a 0.02350277417503524
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 33
# train_discrete_score_W0_p 0.3860103626943005
# train_discrete_score_W0_n 0.020011452179900982
# train_discrete_score_W0_a  0.018054511188157655
# test_discrete_score_W0_p 0.41792656587473004
# test_discrete_score_W0_n 0.03290767433589995
# test_discrete_score_W0_a 0.03985833009306197
# train_discrete_score_W_discrete_p 0.38374352331606215
# train_discrete_score_W_discrete_n 0.020709685568660815
# train_discrete_score_W_discrete_a 0.018461982028207768
# test_discrete_score_W_discrete_p 0.42332613390928725
# test_discrete_score_W_discrete_n 0.02711042434648931
# test_discrete_score_W_discrete_a 0.0328822703481753
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 34
# train_discrete_score_W0_p 0.38439119170984454
# train_discrete_score_W0_n 0.01635618702330483
# train_discrete_score_W0_a  0.015666790335643065
# test_discrete_score_W0_p 0.4190064794816415
# test_discrete_score_W0_n 0.029419454566940898
# test_discrete_score_W0_a 0.030227725760919474
# train_discrete_score_W_discrete_p 0.3798575129533679
# train_discrete_score_W_discrete_n 0.016964549109112367
# train_discrete_score_W_discrete_a 0.018055741779680178
# test_discrete_score_W_discrete_p 0.41252699784017277
# test_discrete_score_W_discrete_n 0.03232859689933823
# test_discrete_score_W_discrete_a 0.049899709023685596
# Not good nmi result for discrete features !!!!!
# neuron unit number: 35
# train_discrete_score_W0_p 0.3863341968911917
# train_discrete_score_W0_n 0.021714763541954986
# train_discrete_score_W0_a  0.023213437695711908
# test_discrete_score_W0_p 0.42548596112311016
# test_discrete_score_W0_n 0.031419092410945086
# test_discrete_score_W0_a 0.04030424334356525
# train_discrete_score_W_discrete_p 0.38115284974093266
# train_discrete_score_W_discrete_n 0.015600742314648348
# train_discrete_score_W_discrete_a 0.011149681470254632
# test_discrete_score_W_discrete_p 0.40496760259179265
# test_discrete_score_W_discrete_n 0.022902432966484927
# test_discrete_score_W_discrete_a 0.0267025202441527
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 36
# train_discrete_score_W0_p 0.3915155440414508
# train_discrete_score_W0_n 0.024212538998849387
# train_discrete_score_W0_a  0.02122897170048638
# test_discrete_score_W0_p 0.4200863930885529
# test_discrete_score_W0_n 0.03263551038312014
# test_discrete_score_W0_a 0.037782233134400295
# train_discrete_score_W_discrete_p 0.3801813471502591
# train_discrete_score_W_discrete_n 0.015565293175617025
# train_discrete_score_W_discrete_a 0.014883259544058806
# test_discrete_score_W_discrete_p 0.4146868250539957
# test_discrete_score_W_discrete_n 0.028702742137451335
# test_discrete_score_W_discrete_a 0.03262435156653162
# Not good nmi result for discrete features !!!!!
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# neuron unit number: 37
# train_discrete_score_W0_p 0.3853626943005181
# train_discrete_score_W0_n 0.016697082254003962
# train_discrete_score_W0_a  0.015904664342333737
# test_discrete_score_W0_p 0.39740820734341253
# test_discrete_score_W0_n 0.015575921638761502
# test_discrete_score_W0_a 0.01617709754557875

# %%
 #new baseN endocing
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 5
best_num = 48
interval = 1




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
