# %%
import pandas as pd
import numpy as np
import newSom
import optimizeW_Kfolder_CM
import dataset_read

# %%
dataread = dataset_read.DATAREAD()

# %%
csv_training = pd.read_csv("Crowdsourced Mapping/training.csv")
csv_test = pd.read_csv("Crowdsourced Mapping/testing.csv")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_training,"class")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_test,"class")

# %%
som = newSom.SOM(m=6, n=4, dim=28)

# %%
optimize_W1 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =20,subset_percentage = 0.1)
optimize_W1.runOptimize()
# Out:
# k number :2
#
# validate_score_W1_average : 0.8993898793550446
# validate_score_W2_average : 0.9091566335444373
# test_score_W1_average : 0.6983333333333334
# test_score_W2_average : 0.7416666666666667
# k number :3
#
# validate_score_W1_average : 0.9047889995258416
# validate_score_W2_average : 0.8264580369843527
# test_score_W1_average : 0.5288888888888889
# test_score_W2_average : 0.4822222222222223
# k number :4
#
# validate_score_W1_average : 0.909076931642213
# validate_score_W2_average : 0.9083214791490077
# test_score_W1_average : 0.6141666666666666
# test_score_W2_average : 0.63
# k number :5
#
# validate_score_W1_average : 0.8648648648648647
# validate_score_W2_average : 0.8939781887150309
# test_score_W1_average : 0.6726666666666667
# test_score_W2_average : 0.6093333333333334
# k number :6
#
# validate_score_W1_average : 0.9265006715647838
# validate_score_W2_average : 0.9487914855556916
# test_score_W1_average : 0.616111111111111
# ...

# %%
optimize_W2 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =15,subset_percentage = 0.5)
optimize_W2.runOptimize()
# Out:
# k number :2
#
# validate_score_W1_average : 0.736105239651018
# validate_score_W2_average : 0.7112617330478197
# test_score_W1_average : 0.5433333333333333
# test_score_W2_average : 0.5966666666666667
# k number :3
#
# validate_score_W1_average : 0.8527264106211474
# validate_score_W2_average : 0.914651493598862
# test_score_W1_average : 0.5366666666666666
# test_score_W2_average : 0.7422222222222222
# k number :4
#
# validate_score_W1_average : 0.8654569500334621
# validate_score_W2_average : 0.9262363310033531
# test_score_W1_average : 0.5216666666666666
# test_score_W2_average : 0.6875
# k number :5
#
# validate_score_W1_average : 0.880606922712186
# validate_score_W2_average : 0.8618302513039355
# test_score_W1_average : 0.6293333333333333
# test_score_W2_average : 0.5720000000000001
# k number :6
#
# validate_score_W1_average : 0.9016583322703552
# validate_score_W2_average : 0.8987207354557069
# test_score_W1_average : 0.5833333333333334
# ...

# %%
optimize_W3 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =5,subset_percentage = 0.2)
optimize_W3.runOptimize()
# Out:
# validate_score_W1_average : 0.9184447605500237
# validate_score_W2_average : 0.8542437174016122
# test_score_W1_average : 0.6353333333333333
# test_score_W2_average : 0.64

# %%
optimize_W3 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =3,subset_percentage = 0.1)
optimize_W3.runOptimize()
# Out:
# validate_score_W1_average : 0.9035561877667141
# validate_score_W2_average : 0.912185870080607
# test_score_W1_average : 0.6433333333333334
# test_score_W2_average : 0.6777777777777777

# %%
optimize_W4 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =5,subset_percentage = 0.8)
optimize_W4.runOptimize()
# Out:
# validate_score_W1_average : 0.9209103840682789
# validate_score_W2_average : 0.9216690374585111
# test_score_W1_average : 0.6166666666666667
# test_score_W2_average : 0.6393333333333333

# %%
optimize_W5 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =5,subset_percentage = 0.5)
optimize_W5.runOptimize()
# Out:
# validate_score_W1_average : 0.9326695116168799
# validate_score_W2_average : 0.8989094357515409
# test_score_W1_average : 0.6293333333333334
# test_score_W2_average : 0.5846666666666667

# %%
optimize_W6 = optimizeW_Kfolder_CM.OptimizeW(som,csv_training,Y = csv_test,classNum =6,k_folder_num =5,subset_percentage = 0.2)
optimize_W6.runOptimize()
# Out:
# validate_score_W1_average : 0.9339971550497866
# validate_score_W2_average : 0.9144618302513038
# test_score_W1_average : 0.666
# test_score_W2_average : 0.658
