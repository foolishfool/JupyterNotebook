# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# self.continuous_feature_num 1
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
#Randmom Forest
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5



features_chosen = [0,1,2,3,4,7,8,9]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
# Out:
# Neuron/Cluster number: 2
# accuracy_score_orignial 0.44816053511705684
# recall_score_original 0.44934669769106855
# precision_score_original 0.44632527264106214
# f1_score_original 0.4409314975352711
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5193305888670127
# precision_score_sog 0.570889399409255
# f1_score_sog 0.4103366201972118
# Not good accuracy result !!!!!
# Neuron/Cluster number: 7
# accuracy_score_orignial 0.47157190635451507
# recall_score_original 0.472189905136925
# precision_score_original 0.4717602689930934
# f1_score_original 0.4698581560283687
# accuracy_score_sog 0.48494983277591974
# recall_score_sog 0.48664310005369604
# precision_score_sog 0.4849242424242424
# f1_score_sog 0.470735632183908
# Neuron/Cluster number: 12
# accuracy_score_orignial 0.4983277591973244
# recall_score_original 0.4985457311616252
# precision_score_original 0.4985431235431236
# f1_score_original 0.49818743286788403
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5055709683193127
# precision_score_sog 0.5056390977443609
# f1_score_sog 0.5037678299093926
# Neuron/Cluster number: 17
# accuracy_score_orignial 0.49498327759197325
# recall_score_original 0.49523447288347955
# precision_score_original 0.49522292993630573
# f1_score_original 0.49477983550607063
# accuracy_score_sog 0.5083612040133779
# recall_score_sog 0.5086137461965277
# precision_score_sog 0.5086346102090249
# f1_score_sog 0.5081631511218038
# Neuron/Cluster number: 22
# accuracy_score_orignial 0.5050167224080268
# recall_score_original 0.5047655271165206
# precision_score_original 0.5047770700636942
# f1_score_original 0.5045678459471563
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5125962054770001
# precision_score_sog 0.5130035107169254
# f1_score_sog 0.5082680003604578
# Neuron/Cluster number: 27
# accuracy_score_orignial 0.5016722408026756
# recall_score_original 0.5019912296402362
# precision_score_original 0.5019991015274035
# f1_score_original 0.5013152445235456
# accuracy_score_sog 0.5183946488294314
# recall_score_sog 0.5186817612314301
# precision_score_sog 0.5187404614417811
# f1_score_sog 0.5181305398871878
# Neuron/Cluster number: 32
# accuracy_score_orignial 0.48494983277591974
# recall_score_original 0.4845623769464829
# precision_score_original 0.484472049689441
# f1_score_original 0.483974358974359
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5057052085197781
# precision_score_sog 0.5058139534883721
# f1_score_sog 0.5030098831985624
# Neuron/Cluster number: 37
# accuracy_score_orignial 0.5016722408026756
# recall_score_original 0.5021254698407016
# precision_score_original 0.502142728256947
# f1_score_original 0.5008682792386032
# accuracy_score_sog 0.5618729096989966
# recall_score_sog 0.5624664399498837
# precision_score_sog 0.5633278896751951
# f1_score_sog 0.5606147288126087
# Neuron/Cluster number: 42
# accuracy_score_orignial 0.5150501672240803
# recall_score_original 0.515034902452121
# precision_score_original 0.51503355704698
# f1_score_original 0.5150284685168407
# accuracy_score_sog 0.5083612040133779
# recall_score_sog 0.5076069446930374
# precision_score_sog 0.50778245742538
# f1_score_sog 0.5051730931607092
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 47
# accuracy_score_orignial 0.5083612040133779
# recall_score_original 0.5082110255951315
# precision_score_original 0.508217644424541
# f1_score_original 0.5081631511218039
# accuracy_score_sog 0.5384615384615384
# recall_score_sog 0.5388177913012351
# precision_score_sog 0.5390062949640289
# f1_score_sog 0.5380429914912674
# Neuron/Cluster number: 52
# accuracy_score_orignial 0.49498327759197325
# recall_score_original 0.4945632718811527
# precision_score_original 0.49452554744525545
# f1_score_original 0.4938736617902584
# accuracy_score_sog 0.5183946488294314
# recall_score_sog 0.5181448004295687
# precision_score_sog 0.5181887503364133
# f1_score_sog 0.5179579041648008
# Neuron/Cluster number: 57
# accuracy_score_orignial 0.5150501672240803
# recall_score_original 0.5144308215500268
# precision_score_original 0.5146537622682661
# f1_score_original 0.5128706419029
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.49874709146232327
# precision_score_sog 0.49873839776516177
# f1_score_sog 0.4976478494623656
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 62
# accuracy_score_orignial 0.5150501672240803
# recall_score_original 0.5142294612493288
# precision_score_original 0.5146206896551724
# f1_score_original 0.5113553113553114
# accuracy_score_sog 0.5083612040133779
# recall_score_sog 0.5084123858958296
# precision_score_sog 0.5084123858958296
# f1_score_sog 0.5083612040133779
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 67
# accuracy_score_orignial 0.5250836120401338
# recall_score_original 0.5244317164846967
# precision_score_original 0.5248520710059172
# f1_score_original 0.5227293165467626
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5117236441739753
# precision_score_sog 0.5117225950782998
# f1_score_sog 0.5117002237136465
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 72
# accuracy_score_orignial 0.5284280936454849
# recall_score_original 0.5278772149633076
# precision_score_original 0.5282181357006975
# f1_score_original 0.5267128439440035
# accuracy_score_sog 0.5183946488294314
# recall_score_sog 0.5182119205298013
# precision_score_sog 0.5182347670250895
# f1_score_sog 0.5181305398871878
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 77
# accuracy_score_orignial 0.5217391304347826
# recall_score_original 0.5214560587077144
# precision_score_original 0.5215234760750516
# f1_score_original 0.5212035699488248
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5113880436728119
# precision_score_sog 0.5114330637915543
# f1_score_sog 0.5110439068100359
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 82
# accuracy_score_orignial 0.4983277591973244
# recall_score_original 0.4978745301592984
# precision_score_original 0.49785727174305305
# f1_score_original 0.4970619897730331
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5146993019509576
# precision_score_sog 0.5147706834532375
# f1_score_sog 0.5142677885207882
# Neuron/Cluster number: 87
# accuracy_score_orignial 0.5183946488294314
# recall_score_original 0.5180105602291032
# precision_score_original 0.5181159420289855
# f1_score_original 0.5174825174825175
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5114551637730446
# precision_score_sog 0.5114829102000538
# f1_score_sog 0.5112628750559784
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 92
# accuracy_score_orignial 0.5217391304347826
# recall_score_original 0.5209190979058529
# precision_score_original 0.5214942528735632
# f1_score_original 0.518095238095238
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5146993019509576
# precision_score_sog 0.5147706834532375
# f1_score_sog 0.5142677885207882
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 97
# accuracy_score_orignial 0.5150501672240803
# recall_score_original 0.5140281009486307
# precision_score_original 0.5146358543417366
# f1_score_original 0.5094311868472566
# accuracy_score_sog 0.5050167224080268
# recall_score_sog 0.5053696080186146
# precision_score_sog 0.5053956834532374
# f1_score_sog 0.5045678459471563
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_original mean 0.504180602006689
# all_recall_score_original mean 0.5039914086271702
# all_precision_score_original mean 0.5039495374630144
# all_f1_score_original mean 0.5024245273973006
# all_accuracy_score_sog mean 0.5135451505016722
# all_recall_score_sog mean 0.5139442008233399
# all_precision_score_sog mean 0.5165455918975339
# all_f1_score_sog mean 0.5067725198209617
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.504181  0.019407  0.004340   0.495098
# 1       all_accuracy_score_sog  20.0  0.513545  0.015210  0.003401   0.506427
# 2                     combined  40.0  0.508863  0.017851  0.002823   0.503154
#
#    Interval
# 0  0.513263
# 1  0.520664
# 2  0.514572
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0094
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.6985
# 3                           Two side test p value =    0.0976
# 4                          Difference < 0 p value =    0.0488
# 5                          Difference > 0 p value =    0.9512
# 6                                       Cohen's d =   -0.5371
# 7                                       Hedge's g =   -0.5264
# 8                                  Glass's delta1 =   -0.4825
# 9                                Point-Biserial r =   -0.2656
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.503991  0.018982  0.004245   0.495107
# 1       all_recall_score_sog  20.0  0.513944  0.015162  0.003390   0.506848
# 2                   combined  40.0  0.508968  0.017690  0.002797   0.503310
#
#    Interval
# 0  0.512875
# 1  0.521040
# 2  0.514625
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0100
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -1.8321
# 3                           Two side test p value =    0.0748
# 4                          Difference < 0 p value =    0.0374
# 5                          Difference > 0 p value =    0.9626
# 6                                       Cohen's d =   -0.5794
# 7                                       Hedge's g =   -0.5679
# 8                                  Glass's delta1 =   -0.5243
# 9                                Point-Biserial r =   -0.2849
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.503950  0.019604  0.004384
# 1       all_precision_score_sog  20.0  0.516546  0.020041  0.004481
# 2                      combined  40.0  0.510248  0.020581  0.003254
#
#    95% Conf.  Interval
# 0   0.494775  0.513125
# 1   0.507166  0.525925
# 2   0.503665  0.516830
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0126
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.0093
# 3                           Two side test p value =    0.0516
# 4                          Difference < 0 p value =    0.0258
# 5                          Difference > 0 p value =    0.9742
# 6                                       Cohen's d =   -0.6354
# 7                                       Hedge's g =   -0.6228
# 8                                  Glass's delta1 =   -0.6425
# 9                                Point-Biserial r =   -0.3099
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.502425  0.020034  0.004480   0.493048
# 1       all_f1_score_sog  20.0  0.506773  0.028242  0.006315   0.493555
# 2               combined  40.0  0.504599  0.024268  0.003837   0.496837
#
#    Interval
# 0  0.511801
# 1  0.519990
# 2  0.512360
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0043
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -0.5616
# 3                           Two side test p value =    0.5777
# 4                          Difference < 0 p value =    0.2889
# 5                          Difference > 0 p value =    0.7111
# 6                                       Cohen's d =   -0.1776
# 7                                       Hedge's g =   -0.1741
# 8                                  Glass's delta1 =   -0.2170
# 9                                Point-Biserial r =   -0.0907

# %%
dataread.PCA_Comparision() #123 0, 1, 2, 4, 7 |2, 1, 0, 3, 7 |7, 8, 9
# Out:
# Sorted feature index for component 0 [0, 1, 2, 4, 6, 8, 7, 9, 3, 5]
# Sorted imporance porporation for component 0  [0.33661359242884825, 0.2458668406274322, 0.1428518416421228, 0.1333390858175768, 0.11627421984604816, 0.014141553786273544, 0.004504276704620272, 0.003423597317048105, 0.0027575816353430007, 0.0002274101946865065]
# Sorted feature index for component 1 [1, 2, 3, 5, 8, 4, 0, 7, 6, 9]
# Sorted imporance porporation for component 1  [0.31800490910460466, 0.2630669497198022, 0.19196020422770638, 0.1496540139413969, 0.03439371429646926, 0.031660187774690846, 0.004048473490305111, 0.0031318084471728923, 0.003121991939307226, 0.0009577470585445335]
# Sorted feature index for component 2 [8, 9, 7, 6, 5, 2, 3, 1, 4, 0]
# Sorted imporance porporation for component 2  [0.42275623291792247, 0.3061124894093449, 0.2413066316326907, 0.013155120301681077, 0.006450687448499323, 0.004090867058128705, 0.0029544549129958218, 0.0020763329486657846, 0.0009372589239235357, 0.00015992444614797694]
# Sorted feature index for component 3 [7, 9, 8, 6, 0, 5, 2, 3, 1, 4]
# Sorted imporance porporation for component 3  [0.380251606036717, 0.35908922803408955, 0.24172557435549097, 0.006550025139276755, 0.003441699551696207, 0.0032980936320367795, 0.001772615104098343, 0.0014716330039550717, 0.0012894884344825928, 0.0011100367081567934]
# Sorted feature index for component 4 [9, 7, 8, 5, 6, 0, 4, 1, 2, 3]
# Sorted imporance porporation for component 4  [0.4619966104023229, 0.41476311802141413, 0.09786917467078711, 0.008797347364517417, 0.007252095060405336, 0.003411012788447914, 0.0030271474086435456, 0.0017727000868522907, 0.0006037153346557798, 0.0005070788619536532]
# Sorted feature index for component 5 [5, 0, 1, 9, 8, 2, 4, 7, 3, 6]
# Sorted imporance porporation for component 5  [0.7709829285792112, 0.08516640674104034, 0.06655256541548846, 0.023966780968557838, 0.019724178798723648, 0.011265682758035193, 0.005999368248517318, 0.005599690843190843, 0.005453223681747715, 0.005289173965487391]
# Sorted feature index for component 6 [1, 0, 2, 3, 6, 9, 5, 4, 7, 8]
# Sorted imporance porporation for component 6  [0.22852252179391147, 0.17898114452475256, 0.17094867897240051, 0.1661310481913758, 0.13160928261283128, 0.1053400950258278, 0.013771406779358083, 0.0019514064959382817, 0.0014998011335853796, 0.0012446144700186824]
# Sorted feature index for component 7 [0, 1, 3, 5, 8, 7, 2, 4, 9, 6]
# Sorted imporance porporation for component 7  [0.4673095483410768, 0.2995896916695633, 0.0936152025852332, 0.056700586051462186, 0.0398886880942091, 0.024930200418235623, 0.0057340594761382735, 0.004847243333697361, 0.0043917656375503066, 0.002993014392833835]
# Sorted feature index for component 8 [1, 0, 2, 3, 5, 9, 6, 8, 4, 7]
# Sorted imporance porporation for component 8  [0.24457168709254093, 0.21775670496145716, 0.1943637281830295, 0.18099300858501616, 0.07683082795802555, 0.04059060985803979, 0.037336333779431505, 0.004337567088016728, 0.002665073293087436, 0.0005544592013552777]
# Sorted feature index for component 9 [2, 1, 0, 3, 8, 6, 9, 4, 5, 7]
# Sorted imporance porporation for component 9  [0.3781159840734287, 0.1765737201427096, 0.15176996049300853, 0.12809607716381446, 0.10068936990238875, 0.04865037363739037, 0.014628893884304328, 0.0006734603078982757, 0.00046681058281497983, 0.00033534981224161406]
# [0.32660409 0.31263013 0.29682371 0.01975358 0.00841862 0.00768271
#  0.0072813  0.0071624  0.00685592 0.00678753]
