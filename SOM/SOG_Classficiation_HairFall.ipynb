# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# self.continuous_feature_num 1
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
#Randmom Forest
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 1


features =2# [0,1,2,3,4,7,8,9]
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features)
# Out:
# Experiment number: 1
# self.train_new_embedding_sog_fuzzy.shape  (700, 20)
# self.train_discrete_extra_sog_fuzzyc (700, 40)
# accuracy_score_orignial 0.5284280936454849
# recall_score_original 0.528814317673378
# precision_score_original 0.5304347826086957
# f1_score_original 0.5222505524392317
# accuracy_score_sog 0.46153846153846156
# recall_score_sog 0.46161073825503357
# precision_score_sog 0.46153846153846156
# f1_score_sog 0.4613215464667375
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# self.train_new_embedding_sog_fuzzy.shape  (700, 20)
# self.train_discrete_extra_sog_fuzzyc (700, 40)
# accuracy_score_orignial 0.5418060200668896
# recall_score_original 0.5424384787472036
# precision_score_original 0.5495093433552563
# f1_score_original 0.5251492494059005
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.49843400447427294
# ...

# %%
dataread.PCA_Comparision() #123 0, 1, 2, 4, 7 |2, 1, 0, 3, 7 |7, 8, 9
# Out:
# Sorted feature index for component 0 [1, 2, 0, 3, 5, 9, 4, 6, 7, 8]
# Sorted imporance porporation for component 0  [0.3297188546391203, 0.22995893887796473, 0.15447088455098273, 0.10536484159705763, 0.07765037725635794, 0.07217758047907749, 0.026896310972464036, 0.0023822552253111285, 0.0007695090619841662, 0.0006104473396798286]
# Sorted feature index for component 1 [1, 0, 2, 3, 7, 5, 6, 9, 8, 4]
# Sorted imporance porporation for component 1  [0.3344179862784272, 0.22793354792233422, 0.2016504211291741, 0.10231181007769968, 0.0592081331007112, 0.05041569177966585, 0.012033777874122308, 0.007108241578502518, 0.003397696208380437, 0.001522694050982588]
# Sorted feature index for component 2 [8, 9, 7, 6, 5, 0, 1, 2, 3, 4]
# ...

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.5217391304347826
# recall_score_original 0.534554312522555
# precision_score_original 0.5371339926313748
# f1_score_original 0.5175079273728517
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 20)
# accuracy_score_sog 0.5217391304347826
# recall_score_sog 0.5278554673403104
# precision_score_sog 0.5281065088757396
# f1_score_sog 0.5215464667375371
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.5217391304347826
# recall_score_original 0.534554312522555
# precision_score_original 0.5371339926313748
# f1_score_original 0.5175079273728517
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 70)
# accuracy_score_sog 0.5183946488294314
# recall_score_sog 0.5211340671237821
# precision_score_sog 0.5210297154143101
# f1_score_sog 0.5182599355531686
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# ...

# %%
#LogisticRegression
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 10
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 10
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.49229900632339657
# precision_score_original 0.4916658519894418
# f1_score_original 0.47330623306233066
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 100)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5103658536585366
# precision_score_sog 0.5106014412416852
# f1_score_sog 0.5008682792386032
# neuron unit number: 15
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\sklearn\linear_model\_logistic.py:1171: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# ...

# %%
#Decision Tree
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.4882943143812709
# recall_score_original 0.4851527403414196
# precision_score_original 0.48507226738934056
# f1_score_original 0.4849760765550239
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 20)
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5158580413297394
# precision_score_sog 0.5158026680992032
# f1_score_sog 0.5148548089296705
# neuron unit number: 7
# accuracy_score_orignial 0.4816053511705686
# recall_score_original 0.4797169811320755
# precision_score_original 0.47973336924319954
# f1_score_original 0.47971979298808887
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 70)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.4967205750224618
# precision_score_sog 0.49672557638826587
# f1_score_sog 0.49670078103959064
# neuron unit number: 12
# accuracy_score_orignial 0.5050167224080268
# recall_score_original 0.5038634321653189
# ...

# %%
#LinearDiscriminantAnalysis()
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.4786110613925183
# precision_score_original 0.4785071942446043
# f1_score_original 0.47778772951186743
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 20)
# accuracy_score_sog 0.47491638795986624
# recall_score_sog 0.4751655629139073
# precision_score_sog 0.475105409527227
# f1_score_sog 0.47470486208247076
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.4786110613925183
# precision_score_original 0.4785071942446043
# f1_score_original 0.47778772951186743
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 70)
# accuracy_score_sog 0.4916387959866221
# recall_score_sog 0.49178897440486846
# precision_score_sog 0.491782355575459
# f1_score_sog 0.4915876141041704
# ...

# %%
#KNN
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.44816053511705684
# recall_score_original 0.4493464052287582
# precision_score_original 0.4488240615106287
# f1_score_original 0.44727024210986255
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 20)
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5122213268869191
# precision_score_sog 0.5122377622377623
# f1_score_sog 0.5116565240737427
# neuron unit number: 7
# accuracy_score_orignial 0.44816053511705684
# recall_score_original 0.4493464052287582
# precision_score_original 0.4488240615106287
# f1_score_original 0.44727024210986255
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 70)
# accuracy_score_sog 0.5183946488294314
# recall_score_sog 0.5187572745993374
# precision_score_sog 0.5187639946260636
# f1_score_sog 0.5183892617449665
# neuron unit number: 12
# accuracy_score_orignial 0.44816053511705684
# recall_score_original 0.4493464052287582
# ...

# %%
#SVM
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
best_num = 48
interval = 5

experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval)
# Out:
# neuron unit number: 2
# accuracy_score_orignial 0.5418060200668896
# recall_score_original 0.5432795698924731
# precision_score_original 0.5434782608695652
# f1_score_original 0.5416214401611369
# SOG Classficiation
# self.train_new_embedding_sog_fuzzy shape (700, 20)
# accuracy_score_sog 0.4816053511705686
# recall_score_sog 0.5
# precision_score_sog 0.2408026755852843
# f1_score_sog 0.32505643340857787
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# neuron unit number: 7
# accuracy_score_orignial 0.5418060200668896
# recall_score_original 0.5432795698924731
# precision_score_original 0.5434782608695652
# f1_score_original 0.5416214401611369
# ...
