# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# self.continuous_feature_num 1
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
#Randmom Forest
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 2
dim_num = 7
best_num = 48
interval = 1



features_chosen = [0,1,2,3,4,7,8,9]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,unstable_repeat_num,interval,features_chosen,feature_combination_number)
# Out:
# Experiment number: 1
# accuracy_score_orignial 0.5250836120401338
# recall_score_original 0.5296251239073624
# precision_score_original 0.5297376752600633
# f1_score_original 0.5250357973867907
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5451505016722408
# recall_score_sog 0.5481436424258809
# precision_score_sog 0.5480008984725966
# f1_score_sog 0.545104707356363
# Experiment number: 2
# accuracy_score_orignial 0.5117056856187291
# recall_score_original 0.5133369379111472
# precision_score_original 0.5132616487455197
# f1_score_original 0.511437908496732
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5384615384615384
# recall_score_sog 0.5402811570694782
# precision_score_sog 0.5400537634408602
# f1_score_sog 0.5382084340585549
# Experiment number: 3
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.4790934486798234
# precision_score_original 0.4792282209687528
# f1_score_original 0.47778772951186743
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5083612040133779
# recall_score_sog 0.5079976570244211
# precision_score_sog 0.5079425451942008
# f1_score_sog 0.5072809820077351
# Experiment number: 4
# accuracy_score_orignial 0.49498327759197325
# recall_score_original 0.4973416238623051
# precision_score_original 0.49735164736511356
# f1_score_original 0.4948928791184203
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4882943143812709
# recall_score_sog 0.48666306208885285
# precision_score_sog 0.4867383512544803
# f1_score_sog 0.486433085981791
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_orignial 0.4916387959866221
# recall_score_original 0.4959448499594485
# precision_score_original 0.49592944369063774
# f1_score_original 0.4915876141041704
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4816053511705686
# recall_score_sog 0.48217986843290983
# precision_score_sog 0.4822994987468672
# f1_score_sog 0.481024848545929
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_orignial 0.5016722408026756
# recall_score_original 0.5052041092187077
# precision_score_original 0.5052041092187077
# f1_score_original 0.5016722408026756
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.48494983277591974
# recall_score_sog 0.4880823646030459
# precision_score_sog 0.48809523809523814
# f1_score_sog 0.48494407158836694
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# accuracy_score_orignial 0.5083612040133779
# recall_score_original 0.5096873028746508
# precision_score_original 0.509628302731751
# f1_score_original 0.5080089996306122
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5133369379111472
# precision_score_sog 0.5132616487455197
# f1_score_sog 0.511437908496732
# Experiment number: 8
# accuracy_score_orignial 0.47491638795986624
# recall_score_original 0.4748805983599171
# precision_score_original 0.47505592841163313
# f1_score_original 0.47406926067423283
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.4976119671983419
# precision_score_sog 0.49762799856784823
# f1_score_sog 0.4970619897730331
# Experiment number: 9
# accuracy_score_orignial 0.4983277591973244
# recall_score_original 0.49986482833198165
# precision_score_original 0.4998655913978495
# f1_score_original 0.49805264571582053
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5186762187978733
# precision_score_sog 0.5186762187978733
# f1_score_sog 0.5150501672240803
# Experiment number: 10
# accuracy_score_orignial 0.5250836120401338
# recall_score_original 0.5268090474903127
# precision_score_original 0.52665770609319
# f1_score_original 0.5248231712776434
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4983277591973244
# recall_score_sog 0.5021176894656213
# precision_score_sog 0.5021201732226632
# f1_score_sog 0.49832214765100674
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# accuracy_score_orignial 0.4983277591973244
# recall_score_original 0.5026809047490313
# precision_score_original 0.5026910900045228
# f1_score_original 0.4982772507606944
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5248715869153825
# precision_score_sog 0.5260869565217392
# f1_score_sog 0.5124104501951258
# Experiment number: 12
# accuracy_score_orignial 0.4882943143812709
# recall_score_original 0.49229521492295214
# precision_score_original 0.4922764227642277
# f1_score_original 0.48827141850397665
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5217391304347826
# recall_score_sog 0.5214697666035866
# precision_score_sog 0.521321818507249
# f1_score_sog 0.5206883022252116
# Experiment number: 13
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.47684058754618364
# precision_score_original 0.47698163905060453
# f1_score_original 0.4765688122811742
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5035144633684779
# precision_score_sog 0.5034965034965035
# f1_score_sog 0.5014714933139373
# Experiment number: 14
# accuracy_score_orignial 0.4916387959866221
# recall_score_original 0.4953816346760386
# precision_score_original 0.4953762179718513
# f1_score_original 0.4916331096196868
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4916387959866221
# recall_score_sog 0.49425520410921875
# precision_score_sog 0.4942722371967655
# f1_score_sog 0.4915876141041704
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# accuracy_score_orignial 0.5217391304347826
# recall_score_original 0.5197801207533568
# precision_score_original 0.5196913967883735
# f1_score_original 0.5195896675318254
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5284280936454849
# recall_score_sog 0.5248265296927097
# precision_score_sog 0.5248556477805846
# f1_score_sog 0.5248351648351648
# Experiment number: 16
# accuracy_score_orignial 0.5150501672240803
# recall_score_original 0.5141704965305939
# precision_score_original 0.5140791476407915
# f1_score_original 0.5136575242582311
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5217391304347826
# recall_score_sog 0.5242858430206362
# precision_score_sog 0.5241942723763354
# f1_score_sog 0.5216535212843318
# Experiment number: 17
# accuracy_score_orignial 0.5418060200668896
# recall_score_original 0.5439307921059746
# precision_score_original 0.5437062937062938
# f1_score_original 0.541621440161137
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5217391304347826
# recall_score_sog 0.526538704154276
# precision_score_sog 0.5266781411359724
# f1_score_sog 0.5216535212843318
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_orignial 0.5050167224080268
# recall_score_original 0.5043480219879247
# precision_score_original 0.5043188327962764
# f1_score_original 0.5037678299093926
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5284280936454849
# recall_score_sog 0.5282058213931693
# precision_score_sog 0.5280114551637731
# f1_score_sog 0.5273919623339499
# Experiment number: 19
# accuracy_score_orignial 0.49498327759197325
# recall_score_original 0.4956519780120754
# precision_score_original 0.4956811672037236
# f1_score_original 0.4944177556802275
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5116472920609174
# precision_score_sog 0.511565995525727
# f1_score_sog 0.5107808857808858
# Experiment number: 20
# accuracy_score_orignial 0.4782608695652174
# recall_score_original 0.4802198792466432
# precision_score_original 0.48030860321162644
# f1_score_original 0.4781149301825993
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.47491638795986624
# recall_score_sog 0.475443813643327
# precision_score_sog 0.475608664518439
# f1_score_sog 0.47432839497877965
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# accuracy_score_orignial 0.5050167224080268
# recall_score_original 0.5077273136883842
# precision_score_original 0.5077044025157234
# f1_score_original 0.5049668874172186
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5150501672240803
# recall_score_sog 0.5192394340812831
# precision_score_sog 0.5192863595302619
# f1_score_sog 0.5150284685168406
# Experiment number: 22
# accuracy_score_orignial 0.5050167224080268
# recall_score_original 0.5060376678381544
# precision_score_original 0.5059987465305757
# f1_score_original 0.5045678459471563
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5484949832775919
# recall_score_sog 0.5506668468955573
# precision_score_sog 0.5504079254079254
# f1_score_sog 0.5483130979690035
# Experiment number: 23
# accuracy_score_orignial 0.47491638795986624
# recall_score_original 0.475443813643327
# precision_score_original 0.475608664518439
# f1_score_original 0.47432839497877965
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.46488294314381273
# recall_score_sog 0.4633684779670181
# precision_score_sog 0.46359158083296015
# f1_score_sog 0.4631474997755633
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# accuracy_score_orignial 0.4983277591973244
# recall_score_original 0.5015544741822114
# precision_score_original 0.5015527950310559
# f1_score_original 0.4983221476510067
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4882943143812709
# recall_score_sog 0.49060556907272235
# precision_score_sog 0.4906409911123081
# f1_score_sog 0.4882027185769424
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# accuracy_score_orignial 0.4882943143812709
# recall_score_original 0.48778949265567273
# precision_score_original 0.4878736352246286
# f1_score_original 0.48717000168152014
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5183946488294314
# recall_score_sog 0.5166937010002703
# precision_score_sog 0.5166083916083917
# f1_score_sog 0.5164420485175203
# Experiment number: 26
# accuracy_score_orignial 0.5083612040133779
# recall_score_original 0.5102505181580608
# precision_score_original 0.5101981351981352
# f1_score_original 0.5081631511218038
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5284280936454849
# recall_score_sog 0.5315851130936289
# precision_score_sog 0.5315197841726619
# f1_score_sog 0.5284069935232725
# Experiment number: 27
# accuracy_score_orignial 0.4816053511705686
# recall_score_original 0.4810534378660899
# precision_score_original 0.48118399856810457
# f1_score_original 0.4804663415727818
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4782608695652174
# recall_score_sog 0.4774038028295936
# precision_score_sog 0.4775554958825635
# f1_score_sog 0.4769444693639544
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# accuracy_score_orignial 0.4983277591973244
# recall_score_original 0.5015544741822114
# precision_score_original 0.5015527950310559
# f1_score_original 0.4983221476510067
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5016722408026756
# recall_score_sog 0.5029512480850681
# precision_score_sog 0.5029332736229288
# f1_score_sog 0.5013152445235457
# Experiment number: 29
# accuracy_score_orignial 0.49498327759197325
# recall_score_original 0.4956519780120754
# precision_score_original 0.4956811672037236
# f1_score_original 0.4944177556802275
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.5117056856187291
# recall_score_sog 0.5139001531945571
# precision_score_sog 0.5138378038934243
# f1_score_sog 0.5115691013247405
# Experiment number: 30
# accuracy_score_orignial 0.4682274247491639
# recall_score_original 0.4698341894205641
# precision_score_original 0.46998834498834496
# f1_score_original 0.46801320427460413
# self.train_discrete_extra_sog_fuzzy shape (700, 196)
# accuracy_score_sog 0.4782608695652174
# recall_score_sog 0.481909525096873
# precision_score_sog 0.4818883074702274
# f1_score_sog 0.47825503355704696
# all_accuracy_score_original mean 0.4982162764771461
# all_recall_score_original mean 0.49979949535910606
# all_precision_score_original mean 0.49981245899437654
# all_f1_score_original mean 0.49773419545280057
# all_accuracy_score_sog mean 0.5073578595317725
# all_recall_score_sog mean 0.5089491153765281
# all_precision_score_sog mean 0.5089725980098296
# all_f1_score_sog mean 0.5066431442889304
# Accuracy Score T-Test
#                       Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  30.0  0.498216  0.017110  0.003124   0.491827
# 1       all_accuracy_score_sog  30.0  0.507358  0.021427  0.003912   0.499357
# 2                     combined  60.0  0.502787  0.019769  0.002552   0.497680
#
#    Interval
# 0  0.504605
# 1  0.515359
# 2  0.507894
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0091
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -1.8261
# 3                           Two side test p value =    0.0730
# 4                          Difference < 0 p value =    0.0365
# 5                          Difference > 0 p value =    0.9635
# 6                                       Cohen's d =   -0.4715
# 7                                       Hedge's g =   -0.4654
# 8                                  Glass's delta1 =   -0.5343
# 9                                Point-Biserial r =   -0.2332
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  30.0  0.499799  0.017427  0.003182   0.493292
# 1       all_recall_score_sog  30.0  0.508949  0.021995  0.004016   0.500736
# 2                   combined  60.0  0.504374  0.020207  0.002609   0.499154
#
#    Interval
# 0  0.506307
# 1  0.517162
# 2  0.509594
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0091
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -1.7859
# 3                           Two side test p value =    0.0793
# 4                          Difference < 0 p value =    0.0397
# 5                          Difference > 0 p value =    0.9603
# 6                                       Cohen's d =   -0.4611
# 7                                       Hedge's g =   -0.4551
# 8                                  Glass's delta1 =   -0.5250
# 9                                Point-Biserial r =   -0.2283
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  30.0  0.499812  0.017346  0.003167
# 1       all_precision_score_sog  30.0  0.508973  0.021939  0.004005
# 2                      combined  60.0  0.504393  0.020144  0.002601
#
#    95% Conf.  Interval
# 0   0.493335  0.506290
# 1   0.500781  0.517165
# 2   0.499189  0.509596
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0092
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -1.7939
# 3                           Two side test p value =    0.0780
# 4                          Difference < 0 p value =    0.0390
# 5                          Difference > 0 p value =    0.9610
# 6                                       Cohen's d =   -0.4632
# 7                                       Hedge's g =   -0.4572
# 8                                  Glass's delta1 =   -0.5281
# 9                                Point-Biserial r =   -0.2293
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  30.0  0.497734  0.017137  0.003129   0.491335
# 1       all_f1_score_sog  30.0  0.506643  0.021474  0.003921   0.498625
# 2               combined  60.0  0.502189  0.019778  0.002553   0.497079
#
#    Interval
# 0  0.504133
# 1  0.514662
# 2  0.507298
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0089
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -1.7761
# 3                           Two side test p value =    0.0810
# 4                          Difference < 0 p value =    0.0405
# 5                          Difference > 0 p value =    0.9595
# 6                                       Cohen's d =   -0.4586
# 7                                       Hedge's g =   -0.4526
# 8                                  Glass's delta1 =   -0.5199
# 9                                Point-Biserial r =   -0.2271

# %%
dataread.PCA_Comparision() #123 0, 1, 2, 4, 7 |2, 1, 0, 3, 7 |7, 8, 9
# Out:
# Sorted feature index for component 0 [3, 2, 0, 1, 4, 9, 6, 8, 7, 5]
# Sorted imporance porporation for component 0  [0.3611586549197475, 0.23672651433209774, 0.17038322707772846, 0.08579925712023988, 0.08568144728680503, 0.05373573721386208, 0.0021968794988418538, 0.002031994743900104, 0.0012419671671950643, 0.001044320639582118]
# Sorted feature index for component 1 [2, 0, 1, 3, 8, 5, 6, 7, 4, 9]
# Sorted imporance porporation for component 1  [0.3775700484473064, 0.2834647305474879, 0.11779296114278134, 0.07820759545591256, 0.052989900935891995, 0.042464947875108586, 0.03721205797752161, 0.004887118811701595, 0.0036340147257227094, 0.0017766240805653065]
# Sorted feature index for component 2 [8, 7, 9, 6, 4, 1, 0, 2, 5, 3]
# Sorted imporance porporation for component 2  [0.33578961020360204, 0.33491579211368816, 0.3047704830100721, 0.008278703818135091, 0.006977565822813033, 0.004879668812645872, 0.0021671627281581248, 0.0010903478756697554, 0.0008728996283694952, 0.00025776598684629974]
# Sorted feature index for component 3 [9, 7, 8, 5, 4, 3, 6, 0, 2, 1]
# Sorted imporance porporation for component 3  [0.4825082769787708, 0.3947925465364188, 0.09515234347422395, 0.00919014604616853, 0.005977861988114187, 0.005576440036013183, 0.002630420779863664, 0.0018740430695533673, 0.001581447348600701, 0.000716473742272834]
# Sorted feature index for component 4 [7, 9, 8, 0, 4, 5, 2, 1, 3, 6]
# Sorted imporance porporation for component 4  [0.5157349505202125, 0.3136161902043238, 0.1548706223411867, 0.004845496189535748, 0.0030780858617148197, 0.0029522268855376923, 0.0013874750214876712, 0.0013063395722286266, 0.001185733275284621, 0.0010228801284878299]
# Sorted feature index for component 5 [0, 1, 2, 9, 7, 4, 8, 3, 5, 6]
# Sorted imporance porporation for component 5  [0.8064281335446492, 0.05821381528405983, 0.056287688746386816, 0.01792702497414056, 0.015187656384879202, 0.014502257143158306, 0.011409964487974747, 0.010421971197511395, 0.00889454726974425, 0.0007269409674956433]
# Sorted feature index for component 6 [0, 2, 1, 3, 8, 6, 4, 9, 7, 5]
# Sorted imporance porporation for component 6  [0.307784038812172, 0.21287722834620257, 0.197237455889086, 0.10093233506440735, 0.08401485214586994, 0.08192287419328305, 0.008308622453394228, 0.002758561552458301, 0.0021610685897467787, 0.002002962953379744]
# Sorted feature index for component 7 [0, 2, 1, 4, 8, 6, 3, 5, 9, 7]
# Sorted imporance porporation for component 7  [0.36380656670104455, 0.2500541787050221, 0.180302574177234, 0.14448559252075216, 0.03507692016407119, 0.010026471371402262, 0.005889645583288501, 0.0035667965562973494, 0.0034528823778043954, 0.0033383718430834933]
# Sorted feature index for component 8 [2, 0, 1, 4, 3, 8, 9, 5, 6, 7]
# Sorted imporance porporation for component 8  [0.5660653367692495, 0.11137618357805797, 0.09969080949333461, 0.074163889030809, 0.06228639357471818, 0.038692453170431775, 0.034461038768009704, 0.0075280253050460265, 0.005727475322786273, 8.394987556656945e-06]
# Sorted feature index for component 9 [0, 1, 2, 3, 6, 9, 4, 8, 5, 7]
# Sorted imporance porporation for component 9  [0.22116865476607198, 0.20394324597269722, 0.19506403582498616, 0.18543711706505597, 0.15663582673801452, 0.021581819940675973, 0.01203817867432318, 0.002149015452564566, 0.0010738413845644277, 0.0009082641810463131]
# [0.33448824 0.31315068 0.2867565  0.02081157 0.0086282  0.0077649
#  0.0074102  0.00717495 0.00709403 0.00672073]
