# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("hcvdat0.csv")
csv = csv.drop(columns=['ID'])
dataread.replaceNANinDataset(csv)
dataread.stringToIntHCVDataSet(csv,"Category")
dataread.stringToIntHCVDataSet(csv,"Sex")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Category")

# %%
scoretype = 0
scope_num = 30
class_num = 5
dim_num = 12
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 5
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.45454545454545453
# error_data0_score_W0 0.36363636363636365
# combinedweight shape 0: (10, 12)
# right_data0_score_W' 0.9870801033591732
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5833333333333334
# error_data1_score_W0 0.5416666666666666
# combinedweight shape1 : (15, 12)
# right_data1_score_W' 0.8
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.6
# error_data2_score_W0 0.5
# combinedweight shape1 : (20, 12)
# right_data2_score_W' 0.7857142857142857
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.75
# error_data3_score_W0 0.5
# combinedweight shape1 : (25, 12)
# right_data3_score_W' 0.8333333333333334
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 1.0
# error_data4_score_W0 1.0
# Error data can be represented by W0 4
# combinedweight shape1 : (30, 12)
# right_data4_score_W' 0.6666666666666666
# Finish one splitting *********
# 5
#  NO Error Data, Finish Training!
# split_num 5
# all_train_score_W' split_num : 0 0.8979118329466357
# test_score_W': split_num : 0 0.8641304347826086
# all_train_score_W' split_num : 1 0.9443155452436195
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 0.9767981438515081
# test_score_W': split_num : 2 0.907608695652174
# all_train_score_W' split_num : 3 0.9907192575406032
# test_score_W': split_num : 3 0.9130434782608695
# all_train_score_W' split_num : 4 0.9976798143851509
# test_score_W': split_num : 4 0.9184782608695652
# all_train_score_W' split_num : 5 1.0
# test_score_W': split_num : 5 0.9184782608695652
# neuron unit number: 10
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5833333333333334
# error_data0_score_W0 0.4444444444444444
# combinedweight shape 0: (20, 12)
# right_data0_score_W' 0.9822784810126582
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.9333333333333333
# error_data1_score_W0 0.7333333333333333
# combinedweight shape1 : (30, 12)
# right_data1_score_W' 0.8571428571428571
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (40, 12)
# right_data2_score_W' 0.7857142857142857
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9164733178654292
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.9651972157772621
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 0.9976798143851509
# test_score_W': split_num : 2 0.9130434782608695
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9130434782608695
# neuron unit number: 15
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5789473684210527
# error_data0_score_W0 0.42105263157894735
# combinedweight shape 0: (30, 12)
# right_data0_score_W' 0.9949109414758269
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8125
# error_data1_score_W0 0.4375
# combinedweight shape1 : (45, 12)
# right_data1_score_W' 0.8636363636363636
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.3333333333333333
# combinedweight shape1 : (60, 12)
# right_data2_score_W' 0.6153846153846154
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9118329466357309
# test_score_W': split_num : 0 0.8641304347826086
# all_train_score_W' split_num : 1 0.962877030162413
# test_score_W': split_num : 1 0.8913043478260869
# all_train_score_W' split_num : 2 0.9930394431554525
# test_score_W': split_num : 2 0.8967391304347826
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9021739130434783
# neuron unit number: 20
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6410256410256411
# error_data0_score_W0 0.38461538461538464
# combinedweight shape 0: (40, 12)
# right_data0_score_W' 0.9821428571428571
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8571428571428571
# error_data1_score_W0 0.42857142857142855
# combinedweight shape1 : (60, 12)
# right_data1_score_W' 0.84
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (80, 12)
# right_data2_score_W' 0.9166666666666666
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.9095127610208816
# test_score_W': split_num : 0 0.875
# all_train_score_W' split_num : 1 0.9675174013921114
# test_score_W': split_num : 1 0.8967391304347826
# all_train_score_W' split_num : 2 0.9953596287703016
# test_score_W': split_num : 2 0.9184782608695652
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.9184782608695652
# neuron unit number: 25
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7741935483870968
# error_data0_score_W0 0.5161290322580645
# combinedweight shape 0: (50, 12)
# right_data0_score_W' 0.9725
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.42857142857142855
# combinedweight shape1 : (75, 12)
# right_data1_score_W' 0.6666666666666666
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9280742459396751
# test_score_W': split_num : 0 0.875
# all_train_score_W' split_num : 1 0.9837587006960556
# test_score_W': split_num : 1 0.8967391304347826
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8913043478260869
# neuron unit number: 30
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.4444444444444444
# combinedweight shape 0: (60, 12)
# right_data0_score_W' 0.9848101265822785
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.3333333333333333
# combinedweight shape1 : (90, 12)
# right_data1_score_W' 0.7333333333333333
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9164733178654292
# test_score_W': split_num : 0 0.8695652173913043
# all_train_score_W' split_num : 1 0.9860788863109049
# test_score_W': split_num : 1 0.8858695652173914
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8913043478260869
# neuron unit number: 35
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8387096774193549
# error_data0_score_W0 0.4838709677419355
# combinedweight shape 0: (70, 12)
# right_data0_score_W' 0.965
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8
# combinedweight shape1 : (105, 12)
# right_data1_score_W' 0.7307692307692307
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9280742459396751
# test_score_W': split_num : 0 0.8858695652173914
# all_train_score_W' split_num : 1 0.988399071925754
# test_score_W': split_num : 1 0.8913043478260869
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8913043478260869
# neuron unit number: 40
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7428571428571429
# error_data0_score_W0 0.4
# combinedweight shape 0: (80, 12)
# right_data0_score_W' 0.9747474747474747
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4444444444444444
# combinedweight shape1 : (120, 12)
# right_data1_score_W' 0.8076923076923077
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9187935034802784
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.9791183294663574
# test_score_W': split_num : 1 0.907608695652174
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.907608695652174
# neuron unit number: 45
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.896551724137931
# error_data0_score_W0 0.4827586206896552
# combinedweight shape 0: (90, 12)
# right_data0_score_W' 0.9701492537313433
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (135, 12)
# right_data1_score_W' 0.6923076923076923
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9327146171693735
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.9930394431554525
# test_score_W': split_num : 1 0.907608695652174
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 50
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8666666666666667
# error_data0_score_W0 0.5333333333333333
# combinedweight shape 0: (100, 12)
# right_data0_score_W' 0.9750623441396509
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (150, 12)
# right_data1_score_W' 0.8846153846153846
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9303944315545244
# test_score_W': split_num : 0 0.8641304347826086
# all_train_score_W' split_num : 1 0.9907192575406032
# test_score_W': split_num : 1 0.8967391304347826
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 55
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.6
# combinedweight shape 0: (110, 12)
# right_data0_score_W' 0.9679802955665024
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.8586956521739131
# all_train_score_W' split_num : 1 1.0
# test_score_W': split_num : 1 0.8858695652173914
# neuron unit number: 60
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9230769230769231
# error_data0_score_W0 0.5384615384615384
# combinedweight shape 0: (120, 12)
# right_data0_score_W' 0.980246913580247
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (180, 12)
# right_data1_score_W' 0.7916666666666666
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9396751740139211
# test_score_W': split_num : 0 0.8967391304347826
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 65
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9285714285714286
# error_data0_score_W0 0.5
# combinedweight shape 0: (130, 12)
# right_data0_score_W' 0.9776674937965261
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (195, 12)
# right_data1_score_W' 0.8846153846153846
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9350348027842227
# test_score_W': split_num : 0 0.8695652173913043
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.9184782608695652
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9184782608695652
# neuron unit number: 70
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8214285714285714
# error_data0_score_W0 0.5357142857142857
# combinedweight shape 0: (140, 12)
# right_data0_score_W' 0.9826302729528535
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8
# combinedweight shape1 : (210, 12)
# right_data1_score_W' 0.8695652173913043
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9350348027842227
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.988399071925754
# test_score_W': split_num : 1 0.8967391304347826
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 75
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9565217391304348
# error_data0_score_W0 0.5652173913043478
# combinedweight shape 0: (150, 12)
# right_data0_score_W' 0.9607843137254902
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (225, 12)
# right_data1_score_W' 0.9545454545454546
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9466357308584686
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.9976798143851509
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 80
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.5714285714285714
# combinedweight shape 0: (160, 12)
# right_data0_score_W' 0.9658536585365853
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W' split_num : 0 0.951276102088167
# test_score_W': split_num : 0 0.875
# all_train_score_W' split_num : 1 1.0
# test_score_W': split_num : 1 0.9021739130434783
# neuron unit number: 85
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9166666666666666
# error_data0_score_W0 0.5
# combinedweight shape 0: (170, 12)
# right_data0_score_W' 0.9606879606879607
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (255, 12)
# right_data1_score_W' 0.8181818181818182
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9443155452436195
# test_score_W': split_num : 0 0.8913043478260869
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.8967391304347826
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8967391304347826
# neuron unit number: 90
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9583333333333334
# error_data0_score_W0 0.5833333333333334
# combinedweight shape 0: (180, 12)
# right_data0_score_W' 0.9680589680589681
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (270, 12)
# right_data1_score_W' 0.8695652173913043
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9443155452436195
# test_score_W': split_num : 0 0.8913043478260869
# all_train_score_W' split_num : 1 0.9976798143851509
# test_score_W': split_num : 1 0.907608695652174
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.907608695652174
# neuron unit number: 95
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.92
# error_data0_score_W0 0.56
# combinedweight shape 0: (190, 12)
# right_data0_score_W' 0.9556650246305419
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (285, 12)
# right_data1_score_W' 0.8695652173913043
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.907608695652174
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.907608695652174
# neuron unit number: 100
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8571428571428571
# error_data0_score_W0 0.4642857142857143
# combinedweight shape 0: (200, 12)
# right_data0_score_W' 0.9379652605459057
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (300, 12)
# right_data1_score_W' 0.9583333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9350348027842227
# test_score_W': split_num : 0 0.8586956521739131
# all_train_score_W' split_num : 1 0.9907192575406032
# test_score_W': split_num : 1 0.8858695652173914
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8967391304347826
# neuron unit number: 105
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.5833333333333334
# combinedweight shape 0: (210, 12)
# right_data0_score_W' 0.9778869778869779
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (315, 12)
# right_data1_score_W' 0.8571428571428571
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9443155452436195
# test_score_W': split_num : 0 0.8967391304347826
# all_train_score_W' split_num : 1 0.9930394431554525
# test_score_W': split_num : 1 0.9130434782608695
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9130434782608695
# neuron unit number: 110
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96
# error_data0_score_W0 0.6
# combinedweight shape 0: (220, 12)
# right_data0_score_W' 0.9729064039408867
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (330, 12)
# right_data1_score_W' 0.9583333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.875
# all_train_score_W' split_num : 1 0.9976798143851509
# test_score_W': split_num : 1 0.907608695652174
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.907608695652174
# neuron unit number: 115
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.4666666666666667
# combinedweight shape 0: (230, 12)
# right_data0_score_W' 0.972568578553616
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (345, 12)
# right_data1_score_W' 0.7407407407407407
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9303944315545244
# test_score_W': split_num : 0 0.8804347826086957
# all_train_score_W' split_num : 1 0.9930394431554525
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 120
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9523809523809523
# error_data0_score_W0 0.5238095238095238
# combinedweight shape 0: (240, 12)
# right_data0_score_W' 0.9634146341463414
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (360, 12)
# right_data1_score_W' 0.9
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.951276102088167
# test_score_W': split_num : 0 0.875
# all_train_score_W' split_num : 1 0.9976798143851509
# test_score_W': split_num : 1 0.907608695652174
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.907608695652174
# neuron unit number: 125
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.92
# error_data0_score_W0 0.52
# combinedweight shape 0: (250, 12)
# right_data0_score_W' 0.9778325123152709
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (375, 12)
# right_data1_score_W' 0.782608695652174
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.8695652173913043
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.8858695652173914
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8804347826086957
# neuron unit number: 130
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.92
# error_data0_score_W0 0.52
# combinedweight shape 0: (260, 12)
# right_data0_score_W' 0.9655172413793104
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (390, 12)
# right_data1_score_W' 0.8260869565217391
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.8858695652173914
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 135
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.92
# error_data0_score_W0 0.56
# combinedweight shape 0: (270, 12)
# right_data0_score_W' 0.9556650246305419
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (405, 12)
# right_data1_score_W' 0.6956521739130435
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.8967391304347826
# all_train_score_W' split_num : 1 0.9953596287703016
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.907608695652174
# neuron unit number: 140
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96
# error_data0_score_W0 0.6
# combinedweight shape 0: (280, 12)
# right_data0_score_W' 0.9655172413793104
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (420, 12)
# right_data1_score_W' 0.8333333333333334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9419953596287703
# test_score_W': split_num : 0 0.9021739130434783
# all_train_score_W' split_num : 1 0.9976798143851509
# test_score_W': split_num : 1 0.9021739130434783
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.9021739130434783
# neuron unit number: 145
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8461538461538461
# error_data0_score_W0 0.46153846153846156
# combinedweight shape 0: (290, 12)
# right_data0_score_W' 0.9703703703703703
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (435, 12)
# right_data1_score_W' 1.0
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9396751740139211
# test_score_W': split_num : 0 0.875
# all_train_score_W' split_num : 1 0.9907192575406032
# test_score_W': split_num : 1 0.8858695652173914
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8858695652173914
# neuron unit number: 150
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9545454545454546
# error_data0_score_W0 0.5454545454545454
# combinedweight shape 0: (300, 12)
# right_data0_score_W' 0.9682151589242054
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (450, 12)
# right_data1_score_W' 0.9047619047619048
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.9489559164733179
# test_score_W': split_num : 0 0.8967391304347826
# all_train_score_W' split_num : 1 0.9976798143851509
# test_score_W': split_num : 1 0.8858695652173914
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.8858695652173914

# %%
# local scope2
scoretype = 1
scope_num = 30
class_num = 5
dim_num = 12
unstable_repeat_num = 1


unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 5
# *******************
#
# Error Data percentage 0.12761020881670534
# right_data0_score_W0 1.0
# error_data0_score_W1 0.17147017287345312
# error_data0_score_W0 0.055549463445433316
# combinedweight shape 0: (10, 12)
# right_data0_score_W' 0.35825282124518687
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.13428125739333482
# error_data1_score_W0 0.0
# combinedweight shape1 : (15, 12)
# right_data1_score_W' 0.5829691156123314
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5602283991224877
# error_data2_score_W0 0.3647240145553263
# combinedweight shape1 : (20, 12)
# right_data2_score_W' 0.5118677282161289
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.0
# combinedweight shape1 : (25, 12)
# right_data3_score_W' 0.7699888529362955
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.1088318271387047
# all_train_score_W': 1.0
# test_score_W0 : 0.0
# test_score_W': 0.5970265453513499
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.11136890951276102
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3405796550218781
# error_data0_score_W0 0.258575177267481
# combinedweight shape 0: (20, 12)
# right_data0_score_W' 0.6121082567430715
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6598272202021846
# error_data1_score_W0 0.3814844950785301
# combinedweight shape1 : (30, 12)
# right_data1_score_W' 0.44424896401061703
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (40, 12)
# right_data2_score_W' 0.530560316842977
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.40086799248231675
# all_train_score_W': 1.0
# test_score_W0 : 0.39806752480420565
# test_score_W': 0.5022794659226641
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.10208816705336426
# right_data0_score_W0 1.0
# error_data0_score_W1 0.27984580872008447
# error_data0_score_W0 0.10719613103377484
# combinedweight shape 0: (30, 12)
# right_data0_score_W' 0.6247748422102969
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6242190238986947
# error_data1_score_W0 0.2581064227572817
# combinedweight shape1 : (45, 12)
# right_data1_score_W' 0.4833989630704991
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (60, 12)
# right_data2_score_W' 0.7368935845192994
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.402011934767055
# all_train_score_W': 1.0
# test_score_W0 : 0.33699358869456797
# test_score_W': 0.5615303217469364
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.09976798143851508
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5280295230488669
# error_data0_score_W0 0.19040498112401166
# combinedweight shape 0: (40, 12)
# right_data0_score_W' 0.5083259398915008
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4376652075111212
# combinedweight shape1 : (60, 12)
# right_data1_score_W' 0.49211607345775044
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4455771541704542
# all_train_score_W': 1.0
# test_score_W0 : 0.4063218026836618
# test_score_W': 0.5049866014187433
# neuron unit number: 25
# *******************
#
# Error Data percentage 0.09280742459396751
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5959199449709743
# error_data0_score_W0 0.21137398467488652
# combinedweight shape 0: (50, 12)
# right_data0_score_W' 0.40407174399614787
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4995511825382859
# combinedweight shape1 : (75, 12)
# right_data1_score_W' 0.539954661077264
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4307959019369069
# all_train_score_W': 1.0
# test_score_W0 : 0.39174344868967453
# test_score_W': 0.562186250394899
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.10208816705336426
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6581607921602391
# error_data0_score_W0 0.2306533687064719
# combinedweight shape 0: (60, 12)
# right_data0_score_W' 0.5539133351027962
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7242762259301011
# combinedweight shape1 : (90, 12)
# right_data1_score_W' 0.554575792361063
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4049925798700119
# all_train_score_W': 1.0
# test_score_W0 : 0.31903252644811103
# test_score_W': 0.5972031119776844
# neuron unit number: 35
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6082990214531095
# error_data0_score_W0 0.2047749550451442
# combinedweight shape 0: (70, 12)
# right_data0_score_W' 0.4109577208495084
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5050000136037719
# combinedweight shape1 : (105, 12)
# right_data1_score_W' 0.7538501791856901
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5440591347015897
# all_train_score_W': 1.0
# test_score_W0 : 0.4721500768787662
# test_score_W': 0.5119150315494763
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6616955990012316
# error_data0_score_W0 0.3088246687437751
# combinedweight shape 0: (80, 12)
# right_data0_score_W' 0.45769507690690975
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4568876526410577
# combinedweight shape1 : (120, 12)
# right_data1_score_W' 0.6156996242675866
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6264662637135693
# all_train_score_W': 1.0
# test_score_W0 : 0.5421435293053627
# test_score_W': 0.5694528263836295
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5212222918785748
# error_data0_score_W0 0.28074366878533075
# combinedweight shape 0: (90, 12)
# right_data0_score_W' 0.3504112802330138
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8602254409666873
# error_data1_score_W0 0.3269226590644757
# combinedweight shape1 : (135, 12)
# right_data1_score_W' 0.52056838769
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (180, 12)
# right_data2_score_W' 0.8633416908739602
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5382547194745864
# all_train_score_W': 1.0
# test_score_W0 : 0.5105642394605284
# test_score_W': 0.49097903966136963
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7034663806317463
# error_data0_score_W0 0.37468917749853414
# combinedweight shape 0: (100, 12)
# right_data0_score_W' 0.4085994652295931
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.16336407391907906
# combinedweight shape1 : (150, 12)
# right_data1_score_W' 0.5933634455973422
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.541375818615616
# all_train_score_W': 1.0
# test_score_W0 : 0.520843041177964
# test_score_W': 0.5686164668054912
# neuron unit number: 55
# *******************
#
# Error Data percentage 0.08816705336426914
# right_data0_score_W0 1.0
# error_data0_score_W1 0.683332377169928
# error_data0_score_W0 0.2520363113603924
# combinedweight shape 0: (110, 12)
# right_data0_score_W' 0.38010337706685837
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.43432493114887843
# combinedweight shape1 : (165, 12)
# right_data1_score_W' 0.8439818941653644
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.4735120828188049
# all_train_score_W': 1.0
# test_score_W0 : 0.4428112867218396
# test_score_W': 0.5408240081613633
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.08120649651972157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7278823116261223
# error_data0_score_W0 0.4793857697911849
# combinedweight shape 0: (120, 12)
# right_data0_score_W' 0.4490803212455307
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6515533942552646
# combinedweight shape1 : (180, 12)
# right_data1_score_W' 0.5426900918496365
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5622547273352103
# all_train_score_W': 1.0
# test_score_W0 : 0.4640075955403797
# test_score_W': 0.5611320363542928
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.836155804496103
# error_data0_score_W0 0.28824662183339755
# combinedweight shape 0: (130, 12)
# right_data0_score_W' 0.35911424723007035
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7336804366512112
# combinedweight shape1 : (195, 12)
# right_data1_score_W' 0.6368706466401166
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5255884075029735
# all_train_score_W': 1.0
# test_score_W0 : 0.5149259797923001
# test_score_W': 0.6077827231639451
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7778164965745453
# error_data0_score_W0 0.23892248815956021
# combinedweight shape 0: (140, 12)
# right_data0_score_W' 0.4368356262327898
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5771596324111234
# combinedweight shape1 : (210, 12)
# right_data1_score_W' 0.47699671276291045
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5566637626276579
# all_train_score_W': 1.0
# test_score_W0 : 0.44601905219672705
# test_score_W': 0.5486392046952129
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8075588922381141
# error_data0_score_W0 0.3963120944433575
# combinedweight shape 0: (150, 12)
# right_data0_score_W' 0.3148586301065035
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7336804366512112
# combinedweight shape1 : (225, 12)
# right_data1_score_W' 0.8096752390213187
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5602022031048409
# all_train_score_W': 1.0
# test_score_W0 : 0.46313718432780027
# test_score_W': 0.48766796938732926
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.08584686774941995
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7100656487189986
# error_data0_score_W0 0.11036710879969601
# combinedweight shape 0: (160, 12)
# right_data0_score_W' 0.3084112348699813
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.3063371471741693
# combinedweight shape1 : (240, 12)
# right_data1_score_W' 0.6118383935612405
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.47712154168044435
# all_train_score_W': 1.0
# test_score_W0 : 0.4716318301439422
# test_score_W': 0.5421523925325972
# neuron unit number: 85
# *******************
#
# Error Data percentage 0.06728538283062645
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7644857551093839
# error_data0_score_W0 0.31331523076147916
# combinedweight shape 0: (170, 12)
# right_data0_score_W' 0.4828292045423544
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (255, 12)
# right_data1_score_W' 0.6388648111688869
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6220431599247735
# all_train_score_W': 1.0
# test_score_W0 : 0.5239817985182886
# test_score_W': 0.5554243308722212
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8753459136461582
# error_data0_score_W0 0.23390711398259928
# combinedweight shape 0: (180, 12)
# right_data0_score_W' 0.3808083298213334
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (270, 12)
# right_data1_score_W' 0.6614180637520272
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5351134653919088
# all_train_score_W': 1.0
# test_score_W0 : 0.6107342664389063
# test_score_W': 0.6078331191906956
# neuron unit number: 95
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8540491819240145
# error_data0_score_W0 0.38852204996649625
# combinedweight shape 0: (190, 12)
# right_data0_score_W' 0.35197528156188684
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (285, 12)
# right_data1_score_W' 0.5974769391150749
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5594905578593868
# all_train_score_W': 1.0
# test_score_W0 : 0.4901968209457831
# test_score_W': 0.5478954544706307
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7702215346846897
# error_data0_score_W0 0.3624696006807224
# combinedweight shape 0: (200, 12)
# right_data0_score_W' 0.3951730923943278
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7336804366512112
# combinedweight shape1 : (300, 12)
# right_data1_score_W' 0.7075298394219068
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5992371192416238
# all_train_score_W': 1.0
# test_score_W0 : 0.5201518022846428
# test_score_W': 0.5908408616963678
# neuron unit number: 105
# *******************
#
# Error Data percentage 0.06264501160092807
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8007634277638344
# error_data0_score_W0 0.268338920623915
# combinedweight shape 0: (210, 12)
# right_data0_score_W' 0.4079379911712841
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.3437110184854508
# combinedweight shape1 : (315, 12)
# right_data1_score_W' 0.6622017476034987
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5955579945322378
# all_train_score_W': 1.0
# test_score_W0 : 0.5414207576369251
# test_score_W': 0.5508182005769411
# neuron unit number: 110
# *******************
#
# Error Data percentage 0.08352668213457076
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6278865365510711
# error_data0_score_W0 0.2802302795612153
# combinedweight shape 0: (220, 12)
# right_data0_score_W' 0.4203901144918449
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7020168761809934
# combinedweight shape1 : (330, 12)
# right_data1_score_W' 0.569475001226128
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.49409308922180933
# all_train_score_W': 1.0
# test_score_W0 : 0.3153406437981843
# test_score_W': 0.47434186757151064
# neuron unit number: 115
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7913309170590276
# error_data0_score_W0 0.3193361183770992
# combinedweight shape 0: (230, 12)
# right_data0_score_W' 0.3931300634051629
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (345, 12)
# right_data1_score_W' 0.6387296770398382
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5589205025805115
# all_train_score_W': 1.0
# test_score_W0 : 0.38128898558353175
# test_score_W': 0.4980340698713453
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6881390244353358
# error_data0_score_W0 0.34018714882162376
# combinedweight shape 0: (240, 12)
# right_data0_score_W' 0.3602892099194786
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6712694853274374
# combinedweight shape1 : (360, 12)
# right_data1_score_W' 0.386738772193474
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5944053862535568
# all_train_score_W': 1.0
# test_score_W0 : 0.5736921635484897
# test_score_W': 0.5661999685478883
# neuron unit number: 125
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.889994578396936
# error_data0_score_W0 0.30022602608778926
# combinedweight shape 0: (250, 12)
# right_data0_score_W' 0.43973813630483904
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (375, 12)
# right_data1_score_W' 0.6055429698839818
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5890517917614229
# all_train_score_W': 1.0
# test_score_W0 : 0.45180884304944774
# test_score_W': 0.5189684031675715
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7614340951031745
# error_data0_score_W0 0.281772488886974
# combinedweight shape 0: (260, 12)
# right_data0_score_W' 0.4417227543065988
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.39999999999999997
# combinedweight shape1 : (390, 12)
# right_data1_score_W' 0.4755490348952039
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5447873377750363
# all_train_score_W': 1.0
# test_score_W0 : 0.5173838259965692
# test_score_W': 0.5154592705333677
# neuron unit number: 135
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8189190326171495
# error_data0_score_W0 0.25273899976979247
# combinedweight shape 0: (270, 12)
# right_data0_score_W' 0.4692438102179362
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2740175421212811
# combinedweight shape1 : (405, 12)
# right_data1_score_W' 0.7349457899389306
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5013444755430384
# all_train_score_W': 1.0
# test_score_W0 : 0.3058988428254806
# test_score_W': 0.3844213085534715
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8155488218151493
# error_data0_score_W0 0.2977091410105518
# combinedweight shape 0: (280, 12)
# right_data0_score_W' 0.33799949176779526
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (420, 12)
# right_data1_score_W' 0.596632346523101
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5747740009961889
# all_train_score_W': 1.0
# test_score_W0 : 0.43165381052875823
# test_score_W': 0.49202272098695826
# neuron unit number: 145
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6772469981131813
# error_data0_score_W0 0.26222355008355486
# combinedweight shape 0: (290, 12)
# right_data0_score_W' 0.41895037967712573
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6515533942552646
# combinedweight shape1 : (435, 12)
# right_data1_score_W' 0.6542689670743776
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5522535307996103
# all_train_score_W': 1.0
# test_score_W0 : 0.5274990550839656
# test_score_W': 0.5563348486305476
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7837555956268668
# error_data0_score_W0 0.3583664344879407
# combinedweight shape 0: (300, 12)
# right_data0_score_W' 0.5198525068595922
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2740175421212811
# combinedweight shape1 : (450, 12)
# right_data1_score_W' 0.5738276140762859
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6078880158530171
# all_train_score_W': 1.0
# test_score_W0 : 0.4820480076845285
# test_score_W': 0.5388135666556664
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.445783  0.114427  0.020891   0.403055  0.488511
# 1  test_score_W'  30.0  0.538393  0.047332  0.008642   0.520719  0.556067
# 2       combined  60.0  0.492088  0.098577  0.012726   0.466623  0.517553
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0926
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -4.0963
# 3                       Two side test p value =    0.0001
# 4                      Difference < 0 p value =    0.0001
# 5                      Difference > 0 p value =    0.9999
# 6                                   Cohen's d =   -1.0577
# 7                                   Hedge's g =   -1.0439
# 8                               Glass's delta =   -0.8093
# 9                                 Pearson's r =    0.4737
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-4.09629192497004, pvalue=6.596128810876402e-05)

# %%
scoretype = 1
scope_num = 30
class_num = 5
dim_num = 12
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 5
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.048358479497020525
# error_data0_score_W0 0.18435640752452273
# combinedweight shape 0: (10, 12)
# right_data0_score_W' 0.8583187483903157
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2725768861531576
# error_data1_score_W0 0.15215551536851848
# combinedweight shape1 : (15, 12)
# right_data1_score_W' 0.14238709052891138
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.44346248805000243
# error_data2_score_W0 0.44346248805000243
# combinedweight shape1 : (20, 12)
# right_data2_score_W' 0.2658169593679178
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (25, 12)
# right_data3_score_W' 0.4739909923274765
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W' split_num : 0 0.35875171235160275
# test_score_W': split_num : 0 0.3304774728894529
# all_train_score_W' split_num : 1 0.6682842937594403
# test_score_W': split_num : 1 0.49767607286726034
# all_train_score_W' split_num : 2 0.8736023506047824
# test_score_W': split_num : 2 0.5142935926182218
# all_train_score_W' split_num : 3 0.9801164199634174
# test_score_W': split_num : 3 0.5536918107615428
# all_train_score_W' split_num : 4 1.0
# test_score_W': split_num : 4 0.5536918107615428
# neuron unit number: 10
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.1445584140668828
# error_data0_score_W0 0.20659144111256864
# combinedweight shape 0: (20, 12)
# right_data0_score_W' 0.7027690499544236
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2594478348576218
# error_data1_score_W0 0.09193520332769457
# combinedweight shape1 : (30, 12)
# right_data1_score_W' 0.36549955555914326
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.696865496849293
# error_data2_score_W0 0.1941862739736645
# combinedweight shape1 : (40, 12)
# right_data2_score_W' 0.47709948666206814
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (50, 12)
# right_data3_score_W' 0.7864379259835012
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W' split_num : 0 0.4843066159798016
# test_score_W': split_num : 0 0.45026561162655787
# all_train_score_W' split_num : 1 0.7180838532840613
# test_score_W': split_num : 1 0.454004145065902
# all_train_score_W' split_num : 2 0.8803090866542638
# test_score_W': split_num : 2 0.47868241386111626
# all_train_score_W' split_num : 3 0.9872486267471623
# test_score_W': split_num : 3 0.5210409286972748
# all_train_score_W' split_num : 4 1.0
# test_score_W': split_num : 4 0.5210409286972748
# neuron unit number: 15
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3469832089596584
# error_data0_score_W0 0.21328199940139428
# combinedweight shape 0: (30, 12)
# right_data0_score_W' 0.7899351974522859
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6302852238191594
# error_data1_score_W0 0.18867826999798382
# combinedweight shape1 : (45, 12)
# right_data1_score_W' 0.601061091107403
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (60, 12)
# right_data2_score_W' 0.5243237069293185
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.2815630727283939
# test_score_W': split_num : 0 0.28002910126340946
# all_train_score_W' split_num : 1 0.7127503432086383
# test_score_W': split_num : 1 0.5046413505435089
# all_train_score_W' split_num : 2 0.9311444238296769
# test_score_W': split_num : 2 0.5487708457299936
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.5595752829658702
# neuron unit number: 20
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.45964837572687833
# error_data0_score_W0 0.1481281848336465
# combinedweight shape 0: (40, 12)
# right_data0_score_W' 0.6809290535117878
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4860206166722178
# error_data1_score_W0 0.0
# combinedweight shape1 : (60, 12)
# right_data1_score_W' 0.5222929030754574
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (80, 12)
# right_data2_score_W' 0.5211652822887296
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.2406870569649023
# test_score_W': split_num : 0 0.16774026016608573
# all_train_score_W' split_num : 1 0.7867818202970245
# test_score_W': split_num : 1 0.5331330606680441
# all_train_score_W' split_num : 2 0.9507854760171974
# test_score_W': split_num : 2 0.5654444609121011
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.5654444609121011
# neuron unit number: 25
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.49370014555404357
# error_data0_score_W0 0.16961315924615852
# combinedweight shape 0: (50, 12)
# right_data0_score_W' 0.8212183341096926
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8772581397357428
# error_data1_score_W0 0.1880240644828777
# combinedweight shape1 : (75, 12)
# right_data1_score_W' 0.5104687182611827
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (100, 12)
# right_data2_score_W' 0.6954082315726281
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.34698393236768094
# test_score_W': split_num : 0 0.19842877480732785
# all_train_score_W' split_num : 1 0.8169235805665478
# test_score_W': split_num : 1 0.4252258447718265
# all_train_score_W' split_num : 2 0.9840823842719755
# test_score_W': split_num : 2 0.46873420270303645
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.46873420270303645
# neuron unit number: 30
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7461572511958758
# error_data0_score_W0 0.2814911110518002
# combinedweight shape 0: (60, 12)
# right_data0_score_W' 0.5770120191784611
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.39472833517573314
# combinedweight shape1 : (90, 12)
# right_data1_score_W' 0.5644823046139033
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.47797212756787555
# test_score_W': split_num : 0 0.39743019478556624
# all_train_score_W' split_num : 1 0.9124387631556503
# test_score_W': split_num : 1 0.5524744134201797
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5417425211462953
# neuron unit number: 35
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5448641166552753
# error_data0_score_W0 0.225430153158484
# combinedweight shape 0: (70, 12)
# right_data0_score_W' 0.4392605183936633
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8242526198390177
# error_data1_score_W0 0.21562784662024478
# combinedweight shape1 : (105, 12)
# right_data1_score_W' 0.46991618863383483
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (140, 12)
# right_data2_score_W' 0.7182659441747598
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W' split_num : 0 0.3890332912601193
# test_score_W': split_num : 0 0.3370927591513958
# all_train_score_W' split_num : 1 0.8172142499603315
# test_score_W': split_num : 1 0.49752643468310015
# all_train_score_W' split_num : 2 0.9824158456514211
# test_score_W': split_num : 2 0.5163013937141913
# all_train_score_W' split_num : 3 1.0
# test_score_W': split_num : 3 0.5163013937141913
# neuron unit number: 40
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7438143007280665
# error_data0_score_W0 0.3683595938556112
# combinedweight shape 0: (80, 12)
# right_data0_score_W' 0.4425029222278474
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (120, 12)
# right_data1_score_W' 0.6149682422221334
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6307070802292628
# test_score_W': split_num : 0 0.47169501717416157
# all_train_score_W' split_num : 1 0.9565166982815781
# test_score_W': split_num : 1 0.5337032360906263
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5676108902230188
# neuron unit number: 45
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7137576701025956
# error_data0_score_W0 0.21154705745393168
# combinedweight shape 0: (90, 12)
# right_data0_score_W' 0.3163877085090857
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (135, 12)
# right_data1_score_W' 0.5479866319785744
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5477688668767878
# test_score_W': split_num : 0 0.41642357103087974
# all_train_score_W' split_num : 1 0.9440470052401894
# test_score_W': split_num : 1 0.4963806179273819
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.4805595388289301
# neuron unit number: 50
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7088407739969921
# error_data0_score_W0 0.20229979243964746
# combinedweight shape 0: (100, 12)
# right_data0_score_W' 0.581906185797828
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (150, 12)
# right_data1_score_W' 0.3690127127260757
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5105725341348637
# test_score_W': split_num : 0 0.40382137083278113
# all_train_score_W' split_num : 1 0.9225260282294832
# test_score_W': split_num : 1 0.5167301546702948
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.48815704795877635
# neuron unit number: 55
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7257259497071246
# error_data0_score_W0 0.2910123314527857
# combinedweight shape 0: (110, 12)
# right_data0_score_W' 0.2693058910605055
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2693558349079911
# combinedweight shape1 : (165, 12)
# right_data1_score_W' 0.7054585216162846
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.556962859389937
# test_score_W': split_num : 0 0.4205718874567241
# all_train_score_W' split_num : 1 0.9176874077477644
# test_score_W': split_num : 1 0.4788769897546519
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.47889419046649656
# neuron unit number: 60
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.3172338623770718
# combinedweight shape 0: (120, 12)
# right_data0_score_W' 0.448439628986372
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W' split_num : 0 0.6821247073799455
# test_score_W': split_num : 0 0.45573366530753423
# all_train_score_W' split_num : 1 1.0
# test_score_W': split_num : 1 0.484274062358571
# neuron unit number: 65
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.794735307559819
# error_data0_score_W0 0.2548312161398607
# combinedweight shape 0: (130, 12)
# right_data0_score_W' 0.5183568040891161
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2740175421212811
# combinedweight shape1 : (195, 12)
# right_data1_score_W' 0.5532553589884477
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5904940816340188
# test_score_W': split_num : 0 0.46148615006258425
# all_train_score_W' split_num : 1 0.9565166982815781
# test_score_W': split_num : 1 0.5332476184031797
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5409271952829445
# neuron unit number: 70
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8180622406806852
# error_data0_score_W0 0.2139305904219261
# combinedweight shape 0: (140, 12)
# right_data0_score_W' 0.35104737196189695
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (210, 12)
# right_data1_score_W' 0.7352476106386159
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5167271830652095
# test_score_W': split_num : 0 0.5037717822900565
# all_train_score_W' split_num : 1 0.9671194102436592
# test_score_W': split_num : 1 0.5201327733360813
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5722770549873343
# neuron unit number: 75
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6901953516324303
# error_data0_score_W0 0.25484324785852125
# combinedweight shape 0: (150, 12)
# right_data0_score_W' 0.3985003293297817
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.3586599605575701
# combinedweight shape1 : (225, 12)
# right_data1_score_W' 0.5866282084415352
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6096084713960239
# test_score_W': split_num : 0 0.41127762256549155
# all_train_score_W' split_num : 1 0.9372408509258198
# test_score_W': split_num : 1 0.43553119781231087
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.43247470346503664
# neuron unit number: 80
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8144272205079164
# error_data0_score_W0 0.2676085030887711
# combinedweight shape 0: (160, 12)
# right_data0_score_W' 0.4049667977254374
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (240, 12)
# right_data1_score_W' 0.7634906695602708
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6037326701340646
# test_score_W': split_num : 0 0.42677597298835884
# all_train_score_W' split_num : 1 0.9515324045598863
# test_score_W': split_num : 1 0.47638227926367455
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.46324803917455454
# neuron unit number: 85
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7561625148653935
# error_data0_score_W0 0.21824960360299
# combinedweight shape 0: (170, 12)
# right_data0_score_W' 0.4123177887398307
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (255, 12)
# right_data1_score_W' 0.7409568534980415
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6016806639862933
# test_score_W': split_num : 0 0.5282050544775295
# all_train_score_W' split_num : 1 0.9432382814588404
# test_score_W': split_num : 1 0.5839318186298352
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.6009440603739051
# neuron unit number: 90
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.2667360982459333
# combinedweight shape 0: (180, 12)
# right_data0_score_W' 0.33982174497917694
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W' split_num : 0 0.6019682483621313
# test_score_W': split_num : 0 0.41844123330998884
# all_train_score_W' split_num : 1 1.0
# test_score_W': split_num : 1 0.5021106308226355
# neuron unit number: 95
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 1.0
# error_data0_score_W0 0.3106362315119492
# combinedweight shape 0: (190, 12)
# right_data0_score_W' 0.37164711137289297
# Finish one splitting *********
# 1
#  NO Error Data, Finish Training!
# split_num 1
# all_train_score_W' split_num : 0 0.6475716754622802
# test_score_W': split_num : 0 0.4143141890014498
# all_train_score_W' split_num : 1 1.0
# test_score_W': split_num : 1 0.4466334487073605
# neuron unit number: 100
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9067933713346947
# error_data0_score_W0 0.20715515418783298
# combinedweight shape 0: (200, 12)
# right_data0_score_W' 0.425276464030371
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (300, 12)
# right_data1_score_W' 0.7607146952542877
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6126341156776623
# test_score_W': split_num : 0 0.3712207535015072
# all_train_score_W' split_num : 1 0.9824158456514211
# test_score_W': split_num : 1 0.5209282399904182
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5066007330780744
# neuron unit number: 105
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.538820178867253
# error_data0_score_W0 0.1783440493056216
# combinedweight shape 0: (210, 12)
# right_data0_score_W' 0.3806543336678115
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2569262457413678
# combinedweight shape1 : (315, 12)
# right_data1_score_W' 0.7397359006648703
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5163356240466733
# test_score_W': split_num : 0 0.31466673032737724
# all_train_score_W' split_num : 1 0.8867376102067624
# test_score_W': split_num : 1 0.5162524950942171
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5212192235636697
# neuron unit number: 110
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9304594359857494
# error_data0_score_W0 0.2631409512237142
# combinedweight shape 0: (220, 12)
# right_data0_score_W' 0.42314544798707787
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (330, 12)
# right_data1_score_W' 0.7012532929922551
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.527224731581516
# test_score_W': split_num : 0 0.34394051902732703
# all_train_score_W' split_num : 1 0.9832315277381695
# test_score_W': split_num : 1 0.5190081307867187
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5190081307867187
# neuron unit number: 115
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7764420741971452
# error_data0_score_W0 0.19137857849622916
# combinedweight shape 0: (230, 12)
# right_data0_score_W' 0.5190087530976873
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (345, 12)
# right_data1_score_W' 0.5843515411688849
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5210018406945799
# test_score_W': split_num : 0 0.32797117029214856
# all_train_score_W' split_num : 1 0.9671194102436592
# test_score_W': split_num : 1 0.5075317040607287
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5219717962571382
# neuron unit number: 120
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8947665465804299
# error_data0_score_W0 0.218860963100611
# combinedweight shape 0: (240, 12)
# right_data0_score_W' 0.5251757180075254
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (360, 12)
# right_data1_score_W' 0.6502340196689813
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6489764793024043
# test_score_W': split_num : 0 0.5033902177315491
# all_train_score_W' split_num : 1 0.976950986074647
# test_score_W': split_num : 1 0.5081539807566535
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5081666558599979
# neuron unit number: 125
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.62875381498874
# error_data0_score_W0 0.30002399678404723
# combinedweight shape 0: (250, 12)
# right_data0_score_W' 0.3632294480151382
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (375, 12)
# right_data1_score_W' 0.5948370482025545
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5473236940990699
# test_score_W': split_num : 0 0.39886371773114465
# all_train_score_W' split_num : 1 0.907954905669693
# test_score_W': split_num : 1 0.5461360643893352
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5471478736475951
# neuron unit number: 130
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.839478886231599
# error_data0_score_W0 0.29938901689890207
# combinedweight shape 0: (260, 12)
# right_data0_score_W' 0.3099369478210964
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (390, 12)
# right_data1_score_W' 0.6550438780817864
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5732599130913355
# test_score_W': split_num : 0 0.4424996285418953
# all_train_score_W' split_num : 1 0.9601886858505589
# test_score_W': split_num : 1 0.46574165662455147
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.46574165662455147
# neuron unit number: 135
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8347772976500389
# error_data0_score_W0 0.3184244086742074
# combinedweight shape 0: (270, 12)
# right_data0_score_W' 0.4477500813924469
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (405, 12)
# right_data1_score_W' 0.6325542860057444
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6302040521229101
# test_score_W': split_num : 0 0.48321496711216605
# all_train_score_W' split_num : 1 0.9704370861734845
# test_score_W': split_num : 1 0.5169394136256134
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5312207671966431
# neuron unit number: 140
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6719936632485758
# error_data0_score_W0 0.26407577649191355
# combinedweight shape 0: (280, 12)
# right_data0_score_W' 0.48899312186469124
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.3586599605575701
# combinedweight shape1 : (420, 12)
# right_data1_score_W' 0.5256277650059583
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.533712178970946
# test_score_W': split_num : 0 0.4564510807010716
# all_train_score_W' split_num : 1 0.9249710122283176
# test_score_W': split_num : 1 0.5022919883340698
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5127524477265548
# neuron unit number: 145
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9094978347609111
# error_data0_score_W0 0.2722207567162153
# combinedweight shape 0: (290, 12)
# right_data0_score_W' 0.39035420943936877
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (435, 12)
# right_data1_score_W' 0.5216242997024002
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.6349838138041138
# test_score_W': split_num : 0 0.5178669778290502
# all_train_score_W' split_num : 1 0.9840823842719755
# test_score_W': split_num : 1 0.5440901740181888
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.5440901740181888
# neuron unit number: 150
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.737556436108435
# error_data0_score_W0 0.2630158442696191
# combinedweight shape 0: (300, 12)
# right_data0_score_W' 0.3682965489265617
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (450, 12)
# right_data1_score_W' 0.7052123658100048
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W' split_num : 0 0.5532522247264646
# test_score_W': split_num : 0 0.39701843928921376
# all_train_score_W' split_num : 1 0.953189379034402
# test_score_W': split_num : 1 0.44263513151497536
# all_train_score_W' split_num : 2 1.0
# test_score_W': split_num : 2 0.4462554785014214

# %%
# local scope2
scoretype = 2
scope_num = 30
class_num = 5
dim_num = 12
unstable_repeat_num = 1


unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 5
# *******************
#
# Error Data percentage 0.10440835266821345
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03976273139138422
# error_data0_score_W0 0.009011029336812705
# combinedweight shape 0: (10, 12)
# right_data0_score_W' 0.8977996495820606
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.1735112936344969
# error_data1_score_W0 0.060761491418425725
# combinedweight shape1 : (15, 12)
# right_data1_score_W' 0.1440430783037918
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3739130434782609
# error_data2_score_W0 0.3739130434782609
# combinedweight shape1 : (20, 12)
# right_data2_score_W' 0.025281453683586808
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.0
# combinedweight shape1 : (25, 12)
# right_data3_score_W' 0.411214953271028
# Finish one training *********
# 4
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5816239397874573
# all_train_score_W': 1.0
# test_score_W0 : 0.7006262407328009
# test_score_W': 0.8146256972390623
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.12064965197215777
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07315282239559431
# error_data0_score_W0 0.019304593505968356
# combinedweight shape 0: (20, 12)
# right_data0_score_W' 0.6865748375745004
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.39756782039289057
# error_data1_score_W0 0.08830054725632303
# combinedweight shape1 : (30, 12)
# right_data1_score_W' 0.11168979643685097
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 -0.1111111111111111
# combinedweight shape1 : (40, 12)
# right_data2_score_W' 0.2897235703734965
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.26313367526502685
# all_train_score_W': 1.0
# test_score_W0 : 0.2161170985844692
# test_score_W': 0.7906299438353259
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.10672853828306264
# right_data0_score_W0 1.0
# error_data0_score_W1 0.1767812544740149
# error_data0_score_W0 0.05006385318933763
# combinedweight shape 0: (30, 12)
# right_data0_score_W' 0.9939381994722434
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5107296137339056
# error_data1_score_W0 0.04404540064374047
# combinedweight shape1 : (45, 12)
# right_data1_score_W' 0.49514563106796117
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.0
# combinedweight shape1 : (60, 12)
# right_data2_score_W' 0.37282229965156793
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7461210510335193
# all_train_score_W': 1.0
# test_score_W0 : 0.6740463421482047
# test_score_W': 0.6895966710098178
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.0951276102088167
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4146509567100988
# error_data0_score_W0 0.13700189232921042
# combinedweight shape 0: (40, 12)
# right_data0_score_W' 0.7487402757629624
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2028985507246377
# combinedweight shape1 : (60, 12)
# right_data1_score_W' 0.5437270126685738
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.674953335526553
# all_train_score_W': 1.0
# test_score_W0 : 0.5585493273884015
# test_score_W': 0.7401301144205512
# neuron unit number: 25
# *******************
#
# Error Data percentage 0.09976798143851508
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3667484821082547
# error_data0_score_W0 0.10154512466346717
# combinedweight shape 0: (50, 12)
# right_data0_score_W' 0.4420730217960897
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8450704225352113
# error_data1_score_W0 -0.1239356669820246
# combinedweight shape1 : (75, 12)
# right_data1_score_W' 0.24409316404607753
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (100, 12)
# right_data2_score_W' 0.5152542372881356
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6137100387372844
# all_train_score_W': 1.0
# test_score_W0 : 0.6987099989943187
# test_score_W': 0.8132422433144139
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.09744779582366589
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3590991478154635
# error_data0_score_W0 0.04165375744431822
# combinedweight shape 0: (60, 12)
# right_data0_score_W' 0.31752375780890735
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6972477064220184
# error_data1_score_W0 -0.08674698795180723
# combinedweight shape1 : (90, 12)
# right_data1_score_W' 0.4013345381246959
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 1.0
# Error data can be represented by W0 2
# combinedweight shape1 : (120, 12)
# right_data2_score_W' 1.0
# Finish one training *********
# 3
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.6217390203620555
# all_train_score_W': 1.0
# test_score_W0 : 0.5420237434463941
# test_score_W': 0.7572435495421301
# neuron unit number: 35
# *******************
#
# Error Data percentage 0.09280742459396751
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5394833948339484
# error_data0_score_W0 0.3479589238733769
# combinedweight shape 0: (70, 12)
# right_data0_score_W' 0.35909399783228696
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (105, 12)
# right_data1_score_W' 0.37936384794414274
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.699888692504874
# all_train_score_W': 1.0
# test_score_W0 : 0.6661731444743064
# test_score_W': 0.8181392157416473
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9325265758139276
# error_data0_score_W0 0.2479775543605331
# combinedweight shape 0: (80, 12)
# right_data0_score_W' 0.30110838858369476
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (120, 12)
# right_data1_score_W' 0.4846012108449592
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.756480805109004
# all_train_score_W': 1.0
# test_score_W0 : 0.5978787022497912
# test_score_W': 0.7035635235544608
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.08816705336426914
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6866526771271028
# error_data0_score_W0 0.03974732523717396
# combinedweight shape 0: (90, 12)
# right_data0_score_W' 0.36336465951164826
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (135, 12)
# right_data1_score_W' 0.14609739826551035
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7206036173311278
# all_train_score_W': 1.0
# test_score_W0 : 0.5371161869978658
# test_score_W': 0.7443845614955841
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5508021390374331
# error_data0_score_W0 0.12396694214876033
# combinedweight shape 0: (100, 12)
# right_data0_score_W' 0.32859744816071823
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2857142857142857
# combinedweight shape1 : (150, 12)
# right_data1_score_W' 0.46295786284770035
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8489143608885372
# all_train_score_W': 1.0
# test_score_W0 : 0.6690593844064795
# test_score_W': 0.7352964843394865
# neuron unit number: 55
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5702438049560352
# error_data0_score_W0 0.01445945945945946
# combinedweight shape 0: (110, 12)
# right_data0_score_W' 0.3128816020383521
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.25
# combinedweight shape1 : (165, 12)
# right_data1_score_W' 0.40173097728092316
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.758377100591278
# all_train_score_W': 1.0
# test_score_W0 : 0.658222201245126
# test_score_W': 0.7903936263527351
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.0951276102088167
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5266127268751367
# error_data0_score_W0 0.06311871976181616
# combinedweight shape 0: (120, 12)
# right_data0_score_W' 0.6892216272989531
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.12550607287449392
# combinedweight shape1 : (180, 12)
# right_data1_score_W' 0.5185450086849903
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7105996209195277
# all_train_score_W': 1.0
# test_score_W0 : 0.7110407608753313
# test_score_W': 0.7890398480991688
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.08120649651972157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5958696649839376
# error_data0_score_W0 0.10296712109061748
# combinedweight shape 0: (130, 12)
# right_data0_score_W' 0.2627518656663477
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.14285714285714285
# combinedweight shape1 : (195, 12)
# right_data1_score_W' 0.5009000307327567
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7966331918468154
# all_train_score_W': 1.0
# test_score_W0 : 0.7649749281593623
# test_score_W': 0.8199800291131804
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5530808862601946
# error_data0_score_W0 0.32655196207180537
# combinedweight shape 0: (140, 12)
# right_data0_score_W' 0.3358045063017985
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.16666666666666666
# combinedweight shape1 : (210, 12)
# right_data1_score_W' 0.15788233908485955
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8265471763330029
# all_train_score_W': 1.0
# test_score_W0 : 0.715492849146449
# test_score_W': 0.7160491569074267
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.06496519721577726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8657336695911626
# error_data0_score_W0 0.19206680584551147
# combinedweight shape 0: (150, 12)
# right_data0_score_W' 0.2849627278639586
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (225, 12)
# right_data1_score_W' 0.5026271489057798
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.803437598210332
# all_train_score_W': 1.0
# test_score_W0 : 0.6354544285931449
# test_score_W': 0.7669797154258935
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.05336426914153132
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8899521531100478
# error_data0_score_W0 0.11342490031014621
# combinedweight shape 0: (160, 12)
# right_data0_score_W' 0.3618265334963036
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (240, 12)
# right_data1_score_W' 0.34795180722891567
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8892707925587104
# all_train_score_W': 1.0
# test_score_W0 : 0.7101597944199076
# test_score_W': 0.7418609591218763
# neuron unit number: 85
# *******************
#
# Error Data percentage 0.060324825986078884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5628556647697879
# error_data0_score_W0 0.1301179276533722
# combinedweight shape 0: (170, 12)
# right_data0_score_W' 0.27098047640050266
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.3157894736842105
# combinedweight shape1 : (255, 12)
# right_data1_score_W' 0.583732057416268
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8628869237815036
# all_train_score_W': 1.0
# test_score_W0 : 0.8696824734466534
# test_score_W': 0.8139161305299295
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.09048723897911833
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5384379386963919
# error_data0_score_W0 0.08567941252976369
# combinedweight shape 0: (180, 12)
# right_data0_score_W' 0.789615565711499
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.2727272727272727
# combinedweight shape1 : (270, 12)
# right_data1_score_W' 0.2995021064726159
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.5776172258581017
# all_train_score_W': 1.0
# test_score_W0 : 0.7019438513142086
# test_score_W': 0.7752107286680847
# neuron unit number: 95
# *******************
#
# Error Data percentage 0.08120649651972157
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9074190704118906
# error_data0_score_W0 0.1722255912674348
# combinedweight shape 0: (190, 12)
# right_data0_score_W' 0.41078818347498425
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (285, 12)
# right_data1_score_W' 0.5557357771379912
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7542357389311685
# all_train_score_W': 1.0
# test_score_W0 : 0.6537768261832609
# test_score_W': 0.7907085979595581
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8185873699907745
# error_data0_score_W0 0.12413452670139385
# combinedweight shape 0: (200, 12)
# right_data0_score_W' 0.28552145883958735
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (300, 12)
# right_data1_score_W' 0.5832838656060786
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8605558590120073
# all_train_score_W': 1.0
# test_score_W0 : 0.7018485335613575
# test_score_W': 0.7668293373460198
# neuron unit number: 105
# *******************
#
# Error Data percentage 0.06264501160092807
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8655229662423907
# error_data0_score_W0 0.10379346680716543
# combinedweight shape 0: (210, 12)
# right_data0_score_W' 0.2693149578498577
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (315, 12)
# right_data1_score_W' 0.5474370090118494
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8278567244311961
# all_train_score_W': 1.0
# test_score_W0 : 0.7490186690668048
# test_score_W': 0.7836965580311378
# neuron unit number: 110
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7616065137399202
# error_data0_score_W0 0.34048083170890187
# combinedweight shape 0: (220, 12)
# right_data0_score_W' 0.3183124873161641
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.2
# combinedweight shape1 : (330, 12)
# right_data1_score_W' 0.5653301307421459
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8272322587941056
# all_train_score_W': 1.0
# test_score_W0 : 0.727541517168427
# test_score_W': 0.7921806940331763
# neuron unit number: 115
# *******************
#
# Error Data percentage 0.08352668213457076
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6984669960724693
# error_data0_score_W0 0.04214260652606136
# combinedweight shape 0: (230, 12)
# right_data0_score_W' 0.401330747709506
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.07142857142857142
# combinedweight shape1 : (345, 12)
# right_data1_score_W' 0.40964189876931617
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7542243043812836
# all_train_score_W': 1.0
# test_score_W0 : 0.656536799904679
# test_score_W': 0.7503310055662498
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5896861933521983
# error_data0_score_W0 0.16863798564612487
# combinedweight shape 0: (240, 12)
# right_data0_score_W' 0.21437456325976675
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.19047619047619047
# combinedweight shape1 : (360, 12)
# right_data1_score_W' 0.3951612903225806
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8054882686586603
# all_train_score_W': 1.0
# test_score_W0 : 0.716232594910005
# test_score_W': 0.8165551647514235
# neuron unit number: 125
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5898161244695899
# error_data0_score_W0 0.09937888198757763
# combinedweight shape 0: (250, 12)
# right_data0_score_W' 0.2721526682599054
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.17647058823529413
# combinedweight shape1 : (375, 12)
# right_data1_score_W' 0.5125193884334146
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8722381361482304
# all_train_score_W': 1.0
# test_score_W0 : 0.6630322908113353
# test_score_W': 0.7265245219811994
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.06264501160092807
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5012406947890818
# error_data0_score_W0 0.10364372469635627
# combinedweight shape 0: (260, 12)
# right_data0_score_W' 0.3943486837904582
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 -0.19047619047619047
# combinedweight shape1 : (390, 12)
# right_data1_score_W' 0.4806531771388001
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.840296999877806
# all_train_score_W': 1.0
# test_score_W0 : 0.7577832257614752
# test_score_W': 0.7590465361013785
# neuron unit number: 135
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.805184603299293
# error_data0_score_W0 0.08742861738920614
# combinedweight shape 0: (270, 12)
# right_data0_score_W' 0.3755735822928722
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (405, 12)
# right_data1_score_W' 0.4617448806823627
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8128939531378186
# all_train_score_W': 1.0
# test_score_W0 : 0.6038589855589963
# test_score_W': 0.645968330502161
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.058004640371229696
# right_data0_score_W0 1.0
# error_data0_score_W1 0.871758335708179
# error_data0_score_W0 0.18739226791430683
# combinedweight shape 0: (280, 12)
# right_data0_score_W' 0.33885046886885456
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (420, 12)
# right_data1_score_W' 0.41803404385830395
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8427452981556085
# all_train_score_W': 1.0
# test_score_W0 : 0.7591414480754617
# test_score_W': 0.7906667466403583
# neuron unit number: 145
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.65489443378119
# error_data0_score_W0 0.26630342244168226
# combinedweight shape 0: (290, 12)
# right_data0_score_W' 0.3124084351296784
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (435, 12)
# right_data1_score_W' 0.6968687541638907
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.7803619122157144
# all_train_score_W': 1.0
# test_score_W0 : 0.7911750909558849
# test_score_W': 0.8783290275679617
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8558579881656805
# error_data0_score_W0 0.1472943125345113
# combinedweight shape 0: (300, 12)
# right_data0_score_W' 0.2976931317480082
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.0
# combinedweight shape1 : (450, 12)
# right_data1_score_W' 0.5414038028852517
# Finish one training *********
# 2
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.8259189416621355
# all_train_score_W': 1.0
# test_score_W0 : 0.6920655312772541
# test_score_W': 0.7578756340627738
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.669976  0.112107  0.020468   0.628115  0.711838
# 1  test_score_W'  30.0  0.769300  0.046499  0.008490   0.751937  0.786663
# 2       combined  60.0  0.719638  0.098734  0.012746   0.694132  0.745144
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0993
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -4.4824
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.1573
# 7                                   Hedge's g =   -1.1423
# 8                               Glass's delta =   -0.8860
# 9                                 Pearson's r =    0.5072
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-4.48238873900845, pvalue=1.7663570327335004e-05)

# %%
scoretype = 0
scope_num = 60
class_num = 5
dim_num = 12
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:       
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 5
# *******************
#
# Error Data percentage 0.12761020881670534
# right_data0_score_W0 1.0
# error_data0_score_W1 0.4909090909090909
# error_data0_score_W0 0.38181818181818183
# combinedweight shape 0: (10, 12)
# right_data0_score_W' 1.0
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.5714285714285714
# error_data1_score_W0 0.5
# combinedweight shape1 : (15, 12)
# right_data1_score_W' 0.7407407407407407
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.8333333333333334
# error_data2_score_W0 0.3333333333333333
# combinedweight shape1 : (20, 12)
# right_data2_score_W' 0.6875
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 0.5
# combinedweight shape1 : (25, 12)
# right_data3_score_W' 0.6
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W0: 0.8723897911832946
# all_train_score_W': 1.0
# test_score_W0 : 0.8532608695652174
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)25
# neuron unit number: 10
# *******************
#
# Error Data percentage 0.1136890951276102
# right_data0_score_W0 1.0
# error_data0_score_W1 0.5714285714285714
# error_data0_score_W0 0.3673469387755102
# combinedweight shape 0: (20, 12)
# right_data0_score_W' 0.9842931937172775
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.6190476190476191
# error_data1_score_W0 0.3333333333333333
# combinedweight shape1 : (30, 12)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.875
# error_data2_score_W0 0.375
# combinedweight shape1 : (40, 12)
# right_data2_score_W' 0.5384615384615384
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 1.0
# error_data3_score_W0 1.0
# Error data can be represented by W0 3
# combinedweight shape1 : (50, 12)
# right_data3_score_W' 0.7142857142857143
# Finish one splitting *********
# 4
#  NO Error Data, Finish Training!
# split_num 4
# all_train_score_W0: 0.8863109048723898
# all_train_score_W': 1.0
# test_score_W0 : 0.8804347826086957
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)50
# neuron unit number: 15
# *******************
#
# Error Data percentage 0.10904872389791183
# right_data0_score_W0 1.0
# error_data0_score_W1 0.574468085106383
# error_data0_score_W0 0.3404255319148936
# combinedweight shape 0: (30, 12)
# right_data0_score_W' 0.9869791666666666
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.75
# error_data1_score_W0 0.45
# combinedweight shape1 : (45, 12)
# right_data1_score_W' 0.7037037037037037
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.8
# combinedweight shape1 : (60, 12)
# right_data2_score_W' 0.8
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.8909512761020881
# all_train_score_W': 1.0
# test_score_W0 : 0.8695652173913043
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)60
# neuron unit number: 20
# *******************
#
# Error Data percentage 0.10440835266821345
# right_data0_score_W0 1.0
# error_data0_score_W1 0.6888888888888889
# error_data0_score_W0 0.4
# combinedweight shape 0: (40, 12)
# right_data0_score_W' 0.9818652849740933
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.8571428571428571
# error_data1_score_W0 0.42857142857142855
# combinedweight shape1 : (60, 12)
# right_data1_score_W' 0.6451612903225806
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 1.0
# error_data2_score_W0 0.5
# combinedweight shape1 : (80, 12)
# right_data2_score_W' 0.9166666666666666
# Finish one splitting *********
# 3
#  NO Error Data, Finish Training!
# split_num 3
# all_train_score_W0: 0.8955916473317865
# all_train_score_W': 1.0
# test_score_W0 : 0.875
# test_score_W': 0.9293478260869565
# class_num*x*(optimize_W.split_num +1)80
# neuron unit number: 25
# *******************
#
# Error Data percentage 0.08584686774941995
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8108108108108109
# error_data0_score_W0 0.4864864864864865
# combinedweight shape 0: (50, 12)
# right_data0_score_W' 0.9644670050761421
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5714285714285714
# combinedweight shape1 : (75, 12)
# right_data1_score_W' 0.7
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.91415313225058
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)75
# neuron unit number: 30
# *******************
#
# Error Data percentage 0.09280742459396751
# right_data0_score_W0 1.0
# error_data0_score_W1 0.825
# error_data0_score_W0 0.45
# combinedweight shape 0: (60, 12)
# right_data0_score_W' 0.9718670076726342
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.7142857142857143
# combinedweight shape1 : (90, 12)
# right_data1_score_W' 0.696969696969697
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9071925754060325
# all_train_score_W': 1.0
# test_score_W0 : 0.8858695652173914
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)90
# neuron unit number: 35
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.84375
# error_data0_score_W0 0.53125
# combinedweight shape 0: (70, 12)
# right_data0_score_W' 0.9624060150375939
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4
# combinedweight shape1 : (105, 12)
# right_data1_score_W' 0.6296296296296297
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)105
# neuron unit number: 40
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.90625
# error_data0_score_W0 0.4375
# combinedweight shape 0: (80, 12)
# right_data0_score_W' 0.949874686716792
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (120, 12)
# right_data1_score_W' 0.7241379310344828
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)120
# neuron unit number: 45
# *******************
#
# Error Data percentage 0.058004640371229696
# right_data0_score_W0 1.0
# error_data0_score_W1 0.88
# error_data0_score_W0 0.48
# combinedweight shape 0: (90, 12)
# right_data0_score_W' 0.9556650246305419
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (135, 12)
# right_data1_score_W' 0.7727272727272727
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9419953596287703
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)135
# neuron unit number: 50
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.5
# combinedweight shape 0: (100, 12)
# right_data0_score_W' 0.9650872817955112
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (150, 12)
# right_data1_score_W' 0.8888888888888888
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)150
# neuron unit number: 55
# *******************
#
# Error Data percentage 0.08584686774941995
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7837837837837838
# error_data0_score_W0 0.4594594594594595
# combinedweight shape 0: (110, 12)
# right_data0_score_W' 0.9619289340101523
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (165, 12)
# right_data1_score_W' 0.6896551724137931
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.91415313225058
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)165
# neuron unit number: 60
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9090909090909091
# error_data0_score_W0 0.5151515151515151
# combinedweight shape 0: (120, 12)
# right_data0_score_W' 0.9673366834170855
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (180, 12)
# right_data1_score_W' 0.7333333333333333
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)180
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.46875
# combinedweight shape 0: (130, 12)
# right_data0_score_W' 0.9523809523809523
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (195, 12)
# right_data1_score_W' 0.7142857142857143
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.9184782608695652
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)195
# neuron unit number: 70
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9117647058823529
# error_data0_score_W0 0.4117647058823529
# combinedweight shape 0: (140, 12)
# right_data0_score_W' 0.9722921914357683
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (210, 12)
# right_data1_score_W' 0.7096774193548387
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9211136890951276
# all_train_score_W': 1.0
# test_score_W0 : 0.9184782608695652
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)210
# neuron unit number: 75
# *******************
#
# Error Data percentage 0.05336426914153132
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9565217391304348
# error_data0_score_W0 0.5217391304347826
# combinedweight shape 0: (150, 12)
# right_data0_score_W' 0.9632352941176471
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (225, 12)
# right_data1_score_W' 0.8181818181818182
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9466357308584686
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)225
# neuron unit number: 80
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8484848484848485
# error_data0_score_W0 0.3939393939393939
# combinedweight shape 0: (160, 12)
# right_data0_score_W' 0.9522613065326633
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (240, 12)
# right_data1_score_W' 0.8928571428571429
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)240
# neuron unit number: 85
# *******************
#
# Error Data percentage 0.06728538283062645
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7931034482758621
# error_data0_score_W0 0.3793103448275862
# combinedweight shape 0: (170, 12)
# right_data0_score_W' 0.9601990049751243
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (255, 12)
# right_data1_score_W' 0.8260869565217391
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9327146171693735
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)255
# neuron unit number: 90
# *******************
#
# Error Data percentage 0.05568445475638051
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9583333333333334
# error_data0_score_W0 0.6666666666666666
# combinedweight shape 0: (180, 12)
# right_data0_score_W' 0.9533169533169533
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (270, 12)
# right_data1_score_W' 0.9130434782608695
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9443155452436195
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)270
# neuron unit number: 95
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9
# error_data0_score_W0 0.6333333333333333
# combinedweight shape 0: (190, 12)
# right_data0_score_W' 0.9576059850374065
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (285, 12)
# right_data1_score_W' 0.7037037037037037
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.9184782608695652
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)285
# neuron unit number: 100
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8709677419354839
# error_data0_score_W0 0.4838709677419355
# combinedweight shape 0: (200, 12)
# right_data0_score_W' 0.9575
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (300, 12)
# right_data1_score_W' 0.8518518518518519
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9280742459396751
# all_train_score_W': 1.0
# test_score_W0 : 0.9184782608695652
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)300
# neuron unit number: 105
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9393939393939394
# error_data0_score_W0 0.36363636363636365
# combinedweight shape 0: (210, 12)
# right_data0_score_W' 0.964824120603015
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (315, 12)
# right_data1_score_W' 0.6451612903225806
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8858695652173914
# test_score_W': 0.8967391304347826
# class_num*x*(optimize_W.split_num +1)315
# neuron unit number: 110
# *******************
#
# Error Data percentage 0.06728538283062645
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8620689655172413
# error_data0_score_W0 0.5862068965517241
# combinedweight shape 0: (220, 12)
# right_data0_score_W' 0.972636815920398
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (330, 12)
# right_data1_score_W' 0.76
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9327146171693735
# all_train_score_W': 1.0
# test_score_W0 : 0.8858695652173914
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)330
# neuron unit number: 115
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9090909090909091
# error_data0_score_W0 0.3939393939393939
# combinedweight shape 0: (230, 12)
# right_data0_score_W' 0.9698492462311558
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (345, 12)
# right_data1_score_W' 0.8666666666666667
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8913043478260869
# test_score_W': 0.8967391304347826
# class_num*x*(optimize_W.split_num +1)345
# neuron unit number: 120
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8125
# error_data0_score_W0 0.5625
# combinedweight shape 0: (240, 12)
# right_data0_score_W' 0.9548872180451128
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8333333333333334
# combinedweight shape1 : (360, 12)
# right_data1_score_W' 0.8076923076923077
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)360
# neuron unit number: 125
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9393939393939394
# error_data0_score_W0 0.36363636363636365
# combinedweight shape 0: (250, 12)
# right_data0_score_W' 0.9698492462311558
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (375, 12)
# right_data1_score_W' 0.8064516129032258
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)375
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.06496519721577726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8928571428571429
# error_data0_score_W0 0.5
# combinedweight shape 0: (260, 12)
# right_data0_score_W' 0.9776674937965261
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (390, 12)
# right_data1_score_W' 0.8
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9350348027842227
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)390
# neuron unit number: 135
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8235294117647058
# error_data0_score_W0 0.5588235294117647
# combinedweight shape 0: (270, 12)
# right_data0_score_W' 0.9546599496221663
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (405, 12)
# right_data1_score_W' 0.8928571428571429
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9211136890951276
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)405
# neuron unit number: 140
# *******************
#
# Error Data percentage 0.08584686774941995
# right_data0_score_W0 1.0
# error_data0_score_W1 0.918918918918919
# error_data0_score_W0 0.4594594594594595
# combinedweight shape 0: (280, 12)
# right_data0_score_W' 0.9720812182741116
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (420, 12)
# right_data1_score_W' 0.6764705882352942
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.91415313225058
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)420
# neuron unit number: 145
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8484848484848485
# error_data0_score_W0 0.45454545454545453
# combinedweight shape 0: (290, 12)
# right_data0_score_W' 0.964824120603015
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (435, 12)
# right_data1_score_W' 0.6071428571428571
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9347826086956522
# class_num*x*(optimize_W.split_num +1)435
# neuron unit number: 150
# *******************
#
# Error Data percentage 0.060324825986078884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8846153846153846
# error_data0_score_W0 0.38461538461538464
# combinedweight shape 0: (300, 12)
# right_data0_score_W' 0.9679012345679012
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (450, 12)
# right_data1_score_W' 0.8260869565217391
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9396751740139211
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.9021739130434783
# class_num*x*(optimize_W.split_num +1)450
# neuron unit number: 155
# *******************
#
# Error Data percentage 0.06496519721577726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8928571428571429
# error_data0_score_W0 0.5357142857142857
# combinedweight shape 0: (310, 12)
# right_data0_score_W' 0.9652605459057072
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (465, 12)
# right_data1_score_W' 0.84
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9350348027842227
# all_train_score_W': 1.0
# test_score_W0 : 0.8913043478260869
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)465
# neuron unit number: 160
# *******************
#
# Error Data percentage 0.06496519721577726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8928571428571429
# error_data0_score_W0 0.5357142857142857
# combinedweight shape 0: (320, 12)
# right_data0_score_W' 0.9652605459057072
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (480, 12)
# right_data1_score_W' 0.88
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9350348027842227
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9347826086956522
# class_num*x*(optimize_W.split_num +1)480
# neuron unit number: 165
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8823529411764706
# error_data0_score_W0 0.47058823529411764
# combinedweight shape 0: (330, 12)
# right_data0_score_W' 0.9722921914357683
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.75
# combinedweight shape1 : (495, 12)
# right_data1_score_W' 0.7333333333333333
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9211136890951276
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)495
# neuron unit number: 170
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8666666666666667
# error_data0_score_W0 0.6
# combinedweight shape 0: (340, 12)
# right_data0_score_W' 0.9650872817955112
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (510, 12)
# right_data1_score_W' 0.8846153846153846
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.8858695652173914
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)510
# neuron unit number: 175
# *******************
#
# Error Data percentage 0.06728538283062645
# right_data0_score_W0 1.0
# error_data0_score_W1 0.896551724137931
# error_data0_score_W0 0.5172413793103449
# combinedweight shape 0: (350, 12)
# right_data0_score_W' 0.9651741293532339
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (525, 12)
# right_data1_score_W' 0.8846153846153846
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9327146171693735
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)525
# neuron unit number: 180
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.5
# combinedweight shape 0: (360, 12)
# right_data0_score_W' 0.9675810473815462
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.4
# combinedweight shape1 : (540, 12)
# right_data1_score_W' 0.68
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.8858695652173914
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)540
# neuron unit number: 185
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.40625
# combinedweight shape 0: (370, 12)
# right_data0_score_W' 0.9624060150375939
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (555, 12)
# right_data1_score_W' 0.8214285714285714
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)555
# neuron unit number: 190
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.875
# error_data0_score_W0 0.5
# combinedweight shape 0: (380, 12)
# right_data0_score_W' 0.9799498746867168
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (570, 12)
# right_data1_score_W' 0.8571428571428571
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)570
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8484848484848485
# error_data0_score_W0 0.45454545454545453
# combinedweight shape 0: (390, 12)
# right_data0_score_W' 0.9748743718592965
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (585, 12)
# right_data1_score_W' 0.7857142857142857
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)585
# neuron unit number: 200
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9333333333333333
# error_data0_score_W0 0.5333333333333333
# combinedweight shape 0: (400, 12)
# right_data0_score_W' 0.9551122194513716
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (600, 12)
# right_data1_score_W' 0.7857142857142857
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.9184782608695652
# test_score_W': 0.9293478260869565
# class_num*x*(optimize_W.split_num +1)600
# neuron unit number: 205
# *******************
#
# Error Data percentage 0.06728538283062645
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9310344827586207
# error_data0_score_W0 0.5517241379310345
# combinedweight shape 0: (410, 12)
# right_data0_score_W' 0.9800995024875622
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (615, 12)
# right_data1_score_W' 0.8148148148148148
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9327146171693735
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)615
# neuron unit number: 210
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.4666666666666667
# combinedweight shape 0: (420, 12)
# right_data0_score_W' 0.970074812967581
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (630, 12)
# right_data1_score_W' 0.8
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)630
# neuron unit number: 215
# *******************
#
# Error Data percentage 0.08584686774941995
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8648648648648649
# error_data0_score_W0 0.4864864864864865
# combinedweight shape 0: (430, 12)
# right_data0_score_W' 0.9695431472081218
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (645, 12)
# right_data1_score_W' 0.6875
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.91415313225058
# all_train_score_W': 1.0
# test_score_W0 : 0.8858695652173914
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)645
# neuron unit number: 220
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8484848484848485
# error_data0_score_W0 0.45454545454545453
# combinedweight shape 0: (440, 12)
# right_data0_score_W' 0.9824120603015075
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6
# combinedweight shape1 : (660, 12)
# right_data1_score_W' 0.8214285714285714
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)660
# neuron unit number: 225
# *******************
#
# Error Data percentage 0.09048723897911833
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7948717948717948
# error_data0_score_W0 0.38461538461538464
# combinedweight shape 0: (450, 12)
# right_data0_score_W' 0.9770408163265306
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.625
# combinedweight shape1 : (675, 12)
# right_data1_score_W' 0.6774193548387096
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9095127610208816
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9293478260869565
# class_num*x*(optimize_W.split_num +1)675
# neuron unit number: 230
# *******************
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.96875
# error_data0_score_W0 0.46875
# combinedweight shape 0: (460, 12)
# right_data0_score_W' 0.9674185463659147
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (690, 12)
# right_data1_score_W' 0.967741935483871
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)690
# neuron unit number: 235
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8125
# error_data0_score_W0 0.5
# combinedweight shape 0: (470, 12)
# right_data0_score_W' 0.9573934837092731
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (705, 12)
# right_data1_score_W' 0.7692307692307693
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.9293478260869565
# class_num*x*(optimize_W.split_num +1)705
# neuron unit number: 240
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8484848484848485
# error_data0_score_W0 0.5151515151515151
# combinedweight shape 0: (480, 12)
# right_data0_score_W' 0.9673366834170855
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.8
# combinedweight shape1 : (720, 12)
# right_data1_score_W' 0.8214285714285714
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)720
# neuron unit number: 245
# *******************
#
# Error Data percentage 0.060324825986078884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8461538461538461
# error_data0_score_W0 0.4230769230769231
# combinedweight shape 0: (490, 12)
# right_data0_score_W' 0.9481481481481482
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (735, 12)
# right_data1_score_W' 0.8181818181818182
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9396751740139211
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)735
# neuron unit number: 250
# *******************
#
# Error Data percentage 0.06496519721577726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9642857142857143
# error_data0_score_W0 0.5357142857142857
# combinedweight shape 0: (500, 12)
# right_data0_score_W' 0.9851116625310173
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (750, 12)
# right_data1_score_W' 0.8148148148148148
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9350348027842227
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)750
# neuron unit number: 255
# *******************
#
# Error Data percentage 0.06496519721577726
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8928571428571429
# error_data0_score_W0 0.5357142857142857
# combinedweight shape 0: (510, 12)
# right_data0_score_W' 0.9727047146401985
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (765, 12)
# right_data1_score_W' 0.72
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9350348027842227
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)765
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.060324825986078884
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9615384615384616
# error_data0_score_W0 0.5
# combinedweight shape 0: (520, 12)
# right_data0_score_W' 0.9506172839506173
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (780, 12)
# right_data1_score_W' 0.84
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9396751740139211
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)780
# neuron unit number: 265
# *******************
#
# Error Data percentage 0.09048723897911833
# right_data0_score_W0 1.0
# error_data0_score_W1 0.7948717948717948
# error_data0_score_W0 0.5128205128205128
# combinedweight shape 0: (530, 12)
# right_data0_score_W' 0.9693877551020408
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.625
# combinedweight shape1 : (795, 12)
# right_data1_score_W' 0.7096774193548387
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9095127610208816
# all_train_score_W': 1.0
# test_score_W0 : 0.8913043478260869
# test_score_W': 0.9184782608695652
# class_num*x*(optimize_W.split_num +1)795
# neuron unit number: 270
# *******************
#
# Error Data percentage 0.08352668213457076
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8333333333333334
# error_data0_score_W0 0.4166666666666667
# combinedweight shape 0: (540, 12)
# right_data0_score_W' 0.9696202531645569
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (810, 12)
# right_data1_score_W' 0.7
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9164733178654292
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)810
# neuron unit number: 275
# *******************
#
# Error Data percentage 0.07192575406032482
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9032258064516129
# error_data0_score_W0 0.5161290322580645
# combinedweight shape 0: (550, 12)
# right_data0_score_W' 0.975
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.6666666666666666
# combinedweight shape1 : (825, 12)
# right_data1_score_W' 0.7857142857142857
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9280742459396751
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)825
# neuron unit number: 280
# *******************
#
# Error Data percentage 0.07888631090487239
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9411764705882353
# error_data0_score_W0 0.4411764705882353
# combinedweight shape 0: (560, 12)
# right_data0_score_W' 0.9722921914357683
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (840, 12)
# right_data1_score_W' 0.8125
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9211136890951276
# all_train_score_W': 1.0
# test_score_W0 : 0.907608695652174
# test_score_W': 0.9293478260869565
# class_num*x*(optimize_W.split_num +1)840
# neuron unit number: 285
# *******************
#
# Error Data percentage 0.0765661252900232
# right_data0_score_W0 1.0
# error_data0_score_W1 0.8787878787878788
# error_data0_score_W0 0.42424242424242425
# combinedweight shape 0: (570, 12)
# right_data0_score_W' 0.964824120603015
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 0.5
# combinedweight shape1 : (855, 12)
# right_data1_score_W' 0.7931034482758621
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9234338747099768
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.907608695652174
# class_num*x*(optimize_W.split_num +1)855
# neuron unit number: 290
# *******************
#
# Error Data percentage 0.07424593967517401
# right_data0_score_W0 1.0
# error_data0_score_W1 0.90625
# error_data0_score_W0 0.5
# combinedweight shape 0: (580, 12)
# right_data0_score_W' 0.9799498746867168
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (870, 12)
# right_data1_score_W' 0.6896551724137931
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.925754060324826
# all_train_score_W': 1.0
# test_score_W0 : 0.8967391304347826
# test_score_W': 0.9130434782608695
# class_num*x*(optimize_W.split_num +1)870
# neuron unit number: 295
# *******************
#
# Error Data percentage 0.06960556844547564
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9333333333333333
# error_data0_score_W0 0.5
# combinedweight shape 0: (590, 12)
# right_data0_score_W' 0.9750623441396509
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (885, 12)
# right_data1_score_W' 0.75
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9303944315545244
# all_train_score_W': 1.0
# test_score_W0 : 0.9021739130434783
# test_score_W': 0.9293478260869565
# class_num*x*(optimize_W.split_num +1)885
# neuron unit number: 300
# *******************
#
# Error Data percentage 0.05104408352668213
# right_data0_score_W0 1.0
# error_data0_score_W1 0.9090909090909091
# error_data0_score_W0 0.5454545454545454
# combinedweight shape 0: (600, 12)
# right_data0_score_W' 0.9706601466992665
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 1.0
# error_data1_score_W0 1.0
# Error data can be represented by W0 1
# combinedweight shape1 : (900, 12)
# right_data1_score_W' 0.95
# Finish one splitting *********
# 2
#  NO Error Data, Finish Training!
# split_num 2
# all_train_score_W0: 0.9489559164733179
# all_train_score_W': 1.0
# test_score_W0 : 0.9130434782608695
# test_score_W': 0.9239130434782609
# class_num*x*(optimize_W.split_num +1)900
# s 25  value 0.9239130434782609
# s 50  value 0.9239130434782609
# s 60  value 0.9184782608695652
# s 75  value 0.9239130434782609
# s 80  value 0.9293478260869565
# s 90  value 0.907608695652174
# s 105  value 0.9184782608695652
# s 120  value 0.9184782608695652
# s 135  value 0.9130434782608695
# s 150  value 0.9239130434782609
# s 165  value 0.9239130434782609
# s 180  value 0.9239130434782609
# s 195  value 0.9239130434782609
# s 210  value 0.9184782608695652
# s 225  value 0.9239130434782609
# s 240  value 0.9239130434782609
# s 255  value 0.907608695652174
# s 270  value 0.9130434782608695
# s 285  value 0.9184782608695652
# s 300  value 0.9239130434782609
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  20.0  0.903261  0.009094  0.002034   0.899005  0.907517
# 1  test_score_W'  20.0  0.920109  0.005875  0.001314   0.917359  0.922858
# 2       combined  40.0  0.911685  0.011397  0.001802   0.908040  0.915330
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0168
# 1                          Degrees of freedom =   38.0000
# 2                                           t =   -6.9593
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -2.2007
# 7                                   Hedge's g =   -2.1570
# 8                               Glass's delta =   -1.8526
# 9                                 Pearson's r =    0.7486
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
