# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("turkiye-student-evaluation_generic.csv")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"class")

# %%
scoretype = 2
scope_num = 1
class_num = 13
dim_num = 32
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 13
# *******************
#
# error_data0_score_W1 0.021072074772344886
# error_data0_score_W0 0.03372869935972233
# right_data0_score_W' 1.0
# Finish one round splitting 0 *********
#
# error_data1_score_W1 0.009618658452750563
# error_data1_score_W0 0.006289197769677284
# right_data1_score_W' 0.18891662794458808
# Finish one round splitting 1 *********
#
# error_data2_score_W1 0.021903657459711574
# error_data2_score_W0 0.016869885158981097
# right_data2_score_W' 0.29008965970171813
# Finish one round splitting 2 *********
#
# error_data3_score_W1 0.026884175519397445
# error_data3_score_W0 0.017964951590744255
# right_data3_score_W' 0.2282689296320988
# Finish one round splitting 3 *********
#
# error_data4_score_W1 0.02041820194771811
# error_data4_score_W0 0.008661698922607498
# right_data4_score_W' 0.331664754253405
# Finish one round splitting 4 *********
#
# error_data5_score_W1 0.03845565919055319
# error_data5_score_W0 0.017343297090460365
# right_data5_score_W' 0.19844586393922922
# Finish one round splitting 5 *********
#
# error_data6_score_W1 0.031414170371327196
# error_data6_score_W0 0.011186756843979018
# right_data6_score_W' 0.1386174387863814
# Finish one round splitting 6 *********
#
# error_data7_score_W1 0.04093012204980527
# error_data7_score_W0 0.007759803681754246
# right_data7_score_W' 0.20441400647644387
# Finish one round splitting 7 *********
#
# error_data8_score_W1 0.02871379613484101
# error_data8_score_W0 0.017833581560622386
# right_data8_score_W' 0.20790405837105827
# Finish one round splitting 8 *********
#
# error_data9_score_W1 0.03439608494171154
# error_data9_score_W0 0.02706667797526567
# right_data9_score_W' 0.23731978755810437
# Finish one round splitting 9 *********
#
# error_data10_score_W1 0.0509424456029704
# error_data10_score_W0 0.030985883469330157
# right_data10_score_W' 0.21606987566659525
# Finish one round splitting 10 *********
#
# error_data11_score_W1 0.04453195267992708
# error_data11_score_W0 0.008759974312178807
# right_data11_score_W' 0.0341710392428901
# Finish one round splitting 11 *********
#
# error_data12_score_W1 0.06652859646961883
# error_data12_score_W0 0.018399781757364824
# right_data12_score_W' 0.14426135892966355
# Finish one round splitting 12 *********
#
# error_data13_score_W1 0.06648283957272481
# error_data13_score_W0 0.03570819448118232
# right_data13_score_W' 0.2299778558652083
# Finish one round splitting 13 *********
#
# error_data14_score_W1 0.07924714696981829
# error_data14_score_W0 0.02868794539148266
# right_data14_score_W' 0.469609135005691
# Finish one round splitting 14 *********
#
# error_data15_score_W1 0.097267704198494
# error_data15_score_W0 0.021175473948778962
# right_data15_score_W' 0.17352936907647426
# Finish one round splitting 15 *********
#
# error_data16_score_W1 0.07785815049374194
# error_data16_score_W0 -0.031221695348713305
# right_data16_score_W' 0.19020928677945184
# Finish one round splitting 16 *********
#
# error_data17_score_W1 0.05678884873515746
# error_data17_score_W0 0.0394491998511351
# right_data17_score_W' 0.18876404494382024
# Finish one round splitting 17 *********
#
# error_data18_score_W1 0.4964426877470356
# error_data18_score_W0 0.006550218340611353
# right_data18_score_W' 0.05862068965517241
# Finish one round splitting 18 *********
#
# error_data19_score_W1 1.0
# error_data19_score_W0 -0.5
# right_data19_score_W' 0.017857142857142856
# Finish one round splitting 19 *********
#
#  NO Error Data, Finish Training!
# total split_number 19
# stop_split_num 0
# all_train_score_W' split_num : 0 0.015155271737918634
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 0 0.015435313901732967
# stop_split_num 1
# all_train_score_W' split_num : 1 0.05551717409546721
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 1 0.0304322132080129
# stop_split_num 2
# all_train_score_W' split_num : 2 0.09356570819404458
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 2 0.03787598284379287
# stop_split_num 3
# all_train_score_W' split_num : 3 0.1601351061667435
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 3 0.061850629460467245
# stop_split_num 4
# all_train_score_W' split_num : 4 0.20519422919430985
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 4 0.07034449530262399
# stop_split_num 5
# all_train_score_W' split_num : 5 0.24629490294758552
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 5 0.07748612855549693
# stop_split_num 6
# all_train_score_W' split_num : 6 0.28465583390764315
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 6 0.08740669972258615
# stop_split_num 7
# all_train_score_W' split_num : 7 0.30832539446001284
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 7 0.08879807487714973
# stop_split_num 8
# all_train_score_W' split_num : 8 0.33105793500179603
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 8 0.09021923226075118
# stop_split_num 9
# all_train_score_W' split_num : 9 0.35250057477673497
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 9 0.09169138227586965
# stop_split_num 10
# all_train_score_W' split_num : 10 0.36818052095241527
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 10 0.09128160033907905
# stop_split_num 11
# all_train_score_W' split_num : 11 0.3871027526203806
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 11 0.09191057520929274
# stop_split_num 12
# all_train_score_W' split_num : 12 0.3980572896914111
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 12 0.09164431565742129
# stop_split_num 13
# all_train_score_W' split_num : 13 0.40649101790903963
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 13 0.0913538965424974
# stop_split_num 14
# all_train_score_W' split_num : 14 0.4147374703187528
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 14 0.09097607417803781
# stop_split_num 15
# all_train_score_W' split_num : 15 0.42147746177602335
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 15 0.0914601593077899
# stop_split_num 16
# all_train_score_W' split_num : 16 0.4268187808770426
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 16 0.09122278008038985
# stop_split_num 17
# all_train_score_W' split_num : 17 0.4314775864421763
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 17 0.09122278008038985
# stop_split_num 18
# all_train_score_W' split_num : 18 0.4343228858289639
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 18 0.09131664529969458
# stop_split_num 19
# all_train_score_W' split_num : 19 0.43749064580927866
# test_score_W0 : 0.015435313901732967
# test_score_W': split_num : 19 0.090855786348883

# %%
scoretype = 2
scope_num = 30
class_num = 13
dim_num = 32
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
initial_som_result_train = dict()
splitted_number_result = dict()
splitted_number_result_train = dict()
all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(scoretype)       
        x=x+1
    y =y+1
# Out:
# neuron unit number: 13
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.01114538208576963
# error_data0_score_W0 0.024415656129795023
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.49696780384424555
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.016279589019138688
# error_data1_score_W0 0.006615641748524715
# combinedweight shape1 : (39, 32)
# right_data1_score_W' 0.1443036885987344
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.017691781516892158
# error_data2_score_W0 0.011148721404572938
# combinedweight shape1 : (52, 32)
# right_data2_score_W' 0.10100227417708359
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.027926170199092992
# error_data3_score_W0 0.014374565556302737
# combinedweight shape1 : (65, 32)
# right_data3_score_W' 0.0654092489239903
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.031979369825451485
# error_data4_score_W0 0.017194355384534545
# combinedweight shape1 : (78, 32)
# right_data4_score_W' 0.1723500794319
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.023439102349008728
# error_data5_score_W0 0.011056994164747576
# combinedweight shape1 : (91, 32)
# right_data5_score_W' 0.07569724669239533
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.05642255894353861
# error_data6_score_W0 0.029577412736061074
# combinedweight shape1 : (104, 32)
# right_data6_score_W' 0.1356716265598823
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.05157331801798202
# error_data7_score_W0 0.04140791894233358
# combinedweight shape1 : (117, 32)
# right_data7_score_W' 0.2656551434132107
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.03939359632886992
# error_data8_score_W0 0.01884123731458364
# combinedweight shape1 : (130, 32)
# right_data8_score_W' 0.2810647833181589
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.0323903289704568
# error_data9_score_W0 0.03029879210156844
# combinedweight shape1 : (143, 32)
# right_data9_score_W' 0.08370259416242917
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.08467502648155005
# error_data10_score_W0 0.0194171493069275
# combinedweight shape1 : (156, 32)
# right_data10_score_W' 0.12294461803050438
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.07012382301061475
# error_data11_score_W0 0.04010850896094771
# combinedweight shape1 : (169, 32)
# right_data11_score_W' 0.1055346476268467
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.05040523991910384
# error_data12_score_W0 0.03514815282084478
# combinedweight shape1 : (182, 32)
# right_data12_score_W' 0.1685140095213868
# Finish one splitting *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.09216167777504662
# error_data13_score_W0 0.026478868012661
# combinedweight shape1 : (195, 32)
# right_data13_score_W' 0.1008353494316885
# Finish one splitting *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 0.10016593778599726
# error_data14_score_W0 0.07261763256312875
# combinedweight shape1 : (208, 32)
# right_data14_score_W' 0.09974980639780782
# Finish one splitting *********
# 15
# right_data15_score_W0 1.0
# error_data15_score_W1 0.15509685614480787
# error_data15_score_W0 0.040964886596544965
# combinedweight shape1 : (221, 32)
# right_data15_score_W' 0.1391573694324146
# Finish one splitting *********
# 16
# right_data16_score_W0 1.0
# error_data16_score_W1 0.2597986906238283
# error_data16_score_W0 0.070533295151662
# combinedweight shape1 : (234, 32)
# right_data16_score_W' 0.28413998510796723
# Finish one splitting *********
# 17
# right_data17_score_W0 1.0
# error_data17_score_W1 0.33088235294117646
# error_data17_score_W0 0.02045209903121636
# combinedweight shape1 : (247, 32)
# right_data17_score_W' 0.18269230769230768
# Finish one splitting *********
# 18
# right_data18_score_W0 1.0
# error_data18_score_W1 0.0
# error_data18_score_W0 0.0
# combinedweight shape1 : (260, 32)
# right_data18_score_W' -0.07142857142857142
# Finish one splitting *********
# 19
# right_data19_score_W0 1.0
# error_data19_score_W1 1.0
# error_data19_score_W0 1.0
# Error data can be represented by W0 19
# combinedweight shape1 : (273, 32)
# right_data19_score_W' 1.0
# Finish one splitting *********
# 20
#  NO Error Data, Finish Training!
# split_num 20
# all_train_score_W' split_num : 0 0.004264007866514028
# test_score_W': split_num : 0 -0.0012131931054669772
# all_train_score_W' split_num : 1 0.05269192822272531
# test_score_W': split_num : 1 0.029405061011749868
# all_train_score_W' split_num : 2 0.09224667199079967
# test_score_W': split_num : 2 0.04338647942396988
# all_train_score_W' split_num : 3 0.15876488498391836
# test_score_W': split_num : 3 0.06535208229549769
# all_train_score_W' split_num : 4 0.20865577253014836
# test_score_W': split_num : 4 0.07760217822876496
# all_train_score_W' split_num : 5 0.2607075543518686
# test_score_W': split_num : 5 0.08644688436088331
# all_train_score_W' split_num : 6 0.2885989931234669
# test_score_W': split_num : 6 0.08937315510176888
# all_train_score_W' split_num : 7 0.33021557387136735
# test_score_W': split_num : 7 0.09231195706412215
# all_train_score_W' split_num : 8 0.3614532813627009
# test_score_W': split_num : 8 0.09651779592201536
# all_train_score_W' split_num : 9 0.38543001490896067
# test_score_W': split_num : 9 0.0964533636966552
# all_train_score_W' split_num : 10 0.40637897607701967
# test_score_W': split_num : 10 0.09649771846030133
# all_train_score_W' split_num : 11 0.4243355594877885
# test_score_W': split_num : 11 0.09715412401765419
# all_train_score_W' split_num : 12 0.4362114120436075
# test_score_W': split_num : 12 0.0982158175264378
# all_train_score_W' split_num : 13 0.4453573843752922
# test_score_W': split_num : 13 0.09867618771955461
# all_train_score_W' split_num : 14 0.45330002308224066
# test_score_W': split_num : 14 0.09985248179985937
# all_train_score_W' split_num : 15 0.4591609495724548
# test_score_W': split_num : 15 0.10020678458077052
# all_train_score_W' split_num : 16 0.46343293231685656
# test_score_W': split_num : 16 0.10059199351402116
# all_train_score_W' split_num : 17 0.4679111298576011
# test_score_W': split_num : 17 0.10202739629601226
# all_train_score_W' split_num : 18 0.4703840496396927
# test_score_W': split_num : 18 0.10241685439619742
# all_train_score_W' split_num : 19 0.47116341123615285
# test_score_W': split_num : 19 0.10241685439619742
# all_train_score_W' split_num : 20 0.47150497340410497
# test_score_W': split_num : 20 0.10241685439619742
# neuron unit number: 26
# *******************
#
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0139921638850748
# error_data0_score_W0 0.026215820061482285
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.309931074351719
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.01472685127450185
# error_data1_score_W0 0.004778008971598998
# combinedweight shape1 : (78, 32)
# right_data1_score_W' 0.11453800872153604
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.019561820834600414
# error_data2_score_W0 0.007537047295937322
# combinedweight shape1 : (104, 32)
# right_data2_score_W' 0.10828715823348074
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.02484979670909839
# error_data3_score_W0 0.010184651987735424
# combinedweight shape1 : (130, 32)
# right_data3_score_W' 0.10286087846938118
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.025969263966321623
# error_data4_score_W0 0.011335795761359874
# combinedweight shape1 : (156, 32)
# right_data4_score_W' 0.12093740963588859
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.024343911444298098
# error_data5_score_W0 0.0161146241481278
# combinedweight shape1 : (182, 32)
# right_data5_score_W' 0.1508654206389219
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.044443436673077354
# error_data6_score_W0 0.013263741097316272
# combinedweight shape1 : (208, 32)
# right_data6_score_W' 0.14150825049878513
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.03458942323438231
# error_data7_score_W0 0.01109656771451386
# combinedweight shape1 : (234, 32)
# right_data7_score_W' 0.11700562393942346
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.04766494846327392
# error_data8_score_W0 0.009770175705313813
# combinedweight shape1 : (260, 32)
# right_data8_score_W' 0.129980442113181
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.06931993433115702
# error_data9_score_W0 0.015395807852614123
# combinedweight shape1 : (286, 32)
# right_data9_score_W' 0.1488813525283986
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.06487463387812104
# error_data10_score_W0 0.0033656591607401074
# combinedweight shape1 : (312, 32)
# right_data10_score_W' 0.10931939787663007
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.06414132803343515
# error_data11_score_W0 0.007820833785228569
# combinedweight shape1 : (338, 32)
# right_data11_score_W' 0.12665401156118958
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.09020488737422155
# error_data12_score_W0 0.02005967020875631
# combinedweight shape1 : (364, 32)
# right_data12_score_W' 0.042427505314610016
# Finish one splitting *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.16219753800193454
# error_data13_score_W0 0.0786206749331645
# combinedweight shape1 : (390, 32)
# right_data13_score_W' 0.050138199542306895
# Finish one splitting *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 0.2630269523151348
# error_data14_score_W0 -0.02733637070785643
# combinedweight shape1 : (416, 32)
# right_data14_score_W' 0.05492730210016155
# Finish one splitting *********
# 15
# right_data15_score_W0 1.0
# error_data15_score_W1 0.82
# error_data15_score_W0 0.16127320954907162
# combinedweight shape1 : (442, 32)
# right_data15_score_W' 0.31857891671520094
# Finish one splitting *********
# 16
# right_data16_score_W0 1.0
# error_data16_score_W1 1.0
# error_data16_score_W0 1.0
# Error data can be represented by W0 16
# combinedweight shape1 : (468, 32)
# right_data16_score_W' 0.27586206896551724
# Finish one splitting *********
# 17
#  NO Error Data, Finish Training!
# split_num 17
# all_train_score_W' split_num : 0 0.007104481899723699
# test_score_W': split_num : 0 0.003561305413663504
# all_train_score_W' split_num : 1 0.056115038902463624
# test_score_W': split_num : 1 0.03855408932912429
# all_train_score_W' split_num : 2 0.12444079412410942
# test_score_W': split_num : 2 0.0649885628497334
# all_train_score_W' split_num : 3 0.1712473405913924
# test_score_W': split_num : 3 0.0730797122420994
# all_train_score_W' split_num : 4 0.2400333929902537
# test_score_W': split_num : 4 0.08866606668664638
# all_train_score_W' split_num : 5 0.2812000158589998
# test_score_W': split_num : 5 0.09527858043984172
# all_train_score_W' split_num : 6 0.31106644087049107
# test_score_W': split_num : 6 0.09906152720473616
# all_train_score_W' split_num : 7 0.34312606298534226
# test_score_W': split_num : 7 0.09857751241551677
# all_train_score_W' split_num : 8 0.3659794620593308
# test_score_W': split_num : 8 0.09997089777499506
# all_train_score_W' split_num : 9 0.38889874884845993
# test_score_W': split_num : 9 0.10025181217619535
# all_train_score_W' split_num : 10 0.4095188295145542
# test_score_W': split_num : 10 0.10068929371677218
# all_train_score_W' split_num : 11 0.42726201331125563
# test_score_W': split_num : 11 0.10022734918785833
# all_train_score_W' split_num : 12 0.43998352206694297
# test_score_W': split_num : 12 0.10124261113164673
# all_train_score_W' split_num : 13 0.4498521355430185
# test_score_W': split_num : 13 0.10133088497979695
# all_train_score_W' split_num : 14 0.45998450997465423
# test_score_W': split_num : 14 0.10135350442762314
# all_train_score_W' split_num : 15 0.46589800039611373
# test_score_W': split_num : 15 0.10182319272731608

# %%
# local scope2
scoretype = 2
scope_num = 30
class_num = 13
dim_num = 32
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8375061364752087
# right_data0_score_W0 1.0
# error_data0_score_W1 0.018368294781093166
# error_data0_score_W0 0.022911532792061914
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.13424318104467006
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.004015553924799735
# error_data1_score_W0 0.008297532984630422
# combinedweight shape1 : (39, 32)
# right_data1_score_W' 0.3146698989379493
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.01708667732863229
# error_data2_score_W0 0.00672260461075843
# combinedweight shape1 : (52, 32)
# right_data2_score_W' 0.017835185203387276
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.03542626555502965
# error_data3_score_W0 0.011688929490690808
# combinedweight shape1 : (65, 32)
# right_data3_score_W' 0.10664417783530265
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.0349159803676174
# error_data4_score_W0 0.0026333247449279325
# combinedweight shape1 : (78, 32)
# right_data4_score_W' 0.19934354909637172
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.014611682761293663
# error_data5_score_W0 0.005938125760102708
# combinedweight shape1 : (91, 32)
# right_data5_score_W' 0.1568127489244841
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.03869401182352617
# error_data6_score_W0 0.011809578036206227
# combinedweight shape1 : (104, 32)
# right_data6_score_W' 0.024545121471793843
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.03206321496616994
# error_data7_score_W0 0.026065744738687113
# combinedweight shape1 : (117, 32)
# right_data7_score_W' 0.20207495131697512
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.05410133458501763
# error_data8_score_W0 0.020966626708700052
# combinedweight shape1 : (130, 32)
# right_data8_score_W' 0.15551268822319433
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.08428562630681667
# error_data9_score_W0 0.01920090154458667
# combinedweight shape1 : (143, 32)
# right_data9_score_W' 0.18437343148736823
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.06089849079395346
# error_data10_score_W0 0.007853902133799004
# combinedweight shape1 : (156, 32)
# right_data10_score_W' 0.1432797228245337
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.041709579580554164
# error_data11_score_W0 0.008315098712981297
# combinedweight shape1 : (169, 32)
# right_data11_score_W' 0.1254184086794566
# Finish one training *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.05555849464281737
# error_data12_score_W0 0.02334692837114453
# combinedweight shape1 : (182, 32)
# right_data12_score_W' 0.17533086920233695
# Finish one training *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.061252457844247155
# error_data13_score_W0 0.027746258090875983
# combinedweight shape1 : (195, 32)
# right_data13_score_W' 0.11004568256930833
# Finish one training *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 0.08764269695594513
# error_data14_score_W0 0.005087711288092385
# combinedweight shape1 : (208, 32)
# right_data14_score_W' 0.20025429116338206
# Finish one training *********
# 15
# right_data15_score_W0 1.0
# error_data15_score_W1 0.0692653282867829
# error_data15_score_W0 -0.01655860196706616
# combinedweight shape1 : (221, 32)
# right_data15_score_W' 0.1727994812773545
# Finish one training *********
# 16
# right_data16_score_W0 1.0
# error_data16_score_W1 0.178
# error_data16_score_W0 -0.02283464566929134
# combinedweight shape1 : (234, 32)
# right_data16_score_W' 0.13806706114398423
# Finish one training *********
# 17
# right_data17_score_W0 1.0
# error_data17_score_W1 0.32367149758454106
# error_data17_score_W0 -0.018922852983988356
# combinedweight shape1 : (247, 32)
# right_data17_score_W' 0.06129917657822507
# Finish one training *********
# 18
# right_data18_score_W0 1.0
# error_data18_score_W1 1.0
# error_data18_score_W0 0.0
# combinedweight shape1 : (260, 32)
# right_data18_score_W' 0.23580786026200873
# Finish one training *********
# 19
#  NO Error Data, Finish Training!
# all_train_score_W0: -0.00044987925997147705
# all_train_score_W': 0.4492099317250362
# test_score_W0 : -0.0019403980479484554
# test_score_W': 0.08870106057398813
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.7977417771232205
# right_data0_score_W0 1.0
# error_data0_score_W1 0.013170716965109058
# error_data0_score_W0 0.02832868695286842
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.3171203897259142
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.020498578903490623
# error_data1_score_W0 0.006837150615513364
# combinedweight shape1 : (78, 32)
# right_data1_score_W' 0.16684635033208864
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.016516827623426326
# error_data2_score_W0 0.002256066653980125
# combinedweight shape1 : (104, 32)
# right_data2_score_W' 0.08254300525290519
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.02276591012559444
# error_data3_score_W0 0.008950075527389521
# combinedweight shape1 : (130, 32)
# right_data3_score_W' 0.17854740840935102
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.018497694589414294
# error_data4_score_W0 0.011479126496531829
# combinedweight shape1 : (156, 32)
# right_data4_score_W' 0.10676028199470904
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.03585494977774822
# error_data5_score_W0 0.023718743928577028
# combinedweight shape1 : (182, 32)
# right_data5_score_W' 0.08571193905005813
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.05688644495448141
# error_data6_score_W0 0.02147930579106052
# combinedweight shape1 : (208, 32)
# right_data6_score_W' 0.18064188451735014
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.05394970831341029
# error_data7_score_W0 0.017196568455246728
# combinedweight shape1 : (234, 32)
# right_data7_score_W' 0.1233044086575755
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.03068067013751866
# error_data8_score_W0 0.01430009056321271
# combinedweight shape1 : (260, 32)
# right_data8_score_W' 0.12286313078314298
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.05170638991401393
# error_data9_score_W0 0.015260789254605353
# combinedweight shape1 : (286, 32)
# right_data9_score_W' 0.15625967740118196
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.07372411701237302
# error_data10_score_W0 0.022390592323878262
# combinedweight shape1 : (312, 32)
# right_data10_score_W' 0.1339909162298109
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.0907639946180997
# error_data11_score_W0 0.03119920215127129
# combinedweight shape1 : (338, 32)
# right_data11_score_W' 0.05858754273046508
# Finish one training *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.13665609084860267
# error_data12_score_W0 0.02362715595324982
# combinedweight shape1 : (364, 32)
# right_data12_score_W' 0.10205844713021017
# Finish one training *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.14360207127450197
# error_data13_score_W0 0.003747839823581175
# combinedweight shape1 : (390, 32)
# right_data13_score_W' 0.09411876778718489
# Finish one training *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 0.37948717948717947
# error_data14_score_W0 0.0005177323323841574
# combinedweight shape1 : (416, 32)
# right_data14_score_W' 0.28153153153153154
# Finish one training *********
# 15
# right_data15_score_W0 1.0
# error_data15_score_W1 1.0
# error_data15_score_W0 -0.09090909090909091
# combinedweight shape1 : (442, 32)
# right_data15_score_W' 0.13766842413591096
# Finish one training *********
# 16
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.020036786191983548
# all_train_score_W': 0.4786823396900981
# test_score_W0 : 0.01932409312577611
# test_score_W': 0.08656787970026086
# neuron unit number: 39
# *******************
# Error Data percentage 0.780559646539028
# right_data0_score_W0 1.0
# error_data0_score_W1 0.018965665033139092
# error_data0_score_W0 0.04005780383125599
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.4685171052497159
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.022445768664577936
# error_data1_score_W0 0.006865463895731614
# combinedweight shape1 : (117, 32)
# right_data1_score_W' 0.2196193372811914
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.01836229054880824
# error_data2_score_W0 0.0103791108655914
# combinedweight shape1 : (156, 32)
# right_data2_score_W' 0.16917104700391108
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.038474938257033006
# error_data3_score_W0 0.008773110012104268
# combinedweight shape1 : (195, 32)
# right_data3_score_W' 0.20025431297108448
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.04021170146896869
# error_data4_score_W0 0.020757886187129832
# combinedweight shape1 : (234, 32)
# right_data4_score_W' 0.07652119531224277
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.05199247724272543
# error_data5_score_W0 0.02213009172022435
# combinedweight shape1 : (273, 32)
# right_data5_score_W' 0.08133236170597082
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.06130557348529078
# error_data6_score_W0 0.005650750247086813
# combinedweight shape1 : (312, 32)
# right_data6_score_W' 0.15259327874630385
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.07501370994428148
# error_data7_score_W0 0.00702734374043009
# combinedweight shape1 : (351, 32)
# right_data7_score_W' 0.21292873430204498
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.0783377231730195
# error_data8_score_W0 0.004947579924089642
# combinedweight shape1 : (390, 32)
# right_data8_score_W' 0.1219796310330946
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.09448687320437103
# error_data9_score_W0 0.009993779921047217
# combinedweight shape1 : (429, 32)
# right_data9_score_W' 0.12502901770909333
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.100600455437587
# error_data10_score_W0 0.02204404927150775
# combinedweight shape1 : (468, 32)
# right_data10_score_W' 0.08866365787385685
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.2409778812572759
# error_data11_score_W0 0.002982530890498509
# combinedweight shape1 : (507, 32)
# right_data11_score_W' 0.07300316625843838
# Finish one training *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.46189181896557396
# error_data12_score_W0 0.013186951858161398
# combinedweight shape1 : (546, 32)
# right_data12_score_W' 0.039506671377854054
# Finish one training *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.5100502512562815
# error_data13_score_W0 0.04505386875612145
# combinedweight shape1 : (585, 32)
# right_data13_score_W' 0.2760393712354929
# Finish one training *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 1.0
# error_data14_score_W0 0.0
# combinedweight shape1 : (624, 32)
# right_data14_score_W' 0.2542372881355932
# Finish one training *********
# 15
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.03155313544382379
# all_train_score_W': 0.4675890114922583
# test_score_W0 : 0.02829894835023161
# test_score_W': 0.08369694262600434
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7756504663721159
# right_data0_score_W0 1.0
# error_data0_score_W1 0.02270706756172935
# error_data0_score_W0 0.03766109860387724
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.4171783876964365
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.020559927816466362
# error_data1_score_W0 0.00850488894674252
# combinedweight shape1 : (156, 32)
# right_data1_score_W' 0.10865225828663516
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.024638997653208115
# error_data2_score_W0 0.0063516896830720865
# combinedweight shape1 : (208, 32)
# right_data2_score_W' 0.14244360817402338
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.034000275289675176
# error_data3_score_W0 0.01409562417936056
# combinedweight shape1 : (260, 32)
# right_data3_score_W' 0.12001020989596844
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.03803222013795719
# error_data4_score_W0 0.007266015805612233
# combinedweight shape1 : (312, 32)
# right_data4_score_W' 0.09640830273297965
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.053835198936319
# error_data5_score_W0 0.01630981919623838
# combinedweight shape1 : (364, 32)
# right_data5_score_W' 0.05806076032476692
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.06169419608110057
# error_data6_score_W0 0.011448637435644138
# combinedweight shape1 : (416, 32)
# right_data6_score_W' 0.07459023456817183
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.0714914111520675
# error_data7_score_W0 0.012568498225437971
# combinedweight shape1 : (468, 32)
# right_data7_score_W' 0.09957026029310936
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.12671293495714248
# error_data8_score_W0 0.005340638732649413
# combinedweight shape1 : (520, 32)
# right_data8_score_W' 0.10450532928387567
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.09945900384025003
# error_data9_score_W0 0.016392833748673563
# combinedweight shape1 : (572, 32)
# right_data9_score_W' 0.0848456708321958
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.19177847871822462
# error_data10_score_W0 0.009373799613482644
# combinedweight shape1 : (624, 32)
# right_data10_score_W' 0.06526503331019745
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.42602979842243643
# error_data11_score_W0 0.03530254102313076
# combinedweight shape1 : (676, 32)
# right_data11_score_W' 0.15289305469871897
# Finish one training *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.6330935251798561
# error_data12_score_W0 0.03125
# combinedweight shape1 : (728, 32)
# right_data12_score_W' 0.09195530726256983
# Finish one training *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 1.0
# error_data13_score_W0 0.0
# combinedweight shape1 : (780, 32)
# right_data13_score_W' 0.27941176470588236
# Finish one training *********
# 14
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.031488053099486955
# all_train_score_W': 0.4860231330267876
# test_score_W0 : 0.02494505902734969
# test_score_W': 0.07803568557463225
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.7709867452135494
# right_data0_score_W0 1.0
# error_data0_score_W1 0.028681235370105352
# error_data0_score_W0 0.031154702083229548
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.3348982940358277
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.028172570495311453
# error_data1_score_W0 0.0027109849973900343
# combinedweight shape1 : (195, 32)
# right_data1_score_W' 0.11610283800287233
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.02423823679145752
# error_data2_score_W0 0.009395604283184294
# combinedweight shape1 : (260, 32)
# right_data2_score_W' 0.18454629751785812
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.03586441797022341
# error_data3_score_W0 0.0037415485273079837
# combinedweight shape1 : (325, 32)
# right_data3_score_W' 0.14243442320087626
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.045994195301536187
# error_data4_score_W0 0.005672150966148907
# combinedweight shape1 : (390, 32)
# right_data4_score_W' 0.12979208853152172
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.07584073209735674
# error_data5_score_W0 0.009421770850935976
# combinedweight shape1 : (455, 32)
# right_data5_score_W' 0.044486442357374145
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.08176306016579646
# error_data6_score_W0 0.007092308836785765
# combinedweight shape1 : (520, 32)
# right_data6_score_W' 0.10529508487983515
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.0868138001075825
# error_data7_score_W0 0.0011131206982713932
# combinedweight shape1 : (585, 32)
# right_data7_score_W' 0.1113950719089551
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.11384044750322207
# error_data8_score_W0 0.007936324909540986
# combinedweight shape1 : (650, 32)
# right_data8_score_W' 0.08328213033885658
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.14981429018014145
# error_data9_score_W0 -0.007762135964808108
# combinedweight shape1 : (715, 32)
# right_data9_score_W' 0.08981784353149476
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.4966548090423948
# error_data10_score_W0 -0.007507983397853285
# combinedweight shape1 : (780, 32)
# right_data10_score_W' 0.06352403244243644
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.7387033398821218
# error_data11_score_W0 -0.0626808100289296
# combinedweight shape1 : (845, 32)
# right_data11_score_W' 0.23083966257392452
# Finish one training *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 1.0
# error_data12_score_W0 1.0
# Error data can be represented by W0 12
# combinedweight shape1 : (910, 32)
# right_data12_score_W' 0.4967105263157895
# Finish one training *********
# 13
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.030030474216944023
# all_train_score_W': 0.48169019447423517
# test_score_W0 : 0.0178033483772021
# test_score_W': 0.0755513811765317
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7631320569464899
# right_data0_score_W0 1.0
# error_data0_score_W1 0.019310013479324987
# error_data0_score_W0 0.04617611475925062
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.5818886097445789
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.0362816006970788
# error_data1_score_W0 0.007827979397766058
# combinedweight shape1 : (234, 32)
# right_data1_score_W' 0.17564971766676113
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.03430604496154777
# error_data2_score_W0 0.003801667969206881
# combinedweight shape1 : (312, 32)
# right_data2_score_W' 0.13253794413643444
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.03890476307916696
# error_data3_score_W0 0.007389229285156245
# combinedweight shape1 : (390, 32)
# right_data3_score_W' 0.09222063530541524
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.050995202713622595
# error_data4_score_W0 0.007070444775291408
# combinedweight shape1 : (468, 32)
# right_data4_score_W' 0.11773572526816296
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.07663742822111473
# error_data5_score_W0 0.006723789065344767
# combinedweight shape1 : (546, 32)
# right_data5_score_W' 0.10015968775008888
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.09058594698711957
# error_data6_score_W0 0.012621976041078535
# combinedweight shape1 : (624, 32)
# right_data6_score_W' 0.13557584544131895
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.1118369110750114
# error_data7_score_W0 0.011628102412223087
# combinedweight shape1 : (702, 32)
# right_data7_score_W' 0.12728547552292616
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.18111590663617497
# error_data8_score_W0 0.013170821583606747
# combinedweight shape1 : (780, 32)
# right_data8_score_W' 0.16564667569434002
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.27814333085091786
# error_data9_score_W0 0.015463531271075023
# combinedweight shape1 : (858, 32)
# right_data9_score_W' 0.10565399318111375
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.4906137945581101
# error_data10_score_W0 0.006342187181799668
# combinedweight shape1 : (936, 32)
# right_data10_score_W' 0.16443581202815885
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 0.16445623342175067
# combinedweight shape1 : (1014, 32)
# right_data11_score_W' 0.2395677664099322
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.04601451381350944
# all_train_score_W': 0.4954840629398391
# test_score_W0 : 0.0327452609128286
# test_score_W': 0.08627046662958567
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7567501227295041
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04246626623128817
# error_data0_score_W0 0.04380853088526692
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.4045369622015167
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.03564106217858313
# error_data1_score_W0 0.006522745247282495
# combinedweight shape1 : (273, 32)
# right_data1_score_W' 0.18122967371400855
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.04123245634648743
# error_data2_score_W0 0.010040318085211247
# combinedweight shape1 : (364, 32)
# right_data2_score_W' 0.08911011296528132
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.049456172801391786
# error_data3_score_W0 0.012726331359966769
# combinedweight shape1 : (455, 32)
# right_data3_score_W' 0.09269259675364798
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.06615114317034655
# error_data4_score_W0 0.01628030000499483
# combinedweight shape1 : (546, 32)
# right_data4_score_W' 0.07135415206898665
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.09075240977888004
# error_data5_score_W0 0.010625455277853593
# combinedweight shape1 : (637, 32)
# right_data5_score_W' 0.07592164966788487
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.1120807532215099
# error_data6_score_W0 0.007621776307336163
# combinedweight shape1 : (728, 32)
# right_data6_score_W' 0.1622807398033754
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.15982388771441555
# error_data7_score_W0 0.0028057240268166265
# combinedweight shape1 : (819, 32)
# right_data7_score_W' 0.15143198509855077
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.2577868444437207
# error_data8_score_W0 0.013815624215021352
# combinedweight shape1 : (910, 32)
# right_data8_score_W' 0.107328552923672
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.5011713549478626
# error_data9_score_W0 0.015154692051367245
# combinedweight shape1 : (1001, 32)
# right_data9_score_W' 0.19802308717361405
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.810126582278481
# error_data10_score_W0 0.07643312101910828
# combinedweight shape1 : (1092, 32)
# right_data10_score_W' 0.20356859062341978
# Finish one training *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (1183, 32)
# right_data11_score_W' 0.4262295081967213
# Finish one training *********
# 12
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.0438206297798519
# all_train_score_W': 0.4997519358119388
# test_score_W0 : 0.033608036618234
# test_score_W': 0.07762876887411917
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7491408934707904
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05675267513363038
# error_data0_score_W0 0.040697144534476475
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.34834734052586275
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.032908866133466226
# error_data1_score_W0 0.00398365106811165
# combinedweight shape1 : (312, 32)
# right_data1_score_W' 0.23102321844913692
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.05094136841501479
# error_data2_score_W0 0.004304328473341777
# combinedweight shape1 : (416, 32)
# right_data2_score_W' 0.11344653467059583
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.05332398807254651
# error_data3_score_W0 0.00929214112246245
# combinedweight shape1 : (520, 32)
# right_data3_score_W' 0.07574330844245222
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.07932265999524035
# error_data4_score_W0 0.009715861940664884
# combinedweight shape1 : (624, 32)
# right_data4_score_W' 0.07194559713146176
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.10364874309834443
# error_data5_score_W0 0.011839860322530637
# combinedweight shape1 : (728, 32)
# right_data5_score_W' 0.10617174011122511
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.18086501131496435
# error_data6_score_W0 0.002199589515188077
# combinedweight shape1 : (832, 32)
# right_data6_score_W' 0.07883557507092616
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.25939511763938883
# error_data7_score_W0 0.01614675195745271
# combinedweight shape1 : (936, 32)
# right_data7_score_W' 0.16067294197944576
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.3700159489633174
# error_data8_score_W0 -0.004453889805792317
# combinedweight shape1 : (1040, 32)
# right_data8_score_W' 0.1501011956480189
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8050292499781717
# error_data9_score_W0 0.05806708206283972
# combinedweight shape1 : (1144, 32)
# right_data9_score_W' 0.15680512889007614
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (1248, 32)
# right_data10_score_W' 0.24771059297265702
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.04123391841708783
# all_train_score_W': 0.48228721290300614
# test_score_W0 : 0.033599945022564914
# test_score_W': 0.08089309986057326
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.729995090819833
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03328000452684524
# error_data0_score_W0 0.04380813168386461
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.24642878354942652
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.04282109134987148
# error_data1_score_W0 0.00823492066989085
# combinedweight shape1 : (351, 32)
# right_data1_score_W' 0.27260280255397396
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.05257093649128386
# error_data2_score_W0 0.011465434219889261
# combinedweight shape1 : (468, 32)
# right_data2_score_W' 0.16843815202116158
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.07523360340231706
# error_data3_score_W0 0.009643921058764172
# combinedweight shape1 : (585, 32)
# right_data3_score_W' 0.15063820616695398
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.0899137291640516
# error_data4_score_W0 0.013072292052843805
# combinedweight shape1 : (702, 32)
# right_data4_score_W' 0.08652529152117666
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.16070080179010746
# error_data5_score_W0 0.018884713093599643
# combinedweight shape1 : (819, 32)
# right_data5_score_W' 0.12313518119820457
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.23360535214084135
# error_data6_score_W0 0.02305446227947824
# combinedweight shape1 : (936, 32)
# right_data6_score_W' 0.13743213887864816
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.30701058951973553
# error_data7_score_W0 0.021996950703032356
# combinedweight shape1 : (1053, 32)
# right_data7_score_W' 0.1513066536894353
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7360136729877106
# error_data8_score_W0 -0.013511304821574503
# combinedweight shape1 : (1170, 32)
# right_data8_score_W' 0.22551825495049505
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.4473684210526316
# error_data9_score_W0 -0.10526315789473684
# combinedweight shape1 : (1287, 32)
# right_data9_score_W' 0.2739536758074111
# Finish one training *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (1404, 32)
# right_data10_score_W' 0.0
# Finish one training *********
# 11
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.05094367435829621
# all_train_score_W': 0.4903160085591423
# test_score_W0 : 0.03169651905361186
# test_score_W': 0.07691371345772537
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7469317623956799
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04122594241487837
# error_data0_score_W0 0.03263487752955857
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.26341637998843437
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.04085765445398961
# error_data1_score_W0 0.011534751278206435
# combinedweight shape1 : (390, 32)
# right_data1_score_W' 0.2524535938028137
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.05945559824522319
# error_data2_score_W0 0.008058766689813094
# combinedweight shape1 : (520, 32)
# right_data2_score_W' 0.12661687572077931
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.08689927360879497
# error_data3_score_W0 0.0058877314128682745
# combinedweight shape1 : (650, 32)
# right_data3_score_W' 0.09264212864839942
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.10719787916802821
# error_data4_score_W0 0.012428921837292328
# combinedweight shape1 : (780, 32)
# right_data4_score_W' 0.10520552349430856
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.1590075577131359
# error_data5_score_W0 0.016361677334995557
# combinedweight shape1 : (910, 32)
# right_data5_score_W' 0.08822994850436001
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.32361841946654046
# error_data6_score_W0 0.024613953940273152
# combinedweight shape1 : (1040, 32)
# right_data6_score_W' 0.1141736771447096
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5022949603597756
# error_data7_score_W0 0.025398367208401
# combinedweight shape1 : (1170, 32)
# right_data7_score_W' 0.20697605598307678
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8873421819359016
# error_data8_score_W0 0.01951685184694121
# combinedweight shape1 : (1300, 32)
# right_data8_score_W' 0.22352853827471036
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.0
# combinedweight shape1 : (1430, 32)
# right_data9_score_W' 0.36345210155749946
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.037541694515146086
# all_train_score_W': 0.48506140843204937
# test_score_W0 : 0.022632571182853167
# test_score_W': 0.07654329976964323
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7427589592538046
# right_data0_score_W0 1.0
# error_data0_score_W1 0.061108563011744964
# error_data0_score_W0 0.03972200645325311
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.31405187408949914
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.051891040860946584
# error_data1_score_W0 0.009601622953277798
# combinedweight shape1 : (429, 32)
# right_data1_score_W' 0.21406934355794172
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.08139871852587165
# error_data2_score_W0 0.005742586103348213
# combinedweight shape1 : (572, 32)
# right_data2_score_W' 0.12215574784452897
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.08101803019589242
# error_data3_score_W0 0.011884597628168495
# combinedweight shape1 : (715, 32)
# right_data3_score_W' 0.11452000146582908
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.11346058669828966
# error_data4_score_W0 0.01272691939003621
# combinedweight shape1 : (858, 32)
# right_data4_score_W' 0.09071255081402163
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.16828032082444994
# error_data5_score_W0 0.00635325514951434
# combinedweight shape1 : (1001, 32)
# right_data5_score_W' 0.09242992466409639
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.31490083161213717
# error_data6_score_W0 -0.0010429340589337504
# combinedweight shape1 : (1144, 32)
# right_data6_score_W' 0.11862651197084596
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4709599993092909
# error_data7_score_W0 -0.010030522744550725
# combinedweight shape1 : (1287, 32)
# right_data7_score_W' 0.1645624563884923
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.6313559322033898
# error_data8_score_W0 0.004545454545454545
# combinedweight shape1 : (1430, 32)
# right_data8_score_W' 0.2040670061300017
# Finish one training *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (1573, 32)
# right_data9_score_W' 0.3722275795564127
# Finish one training *********
# 10
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.04620659652741043
# all_train_score_W': 0.49437421610537374
# test_score_W0 : 0.026639989460343794
# test_score_W': 0.07850209973142427
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.7135493372606775
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05215760011057609
# error_data0_score_W0 0.05033528791194102
# combinedweight shape 0: (312, 32)
# right_data0_score_W' 0.49044312349561114
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.05810348353332519
# error_data1_score_W0 0.007798523988519262
# combinedweight shape1 : (468, 32)
# right_data1_score_W' 0.1723201971621826
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.0724304704150538
# error_data2_score_W0 0.00784009825107391
# combinedweight shape1 : (624, 32)
# right_data2_score_W' 0.12212555380902383
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.08464987832639291
# error_data3_score_W0 0.011108010338968388
# combinedweight shape1 : (780, 32)
# right_data3_score_W' 0.11404138889657191
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.1248924595886257
# error_data4_score_W0 0.011522802435017666
# combinedweight shape1 : (936, 32)
# right_data4_score_W' 0.0981417613216986
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.21543817603747992
# error_data5_score_W0 0.014093107129140702
# combinedweight shape1 : (1092, 32)
# right_data5_score_W' 0.11272258463108104
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.38473999437271955
# error_data6_score_W0 0.015568710352124383
# combinedweight shape1 : (1248, 32)
# right_data6_score_W' 0.16466905883353172
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7602825353169146
# error_data7_score_W0 0.010197144799456152
# combinedweight shape1 : (1404, 32)
# right_data7_score_W' 0.1835549131972264
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.26956521739130435
# combinedweight shape1 : (1560, 32)
# right_data8_score_W' 0.2589414182939363
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.06820626176482998
# all_train_score_W': 0.5136797230144686
# test_score_W0 : 0.041081199807631176
# test_score_W': 0.07917720532134814
# neuron unit number: 169
# *******************
#
# Error Data percentage 0.7120765832106039
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06403163600500149
# error_data0_score_W0 0.05516300859075318
# combinedweight shape 0: (338, 32)
# right_data0_score_W' 0.29529034223363276
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.06967543060685014
# error_data1_score_W0 0.015001632189235697
# combinedweight shape1 : (507, 32)
# right_data1_score_W' 0.17454177056120396
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.0899839482111056
# error_data2_score_W0 0.008490284805999452
# combinedweight shape1 : (676, 32)
# right_data2_score_W' 0.13976237463576674
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.08698722145422888
# error_data3_score_W0 0.015071275429732156
# combinedweight shape1 : (845, 32)
# right_data3_score_W' 0.12225417702763772
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.19873356465765205
# error_data4_score_W0 0.00758437376589478
# combinedweight shape1 : (1014, 32)
# right_data4_score_W' 0.12435342766795808
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.32372708741231
# error_data5_score_W0 0.017393730413704102
# combinedweight shape1 : (1183, 32)
# right_data5_score_W' 0.12041537898862535
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5049560084641942
# error_data6_score_W0 0.013243865437039159
# combinedweight shape1 : (1352, 32)
# right_data6_score_W' 0.1613279673461496
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5076201641266119
# error_data7_score_W0 0.07342995169082125
# combinedweight shape1 : (1521, 32)
# right_data7_score_W' 0.2781023652497465
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.1450381679389313
# combinedweight shape1 : (1690, 32)
# right_data8_score_W' 0.19313524590163936
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.06793796400042448
# all_train_score_W': 0.4960036689700225
# test_score_W0 : 0.04649457440536602
# test_score_W': 0.08340083849900785
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.7164948453608248
# right_data0_score_W0 1.0
# error_data0_score_W1 0.054416333644226836
# error_data0_score_W0 0.050142193265720336
# combinedweight shape 0: (364, 32)
# right_data0_score_W' 0.46923479323104605
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.0699067209578414
# error_data1_score_W0 0.004584845249206039
# combinedweight shape1 : (546, 32)
# right_data1_score_W' 0.1649529533972252
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.0934901237510828
# error_data2_score_W0 0.007077016222989531
# combinedweight shape1 : (728, 32)
# right_data2_score_W' 0.11809249494036912
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.12490611097694637
# error_data3_score_W0 0.0016897061267520546
# combinedweight shape1 : (910, 32)
# right_data3_score_W' 0.09910133981103889
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.20515698829013085
# error_data4_score_W0 0.0026829485342142767
# combinedweight shape1 : (1092, 32)
# right_data4_score_W' 0.12480149865088808
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.36468184426761185
# error_data5_score_W0 0.0030586773903950614
# combinedweight shape1 : (1274, 32)
# right_data5_score_W' 0.1188315064402324
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5679441989032679
# error_data6_score_W0 0.0049861570303470154
# combinedweight shape1 : (1456, 32)
# right_data6_score_W' 0.16296931967721504
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.779456632282435
# error_data7_score_W0 -0.003331218274111675
# combinedweight shape1 : (1638, 32)
# right_data7_score_W' 0.13264061419556267
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (1820, 32)
# right_data8_score_W' 0.08321964529331514
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.06382743188376855
# all_train_score_W': 0.4991780004057563
# test_score_W0 : 0.04757758848796656
# test_score_W': 0.09187733751282282
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.7295041728031418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0631015881829056
# error_data0_score_W0 0.05287004944387944
# combinedweight shape 0: (390, 32)
# right_data0_score_W' 0.3084981662021458
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.07004228435001353
# error_data1_score_W0 0.006260300809657885
# combinedweight shape1 : (585, 32)
# right_data1_score_W' 0.2415528250717386
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.08373306616616782
# error_data2_score_W0 0.012178206833132308
# combinedweight shape1 : (780, 32)
# right_data2_score_W' 0.1699485184866014
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1260438838641992
# error_data3_score_W0 0.006972804918204454
# combinedweight shape1 : (975, 32)
# right_data3_score_W' 0.12665302603460474
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.22696929528882667
# error_data4_score_W0 0.010471071285253085
# combinedweight shape1 : (1170, 32)
# right_data4_score_W' 0.12981889532858953
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4050604756956266
# error_data5_score_W0 0.017297237404178694
# combinedweight shape1 : (1365, 32)
# right_data5_score_W' 0.11724934438436699
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.48132361198030205
# error_data6_score_W0 0.04802812377315393
# combinedweight shape1 : (1560, 32)
# right_data6_score_W' 0.17022034884605922
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.9117421335379893
# error_data7_score_W0 -0.015023474178403756
# combinedweight shape1 : (1755, 32)
# right_data7_score_W' 0.3905066263282786
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (1950, 32)
# right_data8_score_W' 0.36327345309381237
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.06529152022541398
# all_train_score_W': 0.5059976907047871
# test_score_W0 : 0.041638213068674296
# test_score_W': 0.08780346292787462
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.7056946489936181
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06978293090848976
# error_data0_score_W0 0.04889403614419203
# combinedweight shape 0: (416, 32)
# right_data0_score_W' 0.26850808080611327
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.06669360928535968
# error_data1_score_W0 0.005038227154859089
# combinedweight shape1 : (624, 32)
# right_data1_score_W' 0.16197742492352143
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1102177018035203
# error_data2_score_W0 0.006385231241364122
# combinedweight shape1 : (832, 32)
# right_data2_score_W' 0.11697154548140086
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.13677816738303272
# error_data3_score_W0 0.006833317315431192
# combinedweight shape1 : (1040, 32)
# right_data3_score_W' 0.12472465175879198
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.22433493908225216
# error_data4_score_W0 0.005223224646805821
# combinedweight shape1 : (1248, 32)
# right_data4_score_W' 0.11646742407994315
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.42434983475611393
# error_data5_score_W0 0.01364460198485511
# combinedweight shape1 : (1456, 32)
# right_data5_score_W' 0.1651694832444489
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5710063806013012
# error_data6_score_W0 -0.03528558174177413
# combinedweight shape1 : (1664, 32)
# right_data6_score_W' 0.22173079315154834
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 -0.004415011037527594
# combinedweight shape1 : (1872, 32)
# right_data7_score_W' 0.32859161782081875
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.07298770780277047
# all_train_score_W': 0.5022642077427262
# test_score_W0 : 0.04448535402165802
# test_score_W': 0.0853171774204218
# neuron unit number: 221
# *******************
#
# Error Data percentage 0.6983308787432498
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07669941859758429
# error_data0_score_W0 0.06371713896572241
# combinedweight shape 0: (442, 32)
# right_data0_score_W' 0.32030207805325106
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.09525755757543412
# error_data1_score_W0 0.009830972308409005
# combinedweight shape1 : (663, 32)
# right_data1_score_W' 0.18225660743279828
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.11640458875260778
# error_data2_score_W0 0.006008412961161573
# combinedweight shape1 : (884, 32)
# right_data2_score_W' 0.14622700601123628
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.18904157960841658
# error_data3_score_W0 0.009342735053783758
# combinedweight shape1 : (1105, 32)
# right_data3_score_W' 0.09712121550830109
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.305550728170788
# error_data4_score_W0 0.013601433288644747
# combinedweight shape1 : (1326, 32)
# right_data4_score_W' 0.14340979901988066
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4898946213550026
# error_data5_score_W0 0.026653768341429525
# combinedweight shape1 : (1547, 32)
# right_data5_score_W' 0.18025432296584548
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6662446822604625
# error_data6_score_W0 -0.021857383048165365
# combinedweight shape1 : (1768, 32)
# right_data6_score_W' 0.17692601507508549
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.2857142857142857
# combinedweight shape1 : (1989, 32)
# right_data7_score_W' 0.593515606097266
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.08150144862312143
# all_train_score_W': 0.5078319319514606
# test_score_W0 : 0.0524215089000704
# test_score_W': 0.09034813524067316
# neuron unit number: 234
# *******************
#
# Error Data percentage 0.6816396661757487
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06920529347703189
# error_data0_score_W0 0.06953524190972878
# combinedweight shape 0: (468, 32)
# right_data0_score_W' 0.3893668941060515
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.08302090240374205
# error_data1_score_W0 0.009740340977962284
# combinedweight shape1 : (702, 32)
# right_data1_score_W' 0.16215152058963866
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1186937468152063
# error_data2_score_W0 0.006565434374772466
# combinedweight shape1 : (936, 32)
# right_data2_score_W' 0.09914321875186234
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.20805522538046287
# error_data3_score_W0 0.010254593307934668
# combinedweight shape1 : (1170, 32)
# right_data3_score_W' 0.16055380194771737
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.29022314645485187
# ...
# combinedweight shape1 : (1196, 32)
# right_data2_score_W' 0.12420418672137618
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.20481646324054767
# error_data3_score_W0 0.012720629709641273
# combinedweight shape1 : (1495, 32)
# right_data3_score_W' 0.18887986462579054
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.39984634999565
# error_data4_score_W0 0.022864375162346406
# combinedweight shape1 : (1794, 32)
# right_data4_score_W' 0.16003936259829885
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.611831564574806
# error_data5_score_W0 0.004128411619089399
# combinedweight shape1 : (2093, 32)
# right_data5_score_W' 0.17180710458084517
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.8102575896964122
# error_data6_score_W0 -0.026849217638691324
# combinedweight shape1 : (2392, 32)
# right_data6_score_W' 0.2754707292911912
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.0
# error_data7_score_W0 0.0
# combinedweight shape1 : (2691, 32)
# right_data7_score_W' 0.42457791309161363
# Finish one training *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (2990, 32)
# right_data8_score_W' 0.0
# Finish one training *********
# 9
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.0735630918685753
# all_train_score_W': 0.4986975154179131
# test_score_W0 : 0.049109105656048854
# test_score_W': 0.09404323108077424
# neuron unit number: 312
# *******************
#
# Error Data percentage 0.6909671084928817
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08485280143572431
# error_data0_score_W0 0.051122477188884
# combinedweight shape 0: (624, 32)
# right_data0_score_W' 0.24443911073476476
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.11557902771308524
# error_data1_score_W0 0.00573772250249202
# combinedweight shape1 : (936, 32)
# right_data1_score_W' 0.1747832675467687
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1717163954955417
# error_data2_score_W0 0.008108145247697767
# combinedweight shape1 : (1248, 32)
# right_data2_score_W' 0.12531499146640582
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.297572305446225
# error_data3_score_W0 0.024134420840004823
# combinedweight shape1 : (1560, 32)
# right_data3_score_W' 0.18638671570912108
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4816907831067438
# error_data4_score_W0 0.02770519681191197
# combinedweight shape1 : (1872, 32)
# right_data4_score_W' 0.1945987399608023
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.7136953252287254
# error_data5_score_W0 -0.01739401850065263
# combinedweight shape1 : (2184, 32)
# right_data5_score_W' 0.21744116883089218
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5384615384615384
# error_data6_score_W0 -0.10526315789473684
# combinedweight shape1 : (2496, 32)
# right_data6_score_W' 0.32707891523449384
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 1.0
# Error data can be represented by W0 7
# combinedweight shape1 : (2808, 32)
# right_data7_score_W' 0.34375
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.07413604391227224
# all_train_score_W': 0.4994144099539527
# test_score_W0 : 0.04352529940847333
# test_score_W': 0.07906094502192777
# neuron unit number: 325
# *******************
#
# Error Data percentage 0.6850760922925871
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0915554836999835
# error_data0_score_W0 0.05392805151814819
# combinedweight shape 0: (650, 32)
# right_data0_score_W' 0.33004746590418155
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.11369404559631366
# error_data1_score_W0 0.011605152510283453
# combinedweight shape1 : (975, 32)
# right_data1_score_W' 0.19250577340975447
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.18180905729135127
# error_data2_score_W0 0.011975847392258371
# combinedweight shape1 : (1300, 32)
# right_data2_score_W' 0.14962405685729802
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3124977479056271
# error_data3_score_W0 0.016259628898105425
# combinedweight shape1 : (1625, 32)
# right_data3_score_W' 0.1875917890003562
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5686066247643901
# error_data4_score_W0 0.0333452756167222
# combinedweight shape1 : (1950, 32)
# right_data4_score_W' 0.14065272493386635
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.6813353566009105
# error_data5_score_W0 0.0056657223796034
# combinedweight shape1 : (2275, 32)
# right_data5_score_W' 0.1890314430544377
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 -0.2962962962962963
# combinedweight shape1 : (2600, 32)
# right_data6_score_W' 0.2815294577652208
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.08043091108424888
# all_train_score_W': 0.5132570739519696
# test_score_W0 : 0.04730811361738576
# test_score_W': 0.09289214096380743
# neuron unit number: 338
# *******************
#
# Error Data percentage 0.6899852724594993
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0861925425528119
# error_data0_score_W0 0.05292040832943484
# combinedweight shape 0: (676, 32)
# right_data0_score_W' 0.28436800878448815
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.09607842930866883
# error_data1_score_W0 0.007439205573833122
# combinedweight shape1 : (1014, 32)
# right_data1_score_W' 0.17758347721873902
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.17328708382676958
# error_data2_score_W0 0.006537379271184996
# combinedweight shape1 : (1352, 32)
# right_data2_score_W' 0.1655251535534529
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3018121069299522
# error_data3_score_W0 0.024540400819507674
# combinedweight shape1 : (1690, 32)
# right_data3_score_W' 0.16944196274797949
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4784606502141026
# error_data4_score_W0 0.026701432920073372
# combinedweight shape1 : (2028, 32)
# right_data4_score_W' 0.19948936084946486
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5893472621966386
# error_data5_score_W0 -0.01611176260643451
# combinedweight shape1 : (2366, 32)
# right_data5_score_W' 0.25429580875315466
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.9298128342245989
# error_data6_score_W0 -0.07211231652839821
# combinedweight shape1 : (2704, 32)
# right_data6_score_W' 0.23114462583396841
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 1.0
# Error data can be represented by W0 7
# combinedweight shape1 : (3042, 32)
# right_data7_score_W' 0.6635859519408502
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.07804749013938371
# all_train_score_W': 0.5127067266772258
# test_score_W0 : 0.05142895059908572
# test_score_W': 0.09231860685033619
# neuron unit number: 351
# *******************
#
# Error Data percentage 0.6941580756013745
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0947033135252303
# error_data0_score_W0 0.059830303773406576
# combinedweight shape 0: (702, 32)
# right_data0_score_W' 0.24770749184114302
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.12279514856527701
# error_data1_score_W0 0.005523254261846796
# combinedweight shape1 : (1053, 32)
# right_data1_score_W' 0.24506373982325835
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.22407882110182825
# error_data2_score_W0 0.012448908580197966
# combinedweight shape1 : (1404, 32)
# right_data2_score_W' 0.11676408345294388
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.32911551435934905
# error_data3_score_W0 0.013218782842233608
# combinedweight shape1 : (1755, 32)
# right_data3_score_W' 0.23403241437620087
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5897271464394153
# error_data4_score_W0 0.03382542684559411
# combinedweight shape1 : (2106, 32)
# right_data4_score_W' 0.19143481860031517
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.9189705790492848
# error_data5_score_W0 0.027014593503207503
# combinedweight shape1 : (2457, 32)
# right_data5_score_W' 0.23693058080786047
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (2808, 32)
# right_data6_score_W' 0.4744710860366714
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.08177745075838995
# all_train_score_W': 0.5120183277661138
# test_score_W0 : 0.04654256803801228
# test_score_W': 0.08880771110551035
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.6708394698085419
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09434872055650961
# error_data0_score_W0 0.06411112616457525
# combinedweight shape 0: (728, 32)
# right_data0_score_W' 0.3671221701165004
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.11188395639051155
# error_data1_score_W0 0.010728061788877832
# combinedweight shape1 : (1092, 32)
# right_data1_score_W' 0.194701010436251
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.18998372870918764
# error_data2_score_W0 0.013605141114604133
# combinedweight shape1 : (1456, 32)
# right_data2_score_W' 0.15824264060638218
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3220184005036877
# error_data3_score_W0 0.009250651526238853
# combinedweight shape1 : (1820, 32)
# right_data3_score_W' 0.12779223259048594
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4789781920748587
# error_data4_score_W0 0.02220605329259056
# combinedweight shape1 : (2184, 32)
# right_data4_score_W' 0.17599257548464656
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.7110253398221178
# error_data5_score_W0 -0.03194103194103194
# combinedweight shape1 : (2548, 32)
# right_data5_score_W' 0.2815417247391638
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.7677419354838709
# error_data6_score_W0 -0.14084507042253522
# combinedweight shape1 : (2912, 32)
# right_data6_score_W' 0.30201672405312346
# Finish one training *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 1.0
# Error data can be represented by W0 7
# combinedweight shape1 : (3276, 32)
# right_data7_score_W' -0.06060606060606061
# Finish one training *********
# 8
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.09747125959846598
# all_train_score_W': 0.5140644489076496
# test_score_W0 : 0.04982552709966954
# test_score_W': 0.08983840432071769
# neuron unit number: 377
# *******************
#
# Error Data percentage 0.6944035346097202
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09173935885091554
# error_data0_score_W0 0.05013206862724549
# combinedweight shape 0: (754, 32)
# right_data0_score_W' 0.26774330010337294
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.1037088182330028
# error_data1_score_W0 0.007880630347218462
# combinedweight shape1 : (1131, 32)
# right_data1_score_W' 0.17592238453245185
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.16616782922919068
# error_data2_score_W0 0.008478264883125605
# combinedweight shape1 : (1508, 32)
# right_data2_score_W' 0.1642481957860372
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2736140615756064
# error_data3_score_W0 0.014996962846420738
# combinedweight shape1 : (1885, 32)
# right_data3_score_W' 0.19569034649732336
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5499208569227162
# error_data4_score_W0 0.02334698163376334
# combinedweight shape1 : (2262, 32)
# right_data4_score_W' 0.171009718619525
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.6507272493242373
# error_data5_score_W0 0.037210117413400315
# combinedweight shape1 : (2639, 32)
# right_data5_score_W' 0.20839408239942925
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 -0.023255813953488372
# combinedweight shape1 : (3016, 32)
# right_data6_score_W' 0.2969914683430624
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.07255479779884762
# all_train_score_W': 0.5117590036269872
# test_score_W0 : 0.03961458301654015
# test_score_W': 0.09383095144586275
# neuron unit number: 390
# *******************
#
# Error Data percentage 0.6946489936180658
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08365160931912777
# error_data0_score_W0 0.059063407611024625
# combinedweight shape 0: (780, 32)
# right_data0_score_W' 0.29051106791387005
# Finish one training *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.12082350403364464
# error_data1_score_W0 0.005421314406622389
# combinedweight shape1 : (1170, 32)
# right_data1_score_W' 0.16182146075523368
# Finish one training *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.17480371227381994
# error_data2_score_W0 0.013599195883962115
# combinedweight shape1 : (1560, 32)
# right_data2_score_W' 0.14522142639686608
# Finish one training *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.2655109080436586
# error_data3_score_W0 0.004276772774173053
# combinedweight shape1 : (1950, 32)
# right_data3_score_W' 0.1574104562491953
# Finish one training *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4506185588335028
# error_data4_score_W0 0.023080783371275514
# combinedweight shape1 : (2340, 32)
# right_data4_score_W' 0.19102533072036268
# Finish one training *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.753503801678396
# error_data5_score_W0 0.03845193940364438
# combinedweight shape1 : (2730, 32)
# right_data5_score_W' 0.24261070827935122
# Finish one training *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.058823529411764705
# combinedweight shape1 : (3120, 32)
# right_data6_score_W' 0.27766550309265725
# Finish one training *********
# 7
#  NO Error Data, Finish Training!
# all_train_score_W0: 0.07851863761372349
# all_train_score_W': 0.502895407675963
# test_score_W0 : 0.04432564061955174
# test_score_W': 0.08931966702091547
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.038388  0.012996  0.002373   0.033535  0.043241
# 1  test_score_W'  30.0  0.086599  0.007090  0.001294   0.083952  0.089247
# 2       combined  60.0  0.062494  0.026432  0.003412   0.055665  0.069322
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0482
# 1                          Degrees of freedom =   58.0000
# 2                                           t =  -17.8367
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -4.6054
# 7                                   Hedge's g =   -4.5456
# 8                               Glass's delta =   -3.7096
# 9                                 Pearson's r =    0.9197
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=-17.83673056222203, pvalue=1.6082539749459535e-25)

# %%
# local scope2
scoretype = 2
scope_num = 30
class_num = 13
dim_num = 32
unstable_repeat_num = 30
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []

y = 1
while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(1,scoretype)
        
        all_train_score_W0.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
        test_score_W0.append(optimize_W.test_score_W0)
        test_score_W_combine.append(optimize_W.test_score_W_combined)
        error_data_percentage.append(optimize_W.first_error_data_percentage)
        
        all_train_score_W0_global.append(optimize_W.all_train_score_W0)
        all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
        test_score_W0_global.append(optimize_W.test_score_W0)
        test_score_W_combine_global.append(optimize_W.test_score_W_combined)

        
        x = x+1

    
    figure, axis = plt.subplots(1, 2,figsize=(10, 5))

    if scoretype == 0:
        axis[0].set_title("Purity Score")
    elif scoretype == 1:
        axis[0].set_title("NMI Score")
    elif scoretype == 2:
        axis[0].set_title("ARI Score")
            
    axis[0].set_xlabel('Neuron number')
    axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
    axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
    axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
    axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
    axis[0].legend()
    
    axis[1].set_title("Error_Data_Percentage")
    axis[1].set_xlabel('Neuron number')
    axis[1].plot(unit_list,error_data_percentage,'g')

    plt.show()
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []
    

df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])

summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')
# Out:
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8114874815905744
# right_data0_score_W0 1.0
# error_data0_score_W1 0.013804648954173078
# error_data0_score_W0 0.028546450172309112
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.17684127176110387
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.008607020224347403
# all_train_score_W': 0.009165491232877939
# test_score_W0 : 0.0054125368125798445
# test_score_W': 0.009404234126080614
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.8178694158075601
# right_data0_score_W0 1.0
# error_data0_score_W1 0.01552125875496197
# error_data0_score_W0 0.029372954276271054
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.28950342420861735
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.010051625355644826
# all_train_score_W': 0.011105563987996437
# test_score_W0 : 0.013389862980718075
# test_score_W': 0.009293403905563678
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.7960235640648011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.024056758649179937
# error_data0_score_W0 0.030163623978756205
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.1849379877479391
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.022357309429427676
# all_train_score_W': 0.019862979695229398
# test_score_W0 : 0.022007948944205484
# test_score_W': 0.018018570280931522
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7677957781050565
# right_data0_score_W0 1.0
# error_data0_score_W1 0.037493245818372996
# error_data0_score_W0 0.039246946879517755
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.4034329658731826
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0316750627425996
# all_train_score_W': 0.042645739192838934
# test_score_W0 : 0.03370512751110831
# test_score_W': 0.04458829900621887
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.789887088856161
# right_data0_score_W0 1.0
# error_data0_score_W1 0.026460744244762118
# error_data0_score_W0 0.030974841700465692
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.3118050145155169
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.022855087499822846
# all_train_score_W': 0.02831808078205038
# test_score_W0 : 0.01788787136271492
# test_score_W': 0.02131566391163206
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7503681885125184
# right_data0_score_W0 1.0
# error_data0_score_W1 0.029506085346037762
# error_data0_score_W0 0.04309623312253114
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.35942543226998036
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04632830377894732
# all_train_score_W': 0.036748078084399
# test_score_W0 : 0.03926640383849038
# test_score_W': 0.026860900070673596
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7670594010800197
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03954895034112308
# error_data0_score_W0 0.030836980372891027
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.28193051631998933
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.028344617565589387
# all_train_score_W': 0.054353441322154916
# test_score_W0 : 0.026074289232169926
# test_score_W': 0.03526039828464121
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7631320569464899
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04884791130208988
# error_data0_score_W0 0.03367655390422052
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.2868123677495257
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03332312883095993
# all_train_score_W': 0.04551255221005141
# test_score_W0 : 0.026204002418158717
# test_score_W': 0.029090042554647196
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.7589592538046146
# right_data0_score_W0 1.0
# error_data0_score_W1 0.047823919164817714
# error_data0_score_W0 0.036298868748143524
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.24837122111617657
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.036647254012208676
# all_train_score_W': 0.045358853940138354
# test_score_W0 : 0.02890805052537451
# test_score_W': 0.033934716610159
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7474226804123711
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05156016502390245
# error_data0_score_W0 0.03986988249952119
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.3219600170550979
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04325730227635818
# all_train_score_W': 0.050802417425341174
# test_score_W0 : 0.02491740353155911
# test_score_W': 0.035454561316954916
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7277859597447226
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05052042696987171
# error_data0_score_W0 0.055357526709333076
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.35740349080644607
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05697042824089726
# all_train_score_W': 0.05293638989596826
# test_score_W0 : 0.03917229501957728
# test_score_W': 0.036055882870436214
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.7346588119783997
# right_data0_score_W0 1.0
# error_data0_score_W1 0.053184509712223715
# error_data0_score_W0 0.048893198606335474
# combinedweight shape 0: (312, 32)
# right_data0_score_W' 0.31162209863506996
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05634030439141906
# all_train_score_W': 0.0575073499632305
# test_score_W0 : 0.03794189444616394
# test_score_W': 0.03646954621438444
# neuron unit number: 169
# *******************
#
# Error Data percentage 0.7346588119783997
# right_data0_score_W0 1.0
# error_data0_score_W1 0.055127678215702094
# error_data0_score_W0 0.04751835643773422
# combinedweight shape 0: (338, 32)
# right_data0_score_W' 0.4446992806919295
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05646140262077287
# all_train_score_W': 0.065785619278421
# test_score_W0 : 0.03815701818375367
# test_score_W': 0.04697615731969026
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.7027491408934707
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05581868176650788
# error_data0_score_W0 0.05093781263560869
# combinedweight shape 0: (364, 32)
# right_data0_score_W' 0.31373477776465086
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06703114610561318
# all_train_score_W': 0.07278309567718434
# test_score_W0 : 0.04536482599472537
# test_score_W': 0.05022856938499615
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.7061855670103093
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05857413028432573
# error_data0_score_W0 0.051883223939447096
# combinedweight shape 0: (390, 32)
# right_data0_score_W' 0.22869403584088951
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06815376088083273
# all_train_score_W': 0.06143007221893924
# test_score_W0 : 0.04699957577898849
# test_score_W': 0.04422283368746596
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.708885616102111
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0668273602092852
# error_data0_score_W0 0.05448834044373966
# combinedweight shape 0: (416, 32)
# right_data0_score_W' 0.2998750492496873
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06848466540078159
# all_train_score_W': 0.06108519888092652
# test_score_W0 : 0.04983719855380945
# test_score_W': 0.03776626493951888
# neuron unit number: 221
# *******************
#
# Error Data percentage 0.7216494845360825
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09530502186966837
# error_data0_score_W0 0.04104821680763729
# combinedweight shape 0: (442, 32)
# right_data0_score_W' 0.4145556999763305
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05442274681969307
# all_train_score_W': 0.07937476873401024
# test_score_W0 : 0.03323701829267187
# test_score_W': 0.046804171630107395
# neuron unit number: 234
# *******************
#
# Error Data percentage 0.6944035346097202
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07618354014908663
# error_data0_score_W0 0.051404407881856344
# combinedweight shape 0: (468, 32)
# right_data0_score_W' 0.30175622227853294
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0737155004033415
# all_train_score_W': 0.07745196893067877
# test_score_W0 : 0.05866727274686083
# test_score_W': 0.04562157672250511
# neuron unit number: 247
# *******************
#
# Error Data percentage 0.7292587137947962
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07391568236800328
# error_data0_score_W0 0.04681477298708617
# combinedweight shape 0: (494, 32)
# right_data0_score_W' 0.2090216169275524
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05417676125497074
# all_train_score_W': 0.06312858832158237
# test_score_W0 : 0.03759573956964126
# test_score_W': 0.04302785367907254
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.6998036327933235
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07212407023682119
# error_data0_score_W0 0.05740924454724485
# combinedweight shape 0: (520, 32)
# right_data0_score_W' 0.3927475185828364
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07467456730514548
# all_train_score_W': 0.07386277296270845
# test_score_W0 : 0.05442589691107903
# test_score_W': 0.04786706097649546
# neuron unit number: 273
# *******************
#
# Error Data percentage 0.7174766813942072
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06084174430503112
# error_data0_score_W0 0.06267430414150672
# combinedweight shape 0: (546, 32)
# right_data0_score_W' 0.32138384796498987
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07262701584711993
# all_train_score_W': 0.06586210123424016
# test_score_W0 : 0.05497849610845439
# test_score_W': 0.039777130239691844
# neuron unit number: 286
# *******************
#
# Error Data percentage 0.697594501718213
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09124942648819499
# error_data0_score_W0 0.05801948875837163
# combinedweight shape 0: (572, 32)
# right_data0_score_W' 0.3181906804936128
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07700964638767631
# all_train_score_W': 0.0877762985465949
# test_score_W0 : 0.03928867628110344
# test_score_W': 0.04555541705268042
# neuron unit number: 299
# *******************
#
# Error Data percentage 0.7214040255277369
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08608884418178107
# error_data0_score_W0 0.04236625688499516
# combinedweight shape 0: (598, 32)
# right_data0_score_W' 0.24086750456204914
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.055674068697183485
# all_train_score_W': 0.06703389555554069
# test_score_W0 : 0.04004378615584503
# test_score_W': 0.04080664929102229
# neuron unit number: 312
# *******************
#
# Error Data percentage 0.6968581246931762
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08920377730311137
# error_data0_score_W0 0.06082670415216256
# combinedweight shape 0: (624, 32)
# right_data0_score_W' 0.29056346045615233
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07709529442181978
# all_train_score_W': 0.07399322063881403
# test_score_W0 : 0.048646984738389354
# test_score_W': 0.04430959638687577
# neuron unit number: 325
# *******************
#
# Error Data percentage 0.7157584683357879
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08671987287515999
# error_data0_score_W0 0.04936523023799836
# combinedweight shape 0: (650, 32)
# right_data0_score_W' 0.2718776963699077
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.061095311739822016
# all_train_score_W': 0.07899256034009487
# test_score_W0 : 0.03892305632161746
# test_score_W': 0.05176951347476486
# neuron unit number: 338
# *******************
#
# Error Data percentage 0.7017673048600883
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07755938571244651
# error_data0_score_W0 0.048771471366012085
# combinedweight shape 0: (676, 32)
# right_data0_score_W' 0.29355417522804544
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06848918276665948
# all_train_score_W': 0.07458980559026103
# test_score_W0 : 0.049582204672153254
# test_score_W': 0.042141816533631825
# neuron unit number: 351
# *******************
#
# Error Data percentage 0.7344133529700541
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0672051582197281
# error_data0_score_W0 0.033657432960286116
# combinedweight shape 0: (702, 32)
# right_data0_score_W' 0.18621636824267004
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04528886553220285
# all_train_score_W': 0.04984106705251641
# test_score_W0 : 0.02017599540257612
# test_score_W': 0.025520759039373186
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.710112911143839
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07399823143960073
# error_data0_score_W0 0.045574955313994546
# combinedweight shape 0: (728, 32)
# right_data0_score_W' 0.4045505517144081
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06073862356389866
# all_train_score_W': 0.07641072895638286
# test_score_W0 : 0.03537998426626665
# test_score_W': 0.04213967602409225
# neuron unit number: 377
# *******************
#
# Error Data percentage 0.718213058419244
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08072793579555006
# error_data0_score_W0 0.045223814968342074
# combinedweight shape 0: (754, 32)
# right_data0_score_W' 0.23200436154361187
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05798633183270677
# all_train_score_W': 0.06683214075079057
# test_score_W0 : 0.04947924750637022
# test_score_W': 0.03409102842080267
# neuron unit number: 390
# *******************
#
# Error Data percentage 0.7147766323024055
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07430136439629371
# error_data0_score_W0 0.043222928005391084
# combinedweight shape 0: (780, 32)
# right_data0_score_W' 0.2540694550024704
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.058008229192100476
# all_train_score_W': 0.05629307285102629
# test_score_W0 : 0.034842236838010965
# test_score_W': 0.03373440202328962
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8252331860579283
# right_data0_score_W0 1.0
# error_data0_score_W1 0.015295457302300246
# error_data0_score_W0 0.028896150911499816
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.20762534072770253
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0075894909564633885
# all_train_score_W': 0.00675901855141811
# test_score_W0 : 0.005009823025841042
# test_score_W': 0.005874975155388741
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.7979872361315661
# right_data0_score_W0 1.0
# error_data0_score_W1 0.020966598970335062
# error_data0_score_W0 0.032905097427788646
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.4044159764019882
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.021182155066949024
# all_train_score_W': 0.022820227836520594
# test_score_W0 : 0.021070555966784584
# test_score_W': 0.02539635644862593
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.7925871379479626
# right_data0_score_W0 1.0
# error_data0_score_W1 0.028243256801630357
# error_data0_score_W0 0.03338116548629646
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.16681869035936886
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.01982251498652761
# all_train_score_W': 0.019326151448491778
# test_score_W0 : 0.01717640485313023
# test_score_W': 0.014493311526634805
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7849779086892489
# right_data0_score_W0 1.0
# error_data0_score_W1 0.023125864644619226
# error_data0_score_W0 0.03427280864023809
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.5154767263519873
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.02305348124941315
# all_train_score_W': 0.023467733938176312
# test_score_W0 : 0.02248014336976765
# test_score_W': 0.02022376253448756
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.7938144329896907
# right_data0_score_W0 1.0
# error_data0_score_W1 0.033646686783135336
# error_data0_score_W0 0.029308068427462506
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.2688013840261042
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.01614476693921059
# all_train_score_W': 0.033013066580769385
# test_score_W0 : 0.019551775946605204
# test_score_W': 0.03212024638745341
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7660775650466373
# right_data0_score_W0 1.0
# error_data0_score_W1 0.034590248802439355
# error_data0_score_W0 0.03686666067534463
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.28989749912200213
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03384606448368601
# all_train_score_W': 0.02899822130464203
# test_score_W0 : 0.026828332160003215
# test_score_W': 0.023728493318240052
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7594501718213058
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04366066972277903
# error_data0_score_W0 0.033943900428366265
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.30009172921862654
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03214290298996172
# all_train_score_W': 0.04061951967099733
# test_score_W0 : 0.025082532770878813
# test_score_W': 0.026077832342818155
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7447226313205695
# right_data0_score_W0 1.0
# error_data0_score_W1 0.045253868451771845
# error_data0_score_W0 0.04569793598018505
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.3240080483883857
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04801101545975164
# all_train_score_W': 0.04942533382869186
# test_score_W0 : 0.03871159307631212
# test_score_W': 0.040263104526354516
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.7268041237113402
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03914604129425157
# error_data0_score_W0 0.04870194232351547
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.38319362421988057
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05913607963290611
# all_train_score_W': 0.05042595127540165
# test_score_W0 : 0.035781166254480606
# test_score_W': 0.03443253582168548
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7410407461953854
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04782360977711636
# error_data0_score_W0 0.03476849717503207
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.4510152847258518
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04020595620474244
# all_train_score_W': 0.05053947267509
# test_score_W0 : 0.027850025041193303
# test_score_W': 0.031990580589083994
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7295041728031418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0627894277309812
# error_data0_score_W0 0.03583869605165381
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.2339395030743481
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.044780812053362734
# all_train_score_W': 0.056810225685784914
# test_score_W0 : 0.03589572682118066
# test_score_W': 0.03682423020760584
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.7270495827196858
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04743457064426118
# error_data0_score_W0 0.03681430823898675
# combinedweight shape 0: (312, 32)
# right_data0_score_W' 0.3359224948000568
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04767089415115648
# all_train_score_W': 0.0576488038111446
# test_score_W0 : 0.035123747293495974
# test_score_W': 0.0413398281758168
# neuron unit number: 169
# *******************
#
# Error Data percentage 0.7295041728031418
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05412771373902189
# error_data0_score_W0 0.04803219683287667
# combinedweight shape 0: (338, 32)
# right_data0_score_W' 0.2284254017553154
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.054214103210753234
# all_train_score_W': 0.049794206201541194
# test_score_W0 : 0.03954571590706097
# test_score_W': 0.035497287563539204
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.708885616102111
# right_data0_score_W0 1.0
# error_data0_score_W1 0.055958904805884904
# error_data0_score_W0 0.05232637027893257
# combinedweight shape 0: (364, 32)
# right_data0_score_W' 0.39091514866018445
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06970123123923315
# all_train_score_W': 0.07116352531150906
# test_score_W0 : 0.04705338481709787
# test_score_W': 0.04238769687847823
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.7231222385861561
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07431701291931515
# error_data0_score_W0 0.03987945944709467
# combinedweight shape 0: (390, 32)
# right_data0_score_W' 0.3661723764826248
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.055794490415874434
# all_train_score_W': 0.06893515157666694
# test_score_W0 : 0.029415491480065777
# test_score_W': 0.03874323481585198
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.7128129602356407
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06391158869351743
# error_data0_score_W0 0.04994762392344524
# combinedweight shape 0: (416, 32)
# right_data0_score_W' 0.39131805228998895
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06442609512513169
# all_train_score_W': 0.07426086338657155
# test_score_W0 : 0.04693959747397675
# test_score_W': 0.04309416698701682
# neuron unit number: 221
# *******************
#
# Error Data percentage 0.7047128129602357
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0801039564279318
# error_data0_score_W0 0.050172661325588896
# combinedweight shape 0: (442, 32)
# right_data0_score_W' 0.2777415579481444
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07367243379731063
# all_train_score_W': 0.07476570062385872
# test_score_W0 : 0.04528103979171843
# test_score_W': 0.039977627403708055
# neuron unit number: 234
# *******************
#
# Error Data percentage 0.729995090819833
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07418298528528965
# error_data0_score_W0 0.048630839259750085
# combinedweight shape 0: (468, 32)
# right_data0_score_W' 0.3122502964175171
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.056961854134642616
# all_train_score_W': 0.0676969412872672
# test_score_W0 : 0.03826279997527537
# test_score_W': 0.04639071972484128
# neuron unit number: 247
# *******************
#
# Error Data percentage 0.7083946980854198
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0815988519658539
# error_data0_score_W0 0.05284489075723411
# combinedweight shape 0: (494, 32)
# right_data0_score_W' 0.331285730862594
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07119445452956502
# all_train_score_W': 0.0778916846413219
# test_score_W0 : 0.04098051464267649
# test_score_W': 0.03900981207072003
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.7214040255277369
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07985149558799873
# error_data0_score_W0 0.04616102245998519
# combinedweight shape 0: (520, 32)
# right_data0_score_W' 0.28672362844645966
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.056777056557214496
# all_train_score_W': 0.07219800152237234
# test_score_W0 : 0.03144819754506576
# test_score_W': 0.043841453815167464
# neuron unit number: 273
# *******************
#
# Error Data percentage 0.6872852233676976
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09182314958499811
# error_data0_score_W0 0.06671144398418496
# combinedweight shape 0: (546, 32)
# right_data0_score_W' 0.4495327670741209
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08470366543472785
# all_train_score_W': 0.09821788502628058
# test_score_W0 : 0.060036705680041026
# test_score_W': 0.06486021620056417
# neuron unit number: 286
# *******************
#
# Error Data percentage 0.7196858124693176
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07690141861725272
# error_data0_score_W0 0.046270614644156854
# combinedweight shape 0: (572, 32)
# right_data0_score_W' 0.27667054079123143
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.061604733389438365
# all_train_score_W': 0.06232780083280299
# test_score_W0 : 0.03665854927406913
# test_score_W': 0.03956530553896007
# neuron unit number: 299
# *******************
#
# Error Data percentage 0.7196858124693176
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07546856923172227
# error_data0_score_W0 0.052068423812101555
# combinedweight shape 0: (598, 32)
# right_data0_score_W' 0.2051479902765849
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06108302994587845
# all_train_score_W': 0.06371787077992978
# test_score_W0 : 0.04514228275511077
# test_score_W': 0.04059209470369998
# neuron unit number: 312
# *******************
#
# Error Data percentage 0.7137947962690231
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07196965323195416
# error_data0_score_W0 0.045994086987999554
# combinedweight shape 0: (624, 32)
# right_data0_score_W' 0.36847412756209724
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.058893979167940654
# all_train_score_W': 0.06496011566026628
# test_score_W0 : 0.039082339072348427
# test_score_W': 0.039520588558192966
# neuron unit number: 325
# *******************
#
# Error Data percentage 0.6944035346097202
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07946394145703382
# error_data0_score_W0 0.054437304017707105
# combinedweight shape 0: (650, 32)
# right_data0_score_W' 0.3553876718151468
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07346596929321107
# all_train_score_W': 0.0865748595832113
# test_score_W0 : 0.042616343350729585
# test_score_W': 0.04510314142283519
# neuron unit number: 338
# *******************
#
# Error Data percentage 0.7032400589101621
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0790431560900836
# error_data0_score_W0 0.05117113797573162
# combinedweight shape 0: (676, 32)
# right_data0_score_W' 0.27915649107675683
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06976197342343786
# all_train_score_W': 0.0655313218739448
# test_score_W0 : 0.04650241426442654
# test_score_W': 0.039403823402628164
# neuron unit number: 351
# *******************
#
# Error Data percentage 0.7029945999018163
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08945485191212027
# error_data0_score_W0 0.06313785554555948
# combinedweight shape 0: (702, 32)
# right_data0_score_W' 0.24758767293831402
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07754218206488599
# all_train_score_W': 0.0754977022361711
# test_score_W0 : 0.06059336497305946
# test_score_W': 0.05094750433191334
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.6811487481590575
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08710133891629337
# error_data0_score_W0 0.05653256829541189
# combinedweight shape 0: (728, 32)
# right_data0_score_W' 0.30070836234821585
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08321326200701985
# all_train_score_W': 0.0796652652463602
# test_score_W0 : 0.05911653366244065
# test_score_W': 0.04227291970473696
# neuron unit number: 377
# *******************
#
# Error Data percentage 0.710112911143839
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07118160410777062
# error_data0_score_W0 0.05591816674408808
# combinedweight shape 0: (754, 32)
# right_data0_score_W' 0.41033117669434627
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07289027237001722
# all_train_score_W': 0.09024550747677071
# test_score_W0 : 0.04720964194033926
# test_score_W': 0.058700157498953714
# neuron unit number: 390
# *******************
#
# Error Data percentage 0.6897398134511536
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0885743262620112
# error_data0_score_W0 0.05774355006762807
# combinedweight shape 0: (780, 32)
# right_data0_score_W' 0.36839915411986063
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08142624974107908
# all_train_score_W': 0.09194791292326102
# test_score_W0 : 0.048132897077664855
# test_score_W': 0.04971332088009406
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8213058419243986
# right_data0_score_W0 1.0
# error_data0_score_W1 0.01398840007598415
# error_data0_score_W0 0.024447146000607902
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.38462984799621486
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0032529297681144014
# all_train_score_W': 0.01732457832705566
# test_score_W0 : 0.0007543562757394323
# test_score_W': 0.01382125032015773
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.8102601865488464
# right_data0_score_W0 1.0
# error_data0_score_W1 0.018667054220166183
# error_data0_score_W0 0.033119039248028614
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.1792831349903745
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.018474989783736274
# all_train_score_W': 0.02224646482910744
# test_score_W0 : 0.022722838201129456
# test_score_W': 0.021357207995425932
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.7979872361315661
# right_data0_score_W0 1.0
# error_data0_score_W1 0.030486267371269218
# error_data0_score_W0 0.03313263927097499
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.32783574413401095
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.021030818928221853
# all_train_score_W': 0.039941445891144914
# test_score_W0 : 0.0176773284568312
# test_score_W': 0.03544174883593398
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7847324496809033
# right_data0_score_W0 1.0
# error_data0_score_W1 0.020713336912943775
# error_data0_score_W0 0.030343736562632357
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.24523414071976715
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.02414100251019735
# all_train_score_W': 0.018790174483232724
# test_score_W0 : 0.017446079882113146
# test_score_W': 0.013907075093593868
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.7665684830633285
# right_data0_score_W0 1.0
# error_data0_score_W1 0.020419291918294166
# error_data0_score_W0 0.03720238981234697
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.28344092104909896
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.033747380633622204
# all_train_score_W': 0.02668703993056659
# test_score_W0 : 0.0232576349703006
# test_score_W': 0.022492667614874975
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7655866470299459
# right_data0_score_W0 1.0
# error_data0_score_W1 0.039937055318181335
# error_data0_score_W0 0.041954149040346965
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.3477766285561229
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03694011839545588
# all_train_score_W': 0.03619720080604544
# test_score_W0 : 0.03287185739320162
# test_score_W': 0.02610405143766029
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7614138438880707
# right_data0_score_W0 1.0
# error_data0_score_W1 0.041834147320942636
# error_data0_score_W0 0.04028704030677316
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.34557219526092287
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.034774189661842675
# all_train_score_W': 0.04873014800748735
# test_score_W0 : 0.026309763487119338
# test_score_W': 0.0298884626957432
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7545409916543937
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03365421239961102
# error_data0_score_W0 0.046336734544283144
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.3840433791092967
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.042507549629821416
# all_train_score_W': 0.047607421226269174
# test_score_W0 : 0.02898981494706319
# test_score_W': 0.031099013257271824
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.7363770250368189
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04253076320676253
# error_data0_score_W0 0.04920525872853257
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.41130007016115816
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.054500756013752566
# all_train_score_W': 0.056807299423401965
# test_score_W0 : 0.04185189158504285
# test_score_W': 0.03509922720119075
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7390770741286206
# right_data0_score_W0 1.0
# error_data0_score_W1 0.045780653017616094
# error_data0_score_W0 0.03460013418120707
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.2404021978338498
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04307400733020531
# all_train_score_W': 0.044835821514614606
# test_score_W0 : 0.02604244031229492
# test_score_W': 0.02978766400079391
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7329405989199803
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05607956701316377
# error_data0_score_W0 0.04106377336995118
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.3646984348843592
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04974460256566456
# all_train_score_W': 0.07103112129496925
# test_score_W0 : 0.033858671957208604
# test_score_W': 0.043624640595529125
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.7211585665193913
# right_data0_score_W0 1.0
# error_data0_score_W1 0.045964110802329726
# error_data0_score_W0 0.04341797043098705
# combinedweight shape 0: (312, 32)
# right_data0_score_W' 0.28197717375073084
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05889406607034752
# all_train_score_W': 0.054940134934748065
# test_score_W0 : 0.031405917672549445
# test_score_W': 0.04013223306560208
# neuron unit number: 169
# *******************
#
# Error Data percentage 0.7245949926362297
# right_data0_score_W0 1.0
# error_data0_score_W1 0.056130247277431655
# error_data0_score_W0 0.05070268379649658
# combinedweight shape 0: (338, 32)
# right_data0_score_W' 0.444492987100568
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06036292733961561
# all_train_score_W': 0.06588099725166627
# test_score_W0 : 0.037254913767645295
# test_score_W': 0.04030115654256074
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.7245949926362297
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05402609725156903
# error_data0_score_W0 0.03564302472958074
# combinedweight shape 0: (364, 32)
# right_data0_score_W' 0.38021780614020806
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.049490378724811414
# all_train_score_W': 0.05889801910488959
# test_score_W0 : 0.02270661004464483
# test_score_W': 0.037789516121079204
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.7216494845360825
# right_data0_score_W0 1.0
# error_data0_score_W1 0.059742413049958545
# error_data0_score_W0 0.048525605556363906
# combinedweight shape 0: (390, 32)
# right_data0_score_W' 0.441295951897848
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.062382684721471
# all_train_score_W': 0.07064204249659417
# test_score_W0 : 0.043110763099221044
# test_score_W': 0.040168502790493374
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.7223858615611193
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06926421117484992
# error_data0_score_W0 0.04288796519227115
# combinedweight shape 0: (416, 32)
# right_data0_score_W' 0.3183698761152201
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05580008343700219
# all_train_score_W': 0.07047267635932801
# test_score_W0 : 0.03927942177795471
# test_score_W': 0.05057401485997488
# neuron unit number: 221
# *******************
#
# Error Data percentage 0.7027491408934707
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07063152783722842
# error_data0_score_W0 0.05564344798170467
# combinedweight shape 0: (442, 32)
# right_data0_score_W' 0.3560312996240302
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07271881030263411
# all_train_score_W': 0.07453688590785951
# test_score_W0 : 0.04956471498069536
# test_score_W': 0.050676688499743154
# neuron unit number: 234
# *******************
#
# Error Data percentage 0.7164948453608248
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05872741127134607
# error_data0_score_W0 0.055870941820035665
# combinedweight shape 0: (468, 32)
# right_data0_score_W' 0.32800915212605763
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06633294391473202
# all_train_score_W': 0.05786743872678396
# test_score_W0 : 0.04747019327725601
# test_score_W': 0.03145963954933017
# neuron unit number: 247
# *******************
#
# Error Data percentage 0.6926853215513009
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07413035048475
# error_data0_score_W0 0.06656027860593507
# combinedweight shape 0: (494, 32)
# right_data0_score_W' 0.2794586662949923
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0827566943821911
# all_train_score_W': 0.08040327468070628
# test_score_W0 : 0.056768661922328476
# test_score_W': 0.04354380431413053
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.7052037309769269
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08876393034257249
# error_data0_score_W0 0.0574133813689939
# combinedweight shape 0: (520, 32)
# right_data0_score_W' 0.3337178261959638
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07001971573582946
# all_train_score_W': 0.08212734466199428
# test_score_W0 : 0.04202531840344488
# test_score_W': 0.04661222717459511
# neuron unit number: 273
# *******************
#
# Error Data percentage 0.7025036818851251
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08195557184318651
# error_data0_score_W0 0.06807646636122178
# combinedweight shape 0: (546, 32)
# right_data0_score_W' 0.2860889084562005
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08215038017635012
# all_train_score_W': 0.07356590888290056
# test_score_W0 : 0.0550290997325811
# test_score_W': 0.036656686015076025
# neuron unit number: 286
# *******************
#
# Error Data percentage 0.7270495827196858
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07448717562135389
# error_data0_score_W0 0.04385585211536911
# combinedweight shape 0: (572, 32)
# right_data0_score_W' 0.2236854473010074
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05366763442006894
# all_train_score_W': 0.06257087837694146
# test_score_W0 : 0.03084903708887474
# test_score_W': 0.03294905339438919
# neuron unit number: 299
# *******************
#
# Error Data percentage 0.7157584683357879
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06606239314980751
# error_data0_score_W0 0.051916993799869825
# combinedweight shape 0: (598, 32)
# right_data0_score_W' 0.364965337832083
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06501408744332061
# all_train_score_W': 0.07522574154333386
# test_score_W0 : 0.043942186618591506
# test_score_W': 0.05211903796555996
# neuron unit number: 312
# *******************
#
# Error Data percentage 0.6998036327933235
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08207912616633412
# error_data0_score_W0 0.0619829110348803
# combinedweight shape 0: (624, 32)
# right_data0_score_W' 0.38971058879212506
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.081948179778029
# all_train_score_W': 0.0898284579805536
# test_score_W0 : 0.05730418874617999
# test_score_W': 0.05075908470922238
# neuron unit number: 325
# *******************
#
# Error Data percentage 0.7125675012272951
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06862833107091199
# error_data0_score_W0 0.04785672789047938
# combinedweight shape 0: (650, 32)
# right_data0_score_W' 0.24816598123160483
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.060875008137801584
# all_train_score_W': 0.07094241194077927
# test_score_W0 : 0.04335953472036344
# test_score_W': 0.052767364166700456
# neuron unit number: 338
# *******************
#
# Error Data percentage 0.7162493863524791
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07778242104672088
# error_data0_score_W0 0.04713785009135795
# combinedweight shape 0: (676, 32)
# right_data0_score_W' 0.33124661970049857
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06208584333132544
# all_train_score_W': 0.07093645295633158
# test_score_W0 : 0.03397659366515732
# test_score_W': 0.038542202501705
# neuron unit number: 351
# *******************
#
# Error Data percentage 0.6850760922925871
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09406883955345897
# error_data0_score_W0 0.06801734141679448
# combinedweight shape 0: (702, 32)
# right_data0_score_W' 0.30486069622396933
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08983531195152408
# all_train_score_W': 0.08777983149525795
# test_score_W0 : 0.058236027505201786
# test_score_W': 0.05127984573284618
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.7032400589101621
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0707634307542547
# error_data0_score_W0 0.0537474777116986
# combinedweight shape 0: (728, 32)
# right_data0_score_W' 0.33729895411511246
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0665637022446694
# all_train_score_W': 0.07933723790558567
# test_score_W0 : 0.04219101498677392
# test_score_W': 0.04802596829763455
# neuron unit number: 377
# *******************
#
# Error Data percentage 0.6958762886597938
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08176693386217819
# error_data0_score_W0 0.04867016801033127
# combinedweight shape 0: (754, 32)
# right_data0_score_W' 0.3108686529657739
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07606652484116316
# all_train_score_W': 0.06872281988086405
# test_score_W0 : 0.049687791776519066
# test_score_W': 0.03830897756715524
# neuron unit number: 390
# *******************
#
# Error Data percentage 0.7071674030436917
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09211882865348703
# error_data0_score_W0 0.05279538015671761
# combinedweight shape 0: (780, 32)
# right_data0_score_W' 0.20786400071437303
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06802097902662839
# all_train_score_W': 0.07710517769229122
# test_score_W0 : 0.04901229143510733
# test_score_W': 0.04708367494402742
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8303878252331861
# right_data0_score_W0 1.0
# error_data0_score_W1 0.01588898718582689
# error_data0_score_W0 0.02956119472566215
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.27111333768619333
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.004319882131672213
# all_train_score_W': 0.011509209924077626
# test_score_W0 : 0.001439030844197214
# test_score_W': 0.014252837679509136
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.8080510554737359
# right_data0_score_W0 1.0
# error_data0_score_W1 0.020560272529180804
# error_data0_score_W0 0.02781442202158958
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.3543886089575109
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.013835954808243756
# all_train_score_W': 0.027844682801485717
# test_score_W0 : 0.010059476901330897
# test_score_W': 0.025815411772179008
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.7999509081983309
# right_data0_score_W0 1.0
# error_data0_score_W1 0.022934614150750737
# error_data0_score_W0 0.02894002028748922
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.2603986971048479
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.012805433247317656
# all_train_score_W': 0.024570717503267257
# test_score_W0 : 0.010296950984169446
# test_score_W': 0.020868100796723424
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7727049582719686
# right_data0_score_W0 1.0
# error_data0_score_W1 0.019909372136660365
# error_data0_score_W0 0.03978024169816373
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.31923698968216674
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.033778866636234126
# all_train_score_W': 0.024976669744879765
# test_score_W0 : 0.023890887201129356
# test_score_W': 0.021215467802870615
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.7722140402552774
# right_data0_score_W0 1.0
# error_data0_score_W1 0.032802023121542935
# error_data0_score_W0 0.03167848343279626
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.3878375340242339
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.026502749736575206
# all_train_score_W': 0.03172459260444415
# test_score_W0 : 0.022257413450808207
# test_score_W': 0.024270801978458965
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7616593028964163
# right_data0_score_W0 1.0
# error_data0_score_W1 0.04251418227138727
# error_data0_score_W0 0.04028349873615468
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.2690043030629856
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.037003982024422045
# all_train_score_W': 0.045343014975051
# test_score_W0 : 0.033852197913699866
# test_score_W': 0.03535350564677955
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7810505645557192
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03820079740858408
# error_data0_score_W0 0.028770600595785175
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.24799885255876652
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.022317575776643086
# all_train_score_W': 0.024764014995306432
# test_score_W0 : 0.0178169946250601
# test_score_W': 0.01999875858822072
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7594501718213058
# right_data0_score_W0 1.0
# error_data0_score_W1 0.040337764182397665
# error_data0_score_W0 0.03818065518406766
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.2986486401113889
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03546644547594012
# all_train_score_W': 0.03894922511769862
# test_score_W0 : 0.025793477798771773
# test_score_W': 0.036889509089362005
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.7363770250368189
# right_data0_score_W0 1.0
# error_data0_score_W1 0.050833983244458786
# error_data0_score_W0 0.048601756716097885
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.21003672269212267
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.051404931028711076
# all_train_score_W': 0.05604334235338468
# test_score_W0 : 0.04004083808646761
# test_score_W': 0.04163542457721623
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7307314678448699
# right_data0_score_W0 1.0
# error_data0_score_W1 0.043216994158322475
# error_data0_score_W0 0.04517414687419771
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.2380766562841409
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05230894254809499
# all_train_score_W': 0.0492609593301874
# test_score_W0 : 0.028645144344997164
# test_score_W': 0.03084094020827085
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7353951890034365
# right_data0_score_W0 1.0
# error_data0_score_W1 0.048054300467529065
# error_data0_score_W0 0.04634885970026156
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.30172640247766364
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05239487283753423
# all_train_score_W': 0.05133843979898221
# test_score_W0 : 0.03947279267458789
# ...
# *******************
#
# Error Data percentage 0.689494354442808
# right_data0_score_W0 1.0
# error_data0_score_W1 0.10312523208177077
# error_data0_score_W0 0.059655978520427755
# combinedweight shape 0: (780, 32)
# right_data0_score_W' 0.2510311763367732
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08393442157021577
# all_train_score_W': 0.08689498915062308
# test_score_W0 : 0.05609825817891929
# test_score_W': 0.04640483513678953
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8225331369661266
# right_data0_score_W0 1.0
# error_data0_score_W1 0.014915618639329487
# error_data0_score_W0 0.03506777363836413
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.24615246602722426
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.011247117263917446
# all_train_score_W': 0.014370410926751584
# test_score_W0 : 0.006753416989978689
# test_score_W': 0.007522016540091867
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.802405498281787
# right_data0_score_W0 1.0
# error_data0_score_W1 0.016946369833778188
# error_data0_score_W0 0.03292595176519116
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.4116420819933339
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.015586428128024014
# all_train_score_W': 0.02814027469653828
# test_score_W0 : 0.01922647341249153
# test_score_W': 0.02431684409476138
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.804860088365243
# right_data0_score_W0 1.0
# error_data0_score_W1 0.025322442730322713
# error_data0_score_W0 0.030417739537405775
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.18907684737164693
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.018796261151117565
# all_train_score_W': 0.02501814333703167
# test_score_W0 : 0.016579239916917652
# test_score_W': 0.01393090454612225
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7650957290132547
# right_data0_score_W0 1.0
# error_data0_score_W1 0.024842428717073685
# error_data0_score_W0 0.0495996212309252
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.3273294829302771
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.040291295143920165
# all_train_score_W': 0.04878413588875453
# test_score_W0 : 0.03474354594121207
# test_score_W': 0.03852518097599966
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.7749140893470791
# right_data0_score_W0 1.0
# error_data0_score_W1 0.028489943741424238
# error_data0_score_W0 0.039953530337501986
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.4273553092462485
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.031750014801536414
# all_train_score_W': 0.035338706448262994
# test_score_W0 : 0.02251707950268736
# test_score_W': 0.02689356329694171
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7673048600883653
# right_data0_score_W0 1.0
# error_data0_score_W1 0.03313710951572761
# error_data0_score_W0 0.038588983052047846
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.3023032315597108
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03166270518585073
# all_train_score_W': 0.03209655261564264
# test_score_W0 : 0.021166772775066418
# test_score_W': 0.02078623639617755
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7488954344624448
# right_data0_score_W0 1.0
# error_data0_score_W1 0.028901518934941688
# error_data0_score_W0 0.04011287340982748
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.49714091693716883
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.03929485070101068
# all_train_score_W': 0.04856121317699713
# test_score_W0 : 0.0232471530067136
# test_score_W': 0.02910544797381841
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7491408934707904
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0526706867188956
# error_data0_score_W0 0.04470469857782958
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.23119245197377544
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04472183626280132
# all_train_score_W': 0.056534464522377516
# test_score_W0 : 0.03709223096975076
# test_score_W': 0.045920558581860206
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.7410407461953854
# right_data0_score_W0 1.0
# error_data0_score_W1 0.033458980704785465
# error_data0_score_W0 0.05130167318009859
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.5683271036523644
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.052687224319781345
# all_train_score_W': 0.05819418948036205
# test_score_W0 : 0.03721015666416645
# test_score_W': 0.03391055661225239
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7395679921453118
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05145959578776946
# error_data0_score_W0 0.040458005839926814
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.3700158278168627
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.04291785391609747
# all_train_score_W': 0.06091079035357599
# test_score_W0 : 0.023420403231812163
# test_score_W': 0.041378415439559675
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7221404025527737
# right_data0_score_W0 1.0
# error_data0_score_W1 0.050730452280818565
# error_data0_score_W0 0.055988661407555866
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.29050991923462566
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06390260386205013
# all_train_score_W': 0.06233258266541016
# test_score_W0 : 0.04667007555606004
# test_score_W': 0.036818480994761794
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.7307314678448699
# right_data0_score_W0 1.0
# error_data0_score_W1 0.051976840376922455
# error_data0_score_W0 0.04470231607596307
# combinedweight shape 0: (312, 32)
# right_data0_score_W' 0.45562607415919193
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.05490424934132303
# all_train_score_W': 0.06816985947257095
# test_score_W0 : 0.03905349907550542
# test_score_W': 0.044646029059066096
# neuron unit number: 169
# *******************
#
# Error Data percentage 0.7324496809032891
# right_data0_score_W0 1.0
# error_data0_score_W1 0.05775482785553863
# error_data0_score_W0 0.04904666524863633
# combinedweight shape 0: (338, 32)
# right_data0_score_W' 0.3513195629464238
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.057400638378849886
# all_train_score_W': 0.06701602749353755
# test_score_W0 : 0.04331680287103752
# test_score_W': 0.03911698852887954
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.7066764850270005
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06834346432860204
# error_data0_score_W0 0.05059358594472856
# combinedweight shape 0: (364, 32)
# right_data0_score_W' 0.3566076701629771
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06497379904471201
# all_train_score_W': 0.06515295944989048
# test_score_W0 : 0.04138847275420371
# test_score_W': 0.037321499173848006
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.7123220422189495
# right_data0_score_W0 1.0
# error_data0_score_W1 0.061663726415105695
# error_data0_score_W0 0.04808050589267141
# combinedweight shape 0: (390, 32)
# right_data0_score_W' 0.3698670092933575
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06567824847993747
# all_train_score_W': 0.08133430788282471
# test_score_W0 : 0.04448486564431988
# test_score_W': 0.04883550843670619
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.7108492881688758
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06529502930833628
# error_data0_score_W0 0.0466240370702609
# combinedweight shape 0: (416, 32)
# right_data0_score_W' 0.4349847923246802
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06318530083490495
# all_train_score_W': 0.07389757921387566
# test_score_W0 : 0.042003640629605044
# test_score_W': 0.04655998314247537
# neuron unit number: 221
# *******************
#
# Error Data percentage 0.7137947962690231
# right_data0_score_W0 1.0
# error_data0_score_W1 0.065989947636261
# error_data0_score_W0 0.05361117446674705
# combinedweight shape 0: (442, 32)
# right_data0_score_W' 0.30060083487501565
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06624788272172434
# all_train_score_W': 0.0695235438608917
# test_score_W0 : 0.046799605197285404
# test_score_W': 0.03913360206466272
# neuron unit number: 234
# *******************
#
# Error Data percentage 0.7241040746195385
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07747536666591416
# error_data0_score_W0 0.04745126096299847
# combinedweight shape 0: (468, 32)
# right_data0_score_W' 0.3012839376476742
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.062414613191117775
# all_train_score_W': 0.06297593589486265
# test_score_W0 : 0.047639425918345316
# test_score_W': 0.04173506617756801
# neuron unit number: 247
# *******************
#
# Error Data percentage 0.7115856651939126
# right_data0_score_W0 1.0
# error_data0_score_W1 0.0868497518892932
# error_data0_score_W0 0.05539912287592466
# combinedweight shape 0: (494, 32)
# right_data0_score_W' 0.3650841249167039
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06967173214676743
# all_train_score_W': 0.08348296845517343
# test_score_W0 : 0.05049459251682534
# test_score_W': 0.05284488214479076
# neuron unit number: 260
# *******************
#
# Error Data percentage 0.7029945999018163
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08355424394365767
# error_data0_score_W0 0.04920928071095911
# combinedweight shape 0: (520, 32)
# right_data0_score_W' 0.3637957338746987
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06795129044023386
# all_train_score_W': 0.08445568010229217
# test_score_W0 : 0.040254571285009526
# test_score_W': 0.04534434133981725
# neuron unit number: 273
# *******************
#
# Error Data percentage 0.7000490918016691
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08137860869957861
# error_data0_score_W0 0.05679195369971519
# combinedweight shape 0: (546, 32)
# right_data0_score_W' 0.302943546387774
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07062687416252096
# all_train_score_W': 0.06987855300431578
# test_score_W0 : 0.052996376617797394
# test_score_W': 0.04983552692696979
# neuron unit number: 286
# *******************
#
# Error Data percentage 0.6890034364261168
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08070713891352232
# error_data0_score_W0 0.0635376611586316
# combinedweight shape 0: (572, 32)
# right_data0_score_W' 0.3991467414584384
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08794527374550057
# all_train_score_W': 0.08314860248787397
# test_score_W0 : 0.06514575517394425
# test_score_W': 0.056109594918739014
# neuron unit number: 299
# *******************
#
# Error Data percentage 0.7007854688267059
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08510746410587326
# error_data0_score_W0 0.060091219237944346
# combinedweight shape 0: (598, 32)
# right_data0_score_W' 0.3343952853526761
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.0783441013085196
# all_train_score_W': 0.07866475219680635
# test_score_W0 : 0.05562916100279577
# test_score_W': 0.04490717006166329
# neuron unit number: 312
# *******************
#
# Error Data percentage 0.7250859106529209
# right_data0_score_W0 1.0
# error_data0_score_W1 0.06354337090669186
# error_data0_score_W0 0.04484000354023924
# combinedweight shape 0: (624, 32)
# right_data0_score_W' 0.3671354446260479
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.059256466529905655
# all_train_score_W': 0.0666433915793007
# test_score_W0 : 0.03407757063193428
# test_score_W': 0.03955119432398557
# neuron unit number: 325
# *******************
#
# Error Data percentage 0.6860579283259696
# right_data0_score_W0 1.0
# error_data0_score_W1 0.08608863919131036
# error_data0_score_W0 0.06018545255694392
# combinedweight shape 0: (650, 32)
# right_data0_score_W' 0.3567134572944323
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08715606791392905
# all_train_score_W': 0.08649995540244569
# test_score_W0 : 0.053181816603316084
# test_score_W': 0.04695155729786945
# neuron unit number: 338
# *******************
#
# Error Data percentage 0.697594501718213
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07828763346974937
# error_data0_score_W0 0.058360154067383416
# combinedweight shape 0: (676, 32)
# right_data0_score_W' 0.2821888330477241
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.07570661247539663
# all_train_score_W': 0.0826405936128973
# test_score_W0 : 0.05028162063778934
# test_score_W': 0.047159265645776424
# neuron unit number: 351
# *******************
#
# Error Data percentage 0.6921944035346097
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09652306163583325
# error_data0_score_W0 0.0636938876766427
# combinedweight shape 0: (702, 32)
# right_data0_score_W' 0.21035710119603954
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08575358548515537
# all_train_score_W': 0.07836433252534555
# test_score_W0 : 0.060538023850790344
# test_score_W': 0.045919404818976786
# neuron unit number: 364
# *******************
#
# Error Data percentage 0.6983308787432498
# right_data0_score_W0 1.0
# error_data0_score_W1 0.10041769154731316
# error_data0_score_W0 0.05560994904344897
# combinedweight shape 0: (728, 32)
# right_data0_score_W' 0.2482645636972557
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06936387006859465
# all_train_score_W': 0.08685028457025286
# test_score_W0 : 0.0488810263779211
# test_score_W': 0.049420159652717593
# neuron unit number: 377
# *******************
#
# Error Data percentage 0.7133038782523319
# right_data0_score_W0 1.0
# error_data0_score_W1 0.07414053757021052
# error_data0_score_W0 0.044493275390710296
# combinedweight shape 0: (754, 32)
# right_data0_score_W' 0.35609800573050093
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.06394153683970652
# all_train_score_W': 0.06738299172209791
# test_score_W0 : 0.041157794752161365
# test_score_W': 0.03870997321251096
# neuron unit number: 390
# *******************
#
# Error Data percentage 0.6929307805596465
# right_data0_score_W0 1.0
# error_data0_score_W1 0.09242873072932015
# error_data0_score_W0 0.0659212272779275
# combinedweight shape 0: (780, 32)
# right_data0_score_W' 0.37125907312891904
# Finish one training *********
# 1
#  Max Training Time !
# all_train_score_W0: 0.08094273562771098
# all_train_score_W': 0.08319701752018434
# test_score_W0 : 0.05048861897295377
# test_score_W': 0.041752079737205815
#         Variable       N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0   900.0  0.037997  0.013987  0.000466   0.037082  0.038912
# 1  test_score_W'   900.0  0.037540  0.011341  0.000378   0.036798  0.038282
# 2       combined  1800.0  0.037769  0.012732  0.000300   0.037180  0.038357
#                               Independent t-test    results
# 0  Difference (test_score_W0 - test_score_W') =      0.0005
# 1                          Degrees of freedom =   1798.0000
# 2                                           t =      0.7612
# 3                       Two side test p value =      0.4466
# 4                      Difference < 0 p value =      0.7767
# 5                      Difference > 0 p value =      0.2233
# 6                                   Cohen's d =      0.0359
# 7                                   Hedge's g =      0.0359
# 8                               Glass's delta =      0.0327
# 9                                 Pearson's r =      0.0179
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# Ttest_indResult(statistic=0.7612469274526772, pvalue=0.7766952894509798)

# %%
scoretype = 0
scope_num = 120
class_num = 13
dim_num = 32
unstable_repeat_num = 1
unit_list = []    
all_train_score_W0 =[]
all_train_score_W_combine =[]
test_score_W0 = []
test_score_W_combine= []
error_data_percentage = []

initial_som_result = dict()
splitted_number_result = dict()

all_train_score_W0_global =[]
all_train_score_W_combine_global =[]
test_score_W0_global = []
test_score_W_combine_global = []

p_values = []
y = 1


while y <= unstable_repeat_num:
    x = 1
    while x <= scope_num:
        unit_list.append(class_num*x)
        print("neuron unit number: {}".format(class_num*x))
        print("*******************\n")
        som = newSom.SOM(m= class_num, n= x, dim=dim_num)  
        optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
        optimize_W.run(20,scoretype)
        
        if optimize_W.W0IsBest == False:       
            all_train_score_W0.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine.append(optimize_W.all_train_score_W_Combined)
            test_score_W0.append(optimize_W.test_score_W0)
            test_score_W_combine.append(optimize_W.test_score_W_combined)
            error_data_percentage.append(optimize_W.first_error_data_percentage)
            
            all_train_score_W0_global.append(optimize_W.all_train_score_W0)
            all_train_score_W_combine_global.append(optimize_W.all_train_score_W_Combined)
            test_score_W0_global.append(optimize_W.test_score_W0)
            test_score_W_combine_global.append(optimize_W.test_score_W_combined)        
            if (scoretype==0):
                splitted_number_result[class_num*x*(optimize_W.split_num +1)] = optimize_W.test_score_W_combined 
                print("class_num*x*(optimize_W.split_num +1){}".format(class_num*x*(optimize_W.split_num +1)))
                initial_som_result[class_num*x] = optimize_W.test_score_W0 
        
        x=x+1

    if (scoretype!=0):
        figure, axis = plt.subplots(1, 2,figsize=(10, 5))
        if scoretype == 1:
            axis[0].set_title("NMI Score")
        elif scoretype == 2:
            axis[0].set_title("ARI Score")

        
        axis[0].set_xlabel('Neuron number')
        axis[0].plot(unit_list,all_train_score_W0,'r',label ='all_train_score_W0')
        axis[0].plot(unit_list,all_train_score_W_combine,'c',label ='all_train_score_W\'')
        axis[0].plot(unit_list,test_score_W0,'y',label ='test_score_W1')
        axis[0].plot(unit_list,test_score_W_combine,'k',label ='test_score_W\'')
        axis[0].legend()

        axis[1].set_title("Error_Data_Percentage")
        axis[1].set_xlabel('Neuron number')
        axis[1].plot(unit_list,error_data_percentage,'g')

        plt.show()
    
    y =y+1
    #reset
    unit_list = []  
    all_train_score_W0 =[]
    all_train_score_W_combine =[]
    test_score_W0 = []
    test_score_W_combine= []
    error_data_percentage = []

                   
                                      
if (scoretype!=0):
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])
else: 
    test_score_W0_global =[] #reset test_score_W0_global
    test_score_W_combine_global = []
    
    od = collections.OrderedDict(sorted(splitted_number_result.items()))
    
    keys = od.keys()
    for s in keys:
        if s in initial_som_result:
            test_score_W_combine_global.append(od[s])
            test_score_W0_global.append(initial_som_result[s])
            unit_list.append(s)
            print("s {}  value {} ".format(s,od[s]))
        
    df1 = pd.DataFrame(test_score_W0_global, columns = ['test_score_W0'])                                
    df2 = pd.DataFrame(test_score_W_combine_global, columns = ['test_score_W\''])                          
    


summary, results = rp.ttest(group1= df1['test_score_W0'], group1_name= "test_score_W0",
                            group2= df2['test_score_W\''], group2_name= "test_score_W\'")
print(summary)
print(results)

stats.ttest_ind(test_score_W0_global, test_score_W_combine_global,alternative = 'less')


                                      
if scoretype == 0:
    plt.title("Purity Score")      
    plt.xlabel('Neuron number')
    plt.plot(unit_list,test_score_W0_global,'y',label ='test_score_W1')
    plt.plot(unit_list,test_score_W_combine_global,'k',label ='test_score_W\'')
    plt.legend()
    plt.show()
# Out:
# neuron unit number: 13
# *******************
#
# Error Data percentage 0.8178694158075601
# right_data0_score_W0 1.0
# error_data0_score_W1 0.17046818727490998
# error_data0_score_W0 0.1752701080432173
# combinedweight shape 0: (26, 32)
# right_data0_score_W' 0.7803234501347709
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.17221418234442837
# error_data1_score_W0 0.14544138929088277
# combinedweight shape1 : (39, 32)
# right_data1_score_W' 0.44366197183098594
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.16433566433566432
# error_data2_score_W0 0.1354895104895105
# combinedweight shape1 : (52, 32)
# right_data2_score_W' 0.4642857142857143
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1788702928870293
# error_data3_score_W0 0.14069037656903766
# combinedweight shape1 : (65, 32)
# right_data3_score_W' 0.5585106382978723
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.1942675159235669
# error_data4_score_W0 0.14777070063694267
# combinedweight shape1 : (78, 32)
# right_data4_score_W' 0.5292397660818714
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.1992094861660079
# error_data5_score_W0 0.1541501976284585
# combinedweight shape1 : (91, 32)
# right_data5_score_W' 0.42295081967213116
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.19447186574531095
# error_data6_score_W0 0.13919052319842054
# combinedweight shape1 : (104, 32)
# right_data6_score_W' 0.4444444444444444
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.22916666666666666
# error_data7_score_W0 0.16176470588235295
# combinedweight shape1 : (117, 32)
# right_data7_score_W' 0.49746192893401014
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.23370429252782193
# error_data8_score_W0 0.17170111287758347
# combinedweight shape1 : (130, 32)
# right_data8_score_W' 0.4919786096256685
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.2033195020746888
# error_data9_score_W0 0.14107883817427386
# combinedweight shape1 : (143, 32)
# right_data9_score_W' 0.5510204081632653
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.22916666666666666
# error_data10_score_W0 0.19270833333333334
# combinedweight shape1 : (156, 32)
# right_data10_score_W' 0.5816326530612245
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.27702702702702703
# error_data11_score_W0 0.17567567567567569
# combinedweight shape1 : (169, 32)
# right_data11_score_W' 0.6136363636363636
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.2803738317757009
# error_data12_score_W0 0.17757009345794392
# combinedweight shape1 : (182, 32)
# right_data12_score_W' 0.5121951219512195
# Finish one splitting *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.33116883116883117
# error_data13_score_W0 0.2077922077922078
# combinedweight shape1 : (195, 32)
# right_data13_score_W' 0.55
# Finish one splitting *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 0.32038834951456313
# error_data14_score_W0 0.1650485436893204
# combinedweight shape1 : (208, 32)
# right_data14_score_W' 0.5686274509803921
# Finish one splitting *********
# 15
# right_data15_score_W0 1.0
# error_data15_score_W1 0.42857142857142855
# error_data15_score_W0 0.22857142857142856
# combinedweight shape1 : (221, 32)
# right_data15_score_W' 0.5757575757575758
# Finish one splitting *********
# 16
# right_data16_score_W0 1.0
# error_data16_score_W1 0.4
# error_data16_score_W0 0.225
# combinedweight shape1 : (234, 32)
# right_data16_score_W' 0.6
# Finish one splitting *********
# 17
# right_data17_score_W0 1.0
# error_data17_score_W1 0.625
# error_data17_score_W0 0.3333333333333333
# combinedweight shape1 : (247, 32)
# right_data17_score_W' 0.8125
# Finish one splitting *********
# 18
# right_data18_score_W0 1.0
# error_data18_score_W1 0.8888888888888888
# error_data18_score_W0 0.5555555555555556
# combinedweight shape1 : (260, 32)
# right_data18_score_W' 0.8
# Finish one splitting *********
# 19
# right_data19_score_W0 1.0
# error_data19_score_W1 1.0
# error_data19_score_W0 1.0
# Error data can be represented by W0 19
# combinedweight shape1 : (273, 32)
# right_data19_score_W' 0.875
# Finish one splitting *********
# 20
#  NO Error Data, Finish Training!
# split_num 20
# all_train_score_W0: 0.18213058419243985
# all_train_score_W': 0.7255768286696122
# test_score_W0 : 0.1764032073310424
# test_score_W': 0.2777777777777778
# class_num*x*(optimize_W.split_num +1)273
# neuron unit number: 26
# *******************
#
# Error Data percentage 0.7960235640648011
# right_data0_score_W0 1.0
# error_data0_score_W1 0.1967314215232809
# error_data0_score_W0 0.1788467468393463
# combinedweight shape 0: (52, 32)
# right_data0_score_W' 0.6582430806257521
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.18886756238003838
# error_data1_score_W0 0.16429942418426105
# combinedweight shape1 : (78, 32)
# right_data1_score_W' 0.47492163009404387
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.195929957406531
# error_data2_score_W0 0.13771888310459063
# combinedweight shape1 : (104, 32)
# right_data2_score_W' 0.5365853658536586
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.1842260153031195
# error_data3_score_W0 0.15008828722778106
# combinedweight shape1 : (130, 32)
# right_data3_score_W' 0.3743961352657005
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.22294372294372294
# error_data4_score_W0 0.15945165945165946
# combinedweight shape1 : (156, 32)
# right_data4_score_W' 0.3706070287539936
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.22098421541318478
# error_data5_score_W0 0.14484679665738162
# combinedweight shape1 : (182, 32)
# right_data5_score_W' 0.4368932038834951
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.2550655542312277
# error_data6_score_W0 0.18474374255065554
# combinedweight shape1 : (208, 32)
# right_data6_score_W' 0.42857142857142855
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.2512
# error_data7_score_W0 0.1792
# combinedweight shape1 : (234, 32)
# right_data7_score_W' 0.6214953271028038
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.25427350427350426
# error_data8_score_W0 0.16452991452991453
# combinedweight shape1 : (260, 32)
# right_data8_score_W' 0.39490445859872614
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.2492836676217765
# error_data9_score_W0 0.16332378223495703
# combinedweight shape1 : (286, 32)
# right_data9_score_W' 0.3949579831932773
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.26717557251908397
# error_data10_score_W0 0.18702290076335878
# combinedweight shape1 : (312, 32)
# right_data10_score_W' 0.39080459770114945
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.3229166666666667
# error_data11_score_W0 0.15625
# combinedweight shape1 : (338, 32)
# right_data11_score_W' 0.4142857142857143
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.3769230769230769
# error_data12_score_W0 0.2076923076923077
# combinedweight shape1 : (364, 32)
# right_data12_score_W' 0.43548387096774194
# Finish one splitting *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.3950617283950617
# error_data13_score_W0 0.2345679012345679
# combinedweight shape1 : (390, 32)
# right_data13_score_W' 0.4489795918367347
# Finish one splitting *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 0.6326530612244898
# error_data14_score_W0 0.3469387755102041
# combinedweight shape1 : (416, 32)
# right_data14_score_W' 0.59375
# Finish one splitting *********
# 15
# right_data15_score_W0 1.0
# error_data15_score_W1 0.8888888888888888
# error_data15_score_W0 0.5
# combinedweight shape1 : (442, 32)
# right_data15_score_W' 0.4838709677419355
# Finish one splitting *********
# 16
# right_data16_score_W0 1.0
# error_data16_score_W1 1.0
# error_data16_score_W0 1.0
# Error data can be represented by W0 16
# combinedweight shape1 : (468, 32)
# right_data16_score_W' 0.75
# Finish one splitting *********
# 17
#  NO Error Data, Finish Training!
# split_num 17
# all_train_score_W0: 0.20397643593519882
# all_train_score_W': 0.7245949926362297
# test_score_W0 : 0.18384879725085912
# test_score_W': 0.28865979381443296
# class_num*x*(optimize_W.split_num +1)468
# neuron unit number: 39
# *******************
#
# Error Data percentage 0.7864506627393225
# right_data0_score_W0 1.0
# error_data0_score_W1 0.20411985018726592
# error_data0_score_W0 0.1772784019975031
# combinedweight shape 0: (78, 32)
# right_data0_score_W' 0.7298850574712644
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.20745098039215687
# error_data1_score_W0 0.15411764705882353
# combinedweight shape1 : (117, 32)
# right_data1_score_W' 0.591743119266055
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.1979218208807521
# error_data2_score_W0 0.15141019297377536
# combinedweight shape1 : (156, 32)
# right_data2_score_W' 0.5236294896030246
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.22516964836520667
# error_data3_score_W0 0.16656384947563233
# combinedweight shape1 : (195, 32)
# right_data3_score_W' 0.365
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.24601910828025478
# error_data4_score_W0 0.15286624203821655
# combinedweight shape1 : (234, 32)
# right_data4_score_W' 0.4465753424657534
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.2713833157338965
# error_data5_score_W0 0.15945089757127773
# combinedweight shape1 : (273, 32)
# right_data5_score_W' 0.44660194174757284
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.2536231884057971
# error_data6_score_W0 0.1492753623188406
# combinedweight shape1 : (312, 32)
# right_data6_score_W' 0.35797665369649806
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.287378640776699
# error_data7_score_W0 0.16310679611650486
# combinedweight shape1 : (351, 32)
# right_data7_score_W' 0.4228571428571429
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.3133514986376022
# error_data8_score_W0 0.17166212534059946
# combinedweight shape1 : (390, 32)
# right_data8_score_W' 0.36486486486486486
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.34523809523809523
# error_data9_score_W0 0.18253968253968253
# combinedweight shape1 : (429, 32)
# right_data9_score_W' 0.4
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.4
# error_data10_score_W0 0.2
# combinedweight shape1 : (468, 32)
# right_data10_score_W' 0.41379310344827586
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.48484848484848486
# error_data11_score_W0 0.24242424242424243
# combinedweight shape1 : (507, 32)
# right_data11_score_W' 0.3787878787878788
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.6274509803921569
# error_data12_score_W0 0.3333333333333333
# combinedweight shape1 : (546, 32)
# right_data12_score_W' 0.4791666666666667
# Finish one splitting *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 0.8947368421052632
# error_data13_score_W0 0.47368421052631576
# combinedweight shape1 : (585, 32)
# right_data13_score_W' 0.5
# Finish one splitting *********
# 14
# right_data14_score_W0 1.0
# error_data14_score_W1 1.0
# error_data14_score_W0 1.0
# Error data can be represented by W0 14
# combinedweight shape1 : (624, 32)
# right_data14_score_W' 0.7647058823529411
# Finish one splitting *********
# 15
#  NO Error Data, Finish Training!
# split_num 15
# all_train_score_W0: 0.21354933726067746
# all_train_score_W': 0.7231222385861561
# test_score_W0 : 0.1958762886597938
# test_score_W': 0.28923253150057276
# class_num*x*(optimize_W.split_num +1)624
# neuron unit number: 52
# *******************
#
# Error Data percentage 0.7906234658811978
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2157714995343061
# error_data0_score_W0 0.18162061471592672
# combinedweight shape 0: (104, 32)
# right_data0_score_W' 0.608440797186401
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.21456848772763262
# error_data1_score_W0 0.16904196357878068
# combinedweight shape1 : (156, 32)
# right_data1_score_W' 0.5928057553956835
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2399193548387097
# error_data2_score_W0 0.1537298387096774
# combinedweight shape1 : (208, 32)
# right_data2_score_W' 0.38191881918819187
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.23938992042440319
# error_data3_score_W0 0.15915119363395225
# combinedweight shape1 : (260, 32)
# right_data3_score_W' 0.4180672268907563
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.26068003487358327
# error_data4_score_W0 0.17175239755884916
# combinedweight shape1 : (312, 32)
# right_data4_score_W' 0.39058171745152354
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.27358490566037735
# error_data5_score_W0 0.19929245283018868
# combinedweight shape1 : (364, 32)
# right_data5_score_W' 0.4214046822742475
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3051948051948052
# error_data6_score_W0 0.16233766233766234
# combinedweight shape1 : (416, 32)
# right_data6_score_W' 0.43103448275862066
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.34813084112149534
# error_data7_score_W0 0.1939252336448598
# combinedweight shape1 : (468, 32)
# right_data7_score_W' 0.39893617021276595
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.3548387096774194
# error_data8_score_W0 0.2078853046594982
# combinedweight shape1 : (520, 32)
# right_data8_score_W' 0.42953020134228187
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.4166666666666667
# error_data9_score_W0 0.21666666666666667
# combinedweight shape1 : (572, 32)
# right_data9_score_W' 0.3434343434343434
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.5428571428571428
# error_data10_score_W0 0.2571428571428571
# combinedweight shape1 : (624, 32)
# right_data10_score_W' 0.41333333333333333
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.7916666666666666
# error_data11_score_W0 0.3333333333333333
# combinedweight shape1 : (676, 32)
# right_data11_score_W' 0.42105263157894735
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 0.9
# error_data12_score_W0 0.7
# combinedweight shape1 : (728, 32)
# right_data12_score_W' 0.6052631578947368
# Finish one splitting *********
# 13
# right_data13_score_W0 1.0
# error_data13_score_W1 1.0
# error_data13_score_W0 1.0
# Error data can be represented by W0 13
# combinedweight shape1 : (780, 32)
# right_data13_score_W' 0.8888888888888888
# Finish one splitting *********
# 14
#  NO Error Data, Finish Training!
# split_num 14
# all_train_score_W0: 0.20937653411880217
# all_train_score_W': 0.7255768286696122
# test_score_W0 : 0.18384879725085912
# test_score_W': 0.2789232531500573
# class_num*x*(optimize_W.split_num +1)780
# neuron unit number: 65
# *******************
#
# Error Data percentage 0.7891507118311242
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22612752721617418
# error_data0_score_W0 0.17791601866251944
# combinedweight shape 0: (130, 32)
# right_data0_score_W' 0.5389988358556461
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.1989549839228296
# error_data1_score_W0 0.1467041800643087
# combinedweight shape1 : (195, 32)
# right_data1_score_W' 0.546079779917469
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.24586051179126944
# error_data2_score_W0 0.17160060210737582
# combinedweight shape1 : (260, 32)
# right_data2_score_W' 0.3595959595959596
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.25681969394544246
# error_data3_score_W0 0.15036593479707253
# combinedweight shape1 : (325, 32)
# right_data3_score_W' 0.39387755102040817
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.2945389435989257
# error_data4_score_W0 0.1718889883616831
# combinedweight shape1 : (390, 32)
# right_data4_score_W' 0.3704663212435233
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3096446700507614
# error_data5_score_W0 0.17639593908629442
# combinedweight shape1 : (455, 32)
# right_data5_score_W' 0.39209726443769
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3180147058823529
# error_data6_score_W0 0.16727941176470587
# combinedweight shape1 : (520, 32)
# right_data6_score_W' 0.36065573770491804
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.3692722371967655
# error_data7_score_W0 0.21024258760107817
# combinedweight shape1 : (585, 32)
# right_data7_score_W' 0.34104046242774566
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.46153846153846156
# error_data8_score_W0 0.21367521367521367
# combinedweight shape1 : (650, 32)
# right_data8_score_W' 0.4233576642335766
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.5873015873015873
# error_data9_score_W0 0.25396825396825395
# combinedweight shape1 : (715, 32)
# right_data9_score_W' 0.37037037037037035
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.6923076923076923
# error_data10_score_W0 0.28846153846153844
# combinedweight shape1 : (780, 32)
# right_data10_score_W' 0.5135135135135135
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 0.9375
# error_data11_score_W0 0.5
# combinedweight shape1 : (845, 32)
# right_data11_score_W' 0.6666666666666666
# Finish one splitting *********
# 12
# right_data12_score_W0 1.0
# error_data12_score_W1 1.0
# error_data12_score_W0 1.0
# Error data can be represented by W0 12
# combinedweight shape1 : (910, 32)
# right_data12_score_W' 0.7333333333333333
# Finish one splitting *********
# 13
#  NO Error Data, Finish Training!
# split_num 13
# all_train_score_W0: 0.2108492881688758
# all_train_score_W': 0.7236131566028473
# test_score_W0 : 0.19243986254295534
# test_score_W': 0.28751431844215347
# class_num*x*(optimize_W.split_num +1)910
# neuron unit number: 78
# *******************
#
# Error Data percentage 0.7665684830633285
# right_data0_score_W0 1.0
# error_data0_score_W1 0.22062119756644252
# error_data0_score_W0 0.1834774255523535
# combinedweight shape 0: (156, 32)
# right_data0_score_W' 0.7444794952681388
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.22350041084634348
# error_data1_score_W0 0.15242399342645852
# combinedweight shape1 : (234, 32)
# right_data1_score_W' 0.42670537010159654
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.23703703703703705
# error_data2_score_W0 0.14656084656084656
# combinedweight shape1 : (312, 32)
# right_data2_score_W' 0.3272058823529412
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.23994452149791956
# error_data3_score_W0 0.14909847434119278
# combinedweight shape1 : (390, 32)
# right_data3_score_W' 0.3482142857142857
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.29744525547445255
# error_data4_score_W0 0.15693430656934307
# combinedweight shape1 : (468, 32)
# right_data4_score_W' 0.32947976878612717
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3064935064935065
# error_data5_score_W0 0.15974025974025974
# combinedweight shape1 : (546, 32)
# right_data5_score_W' 0.401840490797546
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.33707865168539325
# error_data6_score_W0 0.18352059925093633
# combinedweight shape1 : (624, 32)
# right_data6_score_W' 0.3940677966101695
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.4011299435028249
# error_data7_score_W0 0.1864406779661017
# combinedweight shape1 : (702, 32)
# right_data7_score_W' 0.31666666666666665
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5047169811320755
# error_data8_score_W0 0.23113207547169812
# combinedweight shape1 : (780, 32)
# right_data8_score_W' 0.44366197183098594
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.6666666666666666
# error_data9_score_W0 0.24761904761904763
# combinedweight shape1 : (858, 32)
# right_data9_score_W' 0.4953271028037383
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.9428571428571428
# error_data10_score_W0 0.34285714285714286
# combinedweight shape1 : (936, 32)
# right_data10_score_W' 0.4857142857142857
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 0.5
# combinedweight shape1 : (1014, 32)
# right_data11_score_W' 0.8181818181818182
# Finish one splitting *********
# 12
#  NO Error Data, Finish Training!
# split_num 12
# all_train_score_W0: 0.23343151693667158
# all_train_score_W': 0.7292587137947962
# test_score_W0 : 0.21878579610538373
# test_score_W': 0.28751431844215347
# class_num*x*(optimize_W.split_num +1)1014
# neuron unit number: 91
# *******************
#
# Error Data percentage 0.7702503681885126
# right_data0_score_W0 1.0
# error_data0_score_W1 0.25207138304652643
# error_data0_score_W0 0.17686424474187382
# combinedweight shape 0: (182, 32)
# right_data0_score_W' 0.5683760683760684
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2577758841073711
# error_data1_score_W0 0.15509160630592245
# combinedweight shape1 : (273, 32)
# right_data1_score_W' 0.5309734513274337
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.2600459242250287
# error_data2_score_W0 0.14753157290470723
# combinedweight shape1 : (364, 32)
# right_data2_score_W' 0.3785123966942149
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.28937160589604344
# error_data3_score_W0 0.16291698991466252
# combinedweight shape1 : (455, 32)
# right_data3_score_W' 0.3554083885209713
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3089519650655022
# error_data4_score_W0 0.18340611353711792
# combinedweight shape1 : (546, 32)
# right_data4_score_W' 0.3646112600536193
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.3459715639810427
# error_data5_score_W0 0.16587677725118483
# combinedweight shape1 : (637, 32)
# right_data5_score_W' 0.34275618374558303
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.3961352657004831
# error_data6_score_W0 0.19082125603864733
# combinedweight shape1 : (728, 32)
# right_data6_score_W' 0.3881278538812785
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.464
# error_data7_score_W0 0.196
# combinedweight shape1 : (819, 32)
# right_data7_score_W' 0.4024390243902439
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.5895522388059702
# error_data8_score_W0 0.23134328358208955
# combinedweight shape1 : (910, 32)
# right_data8_score_W' 0.4051724137931034
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.7090909090909091
# error_data9_score_W0 0.2545454545454545
# combinedweight shape1 : (1001, 32)
# right_data9_score_W' 0.4810126582278481
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 0.9375
# error_data10_score_W0 0.4375
# combinedweight shape1 : (1092, 32)
# right_data10_score_W' 0.5384615384615384
# Finish one splitting *********
# 11
# right_data11_score_W0 1.0
# error_data11_score_W1 1.0
# error_data11_score_W0 1.0
# Error data can be represented by W0 11
# combinedweight shape1 : (1183, 32)
# right_data11_score_W' 0.8
# Finish one splitting *********
# 12
#  NO Error Data, Finish Training!
# split_num 12
# all_train_score_W0: 0.22974963181148747
# all_train_score_W': 0.7363770250368189
# test_score_W0 : 0.19072164948453607
# test_score_W': 0.28923253150057276
# class_num*x*(optimize_W.split_num +1)1183
# neuron unit number: 104
# *******************
#
# Error Data percentage 0.7464408443789887
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2518908253863861
# error_data0_score_W0 0.21078592568234134
# combinedweight shape 0: (208, 32)
# right_data0_score_W' 0.5963213939980639
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2571428571428571
# error_data1_score_W0 0.15692307692307692
# combinedweight shape1 : (312, 32)
# right_data1_score_W' 0.4856396866840731
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.25384615384615383
# error_data2_score_W0 0.15739644970414202
# combinedweight shape1 : (416, 32)
# right_data2_score_W' 0.39658119658119656
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.28945281522601113
# error_data3_score_W0 0.17287866772402855
# combinedweight shape1 : (520, 32)
# right_data3_score_W' 0.41025641025641024
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.328125
# error_data4_score_W0 0.19308035714285715
# combinedweight shape1 : (624, 32)
# right_data4_score_W' 0.33972602739726027
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4019933554817276
# error_data5_score_W0 0.19269102990033224
# combinedweight shape1 : (728, 32)
# right_data5_score_W' 0.41836734693877553
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.4361111111111111
# error_data6_score_W0 0.18888888888888888
# combinedweight shape1 : (832, 32)
# right_data6_score_W' 0.371900826446281
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.5714285714285714
# error_data7_score_W0 0.26108374384236455
# combinedweight shape1 : (936, 32)
# right_data7_score_W' 0.3821656050955414
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.8045977011494253
# error_data8_score_W0 0.27586206896551724
# combinedweight shape1 : (1040, 32)
# right_data8_score_W' 0.4396551724137931
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 0.8823529411764706
# error_data9_score_W0 0.5294117647058824
# combinedweight shape1 : (1144, 32)
# right_data9_score_W' 0.5142857142857142
# Finish one splitting *********
# 10
# right_data10_score_W0 1.0
# error_data10_score_W1 1.0
# error_data10_score_W0 1.0
# Error data can be represented by W0 10
# combinedweight shape1 : (1248, 32)
# right_data10_score_W' 0.8666666666666667
# Finish one splitting *********
# 11
#  NO Error Data, Finish Training!
# split_num 11
# all_train_score_W0: 0.2535591556210113
# all_train_score_W': 0.7280314187530682
# test_score_W0 : 0.22279495990836198
# test_score_W': 0.27949599083619703
# class_num*x*(optimize_W.split_num +1)1248
# neuron unit number: 117
# *******************
#
# Error Data percentage 0.7513500245459008
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2701731460307089
# error_data0_score_W0 0.1871937275400196
# combinedweight shape 0: (234, 32)
# right_data0_score_W' 0.596248766041461
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.27081468218442256
# error_data1_score_W0 0.1450313339301701
# combinedweight shape1 : (351, 32)
# right_data1_score_W' 0.43047158403869407
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.29097605893186
# error_data2_score_W0 0.15285451197053407
# combinedweight shape1 : (468, 32)
# right_data2_score_W' 0.43305785123966944
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3116883116883117
# error_data3_score_W0 0.1619047619047619
# combinedweight shape1 : (585, 32)
# right_data3_score_W' 0.33122362869198313
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.3610062893081761
# error_data4_score_W0 0.19748427672955976
# combinedweight shape1 : (702, 32)
# right_data4_score_W' 0.375
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.4153543307086614
# error_data5_score_W0 0.19094488188976377
# combinedweight shape1 : (819, 32)
# right_data5_score_W' 0.40069686411149824
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.494949494949495
# error_data6_score_W0 0.19528619528619529
# combinedweight shape1 : (936, 32)
# right_data6_score_W' 0.38388625592417064
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.6133333333333333
# error_data7_score_W0 0.26
# combinedweight shape1 : (1053, 32)
# right_data7_score_W' 0.3741496598639456
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.7931034482758621
# error_data8_score_W0 0.3275862068965517
# combinedweight shape1 : (1170, 32)
# right_data8_score_W' 0.45652173913043476
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 0.6666666666666666
# combinedweight shape1 : (1287, 32)
# right_data9_score_W' 0.5869565217391305
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.24864997545409917
# all_train_score_W': 0.7405498281786942
# test_score_W0 : 0.20904925544100803
# test_score_W': 0.29782359679266895
# class_num*x*(optimize_W.split_num +1)1287
# neuron unit number: 130
# *******************
#
# Error Data percentage 0.7324496809032891
# right_data0_score_W0 1.0
# error_data0_score_W1 0.278485254691689
# error_data0_score_W0 0.19839142091152814
# combinedweight shape 0: (260, 32)
# right_data0_score_W' 0.6201834862385321
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2810032512772875
# error_data1_score_W0 0.15188109614491407
# combinedweight shape1 : (390, 32)
# right_data1_score_W' 0.4729241877256318
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.32558139534883723
# error_data2_score_W0 0.1698966408268734
# combinedweight shape1 : (520, 32)
# right_data2_score_W' 0.3504132231404959
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.34195402298850575
# error_data3_score_W0 0.16666666666666666
# combinedweight shape1 : (650, 32)
# right_data3_score_W' 0.47023809523809523
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.38719068413391555
# error_data4_score_W0 0.1965065502183406
# combinedweight shape1 : (780, 32)
# right_data4_score_W' 0.3445378151260504
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.46318289786223277
# error_data5_score_W0 0.19714964370546317
# combinedweight shape1 : (910, 32)
# right_data5_score_W' 0.39097744360902253
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.5663716814159292
# error_data6_score_W0 0.20353982300884957
# combinedweight shape1 : (1040, 32)
# right_data6_score_W' 0.358974358974359
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.7857142857142857
# error_data7_score_W0 0.2755102040816326
# combinedweight shape1 : (1170, 32)
# right_data7_score_W' 0.515625
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 0.9047619047619048
# error_data8_score_W0 0.5238095238095238
# combinedweight shape1 : (1300, 32)
# right_data8_score_W' 0.5714285714285714
# Finish one splitting *********
# 9
# right_data9_score_W0 1.0
# error_data9_score_W1 1.0
# error_data9_score_W0 1.0
# Error data can be represented by W0 9
# combinedweight shape1 : (1430, 32)
# right_data9_score_W' 0.8421052631578947
# Finish one splitting *********
# 10
#  NO Error Data, Finish Training!
# split_num 10
# all_train_score_W0: 0.26755031909671084
# all_train_score_W': 0.7366224840451645
# test_score_W0 : 0.22451317296678122
# test_score_W': 0.3006872852233677
# class_num*x*(optimize_W.split_num +1)1430
# neuron unit number: 143
# *******************
#
# Error Data percentage 0.7427589592538046
# right_data0_score_W0 1.0
# error_data0_score_W1 0.29114342366159945
# error_data0_score_W0 0.19629874421678783
# combinedweight shape 0: (286, 32)
# right_data0_score_W' 0.5820610687022901
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2745920745920746
# error_data1_score_W0 0.1627039627039627
# combinedweight shape1 : (429, 32)
# right_data1_score_W' 0.48240635641316687
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3232647814910026
# error_data2_score_W0 0.18380462724935734
# combinedweight shape1 : (572, 32)
# right_data2_score_W' 0.3531409168081494
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.35327635327635326
# error_data3_score_W0 0.19278252611585944
# combinedweight shape1 : (715, 32)
# right_data3_score_W' 0.3379721669980119
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4067547723935389
# error_data4_score_W0 0.19530102790014683
# combinedweight shape1 : (858, 32)
# right_data4_score_W' 0.2956989247311828
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5024752475247525
# error_data5_score_W0 0.19306930693069307
# combinedweight shape1 : (1001, 32)
# right_data5_score_W' 0.3285198555956679
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6766169154228856
# error_data6_score_W0 0.2537313432835821
# combinedweight shape1 : (1144, 32)
# right_data6_score_W' 0.4088669950738916
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.8461538461538461
# error_data7_score_W0 0.3384615384615385
# combinedweight shape1 : (1287, 32)
# right_data7_score_W' 0.4117647058823529
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.8
# combinedweight shape1 : (1430, 32)
# right_data8_score_W' 0.5636363636363636
# Finish one splitting *********
# 9
#  NO Error Data, Finish Training!
# split_num 9
# all_train_score_W0: 0.25724104074619536
# all_train_score_W': 0.7368679430535101
# test_score_W0 : 0.21076746849942726
# test_score_W': 0.2920962199312715
# class_num*x*(optimize_W.split_num +1)1430
# neuron unit number: 156
# *******************
#
# Error Data percentage 0.7324496809032891
# right_data0_score_W0 1.0
# error_data0_score_W1 0.27781501340482573
# error_data0_score_W0 0.20878016085790885
# combinedweight shape 0: (312, 32)
# right_data0_score_W' 0.5862385321100917
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.2798143851508121
# error_data1_score_W0 0.15962877030162412
# combinedweight shape1 : (468, 32)
# right_data1_score_W' 0.5126658624849216
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.31056701030927836
# error_data2_score_W0 0.1713917525773196
# combinedweight shape1 : (624, 32)
# right_data2_score_W' 0.39800995024875624
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3542056074766355
# error_data3_score_W0 0.16542056074766356
# combinedweight shape1 : (780, 32)
# right_data3_score_W' 0.3070539419087137
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4283646888567294
# error_data4_score_W0 0.17800289435600578
# combinedweight shape1 : (936, 32)
# right_data4_score_W' 0.38522427440633245
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5215189873417722
# error_data5_score_W0 0.189873417721519
# combinedweight shape1 : (1092, 32)
# right_data5_score_W' 0.35135135135135137
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.6772486772486772
# error_data6_score_W0 0.24338624338624337
# combinedweight shape1 : (1248, 32)
# right_data6_score_W' 0.4077669902912621
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.8524590163934426
# error_data7_score_W0 0.36065573770491804
# combinedweight shape1 : (1404, 32)
# right_data7_score_W' 0.5234375
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 0.4444444444444444
# combinedweight shape1 : (1560, 32)
# right_data8_score_W' 0.6153846153846154
# Finish one splitting *********
# 9
#  NO Error Data, Finish Training!
# split_num 9
# all_train_score_W0: 0.26755031909671084
# all_train_score_W': 0.7346588119783997
# test_score_W0 : 0.21935853379152348
# test_score_W': 0.28465063001145474
# class_num*x*(optimize_W.split_num +1)1560
# neuron unit number: 169
# *******************
#
# Error Data percentage 0.7177221404025528
# right_data0_score_W0 1.0
# error_data0_score_W1 0.27667578659370723
# error_data0_score_W0 0.216484268125855
# combinedweight shape 0: (338, 32)
# right_data0_score_W' 0.6721739130434783
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.28888888888888886
# error_data1_score_W0 0.1635933806146572
# combinedweight shape1 : (507, 32)
# right_data1_score_W' 0.411619283065513
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.34242021276595747
# error_data2_score_W0 0.19680851063829788
# combinedweight shape1 : (676, 32)
# right_data2_score_W' 0.3960720130932897
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.3822042467138524
# error_data3_score_W0 0.18402426693629928
# combinedweight shape1 : (845, 32)
# right_data3_score_W' 0.3553398058252427
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.42716857610474634
# error_data4_score_W0 0.18166939443535188
# combinedweight shape1 : (1014, 32)
# right_data4_score_W' 0.40476190476190477
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.5371428571428571
# error_data5_score_W0 0.2
# combinedweight shape1 : (1183, 32)
# right_data5_score_W' 0.3831417624521073
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.7469135802469136
# error_data6_score_W0 0.3148148148148148
# combinedweight shape1 : (1352, 32)
# right_data6_score_W' 0.4148936170212766
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.926829268292683
# error_data7_score_W0 0.3902439024390244
# combinedweight shape1 : (1521, 32)
# right_data7_score_W' 0.5454545454545454
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (1690, 32)
# right_data8_score_W' 0.7894736842105263
# Finish one splitting *********
# 9
#  NO Error Data, Finish Training!
# split_num 9
# all_train_score_W0: 0.2822778595974472
# all_train_score_W': 0.7380952380952381
# test_score_W0 : 0.24856815578465064
# test_score_W': 0.28923253150057276
# class_num*x*(optimize_W.split_num +1)1690
# neuron unit number: 182
# *******************
#
# Error Data percentage 0.7309769268532155
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2907991940899933
# error_data0_score_W0 0.19610476830087306
# combinedweight shape 0: (364, 32)
# right_data0_score_W' 0.6551094890510949
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3087121212121212
# error_data1_score_W0 0.15246212121212122
# combinedweight shape1 : (546, 32)
# right_data1_score_W' 0.4295612009237875
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3232876712328767
# error_data2_score_W0 0.1547945205479452
# combinedweight shape1 : (728, 32)
# right_data2_score_W' 0.43558282208588955
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4018218623481781
# error_data3_score_W0 0.18724696356275303
# combinedweight shape1 : (910, 32)
# right_data3_score_W' 0.3559322033898305
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4653130287648054
# error_data4_score_W0 0.22165820642978004
# combinedweight shape1 : (1092, 32)
# right_data4_score_W' 0.37279596977329976
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.6012658227848101
# error_data5_score_W0 0.2310126582278481
# combinedweight shape1 : (1274, 32)
# right_data5_score_W' 0.3781818181818182
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.7301587301587301
# error_data6_score_W0 0.29365079365079366
# combinedweight shape1 : (1456, 32)
# right_data6_score_W' 0.4052631578947368
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.9411764705882353
# error_data7_score_W0 0.5294117647058824
# combinedweight shape1 : (1638, 32)
# right_data7_score_W' 0.5760869565217391
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (1820, 32)
# right_data8_score_W' 0.71875
# Finish one splitting *********
# 9
#  NO Error Data, Finish Training!
# split_num 9
# all_train_score_W0: 0.2690230731467845
# all_train_score_W': 0.7422680412371134
# test_score_W0 : 0.2222222222222222
# test_score_W': 0.2943871706758305
# class_num*x*(optimize_W.split_num +1)1820
# neuron unit number: 195
# *******************
#
# Error Data percentage 0.7368679430535101
# right_data0_score_W0 1.0
# error_data0_score_W1 0.2981345769487009
# error_data0_score_W0 0.18920719520319787
# combinedweight shape 0: (390, 32)
# right_data0_score_W' 0.6110074626865671
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3350735643094447
# error_data1_score_W0 0.1703844328429046
# combinedweight shape1 : (585, 32)
# right_data1_score_W' 0.41787709497206704
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3483226266952177
# error_data2_score_W0 0.1655960028551035
# combinedweight shape1 : (780, 32)
# right_data2_score_W' 0.4447592067988669
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.4008762322015334
# error_data3_score_W0 0.17634173055859803
# combinedweight shape1 : (975, 32)
# right_data3_score_W' 0.3729508196721312
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.4826325411334552
# error_data4_score_W0 0.19744058500914077
# combinedweight shape1 : (1170, 32)
# right_data4_score_W' 0.38524590163934425
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.657243816254417
# error_data5_score_W0 0.26148409893992935
# combinedweight shape1 : (1365, 32)
# right_data5_score_W' 0.42045454545454547
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.8041237113402062
# error_data6_score_W0 0.29896907216494845
# combinedweight shape1 : (1560, 32)
# right_data6_score_W' 0.43548387096774194
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 0.8947368421052632
# error_data7_score_W0 0.5263157894736842
# combinedweight shape1 : (1755, 32)
# right_data7_score_W' 0.5769230769230769
# Finish one splitting *********
# 8
# right_data8_score_W0 1.0
# error_data8_score_W1 1.0
# error_data8_score_W0 1.0
# Error data can be represented by W0 8
# combinedweight shape1 : (1950, 32)
# right_data8_score_W' 0.7647058823529411
# Finish one splitting *********
# 9
#  NO Error Data, Finish Training!
# split_num 9
# all_train_score_W0: 0.26313205694648995
# all_train_score_W': 0.741286205203731
# test_score_W0 : 0.20847651775486828
# test_score_W': 0.29667812142038946
# class_num*x*(optimize_W.split_num +1)1950
# neuron unit number: 208
# *******************
#
# Error Data percentage 0.7137947962690231
# right_data0_score_W0 1.0
# error_data0_score_W1 0.30845942228335627
# error_data0_score_W0 0.20013755158184318
# combinedweight shape 0: (416, 32)
# right_data0_score_W' 0.5857632933104632
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.331178518150174
# error_data1_score_W0 0.16210840377921432
# combinedweight shape1 : (624, 32)
# right_data1_score_W' 0.496098104793757
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.3903345724907063
# error_data2_score_W0 0.17397769516728626
# combinedweight shape1 : (832, 32)
# right_data2_score_W' 0.3963963963963964
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.42317073170731706
# error_data3_score_W0 0.174390243902439
# combinedweight shape1 : (1040, 32)
# right_data3_score_W' 0.34095238095238095
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.5412262156448203
# error_data4_score_W0 0.21141649048625794
# combinedweight shape1 : (1248, 32)
# right_data4_score_W' 0.34870317002881845
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.7142857142857143
# error_data5_score_W0 0.23963133640552994
# combinedweight shape1 : (1456, 32)
# right_data5_score_W' 0.43359375
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.9032258064516129
# error_data6_score_W0 0.4032258064516129
# combinedweight shape1 : (1664, 32)
# right_data6_score_W' 0.5225806451612903
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.8333333333333334
# combinedweight shape1 : (1872, 32)
# right_data7_score_W' 0.6428571428571429
# Finish one splitting *********
# 8
#  NO Error Data, Finish Training!
# split_num 8
# all_train_score_W0: 0.2862052037309769
# all_train_score_W': 0.740058910162003
# test_score_W0 : 0.2279495990836197
# test_score_W': 0.28751431844215347
# class_num*x*(optimize_W.split_num +1)1872
# neuron unit number: 221
# *******************
#
# Error Data percentage 0.7155130093274423
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3111492281303602
# error_data0_score_W0 0.20034305317324186
# combinedweight shape 0: (442, 32)
# right_data0_score_W' 0.6238136324417601
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.33565737051792827
# error_data1_score_W0 0.16832669322709162
# combinedweight shape1 : (663, 32)
# right_data1_score_W' 0.4994487320837927
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.36881559220389803
# error_data2_score_W0 0.18590704647676162
# combinedweight shape1 : (884, 32)
# right_data2_score_W' 0.41097922848664686
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.45368171021377673
# error_data3_score_W0 0.19714964370546317
# combinedweight shape1 : (1105, 32)
# right_data3_score_W' 0.4349593495934959
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.591304347826087
# error_data4_score_W0 0.20434782608695654
# combinedweight shape1 : (1326, 32)
# right_data4_score_W' 0.3900523560209424
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.723404255319149
# error_data5_score_W0 0.2712765957446808
# combinedweight shape1 : (1547, 32)
# right_data5_score_W' 0.39338235294117646
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.9423076923076923
# error_data6_score_W0 0.36538461538461536
# combinedweight shape1 : (1768, 32)
# right_data6_score_W' 0.5808823529411765
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 0.6666666666666666
# combinedweight shape1 : (1989, 32)
# right_data7_score_W' 0.6326530612244898
# Finish one splitting *********
# 8
#  NO Error Data, Finish Training!
# split_num 8
# all_train_score_W0: 0.28448699067255767
# all_train_score_W': 0.7390770741286206
# test_score_W0 : 0.2468499427262314
# test_score_W': 0.2920962199312715
# class_num*x*(optimize_W.split_num +1)1989
# neuron unit number: 234
# *******************
#
# Error Data percentage 0.7069219440353461
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3104166666666667
# error_data0_score_W0 0.21805555555555556
# combinedweight shape 0: (468, 32)
# right_data0_score_W' 0.6113902847571189
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3464249748237664
# error_data1_score_W0 0.1691842900302115
# combinedweight shape1 : (702, 32)
# right_data1_score_W' 0.42058165548098436
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.39060092449922956
# error_data2_score_W0 0.1802773497688752
# combinedweight shape1 : (936, 32)
# ...
# error_data0_score_W0 0.21875
# combinedweight shape 0: (2938, 32)
# right_data0_score_W' 0.6217054263565891
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4316546762589928
# error_data1_score_W0 0.1853901494189264
# combinedweight shape1 : (4407, 32)
# right_data1_score_W' 0.42988741044012285
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5472249269717624
# error_data2_score_W0 0.1830574488802337
# combinedweight shape1 : (5876, 32)
# right_data2_score_W' 0.41923076923076924
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6623655913978495
# error_data3_score_W0 0.23870967741935484
# combinedweight shape1 : (7345, 32)
# right_data3_score_W' 0.5071174377224199
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.802547770700637
# error_data4_score_W0 0.267515923566879
# combinedweight shape1 : (8814, 32)
# right_data4_score_W' 0.5454545454545454
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.967741935483871
# error_data5_score_W0 0.5483870967741935
# combinedweight shape1 : (10283, 32)
# right_data5_score_W' 0.5079365079365079
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (11752, 32)
# right_data6_score_W' 0.7333333333333333
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.3166421207658321
# all_train_score_W': 0.738831615120275
# test_score_W0 : 0.25143184421534936
# test_score_W': 0.2920962199312715
# class_num*x*(optimize_W.split_num +1)11752
# neuron unit number: 1482
# *******************
#
# Error Data percentage 0.6961217476681394
# right_data0_score_W0 1.0
# error_data0_score_W1 0.36671368124118475
# error_data0_score_W0 0.2048660084626234
# combinedweight shape 0: (2964, 32)
# right_data0_score_W' 0.5541195476575121
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3992204899777283
# error_data1_score_W0 0.17371937639198218
# combinedweight shape1 : (4446, 32)
# right_data1_score_W' 0.5365384615384615
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5162187210379982
# error_data2_score_W0 0.1881371640407785
# combinedweight shape1 : (5928, 32)
# right_data2_score_W' 0.41562064156206413
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6647509578544061
# error_data3_score_W0 0.2547892720306513
# combinedweight shape1 : (7410, 32)
# right_data3_score_W' 0.4272890484739677
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.7714285714285715
# error_data4_score_W0 0.29714285714285715
# combinedweight shape1 : (8892, 32)
# right_data4_score_W' 0.45821325648414984
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.925
# error_data5_score_W0 0.525
# combinedweight shape1 : (10374, 32)
# right_data5_score_W' 0.4666666666666667
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.6666666666666666
# combinedweight shape1 : (11856, 32)
# right_data6_score_W' 0.7837837837837838
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.30387825233186055
# all_train_score_W': 0.7420225822287678
# test_score_W0 : 0.2290950744558992
# test_score_W': 0.30469644902634596
# class_num*x*(optimize_W.split_num +1)11856
# neuron unit number: 1495
# *******************
#
# Error Data percentage 0.6917034855179185
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3683463449254791
# error_data0_score_W0 0.21327182398864442
# combinedweight shape 0: (2990, 32)
# right_data0_score_W' 0.5700636942675159
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.42247191011235957
# error_data1_score_W0 0.1747191011235955
# combinedweight shape1 : (4485, 32)
# right_data1_score_W' 0.47109826589595377
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5505836575875487
# error_data2_score_W0 0.20330739299610895
# combinedweight shape1 : (5980, 32)
# right_data2_score_W' 0.3976063829787234
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6861471861471862
# error_data3_score_W0 0.2662337662337662
# combinedweight shape1 : (7475, 32)
# right_data3_score_W' 0.49823321554770317
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.8344827586206897
# error_data4_score_W0 0.3310344827586207
# combinedweight shape1 : (8970, 32)
# right_data4_score_W' 0.47003154574132494
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 1.0
# error_data5_score_W0 0.5416666666666666
# combinedweight shape1 : (10465, 32)
# right_data5_score_W' 0.5867768595041323
# Finish one splitting *********
# 6
#  NO Error Data, Finish Training!
# split_num 6
# all_train_score_W0: 0.3082965144820815
# all_train_score_W': 0.7422680412371134
# test_score_W0 : 0.22737686139747995
# test_score_W': 0.29152348224513175
# class_num*x*(optimize_W.split_num +1)10465
# neuron unit number: 1508
# *******************
#
# Error Data percentage 0.6924398625429553
# right_data0_score_W0 1.0
# error_data0_score_W1 0.34739454094292804
# error_data0_score_W0 0.2130450194966324
# combinedweight shape 0: (3016, 32)
# right_data0_score_W' 0.5482841181165203
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.3900054318305269
# error_data1_score_W0 0.17599130907115698
# combinedweight shape1 : (4524, 32)
# right_data1_score_W' 0.4959183673469388
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.4772929652715939
# error_data2_score_W0 0.1772039180765806
# combinedweight shape1 : (6032, 32)
# right_data2_score_W' 0.3746518105849582
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6388415672913118
# error_data3_score_W0 0.23679727427597955
# combinedweight shape1 : (7540, 32)
# right_data3_score_W' 0.43097014925373134
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.8066037735849056
# error_data4_score_W0 0.28773584905660377
# combinedweight shape1 : (9048, 32)
# right_data4_score_W' 0.456
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.9024390243902439
# error_data5_score_W0 0.5365853658536586
# combinedweight shape1 : (10556, 32)
# right_data5_score_W' 0.5789473684210527
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 0.75
# error_data6_score_W0 0.75
# combinedweight shape1 : (12064, 32)
# right_data6_score_W' 0.8378378378378378
# Finish one splitting *********
# 7
# right_data7_score_W0 1.0
# error_data7_score_W1 1.0
# error_data7_score_W0 1.0
# Error data can be represented by W0 7
# combinedweight shape1 : (13572, 32)
# right_data7_score_W' 1.0
# Finish one splitting *********
# 8
#  NO Error Data, Finish Training!
# split_num 8
# all_train_score_W0: 0.3075601374570447
# all_train_score_W': 0.7405498281786942
# test_score_W0 : 0.24398625429553264
# test_score_W': 0.290950744558992
# class_num*x*(optimize_W.split_num +1)13572
# neuron unit number: 1521
# *******************
#
# Error Data percentage 0.7083946980854198
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35932085932085933
# error_data0_score_W0 0.19889119889119888
# combinedweight shape 0: (3042, 32)
# right_data0_score_W' 0.5370370370370371
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4142779881016766
# error_data1_score_W0 0.1795565170362358
# combinedweight shape1 : (4563, 32)
# right_data1_score_W' 0.5004821600771456
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5337026777469991
# error_data2_score_W0 0.18005540166204986
# combinedweight shape1 : (6084, 32)
# right_data2_score_W' 0.4660574412532637
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6534653465346535
# error_data3_score_W0 0.24554455445544554
# combinedweight shape1 : (7605, 32)
# right_data3_score_W' 0.43079584775086505
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.8
# error_data4_score_W0 0.2742857142857143
# combinedweight shape1 : (9126, 32)
# right_data4_score_W' 0.4636363636363636
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.9428571428571428
# error_data5_score_W0 0.5142857142857142
# combinedweight shape1 : (10647, 32)
# right_data5_score_W' 0.5857142857142857
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (12168, 32)
# right_data6_score_W' 0.7878787878787878
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.2916053019145803
# all_train_score_W': 0.7427589592538046
# test_score_W0 : 0.22451317296678122
# test_score_W': 0.29896907216494845
# class_num*x*(optimize_W.split_num +1)12168
# neuron unit number: 1534
# *******************
#
# Error Data percentage 0.6921944035346097
# right_data0_score_W0 1.0
# error_data0_score_W1 0.35425531914893615
# error_data0_score_W0 0.2170212765957447
# combinedweight shape 0: (3068, 32)
# right_data0_score_W' 0.5741626794258373
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.4085667215815486
# error_data1_score_W0 0.1658429434376716
# combinedweight shape1 : (4602, 32)
# right_data1_score_W' 0.4994994994994995
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.49303621169916434
# error_data2_score_W0 0.1968430826369545
# combinedweight shape1 : (6136, 32)
# right_data2_score_W' 0.3978494623655914
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6172161172161172
# error_data3_score_W0 0.23443223443223443
# combinedweight shape1 : (7670, 32)
# right_data3_score_W' 0.4293785310734463
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.7559808612440191
# error_data4_score_W0 0.291866028708134
# combinedweight shape1 : (9204, 32)
# right_data4_score_W' 0.47181008902077154
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.8823529411764706
# error_data5_score_W0 0.39215686274509803
# combinedweight shape1 : (10738, 32)
# right_data5_score_W' 0.6075949367088608
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (12272, 32)
# right_data6_score_W' 0.6
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.3078055964653903
# all_train_score_W': 0.7444771723122239
# test_score_W0 : 0.23539518900343642
# test_score_W': 0.29381443298969073
# class_num*x*(optimize_W.split_num +1)12272
# neuron unit number: 1547
# *******************
#
# Error Data percentage 0.6799214531173294
# right_data0_score_W0 1.0
# error_data0_score_W1 0.36823104693140796
# error_data0_score_W0 0.22021660649819494
# combinedweight shape 0: (3094, 32)
# right_data0_score_W' 0.6265337423312883
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.43542857142857144
# error_data1_score_W0 0.17885714285714285
# combinedweight shape1 : (4641, 32)
# right_data1_score_W' 0.45588235294117646
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.5404858299595142
# error_data2_score_W0 0.2216599190283401
# combinedweight shape1 : (6188, 32)
# right_data2_score_W' 0.48556430446194226
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.6585903083700441
# error_data3_score_W0 0.24669603524229075
# combinedweight shape1 : (7735, 32)
# right_data3_score_W' 0.4794007490636704
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.7806451612903226
# error_data4_score_W0 0.38064516129032255
# combinedweight shape1 : (9282, 32)
# right_data4_score_W' 0.5016722408026756
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.8823529411764706
# error_data5_score_W0 0.5882352941176471
# combinedweight shape1 : (10829, 32)
# right_data5_score_W' 0.6446280991735537
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 1.0
# Error data can be represented by W0 6
# combinedweight shape1 : (12376, 32)
# right_data6_score_W' 0.7666666666666667
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.32007854688267057
# all_train_score_W': 0.742513500245459
# test_score_W0 : 0.24971363115693013
# test_score_W': 0.29782359679266895
# class_num*x*(optimize_W.split_num +1)12376
# neuron unit number: 1560
# *******************
#
# Error Data percentage 0.711340206185567
# right_data0_score_W0 1.0
# error_data0_score_W1 0.3305728088336784
# error_data0_score_W0 0.2056590752242926
# combinedweight shape 0: (3120, 32)
# right_data0_score_W' 0.5748299319727891
# Finish one splitting *********
# 1
# right_data1_score_W0 1.0
# error_data1_score_W1 0.37989690721649483
# error_data1_score_W0 0.16494845360824742
# combinedweight shape1 : (4680, 32)
# right_data1_score_W' 0.4561586638830898
# Finish one splitting *********
# 2
# right_data2_score_W0 1.0
# error_data2_score_W1 0.4679966749792186
# error_data2_score_W0 0.19118869492934332
# combinedweight shape1 : (6240, 32)
# right_data2_score_W' 0.41383989145183175
# Finish one splitting *********
# 3
# right_data3_score_W0 1.0
# error_data3_score_W1 0.559375
# error_data3_score_W0 0.215625
# combinedweight shape1 : (7800, 32)
# right_data3_score_W' 0.42984014209591476
# Finish one splitting *********
# 4
# right_data4_score_W0 1.0
# error_data4_score_W1 0.6737588652482269
# error_data4_score_W0 0.24822695035460993
# combinedweight shape1 : (9360, 32)
# right_data4_score_W' 0.441340782122905
# Finish one splitting *********
# 5
# right_data5_score_W0 1.0
# error_data5_score_W1 0.782608695652174
# error_data5_score_W0 0.3695652173913043
# combinedweight shape1 : (10920, 32)
# right_data5_score_W' 0.5052631578947369
# Finish one splitting *********
# 6
# right_data6_score_W0 1.0
# error_data6_score_W1 1.0
# error_data6_score_W0 0.7
# combinedweight shape1 : (12480, 32)
# right_data6_score_W' 0.5555555555555556
# Finish one splitting *********
# 7
#  NO Error Data, Finish Training!
# split_num 7
# all_train_score_W0: 0.28865979381443296
# all_train_score_W': 0.742513500245459
# test_score_W0 : 0.23310423825887744
# test_score_W': 0.3035509736540664
# class_num*x*(optimize_W.split_num +1)12480
# s 273  value 0.2777777777777778
# s 468  value 0.28865979381443296
# s 624  value 0.28923253150057276
# s 780  value 0.2789232531500573
# s 910  value 0.28751431844215347
# s 1014  value 0.28751431844215347
# s 1183  value 0.28923253150057276
# s 1248  value 0.27949599083619703
# s 1287  value 0.29782359679266895
# s 1430  value 0.2920962199312715
# s 1560  value 0.28465063001145474
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  11.0  0.233521  0.016552  0.004991   0.222401  0.244641
# 1  test_score_W'  11.0  0.286629  0.006058  0.001827   0.282559  0.290699
# 2       combined  22.0  0.260075  0.029777  0.006348   0.246873  0.273277
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0531
# 1                          Degrees of freedom =   20.0000
# 2                                           t =   -9.9933
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -4.2611
# 7                                   Hedge's g =   -4.0993
# 8                               Glass's delta =   -3.2085
# 9                                 Pearson's r =    0.9128
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
