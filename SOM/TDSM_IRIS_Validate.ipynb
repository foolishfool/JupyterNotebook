# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Iris.csv")
csv = csv.drop(columns=['Id'])
dataread.stringToIntIrisDataSet(csv,"Species")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Species")

#print("self.data_train len {}".format(len(dataread.data_train)))

# %%
import experiment
unstable_repeate_num= 1
scope_num = 1
class_num = 3
dim_num = 4

som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
optimize_W = TDSM_SOM.TDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
optimize_W.run()
# Out:
# right_data0_score_W0 purity 1.0
# right_data0_score_W0 nmi 1.0
# right_data0_score_W0 api 1.0
# error_data0_score_W1 purity 0.8823529411764706
# error_data0_score_W1 nmi 2.145592120184921e-15
# error_data0_score_W1 api 0.0
# error_data0_score_W0 purity 1.0
# error_data0_score_W0 nmi 1.0
# error_data0_score_W0 api 1.0
# Error data can be represented by W0 purity 0
# Error data can be represented by W0 nmi 0
# Error data can be represented by W0 api 0
# right_data0_score_W' purity 1.0
# right_data0_score_W' nmi 1.0
# right_data0_score_W' api 1.0
# Finish one round splitting 0 *********
#
# right_data1_score_W0 purity 1.0
# right_data1_score_W0 nmi 1.0
# right_data1_score_W0 api 1.0
# error_data1_score_W1 purity 1.0
# error_data1_score_W1 nmi 1.0
# error_data1_score_W1 api 1.0
# error_data1_score_W0 purity 1.0
# error_data1_score_W0 nmi 0.0
# error_data1_score_W0 api 0.0
# Error data can be represented by W0 purity 1
# right_data1_score_W' purity 1.0
# right_data1_score_W' nmi 0.0
# right_data1_score_W' api 0.0
# Finish one round splitting 1 *********
#
#  NO Error Data, Finish Training!
# total split_number 2
# stop_split_num 0
# all_train_score_W' purity split_num : 0 0.8380952380952381
# all_train_score_W' nmi split_num : 0 0.6958681508766825
# all_train_score_W' ari split_num : 0 0.6310456694601201
# test_score_W0 purity: 0.8666666666666667
# test_score_W0 nmi: 0.7692631310015836
# test_score_W0 api: 0.683946070493305
# test_score_W': purity split_num : 0 0.8666666666666667
# test_score_W': nmi split_num : 0 0.7692631310015836
# test_score_W': ari split_num : 0 0.683946070493305
# stop_split_num 1
# all_train_score_W' purity split_num : 1 0.9809523809523809
# all_train_score_W' nmi split_num : 1 0.9327434766897916
# all_train_score_W' ari split_num : 1 0.94263507723267
# test_score_W0 purity: 0.8666666666666667
# test_score_W0 nmi: 0.7692631310015836
# test_score_W0 api: 0.683946070493305
# test_score_W': purity split_num : 1 0.9333333333333333
# test_score_W': nmi split_num : 1 0.8072924374942705
# test_score_W': ari split_num : 1 0.8199194044887222
# stop_split_num 2
# all_train_score_W' purity split_num : 2 1.0
# all_train_score_W' nmi split_num : 2 1.0
# all_train_score_W' ari split_num : 2 1.0
# test_score_W0 purity: 0.8666666666666667
# test_score_W0 nmi: 0.7692631310015836
# test_score_W0 api: 0.683946070493305
# test_score_W': purity split_num : 2 0.8888888888888888
# test_score_W': nmi split_num : 2 0.745556631484033
# test_score_W': ari split_num : 2 0.7225051154360034
# all_train_scores_W_Combined_last_p 1.0
# all_train_scores_W_Combined_last_n 1.0
# all_train_scores_W_Combined_last_a 1.0
# test_scores_W_Combined_last_p 0.8888888888888888
# test_scores_W_Combined_last_n 0.745556631484033
# test_scores_W_Combined_last_a 0.7225051154360034
