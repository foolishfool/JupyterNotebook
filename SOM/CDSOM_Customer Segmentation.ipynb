# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/Test.csv")
csv = csv.drop(columns=['ID','Segmentation'])
csv2 = csv2.drop(columns=['ID'])   

csv['Family_Size'] = pd.to_numeric(csv['Family_Size'])
csv2['Family_Size'] = pd.to_numeric(csv2['Family_Size'])
csv['Work_Experience'] = pd.to_numeric(csv['Work_Experience'])
csv2['Work_Experience'] = pd.to_numeric(csv2['Work_Experience'])

csv_original_encode1 = csv
csv_original_encode2 = csv2

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode1,"Var_1")
#one hot encoding vs proposed
dataread.baseN_encoding(csv_original_encode1,["Gender","Ever_Married","Graduated","Profession","Spending_Score","Family_Size","Work_Experience"])


csv_training_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.5))


dataread.label_encoding(csv_original_encode2,"Var_1")
#one hot encoding vs proposed
dataread.baseN_encoding(csv_original_encode2,["Gender","Ever_Married","Graduated","Profession","Spending_Score","Family_Size","Work_Experience"])

#dataread.original_encoding_data is udpated through dataread.label_encoding function
csv_test_original_encoded = dataread.original_encoding_data

dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Ever_Married")
dataread.label_encoding(csv,"Graduated")
dataread.label_encoding(csv,"Profession")
dataread.label_encoding(csv,"Spending_Score")
dataread.label_encoding(csv,"Var_1")
dataread.label_encoding(csv,"Family_Size")
dataread.label_encoding(csv,"Work_Experience")



dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Ever_Married")
dataread.label_encoding(csv2,"Graduated")
dataread.label_encoding(csv2,"Profession")
dataread.label_encoding(csv2,"Spending_Score")
dataread.label_encoding(csv2,"Var_1")
dataread.label_encoding(csv2,"Family_Size")
dataread.label_encoding(csv2,"Work_Experience")



csv_training = csv.sample(int(csv.shape[0]*0.5))
csv_test = csv2




dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Var_1")
# Out:
# self.data_continuous_indexes ['Age']
#  column number self.data_train_discrete 7

# %%
#BASE n encoding vs proposed
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6608824987605354
# train_discrete_score_W_discrete_n 0.012640070295462505
# train_discrete_score_W_discrete_a 0.025962038578518743
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.029652308931311964
# test_discrete_score_W_discrete_a 0.07475183240032814
# neuron unit number: 16
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6591472483886961
# train_discrete_score_W_discrete_n 0.003484383115877155
# train_discrete_score_W_discrete_a 0.0037737902108196915
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.02316925722767526
# test_discrete_score_W_discrete_a 0.05996170770163309
# neuron unit number: 19
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6611303916707982
# train_discrete_score_W_discrete_n 0.01283911348137719
# train_discrete_score_W_discrete_a 0.016025394483510844
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.02582502295862634
# test_discrete_score_W_discrete_a 0.06566239300826134
# neuron unit number: 22
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6623698562221121
# train_discrete_score_W_discrete_n 0.01840978268733728
# train_discrete_score_W_discrete_a 0.02208037821224103
# test_discrete_score_W_discrete_p 0.6429387133612485
# test_discrete_score_W_discrete_n 0.022962220179544846
# test_discrete_score_W_discrete_a 0.05249462474776647
# neuron unit number: 25
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.66038671294001
# train_discrete_score_W_discrete_n 0.011199206983603943
# train_discrete_score_W_discrete_a 0.014882294197474904
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.02907078915750462
# test_discrete_score_W_discrete_a 0.055051546228332304
# neuron unit number: 28
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6611303916707982
# train_discrete_score_W_discrete_n 0.012585767348580945
# train_discrete_score_W_discrete_a 0.018670625936221152
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.023899369674982563
# test_discrete_score_W_discrete_a 0.05758234758722305
# neuron unit number: 31
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.66038671294001
# train_discrete_score_W_discrete_n 0.007432247924938749
# train_discrete_score_W_discrete_a 0.009044637665347558
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.022195711171810274
# test_discrete_score_W_discrete_a 0.05105332424828769
# neuron unit number: 34
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6598909271194844
# train_discrete_score_W_discrete_n 0.010799424661457467
# train_discrete_score_W_discrete_a 0.011563675995874259
# test_discrete_score_W_discrete_p 0.6452226874762086
# test_discrete_score_W_discrete_n 0.03352532994469853
# test_discrete_score_W_discrete_a 0.06234662860166891
# neuron unit number: 37
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.661378284581061
# train_discrete_score_W_discrete_n 0.02085453907053207
# train_discrete_score_W_discrete_a 0.029641165540139767
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.02530209563975969
# test_discrete_score_W_discrete_a 0.05395315658488731
# neuron unit number: 40
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6623698562221121
# train_discrete_score_W_discrete_n 0.015284859669020712
# train_discrete_score_W_discrete_a 0.017807100405781796
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.029917347906362374
# test_discrete_score_W_discrete_a 0.07096167779942503
# neuron unit number: 43
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.661378284581061
# train_discrete_score_W_discrete_n 0.015304553956232063
# train_discrete_score_W_discrete_a 0.01764851592763275
# test_discrete_score_W_discrete_p 0.6456033498287019
# test_discrete_score_W_discrete_n 0.03200281347076688
# test_discrete_score_W_discrete_a 0.06544577686843982
# neuron unit number: 46
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6598909271194844
# train_discrete_score_W_discrete_n 0.008499764222308876
# train_discrete_score_W_discrete_a 0.011370173759373816
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.02422693259773948
# test_discrete_score_W_discrete_a 0.05778288605752252
# neuron unit number: 49
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6618740704015865
# train_discrete_score_W_discrete_n 0.012722742525287137
# train_discrete_score_W_discrete_a 0.01742827997883366
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.028633265469196062
# test_discrete_score_W_discrete_a 0.06999955410285325
# neuron unit number: 52
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6596430342092217
# train_discrete_score_W_discrete_n 0.00839661916149338
# train_discrete_score_W_discrete_a 0.010109841830841477
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.030317033166731434
# test_discrete_score_W_discrete_a 0.07804266521984356
# neuron unit number: 55
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0040790712525845445
# test_discrete_score_W0_a 0.006714370013403547
# train_discrete_score_W_discrete_p 0.6606346058502727
# train_discrete_score_W_discrete_n 0.012617212190588586
# train_discrete_score_W_discrete_a 0.014220097842118872
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.02427590534416372
# test_discrete_score_W_discrete_a 0.055315843000476476
# neuron unit number: 58
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.004154003010983101
# test_discrete_score_W0_a 0.00434447575660072
# train_discrete_score_W_discrete_p 0.6606346058502727
# train_discrete_score_W_discrete_n 0.009004200428876665
# train_discrete_score_W_discrete_a 0.011315747223051908
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.012542635821009942
# test_discrete_score_W_discrete_a 0.018704169035921453
# neuron unit number: 61
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6611303916707982
# train_discrete_score_W_discrete_n 0.014274247423800724
# train_discrete_score_W_discrete_a 0.01804463622419663
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.020939399393582254
# test_discrete_score_W_discrete_a 0.03259682571755817
# neuron unit number: 64
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6618740704015865
# train_discrete_score_W_discrete_n 0.016019423748192554
# train_discrete_score_W_discrete_a 0.0188615449997059
# test_discrete_score_W_discrete_p 0.6444613627712219
# test_discrete_score_W_discrete_n 0.0308802111879716
# test_discrete_score_W_discrete_a 0.06416713903879627
# neuron unit number: 67
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6623698562221121
# train_discrete_score_W_discrete_n 0.016385052927203395
# train_discrete_score_W_discrete_a 0.022841772972658367
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.019515724575821083
# test_discrete_score_W_discrete_a 0.031584446462495225
# neuron unit number: 70
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0017229516026716738
# test_discrete_score_W0_a 0.003430837003821535
# train_discrete_score_W_discrete_p 0.6608824987605354
# train_discrete_score_W_discrete_n 0.014826697250196391
# train_discrete_score_W_discrete_a 0.020921293023330928
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.01963913353553542
# test_discrete_score_W_discrete_a 0.041433193182953895
# neuron unit number: 73
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6616261774913238
# train_discrete_score_W_discrete_n 0.01655032220893434
# train_discrete_score_W_discrete_a 0.021215501236103548
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.024358340411973517
# test_discrete_score_W_discrete_a 0.055487229738452354
# neuron unit number: 76
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.005620371099673306
# test_discrete_score_W0_a 0.009603723554592514
# train_discrete_score_W_discrete_p 0.661378284581061
# train_discrete_score_W_discrete_n 0.013247779332193843
# train_discrete_score_W_discrete_a 0.016727102262678237
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.021305425497081424
# test_discrete_score_W_discrete_a 0.050793276284233316
# neuron unit number: 79
# train_discrete_score_W0_p 0.6588993554784334
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.001203008377891334
# test_discrete_score_W0_a 0.0008009622694598731
# train_discrete_score_W_discrete_p 0.6616261774913238
# train_discrete_score_W_discrete_n 0.015135680004368055
# train_discrete_score_W_discrete_a 0.018540739989070975
# test_discrete_score_W_discrete_p 0.6429387133612485
# test_discrete_score_W_discrete_n 0.034218472072210585
# test_discrete_score_W_discrete_a 0.08314586594459236
# test_discrete_score_W0_p mean 0.6365005544429917
# test_discrete_score_W_discrete_p mean 0.6423263434898463
# test_discrete_score_W0_n mean 0.0007295393627740852
# test_discrete_score_W_discrete_n mean 0.02558151066678521
# test_discrete_score_W0_a mean 0.0010823638520816605
# test_discrete_score_W_discrete_a mean 0.05688339606791096
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.012979  0.003884  0.000810   0.011299  0.014658
# 2         combined  46.0  0.006489  0.007101  0.001047   0.004381  0.008598
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0130
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -16.0269
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.7261
# 7                                    Hedge's g =   -4.6451
# 8                                Glass's delta =      -inf
# 9                                  Pearson's r =    0.9240
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.000730  0.001619  0.000338   0.000029  0.001430
# 1  test_dis_W_dis  23.0  0.025582  0.005224  0.001089   0.023322  0.027841
# 2        combined  46.0  0.013156  0.013132  0.001936   0.009256  0.017055
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0249
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -21.7925
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -6.4262
# 7                                  Hedge's g =   -6.3161
# 8                              Glass's delta =  -15.3512
# 9                                Pearson's r =    0.9567
# ARI T-Test
#           Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.00000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.01690  0.005786  0.001206   0.014398  0.019402
# 2         combined  46.0  0.00845  0.009453  0.001394   0.005643  0.011257
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0169
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -14.0084
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.1309
# 7                                    Hedge's g =   -4.0600
# 8                                Glass's delta =      -inf
# 9                                  Pearson's r =    0.9038
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.001082  0.002538  0.000529  -0.000015  0.002180
# 1  test_dis_W_dis  23.0  0.056883  0.015231  0.003176   0.050297  0.063470
# 2        combined  46.0  0.028983  0.030204  0.004453   0.020013  0.037952
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0558
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -17.3309
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -5.1106
# 7                                  Hedge's g =   -5.0230
# 8                              Glass's delta =  -21.9905
# 9                                Pearson's r =    0.9339
# Purity T-Test
#           Variable     N      Mean            SD            SE  95% Conf.  \
# 0     train_dis_W0  23.0  0.658899  3.405525e-16  4.734007e-17   0.658899
# 1  train_dis_W_dis  23.0  0.661044  8.831287e-04  1.841451e-04   0.660662
# 2         combined  46.0  0.659972  1.247760e-03  1.839721e-04   0.659601
#
#    Interval
# 0  0.658899
# 1  0.661426
# 2  0.660342
#                                Independent t-test       results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =  -2.100000e-03
# 1                           Degrees of freedom =   4.400000e+01
# 2                                            t =  -1.164740e+01
# 3                        Two side test p value =   0.000000e+00
# 4                       Difference < 0 p value =   0.000000e+00
# 5                       Difference > 0 p value =   1.000000e+00
# 6                                    Cohen's d =  -3.434600e+00
# 7                                    Hedge's g =  -3.375800e+00
# 8                                Glass's delta =  -6.298038e+12
# 9                                  Pearson's r =   8.690000e-01
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636501  0.000110  0.000023   0.636453  0.636548
# 1  test_dis_W_dis  23.0  0.642326  0.001390  0.000290   0.641725  0.642928
# 2        combined  46.0  0.639413  0.003102  0.000457   0.638492  0.640335
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0058
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -20.0334
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -5.9075
# 7                                  Hedge's g =   -5.8063
# 8                              Glass's delta =  -53.1209
# 9                                Pearson's r =    0.9493
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:47: RuntimeWarning: divide by zero encountered in scalar divide
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2351: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2352: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:26: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_val, p_val = scipy.stats.ttest_ind(group1, group2, nan_policy= 'omit')
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
#onhot encoding vs proposed
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6524541398116014
#  nmi y_true[5 5 5 ... 3 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# 11.86920008834877
# 11.97799536861296
# train_discrete_score_W0_n 0.9162164272785353
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# 11.250515732891433
# 11.359200485133634
# test_discrete_score_W0_n 0.9116493079252818
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6551809618244918
#  nmi y_true[5 5 5 ... 3 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 3 5]
# train_discrete_score_W_discrete_n 0.01510035622235109
# train_discrete_score_W_discrete_a 0.030108037436349478
# test_discrete_score_W_discrete_p 0.6444613627712219
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [0 1 2 3 5]
# test_discrete_score_W_discrete_n 0.03388484817730231
# test_discrete_score_W_discrete_a 0.07812587559762045
# Not good nmi result for discrete features !!!!!
# neuron unit number: 16
# train_discrete_score_W0_p 0.6524541398116014
#  nmi y_true[5 5 5 ... 3 5 5] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# 11.86920008834877
# 11.97799536861296
# train_discrete_score_W0_n 0.9162164272785353
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
#  nmi y_true[5 5 5 ... 5 3 6] unique[0 1 2 3 4 5 6 7] y_pred [5 5 5 ... 5 5 5] unique [5]
# 11.250515732891433
# 11.359200485133634
# test_discrete_score_W0_n 0.9116493079252818
# test_discrete_score_W0_a 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       8 interval = 3
#      11 experiment = experiment.Experiment()
# ---> 12 experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
#
# File C:\JupyterDoc\SOM\experiment.py:306, in Experiment.UTtest_Discrete_Continuous(self, dataread, noralimized, class_num, best_num, neuron_scope_num, unstable_repeat_num, type, interval, test_type, compareType)
#     304 while y <= neuron_scope_num:
#     305     print("neuron unit number: {}".format(y))
# --> 306     self.InitializedExperimentDataList(
#     307                         dataread,
#     308                         noralimized,
#     309                         y,
#     310                         all_train_score_W0_p,
#     311                         all_train_score_W_combine_p,
#     312                         test_score_W0_p,
#     313                         test_score_W_combine_p,
#     314                         all_train_score_W0_n,
#     315                         all_train_score_W_combine_n,
#     316                         test_score_W0_n,
#     317                         test_score_W_combine_n,
#     318                         all_train_score_W0_a,
#     319                         all_train_score_W_combine_a,
#     320                         test_score_W0_a,
#     321                         test_score_W_combine_a,
#     322                         train_discrete_score_W0_p,
#     323                         train_discrete_score_W_discrete_p,
#     324                         test_discrete_score_W0_p,
#     325                         test_discrete_score_W_discrete_p,
#     326                         train_discrete_score_W0_n,
#     327                         train_discrete_score_W_discrete_n,
#     328                         test_discrete_score_W0_n,
#     329                         test_discrete_score_W_discrete_n,
#     330                         train_discrete_score_W0_a,
#     331                         train_discrete_score_W_discrete_a,
#     332                         test_discrete_score_W0_a,
#     333                         test_discrete_score_W_discrete_a,
#     334                         test_type,
#     335                         compareType
#     336                         )
#     337     y =y + interval
#     338     if(y<= neuron_scope_num):
#
# File C:\JupyterDoc\SOM\experiment.py:197, in Experiment.InitializedExperimentDataList(self, dataread, continuous_features_noralimized, y, all_train_score_W0_p, all_train_score_W_combine_p, test_score_W0_p, test_score_W_combine_p, all_train_score_W0_n, all_train_score_W_combine_n, test_score_W0_n, test_score_W_combine_n, all_train_score_W0_a, all_train_score_W_combine_a, test_score_W0_a, test_score_W_combine_a, train_discrete_score_W0_p, train_discrete_score_W_discrete_p, test_discrete_score_W0_p, test_discrete_score_W_discrete_p, train_discrete_score_W0_n, train_discrete_score_W_discrete_n, test_discrete_score_W0_n, test_discrete_score_W_discrete_n, train_discrete_score_W0_a, train_discrete_score_W_discrete_a, test_discrete_score_W0_a, test_discrete_score_W_discrete_a, iscontinous_data_test, compareType)
#     195     optimize_W.do_COSOM(optimize_W.som_discrete_original,optimize_W.data_train_discrete_normalized, optimize_W.data_train_discrete_unnormalized, optimize_W.data_test_discrete_normalized,optimize_W.data_test_discrete_unnormalized,iscontinous_data_test,1)
#     196 if compareType == 3: #discrete unnormalization
# --> 197      optimize_W.do_DOSOM()
#     198 if compareType == 4: # hybrid embedding continous + discrete_embedding
#     199      optimize_W.do_CDOSOM()
#
# File C:\JupyterDoc\SOM\CDSOM.py:1238, in CDSOM.do_DOSOM(self)
#    1234 #print(f"self.training_new_embedding  {self.discrete_data_embedding.shape} " )
#    1235 # new som neuron number is not changed, m,n not change
#    1236 self.som_newEmbedding = newSom.SOM(self.som_discrete_original_encoder.weights0.shape[0] , self.som_discrete_original_encoder.weights0.shape[1],dim)
# -> 1238 self.som_newEmbedding.fit(self.discrete_data_embedding)
#    1239 weight_newEmbedding = self.som_newEmbedding.weights0
#    1241 self.train_W_newembedding_predicted_label = self.som_newEmbedding.predict(self.discrete_data_embedding,weight_newEmbedding)
#
# File C:\JupyterDoc\SOM\newSom.py:368, in SOM.fit(self, X, weightIndex, epochs, shuffle, showlog)
#     363 input = X[idx]
#     365 #if (type(input) is np.float64):
#     366 #    input = [input]
#     367 # Do one step of training
# --> 368 self.step(input,showlog)
#     369 # Update learning rate
#     370 global_iter_counter += 1
#
# File C:\JupyterDoc\SOM\newSom.py:182, in SOM.step(self, x, showlog)
#     173 x_stack = np.stack([x]*(self.m*self.n), axis=0)
#     174 #print("x_stack {}".format(x_stack))
#     175 #print("self.weights{}".format(self.weights));
#     176 #print("x_stack{}".format(x_stack));
#    (...)
#     180 #if showlog == True:
#     181 #    print("x {} {}".format(x, self.weights.shape) )
# --> 182 bmu_index = self._find_bmu(x,self.weights,showlog)
#     184 #print("bmu_index{}".format(bmu_index));
#     185 # Find location of best matching unit, _locations is all the indices for a given matrix for array
#     186 # bmu_location is the bmu_indexth element in _locations, such as if bmu_index = 4 in [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1]] it return [2,0]
#     187 bmu_location = self._locations[bmu_index,:]
#
# File C:\JupyterDoc\SOM\newSom.py:132, in SOM._find_bmu(self, x, newWeights, showlog)
#     126  x_stack = np.stack([x]*(newWeights.shape[0]), axis=0)
#     127  # Calculate distance between x and each weight  ， it use the norm to represent the distance of the concept of vector x_stack - newWeights
#     128 # if showlog:
#     129  #    print("x {} x_stack{}  newWeights {} m {} n{} dim{}".format(x, x_stack, newWeights, self.m,self.n,self.dim))
#     130 # if x_stack.shape != newWeights.shape:
#     131  #    print("x {} x_stack{}  newWeights {} m {} n{} dim{}".format(x, x_stack, newWeights, self.m,self.n,self.dim))
# --> 132  distance = np.linalg.norm((x_stack - newWeights).astype(float), axis=1)
#     133  # Find index of best matching unit
#     134  return np.argmin(distance)
#
# File <__array_function__ internals>:200, in norm(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py:2541, in norm(x, ord, axis, keepdims)
#    2538     return add.reduce(abs(x), axis=axis, keepdims=keepdims)
#    2539 elif ord is None or ord == 2:
#    2540     # special case for speedup
# -> 2541     s = (x.conj() * x).real
#    2542     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2543 # None of the str-type keywords for ord ('fro', 'nuc')
#    2544 # are valid for vectors
#
# KeyboardInterrupt:

# %%
#softmax vs original
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)

# %%
#comparision softmax
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,False,3)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,False,3)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 13
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,0)
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,1)
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True,2)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 13
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,True)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 200
class_num = 4
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
