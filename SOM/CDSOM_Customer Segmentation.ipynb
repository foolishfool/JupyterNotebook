# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/Test.csv")
csv = csv.drop(columns=['ID','Segmentation'])
csv2 = csv2.drop(columns=['ID'])   


dataread.stringToIntCustomerSegmentationDataSet(csv,"Gender")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Ever_Married")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Graduated")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Profession")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Spending_Score")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Var_1")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Family_Size")
dataread.stringToIntCustomerSegmentationDataSet(csv,"Work_Experience")




dataread.stringToIntCustomerSegmentationDataSet(csv2,"Gender")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Ever_Married")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Graduated")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Profession")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Spending_Score")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Var_1")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Family_Size")
dataread.stringToIntCustomerSegmentationDataSet(csv2,"Work_Experience")

csv['Family_Size'] = pd.to_numeric(csv['Family_Size'])
csv2['Family_Size'] = pd.to_numeric(csv2['Family_Size'])
csv['Work_Experience'] = pd.to_numeric(csv['Work_Experience'])
csv2['Work_Experience'] = pd.to_numeric(csv2['Work_Experience'])


csv_training = csv
csv_test = csv2



dataread.initializedataset(csv_training,csv_training,csv_test,"Var_1")
# Out:
# Unkonwn value 4.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 1.0 at Family_Size
# Unkonwn value 2.0 at Family_Size
# Unkonwn value 6.0 at Family_Size
# Unkonwn value 2.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 4.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 4.0 at Family_Size
# Unkonwn value 1.0 at Family_Size
# Unkonwn value 1.0 at Family_Size
# Unkonwn value 2.0 at Family_Size
# Unkonwn value 5.0 at Family_Size
# Unkonwn value 6.0 at Family_Size
# Unkonwn value 4.0 at Family_Size
# Unkonwn value 1.0 at Family_Size
# Unkonwn value 1.0 at Family_Size
# Unkonwn value 4.0 at Family_Size
# Unkonwn value 2.0 at Family_Size
# Unkonwn value 2.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 8.0 at Family_Size
# Unkonwn value 3.0 at Family_Size
# Unkonwn value 1.0 at Family_Size
# ...

# %%
import experiment
unstable_repeat_num= 30
scope_num = 200
class_num = 13
dim_num = 7
best_num = 48
interval = 5


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval)
# Out:
# neuron unit number: 13
#  nmi y_true[7 7 7 ... 7 7 7] unique[1 2 3 4 5 6 7 8] y_pred [7 7 7 ... 7 7 7] unique [7]
# train_discrete_score_W0_n 0.0
#  nmi y_true[7 7 7 ... 7 7 7] unique[1 2 3 4 5 6 7 8] y_pred [7 7 7 ... 7 7 7] unique [7]
# train_discrete_score_W0_a  0.0
#  nmi y_true[7 7 7 ... 7 5 8] unique[1 2 3 4 5 6 7 8] y_pred [7 7 7 ... 7 7 7] unique [7]
# test_discrete_score_W0_n 0.0
#  nmi y_true[7 7 7 ... 7 5 8] unique[1 2 3 4 5 6 7 8] y_pred [7 7 7 ... 7 7 7] unique [7]
# test_discrete_score_W0 0.0
# C:\JupyterDoc\SOM\CDSOM.py:707: RuntimeWarning: divide by zero encountered in divide
#   current_row[i] = current_row[i] /denominator2
# C:\JupyterDoc\SOM\CDSOM.py:707: RuntimeWarning: invalid value encountered in divide
#   current_row[i] = current_row[i] /denominator2
#  labels [1 1 1 ... 1 1 0]
# predicted_clusters_indexes [1 1 1 ... 1 1 0]
#  nmi y_true[7 7 7 ... 7 7 7] unique[1 2 3 4 5 6 7 8] y_pred [7 7 7 ... 7 7 7] unique [7]
# train_discrete_score_W_discrete_n 0.0
# ...

# %%
import experiment
unstable_repeat_num= 30
scope_num = 200
class_num = 100
row = 8
column = 4
dim_num = 7
best_num = 48


experiment = experiment.Experiment()

experiment.UTest_FESOM(dataread,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,row,column)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 200
class_num = 8
row = 8
column = 4
dim_num = 7
best_num = 48


experiment = experiment.Experiment()

experiment.UTest_FESOM(dataread,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,row,column)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 14
row = 8
column = 4
dim_num = 32
best_num = 48


experiment = experiment.Experiment()

experiment.UTest_FESOM(dataread,class_num, dim_num,best_num, scope_num,unstable_repeat_num,1,row,column)

# %%
unstable_repeat_num= 30
scope_num = 62
class_num = 13
dim_num = 32

best_num = 48

elbow_num = 1
row = 8
column = 4
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )   

experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)

# %%
unstable_repeat_num= 30
scope_num = 62
class_num = 13
dim_num = 32

best_num = 48

elbow_num = 1
row = 8
column = 4
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
optimize_W.run( )   

#experiment = experiment.Experiment()
#experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
#print("*****************************************************************************************")
#print("Best Number SOM Comparision")
#print("*****************************************************************************************")
#experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
