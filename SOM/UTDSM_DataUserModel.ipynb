# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import experiment
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Data_User_Modeling_Dataset_Hamdi Tolga KAHRAMAN.csv")
dataread.stringToIntDataUserModelDataSet(csv," UNS")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test," UNS")

# %%
unstable_repeat_num= 30
scope_num = 34
class_num = 4
dim_num = 5
best_num =18

total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     


experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1)
# Out:
# neuron unit number: 4
# all_train_score_W0_n 0.12373655130197399
# all_train_score_W0_a 0.07487686649599085
# test_score_W0_n 0.1341706011952792
# test_score_W0_a  0.05067620552787463
# Split one time!
# self.rest_data_W0_p 0.5897435897435898
# self.rest_data_W0_n 0.12415765053843454
# self.rest_data_W0_a 0.09052268811028144
# Split one time!
# self.rest_data_W0_p 0.6666666666666666
# self.rest_data_W0_n 0.20501156779521476
# self.rest_data_W0_a 0.17336646689080543
# Split one time!
# self.rest_data_W0_p 0.5555555555555556
# self.rest_data_W0_n 0.40632508240721305
# self.rest_data_W0_a 0.10819672131147541
# Split one time!
# self.rest_data_W0_p 0.75
# self.rest_data_W0_n 0.6598106590064562
# self.rest_data_W0_a 0.3717948717948718
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.8571428571428571
# self.rest_data_W0_n 0.8579917415317729
# self.rest_data_W0_a 0.9049773755656109
# Split one time!
# self.rest_data_W0_p 0.8333333333333334
# self.rest_data_W0_n 0.6836398690443692
# self.rest_data_W0_a 0.5
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.75
# self.rest_data_W0_n 0.0
# self.rest_data_W0_a 0.0
# Split one time!
# self.rest_data_W0_p 0.6
# self.rest_data_W0_n 0.4743509876140318
# self.rest_data_W0_a -0.25
# Split one time!
# self.rest_data_W0_p 0.7142857142857143
# self.rest_data_W0_n 0.47659894423590704
# self.rest_data_W0_a 0.07692307692307693
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.3420256024483556
# all_train_score_W_Combined_a 0.3093603848944987
# test_score_W_combined_n 0.2605056163131844
# test_score_W_combined_a 0.18656111874635997
# Combine Neurons Number :46
# neuron unit number: 5
# all_train_score_W0_n 0.20031922834107435
# all_train_score_W0_a 0.16158886990020432
# test_score_W0_n 0.31223073544317903
# test_score_W0_a  0.2999842294814289
# Split one time!
# self.rest_data_W0_p 0.5714285714285714
# self.rest_data_W0_n 0.16753523159706288
# self.rest_data_W0_a 0.141842279497289
# Split one time!
# self.rest_data_W0_p 0.6
# self.rest_data_W0_n 0.4288079958751877
# self.rest_data_W0_a 0.31286101614994694
# Split one time!
# self.rest_data_W0_p 0.6875
# self.rest_data_W0_n 0.5343362092396602
# self.rest_data_W0_a 0.3717277486910995
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.8571428571428571
# self.rest_data_W0_n 0.7447395504214406
# self.rest_data_W0_a 0.5384615384615384
# Split one time!
# self.rest_data_W0_p 0.8333333333333334
# self.rest_data_W0_n 0.47870397138568005
# self.rest_data_W0_a 0.32432432432432434
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2963846518736726
# all_train_score_W_Combined_a 0.28867393552327275
# test_score_W_combined_n 0.23077552687418504
# test_score_W_combined_a 0.15996739276354416
# Combine Neurons Number :35
# neuron unit number: 6
# all_train_score_W0_n 0.2730331318826367
# all_train_score_W0_a 0.20805339377568588
# test_score_W0_n 0.2125728418889736
# test_score_W0_a  0.11469686141385266
# Split one time!
# self.rest_data_W0_p 0.7227722772277227
# self.rest_data_W0_n 0.47615365233507
# self.rest_data_W0_a 0.393318780009486
# Split one time!
# self.rest_data_W0_p 0.8235294117647058
# self.rest_data_W0_n 0.6185519537053649
# self.rest_data_W0_a 0.5372669482486454
# Split one time!
# self.rest_data_W0_p 0.7692307692307693
# self.rest_data_W0_n 0.7055006723864707
# self.rest_data_W0_a 0.4743935309973046
# Split one time!
# self.rest_data_W0_p 0.8333333333333334
# self.rest_data_W0_n 0.6853314789615866
# self.rest_data_W0_a 0.3181818181818182
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.9
# self.rest_data_W0_n 0.8458724127102427
# self.rest_data_W0_a 0.6376811594202898
# all_train_score_W_Combined_n 0.5347572570924338
# all_train_score_W_Combined_a 0.49968708771647763
# test_score_W_combined_n 0.5293963638614929
# test_score_W_combined_a 0.44463040106224333
# Combine Neurons Number :52
# neuron unit number: 7
# all_train_score_W0_n 0.12610591829796083
# all_train_score_W0_a 0.07784218152070242
# test_score_W0_n 0.12884856612421797
# test_score_W0_a  0.10327835815559037
# Split one time!
# self.rest_data_W0_p 0.5204081632653061
# self.rest_data_W0_n 0.1785066772996115
# self.rest_data_W0_a 0.08719234151689724
# Split one time!
# self.rest_data_W0_p 0.6511627906976745
# self.rest_data_W0_n 0.584861182755702
# self.rest_data_W0_a 0.455657273637534
# Split one time!
# self.rest_data_W0_p 0.7692307692307693
# self.rest_data_W0_n 0.6877250964842807
# self.rest_data_W0_a 0.457002457002457
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.35229599120032706
# all_train_score_W_Combined_a 0.2603983695115939
# test_score_W_combined_n 0.27748593701339286
# test_score_W_combined_a 0.20556605694012273
# Combine Neurons Number :36
# neuron unit number: 8
# all_train_score_W0_n 0.2596141937255833
# all_train_score_W0_a 0.2247270517370155
# test_score_W0_n 0.3124998272973077
# test_score_W0_a  0.26384788518312824
# Split one time!
# self.rest_data_W0_p 0.631578947368421
# self.rest_data_W0_n 0.32336341391922113
# self.rest_data_W0_a 0.2910016294780713
# Split one time!
# self.rest_data_W0_p 0.7741935483870968
# self.rest_data_W0_n 0.5919959470006746
# self.rest_data_W0_a 0.5139985323222664
# Split one time!
# self.rest_data_W0_p 0.8461538461538461
# self.rest_data_W0_n 0.6180770135452178
# self.rest_data_W0_a 0.5226781857451404
# Split one time!
# self.rest_data_W0_p 0.8888888888888888
# self.rest_data_W0_n 0.7837391668505189
# self.rest_data_W0_a 0.6830985915492958
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.4018616567025572
# all_train_score_W_Combined_a 0.3695858871648272
# test_score_W_combined_n 0.37138885661608234
# test_score_W_combined_a 0.265330908246916
# Combine Neurons Number :52
# neuron unit number: 9
# all_train_score_W0_n 0.23235483262432724
# all_train_score_W0_a 0.15958321892749275
# test_score_W0_n 0.194577243289825
# test_score_W0_a  0.12164556045851868
# Split one time!
# self.rest_data_W0_p 0.5948275862068966
# self.rest_data_W0_n 0.2510489293333599
# self.rest_data_W0_a 0.19557115108182008
# Split one time!
# self.rest_data_W0_p 0.7
# self.rest_data_W0_n 0.40582031903988175
# self.rest_data_W0_a 0.3301792535997649
# Split one time!
# self.rest_data_W0_p 0.8666666666666667
# self.rest_data_W0_n 0.5679883825994245
# self.rest_data_W0_a 0.5273818454613654
# Split one time!
# self.rest_data_W0_p 0.8888888888888888
# self.rest_data_W0_n 0.8317106220795075
# self.rest_data_W0_a 0.7692307692307693
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.3379223967642051
# all_train_score_W_Combined_a 0.2979830146125096
# test_score_W_combined_n 0.23634209494108632
# test_score_W_combined_a 0.16551868108000967
# Combine Neurons Number :41
# neuron unit number: 10
# all_train_score_W0_n 0.39162129653227307
# all_train_score_W0_a 0.335379357865713
# test_score_W0_n 0.37537446512933803
# test_score_W0_a  0.24100131694392665
# Split one time!
# self.rest_data_W0_p 0.7301587301587301
# self.rest_data_W0_n 0.4563010328767751
# self.rest_data_W0_a 0.4097348862351735
# Split one time!
# self.rest_data_W0_p 0.8620689655172413
# self.rest_data_W0_n 0.6345280293226173
# self.rest_data_W0_a 0.5647279549718575
# Split one time!
# self.rest_data_W0_p 0.9285714285714286
# self.rest_data_W0_n 0.9172991675608994
# self.rest_data_W0_a 0.9461538461538461
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5070408786015798
# all_train_score_W_Combined_a 0.5040359594536086
# test_score_W_combined_n 0.33814778778683885
# test_score_W_combined_a 0.226281583841251
# Combine Neurons Number :64
# neuron unit number: 11
# all_train_score_W0_n 0.2885005883289448
# all_train_score_W0_a 0.18446072099177474
# test_score_W0_n 0.26145517504899507
# test_score_W0_a  0.15029776379927154
# Split one time!
# self.rest_data_W0_p 0.6868686868686869
# self.rest_data_W0_n 0.3954402737196803
# self.rest_data_W0_a 0.34414069944964365
# Split one time!
# self.rest_data_W0_p 0.6176470588235294
# self.rest_data_W0_n 0.39348748943972556
# self.rest_data_W0_a 0.24043267928891882
# Split one time!
# self.rest_data_W0_p 0.8666666666666667
# self.rest_data_W0_n 0.739596579520434
# self.rest_data_W0_a 0.6391752577319587
# Split one time!
# self.rest_data_W0_p 0.9090909090909091
# self.rest_data_W0_n 0.7997629655363263
# self.rest_data_W0_a 0.6857142857142857
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 0.7272727272727273
# self.rest_data_W0_n 0.6250318557192439
# self.rest_data_W0_a 0.3188854489164087
# all_train_score_W_Combined_n 0.4522883457754294
# all_train_score_W_Combined_a 0.4022508120973321
# test_score_W_combined_n 0.4241247046790803
# test_score_W_combined_a 0.3066473240893807
# Combine Neurons Number :52
# neuron unit number: 12
# all_train_score_W0_n 0.372259348399801
# all_train_score_W0_a 0.35179911789005036
# test_score_W0_n 0.3369107411264457
# test_score_W0_a  0.21243288029190102
# Split one time!
# self.rest_data_W0_p 0.7096774193548387
# self.rest_data_W0_n 0.3990348141584986
# self.rest_data_W0_a 0.3795572298476696
# Split one time!
# self.rest_data_W0_p 0.9166666666666666
# self.rest_data_W0_n 0.7742409648443337
# self.rest_data_W0_a 0.7840867632914331
# Split one time!
# self.rest_data_W0_p 0.9444444444444444
# self.rest_data_W0_n 0.9070190463350578
# self.rest_data_W0_a 0.8930817610062893
# all_train_score_W_Combined_n 0.48826166066797744
# all_train_score_W_Combined_a 0.5086294775661376
# test_score_W_combined_n 0.40023603212024944
# test_score_W_combined_a 0.2929020772941049
# Combine Neurons Number :76
# neuron unit number: 13
# all_train_score_W0_n 0.2645781051428807
# all_train_score_W0_a 0.21901222797453992
# test_score_W0_n 0.2675694944969783
# test_score_W0_a  0.2575377396925343
# Split one time!
# self.rest_data_W0_p 0.6206896551724138
# self.rest_data_W0_n 0.2773399428853044
# self.rest_data_W0_a 0.2550621876349898
# Split one time!
# self.rest_data_W0_p 0.6857142857142857
# self.rest_data_W0_n 0.45621043343965684
# self.rest_data_W0_a 0.2687361419068736
# Split one time!
# self.rest_data_W0_p 0.85
# self.rest_data_W0_n 0.6134736920703943
# self.rest_data_W0_a 0.5510927347903131
# Split one time!
# self.rest_data_W0_p 0.7142857142857143
# self.rest_data_W0_n 0.5636355530993447
# self.rest_data_W0_a 0.2125
# all_train_score_W_Combined_n 0.35438000710095
# all_train_score_W_Combined_a 0.3059071088968271
# test_score_W_combined_n 0.26003436336458957
# test_score_W_combined_a 0.15314657153955533
# Combine Neurons Number :42
# neuron unit number: 14
# all_train_score_W0_n 0.3976034367384379
# all_train_score_W0_a 0.3808588163097781
# test_score_W0_n 0.3198860204669226
# test_score_W0_a  0.22626829459141037
# Split one time!
# self.rest_data_W0_p 0.7829457364341085
# self.rest_data_W0_n 0.5269595081534529
# self.rest_data_W0_a 0.5037604393341111
# Split one time!
# self.rest_data_W0_p 0.9375
# self.rest_data_W0_n 0.8539837639978899
# self.rest_data_W0_a 0.8567164179104477
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5990836026796423
# all_train_score_W_Combined_a 0.610393567850143
# test_score_W_combined_n 0.39744863949062365
# test_score_W_combined_a 0.30178787319546085
# Combine Neurons Number :88
# neuron unit number: 15
# all_train_score_W0_n 0.23953324547679639
# all_train_score_W0_a 0.18657061176517808
# test_score_W0_n 0.17541717216413966
# test_score_W0_a  0.13330233338161196
# Split one time!
# self.rest_data_W0_p 0.6018518518518519
# self.rest_data_W0_n 0.22749802671504385
# self.rest_data_W0_a 0.18142575242633216
# Split one time!
# self.rest_data_W0_p 0.7096774193548387
# self.rest_data_W0_n 0.4878743645254373
# self.rest_data_W0_a 0.37258253125843305
# Split one time!
# self.rest_data_W0_p 0.8148148148148148
# self.rest_data_W0_n 0.6745126460583438
# self.rest_data_W0_a 0.5219204903379586
# Split one time!
# self.rest_data_W0_p 0.9166666666666666
# self.rest_data_W0_n 0.8447914757396762
# self.rest_data_W0_a 0.7049808429118773
# all_train_score_W_Combined_n 0.35666826643969907
# all_train_score_W_Combined_a 0.3092452070031289
# test_score_W_combined_n 0.23769207317175853
# test_score_W_combined_a 0.17942362167327253
# Combine Neurons Number :55
# neuron unit number: 16
# all_train_score_W0_n 0.4867745777325249
# all_train_score_W0_a 0.48585358493683745
# test_score_W0_n 0.32447332858324385
# test_score_W0_a  0.2941622441243366
# Split one time!
# self.rest_data_W0_p 0.7819548872180451
# self.rest_data_W0_n 0.5339315581079579
# self.rest_data_W0_a 0.5117588501570224
# Split one time!
# self.rest_data_W0_p 0.95
# self.rest_data_W0_n 0.8693187509639276
# self.rest_data_W0_a 0.8596911028931912
# all_train_score_W_Combined_n 0.6002486591603763
# all_train_score_W_Combined_a 0.5985426146146487
# test_score_W_combined_n 0.35364649900250134
# test_score_W_combined_a 0.2859067604145237
# Combine Neurons Number :88
# neuron unit number: 17
# all_train_score_W0_n 0.25256031711604
# all_train_score_W0_a 0.21945438318841956
# test_score_W0_n 0.22314347087170247
# test_score_W0_a  0.1455592487630401
# Split one time!
# self.rest_data_W0_p 0.65
# self.rest_data_W0_n 0.3314022677637726
# self.rest_data_W0_a 0.2732416572809511
# Split one time!
# self.rest_data_W0_p 0.9032258064516129
# self.rest_data_W0_n 0.7254074598313106
# self.rest_data_W0_a 0.6967340590979783
# Split one time!
# self.rest_data_W0_p 0.9230769230769231
# self.rest_data_W0_n 0.792969026945973
# self.rest_data_W0_a 0.7169811320754716
# Split one time!
# self.rest_data_W0_p 0.8571428571428571
# self.rest_data_W0_n 0.7332088370806865
# self.rest_data_W0_a 0.580368906455863
# all_train_score_W_Combined_n 0.42711781470783444
# all_train_score_W_Combined_a 0.40731268152472433
# test_score_W_combined_n 0.27255942745177825
# test_score_W_combined_a 0.23509545507613225
# Combine Neurons Number :54
# neuron unit number: 18
# all_train_score_W0_n 0.5496405896737009
# all_train_score_W0_a 0.5507801965899382
# test_score_W0_n 0.4288335502179277
# test_score_W0_a  0.32199542982355034
# Split one time!
# self.rest_data_W0_p 0.8181818181818182
# self.rest_data_W0_n 0.5821136507160312
# self.rest_data_W0_a 0.5764502744371944
# Split one time!
# self.rest_data_W0_p 0.9487179487179487
# self.rest_data_W0_n 0.8599459463075544
# self.rest_data_W0_a 0.8567164931985943
# all_train_score_W_Combined_n 0.6377015191243652
# all_train_score_W_Combined_a 0.6565701170145815
# test_score_W_combined_n 0.42860229228216284
# test_score_W_combined_a 0.3072518964640077
# Combine Neurons Number :108
# neuron unit number: 19
# all_train_score_W0_n 0.3112010627659958
# all_train_score_W0_a 0.24110766050683838
# test_score_W0_n 0.351008637101673
# test_score_W0_a  0.2331438506856591
# Split one time!
# self.rest_data_W0_p 0.6551724137931034
# self.rest_data_W0_n 0.37761838711645984
# self.rest_data_W0_a 0.32143140641990775
# Split one time!
# self.rest_data_W0_p 0.7073170731707317
# self.rest_data_W0_n 0.3603679984423402
# self.rest_data_W0_a 0.2707777523693371
# Split one time!
# self.rest_data_W0_p 0.8333333333333334
# self.rest_data_W0_n 0.6853062643182042
# self.rest_data_W0_a 0.5941644562334217
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.4277515850812999
# all_train_score_W_Combined_a 0.3675258225179417
# test_score_W_combined_n 0.2744326202069382
# test_score_W_combined_a 0.16310408248975394
# Combine Neurons Number :51
# neuron unit number: 20
# all_train_score_W0_n 0.5277446172756051
# all_train_score_W0_a 0.5240564121538928
# test_score_W0_n 0.34927880049564053
# test_score_W0_a  0.28136921979256585
# Split one time!
# self.rest_data_W0_p 0.8345323741007195
# self.rest_data_W0_n 0.6093969598584643
# self.rest_data_W0_a 0.5957938605011556
# Split one time!
# self.rest_data_W0_p 0.8571428571428571
# self.rest_data_W0_n 0.7208273086616986
# self.rest_data_W0_a 0.5939849624060151
# all_train_score_W_Combined_n 0.6431060267301228
# all_train_score_W_Combined_a 0.6357148940853719
# test_score_W_combined_n 0.4607113966927203
# test_score_W_combined_a 0.3911734659917986
# Combine Neurons Number :105
# neuron unit number: 21
# all_train_score_W0_n 0.34919972561865
# all_train_score_W0_a 0.28759248415578476
# test_score_W0_n 0.2926840318730609
# test_score_W0_a  0.2133891309941237
# Split one time!
# self.rest_data_W0_p 0.680672268907563
# self.rest_data_W0_n 0.3556970411801765
# self.rest_data_W0_a 0.3088945375139615
# Split one time!
# self.rest_data_W0_p 0.8108108108108109
# self.rest_data_W0_n 0.6412011402092946
# self.rest_data_W0_a 0.5420238306953583
# Split one time!
# self.rest_data_W0_p 0.875
# self.rest_data_W0_n 0.7790915168588379
# self.rest_data_W0_a 0.6816976127320955
# all_train_score_W_Combined_n 0.44633105086329633
# all_train_score_W_Combined_a 0.41748086568024045
# test_score_W_combined_n 0.34860088535576145
# test_score_W_combined_a 0.28550997214612267
# Combine Neurons Number :58
# neuron unit number: 22
# all_train_score_W0_n 0.6423510025097457
# all_train_score_W0_a 0.6720983719966804
# test_score_W0_n 0.30928489310522206
# test_score_W0_a  0.1765358279189654
# Split one time!
# self.rest_data_W0_p 0.8633093525179856
# self.rest_data_W0_n 0.6437088395136153
# self.rest_data_W0_a 0.6539929494887691
# Split one time!
# self.rest_data_W0_p 0.9736842105263158
# self.rest_data_W0_n 0.9423229370257681
# self.rest_data_W0_a 0.9515498841629247
# all_train_score_W_Combined_n 0.6989215602796603
# all_train_score_W_Combined_a 0.7174467874222563
# test_score_W_combined_n 0.4240983183612215
# test_score_W_combined_a 0.3333558569094535
# Combine Neurons Number :123
# neuron unit number: 23
# all_train_score_W0_n 0.44510720667162423
# all_train_score_W0_a 0.33863686200324167
# test_score_W0_n 0.3620440545371476
# test_score_W0_a  0.25740345190160113
# Split one time!
# self.rest_data_W0_p 0.672
# self.rest_data_W0_n 0.4501696985164245
# self.rest_data_W0_a 0.35230747345305424
# Split one time!
# self.rest_data_W0_p 0.9
# self.rest_data_W0_n 0.8071535619162493
# self.rest_data_W0_a 0.7759056127256964
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5298905224550838
# all_train_score_W_Combined_a 0.4686157543012842
# test_score_W_combined_n 0.46688430416344295
# test_score_W_combined_a 0.3963252103145574
# Combine Neurons Number :64
# neuron unit number: 24
# all_train_score_W0_n 0.6965509628829669
# all_train_score_W0_a 0.6898321375494981
# test_score_W0_n 0.3545359803624063
# test_score_W0_a  0.26535928189484553
# Split one time!
# self.rest_data_W0_p 0.9324324324324325
# self.rest_data_W0_n 0.8066048559182732
# self.rest_data_W0_a 0.821732070530833
# Split one time!
# self.rest_data_W0_p 0.9655172413793104
# self.rest_data_W0_n 0.9116535928729138
# self.rest_data_W0_a 0.9036759985485807
# all_train_score_W_Combined_n 0.8211719344340396
# all_train_score_W_Combined_a 0.84500465982293
# test_score_W_combined_n 0.512144880969217
# test_score_W_combined_a 0.44428666168108255
# Combine Neurons Number :134
# neuron unit number: 25
# all_train_score_W0_n 0.3185984893365192
# all_train_score_W0_a 0.29382814548915626
# test_score_W0_n 0.4064192636619272
# test_score_W0_a  0.3119693829457492
# Split one time!
# self.rest_data_W0_p 0.6825396825396826
# self.rest_data_W0_n 0.3669962040702822
# self.rest_data_W0_a 0.34608784777619134
# Split one time!
# self.rest_data_W0_p 0.8484848484848485
# self.rest_data_W0_n 0.7134314561296446
# self.rest_data_W0_a 0.6183941718382608
# Split one time!
# self.rest_data_W0_p 0.9
# self.rest_data_W0_n 0.7993458674975206
# self.rest_data_W0_a 0.7797810688989053
# all_train_score_W_Combined_n 0.4404546042014566
# all_train_score_W_Combined_a 0.435561326290724
# test_score_W_combined_n 0.28481110379254854
# test_score_W_combined_a 0.16436032275386017
# Combine Neurons Number :60
# neuron unit number: 26
# all_train_score_W0_n 0.7169944846136772
# all_train_score_W0_a 0.6968870983822916
# test_score_W0_n 0.3959187533349535
# test_score_W0_a  0.27377323321869546
# Split one time!
# self.rest_data_W0_p 0.9054054054054054
# self.rest_data_W0_n 0.7415023953342724
# self.rest_data_W0_a 0.7489136399920701
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7755759330406711
# all_train_score_W_Combined_a 0.7940187223995614
# test_score_W_combined_n 0.5095493258144888
# test_score_W_combined_a 0.5000982086509618
# Combine Neurons Number :129
# neuron unit number: 27
# all_train_score_W0_n 0.42799495892930517
# all_train_score_W0_a 0.4000942552479623
# test_score_W0_n 0.19739195893901199
# test_score_W0_a  0.0984401375226659
# Split one time!
# self.rest_data_W0_p 0.7560975609756098
# self.rest_data_W0_n 0.4536176164341765
# self.rest_data_W0_a 0.44730786263705774
# Split one time!
# self.rest_data_W0_p 0.8857142857142857
# self.rest_data_W0_n 0.7406977751387824
# self.rest_data_W0_a 0.6402234636871509
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8982822328416145
# self.rest_data_W0_a 0.8446475195822454
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5464093463168451
# all_train_score_W_Combined_a 0.5524362432843178
# test_score_W_combined_n 0.3169460969817144
# test_score_W_combined_a 0.2317798162659197
# Combine Neurons Number :71
# neuron unit number: 28
# all_train_score_W0_n 0.726262175522489
# all_train_score_W0_a 0.7166040727846066
# test_score_W0_n 0.34910588910288315
# test_score_W0_a  0.21920386538992567
# Split one time!
# self.rest_data_W0_p 0.8940397350993378
# self.rest_data_W0_n 0.7600487484550811
# self.rest_data_W0_a 0.7410088924482089
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7851001896367164
# all_train_score_W_Combined_a 0.7826715698248943
# test_score_W_combined_n 0.4573803685009507
# test_score_W_combined_a 0.351368139357827
# Combine Neurons Number :129
# neuron unit number: 29
# all_train_score_W0_n 0.4563415055032715
# all_train_score_W0_a 0.4349050721377587
# test_score_W0_n 0.40885432296545476
# test_score_W0_a  0.3478466884870397
# Split one time!
# self.rest_data_W0_p 0.7777777777777778
# self.rest_data_W0_n 0.5097321682299893
# self.rest_data_W0_a 0.5116315881982302
# Split one time!
# self.rest_data_W0_p 0.8064516129032258
# self.rest_data_W0_n 0.6585223511563162
# self.rest_data_W0_a 0.539073305670816
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5591723482934376
# all_train_score_W_Combined_a 0.5655940139270819
# test_score_W_combined_n 0.36467148935249916
# test_score_W_combined_a 0.3112207520202792
# Combine Neurons Number :69
# neuron unit number: 30
# all_train_score_W0_n 0.6654064860879665
# all_train_score_W0_a 0.6680896752298178
# test_score_W0_n 0.3113301345098454
# test_score_W0_a  0.15314912280191445
# Split one time!
# self.rest_data_W0_p 0.8831168831168831
# self.rest_data_W0_n 0.7239369039071939
# self.rest_data_W0_a 0.6969480174921779
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7496574697065321
# all_train_score_W_Combined_a 0.7387379671370665
# test_score_W_combined_n 0.4540896509780366
# test_score_W_combined_a 0.37241026218528567
# Combine Neurons Number :138
# neuron unit number: 31
# all_train_score_W0_n 0.4763325333027204
# all_train_score_W0_a 0.43070486339402847
# test_score_W0_n 0.36300498239783396
# test_score_W0_a  0.29087303646567686
# Split one time!
# self.rest_data_W0_p 0.7857142857142857
# self.rest_data_W0_n 0.5406934945028173
# self.rest_data_W0_a 0.5177630897944246
# Split one time!
# self.rest_data_W0_p 0.7894736842105263
# self.rest_data_W0_n 0.5972935471827947
# self.rest_data_W0_a 0.4939365413367296
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5586034007648233
# all_train_score_W_Combined_a 0.5524227773541768
# test_score_W_combined_n 0.4256023607768831
# test_score_W_combined_a 0.320971063233631
# Combine Neurons Number :70
# neuron unit number: 32
# all_train_score_W0_n 0.7789579944157349
# all_train_score_W0_a 0.8159089836353276
# test_score_W0_n 0.3449644647523252
# test_score_W0_a  0.2240342624307886
# Split one time!
# self.rest_data_W0_p 0.9342105263157895
# self.rest_data_W0_n 0.8104832611712122
# self.rest_data_W0_a 0.8321167511677903
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8344687767549299
# all_train_score_W_Combined_a 0.8600619568548281
# test_score_W_combined_n 0.4825555489959006
# test_score_W_combined_a 0.42184342607558845
# Combine Neurons Number :142
# neuron unit number: 33
# all_train_score_W0_n 0.42308880317198094
# all_train_score_W0_a 0.3885853629540368
# test_score_W0_n 0.4047842100331554
# test_score_W0_a  0.317207752694451
# Split one time!
# self.rest_data_W0_p 0.7637795275590551
# self.rest_data_W0_n 0.5385077884674966
# self.rest_data_W0_a 0.46966381225744136
# Split one time!
# self.rest_data_W0_p 0.8333333333333334
# self.rest_data_W0_n 0.6559987077817635
# self.rest_data_W0_a 0.5323266383228266
# Split one time!
# self.rest_data_W0_p 0.9473684210526315
# self.rest_data_W0_n 0.9005621505361942
# self.rest_data_W0_a 0.849221122758891
# all_train_score_W_Combined_n 0.5711124696421582
# all_train_score_W_Combined_a 0.5296378981793926
# test_score_W_combined_n 0.4450260202724839
# test_score_W_combined_a 0.3317020113601212
# Combine Neurons Number :74
# neuron unit number: 34
# all_train_score_W0_n 0.7298223959395829
# all_train_score_W0_a 0.7519626937595374
# test_score_W0_n 0.2864039197986071
# test_score_W0_a  0.15074917216698383
# Split one time!
# self.rest_data_W0_p 0.9415584415584416
# self.rest_data_W0_n 0.8091874249074528
# self.rest_data_W0_a 0.84216922524019
# all_train_score_W_Combined_n 0.8189174295154438
# all_train_score_W_Combined_a 0.8480907183916422
# test_score_W_combined_n 0.4307474229645615
# test_score_W_combined_a 0.33757507537781073
# Combine Neurons Number :146
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.306290  0.081204  0.014585   0.276504  0.336076
# 1  test_score_W'  31.0  0.376666  0.091275  0.016393   0.343186  0.410146
# 2       combined  62.0  0.341478  0.092729  0.011777   0.317929  0.365027
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0704
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -3.2074
# 3                       Two side test p value =    0.0021
# 4                      Difference < 0 p value =    0.0011
# 5                      Difference > 0 p value =    0.9989
# 6                                   Cohen's d =   -0.8147
# 7                                   Hedge's g =   -0.8044
# 8                               Glass's delta =   -0.8667
# 9                                 Pearson's r =    0.3826
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.306290  0.081204  0.014585   0.276504  0.336076
# 1  test_score_W'  31.0  0.292681  0.095449  0.017143   0.257670  0.327692
# 2       combined  62.0  0.299485  0.088151  0.011195   0.277099  0.321871
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0136
# 1                          Degrees of freedom =   60.0000
# 2                                           t =    0.6046
# 3                       Two side test p value =    0.5477
# 4                      Difference < 0 p value =    0.7261
# 5                      Difference > 0 p value =    0.2739
# 6                                   Cohen's d =    0.1536
# 7                                   Hedge's g =    0.1516
# 8                               Glass's delta =    0.1676
# 9                                 Pearson's r =    0.0778
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.5662496723629069
# all_train_score_W0_a 0.5562429848189427
# test_score_W0_n 0.4803899743214545
# test_score_W0_a  0.4304188031896603
# Split one time!
# self.rest_data_W0_p 0.8175182481751825
# self.rest_data_W0_n 0.6186177919194243
# self.rest_data_W0_a 0.601911346084715
# Split one time!
# self.rest_data_W0_p 0.96875
# self.rest_data_W0_n 0.923941561626249
# self.rest_data_W0_a 0.9193282777969789
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6778212190444761
# all_train_score_W_Combined_a 0.672316373126598
# test_score_W_combined_n 0.47054011501111703
# test_score_W_combined_a 0.3834302842482282
# Combine Neurons Number :108
# all_train_score_W0_n 0.5059030594392282
# all_train_score_W0_a 0.4563697361467419
# test_score_W0_n 0.3151673077754017
# test_score_W0_a  0.17770195858256493
# Split one time!
# self.rest_data_W0_p 0.8014705882352942
# self.rest_data_W0_n 0.5939796740340769
# self.rest_data_W0_a 0.5526715601224086
# Split one time!
# self.rest_data_W0_p 0.9473684210526315
# self.rest_data_W0_n 0.8545034387574824
# self.rest_data_W0_a 0.8526097662059046
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6388403095950516
# all_train_score_W_Combined_a 0.6224899370010942
# test_score_W_combined_n 0.4339256002659496
# test_score_W_combined_a 0.36920001780914685
# Combine Neurons Number :100
# all_train_score_W0_n 0.5462372948274145
# all_train_score_W0_a 0.5335235986784843
# test_score_W0_n 0.5091017586602554
# test_score_W0_a  0.390521064137307
# Split one time!
# self.rest_data_W0_p 0.8235294117647058
# self.rest_data_W0_n 0.6096634238405517
# self.rest_data_W0_a 0.5938326300367586
# Split one time!
# self.rest_data_W0_p 0.9714285714285714
# self.rest_data_W0_n 0.9428450151510978
# self.rest_data_W0_a 0.9583828775267539
# all_train_score_W_Combined_n 0.6711209048655252
# all_train_score_W_Combined_a 0.6766228160895457
# test_score_W_combined_n 0.4483609656824972
# test_score_W_combined_a 0.3883253524725855
# Combine Neurons Number :103
# all_train_score_W0_n 0.5157526583333585
# all_train_score_W0_a 0.5019171786211882
# test_score_W0_n 0.3533384739420143
# test_score_W0_a  0.2508595254931604
# Split one time!
# self.rest_data_W0_p 0.8
# self.rest_data_W0_n 0.5573326208429056
# self.rest_data_W0_a 0.5316657789776685
# Split one time!
# self.rest_data_W0_p 0.9512195121951219
# self.rest_data_W0_n 0.8918161607760428
# self.rest_data_W0_a 0.8602807719376226
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6277079360951506
# all_train_score_W_Combined_a 0.6173636420468691
# test_score_W_combined_n 0.40052043787737035
# test_score_W_combined_a 0.2905045641421439
# Combine Neurons Number :107
# all_train_score_W0_n 0.5543350626011815
# all_train_score_W0_a 0.5523676947224243
# test_score_W0_n 0.3336251313403905
# test_score_W0_a  0.24889814756147605
# Split one time!
# self.rest_data_W0_p 0.841726618705036
# self.rest_data_W0_n 0.6701591861060744
# self.rest_data_W0_a 0.6368059138643171
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7116413493352597
# all_train_score_W_Combined_a 0.6975562866819761
# test_score_W_combined_n 0.4434889995059741
# test_score_W_combined_a 0.3356482971737591
# Combine Neurons Number :101
# all_train_score_W0_n 0.6685148448165257
# all_train_score_W0_a 0.6598832791212732
# test_score_W0_n 0.31678111590758934
# test_score_W0_a  0.20390674155689312
# Split one time!
# self.rest_data_W0_p 0.9044117647058824
# self.rest_data_W0_n 0.7724110079342966
# self.rest_data_W0_a 0.7524068717388306
# Split one time!
# self.rest_data_W0_p 0.9743589743589743
# self.rest_data_W0_n 0.9190367793114824
# self.rest_data_W0_a 0.9129581151832461
# all_train_score_W_Combined_n 0.8004825069488974
# all_train_score_W_Combined_a 0.7953231877810868
# test_score_W_combined_n 0.46574874539634925
# test_score_W_combined_a 0.3660615083774055
# Combine Neurons Number :109
# all_train_score_W0_n 0.5226402789770893
# all_train_score_W0_a 0.4821506502083028
# test_score_W0_n 0.34192961708068037
# test_score_W0_a  0.298150935179846
# Split one time!
# self.rest_data_W0_p 0.8062015503875969
# self.rest_data_W0_n 0.5977215253753732
# self.rest_data_W0_a 0.5603827085334273
# Split one time!
# self.rest_data_W0_p 0.8974358974358975
# self.rest_data_W0_n 0.730341934576482
# self.rest_data_W0_a 0.7113516998670195
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.631250922602191
# all_train_score_W_Combined_a 0.6234759121936846
# test_score_W_combined_n 0.4408267963358489
# test_score_W_combined_a 0.35245280684339436
# Combine Neurons Number :112
# all_train_score_W0_n 0.5683373705742515
# all_train_score_W0_a 0.5604834067777374
# test_score_W0_n 0.32564547006726874
# test_score_W0_a  0.2195240691128842
# Split one time!
# self.rest_data_W0_p 0.8455882352941176
# self.rest_data_W0_n 0.600865424148825
# self.rest_data_W0_a 0.60775831406194
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6708828937449446
# all_train_score_W_Combined_a 0.6864171516248183
# test_score_W_combined_n 0.3579032659018107
# test_score_W_combined_a 0.2764074785477877
# Combine Neurons Number :104
# all_train_score_W0_n 0.5736678577138435
# all_train_score_W0_a 0.55832269003739
# test_score_W0_n 0.31847204695387077
# test_score_W0_a  0.19445762746837794
# Split one time!
# self.rest_data_W0_p 0.8540145985401459
# self.rest_data_W0_n 0.672389348619871
# self.rest_data_W0_a 0.661991009110273
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7348370007232318
# all_train_score_W_Combined_a 0.7291544085398094
# test_score_W_combined_n 0.38884114302456996
# test_score_W_combined_a 0.3049857707384998
# Combine Neurons Number :111
# all_train_score_W0_n 0.5565687548827775
# all_train_score_W0_a 0.5356728965896704
# test_score_W0_n 0.3934821188138553
# test_score_W0_a  0.3222598544353967
# Split one time!
# self.rest_data_W0_p 0.8442622950819673
# self.rest_data_W0_n 0.6455956034677236
# self.rest_data_W0_a 0.6242732718133318
# Split one time!
# self.rest_data_W0_p 0.9545454545454546
# self.rest_data_W0_n 0.8843825603401847
# self.rest_data_W0_a 0.8891758759769492
# all_train_score_W_Combined_n 0.7147708742348257
# all_train_score_W_Combined_a 0.7138476526962909
# test_score_W_combined_n 0.4528855524454172
# test_score_W_combined_a 0.33887359237718107
# Combine Neurons Number :117
# all_train_score_W0_n 0.5611045523764379
# all_train_score_W0_a 0.5846632048411943
# test_score_W0_n 0.33619902286545134
# test_score_W0_a  0.23651861301171287
# Split one time!
# self.rest_data_W0_p 0.855072463768116
# self.rest_data_W0_n 0.6110953099555184
# self.rest_data_W0_a 0.6418281889265511
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.8639238374091843
# self.rest_data_W0_a 0.8378087136311468
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6683704413628423
# all_train_score_W_Combined_a 0.6903654858019584
# test_score_W_combined_n 0.4006623053957458
# test_score_W_combined_a 0.3599283576292825
# Combine Neurons Number :106
# all_train_score_W0_n 0.526024219689066
# all_train_score_W0_a 0.5189577059611754
# test_score_W0_n 0.47172793360086634
# test_score_W0_a  0.3626543691310762
# Split one time!
# self.rest_data_W0_p 0.782608695652174
# self.rest_data_W0_n 0.549916042142073
# self.rest_data_W0_a 0.5146210165189689
# Split one time!
# self.rest_data_W0_p 0.972972972972973
# self.rest_data_W0_n 0.9267059530116842
# self.rest_data_W0_a 0.9132036128330367
# all_train_score_W_Combined_n 0.6107558008067656
# all_train_score_W_Combined_a 0.6005378639109242
# test_score_W_combined_n 0.4200613955761602
# test_score_W_combined_a 0.29614555901364614
# Combine Neurons Number :102
# all_train_score_W0_n 0.6194102673585541
# all_train_score_W0_a 0.5899089346650332
# test_score_W0_n 0.3259927219395738
# test_score_W0_a  0.225799496945742
# Split one time!
# self.rest_data_W0_p 0.8226950354609929
# self.rest_data_W0_n 0.6054298364387369
# self.rest_data_W0_a 0.5887068805600587
# Split one time!
# self.rest_data_W0_p 0.9705882352941176
# self.rest_data_W0_n 0.9209655298773791
# self.rest_data_W0_a 0.9141532387641739
# all_train_score_W_Combined_n 0.661108493998922
# all_train_score_W_Combined_a 0.6536096457923325
# test_score_W_combined_n 0.471200231379509
# test_score_W_combined_a 0.32997291689047453
# Combine Neurons Number :101
# all_train_score_W0_n 0.5532142111889857
# all_train_score_W0_a 0.5268924064455587
# test_score_W0_n 0.4113625426190561
# test_score_W0_a  0.2920619850206741
# Split one time!
# self.rest_data_W0_p 0.8235294117647058
# self.rest_data_W0_n 0.607772971079127
# self.rest_data_W0_a 0.5877097833159055
# Split one time!
# self.rest_data_W0_p 0.9642857142857143
# self.rest_data_W0_n 0.9038719040036798
# self.rest_data_W0_a 0.8846036430243207
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6670245234209657
# all_train_score_W_Combined_a 0.6721925142690749
# test_score_W_combined_n 0.4423295180184436
# test_score_W_combined_a 0.3649908815125236
# Combine Neurons Number :99
# all_train_score_W0_n 0.5779946079929967
# all_train_score_W0_a 0.5805889330960262
# test_score_W0_n 0.366791819887305
# test_score_W0_a  0.28409141223426126
# Split one time!
# self.rest_data_W0_p 0.8796992481203008
# self.rest_data_W0_n 0.7011619334348811
# self.rest_data_W0_a 0.6884064873713586
# Split one time!
# self.rest_data_W0_p 0.9142857142857143
# self.rest_data_W0_n 0.862732851252389
# self.rest_data_W0_a 0.7764822003373576
# all_train_score_W_Combined_n 0.7335531275820423
# all_train_score_W_Combined_a 0.7348601552685946
# test_score_W_combined_n 0.5215174689200128
# test_score_W_combined_a 0.47061797334567573
# Combine Neurons Number :105
# all_train_score_W0_n 0.5479972691766076
# all_train_score_W0_a 0.5302396272287414
# test_score_W0_n 0.36328863164122205
# test_score_W0_a  0.2825512217929754
# Split one time!
# self.rest_data_W0_p 0.8260869565217391
# self.rest_data_W0_n 0.5882699916417395
# self.rest_data_W0_a 0.5771272288063825
# Split one time!
# self.rest_data_W0_p 0.9722222222222222
# self.rest_data_W0_n 0.9235279100336472
# self.rest_data_W0_a 0.9138670345650471
# all_train_score_W_Combined_n 0.6483502752750834
# all_train_score_W_Combined_a 0.651895373606287
# test_score_W_combined_n 0.3612947400261161
# test_score_W_combined_a 0.26352210927934855
# Combine Neurons Number :107
# all_train_score_W0_n 0.6199926109971506
# all_train_score_W0_a 0.6178824819763641
# test_score_W0_n 0.42399181122110896
# test_score_W0_a  0.3128477799553885
# Split one time!
# self.rest_data_W0_p 0.875968992248062
# self.rest_data_W0_n 0.6858899068599559
# self.rest_data_W0_a 0.6846994916659142
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7507199395900304
# all_train_score_W_Combined_a 0.7696789546194631
# test_score_W_combined_n 0.4529452516213253
# test_score_W_combined_a 0.3585858963124704
# Combine Neurons Number :107
# all_train_score_W0_n 0.5644763488595781
# all_train_score_W0_a 0.5388785809189391
# test_score_W0_n 0.33778339001762947
# test_score_W0_a  0.25427405282524657
# Split one time!
# self.rest_data_W0_p 0.8142857142857143
# self.rest_data_W0_n 0.6062434469185782
# self.rest_data_W0_a 0.5773225676172795
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6610208646907821
# all_train_score_W_Combined_a 0.6646105927962609
# test_score_W_combined_n 0.38883629069045506
# test_score_W_combined_a 0.3357736484532173
# Combine Neurons Number :97
# all_train_score_W0_n 0.5679388654453247
# all_train_score_W0_a 0.5672251994775777
# test_score_W0_n 0.3112970872004415
# test_score_W0_a  0.1661886494096386
# Split one time!
# self.rest_data_W0_p 0.8235294117647058
# self.rest_data_W0_n 0.604296218791182
# self.rest_data_W0_a 0.6052337303845396
# Split one time!
# self.rest_data_W0_p 0.9743589743589743
# self.rest_data_W0_n 0.9238681779433966
# self.rest_data_W0_a 0.9126099091897841
# all_train_score_W_Combined_n 0.6660495799803525
# all_train_score_W_Combined_a 0.6710497958908659
# test_score_W_combined_n 0.4168050462049529
# test_score_W_combined_a 0.27468476059874153
# Combine Neurons Number :102
# all_train_score_W0_n 0.5464254944820258
# all_train_score_W0_a 0.5320771252190304
# test_score_W0_n 0.4398484590302346
# test_score_W0_a  0.3797121489338381
# Split one time!
# self.rest_data_W0_p 0.8045112781954887
# self.rest_data_W0_n 0.5665229199171361
# self.rest_data_W0_a 0.5565057098139238
# Split one time!
# self.rest_data_W0_p 0.9473684210526315
# self.rest_data_W0_n 0.8733659943878535
# self.rest_data_W0_a 0.8525945218178207
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6324999771860071
# all_train_score_W_Combined_a 0.6311442810271688
# test_score_W_combined_n 0.43658795800505334
# test_score_W_combined_a 0.3587774310443336
# Combine Neurons Number :103
# all_train_score_W0_n 0.583905971473235
# all_train_score_W0_a 0.5594083715676088
# test_score_W0_n 0.4472190449267985
# test_score_W0_a  0.40234633945949166
# Split one time!
# self.rest_data_W0_p 0.8382352941176471
# self.rest_data_W0_n 0.6356202450588762
# self.rest_data_W0_a 0.6048312990798131
# Split one time!
# self.rest_data_W0_p 0.967741935483871
# self.rest_data_W0_n 0.9220199417078079
# self.rest_data_W0_a 0.9129172714078374
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6924081187025315
# all_train_score_W_Combined_a 0.6842035630156468
# test_score_W_combined_n 0.4266395959716757
# test_score_W_combined_a 0.31966233715905934
# Combine Neurons Number :109
# all_train_score_W0_n 0.4807775621412797
# all_train_score_W0_a 0.46595701366177783
# test_score_W0_n 0.2806966873861134
# test_score_W0_a  0.20799792872946382
# Split one time!
# self.rest_data_W0_p 0.8014705882352942
# self.rest_data_W0_n 0.5165112108325939
# self.rest_data_W0_a 0.5454641854285698
# Split one time!
# self.rest_data_W0_p 0.9333333333333333
# self.rest_data_W0_n 0.8774670556386994
# self.rest_data_W0_a 0.8017771701982228
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.596217964468229
# all_train_score_W_Combined_a 0.6227004418659561
# test_score_W_combined_n 0.3090776302481066
# test_score_W_combined_a 0.2669453898815027
# Combine Neurons Number :103
# all_train_score_W0_n 0.553007481105107
# all_train_score_W0_a 0.5373163472636964
# test_score_W0_n 0.36795404483139427
# test_score_W0_a  0.2750566518882576
# Split one time!
# self.rest_data_W0_p 0.8148148148148148
# self.rest_data_W0_n 0.5680646791532
# self.rest_data_W0_a 0.5565349118370262
# Split one time!
# self.rest_data_W0_p 0.9459459459459459
# self.rest_data_W0_n 0.8621115691978549
# self.rest_data_W0_a 0.8395769768989011
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6316911130794163
# all_train_score_W_Combined_a 0.6313228332366291
# test_score_W_combined_n 0.3570229953363963
# test_score_W_combined_a 0.2290880649143425
# Combine Neurons Number :108
# all_train_score_W0_n 0.5915320207613495
# all_train_score_W0_a 0.577319055120284
# test_score_W0_n 0.4630353428539924
# test_score_W0_a  0.41191699306839963
# Split one time!
# self.rest_data_W0_p 0.851063829787234
# self.rest_data_W0_n 0.6573980033832448
# self.rest_data_W0_a 0.6516410852715934
# Split one time!
# self.rest_data_W0_p 0.90625
# self.rest_data_W0_n 0.8117479437037746
# self.rest_data_W0_a 0.7732774211499096
# all_train_score_W_Combined_n 0.6909995642977131
# all_train_score_W_Combined_a 0.6885629266087455
# test_score_W_combined_n 0.4415061535576579
# test_score_W_combined_a 0.4050377624699145
# Combine Neurons Number :102
# all_train_score_W0_n 0.5387889696446297
# all_train_score_W0_a 0.5360131400981357
# test_score_W0_n 0.3818164440351703
# test_score_W0_a  0.27019834394988373
# Split one time!
# self.rest_data_W0_p 0.8321167883211679
# self.rest_data_W0_n 0.603491037519228
# self.rest_data_W0_a 0.589996577776004
# Split one time!
# self.rest_data_W0_p 0.9714285714285714
# self.rest_data_W0_n 0.9196505622399324
# self.rest_data_W0_a 0.907067236192507
# all_train_score_W_Combined_n 0.6597421356165296
# all_train_score_W_Combined_a 0.6676462006168327
# test_score_W_combined_n 0.43547485895569027
# test_score_W_combined_a 0.3196301719651955
# Combine Neurons Number :108
# all_train_score_W0_n 0.5950832034488466
# all_train_score_W0_a 0.5915668848929938
# test_score_W0_n 0.33625602398806764
# test_score_W0_a  0.29585402039695796
# Split one time!
# self.rest_data_W0_p 0.849624060150376
# self.rest_data_W0_n 0.649671284064239
# self.rest_data_W0_a 0.647613878594408
# Split one time!
# self.rest_data_W0_p 0.9210526315789473
# self.rest_data_W0_n 0.783405079966193
# self.rest_data_W0_a 0.7562116906337117
# all_train_score_W_Combined_n 0.6860918978654584
# all_train_score_W_Combined_a 0.6967498914992752
# test_score_W_combined_n 0.47138261447185476
# test_score_W_combined_a 0.38658555265720684
# Combine Neurons Number :111
# all_train_score_W0_n 0.4984856950697913
# all_train_score_W0_a 0.47302268678831716
# test_score_W0_n 0.3801481666890176
# test_score_W0_a  0.28836815911970154
# Split one time!
# self.rest_data_W0_p 0.8449612403100775
# self.rest_data_W0_n 0.6347751490421137
# self.rest_data_W0_a 0.6384266923128067
# Split one time!
# self.rest_data_W0_p 0.8809523809523809
# self.rest_data_W0_n 0.7064144671471431
# self.rest_data_W0_a 0.6910789632308619
# all_train_score_W_Combined_n 0.645511024846412
# all_train_score_W_Combined_a 0.6681286577275976
# test_score_W_combined_n 0.5160374856747431
# test_score_W_combined_a 0.43144204514458134
# Combine Neurons Number :106
# all_train_score_W0_n 0.5208223413899382
# all_train_score_W0_a 0.4915105572481239
# test_score_W0_n 0.41592697921333643
# test_score_W0_a  0.31492792381763024
# Split one time!
# self.rest_data_W0_p 0.8071428571428572
# self.rest_data_W0_n 0.5799114414557099
# self.rest_data_W0_a 0.5534968795008648
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6496078230918344
# all_train_score_W_Combined_a 0.634386421454763
# test_score_W_combined_n 0.43652187255085445
# test_score_W_combined_a 0.3419569230769231
# Combine Neurons Number :107
# all_train_score_W0_n 0.6246147923698135
# all_train_score_W0_a 0.6271371603093471
# test_score_W0_n 0.33528492049906666
# test_score_W0_a  0.24159139983423417
# Split one time!
# self.rest_data_W0_p 0.8671328671328671
# self.rest_data_W0_n 0.6754304118734611
# self.rest_data_W0_a 0.6710196547975659
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7227152449239014
# all_train_score_W_Combined_a 0.7298104346568615
# test_score_W_combined_n 0.4756070480785404
# test_score_W_combined_a 0.44617285906309184
# Combine Neurons Number :100
# all_train_score_W0_n 0.5172180445370679
# all_train_score_W0_a 0.4993851291318332
# test_score_W0_n 0.40622677491417836
# test_score_W0_a  0.3029386336505692
# Split one time!
# self.rest_data_W0_p 0.8098591549295775
# self.rest_data_W0_n 0.5703460001124598
# self.rest_data_W0_a 0.555688311566431
# Split one time!
# self.rest_data_W0_p 0.9705882352941176
# self.rest_data_W0_n 0.9243107396679147
# self.rest_data_W0_a 0.9324808184143223
# all_train_score_W_Combined_n 0.6286181918254853
# all_train_score_W_Combined_a 0.6262200779480497
# test_score_W_combined_n 0.39121502517297296
# test_score_W_combined_a 0.28946413224323514
# Combine Neurons Number :101
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.376359  0.058664  0.010710   0.354454  0.398265
# 1  test_score_W'  30.0  0.429192  0.046626  0.008513   0.411782  0.446603
# 2       combined  60.0  0.402776  0.058905  0.007605   0.387559  0.417992
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0528
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -3.8617
# 3                       Two side test p value =    0.0003
# 4                      Difference < 0 p value =    0.0001
# 5                      Difference > 0 p value =    0.9999
# 6                                   Cohen's d =   -0.9971
# 7                                   Hedge's g =   -0.9841
# 8                               Glass's delta =   -0.9006
# 9                                 Pearson's r =    0.4522
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.376359  0.058664  0.010710   0.354454  0.398265
# 1  test_score_W'  30.0  0.341829  0.056185  0.010258   0.320849  0.362809
# 2       combined  60.0  0.359094  0.059551  0.007688   0.343711  0.374478
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0345
# 1                          Degrees of freedom =   58.0000
# 2                                           t =    2.3284
# 3                       Two side test p value =    0.0234
# 4                      Difference < 0 p value =    0.9883
# 5                      Difference > 0 p value =    0.0117
# 6                                   Cohen's d =    0.6012
# 7                                   Hedge's g =    0.5934
# 8                               Glass's delta =    0.5886
# 9                                 Pearson's r =    0.2924
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
