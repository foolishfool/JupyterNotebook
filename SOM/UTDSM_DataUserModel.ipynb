# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import experiment
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Data_User_Modeling_Dataset_Hamdi Tolga KAHRAMAN.csv")
dataread.stringToIntDataUserModelDataSet(csv," UNS")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test," UNS")

# %%
unstable_repeat_num= 30
scope_num = 34
class_num = 4
dim_num = 5
best_num =18

elbow_num = 1
row = 2
column = 3
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )   

experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# neuron unit number: 4
# all_train_score_W0_n 0.11493094287938074
# all_train_score_W0_a 0.07058441413117267
# test_score_W0_n 0.26028179085176817
# test_score_W0_a  0.15487660867110434
# all_train_score_W_Combined_n 0.18315131743335525
# all_train_score_W_Combined_a 0.12581448830969721
# test_score_W_combined_n 0.20516927820110303
# test_score_W_combined_a 0.13100426064705917
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :11
# neuron unit number: 5
# all_train_score_W0_n 0.08003950301088021
# all_train_score_W0_a 0.08021958220751209
# test_score_W0_n 0.14185163624666633
# test_score_W0_a  0.07325862642031984
# all_train_score_W_Combined_n 0.25774580814111575
# all_train_score_W_Combined_a 0.240705081076415
# test_score_W_combined_n 0.13930546389640397
# test_score_W_combined_a 0.10159591361279631
# Not good nmi result !!!!!
# Combine Neurons Number :12
# neuron unit number: 6
# all_train_score_W0_n 0.30705186271754176
# all_train_score_W0_a 0.22424897902536647
# test_score_W0_n 0.30611418324176726
# test_score_W0_a  0.2817704872963871
# all_train_score_W_Combined_n 0.32376766975641214
# all_train_score_W_Combined_a 0.2128100046261842
# test_score_W_combined_n 0.33802917207070776
# test_score_W_combined_a 0.2689360732194831
# Not good ari result !!!!!
# Combine Neurons Number :17
# neuron unit number: 7
# all_train_score_W0_n 0.10948804100420913
# all_train_score_W0_a 0.08437065068647602
# test_score_W0_n 0.07599821474610172
# test_score_W0_a  0.03513485786308544
# all_train_score_W_Combined_n 0.26376914911965627
# all_train_score_W_Combined_a 0.20217965183608885
# test_score_W_combined_n 0.31035135305684797
# test_score_W_combined_a 0.2439660260415176
# Combine Neurons Number :14
# neuron unit number: 8
# all_train_score_W0_n 0.2391848332858499
# all_train_score_W0_a 0.19186350656039336
# test_score_W0_n 0.2663546383905145
# test_score_W0_a  0.19916475545764328
# all_train_score_W_Combined_n 0.33681462300530074
# all_train_score_W_Combined_a 0.28292944331467546
# test_score_W_combined_n 0.26713723284585
# test_score_W_combined_a 0.19887639459065198
# Not good ari result !!!!!
# Combine Neurons Number :26
# neuron unit number: 9
# all_train_score_W0_n 0.26435695721972513
# all_train_score_W0_a 0.21063694294555385
# test_score_W0_n 0.18235515308880793
# test_score_W0_a  0.08755151420072285
# all_train_score_W_Combined_n 0.39430909381714835
# all_train_score_W_Combined_a 0.38040046759827834
# test_score_W_combined_n 0.2680410529117985
# test_score_W_combined_a 0.21687603697558663
# Combine Neurons Number :17
# neuron unit number: 10
# all_train_score_W0_n 0.36564193875522466
# all_train_score_W0_a 0.32646457876916374
# test_score_W0_n 0.3689893030168004
# test_score_W0_a  0.32339083863340606
# all_train_score_W_Combined_n 0.426702122069228
# all_train_score_W_Combined_a 0.4087751161608197
# test_score_W_combined_n 0.37854149570156415
# test_score_W_combined_a 0.33048989267136364
# Combine Neurons Number :39
# neuron unit number: 11
# all_train_score_W0_n 0.34566553238294495
# all_train_score_W0_a 0.22895562732503655
# test_score_W0_n 0.35551052691156065
# test_score_W0_a  0.21586145452867492
# all_train_score_W_Combined_n 0.4059692840551518
# all_train_score_W_Combined_a 0.33035052727280007
# test_score_W_combined_n 0.3045244257361585
# test_score_W_combined_a 0.21003194881180431
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :21
# neuron unit number: 12
# all_train_score_W0_n 0.43969905770151546
# all_train_score_W0_a 0.42942263725356977
# test_score_W0_n 0.34963979703249015
# test_score_W0_a  0.2710563128273529
# all_train_score_W_Combined_n 0.5066843038196814
# all_train_score_W_Combined_a 0.48854121678941714
# test_score_W_combined_n 0.4261367488046533
# test_score_W_combined_a 0.40126622493748165
# Combine Neurons Number :50
# neuron unit number: 13
# all_train_score_W0_n 0.2376389179525064
# all_train_score_W0_a 0.18814461471856553
# test_score_W0_n 0.23219614282233322
# test_score_W0_a  0.157146243185589
# all_train_score_W_Combined_n 0.2503986316810549
# all_train_score_W_Combined_a 0.22141755817359984
# test_score_W_combined_n 0.28896662654566996
# test_score_W_combined_a 0.2940928039652462
# Combine Neurons Number :23
# neuron unit number: 14
# all_train_score_W0_n 0.5576337833097219
# all_train_score_W0_a 0.5472966920206677
# test_score_W0_n 0.3725943009846827
# test_score_W0_a  0.2696348881772702
# all_train_score_W_Combined_n 0.5828736949709249
# all_train_score_W_Combined_a 0.5682917872888221
# test_score_W_combined_n 0.42972182105173085
# test_score_W_combined_a 0.36293698789000145
# Combine Neurons Number :61
# neuron unit number: 15
# all_train_score_W0_n 0.385379536613879
# all_train_score_W0_a 0.3370790926664464
# test_score_W0_n 0.3614782122337114
# test_score_W0_a  0.2277353438247624
# all_train_score_W_Combined_n 0.37785406388657716
# all_train_score_W_Combined_a 0.3354056181528071
# test_score_W_combined_n 0.2925479165465488
# test_score_W_combined_a 0.23010686296446303
# Not good nmi result !!!!!
# Combine Neurons Number :25
# neuron unit number: 16
# all_train_score_W0_n 0.4254805581681957
# all_train_score_W0_a 0.40368360002689047
# test_score_W0_n 0.3277364789062515
# test_score_W0_a  0.1400084532453523
# all_train_score_W_Combined_n 0.5147138331559332
# all_train_score_W_Combined_a 0.5103494692640452
# test_score_W_combined_n 0.28484637932861423
# test_score_W_combined_a 0.20391017022651664
# Not good nmi result !!!!!
# Combine Neurons Number :72
# neuron unit number: 17
# all_train_score_W0_n 0.3075682683495862
# all_train_score_W0_a 0.24146877635105807
# test_score_W0_n 0.21778159643965123
# test_score_W0_a  0.17240719212002784
# all_train_score_W_Combined_n 0.3668142479072323
# all_train_score_W_Combined_a 0.3141907478322847
# test_score_W_combined_n 0.2778127280652928
# test_score_W_combined_a 0.223506227574787
# Combine Neurons Number :25
# neuron unit number: 18
# all_train_score_W0_n 0.6187369560857998
# all_train_score_W0_a 0.5902951444725828
# test_score_W0_n 0.36775649414225126
# test_score_W0_a  0.2735481331617119
# all_train_score_W_Combined_n 0.6605178034826659
# all_train_score_W_Combined_a 0.6543212431380375
# test_score_W_combined_n 0.42921583488461923
# test_score_W_combined_a 0.39466036618829703
# Combine Neurons Number :85
# neuron unit number: 19
# all_train_score_W0_n 0.28141707534078886
# all_train_score_W0_a 0.2162844950818104
# test_score_W0_n 0.27397890211845016
# test_score_W0_a  0.24186716109093495
# all_train_score_W_Combined_n 0.408880685237144
# all_train_score_W_Combined_a 0.3736462268074363
# test_score_W_combined_n 0.25027956966230375
# test_score_W_combined_a 0.15438784310226902
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :27
# neuron unit number: 20
# all_train_score_W0_n 0.6301913289755527
# all_train_score_W0_a 0.6078719091082019
# test_score_W0_n 0.4586712804074088
# test_score_W0_a  0.37392643582414714
# all_train_score_W_Combined_n 0.7338676480872035
# all_train_score_W_Combined_a 0.7283141149891891
# test_score_W_combined_n 0.42614725885760274
# test_score_W_combined_a 0.36007249104533795
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :94
# neuron unit number: 21
# all_train_score_W0_n 0.3117143288709011
# all_train_score_W0_a 0.2422974105290649
# test_score_W0_n 0.3001342484798238
# test_score_W0_a  0.16256153426867131
# all_train_score_W_Combined_n 0.349209247734611
# all_train_score_W_Combined_a 0.30928629659326234
# test_score_W_combined_n 0.3474248375429387
# test_score_W_combined_a 0.28556040917764314
# Combine Neurons Number :35
# neuron unit number: 22
# all_train_score_W0_n 0.6614007550202743
# all_train_score_W0_a 0.6394567494617914
# test_score_W0_n 0.27946696476190785
# test_score_W0_a  0.20056641036704018
# all_train_score_W_Combined_n 0.7207159755683238
# all_train_score_W_Combined_a 0.7085684893197122
# test_score_W_combined_n 0.3602162112324764
# test_score_W_combined_a 0.2868138355441462
# Combine Neurons Number :109
# neuron unit number: 23
# all_train_score_W0_n 0.3760578309162443
# all_train_score_W0_a 0.31479708118511335
# test_score_W0_n 0.3198274642633001
# test_score_W0_a  0.2518660675666846
# all_train_score_W_Combined_n 0.40132915467564534
# all_train_score_W_Combined_a 0.3585851452589616
# test_score_W_combined_n 0.2050711844990798
# test_score_W_combined_a 0.18071980928492165
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :33
# neuron unit number: 24
# all_train_score_W0_n 0.7251675112663768
# all_train_score_W0_a 0.7384651252416937
# test_score_W0_n 0.3852847440595354
# test_score_W0_a  0.2514921402310861
# all_train_score_W_Combined_n 0.7468965858534302
# all_train_score_W_Combined_a 0.7577852874578075
# test_score_W_combined_n 0.41951801985703113
# test_score_W_combined_a 0.37013377078416126
# Combine Neurons Number :117
# neuron unit number: 25
# all_train_score_W0_n 0.424676452166029
# all_train_score_W0_a 0.35673298252825775
# test_score_W0_n 0.3158534360036352
# test_score_W0_a  0.15598480985621296
# all_train_score_W_Combined_n 0.4657969461214843
# all_train_score_W_Combined_a 0.3996274133144922
# test_score_W_combined_n 0.37379486299976256
# test_score_W_combined_a 0.29563258578163915
# Combine Neurons Number :39
# neuron unit number: 26
# all_train_score_W0_n 0.7267663321672871
# all_train_score_W0_a 0.756052916503818
# test_score_W0_n 0.27118396005095746
# test_score_W0_a  0.18058160933846606
# all_train_score_W_Combined_n 0.7522075009875951
# all_train_score_W_Combined_a 0.7824731075282334
# test_score_W_combined_n 0.40489360942078517
# test_score_W_combined_a 0.31677417471760894
# Combine Neurons Number :118
# neuron unit number: 27
# all_train_score_W0_n 0.3918327344808721
# all_train_score_W0_a 0.3621929092345491
# test_score_W0_n 0.20384552087919403
# test_score_W0_a  0.10601541393570106
# all_train_score_W_Combined_n 0.4924760217119377
# all_train_score_W_Combined_a 0.4864293145907646
# test_score_W_combined_n 0.30780960210473474
# test_score_W_combined_a 0.2627095921063825
# Combine Neurons Number :44
# neuron unit number: 28
# all_train_score_W0_n 0.7621055504522903
# all_train_score_W0_a 0.7938791000118858
# test_score_W0_n 0.26911495001552344
# test_score_W0_a  0.17013689045378114
# all_train_score_W_Combined_n 0.7912035353928742
# all_train_score_W_Combined_a 0.8173098964956816
# test_score_W_combined_n 0.36447619299098744
# test_score_W_combined_a 0.2787869705306201
# Combine Neurons Number :118
# neuron unit number: 29
# all_train_score_W0_n 0.34097596992199836
# all_train_score_W0_a 0.2828853477828394
# test_score_W0_n 0.34247831015167707
# test_score_W0_a  0.2410507792860734
# all_train_score_W_Combined_n 0.40391016068070473
# all_train_score_W_Combined_a 0.35642517388872735
# test_score_W_combined_n 0.22959662767414457
# test_score_W_combined_a 0.13851842470728187
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :44
# neuron unit number: 30
# all_train_score_W0_n 0.837088894773472
# all_train_score_W0_a 0.8638800291784459
# test_score_W0_n 0.36641856784924287
# test_score_W0_a  0.29049940244569356
# all_train_score_W_Combined_n 0.8867695507639848
# all_train_score_W_Combined_a 0.9203466422872998
# test_score_W_combined_n 0.41775560367669495
# test_score_W_combined_a 0.3693940580277524
# Combine Neurons Number :131
# neuron unit number: 31
# all_train_score_W0_n 0.36895184234757206
# all_train_score_W0_a 0.34885826480632187
# test_score_W0_n 0.149134631195614
# test_score_W0_a  0.0837878887493495
# all_train_score_W_Combined_n 0.4156970220786068
# all_train_score_W_Combined_a 0.397976247767486
# test_score_W_combined_n 0.2481005442883083
# test_score_W_combined_a 0.1804574836155934
# Combine Neurons Number :49
# neuron unit number: 32
# all_train_score_W0_n 0.8216208042292641
# all_train_score_W0_a 0.8230918910943817
# test_score_W0_n 0.2951623908159649
# test_score_W0_a  0.17375558583298625
# all_train_score_W_Combined_n 0.8218409705383432
# all_train_score_W_Combined_a 0.8522054683579308
# test_score_W_combined_n 0.43253773173181487
# test_score_W_combined_a 0.38525561824941784
# Combine Neurons Number :129
# neuron unit number: 33
# all_train_score_W0_n 0.4794341342254444
# all_train_score_W0_a 0.4244990338932021
# test_score_W0_n 0.45701777040306163
# test_score_W0_a  0.447926366504884
# all_train_score_W_Combined_n 0.5090402438943146
# all_train_score_W_Combined_a 0.4887469394119652
# test_score_W_combined_n 0.431257503954132
# test_score_W_combined_a 0.35514104624841175
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :47
# neuron unit number: 34
# all_train_score_W0_n 0.8275826083442009
# all_train_score_W0_a 0.8460524759029521
# test_score_W0_n 0.3043483254944912
# test_score_W0_a  0.1857170864113905
# all_train_score_W_Combined_n 0.8574231710409438
# all_train_score_W_Combined_a 0.8777250922297336
# test_score_W_combined_n 0.45889429493934064
# test_score_W_combined_a 0.3983491222905361
# Combine Neurons Number :130
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.296083  0.086846  0.015598   0.264227  0.327938
# 1  test_score_W'  31.0  0.332843  0.083932  0.015075   0.302056  0.363629
# 2       combined  62.0  0.314463  0.086702  0.011011   0.292444  0.336481
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0368
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -1.6946
# 3                       Two side test p value =    0.0953
# 4                      Difference < 0 p value =    0.0477
# 5                      Difference > 0 p value =    0.9523
# 6                                   Cohen's d =   -0.4304
# 7                                   Hedge's g =   -0.4250
# 8                               Glass's delta =   -0.4233
# 9                                 Pearson's r =    0.2137
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.296083  0.086846  0.015598   0.264227  0.327938
# 1  test_score_W'  31.0  0.271967  0.087303  0.015680   0.239944  0.303989
# 2       combined  62.0  0.284025  0.087209  0.011076   0.261878  0.306172
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0241
# 1                          Degrees of freedom =   60.0000
# 2                                           t =    1.0904
# 3                       Two side test p value =    0.2799
# 4                      Difference < 0 p value =    0.8600
# 5                      Difference > 0 p value =    0.1400
# 6                                   Cohen's d =    0.2770
# 7                                   Hedge's g =    0.2735
# 8                               Glass's delta =    0.2777
# 9                                 Pearson's r =    0.1394
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.5678460529669757
# all_train_score_W0_a 0.535497745405664
# test_score_W0_n 0.3262095499174033
# test_score_W0_a  0.2678795802385679
# all_train_score_W_Combined_n 0.6187210850410881
# all_train_score_W_Combined_a 0.6102036654737014
# test_score_W_combined_n 0.3719276718212988
# test_score_W_combined_a 0.31476653235363833
# Combine Neurons Number :85
# all_train_score_W0_n 0.5582355800801602
# all_train_score_W0_a 0.5216911658302497
# test_score_W0_n 0.4058175087728832
# test_score_W0_a  0.2854961762376735
# all_train_score_W_Combined_n 0.6504236517325337
# all_train_score_W_Combined_a 0.6391586998356531
# test_score_W_combined_n 0.3487722565253551
# test_score_W_combined_a 0.2637977652795762
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :86
# all_train_score_W0_n 0.5929060517893621
# all_train_score_W0_a 0.5580895732969323
# test_score_W0_n 0.42008707876954815
# test_score_W0_a  0.326364938802162
# all_train_score_W_Combined_n 0.6559438803298802
# all_train_score_W_Combined_a 0.6360767315851064
# test_score_W_combined_n 0.28379930490253547
# test_score_W_combined_a 0.2518114148240596
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :87
# all_train_score_W0_n 0.5756371766153415
# all_train_score_W0_a 0.5846401251573984
# test_score_W0_n 0.470528396520086
# test_score_W0_a  0.39106284632170296
# all_train_score_W_Combined_n 0.6243668586418467
# all_train_score_W_Combined_a 0.6365359148711696
# test_score_W_combined_n 0.4098140410934921
# test_score_W_combined_a 0.31607001269541546
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :83
# all_train_score_W0_n 0.5699496476783252
# all_train_score_W0_a 0.5725750078246417
# test_score_W0_n 0.3274769748966281
# test_score_W0_a  0.22312553917146147
# all_train_score_W_Combined_n 0.6410338367084722
# all_train_score_W_Combined_a 0.6612983765631711
# test_score_W_combined_n 0.4160604499002535
# test_score_W_combined_a 0.3829445763796263
# Combine Neurons Number :88
# all_train_score_W0_n 0.5364613604744609
# all_train_score_W0_a 0.5008928767885722
# test_score_W0_n 0.25847515850715247
# test_score_W0_a  0.17214587684116484
# all_train_score_W_Combined_n 0.6223449188155616
# all_train_score_W_Combined_a 0.6043611676032804
# test_score_W_combined_n 0.3306299618749804
# test_score_W_combined_a 0.2318454177096309
# Combine Neurons Number :81
# all_train_score_W0_n 0.5883563287701786
# all_train_score_W0_a 0.569483637721332
# test_score_W0_n 0.3975988503224985
# test_score_W0_a  0.33328142069751043
# all_train_score_W_Combined_n 0.6492632341632508
# all_train_score_W_Combined_a 0.6556829238650301
# test_score_W_combined_n 0.35901765164920996
# test_score_W_combined_a 0.3030284057825834
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :84
# all_train_score_W0_n 0.6087457563436421
# all_train_score_W0_a 0.5982770459698193
# test_score_W0_n 0.46721868878343165
# test_score_W0_a  0.3837267104303596
# all_train_score_W_Combined_n 0.6957477694692171
# all_train_score_W_Combined_a 0.673700149511876
# test_score_W_combined_n 0.417530247681893
# test_score_W_combined_a 0.37891398582302416
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :89
# all_train_score_W0_n 0.5791642072153821
# all_train_score_W0_a 0.580480192519889
# test_score_W0_n 0.3209458717688664
# test_score_W0_a  0.24097659431013196
# all_train_score_W_Combined_n 0.6205703684324267
# all_train_score_W_Combined_a 0.615212350081883
# test_score_W_combined_n 0.3800692473776816
# test_score_W_combined_a 0.3049183240693888
# Combine Neurons Number :85
# all_train_score_W0_n 0.556959984945393
# all_train_score_W0_a 0.5551438736008604
# test_score_W0_n 0.27680762528453123
# test_score_W0_a  0.18167384446774895
# all_train_score_W_Combined_n 0.66126226417943
# all_train_score_W_Combined_a 0.6894926392123195
# test_score_W_combined_n 0.31355725673138996
# test_score_W_combined_a 0.264946142182388
# Combine Neurons Number :83
# all_train_score_W0_n 0.5908539759684113
# all_train_score_W0_a 0.5992600878450659
# test_score_W0_n 0.3902273635100572
# test_score_W0_a  0.27976245734556493
# all_train_score_W_Combined_n 0.6374266754704293
# all_train_score_W_Combined_a 0.6697684933206705
# test_score_W_combined_n 0.44079876405559065
# test_score_W_combined_a 0.39367326835926336
# Combine Neurons Number :84
# all_train_score_W0_n 0.5886876812052763
# all_train_score_W0_a 0.5977983790429752
# test_score_W0_n 0.32863145300464985
# test_score_W0_a  0.22718628295413248
# all_train_score_W_Combined_n 0.6166570656859124
# all_train_score_W_Combined_a 0.6345188136600651
# test_score_W_combined_n 0.39373937203246223
# test_score_W_combined_a 0.30932643665535525
# Combine Neurons Number :87
# all_train_score_W0_n 0.583100776259817
# all_train_score_W0_a 0.5564253135881668
# test_score_W0_n 0.2692250751786926
# test_score_W0_a  0.15859082163044477
# all_train_score_W_Combined_n 0.6242007559644897
# all_train_score_W_Combined_a 0.6376873573173124
# test_score_W_combined_n 0.4300464676910518
# test_score_W_combined_a 0.39649600355797804
# Combine Neurons Number :77
# all_train_score_W0_n 0.5406070121762699
# all_train_score_W0_a 0.525646860401301
# test_score_W0_n 0.2515301225623206
# test_score_W0_a  0.12441575088712073
# all_train_score_W_Combined_n 0.647872349727216
# all_train_score_W_Combined_a 0.6474868670634611
# test_score_W_combined_n 0.3723679396482625
# test_score_W_combined_a 0.2795117209177291
# Combine Neurons Number :86
# all_train_score_W0_n 0.5761876954403307
# all_train_score_W0_a 0.5543537657729666
# test_score_W0_n 0.2831001890696583
# test_score_W0_a  0.1489158633058963
# all_train_score_W_Combined_n 0.6251313115723909
# all_train_score_W_Combined_a 0.63463802878921
# test_score_W_combined_n 0.33757081344555134
# test_score_W_combined_a 0.2811762273046859
# Combine Neurons Number :84
# all_train_score_W0_n 0.545346766675945
# all_train_score_W0_a 0.5147336619837993
# test_score_W0_n 0.3783332804544026
# test_score_W0_a  0.29789147632206353
# all_train_score_W_Combined_n 0.5839712283263003
# all_train_score_W_Combined_a 0.5880125319237094
# test_score_W_combined_n 0.4014303503604575
# test_score_W_combined_a 0.3342907927479559
# Combine Neurons Number :87
# all_train_score_W0_n 0.5594962047527241
# all_train_score_W0_a 0.5767580494623291
# test_score_W0_n 0.27647380208563355
# test_score_W0_a  0.2059364211092678
# all_train_score_W_Combined_n 0.6347900988272493
# all_train_score_W_Combined_a 0.65476301667525
# test_score_W_combined_n 0.2902060327924738
# test_score_W_combined_a 0.2465236051502146
# Combine Neurons Number :83
# all_train_score_W0_n 0.6465064831557809
# all_train_score_W0_a 0.6386918855139301
# test_score_W0_n 0.3178658956006935
# test_score_W0_a  0.24246551596047647
# all_train_score_W_Combined_n 0.6737456700809932
# all_train_score_W_Combined_a 0.6919582838135783
# test_score_W_combined_n 0.4233118547993784
# test_score_W_combined_a 0.33589488075508794
# Combine Neurons Number :83
# all_train_score_W0_n 0.5520680240769499
# all_train_score_W0_a 0.5802987439250471
# test_score_W0_n 0.2996762366984547
# test_score_W0_a  0.2310643819877073
# all_train_score_W_Combined_n 0.6237929365526815
# all_train_score_W_Combined_a 0.6684459510331903
# test_score_W_combined_n 0.39736812356595314
# test_score_W_combined_a 0.3437241002089493
# Combine Neurons Number :85
# all_train_score_W0_n 0.4771775223822757
# all_train_score_W0_a 0.4585399857193266
# test_score_W0_n 0.3144490003756459
# test_score_W0_a  0.17414054252535915
# all_train_score_W_Combined_n 0.5267779494294883
# all_train_score_W_Combined_a 0.5180399638137807
# test_score_W_combined_n 0.31572633235121966
# test_score_W_combined_a 0.22315738390242787
# Combine Neurons Number :78
# all_train_score_W0_n 0.5487071303981648
# all_train_score_W0_a 0.5595831589654798
# test_score_W0_n 0.3964241896771899
# test_score_W0_a  0.3075008365093485
# all_train_score_W_Combined_n 0.5638473997635395
# all_train_score_W_Combined_a 0.5808799407238284
# test_score_W_combined_n 0.31913202888882003
# test_score_W_combined_a 0.27747026718014284
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :86
# all_train_score_W0_n 0.5088749785468812
# all_train_score_W0_a 0.5052371896587257
# test_score_W0_n 0.42882105444688157
# test_score_W0_a  0.3784667393055553
# all_train_score_W_Combined_n 0.5923476232098516
# all_train_score_W_Combined_a 0.5784789927731621
# test_score_W_combined_n 0.3681421669865871
# test_score_W_combined_a 0.2790338394904893
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :85
# all_train_score_W0_n 0.5386479399358102
# all_train_score_W0_a 0.5178943241998004
# test_score_W0_n 0.32002189882523363
# test_score_W0_a  0.30229663352858843
# all_train_score_W_Combined_n 0.5712661512558125
# all_train_score_W_Combined_a 0.5611581135288896
# test_score_W_combined_n 0.34944334429489476
# test_score_W_combined_a 0.23466547260035225
# Not good ari result !!!!!
# Combine Neurons Number :81
# all_train_score_W0_n 0.559823622437339
# all_train_score_W0_a 0.5808355604410704
# test_score_W0_n 0.2559487109795628
# test_score_W0_a  0.12882060779731502
# all_train_score_W_Combined_n 0.5902718844527601
# all_train_score_W_Combined_a 0.6086766496468019
# test_score_W_combined_n 0.3317493550499916
# test_score_W_combined_a 0.23465568610193693
# Combine Neurons Number :76
# all_train_score_W0_n 0.5688003001624
# all_train_score_W0_a 0.5638676728636675
# test_score_W0_n 0.31332466752682525
# test_score_W0_a  0.2286400866731061
# all_train_score_W_Combined_n 0.6477101103655823
# all_train_score_W_Combined_a 0.6450211537700492
# test_score_W_combined_n 0.3850404484800781
# test_score_W_combined_a 0.28716557769506207
# Combine Neurons Number :87
# all_train_score_W0_n 0.6448827871845061
# all_train_score_W0_a 0.6431869344787535
# test_score_W0_n 0.3640754011755085
# test_score_W0_a  0.22182614409796553
# all_train_score_W_Combined_n 0.6839900714881426
# all_train_score_W_Combined_a 0.6858186941630936
# test_score_W_combined_n 0.4174557232975895
# test_score_W_combined_a 0.3518767786329775
# Combine Neurons Number :88
# all_train_score_W0_n 0.5612466878050318
# all_train_score_W0_a 0.5223520116661848
# test_score_W0_n 0.3029694640957672
# test_score_W0_a  0.18424439615392688
# all_train_score_W_Combined_n 0.6463639342001948
# all_train_score_W_Combined_a 0.6178909132179176
# test_score_W_combined_n 0.3237398979334681
# test_score_W_combined_a 0.2068814376506684
# Combine Neurons Number :91
# all_train_score_W0_n 0.5839492295651809
# all_train_score_W0_a 0.5486613729957575
# test_score_W0_n 0.3976068120884451
# test_score_W0_a  0.2934163046355051
# all_train_score_W_Combined_n 0.6325831877350777
# all_train_score_W_Combined_a 0.6284754023424142
# test_score_W_combined_n 0.45207706975779627
# test_score_W_combined_a 0.41129083162379676
# Combine Neurons Number :84
# all_train_score_W0_n 0.5524379786809483
# all_train_score_W0_a 0.5325218419110982
# test_score_W0_n 0.4042640426042297
# test_score_W0_a  0.3698305764593807
# all_train_score_W_Combined_n 0.5686500783253866
# all_train_score_W_Combined_a 0.5515695822537284
# test_score_W_combined_n 0.4042674331920238
# test_score_W_combined_a 0.3669057023680152
# Not good ari result !!!!!
# Combine Neurons Number :80
# all_train_score_W0_n 0.6015080923710616
# all_train_score_W0_a 0.5968999390855135
# test_score_W0_n 0.3012418151612939
# test_score_W0_a  0.16832562718790692
# all_train_score_W_Combined_n 0.6355832989015688
# all_train_score_W_Combined_a 0.6610537750017684
# test_score_W_combined_n 0.4196181778449632
# test_score_W_combined_a 0.41568023655745956
# Combine Neurons Number :84
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.342179  0.063148  0.011529   0.318599  0.365759
# 1  test_score_W'  30.0  0.373480  0.046254  0.008445   0.356209  0.390752
# 2       combined  60.0  0.357830  0.057103  0.007372   0.343079  0.372581
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0313
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -2.1902
# 3                       Two side test p value =    0.0325
# 4                      Difference < 0 p value =    0.0163
# 5                      Difference > 0 p value =    0.9837
# 6                                   Cohen's d =   -0.5655
# 7                                   Hedge's g =   -0.5582
# 8                               Glass's delta =   -0.4957
# 9                                 Pearson's r =    0.2764
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.342179  0.063148  0.011529   0.318599  0.365759
# 1  test_score_W'  30.0  0.307415  0.060120  0.010976   0.284966  0.329864
# 2       combined  60.0  0.324797  0.063592  0.008210   0.308370  0.341224
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0348
# 1                          Degrees of freedom =   58.0000
# 2                                           t =    2.1839
# 3                       Two side test p value =    0.0330
# 4                      Difference < 0 p value =    0.9835
# 5                      Difference > 0 p value =    0.0165
# 6                                   Cohen's d =    0.5639
# 7                                   Hedge's g =    0.5566
# 8                               Glass's delta =    0.5505
# 9                                 Pearson's r =    0.2756
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)

# %%
unstable_repeat_num= 30
scope_num = 34
class_num = 4
dim_num = 5
best_num =18

elbow_num = 1
row = 2
column = 3
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
optimize_W.run( )   

#experiment = experiment.Experiment()
#experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
#print("*****************************************************************************************")
#print("Best Number SOM Comparision")
#print("*****************************************************************************************")
#experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# True Distribution :
# neuron data  **************** 0
# ****************
# neuron data  **************** 1
# ****************
# neuron data  **************** 2
# ****************
# neuron data  **************** 3
# ****************
# all_train_score_W0_n 0.303893782155487
# all_train_score_W0_a 0.24367462475915602
# test_score_W0_n 0.2566167766805607
# test_score_W0_a  0.12782625525629157
# cluster index  number 28
# neuron data  **************** 0
# ****************
# cluster index  number 17
# neuron data  **************** 1
# ****************
# cluster index  number 33
# neuron data  **************** 2
# ****************
# cluster index  number 9
# neuron data  **************** 3
# ****************
# cluster index  number 11
# neuron data  **************** 4
# ****************
# cluster index  number 15
# neuron data  **************** 5
# ****************
# cluster index  number 38
# neuron data  **************** 6
# ****************
# cluster index  number 7
# neuron data  **************** 7
# ****************
# cluster index  number 23
# neuron data  **************** 8
# ****************
# all_train_score_W_Combined_n 0.2476274596348868
# all_train_score_W_Combined_a 0.18883694792019773
# test_score_W_combined_n 0.2382369130222287
# test_score_W_combined_a 0.1015618475752459
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :9
