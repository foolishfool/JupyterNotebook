# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# self.continuous_feature_num 2
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num =2
best_num = 48
interval = 5


features_chosen = [0,1,2,3,4,5,6,7,8]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
# Out:
# Neuron number: 2
# test_score_W0_p0.14666666666666667
# test_score_W0_n 0.010070457087321917
# test_score_W0_a  0.0003348648429734724
# test_score_W_combine_p 0.12666666666666668
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 7
# test_score_W0_p0.18333333333333332
# test_score_W0_n 0.029304234497896063
# test_score_W0_a  0.0022113926329432676
# test_score_W_combine_p 0.17666666666666667
# test_score_W_combine_n 0.037383858465604686
# test_score_W_combine_a 0.003351508086075982
# Not good purity result !!!!!
# Neuron number: 12
# test_score_W0_p0.22
# test_score_W0_n 0.05521177593144658
# test_score_W0_a  0.013909825755127083
# test_score_W_combine_p 0.18666666666666668
# test_score_W_combine_n 0.046669719972948845
# test_score_W_combine_a 0.0066996005500330165
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 17
# test_score_W0_p0.25333333333333335
# test_score_W0_n 0.07483985907966058
# test_score_W0_a  0.027032734846099915
# test_score_W_combine_p 0.21666666666666667
# test_score_W_combine_n 0.06192513373016372
# test_score_W_combine_a 0.006168864022609587
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 22
# test_score_W0_p0.25666666666666665
# test_score_W0_n 0.08298108465797709
# test_score_W0_a  0.025482685088285464
# test_score_W_combine_p 0.23
# test_score_W_combine_n 0.06144740102994193
# test_score_W_combine_a 0.016431761430251074
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 27
# test_score_W0_p0.27
# test_score_W0_n 0.08649859395112641
# test_score_W0_a  0.035105894314338214
# test_score_W_combine_p 0.23
# test_score_W_combine_n 0.0708657616662659
# test_score_W_combine_a 0.01896575751972877
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 32
# test_score_W0_p0.29333333333333333
# test_score_W0_n 0.11159787439738406
# test_score_W0_a  0.03564266052456667
# test_score_W_combine_p 0.23666666666666666
# test_score_W_combine_n 0.07837741558146333
# test_score_W_combine_a 0.017140292416706608
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 37
# test_score_W0_p0.25
# test_score_W0_n 0.06317839247553021
# test_score_W0_a  0.017672525614326653
# test_score_W_combine_p 0.25333333333333335
# test_score_W_combine_n 0.069806306553391
# test_score_W_combine_a 0.02293524967184802
# Neuron number: 42
# test_score_W0_p0.32
# test_score_W0_n 0.11701381938056729
# test_score_W0_a  0.04899108045697285
# test_score_W_combine_p 0.25
# test_score_W_combine_n 0.07997728714669643
# test_score_W_combine_a 0.018866284003703552
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 47
# test_score_W0_p0.2866666666666667
# test_score_W0_n 0.0919808084619895
# test_score_W0_a  0.03449901649684301
# test_score_W_combine_p 0.25333333333333335
# test_score_W_combine_n 0.0764199364675806
# test_score_W_combine_a 0.027175253954063436
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 52
# test_score_W0_p0.35
# test_score_W0_n 0.13364779213682
# test_score_W0_a  0.06871536791174414
# test_score_W_combine_p 0.27666666666666667
# test_score_W_combine_n 0.09751499324667225
# test_score_W_combine_a 0.03171230216354478
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 57
# test_score_W0_p0.30666666666666664
# test_score_W0_n 0.11503483234398793
# test_score_W0_a  0.04772025678376436
# test_score_W_combine_p 0.26666666666666666
# test_score_W_combine_n 0.08116283848089273
# test_score_W_combine_a 0.025886117750650858
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 62
# test_score_W0_p0.32666666666666666
# test_score_W0_n 0.11729524557511081
# test_score_W0_a  0.0475688318174202
# test_score_W_combine_p 0.2866666666666667
# test_score_W_combine_n 0.10518362272343385
# test_score_W_combine_a 0.03842623513298141
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 67
# test_score_W0_p0.2866666666666667
# test_score_W0_n 0.09131082236862684
# test_score_W0_a  0.04012609393668348
# test_score_W_combine_p 0.27
# test_score_W_combine_n 0.08425696679593418
# test_score_W_combine_a 0.03238703928285842
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 72
# test_score_W0_p0.37
# test_score_W0_n 0.15996246903885017
# test_score_W0_a  0.07912876055027364
# test_score_W_combine_p 0.31333333333333335
# test_score_W_combine_n 0.11995966971028314
# test_score_W_combine_a 0.0432053553288065
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 77
# test_score_W0_p0.3933333333333333
# test_score_W0_n 0.16908005472585805
# test_score_W0_a  0.09504887901560355
# test_score_W_combine_p 0.31
# test_score_W_combine_n 0.11699174539959227
# test_score_W_combine_a 0.04951755689509077
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 82
# test_score_W0_p0.2966666666666667
# test_score_W0_n 0.11077292992088056
# test_score_W0_a  0.04449564574659762
# test_score_W_combine_p 0.30333333333333334
# test_score_W_combine_n 0.11434728851221238
# test_score_W_combine_a 0.03954264848539777
# Not good ari !!!!!
# Neuron number: 87
# test_score_W0_p0.37666666666666665
# test_score_W0_n 0.1511245222571207
# test_score_W0_a  0.08551345355009582
# test_score_W_combine_p 0.3233333333333333
# test_score_W_combine_n 0.12237041347395189
# test_score_W_combine_a 0.054169121260930084
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 92
# test_score_W0_p0.35
# test_score_W0_n 0.1398404348382852
# test_score_W0_a  0.06408581886928408
# test_score_W_combine_p 0.29333333333333333
# test_score_W_combine_n 0.10993452309322979
# test_score_W_combine_a 0.04156872529587129
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 97
# test_score_W0_p0.2633333333333333
# test_score_W0_n 0.08045684628146416
# test_score_W0_a  0.02162177639523442
# test_score_W_combine_p 0.3233333333333333
# test_score_W_combine_n 0.12712317136341814
# test_score_W_combine_a 0.050198597317304035
# all_test_score_W0_p mean 0.29
# all_test_score_W0_n mean 0.09956014247039521
# all_test_score_W0_a mean 0.0417453782574589
# all_test_score_W_combine_p mean 0.2563333333333333
# all_test_score_W_combine_n mean 0.08308590267068386
# all_test_score_W_combine_a mean 0.0272174135284228
# Purity T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_p  20.0  0.290000  0.063403  0.014177   0.260327
# 1  all_test_score_W_combine_p  20.0  0.256333  0.052179  0.011668   0.231913
# 2                    combined  40.0  0.273167  0.059795  0.009454   0.254043
#
#    Interval
# 0  0.319673
# 1  0.280754
# 2  0.292290
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_p - all_test_sco...   0.0337
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    1.8336
# 3                           Two side test p value =    0.0746
# 4                          Difference < 0 p value =    0.9627
# 5                          Difference > 0 p value =    0.0373
# 6                                       Cohen's d =    0.5798
# 7                                       Hedge's g =    0.5683
# 8                                  Glass's delta1 =    0.5310
# 9                                Point-Biserial r =    0.2851
# NMI T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_n  20.0  0.099560  0.041572  0.009296   0.080104
# 1  all_test_score_W_combine_n  20.0  0.083086  0.032467  0.007260   0.067891
# 2                    combined  40.0  0.091323  0.037750  0.005969   0.079250
#
#    Interval
# 0  0.119016
# 1  0.098281
# 2  0.103396
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_n - all_test_sco...   0.0165
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    1.3968
# 3                           Two side test p value =    0.1706
# 4                          Difference < 0 p value =    0.9147
# 5                          Difference > 0 p value =    0.0853
# 6                                       Cohen's d =    0.4417
# 7                                       Hedge's g =    0.4329
# 8                                  Glass's delta1 =    0.3963
# 9                                Point-Biserial r =    0.2210
# ARI Score T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_a  20.0  0.041745  0.026323  0.005886   0.029426
# 1  all_test_score_W_combine_a  20.0  0.027217  0.016364  0.003659   0.019559
# 2                    combined  40.0  0.034481  0.022851  0.003613   0.027173
#
#    Interval
# 0  0.054065
# 1  0.034876
# 2  0.041789
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_a - all_test_sco...   0.0145
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    2.0962
# 3                           Two side test p value =    0.0428
# 4                          Difference < 0 p value =    0.9786
# 5                          Difference > 0 p value =    0.0214
# 6                                       Cohen's d =    0.6629
# 7                                       Hedge's g =    0.6497
# 8                                  Glass's delta1 =    0.5519
# 9                                Point-Biserial r =    0.3219
