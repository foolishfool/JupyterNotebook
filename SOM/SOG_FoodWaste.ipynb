# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Food Waste data and research.csv",encoding='latin-1')
csv = csv.drop(columns=['Source'])
csv_original_encode = csv

dataread.hash_encoding(csv_original_encode,["Country","Region"])

dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Confidence in estimate")
dataread.label_encoding(csv,"Region")



                                 
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Confidence in estimate")
# Out:
# self.data_continuous_indexes ['Country', 'combined figures (kg/capita/year)', 'Household estimate (kg/capita/year)', 'Household estimate (tonnes/year)', 'Retail estimate (tonnes/year)', 'Food service estimate (tonnes/year)', 'M49 code']
# self.continuous_feature_num 7
#  column number self.data_train_discrete 3

# %%
#fuzzy vs probability
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3



experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
# all_train_score_W0_p 0.62
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.578125
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.62
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p 0.578125
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 7
# all_train_score_W0_p 0.6266666666666667
# all_train_score_W0_n 0.042147983465717714
# all_train_score_W0_a 0.021141120773895312
# test_score_W0_p0.578125
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.6266666666666667
# all_train_score_W_combine_n 0.042147983465717714
# all_train_score_W_combine_a 0.021141120773895312
# test_score_W_combine_p 0.578125
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# neuron unit number: 10
# all_train_score_W0_p 0.6266666666666667
# all_train_score_W0_n 0.042147983465717714
# all_train_score_W0_a 0.021141120773895312
# test_score_W0_p0.578125
# test_score_W0_n 0.10845991505231128
# test_score_W0_a  0.08283911481875898
# all_train_score_W_combine_p 0.6266666666666667
# all_train_score_W_combine_n 0.042147983465717714
# all_train_score_W_combine_a 0.021141120773895312
# test_score_W_combine_p 0.578125
# test_score_W_combine_n 0.10845991505231128
# test_score_W_combine_a 0.08283911481875898
# neuron unit number: 13
# all_train_score_W0_p 0.6266666666666667
# all_train_score_W0_n 0.042147983465717714
# all_train_score_W0_a 0.021141120773895312
# test_score_W0_p0.59375
# test_score_W0_n 0.10717714583256725
# test_score_W0_a  0.06182583255263805
# all_train_score_W_combine_p 0.6266666666666667
# all_train_score_W_combine_n 0.042147983465717714
# all_train_score_W_combine_a 0.021141120773895312
# test_score_W_combine_p 0.59375
# test_score_W_combine_n 0.10717714583256725
# test_score_W_combine_a 0.06182583255263805
# neuron unit number: 16
# all_train_score_W0_p 0.6466666666666666
# all_train_score_W0_n 0.15685073049490628
# all_train_score_W0_a 0.1471456796894925
# test_score_W0_p0.640625
# test_score_W0_n 0.17725538367835278
# test_score_W0_a  0.1564606622479119
# all_train_score_W_combine_p 0.6466666666666666
# all_train_score_W_combine_n 0.15685073049490628
# all_train_score_W_combine_a 0.1471456796894925
# test_score_W_combine_p 0.640625
# test_score_W_combine_n 0.17725538367835278
# test_score_W_combine_a 0.1564606622479119
# neuron unit number: 19
# all_train_score_W0_p 0.6466666666666666
# all_train_score_W0_n 0.16175360749019005
# all_train_score_W0_a 0.15046681939964412
# test_score_W0_p0.65625
# test_score_W0_n 0.20751783044759273
# test_score_W0_a  0.1795885885161695
# all_train_score_W_combine_p 0.6466666666666666
# all_train_score_W_combine_n 0.16175360749019005
# all_train_score_W_combine_a 0.15046681939964412
# test_score_W_combine_p 0.65625
# test_score_W_combine_n 0.20751783044759273
# test_score_W_combine_a 0.1795885885161695
# neuron unit number: 22
# all_train_score_W0_p 0.66
# all_train_score_W0_n 0.18955559920843942
# all_train_score_W0_a 0.17047535841266293
# test_score_W0_p0.6875
# test_score_W0_n 0.21322137873256003
# test_score_W0_a  0.22988387137742994
# all_train_score_W_combine_p 0.66
# all_train_score_W_combine_n 0.18955559920843942
# all_train_score_W_combine_a 0.17047535841266293
# test_score_W_combine_p 0.6875
# test_score_W_combine_n 0.21322137873256003
# test_score_W_combine_a 0.22988387137742994
# neuron unit number: 25
# all_train_score_W0_p 0.66
# all_train_score_W0_n 0.20507609153481243
# all_train_score_W0_a 0.18601917911974544
# test_score_W0_p0.734375
# test_score_W0_n 0.2617766055823423
# test_score_W0_a  0.3307665602953031
# all_train_score_W_combine_p 0.66
# all_train_score_W_combine_n 0.20507609153481243
# all_train_score_W_combine_a 0.18601917911974544
# test_score_W_combine_p 0.734375
# test_score_W_combine_n 0.2617766055823423
# test_score_W_combine_a 0.3307665602953031
# neuron unit number: 28
# all_train_score_W0_p 0.6666666666666666
# all_train_score_W0_n 0.22013508188785064
# all_train_score_W0_a 0.1954339883241872
# test_score_W0_p0.734375
# test_score_W0_n 0.2617766055823423
# test_score_W0_a  0.3307665602953031
# all_train_score_W_combine_p 0.6666666666666666
# all_train_score_W_combine_n 0.22013508188785064
# all_train_score_W_combine_a 0.1954339883241872
# test_score_W_combine_p 0.734375
# test_score_W_combine_n 0.2617766055823423
# test_score_W_combine_a 0.3307665602953031
# neuron unit number: 31
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.2587171414947945
# all_train_score_W0_a 0.2090801674049762
# test_score_W0_p0.734375
# test_score_W0_n 0.2617766055823423
# test_score_W0_a  0.3307665602953031
# all_train_score_W_combine_p 0.68
# all_train_score_W_combine_n 0.2587171414947945
# all_train_score_W_combine_a 0.2090801674049762
# test_score_W_combine_p 0.734375
# test_score_W_combine_n 0.2617766055823423
# test_score_W_combine_a 0.3307665602953031
# neuron unit number: 34
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.2638847360180301
# all_train_score_W0_a 0.21198298246772954
# test_score_W0_p0.734375
# test_score_W0_n 0.29354564971322067
# test_score_W0_a  0.32159908786431984
# all_train_score_W_combine_p 0.68
# all_train_score_W_combine_n 0.2638847360180301
# all_train_score_W_combine_a 0.21198298246772954
# test_score_W_combine_p 0.734375
# test_score_W_combine_n 0.29354564971322067
# test_score_W_combine_a 0.32159908786431984
# neuron unit number: 37
# all_train_score_W0_p 0.72
# all_train_score_W0_n 0.28201699807470765
# all_train_score_W0_a 0.2721816224694641
# test_score_W0_p0.734375
# test_score_W0_n 0.30701171432196644
# test_score_W0_a  0.3143592523965849
# all_train_score_W_combine_p 0.72
# all_train_score_W_combine_n 0.28201699807470765
# all_train_score_W_combine_a 0.2721816224694641
# test_score_W_combine_p 0.734375
# test_score_W_combine_n 0.30701171432196644
# test_score_W_combine_a 0.3143592523965849
# neuron unit number: 40
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.3236426936389299
# all_train_score_W0_a 0.30092789557513805
# test_score_W0_p0.734375
# test_score_W0_n 0.30701171432196644
# test_score_W0_a  0.3143592523965849
# all_train_score_W_combine_p 0.7333333333333333
# all_train_score_W_combine_n 0.3236426936389299
# all_train_score_W_combine_a 0.30092789557513805
# test_score_W_combine_p 0.734375
# test_score_W_combine_n 0.30701171432196644
# test_score_W_combine_a 0.3143592523965849
# neuron unit number: 43
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.34475915944040697
# all_train_score_W0_a 0.31245279837302015
# test_score_W0_p0.75
# test_score_W0_n 0.34607926520507565
# test_score_W0_a  0.3276363441742636
# all_train_score_W_combine_p 0.74
# all_train_score_W_combine_n 0.34475915944040697
# all_train_score_W_combine_a 0.31245279837302015
# test_score_W_combine_p 0.75
# test_score_W_combine_n 0.34607926520507565
# test_score_W_combine_a 0.3276363441742636
# neuron unit number: 46
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.3543800162491038
# all_train_score_W0_a 0.3246087731381938
# test_score_W0_p0.75
# test_score_W0_n 0.34607926520507565
# test_score_W0_a  0.3276363441742636
# all_train_score_W_combine_p 0.7533333333333333
# all_train_score_W_combine_n 0.3466947110405207
# all_train_score_W_combine_a 0.33907719062955927
# test_score_W_combine_p 0.75
# test_score_W_combine_n 0.36736215474444417
# test_score_W_combine_a 0.3561782716249645
# neuron unit number: 49
# all_train_score_W0_p 0.7666666666666667
# all_train_score_W0_n 0.3833474979027841
# all_train_score_W0_a 0.36763120591455806
# test_score_W0_p0.765625
# test_score_W0_n 0.3861955073386455
# test_score_W0_a  0.3942811050288093
# all_train_score_W_combine_p 0.7666666666666667
# all_train_score_W_combine_n 0.3833474979027841
# all_train_score_W_combine_a 0.36763120591455806
# test_score_W_combine_p 0.765625
# test_score_W_combine_n 0.3861955073386455
# test_score_W_combine_a 0.3942811050288093
# test_score_W0_p mean 0.6865234375
# test_score_W_combine_p mean 0.6865234375
# test_score_W0_n mean 0.2240552866622726
# test_score_W_combine_n mean 0.22538546725848313
# test_score_W0_a mean 0.23142307102710277
# test_score_W_combine_a mean 0.23320694149277157
# NMI T-Test
#           Variable     N     Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.20441  0.122815  0.030704   0.138967  0.269854
# 1  train_W_combine  16.0  0.20393  0.122203  0.030551   0.138812  0.269047
# 2         combined  32.0  0.20417  0.120518  0.021305   0.160719  0.247621
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =    0.0005
# 1                       Degrees of freedom =   30.0000
# 2                                        t =    0.0111
# 3                    Two side test p value =    0.9912
# 4                   Difference < 0 p value =    0.5044
# 5                   Difference > 0 p value =    0.4956
# 6                                Cohen's d =    0.0039
# 7                                Hedge's g =    0.0038
# 8                           Glass's delta1 =    0.0039
# 9                         Point-Biserial r =    0.0020
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.224055  0.118021  0.029505   0.161166  0.286944
# 1  test_W_combine  16.0  0.225385  0.119598  0.029899   0.161656  0.289115
# 2        combined  32.0  0.224720  0.116882  0.020662   0.182580  0.266861
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0013
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -0.0317
# 3                  Two side test p value =    0.9749
# 4                 Difference < 0 p value =    0.4875
# 5                 Difference > 0 p value =    0.5125
# 6                              Cohen's d =   -0.0112
# 7                              Hedge's g =   -0.0109
# 8                         Glass's delta1 =   -0.0113
# 9                       Point-Biserial r =   -0.0058
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.181989  0.118043  0.029511   0.119089  0.244890
# 1  train_W_combine  16.0  0.182894  0.119258  0.029814   0.119346  0.246442
# 2         combined  32.0  0.182442  0.116723  0.020634   0.140358  0.224525
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0009
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -0.0216
# 3                    Two side test p value =    0.9829
# 4                   Difference < 0 p value =    0.4915
# 5                   Difference > 0 p value =    0.5085
# 6                                Cohen's d =   -0.0076
# 7                                Hedge's g =   -0.0074
# 8                           Glass's delta1 =   -0.0077
# 9                         Point-Biserial r =   -0.0039
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.231423  0.132362  0.033090   0.160892  0.301954
# 1  test_W_combine  16.0  0.233207  0.133928  0.033482   0.161842  0.304572
# 2        combined  32.0  0.232315  0.130985  0.023155   0.185090  0.279540
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0018
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -0.0379
# 3                  Two side test p value =    0.9700
# 4                 Difference < 0 p value =    0.4850
# 5                 Difference > 0 p value =    0.5150
# 6                              Cohen's d =   -0.0134
# 7                              Hedge's g =   -0.0131
# 8                         Glass's delta1 =   -0.0135
# 9                       Point-Biserial r =   -0.0069
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.677917  0.048486  0.012122   0.652080  0.703753
# 1  train_W_combine  16.0  0.678333  0.049141  0.012285   0.652148  0.704519
# 2         combined  32.0  0.678125  0.048021  0.008489   0.660811  0.695439
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0004
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -0.0241
# 3                    Two side test p value =    0.9809
# 4                   Difference < 0 p value =    0.4904
# 5                   Difference > 0 p value =    0.5096
# 6                                Cohen's d =   -0.0085
# 7                                Hedge's g =   -0.0083
# 8                           Glass's delta1 =   -0.0086
# 9                         Point-Biserial r =   -0.0044
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.686523  0.070680  0.017670   0.648860  0.724186
# 1  test_W_combine  16.0  0.686523  0.070680  0.017670   0.648860  0.724186
# 2        combined  32.0  0.686523  0.069531  0.012291   0.661455  0.711592
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =       0.0
# 1                     Degrees of freedom =      30.0
# 2                                      t =       0.0
# 3                  Two side test p value =       1.0
# 4                 Difference < 0 p value =       0.5
# 5                 Difference > 0 p value =       0.5
# 6                              Cohen's d =       0.0
# 7                              Hedge's g =       0.0
# 8                         Glass's delta1 =       0.0
# 9                       Point-Biserial r =       0.0

# %%
#new binary encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3



experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
# all_train_score_W0_p 0.6733333333333333
# all_train_score_W0_n 0.10443878784166803
# all_train_score_W0_a 0.1765484670622553
# test_score_W0_p0.671875
# test_score_W0_n 0.17819402155410757
# test_score_W0_a  0.1776826405192653
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.3516716489546943
# all_train_score_W_combine_a 0.35958140486305945
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6856840403085973
# test_score_W_combine_a 0.7533840342443252
# neuron unit number: 7
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.20115312006214559
# all_train_score_W0_a 0.27511630676455917
# test_score_W0_p0.75
# test_score_W0_n 0.33811457422659635
# test_score_W0_a  0.3768813057874254
# all_train_score_W_combine_p 0.7666666666666667
# all_train_score_W_combine_n 0.31054796050430955
# all_train_score_W_combine_a 0.3653600825181716
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.5998695780162709
# test_score_W_combine_a 0.6477421248698253
# neuron unit number: 10
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.24887109953871533
# all_train_score_W0_a 0.3365858538295615
# test_score_W0_p0.84375
# test_score_W0_n 0.5193194043223739
# test_score_W0_a  0.571725912581701
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.3551027213326078
# all_train_score_W_combine_a 0.39646122165970166
# test_score_W_combine_p 0.84375
# test_score_W_combine_n 0.5183205839663988
# test_score_W_combine_a 0.5854795677287794
# Not good nmi result for discrete features !!!!!
# neuron unit number: 13
# all_train_score_W0_p 0.7133333333333334
# all_train_score_W0_n 0.2006169947046647
# all_train_score_W0_a 0.2836740143858907
# test_score_W0_p0.8125
# test_score_W0_n 0.4102642608594148
# test_score_W0_a  0.45873126864284514
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.29270512758809186
# all_train_score_W_combine_a 0.3557791649040035
# test_score_W_combine_p 0.828125
# test_score_W_combine_n 0.513822019791955
# test_score_W_combine_a 0.553000075246432
# neuron unit number: 16
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.23489689443639805
# all_train_score_W0_a 0.3283285683768271
# test_score_W0_p0.796875
# test_score_W0_n 0.3858397974903989
# test_score_W0_a  0.4854806620688024
# all_train_score_W_combine_p 0.7866666666666666
# all_train_score_W_combine_n 0.36345486379581116
# all_train_score_W_combine_a 0.41861223180918966
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.652590205682917
# test_score_W_combine_a 0.6287645801954534
# neuron unit number: 19
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.2670811438760867
# all_train_score_W0_a 0.3460605417569514
# test_score_W0_p0.828125
# test_score_W0_n 0.43763630110002416
# test_score_W0_a  0.5224441573336466
# all_train_score_W_combine_p 0.7266666666666667
# all_train_score_W_combine_n 0.24709039816371317
# all_train_score_W_combine_a 0.2925187909046447
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6581447124487259
# test_score_W_combine_a 0.7018433930343386
# neuron unit number: 22
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.2364464519545466
# all_train_score_W0_a 0.3124466122712489
# test_score_W0_p0.78125
# test_score_W0_n 0.3581021557358684
# test_score_W0_a  0.4115230300749715
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.42977982446008234
# all_train_score_W_combine_a 0.4927940225996919
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6906710101669784
# test_score_W_combine_a 0.7204079457020006
# neuron unit number: 25
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.28810638167192926
# all_train_score_W0_a 0.319895282185539
# test_score_W0_p0.84375
# test_score_W0_n 0.524969141296527
# test_score_W0_a  0.583881013135341
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.4161499350223656
# all_train_score_W_combine_a 0.49368918423407
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6673356749569541
# test_score_W_combine_a 0.7299129883594562
# neuron unit number: 28
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.21447125116972132
# all_train_score_W0_a 0.3144477258415609
# test_score_W0_p0.8125
# test_score_W0_n 0.41483138531894503
# test_score_W0_a  0.4786305828129938
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.339968549347935
# all_train_score_W_combine_a 0.3939660436486456
# test_score_W_combine_p 0.828125
# test_score_W_combine_n 0.5433527229703731
# test_score_W_combine_a 0.5528631096943173
# neuron unit number: 31
# all_train_score_W0_p 0.7533333333333333
# all_train_score_W0_n 0.3168770958661467
# all_train_score_W0_a 0.40961671565902674
# test_score_W0_p0.859375
# test_score_W0_n 0.5493629230912289
# test_score_W0_a  0.6342995426964892
# all_train_score_W_combine_p 0.7466666666666667
# all_train_score_W_combine_n 0.27895771497976085
# all_train_score_W_combine_a 0.3127812329043149
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.5761511506476131
# test_score_W_combine_a 0.6202878252590663
# Not good ari result for discrete features  !!!!!
# neuron unit number: 34
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.20163564864406694
# all_train_score_W0_a 0.23918456988884346
# test_score_W0_p0.796875
# test_score_W0_n 0.37398773890595016
# test_score_W0_a  0.4345259519846847
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.38358867483297276
# all_train_score_W_combine_a 0.3916801878505072
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6684234136672929
# test_score_W_combine_a 0.6630075201516642
# neuron unit number: 37
# all_train_score_W0_p 0.7533333333333333
# all_train_score_W0_n 0.2677749400548387
# all_train_score_W0_a 0.3562964495102467
# test_score_W0_p0.859375
# test_score_W0_n 0.5154014550854685
# test_score_W0_a  0.6092839227046314
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.35811813862411385
# all_train_score_W_combine_a 0.4290355933838473
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.6120912918003845
# test_score_W_combine_a 0.6656929651125709
# neuron unit number: 40
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.2783487610074369
# all_train_score_W0_a 0.3439207090468211
# test_score_W0_p0.90625
# test_score_W0_n 0.6805973624063897
# test_score_W0_a  0.7748187394048425
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.2896287072157759
# all_train_score_W_combine_a 0.3628757967560151
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.6535817466505217
# test_score_W_combine_a 0.7195092532998882
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 43
# all_train_score_W0_p 0.7666666666666667
# all_train_score_W0_n 0.27648557352145253
# all_train_score_W0_a 0.38868206745884065
# test_score_W0_p0.859375
# test_score_W0_n 0.5285048241107222
# test_score_W0_a  0.6454494810902264
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.39774476102484524
# all_train_score_W_combine_a 0.4056890114641915
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.670869083199108
# test_score_W_combine_a 0.709333601143097
# neuron unit number: 46
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.2646390309057722
# all_train_score_W0_a 0.35986092324984553
# test_score_W0_p0.859375
# test_score_W0_n 0.5659323267222368
# test_score_W0_a  0.5958371943830637
# all_train_score_W_combine_p 0.7533333333333333
# all_train_score_W_combine_n 0.2828908848736709
# all_train_score_W_combine_a 0.3234050686639389
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6662547197571403
# test_score_W_combine_a 0.7254261424804542
# neuron unit number: 49
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.20572469517589237
# all_train_score_W0_a 0.2954221803448811
# test_score_W0_p0.875
# test_score_W0_n 0.5990886992016348
# test_score_W0_a  0.6643133075795924
# all_train_score_W_combine_p 0.82
# all_train_score_W_combine_n 0.4521887308808624
# all_train_score_W_combine_a 0.48483227389558686
# test_score_W_combine_p 0.8125
# test_score_W_combine_n 0.5434278005581673
# test_score_W_combine_a 0.5648392748531641
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# test_score_W0_p mean 0.822265625
# test_score_W_combine_p mean 0.87109375
# test_score_W0_n mean 0.4612591482142429
# test_score_W_combine_n mean 0.6200368596618374
# test_score_W0_a mean 0.5265942945500326
# test_score_W_combine_a mean 0.6588434000859271
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.237973  0.050283  0.012571   0.211179  0.264767
# 1  train_W_combine  16.0  0.346849  0.059684  0.014921   0.315046  0.378653
# 2         combined  32.0  0.292411  0.077499  0.013700   0.264470  0.320353
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1089
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -5.5804
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.9730
# 7                                Hedge's g =   -1.9232
# 8                           Glass's delta1 =   -2.1653
# 9                         Point-Biserial r =   -0.7137
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.461259  0.122545  0.030636   0.395960  0.526559
# 1  test_W_combine  16.0  0.620037  0.062186  0.015547   0.586900  0.653174
# 2        combined  32.0  0.540648  0.125074  0.022110   0.495554  0.585742
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1588
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -4.6217
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.6340
# 7                              Hedge's g =   -1.5928
# 8                         Glass's delta1 =   -1.2957
# 9                       Point-Biserial r =   -0.6449
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.317880  0.056753  0.014188   0.287639  0.348122
# 1  train_W_combine  16.0  0.392441  0.061212  0.015303   0.359824  0.425059
# 2         combined  32.0  0.355161  0.069327  0.012255   0.330166  0.380156
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0746
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -3.5729
# 3                    Two side test p value =    0.0012
# 4                   Difference < 0 p value =    0.0006
# 5                   Difference > 0 p value =    0.9994
# 6                                Cohen's d =   -1.2632
# 7                                Hedge's g =   -1.2314
# 8                           Glass's delta1 =   -1.3138
# 9                         Point-Biserial r =   -0.5464
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.526594  0.140889  0.035222   0.451520  0.601669
# 1  test_W_combine  16.0  0.658843  0.068080  0.017020   0.622566  0.695121
# 2        combined  32.0  0.592719  0.127910  0.022611   0.546603  0.638835
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1322
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -3.3807
# 3                  Two side test p value =    0.0020
# 4                 Difference < 0 p value =    0.0010
# 5                 Difference > 0 p value =    0.9990
# 6                              Cohen's d =   -1.1953
# 7                              Hedge's g =   -1.1651
# 8                         Glass's delta1 =   -0.9387
# 9                       Point-Biserial r =   -0.5252
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.732917  0.022240  0.005560   0.721066  0.744768
# 1  train_W_combine  16.0  0.776250  0.025644  0.006411   0.762586  0.789914
# 2         combined  32.0  0.754583  0.032282  0.005707   0.742945  0.766222
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0433
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -5.1064
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -1.8054
# 7                                Hedge's g =   -1.7599
# 8                           Glass's delta1 =   -1.9484
# 9                         Point-Biserial r =   -0.6819
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.822266  0.056156  0.014039   0.792342  0.852189
# 1  test_W_combine  16.0  0.871094  0.029920  0.007480   0.855151  0.887037
# 2        combined  32.0  0.846680  0.050738  0.008969   0.828387  0.864973
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0488
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -3.0695
# 3                  Two side test p value =    0.0045
# 4                 Difference < 0 p value =    0.0023
# 5                 Difference > 0 p value =    0.9977
# 6                              Cohen's d =   -1.0852
# 7                              Hedge's g =   -1.0579
# 8                         Glass's delta1 =   -0.8695
# 9                       Point-Biserial r =   -0.4889

# %%
#new hash encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3



experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
# all_train_score_W0_p 0.6466666666666666
# all_train_score_W0_n 0.11604899787545829
# all_train_score_W0_a 0.19089043211194254
# test_score_W0_p0.75
# test_score_W0_n 0.29122501881400076
# test_score_W0_a  0.3484092160659407
# all_train_score_W_combine_p 0.84
# all_train_score_W_combine_n 0.46612961487810517
# all_train_score_W_combine_a 0.5583506022505696
# test_score_W_combine_p 0.828125
# test_score_W_combine_n 0.5122288421676002
# test_score_W_combine_a 0.5397196722540228
# neuron unit number: 7
# all_train_score_W0_p 0.6866666666666666
# all_train_score_W0_n 0.22130145346932198
# all_train_score_W0_a 0.22455619194157322
# test_score_W0_p0.78125
# test_score_W0_n 0.4471595872462828
# test_score_W0_a  0.4350273758136246
# all_train_score_W_combine_p 0.7733333333333333
# all_train_score_W_combine_n 0.3334017895476546
# all_train_score_W_combine_a 0.41437379176047207
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.6147777524135831
# test_score_W_combine_a 0.589604532280044
# neuron unit number: 10
# all_train_score_W0_p 0.7133333333333334
# all_train_score_W0_n 0.24615496858542524
# all_train_score_W0_a 0.2660621519516096
# test_score_W0_p0.78125
# test_score_W0_n 0.4098856114465084
# test_score_W0_a  0.45914586092992843
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.40212668225520787
# all_train_score_W_combine_a 0.45181788118178906
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6442880558260461
# test_score_W_combine_a 0.6798620720945532
# neuron unit number: 13
# all_train_score_W0_p 0.7666666666666667
# all_train_score_W0_n 0.3456709497973026
# all_train_score_W0_a 0.39489028487274846
# test_score_W0_p0.859375
# test_score_W0_n 0.62198984306321
# test_score_W0_a  0.5975709063530904
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.4088472134425848
# all_train_score_W_combine_a 0.44520380237365853
# test_score_W_combine_p 0.84375
# test_score_W_combine_n 0.4751427389578657
# test_score_W_combine_a 0.5213298751963882
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 16
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.2819726801150114
# all_train_score_W0_a 0.25146210308746114
# test_score_W0_p0.8125
# test_score_W0_n 0.4588326676260311
# test_score_W0_a  0.48370102074415544
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.38053312220288243
# all_train_score_W_combine_a 0.46505403285086183
# test_score_W_combine_p 0.78125
# test_score_W_combine_n 0.4093688204928438
# test_score_W_combine_a 0.4073378403574314
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 19
# all_train_score_W0_p 0.72
# all_train_score_W0_n 0.25079346357872234
# all_train_score_W0_a 0.2981891538052807
# test_score_W0_p0.84375
# test_score_W0_n 0.5369345030857503
# test_score_W0_a  0.5537702774971774
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.41655099331922135
# all_train_score_W_combine_a 0.45012848149662177
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5887537326316182
# test_score_W_combine_a 0.6335229882956641
# neuron unit number: 22
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.2736604912126404
# all_train_score_W0_a 0.3169998114110466
# test_score_W0_p0.84375
# test_score_W0_n 0.5376235699673813
# test_score_W0_a  0.6012401904790161
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.41420476863260697
# all_train_score_W_combine_a 0.4628833689879219
# test_score_W_combine_p 0.828125
# test_score_W_combine_n 0.49497232071168057
# test_score_W_combine_a 0.5198183070654081
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 25
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.28550705823342354
# all_train_score_W0_a 0.3197420013865384
# test_score_W0_p0.828125
# test_score_W0_n 0.4857335531936912
# test_score_W0_a  0.5354448219080539
# all_train_score_W_combine_p 0.82
# all_train_score_W_combine_n 0.45057489012317675
# all_train_score_W_combine_a 0.5165659637211174
# test_score_W_combine_p 0.84375
# test_score_W_combine_n 0.5113091310397946
# test_score_W_combine_a 0.5840102046558743
# neuron unit number: 28
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.22327156709603652
# all_train_score_W0_a 0.2596216422656457
# test_score_W0_p0.8125
# test_score_W0_n 0.463188492187051
# test_score_W0_a  0.4846819408873815
# all_train_score_W_combine_p 0.8333333333333334
# all_train_score_W_combine_n 0.4796960473600999
# all_train_score_W_combine_a 0.532071811960409
# test_score_W_combine_p 0.84375
# test_score_W_combine_n 0.4900552289424391
# test_score_W_combine_a 0.5588373585363186
# neuron unit number: 31
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.23092305802051727
# all_train_score_W0_a 0.298655105382405
# test_score_W0_p0.796875
# test_score_W0_n 0.46812033424812466
# test_score_W0_a  0.4433546142175836
# all_train_score_W_combine_p 0.82
# all_train_score_W_combine_n 0.44211597649589535
# all_train_score_W_combine_a 0.514911223792061
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.5441689872125115
# test_score_W_combine_a 0.5956802533914121
# neuron unit number: 34
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.3125258587715663
# all_train_score_W0_a 0.3348058384199578
# test_score_W0_p0.84375
# test_score_W0_n 0.519008571044584
# test_score_W0_a  0.603647144950202
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.44477823900415453
# all_train_score_W_combine_a 0.5174360663872734
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.554427755736682
# test_score_W_combine_a 0.6143461592177397
# neuron unit number: 37
# all_train_score_W0_p 0.72
# all_train_score_W0_n 0.249609452755032
# all_train_score_W0_a 0.29246148381543985
# test_score_W0_p0.796875
# test_score_W0_n 0.5033303250394953
# test_score_W0_a  0.4556594825497269
# all_train_score_W_combine_p 0.8066666666666666
# all_train_score_W_combine_n 0.4683447752845197
# all_train_score_W_combine_a 0.47449898224409826
# test_score_W_combine_p 0.8125
# test_score_W_combine_n 0.45507051041498076
# test_score_W_combine_a 0.4811031705412006
# Not good nmi result for discrete features !!!!!
# neuron unit number: 40
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.30215131524161765
# all_train_score_W0_a 0.3590104914362329
# test_score_W0_p0.875
# test_score_W0_n 0.6234830673688995
# test_score_W0_a  0.656122378348446
# all_train_score_W_combine_p 0.8066666666666666
# all_train_score_W_combine_n 0.4158878617322975
# all_train_score_W_combine_a 0.48774946879177894
# test_score_W_combine_p 0.828125
# test_score_W_combine_n 0.4946324275828656
# test_score_W_combine_a 0.5439233944940534
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 43
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.31091642175157685
# all_train_score_W0_a 0.3664492385692136
# test_score_W0_p0.84375
# test_score_W0_n 0.5425269064429868
# test_score_W0_a  0.5336797705882876
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.4329701247810972
# all_train_score_W_combine_a 0.48690564534934067
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5564545261977122
# test_score_W_combine_a 0.6159073678406506
# neuron unit number: 46
# all_train_score_W0_p 0.7133333333333334
# all_train_score_W0_n 0.2834685050547523
# all_train_score_W0_a 0.2796147302308506
# test_score_W0_p0.84375
# test_score_W0_n 0.515011784389401
# test_score_W0_a  0.6090235979415004
# all_train_score_W_combine_p 0.82
# all_train_score_W_combine_n 0.4666928571638074
# all_train_score_W_combine_a 0.5083066715175135
# test_score_W_combine_p 0.828125
# test_score_W_combine_n 0.5110161046773611
# test_score_W_combine_a 0.48518947788294703
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 49
# all_train_score_W0_p 0.72
# all_train_score_W0_n 0.26937397368719335
# all_train_score_W0_a 0.3078705976155118
# test_score_W0_p0.84375
# test_score_W0_n 0.48525749950051794
# test_score_W0_a  0.5930677363802052
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.37148011923659446
# all_train_score_W_combine_a 0.45910625039243874
# test_score_W_combine_p 0.796875
# test_score_W_combine_n 0.4163818572151136
# test_score_W_combine_a 0.4323589764362189
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# test_score_W0_p mean 0.822265625
# test_score_W_combine_p mean 0.841796875
# test_score_W0_n mean 0.4943319584164947
# test_score_W_combine_n mean 0.5170655495137937
# test_score_W0_a mean 0.5245966459783951
# test_score_W_combine_a mean 0.5501594781587454
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.262709  0.052350  0.013087   0.234814  0.290605
# 1  train_W_combine  16.0  0.424646  0.039989  0.009997   0.403337  0.445955
# 2         combined  32.0  0.343678  0.094166  0.016646   0.309727  0.377628
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1619
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -9.8328
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.4764
# 7                                Hedge's g =   -3.3888
# 8                           Glass's delta1 =   -3.0934
# 9                         Point-Biserial r =   -0.8736
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.494332  0.079073  0.019768   0.452197  0.536467
# 1  test_W_combine  16.0  0.517066  0.065169  0.016292   0.482339  0.551792
# 2        combined  32.0  0.505699  0.072207  0.012764   0.479665  0.531732
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0227
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -0.8874
# 3                  Two side test p value =    0.3819
# 4                 Difference < 0 p value =    0.1909
# 5                 Difference > 0 p value =    0.8091
# 6                              Cohen's d =   -0.3138
# 7                              Hedge's g =   -0.3058
# 8                         Glass's delta1 =   -0.2875
# 9                       Point-Biserial r =   -0.1599
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.297580  0.052898  0.013224   0.269393  0.325767
# 1  train_W_combine  16.0  0.484085  0.037980  0.009495   0.463847  0.504323
# 2         combined  32.0  0.390833  0.105017  0.018564   0.352970  0.428695
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1865
# 1                       Degrees of freedom =   30.0000
# 2                                        t =  -11.4561
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -4.0503
# 7                                Hedge's g =   -3.9482
# 8                           Glass's delta1 =   -3.5258
# 9                         Point-Biserial r =   -0.9022
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.524597  0.083897  0.020974   0.479891  0.569302
# 1  test_W_combine  16.0  0.550159  0.074040  0.018510   0.510706  0.589613
# 2        combined  32.0  0.537378  0.078912  0.013950   0.508927  0.565829
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0256
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -0.9138
# 3                  Two side test p value =    0.3681
# 4                 Difference < 0 p value =    0.1841
# 5                 Difference > 0 p value =    0.8159
# 6                              Cohen's d =   -0.3231
# 7                              Hedge's g =   -0.3149
# 8                         Glass's delta1 =   -0.3047
# 9                       Point-Biserial r =   -0.1646
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.719583  0.028542  0.007135   0.704375  0.734792
# 1  train_W_combine  16.0  0.807500  0.017019  0.004255   0.798431  0.816569
# 2         combined  32.0  0.763542  0.050289  0.008890   0.745411  0.781673
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0879
# 1                       Degrees of freedom =   30.0000
# 2                                        t =  -10.5827
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.7415
# 7                                Hedge's g =   -3.6472
# 8                           Glass's delta1 =   -3.0803
# 9                         Point-Biserial r =   -0.8881
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.822266  0.033694  0.008423   0.804312  0.840220
# 1  test_W_combine  16.0  0.841797  0.030123  0.007531   0.825746  0.857848
# 2        combined  32.0  0.832031  0.032967  0.005828   0.820145  0.843917
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0195
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -1.7286
# 3                  Two side test p value =    0.0942
# 4                 Difference < 0 p value =    0.0471
# 5                 Difference > 0 p value =    0.9529
# 6                              Cohen's d =   -0.6112
# 7                              Hedge's g =   -0.5957
# 8                         Glass's delta1 =   -0.5797
# 9                       Point-Biserial r =   -0.3010

# %%
#new one hot encoding  hybird
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3



experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.1448427292528757
# all_train_score_W0_a 0.20895051518897279
# test_score_W0_p0.78125
# test_score_W0_n 0.31712893708029893
# test_score_W0_a  0.41563434429730883
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.34637010858687095
# all_train_score_W_combine_a 0.35907861123471424
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5515509787497271
# test_score_W_combine_a 0.6230548265101573
# neuron unit number: 7
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.19905452083702443
# all_train_score_W0_a 0.25442685523851266
# test_score_W0_p0.78125
# test_score_W0_n 0.33449976064427467
# test_score_W0_a  0.4327267146071572
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.4013736780221383
# all_train_score_W_combine_a 0.4429278465441217
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5606026020920707
# test_score_W_combine_a 0.6448709785671196
# neuron unit number: 10
# all_train_score_W0_p 0.6866666666666666
# all_train_score_W0_n 0.20633349017012198
# all_train_score_W0_a 0.21948382248811432
# test_score_W0_p0.796875
# test_score_W0_n 0.34464205813422133
# test_score_W0_a  0.4289732577089023
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.3453764908408497
# all_train_score_W_combine_a 0.3693555324368847
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6070065658061553
# test_score_W_combine_a 0.6805854201950678
# neuron unit number: 13
# all_train_score_W0_p 0.6866666666666666
# all_train_score_W0_n 0.2029094577146572
# all_train_score_W0_a 0.22120480104385318
# test_score_W0_p0.859375
# test_score_W0_n 0.4956205501401501
# test_score_W0_a  0.5716204025699471
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.42042156114574725
# all_train_score_W_combine_a 0.44395604711439507
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5866560305912975
# test_score_W_combine_a 0.6429010745048411
# neuron unit number: 16
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.25974619531061205
# all_train_score_W0_a 0.3307632100977182
# test_score_W0_p0.859375
# test_score_W0_n 0.5466106965758837
# test_score_W0_a  0.6784432570380413
# all_train_score_W_combine_p 0.7733333333333333
# all_train_score_W_combine_n 0.32923907095615257
# all_train_score_W_combine_a 0.3980393937947998
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5528017494167266
# test_score_W_combine_a 0.6053082840358935
# Not good ari result for discrete features  !!!!!
# neuron unit number: 19
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.2607785433279304
# all_train_score_W0_a 0.3201404010569718
# test_score_W0_p0.828125
# test_score_W0_n 0.41183483002200516
# test_score_W0_a  0.47568347813774575
# all_train_score_W_combine_p 0.7533333333333333
# all_train_score_W_combine_n 0.3265121462248643
# all_train_score_W_combine_a 0.3582745650398722
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5266967775023702
# test_score_W_combine_a 0.6449233936075899
# neuron unit number: 22
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.17812746649797415
# all_train_score_W0_a 0.21805440115621766
# test_score_W0_p0.828125
# test_score_W0_n 0.4594174759278988
# test_score_W0_a  0.5594132361497093
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.41918148541553013
# all_train_score_W_combine_a 0.4233880298768016
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6134647749574672
# test_score_W_combine_a 0.6567342073897497
# neuron unit number: 25
# all_train_score_W0_p 0.72
# all_train_score_W0_n 0.26478055064229694
# all_train_score_W0_a 0.3249587769184174
# test_score_W0_p0.828125
# test_score_W0_n 0.441632551973543
# test_score_W0_a  0.5247688470601204
# all_train_score_W_combine_p 0.7666666666666667
# all_train_score_W_combine_n 0.35164193974392266
# all_train_score_W_combine_a 0.37656928208412277
# test_score_W_combine_p 0.921875
# test_score_W_combine_n 0.6998885676972874
# test_score_W_combine_a 0.7450848418293244
# neuron unit number: 28
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.2920793975820487
# all_train_score_W0_a 0.33735101677678425
# test_score_W0_p0.859375
# test_score_W0_n 0.4787744001709113
# test_score_W0_a  0.6191881657433451
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.3368701587756162
# all_train_score_W_combine_a 0.3686843389387076
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.5245195514402294
# test_score_W_combine_a 0.5762971479872894
# Not good ari result for discrete features  !!!!!
# neuron unit number: 31
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.18087591333740313
# all_train_score_W0_a 0.24400696135339342
# test_score_W0_p0.78125
# test_score_W0_n 0.31435814696408093
# test_score_W0_a  0.42283774198213586
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.3675962871233721
# all_train_score_W_combine_a 0.4196147119559374
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5716895989328749
# test_score_W_combine_a 0.6161356537962713
# neuron unit number: 34
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.23371357013396574
# all_train_score_W0_a 0.2435157699870006
# test_score_W0_p0.8125
# test_score_W0_n 0.38721050889470643
# test_score_W0_a  0.4736597818519378
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.3946960188044351
# all_train_score_W_combine_a 0.44469516405414133
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5782491545753647
# test_score_W_combine_a 0.6825912269773841
# neuron unit number: 37
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.283122541843504
# all_train_score_W0_a 0.33025328908560647
# test_score_W0_p0.859375
# test_score_W0_n 0.5116451331216412
# test_score_W0_a  0.5925305930558041
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.36759503679028255
# all_train_score_W_combine_a 0.41521208123443054
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5974313979460228
# test_score_W_combine_a 0.6686556852370731
# neuron unit number: 40
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.2102077193589777
# all_train_score_W0_a 0.27915518958319346
# test_score_W0_p0.921875
# test_score_W0_n 0.7141043436190186
# test_score_W0_a  0.7501143597477298
# all_train_score_W_combine_p 0.7733333333333333
# all_train_score_W_combine_n 0.3563768149722018
# all_train_score_W_combine_a 0.40181747773550897
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.5873609070360711
# test_score_W_combine_a 0.6489977956126691
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 43
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.28095426444323446
# all_train_score_W0_a 0.3359958561135775
# test_score_W0_p0.859375
# test_score_W0_n 0.520811856045683
# test_score_W0_a  0.6328768903207898
# all_train_score_W_combine_p 0.7666666666666667
# all_train_score_W_combine_n 0.38429549771248506
# all_train_score_W_combine_a 0.4248773907020263
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6056291863927478
# test_score_W_combine_a 0.656788254940764
# neuron unit number: 46
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.2647840948861267
# all_train_score_W0_a 0.33358872399252887
# test_score_W0_p0.828125
# test_score_W0_n 0.4059656981941037
# test_score_W0_a  0.5299353920894416
# all_train_score_W_combine_p 0.82
# all_train_score_W_combine_n 0.4383467149571935
# all_train_score_W_combine_a 0.5064266355663997
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6043609505625092
# test_score_W_combine_a 0.6567916323476012
# neuron unit number: 49
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.2547772978599487
# all_train_score_W0_a 0.34279636965494276
# test_score_W0_p0.84375
# test_score_W0_n 0.474429781134806
# test_score_W0_a  0.5655510170343787
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.3807147660300223
# all_train_score_W_combine_a 0.45661679067949745
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.49220569836520367
# test_score_W_combine_a 0.5754490552446444
# test_score_W0_p mean 0.8330078125
# test_score_W_combine_p mean 0.880859375
# test_score_W0_n mean 0.4474179205402017
# test_score_W_combine_n mean 0.5787571557540078
# test_score_W0_a mean 0.542122342462156
# test_score_W_combine_a mean 0.645323092423965
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.232318  0.044019  0.011005   0.208862  0.255774
# 1  train_W_combine  16.0  0.372913  0.034408  0.008602   0.354578  0.391248
# 2         combined  32.0  0.302615  0.081312  0.014374   0.273299  0.331931
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1406
# 1                       Degrees of freedom =   30.0000
# 2                                        t =  -10.0656
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.5587
# 7                                Hedge's g =   -3.4690
# 8                           Glass's delta1 =   -3.1940
# 9                         Point-Biserial r =   -0.8784
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.447418  0.103050  0.025762   0.392506  0.502329
# 1  test_W_combine  16.0  0.578757  0.047241  0.011810   0.553584  0.603930
# 2        combined  32.0  0.513088  0.103295  0.018260   0.475846  0.550329
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1313
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -4.6343
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.6385
# 7                              Hedge's g =   -1.5972
# 8                         Glass's delta1 =   -1.2745
# 9                       Point-Biserial r =   -0.6459
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.284040  0.052281  0.013070   0.256182  0.311899
# 1  train_W_combine  16.0  0.413096  0.041016  0.010254   0.391240  0.434952
# 2         combined  32.0  0.348568  0.080217  0.014180   0.319647  0.377489
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1291
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -7.7686
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.7466
# 7                                Hedge's g =   -2.6774
# 8                           Glass's delta1 =   -2.4685
# 9                         Point-Biserial r =   -0.8173
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.542122  0.098261  0.024565   0.489763  0.594482
# 1  test_W_combine  16.0  0.645323  0.041744  0.010436   0.623079  0.667567
# 2        combined  32.0  0.593723  0.090904  0.016070   0.560948  0.626497
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1032
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -3.8666
# 3                  Two side test p value =    0.0006
# 4                 Difference < 0 p value =    0.0003
# 5                 Difference > 0 p value =    0.9997
# 6                              Cohen's d =   -1.3671
# 7                              Hedge's g =   -1.3326
# 8                         Glass's delta1 =   -1.0503
# 9                       Point-Biserial r =   -0.5767
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.711667  0.024037  0.006009   0.698858  0.724475
# 1  train_W_combine  16.0  0.779167  0.018837  0.004709   0.769129  0.789204
# 2         combined  32.0  0.745417  0.040337  0.007131   0.730874  0.759960
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0675
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -8.8413
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.1259
# 7                                Hedge's g =   -3.0471
# 8                           Glass's delta1 =   -2.8082
# 9                         Point-Biserial r =   -0.8501
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.833008  0.037724  0.009431   0.812906  0.853110
# 1  test_W_combine  16.0  0.880859  0.014960  0.003740   0.872888  0.888831
# 2        combined  32.0  0.856934  0.037253  0.006586   0.843502  0.870365
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0479
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -4.7165
# 3                  Two side test p value =    0.0001
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -1.6675
# 7                              Hedge's g =   -1.6255
# 8                         Glass's delta1 =   -1.2684
# 9                       Point-Biserial r =   -0.6525

# %%
#new sum  hybird
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3



experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
# all_train_score_W0_p 0.6866666666666666
# all_train_score_W0_n 0.17427373896583098
# all_train_score_W0_a 0.2221631623943773
# test_score_W0_p0.71875
# test_score_W0_n 0.18939571443826786
# test_score_W0_a  0.2515652791377632
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.41623142625585186
# all_train_score_W_combine_a 0.5229453083937754
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6160090828846758
# test_score_W_combine_a 0.6436355041714293
# neuron unit number: 7
# all_train_score_W0_p 0.7333333333333333
# all_train_score_W0_n 0.24330213947178972
# all_train_score_W0_a 0.34521265568277465
# test_score_W0_p0.765625
# test_score_W0_n 0.25990826036943293
# test_score_W0_a  0.3484323162836825
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.4564788441693298
# all_train_score_W_combine_a 0.4974017973651807
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6625990575610783
# test_score_W_combine_a 0.6451583070557244
# neuron unit number: 10
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.3094988138399441
# all_train_score_W0_a 0.3549366741033793
# test_score_W0_p0.8125
# test_score_W0_n 0.3850349442783011
# test_score_W0_a  0.46094871318368913
# all_train_score_W_combine_p 0.8266666666666667
# all_train_score_W_combine_n 0.4681069197211159
# all_train_score_W_combine_a 0.5623980736177322
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.5627950636446339
# test_score_W_combine_a 0.554944317324129
# neuron unit number: 13
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.18417338299339844
# all_train_score_W0_a 0.23533570759601968
# test_score_W0_p0.796875
# test_score_W0_n 0.3740546594009928
# test_score_W0_a  0.4325679949336428
# all_train_score_W_combine_p 0.8333333333333334
# all_train_score_W_combine_n 0.45642266601467973
# all_train_score_W_combine_a 0.5558755553354258
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.5530003308571606
# test_score_W_combine_a 0.5839427329345016
# neuron unit number: 16
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.24095950112752473
# all_train_score_W0_a 0.35112898031929723
# test_score_W0_p0.828125
# test_score_W0_n 0.40265677125103894
# test_score_W0_a  0.49102046716229575
# all_train_score_W_combine_p 0.82
# all_train_score_W_combine_n 0.41685674804101347
# all_train_score_W_combine_a 0.5246300047216035
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5620076982643164
# test_score_W_combine_a 0.6086095543791983
# neuron unit number: 19
# all_train_score_W0_p 0.7666666666666667
# all_train_score_W0_n 0.3276053428828886
# all_train_score_W0_a 0.3970894324660406
# test_score_W0_p0.75
# test_score_W0_n 0.2519338524178743
# test_score_W0_a  0.3246124366166979
# all_train_score_W_combine_p 0.8066666666666666
# all_train_score_W_combine_n 0.3991992324408364
# all_train_score_W_combine_a 0.489551005705484
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6475062090438153
# test_score_W_combine_a 0.6909705686255834
# neuron unit number: 22
# all_train_score_W0_p 0.6933333333333334
# all_train_score_W0_n 0.23131609185805468
# all_train_score_W0_a 0.27412411722800106
# test_score_W0_p0.828125
# test_score_W0_n 0.4427372546346497
# test_score_W0_a  0.48747578128025787
# all_train_score_W_combine_p 0.8533333333333334
# all_train_score_W_combine_n 0.5374686141420061
# all_train_score_W_combine_a 0.5712223617102307
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5620076982643164
# test_score_W_combine_a 0.6086095543791983
# neuron unit number: 25
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.25144551379254876
# all_train_score_W0_a 0.3483208515356014
# test_score_W0_p0.875
# test_score_W0_n 0.5526194658432476
# test_score_W0_a  0.5959156039291922
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.4001475405879109
# all_train_score_W_combine_a 0.4624242606968323
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.6193825842722539
# test_score_W_combine_a 0.612061192728528
# neuron unit number: 28
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.2778604110815158
# all_train_score_W0_a 0.375588528663739
# test_score_W0_p0.84375
# test_score_W0_n 0.4557848918632804
# test_score_W0_a  0.5466389362265778
# all_train_score_W_combine_p 0.8066666666666666
# all_train_score_W_combine_n 0.41256147461132675
# all_train_score_W_combine_a 0.4994228316763286
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5668070663676903
# test_score_W_combine_a 0.6211363699140955
# neuron unit number: 31
# all_train_score_W0_p 0.7133333333333334
# all_train_score_W0_n 0.2326892118685308
# all_train_score_W0_a 0.29855045430704863
# test_score_W0_p0.8125
# test_score_W0_n 0.4173905401788839
# test_score_W0_a  0.4505112561911289
# all_train_score_W_combine_p 0.8133333333333334
# all_train_score_W_combine_n 0.4262320517192937
# all_train_score_W_combine_a 0.5077086848027604
# test_score_W_combine_p 0.859375
# test_score_W_combine_n 0.4795863930321682
# test_score_W_combine_a 0.5829602819316125
# neuron unit number: 34
# all_train_score_W0_p 0.7533333333333333
# all_train_score_W0_n 0.29607878083305295
# all_train_score_W0_a 0.37520369911508844
# test_score_W0_p0.8125
# test_score_W0_n 0.4211329842908404
# test_score_W0_a  0.4798188654978073
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.4068891123340416
# all_train_score_W_combine_a 0.45379757121025
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6479097469136795
# test_score_W_combine_a 0.6734832541460962
# neuron unit number: 37
# all_train_score_W0_p 0.7466666666666667
# all_train_score_W0_n 0.26179639083291106
# all_train_score_W0_a 0.3654493711730805
# test_score_W0_p0.8125
# test_score_W0_n 0.3819451072219393
# test_score_W0_a  0.4534409698809
# all_train_score_W_combine_p 0.84
# all_train_score_W_combine_n 0.506032889426663
# all_train_score_W_combine_a 0.5508262303199094
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5309145554615433
# test_score_W_combine_a 0.6296211700658113
# neuron unit number: 40
# all_train_score_W0_p 0.7733333333333333
# all_train_score_W0_n 0.3661726986735933
# all_train_score_W0_a 0.42096114619464053
# test_score_W0_p0.828125
# test_score_W0_n 0.4567277469620242
# test_score_W0_a  0.4698947909604409
# all_train_score_W_combine_p 0.8333333333333334
# all_train_score_W_combine_n 0.46524911825770876
# all_train_score_W_combine_a 0.5725811816183489
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6167563328728602
# test_score_W_combine_a 0.6801562605027065
# neuron unit number: 43
# all_train_score_W0_p 0.74
# all_train_score_W0_n 0.2788155708106285
# all_train_score_W0_a 0.37176202108572826
# test_score_W0_p0.828125
# test_score_W0_n 0.4195040702221159
# test_score_W0_a  0.4859882260976639
# all_train_score_W_combine_p 0.8066666666666666
# all_train_score_W_combine_n 0.40706195806872525
# all_train_score_W_combine_a 0.5185720459325267
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5498929725658727
# test_score_W_combine_a 0.6163193532367405
# neuron unit number: 46
# all_train_score_W0_p 0.7533333333333333
# all_train_score_W0_n 0.2931588174205453
# all_train_score_W0_a 0.3886327859443738
# test_score_W0_p0.765625
# test_score_W0_n 0.28883877763544585
# test_score_W0_a  0.34646477405500997
# all_train_score_W_combine_p 0.7866666666666666
# all_train_score_W_combine_n 0.35126776357381884
# all_train_score_W_combine_a 0.43795230703410915
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.5184689733483087
# test_score_W_combine_a 0.6285643065384907
# neuron unit number: 49
# all_train_score_W0_p 0.7866666666666666
# all_train_score_W0_n 0.3426742278372356
# all_train_score_W0_a 0.44238386428599163
# test_score_W0_p0.828125
# test_score_W0_n 0.4180367958955709
# test_score_W0_a  0.48924887981546783
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.41412193480210613
# all_train_score_W_combine_a 0.4737450202976405
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.5925815286219834
# test_score_W_combine_a 0.6550654600907817
# test_score_W0_p mean 0.806640625
# test_score_W_combine_p mean 0.87890625
# test_score_W0_n mean 0.38235636480649415
# test_score_W_combine_n mean 0.5805140808735223
# test_score_W0_a mean 0.44465908070326365
# test_score_W_combine_a mean 0.6272023867515392
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.269489  0.053008  0.013252   0.241243  0.297735
# 1  train_W_combine  16.0  0.433771  0.045628  0.011407   0.409457  0.458084
# 2         combined  32.0  0.351630  0.096601  0.017077   0.316801  0.386458
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1643
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -9.3955
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.3218
# 7                                Hedge's g =   -3.2381
# 8                           Glass's delta1 =   -3.0992
# 9                         Point-Biserial r =   -0.8639
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.382356  0.092164  0.023041   0.333246  0.431467
# 1  test_W_combine  16.0  0.580514  0.051235  0.012809   0.553213  0.607815
# 2        combined  32.0  0.481435  0.124554  0.022018   0.436529  0.526342
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1982
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -7.5168
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.6576
# 7                              Hedge's g =   -2.5906
# 8                         Glass's delta1 =   -2.1501
# 9                       Point-Biserial r =   -0.8082
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.347928  0.061730  0.015433   0.315034  0.380821
# 1  train_W_combine  16.0  0.512566  0.042546  0.010637   0.489895  0.535237
# 2         combined  32.0  0.430247  0.098564  0.017424   0.394711  0.465783
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1646
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -8.7840
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.1056
# 7                                Hedge's g =   -3.0273
# 8                           Glass's delta1 =   -2.6671
# 9                         Point-Biserial r =   -0.8486
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.444659  0.087159  0.021790   0.398215  0.491103
# 1  test_W_combine  16.0  0.627202  0.036982  0.009245   0.607496  0.646909
# 2        combined  32.0  0.535931  0.113740  0.020107   0.494923  0.576938
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1825
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -7.7120
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.7266
# 7                              Hedge's g =   -2.6579
# 8                         Glass's delta1 =   -2.0944
# 9                       Point-Biserial r =   -0.8153
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.735417  0.030377  0.007594   0.719230  0.751604
# 1  train_W_combine  16.0  0.815000  0.018459  0.004615   0.805164  0.824836
# 2         combined  32.0  0.775208  0.047390  0.008377   0.758122  0.792294
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0796
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -8.9555
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.1663
# 7                                Hedge's g =   -3.0864
# 8                           Glass's delta1 =   -2.6198
# 9                         Point-Biserial r =   -0.8531
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.806641  0.039062  0.009766   0.785826  0.827456
# 1  test_W_combine  16.0  0.878906  0.013380  0.003345   0.871776  0.886036
# 2        combined  32.0  0.842773  0.046612  0.008240   0.825968  0.859579
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0723
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -7.0007
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.4751
# 7                              Hedge's g =   -2.4127
# 8                         Glass's delta1 =   -1.8500
# 9                       Point-Biserial r =   -0.7876

# %%
#new baseN  hybird
import experiment
unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3



experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
# all_train_score_W0_p 0.6066666666666667
# all_train_score_W0_n 0.07816770594470215
# all_train_score_W0_a 0.10079067682653518
# test_score_W0_p0.78125
# test_score_W0_n 0.3773385674165651
# test_score_W0_a  0.37643790743779254
# all_train_score_W_combine_p 0.7733333333333333
# all_train_score_W_combine_n 0.36154067745140145
# all_train_score_W_combine_a 0.4291064391059063
# test_score_W_combine_p 0.953125
# test_score_W_combine_n 0.7754681234490732
# test_score_W_combine_a 0.8408822510899389
# neuron unit number: 7
# all_train_score_W0_p 0.6866666666666666
# all_train_score_W0_n 0.22046210755904666
# all_train_score_W0_a 0.25770237050815004
# test_score_W0_p0.796875
# test_score_W0_n 0.3987883664881919
# test_score_W0_a  0.40252070410136986
# all_train_score_W_combine_p 0.7533333333333333
# all_train_score_W_combine_n 0.32513998884387957
# all_train_score_W_combine_a 0.38679710999215033
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.6114034910311885
# test_score_W_combine_a 0.6390881593507931
# neuron unit number: 10
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.2379901426958325
# all_train_score_W0_a 0.2878724539143587
# test_score_W0_p0.828125
# test_score_W0_n 0.4125676442286703
# test_score_W0_a  0.46154960601983946
# all_train_score_W_combine_p 0.7533333333333333
# all_train_score_W_combine_n 0.3272384601539237
# all_train_score_W_combine_a 0.38502878038203
# test_score_W_combine_p 0.921875
# test_score_W_combine_n 0.668462003398368
# test_score_W_combine_a 0.7479421954050486
# neuron unit number: 13
# all_train_score_W0_p 0.6866666666666666
# all_train_score_W0_n 0.203347991918185
# all_train_score_W0_a 0.22589374940025764
# test_score_W0_p0.828125
# test_score_W0_n 0.4307236038122678
# test_score_W0_a  0.4680984910909687
# all_train_score_W_combine_p 0.8
# all_train_score_W_combine_n 0.4154881371717691
# all_train_score_W_combine_a 0.4827416641631185
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6742760509980273
# test_score_W_combine_a 0.7174003820354493
# neuron unit number: 16
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.2457239537831226
# all_train_score_W0_a 0.28039294265133535
# test_score_W0_p0.859375
# test_score_W0_n 0.6267504223963339
# test_score_W0_a  0.5536602784333203
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.35418647102534234
# all_train_score_W_combine_a 0.43767343362949135
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6581256153907428
# test_score_W_combine_a 0.7075259139075004
# neuron unit number: 19
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.23684972584893785
# all_train_score_W0_a 0.2813657319104084
# test_score_W0_p0.828125
# test_score_W0_n 0.4421300323654333
# test_score_W0_a  0.48336983018634055
# all_train_score_W_combine_p 0.8266666666666667
# all_train_score_W_combine_n 0.4619737353033364
# all_train_score_W_combine_a 0.5392305190325061
# test_score_W_combine_p 0.953125
# test_score_W_combine_n 0.8010617307743501
# test_score_W_combine_a 0.8571010871587678
# neuron unit number: 22
# all_train_score_W0_p 0.7133333333333334
# all_train_score_W0_n 0.24783104658726696
# all_train_score_W0_a 0.2957391327092989
# test_score_W0_p0.859375
# test_score_W0_n 0.4673925594573971
# test_score_W0_a  0.5442880537302295
# all_train_score_W_combine_p 0.7666666666666667
# all_train_score_W_combine_n 0.3304496220953264
# all_train_score_W_combine_a 0.3989072843549461
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6272538307036181
# test_score_W_combine_a 0.6975581539478577
# neuron unit number: 25
# all_train_score_W0_p 0.7066666666666667
# all_train_score_W0_n 0.23554291528751378
# all_train_score_W0_a 0.29271248310390613
# test_score_W0_p0.8125
# test_score_W0_n 0.41443125362638084
# test_score_W0_a  0.463225563045471
# all_train_score_W_combine_p 0.7933333333333333
# all_train_score_W_combine_n 0.3639707399707843
# all_train_score_W_combine_a 0.47004651898534555
# test_score_W_combine_p 0.921875
# test_score_W_combine_n 0.6793320144365457
# test_score_W_combine_a 0.7358966706361754
# neuron unit number: 28
# all_train_score_W0_p 0.6933333333333334
# all_train_score_W0_n 0.25525392241977346
# all_train_score_W0_a 0.28889595927457845
# test_score_W0_p0.84375
# test_score_W0_n 0.4766304786620257
# test_score_W0_a  0.5644963163057599
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.39198320787147717
# all_train_score_W_combine_a 0.4315407605138843
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6241448103916319
# test_score_W_combine_a 0.7106088269735037
# neuron unit number: 31
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.23899647304517702
# all_train_score_W0_a 0.2799527833086945
# test_score_W0_p0.84375
# test_score_W0_n 0.5300595132944443
# test_score_W0_a  0.511617848263281
# all_train_score_W_combine_p 0.7533333333333333
# all_train_score_W_combine_n 0.302165970600974
# all_train_score_W_combine_a 0.3508387522049161
# test_score_W_combine_p 0.890625
# test_score_W_combine_n 0.5710470056712382
# test_score_W_combine_a 0.6577212302647992
# neuron unit number: 34
# all_train_score_W0_p 0.7266666666666667
# all_train_score_W0_n 0.262202111427314
# all_train_score_W0_a 0.3075021567938279
# test_score_W0_p0.796875
# test_score_W0_n 0.3526368501452779
# test_score_W0_a  0.38207353310763864
# all_train_score_W_combine_p 0.78
# all_train_score_W_combine_n 0.3570774280213087
# all_train_score_W_combine_a 0.4167552467104867
# test_score_W_combine_p 0.921875
# test_score_W_combine_n 0.7020427415525282
# test_score_W_combine_a 0.7642946199350962
# neuron unit number: 37
# all_train_score_W0_p 0.72
# all_train_score_W0_n 0.27217546870608456
# all_train_score_W0_a 0.32043897879111677
# test_score_W0_p0.90625
# test_score_W0_n 0.6702237914964133
# test_score_W0_a  0.6999310308239164
# all_train_score_W_combine_p 0.7333333333333333
# all_train_score_W_combine_n 0.29933533259327433
# all_train_score_W_combine_a 0.31088776066928253
# test_score_W_combine_p 0.875
# test_score_W_combine_n 0.578162380778043
# test_score_W_combine_a 0.613534548607527
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 40
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.1989226820532885
# all_train_score_W0_a 0.286848758794466
# test_score_W0_p0.84375
# test_score_W0_n 0.49829132703546447
# test_score_W0_a  0.5240722980450019
# all_train_score_W_combine_p 0.7733333333333333
# all_train_score_W_combine_n 0.329077362950467
# all_train_score_W_combine_a 0.42758927466496727
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6431831533279768
# test_score_W_combine_a 0.700280854220762
# neuron unit number: 43
# all_train_score_W0_p 0.7133333333333334
# all_train_score_W0_n 0.2541990877920628
# all_train_score_W0_a 0.32793156254847905
# test_score_W0_p0.84375
# test_score_W0_n 0.49251760102967224
# test_score_W0_a  0.5308437589293867
# all_train_score_W_combine_p 0.8066666666666666
# all_train_score_W_combine_n 0.4144163459419645
# all_train_score_W_combine_a 0.5014756975218917
# test_score_W_combine_p 0.921875
# test_score_W_combine_n 0.668462003398368
# test_score_W_combine_a 0.7479421954050486
# neuron unit number: 46
# all_train_score_W0_p 0.7
# all_train_score_W0_n 0.25953708807340803
# all_train_score_W0_a 0.29659618910115676
# test_score_W0_p0.890625
# test_score_W0_n 0.5902805830348422
# test_score_W0_a  0.6844930681667183
# all_train_score_W_combine_p 0.7666666666666667
# all_train_score_W_combine_n 0.3438506507553447
# all_train_score_W_combine_a 0.40373080199442984
# test_score_W_combine_p 0.953125
# test_score_W_combine_n 0.7754681234490729
# test_score_W_combine_a 0.8408822510899389
# neuron unit number: 49
# all_train_score_W0_p 0.68
# all_train_score_W0_n 0.196987089836087
# all_train_score_W0_a 0.22954239799283035
# test_score_W0_p0.828125
# test_score_W0_n 0.46775507380069276
# test_score_W0_a  0.4977445467465859
# all_train_score_W_combine_p 0.7866666666666666
# all_train_score_W_combine_n 0.3698632842777149
# all_train_score_W_combine_a 0.43893629311164245
# test_score_W_combine_p 0.90625
# test_score_W_combine_n 0.6546301221525874
# test_score_W_combine_a 0.721616447354794
# test_score_W0_p mean 0.8369140625
# test_score_W_combine_p mean 0.9150390625
# test_score_W0_n mean 0.47803235426812957
# test_score_W_combine_n mean 0.6695327000564599
# test_score_W0_a mean 0.5092764271521013
# test_score_W_combine_a mean 0.7312672367114377
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.227762  0.045847  0.011462   0.203332  0.252192
# 1  train_W_combine  16.0  0.359235  0.043980  0.010995   0.335799  0.382670
# 2         combined  32.0  0.293498  0.080085  0.014157   0.264624  0.322372
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1315
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -8.2777
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.9266
# 7                                Hedge's g =   -2.8528
# 8                           Glass's delta1 =   -2.8677
# 9                         Point-Biserial r =   -0.8340
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.478032  0.089145  0.022286   0.430530  0.525534
# 1  test_W_combine  16.0  0.669533  0.066954  0.016739   0.633855  0.705210
# 2        combined  32.0  0.573783  0.124412  0.021993   0.528927  0.618638
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.1915
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -6.8707
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.4291
# 7                              Hedge's g =   -2.3679
# 8                         Glass's delta1 =   -2.1482
# 9                       Point-Biserial r =   -0.7819
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.272511  0.053387  0.013347   0.244063  0.300959
# 1  train_W_combine  16.0  0.425705  0.056246  0.014061   0.395734  0.455677
# 2         combined  32.0  0.349108  0.094690  0.016739   0.314969  0.383248
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.1532
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -7.9018
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -2.7937
# 7                                Hedge's g =   -2.7233
# 8                           Glass's delta1 =   -2.8695
# 9                         Point-Biserial r =   -0.8219
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.509276  0.091690  0.022923   0.460418  0.558135
# 1  test_W_combine  16.0  0.731267  0.069605  0.017401   0.694177  0.768357
# 2        combined  32.0  0.620272  0.138310  0.024450   0.570406  0.670138
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.2220
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -7.7136
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.7272
# 7                              Hedge's g =   -2.6584
# 8                         Glass's delta1 =   -2.4211
# 9                       Point-Biserial r =   -0.8154
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  16.0  0.696667  0.026998  0.006749   0.682280  0.711053
# 1  train_W_combine  16.0  0.776667  0.023222  0.005805   0.764293  0.789041
# 2         combined  32.0  0.736667  0.047594  0.008414   0.719507  0.753826
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0800
# 1                       Degrees of freedom =   30.0000
# 2                                        t =   -8.9860
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =   -3.1770
# 7                                Hedge's g =   -3.0969
# 8                           Glass's delta1 =   -2.9632
# 9                         Point-Biserial r =   -0.8539
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  16.0  0.836914  0.032760  0.008190   0.819458  0.854371
# 1  test_W_combine  16.0  0.915039  0.022799  0.005700   0.902890  0.927188
# 2        combined  32.0  0.875977  0.048435  0.008562   0.858514  0.893439
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0781
# 1                     Degrees of freedom =   30.0000
# 2                                      t =   -7.8296
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -2.7682
# 7                              Hedge's g =   -2.6984
# 8                         Glass's delta1 =   -2.3848
# 9                       Point-Biserial r =   -0.8194
