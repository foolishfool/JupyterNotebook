# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# self.continuous_feature_num 2
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
#Gaussian Naive Bayes
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num =2
best_num = 48
interval = 5


features_chosen = [0,1,2,3,4,5,6,7,8]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
# Out:
# Neuron/Cluster number: 2
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.10186369186369187
# precision_score_original 0.10106098846520302
# f1_score_original 0.09519670709777761
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10365153365153364
# precision_score_sog 0.09671725912028553
# f1_score_sog 0.09651575886945306
# Not good precision_score_original !!!!!
# Neuron/Cluster number: 7
# accuracy_score_orignial 0.1
# recall_score_original 0.09635808635808635
# precision_score_original 0.10444068929653953
# f1_score_original 0.09515263718121313
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09283956783956784
# precision_score_sog 0.09307575200432343
# f1_score_sog 0.08830312296741442
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 12
# accuracy_score_orignial 0.09
# recall_score_original 0.08922336922336921
# precision_score_original 0.0855239959338463
# f1_score_original 0.08512151453896026
# accuracy_score_sog 0.1
# recall_score_sog 0.09635808635808635
# precision_score_sog 0.09757430487564646
# f1_score_sog 0.09347627251024726
# Neuron/Cluster number: 17
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.09907573907573908
# precision_score_original 0.10030076311755085
# f1_score_original 0.09504391801730337
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.09988770488770488
# precision_score_sog 0.098958840937478
# f1_score_sog 0.09574638007132286
# Not good precision_score_original !!!!!
# Neuron/Cluster number: 22
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.08973618973618974
# precision_score_original 0.08270161076253721
# f1_score_original 0.08358665598442795
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.09867798867798866
# precision_score_sog 0.1035422385612995
# f1_score_sog 0.09750223341128611
# Neuron/Cluster number: 27
# accuracy_score_orignial 0.09
# recall_score_original 0.08649036149036148
# precision_score_original 0.08402560778812343
# f1_score_original 0.08230400178357211
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09324360824360824
# precision_score_sog 0.09863123477361145
# f1_score_sog 0.09204897998304758
# Neuron/Cluster number: 32
# accuracy_score_orignial 0.10333333333333333
# recall_score_original 0.09932826432826432
# precision_score_original 0.10089449698145352
# f1_score_original 0.09613509666211284
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09106800606800607
# precision_score_sog 0.08816449826581539
# f1_score_sog 0.08732982431678744
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 37
# accuracy_score_orignial 0.08666666666666667
# recall_score_original 0.08384578384578384
# precision_score_original 0.08666791756575037
# f1_score_original 0.08079643106052842
# accuracy_score_sog 0.10666666666666667
# recall_score_sog 0.10476985976985977
# precision_score_sog 0.10054916213720114
# f1_score_sog 0.10034370882607711
# Neuron/Cluster number: 42
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.08861786361786361
# precision_score_original 0.08745089088226343
# f1_score_original 0.08472350553239386
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09432104932104932
# precision_score_sog 0.0979413305357476
# f1_score_sog 0.09256754801867584
# Neuron/Cluster number: 47
# accuracy_score_orignial 0.1
# recall_score_original 0.09833111333111333
# precision_score_original 0.09962373869642041
# f1_score_original 0.09445895877679986
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.08947256447256446
# precision_score_sog 0.08962895061257888
# f1_score_sog 0.08532525459492767
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 52
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.0908208458208458
# precision_score_original 0.0865060708989099
# f1_score_original 0.08601901454653454
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09158804158804158
# precision_score_sog 0.09486822434190856
# f1_score_sog 0.08888030731301248
# Neuron/Cluster number: 57
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.09127150627150628
# precision_score_original 0.08463507392078821
# f1_score_original 0.0849043765063579
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09543937543937545
# precision_score_sog 0.09887160980776166
# f1_score_sog 0.09283557018971658
# Neuron/Cluster number: 62
# accuracy_score_orignial 0.09
# recall_score_original 0.0883085433085433
# precision_score_original 0.08428862280415048
# f1_score_original 0.08309096582011943
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09093480593480592
# precision_score_sog 0.08402661971289421
# f1_score_sog 0.08469552425493485
# Not good precision_score_original !!!!!
# Neuron/Cluster number: 67
# accuracy_score_orignial 0.1
# recall_score_original 0.09728401228401228
# precision_score_original 0.1005978834592723
# f1_score_original 0.09502031641366199
# accuracy_score_sog 0.09666666666666666
# recall_score_sog 0.09418063418063419
# precision_score_sog 0.09490295418866848
# f1_score_sog 0.09026345161100228
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_original !!!!!
# Not good accuracy result !!!!!
# Neuron/Cluster number: 72
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.09034558034558034
# precision_score_original 0.08611227900609755
# f1_score_original 0.0853904664603254
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10025419025419025
# precision_score_sog 0.1016882396799581
# f1_score_sog 0.09706754086387025
# Neuron/Cluster number: 77
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.08973618973618974
# precision_score_original 0.08720797358605648
# f1_score_original 0.08406239587782163
# accuracy_score_sog 0.1
# recall_score_sog 0.09735523735523735
# precision_score_sog 0.0961134835305018
# f1_score_sog 0.093478139249299
# Neuron/Cluster number: 82
# accuracy_score_orignial 0.09333333333333334
# recall_score_original 0.08932826432826434
# precision_score_original 0.091661466615027
# f1_score_original 0.08689626486521879
# accuracy_score_sog 0.1
# recall_score_sog 0.0978020128020128
# precision_score_sog 0.10084360975412249
# f1_score_sog 0.09533012077257498
# Neuron/Cluster number: 87
# accuracy_score_orignial 0.09666666666666666
# recall_score_original 0.09410940910940911
# precision_score_original 0.09705076828691492
# f1_score_original 0.09115645534619815
# accuracy_score_sog 0.10333333333333333
# recall_score_sog 0.10047693047693047
# precision_score_sog 0.10271087727990855
# f1_score_sog 0.09761802195378531
# Neuron/Cluster number: 92
# accuracy_score_orignial 0.09666666666666666
# recall_score_original 0.09412050912050912
# precision_score_original 0.08543140105231609
# f1_score_original 0.08686455163345687
# accuracy_score_sog 0.09333333333333334
# recall_score_sog 0.09021330521330523
# precision_score_sog 0.09179036449780352
# f1_score_sog 0.08762449801654469
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Neuron/Cluster number: 97
# accuracy_score_orignial 0.09666666666666666
# recall_score_original 0.09325470825470826
# precision_score_original 0.09320600887296702
# f1_score_original 0.0885724491697973
# accuracy_score_sog 0.11333333333333333
# recall_score_sog 0.11144374144374145
# precision_score_sog 0.10299914795538251
# f1_score_sog 0.10392836906724719
# all_accuracy_score_original mean 0.0955
# all_recall_score_original mean 0.09257250157250155
# all_precision_score_original mean 0.09146941239960939
# all_f1_score_original mean 0.08822483416372906
# all_accuracy_score_sog mean 0.0995
# all_recall_score_sog mean 0.09669891219891219
# all_precision_score_sog mean 0.09667993512864485
# all_f1_score_sog mean 0.09304403134306134
# Accuracy Score T-Test
#                       Variable     N    Mean        SD        SE  95% Conf.  \
# 0  all_accuracy_score_original  20.0  0.0955  0.004870  0.001089   0.093221
# 1       all_accuracy_score_sog  20.0  0.0995  0.005217  0.001167   0.097058
# 2                     combined  40.0  0.0975  0.005377  0.000850   0.095780
#
#    Interval
# 0  0.097779
# 1  0.101942
# 2  0.099220
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_original - all_...  -0.0040
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.5065
# 3                           Two side test p value =    0.0166
# 4                          Difference < 0 p value =    0.0083
# 5                          Difference > 0 p value =    0.9917
# 6                                       Cohen's d =   -0.7926
# 7                                       Hedge's g =   -0.7769
# 8                                  Glass's delta1 =   -0.8214
# 9                                Point-Biserial r =   -0.3767
# Recall Score T-Test
#                     Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_original  20.0  0.092573  0.004832  0.001081   0.090311
# 1       all_recall_score_sog  20.0  0.096699  0.005617  0.001256   0.094070
# 2                   combined  40.0  0.094636  0.005578  0.000882   0.092852
#
#    Interval
# 0  0.094834
# 1  0.099328
# 2  0.096420
#                                   Independent t-test  results
# 0  Difference (all_recall_score_original - all_re...  -0.0041
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.4906
# 3                           Two side test p value =    0.0172
# 4                          Difference < 0 p value =    0.0086
# 5                          Difference > 0 p value =    0.9914
# 6                                       Cohen's d =   -0.7876
# 7                                       Hedge's g =   -0.7719
# 8                                  Glass's delta1 =   -0.8539
# 9                                Point-Biserial r =   -0.3746
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_original  20.0  0.091469  0.007342  0.001642
# 1       all_precision_score_sog  20.0  0.096680  0.005246  0.001173
# 2                      combined  40.0  0.094075  0.006829  0.001080
#
#    95% Conf.  Interval
# 0   0.088033  0.094906
# 1   0.094225  0.099135
# 2   0.091891  0.096259
#                                   Independent t-test  results
# 0  Difference (all_precision_score_original - all...  -0.0052
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.5823
# 3                           Two side test p value =    0.0138
# 4                          Difference < 0 p value =    0.0069
# 5                          Difference > 0 p value =    0.9931
# 6                                       Cohen's d =   -0.8166
# 7                                       Hedge's g =   -0.8004
# 8                                  Glass's delta1 =   -0.7097
# 9                                Point-Biserial r =   -0.3864
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_original  20.0  0.088225  0.005152  0.001152   0.085814
# 1       all_f1_score_sog  20.0  0.093044  0.005098  0.001140   0.090658
# 2               combined  40.0  0.090634  0.005617  0.000888   0.088838
#
#    Interval
# 0  0.090636
# 1  0.095430
# 2  0.092431
#                                   Independent t-test  results
# 0  Difference (all_f1_score_original - all_f1_sco...  -0.0048
# 1                              Degrees of freedom =   38.0000
# 2                                               t =   -2.9736
# 3                           Two side test p value =    0.0051
# 4                          Difference < 0 p value =    0.0025
# 5                          Difference > 0 p value =    0.9975
# 6                                       Cohen's d =   -0.9403
# 7                                       Hedge's g =   -0.9216
# 8                                  Glass's delta1 =   -0.9354
# 9                                Point-Biserial r =   -0.4345

# %%
dataread.PCA_Comparision() # 1-8  8, 4, 5, 3, 6 |[5, 3, 4, 6, 8,|7, 8, 6, 5|5, 6, 7, 8, 4|5, 6, 8, 7, 3|7, 6, 4, 5, 3|5, 0, 1|2, 5, 3
# Out:
# Sorted feature index for component 0 [6, 8, 5, 4, 2, 7, 0, 1, 3]
# Sorted imporance porporation for component 0  [0.3186531657446461, 0.2744325036941778, 0.18210052519781442, 0.0882762075510554, 0.08819243176741973, 0.021194804425063444, 0.013944728151854784, 0.012218997382707783, 0.0009866360852603365]
# Sorted feature index for component 1 [3, 6, 5, 4, 8, 7, 0, 1, 2]
# Sorted imporance porporation for component 1  [0.29038357101420254, 0.24375829197882523, 0.14893337153226505, 0.09959939241316058, 0.09444444352967067, 0.08320457966109408, 0.027635167989697867, 0.009489904922879232, 0.002551276958204655]
# Sorted feature index for component 2 [7, 3, 4, 5, 8, 6, 2, 1, 0]
# Sorted imporance porporation for component 2  [0.22862146640105535, 0.21405517095035567, 0.14875536756258065, 0.14436826988169804, 0.1261076620836103, 0.09179547025405153, 0.02503901562440645, 0.01344118013304378, 0.007816397109198259]
# Sorted feature index for component 3 [8, 7, 6, 4, 3, 5, 2, 0, 1]
# Sorted imporance porporation for component 3  [0.23880582356369862, 0.23742418291022968, 0.18856149825970647, 0.14521625616494252, 0.09067795076416021, 0.08175347790756245, 0.008965834667811765, 0.008097856234350298, 0.0004971195275378661]
# Sorted feature index for component 4 [5, 4, 7, 8, 6, 0, 1, 3, 2]
# Sorted imporance porporation for component 4  [0.2948106873071291, 0.23535527102984397, 0.1753762973197707, 0.15810476812596896, 0.07902469048059355, 0.028254526870065213, 0.02574858337763093, 0.0030964648803232025, 0.00022871060867442884]
# Sorted feature index for component 5 [5, 3, 8, 7, 4, 6, 1, 0, 2]
# Sorted imporance porporation for component 5  [0.25338382755390143, 0.24097584583163492, 0.14226938084732285, 0.14133341262274549, 0.10400214599721341, 0.08980102660887858, 0.014066225388934456, 0.010939989530202346, 0.0032281456191664893]
# Sorted feature index for component 6 [1, 4, 5, 6, 0, 2, 7, 8, 3]
# Sorted imporance porporation for component 6  [0.5950643674870033, 0.3115752333171866, 0.02927185562797222, 0.024618970626944042, 0.01896737196007113, 0.014509584971456936, 0.004114156952561862, 0.0016886559450775055, 0.00018980311172636302]
# Sorted feature index for component 7 [2, 4, 5, 3, 0, 1, 8, 6, 7]
# Sorted imporance porporation for component 7  [0.3656146597493066, 0.3512346529920286, 0.2012110025539973, 0.026065088041819576, 0.023647707861544666, 0.011163420918969354, 0.010511618808959325, 0.005847376118160731, 0.004704472955213781]
# Sorted feature index for component 8 [3, 4, 1, 5, 2, 0, 7, 6, 8]
# Sorted imporance porporation for component 8  [0.40850816853206234, 0.31100437373021017, 0.14954061531730606, 0.039033465105054434, 0.032438221029206064, 0.02449253118960473, 0.021801598267683242, 0.0067488854087115815, 0.006432141420161207]
# [0.15373915 0.14430262 0.1422407  0.14110351 0.13716814 0.1240638
#  0.05721431 0.05172571 0.04844206]
