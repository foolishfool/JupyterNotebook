# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import TDSM_SOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import experiment
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("MiceProtein/Data_Cortex_Nuclear.csv")
csv = csv.drop(columns=['MouseID'])
dataread.replaceNANinDataset(csv)

dataread.stringToIntMiceProteinDataSet(csv,"Genotype")
dataread.stringToIntMiceProteinDataSet(csv,"Treatment")
dataread.stringToIntMiceProteinDataSet(csv,"class")
dataread.stringToIntMiceProteinDataSet(csv,"Behavior")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"class")

# %%
unstable_repeat_num= 40
scope_num = 48
class_num = 8
dim_num = 80
best_num = 24
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

#som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num)
#optimize_W.run(  total_label_train  )     


experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1)
# Out:
# neuron unit number: 8
# all_train_score_W0_n 0.2594186990065041
# all_train_score_W0_a 0.14286530399986855
# test_score_W0_n 0.30183469637767557
# test_score_W0_a  0.1588576374265763
# Split one time!
# self.rest_data_W0_n 0.26015968396621997
# self.rest_data_W0_a 0.14451970988990653
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2650931866588399
# all_train_score_W_Combined_a 0.14681529563064366
# test_score_W_combined_n 0.2967153714619338
# test_score_W_combined_a 0.16264681292293584
# Not good nmi result !!!!!
# Combine Neurons Number :23
# neuron unit number: 9
# all_train_score_W0_n 0.3233249287738163
# all_train_score_W0_a 0.18980612579879827
# test_score_W0_n 0.3806629180408757
# test_score_W0_a  0.20836184681485156
# Split one time!
# self.rest_data_W0_n 0.3240696197923277
# self.rest_data_W0_a 0.19169633444411102
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.3255301634773129
# all_train_score_W_Combined_a 0.1927565486190649
# test_score_W_combined_n 0.3812814797012536
# test_score_W_combined_a 0.22015265463385983
# Combine Neurons Number :12
# neuron unit number: 10
# all_train_score_W0_n 0.33945295038147894
# all_train_score_W0_a 0.22423533273595095
# test_score_W0_n 0.3248793536867008
# test_score_W0_a  0.19615660196186346
# Split one time!
# self.rest_data_W0_n 0.34385916145394946
# self.rest_data_W0_a 0.22793627987395992
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.3495322746152778
# all_train_score_W_Combined_a 0.23402312091350966
# test_score_W_combined_n 0.34457533676590385
# test_score_W_combined_a 0.2114509424512398
# Combine Neurons Number :35
# neuron unit number: 11
# all_train_score_W0_n 0.3520034300157081
# all_train_score_W0_a 0.19859222288839629
# test_score_W0_n 0.3791848017639242
# test_score_W0_a  0.20892176798639336
# Split one time!
# self.rest_data_W0_n 0.36379300022197814
# self.rest_data_W0_a 0.21903295002025497
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.36750491413569486
# all_train_score_W_Combined_a 0.21829191407528123
# test_score_W_combined_n 0.39688679200343535
# test_score_W_combined_a 0.2428058745391697
# Combine Neurons Number :16
# neuron unit number: 12
# all_train_score_W0_n 0.3474052608372274
# all_train_score_W0_a 0.22361324723978185
# test_score_W0_n 0.31308889962462605
# test_score_W0_a  0.1735635979544467
# Split one time!
# self.rest_data_W0_n 0.33676519086368134
# self.rest_data_W0_a 0.22999056087167358
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.34504760142467206
# all_train_score_W_Combined_a 0.23707407134254227
# test_score_W_combined_n 0.3940427130322051
# test_score_W_combined_a 0.272735457108174
# Combine Neurons Number :48
# neuron unit number: 13
# all_train_score_W0_n 0.2759520172226526
# all_train_score_W0_a 0.15267007878993602
# test_score_W0_n 0.2870796243384584
# test_score_W0_a  0.1434503379207858
# Split one time!
# self.rest_data_W0_n 0.2766657165380777
# self.rest_data_W0_a 0.14976482565290533
# Split one time!
# self.rest_data_W0_n 0.6753081890804937
# self.rest_data_W0_a 0.5745978252774261
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.2907938744339522
# all_train_score_W_Combined_a 0.1676750272556139
# test_score_W_combined_n 0.30405724775374393
# test_score_W_combined_a 0.15678483349049557
# Combine Neurons Number :24
# neuron unit number: 14
# all_train_score_W0_n 0.44288387969353865
# all_train_score_W0_a 0.338845376473873
# test_score_W0_n 0.3951132649847082
# test_score_W0_a  0.2514216270586781
# Split one time!
# self.rest_data_W0_n 0.44333510380414537
# self.rest_data_W0_a 0.3371992145070087
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.4460873583742297
# all_train_score_W_Combined_a 0.3401133055147601
# test_score_W_combined_n 0.47639178450502534
# test_score_W_combined_a 0.3274468775716592
# Combine Neurons Number :52
# neuron unit number: 15
# all_train_score_W0_n 0.3105122075339129
# all_train_score_W0_a 0.20191136267910495
# test_score_W0_n 0.3183648274768014
# test_score_W0_a  0.17197823089026176
# Split one time!
# self.rest_data_W0_n 0.3182601438617068
# self.rest_data_W0_a 0.2081009531369885
# Split one time!
# self.rest_data_W0_n 0.9074676525260507
# self.rest_data_W0_a 0.873034046399518
# all_train_score_W_Combined_n 0.33717455802966706
# all_train_score_W_Combined_a 0.22564165220935017
# test_score_W_combined_n 0.36533155892962366
# test_score_W_combined_a 0.20535494370473875
# Combine Neurons Number :28
# neuron unit number: 16
# all_train_score_W0_n 0.5171377821644001
# all_train_score_W0_a 0.43639984742153126
# test_score_W0_n 0.48211507154721667
# test_score_W0_a  0.3503986739915014
# Split one time!
# self.rest_data_W0_n 0.530115847116137
# self.rest_data_W0_a 0.44656025488832785
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5347925222470099
# all_train_score_W_Combined_a 0.4523179162824557
# test_score_W_combined_n 0.5524622998363108
# test_score_W_combined_a 0.428618554144519
# Combine Neurons Number :68
# neuron unit number: 17
# all_train_score_W0_n 0.361856410161431
# all_train_score_W0_a 0.24645323205066128
# test_score_W0_n 0.3632794705167769
# test_score_W0_a  0.22207210356319843
# Split one time!
# self.rest_data_W0_n 0.3718175105646935
# self.rest_data_W0_a 0.24380461422410482
# Split one time!
# self.rest_data_W0_n 0.7373935750425659
# self.rest_data_W0_a 0.6289439829048648
# all_train_score_W_Combined_n 0.38511298623392287
# all_train_score_W_Combined_a 0.2581099052197691
# test_score_W_combined_n 0.3838797973965771
# test_score_W_combined_a 0.22749402025716747
# Combine Neurons Number :27
# neuron unit number: 18
# all_train_score_W0_n 0.5681421826379168
# all_train_score_W0_a 0.4748110770644199
# test_score_W0_n 0.557256482971674
# test_score_W0_a  0.4142900447901276
# Split one time!
# self.rest_data_W0_n 0.5730443425218196
# self.rest_data_W0_a 0.48190501977837863
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5776187329010558
# all_train_score_W_Combined_a 0.48830888361565994
# test_score_W_combined_n 0.5966451939192354
# test_score_W_combined_a 0.46790989554042917
# Combine Neurons Number :87
# neuron unit number: 19
# all_train_score_W0_n 0.35428900444232075
# all_train_score_W0_a 0.22351778189288005
# test_score_W0_n 0.36458865429488396
# test_score_W0_a  0.20334896034776276
# Split one time!
# self.rest_data_W0_n 0.3625923139389462
# self.rest_data_W0_a 0.2320276244137958
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.37772922301012063
# all_train_score_W_Combined_a 0.24794067659026006
# test_score_W_combined_n 0.40058559024118395
# test_score_W_combined_a 0.23804260297673238
# Combine Neurons Number :31
# neuron unit number: 20
# all_train_score_W0_n 0.6256651483708112
# all_train_score_W0_a 0.5571508786367729
# test_score_W0_n 0.644542868437876
# test_score_W0_a  0.5566170079205889
# Split one time!
# self.rest_data_W0_n 0.6374227982868249
# self.rest_data_W0_a 0.5692990604555453
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6432786996619276
# all_train_score_W_Combined_a 0.5799309887755004
# test_score_W_combined_n 0.718977857148765
# test_score_W_combined_a 0.6270443771002295
# Combine Neurons Number :101
# neuron unit number: 21
# all_train_score_W0_n 0.40223983800716345
# all_train_score_W0_a 0.24748370817676926
# test_score_W0_n 0.39344973707181674
# test_score_W0_a  0.23889232668227384
# Split one time!
# self.rest_data_W0_n 0.4091840768161235
# self.rest_data_W0_a 0.2508680413054289
# Split one time!
# self.rest_data_W0_n 0.7420620563522774
# self.rest_data_W0_a 0.5054945054945055
# all_train_score_W_Combined_n 0.40953281718462986
# all_train_score_W_Combined_a 0.25430818591933585
# test_score_W_combined_n 0.4526688618513722
# test_score_W_combined_a 0.276717763244003
# Combine Neurons Number :25
# neuron unit number: 22
# all_train_score_W0_n 0.6484372175239772
# all_train_score_W0_a 0.5904858101744499
# test_score_W0_n 0.6052317148361118
# test_score_W0_a  0.48914174041146946
# Split one time!
# self.rest_data_W0_n 0.6504313498480744
# self.rest_data_W0_a 0.5949187443352536
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6532071251909872
# all_train_score_W_Combined_a 0.5975390015239278
# test_score_W_combined_n 0.6864531700997242
# test_score_W_combined_a 0.5979878623324167
# Combine Neurons Number :115
# neuron unit number: 23
# all_train_score_W0_n 0.34514041479473784
# all_train_score_W0_a 0.20449027988551943
# test_score_W0_n 0.38700604251506576
# test_score_W0_a  0.22179538069321264
# Split one time!
# self.rest_data_W0_n 0.3454226294594127
# self.rest_data_W0_a 0.20063792922494528
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.3522257342595916
# all_train_score_W_Combined_a 0.201671974037462
# test_score_W_combined_n 0.4154319745490467
# test_score_W_combined_a 0.2780262705864918
# Combine Neurons Number :29
# neuron unit number: 24
# all_train_score_W0_n 0.6912888199136886
# all_train_score_W0_a 0.6359382818202529
# test_score_W0_n 0.6819411368916286
# test_score_W0_a  0.5716452069619092
# Split one time!
# self.rest_data_W0_n 0.6908381200123409
# self.rest_data_W0_a 0.6366469677884253
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6926525027038078
# all_train_score_W_Combined_a 0.6377078409386151
# test_score_W_combined_n 0.7283990825634413
# test_score_W_combined_a 0.6262251857923684
# Combine Neurons Number :106
# neuron unit number: 25
# all_train_score_W0_n 0.39267593205240886
# all_train_score_W0_a 0.26560072799090556
# test_score_W0_n 0.4362964530698212
# test_score_W0_a  0.2861599133706207
# Split one time!
# self.rest_data_W0_n 0.3979928541895216
# self.rest_data_W0_a 0.2677208413647682
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.4036696731182201
# all_train_score_W_Combined_a 0.270879100576048
# test_score_W_combined_n 0.4663756212900684
# test_score_W_combined_a 0.30563025517258513
# Combine Neurons Number :30
# neuron unit number: 26
# all_train_score_W0_n 0.7299360252134627
# all_train_score_W0_a 0.7041427589244211
# test_score_W0_n 0.6920063828980973
# test_score_W0_a  0.6284752792499435
# Split one time!
# self.rest_data_W0_n 0.7351691013894235
# self.rest_data_W0_a 0.7091160477403851
# all_train_score_W_Combined_n 0.7376950831276857
# all_train_score_W_Combined_a 0.711441334692364
# test_score_W_combined_n 0.7498785646460647
# test_score_W_combined_a 0.6849053019356753
# Combine Neurons Number :137
# neuron unit number: 27
# all_train_score_W0_n 0.32988696485002306
# all_train_score_W0_a 0.2186005777991614
# test_score_W0_n 0.36647325729683283
# test_score_W0_a  0.2034228555755356
# Split one time!
# self.rest_data_W0_n 0.3465137663287504
# self.rest_data_W0_a 0.228043472319275
# Split one time!
# self.rest_data_W0_n 0.8968756529090475
# self.rest_data_W0_a 0.9769938650306749
# all_train_score_W_Combined_n 0.35087386256685543
# all_train_score_W_Combined_a 0.2307250331511448
# test_score_W_combined_n 0.38835652950034366
# test_score_W_combined_a 0.2185766390281488
# Combine Neurons Number :32
# neuron unit number: 28
# all_train_score_W0_n 0.7228234642601843
# all_train_score_W0_a 0.6757436373797429
# test_score_W0_n 0.5960003848997178
# test_score_W0_a  0.46916645692100933
# Split one time!
# self.rest_data_W0_n 0.7283035889766181
# self.rest_data_W0_a 0.6816460287380045
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7298564558123434
# all_train_score_W_Combined_a 0.6832160401398604
# test_score_W_combined_n 0.6681847438269312
# test_score_W_combined_a 0.55331106275247
# Combine Neurons Number :146
# neuron unit number: 29
# all_train_score_W0_n 0.4151420869340931
# all_train_score_W0_a 0.2799247882487384
# test_score_W0_n 0.3796951381505493
# test_score_W0_a  0.2283640507393044
# Split one time!
# self.rest_data_W0_n 0.4093139131800241
# self.rest_data_W0_a 0.28014380116207543
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.41752814902284546
# all_train_score_W_Combined_a 0.29091476973119657
# test_score_W_combined_n 0.4130467673234451
# test_score_W_combined_a 0.25857434007362146
# Combine Neurons Number :38
# neuron unit number: 30
# all_train_score_W0_n 0.8130765082652449
# all_train_score_W0_a 0.7941535649028035
# test_score_W0_n 0.7221049594162379
# test_score_W0_a  0.667614033453864
# Split one time!
# self.rest_data_W0_n 0.8123597896712262
# self.rest_data_W0_a 0.7934470901847342
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8130765082652449
# all_train_score_W_Combined_a 0.7941535649028035
# test_score_W_combined_n 0.8056624951709684
# test_score_W_combined_a 0.7748102547029456
# Combine Neurons Number :151
# neuron unit number: 31
# all_train_score_W0_n 0.5040873120346572
# all_train_score_W0_a 0.37652184843273295
# test_score_W0_n 0.48152561937976046
# test_score_W0_a  0.3107164210982312
# Split one time!
# self.rest_data_W0_n 0.5047114680447452
# self.rest_data_W0_a 0.37561889199058934
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5059854581667246
# all_train_score_W_Combined_a 0.3778047003390944
# test_score_W_combined_n 0.499710231976979
# test_score_W_combined_a 0.3159945819594208
# Combine Neurons Number :35
# neuron unit number: 32
# all_train_score_W0_n 0.7664772945836696
# all_train_score_W0_a 0.7446162281517382
# test_score_W0_n 0.7024270043789114
# test_score_W0_a  0.6580329457767121
# Split one time!
# self.rest_data_W0_n 0.7678963193602419
# self.rest_data_W0_a 0.7468652579583801
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7694622887144671
# all_train_score_W_Combined_a 0.7481488859455478
# test_score_W_combined_n 0.7758878722897742
# test_score_W_combined_a 0.7299936686265408
# Combine Neurons Number :147
# neuron unit number: 33
# all_train_score_W0_n 0.3354769652828235
# all_train_score_W0_a 0.21257078976157462
# test_score_W0_n 0.3522150764305652
# test_score_W0_a  0.19692474705122084
# Split one time!
# self.rest_data_W0_n 0.3405576508231072
# self.rest_data_W0_a 0.2148153477930879
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.3482228705178471
# all_train_score_W_Combined_a 0.22060268503906977
# test_score_W_combined_n 0.3990808470891204
# test_score_W_combined_a 0.23030334044591316
# Combine Neurons Number :39
# neuron unit number: 34
# all_train_score_W0_n 0.8666320830131975
# all_train_score_W0_a 0.8559178920501428
# test_score_W0_n 0.8012361161998786
# test_score_W0_a  0.7630758678948278
# Split one time!
# self.rest_data_W0_n 0.8657928968466679
# self.rest_data_W0_a 0.8550787961180261
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8666320830131975
# all_train_score_W_Combined_a 0.8559178920501428
# test_score_W_combined_n 0.8853818786759793
# test_score_W_combined_a 0.854527229971399
# Combine Neurons Number :172
# neuron unit number: 35
# all_train_score_W0_n 0.468944665844369
# all_train_score_W0_a 0.3388708361496219
# test_score_W0_n 0.4457041653538937
# test_score_W0_a  0.2648698193435543
# Split one time!
# self.rest_data_W0_n 0.47499934443725306
# self.rest_data_W0_a 0.3542479749419183
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.486265262267454
# all_train_score_W_Combined_a 0.3688036707689946
# test_score_W_combined_n 0.488493763593957
# test_score_W_combined_a 0.33168912496163055
# Combine Neurons Number :46
# neuron unit number: 36
# all_train_score_W0_n 0.7305917397661305
# all_train_score_W0_a 0.6908015484819647
# test_score_W0_n 0.6925233826175825
# test_score_W0_a  0.6173546726523454
# Split one time!
# self.rest_data_W0_n 0.731846887307732
# self.rest_data_W0_a 0.6910751118802388
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7333191963831608
# all_train_score_W_Combined_a 0.6939433782957615
# test_score_W_combined_n 0.7580788563330852
# test_score_W_combined_a 0.6838034368041482
# Combine Neurons Number :139
# neuron unit number: 37
# all_train_score_W0_n 0.4213650683896288
# all_train_score_W0_a 0.2951094500298525
# test_score_W0_n 0.4374750570926884
# test_score_W0_a  0.26830573772653976
# Split one time!
# self.rest_data_W0_n 0.423240713858474
# self.rest_data_W0_a 0.300927333880457
# Split one time!
# self.rest_data_W0_n 0.7916913688257836
# self.rest_data_W0_a 0.7637231503579952
# all_train_score_W_Combined_n 0.4375187525408492
# all_train_score_W_Combined_a 0.3139434870940536
# test_score_W_combined_n 0.43759693765318125
# test_score_W_combined_a 0.26127326880152857
# Not good ari result !!!!!
# Combine Neurons Number :42
# neuron unit number: 38
# all_train_score_W0_n 0.8175741317298054
# all_train_score_W0_a 0.8044324181785871
# test_score_W0_n 0.6929017560069045
# test_score_W0_a  0.6328666214034526
# Split one time!
# self.rest_data_W0_n 0.8168704847988921
# self.rest_data_W0_a 0.8036266898610332
# all_train_score_W_Combined_n 0.8175741317298054
# all_train_score_W_Combined_a 0.8044324181785871
# test_score_W_combined_n 0.8148433348372506
# test_score_W_combined_a 0.7827621771817556
# Combine Neurons Number :165
# neuron unit number: 39
# all_train_score_W0_n 0.4395205475638043
# all_train_score_W0_a 0.3273674126761328
# test_score_W0_n 0.43944654995818505
# test_score_W0_a  0.28858360999733584
# Split one time!
# self.rest_data_W0_n 0.4504579591679667
# self.rest_data_W0_a 0.3365509095890647
# Split one time!
# self.rest_data_W0_n 0.36340515765098635
# self.rest_data_W0_a 0.21087606600952485
# all_train_score_W_Combined_n 0.4566513904768277
# all_train_score_W_Combined_a 0.3428101512048478
# test_score_W_combined_n 0.4982007884084435
# test_score_W_combined_a 0.3714959038825553
# Combine Neurons Number :44
# neuron unit number: 40
# all_train_score_W0_n 0.69567539986153
# all_train_score_W0_a 0.6474819644218454
# test_score_W0_n 0.6477811975957618
# test_score_W0_a  0.5395920496585275
# Split one time!
# self.rest_data_W0_n 0.7010115585175198
# self.rest_data_W0_a 0.6580340935205924
# all_train_score_W_Combined_n 0.7036504538073245
# all_train_score_W_Combined_a 0.6592407455328126
# test_score_W_combined_n 0.7005278843095861
# test_score_W_combined_a 0.6100369438011216
# Combine Neurons Number :127
# neuron unit number: 41
# all_train_score_W0_n 0.38320689648275824
# all_train_score_W0_a 0.25997269949718366
# test_score_W0_n 0.3839288586491032
# test_score_W0_a  0.24088685109355298
# Split one time!
# self.rest_data_W0_n 0.3868215104090717
# self.rest_data_W0_a 0.26381657911158324
# Split one time!
# self.rest_data_W0_n 0.7512380323846723
# self.rest_data_W0_a 0.5320197044334976
# all_train_score_W_Combined_n 0.39227027054370245
# all_train_score_W_Combined_a 0.27025953807967723
# test_score_W_combined_n 0.41808151342179234
# test_score_W_combined_a 0.26950460581158026
# Combine Neurons Number :39
# neuron unit number: 42
# all_train_score_W0_n 0.8329392619435535
# all_train_score_W0_a 0.8287066979222667
# test_score_W0_n 0.7754096522654452
# test_score_W0_a  0.7439221702682466
# Split one time!
# self.rest_data_W0_n 0.8321647316474425
# self.rest_data_W0_a 0.8278585670834032
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.8329392619435535
# all_train_score_W_Combined_a 0.8287066979222667
# test_score_W_combined_n 0.8570318337370468
# test_score_W_combined_a 0.8352418076270909
# Combine Neurons Number :173
# neuron unit number: 43
# all_train_score_W0_n 0.5713159160777054
# all_train_score_W0_a 0.4812161474252318
# test_score_W0_n 0.543526059818231
# test_score_W0_a  0.40927741130107037
# Split one time!
# self.rest_data_W0_n 0.5902467940568562
# self.rest_data_W0_a 0.5020709368321166
# Split one time!
# self.rest_data_W0_n 0.9337184994946419
# self.rest_data_W0_a 0.9357935912126121
# all_train_score_W_Combined_n 0.5979639661797547
# all_train_score_W_Combined_a 0.5104927523873785
# test_score_W_combined_n 0.5919504397128852
# test_score_W_combined_a 0.4469414581090166
# Combine Neurons Number :53
# neuron unit number: 44
# all_train_score_W0_n 0.7962804651839939
# all_train_score_W0_a 0.774069655688245
# test_score_W0_n 0.7335692441578094
# test_score_W0_a  0.6836199196120435
# Split one time!
# self.rest_data_W0_n 0.8022756166336017
# self.rest_data_W0_a 0.7865515527006117
# all_train_score_W_Combined_n 0.8038386527158988
# all_train_score_W_Combined_a 0.7878548483144051
# test_score_W_combined_n 0.8365961159142165
# test_score_W_combined_a 0.8066703317937884
# Combine Neurons Number :158
# neuron unit number: 45
# all_train_score_W0_n 0.4861575005017666
# all_train_score_W0_a 0.3432257622770877
# test_score_W0_n 0.4753626580213919
# test_score_W0_a  0.31604483117976395
# Split one time!
# self.rest_data_W0_n 0.5202891083726585
# self.rest_data_W0_a 0.372254106545487
# Split one time!
# self.rest_data_W0_n 0.8235634489481841
# self.rest_data_W0_a 0.8522111485846375
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5353136772139524
# all_train_score_W_Combined_a 0.39316673507875693
# test_score_W_combined_n 0.5502644637368098
# test_score_W_combined_a 0.4108768495900875
# Combine Neurons Number :54
# neuron unit number: 46
# all_train_score_W0_n 0.7694101509512862
# all_train_score_W0_a 0.741989523203417
# test_score_W0_n 0.7120174821294364
# test_score_W0_a  0.6368426441534102
# Split one time!
# self.rest_data_W0_n 0.7691127473402664
# self.rest_data_W0_a 0.7397429331889448
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7707961304881761
# all_train_score_W_Combined_a 0.7420986129090262
# test_score_W_combined_n 0.7605488541196541
# test_score_W_combined_a 0.7130910679439253
# Combine Neurons Number :158
# neuron unit number: 47
# all_train_score_W0_n 0.44571896252645504
# all_train_score_W0_a 0.3297366250262611
# test_score_W0_n 0.42720440462847803
# test_score_W0_a  0.26902566440226494
# Split one time!
# self.rest_data_W0_n 0.4467448361860991
# self.rest_data_W0_a 0.3413388753943599
# Split one time!
# self.rest_data_W0_n 0.88615545363153
# self.rest_data_W0_a 0.8633808340959602
# all_train_score_W_Combined_n 0.453610024470281
# all_train_score_W_Combined_a 0.3463891768979195
# test_score_W_combined_n 0.5027184954056628
# test_score_W_combined_a 0.3594433142199477
# Combine Neurons Number :54
# neuron unit number: 48
# all_train_score_W0_n 0.7729486952318915
# all_train_score_W0_a 0.7501120129517548
# test_score_W0_n 0.6686091187934193
# test_score_W0_a  0.5743876575344955
# Split one time!
# self.rest_data_W0_n 0.7717706857677546
# self.rest_data_W0_a 0.748166647837501
# all_train_score_W_Combined_n 0.7729486952318915
# all_train_score_W_Combined_a 0.7501120129517548
# test_score_W_combined_n 0.7534495131601221
# test_score_W_combined_a 0.6817076343337729
# Combine Neurons Number :159
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  41.0  0.506953  0.155583  0.024298   0.457845  0.556061
# 1  test_score_W'  41.0  0.558896  0.175836  0.027461   0.503395  0.614397
# 2       combined  82.0  0.532924  0.167047  0.018447   0.496220  0.569629
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0519
# 1                          Degrees of freedom =   80.0000
# 2                                           t =   -1.4166
# 3                       Two side test p value =    0.1605
# 4                      Difference < 0 p value =    0.0802
# 5                      Difference > 0 p value =    0.9198
# 6                                   Cohen's d =   -0.3129
# 7                                   Hedge's g =   -0.3099
# 8                               Glass's delta =   -0.3339
# 9                                 Pearson's r =    0.1564
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  41.0  0.506953  0.155583  0.024298   0.457845  0.556061
# 1  test_score_W'  41.0  0.440454  0.220294  0.034404   0.370921  0.509987
# 2       combined  82.0  0.473703  0.192453  0.021253   0.431417  0.515990
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0665
# 1                          Degrees of freedom =   80.0000
# 2                                           t =    1.5788
# 3                       Two side test p value =    0.1183
# 4                      Difference < 0 p value =    0.9408
# 5                      Difference > 0 p value =    0.0592
# 6                                   Cohen's d =    0.3487
# 7                                   Hedge's g =    0.3454
# 8                               Glass's delta =    0.4274
# 9                                 Pearson's r =    0.1738
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.6972514700968963
# all_train_score_W0_a 0.6585277924620079
# test_score_W0_n 0.6545189594738499
# test_score_W0_a  0.5866937237284655
# Split one time!
# self.rest_data_W0_n 0.6964307306605665
# self.rest_data_W0_a 0.6561611361393408
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6990972433982734
# all_train_score_W_Combined_a 0.6592184386506292
# test_score_W_combined_n 0.7430560377233154
# test_score_W_combined_a 0.6895736954912014
# Combine Neurons Number :119
# all_train_score_W0_n 0.6796121626774122
# all_train_score_W0_a 0.6319118613568933
# test_score_W0_n 0.6598222653640942
# test_score_W0_a  0.5451894746341703
# Split one time!
# self.rest_data_W0_n 0.687561605829519
# self.rest_data_W0_a 0.642333808015749
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6917781567384588
# all_train_score_W_Combined_a 0.6454232148111109
# test_score_W_combined_n 0.6842934314483783
# test_score_W_combined_a 0.5797217158699315
# Combine Neurons Number :112
# all_train_score_W0_n 0.690296043667326
# all_train_score_W0_a 0.6333239092598466
# test_score_W0_n 0.620244000452256
# test_score_W0_a  0.4996694922943912
# Split one time!
# self.rest_data_W0_n 0.6976951508058513
# self.rest_data_W0_a 0.6446578185041478
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7007818459533874
# all_train_score_W_Combined_a 0.6465599426052674
# test_score_W_combined_n 0.7232566034041578
# test_score_W_combined_a 0.6318358026143357
# Combine Neurons Number :128
# all_train_score_W0_n 0.696942759947646
# all_train_score_W0_a 0.660785854916498
# test_score_W0_n 0.6288108272298711
# test_score_W0_a  0.517830632030821
# Split one time!
# self.rest_data_W0_n 0.6975488898692522
# self.rest_data_W0_a 0.662616191472679
# all_train_score_W_Combined_n 0.6984488932177412
# all_train_score_W_Combined_a 0.6634824950996099
# test_score_W_combined_n 0.6530337445651466
# test_score_W_combined_a 0.5652713275450433
# Combine Neurons Number :107
# all_train_score_W0_n 0.7516687903652064
# all_train_score_W0_a 0.7110829448005058
# test_score_W0_n 0.7347382426425833
# test_score_W0_a  0.6620368194806839
# Split one time!
# self.rest_data_W0_n 0.7520530246869723
# self.rest_data_W0_a 0.710414739281266
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7547791070168492
# all_train_score_W_Combined_a 0.7149119179262993
# test_score_W_combined_n 0.7499007295221557
# test_score_W_combined_a 0.6791483950375681
# Combine Neurons Number :127
# all_train_score_W0_n 0.7128449864475809
# all_train_score_W0_a 0.6697396473708183
# test_score_W0_n 0.5980161746318435
# test_score_W0_a  0.4855104235442047
# Split one time!
# self.rest_data_W0_n 0.7218351718615105
# self.rest_data_W0_a 0.6808498351677711
# all_train_score_W_Combined_n 0.7241455712426929
# all_train_score_W_Combined_a 0.6822888526432183
# test_score_W_combined_n 0.7369363674816729
# test_score_W_combined_a 0.6594375615609652
# Combine Neurons Number :122
# all_train_score_W0_n 0.6776304701431152
# all_train_score_W0_a 0.6218154607055782
# test_score_W0_n 0.643796404653159
# test_score_W0_a  0.5530913466489915
# Split one time!
# self.rest_data_W0_n 0.6751469171297546
# self.rest_data_W0_a 0.617621920459373
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6784573560441006
# all_train_score_W_Combined_a 0.6230639335130916
# test_score_W_combined_n 0.6788138867763447
# test_score_W_combined_a 0.5935491916443525
# Combine Neurons Number :132
# all_train_score_W0_n 0.7266409986476171
# all_train_score_W0_a 0.6867900314773673
# test_score_W0_n 0.6837351795067558
# test_score_W0_a  0.5568963487103017
# Split one time!
# self.rest_data_W0_n 0.7341475201753985
# self.rest_data_W0_a 0.6948605930061376
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7382198467266791
# all_train_score_W_Combined_a 0.7001971438733366
# test_score_W_combined_n 0.7208935331202329
# test_score_W_combined_a 0.6358582570861806
# Combine Neurons Number :126
# all_train_score_W0_n 0.6614210135485653
# all_train_score_W0_a 0.6125935270170206
# test_score_W0_n 0.607055235302785
# test_score_W0_a  0.5042584130916646
# Split one time!
# self.rest_data_W0_n 0.6586379785834979
# self.rest_data_W0_a 0.6082414309727204
# all_train_score_W_Combined_n 0.6614210135485653
# all_train_score_W_Combined_a 0.6125935270170206
# test_score_W_combined_n 0.6379602015437599
# test_score_W_combined_a 0.5731092206921228
# Combine Neurons Number :105
# all_train_score_W0_n 0.6286722640937766
# all_train_score_W0_a 0.5633027896022967
# test_score_W0_n 0.6140696760488731
# test_score_W0_a  0.4879047338444391
# Split one time!
# self.rest_data_W0_n 0.6384267690075262
# self.rest_data_W0_a 0.5756686614209534
# Split one time!
# self.rest_data_W0_n 0.8471846415220998
# self.rest_data_W0_a 0.7482014388489209
# all_train_score_W_Combined_n 0.6411362520207725
# all_train_score_W_Combined_a 0.5794799281868033
# test_score_W_combined_n 0.6690583378635472
# test_score_W_combined_a 0.5562758211227573
# Combine Neurons Number :106
# all_train_score_W0_n 0.6991374787120029
# all_train_score_W0_a 0.6594376033463577
# test_score_W0_n 0.6589952154518364
# test_score_W0_a  0.5672786231742747
# Split one time!
# self.rest_data_W0_n 0.6977031977282897
# self.rest_data_W0_a 0.6571006177629551
# all_train_score_W_Combined_n 0.6991374787120029
# all_train_score_W_Combined_a 0.6594376033463577
# test_score_W_combined_n 0.7470241651473399
# test_score_W_combined_a 0.670005701635435
# Combine Neurons Number :118
# all_train_score_W0_n 0.6657399562969282
# all_train_score_W0_a 0.5827498739070793
# test_score_W0_n 0.6601286166884142
# test_score_W0_a  0.5251816219327656
# Split one time!
# self.rest_data_W0_n 0.6732837201151544
# self.rest_data_W0_a 0.5954213374758751
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.678181574100515
# all_train_score_W_Combined_a 0.6018311680133437
# test_score_W_combined_n 0.7282253967963616
# test_score_W_combined_a 0.6059283465044604
# Combine Neurons Number :105
# all_train_score_W0_n 0.7210169743041844
# all_train_score_W0_a 0.689286687043843
# test_score_W0_n 0.6161100692389256
# test_score_W0_a  0.5169186186889799
# Split one time!
# self.rest_data_W0_n 0.7286605626077127
# self.rest_data_W0_a 0.7009627122893204
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7323215660147577
# all_train_score_W_Combined_a 0.7050420323875722
# test_score_W_combined_n 0.7383704005253143
# test_score_W_combined_a 0.6636822703286214
# Combine Neurons Number :140
# all_train_score_W0_n 0.6685894037854399
# all_train_score_W0_a 0.6182285997012025
# test_score_W0_n 0.613375935278373
# test_score_W0_a  0.5189744523903863
# Split one time!
# self.rest_data_W0_n 0.66938409952535
# self.rest_data_W0_a 0.6180554939187629
# all_train_score_W_Combined_n 0.670853946526111
# all_train_score_W_Combined_a 0.6202872268827447
# test_score_W_combined_n 0.6809815188802015
# test_score_W_combined_a 0.5858613202126172
# Combine Neurons Number :98
# all_train_score_W0_n 0.6768436204366458
# all_train_score_W0_a 0.6284005406584587
# test_score_W0_n 0.6199327875218138
# test_score_W0_a  0.5136083804598657
# Split one time!
# self.rest_data_W0_n 0.6880643066280346
# self.rest_data_W0_a 0.6505182700370913
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6920961079411461
# all_train_score_W_Combined_a 0.6534707013035564
# test_score_W_combined_n 0.7447062088969185
# test_score_W_combined_a 0.6600160065302462
# Combine Neurons Number :125
# all_train_score_W0_n 0.7085906025670937
# all_train_score_W0_a 0.6653480395274155
# test_score_W0_n 0.6405806243511682
# test_score_W0_a  0.5439125599312296
# Split one time!
# self.rest_data_W0_n 0.7112764686203161
# self.rest_data_W0_a 0.6704633181990114
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7142688212823153
# all_train_score_W_Combined_a 0.6744799261626614
# test_score_W_combined_n 0.71670819511635
# test_score_W_combined_a 0.6374053897667632
# Combine Neurons Number :124
# all_train_score_W0_n 0.7061631251452382
# all_train_score_W0_a 0.6619861682693265
# test_score_W0_n 0.6360640377539183
# test_score_W0_a  0.5210721861916299
# Split one time!
# self.rest_data_W0_n 0.7096599015065607
# self.rest_data_W0_a 0.6596070229575268
# all_train_score_W_Combined_n 0.7110179739282817
# all_train_score_W_Combined_a 0.6615760701506957
# test_score_W_combined_n 0.6895522744329123
# test_score_W_combined_a 0.5678270348385975
# Combine Neurons Number :112
# all_train_score_W0_n 0.6720311883659057
# all_train_score_W0_a 0.6202476083633999
# test_score_W0_n 0.625461902609743
# test_score_W0_a  0.5266338454006441
# Split one time!
# self.rest_data_W0_n 0.6760152256654515
# self.rest_data_W0_a 0.6277172709085621
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.679223176094177
# all_train_score_W_Combined_a 0.6308604036214562
# test_score_W_combined_n 0.6804917850425892
# test_score_W_combined_a 0.6014403790435517
# Combine Neurons Number :114
# all_train_score_W0_n 0.6710561930451981
# all_train_score_W0_a 0.6157574528833253
# test_score_W0_n 0.577597219569942
# test_score_W0_a  0.48070051779059214
# Split one time!
# self.rest_data_W0_n 0.6831499703042784
# self.rest_data_W0_a 0.6352740972787849
# all_train_score_W_Combined_n 0.6858907154912547
# all_train_score_W_Combined_a 0.6384806024184304
# test_score_W_combined_n 0.661037607899624
# test_score_W_combined_a 0.5817890537440523
# Combine Neurons Number :119
# all_train_score_W0_n 0.6585340976917218
# all_train_score_W0_a 0.618787957787606
# test_score_W0_n 0.609598165003582
# test_score_W0_a  0.5232653061251729
# Split one time!
# self.rest_data_W0_n 0.6627735250896136
# self.rest_data_W0_a 0.6216025128937732
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6643677386440952
# all_train_score_W_Combined_a 0.6233666399620095
# test_score_W_combined_n 0.7085544798009749
# test_score_W_combined_a 0.6430901768589995
# Combine Neurons Number :112
# all_train_score_W0_n 0.7069247174904713
# all_train_score_W0_a 0.6773699577283089
# test_score_W0_n 0.6489380179183947
# test_score_W0_a  0.5886515006832354
# Split one time!
# self.rest_data_W0_n 0.7009315007864202
# self.rest_data_W0_a 0.6756849801207647
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7050100943223867
# all_train_score_W_Combined_a 0.6800563943517764
# test_score_W_combined_n 0.7625894706718941
# test_score_W_combined_a 0.6912823120225875
# Combine Neurons Number :118
# all_train_score_W0_n 0.6398883318411164
# all_train_score_W0_a 0.5845195899710778
# test_score_W0_n 0.5683494950219389
# test_score_W0_a  0.4595028802089011
# Split one time!
# self.rest_data_W0_n 0.6434962611190571
# self.rest_data_W0_a 0.5913666488612377
# all_train_score_W_Combined_n 0.6455051842887969
# all_train_score_W_Combined_a 0.5929167470452615
# test_score_W_combined_n 0.6252112274792263
# test_score_W_combined_a 0.5482247116359446
# Combine Neurons Number :105
# all_train_score_W0_n 0.6679550136394997
# all_train_score_W0_a 0.6221119639489265
# test_score_W0_n 0.6103693416437956
# test_score_W0_a  0.5161860651315016
# Split one time!
# self.rest_data_W0_n 0.6762551082617136
# self.rest_data_W0_a 0.6317594369880208
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6784531021510924
# all_train_score_W_Combined_a 0.6329199981749174
# test_score_W_combined_n 0.723650556387497
# test_score_W_combined_a 0.6428269062580084
# Combine Neurons Number :105
# all_train_score_W0_n 0.675208221142445
# all_train_score_W0_a 0.6407804961725682
# test_score_W0_n 0.5921321307856324
# test_score_W0_a  0.5027776756941474
# Split one time!
# self.rest_data_W0_n 0.6761719518373643
# self.rest_data_W0_a 0.6421730826738166
# all_train_score_W_Combined_n 0.6765077122118315
# all_train_score_W_Combined_a 0.6421285972532478
# test_score_W_combined_n 0.6413154601249682
# test_score_W_combined_a 0.5667123127832034
# Combine Neurons Number :107
# all_train_score_W0_n 0.6897873863853997
# all_train_score_W0_a 0.6211426799067068
# test_score_W0_n 0.6434375690028937
# test_score_W0_a  0.5261511515544393
# Split one time!
# self.rest_data_W0_n 0.6926521507996697
# self.rest_data_W0_a 0.6279105691132939
# all_train_score_W_Combined_n 0.6948514475860255
# all_train_score_W_Combined_a 0.6307968661303263
# test_score_W_combined_n 0.701220379753991
# test_score_W_combined_a 0.5853351658903879
# Combine Neurons Number :114
# all_train_score_W0_n 0.6918079038155591
# all_train_score_W0_a 0.6351813713124852
# test_score_W0_n 0.6138588283126338
# test_score_W0_a  0.48805259076523577
# Split one time!
# self.rest_data_W0_n 0.6997388360207294
# self.rest_data_W0_a 0.6398532665557045
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.704626250368723
# all_train_score_W_Combined_a 0.646643665204395
# test_score_W_combined_n 0.6892231461600827
# test_score_W_combined_a 0.579372721499884
# Combine Neurons Number :118
# all_train_score_W0_n 0.7440102572551893
# all_train_score_W0_a 0.7206313468864889
# test_score_W0_n 0.6345216638525943
# test_score_W0_a  0.5305860145734858
# Split one time!
# self.rest_data_W0_n 0.742547058900897
# self.rest_data_W0_a 0.718476179153545
# all_train_score_W_Combined_n 0.7440102572551893
# all_train_score_W_Combined_a 0.7206313468864889
# test_score_W_combined_n 0.7308423881373387
# test_score_W_combined_a 0.6377040926591478
# Combine Neurons Number :119
# all_train_score_W0_n 0.7025625987431479
# all_train_score_W0_a 0.6570364898993012
# test_score_W0_n 0.6628560872420273
# test_score_W0_a  0.5572107825010617
# Split one time!
# self.rest_data_W0_n 0.699885375158771
# self.rest_data_W0_a 0.6541121383879828
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7025625987431479
# all_train_score_W_Combined_a 0.6570364898993012
# test_score_W_combined_n 0.7235775925404997
# test_score_W_combined_a 0.6268140885512915
# Combine Neurons Number :121
# all_train_score_W0_n 0.6368335626743616
# all_train_score_W0_a 0.5638502733248709
# test_score_W0_n 0.5702453748901937
# test_score_W0_a  0.43934748163610304
# Split one time!
# self.rest_data_W0_n 0.6471293080651082
# self.rest_data_W0_a 0.5760037612803295
# all_train_score_W_Combined_n 0.6495015597630054
# all_train_score_W_Combined_a 0.5804370074917048
# test_score_W_combined_n 0.6177484270496569
# test_score_W_combined_a 0.474966299338767
# Combine Neurons Number :107
# all_train_score_W0_n 0.7040480301930432
# all_train_score_W0_a 0.6379902338451946
# test_score_W0_n 0.6162448174219765
# test_score_W0_a  0.4992441151641899
# Split one time!
# self.rest_data_W0_n 0.7075756772235168
# self.rest_data_W0_a 0.6408932571397009
# all_train_score_W_Combined_n 0.7082530294948781
# all_train_score_W_Combined_a 0.6421151719606774
# test_score_W_combined_n 0.702037930161885
# test_score_W_combined_a 0.5956092109847337
# Combine Neurons Number :124
# all_train_score_W0_n 0.7425754632120768
# all_train_score_W0_a 0.7041901533785888
# test_score_W0_n 0.707985226071537
# test_score_W0_a  0.6510668514817678
# Split one time!
# self.rest_data_W0_n 0.7454241077613497
# self.rest_data_W0_a 0.7093864291036791
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7470547447548986
# all_train_score_W_Combined_a 0.7112400921346413
# test_score_W_combined_n 0.7754700930088099
# test_score_W_combined_a 0.7102248580676459
# Combine Neurons Number :136
# all_train_score_W0_n 0.600211386348272
# all_train_score_W0_a 0.5236502870213898
# test_score_W0_n 0.5166092633967831
# test_score_W0_a  0.3864899118075842
# Split one time!
# self.rest_data_W0_n 0.6116968355539316
# self.rest_data_W0_a 0.5319831156433114
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6185159149349985
# all_train_score_W_Combined_a 0.5423206589132511
# test_score_W_combined_n 0.6104379497961888
# test_score_W_combined_a 0.47307966175640653
# Combine Neurons Number :112
# all_train_score_W0_n 0.7263187412081249
# all_train_score_W0_a 0.6819198471556736
# test_score_W0_n 0.6798224212621771
# test_score_W0_a  0.5752679004633836
# Split one time!
# self.rest_data_W0_n 0.7202291142529434
# self.rest_data_W0_a 0.6842186509547228
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7246228661322242
# all_train_score_W_Combined_a 0.6904842863458476
# test_score_W_combined_n 0.7028066680181243
# test_score_W_combined_a 0.620365358282112
# Combine Neurons Number :130
# all_train_score_W0_n 0.669909595971452
# all_train_score_W0_a 0.5803757617382579
# test_score_W0_n 0.615448917637712
# test_score_W0_a  0.5077801908190213
# Split one time!
# self.rest_data_W0_n 0.6764520348820628
# self.rest_data_W0_a 0.59514697935292
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6798136104813407
# all_train_score_W_Combined_a 0.5979792200909261
# test_score_W_combined_n 0.709931295599368
# test_score_W_combined_a 0.5801985696708055
# Combine Neurons Number :117
# all_train_score_W0_n 0.7128975747123993
# all_train_score_W0_a 0.6632253530943596
# test_score_W0_n 0.6587966391509077
# test_score_W0_a  0.5641189534962605
# Split one time!
# self.rest_data_W0_n 0.7148424850719829
# self.rest_data_W0_a 0.6642941878191027
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7165866917800793
# all_train_score_W_Combined_a 0.6661185838289317
# test_score_W_combined_n 0.722703289539897
# test_score_W_combined_a 0.6283860346338923
# Combine Neurons Number :114
# all_train_score_W0_n 0.7791251787395577
# all_train_score_W0_a 0.760061147473109
# test_score_W0_n 0.7638205513920142
# test_score_W0_a  0.7040483177852169
# Split one time!
# self.rest_data_W0_n 0.783176536151284
# self.rest_data_W0_a 0.765266196788341
# all_train_score_W_Combined_n 0.78530391014893
# all_train_score_W_Combined_a 0.7680794816788341
# test_score_W_combined_n 0.8298759279591704
# test_score_W_combined_a 0.7884639447323205
# Combine Neurons Number :129
# all_train_score_W0_n 0.7264611677889157
# all_train_score_W0_a 0.673722516025614
# test_score_W0_n 0.6794018886746268
# test_score_W0_a  0.58689612839418
# Split one time!
# self.rest_data_W0_n 0.7285494036103201
# self.rest_data_W0_a 0.6769743999184452
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7309901334548863
# all_train_score_W_Combined_a 0.6802369734585757
# test_score_W_combined_n 0.7354204178124486
# test_score_W_combined_a 0.6519402624224335
# Combine Neurons Number :120
# all_train_score_W0_n 0.7051212781452485
# all_train_score_W0_a 0.6507647982516784
# test_score_W0_n 0.6063826421559938
# test_score_W0_a  0.4973079493086729
# Split one time!
# self.rest_data_W0_n 0.7051167170231523
# self.rest_data_W0_a 0.6511747923041152
# all_train_score_W_Combined_n 0.7062514818462383
# all_train_score_W_Combined_a 0.6528197984422958
# test_score_W_combined_n 0.6870996029522369
# test_score_W_combined_a 0.5944713700516708
# Combine Neurons Number :117
# all_train_score_W0_n 0.7006745298732278
# all_train_score_W0_a 0.660925393926034
# test_score_W0_n 0.68941726989279
# test_score_W0_a  0.6190483797126426
# Split one time!
# self.rest_data_W0_n 0.6998979478311325
# self.rest_data_W0_a 0.6599327380334105
# all_train_score_W_Combined_n 0.7006745298732278
# all_train_score_W_Combined_a 0.660925393926034
# test_score_W_combined_n 0.731841360932305
# test_score_W_combined_a 0.6720091365014643
# Combine Neurons Number :118
# all_train_score_W0_n 0.6956894085636276
# all_train_score_W0_a 0.6444587608041413
# test_score_W0_n 0.6877997508406823
# test_score_W0_a  0.6017280649681338
# Split one time!
# self.rest_data_W0_n 0.6953781570454142
# self.rest_data_W0_a 0.6450174233204976
# Split one time!
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6970824628599604
# all_train_score_W_Combined_a 0.6465336066380913
# test_score_W_combined_n 0.735911524086893
# test_score_W_combined_a 0.6584198011318954
# Combine Neurons Number :120
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  40.0  0.636727  0.046076  0.007285   0.621991  0.651463
# 1  test_score_W'  40.0  0.706294  0.044964  0.007109   0.691914  0.720674
# 2       combined  80.0  0.671511  0.057196  0.006395   0.658782  0.684239
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0696
# 1                          Degrees of freedom =   78.0000
# 2                                           t =   -6.8341
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.5282
# 7                                   Hedge's g =   -1.5134
# 8                               Glass's delta =   -1.5098
# 9                                 Pearson's r =    0.6120
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  40.0  0.636727  0.046076  0.007285   0.621991  0.651463
# 1  test_score_W'  40.0  0.617681  0.059578  0.009420   0.598627  0.636735
# 2       combined  80.0  0.627204  0.053779  0.006013   0.615236  0.639172
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0190
# 1                          Degrees of freedom =   78.0000
# 2                                           t =    1.5994
# 3                       Two side test p value =    0.1138
# 4                      Difference < 0 p value =    0.9431
# 5                      Difference > 0 p value =    0.0569
# 6                                   Cohen's d =    0.3576
# 7                                   Hedge's g =    0.3542
# 8                               Glass's delta =    0.4134
# 9                                 Pearson's r =    0.1782
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
