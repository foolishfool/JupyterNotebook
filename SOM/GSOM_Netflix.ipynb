# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import newSom
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
from fcmeans import FCM
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")

#dataread.data_train_discrete
# Out:
# self.continuous_feature_num 3
# self.data_discrete_indexes ['Monthly Revenue', 'Country', 'Gender', 'Device']

# %%
import experiment
unstable_repeat_num= 30
best_num =26
scope_num = 100
class_num = 2
interval = 5

features_chosen = [0,1,2]
feature_combination_number = 2
experiment = experiment.Experiment()
experiment.UTtest_Discrete(dataread,class_num,scope_num,interval,features_chosen,feature_combination_number)
# Out:
# Neuron number: 2
# test_score_W0_p0.428
# test_score_W0_n 0.04429397636237867
# test_score_W0_a  0.039403928246153457
# test_score_W_combine_p 0.428
# test_score_W_combine_n 0.04429397636237867
# test_score_W_combine_a 0.039403928246153457
# Neuron number: 7
# test_score_W0_p0.47733333333333333
# test_score_W0_n 0.06043964362248026
# test_score_W0_a  0.048528202908704354
# test_score_W_combine_p 0.432
# test_score_W_combine_n 0.019864731051748654
# test_score_W_combine_a 0.025342937034203
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 12
# test_score_W0_p0.49333333333333335
# test_score_W0_n 0.06702581714166296
# test_score_W0_a  0.06144546949319521
# test_score_W_combine_p 0.492
# test_score_W_combine_n 0.07546813570980766
# test_score_W_combine_a 0.09033361695520026
# Not good purity result !!!!!
# Neuron number: 17
# test_score_W0_p0.5026666666666667
# test_score_W0_n 0.06503203679457246
# test_score_W0_a  0.08010921245110406
# test_score_W_combine_p 0.476
# test_score_W_combine_n 0.03821641996306385
# test_score_W_combine_a 0.044878906066967206
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 22
# test_score_W0_p0.5
# test_score_W0_n 0.054876928504747194
# test_score_W0_a  0.0689542492965087
# test_score_W_combine_p 0.484
# test_score_W_combine_n 0.04364364453356963
# test_score_W_combine_a 0.04683130758291588
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 27
# test_score_W0_p0.5106666666666667
# test_score_W0_n 0.0625355301115048
# test_score_W0_a  0.06922496182606837
# test_score_W_combine_p 0.45866666666666667
# test_score_W_combine_n 0.030934874815443
# test_score_W_combine_a 0.03277454785954625
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 32
# test_score_W0_p0.548
# test_score_W0_n 0.086161302837162
# test_score_W0_a  0.10676799281577556
# test_score_W_combine_p 0.4533333333333333
# test_score_W_combine_n 0.022846964637620756
# test_score_W_combine_a 0.03114079447563324
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 37
# test_score_W0_p0.49733333333333335
# test_score_W0_n 0.052391724799620135
# test_score_W0_a  0.06152404635898985
# test_score_W_combine_p 0.444
# test_score_W_combine_n 0.021799708839289153
# test_score_W_combine_a 0.022479466807467017
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 42
# test_score_W0_p0.5533333333333333
# test_score_W0_n 0.09621150427855596
# test_score_W0_a  0.11392322106259443
# test_score_W_combine_p 0.4786666666666667
# test_score_W_combine_n 0.059825055262484036
# test_score_W_combine_a 0.04109838823897037
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 47
# test_score_W0_p0.5146666666666667
# test_score_W0_n 0.06976229203408708
# test_score_W0_a  0.07881586623871688
# test_score_W_combine_p 0.44133333333333336
# test_score_W_combine_n 0.020760439760317537
# test_score_W_combine_a 0.025291369484922856
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 52
# test_score_W0_p0.568
# test_score_W0_n 0.10798943486864275
# test_score_W0_a  0.12479926659188009
# test_score_W_combine_p 0.44133333333333336
# test_score_W_combine_n 0.01872071604840657
# test_score_W_combine_a 0.026758738377996846
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 57
# test_score_W0_p0.5786666666666667
# test_score_W0_n 0.11130758924749634
# test_score_W0_a  0.13474830573983634
# test_score_W_combine_p 0.45066666666666666
# test_score_W_combine_n 0.02218116953397708
# test_score_W_combine_a 0.03150793779970716
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 62
# test_score_W0_p0.548
# test_score_W0_n 0.08563538303432847
# test_score_W0_a  0.10308507572002754
# test_score_W_combine_p 0.4706666666666667
# test_score_W_combine_n 0.033804763029588944
# test_score_W_combine_a 0.044582303488472565
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 67
# test_score_W0_p0.5333333333333333
# test_score_W0_n 0.07655329680330736
# test_score_W0_a  0.09050906763169035
# test_score_W_combine_p 0.4573333333333333
# test_score_W_combine_n 0.02455410692247829
# test_score_W_combine_a 0.03180527443891328
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 72
# test_score_W0_p0.5706666666666667
# test_score_W0_n 0.11489159427536663
# test_score_W0_a  0.12202516921877025
# test_score_W_combine_p 0.4746666666666667
# test_score_W_combine_n 0.034148197907412595
# test_score_W_combine_a 0.04660588627629494
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 77
# test_score_W0_p0.5813333333333334
# test_score_W0_n 0.11553561154547101
# test_score_W0_a  0.13669991127403153
# test_score_W_combine_p 0.4613333333333333
# test_score_W_combine_n 0.02817418941327886
# test_score_W_combine_a 0.041195523238669866
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 82
# test_score_W0_p0.564
# test_score_W0_n 0.10280434595137163
# test_score_W0_a  0.12005168651554761
# test_score_W_combine_p 0.504
# test_score_W_combine_n 0.056451548929465446
# test_score_W_combine_a 0.0676463924891009
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 87
# test_score_W0_p0.564
# test_score_W0_n 0.09715941745746859
# test_score_W0_a  0.11805604619192765
# test_score_W_combine_p 0.45466666666666666
# test_score_W_combine_n 0.024941448949426626
# test_score_W_combine_a 0.03551141016884792
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 92
# test_score_W0_p0.596
# test_score_W0_n 0.12642317177898707
# test_score_W0_a  0.15594558601698583
# test_score_W_combine_p 0.4653333333333333
# test_score_W_combine_n 0.029198623281228943
# test_score_W_combine_a 0.03824044744026354
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# Neuron number: 97
# test_score_W0_p0.49733333333333335
# test_score_W0_n 0.05359646692860652
# test_score_W0_a  0.06152999192173513
# test_score_W_combine_p 0.472
# test_score_W_combine_n 0.036388450420683144
# test_score_W_combine_a 0.04081350280745826
# Not good purity result !!!!!
# Not good nmi result !!!!!
# Not good ari !!!!!
# all_test_score_W0_p mean 0.5313333333333333
# all_test_score_W0_n mean 0.08253135341889088
# all_test_score_W0_a mean 0.09480736287601216
# all_test_score_W_combine_p mean 0.4619999999999999
# all_test_score_W_combine_n mean 0.034310858268583475
# all_test_score_W_combine_a mean 0.04021213396388524
# Purity T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_p  20.0  0.531333  0.042828  0.009577   0.511289
# 1  all_test_score_W_combine_p  20.0  0.462000  0.019859  0.004441   0.452706
# 2                    combined  40.0  0.496667  0.048149  0.007613   0.481268
#
#    Interval
# 0  0.551377
# 1  0.471294
# 2  0.512065
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_p - all_test_sco...   0.0693
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    6.5681
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.0770
# 7                                       Hedge's g =    2.0358
# 8                                  Glass's delta1 =    1.6189
# 9                                Point-Biserial r =    0.7292
# NMI T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_n  20.0  0.082531  0.025110  0.005615   0.070779
# 1  all_test_score_W_combine_n  20.0  0.034311  0.015166  0.003391   0.027213
# 2                    combined  40.0  0.058421  0.031866  0.005038   0.048230
#
#    Interval
# 0  0.094283
# 1  0.041409
# 2  0.068612
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_n - all_test_sco...   0.0482
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    7.3513
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.3247
# 7                                       Hedge's g =    2.2785
# 8                                  Glass's delta1 =    1.9204
# 9                                Point-Biserial r =    0.7663
# ARI Score T-Test
#                      Variable     N      Mean        SD        SE  95% Conf.  \
# 0         all_test_score_W0_a  20.0  0.094807  0.033115  0.007405   0.079309
# 1  all_test_score_W_combine_a  20.0  0.040212  0.015631  0.003495   0.032897
# 2                    combined  40.0  0.067510  0.037650  0.005953   0.055469
#
#    Interval
# 0  0.110306
# 1  0.047528
# 2  0.079551
#                                   Independent t-test  results
# 0  Difference (all_test_score_W0_a - all_test_sco...   0.0546
# 1                              Degrees of freedom =   38.0000
# 2                                               t =    6.6675
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.1084
# 7                                       Hedge's g =    2.0666
# 8                                  Glass's delta1 =    1.6486
# 9                                Point-Biserial r =    0.7343
