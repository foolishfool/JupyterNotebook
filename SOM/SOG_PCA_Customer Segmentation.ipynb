# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
# Out:
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\__init__.py:132: UserWarning: A NumPy version >=1.21.6 and <1.28.0 is required for this version of SciPy (detected version 1.21.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CustomerSegmentation/Train.csv")
csv2 = pd.read_csv("CustomerSegmentation/Test.csv")
csv = csv.drop(columns=['ID','Segmentation'])
csv2 = csv2.drop(columns=['ID'])   

csv['Family_Size'] = pd.to_numeric(csv['Family_Size'])
csv2['Family_Size'] = pd.to_numeric(csv2['Family_Size'])
csv['Work_Experience'] = pd.to_numeric(csv['Work_Experience'])
csv2['Work_Experience'] = pd.to_numeric(csv2['Work_Experience'])

csv_original_encode1 = csv
csv_original_encode2 = csv2

# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode1,"Var_1")
#one hot encoding vs proposed
dataread.onehot_encoding(csv_original_encode1,["Gender","Ever_Married","Graduated","Profession","Spending_Score","Family_Size","Work_Experience"])




csv_training_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.5))


dataread.label_encoding(csv_original_encode2,"Var_1")
#one hot encoding vs proposed
dataread.onehot_encoding(csv_original_encode2,["Gender","Ever_Married","Graduated","Profession","Spending_Score","Family_Size","Work_Experience"])


#dataread.original_encoding_data is udpated through dataread.label_encoding function
csv_test_original_encoded = dataread.original_encoding_data

dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Ever_Married")
dataread.label_encoding(csv,"Graduated")
dataread.label_encoding(csv,"Profession")
dataread.label_encoding(csv,"Spending_Score")
dataread.label_encoding(csv,"Var_1")
dataread.label_encoding(csv,"Family_Size")
dataread.label_encoding(csv,"Work_Experience")

# label encoding
#dataread.original_encoding_data = csv
#*** -1 the class labe is not included 
#dataread.original_encoded_feature_num = csv.shape[1]-1



dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Ever_Married")
dataread.label_encoding(csv2,"Graduated")
dataread.label_encoding(csv2,"Profession")
dataread.label_encoding(csv2,"Spending_Score")
dataread.label_encoding(csv2,"Var_1")
dataread.label_encoding(csv2,"Family_Size")
dataread.label_encoding(csv2,"Work_Experience")



csv_training = csv.sample(int(csv.shape[0]*0.5))

#csv_training_original_encoded = csv_training

csv_test = csv2

#csv_test_original_encoded = csv_test


dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Var_1")
# Out:
# self.data_continuous_indexes ['Age']
# self.continuous_feature_num 1
#  column number self.data_train_discrete 7

# %%
#SpectralClustering
import experiment
unstable_repeat_num= 30
scope_num = 40
class_num = 13
dim_num = 7
best_num = 48
interval = 2


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# 13
# (4034, 43)
# Sorted index for feature 0 [42, 41, 38, 26, 21, 36, 30, 3, 32, 40, 39, 23, 22, 24, 33, 29, 34, 28, 31, 37, 35, 25, 19, 16, 27, 20, 15, 13, 17, 4, 6, 9, 10, 2, 14, 5, 8, 11, 18, 12, 7, 1, 0]
# Sorted list for feature 0  [0.9994488015905917, 0.024729941278314044, 0.01267119446979368, 0.008971124925949705, 0.007650777173576521, 0.005435874678699153, 0.005015725850717929, 0.004251445407795964, 0.004092609053740412, 0.0037204039877127807, 0.003714453051879586, 0.0036003349908158137, 0.003563183752971907, 0.003547319403386032, 0.003487764660589935, 0.0026409602953499853, 0.002003214789999904, 0.0017933251897518604, 0.0017539588135346744, 0.001514550263064467, 0.0009897266653686185, 0.0009249348508351128, 0.000785491526050595, 0.
#  5.96761219e-05 4.90232130e-05 3.28610710e-05 2.85608835e-05
#  1.64799959e-05 7.18598968e-06 6.47322223e-06 5.85453988e-06
#  4.12865356e-06 8.24159536e-07 7.14991535e-07 4.29326249e-07
#  2.33258815e-07 2.06462390e-07 1.15818690e-07 7.96080253e-08
#  2.46584714e-27 8.72991029e-31 1.40021175e-31 8.56936762e-32
#  5.64997433e-32 3.71177812e-32 3.27978800e-32 2.28143877e-32
#  2.12871382e-32 1.61793552e-32 1.25331943e-32 9.72964206e-33
#  9.64531956e-33 9.01707574e-33 8.17868025e-33 4.98162633e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  3.36535926e-33 3.36535926e-33 3.36535926e-33 3.36535926e-33
#  2.38740544e-33 1.55971508e-33 1.25602172e-33 7.40856204e-34
#  7.05249979e-35]
# neuron unit number: 21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       8 interval = 2
#      11 experiment = experiment.Experiment()
# ---> 12 experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
#
# File C:\JupyterDoc\SOM\experiment.py:313, in Experiment.UTtest_Discrete_Continuous(self, dataread, noralimized, class_num, best_num, neuron_scope_num, unstable_repeat_num, type, interval, test_type, compareType)
#     311 while y <= neuron_scope_num:
#     312     print("neuron unit number: {}".format(y))
# --> 313     self.InitializedExperimentDataList(
#     314                         dataread,
#     315                         noralimized,
#     316                         y,
#     317                         all_train_score_W0_p,
#     318                         all_train_score_W_combine_p,
#     319                         test_score_W0_p,
#     320                         test_score_W_combine_p,
#     321                         all_train_score_W0_n,
#     322                         all_train_score_W_combine_n,
#     323                         test_score_W0_n,
#     324                         test_score_W_combine_n,
#     325                         all_train_score_W0_a,
#     326                         all_train_score_W_combine_a,
#     327                         test_score_W0_a,
#     328                         test_score_W_combine_a,
#     329                         train_discrete_score_W0_p,
#     330                         train_discrete_score_W_discrete_p,
#     331                         test_discrete_score_W0_p,
#     332                         test_discrete_score_W_discrete_p,
#     333                         train_discrete_score_W0_n,
#     334                         train_discrete_score_W_discrete_n,
#     335                         test_discrete_score_W0_n,
#     336                         test_discrete_score_W_discrete_n,
#     337                         train_discrete_score_W0_a,
#     338                         train_discrete_score_W_discrete_a,
#     339                         test_discrete_score_W0_a,
#     340                         test_discrete_score_W_discrete_a,
#     341                         test_type,
#     342                         compareType
#     343                         )
#     344     y =y + interval
#     345     if(y<= neuron_scope_num):
#
# File C:\JupyterDoc\SOM\experiment.py:203, in Experiment.InitializedExperimentDataList(self, dataread, continuous_features_noralimized, y, all_train_score_W0_p, all_train_score_W_combine_p, test_score_W0_p, test_score_W_combine_p, all_train_score_W0_n, all_train_score_W_combine_n, test_score_W0_n, test_score_W_combine_n, all_train_score_W0_a, all_train_score_W_combine_a, test_score_W0_a, test_score_W_combine_a, train_discrete_score_W0_p, train_discrete_score_W_discrete_p, test_discrete_score_W0_p, test_discrete_score_W_discrete_p, train_discrete_score_W0_n, train_discrete_score_W_discrete_n, test_discrete_score_W0_n, test_discrete_score_W_discrete_n, train_discrete_score_W0_a, train_discrete_score_W_discrete_a, test_discrete_score_W0_a, test_discrete_score_W_discrete_a, iscontinous_data_test, compareType)
#     199     optimize_W.do_COSOM(optimize_W.som_discrete_original,optimize_W.data_train_discrete_normalized, optimize_W.data_train_discrete_unnormalized, optimize_W.data_test_discrete_normalized,optimize_W.data_test_discrete_unnormalized,iscontinous_data_test,1)
#     200 if compareType == 3: #discrete unnormalization
#     201     # optimize_W.do_DOSOM(False)
#     202      #get self.discrete_data_embedding_sog  and  self.test_new_embedding_sog
# --> 203      optimize_W.get_SOG_Embedding()
#     204 if compareType == 4: # hybrid embedding continous + discrete_embedding
#     205      optimize_W.do_CDOSOM(True)
#
# File C:\JupyterDoc\SOM\CDSOM.py:1410, in CDSOM.get_SOG_Embedding(self, fuzzy_set_no_probability)
#    1403 """
#    1404 do discrete optimized SOM
#    1405
#    1406 """
#    1408 self.getAllfeatureGroups()  #group each column by feature value get    self.all_feature_groups
# -> 1410 self.som.fit(self.data_train_all)
#    1411 weight_original = self.som.weights0
#    1412 self.train_W0_predicted_label = self.som.predict(self.data_train_all,weight_original)
#
# File C:\JupyterDoc\SOM\newSom.py:364, in SOM.fit(self, X, weightIndex, epochs, shuffle, showlog)
#     359 input = X[idx]
#     361 #if (type(input) is np.float64):
#     362 #    input = [input]
#     363 # Do one step of training
# --> 364 self.step(input,showlog)
#     365 # Update learning rate
#     366 global_iter_counter += 1
#
# File C:\JupyterDoc\SOM\newSom.py:177, in SOM.step(self, x, showlog)
#     168 x_stack = np.stack([x]*(self.m*self.n), axis=0)
#     169 #print("x_stack {}".format(x_stack))
#     170 #print("self.weights{}".format(self.weights));
#     171 #print("x_stack{}".format(x_stack));
#    (...)
#     175 #if showlog == True:
#     176 #    print("x {} {}".format(x, self.weights.shape) )
# --> 177 bmu_index = self._find_bmu(x,self.weights,showlog)
#     179 #print("bmu_index{}".format(bmu_index));
#     180 # Find location of best matching unit, _locations is all the indices for a given matrix for array
#     181 # bmu_location is the bmu_indexth element in _locations, such as if bmu_index = 4 in [[0,0],[0,1],[1,0],[1,1],[2,0],[2,1]] it return [2,0]
#     182 bmu_location = self._locations[bmu_index,:]
#
# File C:\JupyterDoc\SOM\newSom.py:129, in SOM._find_bmu(self, x, newWeights, showlog)
#     127 distance = np.linalg.norm((x_stack - newWeights).astype(float), axis=1)
#     128 # Find index of best matching unit
# --> 129 return np.argmin(distance)
#
# File <__array_function__ internals>:5, in argmin(*args, **kwargs)
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:1276, in argmin(a, axis, out)
#    1202 @array_function_dispatch(_argmin_dispatcher)
#    1203 def argmin(a, axis=None, out=None):
#    1204     """
#    1205     Returns the indices of the minimum values along an axis.
#    1206
#    (...)
#    1274
#    1275     """
# -> 1276     return _wrapfunc(a, 'argmin', axis=axis, out=out)
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
#new  sum encoding hybrid
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 13
# all_train_score_W0_p 0.6494794248884482
# all_train_score_W0_n 0.0005555035869912301
# all_train_score_W0_a 0.0002853629900585744
# test_score_W0_p0.6379901027788352
# test_score_W0_n 0.011086191487726951
# test_score_W0_a  0.009582927480376457
# all_train_score_W_combine_p 0.6499752107089737
# all_train_score_W_combine_n 0.002925392539555737
# all_train_score_W_combine_a 0.00515741919947975
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.007527247976164777
# test_score_W_combine_a 0.006840545327544396
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 16
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.003388587179459661
# all_train_score_W0_a 0.006658888966695111
# test_score_W0_p0.6387514274838219
# test_score_W0_n 0.023161625397454852
# test_score_W0_a  0.028391089761498393
# all_train_score_W_combine_p 0.6504709965294992
# all_train_score_W_combine_n 0.0072897585396789035
# all_train_score_W_combine_a 0.010070870204112969
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.006392780497175462
# test_score_W_combine_a 0.011032758184753199
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 19
# all_train_score_W0_p 0.6499752107089737
# all_train_score_W0_n 0.005226952304387529
# all_train_score_W0_a 0.0035757361714543047
# test_score_W0_p0.6391320898363152
# test_score_W0_n 0.015049425749464353
# test_score_W0_a  0.025707592018203662
# all_train_score_W_combine_p 0.6504709965294992
# all_train_score_W_combine_n 0.004119804708567976
# all_train_score_W_combine_a 0.0025809533568932654
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.006924711491394791
# test_score_W_combine_a 0.009830001130403594
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 22
# all_train_score_W0_p 0.6494794248884482
# all_train_score_W0_n 0.0012760020557244741
# all_train_score_W0_a 0.0004361660104913857
# test_score_W0_p0.6391320898363152
# test_score_W0_n 0.02050757870729038
# test_score_W0_a  0.03660794336132052
# all_train_score_W_combine_p 0.649727317798711
# all_train_score_W_combine_n 0.0009529473082285373
# all_train_score_W_combine_a 0.0006409320654133861
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.010372589754985386
# test_score_W_combine_a 0.0068413071621542376
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 25
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.0033303536994351555
# all_train_score_W0_a 0.002350217594805468
# test_score_W0_p0.6395127521888085
# test_score_W0_n 0.014016425109052521
# test_score_W0_a  0.025392504353509187
# all_train_score_W_combine_p 0.6504709965294992
# all_train_score_W_combine_n 0.0035764240768683567
# all_train_score_W_combine_a 0.003086747556310149
# test_score_W_combine_p 0.6372287780738485
# test_score_W_combine_n 0.006098320836525068
# test_score_W_combine_a 0.008892990001858832
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 28
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.0022200023731472544
# all_train_score_W0_a 0.002449336169564299
# test_score_W0_p0.6383707651313285
# test_score_W0_n 0.020508784008996025
# test_score_W0_a  0.03601126819195993
# all_train_score_W_combine_p 0.6502231036192365
# all_train_score_W_combine_n 0.0049592800123806555
# all_train_score_W_combine_a 0.003128233013746973
# test_score_W_combine_p 0.6379901027788352
# test_score_W_combine_n 0.014273918638322598
# test_score_W_combine_a 0.02366173062456171
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 31
# all_train_score_W0_p 0.6499752107089737
# all_train_score_W0_n 0.002693613562213823
# all_train_score_W0_a 0.0022834630236455477
# test_score_W0_p0.6417967263037686
# test_score_W0_n 0.02246144432450243
# test_score_W0_a  0.0423185603975067
# all_train_score_W_combine_p 0.6494794248884482
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p 0.6387514274838219
# test_score_W_combine_n 0.012092698360559798
# test_score_W_combine_a 0.010401510508225457
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 34
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.0031396762922343544
# all_train_score_W0_a 0.0050577330298927576
# test_score_W0_p0.6433193757137419
# test_score_W0_n 0.03528997998579866
# test_score_W0_a  0.05971325690334629
# all_train_score_W_combine_p 0.6494794248884482
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p 0.6379901027788352
# test_score_W_combine_n 0.011204975727950461
# test_score_W_combine_a 0.017576148738640825
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 37
# all_train_score_W0_p 0.6499752107089737
# all_train_score_W0_n 0.003553714002290014
# all_train_score_W0_a 0.004368983558085779
# test_score_W0_p0.6391320898363152
# test_score_W0_n 0.011630530880093283
# test_score_W0_a  0.017916197881692554
# all_train_score_W_combine_p 0.649727317798711
# all_train_score_W_combine_n 0.004772806046794402
# all_train_score_W_combine_a 0.004141124553506329
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.008886567292488661
# test_score_W_combine_a 0.01517826758557949
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 40
# all_train_score_W0_p 0.6494794248884482
# all_train_score_W0_n 0.0038089398393487245
# all_train_score_W0_a 0.00780935436699179
# test_score_W0_p0.6425580510087552
# test_score_W0_n 0.03940145740822984
# test_score_W0_a  0.06690719999390059
# all_train_score_W_combine_p 0.6499752107089737
# all_train_score_W_combine_n 0.006177752375218837
# all_train_score_W_combine_a 0.007674438927844588
# test_score_W_combine_p 0.6391320898363152
# test_score_W_combine_n 0.01412030238118911
# test_score_W_combine_a 0.01900336495598584
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 43
# all_train_score_W0_p 0.6494794248884482
# all_train_score_W0_n 0.0021183102540711725
# all_train_score_W0_a 0.001049546974975374
# test_score_W0_p0.6379901027788352
# test_score_W0_n 0.011601628316197847
# test_score_W0_a  0.017391206598072015
# all_train_score_W_combine_p 0.6514625681705504
# all_train_score_W_combine_n 0.010753914932306926
# all_train_score_W_combine_a 0.008219337509034074
# test_score_W_combine_p 0.6372287780738485
# test_score_W_combine_n 0.007041328693267459
# test_score_W_combine_a 0.014784266572219719
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 46
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.002403481334883316
# all_train_score_W0_a 0.001964675100066757
# test_score_W0_p0.6414160639512753
# test_score_W0_n 0.028844881612861875
# test_score_W0_a  0.04187707469754331
# all_train_score_W_combine_p 0.6499752107089737
# all_train_score_W_combine_n 0.0017855695822519245
# all_train_score_W_combine_a 0.0012223466277292091
# test_score_W_combine_p 0.6364674533688618
# test_score_W_combine_n 0.0021435793413293915
# test_score_W_combine_a 0.0006325792973584242
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 49
# all_train_score_W0_p 0.6502231036192365
# all_train_score_W0_n 0.002502575519451551
# all_train_score_W0_a 0.0017463169142514616
# test_score_W0_p0.6410354015987819
# test_score_W0_n 0.021769586605338332
# test_score_W0_a  0.03143437186358865
# all_train_score_W_combine_p 0.6499752107089737
# all_train_score_W_combine_n 0.002117938099553087
# all_train_score_W_combine_a 0.0015076374394369467
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.005510843047575896
# test_score_W_combine_a 0.003927244297531901
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 52
# all_train_score_W0_p 0.6509667823500248
# all_train_score_W0_n 0.012931227877046115
# all_train_score_W0_a 0.022007207884345577
# test_score_W0_p0.6444613627712219
# test_score_W0_n 0.03343712382501601
# test_score_W0_a  0.04086342374258614
# all_train_score_W_combine_p 0.6499752107089737
# all_train_score_W_combine_n 0.0019036856100016386
# all_train_score_W_combine_a 0.0012824635579949237
# test_score_W_combine_p 0.6364674533688618
# test_score_W_combine_n 0.0012468461360443679
# test_score_W_combine_a 0.000521605253166759
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 55
# all_train_score_W0_p 0.6499752107089737
# all_train_score_W0_n 0.001747290048674146
# all_train_score_W0_a 0.001389963694428693
# test_score_W0_p0.6391320898363152
# test_score_W0_n 0.020965770978567402
# test_score_W0_a  0.04788936481772825
# all_train_score_W_combine_p 0.649727317798711
# all_train_score_W_combine_n 0.001891100167530013
# all_train_score_W_combine_a 0.001417511038979531
# test_score_W_combine_p 0.6376094404263418
# test_score_W_combine_n 0.0039036183958236475
# test_score_W_combine_a 0.007491850457793108
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 58
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.006223314769501902
# all_train_score_W0_a 0.006880144322617874
# test_score_W0_p0.6398934145413019
# test_score_W0_n 0.023782488694463012
# test_score_W0_a  0.04382114733002421
# all_train_score_W_combine_p 0.6494794248884482
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p 0.6364674533688618
# test_score_W_combine_n 0.0
# test_score_W_combine_a 0.0
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 61
# all_train_score_W0_p 0.6502231036192365
# all_train_score_W0_n 0.005668862629198824
# all_train_score_W0_a 0.004840861559928272
# test_score_W0_p0.6387514274838219
# test_score_W0_n 0.023723052742978003
# test_score_W0_a  0.04491195075336635
# all_train_score_W_combine_p 0.6499752107089737
# all_train_score_W_combine_n 0.004223986247259094
# all_train_score_W_combine_a 0.0072966394625002045
# test_score_W_combine_p 0.6372287780738485
# test_score_W_combine_n 0.007046932565345352
# test_score_W_combine_a 0.009437280185790512
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 64
# all_train_score_W0_p 0.6504709965294992
# all_train_score_W0_n 0.006401708358119477
# all_train_score_W0_a 0.012164782286019976
# test_score_W0_p0.6425580510087552
# test_score_W0_n 0.023317212033351745
# test_score_W0_a  0.03876371864164397
# all_train_score_W_combine_p 0.6512146752602875
# all_train_score_W_combine_n 0.008542140044721775
# all_train_score_W_combine_a 0.01098028101219277
# test_score_W_combine_p 0.6379901027788352
# test_score_W_combine_n 0.006751284618870218
# test_score_W_combine_a 0.010028908748496256
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 67
# all_train_score_W0_p 0.650718889439762
# all_train_score_W0_n 0.0051845190418822
# all_train_score_W0_a 0.006617353491060796
# test_score_W0_p0.642177388656262
# test_score_W0_n 0.027090612693072714
# test_score_W0_a  0.052166469053604406
# all_train_score_W_combine_p 0.650718889439762
# all_train_score_W_combine_n 0.008610329817253612
# all_train_score_W_combine_a 0.008453017470871994
# test_score_W_combine_p 0.6372287780738485
# test_score_W_combine_n 0.002905592575401262
# test_score_W_combine_a 0.0019926251117465574
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 70
# all_train_score_W0_p 0.6502231036192365
# all_train_score_W0_n 0.004923077568996592
# all_train_score_W0_a 0.004567114814853316
# test_score_W0_p0.6410354015987819
# test_score_W0_n 0.02319264491557996
# test_score_W0_a  0.03493895244264154
# all_train_score_W_combine_p 0.649727317798711
# all_train_score_W_combine_n 0.0060685328948859515
# all_train_score_W_combine_a 0.008539188528802288
# test_score_W_combine_p 0.6364674533688618
# test_score_W_combine_n 0.004286461218634753
# test_score_W_combine_a 0.004900302519891381
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 73
# all_train_score_W0_p 0.649727317798711
# all_train_score_W0_n 0.007796931736959391
# all_train_score_W0_a 0.012527872589069082
# test_score_W0_p0.6444613627712219
# test_score_W0_n 0.03666870390478439
# test_score_W0_a  0.06785938234720229
# all_train_score_W_combine_p 0.6494794248884482
# all_train_score_W_combine_n 0.0
# all_train_score_W_combine_a 0.0
# test_score_W_combine_p 0.6368481157213551
# test_score_W_combine_n 0.001203008377891334
# test_score_W_combine_a 0.0008009622694598731
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 76
# all_train_score_W0_p 0.6494794248884482
# all_train_score_W0_n 0.002066608918933728
# all_train_score_W0_a 0.0026383947951808266
# test_score_W0_p0.6372287780738485
# test_score_W0_n 0.012327354497215108
# test_score_W0_a  0.030374248334742508
# all_train_score_W_combine_p 0.649727317798711
# all_train_score_W_combine_n 0.0008361739181216777
# all_train_score_W_combine_a 0.0005815161618859096
# test_score_W_combine_p 0.6368481157213551
# test_score_W_combine_n 0.0048736387077810035
# test_score_W_combine_a 0.006056546910259702
# Not good nmi result for discrete features !!!!!
# Not good ari result for discrete features  !!!!!
# Not good purity result for discrete features  !!!!!
# neuron unit number: 79
# all_train_score_W0_p 0.6499752107089737
# all_train_score_W0_n 0.002777683825254428
# all_train_score_W0_a 0.004810305085757468
# test_score_W0_p0.6383707651313285
# test_score_W0_n 0.013032277157284592
# test_score_W0_a  0.008029917553220274
# all_train_score_W_combine_p 0.6514625681705504
# all_train_score_W_combine_n 0.006984693397943149
# all_train_score_W_combine_a 0.006585048278069239
# test_score_W_combine_p 0.6383707651313285
# test_score_W_combine_n 0.008952116148961327
# test_score_W_combine_a 0.013289961290397698
# Not good nmi result for discrete features !!!!!
# test_score_W0_p mean 0.6403568295791199
# test_score_W_combine_p mean 0.6374770361298224
# test_score_W0_n mean 0.02229855569718784
# test_score_W_combine_n mean 0.006685189686247049
# test_score_W0_a mean 0.036907381239968624
# test_score_W_combine_a mean 0.00883142422320954
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  23.0  0.003997  0.002663  0.000555   0.002846  0.005149
# 1  train_W_combine  23.0  0.003847  0.003157  0.000658   0.002482  0.005213
# 2         combined  46.0  0.003922  0.002889  0.000426   0.003065  0.004780
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =    0.0001
# 1                       Degrees of freedom =   44.0000
# 2                                        t =    0.1740
# 3                    Two side test p value =    0.8627
# 4                   Difference < 0 p value =    0.5687
# 5                   Difference > 0 p value =    0.4313
# 6                                Cohen's d =    0.0513
# 7                                Hedge's g =    0.0504
# 8                           Glass's delta1 =    0.0563
# 9                         Point-Biserial r =    0.0262
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  23.0  0.022299  0.008349  0.001741   0.018688  0.025909
# 1  test_W_combine  23.0  0.006685  0.003960  0.000826   0.004973  0.008398
# 2        combined  46.0  0.014492  0.010200  0.001504   0.011463  0.017521
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =    0.0156
# 1                     Degrees of freedom =   44.0000
# 2                                      t =    8.1038
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    1.0000
# 5                 Difference > 0 p value =    0.0000
# 6                              Cohen's d =    2.3897
# 7                              Hedge's g =    2.3487
# 8                         Glass's delta1 =    1.8702
# 9                       Point-Biserial r =    0.7738
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  23.0  0.005151  0.004928  0.001027   0.003020  0.007282
# 1  train_W_combine  23.0  0.004025  0.003660  0.000763   0.002442  0.005607
# 2         combined  46.0  0.004588  0.004330  0.000638   0.003302  0.005874
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =    0.0011
# 1                       Degrees of freedom =   44.0000
# 2                                        t =    0.8803
# 3                    Two side test p value =    0.3835
# 4                   Difference < 0 p value =    0.8083
# 5                   Difference > 0 p value =    0.1917
# 6                                Cohen's d =    0.2596
# 7                                Hedge's g =    0.2551
# 8                           Glass's delta1 =    0.2287
# 9                         Point-Biserial r =    0.1316
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  23.0  0.036907  0.016021  0.003341   0.029980  0.043835
# 1  test_W_combine  23.0  0.008831  0.006353  0.001325   0.006084  0.011579
# 2        combined  46.0  0.022869  0.018619  0.002745   0.017340  0.028398
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =    0.0281
# 1                     Degrees of freedom =   44.0000
# 2                                      t =    7.8127
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    1.0000
# 5                 Difference > 0 p value =    0.0000
# 6                              Cohen's d =    2.3038
# 7                              Hedge's g =    2.2643
# 8                         Glass's delta1 =    1.7525
# 9                       Point-Biserial r =    0.7623
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  23.0  0.649921  0.000402  0.000084   0.649747  0.650095
# 1  train_W_combine  23.0  0.650126  0.000606  0.000126   0.649864  0.650388
# 2         combined  46.0  0.650024  0.000519  0.000077   0.649870  0.650178
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0002
# 1                       Degrees of freedom =   44.0000
# 2                                        t =   -1.3503
# 3                    Two side test p value =    0.1838
# 4                   Difference < 0 p value =    0.0919
# 5                   Difference > 0 p value =    0.9081
# 6                                Cohen's d =   -0.3982
# 7                                Hedge's g =   -0.3913
# 8                           Glass's delta1 =   -0.5092
# 9                         Point-Biserial r =   -0.1995
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  23.0  0.640357  0.002138  0.000446   0.639432  0.641281
# 1  test_W_combine  23.0  0.637477  0.000713  0.000149   0.637169  0.637785
# 2        combined  46.0  0.638917  0.002145  0.000316   0.638280  0.639554
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =    0.0029
# 1                     Degrees of freedom =   44.0000
# 2                                      t =    6.1282
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    1.0000
# 5                 Difference > 0 p value =    0.0000
# 6                              Cohen's d =    1.8071
# 7                              Hedge's g =    1.7761
# 8                         Glass's delta1 =    1.3470
# 9                       Point-Biserial r =    0.6786

# %%
#new  one hot encoding
import experiment
unstable_repeat_num= 30
scope_num = 40
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.650718889439762
# train_discrete_score_W_discrete_n 0.00799336216720857
# train_discrete_score_W_discrete_a 0.013218649662858456
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.02354599109217061
# test_discrete_score_W_discrete_a 0.04639971634170819
# neuron unit number: 16
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6527020327218641
# train_discrete_score_W_discrete_n 0.016516497414662313
# train_discrete_score_W_discrete_a 0.02510055684264474
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.02122339092650749
# test_discrete_score_W_discrete_a 0.028034099032849782
# neuron unit number: 19
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6524541398116014
# train_discrete_score_W_discrete_n 0.017567582946811117
# train_discrete_score_W_discrete_a 0.042055508782862176
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.0318100135313587
# test_discrete_score_W_discrete_a 0.07583777757189542
# neuron unit number: 22
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6536936043629152
# train_discrete_score_W_discrete_n 0.02147880653288473
# train_discrete_score_W_discrete_a 0.038019566402730395
# test_discrete_score_W_discrete_p 0.6433193757137419
# test_discrete_score_W_discrete_n 0.03545784000436369
# test_discrete_score_W_discrete_a 0.07203444358783438
# neuron unit number: 25
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6504709965294992
# train_discrete_score_W_discrete_n 0.01107268510849463
# train_discrete_score_W_discrete_a 0.01671661616053407
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.020784934858639692
# test_discrete_score_W_discrete_a 0.03155146175294875
# neuron unit number: 28
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6504709965294992
# train_discrete_score_W_discrete_n 0.007657980034663885
# train_discrete_score_W_discrete_a 0.009437936153534684
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.02398966514538326
# test_discrete_score_W_discrete_a 0.03161524034322123
# neuron unit number: 31
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6527020327218641
# train_discrete_score_W_discrete_n 0.01666100958040172
# train_discrete_score_W_discrete_a 0.02790892688907936
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.022713382709632142
# test_discrete_score_W_discrete_a 0.04013717981388054
# neuron unit number: 34
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6504709965294992
# train_discrete_score_W_discrete_n 0.009767721829823302
# train_discrete_score_W_discrete_a 0.01907560858696193
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.028264870828579352
# test_discrete_score_W_discrete_a 0.059527652684918685
# neuron unit number: 37
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6502231036192365
# train_discrete_score_W_discrete_n 0.009393950292110877
# train_discrete_score_W_discrete_a 0.013517705482796322
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.020129613500430205
# test_discrete_score_W_discrete_a 0.030982872619057075
# neuron unit number: 40
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.004953357629227634
# test_discrete_score_W0_a 0.01121756998676439
# train_discrete_score_W_discrete_p 0.6502231036192365
# train_discrete_score_W_discrete_n 0.009791037115453517
# train_discrete_score_W_discrete_a 0.01750505814872042
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.021782537442209073
# test_discrete_score_W_discrete_a 0.042390565012144305
# neuron unit number: 43
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6512146752602875
# train_discrete_score_W_discrete_n 0.013622248004707863
# train_discrete_score_W_discrete_a 0.012881419494792852
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.023143589602486758
# test_discrete_score_W_discrete_a 0.04430806968747459
# neuron unit number: 46
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6494794248884482
# train_discrete_score_W_discrete_n 0.00278132153691312
# train_discrete_score_W_discrete_a 0.0033012922798114006
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.027939659656943727
# test_discrete_score_W_discrete_a 0.061135983732054276
# neuron unit number: 49
# train_discrete_score_W0_p 0.649727317798711
# train_discrete_score_W0_n 0.003052701842770124
# train_discrete_score_W0_a  0.0020939418953783207
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.0023952718348846298
# test_discrete_score_W0_a 0.001978787796057316
# train_discrete_score_W_discrete_p 0.649727317798711
# train_discrete_score_W_discrete_n 0.012718853726306677
# train_discrete_score_W_discrete_a 0.021518505324897
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.02902464459296064
# test_discrete_score_W_discrete_a 0.05930188225778519
# neuron unit number: 52
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6502231036192365
# train_discrete_score_W_discrete_n 0.00931844832522796
# train_discrete_score_W_discrete_a 0.011398349235675053
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.021505518984436804
# test_discrete_score_W_discrete_a 0.03911637846879143
# neuron unit number: 55
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6509667823500248
# train_discrete_score_W_discrete_n 0.013509798616489403
# train_discrete_score_W_discrete_a 0.020024523370134016
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.03373055689436189
# test_discrete_score_W_discrete_a 0.07046421754214624
# neuron unit number: 58
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.004229199943162371
# test_discrete_score_W0_a 0.006104499906516449
# train_discrete_score_W_discrete_p 0.6531978185423897
# train_discrete_score_W_discrete_n 0.017821431100113055
# train_discrete_score_W_discrete_a 0.038924235420833654
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.016485348000266742
# test_discrete_score_W_discrete_a 0.03601224110259693
# neuron unit number: 61
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.003928652378640478
# test_discrete_score_W0_a 0.009019465022450686
# train_discrete_score_W_discrete_p 0.650718889439762
# train_discrete_score_W_discrete_n 0.010167856139175162
# train_discrete_score_W_discrete_a 0.013703845358984957
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.023384279376335654
# test_discrete_score_W_discrete_a 0.05205220187250532
# neuron unit number: 64
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.00043392626434970885
# train_discrete_score_W0_a  0.00022321540827512708
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.00240176981848811
# test_discrete_score_W0_a 0.0016033428988855142
# train_discrete_score_W_discrete_p 0.6509667823500248
# train_discrete_score_W_discrete_n 0.015950815860474282
# train_discrete_score_W_discrete_a 0.0283366046537222
# test_discrete_score_W_discrete_p 0.6459840121811953
# test_discrete_score_W_discrete_n 0.03191101235421643
# test_discrete_score_W_discrete_a 0.06924665837528257
# neuron unit number: 67
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.002997774517057731
# test_discrete_score_W0_a 0.003489801528186152
# train_discrete_score_W_discrete_p 0.6512146752602875
# train_discrete_score_W_discrete_n 0.013945391484595301
# train_discrete_score_W_discrete_a 0.02469544720422144
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.016181243983238235
# test_discrete_score_W_discrete_a 0.02214565722216878
# neuron unit number: 70
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.001068115603145314
# train_discrete_score_W0_a  0.0014441309843670645
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.002996837218466603
# test_discrete_score_W0_a 0.004220976518929651
# train_discrete_score_W_discrete_p 0.6527020327218641
# train_discrete_score_W_discrete_n 0.016687393374623258
# train_discrete_score_W_discrete_a 0.029398763441394846
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.02166467504423267
# test_discrete_score_W_discrete_a 0.042702241810689684
# neuron unit number: 73
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6514625681705504
# train_discrete_score_W_discrete_n 0.01193111125974533
# train_discrete_score_W_discrete_a 0.019691959090041525
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.027269137520756385
# test_discrete_score_W_discrete_a 0.045213816635153246
# neuron unit number: 76
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.005923973967820541
# test_discrete_score_W0_a 0.009719133698049115
# train_discrete_score_W_discrete_p 0.6514625681705504
# train_discrete_score_W_discrete_n 0.02055977825024134
# train_discrete_score_W_discrete_a 0.0440557784859652
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.031684347760736094
# test_discrete_score_W_discrete_a 0.0676632576645873
# neuron unit number: 79
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.650718889439762
# train_discrete_score_W_discrete_n 0.007899367927204217
# train_discrete_score_W_discrete_a 0.017505504952874996
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.01301140654121367
# test_discrete_score_W_discrete_a 0.019567796244000513
# test_discrete_score_W0_p mean 0.6365833071283163
# test_discrete_score_W_discrete_p mean 0.6413167607288857
# test_discrete_score_W0_n mean 0.001296819013380352
# test_discrete_score_W_discrete_n mean 0.02463642001528087
# test_discrete_score_W0_a mean 0.0020588511893843164
# test_discrete_score_W_discrete_a mean 0.04728006136416063
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000198  0.000666  0.000139  -0.000090  0.000486
# 1  train_dis_W_dis  23.0  0.012818  0.004604  0.000960   0.010827  0.014809
# 2         combined  46.0  0.006508  0.007161  0.001056   0.004381  0.008635
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0126
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -13.0109
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.8367
# 7                                    Hedge's g =   -3.7709
# 8                               Glass's delta1 =  -18.9607
# 9                             Point-Biserial r =   -0.8909
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.001297  0.001951  0.000407   0.000453  0.002141
# 1  test_dis_W_dis  23.0  0.024636  0.005877  0.001225   0.022095  0.027178
# 2        combined  46.0  0.012967  0.012568  0.001853   0.009234  0.016699
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0233
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -18.0758
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -5.3303
# 7                                  Hedge's g =   -5.2389
# 8                             Glass's delta1 =  -11.9627
# 9                           Point-Biserial r =   -0.9388
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000164  0.000518  0.000108  -0.000060  0.000388
# 1  train_dis_W_dis  23.0  0.022087  0.010841  0.002260   0.017399  0.026775
# 2         combined  46.0  0.011125  0.013432  0.001980   0.007136  0.015114
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0219
# 1                           Degrees of freedom =   44.0000
# 2                                            t =   -9.6875
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.8567
# 7                                    Hedge's g =   -2.8077
# 8                               Glass's delta1 =  -42.3165
# 9                             Point-Biserial r =   -0.8251
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.002059  0.003554  0.000741   0.000522  0.003596
# 1  test_dis_W_dis  23.0  0.047280  0.016794  0.003502   0.040018  0.054542
# 2        combined  46.0  0.024669  0.025820  0.003807   0.017002  0.032337
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0452
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -12.6338
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.7255
# 7                                  Hedge's g =   -3.6616
# 8                             Glass's delta1 =  -12.7236
# 9                           Point-Biserial r =   -0.8854
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.649264  0.000113  0.000024   0.649215  0.649313
# 1  train_dis_W_dis  23.0  0.651225  0.001149  0.000240   0.650728  0.651722
# 2         combined  46.0  0.650245  0.001279  0.000189   0.649865  0.650624
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0020
# 1                           Degrees of freedom =   44.0000
# 2                                            t =   -8.1452
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.4019
# 7                                    Hedge's g =   -2.3607
# 8                               Glass's delta1 =  -17.2888
# 9                             Point-Biserial r =   -0.7754
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636583  0.000242  0.000050   0.636479  0.636688
# 1  test_dis_W_dis  23.0  0.641317  0.001624  0.000339   0.640614  0.642019
# 2        combined  46.0  0.638950  0.002654  0.000391   0.638162  0.639738
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0047
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -13.8258
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -4.0770
# 7                                  Hedge's g =   -4.0071
# 8                             Glass's delta1 =  -19.5839
# 9                           Point-Biserial r =   -0.9016

# %%
#new sum encoding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.03438276833103381
# train_discrete_score_W_discrete_a 0.051592546508344606
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.02903441134242976
# test_discrete_score_W_discrete_a 0.047588893798006
# neuron unit number: 16
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.03490361129206053
# train_discrete_score_W_discrete_a 0.06735522537744684
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.033960177549881294
# test_discrete_score_W_discrete_a 0.06799378329008898
# neuron unit number: 19
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.03133680764031279
# train_discrete_score_W_discrete_a 0.05755683304833491
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.031727325565626366
# test_discrete_score_W_discrete_a 0.06481533417444627
# neuron unit number: 22
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.028831156003915833
# train_discrete_score_W_discrete_a 0.04966011746654931
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.03352673106648154
# test_discrete_score_W_discrete_a 0.06410438797469269
# neuron unit number: 25
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6536936043629152
# train_discrete_score_W_discrete_n 0.026005995774903746
# train_discrete_score_W_discrete_a 0.04545694930203832
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.02234125632243741
# test_discrete_score_W_discrete_a 0.047164029318957086
# neuron unit number: 28
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.031980569636595194
# train_discrete_score_W_discrete_a 0.05325260534032549
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.027507966878751986
# test_discrete_score_W_discrete_a 0.04636512188315085
# neuron unit number: 31
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6519583539910758
# train_discrete_score_W_discrete_n 0.017006832787743783
# train_discrete_score_W_discrete_a 0.027618903714790456
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.03236397492702762
# test_discrete_score_W_discrete_a 0.06794618578373526
# neuron unit number: 34
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6546851760039663
# train_discrete_score_W_discrete_n 0.030585451933755572
# train_discrete_score_W_discrete_a 0.06841071846442677
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.026589789531578836
# test_discrete_score_W_discrete_a 0.05647178231080126
# neuron unit number: 37
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6574119980168567
# train_discrete_score_W_discrete_n 0.033053930471165685
# train_discrete_score_W_discrete_a 0.06350143861033687
# test_discrete_score_W_discrete_p 0.6429387133612485
# test_discrete_score_W_discrete_n 0.03451246191387892
# test_discrete_score_W_discrete_a 0.07608162420441673
# neuron unit number: 40
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.652949925632127
# train_discrete_score_W_discrete_n 0.016884467195696515
# train_discrete_score_W_discrete_a 0.022410937213766708
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.019220305170769943
# test_discrete_score_W_discrete_a 0.027025127885326922
# neuron unit number: 43
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6527020327218641
# train_discrete_score_W_discrete_n 0.025943317127736173
# train_discrete_score_W_discrete_a 0.04450116543530499
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.012850241227512068
# test_discrete_score_W_discrete_a 0.01227218884063918
# neuron unit number: 46
# train_discrete_score_W0_p 0.649727317798711
# train_discrete_score_W0_n 0.0015385082476042403
# train_discrete_score_W0_a  0.002221313096141952
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6519583539910758
# train_discrete_score_W_discrete_n 0.014120234200766291
# train_discrete_score_W_discrete_a 0.028910658863620684
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.022256829824149085
# test_discrete_score_W_discrete_a 0.04664642257101573
# neuron unit number: 49
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6531978185423897
# train_discrete_score_W_discrete_n 0.020340959013208634
# train_discrete_score_W_discrete_a 0.03707001070452239
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.026883983546599533
# test_discrete_score_W_discrete_a 0.06692700293291155
# neuron unit number: 52
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.650718889439762
# train_discrete_score_W_discrete_n 0.018233686754243104
# train_discrete_score_W_discrete_a 0.04166061553855312
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.018558264632408752
# test_discrete_score_W_discrete_a 0.035862964741517
# neuron unit number: 55
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6519583539910758
# train_discrete_score_W_discrete_n 0.016681660531040456
# train_discrete_score_W_discrete_a 0.03366691005466512
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.020830259381771465
# test_discrete_score_W_discrete_a 0.03496785538245241
# neuron unit number: 58
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.033684043855619565
# train_discrete_score_W_discrete_a 0.06440792409525097
# test_discrete_score_W_discrete_p 0.6482679862961553
# test_discrete_score_W_discrete_n 0.04323027178440563
# test_discrete_score_W_discrete_a 0.09965703901558079
# neuron unit number: 61
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6544372830937035
# train_discrete_score_W_discrete_n 0.02722885420620236
# train_discrete_score_W_discrete_a 0.057355111397290305
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.021529226002066908
# test_discrete_score_W_discrete_a 0.030662280686315505
# neuron unit number: 64
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.004826846009011013
# test_discrete_score_W0_a 0.00887652733304448
# train_discrete_score_W_discrete_p 0.6522062469013387
# train_discrete_score_W_discrete_n 0.015888991160850074
# train_discrete_score_W_discrete_a 0.02950463720600646
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.018346434915657243
# test_discrete_score_W_discrete_a 0.031023082176365555
# neuron unit number: 67
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6564204263758057
# train_discrete_score_W_discrete_n 0.02761776845889416
# train_discrete_score_W_discrete_a 0.047259966274041304
# test_discrete_score_W_discrete_p 0.6471259992386753
# test_discrete_score_W_discrete_n 0.037973223838926956
# test_discrete_score_W_discrete_a 0.06968473182777195
# neuron unit number: 70
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6522062469013387
# train_discrete_score_W_discrete_n 0.01292040392697607
# train_discrete_score_W_discrete_a 0.017329648806076348
# test_discrete_score_W_discrete_p 0.6417967263037686
# test_discrete_score_W_discrete_n 0.020394451903793943
# test_discrete_score_W_discrete_a 0.029929861743562398
# neuron unit number: 73
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6531978185423897
# train_discrete_score_W_discrete_n 0.02290466015663722
# train_discrete_score_W_discrete_a 0.04677684171014054
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.034970230363022325
# test_discrete_score_W_discrete_a 0.06193238344679256
# neuron unit number: 76
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.002136782515920749
# test_discrete_score_W0_a 0.0045590531286126175
# train_discrete_score_W_discrete_p 0.6551809618244918
# train_discrete_score_W_discrete_n 0.032868356036134944
# train_discrete_score_W_discrete_a 0.07272383144896619
# test_discrete_score_W_discrete_p 0.6433193757137419
# test_discrete_score_W_discrete_n 0.03156031887912697
# test_discrete_score_W_discrete_a 0.05892853382405986
# neuron unit number: 79
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.652949925632127
# train_discrete_score_W_discrete_n 0.01687724283260175
# train_discrete_score_W_discrete_a 0.032000053647229604
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.01729858022797992
# test_discrete_score_W_discrete_a 0.025438060716303282
# test_discrete_score_W0_p mean 0.6364674533688619
# test_discrete_score_W_discrete_p mean 0.6420118832856125
# test_discrete_score_W0_n mean 0.0003027664576057288
# test_discrete_score_W_discrete_n mean 0.0268463789911428
# test_discrete_score_W0_a mean 0.0005841556722459608
# test_discrete_score_W_discrete_a mean 0.05084733384908304
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000067  0.000321  0.000067  -0.000072  0.000206
# 1  train_dis_W_dis  23.0  0.024795  0.007447  0.001553   0.021575  0.028015
# 2         combined  46.0  0.012431  0.013543  0.001997   0.008409  0.016453
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0247
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -15.9109
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.6919
# 7                                    Hedge's g =   -4.6114
# 8                               Glass's delta1 =  -77.0819
# 9                             Point-Biserial r =   -0.9230
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.000303  0.001082  0.000226  -0.000165  0.000771
# 1  test_dis_W_dis  23.0  0.026846  0.007768  0.001620   0.023487  0.030206
# 2        combined  46.0  0.013575  0.014496  0.002137   0.009270  0.017879
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0265
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -16.2303
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -4.7860
# 7                                  Hedge's g =   -4.7040
# 8                             Glass's delta1 =  -24.5320
# 9                           Point-Biserial r =   -0.9257
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000097  0.000463  0.000097  -0.000104  0.000297
# 1  train_dis_W_dis  23.0  0.046086  0.015680  0.003270   0.039306  0.052867
# 2         combined  46.0  0.023091  0.025706  0.003790   0.015458  0.030725
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0460
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -14.0600
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.1461
# 7                                    Hedge's g =   -4.0750
# 8                               Glass's delta1 =  -99.2920
# 9                             Point-Biserial r =   -0.9044
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.000584  0.002042  0.000426  -0.000299  0.001467
# 1  test_dis_W_dis  23.0  0.050847  0.020546  0.004284   0.041962  0.059732
# 2        combined  46.0  0.025716  0.029224  0.004309   0.017037  0.034394
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0503
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -11.6747
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.4427
# 7                                  Hedge's g =   -3.3837
# 8                             Glass's delta1 =  -24.6154
# 9                           Point-Biserial r =   -0.8695
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.649490  0.000052  0.000011   0.649468  0.649513
# 1  train_dis_W_dis  23.0  0.654394  0.002280  0.000475   0.653408  0.655380
# 2         combined  46.0  0.651942  0.002948  0.000435   0.651067  0.652818
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0049
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -10.3119
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.0408
# 7                                    Hedge's g =   -2.9887
# 8                               Glass's delta1 =  -94.8741
# 9                             Point-Biserial r =   -0.8410
#          Variable     N      Mean            SD            SE  95% Conf.  \
# 0     test_dis_W0  23.0  0.636467  1.135175e-16  2.367003e-17   0.636467
# 1  test_dis_W_dis  23.0  0.642012  2.340450e-03  4.880177e-04   0.641000
# 2        combined  46.0  0.639240  3.245604e-03  4.785383e-04   0.638276
#
#    Interval
# 0  0.636467
# 1  0.643024
# 2  0.640203
#                              Independent t-test       results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =  -5.500000e-03
# 1                         Degrees of freedom =   4.400000e+01
# 2                                          t =  -1.136110e+01
# 3                      Two side test p value =   0.000000e+00
# 4                     Difference < 0 p value =   0.000000e+00
# 5                     Difference > 0 p value =   1.000000e+00
# 6                                  Cohen's d =  -3.350200e+00
# 7                                  Hedge's g =  -3.292800e+00
# 8                             Glass's delta1 =  -4.884207e+13
# 9                           Point-Biserial r =  -8.636000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#new  sum encoding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)

# %%
#new binary encooding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6546851760039663
# train_discrete_score_W_discrete_n 0.020359834023455883
# train_discrete_score_W_discrete_a 0.03535096073075562
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.01537656467683043
# test_discrete_score_W_discrete_a 0.01719430075781127
# neuron unit number: 16
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.02744724988952966
# train_discrete_score_W_discrete_a 0.04486814216514231
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.01689007616658821
# test_discrete_score_W_discrete_a 0.02145439815916979
# neuron unit number: 19
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6586514625681705
# train_discrete_score_W_discrete_n 0.028750341604143036
# train_discrete_score_W_discrete_a 0.04231161863161349
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.025867562853238296
# test_discrete_score_W_discrete_a 0.037521302611163806
# neuron unit number: 22
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6556767476450174
# train_discrete_score_W_discrete_n 0.02585591135855148
# train_discrete_score_W_discrete_a 0.04580523316539327
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.03243450116547064
# test_discrete_score_W_discrete_a 0.05548173898045852
# neuron unit number: 25
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.003638762152290796
# test_discrete_score_W0_a 0.00813674037951045
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.029355101745679534
# train_discrete_score_W_discrete_a 0.055107719589977636
# test_discrete_score_W_discrete_p 0.6444613627712219
# test_discrete_score_W_discrete_n 0.02655621607497394
# test_discrete_score_W_discrete_a 0.03896804895437035
# neuron unit number: 28
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6574119980168567
# train_discrete_score_W_discrete_n 0.038975361673958965
# train_discrete_score_W_discrete_a 0.07986765527989982
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.013095698732915701
# test_discrete_score_W_discrete_a 0.016141070761180223
# neuron unit number: 31
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.028057242055828716
# train_discrete_score_W_discrete_a 0.05478123616277352
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.02283957754438815
# test_discrete_score_W_discrete_a 0.04771939624627772
# neuron unit number: 34
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0021826873446067047
# test_discrete_score_W0_a 0.0014341476180130333
# train_discrete_score_W_discrete_p 0.6522062469013387
# train_discrete_score_W_discrete_n 0.01902416607891135
# train_discrete_score_W_discrete_a 0.028075625042146272
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.015976173714803775
# test_discrete_score_W_discrete_a 0.02665831835736267
# neuron unit number: 37
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6531978185423897
# train_discrete_score_W_discrete_n 0.018464721585504506
# train_discrete_score_W_discrete_a 0.028763167127340165
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.020044022352248586
# test_discrete_score_W_discrete_a 0.015955302313090763
# neuron unit number: 40
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.026883065487093426
# train_discrete_score_W_discrete_a 0.04078882393934616
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.03279670227925234
# test_discrete_score_W_discrete_a 0.0669016636412912
# neuron unit number: 43
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6591472483886961
# train_discrete_score_W_discrete_n 0.03650370979189867
# train_discrete_score_W_discrete_a 0.0655053334807086
# test_discrete_score_W_discrete_p 0.6444613627712219
# test_discrete_score_W_discrete_n 0.03521984419992176
# test_discrete_score_W_discrete_a 0.06646020083543325
# neuron unit number: 46
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.004337267637324596
# test_discrete_score_W0_a 0.004779213718425604
# train_discrete_score_W_discrete_p 0.6517104610808131
# train_discrete_score_W_discrete_n 0.0206429203811899
# train_discrete_score_W_discrete_a 0.039124647198683866
# test_discrete_score_W_discrete_p 0.6398934145413019
# test_discrete_score_W_discrete_n 0.014977123857131685
# test_discrete_score_W_discrete_a 0.016892097311900243
# neuron unit number: 49
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.0023142544732480353
# test_discrete_score_W0_a 0.001132793752896535
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.028386397686571415
# train_discrete_score_W_discrete_a 0.050313106852449045
# test_discrete_score_W_discrete_p 0.6440807004187286
# test_discrete_score_W_discrete_n 0.03156835198673467
# test_discrete_score_W_discrete_a 0.06019838337430236
# neuron unit number: 52
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6383707651313285
# test_discrete_score_W0_n 0.008651743033557757
# test_discrete_score_W0_a 0.01035821948789422
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.02828392415614422
# train_discrete_score_W_discrete_a 0.042543285063018514
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.024410574136088114
# test_discrete_score_W_discrete_a 0.031891637876682366
# neuron unit number: 55
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.004395894172605202
# test_discrete_score_W0_a 0.0051283468970407305
# train_discrete_score_W_discrete_p 0.6546851760039663
# train_discrete_score_W_discrete_n 0.020437794495053056
# train_discrete_score_W_discrete_a 0.04135770492986113
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.029088472933790594
# test_discrete_score_W_discrete_a 0.05688171302462553
# neuron unit number: 58
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6536936043629152
# train_discrete_score_W_discrete_n 0.01865375514089075
# train_discrete_score_W_discrete_a 0.024596182538730867
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.028278294511490748
# test_discrete_score_W_discrete_a 0.05472673299810102
# neuron unit number: 61
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.022181605692204186
# train_discrete_score_W_discrete_a 0.03363428291163945
# test_discrete_score_W_discrete_p 0.6398934145413019
# test_discrete_score_W_discrete_n 0.015939654942925412
# test_discrete_score_W_discrete_a 0.022898318834454236
# neuron unit number: 64
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6383707651313285
# test_discrete_score_W0_n 0.014547547509160702
# test_discrete_score_W0_a 0.019951893073223256
# train_discrete_score_W_discrete_p 0.653941497273178
# train_discrete_score_W_discrete_n 0.02417404843852972
# train_discrete_score_W_discrete_a 0.050048688766474794
# test_discrete_score_W_discrete_p 0.6398934145413019
# test_discrete_score_W_discrete_n 0.018471147651053548
# test_discrete_score_W_discrete_a 0.03554230149638056
# neuron unit number: 67
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6509667823500248
# train_discrete_score_W_discrete_n 0.016393010954133615
# train_discrete_score_W_discrete_a 0.03803970380179162
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.02362661841711652
# test_discrete_score_W_discrete_a 0.0510688360327977
# neuron unit number: 70
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6402740768937952
# test_discrete_score_W0_n 0.014593906988663962
# test_discrete_score_W0_a 0.025385093274361722
# train_discrete_score_W_discrete_p 0.653941497273178
# train_discrete_score_W_discrete_n 0.018917900306009153
# train_discrete_score_W_discrete_a 0.02458704689535371
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.03158533173914054
# test_discrete_score_W_discrete_a 0.06326863590104842
# neuron unit number: 73
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.030018894120050224
# train_discrete_score_W_discrete_a 0.05401909957468187
# test_discrete_score_W_discrete_p 0.6440807004187286
# test_discrete_score_W_discrete_n 0.029543619292476883
# test_discrete_score_W_discrete_a 0.05330332593895048
# neuron unit number: 76
# train_discrete_score_W0_p 0.6494794248884482
# train_discrete_score_W0_n 0.004243485412768777
# train_discrete_score_W0_a  0.008427824433291634
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.007804533173718753
# test_discrete_score_W0_a 0.009162392340879656
# train_discrete_score_W_discrete_p 0.6494794248884482
# train_discrete_score_W_discrete_n 0.0035234299476272005
# train_discrete_score_W_discrete_a 0.0037525458081702936
# test_discrete_score_W_discrete_p 0.6398934145413019
# test_discrete_score_W_discrete_n 0.023744579560691523
# test_discrete_score_W_discrete_a 0.04732023431922257
# neuron unit number: 79
# train_discrete_score_W0_p 0.6492315319781854
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6376094404263418
# test_discrete_score_W0_n 0.004625337823242721
# test_discrete_score_W0_a 0.007128160370053225
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.032119872954142266
# train_discrete_score_W_discrete_a 0.06812356007376169
# test_discrete_score_W_discrete_p 0.6444613627712219
# test_discrete_score_W_discrete_n 0.030853176855983468
# test_discrete_score_W_discrete_a 0.05205576272863553
# test_discrete_score_W0_p mean 0.6369474189437448
# test_discrete_score_W_discrete_p mean 0.6413002101918207
# test_discrete_score_W0_n mean 0.002917040622105184
# test_discrete_score_W_discrete_n mean 0.024312342854141543
# test_discrete_score_W0_a mean 0.00402595656140428
# test_discrete_score_W_discrete_a mean 0.04158711832411785
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000184  0.000885  0.000184  -0.000198  0.000567
# 1  train_dis_W_dis  23.0  0.024496  0.007488  0.001561   0.021258  0.027734
# 2         combined  46.0  0.012340  0.013373  0.001972   0.008369  0.016312
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0243
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -15.4632
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.5598
# 7                                    Hedge's g =   -4.4817
# 8                               Glass's delta1 =  -27.4761
# 9                             Point-Biserial r =   -0.9190
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.002917  0.004510  0.000940   0.000967  0.004867
# 1  test_dis_W_dis  23.0  0.024312  0.006814  0.001421   0.021366  0.027259
# 2        combined  46.0  0.013615  0.012232  0.001804   0.009982  0.017247
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0214
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -12.5570
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.7029
# 7                                  Hedge's g =   -3.6394
# 8                             Glass's delta1 =   -4.7436
# 9                           Point-Biserial r =   -0.8842
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000366  0.001757  0.000366  -0.000393  0.001126
# 1  train_dis_W_dis  23.0  0.043103  0.016315  0.003402   0.036048  0.050158
# 2         combined  46.0  0.021735  0.024462  0.003607   0.014470  0.028999
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0427
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -12.4905
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.6833
# 7                                    Hedge's g =   -3.6201
# 8                               Glass's delta1 =  -24.3190
# 9                             Point-Biserial r =   -0.8832
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.004026  0.006844  0.001427   0.001066  0.006985
# 1  test_dis_W_dis  23.0  0.041587  0.017482  0.003645   0.034027  0.049147
# 2        combined  46.0  0.022807  0.023084  0.003404   0.015952  0.029662
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0376
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -9.5951
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.8295
# 7                                  Hedge's g =   -2.7809
# 8                             Glass's delta1 =   -5.4883
# 9                           Point-Biserial r =   -0.8226
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.649242  0.000052  0.000011   0.649220  0.649265
# 1  train_dis_W_dis  23.0  0.655235  0.002547  0.000531   0.654134  0.656336
# 2         combined  46.0  0.652239  0.003514  0.000518   0.651195  0.653282
#                                Independent t-test   results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =    -0.0060
# 1                           Degrees of freedom =    44.0000
# 2                                            t =   -11.2826
# 3                        Two side test p value =     0.0000
# 4                       Difference < 0 p value =     0.0000
# 5                       Difference > 0 p value =     1.0000
# 6                                    Cohen's d =    -3.3271
# 7                                    Hedge's g =    -3.2700
# 8                               Glass's delta1 =  -115.9340
# 9                             Point-Biserial r =    -0.8621
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636947  0.000934  0.000195   0.636544  0.637351
# 1  test_dis_W_dis  23.0  0.641300  0.002051  0.000428   0.640413  0.642187
# 2        combined  46.0  0.639124  0.002707  0.000399   0.638320  0.639928
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0044
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -9.2617
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.7311
# 7                                  Hedge's g =   -2.6843
# 8                             Glass's delta1 =   -4.6606
# 9                           Point-Biserial r =   -0.8130

# %%
#new hash encooding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.018118345380302353
# train_discrete_score_W_discrete_a 0.032702257554616546
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.024065989516946603
# test_discrete_score_W_discrete_a 0.04407495622173072
# neuron unit number: 16
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.014587109953095007
# train_discrete_score_W_discrete_a 0.02450801996001487
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.02671561415311956
# test_discrete_score_W_discrete_a 0.04846207662205448
# neuron unit number: 19
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.009519163965665533
# train_discrete_score_W_discrete_a 0.017161640274706676
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.01722376010539372
# test_discrete_score_W_discrete_a 0.029163360970508076
# neuron unit number: 22
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6556767476450174
# train_discrete_score_W_discrete_n 0.00790187857020525
# train_discrete_score_W_discrete_a 0.007326739921479332
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.009711561925087597
# test_discrete_score_W_discrete_a 0.011920884041029743
# neuron unit number: 25
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.010668255467803842
# train_discrete_score_W_discrete_a 0.02369201989467145
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.01737033142778563
# test_discrete_score_W_discrete_a 0.026644959392194117
# neuron unit number: 28
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.01715262373079095
# train_discrete_score_W_discrete_a 0.034278526111709805
# test_discrete_score_W_discrete_p 0.6376094404263418
# test_discrete_score_W_discrete_n 0.012313917714986656
# test_discrete_score_W_discrete_a 0.015684601921636593
# neuron unit number: 31
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6561725334655429
# train_discrete_score_W_discrete_n 0.015720876448203767
# train_discrete_score_W_discrete_a 0.03570924825574337
# test_discrete_score_W_discrete_p 0.6429387133612485
# test_discrete_score_W_discrete_n 0.03154067002310195
# test_discrete_score_W_discrete_a 0.0751371123693475
# neuron unit number: 34
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6368481157213551
# test_discrete_score_W0_n 0.0017884605393427432
# test_discrete_score_W0_a 0.002258480229551569
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.009520970186715298
# train_discrete_score_W_discrete_a 0.016608145170239254
# test_discrete_score_W_discrete_p 0.6372287780738485
# test_discrete_score_W_discrete_n 0.007404022746073752
# test_discrete_score_W_discrete_a 0.007943047180879476
# neuron unit number: 37
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.013999834611619159
# train_discrete_score_W_discrete_a 0.032486228941123955
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.012876636195971496
# test_discrete_score_W_discrete_a 0.02186656951955516
# neuron unit number: 40
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.02446974732497045
# train_discrete_score_W_discrete_a 0.05597037694889884
# test_discrete_score_W_discrete_p 0.646745336886182
# test_discrete_score_W_discrete_n 0.03273424741004576
# test_discrete_score_W_discrete_a 0.05956524635114559
# neuron unit number: 43
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6584035696579078
# train_discrete_score_W_discrete_n 0.02142511438102251
# train_discrete_score_W_discrete_a 0.03822784244141862
# test_discrete_score_W_discrete_p 0.6406547392462886
# test_discrete_score_W_discrete_n 0.023923791368397066
# test_discrete_score_W_discrete_a 0.039605332085496166
# neuron unit number: 46
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.0025285114171116345
# train_discrete_score_W_discrete_a 0.0037176673018163944
# test_discrete_score_W_discrete_p 0.6376094404263418
# test_discrete_score_W_discrete_n 0.010473058543010285
# test_discrete_score_W_discrete_a 0.018652526664571352
# neuron unit number: 49
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.016111566047419354
# train_discrete_score_W_discrete_a 0.029318500323216708
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.012649763549532912
# test_discrete_score_W_discrete_a 0.015218816346312409
# neuron unit number: 52
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.019057625250223954
# train_discrete_score_W_discrete_a 0.042048151124128436
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.018121700502806256
# test_discrete_score_W_discrete_a 0.03207031937618304
# neuron unit number: 55
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6556767476450174
# train_discrete_score_W_discrete_n 0.005178151936004987
# train_discrete_score_W_discrete_a 0.005689324035383648
# test_discrete_score_W_discrete_p 0.6364674533688618
# test_discrete_score_W_discrete_n 0.004297006271320883
# test_discrete_score_W_discrete_a 0.0019742964182024093
# neuron unit number: 58
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.004504777435966009
# train_discrete_score_W_discrete_a 0.005783031077328304
# test_discrete_score_W_discrete_p 0.6387514274838219
# test_discrete_score_W_discrete_n 0.017188848471017853
# test_discrete_score_W_discrete_a 0.03441675189818609
# neuron unit number: 61
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6564204263758057
# train_discrete_score_W_discrete_n 0.011376098349416447
# train_discrete_score_W_discrete_a 0.02465665517757071
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.015856482220314702
# test_discrete_score_W_discrete_a 0.028086534061918144
# neuron unit number: 64
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.001882004465755632
# train_discrete_score_W0_a  0.0031103818494658364
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0029382837766998757
# test_discrete_score_W0_a 0.0034194131575489175
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.012785681447973605
# train_discrete_score_W_discrete_a 0.018800367405284065
# test_discrete_score_W_discrete_p 0.6440807004187286
# test_discrete_score_W_discrete_n 0.03219053836978676
# test_discrete_score_W_discrete_a 0.0672408561767136
# neuron unit number: 67
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.017839577048525172
# train_discrete_score_W_discrete_a 0.03792036306321542
# test_discrete_score_W_discrete_p 0.6398934145413019
# test_discrete_score_W_discrete_n 0.023048311857173657
# test_discrete_score_W_discrete_a 0.05152993116440853
# neuron unit number: 70
# train_discrete_score_W0_p 0.6551809618244918
# train_discrete_score_W0_n 0.0020416507545573397
# train_discrete_score_W0_a  0.00158606468653696
# test_discrete_score_W0_p 0.6376094404263418
# test_discrete_score_W0_n 0.005986386736924135
# test_discrete_score_W0_a 0.010056226762348396
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.016742226335196144
# train_discrete_score_W_discrete_a 0.023505480797211178
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.013161433538124314
# test_discrete_score_W_discrete_a 0.025347392455979074
# neuron unit number: 73
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6601388200297471
# train_discrete_score_W_discrete_n 0.026029580250179173
# train_discrete_score_W_discrete_a 0.04910101896288828
# test_discrete_score_W_discrete_p 0.6456033498287019
# test_discrete_score_W_discrete_n 0.03243408290284028
# test_discrete_score_W_discrete_a 0.06871096675608669
# neuron unit number: 76
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6376094404263418
# test_discrete_score_W0_n 0.006284754059210734
# test_discrete_score_W0_a 0.012421300680640658
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.009357305024049252
# train_discrete_score_W_discrete_a 0.014780569662483799
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.015382660628817246
# test_discrete_score_W_discrete_a 0.030966868208284055
# neuron unit number: 79
# train_discrete_score_W0_p 0.6546851760039663
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0008464406634374921
# test_discrete_score_W0_a 0.00039092553757657383
# train_discrete_score_W_discrete_p 0.6551809618244918
# train_discrete_score_W_discrete_n 0.007846587361319528
# train_discrete_score_W_discrete_a 0.01597055403216317
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.03420335524995573
# test_discrete_score_W_discrete_a 0.08293940051240892
# test_discrete_score_W0_p mean 0.6365833071283163
# test_discrete_score_W_discrete_p mean 0.6401582231343406
# test_discrete_score_W0_n mean 0.0007758402511136948
# test_discrete_score_W_discrete_n mean 0.01934294716050481
# test_discrete_score_W0_a mean 0.0012411454942463528
# test_discrete_score_W_discrete_a mean 0.03640099159629704
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000171  0.000566  0.000118  -0.000074  0.000415
# 1  train_dis_W_dis  23.0  0.013584  0.006193  0.001291   0.010906  0.016262
# 2         combined  46.0  0.006878  0.008055  0.001188   0.004485  0.009270
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0134
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -10.3445
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -3.0504
# 7                                    Hedge's g =   -2.9981
# 8                               Glass's delta1 =  -23.7110
# 9                             Point-Biserial r =   -0.8418
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.000776  0.001835  0.000383  -0.000017  0.001569
# 1  test_dis_W_dis  23.0  0.019343  0.008928  0.001862   0.015482  0.023204
# 2        combined  46.0  0.010059  0.011345  0.001673   0.006690  0.013429
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0186
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -9.7693
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.8808
# 7                                  Hedge's g =   -2.8314
# 8                             Glass's delta1 =  -10.1210
# 9                           Point-Biserial r =   -0.8273
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000204  0.000714  0.000149  -0.000105  0.000513
# 1  train_dis_W_dis  23.0  0.025651  0.014087  0.002937   0.019559  0.031742
# 2         combined  46.0  0.012927  0.016209  0.002390   0.008114  0.017741
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0254
# 1                           Degrees of freedom =   44.0000
# 2                                            t =   -8.6520
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.5513
# 7                                    Hedge's g =   -2.5076
# 8                               Glass's delta1 =  -35.6144
# 9                             Point-Biserial r =   -0.7936
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.001241  0.003282  0.000684  -0.000178  0.002660
# 1  test_dis_W_dis  23.0  0.036401  0.022392  0.004669   0.026718  0.046084
# 2        combined  46.0  0.018821  0.023797  0.003509   0.011754  0.025888
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0352
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -7.4508
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.1971
# 7                                  Hedge's g =   -2.1594
# 8                             Glass's delta1 =  -10.7139
# 9                           Point-Biserial r =   -0.7469
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.654707  0.000103  0.000022   0.654662  0.654751
# 1  train_dis_W_dis  23.0  0.656625  0.001179  0.000246   0.656116  0.657135
# 2         combined  46.0  0.655666  0.001275  0.000188   0.655287  0.656045
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0019
# 1                           Degrees of freedom =   44.0000
# 2                                            t =   -7.7766
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -2.2932
# 7                                    Hedge's g =   -2.2539
# 8                               Glass's delta1 =  -18.5578
# 9                             Point-Biserial r =   -0.7608
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636583  0.000333  0.000070   0.636439  0.636727
# 1  test_dis_W_dis  23.0  0.640158  0.002552  0.000532   0.639055  0.641262
# 2        combined  46.0  0.638371  0.002550  0.000376   0.637613  0.639128
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0036
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -6.6613
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -1.9643
# 7                                  Hedge's g =   -1.9306
# 8                             Glass's delta1 =  -10.7247
# 9                           Point-Biserial r =   -0.7086

# %%
#new  baseN encoding
import experiment
unstable_repeat_num= 30
scope_num = 80
class_num = 13
dim_num = 7
best_num = 48
interval = 3


experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 13
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.021221683239697055
# train_discrete_score_W_discrete_a 0.03905586340910106
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.016817077966245084
# test_discrete_score_W_discrete_a 0.021818659382341524
# neuron unit number: 16
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6574119980168567
# train_discrete_score_W_discrete_n 0.021216360919021394
# train_discrete_score_W_discrete_a 0.03733547759720087
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.0273460907877813
# test_discrete_score_W_discrete_a 0.044005521998694376
# neuron unit number: 19
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6593951412989588
# train_discrete_score_W_discrete_n 0.02358636395747185
# train_discrete_score_W_discrete_a 0.04163270252893237
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.024656243990377236
# test_discrete_score_W_discrete_a 0.0522238740818072
# neuron unit number: 22
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.658155676747645
# train_discrete_score_W_discrete_n 0.014384424106097533
# train_discrete_score_W_discrete_a 0.023022335885052148
# test_discrete_score_W_discrete_p 0.6437000380662352
# test_discrete_score_W_discrete_n 0.0353044048564198
# test_discrete_score_W_discrete_a 0.0780168515519242
# neuron unit number: 25
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6586514625681705
# train_discrete_score_W_discrete_n 0.021263654714685807
# train_discrete_score_W_discrete_a 0.040827366283386284
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.026477762131381893
# test_discrete_score_W_discrete_a 0.045780996314031396
# neuron unit number: 28
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.013121453890830451
# train_discrete_score_W_discrete_a 0.01647888939495764
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.025158370939487914
# test_discrete_score_W_discrete_a 0.04368504065927013
# neuron unit number: 31
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.013306356318926274
# train_discrete_score_W_discrete_a 0.021661912265834856
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.027845932607313308
# test_discrete_score_W_discrete_a 0.051356674876185775
# neuron unit number: 34
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6596430342092217
# train_discrete_score_W_discrete_n 0.02024264858263857
# train_discrete_score_W_discrete_a 0.032478901967917036
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.028731614081560816
# test_discrete_score_W_discrete_a 0.06626131938572091
# neuron unit number: 37
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.013904486433166593
# train_discrete_score_W_discrete_a 0.02684414742094661
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.02194110366609597
# test_discrete_score_W_discrete_a 0.04021825005247288
# neuron unit number: 40
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6596430342092217
# train_discrete_score_W_discrete_n 0.021643531870837833
# train_discrete_score_W_discrete_a 0.04349459130985187
# test_discrete_score_W_discrete_p 0.6414160639512753
# test_discrete_score_W_discrete_n 0.023230245737026062
# test_discrete_score_W_discrete_a 0.042288155401517105
# neuron unit number: 43
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6549330689142291
# train_discrete_score_W_discrete_n 0.002990753075196906
# train_discrete_score_W_discrete_a 0.0038326442333023445
# test_discrete_score_W_discrete_p 0.6372287780738485
# test_discrete_score_W_discrete_n 0.008494288810362127
# test_discrete_score_W_discrete_a 0.01568632141561008
# neuron unit number: 46
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6391320898363152
# test_discrete_score_W0_n 0.01353327161891215
# test_discrete_score_W0_a 0.020719834572384264
# train_discrete_score_W_discrete_p 0.6584035696579078
# train_discrete_score_W_discrete_n 0.02193480768448553
# train_discrete_score_W_discrete_a 0.029581311520001232
# test_discrete_score_W_discrete_p 0.6425580510087552
# test_discrete_score_W_discrete_n 0.029307312364890654
# test_discrete_score_W_discrete_a 0.04813180735169105
# neuron unit number: 49
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.658155676747645
# train_discrete_score_W_discrete_n 0.018299035204639345
# train_discrete_score_W_discrete_a 0.037409014338180724
# test_discrete_score_W_discrete_p 0.642177388656262
# test_discrete_score_W_discrete_n 0.02095875811763834
# test_discrete_score_W_discrete_a 0.03399157318055523
# neuron unit number: 52
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6618740704015865
# train_discrete_score_W_discrete_n 0.026804713486238547
# train_discrete_score_W_discrete_a 0.041361446576825875
# test_discrete_score_W_discrete_p 0.6444613627712219
# test_discrete_score_W_discrete_n 0.0332678040801299
# test_discrete_score_W_discrete_a 0.05803630871161119
# neuron unit number: 55
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6576598909271195
# train_discrete_score_W_discrete_n 0.015659694489200477
# train_discrete_score_W_discrete_a 0.022107861505417322
# test_discrete_score_W_discrete_p 0.6379901027788352
# test_discrete_score_W_discrete_n 0.013932262292069812
# test_discrete_score_W_discrete_a 0.018984659442244
# neuron unit number: 58
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.010805551226669782
# train_discrete_score_W_discrete_a 0.02135367545970788
# test_discrete_score_W_discrete_p 0.6391320898363152
# test_discrete_score_W_discrete_n 0.01828490650678198
# test_discrete_score_W_discrete_a 0.031613527257143496
# neuron unit number: 61
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.657164105106594
# train_discrete_score_W_discrete_n 0.014599546708449028
# train_discrete_score_W_discrete_a 0.02293941263056107
# test_discrete_score_W_discrete_p 0.6379901027788352
# test_discrete_score_W_discrete_n 0.01189289675813938
# test_discrete_score_W_discrete_a 0.017138770730328854
# neuron unit number: 64
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.002302899174090629
# test_discrete_score_W0_a 0.0021232392838047578
# train_discrete_score_W_discrete_p 0.6566683192860684
# train_discrete_score_W_discrete_n 0.013392997580977438
# train_discrete_score_W_discrete_a 0.024026150639118768
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.018809017774333636
# test_discrete_score_W_discrete_a 0.03373817187440117
# neuron unit number: 67
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6593951412989588
# train_discrete_score_W_discrete_n 0.01985195593407357
# train_discrete_score_W_discrete_a 0.03157304293756439
# test_discrete_score_W_discrete_p 0.6410354015987819
# test_discrete_score_W_discrete_n 0.023127598937977542
# test_discrete_score_W_discrete_a 0.031960576735428424
# neuron unit number: 70
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6372287780738485
# test_discrete_score_W0_n 0.004155153649274146
# test_discrete_score_W0_a 0.004950799269075385
# train_discrete_score_W_discrete_p 0.6564204263758057
# train_discrete_score_W_discrete_n 0.01546025602235124
# train_discrete_score_W_discrete_a 0.029907543407741367
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.016139387121948304
# test_discrete_score_W_discrete_a 0.03202011353282983
# neuron unit number: 73
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6554288547347545
# train_discrete_score_W_discrete_n 0.013730896119480617
# train_discrete_score_W_discrete_a 0.029224223524455795
# test_discrete_score_W_discrete_p 0.6395127521888085
# test_discrete_score_W_discrete_n 0.014975803306513349
# test_discrete_score_W_discrete_a 0.03278907142718398
# neuron unit number: 76
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6398934145413019
# test_discrete_score_W0_n 0.021796749192488075
# test_discrete_score_W0_a 0.028661667131483527
# train_discrete_score_W_discrete_p 0.6569162121963312
# train_discrete_score_W_discrete_n 0.013381771102258737
# train_discrete_score_W_discrete_a 0.020170034233465736
# test_discrete_score_W_discrete_p 0.6433193757137419
# test_discrete_score_W_discrete_n 0.02673717997171002
# test_discrete_score_W_discrete_a 0.04139739091756187
# neuron unit number: 79
# train_discrete_score_W0_p 0.6549330689142291
# train_discrete_score_W0_n 0.0
# train_discrete_score_W0_a  0.0
# test_discrete_score_W0_p 0.6364674533688618
# test_discrete_score_W0_n 0.0
# test_discrete_score_W0_a 0.0
# train_discrete_score_W_discrete_p 0.6579077838373822
# train_discrete_score_W_discrete_n 0.020373017315071972
# train_discrete_score_W_discrete_a 0.03682864642572531
# test_discrete_score_W_discrete_p 0.6402740768937952
# test_discrete_score_W_discrete_n 0.030587712605552514
# test_discrete_score_W_discrete_a 0.06665826125896962
# test_discrete_score_W0_p mean 0.6367653630360305
# test_discrete_score_W_discrete_p mean 0.6408533456910677
# test_discrete_score_W0_n mean 0.001816872766728913
# test_discrete_score_W_discrete_n mean 0.022783642409205954
# test_discrete_score_W0_a mean 0.0024545887068151274
# test_discrete_score_W_discrete_a mean 0.041208778153892366
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.017008  0.005211  0.001087   0.014754  0.019261
# 2         combined  46.0  0.008504  0.009338  0.001377   0.005731  0.011277
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0170
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -15.6529
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.6158
# 7                                    Hedge's g =   -4.5367
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9207
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.001817  0.005244  0.001093  -0.000451  0.004084
# 1  test_dis_W_dis  23.0  0.022784  0.006983  0.001456   0.019764  0.025803
# 2        combined  46.0  0.012300  0.012232  0.001804   0.008668  0.015933
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0210
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -11.5152
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.3956
# 7                                  Hedge's g =   -3.3374
# 8                             Glass's delta1 =   -3.9986
# 9                           Point-Biserial r =   -0.8665
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     train_dis_W0  23.0  0.000000  0.000000  0.000000        NaN       NaN
# 1  train_dis_W_dis  23.0  0.029267  0.009800  0.002044   0.025029  0.033505
# 2         combined  46.0  0.014634  0.016305  0.002404   0.009792  0.019476
#                                Independent t-test  results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =   -0.0293
# 1                           Degrees of freedom =   44.0000
# 2                                            t =  -14.3219
# 3                        Two side test p value =    0.0000
# 4                       Difference < 0 p value =    0.0000
# 5                       Difference > 0 p value =    1.0000
# 6                                    Cohen's d =   -4.2233
# 7                                    Hedge's g =   -4.1509
# 8                               Glass's delta1 =      -inf
# 9                             Point-Biserial r =   -0.9074
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.002455  0.007202  0.001502  -0.000660  0.005569
# 1  test_dis_W_dis  23.0  0.041209  0.016186  0.003375   0.034209  0.048208
# 2        combined  46.0  0.021832  0.023179  0.003418   0.014948  0.028715
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0388
# 1                         Degrees of freedom =   44.0000
# 2                                          t =  -10.4907
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -3.0935
# 7                                  Hedge's g =   -3.0405
# 8                             Glass's delta1 =   -5.3807
# 9                           Point-Biserial r =   -0.8452
# Purity T-Test
#           Variable     N      Mean            SD            SE  95% Conf.  \
# 0     train_dis_W0  23.0  0.654933  1.135175e-16  2.367003e-17   0.654933
# 1  train_dis_W_dis  23.0  0.657832  1.565021e-03  3.263295e-04   0.657156
# 2         combined  46.0  0.656383  1.829090e-03  2.696846e-04   0.655840
#
#    Interval
# 0  0.654933
# 1  0.658509
# 2  0.656926
#                                Independent t-test       results
# 0  Difference (train_dis_W0 - train_dis_W_dis) =  -2.900000e-03
# 1                           Degrees of freedom =   4.400000e+01
# 2                                            t =  -8.884500e+00
# 3                        Two side test p value =   0.000000e+00
# 4                       Difference < 0 p value =   0.000000e+00
# 5                       Difference > 0 p value =   1.000000e+00
# 6                                    Cohen's d =  -2.619900e+00
# 7                                    Hedge's g =  -2.575000e+00
# 8                               Glass's delta1 =  -2.554029e+13
# 9                             Point-Biserial r =  -8.013000e-01
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0     test_dis_W0  23.0  0.636765  0.000889  0.000185   0.636381  0.637150
# 1  test_dis_W_dis  23.0  0.640853  0.001861  0.000388   0.640049  0.641658
# 2        combined  46.0  0.638809  0.002520  0.000372   0.638061  0.639558
#                              Independent t-test  results
# 0  Difference (test_dis_W0 - test_dis_W_dis) =   -0.0041
# 1                         Degrees of freedom =   44.0000
# 2                                          t =   -9.5070
# 3                      Two side test p value =    0.0000
# 4                     Difference < 0 p value =    0.0000
# 5                     Difference > 0 p value =    1.0000
# 6                                  Cohen's d =   -2.8035
# 7                                  Hedge's g =   -2.7554
# 8                             Glass's delta1 =   -4.5999
# 9                           Point-Biserial r =   -0.8201
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
