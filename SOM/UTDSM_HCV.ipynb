# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("hcvdat0.csv")
csv = csv.drop(columns=['ID'])
dataread.replaceNANinDataset(csv)
dataread.stringToIntHCVDataSet(csv,"Category")
dataread.stringToIntHCVDataSet(csv,"Sex")
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
dataread.initializedataset(csv_training,csv_test,"Category")

# %%
import experiment
unstable_repeat_num= 30
scope_num = 35
class_num = 5
row = 3
column  = 4
dim_num = 12
best_num = 20


som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)  
optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
optimize_W.run( )
# Out:
# True Distribution :
# neuron data  **************** 0
# ****************
# all_train_score_W0_n 0.6939942515426142
# all_train_score_W0_a 0.8325077217883516
# test_score_W0_n 0.4213738623063806
# test_score_W0_a  0.5924533915564323
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 13>()
#      11 som = newSom.SOM(m= class_num, n=  scope_num, dim=dim_num)
#      12 optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
# ---> 13 optimize_W.run( )
#
# File C:\JupyterDoc\SOM\UTDSM.py:698, in UTDSM_SOM.run(self)
#     691 # print("len self.all_split_datas 2 {}".format(len(self.all_split_datas)))
#     693  self.test_optimized_clusters()
# --> 698  self.test_combineW()
#
# File C:\JupyterDoc\SOM\UTDSM.py:803, in UTDSM_SOM.test_combineW(self)
#     802 def test_combineW(self):
# --> 803     self.train_W_combined_predicted_label = self.predict_based_splitdata(self.data_train,self.all_split_datas)
#     806     # predicted_clusters = [[2,4,14,23,21],[1,43,24,5]]
#     807    # print("current train data generated predicted_clusters len {}".format(len(predicted_clusters)))
#     808     # predicted_clusters  [[23,31,21,2],[1,3,5,76],[45,5,12]] index in data_train
#     809
#     810     #print("self.train_W_combined_predicted_label {}".format(self.train_W_combined_predicted_label))
#     811     #*** needs to use self.combinedweight.shape[0] cannot use self.som.m*self.som.n as neruons is changed
#     812     predicted_clusters,current_clustered_datas = self.get_indices_in_predicted_clusters(len(self.all_split_datas), self.train_W_combined_predicted_label)
#
# File C:\JupyterDoc\SOM\UTDSM.py:484, in UTDSM_SOM.predict_based_splitdata(self, X, Y)
#     482 labels =[]
#     483 for x in X:
# --> 484     b = self._find_belonged_neuron(x,Y)
#     485     labels.append(b)
#     487 # winWindexlabels, labels = np.array([ for x in X])
#     488 # labels will be always from 0 - (m*n)*stop_split_num-1
#
# File C:\JupyterDoc\SOM\UTDSM.py:431, in UTDSM_SOM._find_belonged_neuron(self, x, Y)
#     421         break
#     424 #*** self.rightdatas = [[[],[]],[data in rightdata2],[]]
#     425 #if len(Y[firstindex]) == 1 :
#     426 #    print("x {} Y[0] {}".format(x,Y[firstindex][0]))
#    (...)
#     429 #print("x {} Y[0] {}".format(x,Y[firstindex]))
#     430 #print("x {} Y[0][0] {}".format(x,Y[firstindex][0]))
# --> 431 distance = math.dist(x,Y[firstindex][0])
#     433 w_index = 0
#     434 for i in range(0,len(Y)):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import experiment
unstable_repeat_num= 30
scope_num = 35
class_num = 5
dim_num = 12
best_num = 20

total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)

experiment = experiment.Experiment()

experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1)
# Out:
# neuron unit number: 5
# all_train_score_W0_n 0.09051227519868267
# all_train_score_W0_a 0.0971336994621223
# test_score_W0_n 3.158997273328321e-15
# test_score_W0_a  0.0
# Split one time!
# self.rest_data_W0_p 0.8797169811320755
# self.rest_data_W0_n 0.07798075083591699
# self.rest_data_W0_a 0.08492051037340631
# all_train_score_W_Combined_n 0.2008649811524795
# all_train_score_W_Combined_a 0.2323497134800504
# test_score_W_combined_n 0.12144159250494654
# test_score_W_combined_a 0.14407340709894187
# Combine Neurons Number :10
# neuron unit number: 6
# all_train_score_W0_n 0.04871287347248528
# all_train_score_W0_a 0.050540409354000865
# test_score_W0_n 0.08748657248118376
# test_score_W0_a  0.07721834437633608
# Split one time!
# self.rest_data_W0_p 0.8708920187793427
# self.rest_data_W0_n 0.05383313122957373
# self.rest_data_W0_a 0.056183871212264584
# all_train_score_W_Combined_n 0.14525668648254877
# all_train_score_W_Combined_a 0.16670637135226485
# test_score_W_combined_n 0.17856877283847397
# test_score_W_combined_a 0.21071543072837587
# Combine Neurons Number :13
# neuron unit number: 7
# all_train_score_W0_n 0.41498453888820314
# all_train_score_W0_a 0.6072825496257889
# test_score_W0_n 0.3530539609483896
# test_score_W0_a  0.5345762269829856
# Split one time!
# self.rest_data_W0_p 0.9039812646370023
# self.rest_data_W0_n 0.41305312773531655
# self.rest_data_W0_a 0.6037576226792365
# all_train_score_W_Combined_n 0.4320585605030492
# all_train_score_W_Combined_a 0.6224885264304922
# test_score_W_combined_n 0.4887642775754097
# test_score_W_combined_a 0.6509385156722047
# Combine Neurons Number :11
# neuron unit number: 8
# all_train_score_W0_n 0.343064632170054
# all_train_score_W0_a 0.5411882309413851
# test_score_W0_n 0.22541134336899618
# test_score_W0_a  0.3698159104051398
# Split one time!
# self.rest_data_W0_p 0.8974358974358975
# self.rest_data_W0_n 0.33622796248418524
# self.rest_data_W0_a 0.5254781211853325
# all_train_score_W_Combined_n 0.35800946204370243
# all_train_score_W_Combined_a 0.5417508669787823
# test_score_W_combined_n 0.1618661105697101
# test_score_W_combined_a 0.3277526025558464
# Combine Neurons Number :18
# neuron unit number: 9
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_n 3.158997273328321e-15
# test_score_W0_a  0.0
# Split one time!
# self.rest_data_W0_p 0.8660049627791563
# self.rest_data_W0_n 0.0
# self.rest_data_W0_a 0.0
# Split one time!
# self.rest_data_W0_p 0.9230769230769231
# self.rest_data_W0_n 0.7367190485726262
# self.rest_data_W0_a 0.8363671572424477
# all_train_score_W_Combined_n 0.12260751666403032
# all_train_score_W_Combined_a 0.14400676577230023
# test_score_W_combined_n 0.1244352457594962
# test_score_W_combined_a 0.14777185533987236
# Combine Neurons Number :20
# neuron unit number: 10
# all_train_score_W0_n 0.41198333230327683
# all_train_score_W0_a 0.6220725079222311
# test_score_W0_n 0.34577648031715186
# test_score_W0_a  0.5895420051697384
# Split one time!
# self.rest_data_W0_p 0.9187192118226601
# self.rest_data_W0_n 0.46835801664245197
# self.rest_data_W0_a 0.6795926103865619
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5265581617067302
# all_train_score_W_Combined_a 0.7172942162607897
# test_score_W_combined_n 0.4639993399918991
# test_score_W_combined_a 0.6497118273013737
# Combine Neurons Number :38
# neuron unit number: 11
# all_train_score_W0_n 0.44773470974494184
# all_train_score_W0_a 0.657173201333666
# test_score_W0_n 0.24767938952450408
# test_score_W0_a  0.37668739847905713
# Split one time!
# self.rest_data_W0_p 0.909952606635071
# self.rest_data_W0_n 0.4663093795003262
# self.rest_data_W0_a 0.6607074125717507
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.48371683495981477
# all_train_score_W_Combined_a 0.6765112690748416
# test_score_W_combined_n 0.3214725906975742
# test_score_W_combined_a 0.4403812394794572
# Combine Neurons Number :18
# neuron unit number: 12
# all_train_score_W0_n 0.37940062985088546
# all_train_score_W0_a 0.4314650220982432
# test_score_W0_n 0.34632026496371504
# test_score_W0_a  0.42450526560082436
# Split one time!
# self.rest_data_W0_p 0.9042056074766355
# self.rest_data_W0_n 0.4056265942189789
# self.rest_data_W0_a 0.45353926018621493
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.4345643623943978
# all_train_score_W_Combined_a 0.4852111864242719
# test_score_W_combined_n 0.38854292886826497
# test_score_W_combined_a 0.44632192265181275
# Combine Neurons Number :37
# neuron unit number: 13
# all_train_score_W0_n 0.49626264795609426
# all_train_score_W0_a 0.7038433177912138
# test_score_W0_n 0.449619353306419
# test_score_W0_a  0.6452112982209977
# Split one time!
# self.rest_data_W0_p 0.9107981220657277
# self.rest_data_W0_n 0.49552252914367007
# self.rest_data_W0_a 0.7029864928775458
# all_train_score_W_Combined_n 0.49626264795609426
# all_train_score_W_Combined_a 0.7038433177912138
# test_score_W_combined_n 0.5301722827041622
# test_score_W_combined_a 0.7045688941547725
# Combine Neurons Number :15
# neuron unit number: 14
# all_train_score_W0_n 0.539492853406771
# all_train_score_W0_a 0.6348817851181683
# test_score_W0_n 0.5671811831835667
# test_score_W0_a  0.6721674805683258
# Split one time!
# self.rest_data_W0_p 0.9182692307692307
# self.rest_data_W0_n 0.5382857737511301
# self.rest_data_W0_a 0.6324632760710129
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.539492853406771
# all_train_score_W_Combined_a 0.6348817851181683
# test_score_W_combined_n 0.5846843471531341
# test_score_W_combined_a 0.6813032823940667
# Combine Neurons Number :55
# neuron unit number: 15
# all_train_score_W0_n 0.5302620976054709
# all_train_score_W0_a 0.6697071526082656
# test_score_W0_n 0.3968918995203331
# test_score_W0_a  0.5803066329826495
# Split one time!
# self.rest_data_W0_p 0.9272300469483568
# self.rest_data_W0_n 0.5209906028065755
# self.rest_data_W0_a 0.6570464640406981
# all_train_score_W_Combined_n 0.5472853228330093
# all_train_score_W_Combined_a 0.6846496406977013
# test_score_W_combined_n 0.4025507582147079
# test_score_W_combined_a 0.5658994392478461
# Combine Neurons Number :19
# neuron unit number: 16
# all_train_score_W0_n 0.5173354693471163
# all_train_score_W0_a 0.7677551890414213
# test_score_W0_n 0.35812310773277406
# test_score_W0_a  0.48371599066671517
# Split one time!
# self.rest_data_W0_p 0.9225352112676056
# self.rest_data_W0_n 0.5030308094514209
# self.rest_data_W0_a 0.7583988610406087
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5173354693471163
# all_train_score_W_Combined_a 0.7677551890414213
# test_score_W_combined_n 0.4823868317940264
# test_score_W_combined_a 0.6563663831285144
# Combine Neurons Number :64
# neuron unit number: 17
# all_train_score_W0_n 0.4394937308676057
# all_train_score_W0_a 0.619700992175544
# test_score_W0_n 0.4153647748083447
# test_score_W0_a  0.5972027625299092
# Split one time!
# self.rest_data_W0_p 0.91725768321513
# self.rest_data_W0_n 0.4341378072538938
# self.rest_data_W0_a 0.5971274747048213
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5042284550015678
# all_train_score_W_Combined_a 0.6505855616467919
# test_score_W_combined_n 0.3754643464378042
# test_score_W_combined_a 0.5027306500316443
# Combine Neurons Number :25
# neuron unit number: 18
# all_train_score_W0_n 0.5263120844629944
# all_train_score_W0_a 0.7100487308838848
# test_score_W0_n 0.3632201916874696
# test_score_W0_a  0.4695495560464277
# Split one time!
# self.rest_data_W0_p 0.9320843091334895
# self.rest_data_W0_n 0.5542342657272978
# self.rest_data_W0_a 0.7254087621102862
# all_train_score_W_Combined_n 0.5702370323437054
# all_train_score_W_Combined_a 0.7379880801090712
# test_score_W_combined_n 0.4980167212562636
# test_score_W_combined_a 0.6511046461623335
# Combine Neurons Number :76
# neuron unit number: 19
# all_train_score_W0_n 0.40184233012402065
# all_train_score_W0_a 0.5729959868650687
# test_score_W0_n 0.46033697152377906
# test_score_W0_a  0.6211736272533585
# Split one time!
# self.rest_data_W0_p 0.9144893111638955
# self.rest_data_W0_n 0.4167961290012657
# self.rest_data_W0_a 0.5086147483069172
# Split one time!
# self.rest_data_W0_p 0.8888888888888888
# self.rest_data_W0_n 0.7615756770411353
# self.rest_data_W0_a 0.6086956521739131
# all_train_score_W_Combined_n 0.4837363091762296
# all_train_score_W_Combined_a 0.595797804921301
# test_score_W_combined_n 0.3691387553063993
# test_score_W_combined_a 0.47421534274299293
# Combine Neurons Number :26
# neuron unit number: 20
# all_train_score_W0_n 0.6284048299573833
# all_train_score_W0_a 0.8166006452813538
# test_score_W0_n 0.4740179978483659
# test_score_W0_a  0.6083860717828082
# Split one time!
# self.rest_data_W0_p 0.9414519906323185
# self.rest_data_W0_n 0.6278858189649127
# self.rest_data_W0_a 0.8161172834500328
# all_train_score_W_Combined_n 0.6284048299573833
# all_train_score_W_Combined_a 0.8166006452813538
# test_score_W_combined_n 0.5044537435175985
# test_score_W_combined_a 0.6918187403255754
# Combine Neurons Number :93
# neuron unit number: 21
# all_train_score_W0_n 0.4490619342721316
# all_train_score_W0_a 0.607916683575785
# test_score_W0_n 0.3736632284588575
# test_score_W0_a  0.5005017911335279
# Split one time!
# self.rest_data_W0_p 0.9176470588235294
# self.rest_data_W0_n 0.46410597811199195
# self.rest_data_W0_a 0.6221880378618464
# all_train_score_W_Combined_n 0.5045037813574639
# all_train_score_W_Combined_a 0.6544255059386649
# test_score_W_combined_n 0.5031233377886221
# test_score_W_combined_a 0.6536447281499892
# Combine Neurons Number :27
# neuron unit number: 22
# all_train_score_W0_n 0.5968131600777606
# all_train_score_W0_a 0.75277792239636
# test_score_W0_n 0.3033665847157764
# test_score_W0_a  0.3793015309016132
# Split one time!
# self.rest_data_W0_p 0.9363207547169812
# self.rest_data_W0_n 0.5857058947185861
# self.rest_data_W0_a 0.7443339774388699
# all_train_score_W_Combined_n 0.5968131600777606
# all_train_score_W_Combined_a 0.75277792239636
# test_score_W_combined_n 0.4298297650152366
# test_score_W_combined_a 0.627284630877639
# Combine Neurons Number :110
# neuron unit number: 23
# all_train_score_W0_n 0.5477585008179316
# all_train_score_W0_a 0.7135787985889323
# test_score_W0_n 0.3773929275495453
# test_score_W0_a  0.5389617227733575
# Split one time!
# self.rest_data_W0_p 0.9239904988123515
# self.rest_data_W0_n 0.5442232174097689
# self.rest_data_W0_a 0.7185456235277909
# all_train_score_W_Combined_n 0.5638225321848843
# all_train_score_W_Combined_a 0.7398825029195297
# test_score_W_combined_n 0.4322590302058434
# test_score_W_combined_a 0.6097549414184777
# Combine Neurons Number :30
# neuron unit number: 24
# all_train_score_W0_n 0.5600375414693489
# all_train_score_W0_a 0.7430834534486672
# test_score_W0_n 0.3804684128350649
# test_score_W0_a  0.5880897670152185
# Split one time!
# self.rest_data_W0_p 0.9295774647887324
# self.rest_data_W0_n 0.5539611827412699
# self.rest_data_W0_a 0.7343222133375927
# all_train_score_W_Combined_n 0.5632866298212021
# all_train_score_W_Combined_a 0.7392404557016998
# test_score_W_combined_n 0.49267079921539997
# test_score_W_combined_a 0.652579345634765
# Combine Neurons Number :125
# neuron unit number: 25
# all_train_score_W0_n 0.5746684742943944
# all_train_score_W0_a 0.7810244157577414
# test_score_W0_n 0.42819974953194956
# test_score_W0_a  0.5846774198438383
# Split one time!
# self.rest_data_W0_p 0.9254079254079254
# self.rest_data_W0_n 0.5661416769371296
# self.rest_data_W0_a 0.7754681227793762
# all_train_score_W_Combined_n 0.5746684742943944
# all_train_score_W_Combined_a 0.7810244157577414
# test_score_W_combined_n 0.4304797884811361
# test_score_W_combined_a 0.6122520850252008
# Combine Neurons Number :25
# neuron unit number: 26
# all_train_score_W0_n 0.6894261746409771
# all_train_score_W0_a 0.8082886349395842
# test_score_W0_n 0.31963793961250125
# test_score_W0_a  0.47612146309883946
# Split one time!
# self.rest_data_W0_p 0.9484777517564403
# self.rest_data_W0_n 0.6890758854023614
# self.rest_data_W0_a 0.8078418377775672
# all_train_score_W_Combined_n 0.6894261746409771
# all_train_score_W_Combined_a 0.8082886349395842
# test_score_W_combined_n 0.535012241379446
# test_score_W_combined_a 0.6930225733711787
# Combine Neurons Number :133
# neuron unit number: 27
# all_train_score_W0_n 0.5254544673674291
# all_train_score_W0_a 0.6535498438401279
# test_score_W0_n 0.5131006131166019
# test_score_W0_a  0.7375364589179367
# Split one time!
# self.rest_data_W0_p 0.9227166276346604
# self.rest_data_W0_n 0.4960619896417184
# self.rest_data_W0_a 0.6290612280724273
# all_train_score_W_Combined_n 0.5254544673674291
# all_train_score_W_Combined_a 0.6535498438401279
# test_score_W_combined_n 0.41643483559326655
# test_score_W_combined_a 0.6087146208908669
# Combine Neurons Number :28
# neuron unit number: 28
# all_train_score_W0_n 0.6309460750569014
# all_train_score_W0_a 0.8071223734544697
# test_score_W0_n 0.33811480546540124
# test_score_W0_a  0.4389755911876144
# Split one time!
# self.rest_data_W0_p 0.9460093896713615
# self.rest_data_W0_n 0.6421021060522827
# self.rest_data_W0_a 0.8189247293410499
# all_train_score_W_Combined_n 0.6427214121510133
# all_train_score_W_Combined_a 0.8195265005133047
# test_score_W_combined_n 0.5318339009296875
# test_score_W_combined_a 0.7296705122597136
# Combine Neurons Number :142
# neuron unit number: 29
# all_train_score_W0_n 0.49052904249425905
# all_train_score_W0_a 0.6024471762979424
# test_score_W0_n 0.5149387674027407
# test_score_W0_a  0.592016027794889
# Split one time!
# self.rest_data_W0_p 0.919431279620853
# self.rest_data_W0_n 0.4947140530281364
# self.rest_data_W0_a 0.6095664601392186
# Split one time!
# self.rest_data_W0_p 0.75
# self.rest_data_W0_n 0.0
# self.rest_data_W0_a 0.0
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.49052904249425905
# all_train_score_W_Combined_a 0.6024471762979424
# test_score_W_combined_n 0.4682081481391823
# test_score_W_combined_a 0.6120571548287986
# Combine Neurons Number :33
# neuron unit number: 30
# all_train_score_W0_n 0.72461347845144
# all_train_score_W0_a 0.8496816131697458
# test_score_W0_n 0.35353441860728985
# test_score_W0_a  0.43440914486536
# Split one time!
# self.rest_data_W0_p 0.9576470588235294
# self.rest_data_W0_n 0.7240720525555198
# self.rest_data_W0_a 0.8490872054308424
# all_train_score_W_Combined_n 0.72461347845144
# all_train_score_W_Combined_a 0.8496816131697458
# test_score_W_combined_n 0.448455435242291
# test_score_W_combined_a 0.66650670317202
# Combine Neurons Number :178
# neuron unit number: 31
# all_train_score_W0_n 0.4486476947390759
# all_train_score_W0_a 0.6146598964521024
# test_score_W0_n 0.5739291717702504
# test_score_W0_a  0.7420592758661771
# Split one time!
# self.rest_data_W0_p 0.9267139479905437
# self.rest_data_W0_n 0.4919473165608077
# self.rest_data_W0_a 0.6599407701037106
# all_train_score_W_Combined_n 0.5235665830459624
# all_train_score_W_Combined_a 0.6877789425155059
# test_score_W_combined_n 0.46235995569090177
# test_score_W_combined_a 0.6521700620146962
# Combine Neurons Number :38
# neuron unit number: 32
# all_train_score_W0_n 0.7875878680210555
# all_train_score_W0_a 0.8933669599486315
# test_score_W0_n 0.37719798767558804
# test_score_W0_a  0.48524499431099505
# Split one time!
# self.rest_data_W0_p 0.9625292740046838
# self.rest_data_W0_n 0.7819620490825164
# self.rest_data_W0_a 0.8901642459771973
# all_train_score_W_Combined_n 0.7875878680210555
# all_train_score_W_Combined_a 0.8933669599486315
# test_score_W_combined_n 0.5231213644572595
# test_score_W_combined_a 0.6920778729499777
# Combine Neurons Number :172
# neuron unit number: 33
# all_train_score_W0_n 0.5433419888865529
# all_train_score_W0_a 0.6903080575193544
# test_score_W0_n 0.328116987788606
# test_score_W0_a  0.4641579278180692
# Split one time!
# self.rest_data_W0_p 0.9316037735849056
# self.rest_data_W0_n 0.5801710540177577
# self.rest_data_W0_a 0.704893338124588
# all_train_score_W_Combined_n 0.5854405433100095
# all_train_score_W_Combined_a 0.7183996440811506
# test_score_W_combined_n 0.5951322840232944
# test_score_W_combined_a 0.6959268797951659
# Combine Neurons Number :36
# neuron unit number: 34
# all_train_score_W0_n 0.7244879086351002
# all_train_score_W0_a 0.8479962412669945
# test_score_W0_n 0.3260959759118954
# test_score_W0_a  0.3591429475944021
# Split one time!
# self.rest_data_W0_p 0.9553990610328639
# self.rest_data_W0_n 0.7240428833787145
# self.rest_data_W0_a 0.8475101395526673
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.7244879086351002
# all_train_score_W_Combined_a 0.8479962412669945
# test_score_W_combined_n 0.5517593890063907
# test_score_W_combined_a 0.7308963596761711
# Combine Neurons Number :190
# neuron unit number: 35
# all_train_score_W0_n 0.41774516291770014
# all_train_score_W0_a 0.5461653956827833
# test_score_W0_n 0.40073477451986494
# test_score_W0_a  0.5428544074388768
# Split one time!
# self.rest_data_W0_p 0.9075425790754258
# self.rest_data_W0_n 0.42460596164543774
# self.rest_data_W0_a 0.5592157021612753
# Split one time!
# self.rest_data_W0_p 0.9375
# self.rest_data_W0_n 0.48200937669311933
# self.rest_data_W0_a 0.5833333333333334
# all_train_score_W_Combined_n 0.4289878021154094
# all_train_score_W_Combined_a 0.5619398453154055
# test_score_W_combined_n 0.3232483896000875
# test_score_W_combined_a 0.47189653145880117
# Combine Neurons Number :44
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.354806  0.135463  0.024330   0.305117  0.404494
# 1  test_score_W'  31.0  0.423867  0.127908  0.022973   0.376950  0.470784
# 2       combined  62.0  0.389337  0.135214  0.017172   0.354999  0.423674
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0691
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -2.0639
# 3                       Two side test p value =    0.0434
# 4                      Difference < 0 p value =    0.0217
# 5                      Difference > 0 p value =    0.9783
# 6                                   Cohen's d =   -0.5242
# 7                                   Hedge's g =   -0.5176
# 8                               Glass's delta =   -0.5098
# 9                                 Pearson's r =    0.2575
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.354806  0.135463  0.024330   0.305117  0.404494
# 1  test_score_W'  31.0  0.569488  0.164544  0.029553   0.509133  0.629843
# 2       combined  62.0  0.462147  0.184530  0.023435   0.415285  0.509009
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.2147
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -5.6083
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.4245
# 7                                   Hedge's g =   -1.4066
# 8                               Glass's delta =   -1.5848
# 9                                 Pearson's r =    0.5865
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.5808467921795347
# all_train_score_W0_a 0.7441835724542509
# test_score_W0_n 0.33480698719756385
# test_score_W0_a  0.5035332081447661
# Split one time!
# self.rest_data_W0_p 0.931924882629108
# self.rest_data_W0_n 0.5913858593672149
# self.rest_data_W0_a 0.7403536875746993
# all_train_score_W_Combined_n 0.5932607391614032
# all_train_score_W_Combined_a 0.7445114642453103
# test_score_W_combined_n 0.5056438440820923
# test_score_W_combined_a 0.6533984196532553
# Combine Neurons Number :91
# all_train_score_W0_n 0.568393694922243
# all_train_score_W0_a 0.7799817551377777
# test_score_W0_n 0.3445182194346496
# test_score_W0_a  0.5924558496175593
# Split one time!
# self.rest_data_W0_p 0.9342723004694836
# self.rest_data_W0_n 0.5676573433883008
# self.rest_data_W0_a 0.7792825088288745
# all_train_score_W_Combined_n 0.568393694922243
# all_train_score_W_Combined_a 0.7799817551377777
# test_score_W_combined_n 0.5259408324430914
# test_score_W_combined_a 0.6921008543389278
# Combine Neurons Number :96
# all_train_score_W0_n 0.7182065290954315
# all_train_score_W0_a 0.8459372258848162
# test_score_W0_n 0.4034438196629317
# test_score_W0_a  0.548614407312503
# Split one time!
# self.rest_data_W0_p 0.951048951048951
# self.rest_data_W0_n 0.7151834152770206
# self.rest_data_W0_a 0.8437937146030876
# all_train_score_W_Combined_n 0.7182065290954315
# all_train_score_W_Combined_a 0.8459372258848162
# test_score_W_combined_n 0.5276594660136631
# test_score_W_combined_a 0.7285140037393895
# Combine Neurons Number :89
# all_train_score_W0_n 0.5939924833834093
# all_train_score_W0_a 0.7566541628340197
# test_score_W0_n 0.35809767622362226
# test_score_W0_a  0.4111611846653482
# Split one time!
# self.rest_data_W0_p 0.9341176470588235
# self.rest_data_W0_n 0.58106218666354
# self.rest_data_W0_a 0.7452590421549131
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.5939924833834093
# all_train_score_W_Combined_a 0.7566541628340197
# test_score_W_combined_n 0.41578849555947417
# test_score_W_combined_a 0.5870082798067646
# Combine Neurons Number :93
# all_train_score_W0_n 0.6202094156006407
# all_train_score_W0_a 0.7547441973746177
# test_score_W0_n 0.3027087671595509
# test_score_W0_a  0.4560499721084435
# Split one time!
# self.rest_data_W0_p 0.9408983451536643
# self.rest_data_W0_n 0.6266009950145591
# self.rest_data_W0_a 0.7636017511667674
# all_train_score_W_Combined_n 0.6307928091086686
# all_train_score_W_Combined_a 0.7678722402403706
# test_score_W_combined_n 0.43666953479023096
# test_score_W_combined_a 0.6102490735718946
# Combine Neurons Number :98
# all_train_score_W0_n 0.5770047870330385
# all_train_score_W0_a 0.7631127020996098
# test_score_W0_n 0.3431310176442877
# test_score_W0_a  0.5163326086972589
# Split one time!
# self.rest_data_W0_p 0.9366197183098591
# self.rest_data_W0_n 0.571016888984593
# self.rest_data_W0_a 0.7623071834558768
# all_train_score_W_Combined_n 0.5919682599509543
# all_train_score_W_Combined_a 0.7759268996381906
# test_score_W_combined_n 0.4450242100958878
# test_score_W_combined_a 0.6548715114944894
# Combine Neurons Number :93
# all_train_score_W0_n 0.5425948359352202
# all_train_score_W0_a 0.7535846708234768
# test_score_W0_n 0.26682702824142396
# test_score_W0_a  0.4135022118364981
# Split one time!
# self.rest_data_W0_p 0.9316037735849056
# self.rest_data_W0_n 0.5666997019104938
# self.rest_data_W0_a 0.7723055321647991
# all_train_score_W_Combined_n 0.5830475705734404
# all_train_score_W_Combined_a 0.7800704309714326
# test_score_W_combined_n 0.40496622570804824
# test_score_W_combined_a 0.587046682204222
# Combine Neurons Number :89
# all_train_score_W0_n 0.6497180878491255
# all_train_score_W0_a 0.8061719748804799
# test_score_W0_n 0.43205853506818137
# test_score_W0_a  0.49761554751440823
# Split one time!
# self.rest_data_W0_p 0.9478672985781991
# self.rest_data_W0_n 0.6406370956557524
# self.rest_data_W0_a 0.8017019423944284
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6665966731097963
# all_train_score_W_Combined_a 0.8191730065783788
# test_score_W_combined_n 0.526834953996072
# test_score_W_combined_a 0.6544627407037786
# Combine Neurons Number :90
# all_train_score_W0_n 0.6310091262537868
# all_train_score_W0_a 0.7799933396991927
# test_score_W0_n 0.3853753731760604
# test_score_W0_a  0.5746172830659009
# Split one time!
# self.rest_data_W0_p 0.9413145539906104
# self.rest_data_W0_n 0.6212899036900688
# self.rest_data_W0_a 0.7729007946995454
# all_train_score_W_Combined_n 0.6310091262537868
# all_train_score_W_Combined_a 0.7799933396991927
# test_score_W_combined_n 0.5055782275661335
# test_score_W_combined_a 0.652088123385467
# Combine Neurons Number :90
# all_train_score_W0_n 0.6017636527202828
# all_train_score_W0_a 0.7447583997732237
# test_score_W0_n 0.5119901693059817
# test_score_W0_a  0.6599368209890816
# Split one time!
# self.rest_data_W0_p 0.9370629370629371
# self.rest_data_W0_n 0.5912178548887669
# self.rest_data_W0_a 0.7367684967534047
# all_train_score_W_Combined_n 0.6017636527202828
# all_train_score_W_Combined_a 0.7447583997732237
# test_score_W_combined_n 0.5909704187928716
# test_score_W_combined_a 0.6954302394623851
# Combine Neurons Number :89
# all_train_score_W0_n 0.5482963503795907
# all_train_score_W0_a 0.7409821302063836
# test_score_W0_n 0.3545173126205926
# test_score_W0_a  0.44827986241769135
# Split one time!
# self.rest_data_W0_p 0.9297423887587822
# self.rest_data_W0_n 0.5511134531143579
# self.rest_data_W0_a 0.7424823036985702
# all_train_score_W_Combined_n 0.5730903409094612
# all_train_score_W_Combined_a 0.7545614719761351
# test_score_W_combined_n 0.5667435221393692
# test_score_W_combined_a 0.6947471360715284
# Combine Neurons Number :95
# all_train_score_W0_n 0.6551011122469466
# all_train_score_W0_a 0.8303818992402395
# test_score_W0_n 0.4435120871011741
# test_score_W0_a  0.6493101523028985
# Split one time!
# self.rest_data_W0_p 0.9484777517564403
# self.rest_data_W0_n 0.6545975873871129
# self.rest_data_W0_a 0.829916405540675
# all_train_score_W_Combined_n 0.6551011122469466
# all_train_score_W_Combined_a 0.8303818992402395
# test_score_W_combined_n 0.5351201276051976
# test_score_W_combined_a 0.7294866982437943
# Combine Neurons Number :93
# all_train_score_W0_n 0.5610986042673093
# all_train_score_W0_a 0.7946095881253405
# test_score_W0_n 0.44630701675484946
# test_score_W0_a  0.647857796484818
# Split one time!
# self.rest_data_W0_p 0.9339622641509434
# self.rest_data_W0_n 0.5770896456701338
# self.rest_data_W0_a 0.7970394321667749
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.592059719404849
# all_train_score_W_Combined_a 0.8069651185480514
# test_score_W_combined_n 0.3515668159342523
# test_score_W_combined_a 0.5759668909472144
# Combine Neurons Number :97
# all_train_score_W0_n 0.5573234161846993
# all_train_score_W0_a 0.7121503312633491
# test_score_W0_n 0.31508948256226715
# test_score_W0_a  0.481962447953492
# Split one time!
# self.rest_data_W0_p 0.9344262295081968
# self.rest_data_W0_n 0.5633363855774486
# self.rest_data_W0_a 0.716325428156328
# all_train_score_W_Combined_n 0.5720783601477092
# all_train_score_W_Combined_a 0.7213167406942582
# test_score_W_combined_n 0.4065786489123528
# test_score_W_combined_a 0.5669636723339593
# Combine Neurons Number :98
# all_train_score_W0_n 0.6117219182851966
# all_train_score_W0_a 0.7944490204205673
# test_score_W0_n 0.4066975058187736
# test_score_W0_a  0.5858236570823505
# Split one time!
# self.rest_data_W0_p 0.9460093896713615
# self.rest_data_W0_n 0.6217240232410408
# self.rest_data_W0_a 0.7838959116722679
# all_train_score_W_Combined_n 0.6371685580389611
# all_train_score_W_Combined_a 0.7960712645156948
# test_score_W_combined_n 0.43284563875934645
# test_score_W_combined_a 0.6276000629021801
# Combine Neurons Number :94
# all_train_score_W0_n 0.6601749094290088
# all_train_score_W0_a 0.7975634062645065
# test_score_W0_n 0.39745242458420754
# test_score_W0_a  0.538727126826631
# Split one time!
# self.rest_data_W0_p 0.9505882352941176
# self.rest_data_W0_n 0.6716863009362188
# self.rest_data_W0_a 0.7948612279272308
# all_train_score_W_Combined_n 0.6745084520554415
# all_train_score_W_Combined_a 0.7981573107816599
# test_score_W_combined_n 0.45357517534205183
# test_score_W_combined_a 0.6427375031451094
# Combine Neurons Number :99
# all_train_score_W0_n 0.6553615126671646
# all_train_score_W0_a 0.8177727505408792
# test_score_W0_n 0.4928038525234677
# test_score_W0_a  0.7348558280579004
# Split one time!
# self.rest_data_W0_p 0.9408983451536643
# self.rest_data_W0_n 0.6544351386428989
# self.rest_data_W0_a 0.8168268252552435
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6553615126671646
# all_train_score_W_Combined_a 0.8177727505408792
# test_score_W_combined_n 0.5344514181219976
# test_score_W_combined_a 0.7296530841258003
# Combine Neurons Number :92
# all_train_score_W0_n 0.6359045966150438
# all_train_score_W0_a 0.8167848841773521
# test_score_W0_n 0.3733929175480601
# test_score_W0_a  0.3605864941909591
# Split one time!
# self.rest_data_W0_p 0.9527186761229315
# self.rest_data_W0_n 0.6719798373052009
# self.rest_data_W0_a 0.8315226389738712
# all_train_score_W_Combined_n 0.6918220583486203
# all_train_score_W_Combined_a 0.843493449041172
# test_score_W_combined_n 0.5056438440820923
# test_score_W_combined_a 0.6533984196532553
# Combine Neurons Number :91
# all_train_score_W0_n 0.5778949077618544
# all_train_score_W0_a 0.7506507101016484
# test_score_W0_n 0.334342246822589
# test_score_W0_a  0.45090031280156073
# Split one time!
# self.rest_data_W0_p 0.9341176470588235
# self.rest_data_W0_n 0.5827329987677841
# self.rest_data_W0_a 0.7435014850282795
# all_train_score_W_Combined_n 0.5924625372601939
# all_train_score_W_Combined_a 0.7513113206937395
# test_score_W_combined_n 0.5851454507899897
# test_score_W_combined_a 0.7316394087472612
# Combine Neurons Number :90
# all_train_score_W0_n 0.6329885472365122
# all_train_score_W0_a 0.8126176013592978
# test_score_W0_n 0.29752246804480564
# test_score_W0_a  0.4860273981604233
# Split one time!
# self.rest_data_W0_p 0.9411764705882353
# self.rest_data_W0_n 0.6322270153730769
# self.rest_data_W0_a 0.811865779767066
# all_train_score_W_Combined_n 0.6329885472365122
# all_train_score_W_Combined_a 0.8126176013592978
# test_score_W_combined_n 0.5647038596284989
# test_score_W_combined_a 0.7308963596761711
# Combine Neurons Number :91
# all_train_score_W0_n 0.6137078670773861
# all_train_score_W0_a 0.7787528142057724
# test_score_W0_n 0.5925986770635877
# test_score_W0_a  0.7612905019953154
# Split one time!
# self.rest_data_W0_p 0.9393939393939394
# self.rest_data_W0_n 0.609092789674709
# self.rest_data_W0_a 0.7753814774953892
# all_train_score_W_Combined_n 0.6137078670773861
# all_train_score_W_Combined_a 0.7787528142057724
# test_score_W_combined_n 0.5212951563009277
# test_score_W_combined_a 0.6919355965353451
# Combine Neurons Number :88
# all_train_score_W0_n 0.631590723338524
# all_train_score_W0_a 0.7948400007666807
# test_score_W0_n 0.32298500875582986
# test_score_W0_a  0.5210120703202352
# Split one time!
# self.rest_data_W0_p 0.936768149882904
# self.rest_data_W0_n 0.6230213918501413
# self.rest_data_W0_a 0.7887010660336619
# all_train_score_W_Combined_n 0.631590723338524
# all_train_score_W_Combined_a 0.7948400007666807
# test_score_W_combined_n 0.48924511159290507
# test_score_W_combined_a 0.7031815619128319
# Combine Neurons Number :93
# all_train_score_W0_n 0.6592167399519099
# all_train_score_W0_a 0.7883759526967659
# test_score_W0_n 0.48981864842324974
# test_score_W0_a  0.6824113977973048
# Split one time!
# self.rest_data_W0_p 0.9458823529411765
# self.rest_data_W0_n 0.631353759079677
# self.rest_data_W0_a 0.7679580621013239
# Split one time!
# self.rest_data_W0_p 1.0
# self.rest_data_W0_n 1.0
# self.rest_data_W0_a 1.0
# all_train_score_W_Combined_n 0.6592167399519099
# all_train_score_W_Combined_a 0.7883759526967659
# test_score_W_combined_n 0.4954989392176454
# test_score_W_combined_a 0.6433475175895541
# Combine Neurons Number :100
# all_train_score_W0_n 0.6375337115244158
# all_train_score_W0_a 0.8134646627775717
# test_score_W0_n 0.4163134481254619
# test_score_W0_a  0.5557056497453243
# Split one time!
# self.rest_data_W0_p 0.9462616822429907
# self.rest_data_W0_n 0.6371629738768608
# self.rest_data_W0_a 0.8130999836871021
# all_train_score_W_Combined_n 0.6375337115244158
# all_train_score_W_Combined_a 0.8134646627775717
# test_score_W_combined_n 0.4680523761588566
# test_score_W_combined_a 0.6344758442494263
# Combine Neurons Number :91
# all_train_score_W0_n 0.5610477990274592
# all_train_score_W0_a 0.6982532296166232
# test_score_W0_n 0.2847990595474418
# test_score_W0_a  0.45082567889316943
# Split one time!
# self.rest_data_W0_p 0.9317647058823529
# self.rest_data_W0_n 0.5604088134184246
# self.rest_data_W0_a 0.6973358688432834
# all_train_score_W_Combined_n 0.5610477990274592
# all_train_score_W_Combined_a 0.6982532296166232
# test_score_W_combined_n 0.38706635949908275
# test_score_W_combined_a 0.5656859647611114
# Combine Neurons Number :95
# all_train_score_W0_n 0.6180447584026845
# all_train_score_W0_a 0.760848478699816
# test_score_W0_n 0.4143709797811069
# test_score_W0_a  0.6216439197290835
# Split one time!
# self.rest_data_W0_p 0.9364705882352942
# self.rest_data_W0_n 0.6130862404642987
# self.rest_data_W0_a 0.7566976097403937
# all_train_score_W_Combined_n 0.6180447584026845
# all_train_score_W_Combined_a 0.760848478699816
# test_score_W_combined_n 0.5115960447366134
# test_score_W_combined_a 0.6908957696200977
# Combine Neurons Number :93
# all_train_score_W0_n 0.6076648372785736
# all_train_score_W0_a 0.7757190739560689
# test_score_W0_n 0.5416316988845236
# test_score_W0_a  0.7664986924581713
# Split one time!
# self.rest_data_W0_p 0.9413145539906104
# self.rest_data_W0_n 0.622698848635722
# self.rest_data_W0_a 0.7800318737839045
# all_train_score_W_Combined_n 0.638424305853339
# all_train_score_W_Combined_a 0.787163908229841
# test_score_W_combined_n 0.4786528424968605
# test_score_W_combined_a 0.5857773427540066
# Combine Neurons Number :96
# all_train_score_W0_n 0.5266375129538992
# all_train_score_W0_a 0.734990711142497
# test_score_W0_n 0.5037636259613945
# test_score_W0_a  0.6472764200767352
# Split one time!
# self.rest_data_W0_p 0.9248826291079812
# self.rest_data_W0_n 0.5437938864315714
# self.rest_data_W0_a 0.7408465590911137
# all_train_score_W_Combined_n 0.5547612871898385
# all_train_score_W_Combined_a 0.748609678967907
# test_score_W_combined_n 0.5571154170201648
# test_score_W_combined_a 0.7297582423881482
# Combine Neurons Number :90
# all_train_score_W0_n 0.6335158537650073
# all_train_score_W0_a 0.7951618149545946
# test_score_W0_n 0.3450165070882313
# test_score_W0_a  0.40005437772417585
# Split one time!
# self.rest_data_W0_p 0.9440559440559441
# self.rest_data_W0_n 0.6470905053438435
# self.rest_data_W0_a 0.807667993231675
# all_train_score_W_Combined_n 0.6473169651648744
# all_train_score_W_Combined_a 0.8079110995870653
# test_score_W_combined_n 0.5108034016462089
# test_score_W_combined_a 0.6541336996569288
# Combine Neurons Number :91
# all_train_score_W0_n 0.5590426224437571
# all_train_score_W0_a 0.7646313401789617
# test_score_W0_n 0.41689313781873155
# test_score_W0_a  0.614680463682334
# Split one time!
# self.rest_data_W0_p 0.9299065420560748
# self.rest_data_W0_n 0.558612587578893
# self.rest_data_W0_a 0.7641861721137783
# all_train_score_W_Combined_n 0.5590426224437571
# all_train_score_W_Combined_a 0.7646313401789617
# test_score_W_combined_n 0.47561862949983763
# test_score_W_combined_a 0.6076242234413215
# Combine Neurons Number :93
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.395760  0.080782  0.014749   0.365595  0.425924
# 1  test_score_W'  30.0  0.490546  0.060363  0.011021   0.468007  0.513086
# 2       combined  60.0  0.443153  0.085339  0.011017   0.421108  0.465198
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0948
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -5.1483
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.3293
# 7                                   Hedge's g =   -1.3120
# 8                               Glass's delta =   -1.1734
# 9                                 Pearson's r =    0.5600
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.395760  0.080782  0.014749   0.365595  0.425924
# 1  test_score_W'  30.0  0.656836  0.054119  0.009881   0.636627  0.677044
# 2       combined  60.0  0.526298  0.148244  0.019138   0.488002  0.564593
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.2611
# 1                          Degrees of freedom =   58.0000
# 2                                           t =  -14.7064
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -3.7972
# 7                                   Hedge's g =   -3.7479
# 8                               Glass's delta =   -3.2319
# 9                                 Pearson's r =    0.8880
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
