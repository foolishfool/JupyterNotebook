# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION

import pandas as pd
import numpy as np
import newSom 
import experiment
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("hcvdat0.csv")
csv = csv.drop(columns=['ID'])
dataread.replaceNANinDataset(csv)
csv_original_encode = csv


# class label do not need to onehot encoding, label ercoding will be OK
dataread.label_encoding(csv_original_encode,"Category")
dataread.hash_encoding(csv_original_encode,["Sex"])

dataread.label_encoding(csv,"Sex")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


csv_test_original_encoded = dataread.original_encoding_data.sample(int(dataread.original_encoding_data.shape[0]*0.3))
csv_training_original_encoded = dataread.original_encoding_data.drop(csv_test_original_encoded.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,csv_training_original_encoded,csv_test_original_encoded,"Category")
# Out:
# self.data_continuous_indexes ['Age', 'ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA', 'GGT', 'PROT']
# self.continuous_feature_num 11
#  column number self.data_train_discrete 1

# %%
# new binary endoding hybrid
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9164733178654292
# all_train_score_W_combine_n 0.4845509183446439
# all_train_score_W_combine_a 0.734946229913767
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.5450788873592789
# test_score_W_combine_a 0.7561414900911526
# neuron unit number: 10
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.05826680289333184
# test_score_W0_a  0.0609337557369725
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5102273712408548
# all_train_score_W_combine_a 0.6833434185242844
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6484052592255745
# test_score_W_combine_a 0.8315181319924732
# neuron unit number: 15
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.540597467922588
# all_train_score_W_combine_a 0.7652334240921566
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.8243097041636037
# test_score_W_combine_a 0.9595523858471579
# neuron unit number: 20
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.10804176519271506
# test_score_W0_a  0.11851942596749554
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.5066278195567924
# all_train_score_W_combine_a 0.7238445112040388
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6931046772317819
# test_score_W_combine_a 0.8759524302333369
# neuron unit number: 25
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.10804176519271506
# test_score_W0_a  0.11851942596749554
# all_train_score_W_combine_p 0.91415313225058
# all_train_score_W_combine_n 0.4396754343256085
# all_train_score_W_combine_a 0.6806649227619184
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6842905341896834
# test_score_W_combine_a 0.8556082513804916
# neuron unit number: 30
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1836627428760779
# test_score_W0_a  0.2274302437733503
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.5204573764690665
# all_train_score_W_combine_a 0.7422595949724583
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6594682071224401
# test_score_W_combine_a 0.8477884335733512
# neuron unit number: 35
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.875
# test_score_W0_n 0.10804176519271506
# test_score_W0_a  0.11851942596749554
# all_train_score_W_combine_p 0.9187935034802784
# all_train_score_W_combine_n 0.4566526286702333
# all_train_score_W_combine_a 0.7260310688274553
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.5261524098397664
# test_score_W_combine_a 0.6930285056760497
# neuron unit number: 40
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1693103509272268
# test_score_W0_a  0.21306515756559644
# all_train_score_W_combine_p 0.9187935034802784
# all_train_score_W_combine_n 0.47413508613012917
# all_train_score_W_combine_a 0.7310058940382285
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6004607181767027
# test_score_W_combine_a 0.7900044505675488
# neuron unit number: 45
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.048837767151994615
# all_train_score_W0_a 0.05358201106006464
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.49831129530798857
# all_train_score_W_combine_a 0.7148184777646972
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6697106136444986
# test_score_W_combine_a 0.8222822739957879
# neuron unit number: 50
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.05826680289333184
# test_score_W0_a  0.0609337557369725
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5204055690765551
# all_train_score_W_combine_a 0.7528224418524351
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.6929284624118721
# test_score_W_combine_a 0.8798172448477747
# neuron unit number: 55
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8858695652173914
# test_score_W0_n 0.211233751890184
# test_score_W0_a  0.2626460959497797
# all_train_score_W_combine_p 0.9211136890951276
# all_train_score_W_combine_n 0.47274551667189213
# all_train_score_W_combine_a 0.6784062058152842
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.75344328289352
# test_score_W_combine_a 0.9316276697089158
# neuron unit number: 60
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02405777989859681
# all_train_score_W0_a 0.026864964014238858
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.05598340142071136
# test_score_W0_a  0.060466674789813574
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.5990853671597701
# all_train_score_W_combine_a 0.8086378909450537
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6237808170782867
# test_score_W_combine_a 0.789848703863837
# neuron unit number: 65
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.16158866751571838
# test_score_W0_a  0.2269910341336535
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.5224462729336813
# all_train_score_W_combine_a 0.7816510944945146
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7964879911968408
# test_score_W_combine_a 0.9351766397502881
# neuron unit number: 70
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.5726924860048166
# all_train_score_W_combine_a 0.7773874311089425
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.6103716776105179
# test_score_W_combine_a 0.728726415672266
# neuron unit number: 75
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5231698794531938
# all_train_score_W_combine_a 0.7775287329364661
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6922067285282898
# test_score_W_combine_a 0.8788143289494251
# neuron unit number: 80
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.16734813874209373
# test_score_W0_a  0.21254398758079618
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5790158858606249
# all_train_score_W_combine_a 0.7954699681999838
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.7432134015909186
# test_score_W_combine_a 0.880224410056161
# neuron unit number: 85
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1570747604501616
# test_score_W0_a  0.17432613193198876
# all_train_score_W_combine_p 0.9164733178654292
# all_train_score_W_combine_n 0.44468175432344165
# all_train_score_W_combine_a 0.6697064675348378
# test_score_W_combine_p 0.9184782608695652
# test_score_W_combine_n 0.5443073579937002
# test_score_W_combine_a 0.7337851435027396
# neuron unit number: 90
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9211136890951276
# all_train_score_W_combine_n 0.5030602313538887
# all_train_score_W_combine_a 0.7452707029618433
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6383963940451362
# test_score_W_combine_a 0.8485180204911212
# neuron unit number: 95
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.10804176519271506
# test_score_W0_a  0.11851942596749554
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5828525171954287
# all_train_score_W_combine_a 0.7877546677135007
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.789837443439929
# test_score_W_combine_a 0.9349445836756437
# neuron unit number: 100
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02618305937841556
# all_train_score_W0_a 0.02730573538663933
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.48605531022999615
# all_train_score_W_combine_a 0.7258999278921496
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.644397821326482
# test_score_W_combine_a 0.8207849641813808
# test_score_W0_p mean 0.8720108695652176
# test_score_W_combine_p mean 0.9404891304347824
# test_score_W0_n mean 0.08274512401898489
# test_score_W_combine_n mean 0.6690176194534412
# test_score_W0_a mean 0.09867072705344529
# test_score_W_combine_a mean 0.8397072239028451
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.014118  0.015325  0.003427   0.006946  0.021290
# 1  train_W_combine  20.0  0.511872  0.045595  0.010195   0.490533  0.533211
# 2         combined  40.0  0.262995  0.254274  0.040204   0.181674  0.344316
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.4978
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -46.2780
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -14.6344
# 7                                Hedge's g =  -14.3436
# 8                           Glass's delta1 =  -32.4809
# 9                         Point-Biserial r =   -0.9912
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.082745  0.074512  0.016661   0.047873  0.117618
# 1  test_W_combine  20.0  0.669018  0.083693  0.018714   0.629848  0.708187
# 2        combined  40.0  0.375881  0.307001  0.048541   0.277698  0.474065
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.5863
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -23.3980
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -7.3991
# 7                              Hedge's g =   -7.2521
# 8                         Glass's delta1 =   -7.8682
# 9                       Point-Biserial r =   -0.9670
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.014945  0.016369  0.003660   0.007284  0.022605
# 1  train_W_combine  20.0  0.740134  0.041234  0.009220   0.720836  0.759432
# 2         combined  40.0  0.377539  0.368517  0.058268   0.259682  0.495397
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.7252
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -73.1031
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -23.1172
# 7                                Hedge's g =  -22.6580
# 8                           Glass's delta1 =  -44.3035
# 9                         Point-Biserial r =   -0.9965
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.098671  0.093399  0.020885   0.054959  0.142383
# 1  test_W_combine  20.0  0.839707  0.074412  0.016639   0.804881  0.874533
# 2        combined  40.0  0.469189  0.384384  0.060776   0.346257  0.592121
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.7410
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -27.7515
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -8.7758
# 7                              Hedge's g =   -8.6014
# 8                         Glass's delta1 =   -7.9341
# 9                       Point-Biserial r =   -0.9762
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.869026  0.001403  0.000314   0.868369  0.869682
# 1  train_W_combine  20.0  0.923898  0.005713  0.001277   0.921224  0.926572
# 2         combined  40.0  0.896462  0.028087  0.004441   0.887479  0.905445
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0549
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -41.7135
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -13.1910
# 7                                Hedge's g =  -12.9289
# 8                           Glass's delta1 =  -39.1035
# 9                         Point-Biserial r =   -0.9893
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.872011  0.007157  0.001600   0.868661  0.875360
# 1  test_W_combine  20.0  0.940489  0.011218  0.002508   0.935239  0.945739
# 2        combined  40.0  0.906250  0.035898  0.005676   0.894769  0.917731
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0685
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -23.0144
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -7.2778
# 7                              Hedge's g =   -7.1332
# 8                         Glass's delta1 =   -9.5680
# 9                       Point-Biserial r =   -0.9659

# %%
# new effect hybrid
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.1225485570439078
# test_score_W0_a  0.16060626204879347
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5929064657384391
# all_train_score_W_combine_a 0.8500223858665833
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7225173692279139
# test_score_W_combine_a 0.880493543239553
# neuron unit number: 10
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02656889872182468
# all_train_score_W0_a 0.027365016833234588
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1616992170022553
# test_score_W0_a  0.21172303488136557
# all_train_score_W_combine_p 0.91415313225058
# all_train_score_W_combine_n 0.4696836327291423
# all_train_score_W_combine_a 0.754245341714392
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.6778703335675665
# test_score_W_combine_a 0.8561172196538019
# neuron unit number: 15
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8858695652173914
# test_score_W0_n 0.20183811578874958
# test_score_W0_a  0.22707284507477568
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5603359993403373
# all_train_score_W_combine_a 0.7997858566303909
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7121611374371201
# test_score_W_combine_a 0.8843391310512032
# neuron unit number: 20
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.024733542963072303
# all_train_score_W0_a 0.027012676683563597
# test_score_W0_p0.8913043478260869
# test_score_W0_n 0.24370739802695213
# test_score_W0_a  0.2779498135114207
# all_train_score_W_combine_p 0.9211136890951276
# all_train_score_W_combine_n 0.530039356664357
# all_train_score_W_combine_a 0.7952712381953033
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.680130377548109
# test_score_W_combine_a 0.8534010548622368
# neuron unit number: 25
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8913043478260869
# test_score_W0_n 0.24222734991950548
# test_score_W0_a  0.3087780568496008
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5482408157581538
# all_train_score_W_combine_a 0.8235552409337566
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.5860723280658586
# test_score_W_combine_a 0.6946044490431897
# neuron unit number: 30
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.11766587814211309
# test_score_W0_a  0.15890572757070184
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.5314640819226044
# all_train_score_W_combine_a 0.7559366082234757
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6156005540391436
# test_score_W_combine_a 0.7743735922781998
# neuron unit number: 35
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1603085039287826
# test_score_W0_a  0.1746327919703887
# all_train_score_W_combine_p 0.9118329466357309
# all_train_score_W_combine_n 0.44730600952392746
# all_train_score_W_combine_a 0.6999633683316593
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.744284523067765
# test_score_W_combine_a 0.9092436671614794
# neuron unit number: 40
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.024733542963072303
# all_train_score_W0_a 0.027012676683563597
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.2260231904046532
# test_score_W0_a  0.2631229555169445
# all_train_score_W_combine_p 0.9443155452436195
# all_train_score_W_combine_n 0.6446110297456601
# all_train_score_W_combine_a 0.8629842466420089
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7755521732279494
# test_score_W_combine_a 0.9371208060917844
# neuron unit number: 45
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.13052731619799796
# test_score_W0_a  0.19652089581616117
# all_train_score_W_combine_p 0.9211136890951276
# all_train_score_W_combine_n 0.5071199925519912
# all_train_score_W_combine_a 0.7729278600574518
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.70122823904228
# test_score_W_combine_a 0.883398605565209
# neuron unit number: 50
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1700382878185504
# test_score_W0_a  0.24561861269038188
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.5907168413864547
# all_train_score_W_combine_a 0.8330163775621762
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.558962793656697
# test_score_W_combine_a 0.69395876875035
# neuron unit number: 55
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.034859384191231274
# all_train_score_W0_a 0.02824586720741206
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.15153425924475883
# test_score_W0_a  0.17296950403643188
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5907794534698964
# all_train_score_W_combine_a 0.8344726257165687
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.7353036217400558
# test_score_W_combine_a 0.9066661642989645
# neuron unit number: 60
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02656889872182468
# all_train_score_W0_a 0.027365016833234588
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1536234304006797
# test_score_W0_a  0.17341812377929253
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5162513026764277
# all_train_score_W_combine_a 0.7703470506488299
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.740488342042335
# test_score_W_combine_a 0.8848783108913523
# neuron unit number: 65
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.027102119148141725
# all_train_score_W0_a 0.027453101870652336
# test_score_W0_p0.875
# test_score_W0_n 0.11013317688156976
# test_score_W0_a  0.11886223655196082
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5488207483981365
# all_train_score_W_combine_a 0.8094756433133988
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.7399650782417239
# test_score_W_combine_a 0.9082963904701452
# neuron unit number: 70
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.11766587814211309
# test_score_W0_a  0.15890572757070184
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.5283272874764144
# all_train_score_W_combine_a 0.7755786396693449
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6301559158516454
# test_score_W_combine_a 0.8183559389725128
# neuron unit number: 75
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1625008284566649
# test_score_W0_a  0.21094214518149595
# all_train_score_W_combine_p 0.9164733178654292
# all_train_score_W_combine_n 0.5065959992442399
# all_train_score_W_combine_a 0.7902871384086861
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6848751749254217
# test_score_W_combine_a 0.8542715633543145
# neuron unit number: 80
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.11631956655451048
# test_score_W0_a  0.1592864605740274
# all_train_score_W_combine_p 0.91415313225058
# all_train_score_W_combine_n 0.47804130262242345
# all_train_score_W_combine_a 0.7500844920576492
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6438773565793381
# test_score_W_combine_a 0.8537802249419051
# neuron unit number: 85
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.027102119148141725
# all_train_score_W0_a 0.027453101870652336
# test_score_W0_p0.8858695652173914
# test_score_W0_n 0.26348499062642566
# test_score_W0_a  0.3107282566772244
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5101642840075008
# all_train_score_W_combine_a 0.747140175250303
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6701516577930494
# test_score_W_combine_a 0.8262702185176707
# neuron unit number: 90
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.05039475567250457
# all_train_score_W0_a 0.05387511248355901
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.1561080041866679
# test_score_W0_a  0.17368029092983914
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5159553162749185
# all_train_score_W_combine_a 0.7611554744544561
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6801603355585095
# test_score_W_combine_a 0.8350460782198788
# neuron unit number: 95
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.02656889872182468
# all_train_score_W0_a 0.027365016833234588
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.07206993291447364
# test_score_W0_a  0.10502597896256538
# all_train_score_W_combine_p 0.9164733178654292
# all_train_score_W_combine_n 0.4963946033148099
# all_train_score_W_combine_a 0.8035636484771601
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6565849634055074
# test_score_W_combine_a 0.7985605137992424
# neuron unit number: 100
# all_train_score_W0_p 0.8677494199535963
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.19138599585894897
# test_score_W0_a  0.17790432120789879
# all_train_score_W_combine_p 0.9211136890951276
# all_train_score_W_combine_n 0.5327233231891066
# all_train_score_W_combine_a 0.8027062278597222
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6705643692469104
# test_score_W_combine_a 0.8627651167514829
# test_score_W0_p mean 0.8796195652173913
# test_score_W_combine_p mean 0.944836956521739
# test_score_W0_n mean 0.16357049387701403
# test_score_W_combine_n mean 0.681325332213245
# test_score_W0_a mean 0.1993327020700986
# test_score_W_combine_a mean 0.8457970678957238
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.013432  0.016152  0.003612   0.005872  0.020991
# 1  train_W_combine  20.0  0.532324  0.047095  0.010531   0.510283  0.554365
# 2         combined  40.0  0.272878  0.265039  0.041906   0.188114  0.357641
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.5189
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -46.6086
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -14.7389
# 7                                Hedge's g =  -14.4461
# 8                           Glass's delta1 =  -32.1254
# 9                         Point-Biserial r =   -0.9914
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.163570  0.051061  0.011417   0.139673  0.187468
# 1  test_W_combine  20.0  0.681325  0.055727  0.012461   0.655244  0.707406
# 2        combined  40.0  0.422448  0.267430  0.042284   0.336920  0.507976
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.5178
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -30.6350
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -9.6876
# 7                              Hedge's g =   -9.4952
# 8                         Glass's delta1 =  -10.1400
# 9                       Point-Biserial r =   -0.9803
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.013657  0.016517  0.003693   0.005927  0.021387
# 1  train_W_combine  20.0  0.789626  0.040015  0.008948   0.770899  0.808353
# 2         combined  40.0  0.401642  0.394087  0.062311   0.275607  0.527677
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.7760
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -80.1637
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -25.3500
# 7                                Hedge's g =  -24.8463
# 8                           Glass's delta1 =  -46.9813
# 9                         Point-Biserial r =   -0.9971
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.199333  0.057437  0.012843   0.172452  0.226214
# 1  test_W_combine  20.0  0.845797  0.065168  0.014572   0.815297  0.876297
# 2        combined  40.0  0.522565  0.332918  0.052639   0.416093  0.629037
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6465
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -33.2816
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -10.5246
# 7                              Hedge's g =  -10.3155
# 8                         Glass's delta1 =  -11.2553
# 9                       Point-Biserial r =   -0.9833
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.868910  0.001408  0.000315   0.868250  0.869569
# 1  train_W_combine  20.0  0.923782  0.007424  0.001660   0.920307  0.927257
# 2         combined  40.0  0.896346  0.028282  0.004472   0.887301  0.905391
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0549
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -32.4737
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -10.2691
# 7                                Hedge's g =  -10.0651
# 8                           Glass's delta1 =  -38.9636
# 9                         Point-Biserial r =   -0.9825
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.879620  0.005652  0.001264   0.876974  0.882265
# 1  test_W_combine  20.0  0.944837  0.009540  0.002133   0.940372  0.949302
# 2        combined  40.0  0.912228  0.033919  0.005363   0.901380  0.923076
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0652
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -26.3018
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -8.3173
# 7                              Hedge's g =   -8.1521
# 8                         Glass's delta1 =  -11.5386
# 9                       Point-Biserial r =   -0.9736

# %%
# new baseN hybrid
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.024894155881908613
# all_train_score_W0_a 0.028068140033220484
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.08101066172434228
# test_score_W0_a  0.10814558598271087
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.5144061921876237
# all_train_score_W_combine_a 0.73868674399347
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6417857317674603
# test_score_W_combine_a 0.8108708964874187
# neuron unit number: 10
# all_train_score_W0_p 0.8793503480278422
# all_train_score_W0_n 0.07256817492327755
# all_train_score_W0_a 0.08262621510439234
# test_score_W0_p0.875
# test_score_W0_n 0.18982186262017306
# test_score_W0_a  0.20870699301250234
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.5600512356010057
# all_train_score_W_combine_a 0.7464692022976304
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6737011224408145
# test_score_W_combine_a 0.8658651298943453
# neuron unit number: 15
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.024894155881908613
# all_train_score_W0_a 0.028068140033220484
# test_score_W0_p0.8532608695652174
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5294778094180372
# all_train_score_W_combine_a 0.7502528227215327
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.596800182191945
# test_score_W_combine_a 0.7864443828960781
# neuron unit number: 20
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.024894155881908613
# all_train_score_W0_a 0.028068140033220484
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5455110808487664
# all_train_score_W_combine_a 0.7836986445256016
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.6096091927551062
# test_score_W_combine_a 0.7746223158676285
# neuron unit number: 25
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.024894155881908613
# all_train_score_W0_a 0.028068140033220484
# test_score_W0_p0.8532608695652174
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9443155452436195
# all_train_score_W_combine_n 0.635420968379458
# all_train_score_W_combine_a 0.8428257910264771
# test_score_W_combine_p 0.9619565217391305
# test_score_W_combine_n 0.7551124545230311
# test_score_W_combine_a 0.8904800136556418
# neuron unit number: 30
# all_train_score_W0_p 0.877030162412993
# all_train_score_W0_n 0.06302647796584306
# all_train_score_W0_a 0.05711352326677609
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.10230415764343266
# test_score_W0_a  0.10844835808633528
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.47144519695819825
# all_train_score_W_combine_a 0.7132105533780652
# test_score_W_combine_p 0.9130434782608695
# test_score_W_combine_n 0.5676309186217523
# test_score_W_combine_a 0.7783276291701275
# neuron unit number: 35
# all_train_score_W0_p 0.877030162412993
# all_train_score_W0_n 0.04900929651027695
# all_train_score_W0_a 0.05560350432760354
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9466357308584686
# all_train_score_W_combine_n 0.6671074304098593
# all_train_score_W_combine_a 0.882973967945262
# test_score_W_combine_p 0.9619565217391305
# test_score_W_combine_n 0.8046238709452486
# test_score_W_combine_a 0.9406782289964827
# neuron unit number: 40
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9419953596287703
# all_train_score_W_combine_n 0.585540863836259
# all_train_score_W_combine_a 0.7954811302796955
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.7017035161374835
# test_score_W_combine_a 0.8895177249601128
# neuron unit number: 45
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5493969174873464
# all_train_score_W_combine_a 0.7517840414882981
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.7532184591648677
# test_score_W_combine_a 0.91228383071409
# neuron unit number: 50
# all_train_score_W0_p 0.877030162412993
# all_train_score_W0_n 0.04900929651027695
# all_train_score_W0_a 0.05560350432760354
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.10230415764343266
# test_score_W0_a  0.10844835808633528
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.5476843823194535
# all_train_score_W_combine_a 0.7681321029870304
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6719702051579977
# test_score_W_combine_a 0.8063084588744178
# neuron unit number: 55
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.570659945480802
# all_train_score_W_combine_a 0.7595620699027741
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6719890489593989
# test_score_W_combine_a 0.8328712863508155
# neuron unit number: 60
# all_train_score_W0_p 0.8793503480278422
# all_train_score_W0_n 0.07256817492327755
# all_train_score_W0_a 0.08262621510439234
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.19319642374096252
# test_score_W0_a  0.22941041219063882
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.5583727711842893
# all_train_score_W_combine_a 0.760196168216715
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6464887244952722
# test_score_W_combine_a 0.8047564343622922
# neuron unit number: 65
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.12847545120485998
# test_score_W0_a  0.15945994809331454
# all_train_score_W_combine_p 0.9396751740139211
# all_train_score_W_combine_n 0.5971664370254869
# all_train_score_W_combine_a 0.8024376481278869
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.6022678746447471
# test_score_W_combine_a 0.8344704258290874
# neuron unit number: 70
# all_train_score_W0_p 0.8793503480278422
# all_train_score_W0_n 0.07383320832553354
# all_train_score_W0_a 0.08293738678494414
# test_score_W0_p0.875
# test_score_W0_n 0.19716366927072546
# test_score_W0_a  0.2097947607518205
# all_train_score_W_combine_p 0.9396751740139211
# all_train_score_W_combine_n 0.5641666006737046
# all_train_score_W_combine_a 0.7691810122640543
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6490094852595497
# test_score_W_combine_a 0.8614328186552631
# neuron unit number: 75
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.14984430251069722
# test_score_W0_a  0.15988042835940094
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6252124493901687
# all_train_score_W_combine_a 0.8465751241180656
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.6449079602123089
# test_score_W_combine_a 0.860634554922516
# neuron unit number: 80
# all_train_score_W0_p 0.877030162412993
# all_train_score_W0_n 0.06302647796584306
# all_train_score_W0_a 0.05711352326677609
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.10230415764343266
# test_score_W0_a  0.10844835808633528
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.5813506077247406
# all_train_score_W_combine_a 0.7758399967146375
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.7672696788692
# test_score_W_combine_a 0.9138627406427939
# neuron unit number: 85
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.024894155881908613
# all_train_score_W0_a 0.028068140033220484
# test_score_W0_p0.875
# test_score_W0_n 0.2106503834883598
# test_score_W0_a  0.2564047369302487
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5586797241157947
# all_train_score_W_combine_a 0.7639373395400746
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.64586409291609
# test_score_W_combine_a 0.83690652272899
# neuron unit number: 90
# all_train_score_W0_p 0.8793503480278422
# all_train_score_W0_n 0.08559840854166269
# all_train_score_W0_a 0.08400820038410543
# test_score_W0_p0.8858695652173914
# test_score_W0_n 0.309290376020645
# test_score_W0_a  0.37380716771378314
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5371774721333438
# all_train_score_W_combine_a 0.7536915794753597
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.7108154570042996
# test_score_W_combine_a 0.8902482713772017
# neuron unit number: 95
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.024894155881908613
# all_train_score_W0_a 0.028068140033220484
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9419953596287703
# all_train_score_W_combine_n 0.6251873269496738
# all_train_score_W_combine_a 0.85633056230913
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6971031478982016
# test_score_W_combine_a 0.8633536675026289
# neuron unit number: 100
# all_train_score_W0_p 0.877030162412993
# all_train_score_W0_n 0.06302647796584306
# all_train_score_W0_a 0.05711352326677609
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.05387219824228075
# test_score_W0_a  0.05538419259617253
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.588971889526215
# all_train_score_W_combine_a 0.8340636630406598
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.6340235827458005
# test_score_W_combine_a 0.8435266355869656
# test_score_W0_p mean 0.8641304347826088
# test_score_W_combine_p mean 0.9385869565217391
# test_score_W0_n mean 0.10717354956035144
# test_score_W_combine_n mean 0.6722947353355287
# test_score_W0_a mean 0.12093222277333167
# test_score_W_combine_a mean 0.8498730984737449
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.037052  0.029284  0.006548   0.023346  0.050757
# 1  train_W_combine  20.0  0.570649  0.045135  0.010092   0.549526  0.591773
# 2         combined  40.0  0.303850  0.272795  0.043133   0.216606  0.391095
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.5336
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -44.3535
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -14.0258
# 7                                Hedge's g =  -13.7471
# 8                           Glass's delta1 =  -18.2215
# 9                         Point-Biserial r =   -0.9905
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.107174  0.079398  0.017754   0.070014  0.144333
# 1  test_W_combine  20.0  0.672295  0.062173  0.013902   0.643197  0.701393
# 2        combined  40.0  0.389734  0.294690  0.046595   0.295488  0.483981
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.5651
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -25.0614
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -7.9251
# 7                              Hedge's g =   -7.7677
# 8                         Glass's delta1 =   -7.1176
# 9                       Point-Biserial r =   -0.9711
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.039158  0.030453  0.006809   0.024905  0.053410
# 1  train_W_combine  20.0  0.784767  0.045331  0.010136   0.763551  0.805982
# 2         combined  40.0  0.411962  0.379473  0.060000   0.290601  0.533323
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.7456
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -61.0596
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -19.3087
# 7                                Hedge's g =  -18.9251
# 8                           Glass's delta1 =  -24.4842
# 9                         Point-Biserial r =   -0.9949
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.120932  0.095318  0.021314   0.076322  0.165542
# 1  test_W_combine  20.0  0.849873  0.047444  0.010609   0.827669  0.872077
# 2        combined  40.0  0.485403  0.376520  0.059533   0.364986  0.605820
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.7289
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -30.6175
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -9.6821
# 7                              Hedge's g =   -9.4897
# 8                         Glass's delta1 =   -7.6475
# 9                       Point-Biserial r =   -0.9803
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.875638  0.002542  0.000568   0.874449  0.876828
# 1  train_W_combine  20.0  0.935615  0.005921  0.001324   0.932844  0.938386
# 2         combined  40.0  0.905626  0.030702  0.004854   0.895808  0.915445
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0600
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -41.6255
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -13.1631
# 7                                Hedge's g =  -12.9016
# 8                           Glass's delta1 =  -23.5977
# 9                         Point-Biserial r =   -0.9892
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.864130  0.008456  0.001891   0.860173  0.868088
# 1  test_W_combine  20.0  0.938587  0.011842  0.002648   0.933045  0.944129
# 2        combined  40.0  0.901359  0.039047  0.006174   0.888871  0.913846
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0745
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -22.8836
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -7.2364
# 7                              Hedge's g =   -7.0927
# 8                         Glass's delta1 =   -8.8048
# 9                       Point-Biserial r =   -0.9656

# %%
# new onehot encoding endoding hybrid
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.08104480893652764
# test_score_W0_a  0.10203030627917817
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.5852718747450386
# all_train_score_W_combine_a 0.7889915832309783
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.711931779931049
# test_score_W_combine_a 0.88486902272962
# neuron unit number: 10
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.18224092875310569
# test_score_W0_a  0.1706451942746862
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6239051200987648
# all_train_score_W_combine_a 0.8535353468461783
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6418122556466261
# test_score_W_combine_a 0.7990719161008885
# neuron unit number: 15
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.06822056303390608
# test_score_W0_a  0.05971339527283224
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.6003562533257313
# all_train_score_W_combine_a 0.8300821823489484
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6692412271928663
# test_score_W_combine_a 0.8007589697020565
# neuron unit number: 20
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.040107776711508454
# all_train_score_W0_a 0.050833357166431475
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.12201257536940247
# test_score_W0_a  0.11590153836635107
# all_train_score_W_combine_p 0.9489559164733179
# all_train_score_W_combine_n 0.6921112844205544
# all_train_score_W_combine_a 0.9166082340883417
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6007117099266903
# test_score_W_combine_a 0.7553219640658806
# neuron unit number: 25
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.6229945075188155
# all_train_score_W_combine_a 0.8671412236265869
# test_score_W_combine_p 0.9184782608695652
# test_score_W_combine_n 0.5283701964501164
# test_score_W_combine_a 0.6648796343796749
# neuron unit number: 30
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.027989309381764707
# all_train_score_W0_a 0.028123819052645074
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.11927617834732153
# test_score_W0_a  0.11546015121625938
# all_train_score_W_combine_p 0.9419953596287703
# all_train_score_W_combine_n 0.6197387344243634
# all_train_score_W_combine_a 0.8194200461119652
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.579425359709371
# test_score_W_combine_a 0.7379637041897016
# neuron unit number: 35
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.024361817144530236
# all_train_score_W0_a 0.027406302492329566
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.11488553187116103
# test_score_W0_a  0.11457737691607602
# all_train_score_W_combine_p 0.9489559164733179
# all_train_score_W_combine_n 0.6762475524518018
# all_train_score_W_combine_a 0.8554394241396143
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6493724322593126
# test_score_W_combine_a 0.8066561127546384
# neuron unit number: 40
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.024361817144530236
# all_train_score_W0_a 0.027406302492329566
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.11488553187116103
# test_score_W0_a  0.11457737691607602
# all_train_score_W_combine_p 0.9489559164733179
# all_train_score_W_combine_n 0.6904800106208329
# all_train_score_W_combine_a 0.8825956651938484
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6690251009636753
# test_score_W_combine_a 0.8277328647506941
# neuron unit number: 45
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.06822056303390608
# test_score_W0_a  0.05971339527283224
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6109070297632512
# all_train_score_W_combine_a 0.8017655608474095
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.5559581826806114
# test_score_W_combine_a 0.7251940258146319
# neuron unit number: 50
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.027989309381764707
# all_train_score_W0_a 0.028123819052645074
# test_score_W0_p0.875
# test_score_W0_n 0.16114588792262738
# test_score_W0_a  0.16791711716939325
# all_train_score_W_combine_p 0.9489559164733179
# all_train_score_W_combine_n 0.6614495842225125
# all_train_score_W_combine_a 0.8597157903965179
# test_score_W_combine_p 0.9239130434782609
# test_score_W_combine_n 0.5343676939939126
# test_score_W_combine_a 0.6725251267395097
# neuron unit number: 55
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.5998131275348325
# all_train_score_W_combine_a 0.8481604832817579
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.5982545825547717
# test_score_W_combine_a 0.7823187717397889
# neuron unit number: 60
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6547078887992925
# all_train_score_W_combine_a 0.8802511918570373
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6235305999461196
# test_score_W_combine_a 0.7492425798261236
# neuron unit number: 65
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.11488553187116103
# test_score_W0_a  0.11457737691607602
# all_train_score_W_combine_p 0.9466357308584686
# all_train_score_W_combine_n 0.6587768493255853
# all_train_score_W_combine_a 0.8686092904477661
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.6007970643501741
# test_score_W_combine_a 0.7827118166352356
# neuron unit number: 70
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6154176240356182
# all_train_score_W_combine_a 0.8580676203814206
# test_score_W_combine_p 0.9130434782608695
# test_score_W_combine_n 0.5036957611270297
# test_score_W_combine_a 0.6366502153385286
# neuron unit number: 75
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.06822056303390608
# test_score_W0_a  0.05971339527283224
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.6165412950440916
# all_train_score_W_combine_a 0.8406411360354226
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.6163654433592164
# test_score_W_combine_a 0.7834632434859858
# neuron unit number: 80
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.024361817144530236
# all_train_score_W0_a 0.027406302492329566
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_combine_p 0.9466357308584686
# all_train_score_W_combine_n 0.6755789814458292
# all_train_score_W_combine_a 0.9035363855972675
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.588311750588827
# test_score_W_combine_a 0.7753433567058331
# neuron unit number: 85
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.15087665680991771
# test_score_W0_a  0.16631435978003703
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.6001995501083882
# all_train_score_W_combine_a 0.8437141341886232
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.5690037830146479
# test_score_W_combine_a 0.7369438305472268
# neuron unit number: 90
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.06822056303390608
# test_score_W0_a  0.05971339527283224
# all_train_score_W_combine_p 0.9466357308584686
# all_train_score_W_combine_n 0.6707666157997703
# all_train_score_W_combine_a 0.8566956017411664
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.622331316103527
# test_score_W_combine_a 0.7980267919204992
# neuron unit number: 95
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.07937995751799674
# all_train_score_W0_a 0.16883236670327015
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.10472948906578634
# test_score_W0_a  0.11325321546580096
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5242941519433825
# all_train_score_W_combine_a 0.778211476334175
# test_score_W_combine_p 0.9184782608695652
# test_score_W_combine_n 0.518397839366174
# test_score_W_combine_a 0.722718079255161
# neuron unit number: 100
# all_train_score_W0_p 0.8700696055684455
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.06822056303390608
# test_score_W0_a  0.05971339527283224
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.6131837058776037
# all_train_score_W_combine_a 0.8402020043324149
# test_score_W_combine_p 0.9293478260869565
# test_score_W_combine_n 0.6565814191773188
# test_score_W_combine_a 0.8406015277232216
# test_score_W0_p mean 0.8660326086956521
# test_score_W_combine_p mean 0.9304347826086957
# test_score_W0_n mean 0.08035429679938513
# test_score_W_combine_n mean 0.6018742749171018
# test_score_W0_a mean 0.07969104948320477
# test_score_W_combine_a mean 0.764149677720245
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.012428  0.020734  0.004636   0.002724  0.022131
# 1  train_W_combine  20.0  0.630637  0.041611  0.009305   0.611162  0.650112
# 2         combined  40.0  0.321532  0.314720  0.049762   0.220880  0.422185
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.6182
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -59.4680
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -18.8054
# 7                                Hedge's g =  -18.4318
# 8                           Glass's delta1 =  -29.8160
# 9                         Point-Biserial r =   -0.9947
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.080354  0.057273  0.012807   0.053550  0.107159
# 1  test_W_combine  20.0  0.601874  0.055989  0.012520   0.575670  0.628078
# 2        combined  40.0  0.341114  0.269934  0.042680   0.254785  0.427443
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.5215
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -29.1197
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -9.2085
# 7                              Hedge's g =   -9.0255
# 8                         Glass's delta1 =   -9.1058
# 9                       Point-Biserial r =   -0.9783
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.017907  0.038737  0.008662  -0.000223  0.036036
# 1  train_W_combine  20.0  0.849669  0.034736  0.007767   0.833412  0.865926
# 2         combined  40.0  0.433788  0.422742  0.066841   0.298588  0.568987
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.8318
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -71.4921
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -22.6078
# 7                                Hedge's g =  -22.1586
# 8                           Glass's delta1 =  -21.4720
# 9                         Point-Biserial r =   -0.9963
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.079691  0.058569  0.013096   0.052280  0.107102
# 1  test_W_combine  20.0  0.764150  0.060963  0.013632   0.735618  0.792681
# 2        combined  40.0  0.421920  0.351576  0.055589   0.309481  0.534360
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6845
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -36.2080
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =  -11.4500
# 7                              Hedge's g =  -11.2225
# 8                         Glass's delta1 =  -11.6864
# 9                       Point-Biserial r =   -0.9858
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.870998  0.001388  0.000310   0.870348  0.871647
# 1  train_W_combine  20.0  0.939675  0.006981  0.001561   0.936408  0.942942
# 2         combined  40.0  0.905336  0.035129  0.005554   0.894102  0.916571
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0687
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -43.1519
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -13.6458
# 7                                Hedge's g =  -13.3747
# 8                           Glass's delta1 =  -49.4782
# 9                         Point-Biserial r =   -0.9899
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.866033  0.005652  0.001264   0.863387  0.868678
# 1  test_W_combine  20.0  0.930435  0.008383  0.001874   0.926512  0.934358
# 2        combined  40.0  0.898234  0.033366  0.005276   0.887563  0.908905
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0644
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -28.4880
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -9.0087
# 7                              Hedge's g =   -8.8297
# 8                         Glass's delta1 =  -11.3943
# 9                       Point-Biserial r =   -0.9774

# %%
# new hash endoding hybrid
import experiment
unstable_repeat_num= 30
scope_num = 100
class_num = 5
best_num = 48
interval = 5




experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 5
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.130317969657864
# test_score_W0_a  0.15790102419180926
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5342787871473063
# all_train_score_W_combine_a 0.783048984607466
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.6803443301250482
# test_score_W_combine_a 0.8327189966768972
# neuron unit number: 10
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.026477311787645647
# all_train_score_W0_a 0.028398387767640917
# test_score_W0_p0.875
# test_score_W0_n 0.20863194321965453
# test_score_W0_a  0.2533636357944692
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.5379509569935844
# all_train_score_W_combine_a 0.7902639303635407
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6581028931450802
# test_score_W_combine_a 0.7754265273063531
# neuron unit number: 15
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.17458292212389528
# test_score_W0_a  0.20758114089649507
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6071369176096778
# all_train_score_W_combine_a 0.8678232305059932
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.5886003881192944
# test_score_W_combine_a 0.7713209107078501
# neuron unit number: 20
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.05402620919072641
# all_train_score_W0_a 0.0574291176390714
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.130317969657864
# test_score_W0_a  0.15790102419180926
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5667570130579312
# all_train_score_W_combine_a 0.7882806888226503
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6703035842643031
# test_score_W_combine_a 0.8397733189248259
# neuron unit number: 25
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.130317969657864
# test_score_W0_a  0.15790102419180926
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.5878536218336696
# all_train_score_W_combine_a 0.8353381425881657
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6618340294261704
# test_score_W_combine_a 0.8056758320268185
# neuron unit number: 30
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.23430903202870776
# test_score_W0_a  0.25730696138181536
# all_train_score_W_combine_p 0.9419953596287703
# all_train_score_W_combine_n 0.6102095022043938
# all_train_score_W_combine_a 0.8338295401880617
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7444777574958539
# test_score_W_combine_a 0.8641417378809656
# neuron unit number: 35
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.027480876424520767
# all_train_score_W0_a 0.028580386758412176
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.04547797348511291
# test_score_W0_a  0.05326770263953677
# all_train_score_W_combine_p 0.951276102088167
# all_train_score_W_combine_n 0.7131520932286445
# all_train_score_W_combine_a 0.9062552965254387
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7439384691722005
# test_score_W_combine_a 0.8889280735399787
# neuron unit number: 40
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.03980924152538867
# all_train_score_W0_a 0.029672380703039722
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.1751326060661847
# test_score_W0_a  0.2808668701562109
# all_train_score_W_combine_p 0.9373549883990719
# all_train_score_W_combine_n 0.6050076060485857
# all_train_score_W_combine_a 0.8457641342896479
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6507229997642298
# test_score_W_combine_a 0.8017667794138287
# neuron unit number: 45
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.05453136363354406
# all_train_score_W0_a 0.057519186524151285
# test_score_W0_p0.875
# test_score_W0_n 0.214541116799402
# test_score_W0_a  0.32470545557715563
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5719199216775088
# all_train_score_W_combine_a 0.8004488588300067
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7864592713478603
# test_score_W_combine_a 0.9140021436683623
# neuron unit number: 50
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.041505060744798206
# all_train_score_W0_a 0.056258222133032984
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.04547797348511291
# test_score_W0_a  0.05326770263953677
# all_train_score_W_combine_p 0.9280742459396751
# all_train_score_W_combine_n 0.5526805362707515
# all_train_score_W_combine_a 0.7908529865624505
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.7317937447521469
# test_score_W_combine_a 0.8386101254638751
# neuron unit number: 55
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.875
# test_score_W0_n 0.21158557945295242
# test_score_W0_a  0.2536292516995245
# all_train_score_W_combine_p 0.9234338747099768
# all_train_score_W_combine_n 0.4837416704155004
# all_train_score_W_combine_a 0.7614171113548355
# test_score_W_combine_p 0.9184782608695652
# test_score_W_combine_n 0.5123437070779069
# test_score_W_combine_a 0.6793744644829083
# neuron unit number: 60
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.18836318862992088
# test_score_W0_a  0.2529550796444251
# all_train_score_W_combine_p 0.925754060324826
# all_train_score_W_combine_n 0.5473281239627559
# all_train_score_W_combine_a 0.8031460014615311
# test_score_W_combine_p 0.9456521739130435
# test_score_W_combine_n 0.6779060672615825
# test_score_W_combine_a 0.8135091785920383
# neuron unit number: 65
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.04547797348511291
# test_score_W0_a  0.05326770263953677
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5868648940057404
# all_train_score_W_combine_a 0.8260083138699309
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.5920678899424376
# test_score_W_combine_a 0.7443583100344343
# neuron unit number: 70
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8695652173913043
# test_score_W0_n 0.17458292212389528
# test_score_W0_a  0.20758114089649507
# all_train_score_W_combine_p 0.9303944315545244
# all_train_score_W_combine_n 0.5627469289073395
# all_train_score_W_combine_a 0.823633573373252
# test_score_W_combine_p 0.9510869565217391
# test_score_W_combine_n 0.7207238295815036
# test_score_W_combine_a 0.8366796198797211
# neuron unit number: 75
# all_train_score_W0_p 0.8747099767981439
# all_train_score_W0_n 0.05453136363354406
# all_train_score_W0_a 0.057519186524151285
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.130317969657864
# test_score_W0_a  0.15790102419180926
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5550961575573164
# all_train_score_W_combine_a 0.803144209690877
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6288629962469698
# test_score_W_combine_a 0.8329894705273625
# neuron unit number: 80
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.09829474622491935
# test_score_W0_a  0.10727678484851168
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.5672544521099967
# all_train_score_W_combine_a 0.8169881093215792
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7541663396228684
# test_score_W_combine_a 0.8887288728812281
# neuron unit number: 85
# all_train_score_W0_p 0.877030162412993
# all_train_score_W0_n 0.05422188181823394
# all_train_score_W0_a 0.056618497673352496
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.2297796410995556
# test_score_W0_a  0.2539050263043523
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5891631806209165
# all_train_score_W_combine_a 0.8343948495000999
# test_score_W_combine_p 0.9402173913043478
# test_score_W_combine_n 0.6130817783900251
# test_score_W_combine_a 0.7815403250799068
# neuron unit number: 90
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8586956521739131
# test_score_W0_n 0.04547797348511291
# test_score_W0_a  0.05326770263953677
# all_train_score_W_combine_p 0.9327146171693735
# all_train_score_W_combine_n 0.5600132276319081
# all_train_score_W_combine_a 0.8221659295299933
# test_score_W_combine_p 0.9347826086956522
# test_score_W_combine_n 0.614957186508367
# test_score_W_combine_a 0.8008542865250519
# neuron unit number: 95
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8804347826086957
# test_score_W0_n 0.2297796410995556
# test_score_W0_a  0.2539050263043523
# all_train_score_W_combine_p 0.9187935034802784
# all_train_score_W_combine_n 0.48153549668120604
# all_train_score_W_combine_a 0.7325973378998665
# test_score_W_combine_p 0.9130434782608695
# test_score_W_combine_n 0.4841018789213223
# test_score_W_combine_a 0.6846868472712363
# neuron unit number: 100
# all_train_score_W0_p 0.8723897911832946
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.8641304347826086
# test_score_W0_n 0.130317969657864
# test_score_W0_a  0.15790102419180926
# all_train_score_W_combine_p 0.9350348027842227
# all_train_score_W_combine_n 0.5902425665732385
# all_train_score_W_combine_a 0.8363269197224996
# test_score_W_combine_p 0.9565217391304348
# test_score_W_combine_n 0.7252927609232165
# test_score_W_combine_a 0.8856602075720296
# test_score_W0_p mean 0.8679347826086957
# test_score_W_combine_p mean 0.94375
# test_score_W0_n mean 0.14865425405492072
# test_score_W_combine_n mean 0.6620040951044194
# test_score_W0_a mean 0.18278261525105002
# test_score_W_combine_a mean 0.8140373014227835
# NMI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.017629  0.023344  0.005220   0.006704  0.028555
# 1  train_W_combine  20.0  0.570547  0.048595  0.010866   0.547804  0.593290
# 2         combined  40.0  0.294088  0.282498  0.044667   0.203741  0.384435
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.5529
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -45.8665
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -14.5043
# 7                                Hedge's g =  -14.2161
# 8                           Glass's delta1 =  -23.6854
# 9                         Point-Biserial r =   -0.9911
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.148654  0.066022  0.014763   0.117755  0.179554
# 1  test_W_combine  20.0  0.662004  0.079688  0.017819   0.624709  0.699299
# 2        combined  40.0  0.405329  0.269794  0.042658   0.319045  0.491613
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.5133
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -22.1846
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -7.0154
# 7                              Hedge's g =   -6.8760
# 8                         Glass's delta1 =   -7.7754
# 9                       Point-Biserial r =   -0.9635
# ARI T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.018600  0.024995  0.005589   0.006902  0.030298
# 1  train_W_combine  20.0  0.815086  0.037696  0.008429   0.797444  0.832728
# 2         combined  40.0  0.416843  0.404550  0.063965   0.287462  0.546225
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.7965
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -78.7537
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -24.9041
# 7                                Hedge's g =  -24.4093
# 8                           Glass's delta1 =  -31.8657
# 9                         Point-Biserial r =   -0.9970
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.182783  0.085064  0.019021   0.142971  0.222594
# 1  test_W_combine  20.0  0.814037  0.063160  0.014123   0.784477  0.843597
# 2        combined  40.0  0.498410  0.328091  0.051876   0.393481  0.603339
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.6313
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -26.6456
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -8.4261
# 7                              Hedge's g =   -8.2587
# 8                         Glass's delta1 =   -7.4209
# 9                       Point-Biserial r =   -0.9743
# Purity T-Test
#           Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         train_W0  20.0  0.873434  0.001403  0.000314   0.872777  0.874091
# 1  train_W_combine  20.0  0.932831  0.006753  0.001510   0.929670  0.935991
# 2         combined  40.0  0.903132  0.030460  0.004816   0.893391  0.912874
#                            Independent t-test  results
# 0  Difference (train_W0 - train_W_combine) =   -0.0594
# 1                       Degrees of freedom =   38.0000
# 2                                        t =  -38.5129
# 3                    Two side test p value =    0.0000
# 4                   Difference < 0 p value =    0.0000
# 5                   Difference > 0 p value =    1.0000
# 6                                Cohen's d =  -12.1789
# 7                                Hedge's g =  -11.9369
# 8                           Glass's delta1 =  -42.3277
# 9                         Point-Biserial r =   -0.9874
#          Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0         test_W0  20.0  0.867935  0.007075  0.001582   0.864624  0.871246
# 1  test_W_combine  20.0  0.943750  0.012251  0.002739   0.938016  0.949484
# 2        combined  40.0  0.905842  0.039640  0.006268   0.893165  0.918520
#                          Independent t-test  results
# 0  Difference (test_W0 - test_W_combine) =   -0.0758
# 1                     Degrees of freedom =   38.0000
# 2                                      t =  -23.9658
# 3                  Two side test p value =    0.0000
# 4                 Difference < 0 p value =    0.0000
# 5                 Difference > 0 p value =    1.0000
# 6                              Cohen's d =   -7.5787
# 7                              Hedge's g =   -7.4281
# 8                         Glass's delta1 =  -10.7158
# 9                       Point-Biserial r =   -0.9685
