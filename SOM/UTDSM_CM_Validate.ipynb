# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import UTDSM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv_training = pd.read_csv("Crowdsourced Mapping/training.csv")
csv_test = pd.read_csv("Crowdsourced Mapping/testing.csv")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_training,"class")
dataread.stringToIntCrowdsourcedMappingDataSet(csv_test,"class")
dataread.initializedataset_CM(csv_training,csv_test)

# %%
import experiment
unstable_repeat_num= 1
scope_num = 36
class_num = 6
dim_num = 28
best_num =  21
elbow_num = 1
row = 7
column  = 4
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )    


experiment = experiment.Experiment()
experiment.UTtest(dataread,total_label_train,class_num, dim_num,best_num, scope_num,unstable_repeat_num,0,elbow_num ,row,column)
print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# neuron unit number: 6
# all_train_score_W0_n 0.2368738767444618
# all_train_score_W0_a 0.3939598907725655
# test_score_W0_n 0.15216712384066516
# test_score_W0_a  0.11837678750960826
# all_train_score_W_Combined_n 0.46171076627295116
# all_train_score_W_Combined_a 0.6809596529050074
# test_score_W_combined_n 0.3100561674259774
# test_score_W_combined_a 0.220487912589317
# Combine Neurons Number :366
# neuron unit number: 7
# all_train_score_W0_n 0.26145852934857367
# all_train_score_W0_a 0.2659978085629346
# test_score_W0_n 0.29358259056904007
# test_score_W0_a  0.13548753774251493
# all_train_score_W_Combined_n 0.5310402392256914
# all_train_score_W_Combined_a 0.7186216010403359
# test_score_W_combined_n 0.393305474129602
# test_score_W_combined_a 0.2702447412075225
# Combine Neurons Number :350
# neuron unit number: 8
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_Combined_n 0.5390365722113833
# all_train_score_W_Combined_a 0.7285549888868625
# test_score_W_combined_n 0.3575233484487287
# test_score_W_combined_a 0.2632850132551093
# Combine Neurons Number :491
# neuron unit number: 9
# all_train_score_W0_n 0.3145652039074325
# all_train_score_W0_a 0.33066168198335655
# test_score_W0_n 0.31445094988343364
# test_score_W0_a  0.16764874062579627
# all_train_score_W_Combined_n 0.4773199234998619
# all_train_score_W_Combined_a 0.6661516123810478
# test_score_W_combined_n 0.31961869528135534
# test_score_W_combined_a 0.22795318151613747
# Combine Neurons Number :353
# neuron unit number: 10
# all_train_score_W0_n 0.3459255209321387
# all_train_score_W0_a 0.4930682830788595
# test_score_W0_n 0.3463792490374493
# test_score_W0_a  0.2189516986768478
# all_train_score_W_Combined_n 0.5704892250542433
# all_train_score_W_Combined_a 0.7548956117099085
# test_score_W_combined_n 0.3755613546507138
# test_score_W_combined_a 0.28412988781520343
# Combine Neurons Number :640
# neuron unit number: 11
# all_train_score_W0_n 0.20997204221837887
# all_train_score_W0_a 0.3511634594448436
# test_score_W0_n 0.23870030144641774
# test_score_W0_a  0.17499007884262385
# all_train_score_W_Combined_n 0.5410056845043437
# all_train_score_W_Combined_a 0.7396700980822315
# test_score_W_combined_n 0.38352427870331063
# test_score_W_combined_a 0.28195889628809856
# Combine Neurons Number :507
# neuron unit number: 12
# all_train_score_W0_n 0.3339463115614962
# all_train_score_W0_a 0.46574575529970813
# test_score_W0_n 0.34948081241682094
# test_score_W0_a  0.20838459255373976
# all_train_score_W_Combined_n 0.557033236564181
# all_train_score_W_Combined_a 0.7637665099426713
# test_score_W_combined_n 0.41424457644328855
# test_score_W_combined_a 0.31435651722730545
# Combine Neurons Number :662
# neuron unit number: 13
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_n 0.0
# test_score_W0_a  0.0
# all_train_score_W_Combined_n 0.46064239903684345
# all_train_score_W_Combined_a 0.6562891061764851
# test_score_W_combined_n 0.31726856864676234
# test_score_W_combined_a 0.23156562516762877
# Combine Neurons Number :389
# neuron unit number: 14
# all_train_score_W0_n 0.40395991576967366
# all_train_score_W0_a 0.5998565232233758
# test_score_W0_n 0.3498284457330415
# test_score_W0_a  0.23683857728381358
# all_train_score_W_Combined_n 0.5930176161564157
# all_train_score_W_Combined_a 0.7709884394247531
# test_score_W_combined_n 0.4017118722397765
# test_score_W_combined_a 0.282730551285335
# Combine Neurons Number :810
# neuron unit number: 15
# all_train_score_W0_n 0.28689677179170037
# all_train_score_W0_a 0.4411489731255739
# test_score_W0_n 0.2614850222698175
# test_score_W0_a  0.15728952626196152
# all_train_score_W_Combined_n 0.5142236811296412
# all_train_score_W_Combined_a 0.7135951585056457
# test_score_W_combined_n 0.3786183925995226
# test_score_W_combined_a 0.2618188357824572
# Combine Neurons Number :478
# neuron unit number: 16
# all_train_score_W0_n 0.38928761035012976
# all_train_score_W0_a 0.5766005558249773
# test_score_W0_n 0.33947235063332243
# test_score_W0_a  0.2175762171187228
# all_train_score_W_Combined_n 0.6243056609958751
# all_train_score_W_Combined_a 0.8022849313691655
# test_score_W_combined_n 0.364108008153556
# test_score_W_combined_a 0.2607019490636526
# Combine Neurons Number :956
# neuron unit number: 17
# all_train_score_W0_n 0.3431991149352961
# all_train_score_W0_a 0.4820851667650644
# test_score_W0_n 0.3048415483653815
# test_score_W0_a  0.1881617539381445
# all_train_score_W_Combined_n 0.5270639889402567
# all_train_score_W_Combined_a 0.734345634783388
# test_score_W_combined_n 0.35114330627523055
# test_score_W_combined_a 0.2425249222339262
# Combine Neurons Number :491
# neuron unit number: 18
# all_train_score_W0_n 0.4334826480400422
# all_train_score_W0_a 0.6185951774788709
# test_score_W0_n 0.3572855571813645
# test_score_W0_a  0.23072705494604026
# all_train_score_W_Combined_n 0.6231632903899519
# all_train_score_W_Combined_a 0.7913651126849693
# test_score_W_combined_n 0.3621738379634456
# test_score_W_combined_a 0.27190368449422864
# Combine Neurons Number :993
# neuron unit number: 19
# all_train_score_W0_n 0.3193452483608548
# all_train_score_W0_a 0.4751658535831833
# test_score_W0_n 0.32138120541955795
# test_score_W0_a  0.20404043939738756
# all_train_score_W_Combined_n 0.48388833060637204
# all_train_score_W_Combined_a 0.6436792435336669
# test_score_W_combined_n 0.3632974059608704
# test_score_W_combined_a 0.25877937525711564
# Combine Neurons Number :550
# neuron unit number: 20
# all_train_score_W0_n 0.41436631631752635
# all_train_score_W0_a 0.582848667122763
# test_score_W0_n 0.32878848138256817
# test_score_W0_a  0.2046099888379108
# all_train_score_W_Combined_n 0.6691446224686322
# all_train_score_W_Combined_a 0.8255920807262437
# test_score_W_combined_n 0.4266334411360434
# test_score_W_combined_a 0.3314606072230117
# Combine Neurons Number :1169
# neuron unit number: 21
# all_train_score_W0_n 0.3222995817890052
# all_train_score_W0_a 0.45931628804682556
# test_score_W0_n 0.36053037310130037
# test_score_W0_a  0.21656504775055044
# all_train_score_W_Combined_n 0.5648785351957389
# all_train_score_W_Combined_a 0.7320873284015641
# test_score_W_combined_n 0.3739882608669155
# test_score_W_combined_a 0.25525284052091657
# Combine Neurons Number :632
# neuron unit number: 22
# all_train_score_W0_n 0.4526503398149569
# all_train_score_W0_a 0.6271864554266966
# test_score_W0_n 0.3044959556976507
# test_score_W0_a  0.21671815277882384
# all_train_score_W_Combined_n 0.6871619346045116
# all_train_score_W_Combined_a 0.8540583901935148
# test_score_W_combined_n 0.3847488902129239
# test_score_W_combined_a 0.2876255741960122
# Combine Neurons Number :1305
# neuron unit number: 23
# all_train_score_W0_n 0.3983156986359213
# all_train_score_W0_a 0.5436472827396149
# test_score_W0_n 0.32433950417711166
# test_score_W0_a  0.1902975591722315
# all_train_score_W_Combined_n 0.5362646927713562
# all_train_score_W_Combined_a 0.737953894372863
# test_score_W_combined_n 0.3947981163542788
# test_score_W_combined_a 0.27036565214448666
# Combine Neurons Number :638
# neuron unit number: 24
# all_train_score_W0_n 0.4520744704478753
# all_train_score_W0_a 0.6634997584089551
# test_score_W0_n 0.32337067824837895
# test_score_W0_a  0.24376079145327942
# all_train_score_W_Combined_n 0.6634396056420544
# all_train_score_W_Combined_a 0.8328588573356418
# test_score_W_combined_n 0.4094414143537562
# test_score_W_combined_a 0.3127789297866379
# Combine Neurons Number :1347
# neuron unit number: 25
# all_train_score_W0_n 0.3192732844171313
# all_train_score_W0_a 0.42873575285711496
# test_score_W0_n 0.3686010924658766
# test_score_W0_a  0.22437339855446098
# all_train_score_W_Combined_n 0.5830732377083079
# all_train_score_W_Combined_a 0.76891719240679
# test_score_W_combined_n 0.40268334212880214
# test_score_W_combined_a 0.2982977506269757
# Combine Neurons Number :588
# neuron unit number: 26
# all_train_score_W0_n 0.5034374674760325
# all_train_score_W0_a 0.7065080759008023
# test_score_W0_n 0.39740709795843265
# test_score_W0_a  0.2878093990872083
# all_train_score_W_Combined_n 0.6907535902753298
# all_train_score_W_Combined_a 0.8471995792724829
# test_score_W_combined_n 0.40161353305519504
# test_score_W_combined_a 0.30502618502532086
# Combine Neurons Number :1412
# neuron unit number: 27
# all_train_score_W0_n 0.28974943656616975
# all_train_score_W0_a 0.32248493390438776
# test_score_W0_n 0.317673536177014
# test_score_W0_a  0.14183601079689295
# all_train_score_W_Combined_n 0.5365193106589623
# all_train_score_W_Combined_a 0.7286287077362538
# test_score_W_combined_n 0.3926041934445351
# test_score_W_combined_a 0.28189693563035456
# Combine Neurons Number :615
# neuron unit number: 28
# all_train_score_W0_n 0.5073460094865979
# all_train_score_W0_a 0.7174693889700451
# test_score_W0_n 0.3618661178853555
# test_score_W0_a  0.27372722918564196
# all_train_score_W_Combined_n 0.6892870607175362
# all_train_score_W_Combined_a 0.8439906588003379
# test_score_W_combined_n 0.4148761609624381
# test_score_W_combined_a 0.3062492848527446
# Combine Neurons Number :1563
# neuron unit number: 29
# all_train_score_W0_n 0.3641887545272431
# all_train_score_W0_a 0.5611470917185004
# test_score_W0_n 0.3307471908785787
# test_score_W0_a  0.22361715044112782
# all_train_score_W_Combined_n 0.5658351654072885
# all_train_score_W_Combined_a 0.7510771611932188
# test_score_W_combined_n 0.35962998368026494
# test_score_W_combined_a 0.25899211369807074
# Combine Neurons Number :676
# neuron unit number: 30
# all_train_score_W0_n 0.5179588091203234
# all_train_score_W0_a 0.7161876542451804
# test_score_W0_n 0.33961063148720655
# test_score_W0_a  0.21630962746521482
# all_train_score_W_Combined_n 0.72262890319847
# all_train_score_W_Combined_a 0.8783167411031844
# test_score_W_combined_n 0.39140978798911635
# test_score_W_combined_a 0.29068292311592864
# Combine Neurons Number :1619
# neuron unit number: 31
# all_train_score_W0_n 0.33923830023523865
# all_train_score_W0_a 0.5096395995259331
# test_score_W0_n 0.2922671330687972
# test_score_W0_a  0.19878279148720182
# all_train_score_W_Combined_n 0.5380728557813177
# all_train_score_W_Combined_a 0.7199730348684749
# test_score_W_combined_n 0.34250573180707294
# test_score_W_combined_a 0.2408320769786277
# Combine Neurons Number :686
# neuron unit number: 32
# all_train_score_W0_n 0.5453898658410832
# all_train_score_W0_a 0.7323331139633399
# test_score_W0_n 0.430560013495561
# test_score_W0_a  0.29400269211344326
# all_train_score_W_Combined_n 0.7330798711828261
# all_train_score_W_Combined_a 0.8766782553068962
# test_score_W_combined_n 0.41151067063053415
# test_score_W_combined_a 0.3037783104704852
# Not good nmi result !!!!!
# Combine Neurons Number :1751
# neuron unit number: 33
# all_train_score_W0_n 0.36326026794408534
# all_train_score_W0_a 0.4865473155926306
# test_score_W0_n 0.3612290246892443
# test_score_W0_a  0.2010252761743281
# all_train_score_W_Combined_n 0.5681575767837781
# all_train_score_W_Combined_a 0.7723122101945518
# test_score_W_combined_n 0.3020775863732334
# test_score_W_combined_a 0.2324203377641219
# Not good nmi result !!!!!
# Combine Neurons Number :717
# neuron unit number: 34
# all_train_score_W0_n 0.5464028777261255
# all_train_score_W0_a 0.746928006267014
# test_score_W0_n 0.3904773145071147
# test_score_W0_a  0.2716664049209858
# all_train_score_W_Combined_n 0.7178772734242072
# all_train_score_W_Combined_a 0.8724603706381668
# test_score_W_combined_n 0.38166211780126486
# test_score_W_combined_a 0.27837912392930875
# Not good nmi result !!!!!
# Combine Neurons Number :1837
# neuron unit number: 35
# all_train_score_W0_n 0.32511263856596323
# all_train_score_W0_a 0.4717094655877028
# test_score_W0_n 0.3681076478870249
# test_score_W0_a  0.19865017322897743
# all_train_score_W_Combined_n 0.5936656837676894
# all_train_score_W_Combined_a 0.7753032649803278
# test_score_W_combined_n 0.4427059147225996
# test_score_W_combined_a 0.3435504032342917
# Combine Neurons Number :713
# neuron unit number: 36
# all_train_score_W0_n 0.5774304008903087
# all_train_score_W0_a 0.7644616382996244
# test_score_W0_n 0.3895127276198307
# test_score_W0_a  0.3040187107000866
# all_train_score_W_Combined_n 0.7382895662070789
# all_train_score_W_Combined_a 0.8807123572052276
# test_score_W_combined_n 0.3466743675383328
# test_score_W_combined_a 0.24198402988266898
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :1957
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.310279  0.097411  0.017495   0.274548  0.346009
# 1  test_score_W'  31.0  0.376507  0.034581  0.006211   0.363823  0.389191
# 2       combined  62.0  0.343393  0.079808  0.010136   0.323126  0.363660
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0662
# 1                          Degrees of freedom =   60.0000
# 2                                           t =   -3.5673
# 3                       Two side test p value =    0.0007
# 4                      Difference < 0 p value =    0.0004
# 5                      Difference > 0 p value =    0.9996
# 6                                   Cohen's d =   -0.9061
# 7                                   Hedge's g =   -0.8947
# 8                               Glass's delta =   -0.6799
# 9                                 Pearson's r =    0.4183
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  31.0  0.310279  0.097411  0.017495   0.274548  0.346009
# 1  test_score_W'  31.0  0.274581  0.030788  0.005530   0.263288  0.285874
# 2       combined  62.0  0.292430  0.073869  0.009381   0.273671  0.311189
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0357
# 1                          Degrees of freedom =   60.0000
# 2                                           t =    1.9455
# 3                       Two side test p value =    0.0564
# 4                      Difference < 0 p value =    0.9718
# 5                      Difference > 0 p value =    0.0282
# 6                                   Cohen's d =    0.4942
# 7                                   Hedge's g =    0.4880
# 8                               Glass's delta =    0.3665
# 9                                 Pearson's r =    0.2436
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.3370613919209242
# all_train_score_W0_a 0.46590238962402664
# test_score_W0_n 0.25923811054099893
# test_score_W0_a  0.14971982332624478
# all_train_score_W_Combined_n 0.5637118540299682
# all_train_score_W_Combined_a 0.7511138565906808
# test_score_W_combined_n 0.38383153038369183
# test_score_W_combined_a 0.2750255913682183
# Combine Neurons Number :600
# NMI T-Test
#         Variable    N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  1.0  0.259238       NaN       NaN        NaN       NaN
# 1  test_score_W'  1.0  0.383832       NaN       NaN        NaN       NaN
# 2       combined  2.0  0.321535  0.088101  0.062297   -0.47002   1.11309
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.1246
# 1                          Degrees of freedom =    0.0000
# 2                                           t =       NaN
# 3                       Two side test p value =       NaN
# 4                      Difference < 0 p value =       NaN
# 5                      Difference > 0 p value =       NaN
# 6                                   Cohen's d =       NaN
# 7                                   Hedge's g =       NaN
# 8                               Glass's delta =       NaN
# 9                                 Pearson's r =       NaN
# ARI T-Test
#         Variable    N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  1.0  0.259238       NaN       NaN        NaN       NaN
# 1  test_score_W'  1.0  0.275026       NaN       NaN        NaN       NaN
# 2       combined  2.0  0.267132  0.011163  0.007894   0.166832  0.367431
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0158
# 1                          Degrees of freedom =    0.0000
# 2                                           t =       NaN
# 3                       Two side test p value =       NaN
# 4                      Difference < 0 p value =       NaN
# 5                      Difference > 0 p value =       NaN
# 6                                   Cohen's d =       NaN
# 7                                   Hedge's g =       NaN
# 8                               Glass's delta =       NaN
# 9                                 Pearson's r =       NaN
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:262: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\fooli\anaconda3\lib\site-packages\numpy\core\_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import experiment
unstable_repeat_num= 30
scope_num = 36
class_num = 6
dim_num = 28
best_num =  21
elbow_num = 1
row = 7
column  = 4
total_label_train = []

for i in range(0,len(dataread.data_train)):
    total_label_train.append(i)


#som = newSom.SOM(m= class_num, n=  1, dim=dim_num)  
#optimize_W = UTDSM.UTDSM_SOM(som,dataread.data_train,dataread.data_test,dataread.label_train,dataread.label_test,class_num,row,column)
#optimize_W.run( )    

experiment = experiment.Experiment()

print("*****************************************************************************************")
print("Best Number SOM Comparision")
print("*****************************************************************************************")
experiment.UTtest(dataread,total_label_train,class_num, dim_num, best_num,scope_num,unstable_repeat_num,1,elbow_num,row,column)
# Out:
# *****************************************************************************************
# Best Number SOM Comparision
# *****************************************************************************************
# all_train_score_W0_n 0.3185431438358957
# all_train_score_W0_a 0.4301009302027667
# test_score_W0_n 0.31861218508920064
# test_score_W0_a  0.17578544007743152
# all_train_score_W_Combined_n 0.5374584122793471
# all_train_score_W_Combined_a 0.7136292266645575
# test_score_W_combined_n 0.38741405492597786
# test_score_W_combined_a 0.2761994533936461
# Combine Neurons Number :627
# all_train_score_W0_n 0.3184591286837574
# all_train_score_W0_a 0.5114342097511748
# test_score_W0_n 0.2976856605179966
# test_score_W0_a  0.21992379477165244
# all_train_score_W_Combined_n 0.5490386685546824
# all_train_score_W_Combined_a 0.7444557862671398
# test_score_W_combined_n 0.3560449819661483
# test_score_W_combined_a 0.2759412062222895
# Combine Neurons Number :555
# all_train_score_W0_n 0.3392846397460245
# all_train_score_W0_a 0.4647553874739923
# test_score_W0_n 0.34222913219705364
# test_score_W0_a  0.2227671707694069
# all_train_score_W_Combined_n 0.5852422800564715
# all_train_score_W_Combined_a 0.7558812597445941
# test_score_W_combined_n 0.3834058976040032
# test_score_W_combined_a 0.26941056716374334
# Combine Neurons Number :608
# all_train_score_W0_n 0.25003768278576893
# all_train_score_W0_a 0.2583374013011703
# test_score_W0_n 0.30451664979410076
# test_score_W0_a  0.13329842998893557
# all_train_score_W_Combined_n 0.5337028378496783
# all_train_score_W_Combined_a 0.7122628246261934
# test_score_W_combined_n 0.39010015749670707
# test_score_W_combined_a 0.26590699359511866
# Combine Neurons Number :559
# all_train_score_W0_n 0.2914757244994545
# all_train_score_W0_a 0.43618960419904534
# test_score_W0_n 0.3662732158880722
# test_score_W0_a  0.22353117027714695
# all_train_score_W_Combined_n 0.5306510476666778
# all_train_score_W_Combined_a 0.7173458935878019
# test_score_W_combined_n 0.42379013306350366
# test_score_W_combined_a 0.32549095865577204
# Combine Neurons Number :581
# all_train_score_W0_n 0.3456451165444317
# all_train_score_W0_a 0.5034825485374552
# test_score_W0_n 0.2536383803199062
# test_score_W0_a  0.15572303276865632
# all_train_score_W_Combined_n 0.564932587994132
# all_train_score_W_Combined_a 0.7653886952221789
# test_score_W_combined_n 0.3788625576826897
# test_score_W_combined_a 0.27865038937452385
# Combine Neurons Number :603
# all_train_score_W0_n 0.27271263683413954
# all_train_score_W0_a 0.382418154238042
# test_score_W0_n 0.2520257153891879
# test_score_W0_a  0.14151628999083754
# all_train_score_W_Combined_n 0.5523233997881851
# all_train_score_W_Combined_a 0.7617594413576453
# test_score_W_combined_n 0.3212697208156251
# test_score_W_combined_a 0.22339902004452133
# Combine Neurons Number :540
# all_train_score_W0_n 0.2509836488171853
# all_train_score_W0_a 0.39848812184470905
# test_score_W0_n 0.2747371861872263
# test_score_W0_a  0.18629112329049335
# all_train_score_W_Combined_n 0.5334485027346078
# all_train_score_W_Combined_a 0.7499894219555095
# test_score_W_combined_n 0.3022049065622904
# test_score_W_combined_a 0.21038257596626242
# Combine Neurons Number :532
# all_train_score_W0_n 0.2852201253591685
# all_train_score_W0_a 0.43468679471264554
# test_score_W0_n 0.3285337783952718
# test_score_W0_a  0.1993207733181564
# all_train_score_W_Combined_n 0.5523291554687405
# all_train_score_W_Combined_a 0.7442609021704832
# test_score_W_combined_n 0.35104893019338773
# test_score_W_combined_a 0.25271600264308974
# Combine Neurons Number :622
# all_train_score_W0_n 0.3122393722116799
# all_train_score_W0_a 0.41648681941919613
# test_score_W0_n 0.3281092988754187
# test_score_W0_a  0.186158140408037
# all_train_score_W_Combined_n 0.5144034160788531
# all_train_score_W_Combined_a 0.7062079641875378
# test_score_W_combined_n 0.4332985242309729
# test_score_W_combined_a 0.297771368488177
# Combine Neurons Number :522
# all_train_score_W0_n 0.28186632715580734
# all_train_score_W0_a 0.34345689295679255
# test_score_W0_n 0.3303224948906473
# test_score_W0_a  0.15990433472678572
# all_train_score_W_Combined_n 0.5803682081281432
# all_train_score_W_Combined_a 0.7681772897018508
# test_score_W_combined_n 0.32793670616894366
# test_score_W_combined_a 0.2255694203252312
# Not good nmi result !!!!!
# Combine Neurons Number :555
# all_train_score_W0_n 0.2732757791125007
# all_train_score_W0_a 0.33590166056279724
# test_score_W0_n 0.32473257258682886
# test_score_W0_a  0.18175929789674558
# all_train_score_W_Combined_n 0.5804585602602245
# all_train_score_W_Combined_a 0.7834084140864764
# test_score_W_combined_n 0.33736321748230114
# test_score_W_combined_a 0.2605887468520346
# Combine Neurons Number :595
# all_train_score_W0_n 0.2780750486667267
# all_train_score_W0_a 0.41820249042510294
# test_score_W0_n 0.35201223749921273
# test_score_W0_a  0.20338869219801184
# all_train_score_W_Combined_n 0.5628012263924909
# all_train_score_W_Combined_a 0.7365275120812647
# test_score_W_combined_n 0.3772688637457135
# test_score_W_combined_a 0.250088018825067
# Combine Neurons Number :578
# all_train_score_W0_n 0.2626206725836333
# all_train_score_W0_a 0.28331853933881346
# test_score_W0_n 0.26896280217558455
# test_score_W0_a  0.12872501280434132
# all_train_score_W_Combined_n 0.49848221135207144
# all_train_score_W_Combined_a 0.6996519259723808
# test_score_W_combined_n 0.32490433665907414
# test_score_W_combined_a 0.24667126760255262
# Combine Neurons Number :558
# all_train_score_W0_n 0.3854842987885428
# all_train_score_W0_a 0.5643246800928713
# test_score_W0_n 0.3502920012645033
# test_score_W0_a  0.2384473801038172
# all_train_score_W_Combined_n 0.5510555348940782
# all_train_score_W_Combined_a 0.7077278482444255
# test_score_W_combined_n 0.3855277298941038
# test_score_W_combined_a 0.2571043981016271
# Combine Neurons Number :541
# all_train_score_W0_n 0.1954566400238728
# all_train_score_W0_a 0.3201361440535426
# test_score_W0_n 0.2061721110089367
# test_score_W0_a  0.10566111310961017
# all_train_score_W_Combined_n 0.4925759199790136
# all_train_score_W_Combined_a 0.6912658740430224
# test_score_W_combined_n 0.3630481754008373
# test_score_W_combined_a 0.2454588252903195
# Combine Neurons Number :526
# all_train_score_W0_n 0.2694892544140243
# all_train_score_W0_a 0.37481321881284885
# test_score_W0_n 0.26190749259985463
# test_score_W0_a  0.1417948088935028
# all_train_score_W_Combined_n 0.5686659315751321
# all_train_score_W_Combined_a 0.7562360134054968
# test_score_W_combined_n 0.36049865710768547
# test_score_W_combined_a 0.26585746755129247
# Combine Neurons Number :613
# all_train_score_W0_n 0.31907280522755005
# all_train_score_W0_a 0.49996619070910303
# test_score_W0_n 0.2589127497801489
# test_score_W0_a  0.1912705514835359
# all_train_score_W_Combined_n 0.5868858754087551
# all_train_score_W_Combined_a 0.7771419161711441
# test_score_W_combined_n 0.3464698645199712
# test_score_W_combined_a 0.2755234926997374
# Combine Neurons Number :588
# all_train_score_W0_n 0.28041675427882484
# all_train_score_W0_a 0.424309601613712
# test_score_W0_n 0.300511145379425
# test_score_W0_a  0.19641840403867725
# all_train_score_W_Combined_n 0.5038668673746809
# all_train_score_W_Combined_a 0.6914819513779952
# test_score_W_combined_n 0.35283617064405626
# test_score_W_combined_a 0.241326387221144
# Combine Neurons Number :627
# all_train_score_W0_n 0.15087891542721332
# all_train_score_W0_a 0.32381611067649985
# test_score_W0_n 0.17278037270729954
# test_score_W0_a  0.09681268849479883
# all_train_score_W_Combined_n 0.5610079858197591
# all_train_score_W_Combined_a 0.7478844210966739
# test_score_W_combined_n 0.3460463912616393
# test_score_W_combined_a 0.250948538498984
# Combine Neurons Number :539
# all_train_score_W0_n 0.3366947009429639
# all_train_score_W0_a 0.5483770712170268
# test_score_W0_n 0.3068480151898674
# test_score_W0_a  0.22223152886867667
# all_train_score_W_Combined_n 0.518659919538949
# all_train_score_W_Combined_a 0.7348314044913524
# test_score_W_combined_n 0.3469165583752385
# test_score_W_combined_a 0.24058833866892013
# Combine Neurons Number :579
# all_train_score_W0_n 0.3110976829329997
# all_train_score_W0_a 0.46836493258781536
# test_score_W0_n 0.3043814137102915
# test_score_W0_a  0.20851723216153356
# all_train_score_W_Combined_n 0.49826931064201657
# all_train_score_W_Combined_a 0.7040319547548305
# test_score_W_combined_n 0.3575140159211887
# test_score_W_combined_a 0.24981234053804025
# Combine Neurons Number :553
# all_train_score_W0_n 0.3132884996884083
# all_train_score_W0_a 0.47446914121856815
# test_score_W0_n 0.30492770168919453
# test_score_W0_a  0.19494384085392086
# all_train_score_W_Combined_n 0.5674251199652562
# all_train_score_W_Combined_a 0.7499216178366976
# test_score_W_combined_n 0.3913648216165831
# test_score_W_combined_a 0.2881637761939456
# Combine Neurons Number :579
# all_train_score_W0_n 0.29997690178148123
# all_train_score_W0_a 0.47156542393881823
# test_score_W0_n 0.3498856225642737
# test_score_W0_a  0.2294053692961894
# all_train_score_W_Combined_n 0.49061837638346145
# all_train_score_W_Combined_a 0.6960328942890337
# test_score_W_combined_n 0.2681954040379345
# test_score_W_combined_a 0.20293456090404716
# Not good nmi result !!!!!
# Not good ari result !!!!!
# Combine Neurons Number :585
# all_train_score_W0_n 0.2933156369457192
# all_train_score_W0_a 0.4927046673829133
# test_score_W0_n 0.26218383946846496
# test_score_W0_a  0.18403723859880267
# all_train_score_W_Combined_n 0.4775331881903194
# all_train_score_W_Combined_a 0.7018913475198755
# test_score_W_combined_n 0.3202224030787825
# test_score_W_combined_a 0.2623714598733895
# Combine Neurons Number :575
# all_train_score_W0_n 0.3594639824573023
# all_train_score_W0_a 0.4837393210633258
# test_score_W0_n 0.32621523319914153
# test_score_W0_a  0.20345815751432877
# all_train_score_W_Combined_n 0.5809976681973874
# all_train_score_W_Combined_a 0.7535038289881385
# test_score_W_combined_n 0.3978058649497501
# test_score_W_combined_a 0.28855688141698804
# Combine Neurons Number :614
# all_train_score_W0_n 0.3269068089579418
# all_train_score_W0_a 0.46104176138214614
# test_score_W0_n 0.334498626455608
# test_score_W0_a  0.19942621360235463
# all_train_score_W_Combined_n 0.5446521592991862
# all_train_score_W_Combined_a 0.731498530418798
# test_score_W_combined_n 0.3861680521855071
# test_score_W_combined_a 0.2690897523507036
# Combine Neurons Number :644
# all_train_score_W0_n 0.30861364625204435
# all_train_score_W0_a 0.4054991229006715
# test_score_W0_n 0.31984429151901833
# test_score_W0_a  0.18728582115495812
# all_train_score_W_Combined_n 0.49366733272313573
# all_train_score_W_Combined_a 0.6902181620910113
# test_score_W_combined_n 0.3277047520314348
# test_score_W_combined_a 0.20776323409503997
# Combine Neurons Number :518
# all_train_score_W0_n 0.33002613443710943
# all_train_score_W0_a 0.4817159041543759
# test_score_W0_n 0.359612908668249
# test_score_W0_a  0.22875393613411962
# all_train_score_W_Combined_n 0.49556960053165966
# all_train_score_W_Combined_a 0.668277687377777
# test_score_W_combined_n 0.4057538823176866
# test_score_W_combined_a 0.2718476854304428
# Combine Neurons Number :550
# all_train_score_W0_n 0.34950971020917876
# all_train_score_W0_a 0.47639352647839517
# test_score_W0_n 0.30900806032588474
# test_score_W0_a  0.20157633294536847
# all_train_score_W_Combined_n 0.5230105860784535
# all_train_score_W_Combined_a 0.7087789741549179
# test_score_W_combined_n 0.4029182816331829
# test_score_W_combined_a 0.29809056767923037
# Combine Neurons Number :574
# NMI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.302346  0.045047  0.008224   0.285525  0.319167
# 1  test_score_W'  30.0  0.361797  0.036797  0.006718   0.348057  0.375537
# 2       combined  60.0  0.332071  0.050612  0.006534   0.318997  0.345146
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =   -0.0595
# 1                          Degrees of freedom =   58.0000
# 2                                           t =   -5.5982
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    0.0000
# 5                      Difference > 0 p value =    1.0000
# 6                                   Cohen's d =   -1.4455
# 7                                   Hedge's g =   -1.4267
# 8                               Glass's delta =   -1.3198
# 9                                 Pearson's r =    0.5923
# ARI T-Test
#         Variable     N      Mean        SD        SE  95% Conf.  Interval
# 0  test_score_W0  30.0  0.302346  0.045047  0.008224   0.285525  0.319167
# 1  test_score_W'  30.0  0.259141  0.027964  0.005105   0.248699  0.269583
# 2       combined  60.0  0.280743  0.043086  0.005562   0.269613  0.291873
#                               Independent t-test  results
# 0  Difference (test_score_W0 - test_score_W') =    0.0432
# 1                          Degrees of freedom =   58.0000
# 2                                           t =    4.4632
# 3                       Two side test p value =    0.0000
# 4                      Difference < 0 p value =    1.0000
# 5                      Difference > 0 p value =    0.0000
# 6                                   Cohen's d =    1.1524
# 7                                   Hedge's g =    1.1374
# 8                               Glass's delta =    0.9591
# 9                                 Pearson's r =    0.5056
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
# C:\Users\fooli\anaconda3\lib\site-packages\researchpy\ttest.py:18: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   groups = group1.append(group2, ignore_index= True)
