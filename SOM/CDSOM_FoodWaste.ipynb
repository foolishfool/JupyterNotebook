# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import newSom
import CDSOM
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
import experiment
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Food Waste data and research.csv",encoding='latin-1')
csv = csv.drop(columns=['Source'])

dataread.changeCategoryTextToInt(csv,"Country")
dataread.changeCategoryTextToInt(csv,"Confidence in estimate")
dataread.changeCategoryTextToInt(csv,"Region")
                                 
csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv_training,csv_training,csv_test,"Confidence in estimate")
# Out:
#  column number self.data_train_discrete 3

# %%
#comparision softmax
import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 4
# train_discrete_score_W0_p 0.9066666666666666
# train_discrete_score_W0_n 0.8030579597052542
# train_discrete_score_W0_a  0.8692758830846964
# test_discrete_score_W0_p 0.890625
# test_discrete_score_W0_n 0.78665100755858
# test_discrete_score_W0 0.8906773018353553
# train_discrete_score_W_discrete_p 0.9066666666666666
# train_discrete_score_W_discrete_n 0.8030579597052542
# train_discrete_score_W_discrete_a 0.8692758830846964
# test_discrete_score_W_discrete_p 0.890625
# test_discrete_score_W_discrete_n 0.78665100755858
# test_discrete_score_W_discrete_a 0.8906773018353553
# neuron unit number: 7
# train_discrete_score_W0_p 0.9066666666666666
# train_discrete_score_W0_n 0.8030579597052542
# train_discrete_score_W0_a  0.8692758830846964
# test_discrete_score_W0_p 0.890625
# test_discrete_score_W0_n 0.78665100755858
# test_discrete_score_W0 0.8906773018353553
# train_discrete_score_W_discrete_p 0.9066666666666666
# ...

# %%
#DOSOM

import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,1,3)
# Out:
# neuron unit number: 4
# train_discrete_score_W0_p 0.76
# train_discrete_score_W0_n 0.4085163445687877
# train_discrete_score_W0_a  0.46242297116954545
# test_discrete_score_W0_p 0.84375
# test_discrete_score_W0_n 0.3810965503793562
# test_discrete_score_W0 0.42298084929225643
# train_discrete_score_W_discrete_p 0.9133333333333333
# train_discrete_score_W_discrete_n 0.7634085538321258
# train_discrete_score_W_discrete_a 0.8781652329414026
# test_discrete_score_W_discrete_p 0.96875
# test_discrete_score_W_discrete_n 0.9294699711062723
# test_discrete_score_W_discrete_a 0.9828017423071519
# neuron unit number: 7
# train_discrete_score_W0_p 0.7333333333333333
# train_discrete_score_W0_n 0.2882566351330299
# train_discrete_score_W0_a  0.3726381435608868
# test_discrete_score_W0_p 0.875
# test_discrete_score_W0_n 0.5055423230377478
# test_discrete_score_W0 0.6312674094707521
# train_discrete_score_W_discrete_p 0.94
# train_discrete_score_W_discrete_n 0.837056419847974
# ...

# %%
#subjective 

import experiment

unstable_repeat_num= 30
scope_num = 50
class_num = 4
best_num = 30
interval = 3


#needs to noralimization
experiment = experiment.Experiment()
experiment.UTtest_Discrete_Continuous(dataread,False,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
# Out:
# neuron unit number: 4
#  all feature number 10
# all_train_score_W0_p 0.5933333333333334
# all_train_score_W0_n 0.0
# all_train_score_W0_a 0.0
# test_score_W0_p0.640625
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 3
# all_train_score_W_combine_p 0.76
# all_train_score_W_combine_n 0.2975296265763413
# all_train_score_W_combine_a 0.3204232531684964
# test_score_W_combine_p0.78125
# test_score_W_combine_n 0.3629975472310558
# test_score_W_combine_a 0.49256448454800084
# neuron unit number: 7
#  all feature number 10
# all_train_score_W0_p 0.6533333333333333
# all_train_score_W0_n 0.13095287105819667
# all_train_score_W0_a 0.1533714840705793
# test_score_W0_p0.640625
# test_score_W0_n 0.0
# test_score_W0_a  0.0
#  discrete feature number 3
# all_train_score_W_combine_p 0.7866666666666666
# all_train_score_W_combine_n 0.36962442580457455
# all_train_score_W_combine_a 0.37648127306115126
# test_score_W_combine_p0.78125
# ...

# %% [markdown]
# ### import experiment
#
# unstable_repeat_num= 30
# scope_num = 50
# class_num = 4
# best_num = 30
# interval = 3
#
#
# #needs to noralimization
# experiment = experiment.Experiment()
# experiment.UTtest_Discrete_Continuous(dataread,class_num,best_num, scope_num,unstable_repeat_num,0,interval,2,4)
