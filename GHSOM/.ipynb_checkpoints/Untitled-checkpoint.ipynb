# %%
import ghsom
# Out:
# WARNING:tensorflow:From C:\Users\fooli\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
ghsom = ghsom.GHSOM("daily_loads.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 ghsom = ghsom.GHSOM("daily_loads")
#
# File C:\JupyterDoc\GHSOM\ghsom.py:11, in GHSOM.__init__(self, xlsxnmae)
#       9     def __init__(self, xlsxnmae):
# ---> 11         df = pd.read_excel(xlsxnmae)
#      12 # -----------------------------------input data random pre-process------------------------------------
#      13         df = df.sample(frac=1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
ghsom.train()
# Out:
# 13.217603888162186
# WARNING:tensorflow:From C:\Users\fooli\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# SOM-Start
# SOM-finish
# each unit mqe:
# [0.0, 12.299817498877346, 6.56140838342582, 6.685553906230137]
# mqe > tau1*mqe0
# dissimilar_weight_location:
# [1 1]
# -----------get_map_weight_before_unit_insertion----------
# [[-3.06589544e-01 -1.33990586e+00 -2.48546124e-01 -1.85464904e-01
#    6.27890751e-02 -4.92929637e-01  5.73136508e-01  3.41818720e-01
#    1.49027511e-01  6.97877526e-01 -1.80312112e-01  5.91380596e-01
#   -7.59397030e-01 -8.14512849e-01  2.55083382e-01 -1.37145317e+00
#    2.34698370e-01  1.30767858e+00 -3.03822666e-01  2.20820487e-01
#   -7.62363136e-01 -4.09331053e-01  1.24473739e+00  9.68925059e-01
# ...
