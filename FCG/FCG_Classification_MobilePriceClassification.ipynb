# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Mobile Price Classification/train.csv")
csv_original_encode = csv

#dataread.hash_encoding(csv_original_encode,["blue","dual_sim","fc","four_g","mobile_wt","n_cores","sc_h","sc_w","talk_time","three_g","touch_screen","wifi"])
dataread.label_encoding(csv,"blue")
dataread.label_encoding(csv,"dual_sim")
dataread.label_encoding(csv,"fc")
dataread.label_encoding(csv,"four_g")
dataread.label_encoding(csv,"mobile_wt")
dataread.label_encoding(csv,"n_cores")
dataread.label_encoding(csv,"sc_h")
dataread.label_encoding(csv,"sc_w")
dataread.label_encoding(csv,"talk_time")
dataread.label_encoding(csv,"three_g")
dataread.label_encoding(csv,"touch_screen")
dataread.label_encoding(csv,"wifi")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"price_range")
# Out:
# continuous_feature_num 8
# discrete_feature_num 12
# self.data_discrete_indexes ['blue', 'dual_sim', 'fc', 'four_g', 'm_dep', 'n_cores', 'sc_h', 'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi']

# %%
import experiment 
scope_num = 30 
topology_ratio = 2

experiment = experiment.Experiment() 
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.22
# recall_score_baseline 0.21816628421553919
# precision_score_baseline 0.2244749002439635
# f1_score_baseline 0.22037694226931942
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 2
# accuracy_score_baseline 0.24
# recall_score_baseline 0.24010422141630752
# precision_score_baseline 0.24303426539198897
# f1_score_baseline 0.24011304628691701
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 3
# accuracy_score_baseline 0.25666666666666665
# recall_score_baseline 0.2566096006182927
# precision_score_baseline 0.2639938474904532
# f1_score_baseline 0.25750481307073914
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_baseline 0.21333333333333335
# recall_score_baseline 0.21279793261374386
# precision_score_baseline 0.21823452712556127
# f1_score_baseline 0.2141103834959767
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 5
# accuracy_score_baseline 0.23666666666666666
# recall_score_baseline 0.23522807904016513
# precision_score_baseline 0.23792919520229944
# f1_score_baseline 0.23614464898190807
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 6
# accuracy_score_baseline 0.24
# recall_score_baseline 0.23904357155598877
# precision_score_baseline 0.24564187608415194
# f1_score_baseline 0.2405058097113033
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 7
# accuracy_score_baseline 0.25166666666666665
# recall_score_baseline 0.25134103770279265
# precision_score_baseline 0.2562815090139253
# f1_score_baseline 0.2524389593581238
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 8
# accuracy_score_baseline 0.24833333333333332
# recall_score_baseline 0.24814156823676692
# precision_score_baseline 0.2510802700445263
# f1_score_baseline 0.2488249366331558
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 9
# accuracy_score_baseline 0.22
# recall_score_baseline 0.21963389313347922
# precision_score_baseline 0.22365710631900038
# f1_score_baseline 0.22027376249193437
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 10
# accuracy_score_baseline 0.245
# recall_score_baseline 0.24268672215692083
# precision_score_baseline 0.24729953766403584
# f1_score_baseline 0.2444820054513729
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 11
# accuracy_score_baseline 0.215
# recall_score_baseline 0.2151003988959287
# precision_score_baseline 0.21850059620640422
# f1_score_baseline 0.2151560458788622
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 12
# accuracy_score_baseline 0.24333333333333335
# recall_score_baseline 0.24343903697173566
# precision_score_baseline 0.2454741622539128
# f1_score_baseline 0.24371078312265085
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 13
# accuracy_score_baseline 0.22
# recall_score_baseline 0.21944544486969986
# precision_score_baseline 0.22531007843507844
# f1_score_baseline 0.22060173032867286
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 14
# accuracy_score_baseline 0.23833333333333334
# recall_score_baseline 0.2372080201653877
# precision_score_baseline 0.24252260114572144
# f1_score_baseline 0.23883190788894498
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 15
# accuracy_score_baseline 0.22666666666666666
# recall_score_baseline 0.22495277096891336
# precision_score_baseline 0.23028105865007076
# f1_score_baseline 0.2268479612290451
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 16
# accuracy_score_baseline 0.22833333333333333
# recall_score_baseline 0.22801294241691594
# precision_score_baseline 0.23049377246822844
# f1_score_baseline 0.22813102676849492
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 17
# accuracy_score_baseline 0.22833333333333333
# recall_score_baseline 0.22667054592758235
# precision_score_baseline 0.22905589656660946
# f1_score_baseline 0.22754284209168313
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 18
# accuracy_score_baseline 0.23833333333333334
# recall_score_baseline 0.23989391311411176
# precision_score_baseline 0.2405320485965647
# f1_score_baseline 0.23864850651497155
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 19
# accuracy_score_baseline 0.23833333333333334
# recall_score_baseline 0.23718302446572315
# precision_score_baseline 0.24144225271583764
# f1_score_baseline 0.2384692880084585
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 20
# accuracy_score_baseline 0.26166666666666666
# recall_score_baseline 0.26062797539411775
# precision_score_baseline 0.26207389573193446
# f1_score_baseline 0.26088119053965
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# accuracy_score_baseline 0.25833333333333336
# recall_score_baseline 0.25666717235425845
# precision_score_baseline 0.2623634579075612
# f1_score_baseline 0.2585739901651307
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_baseline 0.24
# recall_score_baseline 0.23909304532234993
# precision_score_baseline 0.24387430095965093
# f1_score_baseline 0.23992618300596774
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 23
# accuracy_score_baseline 0.23
# recall_score_baseline 0.2287173512959937
# precision_score_baseline 0.23147840669191055
# f1_score_baseline 0.22939143606160411
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 24
# accuracy_score_baseline 0.24666666666666667
# recall_score_baseline 0.2461579987035285
# precision_score_baseline 0.2485537346777179
# f1_score_baseline 0.2462793927223188
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 25
# accuracy_score_baseline 0.23666666666666666
# recall_score_baseline 0.23599304102201452
# precision_score_baseline 0.23930849563055712
# f1_score_baseline 0.23666122212536428
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 26
# accuracy_score_baseline 0.25333333333333335
# recall_score_baseline 0.25291223294120646
# precision_score_baseline 0.25908088594652734
# f1_score_baseline 0.2541598176337768
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 27
# accuracy_score_baseline 0.25333333333333335
# recall_score_baseline 0.25306117187325794
# precision_score_baseline 0.2538570858965596
# f1_score_baseline 0.25307942569278974
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 28
# accuracy_score_baseline 0.24166666666666667
# recall_score_baseline 0.2405093140089001
# precision_score_baseline 0.24561941753349908
# f1_score_baseline 0.24194214569502942
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 29
# accuracy_score_baseline 0.24666666666666667
# recall_score_baseline 0.2440680307091731
# precision_score_baseline 0.24700228326091628
# f1_score_baseline 0.24484185702452455
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# Experiment number: 30
# accuracy_score_baseline 0.245
# recall_score_baseline 0.24483756677465288
# precision_score_baseline 0.25031277096494486
# f1_score_baseline 0.24597372503949874
# accuracy_score_fcg 0.26
# recall_score_fcg 0.2606865724415393
# precision_score_fcg 0.2645490485378126
# f1_score_fcg 0.25588145896656533
# all_accuracy_score_baseline mean 0.2387222222222222
# all_recall_score_baseline mean 0.23794346362951493
# all_precision_score_baseline mean 0.24195880789400376
# all_f1_score_baseline mean 0.23881419284293964
# all_accuracy_score_fcg mean 0.25999999999999995
# all_recall_score_fcg mean 0.2606865724415393
# all_precision_score_fcg mean 0.2645490485378126
# all_f1_score_fcg mean 0.2558814589665654
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.238722  1.295204e-02  2.364709e-03
# 1       all_accuracy_score_fcg  30.0  0.260000  5.646013e-17  1.030816e-17
# 2                     combined  60.0  0.249361  1.405562e-02  1.814573e-03
#
#    95% Conf.  Interval
# 0   0.233886  0.243559
# 1   0.260000  0.260000
# 2   0.245730  0.252992
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...  -0.0213
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -8.9981
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.3233
# 7                                       Hedge's g =   -2.2931
# 8                                  Glass's delta1 =   -1.6428
# 9                                Point-Biserial r =   -0.7633
# Recall Score T-Test
#                     Variable     N      Mean        SD       SE  95% Conf.  \
# 0  all_recall_score_baseline  30.0  0.237943  0.012981  0.00237   0.233096
# 1       all_recall_score_fcg  30.0  0.260687  0.000000  0.00000        NaN
# 2                   combined  60.0  0.249315  0.014640  0.00189   0.245533
#
#    Interval
# 0  0.242791
# 1       NaN
# 2  0.253097
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0227
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -9.5959
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.4777
# 7                                       Hedge's g =   -2.4455
# 8                                  Glass's delta1 =   -1.7520
# 9                                Point-Biserial r =   -0.7833
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.241959  0.012921  0.002359
# 1       all_precision_score_fcg  30.0  0.264549  0.000000  0.000000
# 2                      combined  60.0  0.253254  0.014554  0.001879
#
#    95% Conf.  Interval
# 0   0.237134  0.246784
# 1        NaN       NaN
# 2   0.249494  0.257014
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0226
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -9.5757
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -2.4724
# 7                                       Hedge's g =   -2.4403
# 8                                  Glass's delta1 =   -1.7483
# 9                                Point-Biserial r =   -0.7827
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.238814  1.291482e-02  2.357913e-03
# 1       all_f1_score_fcg  30.0  0.255881  5.646013e-17  1.030816e-17
# 2               combined  60.0  0.247348  1.249160e-02  1.612658e-03
#
#    95% Conf.  Interval
# 0   0.233992  0.243637
# 1   0.255881  0.255881
# 2   0.244121  0.250575
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0171
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -7.2383
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.8689
# 7                                       Hedge's g =   -1.8446
# 8                                  Glass's delta1 =   -1.3215
# 9                                Point-Biserial r =   -0.6889
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
