# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Hotel Reservations.csv")
csv = csv.drop(columns=['Booking_ID'])
csv = csv.sample(int(csv.shape[0]*1))


dataread.label_encoding(csv,"type_of_meal_plan")
dataread.label_encoding(csv,"room_type_reserved")
dataread.label_encoding(csv,"arrival_year")
dataread.label_encoding(csv,"market_segment_type")
dataread.label_encoding(csv,"booking_status")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)


dataread.initializedataset(csv,csv_training,csv_test,"booking_status")
# Out:
# continuous_feature_num 4
# discrete_feature_num 13
# self.data_discrete_indexes ['no_of_adults', 'no_of_children', 'no_of_weekend_nights', 'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space', 'room_type_reserved', 'arrival_year', 'arrival_month', 'market_segment_type', 'repeated_guest', 'no_of_previous_cancellations', 'no_of_special_requests']

# %%
import experiment
scope_num = 50
topology_ratio = 2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 1, choosen_index23816
# key 0, choosen_index14977
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.5825215952949825
# recall_score_fcg 0.6138727791053508
# precision_score_fcg 0.6006815921687495
# f1_score_fcg 0.5756274123796168
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 1, choosen_index6509
# key 0, choosen_index8380
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 1, choosen_index19413
# key 0, choosen_index16245
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 1, choosen_index12390
# key 0, choosen_index19055
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.5825215952949825
# recall_score_fcg 0.6138727791053508
# precision_score_fcg 0.6006815921687495
# f1_score_fcg 0.5756274123796168
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 1, choosen_index21812
# key 0, choosen_index23026
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 1, choosen_index19564
# key 0, choosen_index21684
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 1, choosen_index19364
# key 0, choosen_index4589
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 1, choosen_index6426
# key 0, choosen_index19499
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 1, choosen_index5405
# key 0, choosen_index8804
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.5825215952949825
# recall_score_fcg 0.6138727791053508
# precision_score_fcg 0.6006815921687495
# f1_score_fcg 0.5756274123796168
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 1, choosen_index467
# key 0, choosen_index2994
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.5825215952949825
# recall_score_fcg 0.6138727791053508
# precision_score_fcg 0.6006815921687495
# f1_score_fcg 0.5756274123796168
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 1, choosen_index11591
# key 0, choosen_index9403
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 1, choosen_index23886
# key 0, choosen_index13684
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.5825215952949825
# recall_score_fcg 0.6138727791053508
# precision_score_fcg 0.6006815921687495
# f1_score_fcg 0.5756274123796168
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 1, choosen_index9506
# key 0, choosen_index3304
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.41747840470501746
# recall_score_fcg 0.3861272208946493
# precision_score_fcg 0.3993184078312505
# f1_score_fcg 0.38640099797613997
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 1, choosen_index12926
# key 0, choosen_index16490
# accuracy_score_baseline 0.7552839551553023
# recall_score_baseline 0.669550536171422
# precision_score_baseline 0.7346355385466807
# f1_score_baseline 0.6823259562398635
# accuracy_score_fcg 0.5825215952949825
# recall_score_fcg 0.6138727791053508
# precision_score_fcg 0.6006815921687495
# f1_score_fcg 0.5756274123796168
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# key 1, choosen_index10481
# key 0, choosen_index13513
