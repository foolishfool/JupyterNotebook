# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Netflix Userbase.csv")
csv = csv.drop(columns=['User ID','Plan Duration'])


dataread.label_encoding(csv,"Subscription Type")
dataread.label_encoding(csv,"Country")
dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Device")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)




dataread.initializedataset(csv,csv_training,csv_test,"Subscription Type")

#dataread.data_train_discrete
# Out:
# continuous_feature_num 3
# discrete_feature_num 4
# self.data_discrete_indexes ['Monthly Revenue', 'Country', 'Gender', 'Device']

# %%
import experiment
scope_num = 30
class_num = 2
interval = 1
topology_ratio = 0.1

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 2
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 3
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3466666666666667
# recall_score_fcg 0.33521934972562467
# precision_score_fcg 0.36607334688548426
# f1_score_fcg 0.3149773843684645
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 5
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3453333333333333
# recall_score_fcg 0.32945344557435163
# precision_score_fcg 0.45008470937584216
# f1_score_fcg 0.3464158895941358
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.21733333333333332
# recall_score_fcg 0.18646482278468315
# precision_score_fcg 0.12634075396235148
# f1_score_fcg 0.14810345732123184
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3466666666666667
# recall_score_fcg 0.33521934972562467
# precision_score_fcg 0.36607334688548426
# f1_score_fcg 0.3149773843684645
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 9
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 10
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 11
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.308
# recall_score_fcg 0.3353272047000236
# precision_score_fcg 0.1838419437386735
# f1_score_fcg 0.22698436477356787
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.21733333333333332
# recall_score_fcg 0.18646482278468315
# precision_score_fcg 0.12634075396235148
# f1_score_fcg 0.14810345732123184
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.21733333333333332
# recall_score_fcg 0.18646482278468315
# precision_score_fcg 0.12634075396235148
# f1_score_fcg 0.14810345732123184
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 15
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 16
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 17
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3466666666666667
# recall_score_fcg 0.33521934972562467
# precision_score_fcg 0.36607334688548426
# f1_score_fcg 0.3149773843684645
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 19
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.21733333333333332
# recall_score_fcg 0.18646482278468315
# precision_score_fcg 0.12634075396235148
# f1_score_fcg 0.14810345732123184
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 21
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 22
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3466666666666667
# recall_score_fcg 0.33521934972562467
# precision_score_fcg 0.36607334688548426
# f1_score_fcg 0.3149773843684645
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.308
# recall_score_fcg 0.3353272047000236
# precision_score_fcg 0.1838419437386735
# f1_score_fcg 0.22698436477356787
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 25
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 26
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3453333333333333
# recall_score_fcg 0.32945344557435163
# precision_score_fcg 0.45008470937584216
# f1_score_fcg 0.3464158895941358
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 28
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# Experiment number: 29
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.3466666666666667
# recall_score_fcg 0.33521934972562467
# precision_score_fcg 0.36607334688548426
# f1_score_fcg 0.3149773843684645
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# accuracy_score_orignial 0.576
# recall_score_baseline 0.5623360572628432
# precision_score_baseline 0.5946267143728002
# f1_score_baseline 0.5670279807575674
# accuracy_score_fcg 0.6026666666666667
# recall_score_fcg 0.6137553906130863
# precision_score_fcg 0.7530166015536066
# f1_score_fcg 0.60064485054817
# all_accuracy_score_baseline mean 0.5760000000000001
# all_recall_score_baseline mean 0.5623360572628433
# all_precision_score_baseline mean 0.5946267143728003
# all_f1_score_baseline mean 0.5670279807575674
# all_accuracy_score_fcg mean 0.4718222222222221
# all_recall_score_fcg mean 0.4728452993579357
# all_precision_score_fcg mean 0.5468288427639058
# all_f1_score_fcg mean 0.45083545730605146
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.576000  1.129203e-16  2.061632e-17
# 1       all_accuracy_score_fcg  30.0  0.471822  1.569205e-01  2.864962e-02
# 2                     combined  60.0  0.523911  1.219122e-01  1.573879e-02
#
#    95% Conf.  Interval
# 0   0.576000  0.576000
# 1   0.413227  0.530417
# 2   0.492418  0.555404
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  1.042000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   3.636300e+00
# 3                           Two side test p value =   6.000000e-04
# 4                          Difference < 0 p value =   9.997000e-01
# 5                          Difference > 0 p value =   3.000000e-04
# 6                                       Cohen's d =   9.389000e-01
# 7                                       Hedge's g =   9.267000e-01
# 8                                  Glass's delta1 =   9.225783e+14
# 9                                Point-Biserial r =   4.309000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.562336  1.129203e-16  2.061632e-17
# 1       all_recall_score_fcg  30.0  0.472845  1.701167e-01  3.105891e-02
# 2                   combined  60.0  0.517591  1.275173e-01  1.646242e-02
#
#    95% Conf.  Interval
# 0   0.562336  0.562336
# 1   0.409323  0.536368
# 2   0.484649  0.550532
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re...  8.950000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.881300e+00
# 3                           Two side test p value =   5.500000e-03
# 4                          Difference < 0 p value =   9.972000e-01
# 5                          Difference > 0 p value =   2.800000e-03
# 6                                       Cohen's d =   7.440000e-01
# 7                                       Hedge's g =   7.343000e-01
# 8                                  Glass's delta1 =   7.925129e+14
# 9                                Point-Biserial r =   3.539000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.594627  1.129203e-16  2.061632e-17
# 1       all_precision_score_fcg  30.0  0.546829  2.543124e-01  4.643088e-02
# 2                      combined  60.0  0.570728  1.799171e-01  2.322719e-02
#
#    95% Conf.  Interval
# 0   0.594627  0.594627
# 1   0.451867  0.641791
# 2   0.524250  0.617205
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  4.780000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   1.029400e+00
# 3                           Two side test p value =   3.075000e-01
# 4                          Difference < 0 p value =   8.462000e-01
# 5                          Difference > 0 p value =   1.538000e-01
# 6                                       Cohen's d =   2.658000e-01
# 7                                       Hedge's g =   2.623000e-01
# 8                                  Glass's delta1 =   4.232887e+14
# 9                                Point-Biserial r =   1.340000e-01
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.567028  0.000000  0.000000        NaN
# 1       all_f1_score_fcg  30.0  0.450835  0.182173  0.033260   0.382811
# 2               combined  60.0  0.508932  0.140516  0.018141   0.472633
#
#    Interval
# 0       NaN
# 1  0.518860
# 2  0.545231
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...   0.1162
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    3.4934
# 3                           Two side test p value =    0.0009
# 4                          Difference < 0 p value =    0.9995
# 5                          Difference > 0 p value =    0.0005
# 6                                       Cohen's d =    0.9020
# 7                                       Hedge's g =    0.8903
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.4169
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
