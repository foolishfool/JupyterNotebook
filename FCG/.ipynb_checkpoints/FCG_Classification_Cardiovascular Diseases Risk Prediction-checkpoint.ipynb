# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv = csv.sample(int(csv.shape[0]*0.01))


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
csv_training = csv
dataread.initializedataset(csv,csv_training,csv_test,"General_Health")
# Out:
# continuous_feature_num 7
# discrete_feature_num 11
# self.data_discrete_indexes ['Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex', 'Age_Category', 'Smoking_History']

# %%
import experiment
scope_num = 30
class_num = 5
best_num = 48
interval = 1


experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num)
# Out:
# Experiment number: 5
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 10
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 15
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 20
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 25
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 30
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 35
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 40
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 45
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 50
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 55
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 60
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 65
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 70
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 75
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 80
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 85
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 90
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 95
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# Experiment number: 100
# accuracy_score_orignial 0.4956803455723542
# recall_score_baseline 0.41851518711514013
# precision_score_baseline 0.4992397302087602
# f1_score_baseline 0.43072703146333247
# accuracy_score_fcg 0.2796976241900648
# recall_score_fcg 0.3790188183620976
# precision_score_fcg 0.28743128388421446
# f1_score_fcg 0.2572418677064522
# all_accuracy_score_baseline mean 0.4956803455723543
# all_recall_score_baseline mean 0.4185151871151402
# all_precision_score_baseline mean 0.4992397302087602
# all_f1_score_baseline mean 0.43072703146333247
# all_accuracy_score_fcg mean 0.2796976241900647
# all_recall_score_fcg mean 0.3790188183620976
# all_precision_score_fcg mean 0.28743128388421446
# all_f1_score_fcg mean 0.2572418677064522
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 9
#       5 interval = 5
#       8 experiment = experiment.Experiment()
# ----> 9 experiment.Ttest(dataread,class_num,scope_num,interval)
#
# File C:\JupyterDoc\FCG\experiment.py:131, in Experiment.Ttest(self, dataread, class_num, scope_num, interval)
#     127 axis[3].set_xlabel('Neuron number')
#     128 #axis[4].set_xlabel('Neuron number')
# --> 131 axis[0].plot(plot_unit,all_test_score_baseline_accuracy,'r',label ='all_accuracy_score_baseline')
#     132 axis[0].plot(plot_unit,all_test_score_fcg_accuracy,'b',label ='all_accuracy_score_fcg')
#     133 axis[0].legend(loc='best')
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\envs\gpu_env\lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (19,) and (20,)
