# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Airline Passenger Satisfaction/train.csv")
csv2 = pd.read_csv("Airline Passenger Satisfaction/test.csv")
csv = csv.sample(int(csv.shape[0]*1))
csv = csv.drop(columns=['id'])
csv2 = csv2.drop(columns=['id'])   


#dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv,"Arrival Delay in Minutes")
#dataread.stringToIntAirlinePassengerSatisfactionDataSet(csv2,"Arrival Delay in Minutes")



dataread.label_encoding(csv,"Gender")
dataread.label_encoding(csv,"Customer Type")
dataread.label_encoding(csv,"Type of Travel")
dataread.label_encoding(csv,"Class")
dataread.label_encoding(csv,"satisfaction")


dataread.label_encoding(csv2,"Gender")
dataread.label_encoding(csv2,"Customer Type")
dataread.label_encoding(csv2,"Type of Travel")
dataread.label_encoding(csv2,"Class")
dataread.label_encoding(csv2,"satisfaction")

#print(csv)
csv_training = csv.sample(int(csv.shape[0]*0.03))
csv_test = csv2.sample(int(csv2.shape[0]*0.1))

dataread.initializedataset(csv,csv_training,csv_test,"satisfaction")
# Out:
# continuous_feature_num 4
# discrete_feature_num 18
# self.data_discrete_indexes ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']

# %%
import experiment
scope_num = 30
topology_ratio = 1.2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 0, choosen_index2464
# key 1, choosen_index1593
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 0, choosen_index37
# key 1, choosen_index379
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 0, choosen_index1976
# key 1, choosen_index1332
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 0, choosen_index134
# key 1, choosen_index164
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 0, choosen_index1861
# key 1, choosen_index504
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 0, choosen_index446
# key 1, choosen_index915
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 0, choosen_index338
# key 1, choosen_index2
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 0, choosen_index2377
# key 1, choosen_index2265
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.7620331151328456
# recall_score_fcg 0.777403414195867
# precision_score_fcg 0.7768573068672769
# f1_score_fcg 0.7620302571286568
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 0, choosen_index2751
# key 1, choosen_index1218
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 0, choosen_index1050
# key 1, choosen_index2384
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 0, choosen_index2738
# key 1, choosen_index1501
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 0, choosen_index1052
# key 1, choosen_index511
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 0, choosen_index2638
# key 1, choosen_index2250
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 0, choosen_index388
# key 1, choosen_index1666
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# key 0, choosen_index322
# key 1, choosen_index914
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 0, choosen_index2495
# key 1, choosen_index1910
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 0, choosen_index79
# key 1, choosen_index2848
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 0, choosen_index2635
# key 1, choosen_index694
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 0, choosen_index2352
# key 1, choosen_index967
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# key 0, choosen_index2003
# key 1, choosen_index1439
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 0, choosen_index1567
# key 1, choosen_index1649
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 0, choosen_index2370
# key 1, choosen_index325
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# key 0, choosen_index2643
# key 1, choosen_index1502
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 0, choosen_index1670
# key 1, choosen_index1071
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.7620331151328456
# recall_score_fcg 0.777403414195867
# precision_score_fcg 0.7768573068672769
# f1_score_fcg 0.7620302571286568
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 0, choosen_index114
# key 1, choosen_index541
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 0, choosen_index2805
# key 1, choosen_index192
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# key 0, choosen_index2030
# key 1, choosen_index915
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# key 0, choosen_index2199
# key 1, choosen_index1307
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# key 0, choosen_index1482
# key 1, choosen_index1289
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# key 0, choosen_index442
# key 1, choosen_index2194
# accuracy_score_baseline 0.8617635733538699
# recall_score_baseline 0.8564690026954178
# precision_score_baseline 0.860352900134036
# f1_score_baseline 0.858158959977715
# accuracy_score_fcg 0.23796688486715442
# recall_score_fcg 0.22259658580413297
# precision_score_fcg 0.22314269313272303
# f1_score_fcg 0.2228671788113918
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.8617635733538697
# all_recall_score_baseline mean 0.8564690026954181
# all_precision_score_baseline mean 0.8603529001340359
# all_f1_score_baseline mean 0.8581589599777149
# all_accuracy_score_fcg mean 0.2729046335515339
# all_recall_score_fcg mean 0.2595837076969152
# all_precision_score_fcg mean 0.26005700071502663
# all_f1_score_fcg mean 0.25881138403254267
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.861764  2.258405e-16  4.123265e-17
# 1       all_accuracy_score_fcg  30.0  0.272905  1.329599e-01  2.427504e-02
# 2                     combined  60.0  0.567334  3.112031e-01  4.017615e-02
#
#    95% Conf.  Interval
# 0   0.861764  0.861764
# 1   0.223257  0.322553
# 2   0.486942  0.647726
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_...  5.889000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.425780e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   6.263300e+00
# 7                                       Hedge's g =   6.182000e+00
# 8                                  Glass's delta1 =   2.607411e+15
# 9                                Point-Biserial r =   9.541000e-01
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.856469  3.387608e-16  6.184897e-17
# 1       all_recall_score_fcg  30.0  0.259584  1.407590e-01  2.569896e-02
# 2                   combined  60.0  0.558026  3.167275e-01  4.088934e-02
#
#    95% Conf.  Interval
# 0   0.856469  0.856469
# 1   0.207023  0.312144
# 2   0.476207  0.639846
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re...  5.969000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.322600e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   5.996900e+00
# 7                                       Hedge's g =   5.919100e+00
# 8                                  Glass's delta1 =   1.761967e+15
# 9                                Point-Biserial r =   9.502000e-01
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.860353  1.129203e-16  2.061632e-17
# 1       all_precision_score_fcg  30.0  0.260057  1.404819e-01  2.564837e-02
# 2                      combined  60.0  0.560205  3.183018e-01  4.109259e-02
#
#    95% Conf.  Interval
# 0   0.860353  0.860353
# 1   0.207600  0.312514
# 2   0.477979  0.642431
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  6.003000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.340480e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   6.043100e+00
# 7                                       Hedge's g =   5.964600e+00
# 8                                  Glass's delta1 =   5.316105e+15
# 9                                Point-Biserial r =   9.509000e-01
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.858159  1.129203e-16  2.061632e-17
# 1       all_f1_score_fcg  30.0  0.258811  1.367901e-01  2.497433e-02
# 2               combined  60.0  0.558485  3.170547e-01  4.093158e-02
#
#    95% Conf.  Interval
# 0   0.858159  0.858159
# 1   0.207733  0.309890
# 2   0.476581  0.640389
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  5.993000e-01
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =   2.399850e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   6.196400e+00
# 7                                       Hedge's g =   6.115900e+00
# 8                                  Glass's delta1 =   5.307706e+15
# 9                                Point-Biserial r =   9.532000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
