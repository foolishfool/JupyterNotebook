# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Toddler Autism dataset July 2018.csv")
csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Ethnicity")
dataread.label_encoding(csv,"Jaundice")
dataread.label_encoding(csv,"Family_mem_with_ASD")
dataread.label_encoding(csv,"Who completed the test")
dataread.label_encoding(csv,"Class/ASD Traits ")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Class/ASD Traits ")
# Out:
# continuous_feature_num 1
# discrete_feature_num 17
# self.data_discrete_indexes ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'Age_Mons', 'Qchat-10-Score', 'Sex', 'Ethnicity', 'Jaundice', 'Family_mem_with_ASD', 'Who completed the test']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 0, choosen_index  8
# key 1, choosen_index  41
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 2
# key 0, choosen_index  71
# key 1, choosen_index  5
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 3
# key 0, choosen_index  64
# key 1, choosen_index  55
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 4
# key 0, choosen_index  62
# key 1, choosen_index  35
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 5
# key 0, choosen_index  58
# key 1, choosen_index  21
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 6
# key 0, choosen_index  30
# key 1, choosen_index  21
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 7
# key 0, choosen_index  53
# key 1, choosen_index  5
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 8
# key 0, choosen_index  30
# key 1, choosen_index  17
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 9
# key 0, choosen_index  30
# key 1, choosen_index  31
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 10
# key 0, choosen_index  71
# key 1, choosen_index  66
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 11
# key 0, choosen_index  0
# key 1, choosen_index  33
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 12
# key 0, choosen_index  60
# key 1, choosen_index  46
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 13
# key 0, choosen_index  26
# key 1, choosen_index  2
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 14
# key 0, choosen_index  30
# key 1, choosen_index  56
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 15
# key 0, choosen_index  1
# key 1, choosen_index  70
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 16
# key 0, choosen_index  12
# key 1, choosen_index  44
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 17
# key 0, choosen_index  8
# key 1, choosen_index  23
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 18
# key 0, choosen_index  60
# key 1, choosen_index  2
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 19
# key 0, choosen_index  27
# key 1, choosen_index  59
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 20
# key 0, choosen_index  10
# key 1, choosen_index  35
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 21
# key 0, choosen_index  30
# key 1, choosen_index  67
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 22
# key 0, choosen_index  51
# key 1, choosen_index  28
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 23
# key 0, choosen_index  68
# key 1, choosen_index  63
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 24
# key 0, choosen_index  49
# key 1, choosen_index  28
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 25
# key 0, choosen_index  8
# key 1, choosen_index  38
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 26
# key 0, choosen_index  30
# key 1, choosen_index  19
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 27
# key 0, choosen_index  37
# key 1, choosen_index  61
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 28
# key 0, choosen_index  54
# key 1, choosen_index  38
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 29
# key 0, choosen_index  30
# key 1, choosen_index  73
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# Experiment number: 30
# key 0, choosen_index  57
# key 1, choosen_index  4
# accuracy_score_baseline 1.0
# recall_score_baseline 1.0
# precision_score_baseline 1.0
# f1_score_baseline 1.0
# accuracy_score_fcg 1.0
# recall_score_fcg 1.0
# precision_score_fcg 1.0
# f1_score_fcg 1.0
# all_accuracy_score_baseline mean 1.0
# all_recall_score_baseline mean 1.0
# all_precision_score_baseline mean 1.0
# all_f1_score_baseline mean 1.0
# all_accuracy_score_fcg mean 1.0
# all_recall_score_fcg mean 1.0
# all_precision_score_fcg mean 1.0
# all_f1_score_fcg mean 1.0
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_accuracy_score_baseline  30.0   1.0  0.0  0.0        NaN       NaN
# 1       all_accuracy_score_fcg  30.0   1.0  0.0  0.0        NaN       NaN
# 2                     combined  60.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...      0.0
# 1                              Degrees of freedom =      58.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Recall Score T-Test
#                     Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_recall_score_baseline  30.0   1.0  0.0  0.0        NaN       NaN
# 1       all_recall_score_fcg  30.0   1.0  0.0  0.0        NaN       NaN
# 2                   combined  60.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...      0.0
# 1                              Degrees of freedom =      58.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# Precision Score T-Test
#                        Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_precision_score_baseline  30.0   1.0  0.0  0.0        NaN       NaN
# 1       all_precision_score_fcg  30.0   1.0  0.0  0.0        NaN       NaN
# 2                      combined  60.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...      0.0
# 1                              Degrees of freedom =      58.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# F1 Score T-Test
#                 Variable     N  Mean   SD   SE  95% Conf.  Interval
# 0  all_f1_score_baseline  30.0   1.0  0.0  0.0        NaN       NaN
# 1       all_f1_score_fcg  30.0   1.0  0.0  0.0        NaN       NaN
# 2               combined  60.0   1.0  0.0  0.0        NaN       NaN
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...      0.0
# 1                              Degrees of freedom =      58.0
# 2                                               t =       NaN
# 3                           Two side test p value =       NaN
# 4                          Difference < 0 p value =       NaN
# 5                          Difference > 0 p value =       NaN
# 6                                       Cohen's d =       NaN
# 7                                       Hedge's g =       NaN
# 8                                  Glass's delta1 =       NaN
# 9                                Point-Biserial r =       NaN
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   d = (group1.mean() - group2.mean()) / numpy.sqrt(((group1.count() - 1) * group1.std()**2 + (group2.count() - 1) * group2.std()**2) / (group1.count() + group2.count() - 2))
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   cles = 0 - abs(group1.mean() - group2.mean()) / numpy.sqrt(group1.var() + group2.var())
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
