# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("CVD_cleaned.csv")
csv = csv.sample(int(csv.shape[0]*0.01))


dataread.label_encoding(csv,"General_Health")
dataread.label_encoding(csv,"Checkup")
dataread.label_encoding(csv,"Exercise")
dataread.label_encoding(csv,"Heart_Disease")
dataread.label_encoding(csv,"Skin_Cancer")
dataread.label_encoding(csv,"Other_Cancer")
dataread.label_encoding(csv,"Depression")
dataread.label_encoding(csv,"Diabetes")
dataread.label_encoding(csv,"Arthritis")
dataread.label_encoding(csv,"Sex")
dataread.label_encoding(csv,"Age_Category")
dataread.label_encoding(csv,"Smoking_History")



csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)
csv_training = csv
dataread.initializedataset(csv,csv_training,csv_test,"General_Health")
# Out:
# continuous_feature_num 7
# discrete_feature_num 11
# self.data_discrete_indexes ['Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex', 'Age_Category', 'Smoking_History']

# %%
import experiment
scope_num = 50
topology_ratio = 100

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# key 0, choosen_index2735
# key 2, choosen_index2147
# key 1, choosen_index2268
# key 4, choosen_index2859
# key 3, choosen_index1162
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2602591792656587
# recall_score_fcg 0.2942010138183753
# precision_score_fcg 0.2626423223826904
# f1_score_fcg 0.21960119522575106
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 2
# key 0, choosen_index71
# key 2, choosen_index1557
# key 1, choosen_index1553
# key 4, choosen_index1404
# key 3, choosen_index2512
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2267818574514039
# recall_score_fcg 0.26412922679627415
# precision_score_fcg 0.29533720848092193
# f1_score_fcg 0.14698610887503785
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 3
# key 0, choosen_index132
# key 2, choosen_index1058
# key 1, choosen_index2114
# key 4, choosen_index2459
# key 3, choosen_index628
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.25377969762419006
# recall_score_fcg 0.24178093488773097
# precision_score_fcg 0.25803829675400575
# f1_score_fcg 0.20960666019672008
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 4
# key 0, choosen_index2417
# key 2, choosen_index2967
# key 1, choosen_index1876
# key 4, choosen_index441
# key 3, choosen_index392
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2386609071274298
# recall_score_fcg 0.20362681052001438
# precision_score_fcg 0.23145633636773327
# f1_score_fcg 0.20001569314461004
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 5
# key 0, choosen_index1218
# key 2, choosen_index2531
# key 1, choosen_index3027
# key 4, choosen_index2527
# key 3, choosen_index20
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.28509719222462204
# recall_score_fcg 0.3022558404340243
# precision_score_fcg 0.26523991772751176
# f1_score_fcg 0.26674220276451754
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# key 0, choosen_index1316
# key 2, choosen_index1862
# key 1, choosen_index3027
# key 4, choosen_index2513
# key 3, choosen_index2174
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2591792656587473
# recall_score_fcg 0.315092195891739
# precision_score_fcg 0.25064259622679336
# f1_score_fcg 0.245161837757647
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 7
# key 0, choosen_index2899
# key 2, choosen_index1808
# key 1, choosen_index2458
# key 4, choosen_index1670
# key 3, choosen_index2980
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.31641468682505397
# recall_score_fcg 0.3097408751435021
# precision_score_fcg 0.3124312891127781
# f1_score_fcg 0.26796110092777564
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 8
# key 0, choosen_index817
# key 2, choosen_index729
# key 1, choosen_index682
# key 4, choosen_index1407
# key 3, choosen_index1364
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2991360691144708
# recall_score_fcg 0.3413409670063011
# precision_score_fcg 0.27337894540855995
# f1_score_fcg 0.2697883242431642
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 9
# key 0, choosen_index250
# key 2, choosen_index599
# key 1, choosen_index377
# key 4, choosen_index768
# key 3, choosen_index2801
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.24190064794816415
# recall_score_fcg 0.27781836744143995
# precision_score_fcg 0.23912736781101146
# f1_score_fcg 0.22509567829380334
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 10
# key 0, choosen_index976
# key 2, choosen_index1335
# key 1, choosen_index1569
# key 4, choosen_index1505
# key 3, choosen_index1564
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2526997840172786
# recall_score_fcg 0.3013472713815376
# precision_score_fcg 0.27550311111793097
# f1_score_fcg 0.20265143392712495
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# key 0, choosen_index1885
# key 2, choosen_index620
# key 1, choosen_index2123
# key 4, choosen_index325
# key 3, choosen_index1826
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.21274298056155508
# recall_score_fcg 0.17720788007481328
# precision_score_fcg 0.1675604692590727
# f1_score_fcg 0.1552373236083812
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 12
# key 0, choosen_index59
# key 2, choosen_index2856
# key 1, choosen_index210
# key 4, choosen_index2977
# key 3, choosen_index2129
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.3185745140388769
# recall_score_fcg 0.28854975114255527
# precision_score_fcg 0.23658694379121376
# f1_score_fcg 0.23656055181729232
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 13
# key 0, choosen_index1767
# key 2, choosen_index737
# key 1, choosen_index506
# key 4, choosen_index1788
# key 3, choosen_index2500
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.23542116630669546
# recall_score_fcg 0.25236391085620097
# precision_score_fcg 0.3071593124224703
# f1_score_fcg 0.19327650925283663
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 14
# key 0, choosen_index1158
# key 2, choosen_index416
# key 1, choosen_index780
# key 4, choosen_index1759
# key 3, choosen_index1695
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2159827213822894
# recall_score_fcg 0.284249229092176
# precision_score_fcg 0.22705819630379453
# f1_score_fcg 0.19349366077947497
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 15
# key 0, choosen_index1617
# key 2, choosen_index1019
# key 1, choosen_index1860
# key 4, choosen_index1214
# key 3, choosen_index2506
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.28509719222462204
# recall_score_fcg 0.24978196082707793
# precision_score_fcg 0.27565461670305497
# f1_score_fcg 0.2150075939286265
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 16
# key 0, choosen_index1076
# key 2, choosen_index204
# key 1, choosen_index632
# key 4, choosen_index664
# key 3, choosen_index1149
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.3099352051835853
# recall_score_fcg 0.3183857819266157
# precision_score_fcg 0.25474548544539666
# f1_score_fcg 0.24192819069665647
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 17
# key 0, choosen_index98
# key 2, choosen_index396
# key 1, choosen_index1228
# key 4, choosen_index731
# key 3, choosen_index2314
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.3023758099352052
# recall_score_fcg 0.3072422404232798
# precision_score_fcg 0.27414328469921345
# f1_score_fcg 0.25284871033539114
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 18
# key 0, choosen_index208
# key 2, choosen_index1584
# key 1, choosen_index925
# key 4, choosen_index2367
# key 3, choosen_index2692
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2861771058315335
# recall_score_fcg 0.3358513696263553
# precision_score_fcg 0.2674459411805447
# f1_score_fcg 0.2710047393387936
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 19
# key 0, choosen_index2139
# key 2, choosen_index877
# key 1, choosen_index210
# key 4, choosen_index2513
# key 3, choosen_index1941
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.25377969762419006
# recall_score_fcg 0.23266203396985805
# precision_score_fcg 0.19947226171540736
# f1_score_fcg 0.20677141812928115
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 20
# key 0, choosen_index867
# key 2, choosen_index2346
# key 1, choosen_index2402
# key 4, choosen_index514
# key 3, choosen_index2692
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.30669546436285094
# recall_score_fcg 0.3270863295820463
# precision_score_fcg 0.27831570827377217
# f1_score_fcg 0.2848910471324649
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 21
# key 0, choosen_index713
# key 2, choosen_index367
# key 1, choosen_index1465
# key 4, choosen_index1083
# key 3, choosen_index674
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.3120950323974082
# recall_score_fcg 0.3199794558218316
# precision_score_fcg 0.25752990071515114
# f1_score_fcg 0.25649815665433884
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 22
# key 0, choosen_index2509
# key 2, choosen_index2566
# key 1, choosen_index233
# key 4, choosen_index892
# key 3, choosen_index1095
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.22138228941684665
# recall_score_fcg 0.20798296275166636
# precision_score_fcg 0.20676546335290397
# f1_score_fcg 0.17078175305670834
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 23
# key 0, choosen_index1949
# key 2, choosen_index3036
# key 1, choosen_index2418
# key 4, choosen_index2998
# key 3, choosen_index2957
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.3304535637149028
# recall_score_fcg 0.2740837798347793
# precision_score_fcg 0.24438885496221574
# f1_score_fcg 0.2480743661782554
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 24
# key 0, choosen_index751
# key 2, choosen_index1984
# key 1, choosen_index1728
# key 4, choosen_index218
# key 3, choosen_index113
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2786177105831533
# recall_score_fcg 0.3011891508350674
# precision_score_fcg 0.2865448571066008
# f1_score_fcg 0.22528104927524334
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 25
# key 0, choosen_index1186
# key 2, choosen_index293
# key 1, choosen_index1654
# key 4, choosen_index1658
# key 3, choosen_index1031
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2980561555075594
# recall_score_fcg 0.2917788214018939
# precision_score_fcg 0.3193763404371916
# f1_score_fcg 0.27996361075744713
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 26
# key 0, choosen_index2597
# key 2, choosen_index446
# key 1, choosen_index647
# key 4, choosen_index1858
# key 3, choosen_index1953
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.23110151187904968
# recall_score_fcg 0.2999581398838966
# precision_score_fcg 0.21371442696470505
# f1_score_fcg 0.18026628156725016
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 27
# key 0, choosen_index659
# key 2, choosen_index551
# key 1, choosen_index1588
# key 4, choosen_index3002
# key 3, choosen_index2587
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.27645788336933047
# recall_score_fcg 0.2814246010419626
# precision_score_fcg 0.2532334209740084
# f1_score_fcg 0.22370898780890505
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 28
# key 0, choosen_index1470
# key 2, choosen_index102
# key 1, choosen_index2232
# key 4, choosen_index1828
# key 3, choosen_index239
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.275377969762419
# recall_score_fcg 0.31926575510813093
# precision_score_fcg 0.24281937707629453
# f1_score_fcg 0.23050192608359316
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 29
# key 0, choosen_index198
# key 2, choosen_index1740
# key 1, choosen_index929
# key 4, choosen_index1789
# key 3, choosen_index730
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.13498920086393087
# recall_score_fcg 0.16446342015730936
# precision_score_fcg 0.20214708259710673
# f1_score_fcg 0.13926323521963496
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 30
# key 0, choosen_index140
# key 2, choosen_index46
# key 1, choosen_index210
# key 4, choosen_index1910
# key 3, choosen_index1965
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.21166306695464362
# recall_score_fcg 0.28022909237643673
# precision_score_fcg 0.24652935473978294
# f1_score_fcg 0.1886854374492915
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 31
# key 0, choosen_index2858
# key 2, choosen_index2589
# key 1, choosen_index1742
# key 4, choosen_index520
# key 3, choosen_index2280
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.12742980561555076
# recall_score_fcg 0.16371983062445655
# precision_score_fcg 0.16979798113995706
# f1_score_fcg 0.1264059958481718
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 32
# key 0, choosen_index3001
# key 2, choosen_index1469
# key 1, choosen_index229
# key 4, choosen_index241
# key 3, choosen_index1364
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2861771058315335
# recall_score_fcg 0.2527376463812786
# precision_score_fcg 0.21255285412262154
# f1_score_fcg 0.18196859787180175
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 33
# key 0, choosen_index274
# key 2, choosen_index296
# key 1, choosen_index2061
# key 4, choosen_index3070
# key 3, choosen_index1025
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2786177105831533
# recall_score_fcg 0.23336258135801255
# precision_score_fcg 0.22006837632663295
# f1_score_fcg 0.2092784443979543
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 34
# key 0, choosen_index124
# key 2, choosen_index1595
# key 1, choosen_index1348
# key 4, choosen_index1797
# key 3, choosen_index2893
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.26997840172786175
# recall_score_fcg 0.328653061377219
# precision_score_fcg 0.26886801685997447
# f1_score_fcg 0.24063739303342394
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 35
# key 0, choosen_index2325
# key 2, choosen_index611
# key 1, choosen_index1310
# key 4, choosen_index2595
# key 3, choosen_index2280
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2591792656587473
# recall_score_fcg 0.30684278959550226
# precision_score_fcg 0.2185347545914746
# f1_score_fcg 0.20464601888682732
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 36
# key 0, choosen_index2637
# key 2, choosen_index584
# key 1, choosen_index479
# key 4, choosen_index2312
# key 3, choosen_index628
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.265658747300216
# recall_score_fcg 0.24116342550951347
# precision_score_fcg 0.232496855208545
# f1_score_fcg 0.1937168744608903
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 37
# key 0, choosen_index1463
# key 2, choosen_index1127
# key 1, choosen_index327
# key 4, choosen_index2234
# key 3, choosen_index478
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2958963282937365
# recall_score_fcg 0.28516851391208903
# precision_score_fcg 0.2585775862053988
# f1_score_fcg 0.23838749405688753
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 38
# key 0, choosen_index2135
# key 2, choosen_index2598
# key 1, choosen_index1474
# key 4, choosen_index1374
# key 3, choosen_index1153
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.33153347732181426
# recall_score_fcg 0.29726212242488653
# precision_score_fcg 0.2681235492331858
# f1_score_fcg 0.2285225060042831
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 39
# key 0, choosen_index1244
# key 2, choosen_index1496
# key 1, choosen_index213
# key 4, choosen_index2403
# key 3, choosen_index176
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2688984881209503
# recall_score_fcg 0.27432534999639513
# precision_score_fcg 0.21676089630234693
# f1_score_fcg 0.2190567111011247
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 40
# key 0, choosen_index90
# key 2, choosen_index2152
# key 1, choosen_index1430
# key 4, choosen_index2812
# key 3, choosen_index1897
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.33585313174946
# recall_score_fcg 0.3593511959302935
# precision_score_fcg 0.3459157687617022
# f1_score_fcg 0.31033166664178596
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 41
# key 0, choosen_index473
# key 2, choosen_index2546
# key 1, choosen_index2540
# key 4, choosen_index2400
# key 3, choosen_index1823
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2580993520518359
# recall_score_fcg 0.28523165254747207
# precision_score_fcg 0.2416692324081346
# f1_score_fcg 0.23750991707806118
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 42
# key 0, choosen_index2662
# key 2, choosen_index990
# key 1, choosen_index723
# key 4, choosen_index1735
# key 3, choosen_index113
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.23218142548596113
# recall_score_fcg 0.25579751950397295
# precision_score_fcg 0.20524203954436512
# f1_score_fcg 0.16414170649256374
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 43
# key 0, choosen_index312
# key 2, choosen_index1995
# key 1, choosen_index984
# key 4, choosen_index48
# key 3, choosen_index1916
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.28077753779697623
# recall_score_fcg 0.2684121487148329
# precision_score_fcg 0.23388175928910343
# f1_score_fcg 0.2145341714996789
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 44
# key 0, choosen_index2223
# key 2, choosen_index2709
# key 1, choosen_index640
# key 4, choosen_index2986
# key 3, choosen_index628
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.25161987041036715
# recall_score_fcg 0.23620103226042694
# precision_score_fcg 0.24183488558385563
# f1_score_fcg 0.20361912232322946
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 45
# key 0, choosen_index2067
# key 2, choosen_index639
# key 1, choosen_index1877
# key 4, choosen_index1540
# key 3, choosen_index2639
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.23218142548596113
# recall_score_fcg 0.2511851049429576
# precision_score_fcg 0.21602336671501066
# f1_score_fcg 0.18941994823294733
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 46
# key 0, choosen_index224
# key 2, choosen_index836
# key 1, choosen_index2923
# key 4, choosen_index1872
# key 3, choosen_index405
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2786177105831533
# recall_score_fcg 0.2713615606305498
# precision_score_fcg 0.2595666308093674
# f1_score_fcg 0.2392028399333268
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 47
# key 0, choosen_index2606
# key 2, choosen_index814
# key 1, choosen_index1915
# key 4, choosen_index1042
# key 3, choosen_index1162
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.18466522678185746
# recall_score_fcg 0.15988915391542463
# precision_score_fcg 0.19455961144503725
# f1_score_fcg 0.15933998382489448
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 48
# key 0, choosen_index2043
# key 2, choosen_index960
# key 1, choosen_index2667
# key 4, choosen_index2420
# key 3, choosen_index2288
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.2991360691144708
# recall_score_fcg 0.28701354428367565
# precision_score_fcg 0.24039014675517673
# f1_score_fcg 0.244334600289735
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 49
# key 0, choosen_index2243
# key 2, choosen_index2104
# key 1, choosen_index393
# key 4, choosen_index2569
# key 3, choosen_index1018
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.29481641468682507
# recall_score_fcg 0.2789606293604009
# precision_score_fcg 0.24462221353539726
# f1_score_fcg 0.23786389215100856
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# Experiment number: 50
# key 0, choosen_index2964
# key 2, choosen_index1880
# key 1, choosen_index2632
# key 4, choosen_index2594
# key 3, choosen_index1364
# accuracy_score_baseline 0.35205183585313177
# recall_score_baseline 0.39269214730094226
# precision_score_baseline 0.34372058272775974
# f1_score_baseline 0.33185193511494704
# accuracy_score_fcg 0.3174946004319654
# recall_score_fcg 0.30161145644298126
# precision_score_fcg 0.2862830473321317
# f1_score_fcg 0.2720934521395305
# Not good accuracy result !!!!!
# Not good recall_score result !!!!!
# Not good precision_score_ !!!!!
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.35205183585313177
# all_recall_score_baseline mean 0.39269214730094226
# all_precision_score_baseline mean 0.3437205827277597
# all_f1_score_baseline mean 0.3318519351149471
# all_accuracy_score_fcg mean 0.2655939524838013
# all_recall_score_fcg mean 0.27406638979534464
# all_precision_score_fcg mean 0.24801516524558512
# all_f1_score_fcg mean 0.2192533224138829
# len plot_unit 50  len (all_test_score_baseline_accuracy) 50
# Accuracy Score T-Test
#                       Variable      N      Mean        SD        SE  \
# 0  all_accuracy_score_baseline   50.0  0.352052  0.000000  0.000000
# 1       all_accuracy_score_fcg   50.0  0.265594  0.044529  0.006297
# 2                     combined  100.0  0.308823  0.053563  0.005356
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.252939  0.278249
# 2   0.298195  0.319451
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0865
# 1                              Degrees of freedom =   98.0000
# 2                                               t =   13.7291
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.7458
# 7                                       Hedge's g =    2.7248
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.8111
# Recall Score T-Test
#                     Variable      N      Mean        SD        SE  95% Conf.  \
# 0  all_recall_score_baseline   50.0  0.392692  0.000000  0.000000        NaN
# 1       all_recall_score_fcg   50.0  0.274066  0.046037  0.006511   0.260983
# 2                   combined  100.0  0.333379  0.067842  0.006784   0.319918
#
#    Interval
# 0       NaN
# 1  0.287150
# 2  0.346841
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...   0.1186
# 1                              Degrees of freedom =   98.0000
# 2                                               t =   18.2204
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    3.6441
# 7                                       Hedge's g =    3.6161
# 8                                  Glass's delta1 =       inf
# 9                                Point-Biserial r =    0.8787
# Precision Score T-Test
#                        Variable      N      Mean            SD            SE  \
# 0  all_precision_score_baseline   50.0  0.343721  5.607473e-17  7.930164e-18
# 1       all_precision_score_fcg   50.0  0.248015  3.630864e-02  5.134817e-03
# 2                      combined  100.0  0.295868  5.445652e-02  5.445652e-03
#
#    95% Conf.  Interval
# 0   0.343721  0.343721
# 1   0.237696  0.258334
# 2   0.285063  0.306673
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all...  9.570000e-02
# 1                              Degrees of freedom =   9.800000e+01
# 2                                               t =   1.863850e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   3.727700e+00
# 7                                       Hedge's g =   3.699100e+00
# 8                                  Glass's delta1 =   1.706748e+15
# 9                                Point-Biserial r =   8.832000e-01
# F1 Score T-Test
#                 Variable      N      Mean            SD            SE  \
# 0  all_f1_score_baseline   50.0  0.331852  5.607473e-17  7.930164e-18
# 1       all_f1_score_fcg   50.0  0.219253  3.993329e-02  5.647420e-03
# 2               combined  100.0  0.275553  6.317363e-02  6.317363e-03
#
#    95% Conf.  Interval
# 0   0.331852  0.331852
# 1   0.207904  0.230602
# 2   0.263018  0.288088
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  1.126000e-01
# 1                              Degrees of freedom =   9.800000e+01
# 2                                               t =   1.993810e+01
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   1.000000e+00
# 5                          Difference > 0 p value =   0.000000e+00
# 6                                       Cohen's d =   3.987600e+00
# 7                                       Hedge's g =   3.957000e+00
# 8                                  Glass's delta1 =   2.008010e+15
# 9                                Point-Biserial r =   8.957000e-01
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
