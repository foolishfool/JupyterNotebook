# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
#numpy-1.21.4
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("dummy_data.csv")
#csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"gender")
dataread.label_encoding(csv,"platform")
dataread.label_encoding(csv,"interests")
dataread.label_encoding(csv,"location")
dataread.label_encoding(csv,"demographics")
dataread.label_encoding(csv,"income")
dataread.label_encoding(csv,"profession")
dataread.label_encoding(csv,"indebt")
dataread.label_encoding(csv,"isHomeOwner")
dataread.label_encoding(csv,"Owns_Car")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"time_spent")
# Out:
# continuous_feature_num 2
# discrete_feature_num 9
# self.data_discrete_indexes ['gender', 'platform', 'interests', 'location', 'demographics', 'profession', 'indebt', 'isHomeOwner', 'Owns_Car']

# %%
import experiment
scope_num = 30
topology_ratio =2

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 2
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 3
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 4
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 5
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 6
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 7
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 8
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 9
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 10
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 11
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 12
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 13
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 14
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 15
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 16
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 17
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 18
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 19
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 20
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 21
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 22
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 23
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 24
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 25
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 26
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 27
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 28
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 29
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# Experiment number: 30
# accuracy_score_baseline 0.11
# recall_score_baseline 0.11529851050390201
# precision_score_baseline 0.10793462943322887
# f1_score_baseline 0.10453314685619584
# accuracy_score_fcg 0.13333333333333333
# recall_score_fcg 0.13326196023029568
# precision_score_fcg 0.13554894482906088
# f1_score_fcg 0.1317789382178033
# all_accuracy_score_baseline mean 0.10999999999999997
# all_recall_score_baseline mean 0.115298510503902
# all_precision_score_baseline mean 0.10793462943322887
# all_f1_score_baseline mean 0.1045331468561958
# all_accuracy_score_fcg mean 0.13333333333333333
# all_recall_score_fcg mean 0.1332619602302957
# all_precision_score_fcg mean 0.13554894482906085
# all_f1_score_fcg mean 0.13177893821780326
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.110000  2.823006e-17  5.154081e-18
# 1       all_accuracy_score_fcg  30.0  0.133333  0.000000e+00  0.000000e+00
# 2                     combined  60.0  0.121667  1.176512e-02  1.518871e-03
#
#    95% Conf.  Interval
# 0   0.110000  0.110000
# 1        NaN       NaN
# 2   0.118627  0.124706
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_... -2.330000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -4.527157e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.168907e+15
# 7                                       Hedge's g =  -1.153726e+15
# 8                                  Glass's delta1 =  -8.265420e+14
# 9                                Point-Biserial r =  -1.000000e+00
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.115299  1.411503e-17  2.577041e-18
# 1       all_recall_score_fcg  30.0  0.133262  2.823006e-17  5.154081e-18
# 2                   combined  60.0  0.124280  9.057521e-03  1.169321e-03
#
#    95% Conf.  Interval
# 0   0.115299  0.115299
# 1   0.133262  0.133262
# 2   0.121940  0.126620
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -1.800000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -3.117335e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -8.048925e+14
# 7                                       Hedge's g =  -7.944393e+14
# 8                                  Glass's delta1 =  -1.272647e+15
# 9                                Point-Biserial r =  -1.000000e+00
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.107935  0.000000e+00  0.000000e+00
# 1       all_precision_score_fcg  30.0  0.135549  2.823006e-17  5.154081e-18
# 2                      combined  60.0  0.121742  1.392368e-02  1.797539e-03
#
#    95% Conf.  Interval
# 0        NaN       NaN
# 1   0.135549  0.135549
# 2   0.118145  0.125339
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -2.760000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -5.357757e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -1.383367e+15
# 7                                       Hedge's g =  -1.365401e+15
# 8                                  Glass's delta1 =           -inf
# 9                                Point-Biserial r =  -1.000000e+00
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.104533  4.234510e-17  7.731122e-18
# 1       all_f1_score_fcg  30.0  0.131779  2.823006e-17  5.154081e-18
# 2               combined  60.0  0.118156  1.373786e-02  1.773550e-03
#
#    95% Conf.  Interval
# 0   0.104533  0.104533
# 1   0.131779  0.131779
# 2   0.114607  0.121705
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco... -2.720000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -2.932287e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.571133e+14
# 7                                       Hedge's g =  -7.472807e+14
# 8                                  Glass's delta1 =  -6.434226e+14
# 9                                Point-Biserial r =  -1.000000e+00
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\researchpy\ttest.py:70: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = (group1.mean() - group2.mean()) / group1.std()
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
