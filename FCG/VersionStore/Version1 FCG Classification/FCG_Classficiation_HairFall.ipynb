# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("Predict Hair Fall.csv")
csv = csv.drop(columns=['Id'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"Genetics")
dataread.label_encoding(csv,"Hormonal Changes")
dataread.label_encoding(csv,"Medical Conditions")
dataread.label_encoding(csv,"Medications & Treatments")
dataread.label_encoding(csv,"Nutritional Deficiencies ")
dataread.label_encoding(csv,"Stress")
dataread.label_encoding(csv,"Poor Hair Care Habits ")
dataread.label_encoding(csv,"Environmental Factors")
dataread.label_encoding(csv,"Smoking")
dataread.label_encoding(csv,"Weight Loss ")


csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"Hair Loss")
# Out:
# continuous_feature_num 1
# discrete_feature_num 10
# self.data_discrete_indexes ['Genetics', 'Hormonal Changes', 'Medical Conditions', 'Medications & Treatments', 'Nutritional Deficiencies ', 'Stress', 'Poor Hair Care Habits ', 'Environmental Factors', 'Smoking', 'Weight Loss ']

# %%
import experiment
scope_num = 30
topology_ratio =4

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 2
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 3
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 4
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 5
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 6
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 7
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 8
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 9
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 10
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 11
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 12
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 13
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 14
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 15
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 16
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 17
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 18
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 19
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 20
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 21
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 22
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 23
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 24
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 25
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 26
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 27
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 28
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 29
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# Experiment number: 30
# accuracy_score_baseline 0.4916387959866221
# recall_score_baseline 0.49178897440486846
# precision_score_baseline 0.491782355575459
# f1_score_baseline 0.4915876141041704
# accuracy_score_fcg 0.5384615384615384
# recall_score_fcg 0.5408985144084482
# precision_score_fcg 0.5534690534690534
# f1_score_fcg 0.5108819345661451
# all_accuracy_score_baseline mean 0.4916387959866222
# all_recall_score_baseline mean 0.49178897440486863
# all_precision_score_baseline mean 0.49178235557545913
# all_f1_score_baseline mean 0.4915876141041705
# all_accuracy_score_fcg mean 0.5384615384615384
# all_recall_score_fcg mean 0.5408985144084483
# all_precision_score_fcg mean 0.5534690534690534
# all_f1_score_fcg mean 0.5108819345661451
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.491639  1.129203e-16  2.061632e-17
# 1       all_accuracy_score_fcg  30.0  0.538462  0.000000e+00  0.000000e+00
# 2                     combined  60.0  0.515050  2.360894e-02  3.047901e-03
#
#    95% Conf.  Interval
# 0   0.491639  0.491639
# 1        NaN       NaN
# 2   0.508951  0.521149
#                                   Independent t-test       results
# 0  Difference (all_accuracy_score_baseline - all_... -4.680000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -2.271149e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -5.864081e+14
# 7                                       Hedge's g =  -5.787924e+14
# 8                                  Glass's delta1 =  -4.146532e+14
# 9                                Point-Biserial r =  -1.000000e+00
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.491789  1.693804e-16  3.092449e-17
# 1       all_recall_score_fcg  30.0  0.540899  1.129203e-16  2.061632e-17
# 2                   combined  60.0  0.516344  2.476199e-02  3.196759e-03
#
#    95% Conf.  Interval
# 0   0.491789  0.491789
# 1   0.540899  0.540899
# 2   0.509947  0.522740
#                                   Independent t-test       results
# 0  Difference (all_recall_score_baseline - all_re... -4.910000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -1.321335e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -3.411672e+14
# 7                                       Hedge's g =  -3.367365e+14
# 8                                  Glass's delta1 =  -2.899364e+14
# 9                                Point-Biserial r =  -1.000000e+00
# Precision Score T-Test
#                        Variable     N      Mean            SD            SE  \
# 0  all_precision_score_baseline  30.0  0.491782  1.129203e-16  2.061632e-17
# 1       all_precision_score_fcg  30.0  0.553469  0.000000e+00  0.000000e+00
# 2                      combined  60.0  0.522626  3.110363e-02  4.015462e-03
#
#    95% Conf.  Interval
# 0   0.491782  0.491782
# 1        NaN       NaN
# 2   0.514591  0.530661
#                                   Independent t-test       results
# 0  Difference (all_precision_score_baseline - all... -6.170000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -2.992129e+15
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -7.725643e+14
# 7                                       Hedge's g =  -7.625310e+14
# 8                                  Glass's delta1 =  -5.462855e+14
# 9                                Point-Biserial r =  -1.000000e+00
# F1 Score T-Test
#                 Variable     N      Mean            SD            SE  \
# 0  all_f1_score_baseline  30.0  0.491588  1.129203e-16  2.061632e-17
# 1       all_f1_score_fcg  30.0  0.510882  0.000000e+00  0.000000e+00
# 2               combined  60.0  0.501235  9.728572e-03  1.255953e-03
#
#    95% Conf.  Interval
# 0   0.491588  0.491588
# 1        NaN       NaN
# 2   0.498722  0.503748
#                                   Independent t-test       results
# 0  Difference (all_f1_score_baseline - all_f1_sco... -1.930000e-02
# 1                              Degrees of freedom =   5.800000e+01
# 2                                               t =  -9.358759e+14
# 3                           Two side test p value =   0.000000e+00
# 4                          Difference < 0 p value =   0.000000e+00
# 5                          Difference > 0 p value =   1.000000e+00
# 6                                       Cohen's d =  -2.416421e+14
# 7                                       Hedge's g =  -2.385039e+14
# 8                                  Glass's delta1 =  -1.708668e+14
# 9                                Point-Biserial r =  -1.000000e+00
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
