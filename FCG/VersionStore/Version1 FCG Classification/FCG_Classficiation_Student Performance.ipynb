# %%
#THIS CODE ONLY DO THE WHOLE DATA TRAINING, NO CROSS_VALIDATION AND FEATURE SELECTION
import pandas as pd
import numpy as np
import dataset_read
import researchpy as rp
import scipy.stats as stats
import matplotlib.pyplot as plt
import collections
import warnings
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
dataread = dataset_read.DATAREAD()

# %%
csv = pd.read_csv("student_data.csv")
#csv = csv.drop(columns=['CLIENTNUM'])
#csv = csv.sample(int(csv.shape[0]*0.1))


dataread.label_encoding(csv,"school")
dataread.label_encoding(csv,"sex")
dataread.label_encoding(csv,"address")
dataread.label_encoding(csv,"famsize")
dataread.label_encoding(csv,"Pstatus")
dataread.label_encoding(csv,"Mjob")
dataread.label_encoding(csv,"Fjob")
dataread.label_encoding(csv,"reason")
dataread.label_encoding(csv,"guardian")
dataread.label_encoding(csv,"schoolsup")
dataread.label_encoding(csv,"famsup")
dataread.label_encoding(csv,"paid")
dataread.label_encoding(csv,"activities")
dataread.label_encoding(csv,"nursery")
dataread.label_encoding(csv,"higher")
dataread.label_encoding(csv,"internet")
dataread.label_encoding(csv,"romantic")

csv_test = csv.sample(int(csv.shape[0]*0.3))
csv_training = csv.drop(csv_test.index,axis = 0)

dataread.initializedataset(csv,csv_training,csv_test,"reason")
# Out:
# continuous_feature_num 1
# discrete_feature_num 31
# self.data_discrete_indexes ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'G1', 'G2', 'G3']

# %%
import experiment
scope_num = 30
topology_ratio =4

experiment = experiment.Experiment()
experiment.Ttest(dataread,scope_num,topology_ratio)
# Out:
# Experiment number: 1
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.20660045821683753
# f1_score_baseline 0.21285960443512136
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 2
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.22850951974992895
# precision_score_baseline 0.21389176860874975
# f1_score_baseline 0.22063539413826533
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 3
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.20791427203065135
# f1_score_baseline 0.21356382978723404
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 4
# accuracy_score_baseline 0.3050847457627119
# recall_score_baseline 0.2339443023586246
# precision_score_baseline 0.21855742296918768
# f1_score_baseline 0.22591853089387826
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 5
# accuracy_score_baseline 0.3135593220338983
# recall_score_baseline 0.26623868695479946
# precision_score_baseline 0.28182366039508894
# f1_score_baseline 0.2687043557642149
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 6
# accuracy_score_baseline 0.3135593220338983
# recall_score_baseline 0.2451217201856588
# precision_score_baseline 0.2305306383970177
# f1_score_baseline 0.2375824093497153
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 7
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.2045809003937083
# f1_score_baseline 0.21179577464788732
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 8
# accuracy_score_baseline 0.3050847457627119
# recall_score_baseline 0.23968693757696313
# precision_score_baseline 0.22809350503919373
# f1_score_baseline 0.23366324535679375
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 9
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.20791427203065135
# f1_score_baseline 0.21356382978723404
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 10
# accuracy_score_baseline 0.3305084745762712
# recall_score_baseline 0.26173392062138867
# precision_score_baseline 0.24878449878449876
# f1_score_baseline 0.2550229250748154
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Not good accuracy result !!!!!
# Experiment number: 11
# accuracy_score_baseline 0.3050847457627119
# recall_score_baseline 0.2339443023586246
# precision_score_baseline 0.21855742296918768
# f1_score_baseline 0.22591853089387826
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 12
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.22850951974992895
# precision_score_baseline 0.21365995115995115
# f1_score_baseline 0.2206694271911663
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 13
# accuracy_score_baseline 0.288135593220339
# recall_score_baseline 0.2268992137917969
# precision_score_baseline 0.21551238738738737
# f1_score_baseline 0.22103822159261177
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 14
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.2058947142075221
# f1_score_baseline 0.2125
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 15
# accuracy_score_baseline 0.3135593220338983
# recall_score_baseline 0.24320356161788387
# precision_score_baseline 0.22573125686333234
# f1_score_baseline 0.23389694041867953
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 16
# accuracy_score_baseline 0.2711864406779661
# recall_score_baseline 0.212205171923842
# precision_score_baseline 0.2007142857142857
# f1_score_baseline 0.20626646903820814
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Experiment number: 17
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.20791427203065135
# f1_score_baseline 0.21356382978723404
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 18
# accuracy_score_baseline 0.3050847457627119
# recall_score_baseline 0.2339443023586246
# precision_score_baseline 0.21860874974082523
# f1_score_baseline 0.2256858991887704
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 19
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.22850951974992895
# precision_score_baseline 0.21227969348659004
# f1_score_baseline 0.2200892857142857
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 20
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.20388321995464853
# f1_score_baseline 0.21140350877192982
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 21
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.23233399640049257
# precision_score_baseline 0.21768207282913166
# f1_score_baseline 0.2247001616342719
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 22
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.22850951974992895
# precision_score_baseline 0.21412698412698414
# f1_score_baseline 0.22106331168831167
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 23
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.22850951974992895
# precision_score_baseline 0.21626984126984125
# f1_score_baseline 0.22221462747778536
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 24
# accuracy_score_baseline 0.2966101694915254
# recall_score_baseline 0.22850951974992895
# precision_score_baseline 0.21412698412698414
# f1_score_baseline 0.22106331168831167
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 25
# accuracy_score_baseline 0.288135593220339
# recall_score_baseline 0.2268992137917969
# precision_score_baseline 0.21345121717462145
# f1_score_baseline 0.2198920745753525
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 26
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.20791427203065135
# f1_score_baseline 0.21356382978723404
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 27
# accuracy_score_baseline 0.2711864406779661
# recall_score_baseline 0.212205171923842
# precision_score_baseline 0.20255102040816328
# f1_score_baseline 0.2072533111434713
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Experiment number: 28
# accuracy_score_baseline 0.3050847457627119
# recall_score_baseline 0.2339443023586246
# precision_score_baseline 0.21855742296918768
# f1_score_baseline 0.22591853089387826
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# Experiment number: 29
# accuracy_score_baseline 0.2711864406779661
# recall_score_baseline 0.212205171923842
# precision_score_baseline 0.2007142857142857
# f1_score_baseline 0.20626646903820814
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Experiment number: 30
# accuracy_score_baseline 0.2796610169491525
# recall_score_baseline 0.21954627261532633
# precision_score_baseline 0.2067360728075014
# f1_score_baseline 0.21293213828425095
# accuracy_score_fcg 0.2711864406779661
# recall_score_fcg 0.30056855856088593
# precision_score_fcg 0.29786404515882126
# f1_score_fcg 0.2380681665727548
# Not good accuracy result !!!!!
# all_accuracy_score_baseline mean 0.2926553672316384
# all_recall_score_baseline mean 0.22871611827281052
# all_precision_score_baseline mean 0.21611925079457725
# all_f1_score_baseline mean 0.2219736592681
# all_accuracy_score_fcg mean 0.27118644067796616
# all_recall_score_fcg mean 0.300568558560886
# all_precision_score_fcg mean 0.29786404515882126
# all_f1_score_fcg mean 0.2380681665727548
# len plot_unit 30  len (all_test_score_baseline_accuracy) 30
# Accuracy Score T-Test
#                       Variable     N      Mean            SD            SE  \
# 0  all_accuracy_score_baseline  30.0  0.292655  1.505048e-02  2.747830e-03
# 1       all_accuracy_score_fcg  30.0  0.271186  5.646013e-17  1.030816e-17
# 2                     combined  60.0  0.281921  1.511690e-02  1.951583e-03
#
#    95% Conf.  Interval
# 0   0.287035  0.298275
# 1   0.271186  0.271186
# 2   0.278016  0.285826
#                                   Independent t-test  results
# 0  Difference (all_accuracy_score_baseline - all_...   0.0215
# 1                              Degrees of freedom =   58.0000
# 2                                               t =    7.8130
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    1.0000
# 5                          Difference > 0 p value =    0.0000
# 6                                       Cohen's d =    2.0173
# 7                                       Hedge's g =    1.9911
# 8                                  Glass's delta1 =    1.4265
# 9                                Point-Biserial r =    0.7161
# Recall Score T-Test
#                     Variable     N      Mean            SD            SE  \
# 0  all_recall_score_baseline  30.0  0.228716  1.286722e-02  2.349223e-03
# 1       all_recall_score_fcg  30.0  0.300569  5.646013e-17  1.030816e-17
# 2                   combined  60.0  0.264642  3.733563e-02  4.820009e-03
#
#    95% Conf.  Interval
# 0   0.223911  0.233521
# 1   0.300569  0.300569
# 2   0.254998  0.274287
#                                   Independent t-test  results
# 0  Difference (all_recall_score_baseline - all_re...  -0.0719
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -30.5856
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -7.8972
# 7                                       Hedge's g =   -7.7946
# 8                                  Glass's delta1 =   -5.5841
# 9                                Point-Biserial r =   -0.9704
# Precision Score T-Test
#                        Variable     N      Mean        SD        SE  \
# 0  all_precision_score_baseline  30.0  0.216119  0.015963  0.002914
# 1       all_precision_score_fcg  30.0  0.297864  0.000000  0.000000
# 2                      combined  60.0  0.256992  0.042710  0.005514
#
#    95% Conf.  Interval
# 0   0.210159  0.222080
# 1        NaN       NaN
# 2   0.245959  0.268025
#                                   Independent t-test  results
# 0  Difference (all_precision_score_baseline - all...  -0.0817
# 1                              Degrees of freedom =   58.0000
# 2                                               t =  -28.0491
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -7.2422
# 7                                       Hedge's g =   -7.1482
# 8                                  Glass's delta1 =   -5.1210
# 9                                Point-Biserial r =   -0.9651
# F1 Score T-Test
#                 Variable     N      Mean        SD        SE  95% Conf.  \
# 0  all_f1_score_baseline  30.0  0.221974  0.013574  0.002478   0.216905
# 1       all_f1_score_fcg  30.0  0.238068  0.000000  0.000000        NaN
# 2               combined  60.0  0.230021  0.012507  0.001615   0.226790
#
#    Interval
# 0  0.227042
# 1       NaN
# 2  0.233252
#                                   Independent t-test  results
# 0  Difference (all_f1_score_baseline - all_f1_sco...  -0.0161
# 1                              Degrees of freedom =   58.0000
# 2                                               t =   -6.4943
# 3                           Two side test p value =    0.0000
# 4                          Difference < 0 p value =    0.0000
# 5                          Difference > 0 p value =    1.0000
# 6                                       Cohen's d =   -1.6768
# 7                                       Hedge's g =   -1.6551
# 8                                  Glass's delta1 =   -1.1857
# 9                                Point-Biserial r =   -0.6489
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2241: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\fooli\anaconda3\envs\gpu_env\lib\site-packages\scipy\stats\_distn_infrastructure.py:2242: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
